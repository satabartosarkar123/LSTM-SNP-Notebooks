# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value clipped to $[0, 1]$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Gate Replacement
# Uses FuzzyLSTMSNPCell instead of LSTMSNPCell.
# Gradient clipping applied for stability.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 473 (1.85 KB)
#  Trainable params: 473 (1.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 2)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (230, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (230, 1, 1), y_train shape: (230,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=3798.3286, Expected=3796.0000
# Month=2, Predicted=3797.2713, Expected=3793.0000
# Month=3, Predicted=3793.9321, Expected=3766.0000
# Month=4, Predicted=3765.0213, Expected=3747.0000
# Month=5, Predicted=3746.0213, Expected=3754.0000
# Month=6, Predicted=3756.2758, Expected=3756.0000
# Month=7, Predicted=3757.7911, Expected=3767.0000
# Month=8, Predicted=3769.4661, Expected=3751.0000
# Month=9, Predicted=3750.0213, Expected=3769.0000
# Month=10, Predicted=3771.2643, Expected=3760.0000
# Month=11, Predicted=3759.6986, Expected=3785.0000
# Month=12, Predicted=3786.6077, Expected=3776.0000
# Month=13, Predicted=3775.7316, Expected=3755.0000
# Month=14, Predicted=3754.0213, Expected=3755.0000
# Month=15, Predicted=3756.4484, Expected=3751.0000
# Month=16, Predicted=3751.7371, Expected=3776.0000
# Month=17, Predicted=3777.6090, Expected=3847.0000
# Month=18, Predicted=3845.9991, Expected=3830.0000
# Month=19, Predicted=3829.0213, Expected=3881.0000
# Month=20, Predicted=3880.0213, Expected=3899.0000
# Month=21, Predicted=3901.3596, Expected=3917.0000
# Month=22, Predicted=3919.2940, Expected=3913.0000
# Month=23, Predicted=3913.7978, Expected=3901.0000
# Month=24, Predicted=3900.0213, Expected=3886.0000
# Month=25, Predicted=3885.0213, Expected=3892.5000
# Month=26, Predicted=3894.7411, Expected=3899.0000
# Month=27, Predicted=3901.2716, Expected=3886.0000
# Month=28, Predicted=3885.0213, Expected=3908.0000
# Month=29, Predicted=3909.9352, Expected=3875.0000
# Month=30, Predicted=3874.0213, Expected=3860.0000
# Month=31, Predicted=3859.0213, Expected=3880.0000
# Month=32, Predicted=3882.1168, Expected=3895.0000
# Month=33, Predicted=3897.4538, Expected=3954.0000
# Month=34, Predicted=3953.0213, Expected=3933.0000
# Month=35, Predicted=3932.0213, Expected=3937.0000
# Month=36, Predicted=3939.0010, Expected=3869.0000
# Month=37, Predicted=3873.2156, Expected=3852.0000
# Month=38, Predicted=3851.0213, Expected=3837.0000
# Month=39, Predicted=3836.0213, Expected=3832.0000
# Month=40, Predicted=3832.5081, Expected=3849.0000
# Month=41, Predicted=3851.3293, Expected=3863.0000
# Month=42, Predicted=3865.4782, Expected=3878.0000
# Month=43, Predicted=3880.4427, Expected=3855.0000
# Month=44, Predicted=3854.0213, Expected=3843.0000
# Month=45, Predicted=3842.0213, Expected=3847.0000
# Month=46, Predicted=3849.0068, Expected=3801.0000
# Month=47, Predicted=3800.0213, Expected=3787.0000
# Month=48, Predicted=3786.0213, Expected=3776.0000
# Month=49, Predicted=3775.1580, Expected=3797.0000
# Month=50, Predicted=3799.0309, Expected=3821.0000
# Month=51, Predicted=3822.7390, Expected=3877.0000
# Month=52, Predicted=3876.0213, Expected=3875.0000
# Month=53, Predicted=3876.4334, Expected=3890.0000
# Month=54, Predicted=3892.4212, Expected=3910.0000
# Month=55, Predicted=3912.1370, Expected=3924.0000
# Month=56, Predicted=3926.4849, Expected=3918.0000
# Month=57, Predicted=3918.3595, Expected=3936.0000
# Month=58, Predicted=3938.2687, Expected=3911.0000
# Month=59, Predicted=3910.0213, Expected=3891.0000
# Month=60, Predicted=3890.0213, Expected=3855.0000
# Run 1 — RMSE: 24.466437, MSE: 598.606535, NMSE: 0.0027266586
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3801.0744, Expected=3796.0000
# Month=2, Predicted=3796.7581, Expected=3793.0000
# Month=3, Predicted=3793.5512, Expected=3766.0000
# Month=4, Predicted=3761.9711, Expected=3747.0000
# Month=5, Predicted=3744.3003, Expected=3754.0000
# Month=6, Predicted=3756.3444, Expected=3756.0000
# Month=7, Predicted=3757.4635, Expected=3767.0000
# Month=8, Predicted=3770.0256, Expected=3751.0000
# Month=9, Predicted=3748.9573, Expected=3769.0000
# Month=10, Predicted=3772.0744, Expected=3760.0000
# Month=11, Predicted=3759.5038, Expected=3785.0000
# Month=12, Predicted=3788.0744, Expected=3776.0000
# Month=13, Predicted=3775.5086, Expected=3755.0000
# Month=14, Predicted=3751.9116, Expected=3755.0000
# Month=15, Predicted=3756.0935, Expected=3751.0000
# Month=16, Predicted=3751.3714, Expected=3776.0000
# Month=17, Predicted=3779.0744, Expected=3847.0000
# Month=18, Predicted=3850.0532, Expected=3830.0000
# Month=19, Predicted=3827.7865, Expected=3881.0000
# Month=20, Predicted=3884.0744, Expected=3899.0000
# Month=21, Predicted=3902.0744, Expected=3917.0000
# Month=22, Predicted=3920.0744, Expected=3913.0000
# Month=23, Predicted=3913.3812, Expected=3901.0000
# Month=24, Predicted=3899.8878, Expected=3886.0000
# Month=25, Predicted=3884.1773, Expected=3892.5000
# Month=26, Predicted=3894.7576, Expected=3899.0000
# Month=27, Predicted=3901.2644, Expected=3886.0000
# Month=28, Predicted=3884.6522, Expected=3908.0000
# Month=29, Predicted=3911.0744, Expected=3875.0000
# Month=30, Predicted=3870.4693, Expected=3860.0000
# Month=31, Predicted=3858.1681, Expected=3880.0000
# Month=32, Predicted=3883.0744, Expected=3895.0000
# Month=33, Predicted=3898.0744, Expected=3954.0000
# Month=34, Predicted=3957.0744, Expected=3933.0000
# Month=35, Predicted=3929.9319, Expected=3937.0000
# Month=36, Predicted=3938.8159, Expected=3869.0000
# Month=37, Predicted=3872.5707, Expected=3852.0000
# Month=38, Predicted=3849.7271, Expected=3837.0000
# Month=39, Predicted=3835.1770, Expected=3832.0000
# Month=40, Predicted=3832.1883, Expected=3849.0000
# Month=41, Predicted=3852.0744, Expected=3863.0000
# Month=42, Predicted=3866.0744, Expected=3878.0000
# Month=43, Predicted=3881.0744, Expected=3855.0000
# Month=44, Predicted=3851.5562, Expected=3843.0000
# Month=45, Predicted=3841.8838, Expected=3847.0000
# Month=46, Predicted=3848.8163, Expected=3801.0000
# Month=47, Predicted=3797.3265, Expected=3787.0000
# Month=48, Predicted=3785.3961, Expected=3776.0000
# Month=49, Predicted=3775.1276, Expected=3797.0000
# Month=50, Predicted=3800.0744, Expected=3821.0000
# Month=51, Predicted=3824.0744, Expected=3877.0000
# Month=52, Predicted=3880.0744, Expected=3875.0000
# Month=53, Predicted=3875.7869, Expected=3890.0000
# Month=54, Predicted=3893.0744, Expected=3910.0000
# Month=55, Predicted=3913.0744, Expected=3924.0000
# Month=56, Predicted=3927.0744, Expected=3918.0000
# Month=57, Predicted=3918.0211, Expected=3936.0000
# Month=58, Predicted=3939.0744, Expected=3911.0000
# Month=59, Predicted=3907.2384, Expected=3891.0000
# Month=60, Predicted=3888.1012, Expected=3855.0000
# Run 2 — RMSE: 24.322996, MSE: 591.608156, NMSE: 0.0026681500
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3796.8737, Expected=3796.0000
# Month=2, Predicted=3797.3869, Expected=3793.0000
# Month=3, Predicted=3794.2026, Expected=3766.0000
# Month=4, Predicted=3766.3792, Expected=3747.0000
# Month=5, Predicted=3747.3792, Expected=3754.0000
# Month=6, Predicted=3756.2288, Expected=3756.0000
# Month=7, Predicted=3757.8819, Expected=3767.0000
# Month=8, Predicted=3769.2721, Expected=3751.0000
# Month=9, Predicted=3751.3792, Expected=3769.0000
# Month=10, Predicted=3770.8431, Expected=3760.0000
# Month=11, Predicted=3760.4229, Expected=3785.0000
# Month=12, Predicted=3785.8478, Expected=3776.0000
# Month=13, Predicted=3776.4271, Expected=3755.0000
# Month=14, Predicted=3755.3792, Expected=3755.0000
# Month=15, Predicted=3756.6429, Expected=3751.0000
# Month=16, Predicted=3752.0332, Expected=3776.0000
# Month=17, Predicted=3776.8489, Expected=3847.0000
# Month=18, Predicted=3830.5695, Expected=3830.0000
# Month=19, Predicted=3830.3792, Expected=3881.0000
# Month=20, Predicted=3874.0941, Expected=3899.0000
# Month=21, Predicted=3900.9170, Expected=3917.0000
# Month=22, Predicted=3918.8583, Expected=3913.0000
# Month=23, Predicted=3914.0416, Expected=3901.0000
# Month=24, Predicted=3901.3792, Expected=3886.0000
# Month=25, Predicted=3886.3792, Expected=3892.5000
# Month=26, Predicted=3894.7089, Expected=3899.0000
# Month=27, Predicted=3901.2143, Expected=3886.0000
# Month=28, Predicted=3886.3792, Expected=3908.0000
# Month=29, Predicted=3909.3394, Expected=3875.0000
# Month=30, Predicted=3875.3792, Expected=3860.0000
# Month=31, Predicted=3860.3792, Expected=3880.0000
# Month=32, Predicted=3881.6136, Expected=3895.0000
# Month=33, Predicted=3897.1163, Expected=3954.0000
# Month=34, Predicted=3943.6277, Expected=3933.0000
# Month=35, Predicted=3933.3792, Expected=3937.0000
# Month=36, Predicted=3939.0577, Expected=3869.0000
# Month=37, Predicted=3873.6658, Expected=3852.0000
# Month=38, Predicted=3852.3792, Expected=3837.0000
# Month=39, Predicted=3837.3792, Expected=3832.0000
# Month=40, Predicted=3832.8511, Expected=3849.0000
# Month=41, Predicted=3850.9420, Expected=3863.0000
# Month=42, Predicted=3865.1743, Expected=3878.0000
# Month=43, Predicted=3880.1106, Expected=3855.0000
# Month=44, Predicted=3855.3792, Expected=3843.0000
# Month=45, Predicted=3843.3792, Expected=3847.0000
# Month=46, Predicted=3849.0582, Expected=3801.0000
# Month=47, Predicted=3801.3792, Expected=3787.0000
# Month=48, Predicted=3787.3792, Expected=3776.0000
# Month=49, Predicted=3776.3792, Expected=3797.0000
# Month=50, Predicted=3798.4824, Expected=3821.0000
# Month=51, Predicted=3822.0410, Expected=3877.0000
# Month=52, Predicted=3868.0017, Expected=3875.0000
# Month=53, Predicted=3876.4229, Expected=3890.0000
# Month=54, Predicted=3892.1018, Expected=3910.0000
# Month=55, Predicted=3911.6261, Expected=3924.0000
# Month=56, Predicted=3926.1773, Expected=3918.0000
# Month=57, Predicted=3918.6696, Expected=3936.0000
# Month=58, Predicted=3937.8444, Expected=3911.0000
# Month=59, Predicted=3911.3792, Expected=3891.0000
# Month=60, Predicted=3891.3792, Expected=3855.0000
# Run 3 — RMSE: 24.457199, MSE: 598.154578, NMSE: 0.0027652754
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3796.8742, Expected=3796.0000
# Month=2, Predicted=3797.6296, Expected=3793.0000
# Month=3, Predicted=3794.4474, Expected=3766.0000
# Month=4, Predicted=3763.8603, Expected=3747.0000
# Month=5, Predicted=3745.9430, Expected=3754.0000
# Month=6, Predicted=3756.7956, Expected=3756.0000
# Month=7, Predicted=3758.2977, Expected=3767.0000
# Month=8, Predicted=3769.8425, Expected=3751.0000
# Month=9, Predicted=3750.3851, Expected=3769.0000
# Month=10, Predicted=3771.3358, Expected=3760.0000
# Month=11, Predicted=3760.4743, Expected=3785.0000
# Month=12, Predicted=3786.1659, Expected=3776.0000
# Month=13, Predicted=3776.4775, Expected=3755.0000
# Month=14, Predicted=3753.6566, Expected=3755.0000
# Month=15, Predicted=3756.9562, Expected=3751.0000
# Month=16, Predicted=3752.2821, Expected=3776.0000
# Month=17, Predicted=3777.1662, Expected=3847.0000
# Month=18, Predicted=3829.2928, Expected=3830.0000
# Month=19, Predicted=3829.2789, Expected=3881.0000
# Month=20, Predicted=3873.4815, Expected=3899.0000
# Month=21, Predicted=3901.3762, Expected=3917.0000
# Month=22, Predicted=3919.3429, Expected=3913.0000
# Month=23, Predicted=3914.2864, Expected=3901.0000
# Month=24, Predicted=3900.9958, Expected=3886.0000
# Month=25, Predicted=3885.5342, Expected=3892.5000
# Month=26, Predicted=3895.2713, Expected=3899.0000
# Month=27, Predicted=3901.7726, Expected=3886.0000
# Month=28, Predicted=3885.8415, Expected=3908.0000
# Month=29, Predicted=3909.7414, Expected=3875.0000
# Month=30, Predicted=3872.1766, Expected=3860.0000
# Month=31, Predicted=3859.5364, Expected=3880.0000
# Month=32, Predicted=3882.0644, Expected=3895.0000
# Month=33, Predicted=3897.6482, Expected=3954.0000
# Month=34, Predicted=3942.7231, Expected=3933.0000
# Month=35, Predicted=3931.6857, Expected=3937.0000
# Month=36, Predicted=3939.5932, Expected=3869.0000
# Month=37, Predicted=3869.7647, Expected=3852.0000
# Month=38, Predicted=3851.2462, Expected=3837.0000
# Month=39, Predicted=3836.5347, Expected=3832.0000
# Month=40, Predicted=3833.1179, Expected=3849.0000
# Month=41, Predicted=3851.4510, Expected=3863.0000
# Month=42, Predicted=3865.7192, Expected=3878.0000
# Month=43, Predicted=3880.6449, Expected=3855.0000
# Month=44, Predicted=3853.3834, Expected=3843.0000
# Month=45, Predicted=3842.9971, Expected=3847.0000
# Month=46, Predicted=3849.5921, Expected=3801.0000
# Month=47, Predicted=3797.2317, Expected=3787.0000
# Month=48, Predicted=3786.6912, Expected=3776.0000
# Month=49, Predicted=3776.1529, Expected=3797.0000
# Month=50, Predicted=3798.9091, Expected=3821.0000
# Month=51, Predicted=3822.3795, Expected=3877.0000
# Month=52, Predicted=3867.1961, Expected=3875.0000
# Month=53, Predicted=3876.6496, Expected=3890.0000
# Month=54, Predicted=3892.6403, Expected=3910.0000
# Month=55, Predicted=3912.0701, Expected=3924.0000
# Month=56, Predicted=3926.7209, Expected=3918.0000
# Month=57, Predicted=3918.9572, Expected=3936.0000
# Month=58, Predicted=3938.3355, Expected=3911.0000
# Month=59, Predicted=3909.1182, Expected=3891.0000
# Month=60, Predicted=3889.7994, Expected=3855.0000
# Run 4 — RMSE: 24.305886, MSE: 590.776096, NMSE: 0.0027251258
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3796.5809, Expected=3796.0000
# Month=2, Predicted=3797.3144, Expected=3793.0000
# Month=3, Predicted=3794.0654, Expected=3766.0000
# Month=4, Predicted=3762.7449, Expected=3747.0000
# Month=5, Predicted=3744.6047, Expected=3754.0000
# Month=6, Predicted=3757.1875, Expected=3756.0000
# Month=7, Predicted=3758.2811, Expected=3767.0000
# Month=8, Predicted=3770.4923, Expected=3751.0000
# Month=9, Predicted=3749.0653, Expected=3769.0000
# Month=10, Predicted=3772.0163, Expected=3760.0000
# Month=11, Predicted=3759.5349, Expected=3785.0000
# Month=12, Predicted=3786.4489, Expected=3776.0000
# Month=13, Predicted=3775.5345, Expected=3755.0000
# Month=14, Predicted=3752.3261, Expected=3755.0000
# Month=15, Predicted=3756.8299, Expected=3751.0000
# Month=16, Predicted=3751.8057, Expected=3776.0000
# Month=17, Predicted=3777.4486, Expected=3847.0000
# Month=18, Predicted=3831.6464, Expected=3830.0000
# Month=19, Predicted=3827.9008, Expected=3881.0000
# Month=20, Predicted=3873.3763, Expected=3899.0000
# Month=21, Predicted=3902.0201, Expected=3917.0000
# Month=22, Predicted=3920.0130, Expected=3913.0000
# Month=23, Predicted=3913.7963, Expected=3901.0000
# Month=24, Predicted=3899.8643, Expected=3886.0000
# Month=25, Predicted=3884.2664, Expected=3892.5000
# Month=26, Predicted=3895.6197, Expected=3899.0000
# Month=27, Predicted=3902.1107, Expected=3886.0000
# Month=28, Predicted=3884.6443, Expected=3908.0000
# Month=29, Predicted=3910.2238, Expected=3875.0000
# Month=30, Predicted=3871.4889, Expected=3860.0000
# Month=31, Predicted=3858.2708, Expected=3880.0000
# Month=32, Predicted=3882.6595, Expected=3895.0000
# Month=33, Predicted=3898.3739, Expected=3954.0000
# Month=34, Predicted=3943.3347, Expected=3933.0000
# Month=35, Predicted=3930.3153, Expected=3937.0000
# Month=36, Predicted=3939.7067, Expected=3869.0000
# Month=37, Predicted=3871.8776, Expected=3852.0000
# Month=38, Predicted=3849.9224, Expected=3837.0000
# Month=39, Predicted=3835.2694, Expected=3832.0000
# Month=40, Predicted=3832.5576, Expected=3849.0000
# Month=41, Predicted=3852.1598, Expected=3863.0000
# Month=42, Predicted=3866.4433, Expected=3878.0000
# Month=43, Predicted=3881.3739, Expected=3855.0000
# Month=44, Predicted=3852.0740, Expected=3843.0000
# Month=45, Predicted=3841.8747, Expected=3847.0000
# Month=46, Predicted=3849.7042, Expected=3801.0000
# Month=47, Predicted=3798.0421, Expected=3787.0000
# Month=48, Predicted=3785.4637, Expected=3776.0000
# Month=49, Predicted=3775.0919, Expected=3797.0000
# Month=50, Predicted=3799.4505, Expected=3821.0000
# Month=51, Predicted=3822.7210, Expected=3877.0000
# Month=52, Predicted=3867.4830, Expected=3875.0000
# Month=53, Predicted=3876.3224, Expected=3890.0000
# Month=54, Predicted=3893.3762, Expected=3910.0000
# Month=55, Predicted=3912.6571, Expected=3924.0000
# Month=56, Predicted=3927.4434, Expected=3918.0000
# Month=57, Predicted=3918.2819, Expected=3936.0000
# Month=58, Predicted=3939.0150, Expected=3911.0000
# Month=59, Predicted=3907.8809, Expected=3891.0000
# Month=60, Predicted=3888.4638, Expected=3855.0000
# Run 5 — RMSE: 24.370065, MSE: 593.900087, NMSE: 0.0027226704
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3795.3814, Expected=3796.0000
# Month=2, Predicted=3797.6711, Expected=3793.0000
# Month=3, Predicted=3794.3310, Expected=3766.0000
# Month=4, Predicted=3762.1175, Expected=3747.0000
# Month=5, Predicted=3744.2802, Expected=3754.0000
# Month=6, Predicted=3757.9066, Expected=3756.0000
# Month=7, Predicted=3758.7184, Expected=3767.0000
# Month=8, Predicted=3771.8174, Expected=3751.0000
# Month=9, Predicted=3748.8813, Expected=3769.0000
# Month=10, Predicted=3772.0715, Expected=3760.0000
# Month=11, Predicted=3759.6659, Expected=3785.0000
# Month=12, Predicted=3785.6798, Expected=3776.0000
# Month=13, Predicted=3775.6670, Expected=3755.0000
# Month=14, Predicted=3751.8959, Expected=3755.0000
# Month=15, Predicted=3757.1323, Expected=3751.0000
# Month=16, Predicted=3752.0534, Expected=3776.0000
# Month=17, Predicted=3776.6887, Expected=3847.0000
# Month=18, Predicted=3827.5683, Expected=3830.0000
# Month=19, Predicted=3827.5285, Expected=3881.0000
# Month=20, Predicted=3871.0461, Expected=3899.0000
# Month=21, Predicted=3902.2081, Expected=3917.0000
# Month=22, Predicted=3920.1297, Expected=3913.0000
# Month=23, Predicted=3914.0737, Expected=3901.0000
# Month=24, Predicted=3899.8723, Expected=3886.0000
# Month=25, Predicted=3884.1414, Expected=3892.5000
# Month=26, Predicted=3896.2988, Expected=3899.0000
# Month=27, Predicted=3902.8536, Expected=3886.0000
# Month=28, Predicted=3884.6113, Expected=3908.0000
# Month=29, Predicted=3909.7314, Expected=3875.0000
# Month=30, Predicted=3870.8026, Expected=3860.0000
# Month=31, Predicted=3858.1212, Expected=3880.0000
# Month=32, Predicted=3882.4107, Expected=3895.0000
# Month=33, Predicted=3899.0834, Expected=3954.0000
# Month=34, Predicted=3940.4191, Expected=3933.0000
# Month=35, Predicted=3929.6967, Expected=3937.0000
# Month=36, Predicted=3940.1785, Expected=3869.0000
# Month=37, Predicted=3873.7298, Expected=3852.0000
# Month=38, Predicted=3849.6555, Expected=3837.0000
# Month=39, Predicted=3835.1454, Expected=3832.0000
# Month=40, Predicted=3832.7601, Expected=3849.0000
# Month=41, Predicted=3852.4108, Expected=3863.0000
# Month=42, Predicted=3867.3825, Expected=3878.0000
# Month=43, Predicted=3882.0716, Expected=3855.0000
# Month=44, Predicted=3851.5099, Expected=3843.0000
# Month=45, Predicted=3841.8736, Expected=3847.0000
# Month=46, Predicted=3850.1961, Expected=3801.0000
# Month=47, Predicted=3798.1231, Expected=3787.0000
# Month=48, Predicted=3785.3383, Expected=3776.0000
# Month=49, Predicted=3775.1333, Expected=3797.0000
# Month=50, Predicted=3799.0780, Expected=3821.0000
# Month=51, Predicted=3822.0974, Expected=3877.0000
# Month=52, Predicted=3864.8579, Expected=3875.0000
# Month=53, Predicted=3876.7192, Expected=3890.0000
# Month=54, Predicted=3894.0444, Expected=3910.0000
# Month=55, Predicted=3912.4632, Expected=3924.0000
# Month=56, Predicted=3928.3883, Expected=3918.0000
# Month=57, Predicted=3918.5024, Expected=3936.0000
# Month=58, Predicted=3939.0862, Expected=3911.0000
# Month=59, Predicted=3907.2383, Expected=3891.0000
# Month=60, Predicted=3888.0936, Expected=3855.0000
# Run 6 — RMSE: 24.516914, MSE: 601.079051, NMSE: 0.0027567879
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3797.1877, Expected=3796.0000
# Month=2, Predicted=3797.4494, Expected=3793.0000
# Month=3, Predicted=3794.2538, Expected=3766.0000
# Month=4, Predicted=3764.1293, Expected=3747.0000
# Month=5, Predicted=3745.9293, Expected=3754.0000
# Month=6, Predicted=3756.4794, Expected=3756.0000
# Month=7, Predicted=3758.0503, Expected=3767.0000
# Month=8, Predicted=3769.5626, Expected=3751.0000
# Month=9, Predicted=3750.2348, Expected=3769.0000
# Month=10, Predicted=3771.1864, Expected=3760.0000
# Month=11, Predicted=3759.9437, Expected=3785.0000
# Month=12, Predicted=3786.2102, Expected=3776.0000
# Month=13, Predicted=3775.9446, Expected=3755.0000
# Month=14, Predicted=3753.7281, Expected=3755.0000
# Month=15, Predicted=3756.7744, Expected=3751.0000
# Month=16, Predicted=3752.0513, Expected=3776.0000
# Month=17, Predicted=3777.2097, Expected=3847.0000
# Month=18, Predicted=3830.6851, Expected=3830.0000
# Month=19, Predicted=3829.1472, Expected=3881.0000
# Month=20, Predicted=3874.3395, Expected=3899.0000
# Month=21, Predicted=3901.2013, Expected=3917.0000
# Month=22, Predicted=3919.1879, Expected=3913.0000
# Month=23, Predicted=3914.0536, Expected=3901.0000
# Month=24, Predicted=3900.6410, Expected=3886.0000
# Month=25, Predicted=3885.3370, Expected=3892.5000
# Month=26, Predicted=3894.9538, Expected=3899.0000
# Month=27, Predicted=3901.4534, Expected=3886.0000
# Month=28, Predicted=3885.5393, Expected=3908.0000
# Month=29, Predicted=3909.6974, Expected=3875.0000
# Month=30, Predicted=3872.5587, Expected=3860.0000
# Month=31, Predicted=3859.3357, Expected=3880.0000
# Month=32, Predicted=3881.9654, Expected=3895.0000
# Month=33, Predicted=3897.4278, Expected=3954.0000
# Month=34, Predicted=3943.8026, Expected=3933.0000
# Month=35, Predicted=3931.7371, Expected=3937.0000
# Month=36, Predicted=3939.2654, Expected=3869.0000
# Month=37, Predicted=3872.6764, Expected=3852.0000
# Month=38, Predicted=3851.1304, Expected=3837.0000
# Month=39, Predicted=3836.3365, Expected=3832.0000
# Month=40, Predicted=3832.8362, Expected=3849.0000
# Month=41, Predicted=3851.2791, Expected=3863.0000
# Month=42, Predicted=3865.4813, Expected=3878.0000
# Month=43, Predicted=3880.4264, Expected=3855.0000
# Month=44, Predicted=3853.5264, Expected=3843.0000
# Month=45, Predicted=3842.6400, Expected=3847.0000
# Month=46, Predicted=3849.2671, Expected=3801.0000
# Month=47, Predicted=3797.5026, Expected=3787.0000
# Month=48, Predicted=3786.4371, Expected=3776.0000
# Month=49, Predicted=3775.7422, Expected=3797.0000
# Month=50, Predicted=3798.8375, Expected=3821.0000
# Month=51, Predicted=3822.3851, Expected=3877.0000
# Month=52, Predicted=3868.1851, Expected=3875.0000
# Month=53, Predicted=3876.4617, Expected=3890.0000
# Month=54, Predicted=3892.4256, Expected=3910.0000
# Month=55, Predicted=3911.9661, Expected=3924.0000
# Month=56, Predicted=3926.4820, Expected=3918.0000
# Month=57, Predicted=3918.6077, Expected=3936.0000
# Month=58, Predicted=3938.1869, Expected=3911.0000
# Month=59, Predicted=3909.3271, Expected=3891.0000
# Month=60, Predicted=3889.8279, Expected=3855.0000
# Run 7 — RMSE: 24.341307, MSE: 592.499205, NMSE: 0.0027278978
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3796.8565, Expected=3796.0000
# Month=2, Predicted=3797.3878, Expected=3793.0000
# Month=3, Predicted=3794.0677, Expected=3766.0000
# Month=4, Predicted=3765.8656, Expected=3747.0000
# Month=5, Predicted=3747.0015, Expected=3754.0000
# Month=6, Predicted=3756.4465, Expected=3756.0000
# Month=7, Predicted=3757.9749, Expected=3767.0000
# Month=8, Predicted=3769.6107, Expected=3751.0000
# Month=9, Predicted=3751.0866, Expected=3769.0000
# Month=10, Predicted=3771.1802, Expected=3760.0000
# Month=11, Predicted=3760.4023, Expected=3785.0000
# Month=12, Predicted=3786.0673, Expected=3776.0000
# Month=13, Predicted=3776.4181, Expected=3755.0000
# Month=14, Predicted=3754.9567, Expected=3755.0000
# Month=15, Predicted=3756.6147, Expected=3751.0000
# Month=16, Predicted=3751.8574, Expected=3776.0000
# Month=17, Predicted=3777.0788, Expected=3847.0000
# Month=18, Predicted=3826.6929, Expected=3830.0000
# Month=19, Predicted=3830.1091, Expected=3881.0000
# Month=20, Predicted=3872.5430, Expected=3899.0000
# Month=21, Predicted=3901.4886, Expected=3917.0000
# Month=22, Predicted=3919.2836, Expected=3913.0000
# Month=23, Predicted=3913.9031, Expected=3901.0000
# Month=24, Predicted=3901.1935, Expected=3886.0000
# Month=25, Predicted=3886.1058, Expected=3892.5000
# Month=26, Predicted=3894.9165, Expected=3899.0000
# Month=27, Predicted=3901.4615, Expected=3886.0000
# Month=28, Predicted=3886.1688, Expected=3908.0000
# Month=29, Predicted=3909.6266, Expected=3875.0000
# Month=30, Predicted=3874.8656, Expected=3860.0000
# Month=31, Predicted=3860.1044, Expected=3880.0000
# Month=32, Predicted=3881.9315, Expected=3895.0000
# Month=33, Predicted=3897.5495, Expected=3954.0000
# Month=34, Predicted=3941.2838, Expected=3933.0000
# Month=35, Predicted=3932.9884, Expected=3937.0000
# Month=36, Predicted=3939.1813, Expected=3869.0000
# Month=37, Predicted=3873.9454, Expected=3852.0000
# Month=38, Predicted=3852.0515, Expected=3837.0000
# Month=39, Predicted=3837.1049, Expected=3832.0000
# Month=40, Predicted=3832.7093, Expected=3849.0000
# Month=41, Predicted=3851.3024, Expected=3863.0000
# Month=42, Predicted=3865.5916, Expected=3878.0000
# Month=43, Predicted=3880.5236, Expected=3855.0000
# Month=44, Predicted=3854.9194, Expected=3843.0000
# Month=45, Predicted=3843.1893, Expected=3847.0000
# Month=46, Predicted=3849.1902, Expected=3801.0000
# Month=47, Predicted=3800.8656, Expected=3787.0000
# Month=48, Predicted=3787.1322, Expected=3776.0000
# Month=49, Predicted=3776.2202, Expected=3797.0000
# Month=50, Predicted=3798.7910, Expected=3821.0000
# Month=51, Predicted=3822.3790, Expected=3877.0000
# Month=52, Predicted=3866.0501, Expected=3875.0000
# Month=53, Predicted=3876.5060, Expected=3890.0000
# Month=54, Predicted=3892.4701, Expected=3910.0000
# Month=55, Predicted=3912.0188, Expected=3924.0000
# Month=56, Predicted=3926.6060, Expected=3918.0000
# Month=57, Predicted=3918.6614, Expected=3936.0000
# Month=58, Predicted=3938.1978, Expected=3911.0000
# Month=59, Predicted=3910.8807, Expected=3891.0000
# Month=60, Predicted=3890.9779, Expected=3855.0000
# Run 8 — RMSE: 24.444632, MSE: 597.540043, NMSE: 0.0027624046
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3798.2339, Expected=3796.0000
# Month=2, Predicted=3796.5967, Expected=3793.0000
# Month=3, Predicted=3793.1332, Expected=3766.0000
# Month=4, Predicted=3763.0520, Expected=3747.0000
# Month=5, Predicted=3744.3719, Expected=3754.0000
# Month=6, Predicted=3756.4740, Expected=3756.0000
# Month=7, Predicted=3757.3823, Expected=3767.0000
# Month=8, Predicted=3770.1643, Expected=3751.0000
# Month=9, Predicted=3748.7365, Expected=3769.0000
# Month=10, Predicted=3771.2847, Expected=3760.0000
# Month=11, Predicted=3758.9120, Expected=3785.0000
# Month=12, Predicted=3786.3948, Expected=3776.0000
# Month=13, Predicted=3774.9510, Expected=3755.0000
# Month=14, Predicted=3752.2354, Expected=3755.0000
# Month=15, Predicted=3755.7903, Expected=3751.0000
# Month=16, Predicted=3750.9081, Expected=3776.0000
# Month=17, Predicted=3777.3930, Expected=3847.0000
# Month=18, Predicted=3842.7023, Expected=3830.0000
# Month=19, Predicted=3827.8661, Expected=3881.0000
# Month=20, Predicted=3879.1398, Expected=3899.0000
# Month=21, Predicted=3901.2439, Expected=3917.0000
# Month=22, Predicted=3919.2696, Expected=3913.0000
# Month=23, Predicted=3913.0029, Expected=3901.0000
# Month=24, Predicted=3899.2784, Expected=3886.0000
# Month=25, Predicted=3883.8150, Expected=3892.5000
# Month=26, Predicted=3894.8684, Expected=3899.0000
# Month=27, Predicted=3901.4574, Expected=3886.0000
# Month=28, Predicted=3884.1471, Expected=3908.0000
# Month=29, Predicted=3909.7764, Expected=3875.0000
# Month=30, Predicted=3872.1696, Expected=3860.0000
# Month=31, Predicted=3857.8004, Expected=3880.0000
# Month=32, Predicted=3882.0307, Expected=3895.0000
# Month=33, Predicted=3897.6489, Expected=3954.0000
# Month=34, Predicted=3951.1488, Expected=3933.0000
# Month=35, Predicted=3930.3641, Expected=3937.0000
# Month=36, Predicted=3938.7593, Expected=3869.0000
# Month=37, Predicted=3872.6613, Expected=3852.0000
# Month=38, Predicted=3849.5694, Expected=3837.0000
# Month=39, Predicted=3834.8079, Expected=3832.0000
# Month=40, Predicted=3831.6309, Expected=3849.0000
# Month=41, Predicted=3851.4081, Expected=3863.0000
# Month=42, Predicted=3865.7774, Expected=3878.0000
# Month=43, Predicted=3880.6525, Expected=3855.0000
# Month=44, Predicted=3852.1465, Expected=3843.0000
# Month=45, Predicted=3841.2433, Expected=3847.0000
# Month=46, Predicted=3848.7845, Expected=3801.0000
# Month=47, Predicted=3799.4470, Expected=3787.0000
# Month=48, Predicted=3784.9398, Expected=3776.0000
# Month=49, Predicted=3774.4256, Expected=3797.0000
# Month=50, Predicted=3798.9027, Expected=3821.0000
# Month=51, Predicted=3822.5067, Expected=3877.0000
# Month=52, Predicted=3874.5090, Expected=3875.0000
# Month=53, Predicted=3875.7963, Expected=3890.0000
# Month=54, Predicted=3892.6603, Expected=3910.0000
# Month=55, Predicted=3912.0179, Expected=3924.0000
# Month=56, Predicted=3926.7754, Expected=3918.0000
# Month=57, Predicted=3917.5243, Expected=3936.0000
# Month=58, Predicted=3938.2816, Expected=3911.0000
# Month=59, Predicted=3908.0762, Expected=3891.0000
# Month=60, Predicted=3888.2941, Expected=3855.0000
# Run 9 — RMSE: 24.414195, MSE: 596.052903, NMSE: 0.0027098848
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3796.7851, Expected=3796.0000
# Month=2, Predicted=3797.3247, Expected=3793.0000
# Month=3, Predicted=3794.2513, Expected=3766.0000
# Month=4, Predicted=3766.7227, Expected=3747.0000
# Month=5, Predicted=3747.7227, Expected=3754.0000
# Month=6, Predicted=3755.7808, Expected=3756.0000
# Month=7, Predicted=3757.5400, Expected=3767.0000
# Month=8, Predicted=3768.9485, Expected=3751.0000
# Month=9, Predicted=3751.7227, Expected=3769.0000
# Month=10, Predicted=3770.4940, Expected=3760.0000
# Month=11, Predicted=3760.8622, Expected=3785.0000
# Month=12, Predicted=3785.5205, Expected=3776.0000
# Month=13, Predicted=3776.8647, Expected=3755.0000
# Month=14, Predicted=3755.7227, Expected=3755.0000
# Month=15, Predicted=3756.4269, Expected=3751.0000
# Month=16, Predicted=3752.1894, Expected=3776.0000
# Month=17, Predicted=3776.5218, Expected=3847.0000
# Month=18, Predicted=3834.0896, Expected=3830.0000
# Month=19, Predicted=3830.7227, Expected=3881.0000
# Month=20, Predicted=3875.1205, Expected=3899.0000
# Month=21, Predicted=3900.5473, Expected=3917.0000
# Month=22, Predicted=3918.5076, Expected=3913.0000
# Month=23, Predicted=3914.1942, Expected=3901.0000
# Month=24, Predicted=3901.7227, Expected=3886.0000
# Month=25, Predicted=3886.7227, Expected=3892.5000
# Month=26, Predicted=3894.2585, Expected=3899.0000
# Month=27, Predicted=3900.7616, Expected=3886.0000
# Month=28, Predicted=3886.7227, Expected=3908.0000
# Month=29, Predicted=3908.9843, Expected=3875.0000
# Month=30, Predicted=3875.7227, Expected=3860.0000
# Month=31, Predicted=3860.7227, Expected=3880.0000
# Month=32, Predicted=3881.2552, Expected=3895.0000
# Month=33, Predicted=3896.8031, Expected=3954.0000
# Month=34, Predicted=3945.4929, Expected=3933.0000
# Month=35, Predicted=3933.7227, Expected=3937.0000
# Month=36, Predicted=3938.6394, Expected=3869.0000
# Month=37, Predicted=3874.0828, Expected=3852.0000
# Month=38, Predicted=3852.7227, Expected=3837.0000
# Month=39, Predicted=3837.7227, Expected=3832.0000
# Month=40, Predicted=3833.1243, Expected=3849.0000
# Month=41, Predicted=3850.6027, Expected=3863.0000
# Month=42, Predicted=3864.8813, Expected=3878.0000
# Month=43, Predicted=3879.7988, Expected=3855.0000
# Month=44, Predicted=3855.7227, Expected=3843.0000
# Month=45, Predicted=3843.7227, Expected=3847.0000
# Month=46, Predicted=3848.6399, Expected=3801.0000
# Month=47, Predicted=3801.7227, Expected=3787.0000
# Month=48, Predicted=3787.7227, Expected=3776.0000
# Month=49, Predicted=3776.7227, Expected=3797.0000
# Month=50, Predicted=3798.1241, Expected=3821.0000
# Month=51, Predicted=3821.6999, Expected=3877.0000
# Month=52, Predicted=3869.5278, Expected=3875.0000
# Month=53, Predicted=3876.3403, Expected=3890.0000
# Month=54, Predicted=3891.7914, Expected=3910.0000
# Month=55, Predicted=3911.2670, Expected=3924.0000
# Month=56, Predicted=3925.8835, Expected=3918.0000
# Month=57, Predicted=3919.0640, Expected=3936.0000
# Month=58, Predicted=3937.4956, Expected=3911.0000
# Month=59, Predicted=3911.7227, Expected=3891.0000
# Month=60, Predicted=3891.7227, Expected=3855.0000
# Run 10 — RMSE: 24.455502, MSE: 598.071602, NMSE: 0.0027642255
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3798.9149, Expected=3796.0000
# Month=2, Predicted=3797.0310, Expected=3793.0000
# Month=3, Predicted=3794.0082, Expected=3766.0000
# Month=4, Predicted=3766.4864, Expected=3747.0000
# Month=5, Predicted=3747.6111, Expected=3754.0000
# Month=6, Predicted=3755.1440, Expected=3756.0000
# Month=7, Predicted=3757.0927, Expected=3767.0000
# Month=8, Predicted=3768.1626, Expected=3751.0000
# Month=9, Predicted=3751.6902, Expected=3769.0000
# Month=10, Predicted=3770.1451, Expected=3760.0000
# Month=11, Predicted=3760.8743, Expected=3785.0000
# Month=12, Predicted=3786.0730, Expected=3776.0000
# Month=13, Predicted=3776.8751, Expected=3755.0000
# Month=14, Predicted=3755.5622, Expected=3755.0000
# Month=15, Predicted=3756.0617, Expected=3751.0000
# Month=16, Predicted=3751.9880, Expected=3776.0000
# Month=17, Predicted=3777.0732, Expected=3847.0000
# Month=18, Predicted=3847.4754, Expected=3830.0000
# Month=19, Predicted=3830.6705, Expected=3881.0000
# Month=20, Predicted=3881.4864, Expected=3899.0000
# Month=21, Predicted=3900.1506, Expected=3917.0000
# Month=22, Predicted=3918.1466, Expected=3913.0000
# Month=23, Predicted=3913.9895, Expected=3901.0000
# Month=24, Predicted=3901.7958, Expected=3886.0000
# Month=25, Predicted=3886.7160, Expected=3892.5000
# Month=26, Predicted=3893.6403, Expected=3899.0000
# Month=27, Predicted=3900.1411, Expected=3886.0000
# Month=28, Predicted=3886.7698, Expected=3908.0000
# Month=29, Predicted=3909.1101, Expected=3875.0000
# Month=30, Predicted=3875.4864, Expected=3860.0000
# Month=31, Predicted=3860.7153, Expected=3880.0000
# Month=32, Predicted=3881.1297, Expected=3895.0000
# Month=33, Predicted=3896.1614, Expected=3954.0000
# Month=34, Predicted=3954.4843, Expected=3933.0000
# Month=35, Predicted=3933.5657, Expected=3937.0000
# Month=36, Predicted=3938.1166, Expected=3869.0000
# Month=37, Predicted=3874.4809, Expected=3852.0000
# Month=38, Predicted=3852.6615, Expected=3837.0000
# Month=39, Predicted=3837.7159, Expected=3832.0000
# Month=40, Predicted=3832.9663, Expected=3849.0000
# Month=41, Predicted=3850.1513, Expected=3863.0000
# Month=42, Predicted=3864.1637, Expected=3878.0000
# Month=43, Predicted=3879.1609, Expected=3855.0000
# Month=44, Predicted=3855.5165, Expected=3843.0000
# Month=45, Predicted=3843.7954, Expected=3847.0000
# Month=46, Predicted=3848.1166, Expected=3801.0000
# Month=47, Predicted=3801.4864, Expected=3787.0000
# Month=48, Predicted=3787.7412, Expected=3776.0000
# Month=49, Predicted=3776.8217, Expected=3797.0000
# Month=50, Predicted=3798.1205, Expected=3821.0000
# Month=51, Predicted=3822.0878, Expected=3877.0000
# Month=52, Predicted=3877.4861, Expected=3875.0000
# Month=53, Predicted=3876.0353, Expected=3890.0000
# Month=54, Predicted=3891.1600, Expected=3910.0000
# Month=55, Predicted=3911.1309, Expected=3924.0000
# Month=56, Predicted=3925.1639, Expected=3918.0000
# Month=57, Predicted=3918.9456, Expected=3936.0000
# Month=58, Predicted=3937.1453, Expected=3911.0000
# Month=59, Predicted=3911.4864, Expected=3891.0000
# Month=60, Predicted=3891.5862, Expected=3855.0000
# Run 11 — RMSE: 24.493932, MSE: 599.952681, NMSE: 0.0027471430
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3798.9608, Expected=3796.0000
# Month=2, Predicted=3796.9608, Expected=3793.0000
# Month=3, Predicted=3793.9608, Expected=3766.0000
# Month=4, Predicted=3766.9608, Expected=3747.0000
# Month=5, Predicted=3747.9608, Expected=3754.0000
# Month=6, Predicted=3754.9608, Expected=3756.0000
# Month=7, Predicted=3756.9608, Expected=3767.0000
# Month=8, Predicted=3767.9608, Expected=3751.0000
# Month=9, Predicted=3751.9608, Expected=3769.0000
# Month=10, Predicted=3769.9608, Expected=3760.0000
# Month=11, Predicted=3760.9608, Expected=3785.0000
# Month=12, Predicted=3785.9608, Expected=3776.0000
# Month=13, Predicted=3776.9608, Expected=3755.0000
# Month=14, Predicted=3755.9608, Expected=3755.0000
# Month=15, Predicted=3755.9608, Expected=3751.0000
# Month=16, Predicted=3751.9608, Expected=3776.0000
# Month=17, Predicted=3776.9608, Expected=3847.0000
# Month=18, Predicted=3847.9583, Expected=3830.0000
# Month=19, Predicted=3830.9608, Expected=3881.0000
# Month=20, Predicted=3881.9608, Expected=3899.0000
# Month=21, Predicted=3899.9608, Expected=3917.0000
# Month=22, Predicted=3917.9608, Expected=3913.0000
# Month=23, Predicted=3913.9608, Expected=3901.0000
# Month=24, Predicted=3901.9608, Expected=3886.0000
# Month=25, Predicted=3886.9608, Expected=3892.5000
# Month=26, Predicted=3893.4608, Expected=3899.0000
# Month=27, Predicted=3899.9608, Expected=3886.0000
# Month=28, Predicted=3886.9608, Expected=3908.0000
# Month=29, Predicted=3908.9608, Expected=3875.0000
# Month=30, Predicted=3875.9608, Expected=3860.0000
# Month=31, Predicted=3860.9608, Expected=3880.0000
# Month=32, Predicted=3880.9608, Expected=3895.0000
# Month=33, Predicted=3895.9608, Expected=3954.0000
# Month=34, Predicted=3954.9608, Expected=3933.0000
# Month=35, Predicted=3933.9608, Expected=3937.0000
# Month=36, Predicted=3937.9608, Expected=3869.0000
# Month=37, Predicted=3874.3826, Expected=3852.0000
# Month=38, Predicted=3852.9608, Expected=3837.0000
# Month=39, Predicted=3837.9608, Expected=3832.0000
# Month=40, Predicted=3832.9608, Expected=3849.0000
# Month=41, Predicted=3849.9608, Expected=3863.0000
# Month=42, Predicted=3863.9608, Expected=3878.0000
# Month=43, Predicted=3878.9608, Expected=3855.0000
# Month=44, Predicted=3855.9608, Expected=3843.0000
# Month=45, Predicted=3843.9608, Expected=3847.0000
# Month=46, Predicted=3847.9608, Expected=3801.0000
# Month=47, Predicted=3801.9608, Expected=3787.0000
# Month=48, Predicted=3787.9608, Expected=3776.0000
# Month=49, Predicted=3776.9608, Expected=3797.0000
# Month=50, Predicted=3797.9608, Expected=3821.0000
# Month=51, Predicted=3821.9608, Expected=3877.0000
# Month=52, Predicted=3877.9608, Expected=3875.0000
# Month=53, Predicted=3875.9608, Expected=3890.0000
# Month=54, Predicted=3890.9608, Expected=3910.0000
# Month=55, Predicted=3910.9608, Expected=3924.0000
# Month=56, Predicted=3924.9608, Expected=3918.0000
# Month=57, Predicted=3918.9608, Expected=3936.0000
# Month=58, Predicted=3936.9608, Expected=3911.0000
# Month=59, Predicted=3911.9608, Expected=3891.0000
# Month=60, Predicted=3891.9608, Expected=3855.0000
# Run 12 — RMSE: 24.523002, MSE: 601.377630, NMSE: 0.0027544261
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3797.2164, Expected=3796.0000
# Month=2, Predicted=3797.7576, Expected=3793.0000
# Month=3, Predicted=3794.3583, Expected=3766.0000
# Month=4, Predicted=3763.4082, Expected=3747.0000
# Month=5, Predicted=3745.5001, Expected=3754.0000
# Month=6, Predicted=3756.7894, Expected=3756.0000
# Month=7, Predicted=3758.2923, Expected=3767.0000
# Month=8, Predicted=3769.8768, Expected=3751.0000
# Month=9, Predicted=3749.9428, Expected=3769.0000
# Month=10, Predicted=3771.4595, Expected=3760.0000
# Month=11, Predicted=3760.0527, Expected=3785.0000
# Month=12, Predicted=3786.3204, Expected=3776.0000
# Month=13, Predicted=3776.0840, Expected=3755.0000
# Month=14, Predicted=3753.1926, Expected=3755.0000
# Month=15, Predicted=3756.9796, Expected=3751.0000
# Month=16, Predicted=3752.1321, Expected=3776.0000
# Month=17, Predicted=3777.3201, Expected=3847.0000
# Month=18, Predicted=3826.4470, Expected=3830.0000
# Month=19, Predicted=3829.2112, Expected=3881.0000
# Month=20, Predicted=3872.7477, Expected=3899.0000
# Month=21, Predicted=3901.9814, Expected=3917.0000
# Month=22, Predicted=3919.5288, Expected=3913.0000
# Month=23, Predicted=3914.1914, Expected=3901.0000
# Month=24, Predicted=3900.5354, Expected=3886.0000
# Month=25, Predicted=3885.0757, Expected=3892.5000
# Month=26, Predicted=3895.2475, Expected=3899.0000
# Month=27, Predicted=3901.7584, Expected=3886.0000
# Month=28, Predicted=3885.3916, Expected=3908.0000
# Month=29, Predicted=3909.8915, Expected=3875.0000
# Month=30, Predicted=3871.7905, Expected=3860.0000
# Month=31, Predicted=3859.1060, Expected=3880.0000
# Month=32, Predicted=3882.2046, Expected=3895.0000
# Month=33, Predicted=3897.8221, Expected=3954.0000
# Month=34, Predicted=3941.3117, Expected=3933.0000
# Month=35, Predicted=3931.4948, Expected=3937.0000
# Month=36, Predicted=3939.5466, Expected=3869.0000
# Month=37, Predicted=3870.8874, Expected=3852.0000
# Month=38, Predicted=3850.9291, Expected=3837.0000
# Month=39, Predicted=3836.0826, Expected=3832.0000
# Month=40, Predicted=3832.8921, Expected=3849.0000
# Month=41, Predicted=3851.5496, Expected=3863.0000
# Month=42, Predicted=3865.8587, Expected=3878.0000
# Month=43, Predicted=3880.7769, Expected=3855.0000
# Month=44, Predicted=3852.9463, Expected=3843.0000
# Month=45, Predicted=3842.5544, Expected=3847.0000
# Month=46, Predicted=3849.5246, Expected=3801.0000
# Month=47, Predicted=3796.9138, Expected=3787.0000
# Month=48, Predicted=3786.2926, Expected=3776.0000
# Month=49, Predicted=3775.6969, Expected=3797.0000
# Month=50, Predicted=3799.0487, Expected=3821.0000
# Month=51, Predicted=3822.6486, Expected=3877.0000
# Month=52, Predicted=3866.1797, Expected=3875.0000
# Month=53, Predicted=3877.0246, Expected=3890.0000
# Month=54, Predicted=3892.7125, Expected=3910.0000
# Month=55, Predicted=3912.2656, Expected=3924.0000
# Month=56, Predicted=3926.8805, Expected=3918.0000
# Month=57, Predicted=3918.6675, Expected=3936.0000
# Month=58, Predicted=3938.4441, Expected=3911.0000
# Month=59, Predicted=3908.6923, Expected=3891.0000
# Month=60, Predicted=3889.3536, Expected=3855.0000
# Run 13 — RMSE: 24.301884, MSE: 590.581562, NMSE: 0.0027213939
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3799.4473, Expected=3796.0000
# Month=2, Predicted=3796.9873, Expected=3793.0000
# Month=3, Predicted=3793.9209, Expected=3766.0000
# Month=4, Predicted=3765.2201, Expected=3747.0000
# Month=5, Predicted=3746.8550, Expected=3754.0000
# Month=6, Predicted=3755.3579, Expected=3756.0000
# Month=7, Predicted=3757.1659, Expected=3767.0000
# Month=8, Predicted=3768.4725, Expected=3751.0000
# Month=9, Predicted=3751.0831, Expected=3769.0000
# Month=10, Predicted=3770.5840, Expected=3760.0000
# Month=11, Predicted=3760.5701, Expected=3785.0000
# Month=12, Predicted=3786.5794, Expected=3776.0000
# Month=13, Predicted=3776.5725, Expected=3755.0000
# Month=14, Predicted=3754.6975, Expected=3755.0000
# Month=15, Predicted=3756.0736, Expected=3751.0000
# Month=16, Predicted=3751.8664, Expected=3776.0000
# Month=17, Predicted=3777.5796, Expected=3847.0000
# Month=18, Predicted=3847.7098, Expected=3830.0000
# Month=19, Predicted=3830.0384, Expected=3881.0000
# Month=20, Predicted=3881.9976, Expected=3899.0000
# Month=21, Predicted=3900.6437, Expected=3917.0000
# Month=22, Predicted=3918.5931, Expected=3913.0000
# Month=23, Predicted=3913.8701, Expected=3901.0000
# Month=24, Predicted=3901.3681, Expected=3886.0000
# Month=25, Predicted=3886.1560, Expected=3892.5000
# Month=26, Predicted=3893.8407, Expected=3899.0000
# Month=27, Predicted=3900.3418, Expected=3886.0000
# Month=28, Predicted=3886.2991, Expected=3908.0000
# Month=29, Predicted=3909.5955, Expected=3875.0000
# Month=30, Predicted=3873.7408, Expected=3860.0000
# Month=31, Predicted=3860.1560, Expected=3880.0000
# Month=32, Predicted=3881.5945, Expected=3895.0000
# Month=33, Predicted=3896.5598, Expected=3954.0000
# Month=34, Predicted=3954.8883, Expected=3933.0000
# Month=35, Predicted=3932.7125, Expected=3937.0000
# Month=36, Predicted=3938.2488, Expected=3869.0000
# Month=37, Predicted=3869.1589, Expected=3852.0000
# Month=38, Predicted=3852.0021, Expected=3837.0000
# Month=39, Predicted=3837.1561, Expected=3832.0000
# Month=40, Predicted=3832.8102, Expected=3849.0000
# Month=41, Predicted=3850.5746, Expected=3863.0000
# Month=42, Predicted=3864.5412, Expected=3878.0000
# Month=43, Predicted=3879.5554, Expected=3855.0000
# Month=44, Predicted=3854.5366, Expected=3843.0000
# Month=45, Predicted=3843.3685, Expected=3847.0000
# Month=46, Predicted=3848.2482, Expected=3801.0000
# Month=47, Predicted=3798.6570, Expected=3787.0000
# Month=48, Predicted=3787.2272, Expected=3776.0000
# Month=49, Predicted=3776.4361, Expected=3797.0000
# Month=50, Predicted=3798.5960, Expected=3821.0000
# Month=51, Predicted=3822.6012, Expected=3877.0000
# Month=52, Predicted=3877.9366, Expected=3875.0000
# Month=53, Predicted=3876.0104, Expected=3890.0000
# Month=54, Predicted=3891.5501, Expected=3910.0000
# Month=55, Predicted=3911.6015, Expected=3924.0000
# Month=56, Predicted=3925.5435, Expected=3918.0000
# Month=57, Predicted=3918.7541, Expected=3936.0000
# Month=58, Predicted=3937.5835, Expected=3911.0000
# Month=59, Predicted=3910.3744, Expected=3891.0000
# Month=60, Predicted=3890.7768, Expected=3855.0000
# Run 14 — RMSE: 24.327239, MSE: 591.814566, NMSE: 0.0027032857
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3795.5356, Expected=3796.0000
# Month=2, Predicted=3797.1817, Expected=3793.0000
# Month=3, Predicted=3793.9988, Expected=3766.0000
# Month=4, Predicted=3765.5435, Expected=3747.0000
# Month=5, Predicted=3746.7740, Expected=3754.0000
# Month=6, Predicted=3756.3875, Expected=3756.0000
# Month=7, Predicted=3757.7276, Expected=3767.0000
# Month=8, Predicted=3769.8841, Expected=3751.0000
# Month=9, Predicted=3750.9234, Expected=3769.0000
# Month=10, Predicted=3771.7613, Expected=3760.0000
# Month=11, Predicted=3760.3438, Expected=3785.0000
# Month=12, Predicted=3785.5476, Expected=3776.0000
# Month=13, Predicted=3776.3476, Expected=3755.0000
# Month=14, Predicted=3754.6934, Expected=3755.0000
# Month=15, Predicted=3756.4341, Expected=3751.0000
# Month=16, Predicted=3751.8505, Expected=3776.0000
# Month=17, Predicted=3776.5565, Expected=3847.0000
# Month=18, Predicted=3831.0996, Expected=3830.0000
# Month=19, Predicted=3829.9058, Expected=3881.0000
# Month=20, Predicted=3872.2328, Expected=3899.0000
# Month=21, Predicted=3902.0309, Expected=3917.0000
# Month=22, Predicted=3919.8497, Expected=3913.0000
# Month=23, Predicted=3913.8642, Expected=3901.0000
# Month=24, Predicted=3901.1459, Expected=3886.0000
# Month=25, Predicted=3885.9733, Expected=3892.5000
# Month=26, Predicted=3894.8231, Expected=3899.0000
# Month=27, Predicted=3901.3331, Expected=3886.0000
# Month=28, Predicted=3886.0882, Expected=3908.0000
# Month=29, Predicted=3909.5324, Expected=3875.0000
# Month=30, Predicted=3874.5435, Expected=3860.0000
# Month=31, Predicted=3859.9673, Expected=3880.0000
# Month=32, Predicted=3882.1616, Expected=3895.0000
# Month=33, Predicted=3898.3517, Expected=3954.0000
# Month=34, Predicted=3942.4067, Expected=3933.0000
# Month=35, Predicted=3932.7131, Expected=3937.0000
# Month=36, Predicted=3938.9931, Expected=3869.0000
# Month=37, Predicted=3872.8501, Expected=3852.0000
# Month=38, Predicted=3851.8748, Expected=3837.0000
# Month=39, Predicted=3836.9740, Expected=3832.0000
# Month=40, Predicted=3832.6957, Expected=3849.0000
# Month=41, Predicted=3852.0642, Expected=3863.0000
# Month=42, Predicted=3866.2394, Expected=3878.0000
# Month=43, Predicted=3881.3438, Expected=3855.0000
# Month=44, Predicted=3854.6233, Expected=3843.0000
# Month=45, Predicted=3843.1453, Expected=3847.0000
# Month=46, Predicted=3848.9932, Expected=3801.0000
# Month=47, Predicted=3800.5435, Expected=3787.0000
# Month=48, Predicted=3787.0201, Expected=3776.0000
# Month=49, Predicted=3776.2075, Expected=3797.0000
# Month=50, Predicted=3798.8535, Expected=3821.0000
# Month=51, Predicted=3821.9754, Expected=3877.0000
# Month=52, Predicted=3866.5236, Expected=3875.0000
# Month=53, Predicted=3876.2174, Expected=3890.0000
# Month=54, Predicted=3893.3297, Expected=3910.0000
# Month=55, Predicted=3912.2361, Expected=3924.0000
# Month=56, Predicted=3927.2434, Expected=3918.0000
# Month=57, Predicted=3918.5586, Expected=3936.0000
# Month=58, Predicted=3938.7747, Expected=3911.0000
# Month=59, Predicted=3910.5620, Expected=3891.0000
# Month=60, Predicted=3890.7323, Expected=3855.0000
# Run 15 — RMSE: 24.421117, MSE: 596.390951, NMSE: 0.0027455775
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3796.8336, Expected=3796.0000
# Month=2, Predicted=3797.4621, Expected=3793.0000
# Month=3, Predicted=3794.2229, Expected=3766.0000
# Month=4, Predicted=3762.5843, Expected=3747.0000
# Month=5, Predicted=3745.1559, Expected=3754.0000
# Month=6, Predicted=3756.8248, Expected=3756.0000
# Month=7, Predicted=3758.0586, Expected=3767.0000
# Month=8, Predicted=3770.4400, Expected=3751.0000
# Month=9, Predicted=3749.6107, Expected=3769.0000
# Month=10, Predicted=3771.4576, Expected=3760.0000
# Month=11, Predicted=3760.1510, Expected=3785.0000
# Month=12, Predicted=3785.9614, Expected=3776.0000
# Month=13, Predicted=3776.1531, Expected=3755.0000
# Month=14, Predicted=3752.8946, Expected=3755.0000
# Month=15, Predicted=3756.7069, Expected=3751.0000
# Month=16, Predicted=3752.0581, Expected=3776.0000
# Month=17, Predicted=3776.9563, Expected=3847.0000
# Month=18, Predicted=3836.2351, Expected=3830.0000
# Month=19, Predicted=3828.3077, Expected=3881.0000
# Month=20, Predicted=3875.7682, Expected=3899.0000
# Month=21, Predicted=3901.3544, Expected=3917.0000
# Month=22, Predicted=3919.4208, Expected=3913.0000
# Month=23, Predicted=3914.0820, Expected=3901.0000
# ...
# Month=53, Predicted=3876.3053, Expected=3890.0000
# Month=54, Predicted=3893.5369, Expected=3910.0000
# Month=55, Predicted=3912.8808, Expected=3924.0000
# Month=56, Predicted=3927.6086, Expected=3918.0000
# Month=57, Predicted=3918.2861, Expected=3936.0000
# Month=58, Predicted=3939.2054, Expected=3911.0000
# Month=59, Predicted=3907.6990, Expected=3891.0000
# Month=60, Predicted=3888.2487, Expected=3855.0000
# Run 25 — RMSE: 24.422332, MSE: 596.450318, NMSE: 0.0027382529
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3796.9743, Expected=3796.0000
# Month=2, Predicted=3797.2996, Expected=3793.0000
# Month=3, Predicted=3794.0782, Expected=3766.0000
# Month=4, Predicted=3766.0418, Expected=3747.0000
# Month=5, Predicted=3747.0418, Expected=3754.0000
# Month=6, Predicted=3756.2987, Expected=3756.0000
# Month=7, Predicted=3757.8485, Expected=3767.0000
# Month=8, Predicted=3769.4165, Expected=3751.0000
# Month=9, Predicted=3751.0418, Expected=3769.0000
# Month=10, Predicted=3771.0547, Expected=3760.0000
# Month=11, Predicted=3760.2176, Expected=3785.0000
# Month=12, Predicted=3786.0437, Expected=3776.0000
# Month=13, Predicted=3776.2231, Expected=3755.0000
# Month=14, Predicted=3755.0418, Expected=3755.0000
# Month=15, Predicted=3756.5666, Expected=3751.0000
# Month=16, Predicted=3751.8977, Expected=3776.0000
# Month=17, Predicted=3777.0453, Expected=3847.0000
# Month=18, Predicted=3829.5660, Expected=3830.0000
# Month=19, Predicted=3830.0418, Expected=3881.0000
# Month=20, Predicted=3873.7294, Expected=3899.0000
# Month=21, Predicted=3901.1859, Expected=3917.0000
# Month=22, Predicted=3919.0816, Expected=3913.0000
# Month=23, Predicted=3913.9132, Expected=3901.0000
# Month=24, Predicted=3901.0418, Expected=3886.0000
# Month=25, Predicted=3886.0418, Expected=3892.5000
# Month=26, Predicted=3894.7683, Expected=3899.0000
# Month=27, Predicted=3901.2770, Expected=3886.0000
# Month=28, Predicted=3886.0418, Expected=3908.0000
# Month=29, Predicted=3909.5520, Expected=3875.0000
# Month=30, Predicted=3875.0418, Expected=3860.0000
# Month=31, Predicted=3860.0418, Expected=3880.0000
# Month=32, Predicted=3881.8292, Expected=3895.0000
# Month=33, Predicted=3897.3216, Expected=3954.0000
# Month=34, Predicted=3943.0199, Expected=3933.0000
# Month=35, Predicted=3933.0418, Expected=3937.0000
# Month=36, Predicted=3939.0642, Expected=3869.0000
# Month=37, Predicted=3869.8570, Expected=3852.0000
# Month=38, Predicted=3852.0418, Expected=3837.0000
# Month=39, Predicted=3837.0418, Expected=3832.0000
# Month=40, Predicted=3832.7067, Expected=3849.0000
# Month=41, Predicted=3851.1492, Expected=3863.0000
# Month=42, Predicted=3865.3670, Expected=3878.0000
# Month=43, Predicted=3880.3111, Expected=3855.0000
# Month=44, Predicted=3855.0418, Expected=3843.0000
# Month=45, Predicted=3843.0418, Expected=3847.0000
# Month=46, Predicted=3849.0642, Expected=3801.0000
# Month=47, Predicted=3801.0418, Expected=3787.0000
# Month=48, Predicted=3787.0418, Expected=3776.0000
# Month=49, Predicted=3776.0488, Expected=3797.0000
# Month=50, Predicted=3798.6972, Expected=3821.0000
# Month=51, Predicted=3822.2585, Expected=3877.0000
# Month=52, Predicted=3867.5004, Expected=3875.0000
# Month=53, Predicted=3876.3681, Expected=3890.0000
# Month=54, Predicted=3892.2951, Expected=3910.0000
# Month=55, Predicted=3911.8507, Expected=3924.0000
# Month=56, Predicted=3926.3727, Expected=3918.0000
# Month=57, Predicted=3918.5250, Expected=3936.0000
# Month=58, Predicted=3938.0561, Expected=3911.0000
# Month=59, Predicted=3911.0418, Expected=3891.0000
# Month=60, Predicted=3891.0418, Expected=3855.0000
# Run 26 — RMSE: 24.388760, MSE: 594.811630, NMSE: 0.0027498158
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3796.1791, Expected=3796.0000
# Month=2, Predicted=3797.2464, Expected=3793.0000
# Month=3, Predicted=3794.0697, Expected=3766.0000
# Month=4, Predicted=3765.9830, Expected=3747.0000
# Month=5, Predicted=3747.0693, Expected=3754.0000
# Month=6, Predicted=3756.2602, Expected=3756.0000
# Month=7, Predicted=3757.6602, Expected=3767.0000
# Month=8, Predicted=3769.7815, Expected=3751.0000
# Month=9, Predicted=3751.1374, Expected=3769.0000
# Month=10, Predicted=3771.5826, Expected=3760.0000
# Month=11, Predicted=3760.4897, Expected=3785.0000
# Month=12, Predicted=3785.9000, Expected=3776.0000
# Month=13, Predicted=3776.5015, Expected=3755.0000
# Month=14, Predicted=3755.0353, Expected=3755.0000
# Month=15, Predicted=3756.4025, Expected=3751.0000
# Month=16, Predicted=3751.9626, Expected=3776.0000
# Month=17, Predicted=3776.9112, Expected=3847.0000
# Month=18, Predicted=3826.6598, Expected=3830.0000
# Month=19, Predicted=3830.1511, Expected=3881.0000
# Month=20, Predicted=3871.4715, Expected=3899.0000
# Month=21, Predicted=3901.9749, Expected=3917.0000
# Month=22, Predicted=3919.6938, Expected=3913.0000
# Month=23, Predicted=3913.9871, Expected=3901.0000
# Month=24, Predicted=3901.2376, Expected=3886.0000
# Month=25, Predicted=3886.1569, Expected=3892.5000
# Month=26, Predicted=3894.6982, Expected=3899.0000
# Month=27, Predicted=3901.2167, Expected=3886.0000
# Month=28, Predicted=3886.2123, Expected=3908.0000
# Month=29, Predicted=3909.6924, Expected=3875.0000
# Month=30, Predicted=3874.9830, Expected=3860.0000
# Month=31, Predicted=3860.1564, Expected=3880.0000
# Month=32, Predicted=3882.1625, Expected=3895.0000
# Month=33, Predicted=3898.2268, Expected=3954.0000
# Month=34, Predicted=3940.4388, Expected=3933.0000
# Month=35, Predicted=3933.0576, Expected=3937.0000
# Month=36, Predicted=3938.8850, Expected=3869.0000
# Month=37, Predicted=3873.3992, Expected=3852.0000
# Month=38, Predicted=3852.1100, Expected=3837.0000
# Month=39, Predicted=3837.1566, Expected=3832.0000
# Month=40, Predicted=3832.8483, Expected=3849.0000
# Month=41, Predicted=3851.7895, Expected=3863.0000
# Month=42, Predicted=3866.1871, Expected=3878.0000
# Month=43, Predicted=3881.1946, Expected=3855.0000
# Month=44, Predicted=3855.0101, Expected=3843.0000
# Month=45, Predicted=3843.2359, Expected=3847.0000
# Month=46, Predicted=3848.8875, Expected=3801.0000
# Month=47, Predicted=3800.9830, Expected=3787.0000
# Month=48, Predicted=3787.1816, Expected=3776.0000
# Month=49, Predicted=3776.2939, Expected=3797.0000
# Month=50, Predicted=3798.9376, Expected=3821.0000
# Month=51, Predicted=3822.3071, Expected=3877.0000
# Month=52, Predicted=3865.1147, Expected=3875.0000
# Month=53, Predicted=3876.3199, Expected=3890.0000
# Month=54, Predicted=3893.1354, Expected=3910.0000
# Month=55, Predicted=3912.2571, Expected=3924.0000
# Month=56, Predicted=3927.1937, Expected=3918.0000
# Month=57, Predicted=3918.7710, Expected=3936.0000
# Month=58, Predicted=3938.5973, Expected=3911.0000
# Month=59, Predicted=3910.9884, Expected=3891.0000
# Month=60, Predicted=3891.0512, Expected=3855.0000
# Run 27 — RMSE: 24.421518, MSE: 596.410536, NMSE: 0.0027539643
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3796.7378, Expected=3796.0000
# Month=2, Predicted=3797.2655, Expected=3793.0000
# Month=3, Predicted=3793.8881, Expected=3766.0000
# Month=4, Predicted=3765.9163, Expected=3747.0000
# Month=5, Predicted=3746.9163, Expected=3754.0000
# Month=6, Predicted=3757.0214, Expected=3756.0000
# Month=7, Predicted=3758.2306, Expected=3767.0000
# Month=8, Predicted=3770.2645, Expected=3751.0000
# Month=9, Predicted=3750.9163, Expected=3769.0000
# Month=10, Predicted=3771.8166, Expected=3760.0000
# Month=11, Predicted=3759.9163, Expected=3785.0000
# Month=12, Predicted=3786.4719, Expected=3776.0000
# Month=13, Predicted=3775.9163, Expected=3755.0000
# Month=14, Predicted=3754.9163, Expected=3755.0000
# Month=15, Predicted=3756.7339, Expected=3751.0000
# Month=16, Predicted=3751.5760, Expected=3776.0000
# Month=17, Predicted=3777.4756, Expected=3847.0000
# Month=18, Predicted=3823.9174, Expected=3830.0000
# Month=19, Predicted=3829.9163, Expected=3881.0000
# Month=20, Predicted=3871.5249, Expected=3899.0000
# Month=21, Predicted=3901.9871, Expected=3917.0000
# Month=22, Predicted=3919.8573, Expected=3913.0000
# Month=23, Predicted=3913.6026, Expected=3901.0000
# Month=24, Predicted=3900.9163, Expected=3886.0000
# Month=25, Predicted=3885.9163, Expected=3892.5000
# Month=26, Predicted=3895.4671, Expected=3899.0000
# Month=27, Predicted=3901.9853, Expected=3886.0000
# Month=28, Predicted=3885.9163, Expected=3908.0000
# Month=29, Predicted=3910.1476, Expected=3875.0000
# Month=30, Predicted=3874.9163, Expected=3860.0000
# Month=31, Predicted=3859.9163, Expected=3880.0000
# Month=32, Predicted=3882.5169, Expected=3895.0000
# Month=33, Predicted=3898.1716, Expected=3954.0000
# Month=34, Predicted=3939.6051, Expected=3933.0000
# Month=35, Predicted=3932.9163, Expected=3937.0000
# Month=36, Predicted=3939.6039, Expected=3869.0000
# Month=37, Predicted=3869.7643, Expected=3852.0000
# Month=38, Predicted=3851.9163, Expected=3837.0000
# Month=39, Predicted=3836.9163, Expected=3832.0000
# Month=40, Predicted=3832.2429, Expected=3849.0000
# Month=41, Predicted=3851.9444, Expected=3863.0000
# Month=42, Predicted=3866.2276, Expected=3878.0000
# Month=43, Predicted=3881.1577, Expected=3855.0000
# Month=44, Predicted=3854.9163, Expected=3843.0000
# Month=45, Predicted=3842.9163, Expected=3847.0000
# Month=46, Predicted=3849.6057, Expected=3801.0000
# Month=47, Predicted=3800.9163, Expected=3787.0000
# Month=48, Predicted=3786.9163, Expected=3776.0000
# Month=49, Predicted=3775.9163, Expected=3797.0000
# Month=50, Predicted=3799.3419, Expected=3821.0000
# Month=51, Predicted=3822.7605, Expected=3877.0000
# Month=52, Predicted=3864.5732, Expected=3875.0000
# Month=53, Predicted=3876.3712, Expected=3890.0000
# Month=54, Predicted=3893.1338, Expected=3910.0000
# Month=55, Predicted=3912.5511, Expected=3924.0000
# Month=56, Predicted=3927.2348, Expected=3918.0000
# Month=57, Predicted=3917.9346, Expected=3936.0000
# Month=58, Predicted=3938.8213, Expected=3911.0000
# Month=59, Predicted=3910.9163, Expected=3891.0000
# Month=60, Predicted=3890.9163, Expected=3855.0000
# Run 28 — RMSE: 24.444770, MSE: 597.546761, NMSE: 0.0027622391
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3798.9989, Expected=3796.0000
# Month=2, Predicted=3796.9836, Expected=3793.0000
# Month=3, Predicted=3793.9634, Expected=3766.0000
# Month=4, Predicted=3766.7249, Expected=3747.0000
# Month=5, Predicted=3747.8166, Expected=3754.0000
# Month=6, Predicted=3754.9992, Expected=3756.0000
# Month=7, Predicted=3756.9881, Expected=3767.0000
# Month=8, Predicted=3768.0070, Expected=3751.0000
# Month=9, Predicted=3751.8556, Expected=3769.0000
# Month=10, Predicted=3770.0071, Expected=3760.0000
# Month=11, Predicted=3760.9273, Expected=3785.0000
# Month=12, Predicted=3786.0014, Expected=3776.0000
# Month=13, Predicted=3776.9306, Expected=3755.0000
# Month=14, Predicted=3755.7907, Expected=3755.0000
# Month=15, Predicted=3755.9772, Expected=3751.0000
# Month=16, Predicted=3751.9578, Expected=3776.0000
# Month=17, Predicted=3777.0018, Expected=3847.0000
# Month=18, Predicted=3847.8970, Expected=3830.0000
# Month=19, Predicted=3830.8799, Expected=3881.0000
# Month=20, Predicted=3881.9460, Expected=3899.0000
# Month=21, Predicted=3900.0350, Expected=3917.0000
# Month=22, Predicted=3918.0139, Expected=3913.0000
# Month=23, Predicted=3913.9632, Expected=3901.0000
# Month=24, Predicted=3901.8951, Expected=3886.0000
# Month=25, Predicted=3886.8638, Expected=3892.5000
# Month=26, Predicted=3893.4982, Expected=3899.0000
# Month=27, Predicted=3900.0010, Expected=3886.0000
# Month=28, Predicted=3886.8869, Expected=3908.0000
# Month=29, Predicted=3909.0045, Expected=3875.0000
# Month=30, Predicted=3875.7249, Expected=3860.0000
# Month=31, Predicted=3860.8635, Expected=3880.0000
# Month=32, Predicted=3881.0061, Expected=3895.0000
# Month=33, Predicted=3896.0150, Expected=3954.0000
# Month=34, Predicted=3954.9285, Expected=3933.0000
# Month=35, Predicted=3933.8153, Expected=3937.0000
# Month=36, Predicted=3937.9917, Expected=3869.0000
# Month=37, Predicted=3874.2354, Expected=3852.0000
# Month=38, Predicted=3852.8330, Expected=3837.0000
# Month=39, Predicted=3837.8637, Expected=3832.0000
# Month=40, Predicted=3832.9504, Expected=3849.0000
# Month=41, Predicted=3850.0081, Expected=3863.0000
# Month=42, Predicted=3864.0135, Expected=3878.0000
# Month=43, Predicted=3879.0126, Expected=3855.0000
# Month=44, Predicted=3855.7661, Expected=3843.0000
# Month=45, Predicted=3843.8945, Expected=3847.0000
# Month=46, Predicted=3847.9920, Expected=3801.0000
# Month=47, Predicted=3801.7249, Expected=3787.0000
# Month=48, Predicted=3787.8728, Expected=3776.0000
# Month=49, Predicted=3776.9039, Expected=3797.0000
# Month=50, Predicted=3798.0055, Expected=3821.0000
# Month=51, Predicted=3822.0099, Expected=3877.0000
# Month=52, Predicted=3877.9395, Expected=3875.0000
# Month=53, Predicted=3876.0014, Expected=3890.0000
# Month=54, Predicted=3891.0086, Expected=3910.0000
# Month=55, Predicted=3911.0114, Expected=3924.0000
# Month=56, Predicted=3925.0149, Expected=3918.0000
# Month=57, Predicted=3918.9486, Expected=3936.0000
# Month=58, Predicted=3937.0077, Expected=3911.0000
# Month=59, Predicted=3911.7377, Expected=3891.0000
# Month=60, Predicted=3891.8038, Expected=3855.0000
# Run 29 — RMSE: 24.505047, MSE: 600.497316, NMSE: 0.0027495942
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3796.8902, Expected=3796.0000
# Month=2, Predicted=3797.6786, Expected=3793.0000
# Month=3, Predicted=3794.4676, Expected=3766.0000
# Month=4, Predicted=3763.0300, Expected=3747.0000
# Month=5, Predicted=3745.5514, Expected=3754.0000
# Month=6, Predicted=3756.9062, Expected=3756.0000
# Month=7, Predicted=3758.3804, Expected=3767.0000
# Month=8, Predicted=3770.0212, Expected=3751.0000
# Month=9, Predicted=3750.1106, Expected=3769.0000
# Month=10, Predicted=3771.5728, Expected=3760.0000
# Month=11, Predicted=3760.3270, Expected=3785.0000
# Month=12, Predicted=3786.3667, Expected=3776.0000
# Month=13, Predicted=3776.3269, Expected=3755.0000
# Month=14, Predicted=3753.1697, Expected=3755.0000
# Month=15, Predicted=3757.0591, Expected=3751.0000
# Month=16, Predicted=3752.2443, Expected=3776.0000
# Month=17, Predicted=3777.3667, Expected=3847.0000
# Month=18, Predicted=3833.3781, Expected=3830.0000
# Month=19, Predicted=3828.9447, Expected=3881.0000
# Month=20, Predicted=3874.1036, Expected=3899.0000
# Month=21, Predicted=3901.5656, Expected=3917.0000
# Month=22, Predicted=3919.5726, Expected=3913.0000
# Month=23, Predicted=3914.2438, Expected=3901.0000
# Month=24, Predicted=3900.8262, Expected=3886.0000
# Month=25, Predicted=3885.2943, Expected=3892.5000
# Month=26, Predicted=3895.3725, Expected=3899.0000
# Month=27, Predicted=3901.8720, Expected=3886.0000
# Month=28, Predicted=3885.6515, Expected=3908.0000
# Month=29, Predicted=3909.9692, Expected=3875.0000
# Month=30, Predicted=3870.9703, Expected=3860.0000
# Month=31, Predicted=3859.2953, Expected=3880.0000
# Month=32, Predicted=3882.3007, Expected=3895.0000
# Month=33, Predicted=3897.8635, Expected=3954.0000
# Month=34, Predicted=3944.5476, Expected=3933.0000
# Month=35, Predicted=3931.1817, Expected=3937.0000
# Month=36, Predicted=3939.6405, Expected=3869.0000
# Month=37, Predicted=3871.4304, Expected=3852.0000
# Month=38, Predicted=3850.9052, Expected=3837.0000
# Month=39, Predicted=3836.2944, Expected=3832.0000
# Month=40, Predicted=3833.0098, Expected=3849.0000
# Month=41, Predicted=3851.6856, Expected=3863.0000
# Month=42, Predicted=3865.9280, Expected=3878.0000
# Month=43, Predicted=3880.8635, Expected=3855.0000
# Month=44, Predicted=3852.7863, Expected=3843.0000
# Month=45, Predicted=3842.8268, Expected=3847.0000
# Month=46, Predicted=3849.6405, Expected=3801.0000
# Month=47, Predicted=3795.4485, Expected=3787.0000
# Month=48, Predicted=3786.4729, Expected=3776.0000
# Month=49, Predicted=3775.9974, Expected=3797.0000
# Month=50, Predicted=3799.1422, Expected=3821.0000
# Month=51, Predicted=3822.5811, Expected=3877.0000
# Month=52, Predicted=3868.5297, Expected=3875.0000
# Month=53, Predicted=3876.6923, Expected=3890.0000
# Month=54, Predicted=3892.8636, Expected=3910.0000
# Month=55, Predicted=3912.3006, Expected=3924.0000
# Month=56, Predicted=3926.9280, Expected=3918.0000
# Month=57, Predicted=3918.8364, Expected=3936.0000
# Month=58, Predicted=3938.5727, Expected=3911.0000
# Month=59, Predicted=3908.4052, Expected=3891.0000
# Month=60, Predicted=3889.3613, Expected=3855.0000
# Run 30 — RMSE: 24.284764, MSE: 589.749741, NMSE: 0.0027103384

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Gate Replacement on Dow Jones Industrial Index (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Gate Replacement on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.410098 ± 0.074523
# MSE:  595.858419 ± 3.637466
# NMSE: 0.0027373263 ± 0.0000238052
#
# Best run: 30
#   RMSE: 24.284764
#   MSE:  589.749741
#   NMSE: 0.0027103384

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Gate Replacement — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 24.284764
# MSE:  589.749741
# NMSE: 0.0027103384

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
