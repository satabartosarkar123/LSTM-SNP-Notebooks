# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 361 (1.41 KB)
#  Trainable params: 361 (1.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (539, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (539, 1, 2), y_train shape: (539,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    # Set consumption gate (c) bias to 1.0 (unit forget bias)
    rnn_layer = model.layers[1]
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, bias[units:2*units]
    weights[2] = bias
    cell.set_weights(weights)

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=13.3026, Expected=13.7000
# Month=2, Predicted=14.1764, Expected=13.8140
# Month=3, Predicted=14.1607, Expected=14.3830
# Month=4, Predicted=14.7921, Expected=15.0470
# Month=5, Predicted=15.3384, Expected=15.6930
# Month=6, Predicted=15.8568, Expected=15.8440
# Month=7, Predicted=15.6980, Expected=15.7120
# Month=8, Predicted=15.3327, Expected=15.3130
# Month=9, Predicted=14.7390, Expected=14.7630
# Month=10, Predicted=14.1868, Expected=13.5480
# Month=11, Predicted=12.7725, Expected=13.5860
# Month=12, Predicted=13.5491, Expected=14.5160
# Month=13, Predicted=14.9770, Expected=14.3830
# Month=14, Predicted=14.7495, Expected=14.4970
# Month=15, Predicted=14.9145, Expected=14.7440
# Month=16, Predicted=15.0221, Expected=15.8060
# Month=17, Predicted=16.1742, Expected=16.5270
# Month=18, Predicted=16.7879, Expected=16.5460
# Month=19, Predicted=16.3496, Expected=16.7170
# Month=20, Predicted=16.4679, Expected=16.4330
# Month=21, Predicted=15.9168, Expected=15.7690
# Month=22, Predicted=15.1059, Expected=15.2750
# Month=23, Predicted=14.7934, Expected=15.1230
# Month=24, Predicted=14.9254, Expected=15.5410
# Month=25, Predicted=15.8268, Expected=15.8250
# Month=26, Predicted=16.2242, Expected=16.3760
# Month=27, Predicted=16.8465, Expected=16.3570
# Month=28, Predicted=16.5195, Expected=16.9070
# Month=29, Predicted=17.1644, Expected=17.0210
# Month=30, Predicted=17.0221, Expected=17.4190
# Month=31, Predicted=17.4612, Expected=17.5330
# Month=32, Predicted=17.4107, Expected=17.2680
# Month=33, Predicted=16.9394, Expected=16.6030
# Month=34, Predicted=16.0441, Expected=15.8250
# Month=35, Predicted=15.2875, Expected=15.4460
# Month=36, Predicted=15.1927, Expected=15.6360
# Month=37, Predicted=15.8707, Expected=15.6930
# Month=38, Predicted=16.0802, Expected=16.7550
# Month=39, Predicted=17.3972, Expected=16.5090
# Month=40, Predicted=16.7108, Expected=17.7230
# Month=41, Predicted=18.1311, Expected=18.6910
# Month=42, Predicted=18.9824, Expected=19.1270
# Month=43, Predicted=19.0253, Expected=19.5640
# Month=44, Predicted=19.3265, Expected=19.2030
# Month=45, Predicted=18.5388, Expected=18.2160
# Month=46, Predicted=17.2821, Expected=17.2110
# Month=47, Predicted=16.3631, Expected=16.6600
# Month=48, Predicted=16.1525, Expected=16.8310
# Month=49, Predicted=16.9126, Expected=15.7690
# Month=50, Predicted=15.7013, Expected=15.7310
# Month=51, Predicted=16.1596, Expected=15.9960
# Month=52, Predicted=16.5909, Expected=17.0210
# Month=53, Predicted=17.7747, Expected=17.5520
# Month=54, Predicted=18.0281, Expected=17.8370
# Month=55, Predicted=17.9948, Expected=17.8560
# Month=56, Predicted=17.7208, Expected=17.5710
# Month=57, Predicted=17.1858, Expected=17.0780
# Month=58, Predicted=16.5279, Expected=16.6600
# Month=59, Predicted=16.2057, Expected=16.4330
# Month=60, Predicted=16.1797, Expected=16.5840
# Run 1 — RMSE: 0.427058, MSE: 0.182379, NMSE: 0.0015641678
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.3774, Expected=13.7000
# Month=2, Predicted=14.2209, Expected=13.8140
# Month=3, Predicted=14.3422, Expected=14.3830
# Month=4, Predicted=14.9304, Expected=15.0470
# Month=5, Predicted=15.4235, Expected=15.6930
# Month=6, Predicted=15.7639, Expected=15.8440
# Month=7, Predicted=15.6862, Expected=15.7120
# Month=8, Predicted=15.2902, Expected=15.3130
# Month=9, Predicted=14.8051, Expected=14.7630
# Month=10, Predicted=14.2298, Expected=13.5480
# Month=11, Predicted=12.8996, Expected=13.5860
# Month=12, Predicted=13.5519, Expected=14.5160
# Month=13, Predicted=14.8144, Expected=14.3830
# Month=14, Predicted=14.7889, Expected=14.4970
# Month=15, Predicted=15.1550, Expected=14.7440
# Month=16, Predicted=15.2733, Expected=15.8060
# Month=17, Predicted=16.0879, Expected=16.5270
# Month=18, Predicted=16.7415, Expected=16.5460
# Month=19, Predicted=16.2150, Expected=16.7170
# Month=20, Predicted=16.5153, Expected=16.4330
# Month=21, Predicted=15.9495, Expected=15.7690
# Month=22, Predicted=15.1342, Expected=15.2750
# Month=23, Predicted=14.8854, Expected=15.1230
# Month=24, Predicted=15.0356, Expected=15.5410
# Month=25, Predicted=15.7999, Expected=15.8250
# Month=26, Predicted=16.3000, Expected=16.3760
# Month=27, Predicted=17.0084, Expected=16.3570
# Month=28, Predicted=16.7470, Expected=16.9070
# Month=29, Predicted=17.1793, Expected=17.0210
# Month=30, Predicted=17.0568, Expected=17.4190
# Month=31, Predicted=17.3019, Expected=17.5330
# Month=32, Predicted=17.4061, Expected=17.2680
# Month=33, Predicted=16.8393, Expected=16.6030
# Month=34, Predicted=16.1201, Expected=15.8250
# Month=35, Predicted=15.3682, Expected=15.4460
# Month=36, Predicted=15.3064, Expected=15.6360
# Month=37, Predicted=15.8284, Expected=15.6930
# Month=38, Predicted=16.0793, Expected=16.7550
# Month=39, Predicted=17.4476, Expected=16.5090
# Month=40, Predicted=16.8799, Expected=17.7230
# Month=41, Predicted=18.0279, Expected=18.6910
# Month=42, Predicted=19.1595, Expected=19.1270
# Month=43, Predicted=18.8209, Expected=19.5640
# Month=44, Predicted=19.4753, Expected=19.2030
# Month=45, Predicted=18.5937, Expected=18.2160
# Month=46, Predicted=17.3343, Expected=17.2110
# Month=47, Predicted=16.4507, Expected=16.6600
# Month=48, Predicted=16.3062, Expected=16.8310
# Month=49, Predicted=16.9174, Expected=15.7690
# Month=50, Predicted=15.8746, Expected=15.7310
# Month=51, Predicted=16.3676, Expected=15.9960
# Month=52, Predicted=16.7463, Expected=17.0210
# Month=53, Predicted=17.6059, Expected=17.5520
# Month=54, Predicted=17.8938, Expected=17.8370
# Month=55, Predicted=17.6848, Expected=17.8560
# Month=56, Predicted=17.6262, Expected=17.5710
# Month=57, Predicted=16.9869, Expected=17.0780
# Month=58, Predicted=16.4816, Expected=16.6600
# Month=59, Predicted=16.1678, Expected=16.4330
# Month=60, Predicted=16.1589, Expected=16.5840
# Run 2 — RMSE: 0.413255, MSE: 0.170780, NMSE: 0.0015472848
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.1802, Expected=13.7000
# Month=2, Predicted=14.0962, Expected=13.8140
# Month=3, Predicted=14.4964, Expected=14.3830
# Month=4, Predicted=15.1362, Expected=15.0470
# Month=5, Predicted=15.4523, Expected=15.6930
# Month=6, Predicted=15.7892, Expected=15.8440
# Month=7, Predicted=15.7142, Expected=15.7120
# Month=8, Predicted=15.2490, Expected=15.3130
# Month=9, Predicted=14.6591, Expected=14.7630
# Month=10, Predicted=14.1703, Expected=13.5480
# Month=11, Predicted=12.9905, Expected=13.5860
# Month=12, Predicted=13.5300, Expected=14.5160
# Month=13, Predicted=14.6103, Expected=14.3830
# Month=14, Predicted=14.6637, Expected=14.4970
# Month=15, Predicted=15.3690, Expected=14.7440
# Month=16, Predicted=15.4109, Expected=15.8060
# Month=17, Predicted=16.1759, Expected=16.5270
# Month=18, Predicted=16.8330, Expected=16.5460
# Month=19, Predicted=16.2637, Expected=16.7170
# Month=20, Predicted=16.3170, Expected=16.4330
# Month=21, Predicted=15.9114, Expected=15.7690
# Month=22, Predicted=15.1771, Expected=15.2750
# Month=23, Predicted=14.9661, Expected=15.1230
# Month=24, Predicted=15.0736, Expected=15.5410
# Month=25, Predicted=15.7733, Expected=15.8250
# Month=26, Predicted=16.3812, Expected=16.3760
# Month=27, Predicted=17.2250, Expected=16.3570
# Month=28, Predicted=16.7525, Expected=16.9070
# Month=29, Predicted=17.0158, Expected=17.0210
# Month=30, Predicted=17.0665, Expected=17.4190
# Month=31, Predicted=17.2212, Expected=17.5330
# Month=32, Predicted=17.2133, Expected=17.2680
# Month=33, Predicted=16.7737, Expected=16.6030
# Month=34, Predicted=16.1379, Expected=15.8250
# Month=35, Predicted=15.5124, Expected=15.4460
# Month=36, Predicted=15.4608, Expected=15.6360
# Month=37, Predicted=16.0096, Expected=15.6930
# Month=38, Predicted=16.3468, Expected=16.7550
# Month=39, Predicted=17.6522, Expected=16.5090
# Month=40, Predicted=16.8138, Expected=17.7230
# Month=41, Predicted=17.7518, Expected=18.6910
# Month=42, Predicted=19.2485, Expected=19.1270
# Month=43, Predicted=18.9379, Expected=19.5640
# Month=44, Predicted=19.2511, Expected=19.2030
# Month=45, Predicted=18.6691, Expected=18.2160
# Month=46, Predicted=17.4903, Expected=17.2110
# Month=47, Predicted=16.7119, Expected=16.6600
# Month=48, Predicted=16.5412, Expected=16.8310
# Month=49, Predicted=17.0348, Expected=15.7690
# Month=50, Predicted=16.1103, Expected=15.7310
# Month=51, Predicted=16.5816, Expected=15.9960
# Month=52, Predicted=16.8149, Expected=17.0210
# Month=53, Predicted=17.5910, Expected=17.5520
# Month=54, Predicted=17.8907, Expected=17.8370
# Month=55, Predicted=17.7307, Expected=17.8560
# Month=56, Predicted=17.6112, Expected=17.5710
# Month=57, Predicted=17.0802, Expected=17.0780
# Month=58, Predicted=16.5851, Expected=16.6600
# Month=59, Predicted=16.3947, Expected=16.4330
# Month=60, Predicted=16.3581, Expected=16.5840
# Run 3 — RMSE: 0.426680, MSE: 0.182055, NMSE: 0.0016443676
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.1999, Expected=13.7000
# Month=2, Predicted=13.8745, Expected=13.8140
# Month=3, Predicted=14.3407, Expected=14.3830
# Month=4, Predicted=15.1961, Expected=15.0470
# Month=5, Predicted=15.4792, Expected=15.6930
# Month=6, Predicted=15.8216, Expected=15.8440
# Month=7, Predicted=15.7092, Expected=15.7120
# Month=8, Predicted=15.2793, Expected=15.3130
# Month=9, Predicted=14.7553, Expected=14.7630
# Month=10, Predicted=14.2088, Expected=13.5480
# Month=11, Predicted=13.0037, Expected=13.5860
# Month=12, Predicted=13.6326, Expected=14.5160
# Month=13, Predicted=14.6722, Expected=14.3830
# Month=14, Predicted=14.3535, Expected=14.4970
# Month=15, Predicted=15.3344, Expected=14.7440
# Month=16, Predicted=15.4789, Expected=15.8060
# Month=17, Predicted=16.1617, Expected=16.5270
# Month=18, Predicted=16.7800, Expected=16.5460
# Month=19, Predicted=16.2523, Expected=16.7170
# Month=20, Predicted=16.3344, Expected=16.4330
# Month=21, Predicted=16.0428, Expected=15.7690
# Month=22, Predicted=15.2512, Expected=15.2750
# Month=23, Predicted=15.0576, Expected=15.1230
# Month=24, Predicted=15.2141, Expected=15.5410
# Month=25, Predicted=15.7766, Expected=15.8250
# Month=26, Predicted=16.2689, Expected=16.3760
# Month=27, Predicted=17.2079, Expected=16.3570
# Month=28, Predicted=16.7159, Expected=16.9070
# Month=29, Predicted=17.0341, Expected=17.0210
# Month=30, Predicted=16.9972, Expected=17.4190
# Month=31, Predicted=17.2126, Expected=17.5330
# Month=32, Predicted=17.2726, Expected=17.2680
# Month=33, Predicted=16.8228, Expected=16.6030
# Month=34, Predicted=16.1261, Expected=15.8250
# Month=35, Predicted=15.5606, Expected=15.4460
# Month=36, Predicted=15.5278, Expected=15.6360
# Month=37, Predicted=15.9238, Expected=15.6930
# Month=38, Predicted=16.1065, Expected=16.7550
# Month=39, Predicted=17.6641, Expected=16.5090
# Month=40, Predicted=16.9077, Expected=17.7230
# Month=41, Predicted=17.8343, Expected=18.6910
# Month=42, Predicted=19.0892, Expected=19.1270
# Month=43, Predicted=19.0420, Expected=19.5640
# Month=44, Predicted=19.3275, Expected=19.2030
# Month=45, Predicted=18.7629, Expected=18.2160
# Month=46, Predicted=17.5216, Expected=17.2110
# Month=47, Predicted=16.7819, Expected=16.6600
# Month=48, Predicted=16.6502, Expected=16.8310
# Month=49, Predicted=17.0271, Expected=15.7690
# Month=50, Predicted=15.7879, Expected=15.7310
# Month=51, Predicted=16.5544, Expected=15.9960
# Month=52, Predicted=17.0358, Expected=17.0210
# Month=53, Predicted=17.5907, Expected=17.5520
# Month=54, Predicted=17.7980, Expected=17.8370
# Month=55, Predicted=17.7121, Expected=17.8560
# Month=56, Predicted=17.5863, Expected=17.5710
# Month=57, Predicted=17.1630, Expected=17.0780
# Month=58, Predicted=16.6207, Expected=16.6600
# Month=59, Predicted=16.4167, Expected=16.4330
# Month=60, Predicted=16.4448, Expected=16.5840
# Run 4 — RMSE: 0.411302, MSE: 0.169169, NMSE: 0.0015083659
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.3206, Expected=13.7000
# Month=2, Predicted=14.1727, Expected=13.8140
# Month=3, Predicted=14.0844, Expected=14.3830
# Month=4, Predicted=14.6648, Expected=15.0470
# Month=5, Predicted=15.2915, Expected=15.6930
# Month=6, Predicted=15.8196, Expected=15.8440
# Month=7, Predicted=15.6583, Expected=15.7120
# Month=8, Predicted=15.2477, Expected=15.3130
# Month=9, Predicted=14.6677, Expected=14.7630
# Month=10, Predicted=14.1043, Expected=13.5480
# Month=11, Predicted=12.7706, Expected=13.5860
# Month=12, Predicted=13.4687, Expected=14.5160
# Month=13, Predicted=15.0994, Expected=14.3830
# Month=14, Predicted=14.6352, Expected=14.4970
# Month=15, Predicted=14.6666, Expected=14.7440
# Month=16, Predicted=14.9108, Expected=15.8060
# Month=17, Predicted=16.1237, Expected=16.5270
# Month=18, Predicted=16.7913, Expected=16.5460
# Month=19, Predicted=16.3456, Expected=16.7170
# Month=20, Predicted=16.3891, Expected=16.4330
# Month=21, Predicted=15.9152, Expected=15.7690
# Month=22, Predicted=15.0420, Expected=15.2750
# Month=23, Predicted=14.7217, Expected=15.1230
# Month=24, Predicted=14.9512, Expected=15.5410
# Month=25, Predicted=15.8634, Expected=15.8250
# Month=26, Predicted=16.2130, Expected=16.3760
# Month=27, Predicted=16.7541, Expected=16.3570
# Month=28, Predicted=16.4018, Expected=16.9070
# Month=29, Predicted=17.0128, Expected=17.0210
# Month=30, Predicted=16.9656, Expected=17.4190
# Month=31, Predicted=17.3754, Expected=17.5330
# Month=32, Predicted=17.3848, Expected=17.2680
# Month=33, Predicted=16.8866, Expected=16.6030
# Month=34, Predicted=15.9740, Expected=15.8250
# Month=35, Predicted=15.2028, Expected=15.4460
# Month=36, Predicted=15.1588, Expected=15.6360
# Month=37, Predicted=15.8902, Expected=15.6930
# Month=38, Predicted=16.0597, Expected=16.7550
# Month=39, Predicted=17.3179, Expected=16.5090
# Month=40, Predicted=16.5518, Expected=17.7230
# Month=41, Predicted=17.9371, Expected=18.6910
# Month=42, Predicted=19.0318, Expected=19.1270
# Month=43, Predicted=19.1042, Expected=19.5640
# Month=44, Predicted=19.3509, Expected=19.2030
# Month=45, Predicted=18.5807, Expected=18.2160
# Month=46, Predicted=17.2035, Expected=17.2110
# Month=47, Predicted=16.3076, Expected=16.6600
# Month=48, Predicted=16.1799, Expected=16.8310
# Month=49, Predicted=16.9967, Expected=15.7690
# Month=50, Predicted=15.5948, Expected=15.7310
# Month=51, Predicted=15.8834, Expected=15.9960
# Month=52, Predicted=16.5324, Expected=17.0210
# Month=53, Predicted=17.7035, Expected=17.5520
# Month=54, Predicted=17.9641, Expected=17.8370
# Month=55, Predicted=17.9451, Expected=17.8560
# Month=56, Predicted=17.6868, Expected=17.5710
# Month=57, Predicted=17.1594, Expected=17.0780
# Month=58, Predicted=16.5199, Expected=16.6600
# Month=59, Predicted=16.2023, Expected=16.4330
# Month=60, Predicted=16.2442, Expected=16.5840
# Run 5 — RMSE: 0.450770, MSE: 0.203194, NMSE: 0.0017090940
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2708, Expected=13.7000
# Month=2, Predicted=14.2438, Expected=13.8140
# Month=3, Predicted=14.5335, Expected=14.3830
# Month=4, Predicted=15.0350, Expected=15.0470
# Month=5, Predicted=15.3884, Expected=15.6930
# Month=6, Predicted=15.6730, Expected=15.8440
# Month=7, Predicted=15.5812, Expected=15.7120
# Month=8, Predicted=15.2309, Expected=15.3130
# Month=9, Predicted=14.8056, Expected=14.7630
# Month=10, Predicted=14.3369, Expected=13.5480
# Month=11, Predicted=13.0403, Expected=13.5860
# Month=12, Predicted=13.5923, Expected=14.5160
# Month=13, Predicted=14.8553, Expected=14.3830
# Month=14, Predicted=14.6514, Expected=14.4970
# Month=15, Predicted=15.2073, Expected=14.7440
# Month=16, Predicted=15.4413, Expected=15.8060
# Month=17, Predicted=16.1987, Expected=16.5270
# Month=18, Predicted=16.6732, Expected=16.5460
# Month=19, Predicted=16.2070, Expected=16.7170
# Month=20, Predicted=16.3610, Expected=16.4330
# Month=21, Predicted=16.0398, Expected=15.7690
# Month=22, Predicted=15.2983, Expected=15.2750
# Month=23, Predicted=14.9849, Expected=15.1230
# Month=24, Predicted=15.1374, Expected=15.5410
# Month=25, Predicted=15.8097, Expected=15.8250
# Month=26, Predicted=16.3354, Expected=16.3760
# Month=27, Predicted=17.1224, Expected=16.3570
# Month=28, Predicted=16.8509, Expected=16.9070
# Month=29, Predicted=17.0448, Expected=17.0210
# Month=30, Predicted=16.9499, Expected=17.4190
# Month=31, Predicted=17.1954, Expected=17.5330
# Month=32, Predicted=17.2741, Expected=17.2680
# Month=33, Predicted=16.9307, Expected=16.6030
# Month=34, Predicted=16.2380, Expected=15.8250
# Month=35, Predicted=15.5457, Expected=15.4460
# Month=36, Predicted=15.4629, Expected=15.6360
# Month=37, Predicted=16.0235, Expected=15.6930
# Month=38, Predicted=16.2092, Expected=16.7550
# Month=39, Predicted=17.4783, Expected=16.5090
# Month=40, Predicted=16.9343, Expected=17.7230
# Month=41, Predicted=17.8690, Expected=18.6910
# Month=42, Predicted=19.0084, Expected=19.1270
# Month=43, Predicted=18.9381, Expected=19.5640
# Month=44, Predicted=19.2933, Expected=19.2030
# Month=45, Predicted=18.7368, Expected=18.2160
# Month=46, Predicted=17.5408, Expected=17.2110
# Month=47, Predicted=16.5996, Expected=16.6600
# Month=48, Predicted=16.3971, Expected=16.8310
# Month=49, Predicted=16.9976, Expected=15.7690
# Month=50, Predicted=15.6786, Expected=15.7310
# Month=51, Predicted=16.2848, Expected=15.9960
# Month=52, Predicted=16.8575, Expected=17.0210
# Month=53, Predicted=17.7628, Expected=17.5520
# Month=54, Predicted=17.9129, Expected=17.8370
# Month=55, Predicted=17.7607, Expected=17.8560
# Month=56, Predicted=17.6421, Expected=17.5710
# Month=57, Predicted=17.1592, Expected=17.0780
# Month=58, Predicted=16.5054, Expected=16.6600
# Month=59, Predicted=16.2277, Expected=16.4330
# Month=60, Predicted=16.2590, Expected=16.5840
# Run 6 — RMSE: 0.414143, MSE: 0.171515, NMSE: 0.0015973949
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.3093, Expected=13.7000
# Month=2, Predicted=14.1467, Expected=13.8140
# Month=3, Predicted=14.1917, Expected=14.3830
# Month=4, Predicted=14.8040, Expected=15.0470
# Month=5, Predicted=15.3217, Expected=15.6930
# Month=6, Predicted=15.7924, Expected=15.8440
# Month=7, Predicted=15.6562, Expected=15.7120
# Month=8, Predicted=15.3226, Expected=15.3130
# Month=9, Predicted=14.7810, Expected=14.7630
# Month=10, Predicted=14.2239, Expected=13.5480
# Month=11, Predicted=12.8278, Expected=13.5860
# Month=12, Predicted=13.5186, Expected=14.5160
# Month=13, Predicted=14.8960, Expected=14.3830
# Month=14, Predicted=14.6604, Expected=14.4970
# Month=15, Predicted=14.9148, Expected=14.7440
# Month=16, Predicted=15.0222, Expected=15.8060
# Month=17, Predicted=16.0922, Expected=16.5270
# Month=18, Predicted=16.7468, Expected=16.5460
# Month=19, Predicted=16.3680, Expected=16.7170
# Month=20, Predicted=16.4602, Expected=16.4330
# Month=21, Predicted=15.9321, Expected=15.7690
# Month=22, Predicted=15.1680, Expected=15.2750
# Month=23, Predicted=14.8594, Expected=15.1230
# Month=24, Predicted=14.9450, Expected=15.5410
# Month=25, Predicted=15.7964, Expected=15.8250
# Month=26, Predicted=16.2350, Expected=16.3760
# Month=27, Predicted=16.8491, Expected=16.3570
# Month=28, Predicted=16.5337, Expected=16.9070
# Month=29, Predicted=17.1372, Expected=17.0210
# Month=30, Predicted=16.9986, Expected=17.4190
# Month=31, Predicted=17.4224, Expected=17.5330
# Month=32, Predicted=17.4094, Expected=17.2680
# Month=33, Predicted=16.9606, Expected=16.6030
# Month=34, Predicted=16.1472, Expected=15.8250
# Month=35, Predicted=15.3421, Expected=15.4460
# Month=36, Predicted=15.2251, Expected=15.6360
# Month=37, Predicted=15.8501, Expected=15.6930
# Month=38, Predicted=16.0677, Expected=16.7550
# Month=39, Predicted=17.3822, Expected=16.5090
# Month=40, Predicted=16.7074, Expected=17.7230
# Month=41, Predicted=18.0683, Expected=18.6910
# Month=42, Predicted=18.8838, Expected=19.1270
# Month=43, Predicted=18.9750, Expected=19.5640
# Month=44, Predicted=19.3426, Expected=19.2030
# Month=45, Predicted=18.5617, Expected=18.2160
# Month=46, Predicted=17.3313, Expected=17.2110
# Month=47, Predicted=16.3905, Expected=16.6600
# Month=48, Predicted=16.0964, Expected=16.8310
# Month=49, Predicted=16.8528, Expected=15.7690
# Month=50, Predicted=15.6931, Expected=15.7310
# Month=51, Predicted=16.0659, Expected=15.9960
# Month=52, Predicted=16.5465, Expected=17.0210
# Month=53, Predicted=17.6838, Expected=17.5520
# Month=54, Predicted=18.0821, Expected=17.8370
# Month=55, Predicted=17.9983, Expected=17.8560
# Month=56, Predicted=17.6364, Expected=17.5710
# Month=57, Predicted=17.1207, Expected=17.0780
# Month=58, Predicted=16.5531, Expected=16.6600
# Month=59, Predicted=16.2281, Expected=16.4330
# Month=60, Predicted=16.2091, Expected=16.5840
# Run 7 — RMSE: 0.425596, MSE: 0.181132, NMSE: 0.0015784880
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.3956, Expected=13.7000
# Month=2, Predicted=14.3488, Expected=13.8140
# Month=3, Predicted=14.3239, Expected=14.3830
# Month=4, Predicted=14.8630, Expected=15.0470
# Month=5, Predicted=15.3742, Expected=15.6930
# Month=6, Predicted=15.7164, Expected=15.8440
# Month=7, Predicted=15.5474, Expected=15.7120
# Month=8, Predicted=15.2072, Expected=15.3130
# Month=9, Predicted=14.7467, Expected=14.7630
# Month=10, Predicted=14.2531, Expected=13.5480
# Month=11, Predicted=13.0086, Expected=13.5860
# Month=12, Predicted=13.7084, Expected=14.5160
# Month=13, Predicted=15.0992, Expected=14.3830
# Month=14, Predicted=14.7507, Expected=14.4970
# Month=15, Predicted=14.9033, Expected=14.7440
# Month=16, Predicted=15.1847, Expected=15.8060
# Month=17, Predicted=16.1815, Expected=16.5270
# Month=18, Predicted=16.7285, Expected=16.5460
# Month=19, Predicted=16.2095, Expected=16.7170
# Month=20, Predicted=16.3833, Expected=16.4330
# Month=21, Predicted=16.0116, Expected=15.7690
# Month=22, Predicted=15.2444, Expected=15.2750
# Month=23, Predicted=14.9364, Expected=15.1230
# Month=24, Predicted=15.0947, Expected=15.5410
# Month=25, Predicted=15.8556, Expected=15.8250
# Month=26, Predicted=16.2174, Expected=16.3760
# Month=27, Predicted=16.8574, Expected=16.3570
# Month=28, Predicted=16.6178, Expected=16.9070
# Month=29, Predicted=17.1887, Expected=17.0210
# Month=30, Predicted=17.0541, Expected=17.4190
# Month=31, Predicted=17.3018, Expected=17.5330
# Month=32, Predicted=17.2787, Expected=17.2680
# Month=33, Predicted=16.8242, Expected=16.6030
# Month=34, Predicted=16.1029, Expected=15.8250
# Month=35, Predicted=15.4456, Expected=15.4460
# Month=36, Predicted=15.4348, Expected=15.6360
# Month=37, Predicted=16.0219, Expected=15.6930
# Month=38, Predicted=16.1228, Expected=16.7550
# Month=39, Predicted=17.3689, Expected=16.5090
# Month=40, Predicted=16.7450, Expected=17.7230
# Month=41, Predicted=18.0437, Expected=18.6910
# Month=42, Predicted=19.1504, Expected=19.1270
# Month=43, Predicted=18.9420, Expected=19.5640
# Month=44, Predicted=19.2848, Expected=19.2030
# Month=45, Predicted=18.6555, Expected=18.2160
# Month=46, Predicted=17.4012, Expected=17.2110
# Month=47, Predicted=16.4524, Expected=16.6600
# Month=48, Predicted=16.2251, Expected=16.8310
# Month=49, Predicted=16.8299, Expected=15.7690
# Month=50, Predicted=15.6013, Expected=15.7310
# Month=51, Predicted=16.0934, Expected=15.9960
# Month=52, Predicted=16.6943, Expected=17.0210
# Month=53, Predicted=17.7959, Expected=17.5520
# Month=54, Predicted=18.0824, Expected=17.8370
# Month=55, Predicted=17.9524, Expected=17.8560
# Month=56, Predicted=17.7064, Expected=17.5710
# Month=57, Predicted=17.1580, Expected=17.0780
# Month=58, Predicted=16.5197, Expected=16.6600
# Month=59, Predicted=16.1602, Expected=16.4330
# Month=60, Predicted=16.0622, Expected=16.5840
# Run 8 — RMSE: 0.406755, MSE: 0.165449, NMSE: 0.0015078262
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.3572, Expected=13.7000
# Month=2, Predicted=14.2868, Expected=13.8140
# Month=3, Predicted=14.4317, Expected=14.3830
# Month=4, Predicted=14.9862, Expected=15.0470
# Month=5, Predicted=15.3643, Expected=15.6930
# Month=6, Predicted=15.7749, Expected=15.8440
# Month=7, Predicted=15.6479, Expected=15.7120
# Month=8, Predicted=15.2675, Expected=15.3130
# Month=9, Predicted=14.7244, Expected=14.7630
# Month=10, Predicted=14.1630, Expected=13.5480
# Month=11, Predicted=12.7892, Expected=13.5860
# Month=12, Predicted=13.6604, Expected=14.5160
# Month=13, Predicted=14.9026, Expected=14.3830
# Month=14, Predicted=14.7869, Expected=14.4970
# Month=15, Predicted=15.1702, Expected=14.7440
# Month=16, Predicted=15.2788, Expected=15.8060
# Month=17, Predicted=16.2420, Expected=16.5270
# Month=18, Predicted=16.7148, Expected=16.5460
# Month=19, Predicted=16.3261, Expected=16.7170
# Month=20, Predicted=16.3883, Expected=16.4330
# Month=21, Predicted=15.8946, Expected=15.7690
# Month=22, Predicted=15.0711, Expected=15.2750
# Month=23, Predicted=14.8101, Expected=15.1230
# Month=24, Predicted=15.0122, Expected=15.5410
# Month=25, Predicted=15.8228, Expected=15.8250
# Month=26, Predicted=16.3179, Expected=16.3760
# Month=27, Predicted=17.0905, Expected=16.3570
# Month=28, Predicted=16.7798, Expected=16.9070
# Month=29, Predicted=17.2226, Expected=17.0210
# Month=30, Predicted=17.0142, Expected=17.4190
# Month=31, Predicted=17.3322, Expected=17.5330
# Month=32, Predicted=17.2865, Expected=17.2680
# Month=33, Predicted=16.8126, Expected=16.6030
# Month=34, Predicted=16.0119, Expected=15.8250
# Month=35, Predicted=15.3439, Expected=15.4460
# Month=36, Predicted=15.3313, Expected=15.6360
# Month=37, Predicted=15.8986, Expected=15.6930
# Month=38, Predicted=16.1076, Expected=16.7550
# Month=39, Predicted=17.5218, Expected=16.5090
# Month=40, Predicted=16.9070, Expected=17.7230
# Month=41, Predicted=18.1164, Expected=18.6910
# Month=42, Predicted=18.9003, Expected=19.1270
# Month=43, Predicted=19.0176, Expected=19.5640
# Month=44, Predicted=19.3137, Expected=19.2030
# Month=45, Predicted=18.5610, Expected=18.2160
# Month=46, Predicted=17.2421, Expected=17.2110
# Month=47, Predicted=16.3888, Expected=16.6600
# Month=48, Predicted=16.3073, Expected=16.8310
# Month=49, Predicted=16.9610, Expected=15.7690
# Month=50, Predicted=15.6815, Expected=15.7310
# Month=51, Predicted=16.2122, Expected=15.9960
# Month=52, Predicted=16.6689, Expected=17.0210
# Month=53, Predicted=17.8036, Expected=17.5520
# Month=54, Predicted=17.9561, Expected=17.8370
# Month=55, Predicted=17.8146, Expected=17.8560
# Month=56, Predicted=17.6051, Expected=17.5710
# Month=57, Predicted=17.0901, Expected=17.0780
# Month=58, Predicted=16.4951, Expected=16.6600
# Month=59, Predicted=16.1736, Expected=16.4330
# Month=60, Predicted=16.1642, Expected=16.5840
# Run 9 — RMSE: 0.407613, MSE: 0.166149, NMSE: 0.0014994028
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2607, Expected=13.7000
# Month=2, Predicted=14.1883, Expected=13.8140
# Month=3, Predicted=14.4343, Expected=14.3830
# Month=4, Predicted=15.0873, Expected=15.0470
# Month=5, Predicted=15.4455, Expected=15.6930
# Month=6, Predicted=15.7450, Expected=15.8440
# Month=7, Predicted=15.6124, Expected=15.7120
# Month=8, Predicted=15.2567, Expected=15.3130
# Month=9, Predicted=14.7480, Expected=14.7630
# Month=10, Predicted=14.2396, Expected=13.5480
# Month=11, Predicted=12.9912, Expected=13.5860
# Month=12, Predicted=13.5555, Expected=14.5160
# Month=13, Predicted=14.6894, Expected=14.3830
# Month=14, Predicted=14.6585, Expected=14.4970
# Month=15, Predicted=15.3117, Expected=14.7440
# Month=16, Predicted=15.4569, Expected=15.8060
# Month=17, Predicted=16.1959, Expected=16.5270
# Month=18, Predicted=16.6948, Expected=16.5460
# Month=19, Predicted=16.1961, Expected=16.7170
# Month=20, Predicted=16.3874, Expected=16.4330
# Month=21, Predicted=15.9841, Expected=15.7690
# Month=22, Predicted=15.1986, Expected=15.2750
# Month=23, Predicted=14.9084, Expected=15.1230
# Month=24, Predicted=14.9973, Expected=15.5410
# Month=25, Predicted=15.7165, Expected=15.8250
# Month=26, Predicted=16.2673, Expected=16.3760
# Month=27, Predicted=17.1317, Expected=16.3570
# Month=28, Predicted=16.8781, Expected=16.9070
# Month=29, Predicted=17.2455, Expected=17.0210
# Month=30, Predicted=16.9908, Expected=17.4190
# Month=31, Predicted=17.2280, Expected=17.5330
# Month=32, Predicted=17.2980, Expected=17.2680
# Month=33, Predicted=16.8477, Expected=16.6030
# Month=34, Predicted=16.1381, Expected=15.8250
# Month=35, Predicted=15.4643, Expected=15.4460
# Month=36, Predicted=15.3576, Expected=15.6360
# Month=37, Predicted=15.8349, Expected=15.6930
# Month=38, Predicted=16.1217, Expected=16.7550
# Month=39, Predicted=17.6165, Expected=16.5090
# Month=40, Predicted=16.9558, Expected=17.7230
# Month=41, Predicted=18.1105, Expected=18.6910
# Month=42, Predicted=19.0170, Expected=19.1270
# Month=43, Predicted=18.8909, Expected=19.5640
# Month=44, Predicted=19.3587, Expected=19.2030
# Month=45, Predicted=18.7400, Expected=18.2160
# Month=46, Predicted=17.4712, Expected=17.2110
# Month=47, Predicted=16.6077, Expected=16.6600
# Month=48, Predicted=16.3381, Expected=16.8310
# Month=49, Predicted=16.7710, Expected=15.7690
# Month=50, Predicted=15.6384, Expected=15.7310
# Month=51, Predicted=16.3668, Expected=15.9960
# Month=52, Predicted=16.8533, Expected=17.0210
# Month=53, Predicted=17.7961, Expected=17.5520
# Month=54, Predicted=17.9112, Expected=17.8370
# Month=55, Predicted=17.7366, Expected=17.8560
# Month=56, Predicted=17.5566, Expected=17.5710
# Month=57, Predicted=17.0342, Expected=17.0780
# Month=58, Predicted=16.4495, Expected=16.6600
# Month=59, Predicted=16.1789, Expected=16.4330
# Month=60, Predicted=16.1689, Expected=16.5840
# Run 10 — RMSE: 0.406593, MSE: 0.165318, NMSE: 0.0014848701
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.4404, Expected=13.7000
# Month=2, Predicted=14.3904, Expected=13.8140
# Month=3, Predicted=14.4731, Expected=14.3830
# Month=4, Predicted=14.9300, Expected=15.0470
# Month=5, Predicted=15.2944, Expected=15.6930
# Month=6, Predicted=15.7290, Expected=15.8440
# Month=7, Predicted=15.6254, Expected=15.7120
# Month=8, Predicted=15.3059, Expected=15.3130
# Month=9, Predicted=14.7190, Expected=14.7630
# Month=10, Predicted=14.1989, Expected=13.5480
# Month=11, Predicted=12.9549, Expected=13.5860
# Month=12, Predicted=13.5875, Expected=14.5160
# Month=13, Predicted=14.8579, Expected=14.3830
# Month=14, Predicted=14.8846, Expected=14.4970
# Month=15, Predicted=15.2280, Expected=14.7440
# Month=16, Predicted=15.3347, Expected=15.8060
# Month=17, Predicted=16.2379, Expected=16.5270
# Month=18, Predicted=16.7158, Expected=16.5460
# Month=19, Predicted=16.2692, Expected=16.7170
# Month=20, Predicted=16.3761, Expected=16.4330
# Month=21, Predicted=15.9889, Expected=15.7690
# Month=22, Predicted=15.1173, Expected=15.2750
# Month=23, Predicted=14.8072, Expected=15.1230
# Month=24, Predicted=14.9962, Expected=15.5410
# Month=25, Predicted=15.7948, Expected=15.8250
# Month=26, Predicted=16.3869, Expected=16.3760
# Month=27, Predicted=17.1444, Expected=16.3570
# Month=28, Predicted=16.8313, Expected=16.9070
# Month=29, Predicted=17.2498, Expected=17.0210
# Month=30, Predicted=17.0303, Expected=17.4190
# Month=31, Predicted=17.3429, Expected=17.5330
# Month=32, Predicted=17.3873, Expected=17.2680
# Month=33, Predicted=16.8813, Expected=16.6030
# Month=34, Predicted=15.9836, Expected=15.8250
# Month=35, Predicted=15.2664, Expected=15.4460
# Month=36, Predicted=15.2231, Expected=15.6360
# Month=37, Predicted=15.8063, Expected=15.6930
# Month=38, Predicted=16.1615, Expected=16.7550
# Month=39, Predicted=17.5857, Expected=16.5090
# Month=40, Predicted=16.9165, Expected=17.7230
# Month=41, Predicted=18.1401, Expected=18.6910
# Month=42, Predicted=18.9613, Expected=19.1270
# Month=43, Predicted=19.0048, Expected=19.5640
# Month=44, Predicted=19.2892, Expected=19.2030
# Month=45, Predicted=18.7093, Expected=18.2160
# Month=46, Predicted=17.3384, Expected=17.2110
# Month=47, Predicted=16.4565, Expected=16.6600
# Month=48, Predicted=16.2922, Expected=16.8310
# Month=49, Predicted=16.9312, Expected=15.7690
# Month=50, Predicted=15.7894, Expected=15.7310
# Month=51, Predicted=16.3458, Expected=15.9960
# Month=52, Predicted=16.8412, Expected=17.0210
# Month=53, Predicted=17.8669, Expected=17.5520
# Month=54, Predicted=17.8492, Expected=17.8370
# Month=55, Predicted=17.7460, Expected=17.8560
# Month=56, Predicted=17.5390, Expected=17.5710
# Month=57, Predicted=17.1712, Expected=17.0780
# Month=58, Predicted=16.4974, Expected=16.6600
# Month=59, Predicted=16.1116, Expected=16.4330
# Month=60, Predicted=16.1276, Expected=16.5840
# Run 11 — RMSE: 0.417855, MSE: 0.174603, NMSE: 0.0015780021
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.3010, Expected=13.7000
# Month=2, Predicted=14.0463, Expected=13.8140
# Month=3, Predicted=14.4317, Expected=14.3830
# Month=4, Predicted=15.2423, Expected=15.0470
# Month=5, Predicted=15.4235, Expected=15.6930
# Month=6, Predicted=15.7233, Expected=15.8440
# Month=7, Predicted=15.6036, Expected=15.7120
# Month=8, Predicted=15.2887, Expected=15.3130
# Month=9, Predicted=14.7817, Expected=14.7630
# Month=10, Predicted=14.2078, Expected=13.5480
# Month=11, Predicted=13.0520, Expected=13.5860
# Month=12, Predicted=13.5880, Expected=14.5160
# Month=13, Predicted=14.7541, Expected=14.3830
# Month=14, Predicted=14.5188, Expected=14.4970
# Month=15, Predicted=15.2914, Expected=14.7440
# Month=16, Predicted=15.5159, Expected=15.8060
# Month=17, Predicted=16.1458, Expected=16.5270
# Month=18, Predicted=16.7240, Expected=16.5460
# Month=19, Predicted=16.2111, Expected=16.7170
# Month=20, Predicted=16.3482, Expected=16.4330
# Month=21, Predicted=15.9949, Expected=15.7690
# Month=22, Predicted=15.2259, Expected=15.2750
# Month=23, Predicted=14.9909, Expected=15.1230
# Month=24, Predicted=15.1799, Expected=15.5410
# Month=25, Predicted=15.7788, Expected=15.8250
# Month=26, Predicted=16.2332, Expected=16.3760
# Month=27, Predicted=17.2838, Expected=16.3570
# Month=28, Predicted=16.8701, Expected=16.9070
# Month=29, Predicted=16.9542, Expected=17.0210
# Month=30, Predicted=16.9503, Expected=17.4190
# Month=31, Predicted=17.2142, Expected=17.5330
# Month=32, Predicted=17.3478, Expected=17.2680
# Month=33, Predicted=16.8525, Expected=16.6030
# Month=34, Predicted=16.1353, Expected=15.8250
# Month=35, Predicted=15.5227, Expected=15.4460
# Month=36, Predicted=15.4800, Expected=15.6360
# Month=37, Predicted=15.8864, Expected=15.6930
# Month=38, Predicted=16.1307, Expected=16.7550
# Month=39, Predicted=17.7220, Expected=16.5090
# Month=40, Predicted=16.8728, Expected=17.7230
# Month=41, Predicted=17.6736, Expected=18.6910
# Month=42, Predicted=18.9507, Expected=19.1270
# Month=43, Predicted=18.9288, Expected=19.5640
# Month=44, Predicted=19.3122, Expected=19.2030
# Month=45, Predicted=18.7167, Expected=18.2160
# Month=46, Predicted=17.4939, Expected=17.2110
# Month=47, Predicted=16.6769, Expected=16.6600
# Month=48, Predicted=16.6189, Expected=16.8310
# Month=49, Predicted=17.0082, Expected=15.7690
# Month=50, Predicted=15.9383, Expected=15.7310
# Month=51, Predicted=16.5595, Expected=15.9960
# Month=52, Predicted=16.8422, Expected=17.0210
# Month=53, Predicted=17.4001, Expected=17.5520
# Month=54, Predicted=17.6219, Expected=17.8370
# Month=55, Predicted=17.5561, Expected=17.8560
# Month=56, Predicted=17.4600, Expected=17.5710
# Month=57, Predicted=17.0974, Expected=17.0780
# Month=58, Predicted=16.5285, Expected=16.6600
# Month=59, Predicted=16.3733, Expected=16.4330
# Month=60, Predicted=16.4321, Expected=16.5840
# Run 12 — RMSE: 0.430599, MSE: 0.185415, NMSE: 0.0017526285
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.4430, Expected=13.7000
# Month=2, Predicted=14.3898, Expected=13.8140
# Month=3, Predicted=14.4708, Expected=14.3830
# Month=4, Predicted=14.9676, Expected=15.0470
# Month=5, Predicted=15.3987, Expected=15.6930
# Month=6, Predicted=15.7085, Expected=15.8440
# Month=7, Predicted=15.5748, Expected=15.7120
# Month=8, Predicted=15.3096, Expected=15.3130
# Month=9, Predicted=14.8178, Expected=14.7630
# Month=10, Predicted=14.3229, Expected=13.5480
# Month=11, Predicted=13.0203, Expected=13.5860
# Month=12, Predicted=13.6405, Expected=14.5160
# Month=13, Predicted=14.8722, Expected=14.3830
# Month=14, Predicted=14.8104, Expected=14.4970
# Month=15, Predicted=15.1261, Expected=14.7440
# Month=16, Predicted=15.3186, Expected=15.8060
# Month=17, Predicted=16.1935, Expected=16.5270
# Month=18, Predicted=16.6552, Expected=16.5460
# Month=19, Predicted=16.1959, Expected=16.7170
# Month=20, Predicted=16.4832, Expected=16.4330
# Month=21, Predicted=16.0639, Expected=15.7690
# Month=22, Predicted=15.2830, Expected=15.2750
# Month=23, Predicted=14.9837, Expected=15.1230
# Month=24, Predicted=15.0957, Expected=15.5410
# Month=25, Predicted=15.8845, Expected=15.8250
# Month=26, Predicted=16.3664, Expected=16.3760
# Month=27, Predicted=17.0619, Expected=16.3570
# Month=28, Predicted=16.7598, Expected=16.9070
# Month=29, Predicted=17.2174, Expected=17.0210
# Month=30, Predicted=17.0322, Expected=17.4190
# Month=31, Predicted=17.3395, Expected=17.5330
# Month=32, Predicted=17.3770, Expected=17.2680
# Month=33, Predicted=16.9912, Expected=16.6030
# Month=34, Predicted=16.2588, Expected=15.8250
# Month=35, Predicted=15.5660, Expected=15.4460
# Month=36, Predicted=15.4334, Expected=15.6360
# Month=37, Predicted=15.9293, Expected=15.6930
# Month=38, Predicted=16.1302, Expected=16.7550
# Month=39, Predicted=17.4700, Expected=16.5090
# Month=40, Predicted=16.8672, Expected=17.7230
# Month=41, Predicted=18.0903, Expected=18.6910
# Month=42, Predicted=19.0456, Expected=19.1270
# Month=43, Predicted=18.8452, Expected=19.5640
# Month=44, Predicted=19.3703, Expected=19.2030
# Month=45, Predicted=18.7754, Expected=18.2160
# Month=46, Predicted=17.5180, Expected=17.2110
# Month=47, Predicted=16.5600, Expected=16.6600
# Month=48, Predicted=16.2915, Expected=16.8310
# Month=49, Predicted=16.8606, Expected=15.7690
# Month=50, Predicted=15.7302, Expected=15.7310
# Month=51, Predicted=16.2977, Expected=15.9960
# Month=52, Predicted=16.7259, Expected=17.0210
# Month=53, Predicted=17.7300, Expected=17.5520
# Month=54, Predicted=17.9768, Expected=17.8370
# Month=55, Predicted=17.8378, Expected=17.8560
# Month=56, Predicted=17.6506, Expected=17.5710
# Month=57, Predicted=17.1409, Expected=17.0780
# Month=58, Predicted=16.4843, Expected=16.6600
# Month=59, Predicted=16.1884, Expected=16.4330
# Month=60, Predicted=16.1960, Expected=16.5840
# Run 13 — RMSE: 0.412270, MSE: 0.169966, NMSE: 0.0015791491
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2045, Expected=13.7000
# Month=2, Predicted=14.0584, Expected=13.8140
# Month=3, Predicted=14.5079, Expected=14.3830
# Month=4, Predicted=15.1656, Expected=15.0470
# Month=5, Predicted=15.4438, Expected=15.6930
# Month=6, Predicted=15.7576, Expected=15.8440
# Month=7, Predicted=15.6135, Expected=15.7120
# Month=8, Predicted=15.2032, Expected=15.3130
# Month=9, Predicted=14.6676, Expected=14.7630
# Month=10, Predicted=14.1865, Expected=13.5480
# Month=11, Predicted=12.9593, Expected=13.5860
# Month=12, Predicted=13.6101, Expected=14.5160
# Month=13, Predicted=14.6808, Expected=14.3830
# Month=14, Predicted=14.4192, Expected=14.4970
# Month=15, Predicted=15.2697, Expected=14.7440
# Month=16, Predicted=15.5328, Expected=15.8060
# Month=17, Predicted=16.2414, Expected=16.5270
# Month=18, Predicted=16.7477, Expected=16.5460
# Month=19, Predicted=16.1938, Expected=16.7170
# Month=20, Predicted=16.3366, Expected=16.4330
# Month=21, Predicted=15.9383, Expected=15.7690
# Month=22, Predicted=15.1092, Expected=15.2750
# Month=23, Predicted=14.9398, Expected=15.1230
# Month=24, Predicted=15.0658, Expected=15.5410
# Month=25, Predicted=15.7021, Expected=15.8250
# Month=26, Predicted=16.2466, Expected=16.3760
# Month=27, Predicted=17.2699, Expected=16.3570
# Month=28, Predicted=16.8555, Expected=16.9070
# Month=29, Predicted=17.0897, Expected=17.0210
# Month=30, Predicted=16.9811, Expected=17.4190
# Month=31, Predicted=17.1764, Expected=17.5330
# Month=32, Predicted=17.2186, Expected=17.2680
# Month=33, Predicted=16.7105, Expected=16.6030
# Month=34, Predicted=16.0476, Expected=15.8250
# Month=35, Predicted=15.4448, Expected=15.4460
# Month=36, Predicted=15.3616, Expected=15.6360
# Month=37, Predicted=15.8319, Expected=15.6930
# Month=38, Predicted=16.1544, Expected=16.7550
# Month=39, Predicted=17.7311, Expected=16.5090
# Month=40, Predicted=16.9807, Expected=17.7230
# Month=41, Predicted=17.8675, Expected=18.6910
# Month=42, Predicted=19.0341, Expected=19.1270
# Month=43, Predicted=18.8388, Expected=19.5640
# Month=44, Predicted=19.2187, Expected=19.2030
# Month=45, Predicted=18.6043, Expected=18.2160
# Month=46, Predicted=17.3355, Expected=17.2110
# Month=47, Predicted=16.6291, Expected=16.6600
# Month=48, Predicted=16.4779, Expected=16.8310
# Month=49, Predicted=16.9516, Expected=15.7690
# Month=50, Predicted=15.7404, Expected=15.7310
# Month=51, Predicted=16.5179, Expected=15.9960
# Month=52, Predicted=16.9685, Expected=17.0210
# Month=53, Predicted=17.7515, Expected=17.5520
# Month=54, Predicted=17.8112, Expected=17.8370
# Month=55, Predicted=17.6713, Expected=17.8560
# Month=56, Predicted=17.5501, Expected=17.5710
# Month=57, Predicted=17.0148, Expected=17.0780
# Month=58, Predicted=16.4152, Expected=16.6600
# Month=59, Predicted=16.2434, Expected=16.4330
# Month=60, Predicted=16.3065, Expected=16.5840
# Run 14 — RMSE: 0.416499, MSE: 0.173471, NMSE: 0.0015787249
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.2123, Expected=13.7000
# Month=2, Predicted=14.0067, Expected=13.8140
# Month=3, Predicted=14.4193, Expected=14.3830
# Month=4, Predicted=15.2617, Expected=15.0470
# Month=5, Predicted=15.4665, Expected=15.6930
# Month=6, Predicted=15.7754, Expected=15.8440
# Month=7, Predicted=15.6762, Expected=15.7120
# Month=8, Predicted=15.2716, Expected=15.3130
# Month=9, Predicted=14.7137, Expected=14.7630
# Month=10, Predicted=14.2685, Expected=13.5480
# Month=11, Predicted=12.9531, Expected=13.5860
# Month=12, Predicted=13.5849, Expected=14.5160
# Month=13, Predicted=14.6652, Expected=14.3830
# Month=14, Predicted=14.4794, Expected=14.4970
# Month=15, Predicted=15.4039, Expected=14.7440
# Month=16, Predicted=15.3519, Expected=15.8060
# Month=17, Predicted=16.0929, Expected=16.5270
# Month=18, Predicted=16.6607, Expected=16.5460
# Month=19, Predicted=16.2146, Expected=16.7170
# Month=20, Predicted=16.2826, Expected=16.4330
# Month=21, Predicted=16.0401, Expected=15.7690
# Month=22, Predicted=15.2851, Expected=15.2750
# Month=23, Predicted=15.0212, Expected=15.1230
# Month=24, Predicted=15.1540, Expected=15.5410
# Month=25, Predicted=15.7821, Expected=15.8250
# Month=26, Predicted=16.2926, Expected=16.3760
# Month=27, Predicted=17.3047, Expected=16.3570
# Month=28, Predicted=16.7851, Expected=16.9070
# Month=29, Predicted=16.9801, Expected=17.0210
# Month=30, Predicted=16.9797, Expected=17.4190
# Month=31, Predicted=17.2083, Expected=17.5330
# Month=32, Predicted=17.3028, Expected=17.2680
# Month=33, Predicted=16.9088, Expected=16.6030
# Month=34, Predicted=16.1866, Expected=15.8250
# Month=35, Predicted=15.5191, Expected=15.4460
# Month=36, Predicted=15.4816, Expected=15.6360
# Month=37, Predicted=15.9713, Expected=15.6930
# Month=38, Predicted=16.2399, Expected=16.7550
# Month=39, Predicted=17.7593, Expected=16.5090
# Month=40, Predicted=16.8956, Expected=17.7230
# Month=41, Predicted=17.7526, Expected=18.6910
# Month=42, Predicted=18.9435, Expected=19.1270
# Month=43, Predicted=18.8941, Expected=19.5640
# Month=44, Predicted=19.2050, Expected=19.2030
# Month=45, Predicted=18.7346, Expected=18.2160
# Month=46, Predicted=17.4997, Expected=17.2110
# Month=47, Predicted=16.6516, Expected=16.6600
# Month=48, Predicted=16.5434, Expected=16.8310
# Month=49, Predicted=17.0285, Expected=15.7690
# Month=50, Predicted=15.9772, Expected=15.7310
# Month=51, Predicted=16.7006, Expected=15.9960
# Month=52, Predicted=16.8393, Expected=17.0210
# Month=53, Predicted=17.5527, Expected=17.5520
# Month=54, Predicted=17.6705, Expected=17.8370
# Month=55, Predicted=17.6445, Expected=17.8560
# Month=56, Predicted=17.4967, Expected=17.5710
# Month=57, Predicted=16.9957, Expected=17.0780
# Month=58, Predicted=16.5598, Expected=16.6600
# Month=59, Predicted=16.3695, Expected=16.4330
# Month=60, Predicted=16.3597, Expected=16.5840
# Run 15 — RMSE: 0.443347, MSE: 0.196556, NMSE: 0.0018294401
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.2562, Expected=13.7000
# Month=2, Predicted=14.2194, Expected=13.8140
# Month=3, Predicted=14.5180, Expected=14.3830
# Month=4, Predicted=15.1053, Expected=15.0470
# Month=5, Predicted=15.4345, Expected=15.6930
# Month=6, Predicted=15.7167, Expected=15.8440
# Month=7, Predicted=15.5631, Expected=15.7120
# Month=8, Predicted=15.2756, Expected=15.3130
# Month=9, Predicted=14.7815, Expected=14.7630
# Month=10, Predicted=14.1903, Expected=13.5480
# Month=11, Predicted=12.9209, Expected=13.5860
# Month=12, Predicted=13.5758, Expected=14.5160
# Month=13, Predicted=14.7641, Expected=14.3830
# Month=14, Predicted=14.8559, Expected=14.4970
# Month=15, Predicted=15.2198, Expected=14.7440
# Month=16, Predicted=15.4277, Expected=15.8060
# Month=17, Predicted=16.2375, Expected=16.5270
# Month=18, Predicted=16.6097, Expected=16.5460
# Month=19, Predicted=16.2185, Expected=16.7170
# Month=20, Predicted=16.3681, Expected=16.4330
# Month=21, Predicted=15.9786, Expected=15.7690
# Month=22, Predicted=15.1285, Expected=15.2750
# Month=23, Predicted=14.8551, Expected=15.1230
# Month=24, Predicted=15.0263, Expected=15.5410
# Month=25, Predicted=15.7178, Expected=15.8250
# Month=26, Predicted=16.3149, Expected=16.3760
# Month=27, Predicted=17.1422, Expected=16.3570
# Month=28, Predicted=16.9790, Expected=16.9070
# Month=29, Predicted=17.2912, Expected=17.0210
# Month=30, Predicted=16.9993, Expected=17.4190
# Month=31, Predicted=17.2699, Expected=17.5330
# Month=32, Predicted=17.2726, Expected=17.2680
# Month=33, Predicted=16.8612, Expected=16.6030
# Month=34, Predicted=16.0098, Expected=15.8250
# Month=35, Predicted=15.3363, Expected=15.4460
# Month=36, Predicted=15.3045, Expected=15.6360
# Month=37, Predicted=15.7996, Expected=15.6930
# Month=38, Predicted=16.1594, Expected=16.7550
# Month=39, Predicted=17.5598, Expected=16.5090
# Month=40, Predicted=17.0917, Expected=17.7230
# Month=41, Predicted=18.1395, Expected=18.6910
# Month=42, Predicted=18.8549, Expected=19.1270
# Month=43, Predicted=18.9406, Expected=19.5640
# Month=44, Predicted=19.2829, Expected=19.2030
# Month=45, Predicted=18.7093, Expected=18.2160
# Month=46, Predicted=17.3945, Expected=17.2110
# Month=47, Predicted=16.5593, Expected=16.6600
# Month=48, Predicted=16.4217, Expected=16.8310
# Month=49, Predicted=16.9623, Expected=15.7690
# Month=50, Predicted=15.9139, Expected=15.7310
# Month=51, Predicted=16.3335, Expected=15.9960
# Month=52, Predicted=16.8212, Expected=17.0210
# Month=53, Predicted=17.7278, Expected=17.5520
# Month=54, Predicted=17.7588, Expected=17.8370
# Month=55, Predicted=17.6567, Expected=17.8560
# Month=56, Predicted=17.4736, Expected=17.5710
# Month=57, Predicted=17.0916, Expected=17.0780
# Month=58, Predicted=16.4756, Expected=16.6600
# Month=59, Predicted=16.1701, Expected=16.4330
# Month=60, Predicted=16.2027, Expected=16.5840
# Run 16 — RMSE: 0.404881, MSE: 0.163929, NMSE: 0.0014992786
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.2400, Expected=13.7000
# Month=2, Predicted=14.2585, Expected=13.8140
# Month=3, Predicted=14.4364, Expected=14.3830
# Month=4, Predicted=15.0484, Expected=15.0470
# Month=5, Predicted=15.4596, Expected=15.6930
# Month=6, Predicted=15.7811, Expected=15.8440
# Month=7, Predicted=15.5978, Expected=15.7120
# Month=8, Predicted=15.2232, Expected=15.3130
# Month=9, Predicted=14.6886, Expected=14.7630
# Month=10, Predicted=14.2210, Expected=13.5480
# Month=11, Predicted=12.9622, Expected=13.5860
# Month=12, Predicted=13.6617, Expected=14.5160
# Month=13, Predicted=14.8746, Expected=14.3830
# Month=14, Predicted=14.8099, Expected=14.4970
# Month=15, Predicted=15.1082, Expected=14.7440
# Month=16, Predicted=15.3483, Expected=15.8060
# Month=17, Predicted=16.3190, Expected=16.5270
# Month=18, Predicted=16.7375, Expected=16.5460
# Month=19, Predicted=16.2933, Expected=16.7170
# Month=20, Predicted=16.3854, Expected=16.4330
# Month=21, Predicted=15.8728, Expected=15.7690
# Month=22, Predicted=15.1711, Expected=15.2750
# Month=23, Predicted=14.9194, Expected=15.1230
# Month=24, Predicted=15.0384, Expected=15.5410
# Month=25, Predicted=15.8022, Expected=15.8250
# Month=26, Predicted=16.3443, Expected=16.3760
# Month=27, Predicted=17.0771, Expected=16.3570
# Month=28, Predicted=16.8182, Expected=16.9070
# Month=29, Predicted=17.2996, Expected=17.0210
# Month=30, Predicted=17.0509, Expected=17.4190
# Month=31, Predicted=17.3480, Expected=17.5330
# Month=32, Predicted=17.2839, Expected=17.2680
# Month=33, Predicted=16.7639, Expected=16.6030
# Month=34, Predicted=16.0797, Expected=15.8250
# Month=35, Predicted=15.4639, Expected=15.4460
# Month=36, Predicted=15.4099, Expected=15.6360
# Month=37, Predicted=15.9723, Expected=15.6930
# Month=38, Predicted=16.2009, Expected=16.7550
# Month=39, Predicted=17.5027, Expected=16.5090
# Month=40, Predicted=16.8674, Expected=17.7230
# Month=41, Predicted=18.1463, Expected=18.6910
# Month=42, Predicted=18.9824, Expected=19.1270
# ...
# Month=26, Predicted=16.3223, Expected=16.3760
# Month=27, Predicted=17.1955, Expected=16.3570
# Month=28, Predicted=16.8064, Expected=16.9070
# Month=29, Predicted=17.1376, Expected=17.0210
# Month=30, Predicted=16.9646, Expected=17.4190
# Month=31, Predicted=17.2359, Expected=17.5330
# Month=32, Predicted=17.2853, Expected=17.2680
# Month=33, Predicted=16.8735, Expected=16.6030
# Month=34, Predicted=16.1193, Expected=15.8250
# Month=35, Predicted=15.4393, Expected=15.4460
# Month=36, Predicted=15.4039, Expected=15.6360
# Month=37, Predicted=15.9298, Expected=15.6930
# Month=38, Predicted=16.2302, Expected=16.7550
# Month=39, Predicted=17.6740, Expected=16.5090
# Month=40, Predicted=16.9106, Expected=17.7230
# Month=41, Predicted=17.9928, Expected=18.6910
# Month=42, Predicted=18.9406, Expected=19.1270
# Month=43, Predicted=18.9928, Expected=19.5640
# Month=44, Predicted=19.2778, Expected=19.2030
# Month=45, Predicted=18.6875, Expected=18.2160
# Month=46, Predicted=17.4207, Expected=17.2110
# Month=47, Predicted=16.4628, Expected=16.6600
# Month=48, Predicted=16.3033, Expected=16.8310
# Month=49, Predicted=16.8225, Expected=15.7690
# Month=50, Predicted=15.6223, Expected=15.7310
# Month=51, Predicted=16.5086, Expected=15.9960
# Month=52, Predicted=16.7974, Expected=17.0210
# Month=53, Predicted=17.8860, Expected=17.5520
# Month=54, Predicted=17.9212, Expected=17.8370
# Month=55, Predicted=17.7790, Expected=17.8560
# Month=56, Predicted=17.5252, Expected=17.5710
# Month=57, Predicted=17.0517, Expected=17.0780
# Month=58, Predicted=16.4572, Expected=16.6600
# Month=59, Predicted=16.1217, Expected=16.4330
# Month=60, Predicted=16.1950, Expected=16.5840
# Run 25 — RMSE: 0.420782, MSE: 0.177058, NMSE: 0.0016207603
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.3191, Expected=13.7000
# Month=2, Predicted=14.2073, Expected=13.8140
# Month=3, Predicted=14.2959, Expected=14.3830
# Month=4, Predicted=14.9262, Expected=15.0470
# Month=5, Predicted=15.5107, Expected=15.6930
# Month=6, Predicted=15.9193, Expected=15.8440
# Month=7, Predicted=15.7402, Expected=15.7120
# Month=8, Predicted=15.3378, Expected=15.3130
# Month=9, Predicted=14.7897, Expected=14.7630
# Month=10, Predicted=14.2436, Expected=13.5480
# Month=11, Predicted=12.9020, Expected=13.5860
# Month=12, Predicted=13.4962, Expected=14.5160
# Month=13, Predicted=14.7687, Expected=14.3830
# Month=14, Predicted=14.6617, Expected=14.4970
# Month=15, Predicted=15.0157, Expected=14.7440
# Month=16, Predicted=15.2595, Expected=15.8060
# Month=17, Predicted=16.2567, Expected=16.5270
# Month=18, Predicted=16.7946, Expected=16.5460
# Month=19, Predicted=16.3499, Expected=16.7170
# Month=20, Predicted=16.4800, Expected=16.4330
# Month=21, Predicted=16.0058, Expected=15.7690
# Month=22, Predicted=15.1958, Expected=15.2750
# Month=23, Predicted=14.8453, Expected=15.1230
# Month=24, Predicted=14.9680, Expected=15.5410
# Month=25, Predicted=15.7237, Expected=15.8250
# Month=26, Predicted=16.2580, Expected=16.3760
# Month=27, Predicted=16.9944, Expected=16.3570
# Month=28, Predicted=16.7444, Expected=16.9070
# Month=29, Predicted=17.2191, Expected=17.0210
# Month=30, Predicted=17.0921, Expected=17.4190
# Month=31, Predicted=17.3608, Expected=17.5330
# Month=32, Predicted=17.4044, Expected=17.2680
# Month=33, Predicted=16.9579, Expected=16.6030
# Month=34, Predicted=16.1587, Expected=15.8250
# Month=35, Predicted=15.3870, Expected=15.4460
# Month=36, Predicted=15.2307, Expected=15.6360
# Month=37, Predicted=15.7439, Expected=15.6930
# Month=38, Predicted=16.0314, Expected=16.7550
# Month=39, Predicted=17.4449, Expected=16.5090
# Month=40, Predicted=16.8040, Expected=17.7230
# Month=41, Predicted=18.0456, Expected=18.6910
# Month=42, Predicted=19.0924, Expected=19.1270
# Month=43, Predicted=18.9918, Expected=19.5640
# Month=44, Predicted=19.3341, Expected=19.2030
# Month=45, Predicted=18.6506, Expected=18.2160
# Month=46, Predicted=17.3728, Expected=17.2110
# Month=47, Predicted=16.4107, Expected=16.6600
# Month=48, Predicted=16.1743, Expected=16.8310
# Month=49, Predicted=16.8452, Expected=15.7690
# Month=50, Predicted=15.7538, Expected=15.7310
# Month=51, Predicted=16.3042, Expected=15.9960
# Month=52, Predicted=16.6818, Expected=17.0210
# Month=53, Predicted=17.7368, Expected=17.5520
# Month=54, Predicted=17.9870, Expected=17.8370
# Month=55, Predicted=17.9256, Expected=17.8560
# Month=56, Predicted=17.7466, Expected=17.5710
# Month=57, Predicted=17.1712, Expected=17.0780
# Month=58, Predicted=16.4968, Expected=16.6600
# Month=59, Predicted=16.1735, Expected=16.4330
# Month=60, Predicted=16.1620, Expected=16.5840
# Run 26 — RMSE: 0.411467, MSE: 0.169305, NMSE: 0.0014791249
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.3593, Expected=13.7000
# Month=2, Predicted=14.1925, Expected=13.8140
# Month=3, Predicted=14.1602, Expected=14.3830
# Month=4, Predicted=14.7269, Expected=15.0470
# Month=5, Predicted=15.3701, Expected=15.6930
# Month=6, Predicted=15.8613, Expected=15.8440
# Month=7, Predicted=15.6936, Expected=15.7120
# Month=8, Predicted=15.3280, Expected=15.3130
# Month=9, Predicted=14.7933, Expected=14.7630
# Month=10, Predicted=14.2390, Expected=13.5480
# Month=11, Predicted=12.8744, Expected=13.5860
# Month=12, Predicted=13.4899, Expected=14.5160
# Month=13, Predicted=15.0920, Expected=14.3830
# Month=14, Predicted=14.8057, Expected=14.4970
# Month=15, Predicted=14.8136, Expected=14.7440
# Month=16, Predicted=15.0802, Expected=15.8060
# Month=17, Predicted=16.2102, Expected=16.5270
# Month=18, Predicted=16.8922, Expected=16.5460
# Month=19, Predicted=16.3909, Expected=16.7170
# Month=20, Predicted=16.5233, Expected=16.4330
# Month=21, Predicted=16.0194, Expected=15.7690
# Month=22, Predicted=15.1604, Expected=15.2750
# Month=23, Predicted=14.7967, Expected=15.1230
# Month=24, Predicted=14.9917, Expected=15.5410
# Month=25, Predicted=15.8477, Expected=15.8250
# Month=26, Predicted=16.2540, Expected=16.3760
# Month=27, Predicted=16.8216, Expected=16.3570
# Month=28, Predicted=16.5356, Expected=16.9070
# Month=29, Predicted=17.1194, Expected=17.0210
# Month=30, Predicted=17.0511, Expected=17.4190
# Month=31, Predicted=17.4137, Expected=17.5330
# Month=32, Predicted=17.4447, Expected=17.2680
# Month=33, Predicted=16.9837, Expected=16.6030
# Month=34, Predicted=16.1510, Expected=15.8250
# Month=35, Predicted=15.3457, Expected=15.4460
# Month=36, Predicted=15.2365, Expected=15.6360
# Month=37, Predicted=15.8823, Expected=15.6930
# Month=38, Predicted=16.0743, Expected=16.7550
# Month=39, Predicted=17.3252, Expected=16.5090
# Month=40, Predicted=16.7298, Expected=17.7230
# Month=41, Predicted=18.0379, Expected=18.6910
# Month=42, Predicted=19.2342, Expected=19.1270
# Month=43, Predicted=19.1444, Expected=19.5640
# Month=44, Predicted=19.4866, Expected=19.2030
# Month=45, Predicted=18.6949, Expected=18.2160
# Month=46, Predicted=17.3133, Expected=17.2110
# Month=47, Predicted=16.3116, Expected=16.6600
# Month=48, Predicted=16.1628, Expected=16.8310
# Month=49, Predicted=16.9330, Expected=15.7690
# Month=50, Predicted=15.6705, Expected=15.7310
# Month=51, Predicted=15.8765, Expected=15.9960
# Month=52, Predicted=16.5189, Expected=17.0210
# Month=53, Predicted=17.7227, Expected=17.5520
# Month=54, Predicted=18.1567, Expected=17.8370
# Month=55, Predicted=18.0728, Expected=17.8560
# Month=56, Predicted=17.8584, Expected=17.5710
# Month=57, Predicted=17.3072, Expected=17.0780
# Month=58, Predicted=16.6404, Expected=16.6600
# Month=59, Predicted=16.2799, Expected=16.4330
# Month=60, Predicted=16.2728, Expected=16.5840
# Run 27 — RMSE: 0.431984, MSE: 0.186610, NMSE: 0.0015592438
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.2597, Expected=13.7000
# Month=2, Predicted=14.1358, Expected=13.8140
# Month=3, Predicted=14.5365, Expected=14.3830
# Month=4, Predicted=15.1050, Expected=15.0470
# Month=5, Predicted=15.3915, Expected=15.6930
# Month=6, Predicted=15.7519, Expected=15.8440
# Month=7, Predicted=15.6517, Expected=15.7120
# Month=8, Predicted=15.2250, Expected=15.3130
# Month=9, Predicted=14.7352, Expected=14.7630
# Month=10, Predicted=14.2352, Expected=13.5480
# Month=11, Predicted=12.9283, Expected=13.5860
# Month=12, Predicted=13.6625, Expected=14.5160
# Month=13, Predicted=14.7656, Expected=14.3830
# Month=14, Predicted=14.5856, Expected=14.4970
# Month=15, Predicted=15.3505, Expected=14.7440
# Month=16, Predicted=15.4566, Expected=15.8060
# Month=17, Predicted=16.1947, Expected=16.5270
# Month=18, Predicted=16.7689, Expected=16.5460
# Month=19, Predicted=16.2296, Expected=16.7170
# Month=20, Predicted=16.3849, Expected=16.4330
# Month=21, Predicted=15.9385, Expected=15.7690
# Month=22, Predicted=15.1634, Expected=15.2750
# Month=23, Predicted=14.9460, Expected=15.1230
# Month=24, Predicted=15.0953, Expected=15.5410
# Month=25, Predicted=15.7699, Expected=15.8250
# Month=26, Predicted=16.3058, Expected=16.3760
# Month=27, Predicted=17.1984, Expected=16.3570
# Month=28, Predicted=16.8576, Expected=16.9070
# Month=29, Predicted=17.0651, Expected=17.0210
# Month=30, Predicted=16.9566, Expected=17.4190
# Month=31, Predicted=17.2769, Expected=17.5330
# Month=32, Predicted=17.2455, Expected=17.2680
# Month=33, Predicted=16.7821, Expected=16.6030
# Month=34, Predicted=16.1345, Expected=15.8250
# Month=35, Predicted=15.5133, Expected=15.4460
# Month=36, Predicted=15.4525, Expected=15.6360
# Month=37, Predicted=15.9416, Expected=15.6930
# Month=38, Predicted=16.1865, Expected=16.7550
# Month=39, Predicted=17.6013, Expected=16.5090
# Month=40, Predicted=16.9974, Expected=17.7230
# Month=41, Predicted=17.9411, Expected=18.6910
# Month=42, Predicted=19.1356, Expected=19.1270
# Month=43, Predicted=18.9538, Expected=19.5640
# Month=44, Predicted=19.3556, Expected=19.2030
# Month=45, Predicted=18.6207, Expected=18.2160
# Month=46, Predicted=17.4465, Expected=17.2110
# Month=47, Predicted=16.6001, Expected=16.6600
# Month=48, Predicted=16.4296, Expected=16.8310
# Month=49, Predicted=17.0007, Expected=15.7690
# Month=50, Predicted=15.6718, Expected=15.7310
# Month=51, Predicted=16.3525, Expected=15.9960
# Month=52, Predicted=16.8149, Expected=17.0210
# Month=53, Predicted=17.8153, Expected=17.5520
# Month=54, Predicted=17.9946, Expected=17.8370
# Month=55, Predicted=17.8091, Expected=17.8560
# Month=56, Predicted=17.6644, Expected=17.5710
# Month=57, Predicted=17.1166, Expected=17.0780
# Month=58, Predicted=16.4902, Expected=16.6600
# Month=59, Predicted=16.2299, Expected=16.4330
# Month=60, Predicted=16.2437, Expected=16.5840
# Run 28 — RMSE: 0.407838, MSE: 0.166332, NMSE: 0.0014964049
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.2975, Expected=13.7000
# Month=2, Predicted=14.1111, Expected=13.8140
# Month=3, Predicted=14.3914, Expected=14.3830
# Month=4, Predicted=15.1220, Expected=15.0470
# Month=5, Predicted=15.5762, Expected=15.6930
# Month=6, Predicted=15.7787, Expected=15.8440
# Month=7, Predicted=15.6389, Expected=15.7120
# Month=8, Predicted=15.2807, Expected=15.3130
# Month=9, Predicted=14.7037, Expected=14.7630
# Month=10, Predicted=14.1890, Expected=13.5480
# Month=11, Predicted=12.9513, Expected=13.5860
# Month=12, Predicted=13.5337, Expected=14.5160
# Month=13, Predicted=14.8241, Expected=14.3830
# Month=14, Predicted=14.6571, Expected=14.4970
# Month=15, Predicted=15.2047, Expected=14.7440
# Month=16, Predicted=15.4855, Expected=15.8060
# Month=17, Predicted=16.2507, Expected=16.5270
# Month=18, Predicted=16.6875, Expected=16.5460
# Month=19, Predicted=16.1670, Expected=16.7170
# Month=20, Predicted=16.3785, Expected=16.4330
# Month=21, Predicted=15.9080, Expected=15.7690
# Month=22, Predicted=15.1201, Expected=15.2750
# Month=23, Predicted=14.8977, Expected=15.1230
# Month=24, Predicted=15.0893, Expected=15.5410
# Month=25, Predicted=15.8102, Expected=15.8250
# Month=26, Predicted=16.2716, Expected=16.3760
# Month=27, Predicted=17.1082, Expected=16.3570
# Month=28, Predicted=16.9643, Expected=16.9070
# Month=29, Predicted=17.2152, Expected=17.0210
# Month=30, Predicted=17.0201, Expected=17.4190
# Month=31, Predicted=17.2474, Expected=17.5330
# Month=32, Predicted=17.3122, Expected=17.2680
# Month=33, Predicted=16.6909, Expected=16.6030
# Month=34, Predicted=16.0521, Expected=15.8250
# Month=35, Predicted=15.4128, Expected=15.4460
# Month=36, Predicted=15.3727, Expected=15.6360
# Month=37, Predicted=15.9292, Expected=15.6930
# Month=38, Predicted=16.1735, Expected=16.7550
# Month=39, Predicted=17.5710, Expected=16.5090
# Month=40, Predicted=17.0887, Expected=17.7230
# Month=41, Predicted=18.0236, Expected=18.6910
# Month=42, Predicted=19.0323, Expected=19.1270
# Month=43, Predicted=18.7400, Expected=19.5640
# Month=44, Predicted=19.2720, Expected=19.2030
# Month=45, Predicted=18.5459, Expected=18.2160
# Month=46, Predicted=17.3743, Expected=17.2110
# Month=47, Predicted=16.5905, Expected=16.6600
# Month=48, Predicted=16.4405, Expected=16.8310
# Month=49, Predicted=17.0306, Expected=15.7690
# Month=50, Predicted=15.9229, Expected=15.7310
# Month=51, Predicted=16.3067, Expected=15.9960
# Month=52, Predicted=16.8381, Expected=17.0210
# Month=53, Predicted=17.6855, Expected=17.5520
# Month=54, Predicted=17.8060, Expected=17.8370
# Month=55, Predicted=17.5937, Expected=17.8560
# Month=56, Predicted=17.5787, Expected=17.5710
# Month=57, Predicted=17.0640, Expected=17.0780
# Month=58, Predicted=16.4109, Expected=16.6600
# Month=59, Predicted=16.1951, Expected=16.4330
# Month=60, Predicted=16.2489, Expected=16.5840
# Run 29 — RMSE: 0.402462, MSE: 0.161976, NMSE: 0.0014989347
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.2705, Expected=13.7000
# Month=2, Predicted=14.1921, Expected=13.8140
# Month=3, Predicted=14.3930, Expected=14.3830
# Month=4, Predicted=14.9616, Expected=15.0470
# Month=5, Predicted=15.3732, Expected=15.6930
# Month=6, Predicted=15.7430, Expected=15.8440
# Month=7, Predicted=15.5889, Expected=15.7120
# Month=8, Predicted=15.2419, Expected=15.3130
# Month=9, Predicted=14.7017, Expected=14.7630
# Month=10, Predicted=14.1750, Expected=13.5480
# Month=11, Predicted=12.9610, Expected=13.5860
# Month=12, Predicted=13.4749, Expected=14.5160
# Month=13, Predicted=14.8397, Expected=14.3830
# Month=14, Predicted=14.8585, Expected=14.4970
# Month=15, Predicted=15.1082, Expected=14.7440
# Month=16, Predicted=15.2938, Expected=15.8060
# Month=17, Predicted=16.2353, Expected=16.5270
# Month=18, Predicted=16.6892, Expected=16.5460
# Month=19, Predicted=16.3346, Expected=16.7170
# Month=20, Predicted=16.3628, Expected=16.4330
# Month=21, Predicted=15.9294, Expected=15.7690
# Month=22, Predicted=15.1507, Expected=15.2750
# Month=23, Predicted=14.8378, Expected=15.1230
# Month=24, Predicted=14.9912, Expected=15.5410
# Month=25, Predicted=15.8167, Expected=15.8250
# Month=26, Predicted=16.3657, Expected=16.3760
# Month=27, Predicted=17.0914, Expected=16.3570
# Month=28, Predicted=16.8166, Expected=16.9070
# Month=29, Predicted=17.2496, Expected=17.0210
# Month=30, Predicted=17.0314, Expected=17.4190
# Month=31, Predicted=17.3154, Expected=17.5330
# Month=32, Predicted=17.3230, Expected=17.2680
# Month=33, Predicted=16.9492, Expected=16.6030
# Month=34, Predicted=16.2593, Expected=15.8250
# Month=35, Predicted=15.5582, Expected=15.4460
# Month=36, Predicted=15.4486, Expected=15.6360
# Month=37, Predicted=16.0104, Expected=15.6930
# Month=38, Predicted=16.2711, Expected=16.7550
# Month=39, Predicted=17.5470, Expected=16.5090
# Month=40, Predicted=16.9041, Expected=17.7230
# Month=41, Predicted=18.1208, Expected=18.6910
# Month=42, Predicted=18.8650, Expected=19.1270
# Month=43, Predicted=19.0178, Expected=19.5640
# Month=44, Predicted=19.3230, Expected=19.2030
# Month=45, Predicted=18.7057, Expected=18.2160
# Month=46, Predicted=17.3965, Expected=17.2110
# Month=47, Predicted=16.5096, Expected=16.6600
# Month=48, Predicted=16.2462, Expected=16.8310
# Month=49, Predicted=16.8354, Expected=15.7690
# Month=50, Predicted=15.7933, Expected=15.7310
# Month=51, Predicted=16.0991, Expected=15.9960
# Month=52, Predicted=16.5754, Expected=17.0210
# Month=53, Predicted=17.7632, Expected=17.5520
# Month=54, Predicted=17.9789, Expected=17.8370
# Month=55, Predicted=17.8936, Expected=17.8560
# Month=56, Predicted=17.5435, Expected=17.5710
# Month=57, Predicted=17.0358, Expected=17.0780
# Month=58, Predicted=16.4268, Expected=16.6600
# Month=59, Predicted=16.0923, Expected=16.4330
# Month=60, Predicted=16.0990, Expected=16.5840
# Run 30 — RMSE: 0.411590, MSE: 0.169406, NMSE: 0.0015123331

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Lake Erie Levels (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Lake Erie Levels (30 runs) =====
# RMSE: 0.418490 ± 0.015168
# MSE:  0.175364 ± 0.013051
# NMSE: 0.0015693771 ± 0.0001072715
#
# Best run: 17
#   RMSE: 0.394084
#   MSE:  0.155303
#   NMSE: 0.0013910745

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Feature Augmentation — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Feature Augmentation — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 0.394084
# MSE:  0.155303
# NMSE: 0.0013910745

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
