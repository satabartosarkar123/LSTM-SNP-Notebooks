# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: M4 Weekly
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 5469

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-04-25 09:22:34

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)
# Out:
# Forcing CPU execution (disabled GPU visibility).

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    496
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 505 (1.97 KB)
# Trainable params: 505 (1.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — M4 Weekly

# %%
# ============================================================
# 1. Load Time Series Data
series_df = pd.read_csv(
    '../../content/archive/Weekly-train.csv',
    nrows=1
)

# Extract the first series (dropping the 'V1' ID column and any NaNs)
raw_values = series_df.iloc[0, 1:].dropna().values.astype(float)
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (2179,)
# First 5 values: [1089.2  1078.91 1079.88 1063.58 1060.61]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (2178, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (2118, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (2118, 1, 2), y_train shape: (2118,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/2 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=39190.2019, Expected=39192.3600
# Month=2, Predicted=39309.5281, Expected=40597.3900
# Month=3, Predicted=40637.0485, Expected=40597.3900
# Month=4, Predicted=40699.5409, Expected=40995.0100
# Month=5, Predicted=41025.6044, Expected=40995.0100
# Month=6, Predicted=41040.2165, Expected=39530.0800
# Month=7, Predicted=39495.6252, Expected=39530.0800
# Month=8, Predicted=39987.7170, Expected=40556.7300
# Month=9, Predicted=40585.4141, Expected=40556.7300
# Month=10, Predicted=40658.8809, Expected=40676.2600
# Month=11, Predicted=40701.8051, Expected=40676.2600
# Month=12, Predicted=40698.5043, Expected=40494.5200
# Month=13, Predicted=40510.6052, Expected=40494.5200
# Month=14, Predicted=40526.8987, Expected=39996.7400
# Month=15, Predicted=40000.1038, Expected=39996.7400
# Month=16, Predicted=40078.1442, Expected=39324.7000
# Month=17, Predicted=39319.4368, Expected=39324.7000
# Month=18, Predicted=39449.4789, Expected=38867.2600
# Month=19, Predicted=38869.2989, Expected=38867.2600
# Month=20, Predicted=38940.2522, Expected=36379.6600
# Month=21, Predicted=36297.0769, Expected=36379.6600
# Month=22, Predicted=37516.6425, Expected=38543.0400
# Month=23, Predicted=38581.0334, Expected=38543.0400
# Month=24, Predicted=38528.4280, Expected=37987.6100
# Month=25, Predicted=37979.1754, Expected=37987.6100
# Month=26, Predicted=38082.0551, Expected=38806.2900
# Month=27, Predicted=38840.6459, Expected=38806.2900
# Month=28, Predicted=38908.4409, Expected=38814.1100
# Month=29, Predicted=38836.5655, Expected=38814.1100
# Month=30, Predicted=38835.8858, Expected=39440.6100
# Month=31, Predicted=39475.6968, Expected=39440.6100
# Month=32, Predicted=39527.8857, Expected=38559.3400
# Month=33, Predicted=38548.8007, Expected=38559.3400
# Month=34, Predicted=38751.0279, Expected=38886.2100
# Month=35, Predicted=38912.4814, Expected=38886.2100
# Month=36, Predicted=38922.6135, Expected=38672.6300
# Month=37, Predicted=38687.8726, Expected=38672.6300
# Month=38, Predicted=38708.1859, Expected=38314.7800
# Month=39, Predicted=38323.3753, Expected=38314.7800
# Month=40, Predicted=38369.7001, Expected=38262.3300
# Month=41, Predicted=38281.2128, Expected=38262.3300
# Month=42, Predicted=38285.9232, Expected=38698.1300
# Month=43, Predicted=38730.6664, Expected=38698.1300
# Month=44, Predicted=38748.9133, Expected=38619.7000
# Month=45, Predicted=38639.6741, Expected=38619.7000
# Month=46, Predicted=38644.5305, Expected=37171.8100
# Month=47, Predicted=37136.9227, Expected=37171.8100
# Month=48, Predicted=37620.1564, Expected=37828.6500
# Month=49, Predicted=37854.7874, Expected=37828.6500
# Month=50, Predicted=37923.0131, Expected=37894.9100
# Month=51, Predicted=37919.3872, Expected=37894.9100
# Month=52, Predicted=37916.3074, Expected=38264.0400
# Month=53, Predicted=38295.6876, Expected=38264.0400
# Month=54, Predicted=38305.4666, Expected=38126.4800
# Month=55, Predicted=38144.4219, Expected=38126.4800
# Month=56, Predicted=38155.1140, Expected=38429.9300
# Month=57, Predicted=38459.7016, Expected=38429.9300
# Month=58, Predicted=38463.8777, Expected=36565.1800
# Month=59, Predicted=36513.7360, Expected=36565.1800
# Month=60, Predicted=37263.7350, Expected=35397.1600
# Run 1 — RMSE: 649.500917, MSE: 421851.440764, NMSE: 0.0059113401, sMAPE: 0.898228
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=39153.8863, Expected=39192.3600
# Month=2, Predicted=39365.7128, Expected=40597.3900
# Month=3, Predicted=40570.2022, Expected=40597.3900
# Month=4, Predicted=40770.7428, Expected=40995.0100
# Month=5, Predicted=40963.2174, Expected=40995.0100
# Month=6, Predicted=41078.3680, Expected=39530.0800
# Month=7, Predicted=39488.5358, Expected=39530.0800
# Month=8, Predicted=39703.4328, Expected=40556.7300
# Month=9, Predicted=40526.9413, Expected=40556.7300
# Month=10, Predicted=40730.0828, Expected=40676.2600
# Month=11, Predicted=40643.2652, Expected=40676.2600
# Month=12, Predicted=40660.7678, Expected=40494.5200
# Month=13, Predicted=40459.5190, Expected=40494.5200
# Month=14, Predicted=40488.2498, Expected=39996.7400
# Month=15, Predicted=39959.2719, Expected=39996.7400
# Month=16, Predicted=40170.0928, Expected=39324.7000
# Month=17, Predicted=39286.1288, Expected=39324.7000
# Month=18, Predicted=39498.0528, Expected=38867.2600
# Month=19, Predicted=38829.9927, Expected=38867.2600
# Month=20, Predicted=39017.0405, Expected=36379.6600
# Month=21, Predicted=36341.5690, Expected=36379.6600
# Month=22, Predicted=36553.0128, Expected=38543.0400
# Month=23, Predicted=38518.6645, Expected=38543.0400
# Month=24, Predicted=38716.3928, Expected=37987.6100
# Month=25, Predicted=37945.3903, Expected=37987.6100
# Month=26, Predicted=38160.9628, Expected=38806.2900
# Month=27, Predicted=38777.2251, Expected=38806.2900
# Month=28, Predicted=38979.6428, Expected=38814.1100
# Month=29, Predicted=38780.4891, Expected=38814.1100
# Month=30, Predicted=38781.0618, Expected=39440.6100
# Month=31, Predicted=39411.0879, Expected=39440.6100
# Month=32, Predicted=39594.9588, Expected=38559.3400
# Month=33, Predicted=38519.3052, Expected=38559.3400
# Month=34, Predicted=38732.6928, Expected=38886.2100
# Month=35, Predicted=38854.9527, Expected=38886.2100
# Month=36, Predicted=38941.9853, Expected=38672.6300
# Month=37, Predicted=38637.3347, Expected=38672.6300
# Month=38, Predicted=38678.2253, Expected=38314.7800
# Month=39, Predicted=38278.3747, Expected=38314.7800
# Month=40, Predicted=38396.3592, Expected=38262.3300
# Month=41, Predicted=38228.4920, Expected=38262.3300
# Month=42, Predicted=38229.5436, Expected=38698.1300
# Month=43, Predicted=38667.8405, Expected=38698.1300
# Month=44, Predicted=38795.7909, Expected=38619.7000
# Month=45, Predicted=38585.5325, Expected=38619.7000
# Month=46, Predicted=38589.3733, Expected=37171.8100
# Month=47, Predicted=37130.4065, Expected=37171.8100
# Month=48, Predicted=37345.1628, Expected=37828.6500
# Month=49, Predicted=37798.0473, Expected=37828.6500
# Month=50, Predicted=37988.9548, Expected=37894.9100
# Month=51, Predicted=37861.8827, Expected=37894.9100
# Month=52, Predicted=37868.3942, Expected=38264.0400
# Month=53, Predicted=38233.3739, Expected=38264.0400
# Month=54, Predicted=38336.3924, Expected=38126.4800
# Month=55, Predicted=38091.8274, Expected=38126.4800
# Month=56, Predicted=38107.1538, Expected=38429.9300
# Month=57, Predicted=38398.8687, Expected=38429.9300
# Month=58, Predicted=38476.5221, Expected=36565.1800
# Month=59, Predicted=36523.9541, Expected=36565.1800
# Month=60, Predicted=36738.5328, Expected=35397.1600
# Run 2 — RMSE: 683.349459, MSE: 466966.482961, NMSE: 0.0061104144, sMAPE: 0.982884
#
# ===== RUN 3/2 =====
# Training complete for run 3
# Month=1, Predicted=39183.0322, Expected=39192.3600
# Month=2, Predicted=39479.5429, Expected=40597.3900
# Month=3, Predicted=40556.2519, Expected=40597.3900
# Month=4, Predicted=40840.8327, Expected=40995.0100
# Month=5, Predicted=40969.8545, Expected=40995.0100
# Month=6, Predicted=41042.7978, Expected=39530.0800
# Month=7, Predicted=39579.2390, Expected=39530.0800
# Month=8, Predicted=39948.3046, Expected=40556.7300
# Month=9, Predicted=40497.1567, Expected=40556.7300
# Month=10, Predicted=40766.7045, Expected=40676.2600
# Month=11, Predicted=40656.6894, Expected=40676.2600
# Month=12, Predicted=40670.5945, Expected=40494.5200
# Month=13, Predicted=40480.9582, Expected=40494.5200
# Month=14, Predicted=40475.4289, Expected=39996.7400
# Month=15, Predicted=39986.2042, Expected=39996.7400
# Month=16, Predicted=40223.4488, Expected=39324.7000
# Month=17, Predicted=39314.5613, Expected=39324.7000
# Month=18, Predicted=39620.6375, Expected=38867.2600
# Month=19, Predicted=38853.2791, Expected=38867.2600
# Month=20, Predicted=39072.2399, Expected=36379.6600
# Month=21, Predicted=36542.8276, Expected=36379.6600
# Month=22, Predicted=36874.5016, Expected=38543.0400
# Month=23, Predicted=38422.9722, Expected=38543.0400
# Month=24, Predicted=38651.9212, Expected=37987.6100
# Month=25, Predicted=37977.1665, Expected=37987.6100
# Month=26, Predicted=38240.7273, Expected=38806.2900
# Month=27, Predicted=38772.6370, Expected=38806.2900
# Month=28, Predicted=38970.0362, Expected=38814.1100
# Month=29, Predicted=38797.1729, Expected=38814.1100
# Month=30, Predicted=38797.7008, Expected=39440.6100
# Month=31, Predicted=39414.9356, Expected=39440.6100
# Month=32, Predicted=39551.0681, Expected=38559.3400
# Month=33, Predicted=38550.4335, Expected=38559.3400
# Month=34, Predicted=38906.5345, Expected=38886.2100
# Month=35, Predicted=38851.3052, Expected=38886.2100
# Month=36, Predicted=38917.1882, Expected=38672.6300
# Month=37, Predicted=38659.7904, Expected=38672.6300
# Month=38, Predicted=38682.2623, Expected=38314.7800
# Month=39, Predicted=38302.5268, Expected=38314.7800
# Month=40, Predicted=38456.9473, Expected=38262.3300
# Month=41, Predicted=38243.9455, Expected=38262.3300
# Month=42, Predicted=38242.8673, Expected=38698.1300
# Month=43, Predicted=38673.9198, Expected=38698.1300
# Month=44, Predicted=38755.6416, Expected=38619.7000
# Month=45, Predicted=38604.8539, Expected=38619.7000
# Month=46, Predicted=38599.6565, Expected=37171.8100
# Month=47, Predicted=37207.4720, Expected=37171.8100
# Month=48, Predicted=37588.5198, Expected=37828.6500
# Month=49, Predicted=37772.7518, Expected=37828.6500
# Month=50, Predicted=37947.7315, Expected=37894.9100
# Month=51, Predicted=37877.3537, Expected=37894.9100
# Month=52, Predicted=37883.3042, Expected=38264.0400
# Month=53, Predicted=38241.3717, Expected=38264.0400
# Month=54, Predicted=38304.8895, Expected=38126.4800
# Month=55, Predicted=38112.5571, Expected=38126.4800
# Month=56, Predicted=38106.2823, Expected=38429.9300
# Month=57, Predicted=38406.9534, Expected=38429.9300
# Month=58, Predicted=38455.8640, Expected=36565.1800
# Month=59, Predicted=36673.7753, Expected=36565.1800
# Month=60, Predicted=37015.2867, Expected=35397.1600
# Run 3 — RMSE: 669.546636, MSE: 448292.697398, NMSE: 0.0061392300, sMAPE: 0.942226
#
# ===== RUN 4/2 =====
# Training complete for run 4
# Month=1, Predicted=39199.2231, Expected=39192.3600
# Month=2, Predicted=39427.6586, Expected=40597.3900
# Month=3, Predicted=40604.2531, Expected=40597.3900
# Month=4, Predicted=40604.2531, Expected=40995.0100
# Month=5, Predicted=41001.8731, Expected=40995.0100
# Month=6, Predicted=41001.8731, Expected=39530.0800
# Month=7, Predicted=39541.1571, Expected=39530.0800
# Month=8, Predicted=39951.0788, Expected=40556.7300
# Month=9, Predicted=40563.5931, Expected=40556.7300
# Month=10, Predicted=40563.5931, Expected=40676.2600
# Month=11, Predicted=40683.1231, Expected=40676.2600
# Month=12, Predicted=40683.1231, Expected=40494.5200
# Month=13, Predicted=40501.3831, Expected=40494.5200
# Month=14, Predicted=40501.3831, Expected=39996.7400
# Month=15, Predicted=40003.6031, Expected=39996.7400
# Month=16, Predicted=40170.5814, Expected=39324.7000
# Month=17, Predicted=39331.5631, Expected=39324.7000
# Month=18, Predicted=39569.7079, Expected=38867.2600
# Month=19, Predicted=38874.1231, Expected=38867.2600
# Month=20, Predicted=39020.6632, Expected=36379.6600
# Month=21, Predicted=36516.4914, Expected=36379.6600
# Month=22, Predicted=36964.7089, Expected=38543.0400
# Month=23, Predicted=38549.9031, Expected=38543.0400
# Month=24, Predicted=38549.9031, Expected=37987.6100
# Month=25, Predicted=37994.4731, Expected=37987.6100
# Month=26, Predicted=38187.7814, Expected=38806.2900
# Month=27, Predicted=38813.1531, Expected=38806.2900
# Month=28, Predicted=38813.1531, Expected=38814.1100
# Month=29, Predicted=38820.9731, Expected=38814.1100
# Month=30, Predicted=38820.9731, Expected=39440.6100
# Month=31, Predicted=39447.4731, Expected=39440.6100
# Month=32, Predicted=39447.4731, Expected=38559.3400
# Month=33, Predicted=38566.2031, Expected=38559.3400
# Month=34, Predicted=38865.2265, Expected=38886.2100
# Month=35, Predicted=38893.0731, Expected=38886.2100
# Month=36, Predicted=38893.0731, Expected=38672.6300
# Month=37, Predicted=38679.4931, Expected=38672.6300
# Month=38, Predicted=38679.4931, Expected=38314.7800
# Month=39, Predicted=38321.6431, Expected=38314.7800
# Month=40, Predicted=38409.2732, Expected=38262.3300
# Month=41, Predicted=38269.1931, Expected=38262.3300
# Month=42, Predicted=38269.1931, Expected=38698.1300
# Month=43, Predicted=38704.9931, Expected=38698.1300
# Month=44, Predicted=38704.9931, Expected=38619.7000
# Month=45, Predicted=38626.5631, Expected=38619.7000
# Month=46, Predicted=38626.5631, Expected=37171.8100
# Month=47, Predicted=37180.1243, Expected=37171.8100
# Month=48, Predicted=37589.9051, Expected=37828.6500
# Month=49, Predicted=37835.5131, Expected=37828.6500
# Month=50, Predicted=37835.5131, Expected=37894.9100
# Month=51, Predicted=37901.7731, Expected=37894.9100
# Month=52, Predicted=37901.7731, Expected=38264.0400
# Month=53, Predicted=38270.9031, Expected=38264.0400
# Month=54, Predicted=38270.9031, Expected=38126.4800
# Month=55, Predicted=38133.3431, Expected=38126.4800
# Month=56, Predicted=38133.3431, Expected=38429.9300
# Month=57, Predicted=38436.7931, Expected=38429.9300
# Month=58, Predicted=38436.7931, Expected=36565.1800
# Month=59, Predicted=36631.5606, Expected=36565.1800
# Month=60, Predicted=37051.8563, Expected=35397.1600
# Run 4 — RMSE: 658.035116, MSE: 433010.213275, NMSE: 0.0060722702, sMAPE: 0.895416
#
# ===== RUN 5/2 =====
# Training complete for run 5
# Month=1, Predicted=39216.4018, Expected=39192.3600
# Month=2, Predicted=39243.9996, Expected=40597.3900
# Month=3, Predicted=40587.1319, Expected=40597.3900
# Month=4, Predicted=40893.5479, Expected=40995.0100
# Month=5, Predicted=40988.9784, Expected=40995.0100
# Month=6, Predicted=41050.0278, Expected=39530.0800
# Month=7, Predicted=39578.5273, Expected=39530.0800
# Month=8, Predicted=39581.7196, Expected=40556.7300
# Month=9, Predicted=40550.2301, Expected=40556.7300
# Month=10, Predicted=40806.3145, Expected=40676.2600
# Month=11, Predicted=40677.1609, Expected=40676.2600
# Month=12, Predicted=40686.5428, Expected=40494.5200
# Month=13, Predicted=40504.6168, Expected=40494.5200
# Month=14, Predicted=40508.0745, Expected=39996.7400
# Month=15, Predicted=40016.4225, Expected=39996.7400
# Month=16, Predicted=40048.3796, Expected=39324.7000
# Month=17, Predicted=39349.9103, Expected=39324.7000
# Month=18, Predicted=39376.3396, Expected=38867.2600
# Month=19, Predicted=38886.1399, Expected=38867.2600
# Month=20, Predicted=38918.8996, Expected=36379.6600
# Month=21, Predicted=36431.2996, Expected=36379.6600
# Month=22, Predicted=36431.4455, Expected=38543.0400
# Month=23, Predicted=38520.8880, Expected=38543.0400
# Month=24, Predicted=38675.5503, Expected=37987.6100
# Month=25, Predicted=38002.2647, Expected=37987.6100
# Month=26, Predicted=38039.2496, Expected=38806.2900
# Month=27, Predicted=38800.5625, Expected=38806.2900
# Month=28, Predicted=38992.9512, Expected=38814.1100
# Month=29, Predicted=38818.2351, Expected=38814.1100
# Month=30, Predicted=38819.5554, Expected=39440.6100
# Month=31, Predicted=39435.3892, Expected=39440.6100
# Month=32, Predicted=39562.2401, Expected=38559.3400
# Month=33, Predicted=38589.7932, Expected=38559.3400
# Month=34, Predicted=38610.9796, Expected=38886.2100
# Month=35, Predicted=38885.3904, Expected=38886.2100
# Month=36, Predicted=38925.5352, Expected=38672.6300
# Month=37, Predicted=38683.3511, Expected=38672.6300
# Month=38, Predicted=38689.3984, Expected=38314.7800
# Month=39, Predicted=38330.3428, Expected=38314.7800
# Month=40, Predicted=38351.9268, Expected=38262.3300
# Month=41, Predicted=38269.4764, Expected=38262.3300
# Month=42, Predicted=38268.2024, Expected=38698.1300
# Month=43, Predicted=38694.9363, Expected=38698.1300
# Month=44, Predicted=38762.7089, Expected=38619.7000
# Month=45, Predicted=38626.5421, Expected=38619.7000
# Month=46, Predicted=38626.4033, Expected=37171.8100
# Month=47, Predicted=37220.1755, Expected=37171.8100
# Month=48, Predicted=37223.4496, Expected=37828.6500
# Month=49, Predicted=37824.1902, Expected=37828.6500
# Month=50, Predicted=37960.3674, Expected=37894.9100
# Month=51, Predicted=37897.7913, Expected=37894.9100
# Month=52, Predicted=37901.9504, Expected=38264.0400
# Month=53, Predicted=38261.6308, Expected=38264.0400
# Month=54, Predicted=38312.4064, Expected=38126.4800
# Month=55, Predicted=38135.0150, Expected=38126.4800
# Month=56, Predicted=38136.4230, Expected=38429.9300
# Month=57, Predicted=38428.8737, Expected=38429.9300
# Month=58, Predicted=38464.6855, Expected=36565.1800
# Month=59, Predicted=36616.8196, Expected=36565.1800
# Month=60, Predicted=36616.8196, Expected=35397.1600
# Run 5 — RMSE: 682.330307, MSE: 465574.647418, NMSE: 0.0060199184, sMAPE: 0.956150
#
# ===== RUN 6/2 =====
# Training complete for run 6
# Month=1, Predicted=39146.6082, Expected=39192.3600
# Month=2, Predicted=39484.5045, Expected=40597.3900
# Month=3, Predicted=40534.9637, Expected=40597.3900
# Month=4, Predicted=40823.8274, Expected=40995.0100
# Month=5, Predicted=40924.2222, Expected=40995.0100
# Month=6, Predicted=41034.2510, Expected=39530.0800
# Month=7, Predicted=39492.5363, Expected=39530.0800
# Month=8, Predicted=39908.2140, Expected=40556.7300
# Month=9, Predicted=40477.9492, Expected=40556.7300
# Month=10, Predicted=40727.8656, Expected=40676.2600
# Month=11, Predicted=40612.5204, Expected=40676.2600
# Month=12, Predicted=40651.2325, Expected=40494.5200
# Month=13, Predicted=40442.5252, Expected=40494.5200
# Month=14, Predicted=40396.2847, Expected=39996.7400
# Month=15, Predicted=39949.1410, Expected=39996.7400
# Month=16, Predicted=40203.4880, Expected=39324.7000
# Month=17, Predicted=39277.8732, Expected=39324.7000
# Month=18, Predicted=39627.5143, Expected=38867.2600
# Month=19, Predicted=38815.9520, Expected=38867.2600
# Month=20, Predicted=39039.9221, Expected=36379.6600
# Month=21, Predicted=36578.7989, Expected=36379.6600
# Month=22, Predicted=36784.2311, Expected=38543.0400
# Month=23, Predicted=38418.2307, Expected=38543.0400
# Month=24, Predicted=38648.0341, Expected=37987.6100
# Month=25, Predicted=37909.5925, Expected=37987.6100
# Month=26, Predicted=38233.4384, Expected=38806.2900
# Month=27, Predicted=38746.5031, Expected=38806.2900
# Month=28, Predicted=38937.1259, Expected=38814.1100
# Month=29, Predicted=38753.2143, Expected=38814.1100
# Month=30, Predicted=38762.3669, Expected=39440.6100
# Month=31, Predicted=39383.0372, Expected=39440.6100
# Month=32, Predicted=39530.8573, Expected=38559.3400
# Month=33, Predicted=38511.3858, Expected=38559.3400
# Month=34, Predicted=38910.2791, Expected=38886.2100
# Month=35, Predicted=38823.8356, Expected=38886.2100
# Month=36, Predicted=38909.5460, Expected=38672.6300
# Month=37, Predicted=38619.6598, Expected=38672.6300
# Month=38, Predicted=38566.3651, Expected=38314.7800
# Month=39, Predicted=38265.4361, Expected=38314.7800
# Month=40, Predicted=38378.4280, Expected=38262.3300
# Month=41, Predicted=38209.0813, Expected=38262.3300
# Month=42, Predicted=38196.0993, Expected=38698.1300
# Month=43, Predicted=38641.4448, Expected=38698.1300
# Month=44, Predicted=38746.2784, Expected=38619.7000
# Month=45, Predicted=38564.2225, Expected=38619.7000
# Month=46, Predicted=38547.0339, Expected=37171.8100
# Month=47, Predicted=37136.6361, Expected=37171.8100
# Month=48, Predicted=37549.7936, Expected=37828.6500
# Month=49, Predicted=37751.1811, Expected=37828.6500
# Month=50, Predicted=37925.0922, Expected=37894.9100
# Month=51, Predicted=37835.3525, Expected=37894.9100
# Month=52, Predicted=37857.2797, Expected=38264.0400
# Month=53, Predicted=38207.3677, Expected=38264.0400
# Month=54, Predicted=38297.1243, Expected=38126.4800
# Month=55, Predicted=38072.3082, Expected=38126.4800
# Month=56, Predicted=38039.2192, Expected=38429.9300
# Month=57, Predicted=38374.0987, Expected=38429.9300
# Month=58, Predicted=38448.0264, Expected=36565.1800
# Month=59, Predicted=36588.2905, Expected=36565.1800
# Month=60, Predicted=36950.1863, Expected=35397.1600
# Run 6 — RMSE: 666.620368, MSE: 444382.714819, NMSE: 0.0060765337, sMAPE: 0.968263
#
# ===== RUN 7/2 =====
# Training complete for run 7
# Month=1, Predicted=39170.1914, Expected=39192.3600
# Month=2, Predicted=39364.1032, Expected=40597.3900
# Month=3, Predicted=40541.8222, Expected=40597.3900
# Month=4, Predicted=40857.1332, Expected=40995.0100
# Month=5, Predicted=40949.7537, Expected=40995.0100
# Month=6, Predicted=40992.7939, Expected=39530.0800
# Month=7, Predicted=39521.1084, Expected=39530.0800
# Month=8, Predicted=39921.5625, Expected=40556.7300
# Month=9, Predicted=40494.6584, Expected=40556.7300
# Month=10, Predicted=40774.4778, Expected=40676.2600
# Month=11, Predicted=40636.5044, Expected=40676.2600
# Month=12, Predicted=40618.3784, Expected=40494.5200
# Month=13, Predicted=40462.1794, Expected=40494.5200
# Month=14, Predicted=40508.4694, Expected=39996.7400
# Month=15, Predicted=39971.3621, Expected=39996.7400
# Month=16, Predicted=40122.8447, Expected=39324.7000
# Month=17, Predicted=39301.3051, Expected=39324.7000
# Month=18, Predicted=39504.7137, Expected=38867.2600
# Month=19, Predicted=38837.8083, Expected=38867.2600
# Month=20, Predicted=38980.3240, Expected=36379.6600
# Month=21, Predicted=36386.5194, Expected=36379.6600
# Month=22, Predicted=37015.9233, Expected=38543.0400
# Month=23, Predicted=38449.3011, Expected=38543.0400
# Month=24, Predicted=38552.0965, Expected=37987.6100
# Month=25, Predicted=37960.2810, Expected=37987.6100
# Month=26, Predicted=38132.0060, Expected=38806.2900
# Month=27, Predicted=38756.3958, Expected=38806.2900
# Month=28, Predicted=38955.2717, Expected=38814.1100
# Month=29, Predicted=38776.9219, Expected=38814.1100
# Month=30, Predicted=38776.0843, Expected=39440.6100
# Month=31, Predicted=39394.4638, Expected=39440.6100
# Month=32, Predicted=39517.7809, Expected=38559.3400
# Month=33, Predicted=38541.4119, Expected=38559.3400
# Month=34, Predicted=38799.4571, Expected=38886.2100
# Month=35, Predicted=38837.3617, Expected=38886.2100
# Month=36, Predicted=38862.7891, Expected=38672.6300
# Month=37, Predicted=38640.8252, Expected=38672.6300
# Month=38, Predicted=38697.2068, Expected=38314.7800
# Month=39, Predicted=38286.2240, Expected=38314.7800
# Month=40, Predicted=38393.2807, Expected=38262.3300
# Month=41, Predicted=38226.1478, Expected=38262.3300
# Month=42, Predicted=38238.5612, Expected=38698.1300
# Month=43, Predicted=38653.8831, Expected=38698.1300
# Month=44, Predicted=38708.1252, Expected=38619.7000
# Month=45, Predicted=38584.7172, Expected=38619.7000
# Month=46, Predicted=38602.7735, Expected=37171.8100
# Month=47, Predicted=37162.8057, Expected=37171.8100
# Month=48, Predicted=37559.0745, Expected=37828.6500
# Month=49, Predicted=37768.9579, Expected=37828.6500
# Month=50, Predicted=37917.1130, Expected=37894.9100
# Month=51, Predicted=37856.5697, Expected=37894.9100
# Month=52, Predicted=37845.3563, Expected=38264.0400
# Month=53, Predicted=38220.6339, Expected=38264.0400
# Month=54, Predicted=38253.0534, Expected=38126.4800
# Month=55, Predicted=38092.8972, Expected=38126.4800
# Month=56, Predicted=38126.5357, Expected=38429.9300
# Month=57, Predicted=38387.4868, Expected=38429.9300
# Month=58, Predicted=38399.9456, Expected=36565.1800
# Month=59, Predicted=36563.6661, Expected=36565.1800
# Month=60, Predicted=37053.9954, Expected=35397.1600
# Run 7 — RMSE: 653.869635, MSE: 427545.499775, NMSE: 0.0058737413, sMAPE: 0.920873
#
# ===== RUN 8/2 =====
# Training complete for run 8
# Month=1, Predicted=39142.1620, Expected=39192.3600
# Month=2, Predicted=39438.9486, Expected=40597.3900
# Month=3, Predicted=40534.8739, Expected=40597.3900
# Month=4, Predicted=40817.8489, Expected=40995.0100
# Month=5, Predicted=40927.9231, Expected=40995.0100
# Month=6, Predicted=41035.4286, Expected=39530.0800
# Month=7, Predicted=39489.2552, Expected=39530.0800
# Month=8, Predicted=39975.7739, Expected=40556.7300
# Month=9, Predicted=40491.8538, Expected=40556.7300
# Month=10, Predicted=40729.4313, Expected=40676.2600
# Month=11, Predicted=40611.1535, Expected=40676.2600
# Month=12, Predicted=40649.7538, Expected=40494.5200
# Month=13, Predicted=40439.2414, Expected=40494.5200
# Month=14, Predicted=40389.3296, Expected=39996.7400
# Month=15, Predicted=39944.8799, Expected=39996.7400
# Month=16, Predicted=40148.4990, Expected=39324.7000
# Month=17, Predicted=39274.4331, Expected=39324.7000
# Month=18, Predicted=39585.1001, Expected=38867.2600
# Month=19, Predicted=38814.1394, Expected=38867.2600
# Month=20, Predicted=38985.0744, Expected=36379.6600
# Month=21, Predicted=36581.3157, Expected=36379.6600
# Month=22, Predicted=37167.8186, Expected=38543.0400
# Month=23, Predicted=38467.0962, Expected=38543.0400
# Month=24, Predicted=38646.6883, Expected=37987.6100
# Month=25, Predicted=37937.1163, Expected=37987.6100
# Month=26, Predicted=38181.4767, Expected=38806.2900
# Month=27, Predicted=38745.2903, Expected=38806.2900
# Month=28, Predicted=38939.3603, Expected=38814.1100
# Month=29, Predicted=38751.4067, Expected=38814.1100
# Month=30, Predicted=38759.2350, Expected=39440.6100
# Month=31, Predicted=39380.4109, Expected=39440.6100
# Month=32, Predicted=39532.8437, Expected=38559.3400
# Month=33, Predicted=38508.0802, Expected=38559.3400
# Month=34, Predicted=38897.5465, Expected=38886.2100
# Month=35, Predicted=38825.7133, Expected=38886.2100
# Month=36, Predicted=38910.0516, Expected=38672.6300
# Month=37, Predicted=38617.0590, Expected=38672.6300
# Month=38, Predicted=38558.6583, Expected=38314.7800
# Month=39, Predicted=38261.4005, Expected=38314.7800
# Month=40, Predicted=38329.8836, Expected=38262.3300
# Month=41, Predicted=38205.7936, Expected=38262.3300
# Month=42, Predicted=38191.7806, Expected=38698.1300
# Month=43, Predicted=38638.5316, Expected=38698.1300
# Month=44, Predicted=38747.3987, Expected=38619.7000
# Month=45, Predicted=38562.1171, Expected=38619.7000
# Month=46, Predicted=38542.3009, Expected=37171.8100
# Month=47, Predicted=37131.7122, Expected=37171.8100
# Month=48, Predicted=37615.1374, Expected=37828.6500
# Month=49, Predicted=37764.4663, Expected=37828.6500
# Month=50, Predicted=37927.5198, Expected=37894.9100
# Month=51, Predicted=37833.4058, Expected=37894.9100
# Month=52, Predicted=37854.9921, Expected=38264.0400
# Month=53, Predicted=38204.6885, Expected=38264.0400
# Month=54, Predicted=38297.8224, Expected=38126.4800
# Month=55, Predicted=38070.0374, Expected=38126.4800
# Month=56, Predicted=38033.3051, Expected=38429.9300
# Month=57, Predicted=38370.9762, Expected=38429.9300
# Month=58, Predicted=38448.2210, Expected=36565.1800
# Month=59, Predicted=36604.3782, Expected=36565.1800
# Month=60, Predicted=37063.4856, Expected=35397.1600
# Run 8 — RMSE: 650.824225, MSE: 423572.172031, NMSE: 0.0059651081, sMAPE: 0.944728
#
# ===== RUN 9/2 =====
# Training complete for run 9
# Month=1, Predicted=39216.0939, Expected=39192.3600
# Month=2, Predicted=39244.2399, Expected=40597.3900
# Month=3, Predicted=40587.8347, Expected=40597.3900
# Month=4, Predicted=40934.6582, Expected=40995.0100
# Month=5, Predicted=40986.1854, Expected=40995.0100
# Month=6, Predicted=41048.8126, Expected=39530.0800
# Month=7, Predicted=39577.0478, Expected=39530.0800
# Month=8, Predicted=39581.9599, Expected=40556.7300
# Month=9, Predicted=40549.9650, Expected=40556.7300
# Month=10, Predicted=40808.1894, Expected=40676.2600
# Month=11, Predicted=40678.7851, Expected=40676.2600
# Month=12, Predicted=40688.1196, Expected=40494.5200
# Month=13, Predicted=40505.9641, Expected=40494.5200
# Month=14, Predicted=40508.0519, Expected=39996.7400
# Month=15, Predicted=40016.3213, Expected=39996.7400
# Month=16, Predicted=40048.6199, Expected=39324.7000
# Month=17, Predicted=39348.6733, Expected=39324.7000
# Month=18, Predicted=39376.5799, Expected=38867.2600
# Month=19, Predicted=38885.2288, Expected=38867.2600
# Month=20, Predicted=38919.1399, Expected=36379.6600
# Month=21, Predicted=36431.5399, Expected=36379.6600
# Month=22, Predicted=36431.5399, Expected=38543.0400
# Month=23, Predicted=38517.3577, Expected=38543.0400
# Month=24, Predicted=38685.2405, Expected=37987.6100
# Month=25, Predicted=37978.6356, Expected=37987.6100
# Month=26, Predicted=38039.4899, Expected=38806.2900
# Month=27, Predicted=38801.1272, Expected=38806.2900
# Month=28, Predicted=38986.9845, Expected=38814.1100
# Month=29, Predicted=38820.7548, Expected=38814.1100
# Month=30, Predicted=38820.9488, Expected=39440.6100
# Month=31, Predicted=39437.4994, Expected=39440.6100
# Month=32, Predicted=39556.8779, Expected=38559.3400
# Month=33, Predicted=38590.1390, Expected=38559.3400
# Month=34, Predicted=38611.2199, Expected=38886.2100
# Month=35, Predicted=38885.4864, Expected=38886.2100
# Month=36, Predicted=38925.4517, Expected=38672.6300
# Month=37, Predicted=38685.1679, Expected=38672.6300
# Month=38, Predicted=38689.0503, Expected=38314.7800
# Month=39, Predicted=38330.4703, Expected=38314.7800
# Month=40, Predicted=38349.9144, Expected=38262.3300
# Month=41, Predicted=38269.8017, Expected=38262.3300
# Month=42, Predicted=38269.2287, Expected=38698.1300
# Month=43, Predicted=38696.7638, Expected=38698.1300
# Month=44, Predicted=38760.8146, Expected=38619.7000
# Month=45, Predicted=38628.8374, Expected=38619.7000
# Month=46, Predicted=38627.2408, Expected=37171.8100
# Month=47, Predicted=37217.9066, Expected=37171.8100
# Month=48, Predicted=37223.6899, Expected=37828.6500
# Month=49, Predicted=37823.8863, Expected=37828.6500
# Month=50, Predicted=37954.5973, Expected=37894.9100
# Month=51, Predicted=37900.5050, Expected=37894.9100
# Month=52, Predicted=37903.5321, Expected=38264.0400
# Month=53, Predicted=38263.7011, Expected=38264.0400
# Month=54, Predicted=38311.6790, Expected=38126.4800
# Month=55, Predicted=38137.0822, Expected=38126.4800
# Month=56, Predicted=38136.8060, Expected=38429.9300
# Month=57, Predicted=38430.3397, Expected=38429.9300
# Month=58, Predicted=38464.9207, Expected=36565.1800
# Month=59, Predicted=36617.0599, Expected=36565.1800
# Month=60, Predicted=36617.0599, Expected=35397.1600
# Run 9 — RMSE: 682.188980, MSE: 465381.804817, NMSE: 0.0060011980, sMAPE: 0.953971
#
# ===== RUN 10/2 =====
# Training complete for run 10
# Month=1, Predicted=39092.5859, Expected=39192.3600
# Month=2, Predicted=39448.3582, Expected=40597.3900
# Month=3, Predicted=40524.0869, Expected=40597.3900
# Month=4, Predicted=40806.2628, Expected=40995.0100
# Month=5, Predicted=40897.6211, Expected=40995.0100
# Month=6, Predicted=41005.3472, Expected=39530.0800
# Month=7, Predicted=39407.9941, Expected=39530.0800
# Month=8, Predicted=39830.1149, Expected=40556.7300
# Month=9, Predicted=40494.4447, Expected=40556.7300
# Month=10, Predicted=40690.0704, Expected=40676.2600
# Month=11, Predicted=40575.9826, Expected=40676.2600
# Month=12, Predicted=40616.8273, Expected=40494.5200
# Month=13, Predicted=40398.6864, Expected=40494.5200
# Month=14, Predicted=40351.2696, Expected=39996.7400
# Month=15, Predicted=39900.2329, Expected=39996.7400
# Month=16, Predicted=40163.3986, Expected=39324.7000
# Month=17, Predicted=39229.8205, Expected=39324.7000
# Month=18, Predicted=39592.4876, Expected=38867.2600
# Month=19, Predicted=38778.8065, Expected=38867.2600
# Month=20, Predicted=38999.8618, Expected=36379.6600
# Month=21, Predicted=36468.8300, Expected=36379.6600
# Month=22, Predicted=36518.0752, Expected=38543.0400
# Month=23, Predicted=38503.7981, Expected=38543.0400
# Month=24, Predicted=38515.1808, Expected=37987.6100
# Month=25, Predicted=37876.7912, Expected=37987.6100
# Month=26, Predicted=38194.9962, Expected=38806.2900
# Month=27, Predicted=38729.0770, Expected=38806.2900
# Month=28, Predicted=38907.0008, Expected=38814.1100
# Month=29, Predicted=38712.4520, Expected=38814.1100
# Month=30, Predicted=38724.5765, Expected=39440.6100
# Month=31, Predicted=39354.8865, Expected=39440.6100
# Month=32, Predicted=39502.9817, Expected=38559.3400
# Month=33, Predicted=38444.5206, Expected=38559.3400
# Month=34, Predicted=38876.9836, Expected=38886.2100
# Month=35, Predicted=38811.7157, Expected=38886.2100
# Month=36, Predicted=38880.1400, Expected=38672.6300
# Month=37, Predicted=38573.2944, Expected=38672.6300
# Month=38, Predicted=38519.8509, Expected=38314.7800
# Month=39, Predicted=38220.9721, Expected=38314.7800
# Month=40, Predicted=38340.3350, Expected=38262.3300
# Month=41, Predicted=38174.9803, Expected=38262.3300
# Month=42, Predicted=38156.5298, Expected=38698.1300
# Month=43, Predicted=38612.2239, Expected=38698.1300
# Month=44, Predicted=38717.7726, Expected=38619.7000
# Month=45, Predicted=38520.8495, Expected=38619.7000
# Month=46, Predicted=38506.1732, Expected=37171.8100
# Month=47, Predicted=37057.3872, Expected=37171.8100
# Month=48, Predicted=37474.0309, Expected=37828.6500
# Month=49, Predicted=37765.0551, Expected=37828.6500
# Month=50, Predicted=37897.9898, Expected=37894.9100
# Month=51, Predicted=37795.1958, Expected=37894.9100
# Month=52, Predicted=37821.3090, Expected=38264.0400
# Month=53, Predicted=38175.8783, Expected=38264.0400
# Month=54, Predicted=38267.8028, Expected=38126.4800
# Month=55, Predicted=38027.6948, Expected=38126.4800
# Month=56, Predicted=37996.0175, Expected=38429.9300
# Month=57, Predicted=38344.0880, Expected=38429.9300
# Month=58, Predicted=38417.7811, Expected=36565.1800
# Month=59, Predicted=36481.6878, Expected=36565.1800
# Month=60, Predicted=36810.9499, Expected=35397.1600
# Run 10 — RMSE: 668.972855, MSE: 447524.680062, NMSE: 0.0059595731, sMAPE: 0.996286
#
# ===== RUN 11/2 =====
# Training complete for run 11
# Month=1, Predicted=39113.5787, Expected=39192.3600
# Month=2, Predicted=39403.8544, Expected=40597.3900
# Month=3, Predicted=40529.3381, Expected=40597.3900
# Month=4, Predicted=40814.7469, Expected=40995.0100
# Month=5, Predicted=40927.6975, Expected=40995.0100
# Month=6, Predicted=41031.9874, Expected=39530.0800
# Month=7, Predicted=39485.9370, Expected=39530.0800
# Month=8, Predicted=39923.8200, Expected=40556.7300
# Month=9, Predicted=40474.5270, Expected=40556.7300
# Month=10, Predicted=40716.1137, Expected=40676.2600
# Month=11, Predicted=40604.0774, Expected=40676.2600
# Month=12, Predicted=40640.8807, Expected=40494.5200
# Month=13, Predicted=40420.8448, Expected=40494.5200
# Month=14, Predicted=40361.3711, Expected=39996.7400
# Month=15, Predicted=39920.1351, Expected=39996.7400
# Month=16, Predicted=40127.8888, Expected=39324.7000
# Month=17, Predicted=39245.0158, Expected=39324.7000
# Month=18, Predicted=39548.7387, Expected=38867.2600
# Month=19, Predicted=38789.4652, Expected=38867.2600
# Month=20, Predicted=38971.8405, Expected=36379.6600
# Month=21, Predicted=36521.1743, Expected=36379.6600
# Month=22, Predicted=36801.2085, Expected=38543.0400
# Month=23, Predicted=38432.1826, Expected=38543.0400
# Month=24, Predicted=38630.0039, Expected=37987.6100
# Month=25, Predicted=37927.5723, Expected=37987.6100
# Month=26, Predicted=38153.3411, Expected=38806.2900
# Month=27, Predicted=38737.6572, Expected=38806.2900
# Month=28, Predicted=38929.3578, Expected=38814.1100
# Month=29, Predicted=38740.3946, Expected=38814.1100
# Month=30, Predicted=38744.9658, Expected=39440.6100
# Month=31, Predicted=39372.0266, Expected=39440.6100
# Month=32, Predicted=39526.9577, Expected=38559.3400
# Month=33, Predicted=38474.0175, Expected=38559.3400
# Month=34, Predicted=38858.1774, Expected=38886.2100
# Month=35, Predicted=38813.3997, Expected=38886.2100
# Month=36, Predicted=38906.1878, Expected=38672.6300
# Month=37, Predicted=38597.7882, Expected=38672.6300
# Month=38, Predicted=38571.4623, Expected=38314.7800
# Month=39, Predicted=38239.9800, Expected=38314.7800
# Month=40, Predicted=38344.6929, Expected=38262.3300
# Month=41, Predicted=38190.6069, Expected=38262.3300
# Month=42, Predicted=38173.7792, Expected=38698.1300
# Month=43, Predicted=38629.2016, Expected=38698.1300
# Month=44, Predicted=38743.8729, Expected=38619.7000
# Month=45, Predicted=38545.7859, Expected=38619.7000
# Month=46, Predicted=38522.4969, Expected=37171.8100
# Month=47, Predicted=37125.7039, Expected=37171.8100
# Month=48, Predicted=37564.1655, Expected=37828.6500
# Month=49, Predicted=37746.2302, Expected=37828.6500
# Month=50, Predicted=37920.9165, Expected=37894.9100
# Month=51, Predicted=37821.6861, Expected=37894.9100
# Month=52, Predicted=37843.7859, Expected=38264.0400
# Month=53, Predicted=38194.5077, Expected=38264.0400
# Month=54, Predicted=38294.2844, Expected=38126.4800
# Month=55, Predicted=38052.2482, Expected=38126.4800
# Month=56, Predicted=38009.0131, Expected=38429.9300
# Month=57, Predicted=38360.6231, Expected=38429.9300
# Month=58, Predicted=38444.1321, Expected=36565.1800
# Month=59, Predicted=36597.8923, Expected=36565.1800
# Month=60, Predicted=36979.0395, Expected=35397.1600
# Run 11 — RMSE: 662.145167, MSE: 438436.222081, NMSE: 0.0060440457, sMAPE: 0.976787
#
# ===== RUN 12/2 =====
# Training complete for run 12
# Month=1, Predicted=39202.5475, Expected=39192.3600
# Month=2, Predicted=39364.8803, Expected=40597.3900
# Month=3, Predicted=40604.3826, Expected=40597.3900
# Month=4, Predicted=40805.4871, Expected=40995.0100
# Month=5, Predicted=40998.8649, Expected=40995.0100
# Month=6, Predicted=41077.2391, Expected=39530.0800
# Month=7, Predicted=39550.9880, Expected=39530.0800
# Month=8, Predicted=39702.6003, Expected=40556.7300
# Month=9, Predicted=40563.2192, Expected=40556.7300
# Month=10, Predicted=40786.8583, Expected=40676.2600
# Month=11, Predicted=40682.3305, Expected=40676.2600
# Month=12, Predicted=40685.4411, Expected=40494.5200
# Month=13, Predicted=40501.6324, Expected=40494.5200
# Month=14, Predicted=40535.7266, Expected=39996.7400
# Month=15, Predicted=40005.7572, Expected=39996.7400
# Month=16, Predicted=40169.2603, Expected=39324.7000
# Month=17, Predicted=39335.3289, Expected=39324.7000
# Month=18, Predicted=39497.2203, Expected=38867.2600
# Month=19, Predicted=38876.2226, Expected=38867.2600
# Month=20, Predicted=39033.5885, Expected=36379.6600
# Month=21, Predicted=36424.3068, Expected=36379.6600
# Month=22, Predicted=36552.1803, Expected=38543.0400
# Month=23, Predicted=38550.9376, Expected=38543.0400
# Month=24, Predicted=38660.6160, Expected=37987.6100
# Month=25, Predicted=37982.8153, Expected=37987.6100
# Month=26, Predicted=38160.1303, Expected=38806.2900
# Month=27, Predicted=38812.9143, Expected=38806.2900
# Month=28, Predicted=39018.9898, Expected=38814.1100
# Month=29, Predicted=38820.5734, Expected=38814.1100
# Month=30, Predicted=38820.2700, Expected=39440.6100
# Month=31, Predicted=39446.9783, Expected=39440.6100
# Month=32, Predicted=39606.2613, Expected=38559.3400
# Month=33, Predicted=38571.6665, Expected=38559.3400
# Month=34, Predicted=38731.8603, Expected=38886.2100
# Month=35, Predicted=38892.8613, Expected=38886.2100
# Month=36, Predicted=38943.4097, Expected=38672.6300
# Month=37, Predicted=38679.7966, Expected=38672.6300
# Month=38, Predicted=38724.2972, Expected=38314.7800
# Month=39, Predicted=38322.8905, Expected=38314.7800
# Month=40, Predicted=38427.6957, Expected=38262.3300
# Month=41, Predicted=38269.2256, Expected=38262.3300
# Month=42, Predicted=38274.2912, Expected=38698.1300
# Month=43, Predicted=38704.4714, Expected=38698.1300
# Month=44, Predicted=38794.6797, Expected=38619.7000
# Month=45, Predicted=38626.3652, Expected=38619.7000
# Month=46, Predicted=38635.7400, Expected=37171.8100
# Month=47, Predicted=37192.6634, Expected=37171.8100
# Month=48, Predicted=37344.3303, Expected=37828.6500
# Month=49, Predicted=37835.0578, Expected=37828.6500
# Month=50, Predicted=38003.6897, Expected=37894.9100
# Month=51, Predicted=37901.2272, Expected=37894.9100
# Month=52, Predicted=37900.4270, Expected=38264.0400
# Month=53, Predicted=38270.3290, Expected=38264.0400
# Month=54, Predicted=38335.8856, Expected=38126.4800
# Month=55, Predicted=38133.3460, Expected=38126.4800
# Month=56, Predicted=38155.2277, Expected=38429.9300
# Month=57, Predicted=38436.2993, Expected=38429.9300
# Month=58, Predicted=38479.5232, Expected=36565.1800
# Month=59, Predicted=36593.9838, Expected=36565.1800
# Month=60, Predicted=36737.7003, Expected=35397.1600
# Run 12 — RMSE: 684.812366, MSE: 468967.976501, NMSE: 0.0061204383, sMAPE: 0.955064
#
# ===== RUN 13/2 =====
# Training complete for run 13
# Month=1, Predicted=39229.8751, Expected=39192.3600
# Month=2, Predicted=39229.8751, Expected=40597.3900
# Month=3, Predicted=40634.9051, Expected=40597.3900
# Month=4, Predicted=40634.9051, Expected=40995.0100
# Month=5, Predicted=41032.5251, Expected=40995.0100
# Month=6, Predicted=41032.5251, Expected=39530.0800
# Month=7, Predicted=39567.5951, Expected=39530.0800
# Month=8, Predicted=39567.5951, Expected=40556.7300
# Month=9, Predicted=40594.2451, Expected=40556.7300
# Month=10, Predicted=40594.2451, Expected=40676.2600
# Month=11, Predicted=40713.7751, Expected=40676.2600
# Month=12, Predicted=40713.7751, Expected=40494.5200
# Month=13, Predicted=40532.0351, Expected=40494.5200
# Month=14, Predicted=40532.0351, Expected=39996.7400
# Month=15, Predicted=40034.2551, Expected=39996.7400
# Month=16, Predicted=40034.2551, Expected=39324.7000
# Month=17, Predicted=39362.2151, Expected=39324.7000
# Month=18, Predicted=39362.2151, Expected=38867.2600
# Month=19, Predicted=38904.7751, Expected=38867.2600
# Month=20, Predicted=38904.7751, Expected=36379.6600
# Month=21, Predicted=36417.1837, Expected=36379.6600
# Month=22, Predicted=36417.1751, Expected=38543.0400
# Month=23, Predicted=38580.5551, Expected=38543.0400
# Month=24, Predicted=38580.5551, Expected=37987.6100
# Month=25, Predicted=38025.1251, Expected=37987.6100
# Month=26, Predicted=38025.1251, Expected=38806.2900
# Month=27, Predicted=38843.8051, Expected=38806.2900
# Month=28, Predicted=38843.8051, Expected=38814.1100
# Month=29, Predicted=38851.6251, Expected=38814.1100
# Month=30, Predicted=38851.6251, Expected=39440.6100
# Month=31, Predicted=39478.1251, Expected=39440.6100
# Month=32, Predicted=39478.1251, Expected=38559.3400
# Month=33, Predicted=38596.8551, Expected=38559.3400
# Month=34, Predicted=38596.8551, Expected=38886.2100
# Month=35, Predicted=38923.7251, Expected=38886.2100
# Month=36, Predicted=38923.7251, Expected=38672.6300
# Month=37, Predicted=38710.1451, Expected=38672.6300
# Month=38, Predicted=38710.1451, Expected=38314.7800
# Month=39, Predicted=38352.2951, Expected=38314.7800
# Month=40, Predicted=38352.2951, Expected=38262.3300
# Month=41, Predicted=38299.8451, Expected=38262.3300
# Month=42, Predicted=38299.8451, Expected=38698.1300
# Month=43, Predicted=38735.6451, Expected=38698.1300
# Month=44, Predicted=38735.6451, Expected=38619.7000
# Month=45, Predicted=38657.2151, Expected=38619.7000
# Month=46, Predicted=38657.2151, Expected=37171.8100
# Month=47, Predicted=37209.3251, Expected=37171.8100
# Month=48, Predicted=37209.3251, Expected=37828.6500
# Month=49, Predicted=37866.1651, Expected=37828.6500
# Month=50, Predicted=37866.1651, Expected=37894.9100
# Month=51, Predicted=37932.4251, Expected=37894.9100
# Month=52, Predicted=37932.4251, Expected=38264.0400
# Month=53, Predicted=38301.5551, Expected=38264.0400
# Month=54, Predicted=38301.5551, Expected=38126.4800
# Month=55, Predicted=38163.9951, Expected=38126.4800
# Month=56, Predicted=38163.9951, Expected=38429.9300
# Month=57, Predicted=38467.4451, Expected=38429.9300
# Month=58, Predicted=38467.4451, Expected=36565.1800
# Month=59, Predicted=36602.6951, Expected=36565.1800
# Month=60, Predicted=36602.6951, Expected=35397.1600
# Run 13 — RMSE: 680.368979, MSE: 462901.948255, NMSE: 0.0060666240, sMAPE: 0.975121
#
# ===== RUN 14/2 =====
# Training complete for run 14
# Month=1, Predicted=39229.8751, Expected=39192.3600
# Month=2, Predicted=39229.8751, Expected=40597.3900
# Month=3, Predicted=40634.9051, Expected=40597.3900
# Month=4, Predicted=40634.9051, Expected=40995.0100
# Month=5, Predicted=41032.5251, Expected=40995.0100
# Month=6, Predicted=41032.5251, Expected=39530.0800
# Month=7, Predicted=39567.5951, Expected=39530.0800
# Month=8, Predicted=39567.5951, Expected=40556.7300
# Month=9, Predicted=40594.2451, Expected=40556.7300
# Month=10, Predicted=40594.2451, Expected=40676.2600
# Month=11, Predicted=40713.7751, Expected=40676.2600
# Month=12, Predicted=40713.7751, Expected=40494.5200
# Month=13, Predicted=40532.0351, Expected=40494.5200
# Month=14, Predicted=40532.0351, Expected=39996.7400
# Month=15, Predicted=40034.2551, Expected=39996.7400
# Month=16, Predicted=40034.2551, Expected=39324.7000
# Month=17, Predicted=39362.2151, Expected=39324.7000
# Month=18, Predicted=39362.2151, Expected=38867.2600
# Month=19, Predicted=38904.7751, Expected=38867.2600
# Month=20, Predicted=38904.7751, Expected=36379.6600
# Month=21, Predicted=36417.1751, Expected=36379.6600
# Month=22, Predicted=36417.1751, Expected=38543.0400
# Month=23, Predicted=38580.5551, Expected=38543.0400
# Month=24, Predicted=38580.5551, Expected=37987.6100
# Month=25, Predicted=38025.1251, Expected=37987.6100
# Month=26, Predicted=38025.1251, Expected=38806.2900
# Month=27, Predicted=38843.8051, Expected=38806.2900
# Month=28, Predicted=38843.8051, Expected=38814.1100
# Month=29, Predicted=38851.6251, Expected=38814.1100
# Month=30, Predicted=38851.6251, Expected=39440.6100
# Month=31, Predicted=39478.1251, Expected=39440.6100
# Month=32, Predicted=39478.1251, Expected=38559.3400
# Month=33, Predicted=38596.8551, Expected=38559.3400
# Month=34, Predicted=38596.8551, Expected=38886.2100
# Month=35, Predicted=38923.7251, Expected=38886.2100
# Month=36, Predicted=38923.7251, Expected=38672.6300
# Month=37, Predicted=38710.1451, Expected=38672.6300
# Month=38, Predicted=38710.1451, Expected=38314.7800
# Month=39, Predicted=38352.2951, Expected=38314.7800
# Month=40, Predicted=38352.2951, Expected=38262.3300
# Month=41, Predicted=38299.8451, Expected=38262.3300
# Month=42, Predicted=38299.8451, Expected=38698.1300
# Month=43, Predicted=38735.6451, Expected=38698.1300
# Month=44, Predicted=38735.6451, Expected=38619.7000
# Month=45, Predicted=38657.2151, Expected=38619.7000
# Month=46, Predicted=38657.2151, Expected=37171.8100
# Month=47, Predicted=37209.3251, Expected=37171.8100
# Month=48, Predicted=37209.3251, Expected=37828.6500
# Month=49, Predicted=37866.1651, Expected=37828.6500
# Month=50, Predicted=37866.1651, Expected=37894.9100
# Month=51, Predicted=37932.4251, Expected=37894.9100
# Month=52, Predicted=37932.4251, Expected=38264.0400
# Month=53, Predicted=38301.5551, Expected=38264.0400
# Month=54, Predicted=38301.5551, Expected=38126.4800
# Month=55, Predicted=38163.9951, Expected=38126.4800
# Month=56, Predicted=38163.9951, Expected=38429.9300
# Month=57, Predicted=38467.4451, Expected=38429.9300
# Month=58, Predicted=38467.4451, Expected=36565.1800
# Month=59, Predicted=36602.6951, Expected=36565.1800
# Month=60, Predicted=36602.6951, Expected=35397.1600
# Run 14 — RMSE: 680.368972, MSE: 462901.937433, NMSE: 0.0060666207, sMAPE: 0.975121
#
# ===== RUN 15/2 =====
# Training complete for run 15
# Month=1, Predicted=39172.8426, Expected=39192.3600
# Month=2, Predicted=39373.6658, Expected=40597.3900
# Month=3, Predicted=40545.7280, Expected=40597.3900
# Month=4, Predicted=40795.1295, Expected=40995.0100
# Month=5, Predicted=40908.5744, Expected=40995.0100
# Month=6, Predicted=40999.5054, Expected=39530.0800
# Month=7, Predicted=39536.0421, Expected=39530.0800
# Month=8, Predicted=39925.0290, Expected=40556.7300
# Month=9, Predicted=40490.2967, Expected=40556.7300
# Month=10, Predicted=40770.1051, Expected=40676.2600
# Month=11, Predicted=40614.5414, Expected=40676.2600
# Month=12, Predicted=40623.2022, Expected=40494.5200
# Month=13, Predicted=40466.1391, Expected=40494.5200
# Month=14, Predicted=40512.5786, Expected=39996.7400
# Month=15, Predicted=39973.1182, Expected=39996.7400
# Month=16, Predicted=40130.2436, Expected=39324.7000
# Month=17, Predicted=39301.2297, Expected=39324.7000
# Month=18, Predicted=39514.6337, Expected=38867.2600
# Month=19, Predicted=38836.0182, Expected=38867.2600
# Month=20, Predicted=38987.0403, Expected=36379.6600
# Month=21, Predicted=36427.0968, Expected=36379.6600
# Month=22, Predicted=36977.6634, Expected=38543.0400
# Month=23, Predicted=38448.5602, Expected=38543.0400
# Month=24, Predicted=38539.4242, Expected=37987.6100
# Month=25, Predicted=37895.4917, Expected=37987.6100
# Month=26, Predicted=38141.6008, Expected=38806.2900
# Month=27, Predicted=38759.0369, Expected=38806.2900
# Month=28, Predicted=38970.2571, Expected=38814.1100
# Month=29, Predicted=38764.6122, Expected=38814.1100
# Month=30, Predicted=38779.9884, Expected=39440.6100
# Month=31, Predicted=39400.9753, Expected=39440.6100
# Month=32, Predicted=39534.2311, Expected=38559.3400
# Month=33, Predicted=38539.1706, Expected=38559.3400
# Month=34, Predicted=38810.6136, Expected=38886.2100
# Month=35, Predicted=38836.5779, Expected=38886.2100
# Month=36, Predicted=38865.7137, Expected=38672.6300
# Month=37, Predicted=38642.8056, Expected=38672.6300
# Month=38, Predicted=38701.5232, Expected=38314.7800
# Month=39, Predicted=38287.6032, Expected=38314.7800
# Month=40, Predicted=38398.5618, Expected=38262.3300
# Month=41, Predicted=38227.0038, Expected=38262.3300
# Month=42, Predicted=38242.5635, Expected=38698.1300
# Month=43, Predicted=38659.2516, Expected=38698.1300
# Month=44, Predicted=38716.8570, Expected=38619.7000
# Month=45, Predicted=38584.8710, Expected=38619.7000
# Month=46, Predicted=38606.6951, Expected=37171.8100
# Month=47, Predicted=37178.2182, Expected=37171.8100
# Month=48, Predicted=37562.8631, Expected=37828.6500
# Month=49, Predicted=37763.9823, Expected=37828.6500
# Month=50, Predicted=37934.2463, Expected=37894.9100
# Month=51, Predicted=37850.7080, Expected=37894.9100
# Month=52, Predicted=37849.5897, Expected=38264.0400
# Month=53, Predicted=38226.8366, Expected=38264.0400
# Month=54, Predicted=38258.2305, Expected=38126.4800
# Month=55, Predicted=38094.2830, Expected=38126.4800
# Month=56, Predicted=38130.4732, Expected=38429.9300
# Month=57, Predicted=38391.5862, Expected=38429.9300
# Month=58, Predicted=38401.5504, Expected=36565.1800
# Month=59, Predicted=36590.1763, Expected=36565.1800
# Month=60, Predicted=37044.4314, Expected=35397.1600
# Run 15 — RMSE: 656.404633, MSE: 430867.042868, NMSE: 0.0059585953, sMAPE: 0.934484
#
# ===== RUN 16/2 =====

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on M4 Weekly (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Hybrid (Feature Aug + Gate) — M4 Weekly\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Hybrid (Feature Aug + Gate) — M4 Weekly\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on M4 Weekly
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
