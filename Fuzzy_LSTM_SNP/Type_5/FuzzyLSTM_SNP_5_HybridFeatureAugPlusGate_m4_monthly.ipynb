# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: M4 Monthly
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 5433

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-04-25 09:22:27

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)
# Out:
# Forcing CPU execution (disabled GPU visibility).

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    496
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 505 (1.97 KB)
# Trainable params: 505 (1.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — M4 Monthly

# %%
# ============================================================
# 1. Load Time Series Data
series_df = pd.read_csv(
    '../../content/archive/Monthly-train.csv',
    nrows=1
)

# Extract the first series (dropping the 'V1' ID column and any NaNs)
raw_values = series_df.iloc[0, 1:].dropna().values.astype(float)
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (469,)
# First 5 values: [8000. 8350. 8570. 7700. 7080.]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (468, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (408, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (408, 1, 2), y_train shape: (408,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=9906.2429, Expected=11870.0000
# Month=2, Predicted=11377.0793, Expected=12920.0000
# Month=3, Predicted=12619.5097, Expected=10890.0000
# Month=4, Predicted=11491.9532, Expected=9500.0000
# Month=5, Predicted=9379.1004, Expected=9490.0000
# Month=6, Predicted=9853.6545, Expected=9500.0000
# Month=7, Predicted=9677.2302, Expected=10880.0000
# Month=8, Predicted=10895.5463, Expected=9270.0000
# Month=9, Predicted=9824.8516, Expected=8880.0000
# Month=10, Predicted=8885.4362, Expected=7780.0000
# Month=11, Predicted=8099.4094, Expected=8360.0000
# Month=12, Predicted=8527.4927, Expected=12320.0000
# Month=13, Predicted=13142.5997, Expected=13490.0000
# Month=14, Predicted=12788.6763, Expected=12710.0000
# Month=15, Predicted=12074.5429, Expected=10130.0000
# Month=16, Predicted=10090.3434, Expected=9240.0000
# Month=17, Predicted=9164.4735, Expected=9640.0000
# Month=18, Predicted=10153.4959, Expected=8920.0000
# Month=19, Predicted=8827.9331, Expected=8900.0000
# Month=20, Predicted=9002.0230, Expected=8480.0000
# Month=21, Predicted=8610.4742, Expected=7870.0000
# Month=22, Predicted=7989.3580, Expected=7860.0000
# Month=23, Predicted=8027.4791, Expected=8990.0000
# Month=24, Predicted=9056.1595, Expected=10790.0000
# Month=25, Predicted=10750.1504, Expected=11820.0000
# Month=26, Predicted=11511.7439, Expected=10590.0000
# Month=27, Predicted=10629.3863, Expected=9430.0000
# Month=28, Predicted=9452.4383, Expected=9070.0000
# Month=29, Predicted=9324.4642, Expected=8250.0000
# Month=30, Predicted=8501.9846, Expected=8740.0000
# Month=31, Predicted=8910.8184, Expected=9120.0000
# Month=32, Predicted=9070.1303, Expected=8280.0000
# Month=33, Predicted=8045.0229, Expected=7860.0000
# Month=34, Predicted=7958.6858, Expected=7150.0000
# Month=35, Predicted=7357.3215, Expected=8110.0000
# Month=36, Predicted=8284.1050, Expected=10860.0000
# Month=37, Predicted=11317.4730, Expected=10730.0000
# Month=38, Predicted=10891.2424, Expected=9610.0000
# Month=39, Predicted=9525.1083, Expected=8270.0000
# Month=40, Predicted=8352.1945, Expected=9200.0000
# Month=41, Predicted=9433.7026, Expected=6660.0000
# Month=42, Predicted=7861.4292, Expected=6270.0000
# Month=43, Predicted=6133.0077, Expected=7250.0000
# Month=44, Predicted=7735.0380, Expected=6830.0000
# Month=45, Predicted=6482.6814, Expected=6810.0000
# Month=46, Predicted=6882.1455, Expected=5810.0000
# Month=47, Predicted=5839.6331, Expected=6220.0000
# Month=48, Predicted=6353.3151, Expected=7450.0000
# Month=49, Predicted=7578.4170, Expected=9370.0000
# Month=50, Predicted=9272.6290, Expected=7980.0000
# Month=51, Predicted=8265.7986, Expected=6050.0000
# Month=52, Predicted=5983.5149, Expected=5640.0000
# Month=53, Predicted=5807.4375, Expected=6220.0000
# Month=54, Predicted=6595.3920, Expected=5740.0000
# Month=55, Predicted=5477.2094, Expected=6040.0000
# Month=56, Predicted=6120.6508, Expected=5130.0000
# Month=57, Predicted=5041.4579, Expected=5090.0000
# Month=58, Predicted=5197.9402, Expected=5210.0000
# Month=59, Predicted=5305.7803, Expected=4910.0000
# Month=60, Predicted=4853.9432, Expected=6890.0000
# Run 1 — RMSE: 1252.206961, MSE: 1568022.272494, NMSE: 0.0062845175, sMAPE: 11.669393
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=9896.1656, Expected=11870.0000
# Month=2, Predicted=11043.3652, Expected=12920.0000
# Month=3, Predicted=12411.6543, Expected=10890.0000
# Month=4, Predicted=11150.1438, Expected=9500.0000
# Month=5, Predicted=9419.3206, Expected=9490.0000
# Month=6, Predicted=9907.5973, Expected=9500.0000
# Month=7, Predicted=9771.7862, Expected=10880.0000
# Month=8, Predicted=10939.6389, Expected=9270.0000
# Month=9, Predicted=9615.6232, Expected=8880.0000
# Month=10, Predicted=8836.8284, Expected=7780.0000
# Month=11, Predicted=8045.9123, Expected=8360.0000
# Month=12, Predicted=8518.7111, Expected=12320.0000
# Month=13, Predicted=12570.9057, Expected=13490.0000
# Month=14, Predicted=13485.5630, Expected=12710.0000
# Month=15, Predicted=12407.1768, Expected=10130.0000
# Month=16, Predicted=9967.4133, Expected=9240.0000
# Month=17, Predicted=9390.5027, Expected=9640.0000
# Month=18, Predicted=10275.6815, Expected=8920.0000
# Month=19, Predicted=8872.7495, Expected=8900.0000
# Month=20, Predicted=8955.9293, Expected=8480.0000
# Month=21, Predicted=8587.4802, Expected=7870.0000
# Month=22, Predicted=7909.4815, Expected=7860.0000
# Month=23, Predicted=7985.0147, Expected=8990.0000
# Month=24, Predicted=9113.8808, Expected=10790.0000
# Month=25, Predicted=10460.5149, Expected=11820.0000
# Month=26, Predicted=11200.5610, Expected=10590.0000
# Month=27, Predicted=10502.6331, Expected=9430.0000
# Month=28, Predicted=9378.4711, Expected=9070.0000
# Month=29, Predicted=9314.4909, Expected=8250.0000
# Month=30, Predicted=8444.5169, Expected=8740.0000
# Month=31, Predicted=8885.2775, Expected=9120.0000
# Month=32, Predicted=9153.9925, Expected=8280.0000
# Month=33, Predicted=7978.8797, Expected=7860.0000
# Month=34, Predicted=7905.1614, Expected=7150.0000
# Month=35, Predicted=7284.1527, Expected=8110.0000
# Month=36, Predicted=8255.6156, Expected=10860.0000
# Month=37, Predicted=10901.6546, Expected=10730.0000
# Month=38, Predicted=10918.1683, Expected=9610.0000
# Month=39, Predicted=9330.6009, Expected=8270.0000
# Month=40, Predicted=8312.4074, Expected=9200.0000
# Month=41, Predicted=9446.2007, Expected=6660.0000
# Month=42, Predicted=7409.0834, Expected=6270.0000
# Month=43, Predicted=6256.7251, Expected=7250.0000
# Month=44, Predicted=7877.1085, Expected=6830.0000
# Month=45, Predicted=6561.0420, Expected=6810.0000
# Month=46, Predicted=6805.5932, Expected=5810.0000
# Month=47, Predicted=5778.7497, Expected=6220.0000
# Month=48, Predicted=6331.7850, Expected=7450.0000
# Month=49, Predicted=7598.4858, Expected=9370.0000
# Month=50, Predicted=8925.0993, Expected=7980.0000
# Month=51, Predicted=8410.3110, Expected=6050.0000
# Month=52, Predicted=5868.3005, Expected=5640.0000
# Month=53, Predicted=5900.5181, Expected=6220.0000
# Month=54, Predicted=6669.4772, Expected=5740.0000
# Month=55, Predicted=5515.7489, Expected=6040.0000
# Month=56, Predicted=6069.1087, Expected=5130.0000
# Month=57, Predicted=4978.8093, Expected=5090.0000
# Month=58, Predicted=5163.6641, Expected=5210.0000
# Month=59, Predicted=5363.9962, Expected=4910.0000
# Month=60, Predicted=4900.5270, Expected=6890.0000
# Run 2 — RMSE: 1246.870015, MSE: 1554684.833851, NMSE: 0.0063955284, sMAPE: 11.453623
#
# ===== RUN 3/2 =====
# Training complete for run 3
# Month=1, Predicted=9889.5266, Expected=11870.0000
# Month=2, Predicted=11151.3952, Expected=12920.0000
# Month=3, Predicted=12381.8941, Expected=10890.0000
# Month=4, Predicted=11175.5721, Expected=9500.0000
# Month=5, Predicted=9505.7723, Expected=9490.0000
# Month=6, Predicted=9913.1960, Expected=9500.0000
# Month=7, Predicted=9756.5575, Expected=10880.0000
# Month=8, Predicted=10909.1504, Expected=9270.0000
# Month=9, Predicted=9526.9659, Expected=8880.0000
# Month=10, Predicted=8970.5554, Expected=7780.0000
# Month=11, Predicted=8141.7439, Expected=8360.0000
# Month=12, Predicted=8525.7040, Expected=12320.0000
# Month=13, Predicted=13064.3768, Expected=13490.0000
# Month=14, Predicted=13778.5247, Expected=12710.0000
# Month=15, Predicted=11798.1950, Expected=10130.0000
# Month=16, Predicted=10076.9131, Expected=9240.0000
# Month=17, Predicted=9381.2196, Expected=9640.0000
# Month=18, Predicted=10301.0175, Expected=8920.0000
# Month=19, Predicted=8870.4753, Expected=8900.0000
# Month=20, Predicted=9033.0852, Expected=8480.0000
# Month=21, Predicted=8595.1084, Expected=7870.0000
# Month=22, Predicted=7986.2253, Expected=7860.0000
# Month=23, Predicted=8027.8210, Expected=8990.0000
# Month=24, Predicted=9080.9295, Expected=10790.0000
# Month=25, Predicted=10667.6464, Expected=11820.0000
# Month=26, Predicted=11394.7546, Expected=10590.0000
# Month=27, Predicted=10553.0754, Expected=9430.0000
# Month=28, Predicted=9521.2653, Expected=9070.0000
# Month=29, Predicted=9324.9164, Expected=8250.0000
# Month=30, Predicted=8514.3592, Expected=8740.0000
# Month=31, Predicted=8909.4542, Expected=9120.0000
# Month=32, Predicted=9129.2552, Expected=8280.0000
# Month=33, Predicted=8033.7218, Expected=7860.0000
# Month=34, Predicted=7988.9460, Expected=7150.0000
# Month=35, Predicted=7355.4073, Expected=8110.0000
# Month=36, Predicted=8283.9378, Expected=10860.0000
# Month=37, Predicted=11299.8677, Expected=10730.0000
# Month=38, Predicted=11233.1315, Expected=9610.0000
# Month=39, Predicted=9504.9555, Expected=8270.0000
# Month=40, Predicted=8372.5202, Expected=9200.0000
# Month=41, Predicted=9429.3743, Expected=6660.0000
# Month=42, Predicted=7576.3650, Expected=6270.0000
# Month=43, Predicted=6425.6889, Expected=7250.0000
# Month=44, Predicted=7922.3716, Expected=6830.0000
# Month=45, Predicted=6603.0673, Expected=6810.0000
# Month=46, Predicted=6912.0732, Expected=5810.0000
# Month=47, Predicted=5812.3860, Expected=6220.0000
# Month=48, Predicted=6364.7992, Expected=7450.0000
# Month=49, Predicted=7641.8235, Expected=9370.0000
# Month=50, Predicted=9200.6116, Expected=7980.0000
# Month=51, Predicted=8375.1070, Expected=6050.0000
# Month=52, Predicted=6075.9381, Expected=5640.0000
# Month=53, Predicted=5845.6231, Expected=6220.0000
# Month=54, Predicted=6691.9117, Expected=5740.0000
# Month=55, Predicted=5517.7356, Expected=6040.0000
# Month=56, Predicted=6158.7195, Expected=5130.0000
# Month=57, Predicted=5013.2631, Expected=5090.0000
# Month=58, Predicted=5225.9930, Expected=5210.0000
# Month=59, Predicted=5350.3733, Expected=4910.0000
# Month=60, Predicted=4854.9416, Expected=6890.0000
# Run 3 — RMSE: 1245.805519, MSE: 1552031.390723, NMSE: 0.0062338708, sMAPE: 11.621593
#
# ===== RUN 4/2 =====
# Training complete for run 4
# Month=1, Predicted=9692.4682, Expected=11870.0000
# Month=2, Predicted=11629.6602, Expected=12920.0000
# Month=3, Predicted=12418.7254, Expected=10890.0000
# Month=4, Predicted=11368.3335, Expected=9500.0000
# Month=5, Predicted=9532.4682, Expected=9490.0000
# Month=6, Predicted=9522.4682, Expected=9500.0000
# Month=7, Predicted=9532.4682, Expected=10880.0000
# Month=8, Predicted=10912.4682, Expected=9270.0000
# Month=9, Predicted=9735.7966, Expected=8880.0000
# Month=10, Predicted=8912.4682, Expected=7780.0000
# Month=11, Predicted=7812.4682, Expected=8360.0000
# Month=12, Predicted=8392.4682, Expected=12320.0000
# Month=13, Predicted=12913.8866, Expected=13490.0000
# Month=14, Predicted=13682.3149, Expected=12710.0000
# Month=15, Predicted=12207.9522, Expected=10130.0000
# Month=16, Predicted=10150.9873, Expected=9240.0000
# Month=17, Predicted=9272.4682, Expected=9640.0000
# Month=18, Predicted=9672.4682, Expected=8920.0000
# Month=19, Predicted=8689.1546, Expected=8900.0000
# Month=20, Predicted=8932.4682, Expected=8480.0000
# Month=21, Predicted=8512.4682, Expected=7870.0000
# Month=22, Predicted=7902.4682, Expected=7860.0000
# Month=23, Predicted=7892.4682, Expected=8990.0000
# Month=24, Predicted=9022.4682, Expected=10790.0000
# Month=25, Predicted=10912.9227, Expected=11820.0000
# Month=26, Predicted=11278.7070, Expected=10590.0000
# Month=27, Predicted=10553.8047, Expected=9430.0000
# Month=28, Predicted=9462.4682, Expected=9070.0000
# Month=29, Predicted=9102.4682, Expected=8250.0000
# Month=30, Predicted=8282.4682, Expected=8740.0000
# Month=31, Predicted=8772.4682, Expected=9120.0000
# Month=32, Predicted=9029.1854, Expected=8280.0000
# Month=33, Predicted=8043.4928, Expected=7860.0000
# Month=34, Predicted=7892.4682, Expected=7150.0000
# Month=35, Predicted=7182.4682, Expected=8110.0000
# Month=36, Predicted=8142.4682, Expected=10860.0000
# Month=37, Predicted=11491.2476, Expected=10730.0000
# Month=38, Predicted=10912.8653, Expected=9610.0000
# Month=39, Predicted=9514.6966, Expected=8270.0000
# Month=40, Predicted=8302.4682, Expected=9200.0000
# Month=41, Predicted=9232.4682, Expected=6660.0000
# Month=42, Predicted=7612.2037, Expected=6270.0000
# Month=43, Predicted=6302.4682, Expected=7250.0000
# Month=44, Predicted=7282.4682, Expected=6830.0000
# Month=45, Predicted=6448.5085, Expected=6810.0000
# Month=46, Predicted=6842.4682, Expected=5810.0000
# Month=47, Predicted=5716.6273, Expected=6220.0000
# Month=48, Predicted=6252.4682, Expected=7450.0000
# Month=49, Predicted=7502.5477, Expected=9370.0000
# Month=50, Predicted=9486.1362, Expected=7980.0000
# Month=51, Predicted=8389.4568, Expected=6050.0000
# Month=52, Predicted=6082.4682, Expected=5640.0000
# Month=53, Predicted=5672.4682, Expected=6220.0000
# Month=54, Predicted=6252.4682, Expected=5740.0000
# Month=55, Predicted=5431.7434, Expected=6040.0000
# Month=56, Predicted=6072.4682, Expected=5130.0000
# Month=57, Predicted=4924.5997, Expected=5090.0000
# Month=58, Predicted=5122.4682, Expected=5210.0000
# Month=59, Predicted=5242.4682, Expected=4910.0000
# Month=60, Predicted=4906.1769, Expected=6890.0000
# Run 4 — RMSE: 1252.567717, MSE: 1568925.886893, NMSE: 0.0060272862, sMAPE: 11.693327
#
# ===== RUN 5/2 =====
# Training complete for run 5
# Month=1, Predicted=9862.6946, Expected=11870.0000
# Month=2, Predicted=11408.4383, Expected=12920.0000
# Month=3, Predicted=12458.0338, Expected=10890.0000
# Month=4, Predicted=11130.1836, Expected=9500.0000
# Month=5, Predicted=9439.4293, Expected=9490.0000
# Month=6, Predicted=9743.5564, Expected=9500.0000
# Month=7, Predicted=9720.3214, Expected=10880.0000
# Month=8, Predicted=10895.6073, Expected=9270.0000
# Month=9, Predicted=9734.0213, Expected=8880.0000
# Month=10, Predicted=8856.3580, Expected=7780.0000
# Month=11, Predicted=8104.4783, Expected=8360.0000
# Month=12, Predicted=8467.9874, Expected=12320.0000
# Month=13, Predicted=12916.6205, Expected=13490.0000
# Month=14, Predicted=13423.3179, Expected=12710.0000
# Month=15, Predicted=11840.3400, Expected=10130.0000
# Month=16, Predicted=10163.7487, Expected=9240.0000
# Month=17, Predicted=9131.5064, Expected=9640.0000
# Month=18, Predicted=10068.0493, Expected=8920.0000
# Month=19, Predicted=8847.6358, Expected=8900.0000
# Month=20, Predicted=8991.3514, Expected=8480.0000
# Month=21, Predicted=8691.0490, Expected=7870.0000
# Month=22, Predicted=7994.0418, Expected=7860.0000
# Month=23, Predicted=8017.2455, Expected=8990.0000
# Month=24, Predicted=9072.6509, Expected=10790.0000
# Month=25, Predicted=10671.0778, Expected=11820.0000
# Month=26, Predicted=11433.4565, Expected=10590.0000
# Month=27, Predicted=10516.4135, Expected=9430.0000
# Month=28, Predicted=9478.2742, Expected=9070.0000
# Month=29, Predicted=9263.2217, Expected=8250.0000
# Month=30, Predicted=8491.7082, Expected=8740.0000
# Month=31, Predicted=8873.0852, Expected=9120.0000
# Month=32, Predicted=9142.5197, Expected=8280.0000
# Month=33, Predicted=8028.9946, Expected=7860.0000
# Month=34, Predicted=7952.1405, Expected=7150.0000
# Month=35, Predicted=7358.5686, Expected=8110.0000
# Month=36, Predicted=8257.6917, Expected=10860.0000
# Month=37, Predicted=11246.1482, Expected=10730.0000
# Month=38, Predicted=10776.9002, Expected=9610.0000
# Month=39, Predicted=9375.4778, Expected=8270.0000
# Month=40, Predicted=8390.6201, Expected=9200.0000
# Month=41, Predicted=9351.0017, Expected=6660.0000
# Month=42, Predicted=7645.2299, Expected=6270.0000
# Month=43, Predicted=6102.4060, Expected=7250.0000
# Month=44, Predicted=7785.5390, Expected=6830.0000
# Month=45, Predicted=6556.6168, Expected=6810.0000
# Month=46, Predicted=6880.3847, Expected=5810.0000
# Month=47, Predicted=5844.3145, Expected=6220.0000
# Month=48, Predicted=6319.4273, Expected=7450.0000
# Month=49, Predicted=7643.7605, Expected=9370.0000
# Month=50, Predicted=9165.4025, Expected=7980.0000
# Month=51, Predicted=8214.2045, Expected=6050.0000
# Month=52, Predicted=6044.7554, Expected=5640.0000
# Month=53, Predicted=5718.0222, Expected=6220.0000
# Month=54, Predicted=6599.4599, Expected=5740.0000
# Month=55, Predicted=5464.2115, Expected=6040.0000
# Month=56, Predicted=6132.0780, Expected=5130.0000
# Month=57, Predicted=5070.8206, Expected=5090.0000
# Month=58, Predicted=5178.0868, Expected=5210.0000
# Month=59, Predicted=5365.5483, Expected=4910.0000
# Month=60, Predicted=4913.2379, Expected=6890.0000
# Run 5 — RMSE: 1223.168653, MSE: 1496141.554376, NMSE: 0.0061095544, sMAPE: 11.528838
#
# ===== RUN 6/2 =====
# Training complete for run 6
# Month=1, Predicted=9901.7474, Expected=11870.0000
# Month=2, Predicted=11252.4508, Expected=12920.0000
# Month=3, Predicted=12337.7042, Expected=10890.0000
# Month=4, Predicted=10916.8555, Expected=9500.0000
# Month=5, Predicted=9371.3697, Expected=9490.0000
# Month=6, Predicted=9869.5095, Expected=9500.0000
# Month=7, Predicted=9749.2912, Expected=10880.0000
# Month=8, Predicted=10858.1835, Expected=9270.0000
# Month=9, Predicted=9494.7346, Expected=8880.0000
# Month=10, Predicted=8784.2425, Expected=7780.0000
# Month=11, Predicted=8253.0876, Expected=8360.0000
# Month=12, Predicted=8529.9278, Expected=12320.0000
# Month=13, Predicted=13168.1196, Expected=13490.0000
# Month=14, Predicted=13516.1486, Expected=12710.0000
# Month=15, Predicted=11466.3225, Expected=10130.0000
# Month=16, Predicted=10227.3455, Expected=9240.0000
# Month=17, Predicted=9403.4534, Expected=9640.0000
# Month=18, Predicted=10235.0365, Expected=8920.0000
# Month=19, Predicted=8917.5636, Expected=8900.0000
# Month=20, Predicted=8987.4363, Expected=8480.0000
# Month=21, Predicted=8652.0427, Expected=7870.0000
# Month=22, Predicted=8020.4285, Expected=7860.0000
# Month=23, Predicted=8064.3631, Expected=8990.0000
# Month=24, Predicted=9079.0193, Expected=10790.0000
# Month=25, Predicted=10753.3862, Expected=11820.0000
# Month=26, Predicted=11337.6895, Expected=10590.0000
# Month=27, Predicted=10169.8016, Expected=9430.0000
# Month=28, Predicted=9455.9133, Expected=9070.0000
# Month=29, Predicted=9366.5601, Expected=8250.0000
# Month=30, Predicted=8606.6148, Expected=8740.0000
# Month=31, Predicted=8928.5432, Expected=9120.0000
# Month=32, Predicted=9175.6733, Expected=8280.0000
# Month=33, Predicted=7970.1429, Expected=7860.0000
# Month=34, Predicted=7959.5741, Expected=7150.0000
# Month=35, Predicted=7445.8287, Expected=8110.0000
# Month=36, Predicted=8309.3035, Expected=10860.0000
# Month=37, Predicted=11381.3762, Expected=10730.0000
# Month=38, Predicted=11376.5417, Expected=9610.0000
# Month=39, Predicted=9217.9076, Expected=8270.0000
# Month=40, Predicted=8438.1582, Expected=9200.0000
# Month=41, Predicted=9437.5136, Expected=6660.0000
# Month=42, Predicted=7566.5851, Expected=6270.0000
# Month=43, Predicted=6330.6769, Expected=7250.0000
# Month=44, Predicted=7874.0795, Expected=6830.0000
# Month=45, Predicted=6616.7547, Expected=6810.0000
# Month=46, Predicted=6824.4453, Expected=5810.0000
# Month=47, Predicted=5929.5661, Expected=6220.0000
# Month=48, Predicted=6350.1698, Expected=7450.0000
# Month=49, Predicted=7668.7028, Expected=9370.0000
# Month=50, Predicted=9223.7569, Expected=7980.0000
# Month=51, Predicted=8509.2783, Expected=6050.0000
# Month=52, Predicted=5979.3939, Expected=5640.0000
# Month=53, Predicted=5838.3705, Expected=6220.0000
# Month=54, Predicted=6690.4558, Expected=5740.0000
# Month=55, Predicted=5558.8605, Expected=6040.0000
# Month=56, Predicted=6081.5904, Expected=5130.0000
# Month=57, Predicted=5115.7220, Expected=5090.0000
# Month=58, Predicted=5188.4418, Expected=5210.0000
# Month=59, Predicted=5370.2906, Expected=4910.0000
# Month=60, Predicted=4847.6426, Expected=6890.0000
# Run 6 — RMSE: 1214.165636, MSE: 1474198.192145, NMSE: 0.0060649247, sMAPE: 11.161378
#
# ===== RUN 7/2 =====
# Training complete for run 7
# Month=1, Predicted=9708.2722, Expected=11870.0000
# Month=2, Predicted=11488.7988, Expected=12920.0000
# Month=3, Predicted=12493.8895, Expected=10890.0000
# Month=4, Predicted=11313.3166, Expected=9500.0000
# Month=5, Predicted=9538.8133, Expected=9490.0000
# Month=6, Predicted=9528.8133, Expected=9500.0000
# Month=7, Predicted=9523.2307, Expected=10880.0000
# Month=8, Predicted=10904.4962, Expected=9270.0000
# Month=9, Predicted=9792.6747, Expected=8880.0000
# Month=10, Predicted=8918.8133, Expected=7780.0000
# Month=11, Predicted=7811.4125, Expected=8360.0000
# Month=12, Predicted=8398.8133, Expected=12320.0000
# Month=13, Predicted=13021.4247, Expected=13490.0000
# Month=14, Predicted=13866.1458, Expected=12710.0000
# Month=15, Predicted=12074.7309, Expected=10130.0000
# Month=16, Predicted=10197.6319, Expected=9240.0000
# Month=17, Predicted=9278.8133, Expected=9640.0000
# Month=18, Predicted=9678.8133, Expected=8920.0000
# Month=19, Predicted=8687.7771, Expected=8900.0000
# Month=20, Predicted=8938.8133, Expected=8480.0000
# Month=21, Predicted=8522.3223, Expected=7870.0000
# Month=22, Predicted=7910.0976, Expected=7860.0000
# Month=23, Predicted=7898.8133, Expected=8990.0000
# Month=24, Predicted=9007.3555, Expected=10790.0000
# Month=25, Predicted=10915.1600, Expected=11820.0000
# Month=26, Predicted=11313.5274, Expected=10590.0000
# Month=27, Predicted=10636.1781, Expected=9430.0000
# Month=28, Predicted=9468.8133, Expected=9070.0000
# Month=29, Predicted=9108.8133, Expected=8250.0000
# Month=30, Predicted=8286.8195, Expected=8740.0000
# Month=31, Predicted=8778.8133, Expected=9120.0000
# Month=32, Predicted=8994.1744, Expected=8280.0000
# Month=33, Predicted=8099.2462, Expected=7860.0000
# Month=34, Predicted=7898.8133, Expected=7150.0000
# Month=35, Predicted=7189.2422, Expected=8110.0000
# Month=36, Predicted=8148.8133, Expected=10860.0000
# Month=37, Predicted=11507.8358, Expected=10730.0000
# Month=38, Predicted=11042.2796, Expected=9610.0000
# Month=39, Predicted=9442.6837, Expected=8270.0000
# Month=40, Predicted=8308.8133, Expected=9200.0000
# Month=41, Predicted=9238.8133, Expected=6660.0000
# Month=42, Predicted=7325.6599, Expected=6270.0000
# Month=43, Predicted=6308.8133, Expected=7250.0000
# Month=44, Predicted=7291.8856, Expected=6830.0000
# Month=45, Predicted=6434.4318, Expected=6810.0000
# Month=46, Predicted=6851.7720, Expected=5810.0000
# Month=47, Predicted=5726.3855, Expected=6220.0000
# Month=48, Predicted=6258.8133, Expected=7450.0000
# Month=49, Predicted=7545.6765, Expected=9370.0000
# Month=50, Predicted=9495.1514, Expected=7980.0000
# Month=51, Predicted=8632.6366, Expected=6050.0000
# Month=52, Predicted=6088.8133, Expected=5640.0000
# Month=53, Predicted=5678.8133, Expected=6220.0000
# Month=54, Predicted=6265.3415, Expected=5740.0000
# Month=55, Predicted=5413.8796, Expected=6040.0000
# Month=56, Predicted=6078.8133, Expected=5130.0000
# Month=57, Predicted=4947.7818, Expected=5090.0000
# Month=58, Predicted=5128.8133, Expected=5210.0000
# Month=59, Predicted=5235.7634, Expected=4910.0000
# Month=60, Predicted=4890.9465, Expected=6890.0000
# Run 7 — RMSE: 1260.448201, MSE: 1588729.666254, NMSE: 0.0060340116, sMAPE: 11.740575
#
# ===== RUN 8/2 =====
# Training complete for run 8
# Month=1, Predicted=9824.4213, Expected=11870.0000
# Month=2, Predicted=11796.7904, Expected=12920.0000
# Month=3, Predicted=12365.0448, Expected=10890.0000
# Month=4, Predicted=11318.3928, Expected=9500.0000
# Month=5, Predicted=9547.5944, Expected=9490.0000
# Month=6, Predicted=9853.4269, Expected=9500.0000
# Month=7, Predicted=9667.8198, Expected=10880.0000
# Month=8, Predicted=10914.3913, Expected=9270.0000
# Month=9, Predicted=9825.1193, Expected=8880.0000
# Month=10, Predicted=8997.9375, Expected=7780.0000
# Month=11, Predicted=7903.2350, Expected=8360.0000
# Month=12, Predicted=8546.3228, Expected=12320.0000
# Month=13, Predicted=13247.1237, Expected=13490.0000
# Month=14, Predicted=13653.1730, Expected=12710.0000
# Month=15, Predicted=12010.4392, Expected=10130.0000
# Month=16, Predicted=9966.3974, Expected=9240.0000
# Month=17, Predicted=9480.6633, Expected=9640.0000
# Month=18, Predicted=10043.2798, Expected=8920.0000
# Month=19, Predicted=8841.2685, Expected=8900.0000
# Month=20, Predicted=9014.2846, Expected=8480.0000
# Month=21, Predicted=8562.5896, Expected=7870.0000
# Month=22, Predicted=7926.4430, Expected=7860.0000
# Month=23, Predicted=8003.9469, Expected=8990.0000
# Month=24, Predicted=9060.5851, Expected=10790.0000
# Month=25, Predicted=10895.7690, Expected=11820.0000
# Month=26, Predicted=11320.1280, Expected=10590.0000
# Month=27, Predicted=10579.7504, Expected=9430.0000
# Month=28, Predicted=9457.6237, Expected=9070.0000
# Month=29, Predicted=9299.0197, Expected=8250.0000
# Month=30, Predicted=8356.5398, Expected=8740.0000
# Month=31, Predicted=8908.7100, Expected=9120.0000
# Month=32, Predicted=9057.2641, Expected=8280.0000
# Month=33, Predicted=8054.3410, Expected=7860.0000
# Month=34, Predicted=7951.1681, Expected=7150.0000
# Month=35, Predicted=7245.5978, Expected=8110.0000
# Month=36, Predicted=8277.4367, Expected=10860.0000
# Month=37, Predicted=11638.7652, Expected=10730.0000
# Month=38, Predicted=10790.8302, Expected=9610.0000
# Month=39, Predicted=9484.1966, Expected=8270.0000
# Month=40, Predicted=8310.9324, Expected=9200.0000
# Month=41, Predicted=9454.9731, Expected=6660.0000
# Month=42, Predicted=7719.6578, Expected=6270.0000
# Month=43, Predicted=6451.7431, Expected=7250.0000
# Month=44, Predicted=7622.3243, Expected=6830.0000
# Month=45, Predicted=6472.4556, Expected=6810.0000
# Month=46, Predicted=6896.7552, Expected=5810.0000
# Month=47, Predicted=5723.4957, Expected=6220.0000
# Month=48, Predicted=6379.7495, Expected=7450.0000
# Month=49, Predicted=7544.8972, Expected=9370.0000
# Month=50, Predicted=9463.3177, Expected=7980.0000
# Month=51, Predicted=8523.7712, Expected=6050.0000
# Month=52, Predicted=5995.0286, Expected=5640.0000
# Month=53, Predicted=5944.0929, Expected=6220.0000
# Month=54, Predicted=6508.4309, Expected=5740.0000
# Month=55, Predicted=5458.6984, Expected=6040.0000
# Month=56, Predicted=6149.1676, Expected=5130.0000
# Month=57, Predicted=4989.1793, Expected=5090.0000
# Month=58, Predicted=5218.5024, Expected=5210.0000
# Month=59, Predicted=5323.0823, Expected=4910.0000
# Month=60, Predicted=4922.8508, Expected=6890.0000
# Run 8 — RMSE: 1239.384573, MSE: 1536074.119090, NMSE: 0.0059542224, sMAPE: 11.558151
#
# ===== RUN 9/2 =====
# Training complete for run 9
# Month=1, Predicted=9785.0287, Expected=11870.0000
# Month=2, Predicted=11512.2005, Expected=12920.0000
# Month=3, Predicted=12567.0304, Expected=10890.0000
# Month=4, Predicted=11252.2465, Expected=9500.0000
# Month=5, Predicted=9190.7755, Expected=9490.0000
# Month=6, Predicted=9648.5691, Expected=9500.0000
# Month=7, Predicted=9622.1507, Expected=10880.0000
# Month=8, Predicted=10939.9849, Expected=9270.0000
# Month=9, Predicted=9545.0635, Expected=8880.0000
# Month=10, Predicted=8829.5926, Expected=7780.0000
# Month=11, Predicted=7967.8112, Expected=8360.0000
# Month=12, Predicted=8482.0273, Expected=12320.0000
# Month=13, Predicted=12890.5009, Expected=13490.0000
# Month=14, Predicted=13214.9660, Expected=12710.0000
# Month=15, Predicted=12499.4385, Expected=10130.0000
# Month=16, Predicted=10099.6706, Expected=9240.0000
# Month=17, Predicted=8805.2335, Expected=9640.0000
# Month=18, Predicted=9949.0455, Expected=8920.0000
# Month=19, Predicted=8762.4885, Expected=8900.0000
# Month=20, Predicted=9053.6864, Expected=8480.0000
# Month=21, Predicted=8556.9494, Expected=7870.0000
# Month=22, Predicted=7986.5076, Expected=7860.0000
# Month=23, Predicted=8029.6295, Expected=8990.0000
# Month=24, Predicted=9070.1862, Expected=10790.0000
# Month=25, Predicted=10776.3826, Expected=11820.0000
# Month=26, Predicted=11356.1815, Expected=10590.0000
# Month=27, Predicted=10550.5146, Expected=9430.0000
# Month=28, Predicted=9408.1992, Expected=9070.0000
# Month=29, Predicted=9195.3364, Expected=8250.0000
# Month=30, Predicted=8410.7346, Expected=8740.0000
# Month=31, Predicted=8908.3863, Expected=9120.0000
# Month=32, Predicted=9045.7621, Expected=8280.0000
# Month=33, Predicted=8079.6139, Expected=7860.0000
# Month=34, Predicted=7984.3792, Expected=7150.0000
# Month=35, Predicted=7298.5270, Expected=8110.0000
# Month=36, Predicted=8290.8110, Expected=10860.0000
# Month=37, Predicted=11369.1608, Expected=10730.0000
# Month=38, Predicted=10997.2938, Expected=9610.0000
# Month=39, Predicted=9630.0028, Expected=8270.0000
# Month=40, Predicted=8264.5220, Expected=9200.0000
# Month=41, Predicted=9296.2351, Expected=6660.0000
# Month=42, Predicted=7587.5187, Expected=6270.0000
# Month=43, Predicted=5873.9968, Expected=7250.0000
# Month=44, Predicted=7561.7688, Expected=6830.0000
# Month=45, Predicted=6499.4004, Expected=6810.0000
# Month=46, Predicted=6948.2050, Expected=5810.0000
# Month=47, Predicted=5809.0527, Expected=6220.0000
# Month=48, Predicted=6355.4811, Expected=7450.0000
# Month=49, Predicted=7529.7935, Expected=9370.0000
# Month=50, Predicted=9348.7075, Expected=7980.0000
# Month=51, Predicted=8284.0293, Expected=6050.0000
# Month=52, Predicted=5900.7069, Expected=5640.0000
# Month=53, Predicted=5553.9758, Expected=6220.0000
# Month=54, Predicted=6481.2616, Expected=5740.0000
# Month=55, Predicted=5448.4991, Expected=6040.0000
# Month=56, Predicted=6191.3222, Expected=5130.0000
# Month=57, Predicted=4998.8353, Expected=5090.0000
# Month=58, Predicted=5228.2057, Expected=5210.0000
# Month=59, Predicted=5309.9181, Expected=4910.0000
# Month=60, Predicted=4889.8857, Expected=6890.0000
# Run 9 — RMSE: 1259.184565, MSE: 1585545.768209, NMSE: 0.0062287687, sMAPE: 11.888843
#
# ===== RUN 10/2 =====
# Training complete for run 10
# Month=1, Predicted=9704.2074, Expected=11870.0000
# Month=2, Predicted=12100.3980, Expected=12920.0000
# Month=3, Predicted=12206.8617, Expected=10890.0000
# Month=4, Predicted=11159.9640, Expected=9500.0000
# Month=5, Predicted=9558.2558, Expected=9490.0000
# Month=6, Predicted=9548.6034, Expected=9500.0000
# Month=7, Predicted=9555.8477, Expected=10880.0000
# Month=8, Predicted=10859.2051, Expected=9270.0000
# Month=9, Predicted=9836.0156, Expected=8880.0000
# Month=10, Predicted=8938.6034, Expected=7780.0000
# Month=11, Predicted=7838.6034, Expected=8360.0000
# Month=12, Predicted=8418.6034, Expected=12320.0000
# Month=13, Predicted=13205.0042, Expected=13490.0000
# Month=14, Predicted=14313.3493, Expected=12710.0000
# Month=15, Predicted=10748.3557, Expected=10130.0000
# Month=16, Predicted=9920.3888, Expected=9240.0000
# Month=17, Predicted=9296.6396, Expected=9640.0000
# Month=18, Predicted=9698.6034, Expected=8920.0000
# Month=19, Predicted=8709.2803, Expected=8900.0000
# Month=20, Predicted=8958.6034, Expected=8480.0000
# Month=21, Predicted=8538.6034, Expected=7870.0000
# Month=22, Predicted=7928.6034, Expected=7860.0000
# Month=23, Predicted=7918.6034, Expected=8990.0000
# Month=24, Predicted=8982.0329, Expected=10790.0000
# Month=25, Predicted=10920.2425, Expected=11820.0000
# Month=26, Predicted=11416.6576, Expected=10590.0000
# Month=27, Predicted=10477.1865, Expected=9430.0000
# Month=28, Predicted=9488.6034, Expected=9070.0000
# Month=29, Predicted=9128.6034, Expected=8250.0000
# Month=30, Predicted=8308.6034, Expected=8740.0000
# Month=31, Predicted=8798.6034, Expected=9120.0000
# Month=32, Predicted=9019.8791, Expected=8280.0000
# Month=33, Predicted=8032.5697, Expected=7860.0000
# Month=34, Predicted=7918.6034, Expected=7150.0000
# Month=35, Predicted=7208.6034, Expected=8110.0000
# Month=36, Predicted=8168.6034, Expected=10860.0000
# Month=37, Predicted=11559.1025, Expected=10730.0000
# Month=38, Predicted=11056.0005, Expected=9610.0000
# Month=39, Predicted=9411.8180, Expected=8270.0000
# Month=40, Predicted=8328.6034, Expected=9200.0000
# Month=41, Predicted=9258.6034, Expected=6660.0000
# Month=42, Predicted=7482.0879, Expected=6270.0000
# Month=43, Predicted=6327.6121, Expected=7250.0000
# Month=44, Predicted=7308.6034, Expected=6830.0000
# Month=45, Predicted=6285.3200, Expected=6810.0000
# Month=46, Predicted=6868.6034, Expected=5810.0000
# Month=47, Predicted=5722.4951, Expected=6220.0000
# Month=48, Predicted=6278.6034, Expected=7450.0000
# Month=49, Predicted=7501.3222, Expected=9370.0000
# Month=50, Predicted=9558.4242, Expected=7980.0000
# Month=51, Predicted=8648.1010, Expected=6050.0000
# Month=52, Predicted=6108.6034, Expected=5640.0000
# Month=53, Predicted=5698.6034, Expected=6220.0000
# Month=54, Predicted=6278.6034, Expected=5740.0000
# Month=55, Predicted=5313.3096, Expected=6040.0000
# Month=56, Predicted=6098.6034, Expected=5130.0000
# Month=57, Predicted=4940.7715, Expected=5090.0000
# Month=58, Predicted=5148.6034, Expected=5210.0000
# Month=59, Predicted=5247.8423, Expected=4910.0000
# Month=60, Predicted=4847.8054, Expected=6890.0000
# Run 10 — RMSE: 1229.791611, MSE: 1512387.406534, NMSE: 0.0057388705, sMAPE: 11.515982
#
# ===== RUN 11/2 =====
# Training complete for run 11
# Month=1, Predicted=9883.7766, Expected=11870.0000
# Month=2, Predicted=11367.5840, Expected=12920.0000
# Month=3, Predicted=11970.7560, Expected=10890.0000
# Month=4, Predicted=10477.5408, Expected=9500.0000
# Month=5, Predicted=9653.4819, Expected=9490.0000
# Month=6, Predicted=9961.3487, Expected=9500.0000
# Month=7, Predicted=9746.7803, Expected=10880.0000
# Month=8, Predicted=10958.5846, Expected=9270.0000
# Month=9, Predicted=9606.3440, Expected=8880.0000
# Month=10, Predicted=9042.3006, Expected=7780.0000
# Month=11, Predicted=8111.1636, Expected=8360.0000
# Month=12, Predicted=8520.0149, Expected=12320.0000
# Month=13, Predicted=12565.7759, Expected=13490.0000
# Month=14, Predicted=13665.9377, Expected=12710.0000
# Month=15, Predicted=10028.2549, Expected=10130.0000
# Month=16, Predicted=10061.5002, Expected=9240.0000
# Month=17, Predicted=9545.3970, Expected=9640.0000
# Month=18, Predicted=10239.0456, Expected=8920.0000
# Month=19, Predicted=8833.9574, Expected=8900.0000
# Month=20, Predicted=9000.1902, Expected=8480.0000
# Month=21, Predicted=8608.0152, Expected=7870.0000
# Month=22, Predicted=7946.6841, Expected=7860.0000
# Month=23, Predicted=7995.5179, Expected=8990.0000
# Month=24, Predicted=9120.7476, Expected=10790.0000
# Month=25, Predicted=10565.6831, Expected=11820.0000
# Month=26, Predicted=11203.2371, Expected=10590.0000
# Month=27, Predicted=10169.1427, Expected=9430.0000
# Month=28, Predicted=9533.8662, Expected=9070.0000
# Month=29, Predicted=9354.6960, Expected=8250.0000
# Month=30, Predicted=8463.9438, Expected=8740.0000
# Month=31, Predicted=8882.8972, Expected=9120.0000
# Month=32, Predicted=9199.9556, Expected=8280.0000
# Month=33, Predicted=7987.7548, Expected=7860.0000
# Month=34, Predicted=7959.8175, Expected=7150.0000
# Month=35, Predicted=7317.5953, Expected=8110.0000
# Month=36, Predicted=8253.5030, Expected=10860.0000
# Month=37, Predicted=10995.8949, Expected=10730.0000
# Month=38, Predicted=10878.3764, Expected=9610.0000
# Month=39, Predicted=8906.4338, Expected=8270.0000
# Month=40, Predicted=8388.2006, Expected=9200.0000
# Month=41, Predicted=9479.3647, Expected=6660.0000
# Month=42, Predicted=7627.4406, Expected=6270.0000
# Month=43, Predicted=6515.4707, Expected=7250.0000
# Month=44, Predicted=7847.6124, Expected=6830.0000
# Month=45, Predicted=6578.1276, Expected=6810.0000
# Month=46, Predicted=6887.2436, Expected=5810.0000
# Month=47, Predicted=5763.5094, Expected=6220.0000
# Month=48, Predicted=6355.4631, Expected=7450.0000
# Month=49, Predicted=7628.3549, Expected=9370.0000
# Month=50, Predicted=9063.6787, Expected=7980.0000
# Month=51, Predicted=8171.3059, Expected=6050.0000
# Month=52, Predicted=6116.4655, Expected=5640.0000
# Month=53, Predicted=6002.5153, Expected=6220.0000
# Month=54, Predicted=6626.4511, Expected=5740.0000
# Month=55, Predicted=5507.2534, Expected=6040.0000
# Month=56, Predicted=6127.6259, Expected=5130.0000
# Month=57, Predicted=4975.4084, Expected=5090.0000
# Month=58, Predicted=5204.8517, Expected=5210.0000
# Month=59, Predicted=5382.2795, Expected=4910.0000
# Month=60, Predicted=4903.7535, Expected=6890.0000
# Run 11 — RMSE: 1177.878477, MSE: 1387397.707386, NMSE: 0.0061921870, sMAPE: 10.906670
#
# ===== RUN 12/2 =====
# Training complete for run 12
# Month=1, Predicted=9813.8560, Expected=11870.0000
# Month=2, Predicted=11785.9279, Expected=12920.0000
# Month=3, Predicted=12956.3150, Expected=10890.0000
# Month=4, Predicted=10485.7283, Expected=9500.0000
# Month=5, Predicted=9518.7376, Expected=9490.0000
# Month=6, Predicted=9570.1310, Expected=9500.0000
# Month=7, Predicted=9711.0713, Expected=10880.0000
# Month=8, Predicted=10879.4911, Expected=9270.0000
# Month=9, Predicted=8939.2956, Expected=8880.0000
# Month=10, Predicted=8845.1518, Expected=7780.0000
# Month=11, Predicted=8079.5973, Expected=8360.0000
# Month=12, Predicted=8371.6408, Expected=12320.0000
# Month=13, Predicted=12385.2609, Expected=13490.0000
# Month=14, Predicted=14404.6082, Expected=12710.0000
# Month=15, Predicted=12264.7555, Expected=10130.0000
# Month=16, Predicted=10177.4445, Expected=9240.0000
# Month=17, Predicted=9362.9873, Expected=9640.0000
# Month=18, Predicted=9884.9020, Expected=8920.0000
# Month=19, Predicted=8959.4913, Expected=8900.0000
# Month=20, Predicted=8937.9011, Expected=8480.0000
# Month=21, Predicted=8595.2726, Expected=7870.0000
# Month=22, Predicted=7995.4349, Expected=7860.0000
# Month=23, Predicted=7969.0778, Expected=8990.0000
# Month=24, Predicted=9064.4476, Expected=10790.0000
# Month=25, Predicted=10528.1879, Expected=11820.0000
# Month=26, Predicted=11614.7994, Expected=10590.0000
# Month=27, Predicted=10262.0366, Expected=9430.0000
# Month=28, Predicted=9395.0684, Expected=9070.0000
# Month=29, Predicted=9127.2829, Expected=8250.0000
# Month=30, Predicted=8496.1042, Expected=8740.0000
# Month=31, Predicted=8796.8233, Expected=9120.0000
# Month=32, Predicted=9150.9868, Expected=8280.0000
# Month=33, Predicted=8178.0099, Expected=7860.0000
# Month=34, Predicted=7877.9468, Expected=7150.0000
# Month=35, Predicted=7347.6195, Expected=8110.0000
# Month=36, Predicted=8194.8999, Expected=10860.0000
# Month=37, Predicted=10727.1827, Expected=10730.0000
# Month=38, Predicted=11135.2612, Expected=9610.0000
# Month=39, Predicted=9659.2449, Expected=8270.0000
# Month=40, Predicted=8275.5194, Expected=9200.0000
# Month=41, Predicted=9230.0201, Expected=6660.0000
# Month=42, Predicted=6368.3034, Expected=6270.0000
# Month=43, Predicted=6365.1852, Expected=7250.0000
# Month=44, Predicted=7643.6214, Expected=6830.0000
# Month=45, Predicted=6631.7091, Expected=6810.0000
# Month=46, Predicted=6890.8079, Expected=5810.0000
# Month=47, Predicted=5921.2874, Expected=6220.0000
# Month=48, Predicted=6222.9272, Expected=7450.0000
# Month=49, Predicted=7541.2477, Expected=9370.0000
# Month=50, Predicted=9073.3212, Expected=7980.0000
# Month=51, Predicted=7775.5028, Expected=6050.0000
# Month=52, Predicted=6008.2354, Expected=5640.0000
# Month=53, Predicted=5696.1626, Expected=6220.0000
# Month=54, Predicted=6535.8337, Expected=5740.0000
# Month=55, Predicted=5666.0107, Expected=6040.0000
# Month=56, Predicted=6115.9706, Expected=5130.0000
# Month=57, Predicted=5125.0225, Expected=5090.0000
# Month=58, Predicted=5094.6697, Expected=5210.0000
# Month=59, Predicted=5339.8810, Expected=4910.0000
# Month=60, Predicted=4915.4524, Expected=6890.0000
# Run 12 — RMSE: 1225.408115, MSE: 1501625.049237, NMSE: 0.0058273534, sMAPE: 10.933609
#
# ===== RUN 13/2 =====
# Training complete for run 13
# Month=1, Predicted=9781.9704, Expected=11870.0000
# Month=2, Predicted=11558.4157, Expected=12920.0000
# Month=3, Predicted=12577.4407, Expected=10890.0000
# Month=4, Predicted=11381.3574, Expected=9500.0000
# Month=5, Predicted=9390.7027, Expected=9490.0000
# Month=6, Predicted=9689.8549, Expected=9500.0000
# Month=7, Predicted=9559.9178, Expected=10880.0000
# Month=8, Predicted=10923.4431, Expected=9270.0000
# Month=9, Predicted=9689.5723, Expected=8880.0000
# Month=10, Predicted=8954.1827, Expected=7780.0000
# Month=11, Predicted=7838.9574, Expected=8360.0000
# Month=12, Predicted=8527.6621, Expected=12320.0000
# Month=13, Predicted=13136.6352, Expected=13490.0000
# Month=14, Predicted=13314.3973, Expected=12710.0000
# Month=15, Predicted=12446.8930, Expected=10130.0000
# Month=16, Predicted=9995.5220, Expected=9240.0000
# Month=17, Predicted=9154.7764, Expected=9640.0000
# Month=18, Predicted=9898.3229, Expected=8920.0000
# Month=19, Predicted=8758.4522, Expected=8900.0000
# Month=20, Predicted=9046.9285, Expected=8480.0000
# Month=21, Predicted=8540.4341, Expected=7870.0000
# Month=22, Predicted=7947.4201, Expected=7860.0000
# Month=23, Predicted=8014.8225, Expected=8990.0000
# Month=24, Predicted=9037.4591, Expected=10790.0000
# Month=25, Predicted=10871.1531, Expected=11820.0000
# Month=26, Predicted=11430.3848, Expected=10590.0000
# Month=27, Predicted=10640.4566, Expected=9430.0000
# Month=28, Predicted=9430.4024, Expected=9070.0000
# Month=29, Predicted=9216.5216, Expected=8250.0000
# Month=30, Predicted=8324.5004, Expected=8740.0000
# Month=31, Predicted=8915.5773, Expected=9120.0000
# Month=32, Predicted=8991.8290, Expected=8280.0000
# Month=33, Predicted=8138.8512, Expected=7860.0000
# Month=34, Predicted=7970.7090, Expected=7150.0000
# Month=35, Predicted=7232.5931, Expected=8110.0000
# Month=36, Predicted=8287.8052, Expected=10860.0000
# Month=37, Predicted=11444.1993, Expected=10730.0000
# Month=38, Predicted=10899.8185, Expected=9610.0000
# Month=39, Predicted=9577.7484, Expected=8270.0000
# Month=40, Predicted=8260.9888, Expected=9200.0000
# Month=41, Predicted=9363.8913, Expected=6660.0000
# Month=42, Predicted=7452.4652, Expected=6270.0000
# Month=43, Predicted=6235.6745, Expected=7250.0000
# Month=44, Predicted=7497.0901, Expected=6830.0000
# Month=45, Predicted=6492.2202, Expected=6810.0000
# Month=46, Predicted=6937.0991, Expected=5810.0000
# Month=47, Predicted=5777.7693, Expected=6220.0000
# Month=48, Predicted=6387.1095, Expected=7450.0000
# Month=49, Predicted=7490.9545, Expected=9370.0000
# Month=50, Predicted=9446.5423, Expected=7980.0000
# Month=51, Predicted=8376.0260, Expected=6050.0000
# Month=52, Predicted=5932.3092, Expected=5640.0000
# Month=53, Predicted=5725.5213, Expected=6220.0000
# Month=54, Predicted=6431.0915, Expected=5740.0000
# Month=55, Predicted=5435.0149, Expected=6040.0000
# Month=56, Predicted=6189.2947, Expected=5130.0000
# Month=57, Predicted=5027.2353, Expected=5090.0000
# Month=58, Predicted=5238.9823, Expected=5210.0000
# Month=59, Predicted=5262.1788, Expected=4910.0000
# Month=60, Predicted=4885.0887, Expected=6890.0000
# Run 13 — RMSE: 1254.517495, MSE: 1573814.145315, NMSE: 0.0060901223, sMAPE: 11.708969
#
# ===== RUN 14/2 =====
# Training complete for run 14
# Month=1, Predicted=9977.1320, Expected=11870.0000
# Month=2, Predicted=11876.3340, Expected=12920.0000
# Month=3, Predicted=11967.7242, Expected=10890.0000
# Month=4, Predicted=10773.1006, Expected=9500.0000
# Month=5, Predicted=9300.8020, Expected=9490.0000
# Month=6, Predicted=10230.0990, Expected=9500.0000
# Month=7, Predicted=9859.8742, Expected=10880.0000
# Month=8, Predicted=10866.4441, Expected=9270.0000
# Month=9, Predicted=9601.2545, Expected=8880.0000
# Month=10, Predicted=8779.5468, Expected=7780.0000
# Month=11, Predicted=8303.6944, Expected=8360.0000
# Month=12, Predicted=8474.3351, Expected=12320.0000
# Month=13, Predicted=13045.9926, Expected=13490.0000
# Month=14, Predicted=14580.1397, Expected=12710.0000
# Month=15, Predicted=8969.8583, Expected=10130.0000
# Month=16, Predicted=9906.5782, Expected=9240.0000
# Month=17, Predicted=9423.5577, Expected=9640.0000
# Month=18, Predicted=10686.5821, Expected=8920.0000
# Month=19, Predicted=8899.7476, Expected=8900.0000
# Month=20, Predicted=8932.8817, Expected=8480.0000
# Month=21, Predicted=8630.4151, Expected=7870.0000
# Month=22, Predicted=7901.4707, Expected=7860.0000
# Month=23, Predicted=7999.3830, Expected=8990.0000
# Month=24, Predicted=9103.0705, Expected=10790.0000
# Month=25, Predicted=10613.9763, Expected=11820.0000
# Month=26, Predicted=11432.5872, Expected=10590.0000
# Month=27, Predicted=10060.1355, Expected=9430.0000
# Month=28, Predicted=9293.9917, Expected=9070.0000
# Month=29, Predicted=9457.1052, Expected=8250.0000
# Month=30, Predicted=8556.5174, Expected=8740.0000
# Month=31, Predicted=8866.7468, Expected=9120.0000
# Month=32, Predicted=9187.0948, Expected=8280.0000
# Month=33, Predicted=8085.3723, Expected=7860.0000
# Month=34, Predicted=7863.6904, Expected=7150.0000
# Month=35, Predicted=7368.2249, Expected=8110.0000
# Month=36, Predicted=8254.8685, Expected=10860.0000
# Month=37, Predicted=11249.4839, Expected=10730.0000
# Month=38, Predicted=11190.0621, Expected=9610.0000
# Month=39, Predicted=8884.4213, Expected=8270.0000
# Month=40, Predicted=8205.9101, Expected=9200.0000
# Month=41, Predicted=9566.2634, Expected=6660.0000
# Month=42, Predicted=8273.7639, Expected=6270.0000
# Month=43, Predicted=6172.6784, Expected=7250.0000
# Month=44, Predicted=8374.3982, Expected=6830.0000
# Month=45, Predicted=6481.4297, Expected=6810.0000
# Month=46, Predicted=6832.8545, Expected=5810.0000
# Month=47, Predicted=5818.2140, Expected=6220.0000
# Month=48, Predicted=6291.2929, Expected=7450.0000
# Month=49, Predicted=7696.6581, Expected=9370.0000
# Month=50, Predicted=9202.5535, Expected=7980.0000
# Month=51, Predicted=8037.3695, Expected=6050.0000
# Month=52, Predicted=5697.9105, Expected=5640.0000
# Month=53, Predicted=6057.9132, Expected=6220.0000
# Month=54, Predicted=6943.2221, Expected=5740.0000
# Month=55, Predicted=5481.8951, Expected=6040.0000
# Month=56, Predicted=6079.1152, Expected=5130.0000
# Month=57, Predicted=5080.8105, Expected=5090.0000
# Month=58, Predicted=5120.4511, Expected=5210.0000
# Month=59, Predicted=5437.4570, Expected=4910.0000
# Month=60, Predicted=4853.8279, Expected=6890.0000
# Run 14 — RMSE: 1239.887486, MSE: 1537320.977362, NMSE: 0.0062102371, sMAPE: 11.447740
#
# ===== RUN 15/2 =====
# Training complete for run 15
# Month=1, Predicted=9765.4779, Expected=11870.0000
# Month=2, Predicted=11870.1546, Expected=12920.0000
# Month=3, Predicted=12343.7514, Expected=10890.0000
# Month=4, Predicted=11226.8336, Expected=9500.0000
# Month=5, Predicted=9447.7788, Expected=9490.0000
# Month=6, Predicted=9562.6192, Expected=9500.0000
# Month=7, Predicted=9603.4877, Expected=10880.0000
# Month=8, Predicted=10942.7562, Expected=9270.0000
# Month=9, Predicted=9698.6834, Expected=8880.0000
# Month=10, Predicted=8848.4027, Expected=7780.0000
# Month=11, Predicted=8016.1273, Expected=8360.0000
# Month=12, Predicted=8428.7712, Expected=12320.0000
# Month=13, Predicted=13429.2864, Expected=13490.0000
# Month=14, Predicted=13527.5791, Expected=12710.0000
# Month=15, Predicted=11776.0090, Expected=10130.0000
# Month=16, Predicted=10363.8779, Expected=9240.0000
# Month=17, Predicted=9010.7726, Expected=9640.0000
# Month=18, Predicted=9803.5276, Expected=8920.0000
# Month=19, Predicted=8714.1114, Expected=8900.0000
# Month=20, Predicted=9009.9622, Expected=8480.0000
# Month=21, Predicted=8593.4338, Expected=7870.0000
# Month=22, Predicted=8033.0120, Expected=7860.0000
# Month=23, Predicted=7988.4778, Expected=8990.0000
# Month=24, Predicted=9064.5638, Expected=10790.0000
# Month=25, Predicted=10893.2582, Expected=11820.0000
# Month=26, Predicted=11444.9428, Expected=10590.0000
# Month=27, Predicted=10581.0987, Expected=9430.0000
# Month=28, Predicted=9560.6585, Expected=9070.0000
# Month=29, Predicted=9179.1111, Expected=8250.0000
# Month=30, Predicted=8449.3460, Expected=8740.0000
# Month=31, Predicted=8844.2176, Expected=9120.0000
# Month=32, Predicted=9018.7997, Expected=8280.0000
# Month=33, Predicted=8066.0329, Expected=7860.0000
# Month=34, Predicted=7984.8976, Expected=7150.0000
# Month=35, Predicted=7335.0446, Expected=8110.0000
# Month=36, Predicted=8224.9593, Expected=10860.0000
# Month=37, Predicted=11613.6773, Expected=10730.0000
# Month=38, Predicted=10600.9581, Expected=9610.0000
# Month=39, Predicted=9649.2044, Expected=8270.0000
# Month=40, Predicted=8447.0234, Expected=9200.0000
# Month=41, Predicted=9254.0604, Expected=6660.0000
# Month=42, Predicted=7473.8136, Expected=6270.0000
# Month=43, Predicted=5976.9585, Expected=7250.0000
# Month=44, Predicted=7427.8610, Expected=6830.0000
# Month=45, Predicted=6523.0635, Expected=6810.0000
# Month=46, Predicted=6930.5754, Expected=5810.0000
# Month=47, Predicted=5828.0480, Expected=6220.0000
# Month=48, Predicted=6292.8060, Expected=7450.0000
# Month=49, Predicted=7530.5342, Expected=9370.0000
# Month=50, Predicted=9488.3954, Expected=7980.0000
# Month=51, Predicted=8469.3049, Expected=6050.0000
# Month=52, Predicted=6203.4848, Expected=5640.0000
# Month=53, Predicted=5582.3807, Expected=6220.0000
# Month=54, Predicted=6380.4886, Expected=5740.0000
# Month=55, Predicted=5427.2810, Expected=6040.0000
# Month=56, Predicted=6155.0970, Expected=5130.0000
# Month=57, Predicted=4974.1257, Expected=5090.0000
# Month=58, Predicted=5180.1130, Expected=5210.0000
# Month=59, Predicted=5304.5885, Expected=4910.0000
# Month=60, Predicted=4931.8753, Expected=6890.0000
# Run 15 — RMSE: 1232.247771, MSE: 1518434.568649, NMSE: 0.0058592738, sMAPE: 11.639347
#
# ===== RUN 16/2 =====
# Training complete for run 16
# Month=1, Predicted=9912.2223, Expected=11870.0000
# Month=2, Predicted=11539.2471, Expected=12920.0000
# Month=3, Predicted=12139.7432, Expected=10890.0000
# Month=4, Predicted=10563.6171, Expected=9500.0000
# Month=5, Predicted=9408.8405, Expected=9490.0000
# Month=6, Predicted=9726.7333, Expected=9500.0000
# Month=7, Predicted=9738.3778, Expected=10880.0000
# Month=8, Predicted=10952.9681, Expected=9270.0000
# Month=9, Predicted=9415.4521, Expected=8880.0000
# Month=10, Predicted=8870.9079, Expected=7780.0000
# Month=11, Predicted=8045.6466, Expected=8360.0000
# Month=12, Predicted=8448.2261, Expected=12320.0000
# Month=13, Predicted=13463.4845, Expected=13490.0000
# ...
# Month=59, Predicted=5247.8475, Expected=4910.0000
# Month=60, Predicted=4867.6834, Expected=6890.0000
# Run 25 — RMSE: 1246.553068, MSE: 1553894.551829, NMSE: 0.0061670312, sMAPE: 11.660998
#
# ===== RUN 26/2 =====
# Training complete for run 26
# Month=1, Predicted=9641.1836, Expected=11870.0000
# Month=2, Predicted=11851.1836, Expected=12920.0000
# Month=3, Predicted=12901.1836, Expected=10890.0000
# Month=4, Predicted=10871.1836, Expected=9500.0000
# Month=5, Predicted=9481.1836, Expected=9490.0000
# Month=6, Predicted=9471.1836, Expected=9500.0000
# Month=7, Predicted=9481.1836, Expected=10880.0000
# Month=8, Predicted=10861.1836, Expected=9270.0000
# Month=9, Predicted=9251.1836, Expected=8880.0000
# Month=10, Predicted=8861.1836, Expected=7780.0000
# Month=11, Predicted=7761.1836, Expected=8360.0000
# Month=12, Predicted=8341.1836, Expected=12320.0000
# Month=13, Predicted=12301.1836, Expected=13490.0000
# Month=14, Predicted=13471.1202, Expected=12710.0000
# Month=15, Predicted=12691.1836, Expected=10130.0000
# Month=16, Predicted=10111.1836, Expected=9240.0000
# Month=17, Predicted=9221.1836, Expected=9640.0000
# Month=18, Predicted=9621.1836, Expected=8920.0000
# Month=19, Predicted=8901.1836, Expected=8900.0000
# Month=20, Predicted=8881.1836, Expected=8480.0000
# Month=21, Predicted=8461.1836, Expected=7870.0000
# Month=22, Predicted=7851.1836, Expected=7860.0000
# Month=23, Predicted=7841.1836, Expected=8990.0000
# Month=24, Predicted=8971.1836, Expected=10790.0000
# Month=25, Predicted=10771.1836, Expected=11820.0000
# Month=26, Predicted=11801.1836, Expected=10590.0000
# Month=27, Predicted=10571.1836, Expected=9430.0000
# Month=28, Predicted=9411.1836, Expected=9070.0000
# Month=29, Predicted=9051.1836, Expected=8250.0000
# Month=30, Predicted=8231.1836, Expected=8740.0000
# Month=31, Predicted=8721.1836, Expected=9120.0000
# Month=32, Predicted=9101.1836, Expected=8280.0000
# Month=33, Predicted=8261.1836, Expected=7860.0000
# Month=34, Predicted=7841.1836, Expected=7150.0000
# Month=35, Predicted=7131.1836, Expected=8110.0000
# Month=36, Predicted=8091.1836, Expected=10860.0000
# Month=37, Predicted=10841.1836, Expected=10730.0000
# Month=38, Predicted=10711.1836, Expected=9610.0000
# Month=39, Predicted=9591.1836, Expected=8270.0000
# Month=40, Predicted=8251.1836, Expected=9200.0000
# Month=41, Predicted=9181.1836, Expected=6660.0000
# Month=42, Predicted=6641.1836, Expected=6270.0000
# Month=43, Predicted=6251.1836, Expected=7250.0000
# Month=44, Predicted=7231.1836, Expected=6830.0000
# Month=45, Predicted=6811.1836, Expected=6810.0000
# Month=46, Predicted=6791.1836, Expected=5810.0000
# Month=47, Predicted=5791.1836, Expected=6220.0000
# Month=48, Predicted=6201.1836, Expected=7450.0000
# Month=49, Predicted=7431.1836, Expected=9370.0000
# Month=50, Predicted=9351.1836, Expected=7980.0000
# Month=51, Predicted=7961.1836, Expected=6050.0000
# Month=52, Predicted=6031.1836, Expected=5640.0000
# Month=53, Predicted=5621.1836, Expected=6220.0000
# Month=54, Predicted=6201.1836, Expected=5740.0000
# Month=55, Predicted=5721.1836, Expected=6040.0000
# Month=56, Predicted=6021.1836, Expected=5130.0000
# Month=57, Predicted=5111.1836, Expected=5090.0000
# Month=58, Predicted=5071.1836, Expected=5210.0000
# Month=59, Predicted=5191.1836, Expected=4910.0000
# Month=60, Predicted=4891.1836, Expected=6890.0000
# Run 26 — RMSE: 1247.370595, MSE: 1555933.401778, NMSE: 0.0060459076, sMAPE: 11.121187
#
# ===== RUN 27/2 =====
# Training complete for run 27
# Month=1, Predicted=9949.1402, Expected=11870.0000
# Month=2, Predicted=11192.7124, Expected=12920.0000
# Month=3, Predicted=12477.9130, Expected=10890.0000
# Month=4, Predicted=11234.8900, Expected=9500.0000
# Month=5, Predicted=9477.6649, Expected=9490.0000
# Month=6, Predicted=9785.0983, Expected=9500.0000
# Month=7, Predicted=9708.4386, Expected=10880.0000
# Month=8, Predicted=11053.8234, Expected=9270.0000
# Month=9, Predicted=9585.5030, Expected=8880.0000
# Month=10, Predicted=8860.4344, Expected=7780.0000
# Month=11, Predicted=7932.7427, Expected=8360.0000
# Month=12, Predicted=8514.4581, Expected=12320.0000
# Month=13, Predicted=12687.3561, Expected=13490.0000
# Month=14, Predicted=13882.6495, Expected=12710.0000
# Month=15, Predicted=12630.4058, Expected=10130.0000
# Month=16, Predicted=9890.7625, Expected=9240.0000
# Month=17, Predicted=9498.9928, Expected=9640.0000
# Month=18, Predicted=10039.6493, Expected=8920.0000
# Month=19, Predicted=8846.8626, Expected=8900.0000
# Month=20, Predicted=9015.1690, Expected=8480.0000
# Month=21, Predicted=8590.3924, Expected=7870.0000
# Month=22, Predicted=7954.5667, Expected=7860.0000
# Month=23, Predicted=8033.3035, Expected=8990.0000
# Month=24, Predicted=9188.0379, Expected=10790.0000
# Month=25, Predicted=10518.0626, Expected=11820.0000
# Month=26, Predicted=11322.8486, Expected=10590.0000
# Month=27, Predicted=10619.6221, Expected=9430.0000
# Month=28, Predicted=9351.0958, Expected=9070.0000
# Month=29, Predicted=9263.5595, Expected=8250.0000
# Month=30, Predicted=8394.2597, Expected=8740.0000
# Month=31, Predicted=8915.7849, Expected=9120.0000
# Month=32, Predicted=9139.2797, Expected=8280.0000
# Month=33, Predicted=8107.8954, Expected=7860.0000
# Month=34, Predicted=7932.4522, Expected=7150.0000
# Month=35, Predicted=7282.6349, Expected=8110.0000
# Month=36, Predicted=8298.9833, Expected=10860.0000
# Month=37, Predicted=10909.7239, Expected=10730.0000
# Month=38, Predicted=10923.6087, Expected=9610.0000
# Month=39, Predicted=9521.5862, Expected=8270.0000
# Month=40, Predicted=8250.6278, Expected=9200.0000
# Month=41, Predicted=9395.3763, Expected=6660.0000
# Month=42, Predicted=7303.0859, Expected=6270.0000
# Month=43, Predicted=6503.7765, Expected=7250.0000
# Month=44, Predicted=7647.1260, Expected=6830.0000
# Month=45, Predicted=6656.1202, Expected=6810.0000
# Month=46, Predicted=6912.5260, Expected=5810.0000
# Month=47, Predicted=5779.7160, Expected=6220.0000
# Month=48, Predicted=6354.8080, Expected=7450.0000
# Month=49, Predicted=7599.7067, Expected=9370.0000
# Month=50, Predicted=9027.0935, Expected=7980.0000
# Month=51, Predicted=8320.2557, Expected=6050.0000
# Month=52, Predicted=5819.2477, Expected=5640.0000
# Month=53, Predicted=5810.1242, Expected=6220.0000
# Month=54, Predicted=6549.9738, Expected=5740.0000
# Month=55, Predicted=5591.0279, Expected=6040.0000
# Month=56, Predicted=6171.7052, Expected=5130.0000
# Month=57, Predicted=5027.4187, Expected=5090.0000
# Month=58, Predicted=5197.0023, Expected=5210.0000
# Month=59, Predicted=5391.5539, Expected=4910.0000
# Month=60, Predicted=4955.9085, Expected=6890.0000
# Run 27 — RMSE: 1245.952814, MSE: 1552398.414881, NMSE: 0.0061943007, sMAPE: 11.346903
#
# ===== RUN 28/2 =====
# Training complete for run 28
# Month=1, Predicted=9745.3107, Expected=11870.0000
# Month=2, Predicted=11448.4711, Expected=12920.0000
# Month=3, Predicted=12572.1765, Expected=10890.0000
# Month=4, Predicted=10616.8113, Expected=9500.0000
# Month=5, Predicted=9540.3433, Expected=9490.0000
# Month=6, Predicted=9567.9626, Expected=9500.0000
# Month=7, Predicted=9673.5952, Expected=10880.0000
# Month=8, Predicted=10947.4514, Expected=9270.0000
# Month=9, Predicted=9202.5921, Expected=8880.0000
# Month=10, Predicted=8855.8330, Expected=7780.0000
# Month=11, Predicted=8035.9916, Expected=8360.0000
# Month=12, Predicted=8406.3964, Expected=12320.0000
# Month=13, Predicted=12167.4733, Expected=13490.0000
# Month=14, Predicted=14260.0725, Expected=12710.0000
# Month=15, Predicted=11815.1238, Expected=10130.0000
# Month=16, Predicted=10329.0801, Expected=9240.0000
# Month=17, Predicted=9141.2642, Expected=9640.0000
# Month=18, Predicted=9826.5451, Expected=8920.0000
# Month=19, Predicted=8876.5458, Expected=8900.0000
# Month=20, Predicted=8986.2358, Expected=8480.0000
# Month=21, Predicted=8602.7768, Expected=7870.0000
# Month=22, Predicted=8040.2777, Expected=7860.0000
# Month=23, Predicted=7970.9024, Expected=8990.0000
# Month=24, Predicted=9088.9063, Expected=10790.0000
# Month=25, Predicted=10562.3787, Expected=11820.0000
# Month=26, Predicted=11482.2547, Expected=10590.0000
# Month=27, Predicted=10284.9197, Expected=9430.0000
# Month=28, Predicted=9613.2252, Expected=9070.0000
# Month=29, Predicted=9181.5555, Expected=8250.0000
# Month=30, Predicted=8468.8982, Expected=8740.0000
# Month=31, Predicted=8800.6292, Expected=9120.0000
# Month=32, Predicted=9116.6378, Expected=8280.0000
# Month=33, Predicted=8191.6458, Expected=7860.0000
# Month=34, Predicted=7984.1635, Expected=7150.0000
# Month=35, Predicted=7353.0614, Expected=8110.0000
# Month=36, Predicted=8181.5752, Expected=10860.0000
# Month=37, Predicted=10733.6358, Expected=10730.0000
# Month=38, Predicted=11177.5032, Expected=9610.0000
# Month=39, Predicted=9398.5349, Expected=8270.0000
# Month=40, Predicted=8522.3419, Expected=9200.0000
# Month=41, Predicted=9259.9625, Expected=6660.0000
# Month=42, Predicted=6582.3469, Expected=6270.0000
# Month=43, Predicted=6129.5612, Expected=7250.0000
# Month=44, Predicted=7530.3161, Expected=6830.0000
# Month=45, Predicted=6600.3006, Expected=6810.0000
# Month=46, Predicted=6900.5842, Expected=5810.0000
# Month=47, Predicted=5885.6252, Expected=6220.0000
# Month=48, Predicted=6266.2724, Expected=7450.0000
# Month=49, Predicted=7498.8953, Expected=9370.0000
# Month=50, Predicted=9105.9123, Expected=7980.0000
# Month=51, Predicted=8164.9618, Expected=6050.0000
# Month=52, Predicted=6256.9486, Expected=5640.0000
# Month=53, Predicted=5608.0402, Expected=6220.0000
# Month=54, Predicted=6435.0401, Expected=5740.0000
# Month=55, Predicted=5621.9979, Expected=6040.0000
# Month=56, Predicted=6127.7806, Expected=5130.0000
# Month=57, Predicted=5085.4925, Expected=5090.0000
# Month=58, Predicted=5158.7555, Expected=5210.0000
# Month=59, Predicted=5347.7047, Expected=4910.0000
# Month=60, Predicted=4971.5802, Expected=6890.0000
# Run 28 — RMSE: 1228.050611, MSE: 1508108.303148, NMSE: 0.0061356310, sMAPE: 11.254317
#
# ===== RUN 29/2 =====
# Training complete for run 29
# Month=1, Predicted=9796.7852, Expected=11870.0000
# Month=2, Predicted=11245.7743, Expected=12920.0000
# Month=3, Predicted=12514.8131, Expected=10890.0000
# Month=4, Predicted=11142.6617, Expected=9500.0000
# Month=5, Predicted=9425.3836, Expected=9490.0000
# Month=6, Predicted=9537.9046, Expected=9500.0000
# Month=7, Predicted=9653.9896, Expected=10880.0000
# Month=8, Predicted=11023.7222, Expected=9270.0000
# Month=9, Predicted=9565.6410, Expected=8880.0000
# Month=10, Predicted=8854.1696, Expected=7780.0000
# Month=11, Predicted=7961.4627, Expected=8360.0000
# Month=12, Predicted=8438.6463, Expected=12320.0000
# Month=13, Predicted=12376.4706, Expected=13490.0000
# Month=14, Predicted=13765.8805, Expected=12710.0000
# Month=15, Predicted=12527.8034, Expected=10130.0000
# Month=16, Predicted=10201.0903, Expected=9240.0000
# Month=17, Predicted=9111.7552, Expected=9640.0000
# Month=18, Predicted=9764.1052, Expected=8920.0000
# Month=19, Predicted=8770.0615, Expected=8900.0000
# Month=20, Predicted=9031.0068, Expected=8480.0000
# Month=21, Predicted=8629.4134, Expected=7870.0000
# Month=22, Predicted=8040.9311, Expected=7860.0000
# Month=23, Predicted=8003.2623, Expected=8990.0000
# Month=24, Predicted=9136.8830, Expected=10790.0000
# Month=25, Predicted=10559.9130, Expected=11820.0000
# Month=26, Predicted=11377.3155, Expected=10590.0000
# Month=27, Predicted=10600.0299, Expected=9430.0000
# Month=28, Predicted=9502.9609, Expected=9070.0000
# Month=29, Predicted=9154.2328, Expected=8250.0000
# Month=30, Predicted=8425.7805, Expected=8740.0000
# Month=31, Predicted=8854.6549, Expected=9120.0000
# Month=32, Predicted=9089.6040, Expected=8280.0000
# Month=33, Predicted=8133.1382, Expected=7860.0000
# Month=34, Predicted=7989.8845, Expected=7150.0000
# Month=35, Predicted=7323.2502, Expected=8110.0000
# Month=36, Predicted=8236.3676, Expected=10860.0000
# Month=37, Predicted=10888.0409, Expected=10730.0000
# Month=38, Predicted=11037.3445, Expected=9610.0000
# Month=39, Predicted=9551.1759, Expected=8270.0000
# Month=40, Predicted=8394.8560, Expected=9200.0000
# Month=41, Predicted=9248.5863, Expected=6660.0000
# Month=42, Predicted=7088.9187, Expected=6270.0000
# Month=43, Predicted=6137.1502, Expected=7250.0000
# Month=44, Predicted=7417.2388, Expected=6830.0000
# Month=45, Predicted=6620.8610, Expected=6810.0000
# Month=46, Predicted=6947.0377, Expected=5810.0000
# Month=47, Predicted=5812.9361, Expected=6220.0000
# Month=48, Predicted=6311.3397, Expected=7450.0000
# Month=49, Predicted=7554.0713, Expected=9370.0000
# Month=50, Predicted=9089.1997, Expected=7980.0000
# Month=51, Predicted=8403.2163, Expected=6050.0000
# Month=52, Predicted=6074.0872, Expected=5640.0000
# Month=53, Predicted=5608.1367, Expected=6220.0000
# Month=54, Predicted=6380.0979, Expected=5740.0000
# Month=55, Predicted=5543.5327, Expected=6040.0000
# Month=56, Predicted=6182.1282, Expected=5130.0000
# Month=57, Predicted=5003.5931, Expected=5090.0000
# Month=58, Predicted=5198.5254, Expected=5210.0000
# Month=59, Predicted=5363.0340, Expected=4910.0000
# Month=60, Predicted=5007.3725, Expected=6890.0000
# Run 29 — RMSE: 1254.740583, MSE: 1574373.929902, NMSE: 0.0063406196, sMAPE: 11.602188
#
# ===== RUN 30/2 =====
# Training complete for run 30
# Month=1, Predicted=10014.4519, Expected=11870.0000
# Month=2, Predicted=11722.9541, Expected=12920.0000
# Month=3, Predicted=12582.2762, Expected=10890.0000
# Month=4, Predicted=11125.4379, Expected=9500.0000
# Month=5, Predicted=9280.9316, Expected=9490.0000
# Month=6, Predicted=9955.2278, Expected=9500.0000
# Month=7, Predicted=9791.2483, Expected=10880.0000
# Month=8, Predicted=10909.3652, Expected=9270.0000
# Month=9, Predicted=9695.3583, Expected=8880.0000
# Month=10, Predicted=8760.7488, Expected=7780.0000
# Month=11, Predicted=8242.4779, Expected=8360.0000
# Month=12, Predicted=8508.6973, Expected=12320.0000
# Month=13, Predicted=13063.1483, Expected=13490.0000
# Month=14, Predicted=14036.3989, Expected=12710.0000
# Month=15, Predicted=11550.6849, Expected=10130.0000
# Month=16, Predicted=9802.4749, Expected=9240.0000
# Month=17, Predicted=9129.9201, Expected=9640.0000
# Month=18, Predicted=10356.0834, Expected=8920.0000
# Month=19, Predicted=8978.1862, Expected=8900.0000
# Month=20, Predicted=8961.8053, Expected=8480.0000
# Month=21, Predicted=8649.4997, Expected=7870.0000
# Month=22, Predicted=7969.1117, Expected=7860.0000
# Month=23, Predicted=8043.9799, Expected=8990.0000
# Month=24, Predicted=9111.2578, Expected=10790.0000
# Month=25, Predicted=10710.1971, Expected=11820.0000
# Month=26, Predicted=11470.6337, Expected=10590.0000
# Month=27, Predicted=10451.6374, Expected=9430.0000
# Month=28, Predicted=9327.0403, Expected=9070.0000
# Month=29, Predicted=9351.4005, Expected=8250.0000
# Month=30, Predicted=8589.9273, Expected=8740.0000
# Month=31, Predicted=8914.9795, Expected=9120.0000
# Month=32, Predicted=9243.0845, Expected=8280.0000
# Month=33, Predicted=7940.7059, Expected=7860.0000
# Month=34, Predicted=7896.0035, Expected=7150.0000
# Month=35, Predicted=7396.9502, Expected=8110.0000
# Month=36, Predicted=8301.9137, Expected=10860.0000
# Month=37, Predicted=11215.0117, Expected=10730.0000
# Month=38, Predicted=11117.1125, Expected=9610.0000
# Month=39, Predicted=9267.9480, Expected=8270.0000
# Month=40, Predicted=8201.0040, Expected=9200.0000
# Month=41, Predicted=9446.0185, Expected=6660.0000
# Month=42, Predicted=7877.4316, Expected=6270.0000
# Month=43, Predicted=6061.5574, Expected=7250.0000
# Month=44, Predicted=7903.1228, Expected=6830.0000
# Month=45, Predicted=6543.4496, Expected=6810.0000
# Month=46, Predicted=6851.1867, Expected=5810.0000
# Month=47, Predicted=5933.7224, Expected=6220.0000
# Month=48, Predicted=6315.8426, Expected=7450.0000
# Month=49, Predicted=7733.1274, Expected=9370.0000
# Month=50, Predicted=9235.3884, Expected=7980.0000
# Month=51, Predicted=8361.4688, Expected=6050.0000
# Month=52, Predicted=5635.6111, Expected=5640.0000
# Month=53, Predicted=5785.1396, Expected=6220.0000
# Month=54, Predicted=6743.0703, Expected=5740.0000
# Month=55, Predicted=5427.1395, Expected=6040.0000
# Month=56, Predicted=6094.0407, Expected=5130.0000
# Month=57, Predicted=5077.5064, Expected=5090.0000
# Month=58, Predicted=5145.7257, Expected=5210.0000
# Month=59, Predicted=5389.1361, Expected=4910.0000
# Month=60, Predicted=4876.3791, Expected=6890.0000
# Run 30 — RMSE: 1232.206333, MSE: 1518332.447719, NMSE: 0.0059013545, sMAPE: 11.456676

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on M4 Monthly (30 runs) =====
# RMSE: 1238.860001 ± 24.788833
# MSE:  1535388.587727 ± 60740.177095
# NMSE: 0.0061000565 ± 0.0001838234
# sMAPE: 11.490206 ± 0.292209
#
# Best run: 16
#   RMSE: 1165.911447
#   MSE:  1359349.502284
#   NMSE: 0.0055581250
#   sMAPE: 10.803195

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Hybrid (Feature Aug + Gate) — M4 Monthly\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Hybrid (Feature Aug + Gate) — M4 Monthly\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 1165.911447
# MSE:  1359349.502284
# NMSE: 0.0055581250
# sMAPE: 10.803195

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on M4 Monthly
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
# Out:
# Total notebook execution time: 0h 32m 2.29s
# Total seconds: 1922.29
