# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: S&P 500
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 505 (1.97 KB)
#  Trainable params: 505 (1.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — S&P 500

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/sp500.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (251,)
# First 5 values: [2038.199951 2013.780029 2011.709961 1985.319946 1945.969971]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (250, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (190, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (190, 1, 2), y_train shape: (190,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=2155.6376, Expected=2158.2200
# Month=2, Predicted=2159.2890, Expected=2164.1899
# Month=3, Predicted=2164.8882, Expected=2160.3899
# Month=4, Predicted=2160.7992, Expected=2161.3501
# Month=5, Predicted=2162.1526, Expected=2137.6699
# Month=6, Predicted=2137.4619, Expected=2130.2600
# Month=7, Predicted=2133.4958, Expected=2139.6799
# Month=8, Predicted=2140.7757, Expected=2132.9500
# Month=9, Predicted=2133.1787, Expected=2138.3101
# Month=10, Predicted=2139.3195, Expected=2140.8101
# Month=11, Predicted=2141.3801, Expected=2142.5100
# Month=12, Predicted=2143.1381, Expected=2139.4299
# Month=13, Predicted=2139.9681, Expected=2148.5000
# Month=14, Predicted=2149.4121, Expected=2149.7200
# Month=15, Predicted=2150.1491, Expected=2136.9700
# Month=16, Predicted=2137.2294, Expected=2144.0601
# Month=17, Predicted=2145.5601, Expected=2132.2300
# Month=18, Predicted=2132.3499, Expected=2129.7800
# Month=19, Predicted=2131.1065, Expected=2128.6799
# Month=20, Predicted=2129.3894, Expected=2109.4299
# Month=21, Predicted=2109.5285, Expected=2098.8000
# Month=22, Predicted=2101.1318, Expected=2083.7900
# Month=23, Predicted=2084.7905, Expected=2100.5901
# Month=24, Predicted=2102.4249, Expected=2129.9199
# Month=25, Predicted=2130.1421, Expected=2131.5601
# Month=26, Predicted=2130.7628, Expected=2167.4900
# Month=27, Predicted=2168.7838, Expected=2162.7100
# Month=28, Predicted=2161.4322, Expected=2165.6399
# Month=29, Predicted=2166.5483, Expected=2168.2900
# Month=30, Predicted=2168.9250, Expected=2177.5300
# Month=31, Predicted=2178.3025, Expected=2178.6101
# Month=32, Predicted=2179.0319, Expected=2186.8501
# Month=33, Predicted=2187.6436, Expected=2186.4299
# Month=34, Predicted=2186.8541, Expected=2201.5601
# Month=35, Predicted=2202.5198, Expected=2198.5500
# Month=36, Predicted=2198.6457, Expected=2206.2700
# Month=37, Predicted=2207.1642, Expected=2210.2100
# Month=38, Predicted=2210.7373, Expected=2200.7600
# Month=39, Predicted=2201.0539, Expected=2204.9700
# Month=40, Predicted=2206.1424, Expected=2200.1699
# Month=41, Predicted=2200.5963, Expected=2191.1201
# Month=42, Predicted=2191.7678, Expected=2200.6499
# Month=43, Predicted=2201.8517, Expected=2207.2600
# Month=44, Predicted=2207.7660, Expected=2210.7200
# Month=45, Predicted=2211.2783, Expected=2241.1299
# Month=46, Predicted=2242.2504, Expected=2249.7300
# Month=47, Predicted=2248.8723, Expected=2258.8301
# Month=48, Predicted=2259.4333, Expected=2263.3201
# Month=49, Predicted=2263.8118, Expected=2268.3501
# Month=50, Predicted=2268.9985, Expected=2253.7700
# Month=51, Predicted=2253.8347, Expected=2266.8101
# Month=52, Predicted=2268.5637, Expected=2259.2400
# Month=53, Predicted=2259.3244, Expected=2266.5000
# Month=54, Predicted=2267.5844, Expected=2270.5400
# Month=55, Predicted=2271.0846, Expected=2262.9299
# Month=56, Predicted=2263.2814, Expected=2260.2500
# Month=57, Predicted=2261.2025, Expected=2266.2300
# Month=58, Predicted=2267.0755, Expected=2270.2300
# Month=59, Predicted=2270.8127, Expected=2249.5000
# Month=60, Predicted=2249.3119, Expected=2251.6101
# Run 1 — RMSE: 11.217908, MSE: 125.841459, NMSE: 0.0007650188
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=2156.0768, Expected=2158.2200
# Month=2, Predicted=2159.1469, Expected=2164.1899
# Month=3, Predicted=2165.1168, Expected=2160.3899
# Month=4, Predicted=2161.3168, Expected=2161.3501
# Month=5, Predicted=2162.2770, Expected=2137.6699
# Month=6, Predicted=2138.5968, Expected=2130.2600
# Month=7, Predicted=2131.1869, Expected=2139.6799
# Month=8, Predicted=2140.6068, Expected=2132.9500
# Month=9, Predicted=2133.8768, Expected=2138.3101
# Month=10, Predicted=2139.2369, Expected=2140.8101
# Month=11, Predicted=2141.7369, Expected=2142.5100
# Month=12, Predicted=2143.4369, Expected=2139.4299
# Month=13, Predicted=2140.3568, Expected=2148.5000
# Month=14, Predicted=2149.4269, Expected=2149.7200
# Month=15, Predicted=2150.6469, Expected=2136.9700
# Month=16, Predicted=2137.8969, Expected=2144.0601
# Month=17, Predicted=2144.9869, Expected=2132.2300
# Month=18, Predicted=2133.1569, Expected=2129.7800
# Month=19, Predicted=2130.7069, Expected=2128.6799
# Month=20, Predicted=2129.6068, Expected=2109.4299
# Month=21, Predicted=2110.3568, Expected=2098.8000
# Month=22, Predicted=2099.7269, Expected=2083.7900
# Month=23, Predicted=2084.7169, Expected=2100.5901
# Month=24, Predicted=2101.5170, Expected=2129.9199
# Month=25, Predicted=2130.8468, Expected=2131.5601
# Month=26, Predicted=2132.4869, Expected=2167.4900
# Month=27, Predicted=2168.4169, Expected=2162.7100
# Month=28, Predicted=2163.6368, Expected=2165.6399
# Month=29, Predicted=2166.5668, Expected=2168.2900
# Month=30, Predicted=2169.2169, Expected=2177.5300
# Month=31, Predicted=2178.4569, Expected=2178.6101
# Month=32, Predicted=2179.5370, Expected=2186.8501
# Month=33, Predicted=2187.7770, Expected=2186.4299
# Month=34, Predicted=2187.3568, Expected=2201.5601
# Month=35, Predicted=2202.4869, Expected=2198.5500
# Month=36, Predicted=2199.4769, Expected=2206.2700
# Month=37, Predicted=2207.1969, Expected=2210.2100
# Month=38, Predicted=2211.1368, Expected=2200.7600
# Month=39, Predicted=2201.6869, Expected=2204.9700
# Month=40, Predicted=2205.8969, Expected=2200.1699
# Month=41, Predicted=2201.0968, Expected=2191.1201
# Month=42, Predicted=2192.0470, Expected=2200.6499
# Month=43, Predicted=2201.5768, Expected=2207.2600
# Month=44, Predicted=2208.1869, Expected=2210.7200
# Month=45, Predicted=2211.6469, Expected=2241.1299
# Month=46, Predicted=2242.0568, Expected=2249.7300
# Month=47, Predicted=2250.6569, Expected=2258.8301
# Month=48, Predicted=2259.7570, Expected=2263.3201
# Month=49, Predicted=2264.2470, Expected=2268.3501
# Month=50, Predicted=2269.2770, Expected=2253.7700
# Month=51, Predicted=2254.6969, Expected=2266.8101
# Month=52, Predicted=2267.7369, Expected=2259.2400
# Month=53, Predicted=2260.1669, Expected=2266.5000
# Month=54, Predicted=2267.4269, Expected=2270.5400
# Month=55, Predicted=2271.4669, Expected=2262.9299
# Month=56, Predicted=2263.8568, Expected=2260.2500
# Month=57, Predicted=2261.1769, Expected=2266.2300
# Month=58, Predicted=2267.1569, Expected=2270.2300
# Month=59, Predicted=2271.1569, Expected=2249.5000
# Month=60, Predicted=2250.4269, Expected=2251.6101
# Run 2 — RMSE: 11.083440, MSE: 122.842637, NMSE: 0.0007439119
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=2155.7329, Expected=2158.2200
# Month=2, Predicted=2160.8899, Expected=2164.1899
# Month=3, Predicted=2163.5195, Expected=2160.3899
# Month=4, Predicted=2159.8065, Expected=2161.3501
# Month=5, Predicted=2162.5481, Expected=2137.6699
# Month=6, Predicted=2138.1810, Expected=2130.2600
# Month=7, Predicted=2133.7467, Expected=2139.6799
# Month=8, Predicted=2141.9732, Expected=2132.9500
# Month=9, Predicted=2132.4651, Expected=2138.3101
# Month=10, Predicted=2140.4563, Expected=2140.8101
# Month=11, Predicted=2140.0794, Expected=2142.5100
# Month=12, Predicted=2142.0591, Expected=2139.4299
# Month=13, Predicted=2139.2634, Expected=2148.5000
# Month=14, Predicted=2149.2659, Expected=2149.7200
# Month=15, Predicted=2149.0140, Expected=2136.9700
# Month=16, Predicted=2137.2027, Expected=2144.0601
# Month=17, Predicted=2147.8851, Expected=2132.2300
# Month=18, Predicted=2131.8589, Expected=2129.7800
# Month=19, Predicted=2133.3358, Expected=2128.6799
# Month=20, Predicted=2129.4799, Expected=2109.4299
# Month=21, Predicted=2110.3045, Expected=2098.8000
# Month=22, Predicted=2102.6163, Expected=2083.7900
# Month=23, Predicted=2086.8727, Expected=2100.5901
# Month=24, Predicted=2104.8766, Expected=2129.9199
# Month=25, Predicted=2128.8304, Expected=2131.5601
# Month=26, Predicted=2132.3770, Expected=2167.4900
# Month=27, Predicted=2166.0218, Expected=2162.7100
# Month=28, Predicted=2164.3510, Expected=2165.6399
# Month=29, Predicted=2167.1307, Expected=2168.2900
# Month=30, Predicted=2167.7457, Expected=2177.5300
# Month=31, Predicted=2176.8211, Expected=2178.6101
# Month=32, Predicted=2177.9106, Expected=2186.8501
# Month=33, Predicted=2186.4618, Expected=2186.4299
# Month=34, Predicted=2185.7539, Expected=2201.5601
# Month=35, Predicted=2201.3009, Expected=2198.5500
# Month=36, Predicted=2198.2469, Expected=2206.2700
# Month=37, Predicted=2207.0474, Expected=2210.2100
# Month=38, Predicted=2209.4227, Expected=2200.7600
# Month=39, Predicted=2200.4796, Expected=2204.9700
# Month=40, Predicted=2208.0136, Expected=2200.1699
# Month=41, Predicted=2199.7017, Expected=2191.1201
# Month=42, Predicted=2192.8205, Expected=2200.6499
# Month=43, Predicted=2203.5549, Expected=2207.2600
# Month=44, Predicted=2206.4242, Expected=2210.7200
# Month=45, Predicted=2209.9448, Expected=2241.1299
# Month=46, Predicted=2239.7399, Expected=2249.7300
# Month=47, Predicted=2250.3859, Expected=2258.8301
# Month=48, Predicted=2257.8964, Expected=2263.3201
# Month=49, Predicted=2262.5311, Expected=2268.3501
# Month=50, Predicted=2267.5855, Expected=2253.7700
# Month=51, Predicted=2253.5664, Expected=2266.8101
# Month=52, Predicted=2270.9744, Expected=2259.2400
# Month=53, Predicted=2258.9039, Expected=2266.5000
# Month=54, Predicted=2268.9211, Expected=2270.5400
# Month=55, Predicted=2269.7468, Expected=2262.9299
# Month=56, Predicted=2262.5774, Expected=2260.2500
# Month=57, Predicted=2262.7562, Expected=2266.2300
# Month=58, Predicted=2266.9393, Expected=2270.2300
# Month=59, Predicted=2269.4535, Expected=2249.5000
# Month=60, Predicted=2249.5479, Expected=2251.6101
# Run 3 — RMSE: 11.153947, MSE: 124.410541, NMSE: 0.0007660456
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=2155.7949, Expected=2158.2200
# Month=2, Predicted=2159.2439, Expected=2164.1899
# Month=3, Predicted=2164.3833, Expected=2160.3899
# Month=4, Predicted=2160.6767, Expected=2161.3501
# Month=5, Predicted=2162.0058, Expected=2137.6699
# Month=6, Predicted=2138.6326, Expected=2130.2600
# Month=7, Predicted=2133.9344, Expected=2139.6799
# Month=8, Predicted=2140.5215, Expected=2132.9500
# Month=9, Predicted=2133.2426, Expected=2138.3101
# Month=10, Predicted=2139.1513, Expected=2140.8101
# Month=11, Predicted=2140.9913, Expected=2142.5100
# Month=12, Predicted=2142.7994, Expected=2139.4299
# Month=13, Predicted=2139.8387, Expected=2148.5000
# Month=14, Predicted=2148.9726, Expected=2149.7200
# Month=15, Predicted=2149.8457, Expected=2136.9700
# Month=16, Predicted=2137.6142, Expected=2144.0601
# Month=17, Predicted=2145.5921, Expected=2132.2300
# Month=18, Predicted=2132.6735, Expected=2129.7800
# Month=19, Predicted=2131.3232, Expected=2128.6799
# Month=20, Predicted=2129.2735, Expected=2109.4299
# Month=21, Predicted=2110.3772, Expected=2098.8000
# Month=22, Predicted=2101.6799, Expected=2083.7900
# Month=23, Predicted=2085.4794, Expected=2100.5901
# Month=24, Predicted=2102.2963, Expected=2129.9199
# Month=25, Predicted=2129.1534, Expected=2131.5601
# Month=26, Predicted=2131.5372, Expected=2167.4900
# Month=27, Predicted=2167.0534, Expected=2162.7100
# Month=28, Predicted=2162.4803, Expected=2165.6399
# Month=29, Predicted=2166.3588, Expected=2168.2900
# Month=30, Predicted=2168.5471, Expected=2177.5300
# Month=31, Predicted=2177.6808, Expected=2178.6101
# Month=32, Predicted=2178.7348, Expected=2186.8501
# Month=33, Predicted=2187.0887, Expected=2186.4299
# Month=34, Predicted=2186.6025, Expected=2201.5601
# Month=35, Predicted=2201.7523, Expected=2198.5500
# Month=36, Predicted=2198.7144, Expected=2206.2700
# Month=37, Predicted=2206.7625, Expected=2210.2100
# Month=38, Predicted=2210.3060, Expected=2200.7600
# Month=39, Predicted=2201.2226, Expected=2204.9700
# Month=40, Predicted=2206.1163, Expected=2200.1699
# Month=41, Predicted=2200.5243, Expected=2191.1201
# Month=42, Predicted=2192.0470, Expected=2200.6499
# Month=43, Predicted=2201.6691, Expected=2207.2600
# Month=44, Predicted=2207.2661, Expected=2210.7200
# Month=45, Predicted=2210.8477, Expected=2241.1299
# Month=46, Predicted=2240.7575, Expected=2249.7300
# Month=47, Predicted=2249.5748, Expected=2258.8301
# Month=48, Predicted=2258.7817, Expected=2263.3201
# Month=49, Predicted=2263.3746, Expected=2268.3501
# Month=50, Predicted=2268.5087, Expected=2253.7700
# Month=51, Predicted=2254.3253, Expected=2266.8101
# Month=52, Predicted=2268.5237, Expected=2259.2400
# Month=53, Predicted=2259.5239, Expected=2266.5000
# Month=54, Predicted=2267.3987, Expected=2270.5400
# Month=55, Predicted=2270.6445, Expected=2262.9299
# Month=56, Predicted=2263.3481, Expected=2260.2500
# Month=57, Predicted=2261.3018, Expected=2266.2300
# Month=58, Predicted=2266.7246, Expected=2270.2300
# Month=59, Predicted=2270.3660, Expected=2249.5000
# Month=60, Predicted=2250.2457, Expected=2251.6101
# Run 4 — RMSE: 11.161541, MSE: 124.580004, NMSE: 0.0007608263
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=2155.9990, Expected=2158.2200
# Month=2, Predicted=2160.2179, Expected=2164.1899
# Month=3, Predicted=2164.3693, Expected=2160.3899
# Month=4, Predicted=2160.4080, Expected=2161.3501
# Month=5, Predicted=2162.5633, Expected=2137.6699
# Month=6, Predicted=2138.3134, Expected=2130.2600
# Month=7, Predicted=2132.0093, Expected=2139.6799
# Month=8, Predicted=2141.5067, Expected=2132.9500
# Month=9, Predicted=2132.7993, Expected=2138.3101
# Month=10, Predicted=2140.0399, Expected=2140.8101
# Month=11, Predicted=2140.8259, Expected=2142.5100
# Month=12, Predicted=2142.7911, Expected=2139.4299
# Month=13, Predicted=2139.8454, Expected=2148.5000
# Month=14, Predicted=2149.4944, Expected=2149.7200
# Month=15, Predicted=2149.5597, Expected=2136.9700
# Month=16, Predicted=2137.5701, Expected=2144.0601
# Month=17, Predicted=2146.7764, Expected=2132.2300
# Month=18, Predicted=2132.2234, Expected=2129.7800
# Month=19, Predicted=2132.2965, Expected=2128.6799
# Month=20, Predicted=2129.6744, Expected=2109.4299
# Month=21, Predicted=2110.3512, Expected=2098.8000
# Month=22, Predicted=2100.9629, Expected=2083.7900
# Month=23, Predicted=2085.8364, Expected=2100.5901
# Month=24, Predicted=2103.6929, Expected=2129.9199
# Month=25, Predicted=2129.4242, Expected=2131.5601
# Month=26, Predicted=2131.2490, Expected=2167.4900
# Month=27, Predicted=2167.5909, Expected=2162.7100
# Month=28, Predicted=2162.4497, Expected=2165.6399
# Month=29, Predicted=2167.1451, Expected=2168.2900
# Month=30, Predicted=2168.5084, Expected=2177.5300
# Month=31, Predicted=2177.7268, Expected=2178.6101
# Month=32, Predicted=2178.4493, Expected=2186.8501
# Month=33, Predicted=2187.2398, Expected=2186.4299
# Month=34, Predicted=2186.3075, Expected=2201.5601
# Month=35, Predicted=2202.0660, Expected=2198.5500
# Month=36, Predicted=2198.3156, Expected=2206.2700
# Month=37, Predicted=2207.2977, Expected=2210.2100
# Month=38, Predicted=2210.0899, Expected=2200.7600
# Month=39, Predicted=2201.0047, Expected=2204.9700
# Month=40, Predicted=2207.1884, Expected=2200.1699
# Month=41, Predicted=2200.3327, Expected=2191.1201
# Month=42, Predicted=2192.5752, Expected=2200.6499
# Month=43, Predicted=2202.7854, Expected=2207.2600
# Month=44, Predicted=2207.0728, Expected=2210.7200
# Month=45, Predicted=2210.6702, Expected=2241.1299
# Month=46, Predicted=2241.0789, Expected=2249.7300
# Month=47, Predicted=2249.2954, Expected=2258.8301
# Month=48, Predicted=2258.7530, Expected=2263.3201
# Month=49, Predicted=2263.1625, Expected=2268.3501
# Month=50, Predicted=2268.4285, Expected=2253.7700
# Month=51, Predicted=2253.9538, Expected=2266.8101
# Month=52, Predicted=2269.8087, Expected=2259.2400
# Month=53, Predicted=2259.0179, Expected=2266.5000
# Month=54, Predicted=2268.3898, Expected=2270.5400
# Month=55, Predicted=2270.4404, Expected=2262.9299
# Month=56, Predicted=2263.1453, Expected=2260.2500
# Month=57, Predicted=2262.1557, Expected=2266.2300
# Month=58, Predicted=2267.1866, Expected=2270.2300
# Month=59, Predicted=2270.1975, Expected=2249.5000
# Month=60, Predicted=2249.8343, Expected=2251.6101
# Run 5 — RMSE: 11.198119, MSE: 125.397864, NMSE: 0.0007660646
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=2155.6413, Expected=2158.2200
# Month=2, Predicted=2159.3649, Expected=2164.1899
# Month=3, Predicted=2164.2643, Expected=2160.3899
# Month=4, Predicted=2160.4646, Expected=2161.3501
# Month=5, Predicted=2161.9874, Expected=2137.6699
# Month=6, Predicted=2138.3043, Expected=2130.2600
# Month=7, Predicted=2134.3188, Expected=2139.6799
# Month=8, Predicted=2140.6609, Expected=2132.9500
# Month=9, Predicted=2133.0264, Expected=2138.3101
# Month=10, Predicted=2139.2427, Expected=2140.8101
# Month=11, Predicted=2140.8388, Expected=2142.5100
# Month=12, Predicted=2142.6524, Expected=2139.4299
# Month=13, Predicted=2139.6655, Expected=2148.5000
# Month=14, Predicted=2148.9789, Expected=2149.7200
# Month=15, Predicted=2149.7292, Expected=2136.9700
# Month=16, Predicted=2137.3742, Expected=2144.0601
# Month=17, Predicted=2145.8613, Expected=2132.2300
# Month=18, Predicted=2132.3757, Expected=2129.7800
# Month=19, Predicted=2131.5225, Expected=2128.6799
# Month=20, Predicted=2129.2040, Expected=2109.4299
# Month=21, Predicted=2110.1324, Expected=2098.8000
# Month=22, Predicted=2101.9746, Expected=2083.7900
# Month=23, Predicted=2085.5421, Expected=2100.5901
# Month=24, Predicted=2102.6755, Expected=2129.9199
# Month=25, Predicted=2129.8764, Expected=2131.5601
# Month=26, Predicted=2131.3074, Expected=2167.4900
# Month=27, Predicted=2167.3248, Expected=2162.7100
# Month=28, Predicted=2161.6574, Expected=2165.6399
# Month=29, Predicted=2166.3732, Expected=2168.2900
# Month=30, Predicted=2168.4021, Expected=2177.5300
# Month=31, Predicted=2177.5932, Expected=2178.6101
# Month=32, Predicted=2178.6217, Expected=2186.8501
# Month=33, Predicted=2187.0096, Expected=2186.4299
# Month=34, Predicted=2186.4490, Expected=2201.5601
# Month=35, Predicted=2201.7485, Expected=2198.5500
# Month=36, Predicted=2198.7606, Expected=2206.2700
# Month=37, Predicted=2206.7636, Expected=2210.2100
# Month=38, Predicted=2210.1958, Expected=2200.7600
# Month=39, Predicted=2200.9666, Expected=2204.9700
# Month=40, Predicted=2206.2812, Expected=2200.1699
# Month=41, Predicted=2200.3062, Expected=2191.1201
# Month=42, Predicted=2191.9933, Expected=2200.6499
# Month=43, Predicted=2201.8453, Expected=2207.2600
# Month=44, Predicted=2207.2365, Expected=2210.7200
# Month=45, Predicted=2210.7184, Expected=2241.1299
# Month=46, Predicted=2240.9501, Expected=2249.7300
# Month=47, Predicted=2249.7320, Expected=2258.8301
# Month=48, Predicted=2258.7904, Expected=2263.3201
# Month=49, Predicted=2263.3065, Expected=2268.3501
# Month=50, Predicted=2268.3817, Expected=2253.7700
# Month=51, Predicted=2254.0098, Expected=2266.8101
# Month=52, Predicted=2268.8733, Expected=2259.2400
# Month=53, Predicted=2259.3903, Expected=2266.5000
# Month=54, Predicted=2267.5256, Expected=2270.5400
# Month=55, Predicted=2270.5268, Expected=2262.9299
# Month=56, Predicted=2263.1078, Expected=2260.2500
# Month=57, Predicted=2261.3760, Expected=2266.2300
# Month=58, Predicted=2266.7006, Expected=2270.2300
# Month=59, Predicted=2270.2332, Expected=2249.5000
# Month=60, Predicted=2249.8891, Expected=2251.6101
# Run 6 — RMSE: 11.172526, MSE: 124.825345, NMSE: 0.0007629378
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=2155.6881, Expected=2158.2200
# Month=2, Predicted=2159.2110, Expected=2164.1899
# Month=3, Predicted=2164.6958, Expected=2160.3899
# Month=4, Predicted=2160.8544, Expected=2161.3501
# Month=5, Predicted=2162.0720, Expected=2137.6699
# Month=6, Predicted=2137.6430, Expected=2130.2600
# Month=7, Predicted=2133.6961, Expected=2139.6799
# Month=8, Predicted=2140.6187, Expected=2132.9500
# Month=9, Predicted=2133.3896, Expected=2138.3101
# Month=10, Predicted=2139.2523, Expected=2140.8101
# Month=11, Predicted=2141.2904, Expected=2142.5100
# Month=12, Predicted=2143.0405, Expected=2139.4299
# Month=13, Predicted=2139.9284, Expected=2148.5000
# Month=14, Predicted=2149.1931, Expected=2149.7200
# Month=15, Predicted=2150.2016, Expected=2136.9700
# Month=16, Predicted=2137.3742, Expected=2144.0601
# Month=17, Predicted=2145.5472, Expected=2132.2300
# Month=18, Predicted=2132.5505, Expected=2129.7800
# Month=19, Predicted=2131.1726, Expected=2128.6799
# Month=20, Predicted=2129.2868, Expected=2109.4299
# Month=21, Predicted=2109.6676, Expected=2098.8000
# Month=22, Predicted=2101.2899, Expected=2083.7900
# Month=23, Predicted=2084.8995, Expected=2100.5901
# Month=24, Predicted=2102.3868, Expected=2129.9199
# Month=25, Predicted=2128.6949, Expected=2131.5601
# Month=26, Predicted=2130.0669, Expected=2167.4900
# Month=27, Predicted=2167.9012, Expected=2162.7100
# Month=28, Predicted=2160.5208, Expected=2165.6399
# Month=29, Predicted=2166.7489, Expected=2168.2900
# Month=30, Predicted=2168.7884, Expected=2177.5300
# Month=31, Predicted=2178.0625, Expected=2178.6101
# Month=32, Predicted=2179.1036, Expected=2186.8501
# Month=33, Predicted=2187.4463, Expected=2186.4299
# Month=34, Predicted=2186.9144, Expected=2201.5601
# Month=35, Predicted=2202.1898, Expected=2198.5500
# Month=36, Predicted=2199.0881, Expected=2206.2700
# Month=37, Predicted=2207.0473, Expected=2210.2100
# Month=38, Predicted=2210.6888, Expected=2200.7600
# Month=39, Predicted=2201.1795, Expected=2204.9700
# Month=40, Predicted=2206.1011, Expected=2200.1699
# Month=41, Predicted=2200.6062, Expected=2191.1201
# Month=42, Predicted=2191.8091, Expected=2200.6499
# Month=43, Predicted=2201.7276, Expected=2207.2600
# Month=44, Predicted=2207.7236, Expected=2210.7200
# Month=45, Predicted=2211.2421, Expected=2241.1299
# Month=46, Predicted=2241.4395, Expected=2249.7300
# Month=47, Predicted=2248.7440, Expected=2258.8301
# Month=48, Predicted=2259.4229, Expected=2263.3201
# Month=49, Predicted=2263.8337, Expected=2268.3501
# Month=50, Predicted=2268.8877, Expected=2253.7700
# Month=51, Predicted=2254.0452, Expected=2266.8101
# Month=52, Predicted=2268.5698, Expected=2259.2400
# Month=53, Predicted=2259.7242, Expected=2266.5000
# Month=54, Predicted=2267.5419, Expected=2270.5400
# Month=55, Predicted=2271.0172, Expected=2262.9299
# Month=56, Predicted=2263.3754, Expected=2260.2500
# Month=57, Predicted=2261.1936, Expected=2266.2300
# Month=58, Predicted=2266.8807, Expected=2270.2300
# Month=59, Predicted=2270.7128, Expected=2249.5000
# Month=60, Predicted=2249.5694, Expected=2251.6101
# Run 7 — RMSE: 11.246652, MSE: 126.487186, NMSE: 0.0007682086
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=2155.7077, Expected=2158.2200
# Month=2, Predicted=2159.8574, Expected=2164.1899
# Month=3, Predicted=2164.3053, Expected=2160.3899
# Month=4, Predicted=2160.3049, Expected=2161.3501
# Month=5, Predicted=2162.3268, Expected=2137.6699
# Month=6, Predicted=2137.7851, Expected=2130.2600
# Month=7, Predicted=2133.3685, Expected=2139.6799
# Month=8, Predicted=2141.2699, Expected=2132.9500
# Month=9, Predicted=2132.7180, Expected=2138.3101
# Month=10, Predicted=2139.7855, Expected=2140.8101
# Month=11, Predicted=2140.7423, Expected=2142.5100
# Month=12, Predicted=2142.7027, Expected=2139.4299
# Month=13, Predicted=2139.6893, Expected=2148.5000
# Month=14, Predicted=2149.3827, Expected=2149.7200
# Month=15, Predicted=2149.4593, Expected=2136.9700
# Month=16, Predicted=2137.2730, Expected=2144.0601
# Month=17, Predicted=2146.4382, Expected=2132.2300
# Month=18, Predicted=2132.1004, Expected=2129.7800
# Month=19, Predicted=2131.9184, Expected=2128.6799
# Month=20, Predicted=2129.4300, Expected=2109.4299
# Month=21, Predicted=2109.8058, Expected=2098.8000
# Month=22, Predicted=2101.4632, Expected=2083.7900
# Month=23, Predicted=2085.3800, Expected=2100.5901
# Month=24, Predicted=2103.4547, Expected=2129.9199
# Month=25, Predicted=2129.3679, Expected=2131.5601
# Month=26, Predicted=2130.8381, Expected=2167.4900
# Month=27, Predicted=2167.9102, Expected=2162.7100
# Month=28, Predicted=2162.0841, Expected=2165.6399
# Month=29, Predicted=2167.1652, Expected=2168.2900
# Month=30, Predicted=2168.4210, Expected=2177.5300
# Month=31, Predicted=2177.6939, Expected=2178.6101
# Month=32, Predicted=2178.3512, Expected=2186.8501
# Month=33, Predicted=2187.2135, Expected=2186.4299
# Month=34, Predicted=2186.2128, Expected=2201.5601
# Month=35, Predicted=2202.1013, Expected=2198.5500
# Month=36, Predicted=2198.2137, Expected=2206.2700
# Month=37, Predicted=2207.2289, Expected=2210.2100
# Month=38, Predicted=2209.9987, Expected=2200.7600
# Month=39, Predicted=2200.8382, Expected=2204.9700
# Month=40, Predicted=2206.8271, Expected=2200.1699
# Month=41, Predicted=2200.1957, Expected=2191.1201
# Month=42, Predicted=2192.1333, Expected=2200.6499
# Month=43, Predicted=2202.4754, Expected=2207.2600
# Month=44, Predicted=2206.9623, Expected=2210.7200
# Month=45, Predicted=2210.6048, Expected=2241.1299
# Month=46, Predicted=2241.1968, Expected=2249.7300
# Month=47, Predicted=2248.7252, Expected=2258.8301
# Month=48, Predicted=2258.7428, Expected=2263.3201
# Month=49, Predicted=2263.0711, Expected=2268.3501
# Month=50, Predicted=2268.3792, Expected=2253.7700
# Month=51, Predicted=2253.7572, Expected=2266.8101
# Month=52, Predicted=2269.5657, Expected=2259.2400
# Month=53, Predicted=2258.9641, Expected=2266.5000
# Month=54, Predicted=2268.1578, Expected=2270.5400
# Month=55, Predicted=2270.3521, Expected=2262.9299
# Month=56, Predicted=2262.9987, Expected=2260.2500
# Month=57, Predicted=2261.7502, Expected=2266.2300
# Month=58, Predicted=2267.0366, Expected=2270.2300
# Month=59, Predicted=2270.1175, Expected=2249.5000
# Month=60, Predicted=2249.5184, Expected=2251.6101
# Run 8 — RMSE: 11.225883, MSE: 126.020440, NMSE: 0.0007700755
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=2156.6862, Expected=2158.2200
# Month=2, Predicted=2160.2583, Expected=2164.1899
# Month=3, Predicted=2164.8045, Expected=2160.3899
# Month=4, Predicted=2161.0200, Expected=2161.3501
# Month=5, Predicted=2162.9269, Expected=2137.6699
# Month=6, Predicted=2139.7307, Expected=2130.2600
# Month=7, Predicted=2132.8777, Expected=2139.6799
# Month=8, Predicted=2141.5082, Expected=2132.9500
# Month=9, Predicted=2133.3625, Expected=2138.3101
# Month=10, Predicted=2140.1389, Expected=2140.8101
# Month=11, Predicted=2141.2751, Expected=2142.5100
# Month=12, Predicted=2143.3246, Expected=2139.4299
# Month=13, Predicted=2140.4918, Expected=2148.5000
# Month=14, Predicted=2149.7907, Expected=2149.7200
# Month=15, Predicted=2149.8362, Expected=2136.9700
# Month=16, Predicted=2138.4746, Expected=2144.0601
# Month=17, Predicted=2146.4866, Expected=2132.2300
# Month=18, Predicted=2133.1171, Expected=2129.7800
# Month=19, Predicted=2132.2324, Expected=2128.6799
# Month=20, Predicted=2130.1513, Expected=2109.4299
# Month=21, Predicted=2111.4497, Expected=2098.8000
# Month=22, Predicted=2101.5295, Expected=2083.7900
# Month=23, Predicted=2086.3649, Expected=2100.5901
# Month=24, Predicted=2103.0876, Expected=2129.9199
# Month=25, Predicted=2128.1861, Expected=2131.5601
# Month=26, Predicted=2129.8362, Expected=2167.4900
# Month=27, Predicted=2167.2378, Expected=2162.7100
# Month=28, Predicted=2160.7864, Expected=2165.6399
# Month=29, Predicted=2167.2924, Expected=2168.2900
# Month=30, Predicted=2169.0245, Expected=2177.5300
# Month=31, Predicted=2178.0941, Expected=2178.6101
# Month=32, Predicted=2178.7147, Expected=2186.8501
# Month=33, Predicted=2187.6378, Expected=2186.4299
# Month=34, Predicted=2186.6936, Expected=2201.5601
# Month=35, Predicted=2202.3302, Expected=2198.5500
# Month=36, Predicted=2198.2585, Expected=2206.2700
# Month=37, Predicted=2207.5877, Expected=2210.2100
# Month=38, Predicted=2210.3691, Expected=2200.7600
# Month=39, Predicted=2201.8405, Expected=2204.9700
# Month=40, Predicted=2207.1211, Expected=2200.1699
# Month=41, Predicted=2201.0234, Expected=2191.1201
# Month=42, Predicted=2193.0788, Expected=2200.6499
# Month=43, Predicted=2202.6709, Expected=2207.2600
# Month=44, Predicted=2207.1333, Expected=2210.7200
# Month=45, Predicted=2211.0169, Expected=2241.1299
# Month=46, Predicted=2240.8442, Expected=2249.7300
# Month=47, Predicted=2247.6100, Expected=2258.8301
# Month=48, Predicted=2258.7208, Expected=2263.3201
# Month=49, Predicted=2263.3153, Expected=2268.3501
# Month=50, Predicted=2268.8310, Expected=2253.7700
# Month=51, Predicted=2254.9978, Expected=2266.8101
# Month=52, Predicted=2269.3195, Expected=2259.2400
# Month=53, Predicted=2259.3555, Expected=2266.5000
# Month=54, Predicted=2268.3919, Expected=2270.5400
# Month=55, Predicted=2270.7450, Expected=2262.9299
# Month=56, Predicted=2263.9185, Expected=2260.2500
# Month=57, Predicted=2262.3280, Expected=2266.2300
# Month=58, Predicted=2267.5479, Expected=2270.2300
# Month=59, Predicted=2270.5761, Expected=2249.5000
# Month=60, Predicted=2251.1565, Expected=2251.6101
# Run 9 — RMSE: 11.346213, MSE: 128.736539, NMSE: 0.0007871837
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=2155.1659, Expected=2158.2200
# Month=2, Predicted=2162.1632, Expected=2164.1899
# Month=3, Predicted=2163.1666, Expected=2160.3899
# Month=4, Predicted=2159.5463, Expected=2161.3501
# Month=5, Predicted=2162.1536, Expected=2137.6699
# Month=6, Predicted=2137.9961, Expected=2130.2600
# Month=7, Predicted=2135.4373, Expected=2139.6799
# Month=8, Predicted=2142.6875, Expected=2132.9500
# Month=9, Predicted=2132.2914, Expected=2138.3101
# Month=10, Predicted=2140.9029, Expected=2140.8101
# Month=11, Predicted=2139.7959, Expected=2142.5100
# Month=12, Predicted=2141.6340, Expected=2139.4299
# Month=13, Predicted=2138.7660, Expected=2148.5000
# Month=14, Predicted=2148.7274, Expected=2149.7200
# Month=15, Predicted=2148.7983, Expected=2136.9700
# Month=16, Predicted=2136.7165, Expected=2144.0601
# Month=17, Predicted=2149.2374, Expected=2132.2300
# Month=18, Predicted=2131.6809, Expected=2129.7800
# Month=19, Predicted=2134.9573, Expected=2128.6799
# Month=20, Predicted=2128.9396, Expected=2109.4299
# Month=21, Predicted=2110.0130, Expected=2098.8000
# Month=22, Predicted=2103.9774, Expected=2083.7900
# Month=23, Predicted=2088.9674, Expected=2100.5901
# Month=24, Predicted=2105.7674, Expected=2129.9199
# Month=25, Predicted=2128.4801, Expected=2131.5601
# Month=26, Predicted=2131.8672, Expected=2167.4900
# Month=27, Predicted=2165.7246, Expected=2162.7100
# Month=28, Predicted=2163.8809, Expected=2165.6399
# Month=29, Predicted=2166.9384, Expected=2168.2900
# Month=30, Predicted=2167.3592, Expected=2177.5300
# Month=31, Predicted=2176.4531, Expected=2178.6101
# Month=32, Predicted=2177.6964, Expected=2186.8501
# Month=33, Predicted=2185.9664, Expected=2186.4299
# Month=34, Predicted=2185.5272, Expected=2201.5601
# Month=35, Predicted=2200.7572, Expected=2198.5500
# Month=36, Predicted=2198.0631, Expected=2206.2700
# Month=37, Predicted=2206.5071, Expected=2210.2100
# Month=38, Predicted=2209.1762, Expected=2200.7600
# Month=39, Predicted=2200.1358, Expected=2204.9700
# Month=40, Predicted=2210.0675, Expected=2200.1699
# Month=41, Predicted=2199.3819, Expected=2191.1201
# Month=42, Predicted=2192.8555, Expected=2200.6499
# Month=43, Predicted=2205.1986, Expected=2207.2600
# Month=44, Predicted=2206.2078, Expected=2210.7200
# Month=45, Predicted=2209.6779, Expected=2241.1299
# Month=46, Predicted=2239.4081, Expected=2249.7300
# Month=47, Predicted=2249.8355, Expected=2258.8301
# Month=48, Predicted=2257.6770, Expected=2263.3201
# Month=49, Predicted=2262.3061, Expected=2268.3501
# Month=50, Predicted=2267.2838, Expected=2253.7700
# Month=51, Predicted=2253.3191, Expected=2266.8101
# Month=52, Predicted=2271.9874, Expected=2259.2400
# Month=53, Predicted=2258.7969, Expected=2266.5000
# Month=54, Predicted=2269.7404, Expected=2270.5400
# Month=55, Predicted=2269.4958, Expected=2262.9299
# Month=56, Predicted=2262.2369, Expected=2260.2500
# Month=57, Predicted=2263.8236, Expected=2266.2300
# Month=58, Predicted=2266.3786, Expected=2270.2300
# Month=59, Predicted=2269.1738, Expected=2249.5000
# Month=60, Predicted=2249.3535, Expected=2251.6101
# Run 10 — RMSE: 11.228282, MSE: 126.074320, NMSE: 0.0007799411
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=2155.7926, Expected=2158.2200
# Month=2, Predicted=2159.9057, Expected=2164.1899
# Month=3, Predicted=2164.3827, Expected=2160.3899
# Month=4, Predicted=2160.3574, Expected=2161.3501
# Month=5, Predicted=2162.3815, Expected=2137.6699
# Month=6, Predicted=2137.9552, Expected=2130.2600
# Month=7, Predicted=2133.4873, Expected=2139.6799
# Month=8, Predicted=2141.2615, Expected=2132.9500
# Month=9, Predicted=2132.7232, Expected=2138.3101
# Month=10, Predicted=2139.7776, Expected=2140.8101
# Month=11, Predicted=2140.8110, Expected=2142.5100
# Month=12, Predicted=2142.7684, Expected=2139.4299
# Month=13, Predicted=2139.7770, Expected=2148.5000
# Month=14, Predicted=2149.4316, Expected=2149.7200
# Month=15, Predicted=2149.4929, Expected=2136.9700
# Month=16, Predicted=2137.3491, Expected=2144.0601
# Month=17, Predicted=2146.4316, Expected=2132.2300
# Month=18, Predicted=2132.1236, Expected=2129.7800
# Month=19, Predicted=2131.9589, Expected=2128.6799
# Month=20, Predicted=2129.5259, Expected=2109.4299
# Month=21, Predicted=2110.0026, Expected=2098.8000
# Month=22, Predicted=2101.6659, Expected=2083.7900
# Month=23, Predicted=2085.6363, Expected=2100.5901
# Month=24, Predicted=2103.3538, Expected=2129.9199
# Month=25, Predicted=2129.5013, Expected=2131.5601
# Month=26, Predicted=2131.4668, Expected=2167.4900
# Month=27, Predicted=2167.6495, Expected=2162.7100
# Month=28, Predicted=2162.8179, Expected=2165.6399
# Month=29, Predicted=2166.8107, Expected=2168.2900
# Month=30, Predicted=2168.5043, Expected=2177.5300
# Month=31, Predicted=2177.7533, Expected=2178.6101
# Month=32, Predicted=2178.3755, Expected=2186.8501
# Month=33, Predicted=2187.2464, Expected=2186.4299
# Month=34, Predicted=2186.2484, Expected=2201.5601
# Month=35, Predicted=2202.1161, Expected=2198.5500
# Month=36, Predicted=2198.1880, Expected=2206.2700
# Month=37, Predicted=2207.1923, Expected=2210.2100
# Month=38, Predicted=2210.0456, Expected=2200.7600
# Month=39, Predicted=2200.8895, Expected=2204.9700
# Month=40, Predicted=2206.8452, Expected=2200.1699
# Month=41, Predicted=2200.2790, Expected=2191.1201
# Month=42, Predicted=2192.2557, Expected=2200.6499
# Month=43, Predicted=2202.4857, Expected=2207.2600
# Month=44, Predicted=2206.9981, Expected=2210.7200
# Month=45, Predicted=2210.6260, Expected=2241.1299
# Month=46, Predicted=2241.1495, Expected=2249.7300
# Month=47, Predicted=2249.6499, Expected=2258.8301
# Month=48, Predicted=2258.5992, Expected=2263.3201
# Month=49, Predicted=2263.0820, Expected=2268.3501
# Month=50, Predicted=2268.4137, Expected=2253.7700
# Month=51, Predicted=2253.7946, Expected=2266.8101
# Month=52, Predicted=2269.4778, Expected=2259.2400
# Month=53, Predicted=2258.9053, Expected=2266.5000
# Month=54, Predicted=2268.1001, Expected=2270.5400
# Month=55, Predicted=2270.4039, Expected=2262.9299
# Month=56, Predicted=2263.0526, Expected=2260.2500
# Month=57, Predicted=2261.8210, Expected=2266.2300
# Month=58, Predicted=2267.1086, Expected=2270.2300
# Month=59, Predicted=2270.1789, Expected=2249.5000
# Month=60, Predicted=2249.5534, Expected=2251.6101
# Run 11 — RMSE: 11.184538, MSE: 125.093880, NMSE: 0.0007651553
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=2155.9048, Expected=2158.2200
# Month=2, Predicted=2160.8344, Expected=2164.1899
# Month=3, Predicted=2163.6363, Expected=2160.3899
# Month=4, Predicted=2160.3206, Expected=2161.3501
# Month=5, Predicted=2162.2339, Expected=2137.6699
# Month=6, Predicted=2139.4690, Expected=2130.2600
# Month=7, Predicted=2134.1555, Expected=2139.6799
# Month=8, Predicted=2141.5648, Expected=2132.9500
# Month=9, Predicted=2133.1735, Expected=2138.3101
# Month=10, Predicted=2140.1190, Expected=2140.8101
# Month=11, Predicted=2140.3780, Expected=2142.5100
# Month=12, Predicted=2142.2124, Expected=2139.4299
# Month=13, Predicted=2139.4728, Expected=2148.5000
# Month=14, Predicted=2148.7179, Expected=2149.7200
# Month=15, Predicted=2149.4043, Expected=2136.9700
# Month=16, Predicted=2137.7585, Expected=2144.0601
# Month=17, Predicted=2146.8507, Expected=2132.2300
# Month=18, Predicted=2132.7581, Expected=2129.7800
# Month=19, Predicted=2132.6113, Expected=2128.6799
# Month=20, Predicted=2129.2838, Expected=2109.4299
# Month=21, Predicted=2111.1629, Expected=2098.8000
# Month=22, Predicted=2102.2268, Expected=2083.7900
# Month=23, Predicted=2086.7336, Expected=2100.5901
# Month=24, Predicted=2103.4130, Expected=2129.9199
# Month=25, Predicted=2127.9661, Expected=2131.5601
# Month=26, Predicted=2132.1175, Expected=2167.4900
# Month=27, Predicted=2165.0635, Expected=2162.7100
# Month=28, Predicted=2163.8391, Expected=2165.6399
# Month=29, Predicted=2166.8030, Expected=2168.2900
# Month=30, Predicted=2167.9238, Expected=2177.5300
# Month=31, Predicted=2176.8174, Expected=2178.6101
# Month=32, Predicted=2178.2966, Expected=2186.8501
# Month=33, Predicted=2186.3213, Expected=2186.4299
# Month=34, Predicted=2186.1856, Expected=2201.5601
# Month=35, Predicted=2200.8357, Expected=2198.5500
# Month=36, Predicted=2198.7822, Expected=2206.2700
# Month=37, Predicted=2206.5512, Expected=2210.2100
# Month=38, Predicted=2209.7039, Expected=2200.7600
# Month=39, Predicted=2201.1011, Expected=2204.9700
# Month=40, Predicted=2207.6335, Expected=2200.1699
# Month=41, Predicted=2200.1897, Expected=2191.1201
# Month=42, Predicted=2192.9877, Expected=2200.6499
# Month=43, Predicted=2203.2379, Expected=2207.2600
# Month=44, Predicted=2206.6347, Expected=2210.7200
# Month=45, Predicted=2210.2080, Expected=2241.1299
# Month=46, Predicted=2239.0134, Expected=2249.7300
# Month=47, Predicted=2249.8735, Expected=2258.8301
# Month=48, Predicted=2257.9743, Expected=2263.3201
# Month=49, Predicted=2262.7848, Expected=2268.3501
# Month=50, Predicted=2267.7755, Expected=2253.7700
# Month=51, Predicted=2254.4976, Expected=2266.8101
# Month=52, Predicted=2269.6570, Expected=2259.2400
# Month=53, Predicted=2259.7001, Expected=2266.5000
# Month=54, Predicted=2268.6230, Expected=2270.5400
# Month=55, Predicted=2270.0232, Expected=2262.9299
# Month=56, Predicted=2263.1344, Expected=2260.2500
# Month=57, Predicted=2262.8596, Expected=2266.2300
# Month=58, Predicted=2266.5059, Expected=2270.2300
# Month=59, Predicted=2269.7090, Expected=2249.5000
# Month=60, Predicted=2250.7791, Expected=2251.6101
# Run 12 — RMSE: 11.140027, MSE: 124.100204, NMSE: 0.0007623343
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=2155.6161, Expected=2158.2200
# Month=2, Predicted=2160.3150, Expected=2164.1899
# Month=3, Predicted=2163.7579, Expected=2160.3899
# Month=4, Predicted=2159.8635, Expected=2161.3501
# Month=5, Predicted=2162.2503, Expected=2137.6699
# Month=6, Predicted=2138.2866, Expected=2130.2600
# Month=7, Predicted=2134.7605, Expected=2139.6799
# Month=8, Predicted=2141.4121, Expected=2132.9500
# Month=9, Predicted=2132.3572, Expected=2138.3101
# Month=10, Predicted=2139.9279, Expected=2140.8101
# Month=11, Predicted=2140.2325, Expected=2142.5100
# Month=12, Predicted=2142.2091, Expected=2139.4299
# Month=13, Predicted=2139.3191, Expected=2148.5000
# Month=14, Predicted=2149.0745, Expected=2149.7200
# Month=15, Predicted=2149.0416, Expected=2136.9700
# Month=16, Predicted=2137.1661, Expected=2144.0601
# Month=17, Predicted=2147.4257, Expected=2132.2300
# Month=18, Predicted=2131.7771, Expected=2129.7800
# Month=19, Predicted=2133.0078, Expected=2128.6799
# Month=20, Predicted=2129.2959, Expected=2109.4299
# Month=21, Predicted=2110.2861, Expected=2098.8000
# Month=22, Predicted=2103.3930, Expected=2083.7900
# Month=23, Predicted=2086.9594, Expected=2100.5901
# Month=24, Predicted=2104.4169, Expected=2129.9199
# Month=25, Predicted=2129.5134, Expected=2131.5601
# Month=26, Predicted=2132.1944, Expected=2167.4900
# Month=27, Predicted=2166.7492, Expected=2162.7100
# Month=28, Predicted=2163.3235, Expected=2165.6399
# Month=29, Predicted=2166.7958, Expected=2168.2900
# Month=30, Predicted=2167.9238, Expected=2177.5300
# Month=31, Predicted=2177.0963, Expected=2178.6101
# Month=32, Predicted=2177.9325, Expected=2186.8501
# Month=33, Predicted=2186.6375, Expected=2186.4299
# Month=34, Predicted=2185.7754, Expected=2201.5601
# Month=35, Predicted=2201.4696, Expected=2198.5500
# Month=36, Predicted=2198.1028, Expected=2206.2700
# Month=37, Predicted=2206.8578, Expected=2210.2100
# Month=38, Predicted=2209.5184, Expected=2200.7600
# Month=39, Predicted=2200.5051, Expected=2204.9700
# Month=40, Predicted=2207.4162, Expected=2200.1699
# Month=41, Predicted=2199.7932, Expected=2191.1201
# Month=42, Predicted=2192.5092, Expected=2200.6499
# Month=43, Predicted=2202.8891, Expected=2207.2600
# Month=44, Predicted=2206.5347, Expected=2210.7200
# Month=45, Predicted=2210.0665, Expected=2241.1299
# Month=46, Predicted=2240.2955, Expected=2249.7300
# Month=47, Predicted=2250.4630, Expected=2258.8301
# Month=48, Predicted=2258.1131, Expected=2263.3201
# Month=49, Predicted=2262.6107, Expected=2268.3501
# Month=50, Predicted=2267.8012, Expected=2253.7700
# Month=51, Predicted=2253.5284, Expected=2266.8101
# Month=52, Predicted=2270.5804, Expected=2259.2400
# Month=53, Predicted=2258.7122, Expected=2266.5000
# Month=54, Predicted=2268.3340, Expected=2270.5400
# Month=55, Predicted=2269.8577, Expected=2262.9299
# Month=56, Predicted=2262.6253, Expected=2260.2500
# Month=57, Predicted=2262.2670, Expected=2266.2300
# Month=58, Predicted=2266.7677, Expected=2270.2300
# Month=59, Predicted=2269.5984, Expected=2249.5000
# Month=60, Predicted=2249.5427, Expected=2251.6101
# Run 13 — RMSE: 11.164979, MSE: 124.656757, NMSE: 0.0007682108
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=2155.8313, Expected=2158.2200
# Month=2, Predicted=2159.3703, Expected=2164.1899
# Month=3, Predicted=2164.2065, Expected=2160.3899
# Month=4, Predicted=2160.5716, Expected=2161.3501
# Month=5, Predicted=2162.0192, Expected=2137.6699
# Month=6, Predicted=2138.8864, Expected=2130.2600
# Month=7, Predicted=2134.3071, Expected=2139.6799
# Month=8, Predicted=2140.5927, Expected=2132.9500
# Month=9, Predicted=2133.1712, Expected=2138.3101
# Month=10, Predicted=2139.2183, Expected=2140.8101
# Month=11, Predicted=2140.8251, Expected=2142.5100
# Month=12, Predicted=2142.6697, Expected=2139.4299
# Month=13, Predicted=2139.7685, Expected=2148.5000
# Month=14, Predicted=2148.9042, Expected=2149.7200
# Month=15, Predicted=2149.6965, Expected=2136.9700
# Month=16, Predicted=2137.6774, Expected=2144.0601
# Month=17, Predicted=2145.8248, Expected=2132.2300
# Month=18, Predicted=2132.6710, Expected=2129.7800
# Month=19, Predicted=2131.5649, Expected=2128.6799
# Month=20, Predicted=2129.2699, Expected=2109.4299
# Month=21, Predicted=2110.5766, Expected=2098.8000
# Month=22, Predicted=2102.0514, Expected=2083.7900
# Month=23, Predicted=2085.7829, Expected=2100.5901
# Month=24, Predicted=2102.5518, Expected=2129.9199
# Month=25, Predicted=2129.2044, Expected=2131.5601
# Month=26, Predicted=2131.8297, Expected=2167.4900
# Month=27, Predicted=2166.6487, Expected=2162.7100
# Month=28, Predicted=2163.0718, Expected=2165.6399
# Month=29, Predicted=2166.3768, Expected=2168.2900
# Month=30, Predicted=2168.4016, Expected=2177.5300
# Month=31, Predicted=2177.4822, Expected=2178.6101
# Month=32, Predicted=2178.5893, Expected=2186.8501
# Month=33, Predicted=2186.9250, Expected=2186.4299
# Month=34, Predicted=2186.4630, Expected=2201.5601
# Month=35, Predicted=2201.5590, Expected=2198.5500
# Month=36, Predicted=2198.6828, Expected=2206.2700
# Month=37, Predicted=2206.7018, Expected=2210.2100
# Month=38, Predicted=2210.1275, Expected=2200.7600
# Month=39, Predicted=2201.2043, Expected=2204.9700
# Month=40, Predicted=2206.2712, Expected=2200.1699
# Month=41, Predicted=2200.4413, Expected=2191.1201
# Month=42, Predicted=2192.1738, Expected=2200.6499
# Month=43, Predicted=2201.7862, Expected=2207.2600
# Month=44, Predicted=2207.0839, Expected=2210.7200
# Month=45, Predicted=2210.6738, Expected=2241.1299
# Month=46, Predicted=2240.3805, Expected=2249.7300
# Month=47, Predicted=2249.8661, Expected=2258.8301
# Month=48, Predicted=2258.5936, Expected=2263.3201
# Month=49, Predicted=2263.2052, Expected=2268.3501
# Month=50, Predicted=2268.3285, Expected=2253.7700
# Month=51, Predicted=2254.3788, Expected=2266.8101
# Month=52, Predicted=2268.7789, Expected=2259.2400
# Month=53, Predicted=2259.4937, Expected=2266.5000
# Month=54, Predicted=2267.4788, Expected=2270.5400
# Month=55, Predicted=2270.4633, Expected=2262.9299
# Month=56, Predicted=2263.3034, Expected=2260.2500
# Month=57, Predicted=2261.4435, Expected=2266.2300
# Month=58, Predicted=2266.6689, Expected=2270.2300
# Month=59, Predicted=2270.1852, Expected=2249.5000
# Month=60, Predicted=2250.4201, Expected=2251.6101
# Run 14 — RMSE: 11.143871, MSE: 124.185856, NMSE: 0.0007602341
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=2156.3695, Expected=2158.2200
# Month=2, Predicted=2160.0012, Expected=2164.1899
# Month=3, Predicted=2164.7363, Expected=2160.3899
# Month=4, Predicted=2160.8167, Expected=2161.3501
# Month=5, Predicted=2162.7174, Expected=2137.6699
# Month=6, Predicted=2139.0489, Expected=2130.2600
# Month=7, Predicted=2133.2995, Expected=2139.6799
# Month=8, Predicted=2141.3295, Expected=2132.9500
# Month=9, Predicted=2133.1087, Expected=2138.3101
# Month=10, Predicted=2139.9327, Expected=2140.8101
# Month=11, Predicted=2141.1744, Expected=2142.5100
# Month=12, Predicted=2143.1908, Expected=2139.4299
# Month=13, Predicted=2140.2798, Expected=2148.5000
# Month=14, Predicted=2149.6867, Expected=2149.7200
# Month=15, Predicted=2149.7368, Expected=2136.9700
# Month=16, Predicted=2138.0764, Expected=2144.0601
# Month=17, Predicted=2146.1942, Expected=2132.2300
# Month=18, Predicted=2132.7455, Expected=2129.7800
# Month=19, Predicted=2131.8801, Expected=2128.6799
# Month=20, Predicted=2129.9314, Expected=2109.4299
# Month=21, Predicted=2110.8831, Expected=2098.8000
# Month=22, Predicted=2101.4255, Expected=2083.7900
# Month=23, Predicted=2085.8656, Expected=2100.5901
# Month=24, Predicted=2102.8546, Expected=2129.9199
# Month=25, Predicted=2128.7157, Expected=2131.5601
# Month=26, Predicted=2129.8940, Expected=2167.4900
# Month=27, Predicted=2167.6458, Expected=2162.7100
# Month=28, Predicted=2160.7274, Expected=2165.6399
# Month=29, Predicted=2167.1022, Expected=2168.2900
# Month=30, Predicted=2168.9077, Expected=2177.5300
# Month=31, Predicted=2178.0682, Expected=2178.6101
# Month=32, Predicted=2178.6137, Expected=2186.8501
# Month=33, Predicted=2187.5806, Expected=2186.4299
# Month=34, Predicted=2186.5607, Expected=2201.5601
# Month=35, Predicted=2202.3482, Expected=2198.5500
# Month=36, Predicted=2198.1001, Expected=2206.2700
# Month=37, Predicted=2207.4708, Expected=2210.2100
# Month=38, Predicted=2210.3079, Expected=2200.7600
# Month=39, Predicted=2201.5210, Expected=2204.9700
# Month=40, Predicted=2206.8537, Expected=2200.1699
# Month=41, Predicted=2200.7949, Expected=2191.1201
# Month=42, Predicted=2192.7132, Expected=2200.6499
# Month=43, Predicted=2202.4615, Expected=2207.2600
# Month=44, Predicted=2207.1304, Expected=2210.7200
# Month=45, Predicted=2210.9406, Expected=2241.1299
# Month=46, Predicted=2241.1820, Expected=2249.7300
# Month=47, Predicted=2247.8567, Expected=2258.8301
# Month=48, Predicted=2258.7564, Expected=2263.3201
# Month=49, Predicted=2263.2732, Expected=2268.3501
# Month=50, Predicted=2268.7626, Expected=2253.7700
# Month=51, Predicted=2254.5611, Expected=2266.8101
# Month=52, Predicted=2269.0580, Expected=2259.2400
# Month=53, Predicted=2259.0855, Expected=2266.5000
# Month=54, Predicted=2268.1909, Expected=2270.5400
# Month=55, Predicted=2270.6822, Expected=2262.9299
# Month=56, Predicted=2263.6367, Expected=2260.2500
# Month=57, Predicted=2262.0207, Expected=2266.2300
# Month=58, Predicted=2267.4125, Expected=2270.2300
# Month=59, Predicted=2270.5033, Expected=2249.5000
# Month=60, Predicted=2250.5596, Expected=2251.6101
# Run 15 — RMSE: 11.327178, MSE: 128.304954, NMSE: 0.0007838936
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=2156.0768, Expected=2158.2200
# Month=2, Predicted=2159.1469, Expected=2164.1899
# Month=3, Predicted=2165.1168, Expected=2160.3899
# Month=4, Predicted=2161.3168, Expected=2161.3501
# Month=5, Predicted=2162.2770, Expected=2137.6699
# Month=6, Predicted=2138.5968, Expected=2130.2600
# Month=7, Predicted=2131.1869, Expected=2139.6799
# Month=8, Predicted=2140.6068, Expected=2132.9500
# Month=9, Predicted=2133.8768, Expected=2138.3101
# Month=10, Predicted=2139.2369, Expected=2140.8101
# Month=11, Predicted=2141.7369, Expected=2142.5100
# Month=12, Predicted=2143.4369, Expected=2139.4299
# Month=13, Predicted=2140.3568, Expected=2148.5000
# Month=14, Predicted=2149.4269, Expected=2149.7200
# Month=15, Predicted=2150.6469, Expected=2136.9700
# Month=16, Predicted=2137.8969, Expected=2144.0601
# Month=17, Predicted=2144.9869, Expected=2132.2300
# Month=18, Predicted=2133.1569, Expected=2129.7800
# Month=19, Predicted=2130.7069, Expected=2128.6799
# Month=20, Predicted=2129.6068, Expected=2109.4299
# Month=21, Predicted=2110.3568, Expected=2098.8000
# Month=22, Predicted=2099.7269, Expected=2083.7900
# Month=23, Predicted=2084.7169, Expected=2100.5901
# ...
# Month=53, Predicted=2259.0065, Expected=2266.5000
# Month=54, Predicted=2268.2857, Expected=2270.5400
# Month=55, Predicted=2270.3013, Expected=2262.9299
# Month=56, Predicted=2263.0497, Expected=2260.2500
# Month=57, Predicted=2262.0177, Expected=2266.2300
# Month=58, Predicted=2266.9797, Expected=2270.2300
# Month=59, Predicted=2270.0622, Expected=2249.5000
# Month=60, Predicted=2249.7641, Expected=2251.6101
# Run 25 — RMSE: 11.187610, MSE: 125.162625, NMSE: 0.0007655761
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=2156.1697, Expected=2158.2200
# Month=2, Predicted=2159.8794, Expected=2164.1899
# Month=3, Predicted=2164.1633, Expected=2160.3899
# Month=4, Predicted=2160.5182, Expected=2161.3501
# Month=5, Predicted=2162.4341, Expected=2137.6699
# Month=6, Predicted=2139.1920, Expected=2130.2600
# Month=7, Predicted=2133.6436, Expected=2139.6799
# Month=8, Predicted=2141.1114, Expected=2132.9500
# Month=9, Predicted=2133.0504, Expected=2138.3101
# Month=10, Predicted=2139.7272, Expected=2140.8101
# Month=11, Predicted=2140.6974, Expected=2142.5100
# Month=12, Predicted=2142.7184, Expected=2139.4299
# Month=13, Predicted=2139.9290, Expected=2148.5000
# Month=14, Predicted=2149.2433, Expected=2149.7200
# Month=15, Predicted=2149.4184, Expected=2136.9700
# Month=16, Predicted=2137.9714, Expected=2144.0601
# Month=17, Predicted=2146.1729, Expected=2132.2300
# Month=18, Predicted=2132.7374, Expected=2129.7800
# Month=19, Predicted=2131.8419, Expected=2128.6799
# Month=20, Predicted=2129.6304, Expected=2109.4299
# Month=21, Predicted=2110.9156, Expected=2098.8000
# Month=22, Predicted=2101.5729, Expected=2083.7900
# Month=23, Predicted=2085.7681, Expected=2100.5901
# Month=24, Predicted=2102.8681, Expected=2129.9199
# Month=25, Predicted=2128.2049, Expected=2131.5601
# Month=26, Predicted=2131.7086, Expected=2167.4900
# Month=27, Predicted=2166.1584, Expected=2162.7100
# Month=28, Predicted=2163.6814, Expected=2165.6399
# Month=29, Predicted=2166.8193, Expected=2168.2900
# Month=30, Predicted=2168.4149, Expected=2177.5300
# Month=31, Predicted=2177.4187, Expected=2178.6101
# Month=32, Predicted=2178.3031, Expected=2186.8501
# Month=33, Predicted=2186.9809, Expected=2186.4299
# Month=34, Predicted=2186.2462, Expected=2201.5601
# Month=35, Predicted=2201.6395, Expected=2198.5500
# Month=36, Predicted=2198.3827, Expected=2206.2700
# Month=37, Predicted=2207.0399, Expected=2210.2100
# Month=38, Predicted=2209.8552, Expected=2200.7600
# Month=39, Predicted=2201.3441, Expected=2204.9700
# Month=40, Predicted=2206.7687, Expected=2200.1699
# Month=41, Predicted=2200.4938, Expected=2191.1201
# Month=42, Predicted=2192.6036, Expected=2200.6499
# Month=43, Predicted=2202.3304, Expected=2207.2600
# Month=44, Predicted=2206.6867, Expected=2210.7200
# Month=45, Predicted=2210.4512, Expected=2241.1299
# Month=46, Predicted=2239.8846, Expected=2249.7300
# Month=47, Predicted=2249.5988, Expected=2258.8301
# Month=48, Predicted=2258.1220, Expected=2263.3201
# Month=49, Predicted=2262.8500, Expected=2268.3501
# Month=50, Predicted=2268.2012, Expected=2253.7700
# Month=51, Predicted=2254.5701, Expected=2266.8101
# Month=52, Predicted=2269.0576, Expected=2259.2400
# Month=53, Predicted=2259.3171, Expected=2266.5000
# Month=54, Predicted=2268.0072, Expected=2270.5400
# Month=55, Predicted=2270.2108, Expected=2262.9299
# Month=56, Predicted=2263.4074, Expected=2260.2500
# Month=57, Predicted=2261.9168, Expected=2266.2300
# Month=58, Predicted=2267.0037, Expected=2270.2300
# Month=59, Predicted=2269.9988, Expected=2249.5000
# Month=60, Predicted=2250.7200, Expected=2251.6101
# Run 26 — RMSE: 11.180685, MSE: 125.007723, NMSE: 0.0007659067
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=2155.5722, Expected=2158.2200
# Month=2, Predicted=2159.3649, Expected=2164.1899
# Month=3, Predicted=2164.2345, Expected=2160.3899
# Month=4, Predicted=2160.3912, Expected=2161.3501
# Month=5, Predicted=2161.9661, Expected=2137.6699
# Month=6, Predicted=2138.1255, Expected=2130.2600
# Month=7, Predicted=2134.3458, Expected=2139.6799
# Month=8, Predicted=2140.6796, Expected=2132.9500
# Month=9, Predicted=2132.9237, Expected=2138.3101
# Month=10, Predicted=2139.2449, Expected=2140.8101
# Month=11, Predicted=2140.7835, Expected=2142.5100
# Month=12, Predicted=2142.6137, Expected=2139.4299
# Month=13, Predicted=2139.6129, Expected=2148.5000
# Month=14, Predicted=2148.9868, Expected=2149.7200
# Month=15, Predicted=2149.6362, Expected=2136.9700
# Month=16, Predicted=2137.2784, Expected=2144.0601
# Month=17, Predicted=2145.8878, Expected=2132.2300
# Month=18, Predicted=2132.2759, Expected=2129.7800
# Month=19, Predicted=2131.5056, Expected=2128.6799
# Month=20, Predicted=2129.1764, Expected=2109.4299
# Month=21, Predicted=2109.9859, Expected=2098.8000
# Month=22, Predicted=2101.9553, Expected=2083.7900
# Month=23, Predicted=2085.4457, Expected=2100.5901
# Month=24, Predicted=2102.7663, Expected=2129.9199
# Month=25, Predicted=2129.8389, Expected=2131.5601
# Month=26, Predicted=2132.0582, Expected=2167.4900
# Month=27, Predicted=2167.4156, Expected=2162.7100
# Month=28, Predicted=2163.2190, Expected=2165.6399
# Month=29, Predicted=2166.3875, Expected=2168.2900
# Month=30, Predicted=2168.3615, Expected=2177.5300
# Month=31, Predicted=2177.5735, Expected=2178.6101
# Month=32, Predicted=2178.5295, Expected=2186.8501
# Month=33, Predicted=2186.9990, Expected=2186.4299
# Month=34, Predicted=2186.3643, Expected=2201.5601
# Month=35, Predicted=2201.7681, Expected=2198.5500
# Month=36, Predicted=2198.5820, Expected=2206.2700
# Month=37, Predicted=2206.7693, Expected=2210.2100
# Month=38, Predicted=2210.1199, Expected=2200.7600
# Month=39, Predicted=2200.8851, Expected=2204.9700
# Month=40, Predicted=2206.2863, Expected=2200.1699
# Month=41, Predicted=2200.2398, Expected=2191.1201
# Month=42, Predicted=2191.9242, Expected=2200.6499
# Month=43, Predicted=2201.8780, Expected=2207.2600
# Month=44, Predicted=2207.1444, Expected=2210.7200
# Month=45, Predicted=2210.6608, Expected=2241.1299
# Month=46, Predicted=2240.9759, Expected=2249.7300
# Month=47, Predicted=2250.2005, Expected=2258.8301
# Month=48, Predicted=2258.7469, Expected=2263.3201
# Month=49, Predicted=2263.2239, Expected=2268.3501
# Month=50, Predicted=2268.3428, Expected=2253.7700
# Month=51, Predicted=2253.9016, Expected=2266.8101
# Month=52, Predicted=2268.9270, Expected=2259.2400
# Month=53, Predicted=2259.2528, Expected=2266.5000
# Month=54, Predicted=2267.5371, Expected=2270.5400
# Month=55, Predicted=2270.4583, Expected=2262.9299
# Month=56, Predicted=2263.0332, Expected=2260.2500
# Month=57, Predicted=2261.3480, Expected=2266.2300
# Month=58, Predicted=2266.7000, Expected=2270.2300
# Month=59, Predicted=2270.1737, Expected=2249.5000
# Month=60, Predicted=2249.7458, Expected=2251.6101
# Run 27 — RMSE: 11.121760, MSE: 123.693545, NMSE: 0.0007565135
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=2156.2613, Expected=2158.2200
# Month=2, Predicted=2159.6754, Expected=2164.1899
# Month=3, Predicted=2164.8384, Expected=2160.3899
# Month=4, Predicted=2160.8792, Expected=2161.3501
# Month=5, Predicted=2162.6093, Expected=2137.6699
# Month=6, Predicted=2138.6261, Expected=2130.2600
# Month=7, Predicted=2133.2143, Expected=2139.6799
# Month=8, Predicted=2141.1125, Expected=2132.9500
# Month=9, Predicted=2133.1280, Expected=2138.3101
# Month=10, Predicted=2139.7163, Expected=2140.8101
# Month=11, Predicted=2141.2526, Expected=2142.5100
# Month=12, Predicted=2143.2771, Expected=2139.4299
# Month=13, Predicted=2140.3234, Expected=2148.5000
# Month=14, Predicted=2149.6984, Expected=2149.7200
# Month=15, Predicted=2149.7495, Expected=2136.9700
# Month=16, Predicted=2137.9675, Expected=2144.0601
# Month=17, Predicted=2145.7315, Expected=2132.2300
# Month=18, Predicted=2132.7677, Expected=2129.7800
# Month=19, Predicted=2131.3904, Expected=2128.6799
# Month=20, Predicted=2129.8613, Expected=2109.4299
# Month=21, Predicted=2110.5018, Expected=2098.8000
# Month=22, Predicted=2101.1013, Expected=2083.7900
# Month=23, Predicted=2085.2884, Expected=2100.5901
# Month=24, Predicted=2102.4065, Expected=2129.9199
# Month=25, Predicted=2128.9114, Expected=2131.5601
# Month=26, Predicted=2129.9115, Expected=2167.4900
# Month=27, Predicted=2167.7463, Expected=2162.7100
# Month=28, Predicted=2160.2457, Expected=2165.6399
# Month=29, Predicted=2166.9692, Expected=2168.2900
# Month=30, Predicted=2168.9997, Expected=2177.5300
# Month=31, Predicted=2178.1789, Expected=2178.6101
# Month=32, Predicted=2178.6221, Expected=2186.8501
# Month=33, Predicted=2187.6881, Expected=2186.4299
# Month=34, Predicted=2186.5934, Expected=2201.5601
# Month=35, Predicted=2202.4757, Expected=2198.5500
# Month=36, Predicted=2197.9802, Expected=2206.2700
# Month=37, Predicted=2207.4749, Expected=2210.2100
# Month=38, Predicted=2210.3445, Expected=2200.7600
# Month=39, Predicted=2201.5391, Expected=2204.9700
# Month=40, Predicted=2206.4802, Expected=2200.1699
# Month=41, Predicted=2200.8554, Expected=2191.1201
# Month=42, Predicted=2192.4021, Expected=2200.6499
# Month=43, Predicted=2202.1530, Expected=2207.2600
# Month=44, Predicted=2207.1175, Expected=2210.7200
# Month=45, Predicted=2210.9993, Expected=2241.1299
# Month=46, Predicted=2241.2540, Expected=2249.7300
# Month=47, Predicted=2248.4379, Expected=2258.8301
# Month=48, Predicted=2258.7555, Expected=2263.3201
# Month=49, Predicted=2263.2763, Expected=2268.3501
# Month=50, Predicted=2268.8526, Expected=2253.7700
# Month=51, Predicted=2254.5266, Expected=2266.8101
# Month=52, Predicted=2268.6023, Expected=2259.2400
# Month=53, Predicted=2259.0345, Expected=2266.5000
# Month=54, Predicted=2267.9481, Expected=2270.5400
# Month=55, Predicted=2270.7282, Expected=2262.9299
# Month=56, Predicted=2263.6749, Expected=2260.2500
# Month=57, Predicted=2261.6670, Expected=2266.2300
# Month=58, Predicted=2267.4096, Expected=2270.2300
# Month=59, Predicted=2270.5729, Expected=2249.5000
# Month=60, Predicted=2250.3569, Expected=2251.6101
# Run 28 — RMSE: 11.319829, MSE: 128.138522, NMSE: 0.0007810441
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=2155.8995, Expected=2158.2200
# Month=2, Predicted=2159.4463, Expected=2164.1899
# Month=3, Predicted=2164.2235, Expected=2160.3899
# Month=4, Predicted=2160.5579, Expected=2161.3501
# Month=5, Predicted=2162.0931, Expected=2137.6699
# Month=6, Predicted=2138.9734, Expected=2130.2600
# Month=7, Predicted=2134.2355, Expected=2139.6799
# Month=8, Predicted=2140.6658, Expected=2132.9500
# Month=9, Predicted=2133.1094, Expected=2138.3101
# Month=10, Predicted=2139.2961, Expected=2140.8101
# Month=11, Predicted=2140.8156, Expected=2142.5100
# Month=12, Predicted=2142.6956, Expected=2139.4299
# Month=13, Predicted=2139.8064, Expected=2148.5000
# Month=14, Predicted=2148.9685, Expected=2149.7200
# Month=15, Predicted=2149.6332, Expected=2136.9700
# Month=16, Predicted=2137.7346, Expected=2144.0601
# Month=17, Predicted=2145.8803, Expected=2132.2300
# Month=18, Predicted=2132.6523, Expected=2129.7800
# Month=19, Predicted=2131.6351, Expected=2128.6799
# Month=20, Predicted=2129.3378, Expected=2109.4299
# Month=21, Predicted=2110.6671, Expected=2098.8000
# Month=22, Predicted=2102.0549, Expected=2083.7900
# Month=23, Predicted=2085.8754, Expected=2100.5901
# Month=24, Predicted=2102.5793, Expected=2129.9199
# Month=25, Predicted=2129.0263, Expected=2131.5601
# Month=26, Predicted=2131.6108, Expected=2167.4900
# Month=27, Predicted=2166.6807, Expected=2162.7100
# Month=28, Predicted=2163.0163, Expected=2165.6399
# Month=29, Predicted=2166.4642, Expected=2168.2900
# Month=30, Predicted=2168.4218, Expected=2177.5300
# Month=31, Predicted=2177.5024, Expected=2178.6101
# Month=32, Predicted=2178.5228, Expected=2186.8501
# Month=33, Predicted=2186.9619, Expected=2186.4299
# Month=34, Predicted=2186.4132, Expected=2201.5601
# Month=35, Predicted=2201.6052, Expected=2198.5500
# Month=36, Predicted=2198.5272, Expected=2206.2700
# Month=37, Predicted=2206.7695, Expected=2210.2100
# Month=38, Predicted=2210.0837, Expected=2200.7600
# Month=39, Predicted=2201.2249, Expected=2204.9700
# Month=40, Predicted=2206.3449, Expected=2200.1699
# Month=41, Predicted=2200.4522, Expected=2191.1201
# Month=42, Predicted=2192.2617, Expected=2200.6499
# Month=43, Predicted=2201.8554, Expected=2207.2600
# Month=44, Predicted=2207.0114, Expected=2210.7200
# Month=45, Predicted=2210.6457, Expected=2241.1299
# Month=46, Predicted=2240.3935, Expected=2249.7300
# Month=47, Predicted=2249.6585, Expected=2258.8301
# Month=48, Predicted=2258.5303, Expected=2263.3201
# Month=49, Predicted=2263.1387, Expected=2268.3501
# Month=50, Predicted=2268.3288, Expected=2253.7700
# Month=51, Predicted=2254.3946, Expected=2266.8101
# Month=52, Predicted=2268.8172, Expected=2259.2400
# Month=53, Predicted=2259.3755, Expected=2266.5000
# Month=54, Predicted=2267.5565, Expected=2270.5400
# Month=55, Predicted=2270.4262, Expected=2262.9299
# Month=56, Predicted=2263.3201, Expected=2260.2500
# Month=57, Predicted=2261.5263, Expected=2266.2300
# Month=58, Predicted=2266.7328, Expected=2270.2300
# Month=59, Predicted=2270.1664, Expected=2249.5000
# Month=60, Predicted=2250.4656, Expected=2251.6101
# Run 29 — RMSE: 11.167220, MSE: 124.706806, NMSE: 0.0007637108
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=2155.7810, Expected=2158.2200
# Month=2, Predicted=2159.3344, Expected=2164.1899
# Month=3, Predicted=2164.2366, Expected=2160.3899
# Month=4, Predicted=2160.5558, Expected=2161.3501
# Month=5, Predicted=2161.9994, Expected=2137.6699
# Month=6, Predicted=2138.7387, Expected=2130.2600
# Month=7, Predicted=2134.2387, Expected=2139.6799
# Month=8, Predicted=2140.5854, Expected=2132.9500
# Month=9, Predicted=2133.1354, Expected=2138.3101
# Month=10, Predicted=2139.1988, Expected=2140.8101
# Month=11, Predicted=2140.8431, Expected=2142.5100
# Month=12, Predicted=2142.6777, Expected=2139.4299
# Month=13, Predicted=2139.7510, Expected=2148.5000
# Month=14, Predicted=2148.9180, Expected=2149.7200
# Month=15, Predicted=2149.7076, Expected=2136.9700
# Month=16, Predicted=2137.6043, Expected=2144.0601
# Month=17, Predicted=2145.7784, Expected=2132.2300
# Month=18, Predicted=2132.6048, Expected=2129.7800
# Month=19, Predicted=2131.5013, Expected=2128.6799
# Month=20, Predicted=2129.2484, Expected=2109.4299
# Month=21, Predicted=2110.4570, Expected=2098.8000
# Month=22, Predicted=2101.9589, Expected=2083.7900
# Month=23, Predicted=2085.6771, Expected=2100.5901
# Month=24, Predicted=2102.5236, Expected=2129.9199
# Month=25, Predicted=2129.3620, Expected=2131.5601
# Month=26, Predicted=2131.7707, Expected=2167.4900
# Month=27, Predicted=2166.8618, Expected=2162.7100
# Month=28, Predicted=2162.9910, Expected=2165.6399
# Month=29, Predicted=2166.3727, Expected=2168.2900
# Month=30, Predicted=2168.4152, Expected=2177.5300
# Month=31, Predicted=2177.5261, Expected=2178.6101
# Month=32, Predicted=2178.5994, Expected=2186.8501
# Month=33, Predicted=2186.9585, Expected=2186.4299
# Month=34, Predicted=2186.4657, Expected=2201.5601
# Month=35, Predicted=2201.6173, Expected=2198.5500
# Month=36, Predicted=2198.6534, Expected=2206.2700
# Month=37, Predicted=2206.7135, Expected=2210.2100
# Month=38, Predicted=2210.1541, Expected=2200.7600
# Month=39, Predicted=2201.1544, Expected=2204.9700
# Month=40, Predicted=2206.2330, Expected=2200.1699
# Month=41, Predicted=2200.4194, Expected=2191.1201
# Month=42, Predicted=2192.1076, Expected=2200.6499
# Month=43, Predicted=2201.7644, Expected=2207.2600
# Month=44, Predicted=2207.1244, Expected=2210.7200
# Month=45, Predicted=2210.6982, Expected=2241.1299
# Month=46, Predicted=2240.5559, Expected=2249.7300
# Month=47, Predicted=2249.8280, Expected=2258.8301
# Month=48, Predicted=2258.6588, Expected=2263.3201
# Month=49, Predicted=2263.2346, Expected=2268.3501
# Month=50, Predicted=2268.3579, Expected=2253.7700
# Month=51, Predicted=2254.2947, Expected=2266.8101
# Month=52, Predicted=2268.7411, Expected=2259.2400
# Month=53, Predicted=2259.4432, Expected=2266.5000
# Month=54, Predicted=2267.4615, Expected=2270.5400
# Month=55, Predicted=2270.4907, Expected=2262.9299
# Month=56, Predicted=2263.2648, Expected=2260.2500
# Month=57, Predicted=2261.3936, Expected=2266.2300
# Month=58, Predicted=2266.6733, Expected=2270.2300
# Month=59, Predicted=2270.2111, Expected=2249.5000
# Month=60, Predicted=2250.2934, Expected=2251.6101
# Run 30 — RMSE: 11.145798, MSE: 124.228814, NMSE: 0.0007601007

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on S&P 500 (30 runs) =====
# RMSE: 11.190826 ± 0.069304
# MSE:  125.239396 ± 1.552787
# NMSE: 0.0007659945 ± 0.0000101003
#
# Best run: 19
#   RMSE: 11.037033
#   MSE:  121.816088
#   NMSE: 0.0007465323

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Hybrid (Feature Aug + Gate) — S&P 500\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Hybrid (Feature Aug + Gate) — S&P 500\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 11.037033
# MSE:  121.816088
# NMSE: 0.0007465323

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on S&P 500
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
