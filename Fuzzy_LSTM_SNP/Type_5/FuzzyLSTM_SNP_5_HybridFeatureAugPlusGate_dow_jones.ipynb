# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 505 (1.97 KB)
#  Trainable params: 505 (1.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (230, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (230, 1, 2), y_train shape: (230,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(2):
    print(f'\n===== RUN {run+1}/2 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=3804.6282, Expected=3796.0000
# Month=2, Predicted=3798.0777, Expected=3793.0000
# Month=3, Predicted=3793.3834, Expected=3766.0000
# Month=4, Predicted=3766.2751, Expected=3747.0000
# Month=5, Predicted=3746.3053, Expected=3754.0000
# Month=6, Predicted=3755.4789, Expected=3756.0000
# Month=7, Predicted=3756.2089, Expected=3767.0000
# Month=8, Predicted=3767.6402, Expected=3751.0000
# Month=9, Predicted=3750.3234, Expected=3769.0000
# Month=10, Predicted=3770.7729, Expected=3760.0000
# Month=11, Predicted=3759.5927, Expected=3785.0000
# Month=12, Predicted=3786.5300, Expected=3776.0000
# Month=13, Predicted=3776.1160, Expected=3755.0000
# Month=14, Predicted=3755.8232, Expected=3755.0000
# Month=15, Predicted=3756.1733, Expected=3751.0000
# Month=16, Predicted=3751.3981, Expected=3776.0000
# Month=17, Predicted=3777.3192, Expected=3847.0000
# Month=18, Predicted=3856.2443, Expected=3830.0000
# Month=19, Predicted=3839.7102, Expected=3881.0000
# Month=20, Predicted=3883.0158, Expected=3899.0000
# Month=21, Predicted=3909.0197, Expected=3917.0000
# Month=22, Predicted=3918.2293, Expected=3913.0000
# Month=23, Predicted=3912.8338, Expected=3901.0000
# Month=24, Predicted=3901.5162, Expected=3886.0000
# Month=25, Predicted=3887.1622, Expected=3892.5000
# Month=26, Predicted=3894.0670, Expected=3899.0000
# Month=27, Predicted=3899.3914, Expected=3886.0000
# Month=28, Predicted=3885.6705, Expected=3908.0000
# Month=29, Predicted=3909.8574, Expected=3875.0000
# Month=30, Predicted=3872.9237, Expected=3860.0000
# Month=31, Predicted=3856.8868, Expected=3880.0000
# Month=32, Predicted=3881.8967, Expected=3895.0000
# Month=33, Predicted=3896.6568, Expected=3954.0000
# Month=34, Predicted=3959.0979, Expected=3933.0000
# Month=35, Predicted=3937.9591, Expected=3937.0000
# Month=36, Predicted=3937.7580, Expected=3869.0000
# Month=37, Predicted=3869.8733, Expected=3852.0000
# Month=38, Predicted=3857.9301, Expected=3837.0000
# Month=39, Predicted=3838.2681, Expected=3832.0000
# Month=40, Predicted=3833.3693, Expected=3849.0000
# Month=41, Predicted=3850.1926, Expected=3863.0000
# Month=42, Predicted=3864.1693, Expected=3878.0000
# Month=43, Predicted=3878.8750, Expected=3855.0000
# Month=44, Predicted=3853.7644, Expected=3843.0000
# Month=45, Predicted=3843.5078, Expected=3847.0000
# Month=46, Predicted=3848.4709, Expected=3801.0000
# Month=47, Predicted=3800.5167, Expected=3787.0000
# Month=48, Predicted=3781.2610, Expected=3776.0000
# Month=49, Predicted=3777.2938, Expected=3797.0000
# Month=50, Predicted=3798.7011, Expected=3821.0000
# Month=51, Predicted=3823.6796, Expected=3877.0000
# Month=52, Predicted=3883.9522, Expected=3875.0000
# Month=53, Predicted=3883.2093, Expected=3890.0000
# Month=54, Predicted=3890.5838, Expected=3910.0000
# Month=55, Predicted=3911.4270, Expected=3924.0000
# Month=56, Predicted=3925.4743, Expected=3918.0000
# Month=57, Predicted=3917.6105, Expected=3936.0000
# Month=58, Predicted=3937.2111, Expected=3911.0000
# Month=59, Predicted=3909.5724, Expected=3891.0000
# Month=60, Predicted=3890.8237, Expected=3855.0000
# Run 1 — RMSE: 24.195387, MSE: 585.416770, NMSE: 0.0026342707
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3796.4821, Expected=3796.0000
# Month=2, Predicted=3795.5758, Expected=3793.0000
# Month=3, Predicted=3795.2845, Expected=3766.0000
# Month=4, Predicted=3764.4226, Expected=3747.0000
# Month=5, Predicted=3744.7422, Expected=3754.0000
# Month=6, Predicted=3755.8677, Expected=3756.0000
# Month=7, Predicted=3758.1511, Expected=3767.0000
# Month=8, Predicted=3771.8150, Expected=3751.0000
# Month=9, Predicted=3748.0492, Expected=3769.0000
# Month=10, Predicted=3773.5251, Expected=3760.0000
# Month=11, Predicted=3758.5450, Expected=3785.0000
# Month=12, Predicted=3792.2966, Expected=3776.0000
# Month=13, Predicted=3774.5959, Expected=3755.0000
# Month=14, Predicted=3754.8606, Expected=3755.0000
# Month=15, Predicted=3755.2951, Expected=3751.0000
# Month=16, Predicted=3753.6297, Expected=3776.0000
# Month=17, Predicted=3783.6348, Expected=3847.0000
# Month=18, Predicted=3841.2954, Expected=3830.0000
# Month=19, Predicted=3827.4981, Expected=3881.0000
# Month=20, Predicted=3887.0977, Expected=3899.0000
# Month=21, Predicted=3897.6165, Expected=3917.0000
# Month=22, Predicted=3917.8317, Expected=3913.0000
# Month=23, Predicted=3912.3219, Expected=3901.0000
# Month=24, Predicted=3902.1944, Expected=3886.0000
# Month=25, Predicted=3886.9962, Expected=3892.5000
# Month=26, Predicted=3895.7840, Expected=3899.0000
# Month=27, Predicted=3902.0824, Expected=3886.0000
# Month=28, Predicted=3884.8853, Expected=3908.0000
# Month=29, Predicted=3914.2426, Expected=3875.0000
# Month=30, Predicted=3866.1504, Expected=3860.0000
# Month=31, Predicted=3856.2338, Expected=3880.0000
# Month=32, Predicted=3885.4227, Expected=3895.0000
# Month=33, Predicted=3895.9015, Expected=3954.0000
# Month=34, Predicted=3953.4665, Expected=3933.0000
# Month=35, Predicted=3928.5704, Expected=3937.0000
# Month=36, Predicted=3936.2849, Expected=3869.0000
# Month=37, Predicted=3863.8209, Expected=3852.0000
# Month=38, Predicted=3852.6025, Expected=3837.0000
# Month=39, Predicted=3837.5882, Expected=3832.0000
# Month=40, Predicted=3833.7123, Expected=3849.0000
# Month=41, Predicted=3855.7705, Expected=3863.0000
# Month=42, Predicted=3864.0189, Expected=3878.0000
# Month=43, Predicted=3879.1258, Expected=3855.0000
# Month=44, Predicted=3849.9490, Expected=3843.0000
# Month=45, Predicted=3841.7179, Expected=3847.0000
# Month=46, Predicted=3850.7507, Expected=3801.0000
# Month=47, Predicted=3793.7557, Expected=3787.0000
# Month=48, Predicted=3782.5249, Expected=3776.0000
# Month=49, Predicted=3777.2998, Expected=3797.0000
# Month=50, Predicted=3803.7444, Expected=3821.0000
# Month=51, Predicted=3821.5523, Expected=3877.0000
# Month=52, Predicted=3873.5532, Expected=3875.0000
# Month=53, Predicted=3874.3819, Expected=3890.0000
# Month=54, Predicted=3894.6367, Expected=3910.0000
# Month=55, Predicted=3911.1241, Expected=3924.0000
# Month=56, Predicted=3924.8509, Expected=3918.0000
# Month=57, Predicted=3916.9478, Expected=3936.0000
# Month=58, Predicted=3942.6350, Expected=3911.0000
# Month=59, Predicted=3905.2484, Expected=3891.0000
# Month=60, Predicted=3888.9769, Expected=3855.0000
# Run 2 — RMSE: 24.133705, MSE: 582.435725, NMSE: 0.0026797414
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3797.3436, Expected=3796.0000
# Month=2, Predicted=3795.3436, Expected=3793.0000
# Month=3, Predicted=3794.9513, Expected=3766.0000
# Month=4, Predicted=3767.3752, Expected=3747.0000
# Month=5, Predicted=3748.8127, Expected=3754.0000
# Month=6, Predicted=3756.5178, Expected=3756.0000
# Month=7, Predicted=3756.5309, Expected=3767.0000
# Month=8, Predicted=3768.7732, Expected=3751.0000
# Month=9, Predicted=3750.3436, Expected=3769.0000
# Month=10, Predicted=3771.7051, Expected=3760.0000
# Month=11, Predicted=3759.3436, Expected=3785.0000
# Month=12, Predicted=3788.0320, Expected=3776.0000
# Month=13, Predicted=3775.3436, Expected=3755.0000
# Month=14, Predicted=3757.3618, Expected=3755.0000
# Month=15, Predicted=3757.3761, Expected=3751.0000
# Month=16, Predicted=3752.6101, Expected=3776.0000
# Month=17, Predicted=3778.8969, Expected=3847.0000
# Month=18, Predicted=3846.4373, Expected=3830.0000
# Month=19, Predicted=3829.3436, Expected=3881.0000
# Month=20, Predicted=3883.1423, Expected=3899.0000
# Month=21, Predicted=3898.3436, Expected=3917.0000
# Month=22, Predicted=3916.3436, Expected=3913.0000
# Month=23, Predicted=3912.3436, Expected=3901.0000
# Month=24, Predicted=3902.9898, Expected=3886.0000
# Month=25, Predicted=3888.6727, Expected=3892.5000
# Month=26, Predicted=3895.2980, Expected=3899.0000
# Month=27, Predicted=3899.7971, Expected=3886.0000
# Month=28, Predicted=3886.1065, Expected=3908.0000
# Month=29, Predicted=3910.8953, Expected=3875.0000
# Month=30, Predicted=3874.3436, Expected=3860.0000
# Month=31, Predicted=3860.8545, Expected=3880.0000
# Month=32, Predicted=3882.7713, Expected=3895.0000
# Month=33, Predicted=3894.3436, Expected=3954.0000
# Month=34, Predicted=3955.1725, Expected=3933.0000
# Month=35, Predicted=3932.3436, Expected=3937.0000
# Month=36, Predicted=3939.3413, Expected=3869.0000
# Month=37, Predicted=3868.3436, Expected=3852.0000
# Month=38, Predicted=3859.8644, Expected=3837.0000
# Month=39, Predicted=3839.6717, Expected=3832.0000
# Month=40, Predicted=3834.7686, Expected=3849.0000
# Month=41, Predicted=3851.7992, Expected=3863.0000
# Month=42, Predicted=3862.3436, Expected=3878.0000
# Month=43, Predicted=3877.5861, Expected=3855.0000
# Month=44, Predicted=3854.3436, Expected=3843.0000
# Month=45, Predicted=3845.2478, Expected=3847.0000
# Month=46, Predicted=3849.8524, Expected=3801.0000
# Month=47, Predicted=3800.3436, Expected=3787.0000
# Month=48, Predicted=3786.2103, Expected=3776.0000
# Month=49, Predicted=3778.7407, Expected=3797.0000
# Month=50, Predicted=3799.9777, Expected=3821.0000
# Month=51, Predicted=3820.3436, Expected=3877.0000
# Month=52, Predicted=3876.3436, Expected=3875.0000
# Month=53, Predicted=3874.3436, Expected=3890.0000
# Month=54, Predicted=3892.4627, Expected=3910.0000
# Month=55, Predicted=3909.5754, Expected=3924.0000
# Month=56, Predicted=3923.3436, Expected=3918.0000
# Month=57, Predicted=3917.3436, Expected=3936.0000
# Month=58, Predicted=3938.8740, Expected=3911.0000
# Month=59, Predicted=3910.3436, Expected=3891.0000
# Month=60, Predicted=3893.0754, Expected=3855.0000
# Run 3 — RMSE: 24.765417, MSE: 613.325895, NMSE: 0.0028322936
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3803.8343, Expected=3796.0000
# Month=2, Predicted=3798.4557, Expected=3793.0000
# Month=3, Predicted=3793.9892, Expected=3766.0000
# Month=4, Predicted=3766.8219, Expected=3747.0000
# Month=5, Predicted=3746.6104, Expected=3754.0000
# Month=6, Predicted=3757.4115, Expected=3756.0000
# Month=7, Predicted=3755.0323, Expected=3767.0000
# Month=8, Predicted=3767.7710, Expected=3751.0000
# Month=9, Predicted=3748.1707, Expected=3769.0000
# Month=10, Predicted=3773.2471, Expected=3760.0000
# Month=11, Predicted=3757.3015, Expected=3785.0000
# Month=12, Predicted=3789.0899, Expected=3776.0000
# Month=13, Predicted=3774.4193, Expected=3755.0000
# Month=14, Predicted=3757.2067, Expected=3755.0000
# Month=15, Predicted=3757.6202, Expected=3751.0000
# Month=16, Predicted=3751.7786, Expected=3776.0000
# Month=17, Predicted=3779.1799, Expected=3847.0000
# Month=18, Predicted=3852.5170, Expected=3830.0000
# Month=19, Predicted=3848.8778, Expected=3881.0000
# Month=20, Predicted=3885.1737, Expected=3899.0000
# Month=21, Predicted=3913.7677, Expected=3917.0000
# Month=22, Predicted=3916.0033, Expected=3913.0000
# Month=23, Predicted=3910.6425, Expected=3901.0000
# Month=24, Predicted=3902.5153, Expected=3886.0000
# Month=25, Predicted=3889.0535, Expected=3892.5000
# Month=26, Predicted=3896.3984, Expected=3899.0000
# Month=27, Predicted=3898.3886, Expected=3886.0000
# Month=28, Predicted=3884.3230, Expected=3908.0000
# Month=29, Predicted=3912.5246, Expected=3875.0000
# Month=30, Predicted=3870.0110, Expected=3860.0000
# Month=31, Predicted=3856.4729, Expected=3880.0000
# Month=32, Predicted=3884.4940, Expected=3895.0000
# Month=33, Predicted=3894.4834, Expected=3954.0000
# Month=34, Predicted=3955.8096, Expected=3933.0000
# Month=35, Predicted=3946.3508, Expected=3937.0000
# Month=36, Predicted=3938.5983, Expected=3869.0000
# Month=37, Predicted=3868.6398, Expected=3852.0000
# Month=38, Predicted=3856.1903, Expected=3837.0000
# Month=39, Predicted=3839.8955, Expected=3832.0000
# Month=40, Predicted=3835.4302, Expected=3849.0000
# Month=41, Predicted=3852.1022, Expected=3863.0000
# Month=42, Predicted=3862.0208, Expected=3878.0000
# Month=43, Predicted=3876.8860, Expected=3855.0000
# Month=44, Predicted=3851.0505, Expected=3843.0000
# Month=45, Predicted=3844.3637, Expected=3847.0000
# Month=46, Predicted=3850.7324, Expected=3801.0000
# Month=47, Predicted=3799.4867, Expected=3787.0000
# Month=48, Predicted=3780.5904, Expected=3776.0000
# Month=49, Predicted=3779.2331, Expected=3797.0000
# Month=50, Predicted=3801.3919, Expected=3821.0000
# Month=51, Predicted=3821.4054, Expected=3877.0000
# Month=52, Predicted=3880.8265, Expected=3875.0000
# Month=53, Predicted=3890.3215, Expected=3890.0000
# Month=54, Predicted=3891.1575, Expected=3910.0000
# Month=55, Predicted=3909.3238, Expected=3924.0000
# Month=56, Predicted=3923.3580, Expected=3918.0000
# Month=57, Predicted=3915.4227, Expected=3936.0000
# Month=58, Predicted=3939.2537, Expected=3911.0000
# Month=59, Predicted=3906.7880, Expected=3891.0000
# Month=60, Predicted=3891.3004, Expected=3855.0000
# Run 4 — RMSE: 24.014602, MSE: 576.701122, NMSE: 0.0025974318
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3804.0532, Expected=3796.0000
# Month=2, Predicted=3798.1073, Expected=3793.0000
# Month=3, Predicted=3793.5522, Expected=3766.0000
# Month=4, Predicted=3766.0842, Expected=3747.0000
# Month=5, Predicted=3745.6752, Expected=3754.0000
# Month=6, Predicted=3755.5348, Expected=3756.0000
# Month=7, Predicted=3755.8977, Expected=3767.0000
# Month=8, Predicted=3767.6522, Expected=3751.0000
# Month=9, Predicted=3749.8360, Expected=3769.0000
# Month=10, Predicted=3771.4893, Expected=3760.0000
# Month=11, Predicted=3759.0743, Expected=3785.0000
# Month=12, Predicted=3787.2407, Expected=3776.0000
# Month=13, Predicted=3775.6323, Expected=3755.0000
# Month=14, Predicted=3755.8082, Expected=3755.0000
# Month=15, Predicted=3755.6626, Expected=3751.0000
# Month=16, Predicted=3751.3419, Expected=3776.0000
# Month=17, Predicted=3777.7336, Expected=3847.0000
# Month=18, Predicted=3854.8284, Expected=3830.0000
# Month=19, Predicted=3841.7768, Expected=3881.0000
# Month=20, Predicted=3884.7274, Expected=3899.0000
# Month=21, Predicted=3910.0993, Expected=3917.0000
# Month=22, Predicted=3917.9836, Expected=3913.0000
# Month=23, Predicted=3912.4175, Expected=3901.0000
# Month=24, Predicted=3901.6186, Expected=3886.0000
# Month=25, Predicted=3887.1535, Expected=3892.5000
# Month=26, Predicted=3894.4844, Expected=3899.0000
# Month=27, Predicted=3899.1263, Expected=3886.0000
# Month=28, Predicted=3885.3478, Expected=3908.0000
# Month=29, Predicted=3910.6786, Expected=3875.0000
# Month=30, Predicted=3872.1739, Expected=3860.0000
# Month=31, Predicted=3857.8091, Expected=3880.0000
# Month=32, Predicted=3882.7056, Expected=3895.0000
# Month=33, Predicted=3896.0414, Expected=3954.0000
# Month=34, Predicted=3958.0898, Expected=3933.0000
# Month=35, Predicted=3940.8451, Expected=3937.0000
# Month=36, Predicted=3937.6034, Expected=3869.0000
# Month=37, Predicted=3867.6193, Expected=3852.0000
# Month=38, Predicted=3851.7730, Expected=3837.0000
# Month=39, Predicted=3838.2318, Expected=3832.0000
# Month=40, Predicted=3833.4338, Expected=3849.0000
# Month=41, Predicted=3850.5686, Expected=3863.0000
# Month=42, Predicted=3863.6443, Expected=3878.0000
# Month=43, Predicted=3878.5155, Expected=3855.0000
# Month=44, Predicted=3853.1931, Expected=3843.0000
# Month=45, Predicted=3842.5990, Expected=3847.0000
# Month=46, Predicted=3848.9046, Expected=3801.0000
# Month=47, Predicted=3799.4840, Expected=3787.0000
# Month=48, Predicted=3784.7065, Expected=3776.0000
# Month=49, Predicted=3777.3986, Expected=3797.0000
# Month=50, Predicted=3799.4228, Expected=3821.0000
# Month=51, Predicted=3822.9680, Expected=3877.0000
# Month=52, Predicted=3882.8431, Expected=3875.0000
# Month=53, Predicted=3885.3306, Expected=3890.0000
# Month=54, Predicted=3891.0635, Expected=3910.0000
# Month=55, Predicted=3910.9285, Expected=3924.0000
# Month=56, Predicted=3924.9534, Expected=3918.0000
# Month=57, Predicted=3917.2076, Expected=3936.0000
# Month=58, Predicted=3937.6891, Expected=3911.0000
# Month=59, Predicted=3908.9028, Expected=3891.0000
# Month=60, Predicted=3889.9336, Expected=3855.0000
# Run 5 — RMSE: 23.977027, MSE: 574.897800, NMSE: 0.0025866443
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3805.8976, Expected=3796.0000
# Month=2, Predicted=3796.4319, Expected=3793.0000
# Month=3, Predicted=3794.3245, Expected=3766.0000
# Month=4, Predicted=3767.0366, Expected=3747.0000
# Month=5, Predicted=3745.3846, Expected=3754.0000
# Month=6, Predicted=3757.0434, Expected=3756.0000
# Month=7, Predicted=3755.8759, Expected=3767.0000
# Month=8, Predicted=3769.2622, Expected=3751.0000
# Month=9, Predicted=3746.7137, Expected=3769.0000
# Month=10, Predicted=3773.5252, Expected=3760.0000
# Month=11, Predicted=3756.2529, Expected=3785.0000
# Month=12, Predicted=3790.7767, Expected=3776.0000
# Month=13, Predicted=3773.0924, Expected=3755.0000
# Month=14, Predicted=3756.9080, Expected=3755.0000
# Month=15, Predicted=3756.7554, Expected=3751.0000
# Month=16, Predicted=3753.2120, Expected=3776.0000
# Month=17, Predicted=3781.7394, Expected=3847.0000
# Month=18, Predicted=3858.2066, Expected=3830.0000
# Month=19, Predicted=3847.1469, Expected=3881.0000
# Month=20, Predicted=3885.9338, Expected=3899.0000
# Month=21, Predicted=3918.4402, Expected=3917.0000
# Month=22, Predicted=3914.4674, Expected=3913.0000
# Month=23, Predicted=3909.0486, Expected=3901.0000
# Month=24, Predicted=3902.9172, Expected=3886.0000
# Month=25, Predicted=3889.0734, Expected=3892.5000
# Month=26, Predicted=3896.7042, Expected=3899.0000
# Month=27, Predicted=3899.5099, Expected=3886.0000
# Month=28, Predicted=3884.1021, Expected=3908.0000
# Month=29, Predicted=3913.6217, Expected=3875.0000
# Month=30, Predicted=3867.9692, Expected=3860.0000
# Month=31, Predicted=3855.9128, Expected=3880.0000
# Month=32, Predicted=3885.3732, Expected=3895.0000
# Month=33, Predicted=3894.5700, Expected=3954.0000
# Month=34, Predicted=3958.1861, Expected=3933.0000
# Month=35, Predicted=3947.3776, Expected=3937.0000
# Month=36, Predicted=3937.3786, Expected=3869.0000
# Month=37, Predicted=3865.0501, Expected=3852.0000
# Month=38, Predicted=3853.3493, Expected=3837.0000
# Month=39, Predicted=3839.4306, Expected=3832.0000
# Month=40, Predicted=3835.3939, Expected=3849.0000
# Month=41, Predicted=3854.4100, Expected=3863.0000
# Month=42, Predicted=3861.8140, Expected=3878.0000
# Month=43, Predicted=3876.1722, Expected=3855.0000
# Month=44, Predicted=3849.1276, Expected=3843.0000
# Month=45, Predicted=3843.0253, Expected=3847.0000
# Month=46, Predicted=3851.5297, Expected=3801.0000
# Month=47, Predicted=3797.6467, Expected=3787.0000
# Month=48, Predicted=3781.1261, Expected=3776.0000
# Month=49, Predicted=3779.2041, Expected=3797.0000
# Month=50, Predicted=3803.1030, Expected=3821.0000
# Month=51, Predicted=3822.0787, Expected=3877.0000
# Month=52, Predicted=3883.6967, Expected=3875.0000
# Month=53, Predicted=3892.8140, Expected=3890.0000
# Month=54, Predicted=3891.7015, Expected=3910.0000
# Month=55, Predicted=3909.3663, Expected=3924.0000
# Month=56, Predicted=3922.6397, Expected=3918.0000
# Month=57, Predicted=3913.8265, Expected=3936.0000
# Month=58, Predicted=3940.9671, Expected=3911.0000
# Month=59, Predicted=3905.0917, Expected=3891.0000
# Month=60, Predicted=3889.9018, Expected=3855.0000
# Run 6 — RMSE: 23.961970, MSE: 574.175986, NMSE: 0.0025743937
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3805.5932, Expected=3796.0000
# Month=2, Predicted=3798.0526, Expected=3793.0000
# Month=3, Predicted=3793.6582, Expected=3766.0000
# Month=4, Predicted=3766.4437, Expected=3747.0000
# Month=5, Predicted=3747.1623, Expected=3754.0000
# Month=6, Predicted=3757.0276, Expected=3756.0000
# Month=7, Predicted=3755.3994, Expected=3767.0000
# Month=8, Predicted=3767.2811, Expected=3751.0000
# Month=9, Predicted=3748.8372, Expected=3769.0000
# Month=10, Predicted=3772.4759, Expected=3760.0000
# Month=11, Predicted=3758.2815, Expected=3785.0000
# Month=12, Predicted=3787.9356, Expected=3776.0000
# Month=13, Predicted=3774.9353, Expected=3755.0000
# Month=14, Predicted=3756.8347, Expected=3755.0000
# Month=15, Predicted=3757.5248, Expected=3751.0000
# Month=16, Predicted=3751.3558, Expected=3776.0000
# Month=17, Predicted=3778.0489, Expected=3847.0000
# Month=18, Predicted=3856.7182, Expected=3830.0000
# Month=19, Predicted=3839.3423, Expected=3881.0000
# Month=20, Predicted=3885.1132, Expected=3899.0000
# Month=21, Predicted=3911.1307, Expected=3917.0000
# Month=22, Predicted=3917.7624, Expected=3913.0000
# Month=23, Predicted=3911.6614, Expected=3901.0000
# Month=24, Predicted=3902.0390, Expected=3886.0000
# Month=25, Predicted=3888.4713, Expected=3892.5000
# Month=26, Predicted=3895.6845, Expected=3899.0000
# Month=27, Predicted=3898.6896, Expected=3886.0000
# Month=28, Predicted=3884.5517, Expected=3908.0000
# Month=29, Predicted=3911.4349, Expected=3875.0000
# Month=30, Predicted=3870.7158, Expected=3860.0000
# Month=31, Predicted=3857.3880, Expected=3880.0000
# Month=32, Predicted=3883.5293, Expected=3895.0000
# Month=33, Predicted=3896.0798, Expected=3954.0000
# Month=34, Predicted=3958.7654, Expected=3933.0000
# Month=35, Predicted=3940.9918, Expected=3937.0000
# Month=36, Predicted=3939.5385, Expected=3869.0000
# Month=37, Predicted=3867.8349, Expected=3852.0000
# Month=38, Predicted=3857.1697, Expected=3837.0000
# Month=39, Predicted=3839.9916, Expected=3832.0000
# Month=40, Predicted=3834.8917, Expected=3849.0000
# Month=41, Predicted=3851.0938, Expected=3863.0000
# Month=42, Predicted=3863.4886, Expected=3878.0000
# Month=43, Predicted=3878.1928, Expected=3855.0000
# Month=44, Predicted=3851.8030, Expected=3843.0000
# Month=45, Predicted=3844.7036, Expected=3847.0000
# Month=46, Predicted=3849.9422, Expected=3801.0000
# Month=47, Predicted=3799.3028, Expected=3787.0000
# Month=48, Predicted=3780.2301, Expected=3776.0000
# Month=49, Predicted=3778.7651, Expected=3797.0000
# Month=50, Predicted=3800.2299, Expected=3821.0000
# Month=51, Predicted=3823.3274, Expected=3877.0000
# Month=52, Predicted=3884.1851, Expected=3875.0000
# Month=53, Predicted=3885.7455, Expected=3890.0000
# Month=54, Predicted=3890.9848, Expected=3910.0000
# Month=55, Predicted=3910.8296, Expected=3924.0000
# Month=56, Predicted=3924.8497, Expected=3918.0000
# Month=57, Predicted=3916.3754, Expected=3936.0000
# Month=58, Predicted=3938.2318, Expected=3911.0000
# Month=59, Predicted=3907.4831, Expected=3891.0000
# Month=60, Predicted=3891.8776, Expected=3855.0000
# Run 7 — RMSE: 24.283269, MSE: 589.677129, NMSE: 0.0026494363
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3804.9461, Expected=3796.0000
# Month=2, Predicted=3798.1692, Expected=3793.0000
# Month=3, Predicted=3793.9144, Expected=3766.0000
# Month=4, Predicted=3766.5701, Expected=3747.0000
# Month=5, Predicted=3744.2461, Expected=3754.0000
# Month=6, Predicted=3754.9477, Expected=3756.0000
# Month=7, Predicted=3755.2006, Expected=3767.0000
# Month=8, Predicted=3767.7894, Expected=3751.0000
# Month=9, Predicted=3748.2055, Expected=3769.0000
# Month=10, Predicted=3774.4676, Expected=3760.0000
# Month=11, Predicted=3757.2517, Expected=3785.0000
# Month=12, Predicted=3789.5183, Expected=3776.0000
# Month=13, Predicted=3774.0427, Expected=3755.0000
# Month=14, Predicted=3757.2373, Expected=3755.0000
# Month=15, Predicted=3753.9383, Expected=3751.0000
# Month=16, Predicted=3751.6157, Expected=3776.0000
# Month=17, Predicted=3779.2183, Expected=3847.0000
# Month=18, Predicted=3855.3044, Expected=3830.0000
# Month=19, Predicted=3844.4490, Expected=3881.0000
# Month=20, Predicted=3888.2018, Expected=3899.0000
# Month=21, Predicted=3914.8204, Expected=3917.0000
# Month=22, Predicted=3916.6584, Expected=3913.0000
# Month=23, Predicted=3910.6399, Expected=3901.0000
# Month=24, Predicted=3902.3637, Expected=3886.0000
# Month=25, Predicted=3888.4080, Expected=3892.5000
# Month=26, Predicted=3896.5606, Expected=3899.0000
# Month=27, Predicted=3898.5947, Expected=3886.0000
# Month=28, Predicted=3884.3136, Expected=3908.0000
# Month=29, Predicted=3913.6855, Expected=3875.0000
# Month=30, Predicted=3869.5815, Expected=3860.0000
# Month=31, Predicted=3856.4716, Expected=3880.0000
# Month=32, Predicted=3886.2902, Expected=3895.0000
# Month=33, Predicted=3894.9213, Expected=3954.0000
# Month=34, Predicted=3958.1174, Expected=3933.0000
# Month=35, Predicted=3945.2049, Expected=3937.0000
# Month=36, Predicted=3934.4424, Expected=3869.0000
# Month=37, Predicted=3866.6313, Expected=3852.0000
# Month=38, Predicted=3854.7509, Expected=3837.0000
# Month=39, Predicted=3836.6671, Expected=3832.0000
# Month=40, Predicted=3834.1658, Expected=3849.0000
# Month=41, Predicted=3852.1128, Expected=3863.0000
# Month=42, Predicted=3862.4856, Expected=3878.0000
# Month=43, Predicted=3877.3993, Expected=3855.0000
# Month=44, Predicted=3850.9863, Expected=3843.0000
# Month=45, Predicted=3840.5261, Expected=3847.0000
# Month=46, Predicted=3851.7543, Expected=3801.0000
# Month=47, Predicted=3798.3029, Expected=3787.0000
# Month=48, Predicted=3784.6869, Expected=3776.0000
# Month=49, Predicted=3777.7870, Expected=3797.0000
# Month=50, Predicted=3802.1126, Expected=3821.0000
# Month=51, Predicted=3822.1448, Expected=3877.0000
# Month=52, Predicted=3882.9586, Expected=3875.0000
# Month=53, Predicted=3889.7863, Expected=3890.0000
# Month=54, Predicted=3891.4996, Expected=3910.0000
# Month=55, Predicted=3909.9921, Expected=3924.0000
# Month=56, Predicted=3923.7515, Expected=3918.0000
# Month=57, Predicted=3915.5079, Expected=3936.0000
# Month=58, Predicted=3939.3159, Expected=3911.0000
# Month=59, Predicted=3906.6128, Expected=3891.0000
# Month=60, Predicted=3888.2314, Expected=3855.0000
# Run 8 — RMSE: 23.911529, MSE: 571.761204, NMSE: 0.0025582866
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3803.8671, Expected=3796.0000
# Month=2, Predicted=3799.0279, Expected=3793.0000
# Month=3, Predicted=3794.2264, Expected=3766.0000
# Month=4, Predicted=3764.2153, Expected=3747.0000
# Month=5, Predicted=3745.9054, Expected=3754.0000
# Month=6, Predicted=3756.8582, Expected=3756.0000
# Month=7, Predicted=3756.1183, Expected=3767.0000
# Month=8, Predicted=3770.1329, Expected=3751.0000
# Month=9, Predicted=3745.8455, Expected=3769.0000
# Month=10, Predicted=3773.9462, Expected=3760.0000
# Month=11, Predicted=3755.8995, Expected=3785.0000
# Month=12, Predicted=3791.2889, Expected=3776.0000
# Month=13, Predicted=3773.1502, Expected=3755.0000
# Month=14, Predicted=3755.3726, Expected=3755.0000
# Month=15, Predicted=3756.6157, Expected=3751.0000
# Month=16, Predicted=3751.9380, Expected=3776.0000
# Month=17, Predicted=3781.2513, Expected=3847.0000
# Month=18, Predicted=3850.9438, Expected=3830.0000
# Month=19, Predicted=3842.1956, Expected=3881.0000
# Month=20, Predicted=3886.9801, Expected=3899.0000
# Month=21, Predicted=3915.1162, Expected=3917.0000
# Month=22, Predicted=3916.9116, Expected=3913.0000
# Month=23, Predicted=3910.0014, Expected=3901.0000
# Month=24, Predicted=3901.5792, Expected=3886.0000
# Month=25, Predicted=3887.4875, Expected=3892.5000
# Month=26, Predicted=3896.1767, Expected=3899.0000
# Month=27, Predicted=3900.2081, Expected=3886.0000
# Month=28, Predicted=3883.0081, Expected=3908.0000
# Month=29, Predicted=3914.1993, Expected=3875.0000
# Month=30, Predicted=3863.0258, Expected=3860.0000
# Month=31, Predicted=3857.1726, Expected=3880.0000
# Month=32, Predicted=3885.5913, Expected=3895.0000
# Month=33, Predicted=3895.4763, Expected=3954.0000
# Month=34, Predicted=3955.1620, Expected=3933.0000
# Month=35, Predicted=3940.8309, Expected=3937.0000
# Month=36, Predicted=3938.2325, Expected=3869.0000
# Month=37, Predicted=3860.9597, Expected=3852.0000
# Month=38, Predicted=3853.2552, Expected=3837.0000
# Month=39, Predicted=3838.3554, Expected=3832.0000
# Month=40, Predicted=3834.3593, Expected=3849.0000
# Month=41, Predicted=3854.6377, Expected=3863.0000
# Month=42, Predicted=3863.1582, Expected=3878.0000
# Month=43, Predicted=3878.2875, Expected=3855.0000
# Month=44, Predicted=3846.8370, Expected=3843.0000
# Month=45, Predicted=3843.2085, Expected=3847.0000
# Month=46, Predicted=3850.6899, Expected=3801.0000
# Month=47, Predicted=3793.2567, Expected=3787.0000
# Month=48, Predicted=3782.5424, Expected=3776.0000
# Month=49, Predicted=3777.8725, Expected=3797.0000
# Month=50, Predicted=3803.3768, Expected=3821.0000
# Month=51, Predicted=3821.8663, Expected=3877.0000
# Month=52, Predicted=3879.6897, Expected=3875.0000
# Month=53, Predicted=3891.3547, Expected=3890.0000
# Month=54, Predicted=3893.9535, Expected=3910.0000
# Month=55, Predicted=3910.3550, Expected=3924.0000
# Month=56, Predicted=3924.3215, Expected=3918.0000
# Month=57, Predicted=3914.5196, Expected=3936.0000
# Month=58, Predicted=3941.7504, Expected=3911.0000
# Month=59, Predicted=3901.9484, Expected=3891.0000
# Month=60, Predicted=3890.3470, Expected=3855.0000
# Run 9 — RMSE: 23.804217, MSE: 566.640757, NMSE: 0.0025491688
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3804.3640, Expected=3796.0000
# Month=2, Predicted=3797.5725, Expected=3793.0000
# Month=3, Predicted=3794.2603, Expected=3766.0000
# Month=4, Predicted=3766.2955, Expected=3747.0000
# Month=5, Predicted=3744.6487, Expected=3754.0000
# Month=6, Predicted=3756.4751, Expected=3756.0000
# Month=7, Predicted=3755.4556, Expected=3767.0000
# Month=8, Predicted=3768.1145, Expected=3751.0000
# Month=9, Predicted=3748.1669, Expected=3769.0000
# Month=10, Predicted=3773.3214, Expected=3760.0000
# Month=11, Predicted=3757.6333, Expected=3785.0000
# Month=12, Predicted=3789.3093, Expected=3776.0000
# Month=13, Predicted=3774.7558, Expected=3755.0000
# Month=14, Predicted=3756.1576, Expected=3755.0000
# Month=15, Predicted=3756.0108, Expected=3751.0000
# Month=16, Predicted=3752.3149, Expected=3776.0000
# Month=17, Predicted=3779.3454, Expected=3847.0000
# Month=18, Predicted=3854.9102, Expected=3830.0000
# Month=19, Predicted=3843.0467, Expected=3881.0000
# Month=20, Predicted=3885.2678, Expected=3899.0000
# Month=21, Predicted=3913.8806, Expected=3917.0000
# Month=22, Predicted=3915.4364, Expected=3913.0000
# Month=23, Predicted=3910.6090, Expected=3901.0000
# Month=24, Predicted=3902.5431, Expected=3886.0000
# Month=25, Predicted=3888.0104, Expected=3892.5000
# Month=26, Predicted=3896.0777, Expected=3899.0000
# Month=27, Predicted=3898.8791, Expected=3886.0000
# Month=28, Predicted=3884.7553, Expected=3908.0000
# Month=29, Predicted=3912.9465, Expected=3875.0000
# Month=30, Predicted=3870.8540, Expected=3860.0000
# Month=31, Predicted=3855.9390, Expected=3880.0000
# Month=32, Predicted=3884.9529, Expected=3895.0000
# Month=33, Predicted=3894.9735, Expected=3954.0000
# Month=34, Predicted=3958.0884, Expected=3933.0000
# Month=35, Predicted=3944.7428, Expected=3937.0000
# Month=36, Predicted=3936.6820, Expected=3869.0000
# Month=37, Predicted=3863.7058, Expected=3852.0000
# Month=38, Predicted=3853.8385, Expected=3837.0000
# Month=39, Predicted=3839.0272, Expected=3832.0000
# Month=40, Predicted=3834.4568, Expected=3849.0000
# Month=41, Predicted=3852.5116, Expected=3863.0000
# Month=42, Predicted=3862.2953, Expected=3878.0000
# Month=43, Predicted=3877.1585, Expected=3855.0000
# Month=44, Predicted=3851.2198, Expected=3843.0000
# Month=45, Predicted=3842.1091, Expected=3847.0000
# Month=46, Predicted=3850.6953, Expected=3801.0000
# Month=47, Predicted=3797.0953, Expected=3787.0000
# Month=48, Predicted=3782.6226, Expected=3776.0000
# Month=49, Predicted=3778.3452, Expected=3797.0000
# Month=50, Predicted=3801.8466, Expected=3821.0000
# Month=51, Predicted=3822.0641, Expected=3877.0000
# Month=52, Predicted=3882.0069, Expected=3875.0000
# Month=53, Predicted=3888.7353, Expected=3890.0000
# Month=54, Predicted=3891.2217, Expected=3910.0000
# Month=55, Predicted=3909.8050, Expected=3924.0000
# Month=56, Predicted=3923.4491, Expected=3918.0000
# Month=57, Predicted=3915.2501, Expected=3936.0000
# Month=58, Predicted=3939.5174, Expected=3911.0000
# Month=59, Predicted=3907.2937, Expected=3891.0000
# Month=60, Predicted=3889.0139, Expected=3855.0000
# Run 10 — RMSE: 23.977664, MSE: 574.928382, NMSE: 0.0025843819
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3801.1157, Expected=3796.0000
# Month=2, Predicted=3798.5233, Expected=3793.0000
# Month=3, Predicted=3793.9377, Expected=3766.0000
# Month=4, Predicted=3763.5536, Expected=3747.0000
# Month=5, Predicted=3745.4773, Expected=3754.0000
# Month=6, Predicted=3756.5282, Expected=3756.0000
# Month=7, Predicted=3756.4818, Expected=3767.0000
# Month=8, Predicted=3769.0596, Expected=3751.0000
# Month=9, Predicted=3747.4992, Expected=3769.0000
# Month=10, Predicted=3773.5908, Expected=3760.0000
# Month=11, Predicted=3758.0715, Expected=3785.0000
# Month=12, Predicted=3790.2900, Expected=3776.0000
# Month=13, Predicted=3775.0275, Expected=3755.0000
# Month=14, Predicted=3754.4353, Expected=3755.0000
# Month=15, Predicted=3755.9876, Expected=3751.0000
# Month=16, Predicted=3752.1536, Expected=3776.0000
# Month=17, Predicted=3780.3346, Expected=3847.0000
# Month=18, Predicted=3842.9486, Expected=3830.0000
# Month=19, Predicted=3846.2291, Expected=3881.0000
# Month=20, Predicted=3886.7585, Expected=3899.0000
# Month=21, Predicted=3912.0279, Expected=3917.0000
# Month=22, Predicted=3916.7967, Expected=3913.0000
# Month=23, Predicted=3911.4029, Expected=3901.0000
# Month=24, Predicted=3901.2890, Expected=3886.0000
# Month=25, Predicted=3886.9231, Expected=3892.5000
# Month=26, Predicted=3896.0215, Expected=3899.0000
# Month=27, Predicted=3900.0056, Expected=3886.0000
# Month=28, Predicted=3883.8857, Expected=3908.0000
# Month=29, Predicted=3913.4844, Expected=3875.0000
# Month=30, Predicted=3864.7766, Expected=3860.0000
# Month=31, Predicted=3857.4768, Expected=3880.0000
# Month=32, Predicted=3885.2659, Expected=3895.0000
# Month=33, Predicted=3895.9204, Expected=3954.0000
# Month=34, Predicted=3950.6035, Expected=3933.0000
# Month=35, Predicted=3943.0520, Expected=3937.0000
# Month=36, Predicted=3937.2604, Expected=3869.0000
# Month=37, Predicted=3860.0968, Expected=3852.0000
# Month=38, Predicted=3851.6546, Expected=3837.0000
# Month=39, Predicted=3837.4475, Expected=3832.0000
# Month=40, Predicted=3834.0067, Expected=3849.0000
# Month=41, Predicted=3853.4161, Expected=3863.0000
# Month=42, Predicted=3863.5362, Expected=3878.0000
# Month=43, Predicted=3878.2401, Expected=3855.0000
# Month=44, Predicted=3848.7114, Expected=3843.0000
# Month=45, Predicted=3842.2665, Expected=3847.0000
# Month=46, Predicted=3850.6212, Expected=3801.0000
# Month=47, Predicted=3791.8395, Expected=3787.0000
# Month=48, Predicted=3783.7705, Expected=3776.0000
# Month=49, Predicted=3777.3496, Expected=3797.0000
# Month=50, Predicted=3802.5711, Expected=3821.0000
# Month=51, Predicted=3821.9497, Expected=3877.0000
# Month=52, Predicted=3874.8344, Expected=3875.0000
# Month=53, Predicted=3888.9021, Expected=3890.0000
# Month=54, Predicted=3892.5073, Expected=3910.0000
# Month=55, Predicted=3910.5669, Expected=3924.0000
# Month=56, Predicted=3924.4673, Expected=3918.0000
# Month=57, Predicted=3915.9518, Expected=3936.0000
# Month=58, Predicted=3940.3965, Expected=3911.0000
# Month=59, Predicted=3904.2173, Expected=3891.0000
# Month=60, Predicted=3889.5678, Expected=3855.0000
# Run 11 — RMSE: 23.361450, MSE: 545.757352, NMSE: 0.0024691176
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3800.3744, Expected=3796.0000
# Month=2, Predicted=3797.1340, Expected=3793.0000
# Month=3, Predicted=3792.5803, Expected=3766.0000
# Month=4, Predicted=3763.1379, Expected=3747.0000
# Month=5, Predicted=3746.9569, Expected=3754.0000
# Month=6, Predicted=3757.0127, Expected=3756.0000
# Month=7, Predicted=3757.0951, Expected=3767.0000
# Month=8, Predicted=3769.4102, Expected=3751.0000
# Month=9, Predicted=3747.9404, Expected=3769.0000
# Month=10, Predicted=3773.2460, Expected=3760.0000
# Month=11, Predicted=3758.3824, Expected=3785.0000
# Month=12, Predicted=3789.4042, Expected=3776.0000
# Month=13, Predicted=3774.8116, Expected=3755.0000
# Month=14, Predicted=3753.1393, Expected=3755.0000
# Month=15, Predicted=3756.7946, Expected=3751.0000
# Month=16, Predicted=3752.0030, Expected=3776.0000
# Month=17, Predicted=3780.1823, Expected=3847.0000
# Month=18, Predicted=3840.7886, Expected=3830.0000
# Month=19, Predicted=3843.0752, Expected=3881.0000
# Month=20, Predicted=3883.2603, Expected=3899.0000
# Month=21, Predicted=3912.4157, Expected=3917.0000
# Month=22, Predicted=3915.3269, Expected=3913.0000
# Month=23, Predicted=3911.3221, Expected=3901.0000
# Month=24, Predicted=3900.1922, Expected=3886.0000
# Month=25, Predicted=3886.1809, Expected=3892.5000
# Month=26, Predicted=3895.6815, Expected=3899.0000
# Month=27, Predicted=3900.7816, Expected=3886.0000
# Month=28, Predicted=3884.0357, Expected=3908.0000
# Month=29, Predicted=3912.9691, Expected=3875.0000
# Month=30, Predicted=3866.0235, Expected=3860.0000
# Month=31, Predicted=3859.4657, Expected=3880.0000
# Month=32, Predicted=3885.2608, Expected=3895.0000
# Month=33, Predicted=3896.6752, Expected=3954.0000
# Month=34, Predicted=3948.1688, Expected=3933.0000
# Month=35, Predicted=3944.0081, Expected=3937.0000
# Month=36, Predicted=3936.5418, Expected=3869.0000
# Month=37, Predicted=3861.1948, Expected=3852.0000
# Month=38, Predicted=3853.7203, Expected=3837.0000
# Month=39, Predicted=3837.6269, Expected=3832.0000
# Month=40, Predicted=3833.6709, Expected=3849.0000
# Month=41, Predicted=3853.3323, Expected=3863.0000
# Month=42, Predicted=3864.3850, Expected=3878.0000
# Month=43, Predicted=3878.6741, Expected=3855.0000
# Month=44, Predicted=3849.1992, Expected=3843.0000
# Month=45, Predicted=3843.0017, Expected=3847.0000
# Month=46, Predicted=3850.0076, Expected=3801.0000
# Month=47, Predicted=3792.9478, Expected=3787.0000
# Month=48, Predicted=3787.0056, Expected=3776.0000
# Month=49, Predicted=3776.9939, Expected=3797.0000
# Month=50, Predicted=3802.2589, Expected=3821.0000
# Month=51, Predicted=3822.3072, Expected=3877.0000
# Month=52, Predicted=3872.3773, Expected=3875.0000
# Month=53, Predicted=3889.0596, Expected=3890.0000
# Month=54, Predicted=3890.5577, Expected=3910.0000
# Month=55, Predicted=3911.1934, Expected=3924.0000
# Month=56, Predicted=3924.7724, Expected=3918.0000
# Month=57, Predicted=3915.9880, Expected=3936.0000
# Month=58, Predicted=3939.7559, Expected=3911.0000
# Month=59, Predicted=3904.9840, Expected=3891.0000
# Month=60, Predicted=3890.3926, Expected=3855.0000
# Run 12 — RMSE: 23.333417, MSE: 544.448329, NMSE: 0.0024776255
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3802.1419, Expected=3796.0000
# Month=2, Predicted=3795.4448, Expected=3793.0000
# Month=3, Predicted=3795.8044, Expected=3766.0000
# Month=4, Predicted=3766.0673, Expected=3747.0000
# Month=5, Predicted=3745.6336, Expected=3754.0000
# Month=6, Predicted=3754.9866, Expected=3756.0000
# Month=7, Predicted=3757.3909, Expected=3767.0000
# Month=8, Predicted=3771.3088, Expected=3751.0000
# Month=9, Predicted=3747.8520, Expected=3769.0000
# Month=10, Predicted=3771.8574, Expected=3760.0000
# Month=11, Predicted=3757.8949, Expected=3785.0000
# Month=12, Predicted=3790.9041, Expected=3776.0000
# Month=13, Predicted=3774.2483, Expected=3755.0000
# Month=14, Predicted=3756.1029, Expected=3755.0000
# Month=15, Predicted=3755.0052, Expected=3751.0000
# Month=16, Predicted=3753.5670, Expected=3776.0000
# Month=17, Predicted=3782.8061, Expected=3847.0000
# Month=18, Predicted=3855.1278, Expected=3830.0000
# Month=19, Predicted=3829.3135, Expected=3881.0000
# Month=20, Predicted=3886.3094, Expected=3899.0000
# Month=21, Predicted=3902.9365, Expected=3917.0000
# Month=22, Predicted=3917.5274, Expected=3913.0000
# Month=23, Predicted=3911.3768, Expected=3901.0000
# Month=24, Predicted=3903.0059, Expected=3886.0000
# Month=25, Predicted=3887.3863, Expected=3892.5000
# Month=26, Predicted=3894.7866, Expected=3899.0000
# Month=27, Predicted=3901.3334, Expected=3886.0000
# Month=28, Predicted=3885.1303, Expected=3908.0000
# Month=29, Predicted=3912.3715, Expected=3875.0000
# Month=30, Predicted=3869.9333, Expected=3860.0000
# Month=31, Predicted=3857.5525, Expected=3880.0000
# Month=32, Predicted=3883.4941, Expected=3895.0000
# Month=33, Predicted=3895.6787, Expected=3954.0000
# Month=34, Predicted=3962.6403, Expected=3933.0000
# Month=35, Predicted=3930.8596, Expected=3937.0000
# Month=36, Predicted=3937.0364, Expected=3869.0000
# Month=37, Predicted=3860.3429, Expected=3852.0000
# Month=38, Predicted=3856.3224, Expected=3837.0000
# Month=39, Predicted=3837.6452, Expected=3832.0000
# Month=40, Predicted=3833.4657, Expected=3849.0000
# Month=41, Predicted=3854.6374, Expected=3863.0000
# Month=42, Predicted=3863.3263, Expected=3878.0000
# Month=43, Predicted=3878.1702, Expected=3855.0000
# Month=44, Predicted=3851.1544, Expected=3843.0000
# Month=45, Predicted=3842.2019, Expected=3847.0000
# Month=46, Predicted=3849.9149, Expected=3801.0000
# Month=47, Predicted=3795.2185, Expected=3787.0000
# Month=48, Predicted=3778.4994, Expected=3776.0000
# Month=49, Predicted=3777.3800, Expected=3797.0000
# Month=50, Predicted=3801.9558, Expected=3821.0000
# Month=51, Predicted=3822.8092, Expected=3877.0000
# Month=52, Predicted=3882.9643, Expected=3875.0000
# Month=53, Predicted=3876.1676, Expected=3890.0000
# Month=54, Predicted=3895.1259, Expected=3910.0000
# Month=55, Predicted=3910.8409, Expected=3924.0000
# Month=56, Predicted=3924.5098, Expected=3918.0000
# Month=57, Predicted=3915.9529, Expected=3936.0000
# Month=58, Predicted=3941.5863, Expected=3911.0000
# Month=59, Predicted=3906.9828, Expected=3891.0000
# Month=60, Predicted=3889.8259, Expected=3855.0000
# Run 13 — RMSE: 24.379947, MSE: 594.381831, NMSE: 0.0026914929
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3801.9915, Expected=3796.0000
# Month=2, Predicted=3797.7766, Expected=3793.0000
# Month=3, Predicted=3794.2227, Expected=3766.0000
# Month=4, Predicted=3765.3083, Expected=3747.0000
# Month=5, Predicted=3744.3556, Expected=3754.0000
# Month=6, Predicted=3754.8787, Expected=3756.0000
# Month=7, Predicted=3757.1474, Expected=3767.0000
# Month=8, Predicted=3769.1991, Expected=3751.0000
# Month=9, Predicted=3749.4735, Expected=3769.0000
# Month=10, Predicted=3773.3764, Expected=3760.0000
# Month=11, Predicted=3759.4651, Expected=3785.0000
# Month=12, Predicted=3788.7656, Expected=3776.0000
# Month=13, Predicted=3775.6952, Expected=3755.0000
# Month=14, Predicted=3755.9184, Expected=3755.0000
# Month=15, Predicted=3754.2400, Expected=3751.0000
# Month=16, Predicted=3751.9990, Expected=3776.0000
# Month=17, Predicted=3779.3224, Expected=3847.0000
# Month=18, Predicted=3847.4655, Expected=3830.0000
# Month=19, Predicted=3834.3335, Expected=3881.0000
# Month=20, Predicted=3885.8566, Expected=3899.0000
# Month=21, Predicted=3905.5772, Expected=3917.0000
# Month=22, Predicted=3919.5921, Expected=3913.0000
# Month=23, Predicted=3913.2747, Expected=3901.0000
# Month=24, Predicted=3901.8153, Expected=3886.0000
# Month=25, Predicted=3887.2790, Expected=3892.5000
# Month=26, Predicted=3895.4824, Expected=3899.0000
# Month=27, Predicted=3900.6347, Expected=3886.0000
# Month=28, Predicted=3885.3191, Expected=3908.0000
# Month=29, Predicted=3912.1375, Expected=3875.0000
# Month=30, Predicted=3868.5363, Expected=3860.0000
# Month=31, Predicted=3856.1779, Expected=3880.0000
# Month=32, Predicted=3884.3366, Expected=3895.0000
# Month=33, Predicted=3897.6410, Expected=3954.0000
# Month=34, Predicted=3955.2444, Expected=3933.0000
# Month=35, Predicted=3932.9941, Expected=3937.0000
# Month=36, Predicted=3935.8573, Expected=3869.0000
# Month=37, Predicted=3865.6323, Expected=3852.0000
# Month=38, Predicted=3856.8348, Expected=3837.0000
# Month=39, Predicted=3837.3879, Expected=3832.0000
# Month=40, Predicted=3833.4461, Expected=3849.0000
# Month=41, Predicted=3852.0685, Expected=3863.0000
# Month=42, Predicted=3865.4129, Expected=3878.0000
# Month=43, Predicted=3880.3697, Expected=3855.0000
# Month=44, Predicted=3851.7711, Expected=3843.0000
# Month=45, Predicted=3841.1194, Expected=3847.0000
# Month=46, Predicted=3850.1610, Expected=3801.0000
# Month=47, Predicted=3796.2045, Expected=3787.0000
# Month=48, Predicted=3783.2700, Expected=3776.0000
# Month=49, Predicted=3777.2445, Expected=3797.0000
# Month=50, Predicted=3800.8603, Expected=3821.0000
# Month=51, Predicted=3824.1191, Expected=3877.0000
# Month=52, Predicted=3878.8206, Expected=3875.0000
# Month=53, Predicted=3880.5450, Expected=3890.0000
# Month=54, Predicted=3892.5589, Expected=3910.0000
# Month=55, Predicted=3912.7090, Expected=3924.0000
# Month=56, Predicted=3926.5507, Expected=3918.0000
# Month=57, Predicted=3917.9226, Expected=3936.0000
# Month=58, Predicted=3939.1983, Expected=3911.0000
# Month=59, Predicted=3907.0555, Expected=3891.0000
# Month=60, Predicted=3888.6966, Expected=3855.0000
# Run 14 — RMSE: 23.849140, MSE: 568.781473, NMSE: 0.0025787890
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3799.2460, Expected=3796.0000
# Month=2, Predicted=3797.5381, Expected=3793.0000
# Month=3, Predicted=3794.5381, Expected=3766.0000
# Month=4, Predicted=3767.5381, Expected=3747.0000
# Month=5, Predicted=3745.1306, Expected=3754.0000
# Month=6, Predicted=3755.5381, Expected=3756.0000
# Month=7, Predicted=3757.5381, Expected=3767.0000
# Month=8, Predicted=3768.5381, Expected=3751.0000
# Month=9, Predicted=3752.5381, Expected=3769.0000
# Month=10, Predicted=3770.5381, Expected=3760.0000
# Month=11, Predicted=3761.5381, Expected=3785.0000
# Month=12, Predicted=3786.5381, Expected=3776.0000
# Month=13, Predicted=3777.5381, Expected=3755.0000
# Month=14, Predicted=3756.5381, Expected=3755.0000
# Month=15, Predicted=3756.5381, Expected=3751.0000
# Month=16, Predicted=3752.5381, Expected=3776.0000
# Month=17, Predicted=3777.5381, Expected=3847.0000
# Month=18, Predicted=3845.6012, Expected=3830.0000
# Month=19, Predicted=3831.5381, Expected=3881.0000
# Month=20, Predicted=3881.8316, Expected=3899.0000
# Month=21, Predicted=3900.5381, Expected=3917.0000
# Month=22, Predicted=3918.5381, Expected=3913.0000
# Month=23, Predicted=3914.5381, Expected=3901.0000
# Month=24, Predicted=3902.5381, Expected=3886.0000
# Month=25, Predicted=3887.5381, Expected=3892.5000
# Month=26, Predicted=3894.0381, Expected=3899.0000
# Month=27, Predicted=3900.5381, Expected=3886.0000
# Month=28, Predicted=3887.5381, Expected=3908.0000
# Month=29, Predicted=3909.5381, Expected=3875.0000
# Month=30, Predicted=3876.5381, Expected=3860.0000
# Month=31, Predicted=3855.9771, Expected=3880.0000
# Month=32, Predicted=3881.5381, Expected=3895.0000
# Month=33, Predicted=3896.5381, Expected=3954.0000
# Month=34, Predicted=3953.4868, Expected=3933.0000
# Month=35, Predicted=3934.5381, Expected=3937.0000
# Month=36, Predicted=3938.5381, Expected=3869.0000
# Month=37, Predicted=3871.6489, Expected=3852.0000
# Month=38, Predicted=3855.4882, Expected=3837.0000
# Month=39, Predicted=3838.5381, Expected=3832.0000
# Month=40, Predicted=3833.5381, Expected=3849.0000
# Month=41, Predicted=3850.5381, Expected=3863.0000
# Month=42, Predicted=3864.5381, Expected=3878.0000
# Month=43, Predicted=3879.5381, Expected=3855.0000
# Month=44, Predicted=3856.5381, Expected=3843.0000
# Month=45, Predicted=3844.0667, Expected=3847.0000
# Month=46, Predicted=3848.5381, Expected=3801.0000
# Month=47, Predicted=3802.5381, Expected=3787.0000
# Month=48, Predicted=3781.3418, Expected=3776.0000
# Month=49, Predicted=3777.5381, Expected=3797.0000
# Month=50, Predicted=3798.5381, Expected=3821.0000
# Month=51, Predicted=3822.5381, Expected=3877.0000
# Month=52, Predicted=3876.5977, Expected=3875.0000
# Month=53, Predicted=3876.5381, Expected=3890.0000
# Month=54, Predicted=3891.5381, Expected=3910.0000
# Month=55, Predicted=3911.5381, Expected=3924.0000
# Month=56, Predicted=3925.5381, Expected=3918.0000
# Month=57, Predicted=3919.5381, Expected=3936.0000
# Month=58, Predicted=3937.5381, Expected=3911.0000
# Month=59, Predicted=3912.5381, Expected=3891.0000
# Month=60, Predicted=3890.2164, Expected=3855.0000
# Run 15 — RMSE: 24.443529, MSE: 597.486121, NMSE: 0.0027307311
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3800.4616, Expected=3796.0000
# Month=2, Predicted=3795.7261, Expected=3793.0000
# Month=3, Predicted=3794.3329, Expected=3766.0000
# Month=4, Predicted=3766.3807, Expected=3747.0000
# Month=5, Predicted=3746.0174, Expected=3754.0000
# Month=6, Predicted=3755.1439, Expected=3756.0000
# Month=7, Predicted=3757.4227, Expected=3767.0000
# Month=8, Predicted=3769.3749, Expected=3751.0000
# Month=9, Predicted=3750.5612, Expected=3769.0000
# Month=10, Predicted=3770.9341, Expected=3760.0000
# Month=11, Predicted=3759.8162, Expected=3785.0000
# Month=12, Predicted=3788.0902, Expected=3776.0000
# Month=13, Predicted=3775.7995, Expected=3755.0000
# Month=14, Predicted=3755.7034, Expected=3755.0000
# Month=15, Predicted=3755.5473, Expected=3751.0000
# Month=16, Predicted=3752.6275, Expected=3776.0000
# Month=17, Predicted=3779.5546, Expected=3847.0000
# Month=18, Predicted=3852.1675, Expected=3830.0000
# Month=19, Predicted=3828.4502, Expected=3881.0000
# Month=20, Predicted=3882.6618, Expected=3899.0000
# Month=21, Predicted=3900.8743, Expected=3917.0000
# Month=22, Predicted=3917.5316, Expected=3913.0000
# Month=23, Predicted=3912.8501, Expected=3901.0000
# ...
# Month=53, Predicted=3884.3003, Expected=3890.0000
# Month=54, Predicted=3890.5825, Expected=3910.0000
# Month=55, Predicted=3911.1928, Expected=3924.0000
# Month=56, Predicted=3925.0282, Expected=3918.0000
# Month=57, Predicted=3916.4408, Expected=3936.0000
# Month=58, Predicted=3937.3823, Expected=3911.0000
# Month=59, Predicted=3907.7654, Expected=3891.0000
# Month=60, Predicted=3891.5539, Expected=3855.0000
# Run 25 — RMSE: 24.144454, MSE: 582.954638, NMSE: 0.0026217385
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3805.9169, Expected=3796.0000
# Month=2, Predicted=3798.1237, Expected=3793.0000
# Month=3, Predicted=3793.1886, Expected=3766.0000
# Month=4, Predicted=3764.8857, Expected=3747.0000
# Month=5, Predicted=3747.8968, Expected=3754.0000
# Month=6, Predicted=3756.4433, Expected=3756.0000
# Month=7, Predicted=3754.9490, Expected=3767.0000
# Month=8, Predicted=3767.5766, Expected=3751.0000
# Month=9, Predicted=3747.7275, Expected=3769.0000
# Month=10, Predicted=3772.2440, Expected=3760.0000
# Month=11, Predicted=3757.0150, Expected=3785.0000
# Month=12, Predicted=3788.4219, Expected=3776.0000
# Month=13, Predicted=3773.9884, Expected=3755.0000
# Month=14, Predicted=3755.3128, Expected=3755.0000
# Month=15, Predicted=3756.9740, Expected=3751.0000
# Month=16, Predicted=3750.8455, Expected=3776.0000
# Month=17, Predicted=3778.8080, Expected=3847.0000
# Month=18, Predicted=3857.1184, Expected=3830.0000
# Month=19, Predicted=3844.4282, Expected=3881.0000
# Month=20, Predicted=3886.3945, Expected=3899.0000
# Month=21, Predicted=3915.9038, Expected=3917.0000
# Month=22, Predicted=3916.7244, Expected=3913.0000
# Month=23, Predicted=3910.4792, Expected=3901.0000
# Month=24, Predicted=3901.0571, Expected=3886.0000
# Month=25, Predicted=3887.0659, Expected=3892.5000
# Month=26, Predicted=3894.9635, Expected=3899.0000
# Month=27, Predicted=3898.4161, Expected=3886.0000
# Month=28, Predicted=3883.8012, Expected=3908.0000
# Month=29, Predicted=3911.5025, Expected=3875.0000
# Month=30, Predicted=3868.8572, Expected=3860.0000
# Month=31, Predicted=3860.6405, Expected=3880.0000
# Month=32, Predicted=3883.3935, Expected=3895.0000
# Month=33, Predicted=3895.1321, Expected=3954.0000
# Month=34, Predicted=3958.9504, Expected=3933.0000
# Month=35, Predicted=3944.8608, Expected=3937.0000
# Month=36, Predicted=3938.9097, Expected=3869.0000
# Month=37, Predicted=3864.6116, Expected=3852.0000
# Month=38, Predicted=3856.0069, Expected=3837.0000
# Month=39, Predicted=3838.5057, Expected=3832.0000
# Month=40, Predicted=3833.7807, Expected=3849.0000
# Month=41, Predicted=3851.3179, Expected=3863.0000
# Month=42, Predicted=3862.5924, Expected=3878.0000
# Month=43, Predicted=3877.4922, Expected=3855.0000
# Month=44, Predicted=3850.4276, Expected=3843.0000
# Month=45, Predicted=3844.3422, Expected=3847.0000
# Month=46, Predicted=3849.1623, Expected=3801.0000
# Month=47, Predicted=3796.7241, Expected=3787.0000
# Month=48, Predicted=3787.9608, Expected=3776.0000
# Month=49, Predicted=3777.4222, Expected=3797.0000
# Month=50, Predicted=3800.3274, Expected=3821.0000
# Month=51, Predicted=3822.5411, Expected=3877.0000
# Month=52, Predicted=3884.0902, Expected=3875.0000
# Month=53, Predicted=3890.0105, Expected=3890.0000
# Month=54, Predicted=3891.3696, Expected=3910.0000
# Month=55, Predicted=3910.1616, Expected=3924.0000
# Month=56, Predicted=3923.8966, Expected=3918.0000
# Month=57, Predicted=3915.2859, Expected=3936.0000
# Month=58, Predicted=3938.5085, Expected=3911.0000
# Month=59, Predicted=3906.0215, Expected=3891.0000
# Month=60, Predicted=3891.9729, Expected=3855.0000
# Run 26 — RMSE: 24.056201, MSE: 578.700802, NMSE: 0.0025889333
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3799.9171, Expected=3796.0000
# Month=2, Predicted=3797.5734, Expected=3793.0000
# Month=3, Predicted=3793.3103, Expected=3766.0000
# Month=4, Predicted=3762.4920, Expected=3747.0000
# Month=5, Predicted=3745.2314, Expected=3754.0000
# Month=6, Predicted=3754.4770, Expected=3756.0000
# Month=7, Predicted=3757.3588, Expected=3767.0000
# Month=8, Predicted=3769.2848, Expected=3751.0000
# Month=9, Predicted=3749.4597, Expected=3769.0000
# Month=10, Predicted=3771.1149, Expected=3760.0000
# Month=11, Predicted=3759.9996, Expected=3785.0000
# Month=12, Predicted=3788.2785, Expected=3776.0000
# Month=13, Predicted=3776.2351, Expected=3755.0000
# Month=14, Predicted=3752.6614, Expected=3755.0000
# Month=15, Predicted=3754.5669, Expected=3751.0000
# Month=16, Predicted=3751.3004, Expected=3776.0000
# Month=17, Predicted=3779.3510, Expected=3847.0000
# Month=18, Predicted=3846.0955, Expected=3830.0000
# Month=19, Predicted=3830.4136, Expected=3881.0000
# Month=20, Predicted=3885.3692, Expected=3899.0000
# Month=21, Predicted=3901.0851, Expected=3917.0000
# Month=22, Predicted=3919.7505, Expected=3913.0000
# Month=23, Predicted=3913.7944, Expected=3901.0000
# Month=24, Predicted=3899.9701, Expected=3886.0000
# Month=25, Predicted=3884.4784, Expected=3892.5000
# Month=26, Predicted=3893.3401, Expected=3899.0000
# Month=27, Predicted=3900.8997, Expected=3886.0000
# Month=28, Predicted=3884.9760, Expected=3908.0000
# Month=29, Predicted=3910.8250, Expected=3875.0000
# Month=30, Predicted=3868.8045, Expected=3860.0000
# Month=31, Predicted=3858.5975, Expected=3880.0000
# Month=32, Predicted=3882.4300, Expected=3895.0000
# Month=33, Predicted=3897.6654, Expected=3954.0000
# Month=34, Predicted=3955.0705, Expected=3933.0000
# Month=35, Predicted=3931.7828, Expected=3937.0000
# Month=36, Predicted=3936.8428, Expected=3869.0000
# Month=37, Predicted=3858.7594, Expected=3852.0000
# Month=38, Predicted=3857.4527, Expected=3837.0000
# Month=39, Predicted=3835.3150, Expected=3832.0000
# Month=40, Predicted=3831.4849, Expected=3849.0000
# Month=41, Predicted=3851.7305, Expected=3863.0000
# Month=42, Predicted=3865.6300, Expected=3878.0000
# Month=43, Predicted=3880.6810, Expected=3855.0000
# Month=44, Predicted=3851.8256, Expected=3843.0000
# Month=45, Predicted=3841.5252, Expected=3847.0000
# Month=46, Predicted=3847.7824, Expected=3801.0000
# Month=47, Predicted=3793.1182, Expected=3787.0000
# Month=48, Predicted=3787.2355, Expected=3776.0000
# Month=49, Predicted=3774.7979, Expected=3797.0000
# Month=50, Predicted=3799.8669, Expected=3821.0000
# Month=51, Predicted=3823.7764, Expected=3877.0000
# Month=52, Predicted=3877.6551, Expected=3875.0000
# Month=53, Predicted=3877.1140, Expected=3890.0000
# Month=54, Predicted=3892.5283, Expected=3910.0000
# Month=55, Predicted=3912.8807, Expected=3924.0000
# Month=56, Predicted=3926.6121, Expected=3918.0000
# Month=57, Predicted=3918.3540, Expected=3936.0000
# Month=58, Predicted=3938.7746, Expected=3911.0000
# Month=59, Predicted=3907.2846, Expected=3891.0000
# Month=60, Predicted=3889.0991, Expected=3855.0000
# Run 27 — RMSE: 23.938668, MSE: 573.059838, NMSE: 0.0025966925
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3805.3802, Expected=3796.0000
# Month=2, Predicted=3798.0586, Expected=3793.0000
# Month=3, Predicted=3792.0632, Expected=3766.0000
# Month=4, Predicted=3763.4514, Expected=3747.0000
# Month=5, Predicted=3747.6430, Expected=3754.0000
# Month=6, Predicted=3756.6218, Expected=3756.0000
# Month=7, Predicted=3755.2130, Expected=3767.0000
# Month=8, Predicted=3767.7933, Expected=3751.0000
# Month=9, Predicted=3747.4173, Expected=3769.0000
# Month=10, Predicted=3772.5715, Expected=3760.0000
# Month=11, Predicted=3757.6277, Expected=3785.0000
# Month=12, Predicted=3788.7907, Expected=3776.0000
# Month=13, Predicted=3774.5923, Expected=3755.0000
# Month=14, Predicted=3753.9908, Expected=3755.0000
# Month=15, Predicted=3756.9198, Expected=3751.0000
# Month=16, Predicted=3750.3950, Expected=3776.0000
# Month=17, Predicted=3779.3793, Expected=3847.0000
# Month=18, Predicted=3856.3923, Expected=3830.0000
# Month=19, Predicted=3840.5671, Expected=3881.0000
# Month=20, Predicted=3885.2165, Expected=3899.0000
# Month=21, Predicted=3911.4783, Expected=3917.0000
# Month=22, Predicted=3917.4753, Expected=3913.0000
# Month=23, Predicted=3911.2979, Expected=3901.0000
# Month=24, Predicted=3900.0165, Expected=3886.0000
# Month=25, Predicted=3886.4666, Expected=3892.5000
# Month=26, Predicted=3895.0800, Expected=3899.0000
# Month=27, Predicted=3898.8360, Expected=3886.0000
# Month=28, Predicted=3883.2373, Expected=3908.0000
# Month=29, Predicted=3912.0345, Expected=3875.0000
# Month=30, Predicted=3867.9393, Expected=3860.0000
# Month=31, Predicted=3859.9351, Expected=3880.0000
# Month=32, Predicted=3884.0495, Expected=3895.0000
# Month=33, Predicted=3896.4376, Expected=3954.0000
# Month=34, Predicted=3960.1991, Expected=3933.0000
# Month=35, Predicted=3941.9473, Expected=3937.0000
# Month=36, Predicted=3937.0968, Expected=3869.0000
# Month=37, Predicted=3860.8819, Expected=3852.0000
# Month=38, Predicted=3854.8899, Expected=3837.0000
# Month=39, Predicted=3838.2614, Expected=3832.0000
# Month=40, Predicted=3833.5710, Expected=3849.0000
# Month=41, Predicted=3851.6439, Expected=3863.0000
# Month=42, Predicted=3863.9398, Expected=3878.0000
# Month=43, Predicted=3878.7361, Expected=3855.0000
# Month=44, Predicted=3849.9561, Expected=3843.0000
# Month=45, Predicted=3843.8770, Expected=3847.0000
# Month=46, Predicted=3849.1507, Expected=3801.0000
# Month=47, Predicted=3794.0318, Expected=3787.0000
# Month=48, Predicted=3787.7709, Expected=3776.0000
# Month=49, Predicted=3777.0949, Expected=3797.0000
# Month=50, Predicted=3800.9118, Expected=3821.0000
# Month=51, Predicted=3823.8486, Expected=3877.0000
# Month=52, Predicted=3884.4112, Expected=3875.0000
# Month=53, Predicted=3886.2901, Expected=3890.0000
# Month=54, Predicted=3889.9720, Expected=3910.0000
# Month=55, Predicted=3911.5995, Expected=3924.0000
# Month=56, Predicted=3925.2381, Expected=3918.0000
# Month=57, Predicted=3915.7129, Expected=3936.0000
# Month=58, Predicted=3938.6705, Expected=3911.0000
# Month=59, Predicted=3905.6423, Expected=3891.0000
# Month=60, Predicted=3891.4543, Expected=3855.0000
# Run 28 — RMSE: 23.899789, MSE: 571.199909, NMSE: 0.0025609269
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3801.6520, Expected=3796.0000
# Month=2, Predicted=3796.5645, Expected=3793.0000
# Month=3, Predicted=3793.0250, Expected=3766.0000
# Month=4, Predicted=3763.5475, Expected=3747.0000
# Month=5, Predicted=3745.9700, Expected=3754.0000
# Month=6, Predicted=3754.1663, Expected=3756.0000
# Month=7, Predicted=3756.9932, Expected=3767.0000
# Month=8, Predicted=3768.8188, Expected=3751.0000
# Month=9, Predicted=3749.8245, Expected=3769.0000
# Month=10, Predicted=3770.3869, Expected=3760.0000
# Month=11, Predicted=3759.8429, Expected=3785.0000
# Month=12, Predicted=3787.7584, Expected=3776.0000
# Month=13, Predicted=3775.8799, Expected=3755.0000
# Month=14, Predicted=3753.2118, Expected=3755.0000
# Month=15, Predicted=3754.5322, Expected=3751.0000
# Month=16, Predicted=3751.1618, Expected=3776.0000
# Month=17, Predicted=3779.1082, Expected=3847.0000
# Month=18, Predicted=3853.4461, Expected=3830.0000
# Month=19, Predicted=3828.3755, Expected=3881.0000
# Month=20, Predicted=3885.1649, Expected=3899.0000
# Month=21, Predicted=3901.1267, Expected=3917.0000
# Month=22, Predicted=3919.4817, Expected=3913.0000
# Month=23, Predicted=3913.3574, Expected=3901.0000
# Month=24, Predicted=3900.1194, Expected=3886.0000
# Month=25, Predicted=3884.8229, Expected=3892.5000
# Month=26, Predicted=3892.9394, Expected=3899.0000
# Month=27, Predicted=3900.4775, Expected=3886.0000
# Month=28, Predicted=3885.1738, Expected=3908.0000
# Month=29, Predicted=3910.1363, Expected=3875.0000
# Month=30, Predicted=3870.8767, Expected=3860.0000
# Month=31, Predicted=3859.4614, Expected=3880.0000
# Month=32, Predicted=3881.7799, Expected=3895.0000
# Month=33, Predicted=3897.4045, Expected=3954.0000
# Month=34, Predicted=3959.8025, Expected=3933.0000
# Month=35, Predicted=3930.9443, Expected=3937.0000
# Month=36, Predicted=3936.4495, Expected=3869.0000
# Month=37, Predicted=3862.6197, Expected=3852.0000
# Month=38, Predicted=3855.7553, Expected=3837.0000
# Month=39, Predicted=3835.8391, Expected=3832.0000
# Month=40, Predicted=3831.4950, Expected=3849.0000
# Month=41, Predicted=3851.2523, Expected=3863.0000
# Month=42, Predicted=3865.3097, Expected=3878.0000
# Month=43, Predicted=3880.3490, Expected=3855.0000
# Month=44, Predicted=3852.7187, Expected=3843.0000
# Month=45, Predicted=3841.8988, Expected=3847.0000
# Month=46, Predicted=3847.4415, Expected=3801.0000
# Month=47, Predicted=3795.8074, Expected=3787.0000
# Month=48, Predicted=3787.6864, Expected=3776.0000
# Month=49, Predicted=3775.1134, Expected=3797.0000
# Month=50, Predicted=3799.2676, Expected=3821.0000
# Month=51, Predicted=3824.1687, Expected=3877.0000
# Month=52, Predicted=3882.3863, Expected=3875.0000
# Month=53, Predicted=3875.3528, Expected=3890.0000
# Month=54, Predicted=3891.8782, Expected=3910.0000
# Month=55, Predicted=3912.8682, Expected=3924.0000
# Month=56, Predicted=3926.2457, Expected=3918.0000
# Month=57, Predicted=3918.0689, Expected=3936.0000
# Month=58, Predicted=3938.2307, Expected=3911.0000
# Month=59, Predicted=3908.4196, Expected=3891.0000
# Month=60, Predicted=3889.7635, Expected=3855.0000
# Run 29 — RMSE: 24.229563, MSE: 587.071716, NMSE: 0.0026526923
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3802.5756, Expected=3796.0000
# Month=2, Predicted=3796.6850, Expected=3793.0000
# Month=3, Predicted=3793.6028, Expected=3766.0000
# Month=4, Predicted=3763.5484, Expected=3747.0000
# Month=5, Predicted=3745.4489, Expected=3754.0000
# Month=6, Predicted=3757.2255, Expected=3756.0000
# Month=7, Predicted=3756.0013, Expected=3767.0000
# Month=8, Predicted=3769.4731, Expected=3751.0000
# Month=9, Predicted=3746.6631, Expected=3769.0000
# Month=10, Predicted=3774.3057, Expected=3760.0000
# Month=11, Predicted=3756.5433, Expected=3785.0000
# Month=12, Predicted=3791.5678, Expected=3776.0000
# Month=13, Predicted=3773.5985, Expected=3755.0000
# Month=14, Predicted=3754.3564, Expected=3755.0000
# Month=15, Predicted=3756.7786, Expected=3751.0000
# Month=16, Predicted=3751.8587, Expected=3776.0000
# Month=17, Predicted=3782.0500, Expected=3847.0000
# Month=18, Predicted=3852.1497, Expected=3830.0000
# Month=19, Predicted=3845.0786, Expected=3881.0000
# Month=20, Predicted=3889.7873, Expected=3899.0000
# Month=21, Predicted=3913.5234, Expected=3917.0000
# Month=22, Predicted=3914.8790, Expected=3913.0000
# Month=23, Predicted=3909.9446, Expected=3901.0000
# Month=24, Predicted=3901.0634, Expected=3886.0000
# Month=25, Predicted=3886.8854, Expected=3892.5000
# Month=26, Predicted=3896.3086, Expected=3899.0000
# Month=27, Predicted=3899.8331, Expected=3886.0000
# Month=28, Predicted=3883.3294, Expected=3908.0000
# Month=29, Predicted=3914.3361, Expected=3875.0000
# Month=30, Predicted=3865.0019, Expected=3860.0000
# Month=31, Predicted=3856.8908, Expected=3880.0000
# Month=32, Predicted=3886.0093, Expected=3895.0000
# Month=33, Predicted=3894.1669, Expected=3954.0000
# Month=34, Predicted=3955.7409, Expected=3933.0000
# Month=35, Predicted=3947.2397, Expected=3937.0000
# Month=36, Predicted=3938.1933, Expected=3869.0000
# Month=37, Predicted=3855.7970, Expected=3852.0000
# Month=38, Predicted=3857.8948, Expected=3837.0000
# Month=39, Predicted=3838.0363, Expected=3832.0000
# Month=40, Predicted=3834.1632, Expected=3849.0000
# Month=41, Predicted=3854.2187, Expected=3863.0000
# Month=42, Predicted=3862.0232, Expected=3878.0000
# Month=43, Predicted=3877.0678, Expected=3855.0000
# Month=44, Predicted=3848.0096, Expected=3843.0000
# Month=45, Predicted=3842.8501, Expected=3847.0000
# Month=46, Predicted=3850.6521, Expected=3801.0000
# Month=47, Predicted=3792.1013, Expected=3787.0000
# Month=48, Predicted=3781.5023, Expected=3776.0000
# Month=49, Predicted=3777.5084, Expected=3797.0000
# Month=50, Predicted=3803.3959, Expected=3821.0000
# Month=51, Predicted=3820.9421, Expected=3877.0000
# Month=52, Predicted=3879.9101, Expected=3875.0000
# Month=53, Predicted=3889.9438, Expected=3890.0000
# Month=54, Predicted=3892.7273, Expected=3910.0000
# Month=55, Predicted=3909.5262, Expected=3924.0000
# Month=56, Predicted=3922.6729, Expected=3918.0000
# Month=57, Predicted=3914.6876, Expected=3936.0000
# Month=58, Predicted=3941.1993, Expected=3911.0000
# Month=59, Predicted=3903.5165, Expected=3891.0000
# Month=60, Predicted=3889.6875, Expected=3855.0000
# Run 30 — RMSE: 23.795412, MSE: 566.221650, NMSE: 0.0025366147

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (2 runs)
# ============================================================

print('\n===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Dow Jones Industrial Index (2 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.050269 ± 0.283998
# MSE:  578.496111 ± 13.640992
# NMSE: 0.0026149765 ± 0.0000725272
#
# Best run: 12
#   RMSE: 23.333417
#   MSE:  544.448329
#   NMSE: 0.0024776255

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Hybrid (Feature Aug + Gate) — Dow Jones Industrial Index\nPredictions vs Actual (Best of 2 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Hybrid (Feature Aug + Gate) — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 23.333417
# MSE:  544.448329
# NMSE: 0.0024776255

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
