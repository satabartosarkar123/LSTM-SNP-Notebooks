# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: M4 Daily
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 4864

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-04-25 09:22:19

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)
# Out:
# Forcing CPU execution (disabled GPU visibility).

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn_1 (RNN)                 (1, 8)                    496
#
#  dense_1 (Dense)             (1, 1)                    9
#
# =================================================================
# Total params: 505 (1.97 KB)
# Trainable params: 505 (1.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — M4 Daily

# %%
# ============================================================
# 1. Load Time Series Data
series_df = pd.read_csv(
    '../../content/archive/Daily-train.csv',
    nrows=1
)

# Extract the first series (dropping the 'V1' ID column and any NaNs)
raw_values = series_df.iloc[0, 1:].dropna().values.astype(float)
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (1006,)
# First 5 values: [1017.1 1019.3 1017.  1019.2 1018.7]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (1005, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (945, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (945, 1, 2), y_train shape: (945,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/2 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=1946.8989, Expected=1955.7000
# Month=2, Predicted=1957.0989, Expected=1949.5000
# Month=3, Predicted=1950.8989, Expected=1960.0000
# Month=4, Predicted=1961.3989, Expected=1962.8000
# Month=5, Predicted=1964.1989, Expected=1945.7000
# Month=6, Predicted=1947.0989, Expected=1948.1000
# Month=7, Predicted=1949.4989, Expected=1950.5000
# Month=8, Predicted=1951.8989, Expected=1946.6000
# Month=9, Predicted=1947.9989, Expected=1939.9000
# Month=10, Predicted=1941.2989, Expected=1953.2000
# Month=11, Predicted=1954.5989, Expected=1945.4000
# Month=12, Predicted=1946.7989, Expected=1949.8000
# Month=13, Predicted=1951.1989, Expected=1947.8000
# Month=14, Predicted=1949.1989, Expected=1957.4000
# Month=15, Predicted=1958.7989, Expected=1968.4000
# Month=16, Predicted=1969.7989, Expected=1974.9000
# Month=17, Predicted=1976.2989, Expected=1987.4000
# Month=18, Predicted=1988.7989, Expected=1972.2000
# Month=19, Predicted=1973.5989, Expected=1962.5000
# Month=20, Predicted=1963.8989, Expected=1953.8000
# Month=21, Predicted=1955.1989, Expected=1947.3000
# Month=22, Predicted=1948.6989, Expected=1950.2000
# Month=23, Predicted=1951.5989, Expected=1954.0000
# Month=24, Predicted=1955.3989, Expected=1946.6000
# Month=25, Predicted=1947.9989, Expected=1951.5000
# Month=26, Predicted=1952.8989, Expected=1947.6000
# Month=27, Predicted=1948.9989, Expected=1943.4000
# Month=28, Predicted=1944.7989, Expected=1942.3000
# Month=29, Predicted=1943.6989, Expected=1936.4000
# Month=30, Predicted=1937.7989, Expected=1942.7000
# Month=31, Predicted=1944.0989, Expected=1955.3000
# Month=32, Predicted=1956.6989, Expected=1962.3000
# Month=33, Predicted=1963.6989, Expected=1965.3000
# Month=34, Predicted=1966.6989, Expected=1958.1000
# Month=35, Predicted=1959.4989, Expected=1961.3000
# Month=36, Predicted=1962.6989, Expected=1963.5000
# Month=37, Predicted=1964.8989, Expected=1974.1000
# Month=38, Predicted=1975.4989, Expected=1968.1000
# Month=39, Predicted=1969.4989, Expected=1979.5000
# Month=40, Predicted=1980.8989, Expected=1991.2000
# Month=41, Predicted=1992.5989, Expected=1997.7000
# Month=42, Predicted=1999.0989, Expected=1996.1000
# Month=43, Predicted=1997.4989, Expected=2003.5000
# Month=44, Predicted=2004.8989, Expected=2001.1000
# Month=45, Predicted=2002.4989, Expected=2002.7000
# Month=46, Predicted=2004.0989, Expected=2004.1000
# Month=47, Predicted=2005.4989, Expected=2004.3000
# Month=48, Predicted=2005.6989, Expected=2016.4000
# Month=49, Predicted=2017.7989, Expected=2016.5000
# Month=50, Predicted=2017.8989, Expected=2021.1000
# Month=51, Predicted=2022.4989, Expected=2008.2000
# Month=52, Predicted=2009.5989, Expected=2002.9000
# Month=53, Predicted=2004.2989, Expected=2012.6000
# Month=54, Predicted=2013.9989, Expected=2013.8000
# Month=55, Predicted=2015.1989, Expected=2003.4000
# Month=56, Predicted=2004.7989, Expected=2015.6000
# Month=57, Predicted=2016.9989, Expected=2009.7000
# Month=58, Predicted=2011.0989, Expected=2022.1000
# Month=59, Predicted=2023.4989, Expected=2031.6000
# Month=60, Predicted=2032.9989, Expected=2029.7000
# Run 1 — RMSE: 7.787020, MSE: 60.637675, NMSE: 0.0013579179, sMAPE: 0.331413
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=1946.8989, Expected=1955.7000
# Month=2, Predicted=1957.0989, Expected=1949.5000
# Month=3, Predicted=1950.8989, Expected=1960.0000
# Month=4, Predicted=1961.3989, Expected=1962.8000
# Month=5, Predicted=1964.1989, Expected=1945.7000
# Month=6, Predicted=1947.0989, Expected=1948.1000
# Month=7, Predicted=1949.4989, Expected=1950.5000
# Month=8, Predicted=1951.8989, Expected=1946.6000
# Month=9, Predicted=1947.9989, Expected=1939.9000
# Month=10, Predicted=1941.2989, Expected=1953.2000
# Month=11, Predicted=1954.5989, Expected=1945.4000
# Month=12, Predicted=1946.7989, Expected=1949.8000
# Month=13, Predicted=1951.1989, Expected=1947.8000
# Month=14, Predicted=1949.1989, Expected=1957.4000
# Month=15, Predicted=1958.7989, Expected=1968.4000
# Month=16, Predicted=1969.7989, Expected=1974.9000
# Month=17, Predicted=1976.2989, Expected=1987.4000
# Month=18, Predicted=1988.7989, Expected=1972.2000
# Month=19, Predicted=1973.5989, Expected=1962.5000
# Month=20, Predicted=1963.8989, Expected=1953.8000
# Month=21, Predicted=1955.1989, Expected=1947.3000
# Month=22, Predicted=1948.6989, Expected=1950.2000
# Month=23, Predicted=1951.5989, Expected=1954.0000
# Month=24, Predicted=1955.3989, Expected=1946.6000
# Month=25, Predicted=1947.9989, Expected=1951.5000
# Month=26, Predicted=1952.8989, Expected=1947.6000
# Month=27, Predicted=1948.9989, Expected=1943.4000
# Month=28, Predicted=1944.7989, Expected=1942.3000
# Month=29, Predicted=1943.6989, Expected=1936.4000
# Month=30, Predicted=1937.7989, Expected=1942.7000
# Month=31, Predicted=1944.0989, Expected=1955.3000
# Month=32, Predicted=1956.6989, Expected=1962.3000
# Month=33, Predicted=1963.6989, Expected=1965.3000
# Month=34, Predicted=1966.6989, Expected=1958.1000
# Month=35, Predicted=1959.4989, Expected=1961.3000
# Month=36, Predicted=1962.6989, Expected=1963.5000
# Month=37, Predicted=1964.8989, Expected=1974.1000
# Month=38, Predicted=1975.4989, Expected=1968.1000
# Month=39, Predicted=1969.4989, Expected=1979.5000
# Month=40, Predicted=1980.8989, Expected=1991.2000
# Month=41, Predicted=1992.5989, Expected=1997.7000
# Month=42, Predicted=1999.0989, Expected=1996.1000
# Month=43, Predicted=1997.4989, Expected=2003.5000
# Month=44, Predicted=2004.8989, Expected=2001.1000
# Month=45, Predicted=2002.4989, Expected=2002.7000
# Month=46, Predicted=2004.0989, Expected=2004.1000
# Month=47, Predicted=2005.4989, Expected=2004.3000
# Month=48, Predicted=2005.6989, Expected=2016.4000
# Month=49, Predicted=2017.7989, Expected=2016.5000
# Month=50, Predicted=2017.8989, Expected=2021.1000
# Month=51, Predicted=2022.4989, Expected=2008.2000
# Month=52, Predicted=2009.5989, Expected=2002.9000
# Month=53, Predicted=2004.2989, Expected=2012.6000
# Month=54, Predicted=2013.9989, Expected=2013.8000
# Month=55, Predicted=2015.1989, Expected=2003.4000
# Month=56, Predicted=2004.7989, Expected=2015.6000
# Month=57, Predicted=2016.9989, Expected=2009.7000
# Month=58, Predicted=2011.0989, Expected=2022.1000
# Month=59, Predicted=2023.4989, Expected=2031.6000
# Month=60, Predicted=2032.9989, Expected=2029.7000
# Run 2 — RMSE: 7.787020, MSE: 60.637675, NMSE: 0.0013579179, sMAPE: 0.331413
#
# ===== RUN 3/2 =====
# Training complete for run 3
# Month=1, Predicted=1945.5159, Expected=1955.7000
# Month=2, Predicted=1954.3939, Expected=1949.5000
# Month=3, Predicted=1949.7560, Expected=1960.0000
# Month=4, Predicted=1958.8543, Expected=1962.8000
# Month=5, Predicted=1962.2978, Expected=1945.7000
# Month=6, Predicted=1946.2686, Expected=1948.1000
# Month=7, Predicted=1948.4527, Expected=1950.5000
# Month=8, Predicted=1949.6644, Expected=1946.6000
# Month=9, Predicted=1946.2415, Expected=1939.9000
# Month=10, Predicted=1939.6641, Expected=1953.2000
# Month=11, Predicted=1951.9243, Expected=1945.4000
# Month=12, Predicted=1946.0183, Expected=1949.8000
# Month=13, Predicted=1949.0833, Expected=1947.8000
# Month=14, Predicted=1947.3597, Expected=1957.4000
# Month=15, Predicted=1956.1352, Expected=1968.4000
# Month=16, Predicted=1967.1899, Expected=1974.9000
# Month=17, Predicted=1974.1456, Expected=1987.4000
# Month=18, Predicted=1986.0054, Expected=1972.2000
# Month=19, Predicted=1973.4019, Expected=1962.5000
# Month=20, Predicted=1963.1918, Expected=1953.8000
# Month=21, Predicted=1953.8950, Expected=1947.3000
# Month=22, Predicted=1947.2166, Expected=1950.2000
# Month=23, Predicted=1949.4647, Expected=1954.0000
# Month=24, Predicted=1953.0979, Expected=1946.6000
# Month=25, Predicted=1946.5423, Expected=1951.5000
# Month=26, Predicted=1950.7193, Expected=1947.6000
# Month=27, Predicted=1947.3210, Expected=1943.4000
# Month=28, Predicted=1943.0161, Expected=1942.3000
# Month=29, Predicted=1941.7211, Expected=1936.4000
# Month=30, Predicted=1936.0938, Expected=1942.7000
# Month=31, Predicted=1941.7520, Expected=1955.3000
# Month=32, Predicted=1953.8591, Expected=1962.3000
# Month=33, Predicted=1961.5799, Expected=1965.3000
# Month=34, Predicted=1964.6367, Expected=1958.1000
# Month=35, Predicted=1958.0018, Expected=1961.3000
# Month=36, Predicted=1960.6016, Expected=1963.5000
# Month=37, Predicted=1962.7174, Expected=1974.1000
# Month=38, Predicted=1972.7445, Expected=1968.1000
# Month=39, Predicted=1968.3629, Expected=1979.5000
# Month=40, Predicted=1978.2967, Expected=1991.2000
# Month=41, Predicted=1989.9971, Expected=1997.7000
# Month=42, Predicted=1996.9862, Expected=1996.1000
# Month=43, Predicted=1995.7658, Expected=2003.5000
# Month=44, Predicted=2002.3649, Expected=2001.1000
# Month=45, Predicted=2000.8500, Expected=2002.7000
# Month=46, Predicted=2001.9387, Expected=2004.1000
# Month=47, Predicted=2003.3472, Expected=2004.3000
# Month=48, Predicted=2003.6329, Expected=2016.4000
# Month=49, Predicted=2014.9502, Expected=2016.5000
# Month=50, Predicted=2016.3459, Expected=2021.1000
# Month=51, Predicted=2020.1421, Expected=2008.2000
# Month=52, Predicted=2008.5667, Expected=2002.9000
# Month=53, Predicted=2003.1109, Expected=2012.6000
# Month=54, Predicted=2011.4163, Expected=2013.8000
# Month=55, Predicted=2013.3858, Expected=2003.4000
# Month=56, Predicted=2003.4568, Expected=2015.6000
# Month=57, Predicted=2014.6796, Expected=2009.7000
# Month=58, Predicted=2010.0520, Expected=2022.1000
# Month=59, Predicted=2020.8421, Expected=2031.6000
# Month=60, Predicted=2030.6254, Expected=2029.7000
# Run 3 — RMSE: 7.998856, MSE: 63.981695, NMSE: 0.0014374724, sMAPE: 0.343916
#
# ===== RUN 4/2 =====
# Training complete for run 4
# Month=1, Predicted=1945.3185, Expected=1955.7000
# Month=2, Predicted=1954.5066, Expected=1949.5000
# Month=3, Predicted=1950.1362, Expected=1960.0000
# Month=4, Predicted=1958.6935, Expected=1962.8000
# Month=5, Predicted=1962.5770, Expected=1945.7000
# Month=6, Predicted=1946.6135, Expected=1948.1000
# Month=7, Predicted=1948.3600, Expected=1950.5000
# Month=8, Predicted=1949.8039, Expected=1946.6000
# Month=9, Predicted=1946.4692, Expected=1939.9000
# Month=10, Predicted=1939.7951, Expected=1953.2000
# Month=11, Predicted=1951.7122, Expected=1945.4000
# Month=12, Predicted=1946.4889, Expected=1949.8000
# Month=13, Predicted=1948.9692, Expected=1947.8000
# Month=14, Predicted=1947.5993, Expected=1957.4000
# Month=15, Predicted=1956.1086, Expected=1968.4000
# Month=16, Predicted=1967.3493, Expected=1974.9000
# Month=17, Predicted=1974.3580, Expected=1987.4000
# Month=18, Predicted=1986.0964, Expected=1972.2000
# Month=19, Predicted=1973.9317, Expected=1962.5000
# Month=20, Predicted=1963.3511, Expected=1953.8000
# Month=21, Predicted=1953.9780, Expected=1947.3000
# Month=22, Predicted=1947.2688, Expected=1950.2000
# Month=23, Predicted=1949.4046, Expected=1954.0000
# Month=24, Predicted=1953.2468, Expected=1946.6000
# Month=25, Predicted=1946.8302, Expected=1951.5000
# Month=26, Predicted=1950.6129, Expected=1947.6000
# Month=27, Predicted=1947.5910, Expected=1943.4000
# Month=28, Predicted=1943.1169, Expected=1942.3000
# Month=29, Predicted=1941.7720, Expected=1936.4000
# Month=30, Predicted=1936.2683, Expected=1942.7000
# Month=31, Predicted=1941.6614, Expected=1955.3000
# Month=32, Predicted=1953.9627, Expected=1962.3000
# Month=33, Predicted=1961.8024, Expected=1965.3000
# Month=34, Predicted=1964.8472, Expected=1958.1000
# Month=35, Predicted=1958.2668, Expected=1961.3000
# Month=36, Predicted=1960.5259, Expected=1963.5000
# Month=37, Predicted=1962.8890, Expected=1974.1000
# Month=38, Predicted=1972.8042, Expected=1968.1000
# Month=39, Predicted=1968.7528, Expected=1979.5000
# Month=40, Predicted=1978.1290, Expected=1991.2000
# Month=41, Predicted=1990.1570, Expected=1997.7000
# Month=42, Predicted=1997.2008, Expected=1996.1000
# Month=43, Predicted=1996.0244, Expected=2003.5000
# Month=44, Predicted=2002.3719, Expected=2001.1000
# Month=45, Predicted=2001.1520, Expected=2002.7000
# Month=46, Predicted=2001.9970, Expected=2004.1000
# Month=47, Predicted=2003.4993, Expected=2004.3000
# Month=48, Predicted=2003.7965, Expected=2016.4000
# Month=49, Predicted=2014.9500, Expected=2016.5000
# Month=50, Predicted=2016.6793, Expected=2021.1000
# Month=51, Predicted=2020.2148, Expected=2008.2000
# Month=52, Predicted=2008.9230, Expected=2002.9000
# Month=53, Predicted=2003.1326, Expected=2012.6000
# Month=54, Predicted=2011.2850, Expected=2013.8000
# Month=55, Predicted=2013.6778, Expected=2003.4000
# Month=56, Predicted=2003.7164, Expected=2015.6000
# Month=57, Predicted=2014.3845, Expected=2009.7000
# Month=58, Predicted=2010.4718, Expected=2022.1000
# Month=59, Predicted=2020.6625, Expected=2031.6000
# Month=60, Predicted=2030.8240, Expected=2029.7000
# Run 4 — RMSE: 7.981059, MSE: 63.697299, NMSE: 0.0014313116, sMAPE: 0.342496
#
# ===== RUN 5/2 =====
# Training complete for run 5
# Month=1, Predicted=1946.3195, Expected=1955.7000
# Month=2, Predicted=1955.1571, Expected=1949.5000
# Month=3, Predicted=1950.8034, Expected=1960.0000
# Month=4, Predicted=1959.3221, Expected=1962.8000
# Month=5, Predicted=1963.1951, Expected=1945.7000
# Month=6, Predicted=1947.1972, Expected=1948.1000
# Month=7, Predicted=1949.2260, Expected=1950.5000
# Month=8, Predicted=1950.3783, Expected=1946.6000
# Month=9, Predicted=1946.9867, Expected=1939.9000
# Month=10, Predicted=1940.0667, Expected=1953.2000
# Month=11, Predicted=1952.4491, Expected=1945.4000
# Month=12, Predicted=1947.1318, Expected=1949.8000
# Month=13, Predicted=1949.4435, Expected=1947.8000
# Month=14, Predicted=1948.1833, Expected=1957.4000
# Month=15, Predicted=1956.6723, Expected=1968.4000
# Month=16, Predicted=1967.9714, Expected=1974.9000
# Month=17, Predicted=1974.9702, Expected=1987.4000
# Month=18, Predicted=1986.7372, Expected=1972.2000
# Month=19, Predicted=1974.6867, Expected=1962.5000
# Month=20, Predicted=1963.2538, Expected=1953.8000
# Month=21, Predicted=1954.0140, Expected=1947.3000
# Month=22, Predicted=1947.4001, Expected=1950.2000
# Month=23, Predicted=1949.8418, Expected=1954.0000
# Month=24, Predicted=1953.8134, Expected=1946.6000
# Month=25, Predicted=1947.3958, Expected=1951.5000
# Month=26, Predicted=1951.1005, Expected=1947.6000
# Month=27, Predicted=1948.1876, Expected=1943.4000
# Month=28, Predicted=1943.4227, Expected=1942.3000
# Month=29, Predicted=1942.1334, Expected=1936.4000
# Month=30, Predicted=1936.6655, Expected=1942.7000
# Month=31, Predicted=1942.1779, Expected=1955.3000
# Month=32, Predicted=1954.6052, Expected=1962.3000
# Month=33, Predicted=1962.3877, Expected=1965.3000
# Month=34, Predicted=1965.4649, Expected=1958.1000
# Month=35, Predicted=1958.8079, Expected=1961.3000
# Month=36, Predicted=1960.9591, Expected=1963.5000
# Month=37, Predicted=1963.4549, Expected=1974.1000
# Month=38, Predicted=1973.4022, Expected=1968.1000
# Month=39, Predicted=1969.4148, Expected=1979.5000
# Month=40, Predicted=1978.7774, Expected=1991.2000
# Month=41, Predicted=1990.7661, Expected=1997.7000
# Month=42, Predicted=1997.8052, Expected=1996.1000
# Month=43, Predicted=1996.6417, Expected=2003.5000
# Month=44, Predicted=2002.9023, Expected=2001.1000
# Month=45, Predicted=2001.7760, Expected=2002.7000
# Month=46, Predicted=2002.4292, Expected=2004.1000
# Month=47, Predicted=2004.0209, Expected=2004.3000
# Month=48, Predicted=2004.3010, Expected=2016.4000
# Month=49, Predicted=2015.5561, Expected=2016.5000
# Month=50, Predicted=2017.2855, Expected=2021.1000
# Month=51, Predicted=2020.7314, Expected=2008.2000
# Month=52, Predicted=2009.5449, Expected=2002.9000
# Month=53, Predicted=2003.2687, Expected=2012.6000
# Month=54, Predicted=2011.9040, Expected=2013.8000
# Month=55, Predicted=2014.3029, Expected=2003.4000
# Month=56, Predicted=2004.1920, Expected=2015.6000
# Month=57, Predicted=2015.2670, Expected=2009.7000
# Month=58, Predicted=2011.1256, Expected=2022.1000
# Month=59, Predicted=2021.3350, Expected=2031.6000
# Month=60, Predicted=2031.4108, Expected=2029.7000
# Run 5 — RMSE: 7.865937, MSE: 61.872962, NMSE: 0.0013904830, sMAPE: 0.336191
#
# ===== RUN 6/2 =====
# Training complete for run 6
# Month=1, Predicted=1947.5199, Expected=1955.7000
# Month=2, Predicted=1957.0509, Expected=1949.5000
# Month=3, Predicted=1950.8509, Expected=1960.0000
# Month=4, Predicted=1961.2869, Expected=1962.8000
# Month=5, Predicted=1964.1509, Expected=1945.7000
# Month=6, Predicted=1947.0509, Expected=1948.1000
# Month=7, Predicted=1950.3296, Expected=1950.5000
# Month=8, Predicted=1951.8509, Expected=1946.6000
# Month=9, Predicted=1947.9509, Expected=1939.9000
# Month=10, Predicted=1941.1206, Expected=1953.2000
# Month=11, Predicted=1954.4941, Expected=1945.4000
# Month=12, Predicted=1946.7509, Expected=1949.8000
# Month=13, Predicted=1951.0575, Expected=1947.8000
# Month=14, Predicted=1949.1509, Expected=1957.4000
# Month=15, Predicted=1958.7509, Expected=1968.4000
# Month=16, Predicted=1969.7509, Expected=1974.9000
# Month=17, Predicted=1976.2509, Expected=1987.4000
# Month=18, Predicted=1988.7509, Expected=1972.2000
# Month=19, Predicted=1973.5509, Expected=1962.5000
# Month=20, Predicted=1964.3399, Expected=1953.8000
# Month=21, Predicted=1955.0242, Expected=1947.3000
# Month=22, Predicted=1948.4975, Expected=1950.2000
# Month=23, Predicted=1951.4370, Expected=1954.0000
# Month=24, Predicted=1955.3509, Expected=1946.6000
# Month=25, Predicted=1947.9509, Expected=1951.5000
# Month=26, Predicted=1952.7539, Expected=1947.6000
# Month=27, Predicted=1948.9509, Expected=1943.4000
# Month=28, Predicted=1944.6464, Expected=1942.3000
# Month=29, Predicted=1943.5625, Expected=1936.4000
# Month=30, Predicted=1937.7509, Expected=1942.7000
# Month=31, Predicted=1943.9672, Expected=1955.3000
# Month=32, Predicted=1956.6509, Expected=1962.3000
# Month=33, Predicted=1963.6509, Expected=1965.3000
# Month=34, Predicted=1966.6509, Expected=1958.1000
# Month=35, Predicted=1959.4509, Expected=1961.3000
# Month=36, Predicted=1962.5410, Expected=1963.5000
# Month=37, Predicted=1964.8509, Expected=1974.1000
# Month=38, Predicted=1975.4509, Expected=1968.1000
# Month=39, Predicted=1969.4509, Expected=1979.5000
# Month=40, Predicted=1980.7942, Expected=1991.2000
# Month=41, Predicted=1992.5509, Expected=1997.7000
# Month=42, Predicted=1999.0509, Expected=1996.1000
# Month=43, Predicted=1997.4509, Expected=2003.5000
# Month=44, Predicted=2004.8509, Expected=2001.1000
# Month=45, Predicted=2002.4509, Expected=2002.7000
# Month=46, Predicted=2004.0509, Expected=2004.1000
# Month=47, Predicted=2005.4509, Expected=2004.3000
# Month=48, Predicted=2005.6509, Expected=2016.4000
# Month=49, Predicted=2017.7509, Expected=2016.5000
# Month=50, Predicted=2017.8509, Expected=2021.1000
# Month=51, Predicted=2022.4509, Expected=2008.2000
# Month=52, Predicted=2009.5509, Expected=2002.9000
# Month=53, Predicted=2004.4444, Expected=2012.6000
# Month=54, Predicted=2013.9016, Expected=2013.8000
# Month=55, Predicted=2015.1509, Expected=2003.4000
# Month=56, Predicted=2004.7509, Expected=2015.6000
# Month=57, Predicted=2016.9980, Expected=2009.7000
# Month=58, Predicted=2011.0509, Expected=2022.1000
# Month=59, Predicted=2023.4006, Expected=2031.6000
# Month=60, Predicted=2032.9509, Expected=2029.7000
# Run 6 — RMSE: 7.784145, MSE: 60.592914, NMSE: 0.0013576910, sMAPE: 0.330754
#
# ===== RUN 7/2 =====
# Training complete for run 7
# Month=1, Predicted=1946.6229, Expected=1955.7000
# Month=2, Predicted=1955.8221, Expected=1949.5000
# Month=3, Predicted=1951.0192, Expected=1960.0000
# Month=4, Predicted=1959.8579, Expected=1962.8000
# Month=5, Predicted=1963.7330, Expected=1945.7000
# Month=6, Predicted=1947.1214, Expected=1948.1000
# Month=7, Predicted=1949.4547, Expected=1950.5000
# Month=8, Predicted=1950.7918, Expected=1946.6000
# Month=9, Predicted=1947.2551, Expected=1939.9000
# Month=10, Predicted=1940.3089, Expected=1953.2000
# Month=11, Predicted=1953.0192, Expected=1945.4000
# Month=12, Predicted=1947.3160, Expected=1949.8000
# Month=13, Predicted=1949.8739, Expected=1947.8000
# Month=14, Predicted=1948.4934, Expected=1957.4000
# Month=15, Predicted=1957.2364, Expected=1968.4000
# Month=16, Predicted=1968.7743, Expected=1974.9000
# Month=17, Predicted=1975.6675, Expected=1987.4000
# Month=18, Predicted=1987.5024, Expected=1972.2000
# Month=19, Predicted=1974.5806, Expected=1962.5000
# Month=20, Predicted=1963.4590, Expected=1953.8000
# Month=21, Predicted=1954.2650, Expected=1947.3000
# Month=22, Predicted=1947.6753, Expected=1950.2000
# Month=23, Predicted=1950.2593, Expected=1954.0000
# Month=24, Predicted=1954.2780, Expected=1946.6000
# Month=25, Predicted=1947.5646, Expected=1951.5000
# Month=26, Predicted=1951.5428, Expected=1947.6000
# Month=27, Predicted=1948.4444, Expected=1943.4000
# Month=28, Predicted=1943.7135, Expected=1942.3000
# Month=29, Predicted=1942.4815, Expected=1936.4000
# Month=30, Predicted=1936.9000, Expected=1942.7000
# Month=31, Predicted=1942.6529, Expected=1955.3000
# Month=32, Predicted=1955.3592, Expected=1962.3000
# Month=33, Predicted=1963.1581, Expected=1965.3000
# Month=34, Predicted=1965.9561, Expected=1958.1000
# Month=35, Predicted=1958.9875, Expected=1961.3000
# Month=36, Predicted=1961.3773, Expected=1963.5000
# Month=37, Predicted=1963.8778, Expected=1974.1000
# Month=38, Predicted=1974.0349, Expected=1968.1000
# Month=39, Predicted=1969.6391, Expected=1979.5000
# Month=40, Predicted=1979.3287, Expected=1991.2000
# Month=41, Predicted=1991.6538, Expected=1997.7000
# Month=42, Predicted=1998.5255, Expected=1996.1000
# Month=43, Predicted=1996.9835, Expected=2003.5000
# Month=44, Predicted=2003.4263, Expected=2001.1000
# Month=45, Predicted=2002.0932, Expected=2002.7000
# Month=46, Predicted=2002.8320, Expected=2004.1000
# Month=47, Predicted=2004.4207, Expected=2004.3000
# Month=48, Predicted=2004.6732, Expected=2016.4000
# Month=49, Predicted=2016.1932, Expected=2016.5000
# Month=50, Predicted=2017.7662, Expected=2021.1000
# Month=51, Predicted=2021.2071, Expected=2008.2000
# Month=52, Predicted=2009.5518, Expected=2002.9000
# Month=53, Predicted=2003.5433, Expected=2012.6000
# Month=54, Predicted=2012.4378, Expected=2013.8000
# Month=55, Predicted=2014.7687, Expected=2003.4000
# Month=56, Predicted=2004.3067, Expected=2015.6000
# Month=57, Predicted=2015.7602, Expected=2009.7000
# Month=58, Predicted=2011.3625, Expected=2022.1000
# Month=59, Predicted=2021.9019, Expected=2031.6000
# Month=60, Predicted=2032.2594, Expected=2029.7000
# Run 7 — RMSE: 7.815229, MSE: 61.077800, NMSE: 0.0013686587, sMAPE: 0.333013
#
# ===== RUN 8/2 =====
# Training complete for run 8
# Month=1, Predicted=1946.9021, Expected=1955.7000
# Month=2, Predicted=1957.1021, Expected=1949.5000
# Month=3, Predicted=1950.9021, Expected=1960.0000
# Month=4, Predicted=1961.4021, Expected=1962.8000
# Month=5, Predicted=1964.2021, Expected=1945.7000
# Month=6, Predicted=1947.1021, Expected=1948.1000
# Month=7, Predicted=1949.5021, Expected=1950.5000
# Month=8, Predicted=1951.9021, Expected=1946.6000
# Month=9, Predicted=1948.0021, Expected=1939.9000
# Month=10, Predicted=1941.3021, Expected=1953.2000
# Month=11, Predicted=1954.6021, Expected=1945.4000
# Month=12, Predicted=1946.8021, Expected=1949.8000
# Month=13, Predicted=1951.2021, Expected=1947.8000
# Month=14, Predicted=1949.2021, Expected=1957.4000
# Month=15, Predicted=1958.8021, Expected=1968.4000
# Month=16, Predicted=1969.7743, Expected=1974.9000
# Month=17, Predicted=1976.3021, Expected=1987.4000
# Month=18, Predicted=1988.7765, Expected=1972.2000
# Month=19, Predicted=1973.6021, Expected=1962.5000
# Month=20, Predicted=1963.9021, Expected=1953.8000
# Month=21, Predicted=1955.2021, Expected=1947.3000
# Month=22, Predicted=1948.7021, Expected=1950.2000
# Month=23, Predicted=1951.6021, Expected=1954.0000
# Month=24, Predicted=1955.4021, Expected=1946.6000
# Month=25, Predicted=1948.0021, Expected=1951.5000
# Month=26, Predicted=1952.9021, Expected=1947.6000
# Month=27, Predicted=1949.0021, Expected=1943.4000
# Month=28, Predicted=1944.8021, Expected=1942.3000
# Month=29, Predicted=1943.7021, Expected=1936.4000
# Month=30, Predicted=1937.8021, Expected=1942.7000
# Month=31, Predicted=1944.1021, Expected=1955.3000
# Month=32, Predicted=1956.6675, Expected=1962.3000
# Month=33, Predicted=1963.7021, Expected=1965.3000
# Month=34, Predicted=1966.7021, Expected=1958.1000
# Month=35, Predicted=1959.5021, Expected=1961.3000
# Month=36, Predicted=1962.7021, Expected=1963.5000
# Month=37, Predicted=1964.9021, Expected=1974.1000
# Month=38, Predicted=1975.5021, Expected=1968.1000
# Month=39, Predicted=1969.5021, Expected=1979.5000
# Month=40, Predicted=1980.9021, Expected=1991.2000
# Month=41, Predicted=1992.5454, Expected=1997.7000
# Month=42, Predicted=1999.1021, Expected=1996.1000
# Month=43, Predicted=1997.5021, Expected=2003.5000
# Month=44, Predicted=2004.9021, Expected=2001.1000
# Month=45, Predicted=2002.5021, Expected=2002.7000
# Month=46, Predicted=2004.1021, Expected=2004.1000
# Month=47, Predicted=2005.5021, Expected=2004.3000
# Month=48, Predicted=2005.7021, Expected=2016.4000
# Month=49, Predicted=2017.8021, Expected=2016.5000
# Month=50, Predicted=2017.9021, Expected=2021.1000
# Month=51, Predicted=2022.5021, Expected=2008.2000
# Month=52, Predicted=2009.6021, Expected=2002.9000
# Month=53, Predicted=2004.3021, Expected=2012.6000
# Month=54, Predicted=2014.0021, Expected=2013.8000
# Month=55, Predicted=2015.2021, Expected=2003.4000
# Month=56, Predicted=2004.8021, Expected=2015.6000
# Month=57, Predicted=2017.0021, Expected=2009.7000
# Month=58, Predicted=2011.1021, Expected=2022.1000
# Month=59, Predicted=2023.5021, Expected=2031.6000
# Month=60, Predicted=2032.9791, Expected=2029.7000
# Run 8 — RMSE: 7.787289, MSE: 60.641869, NMSE: 0.0013581301, sMAPE: 0.331460
#
# ===== RUN 9/2 =====
# Training complete for run 9
# Month=1, Predicted=1945.4200, Expected=1955.7000
# Month=2, Predicted=1955.1441, Expected=1949.5000
# Month=3, Predicted=1950.3480, Expected=1960.0000
# Month=4, Predicted=1959.2627, Expected=1962.8000
# Month=5, Predicted=1962.8510, Expected=1945.7000
# Month=6, Predicted=1947.1795, Expected=1948.1000
# Month=7, Predicted=1948.8814, Expected=1950.5000
# Month=8, Predicted=1950.5449, Expected=1946.6000
# Month=9, Predicted=1947.1265, Expected=1939.9000
# Month=10, Predicted=1940.4001, Expected=1953.2000
# Month=11, Predicted=1952.2877, Expected=1945.4000
# Month=12, Predicted=1946.4081, Expected=1949.8000
# Month=13, Predicted=1949.3971, Expected=1947.8000
# Month=14, Predicted=1948.2265, Expected=1957.4000
# Month=15, Predicted=1956.8270, Expected=1968.4000
# Month=16, Predicted=1967.7288, Expected=1974.9000
# Month=17, Predicted=1974.5956, Expected=1987.4000
# Month=18, Predicted=1986.6438, Expected=1972.2000
# Month=19, Predicted=1973.8347, Expected=1962.5000
# Month=20, Predicted=1962.5646, Expected=1953.8000
# Month=21, Predicted=1954.1424, Expected=1947.3000
# Month=22, Predicted=1947.5618, Expected=1950.2000
# Month=23, Predicted=1949.9572, Expected=1954.0000
# Month=24, Predicted=1953.9429, Expected=1946.6000
# Month=25, Predicted=1947.4283, Expected=1951.5000
# Month=26, Predicted=1951.0865, Expected=1947.6000
# Month=27, Predicted=1948.1865, Expected=1943.4000
# Month=28, Predicted=1943.7318, Expected=1942.3000
# Month=29, Predicted=1942.4131, Expected=1936.4000
# Month=30, Predicted=1936.9621, Expected=1942.7000
# Month=31, Predicted=1942.2501, Expected=1955.3000
# Month=32, Predicted=1954.5493, Expected=1962.3000
# Month=33, Predicted=1961.9251, Expected=1965.3000
# Month=34, Predicted=1965.3266, Expected=1958.1000
# Month=35, Predicted=1958.8887, Expected=1961.3000
# Month=36, Predicted=1961.0056, Expected=1963.5000
# Month=37, Predicted=1963.5734, Expected=1974.1000
# Month=38, Predicted=1973.5096, Expected=1968.1000
# Month=39, Predicted=1968.9349, Expected=1979.5000
# Month=40, Predicted=1978.7121, Expected=1991.2000
# Month=41, Predicted=1990.4246, Expected=1997.7000
# Month=42, Predicted=1997.3783, Expected=1996.1000
# Month=43, Predicted=1996.5121, Expected=2003.5000
# Month=44, Predicted=2003.0885, Expected=2001.1000
# Month=45, Predicted=2001.6011, Expected=2002.7000
# Month=46, Predicted=2002.6819, Expected=2004.1000
# Month=47, Predicted=2004.2054, Expected=2004.3000
# Month=48, Predicted=2004.4912, Expected=2016.4000
# Month=49, Predicted=2015.6875, Expected=2016.5000
# Month=50, Predicted=2016.7858, Expected=2021.1000
# Month=51, Predicted=2020.9246, Expected=2008.2000
# Month=52, Predicted=2009.4600, Expected=2002.9000
# Month=53, Predicted=2002.8574, Expected=2012.6000
# Month=54, Predicted=2011.9486, Expected=2013.8000
# Month=55, Predicted=2013.9994, Expected=2003.4000
# Month=56, Predicted=2004.3573, Expected=2015.6000
# Month=57, Predicted=2014.6333, Expected=2009.7000
# Month=58, Predicted=2010.5347, Expected=2022.1000
# Month=59, Predicted=2021.2525, Expected=2031.6000
# Month=60, Predicted=2030.9975, Expected=2029.7000
# Run 9 — RMSE: 7.876512, MSE: 62.039448, NMSE: 0.0013990053, sMAPE: 0.337413
#
# ===== RUN 10/2 =====
# Training complete for run 10
# Month=1, Predicted=1945.7317, Expected=1955.7000
# Month=2, Predicted=1955.3436, Expected=1949.5000
# Month=3, Predicted=1950.2973, Expected=1960.0000
# Month=4, Predicted=1959.3697, Expected=1962.8000
# Month=5, Predicted=1962.9388, Expected=1945.7000
# Month=6, Predicted=1946.8828, Expected=1948.1000
# Month=7, Predicted=1949.4222, Expected=1950.5000
# Month=8, Predicted=1950.6275, Expected=1946.6000
# Month=9, Predicted=1947.0879, Expected=1939.9000
# Month=10, Predicted=1940.2334, Expected=1953.2000
# Month=11, Predicted=1952.4460, Expected=1945.4000
# Month=12, Predicted=1946.3365, Expected=1949.8000
# Month=13, Predicted=1949.3606, Expected=1947.8000
# Month=14, Predicted=1948.2415, Expected=1957.4000
# Month=15, Predicted=1956.9808, Expected=1968.4000
# Month=16, Predicted=1967.9180, Expected=1974.9000
# Month=17, Predicted=1974.7238, Expected=1987.4000
# Month=18, Predicted=1986.8627, Expected=1972.2000
# Month=19, Predicted=1973.6349, Expected=1962.5000
# Month=20, Predicted=1963.1599, Expected=1953.8000
# Month=21, Predicted=1953.8329, Expected=1947.3000
# Month=22, Predicted=1947.3173, Expected=1950.2000
# Month=23, Predicted=1949.9453, Expected=1954.0000
# Month=24, Predicted=1954.0443, Expected=1946.6000
# Month=25, Predicted=1947.3356, Expected=1951.5000
# Month=26, Predicted=1951.0912, Expected=1947.6000
# Month=27, Predicted=1948.1713, Expected=1943.4000
# Month=28, Predicted=1943.6151, Expected=1942.3000
# Month=29, Predicted=1942.3572, Expected=1936.4000
# Month=30, Predicted=1936.8545, Expected=1942.7000
# Month=31, Predicted=1942.3060, Expected=1955.3000
# Month=32, Predicted=1954.7721, Expected=1962.3000
# Month=33, Predicted=1962.0448, Expected=1965.3000
# Month=34, Predicted=1965.4248, Expected=1958.1000
# Month=35, Predicted=1958.7920, Expected=1961.3000
# Month=36, Predicted=1960.9819, Expected=1963.5000
# Month=37, Predicted=1963.6514, Expected=1974.1000
# Month=38, Predicted=1973.7016, Expected=1968.1000
# Month=39, Predicted=1968.8903, Expected=1979.5000
# Month=40, Predicted=1978.8352, Expected=1991.2000
# Month=41, Predicted=1990.6102, Expected=1997.7000
# Month=42, Predicted=1997.5060, Expected=1996.1000
# Month=43, Predicted=1996.5371, Expected=2003.5000
# Month=44, Predicted=2003.2109, Expected=2001.1000
# Month=45, Predicted=2001.6146, Expected=2002.7000
# Month=46, Predicted=2002.6963, Expected=2004.1000
# Month=47, Predicted=2004.2569, Expected=2004.3000
# Month=48, Predicted=2004.5182, Expected=2016.4000
# Month=49, Predicted=2015.8923, Expected=2016.5000
# Month=50, Predicted=2016.8273, Expected=2021.1000
# Month=51, Predicted=2021.0098, Expected=2008.2000
# Month=52, Predicted=2009.2712, Expected=2002.9000
# Month=53, Predicted=2002.5220, Expected=2012.6000
# Month=54, Predicted=2012.0771, Expected=2013.8000
# Month=55, Predicted=2014.0678, Expected=2003.4000
# Month=56, Predicted=2004.1806, Expected=2015.6000
# Month=57, Predicted=2014.7106, Expected=2009.7000
# Month=58, Predicted=2010.4965, Expected=2022.1000
# Month=59, Predicted=2021.3880, Expected=2031.6000
# Month=60, Predicted=2031.1521, Expected=2029.7000
# Run 10 — RMSE: 7.886983, MSE: 62.204504, NMSE: 0.0014013388, sMAPE: 0.337662
#
# ===== RUN 11/2 =====
# Training complete for run 11
# Month=1, Predicted=1946.4194, Expected=1955.7000
# Month=2, Predicted=1955.3631, Expected=1949.5000
# Month=3, Predicted=1950.8554, Expected=1960.0000
# Month=4, Predicted=1959.4999, Expected=1962.8000
# Month=5, Predicted=1963.3929, Expected=1945.7000
# Month=6, Predicted=1947.0978, Expected=1948.1000
# Month=7, Predicted=1949.3368, Expected=1950.5000
# Month=8, Predicted=1950.5011, Expected=1946.6000
# Month=9, Predicted=1947.0555, Expected=1939.9000
# Month=10, Predicted=1940.2130, Expected=1953.2000
# Month=11, Predicted=1952.6203, Expected=1945.4000
# Month=12, Predicted=1947.2046, Expected=1949.8000
# Month=13, Predicted=1949.6438, Expected=1947.8000
# Month=14, Predicted=1948.2561, Expected=1957.4000
# Month=15, Predicted=1956.8542, Expected=1968.4000
# Month=16, Predicted=1968.2637, Expected=1974.9000
# Month=17, Predicted=1975.2510, Expected=1987.4000
# Month=18, Predicted=1986.9889, Expected=1972.2000
# Month=19, Predicted=1974.5991, Expected=1962.5000
# Month=20, Predicted=1963.5932, Expected=1953.8000
# Month=21, Predicted=1954.2989, Expected=1947.3000
# Month=22, Predicted=1947.6550, Expected=1950.2000
# Month=23, Predicted=1950.0496, Expected=1954.0000
# Month=24, Predicted=1953.9511, Expected=1946.6000
# Month=25, Predicted=1947.4109, Expected=1951.5000
# Month=26, Predicted=1951.3016, Expected=1947.6000
# Month=27, Predicted=1948.2354, Expected=1943.4000
# Month=28, Predicted=1943.5810, Expected=1942.3000
# Month=29, Predicted=1942.3082, Expected=1936.4000
# Month=30, Predicted=1936.7608, Expected=1942.7000
# Month=31, Predicted=1942.3720, Expected=1955.3000
# Month=32, Predicted=1954.8439, Expected=1962.3000
# Month=33, Predicted=1962.7248, Expected=1965.3000
# Month=34, Predicted=1965.6240, Expected=1958.1000
# Month=35, Predicted=1958.8358, Expected=1961.3000
# Month=36, Predicted=1961.1654, Expected=1963.5000
# Month=37, Predicted=1963.5769, Expected=1974.1000
# Month=38, Predicted=1973.5922, Expected=1968.1000
# Month=39, Predicted=1969.4729, Expected=1979.5000
# Month=40, Predicted=1978.9527, Expected=1991.2000
# Month=41, Predicted=1991.1183, Expected=1997.7000
# Month=42, Predicted=1998.1091, Expected=1996.1000
# Month=43, Predicted=1996.7361, Expected=2003.5000
# Month=44, Predicted=2003.0783, Expected=2001.1000
# Month=45, Predicted=2001.8531, Expected=2002.7000
# Month=46, Predicted=2002.5907, Expected=2004.1000
# Month=47, Predicted=2004.1442, Expected=2004.3000
# Month=48, Predicted=2004.4171, Expected=2016.4000
# Month=49, Predicted=2015.7456, Expected=2016.5000
# Month=50, Predicted=2017.4845, Expected=2021.1000
# Month=51, Predicted=2020.8909, Expected=2008.2000
# Month=52, Predicted=2009.4728, Expected=2002.9000
# Month=53, Predicted=2003.5615, Expected=2012.6000
# Month=54, Predicted=2012.0953, Expected=2013.8000
# Month=55, Predicted=2014.4601, Expected=2003.4000
# Month=56, Predicted=2004.2084, Expected=2015.6000
# Month=57, Predicted=2015.4008, Expected=2009.7000
# Month=58, Predicted=2011.2055, Expected=2022.1000
# Month=59, Predicted=2021.5068, Expected=2031.6000
# Month=60, Predicted=2031.7682, Expected=2029.7000
# Run 11 — RMSE: 7.844909, MSE: 61.542601, NMSE: 0.0013825054, sMAPE: 0.335058
#
# ===== RUN 12/2 =====
# Training complete for run 12
# Month=1, Predicted=1946.3184, Expected=1955.7000
# Month=2, Predicted=1955.4579, Expected=1949.5000
# Month=3, Predicted=1950.7314, Expected=1960.0000
# Month=4, Predicted=1959.4529, Expected=1962.8000
# Month=5, Predicted=1963.2955, Expected=1945.7000
# Month=6, Predicted=1947.1339, Expected=1948.1000
# Month=7, Predicted=1949.2132, Expected=1950.5000
# Month=8, Predicted=1950.6445, Expected=1946.6000
# Month=9, Predicted=1947.1773, Expected=1939.9000
# Month=10, Predicted=1940.2770, Expected=1953.2000
# Month=11, Predicted=1952.5248, Expected=1945.4000
# Month=12, Predicted=1946.9199, Expected=1949.8000
# Month=13, Predicted=1949.5465, Expected=1947.8000
# Month=14, Predicted=1948.3565, Expected=1957.4000
# Month=15, Predicted=1956.9831, Expected=1968.4000
# Month=16, Predicted=1968.2235, Expected=1974.9000
# Month=17, Predicted=1975.1291, Expected=1987.4000
# Month=18, Predicted=1987.0623, Expected=1972.2000
# Month=19, Predicted=1974.3079, Expected=1962.5000
# Month=20, Predicted=1963.7837, Expected=1953.8000
# Month=21, Predicted=1954.3449, Expected=1947.3000
# Month=22, Predicted=1947.6281, Expected=1950.2000
# Month=23, Predicted=1949.9935, Expected=1954.0000
# Month=24, Predicted=1954.0941, Expected=1946.6000
# Month=25, Predicted=1947.4951, Expected=1951.5000
# Month=26, Predicted=1951.1856, Expected=1947.6000
# Month=27, Predicted=1948.3171, Expected=1943.4000
# Month=28, Predicted=1943.6486, Expected=1942.3000
# Month=29, Predicted=1942.3693, Expected=1936.4000
# Month=30, Predicted=1936.8822, Expected=1942.7000
# Month=31, Predicted=1942.3486, Expected=1955.3000
# Month=32, Predicted=1954.9299, Expected=1962.3000
# Month=33, Predicted=1962.5204, Expected=1965.3000
# Month=34, Predicted=1965.6584, Expected=1958.1000
# Month=35, Predicted=1958.9311, Expected=1961.3000
# Month=36, Predicted=1961.0677, Expected=1963.5000
# Month=37, Predicted=1963.7119, Expected=1974.1000
# Month=38, Predicted=1973.7518, Expected=1968.1000
# Month=39, Predicted=1969.3343, Expected=1979.5000
# Month=40, Predicted=1978.9161, Expected=1991.2000
# Month=41, Predicted=1990.9902, Expected=1997.7000
# Month=42, Predicted=1997.9487, Expected=1996.1000
# Month=43, Predicted=1996.7706, Expected=2003.5000
# Month=44, Predicted=2003.2142, Expected=2001.1000
# Month=45, Predicted=2001.8657, Expected=2002.7000
# Month=46, Predicted=2002.7050, Expected=2004.1000
# Month=47, Predicted=2004.2920, Expected=2004.3000
# Month=48, Predicted=2004.5613, Expected=2016.4000
# Month=49, Predicted=2015.9071, Expected=2016.5000
# Month=50, Predicted=2017.2950, Expected=2021.1000
# Month=51, Predicted=2021.0397, Expected=2008.2000
# Month=52, Predicted=2009.5115, Expected=2002.9000
# Month=53, Predicted=2003.7150, Expected=2012.6000
# Month=54, Predicted=2012.0916, Expected=2013.8000
# Month=55, Predicted=2014.3952, Expected=2003.4000
# Month=56, Predicted=2004.3047, Expected=2015.6000
# Month=57, Predicted=2015.3930, Expected=2009.7000
# Month=58, Predicted=2010.9912, Expected=2022.1000
# Month=59, Predicted=2021.4746, Expected=2031.6000
# Month=60, Predicted=2031.5832, Expected=2029.7000
# Run 12 — RMSE: 7.853328, MSE: 61.674768, NMSE: 0.0013857595, sMAPE: 0.335664
#
# ===== RUN 13/2 =====
# Training complete for run 13
# Month=1, Predicted=1946.2999, Expected=1955.7000
# Month=2, Predicted=1955.3804, Expected=1949.5000
# Month=3, Predicted=1950.6141, Expected=1960.0000
# Month=4, Predicted=1959.3675, Expected=1962.8000
# Month=5, Predicted=1963.1250, Expected=1945.7000
# Month=6, Predicted=1947.4079, Expected=1948.1000
# Month=7, Predicted=1949.8320, Expected=1950.5000
# Month=8, Predicted=1950.7332, Expected=1946.6000
# Month=9, Predicted=1947.3105, Expected=1939.9000
# Month=10, Predicted=1940.5275, Expected=1953.2000
# Month=11, Predicted=1952.3955, Expected=1945.4000
# Month=12, Predicted=1946.7115, Expected=1949.8000
# Month=13, Predicted=1949.4810, Expected=1947.8000
# Month=14, Predicted=1948.4331, Expected=1957.4000
# Month=15, Predicted=1956.9696, Expected=1968.4000
# Month=16, Predicted=1968.0077, Expected=1974.9000
# Month=17, Predicted=1974.8834, Expected=1987.4000
# Month=18, Predicted=1986.8931, Expected=1972.2000
# Month=19, Predicted=1974.1426, Expected=1962.5000
# Month=20, Predicted=1963.2533, Expected=1953.8000
# Month=21, Predicted=1954.2305, Expected=1947.3000
# Month=22, Predicted=1947.6499, Expected=1950.2000
# Month=23, Predicted=1950.0539, Expected=1954.0000
# Month=24, Predicted=1954.1332, Expected=1946.6000
# Month=25, Predicted=1947.6324, Expected=1951.5000
# Month=26, Predicted=1951.1738, Expected=1947.6000
# Month=27, Predicted=1948.3999, Expected=1943.4000
# Month=28, Predicted=1943.8535, Expected=1942.3000
# Month=29, Predicted=1942.5301, Expected=1936.4000
# Month=30, Predicted=1937.1166, Expected=1942.7000
# Month=31, Predicted=1942.3520, Expected=1955.3000
# Month=32, Predicted=1954.7947, Expected=1962.3000
# Month=33, Predicted=1962.2260, Expected=1965.3000
# Month=34, Predicted=1965.5669, Expected=1958.1000
# Month=35, Predicted=1959.0833, Expected=1961.3000
# Month=36, Predicted=1961.0936, Expected=1963.5000
# Month=37, Predicted=1963.7663, Expected=1974.1000
# Month=38, Predicted=1973.7000, Expected=1968.1000
# Month=39, Predicted=1969.2060, Expected=1979.5000
# Month=40, Predicted=1978.8203, Expected=1991.2000
# Month=41, Predicted=1990.7267, Expected=1997.7000
# Month=42, Predicted=1997.6776, Expected=1996.1000
# Month=43, Predicted=1996.7428, Expected=2003.5000
# Month=44, Predicted=2003.2312, Expected=2001.1000
# Month=45, Predicted=2001.8376, Expected=2002.7000
# Month=46, Predicted=2002.8124, Expected=2004.1000
# Month=47, Predicted=2004.3792, Expected=2004.3000
# Month=48, Predicted=2004.6617, Expected=2016.4000
# Month=49, Predicted=2015.8590, Expected=2016.5000
# Month=50, Predicted=2017.0726, Expected=2021.1000
# Month=51, Predicted=2021.0821, Expected=2008.2000
# Month=52, Predicted=2009.6890, Expected=2002.9000
# Month=53, Predicted=2002.9082, Expected=2012.6000
# Month=54, Predicted=2012.0638, Expected=2013.8000
# Month=55, Predicted=2014.2630, Expected=2003.4000
# Month=56, Predicted=2004.5427, Expected=2015.6000
# Month=57, Predicted=2014.7124, Expected=2009.7000
# Month=58, Predicted=2010.8266, Expected=2022.1000
# Month=59, Predicted=2021.3639, Expected=2031.6000
# Month=60, Predicted=2031.3047, Expected=2029.7000
# Run 13 — RMSE: 7.844602, MSE: 61.537782, NMSE: 0.0013902183, sMAPE: 0.334793
#
# ===== RUN 14/2 =====
# Training complete for run 14
# Month=1, Predicted=1946.0954, Expected=1955.7000
# Month=2, Predicted=1955.5774, Expected=1949.5000
# Month=3, Predicted=1951.0357, Expected=1960.0000
# Month=4, Predicted=1959.7047, Expected=1962.8000
# Month=5, Predicted=1963.5307, Expected=1945.7000
# Month=6, Predicted=1947.2465, Expected=1948.1000
# Month=7, Predicted=1948.9441, Expected=1950.5000
# Month=8, Predicted=1950.6341, Expected=1946.6000
# Month=9, Predicted=1947.3025, Expected=1939.9000
# Month=10, Predicted=1940.2971, Expected=1953.2000
# Month=11, Predicted=1952.7331, Expected=1945.4000
# Month=12, Predicted=1947.1266, Expected=1949.8000
# Month=13, Predicted=1949.7460, Expected=1947.8000
# Month=14, Predicted=1948.4279, Expected=1957.4000
# Month=15, Predicted=1957.1729, Expected=1968.4000
# Month=16, Predicted=1968.5480, Expected=1974.9000
# Month=17, Predicted=1975.5684, Expected=1987.4000
# Month=18, Predicted=1987.4777, Expected=1972.2000
# Month=19, Predicted=1974.5989, Expected=1962.5000
# Month=20, Predicted=1963.2372, Expected=1953.8000
# Month=21, Predicted=1954.0862, Expected=1947.3000
# Month=22, Predicted=1947.5164, Expected=1950.2000
# Month=23, Predicted=1950.0684, Expected=1954.0000
# Month=24, Predicted=1954.2034, Expected=1946.6000
# Month=25, Predicted=1947.6249, Expected=1951.5000
# Month=26, Predicted=1951.3734, Expected=1947.6000
# Month=27, Predicted=1948.3904, Expected=1943.4000
# Month=28, Predicted=1943.7118, Expected=1942.3000
# Month=29, Predicted=1942.3944, Expected=1936.4000
# Month=30, Predicted=1936.8723, Expected=1942.7000
# Month=31, Predicted=1942.4871, Expected=1955.3000
# Month=32, Predicted=1955.1718, Expected=1962.3000
# Month=33, Predicted=1962.9489, Expected=1965.3000
# Month=34, Predicted=1966.0300, Expected=1958.1000
# Month=35, Predicted=1959.0817, Expected=1961.3000
# Month=36, Predicted=1961.2275, Expected=1963.5000
# Month=37, Predicted=1963.8034, Expected=1974.1000
# Month=38, Predicted=1973.9952, Expected=1968.1000
# Month=39, Predicted=1969.6043, Expected=1979.5000
# Month=40, Predicted=1979.1758, Expected=1991.2000
# Month=41, Predicted=1991.2980, Expected=1997.7000
# Month=42, Predicted=1998.4164, Expected=1996.1000
# Month=43, Predicted=1997.0875, Expected=2003.5000
# Month=44, Predicted=2003.4027, Expected=2001.1000
# Month=45, Predicted=2002.0590, Expected=2002.7000
# Month=46, Predicted=2002.8454, Expected=2004.1000
# Month=47, Predicted=2004.3937, Expected=2004.3000
# Month=48, Predicted=2004.6898, Expected=2016.4000
# Month=49, Predicted=2016.1122, Expected=2016.5000
# Month=50, Predicted=2017.6066, Expected=2021.1000
# Month=51, Predicted=2021.2775, Expected=2008.2000
# Month=52, Predicted=2009.5860, Expected=2002.9000
# Month=53, Predicted=2003.3212, Expected=2012.6000
# Month=54, Predicted=2012.1784, Expected=2013.8000
# Month=55, Predicted=2014.6237, Expected=2003.4000
# Month=56, Predicted=2004.4222, Expected=2015.6000
# Month=57, Predicted=2015.3624, Expected=2009.7000
# Month=58, Predicted=2011.1533, Expected=2022.1000
# Month=59, Predicted=2021.7525, Expected=2031.6000
# Month=60, Predicted=2031.8881, Expected=2029.7000
# Run 14 — RMSE: 7.832415, MSE: 61.346720, NMSE: 0.0013742737, sMAPE: 0.334224
#
# ===== RUN 15/2 =====
# Training complete for run 15
# Month=1, Predicted=1947.3719, Expected=1955.7000
# Month=2, Predicted=1957.0705, Expected=1949.5000
# Month=3, Predicted=1950.8705, Expected=1960.0000
# Month=4, Predicted=1961.3705, Expected=1962.8000
# Month=5, Predicted=1964.1705, Expected=1945.7000
# Month=6, Predicted=1947.0705, Expected=1948.1000
# Month=7, Predicted=1950.6489, Expected=1950.5000
# Month=8, Predicted=1951.8705, Expected=1946.6000
# Month=9, Predicted=1947.9705, Expected=1939.9000
# Month=10, Predicted=1941.2705, Expected=1953.2000
# Month=11, Predicted=1954.5705, Expected=1945.4000
# Month=12, Predicted=1946.7705, Expected=1949.8000
# Month=13, Predicted=1951.1705, Expected=1947.8000
# Month=14, Predicted=1949.1705, Expected=1957.4000
# Month=15, Predicted=1958.7705, Expected=1968.4000
# Month=16, Predicted=1969.7705, Expected=1974.9000
# Month=17, Predicted=1976.2705, Expected=1987.4000
# Month=18, Predicted=1988.7705, Expected=1972.2000
# Month=19, Predicted=1973.5705, Expected=1962.5000
# Month=20, Predicted=1963.9233, Expected=1953.8000
# Month=21, Predicted=1955.1705, Expected=1947.3000
# Month=22, Predicted=1948.6705, Expected=1950.2000
# Month=23, Predicted=1951.5705, Expected=1954.0000
# Month=24, Predicted=1955.3705, Expected=1946.6000
# Month=25, Predicted=1947.9705, Expected=1951.5000
# Month=26, Predicted=1952.8705, Expected=1947.6000
# Month=27, Predicted=1948.9705, Expected=1943.4000
# Month=28, Predicted=1944.7705, Expected=1942.3000
# Month=29, Predicted=1943.6705, Expected=1936.4000
# Month=30, Predicted=1937.7705, Expected=1942.7000
# Month=31, Predicted=1944.0705, Expected=1955.3000
# Month=32, Predicted=1956.6705, Expected=1962.3000
# Month=33, Predicted=1963.6705, Expected=1965.3000
# Month=34, Predicted=1966.6705, Expected=1958.1000
# Month=35, Predicted=1959.4705, Expected=1961.3000
# Month=36, Predicted=1962.6705, Expected=1963.5000
# Month=37, Predicted=1964.8705, Expected=1974.1000
# Month=38, Predicted=1975.4705, Expected=1968.1000
# Month=39, Predicted=1969.4705, Expected=1979.5000
# Month=40, Predicted=1980.8705, Expected=1991.2000
# Month=41, Predicted=1992.5705, Expected=1997.7000
# Month=42, Predicted=1999.0705, Expected=1996.1000
# Month=43, Predicted=1997.4705, Expected=2003.5000
# Month=44, Predicted=2004.8705, Expected=2001.1000
# Month=45, Predicted=2002.4705, Expected=2002.7000
# Month=46, Predicted=2004.0705, Expected=2004.1000
# Month=47, Predicted=2005.4705, Expected=2004.3000
# Month=48, Predicted=2005.6705, Expected=2016.4000
# Month=49, Predicted=2017.7705, Expected=2016.5000
# Month=50, Predicted=2017.8705, Expected=2021.1000
# Month=51, Predicted=2022.4705, Expected=2008.2000
# Month=52, Predicted=2009.5705, Expected=2002.9000
# Month=53, Predicted=2004.2705, Expected=2012.6000
# Month=54, Predicted=2013.9705, Expected=2013.8000
# Month=55, Predicted=2015.1705, Expected=2003.4000
# Month=56, Predicted=2004.7705, Expected=2015.6000
# Month=57, Predicted=2016.9705, Expected=2009.7000
# Month=58, Predicted=2011.0705, Expected=2022.1000
# Month=59, Predicted=2023.4705, Expected=2031.6000
# Month=60, Predicted=2032.9705, Expected=2029.7000
# Run 15 — RMSE: 7.777907, MSE: 60.495834, NMSE: 0.0013573861, sMAPE: 0.330422
#
# ===== RUN 16/2 =====
# Training complete for run 16
# Month=1, Predicted=1945.8009, Expected=1955.7000
# Month=2, Predicted=1955.9308, Expected=1949.5000
# Month=3, Predicted=1950.7441, Expected=1960.0000
# Month=4, Predicted=1959.8286, Expected=1962.8000
# Month=5, Predicted=1963.6059, Expected=1945.7000
# Month=6, Predicted=1946.9157, Expected=1948.1000
# Month=7, Predicted=1948.6197, Expected=1950.5000
# Month=8, Predicted=1950.9093, Expected=1946.6000
# Month=9, Predicted=1947.2741, Expected=1939.9000
# Month=10, Predicted=1940.3906, Expected=1953.2000
# Month=11, Predicted=1952.9354, Expected=1945.4000
# Month=12, Predicted=1946.9098, Expected=1949.8000
# Month=13, Predicted=1949.8235, Expected=1947.8000
# Month=14, Predicted=1948.5051, Expected=1957.4000
# Month=15, Predicted=1957.3458, Expected=1968.4000
# Month=16, Predicted=1968.7518, Expected=1974.9000
# Month=17, Predicted=1975.5373, Expected=1987.4000
# Month=18, Predicted=1987.5614, Expected=1972.2000
# Month=19, Predicted=1974.0282, Expected=1962.5000
# Month=20, Predicted=1963.2495, Expected=1953.8000
# Month=21, Predicted=1954.2863, Expected=1947.3000
# Month=22, Predicted=1947.7063, Expected=1950.2000
# Month=23, Predicted=1950.2885, Expected=1954.0000
# Month=24, Predicted=1954.3758, Expected=1946.6000
# ...
# Month=55, Predicted=2014.2305, Expected=2003.4000
# Month=56, Predicted=2004.5441, Expected=2015.6000
# Month=57, Predicted=2015.6603, Expected=2009.7000
# Month=58, Predicted=2010.8662, Expected=2022.1000
# Month=59, Predicted=2021.8774, Expected=2031.6000
# Month=60, Predicted=2031.3273, Expected=2029.7000
# Run 25 — RMSE: 7.822021, MSE: 61.184007, NMSE: 0.0013811322, sMAPE: 0.334603
#
# ===== RUN 26/2 =====
# Training complete for run 26
# Month=1, Predicted=1946.9811, Expected=1955.7000
# Month=2, Predicted=1956.2151, Expected=1949.5000
# Month=3, Predicted=1950.4768, Expected=1960.0000
# Month=4, Predicted=1961.0022, Expected=1962.8000
# Month=5, Predicted=1963.4037, Expected=1945.7000
# Month=6, Predicted=1947.3409, Expected=1948.1000
# Month=7, Predicted=1949.7311, Expected=1950.5000
# Month=8, Predicted=1951.4207, Expected=1946.6000
# Month=9, Predicted=1947.7668, Expected=1939.9000
# Month=10, Predicted=1941.3824, Expected=1953.2000
# Month=11, Predicted=1954.1318, Expected=1945.4000
# Month=12, Predicted=1946.3242, Expected=1949.8000
# Month=13, Predicted=1951.0521, Expected=1947.8000
# Month=14, Predicted=1948.8163, Expected=1957.4000
# Month=15, Predicted=1958.2638, Expected=1968.4000
# Month=16, Predicted=1968.7382, Expected=1974.9000
# Month=17, Predicted=1975.3492, Expected=1987.4000
# Month=18, Predicted=1987.8269, Expected=1972.2000
# Month=19, Predicted=1973.4575, Expected=1962.5000
# Month=20, Predicted=1964.4548, Expected=1953.8000
# Month=21, Predicted=1955.5231, Expected=1947.3000
# Month=22, Predicted=1948.9255, Expected=1950.2000
# Month=23, Predicted=1951.4372, Expected=1954.0000
# Month=24, Predicted=1954.8627, Expected=1946.6000
# Month=25, Predicted=1947.8466, Expected=1951.5000
# Month=26, Predicted=1952.7147, Expected=1947.6000
# Month=27, Predicted=1948.6700, Expected=1943.4000
# Month=28, Predicted=1944.7976, Expected=1942.3000
# Month=29, Predicted=1943.5941, Expected=1936.4000
# Month=30, Predicted=1937.7554, Expected=1942.7000
# Month=31, Predicted=1943.8117, Expected=1955.3000
# Month=32, Predicted=1955.7232, Expected=1962.3000
# Month=33, Predicted=1962.6620, Expected=1965.3000
# Month=34, Predicted=1966.0430, Expected=1958.1000
# Month=35, Predicted=1959.3682, Expected=1961.3000
# Month=36, Predicted=1962.5616, Expected=1963.5000
# Month=37, Predicted=1964.4074, Expected=1974.1000
# Month=38, Predicted=1974.7646, Expected=1968.1000
# Month=39, Predicted=1969.0523, Expected=1979.5000
# Month=40, Predicted=1980.4688, Expected=1991.2000
# Month=41, Predicted=1991.4319, Expected=1997.7000
# Month=42, Predicted=1998.1204, Expected=1996.1000
# Month=43, Predicted=1997.0350, Expected=2003.5000
# Month=44, Predicted=2004.4194, Expected=2001.1000
# Month=45, Predicted=2002.0264, Expected=2002.7000
# Month=46, Predicted=2003.8454, Expected=2004.1000
# Month=47, Predicted=2005.0993, Expected=2004.3000
# Month=48, Predicted=2005.3528, Expected=2016.4000
# Month=49, Predicted=2017.0970, Expected=2016.5000
# Month=50, Predicted=2017.1518, Expected=2021.1000
# Month=51, Predicted=2022.0518, Expected=2008.2000
# Month=52, Predicted=2009.6228, Expected=2002.9000
# Month=53, Predicted=2004.6348, Expected=2012.6000
# Month=54, Predicted=2013.5716, Expected=2013.8000
# Month=55, Predicted=2014.4993, Expected=2003.4000
# Month=56, Predicted=2004.8479, Expected=2015.6000
# Month=57, Predicted=2016.7072, Expected=2009.7000
# Month=58, Predicted=2010.5831, Expected=2022.1000
# Month=59, Predicted=2023.0381, Expected=2031.6000
# Month=60, Predicted=2031.8683, Expected=2029.7000
# Run 26 — RMSE: 7.779821, MSE: 60.525608, NMSE: 0.0013675618, sMAPE: 0.332160
#
# ===== RUN 27/2 =====
# Training complete for run 27
# Month=1, Predicted=1946.8990, Expected=1955.7000
# Month=2, Predicted=1957.0990, Expected=1949.5000
# Month=3, Predicted=1950.8990, Expected=1960.0000
# Month=4, Predicted=1961.3990, Expected=1962.8000
# Month=5, Predicted=1964.1990, Expected=1945.7000
# Month=6, Predicted=1947.0990, Expected=1948.1000
# Month=7, Predicted=1949.4990, Expected=1950.5000
# Month=8, Predicted=1951.8990, Expected=1946.6000
# Month=9, Predicted=1947.9990, Expected=1939.9000
# Month=10, Predicted=1941.2990, Expected=1953.2000
# Month=11, Predicted=1954.5990, Expected=1945.4000
# Month=12, Predicted=1946.7990, Expected=1949.8000
# Month=13, Predicted=1951.1990, Expected=1947.8000
# Month=14, Predicted=1949.1990, Expected=1957.4000
# Month=15, Predicted=1958.7990, Expected=1968.4000
# Month=16, Predicted=1969.7990, Expected=1974.9000
# Month=17, Predicted=1976.2990, Expected=1987.4000
# Month=18, Predicted=1988.7990, Expected=1972.2000
# Month=19, Predicted=1973.5990, Expected=1962.5000
# Month=20, Predicted=1963.8990, Expected=1953.8000
# Month=21, Predicted=1955.1990, Expected=1947.3000
# Month=22, Predicted=1948.6990, Expected=1950.2000
# Month=23, Predicted=1951.5990, Expected=1954.0000
# Month=24, Predicted=1955.3990, Expected=1946.6000
# Month=25, Predicted=1947.9990, Expected=1951.5000
# Month=26, Predicted=1952.8990, Expected=1947.6000
# Month=27, Predicted=1948.9990, Expected=1943.4000
# Month=28, Predicted=1944.7990, Expected=1942.3000
# Month=29, Predicted=1943.6990, Expected=1936.4000
# Month=30, Predicted=1937.7990, Expected=1942.7000
# Month=31, Predicted=1944.0990, Expected=1955.3000
# Month=32, Predicted=1956.6990, Expected=1962.3000
# Month=33, Predicted=1963.6990, Expected=1965.3000
# Month=34, Predicted=1966.6990, Expected=1958.1000
# Month=35, Predicted=1959.4990, Expected=1961.3000
# Month=36, Predicted=1962.6990, Expected=1963.5000
# Month=37, Predicted=1964.8990, Expected=1974.1000
# Month=38, Predicted=1975.4990, Expected=1968.1000
# Month=39, Predicted=1969.4990, Expected=1979.5000
# Month=40, Predicted=1980.8990, Expected=1991.2000
# Month=41, Predicted=1992.5990, Expected=1997.7000
# Month=42, Predicted=1999.0990, Expected=1996.1000
# Month=43, Predicted=1997.4990, Expected=2003.5000
# Month=44, Predicted=2004.8990, Expected=2001.1000
# Month=45, Predicted=2002.4990, Expected=2002.7000
# Month=46, Predicted=2004.0990, Expected=2004.1000
# Month=47, Predicted=2005.4990, Expected=2004.3000
# Month=48, Predicted=2005.6990, Expected=2016.4000
# Month=49, Predicted=2017.7990, Expected=2016.5000
# Month=50, Predicted=2017.8990, Expected=2021.1000
# Month=51, Predicted=2022.4990, Expected=2008.2000
# Month=52, Predicted=2009.5990, Expected=2002.9000
# Month=53, Predicted=2004.2990, Expected=2012.6000
# Month=54, Predicted=2013.9990, Expected=2013.8000
# Month=55, Predicted=2015.1990, Expected=2003.4000
# Month=56, Predicted=2004.7990, Expected=2015.6000
# Month=57, Predicted=2016.9990, Expected=2009.7000
# Month=58, Predicted=2011.0990, Expected=2022.1000
# Month=59, Predicted=2023.4990, Expected=2031.6000
# Month=60, Predicted=2032.9990, Expected=2029.7000
# Run 27 — RMSE: 7.787020, MSE: 60.637674, NMSE: 0.0013579179, sMAPE: 0.331412
#
# ===== RUN 28/2 =====
# Training complete for run 28
# Month=1, Predicted=1946.8989, Expected=1955.7000
# Month=2, Predicted=1957.0989, Expected=1949.5000
# Month=3, Predicted=1950.8989, Expected=1960.0000
# Month=4, Predicted=1961.3989, Expected=1962.8000
# Month=5, Predicted=1964.1989, Expected=1945.7000
# Month=6, Predicted=1947.0989, Expected=1948.1000
# Month=7, Predicted=1949.4989, Expected=1950.5000
# Month=8, Predicted=1951.8989, Expected=1946.6000
# Month=9, Predicted=1947.9989, Expected=1939.9000
# Month=10, Predicted=1941.2989, Expected=1953.2000
# Month=11, Predicted=1954.5989, Expected=1945.4000
# Month=12, Predicted=1946.7989, Expected=1949.8000
# Month=13, Predicted=1951.1989, Expected=1947.8000
# Month=14, Predicted=1949.1989, Expected=1957.4000
# Month=15, Predicted=1958.7989, Expected=1968.4000
# Month=16, Predicted=1969.7989, Expected=1974.9000
# Month=17, Predicted=1976.2989, Expected=1987.4000
# Month=18, Predicted=1988.7989, Expected=1972.2000
# Month=19, Predicted=1973.5989, Expected=1962.5000
# Month=20, Predicted=1963.8989, Expected=1953.8000
# Month=21, Predicted=1955.1989, Expected=1947.3000
# Month=22, Predicted=1948.6989, Expected=1950.2000
# Month=23, Predicted=1951.5989, Expected=1954.0000
# Month=24, Predicted=1955.3989, Expected=1946.6000
# Month=25, Predicted=1947.9989, Expected=1951.5000
# Month=26, Predicted=1952.8989, Expected=1947.6000
# Month=27, Predicted=1948.9989, Expected=1943.4000
# Month=28, Predicted=1944.7989, Expected=1942.3000
# Month=29, Predicted=1943.6989, Expected=1936.4000
# Month=30, Predicted=1937.7989, Expected=1942.7000
# Month=31, Predicted=1944.0989, Expected=1955.3000
# Month=32, Predicted=1956.6989, Expected=1962.3000
# Month=33, Predicted=1963.6989, Expected=1965.3000
# Month=34, Predicted=1966.6989, Expected=1958.1000
# Month=35, Predicted=1959.4989, Expected=1961.3000
# Month=36, Predicted=1962.6989, Expected=1963.5000
# Month=37, Predicted=1964.8989, Expected=1974.1000
# Month=38, Predicted=1975.4989, Expected=1968.1000
# Month=39, Predicted=1969.4989, Expected=1979.5000
# Month=40, Predicted=1980.8989, Expected=1991.2000
# Month=41, Predicted=1992.5989, Expected=1997.7000
# Month=42, Predicted=1999.0989, Expected=1996.1000
# Month=43, Predicted=1997.4989, Expected=2003.5000
# Month=44, Predicted=2004.8989, Expected=2001.1000
# Month=45, Predicted=2002.4989, Expected=2002.7000
# Month=46, Predicted=2004.0989, Expected=2004.1000
# Month=47, Predicted=2005.4989, Expected=2004.3000
# Month=48, Predicted=2005.6989, Expected=2016.4000
# Month=49, Predicted=2017.7989, Expected=2016.5000
# Month=50, Predicted=2017.8989, Expected=2021.1000
# Month=51, Predicted=2022.4989, Expected=2008.2000
# Month=52, Predicted=2009.5989, Expected=2002.9000
# Month=53, Predicted=2004.2989, Expected=2012.6000
# Month=54, Predicted=2013.9989, Expected=2013.8000
# Month=55, Predicted=2015.1989, Expected=2003.4000
# Month=56, Predicted=2004.7989, Expected=2015.6000
# Month=57, Predicted=2016.9989, Expected=2009.7000
# Month=58, Predicted=2011.0989, Expected=2022.1000
# Month=59, Predicted=2023.4989, Expected=2031.6000
# Month=60, Predicted=2032.9989, Expected=2029.7000
# Run 28 — RMSE: 7.787020, MSE: 60.637675, NMSE: 0.0013579179, sMAPE: 0.331413
#
# ===== RUN 29/2 =====
# Training complete for run 29
# Month=1, Predicted=1945.7520, Expected=1955.7000
# Month=2, Predicted=1955.8416, Expected=1949.5000
# Month=3, Predicted=1950.5221, Expected=1960.0000
# Month=4, Predicted=1959.9944, Expected=1962.8000
# Month=5, Predicted=1963.3879, Expected=1945.7000
# Month=6, Predicted=1946.8700, Expected=1948.1000
# Month=7, Predicted=1948.4937, Expected=1950.5000
# Month=8, Predicted=1950.8991, Expected=1946.6000
# Month=9, Predicted=1947.2634, Expected=1939.9000
# Month=10, Predicted=1940.5080, Expected=1953.2000
# Month=11, Predicted=1953.1046, Expected=1945.4000
# Month=12, Predicted=1946.6014, Expected=1949.8000
# Month=13, Predicted=1949.9901, Expected=1947.8000
# Month=14, Predicted=1948.4394, Expected=1957.4000
# Month=15, Predicted=1957.4573, Expected=1968.4000
# Month=16, Predicted=1968.5724, Expected=1974.9000
# Month=17, Predicted=1975.3206, Expected=1987.4000
# Month=18, Predicted=1987.4703, Expected=1972.2000
# Month=19, Predicted=1973.7285, Expected=1962.5000
# Month=20, Predicted=1963.2048, Expected=1953.8000
# Month=21, Predicted=1954.4090, Expected=1947.3000
# Month=22, Predicted=1947.8424, Expected=1950.2000
# Month=23, Predicted=1950.4418, Expected=1954.0000
# Month=24, Predicted=1954.3612, Expected=1946.6000
# Month=25, Predicted=1947.4455, Expected=1951.5000
# Month=26, Predicted=1951.6744, Expected=1947.6000
# Month=27, Predicted=1948.3339, Expected=1943.4000
# Month=28, Predicted=1943.9227, Expected=1942.3000
# Month=29, Predicted=1942.7067, Expected=1936.4000
# Month=30, Predicted=1937.0393, Expected=1942.7000
# Month=31, Predicted=1942.8328, Expected=1955.3000
# Month=32, Predicted=1955.3554, Expected=1962.3000
# Month=33, Predicted=1962.7191, Expected=1965.3000
# Month=34, Predicted=1965.8030, Expected=1958.1000
# Month=35, Predicted=1958.9125, Expected=1961.3000
# Month=36, Predicted=1961.5319, Expected=1963.5000
# Month=37, Predicted=1963.9336, Expected=1974.1000
# Month=38, Predicted=1974.1800, Expected=1968.1000
# Month=39, Predicted=1969.1249, Expected=1979.5000
# Month=40, Predicted=1979.4663, Expected=1991.2000
# Month=41, Predicted=1991.3549, Expected=1997.7000
# Month=42, Predicted=1998.1331, Expected=1996.1000
# Month=43, Predicted=1996.7947, Expected=2003.5000
# Month=44, Predicted=2003.6426, Expected=2001.1000
# Month=45, Predicted=2001.8519, Expected=2002.7000
# Month=46, Predicted=2003.0429, Expected=2004.1000
# Month=47, Predicted=2004.5304, Expected=2004.3000
# Month=48, Predicted=2004.7749, Expected=2016.4000
# Month=49, Predicted=2016.3949, Expected=2016.5000
# Month=50, Predicted=2017.2685, Expected=2021.1000
# Month=51, Predicted=2021.3777, Expected=2008.2000
# Month=52, Predicted=2009.2858, Expected=2002.9000
# Month=53, Predicted=2003.4289, Expected=2012.6000
# Month=54, Predicted=2012.6173, Expected=2013.8000
# Month=55, Predicted=2014.4475, Expected=2003.4000
# Month=56, Predicted=2004.2735, Expected=2015.6000
# Month=57, Predicted=2015.5567, Expected=2009.7000
# Month=58, Predicted=2010.7652, Expected=2022.1000
# Month=59, Predicted=2022.0352, Expected=2031.6000
# Month=60, Predicted=2031.8770, Expected=2029.7000
# Run 29 — RMSE: 7.831213, MSE: 61.327904, NMSE: 0.0013758864, sMAPE: 0.335653
#
# ===== RUN 30/2 =====
# Training complete for run 30
# Month=1, Predicted=1945.6000, Expected=1955.7000
# Month=2, Predicted=1956.2899, Expected=1949.5000
# Month=3, Predicted=1950.7051, Expected=1960.0000
# Month=4, Predicted=1960.2332, Expected=1962.8000
# Month=5, Predicted=1963.7312, Expected=1945.7000
# Month=6, Predicted=1946.8386, Expected=1948.1000
# Month=7, Predicted=1948.2496, Expected=1950.5000
# Month=8, Predicted=1951.1889, Expected=1946.6000
# Month=9, Predicted=1947.4421, Expected=1939.9000
# Month=10, Predicted=1940.5421, Expected=1953.2000
# Month=11, Predicted=1953.3665, Expected=1945.4000
# Month=12, Predicted=1946.7578, Expected=1949.8000
# Month=13, Predicted=1950.0994, Expected=1947.8000
# Month=14, Predicted=1948.6729, Expected=1957.4000
# Month=15, Predicted=1957.7798, Expected=1968.4000
# Month=16, Predicted=1969.0460, Expected=1974.9000
# Month=17, Predicted=1975.7211, Expected=1987.4000
# Month=18, Predicted=1987.9465, Expected=1972.2000
# Month=19, Predicted=1973.7527, Expected=1962.5000
# Month=20, Predicted=1962.8754, Expected=1953.8000
# Month=21, Predicted=1954.2709, Expected=1947.3000
# Month=22, Predicted=1947.7646, Expected=1950.2000
# Month=23, Predicted=1950.5645, Expected=1954.0000
# Month=24, Predicted=1954.6736, Expected=1946.6000
# Month=25, Predicted=1947.5806, Expected=1951.5000
# Month=26, Predicted=1951.8009, Expected=1947.6000
# Month=27, Predicted=1948.5397, Expected=1943.4000
# Month=28, Predicted=1943.9956, Expected=1942.3000
# Month=29, Predicted=1942.8223, Expected=1936.4000
# Month=30, Predicted=1937.1388, Expected=1942.7000
# Month=31, Predicted=1943.0200, Expected=1955.3000
# Month=32, Predicted=1955.8364, Expected=1962.3000
# Month=33, Predicted=1963.1293, Expected=1965.3000
# Month=34, Predicted=1966.1321, Expected=1958.1000
# Month=35, Predicted=1959.0428, Expected=1961.3000
# Month=36, Predicted=1961.6388, Expected=1963.5000
# Month=37, Predicted=1964.2238, Expected=1974.1000
# Month=38, Predicted=1974.5857, Expected=1968.1000
# Month=39, Predicted=1969.3124, Expected=1979.5000
# Month=40, Predicted=1979.7226, Expected=1991.2000
# Month=41, Predicted=1991.8468, Expected=1997.7000
# Month=42, Predicted=1998.5339, Expected=1996.1000
# Month=43, Predicted=1997.0442, Expected=2003.5000
# Month=44, Predicted=2003.9401, Expected=2001.1000
# Month=45, Predicted=2002.0952, Expected=2002.7000
# Month=46, Predicted=2003.2363, Expected=2004.1000
# Month=47, Predicted=2004.7865, Expected=2004.3000
# Month=48, Predicted=2005.0081, Expected=2016.4000
# Month=49, Predicted=2016.7927, Expected=2016.5000
# Month=50, Predicted=2017.5619, Expected=2021.1000
# Month=51, Predicted=2021.6614, Expected=2008.2000
# Month=52, Predicted=2009.3380, Expected=2002.9000
# Month=53, Predicted=2003.2379, Expected=2012.6000
# Month=54, Predicted=2012.8709, Expected=2013.8000
# Month=55, Predicted=2014.7616, Expected=2003.4000
# Month=56, Predicted=2004.3320, Expected=2015.6000
# Month=57, Predicted=2015.6906, Expected=2009.7000
# Month=58, Predicted=2010.9608, Expected=2022.1000
# Month=59, Predicted=2022.3077, Expected=2031.6000
# Month=60, Predicted=2032.3346, Expected=2029.7000
# Run 30 — RMSE: 7.822189, MSE: 61.186643, NMSE: 0.0013678497, sMAPE: 0.335116

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on M4 Daily (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on M4 Daily (30 runs) =====
# RMSE: 7.834780 ± 0.058150
# MSE:  61.387161 ± 0.915632
# NMSE: 0.0013785890 ± 0.0000224076
# sMAPE: 0.334542 ± 0.003486
#
# Best run: 15
#   RMSE: 7.777907
#   MSE:  60.495834
#   NMSE: 0.0013573861
#   sMAPE: 0.330422

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Hybrid (Feature Aug + Gate) — M4 Daily\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Hybrid (Feature Aug + Gate) — M4 Daily\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 7.777907
# MSE:  60.495834
# NMSE: 0.0013573861
# sMAPE: 0.330422

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on M4 Daily
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
# Out:
# Total notebook execution time: 1h 2m 46.30s
# Total seconds: 3766.30
