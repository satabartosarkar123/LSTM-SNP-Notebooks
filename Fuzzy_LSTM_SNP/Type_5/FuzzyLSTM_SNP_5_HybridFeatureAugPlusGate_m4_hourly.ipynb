# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: M4 Hourly
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")
# Out:
# Process ID (PID): 4879

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Notebook execution started at: 2026-04-25 09:22:21

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)
# Out:
# Forcing CPU execution (disabled GPU visibility).

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn_1 (RNN)                 (1, 8)                    496
#
#  dense_1 (Dense)             (1, 1)                    9
#
# =================================================================
# Total params: 505 (1.97 KB)
# Trainable params: 505 (1.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — M4 Hourly

# %%
# ============================================================
# 1. Load Time Series Data
series_df = pd.read_csv(
    '../../content/archive/Hourly-train.csv',
    nrows=1
)

# Extract the first series (dropping the 'V1' ID column and any NaNs)
raw_values = series_df.iloc[0, 1:].dropna().values.astype(float)
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (700,)
# First 5 values: [605. 586. 586. 559. 511.]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (699, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (639, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (639, 1, 2), y_train shape: (639,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/2 =====
# Training complete for run 1
# Month=1, Predicted=672.8412, Expected=696.0000
# Month=2, Predicted=776.9867, Expected=765.0000
# Month=3, Predicted=817.8117, Expected=813.0000
# Month=4, Predicted=839.9891, Expected=851.0000
# Month=5, Predicted=875.0613, Expected=872.0000
# Month=6, Predicted=885.7362, Expected=883.0000
# Month=7, Predicted=896.6597, Expected=899.0000
# Month=8, Predicted=921.2791, Expected=897.0000
# Month=9, Predicted=897.6848, Expected=871.0000
# Month=10, Predicted=835.7436, Expected=831.0000
# Month=11, Predicted=791.1696, Expected=813.0000
# Month=12, Predicted=783.7262, Expected=749.0000
# Month=13, Predicted=675.3959, Expected=664.0000
# Month=14, Predicted=596.8342, Expected=550.0000
# Month=15, Predicted=506.2128, Expected=544.0000
# Month=16, Predicted=513.1130, Expected=505.0000
# Month=17, Predicted=508.1827, Expected=483.0000
# Month=18, Predicted=446.7731, Expected=469.0000
# Month=19, Predicted=466.1558, Expected=466.0000
# Month=20, Predicted=469.4154, Expected=487.0000
# Month=21, Predicted=509.1399, Expected=492.0000
# Month=22, Predicted=499.7627, Expected=531.0000
# Month=23, Predicted=570.2993, Expected=583.0000
# Month=24, Predicted=639.0257, Expected=659.0000
# Month=25, Predicted=735.7732, Expected=743.0000
# Month=26, Predicted=817.6071, Expected=811.0000
# Month=27, Predicted=861.3056, Expected=863.0000
# Month=28, Predicted=895.5135, Expected=898.0000
# Month=29, Predicted=916.8524, Expected=914.0000
# Month=30, Predicted=922.4596, Expected=920.0000
# Month=31, Predicted=930.0956, Expected=926.0000
# Month=32, Predicted=939.7273, Expected=919.0000
# Month=33, Predicted=916.4746, Expected=887.0000
# Month=34, Predicted=843.9388, Expected=862.0000
# Month=35, Predicted=830.6036, Expected=829.0000
# Month=36, Predicted=802.2647, Expected=769.0000
# Month=37, Predicted=722.3886, Expected=691.0000
# Month=38, Predicted=631.7970, Expected=618.0000
# Month=39, Predicted=570.6982, Expected=563.0000
# Month=40, Predicted=528.3167, Expected=529.0000
# Month=41, Predicted=502.0174, Expected=504.0000
# Month=42, Predicted=484.5571, Expected=489.0000
# Month=43, Predicted=479.9051, Expected=487.0000
# Month=44, Predicted=492.2797, Expected=508.0000
# Month=45, Predicted=531.3143, Expected=513.0000
# Month=46, Predicted=520.7205, Expected=555.0000
# Month=47, Predicted=597.2006, Expected=606.0000
# Month=48, Predicted=658.5287, Expected=676.0000
# Month=49, Predicted=745.5562, Expected=761.0000
# Month=50, Predicted=839.4264, Expected=837.0000
# Month=51, Predicted=897.1760, Expected=878.0000
# Month=52, Predicted=896.3815, Expected=890.0000
# Month=53, Predicted=880.0473, Expected=879.0000
# Month=54, Predicted=865.3836, Expected=847.0000
# Month=55, Predicted=805.1899, Expected=820.0000
# Month=56, Predicted=788.1585, Expected=790.0000
# Month=57, Predicted=765.9913, Expected=784.0000
# Month=58, Predicted=768.2425, Expected=752.0000
# Month=59, Predicted=714.1243, Expected=739.0000
# Month=60, Predicted=713.9566, Expected=684.0000
# Run 1 — RMSE: 18.518334, MSE: 342.928684, NMSE: 0.0002284729, sMAPE: 2.223021
#
# ===== RUN 2/2 =====
# Training complete for run 2
# Month=1, Predicted=671.5854, Expected=696.0000
# Month=2, Predicted=772.4640, Expected=765.0000
# Month=3, Predicted=819.0152, Expected=813.0000
# Month=4, Predicted=846.6869, Expected=851.0000
# Month=5, Predicted=880.4846, Expected=872.0000
# Month=6, Predicted=885.1098, Expected=883.0000
# Month=7, Predicted=898.2013, Expected=899.0000
# Month=8, Predicted=923.8352, Expected=897.0000
# Month=9, Predicted=899.0596, Expected=871.0000
# Month=10, Predicted=841.0226, Expected=831.0000
# Month=11, Predicted=785.1132, Expected=813.0000
# Month=12, Predicted=790.5466, Expected=749.0000
# Month=13, Predicted=685.5560, Expected=664.0000
# Month=14, Predicted=598.5141, Expected=550.0000
# Month=15, Predicted=494.6139, Expected=544.0000
# Month=16, Predicted=513.7164, Expected=505.0000
# Month=17, Predicted=489.5601, Expected=483.0000
# Month=18, Predicted=455.0861, Expected=469.0000
# Month=19, Predicted=457.3325, Expected=466.0000
# Month=20, Predicted=464.8232, Expected=487.0000
# Month=21, Predicted=507.6368, Expected=492.0000
# Month=22, Predicted=500.0253, Expected=531.0000
# Month=23, Predicted=573.5246, Expected=583.0000
# Month=24, Predicted=636.6916, Expected=659.0000
# Month=25, Predicted=732.2227, Expected=743.0000
# Month=26, Predicted=813.9299, Expected=811.0000
# Month=27, Predicted=864.2146, Expected=863.0000
# Month=28, Predicted=902.1728, Expected=898.0000
# Month=29, Predicted=920.8112, Expected=914.0000
# Month=30, Predicted=921.9285, Expected=920.0000
# Month=31, Predicted=932.9013, Expected=926.0000
# Month=32, Predicted=940.5476, Expected=919.0000
# Month=33, Predicted=917.2645, Expected=887.0000
# Month=34, Predicted=849.1042, Expected=862.0000
# Month=35, Predicted=831.7110, Expected=829.0000
# Month=36, Predicted=794.1545, Expected=769.0000
# Month=37, Predicted=709.4314, Expected=691.0000
# Month=38, Predicted=629.7508, Expected=618.0000
# Month=39, Predicted=568.4033, Expected=563.0000
# Month=40, Predicted=525.1444, Expected=529.0000
# Month=41, Predicted=503.7637, Expected=504.0000
# Month=42, Predicted=483.4498, Expected=489.0000
# Month=43, Predicted=474.6024, Expected=487.0000
# Month=44, Predicted=486.7127, Expected=508.0000
# Month=45, Predicted=529.7850, Expected=513.0000
# Month=46, Predicted=520.9599, Expected=555.0000
# Month=47, Predicted=600.7670, Expected=606.0000
# Month=48, Predicted=656.9700, Expected=676.0000
# Month=49, Predicted=743.3660, Expected=761.0000
# Month=50, Predicted=835.0414, Expected=837.0000
# Month=51, Predicted=898.2310, Expected=878.0000
# Month=52, Predicted=901.0928, Expected=890.0000
# Month=53, Predicted=887.6109, Expected=879.0000
# Month=54, Predicted=869.4697, Expected=847.0000
# Month=55, Predicted=809.0332, Expected=820.0000
# Month=56, Predicted=787.9902, Expected=790.0000
# Month=57, Predicted=758.3471, Expected=784.0000
# Month=58, Predicted=774.6796, Expected=752.0000
# Month=59, Predicted=717.6899, Expected=739.0000
# Month=60, Predicted=720.5745, Expected=684.0000
# Run 2 — RMSE: 19.474701, MSE: 379.263960, NMSE: 0.0002463024, sMAPE: 2.322525
#
# ===== RUN 3/2 =====
# Training complete for run 3
# Month=1, Predicted=672.1660, Expected=696.0000
# Month=2, Predicted=764.4542, Expected=765.0000
# Month=3, Predicted=824.7029, Expected=813.0000
# Month=4, Predicted=837.7356, Expected=851.0000
# Month=5, Predicted=871.8730, Expected=872.0000
# Month=6, Predicted=886.0015, Expected=883.0000
# Month=7, Predicted=890.0902, Expected=899.0000
# Month=8, Predicted=920.1422, Expected=897.0000
# Month=9, Predicted=894.3950, Expected=871.0000
# Month=10, Predicted=830.0618, Expected=831.0000
# Month=11, Predicted=792.6282, Expected=813.0000
# Month=12, Predicted=783.7704, Expected=749.0000
# Month=13, Predicted=680.5015, Expected=664.0000
# Month=14, Predicted=604.3862, Expected=550.0000
# Month=15, Predicted=480.5746, Expected=544.0000
# Month=16, Predicted=507.9423, Expected=505.0000
# Month=17, Predicted=472.7434, Expected=483.0000
# Month=18, Predicted=449.4479, Expected=469.0000
# Month=19, Predicted=462.4593, Expected=466.0000
# Month=20, Predicted=471.3565, Expected=487.0000
# Month=21, Predicted=511.6294, Expected=492.0000
# Month=22, Predicted=499.1639, Expected=531.0000
# Month=23, Predicted=577.3791, Expected=583.0000
# Month=24, Predicted=643.5498, Expected=659.0000
# Month=25, Predicted=728.2569, Expected=743.0000
# Month=26, Predicted=813.6844, Expected=811.0000
# Month=27, Predicted=864.3536, Expected=863.0000
# Month=28, Predicted=892.9248, Expected=898.0000
# Month=29, Predicted=917.8628, Expected=914.0000
# Month=30, Predicted=920.2045, Expected=920.0000
# Month=31, Predicted=922.1466, Expected=926.0000
# Month=32, Predicted=935.6377, Expected=919.0000
# Month=33, Predicted=909.6618, Expected=887.0000
# Month=34, Predicted=839.8677, Expected=862.0000
# Month=35, Predicted=832.4790, Expected=829.0000
# Month=36, Predicted=801.8673, Expected=769.0000
# Month=37, Predicted=718.7305, Expected=691.0000
# Month=38, Predicted=635.3735, Expected=618.0000
# Month=39, Predicted=572.7264, Expected=563.0000
# Month=40, Predicted=523.1703, Expected=529.0000
# Month=41, Predicted=496.7350, Expected=504.0000
# Month=42, Predicted=482.3444, Expected=489.0000
# Month=43, Predicted=477.6406, Expected=487.0000
# Month=44, Predicted=494.6380, Expected=508.0000
# Month=45, Predicted=533.1623, Expected=513.0000
# Month=46, Predicted=520.1493, Expected=555.0000
# Month=47, Predicted=606.0753, Expected=606.0000
# Month=48, Predicted=664.1871, Expected=676.0000
# Month=49, Predicted=740.3019, Expected=761.0000
# Month=50, Predicted=830.6841, Expected=837.0000
# Month=51, Predicted=900.1049, Expected=878.0000
# Month=52, Predicted=899.3686, Expected=890.0000
# Month=53, Predicted=876.9219, Expected=879.0000
# Month=54, Predicted=854.2978, Expected=847.0000
# Month=55, Predicted=801.3174, Expected=820.0000
# Month=56, Predicted=789.7030, Expected=790.0000
# Month=57, Predicted=765.2409, Expected=784.0000
# Month=58, Predicted=772.6106, Expected=752.0000
# Month=59, Predicted=707.5343, Expected=739.0000
# Month=60, Predicted=717.8989, Expected=684.0000
# Run 3 — RMSE: 19.873790, MSE: 394.967524, NMSE: 0.0002624206, sMAPE: 2.305000
#
# ===== RUN 4/2 =====
# Training complete for run 4
# Month=1, Predicted=671.8014, Expected=696.0000
# Month=2, Predicted=771.5240, Expected=765.0000
# Month=3, Predicted=818.8607, Expected=813.0000
# Month=4, Predicted=840.1294, Expected=851.0000
# Month=5, Predicted=873.8844, Expected=872.0000
# Month=6, Predicted=885.0051, Expected=883.0000
# Month=7, Predicted=887.1761, Expected=899.0000
# Month=8, Predicted=922.5785, Expected=897.0000
# Month=9, Predicted=892.6164, Expected=871.0000
# Month=10, Predicted=838.1419, Expected=831.0000
# Month=11, Predicted=792.7032, Expected=813.0000
# Month=12, Predicted=785.1746, Expected=749.0000
# Month=13, Predicted=682.5807, Expected=664.0000
# Month=14, Predicted=595.6498, Expected=550.0000
# Month=15, Predicted=473.0856, Expected=544.0000
# Month=16, Predicted=495.3893, Expected=505.0000
# Month=17, Predicted=497.0866, Expected=483.0000
# Month=18, Predicted=449.8064, Expected=469.0000
# Month=19, Predicted=462.9094, Expected=466.0000
# Month=20, Predicted=469.4769, Expected=487.0000
# Month=21, Predicted=511.4111, Expected=492.0000
# Month=22, Predicted=493.8185, Expected=531.0000
# Month=23, Predicted=576.6032, Expected=583.0000
# Month=24, Predicted=638.2003, Expected=659.0000
# Month=25, Predicted=730.6193, Expected=743.0000
# Month=26, Predicted=816.1577, Expected=811.0000
# Month=27, Predicted=860.8569, Expected=863.0000
# Month=28, Predicted=894.8905, Expected=898.0000
# Month=29, Predicted=918.3816, Expected=914.0000
# Month=30, Predicted=920.5616, Expected=920.0000
# Month=31, Predicted=923.4264, Expected=926.0000
# Month=32, Predicted=939.4175, Expected=919.0000
# Month=33, Predicted=913.8803, Expected=887.0000
# Month=34, Predicted=846.4752, Expected=862.0000
# Month=35, Predicted=834.0904, Expected=829.0000
# Month=36, Predicted=800.9437, Expected=769.0000
# Month=37, Predicted=726.8421, Expected=691.0000
# Month=38, Predicted=629.5093, Expected=618.0000
# Month=39, Predicted=562.9413, Expected=563.0000
# Month=40, Predicted=524.6413, Expected=529.0000
# Month=41, Predicted=500.5329, Expected=504.0000
# Month=42, Predicted=486.1942, Expected=489.0000
# Month=43, Predicted=478.1825, Expected=487.0000
# Month=44, Predicted=492.1064, Expected=508.0000
# Month=45, Predicted=533.5189, Expected=513.0000
# Month=46, Predicted=514.7397, Expected=555.0000
# Month=47, Predicted=604.3847, Expected=606.0000
# Month=48, Predicted=655.5756, Expected=676.0000
# Month=49, Predicted=741.0820, Expected=761.0000
# Month=50, Predicted=836.2997, Expected=837.0000
# Month=51, Predicted=895.9401, Expected=878.0000
# Month=52, Predicted=898.4104, Expected=890.0000
# Month=53, Predicted=882.4538, Expected=879.0000
# Month=54, Predicted=858.0705, Expected=847.0000
# Month=55, Predicted=806.5906, Expected=820.0000
# Month=56, Predicted=791.3999, Expected=790.0000
# Month=57, Predicted=765.3848, Expected=784.0000
# Month=58, Predicted=771.9106, Expected=752.0000
# Month=59, Predicted=717.0280, Expected=739.0000
# Month=60, Predicted=717.5478, Expected=684.0000
# Run 4 — RMSE: 20.347010, MSE: 414.000820, NMSE: 0.0002715904, sMAPE: 2.352861
#
# ===== RUN 5/2 =====
# Training complete for run 5
# Month=1, Predicted=674.3074, Expected=696.0000
# Month=2, Predicted=777.9585, Expected=765.0000
# Month=3, Predicted=808.2167, Expected=813.0000
# Month=4, Predicted=836.7937, Expected=851.0000
# Month=5, Predicted=879.7027, Expected=872.0000
# Month=6, Predicted=888.2885, Expected=883.0000
# Month=7, Predicted=897.9897, Expected=899.0000
# Month=8, Predicted=919.7695, Expected=897.0000
# Month=9, Predicted=896.7691, Expected=871.0000
# Month=10, Predicted=837.3236, Expected=831.0000
# Month=11, Predicted=792.0255, Expected=813.0000
# Month=12, Predicted=785.1636, Expected=749.0000
# Month=13, Predicted=676.2785, Expected=664.0000
# Month=14, Predicted=601.2120, Expected=550.0000
# Month=15, Predicted=479.1191, Expected=544.0000
# Month=16, Predicted=505.7248, Expected=505.0000
# Month=17, Predicted=496.5659, Expected=483.0000
# Month=18, Predicted=452.1712, Expected=469.0000
# Month=19, Predicted=463.3966, Expected=466.0000
# Month=20, Predicted=470.6730, Expected=487.0000
# Month=21, Predicted=506.7907, Expected=492.0000
# Month=22, Predicted=500.4328, Expected=531.0000
# Month=23, Predicted=567.4572, Expected=583.0000
# Month=24, Predicted=639.0308, Expected=659.0000
# Month=25, Predicted=738.3031, Expected=743.0000
# Month=26, Predicted=815.7946, Expected=811.0000
# Month=27, Predicted=852.8352, Expected=863.0000
# Month=28, Predicted=893.4876, Expected=898.0000
# Month=29, Predicted=919.8343, Expected=914.0000
# Month=30, Predicted=925.8887, Expected=920.0000
# Month=31, Predicted=930.4597, Expected=926.0000
# Month=32, Predicted=936.9363, Expected=919.0000
# Month=33, Predicted=914.1095, Expected=887.0000
# Month=34, Predicted=845.0707, Expected=862.0000
# Month=35, Predicted=832.9111, Expected=829.0000
# Month=36, Predicted=799.6663, Expected=769.0000
# Month=37, Predicted=727.1319, Expected=691.0000
# Month=38, Predicted=634.1125, Expected=618.0000
# Month=39, Predicted=562.7811, Expected=563.0000
# Month=40, Predicted=521.4166, Expected=529.0000
# Month=41, Predicted=500.5554, Expected=504.0000
# Month=42, Predicted=482.0800, Expected=489.0000
# Month=43, Predicted=478.8443, Expected=487.0000
# Month=44, Predicted=493.2789, Expected=508.0000
# Month=45, Predicted=528.5077, Expected=513.0000
# Month=46, Predicted=521.3539, Expected=555.0000
# Month=47, Predicted=594.2860, Expected=606.0000
# Month=48, Predicted=659.2662, Expected=676.0000
# Month=49, Predicted=747.9100, Expected=761.0000
# Month=50, Predicted=839.3757, Expected=837.0000
# Month=51, Predicted=890.0706, Expected=878.0000
# Month=52, Predicted=886.4093, Expected=890.0000
# Month=53, Predicted=888.5828, Expected=879.0000
# Month=54, Predicted=865.4567, Expected=847.0000
# Month=55, Predicted=806.2738, Expected=820.0000
# Month=56, Predicted=790.3419, Expected=790.0000
# Month=57, Predicted=763.6151, Expected=784.0000
# Month=58, Predicted=770.9412, Expected=752.0000
# Month=59, Predicted=715.1161, Expected=739.0000
# Month=60, Predicted=715.6739, Expected=684.0000
# Run 5 — RMSE: 19.602547, MSE: 384.259841, NMSE: 0.0002523324, sMAPE: 2.301334
#
# ===== RUN 6/2 =====
# Training complete for run 6
# Month=1, Predicted=670.3187, Expected=696.0000
# Month=2, Predicted=769.1770, Expected=765.0000
# Month=3, Predicted=819.4913, Expected=813.0000
# Month=4, Predicted=837.3539, Expected=851.0000
# Month=5, Predicted=875.1118, Expected=872.0000
# Month=6, Predicted=887.5605, Expected=883.0000
# Month=7, Predicted=896.1660, Expected=899.0000
# Month=8, Predicted=921.3431, Expected=897.0000
# Month=9, Predicted=896.6013, Expected=871.0000
# Month=10, Predicted=835.7672, Expected=831.0000
# Month=11, Predicted=794.8166, Expected=813.0000
# Month=12, Predicted=787.8323, Expected=749.0000
# Month=13, Predicted=676.1525, Expected=664.0000
# Month=14, Predicted=600.2825, Expected=550.0000
# Month=15, Predicted=480.8856, Expected=544.0000
# Month=16, Predicted=469.6547, Expected=505.0000
# Month=17, Predicted=461.0845, Expected=483.0000
# Month=18, Predicted=453.9498, Expected=469.0000
# Month=19, Predicted=464.0144, Expected=466.0000
# Month=20, Predicted=471.2332, Expected=487.0000
# Month=21, Predicted=508.4750, Expected=492.0000
# Month=22, Predicted=500.4766, Expected=531.0000
# Month=23, Predicted=570.8515, Expected=583.0000
# Month=24, Predicted=641.1040, Expected=659.0000
# Month=25, Predicted=731.0127, Expected=743.0000
# Month=26, Predicted=816.6977, Expected=811.0000
# Month=27, Predicted=860.7397, Expected=863.0000
# Month=28, Predicted=892.8783, Expected=898.0000
# Month=29, Predicted=917.3110, Expected=914.0000
# Month=30, Predicted=923.5422, Expected=920.0000
# Month=31, Predicted=928.7599, Expected=926.0000
# Month=32, Predicted=938.1750, Expected=919.0000
# Month=33, Predicted=913.9842, Expected=887.0000
# Month=34, Predicted=844.7523, Expected=862.0000
# Month=35, Predicted=835.5359, Expected=829.0000
# Month=36, Predicted=802.5936, Expected=769.0000
# Month=37, Predicted=721.8190, Expected=691.0000
# Month=38, Predicted=633.6066, Expected=618.0000
# Month=39, Predicted=562.5502, Expected=563.0000
# Month=40, Predicted=518.1408, Expected=529.0000
# Month=41, Predicted=497.5610, Expected=504.0000
# Month=42, Predicted=481.8245, Expected=489.0000
# Month=43, Predicted=479.7331, Expected=487.0000
# Month=44, Predicted=493.3071, Expected=508.0000
# Month=45, Predicted=530.0542, Expected=513.0000
# Month=46, Predicted=521.4365, Expected=555.0000
# Month=47, Predicted=597.9917, Expected=606.0000
# Month=48, Predicted=660.8188, Expected=676.0000
# Month=49, Predicted=742.2200, Expected=761.0000
# Month=50, Predicted=834.9439, Expected=837.0000
# Month=51, Predicted=896.8411, Expected=878.0000
# Month=52, Predicted=894.3972, Expected=890.0000
# Month=53, Predicted=881.9198, Expected=879.0000
# Month=54, Predicted=860.3947, Expected=847.0000
# Month=55, Predicted=807.8939, Expected=820.0000
# Month=56, Predicted=792.8344, Expected=790.0000
# Month=57, Predicted=766.2968, Expected=784.0000
# Month=58, Predicted=771.8095, Expected=752.0000
# Month=59, Predicted=711.8679, Expected=739.0000
# Month=60, Predicted=717.9219, Expected=684.0000
# Run 6 — RMSE: 20.185348, MSE: 407.448254, NMSE: 0.0002620071, sMAPE: 2.423666
#
# ===== RUN 7/2 =====
# Training complete for run 7
# Month=1, Predicted=672.2590, Expected=696.0000
# Month=2, Predicted=765.2214, Expected=765.0000
# Month=3, Predicted=821.0332, Expected=813.0000
# Month=4, Predicted=837.5238, Expected=851.0000
# Month=5, Predicted=872.1538, Expected=872.0000
# Month=6, Predicted=886.6818, Expected=883.0000
# Month=7, Predicted=888.2297, Expected=899.0000
# Month=8, Predicted=920.0263, Expected=897.0000
# Month=9, Predicted=895.1266, Expected=871.0000
# Month=10, Predicted=831.6719, Expected=831.0000
# Month=11, Predicted=787.4546, Expected=813.0000
# Month=12, Predicted=785.8286, Expected=749.0000
# Month=13, Predicted=696.9595, Expected=664.0000
# Month=14, Predicted=597.5977, Expected=550.0000
# Month=15, Predicted=480.6494, Expected=544.0000
# Month=16, Predicted=517.0697, Expected=505.0000
# Month=17, Predicted=498.8568, Expected=483.0000
# Month=18, Predicted=450.2872, Expected=469.0000
# Month=19, Predicted=460.7281, Expected=466.0000
# Month=20, Predicted=470.5350, Expected=487.0000
# Month=21, Predicted=515.9345, Expected=492.0000
# Month=22, Predicted=502.5636, Expected=531.0000
# Month=23, Predicted=576.6717, Expected=583.0000
# Month=24, Predicted=647.3806, Expected=659.0000
# Month=25, Predicted=729.4285, Expected=743.0000
# Month=26, Predicted=812.3212, Expected=811.0000
# Month=27, Predicted=862.3218, Expected=863.0000
# Month=28, Predicted=892.9475, Expected=898.0000
# Month=29, Predicted=917.2137, Expected=914.0000
# Month=30, Predicted=919.9063, Expected=920.0000
# Month=31, Predicted=919.2321, Expected=926.0000
# Month=32, Predicted=939.5714, Expected=919.0000
# Month=33, Predicted=914.4276, Expected=887.0000
# Month=34, Predicted=841.1124, Expected=862.0000
# Month=35, Predicted=829.0959, Expected=829.0000
# Month=36, Predicted=794.5249, Expected=769.0000
# Month=37, Predicted=719.0244, Expected=691.0000
# Month=38, Predicted=630.8581, Expected=618.0000
# Month=39, Predicted=566.0978, Expected=563.0000
# Month=40, Predicted=525.2270, Expected=529.0000
# Month=41, Predicted=503.5553, Expected=504.0000
# Month=42, Predicted=482.7240, Expected=489.0000
# Month=43, Predicted=475.6821, Expected=487.0000
# Month=44, Predicted=492.9648, Expected=508.0000
# Month=45, Predicted=538.0031, Expected=513.0000
# Month=46, Predicted=523.4805, Expected=555.0000
# Month=47, Predicted=604.5868, Expected=606.0000
# Month=48, Predicted=669.3092, Expected=676.0000
# Month=49, Predicted=740.8837, Expected=761.0000
# Month=50, Predicted=831.1886, Expected=837.0000
# Month=51, Predicted=895.4508, Expected=878.0000
# Month=52, Predicted=900.4344, Expected=890.0000
# Month=53, Predicted=874.0113, Expected=879.0000
# Month=54, Predicted=850.9786, Expected=847.0000
# Month=55, Predicted=803.3195, Expected=820.0000
# Month=56, Predicted=786.1152, Expected=790.0000
# Month=57, Predicted=758.0125, Expected=784.0000
# Month=58, Predicted=775.0293, Expected=752.0000
# Month=59, Predicted=711.3879, Expected=739.0000
# Month=60, Predicted=714.5600, Expected=684.0000
# Run 7 — RMSE: 19.867016, MSE: 394.698341, NMSE: 0.0002668149, sMAPE: 2.319655
#
# ===== RUN 8/2 =====
# Training complete for run 8
# Month=1, Predicted=673.9029, Expected=696.0000
# Month=2, Predicted=777.0887, Expected=765.0000
# Month=3, Predicted=818.8407, Expected=813.0000
# Month=4, Predicted=835.8217, Expected=851.0000
# Month=5, Predicted=872.1422, Expected=872.0000
# Month=6, Predicted=886.0099, Expected=883.0000
# Month=7, Predicted=896.3318, Expected=899.0000
# Month=8, Predicted=920.2759, Expected=897.0000
# Month=9, Predicted=897.9430, Expected=871.0000
# Month=10, Predicted=838.9058, Expected=831.0000
# Month=11, Predicted=794.7636, Expected=813.0000
# Month=12, Predicted=787.1686, Expected=749.0000
# Month=13, Predicted=671.9746, Expected=664.0000
# Month=14, Predicted=603.0336, Expected=550.0000
# Month=15, Predicted=476.3994, Expected=544.0000
# Month=16, Predicted=504.7640, Expected=505.0000
# Month=17, Predicted=470.7332, Expected=483.0000
# Month=18, Predicted=455.0967, Expected=469.0000
# Month=19, Predicted=462.9756, Expected=466.0000
# Month=20, Predicted=470.6800, Expected=487.0000
# Month=21, Predicted=507.4542, Expected=492.0000
# Month=22, Predicted=501.5936, Expected=531.0000
# Month=23, Predicted=567.8657, Expected=583.0000
# Month=24, Predicted=640.9724, Expected=659.0000
# Month=25, Predicted=735.7282, Expected=743.0000
# Month=26, Predicted=820.6466, Expected=811.0000
# Month=27, Predicted=860.1556, Expected=863.0000
# Month=28, Predicted=891.4867, Expected=898.0000
# Month=29, Predicted=914.1529, Expected=914.0000
# Month=30, Predicted=922.0189, Expected=920.0000
# Month=31, Predicted=929.3907, Expected=926.0000
# Month=32, Predicted=937.6086, Expected=919.0000
# Month=33, Predicted=915.3084, Expected=887.0000
# Month=34, Predicted=847.4791, Expected=862.0000
# Month=35, Predicted=835.9066, Expected=829.0000
# Month=36, Predicted=801.0995, Expected=769.0000
# Month=37, Predicted=725.8122, Expected=691.0000
# Month=38, Predicted=633.6667, Expected=618.0000
# Month=39, Predicted=563.1081, Expected=563.0000
# Month=40, Predicted=519.5475, Expected=529.0000
# Month=41, Predicted=495.8866, Expected=504.0000
# Month=42, Predicted=479.4611, Expected=489.0000
# Month=43, Predicted=479.1499, Expected=487.0000
# Month=44, Predicted=493.0016, Expected=508.0000
# Month=45, Predicted=529.1172, Expected=513.0000
# Month=46, Predicted=522.5036, Expected=555.0000
# Month=47, Predicted=594.7195, Expected=606.0000
# Month=48, Predicted=661.1128, Expected=676.0000
# Month=49, Predicted=745.7563, Expected=761.0000
# Month=50, Predicted=841.2459, Expected=837.0000
# Month=51, Predicted=898.0679, Expected=878.0000
# Month=52, Predicted=891.5404, Expected=890.0000
# Month=53, Predicted=876.6437, Expected=879.0000
# Month=54, Predicted=863.4394, Expected=847.0000
# Month=55, Predicted=808.8814, Expected=820.0000
# Month=56, Predicted=792.9814, Expected=790.0000
# Month=57, Predicted=765.1772, Expected=784.0000
# Month=58, Predicted=771.8298, Expected=752.0000
# Month=59, Predicted=715.2731, Expected=739.0000
# Month=60, Predicted=718.5827, Expected=684.0000
# Run 8 — RMSE: 19.845769, MSE: 393.854537, NMSE: 0.0002560162, sMAPE: 2.294550
#
# ===== RUN 9/2 =====
# Training complete for run 9
# Month=1, Predicted=673.4660, Expected=696.0000
# Month=2, Predicted=776.1972, Expected=765.0000
# Month=3, Predicted=820.3619, Expected=813.0000
# Month=4, Predicted=835.6560, Expected=851.0000
# Month=5, Predicted=871.9908, Expected=872.0000
# Month=6, Predicted=885.3391, Expected=883.0000
# Month=7, Predicted=895.1501, Expected=899.0000
# Month=8, Predicted=921.5964, Expected=897.0000
# Month=9, Predicted=897.4235, Expected=871.0000
# Month=10, Predicted=838.2329, Expected=831.0000
# Month=11, Predicted=790.5996, Expected=813.0000
# Month=12, Predicted=782.6285, Expected=749.0000
# Month=13, Predicted=673.9525, Expected=664.0000
# Month=14, Predicted=598.4560, Expected=550.0000
# Month=15, Predicted=492.4298, Expected=544.0000
# Month=16, Predicted=508.5657, Expected=505.0000
# Month=17, Predicted=497.9017, Expected=483.0000
# Month=18, Predicted=447.8789, Expected=469.0000
# Month=19, Predicted=463.8915, Expected=466.0000
# Month=20, Predicted=468.8617, Expected=487.0000
# Month=21, Predicted=509.0683, Expected=492.0000
# Month=22, Predicted=501.7815, Expected=531.0000
# Month=23, Predicted=571.9347, Expected=583.0000
# Month=24, Predicted=640.0578, Expected=659.0000
# Month=25, Predicted=735.4406, Expected=743.0000
# Month=26, Predicted=820.2897, Expected=811.0000
# Month=27, Predicted=861.4516, Expected=863.0000
# Month=28, Predicted=890.8379, Expected=898.0000
# Month=29, Predicted=914.5561, Expected=914.0000
# Month=30, Predicted=921.4175, Expected=920.0000
# Month=31, Predicted=928.3772, Expected=926.0000
# Month=32, Predicted=940.5577, Expected=919.0000
# Month=33, Predicted=917.4080, Expected=887.0000
# Month=34, Predicted=845.3748, Expected=862.0000
# Month=35, Predicted=831.5803, Expected=829.0000
# Month=36, Predicted=800.0041, Expected=769.0000
# Month=37, Predicted=721.5470, Expected=691.0000
# Month=38, Predicted=631.6652, Expected=618.0000
# Month=39, Predicted=569.1937, Expected=563.0000
# Month=40, Predicted=527.3292, Expected=529.0000
# Month=41, Predicted=501.0012, Expected=504.0000
# Month=42, Predicted=483.5748, Expected=489.0000
# Month=43, Predicted=478.6812, Expected=487.0000
# Month=44, Predicted=491.3056, Expected=508.0000
# Month=45, Predicted=531.1423, Expected=513.0000
# Month=46, Predicted=522.6336, Expected=555.0000
# Month=47, Predicted=598.9557, Expected=606.0000
# Month=48, Predicted=660.0169, Expected=676.0000
# Month=49, Predicted=745.0479, Expected=761.0000
# Month=50, Predicted=840.5065, Expected=837.0000
# Month=51, Predicted=898.5406, Expected=878.0000
# Month=52, Predicted=892.8995, Expected=890.0000
# Month=53, Predicted=878.4005, Expected=879.0000
# Month=54, Predicted=861.5467, Expected=847.0000
# Month=55, Predicted=805.3211, Expected=820.0000
# Month=56, Predicted=788.7822, Expected=790.0000
# Month=57, Predicted=764.2063, Expected=784.0000
# Month=58, Predicted=768.7277, Expected=752.0000
# Month=59, Predicted=716.6662, Expected=739.0000
# Month=60, Predicted=715.3785, Expected=684.0000
# Run 9 — RMSE: 18.720465, MSE: 350.455795, NMSE: 0.0002324541, sMAPE: 2.212532
#
# ===== RUN 10/2 =====
# Training complete for run 10
# Month=1, Predicted=673.6944, Expected=696.0000
# Month=2, Predicted=775.9619, Expected=765.0000
# Month=3, Predicted=810.9251, Expected=813.0000
# Month=4, Predicted=835.4434, Expected=851.0000
# Month=5, Predicted=877.3286, Expected=872.0000
# Month=6, Predicted=886.8347, Expected=883.0000
# Month=7, Predicted=897.8098, Expected=899.0000
# Month=8, Predicted=920.5814, Expected=897.0000
# Month=9, Predicted=897.6428, Expected=871.0000
# Month=10, Predicted=835.6300, Expected=831.0000
# Month=11, Predicted=789.9188, Expected=813.0000
# Month=12, Predicted=784.6351, Expected=749.0000
# Month=13, Predicted=676.4648, Expected=664.0000
# Month=14, Predicted=597.3015, Expected=550.0000
# Month=15, Predicted=485.4013, Expected=544.0000
# Month=16, Predicted=511.7511, Expected=505.0000
# Month=17, Predicted=507.5483, Expected=483.0000
# Month=18, Predicted=450.4149, Expected=469.0000
# Month=19, Predicted=464.4248, Expected=466.0000
# Month=20, Predicted=470.1229, Expected=487.0000
# Month=21, Predicted=507.6815, Expected=492.0000
# Month=22, Predicted=502.4146, Expected=531.0000
# Month=23, Predicted=568.7233, Expected=583.0000
# Month=24, Predicted=638.8138, Expected=659.0000
# Month=25, Predicted=736.4693, Expected=743.0000
# Month=26, Predicted=815.7850, Expected=811.0000
# Month=27, Predicted=853.7948, Expected=863.0000
# Month=28, Predicted=892.6818, Expected=898.0000
# Month=29, Predicted=918.3425, Expected=914.0000
# Month=30, Predicted=923.9910, Expected=920.0000
# Month=31, Predicted=930.3490, Expected=926.0000
# Month=32, Predicted=936.7350, Expected=919.0000
# Month=33, Predicted=913.5098, Expected=887.0000
# Month=34, Predicted=842.2230, Expected=862.0000
# Month=35, Predicted=831.3849, Expected=829.0000
# Month=36, Predicted=799.5476, Expected=769.0000
# Month=37, Predicted=722.6936, Expected=691.0000
# Month=38, Predicted=630.4690, Expected=618.0000
# Month=39, Predicted=568.6134, Expected=563.0000
# Month=40, Predicted=527.9594, Expected=529.0000
# Month=41, Predicted=501.9730, Expected=504.0000
# Month=42, Predicted=482.7831, Expected=489.0000
# Month=43, Predicted=478.6435, Expected=487.0000
# Month=44, Predicted=492.7803, Expected=508.0000
# Month=45, Predicted=529.6143, Expected=513.0000
# Month=46, Predicted=523.2743, Expected=555.0000
# Month=47, Predicted=595.8358, Expected=606.0000
# Month=48, Predicted=659.5497, Expected=676.0000
# Month=49, Predicted=746.1705, Expected=761.0000
# Month=50, Predicted=838.4791, Expected=837.0000
# Month=51, Predicted=890.7820, Expected=878.0000
# Month=52, Predicted=887.3508, Expected=890.0000
# Month=53, Predicted=885.4680, Expected=879.0000
# Month=54, Predicted=864.2346, Expected=847.0000
# Month=55, Predicted=803.0723, Expected=820.0000
# Month=56, Predicted=788.7967, Expected=790.0000
# Month=57, Predicted=763.4041, Expected=784.0000
# Month=58, Predicted=769.6844, Expected=752.0000
# Month=59, Predicted=716.0181, Expected=739.0000
# Month=60, Predicted=715.0405, Expected=684.0000
# Run 10 — RMSE: 19.061795, MSE: 363.352025, NMSE: 0.0002422059, sMAPE: 2.271133
#
# ===== RUN 11/2 =====
# Training complete for run 11
# Month=1, Predicted=678.0296, Expected=696.0000
# Month=2, Predicted=773.2478, Expected=765.0000
# Month=3, Predicted=811.3914, Expected=813.0000
# Month=4, Predicted=832.3980, Expected=851.0000
# Month=5, Predicted=871.4952, Expected=872.0000
# Month=6, Predicted=886.7852, Expected=883.0000
# Month=7, Predicted=894.3970, Expected=899.0000
# Month=8, Predicted=918.3686, Expected=897.0000
# Month=9, Predicted=898.0691, Expected=871.0000
# Month=10, Predicted=837.6104, Expected=831.0000
# Month=11, Predicted=792.4654, Expected=813.0000
# Month=12, Predicted=786.1497, Expected=749.0000
# Month=13, Predicted=673.9341, Expected=664.0000
# Month=14, Predicted=597.5840, Expected=550.0000
# Month=15, Predicted=482.3053, Expected=544.0000
# Month=16, Predicted=512.2973, Expected=505.0000
# Month=17, Predicted=481.5907, Expected=483.0000
# Month=18, Predicted=449.7929, Expected=469.0000
# Month=19, Predicted=465.9443, Expected=466.0000
# Month=20, Predicted=469.9206, Expected=487.0000
# Month=21, Predicted=505.5282, Expected=492.0000
# Month=22, Predicted=502.4388, Expected=531.0000
# Month=23, Predicted=565.0843, Expected=583.0000
# Month=24, Predicted=645.4388, Expected=659.0000
# Month=25, Predicted=739.2794, Expected=743.0000
# Month=26, Predicted=812.8453, Expected=811.0000
# Month=27, Predicted=855.0598, Expected=863.0000
# Month=28, Predicted=887.4206, Expected=898.0000
# Month=29, Predicted=914.1493, Expected=914.0000
# Month=30, Predicted=921.4554, Expected=920.0000
# Month=31, Predicted=926.4900, Expected=926.0000
# Month=32, Predicted=935.8615, Expected=919.0000
# Month=33, Predicted=914.2002, Expected=887.0000
# Month=34, Predicted=846.5711, Expected=862.0000
# Month=35, Predicted=832.1333, Expected=829.0000
# Month=36, Predicted=802.5974, Expected=769.0000
# Month=37, Predicted=725.2231, Expected=691.0000
# Month=38, Predicted=632.1979, Expected=618.0000
# Month=39, Predicted=564.4148, Expected=563.0000
# Month=40, Predicted=523.0561, Expected=529.0000
# Month=41, Predicted=501.9639, Expected=504.0000
# Month=42, Predicted=484.4479, Expected=489.0000
# Month=43, Predicted=479.9499, Expected=487.0000
# Month=44, Predicted=492.5821, Expected=508.0000
# Month=45, Predicted=527.2627, Expected=513.0000
# Month=46, Predicted=523.3644, Expected=555.0000
# Month=47, Predicted=591.8817, Expected=606.0000
# Month=48, Predicted=666.1109, Expected=676.0000
# Month=49, Predicted=749.8683, Expected=761.0000
# Month=50, Predicted=836.0404, Expected=837.0000
# Month=51, Predicted=889.4192, Expected=878.0000
# Month=52, Predicted=887.7908, Expected=890.0000
# Month=53, Predicted=873.9107, Expected=879.0000
# Month=54, Predicted=858.2395, Expected=847.0000
# Month=55, Predicted=807.7878, Expected=820.0000
# Month=56, Predicted=789.9008, Expected=790.0000
# Month=57, Predicted=766.6179, Expected=784.0000
# Month=58, Predicted=767.0993, Expected=752.0000
# Month=59, Predicted=716.5941, Expected=739.0000
# Month=60, Predicted=714.1362, Expected=684.0000
# Run 11 — RMSE: 18.493166, MSE: 341.997206, NMSE: 0.0002275673, sMAPE: 2.079317
#
# ===== RUN 12/2 =====
# Training complete for run 12
# Month=1, Predicted=669.1607, Expected=696.0000
# Month=2, Predicted=775.8548, Expected=765.0000
# Month=3, Predicted=820.4157, Expected=813.0000
# Month=4, Predicted=845.3035, Expected=851.0000
# Month=5, Predicted=878.0145, Expected=872.0000
# Month=6, Predicted=884.5611, Expected=883.0000
# Month=7, Predicted=897.8413, Expected=899.0000
# Month=8, Predicted=921.4022, Expected=897.0000
# Month=9, Predicted=896.6059, Expected=871.0000
# Month=10, Predicted=836.0207, Expected=831.0000
# Month=11, Predicted=795.8893, Expected=813.0000
# Month=12, Predicted=782.0156, Expected=749.0000
# Month=13, Predicted=677.7438, Expected=664.0000
# Month=14, Predicted=596.1061, Expected=550.0000
# Month=15, Predicted=485.8947, Expected=544.0000
# Month=16, Predicted=477.7526, Expected=505.0000
# Month=17, Predicted=490.0365, Expected=483.0000
# Month=18, Predicted=447.6205, Expected=469.0000
# Month=19, Predicted=464.7197, Expected=466.0000
# Month=20, Predicted=470.3455, Expected=487.0000
# Month=21, Predicted=509.0418, Expected=492.0000
# Month=22, Predicted=499.9195, Expected=531.0000
# Month=23, Predicted=571.1690, Expected=583.0000
# Month=24, Predicted=636.2279, Expected=659.0000
# Month=25, Predicted=732.1755, Expected=743.0000
# Month=26, Predicted=818.1298, Expected=811.0000
# Month=27, Predicted=865.3635, Expected=863.0000
# Month=28, Predicted=900.4628, Expected=898.0000
# Month=29, Predicted=919.1674, Expected=914.0000
# Month=30, Predicted=923.4671, Expected=920.0000
# Month=31, Predicted=930.7920, Expected=926.0000
# Month=32, Predicted=937.9303, Expected=919.0000
# Month=33, Predicted=914.1266, Expected=887.0000
# Month=34, Predicted=843.2698, Expected=862.0000
# Month=35, Predicted=833.2262, Expected=829.0000
# Month=36, Predicted=801.2273, Expected=769.0000
# Month=37, Predicted=728.0811, Expected=691.0000
# Month=38, Predicted=630.1771, Expected=618.0000
# Month=39, Predicted=565.1291, Expected=563.0000
# Month=40, Predicted=523.7617, Expected=529.0000
# Month=41, Predicted=503.0833, Expected=504.0000
# Month=42, Predicted=485.1751, Expected=489.0000
# Month=43, Predicted=479.8300, Expected=487.0000
# Month=44, Predicted=493.0858, Expected=508.0000
# Month=45, Predicted=530.8860, Expected=513.0000
# Month=46, Predicted=520.7998, Expected=555.0000
# Month=47, Predicted=598.3897, Expected=606.0000
# Month=48, Predicted=653.8499, Expected=676.0000
# Month=49, Predicted=742.2109, Expected=761.0000
# Month=50, Predicted=838.6164, Expected=837.0000
# Month=51, Predicted=900.9364, Expected=878.0000
# Month=52, Predicted=900.5531, Expected=890.0000
# Month=53, Predicted=888.4323, Expected=879.0000
# Month=54, Predicted=865.4198, Expected=847.0000
# Month=55, Predicted=803.6487, Expected=820.0000
# Month=56, Predicted=790.8277, Expected=790.0000
# Month=57, Predicted=765.2649, Expected=784.0000
# Month=58, Predicted=772.5552, Expected=752.0000
# Month=59, Predicted=714.9406, Expected=739.0000
# Month=60, Predicted=715.0407, Expected=684.0000
# Run 12 — RMSE: 19.743945, MSE: 389.823380, NMSE: 0.0002516685, sMAPE: 2.359063
#
# ===== RUN 13/2 =====
# Training complete for run 13
# Month=1, Predicted=668.0300, Expected=696.0000
# Month=2, Predicted=769.4451, Expected=765.0000
# Month=3, Predicted=819.3251, Expected=813.0000
# Month=4, Predicted=843.9268, Expected=851.0000
# Month=5, Predicted=877.0279, Expected=872.0000
# Month=6, Predicted=886.0837, Expected=883.0000
# Month=7, Predicted=891.8015, Expected=899.0000
# Month=8, Predicted=925.4892, Expected=897.0000
# Month=9, Predicted=893.5880, Expected=871.0000
# Month=10, Predicted=834.9197, Expected=831.0000
# Month=11, Predicted=788.8870, Expected=813.0000
# Month=12, Predicted=790.0907, Expected=749.0000
# Month=13, Predicted=691.5532, Expected=664.0000
# Month=14, Predicted=602.2319, Expected=550.0000
# Month=15, Predicted=477.3870, Expected=544.0000
# Month=16, Predicted=524.1018, Expected=505.0000
# Month=17, Predicted=472.2116, Expected=483.0000
# Month=18, Predicted=454.4004, Expected=469.0000
# Month=19, Predicted=458.8203, Expected=466.0000
# Month=20, Predicted=467.5562, Expected=487.0000
# Month=21, Predicted=511.8132, Expected=492.0000
# Month=22, Predicted=496.5837, Expected=531.0000
# Month=23, Predicted=580.2411, Expected=583.0000
# Month=24, Predicted=640.5864, Expected=659.0000
# Month=25, Predicted=727.1277, Expected=743.0000
# Month=26, Predicted=814.3930, Expected=811.0000
# Month=27, Predicted=862.3585, Expected=863.0000
# Month=28, Predicted=898.4507, Expected=898.0000
# Month=29, Predicted=921.3415, Expected=914.0000
# Month=30, Predicted=922.7858, Expected=920.0000
# Month=31, Predicted=927.3675, Expected=926.0000
# Month=32, Predicted=941.1426, Expected=919.0000
# Month=33, Predicted=913.2706, Expected=887.0000
# Month=34, Predicted=845.6634, Expected=862.0000
# Month=35, Predicted=833.5939, Expected=829.0000
# Month=36, Predicted=796.3373, Expected=769.0000
# Month=37, Predicted=717.0484, Expected=691.0000
# Month=38, Predicted=633.1195, Expected=618.0000
# Month=39, Predicted=566.5112, Expected=563.0000
# Month=40, Predicted=522.9265, Expected=529.0000
# Month=41, Predicted=501.4605, Expected=504.0000
# Month=42, Predicted=483.6097, Expected=489.0000
# Month=43, Predicted=476.2239, Expected=487.0000
# Month=44, Predicted=489.4701, Expected=508.0000
# Month=45, Predicted=533.8611, Expected=513.0000
# Month=46, Predicted=517.5396, Expected=555.0000
# Month=47, Predicted=607.9922, Expected=606.0000
# Month=48, Predicted=656.7240, Expected=676.0000
# Month=49, Predicted=737.2629, Expected=761.0000
# Month=50, Predicted=833.9740, Expected=837.0000
# Month=51, Predicted=896.8112, Expected=878.0000
# Month=52, Predicted=901.7528, Expected=890.0000
# Month=53, Predicted=889.0253, Expected=879.0000
# Month=54, Predicted=856.3926, Expected=847.0000
# Month=55, Predicted=808.2044, Expected=820.0000
# Month=56, Predicted=789.9754, Expected=790.0000
# Month=57, Predicted=760.4237, Expected=784.0000
# Month=58, Predicted=776.3484, Expected=752.0000
# Month=59, Predicted=712.0805, Expected=739.0000
# Month=60, Predicted=722.1112, Expected=684.0000
# Run 13 — RMSE: 21.009973, MSE: 441.418978, NMSE: 0.0002886164, sMAPE: 2.471611
#
# ===== RUN 14/2 =====
# Training complete for run 14
# Month=1, Predicted=666.1662, Expected=696.0000
# Month=2, Predicted=766.0860, Expected=765.0000
# Month=3, Predicted=820.6427, Expected=813.0000
# Month=4, Predicted=849.5763, Expected=851.0000
# Month=5, Predicted=873.2897, Expected=872.0000
# Month=6, Predicted=880.0019, Expected=883.0000
# Month=7, Predicted=892.5133, Expected=899.0000
# Month=8, Predicted=922.9203, Expected=897.0000
# Month=9, Predicted=892.7168, Expected=871.0000
# Month=10, Predicted=832.9825, Expected=831.0000
# Month=11, Predicted=785.9872, Expected=813.0000
# Month=12, Predicted=782.2237, Expected=749.0000
# Month=13, Predicted=685.5494, Expected=664.0000
# Month=14, Predicted=598.3816, Expected=550.0000
# Month=15, Predicted=508.3381, Expected=544.0000
# Month=16, Predicted=429.3091, Expected=505.0000
# Month=17, Predicted=469.8784, Expected=483.0000
# Month=18, Predicted=441.7572, Expected=469.0000
# Month=19, Predicted=463.2667, Expected=466.0000
# Month=20, Predicted=471.7309, Expected=487.0000
# Month=21, Predicted=511.0527, Expected=492.0000
# Month=22, Predicted=496.7039, Expected=531.0000
# Month=23, Predicted=574.3640, Expected=583.0000
# Month=24, Predicted=640.8966, Expected=659.0000
# Month=25, Predicted=734.2387, Expected=743.0000
# Month=26, Predicted=804.9873, Expected=811.0000
# Month=27, Predicted=864.8469, Expected=863.0000
# Month=28, Predicted=902.1323, Expected=898.0000
# Month=29, Predicted=919.0723, Expected=914.0000
# Month=30, Predicted=917.9018, Expected=920.0000
# Month=31, Predicted=925.9784, Expected=926.0000
# Month=32, Predicted=938.4706, Expected=919.0000
# Month=33, Predicted=912.2483, Expected=887.0000
# Month=34, Predicted=843.0013, Expected=862.0000
# Month=35, Predicted=826.9713, Expected=829.0000
# Month=36, Predicted=801.1286, Expected=769.0000
# Month=37, Predicted=716.6322, Expected=691.0000
# Month=38, Predicted=633.9478, Expected=618.0000
# Month=39, Predicted=571.3156, Expected=563.0000
# Month=40, Predicted=525.0157, Expected=529.0000
# Month=41, Predicted=498.7522, Expected=504.0000
# Month=42, Predicted=485.4295, Expected=489.0000
# Month=43, Predicted=478.8287, Expected=487.0000
# Month=44, Predicted=493.4573, Expected=508.0000
# Month=45, Predicted=533.0137, Expected=513.0000
# Month=46, Predicted=517.6032, Expected=555.0000
# Month=47, Predicted=601.8385, Expected=606.0000
# Month=48, Predicted=659.3921, Expected=676.0000
# Month=49, Predicted=742.5400, Expected=761.0000
# Month=50, Predicted=825.7899, Expected=837.0000
# Month=51, Predicted=895.4276, Expected=878.0000
# Month=52, Predicted=913.0069, Expected=890.0000
# Month=53, Predicted=885.0778, Expected=879.0000
# Month=54, Predicted=855.2422, Expected=847.0000
# Month=55, Predicted=804.9936, Expected=820.0000
# Month=56, Predicted=785.0077, Expected=790.0000
# Month=57, Predicted=763.9684, Expected=784.0000
# Month=58, Predicted=772.4681, Expected=752.0000
# Month=59, Predicted=713.6556, Expected=739.0000
# Month=60, Predicted=712.5400, Expected=684.0000
# Run 14 — RMSE: 21.136048, MSE: 446.732523, NMSE: 0.0002876679, sMAPE: 2.514931
#
# ===== RUN 15/2 =====
# Training complete for run 15
# Month=1, Predicted=671.4891, Expected=696.0000
# Month=2, Predicted=776.3563, Expected=765.0000
# Month=3, Predicted=818.1136, Expected=813.0000
# Month=4, Predicted=839.3886, Expected=851.0000
# Month=5, Predicted=877.1128, Expected=872.0000
# Month=6, Predicted=885.8783, Expected=883.0000
# Month=7, Predicted=895.7365, Expected=899.0000
# Month=8, Predicted=921.9410, Expected=897.0000
# Month=9, Predicted=896.6736, Expected=871.0000
# Month=10, Predicted=838.4400, Expected=831.0000
# Month=11, Predicted=791.7711, Expected=813.0000
# Month=12, Predicted=786.4671, Expected=749.0000
# Month=13, Predicted=679.4977, Expected=664.0000
# Month=14, Predicted=599.8852, Expected=550.0000
# Month=15, Predicted=476.0237, Expected=544.0000
# Month=16, Predicted=518.9469, Expected=505.0000
# Month=17, Predicted=487.0407, Expected=483.0000
# Month=18, Predicted=454.2046, Expected=469.0000
# Month=19, Predicted=461.2235, Expected=466.0000
# Month=20, Predicted=470.0786, Expected=487.0000
# Month=21, Predicted=509.6973, Expected=492.0000
# Month=22, Predicted=499.1613, Expected=531.0000
# Month=23, Predicted=571.9196, Expected=583.0000
# Month=24, Predicted=638.8624, Expected=659.0000
# Month=25, Predicted=732.7723, Expected=743.0000
# Month=26, Predicted=819.4886, Expected=811.0000
# Month=27, Predicted=860.8969, Expected=863.0000
# Month=28, Predicted=895.3147, Expected=898.0000
# Month=29, Predicted=919.2678, Expected=914.0000
# Month=30, Predicted=922.2992, Expected=920.0000
# Month=31, Predicted=929.5521, Expected=926.0000
# Month=32, Predicted=939.8621, Expected=919.0000
# Month=33, Predicted=916.0555, Expected=887.0000
# Month=34, Predicted=845.9825, Expected=862.0000
# Month=35, Predicted=834.8564, Expected=829.0000
# Month=36, Predicted=797.8975, Expected=769.0000
# Month=37, Predicted=722.5160, Expected=691.0000
# Month=38, Predicted=631.6822, Expected=618.0000
# Month=39, Predicted=563.4085, Expected=563.0000
# Month=40, Predicted=522.7144, Expected=529.0000
# Month=41, Predicted=500.5395, Expected=504.0000
# Month=42, Predicted=480.6477, Expected=489.0000
# Month=43, Predicted=477.6555, Expected=487.0000
# Month=44, Predicted=491.8804, Expected=508.0000
# Month=45, Predicted=531.2454, Expected=513.0000
# Month=46, Predicted=520.1456, Expected=555.0000
# Month=47, Predicted=598.9220, Expected=606.0000
# Month=48, Predicted=658.5216, Expected=676.0000
# Month=49, Predicted=742.8000, Expected=761.0000
# Month=50, Predicted=840.0646, Expected=837.0000
# Month=51, Predicted=898.0839, Expected=878.0000
# Month=52, Predicted=893.8189, Expected=890.0000
# Month=53, Predicted=885.2668, Expected=879.0000
# Month=54, Predicted=863.9582, Expected=847.0000
# Month=55, Predicted=808.7485, Expected=820.0000
# Month=56, Predicted=791.5673, Expected=790.0000
# Month=57, Predicted=762.0940, Expected=784.0000
# Month=58, Predicted=774.1446, Expected=752.0000
# Month=59, Predicted=712.3555, Expected=739.0000
# Month=60, Predicted=720.6300, Expected=684.0000
# Run 15 — RMSE: 20.206634, MSE: 408.308061, NMSE: 0.0002666521, sMAPE: 2.372040
#
# ===== RUN 16/2 =====
# Training complete for run 16
# Month=1, Predicted=673.3462, Expected=696.0000
# Month=2, Predicted=771.8467, Expected=765.0000
# Month=3, Predicted=816.5415, Expected=813.0000
# Month=4, Predicted=835.0247, Expected=851.0000
# Month=5, Predicted=874.7236, Expected=872.0000
# Month=6, Predicted=886.9638, Expected=883.0000
# Month=7, Predicted=896.5344, Expected=899.0000
# Month=8, Predicted=919.8619, Expected=897.0000
# Month=9, Predicted=896.9442, Expected=871.0000
# Month=10, Predicted=836.9868, Expected=831.0000
# Month=11, Predicted=795.8033, Expected=813.0000
# Month=12, Predicted=786.4412, Expected=749.0000
# Month=13, Predicted=671.6522, Expected=664.0000
# Month=14, Predicted=599.8208, Expected=550.0000
# Month=15, Predicted=464.2796, Expected=544.0000
# Month=16, Predicted=574.2629, Expected=505.0000
# Month=17, Predicted=470.5283, Expected=483.0000
# Month=18, Predicted=454.6172, Expected=469.0000
# Month=19, Predicted=463.8304, Expected=466.0000
# Month=20, Predicted=472.4425, Expected=487.0000
# Month=21, Predicted=508.3436, Expected=492.0000
# Month=22, Predicted=501.1826, Expected=531.0000
# Month=23, Predicted=567.8909, Expected=583.0000
# Month=24, Predicted=638.9351, Expected=659.0000
# Month=25, Predicted=733.9526, Expected=743.0000
# Month=26, Predicted=815.3910, Expected=811.0000
# Month=27, Predicted=858.1688, Expected=863.0000
# Month=28, Predicted=891.2457, Expected=898.0000
# Month=29, Predicted=916.2662, Expected=914.0000
# Month=30, Predicted=923.6751, Expected=920.0000
# Month=31, Predicted=929.2488, Expected=926.0000
# Month=32, Predicted=937.1956, Expected=919.0000
# Month=33, Predicted=914.4458, Expected=887.0000
# Month=34, Predicted=845.5110, Expected=862.0000
# Month=35, Predicted=836.7037, Expected=829.0000
# Month=36, Predicted=801.9684, Expected=769.0000
# Month=37, Predicted=727.7965, Expected=691.0000
# Month=38, Predicted=632.9776, Expected=618.0000
# Month=39, Predicted=563.7718, Expected=563.0000
# Month=40, Predicted=521.5502, Expected=529.0000
# Month=41, Predicted=495.2325, Expected=504.0000
# Month=42, Predicted=479.7800, Expected=489.0000
# Month=43, Predicted=479.0887, Expected=487.0000
# Month=44, Predicted=494.9890, Expected=508.0000
# Month=45, Predicted=529.9663, Expected=513.0000
# Month=46, Predicted=522.0760, Expected=555.0000
# Month=47, Predicted=594.7444, Expected=606.0000
# Month=48, Predicted=659.5280, Expected=676.0000
# Month=49, Predicted=744.6009, Expected=761.0000
# Month=50, Predicted=836.0236, Expected=837.0000
# Month=51, Predicted=894.3552, Expected=878.0000
# Month=52, Predicted=889.4651, Expected=890.0000
# Month=53, Predicted=882.1971, Expected=879.0000
# Month=54, Predicted=863.0969, Expected=847.0000
# Month=55, Predicted=806.8723, Expected=820.0000
# Month=56, Predicted=793.8759, Expected=790.0000
# Month=57, Predicted=765.6481, Expected=784.0000
# Month=58, Predicted=771.6491, Expected=752.0000
# Month=59, Predicted=714.6622, Expected=739.0000
# Month=60, Predicted=719.4506, Expected=684.0000
# Run 16 — RMSE: 22.327791, MSE: 498.530238, NMSE: 0.0003292426, sMAPE: 2.532920
#
# ...
# Month=42, Predicted=481.8153, Expected=489.0000
# Month=43, Predicted=479.2403, Expected=487.0000
# Month=44, Predicted=492.3108, Expected=508.0000
# Month=45, Predicted=530.8833, Expected=513.0000
# Month=46, Predicted=520.5316, Expected=555.0000
# Month=47, Predicted=599.9688, Expected=606.0000
# Month=48, Predicted=656.0602, Expected=676.0000
# Month=49, Predicted=741.9221, Expected=761.0000
# Month=50, Predicted=837.4272, Expected=837.0000
# Month=51, Predicted=896.2917, Expected=878.0000
# Month=52, Predicted=897.6240, Expected=890.0000
# Month=53, Predicted=881.3943, Expected=879.0000
# Month=54, Predicted=864.0708, Expected=847.0000
# Month=55, Predicted=806.3296, Expected=820.0000
# Month=56, Predicted=788.6663, Expected=790.0000
# Month=57, Predicted=763.0279, Expected=784.0000
# Month=58, Predicted=773.3218, Expected=752.0000
# Month=59, Predicted=715.4434, Expected=739.0000
# Month=60, Predicted=715.4828, Expected=684.0000
# Run 25 — RMSE: 19.548100, MSE: 382.128201, NMSE: 0.0002524000, sMAPE: 2.332115
#
# ===== RUN 26/2 =====
# Training complete for run 26
# Month=1, Predicted=670.4290, Expected=696.0000
# Month=2, Predicted=768.9915, Expected=765.0000
# Month=3, Predicted=820.7511, Expected=813.0000
# Month=4, Predicted=839.9950, Expected=851.0000
# Month=5, Predicted=874.3656, Expected=872.0000
# Month=6, Predicted=885.6266, Expected=883.0000
# Month=7, Predicted=894.8636, Expected=899.0000
# Month=8, Predicted=920.5884, Expected=897.0000
# Month=9, Predicted=895.4889, Expected=871.0000
# Month=10, Predicted=834.6638, Expected=831.0000
# Month=11, Predicted=792.6566, Expected=813.0000
# Month=12, Predicted=784.4004, Expected=749.0000
# Month=13, Predicted=676.6327, Expected=664.0000
# Month=14, Predicted=603.8244, Expected=550.0000
# Month=15, Predicted=485.4772, Expected=544.0000
# Month=16, Predicted=509.5752, Expected=505.0000
# Month=17, Predicted=506.3105, Expected=483.0000
# Month=18, Predicted=450.5033, Expected=469.0000
# Month=19, Predicted=466.2373, Expected=466.0000
# Month=20, Predicted=473.0739, Expected=487.0000
# Month=21, Predicted=512.8145, Expected=492.0000
# Month=22, Predicted=499.1763, Expected=531.0000
# Month=23, Predicted=572.5903, Expected=583.0000
# Month=24, Predicted=640.0739, Expected=659.0000
# Month=25, Predicted=731.1612, Expected=743.0000
# Month=26, Predicted=815.3063, Expected=811.0000
# Month=27, Predicted=862.7998, Expected=863.0000
# Month=28, Predicted=894.4024, Expected=898.0000
# Month=29, Predicted=917.1605, Expected=914.0000
# Month=30, Predicted=921.7719, Expected=920.0000
# Month=31, Predicted=927.9788, Expected=926.0000
# Month=32, Predicted=938.2944, Expected=919.0000
# Month=33, Predicted=913.6626, Expected=887.0000
# Month=34, Predicted=843.2189, Expected=862.0000
# Month=35, Predicted=831.8586, Expected=829.0000
# Month=36, Predicted=801.0800, Expected=769.0000
# Month=37, Predicted=725.9071, Expected=691.0000
# Month=38, Predicted=635.8596, Expected=618.0000
# Month=39, Predicted=565.8984, Expected=563.0000
# Month=40, Predicted=522.4913, Expected=529.0000
# Month=41, Predicted=499.6785, Expected=504.0000
# Month=42, Predicted=480.3311, Expected=489.0000
# Month=43, Predicted=479.7367, Expected=487.0000
# Month=44, Predicted=495.6060, Expected=508.0000
# Month=45, Predicted=534.1833, Expected=513.0000
# Month=46, Predicted=520.1081, Expected=555.0000
# Month=47, Predicted=599.8819, Expected=606.0000
# Month=48, Predicted=660.1050, Expected=676.0000
# Month=49, Predicted=742.3847, Expected=761.0000
# Month=50, Predicted=833.8720, Expected=837.0000
# Month=51, Predicted=897.7584, Expected=878.0000
# Month=52, Predicted=901.5040, Expected=890.0000
# Month=53, Predicted=879.7554, Expected=879.0000
# Month=54, Predicted=860.8449, Expected=847.0000
# Month=55, Predicted=806.4060, Expected=820.0000
# Month=56, Predicted=789.2145, Expected=790.0000
# Month=57, Predicted=764.8734, Expected=784.0000
# Month=58, Predicted=769.9060, Expected=752.0000
# Month=59, Predicted=713.1443, Expected=739.0000
# Month=60, Predicted=715.0838, Expected=684.0000
# Run 26 — RMSE: 19.704581, MSE: 388.270495, NMSE: 0.0002585134, sMAPE: 2.307376
#
# ===== RUN 27/2 =====
# Training complete for run 27
# Month=1, Predicted=669.5355, Expected=696.0000
# Month=2, Predicted=774.7085, Expected=765.0000
# Month=3, Predicted=818.0145, Expected=813.0000
# Month=4, Predicted=845.0379, Expected=851.0000
# Month=5, Predicted=879.7658, Expected=872.0000
# Month=6, Predicted=886.6539, Expected=883.0000
# Month=7, Predicted=897.1271, Expected=899.0000
# Month=8, Predicted=920.7748, Expected=897.0000
# Month=9, Predicted=895.0096, Expected=871.0000
# Month=10, Predicted=836.4803, Expected=831.0000
# Month=11, Predicted=794.4044, Expected=813.0000
# Month=12, Predicted=787.5187, Expected=749.0000
# Month=13, Predicted=674.8655, Expected=664.0000
# Month=14, Predicted=603.3357, Expected=550.0000
# Month=15, Predicted=481.1890, Expected=544.0000
# Month=16, Predicted=514.1502, Expected=505.0000
# Month=17, Predicted=474.0483, Expected=483.0000
# Month=18, Predicted=454.8261, Expected=469.0000
# Month=19, Predicted=463.1430, Expected=466.0000
# Month=20, Predicted=472.8054, Expected=487.0000
# Month=21, Predicted=508.8689, Expected=492.0000
# Month=22, Predicted=498.2408, Expected=531.0000
# Month=23, Predicted=571.4148, Expected=583.0000
# Month=24, Predicted=635.9640, Expected=659.0000
# Month=25, Predicted=732.5343, Expected=743.0000
# Month=26, Predicted=816.5829, Expected=811.0000
# Month=27, Predicted=863.1963, Expected=863.0000
# Month=28, Predicted=900.1958, Expected=898.0000
# Month=29, Predicted=920.9725, Expected=914.0000
# Month=30, Predicted=924.5953, Expected=920.0000
# Month=31, Predicted=929.8100, Expected=926.0000
# Month=32, Predicted=937.8306, Expected=919.0000
# Month=33, Predicted=913.4399, Expected=887.0000
# Month=34, Predicted=845.0391, Expected=862.0000
# Month=35, Predicted=834.6258, Expected=829.0000
# Month=36, Predicted=801.0263, Expected=769.0000
# Month=37, Predicted=724.2754, Expected=691.0000
# Month=38, Predicted=634.5789, Expected=618.0000
# Month=39, Predicted=564.5359, Expected=563.0000
# Month=40, Predicted=520.0384, Expected=529.0000
# Month=41, Predicted=497.5907, Expected=504.0000
# Month=42, Predicted=479.8322, Expected=489.0000
# Month=43, Predicted=479.0969, Expected=487.0000
# Month=44, Predicted=495.0272, Expected=508.0000
# Month=45, Predicted=530.3893, Expected=513.0000
# Month=46, Predicted=519.2049, Expected=555.0000
# Month=47, Predicted=598.6074, Expected=606.0000
# Month=48, Predicted=655.2563, Expected=676.0000
# Month=49, Predicted=742.7938, Expected=761.0000
# Month=50, Predicted=837.4313, Expected=837.0000
# Month=51, Predicted=898.5114, Expected=878.0000
# Month=52, Predicted=899.6303, Expected=890.0000
# Month=53, Predicted=890.5100, Expected=879.0000
# Month=54, Predicted=863.4689, Expected=847.0000
# Month=55, Predicted=807.6238, Expected=820.0000
# Month=56, Predicted=791.7217, Expected=790.0000
# Month=57, Predicted=764.7617, Expected=784.0000
# Month=58, Predicted=771.5017, Expected=752.0000
# Month=59, Predicted=712.1045, Expected=739.0000
# Month=60, Predicted=717.7432, Expected=684.0000
# Run 27 — RMSE: 19.989080, MSE: 399.563329, NMSE: 0.0002589548, sMAPE: 2.353714
#
# ===== RUN 28/2 =====
# Training complete for run 28
# Month=1, Predicted=676.3096, Expected=696.0000
# Month=2, Predicted=769.6302, Expected=765.0000
# Month=3, Predicted=811.7904, Expected=813.0000
# Month=4, Predicted=836.4706, Expected=851.0000
# Month=5, Predicted=877.3506, Expected=872.0000
# Month=6, Predicted=888.3011, Expected=883.0000
# Month=7, Predicted=894.1546, Expected=899.0000
# Month=8, Predicted=917.1941, Expected=897.0000
# Month=9, Predicted=894.6732, Expected=871.0000
# Month=10, Predicted=835.8124, Expected=831.0000
# Month=11, Predicted=790.8471, Expected=813.0000
# Month=12, Predicted=783.8970, Expected=749.0000
# Month=13, Predicted=683.9594, Expected=664.0000
# Month=14, Predicted=602.2057, Expected=550.0000
# Month=15, Predicted=508.9953, Expected=544.0000
# Month=16, Predicted=527.9484, Expected=505.0000
# Month=17, Predicted=490.0058, Expected=483.0000
# Month=18, Predicted=448.9717, Expected=469.0000
# Month=19, Predicted=464.4920, Expected=466.0000
# Month=20, Predicted=468.6630, Expected=487.0000
# Month=21, Predicted=504.0012, Expected=492.0000
# Month=22, Predicted=498.9562, Expected=531.0000
# Month=23, Predicted=565.0780, Expected=583.0000
# Month=24, Predicted=643.9209, Expected=659.0000
# Month=25, Predicted=736.8114, Expected=743.0000
# Month=26, Predicted=809.9483, Expected=811.0000
# Month=27, Predicted=854.3969, Expected=863.0000
# Month=28, Predicted=892.2691, Expected=898.0000
# Month=29, Predicted=919.6867, Expected=914.0000
# Month=30, Predicted=923.4146, Expected=920.0000
# Month=31, Predicted=926.2443, Expected=926.0000
# Month=32, Predicted=934.2572, Expected=919.0000
# Month=33, Predicted=911.4479, Expected=887.0000
# Month=34, Predicted=845.1792, Expected=862.0000
# Month=35, Predicted=832.9424, Expected=829.0000
# Month=36, Predicted=800.5212, Expected=769.0000
# Month=37, Predicted=719.3091, Expected=691.0000
# Month=38, Predicted=634.2138, Expected=618.0000
# Month=39, Predicted=572.1794, Expected=563.0000
# Month=40, Predicted=528.2787, Expected=529.0000
# Month=41, Predicted=501.6466, Expected=504.0000
# Month=42, Predicted=486.3148, Expected=489.0000
# Month=43, Predicted=480.8918, Expected=487.0000
# Month=44, Predicted=491.2768, Expected=508.0000
# Month=45, Predicted=525.6387, Expected=513.0000
# Month=46, Predicted=519.8979, Expected=555.0000
# Month=47, Predicted=592.0111, Expected=606.0000
# Month=48, Predicted=664.6960, Expected=676.0000
# Month=49, Predicted=748.0746, Expected=761.0000
# Month=50, Predicted=832.4533, Expected=837.0000
# Month=51, Predicted=888.4831, Expected=878.0000
# Month=52, Predicted=892.1182, Expected=890.0000
# Month=53, Predicted=880.1072, Expected=879.0000
# Month=54, Predicted=859.3400, Expected=847.0000
# Month=55, Predicted=807.1538, Expected=820.0000
# Month=56, Predicted=789.6047, Expected=790.0000
# Month=57, Predicted=764.4238, Expected=784.0000
# Month=58, Predicted=777.0172, Expected=752.0000
# Month=59, Predicted=713.3564, Expected=739.0000
# Month=60, Predicted=720.1299, Expected=684.0000
# Run 28 — RMSE: 18.205151, MSE: 331.427534, NMSE: 0.0002231893, sMAPE: 2.163862
#
# ===== RUN 29/2 =====
# Training complete for run 29
# Month=1, Predicted=673.7368, Expected=696.0000
# Month=2, Predicted=776.2067, Expected=765.0000
# Month=3, Predicted=812.7192, Expected=813.0000
# Month=4, Predicted=841.5969, Expected=851.0000
# Month=5, Predicted=874.8296, Expected=872.0000
# Month=6, Predicted=882.7992, Expected=883.0000
# Month=7, Predicted=896.8118, Expected=899.0000
# Month=8, Predicted=922.6527, Expected=897.0000
# Month=9, Predicted=898.3175, Expected=871.0000
# Month=10, Predicted=839.4711, Expected=831.0000
# Month=11, Predicted=791.6942, Expected=813.0000
# Month=12, Predicted=783.6732, Expected=749.0000
# Month=13, Predicted=675.2377, Expected=664.0000
# Month=14, Predicted=594.8784, Expected=550.0000
# Month=15, Predicted=478.6450, Expected=544.0000
# Month=16, Predicted=508.6432, Expected=505.0000
# Month=17, Predicted=487.8330, Expected=483.0000
# Month=18, Predicted=448.0814, Expected=469.0000
# Month=19, Predicted=464.5439, Expected=466.0000
# Month=20, Predicted=469.0918, Expected=487.0000
# Month=21, Predicted=508.3681, Expected=492.0000
# Month=22, Predicted=500.9177, Expected=531.0000
# Month=23, Predicted=570.8306, Expected=583.0000
# Month=24, Predicted=638.6215, Expected=659.0000
# Month=25, Predicted=736.2085, Expected=743.0000
# Month=26, Predicted=815.9101, Expected=811.0000
# Month=27, Predicted=856.7353, Expected=863.0000
# Month=28, Predicted=897.1031, Expected=898.0000
# Month=29, Predicted=916.9281, Expected=914.0000
# Month=30, Predicted=919.4745, Expected=920.0000
# Month=31, Predicted=931.0267, Expected=926.0000
# Month=32, Predicted=939.5174, Expected=919.0000
# Month=33, Predicted=916.3802, Expected=887.0000
# Month=34, Predicted=846.2943, Expected=862.0000
# Month=35, Predicted=831.8211, Expected=829.0000
# Month=36, Predicted=801.0045, Expected=769.0000
# Month=37, Predicted=727.3101, Expected=691.0000
# Month=38, Predicted=630.3450, Expected=618.0000
# Month=39, Predicted=564.5611, Expected=563.0000
# Month=40, Predicted=524.8469, Expected=529.0000
# Month=41, Predicted=500.5627, Expected=504.0000
# Month=42, Predicted=484.1045, Expected=489.0000
# Month=43, Predicted=478.8811, Expected=487.0000
# Month=44, Predicted=491.5657, Expected=508.0000
# Month=45, Predicted=530.3579, Expected=513.0000
# Month=46, Predicted=521.8530, Expected=555.0000
# Month=47, Predicted=597.8349, Expected=606.0000
# Month=48, Predicted=656.1853, Expected=676.0000
# Month=49, Predicted=745.3888, Expected=761.0000
# Month=50, Predicted=838.5704, Expected=837.0000
# Month=51, Predicted=892.3905, Expected=878.0000
# Month=52, Predicted=895.4101, Expected=890.0000
# Month=53, Predicted=882.0145, Expected=879.0000
# Month=54, Predicted=866.0679, Expected=847.0000
# Month=55, Predicted=806.4820, Expected=820.0000
# Month=56, Predicted=789.6915, Expected=790.0000
# Month=57, Predicted=765.4732, Expected=784.0000
# Month=58, Predicted=768.5653, Expected=752.0000
# Month=59, Predicted=717.8184, Expected=739.0000
# Month=60, Predicted=713.5590, Expected=684.0000
# Run 29 — RMSE: 19.238358, MSE: 370.114418, NMSE: 0.0002422760, sMAPE: 2.193818
#
# ===== RUN 30/2 =====
# Training complete for run 30
# Month=1, Predicted=671.8892, Expected=696.0000
# Month=2, Predicted=775.9111, Expected=765.0000
# Month=3, Predicted=816.0093, Expected=813.0000
# Month=4, Predicted=841.5109, Expected=851.0000
# Month=5, Predicted=878.2039, Expected=872.0000
# Month=6, Predicted=886.0871, Expected=883.0000
# Month=7, Predicted=897.5962, Expected=899.0000
# Month=8, Predicted=920.3040, Expected=897.0000
# Month=9, Predicted=896.0518, Expected=871.0000
# Month=10, Predicted=834.1387, Expected=831.0000
# Month=11, Predicted=795.2502, Expected=813.0000
# Month=12, Predicted=783.0765, Expected=749.0000
# Month=13, Predicted=672.7422, Expected=664.0000
# Month=14, Predicted=599.6096, Expected=550.0000
# Month=15, Predicted=482.9535, Expected=544.0000
# Month=16, Predicted=532.8089, Expected=505.0000
# Month=17, Predicted=494.2660, Expected=483.0000
# Month=18, Predicted=451.9517, Expected=469.0000
# Month=19, Predicted=465.2165, Expected=466.0000
# Month=20, Predicted=471.6605, Expected=487.0000
# Month=21, Predicted=507.4189, Expected=492.0000
# Month=22, Predicted=500.2567, Expected=531.0000
# Month=23, Predicted=569.6129, Expected=583.0000
# Month=24, Predicted=635.6732, Expected=659.0000
# Month=25, Predicted=734.4337, Expected=743.0000
# Month=26, Predicted=816.6683, Expected=811.0000
# Month=27, Predicted=860.1201, Expected=863.0000
# Month=28, Predicted=897.0625, Expected=898.0000
# Month=29, Predicted=919.8596, Expected=914.0000
# Month=30, Predicted=923.4564, Expected=920.0000
# Month=31, Predicted=929.9484, Expected=926.0000
# Month=32, Predicted=936.6505, Expected=919.0000
# Month=33, Predicted=912.3887, Expected=887.0000
# Month=34, Predicted=842.4631, Expected=862.0000
# Month=35, Predicted=834.8757, Expected=829.0000
# Month=36, Predicted=802.3032, Expected=769.0000
# Month=37, Predicted=723.9776, Expected=691.0000
# Month=38, Predicted=631.4881, Expected=618.0000
# Month=39, Predicted=568.5003, Expected=563.0000
# Month=40, Predicted=524.7791, Expected=529.0000
# Month=41, Predicted=495.9001, Expected=504.0000
# Month=42, Predicted=482.4969, Expected=489.0000
# Month=43, Predicted=480.2641, Expected=487.0000
# Month=44, Predicted=494.4439, Expected=508.0000
# Month=45, Predicted=529.0767, Expected=513.0000
# Month=46, Predicted=521.1871, Expected=555.0000
# Month=47, Predicted=596.7445, Expected=606.0000
# Month=48, Predicted=656.3612, Expected=676.0000
# Month=49, Predicted=744.3302, Expected=761.0000
# Month=50, Predicted=838.4276, Expected=837.0000
# Month=51, Predicted=895.8126, Expected=878.0000
# Month=52, Predicted=896.1925, Expected=890.0000
# Month=53, Predicted=887.5074, Expected=879.0000
# Month=54, Predicted=862.8263, Expected=847.0000
# Month=55, Predicted=805.2004, Expected=820.0000
# Month=56, Predicted=791.9740, Expected=790.0000
# Month=57, Predicted=765.8477, Expected=784.0000
# Month=58, Predicted=771.0054, Expected=752.0000
# Month=59, Predicted=711.6479, Expected=739.0000
# Month=60, Predicted=717.6838, Expected=684.0000
# Run 30 — RMSE: 19.597614, MSE: 384.066466, NMSE: 0.0002536386, sMAPE: 2.336780

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on M4 Hourly (30 runs) =====
# RMSE: 19.741860 ± 0.865490
# MSE:  390.490098 ± 34.714088
# NMSE: 0.0002570065 ± 0.0000223078
# sMAPE: 2.328285 ± 0.102306
#
# Best run: 28
#   RMSE: 18.205151
#   MSE:  331.427534
#   NMSE: 0.0002231893
#   sMAPE: 2.163862

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Hybrid (Feature Aug + Gate) — M4 Hourly\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Hybrid (Feature Aug + Gate) — M4 Hourly\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 18.205151
# MSE:  331.427534
# NMSE: 0.0002231893
# sMAPE: 2.163862

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on M4 Hourly
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
# Out:
# Total notebook execution time: 0h 49m 25.53s
# Total seconds: 2965.53
