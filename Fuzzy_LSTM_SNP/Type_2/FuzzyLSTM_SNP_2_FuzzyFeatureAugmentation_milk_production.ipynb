# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 361 (1.41 KB)
#  Trainable params: 361 (1.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (107, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (107, 1, 2), y_train shape: (107,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(2):
    print(f'\n===== RUN {run+1}/2 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    # Set consumption gate (c) bias to 1.0 (unit forget bias)
    rnn_layer = model.layers[1]
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, bias[units:2*units]
    weights[2] = bias
    cell.set_weights(weights)

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=761.2858, Expected=804.0000
# Month=2, Predicted=752.1213, Expected=756.0000
# Month=3, Predicted=865.0446, Expected=860.0000
# Month=4, Predicted=888.5226, Expected=878.0000
# Month=5, Predicted=948.4295, Expected=942.0000
# Month=6, Predicted=907.4264, Expected=913.0000
# Month=7, Predicted=855.4366, Expected=869.0000
# Month=8, Predicted=811.8088, Expected=834.0000
# Month=9, Predicted=794.8725, Expected=790.0000
# Month=10, Predicted=795.9461, Expected=800.0000
# Month=11, Predicted=783.8593, Expected=763.0000
# Month=12, Predicted=801.7396, Expected=800.0000
# Month=13, Predicted=813.8733, Expected=826.0000
# Month=14, Predicted=789.5065, Expected=799.0000
# Month=15, Predicted=878.7528, Expected=890.0000
# Month=16, Predicted=902.9805, Expected=900.0000
# Month=17, Predicted=962.4157, Expected=961.0000
# Month=18, Predicted=934.1636, Expected=935.0000
# Month=19, Predicted=896.5874, Expected=894.0000
# Month=20, Predicted=850.0648, Expected=855.0000
# Month=21, Predicted=827.8627, Expected=809.0000
# Month=22, Predicted=817.0481, Expected=810.0000
# Month=23, Predicted=792.8451, Expected=766.0000
# Month=24, Predicted=804.1022, Expected=805.0000
# Month=25, Predicted=805.5678, Expected=821.0000
# Month=26, Predicted=783.4844, Expected=773.0000
# Month=27, Predicted=883.3003, Expected=883.0000
# Month=28, Predicted=879.3932, Expected=898.0000
# Month=29, Predicted=969.2215, Expected=957.0000
# Month=30, Predicted=958.0780, Expected=924.0000
# Month=31, Predicted=899.7356, Expected=881.0000
# Month=32, Predicted=849.9645, Expected=837.0000
# Month=33, Predicted=813.9124, Expected=784.0000
# Month=34, Predicted=793.4918, Expected=791.0000
# Month=35, Predicted=767.8714, Expected=760.0000
# Month=36, Predicted=777.6636, Expected=802.0000
# Month=37, Predicted=808.4493, Expected=828.0000
# Month=38, Predicted=794.9086, Expected=778.0000
# Month=39, Predicted=894.9434, Expected=889.0000
# Month=40, Predicted=893.7645, Expected=902.0000
# Month=41, Predicted=978.1727, Expected=969.0000
# Month=42, Predicted=960.6247, Expected=947.0000
# Month=43, Predicted=910.0460, Expected=908.0000
# Month=44, Predicted=856.6554, Expected=867.0000
# Month=45, Predicted=836.8051, Expected=815.0000
# Month=46, Predicted=821.5014, Expected=812.0000
# Month=47, Predicted=792.0873, Expected=773.0000
# Month=48, Predicted=801.5934, Expected=813.0000
# Month=49, Predicted=811.4050, Expected=834.0000
# Month=50, Predicted=796.6451, Expected=782.0000
# Month=51, Predicted=901.0282, Expected=892.0000
# Month=52, Predicted=893.5205, Expected=903.0000
# Month=53, Predicted=974.7707, Expected=966.0000
# Month=54, Predicted=970.3352, Expected=937.0000
# Month=55, Predicted=917.8572, Expected=896.0000
# Month=56, Predicted=862.7287, Expected=858.0000
# Month=57, Predicted=831.3380, Expected=817.0000
# Month=58, Predicted=820.8031, Expected=827.0000
# Month=59, Predicted=807.3844, Expected=797.0000
# Month=60, Predicted=823.6490, Expected=843.0000
# Run 1 — RMSE: 15.458969, MSE: 238.979728, NMSE: 0.0010306241
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=767.0229, Expected=804.0000
# Month=2, Predicted=742.7345, Expected=756.0000
# Month=3, Predicted=854.9191, Expected=860.0000
# Month=4, Predicted=876.1076, Expected=878.0000
# Month=5, Predicted=963.5132, Expected=942.0000
# Month=6, Predicted=902.7587, Expected=913.0000
# Month=7, Predicted=847.0601, Expected=869.0000
# Month=8, Predicted=809.7131, Expected=834.0000
# Month=9, Predicted=791.7399, Expected=790.0000
# Month=10, Predicted=804.5297, Expected=800.0000
# Month=11, Predicted=768.8133, Expected=763.0000
# Month=12, Predicted=807.4197, Expected=800.0000
# Month=13, Predicted=818.9521, Expected=826.0000
# Month=14, Predicted=786.9572, Expected=799.0000
# Month=15, Predicted=873.0640, Expected=890.0000
# Month=16, Predicted=910.0823, Expected=900.0000
# Month=17, Predicted=958.9578, Expected=961.0000
# Month=18, Predicted=939.5863, Expected=935.0000
# Month=19, Predicted=896.4399, Expected=894.0000
# Month=20, Predicted=849.1187, Expected=855.0000
# Month=21, Predicted=825.8953, Expected=809.0000
# Month=22, Predicted=817.5372, Expected=810.0000
# Month=23, Predicted=778.0423, Expected=766.0000
# Month=24, Predicted=813.5081, Expected=805.0000
# Month=25, Predicted=816.4527, Expected=821.0000
# Month=26, Predicted=788.6148, Expected=773.0000
# Month=27, Predicted=878.7800, Expected=883.0000
# Month=28, Predicted=884.9959, Expected=898.0000
# Month=29, Predicted=956.6715, Expected=957.0000
# Month=30, Predicted=939.4788, Expected=924.0000
# Month=31, Predicted=902.7652, Expected=881.0000
# Month=32, Predicted=850.6431, Expected=837.0000
# Month=33, Predicted=816.7086, Expected=784.0000
# Month=34, Predicted=787.0311, Expected=791.0000
# Month=35, Predicted=749.8197, Expected=760.0000
# Month=36, Predicted=790.1448, Expected=802.0000
# Month=37, Predicted=814.5340, Expected=828.0000
# Month=38, Predicted=788.7685, Expected=778.0000
# Month=39, Predicted=888.6505, Expected=889.0000
# Month=40, Predicted=891.8702, Expected=902.0000
# Month=41, Predicted=979.2803, Expected=969.0000
# Month=42, Predicted=947.0553, Expected=947.0000
# Month=43, Predicted=910.7039, Expected=908.0000
# Month=44, Predicted=862.0379, Expected=867.0000
# Month=45, Predicted=831.9520, Expected=815.0000
# Month=46, Predicted=827.1052, Expected=812.0000
# Month=47, Predicted=773.8209, Expected=773.0000
# Month=48, Predicted=810.2022, Expected=813.0000
# Month=49, Predicted=821.2006, Expected=834.0000
# Month=50, Predicted=797.1204, Expected=782.0000
# Month=51, Predicted=895.5509, Expected=892.0000
# Month=52, Predicted=895.3502, Expected=903.0000
# Month=53, Predicted=968.3935, Expected=966.0000
# Month=54, Predicted=953.5610, Expected=937.0000
# Month=55, Predicted=923.6922, Expected=896.0000
# Month=56, Predicted=869.1161, Expected=858.0000
# Month=57, Predicted=835.8977, Expected=817.0000
# Month=58, Predicted=822.5806, Expected=827.0000
# Month=59, Predicted=797.3958, Expected=797.0000
# Month=60, Predicted=831.4205, Expected=843.0000
# Run 2 — RMSE: 13.178216, MSE: 173.665384, NMSE: 0.0007681146
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=762.2063, Expected=804.0000
# Month=2, Predicted=770.2742, Expected=756.0000
# Month=3, Predicted=874.1498, Expected=860.0000
# Month=4, Predicted=875.8262, Expected=878.0000
# Month=5, Predicted=931.5092, Expected=942.0000
# Month=6, Predicted=896.4533, Expected=913.0000
# Month=7, Predicted=842.6128, Expected=869.0000
# Month=8, Predicted=799.3100, Expected=834.0000
# Month=9, Predicted=797.3882, Expected=790.0000
# Month=10, Predicted=790.0775, Expected=800.0000
# Month=11, Predicted=782.2882, Expected=763.0000
# Month=12, Predicted=795.4356, Expected=800.0000
# Month=13, Predicted=814.6807, Expected=826.0000
# Month=14, Predicted=812.6675, Expected=799.0000
# Month=15, Predicted=877.4205, Expected=890.0000
# Month=16, Predicted=901.7224, Expected=900.0000
# Month=17, Predicted=951.0936, Expected=961.0000
# Month=18, Predicted=936.7266, Expected=935.0000
# Month=19, Predicted=904.3484, Expected=894.0000
# Month=20, Predicted=845.0599, Expected=855.0000
# Month=21, Predicted=834.1145, Expected=809.0000
# Month=22, Predicted=818.6564, Expected=810.0000
# Month=23, Predicted=793.4571, Expected=766.0000
# Month=24, Predicted=799.7043, Expected=805.0000
# Month=25, Predicted=810.6631, Expected=821.0000
# Month=26, Predicted=808.4558, Expected=773.0000
# Month=27, Predicted=871.8521, Expected=883.0000
# Month=28, Predicted=885.9769, Expected=898.0000
# Month=29, Predicted=962.3919, Expected=957.0000
# Month=30, Predicted=945.9081, Expected=924.0000
# Month=31, Predicted=898.3810, Expected=881.0000
# Month=32, Predicted=836.5615, Expected=837.0000
# Month=33, Predicted=822.4074, Expected=784.0000
# Month=34, Predicted=800.7032, Expected=791.0000
# Month=35, Predicted=768.4016, Expected=760.0000
# Month=36, Predicted=774.7096, Expected=802.0000
# Month=37, Predicted=806.7704, Expected=828.0000
# Month=38, Predicted=816.5149, Expected=778.0000
# Month=39, Predicted=886.7480, Expected=889.0000
# Month=40, Predicted=896.4604, Expected=902.0000
# Month=41, Predicted=969.2555, Expected=969.0000
# Month=42, Predicted=944.9058, Expected=947.0000
# Month=43, Predicted=899.0628, Expected=908.0000
# Month=44, Predicted=837.8766, Expected=867.0000
# Month=45, Predicted=833.4296, Expected=815.0000
# Month=46, Predicted=819.8875, Expected=812.0000
# Month=47, Predicted=794.1320, Expected=773.0000
# Month=48, Predicted=795.4811, Expected=813.0000
# Month=49, Predicted=814.7763, Expected=834.0000
# Month=50, Predicted=818.9899, Expected=782.0000
# Month=51, Predicted=890.8326, Expected=892.0000
# Month=52, Predicted=899.0093, Expected=903.0000
# Month=53, Predicted=973.0883, Expected=966.0000
# Month=54, Predicted=960.7554, Expected=937.0000
# Month=55, Predicted=921.3027, Expected=896.0000
# Month=56, Predicted=852.2022, Expected=858.0000
# Month=57, Predicted=839.7714, Expected=817.0000
# Month=58, Predicted=825.3474, Expected=827.0000
# Month=59, Predicted=810.4122, Expected=797.0000
# Month=60, Predicted=822.8709, Expected=843.0000
# Run 3 — RMSE: 18.390161, MSE: 338.198034, NMSE: 0.0016860158
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=774.4941, Expected=804.0000
# Month=2, Predicted=743.6426, Expected=756.0000
# Month=3, Predicted=854.9001, Expected=860.0000
# Month=4, Predicted=865.0072, Expected=878.0000
# Month=5, Predicted=933.6520, Expected=942.0000
# Month=6, Predicted=884.9783, Expected=913.0000
# Month=7, Predicted=835.7561, Expected=869.0000
# Month=8, Predicted=809.9912, Expected=834.0000
# Month=9, Predicted=796.4695, Expected=790.0000
# Month=10, Predicted=795.5060, Expected=800.0000
# Month=11, Predicted=772.1928, Expected=763.0000
# Month=12, Predicted=803.1562, Expected=800.0000
# Month=13, Predicted=824.7086, Expected=826.0000
# Month=14, Predicted=786.3888, Expected=799.0000
# Month=15, Predicted=867.3398, Expected=890.0000
# Month=16, Predicted=908.0563, Expected=900.0000
# Month=17, Predicted=955.7367, Expected=961.0000
# Month=18, Predicted=929.7103, Expected=935.0000
# Month=19, Predicted=881.5079, Expected=894.0000
# Month=20, Predicted=843.9611, Expected=855.0000
# Month=21, Predicted=824.1107, Expected=809.0000
# Month=22, Predicted=812.8271, Expected=810.0000
# Month=23, Predicted=782.9959, Expected=766.0000
# Month=24, Predicted=808.4717, Expected=805.0000
# Month=25, Predicted=827.0050, Expected=821.0000
# Month=26, Predicted=787.4051, Expected=773.0000
# Month=27, Predicted=861.6758, Expected=883.0000
# Month=28, Predicted=894.0617, Expected=898.0000
# Month=29, Predicted=965.3422, Expected=957.0000
# Month=30, Predicted=949.5202, Expected=924.0000
# Month=31, Predicted=888.5390, Expected=881.0000
# Month=32, Predicted=840.7896, Expected=837.0000
# Month=33, Predicted=808.4886, Expected=784.0000
# Month=34, Predicted=787.1925, Expected=791.0000
# Month=35, Predicted=758.3259, Expected=760.0000
# Month=36, Predicted=790.4974, Expected=802.0000
# Month=37, Predicted=822.7446, Expected=828.0000
# Month=38, Predicted=784.6278, Expected=778.0000
# Month=39, Predicted=882.7391, Expected=889.0000
# Month=40, Predicted=894.6443, Expected=902.0000
# Month=41, Predicted=975.9078, Expected=969.0000
# Month=42, Predicted=944.8971, Expected=947.0000
# Month=43, Predicted=893.4889, Expected=908.0000
# Month=44, Predicted=855.7532, Expected=867.0000
# Month=45, Predicted=830.7359, Expected=815.0000
# Month=46, Predicted=818.8886, Expected=812.0000
# Month=47, Predicted=778.8103, Expected=773.0000
# Month=48, Predicted=805.0259, Expected=813.0000
# Month=49, Predicted=832.2709, Expected=834.0000
# Month=50, Predicted=795.5471, Expected=782.0000
# Month=51, Predicted=878.4705, Expected=892.0000
# Month=52, Predicted=901.0559, Expected=903.0000
# Month=53, Predicted=974.6362, Expected=966.0000
# Month=54, Predicted=956.9531, Expected=937.0000
# Month=55, Predicted=900.6155, Expected=896.0000
# Month=56, Predicted=853.9199, Expected=858.0000
# Month=57, Predicted=827.2773, Expected=817.0000
# Month=58, Predicted=820.3745, Expected=827.0000
# Month=59, Predicted=800.3959, Expected=797.0000
# Month=60, Predicted=832.1211, Expected=843.0000
# Run 4 — RMSE: 12.836215, MSE: 164.768419, NMSE: 0.0007873839
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=773.6336, Expected=804.0000
# Month=2, Predicted=761.7488, Expected=756.0000
# Month=3, Predicted=846.6767, Expected=860.0000
# Month=4, Predicted=880.3887, Expected=878.0000
# Month=5, Predicted=943.0286, Expected=942.0000
# Month=6, Predicted=913.1810, Expected=913.0000
# Month=7, Predicted=879.7365, Expected=869.0000
# Month=8, Predicted=825.0031, Expected=834.0000
# Month=9, Predicted=807.7821, Expected=790.0000
# Month=10, Predicted=793.5416, Expected=800.0000
# Month=11, Predicted=787.9632, Expected=763.0000
# Month=12, Predicted=791.5996, Expected=800.0000
# Month=13, Predicted=828.5393, Expected=826.0000
# Month=14, Predicted=796.8718, Expected=799.0000
# Month=15, Predicted=869.9150, Expected=890.0000
# Month=16, Predicted=899.6136, Expected=900.0000
# Month=17, Predicted=947.6394, Expected=961.0000
# Month=18, Predicted=936.0009, Expected=935.0000
# Month=19, Predicted=903.1261, Expected=894.0000
# Month=20, Predicted=847.0721, Expected=855.0000
# Month=21, Predicted=828.3421, Expected=809.0000
# Month=22, Predicted=809.9644, Expected=810.0000
# Month=23, Predicted=796.8039, Expected=766.0000
# Month=24, Predicted=798.4537, Expected=805.0000
# Month=25, Predicted=829.5618, Expected=821.0000
# Month=26, Predicted=797.1493, Expected=773.0000
# Month=27, Predicted=874.1493, Expected=883.0000
# Month=28, Predicted=894.7928, Expected=898.0000
# Month=29, Predicted=975.9946, Expected=957.0000
# Month=30, Predicted=953.5889, Expected=924.0000
# Month=31, Predicted=908.2802, Expected=881.0000
# Month=32, Predicted=841.5260, Expected=837.0000
# Month=33, Predicted=810.5189, Expected=784.0000
# Month=34, Predicted=783.9074, Expected=791.0000
# Month=35, Predicted=771.5992, Expected=760.0000
# Month=36, Predicted=779.8141, Expected=802.0000
# Month=37, Predicted=827.1764, Expected=828.0000
# Month=38, Predicted=802.7238, Expected=778.0000
# Month=39, Predicted=874.7293, Expected=889.0000
# Month=40, Predicted=896.4131, Expected=902.0000
# Month=41, Predicted=983.0492, Expected=969.0000
# Month=42, Predicted=954.1300, Expected=947.0000
# Month=43, Predicted=925.6782, Expected=908.0000
# Month=44, Predicted=865.2691, Expected=867.0000
# Month=45, Predicted=840.1529, Expected=815.0000
# Month=46, Predicted=816.7047, Expected=812.0000
# Month=47, Predicted=797.0002, Expected=773.0000
# Month=48, Predicted=800.1799, Expected=813.0000
# Month=49, Predicted=835.4613, Expected=834.0000
# Month=50, Predicted=809.6485, Expected=782.0000
# Month=51, Predicted=888.4139, Expected=892.0000
# Month=52, Predicted=907.4808, Expected=903.0000
# Month=53, Predicted=985.7518, Expected=966.0000
# Month=54, Predicted=968.3819, Expected=937.0000
# Month=55, Predicted=929.2876, Expected=896.0000
# Month=56, Predicted=860.8965, Expected=858.0000
# Month=57, Predicted=830.5612, Expected=817.0000
# Month=58, Predicted=814.0874, Expected=827.0000
# Month=59, Predicted=811.9508, Expected=797.0000
# Month=60, Predicted=818.3217, Expected=843.0000
# Run 5 — RMSE: 16.278615, MSE: 264.993319, NMSE: 0.0011875735
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=775.0975, Expected=804.0000
# Month=2, Predicted=773.7632, Expected=756.0000
# Month=3, Predicted=822.6757, Expected=860.0000
# Month=4, Predicted=848.6267, Expected=878.0000
# Month=5, Predicted=933.7842, Expected=942.0000
# Month=6, Predicted=891.5874, Expected=913.0000
# Month=7, Predicted=849.8049, Expected=869.0000
# Month=8, Predicted=811.3863, Expected=834.0000
# Month=9, Predicted=804.2427, Expected=790.0000
# Month=10, Predicted=792.6788, Expected=800.0000
# Month=11, Predicted=785.4700, Expected=763.0000
# Month=12, Predicted=789.3073, Expected=800.0000
# Month=13, Predicted=822.4924, Expected=826.0000
# Month=14, Predicted=807.1816, Expected=799.0000
# Month=15, Predicted=846.9873, Expected=890.0000
# Month=16, Predicted=866.7060, Expected=900.0000
# Month=17, Predicted=933.5858, Expected=961.0000
# Month=18, Predicted=930.9644, Expected=935.0000
# Month=19, Predicted=896.2520, Expected=894.0000
# Month=20, Predicted=855.1763, Expected=855.0000
# Month=21, Predicted=820.8033, Expected=809.0000
# Month=22, Predicted=801.6958, Expected=810.0000
# Month=23, Predicted=792.1238, Expected=766.0000
# Month=24, Predicted=791.9751, Expected=805.0000
# Month=25, Predicted=835.2445, Expected=821.0000
# Month=26, Predicted=805.6905, Expected=773.0000
# Month=27, Predicted=856.5512, Expected=883.0000
# Month=28, Predicted=876.4769, Expected=898.0000
# Month=29, Predicted=961.0973, Expected=957.0000
# Month=30, Predicted=952.3226, Expected=924.0000
# Month=31, Predicted=882.1365, Expected=881.0000
# Month=32, Predicted=840.7518, Expected=837.0000
# Month=33, Predicted=801.7755, Expected=784.0000
# Month=34, Predicted=781.7817, Expected=791.0000
# Month=35, Predicted=778.9713, Expected=760.0000
# Month=36, Predicted=779.8299, Expected=802.0000
# Month=37, Predicted=838.7909, Expected=828.0000
# Month=38, Predicted=815.9652, Expected=778.0000
# Month=39, Predicted=861.4846, Expected=889.0000
# Month=40, Predicted=879.3422, Expected=902.0000
# Month=41, Predicted=970.8487, Expected=969.0000
# Month=42, Predicted=951.6435, Expected=947.0000
# Month=43, Predicted=894.4170, Expected=908.0000
# Month=44, Predicted=848.9662, Expected=867.0000
# Month=45, Predicted=834.5726, Expected=815.0000
# Month=46, Predicted=815.7631, Expected=812.0000
# Month=47, Predicted=793.7689, Expected=773.0000
# Month=48, Predicted=797.1558, Expected=813.0000
# Month=49, Predicted=842.1508, Expected=834.0000
# Month=50, Predicted=823.2643, Expected=782.0000
# Month=51, Predicted=869.7869, Expected=892.0000
# Month=52, Predicted=887.0443, Expected=903.0000
# Month=53, Predicted=971.7248, Expected=966.0000
# Month=54, Predicted=963.5787, Expected=937.0000
# Month=55, Predicted=897.3906, Expected=896.0000
# Month=56, Predicted=854.0018, Expected=858.0000
# Month=57, Predicted=821.8731, Expected=817.0000
# Month=58, Predicted=811.5138, Expected=827.0000
# Month=59, Predicted=810.3033, Expected=797.0000
# Month=60, Predicted=822.8223, Expected=843.0000
# Run 6 — RMSE: 19.851559, MSE: 394.084383, NMSE: 0.0021689626
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=768.3636, Expected=804.0000
# Month=2, Predicted=753.9019, Expected=756.0000
# Month=3, Predicted=851.6725, Expected=860.0000
# Month=4, Predicted=878.4082, Expected=878.0000
# Month=5, Predicted=955.6527, Expected=942.0000
# Month=6, Predicted=907.3834, Expected=913.0000
# Month=7, Predicted=859.1472, Expected=869.0000
# Month=8, Predicted=824.6927, Expected=834.0000
# Month=9, Predicted=804.0874, Expected=790.0000
# Month=10, Predicted=791.8298, Expected=800.0000
# Month=11, Predicted=777.8116, Expected=763.0000
# Month=12, Predicted=809.2155, Expected=800.0000
# Month=13, Predicted=820.7519, Expected=826.0000
# Month=14, Predicted=788.2903, Expected=799.0000
# Month=15, Predicted=874.4212, Expected=890.0000
# Month=16, Predicted=907.2956, Expected=900.0000
# Month=17, Predicted=950.1334, Expected=961.0000
# Month=18, Predicted=948.0919, Expected=935.0000
# Month=19, Predicted=899.3276, Expected=894.0000
# Month=20, Predicted=854.2104, Expected=855.0000
# Month=21, Predicted=828.7287, Expected=809.0000
# Month=22, Predicted=807.5469, Expected=810.0000
# Month=23, Predicted=787.4627, Expected=766.0000
# Month=24, Predicted=817.0130, Expected=805.0000
# Month=25, Predicted=820.3516, Expected=821.0000
# Month=26, Predicted=790.3274, Expected=773.0000
# Month=27, Predicted=879.4353, Expected=883.0000
# Month=28, Predicted=887.8839, Expected=898.0000
# Month=29, Predicted=963.7209, Expected=957.0000
# Month=30, Predicted=954.6598, Expected=924.0000
# Month=31, Predicted=897.0634, Expected=881.0000
# Month=32, Predicted=857.4520, Expected=837.0000
# Month=33, Predicted=819.1815, Expected=784.0000
# Month=34, Predicted=786.2726, Expected=791.0000
# Month=35, Predicted=763.1037, Expected=760.0000
# Month=36, Predicted=799.6388, Expected=802.0000
# Month=37, Predicted=820.2041, Expected=828.0000
# Month=38, Predicted=800.5345, Expected=778.0000
# Month=39, Predicted=883.1446, Expected=889.0000
# Month=40, Predicted=896.8154, Expected=902.0000
# Month=41, Predicted=984.9310, Expected=969.0000
# Month=42, Predicted=949.1564, Expected=947.0000
# Month=43, Predicted=907.0652, Expected=908.0000
# Month=44, Predicted=862.9058, Expected=867.0000
# Month=45, Predicted=837.9442, Expected=815.0000
# Month=46, Predicted=811.7978, Expected=812.0000
# Month=47, Predicted=784.2675, Expected=773.0000
# Month=48, Predicted=815.2779, Expected=813.0000
# Month=49, Predicted=824.7304, Expected=834.0000
# Month=50, Predicted=795.8989, Expected=782.0000
# Month=51, Predicted=895.2490, Expected=892.0000
# Month=52, Predicted=899.8052, Expected=903.0000
# Month=53, Predicted=971.7676, Expected=966.0000
# Month=54, Predicted=969.0952, Expected=937.0000
# Month=55, Predicted=919.7572, Expected=896.0000
# Month=56, Predicted=875.5912, Expected=858.0000
# Month=57, Predicted=839.2389, Expected=817.0000
# Month=58, Predicted=817.1125, Expected=827.0000
# Month=59, Predicted=810.0162, Expected=797.0000
# Month=60, Predicted=841.2277, Expected=843.0000
# Run 7 — RMSE: 14.136733, MSE: 199.847224, NMSE: 0.0009057469
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=774.9331, Expected=804.0000
# Month=2, Predicted=753.2299, Expected=756.0000
# Month=3, Predicted=866.6381, Expected=860.0000
# Month=4, Predicted=886.7658, Expected=878.0000
# Month=5, Predicted=949.1158, Expected=942.0000
# Month=6, Predicted=905.8995, Expected=913.0000
# Month=7, Predicted=857.3187, Expected=869.0000
# Month=8, Predicted=811.9278, Expected=834.0000
# Month=9, Predicted=797.6670, Expected=790.0000
# Month=10, Predicted=802.6084, Expected=800.0000
# Month=11, Predicted=781.7785, Expected=763.0000
# Month=12, Predicted=793.3438, Expected=800.0000
# Month=13, Predicted=825.3457, Expected=826.0000
# Month=14, Predicted=786.4831, Expected=799.0000
# Month=15, Predicted=879.4679, Expected=890.0000
# Month=16, Predicted=903.2507, Expected=900.0000
# Month=17, Predicted=949.5160, Expected=961.0000
# Month=18, Predicted=936.7552, Expected=935.0000
# Month=19, Predicted=887.4144, Expected=894.0000
# Month=20, Predicted=849.2687, Expected=855.0000
# Month=21, Predicted=828.1650, Expected=809.0000
# Month=22, Predicted=817.7307, Expected=810.0000
# Month=23, Predicted=790.8937, Expected=766.0000
# Month=24, Predicted=803.2141, Expected=805.0000
# Month=25, Predicted=826.5228, Expected=821.0000
# Month=26, Predicted=787.6176, Expected=773.0000
# Month=27, Predicted=878.3215, Expected=883.0000
# Month=28, Predicted=888.6105, Expected=898.0000
# Month=29, Predicted=981.3456, Expected=957.0000
# Month=30, Predicted=952.0484, Expected=924.0000
# Month=31, Predicted=883.3917, Expected=881.0000
# Month=32, Predicted=846.6379, Expected=837.0000
# Month=33, Predicted=815.6937, Expected=784.0000
# Month=34, Predicted=797.7874, Expected=791.0000
# Month=35, Predicted=766.9780, Expected=760.0000
# Month=36, Predicted=784.5366, Expected=802.0000
# Month=37, Predicted=829.2453, Expected=828.0000
# Month=38, Predicted=794.6840, Expected=778.0000
# Month=39, Predicted=886.7347, Expected=889.0000
# Month=40, Predicted=899.0145, Expected=902.0000
# Month=41, Predicted=997.1993, Expected=969.0000
# Month=42, Predicted=953.5171, Expected=947.0000
# Month=43, Predicted=902.5513, Expected=908.0000
# Month=44, Predicted=857.1354, Expected=867.0000
# Month=45, Predicted=837.9174, Expected=815.0000
# Month=46, Predicted=828.6813, Expected=812.0000
# Month=47, Predicted=788.4210, Expected=773.0000
# Month=48, Predicted=801.1394, Expected=813.0000
# Month=49, Predicted=832.1264, Expected=834.0000
# Month=50, Predicted=800.3391, Expected=782.0000
# Month=51, Predicted=893.1697, Expected=892.0000
# Month=52, Predicted=902.1493, Expected=903.0000
# Month=53, Predicted=990.5232, Expected=966.0000
# Month=54, Predicted=965.3252, Expected=937.0000
# Month=55, Predicted=902.5280, Expected=896.0000
# Month=56, Predicted=863.1387, Expected=858.0000
# Month=57, Predicted=833.2576, Expected=817.0000
# Month=58, Predicted=827.6636, Expected=827.0000
# Month=59, Predicted=811.4220, Expected=797.0000
# Month=60, Predicted=826.2947, Expected=843.0000
# Run 8 — RMSE: 14.109041, MSE: 199.065026, NMSE: 0.0008882498
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=775.5841, Expected=804.0000
# Month=2, Predicted=758.9496, Expected=756.0000
# Month=3, Predicted=869.7544, Expected=860.0000
# Month=4, Predicted=872.6248, Expected=878.0000
# Month=5, Predicted=953.0407, Expected=942.0000
# Month=6, Predicted=885.9470, Expected=913.0000
# Month=7, Predicted=856.0133, Expected=869.0000
# Month=8, Predicted=814.8301, Expected=834.0000
# Month=9, Predicted=810.0496, Expected=790.0000
# Month=10, Predicted=801.9429, Expected=800.0000
# Month=11, Predicted=783.7488, Expected=763.0000
# Month=12, Predicted=789.3901, Expected=800.0000
# Month=13, Predicted=825.5346, Expected=826.0000
# Month=14, Predicted=792.3273, Expected=799.0000
# Month=15, Predicted=888.3118, Expected=890.0000
# Month=16, Predicted=901.8547, Expected=900.0000
# Month=17, Predicted=949.3500, Expected=961.0000
# Month=18, Predicted=947.6362, Expected=935.0000
# Month=19, Predicted=903.5160, Expected=894.0000
# Month=20, Predicted=867.0949, Expected=855.0000
# Month=21, Predicted=831.1416, Expected=809.0000
# Month=22, Predicted=812.3474, Expected=810.0000
# Month=23, Predicted=792.7980, Expected=766.0000
# Month=24, Predicted=792.1952, Expected=805.0000
# Month=25, Predicted=826.5462, Expected=821.0000
# Month=26, Predicted=795.6224, Expected=773.0000
# Month=27, Predicted=881.8373, Expected=883.0000
# Month=28, Predicted=889.8395, Expected=898.0000
# Month=29, Predicted=975.8018, Expected=957.0000
# Month=30, Predicted=930.0804, Expected=924.0000
# Month=31, Predicted=871.3963, Expected=881.0000
# Month=32, Predicted=843.8269, Expected=837.0000
# Month=33, Predicted=814.7394, Expected=784.0000
# Month=34, Predicted=787.1963, Expected=791.0000
# Month=35, Predicted=770.8616, Expected=760.0000
# Month=36, Predicted=768.3563, Expected=802.0000
# Month=37, Predicted=830.6724, Expected=828.0000
# Month=38, Predicted=799.5822, Expected=778.0000
# Month=39, Predicted=887.0226, Expected=889.0000
# Month=40, Predicted=897.7051, Expected=902.0000
# Month=41, Predicted=989.9852, Expected=969.0000
# Month=42, Predicted=930.9418, Expected=947.0000
# Month=43, Predicted=890.5904, Expected=908.0000
# Month=44, Predicted=856.1228, Expected=867.0000
# Month=45, Predicted=841.9391, Expected=815.0000
# Month=46, Predicted=822.1727, Expected=812.0000
# Month=47, Predicted=789.7118, Expected=773.0000
# Month=48, Predicted=789.6373, Expected=813.0000
# Month=49, Predicted=830.8340, Expected=834.0000
# Month=50, Predicted=804.6032, Expected=782.0000
# Month=51, Predicted=895.5942, Expected=892.0000
# Month=52, Predicted=900.7740, Expected=903.0000
# Month=53, Predicted=984.8045, Expected=966.0000
# Month=54, Predicted=943.9508, Expected=937.0000
# Month=55, Predicted=889.5959, Expected=896.0000
# Month=56, Predicted=859.4929, Expected=858.0000
# Month=57, Predicted=833.2733, Expected=817.0000
# Month=58, Predicted=820.1709, Expected=827.0000
# Month=59, Predicted=808.7293, Expected=797.0000
# Month=60, Predicted=816.8931, Expected=843.0000
# Run 9 — RMSE: 15.260472, MSE: 232.882004, NMSE: 0.0011196964
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=764.4818, Expected=804.0000
# Month=2, Predicted=752.3701, Expected=756.0000
# Month=3, Predicted=868.2682, Expected=860.0000
# Month=4, Predicted=880.9896, Expected=878.0000
# Month=5, Predicted=938.7579, Expected=942.0000
# Month=6, Predicted=904.5655, Expected=913.0000
# Month=7, Predicted=853.1473, Expected=869.0000
# Month=8, Predicted=817.9296, Expected=834.0000
# Month=9, Predicted=800.6397, Expected=790.0000
# Month=10, Predicted=791.0703, Expected=800.0000
# Month=11, Predicted=781.1729, Expected=763.0000
# Month=12, Predicted=810.0987, Expected=800.0000
# Month=13, Predicted=813.2839, Expected=826.0000
# Month=14, Predicted=789.7524, Expected=799.0000
# Month=15, Predicted=865.9261, Expected=890.0000
# Month=16, Predicted=902.3534, Expected=900.0000
# Month=17, Predicted=964.5978, Expected=961.0000
# Month=18, Predicted=932.9444, Expected=935.0000
# Month=19, Predicted=884.2183, Expected=894.0000
# Month=20, Predicted=843.4791, Expected=855.0000
# Month=21, Predicted=824.7964, Expected=809.0000
# Month=22, Predicted=809.1161, Expected=810.0000
# Month=23, Predicted=791.4531, Expected=766.0000
# Month=24, Predicted=815.3464, Expected=805.0000
# Month=25, Predicted=817.0536, Expected=821.0000
# Month=26, Predicted=792.1170, Expected=773.0000
# Month=27, Predicted=866.8870, Expected=883.0000
# Month=28, Predicted=892.2079, Expected=898.0000
# Month=29, Predicted=970.9703, Expected=957.0000
# Month=30, Predicted=958.1487, Expected=924.0000
# Month=31, Predicted=908.1678, Expected=881.0000
# Month=32, Predicted=850.9898, Expected=837.0000
# Month=33, Predicted=816.5203, Expected=784.0000
# Month=34, Predicted=789.8369, Expected=791.0000
# Month=35, Predicted=773.0220, Expected=760.0000
# Month=36, Predicted=803.2444, Expected=802.0000
# Month=37, Predicted=816.5343, Expected=828.0000
# Month=38, Predicted=795.0556, Expected=778.0000
# Month=39, Predicted=887.0031, Expected=889.0000
# Month=40, Predicted=905.1869, Expected=902.0000
# Month=41, Predicted=979.1217, Expected=969.0000
# Month=42, Predicted=948.1611, Expected=947.0000
# Month=43, Predicted=904.8690, Expected=908.0000
# Month=44, Predicted=855.7197, Expected=867.0000
# Month=45, Predicted=836.4659, Expected=815.0000
# Month=46, Predicted=815.3203, Expected=812.0000
# Month=47, Predicted=790.6992, Expected=773.0000
# Month=48, Predicted=813.6098, Expected=813.0000
# Month=49, Predicted=824.5088, Expected=834.0000
# Month=50, Predicted=803.3692, Expected=782.0000
# Month=51, Predicted=886.4794, Expected=892.0000
# Month=52, Predicted=906.1254, Expected=903.0000
# Month=53, Predicted=977.6773, Expected=966.0000
# Month=54, Predicted=963.4909, Expected=937.0000
# Month=55, Predicted=922.1867, Expected=896.0000
# Month=56, Predicted=861.9133, Expected=858.0000
# Month=57, Predicted=833.3671, Expected=817.0000
# Month=58, Predicted=818.8288, Expected=827.0000
# Month=59, Predicted=814.0722, Expected=797.0000
# Month=60, Predicted=844.0059, Expected=843.0000
# Run 10 — RMSE: 14.925975, MSE: 222.784731, NMSE: 0.0010321647
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=770.0912, Expected=804.0000
# Month=2, Predicted=759.4798, Expected=756.0000
# Month=3, Predicted=884.8872, Expected=860.0000
# Month=4, Predicted=895.2850, Expected=878.0000
# Month=5, Predicted=954.0425, Expected=942.0000
# Month=6, Predicted=907.0284, Expected=913.0000
# Month=7, Predicted=846.2336, Expected=869.0000
# Month=8, Predicted=807.4258, Expected=834.0000
# Month=9, Predicted=777.0529, Expected=790.0000
# Month=10, Predicted=796.9104, Expected=800.0000
# Month=11, Predicted=780.7763, Expected=763.0000
# Month=12, Predicted=799.9653, Expected=800.0000
# Month=13, Predicted=819.5019, Expected=826.0000
# Month=14, Predicted=795.2786, Expected=799.0000
# Month=15, Predicted=889.6391, Expected=890.0000
# Month=16, Predicted=899.5930, Expected=900.0000
# Month=17, Predicted=966.2456, Expected=961.0000
# Month=18, Predicted=945.6978, Expected=935.0000
# Month=19, Predicted=898.9486, Expected=894.0000
# Month=20, Predicted=858.1968, Expected=855.0000
# Month=21, Predicted=817.8461, Expected=809.0000
# Month=22, Predicted=823.1008, Expected=810.0000
# Month=23, Predicted=792.8103, Expected=766.0000
# Month=24, Predicted=805.0328, Expected=805.0000
# Month=25, Predicted=818.1925, Expected=821.0000
# Month=26, Predicted=797.8517, Expected=773.0000
# Month=27, Predicted=883.2275, Expected=883.0000
# Month=28, Predicted=891.8326, Expected=898.0000
# Month=29, Predicted=976.8375, Expected=957.0000
# Month=30, Predicted=945.8522, Expected=924.0000
# Month=31, Predicted=892.3574, Expected=881.0000
# Month=32, Predicted=856.5689, Expected=837.0000
# Month=33, Predicted=812.5210, Expected=784.0000
# Month=34, Predicted=807.7458, Expected=791.0000
# Month=35, Predicted=765.5728, Expected=760.0000
# Month=36, Predicted=784.6445, Expected=802.0000
# Month=37, Predicted=816.9383, Expected=828.0000
# Month=38, Predicted=801.5728, Expected=778.0000
# Month=39, Predicted=895.7436, Expected=889.0000
# Month=40, Predicted=909.0328, Expected=902.0000
# Month=41, Predicted=990.3941, Expected=969.0000
# Month=42, Predicted=941.3146, Expected=947.0000
# Month=43, Predicted=894.9985, Expected=908.0000
# Month=44, Predicted=849.1308, Expected=867.0000
# Month=45, Predicted=813.3588, Expected=815.0000
# Month=46, Predicted=821.8163, Expected=812.0000
# Month=47, Predicted=791.0317, Expected=773.0000
# Month=48, Predicted=801.9216, Expected=813.0000
# Month=49, Predicted=817.9466, Expected=834.0000
# Month=50, Predicted=808.5879, Expected=782.0000
# Month=51, Predicted=898.8712, Expected=892.0000
# Month=52, Predicted=906.8912, Expected=903.0000
# Month=53, Predicted=986.2447, Expected=966.0000
# Month=54, Predicted=959.1080, Expected=937.0000
# Month=55, Predicted=912.1809, Expected=896.0000
# Month=56, Predicted=872.6634, Expected=858.0000
# Month=57, Predicted=829.1350, Expected=817.0000
# Month=58, Predicted=832.8872, Expected=827.0000
# Month=59, Predicted=810.6916, Expected=797.0000
# Month=60, Predicted=829.9880, Expected=843.0000
# Run 11 — RMSE: 15.216333, MSE: 231.536799, NMSE: 0.0010054427
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=767.1367, Expected=804.0000
# Month=2, Predicted=756.8838, Expected=756.0000
# Month=3, Predicted=860.4183, Expected=860.0000
# Month=4, Predicted=874.5581, Expected=878.0000
# Month=5, Predicted=937.4243, Expected=942.0000
# Month=6, Predicted=895.6871, Expected=913.0000
# Month=7, Predicted=848.9739, Expected=869.0000
# Month=8, Predicted=813.4532, Expected=834.0000
# Month=9, Predicted=789.2882, Expected=790.0000
# Month=10, Predicted=797.6342, Expected=800.0000
# Month=11, Predicted=783.0938, Expected=763.0000
# Month=12, Predicted=804.5366, Expected=800.0000
# Month=13, Predicted=817.9811, Expected=826.0000
# Month=14, Predicted=795.2672, Expected=799.0000
# Month=15, Predicted=868.8225, Expected=890.0000
# Month=16, Predicted=903.6021, Expected=900.0000
# Month=17, Predicted=956.9145, Expected=961.0000
# Month=18, Predicted=943.5269, Expected=935.0000
# Month=19, Predicted=899.2745, Expected=894.0000
# Month=20, Predicted=853.7004, Expected=855.0000
# Month=21, Predicted=821.9818, Expected=809.0000
# Month=22, Predicted=817.8278, Expected=810.0000
# Month=23, Predicted=793.1420, Expected=766.0000
# Month=24, Predicted=808.4796, Expected=805.0000
# Month=25, Predicted=823.0561, Expected=821.0000
# Month=26, Predicted=796.8747, Expected=773.0000
# Month=27, Predicted=868.8824, Expected=883.0000
# Month=28, Predicted=896.9730, Expected=898.0000
# Month=29, Predicted=969.8831, Expected=957.0000
# Month=30, Predicted=951.6661, Expected=924.0000
# Month=31, Predicted=896.6953, Expected=881.0000
# Month=32, Predicted=848.7668, Expected=837.0000
# Month=33, Predicted=812.4446, Expected=784.0000
# Month=34, Predicted=797.3756, Expected=791.0000
# Month=35, Predicted=771.1693, Expected=760.0000
# Month=36, Predicted=792.7888, Expected=802.0000
# Month=37, Predicted=817.7149, Expected=828.0000
# Month=38, Predicted=796.7948, Expected=778.0000
# Month=39, Predicted=883.6855, Expected=889.0000
# Month=40, Predicted=906.2263, Expected=902.0000
# Month=41, Predicted=978.4804, Expected=969.0000
# Month=42, Predicted=942.8765, Expected=947.0000
# Month=43, Predicted=899.2255, Expected=908.0000
# Month=44, Predicted=855.3365, Expected=867.0000
# Month=45, Predicted=823.9671, Expected=815.0000
# Month=46, Predicted=819.6507, Expected=812.0000
# Month=47, Predicted=790.5140, Expected=773.0000
# Month=48, Predicted=809.8862, Expected=813.0000
# Month=49, Predicted=828.3423, Expected=834.0000
# Month=50, Predicted=808.9957, Expected=782.0000
# Month=51, Predicted=880.4785, Expected=892.0000
# Month=52, Predicted=904.8935, Expected=903.0000
# Month=53, Predicted=973.5963, Expected=966.0000
# Month=54, Predicted=964.9196, Expected=937.0000
# Month=55, Predicted=913.4632, Expected=896.0000
# Month=56, Predicted=863.8044, Expected=858.0000
# Month=57, Predicted=829.4051, Expected=817.0000
# Month=58, Predicted=826.8231, Expected=827.0000
# Month=59, Predicted=810.3155, Expected=797.0000
# Month=60, Predicted=829.2665, Expected=843.0000
# Run 12 — RMSE: 13.908383, MSE: 193.443119, NMSE: 0.0009312701
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=766.7577, Expected=804.0000
# Month=2, Predicted=745.0776, Expected=756.0000
# Month=3, Predicted=855.0536, Expected=860.0000
# Month=4, Predicted=885.6755, Expected=878.0000
# Month=5, Predicted=956.6642, Expected=942.0000
# Month=6, Predicted=897.9290, Expected=913.0000
# Month=7, Predicted=852.6607, Expected=869.0000
# Month=8, Predicted=815.0188, Expected=834.0000
# Month=9, Predicted=798.6641, Expected=790.0000
# Month=10, Predicted=802.3061, Expected=800.0000
# Month=11, Predicted=778.5261, Expected=763.0000
# Month=12, Predicted=798.7998, Expected=800.0000
# Month=13, Predicted=817.4054, Expected=826.0000
# Month=14, Predicted=786.0055, Expected=799.0000
# Month=15, Predicted=872.9919, Expected=890.0000
# Month=16, Predicted=904.6999, Expected=900.0000
# Month=17, Predicted=963.2861, Expected=961.0000
# Month=18, Predicted=925.5760, Expected=935.0000
# Month=19, Predicted=881.4774, Expected=894.0000
# Month=20, Predicted=840.6939, Expected=855.0000
# Month=21, Predicted=824.0669, Expected=809.0000
# Month=22, Predicted=816.3747, Expected=810.0000
# Month=23, Predicted=787.5446, Expected=766.0000
# Month=24, Predicted=806.8895, Expected=805.0000
# Month=25, Predicted=813.5225, Expected=821.0000
# Month=26, Predicted=784.7297, Expected=773.0000
# Month=27, Predicted=876.2959, Expected=883.0000
# Month=28, Predicted=888.6251, Expected=898.0000
# Month=29, Predicted=962.5432, Expected=957.0000
# Month=30, Predicted=947.6136, Expected=924.0000
# Month=31, Predicted=898.4318, Expected=881.0000
# Month=32, Predicted=853.6764, Expected=837.0000
# Month=33, Predicted=809.5851, Expected=784.0000
# Month=34, Predicted=782.4154, Expected=791.0000
# Month=35, Predicted=763.2395, Expected=760.0000
# Month=36, Predicted=783.2643, Expected=802.0000
# Month=37, Predicted=816.7993, Expected=828.0000
# Month=38, Predicted=790.4655, Expected=778.0000
# Month=39, Predicted=884.7245, Expected=889.0000
# Month=40, Predicted=900.9682, Expected=902.0000
# Month=41, Predicted=980.2362, Expected=969.0000
# Month=42, Predicted=945.7887, Expected=947.0000
# Month=43, Predicted=904.9856, Expected=908.0000
# Month=44, Predicted=857.1895, Expected=867.0000
# Month=45, Predicted=833.2229, Expected=815.0000
# Month=46, Predicted=821.1852, Expected=812.0000
# Month=47, Predicted=784.5234, Expected=773.0000
# Month=48, Predicted=804.5404, Expected=813.0000
# Month=49, Predicted=819.9519, Expected=834.0000
# Month=50, Predicted=795.2130, Expected=782.0000
# Month=51, Predicted=891.4652, Expected=892.0000
# Month=52, Predicted=902.0745, Expected=903.0000
# Month=53, Predicted=971.5487, Expected=966.0000
# Month=54, Predicted=956.2382, Expected=937.0000
# Month=55, Predicted=914.1766, Expected=896.0000
# Month=56, Predicted=865.6990, Expected=858.0000
# Month=57, Predicted=828.2703, Expected=817.0000
# Month=58, Predicted=817.8211, Expected=827.0000
# Month=59, Predicted=804.7663, Expected=797.0000
# Month=60, Predicted=824.7528, Expected=843.0000
# Run 13 — RMSE: 13.061162, MSE: 170.593953, NMSE: 0.0007712287
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=768.3794, Expected=804.0000
# Month=2, Predicted=769.3036, Expected=756.0000
# Month=3, Predicted=869.2025, Expected=860.0000
# Month=4, Predicted=872.2530, Expected=878.0000
# Month=5, Predicted=936.8696, Expected=942.0000
# Month=6, Predicted=904.5180, Expected=913.0000
# Month=7, Predicted=846.4126, Expected=869.0000
# Month=8, Predicted=811.0803, Expected=834.0000
# Month=9, Predicted=806.8037, Expected=790.0000
# Month=10, Predicted=796.8742, Expected=800.0000
# Month=11, Predicted=781.8149, Expected=763.0000
# Month=12, Predicted=797.3376, Expected=800.0000
# Month=13, Predicted=820.9474, Expected=826.0000
# Month=14, Predicted=810.8826, Expected=799.0000
# Month=15, Predicted=879.3418, Expected=890.0000
# Month=16, Predicted=904.0180, Expected=900.0000
# Month=17, Predicted=954.4529, Expected=961.0000
# Month=18, Predicted=935.2485, Expected=935.0000
# Month=19, Predicted=904.7469, Expected=894.0000
# Month=20, Predicted=856.6979, Expected=855.0000
# Month=21, Predicted=837.7112, Expected=809.0000
# Month=22, Predicted=814.3494, Expected=810.0000
# Month=23, Predicted=792.7640, Expected=766.0000
# Month=24, Predicted=803.8681, Expected=805.0000
# Month=25, Predicted=824.5261, Expected=821.0000
# Month=26, Predicted=811.2332, Expected=773.0000
# Month=27, Predicted=873.7965, Expected=883.0000
# Month=28, Predicted=883.6818, Expected=898.0000
# Month=29, Predicted=965.0923, Expected=957.0000
# Month=30, Predicted=936.6287, Expected=924.0000
# Month=31, Predicted=877.2259, Expected=881.0000
# Month=32, Predicted=833.5181, Expected=837.0000
# Month=33, Predicted=815.0055, Expected=784.0000
# Month=34, Predicted=789.4098, Expected=791.0000
# Month=35, Predicted=767.8451, Expected=760.0000
# Month=36, Predicted=781.2889, Expected=802.0000
# Month=37, Predicted=815.9536, Expected=828.0000
# Month=38, Predicted=813.8689, Expected=778.0000
# Month=39, Predicted=885.3133, Expected=889.0000
# Month=40, Predicted=891.4033, Expected=902.0000
# Month=41, Predicted=971.7805, Expected=969.0000
# Month=42, Predicted=944.4633, Expected=947.0000
# Month=43, Predicted=899.0857, Expected=908.0000
# Month=44, Predicted=849.9092, Expected=867.0000
# Month=45, Predicted=840.8557, Expected=815.0000
# Month=46, Predicted=822.6372, Expected=812.0000
# Month=47, Predicted=792.9029, Expected=773.0000
# Month=48, Predicted=802.1328, Expected=813.0000
# Month=49, Predicted=827.7329, Expected=834.0000
# Month=50, Predicted=820.7457, Expected=782.0000
# Month=51, Predicted=891.3884, Expected=892.0000
# Month=52, Predicted=895.5773, Expected=903.0000
# Month=53, Predicted=973.2418, Expected=966.0000
# Month=54, Predicted=953.7652, Expected=937.0000
# Month=55, Predicted=905.8096, Expected=896.0000
# Month=56, Predicted=853.0022, Expected=858.0000
# Month=57, Predicted=834.5621, Expected=817.0000
# Month=58, Predicted=817.8209, Expected=827.0000
# Month=59, Predicted=806.6173, Expected=797.0000
# Month=60, Predicted=822.0897, Expected=843.0000
# Run 14 — RMSE: 15.838281, MSE: 250.851139, NMSE: 0.0013175951
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=760.4991, Expected=804.0000
# Month=2, Predicted=747.0369, Expected=756.0000
# Month=3, Predicted=864.9779, Expected=860.0000
# Month=4, Predicted=880.1999, Expected=878.0000
# Month=5, Predicted=955.2849, Expected=942.0000
# Month=6, Predicted=906.3965, Expected=913.0000
# Month=7, Predicted=850.0976, Expected=869.0000
# Month=8, Predicted=820.7296, Expected=834.0000
# Month=9, Predicted=799.2337, Expected=790.0000
# Month=10, Predicted=808.2849, Expected=800.0000
# Month=11, Predicted=780.8141, Expected=763.0000
# Month=12, Predicted=800.9559, Expected=800.0000
# Month=13, Predicted=815.1413, Expected=826.0000
# Month=14, Predicted=790.5157, Expected=799.0000
# Month=15, Predicted=871.7527, Expected=890.0000
# Month=16, Predicted=900.6481, Expected=900.0000
# Month=17, Predicted=956.7842, Expected=961.0000
# Month=18, Predicted=938.7260, Expected=935.0000
# Month=19, Predicted=898.8753, Expected=894.0000
# Month=20, Predicted=864.7032, Expected=855.0000
# Month=21, Predicted=841.2672, Expected=809.0000
# Month=22, Predicted=831.2591, Expected=810.0000
# Month=23, Predicted=790.2664, Expected=766.0000
# Month=24, Predicted=801.7142, Expected=805.0000
# Month=25, Predicted=804.6502, Expected=821.0000
# Month=26, Predicted=784.4125, Expected=773.0000
# Month=27, Predicted=874.1504, Expected=883.0000
# Month=28, Predicted=881.3411, Expected=898.0000
# Month=29, Predicted=966.9210, Expected=957.0000
# Month=30, Predicted=950.7246, Expected=924.0000
# Month=31, Predicted=889.3974, Expected=881.0000
# Month=32, Predicted=845.6050, Expected=837.0000
# Month=33, Predicted=814.7605, Expected=784.0000
# Month=34, Predicted=794.8910, Expected=791.0000
# Month=35, Predicted=751.8328, Expected=760.0000
# Month=36, Predicted=766.4424, Expected=802.0000
# Month=37, Predicted=802.4090, Expected=828.0000
# Month=38, Predicted=793.6690, Expected=778.0000
# Month=39, Predicted=886.4522, Expected=889.0000
# Month=40, Predicted=896.2655, Expected=902.0000
# Month=41, Predicted=983.7700, Expected=969.0000
# Month=42, Predicted=959.0981, Expected=947.0000
# Month=43, Predicted=904.7754, Expected=908.0000
# Month=44, Predicted=861.5098, Expected=867.0000
# Month=45, Predicted=833.5568, Expected=815.0000
# Month=46, Predicted=830.1475, Expected=812.0000
# Month=47, Predicted=783.7910, Expected=773.0000
# Month=48, Predicted=793.0976, Expected=813.0000
# Month=49, Predicted=806.2515, Expected=834.0000
# Month=50, Predicted=794.5920, Expected=782.0000
# Month=51, Predicted=891.9272, Expected=892.0000
# Month=52, Predicted=895.8396, Expected=903.0000
# Month=53, Predicted=980.1332, Expected=966.0000
# Month=54, Predicted=967.1972, Expected=937.0000
# Month=55, Predicted=913.6714, Expected=896.0000
# Month=56, Predicted=863.8532, Expected=858.0000
# Month=57, Predicted=834.8859, Expected=817.0000
# Month=58, Predicted=826.4009, Expected=827.0000
# Month=59, Predicted=800.7869, Expected=797.0000
# Month=60, Predicted=818.2830, Expected=843.0000
# Run 15 — RMSE: 16.284525, MSE: 265.185744, NMSE: 0.0011303888
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=773.4180, Expected=804.0000
# Month=2, Predicted=760.0141, Expected=756.0000
# Month=3, Predicted=849.1274, Expected=860.0000
# Month=4, Predicted=866.1030, Expected=878.0000
# Month=5, Predicted=930.0836, Expected=942.0000
# Month=6, Predicted=900.7400, Expected=913.0000
# Month=7, Predicted=860.8925, Expected=869.0000
# Month=8, Predicted=817.8344, Expected=834.0000
# Month=9, Predicted=806.0787, Expected=790.0000
# Month=10, Predicted=787.8240, Expected=800.0000
# Month=11, Predicted=772.8752, Expected=763.0000
# Month=12, Predicted=788.9089, Expected=800.0000
# Month=13, Predicted=816.2787, Expected=826.0000
# Month=14, Predicted=788.3687, Expected=799.0000
# Month=15, Predicted=854.8482, Expected=890.0000
# Month=16, Predicted=884.3093, Expected=900.0000
# Month=17, Predicted=936.3106, Expected=961.0000
# Month=18, Predicted=941.9885, Expected=935.0000
# Month=19, Predicted=916.2860, Expected=894.0000
# Month=20, Predicted=868.1557, Expected=855.0000
# Month=21, Predicted=827.8771, Expected=809.0000
# Month=22, Predicted=805.7585, Expected=810.0000
# Month=23, Predicted=786.4196, Expected=766.0000
# Month=24, Predicted=807.1579, Expected=805.0000
# Month=25, Predicted=829.8443, Expected=821.0000
# Month=26, Predicted=806.2052, Expected=773.0000
# Month=27, Predicted=863.2116, Expected=883.0000
# Month=28, Predicted=880.6818, Expected=898.0000
# Month=29, Predicted=973.9934, Expected=957.0000
# Month=30, Predicted=938.8490, Expected=924.0000
# Month=31, Predicted=879.8811, Expected=881.0000
# Month=32, Predicted=834.0885, Expected=837.0000
# Month=33, Predicted=813.5333, Expected=784.0000
# Month=34, Predicted=790.8393, Expected=791.0000
# Month=35, Predicted=768.1692, Expected=760.0000
# Month=36, Predicted=787.7943, Expected=802.0000
# Month=37, Predicted=827.4622, Expected=828.0000
# Month=38, Predicted=810.4511, Expected=778.0000
# Month=39, Predicted=870.2770, Expected=889.0000
# Month=40, Predicted=885.0896, Expected=902.0000
# Month=41, Predicted=977.7337, Expected=969.0000
# Month=42, Predicted=943.4098, Expected=947.0000
# Month=43, Predicted=901.8059, Expected=908.0000
# Month=44, Predicted=850.9353, Expected=867.0000
# Month=45, Predicted=840.4657, Expected=815.0000
# Month=46, Predicted=818.0901, Expected=812.0000
# Month=47, Predicted=786.3076, Expected=773.0000
# Month=48, Predicted=797.5370, Expected=813.0000
# Month=49, Predicted=823.6556, Expected=834.0000
# Month=50, Predicted=805.7334, Expected=782.0000
# Month=51, Predicted=874.0709, Expected=892.0000
# Month=52, Predicted=887.9725, Expected=903.0000
# Month=53, Predicted=966.4788, Expected=966.0000
# Month=54, Predicted=951.0296, Expected=937.0000
# Month=55, Predicted=906.5157, Expected=896.0000
# Month=56, Predicted=858.8454, Expected=858.0000
# Month=57, Predicted=829.4347, Expected=817.0000
# Month=58, Predicted=812.0198, Expected=827.0000
# Month=59, Predicted=805.1795, Expected=797.0000
# Month=60, Predicted=828.2248, Expected=843.0000
# Run 16 — RMSE: 15.901138, MSE: 252.846189, NMSE: 0.0013057356
#
# ===== RUN 17/30 =====
# ...
# Month=40, Predicted=873.3417, Expected=902.0000
# Month=41, Predicted=963.1381, Expected=969.0000
# Month=42, Predicted=957.3260, Expected=947.0000
# Month=43, Predicted=914.0407, Expected=908.0000
# Month=44, Predicted=860.3784, Expected=867.0000
# Month=45, Predicted=840.3149, Expected=815.0000
# Month=46, Predicted=814.4586, Expected=812.0000
# Month=47, Predicted=795.5301, Expected=773.0000
# Month=48, Predicted=795.3693, Expected=813.0000
# Month=49, Predicted=829.6751, Expected=834.0000
# Month=50, Predicted=821.0328, Expected=782.0000
# Month=51, Predicted=884.8097, Expected=892.0000
# Month=52, Predicted=880.8175, Expected=903.0000
# Month=53, Predicted=964.7789, Expected=966.0000
# Month=54, Predicted=963.1797, Expected=937.0000
# Month=55, Predicted=905.1048, Expected=896.0000
# Month=56, Predicted=849.3330, Expected=858.0000
# Month=57, Predicted=831.0686, Expected=817.0000
# Month=58, Predicted=814.9980, Expected=827.0000
# Month=59, Predicted=816.3394, Expected=797.0000
# Month=60, Predicted=816.6443, Expected=843.0000
# Run 25 — RMSE: 19.287450, MSE: 372.005730, NMSE: 0.0019947034
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=769.5881, Expected=804.0000
# Month=2, Predicted=755.2408, Expected=756.0000
# Month=3, Predicted=875.1263, Expected=860.0000
# Month=4, Predicted=882.4941, Expected=878.0000
# Month=5, Predicted=949.1609, Expected=942.0000
# Month=6, Predicted=909.3761, Expected=913.0000
# Month=7, Predicted=853.4119, Expected=869.0000
# Month=8, Predicted=818.0932, Expected=834.0000
# Month=9, Predicted=791.8401, Expected=790.0000
# Month=10, Predicted=795.2716, Expected=800.0000
# Month=11, Predicted=775.4503, Expected=763.0000
# Month=12, Predicted=806.4620, Expected=800.0000
# Month=13, Predicted=820.2103, Expected=826.0000
# Month=14, Predicted=802.9667, Expected=799.0000
# Month=15, Predicted=863.5057, Expected=890.0000
# Month=16, Predicted=899.6376, Expected=900.0000
# Month=17, Predicted=965.3601, Expected=961.0000
# Month=18, Predicted=945.0205, Expected=935.0000
# Month=19, Predicted=893.4332, Expected=894.0000
# Month=20, Predicted=844.3373, Expected=855.0000
# Month=21, Predicted=821.0072, Expected=809.0000
# Month=22, Predicted=817.9067, Expected=810.0000
# Month=23, Predicted=788.1471, Expected=766.0000
# Month=24, Predicted=817.1199, Expected=805.0000
# Month=25, Predicted=827.1813, Expected=821.0000
# Month=26, Predicted=807.6973, Expected=773.0000
# Month=27, Predicted=867.1938, Expected=883.0000
# Month=28, Predicted=877.8583, Expected=898.0000
# Month=29, Predicted=954.6596, Expected=957.0000
# Month=30, Predicted=942.6273, Expected=924.0000
# Month=31, Predicted=915.6650, Expected=881.0000
# Month=32, Predicted=856.3050, Expected=837.0000
# Month=33, Predicted=822.0143, Expected=784.0000
# Month=34, Predicted=806.5569, Expected=791.0000
# Month=35, Predicted=769.4593, Expected=760.0000
# Month=36, Predicted=797.1199, Expected=802.0000
# Month=37, Predicted=819.4071, Expected=828.0000
# Month=38, Predicted=802.7955, Expected=778.0000
# Month=39, Predicted=888.3315, Expected=889.0000
# Month=40, Predicted=895.4059, Expected=902.0000
# Month=41, Predicted=974.7849, Expected=969.0000
# Month=42, Predicted=948.3039, Expected=947.0000
# Month=43, Predicted=907.6067, Expected=908.0000
# Month=44, Predicted=857.1179, Expected=867.0000
# Month=45, Predicted=828.8236, Expected=815.0000
# Month=46, Predicted=819.4702, Expected=812.0000
# Month=47, Predicted=787.1347, Expected=773.0000
# Month=48, Predicted=813.1652, Expected=813.0000
# Month=49, Predicted=830.5704, Expected=834.0000
# Month=50, Predicted=814.6848, Expected=782.0000
# Month=51, Predicted=886.9360, Expected=892.0000
# Month=52, Predicted=890.0510, Expected=903.0000
# Month=53, Predicted=967.7910, Expected=966.0000
# Month=54, Predicted=954.8767, Expected=937.0000
# Month=55, Predicted=938.8337, Expected=896.0000
# Month=56, Predicted=872.2182, Expected=858.0000
# Month=57, Predicted=841.3828, Expected=817.0000
# Month=58, Predicted=834.2367, Expected=827.0000
# Month=59, Predicted=808.5018, Expected=797.0000
# Month=60, Predicted=834.3978, Expected=843.0000
# Run 26 — RMSE: 16.056603, MSE: 257.814489, NMSE: 0.0012685080
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=769.0882, Expected=804.0000
# Month=2, Predicted=756.1050, Expected=756.0000
# Month=3, Predicted=876.1122, Expected=860.0000
# Month=4, Predicted=883.0002, Expected=878.0000
# Month=5, Predicted=950.7129, Expected=942.0000
# Month=6, Predicted=897.1733, Expected=913.0000
# Month=7, Predicted=844.4495, Expected=869.0000
# Month=8, Predicted=803.4303, Expected=834.0000
# Month=9, Predicted=786.7668, Expected=790.0000
# Month=10, Predicted=807.1998, Expected=800.0000
# Month=11, Predicted=777.0023, Expected=763.0000
# Month=12, Predicted=803.7249, Expected=800.0000
# Month=13, Predicted=824.0656, Expected=826.0000
# Month=14, Predicted=797.0502, Expected=799.0000
# Month=15, Predicted=884.1900, Expected=890.0000
# Month=16, Predicted=901.2201, Expected=900.0000
# Month=17, Predicted=963.1294, Expected=961.0000
# Month=18, Predicted=936.6710, Expected=935.0000
# Month=19, Predicted=884.2467, Expected=894.0000
# Month=20, Predicted=844.9076, Expected=855.0000
# Month=21, Predicted=817.6644, Expected=809.0000
# Month=22, Predicted=825.1661, Expected=810.0000
# Month=23, Predicted=784.0840, Expected=766.0000
# Month=24, Predicted=804.4725, Expected=805.0000
# Month=25, Predicted=819.2300, Expected=821.0000
# Month=26, Predicted=795.7274, Expected=773.0000
# Month=27, Predicted=879.4101, Expected=883.0000
# Month=28, Predicted=895.1451, Expected=898.0000
# Month=29, Predicted=972.2969, Expected=957.0000
# Month=30, Predicted=940.9304, Expected=924.0000
# Month=31, Predicted=880.7681, Expected=881.0000
# Month=32, Predicted=851.4417, Expected=837.0000
# Month=33, Predicted=814.1723, Expected=784.0000
# Month=34, Predicted=804.5105, Expected=791.0000
# Month=35, Predicted=755.0971, Expected=760.0000
# Month=36, Predicted=782.6740, Expected=802.0000
# Month=37, Predicted=813.4952, Expected=828.0000
# Month=38, Predicted=795.4533, Expected=778.0000
# Month=39, Predicted=887.3651, Expected=889.0000
# Month=40, Predicted=905.2873, Expected=902.0000
# Month=41, Predicted=985.6832, Expected=969.0000
# Month=42, Predicted=945.5782, Expected=947.0000
# Month=43, Predicted=895.4494, Expected=908.0000
# Month=44, Predicted=857.9314, Expected=867.0000
# Month=45, Predicted=827.2535, Expected=815.0000
# Month=46, Predicted=833.4205, Expected=812.0000
# Month=47, Predicted=781.1683, Expected=773.0000
# Month=48, Predicted=802.6102, Expected=813.0000
# Month=49, Predicted=820.0564, Expected=834.0000
# Month=50, Predicted=806.7672, Expected=782.0000
# Month=51, Predicted=894.1439, Expected=892.0000
# Month=52, Predicted=910.0949, Expected=903.0000
# Month=53, Predicted=981.3846, Expected=966.0000
# Month=54, Predicted=953.6763, Expected=937.0000
# Month=55, Predicted=898.2722, Expected=896.0000
# Month=56, Predicted=864.5379, Expected=858.0000
# Month=57, Predicted=828.7751, Expected=817.0000
# Month=58, Predicted=834.3537, Expected=827.0000
# Month=59, Predicted=803.9424, Expected=797.0000
# Month=60, Predicted=826.6716, Expected=843.0000
# Run 27 — RMSE: 13.567395, MSE: 184.074205, NMSE: 0.0008441780
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=775.7016, Expected=804.0000
# Month=2, Predicted=760.7415, Expected=756.0000
# Month=3, Predicted=857.8003, Expected=860.0000
# Month=4, Predicted=889.7684, Expected=878.0000
# Month=5, Predicted=953.1651, Expected=942.0000
# Month=6, Predicted=892.8969, Expected=913.0000
# Month=7, Predicted=840.2439, Expected=869.0000
# Month=8, Predicted=797.7392, Expected=834.0000
# Month=9, Predicted=795.7942, Expected=790.0000
# Month=10, Predicted=803.8790, Expected=800.0000
# Month=11, Predicted=778.0074, Expected=763.0000
# Month=12, Predicted=797.5879, Expected=800.0000
# Month=13, Predicted=826.1514, Expected=826.0000
# Month=14, Predicted=794.7698, Expected=799.0000
# Month=15, Predicted=876.8259, Expected=890.0000
# Month=16, Predicted=903.6514, Expected=900.0000
# Month=17, Predicted=950.1998, Expected=961.0000
# Month=18, Predicted=950.7358, Expected=935.0000
# Month=19, Predicted=908.0537, Expected=894.0000
# Month=20, Predicted=858.3685, Expected=855.0000
# Month=21, Predicted=828.9091, Expected=809.0000
# Month=22, Predicted=815.3573, Expected=810.0000
# Month=23, Predicted=788.2560, Expected=766.0000
# Month=24, Predicted=801.7911, Expected=805.0000
# Month=25, Predicted=829.5766, Expected=821.0000
# Month=26, Predicted=795.5806, Expected=773.0000
# Month=27, Predicted=876.8134, Expected=883.0000
# Month=28, Predicted=887.0490, Expected=898.0000
# Month=29, Predicted=971.7670, Expected=957.0000
# Month=30, Predicted=947.5476, Expected=924.0000
# Month=31, Predicted=904.6272, Expected=881.0000
# Month=32, Predicted=859.7066, Expected=837.0000
# Month=33, Predicted=814.4019, Expected=784.0000
# Month=34, Predicted=786.9878, Expected=791.0000
# Month=35, Predicted=765.5166, Expected=760.0000
# Month=36, Predicted=782.1340, Expected=802.0000
# Month=37, Predicted=826.8119, Expected=828.0000
# Month=38, Predicted=800.4718, Expected=778.0000
# Month=39, Predicted=885.8078, Expected=889.0000
# Month=40, Predicted=898.3209, Expected=902.0000
# Month=41, Predicted=986.8971, Expected=969.0000
# Month=42, Predicted=946.4249, Expected=947.0000
# Month=43, Predicted=901.3074, Expected=908.0000
# Month=44, Predicted=853.6571, Expected=867.0000
# Month=45, Predicted=832.8702, Expected=815.0000
# Month=46, Predicted=819.3274, Expected=812.0000
# Month=47, Predicted=784.5032, Expected=773.0000
# Month=48, Predicted=800.3277, Expected=813.0000
# Month=49, Predicted=833.6860, Expected=834.0000
# Month=50, Predicted=807.2264, Expected=782.0000
# Month=51, Predicted=892.7584, Expected=892.0000
# Month=52, Predicted=900.2881, Expected=903.0000
# Month=53, Predicted=982.0016, Expected=966.0000
# Month=54, Predicted=961.6905, Expected=937.0000
# Month=55, Predicted=921.7598, Expected=896.0000
# Month=56, Predicted=875.5757, Expected=858.0000
# Month=57, Predicted=834.1189, Expected=817.0000
# Month=58, Predicted=821.4208, Expected=827.0000
# Month=59, Predicted=806.6781, Expected=797.0000
# Month=60, Predicted=824.8894, Expected=843.0000
# Run 28 — RMSE: 15.570727, MSE: 242.447532, NMSE: 0.0010884131
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=766.8733, Expected=804.0000
# Month=2, Predicted=794.5593, Expected=756.0000
# Month=3, Predicted=837.8445, Expected=860.0000
# Month=4, Predicted=876.5697, Expected=878.0000
# Month=5, Predicted=928.4256, Expected=942.0000
# Month=6, Predicted=900.4922, Expected=913.0000
# Month=7, Predicted=861.5720, Expected=869.0000
# Month=8, Predicted=801.4896, Expected=834.0000
# Month=9, Predicted=812.9695, Expected=790.0000
# Month=10, Predicted=784.0347, Expected=800.0000
# Month=11, Predicted=777.8326, Expected=763.0000
# Month=12, Predicted=781.9725, Expected=800.0000
# Month=13, Predicted=818.8419, Expected=826.0000
# Month=14, Predicted=831.9205, Expected=799.0000
# Month=15, Predicted=865.0390, Expected=890.0000
# Month=16, Predicted=904.7950, Expected=900.0000
# Month=17, Predicted=952.2489, Expected=961.0000
# Month=18, Predicted=952.4111, Expected=935.0000
# Month=19, Predicted=932.4707, Expected=894.0000
# Month=20, Predicted=868.9747, Expected=855.0000
# Month=21, Predicted=850.1495, Expected=809.0000
# Month=22, Predicted=813.7729, Expected=810.0000
# Month=23, Predicted=797.2281, Expected=766.0000
# Month=24, Predicted=796.8167, Expected=805.0000
# Month=25, Predicted=826.7682, Expected=821.0000
# Month=26, Predicted=836.4041, Expected=773.0000
# Month=27, Predicted=852.4563, Expected=883.0000
# Month=28, Predicted=889.2652, Expected=898.0000
# Month=29, Predicted=956.0739, Expected=957.0000
# Month=30, Predicted=922.0758, Expected=924.0000
# Month=31, Predicted=880.6925, Expected=881.0000
# Month=32, Predicted=819.2821, Expected=837.0000
# Month=33, Predicted=818.9197, Expected=784.0000
# Month=34, Predicted=781.8775, Expected=791.0000
# Month=35, Predicted=767.9640, Expected=760.0000
# Month=36, Predicted=773.2292, Expected=802.0000
# Month=37, Predicted=815.8043, Expected=828.0000
# Month=38, Predicted=833.7418, Expected=778.0000
# Month=39, Predicted=861.5388, Expected=889.0000
# Month=40, Predicted=899.9723, Expected=902.0000
# Month=41, Predicted=964.5825, Expected=969.0000
# Month=42, Predicted=946.4299, Expected=947.0000
# Month=43, Predicted=917.7410, Expected=908.0000
# Month=44, Predicted=845.6343, Expected=867.0000
# Month=45, Predicted=845.1264, Expected=815.0000
# Month=46, Predicted=812.7859, Expected=812.0000
# Month=47, Predicted=790.2986, Expected=773.0000
# Month=48, Predicted=788.1974, Expected=813.0000
# Month=49, Predicted=825.7055, Expected=834.0000
# Month=50, Predicted=841.5399, Expected=782.0000
# Month=51, Predicted=868.4421, Expected=892.0000
# Month=52, Predicted=906.5553, Expected=903.0000
# Month=53, Predicted=969.4152, Expected=966.0000
# Month=54, Predicted=953.9157, Expected=937.0000
# Month=55, Predicted=921.4065, Expected=896.0000
# Month=56, Predicted=852.1822, Expected=858.0000
# Month=57, Predicted=844.1083, Expected=817.0000
# Month=58, Predicted=813.2290, Expected=827.0000
# Month=59, Predicted=805.1064, Expected=797.0000
# Month=60, Predicted=809.8977, Expected=843.0000
# Run 29 — RMSE: 23.787804, MSE: 565.859639, NMSE: 0.0029000591
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=778.1221, Expected=804.0000
# Month=2, Predicted=750.5261, Expected=756.0000
# Month=3, Predicted=860.7317, Expected=860.0000
# Month=4, Predicted=873.6593, Expected=878.0000
# Month=5, Predicted=950.2400, Expected=942.0000
# Month=6, Predicted=901.7884, Expected=913.0000
# Month=7, Predicted=850.1702, Expected=869.0000
# Month=8, Predicted=808.4402, Expected=834.0000
# Month=9, Predicted=792.2677, Expected=790.0000
# Month=10, Predicted=791.8813, Expected=800.0000
# Month=11, Predicted=787.9470, Expected=763.0000
# Month=12, Predicted=784.4817, Expected=800.0000
# Month=13, Predicted=826.3055, Expected=826.0000
# Month=14, Predicted=774.8527, Expected=799.0000
# Month=15, Predicted=883.2220, Expected=890.0000
# Month=16, Predicted=894.5923, Expected=900.0000
# Month=17, Predicted=948.9641, Expected=961.0000
# Month=18, Predicted=945.1938, Expected=935.0000
# Month=19, Predicted=904.8203, Expected=894.0000
# Month=20, Predicted=861.0598, Expected=855.0000
# Month=21, Predicted=825.4495, Expected=809.0000
# Month=22, Predicted=818.2444, Expected=810.0000
# Month=23, Predicted=800.5719, Expected=766.0000
# Month=24, Predicted=798.1250, Expected=805.0000
# Month=25, Predicted=827.5112, Expected=821.0000
# Month=26, Predicted=775.6728, Expected=773.0000
# Month=27, Predicted=878.7703, Expected=883.0000
# Month=28, Predicted=886.5903, Expected=898.0000
# Month=29, Predicted=970.8795, Expected=957.0000
# Month=30, Predicted=945.8379, Expected=924.0000
# Month=31, Predicted=898.1658, Expected=881.0000
# Month=32, Predicted=859.4613, Expected=837.0000
# Month=33, Predicted=816.0418, Expected=784.0000
# Month=34, Predicted=800.8648, Expected=791.0000
# Month=35, Predicted=773.6305, Expected=760.0000
# Month=36, Predicted=778.1233, Expected=802.0000
# Month=37, Predicted=835.0072, Expected=828.0000
# Month=38, Predicted=793.9744, Expected=778.0000
# Month=39, Predicted=881.4214, Expected=889.0000
# Month=40, Predicted=896.7239, Expected=902.0000
# Month=41, Predicted=983.1773, Expected=969.0000
# Month=42, Predicted=943.1555, Expected=947.0000
# Month=43, Predicted=899.0751, Expected=908.0000
# Month=44, Predicted=850.2930, Expected=867.0000
# Month=45, Predicted=822.6729, Expected=815.0000
# Month=46, Predicted=812.0177, Expected=812.0000
# Month=47, Predicted=795.5909, Expected=773.0000
# Month=48, Predicted=790.0024, Expected=813.0000
# Month=49, Predicted=828.6613, Expected=834.0000
# Month=50, Predicted=783.8633, Expected=782.0000
# Month=51, Predicted=889.5192, Expected=892.0000
# Month=52, Predicted=897.0230, Expected=903.0000
# Month=53, Predicted=974.2401, Expected=966.0000
# Month=54, Predicted=961.8014, Expected=937.0000
# Month=55, Predicted=920.1288, Expected=896.0000
# Month=56, Predicted=879.8686, Expected=858.0000
# Month=57, Predicted=836.8942, Expected=817.0000
# Month=58, Predicted=833.3945, Expected=827.0000
# Month=59, Predicted=824.8193, Expected=797.0000
# Month=60, Predicted=829.4786, Expected=843.0000
# Run 30 — RMSE: 15.446579, MSE: 238.596793, NMSE: 0.0010851774

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (2 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Milk Production (2 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Milk Production (30 runs) =====
# RMSE: 15.679812 ± 2.562816
# MSE:  252.424521 ± 89.072430
# NMSE: 0.0012159658 ± 0.0005057978
#
# Best run: 18
#   RMSE: 12.344528
#   MSE:  152.387380
#   NMSE: 0.0006991263

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Feature Augmentation — Monthly Milk Production\nPredictions vs Actual (Best of 2 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Feature Augmentation — Monthly Milk Production\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 12.344528
# MSE:  152.387380
# NMSE: 0.0006991263

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
