# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: S&P 500
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 361 (1.41 KB)
#  Trainable params: 361 (1.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — S&P 500

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/sp500.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (251,)
# First 5 values: [2038.199951 2013.780029 2011.709961 1985.319946 1945.969971]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (250, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (190, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (190, 1, 2), y_train shape: (190,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(2):
    print(f'\n===== RUN {run+1}/2 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    # Set consumption gate (c) bias to 1.0 (unit forget bias)
    rnn_layer = model.layers[1]
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, bias[units:2*units]
    weights[2] = bias
    cell.set_weights(weights)

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=2155.4779, Expected=2158.2200
# Month=2, Predicted=2159.2622, Expected=2164.1899
# Month=3, Predicted=2163.3650, Expected=2160.3899
# Month=4, Predicted=2159.2301, Expected=2161.3501
# Month=5, Predicted=2161.9809, Expected=2137.6699
# Month=6, Predicted=2137.7551, Expected=2130.2600
# Month=7, Predicted=2133.9865, Expected=2139.6799
# Month=8, Predicted=2139.2432, Expected=2132.9500
# Month=9, Predicted=2130.3650, Expected=2138.3101
# Month=10, Predicted=2138.9143, Expected=2140.8101
# Month=11, Predicted=2141.4355, Expected=2142.5100
# Month=12, Predicted=2143.3774, Expected=2139.4299
# Month=13, Predicted=2140.2546, Expected=2148.5000
# Month=14, Predicted=2149.2486, Expected=2149.7200
# Month=15, Predicted=2148.7555, Expected=2136.9700
# Month=16, Predicted=2136.7026, Expected=2144.0601
# Month=17, Predicted=2145.8055, Expected=2132.2300
# Month=18, Predicted=2131.0453, Expected=2129.7800
# Month=19, Predicted=2130.7208, Expected=2128.6799
# Month=20, Predicted=2128.4626, Expected=2109.4299
# Month=21, Predicted=2108.7379, Expected=2098.8000
# Month=22, Predicted=2101.1902, Expected=2083.7900
# Month=23, Predicted=2084.0557, Expected=2100.5901
# Month=24, Predicted=2100.6893, Expected=2129.9199
# Month=25, Predicted=2129.0685, Expected=2131.5601
# Month=26, Predicted=2132.2692, Expected=2167.4900
# Month=27, Predicted=2172.2610, Expected=2162.7100
# Month=28, Predicted=2164.6554, Expected=2165.6399
# Month=29, Predicted=2170.2840, Expected=2168.2900
# Month=30, Predicted=2169.3132, Expected=2177.5300
# Month=31, Predicted=2175.7233, Expected=2178.6101
# Month=32, Predicted=2175.6529, Expected=2186.8501
# Month=33, Predicted=2185.8127, Expected=2186.4299
# Month=34, Predicted=2185.8989, Expected=2201.5601
# Month=35, Predicted=2202.5176, Expected=2198.5500
# Month=36, Predicted=2198.5069, Expected=2206.2700
# Month=37, Predicted=2208.0431, Expected=2210.2100
# Month=38, Predicted=2210.3886, Expected=2200.7600
# Month=39, Predicted=2200.4090, Expected=2204.9700
# Month=40, Predicted=2206.1067, Expected=2200.1699
# Month=41, Predicted=2199.0337, Expected=2191.1201
# Month=42, Predicted=2190.7224, Expected=2200.6499
# Month=43, Predicted=2201.0742, Expected=2207.2600
# Month=44, Predicted=2206.2664, Expected=2210.7200
# Month=45, Predicted=2210.7017, Expected=2241.1299
# Month=46, Predicted=2242.5085, Expected=2249.7300
# Month=47, Predicted=2250.1195, Expected=2258.8301
# Month=48, Predicted=2261.2204, Expected=2263.3201
# Month=49, Predicted=2264.9097, Expected=2268.3501
# Month=50, Predicted=2268.6863, Expected=2253.7700
# Month=51, Predicted=2252.6740, Expected=2266.8101
# Month=52, Predicted=2268.0467, Expected=2259.2400
# Month=53, Predicted=2256.9128, Expected=2266.5000
# Month=54, Predicted=2266.8144, Expected=2270.5400
# Month=55, Predicted=2270.4310, Expected=2262.9299
# Month=56, Predicted=2263.2415, Expected=2260.2500
# Month=57, Predicted=2262.1089, Expected=2266.2300
# Month=58, Predicted=2266.6294, Expected=2270.2300
# Month=59, Predicted=2269.0492, Expected=2249.5000
# Month=60, Predicted=2248.6975, Expected=2251.6101
# Run 1 — RMSE: 11.247843, MSE: 126.513972, NMSE: 0.0007671237
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=2155.7911, Expected=2158.2200
# Month=2, Predicted=2159.2620, Expected=2164.1899
# Month=3, Predicted=2163.6710, Expected=2160.3899
# Month=4, Predicted=2160.0886, Expected=2161.3501
# Month=5, Predicted=2162.1573, Expected=2137.6699
# Month=6, Predicted=2137.4908, Expected=2130.2600
# Month=7, Predicted=2134.0967, Expected=2139.6799
# Month=8, Predicted=2139.6909, Expected=2132.9500
# Month=9, Predicted=2132.0569, Expected=2138.3101
# Month=10, Predicted=2139.5367, Expected=2140.8101
# Month=11, Predicted=2140.0555, Expected=2142.5100
# Month=12, Predicted=2142.5053, Expected=2139.4299
# Month=13, Predicted=2139.4151, Expected=2148.5000
# Month=14, Predicted=2148.9963, Expected=2149.7200
# Month=15, Predicted=2148.9634, Expected=2136.9700
# Month=16, Predicted=2137.5403, Expected=2144.0601
# Month=17, Predicted=2146.0114, Expected=2132.2300
# Month=18, Predicted=2131.2468, Expected=2129.7800
# Month=19, Predicted=2131.9210, Expected=2128.6799
# Month=20, Predicted=2128.6029, Expected=2109.4299
# Month=21, Predicted=2109.5129, Expected=2098.8000
# Month=22, Predicted=2101.4343, Expected=2083.7900
# Month=23, Predicted=2084.2323, Expected=2100.5901
# Month=24, Predicted=2101.8837, Expected=2129.9199
# Month=25, Predicted=2128.9458, Expected=2131.5601
# Month=26, Predicted=2130.9768, Expected=2167.4900
# Month=27, Predicted=2169.4084, Expected=2162.7100
# Month=28, Predicted=2161.0205, Expected=2165.6399
# Month=29, Predicted=2169.5252, Expected=2168.2900
# Month=30, Predicted=2168.7583, Expected=2177.5300
# Month=31, Predicted=2178.2596, Expected=2178.6101
# Month=32, Predicted=2178.5524, Expected=2186.8501
# Month=33, Predicted=2187.7787, Expected=2186.4299
# Month=34, Predicted=2186.0882, Expected=2201.5601
# Month=35, Predicted=2202.3437, Expected=2198.5500
# Month=36, Predicted=2197.5069, Expected=2206.2700
# Month=37, Predicted=2207.7842, Expected=2210.2100
# Month=38, Predicted=2209.6832, Expected=2200.7600
# Month=39, Predicted=2201.0632, Expected=2204.9700
# Month=40, Predicted=2206.7027, Expected=2200.1699
# Month=41, Predicted=2199.6137, Expected=2191.1201
# Month=42, Predicted=2192.1315, Expected=2200.6499
# Month=43, Predicted=2201.6164, Expected=2207.2600
# Month=44, Predicted=2206.2631, Expected=2210.7200
# Month=45, Predicted=2210.7037, Expected=2241.1299
# Month=46, Predicted=2241.3412, Expected=2249.7300
# Month=47, Predicted=2248.3949, Expected=2258.8301
# Month=48, Predicted=2260.3181, Expected=2263.3201
# Month=49, Predicted=2263.6054, Expected=2268.3501
# Month=50, Predicted=2269.1018, Expected=2253.7700
# Month=51, Predicted=2254.2401, Expected=2266.8101
# Month=52, Predicted=2269.9503, Expected=2259.2400
# Month=53, Predicted=2258.0040, Expected=2266.5000
# Month=54, Predicted=2268.5964, Expected=2270.5400
# Month=55, Predicted=2269.8742, Expected=2262.9299
# Month=56, Predicted=2263.0234, Expected=2260.2500
# Month=57, Predicted=2261.4547, Expected=2266.2300
# Month=58, Predicted=2266.2317, Expected=2270.2300
# Month=59, Predicted=2269.6890, Expected=2249.5000
# Month=60, Predicted=2249.4782, Expected=2251.6101
# Run 2 — RMSE: 11.254356, MSE: 126.660521, NMSE: 0.0007684670
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=2155.3324, Expected=2158.2200
# Month=2, Predicted=2159.1476, Expected=2164.1899
# Month=3, Predicted=2163.5701, Expected=2160.3899
# Month=4, Predicted=2159.4766, Expected=2161.3501
# Month=5, Predicted=2161.7830, Expected=2137.6699
# Month=6, Predicted=2137.0215, Expected=2130.2600
# Month=7, Predicted=2133.5104, Expected=2139.6799
# Month=8, Predicted=2139.1636, Expected=2132.9500
# Month=9, Predicted=2131.1576, Expected=2138.3101
# Month=10, Predicted=2139.0181, Expected=2140.8101
# Month=11, Predicted=2140.3127, Expected=2142.5100
# Month=12, Predicted=2142.2381, Expected=2139.4299
# Month=13, Predicted=2139.3128, Expected=2148.5000
# Month=14, Predicted=2148.8208, Expected=2149.7200
# Month=15, Predicted=2148.8670, Expected=2136.9700
# Month=16, Predicted=2136.9769, Expected=2144.0601
# Month=17, Predicted=2145.7815, Expected=2132.2300
# Month=18, Predicted=2131.2088, Expected=2129.7800
# Month=19, Predicted=2131.2366, Expected=2128.6799
# Month=20, Predicted=2128.4708, Expected=2109.4299
# Month=21, Predicted=2108.7813, Expected=2098.8000
# Month=22, Predicted=2101.0460, Expected=2083.7900
# Month=23, Predicted=2083.6140, Expected=2100.5901
# Month=24, Predicted=2100.8912, Expected=2129.9199
# Month=25, Predicted=2129.2055, Expected=2131.5601
# Month=26, Predicted=2130.0075, Expected=2167.4900
# Month=27, Predicted=2169.7339, Expected=2162.7100
# Month=28, Predicted=2161.8444, Expected=2165.6399
# Month=29, Predicted=2169.8954, Expected=2168.2900
# Month=30, Predicted=2169.5659, Expected=2177.5300
# Month=31, Predicted=2177.9322, Expected=2178.6101
# Month=32, Predicted=2178.2380, Expected=2186.8501
# Month=33, Predicted=2187.4648, Expected=2186.4299
# Month=34, Predicted=2186.0010, Expected=2201.5601
# Month=35, Predicted=2202.0043, Expected=2198.5500
# Month=36, Predicted=2197.3654, Expected=2206.2700
# Month=37, Predicted=2207.3250, Expected=2210.2100
# Month=38, Predicted=2209.6773, Expected=2200.7600
# Month=39, Predicted=2200.3017, Expected=2204.9700
# Month=40, Predicted=2206.1210, Expected=2200.1699
# Month=41, Predicted=2199.2694, Expected=2191.1201
# Month=42, Predicted=2191.0905, Expected=2200.6499
# Month=43, Predicted=2200.9472, Expected=2207.2600
# Month=44, Predicted=2206.0305, Expected=2210.7200
# Month=45, Predicted=2209.9255, Expected=2241.1299
# Month=46, Predicted=2241.1152, Expected=2249.7300
# Month=47, Predicted=2248.2815, Expected=2258.8301
# Month=48, Predicted=2259.7324, Expected=2263.3201
# Month=49, Predicted=2263.6788, Expected=2268.3501
# Month=50, Predicted=2268.6290, Expected=2253.7700
# Month=51, Predicted=2253.4699, Expected=2266.8101
# Month=52, Predicted=2269.0806, Expected=2259.2400
# Month=53, Predicted=2258.0928, Expected=2266.5000
# Month=54, Predicted=2267.7816, Expected=2270.5400
# Month=55, Predicted=2270.0886, Expected=2262.9299
# Month=56, Predicted=2262.5908, Expected=2260.2500
# Month=57, Predicted=2261.3738, Expected=2266.2300
# Month=58, Predicted=2266.1588, Expected=2270.2300
# Month=59, Predicted=2269.2859, Expected=2249.5000
# Month=60, Predicted=2248.8173, Expected=2251.6101
# Run 3 — RMSE: 11.369622, MSE: 129.268310, NMSE: 0.0007837406
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=2155.8165, Expected=2158.2200
# Month=2, Predicted=2159.4317, Expected=2164.1899
# Month=3, Predicted=2163.7209, Expected=2160.3899
# Month=4, Predicted=2160.0413, Expected=2161.3501
# Month=5, Predicted=2162.4914, Expected=2137.6699
# Month=6, Predicted=2137.3964, Expected=2130.2600
# Month=7, Predicted=2133.8999, Expected=2139.6799
# Month=8, Predicted=2139.2063, Expected=2132.9500
# Month=9, Predicted=2131.6908, Expected=2138.3101
# Month=10, Predicted=2140.1128, Expected=2140.8101
# Month=11, Predicted=2140.6805, Expected=2142.5100
# Month=12, Predicted=2143.0043, Expected=2139.4299
# Month=13, Predicted=2139.8321, Expected=2148.5000
# Month=14, Predicted=2149.3031, Expected=2149.7200
# Month=15, Predicted=2148.9781, Expected=2136.9700
# Month=16, Predicted=2137.4859, Expected=2144.0601
# Month=17, Predicted=2146.0835, Expected=2132.2300
# Month=18, Predicted=2130.9473, Expected=2129.7800
# Month=19, Predicted=2131.8077, Expected=2128.6799
# Month=20, Predicted=2128.5230, Expected=2109.4299
# Month=21, Predicted=2109.2847, Expected=2098.8000
# Month=22, Predicted=2101.4949, Expected=2083.7900
# Month=23, Predicted=2083.7858, Expected=2100.5901
# Month=24, Predicted=2101.5496, Expected=2129.9199
# Month=25, Predicted=2129.5096, Expected=2131.5601
# Month=26, Predicted=2130.5539, Expected=2167.4900
# Month=27, Predicted=2170.6338, Expected=2162.7100
# Month=28, Predicted=2160.8913, Expected=2165.6399
# Month=29, Predicted=2169.7970, Expected=2168.2900
# Month=30, Predicted=2168.4104, Expected=2177.5300
# Month=31, Predicted=2177.2573, Expected=2178.6101
# Month=32, Predicted=2177.5875, Expected=2186.8501
# Month=33, Predicted=2187.2325, Expected=2186.4299
# Month=34, Predicted=2185.6907, Expected=2201.5601
# Month=35, Predicted=2202.2125, Expected=2198.5500
# Month=36, Predicted=2197.2105, Expected=2206.2700
# Month=37, Predicted=2207.8519, Expected=2210.2100
# Month=38, Predicted=2209.6550, Expected=2200.7600
# Month=39, Predicted=2200.7532, Expected=2204.9700
# Month=40, Predicted=2206.5912, Expected=2200.1699
# Month=41, Predicted=2199.2931, Expected=2191.1201
# Month=42, Predicted=2191.8327, Expected=2200.6499
# Month=43, Predicted=2201.5168, Expected=2207.2600
# Month=44, Predicted=2206.2974, Expected=2210.7200
# Month=45, Predicted=2210.8438, Expected=2241.1299
# Month=46, Predicted=2241.9467, Expected=2249.7300
# Month=47, Predicted=2248.1754, Expected=2258.8301
# Month=48, Predicted=2260.3365, Expected=2263.3201
# Month=49, Predicted=2263.5581, Expected=2268.3501
# Month=50, Predicted=2268.5495, Expected=2253.7700
# Month=51, Predicted=2253.2247, Expected=2266.8101
# Month=52, Predicted=2269.0207, Expected=2259.2400
# Month=53, Predicted=2257.2958, Expected=2266.5000
# Month=54, Predicted=2268.2603, Expected=2270.5400
# Month=55, Predicted=2269.9106, Expected=2262.9299
# Month=56, Predicted=2263.0384, Expected=2260.2500
# Month=57, Predicted=2261.7880, Expected=2266.2300
# Month=58, Predicted=2266.3125, Expected=2270.2300
# Month=59, Predicted=2269.6347, Expected=2249.5000
# Month=60, Predicted=2249.3934, Expected=2251.6101
# Run 4 — RMSE: 11.336907, MSE: 128.525453, NMSE: 0.0007816934
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=2155.4937, Expected=2158.2200
# Month=2, Predicted=2159.2038, Expected=2164.1899
# Month=3, Predicted=2163.1137, Expected=2160.3899
# Month=4, Predicted=2159.4302, Expected=2161.3501
# Month=5, Predicted=2161.8388, Expected=2137.6699
# Month=6, Predicted=2137.1591, Expected=2130.2600
# Month=7, Predicted=2133.9471, Expected=2139.6799
# Month=8, Predicted=2138.6036, Expected=2132.9500
# Month=9, Predicted=2130.9963, Expected=2138.3101
# Month=10, Predicted=2138.9788, Expected=2140.8101
# Month=11, Predicted=2139.6437, Expected=2142.5100
# Month=12, Predicted=2142.0627, Expected=2139.4299
# Month=13, Predicted=2139.0402, Expected=2148.5000
# Month=14, Predicted=2148.5297, Expected=2149.7200
# Month=15, Predicted=2148.2325, Expected=2136.9700
# Month=16, Predicted=2136.8504, Expected=2144.0601
# Month=17, Predicted=2145.6347, Expected=2132.2300
# Month=18, Predicted=2130.3790, Expected=2129.7800
# Month=19, Predicted=2131.1488, Expected=2128.6799
# Month=20, Predicted=2127.7413, Expected=2109.4299
# Month=21, Predicted=2108.6984, Expected=2098.8000
# Month=22, Predicted=2100.8739, Expected=2083.7900
# Month=23, Predicted=2083.1337, Expected=2100.5901
# Month=24, Predicted=2100.3290, Expected=2129.9199
# Month=25, Predicted=2128.1577, Expected=2131.5601
# Month=26, Predicted=2130.4765, Expected=2167.4900
# Month=27, Predicted=2169.0843, Expected=2162.7100
# Month=28, Predicted=2160.9436, Expected=2165.6399
# Month=29, Predicted=2169.2783, Expected=2168.2900
# Month=30, Predicted=2168.4971, Expected=2177.5300
# Month=31, Predicted=2177.4094, Expected=2178.6101
# Month=32, Predicted=2177.4985, Expected=2186.8501
# Month=33, Predicted=2186.9543, Expected=2186.4299
# Month=34, Predicted=2185.1997, Expected=2201.5601
# Month=35, Predicted=2201.6136, Expected=2198.5500
# Month=36, Predicted=2196.3976, Expected=2206.2700
# Month=37, Predicted=2207.1283, Expected=2210.2100
# Month=38, Predicted=2208.7257, Expected=2200.7600
# Month=39, Predicted=2200.0922, Expected=2204.9700
# Month=40, Predicted=2206.3526, Expected=2200.1699
# Month=41, Predicted=2198.6087, Expected=2191.1201
# Month=42, Predicted=2191.3662, Expected=2200.6499
# Month=43, Predicted=2201.0422, Expected=2207.2600
# Month=44, Predicted=2205.1450, Expected=2210.7200
# Month=45, Predicted=2209.6480, Expected=2241.1299
# Month=46, Predicted=2240.4513, Expected=2249.7300
# Month=47, Predicted=2247.1015, Expected=2258.8301
# Month=48, Predicted=2258.8532, Expected=2263.3201
# Month=49, Predicted=2262.5319, Expected=2268.3501
# Month=50, Predicted=2267.9214, Expected=2253.7700
# Month=51, Predicted=2252.9888, Expected=2266.8101
# Month=52, Predicted=2269.4210, Expected=2259.2400
# Month=53, Predicted=2256.6238, Expected=2266.5000
# Month=54, Predicted=2267.7648, Expected=2270.5400
# Month=55, Predicted=2268.9094, Expected=2262.9299
# Month=56, Predicted=2262.2249, Expected=2260.2500
# Month=57, Predicted=2261.3533, Expected=2266.2300
# Month=58, Predicted=2265.6870, Expected=2270.2300
# Month=59, Predicted=2268.6937, Expected=2249.5000
# Month=60, Predicted=2248.7596, Expected=2251.6101
# Run 5 — RMSE: 11.431059, MSE: 130.669105, NMSE: 0.0007950902
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=2155.8343, Expected=2158.2200
# Month=2, Predicted=2159.5024, Expected=2164.1899
# Month=3, Predicted=2163.6606, Expected=2160.3899
# Month=4, Predicted=2160.0791, Expected=2161.3501
# Month=5, Predicted=2162.3757, Expected=2137.6699
# Month=6, Predicted=2137.8561, Expected=2130.2600
# Month=7, Predicted=2134.0903, Expected=2139.6799
# Month=8, Predicted=2139.2621, Expected=2132.9500
# Month=9, Predicted=2131.4521, Expected=2138.3101
# Month=10, Predicted=2139.3189, Expected=2140.8101
# Month=11, Predicted=2140.1165, Expected=2142.5100
# Month=12, Predicted=2142.6199, Expected=2139.4299
# Month=13, Predicted=2139.7143, Expected=2148.5000
# Month=14, Predicted=2149.2794, Expected=2149.7200
# Month=15, Predicted=2149.1042, Expected=2136.9700
# Month=16, Predicted=2137.7427, Expected=2144.0601
# Month=17, Predicted=2146.3393, Expected=2132.2300
# Month=18, Predicted=2131.2402, Expected=2129.7800
# Month=19, Predicted=2131.7543, Expected=2128.6799
# Month=20, Predicted=2128.5118, Expected=2109.4299
# Month=21, Predicted=2109.4351, Expected=2098.8000
# Month=22, Predicted=2101.4121, Expected=2083.7900
# Month=23, Predicted=2083.9717, Expected=2100.5901
# Month=24, Predicted=2101.2250, Expected=2129.9199
# Month=25, Predicted=2128.2994, Expected=2131.5601
# Month=26, Predicted=2130.7187, Expected=2167.4900
# Month=27, Predicted=2169.3786, Expected=2162.7100
# Month=28, Predicted=2161.5358, Expected=2165.6399
# Month=29, Predicted=2169.4491, Expected=2168.2900
# Month=30, Predicted=2169.1454, Expected=2177.5300
# Month=31, Predicted=2178.2093, Expected=2178.6101
# Month=32, Predicted=2178.5324, Expected=2186.8501
# Month=33, Predicted=2187.8393, Expected=2186.4299
# Month=34, Predicted=2186.3178, Expected=2201.5601
# Month=35, Predicted=2202.5292, Expected=2198.5500
# Month=36, Predicted=2197.7807, Expected=2206.2700
# Month=37, Predicted=2207.9422, Expected=2210.2100
# Month=38, Predicted=2209.9583, Expected=2200.7600
# Month=39, Predicted=2201.2486, Expected=2204.9700
# Month=40, Predicted=2206.9588, Expected=2200.1699
# Month=41, Predicted=2199.6591, Expected=2191.1201
# Month=42, Predicted=2192.0860, Expected=2200.6499
# Month=43, Predicted=2201.6464, Expected=2207.2600
# Month=44, Predicted=2206.0929, Expected=2210.7200
# Month=45, Predicted=2210.6253, Expected=2241.1299
# Month=46, Predicted=2241.4781, Expected=2249.7300
# Month=47, Predicted=2248.7332, Expected=2258.8301
# Month=48, Predicted=2260.2946, Expected=2263.3201
# Month=49, Predicted=2264.0465, Expected=2268.3501
# Month=50, Predicted=2269.3824, Expected=2253.7700
# Month=51, Predicted=2254.4909, Expected=2266.8101
# Month=52, Predicted=2269.9495, Expected=2259.2400
# Month=53, Predicted=2257.8636, Expected=2266.5000
# Month=54, Predicted=2268.2434, Expected=2270.5400
# Month=55, Predicted=2269.8566, Expected=2262.9299
# Month=56, Predicted=2263.0938, Expected=2260.2500
# Month=57, Predicted=2261.7916, Expected=2266.2300
# Month=58, Predicted=2266.4016, Expected=2270.2300
# Month=59, Predicted=2269.6382, Expected=2249.5000
# Month=60, Predicted=2249.6544, Expected=2251.6101
# Run 6 — RMSE: 11.299747, MSE: 127.684293, NMSE: 0.0007723847
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=2154.6838, Expected=2158.2200
# Month=2, Predicted=2158.4055, Expected=2164.1899
# Month=3, Predicted=2162.6044, Expected=2160.3899
# Month=4, Predicted=2158.6103, Expected=2161.3501
# Month=5, Predicted=2160.3893, Expected=2137.6699
# Month=6, Predicted=2136.0163, Expected=2130.2600
# Month=7, Predicted=2133.1209, Expected=2139.6799
# Month=8, Predicted=2138.2215, Expected=2132.9500
# Month=9, Predicted=2129.9870, Expected=2138.3101
# Month=10, Predicted=2137.4281, Expected=2140.8101
# Month=11, Predicted=2138.9637, Expected=2142.5100
# Month=12, Predicted=2140.9203, Expected=2139.4299
# Month=13, Predicted=2137.5075, Expected=2148.5000
# Month=14, Predicted=2146.2002, Expected=2149.7200
# Month=15, Predicted=2145.8556, Expected=2136.9700
# Month=16, Predicted=2133.7856, Expected=2144.0601
# Month=17, Predicted=2142.2664, Expected=2132.2300
# Month=18, Predicted=2127.7547, Expected=2129.7800
# Month=19, Predicted=2128.0747, Expected=2128.6799
# Month=20, Predicted=2125.2966, Expected=2109.4299
# Month=21, Predicted=2106.4387, Expected=2098.8000
# Month=22, Predicted=2098.4112, Expected=2083.7900
# Month=23, Predicted=2081.4515, Expected=2100.5901
# Month=24, Predicted=2098.1201, Expected=2129.9199
# Month=25, Predicted=2126.1372, Expected=2131.5601
# Month=26, Predicted=2131.8164, Expected=2167.4900
# Month=27, Predicted=2167.0816, Expected=2162.7100
# Month=28, Predicted=2162.2643, Expected=2165.6399
# Month=29, Predicted=2166.8769, Expected=2168.2900
# Month=30, Predicted=2166.8051, Expected=2177.5300
# Month=31, Predicted=2174.9837, Expected=2178.6101
# Month=32, Predicted=2174.8433, Expected=2186.8501
# Month=33, Predicted=2184.2043, Expected=2186.4299
# Month=34, Predicted=2183.4458, Expected=2201.5601
# Month=35, Predicted=2199.5901, Expected=2198.5500
# Month=36, Predicted=2195.8513, Expected=2206.2700
# Month=37, Predicted=2205.4241, Expected=2210.2100
# Month=38, Predicted=2207.8185, Expected=2200.7600
# Month=39, Predicted=2198.7632, Expected=2204.9700
# Month=40, Predicted=2204.6698, Expected=2200.1699
# Month=41, Predicted=2197.6455, Expected=2191.1201
# Month=42, Predicted=2189.8983, Expected=2200.6499
# Month=43, Predicted=2199.6783, Expected=2207.2600
# Month=44, Predicted=2204.5262, Expected=2210.7200
# Month=45, Predicted=2208.8746, Expected=2241.1299
# Month=46, Predicted=2239.1546, Expected=2249.7300
# Month=47, Predicted=2248.0340, Expected=2258.8301
# Month=48, Predicted=2257.7258, Expected=2263.3201
# Month=49, Predicted=2261.0044, Expected=2268.3501
# Month=50, Predicted=2265.6393, Expected=2253.7700
# Month=51, Predicted=2250.5865, Expected=2266.8101
# Month=52, Predicted=2267.2155, Expected=2259.2400
# Month=53, Predicted=2255.4630, Expected=2266.5000
# Month=54, Predicted=2266.3025, Expected=2270.5400
# Month=55, Predicted=2268.9253, Expected=2262.9299
# Month=56, Predicted=2262.4305, Expected=2260.2500
# Month=57, Predicted=2261.2323, Expected=2266.2300
# Month=58, Predicted=2266.0916, Expected=2270.2300
# Month=59, Predicted=2268.9871, Expected=2249.5000
# Month=60, Predicted=2248.5738, Expected=2251.6101
# Run 7 — RMSE: 11.522949, MSE: 132.778355, NMSE: 0.0007952897
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=2153.8028, Expected=2158.2200
# Month=2, Predicted=2160.5015, Expected=2164.1899
# Month=3, Predicted=2163.5946, Expected=2160.3899
# Month=4, Predicted=2158.9942, Expected=2161.3501
# Month=5, Predicted=2162.8424, Expected=2137.6699
# Month=6, Predicted=2138.1070, Expected=2130.2600
# Month=7, Predicted=2133.4877, Expected=2139.6799
# Month=8, Predicted=2139.6163, Expected=2132.9500
# Month=9, Predicted=2129.7309, Expected=2138.3101
# Month=10, Predicted=2139.3809, Expected=2140.8101
# Month=11, Predicted=2141.8301, Expected=2142.5100
# Month=12, Predicted=2141.6514, Expected=2139.4299
# Month=13, Predicted=2140.2630, Expected=2148.5000
# Month=14, Predicted=2149.2878, Expected=2149.7200
# Month=15, Predicted=2149.0458, Expected=2136.9700
# Month=16, Predicted=2136.9185, Expected=2144.0601
# Month=17, Predicted=2147.0623, Expected=2132.2300
# Month=18, Predicted=2131.0314, Expected=2129.7800
# Month=19, Predicted=2130.0748, Expected=2128.6799
# Month=20, Predicted=2129.5748, Expected=2109.4299
# Month=21, Predicted=2108.0166, Expected=2098.8000
# Month=22, Predicted=2101.4771, Expected=2083.7900
# Month=23, Predicted=2084.1299, Expected=2100.5901
# Month=24, Predicted=2099.8698, Expected=2129.9199
# Month=25, Predicted=2129.6891, Expected=2131.5601
# Month=26, Predicted=2129.9030, Expected=2167.4900
# Month=27, Predicted=2171.8408, Expected=2162.7100
# Month=28, Predicted=2163.5888, Expected=2165.6399
# Month=29, Predicted=2168.2701, Expected=2168.2900
# Month=30, Predicted=2171.1340, Expected=2177.5300
# Month=31, Predicted=2175.6602, Expected=2178.6101
# Month=32, Predicted=2177.8308, Expected=2186.8501
# Month=33, Predicted=2187.4610, Expected=2186.4299
# Month=34, Predicted=2186.4953, Expected=2201.5601
# Month=35, Predicted=2201.8101, Expected=2198.5500
# Month=36, Predicted=2198.0237, Expected=2206.2700
# Month=37, Predicted=2207.2255, Expected=2210.2100
# Month=38, Predicted=2210.9369, Expected=2200.7600
# Month=39, Predicted=2199.8904, Expected=2204.9700
# Month=40, Predicted=2207.3864, Expected=2200.1699
# Month=41, Predicted=2199.6644, Expected=2191.1201
# Month=42, Predicted=2190.5903, Expected=2200.6499
# Month=43, Predicted=2202.2882, Expected=2207.2600
# Month=44, Predicted=2206.0018, Expected=2210.7200
# Month=45, Predicted=2209.6281, Expected=2241.1299
# Month=46, Predicted=2242.8182, Expected=2249.7300
# Month=47, Predicted=2249.1633, Expected=2258.8301
# Month=48, Predicted=2259.9734, Expected=2263.3201
# Month=49, Predicted=2266.0255, Expected=2268.3501
# Month=50, Predicted=2268.3367, Expected=2253.7700
# Month=51, Predicted=2253.9098, Expected=2266.8101
# Month=52, Predicted=2269.6539, Expected=2259.2400
# Month=53, Predicted=2257.8067, Expected=2266.5000
# Month=54, Predicted=2266.1646, Expected=2270.5400
# Month=55, Predicted=2271.4497, Expected=2262.9299
# Month=56, Predicted=2261.7230, Expected=2260.2500
# Month=57, Predicted=2262.4463, Expected=2266.2300
# Month=58, Predicted=2266.6320, Expected=2270.2300
# Month=59, Predicted=2268.6950, Expected=2249.5000
# Month=60, Predicted=2249.3185, Expected=2251.6101
# Run 8 — RMSE: 11.499699, MSE: 132.243072, NMSE: 0.0007987604
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=2155.3413, Expected=2158.2200
# Month=2, Predicted=2159.8608, Expected=2164.1899
# Month=3, Predicted=2163.8101, Expected=2160.3899
# Month=4, Predicted=2159.7055, Expected=2161.3501
# Month=5, Predicted=2162.4550, Expected=2137.6699
# Month=6, Predicted=2137.6143, Expected=2130.2600
# Month=7, Predicted=2133.3325, Expected=2139.6799
# Month=8, Predicted=2139.3042, Expected=2132.9500
# Month=9, Predicted=2130.6582, Expected=2138.3101
# Month=10, Predicted=2139.4314, Expected=2140.8101
# Month=11, Predicted=2141.2334, Expected=2142.5100
# Month=12, Predicted=2142.7504, Expected=2139.4299
# Month=13, Predicted=2140.2445, Expected=2148.5000
# Month=14, Predicted=2149.5219, Expected=2149.7200
# Month=15, Predicted=2149.3379, Expected=2136.9700
# Month=16, Predicted=2137.3772, Expected=2144.0601
# Month=17, Predicted=2146.4277, Expected=2132.2300
# Month=18, Predicted=2131.1937, Expected=2129.7800
# Month=19, Predicted=2130.9154, Expected=2128.6799
# Month=20, Predicted=2128.8839, Expected=2109.4299
# Month=21, Predicted=2108.6002, Expected=2098.8000
# Month=22, Predicted=2101.0231, Expected=2083.7900
# Month=23, Predicted=2083.6425, Expected=2100.5901
# Month=24, Predicted=2100.5267, Expected=2129.9199
# Month=25, Predicted=2128.9805, Expected=2131.5601
# Month=26, Predicted=2130.2960, Expected=2167.4900
# Month=27, Predicted=2170.8523, Expected=2162.7100
# Month=28, Predicted=2163.3713, Expected=2165.6399
# Month=29, Predicted=2170.0585, Expected=2168.2900
# Month=30, Predicted=2170.9419, Expected=2177.5300
# Month=31, Predicted=2177.4737, Expected=2178.6101
# Month=32, Predicted=2178.0882, Expected=2186.8501
# Month=33, Predicted=2187.1522, Expected=2186.4299
# Month=34, Predicted=2185.9817, Expected=2201.5601
# Month=35, Predicted=2201.5783, Expected=2198.5500
# Month=36, Predicted=2197.3031, Expected=2206.2700
# Month=37, Predicted=2206.7384, Expected=2210.2100
# Month=38, Predicted=2209.7776, Expected=2200.7600
# Month=39, Predicted=2199.7443, Expected=2204.9700
# Month=40, Predicted=2205.8291, Expected=2200.1699
# Month=41, Predicted=2198.7680, Expected=2191.1201
# Month=42, Predicted=2190.2575, Expected=2200.6499
# Month=43, Predicted=2200.6558, Expected=2207.2600
# Month=44, Predicted=2205.3936, Expected=2210.7200
# Month=45, Predicted=2209.4643, Expected=2241.1299
# Month=46, Predicted=2241.2722, Expected=2249.7300
# Month=47, Predicted=2248.3031, Expected=2258.8301
# Month=48, Predicted=2259.3017, Expected=2263.3201
# Month=49, Predicted=2264.4455, Expected=2268.3501
# Month=50, Predicted=2268.3090, Expected=2253.7700
# Month=51, Predicted=2253.0765, Expected=2266.8101
# Month=52, Predicted=2268.0450, Expected=2259.2400
# Month=53, Predicted=2257.1251, Expected=2266.5000
# Month=54, Predicted=2266.1769, Expected=2270.5400
# Month=55, Predicted=2269.7760, Expected=2262.9299
# Month=56, Predicted=2261.6507, Expected=2260.2500
# Month=57, Predicted=2260.9489, Expected=2266.2300
# Month=58, Predicted=2265.6181, Expected=2270.2300
# Month=59, Predicted=2268.5134, Expected=2249.5000
# Month=60, Predicted=2248.3819, Expected=2251.6101
# Run 9 — RMSE: 11.432049, MSE: 130.691745, NMSE: 0.0008014130
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=2155.7836, Expected=2158.2200
# Month=2, Predicted=2159.1618, Expected=2164.1899
# Month=3, Predicted=2163.3404, Expected=2160.3899
# Month=4, Predicted=2159.6432, Expected=2161.3501
# Month=5, Predicted=2161.8220, Expected=2137.6699
# Month=6, Predicted=2136.6911, Expected=2130.2600
# Month=7, Predicted=2133.7780, Expected=2139.6799
# Month=8, Predicted=2138.9103, Expected=2132.9500
# Month=9, Predicted=2131.5290, Expected=2138.3101
# Month=10, Predicted=2139.5139, Expected=2140.8101
# Month=11, Predicted=2139.8911, Expected=2142.5100
# Month=12, Predicted=2142.0293, Expected=2139.4299
# Month=13, Predicted=2138.7591, Expected=2148.5000
# Month=14, Predicted=2148.2321, Expected=2149.7200
# Month=15, Predicted=2148.1849, Expected=2136.9700
# Month=16, Predicted=2136.9026, Expected=2144.0601
# Month=17, Predicted=2145.6911, Expected=2132.2300
# Month=18, Predicted=2130.7029, Expected=2129.7800
# Month=19, Predicted=2131.9869, Expected=2128.6799
# Month=20, Predicted=2128.4981, Expected=2109.4299
# Month=21, Predicted=2109.1017, Expected=2098.8000
# Month=22, Predicted=2101.3413, Expected=2083.7900
# Month=23, Predicted=2083.4274, Expected=2100.5901
# Month=24, Predicted=2101.0107, Expected=2129.9199
# Month=25, Predicted=2128.8622, Expected=2131.5601
# Month=26, Predicted=2130.5106, Expected=2167.4900
# Month=27, Predicted=2169.2700, Expected=2162.7100
# Month=28, Predicted=2160.5923, Expected=2165.6399
# Month=29, Predicted=2169.9080, Expected=2168.2900
# Month=30, Predicted=2168.8332, Expected=2177.5300
# Month=31, Predicted=2178.1768, Expected=2178.6101
# Month=32, Predicted=2178.6423, Expected=2186.8501
# Month=33, Predicted=2188.3045, Expected=2186.4299
# Month=34, Predicted=2186.4136, Expected=2201.5601
# Month=35, Predicted=2202.8221, Expected=2198.5500
# Month=36, Predicted=2197.5293, Expected=2206.2700
# Month=37, Predicted=2208.3099, Expected=2210.2100
# Month=38, Predicted=2209.8119, Expected=2200.7600
# Month=39, Predicted=2200.9563, Expected=2204.9700
# Month=40, Predicted=2206.8439, Expected=2200.1699
# Month=41, Predicted=2199.3264, Expected=2191.1201
# Month=42, Predicted=2191.9761, Expected=2200.6499
# Month=43, Predicted=2201.4546, Expected=2207.2600
# Month=44, Predicted=2206.0005, Expected=2210.7200
# Month=45, Predicted=2210.4868, Expected=2241.1299
# Month=46, Predicted=2241.1621, Expected=2249.7300
# Month=47, Predicted=2247.7398, Expected=2258.8301
# Month=48, Predicted=2260.0866, Expected=2263.3201
# Month=49, Predicted=2263.3333, Expected=2268.3501
# Month=50, Predicted=2268.7078, Expected=2253.7700
# Month=51, Predicted=2253.6831, Expected=2266.8101
# Month=52, Predicted=2270.3370, Expected=2259.2400
# Month=53, Predicted=2258.1095, Expected=2266.5000
# Month=54, Predicted=2269.8204, Expected=2270.5400
# Month=55, Predicted=2270.7566, Expected=2262.9299
# Month=56, Predicted=2263.5644, Expected=2260.2500
# Month=57, Predicted=2261.9222, Expected=2266.2300
# Month=58, Predicted=2266.0885, Expected=2270.2300
# Month=59, Predicted=2269.2797, Expected=2249.5000
# Month=60, Predicted=2248.8716, Expected=2251.6101
# Run 10 — RMSE: 11.330599, MSE: 128.382477, NMSE: 0.0007729737
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=2155.0584, Expected=2158.2200
# Month=2, Predicted=2158.9968, Expected=2164.1899
# Month=3, Predicted=2163.4264, Expected=2160.3899
# Month=4, Predicted=2159.1337, Expected=2161.3501
# Month=5, Predicted=2161.8697, Expected=2137.6699
# Month=6, Predicted=2137.3318, Expected=2130.2600
# Month=7, Predicted=2134.0161, Expected=2139.6799
# Month=8, Predicted=2139.1025, Expected=2132.9500
# Month=9, Predicted=2130.4437, Expected=2138.3101
# Month=10, Predicted=2138.7005, Expected=2140.8101
# Month=11, Predicted=2140.9235, Expected=2142.5100
# Month=12, Predicted=2142.5966, Expected=2139.4299
# Month=13, Predicted=2139.4977, Expected=2148.5000
# Month=14, Predicted=2148.7940, Expected=2149.7200
# Month=15, Predicted=2148.6225, Expected=2136.9700
# Month=16, Predicted=2136.6239, Expected=2144.0601
# Month=17, Predicted=2145.8795, Expected=2132.2300
# Month=18, Predicted=2131.0914, Expected=2129.7800
# Month=19, Predicted=2130.7828, Expected=2128.6799
# Month=20, Predicted=2128.2592, Expected=2109.4299
# Month=21, Predicted=2108.2330, Expected=2098.8000
# Month=22, Predicted=2100.7630, Expected=2083.7900
# Month=23, Predicted=2083.3177, Expected=2100.5901
# Month=24, Predicted=2100.0034, Expected=2129.9199
# Month=25, Predicted=2129.2710, Expected=2131.5601
# Month=26, Predicted=2130.5915, Expected=2167.4900
# Month=27, Predicted=2171.1839, Expected=2162.7100
# Month=28, Predicted=2162.7076, Expected=2165.6399
# Month=29, Predicted=2170.6918, Expected=2168.2900
# Month=30, Predicted=2169.4826, Expected=2177.5300
# Month=31, Predicted=2176.4254, Expected=2178.6101
# Month=32, Predicted=2176.3615, Expected=2186.8501
# Month=33, Predicted=2186.3504, Expected=2186.4299
# Month=34, Predicted=2185.5870, Expected=2201.5601
# Month=35, Predicted=2202.0181, Expected=2198.5500
# Month=36, Predicted=2197.3884, Expected=2206.2700
# Month=37, Predicted=2207.7486, Expected=2210.2100
# Month=38, Predicted=2210.0795, Expected=2200.7600
# Month=39, Predicted=2200.3254, Expected=2204.9700
# Month=40, Predicted=2206.4933, Expected=2200.1699
# Month=41, Predicted=2199.3862, Expected=2191.1201
# Month=42, Predicted=2190.9576, Expected=2200.6499
# Month=43, Predicted=2201.1402, Expected=2207.2600
# Month=44, Predicted=2206.2201, Expected=2210.7200
# Month=45, Predicted=2210.1427, Expected=2241.1299
# Month=46, Predicted=2241.8553, Expected=2249.7300
# Month=47, Predicted=2248.6093, Expected=2258.8301
# Month=48, Predicted=2260.6488, Expected=2263.3201
# Month=49, Predicted=2264.4234, Expected=2268.3501
# Month=50, Predicted=2268.6629, Expected=2253.7700
# Month=51, Predicted=2252.8597, Expected=2266.8101
# Month=52, Predicted=2269.0878, Expected=2259.2400
# Month=53, Predicted=2257.6361, Expected=2266.5000
# Month=54, Predicted=2267.5470, Expected=2270.5400
# Month=55, Predicted=2270.3352, Expected=2262.9299
# Month=56, Predicted=2262.6811, Expected=2260.2500
# Month=57, Predicted=2261.7880, Expected=2266.2300
# Month=58, Predicted=2266.4319, Expected=2270.2300
# Month=59, Predicted=2269.0786, Expected=2249.5000
# Month=60, Predicted=2248.6284, Expected=2251.6101
# Run 11 — RMSE: 11.413535, MSE: 130.268778, NMSE: 0.0007864247
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=2155.7565, Expected=2158.2200
# Month=2, Predicted=2159.4231, Expected=2164.1899
# Month=3, Predicted=2163.6195, Expected=2160.3899
# Month=4, Predicted=2160.0633, Expected=2161.3501
# Month=5, Predicted=2162.4773, Expected=2137.6699
# Month=6, Predicted=2137.6663, Expected=2130.2600
# Month=7, Predicted=2133.9064, Expected=2139.6799
# Month=8, Predicted=2139.0893, Expected=2132.9500
# Month=9, Predicted=2131.5326, Expected=2138.3101
# Month=10, Predicted=2139.8680, Expected=2140.8101
# Month=11, Predicted=2140.4603, Expected=2142.5100
# Month=12, Predicted=2142.8431, Expected=2139.4299
# Month=13, Predicted=2139.8508, Expected=2148.5000
# Month=14, Predicted=2149.2841, Expected=2149.7200
# Month=15, Predicted=2149.0713, Expected=2136.9700
# Month=16, Predicted=2137.6884, Expected=2144.0601
# Month=17, Predicted=2146.1579, Expected=2132.2300
# Month=18, Predicted=2131.0416, Expected=2129.7800
# Month=19, Predicted=2131.7241, Expected=2128.6799
# Month=20, Predicted=2128.4886, Expected=2109.4299
# Month=21, Predicted=2109.3772, Expected=2098.8000
# Month=22, Predicted=2101.5415, Expected=2083.7900
# Month=23, Predicted=2083.8807, Expected=2100.5901
# Month=24, Predicted=2101.3667, Expected=2129.9199
# Month=25, Predicted=2129.0552, Expected=2131.5601
# Month=26, Predicted=2130.6878, Expected=2167.4900
# Month=27, Predicted=2170.2700, Expected=2162.7100
# Month=28, Predicted=2161.3286, Expected=2165.6399
# Month=29, Predicted=2169.7241, Expected=2168.2900
# Month=30, Predicted=2168.5051, Expected=2177.5300
# Month=31, Predicted=2177.4682, Expected=2178.6101
# Month=32, Predicted=2178.0473, Expected=2186.8501
# Month=33, Predicted=2187.4656, Expected=2186.4299
# Month=34, Predicted=2185.9909, Expected=2201.5601
# Month=35, Predicted=2202.2470, Expected=2198.5500
# Month=36, Predicted=2197.5267, Expected=2206.2700
# Month=37, Predicted=2207.7767, Expected=2210.2100
# Month=38, Predicted=2209.7178, Expected=2200.7600
# Month=39, Predicted=2200.8764, Expected=2204.9700
# Month=40, Predicted=2206.5645, Expected=2200.1699
# Month=41, Predicted=2199.3140, Expected=2191.1201
# Month=42, Predicted=2191.8008, Expected=2200.6499
# Month=43, Predicted=2201.4258, Expected=2207.2600
# Month=44, Predicted=2206.1500, Expected=2210.7200
# Month=45, Predicted=2210.7306, Expected=2241.1299
# Month=46, Predicted=2241.7354, Expected=2249.7300
# Month=47, Predicted=2248.6362, Expected=2258.8301
# Month=48, Predicted=2260.4761, Expected=2263.3201
# Month=49, Predicted=2263.7698, Expected=2268.3501
# Month=50, Predicted=2268.7946, Expected=2253.7700
# Month=51, Predicted=2253.7164, Expected=2266.8101
# Month=52, Predicted=2269.0742, Expected=2259.2400
# Month=53, Predicted=2257.5070, Expected=2266.5000
# Month=54, Predicted=2268.0167, Expected=2270.5400
# Month=55, Predicted=2269.8270, Expected=2262.9299
# Month=56, Predicted=2262.9684, Expected=2260.2500
# Month=57, Predicted=2261.6970, Expected=2266.2300
# Month=58, Predicted=2266.1749, Expected=2270.2300
# Month=59, Predicted=2269.5493, Expected=2249.5000
# Month=60, Predicted=2249.5806, Expected=2251.6101
# Run 12 — RMSE: 11.308628, MSE: 127.885078, NMSE: 0.0007769534
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=2154.7092, Expected=2158.2200
# Month=2, Predicted=2159.3271, Expected=2164.1899
# Month=3, Predicted=2163.4525, Expected=2160.3899
# Month=4, Predicted=2159.1185, Expected=2161.3501
# Month=5, Predicted=2161.8623, Expected=2137.6699
# Month=6, Predicted=2137.4492, Expected=2130.2600
# Month=7, Predicted=2133.5767, Expected=2139.6799
# Month=8, Predicted=2139.0943, Expected=2132.9500
# Month=9, Predicted=2130.2663, Expected=2138.3101
# Month=10, Predicted=2138.7455, Expected=2140.8101
# Month=11, Predicted=2140.9537, Expected=2142.5100
# Month=12, Predicted=2142.2709, Expected=2139.4299
# Month=13, Predicted=2139.5971, Expected=2148.5000
# Month=14, Predicted=2148.8149, Expected=2149.7200
# Month=15, Predicted=2148.6278, Expected=2136.9700
# Month=16, Predicted=2136.6428, Expected=2144.0601
# Month=17, Predicted=2146.0901, Expected=2132.2300
# Month=18, Predicted=2131.1270, Expected=2129.7800
# Month=19, Predicted=2130.7851, Expected=2128.6799
# Month=20, Predicted=2128.9406, Expected=2109.4299
# Month=21, Predicted=2108.9352, Expected=2098.8000
# Month=22, Predicted=2101.5994, Expected=2083.7900
# Month=23, Predicted=2084.2427, Expected=2100.5901
# Month=24, Predicted=2100.7829, Expected=2129.9199
# Month=25, Predicted=2128.7698, Expected=2131.5601
# Month=26, Predicted=2130.4618, Expected=2167.4900
# Month=27, Predicted=2170.0951, Expected=2162.7100
# Month=28, Predicted=2163.3489, Expected=2165.6399
# Month=29, Predicted=2168.9026, Expected=2168.2900
# Month=30, Predicted=2169.6319, Expected=2177.5300
# Month=31, Predicted=2176.8379, Expected=2178.6101
# Month=32, Predicted=2177.7311, Expected=2186.8501
# Month=33, Predicted=2187.5918, Expected=2186.4299
# Month=34, Predicted=2186.9878, Expected=2201.5601
# Month=35, Predicted=2202.8455, Expected=2198.5500
# Month=36, Predicted=2198.5956, Expected=2206.2700
# Month=37, Predicted=2208.0644, Expected=2210.2100
# Month=38, Predicted=2210.8822, Expected=2200.7600
# Month=39, Predicted=2200.8837, Expected=2204.9700
# Month=40, Predicted=2206.9584, Expected=2200.1699
# Month=41, Predicted=2199.7147, Expected=2191.1201
# Month=42, Predicted=2190.8760, Expected=2200.6499
# Month=43, Predicted=2201.1473, Expected=2207.2600
# Month=44, Predicted=2205.6275, Expected=2210.7200
# Month=45, Predicted=2209.2171, Expected=2241.1299
# Month=46, Predicted=2240.8463, Expected=2249.7300
# Month=47, Predicted=2248.3336, Expected=2258.8301
# Month=48, Predicted=2259.0258, Expected=2263.3201
# Month=49, Predicted=2263.8873, Expected=2268.3501
# Month=50, Predicted=2268.2006, Expected=2253.7700
# Month=51, Predicted=2253.3793, Expected=2266.8101
# Month=52, Predicted=2269.6589, Expected=2259.2400
# Month=53, Predicted=2258.4175, Expected=2266.5000
# Month=54, Predicted=2268.3343, Expected=2270.5400
# Month=55, Predicted=2272.0507, Expected=2262.9299
# Month=56, Predicted=2264.4299, Expected=2260.2500
# Month=57, Predicted=2263.8605, Expected=2266.2300
# Month=58, Predicted=2268.2316, Expected=2270.2300
# Month=59, Predicted=2270.3386, Expected=2249.5000
# Month=60, Predicted=2249.7053, Expected=2251.6101
# Run 13 — RMSE: 11.453212, MSE: 131.176055, NMSE: 0.0007873121
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=2154.8927, Expected=2158.2200
# Month=2, Predicted=2159.3391, Expected=2164.1899
# Month=3, Predicted=2163.5510, Expected=2160.3899
# Month=4, Predicted=2159.4631, Expected=2161.3501
# Month=5, Predicted=2162.3699, Expected=2137.6699
# Month=6, Predicted=2137.6649, Expected=2130.2600
# Month=7, Predicted=2133.5126, Expected=2139.6799
# Month=8, Predicted=2139.1220, Expected=2132.9500
# Month=9, Predicted=2130.6794, Expected=2138.3101
# Month=10, Predicted=2139.5606, Expected=2140.8101
# Month=11, Predicted=2141.6736, Expected=2142.5100
# Month=12, Predicted=2143.0119, Expected=2139.4299
# Month=13, Predicted=2140.0457, Expected=2148.5000
# Month=14, Predicted=2149.1477, Expected=2149.7200
# Month=15, Predicted=2148.8504, Expected=2136.9700
# Month=16, Predicted=2136.8474, Expected=2144.0601
# Month=17, Predicted=2146.0151, Expected=2132.2300
# Month=18, Predicted=2130.8564, Expected=2129.7800
# Month=19, Predicted=2130.4989, Expected=2128.6799
# Month=20, Predicted=2128.6513, Expected=2109.4299
# Month=21, Predicted=2108.7210, Expected=2098.8000
# Month=22, Predicted=2101.3708, Expected=2083.7900
# Month=23, Predicted=2084.1601, Expected=2100.5901
# Month=24, Predicted=2100.8906, Expected=2129.9199
# Month=25, Predicted=2129.4889, Expected=2131.5601
# Month=26, Predicted=2130.7138, Expected=2167.4900
# Month=27, Predicted=2172.1382, Expected=2162.7100
# Month=28, Predicted=2163.1735, Expected=2165.6399
# Month=29, Predicted=2169.4694, Expected=2168.2900
# Month=30, Predicted=2169.2030, Expected=2177.5300
# Month=31, Predicted=2176.2261, Expected=2178.6101
# Month=32, Predicted=2176.9667, Expected=2186.8501
# Month=33, Predicted=2186.8264, Expected=2186.4299
# Month=34, Predicted=2186.0445, Expected=2201.5601
# Month=35, Predicted=2202.0605, Expected=2198.5500
# Month=36, Predicted=2197.6053, Expected=2206.2700
# Month=37, Predicted=2207.3661, Expected=2210.2100
# Month=38, Predicted=2210.0836, Expected=2200.7600
# Month=39, Predicted=2200.2270, Expected=2204.9700
# Month=40, Predicted=2206.2610, Expected=2200.1699
# Month=41, Predicted=2199.1318, Expected=2191.1201
# Month=42, Predicted=2190.7869, Expected=2200.6499
# Month=43, Predicted=2201.3608, Expected=2207.2600
# Month=44, Predicted=2206.2070, Expected=2210.7200
# Month=45, Predicted=2210.4297, Expected=2241.1299
# Month=46, Predicted=2242.6014, Expected=2249.7300
# Month=47, Predicted=2249.1232, Expected=2258.8301
# Month=48, Predicted=2260.6244, Expected=2263.3201
# Month=49, Predicted=2264.8743, Expected=2268.3501
# Month=50, Predicted=2268.6291, Expected=2253.7700
# Month=51, Predicted=2252.8277, Expected=2266.8101
# Month=52, Predicted=2268.0663, Expected=2259.2400
# Month=53, Predicted=2257.0428, Expected=2266.5000
# Month=54, Predicted=2266.7517, Expected=2270.5400
# Month=55, Predicted=2270.4689, Expected=2262.9299
# Month=56, Predicted=2262.7907, Expected=2260.2500
# Month=57, Predicted=2261.9356, Expected=2266.2300
# Month=58, Predicted=2266.3536, Expected=2270.2300
# Month=59, Predicted=2269.0624, Expected=2249.5000
# Month=60, Predicted=2248.9249, Expected=2251.6101
# Run 14 — RMSE: 11.349394, MSE: 128.808745, NMSE: 0.0007823882
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=2155.4071, Expected=2158.2200
# Month=2, Predicted=2159.3089, Expected=2164.1899
# Month=3, Predicted=2163.8226, Expected=2160.3899
# Month=4, Predicted=2159.8542, Expected=2161.3501
# Month=5, Predicted=2162.1757, Expected=2137.6699
# Month=6, Predicted=2137.2829, Expected=2130.2600
# Month=7, Predicted=2134.3181, Expected=2139.6799
# Month=8, Predicted=2139.3837, Expected=2132.9500
# Month=9, Predicted=2131.4568, Expected=2138.3101
# Month=10, Predicted=2139.1196, Expected=2140.8101
# Month=11, Predicted=2140.5224, Expected=2142.5100
# Month=12, Predicted=2142.6242, Expected=2139.4299
# Month=13, Predicted=2139.6326, Expected=2148.5000
# Month=14, Predicted=2149.2609, Expected=2149.7200
# Month=15, Predicted=2149.1362, Expected=2136.9700
# Month=16, Predicted=2137.2217, Expected=2144.0601
# Month=17, Predicted=2146.2958, Expected=2132.2300
# Month=18, Predicted=2131.0711, Expected=2129.7800
# Month=19, Predicted=2131.4619, Expected=2128.6799
# Month=20, Predicted=2128.3871, Expected=2109.4299
# Month=21, Predicted=2108.7794, Expected=2098.8000
# Month=22, Predicted=2101.1323, Expected=2083.7900
# Month=23, Predicted=2083.6466, Expected=2100.5901
# Month=24, Predicted=2101.1465, Expected=2129.9199
# Month=25, Predicted=2129.9199, Expected=2131.5601
# Month=26, Predicted=2131.4598, Expected=2167.4900
# Month=27, Predicted=2169.7348, Expected=2162.7100
# Month=28, Predicted=2161.7893, Expected=2165.6399
# Month=29, Predicted=2170.1216, Expected=2168.2900
# Month=30, Predicted=2169.5065, Expected=2177.5300
# Month=31, Predicted=2178.0160, Expected=2178.6101
# Month=32, Predicted=2177.8170, Expected=2186.8501
# Month=33, Predicted=2187.4302, Expected=2186.4299
# Month=34, Predicted=2185.8281, Expected=2201.5601
# Month=35, Predicted=2202.3985, Expected=2198.5500
# Month=36, Predicted=2197.4419, Expected=2206.2700
# Month=37, Predicted=2207.9472, Expected=2210.2100
# Month=38, Predicted=2210.0103, Expected=2200.7600
# Month=39, Predicted=2200.8358, Expected=2204.9700
# Month=40, Predicted=2206.9817, Expected=2200.1699
# Month=41, Predicted=2199.6338, Expected=2191.1201
# Month=42, Predicted=2191.6979, Expected=2200.6499
# Month=43, Predicted=2201.5772, Expected=2207.2600
# Month=44, Predicted=2206.4609, Expected=2210.7200
# Month=45, Predicted=2210.5599, Expected=2241.1299
# Month=46, Predicted=2241.8300, Expected=2249.7300
# Month=47, Predicted=2248.9547, Expected=2258.8301
# Month=48, Predicted=2260.3837, Expected=2263.3201
# Month=49, Predicted=2264.1143, Expected=2268.3501
# Month=50, Predicted=2269.4006, Expected=2253.7700
# Month=51, Predicted=2253.9349, Expected=2266.8101
# Month=52, Predicted=2270.5074, Expected=2259.2400
# Month=53, Predicted=2257.4976, Expected=2266.5000
# Month=54, Predicted=2268.0530, Expected=2270.5400
# Month=55, Predicted=2269.8541, Expected=2262.9299
# Month=56, Predicted=2262.6992, Expected=2260.2500
# Month=57, Predicted=2261.6238, Expected=2266.2300
# Month=58, Predicted=2266.5434, Expected=2270.2300
# Month=59, Predicted=2269.7480, Expected=2249.5000
# Month=60, Predicted=2249.0892, Expected=2251.6101
# Run 15 — RMSE: 11.290773, MSE: 127.481552, NMSE: 0.0007712138
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=2151.5038, Expected=2158.2200
# Month=2, Predicted=2155.2886, Expected=2164.1899
# Month=3, Predicted=2160.8871, Expected=2160.3899
# Month=4, Predicted=2156.2716, Expected=2161.3501
# Month=5, Predicted=2157.8398, Expected=2137.6699
# Month=6, Predicted=2133.2536, Expected=2130.2600
# Month=7, Predicted=2129.1612, Expected=2139.6799
# Month=8, Predicted=2137.1938, Expected=2132.9500
# Month=9, Predicted=2129.1595, Expected=2138.3101
# Month=10, Predicted=2135.0865, Expected=2140.8101
# Month=11, Predicted=2137.0302, Expected=2142.5100
# Month=12, Predicted=2138.6326, Expected=2139.4299
# Month=13, Predicted=2135.5485, Expected=2148.5000
# Month=14, Predicted=2145.2404, Expected=2149.7200
# Month=15, Predicted=2145.8203, Expected=2136.9700
# Month=16, Predicted=2132.8161, Expected=2144.0601
# Month=17, Predicted=2141.5214, Expected=2132.2300
# Month=18, Predicted=2128.3538, Expected=2129.7800
# Month=19, Predicted=2127.1051, Expected=2128.6799
# Month=20, Predicted=2125.3423, Expected=2109.4299
# Month=21, Predicted=2105.2628, Expected=2098.8000
# Month=22, Predicted=2096.7115, Expected=2083.7900
# Month=23, Predicted=2080.7112, Expected=2100.5901
# ...
# Month=53, Predicted=2258.4587, Expected=2266.5000
# Month=54, Predicted=2268.4388, Expected=2270.5400
# Month=55, Predicted=2269.9751, Expected=2262.9299
# Month=56, Predicted=2262.9706, Expected=2260.2500
# Month=57, Predicted=2261.5870, Expected=2266.2300
# Month=58, Predicted=2266.4952, Expected=2270.2300
# Month=59, Predicted=2269.7270, Expected=2249.5000
# Month=60, Predicted=2249.2026, Expected=2251.6101
# Run 25 — RMSE: 11.311491, MSE: 127.949833, NMSE: 0.0007715660
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=2155.1166, Expected=2158.2200
# Month=2, Predicted=2158.7123, Expected=2164.1899
# Month=3, Predicted=2162.7640, Expected=2160.3899
# Month=4, Predicted=2158.8096, Expected=2161.3501
# Month=5, Predicted=2161.0613, Expected=2137.6699
# Month=6, Predicted=2136.6110, Expected=2130.2600
# Month=7, Predicted=2133.6531, Expected=2139.6799
# Month=8, Predicted=2138.3691, Expected=2132.9500
# Month=9, Predicted=2130.2613, Expected=2138.3101
# Month=10, Predicted=2137.6753, Expected=2140.8101
# Month=11, Predicted=2138.6050, Expected=2142.5100
# Month=12, Predicted=2140.6487, Expected=2139.4299
# Month=13, Predicted=2137.6961, Expected=2148.5000
# Month=14, Predicted=2147.1537, Expected=2149.7200
# Month=15, Predicted=2147.3347, Expected=2136.9700
# Month=16, Predicted=2135.8051, Expected=2144.0601
# Month=17, Predicted=2144.6856, Expected=2132.2300
# Month=18, Predicted=2130.1911, Expected=2129.7800
# Month=19, Predicted=2130.3784, Expected=2128.6799
# Month=20, Predicted=2127.1546, Expected=2109.4299
# Month=21, Predicted=2107.6157, Expected=2098.8000
# Month=22, Predicted=2099.7193, Expected=2083.7900
# Month=23, Predicted=2081.8902, Expected=2100.5901
# Month=24, Predicted=2098.6103, Expected=2129.9199
# Month=25, Predicted=2126.2589, Expected=2131.5601
# Month=26, Predicted=2128.3801, Expected=2167.4900
# Month=27, Predicted=2166.7468, Expected=2162.7100
# Month=28, Predicted=2161.3623, Expected=2165.6399
# Month=29, Predicted=2169.2126, Expected=2168.2900
# Month=30, Predicted=2169.3526, Expected=2177.5300
# Month=31, Predicted=2178.0335, Expected=2178.6101
# Month=32, Predicted=2178.2593, Expected=2186.8501
# Month=33, Predicted=2187.3713, Expected=2186.4299
# Month=34, Predicted=2185.9598, Expected=2201.5601
# Month=35, Predicted=2202.0609, Expected=2198.5500
# Month=36, Predicted=2197.6021, Expected=2206.2700
# Month=37, Predicted=2207.9336, Expected=2210.2100
# Month=38, Predicted=2210.1218, Expected=2200.7600
# Month=39, Predicted=2201.2211, Expected=2204.9700
# Month=40, Predicted=2207.2321, Expected=2200.1699
# Month=41, Predicted=2199.8847, Expected=2191.1201
# Month=42, Predicted=2192.0068, Expected=2200.6499
# Month=43, Predicted=2201.4701, Expected=2207.2600
# Month=44, Predicted=2205.8390, Expected=2210.7200
# Month=45, Predicted=2209.8444, Expected=2241.1299
# Month=46, Predicted=2240.4867, Expected=2249.7300
# Month=47, Predicted=2248.2734, Expected=2258.8301
# Month=48, Predicted=2259.8692, Expected=2263.3201
# Month=49, Predicted=2264.2305, Expected=2268.3501
# Month=50, Predicted=2269.6784, Expected=2253.7700
# Month=51, Predicted=2254.8937, Expected=2266.8101
# Month=52, Predicted=2271.0482, Expected=2259.2400
# Month=53, Predicted=2259.1912, Expected=2266.5000
# Month=54, Predicted=2269.4464, Expected=2270.5400
# Month=55, Predicted=2270.8050, Expected=2262.9299
# Month=56, Predicted=2263.4731, Expected=2260.2500
# Month=57, Predicted=2262.2379, Expected=2266.2300
# Month=58, Predicted=2266.5110, Expected=2270.2300
# Month=59, Predicted=2269.3608, Expected=2249.5000
# Month=60, Predicted=2249.1880, Expected=2251.6101
# Run 26 — RMSE: 11.515608, MSE: 132.609230, NMSE: 0.0007784686
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=2155.0591, Expected=2158.2200
# Month=2, Predicted=2159.3182, Expected=2164.1899
# Month=3, Predicted=2163.6836, Expected=2160.3899
# Month=4, Predicted=2159.5134, Expected=2161.3501
# Month=5, Predicted=2162.2041, Expected=2137.6699
# Month=6, Predicted=2137.7736, Expected=2130.2600
# Month=7, Predicted=2134.0306, Expected=2139.6799
# Month=8, Predicted=2139.0810, Expected=2132.9500
# Month=9, Predicted=2130.3617, Expected=2138.3101
# Month=10, Predicted=2138.6560, Expected=2140.8101
# Month=11, Predicted=2140.7324, Expected=2142.5100
# Month=12, Predicted=2142.5025, Expected=2139.4299
# Month=13, Predicted=2139.6871, Expected=2148.5000
# Month=14, Predicted=2149.2494, Expected=2149.7200
# Month=15, Predicted=2149.1315, Expected=2136.9700
# Month=16, Predicted=2137.1944, Expected=2144.0601
# Month=17, Predicted=2146.4517, Expected=2132.2300
# Month=18, Predicted=2131.3558, Expected=2129.7800
# Month=19, Predicted=2130.9408, Expected=2128.6799
# Month=20, Predicted=2128.4649, Expected=2109.4299
# Month=21, Predicted=2108.5914, Expected=2098.8000
# Month=22, Predicted=2101.0479, Expected=2083.7900
# Month=23, Predicted=2083.6036, Expected=2100.5901
# Month=24, Predicted=2100.2667, Expected=2129.9199
# Month=25, Predicted=2128.3400, Expected=2131.5601
# Month=26, Predicted=2130.2015, Expected=2167.4900
# Month=27, Predicted=2170.3486, Expected=2162.7100
# Month=28, Predicted=2163.5033, Expected=2165.6399
# Month=29, Predicted=2169.9520, Expected=2168.2900
# Month=30, Predicted=2170.3763, Expected=2177.5300
# Month=31, Predicted=2177.7286, Expected=2178.6101
# Month=32, Predicted=2177.9197, Expected=2186.8501
# Month=33, Predicted=2187.5176, Expected=2186.4299
# Month=34, Predicted=2186.5638, Expected=2201.5601
# Month=35, Predicted=2202.5231, Expected=2198.5500
# Month=36, Predicted=2198.0482, Expected=2206.2700
# Month=37, Predicted=2207.8468, Expected=2210.2100
# Month=38, Predicted=2210.5426, Expected=2200.7600
# Month=39, Predicted=2200.8837, Expected=2204.9700
# Month=40, Predicted=2206.9268, Expected=2200.1699
# Month=41, Predicted=2199.7838, Expected=2191.1201
# Month=42, Predicted=2191.3148, Expected=2200.6499
# Month=43, Predicted=2201.4637, Expected=2207.2600
# Month=44, Predicted=2206.1451, Expected=2210.7200
# Month=45, Predicted=2210.0981, Expected=2241.1299
# Month=46, Predicted=2241.8782, Expected=2249.7300
# Month=47, Predicted=2249.4065, Expected=2258.8301
# Month=48, Predicted=2260.4682, Expected=2263.3201
# Month=49, Predicted=2265.2130, Expected=2268.3501
# Month=50, Predicted=2269.6791, Expected=2253.7700
# Month=51, Predicted=2254.1910, Expected=2266.8101
# Month=52, Predicted=2269.7677, Expected=2259.2400
# Month=53, Predicted=2258.1546, Expected=2266.5000
# Month=54, Predicted=2267.4537, Expected=2270.5400
# Month=55, Predicted=2270.2658, Expected=2262.9299
# Month=56, Predicted=2262.7000, Expected=2260.2500
# Month=57, Predicted=2261.8255, Expected=2266.2300
# Month=58, Predicted=2266.5756, Expected=2270.2300
# Month=59, Predicted=2269.2665, Expected=2249.5000
# Month=60, Predicted=2248.9657, Expected=2251.6101
# Run 27 — RMSE: 11.383425, MSE: 129.582359, NMSE: 0.0007800262
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=2155.1809, Expected=2158.2200
# Month=2, Predicted=2159.0968, Expected=2164.1899
# Month=3, Predicted=2163.6461, Expected=2160.3899
# Month=4, Predicted=2159.5122, Expected=2161.3501
# Month=5, Predicted=2161.8893, Expected=2137.6699
# Month=6, Predicted=2137.5172, Expected=2130.2600
# Month=7, Predicted=2134.0873, Expected=2139.6799
# Month=8, Predicted=2139.6627, Expected=2132.9500
# Month=9, Predicted=2131.1025, Expected=2138.3101
# Month=10, Predicted=2138.6542, Expected=2140.8101
# Month=11, Predicted=2140.8865, Expected=2142.5100
# Month=12, Predicted=2142.7363, Expected=2139.4299
# Month=13, Predicted=2139.6592, Expected=2148.5000
# Month=14, Predicted=2149.0379, Expected=2149.7200
# Month=15, Predicted=2148.8567, Expected=2136.9700
# Month=16, Predicted=2136.8081, Expected=2144.0601
# Month=17, Predicted=2145.9905, Expected=2132.2300
# Month=18, Predicted=2131.1052, Expected=2129.7800
# Month=19, Predicted=2130.8049, Expected=2128.6799
# Month=20, Predicted=2128.4384, Expected=2109.4299
# Month=21, Predicted=2108.7147, Expected=2098.8000
# Month=22, Predicted=2100.9943, Expected=2083.7900
# Month=23, Predicted=2084.1178, Expected=2100.5901
# Month=24, Predicted=2101.0387, Expected=2129.9199
# Month=25, Predicted=2129.7738, Expected=2131.5601
# Month=26, Predicted=2131.6681, Expected=2167.4900
# Month=27, Predicted=2170.4306, Expected=2162.7100
# Month=28, Predicted=2163.1797, Expected=2165.6399
# Month=29, Predicted=2169.7826, Expected=2168.2900
# Month=30, Predicted=2169.3535, Expected=2177.5300
# Month=31, Predicted=2177.0410, Expected=2178.6101
# Month=32, Predicted=2177.0241, Expected=2186.8501
# Month=33, Predicted=2186.6024, Expected=2186.4299
# Month=34, Predicted=2185.8199, Expected=2201.5601
# Month=35, Predicted=2202.0475, Expected=2198.5500
# Month=36, Predicted=2197.6141, Expected=2206.2700
# Month=37, Predicted=2207.3409, Expected=2210.2100
# Month=38, Predicted=2209.9299, Expected=2200.7600
# Month=39, Predicted=2200.4632, Expected=2204.9700
# Month=40, Predicted=2206.4206, Expected=2200.1699
# Month=41, Predicted=2199.4289, Expected=2191.1201
# Month=42, Predicted=2191.1239, Expected=2200.6499
# Month=43, Predicted=2201.2727, Expected=2207.2600
# Month=44, Predicted=2206.3059, Expected=2210.7200
# Month=45, Predicted=2210.2314, Expected=2241.1299
# Month=46, Predicted=2241.7481, Expected=2249.7300
# Month=47, Predicted=2249.3379, Expected=2258.8301
# Month=48, Predicted=2260.1622, Expected=2263.3201
# Month=49, Predicted=2264.2895, Expected=2268.3501
# Month=50, Predicted=2268.9086, Expected=2253.7700
# Month=51, Predicted=2253.3778, Expected=2266.8101
# Month=52, Predicted=2269.2016, Expected=2259.2400
# Month=53, Predicted=2257.3815, Expected=2266.5000
# Month=54, Predicted=2267.0204, Expected=2270.5400
# Month=55, Predicted=2269.9971, Expected=2262.9299
# Month=56, Predicted=2262.6454, Expected=2260.2500
# Month=57, Predicted=2261.5451, Expected=2266.2300
# Month=58, Predicted=2266.5280, Expected=2270.2300
# Month=59, Predicted=2269.3836, Expected=2249.5000
# Month=60, Predicted=2248.7935, Expected=2251.6101
# Run 28 — RMSE: 11.269431, MSE: 127.000077, NMSE: 0.0007710686
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=2156.2468, Expected=2158.2200
# Month=2, Predicted=2159.4424, Expected=2164.1899
# Month=3, Predicted=2163.1983, Expected=2160.3899
# Month=4, Predicted=2159.5631, Expected=2161.3501
# Month=5, Predicted=2161.6487, Expected=2137.6699
# Month=6, Predicted=2136.8502, Expected=2130.2600
# Month=7, Predicted=2133.9523, Expected=2139.6799
# Month=8, Predicted=2137.9827, Expected=2132.9500
# Month=9, Predicted=2130.6541, Expected=2138.3101
# Month=10, Predicted=2138.5408, Expected=2140.8101
# Month=11, Predicted=2139.2345, Expected=2142.5100
# Month=12, Predicted=2141.5047, Expected=2139.4299
# Month=13, Predicted=2138.3519, Expected=2148.5000
# Month=14, Predicted=2147.5533, Expected=2149.7200
# Month=15, Predicted=2147.7880, Expected=2136.9700
# Month=16, Predicted=2136.3171, Expected=2144.0601
# Month=17, Predicted=2144.5528, Expected=2132.2300
# Month=18, Predicted=2130.0983, Expected=2129.7800
# Month=19, Predicted=2130.6755, Expected=2128.6799
# Month=20, Predicted=2127.0832, Expected=2109.4299
# Month=21, Predicted=2107.8607, Expected=2098.8000
# Month=22, Predicted=2099.8597, Expected=2083.7900
# Month=23, Predicted=2081.6951, Expected=2100.5901
# Month=24, Predicted=2098.7120, Expected=2129.9199
# Month=25, Predicted=2127.0507, Expected=2131.5601
# Month=26, Predicted=2130.4933, Expected=2167.4900
# Month=27, Predicted=2167.6122, Expected=2162.7100
# Month=28, Predicted=2162.7253, Expected=2165.6399
# Month=29, Predicted=2170.0203, Expected=2168.2900
# Month=30, Predicted=2169.8138, Expected=2177.5300
# Month=31, Predicted=2178.3907, Expected=2178.6101
# Month=32, Predicted=2178.4222, Expected=2186.8501
# Month=33, Predicted=2187.5338, Expected=2186.4299
# Month=34, Predicted=2185.7259, Expected=2201.5601
# Month=35, Predicted=2201.7293, Expected=2198.5500
# Month=36, Predicted=2197.1081, Expected=2206.2700
# Month=37, Predicted=2207.3854, Expected=2210.2100
# Month=38, Predicted=2209.2506, Expected=2200.7600
# Month=39, Predicted=2200.4199, Expected=2204.9700
# Month=40, Predicted=2205.8961, Expected=2200.1699
# Month=41, Predicted=2198.5594, Expected=2191.1201
# Month=42, Predicted=2190.8887, Expected=2200.6499
# Month=43, Predicted=2199.9698, Expected=2207.2600
# Month=44, Predicted=2204.8406, Expected=2210.7200
# Month=45, Predicted=2209.3720, Expected=2241.1299
# Month=46, Predicted=2239.6863, Expected=2249.7300
# Month=47, Predicted=2248.2574, Expected=2258.8301
# Month=48, Predicted=2259.4227, Expected=2263.3201
# Month=49, Predicted=2263.2454, Expected=2268.3501
# Month=50, Predicted=2268.3500, Expected=2253.7700
# Month=51, Predicted=2253.4245, Expected=2266.8101
# Month=52, Predicted=2269.0047, Expected=2259.2400
# Month=53, Predicted=2257.4805, Expected=2266.5000
# Month=54, Predicted=2268.2821, Expected=2270.5400
# Month=55, Predicted=2269.5407, Expected=2262.9299
# Month=56, Predicted=2262.5870, Expected=2260.2500
# Month=57, Predicted=2260.9407, Expected=2266.2300
# Month=58, Predicted=2265.0884, Expected=2270.2300
# Month=59, Predicted=2268.3704, Expected=2249.5000
# Month=60, Predicted=2248.4205, Expected=2251.6101
# Run 29 — RMSE: 11.398354, MSE: 129.922482, NMSE: 0.0007812496
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=2155.5407, Expected=2158.2200
# Month=2, Predicted=2159.3491, Expected=2164.1899
# Month=3, Predicted=2163.2982, Expected=2160.3899
# Month=4, Predicted=2159.7304, Expected=2161.3501
# Month=5, Predicted=2162.2458, Expected=2137.6699
# Month=6, Predicted=2137.2087, Expected=2130.2600
# Month=7, Predicted=2134.1650, Expected=2139.6799
# Month=8, Predicted=2138.8487, Expected=2132.9500
# Month=9, Predicted=2131.2349, Expected=2138.3101
# Month=10, Predicted=2139.0920, Expected=2140.8101
# Month=11, Predicted=2139.8824, Expected=2142.5100
# Month=12, Predicted=2142.3284, Expected=2139.4299
# Month=13, Predicted=2139.3327, Expected=2148.5000
# Month=14, Predicted=2149.0030, Expected=2149.7200
# Month=15, Predicted=2148.5919, Expected=2136.9700
# Month=16, Predicted=2137.3578, Expected=2144.0601
# Month=17, Predicted=2146.3946, Expected=2132.2300
# Month=18, Predicted=2130.6436, Expected=2129.7800
# Month=19, Predicted=2131.5575, Expected=2128.6799
# Month=20, Predicted=2128.1542, Expected=2109.4299
# Month=21, Predicted=2108.8249, Expected=2098.8000
# Month=22, Predicted=2101.0431, Expected=2083.7900
# Month=23, Predicted=2083.2861, Expected=2100.5901
# Month=24, Predicted=2100.6649, Expected=2129.9199
# Month=25, Predicted=2128.6763, Expected=2131.5601
# Month=26, Predicted=2131.3173, Expected=2167.4900
# Month=27, Predicted=2170.1533, Expected=2162.7100
# Month=28, Predicted=2160.7981, Expected=2165.6399
# Month=29, Predicted=2170.9937, Expected=2168.2900
# Month=30, Predicted=2169.2182, Expected=2177.5300
# Month=31, Predicted=2178.1149, Expected=2178.6101
# Month=32, Predicted=2178.2140, Expected=2186.8501
# Month=33, Predicted=2188.0744, Expected=2186.4299
# Month=34, Predicted=2186.2322, Expected=2201.5601
# Month=35, Predicted=2202.8696, Expected=2198.5500
# Month=36, Predicted=2197.4929, Expected=2206.2700
# Month=37, Predicted=2208.4472, Expected=2210.2100
# Month=38, Predicted=2209.8218, Expected=2200.7600
# Month=39, Predicted=2201.1395, Expected=2204.9700
# Month=40, Predicted=2207.3012, Expected=2200.1699
# Month=41, Predicted=2199.3207, Expected=2191.1201
# Month=42, Predicted=2191.9084, Expected=2200.6499
# Month=43, Predicted=2201.5883, Expected=2207.2600
# Month=44, Predicted=2205.8937, Expected=2210.7200
# Month=45, Predicted=2210.5503, Expected=2241.1299
# Month=46, Predicted=2241.6148, Expected=2249.7300
# Month=47, Predicted=2248.3171, Expected=2258.8301
# Month=48, Predicted=2260.8737, Expected=2263.3201
# Month=49, Predicted=2264.2344, Expected=2268.3501
# Month=50, Predicted=2269.6079, Expected=2253.7700
# Month=51, Predicted=2254.2885, Expected=2266.8101
# Month=52, Predicted=2270.8212, Expected=2259.2400
# Month=53, Predicted=2257.4061, Expected=2266.5000
# Month=54, Predicted=2268.5800, Expected=2270.5400
# Month=55, Predicted=2269.8202, Expected=2262.9299
# Month=56, Predicted=2263.0258, Expected=2260.2500
# Month=57, Predicted=2261.9045, Expected=2266.2300
# Month=58, Predicted=2266.2035, Expected=2270.2300
# Month=59, Predicted=2269.3184, Expected=2249.5000
# Month=60, Predicted=2249.1865, Expected=2251.6101
# Run 30 — RMSE: 11.319049, MSE: 128.120868, NMSE: 0.0007710808

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (2 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on S&P 500 (2 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on S&P 500 (30 runs) =====
# RMSE: 12.739369 ± 7.144617
# MSE:  213.337077 ± 447.067952
# NMSE: 0.0010685295 ± 0.0015174617
#
# Best run: 21
#   RMSE: 11.229627
#   MSE:  126.104528
#   NMSE: 0.0007631512

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Feature Augmentation — S&P 500\nPredictions vs Actual (Best of 2 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Feature Augmentation — S&P 500\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 11.229627
# MSE:  126.104528
# NMSE: 0.0007631512

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on S&P 500
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
