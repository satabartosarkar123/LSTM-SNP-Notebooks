# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value clipped to $[0, 1]$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Gate Replacement
# Uses FuzzyLSTMSNPCell instead of LSTMSNPCell.
# Gradient clipping applied for stability.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 473 (1.85 KB)
#  Trainable params: 473 (1.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load
#  Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 2)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (107, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (107, 1, 1), y_train shape: (107,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(2):
    print(f'\n===== RUN {run+1}/2 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=752.3788, Expected=804.0000
# Month=2, Predicted=807.6568, Expected=756.0000
# Month=3, Predicted=744.1771, Expected=860.0000
# Month=4, Predicted=864.6534, Expected=878.0000
# Month=5, Predicted=883.9131, Expected=942.0000
# Month=6, Predicted=946.5903, Expected=913.0000
# Month=7, Predicted=910.5318, Expected=869.0000
# Month=8, Predicted=855.9307, Expected=834.0000
# Month=9, Predicted=823.6359, Expected=790.0000
# Month=10, Predicted=776.2751, Expected=800.0000
# Month=11, Predicted=799.1254, Expected=763.0000
# Month=12, Predicted=756.2909, Expected=800.0000
# Month=13, Predicted=801.1448, Expected=826.0000
# Month=14, Predicted=827.9408, Expected=799.0000
# Month=15, Predicted=796.5960, Expected=890.0000
# Month=16, Predicted=894.9709, Expected=900.0000
# Month=17, Predicted=903.9091, Expected=961.0000
# Month=18, Predicted=965.2871, Expected=935.0000
# Month=19, Predicted=933.2867, Expected=894.0000
# Month=20, Predicted=882.6416, Expected=855.0000
# Month=21, Predicted=843.0019, Expected=809.0000
# Month=22, Predicted=793.9791, Expected=810.0000
# Month=23, Predicted=808.4783, Expected=766.0000
# Month=24, Predicted=755.2492, Expected=805.0000
# Month=25, Predicted=805.9140, Expected=821.0000
# Month=26, Predicted=822.3200, Expected=773.0000
# Month=27, Predicted=760.9968, Expected=883.0000
# Month=28, Predicted=887.8025, Expected=898.0000
# Month=29, Predicted=904.5205, Expected=957.0000
# Month=30, Predicted=961.2372, Expected=924.0000
# Month=31, Predicted=920.0961, Expected=881.0000
# Month=32, Predicted=867.9961, Expected=837.0000
# Month=33, Predicted=822.4546, Expected=784.0000
# Month=34, Predicted=765.6080, Expected=791.0000
# Month=35, Predicted=789.4703, Expected=760.0000
# Month=36, Predicted=756.2017, Expected=802.0000
# Month=37, Predicted=803.7399, Expected=828.0000
# Month=38, Predicted=829.9778, Expected=778.0000
# Month=39, Predicted=765.0764, Expected=889.0000
# Month=40, Predicted=893.7604, Expected=902.0000
# Month=41, Predicted=908.5225, Expected=969.0000
# Month=42, Predicted=973.7221, Expected=947.0000
# Month=43, Predicted=946.7277, Expected=908.0000
# Month=44, Predicted=898.0166, Expected=867.0000
# Month=45, Predicted=854.2695, Expected=815.0000
# Month=46, Predicted=797.2912, Expected=812.0000
# Month=47, Predicted=809.9257, Expected=773.0000
# Month=48, Predicted=764.5098, Expected=813.0000
# Month=49, Predicted=814.2285, Expected=834.0000
# Month=50, Predicted=835.6410, Expected=782.0000
# Month=51, Predicted=768.2397, Expected=892.0000
# Month=52, Predicted=896.6659, Expected=903.0000
# Month=53, Predicted=909.2463, Expected=966.0000
# Month=54, Predicted=970.4357, Expected=937.0000
# Month=55, Predicted=934.4872, Expected=896.0000
# Month=56, Predicted=884.3470, Expected=858.0000
# Month=57, Predicted=846.4850, Expected=817.0000
# Month=58, Predicted=804.3566, Expected=827.0000
# Month=59, Predicted=826.2745, Expected=797.0000
# Month=60, Predicted=793.5899, Expected=843.0000
# Run 1 — RMSE: 48.842560, MSE: 2385.595645, NMSE: 0.0095517597
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=755.3458, Expected=804.0000
# Month=2, Predicted=809.0941, Expected=756.0000
# Month=3, Predicted=741.9467, Expected=860.0000
# Month=4, Predicted=857.4515, Expected=878.0000
# Month=5, Predicted=884.6525, Expected=942.0000
# Month=6, Predicted=946.7759, Expected=913.0000
# Month=7, Predicted=906.2492, Expected=869.0000
# Month=8, Predicted=854.6957, Expected=834.0000
# Month=9, Predicted=822.1389, Expected=790.0000
# Month=10, Predicted=775.1652, Expected=800.0000
# Month=11, Predicted=800.6995, Expected=763.0000
# Month=12, Predicted=753.4234, Expected=800.0000
# Month=13, Predicted=804.1884, Expected=826.0000
# Month=14, Predicted=830.6243, Expected=799.0000
# Month=15, Predicted=792.6997, Expected=890.0000
# Month=16, Predicted=890.5313, Expected=900.0000
# Month=17, Predicted=904.4673, Expected=961.0000
# Month=18, Predicted=965.9847, Expected=935.0000
# Month=19, Predicted=929.1428, Expected=894.0000
# Month=20, Predicted=881.2037, Expected=855.0000
# Month=21, Predicted=841.7978, Expected=809.0000
# Month=22, Predicted=792.8926, Expected=810.0000
# Month=23, Predicted=808.6895, Expected=766.0000
# Month=24, Predicted=753.3727, Expected=805.0000
# Month=25, Predicted=808.9535, Expected=821.0000
# Month=26, Predicted=824.5709, Expected=773.0000
# Month=27, Predicted=758.9753, Expected=883.0000
# Month=28, Predicted=879.0989, Expected=898.0000
# Month=29, Predicted=904.7359, Expected=957.0000
# Month=30, Predicted=962.0958, Expected=924.0000
# Month=31, Predicted=915.8300, Expected=881.0000
# Month=32, Predicted=866.8042, Expected=837.0000
# Month=33, Predicted=821.4232, Expected=784.0000
# Month=34, Predicted=764.3004, Expected=791.0000
# Month=35, Predicted=790.4632, Expected=760.0000
# Month=36, Predicted=752.3733, Expected=802.0000
# Month=37, Predicted=806.5924, Expected=828.0000
# Month=38, Predicted=832.6166, Expected=778.0000
# Month=39, Predicted=763.0324, Expected=889.0000
# Month=40, Predicted=884.8542, Expected=902.0000
# Month=41, Predicted=908.4997, Expected=969.0000
# Month=42, Predicted=973.5303, Expected=947.0000
# Month=43, Predicted=942.5366, Expected=908.0000
# Month=44, Predicted=896.3056, Expected=867.0000
# Month=45, Predicted=853.1268, Expected=815.0000
# Month=46, Predicted=796.0269, Expected=812.0000
# Month=47, Predicted=809.2615, Expected=773.0000
# Month=48, Predicted=762.2331, Expected=813.0000
# Month=49, Predicted=817.2169, Expected=834.0000
# Month=50, Predicted=838.1549, Expected=782.0000
# Month=51, Predicted=766.1328, Expected=892.0000
# Month=52, Predicted=888.0598, Expected=903.0000
# Month=53, Predicted=909.0682, Expected=966.0000
# Month=54, Predicted=970.8378, Expected=937.0000
# Month=55, Predicted=930.2253, Expected=896.0000
# Month=56, Predicted=882.9771, Expected=858.0000
# Month=57, Predicted=845.2267, Expected=817.0000
# Month=58, Predicted=803.2041, Expected=827.0000
# Month=59, Predicted=827.8941, Expected=797.0000
# Month=60, Predicted=789.7633, Expected=843.0000
# Run 2 — RMSE: 49.460998, MSE: 2446.390291, NMSE: 0.0098998344
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=747.6779, Expected=804.0000
# Month=2, Predicted=790.7025, Expected=756.0000
# Month=3, Predicted=752.6779, Expected=860.0000
# Month=4, Predicted=856.6725, Expected=878.0000
# Month=5, Predicted=874.6779, Expected=942.0000
# Month=6, Predicted=928.0056, Expected=913.0000
# Month=7, Predicted=909.6779, Expected=869.0000
# Month=8, Predicted=865.6779, Expected=834.0000
# Month=9, Predicted=830.6779, Expected=790.0000
# Month=10, Predicted=786.6779, Expected=800.0000
# Month=11, Predicted=796.6779, Expected=763.0000
# Month=12, Predicted=759.6779, Expected=800.0000
# Month=13, Predicted=796.6779, Expected=826.0000
# Month=14, Predicted=822.6779, Expected=799.0000
# Month=15, Predicted=795.6779, Expected=890.0000
# Month=16, Predicted=886.6779, Expected=900.0000
# Month=17, Predicted=896.6779, Expected=961.0000
# Month=18, Predicted=946.5377, Expected=935.0000
# Month=19, Predicted=931.6779, Expected=894.0000
# Month=20, Predicted=890.6779, Expected=855.0000
# Month=21, Predicted=851.6779, Expected=809.0000
# Month=22, Predicted=805.6779, Expected=810.0000
# Month=23, Predicted=806.6779, Expected=766.0000
# Month=24, Predicted=762.6779, Expected=805.0000
# Month=25, Predicted=801.6779, Expected=821.0000
# Month=26, Predicted=817.6779, Expected=773.0000
# Month=27, Predicted=769.6779, Expected=883.0000
# Month=28, Predicted=879.6518, Expected=898.0000
# Month=29, Predicted=894.6779, Expected=957.0000
# Month=30, Predicted=942.4571, Expected=924.0000
# Month=31, Predicted=920.6779, Expected=881.0000
# Month=32, Predicted=877.6779, Expected=837.0000
# Month=33, Predicted=833.6779, Expected=784.0000
# Month=34, Predicted=780.6779, Expected=791.0000
# Month=35, Predicted=787.6779, Expected=760.0000
# Month=36, Predicted=756.6779, Expected=802.0000
# Month=37, Predicted=796.6829, Expected=828.0000
# Month=38, Predicted=824.6779, Expected=778.0000
# Month=39, Predicted=774.6779, Expected=889.0000
# Month=40, Predicted=885.6490, Expected=902.0000
# Month=41, Predicted=898.6779, Expected=969.0000
# Month=42, Predicted=955.9159, Expected=947.0000
# Month=43, Predicted=943.6779, Expected=908.0000
# Month=44, Predicted=904.6779, Expected=867.0000
# Month=45, Predicted=863.6779, Expected=815.0000
# Month=46, Predicted=811.6779, Expected=812.0000
# Month=47, Predicted=808.6779, Expected=773.0000
# Month=48, Predicted=769.6779, Expected=813.0000
# Month=49, Predicted=809.6779, Expected=834.0000
# Month=50, Predicted=830.6779, Expected=782.0000
# Month=51, Predicted=778.6779, Expected=892.0000
# Month=52, Predicted=888.6534, Expected=903.0000
# Month=53, Predicted=899.6779, Expected=966.0000
# Month=54, Predicted=951.8149, Expected=937.0000
# Month=55, Predicted=933.6779, Expected=896.0000
# Month=56, Predicted=892.6779, Expected=858.0000
# Month=57, Predicted=854.6779, Expected=817.0000
# Month=58, Predicted=813.6779, Expected=827.0000
# Month=59, Predicted=823.6779, Expected=797.0000
# Month=60, Predicted=793.6779, Expected=843.0000
# Run 3 — RMSE: 47.822716, MSE: 2287.012154, NMSE: 0.0106594065
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=753.5502, Expected=804.0000
# Month=2, Predicted=806.7884, Expected=756.0000
# Month=3, Predicted=743.6639, Expected=860.0000
# Month=4, Predicted=858.4582, Expected=878.0000
# Month=5, Predicted=886.1822, Expected=942.0000
# Month=6, Predicted=943.8517, Expected=913.0000
# Month=7, Predicted=909.0673, Expected=869.0000
# Month=8, Predicted=857.1054, Expected=834.0000
# Month=9, Predicted=825.2158, Expected=790.0000
# Month=10, Predicted=777.6864, Expected=800.0000
# Month=11, Predicted=801.6082, Expected=763.0000
# Month=12, Predicted=755.5744, Expected=800.0000
# Month=13, Predicted=802.6790, Expected=826.0000
# Month=14, Predicted=830.3348, Expected=799.0000
# Month=15, Predicted=794.9487, Expected=890.0000
# Month=16, Predicted=889.8859, Expected=900.0000
# Month=17, Predicted=906.2213, Expected=961.0000
# Month=18, Predicted=963.1512, Expected=935.0000
# Month=19, Predicted=931.8479, Expected=894.0000
# Month=20, Predicted=883.6479, Expected=855.0000
# Month=21, Predicted=844.6214, Expected=809.0000
# Month=22, Predicted=795.5052, Expected=810.0000
# Month=23, Predicted=810.3098, Expected=766.0000
# Month=24, Predicted=755.2326, Expected=805.0000
# Month=25, Predicted=807.1642, Expected=821.0000
# Month=26, Predicted=825.0133, Expected=773.0000
# Month=27, Predicted=760.4295, Expected=883.0000
# Month=28, Predicted=881.2526, Expected=898.0000
# Month=29, Predicted=906.6547, Expected=957.0000
# Month=30, Predicted=959.2811, Expected=924.0000
# Month=31, Predicted=918.6111, Expected=881.0000
# Month=32, Predicted=869.3388, Expected=837.0000
# Month=33, Predicted=824.1729, Expected=784.0000
# Month=34, Predicted=766.8866, Expected=791.0000
# Month=35, Predicted=791.6439, Expected=760.0000
# Month=36, Predicted=754.8060, Expected=802.0000
# Month=37, Predicted=804.6553, Expected=828.0000
# Month=38, Predicted=832.4133, Expected=778.0000
# Month=39, Predicted=764.4257, Expected=889.0000
# Month=40, Predicted=887.1350, Expected=902.0000
# Month=41, Predicted=910.5946, Expected=969.0000
# Month=42, Predicted=970.7094, Expected=947.0000
# Month=43, Predicted=945.2576, Expected=908.0000
# Month=44, Predicted=898.7681, Expected=867.0000
# Month=45, Predicted=855.8465, Expected=815.0000
# Month=46, Predicted=798.5700, Expected=812.0000
# Month=47, Predicted=811.2264, Expected=773.0000
# Month=48, Predicted=764.4650, Expected=813.0000
# Month=49, Predicted=815.3858, Expected=834.0000
# Month=50, Predicted=838.2775, Expected=782.0000
# Month=51, Predicted=767.4851, Expected=892.0000
# Month=52, Predicted=890.0526, Expected=903.0000
# Month=53, Predicted=911.2734, Expected=966.0000
# Month=54, Predicted=968.0055, Expected=937.0000
# Month=55, Predicted=933.0259, Expected=896.0000
# Month=56, Predicted=885.4941, Expected=858.0000
# Month=57, Predicted=848.0731, Expected=817.0000
# Month=58, Predicted=805.8842, Expected=827.0000
# Month=59, Predicted=828.7897, Expected=797.0000
# Month=60, Predicted=792.1329, Expected=843.0000
# Run 4 — RMSE: 49.075148, MSE: 2408.370108, NMSE: 0.0098925400
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=752.4139, Expected=804.0000
# Month=2, Predicted=805.9355, Expected=756.0000
# Month=3, Predicted=744.6783, Expected=860.0000
# Month=4, Predicted=864.1842, Expected=878.0000
# Month=5, Predicted=878.9968, Expected=942.0000
# Month=6, Predicted=944.3838, Expected=913.0000
# Month=7, Predicted=906.3365, Expected=869.0000
# Month=8, Predicted=858.5652, Expected=834.0000
# Month=9, Predicted=826.0062, Expected=790.0000
# Month=10, Predicted=779.5586, Expected=800.0000
# Month=11, Predicted=798.9688, Expected=763.0000
# Month=12, Predicted=754.5210, Expected=800.0000
# Month=13, Predicted=801.2839, Expected=826.0000
# Month=14, Predicted=826.7453, Expected=799.0000
# Month=15, Predicted=792.4004, Expected=890.0000
# Month=16, Predicted=893.6058, Expected=900.0000
# Month=17, Predicted=899.6036, Expected=961.0000
# Month=18, Predicted=963.2660, Expected=935.0000
# Month=19, Predicted=928.7459, Expected=894.0000
# Month=20, Predicted=884.3800, Expected=855.0000
# Month=21, Predicted=845.9084, Expected=809.0000
# Month=22, Predicted=798.0178, Expected=810.0000
# Month=23, Predicted=807.6032, Expected=766.0000
# Month=24, Predicted=755.6026, Expected=805.0000
# Month=25, Predicted=806.3798, Expected=821.0000
# Month=26, Predicted=820.8963, Expected=773.0000
# Month=27, Predicted=761.5532, Expected=883.0000
# Month=28, Predicted=887.4378, Expected=898.0000
# Month=29, Predicted=898.7817, Expected=957.0000
# Month=30, Predicted=959.1719, Expected=924.0000
# Month=31, Predicted=916.7035, Expected=881.0000
# Month=32, Predicted=870.8302, Expected=837.0000
# Month=33, Predicted=826.5497, Expected=784.0000
# Month=34, Predicted=771.1628, Expected=791.0000
# Month=35, Predicted=789.5163, Expected=760.0000
# Month=36, Predicted=752.8174, Expected=802.0000
# Month=37, Predicted=803.4951, Expected=828.0000
# Month=38, Predicted=828.7621, Expected=778.0000
# Month=39, Predicted=766.0340, Expected=889.0000
# Month=40, Predicted=893.4823, Expected=902.0000
# Month=41, Predicted=902.4984, Expected=969.0000
# Month=42, Predicted=971.5212, Expected=947.0000
# Month=43, Predicted=941.4016, Expected=908.0000
# Month=44, Predicted=898.9301, Expected=867.0000
# Month=45, Predicted=857.3654, Expected=815.0000
# Month=46, Predicted=802.4277, Expected=812.0000
# Month=47, Predicted=809.0003, Expected=773.0000
# Month=48, Predicted=763.9543, Expected=813.0000
# Month=49, Predicted=814.4176, Expected=834.0000
# Month=50, Predicted=834.5345, Expected=782.0000
# Month=51, Predicted=769.5029, Expected=892.0000
# Month=52, Predicted=896.4423, Expected=903.0000
# Month=53, Predicted=903.1666, Expected=966.0000
# Month=54, Predicted=968.3513, Expected=937.0000
# Month=55, Predicted=930.3259, Expected=896.0000
# Month=56, Predicted=886.3765, Expected=858.0000
# Month=57, Predicted=849.1824, Expected=817.0000
# Month=58, Predicted=807.3664, Expected=827.0000
# Month=59, Predicted=825.9676, Expected=797.0000
# Month=60, Predicted=789.9617, Expected=843.0000
# Run 5 — RMSE: 49.183544, MSE: 2419.020974, NMSE: 0.0100583819
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=758.6700, Expected=804.0000
# Month=2, Predicted=811.0519, Expected=756.0000
# Month=3, Predicted=747.1892, Expected=860.0000
# Month=4, Predicted=854.1773, Expected=878.0000
# Month=5, Predicted=889.9214, Expected=942.0000
# Month=6, Predicted=946.1089, Expected=913.0000
# Month=7, Predicted=911.8420, Expected=869.0000
# Month=8, Predicted=854.7942, Expected=834.0000
# Month=9, Predicted=820.2484, Expected=790.0000
# Month=10, Predicted=774.5090, Expected=800.0000
# Month=11, Predicted=802.6030, Expected=763.0000
# Month=12, Predicted=757.9507, Expected=800.0000
# Month=13, Predicted=807.6431, Expected=826.0000
# Month=14, Predicted=837.0439, Expected=799.0000
# Month=15, Predicted=799.0394, Expected=890.0000
# Month=16, Predicted=887.4295, Expected=900.0000
# Month=17, Predicted=910.7274, Expected=961.0000
# Month=18, Predicted=966.0193, Expected=935.0000
# Month=19, Predicted=935.0527, Expected=894.0000
# Month=20, Predicted=881.6059, Expected=855.0000
# Month=21, Predicted=840.3077, Expected=809.0000
# Month=22, Predicted=791.9151, Expected=810.0000
# Month=23, Predicted=809.4034, Expected=766.0000
# Month=24, Predicted=756.8314, Expected=805.0000
# Month=25, Predicted=811.9838, Expected=821.0000
# Month=26, Predicted=831.9670, Expected=773.0000
# Month=27, Predicted=764.1396, Expected=883.0000
# Month=28, Predicted=875.5183, Expected=898.0000
# Month=29, Predicted=909.7240, Expected=957.0000
# Month=30, Predicted=962.4618, Expected=924.0000
# Month=31, Predicted=921.2783, Expected=881.0000
# Month=32, Predicted=866.4178, Expected=837.0000
# Month=33, Predicted=819.8914, Expected=784.0000
# Month=34, Predicted=763.2148, Expected=791.0000
# Month=35, Predicted=790.7954, Expected=760.0000
# Month=36, Predicted=756.9719, Expected=802.0000
# Month=37, Predicted=809.9058, Expected=828.0000
# Month=38, Predicted=839.0796, Expected=778.0000
# Month=39, Predicted=768.6021, Expected=889.0000
# Month=40, Predicted=881.2768, Expected=902.0000
# Month=41, Predicted=913.4641, Expected=969.0000
# Month=42, Predicted=972.3837, Expected=947.0000
# Month=43, Predicted=948.5482, Expected=908.0000
# Month=44, Predicted=897.1857, Expected=867.0000
# Month=45, Predicted=851.9419, Expected=815.0000
# Month=46, Predicted=795.2009, Expected=812.0000
# Month=47, Predicted=808.6641, Expected=773.0000
# Month=48, Predicted=765.3200, Expected=813.0000
# Month=49, Predicted=820.4244, Expected=834.0000
# Month=50, Predicted=845.1563, Expected=782.0000
# Month=51, Predicted=771.7503, Expected=892.0000
# Month=52, Predicted=884.5824, Expected=903.0000
# Month=53, Predicted=914.1266, Expected=966.0000
# Month=54, Predicted=970.4874, Expected=937.0000
# Month=55, Predicted=935.8456, Expected=896.0000
# Month=56, Predicted=883.0182, Expected=858.0000
# Month=57, Predicted=843.6999, Expected=817.0000
# Month=58, Predicted=802.1010, Expected=827.0000
# Month=59, Predicted=830.1767, Expected=797.0000
# Month=60, Predicted=794.7814, Expected=843.0000
# Run 6 — RMSE: 48.410194, MSE: 2343.546835, NMSE: 0.0096463964
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=754.4129, Expected=804.0000
# Month=2, Predicted=807.0660, Expected=756.0000
# Month=3, Predicted=740.5632, Expected=860.0000
# Month=4, Predicted=857.0196, Expected=878.0000
# Month=5, Predicted=887.3334, Expected=942.0000
# Month=6, Predicted=943.5674, Expected=913.0000
# Month=7, Predicted=908.2234, Expected=869.0000
# Month=8, Predicted=854.8506, Expected=834.0000
# Month=9, Predicted=823.6738, Expected=790.0000
# Month=10, Predicted=775.4063, Expected=800.0000
# Month=11, Predicted=804.0270, Expected=763.0000
# Month=12, Predicted=754.2789, Expected=800.0000
# Month=13, Predicted=803.7246, Expected=826.0000
# Month=14, Predicted=832.2945, Expected=799.0000
# Month=15, Predicted=795.4544, Expected=890.0000
# Month=16, Predicted=889.5109, Expected=900.0000
# Month=17, Predicted=907.7198, Expected=961.0000
# Month=18, Predicted=962.9183, Expected=935.0000
# Month=19, Predicted=931.6558, Expected=894.0000
# Month=20, Predicted=881.7789, Expected=855.0000
# Month=21, Predicted=842.7550, Expected=809.0000
# Month=22, Predicted=792.9338, Expected=810.0000
# Month=23, Predicted=812.7227, Expected=766.0000
# Month=24, Predicted=753.1539, Expected=805.0000
# Month=25, Predicted=808.0071, Expected=821.0000
# Month=26, Predicted=827.5256, Expected=773.0000
# Month=27, Predicted=757.8779, Expected=883.0000
# Month=28, Predicted=879.3076, Expected=898.0000
# Month=29, Predicted=907.8389, Expected=957.0000
# Month=30, Predicted=959.1776, Expected=924.0000
# Month=31, Predicted=917.1194, Expected=881.0000
# Month=32, Predicted=867.1414, Expected=837.0000
# Month=33, Predicted=821.7504, Expected=784.0000
# Month=34, Predicted=763.3809, Expected=791.0000
# Month=35, Predicted=793.9307, Expected=760.0000
# Month=36, Predicted=754.5043, Expected=802.0000
# Month=37, Predicted=805.4396, Expected=828.0000
# Month=38, Predicted=834.3103, Expected=778.0000
# Month=39, Predicted=761.6185, Expected=889.0000
# Month=40, Predicted=885.0673, Expected=902.0000
# Month=41, Predicted=911.8289, Expected=969.0000
# Month=42, Predicted=970.2359, Expected=947.0000
# Month=43, Predicted=945.5350, Expected=908.0000
# Month=44, Predicted=897.1656, Expected=867.0000
# Month=45, Predicted=853.8028, Expected=815.0000
# Month=46, Predicted=795.2362, Expected=812.0000
# Month=47, Predicted=813.3795, Expected=773.0000
# Month=48, Predicted=762.9622, Expected=813.0000
# Month=49, Predicted=816.2218, Expected=834.0000
# Month=50, Predicted=840.5111, Expected=782.0000
# Month=51, Predicted=764.4588, Expected=892.0000
# Month=52, Predicted=888.0195, Expected=903.0000
# Month=53, Predicted=912.5664, Expected=966.0000
# Month=54, Predicted=967.6752, Expected=937.0000
# Month=55, Predicted=932.2130, Expected=896.0000
# Month=56, Predicted=883.5777, Expected=858.0000
# Month=57, Predicted=846.3101, Expected=817.0000
# Month=58, Predicted=803.8840, Expected=827.0000
# Month=59, Predicted=831.2685, Expected=797.0000
# Month=60, Predicted=792.0278, Expected=843.0000
# Run 7 — RMSE: 49.648336, MSE: 2464.957295, NMSE: 0.0100304790
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=746.2649, Expected=804.0000
# Month=2, Predicted=799.2649, Expected=756.0000
# Month=3, Predicted=751.2649, Expected=860.0000
# Month=4, Predicted=855.2649, Expected=878.0000
# Month=5, Predicted=873.2649, Expected=942.0000
# Month=6, Predicted=937.2649, Expected=913.0000
# Month=7, Predicted=908.2649, Expected=869.0000
# Month=8, Predicted=864.2649, Expected=834.0000
# Month=9, Predicted=829.2649, Expected=790.0000
# Month=10, Predicted=785.2649, Expected=800.0000
# Month=11, Predicted=795.2649, Expected=763.0000
# Month=12, Predicted=758.2649, Expected=800.0000
# Month=13, Predicted=795.2649, Expected=826.0000
# Month=14, Predicted=821.2649, Expected=799.0000
# Month=15, Predicted=794.2649, Expected=890.0000
# Month=16, Predicted=885.2649, Expected=900.0000
# Month=17, Predicted=895.2649, Expected=961.0000
# Month=18, Predicted=956.2649, Expected=935.0000
# Month=19, Predicted=930.2649, Expected=894.0000
# Month=20, Predicted=889.2649, Expected=855.0000
# Month=21, Predicted=850.2649, Expected=809.0000
# Month=22, Predicted=804.2649, Expected=810.0000
# Month=23, Predicted=805.2649, Expected=766.0000
# Month=24, Predicted=761.2649, Expected=805.0000
# Month=25, Predicted=800.2649, Expected=821.0000
# Month=26, Predicted=816.2649, Expected=773.0000
# Month=27, Predicted=768.2649, Expected=883.0000
# Month=28, Predicted=878.2649, Expected=898.0000
# Month=29, Predicted=893.2649, Expected=957.0000
# Month=30, Predicted=952.2649, Expected=924.0000
# Month=31, Predicted=919.2649, Expected=881.0000
# Month=32, Predicted=876.2649, Expected=837.0000
# Month=33, Predicted=832.2649, Expected=784.0000
# Month=34, Predicted=779.2649, Expected=791.0000
# Month=35, Predicted=786.2649, Expected=760.0000
# Month=36, Predicted=755.2649, Expected=802.0000
# Month=37, Predicted=797.2649, Expected=828.0000
# Month=38, Predicted=823.2649, Expected=778.0000
# Month=39, Predicted=773.2649, Expected=889.0000
# Month=40, Predicted=884.2649, Expected=902.0000
# Month=41, Predicted=897.2649, Expected=969.0000
# Month=42, Predicted=964.2649, Expected=947.0000
# Month=43, Predicted=942.2649, Expected=908.0000
# Month=44, Predicted=903.2649, Expected=867.0000
# Month=45, Predicted=862.2649, Expected=815.0000
# Month=46, Predicted=810.2649, Expected=812.0000
# Month=47, Predicted=807.2649, Expected=773.0000
# Month=48, Predicted=768.2649, Expected=813.0000
# Month=49, Predicted=808.2649, Expected=834.0000
# Month=50, Predicted=829.2649, Expected=782.0000
# Month=51, Predicted=777.2649, Expected=892.0000
# Month=52, Predicted=887.2649, Expected=903.0000
# Month=53, Predicted=898.2649, Expected=966.0000
# Month=54, Predicted=961.2649, Expected=937.0000
# Month=55, Predicted=932.2649, Expected=896.0000
# Month=56, Predicted=891.2649, Expected=858.0000
# Month=57, Predicted=853.2649, Expected=817.0000
# Month=58, Predicted=812.2649, Expected=827.0000
# Month=59, Predicted=822.2649, Expected=797.0000
# Month=60, Predicted=792.2649, Expected=843.0000
# Run 8 — RMSE: 48.459014, MSE: 2348.275994, NMSE: 0.0104410850
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=751.7595, Expected=804.0000
# Month=2, Predicted=795.1509, Expected=756.0000
# Month=3, Predicted=741.8320, Expected=860.0000
# Month=4, Predicted=888.4950, Expected=878.0000
# Month=5, Predicted=895.6109, Expected=942.0000
# Month=6, Predicted=918.5831, Expected=913.0000
# Month=7, Predicted=907.0094, Expected=869.0000
# Month=8, Predicted=854.9370, Expected=834.0000
# Month=9, Predicted=822.4015, Expected=790.0000
# Month=10, Predicted=775.6659, Expected=800.0000
# Month=11, Predicted=807.0280, Expected=763.0000
# Month=12, Predicted=752.7676, Expected=800.0000
# Month=13, Predicted=802.6928, Expected=826.0000
# Month=14, Predicted=836.0648, Expected=799.0000
# Month=15, Predicted=793.3249, Expected=890.0000
# Month=16, Predicted=904.1255, Expected=900.0000
# Month=17, Predicted=914.6087, Expected=961.0000
# Month=18, Predicted=941.4543, Expected=935.0000
# Month=19, Predicted=930.4379, Expected=894.0000
# Month=20, Predicted=881.1245, Expected=855.0000
# Month=21, Predicted=842.0821, Expected=809.0000
# Month=22, Predicted=793.8287, Expected=810.0000
# Month=23, Predicted=814.1774, Expected=766.0000
# Month=24, Predicted=752.9299, Expected=805.0000
# Month=25, Predicted=806.0362, Expected=821.0000
# Month=26, Predicted=832.3961, Expected=773.0000
# Month=27, Predicted=758.6145, Expected=883.0000
# Month=28, Predicted=916.1887, Expected=898.0000
# Month=29, Predicted=915.9763, Expected=957.0000
# Month=30, Predicted=939.9083, Expected=924.0000
# Month=31, Predicted=915.9615, Expected=881.0000
# Month=32, Predicted=867.0950, Expected=837.0000
# Month=33, Predicted=822.2547, Expected=784.0000
# Month=34, Predicted=766.5830, Expected=791.0000
# Month=35, Predicted=796.3233, Expected=760.0000
# Month=36, Predicted=752.4154, Expected=802.0000
# Month=37, Predicted=801.4859, Expected=828.0000
# Month=38, Predicted=838.3671, Expected=778.0000
# Month=39, Predicted=762.9724, Expected=889.0000
# Month=40, Predicted=923.0858, Expected=902.0000
# Month=41, Predicted=919.6773, Expected=969.0000
# Month=42, Predicted=947.7180, Expected=947.0000
# Month=43, Predicted=944.7221, Expected=908.0000
# Month=44, Predicted=896.0481, Expected=867.0000
# Month=45, Predicted=853.4808, Expected=815.0000
# Month=46, Predicted=797.9902, Expected=812.0000
# Month=47, Predicted=813.9323, Expected=773.0000
# Month=48, Predicted=761.7598, Expected=813.0000
# Month=49, Predicted=813.6161, Expected=834.0000
# Month=50, Predicted=845.2366, Expected=782.0000
# Month=51, Predicted=766.3450, Expected=892.0000
# Month=52, Predicted=925.5264, Expected=903.0000
# Month=53, Predicted=920.0253, Expected=966.0000
# Month=54, Predicted=943.9215, Expected=937.0000
# Month=55, Predicted=930.9822, Expected=896.0000
# Month=56, Predicted=882.9890, Expected=858.0000
# Month=57, Predicted=845.4505, Expected=817.0000
# Month=58, Predicted=803.5386, Expected=827.0000
# Month=59, Predicted=834.3223, Expected=797.0000
# Month=60, Predicted=789.8995, Expected=843.0000
# Run 9 — RMSE: 48.496284, MSE: 2351.889574, NMSE: 0.0096986587
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=749.3944, Expected=804.0000
# Month=2, Predicted=802.3944, Expected=756.0000
# Month=3, Predicted=745.0442, Expected=860.0000
# Month=4, Predicted=858.3944, Expected=878.0000
# Month=5, Predicted=876.3944, Expected=942.0000
# Month=6, Predicted=940.3944, Expected=913.0000
# Month=7, Predicted=911.3944, Expected=869.0000
# Month=8, Predicted=858.2495, Expected=834.0000
# Month=9, Predicted=826.6658, Expected=790.0000
# Month=10, Predicted=778.8672, Expected=800.0000
# Month=11, Predicted=798.3944, Expected=763.0000
# Month=12, Predicted=757.3066, Expected=800.0000
# Month=13, Predicted=798.3944, Expected=826.0000
# Month=14, Predicted=824.3944, Expected=799.0000
# Month=15, Predicted=797.3944, Expected=890.0000
# Month=16, Predicted=888.3944, Expected=900.0000
# Month=17, Predicted=898.3944, Expected=961.0000
# Month=18, Predicted=959.3944, Expected=935.0000
# Month=19, Predicted=933.3944, Expected=894.0000
# Month=20, Predicted=884.8731, Expected=855.0000
# Month=21, Predicted=845.8654, Expected=809.0000
# Month=22, Predicted=796.7031, Expected=810.0000
# Month=23, Predicted=808.3944, Expected=766.0000
# Month=24, Predicted=756.4612, Expected=805.0000
# Month=25, Predicted=803.3944, Expected=821.0000
# Month=26, Predicted=819.3944, Expected=773.0000
# Month=27, Predicted=761.8290, Expected=883.0000
# Month=28, Predicted=881.4033, Expected=898.0000
# Month=29, Predicted=896.3944, Expected=957.0000
# Month=30, Predicted=955.3944, Expected=924.0000
# Month=31, Predicted=921.0637, Expected=881.0000
# Month=32, Predicted=870.4850, Expected=837.0000
# Month=33, Predicted=825.3360, Expected=784.0000
# Month=34, Predicted=768.4805, Expected=791.0000
# Month=35, Predicted=789.3944, Expected=760.0000
# Month=36, Predicted=757.6462, Expected=802.0000
# Month=37, Predicted=800.3944, Expected=828.0000
# Month=38, Predicted=826.3944, Expected=778.0000
# Month=39, Predicted=765.9531, Expected=889.0000
# Month=40, Predicted=887.4050, Expected=902.0000
# Month=41, Predicted=900.3944, Expected=969.0000
# Month=42, Predicted=967.3944, Expected=947.0000
# Month=43, Predicted=945.3944, Expected=908.0000
# Month=44, Predicted=900.1070, Expected=867.0000
# Month=45, Predicted=857.0328, Expected=815.0000
# Month=46, Predicted=800.0557, Expected=812.0000
# Month=47, Predicted=810.3944, Expected=773.0000
# Month=48, Predicted=765.8968, Expected=813.0000
# Month=49, Predicted=811.3944, Expected=834.0000
# Month=50, Predicted=832.3944, Expected=782.0000
# Month=51, Predicted=769.0677, Expected=892.0000
# Month=52, Predicted=890.4032, Expected=903.0000
# Month=53, Predicted=901.3944, Expected=966.0000
# Month=54, Predicted=964.3944, Expected=937.0000
# Month=55, Predicted=935.3944, Expected=896.0000
# Month=56, Predicted=886.6984, Expected=858.0000
# Month=57, Predicted=849.3642, Expected=817.0000
# Month=58, Predicted=807.0932, Expected=827.0000
# Month=59, Predicted=825.3944, Expected=797.0000
# Month=60, Predicted=795.3044, Expected=843.0000
# Run 10 — RMSE: 49.228216, MSE: 2423.417202, NMSE: 0.0102192206
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=750.3637, Expected=804.0000
# Month=2, Predicted=799.9894, Expected=756.0000
# Month=3, Predicted=745.7106, Expected=860.0000
# Month=4, Predicted=876.4594, Expected=878.0000
# Month=5, Predicted=894.4205, Expected=942.0000
# Month=6, Predicted=938.4860, Expected=913.0000
# Month=7, Predicted=914.3138, Expected=869.0000
# Month=8, Predicted=854.3463, Expected=834.0000
# Month=9, Predicted=823.5073, Expected=790.0000
# Month=10, Predicted=773.9606, Expected=800.0000
# Month=11, Predicted=803.6688, Expected=763.0000
# Month=12, Predicted=760.3316, Expected=800.0000
# Month=13, Predicted=800.8003, Expected=826.0000
# Month=14, Predicted=833.4780, Expected=799.0000
# Month=15, Predicted=799.2925, Expected=890.0000
# Month=16, Predicted=898.4204, Expected=900.0000
# Month=17, Predicted=912.8592, Expected=961.0000
# Month=18, Predicted=956.8048, Expected=935.0000
# Month=19, Predicted=936.7553, Expected=894.0000
# Month=20, Predicted=882.4286, Expected=855.0000
# Month=21, Predicted=841.8274, Expected=809.0000
# Month=22, Predicted=790.5434, Expected=810.0000
# Month=23, Predicted=811.4226, Expected=766.0000
# Month=24, Predicted=756.2661, Expected=805.0000
# Month=25, Predicted=804.4634, Expected=821.0000
# Month=26, Predicted=831.1362, Expected=773.0000
# Month=27, Predicted=761.6401, Expected=883.0000
# Month=28, Predicted=904.9555, Expected=898.0000
# Month=29, Predicted=914.5524, Expected=957.0000
# Month=30, Predicted=952.6340, Expected=924.0000
# Month=31, Predicted=924.0881, Expected=881.0000
# Month=32, Predicted=866.3500, Expected=837.0000
# Month=33, Predicted=819.2854, Expected=784.0000
# Month=34, Predicted=759.2533, Expected=791.0000
# Month=35, Predicted=792.8607, Expected=760.0000
# Month=36, Predicted=758.9159, Expected=802.0000
# Month=37, Predicted=800.6449, Expected=828.0000
# Month=38, Predicted=835.6696, Expected=778.0000
# Month=39, Predicted=765.2414, Expected=889.0000
# Month=40, Predicted=911.5746, Expected=902.0000
# Month=41, Predicted=918.2190, Expected=969.0000
# Month=42, Predicted=966.2510, Expected=947.0000
# Month=43, Predicted=950.0951, Expected=908.0000
# Month=44, Predicted=898.9065, Expected=867.0000
# Month=45, Predicted=852.6304, Expected=815.0000
# Month=46, Predicted=791.6115, Expected=812.0000
# Month=47, Predicted=811.8071, Expected=773.0000
# Month=48, Predicted=767.0057, Expected=813.0000
# Month=49, Predicted=812.2141, Expected=834.0000
# Month=50, Predicted=844.4948, Expected=782.0000
# Month=51, Predicted=767.6343, Expected=892.0000
# Month=52, Predicted=913.2969, Expected=903.0000
# Month=53, Predicted=918.5992, Expected=966.0000
# Month=54, Predicted=962.1685, Expected=937.0000
# Month=55, Predicted=938.2385, Expected=896.0000
# Month=56, Predicted=883.8243, Expected=858.0000
# Month=57, Predicted=845.6542, Expected=817.0000
# Month=58, Predicted=802.7717, Expected=827.0000
# Month=59, Predicted=831.0123, Expected=797.0000
# Month=60, Predicted=796.2830, Expected=843.0000
# Run 11 — RMSE: 48.178830, MSE: 2321.199645, NMSE: 0.0091182118
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=753.6458, Expected=804.0000
# Month=2, Predicted=801.7644, Expected=756.0000
# Month=3, Predicted=751.2696, Expected=860.0000
# Month=4, Predicted=878.9238, Expected=878.0000
# Month=5, Predicted=888.7930, Expected=942.0000
# Month=6, Predicted=937.5800, Expected=913.0000
# Month=7, Predicted=919.4646, Expected=869.0000
# Month=8, Predicted=854.0194, Expected=834.0000
# Month=9, Predicted=818.3791, Expected=790.0000
# Month=10, Predicted=771.9115, Expected=800.0000
# Month=11, Predicted=803.3685, Expected=763.0000
# Month=12, Predicted=764.9585, Expected=800.0000
# Month=13, Predicted=803.2251, Expected=826.0000
# Month=14, Predicted=833.8834, Expected=799.0000
# Month=15, Predicted=806.3977, Expected=890.0000
# Month=16, Predicted=898.5976, Expected=900.0000
# Month=17, Predicted=912.2049, Expected=961.0000
# Month=18, Predicted=956.7509, Expected=935.0000
# Month=19, Predicted=942.6767, Expected=894.0000
# Month=20, Predicted=882.7509, Expected=855.0000
# Month=21, Predicted=837.8946, Expected=809.0000
# Month=22, Predicted=787.3865, Expected=810.0000
# Month=23, Predicted=811.1985, Expected=766.0000
# Month=24, Predicted=761.5418, Expected=805.0000
# Month=25, Predicted=807.2874, Expected=821.0000
# Month=26, Predicted=831.6533, Expected=773.0000
# Month=27, Predicted=767.9072, Expected=883.0000
# Month=28, Predicted=905.8738, Expected=898.0000
# Month=29, Predicted=909.7826, Expected=957.0000
# Month=30, Predicted=952.9879, Expected=924.0000
# Month=31, Predicted=928.6262, Expected=881.0000
# Month=32, Predicted=864.9474, Expected=837.0000
# Month=33, Predicted=814.9342, Expected=784.0000
# Month=34, Predicted=755.1640, Expected=791.0000
# Month=35, Predicted=790.9631, Expected=760.0000
# Month=36, Predicted=764.5205, Expected=802.0000
# Month=37, Predicted=804.3725, Expected=828.0000
# Month=38, Predicted=835.8231, Expected=778.0000
# Month=39, Predicted=771.5946, Expected=889.0000
# Month=40, Predicted=912.8124, Expected=902.0000
# Month=41, Predicted=914.2098, Expected=969.0000
# Month=42, Predicted=965.0372, Expected=947.0000
# Month=43, Predicted=956.1974, Expected=908.0000
# Month=44, Predicted=900.0682, Expected=867.0000
# Month=45, Predicted=849.3987, Expected=815.0000
# Month=46, Predicted=787.6929, Expected=812.0000
# Month=47, Predicted=809.8501, Expected=773.0000
# Month=48, Predicted=771.5674, Expected=813.0000
# Month=49, Predicted=815.4617, Expected=834.0000
# Month=50, Predicted=843.3402, Expected=782.0000
# Month=51, Predicted=773.8913, Expected=892.0000
# Month=52, Predicted=915.4049, Expected=903.0000
# Month=53, Predicted=915.4821, Expected=966.0000
# Month=54, Predicted=961.7330, Expected=937.0000
# Month=55, Predicted=943.4459, Expected=896.0000
# Month=56, Predicted=883.4023, Expected=858.0000
# Month=57, Predicted=841.6513, Expected=817.0000
# Month=58, Predicted=799.7750, Expected=827.0000
# Month=59, Predicted=831.1990, Expected=797.0000
# Month=60, Predicted=802.3681, Expected=843.0000
# Run 12 — RMSE: 47.042651, MSE: 2213.011052, NMSE: 0.0088598025
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=745.8485, Expected=804.0000
# Month=2, Predicted=788.5798, Expected=756.0000
# Month=3, Predicted=750.8485, Expected=860.0000
# Month=4, Predicted=890.9914, Expected=878.0000
# Month=5, Predicted=872.8485, Expected=942.0000
# Month=6, Predicted=919.6249, Expected=913.0000
# Month=7, Predicted=907.8485, Expected=869.0000
# Month=8, Predicted=863.8485, Expected=834.0000
# Month=9, Predicted=828.8485, Expected=790.0000
# Month=10, Predicted=784.8485, Expected=800.0000
# Month=11, Predicted=794.8485, Expected=763.0000
# Month=12, Predicted=757.8485, Expected=800.0000
# Month=13, Predicted=794.8485, Expected=826.0000
# Month=14, Predicted=820.8485, Expected=799.0000
# Month=15, Predicted=793.8485, Expected=890.0000
# Month=16, Predicted=905.4073, Expected=900.0000
# Month=17, Predicted=894.8485, Expected=961.0000
# Month=18, Predicted=940.4367, Expected=935.0000
# Month=19, Predicted=929.8485, Expected=894.0000
# Month=20, Predicted=888.8485, Expected=855.0000
# Month=21, Predicted=849.8485, Expected=809.0000
# Month=22, Predicted=803.8485, Expected=810.0000
# Month=23, Predicted=804.8485, Expected=766.0000
# Month=24, Predicted=760.8485, Expected=805.0000
# Month=25, Predicted=799.8485, Expected=821.0000
# Month=26, Predicted=815.8485, Expected=773.0000
# Month=27, Predicted=767.8485, Expected=883.0000
# Month=28, Predicted=919.5215, Expected=898.0000
# Month=29, Predicted=892.8485, Expected=957.0000
# Month=30, Predicted=937.5401, Expected=924.0000
# Month=31, Predicted=918.8485, Expected=881.0000
# Month=32, Predicted=875.8485, Expected=837.0000
# Month=33, Predicted=831.8485, Expected=784.0000
# Month=34, Predicted=778.8485, Expected=791.0000
# Month=35, Predicted=785.8485, Expected=760.0000
# Month=36, Predicted=754.8485, Expected=802.0000
# Month=37, Predicted=796.7171, Expected=828.0000
# Month=38, Predicted=822.8485, Expected=778.0000
# Month=39, Predicted=772.8485, Expected=889.0000
# Month=40, Predicted=926.5084, Expected=902.0000
# Month=41, Predicted=896.8485, Expected=969.0000
# Month=42, Predicted=948.6512, Expected=947.0000
# Month=43, Predicted=941.8485, Expected=908.0000
# Month=44, Predicted=902.8485, Expected=867.0000
# Month=45, Predicted=861.8485, Expected=815.0000
# Month=46, Predicted=809.8485, Expected=812.0000
# Month=47, Predicted=806.8485, Expected=773.0000
# Month=48, Predicted=767.8485, Expected=813.0000
# Month=49, Predicted=807.8485, Expected=834.0000
# Month=50, Predicted=828.8485, Expected=782.0000
# Month=51, Predicted=776.8485, Expected=892.0000
# Month=52, Predicted=928.7597, Expected=903.0000
# Month=53, Predicted=897.8485, Expected=966.0000
# Month=54, Predicted=944.2833, Expected=937.0000
# Month=55, Predicted=931.8485, Expected=896.0000
# Month=56, Predicted=890.8485, Expected=858.0000
# Month=57, Predicted=852.8485, Expected=817.0000
# Month=58, Predicted=811.8485, Expected=827.0000
# Month=59, Predicted=821.8485, Expected=797.0000
# Month=60, Predicted=791.8485, Expected=843.0000
# Run 13 — RMSE: 48.010100, MSE: 2304.969681, NMSE: 0.0100920558
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=748.0715, Expected=804.0000
# Month=2, Predicted=801.0715, Expected=756.0000
# Month=3, Predicted=742.3430, Expected=860.0000
# Month=4, Predicted=873.1093, Expected=878.0000
# Month=5, Predicted=875.0715, Expected=942.0000
# Month=6, Predicted=939.5411, Expected=913.0000
# Month=7, Predicted=910.0715, Expected=869.0000
# Month=8, Predicted=856.9228, Expected=834.0000
# Month=9, Predicted=827.5744, Expected=790.0000
# Month=10, Predicted=777.5428, Expected=800.0000
# Month=11, Predicted=797.0715, Expected=763.0000
# Month=12, Predicted=757.5252, Expected=800.0000
# Month=13, Predicted=797.0715, Expected=826.0000
# Month=14, Predicted=823.0715, Expected=799.0000
# Month=15, Predicted=796.0715, Expected=890.0000
# Month=16, Predicted=896.7680, Expected=900.0000
# Month=17, Predicted=897.0715, Expected=961.0000
# Month=18, Predicted=958.0715, Expected=935.0000
# Month=19, Predicted=932.0715, Expected=894.0000
# Month=20, Predicted=884.3367, Expected=855.0000
# Month=21, Predicted=845.8199, Expected=809.0000
# Month=22, Predicted=794.8027, Expected=810.0000
# Month=23, Predicted=807.0715, Expected=766.0000
# Month=24, Predicted=755.1341, Expected=805.0000
# Month=25, Predicted=802.0715, Expected=821.0000
# Month=26, Predicted=818.0715, Expected=773.0000
# Month=27, Predicted=759.2875, Expected=883.0000
# Month=28, Predicted=899.7119, Expected=898.0000
# Month=29, Predicted=895.0715, Expected=957.0000
# Month=30, Predicted=954.0715, Expected=924.0000
# Month=31, Predicted=921.0715, Expected=881.0000
# Month=32, Predicted=869.4097, Expected=837.0000
# Month=33, Predicted=823.9603, Expected=784.0000
# Month=34, Predicted=764.5311, Expected=791.0000
# Month=35, Predicted=788.0715, Expected=760.0000
# Month=36, Predicted=757.0715, Expected=802.0000
# Month=37, Predicted=799.0715, Expected=828.0000
# Month=38, Predicted=825.0715, Expected=778.0000
# Month=39, Predicted=762.8426, Expected=889.0000
# Month=40, Predicted=906.2358, Expected=902.0000
# Month=41, Predicted=899.0715, Expected=969.0000
# Month=42, Predicted=967.1749, Expected=947.0000
# Month=43, Predicted=944.0715, Expected=908.0000
# Month=44, Predicted=900.0626, Expected=867.0000
# Month=45, Predicted=856.4778, Expected=815.0000
# Month=46, Predicted=796.4244, Expected=812.0000
# Month=47, Predicted=809.0715, Expected=773.0000
# Month=48, Predicted=765.8157, Expected=813.0000
# Month=49, Predicted=810.0715, Expected=834.0000
# Month=50, Predicted=831.0715, Expected=782.0000
# Month=51, Predicted=765.4061, Expected=892.0000
# Month=52, Predicted=908.5225, Expected=903.0000
# Month=53, Predicted=900.0715, Expected=966.0000
# Month=54, Predicted=963.3603, Expected=937.0000
# Month=55, Predicted=934.0715, Expected=896.0000
# Month=56, Predicted=886.1564, Expected=858.0000
# Month=57, Predicted=849.5690, Expected=817.0000
# Month=58, Predicted=806.5542, Expected=827.0000
# Month=59, Predicted=824.0715, Expected=797.0000
# Month=60, Predicted=794.0715, Expected=843.0000
# Run 14 — RMSE: 49.587287, MSE: 2458.898984, NMSE: 0.0099635576
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=748.9148, Expected=804.0000
# Month=2, Predicted=801.9148, Expected=756.0000
# Month=3, Predicted=745.1647, Expected=860.0000
# Month=4, Predicted=857.9148, Expected=878.0000
# Month=5, Predicted=875.9148, Expected=942.0000
# Month=6, Predicted=939.9148, Expected=913.0000
# Month=7, Predicted=908.1750, Expected=869.0000
# Month=8, Predicted=859.2455, Expected=834.0000
# Month=9, Predicted=826.9590, Expected=790.0000
# Month=10, Predicted=780.1783, Expected=800.0000
# Month=11, Predicted=797.9148, Expected=763.0000
# Month=12, Predicted=755.7456, Expected=800.0000
# Month=13, Predicted=797.9148, Expected=826.0000
# Month=14, Predicted=823.9148, Expected=799.0000
# Month=15, Predicted=795.1568, Expected=890.0000
# Month=16, Predicted=887.9148, Expected=900.0000
# Month=17, Predicted=897.9148, Expected=961.0000
# Month=18, Predicted=958.9148, Expected=935.0000
# Month=19, Predicted=931.2210, Expected=894.0000
# Month=20, Predicted=885.2278, Expected=855.0000
# Month=21, Predicted=846.6958, Expected=809.0000
# Month=22, Predicted=798.5108, Expected=810.0000
# Month=23, Predicted=807.9148, Expected=766.0000
# Month=24, Predicted=756.4658, Expected=805.0000
# Month=25, Predicted=802.9148, Expected=821.0000
# Month=26, Predicted=818.9148, Expected=773.0000
# Month=27, Predicted=762.2414, Expected=883.0000
# Month=28, Predicted=880.9147, Expected=898.0000
# Month=29, Predicted=895.9148, Expected=957.0000
# Month=30, Predicted=954.9148, Expected=924.0000
# Month=31, Predicted=917.9039, Expected=881.0000
# Month=32, Predicted=871.5168, Expected=837.0000
# Month=33, Predicted=827.0808, Expected=784.0000
# Month=34, Predicted=771.3652, Expected=791.0000
# Month=35, Predicted=788.9148, Expected=760.0000
# Month=36, Predicted=754.7412, Expected=802.0000
# Month=37, Predicted=799.9148, Expected=828.0000
# Month=38, Predicted=825.9148, Expected=778.0000
# Month=39, Predicted=766.6903, Expected=889.0000
# Month=40, Predicted=886.9144, Expected=902.0000
# Month=41, Predicted=899.9148, Expected=969.0000
# Month=42, Predicted=966.9148, Expected=947.0000
# Month=43, Predicted=944.4731, Expected=908.0000
# Month=44, Predicted=899.9116, Expected=867.0000
# Month=45, Predicted=858.0801, Expected=815.0000
# Month=46, Predicted=802.6908, Expected=812.0000
# Month=47, Predicted=809.9148, Expected=773.0000
# Month=48, Predicted=765.0544, Expected=813.0000
# Month=49, Predicted=810.9148, Expected=834.0000
# Month=50, Predicted=831.9148, Expected=782.0000
# Month=51, Predicted=770.0592, Expected=892.0000
# Month=52, Predicted=889.9147, Expected=903.0000
# Month=53, Predicted=900.9148, Expected=966.0000
# Month=54, Predicted=963.9148, Expected=937.0000
# Month=55, Predicted=932.1883, Expected=896.0000
# Month=56, Predicted=887.1962, Expected=858.0000
# Month=57, Predicted=850.0193, Expected=817.0000
# Month=58, Predicted=808.0906, Expected=827.0000
# Month=59, Predicted=824.9148, Expected=797.0000
# Month=60, Predicted=792.0819, Expected=843.0000
# Run 15 — RMSE: 49.215079, MSE: 2422.123978, NMSE: 0.0103046017
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=747.5769, Expected=804.0000
# Month=2, Predicted=790.8955, Expected=756.0000
# Month=3, Predicted=745.6107, Expected=860.0000
# Month=4, Predicted=887.4799, Expected=878.0000
# Month=5, Predicted=875.0372, Expected=942.0000
# Month=6, Predicted=922.1179, Expected=913.0000
# Month=7, Predicted=910.0372, Expected=869.0000
# Month=8, Predicted=858.8693, Expected=834.0000
# Month=9, Predicted=827.2589, Expected=790.0000
# Month=10, Predicted=779.7892, Expected=800.0000
# Month=11, Predicted=797.0372, Expected=763.0000
# Month=12, Predicted=756.6729, Expected=800.0000
# Month=13, Predicted=797.0372, Expected=826.0000
# Month=14, Predicted=823.0372, Expected=799.0000
# Month=15, Predicted=796.0372, Expected=890.0000
# Month=16, Predicted=905.7259, Expected=900.0000
# Month=17, Predicted=897.0372, Expected=961.0000
# Month=18, Predicted=943.2034, Expected=935.0000
# Month=19, Predicted=932.0372, Expected=894.0000
# Month=20, Predicted=885.0886, Expected=855.0000
# Month=21, Predicted=846.6600, Expected=809.0000
# Month=22, Predicted=797.9849, Expected=810.0000
# Month=23, Predicted=807.0372, Expected=766.0000
# Month=24, Predicted=756.5557, Expected=805.0000
# Month=25, Predicted=802.0372, Expected=821.0000
# Month=26, Predicted=818.0372, Expected=773.0000
# Month=27, Predicted=762.4312, Expected=883.0000
# Month=28, Predicted=915.1148, Expected=898.0000
# Month=29, Predicted=895.0372, Expected=957.0000
# Month=30, Predicted=940.2605, Expected=924.0000
# Month=31, Predicted=919.8166, Expected=881.0000
# Month=32, Predicted=871.1868, Expected=837.0000
# Month=33, Predicted=826.6839, Expected=784.0000
# Month=34, Predicted=770.4614, Expected=791.0000
# Month=35, Predicted=788.0372, Expected=760.0000
# Month=36, Predicted=756.1859, Expected=802.0000
# Month=37, Predicted=797.2666, Expected=828.0000
# Month=38, Predicted=825.0372, Expected=778.0000
# Month=39, Predicted=766.7877, Expected=889.0000
# Month=40, Predicted=921.7978, Expected=902.0000
# Month=41, Predicted=899.0372, Expected=969.0000
# Month=42, Predicted=952.5555, Expected=947.0000
# Month=43, Predicted=944.0372, Expected=908.0000
# Month=44, Predicted=899.9686, Expected=867.0000
# Month=45, Predicted=857.8939, Expected=815.0000
# Month=46, Predicted=801.8322, Expected=812.0000
# Month=47, Predicted=809.0372, Expected=773.0000
# Month=48, Predicted=765.4479, Expected=813.0000
# Month=49, Predicted=809.5565, Expected=834.0000
# Month=50, Predicted=831.0372, Expected=782.0000
# Month=51, Predicted=770.0557, Expected=892.0000
# Month=52, Predicted=924.0070, Expected=903.0000
# Month=53, Predicted=900.0372, Expected=966.0000
# Month=54, Predicted=946.9564, Expected=937.0000
# Month=55, Predicted=934.0372, Expected=896.0000
# Month=56, Predicted=887.0331, Expected=858.0000
# Month=57, Predicted=850.0635, Expected=817.0000
# Month=58, Predicted=807.9048, Expected=827.0000
# Month=59, Predicted=824.0372, Expected=797.0000
# Month=60, Predicted=793.7385, Expected=843.0000
# Run 16 — RMSE: 48.606434, MSE: 2362.585454, NMSE: 0.0100223655
#
# ...
# Month=41, Predicted=903.7402, Expected=969.0000
# Month=42, Predicted=967.5242, Expected=947.0000
# Month=43, Predicted=939.3306, Expected=908.0000
# Month=44, Predicted=897.6915, Expected=867.0000
# Month=45, Predicted=856.1476, Expected=815.0000
# Month=46, Predicted=802.7847, Expected=812.0000
# Month=47, Predicted=805.4317, Expected=773.0000
# Month=48, Predicted=762.8843, Expected=813.0000
# Month=49, Predicted=809.3543, Expected=834.0000
# Month=50, Predicted=829.4282, Expected=782.0000
# Month=51, Predicted=770.1927, Expected=892.0000
# Month=52, Predicted=916.2101, Expected=903.0000
# Month=53, Predicted=904.3110, Expected=966.0000
# Month=54, Predicted=963.6726, Expected=937.0000
# Month=55, Predicted=928.0808, Expected=896.0000
# Month=56, Predicted=885.3149, Expected=858.0000
# Month=57, Predicted=847.5233, Expected=817.0000
# Month=58, Predicted=806.1643, Expected=827.0000
# Month=59, Predicted=821.8588, Expected=797.0000
# Month=60, Predicted=788.2947, Expected=843.0000
# Run 25 — RMSE: 48.455090, MSE: 2347.895753, NMSE: 0.0094288341
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=753.9274, Expected=804.0000
# Month=2, Predicted=806.5333, Expected=756.0000
# Month=3, Predicted=742.0965, Expected=860.0000
# Month=4, Predicted=865.8825, Expected=878.0000
# Month=5, Predicted=884.0203, Expected=942.0000
# Month=6, Predicted=944.2258, Expected=913.0000
# Month=7, Predicted=909.0810, Expected=869.0000
# Month=8, Predicted=851.9138, Expected=834.0000
# Month=9, Predicted=819.9566, Expected=790.0000
# Month=10, Predicted=771.9008, Expected=800.0000
# Month=11, Predicted=802.1795, Expected=763.0000
# Month=12, Predicted=754.6420, Expected=800.0000
# Month=13, Predicted=803.1405, Expected=826.0000
# Month=14, Predicted=831.2758, Expected=799.0000
# Month=15, Predicted=795.9323, Expected=890.0000
# Month=16, Predicted=894.1995, Expected=900.0000
# Month=17, Predicted=905.7161, Expected=961.0000
# Month=18, Predicted=963.1598, Expected=935.0000
# Month=19, Predicted=932.4950, Expected=894.0000
# Month=20, Predicted=879.3094, Expected=855.0000
# Month=21, Predicted=838.9644, Expected=809.0000
# Month=22, Predicted=788.9571, Expected=810.0000
# Month=23, Predicted=810.3483, Expected=766.0000
# Month=24, Predicted=753.0997, Expected=805.0000
# Month=25, Predicted=807.7407, Expected=821.0000
# Month=26, Predicted=826.6063, Expected=773.0000
# Month=27, Predicted=758.8558, Expected=883.0000
# Month=28, Predicted=890.1109, Expected=898.0000
# Month=29, Predicted=904.0970, Expected=957.0000
# Month=30, Predicted=959.2343, Expected=924.0000
# Month=31, Predicted=918.1093, Expected=881.0000
# Month=32, Predicted=863.8643, Expected=837.0000
# Month=33, Predicted=817.4671, Expected=784.0000
# Month=34, Predicted=758.8274, Expected=791.0000
# Month=35, Predicted=791.8849, Expected=760.0000
# Month=36, Predicted=754.3536, Expected=802.0000
# Month=37, Predicted=804.8884, Expected=828.0000
# Month=38, Predicted=833.2747, Expected=778.0000
# Month=39, Predicted=762.7728, Expected=889.0000
# Month=40, Predicted=896.2392, Expected=902.0000
# Month=41, Predicted=908.0699, Expected=969.0000
# Month=42, Predicted=971.2686, Expected=947.0000
# Month=43, Predicted=946.0199, Expected=908.0000
# Month=44, Predicted=895.2421, Expected=867.0000
# Month=45, Predicted=850.0660, Expected=815.0000
# Month=46, Predicted=790.9565, Expected=812.0000
# Month=47, Predicted=810.7229, Expected=773.0000
# Month=48, Predicted=762.7138, Expected=813.0000
# Month=49, Predicted=815.8328, Expected=834.0000
# Month=50, Predicted=839.5388, Expected=782.0000
# Month=51, Predicted=765.5132, Expected=892.0000
# Month=52, Predicted=898.9489, Expected=903.0000
# Month=53, Predicted=908.9811, Expected=966.0000
# Month=54, Predicted=968.1624, Expected=937.0000
# Month=55, Predicted=933.0706, Expected=896.0000
# Month=56, Predicted=880.8112, Expected=858.0000
# Month=57, Predicted=842.6007, Expected=817.0000
# Month=58, Predicted=800.2510, Expected=827.0000
# Month=59, Predicted=829.4247, Expected=797.0000
# Month=60, Predicted=792.0269, Expected=843.0000
# Run 26 — RMSE: 49.268771, MSE: 2427.411809, NMSE: 0.0096591218
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=755.0947, Expected=804.0000
# Month=2, Predicted=808.2412, Expected=756.0000
# Month=3, Predicted=743.7237, Expected=860.0000
# Month=4, Predicted=861.7252, Expected=878.0000
# Month=5, Predicted=882.9943, Expected=942.0000
# Month=6, Predicted=945.8852, Expected=913.0000
# Month=7, Predicted=909.8260, Expected=869.0000
# Month=8, Predicted=857.5612, Expected=834.0000
# Month=9, Predicted=826.2907, Expected=790.0000
# Month=10, Predicted=778.3457, Expected=800.0000
# Month=11, Predicted=803.3437, Expected=763.0000
# Month=12, Predicted=755.9667, Expected=800.0000
# Month=13, Predicted=804.0970, Expected=826.0000
# Month=14, Predicted=830.3684, Expected=799.0000
# Month=15, Predicted=797.1321, Expected=890.0000
# Month=16, Predicted=892.5603, Expected=900.0000
# Month=17, Predicted=904.3686, Expected=961.0000
# Month=18, Predicted=964.9515, Expected=935.0000
# Month=19, Predicted=933.3695, Expected=894.0000
# Month=20, Predicted=884.0710, Expected=855.0000
# Month=21, Predicted=845.4854, Expected=809.0000
# Month=22, Predicted=796.2897, Expected=810.0000
# Month=23, Predicted=812.6879, Expected=766.0000
# Month=24, Predicted=755.3929, Expected=805.0000
# Month=25, Predicted=809.0397, Expected=821.0000
# Month=26, Predicted=825.1161, Expected=773.0000
# Month=27, Predicted=760.8219, Expected=883.0000
# Month=28, Predicted=884.3683, Expected=898.0000
# Month=29, Predicted=902.9826, Expected=957.0000
# Month=30, Predicted=961.0264, Expected=924.0000
# Month=31, Predicted=918.8975, Expected=881.0000
# Month=32, Predicted=869.8944, Expected=837.0000
# Month=33, Predicted=825.0660, Expected=784.0000
# Month=34, Predicted=768.0271, Expected=791.0000
# Month=35, Predicted=794.0579, Expected=760.0000
# Month=36, Predicted=755.8814, Expected=802.0000
# Month=37, Predicted=806.1154, Expected=828.0000
# Month=38, Predicted=832.3911, Expected=778.0000
# Month=39, Predicted=764.9435, Expected=889.0000
# Month=40, Predicted=890.2932, Expected=902.0000
# Month=41, Predicted=906.8997, Expected=969.0000
# Month=42, Predicted=972.7703, Expected=947.0000
# Month=43, Predicted=947.2693, Expected=908.0000
# Month=44, Predicted=899.1566, Expected=867.0000
# Month=45, Predicted=856.6131, Expected=815.0000
# Month=46, Predicted=799.5580, Expected=812.0000
# Month=47, Predicted=814.2543, Expected=773.0000
# Month=48, Predicted=764.6951, Expected=813.0000
# Month=49, Predicted=817.0724, Expected=834.0000
# Month=50, Predicted=838.2775, Expected=782.0000
# Month=51, Predicted=768.0440, Expected=892.0000
# Month=52, Predicted=893.3408, Expected=903.0000
# Month=53, Predicted=907.7658, Expected=966.0000
# Month=54, Predicted=969.8951, Expected=937.0000
# Month=55, Predicted=933.8408, Expected=896.0000
# Month=56, Predicted=885.9711, Expected=858.0000
# Month=57, Predicted=848.9619, Expected=817.0000
# Month=58, Predicted=806.6433, Expected=827.0000
# Month=59, Predicted=830.3740, Expected=797.0000
# Month=60, Predicted=793.4487, Expected=843.0000
# Run 27 — RMSE: 49.449328, MSE: 2445.236043, NMSE: 0.0100874032
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=761.4413, Expected=804.0000
# Month=2, Predicted=789.6178, Expected=756.0000
# Month=3, Predicted=744.0677, Expected=860.0000
# Month=4, Predicted=881.5765, Expected=878.0000
# Month=5, Predicted=891.9799, Expected=942.0000
# Month=6, Predicted=927.6782, Expected=913.0000
# Month=7, Predicted=907.1445, Expected=869.0000
# Month=8, Predicted=856.9642, Expected=834.0000
# Month=9, Predicted=823.7291, Expected=790.0000
# Month=10, Predicted=777.6574, Expected=800.0000
# Month=11, Predicted=801.3671, Expected=763.0000
# Month=12, Predicted=753.5954, Expected=800.0000
# Month=13, Predicted=809.6001, Expected=826.0000
# Month=14, Predicted=833.6790, Expected=799.0000
# Month=15, Predicted=792.0814, Expected=890.0000
# Month=16, Predicted=902.2432, Expected=900.0000
# Month=17, Predicted=908.8955, Expected=961.0000
# Month=18, Predicted=945.0795, Expected=935.0000
# Month=19, Predicted=929.6451, Expected=894.0000
# Month=20, Predicted=882.9452, Expected=855.0000
# Month=21, Predicted=843.7507, Expected=809.0000
# Month=22, Predicted=795.8857, Expected=810.0000
# Month=23, Predicted=808.7583, Expected=766.0000
# Month=24, Predicted=754.5230, Expected=805.0000
# Month=25, Predicted=814.7011, Expected=821.0000
# Month=26, Predicted=825.8376, Expected=773.0000
# Month=27, Predicted=760.4216, Expected=883.0000
# Month=28, Predicted=905.5600, Expected=898.0000
# Month=29, Predicted=912.5220, Expected=957.0000
# Month=30, Predicted=940.5430, Expected=924.0000
# Month=31, Predicted=916.7228, Expected=881.0000
# Month=32, Predicted=869.0592, Expected=837.0000
# Month=33, Predicted=824.2108, Expected=784.0000
# Month=34, Predicted=768.7078, Expected=791.0000
# Month=35, Predicted=790.8555, Expected=760.0000
# Month=36, Predicted=752.0884, Expected=802.0000
# Month=37, Predicted=807.6111, Expected=828.0000
# Month=38, Predicted=835.8279, Expected=778.0000
# Month=39, Predicted=764.8595, Expected=889.0000
# Month=40, Predicted=911.6238, Expected=902.0000
# Month=41, Predicted=916.3507, Expected=969.0000
# Month=42, Predicted=956.9869, Expected=947.0000
# Month=43, Predicted=943.2445, Expected=908.0000
# Month=44, Predicted=897.6812, Expected=867.0000
# Month=45, Predicted=855.2944, Expected=815.0000
# Month=46, Predicted=800.1457, Expected=812.0000
# Month=47, Predicted=809.2400, Expected=773.0000
# Month=48, Predicted=762.9558, Expected=813.0000
# Month=49, Predicted=823.2695, Expected=834.0000
# Month=50, Predicted=840.3060, Expected=782.0000
# Month=51, Predicted=768.3116, Expected=892.0000
# Month=52, Predicted=914.3537, Expected=903.0000
# Month=53, Predicted=916.7963, Expected=966.0000
# Month=54, Predicted=951.0557, Expected=937.0000
# Month=55, Predicted=931.0546, Expected=896.0000
# Month=56, Predicted=884.8201, Expected=858.0000
# Month=57, Predicted=847.0395, Expected=817.0000
# Month=58, Predicted=805.3476, Expected=827.0000
# Month=59, Predicted=828.5728, Expected=797.0000
# Month=60, Predicted=789.3392, Expected=843.0000
# Run 28 — RMSE: 47.391342, MSE: 2245.939290, NMSE: 0.0095027594
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=746.9043, Expected=804.0000
# Month=2, Predicted=802.5210, Expected=756.0000
# Month=3, Predicted=743.8118, Expected=860.0000
# Month=4, Predicted=872.1687, Expected=878.0000
# Month=5, Predicted=872.7032, Expected=942.0000
# Month=6, Predicted=942.8934, Expected=913.0000
# Month=7, Predicted=902.9829, Expected=869.0000
# Month=8, Predicted=856.9801, Expected=834.0000
# Month=9, Predicted=822.8989, Expected=790.0000
# Month=10, Predicted=777.9674, Expected=800.0000
# Month=11, Predicted=792.7356, Expected=763.0000
# Month=12, Predicted=751.8472, Expected=800.0000
# Month=13, Predicted=795.4441, Expected=826.0000
# Month=14, Predicted=820.2815, Expected=799.0000
# Month=15, Predicted=788.8412, Expected=890.0000
# Month=16, Predicted=898.1166, Expected=900.0000
# Month=17, Predicted=893.8047, Expected=961.0000
# Month=18, Predicted=961.1939, Expected=935.0000
# Month=19, Predicted=925.2259, Expected=894.0000
# Month=20, Predicted=882.3063, Expected=855.0000
# Month=21, Predicted=843.4897, Expected=809.0000
# Month=22, Predicted=796.7201, Expected=810.0000
# Month=23, Predicted=802.0036, Expected=766.0000
# Month=24, Predicted=754.0896, Expected=805.0000
# Month=25, Predicted=800.7400, Expected=821.0000
# Month=26, Predicted=814.4698, Expected=773.0000
# Month=27, Predicted=760.6248, Expected=883.0000
# Month=28, Predicted=897.1600, Expected=898.0000
# Month=29, Predicted=892.6554, Expected=957.0000
# Month=30, Predicted=956.7359, Expected=924.0000
# Month=31, Predicted=913.5198, Expected=881.0000
# Month=32, Predicted=869.0788, Expected=837.0000
# Month=33, Predicted=824.9606, Expected=784.0000
# Month=34, Predicted=770.8412, Expected=791.0000
# Month=35, Predicted=783.4489, Expected=760.0000
# Month=36, Predicted=749.4449, Expected=802.0000
# Month=37, Predicted=798.2394, Expected=828.0000
# Month=38, Predicted=822.3174, Expected=778.0000
# Month=39, Predicted=765.3810, Expected=889.0000
# Month=40, Predicted=903.4879, Expected=902.0000
# Month=41, Predicted=896.5567, Expected=969.0000
# Month=42, Predicted=970.6307, Expected=947.0000
# Month=43, Predicted=937.6835, Expected=908.0000
# Month=44, Predicted=896.5303, Expected=867.0000
# Month=45, Predicted=855.2818, Expected=815.0000
# Month=46, Predicted=801.9692, Expected=812.0000
# Month=47, Predicted=803.6705, Expected=773.0000
# Month=48, Predicted=761.6055, Expected=813.0000
# Month=49, Predicted=808.9005, Expected=834.0000
# Month=50, Predicted=827.8445, Expected=782.0000
# Month=51, Predicted=769.1194, Expected=892.0000
# Month=52, Predicted=906.1393, Expected=903.0000
# Month=53, Predicted=897.4122, Expected=966.0000
# Month=54, Predicted=966.6629, Expected=937.0000
# Month=55, Predicted=926.9683, Expected=896.0000
# Month=56, Predicted=884.2991, Expected=858.0000
# Month=57, Predicted=846.5933, Expected=817.0000
# Month=58, Predicted=805.2827, Expected=827.0000
# Month=59, Predicted=819.7367, Expected=797.0000
# Month=60, Predicted=786.5472, Expected=843.0000
# Run 29 — RMSE: 49.300657, MSE: 2430.554826, NMSE: 0.0097928167
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=751.4987, Expected=804.0000
# Month=2, Predicted=804.9998, Expected=756.0000
# Month=3, Predicted=745.0304, Expected=860.0000
# Month=4, Predicted=867.2754, Expected=878.0000
# Month=5, Predicted=885.5905, Expected=942.0000
# Month=6, Predicted=942.5609, Expected=913.0000
# Month=7, Predicted=913.0215, Expected=869.0000
# Month=8, Predicted=855.0591, Expected=834.0000
# Month=9, Predicted=823.6924, Expected=790.0000
# Month=10, Predicted=775.1526, Expected=800.0000
# Month=11, Predicted=802.1206, Expected=763.0000
# Month=12, Predicted=759.3793, Expected=800.0000
# Month=13, Predicted=800.8775, Expected=826.0000
# Month=14, Predicted=830.7149, Expected=799.0000
# Month=15, Predicted=799.1362, Expected=890.0000
# Month=16, Predicted=894.1967, Expected=900.0000
# Month=17, Predicted=907.0419, Expected=961.0000
# Month=18, Predicted=961.3023, Expected=935.0000
# Month=19, Predicted=935.7592, Expected=894.0000
# Month=20, Predicted=882.6213, Expected=855.0000
# Month=21, Predicted=842.4748, Expected=809.0000
# Month=22, Predicted=792.1653, Expected=810.0000
# Month=23, Predicted=811.3568, Expected=766.0000
# Month=24, Predicted=756.3213, Expected=805.0000
# Month=25, Predicted=805.1767, Expected=821.0000
# Month=26, Predicted=826.4449, Expected=773.0000
# Month=27, Predicted=761.6766, Expected=883.0000
# Month=28, Predicted=892.7152, Expected=898.0000
# Month=29, Predicted=905.9952, Expected=957.0000
# Month=30, Predicted=957.4220, Expected=924.0000
# Month=31, Predicted=922.8205, Expected=881.0000
# Month=32, Predicted=867.0783, Expected=837.0000
# Month=33, Predicted=820.7941, Expected=784.0000
# Month=34, Predicted=761.9587, Expected=791.0000
# Month=35, Predicted=792.2738, Expected=760.0000
# Month=36, Predicted=758.6603, Expected=802.0000
# Month=37, Predicted=802.4771, Expected=828.0000
# Month=38, Predicted=832.7890, Expected=778.0000
# Month=39, Predicted=765.4312, Expected=889.0000
# Month=40, Predicted=898.9968, Expected=902.0000
# Month=41, Predicted=910.0479, Expected=969.0000
# Month=42, Predicted=969.6743, Expected=947.0000
# Month=43, Predicted=948.8759, Expected=908.0000
# Month=44, Predicted=898.6900, Expected=867.0000
# Month=45, Predicted=853.4609, Expected=815.0000
# Month=46, Predicted=794.0305, Expected=812.0000
# Month=47, Predicted=812.3791, Expected=773.0000
# Month=48, Predicted=766.5292, Expected=813.0000
# Month=49, Predicted=813.3271, Expected=834.0000
# Month=50, Predicted=839.1889, Expected=782.0000
# Month=51, Predicted=768.0239, Expected=892.0000
# Month=52, Predicted=901.4098, Expected=903.0000
# Month=53, Predicted=910.9551, Expected=966.0000
# Month=54, Predicted=966.3691, Expected=937.0000
# Month=55, Predicted=937.0002, Expected=896.0000
# Month=56, Predicted=884.1180, Expected=858.0000
# Month=57, Predicted=846.1639, Expected=817.0000
# Month=58, Predicted=803.6606, Expected=827.0000
# Month=59, Predicted=829.3442, Expected=797.0000
# Month=60, Predicted=796.0488, Expected=843.0000
# Run 30 — RMSE: 48.680418, MSE: 2369.783081, NMSE: 0.0095676979

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (2 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Milk Production (2 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Milk Production (30 runs) =====
# RMSE: 48.601945 ± 0.720641
# MSE:  2362.668394 ± 69.729115
# NMSE: 0.0097959410 ± 0.0004181025
#
# Best run: 18
#   RMSE: 47.028204
#   MSE:  2211.651967
#   NMSE: 0.0090352297

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Gate Replacement — Monthly Milk Production\nPredictions vs Actual (Best of 2 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Gate Replacement — Monthly Milk Production\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 47.028204
# MSE:  2211.651967
# NMSE: 0.0090352297

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
