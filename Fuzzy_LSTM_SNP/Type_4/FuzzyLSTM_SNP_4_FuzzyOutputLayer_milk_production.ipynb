# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fuzzy_output_layer              │ (1, 1)                 │            12 │
# │ (FuzzyOutputLayer)              │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332 (1.30 KB)
#  Trainable params: 332 (1.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 2)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (107, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (107, 1, 1), y_train shape: (107,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(2):
    print(f'\n===== RUN {run+1}/2 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    # Set consumption gate (c) bias to 1.0 (unit forget bias)
    rnn_layer = model.layers[1]
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, bias[units:2*units]
    weights[2] = bias
    cell.set_weights(weights)

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=766.9605, Expected=804.0000
# Month=2, Predicted=761.8922, Expected=756.0000
# Month=3, Predicted=850.1409, Expected=860.0000
# Month=4, Predicted=874.4215, Expected=878.0000
# Month=5, Predicted=923.8186, Expected=942.0000
# Month=6, Predicted=930.3618, Expected=913.0000
# Month=7, Predicted=875.7600, Expected=869.0000
# Month=8, Predicted=826.7370, Expected=834.0000
# Month=9, Predicted=807.2182, Expected=790.0000
# Month=10, Predicted=776.9625, Expected=800.0000
# Month=11, Predicted=798.7770, Expected=763.0000
# Month=12, Predicted=794.5904, Expected=800.0000
# Month=13, Predicted=814.7509, Expected=826.0000
# Month=14, Predicted=801.8114, Expected=799.0000
# Month=15, Predicted=877.2394, Expected=890.0000
# Month=16, Predicted=903.2755, Expected=900.0000
# Month=17, Predicted=950.5832, Expected=961.0000
# Month=18, Predicted=955.0109, Expected=935.0000
# Month=19, Predicted=910.6441, Expected=894.0000
# Month=20, Predicted=852.6233, Expected=855.0000
# Month=21, Predicted=826.3564, Expected=809.0000
# Month=22, Predicted=794.6044, Expected=810.0000
# Month=23, Predicted=806.1473, Expected=766.0000
# Month=24, Predicted=791.5377, Expected=805.0000
# Month=25, Predicted=819.7360, Expected=821.0000
# Month=26, Predicted=807.0830, Expected=773.0000
# Month=27, Predicted=850.1719, Expected=883.0000
# Month=28, Predicted=903.3595, Expected=898.0000
# Month=29, Predicted=938.4131, Expected=957.0000
# Month=30, Predicted=972.3444, Expected=924.0000
# Month=31, Predicted=946.3464, Expected=881.0000
# Month=32, Predicted=823.2254, Expected=837.0000
# Month=33, Predicted=795.5811, Expected=784.0000
# Month=34, Predicted=756.3399, Expected=791.0000
# Month=35, Predicted=775.2715, Expected=760.0000
# Month=36, Predicted=780.4846, Expected=802.0000
# Month=37, Predicted=817.7516, Expected=828.0000
# Month=38, Predicted=792.3254, Expected=778.0000
# Month=39, Predicted=865.6361, Expected=889.0000
# Month=40, Predicted=907.8079, Expected=902.0000
# Month=41, Predicted=952.6267, Expected=969.0000
# Month=42, Predicted=972.7301, Expected=947.0000
# Month=43, Predicted=932.2087, Expected=908.0000
# Month=44, Predicted=860.7987, Expected=867.0000
# Month=45, Predicted=835.1152, Expected=815.0000
# Month=46, Predicted=795.4813, Expected=812.0000
# Month=47, Predicted=804.3273, Expected=773.0000
# Month=48, Predicted=794.0380, Expected=813.0000
# Month=49, Predicted=828.4942, Expected=834.0000
# Month=50, Predicted=809.6311, Expected=782.0000
# Month=51, Predicted=865.6791, Expected=892.0000
# Month=52, Predicted=911.8885, Expected=903.0000
# Month=53, Predicted=954.5203, Expected=966.0000
# Month=54, Predicted=978.4746, Expected=937.0000
# Month=55, Predicted=945.4011, Expected=896.0000
# Month=56, Predicted=844.3283, Expected=858.0000
# Month=57, Predicted=822.1774, Expected=817.0000
# Month=58, Predicted=792.3923, Expected=827.0000
# Month=59, Predicted=817.2124, Expected=797.0000
# Month=60, Predicted=822.6035, Expected=843.0000
# Run 1 — RMSE: 23.027205, MSE: 530.252186, NMSE: 0.0022086931
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=756.4987, Expected=804.0000
# Month=2, Predicted=822.3458, Expected=756.0000
# Month=3, Predicted=776.8206, Expected=860.0000
# Month=4, Predicted=852.9572, Expected=878.0000
# Month=5, Predicted=892.3385, Expected=942.0000
# Month=6, Predicted=926.3620, Expected=913.0000
# Month=7, Predicted=883.9350, Expected=869.0000
# Month=8, Predicted=818.8409, Expected=834.0000
# Month=9, Predicted=790.6205, Expected=790.0000
# Month=10, Predicted=763.8563, Expected=800.0000
# Month=11, Predicted=793.8106, Expected=763.0000
# Month=12, Predicted=781.2148, Expected=800.0000
# Month=13, Predicted=811.6062, Expected=826.0000
# Month=14, Predicted=848.7773, Expected=799.0000
# Month=15, Predicted=814.8180, Expected=890.0000
# Month=16, Predicted=889.5470, Expected=900.0000
# Month=17, Predicted=914.7515, Expected=961.0000
# Month=18, Predicted=960.3898, Expected=935.0000
# Month=19, Predicted=942.4786, Expected=894.0000
# Month=20, Predicted=888.7902, Expected=855.0000
# Month=21, Predicted=849.8946, Expected=809.0000
# Month=22, Predicted=808.0649, Expected=810.0000
# Month=23, Predicted=810.1260, Expected=766.0000
# Month=24, Predicted=778.4996, Expected=805.0000
# Month=25, Predicted=808.6496, Expected=821.0000
# Month=26, Predicted=841.6356, Expected=773.0000
# Month=27, Predicted=790.3507, Expected=883.0000
# Month=28, Predicted=881.7692, Expected=898.0000
# Month=29, Predicted=921.1760, Expected=957.0000
# Month=30, Predicted=947.7359, Expected=924.0000
# Month=31, Predicted=900.3502, Expected=881.0000
# Month=32, Predicted=834.0956, Expected=837.0000
# Month=33, Predicted=795.2705, Expected=784.0000
# Month=34, Predicted=756.8843, Expected=791.0000
# Month=35, Predicted=783.7868, Expected=760.0000
# Month=36, Predicted=778.4493, Expected=802.0000
# Month=37, Predicted=814.3269, Expected=828.0000
# Month=38, Predicted=852.6463, Expected=778.0000
# Month=39, Predicted=796.6402, Expected=889.0000
# Month=40, Predicted=887.7253, Expected=902.0000
# Month=41, Predicted=928.1384, Expected=969.0000
# Month=42, Predicted=972.9138, Expected=947.0000
# Month=43, Predicted=959.5392, Expected=908.0000
# Month=44, Predicted=904.2832, Expected=867.0000
# Month=45, Predicted=865.4353, Expected=815.0000
# Month=46, Predicted=818.5285, Expected=812.0000
# Month=47, Predicted=815.7031, Expected=773.0000
# Month=48, Predicted=789.1999, Expected=813.0000
# Month=49, Predicted=820.6828, Expected=834.0000
# Month=50, Predicted=856.4287, Expected=782.0000
# Month=51, Predicted=799.6012, Expected=892.0000
# Month=52, Predicted=888.7944, Expected=903.0000
# Month=53, Predicted=922.8617, Expected=966.0000
# Month=54, Predicted=952.2178, Expected=937.0000
# Month=55, Predicted=909.3354, Expected=896.0000
# Month=56, Predicted=847.0119, Expected=858.0000
# Month=57, Predicted=814.2735, Expected=817.0000
# Month=58, Predicted=788.1416, Expected=827.0000
# Month=59, Predicted=818.2579, Expected=797.0000
# Month=60, Predicted=812.2436, Expected=843.0000
# Run 2 — RMSE: 41.418501, MSE: 1715.492225, NMSE: 0.0082773693
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=756.7184, Expected=804.0000
# Month=2, Predicted=810.6336, Expected=756.0000
# Month=3, Predicted=754.4314, Expected=860.0000
# Month=4, Predicted=869.0543, Expected=878.0000
# Month=5, Predicted=881.1182, Expected=942.0000
# Month=6, Predicted=948.1679, Expected=913.0000
# Month=7, Predicted=911.5742, Expected=869.0000
# Month=8, Predicted=866.1401, Expected=834.0000
# Month=9, Predicted=832.4225, Expected=790.0000
# Month=10, Predicted=788.2762, Expected=800.0000
# Month=11, Predicted=803.1589, Expected=763.0000
# Month=12, Predicted=762.8139, Expected=800.0000
# Month=13, Predicted=805.4804, Expected=826.0000
# Month=14, Predicted=830.7966, Expected=799.0000
# Month=15, Predicted=799.4621, Expected=890.0000
# Month=16, Predicted=898.5674, Expected=900.0000
# Month=17, Predicted=902.8403, Expected=961.0000
# Month=18, Predicted=967.2355, Expected=935.0000
# Month=19, Predicted=934.2609, Expected=894.0000
# Month=20, Predicted=891.8075, Expected=855.0000
# Month=21, Predicted=853.3592, Expected=809.0000
# Month=22, Predicted=807.2843, Expected=810.0000
# Month=23, Predicted=812.5899, Expected=766.0000
# Month=24, Predicted=765.3417, Expected=805.0000
# Month=25, Predicted=810.6986, Expected=821.0000
# Month=26, Predicted=825.1745, Expected=773.0000
# Month=27, Predicted=771.7780, Expected=883.0000
# Month=28, Predicted=892.6042, Expected=898.0000
# Month=29, Predicted=901.1350, Expected=957.0000
# Month=30, Predicted=962.9696, Expected=924.0000
# Month=31, Predicted=922.4042, Expected=881.0000
# Month=32, Predicted=878.4132, Expected=837.0000
# Month=33, Predicted=834.7819, Expected=784.0000
# Month=34, Predicted=781.5737, Expected=791.0000
# Month=35, Predicted=793.9996, Expected=760.0000
# Month=36, Predicted=760.4384, Expected=802.0000
# Month=37, Predicted=807.9200, Expected=828.0000
# Month=38, Predicted=832.8340, Expected=778.0000
# Month=39, Predicted=776.4454, Expected=889.0000
# Month=40, Predicted=898.5572, Expected=902.0000
# Month=41, Predicted=904.8430, Expected=969.0000
# Month=42, Predicted=975.4223, Expected=947.0000
# Month=43, Predicted=946.2499, Expected=908.0000
# Month=44, Predicted=905.6304, Expected=867.0000
# Month=45, Predicted=864.8719, Expected=815.0000
# Month=46, Predicted=812.4857, Expected=812.0000
# Month=47, Predicted=814.1047, Expected=773.0000
# Month=48, Predicted=772.6723, Expected=813.0000
# Month=49, Predicted=818.7547, Expected=834.0000
# Month=50, Predicted=838.5154, Expected=782.0000
# Month=51, Predicted=780.3697, Expected=892.0000
# Month=52, Predicted=901.5599, Expected=903.0000
# Month=53, Predicted=905.7746, Expected=966.0000
# Month=54, Predicted=972.2187, Expected=937.0000
# Month=55, Predicted=935.7391, Expected=896.0000
# Month=56, Predicted=893.5648, Expected=858.0000
# Month=57, Predicted=856.2744, Expected=817.0000
# Month=58, Predicted=815.6035, Expected=827.0000
# Month=59, Predicted=830.2106, Expected=797.0000
# Month=60, Predicted=797.4296, Expected=843.0000
# Run 3 — RMSE: 48.129649, MSE: 2316.463084, NMSE: 0.0101132977
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=763.9714, Expected=804.0000
# Month=2, Predicted=798.4389, Expected=756.0000
# Month=3, Predicted=840.6316, Expected=860.0000
# Month=4, Predicted=887.2671, Expected=878.0000
# Month=5, Predicted=923.0992, Expected=942.0000
# Month=6, Predicted=922.2978, Expected=913.0000
# Month=7, Predicted=877.0422, Expected=869.0000
# Month=8, Predicted=820.4484, Expected=834.0000
# Month=9, Predicted=798.3388, Expected=790.0000
# Month=10, Predicted=792.0403, Expected=800.0000
# Month=11, Predicted=786.3578, Expected=763.0000
# Month=12, Predicted=814.6956, Expected=800.0000
# Month=13, Predicted=811.9825, Expected=826.0000
# Month=14, Predicted=819.7830, Expected=799.0000
# Month=15, Predicted=868.6172, Expected=890.0000
# Month=16, Predicted=911.0018, Expected=900.0000
# Month=17, Predicted=952.1424, Expected=961.0000
# Month=18, Predicted=938.5362, Expected=935.0000
# Month=19, Predicted=901.0867, Expected=894.0000
# Month=20, Predicted=846.6766, Expected=855.0000
# Month=21, Predicted=823.1977, Expected=809.0000
# Month=22, Predicted=812.1131, Expected=810.0000
# Month=23, Predicted=795.6839, Expected=766.0000
# Month=24, Predicted=823.3857, Expected=805.0000
# Month=25, Predicted=820.3854, Expected=821.0000
# Month=26, Predicted=817.2457, Expected=773.0000
# Month=27, Predicted=855.6216, Expected=883.0000
# Month=28, Predicted=914.6290, Expected=898.0000
# Month=29, Predicted=943.0318, Expected=957.0000
# Month=30, Predicted=950.8780, Expected=924.0000
# Month=31, Predicted=918.9343, Expected=881.0000
# Month=32, Predicted=849.9162, Expected=837.0000
# Month=33, Predicted=819.0573, Expected=784.0000
# Month=34, Predicted=803.8062, Expected=791.0000
# Month=35, Predicted=782.4821, Expected=760.0000
# Month=36, Predicted=808.8462, Expected=802.0000
# Month=37, Predicted=811.6200, Expected=828.0000
# Month=38, Predicted=824.4853, Expected=778.0000
# Month=39, Predicted=869.8079, Expected=889.0000
# Month=40, Predicted=917.9209, Expected=902.0000
# Month=41, Predicted=953.7339, Expected=969.0000
# Month=42, Predicted=952.3510, Expected=947.0000
# Month=43, Predicted=916.8127, Expected=908.0000
# Month=44, Predicted=858.6365, Expected=867.0000
# Month=45, Predicted=832.9107, Expected=815.0000
# Month=46, Predicted=817.4893, Expected=812.0000
# Month=47, Predicted=794.8551, Expected=773.0000
# Month=48, Predicted=823.3459, Expected=813.0000
# Month=49, Predicted=828.0194, Expected=834.0000
# Month=50, Predicted=826.9960, Expected=782.0000
# Month=51, Predicted=867.5722, Expected=892.0000
# Month=52, Predicted=923.9836, Expected=903.0000
# Month=53, Predicted=952.4481, Expected=966.0000
# Month=54, Predicted=960.3924, Expected=937.0000
# Month=55, Predicted=935.3151, Expected=896.0000
# Month=56, Predicted=864.8185, Expected=858.0000
# Month=57, Predicted=834.8744, Expected=817.0000
# Month=58, Predicted=826.0051, Expected=827.0000
# Month=59, Predicted=816.7530, Expected=797.0000
# Month=60, Predicted=847.6191, Expected=843.0000
# Run 4 — RMSE: 20.934186, MSE: 438.240138, NMSE: 0.0023844007
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=753.0237, Expected=804.0000
# Month=2, Predicted=805.2455, Expected=756.0000
# Month=3, Predicted=741.6311, Expected=860.0000
# Month=4, Predicted=857.1249, Expected=878.0000
# Month=5, Predicted=849.9730, Expected=942.0000
# Month=6, Predicted=905.9814, Expected=913.0000
# Month=7, Predicted=836.9937, Expected=869.0000
# Month=8, Predicted=793.0946, Expected=834.0000
# Month=9, Predicted=771.2576, Expected=790.0000
# Month=10, Predicted=741.4203, Expected=800.0000
# Month=11, Predicted=778.5234, Expected=763.0000
# Month=12, Predicted=747.6085, Expected=800.0000
# Month=13, Predicted=801.1391, Expected=826.0000
# Month=14, Predicted=827.4100, Expected=799.0000
# Month=15, Predicted=793.8416, Expected=890.0000
# Month=16, Predicted=889.5113, Expected=900.0000
# Month=17, Predicted=880.3184, Expected=961.0000
# Month=18, Predicted=935.3684, Expected=935.0000
# Month=19, Predicted=870.7293, Expected=894.0000
# Month=20, Predicted=826.8485, Expected=855.0000
# Month=21, Predicted=798.0051, Expected=809.0000
# Month=22, Predicted=767.2007, Expected=810.0000
# Month=23, Predicted=793.7769, Expected=766.0000
# Month=24, Predicted=760.2019, Expected=805.0000
# Month=25, Predicted=812.1009, Expected=821.0000
# Month=26, Predicted=830.1414, Expected=773.0000
# Month=27, Predicted=782.6572, Expected=883.0000
# Month=28, Predicted=886.6399, Expected=898.0000
# Month=29, Predicted=899.0169, Expected=957.0000
# Month=30, Predicted=947.2097, Expected=924.0000
# Month=31, Predicted=876.5399, Expected=881.0000
# Month=32, Predicted=829.0732, Expected=837.0000
# Month=33, Predicted=793.5198, Expected=784.0000
# Month=34, Predicted=757.0421, Expected=791.0000
# Month=35, Predicted=788.0172, Expected=760.0000
# Month=36, Predicted=765.5854, Expected=802.0000
# Month=37, Predicted=811.6931, Expected=828.0000
# Month=38, Predicted=837.9917, Expected=778.0000
# Month=39, Predicted=786.8349, Expected=889.0000
# Month=40, Predicted=891.6864, Expected=902.0000
# Month=41, Predicted=899.0035, Expected=969.0000
# Month=42, Predicted=956.1244, Expected=947.0000
# Month=43, Predicted=893.1579, Expected=908.0000
# Month=44, Predicted=845.5455, Expected=867.0000
# Month=45, Predicted=810.4260, Expected=815.0000
# Month=46, Predicted=771.2141, Expected=812.0000
# Month=47, Predicted=794.2795, Expected=773.0000
# Month=48, Predicted=766.0566, Expected=813.0000
# Month=49, Predicted=818.9987, Expected=834.0000
# Month=50, Predicted=841.0098, Expected=782.0000
# Month=51, Predicted=787.3720, Expected=892.0000
# Month=52, Predicted=894.6791, Expected=903.0000
# Month=53, Predicted=899.7411, Expected=966.0000
# Month=54, Predicted=953.3150, Expected=937.0000
# Month=55, Predicted=884.8757, Expected=896.0000
# Month=56, Predicted=838.5945, Expected=858.0000
# Month=57, Predicted=808.7569, Expected=817.0000
# Month=58, Predicted=781.2891, Expected=827.0000
# Month=59, Predicted=813.4733, Expected=797.0000
# Month=60, Predicted=788.1696, Expected=843.0000
# Run 5 — RMSE: 46.801103, MSE: 2190.343223, NMSE: 0.0099891899
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=777.6249, Expected=804.0000
# Month=2, Predicted=794.1573, Expected=756.0000
# Month=3, Predicted=839.8934, Expected=860.0000
# Month=4, Predicted=882.6314, Expected=878.0000
# Month=5, Predicted=930.5735, Expected=942.0000
# Month=6, Predicted=922.3595, Expected=913.0000
# Month=7, Predicted=866.3956, Expected=869.0000
# Month=8, Predicted=821.1679, Expected=834.0000
# Month=9, Predicted=800.7813, Expected=790.0000
# Month=10, Predicted=777.5038, Expected=800.0000
# Month=11, Predicted=789.5294, Expected=763.0000
# Month=12, Predicted=774.8810, Expected=800.0000
# Month=13, Predicted=825.4495, Expected=826.0000
# Month=14, Predicted=818.7478, Expected=799.0000
# Month=15, Predicted=866.0932, Expected=890.0000
# Month=16, Predicted=917.9518, Expected=900.0000
# Month=17, Predicted=955.9737, Expected=961.0000
# Month=18, Predicted=944.4816, Expected=935.0000
# Month=19, Predicted=891.8983, Expected=894.0000
# Month=20, Predicted=847.7326, Expected=855.0000
# Month=21, Predicted=821.4867, Expected=809.0000
# Month=22, Predicted=795.6675, Expected=810.0000
# Month=23, Predicted=800.2360, Expected=766.0000
# Month=24, Predicted=783.9211, Expected=805.0000
# Month=25, Predicted=831.9914, Expected=821.0000
# Month=26, Predicted=796.3856, Expected=773.0000
# Month=27, Predicted=860.3221, Expected=883.0000
# Month=28, Predicted=900.5889, Expected=898.0000
# Month=29, Predicted=954.2360, Expected=957.0000
# Month=30, Predicted=942.3884, Expected=924.0000
# Month=31, Predicted=878.9011, Expected=881.0000
# Month=32, Predicted=833.9886, Expected=837.0000
# Month=33, Predicted=802.0066, Expected=784.0000
# Month=34, Predicted=768.4127, Expected=791.0000
# Month=35, Predicted=780.6936, Expected=760.0000
# Month=36, Predicted=775.3131, Expected=802.0000
# Month=37, Predicted=829.3146, Expected=828.0000
# Month=38, Predicted=810.2203, Expected=778.0000
# Month=39, Predicted=863.5961, Expected=889.0000
# Month=40, Predicted=905.4171, Expected=902.0000
# Month=41, Predicted=951.2558, Expected=969.0000
# Month=42, Predicted=948.9724, Expected=947.0000
# Month=43, Predicted=902.4852, Expected=908.0000
# Month=44, Predicted=861.7402, Expected=867.0000
# Month=45, Predicted=833.2766, Expected=815.0000
# Month=46, Predicted=800.9627, Expected=812.0000
# Month=47, Predicted=801.1404, Expected=773.0000
# Month=48, Predicted=784.4589, Expected=813.0000
# Month=49, Predicted=839.9088, Expected=834.0000
# Month=50, Predicted=821.6100, Expected=782.0000
# Month=51, Predicted=864.2563, Expected=892.0000
# Month=52, Predicted=908.0655, Expected=903.0000
# Month=53, Predicted=957.9637, Expected=966.0000
# Month=54, Predicted=951.5220, Expected=937.0000
# Month=55, Predicted=893.2828, Expected=896.0000
# Month=56, Predicted=849.0253, Expected=858.0000
# Month=57, Predicted=824.1399, Expected=817.0000
# Month=58, Predicted=804.2251, Expected=827.0000
# Month=59, Predicted=817.0510, Expected=797.0000
# Month=60, Predicted=813.1048, Expected=843.0000
# Run 6 — RMSE: 18.549571, MSE: 344.086570, NMSE: 0.0017634973
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=768.8082, Expected=804.0000
# Month=2, Predicted=811.8188, Expected=756.0000
# Month=3, Predicted=825.3485, Expected=860.0000
# Month=4, Predicted=883.2135, Expected=878.0000
# Month=5, Predicted=943.0625, Expected=942.0000
# Month=6, Predicted=938.7037, Expected=913.0000
# Month=7, Predicted=863.6555, Expected=869.0000
# Month=8, Predicted=821.8560, Expected=834.0000
# Month=9, Predicted=808.2583, Expected=790.0000
# Month=10, Predicted=773.3937, Expected=800.0000
# Month=11, Predicted=788.2414, Expected=763.0000
# Month=12, Predicted=774.6294, Expected=800.0000
# Month=13, Predicted=819.6605, Expected=826.0000
# Month=14, Predicted=827.9257, Expected=799.0000
# Month=15, Predicted=859.0332, Expected=890.0000
# Month=16, Predicted=909.2601, Expected=900.0000
# Month=17, Predicted=974.1434, Expected=961.0000
# Month=18, Predicted=958.1975, Expected=935.0000
# Month=19, Predicted=889.8228, Expected=894.0000
# Month=20, Predicted=846.7257, Expected=855.0000
# Month=21, Predicted=827.0395, Expected=809.0000
# Month=22, Predicted=790.8661, Expected=810.0000
# Month=23, Predicted=797.6886, Expected=766.0000
# Month=24, Predicted=775.4216, Expected=805.0000
# Month=25, Predicted=822.2363, Expected=821.0000
# Month=26, Predicted=822.8322, Expected=773.0000
# Month=27, Predicted=840.3101, Expected=883.0000
# Month=28, Predicted=906.3625, Expected=898.0000
# Month=29, Predicted=972.6906, Expected=957.0000
# Month=30, Predicted=967.5649, Expected=924.0000
# Month=31, Predicted=896.2927, Expected=881.0000
# Month=32, Predicted=831.3974, Expected=837.0000
# Month=33, Predicted=805.8124, Expected=784.0000
# Month=34, Predicted=763.0937, Expected=791.0000
# Month=35, Predicted=777.5921, Expected=760.0000
# Month=36, Predicted=765.6024, Expected=802.0000
# Month=37, Predicted=817.2925, Expected=828.0000
# Month=38, Predicted=833.0191, Expected=778.0000
# Month=39, Predicted=843.3283, Expected=889.0000
# Month=40, Predicted=912.4119, Expected=902.0000
# Month=41, Predicted=973.0655, Expected=969.0000
# Month=42, Predicted=973.4779, Expected=947.0000
# Month=43, Predicted=910.2447, Expected=908.0000
# Month=44, Predicted=858.5871, Expected=867.0000
# Month=45, Predicted=836.8611, Expected=815.0000
# Month=46, Predicted=794.9382, Expected=812.0000
# Month=47, Predicted=799.5809, Expected=773.0000
# Month=48, Predicted=779.4878, Expected=813.0000
# Month=49, Predicted=828.3123, Expected=834.0000
# Month=50, Predicted=837.2246, Expected=782.0000
# Month=51, Predicted=849.1919, Expected=892.0000
# Month=52, Predicted=915.1486, Expected=903.0000
# Month=53, Predicted=979.3260, Expected=966.0000
# Month=54, Predicted=974.5072, Expected=937.0000
# Month=55, Predicted=909.1045, Expected=896.0000
# Month=56, Predicted=846.1907, Expected=858.0000
# Month=57, Predicted=827.8878, Expected=817.0000
# Month=58, Predicted=798.3002, Expected=827.0000
# Month=59, Predicted=814.1320, Expected=797.0000
# Month=60, Predicted=804.1951, Expected=843.0000
# Run 7 — RMSE: 26.499594, MSE: 702.228458, NMSE: 0.0028594578
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=772.1260, Expected=804.0000
# Month=2, Predicted=761.8385, Expected=756.0000
# Month=3, Predicted=826.2154, Expected=860.0000
# Month=4, Predicted=863.8781, Expected=878.0000
# Month=5, Predicted=929.9588, Expected=942.0000
# Month=6, Predicted=950.6814, Expected=913.0000
# Month=7, Predicted=886.1789, Expected=869.0000
# Month=8, Predicted=823.1630, Expected=834.0000
# Month=9, Predicted=807.4895, Expected=790.0000
# Month=10, Predicted=782.5705, Expected=800.0000
# Month=11, Predicted=787.0876, Expected=763.0000
# Month=12, Predicted=805.1535, Expected=800.0000
# Month=13, Predicted=825.7902, Expected=826.0000
# Month=14, Predicted=799.6949, Expected=799.0000
# Month=15, Predicted=890.0617, Expected=890.0000
# Month=16, Predicted=909.5421, Expected=900.0000
# Month=17, Predicted=949.0238, Expected=961.0000
# Month=18, Predicted=946.1977, Expected=935.0000
# Month=19, Predicted=890.3531, Expected=894.0000
# Month=20, Predicted=848.7498, Expected=855.0000
# Month=21, Predicted=829.2662, Expected=809.0000
# Month=22, Predicted=800.4161, Expected=810.0000
# Month=23, Predicted=799.4366, Expected=766.0000
# Month=24, Predicted=805.6691, Expected=805.0000
# Month=25, Predicted=828.6667, Expected=821.0000
# Month=26, Predicted=810.3740, Expected=773.0000
# Month=27, Predicted=873.0303, Expected=883.0000
# Month=28, Predicted=893.5732, Expected=898.0000
# Month=29, Predicted=938.1200, Expected=957.0000
# Month=30, Predicted=947.0212, Expected=924.0000
# Month=31, Predicted=872.5695, Expected=881.0000
# Month=32, Predicted=822.6328, Expected=837.0000
# Month=33, Predicted=803.2921, Expected=784.0000
# Month=34, Predicted=769.7666, Expected=791.0000
# Month=35, Predicted=771.5159, Expected=760.0000
# Month=36, Predicted=784.3982, Expected=802.0000
# Month=37, Predicted=820.1638, Expected=828.0000
# Month=38, Predicted=786.7868, Expected=778.0000
# Month=39, Predicted=860.3048, Expected=889.0000
# Month=40, Predicted=896.3148, Expected=902.0000
# Month=41, Predicted=950.5657, Expected=969.0000
# Month=42, Predicted=977.7944, Expected=947.0000
# Month=43, Predicted=929.0070, Expected=908.0000
# Month=44, Predicted=859.5334, Expected=867.0000
# Month=45, Predicted=837.0013, Expected=815.0000
# Month=46, Predicted=806.0983, Expected=812.0000
# Month=47, Predicted=798.4691, Expected=773.0000
# Month=48, Predicted=803.3944, Expected=813.0000
# Month=49, Predicted=834.6775, Expected=834.0000
# Month=50, Predicted=808.6788, Expected=782.0000
# Month=51, Predicted=881.6808, Expected=892.0000
# Month=52, Predicted=900.1313, Expected=903.0000
# Month=53, Predicted=965.0788, Expected=966.0000
# Month=54, Predicted=969.8444, Expected=937.0000
# Month=55, Predicted=891.0816, Expected=896.0000
# Month=56, Predicted=837.2948, Expected=858.0000
# Month=57, Predicted=824.2037, Expected=817.0000
# Month=58, Predicted=801.3218, Expected=827.0000
# Month=59, Predicted=809.5415, Expected=797.0000
# Month=60, Predicted=827.0182, Expected=843.0000
# Run 8 — RMSE: 17.863021, MSE: 319.087513, NMSE: 0.0015142930
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=743.6143, Expected=804.0000
# Month=2, Predicted=797.6666, Expected=756.0000
# Month=3, Predicted=844.0501, Expected=860.0000
# Month=4, Predicted=862.3574, Expected=878.0000
# Month=5, Predicted=904.1163, Expected=942.0000
# Month=6, Predicted=919.2697, Expected=913.0000
# Month=7, Predicted=861.5674, Expected=869.0000
# Month=8, Predicted=814.3264, Expected=834.0000
# Month=9, Predicted=790.3929, Expected=790.0000
# Month=10, Predicted=779.0050, Expected=800.0000
# Month=11, Predicted=790.4792, Expected=763.0000
# Month=12, Predicted=802.5458, Expected=800.0000
# Month=13, Predicted=792.4030, Expected=826.0000
# Month=14, Predicted=831.8743, Expected=799.0000
# Month=15, Predicted=868.6091, Expected=890.0000
# Month=16, Predicted=899.9249, Expected=900.0000
# Month=17, Predicted=947.5711, Expected=961.0000
# Month=18, Predicted=953.4189, Expected=935.0000
# Month=19, Predicted=893.9722, Expected=894.0000
# Month=20, Predicted=842.3055, Expected=855.0000
# Month=21, Predicted=812.7440, Expected=809.0000
# Month=22, Predicted=798.7909, Expected=810.0000
# Month=23, Predicted=804.2227, Expected=766.0000
# Month=24, Predicted=815.2557, Expected=805.0000
# Month=25, Predicted=796.9133, Expected=821.0000
# Month=26, Predicted=836.3985, Expected=773.0000
# Month=27, Predicted=869.8032, Expected=883.0000
# Month=28, Predicted=889.7567, Expected=898.0000
# Month=29, Predicted=960.9276, Expected=957.0000
# Month=30, Predicted=970.4654, Expected=924.0000
# Month=31, Predicted=914.3394, Expected=881.0000
# Month=32, Predicted=849.7107, Expected=837.0000
# Month=33, Predicted=811.0465, Expected=784.0000
# Month=34, Predicted=793.2394, Expected=791.0000
# Month=35, Predicted=789.4959, Expected=760.0000
# Month=36, Predicted=805.5718, Expected=802.0000
# Month=37, Predicted=797.5015, Expected=828.0000
# Month=38, Predicted=845.2958, Expected=778.0000
# Month=39, Predicted=882.7038, Expected=889.0000
# Month=40, Predicted=897.5257, Expected=902.0000
# Month=41, Predicted=956.3720, Expected=969.0000
# Month=42, Predicted=966.4797, Expected=947.0000
# Month=43, Predicted=910.6874, Expected=908.0000
# Month=44, Predicted=860.4374, Expected=867.0000
# Month=45, Predicted=829.9119, Expected=815.0000
# Month=46, Predicted=814.3593, Expected=812.0000
# Month=47, Predicted=812.4953, Expected=773.0000
# Month=48, Predicted=822.2935, Expected=813.0000
# Month=49, Predicted=805.3903, Expected=834.0000
# Month=50, Predicted=850.5666, Expected=782.0000
# Month=51, Predicted=888.3577, Expected=892.0000
# Month=52, Predicted=900.9260, Expected=903.0000
# Month=53, Predicted=971.1325, Expected=966.0000
# Month=54, Predicted=979.3200, Expected=937.0000
# Month=55, Predicted=923.9784, Expected=896.0000
# Month=56, Predicted=862.3275, Expected=858.0000
# Month=57, Predicted=827.0155, Expected=817.0000
# Month=58, Predicted=813.0289, Expected=827.0000
# Month=59, Predicted=819.6574, Expected=797.0000
# Month=60, Predicted=834.7515, Expected=843.0000
# Run 9 — RMSE: 26.133680, MSE: 682.969208, NMSE: 0.0033382721
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=753.0468, Expected=804.0000
# Month=2, Predicted=806.9240, Expected=756.0000
# Month=3, Predicted=756.4896, Expected=860.0000
# Month=4, Predicted=868.0576, Expected=878.0000
# Month=5, Predicted=878.7865, Expected=942.0000
# Month=6, Predicted=945.4946, Expected=913.0000
# Month=7, Predicted=912.1671, Expected=869.0000
# Month=8, Predicted=868.3164, Expected=834.0000
# Month=9, Predicted=833.5738, Expected=790.0000
# Month=10, Predicted=790.1114, Expected=800.0000
# Month=11, Predicted=800.6917, Expected=763.0000
# Month=12, Predicted=763.6730, Expected=800.0000
# Month=13, Predicted=801.9139, Expected=826.0000
# Month=14, Predicted=827.5773, Expected=799.0000
# Month=15, Predicted=799.4564, Expected=890.0000
# Month=16, Predicted=896.4378, Expected=900.0000
# Month=17, Predicted=900.6492, Expected=961.0000
# Month=18, Predicted=964.2588, Expected=935.0000
# Month=19, Predicted=934.4079, Expected=894.0000
# Month=20, Predicted=893.4521, Expected=855.0000
# Month=21, Predicted=854.7348, Expected=809.0000
# Month=22, Predicted=809.2416, Expected=810.0000
# Month=23, Predicted=810.6380, Expected=766.0000
# Month=24, Predicted=766.8421, Expected=805.0000
# Month=25, Predicted=807.0887, Expected=821.0000
# Month=26, Predicted=822.4073, Expected=773.0000
# Month=27, Predicted=773.7218, Expected=883.0000
# Month=28, Predicted=891.4852, Expected=898.0000
# Month=29, Predicted=898.9887, Expected=957.0000
# Month=30, Predicted=960.1551, Expected=924.0000
# Month=31, Predicted=923.3112, Expected=881.0000
# Month=32, Predicted=880.4411, Expected=837.0000
# Month=33, Predicted=836.7921, Expected=784.0000
# Month=34, Predicted=784.3668, Expected=791.0000
# Month=35, Predicted=791.7591, Expected=760.0000
# Month=36, Predicted=760.7380, Expected=802.0000
# Month=37, Predicted=804.2119, Expected=828.0000
# Month=38, Predicted=829.6388, Expected=778.0000
# Month=39, Predicted=778.6198, Expected=889.0000
# Month=40, Predicted=897.5731, Expected=902.0000
# Month=41, Predicted=902.8086, Expected=969.0000
# Month=42, Predicted=972.8697, Expected=947.0000
# Month=43, Predicted=946.2975, Expected=908.0000
# Month=44, Predicted=907.2461, Expected=867.0000
# Month=45, Predicted=866.5999, Expected=815.0000
# Month=46, Predicted=815.2148, Expected=812.0000
# Month=47, Predicted=812.5084, Expected=773.0000
# Month=48, Predicted=773.7480, Expected=813.0000
# Month=49, Predicted=815.0933, Expected=834.0000
# Month=50, Predicted=835.5268, Expected=782.0000
# Month=51, Predicted=782.7493, Expected=892.0000
# Month=52, Predicted=900.4903, Expected=903.0000
# Month=53, Predicted=903.8627, Expected=966.0000
# Month=54, Predicted=969.5312, Expected=937.0000
# Month=55, Predicted=936.3355, Expected=896.0000
# Month=56, Predicted=895.3858, Expected=858.0000
# Month=57, Predicted=857.6586, Expected=817.0000
# Month=58, Predicted=817.1122, Expected=827.0000
# Month=59, Predicted=827.7167, Expected=797.0000
# Month=60, Predicted=797.6233, Expected=843.0000
# Run 10 — RMSE: 47.838384, MSE: 2288.510988, NMSE: 0.0101291990
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=750.5554, Expected=804.0000
# Month=2, Predicted=811.3182, Expected=756.0000
# Month=3, Predicted=785.6809, Expected=860.0000
# Month=4, Predicted=869.8705, Expected=878.0000
# Month=5, Predicted=894.4467, Expected=942.0000
# Month=6, Predicted=946.9911, Expected=913.0000
# Month=7, Predicted=922.5065, Expected=869.0000
# Month=8, Predicted=854.2877, Expected=834.0000
# Month=9, Predicted=807.3070, Expected=790.0000
# Month=10, Predicted=776.4888, Expected=800.0000
# Month=11, Predicted=789.5812, Expected=763.0000
# Month=12, Predicted=778.7424, Expected=800.0000
# Month=13, Predicted=800.0862, Expected=826.0000
# Month=14, Predicted=835.0404, Expected=799.0000
# Month=15, Predicted=815.7055, Expected=890.0000
# Month=16, Predicted=893.8736, Expected=900.0000
# Month=17, Predicted=907.5740, Expected=961.0000
# Month=18, Predicted=961.1104, Expected=935.0000
# Month=19, Predicted=938.4653, Expected=894.0000
# Month=20, Predicted=879.3323, Expected=855.0000
# Month=21, Predicted=829.5537, Expected=809.0000
# Month=22, Predicted=793.4746, Expected=810.0000
# Month=23, Predicted=798.5228, Expected=766.0000
# Month=24, Predicted=781.8491, Expected=805.0000
# Month=25, Predicted=804.6994, Expected=821.0000
# Month=26, Predicted=834.3818, Expected=773.0000
# Month=27, Predicted=798.7353, Expected=883.0000
# Month=28, Predicted=894.8548, Expected=898.0000
# Month=29, Predicted=915.5478, Expected=957.0000
# Month=30, Predicted=963.2403, Expected=924.0000
# Month=31, Predicted=935.8818, Expected=881.0000
# Month=32, Predicted=865.9059, Expected=837.0000
# Month=33, Predicted=814.0278, Expected=784.0000
# Month=34, Predicted=772.0582, Expected=791.0000
# Month=35, Predicted=782.0861, Expected=760.0000
# Month=36, Predicted=779.6597, Expected=802.0000
# Month=37, Predicted=806.0810, Expected=828.0000
# Month=38, Predicted=839.9978, Expected=778.0000
# Month=39, Predicted=803.1778, Expected=889.0000
# Month=40, Predicted=900.4082, Expected=902.0000
# Month=41, Predicted=918.7144, Expected=969.0000
# Month=42, Predicted=974.9032, Expected=947.0000
# Month=43, Predicted=957.7968, Expected=908.0000
# Month=44, Predicted=897.3364, Expected=867.0000
# Month=45, Predicted=842.1055, Expected=815.0000
# Month=46, Predicted=798.5424, Expected=812.0000
# Month=47, Predicted=798.7662, Expected=773.0000
# Month=48, Predicted=787.8858, Expected=813.0000
# Month=49, Predicted=814.3245, Expected=834.0000
# Month=50, Predicted=847.1820, Expected=782.0000
# Month=51, Predicted=810.2553, Expected=892.0000
# Month=52, Predicted=903.8530, Expected=903.0000
# Month=53, Predicted=922.4593, Expected=966.0000
# Month=54, Predicted=972.3926, Expected=937.0000
# Month=55, Predicted=949.7425, Expected=896.0000
# Month=56, Predicted=883.6337, Expected=858.0000
# Month=57, Predicted=834.1869, Expected=817.0000
# Month=58, Predicted=802.1165, Expected=827.0000
# Month=59, Predicted=817.0313, Expected=797.0000
# Month=60, Predicted=810.3494, Expected=843.0000
# Run 11 — RMSE: 40.338389, MSE: 1627.185611, NMSE: 0.0070570478
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=778.9940, Expected=804.0000
# Month=2, Predicted=773.2060, Expected=756.0000
# Month=3, Predicted=835.6905, Expected=860.0000
# Month=4, Predicted=853.0219, Expected=878.0000
# Month=5, Predicted=929.1208, Expected=942.0000
# Month=6, Predicted=921.7948, Expected=913.0000
# Month=7, Predicted=858.1135, Expected=869.0000
# Month=8, Predicted=827.5739, Expected=834.0000
# Month=9, Predicted=810.2737, Expected=790.0000
# Month=10, Predicted=774.9486, Expected=800.0000
# Month=11, Predicted=788.0222, Expected=763.0000
# Month=12, Predicted=792.4853, Expected=800.0000
# Month=13, Predicted=828.6412, Expected=826.0000
# Month=14, Predicted=806.1475, Expected=799.0000
# Month=15, Predicted=864.3279, Expected=890.0000
# Month=16, Predicted=883.8014, Expected=900.0000
# Month=17, Predicted=956.0677, Expected=961.0000
# Month=18, Predicted=944.3107, Expected=935.0000
# Month=19, Predicted=880.2711, Expected=894.0000
# Month=20, Predicted=852.4525, Expected=855.0000
# Month=21, Predicted=830.2543, Expected=809.0000
# Month=22, Predicted=793.5890, Expected=810.0000
# Month=23, Predicted=797.8331, Expected=766.0000
# Month=24, Predicted=795.7780, Expected=805.0000
# Month=25, Predicted=836.3230, Expected=821.0000
# Month=26, Predicted=808.9096, Expected=773.0000
# Month=27, Predicted=861.5613, Expected=883.0000
# Month=28, Predicted=872.5062, Expected=898.0000
# Month=29, Predicted=961.0144, Expected=957.0000
# Month=30, Predicted=967.8868, Expected=924.0000
# Month=31, Predicted=866.5578, Expected=881.0000
# Month=32, Predicted=836.4394, Expected=837.0000
# Month=33, Predicted=809.0765, Expected=784.0000
# Month=34, Predicted=766.8550, Expected=791.0000
# Month=35, Predicted=778.3896, Expected=760.0000
# Month=36, Predicted=785.4697, Expected=802.0000
# Month=37, Predicted=831.0541, Expected=828.0000
# Month=38, Predicted=806.9385, Expected=778.0000
# Month=39, Predicted=863.0427, Expected=889.0000
# Month=40, Predicted=878.1992, Expected=902.0000
# Month=41, Predicted=960.5471, Expected=969.0000
# Month=42, Predicted=966.6994, Expected=947.0000
# Month=43, Predicted=892.6282, Expected=908.0000
# Month=44, Predicted=864.6186, Expected=867.0000
# Month=45, Predicted=840.2327, Expected=815.0000
# Month=46, Predicted=798.3949, Expected=812.0000
# Month=47, Predicted=799.1479, Expected=773.0000
# Month=48, Predicted=796.4999, Expected=813.0000
# Month=49, Predicted=847.1894, Expected=834.0000
# Month=50, Predicted=819.0114, Expected=782.0000
# Month=51, Predicted=869.4073, Expected=892.0000
# Month=52, Predicted=879.6766, Expected=903.0000
# Month=53, Predicted=966.7090, Expected=966.0000
# Month=54, Predicted=979.1682, Expected=937.0000
# Month=55, Predicted=880.4313, Expected=896.0000
# Month=56, Predicted=851.1663, Expected=858.0000
# Month=57, Predicted=830.2947, Expected=817.0000
# Month=58, Predicted=800.5269, Expected=827.0000
# Month=59, Predicted=814.7548, Expected=797.0000
# Month=60, Predicted=824.3406, Expected=843.0000
# Run 12 — RMSE: 20.308745, MSE: 412.445117, NMSE: 0.0021035855
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=767.2535, Expected=804.0000
# Month=2, Predicted=804.5581, Expected=756.0000
# Month=3, Predicted=838.7531, Expected=860.0000
# Month=4, Predicted=886.1444, Expected=878.0000
# Month=5, Predicted=945.1397, Expected=942.0000
# Month=6, Predicted=920.8607, Expected=913.0000
# Month=7, Predicted=870.1486, Expected=869.0000
# Month=8, Predicted=818.1230, Expected=834.0000
# Month=9, Predicted=809.0313, Expected=790.0000
# Month=10, Predicted=783.7071, Expected=800.0000
# Month=11, Predicted=777.9643, Expected=763.0000
# Month=12, Predicted=801.3979, Expected=800.0000
# Month=13, Predicted=813.7553, Expected=826.0000
# Month=14, Predicted=797.7295, Expected=799.0000
# Month=15, Predicted=875.1373, Expected=890.0000
# Month=16, Predicted=912.8845, Expected=900.0000
# Month=17, Predicted=978.0476, Expected=961.0000
# Month=18, Predicted=939.4648, Expected=935.0000
# Month=19, Predicted=888.2968, Expected=894.0000
# Month=20, Predicted=845.9034, Expected=855.0000
# Month=21, Predicted=831.3893, Expected=809.0000
# Month=22, Predicted=802.7814, Expected=810.0000
# Month=23, Predicted=786.5880, Expected=766.0000
# Month=24, Predicted=798.8137, Expected=805.0000
# Month=25, Predicted=818.1591, Expected=821.0000
# Month=26, Predicted=799.0044, Expected=773.0000
# Month=27, Predicted=860.1254, Expected=883.0000
# Month=28, Predicted=918.0209, Expected=898.0000
# Month=29, Predicted=962.5398, Expected=957.0000
# Month=30, Predicted=935.1442, Expected=924.0000
# Month=31, Predicted=884.9523, Expected=881.0000
# Month=32, Predicted=828.1668, Expected=837.0000
# Month=33, Predicted=808.8622, Expected=784.0000
# Month=34, Predicted=774.0025, Expected=791.0000
# Month=35, Predicted=768.7717, Expected=760.0000
# Month=36, Predicted=797.3907, Expected=802.0000
# Month=37, Predicted=816.7590, Expected=828.0000
# Month=38, Predicted=799.6592, Expected=778.0000
# Month=39, Predicted=864.6191, Expected=889.0000
# Month=40, Predicted=921.6834, Expected=902.0000
# Month=41, Predicted=973.3885, Expected=969.0000
# Month=42, Predicted=950.7871, Expected=947.0000
# Month=43, Predicted=913.7041, Expected=908.0000
# Month=44, Predicted=855.1483, Expected=867.0000
# Month=45, Predicted=837.8592, Expected=815.0000
# Month=46, Predicted=804.2079, Expected=812.0000
# Month=47, Predicted=788.9043, Expected=773.0000
# Month=48, Predicted=803.7665, Expected=813.0000
# Month=49, Predicted=824.0037, Expected=834.0000
# Month=50, Predicted=808.2784, Expected=782.0000
# Month=51, Predicted=868.7469, Expected=892.0000
# Month=52, Predicted=927.9182, Expected=903.0000
# Month=53, Predicted=969.7441, Expected=966.0000
# Month=54, Predicted=947.0349, Expected=937.0000
# Month=55, Predicted=904.2523, Expected=896.0000
# Month=56, Predicted=841.4865, Expected=858.0000
# Month=57, Predicted=828.3837, Expected=817.0000
# Month=58, Predicted=807.6435, Expected=827.0000
# Month=59, Predicted=804.3646, Expected=797.0000
# Month=60, Predicted=835.4635, Expected=843.0000
# Run 13 — RMSE: 16.317076, MSE: 266.246963, NMSE: 0.0012290856
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=751.5208, Expected=804.0000
# Month=2, Predicted=808.2919, Expected=756.0000
# Month=3, Predicted=761.7935, Expected=860.0000
# Month=4, Predicted=865.3185, Expected=878.0000
# Month=5, Predicted=882.4341, Expected=942.0000
# Month=6, Predicted=946.7304, Expected=913.0000
# Month=7, Predicted=915.9821, Expected=869.0000
# Month=8, Predicted=867.2625, Expected=834.0000
# Month=9, Predicted=828.9076, Expected=790.0000
# Month=10, Predicted=783.8172, Expected=800.0000
# Month=11, Predicted=795.9380, Expected=763.0000
# Month=12, Predicted=761.3140, Expected=800.0000
# Month=13, Predicted=800.5455, Expected=826.0000
# Month=14, Predicted=829.3638, Expected=799.0000
# Month=15, Predicted=802.9645, Expected=890.0000
# Month=16, Predicted=894.6917, Expected=900.0000
# Month=17, Predicted=904.1499, Expected=961.0000
# Month=18, Predicted=965.3526, Expected=935.0000
# Month=19, Predicted=937.7113, Expected=894.0000
# Month=20, Predicted=892.3719, Expected=855.0000
# Month=21, Predicted=850.0456, Expected=809.0000
# Month=22, Predicted=802.7395, Expected=810.0000
# Month=23, Predicted=805.3806, Expected=766.0000
# Month=24, Predicted=763.4717, Expected=805.0000
# Month=25, Predicted=804.9580, Expected=821.0000
# Month=26, Predicted=823.8968, Expected=773.0000
# Month=27, Predicted=776.5972, Expected=883.0000
# Month=28, Predicted=888.0079, Expected=898.0000
# Month=29, Predicted=902.6803, Expected=957.0000
# Month=30, Predicted=962.0359, Expected=924.0000
# Month=31, Predicted=927.4280, Expected=881.0000
# Month=32, Predicted=879.3010, Expected=837.0000
# Month=33, Predicted=831.6092, Expected=784.0000
# Month=34, Predicted=777.0613, Expected=791.0000
# Month=35, Predicted=786.1389, Expected=760.0000
# Month=36, Predicted=757.7151, Expected=802.0000
# Month=37, Predicted=802.8699, Expected=828.0000
# Month=38, Predicted=831.9978, Expected=778.0000
# Month=39, Predicted=782.6800, Expected=889.0000
# Month=40, Predicted=894.2228, Expected=902.0000
# Month=41, Predicted=906.3647, Expected=969.0000
# Month=42, Predicted=973.9274, Expected=947.0000
# Month=43, Predicted=950.4796, Expected=908.0000
# Month=44, Predicted=907.0583, Expected=867.0000
# Month=45, Predicted=862.3234, Expected=815.0000
# Month=46, Predicted=808.5278, Expected=812.0000
# Month=47, Predicted=806.8242, Expected=773.0000
# Month=48, Predicted=769.8795, Expected=813.0000
# Month=49, Predicted=812.9772, Expected=834.0000
# Month=50, Predicted=837.2596, Expected=782.0000
# Month=51, Predicted=786.2998, Expected=892.0000
# Month=52, Predicted=897.0771, Expected=903.0000
# Month=53, Predicted=907.5263, Expected=966.0000
# Month=54, Predicted=970.8710, Expected=937.0000
# Month=55, Predicted=940.3614, Expected=896.0000
# Month=56, Predicted=894.5871, Expected=858.0000
# Month=57, Predicted=853.0697, Expected=817.0000
# Month=58, Predicted=810.8459, Expected=827.0000
# Month=59, Predicted=822.9750, Expected=797.0000
# Month=60, Predicted=795.3697, Expected=843.0000
# Run 14 — RMSE: 46.960940, MSE: 2205.329908, NMSE: 0.0093102064
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=755.1007, Expected=804.0000
# Month=2, Predicted=808.5324, Expected=756.0000
# Month=3, Predicted=753.5695, Expected=860.0000
# Month=4, Predicted=865.7206, Expected=878.0000
# Month=5, Predicted=881.4561, Expected=942.0000
# Month=6, Predicted=947.1238, Expected=913.0000
# Month=7, Predicted=912.5841, Expected=869.0000
# Month=8, Predicted=867.3060, Expected=834.0000
# Month=9, Predicted=833.6168, Expected=790.0000
# Month=10, Predicted=788.3959, Expected=800.0000
# Month=11, Predicted=802.9103, Expected=763.0000
# Month=12, Predicted=762.1596, Expected=800.0000
# Month=13, Predicted=803.9971, Expected=826.0000
# Month=14, Predicted=829.5883, Expected=799.0000
# Month=15, Predicted=799.5962, Expected=890.0000
# Month=16, Predicted=895.4983, Expected=900.0000
# Month=17, Predicted=903.0985, Expected=961.0000
# Month=18, Predicted=966.0128, Expected=935.0000
# Month=19, Predicted=935.1373, Expected=894.0000
# Month=20, Predicted=892.8366, Expected=855.0000
# Month=21, Predicted=854.2164, Expected=809.0000
# Month=22, Predicted=807.2975, Expected=810.0000
# Month=23, Predicted=812.4960, Expected=766.0000
# Month=24, Predicted=764.4100, Expected=805.0000
# Month=25, Predicted=809.0458, Expected=821.0000
# Month=26, Predicted=824.1427, Expected=773.0000
# Month=27, Predicted=771.0023, Expected=883.0000
# Month=28, Predicted=888.7472, Expected=898.0000
# Month=29, Predicted=901.2435, Expected=957.0000
# Month=30, Predicted=961.9638, Expected=924.0000
# Month=31, Predicted=923.2797, Expected=881.0000
# Month=32, Predicted=879.6322, Expected=837.0000
# Month=33, Predicted=835.5676, Expected=784.0000
# Month=34, Predicted=781.3960, Expected=791.0000
# Month=35, Predicted=793.7555, Expected=760.0000
# Month=36, Predicted=760.0949, Expected=802.0000
# Month=37, Predicted=806.1446, Expected=828.0000
# Month=38, Predicted=831.5880, Expected=778.0000
# Month=39, Predicted=775.6488, Expected=889.0000
# Month=40, Predicted=894.7791, Expected=902.0000
# Month=41, Predicted=905.1841, Expected=969.0000
# Month=42, Predicted=974.1737, Expected=947.0000
# Month=43, Predicted=947.5369, Expected=908.0000
# Month=44, Predicted=907.0031, Expected=867.0000
# Month=45, Predicted=865.8546, Expected=815.0000
# Month=46, Predicted=812.4205, Expected=812.0000
# Month=47, Predicted=814.3100, Expected=773.0000
# Month=48, Predicted=772.0565, Expected=813.0000
# Month=49, Predicted=817.0673, Expected=834.0000
# Month=50, Predicted=837.3536, Expected=782.0000
# Month=51, Predicted=779.3793, Expected=892.0000
# Month=52, Predicted=897.7509, Expected=903.0000
# Month=53, Predicted=906.0497, Expected=966.0000
# Month=54, Predicted=971.0579, Expected=937.0000
# Month=55, Predicted=936.7200, Expected=896.0000
# Month=56, Predicted=894.8383, Expected=858.0000
# Month=57, Predicted=857.3276, Expected=817.0000
# Month=58, Predicted=815.9442, Expected=827.0000
# Month=59, Predicted=829.9054, Expected=797.0000
# Month=60, Predicted=797.1747, Expected=843.0000
# Run 15 — RMSE: 48.405818, MSE: 2343.123186, NMSE: 0.0101910047
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=768.8697, Expected=804.0000
# Month=2, Predicted=770.2658, Expected=756.0000
# Month=3, Predicted=826.8336, Expected=860.0000
# Month=4, Predicted=855.7508, Expected=878.0000
# Month=5, Predicted=905.6535, Expected=942.0000
# Month=6, Predicted=929.2120, Expected=913.0000
# Month=7, Predicted=867.5418, Expected=869.0000
# Month=8, Predicted=830.9520, Expected=834.0000
# Month=9, Predicted=810.4040, Expected=790.0000
# Month=10, Predicted=784.2679, Expected=800.0000
# Month=11, Predicted=789.1838, Expected=763.0000
# Month=12, Predicted=811.3561, Expected=800.0000
# Month=13, Predicted=818.2112, Expected=826.0000
# Month=14, Predicted=799.9605, Expected=799.0000
# Month=15, Predicted=871.4175, Expected=890.0000
# Month=16, Predicted=893.2377, Expected=900.0000
# Month=17, Predicted=960.0450, Expected=961.0000
# Month=18, Predicted=947.8945, Expected=935.0000
# Month=19, Predicted=895.6739, Expected=894.0000
# Month=20, Predicted=863.2688, Expected=855.0000
# Month=21, Predicted=837.3658, Expected=809.0000
# Month=22, Predicted=807.4692, Expected=810.0000
# Month=23, Predicted=811.8402, Expected=766.0000
# Month=24, Predicted=826.9341, Expected=805.0000
# Month=25, Predicted=823.3575, Expected=821.0000
# Month=26, Predicted=814.2306, Expected=773.0000
# Month=27, Predicted=885.5124, Expected=883.0000
# Month=28, Predicted=896.9359, Expected=898.0000
# Month=29, Predicted=983.2976, Expected=957.0000
# Month=30, Predicted=958.6102, Expected=924.0000
# Month=31, Predicted=872.0619, Expected=881.0000
# Month=32, Predicted=831.7517, Expected=837.0000
# Month=33, Predicted=801.6376, Expected=784.0000
# Month=34, Predicted=763.9340, Expected=791.0000
# Month=35, Predicted=770.0519, Expected=760.0000
# Month=36, Predicted=790.6676, Expected=802.0000
# Month=37, Predicted=818.9188, Expected=828.0000
# Month=38, Predicted=799.3688, Expected=778.0000
# Month=39, Predicted=870.0704, Expected=889.0000
# Month=40, Predicted=887.0648, Expected=902.0000
# Month=41, Predicted=946.2162, Expected=969.0000
# Month=42, Predicted=964.2919, Expected=947.0000
# Month=43, Predicted=900.6008, Expected=908.0000
# Month=44, Predicted=856.9066, Expected=867.0000
# Month=45, Predicted=837.5213, Expected=815.0000
# Month=46, Predicted=803.4040, Expected=812.0000
# Month=47, Predicted=796.7713, Expected=773.0000
# Month=48, Predicted=811.2011, Expected=813.0000
# Month=49, Predicted=834.3100, Expected=834.0000
# Month=50, Predicted=811.5106, Expected=782.0000
# Month=51, Predicted=878.0269, Expected=892.0000
# Month=52, Predicted=887.3342, Expected=903.0000
# Month=53, Predicted=967.7143, Expected=966.0000
# Month=54, Predicted=973.8478, Expected=937.0000
# Month=55, Predicted=889.5101, Expected=896.0000
# Month=56, Predicted=851.5414, Expected=858.0000
# Month=57, Predicted=832.4901, Expected=817.0000
# Month=58, Predicted=804.4227, Expected=827.0000
# Month=59, Predicted=815.2661, Expected=797.0000
# Month=60, Predicted=842.8608, Expected=843.0000
# Run 16 — RMSE: 19.260454, MSE: 370.965082, NMSE: 0.0018643503
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=750.9803, Expected=804.0000
# Month=2, Predicted=805.0972, Expected=756.0000
# Month=3, Predicted=784.7972, Expected=860.0000
# Month=4, Predicted=879.0869, Expected=878.0000
# ...
# Month=40, Predicted=881.2807, Expected=902.0000
# Month=41, Predicted=953.3380, Expected=969.0000
# Month=42, Predicted=946.7567, Expected=947.0000
# Month=43, Predicted=931.2302, Expected=908.0000
# Month=44, Predicted=887.5442, Expected=867.0000
# Month=45, Predicted=836.6575, Expected=815.0000
# Month=46, Predicted=810.5154, Expected=812.0000
# Month=47, Predicted=825.3463, Expected=773.0000
# Month=48, Predicted=816.4816, Expected=813.0000
# Month=49, Predicted=818.1485, Expected=834.0000
# Month=50, Predicted=827.7229, Expected=782.0000
# Month=51, Predicted=831.0810, Expected=892.0000
# Month=52, Predicted=885.9590, Expected=903.0000
# Month=53, Predicted=955.0877, Expected=966.0000
# Month=54, Predicted=946.1024, Expected=937.0000
# Month=55, Predicted=926.9464, Expected=896.0000
# Month=56, Predicted=866.5208, Expected=858.0000
# Month=57, Predicted=829.8908, Expected=817.0000
# Month=58, Predicted=813.8367, Expected=827.0000
# Month=59, Predicted=849.0069, Expected=797.0000
# Month=60, Predicted=837.4377, Expected=843.0000
# Run 25 — RMSE: 30.318755, MSE: 919.226933, NMSE: 0.0056548876
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=755.4990, Expected=804.0000
# Month=2, Predicted=795.7645, Expected=756.0000
# Month=3, Predicted=863.4625, Expected=860.0000
# Month=4, Predicted=877.7244, Expected=878.0000
# Month=5, Predicted=939.8722, Expected=942.0000
# Month=6, Predicted=936.8031, Expected=913.0000
# Month=7, Predicted=869.2950, Expected=869.0000
# Month=8, Predicted=817.0531, Expected=834.0000
# Month=9, Predicted=805.7206, Expected=790.0000
# Month=10, Predicted=794.2417, Expected=800.0000
# Month=11, Predicted=791.8615, Expected=763.0000
# Month=12, Predicted=813.7314, Expected=800.0000
# Month=13, Predicted=804.0745, Expected=826.0000
# Month=14, Predicted=808.8103, Expected=799.0000
# Month=15, Predicted=886.9825, Expected=890.0000
# Month=16, Predicted=903.8815, Expected=900.0000
# Month=17, Predicted=968.9930, Expected=961.0000
# Month=18, Predicted=956.9088, Expected=935.0000
# Month=19, Predicted=903.4920, Expected=894.0000
# Month=20, Predicted=844.2627, Expected=855.0000
# Month=21, Predicted=827.2780, Expected=809.0000
# Month=22, Predicted=815.6153, Expected=810.0000
# Month=23, Predicted=803.0276, Expected=766.0000
# Month=24, Predicted=817.9403, Expected=805.0000
# Month=25, Predicted=809.9338, Expected=821.0000
# Month=26, Predicted=802.7368, Expected=773.0000
# Month=27, Predicted=870.1801, Expected=883.0000
# Month=28, Predicted=898.5050, Expected=898.0000
# Month=29, Predicted=954.5060, Expected=957.0000
# Month=30, Predicted=948.8610, Expected=924.0000
# Month=31, Predicted=926.7095, Expected=881.0000
# Month=32, Predicted=831.7645, Expected=837.0000
# Month=33, Predicted=810.2840, Expected=784.0000
# Month=34, Predicted=795.9626, Expected=791.0000
# Month=35, Predicted=781.2209, Expected=760.0000
# Month=36, Predicted=798.2353, Expected=802.0000
# Month=37, Predicted=804.9904, Expected=828.0000
# Month=38, Predicted=809.0886, Expected=778.0000
# Month=39, Predicted=880.1248, Expected=889.0000
# Month=40, Predicted=906.5608, Expected=902.0000
# Month=41, Predicted=970.9057, Expected=969.0000
# Month=42, Predicted=965.2810, Expected=947.0000
# Month=43, Predicted=933.0847, Expected=908.0000
# Month=44, Predicted=857.3063, Expected=867.0000
# Month=45, Predicted=837.9912, Expected=815.0000
# Month=46, Predicted=820.1469, Expected=812.0000
# Month=47, Predicted=806.8073, Expected=773.0000
# Month=48, Predicted=816.2501, Expected=813.0000
# Month=49, Predicted=817.3120, Expected=834.0000
# Month=50, Predicted=815.1324, Expected=782.0000
# Month=51, Predicted=884.3055, Expected=892.0000
# Month=52, Predicted=908.2525, Expected=903.0000
# Month=53, Predicted=970.6968, Expected=966.0000
# Month=54, Predicted=960.0843, Expected=937.0000
# Month=55, Predicted=946.4001, Expected=896.0000
# Month=56, Predicted=848.4128, Expected=858.0000
# Month=57, Predicted=832.6764, Expected=817.0000
# Month=58, Predicted=828.7551, Expected=827.0000
# Month=59, Predicted=817.3803, Expected=797.0000
# Month=60, Predicted=836.2413, Expected=843.0000
# Run 26 — RMSE: 20.090509, MSE: 403.628556, NMSE: 0.0018537112
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=752.6611, Expected=804.0000
# Month=2, Predicted=804.1984, Expected=756.0000
# Month=3, Predicted=783.1717, Expected=860.0000
# Month=4, Predicted=859.2494, Expected=878.0000
# Month=5, Predicted=864.0023, Expected=942.0000
# Month=6, Predicted=924.3936, Expected=913.0000
# Month=7, Predicted=873.3208, Expected=869.0000
# Month=8, Predicted=828.9764, Expected=834.0000
# Month=9, Predicted=800.6868, Expected=790.0000
# Month=10, Predicted=765.6322, Expected=800.0000
# Month=11, Predicted=786.6886, Expected=763.0000
# Month=12, Predicted=764.1418, Expected=800.0000
# Month=13, Predicted=800.1699, Expected=826.0000
# Month=14, Predicted=829.6414, Expected=799.0000
# Month=15, Predicted=824.5308, Expected=890.0000
# Month=16, Predicted=891.9203, Expected=900.0000
# Month=17, Predicted=898.7385, Expected=961.0000
# Month=18, Predicted=950.8693, Expected=935.0000
# Month=19, Predicted=908.9966, Expected=894.0000
# Month=20, Predicted=866.8276, Expected=855.0000
# Month=21, Predicted=833.0839, Expected=809.0000
# Month=22, Predicted=800.3542, Expected=810.0000
# Month=23, Predicted=806.4807, Expected=766.0000
# Month=24, Predicted=792.1591, Expected=805.0000
# Month=25, Predicted=815.6562, Expected=821.0000
# Month=26, Predicted=844.9052, Expected=773.0000
# Month=27, Predicted=836.4981, Expected=883.0000
# Month=28, Predicted=889.9626, Expected=898.0000
# Month=29, Predicted=917.9573, Expected=957.0000
# Month=30, Predicted=952.8077, Expected=924.0000
# Month=31, Predicted=914.3146, Expected=881.0000
# Month=32, Predicted=866.4358, Expected=837.0000
# Month=33, Predicted=825.5066, Expected=784.0000
# Month=34, Predicted=788.9044, Expected=791.0000
# Month=35, Predicted=791.6975, Expected=760.0000
# Month=36, Predicted=788.4769, Expected=802.0000
# Month=37, Predicted=812.9957, Expected=828.0000
# Month=38, Predicted=846.4802, Expected=778.0000
# Month=39, Predicted=835.9256, Expected=889.0000
# Month=40, Predicted=892.0484, Expected=902.0000
# Month=41, Predicted=907.9642, Expected=969.0000
# Month=42, Predicted=955.8679, Expected=947.0000
# Month=43, Predicted=915.2161, Expected=908.0000
# Month=44, Predicted=871.3915, Expected=867.0000
# Month=45, Predicted=833.4178, Expected=815.0000
# Month=46, Predicted=792.8216, Expected=812.0000
# Month=47, Predicted=797.4094, Expected=773.0000
# Month=48, Predicted=780.2159, Expected=813.0000
# Month=49, Predicted=813.5552, Expected=834.0000
# Month=50, Predicted=841.3590, Expected=782.0000
# Month=51, Predicted=828.6765, Expected=892.0000
# Month=52, Predicted=894.1859, Expected=903.0000
# Month=53, Predicted=907.1848, Expected=966.0000
# Month=54, Predicted=954.2874, Expected=937.0000
# Month=55, Predicted=911.7209, Expected=896.0000
# Month=56, Predicted=868.1653, Expected=858.0000
# Month=57, Predicted=833.7366, Expected=817.0000
# Month=58, Predicted=803.8542, Expected=827.0000
# Month=59, Predicted=816.9758, Expected=797.0000
# Month=60, Predicted=806.3286, Expected=843.0000
# Run 27 — RMSE: 35.821808, MSE: 1283.201950, NMSE: 0.0075949078
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=752.2972, Expected=804.0000
# Month=2, Predicted=805.9933, Expected=756.0000
# Month=3, Predicted=749.1786, Expected=860.0000
# Month=4, Predicted=861.3737, Expected=878.0000
# Month=5, Predicted=877.8308, Expected=942.0000
# Month=6, Predicted=940.9449, Expected=913.0000
# Month=7, Predicted=903.0650, Expected=869.0000
# Month=8, Predicted=856.5149, Expected=834.0000
# Month=9, Predicted=824.4439, Expected=790.0000
# Month=10, Predicted=781.3961, Expected=800.0000
# Month=11, Predicted=797.7772, Expected=763.0000
# Month=12, Predicted=757.3268, Expected=800.0000
# Month=13, Predicted=800.6107, Expected=826.0000
# Month=14, Predicted=826.4042, Expected=799.0000
# Month=15, Predicted=794.4015, Expected=890.0000
# Month=16, Predicted=891.1627, Expected=900.0000
# Month=17, Predicted=898.8345, Expected=961.0000
# Month=18, Predicted=960.0925, Expected=935.0000
# Month=19, Predicted=926.3888, Expected=894.0000
# Month=20, Predicted=883.0499, Expected=855.0000
# Month=21, Predicted=845.9658, Expected=809.0000
# Month=22, Predicted=801.1216, Expected=810.0000
# Month=23, Predicted=807.9021, Expected=766.0000
# Month=24, Predicted=760.4144, Expected=805.0000
# Month=25, Predicted=806.3955, Expected=821.0000
# Month=26, Predicted=821.6349, Expected=773.0000
# Month=27, Predicted=766.8434, Expected=883.0000
# Month=28, Predicted=885.0447, Expected=898.0000
# Month=29, Predicted=899.1244, Expected=957.0000
# Month=30, Predicted=956.9728, Expected=924.0000
# Month=31, Predicted=914.8703, Expected=881.0000
# Month=32, Predicted=870.0741, Expected=837.0000
# Month=33, Predicted=827.6494, Expected=784.0000
# Month=34, Predicted=775.5822, Expected=791.0000
# Month=35, Predicted=789.5616, Expected=760.0000
# Month=36, Predicted=755.9393, Expected=802.0000
# Month=37, Predicted=803.4453, Expected=828.0000
# Month=38, Predicted=829.0318, Expected=778.0000
# Month=39, Predicted=771.0770, Expected=889.0000
# Month=40, Predicted=890.7131, Expected=902.0000
# Month=41, Predicted=902.5032, Expected=969.0000
# Month=42, Predicted=968.7904, Expected=947.0000
# Month=43, Predicted=938.7670, Expected=908.0000
# Month=44, Predicted=896.5357, Expected=867.0000
# Month=45, Predicted=856.7589, Expected=815.0000
# Month=46, Predicted=805.5846, Expected=812.0000
# Month=47, Predicted=809.1169, Expected=773.0000
# Month=48, Predicted=767.5721, Expected=813.0000
# Month=49, Predicted=814.0508, Expected=834.0000
# Month=50, Predicted=834.5840, Expected=782.0000
# Month=51, Predicted=774.8576, Expected=892.0000
# Month=52, Predicted=893.7841, Expected=903.0000
# Month=53, Predicted=903.5299, Expected=966.0000
# Month=54, Predicted=965.8712, Expected=937.0000
# Month=55, Predicted=928.2442, Expected=896.0000
# Month=56, Predicted=884.9390, Expected=858.0000
# Month=57, Predicted=848.8180, Expected=817.0000
# Month=58, Predicted=809.3707, Expected=827.0000
# Month=59, Predicted=825.1841, Expected=797.0000
# Month=60, Predicted=792.4456, Expected=843.0000
# Run 28 — RMSE: 47.662052, MSE: 2271.671182, NMSE: 0.0100483881
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=776.0769, Expected=804.0000
# Month=2, Predicted=762.8003, Expected=756.0000
# Month=3, Predicted=830.5418, Expected=860.0000
# Month=4, Predicted=870.5242, Expected=878.0000
# Month=5, Predicted=870.1453, Expected=942.0000
# Month=6, Predicted=902.7595, Expected=913.0000
# Month=7, Predicted=869.3425, Expected=869.0000
# Month=8, Predicted=838.8529, Expected=834.0000
# Month=9, Predicted=817.1175, Expected=790.0000
# Month=10, Predicted=794.5647, Expected=800.0000
# Month=11, Predicted=802.0289, Expected=763.0000
# Month=12, Predicted=802.3752, Expected=800.0000
# Month=13, Predicted=832.5890, Expected=826.0000
# Month=14, Predicted=812.8632, Expected=799.0000
# Month=15, Predicted=893.4693, Expected=890.0000
# Month=16, Predicted=922.5329, Expected=900.0000
# Month=17, Predicted=979.5091, Expected=961.0000
# Month=18, Predicted=958.6846, Expected=935.0000
# Month=19, Predicted=908.6180, Expected=894.0000
# Month=20, Predicted=848.8979, Expected=855.0000
# Month=21, Predicted=819.6192, Expected=809.0000
# Month=22, Predicted=790.6811, Expected=810.0000
# Month=23, Predicted=797.1538, Expected=766.0000
# Month=24, Predicted=798.2521, Expected=805.0000
# Month=25, Predicted=831.5750, Expected=821.0000
# Month=26, Predicted=805.4161, Expected=773.0000
# Month=27, Predicted=873.7869, Expected=883.0000
# Month=28, Predicted=899.3312, Expected=898.0000
# Month=29, Predicted=967.4716, Expected=957.0000
# Month=30, Predicted=953.1664, Expected=924.0000
# Month=31, Predicted=885.3692, Expected=881.0000
# Month=32, Predicted=830.1413, Expected=837.0000
# Month=33, Predicted=800.8803, Expected=784.0000
# Month=34, Predicted=765.3867, Expected=791.0000
# Month=35, Predicted=772.4731, Expected=760.0000
# Month=36, Predicted=781.2946, Expected=802.0000
# Month=37, Predicted=819.5978, Expected=828.0000
# Month=38, Predicted=808.8650, Expected=778.0000
# Month=39, Predicted=850.8381, Expected=889.0000
# Month=40, Predicted=895.9154, Expected=902.0000
# Month=41, Predicted=935.7033, Expected=969.0000
# Month=42, Predicted=946.6255, Expected=947.0000
# Month=43, Predicted=898.2600, Expected=908.0000
# Month=44, Predicted=864.3825, Expected=867.0000
# Month=45, Predicted=839.5348, Expected=815.0000
# Month=46, Predicted=806.2292, Expected=812.0000
# Month=47, Predicted=802.9038, Expected=773.0000
# Month=48, Predicted=798.9048, Expected=813.0000
# Month=49, Predicted=829.4300, Expected=834.0000
# Month=50, Predicted=844.0607, Expected=782.0000
# Month=51, Predicted=862.9144, Expected=892.0000
# Month=52, Predicted=897.8992, Expected=903.0000
# Month=53, Predicted=962.9145, Expected=966.0000
# Month=54, Predicted=979.7741, Expected=937.0000
# Month=55, Predicted=901.0961, Expected=896.0000
# Month=56, Predicted=842.4512, Expected=858.0000
# Month=57, Predicted=820.0540, Expected=817.0000
# Month=58, Predicted=794.1306, Expected=827.0000
# Month=59, Predicted=806.5739, Expected=797.0000
# Month=60, Predicted=815.1275, Expected=843.0000
# Run 29 — RMSE: 22.661586, MSE: 513.547501, NMSE: 0.0025448376
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=743.6708, Expected=804.0000
# Month=2, Predicted=819.7383, Expected=756.0000
# Month=3, Predicted=784.2399, Expected=860.0000
# Month=4, Predicted=855.9536, Expected=878.0000
# Month=5, Predicted=899.9051, Expected=942.0000
# Month=6, Predicted=944.5268, Expected=913.0000
# Month=7, Predicted=936.2353, Expected=869.0000
# Month=8, Predicted=838.3966, Expected=834.0000
# Month=9, Predicted=813.3560, Expected=790.0000
# Month=10, Predicted=787.6087, Expected=800.0000
# Month=11, Predicted=792.3092, Expected=763.0000
# Month=12, Predicted=780.8593, Expected=800.0000
# Month=13, Predicted=791.5161, Expected=826.0000
# Month=14, Predicted=842.2832, Expected=799.0000
# Month=15, Predicted=813.6656, Expected=890.0000
# Month=16, Predicted=888.8135, Expected=900.0000
# Month=17, Predicted=927.1600, Expected=961.0000
# Month=18, Predicted=961.3831, Expected=935.0000
# Month=19, Predicted=957.4929, Expected=894.0000
# Month=20, Predicted=868.2914, Expected=855.0000
# Month=21, Predicted=836.2824, Expected=809.0000
# Month=22, Predicted=803.9144, Expected=810.0000
# Month=23, Predicted=801.9113, Expected=766.0000
# Month=24, Predicted=781.6093, Expected=805.0000
# Month=25, Predicted=795.9583, Expected=821.0000
# Month=26, Predicted=839.4226, Expected=773.0000
# Month=27, Predicted=784.2491, Expected=883.0000
# Month=28, Predicted=882.6424, Expected=898.0000
# Month=29, Predicted=924.4776, Expected=957.0000
# Month=30, Predicted=957.7637, Expected=924.0000
# Month=31, Predicted=945.4467, Expected=881.0000
# Month=32, Predicted=850.1537, Expected=837.0000
# Month=33, Predicted=818.3093, Expected=784.0000
# Month=34, Predicted=777.0411, Expected=791.0000
# Month=35, Predicted=781.1422, Expected=760.0000
# Month=36, Predicted=777.7341, Expected=802.0000
# Month=37, Predicted=796.6511, Expected=828.0000
# Month=38, Predicted=845.8336, Expected=778.0000
# Month=39, Predicted=793.1519, Expected=889.0000
# Month=40, Predicted=887.7048, Expected=902.0000
# Month=41, Predicted=927.2453, Expected=969.0000
# Month=42, Predicted=969.9141, Expected=947.0000
# Month=43, Predicted=970.2248, Expected=908.0000
# Month=44, Predicted=882.1004, Expected=867.0000
# Month=45, Predicted=846.8219, Expected=815.0000
# Month=46, Predicted=807.6005, Expected=812.0000
# Month=47, Predicted=801.1430, Expected=773.0000
# Month=48, Predicted=787.2182, Expected=813.0000
# Month=49, Predicted=806.0170, Expected=834.0000
# Month=50, Predicted=852.4896, Expected=782.0000
# Month=51, Predicted=795.2796, Expected=892.0000
# Month=52, Predicted=890.4846, Expected=903.0000
# Month=53, Predicted=928.5996, Expected=966.0000
# Month=54, Predicted=966.1231, Expected=937.0000
# Month=55, Predicted=959.7970, Expected=896.0000
# Month=56, Predicted=867.1636, Expected=858.0000
# Month=57, Predicted=839.3159, Expected=817.0000
# Month=58, Predicted=812.2852, Expected=827.0000
# Month=59, Predicted=820.9545, Expected=797.0000
# Month=60, Predicted=814.0809, Expected=843.0000
# Run 30 — RMSE: 43.285890, MSE: 1873.668278, NMSE: 0.0078247038

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (2 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Output Layer on Monthly Milk Production (2 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Output Layer on Monthly Milk Production (30 runs) =====
# RMSE: 32.067222 ± 12.373305
# MSE:  1181.405432 ± 809.272123
# NMSE: 0.0055472904 ± 0.0035751664
#
# Best run: 20
#   RMSE: 13.748994
#   MSE:  189.034844
#   NMSE: 0.0009525731

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Output Layer — Monthly Milk Production\nPredictions vs Actual (Best of 2 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Output Layer — Monthly Milk Production\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 13.748994
# MSE:  189.034844
# NMSE: 0.0009525731

# %% [markdown]
# ## Observations
#
# ### Fuzzy Output Layer on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
