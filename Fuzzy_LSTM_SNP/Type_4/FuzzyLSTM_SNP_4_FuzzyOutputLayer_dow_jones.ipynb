# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# GPU Acceleration Settings (CUDA + Apple Metal Support)
# ============================================================
import tensorflow as tf
import platform

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        # Detect GPU type
        if platform.system() == 'Darwin' and platform.processor() == 'arm':
            print(f"Apple Metal GPU Enabled: Found {len(physical_devices)} GPU(s) via tensorflow-metal")
            print(f"  Chipset: Apple {platform.machine()} (M-series)")
        else:
            print(f"CUDA GPU Enabled: Found {len(physical_devices)} GPU(s) - Memory Growth Set")
        for d in physical_devices:
            print(f"  Device: {d.name}")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    if platform.system() == 'Darwin' and platform.processor() == 'arm':
        print("Apple Silicon detected but no GPU found.")
        print("  Install tensorflow-metal: pip install tensorflow-metal")
    else:
        print("No GPU found. Falling back to CPU.")
        print("  For CUDA: ensure NVIDIA drivers + CUDA toolkit are installed.")

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fuzzy_output_layer              │ (1, 1)                 │            12 │
# │ (FuzzyOutputLayer)              │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332 (1.30 KB)
#  Trainable params: 332 (1.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 2)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (230, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (230, 1, 1), y_train shape: (230,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    # Set consumption gate (c) bias to 1.0 (unit forget bias)
    rnn_layer = model.layers[1]
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, bias[units:2*units]
    weights[2] = bias
    cell.set_weights(weights)

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3798.8655, Expected=3796.0000
# Month=2, Predicted=3796.1211, Expected=3793.0000
# Month=3, Predicted=3793.2792, Expected=3766.0000
# Month=4, Predicted=3765.8165, Expected=3747.0000
# Month=5, Predicted=3747.0837, Expected=3754.0000
# Month=6, Predicted=3754.4998, Expected=3756.0000
# Month=7, Predicted=3756.3502, Expected=3767.0000
# Month=8, Predicted=3767.5121, Expected=3751.0000
# Month=9, Predicted=3750.9772, Expected=3769.0000
# Month=10, Predicted=3769.6589, Expected=3760.0000
# Month=11, Predicted=3760.1025, Expected=3785.0000
# Month=12, Predicted=3785.7783, Expected=3776.0000
# Month=13, Predicted=3776.0739, Expected=3755.0000
# Month=14, Predicted=3754.9437, Expected=3755.0000
# Month=15, Predicted=3755.3803, Expected=3751.0000
# Month=16, Predicted=3751.2524, Expected=3776.0000
# Month=17, Predicted=3776.7386, Expected=3847.0000
# Month=18, Predicted=3848.3910, Expected=3830.0000
# Month=19, Predicted=3829.5967, Expected=3881.0000
# Month=20, Predicted=3882.3100, Expected=3899.0000
# Month=21, Predicted=3899.4611, Expected=3917.0000
# Month=22, Predicted=3917.5755, Expected=3913.0000
# Month=23, Predicted=3913.1365, Expected=3901.0000
# Month=24, Predicted=3901.1254, Expected=3886.0000
# Month=25, Predicted=3886.1455, Expected=3892.5000
# Month=26, Predicted=3893.0830, Expected=3899.0000
# Month=27, Predicted=3899.5005, Expected=3886.0000
# Month=28, Predicted=3886.0906, Expected=3908.0000
# Month=29, Predicted=3908.7844, Expected=3875.0000
# Month=30, Predicted=3874.5972, Expected=3860.0000
# Month=31, Predicted=3860.1340, Expected=3880.0000
# Month=32, Predicted=3880.6463, Expected=3895.0000
# Month=33, Predicted=3895.5386, Expected=3954.0000
# Month=34, Predicted=3955.2487, Expected=3933.0000
# Month=35, Predicted=3932.5953, Expected=3937.0000
# Month=36, Predicted=3937.4815, Expected=3869.0000
# Month=37, Predicted=3867.8758, Expected=3852.0000
# Month=38, Predicted=3852.1035, Expected=3837.0000
# Month=39, Predicted=3836.9976, Expected=3832.0000
# Month=40, Predicted=3832.1064, Expected=3849.0000
# Month=41, Predicted=3849.4176, Expected=3863.0000
# Month=42, Predicted=3863.4293, Expected=3878.0000
# Month=43, Predicted=3878.4962, Expected=3855.0000
# Month=44, Predicted=3854.7801, Expected=3843.0000
# Month=45, Predicted=3843.1283, Expected=3847.0000
# Month=46, Predicted=3847.3831, Expected=3801.0000
# Month=47, Predicted=3800.3649, Expected=3787.0000
# Month=48, Predicted=3787.0315, Expected=3776.0000
# Month=49, Predicted=3776.0082, Expected=3797.0000
# Month=50, Predicted=3797.4429, Expected=3821.0000
# Month=51, Predicted=3821.5737, Expected=3877.0000
# Month=52, Predicted=3878.1161, Expected=3875.0000
# Month=53, Predicted=3875.0038, Expected=3890.0000
# Month=54, Predicted=3890.6014, Expected=3910.0000
# Month=55, Predicted=3910.6805, Expected=3924.0000
# Month=56, Predicted=3924.5401, Expected=3918.0000
# Month=57, Predicted=3918.1522, Expected=3936.0000
# Month=58, Predicted=3936.7549, Expected=3911.0000
# Month=59, Predicted=3910.7689, Expected=3891.0000
# Month=60, Predicted=3891.0699, Expected=3855.0000
# Run 1 — RMSE: 24.458822, MSE: 598.233998, NMSE: 0.0027359380
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3798.6601, Expected=3796.0000
# Month=2, Predicted=3796.4085, Expected=3793.0000
# Month=3, Predicted=3793.6239, Expected=3766.0000
# Month=4, Predicted=3765.8259, Expected=3747.0000
# Month=5, Predicted=3747.0519, Expected=3754.0000
# Month=6, Predicted=3754.4068, Expected=3756.0000
# Month=7, Predicted=3756.1075, Expected=3767.0000
# Month=8, Predicted=3767.4403, Expected=3751.0000
# Month=9, Predicted=3750.8866, Expected=3769.0000
# Month=10, Predicted=3769.7955, Expected=3760.0000
# Month=11, Predicted=3760.0070, Expected=3785.0000
# Month=12, Predicted=3785.8315, Expected=3776.0000
# Month=13, Predicted=3776.0404, Expected=3755.0000
# Month=14, Predicted=3754.9818, Expected=3755.0000
# Month=15, Predicted=3755.4736, Expected=3751.0000
# Month=16, Predicted=3751.1147, Expected=3776.0000
# Month=17, Predicted=3776.6332, Expected=3847.0000
# Month=18, Predicted=3847.2961, Expected=3830.0000
# Month=19, Predicted=3829.9298, Expected=3881.0000
# Month=20, Predicted=3882.4199, Expected=3899.0000
# Month=21, Predicted=3899.7607, Expected=3917.0000
# Month=22, Predicted=3917.9478, Expected=3913.0000
# Month=23, Predicted=3913.4968, Expected=3901.0000
# Month=24, Predicted=3901.3363, Expected=3886.0000
# Month=25, Predicted=3886.1482, Expected=3892.5000
# Month=26, Predicted=3893.0024, Expected=3899.0000
# Month=27, Predicted=3899.3092, Expected=3886.0000
# Month=28, Predicted=3885.9745, Expected=3908.0000
# Month=29, Predicted=3908.7880, Expected=3875.0000
# Month=30, Predicted=3874.3227, Expected=3860.0000
# Month=31, Predicted=3860.2253, Expected=3880.0000
# Month=32, Predicted=3880.5888, Expected=3895.0000
# Month=33, Predicted=3895.3059, Expected=3954.0000
# Month=34, Predicted=3954.6226, Expected=3933.0000
# Month=35, Predicted=3932.8116, Expected=3937.0000
# Month=36, Predicted=3937.9602, Expected=3869.0000
# Month=37, Predicted=3867.3125, Expected=3852.0000
# Month=38, Predicted=3852.3270, Expected=3837.0000
# Month=39, Predicted=3836.6455, Expected=3832.0000
# Month=40, Predicted=3831.8730, Expected=3849.0000
# Month=41, Predicted=3849.3016, Expected=3863.0000
# Month=42, Predicted=3863.3009, Expected=3878.0000
# Month=43, Predicted=3878.5643, Expected=3855.0000
# Month=44, Predicted=3854.8010, Expected=3843.0000
# Month=45, Predicted=3843.3241, Expected=3847.0000
# Month=46, Predicted=3847.4189, Expected=3801.0000
# Month=47, Predicted=3799.8505, Expected=3787.0000
# Month=48, Predicted=3787.1635, Expected=3776.0000
# Month=49, Predicted=3775.7974, Expected=3797.0000
# Month=50, Predicted=3797.3889, Expected=3821.0000
# Month=51, Predicted=3821.3546, Expected=3877.0000
# Month=52, Predicted=3877.6280, Expected=3875.0000
# Month=53, Predicted=3875.3509, Expected=3890.0000
# Month=54, Predicted=3891.0752, Expected=3910.0000
# Month=55, Predicted=3910.8641, Expected=3924.0000
# Month=56, Predicted=3924.7156, Expected=3918.0000
# Month=57, Predicted=3918.3731, Expected=3936.0000
# Month=58, Predicted=3936.8734, Expected=3911.0000
# Month=59, Predicted=3910.7192, Expected=3891.0000
# Month=60, Predicted=3891.0850, Expected=3855.0000
# Run 2 — RMSE: 24.471779, MSE: 598.867949, NMSE: 0.0027348346
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3799.8200, Expected=3796.0000
# Month=2, Predicted=3796.8557, Expected=3793.0000
# Month=3, Predicted=3793.2441, Expected=3766.0000
# Month=4, Predicted=3765.3826, Expected=3747.0000
# Month=5, Predicted=3746.1525, Expected=3754.0000
# Month=6, Predicted=3754.0465, Expected=3756.0000
# Month=7, Predicted=3756.6884, Expected=3767.0000
# Month=8, Predicted=3768.1093, Expected=3751.0000
# Month=9, Predicted=3751.4039, Expected=3769.0000
# Month=10, Predicted=3769.8765, Expected=3760.0000
# Month=11, Predicted=3760.4895, Expected=3785.0000
# Month=12, Predicted=3786.0403, Expected=3776.0000
# Month=13, Predicted=3776.4967, Expected=3755.0000
# Month=14, Predicted=3754.6936, Expected=3755.0000
# Month=15, Predicted=3754.9735, Expected=3751.0000
# Month=16, Predicted=3751.2501, Expected=3776.0000
# Month=17, Predicted=3777.1355, Expected=3847.0000
# Month=18, Predicted=3849.1495, Expected=3830.0000
# Month=19, Predicted=3830.8506, Expected=3881.0000
# Month=20, Predicted=3882.3698, Expected=3899.0000
# Month=21, Predicted=3900.2546, Expected=3917.0000
# Month=22, Predicted=3917.9130, Expected=3913.0000
# Month=23, Predicted=3913.2057, Expected=3901.0000
# Month=24, Predicted=3900.7029, Expected=3886.0000
# Month=25, Predicted=3885.4608, Expected=3892.5000
# Month=26, Predicted=3892.6038, Expected=3899.0000
# Month=27, Predicted=3899.7250, Expected=3886.0000
# Month=28, Predicted=3886.3607, Expected=3908.0000
# Month=29, Predicted=3909.0300, Expected=3875.0000
# Month=30, Predicted=3874.8422, Expected=3860.0000
# Month=31, Predicted=3859.5568, Expected=3880.0000
# Month=32, Predicted=3880.6923, Expected=3895.0000
# Month=33, Predicted=3896.3071, Expected=3954.0000
# Month=34, Predicted=3955.9703, Expected=3933.0000
# Month=35, Predicted=3933.5463, Expected=3937.0000
# Month=36, Predicted=3937.2840, Expected=3869.0000
# Month=37, Predicted=3867.6673, Expected=3852.0000
# Month=38, Predicted=3850.3544, Expected=3837.0000
# Month=39, Predicted=3836.3032, Expected=3832.0000
# Month=40, Predicted=3832.1324, Expected=3849.0000
# Month=41, Predicted=3850.2899, Expected=3863.0000
# Month=42, Predicted=3864.6436, Expected=3878.0000
# Month=43, Predicted=3879.4609, Expected=3855.0000
# Month=44, Predicted=3855.0504, Expected=3843.0000
# Month=45, Predicted=3842.7129, Expected=3847.0000
# Month=46, Predicted=3847.1654, Expected=3801.0000
# Month=47, Predicted=3800.0671, Expected=3787.0000
# Month=48, Predicted=3786.0740, Expected=3776.0000
# Month=49, Predicted=3775.7948, Expected=3797.0000
# Month=50, Predicted=3798.0938, Expected=3821.0000
# Month=51, Predicted=3822.8274, Expected=3877.0000
# Month=52, Predicted=3879.1915, Expected=3875.0000
# Month=53, Predicted=3876.1456, Expected=3890.0000
# Month=54, Predicted=3890.7598, Expected=3910.0000
# Month=55, Predicted=3910.8641, Expected=3924.0000
# Month=56, Predicted=3924.7631, Expected=3918.0000
# Month=57, Predicted=3918.1542, Expected=3936.0000
# Month=58, Predicted=3936.5842, Expected=3911.0000
# Month=59, Predicted=3910.7072, Expected=3891.0000
# Month=60, Predicted=3890.3172, Expected=3855.0000
# Run 3 — RMSE: 24.258688, MSE: 588.483966, NMSE: 0.0026852939
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3800.0345, Expected=3796.0000
# Month=2, Predicted=3796.2616, Expected=3793.0000
# Month=3, Predicted=3794.2874, Expected=3766.0000
# Month=4, Predicted=3764.2926, Expected=3747.0000
# Month=5, Predicted=3746.9775, Expected=3754.0000
# Month=6, Predicted=3754.8105, Expected=3756.0000
# Month=7, Predicted=3757.4016, Expected=3767.0000
# Month=8, Predicted=3768.9844, Expected=3751.0000
# Month=9, Predicted=3750.2905, Expected=3769.0000
# Month=10, Predicted=3769.9343, Expected=3760.0000
# Month=11, Predicted=3759.7844, Expected=3785.0000
# Month=12, Predicted=3785.6887, Expected=3776.0000
# Month=13, Predicted=3775.4685, Expected=3755.0000
# Month=14, Predicted=3754.7045, Expected=3755.0000
# Month=15, Predicted=3756.0885, Expected=3751.0000
# Month=16, Predicted=3751.8912, Expected=3776.0000
# Month=17, Predicted=3776.7267, Expected=3847.0000
# Month=18, Predicted=3843.4709, Expected=3830.0000
# Month=19, Predicted=3825.9745, Expected=3881.0000
# Month=20, Predicted=3878.6352, Expected=3899.0000
# Month=21, Predicted=3901.0291, Expected=3917.0000
# Month=22, Predicted=3919.3065, Expected=3913.0000
# Month=23, Predicted=3913.2321, Expected=3901.0000
# Month=24, Predicted=3901.1076, Expected=3886.0000
# Month=25, Predicted=3885.9207, Expected=3892.5000
# Month=26, Predicted=3893.5518, Expected=3899.0000
# Month=27, Predicted=3900.5600, Expected=3886.0000
# Month=28, Predicted=3885.9416, Expected=3908.0000
# Month=29, Predicted=3908.6703, Expected=3875.0000
# Month=30, Predicted=3871.1773, Expected=3860.0000
# Month=31, Predicted=3860.8035, Expected=3880.0000
# Month=32, Predicted=3880.1743, Expected=3895.0000
# Month=33, Predicted=3896.9819, Expected=3954.0000
# Month=34, Predicted=3951.8952, Expected=3933.0000
# Month=35, Predicted=3928.9337, Expected=3937.0000
# Month=36, Predicted=3938.7878, Expected=3869.0000
# Month=37, Predicted=3864.8211, Expected=3852.0000
# Month=38, Predicted=3851.9479, Expected=3837.0000
# Month=39, Predicted=3836.8004, Expected=3832.0000
# Month=40, Predicted=3833.1313, Expected=3849.0000
# Month=41, Predicted=3850.2826, Expected=3863.0000
# Month=42, Predicted=3865.2316, Expected=3878.0000
# Month=43, Predicted=3880.3623, Expected=3855.0000
# Month=44, Predicted=3853.0394, Expected=3843.0000
# Month=45, Predicted=3843.7791, Expected=3847.0000
# Month=46, Predicted=3848.1019, Expected=3801.0000
# Month=47, Predicted=3797.0801, Expected=3787.0000
# Month=48, Predicted=3787.6399, Expected=3776.0000
# Month=49, Predicted=3776.4203, Expected=3797.0000
# Month=50, Predicted=3797.5240, Expected=3821.0000
# Month=51, Predicted=3823.0222, Expected=3877.0000
# Month=52, Predicted=3876.0787, Expected=3875.0000
# Month=53, Predicted=3874.3268, Expected=3890.0000
# Month=54, Predicted=3892.1225, Expected=3910.0000
# Month=55, Predicted=3911.7501, Expected=3924.0000
# Month=56, Predicted=3925.8584, Expected=3918.0000
# Month=57, Predicted=3918.2179, Expected=3936.0000
# Month=58, Predicted=3937.2402, Expected=3911.0000
# Month=59, Predicted=3908.2634, Expected=3891.0000
# Month=60, Predicted=3891.1132, Expected=3855.0000
# Run 4 — RMSE: 24.380662, MSE: 594.416696, NMSE: 0.0027297467
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3799.1771, Expected=3796.0000
# Month=2, Predicted=3796.3236, Expected=3793.0000
# Month=3, Predicted=3792.9609, Expected=3766.0000
# Month=4, Predicted=3765.3869, Expected=3747.0000
# Month=5, Predicted=3746.4451, Expected=3754.0000
# Month=6, Predicted=3754.2735, Expected=3756.0000
# Month=7, Predicted=3756.6054, Expected=3767.0000
# Month=8, Predicted=3767.7838, Expected=3751.0000
# Month=9, Predicted=3751.1036, Expected=3769.0000
# Month=10, Predicted=3769.5313, Expected=3760.0000
# Month=11, Predicted=3760.1699, Expected=3785.0000
# Month=12, Predicted=3785.6896, Expected=3776.0000
# Month=13, Predicted=3776.1939, Expected=3755.0000
# Month=14, Predicted=3754.6655, Expected=3755.0000
# Month=15, Predicted=3755.0102, Expected=3751.0000
# Month=16, Predicted=3751.1984, Expected=3776.0000
# Month=17, Predicted=3776.8934, Expected=3847.0000
# Month=18, Predicted=3848.5931, Expected=3830.0000
# Month=19, Predicted=3830.1364, Expected=3881.0000
# Month=20, Predicted=3881.6773, Expected=3899.0000
# Month=21, Predicted=3899.4966, Expected=3917.0000
# Month=22, Predicted=3917.3709, Expected=3913.0000
# Month=23, Predicted=3912.9410, Expected=3901.0000
# Month=24, Predicted=3900.6743, Expected=3886.0000
# Month=25, Predicted=3885.6294, Expected=3892.5000
# Month=26, Predicted=3892.7541, Expected=3899.0000
# Month=27, Predicted=3899.6096, Expected=3886.0000
# Month=28, Predicted=3886.1830, Expected=3908.0000
# Month=29, Predicted=3908.7205, Expected=3875.0000
# Month=30, Predicted=3874.6736, Expected=3860.0000
# Month=31, Predicted=3859.6457, Expected=3880.0000
# Month=32, Predicted=3880.5724, Expected=3895.0000
# Month=33, Predicted=3895.9052, Expected=3954.0000
# Month=34, Predicted=3955.4474, Expected=3933.0000
# Month=35, Predicted=3933.0081, Expected=3937.0000
# Month=36, Predicted=3936.9415, Expected=3869.0000
# Month=37, Predicted=3867.4447, Expected=3852.0000
# Month=38, Predicted=3851.0376, Expected=3837.0000
# Month=39, Predicted=3836.7418, Expected=3832.0000
# Month=40, Predicted=3832.4033, Expected=3849.0000
# Month=41, Predicted=3850.0675, Expected=3863.0000
# Month=42, Predicted=3864.0086, Expected=3878.0000
# Month=43, Predicted=3878.7609, Expected=3855.0000
# Month=44, Predicted=3854.7659, Expected=3843.0000
# Month=45, Predicted=3842.6491, Expected=3847.0000
# Month=46, Predicted=3847.1182, Expected=3801.0000
# Month=47, Predicted=3800.2034, Expected=3787.0000
# Month=48, Predicted=3786.5878, Expected=3776.0000
# Month=49, Predicted=3776.0242, Expected=3797.0000
# Month=50, Predicted=3797.9578, Expected=3821.0000
# Month=51, Predicted=3822.2259, Expected=3877.0000
# Month=52, Predicted=3878.4090, Expected=3875.0000
# Month=53, Predicted=3875.3357, Expected=3890.0000
# Month=54, Predicted=3890.2121, Expected=3910.0000
# Month=55, Predicted=3910.3752, Expected=3924.0000
# Month=56, Predicted=3924.3937, Expected=3918.0000
# Month=57, Predicted=3918.0036, Expected=3936.0000
# Month=58, Predicted=3936.4051, Expected=3911.0000
# Month=59, Predicted=3910.6885, Expected=3891.0000
# Month=60, Predicted=3890.5329, Expected=3855.0000
# Run 5 — RMSE: 24.313743, MSE: 591.158094, NMSE: 0.0027057673
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3798.7577, Expected=3796.0000
# Month=2, Predicted=3796.3133, Expected=3793.0000
# Month=3, Predicted=3793.2499, Expected=3766.0000
# Month=4, Predicted=3765.9287, Expected=3747.0000
# Month=5, Predicted=3746.9232, Expected=3754.0000
# Month=6, Predicted=3754.2675, Expected=3756.0000
# Month=7, Predicted=3756.2318, Expected=3767.0000
# Month=8, Predicted=3767.3800, Expected=3751.0000
# Month=9, Predicted=3751.0473, Expected=3769.0000
# Month=10, Predicted=3769.4684, Expected=3760.0000
# Month=11, Predicted=3760.1380, Expected=3785.0000
# Month=12, Predicted=3785.5843, Expected=3776.0000
# Month=13, Predicted=3776.1620, Expected=3755.0000
# Month=14, Predicted=3754.9727, Expected=3755.0000
# Month=15, Predicted=3755.1938, Expected=3751.0000
# Month=16, Predicted=3751.1551, Expected=3776.0000
# Month=17, Predicted=3776.5689, Expected=3847.0000
# Month=18, Predicted=3848.1979, Expected=3830.0000
# Month=19, Predicted=3830.1519, Expected=3881.0000
# Month=20, Predicted=3881.9365, Expected=3899.0000
# Month=21, Predicted=3899.5806, Expected=3917.0000
# Month=22, Predicted=3917.5791, Expected=3913.0000
# Month=23, Predicted=3913.2758, Expected=3901.0000
# Month=24, Predicted=3901.1170, Expected=3886.0000
# Month=25, Predicted=3886.0229, Expected=3892.5000
# Month=26, Predicted=3892.7831, Expected=3899.0000
# Month=27, Predicted=3899.3089, Expected=3886.0000
# Month=28, Predicted=3886.0676, Expected=3908.0000
# Month=29, Predicted=3908.5219, Expected=3875.0000
# Month=30, Predicted=3874.8725, Expected=3860.0000
# Month=31, Predicted=3859.9675, Expected=3880.0000
# Month=32, Predicted=3880.4575, Expected=3895.0000
# Month=33, Predicted=3895.4410, Expected=3954.0000
# Month=34, Predicted=3955.0371, Expected=3933.0000
# Month=35, Predicted=3933.0948, Expected=3937.0000
# Month=36, Predicted=3937.2968, Expected=3869.0000
# Month=37, Predicted=3868.8326, Expected=3852.0000
# Month=38, Predicted=3851.8963, Expected=3837.0000
# Month=39, Predicted=3836.9111, Expected=3832.0000
# Month=40, Predicted=3832.0722, Expected=3849.0000
# Month=41, Predicted=3849.4180, Expected=3863.0000
# Month=42, Predicted=3863.4358, Expected=3878.0000
# Month=43, Predicted=3878.4863, Expected=3855.0000
# Month=44, Predicted=3855.0124, Expected=3843.0000
# Month=45, Predicted=3843.0524, Expected=3847.0000
# Month=46, Predicted=3847.2564, Expected=3801.0000
# Month=47, Predicted=3800.7127, Expected=3787.0000
# Month=48, Predicted=3786.9443, Expected=3776.0000
# Month=49, Predicted=3775.9971, Expected=3797.0000
# Month=50, Predicted=3797.4698, Expected=3821.0000
# Month=51, Predicted=3821.5771, Expected=3877.0000
# Month=52, Predicted=3878.0117, Expected=3875.0000
# Month=53, Predicted=3875.3349, Expected=3890.0000
# Month=54, Predicted=3890.5124, Expected=3910.0000
# Month=55, Predicted=3910.5859, Expected=3924.0000
# Month=56, Predicted=3924.5110, Expected=3918.0000
# Month=57, Predicted=3918.2348, Expected=3936.0000
# Month=58, Predicted=3936.5091, Expected=3911.0000
# Month=59, Predicted=3910.9829, Expected=3891.0000
# Month=60, Predicted=3890.9294, Expected=3855.0000
# Run 6 — RMSE: 24.442135, MSE: 597.417978, NMSE: 0.0027313919
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3798.6953, Expected=3796.0000
# Month=2, Predicted=3795.8318, Expected=3793.0000
# Month=3, Predicted=3792.9784, Expected=3766.0000
# Month=4, Predicted=3765.4715, Expected=3747.0000
# Month=5, Predicted=3746.8484, Expected=3754.0000
# Month=6, Predicted=3754.5155, Expected=3756.0000
# Month=7, Predicted=3756.3025, Expected=3767.0000
# Month=8, Predicted=3767.4950, Expected=3751.0000
# Month=9, Predicted=3750.7803, Expected=3769.0000
# Month=10, Predicted=3769.6851, Expected=3760.0000
# Month=11, Predicted=3759.9078, Expected=3785.0000
# Month=12, Predicted=3785.7619, Expected=3776.0000
# Month=13, Predicted=3775.8301, Expected=3755.0000
# Month=14, Predicted=3754.6895, Expected=3755.0000
# Month=15, Predicted=3755.3101, Expected=3751.0000
# Month=16, Predicted=3751.1588, Expected=3776.0000
# Month=17, Predicted=3776.8002, Expected=3847.0000
# Month=18, Predicted=3848.2037, Expected=3830.0000
# Month=19, Predicted=3829.2508, Expected=3881.0000
# Month=20, Predicted=3882.0601, Expected=3899.0000
# Month=21, Predicted=3899.1456, Expected=3917.0000
# Month=22, Predicted=3917.2525, Expected=3913.0000
# Month=23, Predicted=3912.7756, Expected=3901.0000
# Month=24, Predicted=3900.7444, Expected=3886.0000
# Month=25, Predicted=3885.8051, Expected=3892.5000
# Month=26, Predicted=3892.9048, Expected=3899.0000
# Month=27, Predicted=3899.3487, Expected=3886.0000
# Month=28, Predicted=3885.8721, Expected=3908.0000
# Month=29, Predicted=3908.7592, Expected=3875.0000
# Month=30, Predicted=3874.3097, Expected=3860.0000
# Month=31, Predicted=3860.0109, Expected=3880.0000
# Month=32, Predicted=3880.7982, Expected=3895.0000
# Month=33, Predicted=3895.5025, Expected=3954.0000
# Month=34, Predicted=3955.1448, Expected=3933.0000
# Month=35, Predicted=3932.2452, Expected=3937.0000
# Month=36, Predicted=3937.2486, Expected=3869.0000
# Month=37, Predicted=3867.6050, Expected=3852.0000
# Month=38, Predicted=3852.1070, Expected=3837.0000
# Month=39, Predicted=3837.0584, Expected=3832.0000
# Month=40, Predicted=3832.3048, Expected=3849.0000
# Month=41, Predicted=3849.7529, Expected=3863.0000
# Month=42, Predicted=3863.5238, Expected=3878.0000
# Month=43, Predicted=3878.4749, Expected=3855.0000
# Month=44, Predicted=3854.5185, Expected=3843.0000
# Month=45, Predicted=3842.9868, Expected=3847.0000
# Month=46, Predicted=3847.3793, Expected=3801.0000
# Month=47, Predicted=3800.1396, Expected=3787.0000
# Month=48, Predicted=3787.1620, Expected=3776.0000
# Month=49, Predicted=3776.1690, Expected=3797.0000
# Month=50, Predicted=3797.8671, Expected=3821.0000
# Month=51, Predicted=3821.7178, Expected=3877.0000
# Month=52, Predicted=3878.0802, Expected=3875.0000
# Month=53, Predicted=3874.7006, Expected=3890.0000
# Month=54, Predicted=3890.3528, Expected=3910.0000
# Month=55, Predicted=3910.3901, Expected=3924.0000
# Month=56, Predicted=3924.2219, Expected=3918.0000
# Month=57, Predicted=3917.8055, Expected=3936.0000
# Month=58, Predicted=3936.4775, Expected=3911.0000
# Month=59, Predicted=3910.4235, Expected=3891.0000
# Month=60, Predicted=3890.7889, Expected=3855.0000
# Run 7 — RMSE: 24.418671, MSE: 596.271484, NMSE: 0.0027322709
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3798.2557, Expected=3796.0000
# Month=2, Predicted=3795.8445, Expected=3793.0000
# Month=3, Predicted=3793.1450, Expected=3766.0000
# Month=4, Predicted=3765.5164, Expected=3747.0000
# Month=5, Predicted=3746.7605, Expected=3754.0000
# Month=6, Predicted=3754.5813, Expected=3756.0000
# Month=7, Predicted=3756.2788, Expected=3767.0000
# Month=8, Predicted=3767.4699, Expected=3751.0000
# Month=9, Predicted=3750.7427, Expected=3769.0000
# Month=10, Predicted=3769.7407, Expected=3760.0000
# Month=11, Predicted=3759.8915, Expected=3785.0000
# Month=12, Predicted=3785.7471, Expected=3776.0000
# Month=13, Predicted=3775.8381, Expected=3755.0000
# Month=14, Predicted=3754.7046, Expected=3755.0000
# Month=15, Predicted=3755.3886, Expected=3751.0000
# Month=16, Predicted=3751.1508, Expected=3776.0000
# Month=17, Predicted=3776.7365, Expected=3847.0000
# Month=18, Predicted=3846.9273, Expected=3830.0000
# Month=19, Predicted=3829.3848, Expected=3881.0000
# Month=20, Predicted=3881.6714, Expected=3899.0000
# Month=21, Predicted=3899.0611, Expected=3917.0000
# Month=22, Predicted=3917.3165, Expected=3913.0000
# Month=23, Predicted=3912.9707, Expected=3901.0000
# Month=24, Predicted=3900.9394, Expected=3886.0000
# Month=25, Predicted=3885.8735, Expected=3892.5000
# Month=26, Predicted=3893.0258, Expected=3899.0000
# Month=27, Predicted=3899.3609, Expected=3886.0000
# Month=28, Predicted=3885.8467, Expected=3908.0000
# Month=29, Predicted=3908.7683, Expected=3875.0000
# Month=30, Predicted=3874.3714, Expected=3860.0000
# Month=31, Predicted=3859.9487, Expected=3880.0000
# Month=32, Predicted=3880.8430, Expected=3895.0000
# Month=33, Predicted=3895.4227, Expected=3954.0000
# Month=34, Predicted=3954.2402, Expected=3933.0000
# Month=35, Predicted=3932.3962, Expected=3937.0000
# Month=36, Predicted=3937.5111, Expected=3869.0000
# Month=37, Predicted=3868.7082, Expected=3852.0000
# Month=38, Predicted=3851.7031, Expected=3837.0000
# Month=39, Predicted=3836.8117, Expected=3832.0000
# Month=40, Predicted=3832.2469, Expected=3849.0000
# Month=41, Predicted=3849.7388, Expected=3863.0000
# Month=42, Predicted=3863.4119, Expected=3878.0000
# Month=43, Predicted=3878.3698, Expected=3855.0000
# Month=44, Predicted=3854.5614, Expected=3843.0000
# Month=45, Predicted=3843.0311, Expected=3847.0000
# Month=46, Predicted=3847.4466, Expected=3801.0000
# Month=47, Predicted=3800.2282, Expected=3787.0000
# Month=48, Predicted=3786.9286, Expected=3776.0000
# Month=49, Predicted=3775.9864, Expected=3797.0000
# Month=50, Predicted=3797.8550, Expected=3821.0000
# Month=51, Predicted=3821.5029, Expected=3877.0000
# Month=52, Predicted=3877.1406, Expected=3875.0000
# Month=53, Predicted=3874.6787, Expected=3890.0000
# Month=54, Predicted=3890.4750, Expected=3910.0000
# Month=55, Predicted=3910.3893, Expected=3924.0000
# Month=56, Predicted=3924.2725, Expected=3918.0000
# Month=57, Predicted=3917.9560, Expected=3936.0000
# Month=58, Predicted=3936.6111, Expected=3911.0000
# Month=59, Predicted=3910.5107, Expected=3891.0000
# Month=60, Predicted=3890.7562, Expected=3855.0000
# Run 8 — RMSE: 24.435894, MSE: 597.112920, NMSE: 0.0027356867
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3799.3568, Expected=3796.0000
# Month=2, Predicted=3796.6065, Expected=3793.0000
# Month=3, Predicted=3793.2814, Expected=3766.0000
# Month=4, Predicted=3765.7024, Expected=3747.0000
# Month=5, Predicted=3746.5669, Expected=3754.0000
# Month=6, Predicted=3754.0972, Expected=3756.0000
# Month=7, Predicted=3756.2584, Expected=3767.0000
# Month=8, Predicted=3767.4666, Expected=3751.0000
# Month=9, Predicted=3750.9748, Expected=3769.0000
# Month=10, Predicted=3769.4680, Expected=3760.0000
# Month=11, Predicted=3760.1855, Expected=3785.0000
# Month=12, Predicted=3785.7284, Expected=3776.0000
# Month=13, Predicted=3776.2850, Expected=3755.0000
# Month=14, Predicted=3754.7584, Expected=3755.0000
# Month=15, Predicted=3755.0003, Expected=3751.0000
# Month=16, Predicted=3751.0855, Expected=3776.0000
# Month=17, Predicted=3776.7235, Expected=3847.0000
# Month=18, Predicted=3849.0068, Expected=3830.0000
# Month=19, Predicted=3830.5341, Expected=3881.0000
# Month=20, Predicted=3882.3105, Expected=3899.0000
# Month=21, Predicted=3900.1839, Expected=3917.0000
# Month=22, Predicted=3917.9680, Expected=3913.0000
# Month=23, Predicted=3913.4545, Expected=3901.0000
# Month=24, Predicted=3901.0647, Expected=3886.0000
# Month=25, Predicted=3885.8529, Expected=3892.5000
# Month=26, Predicted=3892.7227, Expected=3899.0000
# Month=27, Predicted=3899.4213, Expected=3886.0000
# Month=28, Predicted=3886.0172, Expected=3908.0000
# Month=29, Predicted=3908.5921, Expected=3875.0000
# Month=30, Predicted=3874.7120, Expected=3860.0000
# Month=31, Predicted=3859.5796, Expected=3880.0000
# Month=32, Predicted=3880.4009, Expected=3895.0000
# Month=33, Predicted=3895.7026, Expected=3954.0000
# Month=34, Predicted=3955.6879, Expected=3933.0000
# Month=35, Predicted=3933.3416, Expected=3937.0000
# Month=36, Predicted=3937.2598, Expected=3869.0000
# Month=37, Predicted=3867.9975, Expected=3852.0000
# Month=38, Predicted=3851.0706, Expected=3837.0000
# Month=39, Predicted=3836.4102, Expected=3832.0000
# Month=40, Predicted=3831.6835, Expected=3849.0000
# Month=41, Predicted=3849.3229, Expected=3863.0000
# Month=42, Predicted=3863.5816, Expected=3878.0000
# Month=43, Predicted=3878.6779, Expected=3855.0000
# Month=44, Predicted=3854.8981, Expected=3843.0000
# Month=45, Predicted=3842.7669, Expected=3847.0000
# Month=46, Predicted=3847.1373, Expected=3801.0000
# Month=47, Predicted=3800.2661, Expected=3787.0000
# Month=48, Predicted=3786.3347, Expected=3776.0000
# Month=49, Predicted=3775.5921, Expected=3797.0000
# Month=50, Predicted=3797.3742, Expected=3821.0000
# Month=51, Predicted=3821.8617, Expected=3877.0000
# Month=52, Predicted=3878.6894, Expected=3875.0000
# Month=53, Predicted=3875.7545, Expected=3890.0000
# Month=54, Predicted=3890.6946, Expected=3910.0000
# Month=55, Predicted=3910.9170, Expected=3924.0000
# Month=56, Predicted=3924.8556, Expected=3918.0000
# Month=57, Predicted=3918.3617, Expected=3936.0000
# Month=58, Predicted=3936.6821, Expected=3911.0000
# Month=59, Predicted=3910.9245, Expected=3891.0000
# Month=60, Predicted=3890.6225, Expected=3855.0000
# Run 9 — RMSE: 24.393314, MSE: 595.033776, NMSE: 0.0027110970
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3798.4367, Expected=3796.0000
# Month=2, Predicted=3795.2384, Expected=3793.0000
# Month=3, Predicted=3792.7583, Expected=3766.0000
# Month=4, Predicted=3765.8385, Expected=3747.0000
# Month=5, Predicted=3747.4690, Expected=3754.0000
# Month=6, Predicted=3755.3405, Expected=3756.0000
# Month=7, Predicted=3756.7856, Expected=3767.0000
# Month=8, Predicted=3767.4746, Expected=3751.0000
# Month=9, Predicted=3750.7851, Expected=3769.0000
# Month=10, Predicted=3769.7150, Expected=3760.0000
# Month=11, Predicted=3760.2559, Expected=3785.0000
# Month=12, Predicted=3785.6426, Expected=3776.0000
# Month=13, Predicted=3775.9612, Expected=3755.0000
# Month=14, Predicted=3754.6324, Expected=3755.0000
# Month=15, Predicted=3755.8139, Expected=3751.0000
# Month=16, Predicted=3751.8057, Expected=3776.0000
# Month=17, Predicted=3776.9153, Expected=3847.0000
# Month=18, Predicted=3847.9338, Expected=3830.0000
# Month=19, Predicted=3828.5675, Expected=3881.0000
# Month=20, Predicted=3881.0125, Expected=3899.0000
# Month=21, Predicted=3899.5360, Expected=3917.0000
# Month=22, Predicted=3916.7718, Expected=3913.0000
# Month=23, Predicted=3912.6488, Expected=3901.0000
# Month=24, Predicted=3900.9040, Expected=3886.0000
# Month=25, Predicted=3886.3382, Expected=3892.5000
# Month=26, Predicted=3893.5548, Expected=3899.0000
# Month=27, Predicted=3899.8138, Expected=3886.0000
# Month=28, Predicted=3885.8778, Expected=3908.0000
# Month=29, Predicted=3908.8220, Expected=3875.0000
# Month=30, Predicted=3874.3894, Expected=3860.0000
# Month=31, Predicted=3860.1527, Expected=3880.0000
# Month=32, Predicted=3881.5253, Expected=3895.0000
# Month=33, Predicted=3895.8724, Expected=3954.0000
# Month=34, Predicted=3954.6019, Expected=3933.0000
# Month=35, Predicted=3931.6769, Expected=3937.0000
# Month=36, Predicted=3936.8079, Expected=3869.0000
# Month=37, Predicted=3867.6346, Expected=3852.0000
# Month=38, Predicted=3852.7420, Expected=3837.0000
# Month=39, Predicted=3838.4985, Expected=3832.0000
# Month=40, Predicted=3832.9548, Expected=3849.0000
# Month=41, Predicted=3850.0237, Expected=3863.0000
# Month=42, Predicted=3863.5580, Expected=3878.0000
# Month=43, Predicted=3878.1971, Expected=3855.0000
# Month=44, Predicted=3854.3205, Expected=3843.0000
# Month=45, Predicted=3843.1880, Expected=3847.0000
# Month=46, Predicted=3848.1136, Expected=3801.0000
# Month=47, Predicted=3800.3515, Expected=3787.0000
# Month=48, Predicted=3787.5555, Expected=3776.0000
# Month=49, Predicted=3777.1935, Expected=3797.0000
# Month=50, Predicted=3798.2399, Expected=3821.0000
# Month=51, Predicted=3821.7559, Expected=3877.0000
# Month=52, Predicted=3877.4202, Expected=3875.0000
# Month=53, Predicted=3874.1224, Expected=3890.0000
# Month=54, Predicted=3889.7770, Expected=3910.0000
# Month=55, Predicted=3910.6574, Expected=3924.0000
# Month=56, Predicted=3924.2441, Expected=3918.0000
# Month=57, Predicted=3917.6774, Expected=3936.0000
# Month=58, Predicted=3936.5732, Expected=3911.0000
# Month=59, Predicted=3910.5955, Expected=3891.0000
# Month=60, Predicted=3890.9983, Expected=3855.0000
# Run 10 — RMSE: 24.394765, MSE: 595.104556, NMSE: 0.0027400928
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3800.0339, Expected=3796.0000
# Month=2, Predicted=3796.7494, Expected=3793.0000
# Month=3, Predicted=3793.2073, Expected=3766.0000
# Month=4, Predicted=3765.2116, Expected=3747.0000
# Month=5, Predicted=3746.1672, Expected=3754.0000
# Month=6, Predicted=3753.9825, Expected=3756.0000
# Month=7, Predicted=3756.2613, Expected=3767.0000
# Month=8, Predicted=3767.7447, Expected=3751.0000
# Month=9, Predicted=3750.8649, Expected=3769.0000
# Month=10, Predicted=3769.7888, Expected=3760.0000
# Month=11, Predicted=3760.0959, Expected=3785.0000
# Month=12, Predicted=3786.1049, Expected=3776.0000
# Month=13, Predicted=3776.1775, Expected=3755.0000
# Month=14, Predicted=3754.4497, Expected=3755.0000
# Month=15, Predicted=3754.8924, Expected=3751.0000
# Month=16, Predicted=3750.9528, Expected=3776.0000
# Month=17, Predicted=3777.0595, Expected=3847.0000
# Month=18, Predicted=3849.7575, Expected=3830.0000
# Month=19, Predicted=3830.4790, Expected=3881.0000
# Month=20, Predicted=3883.0783, Expected=3899.0000
# Month=21, Predicted=3900.5200, Expected=3917.0000
# Month=22, Predicted=3918.2313, Expected=3913.0000
# Month=23, Predicted=3913.2116, Expected=3901.0000
# Month=24, Predicted=3900.6165, Expected=3886.0000
# Month=25, Predicted=3885.3662, Expected=3892.5000
# Month=26, Predicted=3892.5230, Expected=3899.0000
# Month=27, Predicted=3899.3780, Expected=3886.0000
# Month=28, Predicted=3885.8249, Expected=3908.0000
# Month=29, Predicted=3908.8980, Expected=3875.0000
# Month=30, Predicted=3874.3078, Expected=3860.0000
# Month=31, Predicted=3859.3986, Expected=3880.0000
# Month=32, Predicted=3880.5954, Expected=3895.0000
# Month=33, Predicted=3896.0200, Expected=3954.0000
# Month=34, Predicted=3956.5237, Expected=3933.0000
# Month=35, Predicted=3933.1878, Expected=3937.0000
# Month=36, Predicted=3937.3403, Expected=3869.0000
# Month=37, Predicted=3868.0344, Expected=3852.0000
# Month=38, Predicted=3850.9159, Expected=3837.0000
# Month=39, Predicted=3836.2102, Expected=3832.0000
# Month=40, Predicted=3831.7727, Expected=3849.0000
# Month=41, Predicted=3849.8555, Expected=3863.0000
# Month=42, Predicted=3864.2197, Expected=3878.0000
# Month=43, Predicted=3879.3175, Expected=3855.0000
# Month=44, Predicted=3854.7334, Expected=3843.0000
# Month=45, Predicted=3842.6132, Expected=3847.0000
# Month=46, Predicted=3847.0945, Expected=3801.0000
# Month=47, Predicted=3799.9053, Expected=3787.0000
# Month=48, Predicted=3786.2305, Expected=3776.0000
# Month=49, Predicted=3775.5274, Expected=3797.0000
# Month=50, Predicted=3797.8175, Expected=3821.0000
# Month=51, Predicted=3822.5444, Expected=3877.0000
# Month=52, Predicted=3879.7340, Expected=3875.0000
# Month=53, Predicted=3876.0990, Expected=3890.0000
# Month=54, Predicted=3891.0693, Expected=3910.0000
# Month=55, Predicted=3911.1620, Expected=3924.0000
# Month=56, Predicted=3924.9524, Expected=3918.0000
# Month=57, Predicted=3918.0838, Expected=3936.0000
# Month=58, Predicted=3936.7046, Expected=3911.0000
# Month=59, Predicted=3910.3842, Expected=3891.0000
# Month=60, Predicted=3890.2122, Expected=3855.0000
# Run 11 — RMSE: 24.331426, MSE: 592.018267, NMSE: 0.0026929060
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3796.9043, Expected=3796.0000
# Month=2, Predicted=3796.5955, Expected=3793.0000
# Month=3, Predicted=3793.8764, Expected=3766.0000
# Month=4, Predicted=3763.7923, Expected=3747.0000
# Month=5, Predicted=3746.2295, Expected=3754.0000
# Month=6, Predicted=3756.5404, Expected=3756.0000
# Month=7, Predicted=3757.8085, Expected=3767.0000
# Month=8, Predicted=3769.5492, Expected=3751.0000
# Month=9, Predicted=3750.4024, Expected=3769.0000
# Month=10, Predicted=3771.2748, Expected=3760.0000
# Month=11, Predicted=3760.1875, Expected=3785.0000
# Month=12, Predicted=3786.2695, Expected=3776.0000
# Month=13, Predicted=3775.9766, Expected=3755.0000
# Month=14, Predicted=3753.7983, Expected=3755.0000
# Month=15, Predicted=3756.8098, Expected=3751.0000
# Month=16, Predicted=3752.0792, Expected=3776.0000
# Month=17, Predicted=3777.6758, Expected=3847.0000
# Month=18, Predicted=3829.2422, Expected=3830.0000
# Month=19, Predicted=3828.1002, Expected=3881.0000
# Month=20, Predicted=3872.0022, Expected=3899.0000
# Month=21, Predicted=3900.5119, Expected=3917.0000
# Month=22, Predicted=3918.5679, Expected=3913.0000
# Month=23, Predicted=3913.2643, Expected=3901.0000
# Month=24, Predicted=3900.5525, Expected=3886.0000
# Month=25, Predicted=3885.4300, Expected=3892.5000
# Month=26, Predicted=3894.8387, Expected=3899.0000
# Month=27, Predicted=3901.1970, Expected=3886.0000
# Month=28, Predicted=3885.7965, Expected=3908.0000
# Month=29, Predicted=3909.9006, Expected=3875.0000
# Month=30, Predicted=3872.0611, Expected=3860.0000
# Month=31, Predicted=3860.1243, Expected=3880.0000
# Month=32, Predicted=3882.4501, Expected=3895.0000
# Month=33, Predicted=3897.4602, Expected=3954.0000
# Month=34, Predicted=3941.4636, Expected=3933.0000
# Month=35, Predicted=3930.8023, Expected=3937.0000
# Month=36, Predicted=3938.8277, Expected=3869.0000
# Month=37, Predicted=3863.5917, Expected=3852.0000
# Month=38, Predicted=3852.1401, Expected=3837.0000
# Month=39, Predicted=3836.9393, Expected=3832.0000
# Month=40, Predicted=3833.3940, Expected=3849.0000
# Month=41, Predicted=3851.7905, Expected=3863.0000
# Month=42, Predicted=3865.4925, Expected=3878.0000
# Month=43, Predicted=3880.1701, Expected=3855.0000
# Month=44, Predicted=3853.3610, Expected=3843.0000
# Month=45, Predicted=3843.2941, Expected=3847.0000
# Month=46, Predicted=3849.1405, Expected=3801.0000
# Month=47, Predicted=3797.0043, Expected=3787.0000
# Month=48, Predicted=3787.4748, Expected=3776.0000
# Month=49, Predicted=3776.5550, Expected=3797.0000
# Month=50, Predicted=3799.5093, Expected=3821.0000
# Month=51, Predicted=3822.6983, Expected=3877.0000
# Month=52, Predicted=3865.4801, Expected=3875.0000
# Month=53, Predicted=3875.3922, Expected=3890.0000
# Month=54, Predicted=3891.8043, Expected=3910.0000
# Month=55, Predicted=3911.6483, Expected=3924.0000
# Month=56, Predicted=3925.9068, Expected=3918.0000
# Month=57, Predicted=3918.1347, Expected=3936.0000
# Month=58, Predicted=3938.1842, Expected=3911.0000
# Month=59, Predicted=3908.7193, Expected=3891.0000
# Month=60, Predicted=3890.0893, Expected=3855.0000
# Run 12 — RMSE: 24.218421, MSE: 586.531939, NMSE: 0.0027278141
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3798.9237, Expected=3796.0000
# Month=2, Predicted=3796.3626, Expected=3793.0000
# Month=3, Predicted=3793.2782, Expected=3766.0000
# Month=4, Predicted=3765.8229, Expected=3747.0000
# Month=5, Predicted=3746.8411, Expected=3754.0000
# Month=6, Predicted=3754.3114, Expected=3756.0000
# Month=7, Predicted=3756.2580, Expected=3767.0000
# Month=8, Predicted=3767.4345, Expected=3751.0000
# Month=9, Predicted=3750.9684, Expected=3769.0000
# Month=10, Predicted=3769.5428, Expected=3760.0000
# Month=11, Predicted=3760.1057, Expected=3785.0000
# Month=12, Predicted=3785.6921, Expected=3776.0000
# Month=13, Predicted=3776.1468, Expected=3755.0000
# Month=14, Predicted=3754.8671, Expected=3755.0000
# Month=15, Predicted=3755.1899, Expected=3751.0000
# Month=16, Predicted=3751.1361, Expected=3776.0000
# Month=17, Predicted=3776.6713, Expected=3847.0000
# Month=18, Predicted=3848.3505, Expected=3830.0000
# Month=19, Predicted=3830.1709, Expected=3881.0000
# Month=20, Predicted=3882.1644, Expected=3899.0000
# Month=21, Predicted=3899.7607, Expected=3917.0000
# Month=22, Predicted=3917.7433, Expected=3913.0000
# Month=23, Predicted=3913.3442, Expected=3901.0000
# Month=24, Predicted=3901.1339, Expected=3886.0000
# Month=25, Predicted=3886.0153, Expected=3892.5000
# Month=26, Predicted=3892.8751, Expected=3899.0000
# Month=27, Predicted=3899.3968, Expected=3886.0000
# Month=28, Predicted=3886.0433, Expected=3908.0000
# Month=29, Predicted=3908.6389, Expected=3875.0000
# Month=30, Predicted=3874.7490, Expected=3860.0000
# Month=31, Predicted=3859.8760, Expected=3880.0000
# Month=32, Predicted=3880.5388, Expected=3895.0000
# Month=33, Predicted=3895.5247, Expected=3954.0000
# Month=34, Predicted=3955.2133, Expected=3933.0000
# Month=35, Predicted=3933.0688, Expected=3937.0000
# Month=36, Predicted=3937.3635, Expected=3869.0000
# Month=37, Predicted=3868.5331, Expected=3852.0000
# Month=38, Predicted=3851.6951, Expected=3837.0000
# Month=39, Predicted=3836.7593, Expected=3832.0000
# Month=40, Predicted=3831.9603, Expected=3849.0000
# Month=41, Predicted=3849.4173, Expected=3863.0000
# Month=42, Predicted=3863.4486, Expected=3878.0000
# Month=43, Predicted=3878.5163, Expected=3855.0000
# Month=44, Predicted=3854.8619, Expected=3843.0000
# Month=45, Predicted=3842.9500, Expected=3847.0000
# Month=46, Predicted=3847.2520, Expected=3801.0000
# Month=47, Predicted=3800.4695, Expected=3787.0000
# Month=48, Predicted=3786.7631, Expected=3776.0000
# Month=49, Predicted=3775.8437, Expected=3797.0000
# Month=50, Predicted=3797.4788, Expected=3821.0000
# Month=51, Predicted=3821.6301, Expected=3877.0000
# Month=52, Predicted=3878.1697, Expected=3875.0000
# Month=53, Predicted=3875.3776, Expected=3890.0000
# Month=54, Predicted=3890.6149, Expected=3910.0000
# Month=55, Predicted=3910.7215, Expected=3924.0000
# Month=56, Predicted=3924.6367, Expected=3918.0000
# Month=57, Predicted=3918.2683, Expected=3936.0000
# Month=58, Predicted=3936.6560, Expected=3911.0000
# Month=59, Predicted=3910.9232, Expected=3891.0000
# Month=60, Predicted=3890.8678, Expected=3855.0000
# Run 13 — RMSE: 24.432138, MSE: 596.929348, NMSE: 0.0027257152
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3799.4351, Expected=3796.0000
# Month=2, Predicted=3796.8145, Expected=3793.0000
# Month=3, Predicted=3793.3899, Expected=3766.0000
# Month=4, Predicted=3765.7594, Expected=3747.0000
# Month=5, Predicted=3746.4478, Expected=3754.0000
# Month=6, Predicted=3754.1807, Expected=3756.0000
# Month=7, Predicted=3756.4869, Expected=3767.0000
# Month=8, Predicted=3767.7371, Expected=3751.0000
# Month=9, Predicted=3751.1628, Expected=3769.0000
# Month=10, Predicted=3769.5482, Expected=3760.0000
# Month=11, Predicted=3760.2469, Expected=3785.0000
# Month=12, Predicted=3785.7956, Expected=3776.0000
# Month=13, Predicted=3776.3883, Expected=3755.0000
# Month=14, Predicted=3754.8610, Expected=3755.0000
# Month=15, Predicted=3754.9835, Expected=3751.0000
# Month=16, Predicted=3751.1279, Expected=3776.0000
# Month=17, Predicted=3776.8850, Expected=3847.0000
# Month=18, Predicted=3848.7712, Expected=3830.0000
# Month=19, Predicted=3830.7771, Expected=3881.0000
# Month=20, Predicted=3882.2644, Expected=3899.0000
# Month=21, Predicted=3900.2298, Expected=3917.0000
# Month=22, Predicted=3918.0824, Expected=3913.0000
# Month=23, Predicted=3913.6070, Expected=3901.0000
# Month=24, Predicted=3901.1532, Expected=3886.0000
# Month=25, Predicted=3885.8599, Expected=3892.5000
# Month=26, Predicted=3892.8081, Expected=3899.0000
# Month=27, Predicted=3899.6312, Expected=3886.0000
# Month=28, Predicted=3886.2427, Expected=3908.0000
# Month=29, Predicted=3908.7646, Expected=3875.0000
# Month=30, Predicted=3874.9066, Expected=3860.0000
# Month=31, Predicted=3859.6106, Expected=3880.0000
# Month=32, Predicted=3880.5136, Expected=3895.0000
# Month=33, Predicted=3895.9061, Expected=3954.0000
# Month=34, Predicted=3955.6525, Expected=3933.0000
# Month=35, Predicted=3933.6116, Expected=3937.0000
# Month=36, Predicted=3937.3461, Expected=3869.0000
# Month=37, Predicted=3868.5329, Expected=3852.0000
# Month=38, Predicted=3850.8311, Expected=3837.0000
# Month=39, Predicted=3836.4039, Expected=3832.0000
# Month=40, Predicted=3832.0375, Expected=3849.0000
# Month=41, Predicted=3849.7794, Expected=3863.0000
# Month=42, Predicted=3863.8598, Expected=3878.0000
# Month=43, Predicted=3878.8302, Expected=3855.0000
# Month=44, Predicted=3855.0464, Expected=3843.0000
# Month=45, Predicted=3842.6716, Expected=3847.0000
# Month=46, Predicted=3847.0471, Expected=3801.0000
# Month=47, Predicted=3800.2652, Expected=3787.0000
# Month=48, Predicted=3786.3018, Expected=3776.0000
# Month=49, Predicted=3775.6446, Expected=3797.0000
# Month=50, Predicted=3797.7142, Expected=3821.0000
# Month=51, Predicted=3822.1067, Expected=3877.0000
# Month=52, Predicted=3878.6392, Expected=3875.0000
# Month=53, Predicted=3875.9052, Expected=3890.0000
# Month=54, Predicted=3890.7195, Expected=3910.0000
# Month=55, Predicted=3910.8362, Expected=3924.0000
# Month=56, Predicted=3924.8588, Expected=3918.0000
# Month=57, Predicted=3918.4651, Expected=3936.0000
# Month=58, Predicted=3936.7062, Expected=3911.0000
# Month=59, Predicted=3911.0641, Expected=3891.0000
# Month=60, Predicted=3890.6648, Expected=3855.0000
# Run 14 — RMSE: 24.356768, MSE: 593.252145, NMSE: 0.0027031361
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3799.6988, Expected=3796.0000
# Month=2, Predicted=3796.8001, Expected=3793.0000
# Month=3, Predicted=3793.3237, Expected=3766.0000
# Month=4, Predicted=3765.4917, Expected=3747.0000
# Month=5, Predicted=3746.2476, Expected=3754.0000
# Month=6, Predicted=3754.0251, Expected=3756.0000
# Month=7, Predicted=3756.3608, Expected=3767.0000
# Month=8, Predicted=3767.6462, Expected=3751.0000
# Month=9, Predicted=3751.0163, Expected=3769.0000
# Month=10, Predicted=3769.5971, Expected=3760.0000
# Month=11, Predicted=3760.2785, Expected=3785.0000
# Month=12, Predicted=3785.9175, Expected=3776.0000
# Month=13, Predicted=3776.4031, Expected=3755.0000
# Month=14, Predicted=3754.6365, Expected=3755.0000
# Month=15, Predicted=3754.9168, Expected=3751.0000
# Month=16, Predicted=3751.0869, Expected=3776.0000
# Month=17, Predicted=3776.9170, Expected=3847.0000
# Month=18, Predicted=3849.4720, Expected=3830.0000
# Month=19, Predicted=3830.7488, Expected=3881.0000
# Month=20, Predicted=3882.6371, Expected=3899.0000
# Month=21, Predicted=3900.4382, Expected=3917.0000
# Month=22, Predicted=3918.1611, Expected=3913.0000
# Month=23, Predicted=3913.5064, Expected=3901.0000
# Month=24, Predicted=3900.9574, Expected=3886.0000
# Month=25, Predicted=3885.6510, Expected=3892.5000
# Month=26, Predicted=3892.6722, Expected=3899.0000
# Month=27, Predicted=3899.5229, Expected=3886.0000
# Month=28, Predicted=3886.0359, Expected=3908.0000
# Month=29, Predicted=3908.7454, Expected=3875.0000
# Month=30, Predicted=3874.6416, Expected=3860.0000
# Month=31, Predicted=3859.3685, Expected=3880.0000
# Month=32, Predicted=3880.4884, Expected=3895.0000
# Month=33, Predicted=3895.9618, Expected=3954.0000
# Month=34, Predicted=3956.1159, Expected=3933.0000
# Month=35, Predicted=3933.5146, Expected=3937.0000
# Month=36, Predicted=3937.3137, Expected=3869.0000
# Month=37, Predicted=3867.4101, Expected=3852.0000
# Month=38, Predicted=3850.4774, Expected=3837.0000
# Month=39, Predicted=3836.1233, Expected=3832.0000
# Month=40, Predicted=3831.6299, Expected=3849.0000
# Month=41, Predicted=3849.5402, Expected=3863.0000
# Month=42, Predicted=3863.8918, Expected=3878.0000
# Month=43, Predicted=3878.9693, Expected=3855.0000
# Month=44, Predicted=3854.9204, Expected=3843.0000
# Month=45, Predicted=3842.6313, Expected=3847.0000
# Month=46, Predicted=3847.1137, Expected=3801.0000
# Month=47, Predicted=3799.9259, Expected=3787.0000
# Month=48, Predicted=3785.9731, Expected=3776.0000
# Month=49, Predicted=3775.4262, Expected=3797.0000
# Month=50, Predicted=3797.5405, Expected=3821.0000
# Month=51, Predicted=3822.2084, Expected=3877.0000
# Month=52, Predicted=3879.1436, Expected=3875.0000
# Month=53, Predicted=3876.0264, Expected=3890.0000
# Month=54, Predicted=3890.8773, Expected=3910.0000
# Month=55, Predicted=3911.0960, Expected=3924.0000
# Month=56, Predicted=3925.0147, Expected=3918.0000
# Month=57, Predicted=3918.3972, Expected=3936.0000
# Month=58, Predicted=3936.7634, Expected=3911.0000
# Month=59, Predicted=3910.8326, Expected=3891.0000
# Month=60, Predicted=3890.3522, Expected=3855.0000
# Run 15 — RMSE: 24.342518, MSE: 592.558190, NMSE: 0.0026955842
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3799.3673, Expected=3796.0000
# Month=2, Predicted=3796.7193, Expected=3793.0000
# Month=3, Predicted=3793.2972, Expected=3766.0000
# Month=4, Predicted=3765.4565, Expected=3747.0000
# Month=5, Predicted=3746.2389, Expected=3754.0000
# Month=6, Predicted=3753.8028, Expected=3756.0000
# Month=7, Predicted=3756.0787, Expected=3767.0000
# Month=8, Predicted=3767.5939, Expected=3751.0000
# Month=9, Predicted=3751.1971, Expected=3769.0000
# Month=10, Predicted=3769.8318, Expected=3760.0000
# Month=11, Predicted=3760.4279, Expected=3785.0000
# Month=12, Predicted=3785.9314, Expected=3776.0000
# Month=13, Predicted=3776.3723, Expected=3755.0000
# Month=14, Predicted=3754.7941, Expected=3755.0000
# Month=15, Predicted=3755.0036, Expected=3751.0000
# Month=16, Predicted=3750.9983, Expected=3776.0000
# Month=17, Predicted=3776.7337, Expected=3847.0000
# Month=18, Predicted=3848.7086, Expected=3830.0000
# Month=19, Predicted=3830.6354, Expected=3881.0000
# Month=20, Predicted=3882.1611, Expected=3899.0000
# Month=21, Predicted=3899.8264, Expected=3917.0000
# Month=22, Predicted=3917.5386, Expected=3913.0000
# Month=23, Predicted=3912.9325, Expected=3901.0000
# Month=24, Predicted=3900.4493, Expected=3886.0000
# Month=25, Predicted=3885.1518, Expected=3892.5000
# Month=26, Predicted=3892.1266, Expected=3899.0000
# Month=27, Predicted=3899.0111, Expected=3886.0000
# Month=28, Predicted=3885.8675, Expected=3908.0000
# ...
# Month=53, Predicted=3874.4358, Expected=3890.0000
# Month=54, Predicted=3891.5208, Expected=3910.0000
# Month=55, Predicted=3911.4894, Expected=3924.0000
# Month=56, Predicted=3925.6007, Expected=3918.0000
# Month=57, Predicted=3918.1407, Expected=3936.0000
# Month=58, Predicted=3937.1699, Expected=3911.0000
# Month=59, Predicted=3908.9565, Expected=3891.0000
# Month=60, Predicted=3890.8156, Expected=3855.0000
# Run 25 — RMSE: 24.294499, MSE: 590.222685, NMSE: 0.0027309623
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3795.9880, Expected=3796.0000
# Month=2, Predicted=3798.2295, Expected=3793.0000
# Month=3, Predicted=3794.2668, Expected=3766.0000
# Month=4, Predicted=3762.1292, Expected=3747.0000
# Month=5, Predicted=3743.8597, Expected=3754.0000
# Month=6, Predicted=3755.6079, Expected=3756.0000
# Month=7, Predicted=3757.9489, Expected=3767.0000
# Month=8, Predicted=3770.0217, Expected=3751.0000
# Month=9, Predicted=3749.7693, Expected=3769.0000
# Month=10, Predicted=3771.5025, Expected=3760.0000
# Month=11, Predicted=3759.9391, Expected=3785.0000
# Month=12, Predicted=3786.3624, Expected=3776.0000
# Month=13, Predicted=3776.1073, Expected=3755.0000
# Month=14, Predicted=3752.5576, Expected=3755.0000
# Month=15, Predicted=3755.8840, Expected=3751.0000
# Month=16, Predicted=3751.5189, Expected=3776.0000
# Month=17, Predicted=3777.3221, Expected=3847.0000
# Month=18, Predicted=3832.2126, Expected=3830.0000
# Month=19, Predicted=3829.1543, Expected=3881.0000
# Month=20, Predicted=3873.8812, Expected=3899.0000
# Month=21, Predicted=3901.7959, Expected=3917.0000
# Month=22, Predicted=3919.7221, Expected=3913.0000
# Month=23, Predicted=3913.9568, Expected=3901.0000
# Month=24, Predicted=3899.7238, Expected=3886.0000
# Month=25, Predicted=3883.7719, Expected=3892.5000
# Month=26, Predicted=3894.2562, Expected=3899.0000
# Month=27, Predicted=3901.4434, Expected=3886.0000
# Month=28, Predicted=3885.3120, Expected=3908.0000
# Month=29, Predicted=3909.9601, Expected=3875.0000
# Month=30, Predicted=3870.4871, Expected=3860.0000
# Month=31, Predicted=3858.1693, Expected=3880.0000
# Month=32, Predicted=3882.0697, Expected=3895.0000
# Month=33, Predicted=3897.8182, Expected=3954.0000
# Month=34, Predicted=3943.1377, Expected=3933.0000
# Month=35, Predicted=3930.8544, Expected=3937.0000
# Month=36, Predicted=3939.3855, Expected=3869.0000
# Month=37, Predicted=3866.7144, Expected=3852.0000
# Month=38, Predicted=3847.7064, Expected=3837.0000
# Month=39, Predicted=3834.1391, Expected=3832.0000
# Month=40, Predicted=3832.2444, Expected=3849.0000
# Month=41, Predicted=3851.5155, Expected=3863.0000
# Month=42, Predicted=3866.0177, Expected=3878.0000
# Month=43, Predicted=3880.9784, Expected=3855.0000
# Month=44, Predicted=3852.2769, Expected=3843.0000
# Month=45, Predicted=3841.7337, Expected=3847.0000
# Month=46, Predicted=3848.4867, Expected=3801.0000
# Month=47, Predicted=3796.2295, Expected=3787.0000
# Month=48, Predicted=3784.7187, Expected=3776.0000
# Month=49, Predicted=3774.6807, Expected=3797.0000
# Month=50, Predicted=3798.9672, Expected=3821.0000
# Month=51, Predicted=3822.2631, Expected=3877.0000
# Month=52, Predicted=3866.9819, Expected=3875.0000
# Month=53, Predicted=3877.5810, Expected=3890.0000
# Month=54, Predicted=3893.0336, Expected=3910.0000
# Month=55, Predicted=3912.2961, Expected=3924.0000
# Month=56, Predicted=3926.8358, Expected=3918.0000
# Month=57, Predicted=3918.4799, Expected=3936.0000
# Month=58, Predicted=3938.4043, Expected=3911.0000
# Month=59, Predicted=3907.3586, Expected=3891.0000
# Month=60, Predicted=3888.2241, Expected=3855.0000
# Run 26 — RMSE: 24.163296, MSE: 583.864855, NMSE: 0.0026772952
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3799.0170, Expected=3796.0000
# Month=2, Predicted=3796.2413, Expected=3793.0000
# Month=3, Predicted=3793.0108, Expected=3766.0000
# Month=4, Predicted=3765.4372, Expected=3747.0000
# Month=5, Predicted=3746.5623, Expected=3754.0000
# Month=6, Predicted=3754.2753, Expected=3756.0000
# Month=7, Predicted=3756.3769, Expected=3767.0000
# Month=8, Predicted=3767.5486, Expected=3751.0000
# Month=9, Predicted=3750.9676, Expected=3769.0000
# Month=10, Predicted=3769.5357, Expected=3760.0000
# Month=11, Predicted=3760.1164, Expected=3785.0000
# Month=12, Predicted=3785.6850, Expected=3776.0000
# Month=13, Predicted=3776.1153, Expected=3755.0000
# Month=14, Predicted=3754.6658, Expected=3755.0000
# Month=15, Predicted=3755.0889, Expected=3751.0000
# Month=16, Predicted=3751.1565, Expected=3776.0000
# Month=17, Predicted=3776.7534, Expected=3847.0000
# Month=18, Predicted=3848.5979, Expected=3830.0000
# Month=19, Predicted=3830.0192, Expected=3881.0000
# Month=20, Predicted=3881.9378, Expected=3899.0000
# Month=21, Predicted=3899.5475, Expected=3917.0000
# Month=22, Predicted=3917.4357, Expected=3913.0000
# Month=23, Predicted=3912.9682, Expected=3901.0000
# Month=24, Predicted=3900.7243, Expected=3886.0000
# Month=25, Predicted=3885.6756, Expected=3892.5000
# Month=26, Predicted=3892.7247, Expected=3899.0000
# Month=27, Predicted=3899.3981, Expected=3886.0000
# Month=28, Predicted=3885.9948, Expected=3908.0000
# Month=29, Predicted=3908.6248, Expected=3875.0000
# Month=30, Predicted=3874.5648, Expected=3860.0000
# Month=31, Predicted=3859.7202, Expected=3880.0000
# Month=32, Predicted=3880.5840, Expected=3895.0000
# Month=33, Predicted=3895.6956, Expected=3954.0000
# Month=34, Predicted=3955.3983, Expected=3933.0000
# Month=35, Predicted=3932.9079, Expected=3937.0000
# Month=36, Predicted=3937.0772, Expected=3869.0000
# Month=37, Predicted=3867.4170, Expected=3852.0000
# Month=38, Predicted=3851.3609, Expected=3837.0000
# Month=39, Predicted=3836.8387, Expected=3832.0000
# Month=40, Predicted=3832.2153, Expected=3849.0000
# Month=41, Predicted=3849.7447, Expected=3863.0000
# Month=42, Predicted=3863.7527, Expected=3878.0000
# Month=43, Predicted=3878.6789, Expected=3855.0000
# Month=44, Predicted=3854.7667, Expected=3843.0000
# Month=45, Predicted=3842.7982, Expected=3847.0000
# Month=46, Predicted=3847.2312, Expected=3801.0000
# Month=47, Predicted=3800.1651, Expected=3787.0000
# Month=48, Predicted=3786.7072, Expected=3776.0000
# Month=49, Predicted=3776.0135, Expected=3797.0000
# Month=50, Predicted=3797.7560, Expected=3821.0000
# Month=51, Predicted=3821.9449, Expected=3877.0000
# Month=52, Predicted=3878.4117, Expected=3875.0000
# Month=53, Predicted=3875.3214, Expected=3890.0000
# Month=54, Predicted=3890.3670, Expected=3910.0000
# Month=55, Predicted=3910.4995, Expected=3924.0000
# Month=56, Predicted=3924.4190, Expected=3918.0000
# Month=57, Predicted=3917.9829, Expected=3936.0000
# Month=58, Predicted=3936.4173, Expected=3911.0000
# Month=59, Predicted=3910.6076, Expected=3891.0000
# Month=60, Predicted=3890.5564, Expected=3855.0000
# Run 27 — RMSE: 24.358073, MSE: 593.315697, NMSE: 0.0027140655
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3798.7815, Expected=3796.0000
# Month=2, Predicted=3796.1128, Expected=3793.0000
# Month=3, Predicted=3793.3462, Expected=3766.0000
# Month=4, Predicted=3765.6266, Expected=3747.0000
# Month=5, Predicted=3746.8942, Expected=3754.0000
# Month=6, Predicted=3754.2707, Expected=3756.0000
# Month=7, Predicted=3756.1015, Expected=3767.0000
# Month=8, Predicted=3767.4331, Expected=3751.0000
# Month=9, Predicted=3750.7753, Expected=3769.0000
# Month=10, Predicted=3769.6993, Expected=3760.0000
# Month=11, Predicted=3759.8411, Expected=3785.0000
# Month=12, Predicted=3785.8476, Expected=3776.0000
# Month=13, Predicted=3775.8343, Expected=3755.0000
# Month=14, Predicted=3754.8967, Expected=3755.0000
# Month=15, Predicted=3755.2394, Expected=3751.0000
# Month=16, Predicted=3751.0127, Expected=3776.0000
# Month=17, Predicted=3776.7241, Expected=3847.0000
# Month=18, Predicted=3848.3746, Expected=3830.0000
# Month=19, Predicted=3829.4404, Expected=3881.0000
# Month=20, Predicted=3882.5723, Expected=3899.0000
# Month=21, Predicted=3899.2481, Expected=3917.0000
# Month=22, Predicted=3917.7347, Expected=3913.0000
# Month=23, Predicted=3913.1214, Expected=3901.0000
# Month=24, Predicted=3901.0926, Expected=3886.0000
# Month=25, Predicted=3885.9271, Expected=3892.5000
# Month=26, Predicted=3892.8510, Expected=3899.0000
# Month=27, Predicted=3899.2315, Expected=3886.0000
# Month=28, Predicted=3885.8875, Expected=3908.0000
# Month=29, Predicted=3908.7305, Expected=3875.0000
# Month=30, Predicted=3874.2487, Expected=3860.0000
# Month=31, Predicted=3860.0934, Expected=3880.0000
# Month=32, Predicted=3880.4755, Expected=3895.0000
# Month=33, Predicted=3895.3533, Expected=3954.0000
# Month=34, Predicted=3955.3171, Expected=3933.0000
# Month=35, Predicted=3932.4093, Expected=3937.0000
# Month=36, Predicted=3937.6997, Expected=3869.0000
# Month=37, Predicted=3867.4565, Expected=3852.0000
# Month=38, Predicted=3852.0393, Expected=3837.0000
# Month=39, Predicted=3836.4640, Expected=3832.0000
# Month=40, Predicted=3831.9474, Expected=3849.0000
# Month=41, Predicted=3849.4039, Expected=3863.0000
# Month=42, Predicted=3863.3578, Expected=3878.0000
# Month=43, Predicted=3878.5130, Expected=3855.0000
# Month=44, Predicted=3854.6571, Expected=3843.0000
# Month=45, Predicted=3843.1259, Expected=3847.0000
# Month=46, Predicted=3847.2296, Expected=3801.0000
# Month=47, Predicted=3800.0155, Expected=3787.0000
# Month=48, Predicted=3787.0202, Expected=3776.0000
# Month=49, Predicted=3775.7057, Expected=3797.0000
# Month=50, Predicted=3797.5590, Expected=3821.0000
# Month=51, Predicted=3821.5267, Expected=3877.0000
# Month=52, Predicted=3878.2488, Expected=3875.0000
# Month=53, Predicted=3874.9221, Expected=3890.0000
# Month=54, Predicted=3890.8292, Expected=3910.0000
# Month=55, Predicted=3910.5782, Expected=3924.0000
# Month=56, Predicted=3924.5152, Expected=3918.0000
# Month=57, Predicted=3918.1234, Expected=3936.0000
# Month=58, Predicted=3936.7123, Expected=3911.0000
# Month=59, Predicted=3910.5343, Expected=3891.0000
# Month=60, Predicted=3890.9676, Expected=3855.0000
# Run 28 — RMSE: 24.476585, MSE: 599.103201, NMSE: 0.0027366240
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3798.6187, Expected=3796.0000
# Month=2, Predicted=3796.2903, Expected=3793.0000
# Month=3, Predicted=3793.2543, Expected=3766.0000
# Month=4, Predicted=3765.9869, Expected=3747.0000
# Month=5, Predicted=3746.9095, Expected=3754.0000
# Month=6, Predicted=3754.1446, Expected=3756.0000
# Month=7, Predicted=3756.1082, Expected=3767.0000
# Month=8, Predicted=3767.2470, Expected=3751.0000
# Month=9, Predicted=3750.9955, Expected=3769.0000
# Month=10, Predicted=3769.3485, Expected=3760.0000
# Month=11, Predicted=3760.0816, Expected=3785.0000
# Month=12, Predicted=3785.4633, Expected=3776.0000
# Month=13, Predicted=3776.1257, Expected=3755.0000
# Month=14, Predicted=3754.9719, Expected=3755.0000
# Month=15, Predicted=3755.1137, Expected=3751.0000
# Month=16, Predicted=3751.0694, Expected=3776.0000
# Month=17, Predicted=3776.4260, Expected=3847.0000
# Month=18, Predicted=3848.0082, Expected=3830.0000
# Month=19, Predicted=3830.1597, Expected=3881.0000
# Month=20, Predicted=3881.8577, Expected=3899.0000
# Month=21, Predicted=3899.5329, Expected=3917.0000
# Month=22, Predicted=3917.5497, Expected=3913.0000
# Month=23, Predicted=3913.3214, Expected=3901.0000
# Month=24, Predicted=3901.1791, Expected=3886.0000
# Month=25, Predicted=3886.0605, Expected=3892.5000
# Month=26, Predicted=3892.7236, Expected=3899.0000
# Month=27, Predicted=3899.2274, Expected=3886.0000
# Month=28, Predicted=3886.0302, Expected=3908.0000
# Month=29, Predicted=3908.4019, Expected=3875.0000
# Month=30, Predicted=3874.8785, Expected=3860.0000
# Month=31, Predicted=3859.8885, Expected=3880.0000
# Month=32, Predicted=3880.2974, Expected=3895.0000
# Month=33, Predicted=3895.2882, Expected=3954.0000
# Month=34, Predicted=3954.8712, Expected=3933.0000
# Month=35, Predicted=3933.1043, Expected=3937.0000
# Month=36, Predicted=3937.2677, Expected=3869.0000
# Month=37, Predicted=3868.7579, Expected=3852.0000
# Month=38, Predicted=3851.6059, Expected=3837.0000
# Month=39, Predicted=3836.6310, Expected=3832.0000
# Month=40, Predicted=3831.7911, Expected=3849.0000
# Month=41, Predicted=3849.1636, Expected=3863.0000
# Month=42, Predicted=3863.2307, Expected=3878.0000
# Month=43, Predicted=3878.3357, Expected=3855.0000
# Month=44, Predicted=3854.9952, Expected=3843.0000
# Month=45, Predicted=3843.0099, Expected=3847.0000
# Month=46, Predicted=3847.1634, Expected=3801.0000
# Month=47, Predicted=3800.7091, Expected=3787.0000
# Month=48, Predicted=3786.7571, Expected=3776.0000
# Month=49, Predicted=3775.7905, Expected=3797.0000
# Month=50, Predicted=3797.2425, Expected=3821.0000
# Month=51, Predicted=3821.3674, Expected=3877.0000
# Month=52, Predicted=3877.8438, Expected=3875.0000
# Month=53, Predicted=3875.2980, Expected=3890.0000
# Month=54, Predicted=3890.4748, Expected=3910.0000
# Month=55, Predicted=3910.5446, Expected=3924.0000
# Month=56, Predicted=3924.4893, Expected=3918.0000
# Month=57, Predicted=3918.2731, Expected=3936.0000
# Month=58, Predicted=3936.4780, Expected=3911.0000
# Month=59, Predicted=3911.0452, Expected=3891.0000
# Month=60, Predicted=3890.9432, Expected=3855.0000
# Run 29 — RMSE: 24.463694, MSE: 598.472307, NMSE: 0.0027345180
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3798.6328, Expected=3796.0000
# Month=2, Predicted=3796.1893, Expected=3793.0000
# Month=3, Predicted=3793.2091, Expected=3766.0000
# Month=4, Predicted=3765.9198, Expected=3747.0000
# Month=5, Predicted=3747.0996, Expected=3754.0000
# Month=6, Predicted=3754.4588, Expected=3756.0000
# Month=7, Predicted=3756.3605, Expected=3767.0000
# Month=8, Predicted=3767.4514, Expected=3751.0000
# Month=9, Predicted=3751.0883, Expected=3769.0000
# Month=10, Predicted=3769.5383, Expected=3760.0000
# Month=11, Predicted=3760.1738, Expected=3785.0000
# Month=12, Predicted=3785.5952, Expected=3776.0000
# Month=13, Predicted=3776.1508, Expected=3755.0000
# Month=14, Predicted=3755.0236, Expected=3755.0000
# Month=15, Predicted=3755.3434, Expected=3751.0000
# Month=16, Predicted=3751.2812, Expected=3776.0000
# Month=17, Predicted=3776.6141, Expected=3847.0000
# Month=18, Predicted=3847.9669, Expected=3830.0000
# Month=19, Predicted=3829.9628, Expected=3881.0000
# Month=20, Predicted=3881.7964, Expected=3899.0000
# Month=21, Predicted=3899.4218, Expected=3917.0000
# Month=22, Predicted=3917.4233, Expected=3913.0000
# Month=23, Predicted=3913.1600, Expected=3901.0000
# Month=24, Predicted=3901.0983, Expected=3886.0000
# Month=25, Predicted=3886.1056, Expected=3892.5000
# Month=26, Predicted=3892.9130, Expected=3899.0000
# Month=27, Predicted=3899.3920, Expected=3886.0000
# Month=28, Predicted=3886.1332, Expected=3908.0000
# Month=29, Predicted=3908.5796, Expected=3875.0000
# Month=30, Predicted=3874.8414, Expected=3860.0000
# Month=31, Predicted=3860.1667, Expected=3880.0000
# Month=32, Predicted=3880.6040, Expected=3895.0000
# Month=33, Predicted=3895.4874, Expected=3954.0000
# Month=34, Predicted=3954.8803, Expected=3933.0000
# Month=35, Predicted=3932.9204, Expected=3937.0000
# Month=36, Predicted=3937.3216, Expected=3869.0000
# Month=37, Predicted=3868.3442, Expected=3852.0000
# Month=38, Predicted=3852.2353, Expected=3837.0000
# Month=39, Predicted=3837.2484, Expected=3832.0000
# Month=40, Predicted=3832.3640, Expected=3849.0000
# Month=41, Predicted=3849.5906, Expected=3863.0000
# Month=42, Predicted=3863.4903, Expected=3878.0000
# Month=43, Predicted=3878.4665, Expected=3855.0000
# Month=44, Predicted=3854.9643, Expected=3843.0000
# Month=45, Predicted=3843.1725, Expected=3847.0000
# Month=46, Predicted=3847.3920, Expected=3801.0000
# Month=47, Predicted=3800.7037, Expected=3787.0000
# Month=48, Predicted=3787.2444, Expected=3776.0000
# Month=49, Predicted=3776.2720, Expected=3797.0000
# Month=50, Predicted=3797.6392, Expected=3821.0000
# Month=51, Predicted=3821.5964, Expected=3877.0000
# Month=52, Predicted=3877.8498, Expected=3875.0000
# Month=53, Predicted=3875.1765, Expected=3890.0000
# Month=54, Predicted=3890.4143, Expected=3910.0000
# Month=55, Predicted=3910.4701, Expected=3924.0000
# Month=56, Predicted=3924.3955, Expected=3918.0000
# Month=57, Predicted=3918.1548, Expected=3936.0000
# Month=58, Predicted=3936.4805, Expected=3911.0000
# Month=59, Predicted=3910.9240, Expected=3891.0000
# Month=60, Predicted=3891.0652, Expected=3855.0000
# Run 30 — RMSE: 24.431616, MSE: 596.903848, NMSE: 0.0027343316

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Output Layer on Dow Jones Industrial Index (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Output Layer on Dow Jones Industrial Index (30 runs) =====
# RMSE: 25.553114 ± 6.350860
# MSE:  693.295044 ± 534.225096
# NMSE: 0.0029274345 ± 0.0011166242
#
# Best run: 20
#   RMSE: 24.140012
#   MSE:  582.740185
#   NMSE: 0.0026748459

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Output Layer — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Output Layer — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 24.140012
# MSE:  582.740185
# NMSE: 0.0026748459

# %% [markdown]
# ## Observations
#
# ### Fuzzy Output Layer on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
