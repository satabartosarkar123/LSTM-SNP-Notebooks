# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: S&P 500
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# GPU Acceleration Settings (CUDA + Apple Metal Support)
# ============================================================
import tensorflow as tf
import platform

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        # Detect GPU type
        if platform.system() == 'Darwin' and platform.processor() == 'arm':
            print(f"Apple Metal GPU Enabled: Found {len(physical_devices)} GPU(s) via tensorflow-metal")
            print(f"  Chipset: Apple {platform.machine()} (M-series)")
        else:
            print(f"CUDA GPU Enabled: Found {len(physical_devices)} GPU(s) - Memory Growth Set")
        for d in physical_devices:
            print(f"  Device: {d.name}")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    if platform.system() == 'Darwin' and platform.processor() == 'arm':
        print("Apple Silicon detected but no GPU found.")
        print("  Install tensorflow-metal: pip install tensorflow-metal")
    else:
        print("No GPU found. Falling back to CPU.")
        print("  For CUDA: ensure NVIDIA drivers + CUDA toolkit are installed.")

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fuzzy_output_layer              │ (1, 1)                 │            12 │
# │ (FuzzyOutputLayer)              │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332 (1.30 KB)
#  Trainable params: 332 (1.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — S&P 500

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/sp500.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (251,)
# First 5 values: [2038.199951 2013.780029 2011.709961 1985.319946 1945.969971]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (250, 2)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (190, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (190, 1, 1), y_train shape: (190,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    # Set consumption gate (c) bias to 1.0 (unit forget bias)
    rnn_layer = model.layers[1]
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, bias[units:2*units]
    weights[2] = bias
    cell.set_weights(weights)

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=2154.9216, Expected=2158.2200
# Month=2, Predicted=2157.2088, Expected=2164.1899
# Month=3, Predicted=2163.2639, Expected=2160.3899
# Month=4, Predicted=2159.7862, Expected=2161.3501
# Month=5, Predicted=2159.7263, Expected=2137.6699
# Month=6, Predicted=2140.3789, Expected=2130.2600
# Month=7, Predicted=2133.4295, Expected=2139.6799
# Month=8, Predicted=2139.3433, Expected=2132.9500
# Month=9, Predicted=2133.0046, Expected=2138.3101
# Month=10, Predicted=2135.0065, Expected=2140.8101
# Month=11, Predicted=2139.9590, Expected=2142.5100
# Month=12, Predicted=2140.6044, Expected=2139.4299
# Month=13, Predicted=2138.6635, Expected=2148.5000
# Month=14, Predicted=2146.1771, Expected=2149.7200
# Month=15, Predicted=2149.1882, Expected=2136.9700
# Month=16, Predicted=2137.1031, Expected=2144.0601
# Month=17, Predicted=2141.7395, Expected=2132.2300
# Month=18, Predicted=2133.3591, Expected=2129.7800
# Month=19, Predicted=2128.1536, Expected=2128.6799
# Month=20, Predicted=2128.3317, Expected=2109.4299
# Month=21, Predicted=2111.0652, Expected=2098.8000
# Month=22, Predicted=2100.5038, Expected=2083.7900
# Month=23, Predicted=2087.0605, Expected=2100.5901
# Month=24, Predicted=2095.9549, Expected=2129.9199
# Month=25, Predicted=2128.9527, Expected=2131.5601
# Month=26, Predicted=2131.1949, Expected=2167.4900
# Month=27, Predicted=2165.4100, Expected=2162.7100
# Month=28, Predicted=2164.1768, Expected=2165.6399
# Month=29, Predicted=2163.7508, Expected=2168.2900
# Month=30, Predicted=2168.5888, Expected=2177.5300
# Month=31, Predicted=2175.8838, Expected=2178.6101
# Month=32, Predicted=2178.2248, Expected=2186.8501
# Month=33, Predicted=2184.3928, Expected=2186.4299
# Month=34, Predicted=2185.7426, Expected=2201.5601
# Month=35, Predicted=2198.2122, Expected=2198.5500
# Month=36, Predicted=2198.3816, Expected=2206.2700
# Month=37, Predicted=2202.9507, Expected=2210.2100
# Month=38, Predicted=2209.2921, Expected=2200.7600
# Month=39, Predicted=2199.9604, Expected=2204.9700
# Month=40, Predicted=2202.4848, Expected=2200.1699
# Month=41, Predicted=2199.8308, Expected=2191.1201
# Month=42, Predicted=2190.2770, Expected=2200.6499
# Month=43, Predicted=2197.4177, Expected=2207.2600
# Month=44, Predicted=2205.5821, Expected=2210.7200
# Month=45, Predicted=2207.9946, Expected=2241.1299
# Month=46, Predicted=2237.9538, Expected=2249.7300
# Month=47, Predicted=2249.8794, Expected=2258.8301
# Month=48, Predicted=2256.6543, Expected=2263.3201
# Month=49, Predicted=2262.4114, Expected=2268.3501
# Month=50, Predicted=2266.4625, Expected=2253.7700
# Month=51, Predicted=2254.1065, Expected=2266.8101
# Month=52, Predicted=2262.5571, Expected=2259.2400
# Month=53, Predicted=2259.6491, Expected=2266.5000
# Month=54, Predicted=2261.7331, Expected=2270.5400
# Month=55, Predicted=2269.1941, Expected=2262.9299
# Month=56, Predicted=2260.9298, Expected=2260.2500
# Month=57, Predicted=2257.9366, Expected=2266.2300
# Month=58, Predicted=2263.5444, Expected=2270.2300
# Month=59, Predicted=2267.8938, Expected=2249.5000
# Month=60, Predicted=2249.7780, Expected=2251.6101
# Run 1 — RMSE: 11.538126, MSE: 133.128348, NMSE: 0.0008256692
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=2155.2509, Expected=2158.2200
# Month=2, Predicted=2160.5752, Expected=2164.1899
# Month=3, Predicted=2164.0902, Expected=2160.3899
# Month=4, Predicted=2159.9309, Expected=2161.3501
# Month=5, Predicted=2163.2094, Expected=2137.6699
# Month=6, Predicted=2140.1521, Expected=2130.2600
# Month=7, Predicted=2135.4750, Expected=2139.6799
# Month=8, Predicted=2138.3875, Expected=2132.9500
# Month=9, Predicted=2130.2273, Expected=2138.3101
# Month=10, Predicted=2138.9607, Expected=2140.8101
# Month=11, Predicted=2141.5147, Expected=2142.5100
# Month=12, Predicted=2142.5503, Expected=2139.4299
# Month=13, Predicted=2140.8511, Expected=2148.5000
# Month=14, Predicted=2149.5622, Expected=2149.7200
# Month=15, Predicted=2149.4161, Expected=2136.9700
# Month=16, Predicted=2139.4382, Expected=2144.0601
# Month=17, Predicted=2146.6460, Expected=2132.2300
# Month=18, Predicted=2131.0802, Expected=2129.7800
# Month=19, Predicted=2131.6658, Expected=2128.6799
# Month=20, Predicted=2129.5471, Expected=2109.4299
# Month=21, Predicted=2110.6383, Expected=2098.8000
# Month=22, Predicted=2103.3920, Expected=2083.7900
# Month=23, Predicted=2085.5137, Expected=2100.5901
# Month=24, Predicted=2098.6869, Expected=2129.9199
# Month=25, Predicted=2125.5255, Expected=2131.5601
# Month=26, Predicted=2130.3396, Expected=2167.4900
# Month=27, Predicted=2165.9458, Expected=2162.7100
# Month=28, Predicted=2163.4268, Expected=2165.6399
# Month=29, Predicted=2170.1296, Expected=2168.2900
# Month=30, Predicted=2171.2379, Expected=2177.5300
# Month=31, Predicted=2177.3824, Expected=2178.6101
# Month=32, Predicted=2178.1417, Expected=2186.8501
# Month=33, Predicted=2187.5372, Expected=2186.4299
# Month=34, Predicted=2186.9521, Expected=2201.5601
# Month=35, Predicted=2200.8491, Expected=2198.5500
# Month=36, Predicted=2198.0737, Expected=2206.2700
# Month=37, Predicted=2207.8005, Expected=2210.2100
# Month=38, Predicted=2210.8011, Expected=2200.7600
# Month=39, Predicted=2202.0862, Expected=2204.9700
# Month=40, Predicted=2207.4158, Expected=2200.1699
# Month=41, Predicted=2200.1923, Expected=2191.1201
# Month=42, Predicted=2192.9019, Expected=2200.6499
# Month=43, Predicted=2201.0866, Expected=2207.2600
# Month=44, Predicted=2205.2189, Expected=2210.7200
# Month=45, Predicted=2210.1594, Expected=2241.1299
# Month=46, Predicted=2239.1791, Expected=2249.7300
# Month=47, Predicted=2248.4355, Expected=2258.8301
# Month=48, Predicted=2260.5993, Expected=2263.3201
# Month=49, Predicted=2266.4398, Expected=2268.3501
# Month=50, Predicted=2269.8408, Expected=2253.7700
# Month=51, Predicted=2254.8250, Expected=2266.8101
# Month=52, Predicted=2268.5873, Expected=2259.2400
# Month=53, Predicted=2257.2831, Expected=2266.5000
# Month=54, Predicted=2266.5224, Expected=2270.5400
# Month=55, Predicted=2270.1833, Expected=2262.9299
# Month=56, Predicted=2264.0459, Expected=2260.2500
# Month=57, Predicted=2263.1551, Expected=2266.2300
# Month=58, Predicted=2266.5152, Expected=2270.2300
# Month=59, Predicted=2268.9057, Expected=2249.5000
# Month=60, Predicted=2252.1003, Expected=2251.6101
# Run 2 — RMSE: 11.521066, MSE: 132.734956, NMSE: 0.0008053195
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=2156.3312, Expected=2158.2200
# Month=2, Predicted=2159.1811, Expected=2164.1899
# Month=3, Predicted=2163.9890, Expected=2160.3899
# Month=4, Predicted=2160.3255, Expected=2161.3501
# Month=5, Predicted=2161.5862, Expected=2137.6699
# Month=6, Predicted=2139.7099, Expected=2130.2600
# Month=7, Predicted=2133.6790, Expected=2139.6799
# Month=8, Predicted=2140.5093, Expected=2132.9500
# Month=9, Predicted=2133.2521, Expected=2138.3101
# Month=10, Predicted=2138.4506, Expected=2140.8101
# Month=11, Predicted=2140.0040, Expected=2142.5100
# Month=12, Predicted=2141.7342, Expected=2139.4299
# Month=13, Predicted=2138.9749, Expected=2148.5000
# Month=14, Predicted=2147.7777, Expected=2149.7200
# Month=15, Predicted=2148.6787, Expected=2136.9700
# Month=16, Predicted=2137.5850, Expected=2144.0601
# Month=17, Predicted=2144.8060, Expected=2132.2300
# Month=18, Predicted=2133.1206, Expected=2129.7800
# Month=19, Predicted=2131.6861, Expected=2128.6799
# Month=20, Predicted=2129.7840, Expected=2109.4299
# Month=21, Predicted=2111.9372, Expected=2098.8000
# Month=22, Predicted=2102.2549, Expected=2083.7900
# Month=23, Predicted=2087.0123, Expected=2100.5901
# Month=24, Predicted=2101.0310, Expected=2129.9199
# Month=25, Predicted=2127.4781, Expected=2131.5601
# Month=26, Predicted=2128.5931, Expected=2167.4900
# Month=27, Predicted=2164.4481, Expected=2162.7100
# Month=28, Predicted=2159.0461, Expected=2165.6399
# Month=29, Predicted=2164.2861, Expected=2168.2900
# Month=30, Predicted=2167.5497, Expected=2177.5300
# Month=31, Predicted=2177.5015, Expected=2178.6101
# Month=32, Predicted=2179.2240, Expected=2186.8501
# Month=33, Predicted=2188.1112, Expected=2186.4299
# Month=34, Predicted=2187.9168, Expected=2201.5601
# Month=35, Predicted=2202.7417, Expected=2198.5500
# Month=36, Predicted=2199.4140, Expected=2206.2700
# Month=37, Predicted=2207.6241, Expected=2210.2100
# Month=38, Predicted=2210.8164, Expected=2200.7600
# Month=39, Predicted=2202.3833, Expected=2204.9700
# Month=40, Predicted=2206.7474, Expected=2200.1699
# Month=41, Predicted=2201.4515, Expected=2191.1201
# Month=42, Predicted=2193.3701, Expected=2200.6499
# Month=43, Predicted=2201.7115, Expected=2207.2600
# Month=44, Predicted=2206.6955, Expected=2210.7200
# Month=45, Predicted=2210.0118, Expected=2241.1299
# Month=46, Predicted=2239.0545, Expected=2249.7300
# Month=47, Predicted=2246.6570, Expected=2258.8301
# Month=48, Predicted=2256.9511, Expected=2263.3201
# Month=49, Predicted=2262.1669, Expected=2268.3501
# Month=50, Predicted=2268.3084, Expected=2253.7700
# Month=51, Predicted=2255.8199, Expected=2266.8101
# Month=52, Predicted=2269.5095, Expected=2259.2400
# Month=53, Predicted=2261.4383, Expected=2266.5000
# Month=54, Predicted=2269.1677, Expected=2270.5400
# Month=55, Predicted=2271.7988, Expected=2262.9299
# Month=56, Predicted=2264.7417, Expected=2260.2500
# Month=57, Predicted=2262.3602, Expected=2266.2300
# Month=58, Predicted=2267.0300, Expected=2270.2300
# Month=59, Predicted=2270.0266, Expected=2249.5000
# Month=60, Predicted=2250.9096, Expected=2251.6101
# Run 3 — RMSE: 11.494869, MSE: 132.132021, NMSE: 0.0007990882
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=2156.8758, Expected=2158.2200
# Month=2, Predicted=2158.6425, Expected=2164.1899
# Month=3, Predicted=2164.3521, Expected=2160.3899
# Month=4, Predicted=2160.8223, Expected=2161.3501
# Month=5, Predicted=2161.9872, Expected=2137.6699
# Month=6, Predicted=2137.1104, Expected=2130.2600
# Month=7, Predicted=2135.5997, Expected=2139.6799
# Month=8, Predicted=2139.8582, Expected=2132.9500
# Month=9, Predicted=2133.2334, Expected=2138.3101
# Month=10, Predicted=2138.0515, Expected=2140.8101
# Month=11, Predicted=2141.0432, Expected=2142.5100
# Month=12, Predicted=2142.8297, Expected=2139.4299
# Month=13, Predicted=2139.8720, Expected=2148.5000
# Month=14, Predicted=2148.5712, Expected=2149.7200
# Month=15, Predicted=2149.9910, Expected=2136.9700
# Month=16, Predicted=2138.6671, Expected=2144.0601
# Month=17, Predicted=2144.5958, Expected=2132.2300
# Month=18, Predicted=2131.8993, Expected=2129.7800
# Month=19, Predicted=2132.2232, Expected=2128.6799
# Month=20, Predicted=2128.9516, Expected=2109.4299
# Month=21, Predicted=2110.5160, Expected=2098.8000
# Month=22, Predicted=2101.6325, Expected=2083.7900
# Month=23, Predicted=2084.0050, Expected=2100.5901
# Month=24, Predicted=2098.7637, Expected=2129.9199
# Month=25, Predicted=2129.7137, Expected=2131.5601
# Month=26, Predicted=2131.4914, Expected=2167.4900
# Month=27, Predicted=2164.9028, Expected=2162.7100
# Month=28, Predicted=2162.8620, Expected=2165.6399
# Month=29, Predicted=2171.2447, Expected=2168.2900
# Month=30, Predicted=2168.3351, Expected=2177.5300
# Month=31, Predicted=2178.2517, Expected=2178.6101
# Month=32, Predicted=2178.8431, Expected=2186.8501
# Month=33, Predicted=2187.1793, Expected=2186.4299
# Month=34, Predicted=2186.6932, Expected=2201.5601
# Month=35, Predicted=2201.0386, Expected=2198.5500
# Month=36, Predicted=2198.7377, Expected=2206.2700
# Month=37, Predicted=2207.0516, Expected=2210.2100
# Month=38, Predicted=2210.4910, Expected=2200.7600
# Month=39, Predicted=2202.2056, Expected=2204.9700
# Month=40, Predicted=2205.8103, Expected=2200.1699
# Month=41, Predicted=2200.3253, Expected=2191.1201
# Month=42, Predicted=2193.0039, Expected=2200.6499
# Month=43, Predicted=2200.4806, Expected=2207.2600
# Month=44, Predicted=2207.4683, Expected=2210.7200
# Month=45, Predicted=2210.8075, Expected=2241.1299
# Month=46, Predicted=2239.7547, Expected=2249.7300
# Month=47, Predicted=2250.0677, Expected=2258.8301
# Month=48, Predicted=2259.3974, Expected=2263.3201
# Month=49, Predicted=2263.6265, Expected=2268.3501
# Month=50, Predicted=2269.3736, Expected=2253.7700
# Month=51, Predicted=2253.5803, Expected=2266.8101
# Month=52, Predicted=2267.7428, Expected=2259.2400
# Month=53, Predicted=2258.9781, Expected=2266.5000
# Month=54, Predicted=2267.2637, Expected=2270.5400
# Month=55, Predicted=2270.8935, Expected=2262.9299
# Month=56, Predicted=2264.0778, Expected=2260.2500
# Month=57, Predicted=2261.1707, Expected=2266.2300
# Month=58, Predicted=2266.3885, Expected=2270.2300
# Month=59, Predicted=2270.4247, Expected=2249.5000
# Month=60, Predicted=2250.0491, Expected=2251.6101
# Run 4 — RMSE: 11.308605, MSE: 127.884558, NMSE: 0.0007771977
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=2155.6529, Expected=2158.2200
# Month=2, Predicted=2158.4636, Expected=2164.1899
# Month=3, Predicted=2164.2812, Expected=2160.3899
# Month=4, Predicted=2160.7229, Expected=2161.3501
# Month=5, Predicted=2161.6889, Expected=2137.6699
# Month=6, Predicted=2138.5041, Expected=2130.2600
# Month=7, Predicted=2130.8237, Expected=2139.6799
# Month=8, Predicted=2139.5802, Expected=2132.9500
# Month=9, Predicted=2133.0078, Expected=2138.3101
# Month=10, Predicted=2138.3866, Expected=2140.8101
# Month=11, Predicted=2140.9124, Expected=2142.5100
# Month=12, Predicted=2142.7186, Expected=2139.4299
# Month=13, Predicted=2139.7751, Expected=2148.5000
# Month=14, Predicted=2148.6092, Expected=2149.7200
# Month=15, Predicted=2149.9282, Expected=2136.9700
# Month=16, Predicted=2137.6007, Expected=2144.0601
# Month=17, Predicted=2144.2381, Expected=2132.2300
# Month=18, Predicted=2132.5880, Expected=2129.7800
# Month=19, Predicted=2130.0760, Expected=2128.6799
# Month=20, Predicted=2128.7937, Expected=2109.4299
# Month=21, Predicted=2109.9577, Expected=2098.8000
# Month=22, Predicted=2099.2571, Expected=2083.7900
# Month=23, Predicted=2084.0527, Expected=2100.5901
# Month=24, Predicted=2100.5462, Expected=2129.9199
# Month=25, Predicted=2130.1188, Expected=2131.5601
# Month=26, Predicted=2131.7357, Expected=2167.4900
# Month=27, Predicted=2167.4873, Expected=2162.7100
# Month=28, Predicted=2163.3338, Expected=2165.6399
# Month=29, Predicted=2166.3803, Expected=2168.2900
# Month=30, Predicted=2168.7882, Expected=2177.5300
# Month=31, Predicted=2177.7888, Expected=2178.6101
# Month=32, Predicted=2179.0084, Expected=2186.8501
# Month=33, Predicted=2187.1892, Expected=2186.4299
# Month=34, Predicted=2186.9284, Expected=2201.5601
# Month=35, Predicted=2201.8206, Expected=2198.5500
# Month=36, Predicted=2199.1419, Expected=2206.2700
# Month=37, Predicted=2206.7835, Expected=2210.2100
# Month=38, Predicted=2210.7171, Expected=2200.7600
# Month=39, Predicted=2201.5698, Expected=2204.9700
# Month=40, Predicted=2205.4818, Expected=2200.1699
# Month=41, Predicted=2200.6825, Expected=2191.1201
# Month=42, Predicted=2191.7676, Expected=2200.6499
# Month=43, Predicted=2200.8295, Expected=2207.2600
# Month=44, Predicted=2207.4337, Expected=2210.7200
# Month=45, Predicted=2211.1238, Expected=2241.1299
# Month=46, Predicted=2241.2308, Expected=2249.7300
# Month=47, Predicted=2250.3399, Expected=2258.8301
# Month=48, Predicted=2259.6933, Expected=2263.3201
# Month=49, Predicted=2264.2386, Expected=2268.3501
# Month=50, Predicted=2269.1968, Expected=2253.7700
# Month=51, Predicted=2254.8823, Expected=2266.8101
# Month=52, Predicted=2267.2772, Expected=2259.2400
# Month=53, Predicted=2259.8665, Expected=2266.5000
# Month=54, Predicted=2266.9640, Expected=2270.5400
# Month=55, Predicted=2270.9980, Expected=2262.9299
# Month=56, Predicted=2263.6993, Expected=2260.2500
# Month=57, Predicted=2260.9570, Expected=2266.2300
# Month=58, Predicted=2266.5976, Expected=2270.2300
# Month=59, Predicted=2270.6070, Expected=2249.5000
# Month=60, Predicted=2250.4254, Expected=2251.6101
# Run 5 — RMSE: 11.125776, MSE: 123.782898, NMSE: 0.0007453938
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=2154.2954, Expected=2158.2200
# Month=2, Predicted=2156.9262, Expected=2164.1899
# Month=3, Predicted=2161.3617, Expected=2160.3899
# Month=4, Predicted=2158.1183, Expected=2161.3501
# Month=5, Predicted=2159.8496, Expected=2137.6699
# Month=6, Predicted=2138.8904, Expected=2130.2600
# Month=7, Predicted=2131.9433, Expected=2139.6799
# Month=8, Predicted=2137.5155, Expected=2132.9500
# Month=9, Predicted=2130.2896, Expected=2138.3101
# Month=10, Predicted=2136.6068, Expected=2140.8101
# Month=11, Predicted=2138.4927, Expected=2142.5100
# Month=12, Predicted=2140.4326, Expected=2139.4299
# Month=13, Predicted=2137.9512, Expected=2148.5000
# Month=14, Predicted=2146.1614, Expected=2149.7200
# Month=15, Predicted=2146.7887, Expected=2136.9700
# Month=16, Predicted=2136.5054, Expected=2144.0601
# Month=17, Predicted=2142.8632, Expected=2132.2300
# Month=18, Predicted=2130.8091, Expected=2129.7800
# Month=19, Predicted=2129.3058, Expected=2128.6799
# Month=20, Predicted=2127.1628, Expected=2109.4299
# Month=21, Predicted=2109.8679, Expected=2098.8000
# Month=22, Predicted=2100.4573, Expected=2083.7900
# Month=23, Predicted=2084.9140, Expected=2100.5901
# Month=24, Predicted=2098.4991, Expected=2129.9199
# Month=25, Predicted=2124.7248, Expected=2131.5601
# Month=26, Predicted=2126.5847, Expected=2167.4900
# Month=27, Predicted=2163.2123, Expected=2162.7100
# Month=28, Predicted=2158.6571, Expected=2165.6399
# Month=29, Predicted=2164.8415, Expected=2168.2900
# Month=30, Predicted=2166.4417, Expected=2177.5300
# Month=31, Predicted=2174.4122, Expected=2178.6101
# Month=32, Predicted=2175.4189, Expected=2186.8501
# Month=33, Predicted=2183.8912, Expected=2186.4299
# Month=34, Predicted=2183.7069, Expected=2201.5601
# Month=35, Predicted=2198.1694, Expected=2198.5500
# Month=36, Predicted=2195.2665, Expected=2206.2700
# Month=37, Predicted=2203.7628, Expected=2210.2100
# Month=38, Predicted=2207.0992, Expected=2200.7600
# Month=39, Predicted=2199.3296, Expected=2204.9700
# Month=40, Predicted=2203.4239, Expected=2200.1699
# Month=41, Predicted=2198.0784, Expected=2191.1201
# Month=42, Predicted=2190.4403, Expected=2200.6499
# Month=43, Predicted=2198.4794, Expected=2207.2600
# Month=44, Predicted=2203.5427, Expected=2210.7200
# Month=45, Predicted=2207.5724, Expected=2241.1299
# Month=46, Predicted=2236.5136, Expected=2249.7300
# Month=47, Predicted=2244.2267, Expected=2258.8301
# Month=48, Predicted=2255.3415, Expected=2263.3201
# Month=49, Predicted=2260.4744, Expected=2268.3501
# Month=50, Predicted=2265.5452, Expected=2253.7700
# Month=51, Predicted=2252.8864, Expected=2266.8101
# Month=52, Predicted=2264.6295, Expected=2259.2400
# Month=53, Predicted=2256.2934, Expected=2266.5000
# Month=54, Predicted=2264.1824, Expected=2270.5400
# Month=55, Predicted=2267.3616, Expected=2262.9299
# Month=56, Predicted=2261.2462, Expected=2260.2500
# Month=57, Predicted=2259.4199, Expected=2266.2300
# Month=58, Predicted=2263.8422, Expected=2270.2300
# Month=59, Predicted=2266.9999, Expected=2249.5000
# Month=60, Predicted=2249.4550, Expected=2251.6101
# Run 6 — RMSE: 11.995854, MSE: 143.900505, NMSE: 0.0008852008
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=2156.6267, Expected=2158.2200
# Month=2, Predicted=2157.8977, Expected=2164.1899
# Month=3, Predicted=2162.8802, Expected=2160.3899
# Month=4, Predicted=2159.6231, Expected=2161.3501
# Month=5, Predicted=2161.6477, Expected=2137.6699
# Month=6, Predicted=2137.7795, Expected=2130.2600
# Month=7, Predicted=2135.9000, Expected=2139.6799
# Month=8, Predicted=2138.6200, Expected=2132.9500
# Month=9, Predicted=2131.0971, Expected=2138.3101
# Month=10, Predicted=2138.3957, Expected=2140.8101
# Month=11, Predicted=2139.3110, Expected=2142.5100
# Month=12, Predicted=2142.2612, Expected=2139.4299
# Month=13, Predicted=2138.8461, Expected=2148.5000
# Month=14, Predicted=2148.1395, Expected=2149.7200
# Month=15, Predicted=2148.3745, Expected=2136.9700
# Month=16, Predicted=2138.6430, Expected=2144.0601
# Month=17, Predicted=2144.5985, Expected=2132.2300
# Month=18, Predicted=2130.2861, Expected=2129.7800
# Month=19, Predicted=2132.4725, Expected=2128.6799
# Month=20, Predicted=2126.9849, Expected=2109.4299
# Month=21, Predicted=2109.9524, Expected=2098.8000
# Month=22, Predicted=2101.7281, Expected=2083.7900
# Month=23, Predicted=2082.2607, Expected=2100.5901
# Month=24, Predicted=2099.6279, Expected=2129.9199
# Month=25, Predicted=2132.7040, Expected=2131.5601
# Month=26, Predicted=2130.3467, Expected=2167.4900
# Month=27, Predicted=2167.4349, Expected=2162.7100
# Month=28, Predicted=2161.1977, Expected=2165.6399
# Month=29, Predicted=2173.2421, Expected=2168.2900
# Month=30, Predicted=2167.2287, Expected=2177.5300
# Month=31, Predicted=2177.8645, Expected=2178.6101
# Month=32, Predicted=2177.6093, Expected=2186.8501
# Month=33, Predicted=2187.2051, Expected=2186.4299
# Month=34, Predicted=2185.3830, Expected=2201.5601
# Month=35, Predicted=2201.4971, Expected=2198.5500
# Month=36, Predicted=2197.0422, Expected=2206.2700
# Month=37, Predicted=2208.0257, Expected=2210.2100
# Month=38, Predicted=2208.9082, Expected=2200.7600
# Month=39, Predicted=2202.0186, Expected=2204.9700
# Month=40, Predicted=2205.7848, Expected=2200.1699
# Month=41, Predicted=2198.6429, Expected=2191.1201
# Month=42, Predicted=2192.7039, Expected=2200.6499
# Month=43, Predicted=2199.7516, Expected=2207.2600
# Month=44, Predicted=2205.9430, Expected=2210.7200
# Month=45, Predicted=2210.1950, Expected=2241.1299
# Month=46, Predicted=2240.8579, Expected=2249.7300
# Month=47, Predicted=2248.6848, Expected=2258.8301
# Month=48, Predicted=2260.7005, Expected=2263.3201
# Month=49, Predicted=2262.8311, Expected=2268.3501
# Month=50, Predicted=2269.2874, Expected=2253.7700
# Month=51, Predicted=2254.6497, Expected=2266.8101
# Month=52, Predicted=2268.5540, Expected=2259.2400
# Month=53, Predicted=2257.0821, Expected=2266.5000
# Month=54, Predicted=2268.4746, Expected=2270.5400
# Month=55, Predicted=2269.0541, Expected=2262.9299
# Month=56, Predicted=2263.6125, Expected=2260.2500
# Month=57, Predicted=2261.0350, Expected=2266.2300
# Month=58, Predicted=2265.1256, Expected=2270.2300
# Month=59, Predicted=2268.9767, Expected=2249.5000
# Month=60, Predicted=2250.1947, Expected=2251.6101
# Run 7 — RMSE: 11.379449, MSE: 129.491862, NMSE: 0.0007847552
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=2150.6380, Expected=2158.2200
# Month=2, Predicted=2154.6864, Expected=2164.1899
# Month=3, Predicted=2157.5507, Expected=2160.3899
# Month=4, Predicted=2155.9357, Expected=2161.3501
# Month=5, Predicted=2162.2350, Expected=2137.6699
# Month=6, Predicted=2141.2279, Expected=2130.2600
# Month=7, Predicted=2133.7501, Expected=2139.6799
# Month=8, Predicted=2139.2258, Expected=2132.9500
# Month=9, Predicted=2128.9231, Expected=2138.3101
# Month=10, Predicted=2136.3180, Expected=2140.8101
# Month=11, Predicted=2137.4015, Expected=2142.5100
# Month=12, Predicted=2139.1804, Expected=2139.4299
# Month=13, Predicted=2137.8042, Expected=2148.5000
# Month=14, Predicted=2149.0146, Expected=2149.7200
# Month=15, Predicted=2151.0271, Expected=2136.9700
# Month=16, Predicted=2138.1934, Expected=2144.0601
# Month=17, Predicted=2144.3113, Expected=2132.2300
# Month=18, Predicted=2126.8776, Expected=2129.7800
# Month=19, Predicted=2126.3781, Expected=2128.6799
# Month=20, Predicted=2124.2654, Expected=2109.4299
# Month=21, Predicted=2106.2486, Expected=2098.8000
# Month=22, Predicted=2099.4477, Expected=2083.7900
# Month=23, Predicted=2082.2019, Expected=2100.5901
# Month=24, Predicted=2100.4568, Expected=2129.9199
# Month=25, Predicted=2132.5605, Expected=2131.5601
# Month=26, Predicted=2136.6549, Expected=2167.4900
# Month=27, Predicted=2171.9350, Expected=2162.7100
# Month=28, Predicted=2164.4027, Expected=2165.6399
# Month=29, Predicted=2165.4680, Expected=2168.2900
# Month=30, Predicted=2164.2143, Expected=2177.5300
# Month=31, Predicted=2170.9704, Expected=2178.6101
# Month=32, Predicted=2173.9400, Expected=2186.8501
# Month=33, Predicted=2187.6571, Expected=2186.4299
# Month=34, Predicted=2191.4774, Expected=2201.5601
# Month=35, Predicted=2208.2892, Expected=2198.5500
# Month=36, Predicted=2203.1278, Expected=2206.2700
# Month=37, Predicted=2207.4550, Expected=2210.2100
# Month=38, Predicted=2206.7483, Expected=2200.7600
# Month=39, Predicted=2195.7230, Expected=2204.9700
# Month=40, Predicted=2201.7290, Expected=2200.1699
# Month=41, Predicted=2195.0142, Expected=2191.1201
# Month=42, Predicted=2190.5249, Expected=2200.6499
# Month=43, Predicted=2204.4508, Expected=2207.2600
# Month=44, Predicted=2213.3658, Expected=2210.7200
# Month=45, Predicted=2215.9601, Expected=2241.1299
# Month=46, Predicted=2244.4341, Expected=2249.7300
# Month=47, Predicted=2249.6490, Expected=2258.8301
# Month=48, Predicted=2257.4789, Expected=2263.3201
# Month=49, Predicted=2260.4037, Expected=2268.3501
# Month=50, Predicted=2264.1769, Expected=2253.7700
# Month=51, Predicted=2250.2448, Expected=2266.8101
# Month=52, Predicted=2267.0352, Expected=2259.2400
# Month=53, Predicted=2260.7541, Expected=2266.5000
# Month=54, Predicted=2270.3897, Expected=2270.5400
# Month=55, Predicted=2273.9032, Expected=2262.9299
# Month=56, Predicted=2263.5553, Expected=2260.2500
# Month=57, Predicted=2259.1692, Expected=2266.2300
# Month=58, Predicted=2261.4000, Expected=2270.2300
# Month=59, Predicted=2264.1838, Expected=2249.5000
# Month=60, Predicted=2247.0029, Expected=2251.6101
# Run 8 — RMSE: 10.868669, MSE: 118.127972, NMSE: 0.0007071999
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=2157.3024, Expected=2158.2200
# Month=2, Predicted=2158.4679, Expected=2164.1899
# Month=3, Predicted=2163.0514, Expected=2160.3899
# Month=4, Predicted=2161.6224, Expected=2161.3501
# Month=5, Predicted=2163.1249, Expected=2137.6699
# Month=6, Predicted=2144.3915, Expected=2130.2600
# Month=7, Predicted=2137.7058, Expected=2139.6799
# Month=8, Predicted=2137.3013, Expected=2132.9500
# Month=9, Predicted=2134.4273, Expected=2138.3101
# Month=10, Predicted=2139.9895, Expected=2140.8101
# Month=11, Predicted=2142.9661, Expected=2142.5100
# Month=12, Predicted=2144.6197, Expected=2139.4299
# Month=13, Predicted=2142.5268, Expected=2148.5000
# Month=14, Predicted=2148.3257, Expected=2149.7200
# Month=15, Predicted=2150.5341, Expected=2136.9700
# Month=16, Predicted=2142.5520, Expected=2144.0601
# Month=17, Predicted=2146.3238, Expected=2132.2300
# Month=18, Predicted=2136.9984, Expected=2129.7800
# Month=19, Predicted=2134.6489, Expected=2128.6799
# Month=20, Predicted=2132.2645, Expected=2109.4299
# Month=21, Predicted=2118.4960, Expected=2098.8000
# Month=22, Predicted=2110.3608, Expected=2083.7900
# Month=23, Predicted=2095.3795, Expected=2100.5901
# Month=24, Predicted=2098.1111, Expected=2129.9199
# Month=25, Predicted=2127.0115, Expected=2131.5601
# Month=26, Predicted=2132.0317, Expected=2167.4900
# Month=27, Predicted=2165.6125, Expected=2162.7100
# Month=28, Predicted=2162.4482, Expected=2165.6399
# Month=29, Predicted=2166.9167, Expected=2168.2900
# Month=30, Predicted=2168.3245, Expected=2177.5300
# Month=31, Predicted=2175.9756, Expected=2178.6101
# Month=32, Predicted=2178.0786, Expected=2186.8501
# Month=33, Predicted=2186.0706, Expected=2186.4299
# Month=34, Predicted=2187.0008, Expected=2201.5601
# Month=35, Predicted=2199.7604, Expected=2198.5500
# Month=36, Predicted=2198.2733, Expected=2206.2700
# Month=37, Predicted=2205.3729, Expected=2210.2100
# Month=38, Predicted=2209.4156, Expected=2200.7600
# Month=39, Predicted=2202.0884, Expected=2204.9700
# Month=40, Predicted=2204.8442, Expected=2200.1699
# Month=41, Predicted=2200.6645, Expected=2191.1201
# Month=42, Predicted=2193.6700, Expected=2200.6499
# Month=43, Predicted=2199.1180, Expected=2207.2600
# Month=44, Predicted=2205.7285, Expected=2210.7200
# Month=45, Predicted=2210.2866, Expected=2241.1299
# Month=46, Predicted=2240.3907, Expected=2249.7300
# Month=47, Predicted=2248.7969, Expected=2258.8301
# Month=48, Predicted=2257.9073, Expected=2263.3201
# Month=49, Predicted=2262.4968, Expected=2268.3501
# Month=50, Predicted=2267.3752, Expected=2253.7700
# Month=51, Predicted=2253.8982, Expected=2266.8101
# Month=52, Predicted=2264.8731, Expected=2259.2400
# Month=53, Predicted=2258.6799, Expected=2266.5000
# Month=54, Predicted=2265.0308, Expected=2270.5400
# Month=55, Predicted=2269.3711, Expected=2262.9299
# Month=56, Predicted=2263.3533, Expected=2260.2500
# Month=57, Predicted=2260.8122, Expected=2266.2300
# Month=58, Predicted=2264.7248, Expected=2270.2300
# Month=59, Predicted=2268.8645, Expected=2249.5000
# Month=60, Predicted=2251.7575, Expected=2251.6101
# Run 9 — RMSE: 11.822558, MSE: 139.772884, NMSE: 0.0009047091
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=2156.4862, Expected=2158.2200
# Month=2, Predicted=2159.2386, Expected=2164.1899
# Month=3, Predicted=2164.0398, Expected=2160.3899
# Month=4, Predicted=2161.0135, Expected=2161.3501
# Month=5, Predicted=2162.6264, Expected=2137.6699
# Month=6, Predicted=2139.5511, Expected=2130.2600
# Month=7, Predicted=2132.8353, Expected=2139.6799
# Month=8, Predicted=2139.1473, Expected=2132.9500
# Month=9, Predicted=2132.6480, Expected=2138.3101
# Month=10, Predicted=2139.5833, Expected=2140.8101
# Month=11, Predicted=2141.2756, Expected=2142.5100
# Month=12, Predicted=2143.3668, Expected=2139.4299
# Month=13, Predicted=2140.5422, Expected=2148.5000
# Month=14, Predicted=2149.0488, Expected=2149.7200
# Month=15, Predicted=2149.7628, Expected=2136.9700
# Month=16, Predicted=2138.8527, Expected=2144.0601
# Month=17, Predicted=2145.2754, Expected=2132.2300
# Month=18, Predicted=2132.2263, Expected=2129.7800
# Month=19, Predicted=2131.4229, Expected=2128.6799
# Month=20, Predicted=2129.1482, Expected=2109.4299
# Month=21, Predicted=2110.9976, Expected=2098.8000
# Month=22, Predicted=2101.4237, Expected=2083.7900
# Month=23, Predicted=2084.8757, Expected=2100.5901
# Month=24, Predicted=2100.6006, Expected=2129.9199
# Month=25, Predicted=2128.5477, Expected=2131.5601
# Month=26, Predicted=2131.7402, Expected=2167.4900
# Month=27, Predicted=2166.8601, Expected=2162.7100
# Month=28, Predicted=2162.4087, Expected=2165.6399
# Month=29, Predicted=2167.6646, Expected=2168.2900
# Month=30, Predicted=2168.7937, Expected=2177.5300
# Month=31, Predicted=2177.3812, Expected=2178.6101
# Month=32, Predicted=2178.6212, Expected=2186.8501
# Month=33, Predicted=2187.2917, Expected=2186.4299
# Month=34, Predicted=2186.8348, Expected=2201.5601
# Month=35, Predicted=2201.6479, Expected=2198.5500
# Month=36, Predicted=2198.5316, Expected=2206.2700
# Month=37, Predicted=2207.0717, Expected=2210.2100
# Month=38, Predicted=2210.2669, Expected=2200.7600
# Month=39, Predicted=2201.9181, Expected=2204.9700
# Month=40, Predicted=2206.0078, Expected=2200.1699
# Month=41, Predicted=2200.2045, Expected=2191.1201
# Month=42, Predicted=2192.4851, Expected=2200.6499
# Month=43, Predicted=2201.0625, Expected=2207.2600
# Month=44, Predicted=2206.6529, Expected=2210.7200
# Month=45, Predicted=2211.2021, Expected=2241.1299
# Month=46, Predicted=2240.4872, Expected=2249.7300
# Month=47, Predicted=2248.9711, Expected=2258.8301
# Month=48, Predicted=2259.5561, Expected=2263.3201
# Month=49, Predicted=2264.0360, Expected=2268.3501
# Month=50, Predicted=2268.8323, Expected=2253.7700
# Month=51, Predicted=2254.9153, Expected=2266.8101
# Month=52, Predicted=2267.3397, Expected=2259.2400
# Month=53, Predicted=2258.4504, Expected=2266.5000
# Month=54, Predicted=2267.2299, Expected=2270.5400
# Month=55, Predicted=2270.4598, Expected=2262.9299
# Month=56, Predicted=2264.0352, Expected=2260.2500
# Month=57, Predicted=2261.7665, Expected=2266.2300
# Month=58, Predicted=2266.3578, Expected=2270.2300
# Month=59, Predicted=2270.0416, Expected=2249.5000
# Month=60, Predicted=2251.3944, Expected=2251.6101
# Run 10 — RMSE: 11.197904, MSE: 125.393053, NMSE: 0.0007642491
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=2155.6054, Expected=2158.2200
# Month=2, Predicted=2158.6490, Expected=2164.1899
# Month=3, Predicted=2164.5762, Expected=2160.3899
# Month=4, Predicted=2160.8087, Expected=2161.3501
# Month=5, Predicted=2161.7708, Expected=2137.6699
# Month=6, Predicted=2138.2179, Expected=2130.2600
# Month=7, Predicted=2130.8341, Expected=2139.6799
# Month=8, Predicted=2140.1058, Expected=2132.9500
# Month=9, Predicted=2133.4128, Expected=2138.3101
# Month=10, Predicted=2138.7710, Expected=2140.8101
# Month=11, Predicted=2141.2361, Expected=2142.5100
# Month=12, Predicted=2142.9394, Expected=2139.4299
# Month=13, Predicted=2139.8765, Expected=2148.5000
# Month=14, Predicted=2148.9024, Expected=2149.7200
# Month=15, Predicted=2150.1152, Expected=2136.9700
# Month=16, Predicted=2137.4478, Expected=2144.0601
# Month=17, Predicted=2144.4892, Expected=2132.2300
# Month=18, Predicted=2132.6921, Expected=2129.7800
# Month=19, Predicted=2130.2606, Expected=2128.6799
# Month=20, Predicted=2129.1272, Expected=2109.4299
# Month=21, Predicted=2109.9874, Expected=2098.8000
# Month=22, Predicted=2099.4121, Expected=2083.7900
# Month=23, Predicted=2084.4044, Expected=2100.5901
# Month=24, Predicted=2101.0807, Expected=2129.9199
# Month=25, Predicted=2130.2648, Expected=2131.5601
# Month=26, Predicted=2131.9572, Expected=2167.4900
# Month=27, Predicted=2167.8718, Expected=2162.7100
# Month=28, Predicted=2163.0997, Expected=2165.6399
# Month=29, Predicted=2166.0071, Expected=2168.2900
# Month=30, Predicted=2168.6482, Expected=2177.5300
# Month=31, Predicted=2177.8698, Expected=2178.6101
# Month=32, Predicted=2178.9615, Expected=2186.8501
# Month=33, Predicted=2187.1928, Expected=2186.4299
# Month=34, Predicted=2186.7866, Expected=2201.5601
# Month=35, Predicted=2201.8968, Expected=2198.5500
# Month=36, Predicted=2198.9089, Expected=2206.2700
# Month=37, Predicted=2206.6135, Expected=2210.2100
# Month=38, Predicted=2210.5534, Expected=2200.7600
# Month=39, Predicted=2201.1498, Expected=2204.9700
# Month=40, Predicted=2205.3402, Expected=2200.1699
# Month=41, Predicted=2200.5546, Expected=2191.1201
# Month=42, Predicted=2191.5494, Expected=2200.6499
# Month=43, Predicted=2201.0302, Expected=2207.2600
# Month=44, Predicted=2207.6162, Expected=2210.7200
# Month=45, Predicted=2211.0880, Expected=2241.1299
# Month=46, Predicted=2241.4867, Expected=2249.7300
# Month=47, Predicted=2250.0748, Expected=2258.8301
# Month=48, Predicted=2259.1597, Expected=2263.3201
# Month=49, Predicted=2263.6545, Expected=2268.3501
# Month=50, Predicted=2268.6811, Expected=2253.7700
# Month=51, Predicted=2254.1643, Expected=2266.8101
# Month=52, Predicted=2267.1588, Expected=2259.2400
# Month=53, Predicted=2259.6140, Expected=2266.5000
# Month=54, Predicted=2266.8558, Expected=2270.5400
# Month=55, Predicted=2270.8910, Expected=2262.9299
# Month=56, Predicted=2263.3249, Expected=2260.2500
# Month=57, Predicted=2260.6537, Expected=2266.2300
# Month=58, Predicted=2266.5998, Expected=2270.2300
# Month=59, Predicted=2270.5933, Expected=2249.5000
# Month=60, Predicted=2249.9866, Expected=2251.6101
# Run 11 — RMSE: 11.128615, MSE: 123.846070, NMSE: 0.0007510295
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=2157.3254, Expected=2158.2200
# Month=2, Predicted=2164.4283, Expected=2164.1899
# Month=3, Predicted=2164.3412, Expected=2160.3899
# Month=4, Predicted=2156.8129, Expected=2161.3501
# Month=5, Predicted=2168.5319, Expected=2137.6699
# Month=6, Predicted=2137.3216, Expected=2130.2600
# Month=7, Predicted=2127.4836, Expected=2139.6799
# Month=8, Predicted=2137.6164, Expected=2132.9500
# Month=9, Predicted=2131.1605, Expected=2138.3101
# Month=10, Predicted=2139.3946, Expected=2140.8101
# Month=11, Predicted=2138.6437, Expected=2142.5100
# Month=12, Predicted=2140.0208, Expected=2139.4299
# Month=13, Predicted=2140.9317, Expected=2148.5000
# Month=14, Predicted=2147.3363, Expected=2149.7200
# Month=15, Predicted=2146.9203, Expected=2136.9700
# Month=16, Predicted=2138.9738, Expected=2144.0601
# Month=17, Predicted=2145.0420, Expected=2132.2300
# Month=18, Predicted=2128.1355, Expected=2129.7800
# Month=19, Predicted=2129.9557, Expected=2128.6799
# Month=20, Predicted=2129.4538, Expected=2109.4299
# Month=21, Predicted=2105.9355, Expected=2098.8000
# Month=22, Predicted=2099.6279, Expected=2083.7900
# Month=23, Predicted=2082.8228, Expected=2100.5901
# Month=24, Predicted=2099.9441, Expected=2129.9199
# Month=25, Predicted=2130.4624, Expected=2131.5601
# Month=26, Predicted=2130.6072, Expected=2167.4900
# Month=27, Predicted=2168.1063, Expected=2162.7100
# Month=28, Predicted=2159.7269, Expected=2165.6399
# Month=29, Predicted=2166.4860, Expected=2168.2900
# Month=30, Predicted=2168.4652, Expected=2177.5300
# Month=31, Predicted=2176.4478, Expected=2178.6101
# Month=32, Predicted=2176.3121, Expected=2186.8501
# Month=33, Predicted=2188.0236, Expected=2186.4299
# Month=34, Predicted=2184.6721, Expected=2201.5601
# Month=35, Predicted=2200.4614, Expected=2198.5500
# Month=36, Predicted=2196.8240, Expected=2206.2700
# Month=37, Predicted=2207.1745, Expected=2210.2100
# Month=38, Predicted=2208.5316, Expected=2200.7600
# Month=39, Predicted=2198.3261, Expected=2204.9700
# Month=40, Predicted=2206.8767, Expected=2200.1699
# Month=41, Predicted=2197.7323, Expected=2191.1201
# Month=42, Predicted=2188.8257, Expected=2200.6499
# Month=43, Predicted=2200.2144, Expected=2207.2600
# Month=44, Predicted=2205.4159, Expected=2210.7200
# Month=45, Predicted=2208.7942, Expected=2241.1299
# Month=46, Predicted=2241.3022, Expected=2249.7300
# Month=47, Predicted=2247.7582, Expected=2258.8301
# Month=48, Predicted=2258.6226, Expected=2263.3201
# Month=49, Predicted=2262.9427, Expected=2268.3501
# Month=50, Predicted=2266.6669, Expected=2253.7700
# Month=51, Predicted=2252.2052, Expected=2266.8101
# Month=52, Predicted=2267.2754, Expected=2259.2400
# Month=53, Predicted=2256.0191, Expected=2266.5000
# Month=54, Predicted=2265.5255, Expected=2270.5400
# Month=55, Predicted=2269.5414, Expected=2262.9299
# Month=56, Predicted=2261.0358, Expected=2260.2500
# Month=57, Predicted=2259.6986, Expected=2266.2300
# Month=58, Predicted=2264.5313, Expected=2270.2300
# Month=59, Predicted=2267.9015, Expected=2249.5000
# Month=60, Predicted=2251.3138, Expected=2251.6101
# Run 12 — RMSE: 11.766405, MSE: 138.448276, NMSE: 0.0008429712
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=2154.6820, Expected=2158.2200
# Month=2, Predicted=2158.2613, Expected=2164.1899
# Month=3, Predicted=2163.4782, Expected=2160.3899
# Month=4, Predicted=2159.3150, Expected=2161.3501
# Month=5, Predicted=2160.8416, Expected=2137.6699
# Month=6, Predicted=2137.8453, Expected=2130.2600
# Month=7, Predicted=2132.2674, Expected=2139.6799
# Month=8, Predicted=2140.4809, Expected=2132.9500
# Month=9, Predicted=2132.2835, Expected=2138.3101
# Month=10, Predicted=2138.0404, Expected=2140.8101
# Month=11, Predicted=2139.9971, Expected=2142.5100
# Month=12, Predicted=2141.6248, Expected=2139.4299
# Month=13, Predicted=2138.6798, Expected=2148.5000
# Month=14, Predicted=2147.8276, Expected=2149.7200
# Month=15, Predicted=2148.2939, Expected=2136.9700
# Month=16, Predicted=2136.1351, Expected=2144.0601
# Month=17, Predicted=2144.1306, Expected=2132.2300
# Month=18, Predicted=2131.6475, Expected=2129.7800
# Month=19, Predicted=2130.0969, Expected=2128.6799
# Month=20, Predicted=2128.7056, Expected=2109.4299
# Month=21, Predicted=2109.7991, Expected=2098.8000
# Month=22, Predicted=2100.6570, Expected=2083.7900
# Month=23, Predicted=2085.8819, Expected=2100.5901
# Month=24, Predicted=2101.5725, Expected=2129.9199
# Month=25, Predicted=2128.0683, Expected=2131.5601
# Month=26, Predicted=2128.1936, Expected=2167.4900
# Month=27, Predicted=2165.4772, Expected=2162.7100
# Month=28, Predicted=2159.1761, Expected=2165.6399
# Month=29, Predicted=2164.0537, Expected=2168.2900
# Month=30, Predicted=2166.9990, Expected=2177.5300
# Month=31, Predicted=2176.1069, Expected=2178.6101
# Month=32, Predicted=2176.7639, Expected=2186.8501
# Month=33, Predicted=2185.3879, Expected=2186.4299
# Month=34, Predicted=2184.8348, Expected=2201.5601
# Month=35, Predicted=2200.2882, Expected=2198.5500
# Month=36, Predicted=2196.5810, Expected=2206.2700
# Month=37, Predicted=2205.1692, Expected=2210.2100
# Month=38, Predicted=2208.8060, Expected=2200.7600
# Month=39, Predicted=2199.7430, Expected=2204.9700
# Month=40, Predicted=2204.8981, Expected=2200.1699
# Month=41, Predicted=2199.6872, Expected=2191.1201
# Month=42, Predicted=2191.2790, Expected=2200.6499
# Month=43, Predicted=2200.8896, Expected=2207.2600
# Month=44, Predicted=2206.1479, Expected=2210.7200
# Month=45, Predicted=2209.2919, Expected=2241.1299
# Month=46, Predicted=2239.4634, Expected=2249.7300
# Month=47, Predicted=2246.3815, Expected=2258.8301
# Month=48, Predicted=2256.2846, Expected=2263.3201
# Month=49, Predicted=2261.1759, Expected=2268.3501
# Month=50, Predicted=2266.5966, Expected=2253.7700
# Month=51, Predicted=2252.4451, Expected=2266.8101
# Month=52, Predicted=2266.5993, Expected=2259.2400
# Month=53, Predicted=2257.9136, Expected=2266.5000
# Month=54, Predicted=2265.9145, Expected=2270.5400
# Month=55, Predicted=2269.3471, Expected=2262.9299
# Month=56, Predicted=2261.9688, Expected=2260.2500
# Month=57, Predicted=2260.2903, Expected=2266.2300
# Month=58, Predicted=2266.0480, Expected=2270.2300
# Month=59, Predicted=2269.2275, Expected=2249.5000
# Month=60, Predicted=2248.9864, Expected=2251.6101
# Run 13 — RMSE: 11.567722, MSE: 133.812189, NMSE: 0.0008225167
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=2156.3349, Expected=2158.2200
# Month=2, Predicted=2158.3066, Expected=2164.1899
# Month=3, Predicted=2162.1303, Expected=2160.3899
# Month=4, Predicted=2159.9758, Expected=2161.3501
# Month=5, Predicted=2161.9176, Expected=2137.6699
# Month=6, Predicted=2141.3816, Expected=2130.2600
# Month=7, Predicted=2135.8422, Expected=2139.6799
# Month=8, Predicted=2136.2331, Expected=2132.9500
# Month=9, Predicted=2131.7174, Expected=2138.3101
# Month=10, Predicted=2139.3649, Expected=2140.8101
# Month=11, Predicted=2139.7279, Expected=2142.5100
# Month=12, Predicted=2142.5347, Expected=2139.4299
# Month=13, Predicted=2140.5129, Expected=2148.5000
# Month=14, Predicted=2147.7963, Expected=2149.7200
# Month=15, Predicted=2148.4708, Expected=2136.9700
# Month=16, Predicted=2140.3250, Expected=2144.0601
# Month=17, Predicted=2144.9335, Expected=2132.2300
# Month=18, Predicted=2132.4328, Expected=2129.7800
# Month=19, Predicted=2132.9281, Expected=2128.6799
# Month=20, Predicted=2128.6426, Expected=2109.4299
# Month=21, Predicted=2114.3129, Expected=2098.8000
# Month=22, Predicted=2106.7542, Expected=2083.7900
# Month=23, Predicted=2089.5988, Expected=2100.5901
# Month=24, Predicted=2098.1974, Expected=2129.9199
# Month=25, Predicted=2126.7971, Expected=2131.5601
# Month=26, Predicted=2130.3174, Expected=2167.4900
# Month=27, Predicted=2168.2233, Expected=2162.7100
# Month=28, Predicted=2161.5110, Expected=2165.6399
# Month=29, Predicted=2168.5356, Expected=2168.2900
# Month=30, Predicted=2167.7713, Expected=2177.5300
# Month=31, Predicted=2176.2888, Expected=2178.6101
# Month=32, Predicted=2177.5960, Expected=2186.8501
# Month=33, Predicted=2186.3423, Expected=2186.4299
# Month=34, Predicted=2185.5685, Expected=2201.5601
# Month=35, Predicted=2201.1307, Expected=2198.5500
# Month=36, Predicted=2197.4977, Expected=2206.2700
# Month=37, Predicted=2206.3625, Expected=2210.2100
# Month=38, Predicted=2209.3613, Expected=2200.7600
# Month=39, Predicted=2200.8600, Expected=2204.9700
# Month=40, Predicted=2204.8450, Expected=2200.1699
# Month=41, Predicted=2198.8029, Expected=2191.1201
# Month=42, Predicted=2191.5826, Expected=2200.6499
# Month=43, Predicted=2199.4280, Expected=2207.2600
# Month=44, Predicted=2205.5861, Expected=2210.7200
# Month=45, Predicted=2210.0685, Expected=2241.1299
# Month=46, Predicted=2243.7433, Expected=2249.7300
# Month=47, Predicted=2250.1982, Expected=2258.8301
# Month=48, Predicted=2259.8045, Expected=2263.3201
# Month=49, Predicted=2263.8468, Expected=2268.3501
# Month=50, Predicted=2268.7463, Expected=2253.7700
# Month=51, Predicted=2253.8054, Expected=2266.8101
# Month=52, Predicted=2267.1505, Expected=2259.2400
# Month=53, Predicted=2257.8845, Expected=2266.5000
# Month=54, Predicted=2266.5847, Expected=2270.5400
# Month=55, Predicted=2270.1085, Expected=2262.9299
# Month=56, Predicted=2262.6873, Expected=2260.2500
# Month=57, Predicted=2260.3629, Expected=2266.2300
# Month=58, Predicted=2265.4791, Expected=2270.2300
# Month=59, Predicted=2269.5144, Expected=2249.5000
# Month=60, Predicted=2250.1097, Expected=2251.6101
# Run 14 — RMSE: 11.556107, MSE: 133.543616, NMSE: 0.0008253545
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=2157.5425, Expected=2158.2200
# Month=2, Predicted=2160.1739, Expected=2164.1899
# Month=3, Predicted=2163.6140, Expected=2160.3899
# Month=4, Predicted=2160.7555, Expected=2161.3501
# Month=5, Predicted=2163.0638, Expected=2137.6699
# Month=6, Predicted=2139.4295, Expected=2130.2600
# Month=7, Predicted=2136.6370, Expected=2139.6799
# Month=8, Predicted=2138.7197, Expected=2132.9500
# Month=9, Predicted=2132.1693, Expected=2138.3101
# Month=10, Predicted=2139.6551, Expected=2140.8101
# Month=11, Predicted=2139.8040, Expected=2142.5100
# Month=12, Predicted=2142.3529, Expected=2139.4299
# Month=13, Predicted=2139.6335, Expected=2148.5000
# Month=14, Predicted=2148.1067, Expected=2149.7200
# Month=15, Predicted=2148.2445, Expected=2136.9700
# Month=16, Predicted=2138.4461, Expected=2144.0601
# Month=17, Predicted=2145.4767, Expected=2132.2300
# Month=18, Predicted=2131.0829, Expected=2129.7800
# Month=19, Predicted=2132.9966, Expected=2128.6799
# Month=20, Predicted=2128.8255, Expected=2109.4299
# Month=21, Predicted=2111.6919, Expected=2098.8000
# Month=22, Predicted=2104.4452, Expected=2083.7900
# Month=23, Predicted=2086.2807, Expected=2100.5901
# Month=24, Predicted=2099.4324, Expected=2129.9199
# Month=25, Predicted=2126.4919, Expected=2131.5601
# Month=26, Predicted=2128.9890, Expected=2167.4900
# Month=27, Predicted=2165.0530, Expected=2162.7100
# Month=28, Predicted=2158.1920, Expected=2165.6399
# Month=29, Predicted=2167.4795, Expected=2168.2900
# Month=30, Predicted=2167.1072, Expected=2177.5300
# Month=31, Predicted=2177.1098, Expected=2178.6101
# Month=32, Predicted=2178.1948, Expected=2186.8501
# Month=33, Predicted=2188.4752, Expected=2186.4299
# Month=34, Predicted=2186.8445, Expected=2201.5601
# Month=35, Predicted=2203.3800, Expected=2198.5500
# Month=36, Predicted=2197.9930, Expected=2206.2700
# Month=37, Predicted=2209.6600, Expected=2210.2100
# Month=38, Predicted=2210.5801, Expected=2200.7600
# Month=39, Predicted=2203.1141, Expected=2204.9700
# Month=40, Predicted=2208.7605, Expected=2200.1699
# Month=41, Predicted=2200.7746, Expected=2191.1201
# Month=42, Predicted=2195.0165, Expected=2200.6499
# Month=43, Predicted=2202.2319, Expected=2207.2600
# Month=44, Predicted=2206.2336, Expected=2210.7200
# Month=45, Predicted=2211.0909, Expected=2241.1299
# Month=46, Predicted=2239.6118, Expected=2249.7300
# Month=47, Predicted=2246.5920, Expected=2258.8301
# Month=48, Predicted=2258.9121, Expected=2263.3201
# Month=49, Predicted=2262.5265, Expected=2268.3501
# Month=50, Predicted=2268.4781, Expected=2253.7700
# Month=51, Predicted=2254.3517, Expected=2266.8101
# Month=52, Predicted=2270.5184, Expected=2259.2400
# Month=53, Predicted=2257.7194, Expected=2266.5000
# Month=54, Predicted=2270.3832, Expected=2270.5400
# Month=55, Predicted=2270.6517, Expected=2262.9299
# Month=56, Predicted=2265.0814, Expected=2260.2500
# Month=57, Predicted=2264.1257, Expected=2266.2300
# Month=58, Predicted=2267.0998, Expected=2270.2300
# Month=59, Predicted=2270.1737, Expected=2249.5000
# Month=60, Predicted=2251.9478, Expected=2251.6101
# Run 15 — RMSE: 11.628550, MSE: 135.223167, NMSE: 0.0008161490
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=2156.6648, Expected=2158.2200
# Month=2, Predicted=2158.4764, Expected=2164.1899
# Month=3, Predicted=2163.7455, Expected=2160.3899
# Month=4, Predicted=2159.9736, Expected=2161.3501
# Month=5, Predicted=2161.1988, Expected=2137.6699
# Month=6, Predicted=2140.2116, Expected=2130.2600
# Month=7, Predicted=2141.0365, Expected=2139.6799
# Month=8, Predicted=2138.7390, Expected=2132.9500
# Month=9, Predicted=2132.5885, Expected=2138.3101
# Month=10, Predicted=2137.7812, Expected=2140.8101
# Month=11, Predicted=2140.4567, Expected=2142.5100
# Month=12, Predicted=2143.8882, Expected=2139.4299
# Month=13, Predicted=2142.7067, Expected=2148.5000
# Month=14, Predicted=2148.4937, Expected=2149.7200
# Month=15, Predicted=2148.7861, Expected=2136.9700
# Month=16, Predicted=2136.1701, Expected=2144.0601
# Month=17, Predicted=2143.8543, Expected=2132.2300
# Month=18, Predicted=2130.5721, Expected=2129.7800
# Month=19, Predicted=2131.1446, Expected=2128.6799
# Month=20, Predicted=2127.7808, Expected=2109.4299
# Month=21, Predicted=2107.2014, Expected=2098.8000
# Month=22, Predicted=2100.7910, Expected=2083.7900
# Month=23, Predicted=2081.0716, Expected=2100.5901
# Month=24, Predicted=2100.4300, Expected=2129.9199
# Month=25, Predicted=2129.6775, Expected=2131.5601
# Month=26, Predicted=2131.0970, Expected=2167.4900
# Month=27, Predicted=2165.7080, Expected=2162.7100
# Month=28, Predicted=2164.4139, Expected=2165.6399
# ...
# Month=53, Predicted=2258.5519, Expected=2266.5000
# Month=54, Predicted=2266.8535, Expected=2270.5400
# Month=55, Predicted=2270.4359, Expected=2262.9299
# Month=56, Predicted=2262.9530, Expected=2260.2500
# Month=57, Predicted=2260.8955, Expected=2266.2300
# Month=58, Predicted=2266.0075, Expected=2270.2300
# Month=59, Predicted=2269.8870, Expected=2249.5000
# Month=60, Predicted=2250.0807, Expected=2251.6101
# Run 25 — RMSE: 11.292349, MSE: 127.517142, NMSE: 0.0007761195
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=2155.3360, Expected=2158.2200
# Month=2, Predicted=2162.3309, Expected=2164.1899
# Month=3, Predicted=2163.9972, Expected=2160.3899
# Month=4, Predicted=2157.2655, Expected=2161.3501
# Month=5, Predicted=2165.2269, Expected=2137.6699
# Month=6, Predicted=2136.6423, Expected=2130.2600
# Month=7, Predicted=2129.8818, Expected=2139.6799
# Month=8, Predicted=2138.9887, Expected=2132.9500
# Month=9, Predicted=2130.2079, Expected=2138.3101
# Month=10, Predicted=2140.4364, Expected=2140.8101
# Month=11, Predicted=2139.8557, Expected=2142.5100
# Month=12, Predicted=2140.5816, Expected=2139.4299
# Month=13, Predicted=2140.0484, Expected=2148.5000
# Month=14, Predicted=2148.0027, Expected=2149.7200
# Month=15, Predicted=2147.2623, Expected=2136.9700
# Month=16, Predicted=2138.0771, Expected=2144.0601
# Month=17, Predicted=2145.3436, Expected=2132.2300
# Month=18, Predicted=2127.7796, Expected=2129.7800
# Month=19, Predicted=2130.6257, Expected=2128.6799
# Month=20, Predicted=2128.3166, Expected=2109.4299
# Month=21, Predicted=2106.3650, Expected=2098.8000
# Month=22, Predicted=2101.4280, Expected=2083.7900
# Month=23, Predicted=2081.8526, Expected=2100.5901
# Month=24, Predicted=2101.0417, Expected=2129.9199
# Month=25, Predicted=2132.1156, Expected=2131.5601
# Month=26, Predicted=2130.3801, Expected=2167.4900
# Month=27, Predicted=2168.0628, Expected=2162.7100
# Month=28, Predicted=2159.3202, Expected=2165.6399
# Month=29, Predicted=2167.6565, Expected=2168.2900
# Month=30, Predicted=2168.2598, Expected=2177.5300
# Month=31, Predicted=2175.4779, Expected=2178.6101
# Month=32, Predicted=2176.0428, Expected=2186.8501
# Month=33, Predicted=2187.7968, Expected=2186.4299
# Month=34, Predicted=2184.4744, Expected=2201.5601
# Month=35, Predicted=2200.8613, Expected=2198.5500
# Month=36, Predicted=2196.4201, Expected=2206.2700
# Month=37, Predicted=2207.0849, Expected=2210.2100
# Month=38, Predicted=2208.5568, Expected=2200.7600
# Month=39, Predicted=2198.4981, Expected=2204.9700
# Month=40, Predicted=2206.5175, Expected=2200.1699
# Month=41, Predicted=2197.3302, Expected=2191.1201
# Month=42, Predicted=2189.9319, Expected=2200.6499
# Month=43, Predicted=2200.5522, Expected=2207.2600
# Month=44, Predicted=2206.2691, Expected=2210.7200
# Month=45, Predicted=2209.6183, Expected=2241.1299
# Month=46, Predicted=2241.7968, Expected=2249.7300
# Month=47, Predicted=2248.4800, Expected=2258.8301
# Month=48, Predicted=2259.1617, Expected=2263.3201
# Month=49, Predicted=2263.5176, Expected=2268.3501
# Month=50, Predicted=2266.0666, Expected=2253.7700
# Month=51, Predicted=2251.1013, Expected=2266.8101
# Month=52, Predicted=2268.1169, Expected=2259.2400
# Month=53, Predicted=2255.1739, Expected=2266.5000
# Month=54, Predicted=2266.4132, Expected=2270.5400
# Month=55, Predicted=2269.5984, Expected=2262.9299
# Month=56, Predicted=2261.1039, Expected=2260.2500
# Month=57, Predicted=2260.7155, Expected=2266.2300
# Month=58, Predicted=2265.1426, Expected=2270.2300
# Month=59, Predicted=2268.3084, Expected=2249.5000
# Month=60, Predicted=2251.7842, Expected=2251.6101
# Run 26 — RMSE: 11.591178, MSE: 134.355414, NMSE: 0.0008171340
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=2158.8754, Expected=2158.2200
# Month=2, Predicted=2165.5960, Expected=2164.1899
# Month=3, Predicted=2165.1155, Expected=2160.3899
# Month=4, Predicted=2162.0839, Expected=2161.3501
# Month=5, Predicted=2168.6240, Expected=2137.6699
# Month=6, Predicted=2138.6415, Expected=2130.2600
# Month=7, Predicted=2145.4892, Expected=2139.6799
# Month=8, Predicted=2140.4948, Expected=2132.9500
# Month=9, Predicted=2131.7993, Expected=2138.3101
# Month=10, Predicted=2146.9766, Expected=2140.8101
# Month=11, Predicted=2143.1629, Expected=2142.5100
# Month=12, Predicted=2146.1041, Expected=2139.4299
# Month=13, Predicted=2144.0710, Expected=2148.5000
# Month=14, Predicted=2152.8858, Expected=2149.7200
# Month=15, Predicted=2150.4873, Expected=2136.9700
# Month=16, Predicted=2141.5362, Expected=2144.0601
# Month=17, Predicted=2152.0276, Expected=2132.2300
# Month=18, Predicted=2130.8112, Expected=2129.7800
# Month=19, Predicted=2139.8179, Expected=2128.6799
# Month=20, Predicted=2133.0753, Expected=2109.4299
# Month=21, Predicted=2111.3240, Expected=2098.8000
# Month=22, Predicted=2113.5419, Expected=2083.7900
# Month=23, Predicted=2089.8715, Expected=2100.5901
# Month=24, Predicted=2100.0990, Expected=2129.9199
# Month=25, Predicted=2127.9936, Expected=2131.5601
# Month=26, Predicted=2131.5102, Expected=2167.4900
# Month=27, Predicted=2162.5892, Expected=2162.7100
# Month=28, Predicted=2160.8615, Expected=2165.6399
# Month=29, Predicted=2175.5784, Expected=2168.2900
# Month=30, Predicted=2171.7279, Expected=2177.5300
# Month=31, Predicted=2178.6495, Expected=2178.6101
# Month=32, Predicted=2179.7018, Expected=2186.8501
# Month=33, Predicted=2191.0530, Expected=2186.4299
# Month=34, Predicted=2187.9328, Expected=2201.5601
# Month=35, Predicted=2202.6776, Expected=2198.5500
# Month=36, Predicted=2198.0374, Expected=2206.2700
# Month=37, Predicted=2211.8680, Expected=2210.2100
# Month=38, Predicted=2211.2486, Expected=2200.7600
# Month=39, Predicted=2203.1142, Expected=2204.9700
# Month=40, Predicted=2212.1720, Expected=2200.1699
# Month=41, Predicted=2200.6635, Expected=2191.1201
# Month=42, Predicted=2196.3704, Expected=2200.6499
# Month=43, Predicted=2204.1768, Expected=2207.2600
# Month=44, Predicted=2206.7515, Expected=2210.7200
# Month=45, Predicted=2213.4870, Expected=2241.1299
# Month=46, Predicted=2238.1683, Expected=2249.7300
# Month=47, Predicted=2248.3584, Expected=2258.8301
# Month=48, Predicted=2263.3427, Expected=2263.3201
# Month=49, Predicted=2266.0976, Expected=2268.3501
# Month=50, Predicted=2270.2657, Expected=2253.7700
# Month=51, Predicted=2254.7607, Expected=2266.8101
# Month=52, Predicted=2268.4027, Expected=2259.2400
# Month=53, Predicted=2257.2477, Expected=2266.5000
# Month=54, Predicted=2271.7053, Expected=2270.5400
# Month=55, Predicted=2271.2208, Expected=2262.9299
# Month=56, Predicted=2265.2766, Expected=2260.2500
# Month=57, Predicted=2268.0459, Expected=2266.2300
# Month=58, Predicted=2268.1692, Expected=2270.2300
# Month=59, Predicted=2270.7152, Expected=2249.5000
# Month=60, Predicted=2251.4427, Expected=2251.6101
# Run 27 — RMSE: 12.191543, MSE: 148.633714, NMSE: 0.0009288159
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=2153.4296, Expected=2158.2200
# Month=2, Predicted=2161.5472, Expected=2164.1899
# Month=3, Predicted=2162.7934, Expected=2160.3899
# Month=4, Predicted=2157.4707, Expected=2161.3501
# Month=5, Predicted=2163.6081, Expected=2137.6699
# Month=6, Predicted=2138.7138, Expected=2130.2600
# Month=7, Predicted=2130.2166, Expected=2139.6799
# Month=8, Predicted=2136.7984, Expected=2132.9500
# Month=9, Predicted=2129.3201, Expected=2138.3101
# Month=10, Predicted=2141.0340, Expected=2140.8101
# Month=11, Predicted=2139.6595, Expected=2142.5100
# Month=12, Predicted=2140.3657, Expected=2139.4299
# Month=13, Predicted=2139.4096, Expected=2148.5000
# Month=14, Predicted=2147.6939, Expected=2149.7200
# Month=15, Predicted=2147.6191, Expected=2136.9700
# Month=16, Predicted=2137.7208, Expected=2144.0601
# Month=17, Predicted=2144.8398, Expected=2132.2300
# Month=18, Predicted=2128.4243, Expected=2129.7800
# Month=19, Predicted=2129.6956, Expected=2128.6799
# Month=20, Predicted=2127.1896, Expected=2109.4299
# Month=21, Predicted=2107.7121, Expected=2098.8000
# Month=22, Predicted=2101.7463, Expected=2083.7900
# Month=23, Predicted=2080.5622, Expected=2100.5901
# Month=24, Predicted=2098.0038, Expected=2129.9199
# Month=25, Predicted=2132.0467, Expected=2131.5601
# Month=26, Predicted=2130.7539, Expected=2167.4900
# Month=27, Predicted=2169.9199, Expected=2162.7100
# Month=28, Predicted=2162.9379, Expected=2165.6399
# Month=29, Predicted=2167.8551, Expected=2168.2900
# Month=30, Predicted=2168.2769, Expected=2177.5300
# Month=31, Predicted=2175.6209, Expected=2178.6101
# Month=32, Predicted=2176.5296, Expected=2186.8501
# Month=33, Predicted=2188.0855, Expected=2186.4299
# Month=34, Predicted=2185.2497, Expected=2201.5601
# Month=35, Predicted=2200.4641, Expected=2198.5500
# Month=36, Predicted=2196.7332, Expected=2206.2700
# Month=37, Predicted=2207.9067, Expected=2210.2100
# Month=38, Predicted=2208.7886, Expected=2200.7600
# Month=39, Predicted=2199.0974, Expected=2204.9700
# Month=40, Predicted=2206.0114, Expected=2200.1699
# Month=41, Predicted=2197.3206, Expected=2191.1201
# Month=42, Predicted=2190.1000, Expected=2200.6499
# Month=43, Predicted=2199.1684, Expected=2207.2600
# Month=44, Predicted=2205.5880, Expected=2210.7200
# Month=45, Predicted=2209.5132, Expected=2241.1299
# Month=46, Predicted=2242.2345, Expected=2249.7300
# Month=47, Predicted=2249.8210, Expected=2258.8301
# Month=48, Predicted=2260.2542, Expected=2263.3201
# Month=49, Predicted=2264.5247, Expected=2268.3501
# Month=50, Predicted=2267.0466, Expected=2253.7700
# Month=51, Predicted=2252.4005, Expected=2266.8101
# Month=52, Predicted=2267.5005, Expected=2259.2400
# Month=53, Predicted=2255.7460, Expected=2266.5000
# Month=54, Predicted=2266.0074, Expected=2270.5400
# Month=55, Predicted=2269.2258, Expected=2262.9299
# Month=56, Predicted=2261.8918, Expected=2260.2500
# Month=57, Predicted=2261.1182, Expected=2266.2300
# Month=58, Predicted=2264.0036, Expected=2270.2300
# Month=59, Predicted=2267.6427, Expected=2249.5000
# Month=60, Predicted=2252.1426, Expected=2251.6101
# Run 28 — RMSE: 11.596045, MSE: 134.468258, NMSE: 0.0008105662
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=2156.7445, Expected=2158.2200
# Month=2, Predicted=2157.5645, Expected=2164.1899
# Month=3, Predicted=2163.0497, Expected=2160.3899
# Month=4, Predicted=2160.0187, Expected=2161.3501
# Month=5, Predicted=2161.5046, Expected=2137.6699
# Month=6, Predicted=2138.6811, Expected=2130.2600
# Month=7, Predicted=2134.9943, Expected=2139.6799
# Month=8, Predicted=2138.9322, Expected=2132.9500
# Month=9, Predicted=2132.0879, Expected=2138.3101
# Month=10, Predicted=2137.7896, Expected=2140.8101
# Month=11, Predicted=2139.7534, Expected=2142.5100
# Month=12, Predicted=2142.3596, Expected=2139.4299
# Month=13, Predicted=2139.0785, Expected=2148.5000
# Month=14, Predicted=2147.9406, Expected=2149.7200
# Month=15, Predicted=2148.7634, Expected=2136.9700
# Month=16, Predicted=2139.1707, Expected=2144.0601
# Month=17, Predicted=2143.9359, Expected=2132.2300
# Month=18, Predicted=2131.4042, Expected=2129.7800
# Month=19, Predicted=2132.1394, Expected=2128.6799
# Month=20, Predicted=2127.5855, Expected=2109.4299
# Month=21, Predicted=2111.0079, Expected=2098.8000
# Month=22, Predicted=2100.8470, Expected=2083.7900
# Month=23, Predicted=2083.3266, Expected=2100.5901
# Month=24, Predicted=2097.7579, Expected=2129.9199
# Month=25, Predicted=2131.4914, Expected=2131.5601
# Month=26, Predicted=2130.7262, Expected=2167.4900
# Month=27, Predicted=2166.1599, Expected=2162.7100
# Month=28, Predicted=2161.1328, Expected=2165.6399
# Month=29, Predicted=2172.8979, Expected=2168.2900
# Month=30, Predicted=2167.1438, Expected=2177.5300
# Month=31, Predicted=2178.7307, Expected=2178.6101
# Month=32, Predicted=2177.7653, Expected=2186.8501
# Month=33, Predicted=2187.2442, Expected=2186.4299
# Month=34, Predicted=2185.6090, Expected=2201.5601
# Month=35, Predicted=2200.8759, Expected=2198.5500
# Month=36, Predicted=2197.4871, Expected=2206.2700
# Month=37, Predicted=2207.5289, Expected=2210.2100
# Month=38, Predicted=2209.1855, Expected=2200.7600
# Month=39, Predicted=2202.5217, Expected=2204.9700
# Month=40, Predicted=2205.1156, Expected=2200.1699
# Month=41, Predicted=2199.3796, Expected=2191.1201
# Month=42, Predicted=2192.8416, Expected=2200.6499
# Month=43, Predicted=2199.1781, Expected=2207.2600
# Month=44, Predicted=2206.2365, Expected=2210.7200
# Month=45, Predicted=2210.2280, Expected=2241.1299
# Month=46, Predicted=2239.6816, Expected=2249.7300
# Month=47, Predicted=2248.6831, Expected=2258.8301
# Month=48, Predicted=2260.2827, Expected=2263.3201
# Month=49, Predicted=2262.7212, Expected=2268.3501
# Month=50, Predicted=2269.8048, Expected=2253.7700
# Month=51, Predicted=2255.2037, Expected=2266.8101
# Month=52, Predicted=2268.0219, Expected=2259.2400
# Month=53, Predicted=2258.1158, Expected=2266.5000
# Month=54, Predicted=2267.8528, Expected=2270.5400
# Month=55, Predicted=2269.7820, Expected=2262.9299
# Month=56, Predicted=2264.0083, Expected=2260.2500
# Month=57, Predicted=2260.5048, Expected=2266.2300
# Month=58, Predicted=2265.1036, Expected=2270.2300
# Month=59, Predicted=2269.2025, Expected=2249.5000
# Month=60, Predicted=2250.8480, Expected=2251.6101
# Run 29 — RMSE: 11.427839, MSE: 130.595496, NMSE: 0.0007912522
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=2153.6101, Expected=2158.2200
# Month=2, Predicted=2156.6101, Expected=2164.1899
# Month=3, Predicted=2162.8874, Expected=2160.3899
# Month=4, Predicted=2159.5171, Expected=2161.3501
# Month=5, Predicted=2161.5148, Expected=2137.6699
# Month=6, Predicted=2134.4211, Expected=2130.2600
# Month=7, Predicted=2129.9042, Expected=2139.6799
# Month=8, Predicted=2140.5254, Expected=2132.9500
# Month=9, Predicted=2134.3323, Expected=2138.3101
# Month=10, Predicted=2140.6527, Expected=2140.8101
# Month=11, Predicted=2142.8622, Expected=2142.5100
# Month=12, Predicted=2143.7289, Expected=2139.4299
# Month=13, Predicted=2138.3315, Expected=2148.5000
# Month=14, Predicted=2147.4301, Expected=2149.7200
# Month=15, Predicted=2148.1198, Expected=2136.9700
# Month=16, Predicted=2133.8166, Expected=2144.0601
# Month=17, Predicted=2143.3570, Expected=2132.2300
# Month=18, Predicted=2131.0607, Expected=2129.7800
# Month=19, Predicted=2129.7804, Expected=2128.6799
# Month=20, Predicted=2129.6849, Expected=2109.4299
# Month=21, Predicted=2108.3218, Expected=2098.8000
# Month=22, Predicted=2097.4028, Expected=2083.7900
# Month=23, Predicted=2080.4890, Expected=2100.5901
# Month=24, Predicted=2102.2700, Expected=2129.9199
# Month=25, Predicted=2131.6718, Expected=2131.5601
# Month=26, Predicted=2134.4245, Expected=2167.4900
# Month=27, Predicted=2170.9486, Expected=2162.7100
# Month=28, Predicted=2164.1507, Expected=2165.6399
# Month=29, Predicted=2164.9708, Expected=2168.2900
# Month=30, Predicted=2167.2643, Expected=2177.5300
# Month=31, Predicted=2176.0232, Expected=2178.6101
# Month=32, Predicted=2176.5960, Expected=2186.8501
# Month=33, Predicted=2188.0269, Expected=2186.4299
# Month=34, Predicted=2188.1209, Expected=2201.5601
# Month=35, Predicted=2204.0818, Expected=2198.5500
# Month=36, Predicted=2199.8847, Expected=2206.2700
# Month=37, Predicted=2206.5378, Expected=2210.2100
# Month=38, Predicted=2208.6921, Expected=2200.7600
# Month=39, Predicted=2197.8614, Expected=2204.9700
# Month=40, Predicted=2204.7009, Expected=2200.1699
# Month=41, Predicted=2197.7876, Expected=2191.1201
# Month=42, Predicted=2189.9520, Expected=2200.6499
# Month=43, Predicted=2202.5582, Expected=2207.2600
# Month=44, Predicted=2209.4577, Expected=2210.7200
# Month=45, Predicted=2213.2405, Expected=2241.1299
# Month=46, Predicted=2244.0580, Expected=2249.7300
# Month=47, Predicted=2251.7066, Expected=2258.8301
# Month=48, Predicted=2258.9763, Expected=2263.3201
# Month=49, Predicted=2261.2124, Expected=2268.3501
# Month=50, Predicted=2267.7505, Expected=2253.7700
# Month=51, Predicted=2252.3958, Expected=2266.8101
# Month=52, Predicted=2266.7776, Expected=2259.2400
# Month=53, Predicted=2259.6744, Expected=2266.5000
# Month=54, Predicted=2268.8456, Expected=2270.5400
# Month=55, Predicted=2272.8950, Expected=2262.9299
# Month=56, Predicted=2264.5017, Expected=2260.2500
# Month=57, Predicted=2259.7872, Expected=2266.2300
# Month=58, Predicted=2264.9300, Expected=2270.2300
# Month=59, Predicted=2268.8493, Expected=2249.5000
# Month=60, Predicted=2244.8851, Expected=2251.6101
# Run 30 — RMSE: 10.957401, MSE: 120.064642, NMSE: 0.0007217055

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Output Layer on S&P 500 (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Output Layer on S&P 500 (30 runs) =====
# RMSE: 11.412300 ± 0.295106
# MSE:  130.327684 ± 6.773239
# NMSE: 0.0007954367 ± 0.0000497362
#
# Best run: 8
#   RMSE: 10.868669
#   MSE:  118.127972
#   NMSE: 0.0007071999

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Output Layer — S&P 500\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Output Layer — S&P 500\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 10.868669
# MSE:  118.127972
# NMSE: 0.0007071999

# %% [markdown]
# ## Observations
#
# ### Fuzzy Output Layer on S&P 500
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
