# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# CPU ONLY Settings (Forced)
# ============================================================
import tensorflow as tf
import platform

try:
    tf.config.set_visible_devices([], 'GPU')
    print('Forcing CPU execution (disabled GPU visibility).')
except RuntimeError as e:
    print(e)

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")

def smape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted) + 1e-8))
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fuzzy_output_layer              │ (1, 1)                 │            12 │
# │ (FuzzyOutputLayer)              │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332 (1.30 KB)
#  Trainable params: 332 (1.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (539, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (539, 1, 1), y_train shape: (539,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_smape = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(2):
    print(f'\n===== RUN {run+1}/2 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    # Set consumption gate (c) bias to 1.0 (unit forget bias)
    rnn_layer = model.layers[1]
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, bias[units:2*units]
    weights[2] = bias
    cell.set_weights(weights)

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    s_mape = smape(actual, predictions)
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_smape.append(s_mape)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, sMAPE: {s_mape:.6f}')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2768, Expected=13.7000
# Month=2, Predicted=14.1817, Expected=13.8140
# Month=3, Predicted=14.5657, Expected=14.3830
# Month=4, Predicted=15.0398, Expected=15.0470
# Month=5, Predicted=15.2911, Expected=15.6930
# Month=6, Predicted=15.6133, Expected=15.8440
# Month=7, Predicted=15.5364, Expected=15.7120
# Month=8, Predicted=15.2641, Expected=15.3130
# Month=9, Predicted=14.6875, Expected=14.7630
# Month=10, Predicted=14.1838, Expected=13.5480
# Month=11, Predicted=12.9603, Expected=13.5860
# Month=12, Predicted=13.6347, Expected=14.5160
# Month=13, Predicted=14.7034, Expected=14.3830
# Month=14, Predicted=14.7960, Expected=14.4970
# Month=15, Predicted=15.2376, Expected=14.7440
# Month=16, Predicted=15.3622, Expected=15.8060
# Month=17, Predicted=16.1249, Expected=16.5270
# Month=18, Predicted=16.4715, Expected=16.5460
# Month=19, Predicted=16.2171, Expected=16.7170
# Month=20, Predicted=16.3573, Expected=16.4330
# Month=21, Predicted=15.8477, Expected=15.7690
# Month=22, Predicted=15.1146, Expected=15.2750
# Month=23, Predicted=14.9732, Expected=15.1230
# Month=24, Predicted=15.1427, Expected=15.5410
# Month=25, Predicted=15.7281, Expected=15.8250
# Month=26, Predicted=16.2591, Expected=16.3760
# Month=27, Predicted=17.1552, Expected=16.3570
# Month=28, Predicted=16.9172, Expected=16.9070
# Month=29, Predicted=17.1293, Expected=17.0210
# Month=30, Predicted=16.8289, Expected=17.4190
# Month=31, Predicted=17.1595, Expected=17.5330
# Month=32, Predicted=17.1568, Expected=17.2680
# Month=33, Predicted=16.6929, Expected=16.6030
# Month=34, Predicted=15.9721, Expected=15.8250
# Month=35, Predicted=15.3954, Expected=15.4460
# Month=36, Predicted=15.3276, Expected=15.6360
# Month=37, Predicted=15.7920, Expected=15.6930
# Month=38, Predicted=16.1519, Expected=16.7550
# Month=39, Predicted=17.6377, Expected=16.5090
# Month=40, Predicted=17.0737, Expected=17.7230
# Month=41, Predicted=18.0299, Expected=18.6910
# Month=42, Predicted=18.6752, Expected=19.1270
# Month=43, Predicted=18.9005, Expected=19.5640
# Month=44, Predicted=19.2858, Expected=19.2030
# Month=45, Predicted=18.5872, Expected=18.2160
# Month=46, Predicted=17.4119, Expected=17.2110
# Month=47, Predicted=16.6372, Expected=16.6600
# Month=48, Predicted=16.4788, Expected=16.8310
# Month=49, Predicted=16.9634, Expected=15.7690
# Month=50, Predicted=15.7259, Expected=15.7310
# Month=51, Predicted=16.2277, Expected=15.9960
# Month=52, Predicted=16.8334, Expected=17.0210
# Month=53, Predicted=17.7929, Expected=17.5520
# Month=54, Predicted=17.8250, Expected=17.8370
# Month=55, Predicted=17.7161, Expected=17.8560
# Month=56, Predicted=17.5247, Expected=17.5710
# Month=57, Predicted=17.0905, Expected=17.0780
# Month=58, Predicted=16.4291, Expected=16.6600
# Month=59, Predicted=16.1596, Expected=16.4330
# Month=60, Predicted=16.3073, Expected=16.5840
# Run 1 — RMSE: 0.408292, MSE: 0.166703, NMSE: 0.0015552405
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2594, Expected=13.7000
# Month=2, Predicted=14.2911, Expected=13.8140
# Month=3, Predicted=14.4998, Expected=14.3830
# Month=4, Predicted=15.1643, Expected=15.0470
# Month=5, Predicted=15.4371, Expected=15.6930
# Month=6, Predicted=15.7031, Expected=15.8440
# Month=7, Predicted=15.5105, Expected=15.7120
# Month=8, Predicted=15.2868, Expected=15.3130
# Month=9, Predicted=14.7254, Expected=14.7630
# Month=10, Predicted=14.1864, Expected=13.5480
# Month=11, Predicted=12.9111, Expected=13.5860
# Month=12, Predicted=13.5912, Expected=14.5160
# Month=13, Predicted=14.7730, Expected=14.3830
# Month=14, Predicted=14.7870, Expected=14.4970
# Month=15, Predicted=15.2502, Expected=14.7440
# Month=16, Predicted=15.4551, Expected=15.8060
# Month=17, Predicted=16.4037, Expected=16.5270
# Month=18, Predicted=16.5502, Expected=16.5460
# Month=19, Predicted=16.2346, Expected=16.7170
# Month=20, Predicted=16.4420, Expected=16.4330
# Month=21, Predicted=15.8704, Expected=15.7690
# Month=22, Predicted=15.1384, Expected=15.2750
# Month=23, Predicted=14.9046, Expected=15.1230
# Month=24, Predicted=15.0679, Expected=15.5410
# Month=25, Predicted=15.7413, Expected=15.8250
# Month=26, Predicted=16.3562, Expected=16.3760
# Month=27, Predicted=17.1746, Expected=16.3570
# Month=28, Predicted=16.8572, Expected=16.9070
# Month=29, Predicted=17.3236, Expected=17.0210
# Month=30, Predicted=16.8052, Expected=17.4190
# Month=31, Predicted=17.2844, Expected=17.5330
# Month=32, Predicted=17.2286, Expected=17.2680
# Month=33, Predicted=16.8207, Expected=16.6030
# Month=34, Predicted=16.0861, Expected=15.8250
# Month=35, Predicted=15.4085, Expected=15.4460
# Month=36, Predicted=15.3379, Expected=15.6360
# Month=37, Predicted=15.9098, Expected=15.6930
# Month=38, Predicted=16.2333, Expected=16.7550
# Month=39, Predicted=17.6228, Expected=16.5090
# Month=40, Predicted=16.8488, Expected=17.7230
# Month=41, Predicted=18.3380, Expected=18.6910
# Month=42, Predicted=18.6737, Expected=19.1270
# Month=43, Predicted=18.8844, Expected=19.5640
# Month=44, Predicted=19.3730, Expected=19.2030
# Month=45, Predicted=18.6121, Expected=18.2160
# Month=46, Predicted=17.4455, Expected=17.2110
# Month=47, Predicted=16.5550, Expected=16.6600
# Month=48, Predicted=16.3624, Expected=16.8310
# Month=49, Predicted=16.9344, Expected=15.7690
# Month=50, Predicted=15.7677, Expected=15.7310
# Month=51, Predicted=16.3601, Expected=15.9960
# Month=52, Predicted=16.7603, Expected=17.0210
# Month=53, Predicted=17.7998, Expected=17.5520
# Month=54, Predicted=17.8719, Expected=17.8370
# Month=55, Predicted=17.8304, Expected=17.8560
# Month=56, Predicted=17.4731, Expected=17.5710
# Month=57, Predicted=17.0705, Expected=17.0780
# Month=58, Predicted=16.4687, Expected=16.6600
# Month=59, Predicted=16.1589, Expected=16.4330
# Month=60, Predicted=16.2395, Expected=16.5840
# Run 2 — RMSE: 0.414852, MSE: 0.172102, NMSE: 0.0015788730
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.3690, Expected=13.7000
# Month=2, Predicted=14.2794, Expected=13.8140
# Month=3, Predicted=14.3903, Expected=14.3830
# Month=4, Predicted=14.9444, Expected=15.0470
# Month=5, Predicted=15.3875, Expected=15.6930
# Month=6, Predicted=15.8302, Expected=15.8440
# Month=7, Predicted=15.6954, Expected=15.7120
# Month=8, Predicted=15.3432, Expected=15.3130
# Month=9, Predicted=14.8213, Expected=14.7630
# Month=10, Predicted=14.3424, Expected=13.5480
# Month=11, Predicted=12.9885, Expected=13.5860
# Month=12, Predicted=13.6851, Expected=14.5160
# Month=13, Predicted=15.0175, Expected=14.3830
# Month=14, Predicted=14.7981, Expected=14.4970
# Month=15, Predicted=15.0413, Expected=14.7440
# Month=16, Predicted=15.2326, Expected=15.8060
# Month=17, Predicted=16.3506, Expected=16.5270
# Month=18, Predicted=16.7469, Expected=16.5460
# Month=19, Predicted=16.4092, Expected=16.7170
# Month=20, Predicted=16.5788, Expected=16.4330
# Month=21, Predicted=16.0189, Expected=15.7690
# Month=22, Predicted=15.3034, Expected=15.2750
# Month=23, Predicted=15.0111, Expected=15.1230
# Month=24, Predicted=15.1186, Expected=15.5410
# Month=25, Predicted=15.9281, Expected=15.8250
# Month=26, Predicted=16.3576, Expected=16.3760
# Month=27, Predicted=17.0139, Expected=16.3570
# Month=28, Predicted=16.7634, Expected=16.9070
# Month=29, Predicted=17.2318, Expected=17.0210
# Month=30, Predicted=17.0069, Expected=17.4190
# Month=31, Predicted=17.4537, Expected=17.5330
# Month=32, Predicted=17.3611, Expected=17.2680
# Month=33, Predicted=16.9481, Expected=16.6030
# Month=34, Predicted=16.2465, Expected=15.8250
# Month=35, Predicted=15.5369, Expected=15.4460
# Month=36, Predicted=15.4158, Expected=15.6360
# Month=37, Predicted=15.9784, Expected=15.6930
# Month=38, Predicted=16.1625, Expected=16.7550
# Month=39, Predicted=17.5079, Expected=16.5090
# Month=40, Predicted=16.8783, Expected=17.7230
# Month=41, Predicted=18.2726, Expected=18.6910
# Month=42, Predicted=18.9223, Expected=19.1270
# Month=43, Predicted=19.0863, Expected=19.5640
# Month=44, Predicted=19.5294, Expected=19.2030
# Month=45, Predicted=18.7479, Expected=18.2160
# Month=46, Predicted=17.5818, Expected=17.2110
# Month=47, Predicted=16.6826, Expected=16.6600
# Month=48, Predicted=16.4335, Expected=16.8310
# Month=49, Predicted=16.9961, Expected=15.7690
# Month=50, Predicted=15.7320, Expected=15.7310
# Month=51, Predicted=16.1172, Expected=15.9960
# Month=52, Predicted=16.5859, Expected=17.0210
# Month=53, Predicted=17.7633, Expected=17.5520
# Month=54, Predicted=17.9799, Expected=17.8370
# Month=55, Predicted=17.9071, Expected=17.8560
# Month=56, Predicted=17.6649, Expected=17.5710
# Month=57, Predicted=17.1087, Expected=17.0780
# Month=58, Predicted=16.4999, Expected=16.6600
# Month=59, Predicted=16.2544, Expected=16.4330
# Month=60, Predicted=16.2254, Expected=16.5840
# Run 3 — RMSE: 0.403301, MSE: 0.162652, NMSE: 0.0014584341
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2841, Expected=13.7000
# Month=2, Predicted=14.0711, Expected=13.8140
# Month=3, Predicted=14.5826, Expected=14.3830
# Month=4, Predicted=15.1632, Expected=15.0470
# Month=5, Predicted=15.3757, Expected=15.6930
# Month=6, Predicted=15.7830, Expected=15.8440
# Month=7, Predicted=15.5985, Expected=15.7120
# Month=8, Predicted=15.2270, Expected=15.3130
# Month=9, Predicted=14.7087, Expected=14.7630
# Month=10, Predicted=14.1423, Expected=13.5480
# Month=11, Predicted=12.9530, Expected=13.5860
# Month=12, Predicted=13.6247, Expected=14.5160
# Month=13, Predicted=14.9078, Expected=14.3830
# Month=14, Predicted=14.5676, Expected=14.4970
# Month=15, Predicted=15.3140, Expected=14.7440
# Month=16, Predicted=15.5148, Expected=15.8060
# Month=17, Predicted=16.2816, Expected=16.5270
# Month=18, Predicted=16.6434, Expected=16.5460
# Month=19, Predicted=16.2427, Expected=16.7170
# Month=20, Predicted=16.3497, Expected=16.4330
# Month=21, Predicted=15.8741, Expected=15.7690
# Month=22, Predicted=15.0978, Expected=15.2750
# Month=23, Predicted=14.8389, Expected=15.1230
# Month=24, Predicted=15.1167, Expected=15.5410
# Month=25, Predicted=15.7816, Expected=15.8250
# Month=26, Predicted=16.1202, Expected=16.3760
# Month=27, Predicted=17.2252, Expected=16.3570
# Month=28, Predicted=17.0030, Expected=16.9070
# Month=29, Predicted=17.2399, Expected=17.0210
# Month=30, Predicted=16.9356, Expected=17.4190
# Month=31, Predicted=17.3271, Expected=17.5330
# Month=32, Predicted=17.2054, Expected=17.2680
# Month=33, Predicted=16.7308, Expected=16.6030
# Month=34, Predicted=15.9627, Expected=15.8250
# Month=35, Predicted=15.3518, Expected=15.4460
# Month=36, Predicted=15.3904, Expected=15.6360
# Month=37, Predicted=15.8019, Expected=15.6930
# Month=38, Predicted=15.9443, Expected=16.7550
# Month=39, Predicted=17.6774, Expected=16.5090
# Month=40, Predicted=17.0598, Expected=17.7230
# Month=41, Predicted=18.2421, Expected=18.6910
# Month=42, Predicted=18.9059, Expected=19.1270
# Month=43, Predicted=19.0031, Expected=19.5640
# Month=44, Predicted=19.3192, Expected=19.2030
# Month=45, Predicted=18.6104, Expected=18.2160
# Month=46, Predicted=17.4574, Expected=17.2110
# Month=47, Predicted=16.5844, Expected=16.6600
# Month=48, Predicted=16.4169, Expected=16.8310
# Month=49, Predicted=17.0395, Expected=15.7690
# Month=50, Predicted=15.6114, Expected=15.7310
# Month=51, Predicted=16.2599, Expected=15.9960
# Month=52, Predicted=16.9666, Expected=17.0210
# Month=53, Predicted=17.7579, Expected=17.5520
# Month=54, Predicted=17.6956, Expected=17.8370
# Month=55, Predicted=17.7252, Expected=17.8560
# Month=56, Predicted=17.5045, Expected=17.5710
# Month=57, Predicted=17.0310, Expected=17.0780
# Month=58, Predicted=16.4391, Expected=16.6600
# Month=59, Predicted=16.1603, Expected=16.4330
# Month=60, Predicted=16.2947, Expected=16.5840
# Run 4 — RMSE: 0.407554, MSE: 0.166100, NMSE: 0.0014938881
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.3186, Expected=13.7000
# Month=2, Predicted=14.2678, Expected=13.8140
# Month=3, Predicted=14.3964, Expected=14.3830
# Month=4, Predicted=15.0217, Expected=15.0470
# Month=5, Predicted=15.4213, Expected=15.6930
# Month=6, Predicted=15.7686, Expected=15.8440
# Month=7, Predicted=15.5794, Expected=15.7120
# Month=8, Predicted=15.2659, Expected=15.3130
# Month=9, Predicted=14.8303, Expected=14.7630
# Month=10, Predicted=14.3224, Expected=13.5480
# Month=11, Predicted=13.0518, Expected=13.5860
# Month=12, Predicted=13.6323, Expected=14.5160
# Month=13, Predicted=15.1053, Expected=14.3830
# Month=14, Predicted=14.9474, Expected=14.4970
# Month=15, Predicted=15.0925, Expected=14.7440
# Month=16, Predicted=15.2314, Expected=15.8060
# Month=17, Predicted=16.4055, Expected=16.5270
# Month=18, Predicted=16.6155, Expected=16.5460
# Month=19, Predicted=16.2669, Expected=16.7170
# Month=20, Predicted=16.4101, Expected=16.4330
# Month=21, Predicted=16.0091, Expected=15.7690
# Month=22, Predicted=15.3243, Expected=15.2750
# Month=23, Predicted=15.0051, Expected=15.1230
# Month=24, Predicted=15.1487, Expected=15.5410
# Month=25, Predicted=16.0113, Expected=15.8250
# Month=26, Predicted=16.4173, Expected=16.3760
# Month=27, Predicted=17.0421, Expected=16.3570
# Month=28, Predicted=16.6488, Expected=16.9070
# Month=29, Predicted=17.1750, Expected=17.0210
# Month=30, Predicted=16.8583, Expected=17.4190
# Month=31, Predicted=17.2774, Expected=17.5330
# Month=32, Predicted=17.2828, Expected=17.2680
# Month=33, Predicted=16.9983, Expected=16.6030
# Month=34, Predicted=16.3489, Expected=15.8250
# Month=35, Predicted=15.6914, Expected=15.4460
# Month=36, Predicted=15.6293, Expected=15.6360
# Month=37, Predicted=16.2075, Expected=15.6930
# Month=38, Predicted=16.3249, Expected=16.7550
# Month=39, Predicted=17.6023, Expected=16.5090
# Month=40, Predicted=16.7225, Expected=17.7230
# Month=41, Predicted=18.3328, Expected=18.6910
# Month=42, Predicted=18.7049, Expected=19.1270
# Month=43, Predicted=18.8457, Expected=19.5640
# Month=44, Predicted=19.3083, Expected=19.2030
# Month=45, Predicted=18.7647, Expected=18.2160
# Month=46, Predicted=17.7043, Expected=17.2110
# Month=47, Predicted=16.7946, Expected=16.6600
# Month=48, Predicted=16.5315, Expected=16.8310
# Month=49, Predicted=17.1877, Expected=15.7690
# Month=50, Predicted=16.1717, Expected=15.7310
# Month=51, Predicted=16.4104, Expected=15.9960
# Month=52, Predicted=16.7247, Expected=17.0210
# Month=53, Predicted=17.7842, Expected=17.5520
# Month=54, Predicted=17.7228, Expected=17.8370
# Month=55, Predicted=17.6485, Expected=17.8560
# Month=56, Predicted=17.4487, Expected=17.5710
# Month=57, Predicted=17.0544, Expected=17.0780
# Month=58, Predicted=16.5564, Expected=16.6600
# Month=59, Predicted=16.2389, Expected=16.4330
# Month=60, Predicted=16.1880, Expected=16.5840
# Run 5 — RMSE: 0.449899, MSE: 0.202409, NMSE: 0.0019380803
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2929, Expected=13.7000
# Month=2, Predicted=14.1948, Expected=13.8140
# Month=3, Predicted=14.3702, Expected=14.3830
# Month=4, Predicted=15.0155, Expected=15.0470
# Month=5, Predicted=15.3368, Expected=15.6930
# Month=6, Predicted=15.7818, Expected=15.8440
# Month=7, Predicted=15.4195, Expected=15.7120
# Month=8, Predicted=15.1756, Expected=15.3130
# Month=9, Predicted=14.7599, Expected=14.7630
# Month=10, Predicted=14.2765, Expected=13.5480
# Month=11, Predicted=12.9739, Expected=13.5860
# Month=12, Predicted=13.6208, Expected=14.5160
# Month=13, Predicted=14.9331, Expected=14.3830
# Month=14, Predicted=14.8956, Expected=14.4970
# Month=15, Predicted=15.0897, Expected=14.7440
# Month=16, Predicted=15.1290, Expected=15.8060
# Month=17, Predicted=16.3833, Expected=16.5270
# Month=18, Predicted=16.4628, Expected=16.5460
# Month=19, Predicted=16.1261, Expected=16.7170
# Month=20, Predicted=16.3506, Expected=16.4330
# Month=21, Predicted=15.9000, Expected=15.7690
# Month=22, Predicted=15.2382, Expected=15.2750
# Month=23, Predicted=14.9297, Expected=15.1230
# Month=24, Predicted=15.0290, Expected=15.5410
# Month=25, Predicted=15.8225, Expected=15.8250
# Month=26, Predicted=16.2250, Expected=16.3760
# Month=27, Predicted=17.0319, Expected=16.3570
# Month=28, Predicted=16.7999, Expected=16.9070
# Month=29, Predicted=17.3692, Expected=17.0210
# Month=30, Predicted=16.7276, Expected=17.4190
# Month=31, Predicted=17.2550, Expected=17.5330
# Month=32, Predicted=17.0906, Expected=17.2680
# Month=33, Predicted=16.7877, Expected=16.6030
# Month=34, Predicted=16.1101, Expected=15.8250
# Month=35, Predicted=15.4174, Expected=15.4460
# Month=36, Predicted=15.3104, Expected=15.6360
# Month=37, Predicted=15.8454, Expected=15.6930
# Month=38, Predicted=16.0180, Expected=16.7550
# Month=39, Predicted=17.5898, Expected=16.5090
# Month=40, Predicted=17.2414, Expected=17.7230
# Month=41, Predicted=18.5007, Expected=18.6910
# Month=42, Predicted=18.6357, Expected=19.1270
# Month=43, Predicted=18.8698, Expected=19.5640
# Month=44, Predicted=19.2337, Expected=19.2030
# Month=45, Predicted=18.5840, Expected=18.2160
# Month=46, Predicted=17.5518, Expected=17.2110
# Month=47, Predicted=16.6653, Expected=16.6600
# Month=48, Predicted=16.3701, Expected=16.8310
# Month=49, Predicted=16.9500, Expected=15.7690
# Month=50, Predicted=15.9827, Expected=15.7310
# Month=51, Predicted=16.3105, Expected=15.9960
# Month=52, Predicted=16.4371, Expected=17.0210
# Month=53, Predicted=17.7367, Expected=17.5520
# Month=54, Predicted=17.7940, Expected=17.8370
# Month=55, Predicted=17.8806, Expected=17.8560
# Month=56, Predicted=17.4725, Expected=17.5710
# Month=57, Predicted=17.0217, Expected=17.0780
# Month=58, Predicted=16.5309, Expected=16.6600
# Month=59, Predicted=16.2463, Expected=16.4330
# Month=60, Predicted=16.2069, Expected=16.5840
# Run 6 — RMSE: 0.423218, MSE: 0.179113, NMSE: 0.0016515123
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.2279, Expected=13.7000
# Month=2, Predicted=14.1334, Expected=13.8140
# Month=3, Predicted=14.7165, Expected=14.3830
# Month=4, Predicted=15.0185, Expected=15.0470
# Month=5, Predicted=15.3356, Expected=15.6930
# Month=6, Predicted=15.8148, Expected=15.8440
# Month=7, Predicted=15.6112, Expected=15.7120
# Month=8, Predicted=15.2611, Expected=15.3130
# Month=9, Predicted=14.7211, Expected=14.7630
# Month=10, Predicted=14.2007, Expected=13.5480
# Month=11, Predicted=12.9036, Expected=13.5860
# Month=12, Predicted=13.5058, Expected=14.5160
# Month=13, Predicted=14.6343, Expected=14.3830
# Month=14, Predicted=14.7121, Expected=14.4970
# Month=15, Predicted=15.4729, Expected=14.7440
# Month=16, Predicted=15.2976, Expected=15.8060
# Month=17, Predicted=16.4441, Expected=16.5270
# Month=18, Predicted=16.6909, Expected=16.5460
# Month=19, Predicted=16.2640, Expected=16.7170
# Month=20, Predicted=16.3850, Expected=16.4330
# Month=21, Predicted=15.8889, Expected=15.7690
# Month=22, Predicted=15.1502, Expected=15.2750
# Month=23, Predicted=14.8447, Expected=15.1230
# Month=24, Predicted=15.0283, Expected=15.5410
# Month=25, Predicted=15.6660, Expected=15.8250
# Month=26, Predicted=16.2224, Expected=16.3760
# Month=27, Predicted=17.3341, Expected=16.3570
# Month=28, Predicted=16.7619, Expected=16.9070
# Month=29, Predicted=17.1918, Expected=17.0210
# Month=30, Predicted=16.8892, Expected=17.4190
# Month=31, Predicted=17.3584, Expected=17.5330
# Month=32, Predicted=17.2619, Expected=17.2680
# Month=33, Predicted=16.8070, Expected=16.6030
# Month=34, Predicted=16.0433, Expected=15.8250
# Month=35, Predicted=15.3275, Expected=15.4460
# Month=36, Predicted=15.2452, Expected=15.6360
# Month=37, Predicted=15.7359, Expected=15.6930
# Month=38, Predicted=16.0516, Expected=16.7550
# Month=39, Predicted=17.6646, Expected=16.5090
# Month=40, Predicted=17.0763, Expected=17.7230
# Month=41, Predicted=18.3653, Expected=18.6910
# Month=42, Predicted=18.9881, Expected=19.1270
# Month=43, Predicted=19.0185, Expected=19.5640
# Month=44, Predicted=19.3952, Expected=19.2030
# Month=45, Predicted=18.6344, Expected=18.2160
# Month=46, Predicted=17.4206, Expected=17.2110
# Month=47, Predicted=16.4818, Expected=16.6600
# Month=48, Predicted=16.2559, Expected=16.8310
# Month=49, Predicted=16.8861, Expected=15.7690
# Month=50, Predicted=15.7790, Expected=15.7310
# Month=51, Predicted=16.1358, Expected=15.9960
# Month=52, Predicted=17.0123, Expected=17.0210
# Month=53, Predicted=17.8977, Expected=17.5520
# Month=54, Predicted=17.7486, Expected=17.8370
# Month=55, Predicted=17.7754, Expected=17.8560
# Month=56, Predicted=17.5685, Expected=17.5710
# Month=57, Predicted=17.0544, Expected=17.0780
# Month=58, Predicted=16.4539, Expected=16.6600
# Month=59, Predicted=16.1698, Expected=16.4330
# Month=60, Predicted=16.1950, Expected=16.5840
# Run 7 — RMSE: 0.419858, MSE: 0.176281, NMSE: 0.0015345720
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.3561, Expected=13.7000
# Month=2, Predicted=14.2763, Expected=13.8140
# Month=3, Predicted=14.3876, Expected=14.3830
# Month=4, Predicted=15.0265, Expected=15.0470
# Month=5, Predicted=15.4742, Expected=15.6930
# Month=6, Predicted=15.7257, Expected=15.8440
# Month=7, Predicted=15.5508, Expected=15.7120
# Month=8, Predicted=15.2719, Expected=15.3130
# Month=9, Predicted=14.6713, Expected=14.7630
# Month=10, Predicted=14.1478, Expected=13.5480
# Month=11, Predicted=12.9344, Expected=13.5860
# Month=12, Predicted=13.5024, Expected=14.5160
# Month=13, Predicted=14.9871, Expected=14.3830
# Month=14, Predicted=14.7970, Expected=14.4970
# Month=15, Predicted=15.0470, Expected=14.7440
# Month=16, Predicted=15.3006, Expected=15.8060
# Month=17, Predicted=16.4007, Expected=16.5270
# Month=18, Predicted=16.6407, Expected=16.5460
# Month=19, Predicted=16.2279, Expected=16.7170
# Month=20, Predicted=16.3894, Expected=16.4330
# Month=21, Predicted=15.8445, Expected=15.7690
# Month=22, Predicted=15.0800, Expected=15.2750
# Month=23, Predicted=14.8033, Expected=15.1230
# Month=24, Predicted=14.9620, Expected=15.5410
# Month=25, Predicted=15.7976, Expected=15.8250
# Month=26, Predicted=16.2917, Expected=16.3760
# Month=27, Predicted=17.0369, Expected=16.3570
# Month=28, Predicted=16.8287, Expected=16.9070
# Month=29, Predicted=17.3608, Expected=17.0210
# Month=30, Predicted=17.0060, Expected=17.4190
# Month=31, Predicted=17.2652, Expected=17.5330
# Month=32, Predicted=17.2055, Expected=17.2680
# Month=33, Predicted=16.7554, Expected=16.6030
# Month=34, Predicted=16.0013, Expected=15.8250
# Month=35, Predicted=15.3454, Expected=15.4460
# Month=36, Predicted=15.2812, Expected=15.6360
# Month=37, Predicted=15.8820, Expected=15.6930
# Month=38, Predicted=16.1314, Expected=16.7550
# Month=39, Predicted=17.5622, Expected=16.5090
# Month=40, Predicted=16.9030, Expected=17.7230
# Month=41, Predicted=18.2861, Expected=18.6910
# Month=42, Predicted=18.7702, Expected=19.1270
# Month=43, Predicted=18.8670, Expected=19.5640
# Month=44, Predicted=19.2875, Expected=19.2030
# Month=45, Predicted=18.5665, Expected=18.2160
# Month=46, Predicted=17.3695, Expected=17.2110
# Month=47, Predicted=16.5130, Expected=16.6600
# Month=48, Predicted=16.2826, Expected=16.8310
# Month=49, Predicted=16.8791, Expected=15.7690
# Month=50, Predicted=15.7500, Expected=15.7310
# Month=51, Predicted=16.1165, Expected=15.9960
# Month=52, Predicted=16.6393, Expected=17.0210
# Month=53, Predicted=17.8700, Expected=17.5520
# Month=54, Predicted=18.0504, Expected=17.8370
# Month=55, Predicted=17.8731, Expected=17.8560
# Month=56, Predicted=17.5690, Expected=17.5710
# Month=57, Predicted=17.1162, Expected=17.0780
# Month=58, Predicted=16.4206, Expected=16.6600
# Month=59, Predicted=16.1122, Expected=16.4330
# Month=60, Predicted=16.1387, Expected=16.5840
# Run 8 — RMSE: 0.411915, MSE: 0.169674, NMSE: 0.0015279762
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.3053, Expected=13.7000
# Month=2, Predicted=14.1884, Expected=13.8140
# Month=3, Predicted=14.1985, Expected=14.3830
# Month=4, Predicted=14.9379, Expected=15.0470
# Month=5, Predicted=15.4320, Expected=15.6930
# Month=6, Predicted=15.9087, Expected=15.8440
# Month=7, Predicted=15.6490, Expected=15.7120
# Month=8, Predicted=15.2858, Expected=15.3130
# Month=9, Predicted=14.7566, Expected=14.7630
# Month=10, Predicted=14.2156, Expected=13.5480
# Month=11, Predicted=12.9458, Expected=13.5860
# Month=12, Predicted=13.7553, Expected=14.5160
# Month=13, Predicted=15.1307, Expected=14.3830
# Month=14, Predicted=14.8664, Expected=14.4970
# Month=15, Predicted=14.7374, Expected=14.7440
# Month=16, Predicted=14.9629, Expected=15.8060
# Month=17, Predicted=16.4851, Expected=16.5270
# Month=18, Predicted=16.6861, Expected=16.5460
# Month=19, Predicted=16.3264, Expected=16.7170
# Month=20, Predicted=16.4939, Expected=16.4330
# Month=21, Predicted=15.9330, Expected=15.7690
# Month=22, Predicted=15.2012, Expected=15.2750
# Month=23, Predicted=14.8705, Expected=15.1230
# Month=24, Predicted=15.0342, Expected=15.5410
# Month=25, Predicted=15.9165, Expected=15.8250
# Month=26, Predicted=16.1692, Expected=16.3760
# Month=27, Predicted=16.8664, Expected=16.3570
# Month=28, Predicted=16.6056, Expected=16.9070
# Month=29, Predicted=17.4049, Expected=17.0210
# Month=30, Predicted=16.9885, Expected=17.4190
# Month=31, Predicted=17.5156, Expected=17.5330
# Month=32, Predicted=17.2881, Expected=17.2680
# Month=33, Predicted=16.8511, Expected=16.6030
# Month=34, Predicted=16.0561, Expected=15.8250
# Month=35, Predicted=15.3144, Expected=15.4460
# Month=36, Predicted=15.2573, Expected=15.6360
# Month=37, Predicted=15.9279, Expected=15.6930
# Month=38, Predicted=16.0162, Expected=16.7550
# Month=39, Predicted=17.5541, Expected=16.5090
# Month=40, Predicted=17.1408, Expected=17.7230
# Month=41, Predicted=18.6558, Expected=18.6910
# Month=42, Predicted=18.8094, Expected=19.1270
# Month=43, Predicted=18.9229, Expected=19.5640
# Month=44, Predicted=19.3146, Expected=19.2030
# Month=45, Predicted=18.5760, Expected=18.2160
# Month=46, Predicted=17.4340, Expected=17.2110
# Month=47, Predicted=16.5392, Expected=16.6600
# Month=48, Predicted=16.3105, Expected=16.8310
# Month=49, Predicted=17.0828, Expected=15.7690
# Month=50, Predicted=16.2578, Expected=15.7310
# Month=51, Predicted=16.2619, Expected=15.9960
# Month=52, Predicted=16.5573, Expected=17.0210
# Month=53, Predicted=17.8033, Expected=17.5520
# Month=54, Predicted=17.9651, Expected=17.8370
# Month=55, Predicted=17.8869, Expected=17.8560
# Month=56, Predicted=17.5313, Expected=17.5710
# Month=57, Predicted=17.0230, Expected=17.0780
# Month=58, Predicted=16.4484, Expected=16.6600
# Month=59, Predicted=16.1290, Expected=16.4330
# Month=60, Predicted=16.0901, Expected=16.5840
# Run 9 — RMSE: 0.419897, MSE: 0.176314, NMSE: 0.0015534987
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.3537, Expected=13.7000
# Month=2, Predicted=14.2294, Expected=13.8140
# Month=3, Predicted=14.3116, Expected=14.3830
# Month=4, Predicted=15.0092, Expected=15.0470
# Month=5, Predicted=15.3399, Expected=15.6930
# Month=6, Predicted=15.8109, Expected=15.8440
# Month=7, Predicted=15.6457, Expected=15.7120
# Month=8, Predicted=15.2769, Expected=15.3130
# Month=9, Predicted=14.8065, Expected=14.7630
# Month=10, Predicted=14.2401, Expected=13.5480
# Month=11, Predicted=12.9341, Expected=13.5860
# Month=12, Predicted=13.5027, Expected=14.5160
# Month=13, Predicted=14.8990, Expected=14.3830
# Month=14, Predicted=14.6942, Expected=14.4970
# Month=15, Predicted=15.0743, Expected=14.7440
# Month=16, Predicted=15.0622, Expected=15.8060
# Month=17, Predicted=16.2529, Expected=16.5270
# Month=18, Predicted=16.6787, Expected=16.5460
# Month=19, Predicted=16.3261, Expected=16.7170
# Month=20, Predicted=16.4172, Expected=16.4330
# Month=21, Predicted=16.0077, Expected=15.7690
# Month=22, Predicted=15.1887, Expected=15.2750
# Month=23, Predicted=14.8397, Expected=15.1230
# Month=24, Predicted=14.9679, Expected=15.5410
# Month=25, Predicted=15.7878, Expected=15.8250
# Month=26, Predicted=16.2034, Expected=16.3760
# Month=27, Predicted=16.9716, Expected=16.3570
# Month=28, Predicted=16.6492, Expected=16.9070
# Month=29, Predicted=17.2430, Expected=17.0210
# Month=30, Predicted=16.9936, Expected=17.4190
# Month=31, Predicted=17.3684, Expected=17.5330
# Month=32, Predicted=17.3891, Expected=17.2680
# Month=33, Predicted=16.9233, Expected=16.6030
# Month=34, Predicted=16.1328, Expected=15.8250
# Month=35, Predicted=15.3668, Expected=15.4460
# Month=36, Predicted=15.2593, Expected=15.6360
# Month=37, Predicted=15.8803, Expected=15.6930
# Month=38, Predicted=16.0777, Expected=16.7550
# Month=39, Predicted=17.4689, Expected=16.5090
# Month=40, Predicted=16.7073, Expected=17.7230
# Month=41, Predicted=18.3565, Expected=18.6910
# Month=42, Predicted=18.9021, Expected=19.1270
# Month=43, Predicted=19.0015, Expected=19.5640
# Month=44, Predicted=19.3816, Expected=19.2030
# Month=45, Predicted=18.7329, Expected=18.2160
# Month=46, Predicted=17.4730, Expected=17.2110
# Month=47, Predicted=16.5580, Expected=16.6600
# Month=48, Predicted=16.2589, Expected=16.8310
# Month=49, Predicted=16.8936, Expected=15.7690
# Month=50, Predicted=15.8078, Expected=15.7310
# Month=51, Predicted=16.3827, Expected=15.9960
# Month=52, Predicted=16.7019, Expected=17.0210
# Month=53, Predicted=17.8344, Expected=17.5520
# Month=54, Predicted=17.9457, Expected=17.8370
# Month=55, Predicted=17.9077, Expected=17.8560
# Month=56, Predicted=17.5095, Expected=17.5710
# Month=57, Predicted=17.0108, Expected=17.0780
# Month=58, Predicted=16.4884, Expected=16.6600
# Month=59, Predicted=16.1777, Expected=16.4330
# Month=60, Predicted=16.1400, Expected=16.5840
# Run 10 — RMSE: 0.422095, MSE: 0.178164, NMSE: 0.0015657165
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.3291, Expected=13.7000
# Month=2, Predicted=14.1895, Expected=13.8140
# Month=3, Predicted=14.1676, Expected=14.3830
# Month=4, Predicted=14.7581, Expected=15.0470
# Month=5, Predicted=15.3027, Expected=15.6930
# Month=6, Predicted=15.8011, Expected=15.8440
# Month=7, Predicted=15.6467, Expected=15.7120
# Month=8, Predicted=15.3278, Expected=15.3130
# Month=9, Predicted=14.8052, Expected=14.7630
# Month=10, Predicted=14.2362, Expected=13.5480
# Month=11, Predicted=12.8853, Expected=13.5860
# Month=12, Predicted=13.4733, Expected=14.5160
# Month=13, Predicted=15.0503, Expected=14.3830
# Month=14, Predicted=14.7859, Expected=14.4970
# Month=15, Predicted=14.8839, Expected=14.7440
# Month=16, Predicted=15.0217, Expected=15.8060
# Month=17, Predicted=16.2585, Expected=16.5270
# Month=18, Predicted=16.7095, Expected=16.5460
# Month=19, Predicted=16.3254, Expected=16.7170
# Month=20, Predicted=16.4544, Expected=16.4330
# Month=21, Predicted=15.9741, Expected=15.7690
# Month=22, Predicted=15.1883, Expected=15.2750
# Month=23, Predicted=14.8068, Expected=15.1230
# Month=24, Predicted=14.9391, Expected=15.5410
# Month=25, Predicted=15.8087, Expected=15.8250
# Month=26, Predicted=16.2238, Expected=16.3760
# Month=27, Predicted=16.8719, Expected=16.3570
# Month=28, Predicted=16.5138, Expected=16.9070
# Month=29, Predicted=17.1075, Expected=17.0210
# Month=30, Predicted=16.9275, Expected=17.4190
# Month=31, Predicted=17.3723, Expected=17.5330
# Month=32, Predicted=17.3621, Expected=17.2680
# Month=33, Predicted=16.9414, Expected=16.6030
# Month=34, Predicted=16.1252, Expected=15.8250
# Month=35, Predicted=15.3208, Expected=15.4460
# Month=36, Predicted=15.1692, Expected=15.6360
# Month=37, Predicted=15.7824, Expected=15.6930
# Month=38, Predicted=15.9910, Expected=16.7550
# Month=39, Predicted=17.4250, Expected=16.5090
# Month=40, Predicted=16.7049, Expected=17.7230
# Month=41, Predicted=18.2429, Expected=18.6910
# Month=42, Predicted=18.9368, Expected=19.1270
# Month=43, Predicted=19.0103, Expected=19.5640
# Month=44, Predicted=19.3417, Expected=19.2030
# Month=45, Predicted=18.6544, Expected=18.2160
# Month=46, Predicted=17.4566, Expected=17.2110
# Month=47, Predicted=16.4526, Expected=16.6600
# Month=48, Predicted=16.1727, Expected=16.8310
# Month=49, Predicted=16.9154, Expected=15.7690
# Month=50, Predicted=15.6972, Expected=15.7310
# Month=51, Predicted=16.0941, Expected=15.9960
# Month=52, Predicted=16.5648, Expected=17.0210
# Month=53, Predicted=17.7814, Expected=17.5520
# Month=54, Predicted=18.0009, Expected=17.8370
# Month=55, Predicted=17.9530, Expected=17.8560
# Month=56, Predicted=17.6501, Expected=17.5710
# Month=57, Predicted=17.1245, Expected=17.0780
# Month=58, Predicted=16.5251, Expected=16.6600
# Month=59, Predicted=16.1885, Expected=16.4330
# Month=60, Predicted=16.1772, Expected=16.5840
# Run 11 — RMSE: 0.434867, MSE: 0.189110, NMSE: 0.0016366294
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2659, Expected=13.7000
# Month=2, Predicted=14.2691, Expected=13.8140
# Month=3, Predicted=14.7950, Expected=14.3830
# Month=4, Predicted=15.2518, Expected=15.0470
# Month=5, Predicted=15.3051, Expected=15.6930
# Month=6, Predicted=15.6570, Expected=15.8440
# Month=7, Predicted=15.5019, Expected=15.7120
# Month=8, Predicted=15.4888, Expected=15.3130
# Month=9, Predicted=14.5741, Expected=14.7630
# Month=10, Predicted=14.1898, Expected=13.5480
# Month=11, Predicted=13.1904, Expected=13.5860
# Month=12, Predicted=13.5782, Expected=14.5160
# Month=13, Predicted=14.9477, Expected=14.3830
# Month=14, Predicted=14.9992, Expected=14.4970
# Month=15, Predicted=15.5025, Expected=14.7440
# Month=16, Predicted=15.5439, Expected=15.8060
# Month=17, Predicted=16.0260, Expected=16.5270
# Month=18, Predicted=16.4631, Expected=16.5460
# Month=19, Predicted=16.1251, Expected=16.7170
# Month=20, Predicted=16.6155, Expected=16.4330
# Month=21, Predicted=15.7029, Expected=15.7690
# Month=22, Predicted=15.2155, Expected=15.2750
# Month=23, Predicted=15.0314, Expected=15.1230
# Month=24, Predicted=15.0904, Expected=15.5410
# Month=25, Predicted=15.8111, Expected=15.8250
# Month=26, Predicted=16.4482, Expected=16.3760
# Month=27, Predicted=17.3240, Expected=16.3570
# Month=28, Predicted=17.1078, Expected=16.9070
# Month=29, Predicted=17.1063, Expected=17.0210
# Month=30, Predicted=16.9662, Expected=17.4190
# Month=31, Predicted=17.0919, Expected=17.5330
# Month=32, Predicted=17.3253, Expected=17.2680
# Month=33, Predicted=16.5500, Expected=16.6030
# Month=34, Predicted=16.0287, Expected=15.8250
# Month=35, Predicted=15.5182, Expected=15.4460
# Month=36, Predicted=15.3542, Expected=15.6360
# Month=37, Predicted=15.8089, Expected=15.6930
# Month=38, Predicted=16.1668, Expected=16.7550
# Month=39, Predicted=17.5956, Expected=16.5090
# Month=40, Predicted=17.3389, Expected=17.7230
# Month=41, Predicted=17.9657, Expected=18.6910
# Month=42, Predicted=18.6217, Expected=19.1270
# Month=43, Predicted=18.7554, Expected=19.5640
# Month=44, Predicted=19.4292, Expected=19.2030
# Month=45, Predicted=18.4595, Expected=18.2160
# Month=46, Predicted=17.6237, Expected=17.2110
# Month=47, Predicted=16.8938, Expected=16.6600
# Month=48, Predicted=16.5340, Expected=16.8310
# Month=49, Predicted=17.0024, Expected=15.7690
# Month=50, Predicted=15.8096, Expected=15.7310
# Month=51, Predicted=16.5128, Expected=15.9960
# Month=52, Predicted=16.9516, Expected=17.0210
# Month=53, Predicted=17.4218, Expected=17.5520
# Month=54, Predicted=17.5588, Expected=17.8370
# Month=55, Predicted=17.6013, Expected=17.8560
# Month=56, Predicted=17.3480, Expected=17.5710
# Month=57, Predicted=17.0448, Expected=17.0780
# Month=58, Predicted=16.4541, Expected=16.6600
# Month=59, Predicted=16.2920, Expected=16.4330
# Month=60, Predicted=16.3458, Expected=16.5840
# Run 12 — RMSE: 0.440114, MSE: 0.193700, NMSE: 0.0019195295
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.3834, Expected=13.7000
# Month=2, Predicted=14.2921, Expected=13.8140
# Month=3, Predicted=14.3542, Expected=14.3830
# Month=4, Predicted=14.8744, Expected=15.0470
# Month=5, Predicted=15.3411, Expected=15.6930
# Month=6, Predicted=15.7308, Expected=15.8440
# Month=7, Predicted=15.5211, Expected=15.7120
# Month=8, Predicted=15.1787, Expected=15.3130
# Month=9, Predicted=14.6986, Expected=14.7630
# Month=10, Predicted=14.1969, Expected=13.5480
# Month=11, Predicted=12.9374, Expected=13.5860
# Month=12, Predicted=13.4972, Expected=14.5160
# Month=13, Predicted=15.0357, Expected=14.3830
# Month=14, Predicted=14.8677, Expected=14.4970
# Month=15, Predicted=14.9990, Expected=14.7440
# Month=16, Predicted=15.1069, Expected=15.8060
# Month=17, Predicted=16.1722, Expected=16.5270
# Month=18, Predicted=16.6191, Expected=16.5460
# Month=19, Predicted=16.2248, Expected=16.7170
# Month=20, Predicted=16.2782, Expected=16.4330
# Month=21, Predicted=15.8771, Expected=15.7690
# Month=22, Predicted=15.1840, Expected=15.2750
# Month=23, Predicted=14.8599, Expected=15.1230
# Month=24, Predicted=15.0308, Expected=15.5410
# Month=25, Predicted=15.9021, Expected=15.8250
# Month=26, Predicted=16.3545, Expected=16.3760
# Month=27, Predicted=16.9765, Expected=16.3570
# Month=28, Predicted=16.6515, Expected=16.9070
# Month=29, Predicted=17.0809, Expected=17.0210
# Month=30, Predicted=16.8389, Expected=17.4190
# Month=31, Predicted=17.1485, Expected=17.5330
# Month=32, Predicted=17.1557, Expected=17.2680
# Month=33, Predicted=16.8259, Expected=16.6030
# Month=34, Predicted=16.1304, Expected=15.8250
# Month=35, Predicted=15.4190, Expected=15.4460
# Month=36, Predicted=15.3084, Expected=15.6360
# Month=37, Predicted=15.8998, Expected=15.6930
# Month=38, Predicted=16.1087, Expected=16.7550
# Month=39, Predicted=17.4418, Expected=16.5090
# Month=40, Predicted=16.7867, Expected=17.7230
# Month=41, Predicted=18.1259, Expected=18.6910
# Month=42, Predicted=18.8671, Expected=19.1270
# Month=43, Predicted=18.9470, Expected=19.5640
# Month=44, Predicted=19.2228, Expected=19.2030
# Month=45, Predicted=18.6202, Expected=18.2160
# Month=46, Predicted=17.5038, Expected=17.2110
# Month=47, Predicted=16.5428, Expected=16.6600
# Month=48, Predicted=16.2470, Expected=16.8310
# Month=49, Predicted=16.9106, Expected=15.7690
# Month=50, Predicted=15.7574, Expected=15.7310
# Month=51, Predicted=16.0922, Expected=15.9960
# Month=52, Predicted=16.5235, Expected=17.0210
# Month=53, Predicted=17.6873, Expected=17.5520
# Month=54, Predicted=17.9547, Expected=17.8370
# Month=55, Predicted=17.8823, Expected=17.8560
# Month=56, Predicted=17.5370, Expected=17.5710
# Month=57, Predicted=17.0088, Expected=17.0780
# Month=58, Predicted=16.4276, Expected=16.6600
# Month=59, Predicted=16.1145, Expected=16.4330
# Month=60, Predicted=16.1298, Expected=16.5840
# Run 13 — RMSE: 0.429072, MSE: 0.184103, NMSE: 0.0016978296
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.3342, Expected=13.7000
# Month=2, Predicted=14.1847, Expected=13.8140
# Month=3, Predicted=14.0549, Expected=14.3830
# Month=4, Predicted=14.8011, Expected=15.0470
# Month=5, Predicted=15.4002, Expected=15.6930
# Month=6, Predicted=15.8930, Expected=15.8440
# Month=7, Predicted=15.6450, Expected=15.7120
# Month=8, Predicted=15.3311, Expected=15.3130
# Month=9, Predicted=14.8301, Expected=14.7630
# Month=10, Predicted=14.2750, Expected=13.5480
# Month=11, Predicted=12.8825, Expected=13.5860
# Month=12, Predicted=13.6169, Expected=14.5160
# Month=13, Predicted=15.0971, Expected=14.3830
# Month=14, Predicted=14.4530, Expected=14.4970
# Month=15, Predicted=14.7051, Expected=14.7440
# Month=16, Predicted=14.9995, Expected=15.8060
# Month=17, Predicted=16.3847, Expected=16.5270
# Month=18, Predicted=16.7693, Expected=16.5460
# Month=19, Predicted=16.2509, Expected=16.7170
# Month=20, Predicted=16.4656, Expected=16.4330
# Month=21, Predicted=15.9607, Expected=15.7690
# Month=22, Predicted=15.1860, Expected=15.2750
# Month=23, Predicted=14.8499, Expected=15.1230
# Month=24, Predicted=14.9889, Expected=15.5410
# Month=25, Predicted=15.8349, Expected=15.8250
# Month=26, Predicted=16.1201, Expected=16.3760
# Month=27, Predicted=16.8062, Expected=16.3570
# Month=28, Predicted=16.4393, Expected=16.9070
# Month=29, Predicted=17.2475, Expected=17.0210
# Month=30, Predicted=17.0404, Expected=17.4190
# Month=31, Predicted=17.5387, Expected=17.5330
# Month=32, Predicted=17.4350, Expected=17.2680
# Month=33, Predicted=16.9532, Expected=16.6030
# Month=34, Predicted=16.1331, Expected=15.8250
# Month=35, Predicted=15.3772, Expected=15.4460
# Month=36, Predicted=15.2959, Expected=15.6360
# Month=37, Predicted=15.8905, Expected=15.6930
# Month=38, Predicted=15.9218, Expected=16.7550
# Month=39, Predicted=17.4155, Expected=16.5090
# Month=40, Predicted=16.3803, Expected=17.7230
# Month=41, Predicted=18.2865, Expected=18.6910
# Month=42, Predicted=18.9718, Expected=19.1270
# Month=43, Predicted=18.9497, Expected=19.5640
# Month=44, Predicted=19.3280, Expected=19.2030
# Month=45, Predicted=18.5886, Expected=18.2160
# Month=46, Predicted=17.4373, Expected=17.2110
# Month=47, Predicted=16.4880, Expected=16.6600
# Month=48, Predicted=16.2019, Expected=16.8310
# Month=49, Predicted=16.8794, Expected=15.7690
# Month=50, Predicted=15.3921, Expected=15.7310
# Month=51, Predicted=16.0032, Expected=15.9960
# Month=52, Predicted=16.5017, Expected=17.0210
# Month=53, Predicted=17.7698, Expected=17.5520
# Month=54, Predicted=17.9159, Expected=17.8370
# Month=55, Predicted=17.8788, Expected=17.8560
# Month=56, Predicted=17.6330, Expected=17.5710
# Month=57, Predicted=17.1591, Expected=17.0780
# Month=58, Predicted=16.5943, Expected=16.6600
# Month=59, Predicted=16.2743, Expected=16.4330
# Month=60, Predicted=16.2373, Expected=16.5840
# Run 14 — RMSE: 0.441158, MSE: 0.194621, NMSE: 0.0016808794
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.3464, Expected=13.7000
# Month=2, Predicted=14.1523, Expected=13.8140
# Month=3, Predicted=13.8256, Expected=14.3830
# Month=4, Predicted=14.7262, Expected=15.0470
# Month=5, Predicted=15.3756, Expected=15.6930
# Month=6, Predicted=15.9538, Expected=15.8440
# Month=7, Predicted=15.7662, Expected=15.7120
# Month=8, Predicted=15.5077, Expected=15.3130
# Month=9, Predicted=14.9909, Expected=14.7630
# Month=10, Predicted=14.3952, Expected=13.5480
# Month=11, Predicted=12.7912, Expected=13.5860
# Month=12, Predicted=13.8040, Expected=14.5160
# Month=13, Predicted=15.2920, Expected=14.3830
# Month=14, Predicted=14.1829, Expected=14.4970
# Month=15, Predicted=14.5317, Expected=14.7440
# Month=16, Predicted=14.8803, Expected=15.8060
# Month=17, Predicted=16.4449, Expected=16.5270
# Month=18, Predicted=16.7782, Expected=16.5460
# Month=19, Predicted=16.3384, Expected=16.7170
# Month=20, Predicted=16.7024, Expected=16.4330
# Month=21, Predicted=16.1408, Expected=15.7690
# Month=22, Predicted=15.2863, Expected=15.2750
# Month=23, Predicted=14.9797, Expected=15.1230
# Month=24, Predicted=15.1373, Expected=15.5410
# Month=25, Predicted=15.9653, Expected=15.8250
# Month=26, Predicted=16.0158, Expected=16.3760
# Month=27, Predicted=16.7088, Expected=16.3570
# Month=28, Predicted=16.2355, Expected=16.9070
# Month=29, Predicted=17.2356, Expected=17.0210
# Month=30, Predicted=16.9881, Expected=17.4190
# Month=31, Predicted=17.6229, Expected=17.5330
# Month=32, Predicted=17.5172, Expected=17.2680
# Month=33, Predicted=17.0221, Expected=16.6030
# Month=34, Predicted=16.1417, Expected=15.8250
# Month=35, Predicted=15.3402, Expected=15.4460
# Month=36, Predicted=15.3000, Expected=15.6360
# Month=37, Predicted=15.9597, Expected=15.6930
# Month=38, Predicted=15.8018, Expected=16.7550
# Month=39, Predicted=17.4854, Expected=16.5090
# Month=40, Predicted=16.1915, Expected=17.7230
# Month=41, Predicted=18.4389, Expected=18.6910
# Month=42, Predicted=19.0488, Expected=19.1270
# Month=43, Predicted=19.1148, Expected=19.5640
# Month=44, Predicted=19.6223, Expected=19.2030
# Month=45, Predicted=18.7890, Expected=18.2160
# Month=46, Predicted=17.5155, Expected=17.2110
# Month=47, Predicted=16.5352, Expected=16.6600
# Month=48, Predicted=16.3413, Expected=16.8310
# Month=49, Predicted=17.1472, Expected=15.7690
# Month=50, Predicted=15.0990, Expected=15.7310
# Month=51, Predicted=15.8733, Expected=15.9960
# Month=52, Predicted=16.3219, Expected=17.0210
# Month=53, Predicted=17.7234, Expected=17.5520
# Month=54, Predicted=17.7276, Expected=17.8370
# Month=55, Predicted=17.8474, Expected=17.8560
# Month=56, Predicted=17.7292, Expected=17.5710
# Month=57, Predicted=17.2938, Expected=17.0780
# Month=58, Predicted=16.7188, Expected=16.6600
# Month=59, Predicted=16.4139, Expected=16.4330
# Month=60, Predicted=16.3693, Expected=16.5840
# Run 15 — RMSE: 0.498901, MSE: 0.248902, NMSE: 0.0020298047
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1978, Expected=13.7000
# Month=2, Predicted=14.0644, Expected=13.8140
# Month=3, Predicted=13.9480, Expected=14.3830
# Month=4, Predicted=14.6232, Expected=15.0470
# Month=5, Predicted=15.2620, Expected=15.6930
# Month=6, Predicted=15.8089, Expected=15.8440
# Month=7, Predicted=15.6181, Expected=15.7120
# Month=8, Predicted=15.2023, Expected=15.3130
# Month=9, Predicted=14.6814, Expected=14.7630
# Month=10, Predicted=14.0789, Expected=13.5480
# Month=11, Predicted=12.6688, Expected=13.5860
# Month=12, Predicted=13.6335, Expected=14.5160
# Month=13, Predicted=15.0835, Expected=14.3830
# Month=14, Predicted=14.7226, Expected=14.4970
# Month=15, Predicted=14.3804, Expected=14.7440
# Month=16, Predicted=14.7570, Expected=15.8060
# Month=17, Predicted=16.3479, Expected=16.5270
# Month=18, Predicted=16.7413, Expected=16.5460
# Month=19, Predicted=16.2196, Expected=16.7170
# Month=20, Predicted=16.3431, Expected=16.4330
# Month=21, Predicted=15.9234, Expected=15.7690
# Month=22, Predicted=14.9941, Expected=15.2750
# Month=23, Predicted=14.6262, Expected=15.1230
# Month=24, Predicted=14.8199, Expected=15.5410
# Month=25, Predicted=15.7530, Expected=15.8250
# Month=26, Predicted=15.9738, Expected=16.3760
# Month=27, Predicted=16.5788, Expected=16.3570
# Month=28, Predicted=16.2522, Expected=16.9070
# Month=29, Predicted=17.0304, Expected=17.0210
# Month=30, Predicted=16.9388, Expected=17.4190
# Month=31, Predicted=17.3757, Expected=17.5330
# Month=32, Predicted=17.3534, Expected=17.2680
# Month=33, Predicted=16.7942, Expected=16.6030
# Month=34, Predicted=15.8800, Expected=15.8250
# Month=35, Predicted=15.0776, Expected=15.4460
# Month=36, Predicted=15.0635, Expected=15.6360
# Month=37, Predicted=15.8068, Expected=15.6930
# Month=38, Predicted=15.8588, Expected=16.7550
# Month=39, Predicted=17.4754, Expected=16.5090
# Month=40, Predicted=16.8984, Expected=17.7230
# Month=41, Predicted=18.4785, Expected=18.6910
# Month=42, Predicted=18.9749, Expected=19.1270
# Month=43, Predicted=18.9854, Expected=19.5640
# Month=44, Predicted=19.2965, Expected=19.2030
# Month=45, Predicted=18.6031, Expected=18.2160
# Month=46, Predicted=17.1705, Expected=17.2110
# Month=47, Predicted=16.1936, Expected=16.6600
# Month=48, Predicted=16.0176, Expected=16.8310
# Month=49, Predicted=16.8646, Expected=15.7690
# Month=50, Predicted=15.7080, Expected=15.7310
# Month=51, Predicted=15.8304, Expected=15.9960
# Month=52, Predicted=16.2625, Expected=17.0210
# Month=53, Predicted=17.6894, Expected=17.5520
# Month=54, Predicted=17.8769, Expected=17.8370
# Month=55, Predicted=17.7871, Expected=17.8560
# Month=56, Predicted=17.5896, Expected=17.5710
# Month=57, Predicted=17.1316, Expected=17.0780
# Month=58, Predicted=16.5300, Expected=16.6600
# Month=59, Predicted=16.2118, Expected=16.4330
# Month=60, Predicted=16.2101, Expected=16.5840
# Run 16 — RMSE: 0.467099, MSE: 0.218182, NMSE: 0.0017663533
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.2619, Expected=13.7000
# Month=2, Predicted=14.1964, Expected=13.8140
# Month=3, Predicted=14.4581, Expected=14.3830
# Month=4, Predicted=15.1109, Expected=15.0470
# Month=5, Predicted=15.4456, Expected=15.6930
# Month=6, Predicted=15.6426, Expected=15.8440
# Month=7, Predicted=15.5265, Expected=15.7120
# Month=8, Predicted=15.2031, Expected=15.3130
# Month=9, Predicted=14.7128, Expected=14.7630
# Month=10, Predicted=14.1897, Expected=13.5480
# Month=11, Predicted=13.0186, Expected=13.5860
# Month=12, Predicted=13.5739, Expected=14.5160
# Month=13, Predicted=14.8486, Expected=14.3830
# Month=14, Predicted=14.8358, Expected=14.4970
# Month=15, Predicted=15.1743, Expected=14.7440
# Month=16, Predicted=15.3760, Expected=15.8060
# Month=17, Predicted=16.3048, Expected=16.5270
# Month=18, Predicted=16.4789, Expected=16.5460
# Month=19, Predicted=16.1851, Expected=16.7170
# Month=20, Predicted=16.3037, Expected=16.4330
# Month=21, Predicted=15.8591, Expected=15.7690
# Month=22, Predicted=15.1811, Expected=15.2750
# Month=23, Predicted=14.9521, Expected=15.1230
# Month=24, Predicted=15.0956, Expected=15.5410
# Month=25, Predicted=15.8074, Expected=15.8250
# Month=26, Predicted=16.3802, Expected=16.3760
# Month=27, Predicted=17.1342, Expected=16.3570
# Month=28, Predicted=16.8519, Expected=16.9070
# Month=29, Predicted=17.1561, Expected=17.0210
# Month=30, Predicted=16.7530, Expected=17.4190
# Month=31, Predicted=17.1346, Expected=17.5330
# Month=32, Predicted=17.1210, Expected=17.2680
# Month=33, Predicted=16.8276, Expected=16.6030
# Month=34, Predicted=16.2280, Expected=15.8250
# Month=35, Predicted=15.6167, Expected=15.4460
# Month=36, Predicted=15.4826, Expected=15.6360
# Month=37, Predicted=16.0518, Expected=15.6930
# Month=38, Predicted=16.3148, Expected=16.7550
# Month=39, Predicted=17.5960, Expected=16.5090
# Month=40, Predicted=16.7836, Expected=17.7230
# Month=41, Predicted=18.0379, Expected=18.6910
# Month=42, Predicted=18.6167, Expected=19.1270
# Month=43, Predicted=18.7941, Expected=19.5640
# Month=44, Predicted=19.2118, Expected=19.2030
# Month=45, Predicted=18.6585, Expected=18.2160
# Month=46, Predicted=17.6612, Expected=17.2110
# Month=47, Predicted=16.8532, Expected=16.6600
# ...
# Month=26, Predicted=16.1368, Expected=16.3760
# Month=27, Predicted=16.8505, Expected=16.3570
# Month=28, Predicted=16.5258, Expected=16.9070
# Month=29, Predicted=17.2871, Expected=17.0210
# Month=30, Predicted=16.9385, Expected=17.4190
# Month=31, Predicted=17.4246, Expected=17.5330
# Month=32, Predicted=17.2944, Expected=17.2680
# Month=33, Predicted=16.8664, Expected=16.6030
# Month=34, Predicted=16.0923, Expected=15.8250
# Month=35, Predicted=15.3712, Expected=15.4460
# Month=36, Predicted=15.2962, Expected=15.6360
# Month=37, Predicted=15.8932, Expected=15.6930
# Month=38, Predicted=15.9689, Expected=16.7550
# Month=39, Predicted=17.5463, Expected=16.5090
# Month=40, Predicted=17.1051, Expected=17.7230
# Month=41, Predicted=18.6154, Expected=18.6910
# Month=42, Predicted=18.8732, Expected=19.1270
# Month=43, Predicted=18.9075, Expected=19.5640
# Month=44, Predicted=19.2544, Expected=19.2030
# Month=45, Predicted=18.5242, Expected=18.2160
# Month=46, Predicted=17.3966, Expected=17.2110
# Month=47, Predicted=16.5185, Expected=16.6600
# Month=48, Predicted=16.3044, Expected=16.8310
# Month=49, Predicted=17.0104, Expected=15.7690
# Month=50, Predicted=16.0865, Expected=15.7310
# Month=51, Predicted=16.2495, Expected=15.9960
# Month=52, Predicted=16.4283, Expected=17.0210
# Month=53, Predicted=17.7715, Expected=17.5520
# Month=54, Predicted=17.9311, Expected=17.8370
# Month=55, Predicted=17.9260, Expected=17.8560
# Month=56, Predicted=17.5864, Expected=17.5710
# Month=57, Predicted=17.0692, Expected=17.0780
# Month=58, Predicted=16.4913, Expected=16.6600
# Month=59, Predicted=16.1873, Expected=16.4330
# Month=60, Predicted=16.1750, Expected=16.5840
# Run 25 — RMSE: 0.418122, MSE: 0.174826, NMSE: 0.0015464977
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.4378, Expected=13.7000
# Month=2, Predicted=14.2933, Expected=13.8140
# Month=3, Predicted=14.3955, Expected=14.3830
# Month=4, Predicted=14.9339, Expected=15.0470
# Month=5, Predicted=15.3842, Expected=15.6930
# Month=6, Predicted=15.6930, Expected=15.8440
# Month=7, Predicted=15.3994, Expected=15.7120
# Month=8, Predicted=15.1204, Expected=15.3130
# Month=9, Predicted=14.7065, Expected=14.7630
# Month=10, Predicted=14.2138, Expected=13.5480
# Month=11, Predicted=13.0090, Expected=13.5860
# Month=12, Predicted=13.7152, Expected=14.5160
# Month=13, Predicted=14.7901, Expected=14.3830
# Month=14, Predicted=14.8749, Expected=14.4970
# Month=15, Predicted=15.0794, Expected=14.7440
# Month=16, Predicted=15.2373, Expected=15.8060
# Month=17, Predicted=16.2634, Expected=16.5270
# Month=18, Predicted=16.5912, Expected=16.5460
# Month=19, Predicted=16.1246, Expected=16.7170
# Month=20, Predicted=16.1204, Expected=16.4330
# Month=21, Predicted=15.8316, Expected=15.7690
# Month=22, Predicted=15.1960, Expected=15.2750
# Month=23, Predicted=14.8745, Expected=15.1230
# Month=24, Predicted=15.1228, Expected=15.5410
# Month=25, Predicted=15.8744, Expected=15.8250
# Month=26, Predicted=16.3874, Expected=16.3760
# Month=27, Predicted=17.0325, Expected=16.3570
# Month=28, Predicted=16.7770, Expected=16.9070
# Month=29, Predicted=17.2051, Expected=17.0210
# Month=30, Predicted=16.8654, Expected=17.4190
# Month=31, Predicted=16.9659, Expected=17.5330
# Month=32, Predicted=16.9729, Expected=17.2680
# Month=33, Predicted=16.7003, Expected=16.6030
# Month=34, Predicted=16.0487, Expected=15.8250
# Month=35, Predicted=15.3404, Expected=15.4460
# Month=36, Predicted=15.3254, Expected=15.6360
# Month=37, Predicted=15.9939, Expected=15.6930
# Month=38, Predicted=16.2757, Expected=16.7550
# Month=39, Predicted=17.5404, Expected=16.5090
# Month=40, Predicted=16.8789, Expected=17.7230
# Month=41, Predicted=18.1651, Expected=18.6910
# Month=42, Predicted=18.7561, Expected=19.1270
# Month=43, Predicted=18.7227, Expected=19.5640
# Month=44, Predicted=18.9584, Expected=19.2030
# Month=45, Predicted=18.5906, Expected=18.2160
# Month=46, Predicted=17.6087, Expected=17.2110
# Month=47, Predicted=16.6725, Expected=16.6600
# Month=48, Predicted=16.4798, Expected=16.8310
# Month=49, Predicted=17.0817, Expected=15.7690
# Month=50, Predicted=15.9942, Expected=15.7310
# Month=51, Predicted=16.3109, Expected=15.9960
# Month=52, Predicted=16.6877, Expected=17.0210
# Month=53, Predicted=17.7104, Expected=17.5520
# Month=54, Predicted=17.8857, Expected=17.8370
# Month=55, Predicted=17.7797, Expected=17.8560
# Month=56, Predicted=17.3834, Expected=17.5710
# Month=57, Predicted=16.9790, Expected=17.0780
# Month=58, Predicted=16.4641, Expected=16.6600
# Month=59, Predicted=16.1388, Expected=16.4330
# Month=60, Predicted=16.1911, Expected=16.5840
# Run 26 — RMSE: 0.427187, MSE: 0.182489, NMSE: 0.0017732917
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.2360, Expected=13.7000
# Month=2, Predicted=14.1549, Expected=13.8140
# Month=3, Predicted=14.6638, Expected=14.3830
# Month=4, Predicted=15.1264, Expected=15.0470
# Month=5, Predicted=15.3123, Expected=15.6930
# Month=6, Predicted=15.6474, Expected=15.8440
# Month=7, Predicted=15.5038, Expected=15.7120
# Month=8, Predicted=15.1872, Expected=15.3130
# Month=9, Predicted=14.6963, Expected=14.7630
# Month=10, Predicted=14.1758, Expected=13.5480
# Month=11, Predicted=12.9528, Expected=13.5860
# Month=12, Predicted=13.6625, Expected=14.5160
# Month=13, Predicted=14.7870, Expected=14.3830
# Month=14, Predicted=14.7811, Expected=14.4970
# Month=15, Predicted=15.3710, Expected=14.7440
# Month=16, Predicted=15.4110, Expected=15.8060
# Month=17, Predicted=16.1078, Expected=16.5270
# Month=18, Predicted=16.4746, Expected=16.5460
# Month=19, Predicted=16.1875, Expected=16.7170
# Month=20, Predicted=16.2125, Expected=16.4330
# Month=21, Predicted=15.8268, Expected=15.7690
# Month=22, Predicted=15.1383, Expected=15.2750
# Month=23, Predicted=14.9265, Expected=15.1230
# Month=24, Predicted=15.1433, Expected=15.5410
# Month=25, Predicted=15.7185, Expected=15.8250
# Month=26, Predicted=16.2942, Expected=16.3760
# Month=27, Predicted=17.2824, Expected=16.3570
# Month=28, Predicted=16.9346, Expected=16.9070
# Month=29, Predicted=17.1085, Expected=17.0210
# Month=30, Predicted=16.8617, Expected=17.4190
# Month=31, Predicted=17.0621, Expected=17.5330
# Month=32, Predicted=17.0196, Expected=17.2680
# Month=33, Predicted=16.6770, Expected=16.6030
# Month=34, Predicted=15.9766, Expected=15.8250
# Month=35, Predicted=15.4309, Expected=15.4460
# Month=36, Predicted=15.3768, Expected=15.6360
# Month=37, Predicted=15.7392, Expected=15.6930
# Month=38, Predicted=16.1662, Expected=16.7550
# Month=39, Predicted=17.7117, Expected=16.5090
# Month=40, Predicted=17.0147, Expected=17.7230
# Month=41, Predicted=18.0229, Expected=18.6910
# Month=42, Predicted=18.6519, Expected=19.1270
# Month=43, Predicted=18.7972, Expected=19.5640
# Month=44, Predicted=19.0860, Expected=19.2030
# Month=45, Predicted=18.5751, Expected=18.2160
# Month=46, Predicted=17.4935, Expected=17.2110
# Month=47, Predicted=16.6446, Expected=16.6600
# Month=48, Predicted=16.5400, Expected=16.8310
# Month=49, Predicted=16.9286, Expected=15.7690
# Month=50, Predicted=15.8098, Expected=15.7310
# Month=51, Predicted=16.3943, Expected=15.9960
# Month=52, Predicted=16.9032, Expected=17.0210
# Month=53, Predicted=17.6356, Expected=17.5520
# Month=54, Predicted=17.6601, Expected=17.8370
# Month=55, Predicted=17.6366, Expected=17.8560
# Month=56, Predicted=17.4275, Expected=17.5710
# Month=57, Predicted=16.9842, Expected=17.0780
# Month=58, Predicted=16.4678, Expected=16.6600
# Month=59, Predicted=16.1780, Expected=16.4330
# Month=60, Predicted=16.3300, Expected=16.5840
# Run 27 — RMSE: 0.427238, MSE: 0.182533, NMSE: 0.0017682758
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.2708, Expected=13.7000
# Month=2, Predicted=14.2290, Expected=13.8140
# Month=3, Predicted=14.4670, Expected=14.3830
# Month=4, Predicted=15.0663, Expected=15.0470
# Month=5, Predicted=15.4546, Expected=15.6930
# Month=6, Predicted=15.8352, Expected=15.8440
# Month=7, Predicted=15.5455, Expected=15.7120
# Month=8, Predicted=15.2633, Expected=15.3130
# Month=9, Predicted=14.6727, Expected=14.7630
# Month=10, Predicted=14.1201, Expected=13.5480
# Month=11, Predicted=12.8476, Expected=13.5860
# Month=12, Predicted=13.6638, Expected=14.5160
# Month=13, Predicted=14.8204, Expected=14.3830
# Month=14, Predicted=14.7035, Expected=14.4970
# Month=15, Predicted=15.0758, Expected=14.7440
# Month=16, Predicted=15.4286, Expected=15.8060
# Month=17, Predicted=16.4943, Expected=16.5270
# Month=18, Predicted=16.7352, Expected=16.5460
# Month=19, Predicted=16.2101, Expected=16.7170
# Month=20, Predicted=16.4366, Expected=16.4330
# Month=21, Predicted=15.8424, Expected=15.7690
# Month=22, Predicted=15.0647, Expected=15.2750
# Month=23, Predicted=14.7520, Expected=15.1230
# Month=24, Predicted=14.9024, Expected=15.5410
# Month=25, Predicted=15.6534, Expected=15.8250
# Month=26, Predicted=16.1526, Expected=16.3760
# Month=27, Predicted=17.0218, Expected=16.3570
# Month=28, Predicted=16.9783, Expected=16.9070
# Month=29, Predicted=17.5150, Expected=17.0210
# Month=30, Predicted=17.1383, Expected=17.4190
# Month=31, Predicted=17.4591, Expected=17.5330
# Month=32, Predicted=17.2289, Expected=17.2680
# Month=33, Predicted=16.7358, Expected=16.6030
# Month=34, Predicted=15.9065, Expected=15.8250
# Month=35, Predicted=15.1822, Expected=15.4460
# Month=36, Predicted=15.1171, Expected=15.6360
# Month=37, Predicted=15.6667, Expected=15.6930
# Month=38, Predicted=15.8600, Expected=16.7550
# Month=39, Predicted=17.4447, Expected=16.5090
# Month=40, Predicted=17.1245, Expected=17.7230
# Month=41, Predicted=18.5325, Expected=18.6910
# Month=42, Predicted=19.0555, Expected=19.1270
# Month=43, Predicted=19.0042, Expected=19.5640
# Month=44, Predicted=19.3940, Expected=19.2030
# Month=45, Predicted=18.6268, Expected=18.2160
# Month=46, Predicted=17.4312, Expected=17.2110
# Month=47, Predicted=16.5415, Expected=16.6600
# Month=48, Predicted=16.3085, Expected=16.8310
# Month=49, Predicted=16.8780, Expected=15.7690
# Month=50, Predicted=15.5290, Expected=15.7310
# Month=51, Predicted=15.9566, Expected=15.9960
# Month=52, Predicted=16.5585, Expected=17.0210
# Month=53, Predicted=17.8438, Expected=17.5520
# Month=54, Predicted=18.0524, Expected=17.8370
# Month=55, Predicted=17.9548, Expected=17.8560
# Month=56, Predicted=17.6218, Expected=17.5710
# Month=57, Predicted=17.1134, Expected=17.0780
# Month=58, Predicted=16.4714, Expected=16.6600
# Month=59, Predicted=16.1058, Expected=16.4330
# Month=60, Predicted=16.0617, Expected=16.5840
# Run 28 — RMSE: 0.400391, MSE: 0.160313, NMSE: 0.0013403217
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.3144, Expected=13.7000
# Month=2, Predicted=14.1572, Expected=13.8140
# Month=3, Predicted=14.0638, Expected=14.3830
# Month=4, Predicted=14.7355, Expected=15.0470
# Month=5, Predicted=15.3370, Expected=15.6930
# Month=6, Predicted=15.8677, Expected=15.8440
# Month=7, Predicted=15.6590, Expected=15.7120
# Month=8, Predicted=15.2776, Expected=15.3130
# Month=9, Predicted=14.7326, Expected=14.7630
# Month=10, Predicted=14.1799, Expected=13.5480
# Month=11, Predicted=12.7927, Expected=13.5860
# Month=12, Predicted=13.6679, Expected=14.5160
# Month=13, Predicted=15.1892, Expected=14.3830
# Month=14, Predicted=14.6717, Expected=14.4970
# Month=15, Predicted=14.7613, Expected=14.7440
# Month=16, Predicted=14.9748, Expected=15.8060
# Month=17, Predicted=16.2747, Expected=16.5270
# Month=18, Predicted=16.7468, Expected=16.5460
# Month=19, Predicted=16.2921, Expected=16.7170
# Month=20, Predicted=16.4194, Expected=16.4330
# Month=21, Predicted=15.8815, Expected=15.7690
# Month=22, Predicted=15.0776, Expected=15.2750
# Month=23, Predicted=14.7876, Expected=15.1230
# Month=24, Predicted=15.0161, Expected=15.5410
# Month=25, Predicted=15.8970, Expected=15.8250
# Month=26, Predicted=16.1930, Expected=16.3760
# Month=27, Predicted=16.8127, Expected=16.3570
# Month=28, Predicted=16.4392, Expected=16.9070
# Month=29, Predicted=17.1455, Expected=17.0210
# Month=30, Predicted=16.9618, Expected=17.4190
# Month=31, Predicted=17.4076, Expected=17.5330
# Month=32, Predicted=17.3267, Expected=17.2680
# Month=33, Predicted=16.8272, Expected=16.6030
# Month=34, Predicted=15.9809, Expected=15.8250
# Month=35, Predicted=15.2421, Expected=15.4460
# Month=36, Predicted=15.2456, Expected=15.6360
# Month=37, Predicted=15.9308, Expected=15.6930
# Month=38, Predicted=16.0369, Expected=16.7550
# Month=39, Predicted=17.4567, Expected=16.5090
# Month=40, Predicted=16.6088, Expected=17.7230
# Month=41, Predicted=18.2478, Expected=18.6910
# Month=42, Predicted=19.0004, Expected=19.1270
# Month=43, Predicted=19.0605, Expected=19.5640
# Month=44, Predicted=19.3606, Expected=19.2030
# Month=45, Predicted=18.5284, Expected=18.2160
# Month=46, Predicted=17.3122, Expected=17.2110
# Month=47, Predicted=16.4225, Expected=16.6600
# Month=48, Predicted=16.3160, Expected=16.8310
# Month=49, Predicted=17.1694, Expected=15.7690
# Month=50, Predicted=15.6977, Expected=15.7310
# Month=51, Predicted=16.1901, Expected=15.9960
# Month=52, Predicted=16.5979, Expected=17.0210
# Month=53, Predicted=17.7334, Expected=17.5520
# Month=54, Predicted=17.9746, Expected=17.8370
# Month=55, Predicted=18.0048, Expected=17.8560
# Month=56, Predicted=17.7721, Expected=17.5710
# Month=57, Predicted=17.2066, Expected=17.0780
# Month=58, Predicted=16.5308, Expected=16.6600
# Month=59, Predicted=16.1817, Expected=16.4330
# Month=60, Predicted=16.1684, Expected=16.5840
# Run 29 — RMSE: 0.439950, MSE: 0.193556, NMSE: 0.0016492227
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.7461, Expected=13.7000
# Month=2, Predicted=14.4994, Expected=13.8140
# Month=3, Predicted=14.2417, Expected=14.3830
# Month=4, Predicted=14.5381, Expected=15.0470
# Month=5, Predicted=15.0377, Expected=15.6930
# Month=6, Predicted=15.5289, Expected=15.8440
# Month=7, Predicted=15.5354, Expected=15.7120
# Month=8, Predicted=15.3430, Expected=15.3130
# Month=9, Predicted=14.9612, Expected=14.7630
# Month=10, Predicted=14.5254, Expected=13.5480
# Month=11, Predicted=13.1252, Expected=13.5860
# Month=12, Predicted=13.8029, Expected=14.5160
# Month=13, Predicted=15.3667, Expected=14.3830
# Month=14, Predicted=15.0732, Expected=14.4970
# Month=15, Predicted=14.8279, Expected=14.7440
# Month=16, Predicted=14.7967, Expected=15.8060
# Month=17, Predicted=15.8224, Expected=16.5270
# Month=18, Predicted=16.3645, Expected=16.5460
# Month=19, Predicted=16.2125, Expected=16.7170
# Month=20, Predicted=16.4624, Expected=16.4330
# Month=21, Predicted=16.1513, Expected=15.7690
# Month=22, Predicted=15.5074, Expected=15.2750
# Month=23, Predicted=15.1384, Expected=15.1230
# Month=24, Predicted=15.2677, Expected=15.5410
# Month=25, Predicted=16.2790, Expected=15.8250
# Month=26, Predicted=16.5694, Expected=16.3760
# Month=27, Predicted=16.8101, Expected=16.3570
# Month=28, Predicted=16.3763, Expected=16.9070
# Month=29, Predicted=16.8299, Expected=17.0210
# Month=30, Predicted=16.7283, Expected=17.4190
# Month=31, Predicted=17.1409, Expected=17.5330
# Month=32, Predicted=17.2093, Expected=17.2680
# Month=33, Predicted=16.9464, Expected=16.6030
# Month=34, Predicted=16.2923, Expected=15.8250
# Month=35, Predicted=15.5572, Expected=15.4460
# Month=36, Predicted=15.5493, Expected=15.6360
# Month=37, Predicted=16.3666, Expected=15.6930
# Month=38, Predicted=16.4417, Expected=16.7550
# Month=39, Predicted=17.2953, Expected=16.5090
# Month=40, Predicted=16.4985, Expected=17.7230
# Month=41, Predicted=17.7764, Expected=18.6910
# Month=42, Predicted=18.5861, Expected=19.1270
# Month=43, Predicted=18.8911, Expected=19.5640
# Month=44, Predicted=19.4018, Expected=19.2030
# Month=45, Predicted=18.9209, Expected=18.2160
# Month=46, Predicted=17.8954, Expected=17.2110
# Month=47, Predicted=16.9827, Expected=16.6600
# Month=48, Predicted=16.6207, Expected=16.8310
# Month=49, Predicted=17.3983, Expected=15.7690
# Month=50, Predicted=16.3726, Expected=15.7310
# Month=51, Predicted=16.3495, Expected=15.9960
# Month=52, Predicted=16.2366, Expected=17.0210
# Month=53, Predicted=17.1919, Expected=17.5520
# Month=54, Predicted=17.4649, Expected=17.8370
# Month=55, Predicted=17.5795, Expected=17.8560
# Month=56, Predicted=17.5187, Expected=17.5710
# Month=57, Predicted=17.1812, Expected=17.0780
# Month=58, Predicted=16.7717, Expected=16.6600
# Month=59, Predicted=16.5086, Expected=16.4330
# Month=60, Predicted=16.4022, Expected=16.5840
# Run 30 — RMSE: 0.544524, MSE: 0.296507, NMSE: 0.0030185928

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (2 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Output Layer on Monthly Lake Erie Levels (2 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'sMAPE: {np.mean(all_smape):.6f} ± {np.std(all_smape):.6f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
print(f'  sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Output Layer on Monthly Lake Erie Levels (30 runs) =====
# RMSE: 0.432001 ± 0.029890
# MSE:  0.187518 ± 0.027742
# NMSE: 0.0016951341 ± 0.0002963945
#
# Best run: 28
#   RMSE: 0.400391
#   MSE:  0.160313
#   NMSE: 0.0013403217

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Output Layer — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 2 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Output Layer — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
print(f'sMAPE: {all_smape[best_idx]:.6f}')
# Out:
# === Best Run Metrics ===
# RMSE: 0.400391
# MSE:  0.160313
# NMSE: 0.0013403217

# %% [markdown]
# ## Observations
#
# ### Fuzzy Output Layer on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
