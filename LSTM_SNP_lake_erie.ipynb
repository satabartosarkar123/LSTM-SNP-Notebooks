# %% [markdown]
# Paper Referred : [LSTM-SNP: A long short-term memory model inspired from spiking neural P systems](https://drive.google.com/file/d/1V_n4Cn342ShMSTQDLnfiGsBgXEeTGyJE/view?usp=sharing)

# %% [markdown]
# Architecture of Neuron :
#
# ![image.png](data:image/png;base64,...)

# %%
# ============================================================
# ALL IMPORTS (consolidated)
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model

# %% [markdown]
# ## Reset Gate
#
# $$
# r(t) = \rho\left( W_r x(t) + U_r u(t-1) + b_r \right)
# $$
#
# ## Consumption Gate
#
# $$
# c(t) = \rho\left( W_c x(t) + U_c u(t-1) + b_c \right)
# $$
#
# ## Output Gate
#
# $$
# o(t) = \rho\left( W_o x(t) + U_o u(t-1) + b_o \right)
# $$
#
# ## Generated Spikes
#
# $$
# a(t) = f\left( W_a x(t) + U_a u(t-1) + b_a \right)
# $$
#
# ---
#
# ### Parameter Dimensions
#
# $$
# W_* \in \mathbb{R}^{d \times h}, \qquad
# U_* \in \mathbb{R}^{h \times h}, \qquad
# b_* \in \mathbb{R}^{h}
# $$
#
# ---
#
# ### Activations
#
# $$
# \rho(\cdot) = \text{hard sigmoid}, \qquad
# f(\cdot) = \tanh
# $$

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
      This serves as an RNN Cell Instance.
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units      # REQUIRED
        self.output_size = units     # REQUIRED

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )

        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )

        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0) #reset :how much previous state reset
        c = self.recurrent_activation(z1) #how much of previous state (u) is consumed.Wrt to current i/p, refer to the T/g(t)->f(t) philosophy
        o = self.recurrent_activation(z2) # generation : how much spike generated.
        a = self.recurrent_activation(z3)

        u = r * u_tm1 - c * a #internal state of LSTM-SNP
        h = o * a #output of SNP

        return h, [u]

# %% [markdown]
# Wrapping in RNN (As directeed in paper)

# %%
def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(
        batch_shape=(batch_size, 1, input_dim)
    )
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)

    model.compile(
        optimizer='adam',
        loss='mean_squared_error'
    )

    return model

# %%
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 329 (1.29 KB)
#  Trainable params: 329 (1.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **TESTING ON DOW_JONES DATASET (from GITHUB REPO attached to paper)**

# %% [markdown]
# # LSTM-SNP Experiment Pipeline — Dow Jones Dataset
#
# ## 1. Load Time Series Data
# - Read monthly Dow Jones closing prices
# - Parse date column
# - Extract raw numeric values
#
#
# ## 2. First-Order Differencing
# - Remove trend component
# - Compute:
#
#   diff(t) = raw(t) − raw(t−1)
#
# - Purpose: make series more stationary
#
#
# ## 3. Convert to Supervised Learning Format
# - Use lag = 1
# - Create input-output pairs:
#
#   X(t) = diff(t−1)
#   y(t) = diff(t)
#
# - Fill initial NaN with 0
#
#
# ## 4. Train-Test Split
# - Last 60 samples → Test set
# - Remaining samples → Training set
#
#
#
# ## 5. Feature Scaling
# - Apply MinMaxScaler
# - Scale to range [-1, 1]
# - Fit scaler on training set only
# - Transform both train and test
#
#
# ## 6. Reshape for RNN Input
# - Reshape X_train to:
#
#   (samples, timesteps=1, features=1)
#
# - Required input shape for RNN
#
#
# ## 7. Model Construction
# - Custom LSTM-SNP cell (8 units)
# - Wrapped inside RNN layer
# - Dense(1) output layer
# - Loss: Mean Squared Error
# - Optimizer: Adam
#
#
#
# ## 8. Model Training
# - Epochs: 200
# - Batch size: 1
# - shuffle=False (preserve sequence order)
# - Backpropagation Through Time
#
#
#
# ## 9. Rolling Prediction (One-Step Ahead)
# For each test sample:
# - Predict next differenced value
# - Inverse scale
# - Inverse differencing:
#
#   predicted_raw(t) = predicted_diff(t) + raw(t−1)
#
#
#
# ## 10. Evaluation Metrics
# - RMSE
# - MSE
# - NMSE:
#
#   NMSE = MSE / ||prediction − mean(actual)||²
#
#
# ## 11. Visualization
# - Plot actual vs predicted
# - Observe tracking behavior

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

def parser(x):
    return pd.to_datetime(x, format='%Y-%m')

series = pd.read_csv(
    'content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)

# %%
train, test = supervised[:-60], supervised[-60:]

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)

# %%
X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]

# %%
# ============================================================
# 30-Run Experiment Protocol (matching reference test.py)
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    # Fix #4: Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)

    # Build stateful model (Fix #2)
    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    # Fix #3: Unit forget bias — set consume gate (c) bias to 1.0
    # Access the RNN layer's cell weights
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()  # [kernel, recurrent_kernel, bias]
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, so bias[units:2*units] = bias[8:16]
    weights[2] = bias
    cell.set_weights(weights)

    # Fix #2: Stateful training with manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train,
            y_train,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Fix #6: Warm-up prediction pass on training data
    # This conditions the hidden states before test predictions
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]

        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\SNP\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=13.2914, Expected=13.7000
# Month=2, Predicted=14.0867, Expected=13.8140
# Month=3, Predicted=13.8304, Expected=14.3830
# Month=4, Predicted=14.6837, Expected=15.0470
# Month=5, Predicted=15.3573, Expected=15.6930
# Month=6, Predicted=15.9487, Expected=15.8440
# Month=7, Predicted=15.7590, Expected=15.7120
# Month=8, Predicted=15.4833, Expected=15.3130
# Month=9, Predicted=14.9717, Expected=14.7630
# Month=10, Predicted=14.3983, Expected=13.5480
# Month=11, Predicted=12.8034, Expected=13.5860
# Month=12, Predicted=13.8067, Expected=14.5160
# Month=13, Predicted=15.1791, Expected=14.3830
# Month=14, Predicted=14.2565, Expected=14.4970
# Month=15, Predicted=14.5404, Expected=14.7440
# Month=16, Predicted=14.8610, Expected=15.8060
# Month=17, Predicted=16.3733, Expected=16.5270
# Month=18, Predicted=16.8193, Expected=16.5460
# Month=19, Predicted=16.3567, Expected=16.7170
# Month=20, Predicted=16.6879, Expected=16.4330
# Month=21, Predicted=16.1352, Expected=15.7690
# Month=22, Predicted=15.2901, Expected=15.2750
# Month=23, Predicted=15.0075, Expected=15.1230
# Month=24, Predicted=15.1219, Expected=15.5410
# Month=25, Predicted=15.8875, Expected=15.8250
# Month=26, Predicted=16.0039, Expected=16.3760
# Month=27, Predicted=16.6805, Expected=16.3570
# Month=28, Predicted=16.2393, Expected=16.9070
# Month=29, Predicted=17.1829, Expected=17.0210
# Month=30, Predicted=16.9784, Expected=17.4190
# Month=31, Predicted=17.5802, Expected=17.5330
# Month=32, Predicted=17.4967, Expected=17.2680
# Month=33, Predicted=17.0041, Expected=16.6030
# Month=34, Predicted=16.1324, Expected=15.8250
# Month=35, Predicted=15.3715, Expected=15.4460
# Month=36, Predicted=15.3334, Expected=15.6360
# Month=37, Predicted=15.8886, Expected=15.6930
# Month=38, Predicted=15.7853, Expected=16.7550
# Month=39, Predicted=17.3936, Expected=16.5090
# Month=40, Predicted=16.2254, Expected=17.7230
# Month=41, Predicted=18.3661, Expected=18.6910
# Month=42, Predicted=19.1012, Expected=19.1270
# Month=43, Predicted=19.1697, Expected=19.5640
# Month=44, Predicted=19.6345, Expected=19.2030
# Month=45, Predicted=18.7759, Expected=18.2160
# Month=46, Predicted=17.4774, Expected=17.2110
# Month=47, Predicted=16.6177, Expected=16.6600
# Month=48, Predicted=16.4760, Expected=16.8310
# Month=49, Predicted=17.1225, Expected=15.7690
# Month=50, Predicted=15.1533, Expected=15.7310
# Month=51, Predicted=15.8817, Expected=15.9960
# Month=52, Predicted=16.2754, Expected=17.0210
# Month=53, Predicted=17.6496, Expected=17.5520
# Month=54, Predicted=17.7772, Expected=17.8370
# Month=55, Predicted=17.8683, Expected=17.8560
# Month=56, Predicted=17.7256, Expected=17.5710
# Month=57, Predicted=17.2832, Expected=17.0780
# Month=58, Predicted=16.7194, Expected=16.6600
# Month=59, Predicted=16.4240, Expected=16.4330
# Month=60, Predicted=16.3598, Expected=16.5840
# Run 1 — RMSE: 0.484944, MSE: 0.235170, NMSE: 0.0019143264
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2617, Expected=13.7000
# Month=2, Predicted=14.0523, Expected=13.8140
# Month=3, Predicted=13.8168, Expected=14.3830
# Month=4, Predicted=14.6786, Expected=15.0470
# Month=5, Predicted=15.3517, Expected=15.6930
# Month=6, Predicted=15.9511, Expected=15.8440
# Month=7, Predicted=15.7816, Expected=15.7120
# Month=8, Predicted=15.5156, Expected=15.3130
# Month=9, Predicted=15.0005, Expected=14.7630
# Month=10, Predicted=14.4129, Expected=13.5480
# Month=11, Predicted=12.8088, Expected=13.5860
# Month=12, Predicted=13.7672, Expected=14.5160
# Month=13, Predicted=15.1451, Expected=14.3830
# Month=14, Predicted=14.2261, Expected=14.4970
# Month=15, Predicted=14.5459, Expected=14.7440
# Month=16, Predicted=14.8667, Expected=15.8060
# Month=17, Predicted=16.3914, Expected=16.5270
# Month=18, Predicted=16.8128, Expected=16.5460
# Month=19, Predicted=16.3861, Expected=16.7170
# Month=20, Predicted=16.7200, Expected=16.4330
# Month=21, Predicted=16.1620, Expected=15.7690
# Month=22, Predicted=15.3160, Expected=15.2750
# Month=23, Predicted=15.0086, Expected=15.1230
# Month=24, Predicted=15.0966, Expected=15.5410
# Month=25, Predicted=15.8448, Expected=15.8250
# Month=26, Predicted=15.9714, Expected=16.3760
# Month=27, Predicted=16.6619, Expected=16.3570
# Month=28, Predicted=16.2476, Expected=16.9070
# Month=29, Predicted=17.1890, Expected=17.0210
# Month=30, Predicted=16.9889, Expected=17.4190
# Month=31, Predicted=17.5878, Expected=17.5330
# Month=32, Predicted=17.5054, Expected=17.2680
# Month=33, Predicted=17.0224, Expected=16.6030
# Month=34, Predicted=16.1562, Expected=15.8250
# Month=35, Predicted=15.3796, Expected=15.4460
# Month=36, Predicted=15.3135, Expected=15.6360
# Month=37, Predicted=15.8466, Expected=15.6930
# Month=38, Predicted=15.7516, Expected=16.7550
# Month=39, Predicted=17.3955, Expected=16.5090
# Month=40, Predicted=16.2304, Expected=17.7230
# Month=41, Predicted=18.4075, Expected=18.6910
# Month=42, Predicted=19.1100, Expected=19.1270
# Month=43, Predicted=19.1919, Expected=19.5640
# Month=44, Predicted=19.6645, Expected=19.2030
# Month=45, Predicted=18.8161, Expected=18.2160
# Month=46, Predicted=17.5217, Expected=17.2110
# Month=47, Predicted=16.6300, Expected=16.6600
# Month=48, Predicted=16.4472, Expected=16.8310
# Month=49, Predicted=17.0630, Expected=15.7690
# Month=50, Predicted=15.1253, Expected=15.7310
# Month=51, Predicted=15.8542, Expected=15.9960
# Month=52, Predicted=16.2410, Expected=17.0210
# Month=53, Predicted=17.6490, Expected=17.5520
# Month=54, Predicted=17.7700, Expected=17.8370
# Month=55, Predicted=17.8951, Expected=17.8560
# Month=56, Predicted=17.7658, Expected=17.5710
# Month=57, Predicted=17.3243, Expected=17.0780
# Month=58, Predicted=16.7519, Expected=16.6600
# Month=59, Predicted=16.4337, Expected=16.4330
# Month=60, Predicted=16.3484, Expected=16.5840
# Run 2 — RMSE: 0.489208, MSE: 0.239324, NMSE: 0.0019177080
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2456, Expected=13.7000
# Month=2, Predicted=14.0346, Expected=13.8140
# Month=3, Predicted=13.8139, Expected=14.3830
# Month=4, Predicted=14.6802, Expected=15.0470
# Month=5, Predicted=15.3654, Expected=15.6930
# Month=6, Predicted=15.9782, Expected=15.8440
# Month=7, Predicted=15.8225, Expected=15.7120
# Month=8, Predicted=15.5611, Expected=15.3130
# Month=9, Predicted=15.0410, Expected=14.7630
# Month=10, Predicted=14.4410, Expected=13.5480
# Month=11, Predicted=12.8289, Expected=13.5860
# Month=12, Predicted=13.7458, Expected=14.5160
# Month=13, Predicted=15.1109, Expected=14.3830
# Month=14, Predicted=14.2129, Expected=14.4970
# Month=15, Predicted=14.5356, Expected=14.7440
# Month=16, Predicted=14.8620, Expected=15.8060
# Month=17, Predicted=16.3946, Expected=16.5270
# Month=18, Predicted=16.8327, Expected=16.5460
# Month=19, Predicted=16.4262, Expected=16.7170
# Month=20, Predicted=16.7597, Expected=16.4330
# Month=21, Predicted=16.2056, Expected=15.7690
# Month=22, Predicted=15.3512, Expected=15.2750
# Month=23, Predicted=15.0249, Expected=15.1230
# Month=24, Predicted=15.0928, Expected=15.5410
# Month=25, Predicted=15.8255, Expected=15.8250
# Month=26, Predicted=15.9591, Expected=16.3760
# Month=27, Predicted=16.6573, Expected=16.3570
# Month=28, Predicted=16.2601, Expected=16.9070
# Month=29, Predicted=17.2005, Expected=17.0210
# Month=30, Predicted=17.0117, Expected=17.4190
# Month=31, Predicted=17.6106, Expected=17.5330
# Month=32, Predicted=17.5347, Expected=17.2680
# Month=33, Predicted=17.0556, Expected=16.6030
# Month=34, Predicted=16.1835, Expected=15.8250
# Month=35, Predicted=15.3930, Expected=15.4460
# Month=36, Predicted=15.3032, Expected=15.6360
# Month=37, Predicted=15.8168, Expected=15.6930
# Month=38, Predicted=15.7240, Expected=16.7550
# Month=39, Predicted=17.3719, Expected=16.5090
# Month=40, Predicted=16.2338, Expected=17.7230
# Month=41, Predicted=18.4127, Expected=18.6910
# Month=42, Predicted=19.1330, Expected=19.1270
# Month=43, Predicted=19.2355, Expected=19.5640
# Month=44, Predicted=19.7176, Expected=19.2030
# Month=45, Predicted=18.8803, Expected=18.2160
# Month=46, Predicted=17.5780, Expected=17.2110
# Month=47, Predicted=16.6625, Expected=16.6600
# Month=48, Predicted=16.4450, Expected=16.8310
# Month=49, Predicted=17.0317, Expected=15.7690
# Month=50, Predicted=15.1042, Expected=15.7310
# Month=51, Predicted=15.8086, Expected=15.9960
# Month=52, Predicted=16.1903, Expected=17.0210
# Month=53, Predicted=17.6098, Expected=17.5520
# Month=54, Predicted=17.7554, Expected=17.8370
# Month=55, Predicted=17.9029, Expected=17.8560
# Month=56, Predicted=17.7874, Expected=17.5710
# Month=57, Predicted=17.3509, Expected=17.0780
# Month=58, Predicted=16.7725, Expected=16.6600
# Month=59, Predicted=16.4415, Expected=16.4330
# Month=60, Predicted=16.3419, Expected=16.5840
# Run 3 — RMSE: 0.495563, MSE: 0.245582, NMSE: 0.0019437709
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2534, Expected=13.7000
# Month=2, Predicted=14.0440, Expected=13.8140
# Month=3, Predicted=13.8236, Expected=14.3830
# Month=4, Predicted=14.6797, Expected=15.0470
# Month=5, Predicted=15.3651, Expected=15.6930
# Month=6, Predicted=15.9752, Expected=15.8440
# Month=7, Predicted=15.8171, Expected=15.7120
# Month=8, Predicted=15.5507, Expected=15.3130
# Month=9, Predicted=15.0304, Expected=14.7630
# Month=10, Predicted=14.4328, Expected=13.5480
# Month=11, Predicted=12.8180, Expected=13.5860
# Month=12, Predicted=13.7447, Expected=14.5160
# Month=13, Predicted=15.1235, Expected=14.3830
# Month=14, Predicted=14.2324, Expected=14.4970
# Month=15, Predicted=14.5379, Expected=14.7440
# Month=16, Predicted=14.8629, Expected=15.8060
# Month=17, Predicted=16.3904, Expected=16.5270
# Month=18, Predicted=16.8351, Expected=16.5460
# Month=19, Predicted=16.4206, Expected=16.7170
# Month=20, Predicted=16.7476, Expected=16.4330
# Month=21, Predicted=16.1969, Expected=15.7690
# Month=22, Predicted=15.3405, Expected=15.2750
# Month=23, Predicted=15.0185, Expected=15.1230
# Month=24, Predicted=15.0960, Expected=15.5410
# Month=25, Predicted=15.8349, Expected=15.8250
# Month=26, Predicted=15.9722, Expected=16.3760
# Month=27, Predicted=16.6627, Expected=16.3570
# Month=28, Predicted=16.2628, Expected=16.9070
# Month=29, Predicted=17.1949, Expected=17.0210
# Month=30, Predicted=17.0113, Expected=17.4190
# Month=31, Predicted=17.6057, Expected=17.5330
# Month=32, Predicted=17.5326, Expected=17.2680
# Month=33, Predicted=17.0504, Expected=16.6030
# Month=34, Predicted=16.1747, Expected=15.8250
# Month=35, Predicted=15.3848, Expected=15.4460
# Month=36, Predicted=15.3035, Expected=15.6360
# Month=37, Predicted=15.8270, Expected=15.6930
# Month=38, Predicted=15.7395, Expected=16.7550
# Month=39, Predicted=17.3760, Expected=16.5090
# Month=40, Predicted=16.2430, Expected=17.7230
# Month=41, Predicted=18.3996, Expected=18.6910
# Month=42, Predicted=19.1328, Expected=19.1270
# Month=43, Predicted=19.2298, Expected=19.5640
# Month=44, Predicted=19.7045, Expected=19.2030
# Month=45, Predicted=18.8669, Expected=18.2160
# Month=46, Predicted=17.5572, Expected=17.2110
# Month=47, Predicted=16.6451, Expected=16.6600
# Month=48, Predicted=16.4426, Expected=16.8310
# Month=49, Predicted=17.0437, Expected=15.7690
# Month=50, Predicted=15.1160, Expected=15.7310
# Month=51, Predicted=15.8142, Expected=15.9960
# Month=52, Predicted=16.2055, Expected=17.0210
# Month=53, Predicted=17.6191, Expected=17.5520
# Month=54, Predicted=17.7663, Expected=17.8370
# Month=55, Predicted=17.9008, Expected=17.8560
# Month=56, Predicted=17.7793, Expected=17.5710
# Month=57, Predicted=17.3409, Expected=17.0780
# Month=58, Predicted=16.7630, Expected=16.6600
# Month=59, Predicted=16.4366, Expected=16.4330
# Month=60, Predicted=16.3441, Expected=16.5840
# Run 4 — RMSE: 0.492862, MSE: 0.242913, NMSE: 0.0019298498
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2847, Expected=13.7000
# Month=2, Predicted=14.0708, Expected=13.8140
# Month=3, Predicted=13.8035, Expected=14.3830
# Month=4, Predicted=14.6835, Expected=15.0470
# Month=5, Predicted=15.3515, Expected=15.6930
# Month=6, Predicted=15.9470, Expected=15.8440
# Month=7, Predicted=15.7690, Expected=15.7120
# Month=8, Predicted=15.5132, Expected=15.3130
# Month=9, Predicted=15.0044, Expected=14.7630
# Month=10, Predicted=14.4228, Expected=13.5480
# Month=11, Predicted=12.9075, Expected=13.5860
# Month=12, Predicted=13.8228, Expected=14.5160
# Month=13, Predicted=15.1926, Expected=14.3830
# Month=14, Predicted=14.1980, Expected=14.4970
# Month=15, Predicted=14.5380, Expected=14.7440
# Month=16, Predicted=14.8651, Expected=15.8060
# Month=17, Predicted=16.4101, Expected=16.5270
# Month=18, Predicted=16.7987, Expected=16.5460
# Month=19, Predicted=16.3620, Expected=16.7170
# Month=20, Predicted=16.7232, Expected=16.4330
# Month=21, Predicted=16.1624, Expected=15.7690
# Month=22, Predicted=15.3320, Expected=15.2750
# Month=23, Predicted=15.0290, Expected=15.1230
# Month=24, Predicted=15.1275, Expected=15.5410
# Month=25, Predicted=15.8762, Expected=15.8250
# Month=26, Predicted=15.9737, Expected=16.3760
# Month=27, Predicted=16.6651, Expected=16.3570
# Month=28, Predicted=16.2292, Expected=16.9070
# Month=29, Predicted=17.1992, Expected=17.0210
# Month=30, Predicted=16.9812, Expected=17.4190
# Month=31, Predicted=17.5968, Expected=17.5330
# Month=32, Predicted=17.5056, Expected=17.2680
# Month=33, Predicted=17.0202, Expected=16.6030
# Month=34, Predicted=16.1681, Expected=15.8250
# Month=35, Predicted=15.4115, Expected=15.4460
# Month=36, Predicted=15.3412, Expected=15.6360
# Month=37, Predicted=15.8797, Expected=15.6930
# Month=38, Predicted=15.7538, Expected=16.7550
# Month=39, Predicted=17.4187, Expected=16.5090
# Month=40, Predicted=16.1880, Expected=17.7230
# Month=41, Predicted=18.4305, Expected=18.6910
# Month=42, Predicted=19.0977, Expected=19.1270
# Month=43, Predicted=19.1692, Expected=19.5640
# Month=44, Predicted=19.6619, Expected=19.2030
# Month=45, Predicted=18.8072, Expected=18.2160
# Month=46, Predicted=17.5846, Expected=17.2110
# Month=47, Predicted=16.7036, Expected=16.6600
# Month=48, Predicted=16.4867, Expected=16.8310
# Month=49, Predicted=17.1116, Expected=15.7690
# Month=50, Predicted=15.1730, Expected=15.7310
# Month=51, Predicted=15.8811, Expected=15.9960
# Month=52, Predicted=16.2516, Expected=17.0210
# Month=53, Predicted=17.6616, Expected=17.5520
# Month=54, Predicted=17.7389, Expected=17.8370
# Month=55, Predicted=17.8671, Expected=17.8560
# Month=56, Predicted=17.7473, Expected=17.5710
# Month=57, Predicted=17.3139, Expected=17.0780
# Month=58, Predicted=16.7486, Expected=16.6600
# Month=59, Predicted=16.4446, Expected=16.4330
# Month=60, Predicted=16.3663, Expected=16.5840
# Run 5 — RMSE: 0.491105, MSE: 0.241185, NMSE: 0.0019567277
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2693, Expected=13.7000
# Month=2, Predicted=14.0534, Expected=13.8140
# Month=3, Predicted=13.8073, Expected=14.3830
# Month=4, Predicted=14.6746, Expected=15.0470
# Month=5, Predicted=15.3488, Expected=15.6930
# Month=6, Predicted=15.9495, Expected=15.8440
# Month=7, Predicted=15.7823, Expected=15.7120
# Month=8, Predicted=15.5267, Expected=15.3130
# Month=9, Predicted=15.0193, Expected=14.7630
# Month=10, Predicted=14.4359, Expected=13.5480
# Month=11, Predicted=12.8377, Expected=13.5860
# Month=12, Predicted=13.7916, Expected=14.5160
# Month=13, Predicted=15.1601, Expected=14.3830
# Month=14, Predicted=14.2105, Expected=14.4970
# Month=15, Predicted=14.5340, Expected=14.7440
# Month=16, Predicted=14.8594, Expected=15.8060
# Month=17, Predicted=16.3966, Expected=16.5270
# Month=18, Predicted=16.8041, Expected=16.5460
# Month=19, Predicted=16.3812, Expected=16.7170
# Month=20, Predicted=16.7272, Expected=16.4330
# Month=21, Predicted=16.1780, Expected=15.7690
# Month=22, Predicted=15.3372, Expected=15.2750
# Month=23, Predicted=15.0330, Expected=15.1230
# Month=24, Predicted=15.1165, Expected=15.5410
# Month=25, Predicted=15.8542, Expected=15.8250
# Month=26, Predicted=15.9673, Expected=16.3760
# Month=27, Predicted=16.6566, Expected=16.3570
# Month=28, Predicted=16.2399, Expected=16.9070
# Month=29, Predicted=17.1899, Expected=17.0210
# Month=30, Predicted=16.9885, Expected=17.4190
# Month=31, Predicted=17.5931, Expected=17.5330
# Month=32, Predicted=17.5115, Expected=17.2680
# Month=33, Predicted=17.0338, Expected=16.6030
# Month=34, Predicted=16.1725, Expected=15.8250
# Month=35, Predicted=15.4012, Expected=15.4460
# Month=36, Predicted=15.3330, Expected=15.6360
# Month=37, Predicted=15.8564, Expected=15.6930
# Month=38, Predicted=15.7464, Expected=16.7550
# Month=39, Predicted=17.3968, Expected=16.5090
# Month=40, Predicted=16.2107, Expected=17.7230
# Month=41, Predicted=18.4134, Expected=18.6910
# Month=42, Predicted=19.1025, Expected=19.1270
# Month=43, Predicted=19.1843, Expected=19.5640
# Month=44, Predicted=19.6703, Expected=19.2030
# Month=45, Predicted=18.8337, Expected=18.2160
# Month=46, Predicted=17.5516, Expected=17.2110
# Month=47, Predicted=16.6677, Expected=16.6600
# Month=48, Predicted=16.4803, Expected=16.8310
# Month=49, Predicted=17.0826, Expected=15.7690
# Month=50, Predicted=15.1274, Expected=15.7310
# Month=51, Predicted=15.8545, Expected=15.9960
# Month=52, Predicted=16.2303, Expected=17.0210
# Month=53, Predicted=17.6405, Expected=17.5520
# Month=54, Predicted=17.7426, Expected=17.8370
# Month=55, Predicted=17.8751, Expected=17.8560
# Month=56, Predicted=17.7578, Expected=17.5710
# Month=57, Predicted=17.3279, Expected=17.0780
# Month=58, Predicted=16.7628, Expected=16.6600
# Month=59, Predicted=16.4486, Expected=16.4330
# Month=60, Predicted=16.3610, Expected=16.5840
# Run 6 — RMSE: 0.492787, MSE: 0.242839, NMSE: 0.0019537774
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.2448, Expected=13.7000
# Month=2, Predicted=14.0356, Expected=13.8140
# Month=3, Predicted=13.8226, Expected=14.3830
# Month=4, Predicted=14.6843, Expected=15.0470
# Month=5, Predicted=15.3713, Expected=15.6930
# Month=6, Predicted=15.9855, Expected=15.8440
# Month=7, Predicted=15.8334, Expected=15.7120
# Month=8, Predicted=15.5690, Expected=15.3130
# Month=9, Predicted=15.0444, Expected=14.7630
# Month=10, Predicted=14.4392, Expected=13.5480
# Month=11, Predicted=12.8151, Expected=13.5860
# Month=12, Predicted=13.7313, Expected=14.5160
# Month=13, Predicted=15.1019, Expected=14.3830
# Month=14, Predicted=14.2221, Expected=14.4970
# Month=15, Predicted=14.5412, Expected=14.7440
# Month=16, Predicted=14.8676, Expected=15.8060
# Month=17, Predicted=16.3918, Expected=16.5270
# Month=18, Predicted=16.8408, Expected=16.5460
# Month=19, Predicted=16.4380, Expected=16.7170
# Month=20, Predicted=16.7666, Expected=16.4330
# Month=21, Predicted=16.2119, Expected=15.7690
# Month=22, Predicted=15.3506, Expected=15.2750
# Month=23, Predicted=15.0195, Expected=15.1230
# Month=24, Predicted=15.0883, Expected=15.5410
# Month=25, Predicted=15.8233, Expected=15.8250
# Month=26, Predicted=15.9647, Expected=16.3760
# Month=27, Predicted=16.6622, Expected=16.3570
# Month=28, Predicted=16.2700, Expected=16.9070
# Month=29, Predicted=17.2038, Expected=17.0210
# Month=30, Predicted=17.0208, Expected=17.4190
# Month=31, Predicted=17.6159, Expected=17.5330
# Month=32, Predicted=17.5428, Expected=17.2680
# Month=33, Predicted=17.0618, Expected=16.6030
# Month=34, Predicted=16.1832, Expected=15.8250
# Month=35, Predicted=15.3855, Expected=15.4460
# Month=36, Predicted=15.2947, Expected=15.6360
# Month=37, Predicted=15.8122, Expected=15.6930
# Month=38, Predicted=15.7274, Expected=16.7550
# Month=39, Predicted=17.3668, Expected=16.5090
# Month=40, Predicted=16.2451, Expected=17.7230
# Month=41, Predicted=18.4047, Expected=18.6910
# Month=42, Predicted=19.1382, Expected=19.1270
# Month=43, Predicted=19.2469, Expected=19.5640
# Month=44, Predicted=19.7263, Expected=19.2030
# Month=45, Predicted=18.8891, Expected=18.2160
# Month=46, Predicted=17.5742, Expected=17.2110
# Month=47, Predicted=16.6478, Expected=16.6600
# Month=48, Predicted=16.4300, Expected=16.8310
# Month=49, Predicted=17.0228, Expected=15.7690
# Month=50, Predicted=15.0971, Expected=15.7310
# Month=51, Predicted=15.8001, Expected=15.9960
# Month=52, Predicted=16.1899, Expected=17.0210
# Month=53, Predicted=17.6066, Expected=17.5520
# Month=54, Predicted=17.7654, Expected=17.8370
# Month=55, Predicted=17.9136, Expected=17.8560
# Month=56, Predicted=17.7968, Expected=17.5710
# Month=57, Predicted=17.3570, Expected=17.0780
# Month=58, Predicted=16.7733, Expected=16.6600
# Month=59, Predicted=16.4387, Expected=16.4330
# Month=60, Predicted=16.3391, Expected=16.5840
# Run 7 — RMSE: 0.495399, MSE: 0.245420, NMSE: 0.0019362438
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2469, Expected=13.7000
# Month=2, Predicted=14.0378, Expected=13.8140
# Month=3, Predicted=13.8222, Expected=14.3830
# Month=4, Predicted=14.6777, Expected=15.0470
# Month=5, Predicted=15.3645, Expected=15.6930
# Month=6, Predicted=15.9758, Expected=15.8440
# Month=7, Predicted=15.8201, Expected=15.7120
# Month=8, Predicted=15.5553, Expected=15.3130
# Month=9, Predicted=15.0369, Expected=14.7630
# Month=10, Predicted=14.4395, Expected=13.5480
# Month=11, Predicted=12.8413, Expected=13.5860
# Month=12, Predicted=13.7392, Expected=14.5160
# Month=13, Predicted=15.1186, Expected=14.3830
# Month=14, Predicted=14.2348, Expected=14.4970
# Month=15, Predicted=14.5383, Expected=14.7440
# Month=16, Predicted=14.8618, Expected=15.8060
# Month=17, Predicted=16.3921, Expected=16.5270
# Month=18, Predicted=16.8372, Expected=16.5460
# Month=19, Predicted=16.4269, Expected=16.7170
# Month=20, Predicted=16.7500, Expected=16.4330
# Month=21, Predicted=16.2025, Expected=15.7690
# Month=22, Predicted=15.3514, Expected=15.2750
# Month=23, Predicted=15.0226, Expected=15.1230
# Month=24, Predicted=15.0921, Expected=15.5410
# Month=25, Predicted=15.8271, Expected=15.8250
# Month=26, Predicted=15.9672, Expected=16.3760
# Month=27, Predicted=16.6594, Expected=16.3570
# Month=28, Predicted=16.2650, Expected=16.9070
# Month=29, Predicted=17.1936, Expected=17.0210
# Month=30, Predicted=17.0122, Expected=17.4190
# Month=31, Predicted=17.6042, Expected=17.5330
# Month=32, Predicted=17.5326, Expected=17.2680
# Month=33, Predicted=17.0546, Expected=16.6030
# Month=34, Predicted=16.1854, Expected=15.8250
# Month=35, Predicted=15.3956, Expected=15.4460
# Month=36, Predicted=15.3029, Expected=15.6360
# Month=37, Predicted=15.8190, Expected=15.6930
# Month=38, Predicted=15.7342, Expected=16.7550
# Month=39, Predicted=17.3750, Expected=16.5090
# Month=40, Predicted=16.2509, Expected=17.7230
# Month=41, Predicted=18.4062, Expected=18.6910
# Month=42, Predicted=19.1385, Expected=19.1270
# Month=43, Predicted=19.2352, Expected=19.5640
# Month=44, Predicted=19.7078, Expected=19.2030
# Month=45, Predicted=18.8772, Expected=18.2160
# Month=46, Predicted=17.5799, Expected=17.2110
# Month=47, Predicted=16.6636, Expected=16.6600
# Month=48, Predicted=16.4447, Expected=16.8310
# Month=49, Predicted=17.0344, Expected=15.7690
# Month=50, Predicted=15.1322, Expected=15.7310
# Month=51, Predicted=15.8100, Expected=15.9960
# Month=52, Predicted=16.1989, Expected=17.0210
# Month=53, Predicted=17.6180, Expected=17.5520
# Month=54, Predicted=17.7675, Expected=17.8370
# Month=55, Predicted=17.9043, Expected=17.8560
# Month=56, Predicted=17.7840, Expected=17.5710
# Month=57, Predicted=17.3475, Expected=17.0780
# Month=58, Predicted=16.7706, Expected=16.6600
# Month=59, Predicted=16.4398, Expected=16.4330
# Month=60, Predicted=16.3421, Expected=16.5840
# Run 8 — RMSE: 0.492733, MSE: 0.242786, NMSE: 0.0019267930
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2576, Expected=13.7000
# Month=2, Predicted=14.0436, Expected=13.8140
# Month=3, Predicted=13.8063, Expected=14.3830
# Month=4, Predicted=14.6795, Expected=15.0470
# Month=5, Predicted=15.3608, Expected=15.6930
# Month=6, Predicted=15.9696, Expected=15.8440
# Month=7, Predicted=15.8094, Expected=15.7120
# Month=8, Predicted=15.5534, Expected=15.3130
# Month=9, Predicted=15.0391, Expected=14.7630
# Month=10, Predicted=14.4450, Expected=13.5480
# Month=11, Predicted=12.8339, Expected=13.5860
# Month=12, Predicted=13.7731, Expected=14.5160
# Month=13, Predicted=15.1378, Expected=14.3830
# Month=14, Predicted=14.2003, Expected=14.4970
# Month=15, Predicted=14.5317, Expected=14.7440
# Month=16, Predicted=14.8613, Expected=15.8060
# Month=17, Predicted=16.4015, Expected=16.5270
# Month=18, Predicted=16.8206, Expected=16.5460
# Month=19, Predicted=16.4089, Expected=16.7170
# Month=20, Predicted=16.7544, Expected=16.4330
# Month=21, Predicted=16.2009, Expected=15.7690
# Month=22, Predicted=15.3511, Expected=15.2750
# Month=23, Predicted=15.0343, Expected=15.1230
# Month=24, Predicted=15.1077, Expected=15.5410
# Month=25, Predicted=15.8413, Expected=15.8250
# Month=26, Predicted=15.9595, Expected=16.3760
# Month=27, Predicted=16.6563, Expected=16.3570
# Month=28, Predicted=16.2488, Expected=16.9070
# Month=29, Predicted=17.2011, Expected=17.0210
# Month=30, Predicted=17.0038, Expected=17.4190
# Month=31, Predicted=17.6092, Expected=17.5330
# Month=32, Predicted=17.5289, Expected=17.2680
# Month=33, Predicted=17.0502, Expected=16.6030
# Month=34, Predicted=16.1824, Expected=15.8250
# Month=35, Predicted=15.3997, Expected=15.4460
# Month=36, Predicted=15.3196, Expected=15.6360
# Month=37, Predicted=15.8364, Expected=15.6930
# Month=38, Predicted=15.7289, Expected=16.7550
# Month=39, Predicted=17.3844, Expected=16.5090
# Month=40, Predicted=16.2142, Expected=17.7230
# Month=41, Predicted=18.4204, Expected=18.6910
# Month=42, Predicted=19.1215, Expected=19.1270
# Month=43, Predicted=19.2170, Expected=19.5640
# Month=44, Predicted=19.7072, Expected=19.2030
# Month=45, Predicted=18.8693, Expected=18.2160
# Month=46, Predicted=17.5755, Expected=17.2110
# Month=47, Predicted=16.6724, Expected=16.6600
# Month=48, Predicted=16.4670, Expected=16.8310
# Month=49, Predicted=17.0588, Expected=15.7690
# Month=50, Predicted=15.1030, Expected=15.7310
# Month=51, Predicted=15.8258, Expected=15.9960
# Month=52, Predicted=16.2038, Expected=17.0210
# Month=53, Predicted=17.6214, Expected=17.5520
# Month=54, Predicted=17.7416, Expected=17.8370
# Month=55, Predicted=17.8888, Expected=17.8560
# Month=56, Predicted=17.7774, Expected=17.5710
# Month=57, Predicted=17.3458, Expected=17.0780
# Month=58, Predicted=16.7732, Expected=16.6600
# Month=59, Predicted=16.4490, Expected=16.4330
# Month=60, Predicted=16.3531, Expected=16.5840
# Run 9 — RMSE: 0.496529, MSE: 0.246541, NMSE: 0.0019622954
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2492, Expected=13.7000
# Month=2, Predicted=14.0384, Expected=13.8140
# Month=3, Predicted=13.8132, Expected=14.3830
# Month=4, Predicted=14.6794, Expected=15.0470
# Month=5, Predicted=15.3623, Expected=15.6930
# Month=6, Predicted=15.9713, Expected=15.8440
# Month=7, Predicted=15.8124, Expected=15.7120
# Month=8, Predicted=15.5541, Expected=15.3130
# Month=9, Predicted=15.0391, Expected=14.7630
# Month=10, Predicted=14.4436, Expected=13.5480
# Month=11, Predicted=12.8433, Expected=13.5860
# Month=12, Predicted=13.7509, Expected=14.5160
# Month=13, Predicted=15.1219, Expected=14.3830
# Month=14, Predicted=14.2150, Expected=14.4970
# Month=15, Predicted=14.5374, Expected=14.7440
# Month=16, Predicted=14.8630, Expected=15.8060
# Month=17, Predicted=16.3981, Expected=16.5270
# Month=18, Predicted=16.8270, Expected=16.5460
# Month=19, Predicted=16.4152, Expected=16.7170
# Month=20, Predicted=16.7521, Expected=16.4330
# Month=21, Predicted=16.2015, Expected=15.7690
# Month=22, Predicted=15.3536, Expected=15.2750
# Month=23, Predicted=15.0289, Expected=15.1230
# Month=24, Predicted=15.0964, Expected=15.5410
# Month=25, Predicted=15.8296, Expected=15.8250
# Month=26, Predicted=15.9608, Expected=16.3760
# Month=27, Predicted=16.6575, Expected=16.3570
# Month=28, Predicted=16.2568, Expected=16.9070
# Month=29, Predicted=17.1985, Expected=17.0210
# Month=30, Predicted=17.0072, Expected=17.4190
# Month=31, Predicted=17.6062, Expected=17.5330
# Month=32, Predicted=17.5293, Expected=17.2680
# Month=33, Predicted=17.0525, Expected=16.6030
# Month=34, Predicted=16.1870, Expected=15.8250
# Month=35, Predicted=15.4011, Expected=15.4460
# Month=36, Predicted=15.3094, Expected=15.6360
# Month=37, Predicted=15.8225, Expected=15.6930
# Month=38, Predicted=15.7290, Expected=16.7550
# Month=39, Predicted=17.3802, Expected=16.5090
# Month=40, Predicted=16.2320, Expected=17.7230
# Month=41, Predicted=18.4179, Expected=18.6910
# Month=42, Predicted=19.1297, Expected=19.1270
# Month=43, Predicted=19.2219, Expected=19.5640
# Month=44, Predicted=19.7048, Expected=19.2030
# Month=45, Predicted=18.8715, Expected=18.2160
# Month=46, Predicted=17.5828, Expected=17.2110
# Month=47, Predicted=16.6724, Expected=16.6600
# Month=48, Predicted=16.4514, Expected=16.8310
# Month=49, Predicted=17.0375, Expected=15.7690
# Month=50, Predicted=15.1192, Expected=15.7310
# Month=51, Predicted=15.8185, Expected=15.9960
# Month=52, Predicted=16.1998, Expected=17.0210
# Month=53, Predicted=17.6205, Expected=17.5520
# Month=54, Predicted=17.7543, Expected=17.8370
# Month=55, Predicted=17.8972, Expected=17.8560
# Month=56, Predicted=17.7821, Expected=17.5710
# Month=57, Predicted=17.3489, Expected=17.0780
# Month=58, Predicted=16.7746, Expected=16.6600
# Month=59, Predicted=16.4452, Expected=16.4330
# Month=60, Predicted=16.3458, Expected=16.5840
# Run 10 — RMSE: 0.494434, MSE: 0.244465, NMSE: 0.0019427982
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.2622, Expected=13.7000
# Month=2, Predicted=14.0510, Expected=13.8140
# Month=3, Predicted=13.8197, Expected=14.3830
# Month=4, Predicted=14.6785, Expected=15.0470
# Month=5, Predicted=15.3585, Expected=15.6930
# Month=6, Predicted=15.9627, Expected=15.8440
# Month=7, Predicted=15.7990, Expected=15.7120
# Month=8, Predicted=15.5366, Expected=15.3130
# Month=9, Predicted=15.0227, Expected=14.7630
# Month=10, Predicted=14.4320, Expected=13.5480
# Month=11, Predicted=12.8213, Expected=13.5860
# Month=12, Predicted=13.7643, Expected=14.5160
# Month=13, Predicted=15.1424, Expected=14.3830
# Month=14, Predicted=14.2292, Expected=14.4970
# Month=15, Predicted=14.5391, Expected=14.7440
# Month=16, Predicted=14.8637, Expected=15.8060
# Month=17, Predicted=16.3934, Expected=16.5270
# Month=18, Predicted=16.8224, Expected=16.5460
# Month=19, Predicted=16.4004, Expected=16.7170
# Month=20, Predicted=16.7354, Expected=16.4330
# Month=21, Predicted=16.1859, Expected=15.7690
# Month=22, Predicted=15.3360, Expected=15.2750
# Month=23, Predicted=15.0232, Expected=15.1230
# Month=24, Predicted=15.1052, Expected=15.5410
# Month=25, Predicted=15.8455, Expected=15.8250
# Month=26, Predicted=15.9739, Expected=16.3760
# Month=27, Predicted=16.6621, Expected=16.3570
# Month=28, Predicted=16.2540, Expected=16.9070
# Month=29, Predicted=17.1927, Expected=17.0210
# Month=30, Predicted=17.0020, Expected=17.4190
# Month=31, Predicted=17.5998, Expected=17.5330
# Month=32, Predicted=17.5231, Expected=17.2680
# Month=33, Predicted=17.0419, Expected=16.6030
# Month=34, Predicted=16.1715, Expected=15.8250
# Month=35, Predicted=15.3897, Expected=15.4460
# Month=36, Predicted=15.3156, Expected=15.6360
# Month=37, Predicted=15.8413, Expected=15.6930
# Month=38, Predicted=15.7462, Expected=16.7550
# Month=39, Predicted=17.3865, Expected=16.5090
# Month=40, Predicted=16.2325, Expected=17.7230
# Month=41, Predicted=18.4046, Expected=18.6910
# Month=42, Predicted=19.1206, Expected=19.1270
# Month=43, Predicted=19.2063, Expected=19.5640
# Month=44, Predicted=19.6834, Expected=19.2030
# Month=45, Predicted=18.8459, Expected=18.2160
# Month=46, Predicted=17.5477, Expected=17.2110
# Month=47, Predicted=16.6496, Expected=16.6600
# Month=48, Predicted=16.4556, Expected=16.8310
# Month=49, Predicted=17.0604, Expected=15.7690
# Month=50, Predicted=15.1199, Expected=15.7310
# Month=51, Predicted=15.8333, Expected=15.9960
# Month=52, Predicted=16.2205, Expected=17.0210
# Month=53, Predicted=17.6315, Expected=17.5520
# Month=54, Predicted=17.7600, Expected=17.8370
# Month=55, Predicted=17.8892, Expected=17.8560
# Month=56, Predicted=17.7681, Expected=17.5710
# Month=57, Predicted=17.3332, Expected=17.0780
# Month=58, Predicted=16.7612, Expected=16.6600
# Month=59, Predicted=16.4411, Expected=16.4330
# Month=60, Predicted=16.3519, Expected=16.5840
# Run 11 — RMSE: 0.491792, MSE: 0.241859, NMSE: 0.0019342624
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2880, Expected=13.7000
# Month=2, Predicted=14.0690, Expected=13.8140
# Month=3, Predicted=13.8117, Expected=14.3830
# Month=4, Predicted=14.6533, Expected=15.0470
# Month=5, Predicted=15.3086, Expected=15.6930
# Month=6, Predicted=15.8857, Expected=15.8440
# Month=7, Predicted=15.6985, Expected=15.7120
# Month=8, Predicted=15.4344, Expected=15.3130
# Month=9, Predicted=14.9387, Expected=14.7630
# Month=10, Predicted=14.3822, Expected=13.5480
# Month=11, Predicted=12.8109, Expected=13.5860
# Month=12, Predicted=13.8200, Expected=14.5160
# Month=13, Predicted=15.2011, Expected=14.3830
# Month=14, Predicted=14.2523, Expected=14.4970
# Month=15, Predicted=14.5434, Expected=14.7440
# Month=16, Predicted=14.8549, Expected=15.8060
# Month=17, Predicted=16.3667, Expected=16.5270
# Month=18, Predicted=16.7572, Expected=16.5460
# Month=19, Predicted=16.3025, Expected=16.7170
# Month=20, Predicted=16.6373, Expected=16.4330
# Month=21, Predicted=16.0936, Expected=15.7690
# Month=22, Predicted=15.2692, Expected=15.2750
# Month=23, Predicted=15.0028, Expected=15.1230
# Month=24, Predicted=15.1220, Expected=15.5410
# Month=25, Predicted=15.8740, Expected=15.8250
# Month=26, Predicted=15.9854, Expected=16.3760
# Month=27, Predicted=16.6515, Expected=16.3570
# Month=28, Predicted=16.2166, Expected=16.9070
# Month=29, Predicted=17.1480, Expected=17.0210
# Month=30, Predicted=16.9405, Expected=17.4190
# Month=31, Predicted=17.5347, Expected=17.5330
# Month=32, Predicted=17.4501, Expected=17.2680
# Month=33, Predicted=16.9705, Expected=16.6030
# Month=34, Predicted=16.1199, Expected=15.8250
# Month=35, Predicted=15.3793, Expected=15.4460
# Month=36, Predicted=15.3523, Expected=15.6360
# Month=37, Predicted=15.8994, Expected=15.6930
# Month=38, Predicted=15.7942, Expected=16.7550
# Month=39, Predicted=17.4125, Expected=16.5090
# Month=40, Predicted=16.2155, Expected=17.7230
# Month=41, Predicted=18.3724, Expected=18.6910
# Month=42, Predicted=19.0473, Expected=19.1270
# Month=43, Predicted=19.0936, Expected=19.5640
# Month=44, Predicted=19.5544, Expected=19.2030
# Month=45, Predicted=18.7100, Expected=18.2160
# Month=46, Predicted=17.4410, Expected=17.2110
# Month=47, Predicted=16.6130, Expected=16.6600
# Month=48, Predicted=16.4915, Expected=16.8310
# Month=49, Predicted=17.1324, Expected=15.7690
# Month=50, Predicted=15.1877, Expected=15.7310
# Month=51, Predicted=15.9247, Expected=15.9960
# Month=52, Predicted=16.3056, Expected=17.0210
# Month=53, Predicted=17.6842, Expected=17.5520
# Month=54, Predicted=17.7615, Expected=17.8370
# Month=55, Predicted=17.8490, Expected=17.8560
# Month=56, Predicted=17.7058, Expected=17.5710
# Month=57, Predicted=17.2696, Expected=17.0780
# Month=58, Predicted=16.7166, Expected=16.6600
# Month=59, Predicted=16.4289, Expected=16.4330
# Month=60, Predicted=16.3679, Expected=16.5840
# Run 12 — RMSE: 0.482524, MSE: 0.232829, NMSE: 0.0019224017
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2712, Expected=13.7000
# Month=2, Predicted=14.0589, Expected=13.8140
# Month=3, Predicted=13.8229, Expected=14.3830
# Month=4, Predicted=14.6693, Expected=15.0470
# Month=5, Predicted=15.3438, Expected=15.6930
# Month=6, Predicted=15.9417, Expected=15.8440
# Month=7, Predicted=15.7713, Expected=15.7120
# Month=8, Predicted=15.5015, Expected=15.3130
# Month=9, Predicted=14.9883, Expected=14.7630
# Month=10, Predicted=14.4070, Expected=13.5480
# Month=11, Predicted=12.8077, Expected=13.5860
# Month=12, Predicted=13.7762, Expected=14.5160
# Month=13, Predicted=15.1626, Expected=14.3830
# Month=14, Predicted=14.2489, Expected=14.4970
# Month=15, Predicted=14.5395, Expected=14.7440
# Month=16, Predicted=14.8573, Expected=15.8060
# Month=17, Predicted=16.3794, Expected=16.5270
# Month=18, Predicted=16.8073, Expected=16.5460
# Month=19, Predicted=16.3743, Expected=16.7170
# Month=20, Predicted=16.7000, Expected=16.4330
# Month=21, Predicted=16.1515, Expected=15.7690
# Month=22, Predicted=15.3049, Expected=15.2750
# Month=23, Predicted=15.0073, Expected=15.1230
# Month=24, Predicted=15.1079, Expected=15.5410
# Month=25, Predicted=15.8563, Expected=15.8250
# Month=26, Predicted=15.9839, Expected=16.3760
# Month=27, Predicted=16.6616, Expected=16.3570
# Month=28, Predicted=16.2454, Expected=16.9070
# Month=29, Predicted=17.1741, Expected=17.0210
# Month=30, Predicted=16.9825, Expected=17.4190
# Month=31, Predicted=17.5761, Expected=17.5330
# Month=32, Predicted=17.4997, Expected=17.2680
# Month=33, Predicted=17.0160, Expected=16.6030
# Month=34, Predicted=16.1463, Expected=15.8250
# Month=35, Predicted=15.3756, Expected=15.4460
# Month=36, Predicted=15.3221, Expected=15.6360
# Month=37, Predicted=15.8613, Expected=15.6930
# Month=38, Predicted=15.7679, Expected=16.7550
# Month=39, Predicted=17.3933, Expected=16.5090
# Month=40, Predicted=16.2348, Expected=17.7230
# Month=41, Predicted=18.3843, Expected=18.6910
# Month=42, Predicted=19.1014, Expected=19.1270
# Month=43, Predicted=19.1793, Expected=19.5640
# Month=44, Predicted=19.6459, Expected=19.2030
# Month=45, Predicted=18.8023, Expected=18.2160
# Month=46, Predicted=17.4997, Expected=17.2110
# Month=47, Predicted=16.6213, Expected=16.6600
# Month=48, Predicted=16.4625, Expected=16.8310
# Month=49, Predicted=17.0890, Expected=15.7690
# Month=50, Predicted=15.1525, Expected=15.7310
# Month=51, Predicted=15.8619, Expected=15.9960
# Month=52, Predicted=16.2509, Expected=17.0210
# Month=53, Predicted=17.6477, Expected=17.5520
# Month=54, Predicted=17.7673, Expected=17.8370
# Month=55, Predicted=17.8780, Expected=17.8560
# Month=56, Predicted=17.7438, Expected=17.5710
# Month=57, Predicted=17.3034, Expected=17.0780
# Month=58, Predicted=16.7346, Expected=16.6600
# Month=59, Predicted=16.4266, Expected=16.4330
# Month=60, Predicted=16.3519, Expected=16.5840
# Run 13 — RMSE: 0.486961, MSE: 0.237131, NMSE: 0.0019150943
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2440, Expected=13.7000
# Month=2, Predicted=14.0330, Expected=13.8140
# Month=3, Predicted=13.8141, Expected=14.3830
# Month=4, Predicted=14.6865, Expected=15.0470
# Month=5, Predicted=15.3704, Expected=15.6930
# Month=6, Predicted=15.9850, Expected=15.8440
# Month=7, Predicted=15.8311, Expected=15.7120
# Month=8, Predicted=15.5707, Expected=15.3130
# Month=9, Predicted=15.0465, Expected=14.7630
# Month=10, Predicted=14.4417, Expected=13.5480
# Month=11, Predicted=12.8141, Expected=13.5860
# Month=12, Predicted=13.7458, Expected=14.5160
# Month=13, Predicted=15.1001, Expected=14.3830
# Month=14, Predicted=14.2056, Expected=14.4970
# Month=15, Predicted=14.5429, Expected=14.7440
# Month=16, Predicted=14.8678, Expected=15.8060
# Month=17, Predicted=16.3957, Expected=16.5270
# Month=18, Predicted=16.8361, Expected=16.5460
# Month=19, Predicted=16.4345, Expected=16.7170
# Month=20, Predicted=16.7728, Expected=16.4330
# Month=21, Predicted=16.2112, Expected=15.7690
# Month=22, Predicted=15.3516, Expected=15.2750
# Month=23, Predicted=15.0251, Expected=15.1230
# Month=24, Predicted=15.0904, Expected=15.5410
# Month=25, Predicted=15.8223, Expected=15.8250
# Month=26, Predicted=15.9569, Expected=16.3760
# Month=27, Predicted=16.6605, Expected=16.3570
# Month=28, Predicted=16.2638, Expected=16.9070
# Month=29, Predicted=17.2092, Expected=17.0210
# Month=30, Predicted=17.0166, Expected=17.4190
# Month=31, Predicted=17.6187, Expected=17.5330
# Month=32, Predicted=17.5402, Expected=17.2680
# Month=33, Predicted=17.0601, Expected=16.6030
# Month=34, Predicted=16.1835, Expected=15.8250
# Month=35, Predicted=15.3896, Expected=15.4460
# Month=36, Predicted=15.3000, Expected=15.6360
# Month=37, Predicted=15.8121, Expected=15.6930
# Month=38, Predicted=15.7190, Expected=16.7550
# Month=39, Predicted=17.3690, Expected=16.5090
# Month=40, Predicted=16.2310, Expected=17.7230
# Month=41, Predicted=18.4181, Expected=18.6910
# Month=42, Predicted=19.1361, Expected=19.1270
# Month=43, Predicted=19.2455, Expected=19.5640
# Month=44, Predicted=19.7315, Expected=19.2030
# Month=45, Predicted=18.8877, Expected=18.2160
# Month=46, Predicted=17.5775, Expected=17.2110
# Month=47, Predicted=16.6582, Expected=16.6600
# Month=48, Predicted=16.4386, Expected=16.8310
# Month=49, Predicted=17.0240, Expected=15.7690
# Month=50, Predicted=15.0809, Expected=15.7310
# Month=51, Predicted=15.8104, Expected=15.9960
# Month=52, Predicted=16.1860, Expected=17.0210
# Month=53, Predicted=17.6047, Expected=17.5520
# Month=54, Predicted=17.7566, Expected=17.8370
# Month=55, Predicted=17.9120, Expected=17.8560
# Month=56, Predicted=17.7975, Expected=17.5710
# Month=57, Predicted=17.3579, Expected=17.0780
# Month=58, Predicted=16.7752, Expected=16.6600
# Month=59, Predicted=16.4417, Expected=16.4330
# Month=60, Predicted=16.3398, Expected=16.5840
# Run 14 — RMSE: 0.496968, MSE: 0.246978, NMSE: 0.0019468991
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.2645, Expected=13.7000
# Month=2, Predicted=14.0553, Expected=13.8140
# Month=3, Predicted=13.8211, Expected=14.3830
# Month=4, Predicted=14.6780, Expected=15.0470
# Month=5, Predicted=15.3635, Expected=15.6930
# Month=6, Predicted=15.9705, Expected=15.8440
# Month=7, Predicted=15.8027, Expected=15.7120
# Month=8, Predicted=15.5320, Expected=15.3130
# Month=9, Predicted=15.0138, Expected=14.7630
# Month=10, Predicted=14.4231, Expected=13.5480
# Month=11, Predicted=12.8052, Expected=13.5860
# Month=12, Predicted=13.7689, Expected=14.5160
# Month=13, Predicted=15.1530, Expected=14.3830
# Month=14, Predicted=14.2342, Expected=14.4970
# Month=15, Predicted=14.5313, Expected=14.7440
# Month=16, Predicted=14.8588, Expected=15.8060
# Month=17, Predicted=16.3961, Expected=16.5270
# Month=18, Predicted=16.8347, Expected=16.5460
# Month=19, Predicted=16.4028, Expected=16.7170
# Month=20, Predicted=16.7327, Expected=16.4330
# Month=21, Predicted=16.1803, Expected=15.7690
# Month=22, Predicted=15.3238, Expected=15.2750
# Month=23, Predicted=15.0168, Expected=15.1230
# Month=24, Predicted=15.1072, Expected=15.5410
# Month=25, Predicted=15.8516, Expected=15.8250
# Month=26, Predicted=15.9788, Expected=16.3760
# Month=27, Predicted=16.6643, Expected=16.3570
# Month=28, Predicted=16.2515, Expected=16.9070
# Month=29, Predicted=17.1910, Expected=17.0210
# Month=30, Predicted=17.0025, Expected=17.4190
# Month=31, Predicted=17.6004, Expected=17.5330
# Month=32, Predicted=17.5241, Expected=17.2680
# Month=33, Predicted=17.0358, Expected=16.6030
# Month=34, Predicted=16.1579, Expected=15.8250
# Month=35, Predicted=15.3774, Expected=15.4460
# Month=36, Predicted=15.3147, Expected=15.6360
# Month=37, Predicted=15.8474, Expected=15.6930
# Month=38, Predicted=15.7496, Expected=16.7550
# Month=39, Predicted=17.3887, Expected=16.5090
# Month=40, Predicted=16.2315, Expected=17.7230
# Month=41, Predicted=18.4019, Expected=18.6910
# Month=42, Predicted=19.1349, Expected=19.1270
# Month=43, Predicted=19.2183, Expected=19.5640
# Month=44, Predicted=19.6900, Expected=19.2030
# Month=45, Predicted=18.8419, Expected=18.2160
# Month=46, Predicted=17.5275, Expected=17.2110
# Month=47, Predicted=16.6362, Expected=16.6600
# Month=48, Predicted=16.4604, Expected=16.8310
# Month=49, Predicted=17.0731, Expected=15.7690
# Month=50, Predicted=15.1142, Expected=15.7310
# Month=51, Predicted=15.8291, Expected=15.9960
# Month=52, Predicted=16.2218, Expected=17.0210
# Month=53, Predicted=17.6340, Expected=17.5520
# Month=54, Predicted=17.7667, Expected=17.8370
# Month=55, Predicted=17.8883, Expected=17.8560
# Month=56, Predicted=17.7620, Expected=17.5710
# Month=57, Predicted=17.3229, Expected=17.0780
# Month=58, Predicted=16.7496, Expected=16.6600
# Month=59, Predicted=16.4343, Expected=16.4330
# Month=60, Predicted=16.3509, Expected=16.5840
# Run 15 — RMSE: 0.492018, MSE: 0.242082, NMSE: 0.0019320243
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.2247, Expected=13.7000
# Month=2, Predicted=14.0218, Expected=13.8140
# Month=3, Predicted=13.8356, Expected=14.3830
# Month=4, Predicted=14.6838, Expected=15.0470
# Month=5, Predicted=15.3799, Expected=15.6930
# Month=6, Predicted=16.0018, Expected=15.8440
# Month=7, Predicted=15.8618, Expected=15.7120
# Month=8, Predicted=15.5912, Expected=15.3130
# Month=9, Predicted=15.0597, Expected=14.7630
# Month=10, Predicted=14.4444, Expected=13.5480
# Month=11, Predicted=12.8395, Expected=13.5860
# Month=12, Predicted=13.6821, Expected=14.5160
# Month=13, Predicted=15.0706, Expected=14.3830
# Month=14, Predicted=14.2464, Expected=14.4970
# Month=15, Predicted=14.5438, Expected=14.7440
# Month=16, Predicted=14.8669, Expected=15.8060
# Month=17, Predicted=16.3873, Expected=16.5270
# Month=18, Predicted=16.8623, Expected=16.5460
# Month=19, Predicted=16.4757, Expected=16.7170
# Month=20, Predicted=16.7791, Expected=16.4330
# Month=21, Predicted=16.2319, Expected=15.7690
# Month=22, Predicted=15.3683, Expected=15.2750
# Month=23, Predicted=15.0105, Expected=15.1230
# Month=24, Predicted=15.0656, Expected=15.5410
# Month=25, Predicted=15.7989, Expected=15.8250
# Month=26, Predicted=15.9639, Expected=16.3760
# Month=27, Predicted=16.6628, Expected=16.3570
# Month=28, Predicted=16.2923, Expected=16.9070
# Month=29, Predicted=17.2017, Expected=17.0210
# Month=30, Predicted=17.0375, Expected=17.4190
# Month=31, Predicted=17.6190, Expected=17.5330
# Month=32, Predicted=17.5564, Expected=17.2680
# Month=33, Predicted=17.0801, Expected=16.6030
# Month=34, Predicted=16.2012, Expected=15.8250
# Month=35, Predicted=15.3878, Expected=15.4460
# Month=36, Predicted=15.2695, Expected=15.6360
# Month=37, Predicted=15.7806, Expected=15.6930
# Month=38, Predicted=15.7197, Expected=16.7550
# Month=39, Predicted=17.3537, Expected=16.5090
# Month=40, Predicted=16.2853, Expected=17.7230
# Month=41, Predicted=18.3992, Expected=18.6910
# Month=42, Predicted=19.1605, Expected=19.1270
# Month=43, Predicted=19.2832, Expected=19.5640
# Month=44, Predicted=19.7499, Expected=19.2030
# Month=45, Predicted=18.9286, Expected=18.2160
# Month=46, Predicted=17.6122, Expected=17.2110
# Month=47, Predicted=16.6514, Expected=16.6600
# Month=48, Predicted=16.3994, Expected=16.8310
# Month=49, Predicted=16.9820, Expected=15.7690
# Month=50, Predicted=15.1276, Expected=15.7310
# Month=51, Predicted=15.7638, Expected=15.9960
# Month=52, Predicted=16.1663, Expected=17.0210
# Month=53, Predicted=17.5943, Expected=17.5520
# Month=54, Predicted=17.7853, Expected=17.8370
# Month=55, Predicted=17.9369, Expected=17.8560
# Month=56, Predicted=17.8176, Expected=17.5710
# Month=57, Predicted=17.3742, Expected=17.0780
# Month=58, Predicted=16.7824, Expected=16.6600
# Month=59, Predicted=16.4315, Expected=16.4330
# Month=60, Predicted=16.3227, Expected=16.5840
# Run 16 — RMSE: 0.495712, MSE: 0.245731, NMSE: 0.0019203046
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.2599, Expected=13.7000
# Month=2, Predicted=14.0465, Expected=13.8140
# Month=3, Predicted=13.8082, Expected=14.3830
# Month=4, Predicted=14.6803, Expected=15.0470
# Month=5, Predicted=15.3579, Expected=15.6930
# Month=6, Predicted=15.9635, Expected=15.8440
# Month=7, Predicted=15.8004, Expected=15.7120
# Month=8, Predicted=15.5448, Expected=15.3130
# Month=9, Predicted=15.0318, Expected=14.7630
# Month=10, Predicted=14.4398, Expected=13.5480
# Month=11, Predicted=12.8269, Expected=13.5860
# Month=12, Predicted=13.7742, Expected=14.5160
# Month=13, Predicted=15.1387, Expected=14.3830
# Month=14, Predicted=14.2048, Expected=14.4970
# Month=15, Predicted=14.5369, Expected=14.7440
# Month=16, Predicted=14.8630, Expected=15.8060
# Month=17, Predicted=16.3996, Expected=16.5270
# Month=18, Predicted=16.8154, Expected=16.5460
# Month=19, Predicted=16.3994, Expected=16.7170
# Month=20, Predicted=16.7470, Expected=16.4330
# Month=21, Predicted=16.1925, Expected=15.7690
# Month=22, Predicted=15.3442, Expected=15.2750
# Month=23, Predicted=15.0313, Expected=15.1230
# Month=24, Predicted=15.1070, Expected=15.5410
# Month=25, Predicted=15.8431, Expected=15.8250
# Month=26, Predicted=15.9626, Expected=16.3760
# Month=27, Predicted=16.6584, Expected=16.3570
# Month=28, Predicted=16.2474, Expected=16.9070
# Month=29, Predicted=17.1998, Expected=17.0210
# Month=30, Predicted=16.9995, Expected=17.4190
# Month=31, Predicted=17.6055, Expected=17.5330
# Month=32, Predicted=17.5239, Expected=17.2680
# Month=33, Predicted=17.0450, Expected=16.6030
# Month=34, Predicted=16.1776, Expected=15.8250
# Month=35, Predicted=15.3966, Expected=15.4460
# Month=36, Predicted=15.3192, Expected=15.6360
# Month=37, Predicted=15.8384, Expected=15.6930
# Month=38, Predicted=15.7334, Expected=16.7550
# Month=39, Predicted=17.3877, Expected=16.5090
# Month=40, Predicted=16.2139, Expected=17.7230
# Month=41, Predicted=18.4201, Expected=18.6910
# Month=42, Predicted=19.1154, Expected=19.1270
# Month=43, Predicted=19.2054, Expected=19.5640
# ...
# Month=26, Predicted=15.9732, Expected=16.3760
# Month=27, Predicted=16.6602, Expected=16.3570
# Month=28, Predicted=16.2467, Expected=16.9070
# Month=29, Predicted=17.1871, Expected=17.0210
# Month=30, Predicted=16.9915, Expected=17.4190
# Month=31, Predicted=17.5907, Expected=17.5330
# Month=32, Predicted=17.5119, Expected=17.2680
# Month=33, Predicted=17.0310, Expected=16.6030
# Month=34, Predicted=16.1635, Expected=15.8250
# Month=35, Predicted=15.3876, Expected=15.4460
# Month=36, Predicted=15.3210, Expected=15.6360
# Month=37, Predicted=15.8507, Expected=15.6930
# Month=38, Predicted=15.7510, Expected=16.7550
# Month=39, Predicted=17.3936, Expected=16.5090
# Month=40, Predicted=16.2250, Expected=17.7230
# Month=41, Predicted=18.4038, Expected=18.6910
# Month=42, Predicted=19.1079, Expected=19.1270
# Month=43, Predicted=19.1904, Expected=19.5640
# Month=44, Predicted=19.6678, Expected=19.2030
# Month=45, Predicted=18.8281, Expected=18.2160
# Month=46, Predicted=17.5330, Expected=17.2110
# Month=47, Predicted=16.6433, Expected=16.6600
# Month=48, Predicted=16.4615, Expected=16.8310
# Month=49, Predicted=17.0732, Expected=15.7690
# Month=50, Predicted=15.1302, Expected=15.7310
# Month=51, Predicted=15.8458, Expected=15.9960
# Month=52, Predicted=16.2308, Expected=17.0210
# Month=53, Predicted=17.6400, Expected=17.5520
# Month=54, Predicted=17.7554, Expected=17.8370
# Month=55, Predicted=17.8817, Expected=17.8560
# Month=56, Predicted=17.7580, Expected=17.5710
# Month=57, Predicted=17.3225, Expected=17.0780
# Month=58, Predicted=16.7529, Expected=16.6600
# Month=59, Predicted=16.4376, Expected=16.4330
# Month=60, Predicted=16.3531, Expected=16.5840
# Run 25 — RMSE: 0.490850, MSE: 0.240934, NMSE: 0.0019350944
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.2625, Expected=13.7000
# Month=2, Predicted=14.0485, Expected=13.8140
# Month=3, Predicted=13.8091, Expected=14.3830
# Month=4, Predicted=14.6799, Expected=15.0470
# Month=5, Predicted=15.3583, Expected=15.6930
# Month=6, Predicted=15.9637, Expected=15.8440
# Month=7, Predicted=15.7988, Expected=15.7120
# Month=8, Predicted=15.5406, Expected=15.3130
# Month=9, Predicted=15.0267, Expected=14.7630
# Month=10, Predicted=14.4355, Expected=13.5480
# Month=11, Predicted=12.8163, Expected=13.5860
# Month=12, Predicted=13.7776, Expected=14.5160
# Month=13, Predicted=15.1403, Expected=14.3830
# Month=14, Predicted=14.2055, Expected=14.4970
# Month=15, Predicted=14.5351, Expected=14.7440
# Month=16, Predicted=14.8628, Expected=15.8060
# Month=17, Predicted=16.3976, Expected=16.5270
# Month=18, Predicted=16.8169, Expected=16.5460
# Month=19, Predicted=16.3965, Expected=16.7170
# Month=20, Predicted=16.7438, Expected=16.4330
# Month=21, Predicted=16.1882, Expected=15.7690
# Month=22, Predicted=15.3373, Expected=15.2750
# Month=23, Predicted=15.0291, Expected=15.1230
# Month=24, Predicted=15.1092, Expected=15.5410
# Month=25, Predicted=15.8461, Expected=15.8250
# Month=26, Predicted=15.9651, Expected=16.3760
# Month=27, Predicted=16.6591, Expected=16.3570
# Month=28, Predicted=16.2462, Expected=16.9070
# Month=29, Predicted=17.1987, Expected=17.0210
# Month=30, Predicted=16.9991, Expected=17.4190
# Month=31, Predicted=17.6048, Expected=17.5330
# Month=32, Predicted=17.5231, Expected=17.2680
# Month=33, Predicted=17.0413, Expected=16.6030
# Month=34, Predicted=16.1707, Expected=15.8250
# Month=35, Predicted=15.3914, Expected=15.4460
# Month=36, Predicted=15.3209, Expected=15.6360
# Month=37, Predicted=15.8427, Expected=15.6930
# Month=38, Predicted=15.7365, Expected=16.7550
# Month=39, Predicted=17.3861, Expected=16.5090
# Month=40, Predicted=16.2118, Expected=17.7230
# Month=41, Predicted=18.4138, Expected=18.6910
# Month=42, Predicted=19.1159, Expected=19.1270
# Month=43, Predicted=19.2047, Expected=19.5640
# Month=44, Predicted=19.6923, Expected=19.2030
# Month=45, Predicted=18.8480, Expected=18.2160
# Month=46, Predicted=17.5493, Expected=17.2110
# Month=47, Predicted=16.6567, Expected=16.6600
# Month=48, Predicted=16.4647, Expected=16.8310
# Month=49, Predicted=17.0641, Expected=15.7690
# Month=50, Predicted=15.0972, Expected=15.7310
# Month=51, Predicted=15.8366, Expected=15.9960
# Month=52, Predicted=16.2142, Expected=17.0210
# Month=53, Predicted=17.6260, Expected=17.5520
# Month=54, Predicted=17.7458, Expected=17.8370
# Month=55, Predicted=17.8850, Expected=17.8560
# Month=56, Predicted=17.7691, Expected=17.5710
# Month=57, Predicted=17.3354, Expected=17.0780
# Month=58, Predicted=16.7638, Expected=16.6600
# Month=59, Predicted=16.4450, Expected=16.4330
# Month=60, Predicted=16.3540, Expected=16.5840
# Run 26 — RMSE: 0.494673, MSE: 0.244701, NMSE: 0.0019539763
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.2509, Expected=13.7000
# Month=2, Predicted=14.0422, Expected=13.8140
# Month=3, Predicted=13.8137, Expected=14.3830
# Month=4, Predicted=14.6948, Expected=15.0470
# Month=5, Predicted=15.3759, Expected=15.6930
# Month=6, Predicted=15.9887, Expected=15.8440
# Month=7, Predicted=15.8295, Expected=15.7120
# Month=8, Predicted=15.5689, Expected=15.3130
# Month=9, Predicted=15.0423, Expected=14.7630
# Month=10, Predicted=14.4378, Expected=13.5480
# Month=11, Predicted=12.8406, Expected=13.5860
# Month=12, Predicted=13.7594, Expected=14.5160
# Month=13, Predicted=15.1145, Expected=14.3830
# Month=14, Predicted=14.1985, Expected=14.4970
# Month=15, Predicted=14.5478, Expected=14.7440
# Month=16, Predicted=14.8737, Expected=15.8060
# Month=17, Predicted=16.4063, Expected=16.5270
# Month=18, Predicted=16.8375, Expected=16.5460
# Month=19, Predicted=16.4299, Expected=16.7170
# Month=20, Predicted=16.7770, Expected=16.4330
# Month=21, Predicted=16.2072, Expected=15.7690
# Month=22, Predicted=15.3517, Expected=15.2750
# Month=23, Predicted=15.0230, Expected=15.1230
# Month=24, Predicted=15.0945, Expected=15.5410
# Month=25, Predicted=15.8326, Expected=15.8250
# Month=26, Predicted=15.9604, Expected=16.3760
# Month=27, Predicted=16.6674, Expected=16.3570
# Month=28, Predicted=16.2612, Expected=16.9070
# Month=29, Predicted=17.2185, Expected=17.0210
# Month=30, Predicted=17.0165, Expected=17.4190
# Month=31, Predicted=17.6252, Expected=17.5330
# Month=32, Predicted=17.5411, Expected=17.2680
# Month=33, Predicted=17.0563, Expected=16.6030
# Month=34, Predicted=16.1838, Expected=15.8250
# Month=35, Predicted=15.3970, Expected=15.4460
# Month=36, Predicted=15.3014, Expected=15.6360
# Month=37, Predicted=15.8213, Expected=15.6930
# Month=38, Predicted=15.7211, Expected=16.7550
# Month=39, Predicted=17.3814, Expected=16.5090
# Month=40, Predicted=16.2208, Expected=17.7230
# Month=41, Predicted=18.4322, Expected=18.6910
# Month=42, Predicted=19.1381, Expected=19.1270
# Month=43, Predicted=19.2437, Expected=19.5640
# Month=44, Predicted=19.7345, Expected=19.2030
# Month=45, Predicted=18.8794, Expected=18.2160
# Month=46, Predicted=17.5924, Expected=17.2110
# Month=47, Predicted=16.6772, Expected=16.6600
# Month=48, Predicted=16.4385, Expected=16.8310
# Month=49, Predicted=17.0343, Expected=15.7690
# Month=50, Predicted=15.0973, Expected=15.7310
# Month=51, Predicted=15.8209, Expected=15.9960
# Month=52, Predicted=16.1944, Expected=17.0210
# Month=53, Predicted=17.6159, Expected=17.5520
# Month=54, Predicted=17.7573, Expected=17.8370
# Month=55, Predicted=17.9131, Expected=17.8560
# Month=56, Predicted=17.7975, Expected=17.5710
# Month=57, Predicted=17.3549, Expected=17.0780
# Month=58, Predicted=16.7701, Expected=16.6600
# Month=59, Predicted=16.4400, Expected=16.4330
# Month=60, Predicted=16.3417, Expected=16.5840
# Run 27 — RMSE: 0.496373, MSE: 0.246386, NMSE: 0.0019462693
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.2569, Expected=13.7000
# Month=2, Predicted=14.0456, Expected=13.8140
# Month=3, Predicted=13.8120, Expected=14.3830
# Month=4, Predicted=14.6773, Expected=15.0470
# Month=5, Predicted=15.3577, Expected=15.6930
# Month=6, Predicted=15.9635, Expected=15.8440
# Month=7, Predicted=15.8015, Expected=15.7120
# Month=8, Predicted=15.5441, Expected=15.3130
# Month=9, Predicted=15.0317, Expected=14.7630
# Month=10, Predicted=14.4397, Expected=13.5480
# Month=11, Predicted=12.8375, Expected=13.5860
# Month=12, Predicted=13.7586, Expected=14.5160
# Month=13, Predicted=15.1373, Expected=14.3830
# Month=14, Predicted=14.2145, Expected=14.4970
# Month=15, Predicted=14.5334, Expected=14.7440
# Month=16, Predicted=14.8601, Expected=15.8060
# Month=17, Predicted=16.3979, Expected=16.5270
# Month=18, Predicted=16.8181, Expected=16.5460
# Month=19, Predicted=16.4017, Expected=16.7170
# Month=20, Predicted=16.7421, Expected=16.4330
# Month=21, Predicted=16.1936, Expected=15.7690
# Month=22, Predicted=15.3469, Expected=15.2750
# Month=23, Predicted=15.0276, Expected=15.1230
# Month=24, Predicted=15.1027, Expected=15.5410
# Month=25, Predicted=15.8402, Expected=15.8250
# Month=26, Predicted=15.9653, Expected=16.3760
# Month=27, Predicted=16.6578, Expected=16.3570
# Month=28, Predicted=16.2506, Expected=16.9070
# Month=29, Predicted=17.1948, Expected=17.0210
# Month=30, Predicted=17.0011, Expected=17.4190
# Month=31, Predicted=17.6022, Expected=17.5330
# Month=32, Predicted=17.5245, Expected=17.2680
# Month=33, Predicted=17.0467, Expected=16.6030
# Month=34, Predicted=16.1806, Expected=15.8250
# Month=35, Predicted=15.3969, Expected=15.4460
# Month=36, Predicted=15.3133, Expected=15.6360
# Month=37, Predicted=15.8337, Expected=15.6930
# Month=38, Predicted=15.7359, Expected=16.7550
# Month=39, Predicted=17.3865, Expected=16.5090
# Month=40, Predicted=16.2234, Expected=17.7230
# Month=41, Predicted=18.4140, Expected=18.6910
# Month=42, Predicted=19.1176, Expected=19.1270
# Month=43, Predicted=19.2058, Expected=19.5640
# Month=44, Predicted=19.6912, Expected=19.2030
# Month=45, Predicted=18.8581, Expected=18.2160
# Month=46, Predicted=17.5692, Expected=17.2110
# Month=47, Predicted=16.6636, Expected=16.6600
# Month=48, Predicted=16.4552, Expected=16.8310
# Month=49, Predicted=17.0523, Expected=15.7690
# Month=50, Predicted=15.1222, Expected=15.7310
# Month=51, Predicted=15.8231, Expected=15.9960
# Month=52, Predicted=16.2079, Expected=17.0210
# Month=53, Predicted=17.6264, Expected=17.5520
# Month=54, Predicted=17.7473, Expected=17.8370
# Month=55, Predicted=17.8856, Expected=17.8560
# Month=56, Predicted=17.7704, Expected=17.5710
# Month=57, Predicted=17.3392, Expected=17.0780
# Month=58, Predicted=16.7681, Expected=16.6600
# Month=59, Predicted=16.4439, Expected=16.4330
# Month=60, Predicted=16.3499, Expected=16.5840
# Run 28 — RMSE: 0.494261, MSE: 0.244293, NMSE: 0.0019502711
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.2604, Expected=13.7000
# Month=2, Predicted=14.0444, Expected=13.8140
# Month=3, Predicted=13.8010, Expected=14.3830
# Month=4, Predicted=14.6844, Expected=15.0470
# Month=5, Predicted=15.3601, Expected=15.6930
# Month=6, Predicted=15.9673, Expected=15.8440
# Month=7, Predicted=15.8048, Expected=15.7120
# Month=8, Predicted=15.5543, Expected=15.3130
# Month=9, Predicted=15.0407, Expected=14.7630
# Month=10, Predicted=14.4465, Expected=13.5480
# Month=11, Predicted=12.8246, Expected=13.5860
# Month=12, Predicted=13.7825, Expected=14.5160
# Month=13, Predicted=15.1342, Expected=14.3830
# Month=14, Predicted=14.1848, Expected=14.4970
# Month=15, Predicted=14.5377, Expected=14.7440
# Month=16, Predicted=14.8658, Expected=15.8060
# Month=17, Predicted=16.4041, Expected=16.5270
# Month=18, Predicted=16.8118, Expected=16.5460
# Month=19, Predicted=16.4012, Expected=16.7170
# Month=20, Predicted=16.7604, Expected=16.4330
# Month=21, Predicted=16.1997, Expected=15.7690
# Month=22, Predicted=15.3500, Expected=15.2750
# Month=23, Predicted=15.0384, Expected=15.1230
# Month=24, Predicted=15.1107, Expected=15.5410
# Month=25, Predicted=15.8430, Expected=15.8250
# Month=26, Predicted=15.9557, Expected=16.3760
# Month=27, Predicted=16.6576, Expected=16.3570
# Month=28, Predicted=16.2444, Expected=16.9070
# Month=29, Predicted=17.2085, Expected=17.0210
# Month=30, Predicted=17.0006, Expected=17.4190
# Month=31, Predicted=17.6135, Expected=17.5330
# Month=32, Predicted=17.5275, Expected=17.2680
# Month=33, Predicted=17.0492, Expected=16.6030
# Month=34, Predicted=16.1814, Expected=15.8250
# Month=35, Predicted=15.4007, Expected=15.4460
# Month=36, Predicted=15.3236, Expected=15.6360
# Month=37, Predicted=15.8385, Expected=15.6930
# Month=38, Predicted=15.7255, Expected=16.7550
# Month=39, Predicted=17.3866, Expected=16.5090
# Month=40, Predicted=16.1982, Expected=17.7230
# Month=41, Predicted=18.4299, Expected=18.6910
# Month=42, Predicted=19.1119, Expected=19.1270
# Month=43, Predicted=19.2080, Expected=19.5640
# Month=44, Predicted=19.7082, Expected=19.2030
# Month=45, Predicted=18.8630, Expected=18.2160
# Month=46, Predicted=17.5711, Expected=17.2110
# Month=47, Predicted=16.6733, Expected=16.6600
# Month=48, Predicted=16.4689, Expected=16.8310
# Month=49, Predicted=17.0591, Expected=15.7690
# Month=50, Predicted=15.0837, Expected=15.7310
# Month=51, Predicted=15.8366, Expected=15.9960
# Month=52, Predicted=16.2048, Expected=17.0210
# Month=53, Predicted=17.6205, Expected=17.5520
# Month=54, Predicted=17.7326, Expected=17.8370
# Month=55, Predicted=17.8876, Expected=17.8560
# Month=56, Predicted=17.7791, Expected=17.5710
# Month=57, Predicted=17.3476, Expected=17.0780
# Month=58, Predicted=16.7753, Expected=16.6600
# Month=59, Predicted=16.4525, Expected=16.4330
# Month=60, Predicted=16.3556, Expected=16.5840
# Run 29 — RMSE: 0.497853, MSE: 0.247858, NMSE: 0.0019735133
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.2600, Expected=13.7000
# Month=2, Predicted=14.0435, Expected=13.8140
# Month=3, Predicted=13.8005, Expected=14.3830
# Month=4, Predicted=14.6802, Expected=15.0470
# Month=5, Predicted=15.3566, Expected=15.6930
# Month=6, Predicted=15.9627, Expected=15.8440
# Month=7, Predicted=15.7997, Expected=15.7120
# Month=8, Predicted=15.5487, Expected=15.3130
# Month=9, Predicted=15.0376, Expected=14.7630
# Month=10, Predicted=14.4461, Expected=13.5480
# Month=11, Predicted=12.8307, Expected=13.5860
# Month=12, Predicted=13.7857, Expected=14.5160
# Month=13, Predicted=15.1374, Expected=14.3830
# Month=14, Predicted=14.1900, Expected=14.4970
# Month=15, Predicted=14.5344, Expected=14.7440
# Month=16, Predicted=14.8624, Expected=15.8060
# Month=17, Predicted=16.4015, Expected=16.5270
# Month=18, Predicted=16.8106, Expected=16.5460
# Month=19, Predicted=16.3966, Expected=16.7170
# Month=20, Predicted=16.7533, Expected=16.4330
# Month=21, Predicted=16.1962, Expected=15.7690
# Month=22, Predicted=15.3494, Expected=15.2750
# Month=23, Predicted=15.0392, Expected=15.1230
# Month=24, Predicted=15.1114, Expected=15.5410
# Month=25, Predicted=15.8429, Expected=15.8250
# Month=26, Predicted=15.9557, Expected=16.3760
# Month=27, Predicted=16.6547, Expected=16.3570
# Month=28, Predicted=16.2421, Expected=16.9070
# Month=29, Predicted=17.2034, Expected=17.0210
# Month=30, Predicted=16.9979, Expected=17.4190
# Month=31, Predicted=17.6086, Expected=17.5330
# Month=32, Predicted=17.5240, Expected=17.2680
# Month=33, Predicted=17.0462, Expected=16.6030
# Month=34, Predicted=16.1810, Expected=15.8250
# Month=35, Predicted=15.4029, Expected=15.4460
# Month=36, Predicted=15.3257, Expected=15.6360
# Month=37, Predicted=15.8394, Expected=15.6930
# Month=38, Predicted=15.7265, Expected=16.7550
# Month=39, Predicted=17.3856, Expected=16.5090
# Month=40, Predicted=16.2017, Expected=17.7230
# Month=41, Predicted=18.4266, Expected=18.6910
# Month=42, Predicted=19.1119, Expected=19.1270
# Month=43, Predicted=19.2030, Expected=19.5640
# Month=44, Predicted=19.6996, Expected=19.2030
# Month=45, Predicted=18.8580, Expected=18.2160
# Month=46, Predicted=17.5710, Expected=17.2110
# Month=47, Predicted=16.6776, Expected=16.6600
# Month=48, Predicted=16.4732, Expected=16.8310
# Month=49, Predicted=17.0613, Expected=15.7690
# Month=50, Predicted=15.0923, Expected=15.7310
# Month=51, Predicted=15.8384, Expected=15.9960
# Month=52, Predicted=16.2060, Expected=17.0210
# Month=53, Predicted=17.6208, Expected=17.5520
# Month=54, Predicted=17.7331, Expected=17.8370
# Month=55, Predicted=17.8825, Expected=17.8560
# Month=56, Predicted=17.7733, Expected=17.5710
# Month=57, Predicted=17.3436, Expected=17.0780
# Month=58, Predicted=16.7738, Expected=16.6600
# Month=59, Predicted=16.4526, Expected=16.4330
# Month=60, Predicted=16.3560, Expected=16.5840
# Run 30 — RMSE: 0.496897, MSE: 0.246906, NMSE: 0.0019700795

# %%
# ============================================================
# Summary Statistics (matching reference calculate.py)
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.10f} ± {np.var(all_rmse):.15f}')
print(f'MSE:  {np.mean(all_mse):.10f} ± {np.var(all_mse):.15f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.var(all_nmse):.15f}')

# Best run (minimum RMSE)
best_idx = all_rmse.index(min(all_rmse))
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.15f}')
print(f'  MSE:  {all_mse[best_idx]:.15f}')
print(f'  NMSE: {all_nmse[best_idx]:.15f}')

print(f'\nAll RMSE values: {all_rmse}')
# Out:
# ===== FINAL RESULTS (30 runs) =====
# RMSE: 0.4925315963 ± 0.000014262799016
# MSE:  0.2426016361 ± 0.000013730778029
# NMSE: 0.0019384141 ± 0.000000000291335
#
# Best run: 12
#   RMSE: 0.482523778812003
#   MSE:  0.232829197119015
#   NMSE: 0.001922401735339
#
# All RMSE values: [0.4849437990665913, 0.4892077925862398, 0.49556270972582306, 0.49286227813376005, 0.4911054380451832, 0.49278703618093184, 0.4953985195408356, 0.4927327987763542, 0.49652867856487964, 0.49443430294436563, 0.4917915517453576, 0.482523778812003, 0.4869614002061106, 0.49696847779555214, 0.4920178260477699, 0.49571244990556684, 0.49506323817599657, 0.4911250321701767, 0.4913662547362228, 0.48423927133032174, 0.4907180635481313, 0.4937860050504988, 0.49369732389106014, 0.49350749959538426, 0.4908504214499599, 0.4946726539079362, 0.49637312885070417, 0.4942605574511626, 0.4978530447312919, 0.4968965557208537]

# %%
# Plot best run predictions vs actual
actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_predictions, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LAKE ERIE LEVELS - use 60 datas as test (Best Run)')
plt.show()

# Error plot
error = abs(np.array(actual) - np.array(best_predictions))
plt.figure(figsize=(10, 5))
plt.plot(error, 'k-o', label='|Actual - Predicted|')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('CLOSING - Prediction Error (Best Run)')
plt.show()

# %%
# Final metrics summary from best run
print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]}')
print(f'MSE:  {all_mse[best_idx]}')
print(f'NMSE: {all_nmse[best_idx]}')
# Out:
# === Best Run Metrics ===
# RMSE: 0.482523778812003
# MSE:  0.23282919711901479
# NMSE: 0.0019224017353389872

# %%
plt.figure(figsize=(10,5))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.legend()
plt.title("LSTM-SNP Dow Jones Prediction")
plt.show()

# %% [markdown]
# Report

# %% [markdown]
# # **Bi-LSTM SNP**

# %%
def build_bilstm_snp_model(input_dim, units, batch_size):
    """
    Stateful BiLSTM-SNP model.
    Both forward and backward cells are independent LSTMSNPCell clones.
    Bidirectional merge_mode='concat' → output dim = 2*units.
    """
    cell_fw = LSTMSNPCell(units)
    cell_bw = LSTMSNPCell(units)

    rnn_fw = layers.RNN(cell_fw, return_sequences=False, stateful=True)
    rnn_bw = layers.RNN(cell_bw, return_sequences=False, stateful=True, go_backwards=True)

    bi_rnn = layers.Bidirectional(rnn_fw, backward_layer=rnn_bw)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = bi_rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
bi_model_check = build_bilstm_snp_model(input_dim=1, units=8, batch_size=1)
bi_model_check.summary()
print(f"\nTotal params: {bi_model_check.count_params()}")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (1, 16)                │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (1, 1)                 │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 657 (2.57 KB)
#  Trainable params: 657 (2.57 KB)
#  Non-trainable params: 0 (0.00 B)
# Total params: 657

# %%
# ============================================================
# BiLSTM-SNP: 30-Run Experiment Protocol
# (Protocol-aligned with baseline LSTM-SNP)
# ============================================================

bi_all_rmse = []
bi_all_mse = []
bi_all_nmse = []
bi_all_predictions = []

for run in range(30):
    print(f'\n===== BiLSTM-SNP RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful BiLSTM model
    model = build_bilstm_snp_model(input_dim=1, units=8, batch_size=1)

    # Unit forget bias for BOTH forward and backward cells
    bi_layer = model.layers[1]  # Bidirectional layer
    for rnn_sub in [bi_layer.forward_layer, bi_layer.backward_layer]:
        cell = rnn_sub.cell
        weights = cell.get_weights()  # [kernel, recurrent_kernel, bias]
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units] = consume gate
        weights[2] = bias
        cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train,
            y_train,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        bi_layer.forward_layer.reset_states()
        bi_layer.backward_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]

        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics (matching calculate.py)
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    bi_all_rmse.append(rmse)
    bi_all_mse.append(mse)
    bi_all_nmse.append(nmse)
    bi_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== BiLSTM-SNP RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2649, Expected=13.7000
# Month=2, Predicted=14.0530, Expected=13.8140
# Month=3, Predicted=13.8175, Expected=14.3830
# Month=4, Predicted=14.6785, Expected=15.0470
# Month=5, Predicted=15.3561, Expected=15.6930
# Month=6, Predicted=15.9591, Expected=15.8440
# Month=7, Predicted=15.7945, Expected=15.7120
# Month=8, Predicted=15.5346, Expected=15.3130
# Month=9, Predicted=15.0228, Expected=14.7630
# Month=10, Predicted=14.4342, Expected=13.5480
# Month=11, Predicted=12.8286, Expected=13.5860
# Month=12, Predicted=13.7710, Expected=14.5160
# Month=13, Predicted=15.1481, Expected=14.3830
# Month=14, Predicted=14.2253, Expected=14.4970
# Month=15, Predicted=14.5393, Expected=14.7440
# Month=16, Predicted=14.8627, Expected=15.8060
# Month=17, Predicted=16.3949, Expected=16.5270
# Month=18, Predicted=16.8171, Expected=16.5460
# Month=19, Predicted=16.3953, Expected=16.7170
# Month=20, Predicted=16.7332, Expected=16.4330
# Month=21, Predicted=16.1842, Expected=15.7690
# Month=22, Predicted=15.3380, Expected=15.2750
# Month=23, Predicted=15.0267, Expected=15.1230
# Month=24, Predicted=15.1084, Expected=15.5410
# Month=25, Predicted=15.8488, Expected=15.8250
# Month=26, Predicted=15.9735, Expected=16.3760
# Month=27, Predicted=16.6622, Expected=16.3570
# Month=28, Predicted=16.2511, Expected=16.9070
# Month=29, Predicted=17.1924, Expected=17.0210
# Month=30, Predicted=16.9982, Expected=17.4190
# Month=31, Predicted=17.5983, Expected=17.5330
# Month=32, Predicted=17.5203, Expected=17.2680
# Month=33, Predicted=17.0410, Expected=16.6030
# Month=34, Predicted=16.1738, Expected=15.8250
# Month=35, Predicted=15.3943, Expected=15.4460
# Month=36, Predicted=15.3201, Expected=15.6360
# Month=37, Predicted=15.8451, Expected=15.6930
# Month=38, Predicted=15.7468, Expected=16.7550
# Month=39, Predicted=17.3916, Expected=16.5090
# Month=40, Predicted=16.2273, Expected=17.7230
# Month=41, Predicted=18.4083, Expected=18.6910
# Month=42, Predicted=19.1148, Expected=19.1270
# Month=43, Predicted=19.1992, Expected=19.5640
# Month=44, Predicted=19.6791, Expected=19.2030
# Month=45, Predicted=18.8431, Expected=18.2160
# Month=46, Predicted=17.5517, Expected=17.2110
# Month=47, Predicted=16.6562, Expected=16.6600
# Month=48, Predicted=16.4616, Expected=16.8310
# Month=49, Predicted=17.0660, Expected=15.7690
# Month=50, Predicted=15.1243, Expected=15.7310
# Month=51, Predicted=15.8396, Expected=15.9960
# Month=52, Predicted=16.2225, Expected=17.0210
# Month=53, Predicted=17.6351, Expected=17.5520
# Month=54, Predicted=17.7552, Expected=17.8370
# Month=55, Predicted=17.8851, Expected=17.8560
# Month=56, Predicted=17.7646, Expected=17.5710
# Month=57, Predicted=17.3315, Expected=17.0780
# Month=58, Predicted=16.7619, Expected=16.6600
# Month=59, Predicted=16.4432, Expected=16.4330
# Month=60, Predicted=16.3543, Expected=16.5840
# Run 1 — RMSE: 0.492002, MSE: 0.242066, NMSE: 0.0019400700
#
# ===== BiLSTM-SNP RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2474, Expected=13.7000
# Month=2, Predicted=14.0372, Expected=13.8140
# Month=3, Predicted=13.8171, Expected=14.3830
# Month=4, Predicted=14.6809, Expected=15.0470
# Month=5, Predicted=15.3662, Expected=15.6930
# Month=6, Predicted=15.9781, Expected=15.8440
# Month=7, Predicted=15.8225, Expected=15.7120
# Month=8, Predicted=15.5609, Expected=15.3130
# Month=9, Predicted=15.0415, Expected=14.7630
# Month=10, Predicted=14.4420, Expected=13.5480
# Month=11, Predicted=12.8333, Expected=13.5860
# Month=12, Predicted=13.7443, Expected=14.5160
# Month=13, Predicted=15.1152, Expected=14.3830
# Month=14, Predicted=14.2190, Expected=14.4970
# Month=15, Predicted=14.5376, Expected=14.7440
# Month=16, Predicted=14.8636, Expected=15.8060
# Month=17, Predicted=16.3959, Expected=16.5270
# Month=18, Predicted=16.8339, Expected=16.5460
# Month=19, Predicted=16.4266, Expected=16.7170
# Month=20, Predicted=16.7583, Expected=16.4330
# Month=21, Predicted=16.2064, Expected=15.7690
# Month=22, Predicted=15.3528, Expected=15.2750
# Month=23, Predicted=15.0252, Expected=15.1230
# Month=24, Predicted=15.0936, Expected=15.5410
# Month=25, Predicted=15.8275, Expected=15.8250
# Month=26, Predicted=15.9624, Expected=16.3760
# Month=27, Predicted=16.6591, Expected=16.3570
# Month=28, Predicted=16.2624, Expected=16.9070
# Month=29, Predicted=17.2003, Expected=17.0210
# Month=30, Predicted=17.0131, Expected=17.4190
# Month=31, Predicted=17.6104, Expected=17.5330
# Month=32, Predicted=17.5354, Expected=17.2680
# Month=33, Predicted=17.0568, Expected=16.6030
# Month=34, Predicted=16.1857, Expected=15.8250
# Month=35, Predicted=15.3948, Expected=15.4460
# Month=36, Predicted=15.3037, Expected=15.6360
# Month=37, Predicted=15.8187, Expected=15.6930
# Month=38, Predicted=15.7280, Expected=16.7550
# Month=39, Predicted=17.3748, Expected=16.5090
# Month=40, Predicted=16.2389, Expected=17.7230
# Month=41, Predicted=18.4131, Expected=18.6910
# Month=42, Predicted=19.1345, Expected=19.1270
# Month=43, Predicted=19.2348, Expected=19.5640
# Month=44, Predicted=19.7153, Expected=19.2030
# Month=45, Predicted=18.8807, Expected=18.2160
# Month=46, Predicted=17.5803, Expected=17.2110
# Month=47, Predicted=16.6629, Expected=16.6600
# Month=48, Predicted=16.4443, Expected=16.8310
# Month=49, Predicted=17.0331, Expected=15.7690
# Month=50, Predicted=15.1127, Expected=15.7310
# Month=51, Predicted=15.8100, Expected=15.9960
# Month=52, Predicted=16.1944, Expected=17.0210
# Month=53, Predicted=17.6140, Expected=17.5520
# Month=54, Predicted=17.7587, Expected=17.8370
# Month=55, Predicted=17.9037, Expected=17.8560
# Month=56, Predicted=17.7877, Expected=17.5710
# Month=57, Predicted=17.3517, Expected=17.0780
# Month=58, Predicted=16.7737, Expected=16.6600
# Month=59, Predicted=16.4423, Expected=16.4330
# Month=60, Predicted=16.3431, Expected=16.5840
# Run 2 — RMSE: 0.494829, MSE: 0.244856, NMSE: 0.0019397571
#
# ===== BiLSTM-SNP RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2751, Expected=13.7000
# Month=2, Predicted=14.0616, Expected=13.8140
# Month=3, Predicted=13.8149, Expected=14.3830
# Month=4, Predicted=14.6754, Expected=15.0470
# Month=5, Predicted=15.3487, Expected=15.6930
# Month=6, Predicted=15.9461, Expected=15.8440
# Month=7, Predicted=15.7739, Expected=15.7120
# Month=8, Predicted=15.5142, Expected=15.3130
# Month=9, Predicted=15.0070, Expected=14.7630
# Month=10, Predicted=14.4263, Expected=13.5480
# Month=11, Predicted=12.8258, Expected=13.5860
# Month=12, Predicted=13.7872, Expected=14.5160
# Month=13, Predicted=15.1681, Expected=14.3830
# Month=14, Predicted=14.2249, Expected=14.4970
# Month=15, Predicted=14.5364, Expected=14.7440
# Month=16, Predicted=14.8603, Expected=15.8060
# Month=17, Predicted=16.3951, Expected=16.5270
# Month=18, Predicted=16.8041, Expected=16.5460
# Month=19, Predicted=16.3715, Expected=16.7170
# Month=20, Predicted=16.7144, Expected=16.4330
# Month=21, Predicted=16.1665, Expected=15.7690
# Month=22, Predicted=15.3247, Expected=15.2750
# Month=23, Predicted=15.0253, Expected=15.1230
# Month=24, Predicted=15.1173, Expected=15.5410
# Month=25, Predicted=15.8613, Expected=15.8250
# Month=26, Predicted=15.9780, Expected=16.3760
# Month=27, Predicted=16.6620, Expected=16.3570
# Month=28, Predicted=16.2411, Expected=16.9070
# Month=29, Predicted=17.1864, Expected=17.0210
# Month=30, Predicted=16.9863, Expected=17.4190
# Month=31, Predicted=17.5887, Expected=17.5330
# Month=32, Predicted=17.5079, Expected=17.2680
# Month=33, Predicted=17.0271, Expected=16.6030
# Month=34, Predicted=16.1628, Expected=15.8250
# Month=35, Predicted=15.3923, Expected=15.4460
# Month=36, Predicted=15.3309, Expected=15.6360
# Month=37, Predicted=15.8626, Expected=15.6930
# Month=38, Predicted=15.7582, Expected=16.7550
# Month=39, Predicted=17.4015, Expected=16.5090
# Month=40, Predicted=16.2158, Expected=17.7230
# Month=41, Predicted=18.4057, Expected=18.6910
# Month=42, Predicted=19.1002, Expected=19.1270
# Month=43, Predicted=19.1737, Expected=19.5640
# Month=44, Predicted=19.6547, Expected=19.2030
# Month=45, Predicted=18.8146, Expected=18.2160
# Month=46, Predicted=17.5274, Expected=17.2110
# Month=47, Predicted=16.6484, Expected=16.6600
# Month=48, Predicted=16.4734, Expected=16.8310
# Month=49, Predicted=17.0882, Expected=15.7690
# Month=50, Predicted=15.1359, Expected=15.7310
# Month=51, Predicted=15.8570, Expected=15.9960
# Month=52, Predicted=16.2406, Expected=17.0210
# Month=53, Predicted=17.6478, Expected=17.5520
# Month=54, Predicted=17.7501, Expected=17.8370
# Month=55, Predicted=17.8714, Expected=17.8560
# Month=56, Predicted=17.7483, Expected=17.5710
# Month=57, Predicted=17.3164, Expected=17.0780
# Month=58, Predicted=16.7521, Expected=16.6600
# Month=59, Predicted=16.4423, Expected=16.4330
# Month=60, Predicted=16.3610, Expected=16.5840
# Run 3 — RMSE: 0.490566, MSE: 0.240655, NMSE: 0.0019431666
#
# ===== BiLSTM-SNP RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2469, Expected=13.7000
# Month=2, Predicted=14.0376, Expected=13.8140
# Month=3, Predicted=13.8201, Expected=14.3830
# Month=4, Predicted=14.6790, Expected=15.0470
# Month=5, Predicted=15.3646, Expected=15.6930
# Month=6, Predicted=15.9756, Expected=15.8440
# Month=7, Predicted=15.8203, Expected=15.7120
# Month=8, Predicted=15.5584, Expected=15.3130
# Month=9, Predicted=15.0408, Expected=14.7630
# Month=10, Predicted=14.4428, Expected=13.5480
# Month=11, Predicted=12.8443, Expected=13.5860
# Month=12, Predicted=13.7377, Expected=14.5160
# Month=13, Predicted=15.1166, Expected=14.3830
# Month=14, Predicted=14.2272, Expected=14.4970
# Month=15, Predicted=14.5378, Expected=14.7440
# Month=16, Predicted=14.8626, Expected=15.8060
# Month=17, Predicted=16.3946, Expected=16.5270
# Month=18, Predicted=16.8335, Expected=16.5460
# Month=19, Predicted=16.4258, Expected=16.7170
# Month=20, Predicted=16.7530, Expected=16.4330
# Month=21, Predicted=16.2055, Expected=15.7690
# Month=22, Predicted=15.3553, Expected=15.2750
# Month=23, Predicted=15.0247, Expected=15.1230
# Month=24, Predicted=15.0923, Expected=15.5410
# Month=25, Predicted=15.8268, Expected=15.8250
# Month=26, Predicted=15.9650, Expected=16.3760
# Month=27, Predicted=16.6593, Expected=16.3570
# Month=28, Predicted=16.2644, Expected=16.9070
# Month=29, Predicted=17.1963, Expected=17.0210
# Month=30, Predicted=17.0125, Expected=17.4190
# Month=31, Predicted=17.6066, Expected=17.5330
# Month=32, Predicted=17.5339, Expected=17.2680
# Month=33, Predicted=17.0572, Expected=16.6030
# Month=34, Predicted=16.1890, Expected=15.8250
# Month=35, Predicted=15.3980, Expected=15.4460
# Month=36, Predicted=15.3027, Expected=15.6360
# Month=37, Predicted=15.8177, Expected=15.6930
# Month=38, Predicted=15.7315, Expected=16.7550
# Month=39, Predicted=17.3761, Expected=16.5090
# Month=40, Predicted=16.2458, Expected=17.7230
# Month=41, Predicted=18.4098, Expected=18.6910
# Month=42, Predicted=19.1337, Expected=19.1270
# Month=43, Predicted=19.2316, Expected=19.5640
# Month=44, Predicted=19.7090, Expected=19.2030
# Month=45, Predicted=18.8800, Expected=18.2160
# Month=46, Predicted=17.5855, Expected=17.2110
# Month=47, Predicted=16.6659, Expected=16.6600
# Month=48, Predicted=16.4428, Expected=16.8310
# Month=49, Predicted=17.0315, Expected=15.7690
# Month=50, Predicted=15.1291, Expected=15.7310
# Month=51, Predicted=15.8074, Expected=15.9960
# Month=52, Predicted=16.1959, Expected=17.0210
# Month=53, Predicted=17.6170, Expected=17.5520
# Month=54, Predicted=17.7617, Expected=17.8370
# Month=55, Predicted=17.9030, Expected=17.8560
# Month=56, Predicted=17.7857, Expected=17.5710
# Month=57, Predicted=17.3508, Expected=17.0780
# Month=58, Predicted=16.7742, Expected=16.6600
# Month=59, Predicted=16.4420, Expected=16.4330
# Month=60, Predicted=16.3428, Expected=16.5840
# Run 4 — RMSE: 0.493727, MSE: 0.243767, NMSE: 0.0019343442
#
# ===== BiLSTM-SNP RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2731, Expected=13.7000
# Month=2, Predicted=14.0620, Expected=13.8140
# Month=3, Predicted=13.8256, Expected=14.3830
# Month=4, Predicted=14.6668, Expected=15.0470
# Month=5, Predicted=15.3338, Expected=15.6930
# Month=6, Predicted=15.9234, Expected=15.8440
# Month=7, Predicted=15.7484, Expected=15.7120
# Month=8, Predicted=15.4790, Expected=15.3130
# Month=9, Predicted=14.9707, Expected=14.7630
# Month=10, Predicted=14.3972, Expected=13.5480
# Month=11, Predicted=12.8251, Expected=13.5860
# Month=12, Predicted=13.7750, Expected=14.5160
# Month=13, Predicted=15.1687, Expected=14.3830
# Month=14, Predicted=14.2570, Expected=14.4970
# Month=15, Predicted=14.5470, Expected=14.7440
# Month=16, Predicted=14.8606, Expected=15.8060
# Month=17, Predicted=16.3767, Expected=16.5270
# Month=18, Predicted=16.7911, Expected=16.5460
# Month=19, Predicted=16.3542, Expected=16.7170
# Month=20, Predicted=16.6747, Expected=16.4330
# Month=21, Predicted=16.1306, Expected=15.7690
# Month=22, Predicted=15.2958, Expected=15.2750
# Month=23, Predicted=14.9999, Expected=15.1230
# Month=24, Predicted=15.1034, Expected=15.5410
# Month=25, Predicted=15.8557, Expected=15.8250
# Month=26, Predicted=15.9860, Expected=16.3760
# Month=27, Predicted=16.6617, Expected=16.3570
# Month=28, Predicted=16.2441, Expected=16.9070
# Month=29, Predicted=17.1654, Expected=17.0210
# Month=30, Predicted=16.9705, Expected=17.4190
# Month=31, Predicted=17.5592, Expected=17.5330
# Month=32, Predicted=17.4818, Expected=17.2680
# Month=33, Predicted=17.0025, Expected=16.6030
# Month=34, Predicted=16.1445, Expected=15.8250
# Month=35, Predicted=15.3817, Expected=15.4460
# Month=36, Predicted=15.3266, Expected=15.6360
# Month=37, Predicted=15.8680, Expected=15.6930
# Month=38, Predicted=15.7799, Expected=16.7550
# Month=39, Predicted=17.4048, Expected=16.5090
# Month=40, Predicted=16.2417, Expected=17.7230
# Month=41, Predicted=18.3822, Expected=18.6910
# Month=42, Predicted=19.0827, Expected=19.1270
# Month=43, Predicted=19.1498, Expected=19.5640
# Month=44, Predicted=19.6102, Expected=19.2030
# Month=45, Predicted=18.7725, Expected=18.2160
# Month=46, Predicted=17.4897, Expected=17.2110
# Month=47, Predicted=16.6169, Expected=16.6600
# Month=48, Predicted=16.4575, Expected=16.8310
# Month=49, Predicted=17.0897, Expected=15.7690
# Month=50, Predicted=15.1883, Expected=15.7310
# Month=51, Predicted=15.8855, Expected=15.9960
# Month=52, Predicted=16.2749, Expected=17.0210
# Month=53, Predicted=17.6686, Expected=17.5520
# Month=54, Predicted=17.7734, Expected=17.8370
# Month=55, Predicted=17.8752, Expected=17.8560
# Month=56, Predicted=17.7352, Expected=17.5710
# Month=57, Predicted=17.2943, Expected=17.0780
# Month=58, Predicted=16.7293, Expected=16.6600
# Month=59, Predicted=16.4229, Expected=16.4330
# Month=60, Predicted=16.3508, Expected=16.5840
# Run 5 — RMSE: 0.482855, MSE: 0.233149, NMSE: 0.0018979986
#
# ===== BiLSTM-SNP RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2654, Expected=13.7000
# Month=2, Predicted=14.0513, Expected=13.8140
# Month=3, Predicted=13.8093, Expected=14.3830
# Month=4, Predicted=14.6789, Expected=15.0470
# Month=5, Predicted=15.3561, Expected=15.6930
# Month=6, Predicted=15.9597, Expected=15.8440
# Month=7, Predicted=15.7932, Expected=15.7120
# Month=8, Predicted=15.5351, Expected=15.3130
# Month=9, Predicted=15.0231, Expected=14.7630
# Month=10, Predicted=14.4347, Expected=13.5480
# Month=11, Predicted=12.8206, Expected=13.5860
# Month=12, Predicted=13.7855, Expected=14.5160
# Month=13, Predicted=15.1501, Expected=14.3830
# Month=14, Predicted=14.2100, Expected=14.4970
# Month=15, Predicted=14.5360, Expected=14.7440
# Month=16, Predicted=14.8626, Expected=15.8060
# Month=17, Predicted=16.3988, Expected=16.5270
# Month=18, Predicted=16.8149, Expected=16.5460
# Month=19, Predicted=16.3916, Expected=16.7170
# Month=20, Predicted=16.7381, Expected=16.4330
# Month=21, Predicted=16.1840, Expected=15.7690
# Month=22, Predicted=15.3358, Expected=15.2750
# Month=23, Predicted=15.0302, Expected=15.1230
# Month=24, Predicted=15.1121, Expected=15.5410
# Month=25, Predicted=15.8501, Expected=15.8250
# Month=26, Predicted=15.9669, Expected=16.3760
# Month=27, Predicted=16.6591, Expected=16.3570
# Month=28, Predicted=16.2443, Expected=16.9070
# Month=29, Predicted=17.1965, Expected=17.0210
# Month=30, Predicted=16.9961, Expected=17.4190
# Month=31, Predicted=17.6013, Expected=17.5330
# Month=32, Predicted=17.5194, Expected=17.2680
# Month=33, Predicted=17.0381, Expected=16.6030
# Month=34, Predicted=16.1699, Expected=15.8250
# Month=35, Predicted=15.3936, Expected=15.4460
# Month=36, Predicted=15.3253, Expected=15.6360
# Month=37, Predicted=15.8483, Expected=15.6930
# Month=38, Predicted=15.7404, Expected=16.7550
# Month=39, Predicted=17.3911, Expected=16.5090
# Month=40, Predicted=16.2135, Expected=17.7230
# Month=41, Predicted=18.4164, Expected=18.6910
# Month=42, Predicted=19.1152, Expected=19.1270
# Month=43, Predicted=19.1993, Expected=19.5640
# Month=44, Predicted=19.6847, Expected=19.2030
# Month=45, Predicted=18.8417, Expected=18.2160
# Month=46, Predicted=17.5475, Expected=17.2110
# Month=47, Predicted=16.6594, Expected=16.6600
# Month=48, Predicted=16.4706, Expected=16.8310
# Month=49, Predicted=17.0717, Expected=15.7690
# Month=50, Predicted=15.1055, Expected=15.7310
# Month=51, Predicted=15.8451, Expected=15.9960
# Month=52, Predicted=16.2212, Expected=17.0210
# Month=53, Predicted=17.6327, Expected=17.5520
# Month=54, Predicted=17.7472, Expected=17.8370
# Month=55, Predicted=17.8822, Expected=17.8560
# Month=56, Predicted=17.7649, Expected=17.5710
# Month=57, Predicted=17.3320, Expected=17.0780
# Month=58, Predicted=16.7625, Expected=16.6600
# Month=59, Predicted=16.4458, Expected=16.4330
# Month=60, Predicted=16.3564, Expected=16.5840
# Run 6 — RMSE: 0.493721, MSE: 0.243760, NMSE: 0.0019511275
#
# ===== BiLSTM-SNP RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.2734, Expected=13.7000
# Month=2, Predicted=14.0573, Expected=13.8140
# Month=3, Predicted=13.8058, Expected=14.3830
# Month=4, Predicted=14.6781, Expected=15.0470
# Month=5, Predicted=15.3503, Expected=15.6930
# Month=6, Predicted=15.9502, Expected=15.8440
# Month=7, Predicted=15.7786, Expected=15.7120
# Month=8, Predicted=15.5216, Expected=15.3130
# Month=9, Predicted=15.0120, Expected=14.7630
# Month=10, Predicted=14.4285, Expected=13.5480
# Month=11, Predicted=12.8138, Expected=13.5860
# Month=12, Predicted=13.8011, Expected=14.5160
# Month=13, Predicted=15.1627, Expected=14.3830
# Month=14, Predicted=14.2047, Expected=14.4970
# Month=15, Predicted=14.5363, Expected=14.7440
# Month=16, Predicted=14.8615, Expected=15.8060
# Month=17, Predicted=16.3978, Expected=16.5270
# Month=18, Predicted=16.8032, Expected=16.5460
# Month=19, Predicted=16.3745, Expected=16.7170
# Month=20, Predicted=16.7274, Expected=16.4330
# Month=21, Predicted=16.1707, Expected=15.7690
# Month=22, Predicted=15.3250, Expected=15.2750
# Month=23, Predicted=15.0298, Expected=15.1230
# Month=24, Predicted=15.1192, Expected=15.5410
# Month=25, Predicted=15.8594, Expected=15.8250
# Month=26, Predicted=15.9689, Expected=16.3760
# Month=27, Predicted=16.6595, Expected=16.3570
# Month=28, Predicted=16.2359, Expected=16.9070
# Month=29, Predicted=17.1940, Expected=17.0210
# Month=30, Predicted=16.9861, Expected=17.4190
# Month=31, Predicted=17.5955, Expected=17.5330
# Month=32, Predicted=17.5099, Expected=17.2680
# Month=33, Predicted=17.0277, Expected=16.6030
# Month=34, Predicted=16.1608, Expected=15.8250
# Month=35, Predicted=15.3915, Expected=15.4460
# Month=36, Predicted=15.3344, Expected=15.6360
# Month=37, Predicted=15.8617, Expected=15.6930
# Month=38, Predicted=15.7473, Expected=16.7550
# Month=39, Predicted=17.3981, Expected=16.5090
# Month=40, Predicted=16.2001, Expected=17.7230
# Month=41, Predicted=18.4155, Expected=18.6910
# Month=42, Predicted=19.1015, Expected=19.1270
# Month=43, Predicted=19.1812, Expected=19.5640
# Month=44, Predicted=19.6700, Expected=19.2030
# Month=45, Predicted=18.8209, Expected=18.2160
# Month=46, Predicted=17.5283, Expected=17.2110
# Month=47, Predicted=16.6535, Expected=16.6600
# Month=48, Predicted=16.4806, Expected=16.8310
# Month=49, Predicted=17.0893, Expected=15.7690
# Month=50, Predicted=15.1061, Expected=15.7310
# Month=51, Predicted=15.8625, Expected=15.9960
# Month=52, Predicted=16.2344, Expected=17.0210
# Month=53, Predicted=17.6405, Expected=17.5520
# Month=54, Predicted=17.7410, Expected=17.8370
# Month=55, Predicted=17.8732, Expected=17.8560
# Month=56, Predicted=17.7540, Expected=17.5710
# Month=57, Predicted=17.3210, Expected=17.0780
# Month=58, Predicted=16.7547, Expected=16.6600
# Month=59, Predicted=16.4451, Expected=16.4330
# Month=60, Predicted=16.3612, Expected=16.5840
# Run 7 — RMSE: 0.493227, MSE: 0.243273, NMSE: 0.0019570121
#
# ===== BiLSTM-SNP RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2723, Expected=13.7000
# Month=2, Predicted=14.0599, Expected=13.8140
# Month=3, Predicted=13.8194, Expected=14.3830
# Month=4, Predicted=14.6713, Expected=15.0470
# Month=5, Predicted=15.3424, Expected=15.6930
# Month=6, Predicted=15.9370, Expected=15.8440
# Month=7, Predicted=15.7649, Expected=15.7120
# Month=8, Predicted=15.5024, Expected=15.3130
# Month=9, Predicted=14.9958, Expected=14.7630
# Month=10, Predicted=14.4177, Expected=13.5480
# Month=11, Predicted=12.8350, Expected=13.5860
# Month=12, Predicted=13.7771, Expected=14.5160
# Month=13, Predicted=15.1647, Expected=14.3830
# Month=14, Predicted=14.2382, Expected=14.4970
# Month=15, Predicted=14.5397, Expected=14.7440
# Month=16, Predicted=14.8592, Expected=15.8060
# Month=17, Predicted=16.3883, Expected=16.5270
# Month=18, Predicted=16.7991, Expected=16.5460
# Month=19, Predicted=16.3672, Expected=16.7170
# Month=20, Predicted=16.6994, Expected=16.4330
# Month=21, Predicted=16.1554, Expected=15.7690
# Month=22, Predicted=15.3186, Expected=15.2750
# Month=23, Predicted=15.0169, Expected=15.1230
# Month=24, Predicted=15.1100, Expected=15.5410
# Month=25, Predicted=15.8556, Expected=15.8250
# Month=26, Predicted=15.9793, Expected=16.3760
# Month=27, Predicted=16.6605, Expected=16.3570
# Month=28, Predicted=16.2432, Expected=16.9070
# Month=29, Predicted=17.1768, Expected=17.0210
# Month=30, Predicted=16.9802, Expected=17.4190
# Month=31, Predicted=17.5761, Expected=17.5330
# Month=32, Predicted=17.4977, Expected=17.2680
# Month=33, Predicted=17.0198, Expected=16.6030
# Month=34, Predicted=16.1602, Expected=15.8250
# Month=35, Predicted=15.3918, Expected=15.4460
# Month=36, Predicted=15.3275, Expected=15.6360
# Month=37, Predicted=15.8603, Expected=15.6930
# Month=38, Predicted=15.7646, Expected=16.7550
# Month=39, Predicted=17.4025, Expected=16.5090
# Month=40, Predicted=16.2296, Expected=17.7230
# Month=41, Predicted=18.3982, Expected=18.6910
# Month=42, Predicted=19.0938, Expected=19.1270
# Month=43, Predicted=19.1650, Expected=19.5640
# Month=44, Predicted=19.6375, Expected=19.2030
# Month=45, Predicted=18.8028, Expected=18.2160
# Month=46, Predicted=17.5221, Expected=17.2110
# Month=47, Predicted=16.6424, Expected=16.6600
# Month=48, Predicted=16.4660, Expected=16.8310
# Month=49, Predicted=17.0833, Expected=15.7690
# Month=50, Predicted=15.1634, Expected=15.7310
# Month=51, Predicted=15.8636, Expected=15.9960
# Month=52, Predicted=16.2501, Expected=17.0210
# Month=53, Predicted=17.6558, Expected=17.5520
# Month=54, Predicted=17.7601, Expected=17.8370
# Month=55, Predicted=17.8749, Expected=17.8560
# Month=56, Predicted=17.7460, Expected=17.5710
# Month=57, Predicted=17.3121, Expected=17.0780
# Month=58, Predicted=16.7482, Expected=16.6600
# Month=59, Predicted=16.4380, Expected=16.4330
# Month=60, Predicted=16.3583, Expected=16.5840
# Run 8 — RMSE: 0.487341, MSE: 0.237501, NMSE: 0.0019232667
#
# ===== BiLSTM-SNP RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2694, Expected=13.7000
# Month=2, Predicted=14.0564, Expected=13.8140
# Month=3, Predicted=13.8137, Expected=14.3830
# Month=4, Predicted=14.6713, Expected=15.0470
# Month=5, Predicted=15.3434, Expected=15.6930
# Month=6, Predicted=15.9396, Expected=15.8440
# Month=7, Predicted=15.7685, Expected=15.7120
# Month=8, Predicted=15.5085, Expected=15.3130
# Month=9, Predicted=15.0021, Expected=14.7630
# Month=10, Predicted=14.4226, Expected=13.5480
# Month=11, Predicted=12.8377, Expected=13.5860
# Month=12, Predicted=13.7823, Expected=14.5160
# Month=13, Predicted=15.1646, Expected=14.3830
# Month=14, Predicted=14.2287, Expected=14.4970
# Month=15, Predicted=14.5378, Expected=14.7440
# Month=16, Predicted=14.8591, Expected=15.8060
# Month=17, Predicted=16.3916, Expected=16.5270
# Month=18, Predicted=16.7999, Expected=16.5460
# Month=19, Predicted=16.3699, Expected=16.7170
# Month=20, Predicted=16.7067, Expected=16.4330
# Month=21, Predicted=16.1609, Expected=15.7690
# Month=22, Predicted=15.3235, Expected=15.2750
# Month=23, Predicted=15.0210, Expected=15.1230
# Month=24, Predicted=15.1105, Expected=15.5410
# Month=25, Predicted=15.8538, Expected=15.8250
# Month=26, Predicted=15.9738, Expected=16.3760
# Month=27, Predicted=16.6581, Expected=16.3570
# Month=28, Predicted=16.2408, Expected=16.9070
# Month=29, Predicted=17.1804, Expected=17.0210
# Month=30, Predicted=16.9815, Expected=17.4190
# Month=31, Predicted=17.5801, Expected=17.5330
# Month=32, Predicted=17.5001, Expected=17.2680
# Month=33, Predicted=17.0225, Expected=16.6030
# Month=34, Predicted=16.1637, Expected=15.8250
# Month=35, Predicted=15.3956, Expected=15.4460
# Month=36, Predicted=15.3297, Expected=15.6360
# Month=37, Predicted=15.8590, Expected=15.6930
# Month=38, Predicted=15.7584, Expected=16.7550
# Month=39, Predicted=17.4020, Expected=16.5090
# Month=40, Predicted=16.2232, Expected=17.7230
# Month=41, Predicted=18.4052, Expected=18.6910
# Month=42, Predicted=19.0973, Expected=19.1270
# Month=43, Predicted=19.1699, Expected=19.5640
# Month=44, Predicted=19.6463, Expected=19.2030
# Month=45, Predicted=18.8110, Expected=18.2160
# Month=46, Predicted=17.5320, Expected=17.2110
# Month=47, Predicted=16.6517, Expected=16.6600
# Month=48, Predicted=16.4704, Expected=16.8310
# Month=49, Predicted=17.0822, Expected=15.7690
# Month=50, Predicted=15.1532, Expected=15.7310
# Month=51, Predicted=15.8630, Expected=15.9960
# Month=52, Predicted=16.2458, Expected=17.0210
# Month=53, Predicted=17.6535, Expected=17.5520
# Month=54, Predicted=17.7548, Expected=17.8370
# Month=55, Predicted=17.8744, Expected=17.8560
# Month=56, Predicted=17.7491, Expected=17.5710
# Month=57, Predicted=17.3164, Expected=17.0780
# Month=58, Predicted=16.7521, Expected=16.6600
# Month=59, Predicted=16.4402, Expected=16.4330
# Month=60, Predicted=16.3574, Expected=16.5840
# Run 9 — RMSE: 0.488938, MSE: 0.239061, NMSE: 0.0019318277
#
# ===== BiLSTM-SNP RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2631, Expected=13.7000
# Month=2, Predicted=14.0498, Expected=13.8140
# Month=3, Predicted=13.8124, Expected=14.3830
# Month=4, Predicted=14.6806, Expected=15.0470
# Month=5, Predicted=15.3608, Expected=15.6930
# Month=6, Predicted=15.9676, Expected=15.8440
# Month=7, Predicted=15.8045, Expected=15.7120
# Month=8, Predicted=15.5443, Expected=15.3130
# Month=9, Predicted=15.0284, Expected=14.7630
# Month=10, Predicted=14.4355, Expected=13.5480
# Month=11, Predicted=12.8143, Expected=13.5860
# Month=12, Predicted=13.7760, Expected=14.5160
# Month=13, Predicted=15.1435, Expected=14.3830
# Month=14, Predicted=14.2117, Expected=14.4970
# Month=15, Predicted=14.5353, Expected=14.7440
# Month=16, Predicted=14.8634, Expected=15.8060
# Month=17, Predicted=16.3981, Expected=16.5270
# Month=18, Predicted=16.8220, Expected=16.5460
# Month=19, Predicted=16.4036, Expected=16.7170
# Month=20, Predicted=16.7466, Expected=16.4330
# Month=21, Predicted=16.1917, Expected=15.7690
# Month=22, Predicted=15.3381, Expected=15.2750
# Month=23, Predicted=15.0278, Expected=15.1230
# Month=24, Predicted=15.1093, Expected=15.5410
# Month=25, Predicted=15.8476, Expected=15.8250
# Month=26, Predicted=15.9679, Expected=16.3760
# Month=27, Predicted=16.6606, Expected=16.3570
# Month=28, Predicted=16.2498, Expected=16.9070
# Month=29, Predicted=17.1990, Expected=17.0210
# Month=30, Predicted=17.0028, Expected=17.4190
# Month=31, Predicted=17.6066, Expected=17.5330
# Month=32, Predicted=17.5266, Expected=17.2680
# Month=33, Predicted=17.0439, Expected=16.6030
# Month=34, Predicted=16.1709, Expected=15.8250
# Month=35, Predicted=15.3891, Expected=15.4460
# Month=36, Predicted=15.3192, Expected=15.6360
# Month=37, Predicted=15.8436, Expected=15.6930
# Month=38, Predicted=15.7387, Expected=16.7550
# Month=39, Predicted=17.3861, Expected=16.5090
# Month=40, Predicted=16.2183, Expected=17.7230
# Month=41, Predicted=18.4123, Expected=18.6910
# Month=42, Predicted=19.1207, Expected=19.1270
# Month=43, Predicted=19.2127, Expected=19.5640
# Month=44, Predicted=19.6980, Expected=19.2030
# Month=45, Predicted=18.8549, Expected=18.2160
# Month=46, Predicted=17.5507, Expected=17.2110
# Month=47, Predicted=16.6535, Expected=16.6600
# Month=48, Predicted=16.4637, Expected=16.8310
# Month=49, Predicted=17.0668, Expected=15.7690
# Month=50, Predicted=15.1000, Expected=15.7310
# Month=51, Predicted=15.8338, Expected=15.9960
# Month=52, Predicted=16.2150, Expected=17.0210
# Month=53, Predicted=17.6267, Expected=17.5520
# Month=54, Predicted=17.7502, Expected=17.8370
# Month=55, Predicted=17.8889, Expected=17.8560
# Month=56, Predicted=17.7722, Expected=17.5710
# Month=57, Predicted=17.3374, Expected=17.0780
# Month=58, Predicted=16.7640, Expected=16.6600
# Month=59, Predicted=16.4442, Expected=16.4330
# Month=60, Predicted=16.3539, Expected=16.5840
# Run 10 — RMSE: 0.494614, MSE: 0.244643, NMSE: 0.0019510259
#
# ===== BiLSTM-SNP RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.2724, Expected=13.7000
# Month=2, Predicted=14.0589, Expected=13.8140
# Month=3, Predicted=13.8157, Expected=14.3830
# Month=4, Predicted=14.6742, Expected=15.0470
# Month=5, Predicted=15.3477, Expected=15.6930
# Month=6, Predicted=15.9461, Expected=15.8440
# Month=7, Predicted=15.7760, Expected=15.7120
# Month=8, Predicted=15.5139, Expected=15.3130
# Month=9, Predicted=15.0040, Expected=14.7630
# Month=10, Predicted=14.4219, Expected=13.5480
# Month=11, Predicted=12.8219, Expected=13.5860
# Month=12, Predicted=13.7876, Expected=14.5160
# Month=13, Predicted=15.1656, Expected=14.3830
# Month=14, Predicted=14.2288, Expected=14.4970
# Month=15, Predicted=14.5385, Expected=14.7440
# Month=16, Predicted=14.8604, Expected=15.8060
# Month=17, Predicted=16.3912, Expected=16.5270
# Month=18, Predicted=16.8059, Expected=16.5460
# Month=19, Predicted=16.3765, Expected=16.7170
# Month=20, Predicted=16.7140, Expected=16.4330
# Month=21, Predicted=16.1645, Expected=15.7690
# Month=22, Predicted=15.3210, Expected=15.2750
# Month=23, Predicted=15.0212, Expected=15.1230
# Month=24, Predicted=15.1138, Expected=15.5410
# Month=25, Predicted=15.8579, Expected=15.8250
# Month=26, Predicted=15.9768, Expected=16.3760
# Month=27, Predicted=16.6609, Expected=16.3570
# Month=28, Predicted=16.2428, Expected=16.9070
# Month=29, Predicted=17.1843, Expected=17.0210
# Month=30, Predicted=16.9860, Expected=17.4190
# Month=31, Predicted=17.5860, Expected=17.5330
# Month=32, Predicted=17.5060, Expected=17.2680
# Month=33, Predicted=17.0251, Expected=16.6030
# Month=34, Predicted=16.1597, Expected=15.8250
# Month=35, Predicted=15.3893, Expected=15.4460
# Month=36, Predicted=15.3294, Expected=15.6360
# Month=37, Predicted=15.8616, Expected=15.6930
# Month=38, Predicted=15.7585, Expected=16.7550
# Month=39, Predicted=17.3992, Expected=16.5090
# Month=40, Predicted=16.2220, Expected=17.7230
# Month=41, Predicted=18.4029, Expected=18.6910
# Month=42, Predicted=19.1024, Expected=19.1270
# Month=43, Predicted=19.1801, Expected=19.5640
# Month=44, Predicted=19.6569, Expected=19.2030
# Month=45, Predicted=18.8162, Expected=18.2160
# Month=46, Predicted=17.5247, Expected=17.2110
# Month=47, Predicted=16.6445, Expected=16.6600
# Month=48, Predicted=16.4719, Expected=16.8310
# Month=49, Predicted=17.0878, Expected=15.7690
# Month=50, Predicted=15.1371, Expected=15.7310
# Month=51, Predicted=15.8619, Expected=15.9960
# Month=52, Predicted=16.2436, Expected=17.0210
# Month=53, Predicted=17.6482, Expected=17.5520
# Month=54, Predicted=17.7557, Expected=17.8370
# Month=55, Predicted=17.8770, Expected=17.8560
# Month=56, Predicted=17.7515, Expected=17.5710
# Month=57, Predicted=17.3166, Expected=17.0780
# Month=58, Predicted=16.7499, Expected=16.6600
# Month=59, Predicted=16.4392, Expected=16.4330
# Month=60, Predicted=16.3582, Expected=16.5840
# Run 11 — RMSE: 0.489780, MSE: 0.239885, NMSE: 0.0019344768
#
# ===== BiLSTM-SNP RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2593, Expected=13.7000
# Month=2, Predicted=14.0465, Expected=13.8140
# Month=3, Predicted=13.8105, Expected=14.3830
# Month=4, Predicted=14.6810, Expected=15.0470
# Month=5, Predicted=15.3593, Expected=15.6930
# Month=6, Predicted=15.9650, Expected=15.8440
# Month=7, Predicted=15.8011, Expected=15.7120
# Month=8, Predicted=15.5444, Expected=15.3130
# Month=9, Predicted=15.0310, Expected=14.7630
# Month=10, Predicted=14.4390, Expected=13.5480
# Month=11, Predicted=12.8267, Expected=13.5860
# Month=12, Predicted=13.7687, Expected=14.5160
# Month=13, Predicted=15.1350, Expected=14.3830
# Month=14, Predicted=14.2074, Expected=14.4970
# Month=15, Predicted=14.5377, Expected=14.7440
# Month=16, Predicted=14.8638, Expected=15.8060
# Month=17, Predicted=16.3988, Expected=16.5270
# Month=18, Predicted=16.8177, Expected=16.5460
# Month=19, Predicted=16.4000, Expected=16.7170
# Month=20, Predicted=16.7462, Expected=16.4330
# Month=21, Predicted=16.1918, Expected=15.7690
# Month=22, Predicted=15.3433, Expected=15.2750
# Month=23, Predicted=15.0300, Expected=15.1230
# Month=24, Predicted=15.1057, Expected=15.5410
# Month=25, Predicted=15.8418, Expected=15.8250
# Month=26, Predicted=15.9643, Expected=16.3760
# Month=27, Predicted=16.6597, Expected=16.3570
# Month=28, Predicted=16.2493, Expected=16.9070
# Month=29, Predicted=17.1997, Expected=17.0210
# Month=30, Predicted=17.0007, Expected=17.4190
# Month=31, Predicted=17.6055, Expected=17.5330
# Month=32, Predicted=17.5245, Expected=17.2680
# Month=33, Predicted=17.0451, Expected=16.6030
# Month=34, Predicted=16.1772, Expected=15.8250
# Month=35, Predicted=15.3960, Expected=15.4460
# Month=36, Predicted=15.3178, Expected=15.6360
# Month=37, Predicted=15.8368, Expected=15.6930
# Month=38, Predicted=15.7349, Expected=16.7550
# Month=39, Predicted=17.3863, Expected=16.5090
# Month=40, Predicted=16.2161, Expected=17.7230
# Month=41, Predicted=18.4173, Expected=18.6910
# Month=42, Predicted=19.1173, Expected=19.1270
# Month=43, Predicted=19.2063, Expected=19.5640
# Month=44, Predicted=19.6942, Expected=19.2030
# Month=45, Predicted=18.8531, Expected=18.2160
# Month=46, Predicted=17.5607, Expected=17.2110
# Month=47, Predicted=16.6626, Expected=16.6600
# Month=48, Predicted=16.4600, Expected=16.8310
# Month=49, Predicted=17.0554, Expected=15.7690
# Month=50, Predicted=15.1055, Expected=15.7310
# Month=51, Predicted=15.8321, Expected=15.9960
# Month=52, Predicted=16.2103, Expected=17.0210
# Month=53, Predicted=17.6257, Expected=17.5520
# Month=54, Predicted=17.7471, Expected=17.8370
# Month=55, Predicted=17.8883, Expected=17.8560
# Month=56, Predicted=17.7728, Expected=17.5710
# Month=57, Predicted=17.3397, Expected=17.0780
# Month=58, Predicted=16.7680, Expected=16.6600
# Month=59, Predicted=16.4459, Expected=16.4330
# Month=60, Predicted=16.3522, Expected=16.5840
# Run 12 — RMSE: 0.494544, MSE: 0.244574, NMSE: 0.0019516169
#
# ===== BiLSTM-SNP RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2694, Expected=13.7000
# Month=2, Predicted=14.0553, Expected=13.8140
# Month=3, Predicted=13.8101, Expected=14.3830
# Month=4, Predicted=14.6789, Expected=15.0470
# Month=5, Predicted=15.3550, Expected=15.6930
# Month=6, Predicted=15.9572, Expected=15.8440
# Month=7, Predicted=15.7892, Expected=15.7120
# Month=8, Predicted=15.5308, Expected=15.3130
# Month=9, Predicted=15.0194, Expected=14.7630
# Month=10, Predicted=14.4323, Expected=13.5480
# Month=11, Predicted=12.8159, Expected=13.5860
# Month=12, Predicted=13.7893, Expected=14.5160
# Month=13, Predicted=15.1577, Expected=14.3830
# Month=14, Predicted=14.2120, Expected=14.4970
# Month=15, Predicted=14.5354, Expected=14.7440
# Month=16, Predicted=14.8620, Expected=15.8060
# Month=17, Predicted=16.3989, Expected=16.5270
# Month=18, Predicted=16.8121, Expected=16.5460
# Month=19, Predicted=16.3867, Expected=16.7170
# Month=20, Predicted=16.7342, Expected=16.4330
# Month=21, Predicted=16.1802, Expected=15.7690
# Month=22, Predicted=15.3318, Expected=15.2750
# Month=23, Predicted=15.0291, Expected=15.1230
# Month=24, Predicted=15.1151, Expected=15.5410
# Month=25, Predicted=15.8555, Expected=15.8250
# Month=26, Predicted=15.9701, Expected=16.3760
# Month=27, Predicted=16.6603, Expected=16.3570
# Month=28, Predicted=16.2425, Expected=16.9070
# Month=29, Predicted=17.1956, Expected=17.0210
# Month=30, Predicted=16.9941, Expected=17.4190
# Month=31, Predicted=17.6002, Expected=17.5330
# Month=32, Predicted=17.5177, Expected=17.2680
# Month=33, Predicted=17.0355, Expected=16.6030
# Month=34, Predicted=16.1662, Expected=15.8250
# Month=35, Predicted=15.3908, Expected=15.4460
# Month=36, Predicted=15.3271, Expected=15.6360
# Month=37, Predicted=15.8541, Expected=15.6930
# Month=38, Predicted=15.7448, Expected=16.7550
# Month=39, Predicted=17.3944, Expected=16.5090
# Month=40, Predicted=16.2115, Expected=17.7230
# Month=41, Predicted=18.4151, Expected=18.6910
# Month=42, Predicted=19.1108, Expected=19.1270
# Month=43, Predicted=19.1934, Expected=19.5640
# Month=44, Predicted=19.6794, Expected=19.2030
# Month=45, Predicted=18.8354, Expected=18.2160
# Month=46, Predicted=17.5395, Expected=17.2110
# Month=47, Predicted=16.6538, Expected=16.6600
# Month=48, Predicted=16.4721, Expected=16.8310
# Month=49, Predicted=17.0792, Expected=15.7690
# Month=50, Predicted=15.1067, Expected=15.7310
# Month=51, Predicted=15.8480, Expected=15.9960
# Month=52, Predicted=16.2262, Expected=17.0210
# Month=53, Predicted=17.6361, Expected=17.5520
# Month=54, Predicted=17.7461, Expected=17.8370
# Month=55, Predicted=17.8786, Expected=17.8560
# Month=56, Predicted=17.7605, Expected=17.5710
# Month=57, Predicted=17.3277, Expected=17.0780
# Month=58, Predicted=16.7591, Expected=16.6600
# Month=59, Predicted=16.4449, Expected=16.4330
# Month=60, Predicted=16.3583, Expected=16.5840
# Run 13 — RMSE: 0.493508, MSE: 0.243551, NMSE: 0.0019530238
#
# ===== BiLSTM-SNP RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2859, Expected=13.7000
# Month=2, Predicted=14.0696, Expected=13.8140
# Month=3, Predicted=13.8133, Expected=14.3830
# Month=4, Predicted=14.6744, Expected=15.0470
# Month=5, Predicted=15.3405, Expected=15.6930
# Month=6, Predicted=15.9320, Expected=15.8440
# Month=7, Predicted=15.7549, Expected=15.7120
# Month=8, Predicted=15.4954, Expected=15.3130
# Month=9, Predicted=14.9904, Expected=14.7630
# Month=10, Predicted=14.4159, Expected=13.5480
# Month=11, Predicted=12.8122, Expected=13.5860
# Month=12, Predicted=13.8144, Expected=14.5160
# Month=13, Predicted=15.1877, Expected=14.3830
# Month=14, Predicted=14.2267, Expected=14.4970
# Month=15, Predicted=14.5422, Expected=14.7440
# Month=16, Predicted=14.8628, Expected=15.8060
# Month=17, Predicted=16.3918, Expected=16.5270
# Month=18, Predicted=16.7911, Expected=16.5460
# Month=19, Predicted=16.3521, Expected=16.7170
# Month=20, Predicted=16.6993, Expected=16.4330
# Month=21, Predicted=16.1478, Expected=15.7690
# Month=22, Predicted=15.3084, Expected=15.2750
# Month=23, Predicted=15.0237, Expected=15.1230
# Month=24, Predicted=15.1260, Expected=15.5410
# Month=25, Predicted=15.8733, Expected=15.8250
# Month=26, Predicted=15.9820, Expected=16.3760
# Month=27, Predicted=16.6628, Expected=16.3570
# Month=28, Predicted=16.2331, Expected=16.9070
# Month=29, Predicted=17.1824, Expected=17.0210
# Month=30, Predicted=16.9746, Expected=17.4190
# Month=31, Predicted=17.5792, Expected=17.5330
# Month=32, Predicted=17.4942, Expected=17.2680
# Month=33, Predicted=17.0122, Expected=16.6030
# Month=34, Predicted=16.1491, Expected=15.8250
# Month=35, Predicted=15.3886, Expected=15.4460
# Month=36, Predicted=15.3445, Expected=15.6360
# Month=37, Predicted=15.8828, Expected=15.6930
# Month=38, Predicted=15.7705, Expected=16.7550
# Month=39, Predicted=17.4111, Expected=16.5090
# Month=40, Predicted=16.2083, Expected=17.7230
# Month=41, Predicted=18.4041, Expected=18.6910
# Month=42, Predicted=19.0858, Expected=19.1270
# Month=43, Predicted=19.1532, Expected=19.5640
# Month=44, Predicted=19.6331, Expected=19.2030
# Month=45, Predicted=18.7869, Expected=18.2160
# Month=46, Predicted=17.4999, Expected=17.2110
# Month=47, Predicted=16.6393, Expected=16.6600
# Month=48, Predicted=16.4874, Expected=16.8310
# Month=49, Predicted=17.1134, Expected=15.7690
# Month=50, Predicted=15.1365, Expected=15.7310
# Month=51, Predicted=15.8909, Expected=15.9960
# Month=52, Predicted=16.2672, Expected=17.0210
# Month=53, Predicted=17.6637, Expected=17.5520
# Month=54, Predicted=17.7514, Expected=17.8370
# Month=55, Predicted=17.8654, Expected=17.8560
# Month=56, Predicted=17.7377, Expected=17.5710
# Month=57, Predicted=17.3039, Expected=17.0780
# Month=58, Predicted=16.7423, Expected=16.6600
# Month=59, Predicted=16.4414, Expected=16.4330
# Month=60, Predicted=16.3674, Expected=16.5840
# Run 14 — RMSE: 0.488831, MSE: 0.238956, NMSE: 0.0019418643
#
# ===== BiLSTM-SNP RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.2594, Expected=13.7000
# Month=2, Predicted=14.0463, Expected=13.8140
# Month=3, Predicted=13.8106, Expected=14.3830
# Month=4, Predicted=14.6842, Expected=15.0470
# Month=5, Predicted=15.3630, Expected=15.6930
# Month=6, Predicted=15.9704, Expected=15.8440
# Month=7, Predicted=15.8081, Expected=15.7120
# Month=8, Predicted=15.5517, Expected=15.3130
# Month=9, Predicted=15.0360, Expected=14.7630
# Month=10, Predicted=14.4411, Expected=13.5480
# Month=11, Predicted=12.8201, Expected=13.5860
# Month=12, Predicted=13.7700, Expected=14.5160
# Month=13, Predicted=15.1317, Expected=14.3830
# Month=14, Predicted=14.2039, Expected=14.4970
# Month=15, Predicted=14.5395, Expected=14.7440
# Month=16, Predicted=14.8660, Expected=15.8060
# Month=17, Predicted=16.4005, Expected=16.5270
# Month=18, Predicted=16.8210, Expected=16.5460
# Month=19, Predicted=16.4063, Expected=16.7170
# Month=20, Predicted=16.7551, Expected=16.4330
# Month=21, Predicted=16.1975, Expected=15.7690
# Month=22, Predicted=15.3454, Expected=15.2750
# Month=23, Predicted=15.0315, Expected=15.1230
# Month=24, Predicted=15.1063, Expected=15.5410
# Month=25, Predicted=15.8418, Expected=15.8250
# Month=26, Predicted=15.9637, Expected=16.3760
# Month=27, Predicted=16.6613, Expected=16.3570
# Month=28, Predicted=16.2514, Expected=16.9070
# Month=29, Predicted=17.2048, Expected=17.0210
# Month=30, Predicted=17.0047, Expected=17.4190
# Month=31, Predicted=17.6114, Expected=17.5330
# Month=32, Predicted=17.5295, Expected=17.2680
# Month=33, Predicted=17.0491, Expected=16.6030
# Month=34, Predicted=16.1781, Expected=15.8250
# Month=35, Predicted=15.3945, Expected=15.4460
# Month=36, Predicted=15.3168, Expected=15.6360
# Month=37, Predicted=15.8355, Expected=15.6930
# Month=38, Predicted=15.7323, Expected=16.7550
# Month=39, Predicted=17.3847, Expected=16.5090
# Month=40, Predicted=16.2148, Expected=17.7230
# Month=41, Predicted=18.4206, Expected=18.6910
# Month=42, Predicted=19.1205, Expected=19.1270
# Month=43, Predicted=19.2141, Expected=19.5640
# Month=44, Predicted=19.7049, Expected=19.2030
# Month=45, Predicted=18.8612, Expected=18.2160
# Month=46, Predicted=17.5629, Expected=17.2110
# Month=47, Predicted=16.6618, Expected=16.6600
# Month=48, Predicted=16.4590, Expected=16.8310
# Month=49, Predicted=17.0541, Expected=15.7690
# Month=50, Predicted=15.0946, Expected=15.7310
# Month=51, Predicted=15.8307, Expected=15.9960
# Month=52, Predicted=16.2069, Expected=17.0210
# Month=53, Predicted=17.6220, Expected=17.5520
# Month=54, Predicted=17.7465, Expected=17.8370
# Month=55, Predicted=17.8921, Expected=17.8560
# Month=56, Predicted=17.7782, Expected=17.5710
# Month=57, Predicted=17.3442, Expected=17.0780
# Month=58, Predicted=16.7702, Expected=16.6600
# Month=59, Predicted=16.4469, Expected=16.4330
# Month=60, Predicted=16.3522, Expected=16.5840
# Run 15 — RMSE: 0.495627, MSE: 0.245646, NMSE: 0.0019554156
#
# ===== BiLSTM-SNP RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.2788, Expected=13.7000
# Month=2, Predicted=14.0660, Expected=13.8140
# Month=3, Predicted=13.8265, Expected=14.3830
# Month=4, Predicted=14.6726, Expected=15.0470
# Month=5, Predicted=15.3480, Expected=15.6930
# Month=6, Predicted=15.9458, Expected=15.8440
# Month=7, Predicted=15.7758, Expected=15.7120
# Month=8, Predicted=15.5076, Expected=15.3130
# Month=9, Predicted=14.9969, Expected=14.7630
# Month=10, Predicted=14.4168, Expected=13.5480
# Month=11, Predicted=12.8183, Expected=13.5860
# Month=12, Predicted=13.7863, Expected=14.5160
# Month=13, Predicted=15.1762, Expected=14.3830
# Month=14, Predicted=14.2531, Expected=14.4970
# Month=15, Predicted=14.5407, Expected=14.7440
# Month=16, Predicted=14.8602, Expected=15.8060
# Month=17, Predicted=16.3857, Expected=16.5270
# Month=18, Predicted=16.8121, Expected=16.5460
# Month=19, Predicted=16.3781, Expected=16.7170
# Month=20, Predicted=16.7050, Expected=16.4330
# Month=21, Predicted=16.1599, Expected=15.7690
# Month=22, Predicted=15.3149, Expected=15.2750
# Month=23, Predicted=15.0171, Expected=15.1230
# Month=24, Predicted=15.1174, Expected=15.5410
# Month=25, Predicted=15.8656, Expected=15.8250
# Month=26, Predicted=15.9898, Expected=16.3760
# Month=27, Predicted=16.6654, Expected=16.3570
# Month=28, Predicted=16.2480, Expected=16.9070
# Month=29, Predicted=17.1779, Expected=17.0210
# Month=30, Predicted=16.9879, Expected=17.4190
# Month=31, Predicted=17.5819, Expected=17.5330
# Month=32, Predicted=17.5064, Expected=17.2680
# Month=33, Predicted=17.0233, Expected=16.6030
# Month=34, Predicted=16.1547, Expected=15.8250
# Month=35, Predicted=15.3843, Expected=15.4460
# Month=36, Predicted=15.3305, Expected=15.6360
# Month=37, Predicted=15.8700, Expected=15.6930
# Month=38, Predicted=15.7732, Expected=16.7550
# Month=39, Predicted=17.4000, Expected=16.5090
# Month=40, Predicted=16.2369, Expected=17.7230
# Month=41, Predicted=18.3890, Expected=18.6910
# Month=42, Predicted=19.1068, Expected=19.1270
# Month=43, Predicted=19.1827, Expected=19.5640
# Month=44, Predicted=19.6500, Expected=19.2030
# Month=45, Predicted=18.8108, Expected=18.2160
# Month=46, Predicted=17.5118, Expected=17.2110
# Month=47, Predicted=16.6335, Expected=16.6600
# Month=48, Predicted=16.4734, Expected=16.8310
# Month=49, Predicted=17.0998, Expected=15.7690
# Month=50, Predicted=15.1569, Expected=15.7310
# Month=51, Predicted=15.8652, Expected=15.9960
# Month=52, Predicted=16.2551, Expected=17.0210
# Month=53, Predicted=17.6534, Expected=17.5520
# Month=54, Predicted=17.7681, Expected=17.8370
# Month=55, Predicted=17.8774, Expected=17.8560
# Month=56, Predicted=17.7458, Expected=17.5710
# Month=57, Predicted=17.3090, Expected=17.0780
# Month=58, Predicted=16.7427, Expected=16.6600
# Month=59, Predicted=16.4356, Expected=16.4330
# Month=60, Predicted=16.3607, Expected=16.5840
# Run 16 — RMSE: 0.487222, MSE: 0.237385, NMSE: 0.0019197082
#
# ===== BiLSTM-SNP RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.2751, Expected=13.7000
# Month=2, Predicted=14.0596, Expected=13.8140
# Month=3, Predicted=13.8086, Expected=14.3830
# Month=4, Predicted=14.6763, Expected=15.0470
# Month=5, Predicted=15.3507, Expected=15.6930
# Month=6, Predicted=15.9494, Expected=15.8440
# Month=7, Predicted=15.7771, Expected=15.7120
# Month=8, Predicted=15.5214, Expected=15.3130
# Month=9, Predicted=15.0153, Expected=14.7630
# Month=10, Predicted=14.4334, Expected=13.5480
# Month=11, Predicted=12.8224, Expected=13.5860
# Month=12, Predicted=13.7938, Expected=14.5160
# Month=13, Predicted=15.1667, Expected=14.3830
# Month=14, Predicted=14.2118, Expected=14.4970
# Month=15, Predicted=14.5327, Expected=14.7440
# Month=16, Predicted=14.8606, Expected=15.8060
# Month=17, Predicted=16.3989, Expected=16.5270
# Month=18, Predicted=16.8046, Expected=16.5460
# Month=19, Predicted=16.3714, Expected=16.7170
# Month=20, Predicted=16.7248, Expected=16.4330
# Month=21, Predicted=16.1744, Expected=15.7690
# Month=22, Predicted=15.3306, Expected=15.2750
# Month=23, Predicted=15.0326, Expected=15.1230
# Month=24, Predicted=15.1215, Expected=15.5410
# Month=25, Predicted=15.8619, Expected=15.8250
# Month=26, Predicted=15.9730, Expected=16.3760
# Month=27, Predicted=16.6593, Expected=16.3570
# Month=28, Predicted=16.2366, Expected=16.9070
# Month=29, Predicted=17.1919, Expected=17.0210
# Month=30, Predicted=16.9888, Expected=17.4190
# Month=31, Predicted=17.5960, Expected=17.5330
# Month=32, Predicted=17.5128, Expected=17.2680
# Month=33, Predicted=17.0308, Expected=16.6030
# Month=34, Predicted=16.1654, Expected=15.8250
# Month=35, Predicted=15.3949, Expected=15.4460
# Month=36, Predicted=15.3338, Expected=15.6360
# Month=37, Predicted=15.8619, Expected=15.6930
# Month=38, Predicted=15.7509, Expected=16.7550
# Month=39, Predicted=17.3976, Expected=16.5090
# Month=40, Predicted=16.2033, Expected=17.7230
# Month=41, Predicted=18.4116, Expected=18.6910
# Month=42, Predicted=19.1032, Expected=19.1270
# Month=43, Predicted=19.1761, Expected=19.5640
# ...
# Month=27, Predicted=16.6633, Expected=16.3570
# Month=28, Predicted=16.2303, Expected=16.9070
# Month=29, Predicted=17.1650, Expected=17.0210
# Month=30, Predicted=16.9675, Expected=17.4190
# Month=31, Predicted=17.5652, Expected=17.5330
# Month=32, Predicted=17.4864, Expected=17.2680
# Month=33, Predicted=17.0016, Expected=16.6030
# Month=34, Predicted=16.1375, Expected=15.8250
# Month=35, Predicted=15.3816, Expected=15.4460
# Month=36, Predicted=15.3469, Expected=15.6360
# Month=37, Predicted=15.8943, Expected=15.6930
# Month=38, Predicted=15.7888, Expected=16.7550
# Month=39, Predicted=17.4102, Expected=16.5090
# Month=40, Predicted=16.2174, Expected=17.7230
# Month=41, Predicted=18.3770, Expected=18.6910
# Month=42, Predicted=19.0813, Expected=19.1270
# Month=43, Predicted=19.1401, Expected=19.5640
# Month=44, Predicted=19.6081, Expected=19.2030
# Month=45, Predicted=18.7643, Expected=18.2160
# Month=46, Predicted=17.4745, Expected=17.2110
# Month=47, Predicted=16.6254, Expected=16.6600
# Month=48, Predicted=16.4934, Expected=16.8310
# Month=49, Predicted=17.1314, Expected=15.7690
# Month=50, Predicted=15.1683, Expected=15.7310
# Month=51, Predicted=15.8893, Expected=15.9960
# Month=52, Predicted=16.2783, Expected=17.0210
# Month=53, Predicted=17.6673, Expected=17.5520
# Month=54, Predicted=17.7587, Expected=17.8370
# Month=55, Predicted=17.8517, Expected=17.8560
# Month=56, Predicted=17.7152, Expected=17.5710
# Month=57, Predicted=17.2818, Expected=17.0780
# Month=58, Predicted=16.7259, Expected=16.6600
# Month=59, Predicted=16.4342, Expected=16.4330
# Month=60, Predicted=16.3705, Expected=16.5840
# Run 25 — RMSE: 0.486082, MSE: 0.236275, NMSE: 0.0019341467
#
# ===== BiLSTM-SNP RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.2794, Expected=13.7000
# Month=2, Predicted=14.0677, Expected=13.8140
# Month=3, Predicted=13.8305, Expected=14.3830
# Month=4, Predicted=14.6649, Expected=15.0470
# Month=5, Predicted=15.3378, Expected=15.6930
# Month=6, Predicted=15.9312, Expected=15.8440
# Month=7, Predicted=15.7587, Expected=15.7120
# Month=8, Predicted=15.4872, Expected=15.3130
# Month=9, Predicted=14.9796, Expected=14.7630
# Month=10, Predicted=14.4058, Expected=13.5480
# Month=11, Predicted=12.8291, Expected=13.5860
# Month=12, Predicted=13.7755, Expected=14.5160
# Month=13, Predicted=15.1798, Expected=14.3830
# Month=14, Predicted=14.2668, Expected=14.4970
# Month=15, Predicted=14.5371, Expected=14.7440
# Month=16, Predicted=14.8526, Expected=15.8060
# Month=17, Predicted=16.3759, Expected=16.5270
# Month=18, Predicted=16.8006, Expected=16.5460
# Month=19, Predicted=16.3630, Expected=16.7170
# Month=20, Predicted=16.6789, Expected=16.4330
# Month=21, Predicted=16.1415, Expected=15.7690
# Month=22, Predicted=15.3040, Expected=15.2750
# Month=23, Predicted=15.0070, Expected=15.1230
# Month=24, Predicted=15.1133, Expected=15.5410
# Month=25, Predicted=15.8659, Expected=15.8250
# Month=26, Predicted=15.9949, Expected=16.3760
# Month=27, Predicted=16.6641, Expected=16.3570
# Month=28, Predicted=16.2466, Expected=16.9070
# Month=29, Predicted=17.1630, Expected=17.0210
# Month=30, Predicted=16.9766, Expected=17.4190
# Month=31, Predicted=17.5645, Expected=17.5330
# Month=32, Predicted=17.4925, Expected=17.2680
# Month=33, Predicted=17.0121, Expected=16.6030
# Month=34, Predicted=16.1489, Expected=15.8250
# Month=35, Predicted=15.3817, Expected=15.4460
# Month=36, Predicted=15.3276, Expected=15.6360
# Month=37, Predicted=15.8719, Expected=15.6930
# Month=38, Predicted=15.7829, Expected=16.7550
# Month=39, Predicted=17.4028, Expected=16.5090
# Month=40, Predicted=16.2452, Expected=17.7230
# Month=41, Predicted=18.3734, Expected=18.6910
# Month=42, Predicted=19.0906, Expected=19.1270
# Month=43, Predicted=19.1606, Expected=19.5640
# Month=44, Predicted=19.6197, Expected=19.2030
# Month=45, Predicted=18.7873, Expected=18.2160
# Month=46, Predicted=17.4970, Expected=17.2110
# Month=47, Predicted=16.6218, Expected=16.6600
# Month=48, Predicted=16.4677, Expected=16.8310
# Month=49, Predicted=17.1024, Expected=15.7690
# Month=50, Predicted=15.1919, Expected=15.7310
# Month=51, Predicted=15.8656, Expected=15.9960
# Month=52, Predicted=16.2617, Expected=17.0210
# Month=53, Predicted=17.6589, Expected=17.5520
# Month=54, Predicted=17.7700, Expected=17.8370
# Month=55, Predicted=17.8684, Expected=17.8560
# Month=56, Predicted=17.7299, Expected=17.5710
# Month=57, Predicted=17.2926, Expected=17.0780
# Month=58, Predicted=16.7299, Expected=16.6600
# Month=59, Predicted=16.4263, Expected=16.4330
# Month=60, Predicted=16.3571, Expected=16.5840
# Run 26 — RMSE: 0.484321, MSE: 0.234567, NMSE: 0.0019100306
#
# ===== BiLSTM-SNP RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.2507, Expected=13.7000
# Month=2, Predicted=14.0390, Expected=13.8140
# Month=3, Predicted=13.8117, Expected=14.3830
# Month=4, Predicted=14.6857, Expected=15.0470
# Month=5, Predicted=15.3660, Expected=15.6930
# Month=6, Predicted=15.9764, Expected=15.8440
# Month=7, Predicted=15.8192, Expected=15.7120
# Month=8, Predicted=15.5631, Expected=15.3130
# Month=9, Predicted=15.0445, Expected=14.7630
# Month=10, Predicted=14.4445, Expected=13.5480
# Month=11, Predicted=12.8260, Expected=13.5860
# Month=12, Predicted=13.7561, Expected=14.5160
# Month=13, Predicted=15.1169, Expected=14.3830
# Month=14, Predicted=14.2043, Expected=14.4970
# Month=15, Predicted=14.5423, Expected=14.7440
# Month=16, Predicted=14.8677, Expected=15.8060
# Month=17, Predicted=16.4007, Expected=16.5270
# Month=18, Predicted=16.8260, Expected=16.5460
# Month=19, Predicted=16.4207, Expected=16.7170
# Month=20, Predicted=16.7650, Expected=16.4330
# Month=21, Predicted=16.2069, Expected=15.7690
# Month=22, Predicted=15.3534, Expected=15.2750
# Month=23, Predicted=15.0300, Expected=15.1230
# Month=24, Predicted=15.0974, Expected=15.5410
# Month=25, Predicted=15.8309, Expected=15.8250
# Month=26, Predicted=15.9587, Expected=16.3760
# Month=27, Predicted=16.6603, Expected=16.3570
# Month=28, Predicted=16.2582, Expected=16.9070
# Month=29, Predicted=17.2079, Expected=17.0210
# Month=30, Predicted=17.0107, Expected=17.4190
# Month=31, Predicted=17.6152, Expected=17.5330
# Month=32, Predicted=17.5349, Expected=17.2680
# Month=33, Predicted=17.0568, Expected=16.6030
# Month=34, Predicted=16.1859, Expected=15.8250
# Month=35, Predicted=15.3962, Expected=15.4460
# Month=36, Predicted=15.3080, Expected=15.6360
# Month=37, Predicted=15.8222, Expected=15.6930
# Month=38, Predicted=15.7244, Expected=16.7550
# Month=39, Predicted=17.3795, Expected=16.5090
# Month=40, Predicted=16.2247, Expected=17.7230
# Month=41, Predicted=18.4252, Expected=18.6910
# Month=42, Predicted=19.1262, Expected=19.1270
# Month=43, Predicted=19.2274, Expected=19.5640
# Month=44, Predicted=19.7176, Expected=19.2030
# Month=45, Predicted=18.8780, Expected=18.2160
# Month=46, Predicted=17.5797, Expected=17.2110
# Month=47, Predicted=16.6654, Expected=16.6600
# Month=48, Predicted=16.4475, Expected=16.8310
# Month=49, Predicted=17.0362, Expected=15.7690
# Month=50, Predicted=15.0948, Expected=15.7310
# Month=51, Predicted=15.8199, Expected=15.9960
# Month=52, Predicted=16.1957, Expected=17.0210
# Month=53, Predicted=17.6153, Expected=17.5520
# Month=54, Predicted=17.7494, Expected=17.8370
# Month=55, Predicted=17.9022, Expected=17.8560
# Month=56, Predicted=17.7897, Expected=17.5710
# Month=57, Predicted=17.3544, Expected=17.0780
# Month=58, Predicted=16.7765, Expected=16.6600
# Month=59, Predicted=16.4461, Expected=16.4330
# Month=60, Predicted=16.3460, Expected=16.5840
# Run 27 — RMSE: 0.496362, MSE: 0.246376, NMSE: 0.0019521989
#
# ===== BiLSTM-SNP RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.2747, Expected=13.7000
# Month=2, Predicted=14.0598, Expected=13.8140
# Month=3, Predicted=13.8123, Expected=14.3830
# Month=4, Predicted=14.6742, Expected=15.0470
# Month=5, Predicted=15.3481, Expected=15.6930
# Month=6, Predicted=15.9461, Expected=15.8440
# Month=7, Predicted=15.7747, Expected=15.7120
# Month=8, Predicted=15.5168, Expected=15.3130
# Month=9, Predicted=15.0116, Expected=14.7630
# Month=10, Predicted=14.4322, Expected=13.5480
# Month=11, Predicted=12.8345, Expected=13.5860
# Month=12, Predicted=13.7957, Expected=14.5160
# Month=13, Predicted=15.1712, Expected=14.3830
# Month=14, Predicted=14.2246, Expected=14.4970
# Month=15, Predicted=14.5361, Expected=14.7440
# Month=16, Predicted=14.8597, Expected=15.8060
# Month=17, Predicted=16.3963, Expected=16.5270
# Month=18, Predicted=16.8056, Expected=16.5460
# Month=19, Predicted=16.3731, Expected=16.7170
# Month=20, Predicted=16.7176, Expected=16.4330
# Month=21, Predicted=16.1704, Expected=15.7690
# Month=22, Predicted=15.3309, Expected=15.2750
# Month=23, Predicted=15.0320, Expected=15.1230
# Month=24, Predicted=15.1207, Expected=15.5410
# Month=25, Predicted=15.8613, Expected=15.8250
# Month=26, Predicted=15.9756, Expected=16.3760
# Month=27, Predicted=16.6597, Expected=16.3570
# Month=28, Predicted=16.2394, Expected=16.9070
# Month=29, Predicted=17.1868, Expected=17.0210
# Month=30, Predicted=16.9867, Expected=17.4190
# Month=31, Predicted=17.5898, Expected=17.5330
# Month=32, Predicted=17.5087, Expected=17.2680
# Month=33, Predicted=17.0291, Expected=16.6030
# Month=34, Predicted=16.1674, Expected=15.8250
# Month=35, Predicted=15.3991, Expected=15.4460
# Month=36, Predicted=15.3358, Expected=15.6360
# Month=37, Predicted=15.8631, Expected=15.6930
# Month=38, Predicted=15.7551, Expected=16.7550
# Month=39, Predicted=17.4004, Expected=16.5090
# Month=40, Predicted=16.2157, Expected=17.7230
# Month=41, Predicted=18.4106, Expected=18.6910
# Month=42, Predicted=19.1051, Expected=19.1270
# Month=43, Predicted=19.1768, Expected=19.5640
# Month=44, Predicted=19.6577, Expected=19.2030
# Month=45, Predicted=18.8193, Expected=18.2160
# Month=46, Predicted=17.5380, Expected=17.2110
# Month=47, Predicted=16.6628, Expected=16.6600
# Month=48, Predicted=16.4836, Expected=16.8310
# Month=49, Predicted=17.0910, Expected=15.7690
# Month=50, Predicted=15.1361, Expected=15.7310
# Month=51, Predicted=15.8593, Expected=15.9960
# Month=52, Predicted=16.2384, Expected=17.0210
# Month=53, Predicted=17.6461, Expected=17.5520
# Month=54, Predicted=17.7483, Expected=17.8370
# Month=55, Predicted=17.8702, Expected=17.8560
# Month=56, Predicted=17.7489, Expected=17.5710
# Month=57, Predicted=17.3192, Expected=17.0780
# Month=58, Predicted=16.7568, Expected=16.6600
# Month=59, Predicted=16.4471, Expected=16.4330
# Month=60, Predicted=16.3635, Expected=16.5840
# Run 28 — RMSE: 0.490933, MSE: 0.241016, NMSE: 0.0019461096
#
# ===== BiLSTM-SNP RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.2789, Expected=13.7000
# Month=2, Predicted=14.0701, Expected=13.8140
# Month=3, Predicted=13.8417, Expected=14.3830
# Month=4, Predicted=14.6655, Expected=15.0470
# Month=5, Predicted=15.3318, Expected=15.6930
# Month=6, Predicted=15.9178, Expected=15.8440
# Month=7, Predicted=15.7424, Expected=15.7120
# Month=8, Predicted=15.4660, Expected=15.3130
# Month=9, Predicted=14.9576, Expected=14.7630
# Month=10, Predicted=14.3867, Expected=13.5480
# Month=11, Predicted=12.8223, Expected=13.5860
# Month=12, Predicted=13.7702, Expected=14.5160
# Month=13, Predicted=15.1794, Expected=14.3830
# Month=14, Predicted=14.2938, Expected=14.4970
# Month=15, Predicted=14.5567, Expected=14.7440
# Month=16, Predicted=14.8638, Expected=15.8060
# Month=17, Predicted=16.3691, Expected=16.5270
# Month=18, Predicted=16.7951, Expected=16.5460
# Month=19, Predicted=16.3532, Expected=16.7170
# Month=20, Predicted=16.6576, Expected=16.4330
# Month=21, Predicted=16.1195, Expected=15.7690
# Month=22, Predicted=15.2848, Expected=15.2750
# Month=23, Predicted=14.9911, Expected=15.1230
# Month=24, Predicted=15.1033, Expected=15.5410
# Month=25, Predicted=15.8612, Expected=15.8250
# Month=26, Predicted=16.0022, Expected=16.3760
# Month=27, Predicted=16.6682, Expected=16.3570
# Month=28, Predicted=16.2531, Expected=16.9070
# Month=29, Predicted=17.1557, Expected=17.0210
# Month=30, Predicted=16.9699, Expected=17.4190
# Month=31, Predicted=17.5484, Expected=17.5330
# Month=32, Predicted=17.4764, Expected=17.2680
# Month=33, Predicted=16.9971, Expected=16.6030
# Month=34, Predicted=16.1375, Expected=15.8250
# Month=35, Predicted=15.3760, Expected=15.4460
# Month=36, Predicted=15.3270, Expected=15.6360
# Month=37, Predicted=15.8768, Expected=15.6930
# Month=38, Predicted=15.8014, Expected=16.7550
# Month=39, Predicted=17.4100, Expected=16.5090
# Month=40, Predicted=16.2687, Expected=17.7230
# Month=41, Predicted=18.3678, Expected=18.6910
# Month=42, Predicted=19.0845, Expected=19.1270
# Month=43, Predicted=19.1467, Expected=19.5640
# Month=44, Predicted=19.5918, Expected=19.2030
# Month=45, Predicted=18.7589, Expected=18.2160
# Month=46, Predicted=17.4708, Expected=17.2110
# Month=47, Predicted=16.6008, Expected=16.6600
# Month=48, Predicted=16.4537, Expected=16.8310
# Month=49, Predicted=17.0987, Expected=15.7690
# Month=50, Predicted=15.2206, Expected=15.7310
# Month=51, Predicted=15.8984, Expected=15.9960
# Month=52, Predicted=16.2975, Expected=17.0210
# Month=53, Predicted=17.6839, Expected=17.5520
# Month=54, Predicted=17.7966, Expected=17.8370
# Month=55, Predicted=17.8806, Expected=17.8560
# Month=56, Predicted=17.7298, Expected=17.5710
# Month=57, Predicted=17.2852, Expected=17.0780
# Month=58, Predicted=16.7199, Expected=16.6600
# Month=59, Predicted=16.4169, Expected=16.4330
# Month=60, Predicted=16.3521, Expected=16.5840
# Run 29 — RMSE: 0.478216, MSE: 0.228691, NMSE: 0.0018699961
#
# ===== BiLSTM-SNP RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.2487, Expected=13.7000
# Month=2, Predicted=14.0379, Expected=13.8140
# Month=3, Predicted=13.8156, Expected=14.3830
# Month=4, Predicted=14.6846, Expected=15.0470
# Month=5, Predicted=15.3673, Expected=15.6930
# Month=6, Predicted=15.9788, Expected=15.8440
# Month=7, Predicted=15.8232, Expected=15.7120
# Month=8, Predicted=15.5640, Expected=15.3130
# Month=9, Predicted=15.0433, Expected=14.7630
# Month=10, Predicted=14.4416, Expected=13.5480
# Month=11, Predicted=12.8205, Expected=13.5860
# Month=12, Predicted=13.7471, Expected=14.5160
# Month=13, Predicted=15.1124, Expected=14.3830
# Month=14, Predicted=14.2116, Expected=14.4970
# Month=15, Predicted=14.5414, Expected=14.7440
# Month=16, Predicted=14.8672, Expected=15.8060
# Month=17, Predicted=16.3968, Expected=16.5270
# Month=18, Predicted=16.8308, Expected=16.5460
# Month=19, Predicted=16.4258, Expected=16.7170
# Month=20, Predicted=16.7644, Expected=16.4330
# Month=21, Predicted=16.2077, Expected=15.7690
# Month=22, Predicted=15.3512, Expected=15.2750
# Month=23, Predicted=15.0254, Expected=15.1230
# Month=24, Predicted=15.0941, Expected=15.5410
# Month=25, Predicted=15.8285, Expected=15.8250
# Month=26, Predicted=15.9612, Expected=16.3760
# Month=27, Predicted=16.6606, Expected=16.3570
# Month=28, Predicted=16.2619, Expected=16.9070
# Month=29, Predicted=17.2056, Expected=17.0210
# Month=30, Predicted=17.0138, Expected=17.4190
# Month=31, Predicted=17.6147, Expected=17.5330
# Month=32, Predicted=17.5371, Expected=17.2680
# Month=33, Predicted=17.0577, Expected=16.6030
# Month=34, Predicted=16.1837, Expected=15.8250
# Month=35, Predicted=15.3912, Expected=15.4460
# Month=36, Predicted=15.3029, Expected=15.6360
# Month=37, Predicted=15.8190, Expected=15.6930
# Month=38, Predicted=15.7260, Expected=16.7550
# Month=39, Predicted=17.3746, Expected=16.5090
# Month=40, Predicted=16.2320, Expected=17.7230
# Month=41, Predicted=18.4168, Expected=18.6910
# Month=42, Predicted=19.1301, Expected=19.1270
# Month=43, Predicted=19.2332, Expected=19.5640
# Month=44, Predicted=19.7192, Expected=19.2030
# Month=45, Predicted=18.8805, Expected=18.2160
# Month=46, Predicted=17.5757, Expected=17.2110
# Month=47, Predicted=16.6574, Expected=16.6600
# Month=48, Predicted=16.4408, Expected=16.8310
# Month=49, Predicted=17.0320, Expected=15.7690
# Month=50, Predicted=15.0958, Expected=15.7310
# Month=51, Predicted=15.8126, Expected=15.9960
# Month=52, Predicted=16.1942, Expected=17.0210
# Month=53, Predicted=17.6122, Expected=17.5520
# Month=54, Predicted=17.7551, Expected=17.8370
# Month=55, Predicted=17.9053, Expected=17.8560
# Month=56, Predicted=17.7911, Expected=17.5710
# Month=57, Predicted=17.3541, Expected=17.0780
# Month=58, Predicted=16.7743, Expected=16.6600
# Month=59, Predicted=16.4428, Expected=16.4330
# Month=60, Predicted=16.3433, Expected=16.5840
# Run 30 — RMSE: 0.495883, MSE: 0.245900, NMSE: 0.0019459519

# %%
# ============================================================
# BiLSTM-SNP Summary Statistics
# ============================================================

print('\n===== BiLSTM-SNP FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(bi_all_rmse):.10f} ± {np.var(bi_all_rmse):.15f}')
print(f'MSE:  {np.mean(bi_all_mse):.10f} ± {np.var(bi_all_mse):.15f}')
print(f'NMSE: {np.mean(bi_all_nmse):.10f} ± {np.var(bi_all_nmse):.15f}')

best_bi_idx = bi_all_rmse.index(min(bi_all_rmse))
print(f'\nBest run: {best_bi_idx+1}')
print(f'  RMSE: {bi_all_rmse[best_bi_idx]:.15f}')
print(f'  MSE:  {bi_all_mse[best_bi_idx]:.15f}')
print(f'  NMSE: {bi_all_nmse[best_bi_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_bi_preds = bi_all_predictions[best_bi_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_bi_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('BiLSTM-SNP — CLOSING (Best Run)')
plt.show()
# Out:
# ===== BiLSTM-SNP FINAL RESULTS (30 runs) =====
# RMSE: 0.4905042250 ± 0.000023693835098
# MSE:  0.2406180886 ± 0.000022529811647
# NMSE: 0.0019359713 ± 0.000000000587699
#
# Best run: 21
#   RMSE: 0.477047866145539
#   MSE:  0.227574666594012
#   NMSE: 0.001859517885963

# %% [markdown]
# # **Incorporating attention mechanism**

# %% [markdown]
# # Attention Mechanism in LSTM-SNP
#
# ## 1. Sequence Representation
#
# Standard LSTM-SNP compresses a sequence as:
#
# $$
# x_1, x_2, \dots, x_T \longrightarrow h_T
# $$
#
# This creates an information bottleneck.
#
# Instead, with attention we retain all hidden states:
#
# $$
# H = \{h_1, h_2, \dots, h_T\}
# $$
#
# where:
#
# $$
# h_t \in \mathbb{R}^{d}
# $$
#
#
#
# ## 2. Alignment Score Function (Additive Attention)
#
# Each hidden state receives a score:
#
# $$
# e_t = v^\top \tanh(W h_t + b)
# $$
#
# where:
#
# $$
# W \in \mathbb{R}^{d \times d},
# \quad
# v \in \mathbb{R}^{d},
# \quad
# b \in \mathbb{R}^{d}
# $$
#
#
#
# ## 3. Softmax Normalization
#
# Attention weights are computed as:
#
# $$
# \alpha_t =
# \frac{\exp(e_t)}
# {\sum_{k=1}^{T} \exp(e_k)}
# $$
#
# with:
#
# $$
# \sum_{t=1}^{T} \alpha_t = 1
# $$
#
#
# ## 4. Context Vector
#
# The context vector is a weighted sum of hidden states:
#
# $$
# c = \sum_{t=1}^{T} \alpha_t h_t
# $$
#
# where:
#
# $$
# c \in \mathbb{R}^{d}
# $$
#
#
#
# ## 5. Final Prediction
#
# The final output is computed as:
#
# $$
# \hat{y} = W_o c + b_o
# $$
#
# where:
#
# $$
# W_o \in \mathbb{R}^{1 \times d},
# \quad
# b_o \in \mathbb{R}
# $$
#
#
# ## 6. Full Compact Form
#
# $$
# e_t = v^\top \tanh(W h_t + b)
# $$
#
# $$
# \alpha_t =
# \frac{\exp(e_t)}
# {\sum_{k=1}^{T} \exp(e_k)}
# $$
#
# $$
# c = \sum_{t=1}^{T} \alpha_t h_t
# $$
#
# $$
# \hat{y} = W_o c + b_o
# $$

# %%
class SimpleAttention(layers.Layer):
    def __init__(self, units):
        super().__init__()
        self.W = layers.Dense(units)
        self.V = layers.Dense(1)

    def call(self, hidden_states):
        # hidden_states: (batch, T, units)

        score = self.V(tf.nn.tanh(self.W(hidden_states)))
        attention_weights = tf.nn.softmax(score, axis=1)

        context_vector = attention_weights * hidden_states
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector

# %%
def build_lstm_snp_attention(input_dim, units, batch_size):
    """
    Stateful LSTM-SNP + Attention model.
    return_sequences=True to provide all hidden states to attention.
    """
    cell = LSTMSNPCell(units)
    rnn_layer = layers.RNN(cell, return_sequences=True, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, None, input_dim))
    sequence_output = rnn_layer(inputs)

    attention_layer = SimpleAttention(units)
    context = attention_layer(sequence_output)

    outputs = layers.Dense(1)(context)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# ============================================================
# LSTM-SNP + Attention (lag=1) — DEGENERATE ATTENTION CONTROL
# With T=1 timestep: softmax([e_1]) = [1.0], α_1 = 1 always.
# Context vector = h_1. Attention has zero selective effect.
# This serves as a control experiment.
# ============================================================
att_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att_model_check.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (1, None, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn_2 (RNN)                     │ (1, None, 8)           │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_attention                │ (1, 8)                 │            81 │
# │ (SimpleAttention)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 410 (1.60 KB)
#  Trainable params: 410 (1.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# LSTM-SNP + Attention (lag=1): 30-Run Protocol
# DEGENERATE ATTENTION CONTROL (T=1, α₁=1 always)
# ============================================================

att1_all_rmse = []
att1_all_mse = []
att1_all_nmse = []
att1_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=1) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train,
            y_train,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]

        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att1_all_rmse.append(rmse)
    att1_all_mse.append(mse)
    att1_all_nmse.append(nmse)
    att1_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== Attention(lag=1) RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2710, Expected=13.7000
# Month=2, Predicted=14.0577, Expected=13.8140
# Month=3, Predicted=13.8147, Expected=14.3830
# Month=4, Predicted=14.6735, Expected=15.0470
# Month=5, Predicted=15.3469, Expected=15.6930
# Month=6, Predicted=15.9457, Expected=15.8440
# Month=7, Predicted=15.7781, Expected=15.7120
# Month=8, Predicted=15.5179, Expected=15.3130
# Month=9, Predicted=15.0080, Expected=14.7630
# Month=10, Predicted=14.4240, Expected=13.5480
# Month=11, Predicted=12.8242, Expected=13.5860
# Month=12, Predicted=13.7810, Expected=14.5160
# Month=13, Predicted=15.1633, Expected=14.3830
# Month=14, Predicted=14.2253, Expected=14.4970
# Month=15, Predicted=14.5371, Expected=14.7440
# Month=16, Predicted=14.8599, Expected=15.8060
# Month=17, Predicted=16.3903, Expected=16.5270
# Month=18, Predicted=16.8028, Expected=16.5460
# Month=19, Predicted=16.3779, Expected=16.7170
# Month=20, Predicted=16.7165, Expected=16.4330
# Month=21, Predicted=16.1686, Expected=15.7690
# Month=22, Predicted=15.3246, Expected=15.2750
# Month=23, Predicted=15.0206, Expected=15.1230
# Month=24, Predicted=15.1118, Expected=15.5410
# Month=25, Predicted=15.8562, Expected=15.8250
# Month=26, Predicted=15.9754, Expected=16.3760
# Month=27, Predicted=16.6600, Expected=16.3570
# Month=28, Predicted=16.2432, Expected=16.9070
# Month=29, Predicted=17.1842, Expected=17.0210
# Month=30, Predicted=16.9867, Expected=17.4190
# Month=31, Predicted=17.5866, Expected=17.5330
# Month=32, Predicted=17.5074, Expected=17.2680
# Month=33, Predicted=17.0278, Expected=16.6030
# Month=34, Predicted=16.1626, Expected=15.8250
# Month=35, Predicted=15.3893, Expected=15.4460
# Month=36, Predicted=15.3263, Expected=15.6360
# Month=37, Predicted=15.8592, Expected=15.6930
# Month=38, Predicted=15.7573, Expected=16.7550
# Month=39, Predicted=17.3984, Expected=16.5090
# Month=40, Predicted=16.2197, Expected=17.7230
# Month=41, Predicted=18.4010, Expected=18.6910
# Month=42, Predicted=19.0980, Expected=19.1270
# Month=43, Predicted=19.1795, Expected=19.5640
# Month=44, Predicted=19.6600, Expected=19.2030
# Month=45, Predicted=18.8234, Expected=18.2160
# Month=46, Predicted=17.5322, Expected=17.2110
# Month=47, Predicted=16.6445, Expected=16.6600
# Month=48, Predicted=16.4671, Expected=16.8310
# Month=49, Predicted=17.0845, Expected=15.7690
# Month=50, Predicted=15.1386, Expected=15.7310
# Month=51, Predicted=15.8582, Expected=15.9960
# Month=52, Predicted=16.2428, Expected=17.0210
# Month=53, Predicted=17.6477, Expected=17.5520
# Month=54, Predicted=17.7517, Expected=17.8370
# Month=55, Predicted=17.8758, Expected=17.8560
# Month=56, Predicted=17.7528, Expected=17.5710
# Month=57, Predicted=17.3190, Expected=17.0780
# Month=58, Predicted=16.7514, Expected=16.6600
# Month=59, Predicted=16.4383, Expected=16.4330
# Month=60, Predicted=16.3563, Expected=16.5840
# Run 1 — RMSE: 0.490640, MSE: 0.240728, NMSE: 0.0019400317
#
# ===== Attention(lag=1) RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2608, Expected=13.7000
# Month=2, Predicted=14.0491, Expected=13.8140
# Month=3, Predicted=13.8047, Expected=14.3830
# Month=4, Predicted=14.6882, Expected=15.0470
# Month=5, Predicted=15.3662, Expected=15.6930
# Month=6, Predicted=15.9738, Expected=15.8440
# Month=7, Predicted=15.8076, Expected=15.7120
# Month=8, Predicted=15.5509, Expected=15.3130
# Month=9, Predicted=15.0323, Expected=14.7630
# Month=10, Predicted=14.4355, Expected=13.5480
# Month=11, Predicted=12.8536, Expected=13.5860
# Month=12, Predicted=13.7807, Expected=14.5160
# Month=13, Predicted=15.1409, Expected=14.3830
# Month=14, Predicted=14.1898, Expected=14.4970
# Month=15, Predicted=14.5383, Expected=14.7440
# Month=16, Predicted=14.8675, Expected=15.8060
# Month=17, Predicted=16.4090, Expected=16.5270
# Month=18, Predicted=16.8218, Expected=16.5460
# Month=19, Predicted=16.4038, Expected=16.7170
# Month=20, Predicted=16.7597, Expected=16.4330
# Month=21, Predicted=16.1943, Expected=15.7690
# Month=22, Predicted=15.3448, Expected=15.2750
# Month=23, Predicted=15.0283, Expected=15.1230
# Month=24, Predicted=15.1070, Expected=15.5410
# Month=25, Predicted=15.8461, Expected=15.8250
# Month=26, Predicted=15.9604, Expected=16.3760
# Month=27, Predicted=16.6626, Expected=16.3570
# Month=28, Predicted=16.2458, Expected=16.9070
# Month=29, Predicted=17.2110, Expected=17.0210
# Month=30, Predicted=17.0028, Expected=17.4190
# Month=31, Predicted=17.6156, Expected=17.5330
# Month=32, Predicted=17.5286, Expected=17.2680
# Month=33, Predicted=17.0443, Expected=16.6030
# Month=34, Predicted=16.1769, Expected=15.8250
# Month=35, Predicted=15.3998, Expected=15.4460
# Month=36, Predicted=15.3165, Expected=15.6360
# Month=37, Predicted=15.8399, Expected=15.6930
# Month=38, Predicted=15.7278, Expected=16.7550
# Month=39, Predicted=17.3919, Expected=16.5090
# Month=40, Predicted=16.2012, Expected=17.7230
# Month=41, Predicted=18.4327, Expected=18.6910
# Month=42, Predicted=19.1232, Expected=19.1270
# Month=43, Predicted=19.2161, Expected=19.5640
# Month=44, Predicted=19.7116, Expected=19.2030
# Month=45, Predicted=18.8574, Expected=18.2160
# Month=46, Predicted=17.5854, Expected=17.2110
# Month=47, Predicted=16.6830, Expected=16.6600
# Month=48, Predicted=16.4593, Expected=16.8310
# Month=49, Predicted=17.0607, Expected=15.7690
# Month=50, Predicted=15.1144, Expected=15.7310
# Month=51, Predicted=15.8351, Expected=15.9960
# Month=52, Predicted=16.2086, Expected=17.0210
# Month=53, Predicted=17.6276, Expected=17.5520
# Month=54, Predicted=17.7429, Expected=17.8370
# Month=55, Predicted=17.8922, Expected=17.8560
# Month=56, Predicted=17.7787, Expected=17.5710
# Month=57, Predicted=17.3419, Expected=17.0780
# Month=58, Predicted=16.7655, Expected=16.6600
# Month=59, Predicted=16.4441, Expected=16.4330
# Month=60, Predicted=16.3510, Expected=16.5840
# Run 2 — RMSE: 0.495916, MSE: 0.245932, NMSE: 0.0019585075
#
# ===== Attention(lag=1) RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2539, Expected=13.7000
# Month=2, Predicted=14.0413, Expected=13.8140
# Month=3, Predicted=13.8073, Expected=14.3830
# Month=4, Predicted=14.6834, Expected=15.0470
# Month=5, Predicted=15.3609, Expected=15.6930
# Month=6, Predicted=15.9680, Expected=15.8440
# Month=7, Predicted=15.8057, Expected=15.7120
# Month=8, Predicted=15.5505, Expected=15.3130
# Month=9, Predicted=15.0348, Expected=14.7630
# Month=10, Predicted=14.4393, Expected=13.5480
# Month=11, Predicted=12.8227, Expected=13.5860
# Month=12, Predicted=13.7654, Expected=14.5160
# Month=13, Predicted=15.1251, Expected=14.3830
# Month=14, Predicted=14.1989, Expected=14.4970
# Month=15, Predicted=14.5403, Expected=14.7440
# Month=16, Predicted=14.8658, Expected=15.8060
# Month=17, Predicted=16.4002, Expected=16.5270
# Month=18, Predicted=16.8179, Expected=16.5460
# Month=19, Predicted=16.4053, Expected=16.7170
# Month=20, Predicted=16.7545, Expected=16.4330
# Month=21, Predicted=16.1954, Expected=15.7690
# Month=22, Predicted=15.3450, Expected=15.2750
# Month=23, Predicted=15.0290, Expected=15.1230
# Month=24, Predicted=15.1005, Expected=15.5410
# Month=25, Predicted=15.8350, Expected=15.8250
# Month=26, Predicted=15.9580, Expected=16.3760
# Month=27, Predicted=16.6585, Expected=16.3570
# Month=28, Predicted=16.2501, Expected=16.9070
# Month=29, Predicted=17.2044, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.6091, Expected=17.5330
# Month=32, Predicted=17.5259, Expected=17.2680
# Month=33, Predicted=17.0472, Expected=16.6030
# Month=34, Predicted=16.1787, Expected=15.8250
# Month=35, Predicted=15.3952, Expected=15.4460
# Month=36, Predicted=15.3135, Expected=15.6360
# Month=37, Predicted=15.8293, Expected=15.6930
# Month=38, Predicted=15.7271, Expected=16.7550
# Month=39, Predicted=17.3836, Expected=16.5090
# Month=40, Predicted=16.2142, Expected=17.7230
# Month=41, Predicted=18.4249, Expected=18.6910
# Month=42, Predicted=19.1187, Expected=19.1270
# Month=43, Predicted=19.2117, Expected=19.5640
# Month=44, Predicted=19.7029, Expected=19.2030
# Month=45, Predicted=18.8592, Expected=18.2160
# Month=46, Predicted=17.5657, Expected=17.2110
# Month=47, Predicted=16.6631, Expected=16.6600
# Month=48, Predicted=16.4538, Expected=16.8310
# Month=49, Predicted=17.0450, Expected=15.7690
# Month=50, Predicted=15.0933, Expected=15.7310
# Month=51, Predicted=15.8299, Expected=15.9960
# Month=52, Predicted=16.2037, Expected=17.0210
# Month=53, Predicted=17.6213, Expected=17.5520
# Month=54, Predicted=17.7455, Expected=17.8370
# Month=55, Predicted=17.8943, Expected=17.8560
# Month=56, Predicted=17.7805, Expected=17.5710
# Month=57, Predicted=17.3459, Expected=17.0780
# Month=58, Predicted=16.7711, Expected=16.6600
# Month=59, Predicted=16.4455, Expected=16.4330
# Month=60, Predicted=16.3483, Expected=16.5840
# Run 3 — RMSE: 0.495689, MSE: 0.245708, NMSE: 0.0019539725
#
# ===== Attention(lag=1) RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2684, Expected=13.7000
# Month=2, Predicted=14.0524, Expected=13.8140
# Month=3, Predicted=13.8035, Expected=14.3830
# Month=4, Predicted=14.6818, Expected=15.0470
# Month=5, Predicted=15.3552, Expected=15.6930
# Month=6, Predicted=15.9574, Expected=15.8440
# Month=7, Predicted=15.7898, Expected=15.7120
# Month=8, Predicted=15.5370, Expected=15.3130
# Month=9, Predicted=15.0263, Expected=14.7630
# Month=10, Predicted=14.4377, Expected=13.5480
# Month=11, Predicted=12.8156, Expected=13.5860
# Month=12, Predicted=13.7940, Expected=14.5160
# Month=13, Predicted=15.1501, Expected=14.3830
# Month=14, Predicted=14.1940, Expected=14.4970
# Month=15, Predicted=14.5369, Expected=14.7440
# Month=16, Predicted=14.8647, Expected=15.8060
# Month=17, Predicted=16.4021, Expected=16.5270
# Month=18, Predicted=16.8061, Expected=16.5460
# Month=19, Predicted=16.3848, Expected=16.7170
# Month=20, Predicted=16.7430, Expected=16.4330
# Month=21, Predicted=16.1851, Expected=15.7690
# Month=22, Predicted=15.3370, Expected=15.2750
# Month=23, Predicted=15.0345, Expected=15.1230
# Month=24, Predicted=15.1159, Expected=15.5410
# Month=25, Predicted=15.8530, Expected=15.8250
# Month=26, Predicted=15.9629, Expected=16.3760
# Month=27, Predicted=16.6588, Expected=16.3570
# Month=28, Predicted=16.2396, Expected=16.9070
# Month=29, Predicted=17.2023, Expected=17.0210
# Month=30, Predicted=16.9938, Expected=17.4190
# Month=31, Predicted=17.6054, Expected=17.5330
# Month=32, Predicted=17.5192, Expected=17.2680
# Month=33, Predicted=17.0385, Expected=16.6030
# Month=34, Predicted=16.1707, Expected=15.8250
# Month=35, Predicted=15.3952, Expected=15.4460
# Month=36, Predicted=15.3290, Expected=15.6360
# Month=37, Predicted=15.8512, Expected=15.6930
# Month=38, Predicted=15.7366, Expected=16.7550
# Month=39, Predicted=17.3934, Expected=16.5090
# Month=40, Predicted=16.1986, Expected=17.7230
# Month=41, Predicted=18.4239, Expected=18.6910
# Month=42, Predicted=19.1052, Expected=19.1270
# Month=43, Predicted=19.1903, Expected=19.5640
# Month=44, Predicted=19.6855, Expected=19.2030
# Month=45, Predicted=18.8395, Expected=18.2160
# Month=46, Predicted=17.5472, Expected=17.2110
# Month=47, Predicted=16.6609, Expected=16.6600
# Month=48, Predicted=16.4729, Expected=16.8310
# Month=49, Predicted=17.0740, Expected=15.7690
# Month=50, Predicted=15.0905, Expected=15.7310
# Month=51, Predicted=15.8508, Expected=15.9960
# Month=52, Predicted=16.2206, Expected=17.0210
# Month=53, Predicted=17.6312, Expected=17.5520
# Month=54, Predicted=17.7354, Expected=17.8370
# Month=55, Predicted=17.8780, Expected=17.8560
# Month=56, Predicted=17.7653, Expected=17.5710
# Month=57, Predicted=17.3341, Expected=17.0780
# Month=58, Predicted=16.7653, Expected=16.6600
# Month=59, Predicted=16.4495, Expected=16.4330
# Month=60, Predicted=16.3593, Expected=16.5840
# Run 4 — RMSE: 0.495500, MSE: 0.245520, NMSE: 0.0019663018
#
# ===== Attention(lag=1) RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2730, Expected=13.7000
# Month=2, Predicted=14.0571, Expected=13.8140
# Month=3, Predicted=13.8082, Expected=14.3830
# Month=4, Predicted=14.6717, Expected=15.0470
# Month=5, Predicted=15.3482, Expected=15.6930
# Month=6, Predicted=15.9490, Expected=15.8440
# Month=7, Predicted=15.7782, Expected=15.7120
# Month=8, Predicted=15.5183, Expected=15.3130
# Month=9, Predicted=15.0101, Expected=14.7630
# Month=10, Predicted=14.4287, Expected=13.5480
# Month=11, Predicted=12.8223, Expected=13.5860
# Month=12, Predicted=13.7965, Expected=14.5160
# Month=13, Predicted=15.1681, Expected=14.3830
# Month=14, Predicted=14.2175, Expected=14.4970
# Month=15, Predicted=14.5298, Expected=14.7440
# Month=16, Predicted=14.8557, Expected=15.8060
# Month=17, Predicted=16.3930, Expected=16.5270
# Month=18, Predicted=16.8073, Expected=16.5460
# Month=19, Predicted=16.3748, Expected=16.7170
# Month=20, Predicted=16.7206, Expected=16.4330
# Month=21, Predicted=16.1704, Expected=15.7690
# Month=22, Predicted=15.3258, Expected=15.2750
# Month=23, Predicted=15.0291, Expected=15.1230
# Month=24, Predicted=15.1202, Expected=15.5410
# Month=25, Predicted=15.8604, Expected=15.8250
# Month=26, Predicted=15.9727, Expected=16.3760
# Month=27, Predicted=16.6569, Expected=16.3570
# Month=28, Predicted=16.2355, Expected=16.9070
# Month=29, Predicted=17.1856, Expected=17.0210
# Month=30, Predicted=16.9861, Expected=17.4190
# Month=31, Predicted=17.5906, Expected=17.5330
# Month=32, Predicted=17.5095, Expected=17.2680
# Month=33, Predicted=17.0268, Expected=16.6030
# Month=34, Predicted=16.1605, Expected=15.8250
# Month=35, Predicted=15.3919, Expected=15.4460
# Month=36, Predicted=15.3341, Expected=15.6360
# Month=37, Predicted=15.8627, Expected=15.6930
# Month=38, Predicted=15.7515, Expected=16.7550
# Month=39, Predicted=17.3942, Expected=16.5090
# Month=40, Predicted=16.2073, Expected=17.7230
# Month=41, Predicted=18.4043, Expected=18.6910
# Month=42, Predicted=19.1070, Expected=19.1270
# Month=43, Predicted=19.1837, Expected=19.5640
# Month=44, Predicted=19.6666, Expected=19.2030
# Month=45, Predicted=18.8226, Expected=18.2160
# Month=46, Predicted=17.5306, Expected=17.2110
# Month=47, Predicted=16.6566, Expected=16.6600
# Month=48, Predicted=16.4852, Expected=16.8310
# Month=49, Predicted=17.0941, Expected=15.7690
# Month=50, Predicted=15.1236, Expected=15.7310
# Month=51, Predicted=15.8554, Expected=15.9960
# Month=52, Predicted=16.2347, Expected=17.0210
# Month=53, Predicted=17.6390, Expected=17.5520
# Month=54, Predicted=17.7440, Expected=17.8370
# Month=55, Predicted=17.8677, Expected=17.8560
# Month=56, Predicted=17.7469, Expected=17.5710
# Month=57, Predicted=17.3155, Expected=17.0780
# Month=58, Predicted=16.7514, Expected=16.6600
# Month=59, Predicted=16.4429, Expected=16.4330
# Month=60, Predicted=16.3609, Expected=16.5840
# Run 5 — RMSE: 0.492381, MSE: 0.242439, NMSE: 0.0019530335
#
# ===== Attention(lag=1) RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2562, Expected=13.7000
# Month=2, Predicted=14.0433, Expected=13.8140
# Month=3, Predicted=13.8156, Expected=14.3830
# Month=4, Predicted=14.6862, Expected=15.0470
# Month=5, Predicted=15.3681, Expected=15.6930
# Month=6, Predicted=15.9792, Expected=15.8440
# Month=7, Predicted=15.8216, Expected=15.7120
# Month=8, Predicted=15.5605, Expected=15.3130
# Month=9, Predicted=15.0387, Expected=14.7630
# Month=10, Predicted=14.4384, Expected=13.5480
# Month=11, Predicted=12.8056, Expected=13.5860
# Month=12, Predicted=13.7653, Expected=14.5160
# Month=13, Predicted=15.1224, Expected=14.3830
# Month=14, Predicted=14.2101, Expected=14.4970
# Month=15, Predicted=14.5425, Expected=14.7440
# Month=16, Predicted=14.8690, Expected=15.8060
# Month=17, Predicted=16.3965, Expected=16.5270
# Month=18, Predicted=16.8318, Expected=16.5460
# Month=19, Predicted=16.4227, Expected=16.7170
# Month=20, Predicted=16.7640, Expected=16.4330
# Month=21, Predicted=16.2034, Expected=15.7690
# Month=22, Predicted=15.3436, Expected=15.2750
# Month=23, Predicted=15.0271, Expected=15.1230
# Month=24, Predicted=15.1022, Expected=15.5410
# Month=25, Predicted=15.8374, Expected=15.8250
# Month=26, Predicted=15.9647, Expected=16.3760
# Month=27, Predicted=16.6628, Expected=16.3570
# Month=28, Predicted=16.2593, Expected=16.9070
# Month=29, Predicted=17.2072, Expected=17.0210
# Month=30, Predicted=17.0128, Expected=17.4190
# Month=31, Predicted=17.6159, Expected=17.5330
# Month=32, Predicted=17.5365, Expected=17.2680
# Month=33, Predicted=17.0536, Expected=16.6030
# Month=34, Predicted=16.1758, Expected=15.8250
# Month=35, Predicted=15.3872, Expected=15.4460
# Month=36, Predicted=15.3113, Expected=15.6360
# Month=37, Predicted=15.8309, Expected=15.6930
# Month=38, Predicted=15.7309, Expected=16.7550
# Month=39, Predicted=17.3766, Expected=16.5090
# Month=40, Predicted=16.2259, Expected=17.7230
# Month=41, Predicted=18.4142, Expected=18.6910
# Month=42, Predicted=19.1304, Expected=19.1270
# Month=43, Predicted=19.2339, Expected=19.5640
# Month=44, Predicted=19.7195, Expected=19.2030
# Month=45, Predicted=18.8733, Expected=18.2160
# Month=46, Predicted=17.5597, Expected=17.2110
# Month=47, Predicted=16.6522, Expected=16.6600
# Month=48, Predicted=16.4524, Expected=16.8310
# Month=49, Predicted=17.0488, Expected=15.7690
# Month=50, Predicted=15.0826, Expected=15.7310
# Month=51, Predicted=15.8261, Expected=15.9960
# Month=52, Predicted=16.2037, Expected=17.0210
# Month=53, Predicted=17.6152, Expected=17.5520
# Month=54, Predicted=17.7562, Expected=17.8370
# Month=55, Predicted=17.9043, Expected=17.8560
# Month=56, Predicted=17.7886, Expected=17.5710
# Month=57, Predicted=17.3497, Expected=17.0780
# Month=58, Predicted=16.7700, Expected=16.6600
# Month=59, Predicted=16.4439, Expected=16.4330
# Month=60, Predicted=16.3487, Expected=16.5840
# Run 6 — RMSE: 0.495673, MSE: 0.245692, NMSE: 0.0019466337
#
# ===== Attention(lag=1) RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.2400, Expected=13.7000
# Month=2, Predicted=14.0277, Expected=13.8140
# Month=3, Predicted=13.8024, Expected=14.3830
# Month=4, Predicted=14.6278, Expected=15.0470
# Month=5, Predicted=15.2928, Expected=15.6930
# Month=6, Predicted=15.8763, Expected=15.8440
# Month=7, Predicted=15.7039, Expected=15.7120
# Month=8, Predicted=15.4299, Expected=15.3130
# Month=9, Predicted=14.9211, Expected=14.7630
# Month=10, Predicted=14.3467, Expected=13.5480
# Month=11, Predicted=12.7821, Expected=13.5860
# Month=12, Predicted=13.7218, Expected=14.5160
# Month=13, Predicted=15.1249, Expected=14.3830
# Month=14, Predicted=14.2413, Expected=14.4970
# Month=15, Predicted=14.5148, Expected=14.7440
# Month=16, Predicted=14.8301, Expected=15.8060
# Month=17, Predicted=16.3313, Expected=16.5270
# Month=18, Predicted=16.7531, Expected=16.5460
# Month=19, Predicted=16.3189, Expected=16.7170
# Month=20, Predicted=16.6225, Expected=16.4330
# Month=21, Predicted=16.0854, Expected=15.7690
# Month=22, Predicted=15.2496, Expected=15.2750
# Month=23, Predicted=14.9495, Expected=15.1230
# Month=24, Predicted=15.0552, Expected=15.5410
# Month=25, Predicted=15.8071, Expected=15.8250
# Month=26, Predicted=15.9469, Expected=16.3760
# Month=27, Predicted=16.6148, Expected=16.3570
# Month=28, Predicted=16.2089, Expected=16.9070
# Month=29, Predicted=17.1123, Expected=17.0210
# Month=30, Predicted=16.9298, Expected=17.4190
# Month=31, Predicted=17.5053, Expected=17.5330
# Month=32, Predicted=17.4326, Expected=17.2680
# Month=33, Predicted=16.9551, Expected=16.6030
# Month=34, Predicted=16.0980, Expected=15.8250
# Month=35, Predicted=15.3358, Expected=15.4460
# Month=36, Predicted=15.2837, Expected=15.6360
# Month=37, Predicted=15.8316, Expected=15.6930
# Month=38, Predicted=15.7580, Expected=16.7550
# Month=39, Predicted=17.3665, Expected=16.5090
# Month=40, Predicted=16.2358, Expected=17.7230
# Month=41, Predicted=18.3317, Expected=18.6910
# Month=42, Predicted=19.0421, Expected=19.1270
# Month=43, Predicted=19.1071, Expected=19.5640
# Month=44, Predicted=19.5508, Expected=19.2030
# Month=45, Predicted=18.7236, Expected=18.2160
# Month=46, Predicted=17.4376, Expected=17.2110
# Month=47, Predicted=16.5593, Expected=16.6600
# Month=48, Predicted=16.4020, Expected=16.8310
# Month=49, Predicted=17.0403, Expected=15.7690
# Month=50, Predicted=15.1664, Expected=15.7310
# Month=51, Predicted=15.8528, Expected=15.9960
# Month=52, Predicted=16.2636, Expected=17.0210
# Month=53, Predicted=17.6558, Expected=17.5520
# Month=54, Predicted=17.7740, Expected=17.8370
# Month=55, Predicted=17.8686, Expected=17.8560
# Month=56, Predicted=17.7255, Expected=17.5710
# Month=57, Predicted=17.2842, Expected=17.0780
# Month=58, Predicted=16.7173, Expected=16.6600
# Month=59, Predicted=16.4084, Expected=16.4330
# Month=60, Predicted=16.3369, Expected=16.5840
# Run 7 — RMSE: 0.484794, MSE: 0.235026, NMSE: 0.0019069423
#
# ===== Attention(lag=1) RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2661, Expected=13.7000
# Month=2, Predicted=14.0630, Expected=13.8140
# Month=3, Predicted=13.8167, Expected=14.3830
# Month=4, Predicted=14.6903, Expected=15.0470
# Month=5, Predicted=15.3736, Expected=15.6930
# Month=6, Predicted=15.9800, Expected=15.8440
# Month=7, Predicted=15.8066, Expected=15.7120
# Month=8, Predicted=15.5380, Expected=15.3130
# Month=9, Predicted=15.0159, Expected=14.7630
# Month=10, Predicted=14.4200, Expected=13.5480
# Month=11, Predicted=13.0376, Expected=13.5860
# Month=12, Predicted=13.7732, Expected=14.5160
# Month=13, Predicted=15.1621, Expected=14.3830
# Month=14, Predicted=14.2124, Expected=14.4970
# Month=15, Predicted=14.5339, Expected=14.7440
# Month=16, Predicted=14.8651, Expected=15.8060
# Month=17, Predicted=16.4164, Expected=16.5270
# Month=18, Predicted=16.8381, Expected=16.5460
# Month=19, Predicted=16.4031, Expected=16.7170
# Month=20, Predicted=16.7450, Expected=16.4330
# Month=21, Predicted=16.1826, Expected=15.7690
# Month=22, Predicted=15.3389, Expected=15.2750
# Month=23, Predicted=15.0126, Expected=15.1230
# Month=24, Predicted=15.1046, Expected=15.5410
# Month=25, Predicted=15.8573, Expected=15.8250
# Month=26, Predicted=15.9766, Expected=16.3760
# Month=27, Predicted=16.6722, Expected=16.3570
# Month=28, Predicted=16.2493, Expected=16.9070
# Month=29, Predicted=17.2065, Expected=17.0210
# Month=30, Predicted=17.0045, Expected=17.4190
# Month=31, Predicted=17.6122, Expected=17.5330
# Month=32, Predicted=17.5281, Expected=17.2680
# Month=33, Predicted=17.0364, Expected=16.6030
# Month=34, Predicted=16.1734, Expected=15.8250
# Month=35, Predicted=15.4031, Expected=15.4460
# Month=36, Predicted=15.3069, Expected=15.6360
# Month=37, Predicted=15.8473, Expected=15.6930
# Month=38, Predicted=15.7422, Expected=16.7550
# Month=39, Predicted=17.4073, Expected=16.5090
# Month=40, Predicted=16.2155, Expected=17.7230
# Month=41, Predicted=18.4298, Expected=18.6910
# Month=42, Predicted=19.1405, Expected=19.1270
# Month=43, Predicted=19.2210, Expected=19.5640
# Month=44, Predicted=19.7028, Expected=19.2030
# Month=45, Predicted=18.8441, Expected=18.2160
# Month=46, Predicted=17.7040, Expected=17.2110
# Month=47, Predicted=16.7500, Expected=16.6600
# Month=48, Predicted=16.4476, Expected=16.8310
# Month=49, Predicted=17.0687, Expected=15.7690
# Month=50, Predicted=15.2775, Expected=15.7310
# Month=51, Predicted=15.8280, Expected=15.9960
# Month=52, Predicted=16.2186, Expected=17.0210
# Month=53, Predicted=17.6461, Expected=17.5520
# Month=54, Predicted=17.7627, Expected=17.8370
# Month=55, Predicted=17.8923, Expected=17.8560
# Month=56, Predicted=17.7683, Expected=17.5710
# Month=57, Predicted=17.3266, Expected=17.0780
# Month=58, Predicted=16.7489, Expected=16.6600
# Month=59, Predicted=16.4317, Expected=16.4330
# Month=60, Predicted=16.3477, Expected=16.5840
# Run 8 — RMSE: 0.488886, MSE: 0.239009, NMSE: 0.0019224414
#
# ===== Attention(lag=1) RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2475, Expected=13.7000
# Month=2, Predicted=14.0351, Expected=13.8140
# Month=3, Predicted=13.8086, Expected=14.3830
# Month=4, Predicted=14.6858, Expected=15.0470
# Month=5, Predicted=15.3664, Expected=15.6930
# Month=6, Predicted=15.9786, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.5646, Expected=15.3130
# Month=9, Predicted=15.0439, Expected=14.7630
# Month=10, Predicted=14.4426, Expected=13.5480
# Month=11, Predicted=12.8170, Expected=13.5860
# Month=12, Predicted=13.7570, Expected=14.5160
# Month=13, Predicted=15.1086, Expected=14.3830
# Month=14, Predicted=14.1974, Expected=14.4970
# Month=15, Predicted=14.5424, Expected=14.7440
# Month=16, Predicted=14.8668, Expected=15.8060
# Month=17, Predicted=16.3978, Expected=16.5270
# Month=18, Predicted=16.8277, Expected=16.5460
# Month=19, Predicted=16.4225, Expected=16.7170
# Month=20, Predicted=16.7690, Expected=16.4330
# Month=21, Predicted=16.2061, Expected=15.7690
# Month=22, Predicted=15.3505, Expected=15.2750
# Month=23, Predicted=15.0292, Expected=15.1230
# Month=24, Predicted=15.0952, Expected=15.5410
# Month=25, Predicted=15.8268, Expected=15.8250
# Month=26, Predicted=15.9550, Expected=16.3760
# Month=27, Predicted=16.6590, Expected=16.3570
# Month=28, Predicted=16.2563, Expected=16.9070
# Month=29, Predicted=17.2090, Expected=17.0210
# Month=30, Predicted=17.0100, Expected=17.4190
# Month=31, Predicted=17.6165, Expected=17.5330
# Month=32, Predicted=17.5347, Expected=17.2680
# Month=33, Predicted=17.0554, Expected=16.6030
# Month=34, Predicted=16.1824, Expected=15.8250
# Month=35, Predicted=15.3933, Expected=15.4460
# Month=36, Predicted=15.3067, Expected=15.6360
# Month=37, Predicted=15.8182, Expected=15.6930
# Month=38, Predicted=15.7191, Expected=16.7550
# Month=39, Predicted=17.3739, Expected=16.5090
# Month=40, Predicted=16.2187, Expected=17.7230
# Month=41, Predicted=18.4236, Expected=18.6910
# Month=42, Predicted=19.1289, Expected=19.1270
# Month=43, Predicted=19.2327, Expected=19.5640
# Month=44, Predicted=19.7237, Expected=19.2030
# Month=45, Predicted=18.8779, Expected=18.2160
# Month=46, Predicted=17.5757, Expected=17.2110
# Month=47, Predicted=16.6646, Expected=16.6600
# Month=48, Predicted=16.4474, Expected=16.8310
# Month=49, Predicted=17.0322, Expected=15.7690
# Month=50, Predicted=15.0791, Expected=15.7310
# Month=51, Predicted=15.8200, Expected=15.9960
# Month=52, Predicted=16.1906, Expected=17.0210
# Month=53, Predicted=17.6090, Expected=17.5520
# Month=54, Predicted=17.7485, Expected=17.8370
# Month=55, Predicted=17.9041, Expected=17.8560
# Month=56, Predicted=17.7911, Expected=17.5710
# Month=57, Predicted=17.3539, Expected=17.0780
# Month=58, Predicted=16.7746, Expected=16.6600
# Month=59, Predicted=16.4445, Expected=16.4330
# Month=60, Predicted=16.3434, Expected=16.5840
# Run 9 — RMSE: 0.497263, MSE: 0.247271, NMSE: 0.0019549562
#
# ===== Attention(lag=1) RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2574, Expected=13.7000
# Month=2, Predicted=14.0422, Expected=13.8140
# Month=3, Predicted=13.8054, Expected=14.3830
# Month=4, Predicted=14.6794, Expected=15.0470
# Month=5, Predicted=15.3569, Expected=15.6930
# Month=6, Predicted=15.9639, Expected=15.8440
# Month=7, Predicted=15.8038, Expected=15.7120
# Month=8, Predicted=15.5509, Expected=15.3130
# Month=9, Predicted=15.0391, Expected=14.7630
# Month=10, Predicted=14.4469, Expected=13.5480
# Month=11, Predicted=12.8421, Expected=13.5860
# Month=12, Predicted=13.7756, Expected=14.5160
# Month=13, Predicted=15.1341, Expected=14.3830
# Month=14, Predicted=14.2000, Expected=14.4970
# Month=15, Predicted=14.5357, Expected=14.7440
# Month=16, Predicted=14.8618, Expected=15.8060
# Month=17, Predicted=16.3997, Expected=16.5270
# Month=18, Predicted=16.8135, Expected=16.5460
# Month=19, Predicted=16.4038, Expected=16.7170
# Month=20, Predicted=16.7516, Expected=16.4330
# Month=21, Predicted=16.1985, Expected=15.7690
# Month=22, Predicted=15.3534, Expected=15.2750
# Month=23, Predicted=15.0369, Expected=15.1230
# Month=24, Predicted=15.1074, Expected=15.5410
# Month=25, Predicted=15.8394, Expected=15.8250
# Month=26, Predicted=15.9577, Expected=16.3760
# Month=27, Predicted=16.6555, Expected=16.3570
# Month=28, Predicted=16.2481, Expected=16.9070
# Month=29, Predicted=17.2007, Expected=17.0210
# Month=30, Predicted=17.0004, Expected=17.4190
# Month=31, Predicted=17.6066, Expected=17.5330
# Month=32, Predicted=17.5253, Expected=17.2680
# Month=33, Predicted=17.0497, Expected=16.6030
# Month=34, Predicted=16.1862, Expected=15.8250
# Month=35, Predicted=15.4054, Expected=15.4460
# Month=36, Predicted=15.3219, Expected=15.6360
# Month=37, Predicted=15.8352, Expected=15.6930
# Month=38, Predicted=15.7286, Expected=16.7550
# Month=39, Predicted=17.3855, Expected=16.5090
# Month=40, Predicted=16.2146, Expected=17.7230
# Month=41, Predicted=18.4239, Expected=18.6910
# Month=42, Predicted=19.1138, Expected=19.1270
# Month=43, Predicted=19.2078, Expected=19.5640
# Month=44, Predicted=19.6994, Expected=19.2030
# Month=45, Predicted=18.8644, Expected=18.2160
# Month=46, Predicted=17.5798, Expected=17.2110
# Month=47, Predicted=16.6785, Expected=16.6600
# Month=48, Predicted=16.4675, Expected=16.8310
# Month=49, Predicted=17.0553, Expected=15.7690
# Month=50, Predicted=15.1104, Expected=15.7310
# Month=51, Predicted=15.8338, Expected=15.9960
# Month=52, Predicted=16.2046, Expected=17.0210
# Month=53, Predicted=17.6215, Expected=17.5520
# Month=54, Predicted=17.7388, Expected=17.8370
# Month=55, Predicted=17.8870, Expected=17.8560
# Month=56, Predicted=17.7760, Expected=17.5710
# Month=57, Predicted=17.3459, Expected=17.0780
# Month=58, Predicted=16.7754, Expected=16.6600
# Month=59, Predicted=16.4511, Expected=16.4330
# Month=60, Predicted=16.3537, Expected=16.5840
# Run 10 — RMSE: 0.495694, MSE: 0.245713, NMSE: 0.0019603085
#
# ===== Attention(lag=1) RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.2464, Expected=13.7000
# Month=2, Predicted=14.0410, Expected=13.8140
# Month=3, Predicted=13.8373, Expected=14.3830
# Month=4, Predicted=14.6844, Expected=15.0470
# Month=5, Predicted=15.3748, Expected=15.6930
# Month=6, Predicted=15.9892, Expected=15.8440
# Month=7, Predicted=15.8384, Expected=15.7120
# Month=8, Predicted=15.5645, Expected=15.3130
# Month=9, Predicted=15.0355, Expected=14.7630
# Month=10, Predicted=14.4289, Expected=13.5480
# Month=11, Predicted=12.8068, Expected=13.5860
# Month=12, Predicted=13.7168, Expected=14.5160
# Month=13, Predicted=15.1052, Expected=14.3830
# Month=14, Predicted=14.2505, Expected=14.4970
# Month=15, Predicted=14.5441, Expected=14.7440
# Month=16, Predicted=14.8687, Expected=15.8060
# Month=17, Predicted=16.3874, Expected=16.5270
# Month=18, Predicted=16.8520, Expected=16.5460
# Month=19, Predicted=16.4468, Expected=16.7170
# Month=20, Predicted=16.7578, Expected=16.4330
# Month=21, Predicted=16.2074, Expected=15.7690
# Month=22, Predicted=15.3414, Expected=15.2750
# Month=23, Predicted=15.0072, Expected=15.1230
# Month=24, Predicted=15.0837, Expected=15.5410
# Month=25, Predicted=15.8255, Expected=15.8250
# Month=26, Predicted=15.9778, Expected=16.3760
# Month=27, Predicted=16.6683, Expected=16.3570
# Month=28, Predicted=16.2809, Expected=16.9070
# Month=29, Predicted=17.1981, Expected=17.0210
# Month=30, Predicted=17.0262, Expected=17.4190
# Month=31, Predicted=17.6120, Expected=17.5330
# Month=32, Predicted=17.5449, Expected=17.2680
# Month=33, Predicted=17.0610, Expected=16.6030
# Month=34, Predicted=16.1767, Expected=15.8250
# Month=35, Predicted=15.3744, Expected=15.4460
# Month=36, Predicted=15.2866, Expected=15.6360
# Month=37, Predicted=15.8137, Expected=15.6930
# Month=38, Predicted=15.7411, Expected=16.7550
# Month=39, Predicted=17.3677, Expected=16.5090
# Month=40, Predicted=16.2701, Expected=17.7230
# Month=41, Predicted=18.3911, Expected=18.6910
# Month=42, Predicted=19.1463, Expected=19.1270
# Month=43, Predicted=19.2560, Expected=19.5640
# Month=44, Predicted=19.7218, Expected=19.2030
# Month=45, Predicted=18.8869, Expected=18.2160
# Month=46, Predicted=17.5584, Expected=17.2110
# Month=47, Predicted=16.6246, Expected=16.6600
# Month=48, Predicted=16.4167, Expected=16.8310
# Month=49, Predicted=17.0235, Expected=15.7690
# Month=50, Predicted=15.1184, Expected=15.7310
# Month=51, Predicted=15.7956, Expected=15.9960
# Month=52, Predicted=16.1989, Expected=17.0210
# Month=53, Predicted=17.6129, Expected=17.5520
# Month=54, Predicted=17.7851, Expected=17.8370
# Month=55, Predicted=17.9215, Expected=17.8560
# Month=56, Predicted=17.7964, Expected=17.5710
# Month=57, Predicted=17.3514, Expected=17.0780
# Month=58, Predicted=16.7643, Expected=16.6600
# Month=59, Predicted=16.4296, Expected=16.4330
# Month=60, Predicted=16.3357, Expected=16.5840
# Run 11 — RMSE: 0.492198, MSE: 0.242259, NMSE: 0.0019115272
#
# ===== Attention(lag=1) RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2762, Expected=13.7000
# Month=2, Predicted=14.0649, Expected=13.8140
# Month=3, Predicted=13.8342, Expected=14.3830
# Month=4, Predicted=14.6674, Expected=15.0470
# Month=5, Predicted=15.3415, Expected=15.6930
# Month=6, Predicted=15.9362, Expected=15.8440
# Month=7, Predicted=15.7692, Expected=15.7120
# Month=8, Predicted=15.5010, Expected=15.3130
# Month=9, Predicted=14.9942, Expected=14.7630
# Month=10, Predicted=14.4168, Expected=13.5480
# Month=11, Predicted=12.8369, Expected=13.5860
# Month=12, Predicted=13.7660, Expected=14.5160
# Month=13, Predicted=15.1692, Expected=14.3830
# Month=14, Predicted=14.2698, Expected=14.4970
# Month=15, Predicted=14.5414, Expected=14.7440
# Month=16, Predicted=14.8572, Expected=15.8060
# Month=17, Predicted=16.3755, Expected=16.5270
# Month=18, Predicted=16.8057, Expected=16.5460
# Month=19, Predicted=16.3747, Expected=16.7170
# Month=20, Predicted=16.6901, Expected=16.4330
# Month=21, Predicted=16.1562, Expected=15.7690
# Month=22, Predicted=15.3186, Expected=15.2750
# Month=23, Predicted=15.0133, Expected=15.1230
# Month=24, Predicted=15.1113, Expected=15.5410
# Month=25, Predicted=15.8606, Expected=15.8250
# Month=26, Predicted=15.9947, Expected=16.3760
# Month=27, Predicted=16.6650, Expected=16.3570
# Month=28, Predicted=16.2540, Expected=16.9070
# Month=29, Predicted=17.1673, Expected=17.0210
# Month=30, Predicted=16.9860, Expected=17.4190
# Month=31, Predicted=17.5714, Expected=17.5330
# Month=32, Predicted=17.5022, Expected=17.2680
# Month=33, Predicted=17.0245, Expected=16.6030
# Month=34, Predicted=16.1619, Expected=15.8250
# Month=35, Predicted=15.3891, Expected=15.4460
# Month=36, Predicted=15.3243, Expected=15.6360
# Month=37, Predicted=15.8631, Expected=15.6930
# Month=38, Predicted=15.7788, Expected=16.7550
# Month=39, Predicted=17.3971, Expected=16.5090
# Month=40, Predicted=16.2533, Expected=17.7230
# Month=41, Predicted=18.3731, Expected=18.6910
# Month=42, Predicted=19.0955, Expected=19.1270
# Month=43, Predicted=19.1694, Expected=19.5640
# Month=44, Predicted=19.6288, Expected=19.2030
# Month=45, Predicted=18.8055, Expected=18.2160
# Month=46, Predicted=17.5192, Expected=17.2110
# Month=47, Predicted=16.6334, Expected=16.6600
# Month=48, Predicted=16.4615, Expected=16.8310
# Month=49, Predicted=17.0878, Expected=15.7690
# Month=50, Predicted=15.1858, Expected=15.7310
# Month=51, Predicted=15.8562, Expected=15.9960
# Month=52, Predicted=16.2539, Expected=17.0210
# Month=53, Predicted=17.6527, Expected=17.5520
# Month=54, Predicted=17.7717, Expected=17.8370
# Month=55, Predicted=17.8737, Expected=17.8560
# Month=56, Predicted=17.7394, Expected=17.5710
# Month=57, Predicted=17.3052, Expected=17.0780
# Month=58, Predicted=16.7417, Expected=16.6600
# Month=59, Predicted=16.4322, Expected=16.4330
# Month=60, Predicted=16.3570, Expected=16.5840
# Run 12 — RMSE: 0.484689, MSE: 0.234924, NMSE: 0.0019086949
#
# ===== Attention(lag=1) RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2646, Expected=13.7000
# Month=2, Predicted=14.0521, Expected=13.8140
# Month=3, Predicted=13.8186, Expected=14.3830
# Month=4, Predicted=14.6779, Expected=15.0470
# Month=5, Predicted=15.3543, Expected=15.6930
# Month=6, Predicted=15.9580, Expected=15.8440
# Month=7, Predicted=15.7950, Expected=15.7120
# Month=8, Predicted=15.5309, Expected=15.3130
# Month=9, Predicted=15.0143, Expected=14.7630
# Month=10, Predicted=14.4239, Expected=13.5480
# Month=11, Predicted=12.8121, Expected=13.5860
# Month=12, Predicted=13.7755, Expected=14.5160
# Month=13, Predicted=15.1475, Expected=14.3830
# Month=14, Predicted=14.2285, Expected=14.4970
# Month=15, Predicted=14.5420, Expected=14.7440
# Month=16, Predicted=14.8630, Expected=15.8060
# Month=17, Predicted=16.3891, Expected=16.5270
# Month=18, Predicted=16.8164, Expected=16.5460
# Month=19, Predicted=16.3984, Expected=16.7170
# Month=20, Predicted=16.7307, Expected=16.4330
# Month=21, Predicted=16.1773, Expected=15.7690
# Month=22, Predicted=15.3265, Expected=15.2750
# Month=23, Predicted=15.0185, Expected=15.1230
# Month=24, Predicted=15.1056, Expected=15.5410
# Month=25, Predicted=15.8482, Expected=15.8250
# Month=26, Predicted=15.9736, Expected=16.3760
# Month=27, Predicted=16.6622, Expected=16.3570
# Month=28, Predicted=16.2523, Expected=16.9070
# Month=29, Predicted=17.1904, Expected=17.0210
# Month=30, Predicted=16.9963, Expected=17.4190
# Month=31, Predicted=17.5947, Expected=17.5330
# Month=32, Predicted=17.5166, Expected=17.2680
# Month=33, Predicted=17.0353, Expected=16.6030
# Month=34, Predicted=16.1638, Expected=15.8250
# Month=35, Predicted=15.3844, Expected=15.4460
# Month=36, Predicted=15.3185, Expected=15.6360
# Month=37, Predicted=15.8480, Expected=15.6930
# Month=38, Predicted=15.7493, Expected=16.7550
# Month=39, Predicted=17.3893, Expected=16.5090
# Month=40, Predicted=16.2315, Expected=17.7230
# Month=41, Predicted=18.4029, Expected=18.6910
# Month=42, Predicted=19.1123, Expected=19.1270
# Month=43, Predicted=19.2040, Expected=19.5640
# Month=44, Predicted=19.6798, Expected=19.2030
# Month=45, Predicted=18.8389, Expected=18.2160
# Month=46, Predicted=17.5352, Expected=17.2110
# Month=47, Predicted=16.6402, Expected=16.6600
# Month=48, Predicted=16.4588, Expected=16.8310
# Month=49, Predicted=17.0712, Expected=15.7690
# Month=50, Predicted=15.1205, Expected=15.7310
# Month=51, Predicted=15.8488, Expected=15.9960
# Month=52, Predicted=16.2292, Expected=17.0210
# Month=53, Predicted=17.6353, Expected=17.5520
# Month=54, Predicted=17.7602, Expected=17.8370
# Month=55, Predicted=17.8905, Expected=17.8560
# Month=56, Predicted=17.7659, Expected=17.5710
# Month=57, Predicted=17.3272, Expected=17.0780
# Month=58, Predicted=16.7536, Expected=16.6600
# Month=59, Predicted=16.4361, Expected=16.4330
# Month=60, Predicted=16.3508, Expected=16.5840
# Run 13 — RMSE: 0.490993, MSE: 0.241074, NMSE: 0.0019304876
#
# ===== Attention(lag=1) RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2735, Expected=13.7000
# Month=2, Predicted=14.0593, Expected=13.8140
# Month=3, Predicted=13.8145, Expected=14.3830
# Month=4, Predicted=14.6756, Expected=15.0470
# Month=5, Predicted=15.3497, Expected=15.6930
# Month=6, Predicted=15.9490, Expected=15.8440
# Month=7, Predicted=15.7798, Expected=15.7120
# Month=8, Predicted=15.5207, Expected=15.3130
# Month=9, Predicted=15.0130, Expected=14.7630
# Month=10, Predicted=14.4313, Expected=13.5480
# Month=11, Predicted=12.8338, Expected=13.5860
# Month=12, Predicted=13.7906, Expected=14.5160
# Month=13, Predicted=15.1666, Expected=14.3830
# Month=14, Predicted=14.2248, Expected=14.4970
# Month=15, Predicted=14.5370, Expected=14.7440
# Month=16, Predicted=14.8600, Expected=15.8060
# Month=17, Predicted=16.3948, Expected=16.5270
# Month=18, Predicted=16.8066, Expected=16.5460
# Month=19, Predicted=16.3786, Expected=16.7170
# Month=20, Predicted=16.7198, Expected=16.4330
# Month=21, Predicted=16.1721, Expected=15.7690
# Month=22, Predicted=15.3310, Expected=15.2750
# Month=23, Predicted=15.0294, Expected=15.1230
# Month=24, Predicted=15.1180, Expected=15.5410
# Month=25, Predicted=15.8595, Expected=15.8250
# Month=26, Predicted=15.9764, Expected=16.3760
# Month=27, Predicted=16.6617, Expected=16.3570
# Month=28, Predicted=16.2433, Expected=16.9070
# Month=29, Predicted=17.1876, Expected=17.0210
# Month=30, Predicted=16.9885, Expected=17.4190
# Month=31, Predicted=17.5904, Expected=17.5330
# Month=32, Predicted=17.5104, Expected=17.2680
# Month=33, Predicted=17.0312, Expected=16.6030
# Month=34, Predicted=16.1681, Expected=15.8250
# Month=35, Predicted=15.3974, Expected=15.4460
# Month=36, Predicted=15.3329, Expected=15.6360
# Month=37, Predicted=15.8610, Expected=15.6930
# Month=38, Predicted=15.7553, Expected=16.7550
# Month=39, Predicted=17.4002, Expected=16.5090
# Month=40, Predicted=16.2181, Expected=17.7230
# Month=41, Predicted=18.4075, Expected=18.6910
# Month=42, Predicted=19.1037, Expected=19.1270
# Month=43, Predicted=19.1818, Expected=19.5640
# Month=44, Predicted=19.6627, Expected=19.2030
# Month=45, Predicted=18.8254, Expected=18.2160
# Month=46, Predicted=17.5402, Expected=17.2110
# Month=47, Predicted=16.6593, Expected=16.6600
# Month=48, Predicted=16.4792, Expected=16.8310
# Month=49, Predicted=17.0885, Expected=15.7690
# Month=50, Predicted=15.1380, Expected=15.7310
# Month=51, Predicted=15.8582, Expected=15.9960
# Month=52, Predicted=16.2378, Expected=17.0210
# Month=53, Predicted=17.6457, Expected=17.5520
# Month=54, Predicted=17.7498, Expected=17.8370
# Month=55, Predicted=17.8735, Expected=17.8560
# Month=56, Predicted=17.7509, Expected=17.5710
# Month=57, Predicted=17.3189, Expected=17.0780
# Month=58, Predicted=16.7541, Expected=16.6600
# Month=59, Predicted=16.4429, Expected=16.4330
# Month=60, Predicted=16.3596, Expected=16.5840
# Run 14 — RMSE: 0.490928, MSE: 0.241010, NMSE: 0.0019439493
#
# ===== Attention(lag=1) RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.2548, Expected=13.7000
# Month=2, Predicted=14.0446, Expected=13.8140
# Month=3, Predicted=13.8246, Expected=14.3830
# Month=4, Predicted=14.6829, Expected=15.0470
# Month=5, Predicted=15.3672, Expected=15.6930
# Month=6, Predicted=15.9776, Expected=15.8440
# Month=7, Predicted=15.8197, Expected=15.7120
# Month=8, Predicted=15.5528, Expected=15.3130
# Month=9, Predicted=15.0307, Expected=14.7630
# Month=10, Predicted=14.4320, Expected=13.5480
# Month=11, Predicted=12.8087, Expected=13.5860
# Month=12, Predicted=13.7517, Expected=14.5160
# Month=13, Predicted=15.1224, Expected=14.3830
# Month=14, Predicted=14.2324, Expected=14.4970
# Month=15, Predicted=14.5434, Expected=14.7440
# Month=16, Predicted=14.8672, Expected=15.8060
# Month=17, Predicted=16.3909, Expected=16.5270
# Month=18, Predicted=16.8372, Expected=16.5460
# Month=19, Predicted=16.4239, Expected=16.7170
# Month=20, Predicted=16.7524, Expected=16.4330
# Month=21, Predicted=16.1973, Expected=15.7690
# Month=22, Predicted=15.3383, Expected=15.2750
# Month=23, Predicted=15.0195, Expected=15.1230
# Month=24, Predicted=15.0977, Expected=15.5410
# Month=25, Predicted=15.8359, Expected=15.8250
# Month=26, Predicted=15.9726, Expected=16.3760
# Month=27, Predicted=16.6647, Expected=16.3570
# Month=28, Predicted=16.2645, Expected=16.9070
# Month=29, Predicted=17.1989, Expected=17.0210
# Month=30, Predicted=17.0131, Expected=17.4190
# Month=31, Predicted=17.6088, Expected=17.5330
# Month=32, Predicted=17.5341, Expected=17.2680
# Month=33, Predicted=17.0507, Expected=16.6030
# Month=34, Predicted=16.1726, Expected=15.8250
# Month=35, Predicted=15.3832, Expected=15.4460
# Month=36, Predicted=15.3058, Expected=15.6360
# Month=37, Predicted=15.8290, Expected=15.6930
# Month=38, Predicted=15.7397, Expected=16.7550
# Month=39, Predicted=17.3754, Expected=16.5090
# Month=40, Predicted=16.2435, Expected=17.7230
# Month=41, Predicted=18.4023, Expected=18.6910
# Month=42, Predicted=19.1349, Expected=19.1270
# Month=43, Predicted=19.2347, Expected=19.5640
# Month=44, Predicted=19.7093, Expected=19.2030
# Month=45, Predicted=18.8668, Expected=18.2160
# Month=46, Predicted=17.5520, Expected=17.2110
# Month=47, Predicted=16.6431, Expected=16.6600
# Month=48, Predicted=16.4450, Expected=16.8310
# Month=49, Predicted=17.0459, Expected=15.7690
# Month=50, Predicted=15.1053, Expected=15.7310
# Month=51, Predicted=15.8207, Expected=15.9960
# Month=52, Predicted=16.2080, Expected=17.0210
# Month=53, Predicted=17.6187, Expected=17.5520
# Month=54, Predicted=17.7696, Expected=17.8370
# Month=55, Predicted=17.9064, Expected=17.8560
# Month=56, Predicted=17.7840, Expected=17.5710
# Month=57, Predicted=17.3432, Expected=17.0780
# Month=58, Predicted=16.7636, Expected=16.6600
# Month=59, Predicted=16.4378, Expected=16.4330
# Month=60, Predicted=16.3454, Expected=16.5840
# Run 15 — RMSE: 0.492726, MSE: 0.242779, NMSE: 0.0019267673
#
# ===== Attention(lag=1) RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.2649, Expected=13.7000
# Month=2, Predicted=14.0551, Expected=13.8140
# Month=3, Predicted=13.8234, Expected=14.3830
# Month=4, Predicted=14.6798, Expected=15.0470
# Month=5, Predicted=15.3607, Expected=15.6930
# Month=6, Predicted=15.9655, Expected=15.8440
# Month=7, Predicted=15.7990, Expected=15.7120
# Month=8, Predicted=15.5296, Expected=15.3130
# Month=9, Predicted=15.0100, Expected=14.7630
# Month=10, Predicted=14.4181, Expected=13.5480
# Month=11, Predicted=12.8274, Expected=13.5860
# Month=12, Predicted=13.7651, Expected=14.5160
# Month=13, Predicted=15.1452, Expected=14.3830
# Month=14, Predicted=14.2343, Expected=14.4970
# Month=15, Predicted=14.5392, Expected=14.7440
# Month=16, Predicted=14.8635, Expected=15.8060
# Month=17, Predicted=16.3907, Expected=16.5270
# Month=18, Predicted=16.8270, Expected=16.5460
# Month=19, Predicted=16.3998, Expected=16.7170
# Month=20, Predicted=16.7310, Expected=16.4330
# Month=21, Predicted=16.1760, Expected=15.7690
# Month=22, Predicted=15.3230, Expected=15.2750
# Month=23, Predicted=15.0122, Expected=15.1230
# Month=24, Predicted=15.1039, Expected=15.5410
# Month=25, Predicted=15.8496, Expected=15.8250
# Month=26, Predicted=15.9794, Expected=16.3760
# Month=27, Predicted=16.6659, Expected=16.3570
# Month=28, Predicted=16.2542, Expected=16.9070
# Month=29, Predicted=17.1916, Expected=17.0210
# Month=30, Predicted=17.0008, Expected=17.4190
# Month=31, Predicted=17.5983, Expected=17.5330
# Month=32, Predicted=17.5211, Expected=17.2680
# Month=33, Predicted=17.0341, Expected=16.6030
# Month=34, Predicted=16.1597, Expected=15.8250
# Month=35, Predicted=15.3840, Expected=15.4460
# Month=36, Predicted=15.3119, Expected=15.6360
# Month=37, Predicted=15.8464, Expected=15.6930
# Month=38, Predicted=15.7522, Expected=16.7550
# Month=39, Predicted=17.3868, Expected=16.5090
# Month=40, Predicted=16.2327, Expected=17.7230
# Month=41, Predicted=18.3973, Expected=18.6910
# Month=42, Predicted=19.1234, Expected=19.1270
# Month=43, Predicted=19.2107, Expected=19.5640
# Month=44, Predicted=19.6839, Expected=19.2030
# Month=45, Predicted=18.8350, Expected=18.2160
# Month=46, Predicted=17.5384, Expected=17.2110
# Month=47, Predicted=16.6467, Expected=16.6600
# Month=48, Predicted=16.4525, Expected=16.8310
# Month=49, Predicted=17.0682, Expected=15.7690
# Month=50, Predicted=15.1337, Expected=15.7310
# Month=51, Predicted=15.8368, Expected=15.9960
# Month=52, Predicted=16.2273, Expected=17.0210
# Month=53, Predicted=17.6336, Expected=17.5520
# Month=54, Predicted=17.7675, Expected=17.8370
# Month=55, Predicted=17.8919, Expected=17.8560
# Month=56, Predicted=17.7644, Expected=17.5710
# Month=57, Predicted=17.3230, Expected=17.0780
# Month=58, Predicted=16.7473, Expected=16.6600
# Month=59, Predicted=16.4313, Expected=16.4330
# Month=60, Predicted=16.3488, Expected=16.5840
# Run 16 — RMSE: 0.489889, MSE: 0.239991, NMSE: 0.0019210190
#
# ===== Attention(lag=1) RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.2623, Expected=13.7000
# Month=2, Predicted=14.0553, Expected=13.8140
# Month=3, Predicted=13.8129, Expected=14.3830
# Month=4, Predicted=14.6724, Expected=15.0470
# Month=5, Predicted=15.3468, Expected=15.6930
# Month=6, Predicted=15.9427, Expected=15.8440
# Month=7, Predicted=15.7665, Expected=15.7120
# Month=8, Predicted=15.4995, Expected=15.3130
# Month=9, Predicted=14.9865, Expected=14.7630
# Month=10, Predicted=14.4020, Expected=13.5480
# Month=11, Predicted=12.8695, Expected=13.5860
# Month=12, Predicted=13.7663, Expected=14.5160
# Month=13, Predicted=15.1587, Expected=14.3830
# Month=14, Predicted=14.2258, Expected=14.4970
# Month=15, Predicted=14.5340, Expected=14.7440
# Month=16, Predicted=14.8582, Expected=15.8060
# Month=17, Predicted=16.3938, Expected=16.5270
# Month=18, Predicted=16.8073, Expected=16.5460
# Month=19, Predicted=16.3681, Expected=16.7170
# Month=20, Predicted=16.7028, Expected=16.4330
# Month=21, Predicted=16.1496, Expected=15.7690
# Month=22, Predicted=15.3147, Expected=15.2750
# Month=23, Predicted=15.0008, Expected=15.1230
# Month=24, Predicted=15.0956, Expected=15.5410
# Month=25, Predicted=15.8462, Expected=15.8250
# Month=26, Predicted=15.9704, Expected=16.3760
# Month=27, Predicted=16.6567, Expected=16.3570
# Month=28, Predicted=16.2362, Expected=16.9070
# Month=29, Predicted=17.1789, Expected=17.0210
# Month=30, Predicted=16.9791, Expected=17.4190
# Month=31, Predicted=17.5778, Expected=17.5330
# Month=32, Predicted=17.4956, Expected=17.2680
# Month=33, Predicted=17.0105, Expected=16.6030
# Month=34, Predicted=16.1541, Expected=15.8250
# Month=35, Predicted=15.3883, Expected=15.4460
# Month=36, Predicted=15.3108, Expected=15.6360
# Month=37, Predicted=15.8501, Expected=15.6930
# Month=38, Predicted=15.7536, Expected=16.7550
# Month=39, Predicted=17.4022, Expected=16.5090
# Month=40, Predicted=16.2218, Expected=17.7230
# Month=41, Predicted=18.4067, Expected=18.6910
# ...
# Month=28, Predicted=16.2489, Expected=16.9070
# Month=29, Predicted=17.2065, Expected=17.0210
# Month=30, Predicted=17.0005, Expected=17.4190
# Month=31, Predicted=17.6104, Expected=17.5330
# Month=32, Predicted=17.5261, Expected=17.2680
# Month=33, Predicted=17.0516, Expected=16.6030
# Month=34, Predicted=16.1877, Expected=15.8250
# Month=35, Predicted=15.4045, Expected=15.4460
# Month=36, Predicted=15.3187, Expected=15.6360
# Month=37, Predicted=15.8312, Expected=15.6930
# Month=38, Predicted=15.7237, Expected=16.7550
# Month=39, Predicted=17.3884, Expected=16.5090
# Month=40, Predicted=16.2109, Expected=17.7230
# Month=41, Predicted=18.4341, Expected=18.6910
# Month=42, Predicted=19.1115, Expected=19.1270
# Month=43, Predicted=19.2101, Expected=19.5640
# Month=44, Predicted=19.7062, Expected=19.2030
# Month=45, Predicted=18.8686, Expected=18.2160
# Month=46, Predicted=17.5840, Expected=17.2110
# Month=47, Predicted=16.6780, Expected=16.6600
# Month=48, Predicted=16.4619, Expected=16.8310
# Month=49, Predicted=17.0494, Expected=15.7690
# Month=50, Predicted=15.1006, Expected=15.7310
# Month=51, Predicted=15.8359, Expected=15.9960
# Month=52, Predicted=16.2013, Expected=17.0210
# Month=53, Predicted=17.6221, Expected=17.5520
# Month=54, Predicted=17.7365, Expected=17.8370
# Month=55, Predicted=17.8919, Expected=17.8560
# Month=56, Predicted=17.7818, Expected=17.5710
# Month=57, Predicted=17.3502, Expected=17.0780
# Month=58, Predicted=16.7773, Expected=16.6600
# Month=59, Predicted=16.4505, Expected=16.4330
# Month=60, Predicted=16.3510, Expected=16.5840
# Run 25 — RMSE: 0.496790, MSE: 0.246800, NMSE: 0.0019646098
#
# ===== Attention(lag=1) RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.2536, Expected=13.7000
# Month=2, Predicted=14.0394, Expected=13.8140
# Month=3, Predicted=13.8031, Expected=14.3830
# Month=4, Predicted=14.6813, Expected=15.0470
# Month=5, Predicted=15.3607, Expected=15.6930
# Month=6, Predicted=15.9693, Expected=15.8440
# Month=7, Predicted=15.8086, Expected=15.7120
# Month=8, Predicted=15.5568, Expected=15.3130
# Month=9, Predicted=15.0438, Expected=14.7630
# Month=10, Predicted=14.4490, Expected=13.5480
# Month=11, Predicted=12.8395, Expected=13.5860
# Month=12, Predicted=13.7684, Expected=14.5160
# Month=13, Predicted=15.1270, Expected=14.3830
# Month=14, Predicted=14.1927, Expected=14.4970
# Month=15, Predicted=14.5350, Expected=14.7440
# Month=16, Predicted=14.8630, Expected=15.8060
# Month=17, Predicted=16.4030, Expected=16.5270
# Month=18, Predicted=16.8175, Expected=16.5460
# Month=19, Predicted=16.4072, Expected=16.7170
# Month=20, Predicted=16.7594, Expected=16.4330
# Month=21, Predicted=16.2036, Expected=15.7690
# Month=22, Predicted=15.3562, Expected=15.2750
# Month=23, Predicted=15.0374, Expected=15.1230
# Month=24, Predicted=15.1044, Expected=15.5410
# Month=25, Predicted=15.8351, Expected=15.8250
# Month=26, Predicted=15.9545, Expected=16.3760
# Month=27, Predicted=16.6553, Expected=16.3570
# Month=28, Predicted=16.2479, Expected=16.9070
# Month=29, Predicted=17.2048, Expected=17.0210
# Month=30, Predicted=17.0033, Expected=17.4190
# Month=31, Predicted=17.6114, Expected=17.5330
# Month=32, Predicted=17.5289, Expected=17.2680
# Month=33, Predicted=17.0523, Expected=16.6030
# Month=34, Predicted=16.1875, Expected=15.8250
# Month=35, Predicted=15.4047, Expected=15.4460
# Month=36, Predicted=15.3179, Expected=15.6360
# Month=37, Predicted=15.8289, Expected=15.6930
# Month=38, Predicted=15.7228, Expected=16.7550
# Month=39, Predicted=17.3826, Expected=16.5090
# Month=40, Predicted=16.2093, Expected=17.7230
# Month=41, Predicted=18.4279, Expected=18.6910
# Month=42, Predicted=19.1201, Expected=19.1270
# Month=43, Predicted=19.2140, Expected=19.5640
# Month=44, Predicted=19.7094, Expected=19.2030
# Month=45, Predicted=18.8707, Expected=18.2160
# Month=46, Predicted=17.5846, Expected=17.2110
# Month=47, Predicted=16.6808, Expected=16.6600
# Month=48, Predicted=16.4635, Expected=16.8310
# Month=49, Predicted=17.0470, Expected=15.7690
# Month=50, Predicted=15.0989, Expected=15.7310
# Month=51, Predicted=15.8252, Expected=15.9960
# Month=52, Predicted=16.1977, Expected=17.0210
# Month=53, Predicted=17.6177, Expected=17.5520
# Month=54, Predicted=17.7374, Expected=17.8370
# Month=55, Predicted=17.8896, Expected=17.8560
# Month=56, Predicted=17.7807, Expected=17.5710
# Month=57, Predicted=17.3504, Expected=17.0780
# Month=58, Predicted=16.7782, Expected=16.6600
# Month=59, Predicted=16.4515, Expected=16.4330
# Month=60, Predicted=16.3513, Expected=16.5840
# Run 26 — RMSE: 0.497266, MSE: 0.247274, NMSE: 0.0019662136
#
# ===== Attention(lag=1) RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.2694, Expected=13.7000
# Month=2, Predicted=14.0598, Expected=13.8140
# Month=3, Predicted=13.8314, Expected=14.3830
# Month=4, Predicted=14.6720, Expected=15.0470
# Month=5, Predicted=15.3556, Expected=15.6930
# Month=6, Predicted=15.9586, Expected=15.8440
# Month=7, Predicted=15.7917, Expected=15.7120
# Month=8, Predicted=15.5145, Expected=15.3130
# Month=9, Predicted=14.9948, Expected=14.7630
# Month=10, Predicted=14.4066, Expected=13.5480
# Month=11, Predicted=12.7911, Expected=13.5860
# Month=12, Predicted=13.7600, Expected=14.5160
# Month=13, Predicted=15.1571, Expected=14.3830
# Month=14, Predicted=14.2583, Expected=14.4970
# Month=15, Predicted=14.5339, Expected=14.7440
# Month=16, Predicted=14.8586, Expected=15.8060
# Month=17, Predicted=16.3808, Expected=16.5270
# Month=18, Predicted=16.8277, Expected=16.5460
# Month=19, Predicted=16.3947, Expected=16.7170
# Month=20, Predicted=16.7116, Expected=16.4330
# Month=21, Predicted=16.1641, Expected=15.7690
# Month=22, Predicted=15.3055, Expected=15.2750
# Month=23, Predicted=15.0019, Expected=15.1230
# Month=24, Predicted=15.1054, Expected=15.5410
# Month=25, Predicted=15.8557, Expected=15.8250
# Month=26, Predicted=15.9900, Expected=16.3760
# Month=27, Predicted=16.6650, Expected=16.3570
# Month=28, Predicted=16.2552, Expected=16.9070
# Month=29, Predicted=17.1778, Expected=17.0210
# Month=30, Predicted=16.9979, Expected=17.4190
# Month=31, Predicted=17.5866, Expected=17.5330
# Month=32, Predicted=17.5152, Expected=17.2680
# Month=33, Predicted=17.0254, Expected=16.6030
# Month=34, Predicted=16.1443, Expected=15.8250
# Month=35, Predicted=15.3643, Expected=15.4460
# Month=36, Predicted=15.3122, Expected=15.6360
# Month=37, Predicted=15.8567, Expected=15.6930
# Month=38, Predicted=15.7687, Expected=16.7550
# Month=39, Predicted=17.3848, Expected=16.5090
# Month=40, Predicted=16.2470, Expected=17.7230
# Month=41, Predicted=18.3749, Expected=18.6910
# Month=42, Predicted=19.1208, Expected=19.1270
# Month=43, Predicted=19.2053, Expected=19.5640
# Month=44, Predicted=19.6666, Expected=19.2030
# Month=45, Predicted=18.8210, Expected=18.2160
# Month=46, Predicted=17.4957, Expected=17.2110
# Month=47, Predicted=16.6051, Expected=16.6600
# Month=48, Predicted=16.4509, Expected=16.8310
# Month=49, Predicted=17.0828, Expected=15.7690
# Month=50, Predicted=15.1395, Expected=15.7310
# Month=51, Predicted=15.8361, Expected=15.9960
# Month=52, Predicted=16.2423, Expected=17.0210
# Month=53, Predicted=17.6396, Expected=17.5520
# Month=54, Predicted=17.7785, Expected=17.8370
# Month=55, Predicted=17.8883, Expected=17.8560
# Month=56, Predicted=17.7541, Expected=17.5710
# Month=57, Predicted=17.3108, Expected=17.0780
# Month=58, Predicted=16.7359, Expected=16.6600
# Month=59, Predicted=16.4246, Expected=16.4330
# Month=60, Predicted=16.3503, Expected=16.5840
# Run 27 — RMSE: 0.487846, MSE: 0.237994, NMSE: 0.0019096248
#
# ===== Attention(lag=1) RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.2646, Expected=13.7000
# Month=2, Predicted=14.0532, Expected=13.8140
# Month=3, Predicted=13.8214, Expected=14.3830
# Month=4, Predicted=14.6769, Expected=15.0470
# Month=5, Predicted=15.3534, Expected=15.6930
# Month=6, Predicted=15.9550, Expected=15.8440
# Month=7, Predicted=15.7894, Expected=15.7120
# Month=8, Predicted=15.5236, Expected=15.3130
# Month=9, Predicted=15.0074, Expected=14.7630
# Month=10, Predicted=14.4182, Expected=13.5480
# Month=11, Predicted=12.8052, Expected=13.5860
# Month=12, Predicted=13.7673, Expected=14.5160
# Month=13, Predicted=15.1453, Expected=14.3830
# Month=14, Predicted=14.2342, Expected=14.4970
# Month=15, Predicted=14.5428, Expected=14.7440
# Month=16, Predicted=14.8647, Expected=15.8060
# Month=17, Predicted=16.3868, Expected=16.5270
# Month=18, Predicted=16.8159, Expected=16.5460
# Month=19, Predicted=16.3922, Expected=16.7170
# Month=20, Predicted=16.7239, Expected=16.4330
# Month=21, Predicted=16.1713, Expected=15.7690
# Month=22, Predicted=15.3196, Expected=15.2750
# Month=23, Predicted=15.0131, Expected=15.1230
# Month=24, Predicted=15.1033, Expected=15.5410
# Month=25, Predicted=15.8475, Expected=15.8250
# Month=26, Predicted=15.9767, Expected=16.3760
# Month=27, Predicted=16.6627, Expected=16.3570
# Month=28, Predicted=16.2522, Expected=16.9070
# Month=29, Predicted=17.1875, Expected=17.0210
# Month=30, Predicted=16.9951, Expected=17.4190
# Month=31, Predicted=17.5912, Expected=17.5330
# Month=32, Predicted=17.5135, Expected=17.2680
# Month=33, Predicted=17.0306, Expected=16.6030
# Month=34, Predicted=16.1581, Expected=15.8250
# Month=35, Predicted=15.3795, Expected=15.4460
# Month=36, Predicted=15.3161, Expected=15.6360
# Month=37, Predicted=15.8486, Expected=15.6930
# Month=38, Predicted=15.7549, Expected=16.7550
# Month=39, Predicted=17.3883, Expected=16.5090
# Month=40, Predicted=16.2333, Expected=17.7230
# Month=41, Predicted=18.3958, Expected=18.6910
# Month=42, Predicted=19.1107, Expected=19.1270
# Month=43, Predicted=19.1973, Expected=19.5640
# Month=44, Predicted=19.6709, Expected=19.2030
# Month=45, Predicted=18.8280, Expected=18.2160
# Month=46, Predicted=17.5222, Expected=17.2110
# Month=47, Predicted=16.6298, Expected=16.6600
# Month=48, Predicted=16.4524, Expected=16.8310
# Month=49, Predicted=17.0686, Expected=15.7690
# Month=50, Predicted=15.1233, Expected=15.7310
# Month=51, Predicted=15.8478, Expected=15.9960
# Month=52, Predicted=16.2359, Expected=17.0210
# Month=53, Predicted=17.6394, Expected=17.5520
# Month=54, Predicted=17.7664, Expected=17.8370
# Month=55, Predicted=17.8911, Expected=17.8560
# Month=56, Predicted=17.7642, Expected=17.5710
# Month=57, Predicted=17.3245, Expected=17.0780
# Month=58, Predicted=16.7507, Expected=16.6600
# Month=59, Predicted=16.4342, Expected=16.4330
# Month=60, Predicted=16.3508, Expected=16.5840
# Run 28 — RMSE: 0.489716, MSE: 0.239822, NMSE: 0.0019224270
#
# ===== Attention(lag=1) RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.2663, Expected=13.7000
# Month=2, Predicted=14.0535, Expected=13.8140
# Month=3, Predicted=13.8192, Expected=14.3830
# Month=4, Predicted=14.6776, Expected=15.0470
# Month=5, Predicted=15.3583, Expected=15.6930
# Month=6, Predicted=15.9633, Expected=15.8440
# Month=7, Predicted=15.7967, Expected=15.7120
# Month=8, Predicted=15.5294, Expected=15.3130
# Month=9, Predicted=15.0114, Expected=14.7630
# Month=10, Predicted=14.4207, Expected=13.5480
# Month=11, Predicted=12.7928, Expected=13.5860
# Month=12, Predicted=13.7703, Expected=14.5160
# Month=13, Predicted=15.1425, Expected=14.3830
# Month=14, Predicted=14.2273, Expected=14.4970
# Month=15, Predicted=14.5358, Expected=14.7440
# Month=16, Predicted=14.8617, Expected=15.8060
# Month=17, Predicted=16.3876, Expected=16.5270
# Month=18, Predicted=16.8230, Expected=16.5460
# Month=19, Predicted=16.3952, Expected=16.7170
# Month=20, Predicted=16.7321, Expected=16.4330
# Month=21, Predicted=16.1767, Expected=15.7690
# Month=22, Predicted=15.3192, Expected=15.2750
# Month=23, Predicted=15.0163, Expected=15.1230
# Month=24, Predicted=15.1081, Expected=15.5410
# Month=25, Predicted=15.8506, Expected=15.8250
# Month=26, Predicted=15.9770, Expected=16.3760
# Month=27, Predicted=16.6628, Expected=16.3570
# Month=28, Predicted=16.2496, Expected=16.9070
# Month=29, Predicted=17.1911, Expected=17.0210
# Month=30, Predicted=16.9992, Expected=17.4190
# Month=31, Predicted=17.5990, Expected=17.5330
# Month=32, Predicted=17.5209, Expected=17.2680
# Month=33, Predicted=17.0334, Expected=16.6030
# Month=34, Predicted=16.1545, Expected=15.8250
# Month=35, Predicted=15.3747, Expected=15.4460
# Month=36, Predicted=15.3162, Expected=15.6360
# Month=37, Predicted=15.8485, Expected=15.6930
# Month=38, Predicted=15.7506, Expected=16.7550
# Month=39, Predicted=17.3814, Expected=16.5090
# Month=40, Predicted=16.2232, Expected=17.7230
# Month=41, Predicted=18.3929, Expected=18.6910
# Month=42, Predicted=19.1187, Expected=19.1270
# Month=43, Predicted=19.2067, Expected=19.5640
# Month=44, Predicted=19.6841, Expected=19.2030
# Month=45, Predicted=18.8334, Expected=18.2160
# Month=46, Predicted=17.5164, Expected=17.2110
# Month=47, Predicted=16.6281, Expected=16.6600
# Month=48, Predicted=16.4577, Expected=16.8310
# Month=49, Predicted=17.0722, Expected=15.7690
# Month=50, Predicted=15.1041, Expected=15.7310
# Month=51, Predicted=15.8369, Expected=15.9960
# Month=52, Predicted=16.2254, Expected=17.0210
# Month=53, Predicted=17.6272, Expected=17.5520
# Month=54, Predicted=17.7604, Expected=17.8370
# Month=55, Predicted=17.8868, Expected=17.8560
# Month=56, Predicted=17.7622, Expected=17.5710
# Month=57, Predicted=17.3228, Expected=17.0780
# Month=58, Predicted=16.7488, Expected=16.6600
# Month=59, Predicted=16.4348, Expected=16.4330
# Month=60, Predicted=16.3522, Expected=16.5840
# Run 29 — RMSE: 0.491872, MSE: 0.241938, NMSE: 0.0019345546
#
# ===== Attention(lag=1) RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.2554, Expected=13.7000
# Month=2, Predicted=14.0423, Expected=13.8140
# Month=3, Predicted=13.8121, Expected=14.3830
# Month=4, Predicted=14.6857, Expected=15.0470
# Month=5, Predicted=15.3666, Expected=15.6930
# Month=6, Predicted=15.9772, Expected=15.8440
# Month=7, Predicted=15.8172, Expected=15.7120
# Month=8, Predicted=15.5564, Expected=15.3130
# Month=9, Predicted=15.0348, Expected=14.7630
# Month=10, Predicted=14.4353, Expected=13.5480
# Month=11, Predicted=12.7989, Expected=13.5860
# Month=12, Predicted=13.7647, Expected=14.5160
# Month=13, Predicted=15.1180, Expected=14.3830
# Month=14, Predicted=14.2015, Expected=14.4970
# Month=15, Predicted=14.5402, Expected=14.7440
# Month=16, Predicted=14.8678, Expected=15.8060
# Month=17, Predicted=16.3959, Expected=16.5270
# Month=18, Predicted=16.8279, Expected=16.5460
# Month=19, Predicted=16.4163, Expected=16.7170
# Month=20, Predicted=16.7614, Expected=16.4330
# Month=21, Predicted=16.1988, Expected=15.7690
# Month=22, Predicted=15.3387, Expected=15.2750
# Month=23, Predicted=15.0252, Expected=15.1230
# Month=24, Predicted=15.1012, Expected=15.5410
# Month=25, Predicted=15.8364, Expected=15.8250
# Month=26, Predicted=15.9621, Expected=16.3760
# Month=27, Predicted=16.6619, Expected=16.3570
# Month=28, Predicted=16.2552, Expected=16.9070
# Month=29, Predicted=17.2069, Expected=17.0210
# Month=30, Predicted=17.0093, Expected=17.4190
# Month=31, Predicted=17.6149, Expected=17.5330
# Month=32, Predicted=17.5336, Expected=17.2680
# Month=33, Predicted=17.0497, Expected=16.6030
# Month=34, Predicted=16.1712, Expected=15.8250
# Month=35, Predicted=15.3840, Expected=15.4460
# Month=36, Predicted=15.3105, Expected=15.6360
# Month=37, Predicted=15.8299, Expected=15.6930
# Month=38, Predicted=15.7283, Expected=16.7550
# Month=39, Predicted=17.3755, Expected=16.5090
# Month=40, Predicted=16.2167, Expected=17.7230
# Month=41, Predicted=18.4127, Expected=18.6910
# Month=42, Predicted=19.1256, Expected=19.1270
# Month=43, Predicted=19.2280, Expected=19.5640
# Month=44, Predicted=19.7161, Expected=19.2030
# Month=45, Predicted=18.8656, Expected=18.2160
# Month=46, Predicted=17.5510, Expected=17.2110
# Month=47, Predicted=16.6475, Expected=16.6600
# Month=48, Predicted=16.4508, Expected=16.8310
# Month=49, Predicted=17.0469, Expected=15.7690
# Month=50, Predicted=15.0728, Expected=15.7310
# Month=51, Predicted=15.8250, Expected=15.9960
# Month=52, Predicted=16.2015, Expected=17.0210
# Month=53, Predicted=17.6132, Expected=17.5520
# Month=54, Predicted=17.7520, Expected=17.8370
# Month=55, Predicted=17.9010, Expected=17.8560
# Month=56, Predicted=17.7852, Expected=17.5710
# Month=57, Predicted=17.3460, Expected=17.0780
# Month=58, Predicted=16.7667, Expected=16.6600
# Month=59, Predicted=16.4421, Expected=16.4330
# Month=60, Predicted=16.3476, Expected=16.5840
# Run 30 — RMSE: 0.496215, MSE: 0.246229, NMSE: 0.0019512571

# %%
# ============================================================
# Attention (lag=1) Summary — Degenerate Attention Control
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=1) — DEGENERATE ATTENTION CONTROL =====')
print('Note: T=1, softmax([e_1]) = [1.0], α_1 = 1 always. Attention has NO selective effect.')
print(f'\nRMSE: {np.mean(att1_all_rmse):.10f} ± {np.var(att1_all_rmse):.15f}')
print(f'MSE:  {np.mean(att1_all_mse):.10f} ± {np.var(att1_all_mse):.15f}')
print(f'NMSE: {np.mean(att1_all_nmse):.10f} ± {np.var(att1_all_nmse):.15f}')

best_att1_idx = att1_all_rmse.index(min(att1_all_rmse))
print(f'\nBest run: {best_att1_idx+1}')
print(f'  RMSE: {att1_all_rmse[best_att1_idx]:.15f}')
print(f'  MSE:  {att1_all_mse[best_att1_idx]:.15f}')
print(f'  NMSE: {att1_all_nmse[best_att1_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att1_preds = att1_all_predictions[best_att1_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att1_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=1) — Degenerate Control (Best Run)')
plt.show()
# Out:
# ===== LSTM-SNP + Attention (lag=1) — DEGENERATE ATTENTION CONTROL =====
# Note: T=1, softmax([e_1]) = [1.0], α_1 = 1 always. Attention has NO selective effect.
#
# RMSE: 0.4929538650 ± 0.000013068384141
# MSE:  0.2430165814 ± 0.000012633855793
# NMSE: 0.0019412734 ± 0.000000000369465
#
# Best run: 12
#   RMSE: 0.484689149523615
#   MSE:  0.234923571665925
#   NMSE: 0.001908694861817

# %% [markdown]
# # LSTM-SNP + Attention (lag=5)

# %%
# Redefine supervised data with lag=5

lag = 5
supervised_lag5 = timeseries_to_supervised(diff_values, lag)

# %%
# lag=5 data preparation (distinct variable names to avoid shadowing)
train5, test5 = supervised_lag5[:-60], supervised_lag5[-60:]

scaler5 = MinMaxScaler(feature_range=(-1, 1))
scaler5.fit(train5)

train5_scaled = scaler5.transform(train5)
test5_scaled = scaler5.transform(test5)

X_train5 = train5_scaled[:, :-1].reshape((-1, lag, 1))
y_train5 = train5_scaled[:, -1]

X_test5 = test5_scaled[:, :-1].reshape((-1, lag, 1))
y_test5 = test5_scaled[:, -1]

print(f"X_train5 shape: {X_train5.shape}")  # (samples, 5, 1)
print(f"X_test5 shape:  {X_test5.shape}")   # (60, 5, 1)
# Out:
# X_train5 shape: (539, 5, 1)
# X_test5 shape:  (60, 5, 1)

# %%
att5_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att5_model_check.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (1, None, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn_1 (RNN)                     │ (1, None, 8)           │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_attention_1              │ (1, 8)                 │            81 │
# │ (SimpleAttention)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 410 (1.60 KB)
#  Trainable params: 410 (1.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# LSTM-SNP + Attention (lag=5): 30-Run Protocol
# ============================================================

att5_all_rmse = []
att5_all_mse = []
att5_all_nmse = []
att5_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=5) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model (input_dim=1, lag=5 timesteps)
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train5,
            y_train5,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    model.predict(X_train5, batch_size=1, verbose=0)

    # Test predictions (single-step over lag=5 windows)
    predictions = []
    for i in range(len(test5_scaled)):
        X_input = X_test5[i].reshape(1, lag, 1)
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling: reconstruct full row [x1..x5, yhat]
        new_row = list(X_test5[i].flatten()) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler5.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train5) + i]

        predictions.append(inverted)

        expected = raw_values[len(train5) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att5_all_rmse.append(rmse)
    att5_all_mse.append(mse)
    att5_all_nmse.append(nmse)
    att5_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== Attention(lag=5) RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.1174, Expected=13.7000
# Month=2, Predicted=13.6864, Expected=13.8140
# Month=3, Predicted=13.8004, Expected=14.3830
# Month=4, Predicted=14.3694, Expected=15.0470
# Month=5, Predicted=15.0334, Expected=15.6930
# Month=6, Predicted=15.6794, Expected=15.8440
# Month=7, Predicted=15.8304, Expected=15.7120
# Month=8, Predicted=15.6984, Expected=15.3130
# Month=9, Predicted=15.2994, Expected=14.7630
# Month=10, Predicted=14.7494, Expected=13.5480
# Month=11, Predicted=13.5344, Expected=13.5860
# Month=12, Predicted=13.5724, Expected=14.5160
# Month=13, Predicted=14.5024, Expected=14.3830
# Month=14, Predicted=14.3694, Expected=14.4970
# Month=15, Predicted=14.4834, Expected=14.7440
# Month=16, Predicted=14.7304, Expected=15.8060
# Month=17, Predicted=15.7924, Expected=16.5270
# Month=18, Predicted=16.5134, Expected=16.5460
# Month=19, Predicted=16.5324, Expected=16.7170
# Month=20, Predicted=16.7034, Expected=16.4330
# Month=21, Predicted=16.4194, Expected=15.7690
# Month=22, Predicted=15.7554, Expected=15.2750
# Month=23, Predicted=15.2614, Expected=15.1230
# Month=24, Predicted=15.1094, Expected=15.5410
# Month=25, Predicted=15.5274, Expected=15.8250
# Month=26, Predicted=15.8114, Expected=16.3760
# Month=27, Predicted=16.3624, Expected=16.3570
# Month=28, Predicted=16.3434, Expected=16.9070
# Month=29, Predicted=16.8934, Expected=17.0210
# Month=30, Predicted=17.0074, Expected=17.4190
# Month=31, Predicted=17.4054, Expected=17.5330
# Month=32, Predicted=17.5194, Expected=17.2680
# Month=33, Predicted=17.2544, Expected=16.6030
# Month=34, Predicted=16.5894, Expected=15.8250
# Month=35, Predicted=15.8114, Expected=15.4460
# Month=36, Predicted=15.4324, Expected=15.6360
# Month=37, Predicted=15.6224, Expected=15.6930
# Month=38, Predicted=15.6794, Expected=16.7550
# Month=39, Predicted=16.7414, Expected=16.5090
# Month=40, Predicted=16.4954, Expected=17.7230
# Month=41, Predicted=17.7094, Expected=18.6910
# Month=42, Predicted=18.6774, Expected=19.1270
# Month=43, Predicted=19.1134, Expected=19.5640
# Month=44, Predicted=19.5504, Expected=19.2030
# Month=45, Predicted=19.1894, Expected=18.2160
# Month=46, Predicted=18.2024, Expected=17.2110
# Month=47, Predicted=17.1974, Expected=16.6600
# Month=48, Predicted=16.6464, Expected=16.8310
# Month=49, Predicted=16.8174, Expected=15.7690
# Month=50, Predicted=15.7554, Expected=15.7310
# Month=51, Predicted=15.7174, Expected=15.9960
# Month=52, Predicted=15.9824, Expected=17.0210
# Month=53, Predicted=17.0074, Expected=17.5520
# Month=54, Predicted=17.5384, Expected=17.8370
# Month=55, Predicted=17.8234, Expected=17.8560
# Month=56, Predicted=17.8424, Expected=17.5710
# Month=57, Predicted=17.5574, Expected=17.0780
# Month=58, Predicted=17.0644, Expected=16.6600
# Month=59, Predicted=16.6464, Expected=16.4330
# Month=60, Predicted=16.4194, Expected=16.5840
# Run 1 — RMSE: 0.562549, MSE: 0.316461, NMSE: 0.0026335474
#
# ===== Attention(lag=5) RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.1177, Expected=13.7000
# Month=2, Predicted=13.6867, Expected=13.8140
# Month=3, Predicted=13.8007, Expected=14.3830
# Month=4, Predicted=14.3697, Expected=15.0470
# Month=5, Predicted=15.0337, Expected=15.6930
# Month=6, Predicted=15.6797, Expected=15.8440
# Month=7, Predicted=15.8307, Expected=15.7120
# Month=8, Predicted=15.6987, Expected=15.3130
# Month=9, Predicted=15.2997, Expected=14.7630
# Month=10, Predicted=14.7497, Expected=13.5480
# Month=11, Predicted=13.5347, Expected=13.5860
# Month=12, Predicted=13.5727, Expected=14.5160
# Month=13, Predicted=14.5027, Expected=14.3830
# Month=14, Predicted=14.3697, Expected=14.4970
# Month=15, Predicted=14.4837, Expected=14.7440
# Month=16, Predicted=14.7307, Expected=15.8060
# Month=17, Predicted=15.7927, Expected=16.5270
# Month=18, Predicted=16.5137, Expected=16.5460
# Month=19, Predicted=16.5327, Expected=16.7170
# Month=20, Predicted=16.7037, Expected=16.4330
# Month=21, Predicted=16.4197, Expected=15.7690
# Month=22, Predicted=15.7557, Expected=15.2750
# Month=23, Predicted=15.2617, Expected=15.1230
# Month=24, Predicted=15.1097, Expected=15.5410
# Month=25, Predicted=15.5277, Expected=15.8250
# Month=26, Predicted=15.8117, Expected=16.3760
# Month=27, Predicted=16.3627, Expected=16.3570
# Month=28, Predicted=16.3437, Expected=16.9070
# Month=29, Predicted=16.8937, Expected=17.0210
# Month=30, Predicted=17.0077, Expected=17.4190
# Month=31, Predicted=17.4057, Expected=17.5330
# Month=32, Predicted=17.5197, Expected=17.2680
# Month=33, Predicted=17.2547, Expected=16.6030
# Month=34, Predicted=16.5897, Expected=15.8250
# Month=35, Predicted=15.8117, Expected=15.4460
# Month=36, Predicted=15.4327, Expected=15.6360
# Month=37, Predicted=15.6227, Expected=15.6930
# Month=38, Predicted=15.6797, Expected=16.7550
# Month=39, Predicted=16.7417, Expected=16.5090
# Month=40, Predicted=16.4957, Expected=17.7230
# Month=41, Predicted=17.7097, Expected=18.6910
# Month=42, Predicted=18.6777, Expected=19.1270
# Month=43, Predicted=19.1137, Expected=19.5640
# Month=44, Predicted=19.5507, Expected=19.2030
# Month=45, Predicted=19.1897, Expected=18.2160
# Month=46, Predicted=18.2027, Expected=17.2110
# Month=47, Predicted=17.1977, Expected=16.6600
# Month=48, Predicted=16.6467, Expected=16.8310
# Month=49, Predicted=16.8177, Expected=15.7690
# Month=50, Predicted=15.7557, Expected=15.7310
# Month=51, Predicted=15.7177, Expected=15.9960
# Month=52, Predicted=15.9827, Expected=17.0210
# Month=53, Predicted=17.0077, Expected=17.5520
# Month=54, Predicted=17.5387, Expected=17.8370
# Month=55, Predicted=17.8237, Expected=17.8560
# Month=56, Predicted=17.8427, Expected=17.5710
# Month=57, Predicted=17.5577, Expected=17.0780
# Month=58, Predicted=17.0647, Expected=16.6600
# Month=59, Predicted=16.6467, Expected=16.4330
# Month=60, Predicted=16.4197, Expected=16.5840
# Run 2 — RMSE: 0.562508, MSE: 0.316415, NMSE: 0.0026332244
#
# ===== Attention(lag=5) RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 3 — RMSE: 0.563213, MSE: 0.317209, NMSE: 0.0026387840
#
# ===== Attention(lag=5) RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.1122, Expected=13.7000
# Month=2, Predicted=13.6812, Expected=13.8140
# Month=3, Predicted=13.7952, Expected=14.3830
# Month=4, Predicted=14.3642, Expected=15.0470
# Month=5, Predicted=15.0282, Expected=15.6930
# Month=6, Predicted=15.6742, Expected=15.8440
# Month=7, Predicted=15.8252, Expected=15.7120
# Month=8, Predicted=15.6932, Expected=15.3130
# Month=9, Predicted=15.2942, Expected=14.7630
# Month=10, Predicted=14.7442, Expected=13.5480
# Month=11, Predicted=13.5292, Expected=13.5860
# Month=12, Predicted=13.5672, Expected=14.5160
# Month=13, Predicted=14.4972, Expected=14.3830
# Month=14, Predicted=14.3642, Expected=14.4970
# Month=15, Predicted=14.4782, Expected=14.7440
# Month=16, Predicted=14.7252, Expected=15.8060
# Month=17, Predicted=15.7872, Expected=16.5270
# Month=18, Predicted=16.5082, Expected=16.5460
# Month=19, Predicted=16.5272, Expected=16.7170
# Month=20, Predicted=16.6982, Expected=16.4330
# Month=21, Predicted=16.4142, Expected=15.7690
# Month=22, Predicted=15.7502, Expected=15.2750
# Month=23, Predicted=15.2562, Expected=15.1230
# Month=24, Predicted=15.1042, Expected=15.5410
# Month=25, Predicted=15.5222, Expected=15.8250
# Month=26, Predicted=15.8062, Expected=16.3760
# Month=27, Predicted=16.3572, Expected=16.3570
# Month=28, Predicted=16.3382, Expected=16.9070
# Month=29, Predicted=16.8882, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.4002, Expected=17.5330
# Month=32, Predicted=17.5142, Expected=17.2680
# Month=33, Predicted=17.2492, Expected=16.6030
# Month=34, Predicted=16.5842, Expected=15.8250
# Month=35, Predicted=15.8062, Expected=15.4460
# Month=36, Predicted=15.4272, Expected=15.6360
# Month=37, Predicted=15.6172, Expected=15.6930
# Month=38, Predicted=15.6742, Expected=16.7550
# Month=39, Predicted=16.7362, Expected=16.5090
# Month=40, Predicted=16.4902, Expected=17.7230
# Month=41, Predicted=17.7042, Expected=18.6910
# Month=42, Predicted=18.6722, Expected=19.1270
# Month=43, Predicted=19.1082, Expected=19.5640
# Month=44, Predicted=19.5452, Expected=19.2030
# Month=45, Predicted=19.1842, Expected=18.2160
# Month=46, Predicted=18.1972, Expected=17.2110
# Month=47, Predicted=17.1922, Expected=16.6600
# Month=48, Predicted=16.6412, Expected=16.8310
# Month=49, Predicted=16.8122, Expected=15.7690
# Month=50, Predicted=15.7502, Expected=15.7310
# Month=51, Predicted=15.7122, Expected=15.9960
# Month=52, Predicted=15.9772, Expected=17.0210
# Month=53, Predicted=17.0022, Expected=17.5520
# Month=54, Predicted=17.5332, Expected=17.8370
# Month=55, Predicted=17.8182, Expected=17.8560
# Month=56, Predicted=17.8372, Expected=17.5710
# Month=57, Predicted=17.5522, Expected=17.0780
# Month=58, Predicted=17.0592, Expected=16.6600
# Month=59, Predicted=16.6412, Expected=16.4330
# Month=60, Predicted=16.4142, Expected=16.5840
# Run 4 — RMSE: 0.563224, MSE: 0.317221, NMSE: 0.0026388692
#
# ===== Attention(lag=5) RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.1178, Expected=13.7000
# Month=2, Predicted=13.6868, Expected=13.8140
# Month=3, Predicted=13.8008, Expected=14.3830
# Month=4, Predicted=14.3698, Expected=15.0470
# Month=5, Predicted=15.0338, Expected=15.6930
# Month=6, Predicted=15.6798, Expected=15.8440
# Month=7, Predicted=15.8308, Expected=15.7120
# Month=8, Predicted=15.6988, Expected=15.3130
# Month=9, Predicted=15.2998, Expected=14.7630
# Month=10, Predicted=14.7498, Expected=13.5480
# Month=11, Predicted=13.5348, Expected=13.5860
# Month=12, Predicted=13.5728, Expected=14.5160
# Month=13, Predicted=14.5028, Expected=14.3830
# Month=14, Predicted=14.3698, Expected=14.4970
# Month=15, Predicted=14.4838, Expected=14.7440
# Month=16, Predicted=14.7308, Expected=15.8060
# Month=17, Predicted=15.7928, Expected=16.5270
# Month=18, Predicted=16.5138, Expected=16.5460
# Month=19, Predicted=16.5328, Expected=16.7170
# Month=20, Predicted=16.7038, Expected=16.4330
# Month=21, Predicted=16.4198, Expected=15.7690
# Month=22, Predicted=15.7558, Expected=15.2750
# Month=23, Predicted=15.2618, Expected=15.1230
# Month=24, Predicted=15.1098, Expected=15.5410
# Month=25, Predicted=15.5278, Expected=15.8250
# Month=26, Predicted=15.8118, Expected=16.3760
# Month=27, Predicted=16.3628, Expected=16.3570
# Month=28, Predicted=16.3438, Expected=16.9070
# Month=29, Predicted=16.8938, Expected=17.0210
# Month=30, Predicted=17.0078, Expected=17.4190
# Month=31, Predicted=17.4058, Expected=17.5330
# Month=32, Predicted=17.5198, Expected=17.2680
# Month=33, Predicted=17.2548, Expected=16.6030
# Month=34, Predicted=16.5898, Expected=15.8250
# Month=35, Predicted=15.8118, Expected=15.4460
# Month=36, Predicted=15.4328, Expected=15.6360
# Month=37, Predicted=15.6228, Expected=15.6930
# Month=38, Predicted=15.6798, Expected=16.7550
# Month=39, Predicted=16.7418, Expected=16.5090
# Month=40, Predicted=16.4958, Expected=17.7230
# Month=41, Predicted=17.7098, Expected=18.6910
# Month=42, Predicted=18.6778, Expected=19.1270
# Month=43, Predicted=19.1138, Expected=19.5640
# Month=44, Predicted=19.5508, Expected=19.2030
# Month=45, Predicted=19.1898, Expected=18.2160
# Month=46, Predicted=18.2028, Expected=17.2110
# Month=47, Predicted=17.1978, Expected=16.6600
# Month=48, Predicted=16.6468, Expected=16.8310
# Month=49, Predicted=16.8178, Expected=15.7690
# Month=50, Predicted=15.7558, Expected=15.7310
# Month=51, Predicted=15.7178, Expected=15.9960
# Month=52, Predicted=15.9828, Expected=17.0210
# Month=53, Predicted=17.0078, Expected=17.5520
# Month=54, Predicted=17.5388, Expected=17.8370
# Month=55, Predicted=17.8238, Expected=17.8560
# Month=56, Predicted=17.8428, Expected=17.5710
# Month=57, Predicted=17.5578, Expected=17.0780
# Month=58, Predicted=17.0648, Expected=16.6600
# Month=59, Predicted=16.6468, Expected=16.4330
# Month=60, Predicted=16.4198, Expected=16.5840
# Run 5 — RMSE: 0.562502, MSE: 0.316408, NMSE: 0.0026331740
#
# ===== Attention(lag=5) RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.1044, Expected=13.7000
# Month=2, Predicted=13.6734, Expected=13.8140
# Month=3, Predicted=13.7874, Expected=14.3830
# Month=4, Predicted=14.3564, Expected=15.0470
# Month=5, Predicted=15.0204, Expected=15.6930
# Month=6, Predicted=15.6664, Expected=15.8440
# Month=7, Predicted=15.8174, Expected=15.7120
# Month=8, Predicted=15.6854, Expected=15.3130
# Month=9, Predicted=15.2864, Expected=14.7630
# Month=10, Predicted=14.7364, Expected=13.5480
# Month=11, Predicted=13.5214, Expected=13.5860
# Month=12, Predicted=13.5594, Expected=14.5160
# Month=13, Predicted=14.4894, Expected=14.3830
# Month=14, Predicted=14.3564, Expected=14.4970
# Month=15, Predicted=14.4704, Expected=14.7440
# Month=16, Predicted=14.7174, Expected=15.8060
# Month=17, Predicted=15.7794, Expected=16.5270
# Month=18, Predicted=16.5004, Expected=16.5460
# Month=19, Predicted=16.5194, Expected=16.7170
# Month=20, Predicted=16.6904, Expected=16.4330
# Month=21, Predicted=16.4064, Expected=15.7690
# Month=22, Predicted=15.7424, Expected=15.2750
# Month=23, Predicted=15.2484, Expected=15.1230
# Month=24, Predicted=15.0964, Expected=15.5410
# Month=25, Predicted=15.5144, Expected=15.8250
# Month=26, Predicted=15.7984, Expected=16.3760
# Month=27, Predicted=16.3494, Expected=16.3570
# Month=28, Predicted=16.3304, Expected=16.9070
# Month=29, Predicted=16.8804, Expected=17.0210
# Month=30, Predicted=16.9944, Expected=17.4190
# Month=31, Predicted=17.3924, Expected=17.5330
# Month=32, Predicted=17.5064, Expected=17.2680
# Month=33, Predicted=17.2414, Expected=16.6030
# Month=34, Predicted=16.5764, Expected=15.8250
# Month=35, Predicted=15.7984, Expected=15.4460
# Month=36, Predicted=15.4194, Expected=15.6360
# Month=37, Predicted=15.6094, Expected=15.6930
# Month=38, Predicted=15.6664, Expected=16.7550
# Month=39, Predicted=16.7284, Expected=16.5090
# Month=40, Predicted=16.4824, Expected=17.7230
# Month=41, Predicted=17.6964, Expected=18.6910
# Month=42, Predicted=18.6644, Expected=19.1270
# Month=43, Predicted=19.1004, Expected=19.5640
# Month=44, Predicted=19.5374, Expected=19.2030
# Month=45, Predicted=19.1764, Expected=18.2160
# Month=46, Predicted=18.1894, Expected=17.2110
# Month=47, Predicted=17.1844, Expected=16.6600
# Month=48, Predicted=16.6334, Expected=16.8310
# Month=49, Predicted=16.8044, Expected=15.7690
# Month=50, Predicted=15.7424, Expected=15.7310
# Month=51, Predicted=15.7044, Expected=15.9960
# Month=52, Predicted=15.9694, Expected=17.0210
# Month=53, Predicted=16.9944, Expected=17.5520
# Month=54, Predicted=17.5254, Expected=17.8370
# Month=55, Predicted=17.8104, Expected=17.8560
# Month=56, Predicted=17.8294, Expected=17.5710
# Month=57, Predicted=17.5444, Expected=17.0780
# Month=58, Predicted=17.0514, Expected=16.6600
# Month=59, Predicted=16.6334, Expected=16.4330
# Month=60, Predicted=16.4064, Expected=16.5840
# Run 6 — RMSE: 0.564333, MSE: 0.318471, NMSE: 0.0026476167
#
# ===== Attention(lag=5) RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.1083, Expected=13.7000
# Month=2, Predicted=13.6773, Expected=13.8140
# Month=3, Predicted=13.7913, Expected=14.3830
# Month=4, Predicted=14.3603, Expected=15.0470
# Month=5, Predicted=15.0243, Expected=15.6930
# Month=6, Predicted=15.6703, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.6893, Expected=15.3130
# Month=9, Predicted=15.2903, Expected=14.7630
# Month=10, Predicted=14.7403, Expected=13.5480
# Month=11, Predicted=13.5253, Expected=13.5860
# Month=12, Predicted=13.5633, Expected=14.5160
# Month=13, Predicted=14.4933, Expected=14.3830
# Month=14, Predicted=14.3603, Expected=14.4970
# Month=15, Predicted=14.4743, Expected=14.7440
# Month=16, Predicted=14.7213, Expected=15.8060
# Month=17, Predicted=15.7833, Expected=16.5270
# Month=18, Predicted=16.5043, Expected=16.5460
# Month=19, Predicted=16.5233, Expected=16.7170
# Month=20, Predicted=16.6943, Expected=16.4330
# Month=21, Predicted=16.4103, Expected=15.7690
# Month=22, Predicted=15.7463, Expected=15.2750
# Month=23, Predicted=15.2523, Expected=15.1230
# Month=24, Predicted=15.1003, Expected=15.5410
# Month=25, Predicted=15.5183, Expected=15.8250
# Month=26, Predicted=15.8023, Expected=16.3760
# Month=27, Predicted=16.3533, Expected=16.3570
# Month=28, Predicted=16.3343, Expected=16.9070
# Month=29, Predicted=16.8843, Expected=17.0210
# Month=30, Predicted=16.9983, Expected=17.4190
# Month=31, Predicted=17.3963, Expected=17.5330
# Month=32, Predicted=17.5103, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5803, Expected=15.8250
# Month=35, Predicted=15.8023, Expected=15.4460
# Month=36, Predicted=15.4233, Expected=15.6360
# Month=37, Predicted=15.6133, Expected=15.6930
# Month=38, Predicted=15.6703, Expected=16.7550
# Month=39, Predicted=16.7323, Expected=16.5090
# Month=40, Predicted=16.4863, Expected=17.7230
# Month=41, Predicted=17.7003, Expected=18.6910
# Month=42, Predicted=18.6683, Expected=19.1270
# Month=43, Predicted=19.1043, Expected=19.5640
# Month=44, Predicted=19.5413, Expected=19.2030
# Month=45, Predicted=19.1803, Expected=18.2160
# Month=46, Predicted=18.1933, Expected=17.2110
# Month=47, Predicted=17.1883, Expected=16.6600
# Month=48, Predicted=16.6373, Expected=16.8310
# Month=49, Predicted=16.8083, Expected=15.7690
# Month=50, Predicted=15.7463, Expected=15.7310
# Month=51, Predicted=15.7083, Expected=15.9960
# Month=52, Predicted=15.9733, Expected=17.0210
# Month=53, Predicted=16.9983, Expected=17.5520
# Month=54, Predicted=17.5293, Expected=17.8370
# Month=55, Predicted=17.8143, Expected=17.8560
# Month=56, Predicted=17.8333, Expected=17.5710
# Month=57, Predicted=17.5483, Expected=17.0780
# Month=58, Predicted=17.0553, Expected=16.6600
# Month=59, Predicted=16.6373, Expected=16.4330
# Month=60, Predicted=16.4103, Expected=16.5840
# Run 7 — RMSE: 0.563766, MSE: 0.317832, NMSE: 0.0026431478
#
# ===== Attention(lag=5) RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.1121, Expected=13.7000
# Month=2, Predicted=13.6811, Expected=13.8140
# Month=3, Predicted=13.7951, Expected=14.3830
# Month=4, Predicted=14.3641, Expected=15.0470
# Month=5, Predicted=15.0281, Expected=15.6930
# Month=6, Predicted=15.6741, Expected=15.8440
# Month=7, Predicted=15.8251, Expected=15.7120
# Month=8, Predicted=15.6931, Expected=15.3130
# Month=9, Predicted=15.2941, Expected=14.7630
# Month=10, Predicted=14.7441, Expected=13.5480
# Month=11, Predicted=13.5291, Expected=13.5860
# Month=12, Predicted=13.5671, Expected=14.5160
# Month=13, Predicted=14.4971, Expected=14.3830
# Month=14, Predicted=14.3641, Expected=14.4970
# Month=15, Predicted=14.4781, Expected=14.7440
# Month=16, Predicted=14.7251, Expected=15.8060
# Month=17, Predicted=15.7871, Expected=16.5270
# Month=18, Predicted=16.5081, Expected=16.5460
# Month=19, Predicted=16.5271, Expected=16.7170
# Month=20, Predicted=16.6981, Expected=16.4330
# Month=21, Predicted=16.4141, Expected=15.7690
# Month=22, Predicted=15.7501, Expected=15.2750
# Month=23, Predicted=15.2561, Expected=15.1230
# Month=24, Predicted=15.1041, Expected=15.5410
# Month=25, Predicted=15.5221, Expected=15.8250
# Month=26, Predicted=15.8061, Expected=16.3760
# Month=27, Predicted=16.3571, Expected=16.3570
# Month=28, Predicted=16.3381, Expected=16.9070
# Month=29, Predicted=16.8881, Expected=17.0210
# Month=30, Predicted=17.0021, Expected=17.4190
# Month=31, Predicted=17.4001, Expected=17.5330
# Month=32, Predicted=17.5141, Expected=17.2680
# Month=33, Predicted=17.2491, Expected=16.6030
# Month=34, Predicted=16.5841, Expected=15.8250
# Month=35, Predicted=15.8061, Expected=15.4460
# Month=36, Predicted=15.4271, Expected=15.6360
# Month=37, Predicted=15.6171, Expected=15.6930
# Month=38, Predicted=15.6741, Expected=16.7550
# Month=39, Predicted=16.7361, Expected=16.5090
# Month=40, Predicted=16.4901, Expected=17.7230
# Month=41, Predicted=17.7041, Expected=18.6910
# Month=42, Predicted=18.6721, Expected=19.1270
# Month=43, Predicted=19.1081, Expected=19.5640
# Month=44, Predicted=19.5451, Expected=19.2030
# Month=45, Predicted=19.1841, Expected=18.2160
# Month=46, Predicted=18.1971, Expected=17.2110
# Month=47, Predicted=17.1921, Expected=16.6600
# Month=48, Predicted=16.6411, Expected=16.8310
# Month=49, Predicted=16.8121, Expected=15.7690
# Month=50, Predicted=15.7501, Expected=15.7310
# Month=51, Predicted=15.7121, Expected=15.9960
# Month=52, Predicted=15.9771, Expected=17.0210
# Month=53, Predicted=17.0021, Expected=17.5520
# Month=54, Predicted=17.5331, Expected=17.8370
# Month=55, Predicted=17.8181, Expected=17.8560
# Month=56, Predicted=17.8371, Expected=17.5710
# Month=57, Predicted=17.5521, Expected=17.0780
# Month=58, Predicted=17.0591, Expected=16.6600
# Month=59, Predicted=16.6411, Expected=16.4330
# Month=60, Predicted=16.4141, Expected=16.5840
# Run 8 — RMSE: 0.563235, MSE: 0.317233, NMSE: 0.0026389535
#
# ===== Attention(lag=5) RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.1175, Expected=13.7000
# Month=2, Predicted=13.6865, Expected=13.8140
# Month=3, Predicted=13.8005, Expected=14.3830
# Month=4, Predicted=14.3695, Expected=15.0470
# Month=5, Predicted=15.0335, Expected=15.6930
# Month=6, Predicted=15.6795, Expected=15.8440
# Month=7, Predicted=15.8305, Expected=15.7120
# Month=8, Predicted=15.6985, Expected=15.3130
# Month=9, Predicted=15.2995, Expected=14.7630
# Month=10, Predicted=14.7495, Expected=13.5480
# Month=11, Predicted=13.5345, Expected=13.5860
# Month=12, Predicted=13.5725, Expected=14.5160
# Month=13, Predicted=14.5025, Expected=14.3830
# Month=14, Predicted=14.3695, Expected=14.4970
# Month=15, Predicted=14.4835, Expected=14.7440
# Month=16, Predicted=14.7305, Expected=15.8060
# Month=17, Predicted=15.7925, Expected=16.5270
# Month=18, Predicted=16.5135, Expected=16.5460
# Month=19, Predicted=16.5325, Expected=16.7170
# Month=20, Predicted=16.7035, Expected=16.4330
# Month=21, Predicted=16.4195, Expected=15.7690
# Month=22, Predicted=15.7555, Expected=15.2750
# Month=23, Predicted=15.2615, Expected=15.1230
# Month=24, Predicted=15.1095, Expected=15.5410
# Month=25, Predicted=15.5275, Expected=15.8250
# Month=26, Predicted=15.8115, Expected=16.3760
# Month=27, Predicted=16.3625, Expected=16.3570
# Month=28, Predicted=16.3435, Expected=16.9070
# Month=29, Predicted=16.8935, Expected=17.0210
# Month=30, Predicted=17.0075, Expected=17.4190
# Month=31, Predicted=17.4055, Expected=17.5330
# Month=32, Predicted=17.5195, Expected=17.2680
# Month=33, Predicted=17.2545, Expected=16.6030
# Month=34, Predicted=16.5895, Expected=15.8250
# Month=35, Predicted=15.8115, Expected=15.4460
# Month=36, Predicted=15.4325, Expected=15.6360
# Month=37, Predicted=15.6225, Expected=15.6930
# Month=38, Predicted=15.6795, Expected=16.7550
# Month=39, Predicted=16.7415, Expected=16.5090
# Month=40, Predicted=16.4955, Expected=17.7230
# Month=41, Predicted=17.7095, Expected=18.6910
# Month=42, Predicted=18.6775, Expected=19.1270
# Month=43, Predicted=19.1135, Expected=19.5640
# Month=44, Predicted=19.5505, Expected=19.2030
# Month=45, Predicted=19.1895, Expected=18.2160
# Month=46, Predicted=18.2025, Expected=17.2110
# Month=47, Predicted=17.1975, Expected=16.6600
# Month=48, Predicted=16.6465, Expected=16.8310
# Month=49, Predicted=16.8175, Expected=15.7690
# Month=50, Predicted=15.7555, Expected=15.7310
# Month=51, Predicted=15.7175, Expected=15.9960
# Month=52, Predicted=15.9825, Expected=17.0210
# Month=53, Predicted=17.0075, Expected=17.5520
# Month=54, Predicted=17.5385, Expected=17.8370
# Month=55, Predicted=17.8235, Expected=17.8560
# Month=56, Predicted=17.8425, Expected=17.5710
# Month=57, Predicted=17.5575, Expected=17.0780
# Month=58, Predicted=17.0645, Expected=16.6600
# Month=59, Predicted=16.6465, Expected=16.4330
# Month=60, Predicted=16.4195, Expected=16.5840
# Run 9 — RMSE: 0.562536, MSE: 0.316447, NMSE: 0.0026334449
#
# ===== Attention(lag=5) RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.1175, Expected=13.7000
# Month=2, Predicted=13.6865, Expected=13.8140
# Month=3, Predicted=13.8005, Expected=14.3830
# Month=4, Predicted=14.3695, Expected=15.0470
# Month=5, Predicted=15.0335, Expected=15.6930
# Month=6, Predicted=15.6795, Expected=15.8440
# Month=7, Predicted=15.8305, Expected=15.7120
# Month=8, Predicted=15.6985, Expected=15.3130
# Month=9, Predicted=15.2995, Expected=14.7630
# Month=10, Predicted=14.7495, Expected=13.5480
# Month=11, Predicted=13.5345, Expected=13.5860
# Month=12, Predicted=13.5725, Expected=14.5160
# Month=13, Predicted=14.5025, Expected=14.3830
# Month=14, Predicted=14.3695, Expected=14.4970
# Month=15, Predicted=14.4835, Expected=14.7440
# Month=16, Predicted=14.7305, Expected=15.8060
# Month=17, Predicted=15.7925, Expected=16.5270
# Month=18, Predicted=16.5135, Expected=16.5460
# Month=19, Predicted=16.5325, Expected=16.7170
# Month=20, Predicted=16.7035, Expected=16.4330
# Month=21, Predicted=16.4195, Expected=15.7690
# Month=22, Predicted=15.7555, Expected=15.2750
# Month=23, Predicted=15.2615, Expected=15.1230
# Month=24, Predicted=15.1095, Expected=15.5410
# Month=25, Predicted=15.5275, Expected=15.8250
# Month=26, Predicted=15.8115, Expected=16.3760
# Month=27, Predicted=16.3625, Expected=16.3570
# Month=28, Predicted=16.3435, Expected=16.9070
# Month=29, Predicted=16.8935, Expected=17.0210
# Month=30, Predicted=17.0075, Expected=17.4190
# Month=31, Predicted=17.4055, Expected=17.5330
# Month=32, Predicted=17.5195, Expected=17.2680
# Month=33, Predicted=17.2545, Expected=16.6030
# Month=34, Predicted=16.5895, Expected=15.8250
# Month=35, Predicted=15.8115, Expected=15.4460
# Month=36, Predicted=15.4325, Expected=15.6360
# Month=37, Predicted=15.6225, Expected=15.6930
# Month=38, Predicted=15.6795, Expected=16.7550
# Month=39, Predicted=16.7415, Expected=16.5090
# Month=40, Predicted=16.4955, Expected=17.7230
# Month=41, Predicted=17.7095, Expected=18.6910
# Month=42, Predicted=18.6775, Expected=19.1270
# Month=43, Predicted=19.1135, Expected=19.5640
# Month=44, Predicted=19.5505, Expected=19.2030
# Month=45, Predicted=19.1895, Expected=18.2160
# Month=46, Predicted=18.2025, Expected=17.2110
# Month=47, Predicted=17.1975, Expected=16.6600
# Month=48, Predicted=16.6465, Expected=16.8310
# Month=49, Predicted=16.8175, Expected=15.7690
# Month=50, Predicted=15.7555, Expected=15.7310
# Month=51, Predicted=15.7175, Expected=15.9960
# Month=52, Predicted=15.9825, Expected=17.0210
# Month=53, Predicted=17.0075, Expected=17.5520
# Month=54, Predicted=17.5385, Expected=17.8370
# Month=55, Predicted=17.8235, Expected=17.8560
# Month=56, Predicted=17.8425, Expected=17.5710
# Month=57, Predicted=17.5575, Expected=17.0780
# Month=58, Predicted=17.0645, Expected=16.6600
# Month=59, Predicted=16.6465, Expected=16.4330
# Month=60, Predicted=16.4195, Expected=16.5840
# Run 10 — RMSE: 0.562538, MSE: 0.316449, NMSE: 0.0026334612
#
# ===== Attention(lag=5) RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.1178, Expected=13.7000
# Month=2, Predicted=13.6868, Expected=13.8140
# Month=3, Predicted=13.8008, Expected=14.3830
# Month=4, Predicted=14.3698, Expected=15.0470
# Month=5, Predicted=15.0338, Expected=15.6930
# Month=6, Predicted=15.6798, Expected=15.8440
# Month=7, Predicted=15.8308, Expected=15.7120
# Month=8, Predicted=15.6988, Expected=15.3130
# Month=9, Predicted=15.2998, Expected=14.7630
# Month=10, Predicted=14.7498, Expected=13.5480
# Month=11, Predicted=13.5348, Expected=13.5860
# Month=12, Predicted=13.5728, Expected=14.5160
# Month=13, Predicted=14.5028, Expected=14.3830
# Month=14, Predicted=14.3698, Expected=14.4970
# Month=15, Predicted=14.4838, Expected=14.7440
# Month=16, Predicted=14.7308, Expected=15.8060
# Month=17, Predicted=15.7928, Expected=16.5270
# Month=18, Predicted=16.5138, Expected=16.5460
# Month=19, Predicted=16.5328, Expected=16.7170
# Month=20, Predicted=16.7038, Expected=16.4330
# Month=21, Predicted=16.4198, Expected=15.7690
# Month=22, Predicted=15.7558, Expected=15.2750
# Month=23, Predicted=15.2618, Expected=15.1230
# Month=24, Predicted=15.1098, Expected=15.5410
# Month=25, Predicted=15.5278, Expected=15.8250
# Month=26, Predicted=15.8118, Expected=16.3760
# Month=27, Predicted=16.3628, Expected=16.3570
# Month=28, Predicted=16.3438, Expected=16.9070
# Month=29, Predicted=16.8938, Expected=17.0210
# Month=30, Predicted=17.0078, Expected=17.4190
# Month=31, Predicted=17.4058, Expected=17.5330
# Month=32, Predicted=17.5198, Expected=17.2680
# Month=33, Predicted=17.2548, Expected=16.6030
# Month=34, Predicted=16.5898, Expected=15.8250
# Month=35, Predicted=15.8118, Expected=15.4460
# Month=36, Predicted=15.4328, Expected=15.6360
# Month=37, Predicted=15.6228, Expected=15.6930
# Month=38, Predicted=15.6798, Expected=16.7550
# Month=39, Predicted=16.7418, Expected=16.5090
# Month=40, Predicted=16.4958, Expected=17.7230
# Month=41, Predicted=17.7098, Expected=18.6910
# Month=42, Predicted=18.6778, Expected=19.1270
# Month=43, Predicted=19.1138, Expected=19.5640
# Month=44, Predicted=19.5508, Expected=19.2030
# Month=45, Predicted=19.1898, Expected=18.2160
# Month=46, Predicted=18.2028, Expected=17.2110
# Month=47, Predicted=17.1978, Expected=16.6600
# Month=48, Predicted=16.6468, Expected=16.8310
# Month=49, Predicted=16.8178, Expected=15.7690
# Month=50, Predicted=15.7558, Expected=15.7310
# Month=51, Predicted=15.7178, Expected=15.9960
# Month=52, Predicted=15.9828, Expected=17.0210
# Month=53, Predicted=17.0078, Expected=17.5520
# Month=54, Predicted=17.5388, Expected=17.8370
# Month=55, Predicted=17.8238, Expected=17.8560
# Month=56, Predicted=17.8428, Expected=17.5710
# Month=57, Predicted=17.5578, Expected=17.0780
# Month=58, Predicted=17.0648, Expected=16.6600
# Month=59, Predicted=16.6468, Expected=16.4330
# Month=60, Predicted=16.4198, Expected=16.5840
# Run 11 — RMSE: 0.562492, MSE: 0.316398, NMSE: 0.0026331011
#
# ===== Attention(lag=5) RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.1176, Expected=13.7000
# Month=2, Predicted=13.6866, Expected=13.8140
# Month=3, Predicted=13.8006, Expected=14.3830
# Month=4, Predicted=14.3696, Expected=15.0470
# Month=5, Predicted=15.0336, Expected=15.6930
# Month=6, Predicted=15.6796, Expected=15.8440
# Month=7, Predicted=15.8306, Expected=15.7120
# Month=8, Predicted=15.6986, Expected=15.3130
# Month=9, Predicted=15.2996, Expected=14.7630
# Month=10, Predicted=14.7496, Expected=13.5480
# Month=11, Predicted=13.5346, Expected=13.5860
# Month=12, Predicted=13.5726, Expected=14.5160
# Month=13, Predicted=14.5026, Expected=14.3830
# Month=14, Predicted=14.3696, Expected=14.4970
# Month=15, Predicted=14.4836, Expected=14.7440
# Month=16, Predicted=14.7306, Expected=15.8060
# Month=17, Predicted=15.7926, Expected=16.5270
# Month=18, Predicted=16.5136, Expected=16.5460
# Month=19, Predicted=16.5326, Expected=16.7170
# Month=20, Predicted=16.7036, Expected=16.4330
# Month=21, Predicted=16.4196, Expected=15.7690
# Month=22, Predicted=15.7556, Expected=15.2750
# Month=23, Predicted=15.2616, Expected=15.1230
# Month=24, Predicted=15.1096, Expected=15.5410
# Month=25, Predicted=15.5276, Expected=15.8250
# Month=26, Predicted=15.8116, Expected=16.3760
# Month=27, Predicted=16.3626, Expected=16.3570
# Month=28, Predicted=16.3436, Expected=16.9070
# Month=29, Predicted=16.8936, Expected=17.0210
# Month=30, Predicted=17.0076, Expected=17.4190
# Month=31, Predicted=17.4056, Expected=17.5330
# Month=32, Predicted=17.5196, Expected=17.2680
# Month=33, Predicted=17.2546, Expected=16.6030
# Month=34, Predicted=16.5896, Expected=15.8250
# Month=35, Predicted=15.8116, Expected=15.4460
# Month=36, Predicted=15.4326, Expected=15.6360
# Month=37, Predicted=15.6226, Expected=15.6930
# Month=38, Predicted=15.6796, Expected=16.7550
# Month=39, Predicted=16.7416, Expected=16.5090
# Month=40, Predicted=16.4956, Expected=17.7230
# Month=41, Predicted=17.7096, Expected=18.6910
# Month=42, Predicted=18.6776, Expected=19.1270
# Month=43, Predicted=19.1136, Expected=19.5640
# Month=44, Predicted=19.5506, Expected=19.2030
# Month=45, Predicted=19.1896, Expected=18.2160
# Month=46, Predicted=18.2026, Expected=17.2110
# Month=47, Predicted=17.1976, Expected=16.6600
# Month=48, Predicted=16.6466, Expected=16.8310
# Month=49, Predicted=16.8176, Expected=15.7690
# Month=50, Predicted=15.7556, Expected=15.7310
# Month=51, Predicted=15.7176, Expected=15.9960
# Month=52, Predicted=15.9826, Expected=17.0210
# Month=53, Predicted=17.0076, Expected=17.5520
# Month=54, Predicted=17.5386, Expected=17.8370
# Month=55, Predicted=17.8236, Expected=17.8560
# Month=56, Predicted=17.8426, Expected=17.5710
# Month=57, Predicted=17.5576, Expected=17.0780
# Month=58, Predicted=17.0646, Expected=16.6600
# Month=59, Predicted=16.6466, Expected=16.4330
# Month=60, Predicted=16.4196, Expected=16.5840
# Run 12 — RMSE: 0.562518, MSE: 0.316426, NMSE: 0.0026332998
#
# ===== Attention(lag=5) RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.1234, Expected=13.7000
# Month=2, Predicted=13.6924, Expected=13.8140
# Month=3, Predicted=13.8064, Expected=14.3830
# Month=4, Predicted=14.3754, Expected=15.0470
# Month=5, Predicted=15.0394, Expected=15.6930
# Month=6, Predicted=15.6854, Expected=15.8440
# Month=7, Predicted=15.8364, Expected=15.7120
# Month=8, Predicted=15.7044, Expected=15.3130
# Month=9, Predicted=15.3054, Expected=14.7630
# Month=10, Predicted=14.7554, Expected=13.5480
# Month=11, Predicted=13.5404, Expected=13.5860
# Month=12, Predicted=13.5784, Expected=14.5160
# Month=13, Predicted=14.5084, Expected=14.3830
# Month=14, Predicted=14.3754, Expected=14.4970
# Month=15, Predicted=14.4894, Expected=14.7440
# Month=16, Predicted=14.7364, Expected=15.8060
# Month=17, Predicted=15.7984, Expected=16.5270
# Month=18, Predicted=16.5194, Expected=16.5460
# Month=19, Predicted=16.5384, Expected=16.7170
# Month=20, Predicted=16.7094, Expected=16.4330
# Month=21, Predicted=16.4254, Expected=15.7690
# Month=22, Predicted=15.7614, Expected=15.2750
# Month=23, Predicted=15.2674, Expected=15.1230
# Month=24, Predicted=15.1154, Expected=15.5410
# Month=25, Predicted=15.5334, Expected=15.8250
# Month=26, Predicted=15.8174, Expected=16.3760
# Month=27, Predicted=16.3684, Expected=16.3570
# Month=28, Predicted=16.3494, Expected=16.9070
# Month=29, Predicted=16.8994, Expected=17.0210
# Month=30, Predicted=17.0134, Expected=17.4190
# Month=31, Predicted=17.4114, Expected=17.5330
# Month=32, Predicted=17.5254, Expected=17.2680
# Month=33, Predicted=17.2604, Expected=16.6030
# Month=34, Predicted=16.5954, Expected=15.8250
# Month=35, Predicted=15.8174, Expected=15.4460
# Month=36, Predicted=15.4384, Expected=15.6360
# Month=37, Predicted=15.6284, Expected=15.6930
# Month=38, Predicted=15.6854, Expected=16.7550
# Month=39, Predicted=16.7474, Expected=16.5090
# Month=40, Predicted=16.5014, Expected=17.7230
# Month=41, Predicted=17.7154, Expected=18.6910
# Month=42, Predicted=18.6834, Expected=19.1270
# Month=43, Predicted=19.1194, Expected=19.5640
# Month=44, Predicted=19.5564, Expected=19.2030
# Month=45, Predicted=19.1954, Expected=18.2160
# Month=46, Predicted=18.2084, Expected=17.2110
# Month=47, Predicted=17.2034, Expected=16.6600
# Month=48, Predicted=16.6524, Expected=16.8310
# Month=49, Predicted=16.8234, Expected=15.7690
# Month=50, Predicted=15.7614, Expected=15.7310
# Month=51, Predicted=15.7234, Expected=15.9960
# Month=52, Predicted=15.9884, Expected=17.0210
# Month=53, Predicted=17.0134, Expected=17.5520
# Month=54, Predicted=17.5444, Expected=17.8370
# Month=55, Predicted=17.8294, Expected=17.8560
# Month=56, Predicted=17.8484, Expected=17.5710
# Month=57, Predicted=17.5634, Expected=17.0780
# Month=58, Predicted=17.0704, Expected=16.6600
# Month=59, Predicted=16.6524, Expected=16.4330
# Month=60, Predicted=16.4254, Expected=16.5840
# Run 13 — RMSE: 0.561819, MSE: 0.315640, NMSE: 0.0026277903
#
# ===== Attention(lag=5) RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.1177, Expected=13.7000
# Month=2, Predicted=13.6867, Expected=13.8140
# Month=3, Predicted=13.8007, Expected=14.3830
# Month=4, Predicted=14.3697, Expected=15.0470
# Month=5, Predicted=15.0337, Expected=15.6930
# Month=6, Predicted=15.6797, Expected=15.8440
# Month=7, Predicted=15.8307, Expected=15.7120
# Month=8, Predicted=15.6987, Expected=15.3130
# Month=9, Predicted=15.2997, Expected=14.7630
# Month=10, Predicted=14.7497, Expected=13.5480
# Month=11, Predicted=13.5347, Expected=13.5860
# Month=12, Predicted=13.5727, Expected=14.5160
# Month=13, Predicted=14.5027, Expected=14.3830
# Month=14, Predicted=14.3697, Expected=14.4970
# Month=15, Predicted=14.4837, Expected=14.7440
# Month=16, Predicted=14.7307, Expected=15.8060
# Month=17, Predicted=15.7927, Expected=16.5270
# Month=18, Predicted=16.5137, Expected=16.5460
# Month=19, Predicted=16.5327, Expected=16.7170
# Month=20, Predicted=16.7037, Expected=16.4330
# Month=21, Predicted=16.4197, Expected=15.7690
# Month=22, Predicted=15.7557, Expected=15.2750
# Month=23, Predicted=15.2617, Expected=15.1230
# Month=24, Predicted=15.1097, Expected=15.5410
# Month=25, Predicted=15.5277, Expected=15.8250
# Month=26, Predicted=15.8117, Expected=16.3760
# Month=27, Predicted=16.3627, Expected=16.3570
# Month=28, Predicted=16.3437, Expected=16.9070
# Month=29, Predicted=16.8937, Expected=17.0210
# Month=30, Predicted=17.0077, Expected=17.4190
# Month=31, Predicted=17.4057, Expected=17.5330
# Month=32, Predicted=17.5197, Expected=17.2680
# Month=33, Predicted=17.2547, Expected=16.6030
# Month=34, Predicted=16.5897, Expected=15.8250
# Month=35, Predicted=15.8117, Expected=15.4460
# Month=36, Predicted=15.4327, Expected=15.6360
# Month=37, Predicted=15.6227, Expected=15.6930
# Month=38, Predicted=15.6797, Expected=16.7550
# Month=39, Predicted=16.7417, Expected=16.5090
# Month=40, Predicted=16.4957, Expected=17.7230
# Month=41, Predicted=17.7097, Expected=18.6910
# Month=42, Predicted=18.6777, Expected=19.1270
# Month=43, Predicted=19.1137, Expected=19.5640
# Month=44, Predicted=19.5507, Expected=19.2030
# Month=45, Predicted=19.1897, Expected=18.2160
# Month=46, Predicted=18.2027, Expected=17.2110
# Month=47, Predicted=17.1977, Expected=16.6600
# Month=48, Predicted=16.6467, Expected=16.8310
# Month=49, Predicted=16.8177, Expected=15.7690
# Month=50, Predicted=15.7557, Expected=15.7310
# Month=51, Predicted=15.7177, Expected=15.9960
# Month=52, Predicted=15.9827, Expected=17.0210
# Month=53, Predicted=17.0077, Expected=17.5520
# Month=54, Predicted=17.5387, Expected=17.8370
# Month=55, Predicted=17.8237, Expected=17.8560
# Month=56, Predicted=17.8427, Expected=17.5710
# Month=57, Predicted=17.5577, Expected=17.0780
# Month=58, Predicted=17.0647, Expected=16.6600
# Month=59, Predicted=16.6467, Expected=16.4330
# Month=60, Predicted=16.4197, Expected=16.5840
# Run 14 — RMSE: 0.562514, MSE: 0.316422, NMSE: 0.0026332711
#
# ===== Attention(lag=5) RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.1083, Expected=13.7000
# Month=2, Predicted=13.6773, Expected=13.8140
# Month=3, Predicted=13.7913, Expected=14.3830
# Month=4, Predicted=14.3603, Expected=15.0470
# Month=5, Predicted=15.0243, Expected=15.6930
# Month=6, Predicted=15.6703, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.6893, Expected=15.3130
# Month=9, Predicted=15.2903, Expected=14.7630
# Month=10, Predicted=14.7403, Expected=13.5480
# Month=11, Predicted=13.5253, Expected=13.5860
# Month=12, Predicted=13.5633, Expected=14.5160
# Month=13, Predicted=14.4933, Expected=14.3830
# Month=14, Predicted=14.3603, Expected=14.4970
# Month=15, Predicted=14.4743, Expected=14.7440
# Month=16, Predicted=14.7213, Expected=15.8060
# Month=17, Predicted=15.7833, Expected=16.5270
# Month=18, Predicted=16.5043, Expected=16.5460
# Month=19, Predicted=16.5233, Expected=16.7170
# Month=20, Predicted=16.6943, Expected=16.4330
# Month=21, Predicted=16.4103, Expected=15.7690
# Month=22, Predicted=15.7463, Expected=15.2750
# Month=23, Predicted=15.2523, Expected=15.1230
# Month=24, Predicted=15.1003, Expected=15.5410
# Month=25, Predicted=15.5183, Expected=15.8250
# Month=26, Predicted=15.8023, Expected=16.3760
# Month=27, Predicted=16.3533, Expected=16.3570
# Month=28, Predicted=16.3343, Expected=16.9070
# Month=29, Predicted=16.8843, Expected=17.0210
# Month=30, Predicted=16.9983, Expected=17.4190
# Month=31, Predicted=17.3963, Expected=17.5330
# Month=32, Predicted=17.5103, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5803, Expected=15.8250
# Month=35, Predicted=15.8023, Expected=15.4460
# Month=36, Predicted=15.4233, Expected=15.6360
# Month=37, Predicted=15.6133, Expected=15.6930
# Month=38, Predicted=15.6703, Expected=16.7550
# Month=39, Predicted=16.7323, Expected=16.5090
# Month=40, Predicted=16.4863, Expected=17.7230
# Month=41, Predicted=17.7003, Expected=18.6910
# Month=42, Predicted=18.6683, Expected=19.1270
# Month=43, Predicted=19.1043, Expected=19.5640
# Month=44, Predicted=19.5413, Expected=19.2030
# Month=45, Predicted=19.1803, Expected=18.2160
# Month=46, Predicted=18.1933, Expected=17.2110
# Month=47, Predicted=17.1883, Expected=16.6600
# Month=48, Predicted=16.6373, Expected=16.8310
# Month=49, Predicted=16.8083, Expected=15.7690
# Month=50, Predicted=15.7463, Expected=15.7310
# Month=51, Predicted=15.7083, Expected=15.9960
# Month=52, Predicted=15.9733, Expected=17.0210
# Month=53, Predicted=16.9983, Expected=17.5520
# Month=54, Predicted=17.5293, Expected=17.8370
# Month=55, Predicted=17.8143, Expected=17.8560
# Month=56, Predicted=17.8333, Expected=17.5710
# Month=57, Predicted=17.5483, Expected=17.0780
# Month=58, Predicted=17.0553, Expected=16.6600
# Month=59, Predicted=16.6373, Expected=16.4330
# Month=60, Predicted=16.4103, Expected=16.5840
# Run 15 — RMSE: 0.563765, MSE: 0.317831, NMSE: 0.0026431367
#
# ===== Attention(lag=5) RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1083, Expected=13.7000
# Month=2, Predicted=13.6773, Expected=13.8140
# Month=3, Predicted=13.7913, Expected=14.3830
# Month=4, Predicted=14.3603, Expected=15.0470
# Month=5, Predicted=15.0243, Expected=15.6930
# Month=6, Predicted=15.6703, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.6893, Expected=15.3130
# Month=9, Predicted=15.2903, Expected=14.7630
# Month=10, Predicted=14.7403, Expected=13.5480
# Month=11, Predicted=13.5253, Expected=13.5860
# Month=12, Predicted=13.5633, Expected=14.5160
# Month=13, Predicted=14.4933, Expected=14.3830
# Month=14, Predicted=14.3603, Expected=14.4970
# Month=15, Predicted=14.4743, Expected=14.7440
# Month=16, Predicted=14.7213, Expected=15.8060
# Month=17, Predicted=15.7833, Expected=16.5270
# Month=18, Predicted=16.5043, Expected=16.5460
# Month=19, Predicted=16.5233, Expected=16.7170
# Month=20, Predicted=16.6943, Expected=16.4330
# Month=21, Predicted=16.4103, Expected=15.7690
# Month=22, Predicted=15.7463, Expected=15.2750
# Month=23, Predicted=15.2523, Expected=15.1230
# Month=24, Predicted=15.1003, Expected=15.5410
# Month=25, Predicted=15.5183, Expected=15.8250
# Month=26, Predicted=15.8023, Expected=16.3760
# Month=27, Predicted=16.3533, Expected=16.3570
# Month=28, Predicted=16.3343, Expected=16.9070
# Month=29, Predicted=16.8843, Expected=17.0210
# Month=30, Predicted=16.9983, Expected=17.4190
# Month=31, Predicted=17.3963, Expected=17.5330
# Month=32, Predicted=17.5103, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5803, Expected=15.8250
# Month=35, Predicted=15.8023, Expected=15.4460
# Month=36, Predicted=15.4233, Expected=15.6360
# Month=37, Predicted=15.6133, Expected=15.6930
# Month=38, Predicted=15.6703, Expected=16.7550
# Month=39, Predicted=16.7323, Expected=16.5090
# Month=40, Predicted=16.4863, Expected=17.7230
# Month=41, Predicted=17.7003, Expected=18.6910
# Month=42, Predicted=18.6683, Expected=19.1270
# Month=43, Predicted=19.1043, Expected=19.5640
# Month=44, Predicted=19.5413, Expected=19.2030
# Month=45, Predicted=19.1803, Expected=18.2160
# Month=46, Predicted=18.1933, Expected=17.2110
# Month=47, Predicted=17.1883, Expected=16.6600
# Month=48, Predicted=16.6373, Expected=16.8310
# Month=49, Predicted=16.8083, Expected=15.7690
# Month=50, Predicted=15.7463, Expected=15.7310
# Month=51, Predicted=15.7083, Expected=15.9960
# Month=52, Predicted=15.9733, Expected=17.0210
# Month=53, Predicted=16.9983, Expected=17.5520
# Month=54, Predicted=17.5293, Expected=17.8370
# Month=55, Predicted=17.8143, Expected=17.8560
# Month=56, Predicted=17.8333, Expected=17.5710
# Month=57, Predicted=17.5483, Expected=17.0780
# Month=58, Predicted=17.0553, Expected=16.6600
# Month=59, Predicted=16.6373, Expected=16.4330
# Month=60, Predicted=16.4103, Expected=16.5840
# Run 16 — RMSE: 0.563766, MSE: 0.317832, NMSE: 0.0026431425
#
# ===== Attention(lag=5) RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.1174, Expected=13.7000
# Month=2, Predicted=13.6864, Expected=13.8140
# Month=3, Predicted=13.8004, Expected=14.3830
# Month=4, Predicted=14.3694, Expected=15.0470
# Month=5, Predicted=15.0334, Expected=15.6930
# Month=6, Predicted=15.6794, Expected=15.8440
# Month=7, Predicted=15.8304, Expected=15.7120
# Month=8, Predicted=15.6984, Expected=15.3130
# Month=9, Predicted=15.2994, Expected=14.7630
# Month=10, Predicted=14.7494, Expected=13.5480
# Month=11, Predicted=13.5344, Expected=13.5860
# Month=12, Predicted=13.5724, Expected=14.5160
# Month=13, Predicted=14.5024, Expected=14.3830
# Month=14, Predicted=14.3694, Expected=14.4970
# Month=15, Predicted=14.4834, Expected=14.7440
# Month=16, Predicted=14.7304, Expected=15.8060
# Month=17, Predicted=15.7924, Expected=16.5270
# Month=18, Predicted=16.5134, Expected=16.5460
# Month=19, Predicted=16.5324, Expected=16.7170
# Month=20, Predicted=16.7034, Expected=16.4330
# Month=21, Predicted=16.4194, Expected=15.7690
# Month=22, Predicted=15.7554, Expected=15.2750
# Month=23, Predicted=15.2614, Expected=15.1230
# Month=24, Predicted=15.1094, Expected=15.5410
# Month=25, Predicted=15.5274, Expected=15.8250
# Month=26, Predicted=15.8114, Expected=16.3760
# Month=27, Predicted=16.3624, Expected=16.3570
# Month=28, Predicted=16.3434, Expected=16.9070
# Month=29, Predicted=16.8934, Expected=17.0210
# Month=30, Predicted=17.0074, Expected=17.4190
# Month=31, Predicted=17.4054, Expected=17.5330
# Month=32, Predicted=17.5194, Expected=17.2680
# Month=33, Predicted=17.2544, Expected=16.6030
# Month=34, Predicted=16.5894, Expected=15.8250
# Month=35, Predicted=15.8114, Expected=15.4460
# Month=36, Predicted=15.4324, Expected=15.6360
# Month=37, Predicted=15.6224, Expected=15.6930
# Month=38, Predicted=15.6794, Expected=16.7550
# Month=39, Predicted=16.7414, Expected=16.5090
# Month=40, Predicted=16.4954, Expected=17.7230
# Month=41, Predicted=17.7094, Expected=18.6910
# ...
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 25 — RMSE: 0.563211, MSE: 0.317206, NMSE: 0.0026387657
#
# ===== Attention(lag=5) RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.1125, Expected=13.7000
# Month=2, Predicted=13.6768, Expected=13.8140
# Month=3, Predicted=13.7877, Expected=14.3830
# Month=4, Predicted=14.3446, Expected=15.0470
# Month=5, Predicted=14.9984, Expected=15.6930
# Month=6, Predicted=15.6389, Expected=15.8440
# Month=7, Predicted=15.7946, Expected=15.7120
# Month=8, Predicted=15.6669, Expected=15.3130
# Month=9, Predicted=15.2801, Expected=14.7630
# Month=10, Predicted=14.7415, Expected=13.5480
# Month=11, Predicted=13.5472, Expected=13.5860
# Month=12, Predicted=13.5855, Expected=14.5160
# Month=13, Predicted=14.5145, Expected=14.3830
# Month=14, Predicted=14.3798, Expected=14.4970
# Month=15, Predicted=14.4890, Expected=14.7440
# Month=16, Predicted=14.7060, Expected=15.8060
# Month=17, Predicted=15.7617, Expected=16.5270
# Month=18, Predicted=16.4834, Expected=16.5460
# Month=19, Predicted=16.4997, Expected=16.7170
# Month=20, Predicted=16.6699, Expected=16.4330
# Month=21, Predicted=16.3945, Expected=15.7690
# Month=22, Predicted=15.7468, Expected=15.2750
# Month=23, Predicted=15.2602, Expected=15.1230
# Month=24, Predicted=15.1092, Expected=15.5410
# Month=25, Predicted=15.5266, Expected=15.8250
# Month=26, Predicted=15.8071, Expected=16.3760
# Month=27, Predicted=16.3457, Expected=16.3570
# Month=28, Predicted=16.3184, Expected=16.9070
# Month=29, Predicted=16.8606, Expected=17.0210
# Month=30, Predicted=16.9777, Expected=17.4190
# Month=31, Predicted=17.3747, Expected=17.5330
# Month=32, Predicted=17.4925, Expected=17.2680
# Month=33, Predicted=17.2314, Expected=16.6030
# Month=34, Predicted=16.5810, Expected=15.8250
# Month=35, Predicted=15.8135, Expected=15.4460
# Month=36, Predicted=15.4382, Expected=15.6360
# Month=37, Predicted=15.6280, Expected=15.6930
# Month=38, Predicted=15.6832, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4799, Expected=17.7230
# Month=41, Predicted=17.6821, Expected=18.6910
# Month=42, Predicted=18.6451, Expected=19.1270
# Month=43, Predicted=19.0759, Expected=19.5640
# Month=44, Predicted=19.5165, Expected=19.2030
# Month=45, Predicted=19.1586, Expected=18.2160
# Month=46, Predicted=18.2006, Expected=17.2110
# Month=47, Predicted=17.2100, Expected=16.6600
# Month=48, Predicted=16.6626, Expected=16.8310
# Month=49, Predicted=16.8338, Expected=15.7690
# Month=50, Predicted=15.7788, Expected=15.7310
# Month=51, Predicted=15.7338, Expected=15.9960
# Month=52, Predicted=15.9880, Expected=17.0210
# Month=53, Predicted=17.0064, Expected=17.5520
# Month=54, Predicted=17.5363, Expected=17.8370
# Month=55, Predicted=17.7905, Expected=17.8560
# Month=56, Predicted=17.8086, Expected=17.5710
# Month=57, Predicted=17.5323, Expected=17.0780
# Month=58, Predicted=17.0520, Expected=16.6600
# Month=59, Predicted=16.6410, Expected=16.4330
# Month=60, Predicted=16.4170, Expected=16.5840
# Run 26 — RMSE: 0.564635, MSE: 0.318813, NMSE: 0.0026785176
#
# ===== Attention(lag=5) RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 27 — RMSE: 0.563215, MSE: 0.317212, NMSE: 0.0026388025
#
# ===== Attention(lag=5) RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.1122, Expected=13.7000
# Month=2, Predicted=13.6812, Expected=13.8140
# Month=3, Predicted=13.7952, Expected=14.3830
# Month=4, Predicted=14.3642, Expected=15.0470
# Month=5, Predicted=15.0282, Expected=15.6930
# Month=6, Predicted=15.6742, Expected=15.8440
# Month=7, Predicted=15.8252, Expected=15.7120
# Month=8, Predicted=15.6932, Expected=15.3130
# Month=9, Predicted=15.2942, Expected=14.7630
# Month=10, Predicted=14.7442, Expected=13.5480
# Month=11, Predicted=13.5292, Expected=13.5860
# Month=12, Predicted=13.5672, Expected=14.5160
# Month=13, Predicted=14.4972, Expected=14.3830
# Month=14, Predicted=14.3642, Expected=14.4970
# Month=15, Predicted=14.4782, Expected=14.7440
# Month=16, Predicted=14.7252, Expected=15.8060
# Month=17, Predicted=15.7872, Expected=16.5270
# Month=18, Predicted=16.5082, Expected=16.5460
# Month=19, Predicted=16.5272, Expected=16.7170
# Month=20, Predicted=16.6982, Expected=16.4330
# Month=21, Predicted=16.4142, Expected=15.7690
# Month=22, Predicted=15.7502, Expected=15.2750
# Month=23, Predicted=15.2562, Expected=15.1230
# Month=24, Predicted=15.1042, Expected=15.5410
# Month=25, Predicted=15.5222, Expected=15.8250
# Month=26, Predicted=15.8062, Expected=16.3760
# Month=27, Predicted=16.3572, Expected=16.3570
# Month=28, Predicted=16.3382, Expected=16.9070
# Month=29, Predicted=16.8882, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.4002, Expected=17.5330
# Month=32, Predicted=17.5142, Expected=17.2680
# Month=33, Predicted=17.2492, Expected=16.6030
# Month=34, Predicted=16.5842, Expected=15.8250
# Month=35, Predicted=15.8062, Expected=15.4460
# Month=36, Predicted=15.4272, Expected=15.6360
# Month=37, Predicted=15.6172, Expected=15.6930
# Month=38, Predicted=15.6742, Expected=16.7550
# Month=39, Predicted=16.7362, Expected=16.5090
# Month=40, Predicted=16.4902, Expected=17.7230
# Month=41, Predicted=17.7042, Expected=18.6910
# Month=42, Predicted=18.6722, Expected=19.1270
# Month=43, Predicted=19.1082, Expected=19.5640
# Month=44, Predicted=19.5452, Expected=19.2030
# Month=45, Predicted=19.1842, Expected=18.2160
# Month=46, Predicted=18.1972, Expected=17.2110
# Month=47, Predicted=17.1922, Expected=16.6600
# Month=48, Predicted=16.6412, Expected=16.8310
# Month=49, Predicted=16.8122, Expected=15.7690
# Month=50, Predicted=15.7502, Expected=15.7310
# Month=51, Predicted=15.7122, Expected=15.9960
# Month=52, Predicted=15.9772, Expected=17.0210
# Month=53, Predicted=17.0022, Expected=17.5520
# Month=54, Predicted=17.5332, Expected=17.8370
# Month=55, Predicted=17.8182, Expected=17.8560
# Month=56, Predicted=17.8372, Expected=17.5710
# Month=57, Predicted=17.5522, Expected=17.0780
# Month=58, Predicted=17.0592, Expected=16.6600
# Month=59, Predicted=16.6412, Expected=16.4330
# Month=60, Predicted=16.4142, Expected=16.5840
# Run 28 — RMSE: 0.563222, MSE: 0.317219, NMSE: 0.0026388506
#
# ===== Attention(lag=5) RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.1156, Expected=13.7000
# Month=2, Predicted=13.6815, Expected=13.8140
# Month=3, Predicted=13.7943, Expected=14.3830
# Month=4, Predicted=14.3595, Expected=15.0470
# Month=5, Predicted=15.0204, Expected=15.6930
# Month=6, Predicted=15.6647, Expected=15.8440
# Month=7, Predicted=15.8171, Expected=15.7120
# Month=8, Predicted=15.6859, Expected=15.3130
# Month=9, Predicted=15.2902, Expected=14.7630
# Month=10, Predicted=14.7445, Expected=13.5480
# Month=11, Predicted=13.5382, Expected=13.5860
# Month=12, Predicted=13.5766, Expected=14.5160
# Month=13, Predicted=14.5020, Expected=14.3830
# Month=14, Predicted=14.3680, Expected=14.4970
# Month=15, Predicted=14.4795, Expected=14.7440
# Month=16, Predicted=14.7202, Expected=15.8060
# Month=17, Predicted=15.7785, Expected=16.5270
# Month=18, Predicted=16.5003, Expected=16.5460
# Month=19, Predicted=16.5188, Expected=16.7170
# Month=20, Predicted=16.6896, Expected=16.4330
# Month=21, Predicted=16.4073, Expected=15.7690
# Month=22, Predicted=15.7495, Expected=15.2750
# Month=23, Predicted=15.2599, Expected=15.1230
# Month=24, Predicted=15.1085, Expected=15.5410
# Month=25, Predicted=15.5256, Expected=15.8250
# Month=26, Predicted=15.8075, Expected=16.3760
# Month=27, Predicted=16.3543, Expected=16.3570
# Month=28, Predicted=16.3337, Expected=16.9070
# Month=29, Predicted=16.8813, Expected=17.0210
# Month=30, Predicted=16.9963, Expected=17.4190
# Month=31, Predicted=17.3939, Expected=17.5330
# Month=32, Predicted=17.5095, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5845, Expected=15.8250
# Month=35, Predicted=15.8096, Expected=15.4460
# Month=36, Predicted=15.4335, Expected=15.6360
# Month=37, Predicted=15.6232, Expected=15.6930
# Month=38, Predicted=15.6790, Expected=16.7550
# Month=39, Predicted=16.7345, Expected=16.5090
# Month=40, Predicted=16.4868, Expected=17.7230
# Month=41, Predicted=17.6951, Expected=18.6910
# Month=42, Predicted=18.6603, Expected=19.1270
# Month=43, Predicted=19.0951, Expected=19.5640
# Month=44, Predicted=19.5343, Expected=19.2030
# Month=45, Predicted=19.1737, Expected=18.2160
# Month=46, Predicted=18.1944, Expected=17.2110
# Month=47, Predicted=17.1970, Expected=16.6600
# Month=48, Predicted=16.6497, Expected=16.8310
# Month=49, Predicted=16.8219, Expected=15.7690
# Month=50, Predicted=15.7640, Expected=15.7310
# Month=51, Predicted=15.7220, Expected=15.9960
# Month=52, Predicted=15.9817, Expected=17.0210
# Month=53, Predicted=17.0006, Expected=17.5520
# Month=54, Predicted=17.5302, Expected=17.8370
# Month=55, Predicted=17.8100, Expected=17.8560
# Month=56, Predicted=17.8288, Expected=17.5710
# Month=57, Predicted=17.5457, Expected=17.0780
# Month=58, Predicted=17.0581, Expected=16.6600
# Month=59, Predicted=16.6436, Expected=16.4330
# Month=60, Predicted=16.4185, Expected=16.5840
# Run 29 — RMSE: 0.563316, MSE: 0.317325, NMSE: 0.0026520799
#
# ===== Attention(lag=5) RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 30 — RMSE: 0.563218, MSE: 0.317215, NMSE: 0.0026388260

# %%
# ============================================================
# Attention (lag=5) Summary Statistics
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=5) FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(att5_all_rmse):.10f} ± {np.var(att5_all_rmse):.15f}')
print(f'MSE:  {np.mean(att5_all_mse):.10f} ± {np.var(att5_all_mse):.15f}')
print(f'NMSE: {np.mean(att5_all_nmse):.10f} ± {np.var(att5_all_nmse):.15f}')

best_att5_idx = att5_all_rmse.index(min(att5_all_rmse))
print(f'\nBest run: {best_att5_idx+1}')
print(f'  RMSE: {att5_all_rmse[best_att5_idx]:.15f}')
print(f'  MSE:  {att5_all_mse[best_att5_idx]:.15f}')
print(f'  NMSE: {att5_all_nmse[best_att5_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att5_preds = att5_all_predictions[best_att5_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att5_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=5) — Best Run')
plt.show()
# Out:
# ===== LSTM-SNP + Attention (lag=5) FINAL RESULTS (30 runs) =====
# RMSE: 0.5634914816 ± 0.000005166428507
# MSE:  0.3175278162 ± 0.000006684598101
# NMSE: 0.0026420389 ± 0.000000000480110
#
# Best run: 13
#   RMSE: 0.561818585903665
#   MSE:  0.315640123466794
#   NMSE: 0.002627790326334

# %% [markdown]
# # LSTM-SNP + Attention (lag=10)

# %%
# Redefine supervised data with lag=10

lag10 = 10
supervised_lag10 = timeseries_to_supervised(diff_values, lag10)

train10, test10 = supervised_lag10[:-60], supervised_lag10[-60:]

scaler10 = MinMaxScaler(feature_range=(-1, 1))
scaler10.fit(train10)

train10_scaled = scaler10.transform(train10)
test10_scaled = scaler10.transform(test10)

X_train10 = train10_scaled[:, :-1].reshape((-1, lag10, 1))
y_train10 = train10_scaled[:, -1]

X_test10 = test10_scaled[:, :-1].reshape((-1, lag10, 1))
y_test10 = test10_scaled[:, -1]

print(f"X_train10 shape: {X_train10.shape}")  # (samples, 10, 1)
print(f"X_test10 shape:  {X_test10.shape}")   # (60, 10, 1)
# Out:
# X_train10 shape: (539, 10, 1)
# X_test10 shape:  (60, 10, 1)

# %%
att10_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att10_model_check.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (1, None, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn_1 (RNN)                     │ (1, None, 8)           │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_attention_1              │ (1, 8)                 │            81 │
# │ (SimpleAttention)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 410 (1.60 KB)
#  Trainable params: 410 (1.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# LSTM-SNP + Attention (lag=10): 30-Run Protocol
# ============================================================

att10_all_rmse = []
att10_all_mse = []
att10_all_nmse = []
att10_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=10) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model (input_dim=1, lag=10 timesteps)
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train10,
            y_train10,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    model.predict(X_train10, batch_size=1, verbose=0)

    # Test predictions (single-step over lag=10 windows)
    predictions = []
    for i in range(len(test10_scaled)):
        X_input = X_test10[i].reshape(1, lag10, 1)
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling: reconstruct full row [x1..x10, yhat]
        new_row = list(X_test10[i].flatten()) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler10.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train10) + i]

        predictions.append(inverted)

        expected = raw_values[len(train10) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att10_all_rmse.append(rmse)
    att10_all_mse.append(mse)
    att10_all_nmse.append(nmse)
    att10_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== Attention(lag=10) RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.1122, Expected=13.7000
# Month=2, Predicted=13.6812, Expected=13.8140
# Month=3, Predicted=13.7952, Expected=14.3830
# Month=4, Predicted=14.3642, Expected=15.0470
# Month=5, Predicted=15.0282, Expected=15.6930
# Month=6, Predicted=15.6742, Expected=15.8440
# Month=7, Predicted=15.8252, Expected=15.7120
# Month=8, Predicted=15.6932, Expected=15.3130
# Month=9, Predicted=15.2942, Expected=14.7630
# Month=10, Predicted=14.7442, Expected=13.5480
# Month=11, Predicted=13.5292, Expected=13.5860
# Month=12, Predicted=13.5672, Expected=14.5160
# Month=13, Predicted=14.4972, Expected=14.3830
# Month=14, Predicted=14.3642, Expected=14.4970
# Month=15, Predicted=14.4782, Expected=14.7440
# Month=16, Predicted=14.7252, Expected=15.8060
# Month=17, Predicted=15.7872, Expected=16.5270
# Month=18, Predicted=16.5082, Expected=16.5460
# Month=19, Predicted=16.5272, Expected=16.7170
# Month=20, Predicted=16.6982, Expected=16.4330
# Month=21, Predicted=16.4142, Expected=15.7690
# Month=22, Predicted=15.7502, Expected=15.2750
# Month=23, Predicted=15.2562, Expected=15.1230
# Month=24, Predicted=15.1042, Expected=15.5410
# Month=25, Predicted=15.5222, Expected=15.8250
# Month=26, Predicted=15.8062, Expected=16.3760
# Month=27, Predicted=16.3572, Expected=16.3570
# Month=28, Predicted=16.3382, Expected=16.9070
# Month=29, Predicted=16.8882, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.4002, Expected=17.5330
# Month=32, Predicted=17.5142, Expected=17.2680
# Month=33, Predicted=17.2492, Expected=16.6030
# Month=34, Predicted=16.5842, Expected=15.8250
# Month=35, Predicted=15.8062, Expected=15.4460
# Month=36, Predicted=15.4272, Expected=15.6360
# Month=37, Predicted=15.6172, Expected=15.6930
# Month=38, Predicted=15.6742, Expected=16.7550
# Month=39, Predicted=16.7362, Expected=16.5090
# Month=40, Predicted=16.4902, Expected=17.7230
# Month=41, Predicted=17.7042, Expected=18.6910
# Month=42, Predicted=18.6722, Expected=19.1270
# Month=43, Predicted=19.1082, Expected=19.5640
# Month=44, Predicted=19.5452, Expected=19.2030
# Month=45, Predicted=19.1842, Expected=18.2160
# Month=46, Predicted=18.1972, Expected=17.2110
# Month=47, Predicted=17.1922, Expected=16.6600
# Month=48, Predicted=16.6412, Expected=16.8310
# Month=49, Predicted=16.8122, Expected=15.7690
# Month=50, Predicted=15.7502, Expected=15.7310
# Month=51, Predicted=15.7122, Expected=15.9960
# Month=52, Predicted=15.9772, Expected=17.0210
# Month=53, Predicted=17.0022, Expected=17.5520
# Month=54, Predicted=17.5332, Expected=17.8370
# Month=55, Predicted=17.8182, Expected=17.8560
# Month=56, Predicted=17.8372, Expected=17.5710
# Month=57, Predicted=17.5522, Expected=17.0780
# Month=58, Predicted=17.0592, Expected=16.6600
# Month=59, Predicted=16.6412, Expected=16.4330
# Month=60, Predicted=16.4142, Expected=16.5840
# Run 1 — RMSE: 0.563224, MSE: 0.317221, NMSE: 0.0026388667
#
# ===== Attention(lag=10) RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.1083, Expected=13.7000
# Month=2, Predicted=13.6773, Expected=13.8140
# Month=3, Predicted=13.7913, Expected=14.3830
# Month=4, Predicted=14.3603, Expected=15.0470
# Month=5, Predicted=15.0243, Expected=15.6930
# Month=6, Predicted=15.6703, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.6893, Expected=15.3130
# Month=9, Predicted=15.2903, Expected=14.7630
# Month=10, Predicted=14.7403, Expected=13.5480
# Month=11, Predicted=13.5253, Expected=13.5860
# Month=12, Predicted=13.5633, Expected=14.5160
# Month=13, Predicted=14.4933, Expected=14.3830
# Month=14, Predicted=14.3603, Expected=14.4970
# Month=15, Predicted=14.4743, Expected=14.7440
# Month=16, Predicted=14.7213, Expected=15.8060
# Month=17, Predicted=15.7833, Expected=16.5270
# Month=18, Predicted=16.5043, Expected=16.5460
# Month=19, Predicted=16.5233, Expected=16.7170
# Month=20, Predicted=16.6943, Expected=16.4330
# Month=21, Predicted=16.4103, Expected=15.7690
# Month=22, Predicted=15.7463, Expected=15.2750
# Month=23, Predicted=15.2523, Expected=15.1230
# Month=24, Predicted=15.1003, Expected=15.5410
# Month=25, Predicted=15.5183, Expected=15.8250
# Month=26, Predicted=15.8023, Expected=16.3760
# Month=27, Predicted=16.3533, Expected=16.3570
# Month=28, Predicted=16.3343, Expected=16.9070
# Month=29, Predicted=16.8843, Expected=17.0210
# Month=30, Predicted=16.9983, Expected=17.4190
# Month=31, Predicted=17.3963, Expected=17.5330
# Month=32, Predicted=17.5103, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5803, Expected=15.8250
# Month=35, Predicted=15.8023, Expected=15.4460
# Month=36, Predicted=15.4233, Expected=15.6360
# Month=37, Predicted=15.6133, Expected=15.6930
# Month=38, Predicted=15.6703, Expected=16.7550
# Month=39, Predicted=16.7323, Expected=16.5090
# Month=40, Predicted=16.4863, Expected=17.7230
# Month=41, Predicted=17.7003, Expected=18.6910
# Month=42, Predicted=18.6683, Expected=19.1270
# Month=43, Predicted=19.1043, Expected=19.5640
# Month=44, Predicted=19.5413, Expected=19.2030
# Month=45, Predicted=19.1803, Expected=18.2160
# Month=46, Predicted=18.1933, Expected=17.2110
# Month=47, Predicted=17.1883, Expected=16.6600
# Month=48, Predicted=16.6373, Expected=16.8310
# Month=49, Predicted=16.8083, Expected=15.7690
# Month=50, Predicted=15.7463, Expected=15.7310
# Month=51, Predicted=15.7083, Expected=15.9960
# Month=52, Predicted=15.9733, Expected=17.0210
# Month=53, Predicted=16.9983, Expected=17.5520
# Month=54, Predicted=17.5293, Expected=17.8370
# Month=55, Predicted=17.8143, Expected=17.8560
# Month=56, Predicted=17.8333, Expected=17.5710
# Month=57, Predicted=17.5483, Expected=17.0780
# Month=58, Predicted=17.0553, Expected=16.6600
# Month=59, Predicted=16.6373, Expected=16.4330
# Month=60, Predicted=16.4103, Expected=16.5840
# Run 2 — RMSE: 0.563766, MSE: 0.317832, NMSE: 0.0026431417
#
# ===== Attention(lag=10) RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.1059, Expected=13.7000
# Month=2, Predicted=13.6749, Expected=13.8140
# Month=3, Predicted=13.7889, Expected=14.3830
# Month=4, Predicted=14.3579, Expected=15.0470
# Month=5, Predicted=15.0219, Expected=15.6930
# Month=6, Predicted=15.6679, Expected=15.8440
# Month=7, Predicted=15.8189, Expected=15.7120
# Month=8, Predicted=15.6869, Expected=15.3130
# Month=9, Predicted=15.2879, Expected=14.7630
# Month=10, Predicted=14.7379, Expected=13.5480
# Month=11, Predicted=13.5229, Expected=13.5860
# Month=12, Predicted=13.5609, Expected=14.5160
# Month=13, Predicted=14.4909, Expected=14.3830
# Month=14, Predicted=14.3579, Expected=14.4970
# Month=15, Predicted=14.4719, Expected=14.7440
# Month=16, Predicted=14.7189, Expected=15.8060
# Month=17, Predicted=15.7809, Expected=16.5270
# Month=18, Predicted=16.5019, Expected=16.5460
# Month=19, Predicted=16.5209, Expected=16.7170
# Month=20, Predicted=16.6919, Expected=16.4330
# Month=21, Predicted=16.4079, Expected=15.7690
# Month=22, Predicted=15.7439, Expected=15.2750
# Month=23, Predicted=15.2499, Expected=15.1230
# Month=24, Predicted=15.0979, Expected=15.5410
# Month=25, Predicted=15.5159, Expected=15.8250
# Month=26, Predicted=15.7999, Expected=16.3760
# Month=27, Predicted=16.3509, Expected=16.3570
# Month=28, Predicted=16.3319, Expected=16.9070
# Month=29, Predicted=16.8819, Expected=17.0210
# Month=30, Predicted=16.9959, Expected=17.4190
# Month=31, Predicted=17.3939, Expected=17.5330
# Month=32, Predicted=17.5079, Expected=17.2680
# Month=33, Predicted=17.2429, Expected=16.6030
# Month=34, Predicted=16.5779, Expected=15.8250
# Month=35, Predicted=15.7999, Expected=15.4460
# Month=36, Predicted=15.4209, Expected=15.6360
# Month=37, Predicted=15.6109, Expected=15.6930
# Month=38, Predicted=15.6679, Expected=16.7550
# Month=39, Predicted=16.7299, Expected=16.5090
# Month=40, Predicted=16.4839, Expected=17.7230
# Month=41, Predicted=17.6979, Expected=18.6910
# Month=42, Predicted=18.6659, Expected=19.1270
# Month=43, Predicted=19.1019, Expected=19.5640
# Month=44, Predicted=19.5389, Expected=19.2030
# Month=45, Predicted=19.1779, Expected=18.2160
# Month=46, Predicted=18.1909, Expected=17.2110
# Month=47, Predicted=17.1859, Expected=16.6600
# Month=48, Predicted=16.6349, Expected=16.8310
# Month=49, Predicted=16.8059, Expected=15.7690
# Month=50, Predicted=15.7439, Expected=15.7310
# Month=51, Predicted=15.7059, Expected=15.9960
# Month=52, Predicted=15.9709, Expected=17.0210
# Month=53, Predicted=16.9959, Expected=17.5520
# Month=54, Predicted=17.5269, Expected=17.8370
# Month=55, Predicted=17.8119, Expected=17.8560
# Month=56, Predicted=17.8309, Expected=17.5710
# Month=57, Predicted=17.5459, Expected=17.0780
# Month=58, Predicted=17.0529, Expected=16.6600
# Month=59, Predicted=16.6349, Expected=16.4330
# Month=60, Predicted=16.4079, Expected=16.5840
# Run 3 — RMSE: 0.564120, MSE: 0.318231, NMSE: 0.0026459392
#
# ===== Attention(lag=10) RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.1059, Expected=13.7000
# Month=2, Predicted=13.6749, Expected=13.8140
# Month=3, Predicted=13.7889, Expected=14.3830
# Month=4, Predicted=14.3579, Expected=15.0470
# Month=5, Predicted=15.0219, Expected=15.6930
# Month=6, Predicted=15.6679, Expected=15.8440
# Month=7, Predicted=15.8189, Expected=15.7120
# Month=8, Predicted=15.6869, Expected=15.3130
# Month=9, Predicted=15.2879, Expected=14.7630
# Month=10, Predicted=14.7379, Expected=13.5480
# Month=11, Predicted=13.5229, Expected=13.5860
# Month=12, Predicted=13.5609, Expected=14.5160
# Month=13, Predicted=14.4909, Expected=14.3830
# Month=14, Predicted=14.3579, Expected=14.4970
# Month=15, Predicted=14.4719, Expected=14.7440
# Month=16, Predicted=14.7189, Expected=15.8060
# Month=17, Predicted=15.7809, Expected=16.5270
# Month=18, Predicted=16.5019, Expected=16.5460
# Month=19, Predicted=16.5209, Expected=16.7170
# Month=20, Predicted=16.6919, Expected=16.4330
# Month=21, Predicted=16.4079, Expected=15.7690
# Month=22, Predicted=15.7439, Expected=15.2750
# Month=23, Predicted=15.2499, Expected=15.1230
# Month=24, Predicted=15.0979, Expected=15.5410
# Month=25, Predicted=15.5159, Expected=15.8250
# Month=26, Predicted=15.7999, Expected=16.3760
# Month=27, Predicted=16.3509, Expected=16.3570
# Month=28, Predicted=16.3319, Expected=16.9070
# Month=29, Predicted=16.8819, Expected=17.0210
# Month=30, Predicted=16.9959, Expected=17.4190
# Month=31, Predicted=17.3939, Expected=17.5330
# Month=32, Predicted=17.5079, Expected=17.2680
# Month=33, Predicted=17.2429, Expected=16.6030
# Month=34, Predicted=16.5779, Expected=15.8250
# Month=35, Predicted=15.7999, Expected=15.4460
# Month=36, Predicted=15.4209, Expected=15.6360
# Month=37, Predicted=15.6109, Expected=15.6930
# Month=38, Predicted=15.6679, Expected=16.7550
# Month=39, Predicted=16.7299, Expected=16.5090
# Month=40, Predicted=16.4839, Expected=17.7230
# Month=41, Predicted=17.6979, Expected=18.6910
# Month=42, Predicted=18.6659, Expected=19.1270
# Month=43, Predicted=19.1019, Expected=19.5640
# Month=44, Predicted=19.5389, Expected=19.2030
# Month=45, Predicted=19.1779, Expected=18.2160
# Month=46, Predicted=18.1909, Expected=17.2110
# Month=47, Predicted=17.1859, Expected=16.6600
# Month=48, Predicted=16.6349, Expected=16.8310
# Month=49, Predicted=16.8059, Expected=15.7690
# Month=50, Predicted=15.7439, Expected=15.7310
# Month=51, Predicted=15.7059, Expected=15.9960
# Month=52, Predicted=15.9709, Expected=17.0210
# Month=53, Predicted=16.9959, Expected=17.5520
# Month=54, Predicted=17.5269, Expected=17.8370
# Month=55, Predicted=17.8119, Expected=17.8560
# Month=56, Predicted=17.8309, Expected=17.5710
# Month=57, Predicted=17.5459, Expected=17.0780
# Month=58, Predicted=17.0529, Expected=16.6600
# Month=59, Predicted=16.6349, Expected=16.4330
# Month=60, Predicted=16.4079, Expected=16.5840
# Run 4 — RMSE: 0.564117, MSE: 0.318229, NMSE: 0.0026459184
#
# ===== Attention(lag=10) RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.1225, Expected=13.7000
# Month=2, Predicted=13.6915, Expected=13.8140
# Month=3, Predicted=13.8055, Expected=14.3830
# Month=4, Predicted=14.3745, Expected=15.0470
# Month=5, Predicted=15.0385, Expected=15.6930
# Month=6, Predicted=15.6845, Expected=15.8440
# Month=7, Predicted=15.8355, Expected=15.7120
# Month=8, Predicted=15.7035, Expected=15.3130
# Month=9, Predicted=15.3045, Expected=14.7630
# Month=10, Predicted=14.7545, Expected=13.5480
# Month=11, Predicted=13.5395, Expected=13.5860
# Month=12, Predicted=13.5775, Expected=14.5160
# Month=13, Predicted=14.5075, Expected=14.3830
# Month=14, Predicted=14.3745, Expected=14.4970
# Month=15, Predicted=14.4885, Expected=14.7440
# Month=16, Predicted=14.7355, Expected=15.8060
# Month=17, Predicted=15.7975, Expected=16.5270
# Month=18, Predicted=16.5185, Expected=16.5460
# Month=19, Predicted=16.5375, Expected=16.7170
# Month=20, Predicted=16.7085, Expected=16.4330
# Month=21, Predicted=16.4245, Expected=15.7690
# Month=22, Predicted=15.7605, Expected=15.2750
# Month=23, Predicted=15.2665, Expected=15.1230
# Month=24, Predicted=15.1145, Expected=15.5410
# Month=25, Predicted=15.5325, Expected=15.8250
# Month=26, Predicted=15.8165, Expected=16.3760
# Month=27, Predicted=16.3675, Expected=16.3570
# Month=28, Predicted=16.3485, Expected=16.9070
# Month=29, Predicted=16.8985, Expected=17.0210
# Month=30, Predicted=17.0125, Expected=17.4190
# Month=31, Predicted=17.4105, Expected=17.5330
# Month=32, Predicted=17.5245, Expected=17.2680
# Month=33, Predicted=17.2595, Expected=16.6030
# Month=34, Predicted=16.5945, Expected=15.8250
# Month=35, Predicted=15.8165, Expected=15.4460
# Month=36, Predicted=15.4375, Expected=15.6360
# Month=37, Predicted=15.6275, Expected=15.6930
# Month=38, Predicted=15.6845, Expected=16.7550
# Month=39, Predicted=16.7465, Expected=16.5090
# Month=40, Predicted=16.5005, Expected=17.7230
# Month=41, Predicted=17.7145, Expected=18.6910
# Month=42, Predicted=18.6825, Expected=19.1270
# Month=43, Predicted=19.1185, Expected=19.5640
# Month=44, Predicted=19.5555, Expected=19.2030
# Month=45, Predicted=19.1945, Expected=18.2160
# Month=46, Predicted=18.2075, Expected=17.2110
# Month=47, Predicted=17.2025, Expected=16.6600
# Month=48, Predicted=16.6515, Expected=16.8310
# Month=49, Predicted=16.8225, Expected=15.7690
# Month=50, Predicted=15.7605, Expected=15.7310
# Month=51, Predicted=15.7225, Expected=15.9960
# Month=52, Predicted=15.9875, Expected=17.0210
# Month=53, Predicted=17.0125, Expected=17.5520
# Month=54, Predicted=17.5435, Expected=17.8370
# Month=55, Predicted=17.8285, Expected=17.8560
# Month=56, Predicted=17.8475, Expected=17.5710
# Month=57, Predicted=17.5625, Expected=17.0780
# Month=58, Predicted=17.0695, Expected=16.6600
# Month=59, Predicted=16.6515, Expected=16.4330
# Month=60, Predicted=16.4245, Expected=16.5840
# Run 5 — RMSE: 0.561927, MSE: 0.315762, NMSE: 0.0026286447
#
# ===== Attention(lag=10) RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.1084, Expected=13.7000
# Month=2, Predicted=13.6774, Expected=13.8140
# Month=3, Predicted=13.7914, Expected=14.3830
# Month=4, Predicted=14.3604, Expected=15.0470
# Month=5, Predicted=15.0244, Expected=15.6930
# Month=6, Predicted=15.6704, Expected=15.8440
# Month=7, Predicted=15.8214, Expected=15.7120
# Month=8, Predicted=15.6894, Expected=15.3130
# Month=9, Predicted=15.2904, Expected=14.7630
# Month=10, Predicted=14.7404, Expected=13.5480
# Month=11, Predicted=13.5254, Expected=13.5860
# Month=12, Predicted=13.5634, Expected=14.5160
# Month=13, Predicted=14.4934, Expected=14.3830
# Month=14, Predicted=14.3604, Expected=14.4970
# Month=15, Predicted=14.4744, Expected=14.7440
# Month=16, Predicted=14.7214, Expected=15.8060
# Month=17, Predicted=15.7834, Expected=16.5270
# Month=18, Predicted=16.5044, Expected=16.5460
# Month=19, Predicted=16.5234, Expected=16.7170
# Month=20, Predicted=16.6944, Expected=16.4330
# Month=21, Predicted=16.4104, Expected=15.7690
# Month=22, Predicted=15.7464, Expected=15.2750
# Month=23, Predicted=15.2524, Expected=15.1230
# Month=24, Predicted=15.1004, Expected=15.5410
# Month=25, Predicted=15.5184, Expected=15.8250
# Month=26, Predicted=15.8024, Expected=16.3760
# Month=27, Predicted=16.3534, Expected=16.3570
# Month=28, Predicted=16.3344, Expected=16.9070
# Month=29, Predicted=16.8844, Expected=17.0210
# Month=30, Predicted=16.9984, Expected=17.4190
# Month=31, Predicted=17.3964, Expected=17.5330
# Month=32, Predicted=17.5104, Expected=17.2680
# Month=33, Predicted=17.2454, Expected=16.6030
# Month=34, Predicted=16.5804, Expected=15.8250
# Month=35, Predicted=15.8024, Expected=15.4460
# Month=36, Predicted=15.4234, Expected=15.6360
# Month=37, Predicted=15.6134, Expected=15.6930
# Month=38, Predicted=15.6704, Expected=16.7550
# Month=39, Predicted=16.7324, Expected=16.5090
# Month=40, Predicted=16.4864, Expected=17.7230
# Month=41, Predicted=17.7004, Expected=18.6910
# Month=42, Predicted=18.6684, Expected=19.1270
# Month=43, Predicted=19.1044, Expected=19.5640
# Month=44, Predicted=19.5414, Expected=19.2030
# Month=45, Predicted=19.1804, Expected=18.2160
# Month=46, Predicted=18.1934, Expected=17.2110
# Month=47, Predicted=17.1884, Expected=16.6600
# Month=48, Predicted=16.6374, Expected=16.8310
# Month=49, Predicted=16.8084, Expected=15.7690
# Month=50, Predicted=15.7464, Expected=15.7310
# Month=51, Predicted=15.7084, Expected=15.9960
# Month=52, Predicted=15.9734, Expected=17.0210
# Month=53, Predicted=16.9984, Expected=17.5520
# Month=54, Predicted=17.5294, Expected=17.8370
# Month=55, Predicted=17.8144, Expected=17.8560
# Month=56, Predicted=17.8334, Expected=17.5710
# Month=57, Predicted=17.5484, Expected=17.0780
# Month=58, Predicted=17.0554, Expected=16.6600
# Month=59, Predicted=16.6374, Expected=16.4330
# Month=60, Predicted=16.4104, Expected=16.5840
# Run 6 — RMSE: 0.563757, MSE: 0.317822, NMSE: 0.0026430779
#
# ===== Attention(lag=10) RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.1240, Expected=13.7000
# Month=2, Predicted=13.6930, Expected=13.8140
# Month=3, Predicted=13.8070, Expected=14.3830
# Month=4, Predicted=14.3760, Expected=15.0470
# Month=5, Predicted=15.0400, Expected=15.6930
# Month=6, Predicted=15.6860, Expected=15.8440
# Month=7, Predicted=15.8370, Expected=15.7120
# Month=8, Predicted=15.7050, Expected=15.3130
# Month=9, Predicted=15.3060, Expected=14.7630
# Month=10, Predicted=14.7560, Expected=13.5480
# Month=11, Predicted=13.5410, Expected=13.5860
# Month=12, Predicted=13.5790, Expected=14.5160
# Month=13, Predicted=14.5090, Expected=14.3830
# Month=14, Predicted=14.3760, Expected=14.4970
# Month=15, Predicted=14.4900, Expected=14.7440
# Month=16, Predicted=14.7370, Expected=15.8060
# Month=17, Predicted=15.7990, Expected=16.5270
# Month=18, Predicted=16.5200, Expected=16.5460
# Month=19, Predicted=16.5390, Expected=16.7170
# Month=20, Predicted=16.7100, Expected=16.4330
# Month=21, Predicted=16.4260, Expected=15.7690
# Month=22, Predicted=15.7620, Expected=15.2750
# Month=23, Predicted=15.2680, Expected=15.1230
# Month=24, Predicted=15.1160, Expected=15.5410
# Month=25, Predicted=15.5340, Expected=15.8250
# Month=26, Predicted=15.8180, Expected=16.3760
# Month=27, Predicted=16.3690, Expected=16.3570
# Month=28, Predicted=16.3500, Expected=16.9070
# Month=29, Predicted=16.9000, Expected=17.0210
# Month=30, Predicted=17.0140, Expected=17.4190
# Month=31, Predicted=17.4120, Expected=17.5330
# Month=32, Predicted=17.5260, Expected=17.2680
# Month=33, Predicted=17.2610, Expected=16.6030
# Month=34, Predicted=16.5960, Expected=15.8250
# Month=35, Predicted=15.8180, Expected=15.4460
# Month=36, Predicted=15.4390, Expected=15.6360
# Month=37, Predicted=15.6290, Expected=15.6930
# Month=38, Predicted=15.6860, Expected=16.7550
# Month=39, Predicted=16.7480, Expected=16.5090
# Month=40, Predicted=16.5020, Expected=17.7230
# Month=41, Predicted=17.7160, Expected=18.6910
# Month=42, Predicted=18.6840, Expected=19.1270
# Month=43, Predicted=19.1200, Expected=19.5640
# Month=44, Predicted=19.5570, Expected=19.2030
# Month=45, Predicted=19.1960, Expected=18.2160
# Month=46, Predicted=18.2090, Expected=17.2110
# Month=47, Predicted=17.2040, Expected=16.6600
# Month=48, Predicted=16.6530, Expected=16.8310
# Month=49, Predicted=16.8240, Expected=15.7690
# Month=50, Predicted=15.7620, Expected=15.7310
# Month=51, Predicted=15.7240, Expected=15.9960
# Month=52, Predicted=15.9890, Expected=17.0210
# Month=53, Predicted=17.0140, Expected=17.5520
# Month=54, Predicted=17.5450, Expected=17.8370
# Month=55, Predicted=17.8300, Expected=17.8560
# Month=56, Predicted=17.8490, Expected=17.5710
# Month=57, Predicted=17.5640, Expected=17.0780
# Month=58, Predicted=17.0710, Expected=16.6600
# Month=59, Predicted=16.6530, Expected=16.4330
# Month=60, Predicted=16.4260, Expected=16.5840
# Run 7 — RMSE: 0.561748, MSE: 0.315561, NMSE: 0.0026272372
#
# ===== Attention(lag=10) RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.1175, Expected=13.7000
# Month=2, Predicted=13.6865, Expected=13.8140
# Month=3, Predicted=13.8005, Expected=14.3830
# Month=4, Predicted=14.3695, Expected=15.0470
# Month=5, Predicted=15.0335, Expected=15.6930
# Month=6, Predicted=15.6795, Expected=15.8440
# Month=7, Predicted=15.8305, Expected=15.7120
# Month=8, Predicted=15.6985, Expected=15.3130
# Month=9, Predicted=15.2995, Expected=14.7630
# Month=10, Predicted=14.7495, Expected=13.5480
# Month=11, Predicted=13.5345, Expected=13.5860
# Month=12, Predicted=13.5725, Expected=14.5160
# Month=13, Predicted=14.5025, Expected=14.3830
# Month=14, Predicted=14.3695, Expected=14.4970
# Month=15, Predicted=14.4835, Expected=14.7440
# Month=16, Predicted=14.7305, Expected=15.8060
# Month=17, Predicted=15.7925, Expected=16.5270
# Month=18, Predicted=16.5135, Expected=16.5460
# Month=19, Predicted=16.5325, Expected=16.7170
# Month=20, Predicted=16.7035, Expected=16.4330
# Month=21, Predicted=16.4195, Expected=15.7690
# Month=22, Predicted=15.7555, Expected=15.2750
# Month=23, Predicted=15.2615, Expected=15.1230
# Month=24, Predicted=15.1095, Expected=15.5410
# Month=25, Predicted=15.5275, Expected=15.8250
# Month=26, Predicted=15.8115, Expected=16.3760
# Month=27, Predicted=16.3625, Expected=16.3570
# Month=28, Predicted=16.3435, Expected=16.9070
# Month=29, Predicted=16.8935, Expected=17.0210
# Month=30, Predicted=17.0075, Expected=17.4190
# Month=31, Predicted=17.4055, Expected=17.5330
# Month=32, Predicted=17.5195, Expected=17.2680
# Month=33, Predicted=17.2545, Expected=16.6030
# Month=34, Predicted=16.5895, Expected=15.8250
# Month=35, Predicted=15.8115, Expected=15.4460
# Month=36, Predicted=15.4325, Expected=15.6360
# Month=37, Predicted=15.6225, Expected=15.6930
# Month=38, Predicted=15.6795, Expected=16.7550
# Month=39, Predicted=16.7415, Expected=16.5090
# Month=40, Predicted=16.4955, Expected=17.7230
# Month=41, Predicted=17.7095, Expected=18.6910
# Month=42, Predicted=18.6775, Expected=19.1270
# Month=43, Predicted=19.1135, Expected=19.5640
# Month=44, Predicted=19.5505, Expected=19.2030
# Month=45, Predicted=19.1895, Expected=18.2160
# Month=46, Predicted=18.2025, Expected=17.2110
# Month=47, Predicted=17.1975, Expected=16.6600
# Month=48, Predicted=16.6465, Expected=16.8310
# Month=49, Predicted=16.8175, Expected=15.7690
# Month=50, Predicted=15.7555, Expected=15.7310
# Month=51, Predicted=15.7175, Expected=15.9960
# Month=52, Predicted=15.9825, Expected=17.0210
# Month=53, Predicted=17.0075, Expected=17.5520
# Month=54, Predicted=17.5385, Expected=17.8370
# Month=55, Predicted=17.8235, Expected=17.8560
# Month=56, Predicted=17.8425, Expected=17.5710
# Month=57, Predicted=17.5575, Expected=17.0780
# Month=58, Predicted=17.0645, Expected=16.6600
# Month=59, Predicted=16.6465, Expected=16.4330
# Month=60, Predicted=16.4195, Expected=16.5840
# Run 8 — RMSE: 0.562534, MSE: 0.316444, NMSE: 0.0026334289
#
# ===== Attention(lag=10) RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.1083, Expected=13.7000
# Month=2, Predicted=13.6773, Expected=13.8140
# Month=3, Predicted=13.7913, Expected=14.3830
# Month=4, Predicted=14.3603, Expected=15.0470
# Month=5, Predicted=15.0243, Expected=15.6930
# Month=6, Predicted=15.6703, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.6893, Expected=15.3130
# Month=9, Predicted=15.2903, Expected=14.7630
# Month=10, Predicted=14.7403, Expected=13.5480
# Month=11, Predicted=13.5253, Expected=13.5860
# Month=12, Predicted=13.5633, Expected=14.5160
# Month=13, Predicted=14.4933, Expected=14.3830
# Month=14, Predicted=14.3603, Expected=14.4970
# Month=15, Predicted=14.4743, Expected=14.7440
# Month=16, Predicted=14.7213, Expected=15.8060
# Month=17, Predicted=15.7833, Expected=16.5270
# Month=18, Predicted=16.5043, Expected=16.5460
# Month=19, Predicted=16.5233, Expected=16.7170
# Month=20, Predicted=16.6943, Expected=16.4330
# Month=21, Predicted=16.4103, Expected=15.7690
# Month=22, Predicted=15.7463, Expected=15.2750
# Month=23, Predicted=15.2523, Expected=15.1230
# Month=24, Predicted=15.1003, Expected=15.5410
# Month=25, Predicted=15.5183, Expected=15.8250
# Month=26, Predicted=15.8023, Expected=16.3760
# Month=27, Predicted=16.3533, Expected=16.3570
# Month=28, Predicted=16.3343, Expected=16.9070
# Month=29, Predicted=16.8843, Expected=17.0210
# Month=30, Predicted=16.9983, Expected=17.4190
# Month=31, Predicted=17.3963, Expected=17.5330
# Month=32, Predicted=17.5103, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5803, Expected=15.8250
# Month=35, Predicted=15.8023, Expected=15.4460
# Month=36, Predicted=15.4233, Expected=15.6360
# Month=37, Predicted=15.6133, Expected=15.6930
# Month=38, Predicted=15.6703, Expected=16.7550
# Month=39, Predicted=16.7323, Expected=16.5090
# Month=40, Predicted=16.4863, Expected=17.7230
# Month=41, Predicted=17.7003, Expected=18.6910
# Month=42, Predicted=18.6683, Expected=19.1270
# Month=43, Predicted=19.1043, Expected=19.5640
# Month=44, Predicted=19.5413, Expected=19.2030
# Month=45, Predicted=19.1803, Expected=18.2160
# Month=46, Predicted=18.1933, Expected=17.2110
# Month=47, Predicted=17.1883, Expected=16.6600
# Month=48, Predicted=16.6373, Expected=16.8310
# Month=49, Predicted=16.8083, Expected=15.7690
# Month=50, Predicted=15.7463, Expected=15.7310
# Month=51, Predicted=15.7083, Expected=15.9960
# Month=52, Predicted=15.9733, Expected=17.0210
# Month=53, Predicted=16.9983, Expected=17.5520
# Month=54, Predicted=17.5293, Expected=17.8370
# Month=55, Predicted=17.8143, Expected=17.8560
# Month=56, Predicted=17.8333, Expected=17.5710
# Month=57, Predicted=17.5483, Expected=17.0780
# Month=58, Predicted=17.0553, Expected=16.6600
# Month=59, Predicted=16.6373, Expected=16.4330
# Month=60, Predicted=16.4103, Expected=16.5840
# Run 9 — RMSE: 0.563767, MSE: 0.317834, NMSE: 0.0026431549
#
# ===== Attention(lag=10) RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.1083, Expected=13.7000
# Month=2, Predicted=13.6773, Expected=13.8140
# Month=3, Predicted=13.7913, Expected=14.3830
# Month=4, Predicted=14.3603, Expected=15.0470
# Month=5, Predicted=15.0243, Expected=15.6930
# Month=6, Predicted=15.6703, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.6893, Expected=15.3130
# Month=9, Predicted=15.2903, Expected=14.7630
# Month=10, Predicted=14.7403, Expected=13.5480
# Month=11, Predicted=13.5253, Expected=13.5860
# Month=12, Predicted=13.5633, Expected=14.5160
# Month=13, Predicted=14.4933, Expected=14.3830
# Month=14, Predicted=14.3603, Expected=14.4970
# Month=15, Predicted=14.4743, Expected=14.7440
# Month=16, Predicted=14.7213, Expected=15.8060
# Month=17, Predicted=15.7833, Expected=16.5270
# Month=18, Predicted=16.5043, Expected=16.5460
# Month=19, Predicted=16.5233, Expected=16.7170
# Month=20, Predicted=16.6943, Expected=16.4330
# Month=21, Predicted=16.4103, Expected=15.7690
# Month=22, Predicted=15.7463, Expected=15.2750
# Month=23, Predicted=15.2523, Expected=15.1230
# Month=24, Predicted=15.1003, Expected=15.5410
# Month=25, Predicted=15.5183, Expected=15.8250
# Month=26, Predicted=15.8023, Expected=16.3760
# Month=27, Predicted=16.3533, Expected=16.3570
# Month=28, Predicted=16.3343, Expected=16.9070
# Month=29, Predicted=16.8843, Expected=17.0210
# Month=30, Predicted=16.9983, Expected=17.4190
# Month=31, Predicted=17.3963, Expected=17.5330
# Month=32, Predicted=17.5103, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5803, Expected=15.8250
# Month=35, Predicted=15.8023, Expected=15.4460
# Month=36, Predicted=15.4233, Expected=15.6360
# Month=37, Predicted=15.6133, Expected=15.6930
# Month=38, Predicted=15.6703, Expected=16.7550
# Month=39, Predicted=16.7323, Expected=16.5090
# Month=40, Predicted=16.4863, Expected=17.7230
# Month=41, Predicted=17.7003, Expected=18.6910
# Month=42, Predicted=18.6683, Expected=19.1270
# Month=43, Predicted=19.1043, Expected=19.5640
# Month=44, Predicted=19.5413, Expected=19.2030
# Month=45, Predicted=19.1803, Expected=18.2160
# Month=46, Predicted=18.1933, Expected=17.2110
# Month=47, Predicted=17.1883, Expected=16.6600
# Month=48, Predicted=16.6373, Expected=16.8310
# Month=49, Predicted=16.8083, Expected=15.7690
# Month=50, Predicted=15.7463, Expected=15.7310
# Month=51, Predicted=15.7083, Expected=15.9960
# Month=52, Predicted=15.9733, Expected=17.0210
# Month=53, Predicted=16.9983, Expected=17.5520
# Month=54, Predicted=17.5293, Expected=17.8370
# Month=55, Predicted=17.8143, Expected=17.8560
# Month=56, Predicted=17.8333, Expected=17.5710
# Month=57, Predicted=17.5483, Expected=17.0780
# Month=58, Predicted=17.0553, Expected=16.6600
# Month=59, Predicted=16.6373, Expected=16.4330
# Month=60, Predicted=16.4103, Expected=16.5840
# Run 10 — RMSE: 0.563765, MSE: 0.317831, NMSE: 0.0026431361
#
# ===== Attention(lag=10) RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.1177, Expected=13.7000
# Month=2, Predicted=13.6867, Expected=13.8140
# Month=3, Predicted=13.8007, Expected=14.3830
# Month=4, Predicted=14.3697, Expected=15.0470
# Month=5, Predicted=15.0337, Expected=15.6930
# Month=6, Predicted=15.6797, Expected=15.8440
# Month=7, Predicted=15.8307, Expected=15.7120
# Month=8, Predicted=15.6987, Expected=15.3130
# Month=9, Predicted=15.2997, Expected=14.7630
# Month=10, Predicted=14.7497, Expected=13.5480
# Month=11, Predicted=13.5347, Expected=13.5860
# Month=12, Predicted=13.5727, Expected=14.5160
# Month=13, Predicted=14.5027, Expected=14.3830
# Month=14, Predicted=14.3697, Expected=14.4970
# Month=15, Predicted=14.4837, Expected=14.7440
# Month=16, Predicted=14.7307, Expected=15.8060
# Month=17, Predicted=15.7927, Expected=16.5270
# Month=18, Predicted=16.5137, Expected=16.5460
# Month=19, Predicted=16.5327, Expected=16.7170
# Month=20, Predicted=16.7037, Expected=16.4330
# Month=21, Predicted=16.4197, Expected=15.7690
# Month=22, Predicted=15.7557, Expected=15.2750
# Month=23, Predicted=15.2617, Expected=15.1230
# Month=24, Predicted=15.1097, Expected=15.5410
# Month=25, Predicted=15.5277, Expected=15.8250
# Month=26, Predicted=15.8117, Expected=16.3760
# Month=27, Predicted=16.3627, Expected=16.3570
# Month=28, Predicted=16.3437, Expected=16.9070
# Month=29, Predicted=16.8937, Expected=17.0210
# Month=30, Predicted=17.0077, Expected=17.4190
# Month=31, Predicted=17.4057, Expected=17.5330
# Month=32, Predicted=17.5197, Expected=17.2680
# Month=33, Predicted=17.2547, Expected=16.6030
# Month=34, Predicted=16.5897, Expected=15.8250
# Month=35, Predicted=15.8117, Expected=15.4460
# Month=36, Predicted=15.4327, Expected=15.6360
# Month=37, Predicted=15.6227, Expected=15.6930
# Month=38, Predicted=15.6797, Expected=16.7550
# Month=39, Predicted=16.7417, Expected=16.5090
# Month=40, Predicted=16.4957, Expected=17.7230
# Month=41, Predicted=17.7097, Expected=18.6910
# Month=42, Predicted=18.6777, Expected=19.1270
# Month=43, Predicted=19.1137, Expected=19.5640
# Month=44, Predicted=19.5507, Expected=19.2030
# Month=45, Predicted=19.1897, Expected=18.2160
# Month=46, Predicted=18.2027, Expected=17.2110
# Month=47, Predicted=17.1977, Expected=16.6600
# Month=48, Predicted=16.6467, Expected=16.8310
# Month=49, Predicted=16.8177, Expected=15.7690
# Month=50, Predicted=15.7557, Expected=15.7310
# Month=51, Predicted=15.7177, Expected=15.9960
# Month=52, Predicted=15.9827, Expected=17.0210
# Month=53, Predicted=17.0077, Expected=17.5520
# Month=54, Predicted=17.5387, Expected=17.8370
# Month=55, Predicted=17.8237, Expected=17.8560
# Month=56, Predicted=17.8427, Expected=17.5710
# Month=57, Predicted=17.5577, Expected=17.0780
# Month=58, Predicted=17.0647, Expected=16.6600
# Month=59, Predicted=16.6467, Expected=16.4330
# Month=60, Predicted=16.4197, Expected=16.5840
# Run 11 — RMSE: 0.562511, MSE: 0.316419, NMSE: 0.0026332507
#
# ===== Attention(lag=10) RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.1059, Expected=13.7000
# Month=2, Predicted=13.6749, Expected=13.8140
# Month=3, Predicted=13.7889, Expected=14.3830
# Month=4, Predicted=14.3579, Expected=15.0470
# Month=5, Predicted=15.0219, Expected=15.6930
# Month=6, Predicted=15.6679, Expected=15.8440
# Month=7, Predicted=15.8189, Expected=15.7120
# Month=8, Predicted=15.6869, Expected=15.3130
# Month=9, Predicted=15.2879, Expected=14.7630
# Month=10, Predicted=14.7379, Expected=13.5480
# Month=11, Predicted=13.5229, Expected=13.5860
# Month=12, Predicted=13.5609, Expected=14.5160
# Month=13, Predicted=14.4909, Expected=14.3830
# Month=14, Predicted=14.3579, Expected=14.4970
# Month=15, Predicted=14.4719, Expected=14.7440
# Month=16, Predicted=14.7189, Expected=15.8060
# Month=17, Predicted=15.7809, Expected=16.5270
# Month=18, Predicted=16.5019, Expected=16.5460
# Month=19, Predicted=16.5209, Expected=16.7170
# Month=20, Predicted=16.6919, Expected=16.4330
# Month=21, Predicted=16.4079, Expected=15.7690
# Month=22, Predicted=15.7439, Expected=15.2750
# Month=23, Predicted=15.2499, Expected=15.1230
# Month=24, Predicted=15.0979, Expected=15.5410
# Month=25, Predicted=15.5159, Expected=15.8250
# Month=26, Predicted=15.7999, Expected=16.3760
# Month=27, Predicted=16.3509, Expected=16.3570
# Month=28, Predicted=16.3319, Expected=16.9070
# Month=29, Predicted=16.8819, Expected=17.0210
# Month=30, Predicted=16.9959, Expected=17.4190
# Month=31, Predicted=17.3939, Expected=17.5330
# Month=32, Predicted=17.5079, Expected=17.2680
# Month=33, Predicted=17.2429, Expected=16.6030
# Month=34, Predicted=16.5779, Expected=15.8250
# Month=35, Predicted=15.7999, Expected=15.4460
# Month=36, Predicted=15.4209, Expected=15.6360
# Month=37, Predicted=15.6109, Expected=15.6930
# Month=38, Predicted=15.6679, Expected=16.7550
# Month=39, Predicted=16.7299, Expected=16.5090
# Month=40, Predicted=16.4839, Expected=17.7230
# Month=41, Predicted=17.6979, Expected=18.6910
# Month=42, Predicted=18.6659, Expected=19.1270
# Month=43, Predicted=19.1019, Expected=19.5640
# Month=44, Predicted=19.5389, Expected=19.2030
# Month=45, Predicted=19.1779, Expected=18.2160
# Month=46, Predicted=18.1909, Expected=17.2110
# Month=47, Predicted=17.1859, Expected=16.6600
# Month=48, Predicted=16.6349, Expected=16.8310
# Month=49, Predicted=16.8059, Expected=15.7690
# Month=50, Predicted=15.7439, Expected=15.7310
# Month=51, Predicted=15.7059, Expected=15.9960
# Month=52, Predicted=15.9709, Expected=17.0210
# Month=53, Predicted=16.9959, Expected=17.5520
# Month=54, Predicted=17.5269, Expected=17.8370
# Month=55, Predicted=17.8119, Expected=17.8560
# Month=56, Predicted=17.8309, Expected=17.5710
# Month=57, Predicted=17.5459, Expected=17.0780
# Month=58, Predicted=17.0529, Expected=16.6600
# Month=59, Predicted=16.6349, Expected=16.4330
# Month=60, Predicted=16.4079, Expected=16.5840
# Run 12 — RMSE: 0.564117, MSE: 0.318228, NMSE: 0.0026459149
#
# ===== Attention(lag=10) RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.1122, Expected=13.7000
# Month=2, Predicted=13.6812, Expected=13.8140
# Month=3, Predicted=13.7952, Expected=14.3830
# Month=4, Predicted=14.3642, Expected=15.0470
# Month=5, Predicted=15.0282, Expected=15.6930
# Month=6, Predicted=15.6742, Expected=15.8440
# Month=7, Predicted=15.8252, Expected=15.7120
# Month=8, Predicted=15.6932, Expected=15.3130
# Month=9, Predicted=15.2942, Expected=14.7630
# Month=10, Predicted=14.7442, Expected=13.5480
# Month=11, Predicted=13.5292, Expected=13.5860
# Month=12, Predicted=13.5672, Expected=14.5160
# Month=13, Predicted=14.4972, Expected=14.3830
# Month=14, Predicted=14.3642, Expected=14.4970
# Month=15, Predicted=14.4782, Expected=14.7440
# Month=16, Predicted=14.7252, Expected=15.8060
# Month=17, Predicted=15.7872, Expected=16.5270
# Month=18, Predicted=16.5082, Expected=16.5460
# Month=19, Predicted=16.5272, Expected=16.7170
# Month=20, Predicted=16.6982, Expected=16.4330
# Month=21, Predicted=16.4142, Expected=15.7690
# Month=22, Predicted=15.7502, Expected=15.2750
# Month=23, Predicted=15.2562, Expected=15.1230
# Month=24, Predicted=15.1042, Expected=15.5410
# Month=25, Predicted=15.5222, Expected=15.8250
# Month=26, Predicted=15.8062, Expected=16.3760
# Month=27, Predicted=16.3572, Expected=16.3570
# Month=28, Predicted=16.3382, Expected=16.9070
# Month=29, Predicted=16.8882, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.4002, Expected=17.5330
# Month=32, Predicted=17.5142, Expected=17.2680
# Month=33, Predicted=17.2492, Expected=16.6030
# Month=34, Predicted=16.5842, Expected=15.8250
# Month=35, Predicted=15.8062, Expected=15.4460
# Month=36, Predicted=15.4272, Expected=15.6360
# Month=37, Predicted=15.6172, Expected=15.6930
# Month=38, Predicted=15.6742, Expected=16.7550
# Month=39, Predicted=16.7362, Expected=16.5090
# Month=40, Predicted=16.4902, Expected=17.7230
# Month=41, Predicted=17.7042, Expected=18.6910
# Month=42, Predicted=18.6722, Expected=19.1270
# Month=43, Predicted=19.1082, Expected=19.5640
# Month=44, Predicted=19.5452, Expected=19.2030
# Month=45, Predicted=19.1842, Expected=18.2160
# Month=46, Predicted=18.1972, Expected=17.2110
# Month=47, Predicted=17.1922, Expected=16.6600
# Month=48, Predicted=16.6412, Expected=16.8310
# Month=49, Predicted=16.8122, Expected=15.7690
# Month=50, Predicted=15.7502, Expected=15.7310
# Month=51, Predicted=15.7122, Expected=15.9960
# Month=52, Predicted=15.9772, Expected=17.0210
# Month=53, Predicted=17.0022, Expected=17.5520
# Month=54, Predicted=17.5332, Expected=17.8370
# Month=55, Predicted=17.8182, Expected=17.8560
# Month=56, Predicted=17.8372, Expected=17.5710
# Month=57, Predicted=17.5522, Expected=17.0780
# Month=58, Predicted=17.0592, Expected=16.6600
# Month=59, Predicted=16.6412, Expected=16.4330
# Month=60, Predicted=16.4142, Expected=16.5840
# Run 13 — RMSE: 0.563228, MSE: 0.317226, NMSE: 0.0026389039
#
# ===== Attention(lag=10) RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.1176, Expected=13.7000
# Month=2, Predicted=13.6866, Expected=13.8140
# Month=3, Predicted=13.8006, Expected=14.3830
# Month=4, Predicted=14.3696, Expected=15.0470
# Month=5, Predicted=15.0336, Expected=15.6930
# Month=6, Predicted=15.6796, Expected=15.8440
# Month=7, Predicted=15.8306, Expected=15.7120
# Month=8, Predicted=15.6986, Expected=15.3130
# Month=9, Predicted=15.2996, Expected=14.7630
# Month=10, Predicted=14.7496, Expected=13.5480
# Month=11, Predicted=13.5346, Expected=13.5860
# Month=12, Predicted=13.5726, Expected=14.5160
# Month=13, Predicted=14.5026, Expected=14.3830
# Month=14, Predicted=14.3696, Expected=14.4970
# Month=15, Predicted=14.4836, Expected=14.7440
# Month=16, Predicted=14.7306, Expected=15.8060
# Month=17, Predicted=15.7926, Expected=16.5270
# Month=18, Predicted=16.5136, Expected=16.5460
# Month=19, Predicted=16.5326, Expected=16.7170
# Month=20, Predicted=16.7036, Expected=16.4330
# Month=21, Predicted=16.4196, Expected=15.7690
# Month=22, Predicted=15.7556, Expected=15.2750
# Month=23, Predicted=15.2616, Expected=15.1230
# Month=24, Predicted=15.1096, Expected=15.5410
# Month=25, Predicted=15.5276, Expected=15.8250
# Month=26, Predicted=15.8116, Expected=16.3760
# Month=27, Predicted=16.3626, Expected=16.3570
# Month=28, Predicted=16.3436, Expected=16.9070
# Month=29, Predicted=16.8936, Expected=17.0210
# Month=30, Predicted=17.0076, Expected=17.4190
# Month=31, Predicted=17.4056, Expected=17.5330
# Month=32, Predicted=17.5196, Expected=17.2680
# Month=33, Predicted=17.2546, Expected=16.6030
# Month=34, Predicted=16.5896, Expected=15.8250
# Month=35, Predicted=15.8116, Expected=15.4460
# Month=36, Predicted=15.4326, Expected=15.6360
# Month=37, Predicted=15.6226, Expected=15.6930
# Month=38, Predicted=15.6796, Expected=16.7550
# Month=39, Predicted=16.7416, Expected=16.5090
# Month=40, Predicted=16.4956, Expected=17.7230
# Month=41, Predicted=17.7096, Expected=18.6910
# Month=42, Predicted=18.6776, Expected=19.1270
# Month=43, Predicted=19.1136, Expected=19.5640
# Month=44, Predicted=19.5506, Expected=19.2030
# Month=45, Predicted=19.1896, Expected=18.2160
# Month=46, Predicted=18.2026, Expected=17.2110
# Month=47, Predicted=17.1976, Expected=16.6600
# Month=48, Predicted=16.6466, Expected=16.8310
# Month=49, Predicted=16.8176, Expected=15.7690
# Month=50, Predicted=15.7556, Expected=15.7310
# Month=51, Predicted=15.7176, Expected=15.9960
# Month=52, Predicted=15.9826, Expected=17.0210
# Month=53, Predicted=17.0076, Expected=17.5520
# Month=54, Predicted=17.5386, Expected=17.8370
# Month=55, Predicted=17.8236, Expected=17.8560
# Month=56, Predicted=17.8426, Expected=17.5710
# Month=57, Predicted=17.5576, Expected=17.0780
# Month=58, Predicted=17.0646, Expected=16.6600
# Month=59, Predicted=16.6466, Expected=16.4330
# Month=60, Predicted=16.4196, Expected=16.5840
# Run 14 — RMSE: 0.562517, MSE: 0.316425, NMSE: 0.0026332932
#
# ===== Attention(lag=10) RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.1122, Expected=13.7000
# Month=2, Predicted=13.6812, Expected=13.8140
# Month=3, Predicted=13.7952, Expected=14.3830
# Month=4, Predicted=14.3642, Expected=15.0470
# Month=5, Predicted=15.0282, Expected=15.6930
# Month=6, Predicted=15.6742, Expected=15.8440
# Month=7, Predicted=15.8252, Expected=15.7120
# Month=8, Predicted=15.6932, Expected=15.3130
# Month=9, Predicted=15.2942, Expected=14.7630
# Month=10, Predicted=14.7442, Expected=13.5480
# Month=11, Predicted=13.5292, Expected=13.5860
# Month=12, Predicted=13.5672, Expected=14.5160
# Month=13, Predicted=14.4972, Expected=14.3830
# Month=14, Predicted=14.3642, Expected=14.4970
# Month=15, Predicted=14.4782, Expected=14.7440
# Month=16, Predicted=14.7252, Expected=15.8060
# Month=17, Predicted=15.7872, Expected=16.5270
# Month=18, Predicted=16.5082, Expected=16.5460
# Month=19, Predicted=16.5272, Expected=16.7170
# Month=20, Predicted=16.6982, Expected=16.4330
# Month=21, Predicted=16.4142, Expected=15.7690
# Month=22, Predicted=15.7502, Expected=15.2750
# Month=23, Predicted=15.2562, Expected=15.1230
# Month=24, Predicted=15.1042, Expected=15.5410
# Month=25, Predicted=15.5222, Expected=15.8250
# Month=26, Predicted=15.8062, Expected=16.3760
# Month=27, Predicted=16.3572, Expected=16.3570
# Month=28, Predicted=16.3382, Expected=16.9070
# Month=29, Predicted=16.8882, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.4002, Expected=17.5330
# Month=32, Predicted=17.5142, Expected=17.2680
# Month=33, Predicted=17.2492, Expected=16.6030
# Month=34, Predicted=16.5842, Expected=15.8250
# Month=35, Predicted=15.8062, Expected=15.4460
# Month=36, Predicted=15.4272, Expected=15.6360
# Month=37, Predicted=15.6172, Expected=15.6930
# Month=38, Predicted=15.6742, Expected=16.7550
# Month=39, Predicted=16.7362, Expected=16.5090
# Month=40, Predicted=16.4902, Expected=17.7230
# Month=41, Predicted=17.7042, Expected=18.6910
# Month=42, Predicted=18.6722, Expected=19.1270
# Month=43, Predicted=19.1082, Expected=19.5640
# Month=44, Predicted=19.5452, Expected=19.2030
# Month=45, Predicted=19.1842, Expected=18.2160
# Month=46, Predicted=18.1972, Expected=17.2110
# Month=47, Predicted=17.1922, Expected=16.6600
# Month=48, Predicted=16.6412, Expected=16.8310
# Month=49, Predicted=16.8122, Expected=15.7690
# Month=50, Predicted=15.7502, Expected=15.7310
# Month=51, Predicted=15.7122, Expected=15.9960
# Month=52, Predicted=15.9772, Expected=17.0210
# Month=53, Predicted=17.0022, Expected=17.5520
# Month=54, Predicted=17.5332, Expected=17.8370
# Month=55, Predicted=17.8182, Expected=17.8560
# Month=56, Predicted=17.8372, Expected=17.5710
# Month=57, Predicted=17.5522, Expected=17.0780
# Month=58, Predicted=17.0592, Expected=16.6600
# Month=59, Predicted=16.6412, Expected=16.4330
# Month=60, Predicted=16.4142, Expected=16.5840
# Run 15 — RMSE: 0.563225, MSE: 0.317223, NMSE: 0.0026388782
#
# ===== Attention(lag=10) RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1059, Expected=13.7000
# Month=2, Predicted=13.6749, Expected=13.8140
# Month=3, Predicted=13.7889, Expected=14.3830
# Month=4, Predicted=14.3579, Expected=15.0470
# Month=5, Predicted=15.0219, Expected=15.6930
# Month=6, Predicted=15.6679, Expected=15.8440
# Month=7, Predicted=15.8189, Expected=15.7120
# Month=8, Predicted=15.6869, Expected=15.3130
# Month=9, Predicted=15.2879, Expected=14.7630
# Month=10, Predicted=14.7379, Expected=13.5480
# Month=11, Predicted=13.5229, Expected=13.5860
# Month=12, Predicted=13.5609, Expected=14.5160
# Month=13, Predicted=14.4909, Expected=14.3830
# Month=14, Predicted=14.3579, Expected=14.4970
# Month=15, Predicted=14.4719, Expected=14.7440
# Month=16, Predicted=14.7189, Expected=15.8060
# Month=17, Predicted=15.7809, Expected=16.5270
# Month=18, Predicted=16.5019, Expected=16.5460
# Month=19, Predicted=16.5209, Expected=16.7170
# Month=20, Predicted=16.6919, Expected=16.4330
# Month=21, Predicted=16.4079, Expected=15.7690
# Month=22, Predicted=15.7439, Expected=15.2750
# Month=23, Predicted=15.2499, Expected=15.1230
# Month=24, Predicted=15.0979, Expected=15.5410
# Month=25, Predicted=15.5159, Expected=15.8250
# Month=26, Predicted=15.7999, Expected=16.3760
# Month=27, Predicted=16.3509, Expected=16.3570
# Month=28, Predicted=16.3319, Expected=16.9070
# Month=29, Predicted=16.8819, Expected=17.0210
# Month=30, Predicted=16.9959, Expected=17.4190
# Month=31, Predicted=17.3939, Expected=17.5330
# Month=32, Predicted=17.5079, Expected=17.2680
# Month=33, Predicted=17.2429, Expected=16.6030
# Month=34, Predicted=16.5779, Expected=15.8250
# Month=35, Predicted=15.7999, Expected=15.4460
# Month=36, Predicted=15.4209, Expected=15.6360
# Month=37, Predicted=15.6109, Expected=15.6930
# Month=38, Predicted=15.6679, Expected=16.7550
# Month=39, Predicted=16.7299, Expected=16.5090
# Month=40, Predicted=16.4839, Expected=17.7230
# Month=41, Predicted=17.6979, Expected=18.6910
# Month=42, Predicted=18.6659, Expected=19.1270
# Month=43, Predicted=19.1019, Expected=19.5640
# Month=44, Predicted=19.5389, Expected=19.2030
# Month=45, Predicted=19.1779, Expected=18.2160
# Month=46, Predicted=18.1909, Expected=17.2110
# Month=47, Predicted=17.1859, Expected=16.6600
# Month=48, Predicted=16.6349, Expected=16.8310
# Month=49, Predicted=16.8059, Expected=15.7690
# Month=50, Predicted=15.7439, Expected=15.7310
# Month=51, Predicted=15.7059, Expected=15.9960
# Month=52, Predicted=15.9709, Expected=17.0210
# Month=53, Predicted=16.9959, Expected=17.5520
# Month=54, Predicted=17.5269, Expected=17.8370
# Month=55, Predicted=17.8119, Expected=17.8560
# Month=56, Predicted=17.8309, Expected=17.5710
# Month=57, Predicted=17.5459, Expected=17.0780
# Month=58, Predicted=17.0529, Expected=16.6600
# Month=59, Predicted=16.6349, Expected=16.4330
# Month=60, Predicted=16.4079, Expected=16.5840
# Run 16 — RMSE: 0.564114, MSE: 0.318225, NMSE: 0.0026458928
#
# ===== Attention(lag=10) RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.1122, Expected=13.7000
# Month=2, Predicted=13.6812, Expected=13.8140
# Month=3, Predicted=13.7952, Expected=14.3830
# Month=4, Predicted=14.3642, Expected=15.0470
# Month=5, Predicted=15.0282, Expected=15.6930
# Month=6, Predicted=15.6742, Expected=15.8440
# Month=7, Predicted=15.8252, Expected=15.7120
# Month=8, Predicted=15.6932, Expected=15.3130
# Month=9, Predicted=15.2942, Expected=14.7630
# Month=10, Predicted=14.7442, Expected=13.5480
# Month=11, Predicted=13.5292, Expected=13.5860
# Month=12, Predicted=13.5672, Expected=14.5160
# Month=13, Predicted=14.4972, Expected=14.3830
# Month=14, Predicted=14.3642, Expected=14.4970
# Month=15, Predicted=14.4782, Expected=14.7440
# Month=16, Predicted=14.7252, Expected=15.8060
# Month=17, Predicted=15.7872, Expected=16.5270
# Month=18, Predicted=16.5082, Expected=16.5460
# Month=19, Predicted=16.5272, Expected=16.7170
# Month=20, Predicted=16.6982, Expected=16.4330
# Month=21, Predicted=16.4142, Expected=15.7690
# Month=22, Predicted=15.7502, Expected=15.2750
# Month=23, Predicted=15.2562, Expected=15.1230
# Month=24, Predicted=15.1042, Expected=15.5410
# Month=25, Predicted=15.5222, Expected=15.8250
# Month=26, Predicted=15.8062, Expected=16.3760
# Month=27, Predicted=16.3572, Expected=16.3570
# Month=28, Predicted=16.3382, Expected=16.9070
# Month=29, Predicted=16.8882, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.4002, Expected=17.5330
# Month=32, Predicted=17.5142, Expected=17.2680
# Month=33, Predicted=17.2492, Expected=16.6030
# Month=34, Predicted=16.5842, Expected=15.8250
# Month=35, Predicted=15.8062, Expected=15.4460
# Month=36, Predicted=15.4272, Expected=15.6360
# Month=37, Predicted=15.6172, Expected=15.6930
# Month=38, Predicted=15.6742, Expected=16.7550
# Month=39, Predicted=16.7362, Expected=16.5090
# Month=40, Predicted=16.4902, Expected=17.7230
# Month=41, Predicted=17.7042, Expected=18.6910
# ...
# Month=28, Predicted=16.3437, Expected=16.9070
# Month=29, Predicted=16.8937, Expected=17.0210
# Month=30, Predicted=17.0077, Expected=17.4190
# Month=31, Predicted=17.4057, Expected=17.5330
# Month=32, Predicted=17.5197, Expected=17.2680
# Month=33, Predicted=17.2547, Expected=16.6030
# Month=34, Predicted=16.5897, Expected=15.8250
# Month=35, Predicted=15.8117, Expected=15.4460
# Month=36, Predicted=15.4327, Expected=15.6360
# Month=37, Predicted=15.6227, Expected=15.6930
# Month=38, Predicted=15.6797, Expected=16.7550
# Month=39, Predicted=16.7417, Expected=16.5090
# Month=40, Predicted=16.4957, Expected=17.7230
# Month=41, Predicted=17.7097, Expected=18.6910
# Month=42, Predicted=18.6777, Expected=19.1270
# Month=43, Predicted=19.1137, Expected=19.5640
# Month=44, Predicted=19.5507, Expected=19.2030
# Month=45, Predicted=19.1897, Expected=18.2160
# Month=46, Predicted=18.2027, Expected=17.2110
# Month=47, Predicted=17.1977, Expected=16.6600
# Month=48, Predicted=16.6467, Expected=16.8310
# Month=49, Predicted=16.8177, Expected=15.7690
# Month=50, Predicted=15.7557, Expected=15.7310
# Month=51, Predicted=15.7177, Expected=15.9960
# Month=52, Predicted=15.9827, Expected=17.0210
# Month=53, Predicted=17.0077, Expected=17.5520
# Month=54, Predicted=17.5387, Expected=17.8370
# Month=55, Predicted=17.8237, Expected=17.8560
# Month=56, Predicted=17.8427, Expected=17.5710
# Month=57, Predicted=17.5577, Expected=17.0780
# Month=58, Predicted=17.0647, Expected=16.6600
# Month=59, Predicted=16.6467, Expected=16.4330
# Month=60, Predicted=16.4197, Expected=16.5840
# Run 25 — RMSE: 0.562505, MSE: 0.316412, NMSE: 0.0026332019
#
# ===== Attention(lag=10) RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.1059, Expected=13.7000
# Month=2, Predicted=13.6749, Expected=13.8140
# Month=3, Predicted=13.7889, Expected=14.3830
# Month=4, Predicted=14.3579, Expected=15.0470
# Month=5, Predicted=15.0219, Expected=15.6930
# Month=6, Predicted=15.6679, Expected=15.8440
# Month=7, Predicted=15.8189, Expected=15.7120
# Month=8, Predicted=15.6869, Expected=15.3130
# Month=9, Predicted=15.2879, Expected=14.7630
# Month=10, Predicted=14.7379, Expected=13.5480
# Month=11, Predicted=13.5229, Expected=13.5860
# Month=12, Predicted=13.5609, Expected=14.5160
# Month=13, Predicted=14.4909, Expected=14.3830
# Month=14, Predicted=14.3579, Expected=14.4970
# Month=15, Predicted=14.4719, Expected=14.7440
# Month=16, Predicted=14.7189, Expected=15.8060
# Month=17, Predicted=15.7809, Expected=16.5270
# Month=18, Predicted=16.5019, Expected=16.5460
# Month=19, Predicted=16.5209, Expected=16.7170
# Month=20, Predicted=16.6919, Expected=16.4330
# Month=21, Predicted=16.4079, Expected=15.7690
# Month=22, Predicted=15.7439, Expected=15.2750
# Month=23, Predicted=15.2499, Expected=15.1230
# Month=24, Predicted=15.0979, Expected=15.5410
# Month=25, Predicted=15.5159, Expected=15.8250
# Month=26, Predicted=15.7999, Expected=16.3760
# Month=27, Predicted=16.3509, Expected=16.3570
# Month=28, Predicted=16.3319, Expected=16.9070
# Month=29, Predicted=16.8819, Expected=17.0210
# Month=30, Predicted=16.9959, Expected=17.4190
# Month=31, Predicted=17.3939, Expected=17.5330
# Month=32, Predicted=17.5079, Expected=17.2680
# Month=33, Predicted=17.2429, Expected=16.6030
# Month=34, Predicted=16.5779, Expected=15.8250
# Month=35, Predicted=15.7999, Expected=15.4460
# Month=36, Predicted=15.4209, Expected=15.6360
# Month=37, Predicted=15.6109, Expected=15.6930
# Month=38, Predicted=15.6679, Expected=16.7550
# Month=39, Predicted=16.7299, Expected=16.5090
# Month=40, Predicted=16.4839, Expected=17.7230
# Month=41, Predicted=17.6979, Expected=18.6910
# Month=42, Predicted=18.6659, Expected=19.1270
# Month=43, Predicted=19.1019, Expected=19.5640
# Month=44, Predicted=19.5389, Expected=19.2030
# Month=45, Predicted=19.1779, Expected=18.2160
# Month=46, Predicted=18.1909, Expected=17.2110
# Month=47, Predicted=17.1859, Expected=16.6600
# Month=48, Predicted=16.6349, Expected=16.8310
# Month=49, Predicted=16.8059, Expected=15.7690
# Month=50, Predicted=15.7439, Expected=15.7310
# Month=51, Predicted=15.7059, Expected=15.9960
# Month=52, Predicted=15.9709, Expected=17.0210
# Month=53, Predicted=16.9959, Expected=17.5520
# Month=54, Predicted=17.5269, Expected=17.8370
# Month=55, Predicted=17.8119, Expected=17.8560
# Month=56, Predicted=17.8309, Expected=17.5710
# Month=57, Predicted=17.5459, Expected=17.0780
# Month=58, Predicted=17.0529, Expected=16.6600
# Month=59, Predicted=16.6349, Expected=16.4330
# Month=60, Predicted=16.4079, Expected=16.5840
# Run 26 — RMSE: 0.564119, MSE: 0.318230, NMSE: 0.0026459289
#
# ===== Attention(lag=10) RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.1175, Expected=13.7000
# Month=2, Predicted=13.6865, Expected=13.8140
# Month=3, Predicted=13.8005, Expected=14.3830
# Month=4, Predicted=14.3695, Expected=15.0470
# Month=5, Predicted=15.0335, Expected=15.6930
# Month=6, Predicted=15.6795, Expected=15.8440
# Month=7, Predicted=15.8305, Expected=15.7120
# Month=8, Predicted=15.6985, Expected=15.3130
# Month=9, Predicted=15.2995, Expected=14.7630
# Month=10, Predicted=14.7495, Expected=13.5480
# Month=11, Predicted=13.5345, Expected=13.5860
# Month=12, Predicted=13.5725, Expected=14.5160
# Month=13, Predicted=14.5025, Expected=14.3830
# Month=14, Predicted=14.3695, Expected=14.4970
# Month=15, Predicted=14.4835, Expected=14.7440
# Month=16, Predicted=14.7305, Expected=15.8060
# Month=17, Predicted=15.7925, Expected=16.5270
# Month=18, Predicted=16.5135, Expected=16.5460
# Month=19, Predicted=16.5325, Expected=16.7170
# Month=20, Predicted=16.7035, Expected=16.4330
# Month=21, Predicted=16.4195, Expected=15.7690
# Month=22, Predicted=15.7555, Expected=15.2750
# Month=23, Predicted=15.2615, Expected=15.1230
# Month=24, Predicted=15.1095, Expected=15.5410
# Month=25, Predicted=15.5275, Expected=15.8250
# Month=26, Predicted=15.8115, Expected=16.3760
# Month=27, Predicted=16.3625, Expected=16.3570
# Month=28, Predicted=16.3435, Expected=16.9070
# Month=29, Predicted=16.8935, Expected=17.0210
# Month=30, Predicted=17.0075, Expected=17.4190
# Month=31, Predicted=17.4055, Expected=17.5330
# Month=32, Predicted=17.5195, Expected=17.2680
# Month=33, Predicted=17.2545, Expected=16.6030
# Month=34, Predicted=16.5895, Expected=15.8250
# Month=35, Predicted=15.8115, Expected=15.4460
# Month=36, Predicted=15.4325, Expected=15.6360
# Month=37, Predicted=15.6225, Expected=15.6930
# Month=38, Predicted=15.6795, Expected=16.7550
# Month=39, Predicted=16.7415, Expected=16.5090
# Month=40, Predicted=16.4955, Expected=17.7230
# Month=41, Predicted=17.7095, Expected=18.6910
# Month=42, Predicted=18.6775, Expected=19.1270
# Month=43, Predicted=19.1135, Expected=19.5640
# Month=44, Predicted=19.5505, Expected=19.2030
# Month=45, Predicted=19.1895, Expected=18.2160
# Month=46, Predicted=18.2025, Expected=17.2110
# Month=47, Predicted=17.1975, Expected=16.6600
# Month=48, Predicted=16.6465, Expected=16.8310
# Month=49, Predicted=16.8175, Expected=15.7690
# Month=50, Predicted=15.7555, Expected=15.7310
# Month=51, Predicted=15.7175, Expected=15.9960
# Month=52, Predicted=15.9825, Expected=17.0210
# Month=53, Predicted=17.0075, Expected=17.5520
# Month=54, Predicted=17.5385, Expected=17.8370
# Month=55, Predicted=17.8235, Expected=17.8560
# Month=56, Predicted=17.8425, Expected=17.5710
# Month=57, Predicted=17.5575, Expected=17.0780
# Month=58, Predicted=17.0645, Expected=16.6600
# Month=59, Predicted=16.6465, Expected=16.4330
# Month=60, Predicted=16.4195, Expected=16.5840
# Run 27 — RMSE: 0.562531, MSE: 0.316441, NMSE: 0.0026334037
#
# ===== Attention(lag=10) RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.1122, Expected=13.7000
# Month=2, Predicted=13.6812, Expected=13.8140
# Month=3, Predicted=13.7952, Expected=14.3830
# Month=4, Predicted=14.3642, Expected=15.0470
# Month=5, Predicted=15.0282, Expected=15.6930
# Month=6, Predicted=15.6742, Expected=15.8440
# Month=7, Predicted=15.8252, Expected=15.7120
# Month=8, Predicted=15.6932, Expected=15.3130
# Month=9, Predicted=15.2942, Expected=14.7630
# Month=10, Predicted=14.7442, Expected=13.5480
# Month=11, Predicted=13.5292, Expected=13.5860
# Month=12, Predicted=13.5672, Expected=14.5160
# Month=13, Predicted=14.4972, Expected=14.3830
# Month=14, Predicted=14.3642, Expected=14.4970
# Month=15, Predicted=14.4782, Expected=14.7440
# Month=16, Predicted=14.7252, Expected=15.8060
# Month=17, Predicted=15.7872, Expected=16.5270
# Month=18, Predicted=16.5082, Expected=16.5460
# Month=19, Predicted=16.5272, Expected=16.7170
# Month=20, Predicted=16.6982, Expected=16.4330
# Month=21, Predicted=16.4142, Expected=15.7690
# Month=22, Predicted=15.7502, Expected=15.2750
# Month=23, Predicted=15.2562, Expected=15.1230
# Month=24, Predicted=15.1042, Expected=15.5410
# Month=25, Predicted=15.5222, Expected=15.8250
# Month=26, Predicted=15.8062, Expected=16.3760
# Month=27, Predicted=16.3572, Expected=16.3570
# Month=28, Predicted=16.3382, Expected=16.9070
# Month=29, Predicted=16.8882, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.4002, Expected=17.5330
# Month=32, Predicted=17.5142, Expected=17.2680
# Month=33, Predicted=17.2492, Expected=16.6030
# Month=34, Predicted=16.5842, Expected=15.8250
# Month=35, Predicted=15.8062, Expected=15.4460
# Month=36, Predicted=15.4272, Expected=15.6360
# Month=37, Predicted=15.6172, Expected=15.6930
# Month=38, Predicted=15.6742, Expected=16.7550
# Month=39, Predicted=16.7362, Expected=16.5090
# Month=40, Predicted=16.4902, Expected=17.7230
# Month=41, Predicted=17.7042, Expected=18.6910
# Month=42, Predicted=18.6722, Expected=19.1270
# Month=43, Predicted=19.1082, Expected=19.5640
# Month=44, Predicted=19.5452, Expected=19.2030
# Month=45, Predicted=19.1842, Expected=18.2160
# Month=46, Predicted=18.1972, Expected=17.2110
# Month=47, Predicted=17.1922, Expected=16.6600
# Month=48, Predicted=16.6412, Expected=16.8310
# Month=49, Predicted=16.8122, Expected=15.7690
# Month=50, Predicted=15.7502, Expected=15.7310
# Month=51, Predicted=15.7122, Expected=15.9960
# Month=52, Predicted=15.9772, Expected=17.0210
# Month=53, Predicted=17.0022, Expected=17.5520
# Month=54, Predicted=17.5332, Expected=17.8370
# Month=55, Predicted=17.8182, Expected=17.8560
# Month=56, Predicted=17.8372, Expected=17.5710
# Month=57, Predicted=17.5522, Expected=17.0780
# Month=58, Predicted=17.0592, Expected=16.6600
# Month=59, Predicted=16.6412, Expected=16.4330
# Month=60, Predicted=16.4142, Expected=16.5840
# Run 28 — RMSE: 0.563225, MSE: 0.317222, NMSE: 0.0026388740
#
# ===== Attention(lag=10) RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.1050, Expected=13.7000
# Month=2, Predicted=13.6740, Expected=13.8140
# Month=3, Predicted=13.7880, Expected=14.3830
# Month=4, Predicted=14.3570, Expected=15.0470
# Month=5, Predicted=15.0210, Expected=15.6930
# Month=6, Predicted=15.6670, Expected=15.8440
# Month=7, Predicted=15.8180, Expected=15.7120
# Month=8, Predicted=15.6860, Expected=15.3130
# Month=9, Predicted=15.2870, Expected=14.7630
# Month=10, Predicted=14.7370, Expected=13.5480
# Month=11, Predicted=13.5220, Expected=13.5860
# Month=12, Predicted=13.5600, Expected=14.5160
# Month=13, Predicted=14.4900, Expected=14.3830
# Month=14, Predicted=14.3570, Expected=14.4970
# Month=15, Predicted=14.4710, Expected=14.7440
# Month=16, Predicted=14.7180, Expected=15.8060
# Month=17, Predicted=15.7800, Expected=16.5270
# Month=18, Predicted=16.5010, Expected=16.5460
# Month=19, Predicted=16.5200, Expected=16.7170
# Month=20, Predicted=16.6910, Expected=16.4330
# Month=21, Predicted=16.4070, Expected=15.7690
# Month=22, Predicted=15.7430, Expected=15.2750
# Month=23, Predicted=15.2490, Expected=15.1230
# Month=24, Predicted=15.0970, Expected=15.5410
# Month=25, Predicted=15.5150, Expected=15.8250
# Month=26, Predicted=15.7990, Expected=16.3760
# Month=27, Predicted=16.3500, Expected=16.3570
# Month=28, Predicted=16.3310, Expected=16.9070
# Month=29, Predicted=16.8810, Expected=17.0210
# Month=30, Predicted=16.9950, Expected=17.4190
# Month=31, Predicted=17.3930, Expected=17.5330
# Month=32, Predicted=17.5070, Expected=17.2680
# Month=33, Predicted=17.2420, Expected=16.6030
# Month=34, Predicted=16.5770, Expected=15.8250
# Month=35, Predicted=15.7990, Expected=15.4460
# Month=36, Predicted=15.4200, Expected=15.6360
# Month=37, Predicted=15.6100, Expected=15.6930
# Month=38, Predicted=15.6670, Expected=16.7550
# Month=39, Predicted=16.7290, Expected=16.5090
# Month=40, Predicted=16.4830, Expected=17.7230
# Month=41, Predicted=17.6970, Expected=18.6910
# Month=42, Predicted=18.6650, Expected=19.1270
# Month=43, Predicted=19.1010, Expected=19.5640
# Month=44, Predicted=19.5380, Expected=19.2030
# Month=45, Predicted=19.1770, Expected=18.2160
# Month=46, Predicted=18.1900, Expected=17.2110
# Month=47, Predicted=17.1850, Expected=16.6600
# Month=48, Predicted=16.6340, Expected=16.8310
# Month=49, Predicted=16.8050, Expected=15.7690
# Month=50, Predicted=15.7430, Expected=15.7310
# Month=51, Predicted=15.7050, Expected=15.9960
# Month=52, Predicted=15.9700, Expected=17.0210
# Month=53, Predicted=16.9950, Expected=17.5520
# Month=54, Predicted=17.5260, Expected=17.8370
# Month=55, Predicted=17.8110, Expected=17.8560
# Month=56, Predicted=17.8300, Expected=17.5710
# Month=57, Predicted=17.5450, Expected=17.0780
# Month=58, Predicted=17.0520, Expected=16.6600
# Month=59, Predicted=16.6340, Expected=16.4330
# Month=60, Predicted=16.4070, Expected=16.5840
# Run 29 — RMSE: 0.564241, MSE: 0.318368, NMSE: 0.0026468965
#
# ===== Attention(lag=10) RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.1059, Expected=13.7000
# Month=2, Predicted=13.6749, Expected=13.8140
# Month=3, Predicted=13.7889, Expected=14.3830
# Month=4, Predicted=14.3579, Expected=15.0470
# Month=5, Predicted=15.0219, Expected=15.6930
# Month=6, Predicted=15.6679, Expected=15.8440
# Month=7, Predicted=15.8189, Expected=15.7120
# Month=8, Predicted=15.6869, Expected=15.3130
# Month=9, Predicted=15.2879, Expected=14.7630
# Month=10, Predicted=14.7379, Expected=13.5480
# Month=11, Predicted=13.5229, Expected=13.5860
# Month=12, Predicted=13.5609, Expected=14.5160
# Month=13, Predicted=14.4909, Expected=14.3830
# Month=14, Predicted=14.3579, Expected=14.4970
# Month=15, Predicted=14.4719, Expected=14.7440
# Month=16, Predicted=14.7189, Expected=15.8060
# Month=17, Predicted=15.7809, Expected=16.5270
# Month=18, Predicted=16.5019, Expected=16.5460
# Month=19, Predicted=16.5209, Expected=16.7170
# Month=20, Predicted=16.6919, Expected=16.4330
# Month=21, Predicted=16.4079, Expected=15.7690
# Month=22, Predicted=15.7439, Expected=15.2750
# Month=23, Predicted=15.2499, Expected=15.1230
# Month=24, Predicted=15.0979, Expected=15.5410
# Month=25, Predicted=15.5159, Expected=15.8250
# Month=26, Predicted=15.7999, Expected=16.3760
# Month=27, Predicted=16.3509, Expected=16.3570
# Month=28, Predicted=16.3319, Expected=16.9070
# Month=29, Predicted=16.8819, Expected=17.0210
# Month=30, Predicted=16.9959, Expected=17.4190
# Month=31, Predicted=17.3939, Expected=17.5330
# Month=32, Predicted=17.5079, Expected=17.2680
# Month=33, Predicted=17.2429, Expected=16.6030
# Month=34, Predicted=16.5779, Expected=15.8250
# Month=35, Predicted=15.7999, Expected=15.4460
# Month=36, Predicted=15.4209, Expected=15.6360
# Month=37, Predicted=15.6109, Expected=15.6930
# Month=38, Predicted=15.6679, Expected=16.7550
# Month=39, Predicted=16.7299, Expected=16.5090
# Month=40, Predicted=16.4839, Expected=17.7230
# Month=41, Predicted=17.6979, Expected=18.6910
# Month=42, Predicted=18.6659, Expected=19.1270
# Month=43, Predicted=19.1019, Expected=19.5640
# Month=44, Predicted=19.5389, Expected=19.2030
# Month=45, Predicted=19.1779, Expected=18.2160
# Month=46, Predicted=18.1909, Expected=17.2110
# Month=47, Predicted=17.1859, Expected=16.6600
# Month=48, Predicted=16.6349, Expected=16.8310
# Month=49, Predicted=16.8059, Expected=15.7690
# Month=50, Predicted=15.7439, Expected=15.7310
# Month=51, Predicted=15.7059, Expected=15.9960
# Month=52, Predicted=15.9709, Expected=17.0210
# Month=53, Predicted=16.9959, Expected=17.5520
# Month=54, Predicted=17.5269, Expected=17.8370
# Month=55, Predicted=17.8119, Expected=17.8560
# Month=56, Predicted=17.8309, Expected=17.5710
# Month=57, Predicted=17.5459, Expected=17.0780
# Month=58, Predicted=17.0529, Expected=16.6600
# Month=59, Predicted=16.6349, Expected=16.4330
# Month=60, Predicted=16.4079, Expected=16.5840
# Run 30 — RMSE: 0.564119, MSE: 0.318231, NMSE: 0.0026459327

# %%
# ============================================================
# Attention (lag=10) Summary Statistics
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=10) FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(att10_all_rmse):.10f} ± {np.var(att10_all_rmse):.15f}')
print(f'MSE:  {np.mean(att10_all_mse):.10f} ± {np.var(att10_all_mse):.15f}')
print(f'NMSE: {np.mean(att10_all_nmse):.10f} ± {np.var(att10_all_nmse):.15f}')

best_att10_idx = att10_all_rmse.index(min(att10_all_rmse))
print(f'\nBest run: {best_att10_idx+1}')
print(f'  RMSE: {att10_all_rmse[best_att10_idx]:.15f}')
print(f'  MSE:  {att10_all_mse[best_att10_idx]:.15f}')
print(f'  NMSE: {att10_all_nmse[best_att10_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att10_preds = att10_all_predictions[best_att10_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att10_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=10) — Best Run')
plt.show()
# Out:
# ===== LSTM-SNP + Attention (lag=10) FINAL RESULTS (30 runs) =====
# RMSE: 0.5677613438 ± 0.000348548104382
# MSE:  0.3227014916 ± 0.000517978738313
# NMSE: 0.0026754268 ± 0.000000022743791
#
# Best run: 7
#   RMSE: 0.561748391845890
#   MSE:  0.315561255741443
#   NMSE: 0.002627237232866

# %% [markdown]
# # LSTM-SNP + Attention (lag=20)

# %%
# Redefine supervised data with lag=20

lag20 = 20
supervised_lag20 = timeseries_to_supervised(diff_values, lag20)

train20, test20 = supervised_lag20[:-60], supervised_lag20[-60:]

scaler20 = MinMaxScaler(feature_range=(-1, 1))
scaler20.fit(train20)

train20_scaled = scaler20.transform(train20)
test20_scaled = scaler20.transform(test20)

X_train20 = train20_scaled[:, :-1].reshape((-1, lag20, 1))
y_train20 = train20_scaled[:, -1]

X_test20 = test20_scaled[:, :-1].reshape((-1, lag20, 1))
y_test20 = test20_scaled[:, -1]

print(f"X_train20 shape: {X_train20.shape}")  # (samples, 20, 1)
print(f"X_test20 shape:  {X_test20.shape}")   # (60, 20, 1)
# Out:
# X_train20 shape: (539, 20, 1)
# X_test20 shape:  (60, 20, 1)

# %%
att20_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att20_model_check.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (1, None, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn_1 (RNN)                     │ (1, None, 8)           │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_attention_1              │ (1, 8)                 │            81 │
# │ (SimpleAttention)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 410 (1.60 KB)
#  Trainable params: 410 (1.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# LSTM-SNP + Attention (lag=20): 30-Run Protocol
# ============================================================

att20_all_rmse = []
att20_all_mse = []
att20_all_nmse = []
att20_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=20) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model (input_dim=1, lag=20 timesteps)
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train20,
            y_train20,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    model.predict(X_train20, batch_size=1, verbose=0)

    # Test predictions (single-step over lag=20 windows)
    predictions = []
    for i in range(len(test20_scaled)):
        X_input = X_test20[i].reshape(1, lag20, 1)
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling: reconstruct full row [x1..x20, yhat]
        new_row = list(X_test20[i].flatten()) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler20.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train20) + i]

        predictions.append(inverted)

        expected = raw_values[len(train20) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att20_all_rmse.append(rmse)
    att20_all_mse.append(mse)
    att20_all_nmse.append(nmse)
    att20_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== Attention(lag=20) RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.1115, Expected=13.7000
# Month=2, Predicted=13.6805, Expected=13.8140
# Month=3, Predicted=13.7945, Expected=14.3830
# Month=4, Predicted=14.3635, Expected=15.0470
# Month=5, Predicted=15.0275, Expected=15.6930
# Month=6, Predicted=15.6735, Expected=15.8440
# Month=7, Predicted=15.8245, Expected=15.7120
# Month=8, Predicted=15.6925, Expected=15.3130
# Month=9, Predicted=15.2935, Expected=14.7630
# Month=10, Predicted=14.7435, Expected=13.5480
# Month=11, Predicted=13.5285, Expected=13.5860
# Month=12, Predicted=13.5665, Expected=14.5160
# Month=13, Predicted=14.4965, Expected=14.3830
# Month=14, Predicted=14.3635, Expected=14.4970
# Month=15, Predicted=14.4775, Expected=14.7440
# Month=16, Predicted=14.7245, Expected=15.8060
# Month=17, Predicted=15.7865, Expected=16.5270
# Month=18, Predicted=16.5075, Expected=16.5460
# Month=19, Predicted=16.5265, Expected=16.7170
# Month=20, Predicted=16.6975, Expected=16.4330
# Month=21, Predicted=16.4135, Expected=15.7690
# Month=22, Predicted=15.7495, Expected=15.2750
# Month=23, Predicted=15.2555, Expected=15.1230
# Month=24, Predicted=15.1035, Expected=15.5410
# Month=25, Predicted=15.5215, Expected=15.8250
# Month=26, Predicted=15.8055, Expected=16.3760
# Month=27, Predicted=16.3565, Expected=16.3570
# Month=28, Predicted=16.3375, Expected=16.9070
# Month=29, Predicted=16.8875, Expected=17.0210
# Month=30, Predicted=17.0015, Expected=17.4190
# Month=31, Predicted=17.3995, Expected=17.5330
# Month=32, Predicted=17.5135, Expected=17.2680
# Month=33, Predicted=17.2485, Expected=16.6030
# Month=34, Predicted=16.5835, Expected=15.8250
# Month=35, Predicted=15.8055, Expected=15.4460
# Month=36, Predicted=15.4265, Expected=15.6360
# Month=37, Predicted=15.6165, Expected=15.6930
# Month=38, Predicted=15.6735, Expected=16.7550
# Month=39, Predicted=16.7355, Expected=16.5090
# Month=40, Predicted=16.4895, Expected=17.7230
# Month=41, Predicted=17.7035, Expected=18.6910
# Month=42, Predicted=18.6715, Expected=19.1270
# Month=43, Predicted=19.1075, Expected=19.5640
# Month=44, Predicted=19.5445, Expected=19.2030
# Month=45, Predicted=19.1835, Expected=18.2160
# Month=46, Predicted=18.1965, Expected=17.2110
# Month=47, Predicted=17.1915, Expected=16.6600
# Month=48, Predicted=16.6405, Expected=16.8310
# Month=49, Predicted=16.8115, Expected=15.7690
# Month=50, Predicted=15.7495, Expected=15.7310
# Month=51, Predicted=15.7115, Expected=15.9960
# Month=52, Predicted=15.9765, Expected=17.0210
# Month=53, Predicted=17.0015, Expected=17.5520
# Month=54, Predicted=17.5325, Expected=17.8370
# Month=55, Predicted=17.8175, Expected=17.8560
# Month=56, Predicted=17.8365, Expected=17.5710
# Month=57, Predicted=17.5515, Expected=17.0780
# Month=58, Predicted=17.0585, Expected=16.6600
# Month=59, Predicted=16.6405, Expected=16.4330
# Month=60, Predicted=16.4135, Expected=16.5840
# Run 1 — RMSE: 0.563326, MSE: 0.317336, NMSE: 0.0026396755
#
# ===== Attention(lag=20) RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.1083, Expected=13.7000
# Month=2, Predicted=13.6773, Expected=13.8140
# Month=3, Predicted=13.7913, Expected=14.3830
# Month=4, Predicted=14.3603, Expected=15.0470
# Month=5, Predicted=15.0243, Expected=15.6930
# Month=6, Predicted=15.6703, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.6893, Expected=15.3130
# Month=9, Predicted=15.2903, Expected=14.7630
# Month=10, Predicted=14.7403, Expected=13.5480
# Month=11, Predicted=13.5253, Expected=13.5860
# Month=12, Predicted=13.5633, Expected=14.5160
# Month=13, Predicted=14.4933, Expected=14.3830
# Month=14, Predicted=14.3603, Expected=14.4970
# Month=15, Predicted=14.4743, Expected=14.7440
# Month=16, Predicted=14.7213, Expected=15.8060
# Month=17, Predicted=15.7833, Expected=16.5270
# Month=18, Predicted=16.5043, Expected=16.5460
# Month=19, Predicted=16.5233, Expected=16.7170
# Month=20, Predicted=16.6943, Expected=16.4330
# Month=21, Predicted=16.4103, Expected=15.7690
# Month=22, Predicted=15.7463, Expected=15.2750
# Month=23, Predicted=15.2523, Expected=15.1230
# Month=24, Predicted=15.1003, Expected=15.5410
# Month=25, Predicted=15.5183, Expected=15.8250
# Month=26, Predicted=15.8023, Expected=16.3760
# Month=27, Predicted=16.3533, Expected=16.3570
# Month=28, Predicted=16.3343, Expected=16.9070
# Month=29, Predicted=16.8843, Expected=17.0210
# Month=30, Predicted=16.9983, Expected=17.4190
# Month=31, Predicted=17.3963, Expected=17.5330
# Month=32, Predicted=17.5103, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5803, Expected=15.8250
# Month=35, Predicted=15.8023, Expected=15.4460
# Month=36, Predicted=15.4233, Expected=15.6360
# Month=37, Predicted=15.6133, Expected=15.6930
# Month=38, Predicted=15.6703, Expected=16.7550
# Month=39, Predicted=16.7323, Expected=16.5090
# Month=40, Predicted=16.4863, Expected=17.7230
# Month=41, Predicted=17.7003, Expected=18.6910
# Month=42, Predicted=18.6683, Expected=19.1270
# Month=43, Predicted=19.1043, Expected=19.5640
# Month=44, Predicted=19.5413, Expected=19.2030
# Month=45, Predicted=19.1803, Expected=18.2160
# Month=46, Predicted=18.1933, Expected=17.2110
# Month=47, Predicted=17.1883, Expected=16.6600
# Month=48, Predicted=16.6373, Expected=16.8310
# Month=49, Predicted=16.8083, Expected=15.7690
# Month=50, Predicted=15.7463, Expected=15.7310
# Month=51, Predicted=15.7083, Expected=15.9960
# Month=52, Predicted=15.9733, Expected=17.0210
# Month=53, Predicted=16.9983, Expected=17.5520
# Month=54, Predicted=17.5293, Expected=17.8370
# Month=55, Predicted=17.8143, Expected=17.8560
# Month=56, Predicted=17.8333, Expected=17.5710
# Month=57, Predicted=17.5483, Expected=17.0780
# Month=58, Predicted=17.0553, Expected=16.6600
# Month=59, Predicted=16.6373, Expected=16.4330
# Month=60, Predicted=16.4103, Expected=16.5840
# Run 2 — RMSE: 0.563766, MSE: 0.317832, NMSE: 0.0026431424
#
# ===== Attention(lag=20) RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.1220, Expected=13.7000
# Month=2, Predicted=13.6910, Expected=13.8140
# Month=3, Predicted=13.8050, Expected=14.3830
# Month=4, Predicted=14.3740, Expected=15.0470
# Month=5, Predicted=15.0380, Expected=15.6930
# Month=6, Predicted=15.6840, Expected=15.8440
# Month=7, Predicted=15.8350, Expected=15.7120
# Month=8, Predicted=15.7030, Expected=15.3130
# Month=9, Predicted=15.3040, Expected=14.7630
# Month=10, Predicted=14.7540, Expected=13.5480
# Month=11, Predicted=13.5390, Expected=13.5860
# Month=12, Predicted=13.5770, Expected=14.5160
# Month=13, Predicted=14.5070, Expected=14.3830
# Month=14, Predicted=14.3740, Expected=14.4970
# Month=15, Predicted=14.4880, Expected=14.7440
# Month=16, Predicted=14.7350, Expected=15.8060
# Month=17, Predicted=15.7970, Expected=16.5270
# Month=18, Predicted=16.5180, Expected=16.5460
# Month=19, Predicted=16.5370, Expected=16.7170
# Month=20, Predicted=16.7080, Expected=16.4330
# Month=21, Predicted=16.4240, Expected=15.7690
# Month=22, Predicted=15.7600, Expected=15.2750
# Month=23, Predicted=15.2660, Expected=15.1230
# Month=24, Predicted=15.1140, Expected=15.5410
# Month=25, Predicted=15.5320, Expected=15.8250
# Month=26, Predicted=15.8160, Expected=16.3760
# Month=27, Predicted=16.3670, Expected=16.3570
# Month=28, Predicted=16.3480, Expected=16.9070
# Month=29, Predicted=16.8980, Expected=17.0210
# Month=30, Predicted=17.0120, Expected=17.4190
# Month=31, Predicted=17.4100, Expected=17.5330
# Month=32, Predicted=17.5240, Expected=17.2680
# Month=33, Predicted=17.2590, Expected=16.6030
# Month=34, Predicted=16.5940, Expected=15.8250
# Month=35, Predicted=15.8160, Expected=15.4460
# Month=36, Predicted=15.4370, Expected=15.6360
# Month=37, Predicted=15.6270, Expected=15.6930
# Month=38, Predicted=15.6840, Expected=16.7550
# Month=39, Predicted=16.7460, Expected=16.5090
# Month=40, Predicted=16.5000, Expected=17.7230
# Month=41, Predicted=17.7140, Expected=18.6910
# Month=42, Predicted=18.6820, Expected=19.1270
# Month=43, Predicted=19.1180, Expected=19.5640
# Month=44, Predicted=19.5550, Expected=19.2030
# Month=45, Predicted=19.1940, Expected=18.2160
# Month=46, Predicted=18.2070, Expected=17.2110
# Month=47, Predicted=17.2020, Expected=16.6600
# Month=48, Predicted=16.6510, Expected=16.8310
# Month=49, Predicted=16.8220, Expected=15.7690
# Month=50, Predicted=15.7600, Expected=15.7310
# Month=51, Predicted=15.7220, Expected=15.9960
# Month=52, Predicted=15.9870, Expected=17.0210
# Month=53, Predicted=17.0120, Expected=17.5520
# Month=54, Predicted=17.5430, Expected=17.8370
# Month=55, Predicted=17.8280, Expected=17.8560
# Month=56, Predicted=17.8470, Expected=17.5710
# Month=57, Predicted=17.5620, Expected=17.0780
# Month=58, Predicted=17.0690, Expected=16.6600
# Month=59, Predicted=16.6510, Expected=16.4330
# Month=60, Predicted=16.4240, Expected=16.5840
# Run 3 — RMSE: 0.561983, MSE: 0.315825, NMSE: 0.0026290878
#
# ===== Attention(lag=20) RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 4 — RMSE: 0.563208, MSE: 0.317203, NMSE: 0.0026387441
#
# ===== Attention(lag=20) RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2231, Expected=13.7000
# Month=2, Predicted=13.8097, Expected=13.8140
# Month=3, Predicted=13.8910, Expected=14.3830
# Month=4, Predicted=14.3857, Expected=15.0470
# Month=5, Predicted=14.9584, Expected=15.6930
# Month=6, Predicted=15.4774, Expected=15.8440
# Month=7, Predicted=15.4554, Expected=15.7120
# Month=8, Predicted=15.3143, Expected=15.3130
# Month=9, Predicted=14.9689, Expected=14.7630
# Month=10, Predicted=14.4676, Expected=13.5480
# Month=11, Predicted=13.3267, Expected=13.5860
# Month=12, Predicted=13.5186, Expected=14.5160
# Month=13, Predicted=14.4595, Expected=14.3830
# Month=14, Predicted=14.4444, Expected=14.4970
# Month=15, Predicted=14.5637, Expected=14.7440
# Month=16, Predicted=14.7526, Expected=15.8060
# Month=17, Predicted=15.6174, Expected=16.5270
# Month=18, Predicted=16.1314, Expected=16.5460
# Month=19, Predicted=16.1803, Expected=16.7170
# Month=20, Predicted=16.3811, Expected=16.4330
# Month=21, Predicted=16.1078, Expected=15.7690
# Month=22, Predicted=15.5036, Expected=15.2750
# Month=23, Predicted=15.0773, Expected=15.1230
# Month=24, Predicted=15.0379, Expected=15.5410
# Month=25, Predicted=15.5159, Expected=15.8250
# Month=26, Predicted=15.8656, Expected=16.3760
# Month=27, Predicted=16.3784, Expected=16.3570
# Month=28, Predicted=16.3409, Expected=16.9070
# Month=29, Predicted=16.7914, Expected=17.0210
# Month=30, Predicted=16.8359, Expected=17.4190
# Month=31, Predicted=17.0293, Expected=17.5330
# Month=32, Predicted=17.1807, Expected=17.2680
# Month=33, Predicted=17.0336, Expected=16.6030
# Month=34, Predicted=16.3672, Expected=15.8250
# Month=35, Predicted=15.6455, Expected=15.4460
# Month=36, Predicted=15.3506, Expected=15.6360
# Month=37, Predicted=15.6595, Expected=15.6930
# Month=38, Predicted=15.8427, Expected=16.7550
# Month=39, Predicted=16.8083, Expected=16.5090
# Month=40, Predicted=16.6085, Expected=17.7230
# Month=41, Predicted=17.5627, Expected=18.6910
# Month=42, Predicted=18.3328, Expected=19.1270
# Month=43, Predicted=18.7844, Expected=19.5640
# Month=44, Predicted=19.2380, Expected=19.2030
# Month=45, Predicted=18.8963, Expected=18.2160
# Month=46, Predicted=17.9349, Expected=17.2110
# Month=47, Predicted=17.0366, Expected=16.6600
# Month=48, Predicted=16.5816, Expected=16.8310
# Month=49, Predicted=16.8233, Expected=15.7690
# Month=50, Predicted=15.9209, Expected=15.7310
# Month=51, Predicted=15.9393, Expected=15.9960
# Month=52, Predicted=16.1850, Expected=17.0210
# Month=53, Predicted=17.0683, Expected=17.5520
# Month=54, Predicted=17.4651, Expected=17.8370
# Month=55, Predicted=17.5559, Expected=17.8560
# Month=56, Predicted=17.4100, Expected=17.5710
# Month=57, Predicted=17.1532, Expected=17.0780
# Month=58, Predicted=16.6978, Expected=16.6600
# Month=59, Predicted=16.4105, Expected=16.4330
# Month=60, Predicted=16.2274, Expected=16.5840
# Run 5 — RMSE: 0.528090, MSE: 0.278880, NMSE: 0.0025631003
#
# ===== Attention(lag=20) RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.1236, Expected=13.7000
# Month=2, Predicted=13.6926, Expected=13.8140
# Month=3, Predicted=13.8066, Expected=14.3830
# Month=4, Predicted=14.3756, Expected=15.0470
# Month=5, Predicted=15.0396, Expected=15.6930
# Month=6, Predicted=15.6856, Expected=15.8440
# Month=7, Predicted=15.8366, Expected=15.7120
# Month=8, Predicted=15.7046, Expected=15.3130
# Month=9, Predicted=15.3056, Expected=14.7630
# Month=10, Predicted=14.7556, Expected=13.5480
# Month=11, Predicted=13.5406, Expected=13.5860
# Month=12, Predicted=13.5786, Expected=14.5160
# Month=13, Predicted=14.5086, Expected=14.3830
# Month=14, Predicted=14.3756, Expected=14.4970
# Month=15, Predicted=14.4896, Expected=14.7440
# Month=16, Predicted=14.7366, Expected=15.8060
# Month=17, Predicted=15.7986, Expected=16.5270
# Month=18, Predicted=16.5196, Expected=16.5460
# Month=19, Predicted=16.5386, Expected=16.7170
# Month=20, Predicted=16.7096, Expected=16.4330
# Month=21, Predicted=16.4256, Expected=15.7690
# Month=22, Predicted=15.7616, Expected=15.2750
# Month=23, Predicted=15.2676, Expected=15.1230
# Month=24, Predicted=15.1156, Expected=15.5410
# Month=25, Predicted=15.5336, Expected=15.8250
# Month=26, Predicted=15.8176, Expected=16.3760
# Month=27, Predicted=16.3686, Expected=16.3570
# Month=28, Predicted=16.3496, Expected=16.9070
# Month=29, Predicted=16.8996, Expected=17.0210
# Month=30, Predicted=17.0136, Expected=17.4190
# Month=31, Predicted=17.4116, Expected=17.5330
# Month=32, Predicted=17.5256, Expected=17.2680
# Month=33, Predicted=17.2606, Expected=16.6030
# Month=34, Predicted=16.5956, Expected=15.8250
# Month=35, Predicted=15.8176, Expected=15.4460
# Month=36, Predicted=15.4386, Expected=15.6360
# Month=37, Predicted=15.6286, Expected=15.6930
# Month=38, Predicted=15.6856, Expected=16.7550
# Month=39, Predicted=16.7476, Expected=16.5090
# Month=40, Predicted=16.5016, Expected=17.7230
# Month=41, Predicted=17.7156, Expected=18.6910
# Month=42, Predicted=18.6836, Expected=19.1270
# Month=43, Predicted=19.1196, Expected=19.5640
# Month=44, Predicted=19.5566, Expected=19.2030
# Month=45, Predicted=19.1956, Expected=18.2160
# Month=46, Predicted=18.2086, Expected=17.2110
# Month=47, Predicted=17.2036, Expected=16.6600
# Month=48, Predicted=16.6526, Expected=16.8310
# Month=49, Predicted=16.8236, Expected=15.7690
# Month=50, Predicted=15.7616, Expected=15.7310
# Month=51, Predicted=15.7236, Expected=15.9960
# Month=52, Predicted=15.9886, Expected=17.0210
# Month=53, Predicted=17.0136, Expected=17.5520
# Month=54, Predicted=17.5446, Expected=17.8370
# Month=55, Predicted=17.8296, Expected=17.8560
# Month=56, Predicted=17.8486, Expected=17.5710
# Month=57, Predicted=17.5636, Expected=17.0780
# Month=58, Predicted=17.0706, Expected=16.6600
# Month=59, Predicted=16.6526, Expected=16.4330
# Month=60, Predicted=16.4256, Expected=16.5840
# Run 6 — RMSE: 0.561791, MSE: 0.315610, NMSE: 0.0026275764
#
# ===== Attention(lag=20) RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.1179, Expected=13.7000
# Month=2, Predicted=13.6869, Expected=13.8140
# Month=3, Predicted=13.8009, Expected=14.3830
# Month=4, Predicted=14.3699, Expected=15.0470
# Month=5, Predicted=15.0339, Expected=15.6930
# Month=6, Predicted=15.6799, Expected=15.8440
# Month=7, Predicted=15.8309, Expected=15.7120
# Month=8, Predicted=15.6989, Expected=15.3130
# Month=9, Predicted=15.2999, Expected=14.7630
# Month=10, Predicted=14.7499, Expected=13.5480
# Month=11, Predicted=13.5349, Expected=13.5860
# Month=12, Predicted=13.5729, Expected=14.5160
# Month=13, Predicted=14.5029, Expected=14.3830
# Month=14, Predicted=14.3699, Expected=14.4970
# Month=15, Predicted=14.4839, Expected=14.7440
# Month=16, Predicted=14.7309, Expected=15.8060
# Month=17, Predicted=15.7929, Expected=16.5270
# Month=18, Predicted=16.5139, Expected=16.5460
# Month=19, Predicted=16.5329, Expected=16.7170
# Month=20, Predicted=16.7039, Expected=16.4330
# Month=21, Predicted=16.4199, Expected=15.7690
# Month=22, Predicted=15.7559, Expected=15.2750
# Month=23, Predicted=15.2619, Expected=15.1230
# Month=24, Predicted=15.1099, Expected=15.5410
# Month=25, Predicted=15.5279, Expected=15.8250
# Month=26, Predicted=15.8119, Expected=16.3760
# Month=27, Predicted=16.3629, Expected=16.3570
# Month=28, Predicted=16.3439, Expected=16.9070
# Month=29, Predicted=16.8939, Expected=17.0210
# Month=30, Predicted=17.0079, Expected=17.4190
# Month=31, Predicted=17.4059, Expected=17.5330
# Month=32, Predicted=17.5199, Expected=17.2680
# Month=33, Predicted=17.2549, Expected=16.6030
# Month=34, Predicted=16.5899, Expected=15.8250
# Month=35, Predicted=15.8119, Expected=15.4460
# Month=36, Predicted=15.4329, Expected=15.6360
# Month=37, Predicted=15.6229, Expected=15.6930
# Month=38, Predicted=15.6799, Expected=16.7550
# Month=39, Predicted=16.7419, Expected=16.5090
# Month=40, Predicted=16.4959, Expected=17.7230
# Month=41, Predicted=17.7099, Expected=18.6910
# Month=42, Predicted=18.6779, Expected=19.1270
# Month=43, Predicted=19.1139, Expected=19.5640
# Month=44, Predicted=19.5509, Expected=19.2030
# Month=45, Predicted=19.1899, Expected=18.2160
# Month=46, Predicted=18.2029, Expected=17.2110
# Month=47, Predicted=17.1979, Expected=16.6600
# Month=48, Predicted=16.6469, Expected=16.8310
# Month=49, Predicted=16.8179, Expected=15.7690
# Month=50, Predicted=15.7559, Expected=15.7310
# Month=51, Predicted=15.7179, Expected=15.9960
# Month=52, Predicted=15.9829, Expected=17.0210
# Month=53, Predicted=17.0079, Expected=17.5520
# Month=54, Predicted=17.5389, Expected=17.8370
# Month=55, Predicted=17.8239, Expected=17.8560
# Month=56, Predicted=17.8429, Expected=17.5710
# Month=57, Predicted=17.5579, Expected=17.0780
# Month=58, Predicted=17.0649, Expected=16.6600
# Month=59, Predicted=16.6469, Expected=16.4330
# Month=60, Predicted=16.4199, Expected=16.5840
# Run 7 — RMSE: 0.562483, MSE: 0.316387, NMSE: 0.0026330251
#
# ===== Attention(lag=20) RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 8 — RMSE: 0.563208, MSE: 0.317203, NMSE: 0.0026387415
#
# ===== Attention(lag=20) RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.1237, Expected=13.7000
# Month=2, Predicted=13.6925, Expected=13.8140
# Month=3, Predicted=13.8059, Expected=14.3830
# Month=4, Predicted=14.3711, Expected=15.0470
# Month=5, Predicted=15.0306, Expected=15.6930
# Month=6, Predicted=15.6725, Expected=15.8440
# Month=7, Predicted=15.8226, Expected=15.7120
# Month=8, Predicted=15.6902, Expected=15.3130
# Month=9, Predicted=15.2916, Expected=14.7630
# Month=10, Predicted=14.7438, Expected=13.5480
# Month=11, Predicted=13.5305, Expected=13.5860
# Month=12, Predicted=13.5791, Expected=14.5160
# Month=13, Predicted=14.5059, Expected=14.3830
# Month=14, Predicted=14.3771, Expected=14.4970
# Month=15, Predicted=14.4906, Expected=14.7440
# Month=16, Predicted=14.7360, Expected=15.8060
# Month=17, Predicted=15.7875, Expected=16.5270
# Month=18, Predicted=16.5037, Expected=16.5460
# Month=19, Predicted=16.5221, Expected=16.7170
# Month=20, Predicted=16.6924, Expected=16.4330
# Month=21, Predicted=16.4091, Expected=15.7690
# Month=22, Predicted=15.7481, Expected=15.2750
# Month=23, Predicted=15.2550, Expected=15.1230
# Month=24, Predicted=15.1061, Expected=15.5410
# Month=25, Predicted=15.5262, Expected=15.8250
# Month=26, Predicted=15.8129, Expected=16.3760
# Month=27, Predicted=16.3615, Expected=16.3570
# Month=28, Predicted=16.3423, Expected=16.9070
# Month=29, Predicted=16.8891, Expected=17.0210
# Month=30, Predicted=17.0022, Expected=17.4190
# Month=31, Predicted=17.3984, Expected=17.5330
# Month=32, Predicted=17.5121, Expected=17.2680
# Month=33, Predicted=17.2541, Expected=16.6030
# Month=34, Predicted=16.5896, Expected=15.8250
# Month=35, Predicted=15.8128, Expected=15.4460
# Month=36, Predicted=15.4355, Expected=15.6360
# Month=37, Predicted=15.6367, Expected=15.6930
# Month=38, Predicted=15.6997, Expected=16.7550
# Month=39, Predicted=16.7491, Expected=16.5090
# Month=40, Predicted=16.5045, Expected=17.7230
# Month=41, Predicted=17.7038, Expected=18.6910
# Month=42, Predicted=18.6637, Expected=19.1270
# Month=43, Predicted=19.0975, Expected=19.5640
# Month=44, Predicted=19.5329, Expected=19.2030
# Month=45, Predicted=19.1735, Expected=18.2160
# Month=46, Predicted=18.1876, Expected=17.2110
# Month=47, Predicted=17.1850, Expected=16.6600
# Month=48, Predicted=16.6345, Expected=16.8310
# Month=49, Predicted=16.8073, Expected=15.7690
# Month=50, Predicted=15.7463, Expected=15.7310
# Month=51, Predicted=15.7098, Expected=15.9960
# Month=52, Predicted=15.9743, Expected=17.0210
# Month=53, Predicted=16.9909, Expected=17.5520
# Month=54, Predicted=17.5194, Expected=17.8370
# Month=55, Predicted=17.8033, Expected=17.8560
# Month=56, Predicted=17.8219, Expected=17.5710
# Month=57, Predicted=17.5375, Expected=17.0780
# Month=58, Predicted=17.0450, Expected=16.6600
# Month=59, Predicted=16.6353, Expected=16.4330
# Month=60, Predicted=16.4084, Expected=16.5840
# Run 9 — RMSE: 0.559582, MSE: 0.313132, NMSE: 0.0026269745
#
# ===== Attention(lag=20) RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 10 — RMSE: 0.563209, MSE: 0.317205, NMSE: 0.0026387524
#
# ===== Attention(lag=20) RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.1179, Expected=13.7000
# Month=2, Predicted=13.6869, Expected=13.8140
# Month=3, Predicted=13.8009, Expected=14.3830
# Month=4, Predicted=14.3699, Expected=15.0470
# Month=5, Predicted=15.0339, Expected=15.6930
# Month=6, Predicted=15.6799, Expected=15.8440
# Month=7, Predicted=15.8309, Expected=15.7120
# Month=8, Predicted=15.6989, Expected=15.3130
# Month=9, Predicted=15.2999, Expected=14.7630
# Month=10, Predicted=14.7499, Expected=13.5480
# Month=11, Predicted=13.5349, Expected=13.5860
# Month=12, Predicted=13.5729, Expected=14.5160
# Month=13, Predicted=14.5029, Expected=14.3830
# Month=14, Predicted=14.3699, Expected=14.4970
# Month=15, Predicted=14.4839, Expected=14.7440
# Month=16, Predicted=14.7309, Expected=15.8060
# Month=17, Predicted=15.7929, Expected=16.5270
# Month=18, Predicted=16.5139, Expected=16.5460
# Month=19, Predicted=16.5329, Expected=16.7170
# Month=20, Predicted=16.7039, Expected=16.4330
# Month=21, Predicted=16.4199, Expected=15.7690
# Month=22, Predicted=15.7559, Expected=15.2750
# Month=23, Predicted=15.2619, Expected=15.1230
# Month=24, Predicted=15.1099, Expected=15.5410
# Month=25, Predicted=15.5279, Expected=15.8250
# Month=26, Predicted=15.8119, Expected=16.3760
# Month=27, Predicted=16.3629, Expected=16.3570
# Month=28, Predicted=16.3439, Expected=16.9070
# Month=29, Predicted=16.8939, Expected=17.0210
# Month=30, Predicted=17.0079, Expected=17.4190
# Month=31, Predicted=17.4059, Expected=17.5330
# Month=32, Predicted=17.5199, Expected=17.2680
# Month=33, Predicted=17.2549, Expected=16.6030
# Month=34, Predicted=16.5899, Expected=15.8250
# Month=35, Predicted=15.8119, Expected=15.4460
# Month=36, Predicted=15.4329, Expected=15.6360
# Month=37, Predicted=15.6229, Expected=15.6930
# Month=38, Predicted=15.6799, Expected=16.7550
# Month=39, Predicted=16.7419, Expected=16.5090
# Month=40, Predicted=16.4959, Expected=17.7230
# Month=41, Predicted=17.7099, Expected=18.6910
# Month=42, Predicted=18.6779, Expected=19.1270
# Month=43, Predicted=19.1139, Expected=19.5640
# Month=44, Predicted=19.5509, Expected=19.2030
# Month=45, Predicted=19.1899, Expected=18.2160
# Month=46, Predicted=18.2029, Expected=17.2110
# Month=47, Predicted=17.1979, Expected=16.6600
# Month=48, Predicted=16.6469, Expected=16.8310
# Month=49, Predicted=16.8179, Expected=15.7690
# Month=50, Predicted=15.7559, Expected=15.7310
# Month=51, Predicted=15.7179, Expected=15.9960
# Month=52, Predicted=15.9829, Expected=17.0210
# Month=53, Predicted=17.0079, Expected=17.5520
# Month=54, Predicted=17.5389, Expected=17.8370
# Month=55, Predicted=17.8239, Expected=17.8560
# Month=56, Predicted=17.8429, Expected=17.5710
# Month=57, Predicted=17.5579, Expected=17.0780
# Month=58, Predicted=17.0649, Expected=16.6600
# Month=59, Predicted=16.6469, Expected=16.4330
# Month=60, Predicted=16.4199, Expected=16.5840
# Run 11 — RMSE: 0.562481, MSE: 0.316385, NMSE: 0.0026330099
#
# ===== Attention(lag=20) RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.1179, Expected=13.7000
# Month=2, Predicted=13.6869, Expected=13.8140
# Month=3, Predicted=13.8009, Expected=14.3830
# Month=4, Predicted=14.3699, Expected=15.0470
# Month=5, Predicted=15.0339, Expected=15.6930
# Month=6, Predicted=15.6799, Expected=15.8440
# Month=7, Predicted=15.8309, Expected=15.7120
# Month=8, Predicted=15.6989, Expected=15.3130
# Month=9, Predicted=15.2999, Expected=14.7630
# Month=10, Predicted=14.7499, Expected=13.5480
# Month=11, Predicted=13.5349, Expected=13.5860
# Month=12, Predicted=13.5729, Expected=14.5160
# Month=13, Predicted=14.5029, Expected=14.3830
# Month=14, Predicted=14.3699, Expected=14.4970
# Month=15, Predicted=14.4839, Expected=14.7440
# Month=16, Predicted=14.7309, Expected=15.8060
# Month=17, Predicted=15.7929, Expected=16.5270
# Month=18, Predicted=16.5139, Expected=16.5460
# Month=19, Predicted=16.5329, Expected=16.7170
# Month=20, Predicted=16.7039, Expected=16.4330
# Month=21, Predicted=16.4199, Expected=15.7690
# Month=22, Predicted=15.7559, Expected=15.2750
# Month=23, Predicted=15.2619, Expected=15.1230
# Month=24, Predicted=15.1099, Expected=15.5410
# Month=25, Predicted=15.5279, Expected=15.8250
# Month=26, Predicted=15.8119, Expected=16.3760
# Month=27, Predicted=16.3629, Expected=16.3570
# Month=28, Predicted=16.3439, Expected=16.9070
# Month=29, Predicted=16.8939, Expected=17.0210
# Month=30, Predicted=17.0079, Expected=17.4190
# Month=31, Predicted=17.4059, Expected=17.5330
# Month=32, Predicted=17.5199, Expected=17.2680
# Month=33, Predicted=17.2549, Expected=16.6030
# Month=34, Predicted=16.5899, Expected=15.8250
# Month=35, Predicted=15.8119, Expected=15.4460
# Month=36, Predicted=15.4329, Expected=15.6360
# Month=37, Predicted=15.6229, Expected=15.6930
# Month=38, Predicted=15.6799, Expected=16.7550
# Month=39, Predicted=16.7419, Expected=16.5090
# Month=40, Predicted=16.4959, Expected=17.7230
# Month=41, Predicted=17.7099, Expected=18.6910
# Month=42, Predicted=18.6779, Expected=19.1270
# Month=43, Predicted=19.1139, Expected=19.5640
# Month=44, Predicted=19.5509, Expected=19.2030
# Month=45, Predicted=19.1899, Expected=18.2160
# Month=46, Predicted=18.2029, Expected=17.2110
# Month=47, Predicted=17.1979, Expected=16.6600
# Month=48, Predicted=16.6469, Expected=16.8310
# Month=49, Predicted=16.8179, Expected=15.7690
# Month=50, Predicted=15.7559, Expected=15.7310
# Month=51, Predicted=15.7179, Expected=15.9960
# Month=52, Predicted=15.9829, Expected=17.0210
# Month=53, Predicted=17.0079, Expected=17.5520
# Month=54, Predicted=17.5389, Expected=17.8370
# Month=55, Predicted=17.8239, Expected=17.8560
# Month=56, Predicted=17.8429, Expected=17.5710
# Month=57, Predicted=17.5579, Expected=17.0780
# Month=58, Predicted=17.0649, Expected=16.6600
# Month=59, Predicted=16.6469, Expected=16.4330
# Month=60, Predicted=16.4199, Expected=16.5840
# Run 12 — RMSE: 0.562483, MSE: 0.316387, NMSE: 0.0026330269
#
# ===== Attention(lag=20) RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 13 — RMSE: 0.563216, MSE: 0.317212, NMSE: 0.0026388048
#
# ===== Attention(lag=20) RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.1118, Expected=13.7000
# Month=2, Predicted=13.6808, Expected=13.8140
# Month=3, Predicted=13.7948, Expected=14.3830
# Month=4, Predicted=14.3638, Expected=15.0470
# Month=5, Predicted=15.0278, Expected=15.6930
# Month=6, Predicted=15.6738, Expected=15.8440
# Month=7, Predicted=15.8248, Expected=15.7120
# Month=8, Predicted=15.6928, Expected=15.3130
# Month=9, Predicted=15.2938, Expected=14.7630
# Month=10, Predicted=14.7438, Expected=13.5480
# Month=11, Predicted=13.5288, Expected=13.5860
# Month=12, Predicted=13.5668, Expected=14.5160
# Month=13, Predicted=14.4968, Expected=14.3830
# Month=14, Predicted=14.3638, Expected=14.4970
# Month=15, Predicted=14.4778, Expected=14.7440
# Month=16, Predicted=14.7248, Expected=15.8060
# Month=17, Predicted=15.7868, Expected=16.5270
# Month=18, Predicted=16.5078, Expected=16.5460
# Month=19, Predicted=16.5268, Expected=16.7170
# Month=20, Predicted=16.6978, Expected=16.4330
# Month=21, Predicted=16.4138, Expected=15.7690
# Month=22, Predicted=15.7498, Expected=15.2750
# Month=23, Predicted=15.2558, Expected=15.1230
# Month=24, Predicted=15.1038, Expected=15.5410
# Month=25, Predicted=15.5218, Expected=15.8250
# Month=26, Predicted=15.8058, Expected=16.3760
# Month=27, Predicted=16.3568, Expected=16.3570
# Month=28, Predicted=16.3378, Expected=16.9070
# Month=29, Predicted=16.8878, Expected=17.0210
# Month=30, Predicted=17.0018, Expected=17.4190
# Month=31, Predicted=17.3998, Expected=17.5330
# Month=32, Predicted=17.5138, Expected=17.2680
# Month=33, Predicted=17.2488, Expected=16.6030
# Month=34, Predicted=16.5838, Expected=15.8250
# Month=35, Predicted=15.8058, Expected=15.4460
# Month=36, Predicted=15.4268, Expected=15.6360
# Month=37, Predicted=15.6168, Expected=15.6930
# Month=38, Predicted=15.6738, Expected=16.7550
# Month=39, Predicted=16.7358, Expected=16.5090
# Month=40, Predicted=16.4898, Expected=17.7230
# Month=41, Predicted=17.7038, Expected=18.6910
# Month=42, Predicted=18.6718, Expected=19.1270
# Month=43, Predicted=19.1078, Expected=19.5640
# Month=44, Predicted=19.5448, Expected=19.2030
# Month=45, Predicted=19.1838, Expected=18.2160
# Month=46, Predicted=18.1968, Expected=17.2110
# Month=47, Predicted=17.1918, Expected=16.6600
# Month=48, Predicted=16.6408, Expected=16.8310
# Month=49, Predicted=16.8118, Expected=15.7690
# Month=50, Predicted=15.7498, Expected=15.7310
# Month=51, Predicted=15.7118, Expected=15.9960
# Month=52, Predicted=15.9768, Expected=17.0210
# Month=53, Predicted=17.0018, Expected=17.5520
# Month=54, Predicted=17.5328, Expected=17.8370
# Month=55, Predicted=17.8178, Expected=17.8560
# Month=56, Predicted=17.8368, Expected=17.5710
# Month=57, Predicted=17.5518, Expected=17.0780
# Month=58, Predicted=17.0588, Expected=16.6600
# Month=59, Predicted=16.6408, Expected=16.4330
# Month=60, Predicted=16.4138, Expected=16.5840
# Run 14 — RMSE: 0.563282, MSE: 0.317287, NMSE: 0.0026393310
#
# ===== Attention(lag=20) RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 15 — RMSE: 0.563208, MSE: 0.317203, NMSE: 0.0026387428
#
# ===== Attention(lag=20) RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 16 — RMSE: 0.563208, MSE: 0.317203, NMSE: 0.0026387408
#
# ===== Attention(lag=20) RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# ...
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 25 — RMSE: 0.563209, MSE: 0.317204, NMSE: 0.0026387481
#
# ===== Attention(lag=20) RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.1326, Expected=13.7000
# Month=2, Predicted=13.7004, Expected=13.8140
# Month=3, Predicted=13.7986, Expected=14.3830
# Month=4, Predicted=14.3009, Expected=15.0470
# Month=5, Predicted=14.8825, Expected=15.6930
# Month=6, Predicted=15.4469, Expected=15.8440
# Month=7, Predicted=15.5526, Expected=15.7120
# Month=8, Predicted=15.4027, Expected=15.3130
# Month=9, Predicted=15.0223, Expected=14.7630
# Month=10, Predicted=14.5331, Expected=13.5480
# Month=11, Predicted=13.3832, Expected=13.5860
# Month=12, Predicted=13.5201, Expected=14.5160
# Month=13, Predicted=14.4284, Expected=14.3830
# Month=14, Predicted=14.3556, Expected=14.4970
# Month=15, Predicted=14.4604, Expected=14.7440
# Month=16, Predicted=14.6709, Expected=15.8060
# Month=17, Predicted=15.6145, Expected=16.5270
# Month=18, Predicted=16.2570, Expected=16.5460
# Month=19, Predicted=16.2497, Expected=16.7170
# Month=20, Predicted=16.3954, Expected=16.4330
# Month=21, Predicted=16.1370, Expected=15.7690
# Month=22, Predicted=15.5499, Expected=15.2750
# Month=23, Predicted=15.0913, Expected=15.1230
# Month=24, Predicted=14.9981, Expected=15.5410
# Month=25, Predicted=15.4403, Expected=15.8250
# Month=26, Predicted=15.7583, Expected=16.3760
# Month=27, Predicted=16.2733, Expected=16.3570
# Month=28, Predicted=16.2473, Expected=16.9070
# Month=29, Predicted=16.7288, Expected=17.0210
# Month=30, Predicted=16.8066, Expected=17.4190
# Month=31, Predicted=17.1392, Expected=17.5330
# Month=32, Predicted=17.2453, Expected=17.2680
# Month=33, Predicted=17.0753, Expected=16.6030
# Month=34, Predicted=16.4356, Expected=15.8250
# Month=35, Predicted=15.7010, Expected=15.4460
# Month=36, Predicted=15.3650, Expected=15.6360
# Month=37, Predicted=15.6427, Expected=15.6930
# Month=38, Predicted=15.7621, Expected=16.7550
# Month=39, Predicted=16.7217, Expected=16.5090
# Month=40, Predicted=16.5042, Expected=17.7230
# Month=41, Predicted=17.5826, Expected=18.6910
# Month=42, Predicted=18.4281, Expected=19.1270
# Month=43, Predicted=18.8024, Expected=19.5640
# Month=44, Predicted=19.1958, Expected=19.2030
# Month=45, Predicted=18.8856, Expected=18.2160
# Month=46, Predicted=17.9575, Expected=17.2110
# Month=47, Predicted=17.0352, Expected=16.6600
# Month=48, Predicted=16.5125, Expected=16.8310
# Month=49, Predicted=16.7165, Expected=15.7690
# Month=50, Predicted=15.7093, Expected=15.7310
# Month=51, Predicted=15.7070, Expected=15.9960
# Month=52, Predicted=15.9585, Expected=17.0210
# Month=53, Predicted=16.8656, Expected=17.5520
# Month=54, Predicted=17.3174, Expected=17.8370
# Month=55, Predicted=17.5461, Expected=17.8560
# Month=56, Predicted=17.5421, Expected=17.5710
# Month=57, Predicted=17.2866, Expected=17.0780
# Month=58, Predicted=16.8256, Expected=16.6600
# Month=59, Predicted=16.5308, Expected=16.4330
# Month=60, Predicted=16.3063, Expected=16.5840
# Run 26 — RMSE: 0.557937, MSE: 0.311294, NMSE: 0.0027778864
#
# ===== Attention(lag=20) RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.1103, Expected=13.7000
# Month=2, Predicted=13.6793, Expected=13.8140
# Month=3, Predicted=13.7933, Expected=14.3830
# Month=4, Predicted=14.3623, Expected=15.0470
# Month=5, Predicted=15.0263, Expected=15.6930
# Month=6, Predicted=15.6723, Expected=15.8440
# Month=7, Predicted=15.8233, Expected=15.7120
# Month=8, Predicted=15.6913, Expected=15.3130
# Month=9, Predicted=15.2923, Expected=14.7630
# Month=10, Predicted=14.7423, Expected=13.5480
# Month=11, Predicted=13.5273, Expected=13.5860
# Month=12, Predicted=13.5653, Expected=14.5160
# Month=13, Predicted=14.4953, Expected=14.3830
# Month=14, Predicted=14.3623, Expected=14.4970
# Month=15, Predicted=14.4763, Expected=14.7440
# Month=16, Predicted=14.7233, Expected=15.8060
# Month=17, Predicted=15.7853, Expected=16.5270
# Month=18, Predicted=16.5063, Expected=16.5460
# Month=19, Predicted=16.5253, Expected=16.7170
# Month=20, Predicted=16.6963, Expected=16.4330
# Month=21, Predicted=16.4123, Expected=15.7690
# Month=22, Predicted=15.7483, Expected=15.2750
# Month=23, Predicted=15.2543, Expected=15.1230
# Month=24, Predicted=15.1023, Expected=15.5410
# Month=25, Predicted=15.5203, Expected=15.8250
# Month=26, Predicted=15.8043, Expected=16.3760
# Month=27, Predicted=16.3553, Expected=16.3570
# Month=28, Predicted=16.3363, Expected=16.9070
# Month=29, Predicted=16.8863, Expected=17.0210
# Month=30, Predicted=17.0003, Expected=17.4190
# Month=31, Predicted=17.3983, Expected=17.5330
# Month=32, Predicted=17.5123, Expected=17.2680
# Month=33, Predicted=17.2473, Expected=16.6030
# Month=34, Predicted=16.5823, Expected=15.8250
# Month=35, Predicted=15.8043, Expected=15.4460
# Month=36, Predicted=15.4253, Expected=15.6360
# Month=37, Predicted=15.6153, Expected=15.6930
# Month=38, Predicted=15.6723, Expected=16.7550
# Month=39, Predicted=16.7343, Expected=16.5090
# Month=40, Predicted=16.4883, Expected=17.7230
# Month=41, Predicted=17.7023, Expected=18.6910
# Month=42, Predicted=18.6703, Expected=19.1270
# Month=43, Predicted=19.1063, Expected=19.5640
# Month=44, Predicted=19.5433, Expected=19.2030
# Month=45, Predicted=19.1823, Expected=18.2160
# Month=46, Predicted=18.1953, Expected=17.2110
# Month=47, Predicted=17.1903, Expected=16.6600
# Month=48, Predicted=16.6393, Expected=16.8310
# Month=49, Predicted=16.8103, Expected=15.7690
# Month=50, Predicted=15.7483, Expected=15.7310
# Month=51, Predicted=15.7103, Expected=15.9960
# Month=52, Predicted=15.9753, Expected=17.0210
# Month=53, Predicted=17.0003, Expected=17.5520
# Month=54, Predicted=17.5313, Expected=17.8370
# Month=55, Predicted=17.8163, Expected=17.8560
# Month=56, Predicted=17.8353, Expected=17.5710
# Month=57, Predicted=17.5503, Expected=17.0780
# Month=58, Predicted=17.0573, Expected=16.6600
# Month=59, Predicted=16.6393, Expected=16.4330
# Month=60, Predicted=16.4123, Expected=16.5840
# Run 27 — RMSE: 0.563495, MSE: 0.317526, NMSE: 0.0026410046
#
# ===== Attention(lag=20) RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.1059, Expected=13.7000
# Month=2, Predicted=13.6749, Expected=13.8140
# Month=3, Predicted=13.7889, Expected=14.3830
# Month=4, Predicted=14.3579, Expected=15.0470
# Month=5, Predicted=15.0219, Expected=15.6930
# Month=6, Predicted=15.6679, Expected=15.8440
# Month=7, Predicted=15.8189, Expected=15.7120
# Month=8, Predicted=15.6869, Expected=15.3130
# Month=9, Predicted=15.2879, Expected=14.7630
# Month=10, Predicted=14.7379, Expected=13.5480
# Month=11, Predicted=13.5229, Expected=13.5860
# Month=12, Predicted=13.5609, Expected=14.5160
# Month=13, Predicted=14.4909, Expected=14.3830
# Month=14, Predicted=14.3579, Expected=14.4970
# Month=15, Predicted=14.4719, Expected=14.7440
# Month=16, Predicted=14.7189, Expected=15.8060
# Month=17, Predicted=15.7809, Expected=16.5270
# Month=18, Predicted=16.5019, Expected=16.5460
# Month=19, Predicted=16.5209, Expected=16.7170
# Month=20, Predicted=16.6919, Expected=16.4330
# Month=21, Predicted=16.4079, Expected=15.7690
# Month=22, Predicted=15.7439, Expected=15.2750
# Month=23, Predicted=15.2499, Expected=15.1230
# Month=24, Predicted=15.0979, Expected=15.5410
# Month=25, Predicted=15.5159, Expected=15.8250
# Month=26, Predicted=15.7999, Expected=16.3760
# Month=27, Predicted=16.3509, Expected=16.3570
# Month=28, Predicted=16.3319, Expected=16.9070
# Month=29, Predicted=16.8819, Expected=17.0210
# Month=30, Predicted=16.9959, Expected=17.4190
# Month=31, Predicted=17.3939, Expected=17.5330
# Month=32, Predicted=17.5079, Expected=17.2680
# Month=33, Predicted=17.2429, Expected=16.6030
# Month=34, Predicted=16.5779, Expected=15.8250
# Month=35, Predicted=15.7999, Expected=15.4460
# Month=36, Predicted=15.4209, Expected=15.6360
# Month=37, Predicted=15.6109, Expected=15.6930
# Month=38, Predicted=15.6679, Expected=16.7550
# Month=39, Predicted=16.7299, Expected=16.5090
# Month=40, Predicted=16.4839, Expected=17.7230
# Month=41, Predicted=17.6979, Expected=18.6910
# Month=42, Predicted=18.6659, Expected=19.1270
# Month=43, Predicted=19.1019, Expected=19.5640
# Month=44, Predicted=19.5389, Expected=19.2030
# Month=45, Predicted=19.1779, Expected=18.2160
# Month=46, Predicted=18.1909, Expected=17.2110
# Month=47, Predicted=17.1859, Expected=16.6600
# Month=48, Predicted=16.6349, Expected=16.8310
# Month=49, Predicted=16.8059, Expected=15.7690
# Month=50, Predicted=15.7439, Expected=15.7310
# Month=51, Predicted=15.7059, Expected=15.9960
# Month=52, Predicted=15.9709, Expected=17.0210
# Month=53, Predicted=16.9959, Expected=17.5520
# Month=54, Predicted=17.5269, Expected=17.8370
# Month=55, Predicted=17.8119, Expected=17.8560
# Month=56, Predicted=17.8309, Expected=17.5710
# Month=57, Predicted=17.5459, Expected=17.0780
# Month=58, Predicted=17.0529, Expected=16.6600
# Month=59, Predicted=16.6349, Expected=16.4330
# Month=60, Predicted=16.4079, Expected=16.5840
# Run 28 — RMSE: 0.564117, MSE: 0.318228, NMSE: 0.0026459166
#
# ===== Attention(lag=20) RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.1044, Expected=13.7000
# Month=2, Predicted=13.6734, Expected=13.8140
# Month=3, Predicted=13.7874, Expected=14.3830
# Month=4, Predicted=14.3564, Expected=15.0470
# Month=5, Predicted=15.0204, Expected=15.6930
# Month=6, Predicted=15.6664, Expected=15.8440
# Month=7, Predicted=15.8174, Expected=15.7120
# Month=8, Predicted=15.6854, Expected=15.3130
# Month=9, Predicted=15.2864, Expected=14.7630
# Month=10, Predicted=14.7364, Expected=13.5480
# Month=11, Predicted=13.5214, Expected=13.5860
# Month=12, Predicted=13.5594, Expected=14.5160
# Month=13, Predicted=14.4894, Expected=14.3830
# Month=14, Predicted=14.3564, Expected=14.4970
# Month=15, Predicted=14.4704, Expected=14.7440
# Month=16, Predicted=14.7174, Expected=15.8060
# Month=17, Predicted=15.7794, Expected=16.5270
# Month=18, Predicted=16.5004, Expected=16.5460
# Month=19, Predicted=16.5194, Expected=16.7170
# Month=20, Predicted=16.6904, Expected=16.4330
# Month=21, Predicted=16.4064, Expected=15.7690
# Month=22, Predicted=15.7424, Expected=15.2750
# Month=23, Predicted=15.2484, Expected=15.1230
# Month=24, Predicted=15.0964, Expected=15.5410
# Month=25, Predicted=15.5144, Expected=15.8250
# Month=26, Predicted=15.7984, Expected=16.3760
# Month=27, Predicted=16.3494, Expected=16.3570
# Month=28, Predicted=16.3304, Expected=16.9070
# Month=29, Predicted=16.8804, Expected=17.0210
# Month=30, Predicted=16.9944, Expected=17.4190
# Month=31, Predicted=17.3924, Expected=17.5330
# Month=32, Predicted=17.5064, Expected=17.2680
# Month=33, Predicted=17.2414, Expected=16.6030
# Month=34, Predicted=16.5764, Expected=15.8250
# Month=35, Predicted=15.7984, Expected=15.4460
# Month=36, Predicted=15.4194, Expected=15.6360
# Month=37, Predicted=15.6094, Expected=15.6930
# Month=38, Predicted=15.6664, Expected=16.7550
# Month=39, Predicted=16.7284, Expected=16.5090
# Month=40, Predicted=16.4824, Expected=17.7230
# Month=41, Predicted=17.6964, Expected=18.6910
# Month=42, Predicted=18.6644, Expected=19.1270
# Month=43, Predicted=19.1004, Expected=19.5640
# Month=44, Predicted=19.5374, Expected=19.2030
# Month=45, Predicted=19.1764, Expected=18.2160
# Month=46, Predicted=18.1894, Expected=17.2110
# Month=47, Predicted=17.1844, Expected=16.6600
# Month=48, Predicted=16.6334, Expected=16.8310
# Month=49, Predicted=16.8044, Expected=15.7690
# Month=50, Predicted=15.7424, Expected=15.7310
# Month=51, Predicted=15.7044, Expected=15.9960
# Month=52, Predicted=15.9694, Expected=17.0210
# Month=53, Predicted=16.9944, Expected=17.5520
# Month=54, Predicted=17.5254, Expected=17.8370
# Month=55, Predicted=17.8104, Expected=17.8560
# Month=56, Predicted=17.8294, Expected=17.5710
# Month=57, Predicted=17.5444, Expected=17.0780
# Month=58, Predicted=17.0514, Expected=16.6600
# Month=59, Predicted=16.6334, Expected=16.4330
# Month=60, Predicted=16.4064, Expected=16.5840
# Run 29 — RMSE: 0.564340, MSE: 0.318480, NMSE: 0.0026476785
#
# ===== Attention(lag=20) RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.1179, Expected=13.7000
# Month=2, Predicted=13.6869, Expected=13.8140
# Month=3, Predicted=13.8009, Expected=14.3830
# Month=4, Predicted=14.3699, Expected=15.0470
# Month=5, Predicted=15.0339, Expected=15.6930
# Month=6, Predicted=15.6799, Expected=15.8440
# Month=7, Predicted=15.8309, Expected=15.7120
# Month=8, Predicted=15.6989, Expected=15.3130
# Month=9, Predicted=15.2999, Expected=14.7630
# Month=10, Predicted=14.7499, Expected=13.5480
# Month=11, Predicted=13.5349, Expected=13.5860
# Month=12, Predicted=13.5729, Expected=14.5160
# Month=13, Predicted=14.5029, Expected=14.3830
# Month=14, Predicted=14.3699, Expected=14.4970
# Month=15, Predicted=14.4839, Expected=14.7440
# Month=16, Predicted=14.7309, Expected=15.8060
# Month=17, Predicted=15.7929, Expected=16.5270
# Month=18, Predicted=16.5139, Expected=16.5460
# Month=19, Predicted=16.5329, Expected=16.7170
# Month=20, Predicted=16.7039, Expected=16.4330
# Month=21, Predicted=16.4199, Expected=15.7690
# Month=22, Predicted=15.7559, Expected=15.2750
# Month=23, Predicted=15.2619, Expected=15.1230
# Month=24, Predicted=15.1099, Expected=15.5410
# Month=25, Predicted=15.5279, Expected=15.8250
# Month=26, Predicted=15.8119, Expected=16.3760
# Month=27, Predicted=16.3629, Expected=16.3570
# Month=28, Predicted=16.3439, Expected=16.9070
# Month=29, Predicted=16.8939, Expected=17.0210
# Month=30, Predicted=17.0079, Expected=17.4190
# Month=31, Predicted=17.4059, Expected=17.5330
# Month=32, Predicted=17.5199, Expected=17.2680
# Month=33, Predicted=17.2549, Expected=16.6030
# Month=34, Predicted=16.5899, Expected=15.8250
# Month=35, Predicted=15.8119, Expected=15.4460
# Month=36, Predicted=15.4329, Expected=15.6360
# Month=37, Predicted=15.6229, Expected=15.6930
# Month=38, Predicted=15.6799, Expected=16.7550
# Month=39, Predicted=16.7419, Expected=16.5090
# Month=40, Predicted=16.4959, Expected=17.7230
# Month=41, Predicted=17.7099, Expected=18.6910
# Month=42, Predicted=18.6779, Expected=19.1270
# Month=43, Predicted=19.1139, Expected=19.5640
# Month=44, Predicted=19.5509, Expected=19.2030
# Month=45, Predicted=19.1899, Expected=18.2160
# Month=46, Predicted=18.2029, Expected=17.2110
# Month=47, Predicted=17.1979, Expected=16.6600
# Month=48, Predicted=16.6469, Expected=16.8310
# Month=49, Predicted=16.8179, Expected=15.7690
# Month=50, Predicted=15.7559, Expected=15.7310
# Month=51, Predicted=15.7179, Expected=15.9960
# Month=52, Predicted=15.9829, Expected=17.0210
# Month=53, Predicted=17.0079, Expected=17.5520
# Month=54, Predicted=17.5389, Expected=17.8370
# Month=55, Predicted=17.8239, Expected=17.8560
# Month=56, Predicted=17.8429, Expected=17.5710
# Month=57, Predicted=17.5579, Expected=17.0780
# Month=58, Predicted=17.0649, Expected=16.6600
# Month=59, Predicted=16.6469, Expected=16.4330
# Month=60, Predicted=16.4199, Expected=16.5840
# Run 30 — RMSE: 0.562482, MSE: 0.316386, NMSE: 0.0026330186

# %%
# ============================================================
# Attention (lag=20) Summary Statistics
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=20) FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(att20_all_rmse):.10f} ± {np.var(att20_all_rmse):.15f}')
print(f'MSE:  {np.mean(att20_all_mse):.10f} ± {np.var(att20_all_mse):.15f}')
print(f'NMSE: {np.mean(att20_all_nmse):.10f} ± {np.var(att20_all_nmse):.15f}')

best_att20_idx = att20_all_rmse.index(min(att20_all_rmse))
print(f'\nBest run: {best_att20_idx+1}')
print(f'  RMSE: {att20_all_rmse[best_att20_idx]:.15f}')
print(f'  MSE:  {att20_all_mse[best_att20_idx]:.15f}')
print(f'  NMSE: {att20_all_nmse[best_att20_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att20_preds = att20_all_predictions[best_att20_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att20_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=20) — Best Run')
plt.show()
# Out:
# ===== LSTM-SNP + Attention (lag=20) FINAL RESULTS (30 runs) =====
# RMSE: 0.5616166860 ± 0.000040430553949
# MSE:  0.3154537325 ± 0.000048234421101
# NMSE: 0.0026394897 ± 0.000000000870647
#
# Best run: 5
#   RMSE: 0.528090456881927
#   MSE:  0.278879530649763
#   NMSE: 0.002563100323514

# %% [markdown]
# # LSTM-SNP + Attention (lag=30)

# %%
# Redefine supervised data with lag=30

lag30 = 30
supervised_lag30 = timeseries_to_supervised(diff_values, lag30)

train30, test30 = supervised_lag30[:-60], supervised_lag30[-60:]

scaler30 = MinMaxScaler(feature_range=(-1, 1))
scaler30.fit(train30)

train30_scaled = scaler30.transform(train30)
test30_scaled = scaler30.transform(test30)

X_train30 = train30_scaled[:, :-1].reshape((-1, lag30, 1))
y_train30 = train30_scaled[:, -1]

X_test30 = test30_scaled[:, :-1].reshape((-1, lag30, 1))
y_test30 = test30_scaled[:, -1]

print(f"X_train30 shape: {X_train30.shape}")  # (samples, 30, 1)
print(f"X_test30 shape:  {X_test30.shape}")   # (60, 30, 1)
# Out:
# X_train30 shape: (539, 30, 1)
# X_test30 shape:  (60, 30, 1)

# %%
att30_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att30_model_check.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (1, None, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn_1 (RNN)                     │ (1, None, 8)           │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_attention_1              │ (1, 8)                 │            81 │
# │ (SimpleAttention)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 410 (1.60 KB)
#  Trainable params: 410 (1.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# LSTM-SNP + Attention (lag=30): 30-Run Protocol
# ============================================================

att30_all_rmse = []
att30_all_mse = []
att30_all_nmse = []
att30_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=30) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model (input_dim=1, lag=30 timesteps)
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train30,
            y_train30,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    model.predict(X_train30, batch_size=1, verbose=0)

    # Test predictions (single-step over lag=30 windows)
    predictions = []
    for i in range(len(test30_scaled)):
        X_input = X_test30[i].reshape(1, lag30, 1)
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling: reconstruct full row [x1..x30, yhat]
        new_row = list(X_test30[i].flatten()) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler30.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train30) + i]

        predictions.append(inverted)

        expected = raw_values[len(train30) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att30_all_rmse.append(rmse)
    att30_all_mse.append(mse)
    att30_all_nmse.append(nmse)
    att30_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== Attention(lag=30) RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2155, Expected=13.7000
# Month=2, Predicted=13.7805, Expected=13.8140
# Month=3, Predicted=13.8933, Expected=14.3830
# Month=4, Predicted=14.4585, Expected=15.0470
# Month=5, Predicted=15.1181, Expected=15.6930
# Month=6, Predicted=15.7600, Expected=15.8440
# Month=7, Predicted=15.9095, Expected=15.7120
# Month=8, Predicted=15.7775, Expected=15.3130
# Month=9, Predicted=15.3801, Expected=14.7630
# Month=10, Predicted=14.8340, Expected=13.5480
# Month=11, Predicted=13.6271, Expected=13.5860
# Month=12, Predicted=13.6676, Expected=14.5160
# Month=13, Predicted=14.5918, Expected=14.3830
# Month=14, Predicted=14.4585, Expected=14.4970
# Month=15, Predicted=14.5711, Expected=14.7440
# Month=16, Predicted=14.8161, Expected=15.8060
# Month=17, Predicted=15.8706, Expected=16.5270
# Month=18, Predicted=16.5873, Expected=16.5460
# Month=19, Predicted=16.6061, Expected=16.7170
# Month=20, Predicted=16.7782, Expected=16.4330
# Month=21, Predicted=16.4959, Expected=15.7690
# Month=22, Predicted=15.8392, Expected=15.2750
# Month=23, Predicted=15.3499, Expected=15.1230
# Month=24, Predicted=15.2010, Expected=15.5410
# Month=25, Predicted=15.6172, Expected=15.8250
# Month=26, Predicted=15.8993, Expected=16.3760
# Month=27, Predicted=16.4472, Expected=16.3570
# Month=28, Predicted=16.4277, Expected=16.9070
# Month=29, Predicted=16.9743, Expected=17.0210
# Month=30, Predicted=17.0874, Expected=17.4190
# Month=31, Predicted=17.4843, Expected=17.5330
# Month=32, Predicted=17.6003, Expected=17.2680
# Month=33, Predicted=17.3363, Expected=16.6030
# Month=34, Predicted=16.6751, Expected=15.8250
# Month=35, Predicted=15.9018, Expected=15.4460
# Month=36, Predicted=15.5269, Expected=15.6360
# Month=37, Predicted=15.7167, Expected=15.6930
# Month=38, Predicted=15.7731, Expected=16.7550
# Month=39, Predicted=16.8276, Expected=16.5090
# Month=40, Predicted=16.5811, Expected=17.7230
# Month=41, Predicted=17.7860, Expected=18.6910
# Month=42, Predicted=18.7490, Expected=19.1270
# Month=43, Predicted=19.1879, Expected=19.5640
# Month=44, Predicted=19.6231, Expected=19.2030
# Month=45, Predicted=19.2632, Expected=18.2160
# Month=46, Predicted=18.2784, Expected=17.2110
# Month=47, Predicted=17.2809, Expected=16.6600
# Month=48, Predicted=16.7346, Expected=16.8310
# Month=49, Predicted=16.9050, Expected=15.7690
# Month=50, Predicted=15.8454, Expected=15.7310
# Month=51, Predicted=15.8067, Expected=15.9960
# Month=52, Predicted=16.0694, Expected=17.0210
# Month=53, Predicted=17.0874, Expected=17.5520
# Month=54, Predicted=17.6157, Expected=17.8370
# Month=55, Predicted=17.9013, Expected=17.8560
# Month=56, Predicted=17.9212, Expected=17.5710
# Month=57, Predicted=17.6392, Expected=17.0780
# Month=58, Predicted=17.1473, Expected=16.6600
# Month=59, Predicted=16.7327, Expected=16.4330
# Month=60, Predicted=16.5067, Expected=16.5840
# Run 1 — RMSE: 0.556474, MSE: 0.309664, NMSE: 0.0026017544
#
# ===== Attention(lag=30) RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.1370, Expected=13.7000
# Month=2, Predicted=13.6859, Expected=13.8140
# Month=3, Predicted=13.7936, Expected=14.3830
# Month=4, Predicted=14.3431, Expected=15.0470
# Month=5, Predicted=14.9852, Expected=15.6930
# Month=6, Predicted=15.6102, Expected=15.8440
# Month=7, Predicted=15.7538, Expected=15.7120
# Month=8, Predicted=15.6205, Expected=15.3130
# Month=9, Predicted=15.2291, Expected=14.7630
# Month=10, Predicted=14.6987, Expected=13.5480
# Month=11, Predicted=13.5162, Expected=13.5860
# Month=12, Predicted=13.5689, Expected=14.5160
# Month=13, Predicted=14.4732, Expected=14.3830
# Month=14, Predicted=14.3393, Expected=14.4970
# Month=15, Predicted=14.4481, Expected=14.7440
# Month=16, Predicted=14.6865, Expected=15.8060
# Month=17, Predicted=15.7175, Expected=16.5270
# Month=18, Predicted=16.4148, Expected=16.5460
# Month=19, Predicted=16.4312, Expected=16.7170
# Month=20, Predicted=16.6075, Expected=16.4330
# Month=21, Predicted=16.3348, Expected=15.7690
# Month=22, Predicted=15.7025, Expected=15.2750
# Month=23, Predicted=15.2331, Expected=15.1230
# Month=24, Predicted=15.0983, Expected=15.5410
# Month=25, Predicted=15.5069, Expected=15.8250
# Month=26, Predicted=15.7822, Expected=16.3760
# Month=27, Predicted=16.3154, Expected=16.3570
# Month=28, Predicted=16.2937, Expected=16.9070
# Month=29, Predicted=16.8262, Expected=17.0210
# Month=30, Predicted=16.9343, Expected=17.4190
# Month=31, Predicted=17.3242, Expected=17.5330
# Month=32, Predicted=17.4481, Expected=17.2680
# Month=33, Predicted=17.1908, Expected=16.6030
# Month=34, Predicted=16.5450, Expected=15.8250
# Month=35, Predicted=15.7901, Expected=15.4460
# Month=36, Predicted=15.4325, Expected=15.6360
# Month=37, Predicted=15.6222, Expected=15.6930
# Month=38, Predicted=15.6770, Expected=16.7550
# Month=39, Predicted=16.7060, Expected=16.5090
# Month=40, Predicted=16.4586, Expected=17.7230
# Month=41, Predicted=17.6367, Expected=18.6910
# Month=42, Predicted=18.5754, Expected=19.1270
# Month=43, Predicted=19.0195, Expected=19.5640
# Month=44, Predicted=19.4488, Expected=19.2030
# Month=45, Predicted=19.0933, Expected=18.2160
# Month=46, Predicted=18.1178, Expected=17.2110
# Month=47, Predicted=17.1445, Expected=16.6600
# Month=48, Predicted=16.6173, Expected=16.8310
# Month=49, Predicted=16.7865, Expected=15.7690
# Month=50, Predicted=15.7325, Expected=15.7310
# Month=51, Predicted=15.6927, Expected=15.9960
# Month=52, Predicted=15.9485, Expected=17.0210
# Month=53, Predicted=16.9408, Expected=17.5520
# Month=54, Predicted=17.4551, Expected=17.8370
# Month=55, Predicted=17.7419, Expected=17.8560
# Month=56, Predicted=17.7675, Expected=17.5710
# Month=57, Predicted=17.4995, Expected=17.0780
# Month=58, Predicted=17.0129, Expected=16.6600
# Month=59, Predicted=16.6126, Expected=16.4330
# Month=60, Predicted=16.3914, Expected=16.5840
# Run 2 — RMSE: 0.562962, MSE: 0.316926, NMSE: 0.0027098203
#
# ===== Attention(lag=30) RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.1177, Expected=13.7000
# Month=2, Predicted=13.6867, Expected=13.8140
# Month=3, Predicted=13.8007, Expected=14.3830
# Month=4, Predicted=14.3697, Expected=15.0470
# Month=5, Predicted=15.0337, Expected=15.6930
# Month=6, Predicted=15.6797, Expected=15.8440
# Month=7, Predicted=15.8307, Expected=15.7120
# Month=8, Predicted=15.6987, Expected=15.3130
# Month=9, Predicted=15.2997, Expected=14.7630
# Month=10, Predicted=14.7497, Expected=13.5480
# Month=11, Predicted=13.5347, Expected=13.5860
# Month=12, Predicted=13.5727, Expected=14.5160
# Month=13, Predicted=14.5027, Expected=14.3830
# Month=14, Predicted=14.3697, Expected=14.4970
# Month=15, Predicted=14.4837, Expected=14.7440
# Month=16, Predicted=14.7307, Expected=15.8060
# Month=17, Predicted=15.7927, Expected=16.5270
# Month=18, Predicted=16.5137, Expected=16.5460
# Month=19, Predicted=16.5327, Expected=16.7170
# Month=20, Predicted=16.7037, Expected=16.4330
# Month=21, Predicted=16.4197, Expected=15.7690
# Month=22, Predicted=15.7557, Expected=15.2750
# Month=23, Predicted=15.2617, Expected=15.1230
# Month=24, Predicted=15.1097, Expected=15.5410
# Month=25, Predicted=15.5277, Expected=15.8250
# Month=26, Predicted=15.8117, Expected=16.3760
# Month=27, Predicted=16.3627, Expected=16.3570
# Month=28, Predicted=16.3437, Expected=16.9070
# Month=29, Predicted=16.8937, Expected=17.0210
# Month=30, Predicted=17.0077, Expected=17.4190
# Month=31, Predicted=17.4057, Expected=17.5330
# Month=32, Predicted=17.5197, Expected=17.2680
# Month=33, Predicted=17.2547, Expected=16.6030
# Month=34, Predicted=16.5897, Expected=15.8250
# Month=35, Predicted=15.8117, Expected=15.4460
# Month=36, Predicted=15.4327, Expected=15.6360
# Month=37, Predicted=15.6227, Expected=15.6930
# Month=38, Predicted=15.6797, Expected=16.7550
# Month=39, Predicted=16.7417, Expected=16.5090
# Month=40, Predicted=16.4957, Expected=17.7230
# Month=41, Predicted=17.7097, Expected=18.6910
# Month=42, Predicted=18.6777, Expected=19.1270
# Month=43, Predicted=19.1137, Expected=19.5640
# Month=44, Predicted=19.5507, Expected=19.2030
# Month=45, Predicted=19.1897, Expected=18.2160
# Month=46, Predicted=18.2027, Expected=17.2110
# Month=47, Predicted=17.1977, Expected=16.6600
# Month=48, Predicted=16.6467, Expected=16.8310
# Month=49, Predicted=16.8177, Expected=15.7690
# Month=50, Predicted=15.7557, Expected=15.7310
# Month=51, Predicted=15.7177, Expected=15.9960
# Month=52, Predicted=15.9827, Expected=17.0210
# Month=53, Predicted=17.0077, Expected=17.5520
# Month=54, Predicted=17.5387, Expected=17.8370
# Month=55, Predicted=17.8237, Expected=17.8560
# Month=56, Predicted=17.8427, Expected=17.5710
# Month=57, Predicted=17.5577, Expected=17.0780
# Month=58, Predicted=17.0647, Expected=16.6600
# Month=59, Predicted=16.6467, Expected=16.4330
# Month=60, Predicted=16.4197, Expected=16.5840
# Run 3 — RMSE: 0.562505, MSE: 0.316412, NMSE: 0.0026332027
#
# ===== Attention(lag=30) RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.1529, Expected=13.7000
# Month=2, Predicted=13.7011, Expected=13.8140
# Month=3, Predicted=13.8081, Expected=14.3830
# Month=4, Predicted=14.3567, Expected=15.0470
# Month=5, Predicted=14.9969, Expected=15.6930
# Month=6, Predicted=15.6209, Expected=15.8440
# Month=7, Predicted=15.7628, Expected=15.7120
# Month=8, Predicted=15.6304, Expected=15.3130
# Month=9, Predicted=15.2408, Expected=14.7630
# Month=10, Predicted=14.7124, Expected=13.5480
# Month=11, Predicted=13.5386, Expected=13.5860
# Month=12, Predicted=13.5895, Expected=14.5160
# Month=13, Predicted=14.4917, Expected=14.3830
# Month=14, Predicted=14.3569, Expected=14.4970
# Month=15, Predicted=14.4626, Expected=14.7440
# Month=16, Predicted=14.6982, Expected=15.8060
# Month=17, Predicted=15.7216, Expected=16.5270
# Month=18, Predicted=16.4190, Expected=16.5460
# Month=19, Predicted=16.4367, Expected=16.7170
# Month=20, Predicted=16.6134, Expected=16.4330
# Month=21, Predicted=16.3393, Expected=15.7690
# Month=22, Predicted=15.7123, Expected=15.2750
# Month=23, Predicted=15.2433, Expected=15.1230
# Month=24, Predicted=15.1070, Expected=15.5410
# Month=25, Predicted=15.5157, Expected=15.8250
# Month=26, Predicted=15.7896, Expected=16.3760
# Month=27, Predicted=16.3239, Expected=16.3570
# Month=28, Predicted=16.3018, Expected=16.9070
# Month=29, Predicted=16.8330, Expected=17.0210
# Month=30, Predicted=16.9415, Expected=17.4190
# Month=31, Predicted=17.3335, Expected=17.5330
# Month=32, Predicted=17.4579, Expected=17.2680
# Month=33, Predicted=17.1991, Expected=16.6030
# Month=34, Predicted=16.5551, Expected=15.8250
# Month=35, Predicted=15.8024, Expected=15.4460
# Month=36, Predicted=15.4449, Expected=15.6360
# Month=37, Predicted=15.6340, Expected=15.6930
# Month=38, Predicted=15.6878, Expected=16.7550
# Month=39, Predicted=16.7136, Expected=16.5090
# Month=40, Predicted=16.4643, Expected=17.7230
# Month=41, Predicted=17.6324, Expected=18.6910
# Month=42, Predicted=18.5751, Expected=19.1270
# Month=43, Predicted=19.0251, Expected=19.5640
# Month=44, Predicted=19.4517, Expected=19.2030
# Month=45, Predicted=19.0976, Expected=18.2160
# Month=46, Predicted=18.1252, Expected=17.2110
# Month=47, Predicted=17.1594, Expected=16.6600
# Month=48, Predicted=16.6337, Expected=16.8310
# Month=49, Predicted=16.8018, Expected=15.7690
# Month=50, Predicted=15.7543, Expected=15.7310
# Month=51, Predicted=15.7127, Expected=15.9960
# Month=52, Predicted=15.9640, Expected=17.0210
# Month=53, Predicted=16.9537, Expected=17.5520
# Month=54, Predicted=17.4702, Expected=17.8370
# Month=55, Predicted=17.7581, Expected=17.8560
# Month=56, Predicted=17.7822, Expected=17.5710
# Month=57, Predicted=17.5141, Expected=17.0780
# Month=58, Predicted=17.0277, Expected=16.6600
# Month=59, Predicted=16.6284, Expected=16.4330
# Month=60, Predicted=16.4073, Expected=16.5840
# Run 4 — RMSE: 0.561044, MSE: 0.314771, NMSE: 0.0027056082
#
# ===== Attention(lag=30) RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 5 — RMSE: 0.563210, MSE: 0.317206, NMSE: 0.0026387612
#
# ===== Attention(lag=30) RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.1084, Expected=13.7000
# Month=2, Predicted=13.6774, Expected=13.8140
# Month=3, Predicted=13.7914, Expected=14.3830
# Month=4, Predicted=14.3604, Expected=15.0470
# Month=5, Predicted=15.0244, Expected=15.6930
# Month=6, Predicted=15.6704, Expected=15.8440
# Month=7, Predicted=15.8214, Expected=15.7120
# Month=8, Predicted=15.6894, Expected=15.3130
# Month=9, Predicted=15.2904, Expected=14.7630
# Month=10, Predicted=14.7404, Expected=13.5480
# Month=11, Predicted=13.5254, Expected=13.5860
# Month=12, Predicted=13.5634, Expected=14.5160
# Month=13, Predicted=14.4934, Expected=14.3830
# Month=14, Predicted=14.3604, Expected=14.4970
# Month=15, Predicted=14.4744, Expected=14.7440
# Month=16, Predicted=14.7214, Expected=15.8060
# Month=17, Predicted=15.7834, Expected=16.5270
# Month=18, Predicted=16.5044, Expected=16.5460
# Month=19, Predicted=16.5234, Expected=16.7170
# Month=20, Predicted=16.6944, Expected=16.4330
# Month=21, Predicted=16.4104, Expected=15.7690
# Month=22, Predicted=15.7464, Expected=15.2750
# Month=23, Predicted=15.2524, Expected=15.1230
# Month=24, Predicted=15.1004, Expected=15.5410
# Month=25, Predicted=15.5184, Expected=15.8250
# Month=26, Predicted=15.8024, Expected=16.3760
# Month=27, Predicted=16.3534, Expected=16.3570
# Month=28, Predicted=16.3344, Expected=16.9070
# Month=29, Predicted=16.8844, Expected=17.0210
# Month=30, Predicted=16.9984, Expected=17.4190
# Month=31, Predicted=17.3964, Expected=17.5330
# Month=32, Predicted=17.5104, Expected=17.2680
# Month=33, Predicted=17.2454, Expected=16.6030
# Month=34, Predicted=16.5804, Expected=15.8250
# Month=35, Predicted=15.8024, Expected=15.4460
# Month=36, Predicted=15.4234, Expected=15.6360
# Month=37, Predicted=15.6134, Expected=15.6930
# Month=38, Predicted=15.6704, Expected=16.7550
# Month=39, Predicted=16.7324, Expected=16.5090
# Month=40, Predicted=16.4864, Expected=17.7230
# Month=41, Predicted=17.7004, Expected=18.6910
# Month=42, Predicted=18.6684, Expected=19.1270
# Month=43, Predicted=19.1044, Expected=19.5640
# Month=44, Predicted=19.5414, Expected=19.2030
# Month=45, Predicted=19.1804, Expected=18.2160
# Month=46, Predicted=18.1934, Expected=17.2110
# Month=47, Predicted=17.1884, Expected=16.6600
# Month=48, Predicted=16.6374, Expected=16.8310
# Month=49, Predicted=16.8084, Expected=15.7690
# Month=50, Predicted=15.7464, Expected=15.7310
# Month=51, Predicted=15.7084, Expected=15.9960
# Month=52, Predicted=15.9734, Expected=17.0210
# Month=53, Predicted=16.9984, Expected=17.5520
# Month=54, Predicted=17.5294, Expected=17.8370
# Month=55, Predicted=17.8144, Expected=17.8560
# Month=56, Predicted=17.8334, Expected=17.5710
# Month=57, Predicted=17.5484, Expected=17.0780
# Month=58, Predicted=17.0554, Expected=16.6600
# Month=59, Predicted=16.6374, Expected=16.4330
# Month=60, Predicted=16.4104, Expected=16.5840
# Run 6 — RMSE: 0.563757, MSE: 0.317822, NMSE: 0.0026430774
#
# ===== Attention(lag=30) RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.1257, Expected=13.7000
# Month=2, Predicted=13.6947, Expected=13.8140
# Month=3, Predicted=13.8087, Expected=14.3830
# Month=4, Predicted=14.3777, Expected=15.0470
# Month=5, Predicted=15.0417, Expected=15.6930
# Month=6, Predicted=15.6877, Expected=15.8440
# Month=7, Predicted=15.8387, Expected=15.7120
# Month=8, Predicted=15.7067, Expected=15.3130
# Month=9, Predicted=15.3077, Expected=14.7630
# Month=10, Predicted=14.7577, Expected=13.5480
# Month=11, Predicted=13.5427, Expected=13.5860
# Month=12, Predicted=13.5807, Expected=14.5160
# Month=13, Predicted=14.5107, Expected=14.3830
# Month=14, Predicted=14.3777, Expected=14.4970
# Month=15, Predicted=14.4917, Expected=14.7440
# Month=16, Predicted=14.7387, Expected=15.8060
# Month=17, Predicted=15.8007, Expected=16.5270
# Month=18, Predicted=16.5217, Expected=16.5460
# Month=19, Predicted=16.5407, Expected=16.7170
# Month=20, Predicted=16.7117, Expected=16.4330
# Month=21, Predicted=16.4277, Expected=15.7690
# Month=22, Predicted=15.7637, Expected=15.2750
# Month=23, Predicted=15.2697, Expected=15.1230
# Month=24, Predicted=15.1177, Expected=15.5410
# Month=25, Predicted=15.5357, Expected=15.8250
# Month=26, Predicted=15.8197, Expected=16.3760
# Month=27, Predicted=16.3707, Expected=16.3570
# Month=28, Predicted=16.3517, Expected=16.9070
# Month=29, Predicted=16.9017, Expected=17.0210
# Month=30, Predicted=17.0157, Expected=17.4190
# Month=31, Predicted=17.4137, Expected=17.5330
# Month=32, Predicted=17.5277, Expected=17.2680
# Month=33, Predicted=17.2627, Expected=16.6030
# Month=34, Predicted=16.5977, Expected=15.8250
# Month=35, Predicted=15.8197, Expected=15.4460
# Month=36, Predicted=15.4407, Expected=15.6360
# Month=37, Predicted=15.6307, Expected=15.6930
# Month=38, Predicted=15.6877, Expected=16.7550
# Month=39, Predicted=16.7497, Expected=16.5090
# Month=40, Predicted=16.5037, Expected=17.7230
# Month=41, Predicted=17.7177, Expected=18.6910
# Month=42, Predicted=18.6857, Expected=19.1270
# Month=43, Predicted=19.1217, Expected=19.5640
# Month=44, Predicted=19.5587, Expected=19.2030
# Month=45, Predicted=19.1977, Expected=18.2160
# Month=46, Predicted=18.2107, Expected=17.2110
# Month=47, Predicted=17.2057, Expected=16.6600
# Month=48, Predicted=16.6547, Expected=16.8310
# Month=49, Predicted=16.8257, Expected=15.7690
# Month=50, Predicted=15.7637, Expected=15.7310
# Month=51, Predicted=15.7257, Expected=15.9960
# Month=52, Predicted=15.9907, Expected=17.0210
# Month=53, Predicted=17.0157, Expected=17.5520
# Month=54, Predicted=17.5467, Expected=17.8370
# Month=55, Predicted=17.8317, Expected=17.8560
# Month=56, Predicted=17.8507, Expected=17.5710
# Month=57, Predicted=17.5657, Expected=17.0780
# Month=58, Predicted=17.0727, Expected=16.6600
# Month=59, Predicted=16.6547, Expected=16.4330
# Month=60, Predicted=16.4277, Expected=16.5840
# Run 7 — RMSE: 0.561556, MSE: 0.315345, NMSE: 0.0026257185
#
# ===== Attention(lag=30) RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.1119, Expected=13.7000
# Month=2, Predicted=13.6809, Expected=13.8140
# Month=3, Predicted=13.7949, Expected=14.3830
# Month=4, Predicted=14.3639, Expected=15.0470
# Month=5, Predicted=15.0279, Expected=15.6930
# Month=6, Predicted=15.6739, Expected=15.8440
# Month=7, Predicted=15.8249, Expected=15.7120
# Month=8, Predicted=15.6929, Expected=15.3130
# Month=9, Predicted=15.2939, Expected=14.7630
# Month=10, Predicted=14.7439, Expected=13.5480
# Month=11, Predicted=13.5289, Expected=13.5860
# Month=12, Predicted=13.5669, Expected=14.5160
# Month=13, Predicted=14.4969, Expected=14.3830
# Month=14, Predicted=14.3639, Expected=14.4970
# Month=15, Predicted=14.4779, Expected=14.7440
# Month=16, Predicted=14.7249, Expected=15.8060
# Month=17, Predicted=15.7869, Expected=16.5270
# Month=18, Predicted=16.5079, Expected=16.5460
# Month=19, Predicted=16.5269, Expected=16.7170
# Month=20, Predicted=16.6979, Expected=16.4330
# Month=21, Predicted=16.4139, Expected=15.7690
# Month=22, Predicted=15.7499, Expected=15.2750
# Month=23, Predicted=15.2559, Expected=15.1230
# Month=24, Predicted=15.1039, Expected=15.5410
# Month=25, Predicted=15.5219, Expected=15.8250
# Month=26, Predicted=15.8059, Expected=16.3760
# Month=27, Predicted=16.3569, Expected=16.3570
# Month=28, Predicted=16.3379, Expected=16.9070
# Month=29, Predicted=16.8879, Expected=17.0210
# Month=30, Predicted=17.0019, Expected=17.4190
# Month=31, Predicted=17.3999, Expected=17.5330
# Month=32, Predicted=17.5139, Expected=17.2680
# Month=33, Predicted=17.2489, Expected=16.6030
# Month=34, Predicted=16.5839, Expected=15.8250
# Month=35, Predicted=15.8059, Expected=15.4460
# Month=36, Predicted=15.4269, Expected=15.6360
# Month=37, Predicted=15.6169, Expected=15.6930
# Month=38, Predicted=15.6739, Expected=16.7550
# Month=39, Predicted=16.7359, Expected=16.5090
# Month=40, Predicted=16.4899, Expected=17.7230
# Month=41, Predicted=17.7039, Expected=18.6910
# Month=42, Predicted=18.6719, Expected=19.1270
# Month=43, Predicted=19.1079, Expected=19.5640
# Month=44, Predicted=19.5449, Expected=19.2030
# Month=45, Predicted=19.1839, Expected=18.2160
# Month=46, Predicted=18.1969, Expected=17.2110
# Month=47, Predicted=17.1919, Expected=16.6600
# Month=48, Predicted=16.6409, Expected=16.8310
# Month=49, Predicted=16.8119, Expected=15.7690
# Month=50, Predicted=15.7499, Expected=15.7310
# Month=51, Predicted=15.7119, Expected=15.9960
# Month=52, Predicted=15.9769, Expected=17.0210
# Month=53, Predicted=17.0019, Expected=17.5520
# Month=54, Predicted=17.5329, Expected=17.8370
# Month=55, Predicted=17.8179, Expected=17.8560
# Month=56, Predicted=17.8369, Expected=17.5710
# Month=57, Predicted=17.5519, Expected=17.0780
# Month=58, Predicted=17.0589, Expected=16.6600
# Month=59, Predicted=16.6409, Expected=16.4330
# Month=60, Predicted=16.4139, Expected=16.5840
# Run 8 — RMSE: 0.563263, MSE: 0.317265, NMSE: 0.0026391770
#
# ===== Attention(lag=30) RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.1171, Expected=13.7000
# Month=2, Predicted=13.6861, Expected=13.8140
# Month=3, Predicted=13.8001, Expected=14.3830
# Month=4, Predicted=14.3691, Expected=15.0470
# Month=5, Predicted=15.0331, Expected=15.6930
# Month=6, Predicted=15.6791, Expected=15.8440
# Month=7, Predicted=15.8301, Expected=15.7120
# Month=8, Predicted=15.6981, Expected=15.3130
# Month=9, Predicted=15.2991, Expected=14.7630
# Month=10, Predicted=14.7491, Expected=13.5480
# Month=11, Predicted=13.5341, Expected=13.5860
# Month=12, Predicted=13.5721, Expected=14.5160
# Month=13, Predicted=14.5021, Expected=14.3830
# Month=14, Predicted=14.3691, Expected=14.4970
# Month=15, Predicted=14.4831, Expected=14.7440
# Month=16, Predicted=14.7301, Expected=15.8060
# Month=17, Predicted=15.7921, Expected=16.5270
# Month=18, Predicted=16.5131, Expected=16.5460
# Month=19, Predicted=16.5321, Expected=16.7170
# Month=20, Predicted=16.7031, Expected=16.4330
# Month=21, Predicted=16.4191, Expected=15.7690
# Month=22, Predicted=15.7551, Expected=15.2750
# Month=23, Predicted=15.2611, Expected=15.1230
# Month=24, Predicted=15.1091, Expected=15.5410
# Month=25, Predicted=15.5271, Expected=15.8250
# Month=26, Predicted=15.8111, Expected=16.3760
# Month=27, Predicted=16.3621, Expected=16.3570
# Month=28, Predicted=16.3431, Expected=16.9070
# Month=29, Predicted=16.8931, Expected=17.0210
# Month=30, Predicted=17.0071, Expected=17.4190
# Month=31, Predicted=17.4051, Expected=17.5330
# Month=32, Predicted=17.5191, Expected=17.2680
# Month=33, Predicted=17.2541, Expected=16.6030
# Month=34, Predicted=16.5891, Expected=15.8250
# Month=35, Predicted=15.8111, Expected=15.4460
# Month=36, Predicted=15.4321, Expected=15.6360
# Month=37, Predicted=15.6221, Expected=15.6930
# Month=38, Predicted=15.6791, Expected=16.7550
# Month=39, Predicted=16.7411, Expected=16.5090
# Month=40, Predicted=16.4951, Expected=17.7230
# Month=41, Predicted=17.7091, Expected=18.6910
# Month=42, Predicted=18.6771, Expected=19.1270
# Month=43, Predicted=19.1131, Expected=19.5640
# Month=44, Predicted=19.5501, Expected=19.2030
# Month=45, Predicted=19.1891, Expected=18.2160
# Month=46, Predicted=18.2021, Expected=17.2110
# Month=47, Predicted=17.1971, Expected=16.6600
# Month=48, Predicted=16.6461, Expected=16.8310
# Month=49, Predicted=16.8171, Expected=15.7690
# Month=50, Predicted=15.7551, Expected=15.7310
# Month=51, Predicted=15.7171, Expected=15.9960
# Month=52, Predicted=15.9821, Expected=17.0210
# Month=53, Predicted=17.0071, Expected=17.5520
# Month=54, Predicted=17.5381, Expected=17.8370
# Month=55, Predicted=17.8231, Expected=17.8560
# Month=56, Predicted=17.8421, Expected=17.5710
# Month=57, Predicted=17.5571, Expected=17.0780
# Month=58, Predicted=17.0641, Expected=16.6600
# Month=59, Predicted=16.6461, Expected=16.4330
# Month=60, Predicted=16.4191, Expected=16.5840
# Run 9 — RMSE: 0.562586, MSE: 0.316503, NMSE: 0.0026338379
#
# ===== Attention(lag=30) RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 10 — RMSE: 0.563213, MSE: 0.317209, NMSE: 0.0026387807
#
# ===== Attention(lag=30) RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.1469, Expected=13.7000
# Month=2, Predicted=13.6956, Expected=13.8140
# Month=3, Predicted=13.8026, Expected=14.3830
# Month=4, Predicted=14.3520, Expected=15.0470
# Month=5, Predicted=14.9938, Expected=15.6930
# Month=6, Predicted=15.6181, Expected=15.8440
# Month=7, Predicted=15.7612, Expected=15.7120
# Month=8, Predicted=15.6278, Expected=15.3130
# Month=9, Predicted=15.2357, Expected=14.7630
# Month=10, Predicted=14.7051, Expected=13.5480
# Month=11, Predicted=13.5232, Expected=13.5860
# Month=12, Predicted=13.5769, Expected=14.5160
# Month=13, Predicted=14.4812, Expected=14.3830
# Month=14, Predicted=14.3472, Expected=14.4970
# Month=15, Predicted=14.4548, Expected=14.7440
# Month=16, Predicted=14.6917, Expected=15.8060
# Month=17, Predicted=15.7239, Expected=16.5270
# Month=18, Predicted=16.4214, Expected=16.5460
# Month=19, Predicted=16.4375, Expected=16.7170
# Month=20, Predicted=16.6142, Expected=16.4330
# Month=21, Predicted=16.3406, Expected=15.7690
# Month=22, Predicted=15.7077, Expected=15.2750
# Month=23, Predicted=15.2391, Expected=15.1230
# Month=24, Predicted=15.1051, Expected=15.5410
# Month=25, Predicted=15.5129, Expected=15.8250
# Month=26, Predicted=15.7869, Expected=16.3760
# Month=27, Predicted=16.3207, Expected=16.3570
# Month=28, Predicted=16.2988, Expected=16.9070
# Month=29, Predicted=16.8319, Expected=17.0210
# Month=30, Predicted=16.9398, Expected=17.4190
# Month=31, Predicted=17.3293, Expected=17.5330
# Month=32, Predicted=17.4536, Expected=17.2680
# Month=33, Predicted=17.1953, Expected=16.6030
# Month=34, Predicted=16.5483, Expected=15.8250
# Month=35, Predicted=15.7934, Expected=15.4460
# Month=36, Predicted=15.4369, Expected=15.6360
# Month=37, Predicted=15.6274, Expected=15.6930
# Month=38, Predicted=15.6818, Expected=16.7550
# Month=39, Predicted=16.7103, Expected=16.5090
# Month=40, Predicted=16.4626, Expected=17.7230
# Month=41, Predicted=17.6417, Expected=18.6910
# Month=42, Predicted=18.5789, Expected=19.1270
# Month=43, Predicted=19.0226, Expected=19.5640
# Month=44, Predicted=19.4520, Expected=19.2030
# Month=45, Predicted=19.0959, Expected=18.2160
# Month=46, Predicted=18.1184, Expected=17.2110
# Month=47, Predicted=17.1444, Expected=16.6600
# Month=48, Predicted=16.6181, Expected=16.8310
# Month=49, Predicted=16.7879, Expected=15.7690
# Month=50, Predicted=15.7351, Expected=15.7310
# Month=51, Predicted=15.6950, Expected=15.9960
# Month=52, Predicted=15.9498, Expected=17.0210
# Month=53, Predicted=16.9442, Expected=17.5520
# Month=54, Predicted=17.4591, Expected=17.8370
# Month=55, Predicted=17.7463, Expected=17.8560
# Month=56, Predicted=17.7716, Expected=17.5710
# Month=57, Predicted=17.5027, Expected=17.0780
# Month=58, Predicted=17.0151, Expected=16.6600
# Month=59, Predicted=16.6143, Expected=16.4330
# Month=60, Predicted=16.3938, Expected=16.5840
# Run 11 — RMSE: 0.561294, MSE: 0.315051, NMSE: 0.0027014960
#
# ===== Attention(lag=30) RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.1261, Expected=13.7000
# Month=2, Predicted=13.6823, Expected=13.8140
# Month=3, Predicted=13.7915, Expected=14.3830
# Month=4, Predicted=14.3482, Expected=15.0470
# Month=5, Predicted=14.9975, Expected=15.6930
# Month=6, Predicted=15.6293, Expected=15.8440
# Month=7, Predicted=15.7748, Expected=15.7120
# Month=8, Predicted=15.6421, Expected=15.3130
# Month=9, Predicted=15.2484, Expected=14.7630
# Month=10, Predicted=14.7119, Expected=13.5480
# Month=11, Predicted=13.5225, Expected=13.5860
# Month=12, Predicted=13.5687, Expected=14.5160
# Month=13, Predicted=14.4794, Expected=14.3830
# Month=14, Predicted=14.3456, Expected=14.4970
# Month=15, Predicted=14.4553, Expected=14.7440
# Month=16, Predicted=14.6961, Expected=15.8060
# Month=17, Predicted=15.7348, Expected=16.5270
# Month=18, Predicted=16.4394, Expected=16.5460
# Month=19, Predicted=16.4566, Expected=16.7170
# Month=20, Predicted=16.6305, Expected=16.4330
# Month=21, Predicted=16.3535, Expected=15.7690
# Month=22, Predicted=15.7143, Expected=15.2750
# Month=23, Predicted=15.2370, Expected=15.1230
# Month=24, Predicted=15.0953, Expected=15.5410
# Month=25, Predicted=15.5077, Expected=15.8250
# Month=26, Predicted=15.7858, Expected=16.3760
# Month=27, Predicted=16.3261, Expected=16.3570
# Month=28, Predicted=16.3050, Expected=16.9070
# Month=29, Predicted=16.8443, Expected=17.0210
# Month=30, Predicted=16.9543, Expected=17.4190
# Month=31, Predicted=17.3480, Expected=17.5330
# Month=32, Predicted=17.4682, Expected=17.2680
# Month=33, Predicted=17.2081, Expected=16.6030
# Month=34, Predicted=16.5553, Expected=15.8250
# Month=35, Predicted=15.7923, Expected=15.4460
# Month=36, Predicted=15.4269, Expected=15.6360
# Month=37, Predicted=15.6165, Expected=15.6930
# Month=38, Predicted=15.6715, Expected=16.7550
# Month=39, Predicted=16.7086, Expected=16.5090
# Month=40, Predicted=16.4615, Expected=17.7230
# Month=41, Predicted=17.6474, Expected=18.6910
# Month=42, Predicted=18.5935, Expected=19.1270
# Month=43, Predicted=19.0372, Expected=19.5640
# Month=44, Predicted=19.4700, Expected=19.2030
# Month=45, Predicted=19.1129, Expected=18.2160
# Month=46, Predicted=18.1327, Expected=17.2110
# Month=47, Predicted=17.1520, Expected=16.6600
# Month=48, Predicted=16.6165, Expected=16.8310
# Month=49, Predicted=16.7863, Expected=15.7690
# Month=50, Predicted=15.7297, Expected=15.7310
# Month=51, Predicted=15.6900, Expected=15.9960
# Month=52, Predicted=15.9486, Expected=17.0210
# Month=53, Predicted=16.9498, Expected=17.5520
# Month=54, Predicted=17.4705, Expected=17.8370
# Month=55, Predicted=17.7562, Expected=17.8560
# Month=56, Predicted=17.7789, Expected=17.5710
# Month=57, Predicted=17.5043, Expected=17.0780
# Month=58, Predicted=17.0155, Expected=16.6600
# Month=59, Predicted=16.6082, Expected=16.4330
# Month=60, Predicted=16.3852, Expected=16.5840
# Run 12 — RMSE: 0.563291, MSE: 0.317296, NMSE: 0.0026982595
#
# ===== Attention(lag=30) RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.1179, Expected=13.7000
# Month=2, Predicted=13.6869, Expected=13.8140
# Month=3, Predicted=13.8009, Expected=14.3830
# Month=4, Predicted=14.3699, Expected=15.0470
# Month=5, Predicted=15.0339, Expected=15.6930
# Month=6, Predicted=15.6799, Expected=15.8440
# Month=7, Predicted=15.8309, Expected=15.7120
# Month=8, Predicted=15.6989, Expected=15.3130
# Month=9, Predicted=15.2999, Expected=14.7630
# Month=10, Predicted=14.7499, Expected=13.5480
# Month=11, Predicted=13.5349, Expected=13.5860
# Month=12, Predicted=13.5729, Expected=14.5160
# Month=13, Predicted=14.5029, Expected=14.3830
# Month=14, Predicted=14.3699, Expected=14.4970
# Month=15, Predicted=14.4839, Expected=14.7440
# Month=16, Predicted=14.7309, Expected=15.8060
# Month=17, Predicted=15.7929, Expected=16.5270
# Month=18, Predicted=16.5139, Expected=16.5460
# Month=19, Predicted=16.5329, Expected=16.7170
# Month=20, Predicted=16.7039, Expected=16.4330
# Month=21, Predicted=16.4199, Expected=15.7690
# Month=22, Predicted=15.7559, Expected=15.2750
# Month=23, Predicted=15.2619, Expected=15.1230
# Month=24, Predicted=15.1099, Expected=15.5410
# Month=25, Predicted=15.5279, Expected=15.8250
# Month=26, Predicted=15.8119, Expected=16.3760
# Month=27, Predicted=16.3629, Expected=16.3570
# Month=28, Predicted=16.3439, Expected=16.9070
# Month=29, Predicted=16.8939, Expected=17.0210
# Month=30, Predicted=17.0079, Expected=17.4190
# Month=31, Predicted=17.4059, Expected=17.5330
# Month=32, Predicted=17.5199, Expected=17.2680
# Month=33, Predicted=17.2549, Expected=16.6030
# Month=34, Predicted=16.5899, Expected=15.8250
# Month=35, Predicted=15.8119, Expected=15.4460
# Month=36, Predicted=15.4329, Expected=15.6360
# Month=37, Predicted=15.6229, Expected=15.6930
# Month=38, Predicted=15.6799, Expected=16.7550
# Month=39, Predicted=16.7419, Expected=16.5090
# Month=40, Predicted=16.4959, Expected=17.7230
# Month=41, Predicted=17.7099, Expected=18.6910
# Month=42, Predicted=18.6779, Expected=19.1270
# Month=43, Predicted=19.1139, Expected=19.5640
# Month=44, Predicted=19.5509, Expected=19.2030
# Month=45, Predicted=19.1899, Expected=18.2160
# Month=46, Predicted=18.2029, Expected=17.2110
# Month=47, Predicted=17.1979, Expected=16.6600
# Month=48, Predicted=16.6469, Expected=16.8310
# Month=49, Predicted=16.8179, Expected=15.7690
# Month=50, Predicted=15.7559, Expected=15.7310
# Month=51, Predicted=15.7179, Expected=15.9960
# Month=52, Predicted=15.9829, Expected=17.0210
# Month=53, Predicted=17.0079, Expected=17.5520
# Month=54, Predicted=17.5389, Expected=17.8370
# Month=55, Predicted=17.8239, Expected=17.8560
# Month=56, Predicted=17.8429, Expected=17.5710
# Month=57, Predicted=17.5579, Expected=17.0780
# Month=58, Predicted=17.0649, Expected=16.6600
# Month=59, Predicted=16.6469, Expected=16.4330
# Month=60, Predicted=16.4199, Expected=16.5840
# Run 13 — RMSE: 0.562481, MSE: 0.316385, NMSE: 0.0026330137
#
# ===== Attention(lag=30) RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.1234, Expected=13.7000
# Month=2, Predicted=13.6924, Expected=13.8140
# Month=3, Predicted=13.8064, Expected=14.3830
# Month=4, Predicted=14.3754, Expected=15.0470
# Month=5, Predicted=15.0394, Expected=15.6930
# Month=6, Predicted=15.6854, Expected=15.8440
# Month=7, Predicted=15.8364, Expected=15.7120
# Month=8, Predicted=15.7044, Expected=15.3130
# Month=9, Predicted=15.3054, Expected=14.7630
# Month=10, Predicted=14.7554, Expected=13.5480
# Month=11, Predicted=13.5404, Expected=13.5860
# Month=12, Predicted=13.5784, Expected=14.5160
# Month=13, Predicted=14.5084, Expected=14.3830
# Month=14, Predicted=14.3754, Expected=14.4970
# Month=15, Predicted=14.4894, Expected=14.7440
# Month=16, Predicted=14.7364, Expected=15.8060
# Month=17, Predicted=15.7984, Expected=16.5270
# Month=18, Predicted=16.5194, Expected=16.5460
# Month=19, Predicted=16.5384, Expected=16.7170
# Month=20, Predicted=16.7094, Expected=16.4330
# Month=21, Predicted=16.4254, Expected=15.7690
# Month=22, Predicted=15.7614, Expected=15.2750
# Month=23, Predicted=15.2674, Expected=15.1230
# Month=24, Predicted=15.1154, Expected=15.5410
# Month=25, Predicted=15.5334, Expected=15.8250
# Month=26, Predicted=15.8174, Expected=16.3760
# Month=27, Predicted=16.3684, Expected=16.3570
# Month=28, Predicted=16.3494, Expected=16.9070
# Month=29, Predicted=16.8994, Expected=17.0210
# Month=30, Predicted=17.0134, Expected=17.4190
# Month=31, Predicted=17.4114, Expected=17.5330
# Month=32, Predicted=17.5254, Expected=17.2680
# Month=33, Predicted=17.2604, Expected=16.6030
# Month=34, Predicted=16.5954, Expected=15.8250
# Month=35, Predicted=15.8174, Expected=15.4460
# Month=36, Predicted=15.4384, Expected=15.6360
# Month=37, Predicted=15.6284, Expected=15.6930
# Month=38, Predicted=15.6854, Expected=16.7550
# Month=39, Predicted=16.7474, Expected=16.5090
# Month=40, Predicted=16.5014, Expected=17.7230
# Month=41, Predicted=17.7154, Expected=18.6910
# Month=42, Predicted=18.6834, Expected=19.1270
# Month=43, Predicted=19.1194, Expected=19.5640
# Month=44, Predicted=19.5564, Expected=19.2030
# Month=45, Predicted=19.1954, Expected=18.2160
# Month=46, Predicted=18.2084, Expected=17.2110
# Month=47, Predicted=17.2034, Expected=16.6600
# Month=48, Predicted=16.6524, Expected=16.8310
# Month=49, Predicted=16.8234, Expected=15.7690
# Month=50, Predicted=15.7614, Expected=15.7310
# Month=51, Predicted=15.7234, Expected=15.9960
# Month=52, Predicted=15.9884, Expected=17.0210
# Month=53, Predicted=17.0134, Expected=17.5520
# Month=54, Predicted=17.5444, Expected=17.8370
# Month=55, Predicted=17.8294, Expected=17.8560
# Month=56, Predicted=17.8484, Expected=17.5710
# Month=57, Predicted=17.5634, Expected=17.0780
# Month=58, Predicted=17.0704, Expected=16.6600
# Month=59, Predicted=16.6524, Expected=16.4330
# Month=60, Predicted=16.4254, Expected=16.5840
# Run 14 — RMSE: 0.561818, MSE: 0.315640, NMSE: 0.0026277893
#
# ===== Attention(lag=30) RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.1011, Expected=13.7000
# Month=2, Predicted=13.6701, Expected=13.8140
# Month=3, Predicted=13.7841, Expected=14.3830
# Month=4, Predicted=14.3531, Expected=15.0470
# Month=5, Predicted=15.0171, Expected=15.6930
# Month=6, Predicted=15.6631, Expected=15.8440
# Month=7, Predicted=15.8141, Expected=15.7120
# Month=8, Predicted=15.6821, Expected=15.3130
# Month=9, Predicted=15.2831, Expected=14.7630
# Month=10, Predicted=14.7331, Expected=13.5480
# Month=11, Predicted=13.5181, Expected=13.5860
# Month=12, Predicted=13.5561, Expected=14.5160
# Month=13, Predicted=14.4861, Expected=14.3830
# Month=14, Predicted=14.3531, Expected=14.4970
# Month=15, Predicted=14.4671, Expected=14.7440
# Month=16, Predicted=14.7141, Expected=15.8060
# Month=17, Predicted=15.7761, Expected=16.5270
# Month=18, Predicted=16.4971, Expected=16.5460
# Month=19, Predicted=16.5161, Expected=16.7170
# Month=20, Predicted=16.6871, Expected=16.4330
# Month=21, Predicted=16.4031, Expected=15.7690
# Month=22, Predicted=15.7391, Expected=15.2750
# Month=23, Predicted=15.2451, Expected=15.1230
# Month=24, Predicted=15.0931, Expected=15.5410
# Month=25, Predicted=15.5111, Expected=15.8250
# Month=26, Predicted=15.7951, Expected=16.3760
# Month=27, Predicted=16.3461, Expected=16.3570
# Month=28, Predicted=16.3271, Expected=16.9070
# Month=29, Predicted=16.8771, Expected=17.0210
# Month=30, Predicted=16.9911, Expected=17.4190
# Month=31, Predicted=17.3891, Expected=17.5330
# Month=32, Predicted=17.5031, Expected=17.2680
# Month=33, Predicted=17.2381, Expected=16.6030
# Month=34, Predicted=16.5731, Expected=15.8250
# Month=35, Predicted=15.7951, Expected=15.4460
# Month=36, Predicted=15.4161, Expected=15.6360
# Month=37, Predicted=15.6061, Expected=15.6930
# Month=38, Predicted=15.6631, Expected=16.7550
# Month=39, Predicted=16.7251, Expected=16.5090
# Month=40, Predicted=16.4791, Expected=17.7230
# Month=41, Predicted=17.6931, Expected=18.6910
# Month=42, Predicted=18.6611, Expected=19.1270
# Month=43, Predicted=19.0971, Expected=19.5640
# Month=44, Predicted=19.5341, Expected=19.2030
# Month=45, Predicted=19.1731, Expected=18.2160
# Month=46, Predicted=18.1861, Expected=17.2110
# Month=47, Predicted=17.1811, Expected=16.6600
# Month=48, Predicted=16.6301, Expected=16.8310
# Month=49, Predicted=16.8011, Expected=15.7690
# Month=50, Predicted=15.7391, Expected=15.7310
# Month=51, Predicted=15.7011, Expected=15.9960
# Month=52, Predicted=15.9661, Expected=17.0210
# Month=53, Predicted=16.9911, Expected=17.5520
# Month=54, Predicted=17.5221, Expected=17.8370
# Month=55, Predicted=17.8071, Expected=17.8560
# Month=56, Predicted=17.8261, Expected=17.5710
# Month=57, Predicted=17.5411, Expected=17.0780
# Month=58, Predicted=17.0481, Expected=16.6600
# Month=59, Predicted=16.6301, Expected=16.4330
# Month=60, Predicted=16.4031, Expected=16.5840
# Run 15 — RMSE: 0.564833, MSE: 0.319036, NMSE: 0.0026515651
#
# ===== Attention(lag=30) RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 16 — RMSE: 0.563208, MSE: 0.317203, NMSE: 0.0026387415
#
# ===== Attention(lag=30) RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.1083, Expected=13.7000
# Month=2, Predicted=13.6773, Expected=13.8140
# Month=3, Predicted=13.7913, Expected=14.3830
# Month=4, Predicted=14.3603, Expected=15.0470
# Month=5, Predicted=15.0243, Expected=15.6930
# Month=6, Predicted=15.6703, Expected=15.8440
# Month=7, Predicted=15.8213, Expected=15.7120
# Month=8, Predicted=15.6893, Expected=15.3130
# Month=9, Predicted=15.2903, Expected=14.7630
# Month=10, Predicted=14.7403, Expected=13.5480
# Month=11, Predicted=13.5253, Expected=13.5860
# Month=12, Predicted=13.5633, Expected=14.5160
# Month=13, Predicted=14.4933, Expected=14.3830
# Month=14, Predicted=14.3603, Expected=14.4970
# Month=15, Predicted=14.4743, Expected=14.7440
# Month=16, Predicted=14.7213, Expected=15.8060
# Month=17, Predicted=15.7833, Expected=16.5270
# Month=18, Predicted=16.5043, Expected=16.5460
# Month=19, Predicted=16.5233, Expected=16.7170
# Month=20, Predicted=16.6943, Expected=16.4330
# Month=21, Predicted=16.4103, Expected=15.7690
# Month=22, Predicted=15.7463, Expected=15.2750
# Month=23, Predicted=15.2523, Expected=15.1230
# Month=24, Predicted=15.1003, Expected=15.5410
# Month=25, Predicted=15.5183, Expected=15.8250
# Month=26, Predicted=15.8023, Expected=16.3760
# Month=27, Predicted=16.3533, Expected=16.3570
# Month=28, Predicted=16.3343, Expected=16.9070
# Month=29, Predicted=16.8843, Expected=17.0210
# Month=30, Predicted=16.9983, Expected=17.4190
# Month=31, Predicted=17.3963, Expected=17.5330
# Month=32, Predicted=17.5103, Expected=17.2680
# Month=33, Predicted=17.2453, Expected=16.6030
# Month=34, Predicted=16.5803, Expected=15.8250
# Month=35, Predicted=15.8023, Expected=15.4460
# Month=36, Predicted=15.4233, Expected=15.6360
# Month=37, Predicted=15.6133, Expected=15.6930
# Month=38, Predicted=15.6703, Expected=16.7550
# Month=39, Predicted=16.7323, Expected=16.5090
# Month=40, Predicted=16.4863, Expected=17.7230
# Month=41, Predicted=17.7003, Expected=18.6910
# ...
# Month=28, Predicted=16.3344, Expected=16.9070
# Month=29, Predicted=16.8844, Expected=17.0210
# Month=30, Predicted=16.9984, Expected=17.4190
# Month=31, Predicted=17.3964, Expected=17.5330
# Month=32, Predicted=17.5104, Expected=17.2680
# Month=33, Predicted=17.2454, Expected=16.6030
# Month=34, Predicted=16.5804, Expected=15.8250
# Month=35, Predicted=15.8024, Expected=15.4460
# Month=36, Predicted=15.4234, Expected=15.6360
# Month=37, Predicted=15.6134, Expected=15.6930
# Month=38, Predicted=15.6704, Expected=16.7550
# Month=39, Predicted=16.7324, Expected=16.5090
# Month=40, Predicted=16.4864, Expected=17.7230
# Month=41, Predicted=17.7004, Expected=18.6910
# Month=42, Predicted=18.6684, Expected=19.1270
# Month=43, Predicted=19.1044, Expected=19.5640
# Month=44, Predicted=19.5414, Expected=19.2030
# Month=45, Predicted=19.1804, Expected=18.2160
# Month=46, Predicted=18.1934, Expected=17.2110
# Month=47, Predicted=17.1884, Expected=16.6600
# Month=48, Predicted=16.6374, Expected=16.8310
# Month=49, Predicted=16.8084, Expected=15.7690
# Month=50, Predicted=15.7464, Expected=15.7310
# Month=51, Predicted=15.7084, Expected=15.9960
# Month=52, Predicted=15.9734, Expected=17.0210
# Month=53, Predicted=16.9984, Expected=17.5520
# Month=54, Predicted=17.5294, Expected=17.8370
# Month=55, Predicted=17.8144, Expected=17.8560
# Month=56, Predicted=17.8334, Expected=17.5710
# Month=57, Predicted=17.5484, Expected=17.0780
# Month=58, Predicted=17.0554, Expected=16.6600
# Month=59, Predicted=16.6374, Expected=16.4330
# Month=60, Predicted=16.4104, Expected=16.5840
# Run 25 — RMSE: 0.563758, MSE: 0.317823, NMSE: 0.0026430782
#
# ===== Attention(lag=30) RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 26 — RMSE: 0.563220, MSE: 0.317216, NMSE: 0.0026388355
#
# ===== Attention(lag=30) RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.1516, Expected=13.7000
# Month=2, Predicted=13.7063, Expected=13.8140
# Month=3, Predicted=13.8130, Expected=14.3830
# Month=4, Predicted=14.3676, Expected=15.0470
# Month=5, Predicted=15.0120, Expected=15.6930
# Month=6, Predicted=15.6383, Expected=15.8440
# Month=7, Predicted=15.7807, Expected=15.7120
# Month=8, Predicted=15.6480, Expected=15.3130
# Month=9, Predicted=15.2577, Expected=14.7630
# Month=10, Predicted=14.7294, Expected=13.5480
# Month=11, Predicted=13.5495, Expected=13.5860
# Month=12, Predicted=13.5942, Expected=14.5160
# Month=13, Predicted=14.5037, Expected=14.3830
# Month=14, Predicted=14.3695, Expected=14.4970
# Month=15, Predicted=14.4782, Expected=14.7440
# Month=16, Predicted=14.7171, Expected=15.8060
# Month=17, Predicted=15.7537, Expected=16.5270
# Month=18, Predicted=16.4476, Expected=16.5460
# Month=19, Predicted=16.4632, Expected=16.7170
# Month=20, Predicted=16.6376, Expected=16.4330
# Month=21, Predicted=16.3670, Expected=15.7690
# Month=22, Predicted=15.7376, Expected=15.2750
# Month=23, Predicted=15.2648, Expected=15.1230
# Month=24, Predicted=15.1233, Expected=15.5410
# Month=25, Predicted=15.5349, Expected=15.8250
# Month=26, Predicted=15.8114, Expected=16.3760
# Month=27, Predicted=16.3488, Expected=16.3570
# Month=28, Predicted=16.3266, Expected=16.9070
# Month=29, Predicted=16.8641, Expected=17.0210
# Month=30, Predicted=16.9721, Expected=17.4190
# Month=31, Predicted=17.3650, Expected=17.5330
# Month=32, Predicted=17.4857, Expected=17.2680
# Month=33, Predicted=17.2293, Expected=16.6030
# Month=34, Predicted=16.5838, Expected=15.8250
# Month=35, Predicted=15.8279, Expected=15.4460
# Month=36, Predicted=15.4641, Expected=15.6360
# Month=37, Predicted=15.6533, Expected=15.6930
# Month=38, Predicted=15.7081, Expected=16.7550
# Month=39, Predicted=16.7432, Expected=16.5090
# Month=40, Predicted=16.4944, Expected=17.7230
# Month=41, Predicted=17.6813, Expected=18.6910
# Month=42, Predicted=18.6091, Expected=19.1270
# Month=43, Predicted=19.0459, Expected=19.5640
# Month=44, Predicted=19.4805, Expected=19.2030
# Month=45, Predicted=19.1258, Expected=18.2160
# Month=46, Predicted=18.1534, Expected=17.2110
# Month=47, Predicted=17.1825, Expected=16.6600
# Month=48, Predicted=16.6483, Expected=16.8310
# Month=49, Predicted=16.8178, Expected=15.7690
# Month=50, Predicted=15.7666, Expected=15.7310
# Month=51, Predicted=15.7262, Expected=15.9960
# Month=52, Predicted=15.9830, Expected=17.0210
# Month=53, Predicted=16.9803, Expected=17.5520
# Month=54, Predicted=17.4933, Expected=17.8370
# Month=55, Predicted=17.7769, Expected=17.8560
# Month=56, Predicted=17.8028, Expected=17.5710
# Month=57, Predicted=17.5303, Expected=17.0780
# Month=58, Predicted=17.0443, Expected=16.6600
# Month=59, Predicted=16.6394, Expected=16.4330
# Month=60, Predicted=16.4179, Expected=16.5840
# Run 27 — RMSE: 0.557670, MSE: 0.310996, NMSE: 0.0026568999
#
# ===== Attention(lag=30) RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.1179, Expected=13.7000
# Month=2, Predicted=13.6869, Expected=13.8140
# Month=3, Predicted=13.8009, Expected=14.3830
# Month=4, Predicted=14.3699, Expected=15.0470
# Month=5, Predicted=15.0339, Expected=15.6930
# Month=6, Predicted=15.6799, Expected=15.8440
# Month=7, Predicted=15.8309, Expected=15.7120
# Month=8, Predicted=15.6989, Expected=15.3130
# Month=9, Predicted=15.2999, Expected=14.7630
# Month=10, Predicted=14.7499, Expected=13.5480
# Month=11, Predicted=13.5349, Expected=13.5860
# Month=12, Predicted=13.5729, Expected=14.5160
# Month=13, Predicted=14.5029, Expected=14.3830
# Month=14, Predicted=14.3699, Expected=14.4970
# Month=15, Predicted=14.4839, Expected=14.7440
# Month=16, Predicted=14.7309, Expected=15.8060
# Month=17, Predicted=15.7929, Expected=16.5270
# Month=18, Predicted=16.5139, Expected=16.5460
# Month=19, Predicted=16.5329, Expected=16.7170
# Month=20, Predicted=16.7039, Expected=16.4330
# Month=21, Predicted=16.4199, Expected=15.7690
# Month=22, Predicted=15.7559, Expected=15.2750
# Month=23, Predicted=15.2619, Expected=15.1230
# Month=24, Predicted=15.1099, Expected=15.5410
# Month=25, Predicted=15.5279, Expected=15.8250
# Month=26, Predicted=15.8119, Expected=16.3760
# Month=27, Predicted=16.3629, Expected=16.3570
# Month=28, Predicted=16.3439, Expected=16.9070
# Month=29, Predicted=16.8939, Expected=17.0210
# Month=30, Predicted=17.0079, Expected=17.4190
# Month=31, Predicted=17.4059, Expected=17.5330
# Month=32, Predicted=17.5199, Expected=17.2680
# Month=33, Predicted=17.2549, Expected=16.6030
# Month=34, Predicted=16.5899, Expected=15.8250
# Month=35, Predicted=15.8119, Expected=15.4460
# Month=36, Predicted=15.4329, Expected=15.6360
# Month=37, Predicted=15.6229, Expected=15.6930
# Month=38, Predicted=15.6799, Expected=16.7550
# Month=39, Predicted=16.7419, Expected=16.5090
# Month=40, Predicted=16.4959, Expected=17.7230
# Month=41, Predicted=17.7099, Expected=18.6910
# Month=42, Predicted=18.6779, Expected=19.1270
# Month=43, Predicted=19.1139, Expected=19.5640
# Month=44, Predicted=19.5509, Expected=19.2030
# Month=45, Predicted=19.1899, Expected=18.2160
# Month=46, Predicted=18.2029, Expected=17.2110
# Month=47, Predicted=17.1979, Expected=16.6600
# Month=48, Predicted=16.6469, Expected=16.8310
# Month=49, Predicted=16.8179, Expected=15.7690
# Month=50, Predicted=15.7559, Expected=15.7310
# Month=51, Predicted=15.7179, Expected=15.9960
# Month=52, Predicted=15.9829, Expected=17.0210
# Month=53, Predicted=17.0079, Expected=17.5520
# Month=54, Predicted=17.5389, Expected=17.8370
# Month=55, Predicted=17.8239, Expected=17.8560
# Month=56, Predicted=17.8429, Expected=17.5710
# Month=57, Predicted=17.5579, Expected=17.0780
# Month=58, Predicted=17.0649, Expected=16.6600
# Month=59, Predicted=16.6469, Expected=16.4330
# Month=60, Predicted=16.4199, Expected=16.5840
# Run 28 — RMSE: 0.562482, MSE: 0.316386, NMSE: 0.0026330187
#
# ===== Attention(lag=30) RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.1179, Expected=13.7000
# Month=2, Predicted=13.6869, Expected=13.8140
# Month=3, Predicted=13.8009, Expected=14.3830
# Month=4, Predicted=14.3699, Expected=15.0470
# Month=5, Predicted=15.0339, Expected=15.6930
# Month=6, Predicted=15.6799, Expected=15.8440
# Month=7, Predicted=15.8309, Expected=15.7120
# Month=8, Predicted=15.6989, Expected=15.3130
# Month=9, Predicted=15.2999, Expected=14.7630
# Month=10, Predicted=14.7499, Expected=13.5480
# Month=11, Predicted=13.5349, Expected=13.5860
# Month=12, Predicted=13.5729, Expected=14.5160
# Month=13, Predicted=14.5029, Expected=14.3830
# Month=14, Predicted=14.3699, Expected=14.4970
# Month=15, Predicted=14.4839, Expected=14.7440
# Month=16, Predicted=14.7309, Expected=15.8060
# Month=17, Predicted=15.7929, Expected=16.5270
# Month=18, Predicted=16.5139, Expected=16.5460
# Month=19, Predicted=16.5329, Expected=16.7170
# Month=20, Predicted=16.7039, Expected=16.4330
# Month=21, Predicted=16.4199, Expected=15.7690
# Month=22, Predicted=15.7559, Expected=15.2750
# Month=23, Predicted=15.2619, Expected=15.1230
# Month=24, Predicted=15.1099, Expected=15.5410
# Month=25, Predicted=15.5279, Expected=15.8250
# Month=26, Predicted=15.8119, Expected=16.3760
# Month=27, Predicted=16.3629, Expected=16.3570
# Month=28, Predicted=16.3439, Expected=16.9070
# Month=29, Predicted=16.8939, Expected=17.0210
# Month=30, Predicted=17.0079, Expected=17.4190
# Month=31, Predicted=17.4059, Expected=17.5330
# Month=32, Predicted=17.5199, Expected=17.2680
# Month=33, Predicted=17.2549, Expected=16.6030
# Month=34, Predicted=16.5899, Expected=15.8250
# Month=35, Predicted=15.8119, Expected=15.4460
# Month=36, Predicted=15.4329, Expected=15.6360
# Month=37, Predicted=15.6229, Expected=15.6930
# Month=38, Predicted=15.6799, Expected=16.7550
# Month=39, Predicted=16.7419, Expected=16.5090
# Month=40, Predicted=16.4959, Expected=17.7230
# Month=41, Predicted=17.7099, Expected=18.6910
# Month=42, Predicted=18.6779, Expected=19.1270
# Month=43, Predicted=19.1139, Expected=19.5640
# Month=44, Predicted=19.5509, Expected=19.2030
# Month=45, Predicted=19.1899, Expected=18.2160
# Month=46, Predicted=18.2029, Expected=17.2110
# Month=47, Predicted=17.1979, Expected=16.6600
# Month=48, Predicted=16.6469, Expected=16.8310
# Month=49, Predicted=16.8179, Expected=15.7690
# Month=50, Predicted=15.7559, Expected=15.7310
# Month=51, Predicted=15.7179, Expected=15.9960
# Month=52, Predicted=15.9829, Expected=17.0210
# Month=53, Predicted=17.0079, Expected=17.5520
# Month=54, Predicted=17.5389, Expected=17.8370
# Month=55, Predicted=17.8239, Expected=17.8560
# Month=56, Predicted=17.8429, Expected=17.5710
# Month=57, Predicted=17.5579, Expected=17.0780
# Month=58, Predicted=17.0649, Expected=16.6600
# Month=59, Predicted=16.6469, Expected=16.4330
# Month=60, Predicted=16.4199, Expected=16.5840
# Run 29 — RMSE: 0.562482, MSE: 0.316386, NMSE: 0.0026330219
#
# ===== Attention(lag=30) RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.1123, Expected=13.7000
# Month=2, Predicted=13.6813, Expected=13.8140
# Month=3, Predicted=13.7953, Expected=14.3830
# Month=4, Predicted=14.3643, Expected=15.0470
# Month=5, Predicted=15.0283, Expected=15.6930
# Month=6, Predicted=15.6743, Expected=15.8440
# Month=7, Predicted=15.8253, Expected=15.7120
# Month=8, Predicted=15.6933, Expected=15.3130
# Month=9, Predicted=15.2943, Expected=14.7630
# Month=10, Predicted=14.7443, Expected=13.5480
# Month=11, Predicted=13.5293, Expected=13.5860
# Month=12, Predicted=13.5673, Expected=14.5160
# Month=13, Predicted=14.4973, Expected=14.3830
# Month=14, Predicted=14.3643, Expected=14.4970
# Month=15, Predicted=14.4783, Expected=14.7440
# Month=16, Predicted=14.7253, Expected=15.8060
# Month=17, Predicted=15.7873, Expected=16.5270
# Month=18, Predicted=16.5083, Expected=16.5460
# Month=19, Predicted=16.5273, Expected=16.7170
# Month=20, Predicted=16.6983, Expected=16.4330
# Month=21, Predicted=16.4143, Expected=15.7690
# Month=22, Predicted=15.7503, Expected=15.2750
# Month=23, Predicted=15.2563, Expected=15.1230
# Month=24, Predicted=15.1043, Expected=15.5410
# Month=25, Predicted=15.5223, Expected=15.8250
# Month=26, Predicted=15.8063, Expected=16.3760
# Month=27, Predicted=16.3573, Expected=16.3570
# Month=28, Predicted=16.3383, Expected=16.9070
# Month=29, Predicted=16.8883, Expected=17.0210
# Month=30, Predicted=17.0023, Expected=17.4190
# Month=31, Predicted=17.4003, Expected=17.5330
# Month=32, Predicted=17.5143, Expected=17.2680
# Month=33, Predicted=17.2493, Expected=16.6030
# Month=34, Predicted=16.5843, Expected=15.8250
# Month=35, Predicted=15.8063, Expected=15.4460
# Month=36, Predicted=15.4273, Expected=15.6360
# Month=37, Predicted=15.6173, Expected=15.6930
# Month=38, Predicted=15.6743, Expected=16.7550
# Month=39, Predicted=16.7363, Expected=16.5090
# Month=40, Predicted=16.4903, Expected=17.7230
# Month=41, Predicted=17.7043, Expected=18.6910
# Month=42, Predicted=18.6723, Expected=19.1270
# Month=43, Predicted=19.1083, Expected=19.5640
# Month=44, Predicted=19.5453, Expected=19.2030
# Month=45, Predicted=19.1843, Expected=18.2160
# Month=46, Predicted=18.1973, Expected=17.2110
# Month=47, Predicted=17.1923, Expected=16.6600
# Month=48, Predicted=16.6413, Expected=16.8310
# Month=49, Predicted=16.8123, Expected=15.7690
# Month=50, Predicted=15.7503, Expected=15.7310
# Month=51, Predicted=15.7123, Expected=15.9960
# Month=52, Predicted=15.9773, Expected=17.0210
# Month=53, Predicted=17.0023, Expected=17.5520
# Month=54, Predicted=17.5333, Expected=17.8370
# Month=55, Predicted=17.8183, Expected=17.8560
# Month=56, Predicted=17.8373, Expected=17.5710
# Month=57, Predicted=17.5523, Expected=17.0780
# Month=58, Predicted=17.0593, Expected=16.6600
# Month=59, Predicted=16.6413, Expected=16.4330
# Month=60, Predicted=16.4143, Expected=16.5840
# Run 30 — RMSE: 0.563208, MSE: 0.317203, NMSE: 0.0026387425

# %%
# ============================================================
# Attention (lag=30) Summary Statistics
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=30) FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(att30_all_rmse):.10f} ± {np.var(att30_all_rmse):.15f}')
print(f'MSE:  {np.mean(att30_all_mse):.10f} ± {np.var(att30_all_mse):.15f}')
print(f'NMSE: {np.mean(att30_all_nmse):.10f} ± {np.var(att30_all_nmse):.15f}')

best_att30_idx = att30_all_rmse.index(min(att30_all_rmse))
print(f'\nBest run: {best_att30_idx+1}')
print(f'  RMSE: {att30_all_rmse[best_att30_idx]:.15f}')
print(f'  MSE:  {att30_all_mse[best_att30_idx]:.15f}')
print(f'  NMSE: {att30_all_nmse[best_att30_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att30_preds = att30_all_predictions[best_att30_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att30_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=30) — Best Run')
plt.show()
# Out:
# ===== LSTM-SNP + Attention (lag=30) FINAL RESULTS (30 runs) =====
# RMSE: 0.5670166182 ± 0.000638473592496
# MSE:  0.3221463189 ± 0.001020626693217
# NMSE: 0.0026847231 ± 0.000000041629362
#
# Best run: 1
#   RMSE: 0.556474433962528
#   MSE:  0.309663795653916
#   NMSE: 0.002601754385231

# %%
# ============================================================
# FINAL COMPREHENSIVE SUMMARY — ALL MODELS
# Average ± Std Dev over 30 runs for RMSE, MSE, NMSE
# ============================================================

models = {
    'LSTM-SNP (Baseline, lag=1)': (all_rmse, all_mse, all_nmse),
    'BiLSTM-SNP (lag=1)': (bi_all_rmse, bi_all_mse, bi_all_nmse),
    'Attention (lag=1, degenerate)': (att1_all_rmse, att1_all_mse, att1_all_nmse),
    'Attention (lag=5)': (att5_all_rmse, att5_all_mse, att5_all_nmse),
    'Attention (lag=10)': (att10_all_rmse, att10_all_mse, att10_all_nmse),
    'Attention (lag=20)': (att20_all_rmse, att20_all_mse, att20_all_nmse),
    'Attention (lag=30)': (att30_all_rmse, att30_all_mse, att30_all_nmse),
}

print('=' * 110)
print('COMPREHENSIVE RESULTS — All Models (30 runs each)')
print('=' * 110)
print(f"{'Model':<35} {'Avg RMSE':>12} {'± Std':>12} {'Avg MSE':>14} {'± Std':>14} {'Avg NMSE':>16} {'± Std':>16}")
print('-' * 110)

for name, (rmse_list, mse_list, nmse_list) in models.items():
    print(
        f"{name:<35} "
        f"{np.mean(rmse_list):>12.6f} {np.std(rmse_list):>12.6f} "
        f"{np.mean(mse_list):>14.6f} {np.std(mse_list):>14.6f} "
        f"{np.mean(nmse_list):>16.10f} {np.std(nmse_list):>16.10f}"
    )

print('=' * 110)
# Out:
# ==============================================================================================================
# COMPREHENSIVE RESULTS — All Models (30 runs each)
# ==============================================================================================================
# Model                                   Avg RMSE        ± Std        Avg MSE          ± Std         Avg NMSE            ± Std
# --------------------------------------------------------------------------------------------------------------
# LSTM-SNP (Baseline, lag=1)              0.492532     0.003777       0.242602       0.003706     0.0019384141     0.0000170685
# BiLSTM-SNP (lag=1)                      0.490504     0.004868       0.240618       0.004747     0.0019359713     0.0000242425
# Attention (lag=1, degenerate)           0.492954     0.003615       0.243017       0.003554     0.0019412734     0.0000192215
# Attention (lag=5)                       0.563491     0.002273       0.317528       0.002585     0.0026420389     0.0000219114
# Attention (lag=10)                      0.567761     0.018669       0.322701       0.022759     0.0026754268     0.0001508104
# Attention (lag=20)                      0.561617     0.006359       0.315454       0.006945     0.0026394897     0.0000295067
# Attention (lag=30)                      0.567017     0.025268       0.322146       0.031947     0.0026847231     0.0002040327
# ==============================================================================================================
