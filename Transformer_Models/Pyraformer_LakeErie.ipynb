# %% [markdown]
# # Pyraformer — Monthly Lake Erie Levels
#
# **Model**: Pyramidal Attention for Time Series
# **Reference**: Liu et al., 2022 — Pyraformer: Low-Complexity Pyramidal Attention for Long-Range Time Series Modeling and Forecasting
#
# ## Description
# This notebook implements the **Pyraformer** Transformer architecture for univariate time-series
# forecasting on the Monthly Lake Erie Levels dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %% [markdown]
# ## Theory: Pyraformer Architecture
#
# ### Pyramidal Attention
# Pyraformer builds a **multi-resolution temporal hierarchy**:
#
# **Level 0 (finest)**: Original sequence tokens
# **Level 1**: Downsampled by factor 2
# **Level $k$**: Downsampled by factor $2^k$
#
# ### CSCM (Coarser-Scale Construction Module)
# Builds the pyramid using 1D convolutions with stride 2:
# $$X^{(k+1)} = \text{Conv1D}(X^{(k)}, \text{stride}=2)$$
#
# ### PAM (Pyramidal Attention Module)
# Two types of attention connections:
#
# 1. **Intra-scale**: Self-attention within each resolution level
# 2. **Inter-scale**: Cross-attention from finer to coarser scales
#
# The finest level queries attend to coarser-level summaries, capturing both local detail and global context.
#
# ### Complexity
# The pyramidal structure reduces attention complexity from $O(L^2)$ to $O(L)$ by limiting attention to $O(1)$ connections per node across scales.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import random
import time

print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Device Selection
# ============================================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f} GB")
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Pyraformer Model Definition

# %%
# ============================================================
# Pyraformer: Pyramidal Attention for Time Series
# Reference: Liu et al., 2022
#
# Key ideas:
# 1. Pyramidal attention: multi-resolution temporal hierarchy
# 2. Coarser-scale nodes summarize finer-scale patterns
# 3. Inter-scale and intra-scale attention connections
# 4. Reduces complexity from O(L^2) to O(L)
#
# For our setup, we build a simplified pyramid with CSCM
# (Coarser-Scale Construction Module) and PAM
# (Pyramidal Attention Module).
# ============================================================

class CoarserScaleConstruction(nn.Module):
    """
    CSCM: Coarser-Scale Construction Module.
    Builds pyramid by progressively downsampling the sequence.
    Uses 1D convolutions with stride=2 for downsampling.
    """
    def __init__(self, d_model, n_scales=2):
        super().__init__()
        self.n_scales = n_scales
        self.downsample_layers = nn.ModuleList([
            nn.Sequential(
                nn.Conv1d(d_model, d_model, kernel_size=3, stride=2, padding=1),
                nn.GELU(),
            )
            for _ in range(n_scales)
        ])

    def forward(self, x):
        """
        x: (B, L, D)
        Returns list of tensors at different scales.
        """
        scales = [x]
        current = x.transpose(1, 2)  # (B, D, L)
        for layer in self.downsample_layers:
            current = layer(current)
            scales.append(current.transpose(1, 2))
        return scales


class PyramidAttentionLayer(nn.Module):
    """
    Pyramidal Attention: applies attention within and across scales.
    - Intra-scale: standard self-attention within each resolution
    - Inter-scale: attention from finer to coarser scale
    """
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        # Intra-scale attention
        self.self_attn = nn.MultiheadAttention(d_model, n_heads,
                                                dropout=dropout,
                                                batch_first=True)
        # Inter-scale attention (cross-attention from fine to coarse)
        self.cross_attn = nn.MultiheadAttention(d_model, n_heads,
                                                 dropout=dropout,
                                                 batch_first=True)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x_fine, x_coarse=None):
        # Intra-scale self-attention
        attn_out, _ = self.self_attn(x_fine, x_fine, x_fine)
        x = self.norm1(x_fine + self.dropout(attn_out))

        # Inter-scale cross-attention (if coarse scale available)
        if x_coarse is not None:
            cross_out, _ = self.cross_attn(x, x_coarse, x_coarse)
            x = self.norm2(x + self.dropout(cross_out))

        # Feed-forward
        ff_out = self.ff(x)
        x = self.norm3(x + ff_out)
        return x


class PyraformerModel(nn.Module):
    """
    Pyraformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, n_scales=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)

        # CSCM: build multi-scale pyramid
        self.cscm = CoarserScaleConstruction(d_model, n_scales)

        # Pyramidal attention layers (one per scale at finest level)
        self.pyramid_layers = nn.ModuleList([
            PyramidAttentionLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])

        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        # Build pyramid
        scales = self.cscm(x)  # List of tensors at different resolutions

        # Apply pyramidal attention at finest scale with coarser context
        finest = scales[0]
        for i, layer in enumerate(self.pyramid_layers):
            # Use next coarser scale as context (if available)
            coarse_idx = min(i + 1, len(scales) - 1)
            coarse = scales[coarse_idx]
            finest = layer(finest, coarse)

        x = finest[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = PyraformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 35169
# Trainable parameters: 35169
# Memory estimate: 137.4 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '/Users/satabarto/Research/content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (539, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (539, 1, 1), y_train shape: (539,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = PyraformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.3200, Expected=13.7000
# Month=2, Predicted=14.0447, Expected=13.8140
# Month=3, Predicted=13.9909, Expected=14.3830
# Month=4, Predicted=14.7277, Expected=15.0470
# Month=5, Predicted=15.4222, Expected=15.6930
# Month=6, Predicted=16.0587, Expected=15.8440
# Month=7, Predicted=16.0429, Expected=15.7120
# Month=8, Predicted=15.5346, Expected=15.3130
# Month=9, Predicted=14.9400, Expected=14.7630
# Month=10, Predicted=14.3406, Expected=13.5480
# Month=11, Predicted=13.0478, Expected=13.5860
# Month=12, Predicted=13.6926, Expected=14.5160
# Month=13, Predicted=15.2432, Expected=14.3830
# Month=14, Predicted=14.2040, Expected=14.4970
# Month=15, Predicted=14.6739, Expected=14.7440
# Month=16, Predicted=14.9928, Expected=15.8060
# Month=17, Predicted=16.5558, Expected=16.5270
# Month=18, Predicted=16.9528, Expected=16.5460
# Month=19, Predicted=16.6283, Expected=16.7170
# Month=20, Predicted=16.9258, Expected=16.4330
# Month=21, Predicted=16.1140, Expected=15.7690
# Month=22, Predicted=15.3221, Expected=15.2750
# Month=23, Predicted=14.8683, Expected=15.1230
# Month=24, Predicted=14.9160, Expected=15.5410
# Month=25, Predicted=15.8753, Expected=15.8250
# Month=26, Predicted=16.1093, Expected=16.3760
# Month=27, Predicted=16.7186, Expected=16.3570
# Month=28, Predicted=16.3816, Expected=16.9070
# Month=29, Predicted=17.2495, Expected=17.0210
# Month=30, Predicted=17.1979, Expected=17.4190
# Month=31, Predicted=17.7513, Expected=17.5330
# Month=32, Predicted=17.7099, Expected=17.2680
# Month=33, Predicted=16.9596, Expected=16.6030
# Month=34, Predicted=16.1559, Expected=15.8250
# Month=35, Predicted=15.3605, Expected=15.4460
# Month=36, Predicted=15.0813, Expected=15.6360
# Month=37, Predicted=15.8535, Expected=15.6930
# Month=38, Predicted=15.8211, Expected=16.7550
# Month=39, Predicted=17.5048, Expected=16.5090
# Month=40, Predicted=16.2122, Expected=17.7230
# Month=41, Predicted=18.4846, Expected=18.6910
# Month=42, Predicted=19.4270, Expected=19.1270
# Month=43, Predicted=19.4626, Expected=19.5640
# Month=44, Predicted=19.8997, Expected=19.2030
# Month=45, Predicted=18.8462, Expected=18.2160
# Month=46, Predicted=17.7301, Expected=17.2110
# Month=47, Predicted=16.7237, Expected=16.6600
# Month=48, Predicted=16.2373, Expected=16.8310
# Month=49, Predicted=17.0398, Expected=15.7690
# Month=50, Predicted=15.2777, Expected=15.7310
# Month=51, Predicted=15.7228, Expected=15.9960
# Month=52, Predicted=16.2596, Expected=17.0210
# Month=53, Predicted=17.7663, Expected=17.5520
# Month=54, Predicted=17.8929, Expected=17.8370
# Month=55, Predicted=18.1225, Expected=17.8560
# Month=56, Predicted=17.9383, Expected=17.5710
# Month=57, Predicted=17.2514, Expected=17.0780
# Month=58, Predicted=16.6716, Expected=16.6600
# Month=59, Predicted=16.2794, Expected=16.4330
# Month=60, Predicted=16.1492, Expected=16.5840
# Run 1 — RMSE: 0.500281, MSE: 0.250282, NMSE: 0.0018838255, Time: 207.5s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2399, Expected=13.7000
# Month=2, Predicted=13.9939, Expected=13.8140
# Month=3, Predicted=13.8999, Expected=14.3830
# Month=4, Predicted=14.6769, Expected=15.0470
# Month=5, Predicted=15.3833, Expected=15.6930
# Month=6, Predicted=16.0157, Expected=15.8440
# Month=7, Predicted=15.9749, Expected=15.7120
# Month=8, Predicted=15.5377, Expected=15.3130
# Month=9, Predicted=14.9481, Expected=14.7630
# Month=10, Predicted=14.3299, Expected=13.5480
# Month=11, Predicted=13.0054, Expected=13.5860
# Month=12, Predicted=13.5835, Expected=14.5160
# Month=13, Predicted=15.1740, Expected=14.3830
# Month=14, Predicted=14.2078, Expected=14.4970
# Month=15, Predicted=14.5829, Expected=14.7440
# Month=16, Predicted=14.9761, Expected=15.8060
# Month=17, Predicted=16.5056, Expected=16.5270
# Month=18, Predicted=16.9393, Expected=16.5460
# Month=19, Predicted=16.5225, Expected=16.7170
# Month=20, Predicted=16.8722, Expected=16.4330
# Month=21, Predicted=16.1380, Expected=15.7690
# Month=22, Predicted=15.3000, Expected=15.2750
# Month=23, Predicted=14.8643, Expected=15.1230
# Month=24, Predicted=14.9309, Expected=15.5410
# Month=25, Predicted=15.8222, Expected=15.8250
# Month=26, Predicted=16.0797, Expected=16.3760
# Month=27, Predicted=16.6668, Expected=16.3570
# Month=28, Predicted=16.2929, Expected=16.9070
# Month=29, Predicted=17.1976, Expected=17.0210
# Month=30, Predicted=17.1069, Expected=17.4190
# Month=31, Predicted=17.6989, Expected=17.5330
# Month=32, Predicted=17.6189, Expected=17.2680
# Month=33, Predicted=16.9863, Expected=16.6030
# Month=34, Predicted=16.1337, Expected=15.8250
# Month=35, Predicted=15.3304, Expected=15.4460
# Month=36, Predicted=15.0920, Expected=15.6360
# Month=37, Predicted=15.8134, Expected=15.6930
# Month=38, Predicted=15.7120, Expected=16.7550
# Month=39, Predicted=17.4546, Expected=16.5090
# Month=40, Predicted=16.2411, Expected=17.7230
# Month=41, Predicted=18.4445, Expected=18.6910
# Month=42, Predicted=19.3644, Expected=19.1270
# Month=43, Predicted=19.4091, Expected=19.5640
# Month=44, Predicted=19.8462, Expected=19.2030
# Month=45, Predicted=18.8593, Expected=18.2160
# Month=46, Predicted=17.6918, Expected=17.2110
# Month=47, Predicted=16.6849, Expected=16.6600
# Month=48, Predicted=16.2266, Expected=16.8310
# Month=49, Predicted=16.9862, Expected=15.7690
# Month=50, Predicted=15.2376, Expected=15.7310
# Month=51, Predicted=15.6474, Expected=15.9960
# Month=52, Predicted=16.2404, Expected=17.0210
# Month=53, Predicted=17.7121, Expected=17.5520
# Month=54, Predicted=17.8402, Expected=17.8370
# Month=55, Predicted=18.0921, Expected=17.8560
# Month=56, Predicted=17.8325, Expected=17.5710
# Month=57, Predicted=17.2753, Expected=17.0780
# Month=58, Predicted=16.6677, Expected=16.6600
# Month=59, Predicted=16.2851, Expected=16.4330
# Month=60, Predicted=16.1794, Expected=16.5840
# Run 2 — RMSE: 0.501295, MSE: 0.251297, NMSE: 0.0018920946, Time: 237.3s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2663, Expected=13.7000
# Month=2, Predicted=14.0878, Expected=13.8140
# Month=3, Predicted=13.9200, Expected=14.3830
# Month=4, Predicted=14.7708, Expected=15.0470
# Month=5, Predicted=15.4909, Expected=15.6930
# Month=6, Predicted=16.1249, Expected=15.8440
# Month=7, Predicted=16.0076, Expected=15.7120
# Month=8, Predicted=15.5351, Expected=15.3130
# Month=9, Predicted=14.9358, Expected=14.7630
# Month=10, Predicted=14.3284, Expected=13.5480
# Month=11, Predicted=13.0291, Expected=13.5860
# Month=12, Predicted=13.5907, Expected=14.5160
# Month=13, Predicted=15.1821, Expected=14.3830
# Month=14, Predicted=14.2051, Expected=14.4970
# Month=15, Predicted=14.6030, Expected=14.7440
# Month=16, Predicted=15.0213, Expected=15.8060
# Month=17, Predicted=16.5679, Expected=16.5270
# Month=18, Predicted=17.0133, Expected=16.5460
# Month=19, Predicted=16.5288, Expected=16.7170
# Month=20, Predicted=16.9113, Expected=16.4330
# Month=21, Predicted=16.1232, Expected=15.7690
# Month=22, Predicted=15.3059, Expected=15.2750
# Month=23, Predicted=14.8586, Expected=15.1230
# Month=24, Predicted=14.9263, Expected=15.5410
# Month=25, Predicted=15.8734, Expected=15.8250
# Month=26, Predicted=16.1216, Expected=16.3760
# Month=27, Predicted=16.7553, Expected=16.3570
# Month=28, Predicted=16.2979, Expected=16.9070
# Month=29, Predicted=17.2858, Expected=17.0210
# Month=30, Predicted=17.1270, Expected=17.4190
# Month=31, Predicted=17.7462, Expected=17.5330
# Month=32, Predicted=17.6390, Expected=17.2680
# Month=33, Predicted=16.9721, Expected=16.6030
# Month=34, Predicted=16.1397, Expected=15.8250
# Month=35, Predicted=15.3419, Expected=15.4460
# Month=36, Predicted=15.0787, Expected=15.6360
# Month=37, Predicted=15.8570, Expected=15.6930
# Month=38, Predicted=15.7207, Expected=16.7550
# Month=39, Predicted=17.5169, Expected=16.5090
# Month=40, Predicted=16.2278, Expected=17.7230
# Month=41, Predicted=18.5643, Expected=18.6910
# Month=42, Predicted=19.3873, Expected=19.1270
# Month=43, Predicted=19.4643, Expected=19.5640
# Month=44, Predicted=19.9016, Expected=19.2030
# Month=45, Predicted=18.8452, Expected=18.2160
# Month=46, Predicted=17.7103, Expected=17.2110
# Month=47, Predicted=16.7040, Expected=16.6600
# Month=48, Predicted=16.2252, Expected=16.8310
# Month=49, Predicted=17.0253, Expected=15.7690
# Month=50, Predicted=15.2580, Expected=15.7310
# Month=51, Predicted=15.6515, Expected=15.9960
# Month=52, Predicted=16.2840, Expected=17.0210
# Month=53, Predicted=17.7586, Expected=17.5520
# Month=54, Predicted=17.9224, Expected=17.8370
# Month=55, Predicted=18.1340, Expected=17.8560
# Month=56, Predicted=17.8388, Expected=17.5710
# Month=57, Predicted=17.2605, Expected=17.0780
# Month=58, Predicted=16.6620, Expected=16.6600
# Month=59, Predicted=16.2740, Expected=16.4330
# Month=60, Predicted=16.1674, Expected=16.5840
# Run 3 — RMSE: 0.506031, MSE: 0.256068, NMSE: 0.0019110659, Time: 262.5s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2501, Expected=13.7000
# Month=2, Predicted=13.9992, Expected=13.8140
# Month=3, Predicted=13.8926, Expected=14.3830
# Month=4, Predicted=14.6822, Expected=15.0470
# Month=5, Predicted=15.4230, Expected=15.6930
# Month=6, Predicted=16.0470, Expected=15.8440
# Month=7, Predicted=16.0020, Expected=15.7120
# Month=8, Predicted=15.5194, Expected=15.3130
# Month=9, Predicted=14.9183, Expected=14.7630
# Month=10, Predicted=14.3009, Expected=13.5480
# Month=11, Predicted=12.9871, Expected=13.5860
# Month=12, Predicted=13.5607, Expected=14.5160
# Month=13, Predicted=15.2353, Expected=14.3830
# Month=14, Predicted=14.1895, Expected=14.4970
# Month=15, Predicted=14.5756, Expected=14.7440
# Month=16, Predicted=14.9914, Expected=15.8060
# Month=17, Predicted=16.5588, Expected=16.5270
# Month=18, Predicted=17.0144, Expected=16.5460
# Month=19, Predicted=16.5006, Expected=16.7170
# Month=20, Predicted=16.9104, Expected=16.4330
# Month=21, Predicted=16.1136, Expected=15.7690
# Month=22, Predicted=15.2747, Expected=15.2750
# Month=23, Predicted=14.8340, Expected=15.1230
# Month=24, Predicted=14.9122, Expected=15.5410
# Month=25, Predicted=15.8078, Expected=15.8250
# Month=26, Predicted=16.0799, Expected=16.3760
# Month=27, Predicted=16.6680, Expected=16.3570
# Month=28, Predicted=16.2726, Expected=16.9070
# Month=29, Predicted=17.1986, Expected=17.0210
# Month=30, Predicted=17.0996, Expected=17.4190
# Month=31, Predicted=17.6841, Expected=17.5330
# Month=32, Predicted=17.6116, Expected=17.2680
# Month=33, Predicted=16.9628, Expected=16.6030
# Month=34, Predicted=16.1084, Expected=15.8250
# Month=35, Predicted=15.3081, Expected=15.4460
# Month=36, Predicted=15.0629, Expected=15.6360
# Month=37, Predicted=15.8525, Expected=15.6930
# Month=38, Predicted=15.6887, Expected=16.7550
# Month=39, Predicted=17.5078, Expected=16.5090
# Month=40, Predicted=16.2185, Expected=17.7230
# Month=41, Predicted=18.4919, Expected=18.6910
# Month=42, Predicted=19.4232, Expected=19.1270
# Month=43, Predicted=19.3955, Expected=19.5640
# Month=44, Predicted=19.8326, Expected=19.2030
# Month=45, Predicted=18.8309, Expected=18.2160
# Month=46, Predicted=17.6724, Expected=17.2110
# Month=47, Predicted=16.6657, Expected=16.6600
# Month=48, Predicted=16.1976, Expected=16.8310
# Month=49, Predicted=17.0244, Expected=15.7690
# Month=50, Predicted=15.2187, Expected=15.7310
# Month=51, Predicted=15.6276, Expected=15.9960
# Month=52, Predicted=16.2476, Expected=17.0210
# Month=53, Predicted=17.7672, Expected=17.5520
# Month=54, Predicted=17.8375, Expected=17.8370
# Month=55, Predicted=18.0921, Expected=17.8560
# Month=56, Predicted=17.8106, Expected=17.5710
# Month=57, Predicted=17.2508, Expected=17.0780
# Month=58, Predicted=16.6374, Expected=16.6600
# Month=59, Predicted=16.2548, Expected=16.4330
# Month=60, Predicted=16.1577, Expected=16.5840
# Run 4 — RMSE: 0.511228, MSE: 0.261354, NMSE: 0.0019522767, Time: 255.0s
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2519, Expected=13.7000
# Month=2, Predicted=14.0471, Expected=13.8140
# Month=3, Predicted=13.9079, Expected=14.3830
# Month=4, Predicted=14.7301, Expected=15.0470
# Month=5, Predicted=15.4651, Expected=15.6930
# Month=6, Predicted=16.0923, Expected=15.8440
# Month=7, Predicted=15.9899, Expected=15.7120
# Month=8, Predicted=15.5242, Expected=15.3130
# Month=9, Predicted=14.9553, Expected=14.7630
# Month=10, Predicted=14.3368, Expected=13.5480
# Month=11, Predicted=12.9619, Expected=13.5860
# Month=12, Predicted=13.5750, Expected=14.5160
# Month=13, Predicted=15.1940, Expected=14.3830
# Month=14, Predicted=14.1944, Expected=14.4970
# Month=15, Predicted=14.5909, Expected=14.7440
# Month=16, Predicted=14.9935, Expected=15.8060
# Month=17, Predicted=16.5245, Expected=16.5270
# Month=18, Predicted=17.0192, Expected=16.5460
# Month=19, Predicted=16.5108, Expected=16.7170
# Month=20, Predicted=16.8894, Expected=16.4330
# Month=21, Predicted=16.1393, Expected=15.7690
# Month=22, Predicted=15.3010, Expected=15.2750
# Month=23, Predicted=14.8724, Expected=15.1230
# Month=24, Predicted=14.9194, Expected=15.5410
# Month=25, Predicted=15.8483, Expected=15.8250
# Month=26, Predicted=16.0965, Expected=16.3760
# Month=27, Predicted=16.7156, Expected=16.3570
# Month=28, Predicted=16.2769, Expected=16.9070
# Month=29, Predicted=17.2462, Expected=17.0210
# Month=30, Predicted=17.1149, Expected=17.4190
# Month=31, Predicted=17.7229, Expected=17.5330
# Month=32, Predicted=17.6269, Expected=17.2680
# Month=33, Predicted=16.9860, Expected=16.6030
# Month=34, Predicted=16.1347, Expected=15.8250
# Month=35, Predicted=15.3226, Expected=15.4460
# Month=36, Predicted=15.0987, Expected=15.6360
# Month=37, Predicted=15.8317, Expected=15.6930
# Month=38, Predicted=15.7072, Expected=16.7550
# Month=39, Predicted=17.4735, Expected=16.5090
# Month=40, Predicted=16.2390, Expected=17.7230
# Month=41, Predicted=18.4659, Expected=18.6910
# Month=42, Predicted=19.3837, Expected=19.1270
# Month=43, Predicted=19.4374, Expected=19.5640
# Month=44, Predicted=19.8745, Expected=19.2030
# Month=45, Predicted=18.8652, Expected=18.2160
# Month=46, Predicted=17.6657, Expected=17.2110
# Month=47, Predicted=16.6574, Expected=16.6600
# Month=48, Predicted=16.2334, Expected=16.8310
# Month=49, Predicted=17.0034, Expected=15.7690
# Month=50, Predicted=15.2054, Expected=15.7310
# Month=51, Predicted=15.6302, Expected=15.9960
# Month=52, Predicted=16.2573, Expected=17.0210
# Month=53, Predicted=17.7308, Expected=17.5520
# Month=54, Predicted=17.8844, Expected=17.8370
# Month=55, Predicted=18.1090, Expected=17.8560
# Month=56, Predicted=17.8208, Expected=17.5710
# Month=57, Predicted=17.2766, Expected=17.0780
# Month=58, Predicted=16.6758, Expected=16.6600
# Month=59, Predicted=16.2928, Expected=16.4330
# Month=60, Predicted=16.1755, Expected=16.5840
# Run 5 — RMSE: 0.507059, MSE: 0.257108, NMSE: 0.0019240128, Time: 273.3s
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2735, Expected=13.7000
# Month=2, Predicted=14.1011, Expected=13.8140
# Month=3, Predicted=13.9375, Expected=14.3830
# Month=4, Predicted=14.7841, Expected=15.0470
# Month=5, Predicted=15.5176, Expected=15.6930
# Month=6, Predicted=16.1498, Expected=15.8440
# Month=7, Predicted=16.0030, Expected=15.7120
# Month=8, Predicted=15.5057, Expected=15.3130
# Month=9, Predicted=14.9499, Expected=14.7630
# Month=10, Predicted=14.3291, Expected=13.5480
# Month=11, Predicted=12.9827, Expected=13.5860
# Month=12, Predicted=13.6145, Expected=14.5160
# Month=13, Predicted=15.1754, Expected=14.3830
# Month=14, Predicted=14.1756, Expected=14.4970
# Month=15, Predicted=14.6205, Expected=14.7440
# Month=16, Predicted=14.9719, Expected=15.8060
# Month=17, Predicted=16.5277, Expected=16.5270
# Month=18, Predicted=17.0421, Expected=16.5460
# Month=19, Predicted=16.5467, Expected=16.7170
# Month=20, Predicted=16.8927, Expected=16.4330
# Month=21, Predicted=16.1167, Expected=15.7690
# Month=22, Predicted=15.2923, Expected=15.2750
# Month=23, Predicted=14.8671, Expected=15.1230
# Month=24, Predicted=14.8966, Expected=15.5410
# Month=25, Predicted=15.8559, Expected=15.8250
# Month=26, Predicted=16.0738, Expected=16.3760
# Month=27, Predicted=16.7652, Expected=16.3570
# Month=28, Predicted=16.3000, Expected=16.9070
# Month=29, Predicted=17.2955, Expected=17.0210
# Month=30, Predicted=17.1445, Expected=17.4190
# Month=31, Predicted=17.7242, Expected=17.5330
# Month=32, Predicted=17.6565, Expected=17.2680
# Month=33, Predicted=16.9609, Expected=16.6030
# Month=34, Predicted=16.1260, Expected=15.8250
# Month=35, Predicted=15.3183, Expected=15.4460
# Month=36, Predicted=15.0913, Expected=15.6360
# Month=37, Predicted=15.8263, Expected=15.6930
# Month=38, Predicted=15.7480, Expected=16.7550
# Month=39, Predicted=17.4767, Expected=16.5090
# Month=40, Predicted=16.2121, Expected=17.7230
# Month=41, Predicted=18.4936, Expected=18.6910
# Month=42, Predicted=19.3707, Expected=19.1270
# Month=43, Predicted=19.4508, Expected=19.5640
# Month=44, Predicted=19.8883, Expected=19.2030
# Month=45, Predicted=18.8555, Expected=18.2160
# Month=46, Predicted=17.6739, Expected=17.2110
# Month=47, Predicted=16.6666, Expected=16.6600
# Month=48, Predicted=16.2256, Expected=16.8310
# Month=49, Predicted=17.0067, Expected=15.7690
# Month=50, Predicted=15.2179, Expected=15.7310
# Month=51, Predicted=15.6454, Expected=15.9960
# Month=52, Predicted=16.2344, Expected=17.0210
# Month=53, Predicted=17.7274, Expected=17.5520
# Month=54, Predicted=17.9285, Expected=17.8370
# Month=55, Predicted=18.0864, Expected=17.8560
# Month=56, Predicted=17.8567, Expected=17.5710
# Month=57, Predicted=17.2543, Expected=17.0780
# Month=58, Predicted=16.6706, Expected=16.6600
# Month=59, Predicted=16.2885, Expected=16.4330
# Month=60, Predicted=16.1475, Expected=16.5840
# Run 6 — RMSE: 0.506664, MSE: 0.256708, NMSE: 0.0019249825, Time: 234.5s
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.2058, Expected=13.7000
# Month=2, Predicted=14.0629, Expected=13.8140
# Month=3, Predicted=13.8660, Expected=14.3830
# Month=4, Predicted=14.7459, Expected=15.0470
# Month=5, Predicted=15.4894, Expected=15.6930
# Month=6, Predicted=16.1198, Expected=15.8440
# Month=7, Predicted=15.9398, Expected=15.7120
# Month=8, Predicted=15.5122, Expected=15.3130
# Month=9, Predicted=14.9404, Expected=14.7630
# Month=10, Predicted=14.3136, Expected=13.5480
# Month=11, Predicted=12.9564, Expected=13.5860
# Month=12, Predicted=13.5476, Expected=14.5160
# Month=13, Predicted=15.1544, Expected=14.3830
# Month=14, Predicted=14.1824, Expected=14.4970
# Month=15, Predicted=14.5490, Expected=14.7440
# Month=16, Predicted=14.9324, Expected=15.8060
# Month=17, Predicted=16.5149, Expected=16.5270
# Month=18, Predicted=17.0178, Expected=16.5460
# Month=19, Predicted=16.4864, Expected=16.7170
# Month=20, Predicted=16.8351, Expected=16.4330
# Month=21, Predicted=16.1282, Expected=15.7690
# Month=22, Predicted=15.2744, Expected=15.2750
# Month=23, Predicted=14.8521, Expected=15.1230
# Month=24, Predicted=14.9078, Expected=15.5410
# Month=25, Predicted=15.8164, Expected=15.8250
# Month=26, Predicted=16.0384, Expected=16.3760
# Month=27, Predicted=16.7255, Expected=16.3570
# Month=28, Predicted=16.2575, Expected=16.9070
# Month=29, Predicted=17.2558, Expected=17.0210
# Month=30, Predicted=17.0730, Expected=17.4190
# Month=31, Predicted=17.6860, Expected=17.5330
# Month=32, Predicted=17.5850, Expected=17.2680
# Month=33, Predicted=16.9752, Expected=16.6030
# Month=34, Predicted=16.1081, Expected=15.8250
# Month=35, Predicted=15.2964, Expected=15.4460
# Month=36, Predicted=15.0847, Expected=15.6360
# Month=37, Predicted=15.7740, Expected=15.6930
# Month=38, Predicted=15.6766, Expected=16.7550
# Month=39, Predicted=17.4639, Expected=16.5090
# Month=40, Predicted=16.2283, Expected=17.7230
# Month=41, Predicted=18.4962, Expected=18.6910
# Month=42, Predicted=19.3513, Expected=19.1270
# Month=43, Predicted=19.4102, Expected=19.5640
# Month=44, Predicted=19.8477, Expected=19.2030
# Month=45, Predicted=18.8521, Expected=18.2160
# Month=46, Predicted=17.6475, Expected=17.2110
# Month=47, Predicted=16.6401, Expected=16.6600
# Month=48, Predicted=16.2102, Expected=16.8310
# Month=49, Predicted=16.9491, Expected=15.7690
# Month=50, Predicted=15.1912, Expected=15.7310
# Month=51, Predicted=15.6128, Expected=15.9960
# Month=52, Predicted=16.1972, Expected=17.0210
# Month=53, Predicted=17.7117, Expected=17.5520
# Month=54, Predicted=17.8875, Expected=17.8370
# Month=55, Predicted=18.0510, Expected=17.8560
# Month=56, Predicted=17.7964, Expected=17.5710
# Month=57, Predicted=17.2656, Expected=17.0780
# Month=58, Predicted=16.6556, Expected=16.6600
# Month=59, Predicted=16.2769, Expected=16.4330
# Month=60, Predicted=16.1648, Expected=16.5840
# Run 7 — RMSE: 0.509282, MSE: 0.259369, NMSE: 0.0019387716, Time: 214.8s
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.1514, Expected=13.7000
# Month=2, Predicted=14.0175, Expected=13.8140
# Month=3, Predicted=13.8132, Expected=14.3830
# Month=4, Predicted=14.7005, Expected=15.0470
# Month=5, Predicted=15.4315, Expected=15.6930
# Month=6, Predicted=16.0619, Expected=15.8440
# Month=7, Predicted=15.8868, Expected=15.7120
# Month=8, Predicted=15.5030, Expected=15.3130
# Month=9, Predicted=14.9250, Expected=14.7630
# Month=10, Predicted=14.3026, Expected=13.5480
# Month=11, Predicted=12.9514, Expected=13.5860
# Month=12, Predicted=13.5143, Expected=14.5160
# Month=13, Predicted=15.1663, Expected=14.3830
# Month=14, Predicted=14.1732, Expected=14.4970
# Month=15, Predicted=14.4962, Expected=14.7440
# Month=16, Predicted=14.9425, Expected=15.8060
# Month=17, Predicted=16.5407, Expected=16.5270
# Month=18, Predicted=16.9699, Expected=16.5460
# Month=19, Predicted=16.4584, Expected=16.7170
# Month=20, Predicted=16.7879, Expected=16.4330
# Month=21, Predicted=16.1110, Expected=15.7690
# Month=22, Predicted=15.2623, Expected=15.2750
# Month=23, Predicted=14.8404, Expected=15.1230
# Month=24, Predicted=14.8981, Expected=15.5410
# Month=25, Predicted=15.8105, Expected=15.8250
# Month=26, Predicted=16.0649, Expected=16.3760
# Month=27, Predicted=16.6846, Expected=16.3570
# Month=28, Predicted=16.2384, Expected=16.9070
# Month=29, Predicted=17.2152, Expected=17.0210
# Month=30, Predicted=17.0202, Expected=17.4190
# Month=31, Predicted=17.6857, Expected=17.5330
# Month=32, Predicted=17.5322, Expected=17.2680
# Month=33, Predicted=16.9587, Expected=16.6030
# Month=34, Predicted=16.0960, Expected=15.8250
# Month=35, Predicted=15.2835, Expected=15.4460
# Month=36, Predicted=15.0684, Expected=15.6360
# Month=37, Predicted=15.7372, Expected=15.6930
# Month=38, Predicted=15.6377, Expected=16.7550
# Month=39, Predicted=17.4897, Expected=16.5090
# Month=40, Predicted=16.2129, Expected=17.7230
# Month=41, Predicted=18.5164, Expected=18.6910
# Month=42, Predicted=19.3691, Expected=19.1270
# Month=43, Predicted=19.3996, Expected=19.5640
# Month=44, Predicted=19.8368, Expected=19.2030
# Month=45, Predicted=18.8351, Expected=18.2160
# Month=46, Predicted=17.6373, Expected=17.2110
# Month=47, Predicted=16.6303, Expected=16.6600
# Month=48, Predicted=16.1992, Expected=16.8310
# Month=49, Predicted=16.9019, Expected=15.7690
# Month=50, Predicted=15.1827, Expected=15.7310
# Month=51, Predicted=15.5971, Expected=15.9960
# Month=52, Predicted=16.2181, Expected=17.0210
# Month=53, Predicted=17.7355, Expected=17.5520
# Month=54, Predicted=17.8520, Expected=17.8370
# Month=55, Predicted=18.0777, Expected=17.8560
# Month=56, Predicted=17.7684, Expected=17.5710
# Month=57, Predicted=17.2484, Expected=17.0780
# Month=58, Predicted=16.6439, Expected=16.6600
# Month=59, Predicted=16.2623, Expected=16.4330
# Month=60, Predicted=16.1506, Expected=16.5840
# Run 8 — RMSE: 0.511551, MSE: 0.261684, NMSE: 0.0019384123, Time: 196.3s
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2268, Expected=13.7000
# Month=2, Predicted=14.0528, Expected=13.8140
# Month=3, Predicted=13.8916, Expected=14.3830
# Month=4, Predicted=14.7358, Expected=15.0470
# Month=5, Predicted=15.4504, Expected=15.6930
# Month=6, Predicted=16.0848, Expected=15.8440
# Month=7, Predicted=15.9572, Expected=15.7120
# Month=8, Predicted=15.5194, Expected=15.3130
# Month=9, Predicted=14.9288, Expected=14.7630
# Month=10, Predicted=14.3191, Expected=13.5480
# Month=11, Predicted=13.0069, Expected=13.5860
# Month=12, Predicted=13.5871, Expected=14.5160
# Month=13, Predicted=15.1463, Expected=14.3830
# Month=14, Predicted=14.1894, Expected=14.4970
# Month=15, Predicted=14.5746, Expected=14.7440
# Month=16, Predicted=14.9877, Expected=15.8060
# Month=17, Predicted=16.5184, Expected=16.5270
# Month=18, Predicted=16.9736, Expected=16.5460
# Month=19, Predicted=16.5264, Expected=16.7170
# Month=20, Predicted=16.8503, Expected=16.4330
# Month=21, Predicted=16.1128, Expected=15.7690
# Month=22, Predicted=15.2941, Expected=15.2750
# Month=23, Predicted=14.8505, Expected=15.1230
# Month=24, Predicted=14.9098, Expected=15.5410
# Month=25, Predicted=15.8537, Expected=15.8250
# Month=26, Predicted=16.1060, Expected=16.3760
# Month=27, Predicted=16.7220, Expected=16.3570
# Month=28, Predicted=16.2941, Expected=16.9070
# Month=29, Predicted=17.2526, Expected=17.0210
# Month=30, Predicted=17.0986, Expected=17.4190
# Month=31, Predicted=17.7280, Expected=17.5330
# Month=32, Predicted=17.6106, Expected=17.2680
# Month=33, Predicted=16.9605, Expected=16.6030
# Month=34, Predicted=16.1279, Expected=15.8250
# Month=35, Predicted=15.3278, Expected=15.4460
# Month=36, Predicted=15.0717, Expected=15.6360
# Month=37, Predicted=15.7905, Expected=15.6930
# Month=38, Predicted=15.7141, Expected=16.7550
# Month=39, Predicted=17.4674, Expected=16.5090
# Month=40, Predicted=16.2149, Expected=17.7230
# Month=41, Predicted=18.4954, Expected=18.6910
# Month=42, Predicted=19.3486, Expected=19.1270
# Month=43, Predicted=19.4431, Expected=19.5640
# Month=44, Predicted=19.8802, Expected=19.2030
# Month=45, Predicted=18.8379, Expected=18.2160
# Month=46, Predicted=17.6923, Expected=17.2110
# Month=47, Predicted=16.6856, Expected=16.6600
# Month=48, Predicted=16.2158, Expected=16.8310
# Month=49, Predicted=16.9643, Expected=15.7690
# Month=50, Predicted=15.2386, Expected=15.7310
# Month=51, Predicted=15.6458, Expected=15.9960
# Month=52, Predicted=16.2635, Expected=17.0210
# Month=53, Predicted=17.7138, Expected=17.5520
# Month=54, Predicted=17.8912, Expected=17.8370
# Month=55, Predicted=18.1185, Expected=17.8560
# Month=56, Predicted=17.8364, Expected=17.5710
# Month=57, Predicted=17.2501, Expected=17.0780
# Month=58, Predicted=16.6539, Expected=16.6600
# Month=59, Predicted=16.2670, Expected=16.4330
# Month=60, Predicted=16.1532, Expected=16.5840
# Run 9 — RMSE: 0.501470, MSE: 0.251472, NMSE: 0.0018819357, Time: 205.0s
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2759, Expected=13.7000
# Month=2, Predicted=14.0584, Expected=13.8140
# Month=3, Predicted=13.9408, Expected=14.3830
# Month=4, Predicted=14.7414, Expected=15.0470
# Month=5, Predicted=15.4763, Expected=15.6930
# Month=6, Predicted=16.1062, Expected=15.8440
# Month=7, Predicted=16.0067, Expected=15.7120
# Month=8, Predicted=15.5299, Expected=15.3130
# Month=9, Predicted=14.9431, Expected=14.7630
# Month=10, Predicted=14.3226, Expected=13.5480
# Month=11, Predicted=12.9729, Expected=13.5860
# Month=12, Predicted=13.6360, Expected=14.5160
# Month=13, Predicted=15.2040, Expected=14.3830
# Month=14, Predicted=14.1996, Expected=14.4970
# Month=15, Predicted=14.6238, Expected=14.7440
# Month=16, Predicted=15.0045, Expected=15.8060
# Month=17, Predicted=16.5624, Expected=16.5270
# Month=18, Predicted=17.0140, Expected=16.5460
# Month=19, Predicted=16.5738, Expected=16.7170
# Month=20, Predicted=16.9007, Expected=16.4330
# Month=21, Predicted=16.1124, Expected=15.7690
# Month=22, Predicted=15.2848, Expected=15.2750
# Month=23, Predicted=14.8603, Expected=15.1230
# Month=24, Predicted=14.9151, Expected=15.5410
# Month=25, Predicted=15.8468, Expected=15.8250
# Month=26, Predicted=16.1030, Expected=16.3760
# Month=27, Predicted=16.7248, Expected=16.3570
# Month=28, Predicted=16.3360, Expected=16.9070
# Month=29, Predicted=17.2553, Expected=17.0210
# Month=30, Predicted=17.1478, Expected=17.4190
# Month=31, Predicted=17.7208, Expected=17.5330
# Month=32, Predicted=17.6598, Expected=17.2680
# Month=33, Predicted=16.9576, Expected=16.6030
# Month=34, Predicted=16.1185, Expected=15.8250
# Month=35, Predicted=15.3091, Expected=15.4460
# Month=36, Predicted=15.0848, Expected=15.6360
# Month=37, Predicted=15.8407, Expected=15.6930
# Month=38, Predicted=15.7637, Expected=16.7550
# Month=39, Predicted=17.5114, Expected=16.5090
# Month=40, Predicted=16.2106, Expected=17.7230
# Month=41, Predicted=18.5250, Expected=18.6910
# Month=42, Predicted=19.4029, Expected=19.1270
# Month=43, Predicted=19.4366, Expected=19.5640
# Month=44, Predicted=19.8739, Expected=19.2030
# Month=45, Predicted=18.8493, Expected=18.2160
# Month=46, Predicted=17.6635, Expected=17.2110
# Month=47, Predicted=16.6563, Expected=16.6600
# Month=48, Predicted=16.2192, Expected=16.8310
# Month=49, Predicted=17.0147, Expected=15.7690
# Month=50, Predicted=15.2077, Expected=15.7310
# Month=51, Predicted=15.6837, Expected=15.9960
# Month=52, Predicted=16.2667, Expected=17.0210
# Month=53, Predicted=17.7620, Expected=17.5520
# Month=54, Predicted=17.8915, Expected=17.8370
# Month=55, Predicted=18.1153, Expected=17.8560
# Month=56, Predicted=17.8838, Expected=17.5710
# Month=57, Predicted=17.2499, Expected=17.0780
# Month=58, Predicted=16.6638, Expected=16.6600
# Month=59, Predicted=16.2814, Expected=16.4330
# Month=60, Predicted=16.1485, Expected=16.5840
# Run 10 — RMSE: 0.503324, MSE: 0.253335, NMSE: 0.0018961339, Time: 177.6s
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.2947, Expected=13.7000
# Month=2, Predicted=14.0508, Expected=13.8140
# Month=3, Predicted=13.9521, Expected=14.3830
# Month=4, Predicted=14.7338, Expected=15.0470
# Month=5, Predicted=15.4616, Expected=15.6930
# Month=6, Predicted=16.0905, Expected=15.8440
# Month=7, Predicted=16.0356, Expected=15.7120
# Month=8, Predicted=15.5654, Expected=15.3130
# Month=9, Predicted=14.9242, Expected=14.7630
# Month=10, Predicted=14.2868, Expected=13.5480
# Month=11, Predicted=12.9995, Expected=13.5860
# Month=12, Predicted=13.6390, Expected=14.5160
# Month=13, Predicted=15.2465, Expected=14.3830
# Month=14, Predicted=14.2352, Expected=14.4970
# Month=15, Predicted=14.6351, Expected=14.7440
# Month=16, Predicted=15.0510, Expected=15.8060
# Month=17, Predicted=16.5428, Expected=16.5270
# Month=18, Predicted=17.0263, Expected=16.5460
# Month=19, Predicted=16.5782, Expected=16.7170
# Month=20, Predicted=16.9430, Expected=16.4330
# Month=21, Predicted=16.1286, Expected=15.7690
# Month=22, Predicted=15.2551, Expected=15.2750
# Month=23, Predicted=14.8274, Expected=15.1230
# Month=24, Predicted=14.9527, Expected=15.5410
# Month=25, Predicted=15.8597, Expected=15.8250
# Month=26, Predicted=16.1372, Expected=16.3760
# Month=27, Predicted=16.7201, Expected=16.3570
# Month=28, Predicted=16.3463, Expected=16.9070
# Month=29, Predicted=17.2507, Expected=17.0210
# Month=30, Predicted=17.1591, Expected=17.4190
# Month=31, Predicted=17.7362, Expected=17.5330
# Month=32, Predicted=17.6711, Expected=17.2680
# Month=33, Predicted=16.9802, Expected=16.6030
# Month=34, Predicted=16.0888, Expected=15.8250
# Month=35, Predicted=15.2932, Expected=15.4460
# Month=36, Predicted=15.0705, Expected=15.6360
# Month=37, Predicted=15.8937, Expected=15.6930
# Month=38, Predicted=15.7665, Expected=16.7550
# Month=39, Predicted=17.4918, Expected=16.5090
# Month=40, Predicted=16.2387, Expected=17.7230
# Month=41, Predicted=18.4705, Expected=18.6910
# Month=42, Predicted=19.4222, Expected=19.1270
# Month=43, Predicted=19.4475, Expected=19.5640
# Month=44, Predicted=19.8846, Expected=19.2030
# Month=45, Predicted=18.8398, Expected=18.2160
# Month=46, Predicted=17.6719, Expected=17.2110
# Month=47, Predicted=16.6664, Expected=16.6600
# Month=48, Predicted=16.1834, Expected=16.8310
# Month=49, Predicted=17.0570, Expected=15.7690
# Month=50, Predicted=15.2229, Expected=15.7310
# Month=51, Predicted=15.6981, Expected=15.9960
# Month=52, Predicted=16.3066, Expected=17.0210
# Month=53, Predicted=17.7551, Expected=17.5520
# Month=54, Predicted=17.8898, Expected=17.8370
# Month=55, Predicted=18.1493, Expected=17.8560
# Month=56, Predicted=17.8882, Expected=17.5710
# Month=57, Predicted=17.2657, Expected=17.0780
# Month=58, Predicted=16.6310, Expected=16.6600
# Month=59, Predicted=16.2588, Expected=16.4330
# Month=60, Predicted=16.1811, Expected=16.5840
# Run 11 — RMSE: 0.502021, MSE: 0.252026, NMSE: 0.0018891166, Time: 190.9s
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2542, Expected=13.7000
# Month=2, Predicted=14.0518, Expected=13.8140
# Month=3, Predicted=13.9157, Expected=14.3830
# Month=4, Predicted=14.7348, Expected=15.0470
# Month=5, Predicted=15.4610, Expected=15.6930
# Month=6, Predicted=16.0942, Expected=15.8440
# Month=7, Predicted=15.9854, Expected=15.7120
# Month=8, Predicted=15.5026, Expected=15.3130
# Month=9, Predicted=14.9312, Expected=14.7630
# Month=10, Predicted=14.3186, Expected=13.5480
# Month=11, Predicted=13.0430, Expected=13.5860
# Month=12, Predicted=13.5862, Expected=14.5160
# Month=13, Predicted=15.1373, Expected=14.3830
# Month=14, Predicted=14.1727, Expected=14.4970
# Month=15, Predicted=14.5987, Expected=14.7440
# Month=16, Predicted=14.9517, Expected=15.8060
# Month=17, Predicted=16.5126, Expected=16.5270
# Month=18, Predicted=16.9839, Expected=16.5460
# Month=19, Predicted=16.5194, Expected=16.7170
# Month=20, Predicted=16.8761, Expected=16.4330
# Month=21, Predicted=16.1124, Expected=15.7690
# Month=22, Predicted=15.2977, Expected=15.2750
# Month=23, Predicted=14.8500, Expected=15.1230
# Month=24, Predicted=14.8950, Expected=15.5410
# Month=25, Predicted=15.8192, Expected=15.8250
# Month=26, Predicted=16.0496, Expected=16.3760
# Month=27, Predicted=16.7175, Expected=16.3570
# Month=28, Predicted=16.2782, Expected=16.9070
# Month=29, Predicted=17.2479, Expected=17.0210
# Month=30, Predicted=17.1227, Expected=17.4190
# Month=31, Predicted=17.6890, Expected=17.5330
# Month=32, Predicted=17.6347, Expected=17.2680
# Month=33, Predicted=16.9582, Expected=16.6030
# Month=34, Predicted=16.1315, Expected=15.8250
# Month=35, Predicted=15.3384, Expected=15.4460
# Month=36, Predicted=15.0746, Expected=15.6360
# Month=37, Predicted=15.8098, Expected=15.6930
# Month=38, Predicted=15.7200, Expected=16.7550
# Month=39, Predicted=17.4616, Expected=16.5090
# Month=40, Predicted=16.2106, Expected=17.7230
# Month=41, Predicted=18.4998, Expected=18.6910
# Month=42, Predicted=19.3391, Expected=19.1270
# Month=43, Predicted=19.4127, Expected=19.5640
# Month=44, Predicted=19.8501, Expected=19.2030
# Month=45, Predicted=18.8410, Expected=18.2160
# Month=46, Predicted=17.7162, Expected=17.2110
# Month=47, Predicted=16.7105, Expected=16.6600
# Month=48, Predicted=16.2153, Expected=16.8310
# Month=49, Predicted=16.9901, Expected=15.7690
# Month=50, Predicted=15.2669, Expected=15.7310
# Month=51, Predicted=15.6274, Expected=15.9960
# Month=52, Predicted=16.2122, Expected=17.0210
# Month=53, Predicted=17.7060, Expected=17.5520
# Month=54, Predicted=17.8826, Expected=17.8370
# Month=55, Predicted=18.0620, Expected=17.8560
# Month=56, Predicted=17.8294, Expected=17.5710
# Month=57, Predicted=17.2498, Expected=17.0780
# Month=58, Predicted=16.6534, Expected=16.6600
# Month=59, Predicted=16.2687, Expected=16.4330
# Month=60, Predicted=16.1467, Expected=16.5840
# Run 12 — RMSE: 0.503808, MSE: 0.253822, NMSE: 0.0019137320, Time: 133.2s
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2103, Expected=13.7000
# Month=2, Predicted=14.0517, Expected=13.8140
# Month=3, Predicted=13.8734, Expected=14.3830
# Month=4, Predicted=14.7347, Expected=15.0470
# Month=5, Predicted=15.4507, Expected=15.6930
# Month=6, Predicted=16.0831, Expected=15.8440
# Month=7, Predicted=15.9417, Expected=15.7120
# Month=8, Predicted=15.5002, Expected=15.3130
# Month=9, Predicted=14.9226, Expected=14.7630
# Month=10, Predicted=14.3071, Expected=13.5480
# Month=11, Predicted=12.9888, Expected=13.5860
# Month=12, Predicted=13.5616, Expected=14.5160
# Month=13, Predicted=15.1889, Expected=14.3830
# Month=14, Predicted=14.1703, Expected=14.4970
# Month=15, Predicted=14.5564, Expected=14.7440
# Month=16, Predicted=14.9322, Expected=15.8060
# Month=17, Predicted=16.5387, Expected=16.5270
# Month=18, Predicted=16.9934, Expected=16.5460
# Month=19, Predicted=16.4998, Expected=16.7170
# Month=20, Predicted=16.8347, Expected=16.4330
# Month=21, Predicted=16.1054, Expected=15.7690
# Month=22, Predicted=15.2766, Expected=15.2750
# Month=23, Predicted=14.8412, Expected=15.1230
# Month=24, Predicted=14.8928, Expected=15.5410
# Month=25, Predicted=15.8402, Expected=15.8250
# Month=26, Predicted=16.0438, Expected=16.3760
# Month=27, Predicted=16.7209, Expected=16.3570
# Month=28, Predicted=16.2669, Expected=16.9070
# Month=29, Predicted=17.2515, Expected=17.0210
# Month=30, Predicted=17.0804, Expected=17.4190
# Month=31, Predicted=17.7094, Expected=17.5330
# Month=32, Predicted=17.5924, Expected=17.2680
# Month=33, Predicted=16.9523, Expected=16.6030
# Month=34, Predicted=16.1103, Expected=15.8250
# Month=35, Predicted=15.3067, Expected=15.4460
# Month=36, Predicted=15.0656, Expected=15.6360
# Month=37, Predicted=15.7721, Expected=15.6930
# Month=38, Predicted=15.6901, Expected=16.7550
# Month=39, Predicted=17.4877, Expected=16.5090
# Month=40, Predicted=16.2058, Expected=17.7230
# Month=41, Predicted=18.4952, Expected=18.6910
# Month=42, Predicted=19.3849, Expected=19.1270
# Month=43, Predicted=19.4333, Expected=19.5640
# Month=44, Predicted=19.8707, Expected=19.2030
# Month=45, Predicted=18.8320, Expected=18.2160
# Month=46, Predicted=17.6702, Expected=17.2110
# Month=47, Predicted=16.6636, Expected=16.6600
# Month=48, Predicted=16.2037, Expected=16.8310
# Month=49, Predicted=16.9487, Expected=15.7690
# Month=50, Predicted=15.2174, Expected=15.7310
# Month=51, Predicted=15.6190, Expected=15.9960
# Month=52, Predicted=16.1995, Expected=17.0210
# Month=53, Predicted=17.7403, Expected=17.5520
# Month=54, Predicted=17.8899, Expected=17.8370
# Month=55, Predicted=18.0566, Expected=17.8560
# Month=56, Predicted=17.8098, Expected=17.5710
# Month=57, Predicted=17.2428, Expected=17.0780
# Month=58, Predicted=16.6446, Expected=16.6600
# Month=59, Predicted=16.2603, Expected=16.4330
# Month=60, Predicted=16.1429, Expected=16.5840
# Run 13 — RMSE: 0.510223, MSE: 0.260328, NMSE: 0.0019381461, Time: 136.9s
#
# ===== RUN 14/30 =====

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS — Pyraformer on Monthly Lake Erie Levels (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Pyraformer — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Pyraformer — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'Pyraformer_LakeErie_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')

# %% [markdown]
# ## Observations
#
# ### Pyraformer on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*
