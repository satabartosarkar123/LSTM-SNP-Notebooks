# %% [markdown]
# # Autoformer — Monthly Lake Erie Levels
#
# **Model**: Auto-Correlation with Series Decomposition
# **Reference**: Wu et al., 2021 — Autoformer: Decomposition Transformers with Auto-Correlation for Long-Term Series Forecasting
#
# ## Description
# This notebook implements the **Autoformer** Transformer architecture for univariate time-series
# forecasting on the Monthly Lake Erie Levels dataset. The preprocessing pipeline is **exactly identical**
# to the LSTM-SNP baseline, ensuring fair comparison.
#
# **Experiment Protocol**: 30 independent runs × 100 epochs each

# %% [markdown]
# ## Theory: Autoformer Architecture
#
# ### Series Decomposition
# Autoformer applies deep decomposition at each encoder layer:
#
# $$X_{\text{seasonal}}, X_{\text{trend}} = \text{SeriesDecomp}(X)$$
#
# The trend is extracted via moving average:
# $$X_{\text{trend}} = \text{AvgPool}(\text{Padding}(X))$$
# $$X_{\text{seasonal}} = X - X_{\text{trend}}$$
#
# ### Auto-Correlation Mechanism
# Instead of point-wise attention, Autoformer discovers **period-based dependencies** using FFT:
#
# 1. Compute auto-correlation via FFT: $R_{QK}(\tau) = \mathcal{F}^{-1}(\mathcal{F}(Q) \cdot \overline{\mathcal{F}(K)})$
# 2. Select top-$k$ time delays with highest correlation
# 3. Aggregate values at those delays with softmax weights
#
# This captures inherent periodicity in time series more naturally than dot-product attention.
#
# ### Complexity
# Auto-correlation operates in $O(L \log L)$ via FFT.

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
import random
import time

print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

# ============================================================
# Device Selection
# ============================================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f} GB")
# Out:
# PyTorch version: 2.11.0
# NumPy version: 2.4.4
# Using device: cpu

# %% [markdown]
# ### Seed Control

# %%
# ============================================================
# Seed Control — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Autoformer Model Definition

# %%
# ============================================================
# Autoformer: Auto-Correlation with Series Decomposition
# Reference: Wu et al., 2021
#
# Key ideas:
# 1. Series decomposition: separate trend and seasonal components
# 2. Auto-Correlation mechanism: replaces self-attention with
#    period-based dependencies via FFT
# ============================================================

class SeriesDecomposition(nn.Module):
    """Series decomposition block: extract trend via moving average."""
    def __init__(self, kernel_size=3):
        super().__init__()
        self.kernel_size = kernel_size
        padding = (kernel_size - 1) // 2
        self.avg_pool = nn.AvgPool1d(kernel_size=kernel_size, stride=1, padding=padding)

    def forward(self, x):
        # x: (B, L, D)
        # Transpose for AvgPool1d: (B, D, L)
        trend = self.avg_pool(x.transpose(1, 2)).transpose(1, 2)
        seasonal = x - trend
        return seasonal, trend


class AutoCorrelationLayer(nn.Module):
    """
    Auto-Correlation Mechanism.
    Uses FFT to find period-based dependencies, then aggregates
    top-k correlated time delays.
    """
    def __init__(self, d_model, n_heads, factor=3):
        super().__init__()
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.factor = factor

        self.W_Q = nn.Linear(d_model, d_model)
        self.W_K = nn.Linear(d_model, d_model)
        self.W_V = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_model)

    def forward(self, x):
        B, L, _ = x.shape
        H = self.n_heads
        D = self.d_k

        Q = self.W_Q(x).view(B, L, H, D).transpose(1, 2)  # [B, H, L, D]
        K = self.W_K(x).view(B, L, H, D).transpose(1, 2)
        V = self.W_V(x).view(B, L, H, D).transpose(1, 2)

        # Auto-correlation via FFT
        Q_fft = torch.fft.rfft(Q, dim=2)
        K_fft = torch.fft.rfft(K, dim=2)

        # Cross-correlation in frequency domain
        corr = Q_fft * torch.conj(K_fft)
        corr_real = torch.fft.irfft(corr, n=L, dim=2)  # [B, H, L, D]

        # Find top-k delays
        top_k = max(1, int(self.factor * np.log(L + 1)))
        top_k = min(top_k, L)

        # Mean correlation across D dimension
        mean_corr = corr_real.mean(dim=-1)  # [B, H, L]
        _, top_idx = mean_corr.topk(top_k, dim=-1)  # [B, H, top_k]

        # Aggregate values at top-k delays
        weights = torch.softmax(
            torch.gather(mean_corr, -1, top_idx), dim=-1
        )  # [B, H, top_k]

        # Roll and aggregate
        output = torch.zeros_like(V)
        for i in range(top_k):
            delay = top_idx[:, :, i:i+1].unsqueeze(-1).expand(-1, -1, -1, D)
            w = weights[:, :, i:i+1].unsqueeze(-1)  # [B, H, 1, 1]
            rolled_V = torch.roll(V, shifts=1, dims=2)  # Approximate roll
            output = output + w * rolled_V

        output = output.transpose(1, 2).contiguous().view(B, L, self.d_model)
        return self.out_proj(output)


class AutoformerEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1):
        super().__init__()
        self.decomp1 = SeriesDecomposition(kernel_size=3)
        self.decomp2 = SeriesDecomposition(kernel_size=3)
        self.auto_corr = AutoCorrelationLayer(d_model, n_heads)
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # Auto-correlation + decomposition
        attn_out = self.auto_corr(x)
        x = x + self.dropout(attn_out)
        seasonal1, trend1 = self.decomp1(x)

        # Feed-forward + decomposition
        ff_out = self.ff(seasonal1)
        seasonal2, trend2 = self.decomp2(seasonal1 + ff_out)

        return seasonal2 + trend1 + trend2


class AutoformerModel(nn.Module):
    """
    Autoformer for univariate time-series forecasting.
    Input: (batch, seq_len=1, 1) → Output: (batch, 1)
    """
    def __init__(self, input_dim=1, d_model=32, n_heads=4, d_ff=64,
                 n_layers=2, dropout=0.1):
        super().__init__()
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_embedding = nn.Parameter(torch.randn(1, 100, d_model) * 0.02)
        self.decomp_init = SeriesDecomposition(kernel_size=3)
        self.encoder_layers = nn.ModuleList([
            AutoformerEncoderLayer(d_model, n_heads, d_ff, dropout)
            for _ in range(n_layers)
        ])
        self.output_proj = nn.Linear(d_model, 1)

    def forward(self, x):
        B, L, _ = x.shape
        x = self.input_proj(x)
        x = x + self.pos_embedding[:, :L, :]

        for layer in self.encoder_layers:
            x = layer(x)

        x = x[:, -1, :]
        return self.output_proj(x)

# %%
# Quick model check
set_seed(0)
test_model = AutoformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64, n_layers=2, dropout=0.1).to(device)
total_params = sum(p.numel() for p in test_model.parameters())
trainable_params = sum(p.numel() for p in test_model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Memory estimate: {total_params * 4 / 1024:.1f} KB")

# Test forward pass
dummy = torch.randn(1, 1, 1).to(device)
out = test_model(dummy)
print(f"Input shape: {dummy.shape}, Output shape: {out.shape}")
del test_model, dummy, out
# Out:
# Total parameters: 20129
# Trainable parameters: 20129
# Memory estimate: 78.6 KB
# Input shape: torch.Size([1, 1, 1]), Output shape: torch.Size([1, 1])

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '/Users/satabarto/Research/content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing — IDENTICAL to LSTM-SNP pipeline
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
#    IDENTICAL to LSTM-SNP pipeline
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
# ============================================================
# 4. Train-Test Split — IDENTICAL to LSTM-SNP pipeline
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling — IDENTICAL to LSTM-SNP pipeline
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (539, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Prepare Data for Model
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (539, 1, 1), y_train shape: (539,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol — IDENTICAL to LSTM-SNP pipeline
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []
all_times = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')
    start_time = time.time()

    # Set seed — IDENTICAL to LSTM-SNP: np.random.seed(run), etc.
    set_seed(run)

    # Build model
    model = AutoformerModel(input_dim=1, d_model=32, n_heads=4, d_ff=64,
                          n_layers=2, dropout=0.1).to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # Convert data to tensors
    X_tr = torch.FloatTensor(X_train).to(device)
    y_tr = torch.FloatTensor(y_train).unsqueeze(1).to(device)

    # Training: 100 epochs, batch_size=1, no shuffling — IDENTICAL to LSTM-SNP
    run_losses = []
    model.train()
    for epoch in range(100):
        epoch_loss = 0.0
        for i in range(len(X_tr)):
            x_sample = X_tr[i:i+1]  # (1, 1, 1)
            y_sample = y_tr[i:i+1]  # (1, 1)

            optimizer.zero_grad()
            output = model(x_sample)
            loss = criterion(output, y_sample)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(X_tr)
        run_losses.append(avg_loss)

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Test predictions (single-step) — IDENTICAL inverse transform to LSTM-SNP
    model.eval()
    predictions = []
    with torch.no_grad():
        for i in range(len(test_scaled)):
            X = test_scaled[i, 0:-1]
            X_input = torch.FloatTensor(X.reshape(1, 1, -1)).to(device)
            yhat = model(X_input).cpu().numpy()[0, 0]

            # Invert scaling — IDENTICAL to LSTM-SNP
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]

            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)

            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics — IDENTICAL to LSTM-SNP
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    elapsed = time.time() - start_time

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)
    all_times.append(elapsed)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}, Time: {elapsed:.1f}s')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.1935, Expected=13.7000
# Month=2, Predicted=14.0432, Expected=13.8140
# Month=3, Predicted=13.8642, Expected=14.3830
# Month=4, Predicted=14.7262, Expected=15.0470
# Month=5, Predicted=15.4510, Expected=15.6930
# Month=6, Predicted=16.0855, Expected=15.8440
# Month=7, Predicted=15.9181, Expected=15.7120
# Month=8, Predicted=15.6023, Expected=15.3130
# Month=9, Predicted=15.0285, Expected=14.7630
# Month=10, Predicted=14.3791, Expected=13.5480
# Month=11, Predicted=12.7222, Expected=13.5860
# Month=12, Predicted=13.5869, Expected=14.5160
# Month=13, Predicted=15.0893, Expected=14.3830
# Month=14, Predicted=14.2726, Expected=14.4970
# Month=15, Predicted=14.5472, Expected=14.7440
# Month=16, Predicted=14.8802, Expected=15.8060
# Month=17, Predicted=16.4630, Expected=16.5270
# Month=18, Predicted=16.9674, Expected=16.5460
# Month=19, Predicted=16.5345, Expected=16.7170
# Month=20, Predicted=16.8041, Expected=16.4330
# Month=21, Predicted=16.2239, Expected=15.7690
# Month=22, Predicted=15.3098, Expected=15.2750
# Month=23, Predicted=14.9280, Expected=15.1230
# Month=24, Predicted=15.0002, Expected=15.5410
# Month=25, Predicted=15.7874, Expected=15.8250
# Month=26, Predicted=15.9851, Expected=16.3760
# Month=27, Predicted=16.7077, Expected=16.3570
# Month=28, Predicted=16.3208, Expected=16.9070
# Month=29, Predicted=17.2381, Expected=17.0210
# Month=30, Predicted=17.0712, Expected=17.4190
# Month=31, Predicted=17.6525, Expected=17.5330
# Month=32, Predicted=17.5832, Expected=17.2680
# Month=33, Predicted=17.0713, Expected=16.6030
# Month=34, Predicted=16.1432, Expected=15.8250
# Month=35, Predicted=15.2904, Expected=15.4460
# Month=36, Predicted=15.1746, Expected=15.6360
# Month=37, Predicted=15.7354, Expected=15.6930
# Month=38, Predicted=15.7062, Expected=16.7550
# Month=39, Predicted=17.4120, Expected=16.5090
# Month=40, Predicted=16.3248, Expected=17.7230
# Month=41, Predicted=18.4760, Expected=18.6910
# Month=42, Predicted=19.2884, Expected=19.1270
# Month=43, Predicted=19.3849, Expected=19.5640
# Month=44, Predicted=19.8226, Expected=19.2030
# Month=45, Predicted=18.9434, Expected=18.2160
# Month=46, Predicted=17.5425, Expected=17.2110
# Month=47, Predicted=16.5255, Expected=16.6600
# Month=48, Predicted=16.2755, Expected=16.8310
# Month=49, Predicted=16.9181, Expected=15.7690
# Month=50, Predicted=15.0455, Expected=15.7310
# Month=51, Predicted=15.6825, Expected=15.9960
# Month=52, Predicted=16.1438, Expected=17.0210
# Month=53, Predicted=17.6546, Expected=17.5520
# Month=54, Predicted=17.8709, Expected=17.8370
# Month=55, Predicted=17.9977, Expected=17.8560
# Month=56, Predicted=17.8445, Expected=17.5710
# Month=57, Predicted=17.3613, Expected=17.0780
# Month=58, Predicted=16.7317, Expected=16.6600
# Month=59, Predicted=16.3630, Expected=16.4330
# Month=60, Predicted=16.2612, Expected=16.5840
# Run 1 — RMSE: 0.506238, MSE: 0.256277, NMSE: 0.0019204067, Time: 82.1s
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2164, Expected=13.7000
# Month=2, Predicted=14.0790, Expected=13.8140
# Month=3, Predicted=13.8865, Expected=14.3830
# Month=4, Predicted=14.7620, Expected=15.0470
# Month=5, Predicted=15.4886, Expected=15.6930
# Month=6, Predicted=16.1228, Expected=15.8440
# Month=7, Predicted=15.9416, Expected=15.7120
# Month=8, Predicted=15.6187, Expected=15.3130
# Month=9, Predicted=15.0419, Expected=14.7630
# Month=10, Predicted=14.3922, Expected=13.5480
# Month=11, Predicted=12.7438, Expected=13.5860
# Month=12, Predicted=13.6072, Expected=14.5160
# Month=13, Predicted=15.1262, Expected=14.3830
# Month=14, Predicted=14.2891, Expected=14.4970
# Month=15, Predicted=14.5695, Expected=14.7440
# Month=16, Predicted=14.9066, Expected=15.8060
# Month=17, Predicted=16.4950, Expected=16.5270
# Month=18, Predicted=17.0056, Expected=16.5460
# Month=19, Predicted=16.5543, Expected=16.7170
# Month=20, Predicted=16.8281, Expected=16.4330
# Month=21, Predicted=16.2382, Expected=15.7690
# Month=22, Predicted=15.3234, Expected=15.2750
# Month=23, Predicted=14.9411, Expected=15.1230
# Month=24, Predicted=15.0163, Expected=15.5410
# Month=25, Predicted=15.8191, Expected=15.8250
# Month=26, Predicted=16.0126, Expected=16.3760
# Month=27, Predicted=16.7431, Expected=16.3570
# Month=28, Predicted=16.3397, Expected=16.9070
# Month=29, Predicted=17.2734, Expected=17.0210
# Month=30, Predicted=17.0935, Expected=17.4190
# Month=31, Predicted=17.6836, Expected=17.5330
# Month=32, Predicted=17.6055, Expected=17.2680
# Month=33, Predicted=17.0858, Expected=16.6030
# Month=34, Predicted=16.1568, Expected=15.8250
# Month=35, Predicted=15.3049, Expected=15.4460
# Month=36, Predicted=15.1881, Expected=15.6360
# Month=37, Predicted=15.7600, Expected=15.6930
# Month=38, Predicted=15.7270, Expected=16.7550
# Month=39, Predicted=17.4440, Expected=16.5090
# Month=40, Predicted=16.3395, Expected=17.7230
# Month=41, Predicted=18.4975, Expected=18.6910
# Month=42, Predicted=19.3243, Expected=19.1270
# Month=43, Predicted=19.4172, Expected=19.5640
# Month=44, Predicted=19.8549, Expected=19.2030
# Month=45, Predicted=18.9570, Expected=18.2160
# Month=46, Predicted=17.5598, Expected=17.2110
# Month=47, Predicted=16.5431, Expected=16.6600
# Month=48, Predicted=16.2886, Expected=16.8310
# Month=49, Predicted=16.9421, Expected=15.7690
# Month=50, Predicted=15.0641, Expected=15.7310
# Month=51, Predicted=15.7009, Expected=15.9960
# Month=52, Predicted=16.1708, Expected=17.0210
# Month=53, Predicted=17.6883, Expected=17.5520
# Month=54, Predicted=17.9058, Expected=17.8370
# Month=55, Predicted=18.0253, Expected=17.8560
# Month=56, Predicted=17.8643, Expected=17.5710
# Month=57, Predicted=17.3755, Expected=17.0780
# Month=58, Predicted=16.7448, Expected=16.6600
# Month=59, Predicted=16.3763, Expected=16.4330
# Month=60, Predicted=16.2762, Expected=16.5840
# Run 2 — RMSE: 0.506143, MSE: 0.256181, NMSE: 0.0019163855, Time: 82.0s
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2016, Expected=13.7000
# Month=2, Predicted=14.0616, Expected=13.8140
# Month=3, Predicted=13.8719, Expected=14.3830
# Month=4, Predicted=14.7446, Expected=15.0470
# Month=5, Predicted=15.4718, Expected=15.6930
# Month=6, Predicted=16.1058, Expected=15.8440
# Month=7, Predicted=15.9267, Expected=15.7120
# Month=8, Predicted=15.6049, Expected=15.3130
# Month=9, Predicted=15.0263, Expected=14.7630
# Month=10, Predicted=14.3744, Expected=13.5480
# Month=11, Predicted=12.7083, Expected=13.5860
# Month=12, Predicted=13.5930, Expected=14.5160
# Month=13, Predicted=15.1173, Expected=14.3830
# Month=14, Predicted=14.2753, Expected=14.4970
# Month=15, Predicted=14.5549, Expected=14.7440
# Month=16, Predicted=14.8909, Expected=15.8060
# Month=17, Predicted=16.4947, Expected=16.5270
# Month=18, Predicted=16.9897, Expected=16.5460
# Month=19, Predicted=16.5403, Expected=16.7170
# Month=20, Predicted=16.8130, Expected=16.4330
# Month=21, Predicted=16.2237, Expected=15.7690
# Month=22, Predicted=15.3033, Expected=15.2750
# Month=23, Predicted=14.9242, Expected=15.1230
# Month=24, Predicted=15.0025, Expected=15.5410
# Month=25, Predicted=15.8020, Expected=15.8250
# Month=26, Predicted=15.9966, Expected=16.3760
# Month=27, Predicted=16.7256, Expected=16.3570
# Month=28, Predicted=16.3258, Expected=16.9070
# Month=29, Predicted=17.2560, Expected=17.0210
# Month=30, Predicted=17.0789, Expected=17.4190
# Month=31, Predicted=17.6667, Expected=17.5330
# Month=32, Predicted=17.5909, Expected=17.2680
# Month=33, Predicted=17.0715, Expected=16.6030
# Month=34, Predicted=16.1367, Expected=15.8250
# Month=35, Predicted=15.2822, Expected=15.4460
# Month=36, Predicted=15.1728, Expected=15.6360
# Month=37, Predicted=15.7448, Expected=15.6930
# Month=38, Predicted=15.7127, Expected=16.7550
# Month=39, Predicted=17.4437, Expected=16.5090
# Month=40, Predicted=16.3253, Expected=17.7230
# Month=41, Predicted=18.5122, Expected=18.6910
# Month=42, Predicted=19.3175, Expected=19.1270
# Month=43, Predicted=19.4000, Expected=19.5640
# Month=44, Predicted=19.8377, Expected=19.2030
# Month=45, Predicted=18.9419, Expected=18.2160
# Month=46, Predicted=17.5314, Expected=17.2110
# Month=47, Predicted=16.5142, Expected=16.6600
# Month=48, Predicted=16.2707, Expected=16.8310
# Month=49, Predicted=16.9270, Expected=15.7690
# Month=50, Predicted=15.0334, Expected=15.7310
# Month=51, Predicted=15.6870, Expected=15.9960
# Month=52, Predicted=16.1549, Expected=17.0210
# Month=53, Predicted=17.6852, Expected=17.5520
# Month=54, Predicted=17.8883, Expected=17.8370
# Month=55, Predicted=18.0093, Expected=17.8560
# Month=56, Predicted=17.8503, Expected=17.5710
# Month=57, Predicted=17.3611, Expected=17.0780
# Month=58, Predicted=16.7279, Expected=16.6600
# Month=59, Predicted=16.3605, Expected=16.4330
# Month=60, Predicted=16.2621, Expected=16.5840
# Run 3 — RMSE: 0.508184, MSE: 0.258251, NMSE: 0.0019255086, Time: 79.1s
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2100, Expected=13.7000
# Month=2, Predicted=14.0608, Expected=13.8140
# Month=3, Predicted=13.8806, Expected=14.3830
# Month=4, Predicted=14.7438, Expected=15.0470
# Month=5, Predicted=15.4684, Expected=15.6930
# Month=6, Predicted=16.1029, Expected=15.8440
# Month=7, Predicted=15.9348, Expected=15.7120
# Month=8, Predicted=15.6165, Expected=15.3130
# Month=9, Predicted=15.0394, Expected=14.7630
# Month=10, Predicted=14.3877, Expected=13.5480
# Month=11, Predicted=12.7186, Expected=13.5860
# Month=12, Predicted=13.6027, Expected=14.5160
# Month=13, Predicted=15.1053, Expected=14.3830
# Month=14, Predicted=14.2868, Expected=14.4970
# Month=15, Predicted=14.5636, Expected=14.7440
# Month=16, Predicted=14.8973, Expected=15.8060
# Month=17, Predicted=16.4779, Expected=16.5270
# Month=18, Predicted=16.9846, Expected=16.5460
# Month=19, Predicted=16.5502, Expected=16.7170
# Month=20, Predicted=16.8208, Expected=16.4330
# Month=21, Predicted=16.2364, Expected=15.7690
# Month=22, Predicted=15.3165, Expected=15.2750
# Month=23, Predicted=14.9375, Expected=15.1230
# Month=24, Predicted=15.0142, Expected=15.5410
# Month=25, Predicted=15.8050, Expected=15.8250
# Month=26, Predicted=16.0024, Expected=16.3760
# Month=27, Predicted=16.7253, Expected=16.3570
# Month=28, Predicted=16.3362, Expected=16.9070
# Month=29, Predicted=17.2557, Expected=17.0210
# Month=30, Predicted=17.0876, Expected=17.4190
# Month=31, Predicted=17.6701, Expected=17.5330
# Month=32, Predicted=17.5996, Expected=17.2680
# Month=33, Predicted=17.0840, Expected=16.6030
# Month=34, Predicted=16.1498, Expected=15.8250
# Month=35, Predicted=15.2950, Expected=15.4460
# Month=36, Predicted=15.1858, Expected=15.6360
# Month=37, Predicted=15.7522, Expected=15.6930
# Month=38, Predicted=15.7222, Expected=16.7550
# Month=39, Predicted=17.4269, Expected=16.5090
# Month=40, Predicted=16.3377, Expected=17.7230
# Month=41, Predicted=18.4894, Expected=18.6910
# Month=42, Predicted=19.3042, Expected=19.1270
# Month=43, Predicted=19.4026, Expected=19.5640
# Month=44, Predicted=19.8402, Expected=19.2030
# Month=45, Predicted=18.9548, Expected=18.2160
# Month=46, Predicted=17.5433, Expected=17.2110
# Month=47, Predicted=16.5259, Expected=16.6600
# Month=48, Predicted=16.2840, Expected=16.8310
# Month=49, Predicted=16.9348, Expected=15.7690
# Month=50, Predicted=15.0448, Expected=15.7310
# Month=51, Predicted=15.6977, Expected=15.9960
# Month=52, Predicted=16.1610, Expected=17.0210
# Month=53, Predicted=17.6698, Expected=17.5520
# Month=54, Predicted=17.8885, Expected=17.8370
# Month=55, Predicted=18.0150, Expected=17.8560
# Month=56, Predicted=17.8602, Expected=17.5710
# Month=57, Predicted=17.3737, Expected=17.0780
# Month=58, Predicted=16.7411, Expected=16.6600
# Month=59, Predicted=16.3736, Expected=16.4330
# Month=60, Predicted=16.2744, Expected=16.5840
# Run 4 — RMSE: 0.505735, MSE: 0.255768, NMSE: 0.0019146656, Time: 129.1s
#
# ===== RUN 5/30 =====

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs) — IDENTICAL format to LSTM-SNP
# ============================================================

print('\n===== FINAL RESULTS — Autoformer on Monthly Lake Erie Levels (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
print(f'Avg training time: {np.mean(all_times):.1f}s ± {np.std(all_times):.1f}s')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Autoformer — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Autoformer — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')

# %% [markdown]
# ## Export Predictions

# %%
# ============================================================
# Save Predictions to CSV
# ============================================================

actual = raw_values[-60:]
results_df = pd.DataFrame({
    'Actual': actual,
    'Predicted_BestRun': all_predictions[best_idx],
})
for i in range(30):
    results_df[f'Predicted_Run_{i+1}'] = all_predictions[i]

csv_filename = 'Autoformer_LakeErie_predictions.csv'
results_df.to_csv(csv_filename, index=False)
print(f'Predictions saved to {csv_filename}')

# %% [markdown]
# ## Observations
#
# ### Autoformer on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with LSTM-SNP variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Compare training time with LSTM-SNP
# 5. **Model Size**: Note parameter count vs LSTM-SNP (~361 params)
#
# *After running all 5 model notebooks per dataset, perform cross-model comparison to evaluate
# whether Transformer architectures improve over LSTM-SNP for these time series datasets.*
