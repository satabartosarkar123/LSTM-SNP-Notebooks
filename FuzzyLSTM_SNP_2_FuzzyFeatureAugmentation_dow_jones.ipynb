# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 361 (1.41 KB)
#  Trainable params: 361 (1.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (290, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (230, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (230, 1, 2), y_train shape: (230,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    # Set consumption gate (c) bias to 1.0 (unit forget bias)
    rnn_layer = model.layers[1]
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, bias[units:2*units]
    weights[2] = bias
    cell.set_weights(weights)

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=3802.5458, Expected=3796.0000
# Month=2, Predicted=3796.3525, Expected=3793.0000
# Month=3, Predicted=3793.6854, Expected=3766.0000
# Month=4, Predicted=3762.7633, Expected=3747.0000
# Month=5, Predicted=3745.4638, Expected=3754.0000
# Month=6, Predicted=3750.0269, Expected=3756.0000
# Month=7, Predicted=3754.7094, Expected=3767.0000
# Month=8, Predicted=3768.0664, Expected=3751.0000
# Month=9, Predicted=3750.4739, Expected=3769.0000
# Month=10, Predicted=3770.5700, Expected=3760.0000
# Month=11, Predicted=3758.8628, Expected=3785.0000
# Month=12, Predicted=3786.7607, Expected=3776.0000
# Month=13, Predicted=3775.4194, Expected=3755.0000
# Month=14, Predicted=3755.8890, Expected=3755.0000
# Month=15, Predicted=3753.7249, Expected=3751.0000
# Month=16, Predicted=3748.5221, Expected=3776.0000
# Month=17, Predicted=3777.0442, Expected=3847.0000
# Month=18, Predicted=3855.0608, Expected=3830.0000
# Month=19, Predicted=3832.4732, Expected=3881.0000
# Month=20, Predicted=3885.7453, Expected=3899.0000
# Month=21, Predicted=3901.0995, Expected=3917.0000
# Month=22, Predicted=3915.9230, Expected=3913.0000
# Month=23, Predicted=3909.9225, Expected=3901.0000
# Month=24, Predicted=3898.9267, Expected=3886.0000
# Month=25, Predicted=3882.7378, Expected=3892.5000
# Month=26, Predicted=3889.5845, Expected=3899.0000
# Month=27, Predicted=3897.3808, Expected=3886.0000
# Month=28, Predicted=3884.8020, Expected=3908.0000
# Month=29, Predicted=3908.8132, Expected=3875.0000
# Month=30, Predicted=3871.4366, Expected=3860.0000
# Month=31, Predicted=3862.9865, Expected=3880.0000
# Month=32, Predicted=3877.1911, Expected=3895.0000
# Month=33, Predicted=3896.9706, Expected=3954.0000
# Month=34, Predicted=3959.5161, Expected=3933.0000
# Month=35, Predicted=3933.7442, Expected=3937.0000
# Month=36, Predicted=3942.3276, Expected=3869.0000
# Month=37, Predicted=3860.8641, Expected=3852.0000
# Month=38, Predicted=3856.0631, Expected=3837.0000
# Month=39, Predicted=3827.3307, Expected=3832.0000
# Month=40, Predicted=3829.1656, Expected=3849.0000
# Month=41, Predicted=3850.0701, Expected=3863.0000
# Month=42, Predicted=3866.4617, Expected=3878.0000
# Month=43, Predicted=3881.1839, Expected=3855.0000
# Month=44, Predicted=3854.8012, Expected=3843.0000
# Month=45, Predicted=3844.7953, Expected=3847.0000
# Month=46, Predicted=3844.1806, Expected=3801.0000
# Month=47, Predicted=3796.1836, Expected=3787.0000
# Month=48, Predicted=3789.1162, Expected=3776.0000
# Month=49, Predicted=3770.4267, Expected=3797.0000
# Month=50, Predicted=3797.3975, Expected=3821.0000
# Month=51, Predicted=3825.8358, Expected=3877.0000
# Month=52, Predicted=3884.1988, Expected=3875.0000
# Month=53, Predicted=3878.0949, Expected=3890.0000
# Month=54, Predicted=3892.4953, Expected=3910.0000
# Month=55, Predicted=3908.6250, Expected=3924.0000
# Month=56, Predicted=3922.9001, Expected=3918.0000
# Month=57, Predicted=3915.9700, Expected=3936.0000
# Month=58, Predicted=3935.3131, Expected=3911.0000
# Month=59, Predicted=3906.9202, Expected=3891.0000
# Month=60, Predicted=3891.9073, Expected=3855.0000
# Run 1 — RMSE: 24.522128, MSE: 601.334748, NMSE: 0.0027092724
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3801.5007, Expected=3796.0000
# Month=2, Predicted=3795.0248, Expected=3793.0000
# Month=3, Predicted=3793.1251, Expected=3766.0000
# Month=4, Predicted=3763.2719, Expected=3747.0000
# Month=5, Predicted=3745.2789, Expected=3754.0000
# Month=6, Predicted=3751.0664, Expected=3756.0000
# Month=7, Predicted=3755.7907, Expected=3767.0000
# Month=8, Predicted=3768.4525, Expected=3751.0000
# Month=9, Predicted=3750.2988, Expected=3769.0000
# Month=10, Predicted=3770.2010, Expected=3760.0000
# Month=11, Predicted=3758.4472, Expected=3785.0000
# Month=12, Predicted=3786.5188, Expected=3776.0000
# Month=13, Predicted=3774.9699, Expected=3755.0000
# Month=14, Predicted=3755.7209, Expected=3755.0000
# Month=15, Predicted=3754.1359, Expected=3751.0000
# Month=16, Predicted=3748.9447, Expected=3776.0000
# Month=17, Predicted=3777.6048, Expected=3847.0000
# Month=18, Predicted=3855.0866, Expected=3830.0000
# Month=19, Predicted=3829.7496, Expected=3881.0000
# Month=20, Predicted=3883.4326, Expected=3899.0000
# Month=21, Predicted=3900.4587, Expected=3917.0000
# Month=22, Predicted=3915.6588, Expected=3913.0000
# Month=23, Predicted=3910.5778, Expected=3901.0000
# Month=24, Predicted=3899.6527, Expected=3886.0000
# Month=25, Predicted=3883.8013, Expected=3892.5000
# Month=26, Predicted=3890.8348, Expected=3899.0000
# Month=27, Predicted=3898.7408, Expected=3886.0000
# Month=28, Predicted=3885.3616, Expected=3908.0000
# Month=29, Predicted=3909.2454, Expected=3875.0000
# Month=30, Predicted=3871.2351, Expected=3860.0000
# Month=31, Predicted=3862.5168, Expected=3880.0000
# Month=32, Predicted=3878.9869, Expected=3895.0000
# Month=33, Predicted=3897.7057, Expected=3954.0000
# Month=34, Predicted=3959.0939, Expected=3933.0000
# Month=35, Predicted=3932.0743, Expected=3937.0000
# Month=36, Predicted=3941.1095, Expected=3869.0000
# Month=37, Predicted=3862.4386, Expected=3852.0000
# Month=38, Predicted=3854.4081, Expected=3837.0000
# Month=39, Predicted=3828.5171, Expected=3832.0000
# Month=40, Predicted=3829.8063, Expected=3849.0000
# Month=41, Predicted=3851.1966, Expected=3863.0000
# Month=42, Predicted=3865.7270, Expected=3878.0000
# Month=43, Predicted=3879.6288, Expected=3855.0000
# Month=44, Predicted=3853.9305, Expected=3843.0000
# Month=45, Predicted=3844.0564, Expected=3847.0000
# Month=46, Predicted=3844.7163, Expected=3801.0000
# Month=47, Predicted=3795.4955, Expected=3787.0000
# Month=48, Predicted=3788.3483, Expected=3776.0000
# Month=49, Predicted=3771.1872, Expected=3797.0000
# Month=50, Predicted=3797.9841, Expected=3821.0000
# Month=51, Predicted=3825.4627, Expected=3877.0000
# Month=52, Predicted=3881.9699, Expected=3875.0000
# Month=53, Predicted=3875.0345, Expected=3890.0000
# Month=54, Predicted=3890.4482, Expected=3910.0000
# Month=55, Predicted=3908.5454, Expected=3924.0000
# Month=56, Predicted=3922.7491, Expected=3918.0000
# Month=57, Predicted=3916.2110, Expected=3936.0000
# Month=58, Predicted=3935.7424, Expected=3911.0000
# Month=59, Predicted=3907.5164, Expected=3891.0000
# Month=60, Predicted=3891.9360, Expected=3855.0000
# Run 2 — RMSE: 24.482420, MSE: 599.388881, NMSE: 0.0027103874
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3801.7415, Expected=3796.0000
# Month=2, Predicted=3797.6891, Expected=3793.0000
# Month=3, Predicted=3793.9282, Expected=3766.0000
# Month=4, Predicted=3764.4269, Expected=3747.0000
# Month=5, Predicted=3745.1616, Expected=3754.0000
# Month=6, Predicted=3751.4960, Expected=3756.0000
# Month=7, Predicted=3754.8181, Expected=3767.0000
# Month=8, Predicted=3768.0219, Expected=3751.0000
# Month=9, Predicted=3751.1998, Expected=3769.0000
# Month=10, Predicted=3770.2780, Expected=3760.0000
# Month=11, Predicted=3759.4586, Expected=3785.0000
# Month=12, Predicted=3786.4237, Expected=3776.0000
# Month=13, Predicted=3775.8962, Expected=3755.0000
# Month=14, Predicted=3755.0131, Expected=3755.0000
# Month=15, Predicted=3754.3119, Expected=3751.0000
# Month=16, Predicted=3749.4222, Expected=3776.0000
# Month=17, Predicted=3777.0103, Expected=3847.0000
# Month=18, Predicted=3853.1120, Expected=3830.0000
# Month=19, Predicted=3831.7834, Expected=3881.0000
# Month=20, Predicted=3883.8736, Expected=3899.0000
# Month=21, Predicted=3900.2812, Expected=3917.0000
# Month=22, Predicted=3917.9840, Expected=3913.0000
# Month=23, Predicted=3912.6985, Expected=3901.0000
# Month=24, Predicted=3900.0733, Expected=3886.0000
# Month=25, Predicted=3884.0393, Expected=3892.5000
# Month=26, Predicted=3890.7438, Expected=3899.0000
# Month=27, Predicted=3898.0465, Expected=3886.0000
# Month=28, Predicted=3885.6143, Expected=3908.0000
# Month=29, Predicted=3909.1983, Expected=3875.0000
# Month=30, Predicted=3873.1592, Expected=3860.0000
# Month=31, Predicted=3859.9488, Expected=3880.0000
# Month=32, Predicted=3878.8385, Expected=3895.0000
# Month=33, Predicted=3896.1946, Expected=3954.0000
# Month=34, Predicted=3959.3311, Expected=3933.0000
# Month=35, Predicted=3934.3906, Expected=3937.0000
# Month=36, Predicted=3938.8080, Expected=3869.0000
# Month=37, Predicted=3864.4523, Expected=3852.0000
# Month=38, Predicted=3849.7241, Expected=3837.0000
# Month=39, Predicted=3830.7004, Expected=3832.0000
# Month=40, Predicted=3830.5282, Expected=3849.0000
# Month=41, Predicted=3850.8551, Expected=3863.0000
# Month=42, Predicted=3866.2056, Expected=3878.0000
# Month=43, Predicted=3881.2709, Expected=3855.0000
# Month=44, Predicted=3855.6386, Expected=3843.0000
# Month=45, Predicted=3843.3236, Expected=3847.0000
# Month=46, Predicted=3845.5476, Expected=3801.0000
# Month=47, Predicted=3797.6272, Expected=3787.0000
# Month=48, Predicted=3785.8619, Expected=3776.0000
# Month=49, Predicted=3772.4681, Expected=3797.0000
# Month=50, Predicted=3797.5296, Expected=3821.0000
# Month=51, Predicted=3824.0688, Expected=3877.0000
# Month=52, Predicted=3882.8768, Expected=3875.0000
# Month=53, Predicted=3877.7214, Expected=3890.0000
# Month=54, Predicted=3891.8344, Expected=3910.0000
# Month=55, Predicted=3910.3422, Expected=3924.0000
# Month=56, Predicted=3924.1566, Expected=3918.0000
# Month=57, Predicted=3917.3034, Expected=3936.0000
# Month=58, Predicted=3935.7890, Expected=3911.0000
# Month=59, Predicted=3908.6697, Expected=3891.0000
# Month=60, Predicted=3889.7213, Expected=3855.0000
# Run 3 — RMSE: 24.375691, MSE: 594.174329, NMSE: 0.0026791312
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3801.5226, Expected=3796.0000
# Month=2, Predicted=3796.0295, Expected=3793.0000
# Month=3, Predicted=3793.0135, Expected=3766.0000
# Month=4, Predicted=3762.9943, Expected=3747.0000
# Month=5, Predicted=3745.7553, Expected=3754.0000
# Month=6, Predicted=3751.6095, Expected=3756.0000
# Month=7, Predicted=3755.8960, Expected=3767.0000
# Month=8, Predicted=3767.9941, Expected=3751.0000
# Month=9, Predicted=3750.4624, Expected=3769.0000
# Month=10, Predicted=3770.1366, Expected=3760.0000
# Month=11, Predicted=3759.3112, Expected=3785.0000
# Month=12, Predicted=3786.2109, Expected=3776.0000
# Month=13, Predicted=3775.8492, Expected=3755.0000
# Month=14, Predicted=3755.2673, Expected=3755.0000
# Month=15, Predicted=3753.9196, Expected=3751.0000
# Month=16, Predicted=3749.4909, Expected=3776.0000
# Month=17, Predicted=3777.2787, Expected=3847.0000
# Month=18, Predicted=3853.4744, Expected=3830.0000
# Month=19, Predicted=3832.0950, Expected=3881.0000
# Month=20, Predicted=3882.6943, Expected=3899.0000
# Month=21, Predicted=3903.6802, Expected=3917.0000
# Month=22, Predicted=3915.7538, Expected=3913.0000
# Month=23, Predicted=3911.4174, Expected=3901.0000
# Month=24, Predicted=3899.3633, Expected=3886.0000
# Month=25, Predicted=3883.3217, Expected=3892.5000
# Month=26, Predicted=3890.7794, Expected=3899.0000
# Month=27, Predicted=3898.4050, Expected=3886.0000
# Month=28, Predicted=3885.2156, Expected=3908.0000
# Month=29, Predicted=3908.7480, Expected=3875.0000
# Month=30, Predicted=3871.6833, Expected=3860.0000
# Month=31, Predicted=3861.8941, Expected=3880.0000
# Month=32, Predicted=3878.3888, Expected=3895.0000
# Month=33, Predicted=3897.2080, Expected=3954.0000
# Month=34, Predicted=3957.0505, Expected=3933.0000
# Month=35, Predicted=3933.9411, Expected=3937.0000
# Month=36, Predicted=3939.5292, Expected=3869.0000
# Month=37, Predicted=3858.9732, Expected=3852.0000
# Month=38, Predicted=3855.2385, Expected=3837.0000
# Month=39, Predicted=3829.9017, Expected=3832.0000
# Month=40, Predicted=3832.3650, Expected=3849.0000
# Month=41, Predicted=3850.9975, Expected=3863.0000
# Month=42, Predicted=3865.8012, Expected=3878.0000
# Month=43, Predicted=3879.8189, Expected=3855.0000
# Month=44, Predicted=3854.2838, Expected=3843.0000
# Month=45, Predicted=3843.8735, Expected=3847.0000
# Month=46, Predicted=3845.2892, Expected=3801.0000
# Month=47, Predicted=3797.3516, Expected=3787.0000
# Month=48, Predicted=3789.0492, Expected=3776.0000
# Month=49, Predicted=3772.2605, Expected=3797.0000
# Month=50, Predicted=3798.7985, Expected=3821.0000
# Month=51, Predicted=3825.1898, Expected=3877.0000
# Month=52, Predicted=3881.1164, Expected=3875.0000
# Month=53, Predicted=3877.7917, Expected=3890.0000
# Month=54, Predicted=3890.8391, Expected=3910.0000
# Month=55, Predicted=3910.3099, Expected=3924.0000
# Month=56, Predicted=3923.9084, Expected=3918.0000
# Month=57, Predicted=3916.7993, Expected=3936.0000
# Month=58, Predicted=3935.7594, Expected=3911.0000
# Month=59, Predicted=3907.8016, Expected=3891.0000
# Month=60, Predicted=3891.2449, Expected=3855.0000
# Run 4 — RMSE: 24.153881, MSE: 583.409970, NMSE: 0.0026480739
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3801.0365, Expected=3796.0000
# Month=2, Predicted=3797.7386, Expected=3793.0000
# Month=3, Predicted=3794.5938, Expected=3766.0000
# Month=4, Predicted=3764.8623, Expected=3747.0000
# Month=5, Predicted=3744.9371, Expected=3754.0000
# Month=6, Predicted=3749.9288, Expected=3756.0000
# Month=7, Predicted=3753.0653, Expected=3767.0000
# Month=8, Predicted=3767.1553, Expected=3751.0000
# Month=9, Predicted=3752.1333, Expected=3769.0000
# Month=10, Predicted=3772.0503, Expected=3760.0000
# Month=11, Predicted=3761.3279, Expected=3785.0000
# Month=12, Predicted=3787.5163, Expected=3776.0000
# Month=13, Predicted=3776.4844, Expected=3755.0000
# Month=14, Predicted=3755.4509, Expected=3755.0000
# Month=15, Predicted=3754.3904, Expected=3751.0000
# Month=16, Predicted=3748.6760, Expected=3776.0000
# Month=17, Predicted=3775.6554, Expected=3847.0000
# Month=18, Predicted=3850.8703, Expected=3830.0000
# Month=19, Predicted=3832.3823, Expected=3881.0000
# Month=20, Predicted=3885.3727, Expected=3899.0000
# Month=21, Predicted=3900.7494, Expected=3917.0000
# Month=22, Predicted=3917.6839, Expected=3913.0000
# Month=23, Predicted=3911.7166, Expected=3901.0000
# Month=24, Predicted=3898.7590, Expected=3886.0000
# Month=25, Predicted=3882.2344, Expected=3892.5000
# Month=26, Predicted=3888.4496, Expected=3899.0000
# Month=27, Predicted=3896.0834, Expected=3886.0000
# Month=28, Predicted=3885.0601, Expected=3908.0000
# Month=29, Predicted=3910.0291, Expected=3875.0000
# Month=30, Predicted=3875.3722, Expected=3860.0000
# Month=31, Predicted=3863.1233, Expected=3880.0000
# Month=32, Predicted=3880.9879, Expected=3895.0000
# Month=33, Predicted=3896.8053, Expected=3954.0000
# Month=34, Predicted=3958.4629, Expected=3933.0000
# Month=35, Predicted=3934.8607, Expected=3937.0000
# Month=36, Predicted=3940.3780, Expected=3869.0000
# Month=37, Predicted=3865.3320, Expected=3852.0000
# Month=38, Predicted=3851.6467, Expected=3837.0000
# Month=39, Predicted=3829.2319, Expected=3832.0000
# Month=40, Predicted=3827.8646, Expected=3849.0000
# Month=41, Predicted=3849.3903, Expected=3863.0000
# Month=42, Predicted=3866.7430, Expected=3878.0000
# Month=43, Predicted=3882.7196, Expected=3855.0000
# Month=44, Predicted=3857.6656, Expected=3843.0000
# Month=45, Predicted=3845.1534, Expected=3847.0000
# Month=46, Predicted=3845.5370, Expected=3801.0000
# Month=47, Predicted=3796.1113, Expected=3787.0000
# Month=48, Predicted=3784.3126, Expected=3776.0000
# Month=49, Predicted=3770.7057, Expected=3797.0000
# Month=50, Predicted=3795.6964, Expected=3821.0000
# Month=51, Predicted=3823.9764, Expected=3877.0000
# Month=52, Predicted=3883.0398, Expected=3875.0000
# Month=53, Predicted=3879.3463, Expected=3890.0000
# Month=54, Predicted=3893.7382, Expected=3910.0000
# Month=55, Predicted=3910.7258, Expected=3924.0000
# Month=56, Predicted=3922.6611, Expected=3918.0000
# Month=57, Predicted=3914.9205, Expected=3936.0000
# Month=58, Predicted=3933.2349, Expected=3911.0000
# Month=59, Predicted=3906.3009, Expected=3891.0000
# Month=60, Predicted=3888.6517, Expected=3855.0000
# Run 5 — RMSE: 24.467005, MSE: 598.634318, NMSE: 0.0026992204
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3802.1255, Expected=3796.0000
# Month=2, Predicted=3795.7638, Expected=3793.0000
# Month=3, Predicted=3794.4556, Expected=3766.0000
# Month=4, Predicted=3764.9806, Expected=3747.0000
# Month=5, Predicted=3746.3271, Expected=3754.0000
# Month=6, Predicted=3749.9615, Expected=3756.0000
# Month=7, Predicted=3753.5190, Expected=3767.0000
# Month=8, Predicted=3766.3874, Expected=3751.0000
# Month=9, Predicted=3749.8909, Expected=3769.0000
# Month=10, Predicted=3770.5009, Expected=3760.0000
# Month=11, Predicted=3759.5659, Expected=3785.0000
# Month=12, Predicted=3785.9880, Expected=3776.0000
# Month=13, Predicted=3775.7994, Expected=3755.0000
# Month=14, Predicted=3755.0765, Expected=3755.0000
# Month=15, Predicted=3754.6359, Expected=3751.0000
# Month=16, Predicted=3748.4973, Expected=3776.0000
# Month=17, Predicted=3775.7719, Expected=3847.0000
# Month=18, Predicted=3855.2520, Expected=3830.0000
# Month=19, Predicted=3832.3107, Expected=3881.0000
# Month=20, Predicted=3885.9708, Expected=3899.0000
# Month=21, Predicted=3904.7791, Expected=3917.0000
# Month=22, Predicted=3915.9115, Expected=3913.0000
# Month=23, Predicted=3911.4370, Expected=3901.0000
# Month=24, Predicted=3900.0787, Expected=3886.0000
# Month=25, Predicted=3883.9043, Expected=3892.5000
# Month=26, Predicted=3889.5330, Expected=3899.0000
# Month=27, Predicted=3896.5678, Expected=3886.0000
# Month=28, Predicted=3883.2533, Expected=3908.0000
# Month=29, Predicted=3908.1995, Expected=3875.0000
# Month=30, Predicted=3871.5395, Expected=3860.0000
# Month=31, Predicted=3862.5754, Expected=3880.0000
# Month=32, Predicted=3878.1108, Expected=3895.0000
# Month=33, Predicted=3896.4917, Expected=3954.0000
# Month=34, Predicted=3958.7171, Expected=3933.0000
# Month=35, Predicted=3934.0332, Expected=3937.0000
# Month=36, Predicted=3942.7812, Expected=3869.0000
# Month=37, Predicted=3864.6247, Expected=3852.0000
# Month=38, Predicted=3858.0189, Expected=3837.0000
# Month=39, Predicted=3827.9074, Expected=3832.0000
# Month=40, Predicted=3826.7647, Expected=3849.0000
# Month=41, Predicted=3848.7495, Expected=3863.0000
# Month=42, Predicted=3866.2742, Expected=3878.0000
# Month=43, Predicted=3881.2198, Expected=3855.0000
# Month=44, Predicted=3855.5426, Expected=3843.0000
# Month=45, Predicted=3846.1572, Expected=3847.0000
# Month=46, Predicted=3845.7863, Expected=3801.0000
# Month=47, Predicted=3795.4961, Expected=3787.0000
# Month=48, Predicted=3788.2840, Expected=3776.0000
# Month=49, Predicted=3770.3272, Expected=3797.0000
# Month=50, Predicted=3795.5601, Expected=3821.0000
# Month=51, Predicted=3825.3736, Expected=3877.0000
# Month=52, Predicted=3884.1510, Expected=3875.0000
# Month=53, Predicted=3878.9750, Expected=3890.0000
# Month=54, Predicted=3893.4132, Expected=3910.0000
# Month=55, Predicted=3912.1761, Expected=3924.0000
# Month=56, Predicted=3924.0047, Expected=3918.0000
# Month=57, Predicted=3916.1595, Expected=3936.0000
# Month=58, Predicted=3935.8450, Expected=3911.0000
# Month=59, Predicted=3907.3353, Expected=3891.0000
# Month=60, Predicted=3891.3986, Expected=3855.0000
# Run 6 — RMSE: 24.757424, MSE: 612.930056, NMSE: 0.0027342695
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3802.5563, Expected=3796.0000
# Month=2, Predicted=3797.6588, Expected=3793.0000
# Month=3, Predicted=3794.8327, Expected=3766.0000
# Month=4, Predicted=3764.4194, Expected=3747.0000
# Month=5, Predicted=3745.7145, Expected=3754.0000
# Month=6, Predicted=3750.3412, Expected=3756.0000
# Month=7, Predicted=3754.5786, Expected=3767.0000
# Month=8, Predicted=3767.4546, Expected=3751.0000
# Month=9, Predicted=3750.2875, Expected=3769.0000
# Month=10, Predicted=3769.7190, Expected=3760.0000
# Month=11, Predicted=3758.6727, Expected=3785.0000
# Month=12, Predicted=3785.9530, Expected=3776.0000
# Month=13, Predicted=3775.4942, Expected=3755.0000
# Month=14, Predicted=3755.6559, Expected=3755.0000
# Month=15, Predicted=3753.8340, Expected=3751.0000
# Month=16, Predicted=3748.3793, Expected=3776.0000
# Month=17, Predicted=3776.3405, Expected=3847.0000
# Month=18, Predicted=3854.8284, Expected=3830.0000
# Month=19, Predicted=3833.0965, Expected=3881.0000
# Month=20, Predicted=3885.9864, Expected=3899.0000
# Month=21, Predicted=3903.1728, Expected=3917.0000
# Month=22, Predicted=3919.0008, Expected=3913.0000
# Month=23, Predicted=3913.2601, Expected=3901.0000
# Month=24, Predicted=3900.9873, Expected=3886.0000
# Month=25, Predicted=3884.2104, Expected=3892.5000
# Month=26, Predicted=3890.3019, Expected=3899.0000
# Month=27, Predicted=3897.9015, Expected=3886.0000
# Month=28, Predicted=3885.1183, Expected=3908.0000
# Month=29, Predicted=3908.4609, Expected=3875.0000
# Month=30, Predicted=3871.8958, Expected=3860.0000
# Month=31, Predicted=3861.5996, Expected=3880.0000
# Month=32, Predicted=3877.2974, Expected=3895.0000
# Month=33, Predicted=3896.5162, Expected=3954.0000
# Month=34, Predicted=3959.0055, Expected=3933.0000
# Month=35, Predicted=3934.4714, Expected=3937.0000
# Month=36, Predicted=3942.0920, Expected=3869.0000
# Month=37, Predicted=3863.9503, Expected=3852.0000
# Month=38, Predicted=3854.3057, Expected=3837.0000
# Month=39, Predicted=3828.7526, Expected=3832.0000
# Month=40, Predicted=3829.0685, Expected=3849.0000
# Month=41, Predicted=3849.0997, Expected=3863.0000
# Month=42, Predicted=3864.8524, Expected=3878.0000
# Month=43, Predicted=3879.8969, Expected=3855.0000
# Month=44, Predicted=3854.8768, Expected=3843.0000
# Month=45, Predicted=3844.3501, Expected=3847.0000
# Month=46, Predicted=3844.2771, Expected=3801.0000
# Month=47, Predicted=3796.4285, Expected=3787.0000
# Month=48, Predicted=3787.4972, Expected=3776.0000
# Month=49, Predicted=3770.4071, Expected=3797.0000
# Month=50, Predicted=3796.2440, Expected=3821.0000
# Month=51, Predicted=3824.0746, Expected=3877.0000
# Month=52, Predicted=3882.6892, Expected=3875.0000
# Month=53, Predicted=3878.2933, Expected=3890.0000
# Month=54, Predicted=3893.4625, Expected=3910.0000
# Month=55, Predicted=3910.6458, Expected=3924.0000
# Month=56, Predicted=3924.8425, Expected=3918.0000
# Month=57, Predicted=3917.9527, Expected=3936.0000
# Month=58, Predicted=3936.3851, Expected=3911.0000
# Month=59, Predicted=3908.5537, Expected=3891.0000
# Month=60, Predicted=3891.4869, Expected=3855.0000
# Run 7 — RMSE: 24.625398, MSE: 606.410229, NMSE: 0.0026983691
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3802.8894, Expected=3796.0000
# Month=2, Predicted=3797.2005, Expected=3793.0000
# Month=3, Predicted=3794.8782, Expected=3766.0000
# Month=4, Predicted=3764.7957, Expected=3747.0000
# Month=5, Predicted=3746.4033, Expected=3754.0000
# Month=6, Predicted=3750.4605, Expected=3756.0000
# Month=7, Predicted=3755.2325, Expected=3767.0000
# Month=8, Predicted=3768.2233, Expected=3751.0000
# Month=9, Predicted=3750.4703, Expected=3769.0000
# Month=10, Predicted=3770.4491, Expected=3760.0000
# Month=11, Predicted=3758.9653, Expected=3785.0000
# Month=12, Predicted=3786.6943, Expected=3776.0000
# Month=13, Predicted=3775.7137, Expected=3755.0000
# Month=14, Predicted=3756.0050, Expected=3755.0000
# Month=15, Predicted=3754.2060, Expected=3751.0000
# Month=16, Predicted=3748.6856, Expected=3776.0000
# Month=17, Predicted=3777.0809, Expected=3847.0000
# Month=18, Predicted=3855.2632, Expected=3830.0000
# Month=19, Predicted=3833.1340, Expected=3881.0000
# Month=20, Predicted=3886.2799, Expected=3899.0000
# Month=21, Predicted=3904.1106, Expected=3917.0000
# Month=22, Predicted=3918.9570, Expected=3913.0000
# Month=23, Predicted=3913.4815, Expected=3901.0000
# Month=24, Predicted=3901.8046, Expected=3886.0000
# Month=25, Predicted=3885.1063, Expected=3892.5000
# Month=26, Predicted=3891.0548, Expected=3899.0000
# Month=27, Predicted=3898.5769, Expected=3886.0000
# Month=28, Predicted=3885.5963, Expected=3908.0000
# Month=29, Predicted=3909.1979, Expected=3875.0000
# Month=30, Predicted=3871.9891, Expected=3860.0000
# Month=31, Predicted=3862.5859, Expected=3880.0000
# Month=32, Predicted=3877.2109, Expected=3895.0000
# Month=33, Predicted=3897.2202, Expected=3954.0000
# Month=34, Predicted=3959.5777, Expected=3933.0000
# Month=35, Predicted=3934.2214, Expected=3937.0000
# Month=36, Predicted=3942.4955, Expected=3869.0000
# Month=37, Predicted=3863.3093, Expected=3852.0000
# Month=38, Predicted=3854.3486, Expected=3837.0000
# Month=39, Predicted=3826.6910, Expected=3832.0000
# Month=40, Predicted=3829.6613, Expected=3849.0000
# Month=41, Predicted=3850.4969, Expected=3863.0000
# Month=42, Predicted=3865.9107, Expected=3878.0000
# Month=43, Predicted=3880.2331, Expected=3855.0000
# Month=44, Predicted=3854.5451, Expected=3843.0000
# Month=45, Predicted=3845.1145, Expected=3847.0000
# Month=46, Predicted=3844.5829, Expected=3801.0000
# Month=47, Predicted=3796.3175, Expected=3787.0000
# Month=48, Predicted=3787.9123, Expected=3776.0000
# Month=49, Predicted=3769.5893, Expected=3797.0000
# Month=50, Predicted=3796.9314, Expected=3821.0000
# Month=51, Predicted=3825.0308, Expected=3877.0000
# Month=52, Predicted=3883.0409, Expected=3875.0000
# Month=53, Predicted=3877.8127, Expected=3890.0000
# Month=54, Predicted=3893.0984, Expected=3910.0000
# Month=55, Predicted=3911.1098, Expected=3924.0000
# Month=56, Predicted=3925.3004, Expected=3918.0000
# Month=57, Predicted=3918.2549, Expected=3936.0000
# Month=58, Predicted=3937.3027, Expected=3911.0000
# Month=59, Predicted=3908.9427, Expected=3891.0000
# Month=60, Predicted=3892.5328, Expected=3855.0000
# Run 8 — RMSE: 24.607010, MSE: 605.504948, NMSE: 0.0026903541
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3801.8711, Expected=3796.0000
# Month=2, Predicted=3797.2422, Expected=3793.0000
# Month=3, Predicted=3793.8504, Expected=3766.0000
# Month=4, Predicted=3764.2437, Expected=3747.0000
# Month=5, Predicted=3745.5376, Expected=3754.0000
# Month=6, Predicted=3751.7372, Expected=3756.0000
# Month=7, Predicted=3754.9147, Expected=3767.0000
# Month=8, Predicted=3767.6334, Expected=3751.0000
# Month=9, Predicted=3750.4591, Expected=3769.0000
# Month=10, Predicted=3769.9281, Expected=3760.0000
# Month=11, Predicted=3759.3071, Expected=3785.0000
# Month=12, Predicted=3786.4514, Expected=3776.0000
# Month=13, Predicted=3775.7668, Expected=3755.0000
# Month=14, Predicted=3755.0450, Expected=3755.0000
# Month=15, Predicted=3754.3117, Expected=3751.0000
# Month=16, Predicted=3749.4992, Expected=3776.0000
# Month=17, Predicted=3776.9383, Expected=3847.0000
# Month=18, Predicted=3853.5148, Expected=3830.0000
# Month=19, Predicted=3831.6361, Expected=3881.0000
# Month=20, Predicted=3884.9205, Expected=3899.0000
# Month=21, Predicted=3900.9584, Expected=3917.0000
# Month=22, Predicted=3917.9304, Expected=3913.0000
# Month=23, Predicted=3912.0934, Expected=3901.0000
# Month=24, Predicted=3899.7464, Expected=3886.0000
# Month=25, Predicted=3883.8661, Expected=3892.5000
# Month=26, Predicted=3890.6796, Expected=3899.0000
# Month=27, Predicted=3897.8758, Expected=3886.0000
# Month=28, Predicted=3884.8586, Expected=3908.0000
# Month=29, Predicted=3908.5587, Expected=3875.0000
# Month=30, Predicted=3872.1648, Expected=3860.0000
# Month=31, Predicted=3860.4136, Expected=3880.0000
# Month=32, Predicted=3878.8382, Expected=3895.0000
# Month=33, Predicted=3895.9804, Expected=3954.0000
# Month=34, Predicted=3958.7901, Expected=3933.0000
# Month=35, Predicted=3933.6065, Expected=3937.0000
# Month=36, Predicted=3939.5712, Expected=3869.0000
# Month=37, Predicted=3864.0579, Expected=3852.0000
# Month=38, Predicted=3853.1575, Expected=3837.0000
# Month=39, Predicted=3831.4788, Expected=3832.0000
# Month=40, Predicted=3829.4971, Expected=3849.0000
# Month=41, Predicted=3849.1276, Expected=3863.0000
# Month=42, Predicted=3864.8861, Expected=3878.0000
# Month=43, Predicted=3880.3250, Expected=3855.0000
# Month=44, Predicted=3854.9579, Expected=3843.0000
# Month=45, Predicted=3843.6632, Expected=3847.0000
# Month=46, Predicted=3845.9143, Expected=3801.0000
# Month=47, Predicted=3797.4226, Expected=3787.0000
# Month=48, Predicted=3786.9578, Expected=3776.0000
# Month=49, Predicted=3772.6714, Expected=3797.0000
# Month=50, Predicted=3796.8674, Expected=3821.0000
# Month=51, Predicted=3823.8576, Expected=3877.0000
# Month=52, Predicted=3882.9831, Expected=3875.0000
# Month=53, Predicted=3878.1160, Expected=3890.0000
# Month=54, Predicted=3892.6297, Expected=3910.0000
# Month=55, Predicted=3911.0991, Expected=3924.0000
# Month=56, Predicted=3924.6923, Expected=3918.0000
# Month=57, Predicted=3917.5006, Expected=3936.0000
# Month=58, Predicted=3936.3702, Expected=3911.0000
# Month=59, Predicted=3908.4157, Expected=3891.0000
# Month=60, Predicted=3890.4817, Expected=3855.0000
# Run 9 — RMSE: 24.462350, MSE: 598.406552, NMSE: 0.0026960460
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3802.4859, Expected=3796.0000
# Month=2, Predicted=3798.3270, Expected=3793.0000
# Month=3, Predicted=3794.1257, Expected=3766.0000
# Month=4, Predicted=3762.9899, Expected=3747.0000
# Month=5, Predicted=3742.9493, Expected=3754.0000
# Month=6, Predicted=3747.9963, Expected=3756.0000
# Month=7, Predicted=3753.1800, Expected=3767.0000
# Month=8, Predicted=3768.7399, Expected=3751.0000
# Month=9, Predicted=3754.1410, Expected=3769.0000
# Month=10, Predicted=3773.8929, Expected=3760.0000
# Month=11, Predicted=3762.0748, Expected=3785.0000
# Month=12, Predicted=3788.2264, Expected=3776.0000
# Month=13, Predicted=3776.6362, Expected=3755.0000
# Month=14, Predicted=3755.4731, Expected=3755.0000
# Month=15, Predicted=3753.9934, Expected=3751.0000
# Month=16, Predicted=3747.6841, Expected=3776.0000
# Month=17, Predicted=3775.7533, Expected=3847.0000
# Month=18, Predicted=3852.4309, Expected=3830.0000
# Month=19, Predicted=3834.7166, Expected=3881.0000
# Month=20, Predicted=3884.4064, Expected=3899.0000
# Month=21, Predicted=3898.8424, Expected=3917.0000
# Month=22, Predicted=3914.8198, Expected=3913.0000
# Month=23, Predicted=3909.3487, Expected=3901.0000
# Month=24, Predicted=3896.7731, Expected=3886.0000
# Month=25, Predicted=3881.0779, Expected=3892.5000
# Month=26, Predicted=3888.9226, Expected=3899.0000
# Month=27, Predicted=3898.4825, Expected=3886.0000
# Month=28, Predicted=3888.4425, Expected=3908.0000
# Month=29, Predicted=3913.3090, Expected=3875.0000
# Month=30, Predicted=3877.5805, Expected=3860.0000
# Month=31, Predicted=3865.3293, Expected=3880.0000
# Month=32, Predicted=3880.6538, Expected=3895.0000
# Month=33, Predicted=3896.9517, Expected=3954.0000
# Month=34, Predicted=3959.0691, Expected=3933.0000
# Month=35, Predicted=3936.0062, Expected=3937.0000
# Month=36, Predicted=3939.7920, Expected=3869.0000
# Month=37, Predicted=3861.3714, Expected=3852.0000
# Month=38, Predicted=3848.5141, Expected=3837.0000
# Month=39, Predicted=3823.1835, Expected=3832.0000
# Month=40, Predicted=3826.3569, Expected=3849.0000
# Month=41, Predicted=3851.4262, Expected=3863.0000
# Month=42, Predicted=3870.5855, Expected=3878.0000
# Month=43, Predicted=3886.5080, Expected=3855.0000
# Month=44, Predicted=3860.9871, Expected=3843.0000
# Month=45, Predicted=3848.3939, Expected=3847.0000
# Month=46, Predicted=3846.1452, Expected=3801.0000
# Month=47, Predicted=3795.6958, Expected=3787.0000
# Month=48, Predicted=3784.4408, Expected=3776.0000
# Month=49, Predicted=3768.2811, Expected=3797.0000
# Month=50, Predicted=3795.1189, Expected=3821.0000
# Month=51, Predicted=3825.1489, Expected=3877.0000
# Month=52, Predicted=3884.4554, Expected=3875.0000
# Month=53, Predicted=3880.8150, Expected=3890.0000
# Month=54, Predicted=3893.5449, Expected=3910.0000
# Month=55, Predicted=3909.1501, Expected=3924.0000
# Month=56, Predicted=3921.1860, Expected=3918.0000
# Month=57, Predicted=3913.7597, Expected=3936.0000
# Month=58, Predicted=3932.3510, Expected=3911.0000
# Month=59, Predicted=3905.8822, Expected=3891.0000
# Month=60, Predicted=3888.3199, Expected=3855.0000
# Run 10 — RMSE: 24.558857, MSE: 603.137438, NMSE: 0.0027113733
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3803.5952, Expected=3796.0000
# Month=2, Predicted=3796.4093, Expected=3793.0000
# Month=3, Predicted=3793.9238, Expected=3766.0000
# Month=4, Predicted=3764.6457, Expected=3747.0000
# Month=5, Predicted=3745.5915, Expected=3754.0000
# Month=6, Predicted=3747.8199, Expected=3756.0000
# Month=7, Predicted=3752.9313, Expected=3767.0000
# Month=8, Predicted=3768.2960, Expected=3751.0000
# Month=9, Predicted=3752.3659, Expected=3769.0000
# Month=10, Predicted=3772.0081, Expected=3760.0000
# Month=11, Predicted=3760.0802, Expected=3785.0000
# Month=12, Predicted=3786.6434, Expected=3776.0000
# Month=13, Predicted=3775.6206, Expected=3755.0000
# Month=14, Predicted=3755.5955, Expected=3755.0000
# Month=15, Predicted=3754.6023, Expected=3751.0000
# Month=16, Predicted=3747.6530, Expected=3776.0000
# Month=17, Predicted=3776.2333, Expected=3847.0000
# Month=18, Predicted=3857.3882, Expected=3830.0000
# Month=19, Predicted=3833.2544, Expected=3881.0000
# Month=20, Predicted=3883.9179, Expected=3899.0000
# Month=21, Predicted=3899.9167, Expected=3917.0000
# Month=22, Predicted=3914.9998, Expected=3913.0000
# Month=23, Predicted=3910.2179, Expected=3901.0000
# Month=24, Predicted=3899.1828, Expected=3886.0000
# Month=25, Predicted=3882.5669, Expected=3892.5000
# Month=26, Predicted=3888.0742, Expected=3899.0000
# Month=27, Predicted=3896.8332, Expected=3886.0000
# Month=28, Predicted=3885.5029, Expected=3908.0000
# Month=29, Predicted=3910.1391, Expected=3875.0000
# Month=30, Predicted=3873.5813, Expected=3860.0000
# Month=31, Predicted=3863.5928, Expected=3880.0000
# Month=32, Predicted=3877.9997, Expected=3895.0000
# Month=33, Predicted=3897.2950, Expected=3954.0000
# Month=34, Predicted=3960.9582, Expected=3933.0000
# Month=35, Predicted=3934.4022, Expected=3937.0000
# Month=36, Predicted=3941.9475, Expected=3869.0000
# Month=37, Predicted=3865.6522, Expected=3852.0000
# Month=38, Predicted=3855.5005, Expected=3837.0000
# Month=39, Predicted=3822.0925, Expected=3832.0000
# Month=40, Predicted=3824.1319, Expected=3849.0000
# Month=41, Predicted=3850.6441, Expected=3863.0000
# Month=42, Predicted=3870.2014, Expected=3878.0000
# Month=43, Predicted=3883.4986, Expected=3855.0000
# Month=44, Predicted=3856.4707, Expected=3843.0000
# Month=45, Predicted=3847.2251, Expected=3847.0000
# Month=46, Predicted=3845.0836, Expected=3801.0000
# Month=47, Predicted=3794.9890, Expected=3787.0000
# Month=48, Predicted=3786.1043, Expected=3776.0000
# Month=49, Predicted=3767.7413, Expected=3797.0000
# Month=50, Predicted=3795.7074, Expected=3821.0000
# Month=51, Predicted=3828.2385, Expected=3877.0000
# Month=52, Predicted=3886.3340, Expected=3875.0000
# Month=53, Predicted=3877.5501, Expected=3890.0000
# Month=54, Predicted=3890.9218, Expected=3910.0000
# Month=55, Predicted=3908.4543, Expected=3924.0000
# Month=56, Predicted=3921.7073, Expected=3918.0000
# Month=57, Predicted=3915.0704, Expected=3936.0000
# Month=58, Predicted=3934.5266, Expected=3911.0000
# Month=59, Predicted=3906.5477, Expected=3891.0000
# Month=60, Predicted=3890.1993, Expected=3855.0000
# Run 11 — RMSE: 24.821538, MSE: 616.108766, NMSE: 0.0027611923
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3801.0356, Expected=3796.0000
# Month=2, Predicted=3794.7488, Expected=3793.0000
# Month=3, Predicted=3794.0317, Expected=3766.0000
# Month=4, Predicted=3766.4365, Expected=3747.0000
# Month=5, Predicted=3746.7346, Expected=3754.0000
# Month=6, Predicted=3747.0941, Expected=3756.0000
# Month=7, Predicted=3753.0142, Expected=3767.0000
# Month=8, Predicted=3767.1691, Expected=3751.0000
# Month=9, Predicted=3751.0324, Expected=3769.0000
# Month=10, Predicted=3772.1463, Expected=3760.0000
# Month=11, Predicted=3760.2660, Expected=3785.0000
# Month=12, Predicted=3786.8763, Expected=3776.0000
# Month=13, Predicted=3775.0222, Expected=3755.0000
# Month=14, Predicted=3756.6388, Expected=3755.0000
# Month=15, Predicted=3755.6383, Expected=3751.0000
# Month=16, Predicted=3748.6681, Expected=3776.0000
# Month=17, Predicted=3776.2310, Expected=3847.0000
# Month=18, Predicted=3854.2616, Expected=3830.0000
# Month=19, Predicted=3830.2342, Expected=3881.0000
# Month=20, Predicted=3883.4470, Expected=3899.0000
# Month=21, Predicted=3900.4493, Expected=3917.0000
# Month=22, Predicted=3915.1914, Expected=3913.0000
# Month=23, Predicted=3910.9607, Expected=3901.0000
# Month=24, Predicted=3901.7896, Expected=3886.0000
# Month=25, Predicted=3886.0940, Expected=3892.5000
# Month=26, Predicted=3890.2605, Expected=3899.0000
# Month=27, Predicted=3896.5498, Expected=3886.0000
# Month=28, Predicted=3884.6568, Expected=3908.0000
# Month=29, Predicted=3909.9371, Expected=3875.0000
# Month=30, Predicted=3873.1210, Expected=3860.0000
# Month=31, Predicted=3863.0172, Expected=3880.0000
# Month=32, Predicted=3880.1453, Expected=3895.0000
# Month=33, Predicted=3896.2626, Expected=3954.0000
# Month=34, Predicted=3957.8347, Expected=3933.0000
# Month=35, Predicted=3932.3684, Expected=3937.0000
# Month=36, Predicted=3942.2556, Expected=3869.0000
# Month=37, Predicted=3865.8888, Expected=3852.0000
# Month=38, Predicted=3844.7733, Expected=3837.0000
# Month=39, Predicted=3812.0157, Expected=3832.0000
# Month=40, Predicted=3815.6229, Expected=3849.0000
# Month=41, Predicted=3847.2473, Expected=3863.0000
# Month=42, Predicted=3869.0462, Expected=3878.0000
# Month=43, Predicted=3882.0272, Expected=3855.0000
# Month=44, Predicted=3854.8025, Expected=3843.0000
# Month=45, Predicted=3846.9940, Expected=3847.0000
# Month=46, Predicted=3847.2310, Expected=3801.0000
# Month=47, Predicted=3794.8348, Expected=3787.0000
# Month=48, Predicted=3773.5526, Expected=3776.0000
# Month=49, Predicted=3754.3002, Expected=3797.0000
# Month=50, Predicted=3788.9772, Expected=3821.0000
# Month=51, Predicted=3828.2689, Expected=3877.0000
# Month=52, Predicted=3886.2945, Expected=3875.0000
# Month=53, Predicted=3877.9259, Expected=3890.0000
# Month=54, Predicted=3888.5738, Expected=3910.0000
# Month=55, Predicted=3908.6548, Expected=3924.0000
# Month=56, Predicted=3921.8318, Expected=3918.0000
# Month=57, Predicted=3915.6819, Expected=3936.0000
# Month=58, Predicted=3935.7961, Expected=3911.0000
# Month=59, Predicted=3906.3811, Expected=3891.0000
# Month=60, Predicted=3886.5929, Expected=3855.0000
# Run 12 — RMSE: 25.445504, MSE: 647.473691, NMSE: 0.0028400249
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3800.7895, Expected=3796.0000
# Month=2, Predicted=3797.0958, Expected=3793.0000
# Month=3, Predicted=3793.4972, Expected=3766.0000
# Month=4, Predicted=3763.9209, Expected=3747.0000
# Month=5, Predicted=3745.4888, Expected=3754.0000
# Month=6, Predicted=3751.7730, Expected=3756.0000
# Month=7, Predicted=3755.0954, Expected=3767.0000
# Month=8, Predicted=3768.2512, Expected=3751.0000
# Month=9, Predicted=3751.7722, Expected=3769.0000
# Month=10, Predicted=3770.8230, Expected=3760.0000
# Month=11, Predicted=3759.9558, Expected=3785.0000
# Month=12, Predicted=3786.5982, Expected=3776.0000
# Month=13, Predicted=3776.1489, Expected=3755.0000
# Month=14, Predicted=3755.5011, Expected=3755.0000
# Month=15, Predicted=3754.9535, Expected=3751.0000
# Month=16, Predicted=3749.8223, Expected=3776.0000
# Month=17, Predicted=3777.0312, Expected=3847.0000
# Month=18, Predicted=3851.5336, Expected=3830.0000
# Month=19, Predicted=3832.4522, Expected=3881.0000
# Month=20, Predicted=3883.6193, Expected=3899.0000
# Month=21, Predicted=3898.8066, Expected=3917.0000
# Month=22, Predicted=3915.2694, Expected=3913.0000
# Month=23, Predicted=3909.9872, Expected=3901.0000
# Month=24, Predicted=3898.1335, Expected=3886.0000
# Month=25, Predicted=3882.8826, Expected=3892.5000
# Month=26, Predicted=3890.0423, Expected=3899.0000
# Month=27, Predicted=3897.2737, Expected=3886.0000
# Month=28, Predicted=3885.1767, Expected=3908.0000
# Month=29, Predicted=3908.9384, Expected=3875.0000
# Month=30, Predicted=3873.1687, Expected=3860.0000
# Month=31, Predicted=3860.9981, Expected=3880.0000
# Month=32, Predicted=3879.4249, Expected=3895.0000
# Month=33, Predicted=3896.3398, Expected=3954.0000
# Month=34, Predicted=3958.0941, Expected=3933.0000
# Month=35, Predicted=3934.8698, Expected=3937.0000
# Month=36, Predicted=3939.4931, Expected=3869.0000
# Month=37, Predicted=3864.1014, Expected=3852.0000
# Month=38, Predicted=3853.2609, Expected=3837.0000
# Month=39, Predicted=3831.7746, Expected=3832.0000
# Month=40, Predicted=3830.6055, Expected=3849.0000
# Month=41, Predicted=3851.0568, Expected=3863.0000
# Month=42, Predicted=3867.2437, Expected=3878.0000
# Month=43, Predicted=3882.4013, Expected=3855.0000
# Month=44, Predicted=3856.9891, Expected=3843.0000
# Month=45, Predicted=3844.8189, Expected=3847.0000
# Month=46, Predicted=3846.5658, Expected=3801.0000
# Month=47, Predicted=3798.4031, Expected=3787.0000
# Month=48, Predicted=3787.5669, Expected=3776.0000
# Month=49, Predicted=3773.7729, Expected=3797.0000
# Month=50, Predicted=3798.1353, Expected=3821.0000
# Month=51, Predicted=3825.3768, Expected=3877.0000
# Month=52, Predicted=3883.2990, Expected=3875.0000
# Month=53, Predicted=3879.0979, Expected=3890.0000
# Month=54, Predicted=3892.3633, Expected=3910.0000
# Month=55, Predicted=3909.5443, Expected=3924.0000
# Month=56, Predicted=3922.4856, Expected=3918.0000
# Month=57, Predicted=3915.8046, Expected=3936.0000
# Month=58, Predicted=3934.7309, Expected=3911.0000
# Month=59, Predicted=3907.4106, Expected=3891.0000
# Month=60, Predicted=3890.0583, Expected=3855.0000
# Run 13 — RMSE: 24.266538, MSE: 588.864888, NMSE: 0.0026934019
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3800.7399, Expected=3796.0000
# Month=2, Predicted=3797.1164, Expected=3793.0000
# Month=3, Predicted=3793.8109, Expected=3766.0000
# Month=4, Predicted=3764.7669, Expected=3747.0000
# Month=5, Predicted=3746.1618, Expected=3754.0000
# Month=6, Predicted=3751.6683, Expected=3756.0000
# Month=7, Predicted=3754.7069, Expected=3767.0000
# Month=8, Predicted=3767.6102, Expected=3751.0000
# Month=9, Predicted=3750.8737, Expected=3769.0000
# Month=10, Predicted=3770.0397, Expected=3760.0000
# Month=11, Predicted=3759.3731, Expected=3785.0000
# Month=12, Predicted=3786.2262, Expected=3776.0000
# Month=13, Predicted=3775.8646, Expected=3755.0000
# Month=14, Predicted=3755.3712, Expected=3755.0000
# Month=15, Predicted=3754.5571, Expected=3751.0000
# Month=16, Predicted=3749.3328, Expected=3776.0000
# Month=17, Predicted=3776.5284, Expected=3847.0000
# Month=18, Predicted=3851.0798, Expected=3830.0000
# Month=19, Predicted=3832.5531, Expected=3881.0000
# Month=20, Predicted=3884.1369, Expected=3899.0000
# Month=21, Predicted=3900.5467, Expected=3917.0000
# Month=22, Predicted=3917.4976, Expected=3913.0000
# Month=23, Predicted=3912.2232, Expected=3901.0000
# Month=24, Predicted=3900.2339, Expected=3886.0000
# Month=25, Predicted=3884.5308, Expected=3892.5000
# Month=26, Predicted=3890.9353, Expected=3899.0000
# Month=27, Predicted=3897.7203, Expected=3886.0000
# Month=28, Predicted=3885.2324, Expected=3908.0000
# Month=29, Predicted=3908.5418, Expected=3875.0000
# Month=30, Predicted=3872.9061, Expected=3860.0000
# Month=31, Predicted=3860.7135, Expected=3880.0000
# Month=32, Predicted=3878.2616, Expected=3895.0000
# Month=33, Predicted=3895.6933, Expected=3954.0000
# Month=34, Predicted=3957.5505, Expected=3933.0000
# Month=35, Predicted=3934.5615, Expected=3937.0000
# Month=36, Predicted=3939.6968, Expected=3869.0000
# Month=37, Predicted=3864.9306, Expected=3852.0000
# Month=38, Predicted=3853.6612, Expected=3837.0000
# Month=39, Predicted=3830.5491, Expected=3832.0000
# Month=40, Predicted=3829.4963, Expected=3849.0000
# Month=41, Predicted=3849.4819, Expected=3863.0000
# Month=42, Predicted=3865.3549, Expected=3878.0000
# Month=43, Predicted=3880.6883, Expected=3855.0000
# Month=44, Predicted=3855.6941, Expected=3843.0000
# Month=45, Predicted=3844.1934, Expected=3847.0000
# Month=46, Predicted=3845.8820, Expected=3801.0000
# Month=47, Predicted=3797.9981, Expected=3787.0000
# Month=48, Predicted=3787.1841, Expected=3776.0000
# Month=49, Predicted=3772.0036, Expected=3797.0000
# Month=50, Predicted=3796.6578, Expected=3821.0000
# Month=51, Predicted=3823.6181, Expected=3877.0000
# Month=52, Predicted=3881.7589, Expected=3875.0000
# Month=53, Predicted=3878.1669, Expected=3890.0000
# Month=54, Predicted=3892.2805, Expected=3910.0000
# Month=55, Predicted=3910.4653, Expected=3924.0000
# Month=56, Predicted=3924.2232, Expected=3918.0000
# Month=57, Predicted=3917.4944, Expected=3936.0000
# Month=58, Predicted=3936.0452, Expected=3911.0000
# Month=59, Predicted=3908.9189, Expected=3891.0000
# Month=60, Predicted=3890.9076, Expected=3855.0000
# Run 14 — RMSE: 24.476603, MSE: 599.104083, NMSE: 0.0027038447
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3802.3720, Expected=3796.0000
# Month=2, Predicted=3797.1963, Expected=3793.0000
# Month=3, Predicted=3794.7460, Expected=3766.0000
# Month=4, Predicted=3763.2516, Expected=3747.0000
# Month=5, Predicted=3744.9203, Expected=3754.0000
# Month=6, Predicted=3749.2712, Expected=3756.0000
# Month=7, Predicted=3753.6323, Expected=3767.0000
# Month=8, Predicted=3767.3426, Expected=3751.0000
# Month=9, Predicted=3750.3355, Expected=3769.0000
# Month=10, Predicted=3770.2612, Expected=3760.0000
# Month=11, Predicted=3758.8897, Expected=3785.0000
# Month=12, Predicted=3786.1514, Expected=3776.0000
# Month=13, Predicted=3775.6319, Expected=3755.0000
# Month=14, Predicted=3755.5078, Expected=3755.0000
# Month=15, Predicted=3753.5866, Expected=3751.0000
# Month=16, Predicted=3747.8794, Expected=3776.0000
# Month=17, Predicted=3776.1844, Expected=3847.0000
# Month=18, Predicted=3855.3505, Expected=3830.0000
# Month=19, Predicted=3833.1016, Expected=3881.0000
# Month=20, Predicted=3887.0791, Expected=3899.0000
# Month=21, Predicted=3904.7741, Expected=3917.0000
# Month=22, Predicted=3917.5966, Expected=3913.0000
# Month=23, Predicted=3912.0752, Expected=3901.0000
# Month=24, Predicted=3900.0664, Expected=3886.0000
# Month=25, Predicted=3882.9436, Expected=3892.5000
# Month=26, Predicted=3889.0717, Expected=3899.0000
# Month=27, Predicted=3896.5102, Expected=3886.0000
# Month=28, Predicted=3884.2193, Expected=3908.0000
# Month=29, Predicted=3908.6063, Expected=3875.0000
# Month=30, Predicted=3870.9969, Expected=3860.0000
# Month=31, Predicted=3862.3540, Expected=3880.0000
# Month=32, Predicted=3876.8629, Expected=3895.0000
# Month=33, Predicted=3895.8067, Expected=3954.0000
# Month=34, Predicted=3958.9890, Expected=3933.0000
# Month=35, Predicted=3934.6414, Expected=3937.0000
# Month=36, Predicted=3942.4691, Expected=3869.0000
# Month=37, Predicted=3861.0462, Expected=3852.0000
# Month=38, Predicted=3856.1130, Expected=3837.0000
# Month=39, Predicted=3827.1402, Expected=3832.0000
# Month=40, Predicted=3828.0853, Expected=3849.0000
# Month=41, Predicted=3849.4283, Expected=3863.0000
# Month=42, Predicted=3866.0431, Expected=3878.0000
# Month=43, Predicted=3880.9488, Expected=3855.0000
# Month=44, Predicted=3854.9281, Expected=3843.0000
# Month=45, Predicted=3844.3443, Expected=3847.0000
# Month=46, Predicted=3844.1636, Expected=3801.0000
# Month=47, Predicted=3795.4222, Expected=3787.0000
# Month=48, Predicted=3789.2329, Expected=3776.0000
# Month=49, Predicted=3770.7424, Expected=3797.0000
# Month=50, Predicted=3796.3839, Expected=3821.0000
# Month=51, Predicted=3825.3384, Expected=3877.0000
# Month=52, Predicted=3884.1951, Expected=3875.0000
# Month=53, Predicted=3879.6499, Expected=3890.0000
# Month=54, Predicted=3893.7455, Expected=3910.0000
# Month=55, Predicted=3911.2591, Expected=3924.0000
# Month=56, Predicted=3924.1417, Expected=3918.0000
# Month=57, Predicted=3917.0740, Expected=3936.0000
# Month=58, Predicted=3936.3351, Expected=3911.0000
# Month=59, Predicted=3907.1840, Expected=3891.0000
# Month=60, Predicted=3891.8998, Expected=3855.0000
# Run 15 — RMSE: 24.631177, MSE: 606.694891, NMSE: 0.0026983621
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3802.3853, Expected=3796.0000
# Month=2, Predicted=3797.0404, Expected=3793.0000
# Month=3, Predicted=3794.3317, Expected=3766.0000
# Month=4, Predicted=3763.4718, Expected=3747.0000
# Month=5, Predicted=3744.5741, Expected=3754.0000
# Month=6, Predicted=3749.2562, Expected=3756.0000
# Month=7, Predicted=3754.7426, Expected=3767.0000
# Month=8, Predicted=3769.0789, Expected=3751.0000
# Month=9, Predicted=3751.9761, Expected=3769.0000
# Month=10, Predicted=3771.3682, Expected=3760.0000
# Month=11, Predicted=3758.9909, Expected=3785.0000
# Month=12, Predicted=3786.5830, Expected=3776.0000
# Month=13, Predicted=3775.2831, Expected=3755.0000
# Month=14, Predicted=3755.8223, Expected=3755.0000
# Month=15, Predicted=3754.0674, Expected=3751.0000
# Month=16, Predicted=3748.2094, Expected=3776.0000
# Month=17, Predicted=3777.1077, Expected=3847.0000
# Month=18, Predicted=3854.7574, Expected=3830.0000
# Month=19, Predicted=3832.5171, Expected=3881.0000
# Month=20, Predicted=3885.0620, Expected=3899.0000
# Month=21, Predicted=3899.0022, Expected=3917.0000
# Month=22, Predicted=3916.0292, Expected=3913.0000
# Month=23, Predicted=3910.5655, Expected=3901.0000
# ...
# Month=53, Predicted=3877.0772, Expected=3890.0000
# Month=54, Predicted=3891.2718, Expected=3910.0000
# Month=55, Predicted=3910.4295, Expected=3924.0000
# Month=56, Predicted=3924.4155, Expected=3918.0000
# Month=57, Predicted=3917.4216, Expected=3936.0000
# Month=58, Predicted=3936.3114, Expected=3911.0000
# Month=59, Predicted=3909.0527, Expected=3891.0000
# Month=60, Predicted=3891.2000, Expected=3855.0000
# Run 25 — RMSE: 24.446705, MSE: 597.641393, NMSE: 0.0026955207
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3801.7901, Expected=3796.0000
# Month=2, Predicted=3796.3424, Expected=3793.0000
# Month=3, Predicted=3794.4204, Expected=3766.0000
# Month=4, Predicted=3763.6451, Expected=3747.0000
# Month=5, Predicted=3745.2246, Expected=3754.0000
# Month=6, Predicted=3750.1306, Expected=3756.0000
# Month=7, Predicted=3754.7596, Expected=3767.0000
# Month=8, Predicted=3767.6340, Expected=3751.0000
# Month=9, Predicted=3750.1013, Expected=3769.0000
# Month=10, Predicted=3770.2081, Expected=3760.0000
# Month=11, Predicted=3758.7810, Expected=3785.0000
# Month=12, Predicted=3786.3901, Expected=3776.0000
# Month=13, Predicted=3775.2947, Expected=3755.0000
# Month=14, Predicted=3755.7677, Expected=3755.0000
# Month=15, Predicted=3753.5836, Expected=3751.0000
# Month=16, Predicted=3748.5290, Expected=3776.0000
# Month=17, Predicted=3776.7510, Expected=3847.0000
# Month=18, Predicted=3854.6442, Expected=3830.0000
# Month=19, Predicted=3831.5154, Expected=3881.0000
# Month=20, Predicted=3885.7874, Expected=3899.0000
# Month=21, Predicted=3903.4210, Expected=3917.0000
# Month=22, Predicted=3917.6172, Expected=3913.0000
# Month=23, Predicted=3912.2444, Expected=3901.0000
# Month=24, Predicted=3900.4277, Expected=3886.0000
# Month=25, Predicted=3883.5534, Expected=3892.5000
# Month=26, Predicted=3890.1100, Expected=3899.0000
# Month=27, Predicted=3897.9593, Expected=3886.0000
# Month=28, Predicted=3884.9695, Expected=3908.0000
# Month=29, Predicted=3908.7958, Expected=3875.0000
# Month=30, Predicted=3871.4026, Expected=3860.0000
# Month=31, Predicted=3862.3496, Expected=3880.0000
# Month=32, Predicted=3877.6188, Expected=3895.0000
# Month=33, Predicted=3896.7272, Expected=3954.0000
# Month=34, Predicted=3958.2698, Expected=3933.0000
# Month=35, Predicted=3933.2581, Expected=3937.0000
# Month=36, Predicted=3942.5471, Expected=3869.0000
# Month=37, Predicted=3861.0835, Expected=3852.0000
# Month=38, Predicted=3854.1625, Expected=3837.0000
# Month=39, Predicted=3827.6900, Expected=3832.0000
# Month=40, Predicted=3829.6044, Expected=3849.0000
# Month=41, Predicted=3849.8823, Expected=3863.0000
# Month=42, Predicted=3865.2962, Expected=3878.0000
# Month=43, Predicted=3879.8337, Expected=3855.0000
# Month=44, Predicted=3854.5088, Expected=3843.0000
# Month=45, Predicted=3844.6541, Expected=3847.0000
# Month=46, Predicted=3844.5438, Expected=3801.0000
# Month=47, Predicted=3795.7827, Expected=3787.0000
# Month=48, Predicted=3787.8553, Expected=3776.0000
# Month=49, Predicted=3770.2600, Expected=3797.0000
# Month=50, Predicted=3797.0534, Expected=3821.0000
# Month=51, Predicted=3824.4442, Expected=3877.0000
# Month=52, Predicted=3881.7374, Expected=3875.0000
# Month=53, Predicted=3876.8511, Expected=3890.0000
# Month=54, Predicted=3892.8453, Expected=3910.0000
# Month=55, Predicted=3910.5610, Expected=3924.0000
# Month=56, Predicted=3924.3373, Expected=3918.0000
# Month=57, Predicted=3917.3334, Expected=3936.0000
# Month=58, Predicted=3936.3025, Expected=3911.0000
# Month=59, Predicted=3907.8202, Expected=3891.0000
# Month=60, Predicted=3891.4665, Expected=3855.0000
# Run 26 — RMSE: 24.570678, MSE: 603.718227, NMSE: 0.0026978658
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3800.8713, Expected=3796.0000
# Month=2, Predicted=3795.9133, Expected=3793.0000
# Month=3, Predicted=3795.6279, Expected=3766.0000
# Month=4, Predicted=3765.2738, Expected=3747.0000
# Month=5, Predicted=3747.7090, Expected=3754.0000
# Month=6, Predicted=3750.8181, Expected=3756.0000
# Month=7, Predicted=3753.0964, Expected=3767.0000
# Month=8, Predicted=3766.1340, Expected=3751.0000
# Month=9, Predicted=3748.7111, Expected=3769.0000
# Month=10, Predicted=3770.1072, Expected=3760.0000
# Month=11, Predicted=3757.9921, Expected=3785.0000
# Month=12, Predicted=3786.5327, Expected=3776.0000
# Month=13, Predicted=3774.5184, Expected=3755.0000
# Month=14, Predicted=3756.0412, Expected=3755.0000
# Month=15, Predicted=3754.4902, Expected=3751.0000
# Month=16, Predicted=3748.2018, Expected=3776.0000
# Month=17, Predicted=3776.0053, Expected=3847.0000
# Month=18, Predicted=3853.7639, Expected=3830.0000
# Month=19, Predicted=3829.6065, Expected=3881.0000
# Month=20, Predicted=3887.7197, Expected=3899.0000
# Month=21, Predicted=3903.6123, Expected=3917.0000
# Month=22, Predicted=3919.8265, Expected=3913.0000
# Month=23, Predicted=3914.1732, Expected=3901.0000
# Month=24, Predicted=3903.4523, Expected=3886.0000
# Month=25, Predicted=3886.4761, Expected=3892.5000
# Month=26, Predicted=3891.9659, Expected=3899.0000
# Month=27, Predicted=3897.2935, Expected=3886.0000
# Month=28, Predicted=3884.3466, Expected=3908.0000
# Month=29, Predicted=3909.1667, Expected=3875.0000
# Month=30, Predicted=3870.1679, Expected=3860.0000
# Month=31, Predicted=3863.4778, Expected=3880.0000
# Month=32, Predicted=3877.1925, Expected=3895.0000
# Month=33, Predicted=3894.5524, Expected=3954.0000
# Month=34, Predicted=3957.6659, Expected=3933.0000
# Month=35, Predicted=3931.5040, Expected=3937.0000
# Month=36, Predicted=3943.4632, Expected=3869.0000
# Month=37, Predicted=3862.9104, Expected=3852.0000
# Month=38, Predicted=3858.1185, Expected=3837.0000
# Month=39, Predicted=3827.7787, Expected=3832.0000
# Month=40, Predicted=3827.1948, Expected=3849.0000
# Month=41, Predicted=3846.7861, Expected=3863.0000
# Month=42, Predicted=3863.1719, Expected=3878.0000
# Month=43, Predicted=3878.5289, Expected=3855.0000
# Month=44, Predicted=3853.4915, Expected=3843.0000
# Month=45, Predicted=3844.6581, Expected=3847.0000
# Month=46, Predicted=3845.2859, Expected=3801.0000
# Month=47, Predicted=3795.7264, Expected=3787.0000
# Month=48, Predicted=3788.2548, Expected=3776.0000
# Month=49, Predicted=3770.4099, Expected=3797.0000
# Month=50, Predicted=3795.4711, Expected=3821.0000
# Month=51, Predicted=3823.0628, Expected=3877.0000
# Month=52, Predicted=3881.5305, Expected=3875.0000
# Month=53, Predicted=3876.3353, Expected=3890.0000
# Month=54, Predicted=3892.8059, Expected=3910.0000
# Month=55, Predicted=3911.8994, Expected=3924.0000
# Month=56, Predicted=3925.2731, Expected=3918.0000
# Month=57, Predicted=3918.2168, Expected=3936.0000
# Month=58, Predicted=3938.1494, Expected=3911.0000
# Month=59, Predicted=3908.3447, Expected=3891.0000
# Month=60, Predicted=3893.6633, Expected=3855.0000
# Run 27 — RMSE: 25.140104, MSE: 632.024843, NMSE: 0.0027962336
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3801.3483, Expected=3796.0000
# Month=2, Predicted=3796.2863, Expected=3793.0000
# Month=3, Predicted=3793.6104, Expected=3766.0000
# Month=4, Predicted=3764.4273, Expected=3747.0000
# Month=5, Predicted=3746.5740, Expected=3754.0000
# Month=6, Predicted=3751.9665, Expected=3756.0000
# Month=7, Predicted=3755.1951, Expected=3767.0000
# Month=8, Predicted=3767.8390, Expected=3751.0000
# Month=9, Predicted=3750.4439, Expected=3769.0000
# Month=10, Predicted=3770.0335, Expected=3760.0000
# Month=11, Predicted=3759.1832, Expected=3785.0000
# Month=12, Predicted=3786.4656, Expected=3776.0000
# Month=13, Predicted=3775.5645, Expected=3755.0000
# Month=14, Predicted=3755.1707, Expected=3755.0000
# Month=15, Predicted=3754.7149, Expected=3751.0000
# Month=16, Predicted=3749.5665, Expected=3776.0000
# Month=17, Predicted=3777.0706, Expected=3847.0000
# Month=18, Predicted=3852.6774, Expected=3830.0000
# Month=19, Predicted=3831.4497, Expected=3881.0000
# Month=20, Predicted=3884.4334, Expected=3899.0000
# Month=21, Predicted=3899.3958, Expected=3917.0000
# Month=22, Predicted=3916.8517, Expected=3913.0000
# Month=23, Predicted=3911.4398, Expected=3901.0000
# Month=24, Predicted=3900.4363, Expected=3886.0000
# Month=25, Predicted=3884.7931, Expected=3892.5000
# Month=26, Predicted=3891.2683, Expected=3899.0000
# Month=27, Predicted=3898.0311, Expected=3886.0000
# Month=28, Predicted=3885.0519, Expected=3908.0000
# Month=29, Predicted=3908.7618, Expected=3875.0000
# Month=30, Predicted=3872.1494, Expected=3860.0000
# Month=31, Predicted=3860.9314, Expected=3880.0000
# Month=32, Predicted=3878.7930, Expected=3895.0000
# Month=33, Predicted=3896.5144, Expected=3954.0000
# Month=34, Predicted=3958.4789, Expected=3933.0000
# Month=35, Predicted=3933.3700, Expected=3937.0000
# Month=36, Predicted=3939.9484, Expected=3869.0000
# Month=37, Predicted=3863.6117, Expected=3852.0000
# Month=38, Predicted=3855.2966, Expected=3837.0000
# Month=39, Predicted=3830.8968, Expected=3832.0000
# Month=40, Predicted=3829.5440, Expected=3849.0000
# Month=41, Predicted=3849.7108, Expected=3863.0000
# Month=42, Predicted=3865.5885, Expected=3878.0000
# Month=43, Predicted=3880.1850, Expected=3855.0000
# Month=44, Predicted=3854.4268, Expected=3843.0000
# Month=45, Predicted=3844.0062, Expected=3847.0000
# Month=46, Predicted=3846.0420, Expected=3801.0000
# Month=47, Predicted=3797.2226, Expected=3787.0000
# Month=48, Predicted=3787.3429, Expected=3776.0000
# Month=49, Predicted=3772.4653, Expected=3797.0000
# Month=50, Predicted=3797.1291, Expected=3821.0000
# Month=51, Predicted=3824.4917, Expected=3877.0000
# Month=52, Predicted=3882.2238, Expected=3875.0000
# Month=53, Predicted=3876.7600, Expected=3890.0000
# Month=54, Predicted=3891.5253, Expected=3910.0000
# Month=55, Predicted=3909.7902, Expected=3924.0000
# Month=56, Predicted=3923.6355, Expected=3918.0000
# Month=57, Predicted=3916.9474, Expected=3936.0000
# Month=58, Predicted=3936.5831, Expected=3911.0000
# Month=59, Predicted=3908.1304, Expected=3891.0000
# Month=60, Predicted=3891.5701, Expected=3855.0000
# Run 28 — RMSE: 24.484877, MSE: 599.509184, NMSE: 0.0027135233
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3802.0159, Expected=3796.0000
# Month=2, Predicted=3797.8034, Expected=3793.0000
# Month=3, Predicted=3794.9904, Expected=3766.0000
# Month=4, Predicted=3764.2533, Expected=3747.0000
# Month=5, Predicted=3745.1041, Expected=3754.0000
# Month=6, Predicted=3749.6944, Expected=3756.0000
# Month=7, Predicted=3753.6469, Expected=3767.0000
# Month=8, Predicted=3767.4875, Expected=3751.0000
# Month=9, Predicted=3750.8308, Expected=3769.0000
# Month=10, Predicted=3770.6509, Expected=3760.0000
# Month=11, Predicted=3759.1721, Expected=3785.0000
# Month=12, Predicted=3786.6052, Expected=3776.0000
# Month=13, Predicted=3775.5010, Expected=3755.0000
# Month=14, Predicted=3755.7031, Expected=3755.0000
# Month=15, Predicted=3754.0563, Expected=3751.0000
# Month=16, Predicted=3748.2627, Expected=3776.0000
# Month=17, Predicted=3776.0867, Expected=3847.0000
# Month=18, Predicted=3853.2827, Expected=3830.0000
# Month=19, Predicted=3833.6297, Expected=3881.0000
# Month=20, Predicted=3886.9135, Expected=3899.0000
# Month=21, Predicted=3901.0466, Expected=3917.0000
# Month=22, Predicted=3918.2048, Expected=3913.0000
# Month=23, Predicted=3912.0636, Expected=3901.0000
# Month=24, Predicted=3899.7400, Expected=3886.0000
# Month=25, Predicted=3883.1780, Expected=3892.5000
# Month=26, Predicted=3889.2513, Expected=3899.0000
# Month=27, Predicted=3896.7206, Expected=3886.0000
# Month=28, Predicted=3884.7227, Expected=3908.0000
# Month=29, Predicted=3908.9742, Expected=3875.0000
# Month=30, Predicted=3872.4133, Expected=3860.0000
# Month=31, Predicted=3862.2089, Expected=3880.0000
# Month=32, Predicted=3878.2915, Expected=3895.0000
# Month=33, Predicted=3896.1213, Expected=3954.0000
# Month=34, Predicted=3959.2656, Expected=3933.0000
# Month=35, Predicted=3935.0649, Expected=3937.0000
# Month=36, Predicted=3942.5003, Expected=3869.0000
# Month=37, Predicted=3864.2903, Expected=3852.0000
# Month=38, Predicted=3854.2502, Expected=3837.0000
# Month=39, Predicted=3828.3810, Expected=3832.0000
# Month=40, Predicted=3827.9040, Expected=3849.0000
# Month=41, Predicted=3849.3976, Expected=3863.0000
# Month=42, Predicted=3866.3254, Expected=3878.0000
# Month=43, Predicted=3881.5320, Expected=3855.0000
# Month=44, Predicted=3855.8746, Expected=3843.0000
# Month=45, Predicted=3844.8738, Expected=3847.0000
# Month=46, Predicted=3844.6773, Expected=3801.0000
# Month=47, Predicted=3795.9041, Expected=3787.0000
# Month=48, Predicted=3786.7144, Expected=3776.0000
# Month=49, Predicted=3770.8756, Expected=3797.0000
# Month=50, Predicted=3796.0407, Expected=3821.0000
# Month=51, Predicted=3824.8828, Expected=3877.0000
# Month=52, Predicted=3884.0413, Expected=3875.0000
# Month=53, Predicted=3879.5821, Expected=3890.0000
# Month=54, Predicted=3893.8879, Expected=3910.0000
# Month=55, Predicted=3910.1012, Expected=3924.0000
# Month=56, Predicted=3923.5460, Expected=3918.0000
# Month=57, Predicted=3916.7612, Expected=3936.0000
# Month=58, Predicted=3935.6895, Expected=3911.0000
# Month=59, Predicted=3907.2644, Expected=3891.0000
# Month=60, Predicted=3890.6356, Expected=3855.0000
# Run 29 — RMSE: 24.611956, MSE: 605.748359, NMSE: 0.0027046770
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3802.7230, Expected=3796.0000
# Month=2, Predicted=3794.7862, Expected=3793.0000
# Month=3, Predicted=3794.7248, Expected=3766.0000
# Month=4, Predicted=3765.9586, Expected=3747.0000
# Month=5, Predicted=3746.8539, Expected=3754.0000
# Month=6, Predicted=3749.1070, Expected=3756.0000
# Month=7, Predicted=3754.3047, Expected=3767.0000
# Month=8, Predicted=3767.5074, Expected=3751.0000
# Month=9, Predicted=3750.6009, Expected=3769.0000
# Month=10, Predicted=3771.4568, Expected=3760.0000
# Month=11, Predicted=3759.5844, Expected=3785.0000
# Month=12, Predicted=3786.4682, Expected=3776.0000
# Month=13, Predicted=3775.6339, Expected=3755.0000
# Month=14, Predicted=3756.0911, Expected=3755.0000
# Month=15, Predicted=3754.7835, Expected=3751.0000
# Month=16, Predicted=3748.1594, Expected=3776.0000
# Month=17, Predicted=3776.7673, Expected=3847.0000
# Month=18, Predicted=3857.5420, Expected=3830.0000
# Month=19, Predicted=3830.7337, Expected=3881.0000
# Month=20, Predicted=3883.7202, Expected=3899.0000
# Month=21, Predicted=3905.4088, Expected=3917.0000
# Month=22, Predicted=3916.3762, Expected=3913.0000
# Month=23, Predicted=3912.9202, Expected=3901.0000
# Month=24, Predicted=3902.5840, Expected=3886.0000
# Month=25, Predicted=3886.0249, Expected=3892.5000
# Month=26, Predicted=3891.1111, Expected=3899.0000
# Month=27, Predicted=3898.4833, Expected=3886.0000
# Month=28, Predicted=3884.8949, Expected=3908.0000
# Month=29, Predicted=3909.6168, Expected=3875.0000
# Month=30, Predicted=3871.9018, Expected=3860.0000
# Month=31, Predicted=3863.5492, Expected=3880.0000
# Month=32, Predicted=3877.1137, Expected=3895.0000
# Month=33, Predicted=3897.5998, Expected=3954.0000
# Month=34, Predicted=3958.7405, Expected=3933.0000
# Month=35, Predicted=3932.2942, Expected=3937.0000
# Month=36, Predicted=3943.2138, Expected=3869.0000
# Month=37, Predicted=3864.2332, Expected=3852.0000
# Month=38, Predicted=3853.0537, Expected=3837.0000
# Month=39, Predicted=3819.3871, Expected=3832.0000
# Month=40, Predicted=3825.6535, Expected=3849.0000
# Month=41, Predicted=3851.2023, Expected=3863.0000
# Month=42, Predicted=3867.3847, Expected=3878.0000
# Month=43, Predicted=3879.7193, Expected=3855.0000
# Month=44, Predicted=3854.9554, Expected=3843.0000
# Month=45, Predicted=3847.1165, Expected=3847.0000
# Month=46, Predicted=3844.2067, Expected=3801.0000
# Month=47, Predicted=3793.5995, Expected=3787.0000
# Month=48, Predicted=3786.0915, Expected=3776.0000
# Month=49, Predicted=3766.2178, Expected=3797.0000
# Month=50, Predicted=3796.0116, Expected=3821.0000
# Month=51, Predicted=3826.3082, Expected=3877.0000
# Month=52, Predicted=3881.2509, Expected=3875.0000
# Month=53, Predicted=3874.2823, Expected=3890.0000
# Month=54, Predicted=3890.8180, Expected=3910.0000
# Month=55, Predicted=3911.1469, Expected=3924.0000
# Month=56, Predicted=3924.3792, Expected=3918.0000
# Month=57, Predicted=3917.2885, Expected=3936.0000
# Month=58, Predicted=3937.2722, Expected=3911.0000
# Month=59, Predicted=3908.6965, Expected=3891.0000
# Month=60, Predicted=3892.9538, Expected=3855.0000
# Run 30 — RMSE: 24.914532, MSE: 620.733908, NMSE: 0.0027516929

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on Dow Jones Industrial Index (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.576188 ± 0.247155
# MSE:  604.050120 ± 12.249335
# NMSE: 0.0027110004 ± 0.0000358794
#
# Best run: 4
#   RMSE: 24.153881
#   MSE:  583.409970
#   NMSE: 0.0026480739

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 24.153881
# MSE:  583.409970
# NMSE: 0.0026480739

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
