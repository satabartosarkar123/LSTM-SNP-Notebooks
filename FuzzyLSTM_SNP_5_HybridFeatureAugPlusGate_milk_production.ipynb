# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 2)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 505 (1.97 KB)
#  Trainable params: 505 (1.97 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (168,)
# First 5 values: [589 561 640 656 727]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=2)
#    Needed for fuzzy feature augmentation: x(t), x(t-1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 2)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (167, 3)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (107, 3), Test: (60, 3)

# %%
# ============================================================
# 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
#    supervised columns: [x(t-2), x(t-1), x(t)]
#    We use x(t-1) as primary input, x(t-2) for fuzzy context
# ============================================================

# Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
y_train = train_scaled[:, -1]        # x(t)

X_test_raw = test_scaled[:, 0:-1]
y_test = test_scaled[:, -1]

# Compute fuzzy features for training data
X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
for i in range(X_train_raw.shape[0]):
    x_t = X_train_raw[i, 1]      # x(t-1) = current input
    x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_train_fuzzy[i, 0] = x_t
    X_train_fuzzy[i, 1] = y_fuzz

X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))

# Compute fuzzy features for test data
X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
for i in range(X_test_raw.shape[0]):
    x_t = X_test_raw[i, 1]
    x_tm1 = X_test_raw[i, 0]
    y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
    X_test_fuzzy[i, 0] = x_t
    X_test_fuzzy[i, 1] = y_fuzz

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (107, 1, 2), y_train shape: (107,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=2, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    for i in range(len(train_scaled)):
        X_raw = train_scaled[i, 0:-1]
        x_t = X_raw[1]
        x_tm1 = X_raw[0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        model.predict(X_aug, batch_size=1, verbose=0)

    # Test predictions (single-step) with fuzzy feature augmentation
    predictions = []
    for i in range(len(test_scaled)):
        X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
        x_t = X_raw[1]      # current input
        x_tm1 = X_raw[0]    # previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
        yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]

        # Invert scaling (need to match the scaler's column structure)
        # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
        new_row = list(X_raw) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=751.2760, Expected=804.0000
# Month=2, Predicted=804.0600, Expected=756.0000
# Month=3, Predicted=799.7953, Expected=860.0000
# Month=4, Predicted=846.2717, Expected=878.0000
# Month=5, Predicted=948.9526, Expected=942.0000
# Month=6, Predicted=910.6309, Expected=913.0000
# Month=7, Predicted=864.8903, Expected=869.0000
# Month=8, Predicted=855.2825, Expected=834.0000
# Month=9, Predicted=808.9927, Expected=790.0000
# Month=10, Predicted=774.6138, Expected=800.0000
# Month=11, Predicted=788.0875, Expected=763.0000
# Month=12, Predicted=818.8498, Expected=800.0000
# Month=13, Predicted=798.7397, Expected=826.0000
# Month=14, Predicted=788.3569, Expected=799.0000
# Month=15, Predicted=867.1261, Expected=890.0000
# Month=16, Predicted=903.5872, Expected=900.0000
# Month=17, Predicted=944.0348, Expected=961.0000
# Month=18, Predicted=954.1393, Expected=935.0000
# Month=19, Predicted=889.3009, Expected=894.0000
# Month=20, Predicted=887.4178, Expected=855.0000
# Month=21, Predicted=832.9612, Expected=809.0000
# Month=22, Predicted=786.4916, Expected=810.0000
# Month=23, Predicted=794.0374, Expected=766.0000
# Month=24, Predicted=807.6361, Expected=805.0000
# Month=25, Predicted=793.5602, Expected=821.0000
# Month=26, Predicted=781.0119, Expected=773.0000
# Month=27, Predicted=838.2632, Expected=883.0000
# Month=28, Predicted=877.8418, Expected=898.0000
# Month=29, Predicted=968.3369, Expected=957.0000
# Month=30, Predicted=936.9471, Expected=924.0000
# Month=31, Predicted=891.4753, Expected=881.0000
# Month=32, Predicted=862.7485, Expected=837.0000
# Month=33, Predicted=809.5207, Expected=784.0000
# Month=34, Predicted=750.7451, Expected=791.0000
# Month=35, Predicted=765.6623, Expected=760.0000
# Month=36, Predicted=811.6145, Expected=802.0000
# Month=37, Predicted=809.1804, Expected=828.0000
# Month=38, Predicted=796.3261, Expected=778.0000
# Month=39, Predicted=860.8285, Expected=889.0000
# Month=40, Predicted=880.7343, Expected=902.0000
# Month=41, Predicted=968.6509, Expected=969.0000
# Month=42, Predicted=944.9564, Expected=947.0000
# Month=43, Predicted=890.3877, Expected=908.0000
# Month=44, Predicted=906.7712, Expected=867.0000
# Month=45, Predicted=847.3392, Expected=815.0000
# Month=46, Predicted=786.9373, Expected=812.0000
# Month=47, Predicted=786.5107, Expected=773.0000
# Month=48, Predicted=809.5311, Expected=813.0000
# Month=49, Predicted=808.8140, Expected=834.0000
# Month=50, Predicted=796.1766, Expected=782.0000
# Month=51, Predicted=856.4248, Expected=892.0000
# Month=52, Predicted=881.4531, Expected=903.0000
# Month=53, Predicted=963.9566, Expected=966.0000
# Month=54, Predicted=949.3767, Expected=937.0000
# Month=55, Predicted=890.6458, Expected=896.0000
# Month=56, Predicted=883.7732, Expected=858.0000
# Month=57, Predicted=836.2298, Expected=817.0000
# Month=58, Predicted=798.0942, Expected=827.0000
# Month=59, Predicted=819.1450, Expected=797.0000
# Month=60, Predicted=851.7054, Expected=843.0000
# Run 1 — RMSE: 24.101045, MSE: 580.860389, NMSE: 0.0027332498
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=751.5427, Expected=804.0000
# Month=2, Predicted=798.7928, Expected=756.0000
# Month=3, Predicted=814.0141, Expected=860.0000
# Month=4, Predicted=862.1619, Expected=878.0000
# Month=5, Predicted=944.9363, Expected=942.0000
# Month=6, Predicted=911.3043, Expected=913.0000
# Month=7, Predicted=864.1442, Expected=869.0000
# Month=8, Predicted=850.3963, Expected=834.0000
# Month=9, Predicted=805.3814, Expected=790.0000
# Month=10, Predicted=768.9046, Expected=800.0000
# Month=11, Predicted=792.8916, Expected=763.0000
# Month=12, Predicted=809.9827, Expected=800.0000
# Month=13, Predicted=798.6590, Expected=826.0000
# Month=14, Predicted=796.4387, Expected=799.0000
# Month=15, Predicted=858.4883, Expected=890.0000
# Month=16, Predicted=917.6749, Expected=900.0000
# Month=17, Predicted=911.8293, Expected=961.0000
# Month=18, Predicted=949.8341, Expected=935.0000
# Month=19, Predicted=891.4881, Expected=894.0000
# Month=20, Predicted=881.2208, Expected=855.0000
# Month=21, Predicted=827.4693, Expected=809.0000
# Month=22, Predicted=781.2863, Expected=810.0000
# Month=23, Predicted=798.8097, Expected=766.0000
# Month=24, Predicted=804.9252, Expected=805.0000
# Month=25, Predicted=793.3065, Expected=821.0000
# Month=26, Predicted=792.0198, Expected=773.0000
# Month=27, Predicted=864.6796, Expected=883.0000
# Month=28, Predicted=888.2757, Expected=898.0000
# Month=29, Predicted=953.9707, Expected=957.0000
# Month=30, Predicted=934.0890, Expected=924.0000
# Month=31, Predicted=903.2111, Expected=881.0000
# Month=32, Predicted=858.1326, Expected=837.0000
# Month=33, Predicted=804.6243, Expected=784.0000
# Month=34, Predicted=746.0344, Expected=791.0000
# Month=35, Predicted=772.3808, Expected=760.0000
# Month=36, Predicted=796.0325, Expected=802.0000
# Month=37, Predicted=810.8530, Expected=828.0000
# Month=38, Predicted=805.0985, Expected=778.0000
# Month=39, Predicted=881.9038, Expected=889.0000
# Month=40, Predicted=891.1683, Expected=902.0000
# Month=41, Predicted=950.6585, Expected=969.0000
# Month=42, Predicted=945.6586, Expected=947.0000
# Month=43, Predicted=880.6447, Expected=908.0000
# Month=44, Predicted=901.4799, Expected=867.0000
# Month=45, Predicted=840.4343, Expected=815.0000
# Month=46, Predicted=780.9452, Expected=812.0000
# Month=47, Predicted=791.7361, Expected=773.0000
# Month=48, Predicted=799.4795, Expected=813.0000
# Month=49, Predicted=809.1489, Expected=834.0000
# Month=50, Predicted=805.9696, Expected=782.0000
# Month=51, Predicted=886.0955, Expected=892.0000
# Month=52, Predicted=890.6859, Expected=903.0000
# Month=53, Predicted=943.2956, Expected=966.0000
# Month=54, Predicted=950.6121, Expected=937.0000
# Month=55, Predicted=891.8812, Expected=896.0000
# Month=56, Predicted=879.2881, Expected=858.0000
# Month=57, Predicted=831.3496, Expected=817.0000
# Month=58, Predicted=793.5732, Expected=827.0000
# Month=59, Predicted=824.4348, Expected=797.0000
# Month=60, Predicted=833.7159, Expected=843.0000
# Run 2 — RMSE: 23.329697, MSE: 544.274747, NMSE: 0.0027215126
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=749.1231, Expected=804.0000
# Month=2, Predicted=818.1210, Expected=756.0000
# Month=3, Predicted=833.1864, Expected=860.0000
# Month=4, Predicted=853.0920, Expected=878.0000
# Month=5, Predicted=934.2641, Expected=942.0000
# Month=6, Predicted=914.5257, Expected=913.0000
# Month=7, Predicted=862.9606, Expected=869.0000
# Month=8, Predicted=855.9641, Expected=834.0000
# Month=9, Predicted=807.6471, Expected=790.0000
# Month=10, Predicted=771.9241, Expected=800.0000
# Month=11, Predicted=788.3239, Expected=763.0000
# Month=12, Predicted=820.3646, Expected=800.0000
# Month=13, Predicted=796.3457, Expected=826.0000
# Month=14, Predicted=792.9818, Expected=799.0000
# Month=15, Predicted=876.9826, Expected=890.0000
# Month=16, Predicted=907.4914, Expected=900.0000
# Month=17, Predicted=945.1088, Expected=961.0000
# Month=18, Predicted=949.3636, Expected=935.0000
# Month=19, Predicted=887.7588, Expected=894.0000
# Month=20, Predicted=886.3937, Expected=855.0000
# Month=21, Predicted=830.7773, Expected=809.0000
# Month=22, Predicted=784.7852, Expected=810.0000
# Month=23, Predicted=794.4907, Expected=766.0000
# Month=24, Predicted=801.4821, Expected=805.0000
# Month=25, Predicted=791.2053, Expected=821.0000
# Month=26, Predicted=784.4937, Expected=773.0000
# Month=27, Predicted=856.4423, Expected=883.0000
# Month=28, Predicted=879.1896, Expected=898.0000
# Month=29, Predicted=946.9747, Expected=957.0000
# Month=30, Predicted=933.7032, Expected=924.0000
# Month=31, Predicted=903.4473, Expected=881.0000
# Month=32, Predicted=863.3086, Expected=837.0000
# Month=33, Predicted=808.2793, Expected=784.0000
# Month=34, Predicted=750.3328, Expected=791.0000
# Month=35, Predicted=767.2422, Expected=760.0000
# Month=36, Predicted=803.2881, Expected=802.0000
# Month=37, Predicted=808.0453, Expected=828.0000
# Month=38, Predicted=797.3192, Expected=778.0000
# Month=39, Predicted=876.5413, Expected=889.0000
# Month=40, Predicted=881.9950, Expected=902.0000
# Month=41, Predicted=947.0685, Expected=969.0000
# Month=42, Predicted=946.2213, Expected=947.0000
# Month=43, Predicted=887.0346, Expected=908.0000
# Month=44, Predicted=906.3129, Expected=867.0000
# Month=45, Predicted=844.4327, Expected=815.0000
# Month=46, Predicted=785.5643, Expected=812.0000
# Month=47, Predicted=787.6381, Expected=773.0000
# Month=48, Predicted=799.6262, Expected=813.0000
# Month=49, Predicted=806.7816, Expected=834.0000
# Month=50, Predicted=799.9008, Expected=782.0000
# Month=51, Predicted=876.1070, Expected=892.0000
# Month=52, Predicted=881.7653, Expected=903.0000
# Month=53, Predicted=944.8853, Expected=966.0000
# Month=54, Predicted=948.0263, Expected=937.0000
# Month=55, Predicted=888.8073, Expected=896.0000
# Month=56, Predicted=884.2909, Expected=858.0000
# Month=57, Predicted=834.3055, Expected=817.0000
# Month=58, Predicted=796.2074, Expected=827.0000
# Month=59, Predicted=819.5453, Expected=797.0000
# Month=60, Predicted=849.7242, Expected=843.0000
# Run 3 — RMSE: 23.058047, MSE: 531.673528, NMSE: 0.0026882231
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=747.7210, Expected=804.0000
# Month=2, Predicted=813.9234, Expected=756.0000
# Month=3, Predicted=806.5216, Expected=860.0000
# Month=4, Predicted=852.2991, Expected=878.0000
# Month=5, Predicted=938.2766, Expected=942.0000
# Month=6, Predicted=913.8890, Expected=913.0000
# Month=7, Predicted=860.9340, Expected=869.0000
# Month=8, Predicted=849.9130, Expected=834.0000
# Month=9, Predicted=808.0098, Expected=790.0000
# Month=10, Predicted=771.7995, Expected=800.0000
# Month=11, Predicted=789.6314, Expected=763.0000
# Month=12, Predicted=815.4670, Expected=800.0000
# Month=13, Predicted=794.8842, Expected=826.0000
# Month=14, Predicted=792.8257, Expected=799.0000
# Month=15, Predicted=861.6354, Expected=890.0000
# Month=16, Predicted=915.9780, Expected=900.0000
# Month=17, Predicted=959.1688, Expected=961.0000
# Month=18, Predicted=960.9141, Expected=935.0000
# Month=19, Predicted=884.7856, Expected=894.0000
# Month=20, Predicted=880.0719, Expected=855.0000
# Month=21, Predicted=830.3631, Expected=809.0000
# Month=22, Predicted=785.1931, Expected=810.0000
# Month=23, Predicted=796.2168, Expected=766.0000
# Month=24, Predicted=804.2717, Expected=805.0000
# Month=25, Predicted=790.4082, Expected=821.0000
# Month=26, Predicted=781.0617, Expected=773.0000
# Month=27, Predicted=826.8704, Expected=883.0000
# Month=28, Predicted=880.9391, Expected=898.0000
# Month=29, Predicted=957.4011, Expected=957.0000
# Month=30, Predicted=935.3019, Expected=924.0000
# Month=31, Predicted=897.5065, Expected=881.0000
# Month=32, Predicted=858.1765, Expected=837.0000
# Month=33, Predicted=808.9439, Expected=784.0000
# Month=34, Predicted=752.5426, Expected=791.0000
# Month=35, Predicted=770.4622, Expected=760.0000
# Month=36, Predicted=810.9490, Expected=802.0000
# Month=37, Predicted=806.7908, Expected=828.0000
# Month=38, Predicted=803.8216, Expected=778.0000
# Month=39, Predicted=840.6354, Expected=889.0000
# Month=40, Predicted=883.2875, Expected=902.0000
# Month=41, Predicted=960.8801, Expected=969.0000
# Month=42, Predicted=946.9093, Expected=947.0000
# Month=43, Predicted=887.9418, Expected=908.0000
# Month=44, Predicted=899.4521, Expected=867.0000
# Month=45, Predicted=843.3929, Expected=815.0000
# Month=46, Predicted=786.5546, Expected=812.0000
# Month=47, Predicted=790.3531, Expected=773.0000
# Month=48, Predicted=808.0154, Expected=813.0000
# Month=49, Predicted=805.6041, Expected=834.0000
# Month=50, Predicted=800.2908, Expected=782.0000
# Month=51, Predicted=842.1489, Expected=892.0000
# Month=52, Predicted=883.5404, Expected=903.0000
# Month=53, Predicted=961.4695, Expected=966.0000
# Month=54, Predicted=956.3047, Expected=937.0000
# Month=55, Predicted=887.1126, Expected=896.0000
# Month=56, Predicted=878.2599, Expected=858.0000
# Month=57, Predicted=834.0290, Expected=817.0000
# Month=58, Predicted=796.2917, Expected=827.0000
# Month=59, Predicted=820.9399, Expected=797.0000
# Month=60, Predicted=849.7536, Expected=843.0000
# Run 4 — RMSE: 25.596800, MSE: 655.196169, NMSE: 0.0031080822
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=746.0432, Expected=804.0000
# Month=2, Predicted=828.1475, Expected=756.0000
# Month=3, Predicted=800.5627, Expected=860.0000
# Month=4, Predicted=843.2656, Expected=878.0000
# Month=5, Predicted=922.3848, Expected=942.0000
# Month=6, Predicted=918.6692, Expected=913.0000
# Month=7, Predicted=863.0908, Expected=869.0000
# Month=8, Predicted=861.4674, Expected=834.0000
# Month=9, Predicted=811.9302, Expected=790.0000
# Month=10, Predicted=779.3249, Expected=800.0000
# Month=11, Predicted=786.9055, Expected=763.0000
# Month=12, Predicted=816.2046, Expected=800.0000
# Month=13, Predicted=793.2893, Expected=826.0000
# Month=14, Predicted=802.6692, Expected=799.0000
# Month=15, Predicted=849.1270, Expected=890.0000
# Month=16, Predicted=903.2097, Expected=900.0000
# Month=17, Predicted=941.1375, Expected=961.0000
# Month=18, Predicted=954.7075, Expected=935.0000
# Month=19, Predicted=889.7123, Expected=894.0000
# Month=20, Predicted=891.4587, Expected=855.0000
# Month=21, Predicted=835.8593, Expected=809.0000
# Month=22, Predicted=792.0306, Expected=810.0000
# Month=23, Predicted=793.7160, Expected=766.0000
# Month=24, Predicted=806.9290, Expected=805.0000
# Month=25, Predicted=788.6224, Expected=821.0000
# Month=26, Predicted=797.6692, Expected=773.0000
# Month=27, Predicted=858.1831, Expected=883.0000
# Month=28, Predicted=868.8392, Expected=898.0000
# Month=29, Predicted=931.0208, Expected=957.0000
# Month=30, Predicted=936.7353, Expected=924.0000
# Month=31, Predicted=904.7152, Expected=881.0000
# Month=32, Predicted=868.0206, Expected=837.0000
# Month=33, Predicted=814.3736, Expected=784.0000
# Month=34, Predicted=758.5010, Expected=791.0000
# Month=35, Predicted=765.8542, Expected=760.0000
# Month=36, Predicted=804.7313, Expected=802.0000
# Month=37, Predicted=804.4142, Expected=828.0000
# Month=38, Predicted=811.5740, Expected=778.0000
# Month=39, Predicted=875.7404, Expected=889.0000
# Month=40, Predicted=871.4404, Expected=902.0000
# Month=41, Predicted=931.4707, Expected=969.0000
# Month=42, Predicted=948.7884, Expected=947.0000
# Month=43, Predicted=884.9106, Expected=908.0000
# Month=44, Predicted=911.4916, Expected=867.0000
# Month=45, Predicted=849.8404, Expected=815.0000
# Month=46, Predicted=793.5715, Expected=812.0000
# Month=47, Predicted=786.9147, Expected=773.0000
# Month=48, Predicted=805.1572, Expected=813.0000
# Month=49, Predicted=804.3251, Expected=834.0000
# Month=50, Predicted=810.6692, Expected=782.0000
# Month=51, Predicted=877.3160, Expected=892.0000
# Month=52, Predicted=871.5630, Expected=903.0000
# Month=53, Predicted=930.9693, Expected=966.0000
# Month=54, Predicted=955.1626, Expected=937.0000
# Month=55, Predicted=891.0746, Expected=896.0000
# Month=56, Predicted=889.2196, Expected=858.0000
# Month=57, Predicted=839.3364, Expected=817.0000
# Month=58, Predicted=802.6660, Expected=827.0000
# Month=59, Predicted=818.3714, Expected=797.0000
# Month=60, Predicted=844.0155, Expected=843.0000
# Run 5 — RMSE: 27.690559, MSE: 766.767031, NMSE: 0.0042010029
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=747.0135, Expected=804.0000
# Month=2, Predicted=795.1215, Expected=756.0000
# Month=3, Predicted=800.2278, Expected=860.0000
# Month=4, Predicted=865.6249, Expected=878.0000
# Month=5, Predicted=964.4548, Expected=942.0000
# Month=6, Predicted=913.2049, Expected=913.0000
# Month=7, Predicted=861.7486, Expected=869.0000
# Month=8, Predicted=844.1548, Expected=834.0000
# Month=9, Predicted=812.3248, Expected=790.0000
# Month=10, Predicted=764.9761, Expected=800.0000
# Month=11, Predicted=795.5751, Expected=763.0000
# Month=12, Predicted=817.4599, Expected=800.0000
# Month=13, Predicted=795.4989, Expected=826.0000
# Month=14, Predicted=791.4845, Expected=799.0000
# Month=15, Predicted=875.2175, Expected=890.0000
# Month=16, Predicted=913.7448, Expected=900.0000
# Month=17, Predicted=931.9592, Expected=961.0000
# Month=18, Predicted=964.6988, Expected=935.0000
# Month=19, Predicted=886.7879, Expected=894.0000
# Month=20, Predicted=871.4649, Expected=855.0000
# Month=21, Predicted=831.6226, Expected=809.0000
# Month=22, Predicted=782.2546, Expected=810.0000
# Month=23, Predicted=803.8980, Expected=766.0000
# Month=24, Predicted=794.8365, Expected=805.0000
# Month=25, Predicted=798.7442, Expected=821.0000
# Month=26, Predicted=786.3888, Expected=773.0000
# Month=27, Predicted=842.5390, Expected=883.0000
# Month=28, Predicted=889.6916, Expected=898.0000
# Month=29, Predicted=991.2403, Expected=957.0000
# Month=30, Predicted=945.9274, Expected=924.0000
# Month=31, Predicted=890.8742, Expected=881.0000
# Month=32, Predicted=855.8372, Expected=837.0000
# Month=33, Predicted=810.7106, Expected=784.0000
# Month=34, Predicted=752.7250, Expected=791.0000
# Month=35, Predicted=784.9230, Expected=760.0000
# Month=36, Predicted=808.1316, Expected=802.0000
# Month=37, Predicted=805.3087, Expected=828.0000
# Month=38, Predicted=800.2157, Expected=778.0000
# Month=39, Predicted=873.3209, Expected=889.0000
# Month=40, Predicted=894.5606, Expected=902.0000
# Month=41, Predicted=991.3426, Expected=969.0000
# Month=42, Predicted=956.3972, Expected=947.0000
# Month=43, Predicted=895.3279, Expected=908.0000
# Month=44, Predicted=891.9492, Expected=867.0000
# Month=45, Predicted=842.8470, Expected=815.0000
# Month=46, Predicted=784.7216, Expected=812.0000
# Month=47, Predicted=803.9450, Expected=773.0000
# Month=48, Predicted=794.9043, Expected=813.0000
# Month=49, Predicted=808.2748, Expected=834.0000
# Month=50, Predicted=800.4690, Expected=782.0000
# Month=51, Predicted=865.1563, Expected=892.0000
# Month=52, Predicted=896.2199, Expected=903.0000
# Month=53, Predicted=983.0681, Expected=966.0000
# Month=54, Predicted=964.2371, Expected=937.0000
# Month=55, Predicted=886.8159, Expected=896.0000
# Month=56, Predicted=872.6630, Expected=858.0000
# Month=57, Predicted=835.1618, Expected=817.0000
# Month=58, Predicted=793.0489, Expected=827.0000
# Month=59, Predicted=823.0588, Expected=797.0000
# Month=60, Predicted=852.4736, Expected=843.0000
# Run 6 — RMSE: 24.725238, MSE: 611.337406, NMSE: 0.0025450263
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=751.1648, Expected=804.0000
# Month=2, Predicted=795.1463, Expected=756.0000
# Month=3, Predicted=777.1362, Expected=860.0000
# Month=4, Predicted=862.0095, Expected=878.0000
# Month=5, Predicted=958.9127, Expected=942.0000
# Month=6, Predicted=914.1019, Expected=913.0000
# Month=7, Predicted=867.0841, Expected=869.0000
# Month=8, Predicted=847.7089, Expected=834.0000
# Month=9, Predicted=806.6214, Expected=790.0000
# Month=10, Predicted=768.2973, Expected=800.0000
# Month=11, Predicted=794.1271, Expected=763.0000
# Month=12, Predicted=811.6757, Expected=800.0000
# Month=13, Predicted=798.3225, Expected=826.0000
# Month=14, Predicted=791.5994, Expected=799.0000
# Month=15, Predicted=849.1666, Expected=890.0000
# Month=16, Predicted=922.7738, Expected=900.0000
# Month=17, Predicted=941.6063, Expected=961.0000
# Month=18, Predicted=969.8832, Expected=935.0000
# Month=19, Predicted=891.2834, Expected=894.0000
# Month=20, Predicted=878.2143, Expected=855.0000
# Month=21, Predicted=828.2158, Expected=809.0000
# Month=22, Predicted=781.3983, Expected=810.0000
# Month=23, Predicted=800.4003, Expected=766.0000
# Month=24, Predicted=792.2472, Expected=805.0000
# Month=25, Predicted=794.5941, Expected=821.0000
# Month=26, Predicted=783.5904, Expected=773.0000
# Month=27, Predicted=816.1972, Expected=883.0000
# Month=28, Predicted=889.2157, Expected=898.0000
# Month=29, Predicted=981.7800, Expected=957.0000
# Month=30, Predicted=942.7506, Expected=924.0000
# Month=31, Predicted=894.6209, Expected=881.0000
# Month=32, Predicted=855.9195, Expected=837.0000
# Month=33, Predicted=805.5347, Expected=784.0000
# Month=34, Predicted=746.8269, Expected=791.0000
# Month=35, Predicted=775.4015, Expected=760.0000
# Month=36, Predicted=808.6375, Expected=802.0000
# Month=37, Predicted=809.7535, Expected=828.0000
# Month=38, Predicted=799.9630, Expected=778.0000
# Month=39, Predicted=827.2478, Expected=889.0000
# Month=40, Predicted=892.3402, Expected=902.0000
# Month=41, Predicted=983.2474, Expected=969.0000
# Month=42, Predicted=955.9606, Expected=947.0000
# Month=43, Predicted=896.8652, Expected=908.0000
# Month=44, Predicted=897.9628, Expected=867.0000
# Month=45, Predicted=840.8823, Expected=815.0000
# Month=46, Predicted=781.3552, Expected=812.0000
# Month=47, Predicted=794.5980, Expected=773.0000
# Month=48, Predicted=797.2280, Expected=813.0000
# Month=49, Predicted=809.6296, Expected=834.0000
# Month=50, Predicted=800.2214, Expected=782.0000
# Month=51, Predicted=829.6091, Expected=892.0000
# Month=52, Predicted=892.4285, Expected=903.0000
# Month=53, Predicted=978.7712, Expected=966.0000
# Month=54, Predicted=965.8555, Expected=937.0000
# Month=55, Predicted=892.7434, Expected=896.0000
# Month=56, Predicted=876.5994, Expected=858.0000
# Month=57, Predicted=832.0614, Expected=817.0000
# Month=58, Predicted=793.5569, Expected=827.0000
# Month=59, Predicted=824.9081, Expected=797.0000
# Month=60, Predicted=846.3127, Expected=843.0000
# Run 7 — RMSE: 28.394640, MSE: 806.255566, NMSE: 0.0032646117
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=749.3688, Expected=804.0000
# Month=2, Predicted=805.7842, Expected=756.0000
# Month=3, Predicted=800.2257, Expected=860.0000
# Month=4, Predicted=857.9238, Expected=878.0000
# Month=5, Predicted=951.8918, Expected=942.0000
# Month=6, Predicted=910.9816, Expected=913.0000
# Month=7, Predicted=867.0013, Expected=869.0000
# Month=8, Predicted=851.4336, Expected=834.0000
# Month=9, Predicted=810.0772, Expected=790.0000
# Month=10, Predicted=770.4995, Expected=800.0000
# Month=11, Predicted=791.6943, Expected=763.0000
# Month=12, Predicted=816.8611, Expected=800.0000
# Month=13, Predicted=797.2594, Expected=826.0000
# Month=14, Predicted=789.5525, Expected=799.0000
# Month=15, Predicted=869.8644, Expected=890.0000
# Month=16, Predicted=905.1697, Expected=900.0000
# Month=17, Predicted=951.1142, Expected=961.0000
# Month=18, Predicted=950.2775, Expected=935.0000
# Month=19, Predicted=891.0541, Expected=894.0000
# Month=20, Predicted=881.5995, Expected=855.0000
# Month=21, Predicted=832.1538, Expected=809.0000
# Month=22, Predicted=784.8992, Expected=810.0000
# Month=23, Predicted=798.4748, Expected=766.0000
# Month=24, Predicted=802.4312, Expected=805.0000
# Month=25, Predicted=795.3287, Expected=821.0000
# Month=26, Predicted=781.8909, Expected=773.0000
# Month=27, Predicted=838.5845, Expected=883.0000
# Month=28, Predicted=885.4262, Expected=898.0000
# Month=29, Predicted=975.1129, Expected=957.0000
# Month=30, Predicted=933.7768, Expected=924.0000
# Month=31, Predicted=901.4737, Expected=881.0000
# Month=32, Predicted=860.5461, Expected=837.0000
# Month=33, Predicted=809.9935, Expected=784.0000
# Month=34, Predicted=752.0694, Expected=791.0000
# Month=35, Predicted=773.7663, Expected=760.0000
# Month=36, Predicted=808.0041, Expected=802.0000
# Month=37, Predicted=805.6244, Expected=828.0000
# Month=38, Predicted=796.1214, Expected=778.0000
# Month=39, Predicted=874.1999, Expected=889.0000
# Month=40, Predicted=889.0141, Expected=902.0000
# Month=41, Predicted=977.8385, Expected=969.0000
# Month=42, Predicted=942.7278, Expected=947.0000
# Month=43, Predicted=890.7087, Expected=908.0000
# Month=44, Predicted=902.6384, Expected=867.0000
# Month=45, Predicted=845.1648, Expected=815.0000
# Month=46, Predicted=786.3772, Expected=812.0000
# Month=47, Predicted=793.6868, Expected=773.0000
# Month=48, Predicted=803.8224, Expected=813.0000
# Month=49, Predicted=808.4945, Expected=834.0000
# Month=50, Predicted=796.4397, Expected=782.0000
# Month=51, Predicted=862.1783, Expected=892.0000
# Month=52, Predicted=890.0987, Expected=903.0000
# Month=53, Predicted=975.2953, Expected=966.0000
# Month=54, Predicted=948.8696, Expected=937.0000
# Month=55, Predicted=892.9363, Expected=896.0000
# Month=56, Predicted=879.7732, Expected=858.0000
# Month=57, Predicted=835.5793, Expected=817.0000
# Month=58, Predicted=796.0440, Expected=827.0000
# Month=59, Predicted=821.4309, Expected=797.0000
# Month=60, Predicted=850.0053, Expected=843.0000
# Run 8 — RMSE: 23.477226, MSE: 551.180136, NMSE: 0.0024922860
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=749.7660, Expected=804.0000
# Month=2, Predicted=814.7597, Expected=756.0000
# Month=3, Predicted=805.0272, Expected=860.0000
# Month=4, Predicted=856.9488, Expected=878.0000
# Month=5, Predicted=947.1460, Expected=942.0000
# Month=6, Predicted=912.7232, Expected=913.0000
# Month=7, Predicted=862.4351, Expected=869.0000
# Month=8, Predicted=857.2299, Expected=834.0000
# Month=9, Predicted=808.0740, Expected=790.0000
# Month=10, Predicted=771.2387, Expected=800.0000
# Month=11, Predicted=789.6354, Expected=763.0000
# Month=12, Predicted=808.9063, Expected=800.0000
# Month=13, Predicted=797.1795, Expected=826.0000
# Month=14, Predicted=794.0412, Expected=799.0000
# Month=15, Predicted=860.1093, Expected=890.0000
# Month=16, Predicted=911.5641, Expected=900.0000
# Month=17, Predicted=952.5962, Expected=961.0000
# Month=18, Predicted=967.3861, Expected=935.0000
# Month=19, Predicted=886.0041, Expected=894.0000
# Month=20, Predicted=887.3202, Expected=855.0000
# Month=21, Predicted=830.8422, Expected=809.0000
# Month=22, Predicted=784.3708, Expected=810.0000
# Month=23, Predicted=795.9376, Expected=766.0000
# Month=24, Predicted=794.0985, Expected=805.0000
# Month=25, Predicted=792.6645, Expected=821.0000
# Month=26, Predicted=782.6404, Expected=773.0000
# Month=27, Predicted=821.1297, Expected=883.0000
# Month=28, Predicted=881.3836, Expected=898.0000
# Month=29, Predicted=968.2745, Expected=957.0000
# Month=30, Predicted=934.8657, Expected=924.0000
# Month=31, Predicted=897.9583, Expected=881.0000
# Month=32, Predicted=864.7407, Expected=837.0000
# Month=33, Predicted=808.2504, Expected=784.0000
# Month=34, Predicted=750.0869, Expected=791.0000
# Month=35, Predicted=769.3718, Expected=760.0000
# Month=36, Predicted=804.5011, Expected=802.0000
# Month=37, Predicted=808.0026, Expected=828.0000
# Month=38, Predicted=805.5389, Expected=778.0000
# Month=39, Predicted=838.8961, Expected=889.0000
# Month=40, Predicted=884.8797, Expected=902.0000
# Month=41, Predicted=970.7352, Expected=969.0000
# Month=42, Predicted=948.2497, Expected=947.0000
# Month=43, Predicted=890.8109, Expected=908.0000
# Month=44, Predicted=907.2665, Expected=867.0000
# Month=45, Predicted=844.2943, Expected=815.0000
# Month=46, Predicted=785.1168, Expected=812.0000
# Month=47, Predicted=789.6014, Expected=773.0000
# Month=48, Predicted=798.0955, Expected=813.0000
# Month=49, Predicted=807.6483, Expected=834.0000
# Month=50, Predicted=801.6105, Expected=782.0000
# Month=51, Predicted=834.8629, Expected=892.0000
# Month=52, Predicted=884.8583, Expected=903.0000
# Month=53, Predicted=968.8257, Expected=966.0000
# Month=54, Predicted=960.3547, Expected=937.0000
# Month=55, Predicted=888.4842, Expected=896.0000
# Month=56, Predicted=885.6103, Expected=858.0000
# Month=57, Predicted=834.3552, Expected=817.0000
# Month=58, Predicted=795.8837, Expected=827.0000
# Month=59, Predicted=820.4831, Expected=797.0000
# Month=60, Predicted=845.9333, Expected=843.0000
# Run 9 — RMSE: 26.821983, MSE: 719.418790, NMSE: 0.0031973276
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=748.4717, Expected=804.0000
# Month=2, Predicted=796.6164, Expected=756.0000
# Month=3, Predicted=811.4825, Expected=860.0000
# Month=4, Predicted=852.7197, Expected=878.0000
# Month=5, Predicted=937.8933, Expected=942.0000
# Month=6, Predicted=914.8189, Expected=913.0000
# Month=7, Predicted=865.0328, Expected=869.0000
# Month=8, Predicted=858.0915, Expected=834.0000
# Month=9, Predicted=807.3657, Expected=790.0000
# Month=10, Predicted=772.9749, Expected=800.0000
# Month=11, Predicted=788.0014, Expected=763.0000
# Month=12, Predicted=823.3233, Expected=800.0000
# Month=13, Predicted=795.8038, Expected=826.0000
# Month=14, Predicted=792.6263, Expected=799.0000
# Month=15, Predicted=863.6898, Expected=890.0000
# Month=16, Predicted=907.8547, Expected=900.0000
# Month=17, Predicted=939.5767, Expected=961.0000
# Month=18, Predicted=967.7084, Expected=935.0000
# Month=19, Predicted=890.4007, Expected=894.0000
# Month=20, Predicted=888.5815, Expected=855.0000
# Month=21, Predicted=830.7610, Expected=809.0000
# Month=22, Predicted=785.3295, Expected=810.0000
# Month=23, Predicted=794.1920, Expected=766.0000
# Month=24, Predicted=810.6557, Expected=805.0000
# Month=25, Predicted=790.4297, Expected=821.0000
# Month=26, Predicted=787.7117, Expected=773.0000
# Month=27, Predicted=849.9785, Expected=883.0000
# Month=28, Predicted=876.5704, Expected=898.0000
# Month=29, Predicted=952.4002, Expected=957.0000
# Month=30, Predicted=944.7043, Expected=924.0000
# Month=31, Predicted=902.0816, Expected=881.0000
# Month=32, Predicted=865.3073, Expected=837.0000
# Month=33, Predicted=808.1268, Expected=784.0000
# Month=34, Predicted=750.3579, Expected=791.0000
# Month=35, Predicted=766.3868, Expected=760.0000
# Month=36, Predicted=810.4989, Expected=802.0000
# Month=37, Predicted=806.9385, Expected=828.0000
# Month=38, Predicted=800.8160, Expected=778.0000
# Month=39, Predicted=872.2520, Expected=889.0000
# Month=40, Predicted=880.0388, Expected=902.0000
# Month=41, Predicted=952.8839, Expected=969.0000
# Month=42, Predicted=957.3938, Expected=947.0000
# Month=43, Predicted=888.1110, Expected=908.0000
# Month=44, Predicted=908.4440, Expected=867.0000
# Month=45, Predicted=844.5419, Expected=815.0000
# Month=46, Predicted=785.8109, Expected=812.0000
# Month=47, Predicted=786.8487, Expected=773.0000
# Month=48, Predicted=805.5849, Expected=813.0000
# Month=49, Predicted=806.1099, Expected=834.0000
# Month=50, Predicted=801.9723, Expected=782.0000
# Month=51, Predicted=869.8046, Expected=892.0000
# Month=52, Predicted=879.7888, Expected=903.0000
# Month=53, Predicted=950.2424, Expected=966.0000
# Month=54, Predicted=966.8992, Expected=937.0000
# Month=55, Predicted=891.6461, Expected=896.0000
# Month=56, Predicted=886.4100, Expected=858.0000
# Month=57, Predicted=834.3201, Expected=817.0000
# Month=58, Predicted=796.8860, Expected=827.0000
# Month=59, Predicted=819.3891, Expected=797.0000
# Month=60, Predicted=853.1174, Expected=843.0000
# Run 10 — RMSE: 24.348677, MSE: 592.858048, NMSE: 0.0027833406
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=751.2259, Expected=804.0000
# Month=2, Predicted=796.4150, Expected=756.0000
# Month=3, Predicted=788.1600, Expected=860.0000
# Month=4, Predicted=862.7061, Expected=878.0000
# Month=5, Predicted=960.2952, Expected=942.0000
# Month=6, Predicted=915.5500, Expected=913.0000
# Month=7, Predicted=864.1351, Expected=869.0000
# Month=8, Predicted=851.6954, Expected=834.0000
# Month=9, Predicted=806.0793, Expected=790.0000
# Month=10, Predicted=767.4665, Expected=800.0000
# Month=11, Predicted=791.7446, Expected=763.0000
# Month=12, Predicted=809.1536, Expected=800.0000
# Month=13, Predicted=798.5341, Expected=826.0000
# Month=14, Predicted=791.8914, Expected=799.0000
# Month=15, Predicted=854.1793, Expected=890.0000
# Month=16, Predicted=921.0508, Expected=900.0000
# Month=17, Predicted=943.7715, Expected=961.0000
# Month=18, Predicted=965.9100, Expected=935.0000
# Month=19, Predicted=887.8340, Expected=894.0000
# Month=20, Predicted=881.9212, Expected=855.0000
# Month=21, Predicted=828.1041, Expected=809.0000
# Month=22, Predicted=780.7908, Expected=810.0000
# Month=23, Predicted=797.8132, Expected=766.0000
# Month=24, Predicted=791.0598, Expected=805.0000
# Month=25, Predicted=794.1251, Expected=821.0000
# Month=26, Predicted=784.1695, Expected=773.0000
# Month=27, Predicted=818.7282, Expected=883.0000
# Month=28, Predicted=888.3158, Expected=898.0000
# Month=29, Predicted=984.5586, Expected=957.0000
# Month=30, Predicted=939.6576, Expected=924.0000
# Month=31, Predicted=895.7616, Expected=881.0000
# Month=32, Predicted=859.7608, Expected=837.0000
# Month=33, Predicted=805.2582, Expected=784.0000
# Month=34, Predicted=746.4303, Expected=791.0000
# Month=35, Predicted=772.1219, Expected=760.0000
# Month=36, Predicted=805.5769, Expected=802.0000
# Month=37, Predicted=809.9061, Expected=828.0000
# Month=38, Predicted=798.5587, Expected=778.0000
# Month=39, Predicted=833.2727, Expected=889.0000
# Month=40, Predicted=891.7825, Expected=902.0000
# Month=41, Predicted=986.2495, Expected=969.0000
# Month=42, Predicted=952.9877, Expected=947.0000
# Month=43, Predicted=896.6307, Expected=908.0000
# Month=44, Predicted=901.8776, Expected=867.0000
# Month=45, Predicted=841.1247, Expected=815.0000
# Month=46, Predicted=781.1777, Expected=812.0000
# Month=47, Predicted=791.7150, Expected=773.0000
# Month=48, Predicted=795.5183, Expected=813.0000
# Month=49, Predicted=809.0792, Expected=834.0000
# Month=50, Predicted=799.1181, Expected=782.0000
# Month=51, Predicted=832.1492, Expected=892.0000
# Month=52, Predicted=891.5992, Expected=903.0000
# Month=53, Predicted=981.6644, Expected=966.0000
# Month=54, Predicted=963.5847, Expected=937.0000
# Month=55, Predicted=890.2889, Expected=896.0000
# Month=56, Predicted=880.4181, Expected=858.0000
# Month=57, Predicted=831.7302, Expected=817.0000
# Month=58, Predicted=792.7075, Expected=827.0000
# Month=59, Predicted=822.4799, Expected=797.0000
# Month=60, Predicted=846.6824, Expected=843.0000
# Run 11 — RMSE: 27.445761, MSE: 753.269810, NMSE: 0.0030329112
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=750.3063, Expected=804.0000
# Month=2, Predicted=797.4849, Expected=756.0000
# Month=3, Predicted=798.6403, Expected=860.0000
# Month=4, Predicted=849.1866, Expected=878.0000
# Month=5, Predicted=961.9358, Expected=942.0000
# Month=6, Predicted=913.8435, Expected=913.0000
# Month=7, Predicted=867.7105, Expected=869.0000
# Month=8, Predicted=857.6541, Expected=834.0000
# Month=9, Predicted=805.5170, Expected=790.0000
# Month=10, Predicted=772.5465, Expected=800.0000
# Month=11, Predicted=786.8463, Expected=763.0000
# Month=12, Predicted=821.1439, Expected=800.0000
# Month=13, Predicted=797.2420, Expected=826.0000
# Month=14, Predicted=788.6191, Expected=799.0000
# Month=15, Predicted=855.9599, Expected=890.0000
# Month=16, Predicted=916.9809, Expected=900.0000
# Month=17, Predicted=948.2837, Expected=961.0000
# Month=18, Predicted=960.5640, Expected=935.0000
# Month=19, Predicted=890.2028, Expected=894.0000
# Month=20, Predicted=889.2643, Expected=855.0000
# Month=21, Predicted=829.6023, Expected=809.0000
# Month=22, Predicted=783.9827, Expected=810.0000
# Month=23, Predicted=792.2566, Expected=766.0000
# Month=24, Predicted=807.3577, Expected=805.0000
# Month=25, Predicted=789.7063, Expected=821.0000
# Month=26, Predicted=780.2114, Expected=773.0000
# Month=27, Predicted=833.5625, Expected=883.0000
# Month=28, Predicted=875.7396, Expected=898.0000
# Month=29, Predicted=986.3974, Expected=957.0000
# Month=30, Predicted=940.3550, Expected=924.0000
# Month=31, Predicted=898.6182, Expected=881.0000
# Month=32, Predicted=863.8889, Expected=837.0000
# Month=33, Predicted=806.1406, Expected=784.0000
# Month=34, Predicted=747.5488, Expected=791.0000
# Month=35, Predicted=762.3532, Expected=760.0000
# Month=36, Predicted=816.0942, Expected=802.0000
# Month=37, Predicted=810.6871, Expected=828.0000
# Month=38, Predicted=800.1172, Expected=778.0000
# Month=39, Predicted=842.3550, Expected=889.0000
# Month=40, Predicted=878.0279, Expected=902.0000
# Month=41, Predicted=988.8459, Expected=969.0000
# Month=42, Predicted=952.1195, Expected=947.0000
# Month=43, Predicted=899.0705, Expected=908.0000
# Month=44, Predicted=910.3880, Expected=867.0000
# Month=45, Predicted=843.8974, Expected=815.0000
# Month=46, Predicted=783.8559, Expected=812.0000
# Month=47, Predicted=783.1371, Expected=773.0000
# Month=48, Predicted=810.5677, Expected=813.0000
# Month=49, Predicted=806.9917, Expected=834.0000
# Month=50, Predicted=797.4929, Expected=782.0000
# Month=51, Predicted=845.7953, Expected=892.0000
# Month=52, Predicted=877.2689, Expected=903.0000
# Month=53, Predicted=985.2876, Expected=966.0000
# Month=54, Predicted=959.9895, Expected=937.0000
# Month=55, Predicted=892.4772, Expected=896.0000
# Month=56, Predicted=886.1370, Expected=858.0000
# Month=57, Predicted=833.1126, Expected=817.0000
# Month=58, Predicted=795.9504, Expected=827.0000
# Month=59, Predicted=819.0750, Expected=797.0000
# Month=60, Predicted=853.3415, Expected=843.0000
# Run 12 — RMSE: 26.462392, MSE: 700.258213, NMSE: 0.0028546164
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=747.9995, Expected=804.0000
# Month=2, Predicted=806.3612, Expected=756.0000
# Month=3, Predicted=799.6523, Expected=860.0000
# Month=4, Predicted=855.6816, Expected=878.0000
# Month=5, Predicted=962.3087, Expected=942.0000
# Month=6, Predicted=912.9535, Expected=913.0000
# Month=7, Predicted=864.6155, Expected=869.0000
# Month=8, Predicted=856.5906, Expected=834.0000
# Month=9, Predicted=807.6387, Expected=790.0000
# Month=10, Predicted=771.9528, Expected=800.0000
# Month=11, Predicted=788.0791, Expected=763.0000
# Month=12, Predicted=813.7610, Expected=800.0000
# Month=13, Predicted=795.3113, Expected=826.0000
# Month=14, Predicted=792.5801, Expected=799.0000
# Month=15, Predicted=867.3349, Expected=890.0000
# Month=16, Predicted=909.8265, Expected=900.0000
# Month=17, Predicted=941.0951, Expected=961.0000
# Month=18, Predicted=965.6931, Expected=935.0000
# Month=19, Predicted=887.8794, Expected=894.0000
# Month=20, Predicted=886.5964, Expected=855.0000
# Month=21, Predicted=830.7801, Expected=809.0000
# Month=22, Predicted=785.1096, Expected=810.0000
# Month=23, Predicted=794.3213, Expected=766.0000
# Month=24, Predicted=798.0255, Expected=805.0000
# Month=25, Predicted=790.6689, Expected=821.0000
# Month=26, Predicted=782.2928, Expected=773.0000
# Month=27, Predicted=829.9108, Expected=883.0000
# Month=28, Predicted=880.8968, Expected=898.0000
# Month=29, Predicted=986.9737, Expected=957.0000
# Month=30, Predicted=934.8175, Expected=924.0000
# Month=31, Predicted=896.2760, Expected=881.0000
# Month=32, Predicted=863.9214, Expected=837.0000
# Month=33, Predicted=808.6096, Expected=784.0000
# Month=34, Predicted=751.3747, Expected=791.0000
# Month=35, Predicted=767.5005, Expected=760.0000
# Month=36, Predicted=807.6034, Expected=802.0000
# Month=37, Predicted=806.5378, Expected=828.0000
# Month=38, Predicted=804.2367, Expected=778.0000
# Month=39, Predicted=853.3307, Expected=889.0000
# Month=40, Predicted=884.1792, Expected=902.0000
# Month=41, Predicted=988.0924, Expected=969.0000
# Month=42, Predicted=948.2495, Expected=947.0000
# Month=43, Predicted=896.9567, Expected=908.0000
# Month=44, Predicted=906.5657, Expected=867.0000
# Month=45, Predicted=844.4160, Expected=815.0000
# Month=46, Predicted=786.3489, Expected=812.0000
# Month=47, Predicted=787.7633, Expected=773.0000
# Month=48, Predicted=800.9634, Expected=813.0000
# Month=49, Predicted=805.9227, Expected=834.0000
# Month=50, Predicted=801.1655, Expected=782.0000
# Month=51, Predicted=847.1177, Expected=892.0000
# Month=52, Predicted=883.9419, Expected=903.0000
# Month=53, Predicted=982.3599, Expected=966.0000
# Month=54, Predicted=961.0837, Expected=937.0000
# Month=55, Predicted=890.7709, Expected=896.0000
# Month=56, Predicted=884.7340, Expected=858.0000
# Month=57, Predicted=834.2394, Expected=817.0000
# Month=58, Predicted=796.2247, Expected=827.0000
# Month=59, Predicted=819.0864, Expected=797.0000
# Month=60, Predicted=849.2684, Expected=843.0000
# Run 13 — RMSE: 25.983828, MSE: 675.159316, NMSE: 0.0028188930
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=750.4072, Expected=804.0000
# Month=2, Predicted=797.7085, Expected=756.0000
# Month=3, Predicted=826.7024, Expected=860.0000
# Month=4, Predicted=851.7544, Expected=878.0000
# Month=5, Predicted=942.1246, Expected=942.0000
# Month=6, Predicted=916.4981, Expected=913.0000
# Month=7, Predicted=864.0408, Expected=869.0000
# Month=8, Predicted=850.8975, Expected=834.0000
# Month=9, Predicted=807.9097, Expected=790.0000
# Month=10, Predicted=772.8045, Expected=800.0000
# Month=11, Predicted=788.7147, Expected=763.0000
# Month=12, Predicted=816.0104, Expected=800.0000
# Month=13, Predicted=797.7293, Expected=826.0000
# Month=14, Predicted=787.5899, Expected=799.0000
# Month=15, Predicted=873.0325, Expected=890.0000
# Month=16, Predicted=909.3666, Expected=900.0000
# Month=17, Predicted=957.0496, Expected=961.0000
# Month=18, Predicted=965.2501, Expected=935.0000
# Month=19, Predicted=888.0240, Expected=894.0000
# Month=20, Predicted=882.0059, Expected=855.0000
# Month=21, Predicted=831.3599, Expected=809.0000
# Month=22, Predicted=785.4569, Expected=810.0000
# Month=23, Predicted=794.7249, Expected=766.0000
# Month=24, Predicted=799.7660, Expected=805.0000
# Month=25, Predicted=792.3746, Expected=821.0000
# Month=26, Predicted=781.6697, Expected=773.0000
# Month=27, Predicted=830.0175, Expected=883.0000
# Month=28, Predicted=881.5476, Expected=898.0000
# Month=29, Predicted=961.0410, Expected=957.0000
# Month=30, Predicted=938.0632, Expected=924.0000
# Month=31, Predicted=905.4372, Expected=881.0000
# Month=32, Predicted=859.5231, Expected=837.0000
# Month=33, Predicted=808.6524, Expected=784.0000
# Month=34, Predicted=750.8841, Expected=791.0000
# Month=35, Predicted=767.1412, Expected=760.0000
# Month=36, Predicted=809.7932, Expected=802.0000
# Month=37, Predicted=809.0001, Expected=828.0000
# Month=38, Predicted=786.2616, Expected=778.0000
# Month=39, Predicted=854.9610, Expected=889.0000
# Month=40, Predicted=884.7507, Expected=902.0000
# Month=41, Predicted=963.8382, Expected=969.0000
# Month=42, Predicted=950.6806, Expected=947.0000
# Month=43, Predicted=890.9655, Expected=908.0000
# Month=44, Predicted=900.3185, Expected=867.0000
# Month=45, Predicted=845.2976, Expected=815.0000
# Month=46, Predicted=786.3130, Expected=812.0000
# Month=47, Predicted=787.4734, Expected=773.0000
# Month=48, Predicted=802.6581, Expected=813.0000
# Month=49, Predicted=807.8677, Expected=834.0000
# Month=50, Predicted=793.5579, Expected=782.0000
# Month=51, Predicted=848.0939, Expected=892.0000
# Month=52, Predicted=884.4900, Expected=903.0000
# Month=53, Predicted=963.3792, Expected=966.0000
# Month=54, Predicted=958.4176, Expected=937.0000
# Month=55, Predicted=889.3188, Expected=896.0000
# Month=56, Predicted=879.3847, Expected=858.0000
# Month=57, Predicted=834.7561, Expected=817.0000
# Month=58, Predicted=796.8131, Expected=827.0000
# Month=59, Predicted=819.9499, Expected=797.0000
# Month=60, Predicted=851.7869, Expected=843.0000
# Run 14 — RMSE: 23.234286, MSE: 539.832050, NMSE: 0.0024394315
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=750.9536, Expected=804.0000
# Month=2, Predicted=798.1042, Expected=756.0000
# Month=3, Predicted=792.9361, Expected=860.0000
# Month=4, Predicted=870.8049, Expected=878.0000
# Month=5, Predicted=952.8990, Expected=942.0000
# Month=6, Predicted=915.4322, Expected=913.0000
# Month=7, Predicted=866.2383, Expected=869.0000
# Month=8, Predicted=843.7609, Expected=834.0000
# Month=9, Predicted=808.3542, Expected=790.0000
# Month=10, Predicted=762.4179, Expected=800.0000
# Month=11, Predicted=795.5955, Expected=763.0000
# Month=12, Predicted=819.2087, Expected=800.0000
# Month=13, Predicted=798.6661, Expected=826.0000
# Month=14, Predicted=787.7606, Expected=799.0000
# Month=15, Predicted=873.3786, Expected=890.0000
# Month=16, Predicted=910.3857, Expected=900.0000
# Month=17, Predicted=957.3895, Expected=961.0000
# Month=18, Predicted=965.8071, Expected=935.0000
# Month=19, Predicted=891.9567, Expected=894.0000
# Month=20, Predicted=872.6973, Expected=855.0000
# Month=21, Predicted=827.8160, Expected=809.0000
# Month=22, Predicted=778.0829, Expected=810.0000
# Month=23, Predicted=803.2186, Expected=766.0000
# Month=24, Predicted=791.5637, Expected=805.0000
# Month=25, Predicted=798.3883, Expected=821.0000
# Month=26, Predicted=782.6437, Expected=773.0000
# Month=27, Predicted=847.7194, Expected=883.0000
# Month=28, Predicted=896.1517, Expected=898.0000
# Month=29, Predicted=977.2521, Expected=957.0000
# Month=30, Predicted=947.7716, Expected=924.0000
# Month=31, Predicted=902.0664, Expected=881.0000
# Month=32, Predicted=854.3031, Expected=837.0000
# Month=33, Predicted=805.6618, Expected=784.0000
# Month=34, Predicted=746.1106, Expected=791.0000
# Month=35, Predicted=783.0784, Expected=760.0000
# Month=36, Predicted=808.0490, Expected=802.0000
# Month=37, Predicted=807.0512, Expected=828.0000
# Month=38, Predicted=794.0746, Expected=778.0000
# Month=39, Predicted=873.2636, Expected=889.0000
# Month=40, Predicted=900.9602, Expected=902.0000
# Month=41, Predicted=980.7665, Expected=969.0000
# Month=42, Predicted=956.7165, Expected=947.0000
# Month=43, Predicted=888.6994, Expected=908.0000
# Month=44, Predicted=890.6203, Expected=867.0000
# Month=45, Predicted=839.2441, Expected=815.0000
# Month=46, Predicted=778.8909, Expected=812.0000
# Month=47, Predicted=801.8275, Expected=773.0000
# Month=48, Predicted=789.0168, Expected=813.0000
# Month=49, Predicted=810.0232, Expected=834.0000
# Month=50, Predicted=795.5343, Expected=782.0000
# Month=51, Predicted=871.0597, Expected=892.0000
# Month=52, Predicted=902.0516, Expected=903.0000
# Month=53, Predicted=979.0473, Expected=966.0000
# Month=54, Predicted=965.5856, Expected=937.0000
# Month=55, Predicted=893.1168, Expected=896.0000
# Month=56, Predicted=872.9040, Expected=858.0000
# Month=57, Predicted=831.5492, Expected=817.0000
# Month=58, Predicted=790.0398, Expected=827.0000
# Month=59, Predicted=824.0107, Expected=797.0000
# Month=60, Predicted=853.5544, Expected=843.0000
# Run 15 — RMSE: 24.040845, MSE: 577.962221, NMSE: 0.0023462982
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=749.0678, Expected=804.0000
# Month=2, Predicted=796.4999, Expected=756.0000
# Month=3, Predicted=790.7149, Expected=860.0000
# Month=4, Predicted=851.7804, Expected=878.0000
# Month=5, Predicted=968.3008, Expected=942.0000
# Month=6, Predicted=911.6814, Expected=913.0000
# Month=7, Predicted=869.7405, Expected=869.0000
# Month=8, Predicted=858.2782, Expected=834.0000
# Month=9, Predicted=807.9484, Expected=790.0000
# Month=10, Predicted=773.2114, Expected=800.0000
# Month=11, Predicted=786.8397, Expected=763.0000
# Month=12, Predicted=813.0147, Expected=800.0000
# Month=13, Predicted=796.3491, Expected=826.0000
# Month=14, Predicted=797.1555, Expected=799.0000
# Month=15, Predicted=857.1438, Expected=890.0000
# Month=16, Predicted=914.5101, Expected=900.0000
# Month=17, Predicted=936.5149, Expected=961.0000
# Month=18, Predicted=950.3670, Expected=935.0000
# Month=19, Predicted=892.2219, Expected=894.0000
# Month=20, Predicted=888.8103, Expected=855.0000
# Month=21, Predicted=831.6333, Expected=809.0000
# Month=22, Predicted=785.9608, Expected=810.0000
# Month=23, Predicted=792.8741, Expected=766.0000
# Month=24, Predicted=799.8304, Expected=805.0000
# Month=25, Predicted=790.5457, Expected=821.0000
# Month=26, Predicted=788.9638, Expected=773.0000
# Month=27, Predicted=825.0088, Expected=883.0000
# Month=28, Predicted=877.2529, Expected=898.0000
# Month=29, Predicted=995.6073, Expected=957.0000
# Month=30, Predicted=929.1511, Expected=924.0000
# Month=31, Predicted=892.4215, Expected=881.0000
# Month=32, Predicted=865.6914, Expected=837.0000
# Month=33, Predicted=809.1161, Expected=784.0000
# Month=34, Predicted=751.6189, Expected=791.0000
# Month=35, Predicted=764.7501, Expected=760.0000
# Month=36, Predicted=808.7841, Expected=802.0000
# Month=37, Predicted=808.1882, Expected=828.0000
# Month=38, Predicted=803.8046, Expected=778.0000
# Month=39, Predicted=837.7526, Expected=889.0000
# Month=40, Predicted=880.3217, Expected=902.0000
# Month=41, Predicted=996.1409, Expected=969.0000
# Month=42, Predicted=942.1756, Expected=947.0000
# Month=43, Predicted=906.1845, Expected=908.0000
# Month=44, Predicted=908.4145, Expected=867.0000
# Month=45, Predicted=845.6552, Expected=815.0000
# Month=46, Predicted=787.0545, Expected=812.0000
# Month=47, Predicted=785.5000, Expected=773.0000
# Month=48, Predicted=803.3406, Expected=813.0000
# Month=49, Predicted=806.3262, Expected=834.0000
# Month=50, Predicted=805.1242, Expected=782.0000
# Month=51, Predicted=837.9888, Expected=892.0000
# Month=52, Predicted=879.8533, Expected=903.0000
# Month=53, Predicted=988.4189, Expected=966.0000
# Month=54, Predicted=948.4247, Expected=937.0000
# Month=55, Predicted=893.7569, Expected=896.0000
# Month=56, Predicted=886.4928, Expected=858.0000
# Month=57, Predicted=835.0097, Expected=817.0000
# Month=58, Predicted=797.1401, Expected=827.0000
# Month=59, Predicted=818.2293, Expected=797.0000
# Month=60, Predicted=849.1125, Expected=843.0000
# Run 16 — RMSE: 27.461833, MSE: 754.152292, NMSE: 0.0031415550
#
# ===== RUN 17/30 =====
# ...
# Month=40, Predicted=884.9540, Expected=902.0000
# Month=41, Predicted=966.6281, Expected=969.0000
# Month=42, Predicted=937.5168, Expected=947.0000
# Month=43, Predicted=890.7423, Expected=908.0000
# Month=44, Predicted=900.2468, Expected=867.0000
# Month=45, Predicted=844.0399, Expected=815.0000
# Month=46, Predicted=788.9784, Expected=812.0000
# Month=47, Predicted=787.4384, Expected=773.0000
# Month=48, Predicted=787.0438, Expected=813.0000
# Month=49, Predicted=804.1999, Expected=834.0000
# Month=50, Predicted=795.3590, Expected=782.0000
# Month=51, Predicted=893.4437, Expected=892.0000
# Month=52, Predicted=884.9229, Expected=903.0000
# Month=53, Predicted=967.0197, Expected=966.0000
# Month=54, Predicted=942.5778, Expected=937.0000
# Month=55, Predicted=890.0764, Expected=896.0000
# Month=56, Predicted=879.4606, Expected=858.0000
# Month=57, Predicted=834.4079, Expected=817.0000
# Month=58, Predicted=795.0004, Expected=827.0000
# Month=59, Predicted=815.8477, Expected=797.0000
# Month=60, Predicted=852.9825, Expected=843.0000
# Run 25 — RMSE: 22.521450, MSE: 507.215730, NMSE: 0.0023009880
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=747.7797, Expected=804.0000
# Month=2, Predicted=806.2058, Expected=756.0000
# Month=3, Predicted=826.5213, Expected=860.0000
# Month=4, Predicted=849.7156, Expected=878.0000
# Month=5, Predicted=953.0946, Expected=942.0000
# Month=6, Predicted=915.5508, Expected=913.0000
# Month=7, Predicted=866.9361, Expected=869.0000
# Month=8, Predicted=860.1733, Expected=834.0000
# Month=9, Predicted=807.3953, Expected=790.0000
# Month=10, Predicted=772.9290, Expected=800.0000
# Month=11, Predicted=786.2845, Expected=763.0000
# Month=12, Predicted=820.3690, Expected=800.0000
# Month=13, Predicted=795.0571, Expected=826.0000
# Month=14, Predicted=788.5501, Expected=799.0000
# Month=15, Predicted=864.4904, Expected=890.0000
# Month=16, Predicted=904.7735, Expected=900.0000
# Month=17, Predicted=953.2840, Expected=961.0000
# Month=18, Predicted=968.5693, Expected=935.0000
# Month=19, Predicted=890.9336, Expected=894.0000
# Month=20, Predicted=891.1877, Expected=855.0000
# Month=21, Predicted=830.9530, Expected=809.0000
# Month=22, Predicted=785.2413, Expected=810.0000
# Month=23, Predicted=792.5493, Expected=766.0000
# Month=24, Predicted=808.9967, Expected=805.0000
# Month=25, Predicted=789.5964, Expected=821.0000
# Month=26, Predicted=780.5813, Expected=773.0000
# Month=27, Predicted=837.5517, Expected=883.0000
# Month=28, Predicted=873.8469, Expected=898.0000
# Month=29, Predicted=974.8743, Expected=957.0000
# Month=30, Predicted=943.2317, Expected=924.0000
# Month=31, Predicted=909.3319, Expected=881.0000
# Month=32, Predicted=866.3772, Expected=837.0000
# Month=33, Predicted=808.3128, Expected=784.0000
# Month=34, Predicted=750.5652, Expected=791.0000
# Month=35, Predicted=765.1274, Expected=760.0000
# Month=36, Predicted=813.6365, Expected=802.0000
# Month=37, Predicted=806.7018, Expected=828.0000
# Month=38, Predicted=796.7335, Expected=778.0000
# Month=39, Predicted=855.3689, Expected=889.0000
# Month=40, Predicted=877.3069, Expected=902.0000
# Month=41, Predicted=977.5605, Expected=969.0000
# Month=42, Predicted=956.3340, Expected=947.0000
# Month=43, Predicted=891.7512, Expected=908.0000
# Month=44, Predicted=912.5269, Expected=867.0000
# Month=45, Predicted=844.9457, Expected=815.0000
# Month=46, Predicted=785.9967, Expected=812.0000
# Month=47, Predicted=785.7971, Expected=773.0000
# Month=48, Predicted=810.7638, Expected=813.0000
# Month=49, Predicted=805.2833, Expected=834.0000
# Month=50, Predicted=796.0246, Expected=782.0000
# Month=51, Predicted=853.1911, Expected=892.0000
# Month=52, Predicted=877.4420, Expected=903.0000
# Month=53, Predicted=975.5566, Expected=966.0000
# Month=54, Predicted=965.8948, Expected=937.0000
# Month=55, Predicted=892.8410, Expected=896.0000
# Month=56, Predicted=888.3800, Expected=858.0000
# Month=57, Predicted=834.3881, Expected=817.0000
# Month=58, Predicted=796.6653, Expected=827.0000
# Month=59, Predicted=817.5565, Expected=797.0000
# Month=60, Predicted=854.2882, Expected=843.0000
# Run 26 — RMSE: 25.333406, MSE: 641.781462, NMSE: 0.0027103560
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=749.0262, Expected=804.0000
# Month=2, Predicted=805.4446, Expected=756.0000
# Month=3, Predicted=855.2705, Expected=860.0000
# Month=4, Predicted=859.5410, Expected=878.0000
# Month=5, Predicted=946.0274, Expected=942.0000
# Month=6, Predicted=916.6650, Expected=913.0000
# Month=7, Predicted=861.7774, Expected=869.0000
# Month=8, Predicted=840.9273, Expected=834.0000
# Month=9, Predicted=808.4584, Expected=790.0000
# Month=10, Predicted=765.8532, Expected=800.0000
# Month=11, Predicted=797.4461, Expected=763.0000
# Month=12, Predicted=816.8414, Expected=800.0000
# Month=13, Predicted=796.4988, Expected=826.0000
# Month=14, Predicted=793.9325, Expected=799.0000
# Month=15, Predicted=882.2960, Expected=890.0000
# Month=16, Predicted=908.5948, Expected=900.0000
# Month=17, Predicted=948.5061, Expected=961.0000
# Month=18, Predicted=958.7151, Expected=935.0000
# Month=19, Predicted=886.0357, Expected=894.0000
# Month=20, Predicted=871.8117, Expected=855.0000
# Month=21, Predicted=828.2281, Expected=809.0000
# Month=22, Predicted=780.3555, Expected=810.0000
# Month=23, Predicted=804.6586, Expected=766.0000
# Month=24, Predicted=798.4220, Expected=805.0000
# Month=25, Predicted=796.1422, Expected=821.0000
# Month=26, Predicted=787.5874, Expected=773.0000
# Month=27, Predicted=837.3431, Expected=883.0000
# Month=28, Predicted=886.0008, Expected=898.0000
# Month=29, Predicted=968.5307, Expected=957.0000
# Month=30, Predicted=941.7822, Expected=924.0000
# Month=31, Predicted=903.9357, Expected=881.0000
# Month=32, Predicted=849.5823, Expected=837.0000
# Month=33, Predicted=806.3914, Expected=784.0000
# Month=34, Predicted=747.5321, Expected=791.0000
# Month=35, Predicted=778.1417, Expected=760.0000
# Month=36, Predicted=808.5247, Expected=802.0000
# Month=37, Predicted=805.3892, Expected=828.0000
# Month=38, Predicted=799.1151, Expected=778.0000
# Month=39, Predicted=859.6966, Expected=889.0000
# Month=40, Predicted=888.0541, Expected=902.0000
# Month=41, Predicted=971.8361, Expected=969.0000
# Month=42, Predicted=952.8256, Expected=947.0000
# Month=43, Predicted=897.4441, Expected=908.0000
# Month=44, Predicted=892.0769, Expected=867.0000
# Month=45, Predicted=839.6947, Expected=815.0000
# Month=46, Predicted=780.6914, Expected=812.0000
# Month=47, Predicted=799.0507, Expected=773.0000
# Month=48, Predicted=798.6179, Expected=813.0000
# Month=49, Predicted=809.2206, Expected=834.0000
# Month=50, Predicted=802.6466, Expected=782.0000
# Month=51, Predicted=855.2849, Expected=892.0000
# Month=52, Predicted=887.5978, Expected=903.0000
# Month=53, Predicted=969.8274, Expected=966.0000
# Month=54, Predicted=958.7965, Expected=937.0000
# Month=55, Predicted=886.1577, Expected=896.0000
# Month=56, Predicted=869.8795, Expected=858.0000
# Month=57, Predicted=832.2753, Expected=817.0000
# Month=58, Predicted=792.4362, Expected=827.0000
# Month=59, Predicted=826.9336, Expected=797.0000
# Month=60, Predicted=851.0611, Expected=843.0000
# Run 27 — RMSE: 23.015347, MSE: 529.706187, NMSE: 0.0024220757
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=748.5959, Expected=804.0000
# Month=2, Predicted=805.0954, Expected=756.0000
# Month=3, Predicted=806.2770, Expected=860.0000
# Month=4, Predicted=861.2035, Expected=878.0000
# Month=5, Predicted=949.2309, Expected=942.0000
# Month=6, Predicted=917.2784, Expected=913.0000
# Month=7, Predicted=864.4877, Expected=869.0000
# Month=8, Predicted=853.7934, Expected=834.0000
# Month=9, Predicted=806.9313, Expected=790.0000
# Month=10, Predicted=770.8564, Expected=800.0000
# Month=11, Predicted=790.4692, Expected=763.0000
# Month=12, Predicted=813.7499, Expected=800.0000
# Month=13, Predicted=796.0541, Expected=826.0000
# Month=14, Predicted=789.4417, Expected=799.0000
# Month=15, Predicted=867.1667, Expected=890.0000
# Month=16, Predicted=909.4310, Expected=900.0000
# Month=17, Predicted=943.0754, Expected=961.0000
# Month=18, Predicted=949.9955, Expected=935.0000
# Month=19, Predicted=887.1012, Expected=894.0000
# Month=20, Predicted=883.8596, Expected=855.0000
# Month=21, Predicted=829.5215, Expected=809.0000
# Month=22, Predicted=784.0612, Expected=810.0000
# Month=23, Predicted=796.8226, Expected=766.0000
# Month=24, Predicted=797.9348, Expected=805.0000
# Month=25, Predicted=792.4224, Expected=821.0000
# Month=26, Predicted=780.6416, Expected=773.0000
# Month=27, Predicted=829.5554, Expected=883.0000
# Month=28, Predicted=886.0126, Expected=898.0000
# Month=29, Predicted=969.3399, Expected=957.0000
# Month=30, Predicted=934.9584, Expected=924.0000
# Month=31, Predicted=895.4591, Expected=881.0000
# Month=32, Predicted=861.3295, Expected=837.0000
# Month=33, Predicted=807.6175, Expected=784.0000
# Month=34, Predicted=750.6915, Expected=791.0000
# Month=35, Predicted=771.5456, Expected=760.0000
# Month=36, Predicted=807.4656, Expected=802.0000
# Month=37, Predicted=806.1860, Expected=828.0000
# Month=38, Predicted=797.0779, Expected=778.0000
# Month=39, Predicted=850.8506, Expected=889.0000
# Month=40, Predicted=890.3287, Expected=902.0000
# Month=41, Predicted=970.0358, Expected=969.0000
# Month=42, Predicted=947.6558, Expected=947.0000
# Month=43, Predicted=892.7956, Expected=908.0000
# Month=44, Predicted=903.7237, Expected=867.0000
# Month=45, Predicted=842.7934, Expected=815.0000
# Month=46, Predicted=785.2683, Expected=812.0000
# Month=47, Predicted=790.9943, Expected=773.0000
# Month=48, Predicted=800.3427, Expected=813.0000
# Month=49, Predicted=806.9838, Expected=834.0000
# Month=50, Predicted=796.6635, Expected=782.0000
# Month=51, Predicted=848.1037, Expected=892.0000
# Month=52, Predicted=891.5421, Expected=903.0000
# Month=53, Predicted=965.7156, Expected=966.0000
# Month=54, Predicted=949.3562, Expected=937.0000
# Month=55, Predicted=890.2288, Expected=896.0000
# Month=56, Predicted=882.0055, Expected=858.0000
# Month=57, Predicted=833.1350, Expected=817.0000
# Month=58, Predicted=795.2408, Expected=827.0000
# Month=59, Predicted=821.0210, Expected=797.0000
# Month=60, Predicted=849.4112, Expected=843.0000
# Run 28 — RMSE: 24.241847, MSE: 587.667150, NMSE: 0.0026877234
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=747.5842, Expected=804.0000
# Month=2, Predicted=810.5185, Expected=756.0000
# Month=3, Predicted=804.8074, Expected=860.0000
# Month=4, Predicted=861.8002, Expected=878.0000
# Month=5, Predicted=956.9353, Expected=942.0000
# Month=6, Predicted=914.3098, Expected=913.0000
# Month=7, Predicted=863.3794, Expected=869.0000
# Month=8, Predicted=837.4613, Expected=834.0000
# Month=9, Predicted=810.2767, Expected=790.0000
# Month=10, Predicted=768.6722, Expected=800.0000
# Month=11, Predicted=795.9738, Expected=763.0000
# Month=12, Predicted=819.6061, Expected=800.0000
# Month=13, Predicted=795.4013, Expected=826.0000
# Month=14, Predicted=795.8703, Expected=799.0000
# Month=15, Predicted=879.1166, Expected=890.0000
# Month=16, Predicted=907.1387, Expected=900.0000
# Month=17, Predicted=932.9366, Expected=961.0000
# Month=18, Predicted=960.5983, Expected=935.0000
# Month=19, Predicted=887.6697, Expected=894.0000
# Month=20, Predicted=867.7626, Expected=855.0000
# Month=21, Predicted=830.3696, Expected=809.0000
# Month=22, Predicted=783.7442, Expected=810.0000
# Month=23, Predicted=803.8075, Expected=766.0000
# Month=24, Predicted=800.3686, Expected=805.0000
# Month=25, Predicted=795.7883, Expected=821.0000
# Month=26, Predicted=787.9644, Expected=773.0000
# Month=27, Predicted=839.6670, Expected=883.0000
# Month=28, Predicted=891.2496, Expected=898.0000
# Month=29, Predicted=977.2183, Expected=957.0000
# Month=30, Predicted=940.5259, Expected=924.0000
# Month=31, Predicted=892.0063, Expected=881.0000
# Month=32, Predicted=848.3373, Expected=837.0000
# Month=33, Predicted=809.5889, Expected=784.0000
# Month=34, Predicted=752.7575, Expected=791.0000
# Month=35, Predicted=779.0351, Expected=760.0000
# Month=36, Predicted=810.5124, Expected=802.0000
# Month=37, Predicted=803.4065, Expected=828.0000
# Month=38, Predicted=808.3357, Expected=778.0000
# Month=39, Predicted=862.8154, Expected=889.0000
# Month=40, Predicted=893.9308, Expected=902.0000
# Month=41, Predicted=976.0759, Expected=969.0000
# Month=42, Predicted=951.1586, Expected=947.0000
# Month=43, Predicted=897.8826, Expected=908.0000
# Month=44, Predicted=885.2736, Expected=867.0000
# Month=45, Predicted=842.0032, Expected=815.0000
# Month=46, Predicted=785.3009, Expected=812.0000
# Month=47, Predicted=799.2267, Expected=773.0000
# Month=48, Predicted=800.0366, Expected=813.0000
# Month=49, Predicted=807.6766, Expected=834.0000
# Month=50, Predicted=805.0528, Expected=782.0000
# Month=51, Predicted=859.1830, Expected=892.0000
# Month=52, Predicted=894.1136, Expected=903.0000
# Month=53, Predicted=968.6258, Expected=966.0000
# Month=54, Predicted=960.9805, Expected=937.0000
# Month=55, Predicted=888.0619, Expected=896.0000
# Month=56, Predicted=866.3193, Expected=858.0000
# Month=57, Predicted=834.2481, Expected=817.0000
# Month=58, Predicted=794.8879, Expected=827.0000
# Month=59, Predicted=825.0011, Expected=797.0000
# Month=60, Predicted=853.1784, Expected=843.0000
# Run 29 — RMSE: 24.017044, MSE: 576.818416, NMSE: 0.0026497701
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=745.4596, Expected=804.0000
# Month=2, Predicted=823.3215, Expected=756.0000
# Month=3, Predicted=832.0487, Expected=860.0000
# Month=4, Predicted=855.5842, Expected=878.0000
# Month=5, Predicted=936.1250, Expected=942.0000
# Month=6, Predicted=913.6904, Expected=913.0000
# Month=7, Predicted=863.8541, Expected=869.0000
# Month=8, Predicted=850.6926, Expected=834.0000
# Month=9, Predicted=811.3350, Expected=790.0000
# Month=10, Predicted=769.0824, Expected=800.0000
# Month=11, Predicted=786.2052, Expected=763.0000
# Month=12, Predicted=823.5684, Expected=800.0000
# Month=13, Predicted=792.9036, Expected=826.0000
# Month=14, Predicted=792.4070, Expected=799.0000
# Month=15, Predicted=883.2243, Expected=890.0000
# Month=16, Predicted=908.8083, Expected=900.0000
# Month=17, Predicted=953.0723, Expected=961.0000
# Month=18, Predicted=955.1725, Expected=935.0000
# Month=19, Predicted=888.9968, Expected=894.0000
# Month=20, Predicted=878.2065, Expected=855.0000
# Month=21, Predicted=832.6721, Expected=809.0000
# Month=22, Predicted=785.9618, Expected=810.0000
# Month=23, Predicted=794.2363, Expected=766.0000
# Month=24, Predicted=800.5930, Expected=805.0000
# Month=25, Predicted=790.3023, Expected=821.0000
# Month=26, Predicted=784.7812, Expected=773.0000
# Month=27, Predicted=853.8027, Expected=883.0000
# Month=28, Predicted=881.0016, Expected=898.0000
# Month=29, Predicted=953.9118, Expected=957.0000
# Month=30, Predicted=932.8439, Expected=924.0000
# Month=31, Predicted=900.8387, Expected=881.0000
# Month=32, Predicted=861.0808, Expected=837.0000
# Month=33, Predicted=812.8283, Expected=784.0000
# Month=34, Predicted=757.7436, Expected=791.0000
# Month=35, Predicted=772.1966, Expected=760.0000
# Month=36, Predicted=809.5489, Expected=802.0000
# Month=37, Predicted=803.3346, Expected=828.0000
# Month=38, Predicted=795.0205, Expected=778.0000
# Month=39, Predicted=879.3172, Expected=889.0000
# Month=40, Predicted=884.5427, Expected=902.0000
# Month=41, Predicted=955.0300, Expected=969.0000
# Month=42, Predicted=947.1410, Expected=947.0000
# Month=43, Predicted=890.2405, Expected=908.0000
# Month=44, Predicted=897.8675, Expected=867.0000
# Month=45, Predicted=845.0454, Expected=815.0000
# Month=46, Predicted=789.9692, Expected=812.0000
# Month=47, Predicted=792.5865, Expected=773.0000
# Month=48, Predicted=792.0526, Expected=813.0000
# Month=49, Predicted=803.2739, Expected=834.0000
# Month=50, Predicted=797.4375, Expected=782.0000
# Month=51, Predicted=875.4744, Expected=892.0000
# Month=52, Predicted=884.5042, Expected=903.0000
# Month=53, Predicted=952.4224, Expected=966.0000
# Month=54, Predicted=953.5847, Expected=937.0000
# Month=55, Predicted=890.4949, Expected=896.0000
# Month=56, Predicted=878.4938, Expected=858.0000
# Month=57, Predicted=835.8989, Expected=817.0000
# Month=58, Predicted=795.4905, Expected=827.0000
# Month=59, Predicted=815.6865, Expected=797.0000
# Month=60, Predicted=854.7088, Expected=843.0000
# Run 30 — RMSE: 22.832475, MSE: 521.321905, NMSE: 0.0025423009

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Monthly Milk Production (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Monthly Milk Production (30 runs) =====
# RMSE: 25.145983 ± 1.819922
# MSE:  635.632590 ± 92.565794
# NMSE: 0.0028222645 ± 0.0004024938
#
# Best run: 25
#   RMSE: 22.521450
#   MSE:  507.215730
#   NMSE: 0.0023009880

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Hybrid (Feature Aug + Gate) — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Hybrid (Feature Aug + Gate) — Monthly Milk Production\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 22.521450
# MSE:  507.215730
# NMSE: 0.0023009880

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
