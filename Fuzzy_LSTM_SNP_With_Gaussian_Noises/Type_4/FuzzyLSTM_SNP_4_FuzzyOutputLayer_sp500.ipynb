# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: S&P 500
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# GPU Acceleration Settings (CUDA + Apple Metal Support)
# ============================================================
import tensorflow as tf
import platform

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        # Detect GPU type
        if platform.system() == 'Darwin' and platform.processor() == 'arm':
            print(f"Apple Metal GPU Enabled: Found {len(physical_devices)} GPU(s) via tensorflow-metal")
            print(f"  Chipset: Apple {platform.machine()} (M-series)")
        else:
            print(f"CUDA GPU Enabled: Found {len(physical_devices)} GPU(s) - Memory Growth Set")
        for d in physical_devices:
            print(f"  Device: {d.name}")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    if platform.system() == 'Darwin' and platform.processor() == 'arm':
        print("Apple Silicon detected but no GPU found.")
        print("  Install tensorflow-metal: pip install tensorflow-metal")
    else:
        print("No GPU found. Falling back to CPU.")
        print("  For CUDA: ensure NVIDIA drivers + CUDA toolkit are installed.")

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 1)]               0
#
#  rnn (RNN)                   (1, 8)                    320
#
#  fuzzy_output_layer (FuzzyO  (1, 1)                    12
#  utputLayer)
#
# =================================================================
# Total params: 332 (1.30 KB)
# Trainable params: 332 (1.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — S&P 500

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/sp500.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 1)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input
    # ============================================================
    
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)
    
        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Output Layer on S&P 500 (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Output Layer — S&P 500\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Output Layer — S&P 500\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.505155)
# ================================================================================
#
# Data shape: (251,)
# First 5 values: [2038.45086852 2013.71018413 2012.03714395 1986.08931179 1945.85168731]
# Supervised data shape: (250, 2)
# Train: (190, 2), Test: (60, 2)
# X_train shape: (190, 1, 1), y_train shape: (190,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=2155.5182, Expected=2158.6526
# Month=2, Predicted=2157.8837, Expected=2164.2981
# Month=3, Predicted=2162.0783, Expected=2159.7606
# Month=4, Predicted=2158.3234, Expected=2161.4376
# Month=5, Predicted=2159.8879, Expected=2137.8646
# Month=6, Predicted=2142.1035, Expected=2129.8135
# Month=7, Predicted=2136.2990, Expected=2139.7576
# Month=8, Predicted=2139.2082, Expected=2132.9794
# Month=9, Predicted=2134.1000, Expected=2137.7327
# Month=10, Predicted=2136.4600, Expected=2140.9908
# Month=11, Predicted=2138.8632, Expected=2142.7933
# Month=12, Predicted=2140.5668, Expected=2139.9770
# Month=13, Predicted=2138.4008, Expected=2149.0323
# Month=14, Predicted=2146.7609, Expected=2149.0240
# Month=15, Predicted=2146.9598, Expected=2136.4962
# Month=16, Predicted=2136.1590, Expected=2144.3202
# Month=17, Predicted=2143.3110, Expected=2132.4895
# Month=18, Predicted=2133.1179, Expected=2130.0402
# Month=19, Predicted=2131.5534, Expected=2130.6262
# Month=20, Predicted=2131.1213, Expected=2109.7183
# Month=21, Predicted=2116.3884, Expected=2099.3737
# Month=22, Predicted=2108.0132, Expected=2084.2720
# Month=23, Predicted=2095.8102, Expected=2100.9191
# Month=24, Predicted=2099.2099, Expected=2129.7607
# Month=25, Predicted=2125.9709, Expected=2131.9435
# Month=26, Predicted=2128.1924, Expected=2167.0996
# Month=27, Predicted=2167.0543, Expected=2162.5903
# Month=28, Predicted=2164.7351, Expected=2165.3947
# Month=29, Predicted=2168.5988, Expected=2168.3314
# Month=30, Predicted=2171.6293, Expected=2178.6993
# Month=31, Predicted=2181.5274, Expected=2177.6668
# Month=32, Predicted=2179.5273, Expected=2187.1968
# Month=33, Predicted=2188.6957, Expected=2185.6153
# Month=34, Predicted=2186.5258, Expected=2201.3217
# Month=35, Predicted=2202.7913, Expected=2199.1001
# Month=36, Predicted=2199.1106, Expected=2206.3025
# Month=37, Predicted=2206.6753, Expected=2209.6655
# Month=38, Predicted=2209.2588, Expected=2200.3987
# Month=39, Predicted=2200.6049, Expected=2205.3133
# Month=40, Predicted=2205.2065, Expected=2199.8010
# Month=41, Predicted=2200.0540, Expected=2191.2295
# Month=42, Predicted=2193.8478, Expected=2200.6729
# Month=43, Predicted=2199.2310, Expected=2206.9309
# Month=44, Predicted=2204.0073, Expected=2211.8030
# Month=45, Predicted=2208.6137, Expected=2241.4501
# Month=46, Predicted=2239.7286, Expected=2248.7070
# Month=47, Predicted=2247.0786, Expected=2258.9243
# Month=48, Predicted=2259.4056, Expected=2262.9858
# Month=49, Predicted=2264.9049, Expected=2268.7807
# Month=50, Predicted=2271.1506, Expected=2253.3697
# Month=51, Predicted=2255.1937, Expected=2266.7521
# Month=52, Predicted=2268.0021, Expected=2259.4951
# Month=53, Predicted=2260.5393, Expected=2266.9373
# Month=54, Predicted=2267.8672, Expected=2269.9337
# Month=55, Predicted=2269.6608, Expected=2262.7610
# Month=56, Predicted=2263.7101, Expected=2260.0101
# Month=57, Predicted=2261.1772, Expected=2265.8999
# Month=58, Predicted=2264.3203, Expected=2271.1218
# Month=59, Predicted=2268.2714, Expected=2249.7046
# Month=60, Predicted=2251.6438, Expected=2250.9732
# Run 1 — RMSE: 11.715237, MSE: 137.246783, NMSE: 0.0008497189
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=2157.3095, Expected=2158.6526
# Month=2, Predicted=2159.6891, Expected=2164.2981
# Month=3, Predicted=2163.3892, Expected=2159.7606
# Month=4, Predicted=2160.5596, Expected=2161.4376
# Month=5, Predicted=2163.1395, Expected=2137.8646
# Month=6, Predicted=2138.7633, Expected=2129.8135
# Month=7, Predicted=2135.7392, Expected=2139.7576
# Month=8, Predicted=2138.7200, Expected=2132.9794
# Month=9, Predicted=2132.2659, Expected=2137.7327
# Month=10, Predicted=2139.1609, Expected=2140.9908
# Month=11, Predicted=2140.4228, Expected=2142.7933
# Month=12, Predicted=2142.6569, Expected=2139.9770
# Month=13, Predicted=2141.3773, Expected=2149.0323
# Month=14, Predicted=2148.6760, Expected=2149.0240
# Month=15, Predicted=2148.6603, Expected=2136.4962
# Month=16, Predicted=2140.0876, Expected=2144.3202
# Month=17, Predicted=2144.6794, Expected=2132.4895
# Month=18, Predicted=2131.4201, Expected=2130.0402
# Month=19, Predicted=2133.6679, Expected=2130.6262
# Month=20, Predicted=2130.8400, Expected=2109.7183
# Month=21, Predicted=2110.5365, Expected=2099.3737
# Month=22, Predicted=2106.0993, Expected=2084.2720
# Month=23, Predicted=2085.2126, Expected=2100.9191
# Month=24, Predicted=2098.9355, Expected=2129.7607
# Month=25, Predicted=2127.7957, Expected=2131.9435
# Month=26, Predicted=2131.4100, Expected=2167.0996
# Month=27, Predicted=2163.8952, Expected=2162.5903
# Month=28, Predicted=2161.8133, Expected=2165.3947
# Month=29, Predicted=2169.3855, Expected=2168.3314
# Month=30, Predicted=2168.8834, Expected=2178.6993
# Month=31, Predicted=2177.9600, Expected=2177.6668
# Month=32, Predicted=2178.3704, Expected=2187.1968
# Month=33, Predicted=2187.7170, Expected=2185.6153
# Month=34, Predicted=2185.4990, Expected=2201.3217
# Month=35, Predicted=2200.2016, Expected=2199.1001
# Month=36, Predicted=2198.8510, Expected=2206.3025
# Month=37, Predicted=2207.0652, Expected=2209.6655
# Month=38, Predicted=2209.4028, Expected=2200.3987
# Month=39, Predicted=2202.0605, Expected=2205.3133
# Month=40, Predicted=2206.5797, Expected=2199.8010
# Month=41, Predicted=2199.5929, Expected=2191.2295
# Month=42, Predicted=2194.2483, Expected=2200.6729
# Month=43, Predicted=2200.1474, Expected=2206.9309
# Month=44, Predicted=2205.6673, Expected=2211.8030
# Month=45, Predicted=2211.9039, Expected=2241.4501
# Month=46, Predicted=2238.8449, Expected=2248.7070
# Month=47, Predicted=2247.3498, Expected=2258.9243
# Month=48, Predicted=2259.7710, Expected=2262.9858
# Month=49, Predicted=2263.2620, Expected=2268.7807
# Month=50, Predicted=2268.8317, Expected=2253.3697
# Month=51, Predicted=2255.3033, Expected=2266.7521
# Month=52, Predicted=2266.7748, Expected=2259.4951
# Month=53, Predicted=2257.9599, Expected=2266.9373
# Month=54, Predicted=2268.0021, Expected=2269.9337
# Month=55, Predicted=2269.5639, Expected=2262.7610
# Month=56, Predicted=2264.0302, Expected=2260.0101
# Month=57, Predicted=2262.2571, Expected=2265.8999
# Month=58, Predicted=2265.4309, Expected=2271.1218
# Month=59, Predicted=2270.4432, Expected=2249.7046
# Month=60, Predicted=2252.7538, Expected=2250.9732
# Run 2 — RMSE: 11.405389, MSE: 130.082909, NMSE: 0.0007984468
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=2155.4759, Expected=2158.6526
# Month=2, Predicted=2159.8608, Expected=2164.2981
# Month=3, Predicted=2165.1665, Expected=2159.7606
# Month=4, Predicted=2160.1655, Expected=2161.4376
# Month=5, Predicted=2162.3484, Expected=2137.8646
# Month=6, Predicted=2137.8096, Expected=2129.8135
# Month=7, Predicted=2131.6074, Expected=2139.7576
# Month=8, Predicted=2141.5449, Expected=2132.9794
# Month=9, Predicted=2133.6705, Expected=2137.7327
# Month=10, Predicted=2139.0496, Expected=2140.9908
# Month=11, Predicted=2141.8638, Expected=2142.7933
# Month=12, Predicted=2143.5004, Expected=2139.9770
# Month=13, Predicted=2140.5640, Expected=2149.0323
# Month=14, Predicted=2150.0335, Expected=2149.0240
# Month=15, Predicted=2149.4026, Expected=2136.4962
# Month=16, Predicted=2136.7469, Expected=2144.3202
# Month=17, Predicted=2145.7506, Expected=2132.4895
# Month=18, Predicted=2132.8034, Expected=2130.0402
# Month=19, Predicted=2131.3179, Expected=2130.6262
# Month=20, Predicted=2131.8046, Expected=2109.7183
# Month=21, Predicted=2109.9747, Expected=2099.3737
# Month=22, Predicted=2101.0333, Expected=2084.2720
# Month=23, Predicted=2085.6209, Expected=2100.9191
# Month=24, Predicted=2102.9356, Expected=2129.7607
# Month=25, Predicted=2130.6757, Expected=2131.9435
# Month=26, Predicted=2131.6622, Expected=2167.0996
# Month=27, Predicted=2167.2420, Expected=2162.5903
# Month=28, Predicted=2161.3432, Expected=2165.3947
# Month=29, Predicted=2165.4099, Expected=2168.3314
# Month=30, Predicted=2168.4904, Expected=2178.6993
# Month=31, Predicted=2179.0170, Expected=2177.6668
# Month=32, Predicted=2177.5670, Expected=2187.1968
# Month=33, Predicted=2187.6635, Expected=2185.6153
# Month=34, Predicted=2185.6321, Expected=2201.3217
# Month=35, Predicted=2201.9090, Expected=2199.1001
# Month=36, Predicted=2198.8651, Expected=2206.3025
# Month=37, Predicted=2206.7813, Expected=2209.6655
# Month=38, Predicted=2209.8893, Expected=2200.3987
# Month=39, Predicted=2200.5046, Expected=2205.3133
# Month=40, Predicted=2206.4052, Expected=2199.8010
# Month=41, Predicted=2200.3062, Expected=2191.2295
# Month=42, Predicted=2192.0347, Expected=2200.6729
# Month=43, Predicted=2202.1561, Expected=2206.9309
# Month=44, Predicted=2207.6454, Expected=2211.8030
# Month=45, Predicted=2212.2942, Expected=2241.4501
# Month=46, Predicted=2241.8637, Expected=2248.7070
# Month=47, Predicted=2247.9794, Expected=2258.9243
# Month=48, Predicted=2258.5977, Expected=2262.9858
# Month=49, Predicted=2262.6349, Expected=2268.7807
# Month=50, Predicted=2268.7642, Expected=2253.3697
# Month=51, Predicted=2253.1211, Expected=2266.7521
# Month=52, Predicted=2268.0821, Expected=2259.4951
# Month=53, Predicted=2259.6641, Expected=2266.9373
# Month=54, Predicted=2268.0052, Expected=2269.9337
# Month=55, Predicted=2270.4729, Expected=2262.7610
# Month=56, Predicted=2263.1107, Expected=2260.0101
# Month=57, Predicted=2260.9973, Expected=2265.8999
# Month=58, Predicted=2267.0450, Expected=2271.1218
# Month=59, Predicted=2271.8416, Expected=2249.7046
# Month=60, Predicted=2249.5206, Expected=2250.9732
# Run 3 — RMSE: 11.269478, MSE: 127.001140, NMSE: 0.0007778930
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=2155.7147, Expected=2158.6526
# Month=2, Predicted=2159.4433, Expected=2164.2981
# Month=3, Predicted=2165.0889, Expected=2159.7606
# Month=4, Predicted=2160.5513, Expected=2161.4376
# Month=5, Predicted=2162.2285, Expected=2137.8646
# Month=6, Predicted=2138.6552, Expected=2129.8135
# Month=7, Predicted=2130.6045, Expected=2139.7576
# Month=8, Predicted=2140.5488, Expected=2132.9794
# Month=9, Predicted=2133.7704, Expected=2137.7327
# Month=10, Predicted=2138.5239, Expected=2140.9908
# Month=11, Predicted=2141.7821, Expected=2142.7933
# Month=12, Predicted=2143.5846, Expected=2139.9770
# Month=13, Predicted=2140.7683, Expected=2149.0323
# Month=14, Predicted=2149.8237, Expected=2149.0240
# Month=15, Predicted=2149.8154, Expected=2136.4962
# Month=16, Predicted=2137.2875, Expected=2144.3202
# Month=17, Predicted=2145.1117, Expected=2132.4895
# Month=18, Predicted=2133.2809, Expected=2130.0402
# Month=19, Predicted=2130.8316, Expected=2130.6262
# Month=20, Predicted=2131.4176, Expected=2109.7183
# Month=21, Predicted=2110.5097, Expected=2099.3737
# Month=22, Predicted=2100.1651, Expected=2084.2720
# Month=23, Predicted=2085.0634, Expected=2100.9191
# Month=24, Predicted=2101.7106, Expected=2129.7607
# Month=25, Predicted=2130.5522, Expected=2131.9435
# Month=26, Predicted=2132.7349, Expected=2167.0996
# Month=27, Predicted=2167.8911, Expected=2162.5903
# Month=28, Predicted=2163.3818, Expected=2165.3947
# Month=29, Predicted=2166.1862, Expected=2168.3314
# Month=30, Predicted=2169.1229, Expected=2178.6993
# Month=31, Predicted=2179.4908, Expected=2177.6668
# Month=32, Predicted=2178.4584, Expected=2187.1968
# Month=33, Predicted=2187.9883, Expected=2185.6153
# Month=34, Predicted=2186.4068, Expected=2201.3217
# Month=35, Predicted=2202.1132, Expected=2199.1001
# Month=36, Predicted=2199.8917, Expected=2206.3025
# Month=37, Predicted=2207.0940, Expected=2209.6655
# Month=38, Predicted=2210.4571, Expected=2200.3987
# Month=39, Predicted=2201.1902, Expected=2205.3133
# Month=40, Predicted=2206.1048, Expected=2199.8010
# Month=41, Predicted=2200.5925, Expected=2191.2295
# Month=42, Predicted=2192.0210, Expected=2200.6729
# Month=43, Predicted=2201.4644, Expected=2206.9309
# Month=44, Predicted=2207.7224, Expected=2211.8030
# Month=45, Predicted=2212.5945, Expected=2241.4501
# Month=46, Predicted=2242.2417, Expected=2248.7070
# Month=47, Predicted=2249.4985, Expected=2258.9243
# Month=48, Predicted=2259.7158, Expected=2262.9858
# Month=49, Predicted=2263.7773, Expected=2268.7807
# Month=50, Predicted=2269.5722, Expected=2253.3697
# Month=51, Predicted=2254.1612, Expected=2266.7521
# Month=52, Predicted=2267.5436, Expected=2259.4951
# Month=53, Predicted=2260.2866, Expected=2266.9373
# Month=54, Predicted=2267.7288, Expected=2269.9337
# Month=55, Predicted=2270.7252, Expected=2262.7610
# Month=56, Predicted=2263.5524, Expected=2260.0101
# Month=57, Predicted=2260.8016, Expected=2265.8999
# Month=58, Predicted=2266.6914, Expected=2271.1218
# Month=59, Predicted=2271.9133, Expected=2249.7046
# Month=60, Predicted=2250.4960, Expected=2250.9732
# Run 4 — RMSE: 11.145421, MSE: 124.220404, NMSE: 0.0007547904
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=2155.6435, Expected=2158.6526
# Month=2, Predicted=2160.9844, Expected=2164.2981
# Month=3, Predicted=2166.0071, Expected=2159.7606
# Month=4, Predicted=2161.3476, Expected=2161.4376
# Month=5, Predicted=2161.5156, Expected=2137.8646
# Month=6, Predicted=2136.2233, Expected=2129.8135
# Month=7, Predicted=2143.3203, Expected=2139.7576
# Month=8, Predicted=2139.1768, Expected=2132.9794
# Month=9, Predicted=2137.2491, Expected=2137.7327
# Month=10, Predicted=2142.9460, Expected=2140.9908
# Month=11, Predicted=2144.0922, Expected=2142.7933
# Month=12, Predicted=2142.5146, Expected=2139.9770
# Month=13, Predicted=2140.3364, Expected=2149.0323
# Month=14, Predicted=2152.1100, Expected=2149.0240
# Month=15, Predicted=2149.3449, Expected=2136.4962
# Month=16, Predicted=2136.4058, Expected=2144.3202
# Month=17, Predicted=2145.3019, Expected=2132.4895
# Month=18, Predicted=2132.9463, Expected=2130.0402
# Month=19, Predicted=2130.3436, Expected=2130.6262
# Month=20, Predicted=2131.0513, Expected=2109.7183
# Month=21, Predicted=2109.5754, Expected=2099.3737
# Month=22, Predicted=2107.5240, Expected=2084.2720
# Month=23, Predicted=2088.3491, Expected=2100.9191
# Month=24, Predicted=2103.7025, Expected=2129.7607
# Month=25, Predicted=2138.0529, Expected=2131.9435
# Month=26, Predicted=2133.5885, Expected=2167.0996
# Month=27, Predicted=2171.3679, Expected=2162.5903
# Month=28, Predicted=2161.5709, Expected=2165.3947
# Month=29, Predicted=2173.9343, Expected=2168.3314
# Month=30, Predicted=2180.7658, Expected=2178.6993
# Month=31, Predicted=2179.6313, Expected=2177.6668
# Month=32, Predicted=2182.2069, Expected=2187.1968
# Month=33, Predicted=2192.4506, Expected=2185.6153
# Month=34, Predicted=2186.7958, Expected=2201.3217
# Month=35, Predicted=2200.7072, Expected=2199.1001
# Month=36, Predicted=2196.5410, Expected=2206.3025
# Month=37, Predicted=2206.3919, Expected=2209.6655
# Month=38, Predicted=2208.5122, Expected=2200.3987
# Month=39, Predicted=2198.7871, Expected=2205.3133
# Month=40, Predicted=2204.9993, Expected=2199.8010
# Month=41, Predicted=2198.9453, Expected=2191.2295
# Month=42, Predicted=2190.0136, Expected=2200.6729
# Month=43, Predicted=2200.6641, Expected=2206.9309
# Month=44, Predicted=2208.6926, Expected=2211.8030
# Month=45, Predicted=2212.1655, Expected=2241.4501
# Month=46, Predicted=2245.3759, Expected=2248.7070
# Month=47, Predicted=2249.1736, Expected=2258.9243
# Month=48, Predicted=2255.3818, Expected=2262.9858
# Month=49, Predicted=2260.1524, Expected=2268.7807
# Month=50, Predicted=2267.2945, Expected=2253.3697
# Month=51, Predicted=2252.4368, Expected=2266.7521
# Month=52, Predicted=2266.8578, Expected=2259.4951
# Month=53, Predicted=2259.3344, Expected=2266.9373
# Month=54, Predicted=2267.1106, Expected=2269.9337
# Month=55, Predicted=2269.1963, Expected=2262.7610
# Month=56, Predicted=2259.4228, Expected=2260.0101
# Month=57, Predicted=2261.3200, Expected=2265.8999
# Month=58, Predicted=2265.8979, Expected=2271.1218
# Month=59, Predicted=2271.8478, Expected=2249.7046
# Month=60, Predicted=2247.0295, Expected=2250.9732
# Run 5 — RMSE: 11.102714, MSE: 123.270253, NMSE: 0.0007913890
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=2156.3362, Expected=2158.6526
# Month=2, Predicted=2159.3470, Expected=2164.2981
# Month=3, Predicted=2164.5960, Expected=2159.7606
# Month=4, Predicted=2160.7485, Expected=2161.4376
# Month=5, Predicted=2162.1018, Expected=2137.8646
# Month=6, Predicted=2140.6300, Expected=2129.8135
# Month=7, Predicted=2131.8301, Expected=2139.7576
# Month=8, Predicted=2140.4014, Expected=2132.9794
# Month=9, Predicted=2134.3107, Expected=2137.7327
# Month=10, Predicted=2138.2437, Expected=2140.9908
# Month=11, Predicted=2141.3358, Expected=2142.7933
# Month=12, Predicted=2143.1642, Expected=2139.9770
# Month=13, Predicted=2140.7652, Expected=2149.0323
# Month=14, Predicted=2148.9797, Expected=2149.0240
# Month=15, Predicted=2149.4243, Expected=2136.4962
# Month=16, Predicted=2138.1669, Expected=2144.3202
# Month=17, Predicted=2144.7276, Expected=2132.4895
# Month=18, Predicted=2134.1782, Expected=2130.0402
# Month=19, Predicted=2131.2685, Expected=2130.6262
# Month=20, Predicted=2131.5401, Expected=2109.7183
# Month=21, Predicted=2112.3172, Expected=2099.3737
# Month=22, Predicted=2101.5175, Expected=2084.2720
# Month=23, Predicted=2086.7802, Expected=2100.9191
# Month=24, Predicted=2101.2904, Expected=2129.7607
# Month=25, Predicted=2128.1799, Expected=2131.9435
# Month=26, Predicted=2131.2291, Expected=2167.0996
# Month=27, Predicted=2164.4861, Expected=2162.5903
# Month=28, Predicted=2162.2278, Expected=2165.3947
# Month=29, Predicted=2165.2791, Expected=2168.3314
# Month=30, Predicted=2168.4809, Expected=2178.6993
# Month=31, Predicted=2178.3640, Expected=2177.6668
# Month=32, Predicted=2178.1292, Expected=2187.1968
# Month=33, Predicted=2187.0473, Expected=2185.6153
# Month=34, Predicted=2186.2286, Expected=2201.3217
# Month=35, Predicted=2200.7945, Expected=2199.1001
# Month=36, Predicted=2199.6326, Expected=2206.3025
# Month=37, Predicted=2206.3825, Expected=2209.6655
# Month=38, Predicted=2209.9598, Expected=2200.3987
# Month=39, Predicted=2201.8918, Expected=2205.3133
# Month=40, Predicted=2205.9917, Expected=2199.8010
# Month=41, Predicted=2201.1247, Expected=2191.2295
# Month=42, Predicted=2192.9660, Expected=2200.6729
# Month=43, Predicted=2201.1491, Expected=2206.9309
# Month=44, Predicted=2207.1077, Expected=2211.8030
# Month=45, Predicted=2211.9044, Expected=2241.4501
# Month=46, Predicted=2239.7320, Expected=2248.7070
# Month=47, Predicted=2247.5838, Expected=2258.9243
# Month=48, Predicted=2257.9646, Expected=2262.9858
# Month=49, Predicted=2262.7237, Expected=2268.7807
# Month=50, Predicted=2268.6580, Expected=2253.3697
# Month=51, Predicted=2255.2680, Expected=2266.7521
# Month=52, Predicted=2266.9223, Expected=2259.4951
# Month=53, Predicted=2260.7864, Expected=2266.9373
# Month=54, Predicted=2267.3136, Expected=2269.9337
# Month=55, Predicted=2270.3654, Expected=2262.7610
# Month=56, Predicted=2264.0789, Expected=2260.0101
# Month=57, Predicted=2261.2194, Expected=2265.8999
# Month=58, Predicted=2266.4256, Expected=2271.1218
# Month=59, Predicted=2271.3971, Expected=2249.7046
# Month=60, Predicted=2252.2246, Expected=2250.9732
# Run 6 — RMSE: 11.293801, MSE: 127.549931, NMSE: 0.0007818889
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=2155.9154, Expected=2158.6526
# Month=2, Predicted=2158.6436, Expected=2164.2981
# Month=3, Predicted=2163.9487, Expected=2159.7606
# Month=4, Predicted=2160.1106, Expected=2161.4376
# Month=5, Predicted=2161.5397, Expected=2137.8646
# Month=6, Predicted=2140.4929, Expected=2129.8135
# Month=7, Predicted=2131.3721, Expected=2139.7576
# Month=8, Predicted=2138.9711, Expected=2132.9794
# Month=9, Predicted=2132.7267, Expected=2137.7327
# Month=10, Predicted=2137.2096, Expected=2140.9908
# Month=11, Predicted=2140.4702, Expected=2142.7933
# Month=12, Predicted=2142.4027, Expected=2139.9770
# Month=13, Predicted=2139.9306, Expected=2149.0323
# Month=14, Predicted=2148.5103, Expected=2149.0240
# Month=15, Predicted=2148.7630, Expected=2136.4962
# Month=16, Predicted=2137.5359, Expected=2144.3202
# Month=17, Predicted=2143.9431, Expected=2132.4895
# Month=18, Predicted=2133.0655, Expected=2130.0402
# Month=19, Predicted=2130.2582, Expected=2130.6262
# Month=20, Predicted=2130.2993, Expected=2109.7183
# Month=21, Predicted=2111.0262, Expected=2099.3737
# Month=22, Predicted=2100.1630, Expected=2084.2720
# Month=23, Predicted=2084.5421, Expected=2100.9191
# Month=24, Predicted=2100.3955, Expected=2129.7607
# Month=25, Predicted=2131.7427, Expected=2131.9435
# Month=26, Predicted=2131.4048, Expected=2167.0996
# Month=27, Predicted=2168.0301, Expected=2162.5903
# Month=28, Predicted=2162.1808, Expected=2165.3947
# Month=29, Predicted=2165.4862, Expected=2168.3314
# Month=30, Predicted=2168.4307, Expected=2178.6993
# Month=31, Predicted=2178.3204, Expected=2177.6668
# Month=32, Predicted=2178.0880, Expected=2187.1968
# Month=33, Predicted=2187.0565, Expected=2185.6153
# Month=34, Predicted=2186.3104, Expected=2201.3217
# Month=35, Predicted=2200.8702, Expected=2199.1001
# Month=36, Predicted=2199.8009, Expected=2206.3025
# Month=37, Predicted=2206.6059, Expected=2209.6655
# Month=38, Predicted=2210.1711, Expected=2200.3987
# Month=39, Predicted=2202.6645, Expected=2205.3133
# Month=40, Predicted=2206.1297, Expected=2199.8010
# Month=41, Predicted=2201.3803, Expected=2191.2295
# Month=42, Predicted=2193.5819, Expected=2200.6729
# Month=43, Predicted=2200.6436, Expected=2206.9309
# Month=44, Predicted=2206.8014, Expected=2211.8030
# Month=45, Predicted=2211.8697, Expected=2241.4501
# Month=46, Predicted=2241.0960, Expected=2248.7070
# Month=47, Predicted=2248.3382, Expected=2258.9243
# Month=48, Predicted=2258.8115, Expected=2262.9858
# Month=49, Predicted=2263.5763, Expected=2268.7807
# Month=50, Predicted=2269.4784, Expected=2253.3697
# Month=51, Predicted=2257.1814, Expected=2266.7521
# Month=52, Predicted=2267.1779, Expected=2259.4951
# Month=53, Predicted=2261.6755, Expected=2266.9373
# Month=54, Predicted=2267.7240, Expected=2269.9337
# Month=55, Predicted=2270.7831, Expected=2262.7610
# Month=56, Predicted=2265.1202, Expected=2260.0101
# Month=57, Predicted=2262.1006, Expected=2265.8999
# Month=58, Predicted=2266.4366, Expected=2271.1218
# Month=59, Predicted=2271.4315, Expected=2249.7046
# Month=60, Predicted=2253.5833, Expected=2250.9732
# Run 7 — RMSE: 11.213242, MSE: 125.736798, NMSE: 0.0007540705
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=2154.3219, Expected=2158.6526
# Month=2, Predicted=2156.9338, Expected=2164.2981
# Month=3, Predicted=2164.2741, Expected=2159.7606
# Month=4, Predicted=2158.0269, Expected=2161.4376
# Month=5, Predicted=2160.2809, Expected=2137.8646
# Month=6, Predicted=2136.1011, Expected=2129.8135
# Month=7, Predicted=2136.2993, Expected=2139.7576
# Month=8, Predicted=2141.5297, Expected=2132.9794
# Month=9, Predicted=2131.3944, Expected=2137.7327
# Month=10, Predicted=2138.2989, Expected=2140.9908
# Month=11, Predicted=2140.2736, Expected=2142.7933
# Month=12, Predicted=2140.9328, Expected=2139.9770
# Month=13, Predicted=2138.2642, Expected=2149.0323
# Month=14, Predicted=2147.3669, Expected=2149.0240
# Month=15, Predicted=2148.2743, Expected=2136.4962
# Month=16, Predicted=2136.4673, Expected=2144.3202
# Month=17, Predicted=2142.6830, Expected=2132.4895
# Month=18, Predicted=2131.9049, Expected=2130.0402
# Month=19, Predicted=2132.2449, Expected=2130.6262
# Month=20, Predicted=2129.5650, Expected=2109.7183
# Month=21, Predicted=2108.1300, Expected=2099.3737
# Month=22, Predicted=2105.4295, Expected=2084.2720
# Month=23, Predicted=2081.6035, Expected=2100.9191
# Month=24, Predicted=2098.3937, Expected=2129.7607
# Month=25, Predicted=2133.7951, Expected=2131.9435
# Month=26, Predicted=2130.0217, Expected=2167.0996
# Month=27, Predicted=2165.4354, Expected=2162.5903
# Month=28, Predicted=2164.7379, Expected=2165.3947
# Month=29, Predicted=2168.9906, Expected=2168.3314
# Month=30, Predicted=2168.4528, Expected=2178.6993
# Month=31, Predicted=2178.7239, Expected=2177.6668
# Month=32, Predicted=2177.0667, Expected=2187.1968
# Month=33, Predicted=2186.0359, Expected=2185.6153
# Month=34, Predicted=2185.8760, Expected=2201.3217
# Month=35, Predicted=2200.6281, Expected=2199.1001
# Month=36, Predicted=2200.4433, Expected=2206.3025
# Month=37, Predicted=2205.3555, Expected=2209.6655
# Month=38, Predicted=2210.6777, Expected=2200.3987
# Month=39, Predicted=2199.2167, Expected=2205.3133
# Month=40, Predicted=2204.2987, Expected=2199.8010
# Month=41, Predicted=2200.3930, Expected=2191.2295
# Month=42, Predicted=2190.7468, Expected=2200.6729
# Month=43, Predicted=2200.0317, Expected=2206.9309
# Month=44, Predicted=2209.6055, Expected=2211.8030
# Month=45, Predicted=2210.7505, Expected=2241.4501
# Month=46, Predicted=2243.6936, Expected=2248.7070
# Month=47, Predicted=2252.9192, Expected=2258.9243
# Month=48, Predicted=2257.9636, Expected=2262.9858
# Month=49, Predicted=2263.3917, Expected=2268.7807
# Month=50, Predicted=2268.8143, Expected=2253.3697
# Month=51, Predicted=2252.2612, Expected=2266.7521
# Month=52, Predicted=2265.9209, Expected=2259.4951
# Month=53, Predicted=2263.1438, Expected=2266.9373
# Month=54, Predicted=2266.1886, Expected=2269.9337
# Month=55, Predicted=2271.8594, Expected=2262.7610
# Month=56, Predicted=2261.6406, Expected=2260.0101
# Month=57, Predicted=2259.1943, Expected=2265.8999
# Month=58, Predicted=2266.6038, Expected=2271.1218
# Month=59, Predicted=2272.2542, Expected=2249.7046
# Month=60, Predicted=2248.7601, Expected=2250.9732
# Run 8 — RMSE: 11.560896, MSE: 133.654307, NMSE: 0.0008050468
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=2156.8858, Expected=2158.6526
# Month=2, Predicted=2159.2444, Expected=2164.2981
# Month=3, Predicted=2164.2138, Expected=2159.7606
# Month=4, Predicted=2160.3158, Expected=2161.4376
# Month=5, Predicted=2162.5694, Expected=2137.8646
# Month=6, Predicted=2137.0275, Expected=2129.8135
# Month=7, Predicted=2135.3644, Expected=2139.7576
# Month=8, Predicted=2140.2689, Expected=2132.9794
# Month=9, Predicted=2132.6892, Expected=2137.7327
# Month=10, Predicted=2137.2165, Expected=2140.9908
# Month=11, Predicted=2140.8745, Expected=2142.7933
# Month=12, Predicted=2142.7638, Expected=2139.9770
# Month=13, Predicted=2140.8486, Expected=2149.0323
# Month=14, Predicted=2148.9431, Expected=2149.0240
# Month=15, Predicted=2148.5624, Expected=2136.4962
# Month=16, Predicted=2139.7620, Expected=2144.3202
# Month=17, Predicted=2145.0852, Expected=2132.4895
# Month=18, Predicted=2129.5268, Expected=2130.0402
# Month=19, Predicted=2133.2086, Expected=2130.6262
# Month=20, Predicted=2130.4812, Expected=2109.7183
# Month=21, Predicted=2110.0187, Expected=2099.3737
# Month=22, Predicted=2104.9680, Expected=2084.2720
# Month=23, Predicted=2083.0690, Expected=2100.9191
# Month=24, Predicted=2099.2532, Expected=2129.7607
# Month=25, Predicted=2129.9578, Expected=2131.9435
# Month=26, Predicted=2130.8167, Expected=2167.0996
# Month=27, Predicted=2160.7855, Expected=2162.5903
# Month=28, Predicted=2161.6761, Expected=2165.3947
# Month=29, Predicted=2170.6033, Expected=2168.3314
# Month=30, Predicted=2166.5573, Expected=2178.6993
# Month=31, Predicted=2177.8571, Expected=2177.6668
# Month=32, Predicted=2177.6408, Expected=2187.1968
# Month=33, Predicted=2188.4196, Expected=2185.6153
# Month=34, Predicted=2184.7274, Expected=2201.3217
# Month=35, Predicted=2200.7128, Expected=2199.1001
# Month=36, Predicted=2198.6079, Expected=2206.3025
# Month=37, Predicted=2207.0172, Expected=2209.6655
# Month=38, Predicted=2209.4046, Expected=2200.3987
# Month=39, Predicted=2201.5010, Expected=2205.3133
# Month=40, Predicted=2206.5413, Expected=2199.8010
# Month=41, Predicted=2198.4014, Expected=2191.2295
# Month=42, Predicted=2193.8395, Expected=2200.6729
# Month=43, Predicted=2200.3720, Expected=2206.9309
# Month=44, Predicted=2207.0364, Expected=2211.8030
# Month=45, Predicted=2211.5153, Expected=2241.4501
# Month=46, Predicted=2239.0594, Expected=2248.7070
# Month=47, Predicted=2248.6469, Expected=2258.9243
# Month=48, Predicted=2259.6381, Expected=2262.9858
# Month=49, Predicted=2262.9902, Expected=2268.7807
# Month=50, Predicted=2268.8355, Expected=2253.3697
# Month=51, Predicted=2253.2663, Expected=2266.7521
# Month=52, Predicted=2268.3992, Expected=2259.4951
# Month=53, Predicted=2255.6510, Expected=2266.9373
# Month=54, Predicted=2267.7966, Expected=2269.9337
# Month=55, Predicted=2269.7851, Expected=2262.7610
# Month=56, Predicted=2263.6500, Expected=2260.0101
# Month=57, Predicted=2261.7545, Expected=2265.8999
# Month=58, Predicted=2265.7722, Expected=2271.1218
# Month=59, Predicted=2270.9884, Expected=2249.7046
# Month=60, Predicted=2252.6552, Expected=2250.9732
# Run 9 — RMSE: 11.569467, MSE: 133.852562, NMSE: 0.0008166563
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=2156.4028, Expected=2158.6526
# Month=2, Predicted=2160.0693, Expected=2164.2981
# Month=3, Predicted=2165.4357, Expected=2159.7606
# Month=4, Predicted=2161.0063, Expected=2161.4376
# Month=5, Predicted=2162.7241, Expected=2137.8646
# Month=6, Predicted=2139.8456, Expected=2129.8135
# Month=7, Predicted=2132.3153, Expected=2139.7576
# Month=8, Predicted=2141.5273, Expected=2132.9794
# Month=9, Predicted=2134.5684, Expected=2137.7327
# Month=10, Predicted=2139.1661, Expected=2140.9908
# Month=11, Predicted=2142.1825, Expected=2142.7933
# Month=12, Predicted=2143.9287, Expected=2139.9770
# Month=13, Predicted=2141.2341, Expected=2149.0323
# Month=14, Predicted=2150.0870, Expected=2149.0240
# Month=15, Predicted=2150.0578, Expected=2136.4962
# Month=16, Predicted=2137.9923, Expected=2144.3202
# Month=17, Predicted=2145.7084, Expected=2132.4895
# Month=18, Predicted=2134.0533, Expected=2130.0402
# Month=19, Predicted=2131.7935, Expected=2130.6262
# Month=20, Predicted=2132.2034, Expected=2109.7183
# Month=21, Predicted=2111.8671, Expected=2099.3737
# Month=22, Predicted=2102.0335, Expected=2084.2720
# Month=23, Predicted=2087.2001, Expected=2100.9191
# Month=24, Predicted=2102.8051, Expected=2129.7607
# Month=25, Predicted=2130.1590, Expected=2131.9435
# Month=26, Predicted=2132.4462, Expected=2167.0996
# Month=27, Predicted=2166.9970, Expected=2162.5903
# Month=28, Predicted=2163.0548, Expected=2165.3947
# Month=29, Predicted=2166.0950, Expected=2168.3314
# Month=30, Predicted=2169.1623, Expected=2178.6993
# Month=31, Predicted=2179.4423, Expected=2177.6668
# Month=32, Predicted=2178.5430, Expected=2187.1968
# Month=33, Predicted=2188.0249, Expected=2185.6153
# Month=34, Predicted=2186.5524, Expected=2201.3217
# Month=35, Predicted=2202.0494, Expected=2199.1001
# Month=36, Predicted=2199.9330, Expected=2206.3025
# Month=37, Predicted=2207.1666, Expected=2209.6655
# Month=38, Predicted=2210.5328, Expected=2200.3987
# Month=39, Predicted=2201.6051, Expected=2205.3133
# Month=40, Predicted=2206.5620, Expected=2199.8010
# Month=41, Predicted=2201.1300, Expected=2191.2295
# Month=42, Predicted=2192.8878, Expected=2200.6729
# Month=43, Predicted=2202.0465, Expected=2206.9309
# Month=44, Predicted=2207.9480, Expected=2211.8030
# Month=45, Predicted=2212.7284, Expected=2241.4501
# Month=46, Predicted=2241.7764, Expected=2248.7070
# Month=47, Predicted=2249.1049, Expected=2258.9243
# Month=48, Predicted=2259.3884, Expected=2262.9858
# Month=49, Predicted=2263.5960, Expected=2268.7807
# Month=50, Predicted=2269.4825, Expected=2253.3697
# Month=51, Predicted=2254.5563, Expected=2266.7521
# Month=52, Predicted=2267.8733, Expected=2259.4951
# Month=53, Predicted=2260.6644, Expected=2266.9373
# Month=54, Predicted=2268.0750, Expected=2269.9337
# Month=55, Predicted=2270.9502, Expected=2262.7610
# Month=56, Predicted=2264.0276, Expected=2260.0101
# Month=57, Predicted=2261.4775, Expected=2265.8999
# Month=58, Predicted=2267.1679, Expected=2271.1218
# Month=59, Predicted=2272.1705, Expected=2249.7046
# Month=60, Predicted=2251.3637, Expected=2250.9732
# Run 10 — RMSE: 11.178517, MSE: 124.959242, NMSE: 0.0007668408
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=2153.4207, Expected=2158.6526
# Month=2, Predicted=2157.1310, Expected=2164.2981
# Month=3, Predicted=2162.7706, Expected=2159.7606
# Month=4, Predicted=2158.2963, Expected=2161.4376
# Month=5, Predicted=2159.9667, Expected=2137.8646
# Month=6, Predicted=2138.4977, Expected=2129.8135
# Month=7, Predicted=2133.7660, Expected=2139.7576
# Month=8, Predicted=2141.7722, Expected=2132.9794
# Month=9, Predicted=2134.5910, Expected=2137.7327
# Month=10, Predicted=2136.5447, Expected=2140.9908
# Month=11, Predicted=2139.5347, Expected=2142.7933
# Month=12, Predicted=2141.8557, Expected=2139.9770
# Month=13, Predicted=2138.9086, Expected=2149.0323
# Month=14, Predicted=2147.9977, Expected=2149.0240
# Month=15, Predicted=2147.6017, Expected=2136.4962
# Month=16, Predicted=2135.2948, Expected=2144.3202
# Month=17, Predicted=2143.3419, Expected=2132.4895
# Month=18, Predicted=2133.5278, Expected=2130.0402
# Month=19, Predicted=2131.2674, Expected=2130.6262
# Month=20, Predicted=2131.0605, Expected=2109.7183
# Month=21, Predicted=2112.0967, Expected=2099.3737
# Month=22, Predicted=2102.4476, Expected=2084.2720
# Month=23, Predicted=2089.5782, Expected=2100.9191
# Month=24, Predicted=2100.6571, Expected=2129.7607
# Month=25, Predicted=2129.3078, Expected=2131.9435
# Month=26, Predicted=2133.5520, Expected=2167.0996
# Month=27, Predicted=2174.7000, Expected=2162.5903
# Month=28, Predicted=2169.1296, Expected=2165.3947
# Month=29, Predicted=2169.0776, Expected=2168.3314
# Month=30, Predicted=2168.1282, Expected=2178.6993
# Month=31, Predicted=2177.2786, Expected=2177.6668
# Month=32, Predicted=2176.3663, Expected=2187.1968
# Month=33, Predicted=2185.8992, Expected=2185.6153
# Month=34, Predicted=2184.5950, Expected=2201.3217
# Month=35, Predicted=2199.8247, Expected=2199.1001
# Month=36, Predicted=2197.6148, Expected=2206.3025
# Month=37, Predicted=2205.1842, Expected=2209.6655
# Month=38, Predicted=2208.5578, Expected=2200.3987
# Month=39, Predicted=2198.8699, Expected=2205.3133
# Month=40, Predicted=2203.8597, Expected=2199.8010
# Month=41, Predicted=2199.1889, Expected=2191.2295
# Month=42, Predicted=2192.1285, Expected=2200.6729
# Month=43, Predicted=2200.2818, Expected=2206.9309
# Month=44, Predicted=2205.6355, Expected=2211.8030
# Month=45, Predicted=2210.3563, Expected=2241.4501
# Month=46, Predicted=2243.3238, Expected=2248.7070
# Month=47, Predicted=2251.6035, Expected=2258.9243
# Month=48, Predicted=2262.8440, Expected=2262.9858
# Month=49, Predicted=2265.4063, Expected=2268.7807
# Month=50, Predicted=2269.2195, Expected=2253.3697
# Month=51, Predicted=2251.8463, Expected=2266.7521
# Month=52, Predicted=2265.7307, Expected=2259.4951
# Month=53, Predicted=2260.8322, Expected=2266.9373
# Month=54, Predicted=2267.0824, Expected=2269.9337
# Month=55, Predicted=2269.1429, Expected=2262.7610
# Month=56, Predicted=2261.6757, Expected=2260.0101
# Month=57, Predicted=2258.6750, Expected=2265.8999
# Month=58, Predicted=2264.3747, Expected=2271.1218
# Month=59, Predicted=2269.6480, Expected=2249.7046
# Month=60, Predicted=2248.5346, Expected=2250.9732
# Run 11 — RMSE: 11.244171, MSE: 126.431372, NMSE: 0.0007798368
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=2158.0921, Expected=2158.6526
# Month=2, Predicted=2159.7925, Expected=2164.2981
# Month=3, Predicted=2162.2117, Expected=2159.7606
# Month=4, Predicted=2159.9120, Expected=2161.4376
# Month=5, Predicted=2162.8079, Expected=2137.8646
# Month=6, Predicted=2141.2026, Expected=2129.8135
# Month=7, Predicted=2138.2225, Expected=2139.7576
# Month=8, Predicted=2137.4622, Expected=2132.9794
# Month=9, Predicted=2131.3918, Expected=2137.7327
# Month=10, Predicted=2138.7701, Expected=2140.9908
# Month=11, Predicted=2139.1492, Expected=2142.7933
# Month=12, Predicted=2142.2570, Expected=2139.9770
# Month=13, Predicted=2141.0058, Expected=2149.0323
# Month=14, Predicted=2148.1177, Expected=2149.0240
# Month=15, Predicted=2147.5018, Expected=2136.4962
# Month=16, Predicted=2140.1719, Expected=2144.3202
# Month=17, Predicted=2145.0991, Expected=2132.4895
# Month=18, Predicted=2132.3850, Expected=2130.0402
# Month=19, Predicted=2134.2719, Expected=2130.6262
# Month=20, Predicted=2130.2803, Expected=2109.7183
# Month=21, Predicted=2113.0394, Expected=2099.3737
# Month=22, Predicted=2107.7204, Expected=2084.2720
# Month=23, Predicted=2089.2523, Expected=2100.9191
# Month=24, Predicted=2099.0076, Expected=2129.7607
# Month=25, Predicted=2129.1431, Expected=2131.9435
# Month=26, Predicted=2128.1463, Expected=2167.0996
# Month=27, Predicted=2165.4751, Expected=2162.5903
# Month=28, Predicted=2158.9955, Expected=2165.3947
# Month=29, Predicted=2171.9093, Expected=2168.3314
# Month=30, Predicted=2169.2246, Expected=2178.6993
# Month=31, Predicted=2177.8392, Expected=2177.6668
# Month=32, Predicted=2177.6170, Expected=2187.1968
# Month=33, Predicted=2187.1990, Expected=2185.6153
# Month=34, Predicted=2184.8475, Expected=2201.3217
# Month=35, Predicted=2199.5888, Expected=2199.1001
# Month=36, Predicted=2196.7770, Expected=2206.3025
# Month=37, Predicted=2206.6274, Expected=2209.6655
# Month=38, Predicted=2207.7218, Expected=2200.3987
# Month=39, Predicted=2201.7765, Expected=2205.3133
# Month=40, Predicted=2206.1441, Expected=2199.8010
# Month=41, Predicted=2198.8585, Expected=2191.2295
# Month=42, Predicted=2194.2505, Expected=2200.6729
# Month=43, Predicted=2199.1030, Expected=2206.9309
# Month=44, Predicted=2203.1368, Expected=2211.8030
# Month=45, Predicted=2209.6327, Expected=2241.4501
# Month=46, Predicted=2239.4124, Expected=2248.7070
# Month=47, Predicted=2243.9066, Expected=2258.9243
# Month=48, Predicted=2258.3259, Expected=2262.9858
# Month=49, Predicted=2261.6327, Expected=2268.7807
# Month=50, Predicted=2268.2161, Expected=2253.3697
# Month=51, Predicted=2255.2763, Expected=2266.7521
# Month=52, Predicted=2266.6866, Expected=2259.4951
# Month=53, Predicted=2257.0035, Expected=2266.9373
# Month=54, Predicted=2267.1270, Expected=2269.9337
# Month=55, Predicted=2267.1665, Expected=2262.7610
# Month=56, Predicted=2263.2769, Expected=2260.0101
# Month=57, Predicted=2262.1052, Expected=2265.8999
# Month=58, Predicted=2264.1080, Expected=2271.1218
# Month=59, Predicted=2268.2873, Expected=2249.7046
# Month=60, Predicted=2251.3076, Expected=2250.9732
# Run 12 — RMSE: 11.776554, MSE: 138.687233, NMSE: 0.0008735964
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=2154.4222, Expected=2158.6526
# Month=2, Predicted=2154.9051, Expected=2164.2981
# Month=3, Predicted=2163.4896, Expected=2159.7606
# Month=4, Predicted=2157.8921, Expected=2161.4376
# Month=5, Predicted=2157.8409, Expected=2137.8646
# Month=6, Predicted=2142.9453, Expected=2129.8135
# Month=7, Predicted=2137.2208, Expected=2139.7576
# Month=8, Predicted=2141.3751, Expected=2132.9794
# Month=9, Predicted=2132.3384, Expected=2137.7327
# Month=10, Predicted=2133.5649, Expected=2140.9908
# Month=11, Predicted=2139.8989, Expected=2142.7933
# Month=12, Predicted=2139.9434, Expected=2139.9770
# Month=13, Predicted=2137.4512, Expected=2149.0323
# Month=14, Predicted=2145.4949, Expected=2149.0240
# Month=15, Predicted=2147.4875, Expected=2136.4962
# Month=16, Predicted=2137.6711, Expected=2144.3202
# Month=17, Predicted=2139.2383, Expected=2132.4895
# Month=18, Predicted=2132.0663, Expected=2130.0402
# Month=19, Predicted=2128.8081, Expected=2130.6262
# Month=20, Predicted=2128.4507, Expected=2109.7183
# Month=21, Predicted=2114.0898, Expected=2099.3737
# Month=22, Predicted=2106.4712, Expected=2084.2720
# Month=23, Predicted=2085.6621, Expected=2100.9191
# Month=24, Predicted=2097.9499, Expected=2129.7607
# Month=25, Predicted=2140.8640, Expected=2131.9435
# Month=26, Predicted=2132.5909, Expected=2167.0996
# Month=27, Predicted=2168.5234, Expected=2162.5903
# Month=28, Predicted=2163.4684, Expected=2165.3947
# Month=29, Predicted=2162.4503, Expected=2168.3314
# Month=30, Predicted=2166.5326, Expected=2178.6993
# Month=31, Predicted=2176.3887, Expected=2177.6668
# Month=32, Predicted=2175.8325, Expected=2187.1968
# Month=33, Predicted=2183.0068, Expected=2185.6153
# Month=34, Predicted=2183.9040, Expected=2201.3217
# Month=35, Predicted=2198.0575, Expected=2199.1001
# Month=36, Predicted=2198.2226, Expected=2206.3025
# Month=37, Predicted=2201.5223, Expected=2209.6655
# Month=38, Predicted=2207.9829, Expected=2200.3987
# Month=39, Predicted=2199.4241, Expected=2205.3133
# Month=40, Predicted=2200.6517, Expected=2199.8010
# Month=41, Predicted=2198.1505, Expected=2191.2295
# Month=42, Predicted=2191.2164, Expected=2200.6729
# Month=43, Predicted=2196.9286, Expected=2206.9309
# Month=44, Predicted=2207.2290, Expected=2211.8030
# Month=45, Predicted=2209.0088, Expected=2241.4501
# Month=46, Predicted=2246.2391, Expected=2248.7070
# Month=47, Predicted=2250.5088, Expected=2258.9243
# Month=48, Predicted=2255.0511, Expected=2262.9858
# Month=49, Predicted=2260.4774, Expected=2268.7807
# Month=50, Predicted=2264.9826, Expected=2253.3697
# Month=51, Predicted=2254.2083, Expected=2266.7521
# Month=52, Predicted=2260.2533, Expected=2259.4951
# Month=53, Predicted=2259.2290, Expected=2266.9373
# Month=54, Predicted=2261.8710, Expected=2269.9337
# Month=55, Predicted=2269.0088, Expected=2262.7610
# Month=56, Predicted=2261.1273, Expected=2260.0101
# Month=57, Predicted=2257.5250, Expected=2265.8999
# Month=58, Predicted=2263.1738, Expected=2271.1218
# Month=59, Predicted=2269.5219, Expected=2249.7046
# Month=60, Predicted=2253.7077, Expected=2250.9732
# Run 13 — RMSE: 11.699181, MSE: 136.870847, NMSE: 0.0008593193
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=2154.9231, Expected=2158.6526
# Month=2, Predicted=2160.1898, Expected=2164.2981
# Month=3, Predicted=2162.4969, Expected=2159.7606
# Month=4, Predicted=2158.9901, Expected=2161.4376
# Month=5, Predicted=2162.7440, Expected=2137.8646
# Month=6, Predicted=2141.0056, Expected=2129.8135
# Month=7, Predicted=2134.6615, Expected=2139.7576
# Month=8, Predicted=2137.4449, Expected=2132.9794
# Month=9, Predicted=2130.0281, Expected=2137.7327
# Month=10, Predicted=2139.9703, Expected=2140.9908
# Month=11, Predicted=2139.6760, Expected=2142.7933
# Month=12, Predicted=2140.9006, Expected=2139.9770
# Month=13, Predicted=2140.1871, Expected=2149.0323
# Month=14, Predicted=2147.9940, Expected=2149.0240
# Month=15, Predicted=2147.5019, Expected=2136.4962
# Month=16, Predicted=2138.9924, Expected=2144.3202
# Month=17, Predicted=2144.1997, Expected=2132.4895
# Month=18, Predicted=2130.8920, Expected=2130.0402
# Month=19, Predicted=2131.9731, Expected=2130.6262
# Month=20, Predicted=2129.9562, Expected=2109.7183
# Month=21, Predicted=2111.0164, Expected=2099.3737
# Month=22, Predicted=2105.8220, Expected=2084.2720
# Month=23, Predicted=2084.3682, Expected=2100.9191
# Month=24, Predicted=2098.8808, Expected=2129.7607
# Month=25, Predicted=2129.7424, Expected=2131.9435
# Month=26, Predicted=2130.8970, Expected=2167.0996
# Month=27, Predicted=2165.5305, Expected=2162.5903
# Month=28, Predicted=2161.1581, Expected=2165.3947
# Month=29, Predicted=2167.4319, Expected=2168.3314
# Month=30, Predicted=2167.9799, Expected=2178.6993
# Month=31, Predicted=2177.0311, Expected=2177.6668
# Month=32, Predicted=2177.1613, Expected=2187.1968
# Month=33, Predicted=2187.3447, Expected=2185.6153
# Month=34, Predicted=2185.1613, Expected=2201.3217
# Month=35, Predicted=2199.9292, Expected=2199.1001
# Month=36, Predicted=2198.3754, Expected=2206.3025
# Month=37, Predicted=2207.0628, Expected=2209.6655
# Month=38, Predicted=2208.9928, Expected=2200.3987
# Month=39, Predicted=2201.4459, Expected=2205.3133
# Month=40, Predicted=2206.2212, Expected=2199.8010
# Month=41, Predicted=2199.2586, Expected=2191.2295
# Month=42, Predicted=2193.6848, Expected=2200.6729
# Month=43, Predicted=2199.7771, Expected=2206.9309
# Month=44, Predicted=2204.8528, Expected=2211.8030
# Month=45, Predicted=2211.2887, Expected=2241.4501
# Month=46, Predicted=2240.0059, Expected=2248.7070
# Month=47, Predicted=2247.1436, Expected=2258.9243
# Month=48, Predicted=2259.2789, Expected=2262.9858
# Month=49, Predicted=2263.0184, Expected=2268.7807
# Month=50, Predicted=2268.1966, Expected=2253.3697
# Month=51, Predicted=2254.7759, Expected=2266.7521
# Month=52, Predicted=2266.6760, Expected=2259.4951
# Month=53, Predicted=2258.0981, Expected=2266.9373
# Month=54, Predicted=2267.3096, Expected=2269.9337
# Month=55, Predicted=2269.3693, Expected=2262.7610
# Month=56, Predicted=2263.9261, Expected=2260.0101
# Month=57, Predicted=2262.2315, Expected=2265.8999
# Month=58, Predicted=2264.5286, Expected=2271.1218
# Month=59, Predicted=2269.4441, Expected=2249.7046
# Month=60, Predicted=2253.3670, Expected=2250.9732
# Run 14 — RMSE: 11.495926, MSE: 132.156309, NMSE: 0.0008074997
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=2155.8660, Expected=2158.6526
# Month=2, Predicted=2158.8120, Expected=2164.2981
# Month=3, Predicted=2164.5498, Expected=2159.7606
# Month=4, Predicted=2160.1038, Expected=2161.4376
# Month=5, Predicted=2161.8675, Expected=2137.8646
# Month=6, Predicted=2140.4753, Expected=2129.8135
# Month=7, Predicted=2134.4568, Expected=2139.7576
# Month=8, Predicted=2140.1066, Expected=2132.9794
# Month=9, Predicted=2130.0157, Expected=2137.7327
# Month=10, Predicted=2137.7060, Expected=2140.9908
# Month=11, Predicted=2140.8364, Expected=2142.7933
# Month=12, Predicted=2142.8088, Expected=2139.9770
# Month=13, Predicted=2140.8823, Expected=2149.0323
# Month=14, Predicted=2148.1041, Expected=2149.0240
# Month=15, Predicted=2149.3688, Expected=2136.4962
# Month=16, Predicted=2138.4179, Expected=2144.3202
# Month=17, Predicted=2143.8026, Expected=2132.4895
# Month=18, Predicted=2131.2647, Expected=2130.0402
# Month=19, Predicted=2131.0199, Expected=2130.6262
# Month=20, Predicted=2131.0531, Expected=2109.7183
# Month=21, Predicted=2109.4289, Expected=2099.3737
# Month=22, Predicted=2103.1821, Expected=2084.2720
# Month=23, Predicted=2085.1778, Expected=2100.9191
# Month=24, Predicted=2101.0166, Expected=2129.7607
# Month=25, Predicted=2129.0341, Expected=2131.9435
# Month=26, Predicted=2132.2702, Expected=2167.0996
# Month=27, Predicted=2161.8450, Expected=2162.5903
# Month=28, Predicted=2165.6544, Expected=2165.3947
# Month=29, Predicted=2168.9153, Expected=2168.3314
# Month=30, Predicted=2168.5109, Expected=2178.6993
# Month=31, Predicted=2179.0752, Expected=2177.6668
# Month=32, Predicted=2177.1605, Expected=2187.1968
# Month=33, Predicted=2187.3286, Expected=2185.6153
# Month=34, Predicted=2186.2374, Expected=2201.3217
# Month=35, Predicted=2200.6268, Expected=2199.1001
# Month=36, Predicted=2199.0890, Expected=2206.3025
# Month=37, Predicted=2206.6319, Expected=2209.6655
# Month=38, Predicted=2210.3050, Expected=2200.3987
# Month=39, Predicted=2201.6558, Expected=2205.3133
# Month=40, Predicted=2205.9648, Expected=2199.8010
# Month=41, Predicted=2199.3529, Expected=2191.2295
# Month=42, Predicted=2192.0013, Expected=2200.6729
# Month=43, Predicted=2200.5966, Expected=2206.9309
# Month=44, Predicted=2206.6246, Expected=2211.8030
# Month=45, Predicted=2212.0916, Expected=2241.4501
# Month=46, Predicted=2239.3600, Expected=2248.7070
# Month=47, Predicted=2249.0605, Expected=2258.9243
# Month=48, Predicted=2259.0491, Expected=2262.9858
# Month=49, Predicted=2264.1602, Expected=2268.7807
# Month=50, Predicted=2269.2932, Expected=2253.3697
# Month=51, Predicted=2253.9568, Expected=2266.7521
# Month=52, Predicted=2266.7293, Expected=2259.4951
# Month=53, Predicted=2256.5856, Expected=2266.9373
# Month=54, Predicted=2267.2539, Expected=2269.9337
# Month=55, Predicted=2270.2358, Expected=2262.7610
# Month=56, Predicted=2264.0395, Expected=2260.0101
# Month=57, Predicted=2261.7272, Expected=2265.8999
# Month=58, Predicted=2266.0398, Expected=2271.1218
# Month=59, Predicted=2271.0738, Expected=2249.7046
# Month=60, Predicted=2250.0353, Expected=2250.9732
# Run 15 — RMSE: 11.269247, MSE: 126.995938, NMSE: 0.0007763030
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=2154.7350, Expected=2158.6526
# Month=2, Predicted=2158.5244, Expected=2164.2981
# Month=3, Predicted=2163.1499, Expected=2159.7606
# Month=4, Predicted=2158.7911, Expected=2161.4376
# Month=5, Predicted=2161.1823, Expected=2137.8646
# Month=6, Predicted=2139.6408, Expected=2129.8135
# Month=7, Predicted=2132.8714, Expected=2139.7576
# Month=8, Predicted=2140.0266, Expected=2132.9794
# Month=9, Predicted=2131.7240, Expected=2137.7327
# Month=10, Predicted=2137.8115, Expected=2140.9908
# Month=11, Predicted=2140.6027, Expected=2142.7933
# Month=12, Predicted=2142.0821, Expected=2139.9770
# Month=13, Predicted=2139.2939, Expected=2149.0323
# Month=14, Predicted=2148.1759, Expected=2149.0240
# Month=15, Predicted=2147.3751, Expected=2136.4962
# Month=16, Predicted=2136.6000, Expected=2144.3202
# Month=17, Predicted=2144.6349, Expected=2132.4895
# Month=18, Predicted=2131.8391, Expected=2130.0402
# Month=19, Predicted=2130.4109, Expected=2130.6262
# ...
# Month=59, Predicted=2268.2355, Expected=2249.7046
# Month=60, Predicted=2249.2183, Expected=2250.9732
# Run 25 — RMSE: 11.582140, MSE: 134.145969, NMSE: 0.0008486516
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=2155.3413, Expected=2158.6526
# Month=2, Predicted=2159.6288, Expected=2164.2981
# Month=3, Predicted=2163.8662, Expected=2159.7606
# Month=4, Predicted=2158.9975, Expected=2161.4376
# Month=5, Predicted=2161.7165, Expected=2137.8646
# Month=6, Predicted=2138.9500, Expected=2129.8135
# Month=7, Predicted=2134.0010, Expected=2139.7576
# Month=8, Predicted=2141.4976, Expected=2132.9794
# Month=9, Predicted=2132.5796, Expected=2137.7327
# Month=10, Predicted=2138.2086, Expected=2140.9908
# Month=11, Predicted=2140.6450, Expected=2142.7933
# Month=12, Predicted=2142.4065, Expected=2139.9770
# Month=13, Predicted=2140.0308, Expected=2149.0323
# Month=14, Predicted=2149.2442, Expected=2149.0240
# Month=15, Predicted=2148.1495, Expected=2136.4962
# Month=16, Predicted=2136.9302, Expected=2144.3202
# Month=17, Predicted=2145.9211, Expected=2132.4895
# Month=18, Predicted=2132.6706, Expected=2130.0402
# Month=19, Predicted=2131.7707, Expected=2130.6262
# Month=20, Predicted=2131.5221, Expected=2109.7183
# Month=21, Predicted=2110.9341, Expected=2099.3737
# Month=22, Predicted=2103.3790, Expected=2084.2720
# Month=23, Predicted=2087.9197, Expected=2100.9191
# Month=24, Predicted=2103.2301, Expected=2129.7607
# Month=25, Predicted=2128.1151, Expected=2131.9435
# Month=26, Predicted=2128.2288, Expected=2167.0996
# Month=27, Predicted=2164.9189, Expected=2162.5903
# Month=28, Predicted=2158.5202, Expected=2165.3947
# Month=29, Predicted=2165.7673, Expected=2168.3314
# Month=30, Predicted=2168.8207, Expected=2178.6993
# Month=31, Predicted=2178.2334, Expected=2177.6668
# Month=32, Predicted=2176.1793, Expected=2187.1968
# Month=33, Predicted=2186.3575, Expected=2185.6153
# Month=34, Predicted=2184.1139, Expected=2201.3217
# Month=35, Predicted=2200.2597, Expected=2199.1001
# Month=36, Predicted=2196.7450, Expected=2206.3025
# Month=37, Predicted=2205.4075, Expected=2209.6655
# Month=38, Predicted=2208.2243, Expected=2200.3987
# Month=39, Predicted=2199.6671, Expected=2205.3133
# Month=40, Predicted=2205.8602, Expected=2199.8010
# Month=41, Predicted=2199.2425, Expected=2191.2295
# Month=42, Predicted=2191.7225, Expected=2200.6729
# Month=43, Predicted=2201.0258, Expected=2206.9309
# Month=44, Predicted=2205.2423, Expected=2211.8030
# Month=45, Predicted=2209.8417, Expected=2241.4501
# Month=46, Predicted=2238.8935, Expected=2248.7070
# Month=47, Predicted=2244.1108, Expected=2258.9243
# Month=48, Predicted=2256.2349, Expected=2262.9858
# Month=49, Predicted=2261.0370, Expected=2268.7807
# Month=50, Predicted=2267.6061, Expected=2253.3697
# Month=51, Predicted=2252.8582, Expected=2266.7521
# Month=52, Predicted=2267.7352, Expected=2259.4951
# Month=53, Predicted=2258.0674, Expected=2266.9373
# Month=54, Predicted=2266.5185, Expected=2269.9337
# Month=55, Predicted=2268.3292, Expected=2262.7610
# Month=56, Predicted=2261.7272, Expected=2260.0101
# Month=57, Predicted=2260.4746, Expected=2265.8999
# Month=58, Predicted=2265.7456, Expected=2271.1218
# Month=59, Predicted=2269.6515, Expected=2249.7046
# Month=60, Predicted=2249.0136, Expected=2250.9732
# Run 26 — RMSE: 11.688755, MSE: 136.627004, NMSE: 0.0008564404
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=2155.1621, Expected=2158.6526
# Month=2, Predicted=2159.5755, Expected=2164.2981
# Month=3, Predicted=2165.4271, Expected=2159.7606
# Month=4, Predicted=2159.3822, Expected=2161.4376
# Month=5, Predicted=2160.6066, Expected=2137.8646
# Month=6, Predicted=2135.7607, Expected=2129.8135
# Month=7, Predicted=2127.4767, Expected=2139.7576
# Month=8, Predicted=2137.5745, Expected=2132.9794
# Month=9, Predicted=2128.5891, Expected=2137.7327
# Month=10, Predicted=2132.8557, Expected=2140.9908
# Month=11, Predicted=2135.4616, Expected=2142.7933
# Month=12, Predicted=2138.7065, Expected=2139.9770
# Month=13, Predicted=2137.8226, Expected=2149.0323
# Month=14, Predicted=2147.5946, Expected=2149.0240
# Month=15, Predicted=2149.5495, Expected=2136.4962
# Month=16, Predicted=2145.6642, Expected=2144.3202
# Month=17, Predicted=2150.2208, Expected=2132.4895
# Month=18, Predicted=2140.0692, Expected=2130.0402
# Month=19, Predicted=2140.9142, Expected=2130.6262
# Month=20, Predicted=2134.2624, Expected=2109.7183
# Month=21, Predicted=2119.0711, Expected=2099.3737
# Month=22, Predicted=2105.8983, Expected=2084.2720
# Month=23, Predicted=2087.8668, Expected=2100.9191
# Month=24, Predicted=2101.5747, Expected=2129.7607
# Month=25, Predicted=2135.4128, Expected=2131.9435
# Month=26, Predicted=2132.4034, Expected=2167.0996
# Month=27, Predicted=2169.7765, Expected=2162.5903
# Month=28, Predicted=2163.0908, Expected=2165.3947
# Month=29, Predicted=2165.1068, Expected=2168.3314
# Month=30, Predicted=2168.6913, Expected=2178.6993
# Month=31, Predicted=2177.9016, Expected=2177.6668
# Month=32, Predicted=2176.6320, Expected=2187.1968
# Month=33, Predicted=2185.4360, Expected=2185.6153
# Month=34, Predicted=2183.4090, Expected=2201.3217
# Month=35, Predicted=2198.6666, Expected=2199.1001
# Month=36, Predicted=2195.8948, Expected=2206.3025
# Month=37, Predicted=2204.0470, Expected=2209.6655
# Month=38, Predicted=2206.2483, Expected=2200.3987
# Month=39, Predicted=2201.1362, Expected=2205.3133
# Month=40, Predicted=2204.6914, Expected=2199.8010
# Month=41, Predicted=2200.3355, Expected=2191.2295
# Month=42, Predicted=2196.0700, Expected=2200.6729
# Month=43, Predicted=2201.0050, Expected=2206.9309
# Month=44, Predicted=2206.6415, Expected=2211.8030
# Month=45, Predicted=2212.7791, Expected=2241.4501
# Month=46, Predicted=2241.2834, Expected=2248.7070
# Month=47, Predicted=2248.2979, Expected=2258.9243
# Month=48, Predicted=2259.8426, Expected=2262.9858
# Month=49, Predicted=2263.1627, Expected=2268.7807
# Month=50, Predicted=2269.5897, Expected=2253.3697
# Month=51, Predicted=2254.4337, Expected=2266.7521
# Month=52, Predicted=2267.3137, Expected=2259.4951
# Month=53, Predicted=2260.0012, Expected=2266.9373
# Month=54, Predicted=2267.2630, Expected=2269.9337
# Month=55, Predicted=2271.4470, Expected=2262.7610
# Month=56, Predicted=2262.5867, Expected=2260.0101
# Month=57, Predicted=2259.8946, Expected=2265.8999
# Month=58, Predicted=2265.6870, Expected=2271.1218
# Month=59, Predicted=2270.8195, Expected=2249.7046
# Month=60, Predicted=2247.9613, Expected=2250.9732
# Run 27 — RMSE: 11.976974, MSE: 143.447907, NMSE: 0.0008953757
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=2157.0038, Expected=2158.6526
# Month=2, Predicted=2159.1433, Expected=2164.2981
# Month=3, Predicted=2164.1166, Expected=2159.7606
# Month=4, Predicted=2160.4807, Expected=2161.4376
# Month=5, Predicted=2162.0862, Expected=2137.8646
# Month=6, Predicted=2140.2162, Expected=2129.8135
# Month=7, Predicted=2134.1969, Expected=2139.7576
# Month=8, Predicted=2137.8676, Expected=2132.9794
# Month=9, Predicted=2133.1112, Expected=2137.7327
# Month=10, Predicted=2138.0702, Expected=2140.9908
# Month=11, Predicted=2141.0239, Expected=2142.7933
# Month=12, Predicted=2142.7757, Expected=2139.9770
# Month=13, Predicted=2140.1414, Expected=2149.0323
# Month=14, Predicted=2148.8446, Expected=2149.0240
# Month=15, Predicted=2149.0086, Expected=2136.4962
# Month=16, Predicted=2137.2745, Expected=2144.3202
# Month=17, Predicted=2144.6913, Expected=2132.4895
# Month=18, Predicted=2132.6698, Expected=2130.0402
# Month=19, Predicted=2132.0243, Expected=2130.6262
# Month=20, Predicted=2130.5855, Expected=2109.7183
# Month=21, Predicted=2112.8042, Expected=2099.3737
# Month=22, Predicted=2104.1422, Expected=2084.2720
# Month=23, Predicted=2087.2111, Expected=2100.9191
# Month=24, Predicted=2098.4599, Expected=2129.7607
# Month=25, Predicted=2133.6320, Expected=2131.9435
# Month=26, Predicted=2130.9498, Expected=2167.0996
# Month=27, Predicted=2164.6225, Expected=2162.5903
# Month=28, Predicted=2162.5986, Expected=2165.3947
# Month=29, Predicted=2164.0349, Expected=2168.3314
# Month=30, Predicted=2167.7968, Expected=2178.6993
# Month=31, Predicted=2177.8807, Expected=2177.6668
# Month=32, Predicted=2177.8133, Expected=2187.1968
# Month=33, Predicted=2187.6010, Expected=2185.6153
# Month=34, Predicted=2186.7218, Expected=2201.3217
# Month=35, Predicted=2201.8534, Expected=2199.1001
# Month=36, Predicted=2200.0948, Expected=2206.3025
# Month=37, Predicted=2207.8513, Expected=2209.6655
# Month=38, Predicted=2210.4346, Expected=2200.3987
# Month=39, Predicted=2203.4994, Expected=2205.3133
# Month=40, Predicted=2206.6173, Expected=2199.8010
# Month=41, Predicted=2201.0480, Expected=2191.2295
# Month=42, Predicted=2194.7760, Expected=2200.6729
# Month=43, Predicted=2200.0752, Expected=2206.9309
# Month=44, Predicted=2206.8023, Expected=2211.8030
# Month=45, Predicted=2211.9197, Expected=2241.4501
# Month=46, Predicted=2241.6311, Expected=2248.7070
# Month=47, Predicted=2247.6234, Expected=2258.9243
# Month=48, Predicted=2256.7842, Expected=2262.9858
# Month=49, Predicted=2262.0585, Expected=2268.7807
# Month=50, Predicted=2268.0972, Expected=2253.3697
# Month=51, Predicted=2254.2882, Expected=2266.7521
# Month=52, Predicted=2268.1011, Expected=2259.4951
# Month=53, Predicted=2260.5293, Expected=2266.9373
# Month=54, Predicted=2268.8206, Expected=2269.9337
# Month=55, Predicted=2270.3443, Expected=2262.7610
# Month=56, Predicted=2265.6122, Expected=2260.0101
# Month=57, Predicted=2262.5236, Expected=2265.8999
# Month=58, Predicted=2265.6545, Expected=2271.1218
# Month=59, Predicted=2271.1622, Expected=2249.7046
# Month=60, Predicted=2253.2462, Expected=2250.9732
# Run 28 — RMSE: 11.435418, MSE: 130.768787, NMSE: 0.0007981286
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=2150.7108, Expected=2158.6526
# Month=2, Predicted=2154.4389, Expected=2164.2981
# Month=3, Predicted=2160.0844, Expected=2159.7606
# Month=4, Predicted=2155.5472, Expected=2161.4376
# Month=5, Predicted=2157.2241, Expected=2137.8646
# Month=6, Predicted=2133.6516, Expected=2129.8135
# Month=7, Predicted=2125.6002, Expected=2139.7576
# Month=8, Predicted=2135.5440, Expected=2132.9794
# Month=9, Predicted=2128.7662, Expected=2137.7327
# Month=10, Predicted=2133.5194, Expected=2140.9908
# Month=11, Predicted=2136.7776, Expected=2142.7933
# Month=12, Predicted=2138.5802, Expected=2139.9770
# Month=13, Predicted=2135.7641, Expected=2149.0323
# Month=14, Predicted=2144.8192, Expected=2149.0240
# Month=15, Predicted=2144.8112, Expected=2136.4962
# Month=16, Predicted=2132.2838, Expected=2144.3202
# Month=17, Predicted=2140.1073, Expected=2132.4895
# Month=18, Predicted=2128.2772, Expected=2130.0402
# Month=19, Predicted=2125.8277, Expected=2130.6262
# Month=20, Predicted=2126.4136, Expected=2109.7183
# Month=21, Predicted=2105.5065, Expected=2099.3737
# Month=22, Predicted=2095.1615, Expected=2084.2720
# Month=23, Predicted=2080.0600, Expected=2100.9191
# Month=24, Predicted=2096.7064, Expected=2129.7607
# Month=25, Predicted=2125.5478, Expected=2131.9435
# Month=26, Predicted=2127.7315, Expected=2167.0996
# Month=27, Predicted=2162.8868, Expected=2162.5903
# Month=28, Predicted=2158.3789, Expected=2165.3947
# Month=29, Predicted=2161.1830, Expected=2168.3314
# Month=30, Predicted=2164.1198, Expected=2178.6993
# Month=31, Predicted=2174.4875, Expected=2177.6668
# Month=32, Predicted=2173.4556, Expected=2187.1968
# Month=33, Predicted=2182.9852, Expected=2185.6153
# Month=34, Predicted=2181.4042, Expected=2201.3217
# Month=35, Predicted=2197.1101, Expected=2199.1001
# Month=36, Predicted=2194.8893, Expected=2206.3025
# Month=37, Predicted=2202.0914, Expected=2209.6655
# Month=38, Predicted=2205.4547, Expected=2200.3987
# Month=39, Predicted=2196.1884, Expected=2205.3133
# Month=40, Predicted=2201.1025, Expected=2199.8010
# Month=41, Predicted=2195.5907, Expected=2191.2295
# Month=42, Predicted=2187.0193, Expected=2200.6729
# Month=43, Predicted=2196.4622, Expected=2206.9309
# Month=44, Predicted=2202.7204, Expected=2211.8030
# Month=45, Predicted=2207.5927, Expected=2241.4501
# Month=46, Predicted=2237.2391, Expected=2248.7070
# Month=47, Predicted=2244.4971, Expected=2258.9243
# Month=48, Predicted=2254.7143, Expected=2262.9858
# Month=49, Predicted=2258.7762, Expected=2268.7807
# Month=50, Predicted=2264.5711, Expected=2253.3697
# Month=51, Predicted=2249.1611, Expected=2266.7521
# Month=52, Predicted=2262.5423, Expected=2259.4951
# Month=53, Predicted=2255.2864, Expected=2266.9373
# Month=54, Predicted=2262.7280, Expected=2269.9337
# Month=55, Predicted=2265.7248, Expected=2262.7610
# Month=56, Predicted=2258.5526, Expected=2260.0101
# Month=57, Predicted=2255.8015, Expected=2265.8999
# Month=58, Predicted=2261.6911, Expected=2271.1218
# Month=59, Predicted=2266.9132, Expected=2249.7046
# Month=60, Predicted=2245.4973, Expected=2250.9732
# Run 29 — RMSE: 12.543726, MSE: 157.345052, NMSE: 0.0009446069
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=2160.0474, Expected=2158.6526
# Month=2, Predicted=2162.9229, Expected=2164.2981
# Month=3, Predicted=2168.1512, Expected=2159.7606
# Month=4, Predicted=2164.4627, Expected=2161.4376
# Month=5, Predicted=2165.6885, Expected=2137.8646
# Month=6, Predicted=2145.0538, Expected=2129.8135
# Month=7, Predicted=2136.7745, Expected=2139.7576
# Month=8, Predicted=2144.8654, Expected=2132.9794
# Month=9, Predicted=2139.4667, Expected=2137.7327
# Month=10, Predicted=2143.0224, Expected=2140.9908
# Month=11, Predicted=2146.0993, Expected=2142.7933
# Month=12, Predicted=2147.8010, Expected=2139.9770
# Month=13, Predicted=2145.4056, Expected=2149.0323
# Month=14, Predicted=2153.1590, Expected=2149.0240
# Month=15, Predicted=2153.7163, Expected=2136.4962
# Month=16, Predicted=2142.6838, Expected=2144.3202
# Month=17, Predicted=2148.8215, Expected=2132.4895
# Month=18, Predicted=2138.9596, Expected=2130.0402
# Month=19, Predicted=2136.0669, Expected=2130.6262
# Month=20, Predicted=2136.3958, Expected=2109.7183
# Month=21, Predicted=2118.0741, Expected=2099.3737
# Month=22, Predicted=2107.7768, Expected=2084.2720
# Month=23, Predicted=2093.8926, Expected=2100.9191
# Month=24, Predicted=2106.9019, Expected=2129.7607
# Month=25, Predicted=2132.9056, Expected=2131.9435
# Month=26, Predicted=2136.5010, Expected=2167.0996
# Month=27, Predicted=2167.9854, Expected=2162.5903
# Month=28, Predicted=2165.8216, Expected=2165.3947
# Month=29, Predicted=2168.1334, Expected=2168.3314
# Month=30, Predicted=2171.1182, Expected=2178.6993
# Month=31, Predicted=2180.7325, Expected=2177.6668
# Month=32, Predicted=2180.4211, Expected=2187.1968
# Month=33, Predicted=2189.0439, Expected=2185.6153
# Month=34, Predicted=2188.1858, Expected=2201.3217
# Month=35, Predicted=2202.4337, Expected=2199.1001
# Month=36, Predicted=2201.2211, Expected=2206.3025
# Month=37, Predicted=2207.7320, Expected=2209.6655
# Month=38, Predicted=2211.2344, Expected=2200.3987
# Month=39, Predicted=2203.0481, Expected=2205.3133
# Month=40, Predicted=2207.1908, Expected=2199.8010
# Month=41, Predicted=2202.5790, Expected=2191.2295
# Month=42, Predicted=2194.7139, Expected=2200.6729
# Month=43, Predicted=2202.8331, Expected=2206.9309
# Month=44, Predicted=2209.0228, Expected=2211.8030
# Month=45, Predicted=2213.7519, Expected=2241.4501
# Month=46, Predicted=2241.3402, Expected=2248.7070
# Month=47, Predicted=2249.2486, Expected=2258.9243
# Month=48, Predicted=2259.0839, Expected=2262.9858
# Month=49, Predicted=2263.3027, Expected=2268.7807
# Month=50, Predicted=2268.9502, Expected=2253.3697
# Month=51, Predicted=2254.8310, Expected=2266.7521
# Month=52, Predicted=2266.8606, Expected=2259.4951
# Month=53, Predicted=2260.6965, Expected=2266.9373
# Month=54, Predicted=2267.3810, Expected=2269.9337
# Month=55, Predicted=2270.5209, Expected=2262.7610
# Month=56, Predicted=2264.0391, Expected=2260.0101
# Month=57, Predicted=2261.3351, Expected=2265.8999
# Month=58, Predicted=2266.7570, Expected=2271.1218
# Month=59, Predicted=2271.8907, Expected=2249.7046
# Month=60, Predicted=2252.5455, Expected=2250.9732
# Run 30 — RMSE: 11.501170, MSE: 132.276902, NMSE: 0.0008713392
#
# ===== FINAL RESULTS — Fuzzy Output Layer on S&P 500 (30 runs) =====
# RMSE: 11.471218 ± 0.286108
# MSE:  131.670697 ± 6.709191
# NMSE: 0.0008113922 ± 0.0000447371
#
# Best run: 5
#   RMSE: 11.102714
#   MSE:  123.270253
#   NMSE: 0.0007913890
# === Best Run Metrics ===
# RMSE: 11.102714
# MSE:  123.270253
# NMSE: 0.0007913890

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Output Layer on S&P 500
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
