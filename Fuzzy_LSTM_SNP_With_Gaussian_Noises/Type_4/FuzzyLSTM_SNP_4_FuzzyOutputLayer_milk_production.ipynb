# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 1)]               0
#
#  rnn (RNN)                   (1, 8)                    320
#
#  fuzzy_output_layer (FuzzyO  (1, 1)                    12
#  utputLayer)
#
# =================================================================
# Total params: 332 (1.30 KB)
# Trainable params: 332 (1.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 1)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input
    # ============================================================
    
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)
    
        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Output Layer on Monthly Milk Production (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Output Layer — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Output Layer — Monthly Milk Production\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.509499)
# ================================================================================
#
# Data shape: (168,)
# First 5 values: [589.25307559 560.92955441 640.32999695 656.77598287 726.88069898]
# Supervised data shape: (167, 2)
# Train: (107, 2), Test: (60, 2)
# X_train shape: (107, 1, 1), y_train shape: (107,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=759.5312, Expected=804.1312
# Month=2, Predicted=822.4307, Expected=755.9621
# Month=3, Predicted=793.2782, Expected=859.0224
# Month=4, Predicted=858.7956, Expected=877.9865
# Month=5, Predicted=892.3795, Expected=942.0307
# Month=6, Predicted=939.3616, Expected=914.2550
# Month=7, Predicted=910.7170, Expected=868.9020
# Month=8, Predicted=843.7758, Expected=834.1536
# Month=9, Predicted=800.2600, Expected=789.9823
# Month=10, Predicted=765.9184, Expected=799.4046
# Month=11, Predicted=785.3321, Expected=763.5823
# Month=12, Predicted=781.2167, Expected=800.3831
# Month=13, Predicted=810.2228, Expected=826.4030
# Month=14, Predicted=849.4167, Expected=798.5367
# Month=15, Predicted=829.2908, Expected=890.7147
# Month=16, Predicted=892.1847, Expected=899.2858
# Month=17, Predicted=915.7861, Expected=961.2990
# Month=18, Predicted=958.8482, Expected=936.1160
# Month=19, Predicted=935.0974, Expected=893.4953
# Month=20, Predicted=872.7810, Expected=854.7115
# Month=21, Predicted=825.2121, Expected=809.0508
# Month=22, Predicted=786.9964, Expected=809.7435
# Month=23, Predicted=796.8003, Expected=765.2099
# Month=24, Predicted=781.5278, Expected=805.0349
# Month=25, Predicted=812.8441, Expected=820.4588
# Month=26, Predicted=846.3700, Expected=773.2413
# Month=27, Predicted=806.8637, Expected=882.5316
# Month=28, Predicted=882.6579, Expected=898.7897
# Month=29, Predicted=919.6952, Expected=956.6009
# Month=30, Predicted=959.3572, Expected=923.8359
# Month=31, Predicted=926.2434, Expected=881.4145
# Month=32, Predicted=858.9505, Expected=836.3729
# Month=33, Predicted=804.9279, Expected=784.1159
# Month=34, Predicted=759.2581, Expected=791.6660
# Month=35, Predicted=776.0769, Expected=759.1810
# Month=36, Predicted=776.3820, Expected=802.0941
# Month=37, Predicted=812.8113, Expected=828.1324
# Month=38, Predicted=853.7103, Expected=778.3983
# Month=39, Predicted=813.2742, Expected=888.3698
# Month=40, Predicted=887.6354, Expected=901.3272
# Month=41, Predicted=919.7301, Expected=969.2659
# Month=42, Predicted=968.6710, Expected=947.1513
# Month=43, Predicted=947.0831, Expected=908.1276
# Month=44, Predicted=885.9652, Expected=867.1765
# Month=45, Predicted=835.1445, Expected=814.6535
# Month=46, Predicted=788.5526, Expected=812.1183
# Month=47, Predicted=794.9165, Expected=773.1493
# Month=48, Predicted=786.2634, Expected=812.6360
# Month=49, Predicted=820.9865, Expected=834.9506
# Month=50, Predicted=860.5230, Expected=782.2414
# Month=51, Predicted=818.0781, Expected=891.3930
# Month=52, Predicted=891.5935, Expected=903.3345
# Month=53, Predicted=924.7072, Expected=965.5034
# Month=54, Predicted=967.3676, Expected=937.4010
# Month=55, Predicted=939.9338, Expected=896.5903
# Month=56, Predicted=875.3426, Expected=857.5819
# Month=57, Predicted=826.3765, Expected=817.4908
# Month=58, Predicted=792.8221, Expected=827.2103
# Month=59, Predicted=812.6359, Expected=797.4188
# Month=60, Predicted=813.0114, Expected=843.9664
# Run 1 — RMSE: 38.389281, MSE: 1473.736917, NMSE: 0.0068372752
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=765.7730, Expected=804.1312
# Month=2, Predicted=756.0690, Expected=755.9621
# Month=3, Predicted=836.5909, Expected=859.0224
# Month=4, Predicted=872.6707, Expected=877.9865
# Month=5, Predicted=941.4700, Expected=942.0307
# Month=6, Predicted=921.2849, Expected=914.2550
# Month=7, Predicted=858.1106, Expected=868.9020
# Month=8, Predicted=826.8101, Expected=834.1536
# Month=9, Predicted=810.2223, Expected=789.9823
# Month=10, Predicted=782.7369, Expected=799.4046
# Month=11, Predicted=784.9721, Expected=763.5823
# Month=12, Predicted=795.2195, Expected=800.3831
# Month=13, Predicted=812.6377, Expected=826.4030
# Month=14, Predicted=816.2666, Expected=798.5367
# Month=15, Predicted=862.9102, Expected=890.7147
# Month=16, Predicted=900.8209, Expected=899.2858
# Month=17, Predicted=982.1389, Expected=961.2990
# Month=18, Predicted=954.2872, Expected=936.1160
# Month=19, Predicted=885.4035, Expected=893.4953
# Month=20, Predicted=841.0249, Expected=854.7115
# Month=21, Predicted=825.8660, Expected=809.0508
# Month=22, Predicted=800.5831, Expected=809.7435
# Month=23, Predicted=799.1600, Expected=765.2099
# Month=24, Predicted=806.9239, Expected=805.0349
# Month=25, Predicted=820.2268, Expected=820.4588
# Month=26, Predicted=810.7572, Expected=773.2413
# Month=27, Predicted=867.5389, Expected=882.5316
# Month=28, Predicted=887.8681, Expected=898.7897
# Month=29, Predicted=975.5826, Expected=956.6009
# Month=30, Predicted=961.5773, Expected=923.8359
# Month=31, Predicted=880.0905, Expected=881.4145
# Month=32, Predicted=823.4521, Expected=836.3729
# Month=33, Predicted=806.6833, Expected=784.1159
# Month=34, Predicted=773.5384, Expected=791.6660
# Month=35, Predicted=775.7154, Expected=759.1810
# Month=36, Predicted=793.5552, Expected=802.0941
# Month=37, Predicted=815.3590, Expected=828.1324
# Month=38, Predicted=787.4674, Expected=778.3983
# Month=39, Predicted=870.7899, Expected=888.3698
# Month=40, Predicted=896.2337, Expected=901.3272
# Month=41, Predicted=973.5350, Expected=969.2659
# Month=42, Predicted=952.8974, Expected=947.1513
# Month=43, Predicted=896.8897, Expected=908.1276
# Month=44, Predicted=858.6033, Expected=867.1765
# Month=45, Predicted=840.5569, Expected=814.6535
# Month=46, Predicted=808.6571, Expected=812.1183
# Month=47, Predicted=800.0411, Expected=773.1493
# Month=48, Predicted=805.3786, Expected=812.6360
# Month=49, Predicted=822.9198, Expected=834.9506
# Month=50, Predicted=830.8574, Expected=782.2414
# Month=51, Predicted=868.6652, Expected=891.3930
# Month=52, Predicted=893.6047, Expected=903.3345
# Month=53, Predicted=982.0580, Expected=965.5034
# Month=54, Predicted=982.1074, Expected=937.4010
# Month=55, Predicted=902.1811, Expected=896.5903
# Month=56, Predicted=834.2327, Expected=857.5819
# Month=57, Predicted=827.0429, Expected=817.4908
# Month=58, Predicted=801.3217, Expected=827.2103
# Month=59, Predicted=809.8576, Expected=797.4188
# Month=60, Predicted=825.0917, Expected=843.9664
# Run 2 — RMSE: 18.988793, MSE: 360.574256, NMSE: 0.0016011638
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=764.4259, Expected=804.1312
# Month=2, Predicted=797.9987, Expected=755.9621
# Month=3, Predicted=839.8604, Expected=859.0224
# Month=4, Predicted=852.3146, Expected=877.9865
# Month=5, Predicted=940.3691, Expected=942.0307
# Month=6, Predicted=967.2628, Expected=914.2550
# Month=7, Predicted=887.6692, Expected=868.9020
# Month=8, Predicted=816.4676, Expected=834.1536
# Month=9, Predicted=797.8115, Expected=789.9823
# Month=10, Predicted=765.5744, Expected=799.4046
# Month=11, Predicted=788.7239, Expected=763.5823
# Month=12, Predicted=776.1151, Expected=800.3831
# Month=13, Predicted=814.3117, Expected=826.4030
# Month=14, Predicted=825.5665, Expected=798.5367
# Month=15, Predicted=861.7679, Expected=890.7147
# Month=16, Predicted=883.4735, Expected=899.2858
# Month=17, Predicted=970.9014, Expected=961.2990
# Month=18, Predicted=986.8084, Expected=936.1160
# Month=19, Predicted=907.2104, Expected=893.4953
# Month=20, Predicted=841.0236, Expected=854.7115
# Month=21, Predicted=817.4274, Expected=809.0508
# Month=22, Predicted=784.2611, Expected=809.7435
# Month=23, Predicted=798.4471, Expected=765.2099
# Month=24, Predicted=777.4087, Expected=805.0349
# Month=25, Predicted=818.3248, Expected=820.4588
# Month=26, Predicted=825.5114, Expected=773.2413
# Month=27, Predicted=852.9549, Expected=882.5316
# Month=28, Predicted=872.9508, Expected=898.7897
# Month=29, Predicted=963.5030, Expected=956.6009
# Month=30, Predicted=990.1249, Expected=923.8359
# Month=31, Predicted=902.0159, Expected=881.4145
# Month=32, Predicted=828.1648, Expected=836.3729
# Month=33, Predicted=796.4939, Expected=784.1159
# Month=34, Predicted=757.3281, Expected=791.6660
# Month=35, Predicted=778.2224, Expected=759.1810
# Month=36, Predicted=766.8252, Expected=802.0941
# Month=37, Predicted=814.6225, Expected=828.1324
# Month=38, Predicted=829.8751, Expected=778.3983
# Month=39, Predicted=858.5518, Expected=888.3698
# Month=40, Predicted=879.0501, Expected=901.3272
# Month=41, Predicted=968.3787, Expected=969.2659
# Month=42, Predicted=997.5556, Expected=947.1513
# Month=43, Predicted=932.2708, Expected=908.1276
# Month=44, Predicted=855.7397, Expected=867.1765
# Month=45, Predicted=826.6497, Expected=814.6535
# Month=46, Predicted=786.9623, Expected=812.1183
# Month=47, Predicted=797.6083, Expected=773.1493
# Month=48, Predicted=779.0268, Expected=812.6360
# Month=49, Predicted=825.7233, Expected=834.9506
# Month=50, Predicted=840.6420, Expected=782.2414
# Month=51, Predicted=860.8988, Expected=891.3930
# Month=52, Predicted=881.0751, Expected=903.3345
# Month=53, Predicted=969.0310, Expected=965.5034
# Month=54, Predicted=998.1006, Expected=937.4010
# Month=55, Predicted=924.8643, Expected=896.5903
# Month=56, Predicted=843.6812, Expected=857.5819
# Month=57, Predicted=817.0842, Expected=817.4908
# Month=58, Predicted=790.7469, Expected=827.2103
# Month=59, Predicted=813.8014, Expected=797.4188
# Month=60, Predicted=804.4699, Expected=843.9664
# Run 3 — RMSE: 29.653994, MSE: 879.359363, NMSE: 0.0031744479
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=761.8290, Expected=804.1312
# Month=2, Predicted=799.9132, Expected=755.9621
# Month=3, Predicted=856.8614, Expected=859.0224
# Month=4, Predicted=870.4173, Expected=877.9865
# Month=5, Predicted=918.7528, Expected=942.0307
# Month=6, Predicted=920.0336, Expected=914.2550
# Month=7, Predicted=853.9876, Expected=868.9020
# Month=8, Predicted=812.7555, Expected=834.1536
# Month=9, Predicted=793.2243, Expected=789.9823
# Month=10, Predicted=791.2251, Expected=799.4046
# Month=11, Predicted=776.9231, Expected=763.5823
# Month=12, Predicted=821.1033, Expected=800.3831
# Month=13, Predicted=803.2426, Expected=826.4030
# Month=14, Predicted=817.4549, Expected=798.5367
# Month=15, Predicted=881.1717, Expected=890.7147
# Month=16, Predicted=900.3745, Expected=899.2858
# Month=17, Predicted=964.9548, Expected=961.2990
# Month=18, Predicted=950.6789, Expected=936.1160
# Month=19, Predicted=895.5472, Expected=893.4953
# Month=20, Predicted=849.3375, Expected=854.7115
# Month=21, Predicted=817.7777, Expected=809.0508
# Month=22, Predicted=807.3422, Expected=809.7435
# Month=23, Predicted=794.1980, Expected=765.2099
# Month=24, Predicted=833.1553, Expected=805.0349
# Month=25, Predicted=814.6612, Expected=820.4588
# Month=26, Predicted=814.0949, Expected=773.2413
# Month=27, Predicted=880.3185, Expected=882.5316
# Month=28, Predicted=893.4391, Expected=898.7897
# Month=29, Predicted=956.4292, Expected=956.6009
# Month=30, Predicted=954.3725, Expected=923.8359
# Month=31, Predicted=902.4638, Expected=881.4145
# Month=32, Predicted=843.8640, Expected=836.3729
# Month=33, Predicted=803.3814, Expected=784.1159
# Month=34, Predicted=790.6265, Expected=791.6660
# Month=35, Predicted=774.3408, Expected=759.1810
# Month=36, Predicted=809.8570, Expected=802.0941
# Month=37, Predicted=811.7724, Expected=828.1324
# Month=38, Predicted=820.9294, Expected=778.3983
# Month=39, Predicted=886.7110, Expected=888.3698
# Month=40, Predicted=900.2879, Expected=901.3272
# Month=41, Predicted=949.3064, Expected=969.2659
# Month=42, Predicted=943.7541, Expected=947.1513
# Month=43, Predicted=886.2442, Expected=908.1276
# Month=44, Predicted=853.1684, Expected=867.1765
# Month=45, Predicted=824.6993, Expected=814.6535
# Month=46, Predicted=826.9803, Expected=812.1183
# Month=47, Predicted=804.9985, Expected=773.1493
# Month=48, Predicted=840.5450, Expected=812.6360
# Month=49, Predicted=815.1267, Expected=834.9506
# Month=50, Predicted=828.8138, Expected=782.2414
# Month=51, Predicted=904.1028, Expected=891.3930
# Month=52, Predicted=901.9714, Expected=903.3345
# Month=53, Predicted=972.5206, Expected=965.5034
# Month=54, Predicted=963.2947, Expected=937.4010
# Month=55, Predicted=918.6905, Expected=896.5903
# Month=56, Predicted=860.3853, Expected=857.5819
# Month=57, Predicted=822.5208, Expected=817.4908
# Month=58, Predicted=804.8080, Expected=827.2103
# Month=59, Predicted=801.0135, Expected=797.4188
# Month=60, Predicted=821.7971, Expected=843.9664
# Run 4 — RMSE: 19.478668, MSE: 379.418511, NMSE: 0.0019800132
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=752.0426, Expected=804.1312
# Month=2, Predicted=785.8963, Expected=755.9621
# Month=3, Predicted=824.2601, Expected=859.0224
# Month=4, Predicted=863.5116, Expected=877.9865
# Month=5, Predicted=916.8021, Expected=942.0307
# Month=6, Predicted=912.2455, Expected=914.2550
# Month=7, Predicted=832.2051, Expected=868.9020
# Month=8, Predicted=833.1299, Expected=834.1536
# Month=9, Predicted=797.7196, Expected=789.9823
# Month=10, Predicted=785.1145, Expected=799.4046
# Month=11, Predicted=791.0599, Expected=763.5823
# Month=12, Predicted=819.2189, Expected=800.3831
# Month=13, Predicted=800.5630, Expected=826.4030
# Month=14, Predicted=814.8509, Expected=798.5367
# Month=15, Predicted=892.8833, Expected=890.7147
# Month=16, Predicted=906.9695, Expected=899.2858
# Month=17, Predicted=976.6227, Expected=961.2990
# Month=18, Predicted=946.9284, Expected=936.1160
# Month=19, Predicted=917.0003, Expected=893.4953
# Month=20, Predicted=872.7547, Expected=854.7115
# Month=21, Predicted=833.3822, Expected=809.0508
# Month=22, Predicted=809.3520, Expected=809.7435
# Month=23, Predicted=802.3398, Expected=765.2099
# Month=24, Predicted=821.6531, Expected=805.0349
# Month=25, Predicted=809.6878, Expected=820.4588
# Month=26, Predicted=813.3290, Expected=773.2413
# Month=27, Predicted=880.3464, Expected=882.5316
# Month=28, Predicted=920.8107, Expected=898.7897
# Month=29, Predicted=950.6203, Expected=956.6009
# Month=30, Predicted=944.6691, Expected=923.8359
# Month=31, Predicted=894.2242, Expected=881.4145
# Month=32, Predicted=850.2621, Expected=836.3729
# Month=33, Predicted=811.7622, Expected=784.1159
# Month=34, Predicted=782.8674, Expected=791.6660
# Month=35, Predicted=786.1602, Expected=759.1810
# Month=36, Predicted=798.4124, Expected=802.0941
# Month=37, Predicted=802.7762, Expected=828.1324
# Month=38, Predicted=816.5734, Expected=778.3983
# Month=39, Predicted=864.6359, Expected=888.3698
# Month=40, Predicted=915.0610, Expected=901.3272
# Month=41, Predicted=978.5496, Expected=969.2659
# Month=42, Predicted=955.9933, Expected=947.1513
# Month=43, Predicted=918.9925, Expected=908.1276
# Month=44, Predicted=880.2201, Expected=867.1765
# Month=45, Predicted=843.4521, Expected=814.6535
# Month=46, Predicted=814.7983, Expected=812.1183
# Month=47, Predicted=804.6101, Expected=773.1493
# Month=48, Predicted=812.3981, Expected=812.6360
# Month=49, Predicted=814.5063, Expected=834.9506
# Month=50, Predicted=823.8277, Expected=782.2414
# Month=51, Predicted=883.1969, Expected=891.3930
# Month=52, Predicted=925.0464, Expected=903.3345
# Month=53, Predicted=978.0454, Expected=965.5034
# Month=54, Predicted=955.1783, Expected=937.4010
# Month=55, Predicted=924.2688, Expected=896.5903
# Month=56, Predicted=873.9416, Expected=857.5819
# Month=57, Predicted=836.8960, Expected=817.4908
# Month=58, Predicted=815.6981, Expected=827.2103
# Month=59, Predicted=820.6008, Expected=797.4188
# Month=60, Predicted=837.2520, Expected=843.9664
# Run 5 — RMSE: 21.564664, MSE: 465.034744, NMSE: 0.0021943209
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=763.7637, Expected=804.1312
# Month=2, Predicted=816.6167, Expected=755.9621
# Month=3, Predicted=766.9982, Expected=859.0224
# Month=4, Predicted=863.5678, Expected=877.9865
# Month=5, Predicted=881.4843, Expected=942.0307
# Month=6, Predicted=936.7132, Expected=914.2550
# Month=7, Predicted=900.4889, Expected=868.9020
# Month=8, Predicted=851.3797, Expected=834.1536
# Month=9, Predicted=820.5188, Expected=789.9823
# Month=10, Predicted=783.5095, Expected=799.4046
# Month=11, Predicted=802.8995, Expected=763.5823
# Month=12, Predicted=773.1035, Expected=800.3831
# Month=13, Predicted=814.0493, Expected=826.4030
# Month=14, Predicted=841.2167, Expected=798.5367
# Month=15, Predicted=811.1717, Expected=890.7147
# Month=16, Predicted=897.2045, Expected=899.2858
# Month=17, Predicted=904.3975, Expected=961.2990
# Month=18, Predicted=958.0188, Expected=936.1160
# Month=19, Predicted=925.2419, Expected=893.4953
# Month=20, Predicted=878.6461, Expected=854.7115
# Month=21, Predicted=842.8599, Expected=809.0508
# Month=22, Predicted=804.2505, Expected=809.7435
# Month=23, Predicted=814.2737, Expected=765.2099
# Month=24, Predicted=776.0668, Expected=805.0349
# Month=25, Predicted=819.9599, Expected=820.4588
# Month=26, Predicted=836.9809, Expected=773.2413
# Month=27, Predicted=787.7521, Expected=882.5316
# Month=28, Predicted=890.4612, Expected=898.7897
# Month=29, Predicted=908.1865, Expected=956.6009
# Month=30, Predicted=956.2316, Expected=923.8359
# Month=31, Predicted=915.1057, Expected=881.4145
# Month=32, Predicted=867.8885, Expected=836.3729
# Month=33, Predicted=825.1706, Expected=784.1159
# Month=34, Predicted=780.1780, Expected=791.6660
# Month=35, Predicted=797.1779, Expected=759.1810
# Month=36, Predicted=770.5291, Expected=802.0941
# Month=37, Predicted=816.0319, Expected=828.1324
# Month=38, Predicted=842.7453, Expected=778.3983
# Month=39, Predicted=790.1292, Expected=888.3698
# Month=40, Predicted=893.7833, Expected=901.3272
# Month=41, Predicted=907.4036, Expected=969.2659
# Month=42, Predicted=966.0566, Expected=947.1513
# Month=43, Predicted=936.0238, Expected=908.1276
# Month=44, Predicted=891.9184, Expected=867.1765
# Month=45, Predicted=853.0279, Expected=814.6535
# Month=46, Predicted=807.5697, Expected=812.1183
# Month=47, Predicted=815.1971, Expected=773.1493
# Month=48, Predicted=783.2649, Expected=812.6360
# Month=49, Predicted=827.1902, Expected=834.9506
# Month=50, Predicted=851.0851, Expected=782.2414
# Month=51, Predicted=796.3840, Expected=891.3930
# Month=52, Predicted=899.0878, Expected=903.3345
# Month=53, Predicted=912.5031, Expected=965.5034
# Month=54, Predicted=965.1014, Expected=937.4010
# Month=55, Predicted=929.0985, Expected=896.5903
# Month=56, Predicted=883.1121, Expected=857.5819
# Month=57, Predicted=845.9681, Expected=817.4908
# Month=58, Predicted=812.3750, Expected=827.2103
# Month=59, Predicted=830.4944, Expected=797.4188
# Month=60, Predicted=805.9531, Expected=843.9664
# Run 6 — RMSE: 42.863387, MSE: 1837.269919, NMSE: 0.0096819785
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=760.4328, Expected=804.1312
# Month=2, Predicted=812.3234, Expected=755.9621
# Month=3, Predicted=758.4364, Expected=859.0224
# Month=4, Predicted=867.7815, Expected=877.9865
# Month=5, Predicted=887.3825, Expected=942.0307
# Month=6, Predicted=950.5759, Expected=914.2550
# Month=7, Predicted=920.2871, Expected=868.9020
# Month=8, Predicted=851.1246, Expected=834.1536
# Month=9, Predicted=819.9212, Expected=789.9823
# Month=10, Predicted=780.8898, Expected=799.4046
# Month=11, Predicted=806.7722, Expected=763.5823
# Month=12, Predicted=768.3699, Expected=800.3831
# Month=13, Predicted=809.6950, Expected=826.4030
# Month=14, Predicted=835.7305, Expected=798.5367
# Month=15, Predicted=804.3843, Expected=890.7147
# Month=16, Predicted=899.1439, Expected=899.2858
# Month=17, Predicted=908.8372, Expected=961.2990
# Month=18, Predicted=970.1113, Expected=936.1160
# Month=19, Predicted=942.6915, Expected=893.4953
# Month=20, Predicted=879.5342, Expected=854.7115
# Month=21, Predicted=839.8236, Expected=809.0508
# Month=22, Predicted=798.3978, Expected=809.7435
# Month=23, Predicted=815.8041, Expected=765.2099
# Month=24, Predicted=766.9065, Expected=805.0349
# Month=25, Predicted=814.2742, Expected=820.4588
# Month=26, Predicted=829.9197, Expected=773.2413
# Month=27, Predicted=772.6104, Expected=882.5316
# Month=28, Predicted=890.7312, Expected=898.7897
# Month=29, Predicted=908.0701, Expected=956.6009
# Month=30, Predicted=965.4355, Expected=923.8359
# Month=31, Predicted=927.9593, Expected=881.4145
# Month=32, Predicted=863.6545, Expected=836.3729
# Month=33, Predicted=817.8717, Expected=784.1159
# Month=34, Predicted=769.1992, Expected=791.6660
# Month=35, Predicted=798.2864, Expected=759.1810
# Month=36, Predicted=764.8196, Expected=802.0941
# Month=37, Predicted=811.4538, Expected=828.1324
# Month=38, Predicted=837.4014, Expected=778.3983
# Month=39, Predicted=777.3338, Expected=888.3698
# Month=40, Predicted=896.7609, Expected=901.3272
# Month=41, Predicted=910.7465, Expected=969.2659
# Month=42, Predicted=977.7282, Expected=947.1513
# Month=43, Predicted=954.2560, Expected=908.1276
# Month=44, Predicted=895.6179, Expected=867.1765
# Month=45, Predicted=850.7727, Expected=814.6535
# Month=46, Predicted=799.1651, Expected=812.1183
# Month=47, Predicted=816.7967, Expected=773.1493
# Month=48, Predicted=776.1672, Expected=812.6360
# Month=49, Predicted=821.9399, Expected=834.9506
# Month=50, Predicted=844.2838, Expected=782.2414
# Month=51, Predicted=780.0929, Expected=891.3930
# Month=52, Predicted=899.8430, Expected=903.3345
# Month=53, Predicted=912.7619, Expected=965.5034
# Month=54, Predicted=974.2379, Expected=937.4010
# Month=55, Predicted=943.0875, Expected=896.5903
# Month=56, Predicted=881.6282, Expected=857.5819
# Month=57, Predicted=842.6531, Expected=817.4908
# Month=58, Predicted=809.5859, Expected=827.2103
# Month=59, Predicted=834.8523, Expected=797.4188
# Month=60, Predicted=803.4492, Expected=843.9664
# Run 7 — RMSE: 46.578772, MSE: 2169.581961, NMSE: 0.0092083193
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=749.8988, Expected=804.1312
# Month=2, Predicted=783.0140, Expected=755.9621
# Month=3, Predicted=879.5999, Expected=859.0224
# Month=4, Predicted=873.8284, Expected=877.9865
# Month=5, Predicted=928.3781, Expected=942.0307
# Month=6, Predicted=911.9977, Expected=914.2550
# Month=7, Predicted=857.4964, Expected=868.9020
# Month=8, Predicted=820.6519, Expected=834.1536
# Month=9, Predicted=805.3373, Expected=789.9823
# Month=10, Predicted=786.9055, Expected=799.4046
# Month=11, Predicted=781.8999, Expected=763.5823
# Month=12, Predicted=818.9257, Expected=800.3831
# Month=13, Predicted=797.4615, Expected=826.4030
# Month=14, Predicted=804.4685, Expected=798.5367
# Month=15, Predicted=876.4135, Expected=890.7147
# Month=16, Predicted=907.2691, Expected=899.2858
# Month=17, Predicted=962.5116, Expected=961.2990
# Month=18, Predicted=939.6188, Expected=936.1160
# Month=19, Predicted=886.7526, Expected=893.4953
# Month=20, Predicted=846.2085, Expected=854.7115
# Month=21, Predicted=827.0196, Expected=809.0508
# Month=22, Predicted=807.3928, Expected=809.7435
# Month=23, Predicted=795.8914, Expected=765.2099
# Month=24, Predicted=823.6715, Expected=805.0349
# Month=25, Predicted=803.9814, Expected=820.4588
# Month=26, Predicted=801.3273, Expected=773.2413
# Month=27, Predicted=881.1887, Expected=882.5316
# Month=28, Predicted=898.1826, Expected=898.7897
# Month=29, Predicted=956.2588, Expected=956.6009
# Month=30, Predicted=933.4067, Expected=923.8359
# Month=31, Predicted=873.5075, Expected=881.4145
# Month=32, Predicted=835.0357, Expected=836.3729
# Month=33, Predicted=811.7527, Expected=784.1159
# Month=34, Predicted=786.6223, Expected=791.6660
# Month=35, Predicted=775.5270, Expected=759.1810
# Month=36, Predicted=813.6830, Expected=802.0941
# Month=37, Predicted=797.4285, Expected=828.1324
# Month=38, Predicted=808.4615, Expected=778.3983
# Month=39, Predicted=897.3399, Expected=888.3698
# Month=40, Predicted=902.6650, Expected=901.3272
# Month=41, Predicted=956.4543, Expected=969.2659
# Month=42, Predicted=939.9301, Expected=947.1513
# Month=43, Predicted=891.5056, Expected=908.1276
# Month=44, Predicted=860.8478, Expected=867.1765
# Month=45, Predicted=841.1257, Expected=814.6535
# Month=46, Predicted=815.9940, Expected=812.1183
# Month=47, Predicted=798.6069, Expected=773.1493
# Month=48, Predicted=827.2133, Expected=812.6360
# Month=49, Predicted=808.8425, Expected=834.9506
# Month=50, Predicted=814.8093, Expected=782.2414
# Month=51, Predicted=902.5050, Expected=891.3930
# Month=52, Predicted=906.3096, Expected=903.3345
# Month=53, Predicted=963.2509, Expected=965.5034
# Month=54, Predicted=941.6625, Expected=937.4010
# Month=55, Predicted=886.5355, Expected=896.5903
# Month=56, Predicted=850.2549, Expected=857.5819
# Month=57, Predicted=831.8516, Expected=817.4908
# Month=58, Predicted=815.2214, Expected=827.2103
# Month=59, Predicted=811.6477, Expected=797.4188
# Month=60, Predicted=847.6403, Expected=843.9664
# Run 8 — RMSE: 17.148453, MSE: 294.069440, NMSE: 0.0015991784
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=746.9587, Expected=804.1312
# Month=2, Predicted=805.8310, Expected=755.9621
# Month=3, Predicted=836.5462, Expected=859.0224
# Month=4, Predicted=877.3980, Expected=877.9865
# Month=5, Predicted=891.5743, Expected=942.0307
# Month=6, Predicted=910.2227, Expected=914.2550
# Month=7, Predicted=875.2144, Expected=868.9020
# Month=8, Predicted=816.5055, Expected=834.1536
# Month=9, Predicted=800.4495, Expected=789.9823
# Month=10, Predicted=781.1362, Expected=799.4046
# Month=11, Predicted=783.7606, Expected=763.5823
# Month=12, Predicted=803.7111, Expected=800.3831
# Month=13, Predicted=792.9651, Expected=826.4030
# Month=14, Predicted=834.4210, Expected=798.5367
# Month=15, Predicted=843.5114, Expected=890.7147
# Month=16, Predicted=899.7187, Expected=899.2858
# Month=17, Predicted=933.5782, Expected=961.2990
# Month=18, Predicted=935.8449, Expected=936.1160
# Month=19, Predicted=908.9416, Expected=893.4953
# Month=20, Predicted=844.5085, Expected=854.7115
# Month=21, Predicted=825.3161, Expected=809.0508
# Month=22, Predicted=808.8691, Expected=809.7435
# Month=23, Predicted=801.4255, Expected=765.2099
# Month=24, Predicted=831.6172, Expected=805.0349
# Month=25, Predicted=808.8912, Expected=820.4588
# Month=26, Predicted=859.1205, Expected=773.2413
# Month=27, Predicted=868.2662, Expected=882.5316
# Month=28, Predicted=904.2614, Expected=898.7897
# Month=29, Predicted=965.5481, Expected=956.6009
# Month=30, Predicted=945.5622, Expected=923.8359
# Month=31, Predicted=926.3127, Expected=881.4145
# Month=32, Predicted=834.8595, Expected=836.3729
# Month=33, Predicted=820.7470, Expected=784.1159
# Month=34, Predicted=812.5700, Expected=791.6660
# Month=35, Predicted=792.9217, Expected=759.1810
# Month=36, Predicted=836.1291, Expected=802.0941
# Month=37, Predicted=814.7374, Expected=828.1324
# Month=38, Predicted=859.5450, Expected=778.3983
# Month=39, Predicted=869.4646, Expected=888.3698
# Month=40, Predicted=911.3468, Expected=901.3272
# Month=41, Predicted=956.5651, Expected=969.2659
# Month=42, Predicted=940.8352, Expected=947.1513
# Month=43, Predicted=905.8999, Expected=908.1276
# Month=44, Predicted=851.6004, Expected=867.1765
# Month=45, Predicted=829.7071, Expected=814.6535
# Month=46, Predicted=800.8310, Expected=812.1183
# Month=47, Predicted=794.6054, Expected=773.1493
# Month=48, Predicted=808.3335, Expected=812.6360
# Month=49, Predicted=803.9288, Expected=834.9506
# Month=50, Predicted=845.0705, Expected=782.2414
# Month=51, Predicted=845.5261, Expected=891.3930
# Month=52, Predicted=908.6839, Expected=903.3345
# Month=53, Predicted=940.0277, Expected=965.5034
# Month=54, Predicted=936.7278, Expected=937.4010
# Month=55, Predicted=901.3939, Expected=896.5903
# Month=56, Predicted=846.1641, Expected=857.5819
# Month=57, Predicted=827.5654, Expected=817.4908
# Month=58, Predicted=809.3741, Expected=827.2103
# Month=59, Predicted=815.2487, Expected=797.4188
# Month=60, Predicted=840.2633, Expected=843.9664
# Run 9 — RMSE: 28.738277, MSE: 825.888567, NMSE: 0.0049898007
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=760.2215, Expected=804.1312
# Month=2, Predicted=827.2550, Expected=755.9621
# Month=3, Predicted=782.0968, Expected=859.0224
# Month=4, Predicted=863.1989, Expected=877.9865
# Month=5, Predicted=892.9331, Expected=942.0307
# Month=6, Predicted=933.3291, Expected=914.2550
# Month=7, Predicted=912.1369, Expected=868.9020
# Month=8, Predicted=833.7306, Expected=834.1536
# Month=9, Predicted=802.3083, Expected=789.9823
# Month=10, Predicted=781.4282, Expected=799.4046
# Month=11, Predicted=790.7667, Expected=763.5823
# Month=12, Predicted=783.6093, Expected=800.3831
# Month=13, Predicted=799.4591, Expected=826.4030
# Month=14, Predicted=845.3390, Expected=798.5367
# Month=15, Predicted=814.6596, Expected=890.7147
# Month=16, Predicted=894.0597, Expected=899.2858
# Month=17, Predicted=914.9095, Expected=961.2990
# Month=18, Predicted=950.5438, Expected=936.1160
# Month=19, Predicted=936.6890, Expected=893.4953
# Month=20, Predicted=862.9626, Expected=854.7115
# Month=21, Predicted=827.0021, Expected=809.0508
# Month=22, Predicted=800.4217, Expected=809.7435
# Month=23, Predicted=803.8698, Expected=765.2099
# Month=24, Predicted=787.2497, Expected=805.0349
# Month=25, Predicted=807.7543, Expected=820.4588
# Month=26, Predicted=845.1614, Expected=773.2413
# Month=27, Predicted=794.4045, Expected=882.5316
# Month=28, Predicted=892.9739, Expected=898.7897
# Month=29, Predicted=918.7027, Expected=956.6009
# Month=30, Predicted=949.6048, Expected=923.8359
# Month=31, Predicted=925.4759, Expected=881.4145
# Month=32, Predicted=850.3623, Expected=836.3729
# Month=33, Predicted=814.5941, Expected=784.1159
# Month=34, Predicted=778.8637, Expected=791.6660
# Month=35, Predicted=790.5933, Expected=759.1810
# Month=36, Predicted=786.1738, Expected=802.0941
# Month=37, Predicted=812.0284, Expected=828.1324
# Month=38, Predicted=852.8126, Expected=778.3983
# Month=39, Predicted=802.3210, Expected=888.3698
# Month=40, Predicted=899.1279, Expected=901.3272
# Month=41, Predicted=921.1588, Expected=969.2659
# Month=42, Predicted=963.0467, Expected=947.1513
# Month=43, Predicted=948.4744, Expected=908.1276
# Month=44, Predicted=877.6550, Expected=867.1765
# Month=45, Predicted=840.6509, Expected=814.6535
# Month=46, Predicted=805.0507, Expected=812.1183
# Month=47, Predicted=804.6426, Expected=773.1493
# Month=48, Predicted=795.6657, Expected=812.6360
# Month=49, Predicted=819.3345, Expected=834.9506
# Month=50, Predicted=859.4958, Expected=782.2414
# Month=51, Predicted=805.6567, Expected=891.3930
# Month=52, Predicted=901.2094, Expected=903.3345
# Month=53, Predicted=923.6824, Expected=965.5034
# Month=54, Predicted=958.7098, Expected=937.4010
# Month=55, Predicted=939.7204, Expected=896.5903
# Month=56, Predicted=866.5971, Expected=857.5819
# Month=57, Predicted=834.0119, Expected=817.4908
# Month=58, Predicted=811.1888, Expected=827.2103
# Month=59, Predicted=826.5967, Expected=797.4188
# Month=60, Predicted=819.9975, Expected=843.9664
# Run 10 — RMSE: 39.458112, MSE: 1556.942634, NMSE: 0.0079873131
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=768.5990, Expected=804.1312
# Month=2, Predicted=791.3522, Expected=755.9621
# Month=3, Predicted=850.8835, Expected=859.0224
# Month=4, Predicted=879.8463, Expected=877.9865
# Month=5, Predicted=931.1659, Expected=942.0307
# Month=6, Predicted=910.0713, Expected=914.2550
# Month=7, Predicted=848.7008, Expected=868.9020
# Month=8, Predicted=826.3766, Expected=834.1536
# Month=9, Predicted=809.3234, Expected=789.9823
# Month=10, Predicted=782.7036, Expected=799.4046
# Month=11, Predicted=778.0257, Expected=763.5823
# Month=12, Predicted=784.4521, Expected=800.3831
# Month=13, Predicted=810.8094, Expected=826.4030
# Month=14, Predicted=823.5838, Expected=798.5367
# Month=15, Predicted=858.9693, Expected=890.7147
# Month=16, Predicted=898.9116, Expected=899.2858
# Month=17, Predicted=969.3833, Expected=961.2990
# Month=18, Predicted=940.4868, Expected=936.1160
# Month=19, Predicted=874.4566, Expected=893.4953
# Month=20, Predicted=852.2178, Expected=854.7115
# Month=21, Predicted=832.8148, Expected=809.0508
# Month=22, Predicted=805.7943, Expected=809.7435
# Month=23, Predicted=789.9027, Expected=765.2099
# Month=24, Predicted=802.7762, Expected=805.0349
# Month=25, Predicted=827.8295, Expected=820.4588
# Month=26, Predicted=812.8094, Expected=773.2413
# Month=27, Predicted=870.0969, Expected=882.5316
# Month=28, Predicted=904.1972, Expected=898.7897
# Month=29, Predicted=937.5795, Expected=956.6009
# Month=30, Predicted=944.6093, Expected=923.8359
# Month=31, Predicted=871.0547, Expected=881.4145
# Month=32, Predicted=838.4809, Expected=836.3729
# Month=33, Predicted=807.9301, Expected=784.1159
# Month=34, Predicted=778.9705, Expected=791.6660
# Month=35, Predicted=768.4854, Expected=759.1810
# Month=36, Predicted=787.2814, Expected=802.0941
# Month=37, Predicted=820.9210, Expected=828.1324
# Month=38, Predicted=816.0685, Expected=778.3983
# Month=39, Predicted=874.4309, Expected=888.3698
# Month=40, Predicted=912.9265, Expected=901.3272
# Month=41, Predicted=963.1363, Expected=969.2659
# Month=42, Predicted=938.4793, Expected=947.1513
# Month=43, Predicted=895.0831, Expected=908.1276
# Month=44, Predicted=865.6315, Expected=867.1765
# Month=45, Predicted=839.6924, Expected=814.6535
# Month=46, Predicted=807.3123, Expected=812.1183
# Month=47, Predicted=792.6641, Expected=773.1493
# Month=48, Predicted=790.5074, Expected=812.6360
# Month=49, Predicted=820.1521, Expected=834.9506
# Month=50, Predicted=834.3784, Expected=782.2414
# Month=51, Predicted=880.8238, Expected=891.3930
# Month=52, Predicted=922.1837, Expected=903.3345
# Month=53, Predicted=941.7071, Expected=965.5034
# Month=54, Predicted=947.5938, Expected=937.4010
# Month=55, Predicted=902.2200, Expected=896.5903
# Month=56, Predicted=852.2005, Expected=857.5819
# Month=57, Predicted=827.5680, Expected=817.4908
# Month=58, Predicted=809.9157, Expected=827.2103
# Month=59, Predicted=803.7393, Expected=797.4188
# Month=60, Predicted=825.1106, Expected=843.9664
# Run 11 — RMSE: 18.308081, MSE: 335.185817, NMSE: 0.0018213592
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=756.4094, Expected=804.1312
# Month=2, Predicted=796.4434, Expected=755.9621
# Month=3, Predicted=869.5090, Expected=859.0224
# Month=4, Predicted=866.5445, Expected=877.9865
# Month=5, Predicted=909.8853, Expected=942.0307
# Month=6, Predicted=910.8395, Expected=914.2550
# Month=7, Predicted=847.3556, Expected=868.9020
# Month=8, Predicted=816.4112, Expected=834.1536
# Month=9, Predicted=806.1875, Expected=789.9823
# Month=10, Predicted=781.2590, Expected=799.4046
# Month=11, Predicted=789.3992, Expected=763.5823
# Month=12, Predicted=789.1801, Expected=800.3831
# Month=13, Predicted=799.5648, Expected=826.4030
# Month=14, Predicted=813.1294, Expected=798.5367
# Month=15, Predicted=844.6962, Expected=890.7147
# Month=16, Predicted=889.8465, Expected=899.2858
# Month=17, Predicted=957.9007, Expected=961.2990
# Month=18, Predicted=957.9101, Expected=936.1160
# Month=19, Predicted=891.4238, Expected=893.4953
# Month=20, Predicted=838.7949, Expected=854.7115
# Month=21, Predicted=824.5915, Expected=809.0508
# Month=22, Predicted=807.2942, Expected=809.7435
# Month=23, Predicted=803.8531, Expected=765.2099
# Month=24, Predicted=812.4887, Expected=805.0349
# Month=25, Predicted=810.1588, Expected=820.4588
# Month=26, Predicted=819.4077, Expected=773.2413
# Month=27, Predicted=867.4924, Expected=882.5316
# Month=28, Predicted=884.3439, Expected=898.7897
# Month=29, Predicted=955.5776, Expected=956.6009
# Month=30, Predicted=962.0475, Expected=923.8359
# Month=31, Predicted=899.9861, Expected=881.4145
# Month=32, Predicted=839.2791, Expected=836.3729
# Month=33, Predicted=820.0978, Expected=784.1159
# Month=34, Predicted=808.6717, Expected=791.6660
# Month=35, Predicted=793.0988, Expected=759.1810
# Month=36, Predicted=815.3023, Expected=802.0941
# Month=37, Predicted=809.8337, Expected=828.1324
# Month=38, Predicted=841.9491, Expected=778.3983
# Month=39, Predicted=907.2717, Expected=888.3698
# Month=40, Predicted=898.9956, Expected=901.3272
# Month=41, Predicted=955.8964, Expected=969.2659
# Month=42, Predicted=948.8929, Expected=947.1513
# Month=43, Predicted=888.3946, Expected=908.1276
# Month=44, Predicted=854.9896, Expected=867.1765
# Month=45, Predicted=840.5993, Expected=814.6535
# Month=46, Predicted=816.8655, Expected=812.1183
# Month=47, Predicted=807.9382, Expected=773.1493
# Month=48, Predicted=816.2151, Expected=812.6360
# Month=49, Predicted=814.7906, Expected=834.9506
# Month=50, Predicted=829.4855, Expected=782.2414
# Month=51, Predicted=885.9345, Expected=891.3930
# Month=52, Predicted=893.6702, Expected=903.3345
# Month=53, Predicted=964.9535, Expected=965.5034
# Month=54, Predicted=972.0124, Expected=937.4010
# Month=55, Predicted=915.8263, Expected=896.5903
# Month=56, Predicted=854.1535, Expected=857.5819
# Month=57, Predicted=837.1099, Expected=817.4908
# Month=58, Predicted=829.2029, Expected=827.2103
# Month=59, Predicted=825.9511, Expected=797.4188
# Month=60, Predicted=849.6709, Expected=843.9664
# Run 12 — RMSE: 23.591297, MSE: 556.549273, NMSE: 0.0030761856
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=758.4900, Expected=804.1312
# Month=2, Predicted=814.5591, Expected=755.9621
# Month=3, Predicted=757.8248, Expected=859.0224
# Month=4, Predicted=866.2253, Expected=877.9865
# Month=5, Predicted=883.3097, Expected=942.0307
# Month=6, Predicted=943.1547, Expected=914.2550
# Month=7, Predicted=904.6675, Expected=868.9020
# Month=8, Predicted=854.5634, Expected=834.1536
# Month=9, Predicted=823.1755, Expected=789.9823
# Month=10, Predicted=782.9818, Expected=799.4046
# Month=11, Predicted=800.3204, Expected=763.5823
# Month=12, Predicted=766.2865, Expected=800.3831
# Month=13, Predicted=807.2400, Expected=826.4030
# Month=14, Predicted=835.3947, Expected=798.5367
# Month=15, Predicted=801.7988, Expected=890.7147
# Month=16, Predicted=898.3760, Expected=899.2858
# Month=17, Predicted=904.3817, Expected=961.2990
# Month=18, Predicted=963.4716, Expected=936.1160
# Month=19, Predicted=929.4592, Expected=893.4953
# Month=20, Predicted=881.9526, Expected=854.7115
# Month=21, Predicted=845.6308, Expected=809.0508
# Month=22, Predicted=803.7795, Expected=809.7435
# Month=23, Predicted=811.7815, Expected=765.2099
# Month=24, Predicted=768.9991, Expected=805.0349
# Month=25, Predicted=813.7319, Expected=820.4588
# Month=26, Predicted=831.3014, Expected=773.2413
# Month=27, Predicted=777.5916, Expected=882.5316
# Month=28, Predicted=892.9633, Expected=898.7897
# Month=29, Predicted=908.4603, Expected=956.6009
# Month=30, Predicted=960.7482, Expected=923.8359
# Month=31, Predicted=917.5357, Expected=881.4145
# Month=32, Predicted=871.0150, Expected=836.3729
# Month=33, Predicted=828.0762, Expected=784.1159
# Month=34, Predicted=779.4325, Expected=791.6660
# Month=35, Predicted=795.2438, Expected=759.1810
# Month=36, Predicted=765.1345, Expected=802.0941
# Month=37, Predicted=811.5221, Expected=828.1324
# Month=38, Predicted=838.5567, Expected=778.3983
# Month=39, Predicted=780.7668, Expected=888.3698
# Month=40, Predicted=897.4064, Expected=901.3272
# Month=41, Predicted=908.5815, Expected=969.2659
# Month=42, Predicted=972.1802, Expected=947.1513
# Month=43, Predicted=939.5572, Expected=908.1276
# Month=44, Predicted=895.0688, Expected=867.1765
# Month=45, Predicted=855.7472, Expected=814.6535
# Month=46, Predicted=806.4479, Expected=812.1183
# Month=47, Predicted=811.8701, Expected=773.1493
# Month=48, Predicted=775.6021, Expected=812.6360
# Month=49, Predicted=820.3570, Expected=834.9506
# Month=50, Predicted=844.7889, Expected=782.2414
# Month=51, Predicted=784.6876, Expected=891.3930
# Month=52, Predicted=900.6776, Expected=903.3345
# Month=53, Predicted=911.8326, Expected=965.5034
# Month=54, Predicted=969.2592, Expected=937.4010
# Month=55, Predicted=931.1495, Expected=896.5903
# Month=56, Predicted=885.6280, Expected=857.5819
# Month=57, Predicted=848.8127, Expected=817.4908
# Month=58, Predicted=812.6356, Expected=827.2103
# Month=59, Predicted=829.7789, Expected=797.4188
# Month=60, Predicted=801.5115, Expected=843.9664
# Run 13 — RMSE: 45.322016, MSE: 2054.085113, NMSE: 0.0095614968
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=760.5281, Expected=804.1312
# Month=2, Predicted=810.9601, Expected=755.9621
# Month=3, Predicted=859.8905, Expected=859.0224
# Month=4, Predicted=877.3772, Expected=877.9865
# Month=5, Predicted=889.4790, Expected=942.0307
# Month=6, Predicted=912.2845, Expected=914.2550
# Month=7, Predicted=880.6529, Expected=868.9020
# Month=8, Predicted=813.5019, Expected=834.1536
# Month=9, Predicted=788.3366, Expected=789.9823
# Month=10, Predicted=778.5196, Expected=799.4046
# Month=11, Predicted=786.3349, Expected=763.5823
# Month=12, Predicted=823.0430, Expected=800.3831
# Month=13, Predicted=806.7421, Expected=826.4030
# Month=14, Predicted=838.6543, Expected=798.5367
# Month=15, Predicted=849.7988, Expected=890.7147
# Month=16, Predicted=907.8598, Expected=899.2858
# Month=17, Predicted=927.2129, Expected=961.2990
# Month=18, Predicted=937.1670, Expected=936.1160
# Month=19, Predicted=911.6033, Expected=893.4953
# Month=20, Predicted=843.1271, Expected=854.7115
# Month=21, Predicted=815.6244, Expected=809.0508
# Month=22, Predicted=805.2810, Expected=809.7435
# Month=23, Predicted=800.3832, Expected=765.2099
# Month=24, Predicted=841.4942, Expected=805.0349
# Month=25, Predicted=819.1883, Expected=820.4588
# Month=26, Predicted=860.9247, Expected=773.2413
# Month=27, Predicted=863.2002, Expected=882.5316
# Month=28, Predicted=900.6087, Expected=898.7897
# Month=29, Predicted=952.0381, Expected=956.6009
# Month=30, Predicted=936.1254, Expected=923.8359
# Month=31, Predicted=927.3712, Expected=881.4145
# Month=32, Predicted=839.8457, Expected=836.3729
# Month=33, Predicted=814.0942, Expected=784.1159
# Month=34, Predicted=804.8295, Expected=791.6660
# Month=35, Predicted=793.1870, Expected=759.1810
# Month=36, Predicted=840.9681, Expected=802.0941
# Month=37, Predicted=817.8209, Expected=828.1324
# Month=38, Predicted=863.3491, Expected=778.3983
# Month=39, Predicted=880.1894, Expected=888.3698
# Month=40, Predicted=906.4545, Expected=901.3272
# Month=41, Predicted=955.7526, Expected=969.2659
# Month=42, Predicted=954.6731, Expected=947.1513
# Month=43, Predicted=940.2519, Expected=908.1276
# Month=44, Predicted=859.2039, Expected=867.1765
# Month=45, Predicted=830.8799, Expected=814.6535
# Month=46, Predicted=820.5367, Expected=812.1183
# Month=47, Predicted=804.4525, Expected=773.1493
# Month=48, Predicted=845.4594, Expected=812.6360
# Month=49, Predicted=826.9721, Expected=834.9506
# Month=50, Predicted=870.9731, Expected=782.2414
# Month=51, Predicted=886.0940, Expected=891.3930
# Month=52, Predicted=909.3288, Expected=903.3345
# Month=53, Predicted=962.0797, Expected=965.5034
# Month=54, Predicted=949.5565, Expected=937.4010
# Month=55, Predicted=942.6083, Expected=896.5903
# Month=56, Predicted=854.9218, Expected=857.5819
# Month=57, Predicted=828.6129, Expected=817.4908
# Month=58, Predicted=818.8056, Expected=827.2103
# Month=59, Predicted=821.3040, Expected=797.4188
# Month=60, Predicted=864.2299, Expected=843.9664
# Run 14 — RMSE: 30.119488, MSE: 907.183561, NMSE: 0.0052615612
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=754.3491, Expected=804.1312
# Month=2, Predicted=808.5623, Expected=755.9621
# Month=3, Predicted=744.7914, Expected=859.0224
# Month=4, Predicted=864.9914, Expected=877.9865
# Month=5, Predicted=877.5474, Expected=942.0307
# Month=6, Predicted=946.6566, Expected=914.2550
# Month=7, Predicted=907.7269, Expected=868.9020
# Month=8, Predicted=853.8589, Expected=834.1536
# Month=9, Predicted=818.3802, Expected=789.9823
# Month=10, Predicted=781.7431, Expected=799.4046
# Month=11, Predicted=802.2968, Expected=763.5823
# Month=12, Predicted=790.7860, Expected=800.3831
# Month=13, Predicted=830.0996, Expected=826.4030
# Month=14, Predicted=852.3215, Expected=798.5367
# Month=15, Predicted=827.3210, Expected=890.7147
# Month=16, Predicted=903.3462, Expected=899.2858
# Month=17, Predicted=902.9630, Expected=961.2990
# Month=18, Predicted=952.7791, Expected=936.1160
# Month=19, Predicted=932.9398, Expected=893.4953
# Month=20, Predicted=895.8078, Expected=854.7115
# Month=21, Predicted=856.4197, Expected=809.0508
# Month=22, Predicted=800.6382, Expected=809.7435
# Month=23, Predicted=797.9191, Expected=765.2099
# Month=24, Predicted=748.0671, Expected=805.0349
# Month=25, Predicted=796.2183, Expected=820.4588
# Month=26, Predicted=814.1399, Expected=773.2413
# Month=27, Predicted=775.1753, Expected=882.5316
# Month=28, Predicted=883.8228, Expected=898.7897
# Month=29, Predicted=903.3482, Expected=956.6009
# Month=30, Predicted=967.2979, Expected=923.8359
# Month=31, Predicted=928.4051, Expected=881.4145
# Month=32, Predicted=873.9437, Expected=836.3729
# Month=33, Predicted=815.4401, Expected=784.1159
# Month=34, Predicted=772.6755, Expected=791.6660
# Month=35, Predicted=796.8612, Expected=759.1810
# Month=36, Predicted=798.6614, Expected=802.0941
# Month=37, Predicted=845.8957, Expected=828.1324
# Month=38, Predicted=865.5990, Expected=778.3983
# Month=39, Predicted=817.7261, Expected=888.3698
# Month=40, Predicted=907.3335, Expected=901.3272
# Month=41, Predicted=914.5258, Expected=969.2659
# Month=42, Predicted=966.6880, Expected=947.1513
# Month=43, Predicted=937.3099, Expected=908.1276
# Month=44, Predicted=899.2678, Expected=867.1765
# Month=45, Predicted=861.4267, Expected=814.6535
# Month=46, Predicted=807.4323, Expected=812.1183
# Month=47, Predicted=808.9761, Expected=773.1493
# Month=48, Predicted=762.2105, Expected=812.6360
# Month=49, Predicted=811.4799, Expected=834.9506
# Month=50, Predicted=834.6123, Expected=782.2414
# Month=51, Predicted=771.5347, Expected=891.3930
# Month=52, Predicted=900.4354, Expected=903.3345
# Month=53, Predicted=907.5655, Expected=965.5034
# Month=54, Predicted=973.2836, Expected=937.4010
# Month=55, Predicted=933.1043, Expected=896.5903
# Month=56, Predicted=880.7330, Expected=857.5819
# Month=57, Predicted=839.4837, Expected=817.4908
# Month=58, Predicted=810.0941, Expected=827.2103
# Month=59, Predicted=834.2587, Expected=797.4188
# Month=60, Predicted=831.7634, Expected=843.9664
# Run 15 — RMSE: 45.573817, MSE: 2076.972771, NMSE: 0.0095116173
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=767.8285, Expected=804.1312
# Month=2, Predicted=777.3800, Expected=755.9621
# Month=3, Predicted=848.7460, Expected=859.0224
# Month=4, Predicted=867.8010, Expected=877.9865
# Month=5, Predicted=939.6597, Expected=942.0307
# Month=6, Predicted=927.0426, Expected=914.2550
# Month=7, Predicted=865.8990, Expected=868.9020
# Month=8, Predicted=831.4696, Expected=834.1536
# Month=9, Predicted=807.4713, Expected=789.9823
# Month=10, Predicted=771.8783, Expected=799.4046
# Month=11, Predicted=785.6575, Expected=763.5823
# Month=12, Predicted=809.7586, Expected=800.3831
# Month=13, Predicted=815.7468, Expected=826.4030
# Month=14, Predicted=809.3078, Expected=798.5367
# Month=15, Predicted=878.7929, Expected=890.7147
# Month=16, Predicted=902.2101, Expected=899.2858
# Month=17, Predicted=953.4020, Expected=961.2990
# Month=18, Predicted=938.5672, Expected=936.1160
# Month=19, Predicted=888.2159, Expected=893.4953
# Month=20, Predicted=858.5116, Expected=854.7115
# Month=21, Predicted=829.5918, Expected=809.0508
# Month=22, Predicted=792.1302, Expected=809.7435
# Month=23, Predicted=797.4136, Expected=765.2099
# Month=24, Predicted=812.4764, Expected=805.0349
# Month=25, Predicted=823.0079, Expected=820.4588
# Month=26, Predicted=813.1984, Expected=773.2413
# Month=27, Predicted=861.7374, Expected=882.5316
# Month=28, Predicted=887.4935, Expected=898.7897
# Month=29, Predicted=969.5758, Expected=956.6009
# Month=30, Predicted=961.2450, Expected=923.8359
# Month=31, Predicted=881.9346, Expected=881.4145
# Month=32, Predicted=843.5750, Expected=836.3729
# Month=33, Predicted=809.6445, Expected=784.1159
# Month=34, Predicted=763.6591, Expected=791.6660
# Month=35, Predicted=772.5175, Expected=759.1810
# Month=36, Predicted=794.2812, Expected=802.0941
# Month=37, Predicted=818.7572, Expected=828.1324
# Month=38, Predicted=810.3573, Expected=778.3983
# Month=39, Predicted=870.3236, Expected=888.3698
# Month=40, Predicted=893.6266, Expected=901.3272
# Month=41, Predicted=970.9124, Expected=969.2659
# Month=42, Predicted=963.6126, Expected=947.1513
# Month=43, Predicted=903.9479, Expected=908.1276
# Month=44, Predicted=870.5120, Expected=867.1765
# Month=45, Predicted=840.6986, Expected=814.6535
# Month=46, Predicted=795.5261, Expected=812.1183
# Month=47, Predicted=794.3139, Expected=773.1493
# Month=48, Predicted=805.0397, Expected=812.6360
# Month=49, Predicted=829.9476, Expected=834.9506
# Month=50, Predicted=826.8245, Expected=782.2414
# Month=51, Predicted=872.5804, Expected=891.3930
# Month=52, Predicted=893.0117, Expected=903.3345
# Month=53, Predicted=981.5296, Expected=965.5034
# Month=54, Predicted=979.0391, Expected=937.4010
# Month=55, Predicted=898.7672, Expected=896.5903
# Month=56, Predicted=856.6024, Expected=857.5819
# Month=57, Predicted=829.5756, Expected=817.4908
# ...
# Month=47, Predicted=798.6436, Expected=773.1493
# Month=48, Predicted=825.0911, Expected=812.6360
# Month=49, Predicted=812.0463, Expected=834.9506
# Month=50, Predicted=821.8681, Expected=782.2414
# Month=51, Predicted=890.7659, Expected=891.3930
# Month=52, Predicted=919.6827, Expected=903.3345
# Month=53, Predicted=953.4143, Expected=965.5034
# Month=54, Predicted=944.8201, Expected=937.4010
# Month=55, Predicted=916.8510, Expected=896.5903
# Month=56, Predicted=873.5669, Expected=857.5819
# Month=57, Predicted=836.7175, Expected=817.4908
# Month=58, Predicted=828.3474, Expected=827.2103
# Month=59, Predicted=814.5388, Expected=797.4188
# Month=60, Predicted=838.7771, Expected=843.9664
# Run 25 — RMSE: 20.745248, MSE: 430.365329, NMSE: 0.0022346181
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=748.5745, Expected=804.1312
# Month=2, Predicted=827.2807, Expected=755.9621
# Month=3, Predicted=762.5868, Expected=859.0224
# Month=4, Predicted=853.5837, Expected=877.9865
# Month=5, Predicted=890.8725, Expected=942.0307
# Month=6, Predicted=921.0093, Expected=914.2550
# Month=7, Predicted=878.3507, Expected=868.9020
# Month=8, Predicted=839.8532, Expected=834.1536
# Month=9, Predicted=818.1205, Expected=789.9823
# Month=10, Predicted=782.6247, Expected=799.4046
# Month=11, Predicted=790.3862, Expected=763.5823
# Month=12, Predicted=765.4820, Expected=800.3831
# Month=13, Predicted=792.7789, Expected=826.4030
# Month=14, Predicted=833.5559, Expected=798.5367
# Month=15, Predicted=789.5492, Expected=890.7147
# Month=16, Predicted=884.7233, Expected=899.2858
# Month=17, Predicted=899.7479, Expected=961.2990
# Month=18, Predicted=948.6762, Expected=936.1160
# Month=19, Predicted=919.4103, Expected=893.4953
# Month=20, Predicted=872.9545, Expected=854.7115
# Month=21, Predicted=847.8056, Expected=809.0508
# Month=22, Predicted=806.9002, Expected=809.7435
# Month=23, Predicted=805.6759, Expected=765.2099
# Month=24, Predicted=768.3631, Expected=805.0349
# Month=25, Predicted=800.8795, Expected=820.4588
# Month=26, Predicted=830.5276, Expected=773.2413
# Month=27, Predicted=779.0962, Expected=882.5316
# Month=28, Predicted=881.5713, Expected=898.7897
# Month=29, Predicted=929.3134, Expected=956.6009
# Month=30, Predicted=951.3056, Expected=923.8359
# Month=31, Predicted=947.1037, Expected=881.4145
# Month=32, Predicted=874.2421, Expected=836.3729
# Month=33, Predicted=851.0574, Expected=784.1159
# Month=34, Predicted=802.0055, Expected=791.6660
# Month=35, Predicted=797.4836, Expected=759.1810
# Month=36, Predicted=804.0027, Expected=802.0941
# Month=37, Predicted=803.4182, Expected=828.1324
# Month=38, Predicted=868.9003, Expected=778.3983
# Month=39, Predicted=810.2978, Expected=888.3698
# Month=40, Predicted=885.6137, Expected=901.3272
# Month=41, Predicted=941.3309, Expected=969.2659
# Month=42, Predicted=954.7462, Expected=947.1513
# Month=43, Predicted=926.6173, Expected=908.1276
# Month=44, Predicted=881.4184, Expected=867.1765
# Month=45, Predicted=855.5408, Expected=814.6535
# Month=46, Predicted=810.7592, Expected=812.1183
# Month=47, Predicted=805.8341, Expected=773.1493
# Month=48, Predicted=787.4607, Expected=812.6360
# Month=49, Predicted=807.1036, Expected=834.9506
# Month=50, Predicted=851.5103, Expected=782.2414
# Month=51, Predicted=776.1411, Expected=891.3930
# Month=52, Predicted=886.5108, Expected=903.3345
# Month=53, Predicted=914.3856, Expected=965.5034
# Month=54, Predicted=950.1239, Expected=937.4010
# Month=55, Predicted=913.2274, Expected=896.5903
# Month=56, Predicted=870.5720, Expected=857.5819
# Month=57, Predicted=847.8004, Expected=817.4908
# Month=58, Predicted=813.0363, Expected=827.2103
# Month=59, Predicted=822.4799, Expected=797.4188
# Month=60, Predicted=805.4108, Expected=843.9664
# Run 26 — RMSE: 44.641710, MSE: 1992.882241, NMSE: 0.0103922965
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=741.5294, Expected=804.1312
# Month=2, Predicted=792.6178, Expected=755.9621
# Month=3, Predicted=864.1646, Expected=859.0224
# Month=4, Predicted=879.3246, Expected=877.9865
# Month=5, Predicted=910.9440, Expected=942.0307
# Month=6, Predicted=891.5289, Expected=914.2550
# Month=7, Predicted=847.4089, Expected=868.9020
# Month=8, Predicted=813.0841, Expected=834.1536
# Month=9, Predicted=800.9776, Expected=789.9823
# Month=10, Predicted=775.1982, Expected=799.4046
# Month=11, Predicted=787.8919, Expected=763.5823
# Month=12, Predicted=821.7222, Expected=800.3831
# Month=13, Predicted=790.9177, Expected=826.4030
# Month=14, Predicted=815.6163, Expected=798.5367
# Month=15, Predicted=856.7159, Expected=890.7147
# Month=16, Predicted=902.5197, Expected=899.2858
# Month=17, Predicted=973.9309, Expected=961.2990
# Month=18, Predicted=944.1086, Expected=936.1160
# Month=19, Predicted=894.1173, Expected=893.4953
# Month=20, Predicted=848.7589, Expected=854.7115
# Month=21, Predicted=821.6115, Expected=809.0508
# Month=22, Predicted=803.1978, Expected=809.7435
# Month=23, Predicted=800.1133, Expected=765.2099
# Month=24, Predicted=831.7557, Expected=805.0349
# Month=25, Predicted=794.7922, Expected=820.4588
# Month=26, Predicted=811.4039, Expected=773.2413
# Month=27, Predicted=861.9797, Expected=882.5316
# Month=28, Predicted=900.8437, Expected=898.7897
# Month=29, Predicted=969.0664, Expected=956.6009
# Month=30, Predicted=940.0160, Expected=923.8359
# Month=31, Predicted=885.1994, Expected=881.4145
# Month=32, Predicted=839.5184, Expected=836.3729
# Month=33, Predicted=807.9700, Expected=784.1159
# Month=34, Predicted=787.4136, Expected=791.6660
# Month=35, Predicted=780.7493, Expected=759.1810
# Month=36, Predicted=805.1474, Expected=802.0941
# Month=37, Predicted=791.0797, Expected=828.1324
# Month=38, Predicted=818.4255, Expected=778.3983
# Month=39, Predicted=886.7991, Expected=888.3698
# Month=40, Predicted=911.4681, Expected=901.3272
# Month=41, Predicted=960.6894, Expected=969.2659
# Month=42, Predicted=932.4331, Expected=947.1513
# Month=43, Predicted=887.3351, Expected=908.1276
# Month=44, Predicted=853.3859, Expected=867.1765
# Month=45, Predicted=828.3871, Expected=814.6535
# Month=46, Predicted=799.4169, Expected=812.1183
# Month=47, Predicted=801.2213, Expected=773.1493
# Month=48, Predicted=828.5245, Expected=812.6360
# Month=49, Predicted=802.6921, Expected=834.9506
# Month=50, Predicted=823.9868, Expected=782.2414
# Month=51, Predicted=873.0915, Expected=891.3930
# Month=52, Predicted=907.8412, Expected=903.3345
# Month=53, Predicted=976.9959, Expected=965.5034
# Month=54, Predicted=951.5945, Expected=937.4010
# Month=55, Predicted=898.9296, Expected=896.5903
# Month=56, Predicted=852.6656, Expected=857.5819
# Month=57, Predicted=825.3401, Expected=817.4908
# Month=58, Predicted=811.4224, Expected=827.2103
# Month=59, Predicted=816.8522, Expected=797.4188
# Month=60, Predicted=847.9485, Expected=843.9664
# Run 27 — RMSE: 21.670474, MSE: 469.609437, NMSE: 0.0024315594
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=752.5644, Expected=804.1312
# Month=2, Predicted=812.5257, Expected=755.9621
# Month=3, Predicted=775.1143, Expected=859.0224
# Month=4, Predicted=848.7645, Expected=877.9865
# Month=5, Predicted=880.1832, Expected=942.0307
# Month=6, Predicted=922.2147, Expected=914.2550
# Month=7, Predicted=888.4768, Expected=868.9020
# Month=8, Predicted=822.9590, Expected=834.1536
# Month=9, Predicted=790.2128, Expected=789.9823
# Month=10, Predicted=763.0629, Expected=799.4046
# Month=11, Predicted=786.0984, Expected=763.5823
# Month=12, Predicted=775.5950, Expected=800.3831
# Month=13, Predicted=802.0636, Expected=826.4030
# Month=14, Predicted=838.7456, Expected=798.5367
# Month=15, Predicted=812.4495, Expected=890.7147
# Month=16, Predicted=882.7287, Expected=899.2858
# Month=17, Predicted=905.0668, Expected=961.2990
# Month=18, Predicted=944.1145, Expected=936.1160
# Month=19, Predicted=917.2219, Expected=893.4953
# Month=20, Predicted=854.9212, Expected=854.7115
# Month=21, Predicted=816.7522, Expected=809.0508
# Month=22, Predicted=785.5835, Expected=809.7435
# Month=23, Predicted=798.5740, Expected=765.2099
# Month=24, Predicted=778.9168, Expected=805.0349
# Month=25, Predicted=807.5003, Expected=820.4588
# Month=26, Predicted=838.0435, Expected=773.2413
# Month=27, Predicted=792.3385, Expected=882.5316
# Month=28, Predicted=876.5311, Expected=898.7897
# Month=29, Predicted=911.3985, Expected=956.6009
# Month=30, Predicted=943.7229, Expected=923.8359
# Month=31, Predicted=907.1854, Expected=881.4145
# Month=32, Predicted=843.7335, Expected=836.3729
# Month=33, Predicted=800.5325, Expected=784.1159
# Month=34, Predicted=762.3443, Expected=791.6660
# Month=35, Predicted=781.4753, Expected=759.1810
# Month=36, Predicted=775.4370, Expected=802.0941
# Month=37, Predicted=807.0536, Expected=828.1324
# Month=38, Predicted=843.9996, Expected=778.3983
# Month=39, Predicted=797.0302, Expected=888.3698
# Month=40, Predicted=880.8025, Expected=901.3272
# Month=41, Predicted=910.8201, Expected=969.2659
# Month=42, Predicted=953.3739, Expected=947.1513
# Month=43, Predicted=927.5397, Expected=908.1276
# Month=44, Predicted=866.5435, Expected=867.1765
# Month=45, Predicted=825.3864, Expected=814.6535
# Month=46, Predicted=786.5881, Expected=812.1183
# Month=47, Predicted=796.9305, Expected=773.1493
# Month=48, Predicted=784.2480, Expected=812.6360
# Month=49, Predicted=815.9853, Expected=834.9506
# Month=50, Predicted=851.7556, Expected=782.2414
# Month=51, Predicted=803.0897, Expected=891.3930
# Month=52, Predicted=885.0204, Expected=903.3345
# Month=53, Predicted=915.8279, Expected=965.5034
# Month=54, Predicted=951.8470, Expected=937.4010
# Month=55, Predicted=920.9210, Expected=896.5903
# Month=56, Predicted=858.6247, Expected=857.5819
# Month=57, Predicted=820.0973, Expected=817.4908
# Month=58, Predicted=793.1732, Expected=827.2103
# Month=59, Predicted=816.0235, Expected=797.4188
# Month=60, Predicted=809.3426, Expected=843.9664
# Run 28 — RMSE: 39.307872, MSE: 1545.108820, NMSE: 0.0080466757
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=757.4663, Expected=804.1312
# Month=2, Predicted=774.4665, Expected=755.9621
# Month=3, Predicted=819.0053, Expected=859.0224
# Month=4, Predicted=875.8319, Expected=877.9865
# Month=5, Predicted=918.3877, Expected=942.0307
# Month=6, Predicted=934.1673, Expected=914.2550
# Month=7, Predicted=859.9624, Expected=868.9020
# Month=8, Predicted=824.1613, Expected=834.1536
# Month=9, Predicted=816.0285, Expected=789.9823
# Month=10, Predicted=801.9892, Expected=799.4046
# Month=11, Predicted=799.8218, Expected=763.5823
# Month=12, Predicted=827.9995, Expected=800.3831
# Month=13, Predicted=806.0160, Expected=826.4030
# Month=14, Predicted=808.3262, Expected=798.5367
# Month=15, Predicted=871.0461, Expected=890.7147
# Month=16, Predicted=905.7736, Expected=899.2858
# Month=17, Predicted=955.8642, Expected=961.2990
# Month=18, Predicted=955.8033, Expected=936.1160
# Month=19, Predicted=899.3927, Expected=893.4953
# Month=20, Predicted=857.4327, Expected=854.7115
# Month=21, Predicted=839.7382, Expected=809.0508
# Month=22, Predicted=821.1468, Expected=809.7435
# Month=23, Predicted=804.1279, Expected=765.2099
# Month=24, Predicted=833.0016, Expected=805.0349
# Month=25, Predicted=815.1429, Expected=820.4588
# Month=26, Predicted=824.1287, Expected=773.2413
# Month=27, Predicted=855.4762, Expected=882.5316
# Month=28, Predicted=903.8838, Expected=898.7897
# Month=29, Predicted=944.8645, Expected=956.6009
# Month=30, Predicted=944.1260, Expected=923.8359
# Month=31, Predicted=882.3650, Expected=881.4145
# Month=32, Predicted=848.1989, Expected=836.3729
# Month=33, Predicted=822.7735, Expected=784.1159
# Month=34, Predicted=798.1564, Expected=791.6660
# Month=35, Predicted=793.6130, Expected=759.1810
# Month=36, Predicted=815.7012, Expected=802.0941
# Month=37, Predicted=808.4646, Expected=828.1324
# Month=38, Predicted=815.2893, Expected=778.3983
# Month=39, Predicted=858.2720, Expected=888.3698
# Month=40, Predicted=908.4843, Expected=901.3272
# Month=41, Predicted=950.9190, Expected=969.2659
# Month=42, Predicted=963.6163, Expected=947.1513
# Month=43, Predicted=914.7177, Expected=908.1276
# Month=44, Predicted=871.4494, Expected=867.1765
# Month=45, Predicted=848.9503, Expected=814.6535
# Month=46, Predicted=826.1690, Expected=812.1183
# Month=47, Predicted=809.0537, Expected=773.1493
# Month=48, Predicted=828.5568, Expected=812.6360
# Month=49, Predicted=820.6932, Expected=834.9506
# Month=50, Predicted=823.3563, Expected=782.2414
# Month=51, Predicted=867.3896, Expected=891.3930
# Month=52, Predicted=912.5897, Expected=903.3345
# Month=53, Predicted=953.7432, Expected=965.5034
# Month=54, Predicted=957.3207, Expected=937.4010
# Month=55, Predicted=904.6078, Expected=896.5903
# Month=56, Predicted=865.5214, Expected=857.5819
# Month=57, Predicted=845.2101, Expected=817.4908
# Month=58, Predicted=824.3729, Expected=827.2103
# Month=59, Predicted=823.8729, Expected=797.4188
# Month=60, Predicted=853.2985, Expected=843.9664
# Run 29 — RMSE: 22.669931, MSE: 513.925793, NMSE: 0.0030055185
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=753.1726, Expected=804.1312
# Month=2, Predicted=815.8422, Expected=755.9621
# Month=3, Predicted=795.6835, Expected=859.0224
# Month=4, Predicted=853.4812, Expected=877.9865
# Month=5, Predicted=874.9134, Expected=942.0307
# Month=6, Predicted=909.8684, Expected=914.2550
# Month=7, Predicted=890.8912, Expected=868.9020
# Month=8, Predicted=813.5816, Expected=834.1536
# Month=9, Predicted=776.2254, Expected=789.9823
# Month=10, Predicted=756.3184, Expected=799.4046
# Month=11, Predicted=773.6701, Expected=763.5823
# Month=12, Predicted=772.8755, Expected=800.3831
# Month=13, Predicted=791.2080, Expected=826.4030
# Month=14, Predicted=830.9702, Expected=798.5367
# Month=15, Predicted=814.0140, Expected=890.7147
# Month=16, Predicted=879.1059, Expected=899.2858
# Month=17, Predicted=897.1428, Expected=961.2990
# Month=18, Predicted=927.3869, Expected=936.1160
# Month=19, Predicted=912.6705, Expected=893.4953
# Month=20, Predicted=839.6873, Expected=854.7115
# Month=21, Predicted=798.1945, Expected=809.0508
# Month=22, Predicted=772.4752, Expected=809.7435
# Month=23, Predicted=781.1639, Expected=765.2099
# Month=24, Predicted=772.4421, Expected=805.0349
# Month=25, Predicted=794.0756, Expected=820.4588
# Month=26, Predicted=827.8471, Expected=773.2413
# Month=27, Predicted=794.5819, Expected=882.5316
# Month=28, Predicted=877.8861, Expected=898.7897
# Month=29, Predicted=899.3685, Expected=956.6009
# Month=30, Predicted=925.8554, Expected=923.8359
# Month=31, Predicted=903.8344, Expected=881.4145
# Month=32, Predicted=827.7385, Expected=836.3729
# Month=33, Predicted=785.4398, Expected=784.1159
# Month=34, Predicted=753.3175, Expected=791.6660
# Month=35, Predicted=767.4731, Expected=759.1810
# Month=36, Predicted=770.7298, Expected=802.0941
# Month=37, Predicted=797.4349, Expected=828.1324
# Month=38, Predicted=837.1703, Expected=778.3983
# Month=39, Predicted=804.4473, Expected=888.3698
# Month=40, Predicted=882.6566, Expected=901.3272
# Month=41, Predicted=899.9192, Expected=969.2659
# Month=42, Predicted=936.5281, Expected=947.1513
# Month=43, Predicted=923.1213, Expected=908.1276
# Month=44, Predicted=851.5572, Expected=867.1765
# Month=45, Predicted=808.8541, Expected=814.6535
# Month=46, Predicted=775.8754, Expected=812.1183
# Month=47, Predicted=780.1561, Expected=773.1493
# Month=48, Predicted=776.4057, Expected=812.6360
# Month=49, Predicted=802.6611, Expected=834.9506
# Month=50, Predicted=841.1508, Expected=782.2414
# Month=51, Predicted=806.6673, Expected=891.3930
# Month=52, Predicted=885.0308, Expected=903.3345
# Month=53, Predicted=902.9082, Expected=965.5034
# Month=54, Predicted=933.3765, Expected=937.4010
# Month=55, Predicted=916.2308, Expected=896.5903
# Month=56, Predicted=842.6877, Expected=857.5819
# Month=57, Predicted=803.2541, Expected=817.4908
# Month=58, Predicted=781.0308, Expected=827.2103
# Month=59, Predicted=800.0049, Expected=797.4188
# Month=60, Predicted=801.3697, Expected=843.9664
# Run 30 — RMSE: 39.615563, MSE: 1569.392842, NMSE: 0.0077987259
#
# ===== FINAL RESULTS — Fuzzy Output Layer on Monthly Milk Production (30 runs) =====
# RMSE: 30.186429 ± 10.046793
# MSE:  1012.158540 ± 631.340959
# NMSE: 0.0050703632 ± 0.0030450280
#
# Best run: 23
#   RMSE: 15.526576
#   MSE:  241.074564
#   NMSE: 0.0011977449
# === Best Run Metrics ===
# RMSE: 15.526576
# MSE:  241.074564
# NMSE: 0.0011977449

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Output Layer on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
