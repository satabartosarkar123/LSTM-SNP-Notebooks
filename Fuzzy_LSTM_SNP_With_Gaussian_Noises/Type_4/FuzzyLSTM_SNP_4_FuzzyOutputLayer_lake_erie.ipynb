# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 1)]               0
#
#  rnn (RNN)                   (1, 8)                    320
#
#  fuzzy_output_layer (FuzzyO  (1, 1)                    12
#  utputLayer)
#
# =================================================================
# Total params: 332 (1.30 KB)
# Trainable params: 332 (1.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 1)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input
    # ============================================================
    
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)
    
        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Output Layer on Monthly Lake Erie Levels (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Output Layer — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Output Layer — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.010052)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.76799303 14.64761015 15.09151064 16.39130966 16.92364626]
# Supervised data shape: (599, 2)
# Train: (539, 2), Test: (60, 2)
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.3199, Expected=13.7084
# Month=2, Predicted=14.2198, Expected=13.8026
# Month=3, Predicted=14.2421, Expected=14.3883
# Month=4, Predicted=14.9301, Expected=15.0615
# Month=5, Predicted=15.4289, Expected=15.6682
# Month=6, Predicted=15.7971, Expected=15.8360
# Month=7, Predicted=15.6032, Expected=15.7178
# Month=8, Predicted=15.2730, Expected=15.3110
# Month=9, Predicted=14.7525, Expected=14.7667
# Month=10, Predicted=14.2283, Expected=13.5419
# Month=11, Predicted=12.9400, Expected=13.5869
# Month=12, Predicted=13.5542, Expected=14.5144
# Month=13, Predicted=14.9165, Expected=14.3947
# Month=14, Predicted=14.6342, Expected=14.4996
# Month=15, Predicted=14.9569, Expected=14.7474
# Month=16, Predicted=15.1339, Expected=15.8019
# Month=17, Predicted=16.3370, Expected=16.5221
# Month=18, Predicted=16.6937, Expected=16.5417
# Month=19, Predicted=16.2973, Expected=16.7210
# Month=20, Predicted=16.3946, Expected=16.4288
# Month=21, Predicted=15.8929, Expected=15.7719
# Month=22, Predicted=15.1803, Expected=15.2959
# Month=23, Predicted=14.8612, Expected=15.1318
# Month=24, Predicted=14.9510, Expected=15.5377
# Month=25, Predicted=15.7596, Expected=15.8371
# Month=26, Predicted=16.1861, Expected=16.3719
# Month=27, Predicted=16.9119, Expected=16.3365
# Month=28, Predicted=16.6495, Expected=16.8969
# Month=29, Predicted=17.2448, Expected=17.0022
# Month=30, Predicted=16.9625, Expected=17.4155
# Month=31, Predicted=17.3575, Expected=17.5332
# Month=32, Predicted=17.2720, Expected=17.2849
# Month=33, Predicted=16.8966, Expected=16.6063
# Month=34, Predicted=16.1171, Expected=15.8228
# Month=35, Predicted=15.3877, Expected=15.4543
# Month=36, Predicted=15.2941, Expected=15.6138
# Month=37, Predicted=15.7936, Expected=15.6954
# Month=38, Predicted=15.9996, Expected=16.7627
# Month=39, Predicted=17.4622, Expected=16.4941
# Month=40, Predicted=16.6926, Expected=17.7345
# Month=41, Predicted=18.3419, Expected=18.6944
# Month=42, Predicted=18.8722, Expected=19.1228
# Month=43, Predicted=18.9578, Expected=19.5704
# Month=44, Predicted=19.2858, Expected=19.2258
# Month=45, Predicted=18.6190, Expected=18.2178
# Month=46, Predicted=17.4802, Expected=17.2135
# Month=47, Predicted=16.5415, Expected=16.6554
# Month=48, Predicted=16.2099, Expected=16.8225
# Month=49, Predicted=16.8059, Expected=15.7773
# Month=50, Predicted=15.7083, Expected=15.7224
# Month=51, Predicted=16.1828, Expected=15.9967
# Month=52, Predicted=16.6094, Expected=17.0162
# Month=53, Predicted=17.7907, Expected=17.5568
# Month=54, Predicted=17.9639, Expected=17.8404
# Month=55, Predicted=17.9050, Expected=17.8664
# Month=56, Predicted=17.5677, Expected=17.5659
# Month=57, Predicted=17.0289, Expected=17.0753
# Month=58, Predicted=16.4791, Expected=16.6502
# Month=59, Predicted=16.1487, Expected=16.4285
# Month=60, Predicted=16.1220, Expected=16.5878
# Run 1 — RMSE: 0.411815, MSE: 0.169591, NMSE: 0.0015051023
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2301, Expected=13.7084
# Month=2, Predicted=14.1382, Expected=13.8026
# Month=3, Predicted=13.8609, Expected=14.3883
# Month=4, Predicted=14.8182, Expected=15.0615
# Month=5, Predicted=15.5292, Expected=15.6682
# Month=6, Predicted=16.0933, Expected=15.8360
# Month=7, Predicted=15.9442, Expected=15.7178
# Month=8, Predicted=15.6194, Expected=15.3110
# Month=9, Predicted=15.0410, Expected=14.7667
# Month=10, Predicted=14.4388, Expected=13.5419
# Month=11, Predicted=13.0605, Expected=13.5869
# Month=12, Predicted=13.6654, Expected=14.5144
# Month=13, Predicted=15.1030, Expected=14.3947
# Month=14, Predicted=14.2785, Expected=14.4996
# Month=15, Predicted=14.5882, Expected=14.7474
# Month=16, Predicted=14.9466, Expected=15.8019
# Month=17, Predicted=16.4237, Expected=16.5221
# Month=18, Predicted=17.0040, Expected=16.5417
# Month=19, Predicted=16.5294, Expected=16.7210
# Month=20, Predicted=16.8609, Expected=16.4288
# Month=21, Predicted=16.2183, Expected=15.7719
# Month=22, Predicted=15.3993, Expected=15.2959
# Month=23, Predicted=15.0058, Expected=15.1318
# Month=24, Predicted=15.0295, Expected=15.5377
# Month=25, Predicted=15.8628, Expected=15.8371
# Month=26, Predicted=16.0662, Expected=16.3719
# Month=27, Predicted=16.7674, Expected=16.3365
# Month=28, Predicted=16.2955, Expected=16.8969
# Month=29, Predicted=17.3163, Expected=17.0022
# Month=30, Predicted=17.0724, Expected=17.4155
# Month=31, Predicted=17.7350, Expected=17.5332
# Month=32, Predicted=17.6176, Expected=17.2849
# Month=33, Predicted=17.1059, Expected=16.6063
# Month=34, Predicted=16.2278, Expected=15.8228
# Month=35, Predicted=15.4189, Expected=15.4543
# Month=36, Predicted=15.2290, Expected=15.6138
# Month=37, Predicted=15.7640, Expected=15.6954
# Month=38, Predicted=15.7655, Expected=16.7627
# Month=39, Predicted=17.3908, Expected=16.4941
# Month=40, Predicted=16.2811, Expected=17.7345
# Month=41, Predicted=18.3994, Expected=18.6944
# Month=42, Predicted=19.2783, Expected=19.1228
# Month=43, Predicted=19.4247, Expected=19.5704
# Month=44, Predicted=19.8998, Expected=19.2258
# Month=45, Predicted=18.9764, Expected=18.2178
# Month=46, Predicted=17.7614, Expected=17.2135
# Month=47, Predicted=16.7628, Expected=16.6554
# Month=48, Predicted=16.3347, Expected=16.8225
# Month=49, Predicted=16.9803, Expected=15.7773
# Month=50, Predicted=15.3134, Expected=15.7224
# Month=51, Predicted=15.7170, Expected=15.9967
# Month=52, Predicted=16.2252, Expected=17.0162
# Month=53, Predicted=17.6286, Expected=17.5568
# Month=54, Predicted=17.9359, Expected=17.8404
# Month=55, Predicted=18.0448, Expected=17.8664
# Month=56, Predicted=17.8767, Expected=17.5659
# Month=57, Predicted=17.3539, Expected=17.0753
# Month=58, Predicted=16.7703, Expected=16.6502
# Month=59, Predicted=16.3830, Expected=16.4285
# Month=60, Predicted=16.2845, Expected=16.5878
# Run 2 — RMSE: 0.497879, MSE: 0.247883, NMSE: 0.0019068033
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.1611, Expected=13.7084
# Month=2, Predicted=14.1901, Expected=13.8026
# Month=3, Predicted=14.4125, Expected=14.3883
# Month=4, Predicted=15.0800, Expected=15.0615
# Month=5, Predicted=15.4266, Expected=15.6682
# Month=6, Predicted=15.7090, Expected=15.8360
# Month=7, Predicted=15.5372, Expected=15.7178
# Month=8, Predicted=15.1882, Expected=15.3110
# Month=9, Predicted=14.7079, Expected=14.7667
# Month=10, Predicted=14.1733, Expected=13.5419
# Month=11, Predicted=13.0725, Expected=13.5869
# Month=12, Predicted=13.8185, Expected=14.5144
# Month=13, Predicted=14.8745, Expected=14.3947
# Month=14, Predicted=14.8467, Expected=14.4996
# Month=15, Predicted=15.2763, Expected=14.7474
# Month=16, Predicted=15.3010, Expected=15.8019
# Month=17, Predicted=16.3794, Expected=16.5221
# Month=18, Predicted=16.5361, Expected=16.5417
# Month=19, Predicted=16.1825, Expected=16.7210
# Month=20, Predicted=16.3287, Expected=16.4288
# Month=21, Predicted=15.8397, Expected=15.7719
# Month=22, Predicted=15.1150, Expected=15.2959
# Month=23, Predicted=14.9917, Expected=15.1318
# Month=24, Predicted=15.0696, Expected=15.5377
# Month=25, Predicted=15.7364, Expected=15.8371
# Month=26, Predicted=16.2991, Expected=16.3719
# Month=27, Predicted=17.1002, Expected=16.3365
# Month=28, Predicted=16.7135, Expected=16.8969
# Month=29, Predicted=17.2069, Expected=17.0022
# Month=30, Predicted=16.7745, Expected=17.4155
# Month=31, Predicted=17.2954, Expected=17.5332
# Month=32, Predicted=17.0551, Expected=17.2849
# Month=33, Predicted=16.7016, Expected=16.6063
# Month=34, Predicted=16.0545, Expected=15.8228
# Month=35, Predicted=15.5001, Expected=15.4543
# Month=36, Predicted=15.3797, Expected=15.6138
# Month=37, Predicted=15.8834, Expected=15.6954
# Month=38, Predicted=16.2023, Expected=16.7627
# Month=39, Predicted=17.6214, Expected=16.4941
# Month=40, Predicted=16.8298, Expected=17.7345
# Month=41, Predicted=18.4001, Expected=18.6944
# Month=42, Predicted=18.7580, Expected=19.1228
# Month=43, Predicted=18.8353, Expected=19.5704
# Month=44, Predicted=19.2427, Expected=19.2258
# Month=45, Predicted=18.5572, Expected=18.2178
# Month=46, Predicted=17.4998, Expected=17.2135
# Month=47, Predicted=16.7911, Expected=16.6554
# Month=48, Predicted=16.5391, Expected=16.8225
# Month=49, Predicted=17.0967, Expected=15.7773
# Month=50, Predicted=16.2654, Expected=15.7224
# Month=51, Predicted=16.4230, Expected=15.9967
# Month=52, Predicted=16.6051, Expected=17.0162
# Month=53, Predicted=17.7121, Expected=17.5568
# Month=54, Predicted=17.6167, Expected=17.8404
# Month=55, Predicted=17.7208, Expected=17.8664
# Month=56, Predicted=17.4624, Expected=17.5659
# Month=57, Predicted=17.0137, Expected=17.0753
# Month=58, Predicted=16.4745, Expected=16.6502
# Month=59, Predicted=16.3301, Expected=16.4285
# Month=60, Predicted=16.3250, Expected=16.5878
# Run 3 — RMSE: 0.420632, MSE: 0.176932, NMSE: 0.0016823947
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.4025, Expected=13.7084
# Month=2, Predicted=14.2357, Expected=13.8026
# Month=3, Predicted=14.1743, Expected=14.3883
# Month=4, Predicted=14.7964, Expected=15.0615
# Month=5, Predicted=15.3743, Expected=15.6682
# Month=6, Predicted=15.8244, Expected=15.8360
# Month=7, Predicted=15.6836, Expected=15.7178
# Month=8, Predicted=15.3430, Expected=15.3110
# Month=9, Predicted=14.7817, Expected=14.7667
# Month=10, Predicted=14.2403, Expected=13.5419
# Month=11, Predicted=12.8673, Expected=13.5869
# Month=12, Predicted=13.6549, Expected=14.5144
# Month=13, Predicted=15.1130, Expected=14.3947
# Month=14, Predicted=14.7511, Expected=14.4996
# Month=15, Predicted=14.8556, Expected=14.7474
# Month=16, Predicted=15.0062, Expected=15.8019
# Month=17, Predicted=16.2354, Expected=16.5221
# Month=18, Predicted=16.7351, Expected=16.5417
# Month=19, Predicted=16.3471, Expected=16.7210
# Month=20, Predicted=16.4836, Expected=16.4288
# Month=21, Predicted=15.9856, Expected=15.7719
# Month=22, Predicted=15.2005, Expected=15.2959
# Month=23, Predicted=14.9407, Expected=15.1318
# Month=24, Predicted=15.1194, Expected=15.5377
# Month=25, Predicted=15.9080, Expected=15.8371
# Month=26, Predicted=16.2600, Expected=16.3719
# Month=27, Predicted=16.8603, Expected=16.3365
# Month=28, Predicted=16.5120, Expected=16.8969
# Month=29, Predicted=17.1281, Expected=17.0022
# Month=30, Predicted=16.9232, Expected=17.4155
# Month=31, Predicted=17.3650, Expected=17.5332
# Month=32, Predicted=17.3342, Expected=17.2849
# Month=33, Predicted=16.9475, Expected=16.6063
# Month=34, Predicted=16.1199, Expected=15.8228
# Month=35, Predicted=15.3783, Expected=15.4543
# Month=36, Predicted=15.3439, Expected=15.6138
# Month=37, Predicted=15.8698, Expected=15.6954
# Month=38, Predicted=16.0202, Expected=16.7627
# Month=39, Predicted=17.4344, Expected=16.4941
# Month=40, Predicted=16.6456, Expected=17.7345
# Month=41, Predicted=18.2657, Expected=18.6944
# Month=42, Predicted=19.0382, Expected=19.1228
# Month=43, Predicted=19.1392, Expected=19.5704
# Month=44, Predicted=19.4778, Expected=19.2258
# Month=45, Predicted=18.7388, Expected=18.2178
# Month=46, Predicted=17.4036, Expected=17.2135
# Month=47, Predicted=16.4547, Expected=16.6554
# Month=48, Predicted=16.3210, Expected=16.8225
# Month=49, Predicted=17.0503, Expected=15.7773
# Month=50, Predicted=15.7131, Expected=15.7224
# Month=51, Predicted=16.0247, Expected=15.9967
# Month=52, Predicted=16.4193, Expected=17.0162
# Month=53, Predicted=17.6244, Expected=17.5568
# Month=54, Predicted=17.8913, Expected=17.8404
# Month=55, Predicted=17.9030, Expected=17.8664
# Month=56, Predicted=17.6459, Expected=17.5659
# Month=57, Predicted=17.0789, Expected=17.0753
# Month=58, Predicted=16.4615, Expected=16.6502
# Month=59, Predicted=16.1636, Expected=16.4285
# Month=60, Predicted=16.2595, Expected=16.5878
# Run 4 — RMSE: 0.426073, MSE: 0.181538, NMSE: 0.0015945104
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2102, Expected=13.7084
# Month=2, Predicted=14.1680, Expected=13.8026
# Month=3, Predicted=14.5843, Expected=14.3883
# Month=4, Predicted=15.1193, Expected=15.0615
# Month=5, Predicted=15.3687, Expected=15.6682
# Month=6, Predicted=15.7372, Expected=15.8360
# Month=7, Predicted=15.5886, Expected=15.7178
# Month=8, Predicted=15.2754, Expected=15.3110
# Month=9, Predicted=14.6766, Expected=14.7667
# Month=10, Predicted=14.2161, Expected=13.5419
# Month=11, Predicted=12.9729, Expected=13.5869
# Month=12, Predicted=13.6063, Expected=14.5144
# Month=13, Predicted=14.7170, Expected=14.3947
# Month=14, Predicted=14.8109, Expected=14.4996
# Month=15, Predicted=15.3513, Expected=14.7474
# Month=16, Predicted=15.3549, Expected=15.8019
# Month=17, Predicted=16.2648, Expected=16.5221
# Month=18, Predicted=16.5881, Expected=16.5417
# Month=19, Predicted=16.1985, Expected=16.7210
# Month=20, Predicted=16.4052, Expected=16.4288
# Month=21, Predicted=15.8223, Expected=15.7719
# Month=22, Predicted=15.1827, Expected=15.2959
# Month=23, Predicted=15.0272, Expected=15.1318
# Month=24, Predicted=15.0958, Expected=15.5377
# Month=25, Predicted=15.7302, Expected=15.8371
# Month=26, Predicted=16.4138, Expected=16.3719
# Month=27, Predicted=17.2300, Expected=16.3365
# Month=28, Predicted=16.7397, Expected=16.8969
# Month=29, Predicted=17.1228, Expected=17.0022
# Month=30, Predicted=16.7862, Expected=17.4155
# Month=31, Predicted=17.2523, Expected=17.5332
# Month=32, Predicted=17.0965, Expected=17.2849
# Month=33, Predicted=16.7629, Expected=16.6063
# Month=34, Predicted=16.1532, Expected=15.8228
# Month=35, Predicted=15.6013, Expected=15.4543
# Month=36, Predicted=15.4724, Expected=15.6138
# Month=37, Predicted=15.8496, Expected=15.6954
# Month=38, Predicted=16.3541, Expected=16.7627
# Month=39, Predicted=17.6683, Expected=16.4941
# Month=40, Predicted=16.6736, Expected=17.7345
# Month=41, Predicted=18.2822, Expected=18.6944
# Month=42, Predicted=18.8557, Expected=19.1228
# Month=43, Predicted=18.9411, Expected=19.5704
# Month=44, Predicted=19.3270, Expected=19.2258
# Month=45, Predicted=18.5960, Expected=18.2178
# Month=46, Predicted=17.5331, Expected=17.2135
# Month=47, Predicted=16.8196, Expected=16.6554
# Month=48, Predicted=16.5686, Expected=16.8225
# Month=49, Predicted=16.9313, Expected=15.7773
# Month=50, Predicted=15.9583, Expected=15.7224
# Month=51, Predicted=16.4613, Expected=15.9967
# Month=52, Predicted=16.8335, Expected=17.0162
# Month=53, Predicted=17.6560, Expected=17.5568
# Month=54, Predicted=17.5952, Expected=17.8404
# Month=55, Predicted=17.6988, Expected=17.8664
# Month=56, Predicted=17.5046, Expected=17.5659
# Month=57, Predicted=16.9934, Expected=17.0753
# Month=58, Predicted=16.4598, Expected=16.6502
# Month=59, Predicted=16.2763, Expected=16.4285
# Month=60, Predicted=16.3091, Expected=16.5878
# Run 5 — RMSE: 0.420939, MSE: 0.177190, NMSE: 0.0016577794
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.3524, Expected=13.7084
# Month=2, Predicted=14.2146, Expected=13.8026
# Month=3, Predicted=13.9632, Expected=14.3883
# Month=4, Predicted=14.6802, Expected=15.0615
# Month=5, Predicted=15.4027, Expected=15.6682
# Month=6, Predicted=15.9369, Expected=15.8360
# Month=7, Predicted=15.8064, Expected=15.7178
# Month=8, Predicted=15.4487, Expected=15.3110
# Month=9, Predicted=14.8767, Expected=14.7667
# Month=10, Predicted=14.3067, Expected=13.5419
# Month=11, Predicted=12.7838, Expected=13.5869
# Month=12, Predicted=13.7466, Expected=14.5144
# Month=13, Predicted=15.3136, Expected=14.3947
# Month=14, Predicted=14.6046, Expected=14.4996
# Month=15, Predicted=14.5154, Expected=14.7474
# Month=16, Predicted=14.8077, Expected=15.8019
# Month=17, Predicted=16.4245, Expected=16.5221
# Month=18, Predicted=16.9303, Expected=16.5417
# Month=19, Predicted=16.4852, Expected=16.7210
# Month=20, Predicted=16.5904, Expected=16.4288
# Month=21, Predicted=16.0864, Expected=15.7719
# Month=22, Predicted=15.2329, Expected=15.2959
# Month=23, Predicted=14.9182, Expected=15.1318
# Month=24, Predicted=15.1413, Expected=15.5377
# Month=25, Predicted=16.0216, Expected=15.8371
# Month=26, Predicted=16.2008, Expected=16.3719
# Month=27, Predicted=16.7302, Expected=16.3365
# Month=28, Predicted=16.2983, Expected=16.8969
# Month=29, Predicted=17.1015, Expected=17.0022
# Month=30, Predicted=16.9915, Expected=17.4155
# Month=31, Predicted=17.5766, Expected=17.5332
# Month=32, Predicted=17.5543, Expected=17.2849
# Month=33, Predicted=17.0533, Expected=16.6063
# Month=34, Predicted=16.0870, Expected=15.8228
# Month=35, Predicted=15.2268, Expected=15.4543
# Month=36, Predicted=15.2484, Expected=15.6138
# Month=37, Predicted=15.9663, Expected=15.6954
# Month=38, Predicted=15.9882, Expected=16.7627
# Month=39, Predicted=17.4607, Expected=16.4941
# Month=40, Predicted=16.5037, Expected=17.7345
# Month=41, Predicted=18.3365, Expected=18.6944
# Month=42, Predicted=19.1599, Expected=19.1228
# Month=43, Predicted=19.2410, Expected=19.5704
# Month=44, Predicted=19.5972, Expected=19.2258
# Month=45, Predicted=18.8359, Expected=18.2178
# Month=46, Predicted=17.4282, Expected=17.2135
# Month=47, Predicted=16.4076, Expected=16.6554
# Month=48, Predicted=16.3341, Expected=16.8225
# Month=49, Predicted=17.2692, Expected=15.7773
# Month=50, Predicted=15.4989, Expected=15.7224
# Month=51, Predicted=15.7443, Expected=15.9967
# Month=52, Predicted=16.3409, Expected=17.0162
# Month=53, Predicted=17.7177, Expected=17.5568
# Month=54, Predicted=17.9331, Expected=17.8404
# Month=55, Predicted=17.9080, Expected=17.8664
# Month=56, Predicted=17.6714, Expected=17.5659
# Month=57, Predicted=17.1658, Expected=17.0753
# Month=58, Predicted=16.6050, Expected=16.6502
# Month=59, Predicted=16.3249, Expected=16.4285
# Month=60, Predicted=16.3802, Expected=16.5878
# Run 6 — RMSE: 0.473206, MSE: 0.223924, NMSE: 0.0018295206
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.2429, Expected=13.7084
# Month=2, Predicted=14.0928, Expected=13.8026
# Month=3, Predicted=13.9095, Expected=14.3883
# Month=4, Predicted=14.7321, Expected=15.0615
# Month=5, Predicted=15.4111, Expected=15.6682
# Month=6, Predicted=15.9684, Expected=15.8360
# Month=7, Predicted=15.9523, Expected=15.7178
# Month=8, Predicted=15.7033, Expected=15.3110
# Month=9, Predicted=15.1369, Expected=14.7667
# Month=10, Predicted=14.5008, Expected=13.5419
# Month=11, Predicted=12.9897, Expected=13.5869
# Month=12, Predicted=13.6364, Expected=14.5144
# Month=13, Predicted=15.1093, Expected=14.3947
# Month=14, Predicted=14.3979, Expected=14.4996
# Month=15, Predicted=14.6155, Expected=14.7474
# Month=16, Predicted=14.9293, Expected=15.8019
# Month=17, Predicted=16.3397, Expected=16.5221
# Month=18, Predicted=16.8510, Expected=16.5417
# Month=19, Predicted=16.5946, Expected=16.7210
# Month=20, Predicted=16.8494, Expected=16.4288
# Month=21, Predicted=16.3234, Expected=15.7719
# Month=22, Predicted=15.4634, Expected=15.2959
# Month=23, Predicted=15.0570, Expected=15.1318
# Month=24, Predicted=15.0703, Expected=15.5377
# Month=25, Predicted=15.8263, Expected=15.8371
# Month=26, Predicted=16.0620, Expected=16.3719
# Month=27, Predicted=16.6958, Expected=16.3365
# Month=28, Predicted=16.3729, Expected=16.8969
# Month=29, Predicted=17.2242, Expected=17.0022
# Month=30, Predicted=17.0983, Expected=17.4155
# Month=31, Predicted=17.6672, Expected=17.5332
# Month=32, Predicted=17.6368, Expected=17.2849
# Month=33, Predicted=17.2040, Expected=16.6063
# Month=34, Predicted=16.2930, Expected=15.8228
# Month=35, Predicted=15.4360, Expected=15.4543
# Month=36, Predicted=15.2552, Expected=15.6138
# Month=37, Predicted=15.7569, Expected=15.6954
# Month=38, Predicted=15.8106, Expected=16.7627
# Month=39, Predicted=17.3647, Expected=16.4941
# Month=40, Predicted=16.4268, Expected=17.7345
# Month=41, Predicted=18.3394, Expected=18.6944
# Month=42, Predicted=19.0883, Expected=19.1228
# Month=43, Predicted=19.3251, Expected=19.5704
# Month=44, Predicted=19.7970, Expected=19.2258
# Month=45, Predicted=19.1144, Expected=18.2178
# Month=46, Predicted=17.7773, Expected=17.2135
# Month=47, Predicted=16.7265, Expected=16.6554
# Month=48, Predicted=16.3439, Expected=16.8225
# Month=49, Predicted=16.9746, Expected=15.7773
# Month=50, Predicted=15.3480, Expected=15.7224
# Month=51, Predicted=15.7519, Expected=15.9967
# Month=52, Predicted=16.2291, Expected=17.0162
# Month=53, Predicted=17.6025, Expected=17.5568
# Month=54, Predicted=17.8423, Expected=17.8404
# Month=55, Predicted=18.0123, Expected=17.8664
# Month=56, Predicted=17.9205, Expected=17.5659
# Month=57, Predicted=17.4474, Expected=17.0753
# Month=58, Predicted=16.8288, Expected=16.6502
# Month=59, Predicted=16.4337, Expected=16.4285
# Month=60, Predicted=16.3327, Expected=16.5878
# Run 7 — RMSE: 0.494592, MSE: 0.244621, NMSE: 0.0019259675
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.3242, Expected=13.7084
# Month=2, Predicted=14.1946, Expected=13.8026
# Month=3, Predicted=13.9071, Expected=14.3883
# Month=4, Predicted=14.6868, Expected=15.0615
# Month=5, Predicted=15.4231, Expected=15.6682
# Month=6, Predicted=15.9566, Expected=15.8360
# Month=7, Predicted=15.8489, Expected=15.7178
# Month=8, Predicted=15.5445, Expected=15.3110
# Month=9, Predicted=14.9742, Expected=14.7667
# Month=10, Predicted=14.3791, Expected=13.5419
# Month=11, Predicted=12.7643, Expected=13.5869
# Month=12, Predicted=13.7833, Expected=14.5144
# Month=13, Predicted=15.4206, Expected=14.3947
# Month=14, Predicted=14.4958, Expected=14.4996
# Month=15, Predicted=14.4677, Expected=14.7474
# Month=16, Predicted=14.8387, Expected=15.8019
# Month=17, Predicted=16.4700, Expected=16.5221
# Month=18, Predicted=16.8966, Expected=16.5417
# Month=19, Predicted=16.4658, Expected=16.7210
# Month=20, Predicted=16.6905, Expected=16.4288
# Month=21, Predicted=16.1864, Expected=15.7719
# Month=22, Predicted=15.2942, Expected=15.2959
# Month=23, Predicted=14.9772, Expected=15.1318
# Month=24, Predicted=15.1342, Expected=15.5377
# Month=25, Predicted=15.9975, Expected=15.8371
# Month=26, Predicted=16.1305, Expected=16.3719
# Month=27, Predicted=16.6761, Expected=16.3365
# Month=28, Predicted=16.2715, Expected=16.8969
# Month=29, Predicted=17.1810, Expected=17.0022
# Month=30, Predicted=17.0619, Expected=17.4155
# Month=31, Predicted=17.6311, Expected=17.5332
# Month=32, Predicted=17.5890, Expected=17.2849
# Month=33, Predicted=17.0881, Expected=16.6063
# Month=34, Predicted=16.1060, Expected=15.8228
# Month=35, Predicted=15.2728, Expected=15.4543
# Month=36, Predicted=15.2823, Expected=15.6138
# Month=37, Predicted=15.9396, Expected=15.6954
# Month=38, Predicted=15.9178, Expected=16.7627
# Month=39, Predicted=17.4568, Expected=16.4941
# Month=40, Predicted=16.3956, Expected=17.7345
# Month=41, Predicted=18.4201, Expected=18.6944
# Month=42, Predicted=19.1403, Expected=19.1228
# Month=43, Predicted=19.2462, Expected=19.5704
# Month=44, Predicted=19.6689, Expected=19.2258
# Month=45, Predicted=18.9205, Expected=18.2178
# Month=46, Predicted=17.4707, Expected=17.2135
# Month=47, Predicted=16.5054, Expected=16.6554
# Month=48, Predicted=16.3856, Expected=16.8225
# Month=49, Predicted=17.2276, Expected=15.7773
# Month=50, Predicted=15.3264, Expected=15.7224
# Month=51, Predicted=15.7184, Expected=15.9967
# Month=52, Predicted=16.3445, Expected=17.0162
# Month=53, Predicted=17.7251, Expected=17.5568
# Month=54, Predicted=17.8471, Expected=17.8404
# Month=55, Predicted=17.8822, Expected=17.8664
# Month=56, Predicted=17.7502, Expected=17.5659
# Month=57, Predicted=17.2886, Expected=17.0753
# Month=58, Predicted=16.7093, Expected=16.6502
# Month=59, Predicted=16.3838, Expected=16.4285
# Month=60, Predicted=16.3690, Expected=16.5878
# Run 8 — RMSE: 0.489071, MSE: 0.239191, NMSE: 0.0019252468
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2972, Expected=13.7084
# Month=2, Predicted=14.2615, Expected=13.8026
# Month=3, Predicted=14.3977, Expected=14.3883
# Month=4, Predicted=15.0578, Expected=15.0615
# Month=5, Predicted=15.5264, Expected=15.6682
# Month=6, Predicted=15.7418, Expected=15.8360
# Month=7, Predicted=15.5156, Expected=15.7178
# Month=8, Predicted=15.2187, Expected=15.3110
# Month=9, Predicted=14.6703, Expected=14.7667
# Month=10, Predicted=14.1577, Expected=13.5419
# Month=11, Predicted=12.9388, Expected=13.5869
# Month=12, Predicted=13.4764, Expected=14.5144
# Month=13, Predicted=14.8722, Expected=14.3947
# Month=14, Predicted=14.7957, Expected=14.4996
# Month=15, Predicted=15.0846, Expected=14.7474
# Month=16, Predicted=15.3605, Expected=15.8019
# Month=17, Predicted=16.4319, Expected=16.5221
# Month=18, Predicted=16.6912, Expected=16.5417
# Month=19, Predicted=16.2247, Expected=16.7210
# Month=20, Predicted=16.2761, Expected=16.4288
# Month=21, Predicted=15.8209, Expected=15.7719
# Month=22, Predicted=15.1007, Expected=15.2959
# Month=23, Predicted=14.8297, Expected=15.1318
# Month=24, Predicted=14.9420, Expected=15.5377
# Month=25, Predicted=15.7336, Expected=15.8371
# Month=26, Predicted=16.2915, Expected=16.3719
# Month=27, Predicted=17.0486, Expected=16.3365
# Month=28, Predicted=16.8675, Expected=16.8969
# Month=29, Predicted=17.4159, Expected=17.0022
# Month=30, Predicted=17.0735, Expected=17.4155
# Month=31, Predicted=17.3054, Expected=17.5332
# Month=32, Predicted=17.1725, Expected=17.2849
# Month=33, Predicted=16.7703, Expected=16.6063
# Month=34, Predicted=16.0207, Expected=15.8228
# Month=35, Predicted=15.3571, Expected=15.4543
# Month=36, Predicted=15.2722, Expected=15.6138
# Month=37, Predicted=15.7794, Expected=15.6954
# Month=38, Predicted=16.0909, Expected=16.7627
# Month=39, Predicted=17.5328, Expected=16.4941
# Month=40, Predicted=16.9302, Expected=17.7345
# Month=41, Predicted=18.3714, Expected=18.6944
# Month=42, Predicted=18.8603, Expected=19.1228
# Month=43, Predicted=18.8503, Expected=19.5704
# Month=44, Predicted=19.1609, Expected=19.2258
# Month=45, Predicted=18.6203, Expected=18.2178
# Month=46, Predicted=17.4525, Expected=17.2135
# Month=47, Predicted=16.5585, Expected=16.6554
# Month=48, Predicted=16.2594, Expected=16.8225
# Month=49, Predicted=16.8234, Expected=15.7773
# Month=50, Predicted=15.7149, Expected=15.7224
# Month=51, Predicted=16.0816, Expected=15.9967
# Month=52, Predicted=16.6104, Expected=17.0162
# Month=53, Predicted=17.8010, Expected=17.5568
# Month=54, Predicted=18.0115, Expected=17.8404
# Month=55, Predicted=17.8486, Expected=17.8664
# Month=56, Predicted=17.5314, Expected=17.5659
# Month=57, Predicted=17.0422, Expected=17.0753
# Month=58, Predicted=16.4287, Expected=16.6502
# Month=59, Predicted=16.1082, Expected=16.4285
# Month=60, Predicted=16.1326, Expected=16.5878
# Run 9 — RMSE: 0.407571, MSE: 0.166114, NMSE: 0.0014863041
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2534, Expected=13.7084
# Month=2, Predicted=14.2087, Expected=13.8026
# Month=3, Predicted=14.3158, Expected=14.3883
# Month=4, Predicted=14.9818, Expected=15.0615
# Month=5, Predicted=15.4445, Expected=15.6682
# Month=6, Predicted=15.7904, Expected=15.8360
# Month=7, Predicted=15.5896, Expected=15.7178
# Month=8, Predicted=15.2847, Expected=15.3110
# Month=9, Predicted=14.7702, Expected=14.7667
# Month=10, Predicted=14.2555, Expected=13.5419
# Month=11, Predicted=12.8999, Expected=13.5869
# Month=12, Predicted=13.6555, Expected=14.5144
# Month=13, Predicted=14.9805, Expected=14.3947
# Month=14, Predicted=14.7627, Expected=14.4996
# Month=15, Predicted=15.0036, Expected=14.7474
# Month=16, Predicted=15.1597, Expected=15.8019
# Month=17, Predicted=16.3270, Expected=16.5221
# Month=18, Predicted=16.5926, Expected=16.5417
# Month=19, Predicted=16.2301, Expected=16.7210
# Month=20, Predicted=16.4649, Expected=16.4288
# Month=21, Predicted=15.9328, Expected=15.7719
# Month=22, Predicted=15.2276, Expected=15.2959
# Month=23, Predicted=14.9494, Expected=15.1318
# Month=24, Predicted=15.0392, Expected=15.5377
# Month=25, Predicted=15.8484, Expected=15.8371
# Month=26, Predicted=16.2827, Expected=16.3719
# Month=27, Predicted=16.9770, Expected=16.3365
# Month=28, Predicted=16.7033, Expected=16.8969
# Month=29, Predicted=17.2540, Expected=17.0022
# Month=30, Predicted=16.8646, Expected=17.4155
# Month=31, Predicted=17.3423, Expected=17.5332
# Month=32, Predicted=17.1882, Expected=17.2849
# Month=33, Predicted=16.8246, Expected=16.6063
# Month=34, Predicted=16.0737, Expected=15.8228
# Month=35, Predicted=15.3819, Expected=15.4543
# Month=36, Predicted=15.3244, Expected=15.6138
# Month=37, Predicted=15.8479, Expected=15.6954
# Month=38, Predicted=16.0814, Expected=16.7627
# Month=39, Predicted=17.5388, Expected=16.4941
# Month=40, Predicted=16.9245, Expected=17.7345
# Month=41, Predicted=18.4635, Expected=18.6944
# Month=42, Predicted=18.7983, Expected=19.1228
# Month=43, Predicted=18.8809, Expected=19.5704
# Month=44, Predicted=19.3153, Expected=19.2258
# Month=45, Predicted=18.5925, Expected=18.2178
# Month=46, Predicted=17.4586, Expected=17.2135
# Month=47, Predicted=16.6029, Expected=16.6554
# Month=48, Predicted=16.3472, Expected=16.8225
# Month=49, Predicted=16.9693, Expected=15.7773
# Month=50, Predicted=15.8360, Expected=15.7224
# Month=51, Predicted=16.2765, Expected=15.9967
# Month=52, Predicted=16.5871, Expected=17.0162
# Month=53, Predicted=17.6892, Expected=17.5568
# Month=54, Predicted=17.8374, Expected=17.8404
# Month=55, Predicted=17.8105, Expected=17.8664
# Month=56, Predicted=17.5621, Expected=17.5659
# Month=57, Predicted=17.0502, Expected=17.0753
# Month=58, Predicted=16.5246, Expected=16.6502
# Month=59, Predicted=16.2117, Expected=16.4285
# Month=60, Predicted=16.1793, Expected=16.5878
# Run 10 — RMSE: 0.407804, MSE: 0.166304, NMSE: 0.0015165867
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.2214, Expected=13.7084
# Month=2, Predicted=14.2285, Expected=13.8026
# Month=3, Predicted=14.5453, Expected=14.3883
# Month=4, Predicted=15.1503, Expected=15.0615
# Month=5, Predicted=15.4693, Expected=15.6682
# Month=6, Predicted=15.7656, Expected=15.8360
# Month=7, Predicted=15.6179, Expected=15.7178
# Month=8, Predicted=15.3368, Expected=15.3110
# Month=9, Predicted=14.7020, Expected=14.7667
# Month=10, Predicted=14.1738, Expected=13.5419
# Month=11, Predicted=12.9598, Expected=13.5869
# Month=12, Predicted=13.5574, Expected=14.5144
# Month=13, Predicted=14.8405, Expected=14.3947
# Month=14, Predicted=14.7588, Expected=14.4996
# Month=15, Predicted=15.2477, Expected=14.7474
# Month=16, Predicted=15.4837, Expected=15.8019
# Month=17, Predicted=16.3362, Expected=16.5221
# Month=18, Predicted=16.6746, Expected=16.5417
# Month=19, Predicted=16.2734, Expected=16.7210
# Month=20, Predicted=16.4570, Expected=16.4288
# Month=21, Predicted=15.8668, Expected=15.7719
# Month=22, Predicted=15.0820, Expected=15.2959
# Month=23, Predicted=14.8989, Expected=15.1318
# Month=24, Predicted=14.9731, Expected=15.5377
# Month=25, Predicted=15.6746, Expected=15.8371
# Month=26, Predicted=16.2085, Expected=16.3719
# Month=27, Predicted=17.1406, Expected=16.3365
# Month=28, Predicted=17.0240, Expected=16.8969
# Month=29, Predicted=17.3514, Expected=17.0022
# Month=30, Predicted=17.0206, Expected=17.4155
# Month=31, Predicted=17.3617, Expected=17.5332
# Month=32, Predicted=17.2766, Expected=17.2849
# Month=33, Predicted=16.7642, Expected=16.6063
# Month=34, Predicted=15.9281, Expected=15.8228
# Month=35, Predicted=15.3557, Expected=15.4543
# Month=36, Predicted=15.2867, Expected=15.6138
# Month=37, Predicted=15.7465, Expected=15.6954
# Month=38, Predicted=16.0783, Expected=16.7627
# Month=39, Predicted=17.6166, Expected=16.4941
# Month=40, Predicted=17.0862, Expected=17.7345
# Month=41, Predicted=18.2376, Expected=18.6944
# Month=42, Predicted=18.8524, Expected=19.1228
# Month=43, Predicted=18.9425, Expected=19.5704
# Month=44, Predicted=19.3666, Expected=19.2258
# Month=45, Predicted=18.5967, Expected=18.2178
# Month=46, Predicted=17.4349, Expected=17.2135
# Month=47, Predicted=16.6806, Expected=16.6554
# Month=48, Predicted=16.4248, Expected=16.8225
# Month=49, Predicted=16.9347, Expected=15.7773
# Month=50, Predicted=15.7822, Expected=15.7224
# Month=51, Predicted=16.3566, Expected=15.9967
# Month=52, Predicted=16.8909, Expected=17.0162
# Month=53, Predicted=17.7658, Expected=17.5568
# Month=54, Predicted=17.8000, Expected=17.8404
# Month=55, Predicted=17.7414, Expected=17.8664
# Month=56, Predicted=17.5531, Expected=17.5659
# Month=57, Predicted=17.0808, Expected=17.0753
# Month=58, Predicted=16.3980, Expected=16.6502
# Month=59, Predicted=16.1663, Expected=16.4285
# Month=60, Predicted=16.1734, Expected=16.5878
# Run 11 — RMSE: 0.403013, MSE: 0.162420, NMSE: 0.0014590923
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2681, Expected=13.7084
# Month=2, Predicted=14.2886, Expected=13.8026
# Month=3, Predicted=14.5237, Expected=14.3883
# Month=4, Predicted=15.0731, Expected=15.0615
# Month=5, Predicted=15.4164, Expected=15.6682
# Month=6, Predicted=15.6679, Expected=15.8360
# Month=7, Predicted=15.5452, Expected=15.7178
# Month=8, Predicted=15.2619, Expected=15.3110
# Month=9, Predicted=14.6818, Expected=14.7667
# Month=10, Predicted=14.1501, Expected=13.5419
# Month=11, Predicted=12.9522, Expected=13.5869
# Month=12, Predicted=13.5032, Expected=14.5144
# Month=13, Predicted=14.8472, Expected=14.3947
# Month=14, Predicted=14.9027, Expected=14.4996
# Month=15, Predicted=15.2074, Expected=14.7474
# Month=16, Predicted=15.4018, Expected=15.8019
# Month=17, Predicted=16.3055, Expected=16.5221
# Month=18, Predicted=16.5804, Expected=16.5417
# Month=19, Predicted=16.1840, Expected=16.7210
# Month=20, Predicted=16.4157, Expected=16.4288
# Month=21, Predicted=15.8299, Expected=15.7719
# Month=22, Predicted=15.0772, Expected=15.2959
# Month=23, Predicted=14.8418, Expected=15.1318
# Month=24, Predicted=14.9760, Expected=15.5377
# Month=25, Predicted=15.7226, Expected=15.8371
# Month=26, Predicted=16.3399, Expected=16.3719
# Month=27, Predicted=17.1206, Expected=16.3365
# Month=28, Predicted=16.9525, Expected=16.8969
# Month=29, Predicted=17.2674, Expected=17.0022
# Month=30, Predicted=16.8470, Expected=17.4155
# Month=31, Predicted=17.2746, Expected=17.5332
# Month=32, Predicted=17.1690, Expected=17.2849
# Month=33, Predicted=16.7089, Expected=16.6063
# Month=34, Predicted=15.9951, Expected=15.8228
# Month=35, Predicted=15.4000, Expected=15.4543
# Month=36, Predicted=15.3468, Expected=15.6138
# Month=37, Predicted=15.8336, Expected=15.6954
# Month=38, Predicted=16.2646, Expected=16.7627
# Month=39, Predicted=17.5454, Expected=16.4941
# Month=40, Predicted=16.9631, Expected=17.7345
# Month=41, Predicted=18.1629, Expected=18.6944
# Month=42, Predicted=18.7659, Expected=19.1228
# Month=43, Predicted=18.8890, Expected=19.5704
# Month=44, Predicted=19.3190, Expected=19.2258
# Month=45, Predicted=18.5713, Expected=18.2178
# Month=46, Predicted=17.3928, Expected=17.2135
# Month=47, Predicted=16.5766, Expected=16.6554
# Month=48, Predicted=16.3165, Expected=16.8225
# Month=49, Predicted=16.8441, Expected=15.7773
# Month=50, Predicted=15.7131, Expected=15.7224
# Month=51, Predicted=16.0565, Expected=15.9967
# Month=52, Predicted=16.6780, Expected=17.0162
# Month=53, Predicted=17.7896, Expected=17.5568
# Month=54, Predicted=18.0234, Expected=17.8404
# Month=55, Predicted=17.7665, Expected=17.8664
# Month=56, Predicted=17.5582, Expected=17.5659
# Month=57, Predicted=17.0581, Expected=17.0753
# Month=58, Predicted=16.4364, Expected=16.6502
# Month=59, Predicted=16.0935, Expected=16.4285
# Month=60, Predicted=16.1309, Expected=16.5878
# Run 12 — RMSE: 0.410529, MSE: 0.168534, NMSE: 0.0015437473
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2825, Expected=13.7084
# Month=2, Predicted=14.1452, Expected=13.8026
# Month=3, Predicted=13.8226, Expected=14.3883
# Month=4, Predicted=14.7874, Expected=15.0615
# Month=5, Predicted=15.3758, Expected=15.6682
# Month=6, Predicted=15.9000, Expected=15.8360
# Month=7, Predicted=15.7585, Expected=15.7178
# Month=8, Predicted=15.4880, Expected=15.3110
# Month=9, Predicted=14.9503, Expected=14.7667
# Month=10, Predicted=14.3855, Expected=13.5419
# Month=11, Predicted=12.9119, Expected=13.5869
# Month=12, Predicted=13.8971, Expected=14.5144
# Month=13, Predicted=15.1734, Expected=14.3947
# Month=14, Predicted=14.4289, Expected=14.4996
# Month=15, Predicted=14.6525, Expected=14.7474
# Month=16, Predicted=14.8813, Expected=15.8019
# Month=17, Predicted=16.4068, Expected=16.5221
# Month=18, Predicted=16.8148, Expected=16.5417
# Month=19, Predicted=16.4155, Expected=16.7210
# Month=20, Predicted=16.7518, Expected=16.4288
# Month=21, Predicted=16.1332, Expected=15.7719
# Month=22, Predicted=15.3282, Expected=15.2959
# Month=23, Predicted=15.0048, Expected=15.1318
# Month=24, Predicted=15.0904, Expected=15.5377
# Month=25, Predicted=15.9219, Expected=15.8371
# Month=26, Predicted=16.0383, Expected=16.3719
# Month=27, Predicted=16.7282, Expected=16.3365
# Month=28, Predicted=16.2358, Expected=16.8969
# Month=29, Predicted=17.2678, Expected=17.0022
# Month=30, Predicted=16.9208, Expected=17.4155
# Month=31, Predicted=17.6240, Expected=17.5332
# Month=32, Predicted=17.4642, Expected=17.2849
# Month=33, Predicted=17.0252, Expected=16.6063
# Month=34, Predicted=16.1550, Expected=15.8228
# Month=35, Predicted=15.3592, Expected=15.4543
# Month=36, Predicted=15.2970, Expected=15.6138
# Month=37, Predicted=15.8523, Expected=15.6954
# Month=38, Predicted=15.8004, Expected=16.7627
# Month=39, Predicted=17.4797, Expected=16.4941
# Month=40, Predicted=16.4136, Expected=17.7345
# Month=41, Predicted=18.5268, Expected=18.6944
# Month=42, Predicted=19.1612, Expected=19.1228
# Month=43, Predicted=19.2702, Expected=19.5704
# Month=44, Predicted=19.7624, Expected=19.2258
# Month=45, Predicted=18.9304, Expected=18.2178
# Month=46, Predicted=17.6092, Expected=17.2135
# Month=47, Predicted=16.6901, Expected=16.6554
# Month=48, Predicted=16.4042, Expected=16.8225
# Month=49, Predicted=17.1410, Expected=15.7773
# Month=50, Predicted=15.4513, Expected=15.7224
# Month=51, Predicted=15.9870, Expected=15.9967
# Month=52, Predicted=16.2401, Expected=17.0162
# Month=53, Predicted=17.6512, Expected=17.5568
# Month=54, Predicted=17.7856, Expected=17.8404
# Month=55, Predicted=17.9015, Expected=17.8664
# Month=56, Predicted=17.7348, Expected=17.5659
# Month=57, Predicted=17.2450, Expected=17.0753
# Month=58, Predicted=16.6860, Expected=16.6502
# Month=59, Predicted=16.3522, Expected=16.4285
# Month=60, Predicted=16.3123, Expected=16.5878
# Run 13 — RMSE: 0.475452, MSE: 0.226054, NMSE: 0.0018246558
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.1836, Expected=13.7084
# Month=2, Predicted=14.0378, Expected=13.8026
# Month=3, Predicted=14.7411, Expected=14.3883
# Month=4, Predicted=15.1304, Expected=15.0615
# Month=5, Predicted=15.2988, Expected=15.6682
# Month=6, Predicted=15.7367, Expected=15.8360
# Month=7, Predicted=15.5790, Expected=15.7178
# Month=8, Predicted=15.2313, Expected=15.3110
# Month=9, Predicted=14.6946, Expected=14.7667
# Month=10, Predicted=14.1976, Expected=13.5419
# Month=11, Predicted=13.0134, Expected=13.5869
# Month=12, Predicted=13.5729, Expected=14.5144
# Month=13, Predicted=14.6883, Expected=14.3947
# Month=14, Predicted=14.7705, Expected=14.4996
# Month=15, Predicted=15.4716, Expected=14.7474
# Month=16, Predicted=15.3112, Expected=15.8019
# Month=17, Predicted=16.1605, Expected=16.5221
# Month=18, Predicted=16.6255, Expected=16.5417
# Month=19, Predicted=16.2474, Expected=16.7210
# Month=20, Predicted=16.3160, Expected=16.4288
# Month=21, Predicted=15.8646, Expected=15.7719
# Month=22, Predicted=15.1968, Expected=15.2959
# Month=23, Predicted=14.9934, Expected=15.1318
# Month=24, Predicted=15.1082, Expected=15.5377
# Month=25, Predicted=15.6671, Expected=15.8371
# Month=26, Predicted=16.2661, Expected=16.3719
# Month=27, Predicted=17.3842, Expected=16.3365
# Month=28, Predicted=16.7468, Expected=16.8969
# Month=29, Predicted=17.0368, Expected=17.0022
# Month=30, Predicted=16.8806, Expected=17.4155
# Month=31, Predicted=17.1471, Expected=17.5332
# Month=32, Predicted=17.0982, Expected=17.2849
# Month=33, Predicted=16.7404, Expected=16.6063
# Month=34, Predicted=16.0588, Expected=15.8228
# Month=35, Predicted=15.4662, Expected=15.4543
# Month=36, Predicted=15.3743, Expected=15.6138
# Month=37, Predicted=15.7002, Expected=15.6954
# Month=38, Predicted=16.1056, Expected=16.7627
# Month=39, Predicted=17.8160, Expected=16.4941
# Month=40, Predicted=16.8913, Expected=17.7345
# Month=41, Predicted=18.1244, Expected=18.6944
# Month=42, Predicted=18.8465, Expected=19.1228
# Month=43, Predicted=18.9017, Expected=19.5704
# Month=44, Predicted=19.2649, Expected=19.2258
# Month=45, Predicted=18.6795, Expected=18.2178
# Month=46, Predicted=17.5784, Expected=17.2135
# Month=47, Predicted=16.7872, Expected=16.6554
# Month=48, Predicted=16.5349, Expected=16.8225
# Month=49, Predicted=16.8860, Expected=15.7773
# Month=50, Predicted=15.8925, Expected=15.7224
# Month=51, Predicted=16.4508, Expected=15.9967
# Month=52, Predicted=16.8641, Expected=17.0162
# Month=53, Predicted=17.6529, Expected=17.5568
# Month=54, Predicted=17.7337, Expected=17.8404
# Month=55, Predicted=17.7122, Expected=17.8664
# Month=56, Predicted=17.4739, Expected=17.5659
# Month=57, Predicted=17.0084, Expected=17.0753
# Month=58, Predicted=16.4963, Expected=16.6502
# Month=59, Predicted=16.2807, Expected=16.4285
# Month=60, Predicted=16.3615, Expected=16.5878
# Run 14 — RMSE: 0.435788, MSE: 0.189911, NMSE: 0.0017535370
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.3648, Expected=13.7084
# Month=2, Predicted=14.2357, Expected=13.8026
# Month=3, Predicted=14.1147, Expected=14.3883
# Month=4, Predicted=14.7700, Expected=15.0615
# Month=5, Predicted=15.3595, Expected=15.6682
# Month=6, Predicted=15.8162, Expected=15.8360
# Month=7, Predicted=15.6854, Expected=15.7178
# Month=8, Predicted=15.3497, Expected=15.3110
# Month=9, Predicted=14.7702, Expected=14.7667
# Month=10, Predicted=14.2009, Expected=13.5419
# Month=11, Predicted=12.7834, Expected=13.5869
# Month=12, Predicted=13.5880, Expected=14.5144
# Month=13, Predicted=15.1731, Expected=14.3947
# Month=14, Predicted=14.7088, Expected=14.4996
# Month=15, Predicted=14.7928, Expected=14.7474
# Month=16, Predicted=15.0142, Expected=15.8019
# Month=17, Predicted=16.2872, Expected=16.5221
# Month=18, Predicted=16.7613, Expected=16.5417
# Month=19, Predicted=16.3444, Expected=16.7210
# Month=20, Predicted=16.4882, Expected=16.4288
# Month=21, Predicted=15.9614, Expected=15.7719
# Month=22, Predicted=15.1274, Expected=15.2959
# Month=23, Predicted=14.8207, Expected=15.1318
# Month=24, Predicted=15.0227, Expected=15.5377
# Month=25, Predicted=15.9118, Expected=15.8371
# Month=26, Predicted=16.2550, Expected=16.3719
# Month=27, Predicted=16.8477, Expected=16.3365
# Month=28, Predicted=16.4479, Expected=16.8969
# Month=29, Predicted=17.1422, Expected=17.0022
# Month=30, Predicted=16.9767, Expected=17.4155
# Month=31, Predicted=17.4731, Expected=17.5332
# Month=32, Predicted=17.4397, Expected=17.2849
# Month=33, Predicted=16.9724, Expected=16.6063
# Month=34, Predicted=16.0501, Expected=15.8228
# Month=35, Predicted=15.2518, Expected=15.4543
# Month=36, Predicted=15.2350, Expected=15.6138
# Month=37, Predicted=15.8760, Expected=15.6954
# Month=38, Predicted=16.0459, Expected=16.7627
# Month=39, Predicted=17.4787, Expected=16.4941
# Month=40, Predicted=16.5883, Expected=17.7345
# Month=41, Predicted=18.2400, Expected=18.6944
# Month=42, Predicted=18.9756, Expected=19.1228
# Month=43, Predicted=19.0486, Expected=19.5704
# Month=44, Predicted=19.3851, Expected=19.2258
# Month=45, Predicted=18.6290, Expected=18.2178
# Month=46, Predicted=17.3153, Expected=17.2135
# Month=47, Predicted=16.3563, Expected=16.6554
# Month=48, Predicted=16.1938, Expected=16.8225
# Month=49, Predicted=17.0741, Expected=15.7773
# Month=50, Predicted=15.6091, Expected=15.7224
# Month=51, Predicted=16.0445, Expected=15.9967
# Month=52, Predicted=16.5193, Expected=17.0162
# Month=53, Predicted=17.7522, Expected=17.5568
# Month=54, Predicted=17.9586, Expected=17.8404
# Month=55, Predicted=17.9419, Expected=17.8664
# Month=56, Predicted=17.6913, Expected=17.5659
# Month=57, Predicted=17.1409, Expected=17.0753
# Month=58, Predicted=16.5185, Expected=16.6502
# Month=59, Predicted=16.1937, Expected=16.4285
# Month=60, Predicted=16.2436, Expected=16.5878
# Run 15 — RMSE: 0.442961, MSE: 0.196214, NMSE: 0.0016852339
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1557, Expected=13.7084
# Month=2, Predicted=14.0344, Expected=13.8026
# Month=3, Predicted=14.4699, Expected=14.3883
# Month=4, Predicted=15.1134, Expected=15.0615
# Month=5, Predicted=15.4157, Expected=15.6682
# Month=6, Predicted=15.7041, Expected=15.8360
# Month=7, Predicted=15.5787, Expected=15.7178
# Month=8, Predicted=15.2625, Expected=15.3110
# Month=9, Predicted=14.6682, Expected=14.7667
# Month=10, Predicted=14.1709, Expected=13.5419
# Month=11, Predicted=12.9451, Expected=13.5869
# Month=12, Predicted=13.6341, Expected=14.5144
# Month=13, Predicted=14.6474, Expected=14.3947
# Month=14, Predicted=14.6036, Expected=14.4996
# Month=15, Predicted=15.1835, Expected=14.7474
# Month=16, Predicted=15.3315, Expected=15.8019
# Month=17, Predicted=16.2959, Expected=16.5221
# Month=18, Predicted=16.5484, Expected=16.5417
# Month=19, Predicted=16.2160, Expected=16.7210
# Month=20, Predicted=16.4059, Expected=16.4288
# Month=21, Predicted=15.8528, Expected=15.7719
# Month=22, Predicted=15.1431, Expected=15.2959
# Month=23, Predicted=14.9837, Expected=15.1318
# Month=24, Predicted=15.1042, Expected=15.5377
# Month=25, Predicted=15.6405, Expected=15.8371
# Month=26, Predicted=16.2213, Expected=16.3719
# Month=27, Predicted=17.1719, Expected=16.3365
# Month=28, Predicted=16.7746, Expected=16.8969
# Month=29, Predicted=17.1610, Expected=17.0022
# Month=30, Predicted=16.8077, Expected=17.4155
# Month=31, Predicted=17.3148, Expected=17.5332
# Month=32, Predicted=17.1509, Expected=17.2849
# Month=33, Predicted=16.7689, Expected=16.6063
# Month=34, Predicted=16.0779, Expected=15.8228
# Month=35, Predicted=15.5050, Expected=15.4543
# Month=36, Predicted=15.4160, Expected=15.6138
# Month=37, Predicted=15.7688, Expected=15.6954
# Month=38, Predicted=16.1961, Expected=16.7627
# Month=39, Predicted=17.6947, Expected=16.4941
# Month=40, Predicted=16.7547, Expected=17.7345
# Month=41, Predicted=18.1983, Expected=18.6944
# Month=42, Predicted=18.7117, Expected=19.1228
# Month=43, Predicted=18.9100, Expected=19.5704
# Month=44, Predicted=19.3635, Expected=19.2258
# Month=45, Predicted=18.6482, Expected=18.2178
# Month=46, Predicted=17.4809, Expected=17.2135
# Month=47, Predicted=16.6964, Expected=16.6554
# Month=48, Predicted=16.5264, Expected=16.8225
# Month=49, Predicted=16.9097, Expected=15.7773
# Month=50, Predicted=15.9748, Expected=15.7224
# Month=51, Predicted=16.5059, Expected=15.9967
# Month=52, Predicted=16.7550, Expected=17.0162
# Month=53, Predicted=17.6551, Expected=17.5568
# Month=54, Predicted=17.6305, Expected=17.8404
# Month=55, Predicted=17.6826, Expected=17.8664
# Month=56, Predicted=17.5145, Expected=17.5659
# Month=57, Predicted=16.9786, Expected=17.0753
# Month=58, Predicted=16.4670, Expected=16.6502
# Month=59, Predicted=16.2896, Expected=16.4285
# Month=60, Predicted=16.3636, Expected=16.5878
# Run 16 — RMSE: 0.413997, MSE: 0.171393, NMSE: 0.0015645997
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.1165, Expected=13.7084
# Month=2, Predicted=13.6997, Expected=13.8026
# Month=3, Predicted=13.7940, Expected=14.3883
# Month=4, Predicted=14.3796, Expected=15.0615
# Month=5, Predicted=15.0528, Expected=15.6682
# Month=6, Predicted=15.6595, Expected=15.8360
# Month=7, Predicted=15.8273, Expected=15.7178
# Month=8, Predicted=15.7091, Expected=15.3110
# Month=9, Predicted=15.3023, Expected=14.7667
# Month=10, Predicted=14.7580, Expected=13.5419
# Month=11, Predicted=13.5332, Expected=13.5869
# Month=12, Predicted=13.5782, Expected=14.5144
# Month=13, Predicted=14.5057, Expected=14.3947
# Month=14, Predicted=14.3860, Expected=14.4996
# Month=15, Predicted=14.4909, Expected=14.7474
# Month=16, Predicted=14.7387, Expected=15.8019
# Month=17, Predicted=15.7932, Expected=16.5221
# Month=18, Predicted=16.5134, Expected=16.5417
# Month=19, Predicted=16.5330, Expected=16.7210
# Month=20, Predicted=16.7123, Expected=16.4288
# Month=21, Predicted=16.4201, Expected=15.7719
# Month=22, Predicted=15.7632, Expected=15.2959
# Month=23, Predicted=15.2872, Expected=15.1318
# Month=24, Predicted=15.1231, Expected=15.5377
# Month=25, Predicted=15.5290, Expected=15.8371
# Month=26, Predicted=15.8284, Expected=16.3719
# Month=27, Predicted=16.3632, Expected=16.3365
# Month=28, Predicted=16.3278, Expected=16.8969
# Month=29, Predicted=16.8882, Expected=17.0022
# Month=30, Predicted=16.9935, Expected=17.4155
# Month=31, Predicted=17.4068, Expected=17.5332
# Month=32, Predicted=17.5245, Expected=17.2849
# Month=33, Predicted=17.2762, Expected=16.6063
# Month=34, Predicted=16.5976, Expected=15.8228
# Month=35, Predicted=15.8141, Expected=15.4543
# Month=36, Predicted=15.4456, Expected=15.6138
# Month=37, Predicted=15.6051, Expected=15.6954
# Month=38, Predicted=15.6867, Expected=16.7627
# ...
# Month=33, Predicted=16.8326, Expected=16.6063
# Month=34, Predicted=15.9944, Expected=15.8228
# Month=35, Predicted=15.2692, Expected=15.4543
# Month=36, Predicted=15.1848, Expected=15.6138
# Month=37, Predicted=15.6405, Expected=15.6954
# Month=38, Predicted=15.9017, Expected=16.7627
# Month=39, Predicted=17.5049, Expected=16.4941
# Month=40, Predicted=17.0499, Expected=17.7345
# Month=41, Predicted=18.5973, Expected=18.6944
# Month=42, Predicted=19.0494, Expected=19.1228
# Month=43, Predicted=19.0587, Expected=19.5704
# Month=44, Predicted=19.4328, Expected=19.2258
# Month=45, Predicted=18.6705, Expected=18.2178
# Month=46, Predicted=17.4687, Expected=17.2135
# Month=47, Predicted=16.5804, Expected=16.6554
# Month=48, Predicted=16.3233, Expected=16.8225
# Month=49, Predicted=16.8815, Expected=15.7773
# Month=50, Predicted=15.7568, Expected=15.7224
# Month=51, Predicted=16.2246, Expected=15.9967
# Month=52, Predicted=16.7598, Expected=17.0162
# Month=53, Predicted=17.8697, Expected=17.5568
# Month=54, Predicted=17.8665, Expected=17.8404
# Month=55, Predicted=17.7435, Expected=17.8664
# Month=56, Predicted=17.5347, Expected=17.5659
# Month=57, Predicted=16.9990, Expected=17.0753
# Month=58, Predicted=16.4788, Expected=16.6502
# Month=59, Predicted=16.1841, Expected=16.4285
# Month=60, Predicted=16.1427, Expected=16.5878
# Run 25 — RMSE: 0.397846, MSE: 0.158282, NMSE: 0.0013558364
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.2692, Expected=13.7084
# Month=2, Predicted=14.1250, Expected=13.8026
# Month=3, Predicted=13.8535, Expected=14.3883
# Month=4, Predicted=14.7642, Expected=15.0615
# Month=5, Predicted=15.4610, Expected=15.6682
# Month=6, Predicted=16.0045, Expected=15.8360
# Month=7, Predicted=15.8647, Expected=15.7178
# Month=8, Predicted=15.5654, Expected=15.3110
# Month=9, Predicted=15.0015, Expected=14.7667
# Month=10, Predicted=14.4094, Expected=13.5419
# Month=11, Predicted=12.8486, Expected=13.5869
# Month=12, Predicted=13.7392, Expected=14.5144
# Month=13, Predicted=15.1669, Expected=14.3947
# Month=14, Predicted=14.2955, Expected=14.4996
# Month=15, Predicted=14.5723, Expected=14.7474
# Month=16, Predicted=14.9232, Expected=15.8019
# Month=17, Predicted=16.4386, Expected=16.5221
# Month=18, Predicted=16.9175, Expected=16.5417
# Month=19, Predicted=16.4488, Expected=16.7210
# Month=20, Predicted=16.7780, Expected=16.4288
# Month=21, Predicted=16.1740, Expected=15.7719
# Month=22, Predicted=15.3298, Expected=15.2959
# Month=23, Predicted=15.0071, Expected=15.1318
# Month=24, Predicted=15.0761, Expected=15.5377
# Month=25, Predicted=15.8718, Expected=15.8371
# Month=26, Predicted=16.0712, Expected=16.3719
# Month=27, Predicted=16.7228, Expected=16.3365
# Month=28, Predicted=16.2681, Expected=16.8969
# Month=29, Predicted=17.2517, Expected=17.0022
# Month=30, Predicted=17.0258, Expected=17.4155
# Month=31, Predicted=17.6726, Expected=17.5332
# Month=32, Predicted=17.5669, Expected=17.2849
# Month=33, Predicted=17.0746, Expected=16.6063
# Month=34, Predicted=16.1585, Expected=15.8228
# Month=35, Predicted=15.3554, Expected=15.4543
# Month=36, Predicted=15.2805, Expected=15.6138
# Month=37, Predicted=15.8248, Expected=15.6954
# Month=38, Predicted=15.8068, Expected=16.7627
# Month=39, Predicted=17.4196, Expected=16.4941
# Month=40, Predicted=16.2538, Expected=17.7345
# Month=41, Predicted=18.4072, Expected=18.6944
# Month=42, Predicted=19.2202, Expected=19.1228
# Month=43, Predicted=19.3009, Expected=19.5704
# Month=44, Predicted=19.7808, Expected=19.2258
# Month=45, Predicted=18.8935, Expected=18.2178
# Month=46, Predicted=17.5676, Expected=17.2135
# Month=47, Predicted=16.6223, Expected=16.6554
# Month=48, Predicted=16.3675, Expected=16.8225
# Month=49, Predicted=17.0618, Expected=15.7773
# Month=50, Predicted=15.1836, Expected=15.7224
# Month=51, Predicted=15.7956, Expected=15.9967
# Month=52, Predicted=16.2737, Expected=17.0162
# Month=53, Predicted=17.6657, Expected=17.5568
# Month=54, Predicted=17.8764, Expected=17.8404
# Month=55, Predicted=17.9742, Expected=17.8664
# Month=56, Predicted=17.8164, Expected=17.5659
# Month=57, Predicted=17.3155, Expected=17.0753
# Month=58, Predicted=16.7383, Expected=16.6502
# Month=59, Predicted=16.3887, Expected=16.4285
# Month=60, Predicted=16.3245, Expected=16.5878
# Run 26 — RMSE: 0.489194, MSE: 0.239311, NMSE: 0.0018816084
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.4194, Expected=13.7084
# Month=2, Predicted=14.4412, Expected=13.8026
# Month=3, Predicted=14.2404, Expected=14.3883
# Month=4, Predicted=15.0231, Expected=15.0615
# Month=5, Predicted=15.4385, Expected=15.6682
# Month=6, Predicted=15.8151, Expected=15.8360
# Month=7, Predicted=15.6549, Expected=15.7178
# Month=8, Predicted=15.3692, Expected=15.3110
# Month=9, Predicted=14.8227, Expected=14.7667
# Month=10, Predicted=14.3169, Expected=13.5419
# Month=11, Predicted=12.8985, Expected=13.5869
# Month=12, Predicted=13.7567, Expected=14.5144
# Month=13, Predicted=15.2304, Expected=14.3947
# Month=14, Predicted=14.9185, Expected=14.4996
# Month=15, Predicted=14.8969, Expected=14.7474
# Month=16, Predicted=15.1147, Expected=15.8019
# Month=17, Predicted=16.4787, Expected=16.5221
# Month=18, Predicted=16.8370, Expected=16.5417
# Month=19, Predicted=16.4336, Expected=16.7210
# Month=20, Predicted=16.6509, Expected=16.4288
# Month=21, Predicted=16.0451, Expected=15.7719
# Month=22, Predicted=15.2651, Expected=15.2959
# Month=23, Predicted=15.0276, Expected=15.1318
# Month=24, Predicted=15.1773, Expected=15.5377
# Month=25, Predicted=16.0995, Expected=15.8371
# Month=26, Predicted=16.3171, Expected=16.3719
# Month=27, Predicted=16.9649, Expected=16.3365
# Month=28, Predicted=16.6913, Expected=16.8969
# Month=29, Predicted=17.2462, Expected=17.0022
# Month=30, Predicted=16.9383, Expected=17.4155
# Month=31, Predicted=17.4980, Expected=17.5332
# Month=32, Predicted=17.4310, Expected=17.2849
# Month=33, Predicted=17.0775, Expected=16.6063
# Month=34, Predicted=16.2706, Expected=15.8228
# Month=35, Predicted=15.5533, Expected=15.4543
# Month=36, Predicted=15.5761, Expected=15.6138
# Month=37, Predicted=16.1809, Expected=15.6954
# Month=38, Predicted=16.1524, Expected=16.7627
# Month=39, Predicted=17.6803, Expected=16.4941
# Month=40, Predicted=17.2397, Expected=17.7345
# Month=41, Predicted=18.1921, Expected=18.6944
# Month=42, Predicted=18.6966, Expected=19.1228
# Month=43, Predicted=18.8966, Expected=19.5704
# Month=44, Predicted=19.3943, Expected=19.2258
# Month=45, Predicted=18.6813, Expected=18.2178
# Month=46, Predicted=17.4847, Expected=17.2135
# Month=47, Predicted=16.6283, Expected=16.6554
# Month=48, Predicted=16.4456, Expected=16.8225
# Month=49, Predicted=17.1606, Expected=15.7773
# Month=50, Predicted=16.2590, Expected=15.7224
# Month=51, Predicted=16.3203, Expected=15.9967
# Month=52, Predicted=16.5552, Expected=17.0162
# Month=53, Predicted=17.7912, Expected=17.5568
# Month=54, Predicted=18.0373, Expected=17.8404
# Month=55, Predicted=17.7069, Expected=17.8664
# Month=56, Predicted=17.5549, Expected=17.5659
# Month=57, Predicted=17.0397, Expected=17.0753
# Month=58, Predicted=16.5042, Expected=16.6502
# Month=59, Predicted=16.2124, Expected=16.4285
# Month=60, Predicted=16.2113, Expected=16.5878
# Run 27 — RMSE: 0.442373, MSE: 0.195694, NMSE: 0.0018248371
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=12.8141, Expected=13.7084
# Month=2, Predicted=13.3973, Expected=13.8026
# Month=3, Predicted=13.4915, Expected=14.3883
# Month=4, Predicted=14.0772, Expected=15.0615
# Month=5, Predicted=14.7504, Expected=15.6682
# Month=6, Predicted=15.3571, Expected=15.8360
# Month=7, Predicted=15.5249, Expected=15.7178
# Month=8, Predicted=15.4067, Expected=15.3110
# Month=9, Predicted=14.9999, Expected=14.7667
# Month=10, Predicted=14.4556, Expected=13.5419
# Month=11, Predicted=13.2308, Expected=13.5869
# Month=12, Predicted=13.2758, Expected=14.5144
# Month=13, Predicted=14.2033, Expected=14.3947
# Month=14, Predicted=14.0836, Expected=14.4996
# Month=15, Predicted=14.1885, Expected=14.7474
# Month=16, Predicted=14.4363, Expected=15.8019
# Month=17, Predicted=15.4908, Expected=16.5221
# Month=18, Predicted=16.2110, Expected=16.5417
# Month=19, Predicted=16.2306, Expected=16.7210
# Month=20, Predicted=16.4099, Expected=16.4288
# Month=21, Predicted=16.1177, Expected=15.7719
# Month=22, Predicted=15.4608, Expected=15.2959
# Month=23, Predicted=14.9848, Expected=15.1318
# Month=24, Predicted=14.8207, Expected=15.5377
# Month=25, Predicted=15.2266, Expected=15.8371
# Month=26, Predicted=15.5260, Expected=16.3719
# Month=27, Predicted=16.0608, Expected=16.3365
# Month=28, Predicted=16.0254, Expected=16.8969
# Month=29, Predicted=16.5858, Expected=17.0022
# Month=30, Predicted=16.6911, Expected=17.4155
# Month=31, Predicted=17.1044, Expected=17.5332
# Month=32, Predicted=17.2221, Expected=17.2849
# Month=33, Predicted=16.9738, Expected=16.6063
# Month=34, Predicted=16.2952, Expected=15.8228
# Month=35, Predicted=15.5117, Expected=15.4543
# Month=36, Predicted=15.1432, Expected=15.6138
# Month=37, Predicted=15.3027, Expected=15.6954
# Month=38, Predicted=15.3843, Expected=16.7627
# Month=39, Predicted=16.4516, Expected=16.4941
# Month=40, Predicted=16.1830, Expected=17.7345
# Month=41, Predicted=17.4234, Expected=18.6944
# Month=42, Predicted=18.3833, Expected=19.1228
# Month=43, Predicted=18.8117, Expected=19.5704
# Month=44, Predicted=19.2593, Expected=19.2258
# Month=45, Predicted=18.9147, Expected=18.2178
# Month=46, Predicted=17.9067, Expected=17.2135
# Month=47, Predicted=16.9024, Expected=16.6554
# Month=48, Predicted=16.3443, Expected=16.8225
# Month=49, Predicted=16.5114, Expected=15.7773
# Month=50, Predicted=15.4662, Expected=15.7224
# Month=51, Predicted=15.4113, Expected=15.9967
# Month=52, Predicted=15.6856, Expected=17.0162
# Month=53, Predicted=16.7051, Expected=17.5568
# Month=54, Predicted=17.2457, Expected=17.8404
# Month=55, Predicted=17.5293, Expected=17.8664
# Month=56, Predicted=17.5553, Expected=17.5659
# Month=57, Predicted=17.2548, Expected=17.0753
# Month=58, Predicted=16.7642, Expected=16.6502
# Month=59, Predicted=16.3391, Expected=16.4285
# Month=60, Predicted=16.1174, Expected=16.5878
# Run 28 — RMSE: 0.669877, MSE: 0.448735, NMSE: 0.0035012983
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.3753, Expected=13.7084
# Month=2, Predicted=14.2060, Expected=13.8026
# Month=3, Predicted=14.0601, Expected=14.3883
# Month=4, Predicted=14.7211, Expected=15.0615
# Month=5, Predicted=15.3370, Expected=15.6682
# Month=6, Predicted=15.8104, Expected=15.8360
# Month=7, Predicted=15.7185, Expected=15.7178
# Month=8, Predicted=15.4373, Expected=15.3110
# Month=9, Predicted=14.8263, Expected=14.7667
# Month=10, Predicted=14.2341, Expected=13.5419
# Month=11, Predicted=12.7830, Expected=13.5869
# Month=12, Predicted=13.6414, Expected=14.5144
# Month=13, Predicted=15.2740, Expected=14.3947
# Month=14, Predicted=14.7315, Expected=14.4996
# Month=15, Predicted=14.7441, Expected=14.7474
# Month=16, Predicted=14.9786, Expected=15.8019
# Month=17, Predicted=16.2977, Expected=16.5221
# Month=18, Predicted=16.7429, Expected=16.5417
# Month=19, Predicted=16.3909, Expected=16.7210
# Month=20, Predicted=16.5327, Expected=16.4288
# Month=21, Predicted=16.0208, Expected=15.7719
# Month=22, Predicted=15.1405, Expected=15.2959
# Month=23, Predicted=14.8241, Expected=15.1318
# Month=24, Predicted=15.0430, Expected=15.5377
# Month=25, Predicted=15.9776, Expected=15.8371
# Month=26, Predicted=16.2148, Expected=16.3719
# Month=27, Predicted=16.7482, Expected=16.3365
# Month=28, Predicted=16.4276, Expected=16.8969
# Month=29, Predicted=17.1270, Expected=17.0022
# Month=30, Predicted=17.0143, Expected=17.4155
# Month=31, Predicted=17.5129, Expected=17.5332
# Month=32, Predicted=17.4959, Expected=17.2849
# Month=33, Predicted=17.0699, Expected=16.6063
# Month=34, Predicted=16.1012, Expected=15.8228
# Month=35, Predicted=15.2558, Expected=15.4543
# Month=36, Predicted=15.2554, Expected=15.6138
# Month=37, Predicted=15.9608, Expected=15.6954
# Month=38, Predicted=16.1304, Expected=16.7627
# Month=39, Predicted=17.4703, Expected=16.4941
# Month=40, Predicted=16.6758, Expected=17.7345
# Month=41, Predicted=18.2732, Expected=18.6944
# Month=42, Predicted=18.9580, Expected=19.1228
# Month=43, Predicted=19.0435, Expected=19.5704
# Month=44, Predicted=19.3808, Expected=19.2258
# Month=45, Predicted=18.6943, Expected=18.2178
# Month=46, Predicted=17.2379, Expected=17.2135
# Month=47, Predicted=16.2600, Expected=16.6554
# Month=48, Predicted=16.1641, Expected=16.8225
# Month=49, Predicted=17.1038, Expected=15.7773
# Month=50, Predicted=15.6834, Expected=15.7224
# Month=51, Predicted=15.9654, Expected=15.9967
# Month=52, Predicted=16.5617, Expected=17.0162
# Month=53, Predicted=17.7552, Expected=17.5568
# Month=54, Predicted=17.9635, Expected=17.8404
# Month=55, Predicted=17.9875, Expected=17.8664
# Month=56, Predicted=17.7857, Expected=17.5659
# Month=57, Predicted=17.2702, Expected=17.0753
# Month=58, Predicted=16.6078, Expected=16.6502
# Month=59, Predicted=16.2733, Expected=16.4285
# Month=60, Predicted=16.3178, Expected=16.5878
# Run 29 — RMSE: 0.444623, MSE: 0.197689, NMSE: 0.0016887833
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.2346, Expected=13.7084
# Month=2, Predicted=14.1047, Expected=13.8026
# Month=3, Predicted=14.2697, Expected=14.3883
# Month=4, Predicted=15.1735, Expected=15.0615
# Month=5, Predicted=15.6517, Expected=15.6682
# Month=6, Predicted=15.7905, Expected=15.8360
# Month=7, Predicted=15.6446, Expected=15.7178
# Month=8, Predicted=15.3221, Expected=15.3110
# Month=9, Predicted=14.7360, Expected=14.7667
# Month=10, Predicted=14.1610, Expected=13.5419
# Month=11, Predicted=12.8528, Expected=13.5869
# Month=12, Predicted=13.6703, Expected=14.5144
# Month=13, Predicted=15.0001, Expected=14.3947
# Month=14, Predicted=14.7445, Expected=14.4996
# Month=15, Predicted=15.2080, Expected=14.7474
# Month=16, Predicted=15.5400, Expected=15.8019
# Month=17, Predicted=16.3783, Expected=16.5221
# Month=18, Predicted=16.5556, Expected=16.5417
# Month=19, Predicted=16.2387, Expected=16.7210
# Month=20, Predicted=16.4242, Expected=16.4288
# Month=21, Predicted=15.9103, Expected=15.7719
# Month=22, Predicted=15.1359, Expected=15.2959
# Month=23, Predicted=14.8356, Expected=15.1318
# Month=24, Predicted=15.0409, Expected=15.5377
# Month=25, Predicted=15.8318, Expected=15.8371
# Month=26, Predicted=16.2156, Expected=16.3719
# Month=27, Predicted=17.0445, Expected=16.3365
# Month=28, Predicted=16.9417, Expected=16.8969
# Month=29, Predicted=17.3885, Expected=17.0022
# Month=30, Predicted=16.9010, Expected=17.4155
# Month=31, Predicted=17.3674, Expected=17.5332
# Month=32, Predicted=17.2193, Expected=17.2849
# Month=33, Predicted=16.7886, Expected=16.6063
# Month=34, Predicted=15.9734, Expected=15.8228
# Month=35, Predicted=15.2552, Expected=15.4543
# Month=36, Predicted=15.2910, Expected=15.6138
# Month=37, Predicted=15.8400, Expected=15.6954
# Month=38, Predicted=16.0549, Expected=16.7627
# Month=39, Predicted=17.5833, Expected=16.4941
# Month=40, Predicted=17.0811, Expected=17.7345
# Month=41, Predicted=18.5174, Expected=18.6944
# Month=42, Predicted=18.8512, Expected=19.1228
# Month=43, Predicted=18.9721, Expected=19.5704
# Month=44, Predicted=19.4149, Expected=19.2258
# Month=45, Predicted=18.7012, Expected=18.2178
# Month=46, Predicted=17.4543, Expected=17.2135
# Month=47, Predicted=16.5277, Expected=16.6554
# Month=48, Predicted=16.4270, Expected=16.8225
# Month=49, Predicted=17.0591, Expected=15.7773
# Month=50, Predicted=15.9301, Expected=15.7224
# Month=51, Predicted=16.4118, Expected=15.9967
# Month=52, Predicted=16.8695, Expected=17.0162
# Month=53, Predicted=17.7554, Expected=17.5568
# Month=54, Predicted=17.5840, Expected=17.8404
# Month=55, Predicted=17.6959, Expected=17.8664
# Month=56, Predicted=17.5704, Expected=17.5659
# Month=57, Predicted=17.0410, Expected=17.0753
# Month=58, Predicted=16.4691, Expected=16.6502
# Month=59, Predicted=16.1545, Expected=16.4285
# Month=60, Predicted=16.2039, Expected=16.5878
# Run 30 — RMSE: 0.405533, MSE: 0.164457, NMSE: 0.0014603657
#
# ===== FINAL RESULTS — Fuzzy Output Layer on Monthly Lake Erie Levels (30 runs) =====
# RMSE: 0.448131 ± 0.055540
# MSE:  0.203906 ± 0.057237
# NMSE: 0.0017501127 ± 0.0003995366
#
# Best run: 25
#   RMSE: 0.397846
#   MSE:  0.158282
#   NMSE: 0.0013558364
# === Best Run Metrics ===
# RMSE: 0.397846
# MSE:  0.158282
# NMSE: 0.0013558364

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Output Layer on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
