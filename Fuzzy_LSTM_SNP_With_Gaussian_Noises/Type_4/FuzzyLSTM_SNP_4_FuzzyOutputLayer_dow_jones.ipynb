# %% [markdown]
# # Notebook 4: LSTM-SNP with Fuzzy Output Layer
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements a **fuzzy output layer** for the LSTM-SNP model. The internal
# LSTM-SNP structure is kept completely intact. The final Dense(1) layer is replaced with a
# fuzzy inference system that takes the RNN hidden state h(t) and produces the prediction
# through Takagi-Sugeno rules.
#
# The fuzzy output layer aggregates h(t) into 2 summary features via mean-pooling, then applies
# 4 rules with fixed Gaussian membership functions and trainable consequent parameters.

# %% [markdown]
# ## Theory: Fuzzy Output Layer
#
# ### LSTM-SNP Cell (Unchanged)
# All internal LSTM-SNP equations remain exactly as in the baseline.
#
# ### Fuzzy Output Computation
# The Dense(1) output layer is replaced with fuzzy inference:
#
# **Input**: $h(t) \in \mathbb{R}^{units}$ from the RNN
#
# **Feature Aggregation**: Mean-pooling into 2 summary statistics:
# - $s_1 = \text{mean}(h_{1:units/2})$
# - $s_2 = \text{mean}(h_{units/2+1:units})$
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(s) = \exp\left(-\frac{(s-(-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(s) = \exp\left(-\frac{(s-(+1))^2}{2 \cdot 0.5^2}\right)$
#
# **4 Takagi-Sugeno Rules** (trainable consequents):
# $y_i = a_i s_1 + b_i s_2 + c_i$
#
# **Defuzzification**: $\hat{y} = \frac{\sum_i w_i y_i}{\sum_i w_i}$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Fuzzy Output Layer

# %%
# ============================================================
# Fuzzy Output Layer
# Replaces Dense(1) with fuzzy inference.
#
# Takes RNN output h(t) ∈ R^units, produces scalar prediction.
# Aggregates h(t) into 2 summary features via mean-pooling:
#   s1 = mean(h[:units//2])
#   s2 = mean(h[units//2:])
#
# Then applies 4 Takagi-Sugeno rules.
# Fixed Gaussian MFs. Trainable consequent parameters.
# ============================================================

class FuzzyOutputLayer(layers.Layer):
    """
    Fuzzy output layer: replaces Dense(1).
    Input: h(t) from RNN (shape: [batch, units])
    Output: scalar prediction (shape: [batch, 1])
    """
    def __init__(self, units_in, **kwargs):
        super().__init__(**kwargs)
        self.units_in = units_in
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        # 4 rules, each with 3 consequent params (a, b, c)
        # y_i = a_i * s1 + b_i * s2 + c_i
        self.rule_a = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_a')
        self.rule_b = self.add_weight(shape=(4,), initializer='glorot_uniform', name='rule_b')
        self.rule_c = self.add_weight(shape=(4,), initializer='zeros', name='rule_c')

    def _gaussian_mf(self, x, center):
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def call(self, inputs):
        half = self.units_in // 2
        # Aggregate to 2 summary features
        s1 = tf.reduce_mean(inputs[:, :half], axis=-1, keepdims=True)  # [batch, 1]
        s2 = tf.reduce_mean(inputs[:, half:], axis=-1, keepdims=True)  # [batch, 1]

        # Membership degrees
        mu_low_s1 = self._gaussian_mf(s1, self.mu_low)
        mu_high_s1 = self._gaussian_mf(s1, self.mu_high)
        mu_low_s2 = self._gaussian_mf(s2, self.mu_low)
        mu_high_s2 = self._gaussian_mf(s2, self.mu_high)

        # Rule weights
        w1 = mu_low_s1 * mu_low_s2
        w2 = mu_low_s1 * mu_high_s2
        w3 = mu_high_s1 * mu_low_s2
        w4 = mu_high_s1 * mu_high_s2

        # Consequent outputs
        y1 = self.rule_a[0] * s1 + self.rule_b[0] * s2 + self.rule_c[0]
        y2 = self.rule_a[1] * s1 + self.rule_b[1] * s2 + self.rule_c[1]
        y3 = self.rule_a[2] * s1 + self.rule_b[2] * s2 + self.rule_c[2]
        y4 = self.rule_a[3] * s1 + self.rule_b[3] * s2 + self.rule_c[3]

        # Defuzzification
        numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
        denominator = w1 + w2 + w3 + w4 + 1e-8

        return numerator / denominator

    def get_config(self):
        config = super().get_config()
        config.update({'units_in': self.units_in})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Output Layer
# LSTMSNPCell is UNMODIFIED.
# Dense(1) is replaced by FuzzyOutputLayer.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = FuzzyOutputLayer(units_in=units)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 1)]               0
#
#  rnn (RNN)                   (1, 8)                    320
#
#  fuzzy_output_layer (FuzzyO  (1, 1)                    12
#  utputLayer)
#
# =================================================================
# Total params: 332 (1.30 KB)
# Trainable params: 332 (1.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 1)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input
    # ============================================================
    
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)
    
        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Output Layer on Dow Jones Industrial Index (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Output Layer — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Output Layer — Dow Jones Industrial Index\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.526428)
# ================================================================================
#
# Data shape: (291,)
# First 5 values: [3645.26148423 3625.9272138  3634.34096137 3621.30176553 3606.87673511]
# Supervised data shape: (290, 2)
# Train: (230, 2), Test: (60, 2)
# X_train shape: (230, 1, 1), y_train shape: (230,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3799.1944, Expected=3796.1139
# Month=2, Predicted=3796.1188, Expected=3793.0240
# Month=3, Predicted=3792.5776, Expected=3765.6570
# Month=4, Predicted=3765.0758, Expected=3748.1286
# Month=5, Predicted=3747.9536, Expected=3754.3337
# Month=6, Predicted=3755.3346, Expected=3754.9339
# Month=7, Predicted=3756.0563, Expected=3767.0982
# Month=8, Predicted=3767.9613, Expected=3750.6516
# Month=9, Predicted=3750.7456, Expected=3769.4487
# Month=10, Predicted=3770.0267, Expected=3759.5828
# Month=11, Predicted=3760.1888, Expected=3784.9396
# Month=12, Predicted=3785.7130, Expected=3776.2658
# Month=13, Predicted=3776.7992, Expected=3755.4558
# Month=14, Predicted=3754.9532, Expected=3754.3681
# Month=15, Predicted=3754.6646, Expected=3750.8239
# Month=16, Predicted=3751.6544, Expected=3775.7500
# Month=17, Predicted=3777.0168, Expected=3846.6561
# Month=18, Predicted=3848.9729, Expected=3830.9294
# Month=19, Predicted=3831.0199, Expected=3881.2132
# Month=20, Predicted=3881.2203, Expected=3898.3362
# Month=21, Predicted=3899.4652, Expected=3917.4832
# Month=22, Predicted=3917.6615, Expected=3914.1172
# Month=23, Predicted=3913.9436, Expected=3901.5435
# Month=24, Predicted=3901.0932, Expected=3885.2002
# Month=25, Predicted=3884.9970, Expected=3892.2451
# Month=26, Predicted=3892.9720, Expected=3899.6669
# Month=27, Predicted=3900.8240, Expected=3885.6275
# Month=28, Predicted=3885.7636, Expected=3908.2336
# Month=29, Predicted=3908.9546, Expected=3875.4078
# Month=30, Predicted=3875.2462, Expected=3859.5120
# Month=31, Predicted=3859.1178, Expected=3879.9687
# Month=32, Predicted=3881.1904, Expected=3893.2937
# Month=33, Predicted=3894.8914, Expected=3953.4607
# Month=34, Predicted=3955.0977, Expected=3932.8670
# Month=35, Predicted=3932.7631, Expected=3936.3431
# Month=36, Predicted=3935.7322, Expected=3869.8593
# Month=37, Predicted=3868.1801, Expected=3851.2471
# Month=38, Predicted=3850.5233, Expected=3836.7683
# Month=39, Predicted=3837.8906, Expected=3832.0688
# Month=40, Predicted=3833.1316, Expected=3849.7587
# Month=41, Predicted=3851.1567, Expected=3862.2441
# Month=42, Predicted=3863.4633, Expected=3878.6123
# Month=43, Predicted=3879.3439, Expected=3855.0054
# Month=44, Predicted=3854.5859, Expected=3842.4833
# Month=45, Predicted=3842.1070, Expected=3847.2433
# Month=46, Predicted=3848.0629, Expected=3801.1048
# Month=47, Predicted=3800.5633, Expected=3786.6840
# Month=48, Predicted=3786.4620, Expected=3776.0367
# Month=49, Predicted=3777.0150, Expected=3796.7972
# Month=50, Predicted=3798.3639, Expected=3821.0598
# Month=51, Predicted=3822.7933, Expected=3877.3486
# Month=52, Predicted=3879.0106, Expected=3875.8349
# Month=53, Predicted=3876.1152, Expected=3889.3484
# Month=54, Predicted=3888.9831, Expected=3911.1229
# Month=55, Predicted=3911.8214, Expected=3922.9724
# Month=56, Predicted=3923.6035, Expected=3917.9201
# Month=57, Predicted=3917.8268, Expected=3936.3097
# Month=58, Predicted=3936.7717, Expected=3911.1479
# Month=59, Predicted=3910.9686, Expected=3890.6722
# Month=60, Predicted=3890.1522, Expected=3854.8904
# Run 1 — RMSE: 24.248377, MSE: 587.983782, NMSE: 0.0027002096
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3798.6730, Expected=3796.1139
# Month=2, Predicted=3796.7277, Expected=3793.0240
# Month=3, Predicted=3793.6639, Expected=3765.6570
# Month=4, Predicted=3765.5480, Expected=3748.1286
# Month=5, Predicted=3748.0633, Expected=3754.3337
# Month=6, Predicted=3754.5966, Expected=3754.9339
# Month=7, Predicted=3755.0733, Expected=3767.0982
# Month=8, Predicted=3767.6250, Expected=3750.6516
# Month=9, Predicted=3750.6334, Expected=3769.4487
# Month=10, Predicted=3770.2378, Expected=3759.5828
# Month=11, Predicted=3759.6858, Expected=3784.9396
# Month=12, Predicted=3785.8873, Expected=3776.2658
# Month=13, Predicted=3776.4602, Expected=3755.4558
# Month=14, Predicted=3755.4668, Expected=3754.3681
# Month=15, Predicted=3754.6757, Expected=3750.8239
# Month=16, Predicted=3750.9575, Expected=3775.7500
# Month=17, Predicted=3776.5139, Expected=3846.6561
# Month=18, Predicted=3848.1431, Expected=3830.9294
# Month=19, Predicted=3831.1490, Expected=3881.2132
# Month=20, Predicted=3883.0180, Expected=3898.3362
# Month=21, Predicted=3899.2816, Expected=3917.4832
# Month=22, Predicted=3918.6817, Expected=3914.1172
# Month=23, Predicted=3914.7498, Expected=3901.5435
# Month=24, Predicted=3901.8784, Expected=3885.2002
# Month=25, Predicted=3885.2564, Expected=3892.2451
# Month=26, Predicted=3892.6640, Expected=3899.6669
# Month=27, Predicted=3900.0308, Expected=3885.6275
# Month=28, Predicted=3885.6384, Expected=3908.2336
# Month=29, Predicted=3909.0561, Expected=3875.4078
# Month=30, Predicted=3874.9985, Expected=3859.5120
# Month=31, Predicted=3859.4985, Expected=3879.9687
# Month=32, Predicted=3880.5213, Expected=3893.2937
# Month=33, Predicted=3893.7336, Expected=3953.4607
# Month=34, Predicted=3954.9113, Expected=3932.8670
# Month=35, Predicted=3932.9600, Expected=3936.3431
# Month=36, Predicted=3937.1781, Expected=3869.8593
# Month=37, Predicted=3868.8952, Expected=3851.2471
# Month=38, Predicted=3850.9678, Expected=3836.7683
# Month=39, Predicted=3836.2426, Expected=3832.0688
# Month=40, Predicted=3831.8277, Expected=3849.7587
# Month=41, Predicted=3850.1044, Expected=3862.2441
# Month=42, Predicted=3862.6774, Expected=3878.6123
# Month=43, Predicted=3879.3677, Expected=3855.0054
# Month=44, Predicted=3854.9822, Expected=3842.4833
# Month=45, Predicted=3842.6705, Expected=3847.2433
# Month=46, Predicted=3847.6063, Expected=3801.1048
# Month=47, Predicted=3800.3280, Expected=3786.6840
# Month=48, Predicted=3786.4972, Expected=3776.0367
# Month=49, Predicted=3775.7318, Expected=3796.7972
# Month=50, Predicted=3797.2157, Expected=3821.0598
# Month=51, Predicted=3821.6853, Expected=3877.3486
# Month=52, Predicted=3878.7653, Expected=3875.8349
# Month=53, Predicted=3876.4298, Expected=3889.3484
# Month=54, Predicted=3890.4892, Expected=3911.1229
# Month=55, Predicted=3912.2255, Expected=3922.9724
# Month=56, Predicted=3923.8408, Expected=3917.9201
# Month=57, Predicted=3918.4335, Expected=3936.3097
# Month=58, Predicted=3937.2545, Expected=3911.1479
# Month=59, Predicted=3911.0285, Expected=3890.6722
# Month=60, Predicted=3890.6174, Expected=3854.8904
# Run 2 — RMSE: 24.499974, MSE: 600.248748, NMSE: 0.0027355406
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3798.7313, Expected=3796.1139
# Month=2, Predicted=3796.5172, Expected=3793.0240
# Month=3, Predicted=3793.2800, Expected=3765.6570
# Month=4, Predicted=3765.2828, Expected=3748.1286
# Month=5, Predicted=3747.8221, Expected=3754.3337
# Month=6, Predicted=3754.5396, Expected=3754.9339
# Month=7, Predicted=3755.1332, Expected=3767.0982
# Month=8, Predicted=3767.5785, Expected=3750.6516
# Month=9, Predicted=3750.5466, Expected=3769.4487
# Month=10, Predicted=3770.0260, Expected=3759.5828
# Month=11, Predicted=3759.6334, Expected=3784.9396
# Month=12, Predicted=3785.7019, Expected=3776.2658
# Month=13, Predicted=3776.3892, Expected=3755.4558
# Month=14, Predicted=3755.2139, Expected=3754.3681
# Month=15, Predicted=3754.4556, Expected=3750.8239
# Month=16, Predicted=3750.9070, Expected=3775.7500
# Month=17, Predicted=3776.4800, Expected=3846.6561
# Month=18, Predicted=3848.5225, Expected=3830.9294
# Month=19, Predicted=3831.1096, Expected=3881.2132
# Month=20, Predicted=3882.6778, Expected=3898.3362
# Month=21, Predicted=3899.2086, Expected=3917.4832
# Month=22, Predicted=3918.3530, Expected=3914.1172
# Month=23, Predicted=3914.4493, Expected=3901.5435
# Month=24, Predicted=3901.5537, Expected=3885.2002
# Month=25, Predicted=3885.0193, Expected=3892.2451
# Month=26, Predicted=3892.5215, Expected=3899.6669
# Month=27, Predicted=3900.0427, Expected=3885.6275
# Month=28, Predicted=3885.5610, Expected=3908.2336
# Month=29, Predicted=3908.8998, Expected=3875.4078
# Month=30, Predicted=3874.9538, Expected=3859.5120
# Month=31, Predicted=3859.2473, Expected=3879.9687
# Month=32, Predicted=3880.4965, Expected=3893.2937
# Month=33, Predicted=3893.8460, Expected=3953.4607
# Month=34, Predicted=3955.0843, Expected=3932.8670
# Month=35, Predicted=3932.8921, Expected=3936.3431
# Month=36, Predicted=3936.7117, Expected=3869.8593
# Month=37, Predicted=3868.5999, Expected=3851.2471
# Month=38, Predicted=3850.6956, Expected=3836.7683
# Month=39, Predicted=3836.4223, Expected=3832.0688
# Month=40, Predicted=3832.0126, Expected=3849.7587
# Month=41, Predicted=3850.2754, Expected=3862.2441
# Month=42, Predicted=3862.7821, Expected=3878.6123
# Month=43, Predicted=3879.2717, Expected=3855.0054
# Month=44, Predicted=3854.7900, Expected=3842.4833
# Month=45, Predicted=3842.3494, Expected=3847.2433
# Month=46, Predicted=3847.4642, Expected=3801.1048
# Month=47, Predicted=3800.2516, Expected=3786.6840
# Month=48, Predicted=3786.3229, Expected=3776.0367
# Month=49, Predicted=3775.8316, Expected=3796.7972
# Month=50, Predicted=3797.3430, Expected=3821.0598
# Month=51, Predicted=3821.8598, Expected=3877.3486
# Month=52, Predicted=3878.9394, Expected=3875.8349
# Month=53, Predicted=3876.3062, Expected=3889.3484
# Month=54, Predicted=3890.0297, Expected=3911.1229
# Month=55, Predicted=3911.9573, Expected=3922.9724
# Month=56, Predicted=3923.6134, Expected=3917.9201
# Month=57, Predicted=3918.1538, Expected=3936.3097
# Month=58, Predicted=3936.9765, Expected=3911.1479
# Month=59, Predicted=3910.8914, Expected=3890.6722
# Month=60, Predicted=3890.3547, Expected=3854.8904
# Run 3 — RMSE: 24.442212, MSE: 597.421706, NMSE: 0.0027252186
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3799.2858, Expected=3796.1139
# Month=2, Predicted=3797.0545, Expected=3793.0240
# Month=3, Predicted=3793.3539, Expected=3765.6570
# Month=4, Predicted=3764.9836, Expected=3748.1286
# Month=5, Predicted=3747.2352, Expected=3754.3337
# Month=6, Predicted=3754.1336, Expected=3754.9339
# Month=7, Predicted=3755.2078, Expected=3767.0982
# Month=8, Predicted=3767.8986, Expected=3750.6516
# Month=9, Predicted=3750.9726, Expected=3769.4487
# Month=10, Predicted=3770.2123, Expected=3759.5828
# Month=11, Predicted=3759.9437, Expected=3784.9396
# Month=12, Predicted=3785.7772, Expected=3776.2658
# Month=13, Predicted=3776.6424, Expected=3755.4558
# Month=14, Predicted=3755.1059, Expected=3754.3681
# Month=15, Predicted=3754.1912, Expected=3750.8239
# Month=16, Predicted=3750.8234, Expected=3775.7500
# Month=17, Predicted=3776.5610, Expected=3846.6561
# Month=18, Predicted=3848.7708, Expected=3830.9294
# Month=19, Predicted=3831.9101, Expected=3881.2132
# Month=20, Predicted=3882.7284, Expected=3898.3362
# Month=21, Predicted=3899.6000, Expected=3917.4832
# Month=22, Predicted=3918.4331, Expected=3914.1172
# Month=23, Predicted=3914.3403, Expected=3901.5435
# Month=24, Predicted=3901.1407, Expected=3885.2002
# Month=25, Predicted=3884.4797, Expected=3892.2451
# Month=26, Predicted=3892.1253, Expected=3899.6669
# Month=27, Predicted=3900.1148, Expected=3885.6275
# Month=28, Predicted=3885.8149, Expected=3908.2336
# Month=29, Predicted=3909.0814, Expected=3875.4078
# Month=30, Predicted=3875.2243, Expected=3859.5120
# Month=31, Predicted=3859.0535, Expected=3879.9687
# Month=32, Predicted=3880.3584, Expected=3893.2937
# Month=33, Predicted=3894.1639, Expected=3953.4607
# Month=34, Predicted=3955.3575, Expected=3932.8670
# Month=35, Predicted=3933.5454, Expected=3936.3431
# Month=36, Predicted=3936.7068, Expected=3869.8593
# Month=37, Predicted=3868.1283, Expected=3851.2471
# Month=38, Predicted=3849.7531, Expected=3836.7683
# Month=39, Predicted=3835.8420, Expected=3832.0688
# Month=40, Predicted=3831.8848, Expected=3849.7587
# Month=41, Predicted=3850.6285, Expected=3862.2441
# Month=42, Predicted=3863.5803, Expected=3878.6123
# Month=43, Predicted=3880.0414, Expected=3855.0054
# Month=44, Predicted=3855.2459, Expected=3842.4833
# Month=45, Predicted=3842.2156, Expected=3847.2433
# Month=46, Predicted=3847.2089, Expected=3801.1048
# Month=47, Predicted=3799.9157, Expected=3786.6840
# Month=48, Predicted=3785.7711, Expected=3776.0367
# Month=49, Predicted=3775.6384, Expected=3796.7972
# Month=50, Predicted=3797.4913, Expected=3821.0598
# Month=51, Predicted=3822.5469, Expected=3877.3486
# Month=52, Predicted=3879.6233, Expected=3875.8349
# Month=53, Predicted=3877.2112, Expected=3889.3484
# Month=54, Predicted=3890.2772, Expected=3911.1229
# Month=55, Predicted=3911.9866, Expected=3922.9724
# Month=56, Predicted=3923.5773, Expected=3917.9201
# Month=57, Predicted=3917.9688, Expected=3936.3097
# Month=58, Predicted=3936.7112, Expected=3911.1479
# Month=59, Predicted=3910.7436, Expected=3890.6722
# Month=60, Predicted=3889.9471, Expected=3854.8904
# Run 4 — RMSE: 24.334654, MSE: 592.175370, NMSE: 0.0026985053
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3797.8531, Expected=3796.1139
# Month=2, Predicted=3796.3515, Expected=3793.0240
# Month=3, Predicted=3793.2615, Expected=3765.6570
# Month=4, Predicted=3765.8945, Expected=3748.1286
# Month=5, Predicted=3748.3662, Expected=3754.3337
# Month=6, Predicted=3754.5713, Expected=3754.9339
# Month=7, Predicted=3755.1715, Expected=3767.0982
# Month=8, Predicted=3767.3357, Expected=3750.6516
# Month=9, Predicted=3750.8892, Expected=3769.4487
# Month=10, Predicted=3769.6863, Expected=3759.5828
# Month=11, Predicted=3759.8203, Expected=3784.9396
# Month=12, Predicted=3785.1771, Expected=3776.2658
# Month=13, Predicted=3776.5034, Expected=3755.4558
# Month=14, Predicted=3755.6933, Expected=3754.3681
# Month=15, Predicted=3754.6057, Expected=3750.8239
# Month=16, Predicted=3751.0615, Expected=3775.7500
# Month=17, Predicted=3775.9875, Expected=3846.6561
# Month=18, Predicted=3846.8936, Expected=3830.9294
# Month=19, Predicted=3831.1669, Expected=3881.2132
# Month=20, Predicted=3881.4507, Expected=3898.3362
# Month=21, Predicted=3898.5738, Expected=3917.4832
# Month=22, Predicted=3917.7207, Expected=3914.1172
# Month=23, Predicted=3914.3547, Expected=3901.5435
# Month=24, Predicted=3901.7811, Expected=3885.2002
# Month=25, Predicted=3885.4377, Expected=3892.2451
# Month=26, Predicted=3892.4826, Expected=3899.6669
# Month=27, Predicted=3899.9045, Expected=3885.6275
# Month=28, Predicted=3885.8650, Expected=3908.2336
# Month=29, Predicted=3908.4712, Expected=3875.4078
# Month=30, Predicted=3875.6453, Expected=3859.5120
# Month=31, Predicted=3859.7496, Expected=3879.9687
# Month=32, Predicted=3880.2062, Expected=3893.2937
# Month=33, Predicted=3893.5313, Expected=3953.4607
# Month=34, Predicted=3953.6983, Expected=3932.8670
# Month=35, Predicted=3933.1046, Expected=3936.3431
# Month=36, Predicted=3936.5807, Expected=3869.8593
# Month=37, Predicted=3870.0969, Expected=3851.2471
# Month=38, Predicted=3851.4847, Expected=3836.7683
# Month=39, Predicted=3837.0059, Expected=3832.0688
# Month=40, Predicted=3832.3064, Expected=3849.7587
# Month=41, Predicted=3849.9963, Expected=3862.2441
# Month=42, Predicted=3862.4817, Expected=3878.6123
# Month=43, Predicted=3878.8499, Expected=3855.0054
# Month=44, Predicted=3855.2429, Expected=3842.4833
# Month=45, Predicted=3842.7209, Expected=3847.2433
# Month=46, Predicted=3847.4808, Expected=3801.1048
# Month=47, Predicted=3801.3423, Expected=3786.6840
# Month=48, Predicted=3786.9216, Expected=3776.0367
# Month=49, Predicted=3776.2743, Expected=3796.7972
# Month=50, Predicted=3797.0347, Expected=3821.0598
# Month=51, Predicted=3821.2973, Expected=3877.3486
# Month=52, Predicted=3877.5861, Expected=3875.8349
# Month=53, Predicted=3876.0725, Expected=3889.3484
# Month=54, Predicted=3889.5859, Expected=3911.1229
# Month=55, Predicted=3911.3604, Expected=3922.9724
# Month=56, Predicted=3923.2099, Expected=3917.9201
# Month=57, Predicted=3918.1576, Expected=3936.3097
# Month=58, Predicted=3936.5473, Expected=3911.1479
# Month=59, Predicted=3911.3855, Expected=3890.6722
# Month=60, Predicted=3890.9097, Expected=3854.8904
# Run 5 — RMSE: 24.508291, MSE: 600.656311, NMSE: 0.0027536180
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3797.9469, Expected=3796.1139
# Month=2, Predicted=3796.4465, Expected=3793.0240
# Month=3, Predicted=3793.3564, Expected=3765.6570
# Month=4, Predicted=3765.9843, Expected=3748.1286
# Month=5, Predicted=3748.4565, Expected=3754.3337
# Month=6, Predicted=3754.6668, Expected=3754.9339
# Month=7, Predicted=3755.2651, Expected=3767.0982
# Month=8, Predicted=3767.4299, Expected=3750.6516
# Month=9, Predicted=3750.9800, Expected=3769.4487
# Month=10, Predicted=3769.7812, Expected=3759.5828
# Month=11, Predicted=3759.9127, Expected=3784.9396
# Month=12, Predicted=3785.2713, Expected=3776.2658
# Month=13, Predicted=3776.5966, Expected=3755.4558
# Month=14, Predicted=3755.7835, Expected=3754.3681
# Month=15, Predicted=3754.6996, Expected=3750.8239
# Month=16, Predicted=3751.1544, Expected=3775.7500
# Month=17, Predicted=3776.0817, Expected=3846.6561
# Month=18, Predicted=3847.0114, Expected=3830.9294
# Month=19, Predicted=3831.2626, Expected=3881.2132
# Month=20, Predicted=3881.5521, Expected=3898.3362
# Month=21, Predicted=3898.6690, Expected=3917.4832
# Month=22, Predicted=3917.8150, Expected=3914.1172
# Month=23, Predicted=3914.4502, Expected=3901.5435
# Month=24, Predicted=3901.8741, Expected=3885.2002
# Month=25, Predicted=3885.5289, Expected=3892.2451
# Month=26, Predicted=3892.5784, Expected=3899.6669
# Month=27, Predicted=3899.9990, Expected=3885.6275
# Month=28, Predicted=3885.9562, Expected=3908.2336
# Month=29, Predicted=3908.5662, Expected=3875.4078
# Month=30, Predicted=3875.7338, Expected=3859.5120
# Month=31, Predicted=3859.8404, Expected=3879.9687
# Month=32, Predicted=3880.3028, Expected=3893.2937
# Month=33, Predicted=3893.6253, Expected=3953.4607
# Month=34, Predicted=3953.8065, Expected=3932.8670
# Month=35, Predicted=3933.1987, Expected=3936.3431
# Month=36, Predicted=3936.6765, Expected=3869.8593
# Month=37, Predicted=3870.1899, Expected=3851.2471
# Month=38, Predicted=3851.5786, Expected=3836.7683
# Month=39, Predicted=3837.0974, Expected=3832.0688
# Month=40, Predicted=3832.4001, Expected=3849.7587
# Month=41, Predicted=3850.0929, Expected=3862.2441
# Month=42, Predicted=3862.5757, Expected=3878.6123
# Month=43, Predicted=3878.9433, Expected=3855.0054
# Month=44, Predicted=3855.3335, Expected=3842.4833
# Month=45, Predicted=3842.8125, Expected=3847.2433
# Month=46, Predicted=3847.5757, Expected=3801.1048
# Month=47, Predicted=3801.4275, Expected=3786.6840
# Month=48, Predicted=3787.0133, Expected=3776.0367
# Month=49, Predicted=3776.3654, Expected=3796.7972
# Month=50, Predicted=3797.1312, Expected=3821.0598
# Month=51, Predicted=3821.3909, Expected=3877.3486
# Month=52, Predicted=3877.6913, Expected=3875.8349
# Month=53, Predicted=3876.1682, Expected=3889.3484
# Month=54, Predicted=3889.6803, Expected=3911.1229
# Month=55, Predicted=3911.4541, Expected=3922.9724
# Month=56, Predicted=3923.3041, Expected=3917.9201
# Month=57, Predicted=3918.2524, Expected=3936.3097
# Month=58, Predicted=3936.6415, Expected=3911.1479
# Month=59, Predicted=3911.4764, Expected=3890.6722
# Month=60, Predicted=3890.9997, Expected=3854.8904
# Run 6 — RMSE: 24.505906, MSE: 600.539451, NMSE: 0.0027530772
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3798.8045, Expected=3796.1139
# Month=2, Predicted=3795.7927, Expected=3793.0240
# Month=3, Predicted=3792.4453, Expected=3765.6570
# Month=4, Predicted=3765.2169, Expected=3748.1286
# Month=5, Predicted=3747.9199, Expected=3754.3337
# Month=6, Predicted=3755.5051, Expected=3754.9339
# Month=7, Predicted=3755.9734, Expected=3767.0982
# Month=8, Predicted=3767.7679, Expected=3750.6516
# Month=9, Predicted=3750.7134, Expected=3769.4487
# Month=10, Predicted=3769.7947, Expected=3759.5828
# Month=11, Predicted=3760.3030, Expected=3784.9396
# Month=12, Predicted=3785.2624, Expected=3776.2658
# Month=13, Predicted=3776.8885, Expected=3755.4558
# Month=14, Predicted=3754.5979, Expected=3754.3681
# Month=15, Predicted=3754.8171, Expected=3750.8239
# Month=16, Predicted=3751.6628, Expected=3775.7500
# Month=17, Predicted=3776.7911, Expected=3846.6561
# Month=18, Predicted=3848.7889, Expected=3830.9294
# Month=19, Predicted=3830.8217, Expected=3881.2132
# Month=20, Predicted=3880.6876, Expected=3898.3362
# Month=21, Predicted=3899.5666, Expected=3917.4832
# Month=22, Predicted=3916.9686, Expected=3914.1172
# Month=23, Predicted=3913.9111, Expected=3901.5435
# Month=24, Predicted=3901.0337, Expected=3885.2002
# Month=25, Predicted=3885.1561, Expected=3892.2451
# Month=26, Predicted=3893.0366, Expected=3899.6669
# Month=27, Predicted=3900.8699, Expected=3885.6275
# Month=28, Predicted=3885.5625, Expected=3908.2336
# Month=29, Predicted=3908.8849, Expected=3875.4078
# Month=30, Predicted=3875.2717, Expected=3859.5120
# Month=31, Predicted=3858.7288, Expected=3879.9687
# Month=32, Predicted=3881.6721, Expected=3893.2937
# Month=33, Predicted=3894.7634, Expected=3953.4607
# Month=34, Predicted=3954.5955, Expected=3932.8670
# Month=35, Predicted=3932.7925, Expected=3936.3431
# Month=36, Predicted=3935.3003, Expected=3869.8593
# Month=37, Predicted=3868.5248, Expected=3851.2471
# Month=38, Predicted=3850.4706, Expected=3836.7683
# Month=39, Predicted=3838.2549, Expected=3832.0688
# Month=40, Predicted=3832.5262, Expected=3849.7587
# Month=41, Predicted=3851.2195, Expected=3862.2441
# Month=42, Predicted=3863.4595, Expected=3878.6123
# Month=43, Predicted=3879.1070, Expected=3855.0054
# Month=44, Predicted=3854.4915, Expected=3842.4833
# Month=45, Predicted=3841.9569, Expected=3847.2433
# Month=46, Predicted=3848.2646, Expected=3801.1048
# Month=47, Predicted=3800.2649, Expected=3786.6840
# Month=48, Predicted=3786.1591, Expected=3776.0367
# Month=49, Predicted=3777.2159, Expected=3796.7972
# Month=50, Predicted=3797.9816, Expected=3821.0598
# Month=51, Predicted=3822.9070, Expected=3877.3486
# Month=52, Predicted=3878.5504, Expected=3875.8349
# Month=53, Predicted=3875.9578, Expected=3889.3484
# Month=54, Predicted=3888.5689, Expected=3911.1229
# Month=55, Predicted=3911.8663, Expected=3922.9724
# Month=56, Predicted=3923.2035, Expected=3917.9201
# Month=57, Predicted=3917.6249, Expected=3936.3097
# Month=58, Predicted=3936.6940, Expected=3911.1479
# Month=59, Predicted=3910.9689, Expected=3890.6722
# Month=60, Predicted=3889.9819, Expected=3854.8904
# Run 7 — RMSE: 24.249332, MSE: 588.030092, NMSE: 0.0027029604
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3798.0193, Expected=3796.1139
# Month=2, Predicted=3796.4710, Expected=3793.0240
# Month=3, Predicted=3793.3897, Expected=3765.6570
# Month=4, Predicted=3765.9962, Expected=3748.1286
# Month=5, Predicted=3748.4842, Expected=3754.3337
# Month=6, Predicted=3754.7216, Expected=3754.9339
# Month=7, Predicted=3755.3045, Expected=3767.0982
# Month=8, Predicted=3767.4859, Expected=3750.6516
# Month=9, Predicted=3750.9960, Expected=3769.4487
# Month=10, Predicted=3769.8509, Expected=3759.5828
# Month=11, Predicted=3759.9345, Expected=3784.9396
# Month=12, Predicted=3785.3464, Expected=3776.2658
# Month=13, Predicted=3776.6171, Expected=3755.4558
# Month=14, Predicted=3755.8004, Expected=3754.3681
# Month=15, Predicted=3754.7449, Expected=3750.8239
# Month=16, Predicted=3751.1907, Expected=3775.7500
# Month=17, Predicted=3776.1540, Expected=3846.6561
# Month=18, Predicted=3847.0603, Expected=3830.9294
# Month=19, Predicted=3831.2619, Expected=3881.2132
# Month=20, Predicted=3881.6373, Expected=3898.3362
# Month=21, Predicted=3898.7239, Expected=3917.4832
# Month=22, Predicted=3917.8793, Expected=3914.1172
# Month=23, Predicted=3914.4788, Expected=3901.5435
# Month=24, Predicted=3901.8984, Expected=3885.2002
# Month=25, Predicted=3885.5537, Expected=3892.2451
# Month=26, Predicted=3892.6352, Expected=3899.6669
# Month=27, Predicted=3900.0491, Expected=3885.6275
# Month=28, Predicted=3885.9766, Expected=3908.2336
# Month=29, Predicted=3908.6411, Expected=3875.4078
# Month=30, Predicted=3875.7401, Expected=3859.5120
# Month=31, Predicted=3859.8709, Expected=3879.9687
# Month=32, Predicted=3880.3750, Expected=3893.2937
# Month=33, Predicted=3893.6785, Expected=3953.4607
# Month=34, Predicted=3953.8729, Expected=3932.8670
# Month=35, Predicted=3933.1974, Expected=3936.3431
# Month=36, Predicted=3936.7258, Expected=3869.8593
# Month=37, Predicted=3870.2339, Expected=3851.2471
# Month=38, Predicted=3851.6147, Expected=3836.7683
# Month=39, Predicted=3837.1285, Expected=3832.0688
# Month=40, Predicted=3832.4381, Expected=3849.7587
# Month=41, Predicted=3850.1543, Expected=3862.2441
# Month=42, Predicted=3862.6256, Expected=3878.6123
# Month=43, Predicted=3878.9997, Expected=3855.0054
# Month=44, Predicted=3855.3418, Expected=3842.4833
# Month=45, Predicted=3842.8416, Expected=3847.2433
# Month=46, Predicted=3847.6248, Expected=3801.1048
# Month=47, Predicted=3801.4467, Expected=3786.6840
# Month=48, Predicted=3787.0482, Expected=3776.0367
# Month=49, Predicted=3776.3980, Expected=3796.7972
# Month=50, Predicted=3797.1972, Expected=3821.0598
# Month=51, Predicted=3821.4548, Expected=3877.3486
# Month=52, Predicted=3877.7592, Expected=3875.8349
# Month=53, Predicted=3876.1860, Expected=3889.3484
# Month=54, Predicted=3889.7373, Expected=3911.1229
# Month=55, Predicted=3911.5208, Expected=3922.9724
# Month=56, Predicted=3923.3543, Expected=3917.9201
# Month=57, Predicted=3918.2794, Expected=3936.3097
# Month=58, Predicted=3936.7094, Expected=3911.1479
# Month=59, Predicted=3911.4847, Expected=3890.6722
# Month=60, Predicted=3891.0229, Expected=3854.8904
# Run 8 — RMSE: 24.503667, MSE: 600.429713, NMSE: 0.0027523634
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3801.5532, Expected=3796.1139
# Month=2, Predicted=3793.5004, Expected=3793.0240
# Month=3, Predicted=3794.4474, Expected=3765.6570
# Month=4, Predicted=3759.6598, Expected=3748.1286
# Month=5, Predicted=3748.8717, Expected=3754.3337
# Month=6, Predicted=3756.0926, Expected=3754.9339
# Month=7, Predicted=3757.3455, Expected=3767.0982
# Month=8, Predicted=3769.5431, Expected=3750.6516
# Month=9, Predicted=3753.2534, Expected=3769.4487
# Month=10, Predicted=3768.9318, Expected=3759.5828
# Month=11, Predicted=3762.7579, Expected=3784.9396
# Month=12, Predicted=3787.8432, Expected=3776.2658
# Month=13, Predicted=3775.0251, Expected=3755.4558
# Month=14, Predicted=3755.5514, Expected=3754.3681
# Month=15, Predicted=3755.7751, Expected=3750.8239
# Month=16, Predicted=3748.6788, Expected=3775.7500
# Month=17, Predicted=3777.5017, Expected=3846.6561
# Month=18, Predicted=3847.4375, Expected=3830.9294
# Month=19, Predicted=3821.2681, Expected=3881.2132
# Month=20, Predicted=3877.2304, Expected=3898.3362
# Month=21, Predicted=3896.8973, Expected=3917.4832
# Month=22, Predicted=3920.2430, Expected=3914.1172
# Month=23, Predicted=3910.9149, Expected=3901.5435
# Month=24, Predicted=3900.5161, Expected=3885.2002
# Month=25, Predicted=3882.6961, Expected=3892.2451
# Month=26, Predicted=3894.0898, Expected=3899.6669
# Month=27, Predicted=3901.6402, Expected=3885.6275
# Month=28, Predicted=3886.5423, Expected=3908.2336
# Month=29, Predicted=3906.4710, Expected=3875.4078
# Month=30, Predicted=3872.5135, Expected=3859.5120
# Month=31, Predicted=3862.4285, Expected=3879.9687
# Month=32, Predicted=3880.3969, Expected=3893.2937
# Month=33, Predicted=3898.5793, Expected=3953.4607
# Month=34, Predicted=3955.2025, Expected=3932.8670
# Month=35, Predicted=3926.9707, Expected=3936.3431
# Month=36, Predicted=3938.8557, Expected=3869.8593
# Month=37, Predicted=3857.3792, Expected=3851.2471
# Month=38, Predicted=3847.7544, Expected=3836.7683
# Month=39, Predicted=3835.9491, Expected=3832.0688
# Month=40, Predicted=3831.6288, Expected=3849.7587
# Month=41, Predicted=3848.3099, Expected=3862.2441
# Month=42, Predicted=3865.9535, Expected=3878.6123
# Month=43, Predicted=3882.7054, Expected=3855.0054
# Month=44, Predicted=3858.3405, Expected=3842.4833
# Month=45, Predicted=3846.7330, Expected=3847.2433
# Month=46, Predicted=3850.3790, Expected=3801.1048
# Month=47, Predicted=3793.1241, Expected=3786.6840
# Month=48, Predicted=3786.9787, Expected=3776.0367
# Month=49, Predicted=3773.4324, Expected=3796.7972
# Month=50, Predicted=3795.7156, Expected=3821.0598
# Month=51, Predicted=3824.4650, Expected=3877.3486
# Month=52, Predicted=3877.1929, Expected=3875.8349
# Month=53, Predicted=3874.1557, Expected=3889.3484
# Month=54, Predicted=3893.2788, Expected=3911.1229
# Month=55, Predicted=3913.5914, Expected=3922.9724
# Month=56, Predicted=3923.1904, Expected=3917.9201
# Month=57, Predicted=3915.8206, Expected=3936.3097
# Month=58, Predicted=3937.9264, Expected=3911.1479
# Month=59, Predicted=3901.2596, Expected=3890.6722
# Month=60, Predicted=3891.7703, Expected=3854.8904
# Run 9 — RMSE: 24.498832, MSE: 600.192755, NMSE: 0.0027625773
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3799.0361, Expected=3796.1139
# Month=2, Predicted=3795.9088, Expected=3793.0240
# Month=3, Predicted=3794.7031, Expected=3765.6570
# Month=4, Predicted=3765.0048, Expected=3748.1286
# Month=5, Predicted=3749.5282, Expected=3754.3337
# Month=6, Predicted=3755.5061, Expected=3754.9339
# Month=7, Predicted=3756.1621, Expected=3767.0982
# Month=8, Predicted=3768.5490, Expected=3750.6516
# Month=9, Predicted=3749.9382, Expected=3769.4487
# Month=10, Predicted=3769.9600, Expected=3759.5828
# Month=11, Predicted=3759.2169, Expected=3784.9396
# Month=12, Predicted=3785.1658, Expected=3776.2658
# Month=13, Predicted=3775.5916, Expected=3755.4558
# Month=14, Predicted=3756.0830, Expected=3754.3681
# Month=15, Predicted=3755.8966, Expected=3750.8239
# Month=16, Predicted=3752.1045, Expected=3775.7500
# Month=17, Predicted=3776.2150, Expected=3846.6561
# Month=18, Predicted=3844.1200, Expected=3830.9294
# Month=19, Predicted=3824.5608, Expected=3881.2132
# Month=20, Predicted=3878.4604, Expected=3898.3362
# Month=21, Predicted=3899.5519, Expected=3917.4832
# Month=22, Predicted=3919.3619, Expected=3914.1172
# Month=23, Predicted=3914.6868, Expected=3901.5435
# Month=24, Predicted=3902.6210, Expected=3885.2002
# Month=25, Predicted=3886.2576, Expected=3892.2451
# Month=26, Predicted=3893.5472, Expected=3899.6669
# Month=27, Predicted=3901.1962, Expected=3885.6275
# Month=28, Predicted=3885.6684, Expected=3908.2336
# Month=29, Predicted=3908.4898, Expected=3875.4078
# Month=30, Predicted=3871.2689, Expected=3859.5120
# Month=31, Predicted=3861.0250, Expected=3879.9687
# Month=32, Predicted=3880.2439, Expected=3893.2937
# Month=33, Predicted=3894.7964, Expected=3953.4607
# Month=34, Predicted=3951.2303, Expected=3932.8670
# Month=35, Predicted=3926.7059, Expected=3936.3431
# Month=36, Predicted=3937.9195, Expected=3869.8593
# Month=37, Predicted=3864.6779, Expected=3851.2471
# Month=38, Predicted=3852.0383, Expected=3836.7683
# Month=39, Predicted=3837.3733, Expected=3832.0688
# Month=40, Predicted=3833.0702, Expected=3849.7587
# Month=41, Predicted=3850.3951, Expected=3862.2441
# Month=42, Predicted=3863.6228, Expected=3878.6123
# Month=43, Predicted=3880.1699, Expected=3855.0054
# Month=44, Predicted=3852.7989, Expected=3842.4833
# Month=45, Predicted=3844.0025, Expected=3847.2433
# Month=46, Predicted=3848.6551, Expected=3801.1048
# Month=47, Predicted=3797.2782, Expected=3786.6840
# Month=48, Predicted=3787.7909, Expected=3776.0367
# Month=49, Predicted=3776.8889, Expected=3796.7972
# Month=50, Predicted=3796.9403, Expected=3821.0598
# Month=51, Predicted=3822.2977, Expected=3877.3486
# Month=52, Predicted=3876.1133, Expected=3875.8349
# Month=53, Predicted=3873.3394, Expected=3889.3484
# Month=54, Predicted=3890.9995, Expected=3911.1229
# Month=55, Predicted=3912.8169, Expected=3922.9724
# Month=56, Predicted=3924.6791, Expected=3917.9201
# Month=57, Predicted=3918.7968, Expected=3936.3097
# Month=58, Predicted=3937.5747, Expected=3911.1479
# Month=59, Predicted=3908.5915, Expected=3890.6722
# Month=60, Predicted=3892.0156, Expected=3854.8904
# Run 10 — RMSE: 24.616217, MSE: 605.958164, NMSE: 0.0027947432
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3796.8847, Expected=3796.1139
# Month=2, Predicted=3797.2219, Expected=3793.0240
# Month=3, Predicted=3793.4823, Expected=3765.6570
# Month=4, Predicted=3761.9532, Expected=3748.1286
# Month=5, Predicted=3746.4247, Expected=3754.3337
# Month=6, Predicted=3756.3067, Expected=3754.9339
# Month=7, Predicted=3756.6428, Expected=3767.0982
# Month=8, Predicted=3769.3577, Expected=3750.6516
# Month=9, Predicted=3750.2316, Expected=3769.4487
# Month=10, Predicted=3771.4063, Expected=3759.5828
# Month=11, Predicted=3759.8628, Expected=3784.9396
# Month=12, Predicted=3786.0977, Expected=3776.2658
# Month=13, Predicted=3776.4437, Expected=3755.4558
# Month=14, Predicted=3753.5915, Expected=3754.3681
# Month=15, Predicted=3755.5169, Expected=3750.8239
# Month=16, Predicted=3751.8339, Expected=3775.7500
# Month=17, Predicted=3776.9023, Expected=3846.6561
# Month=18, Predicted=3834.5664, Expected=3830.9294
# Month=19, Predicted=3829.8434, Expected=3881.2132
# Month=20, Predicted=3876.0539, Expected=3898.3362
# Month=21, Predicted=3900.6191, Expected=3917.4832
# Month=22, Predicted=3919.7275, Expected=3914.1172
# Month=23, Predicted=3913.8556, Expected=3901.5435
# Month=24, Predicted=3899.5136, Expected=3885.2002
# Month=25, Predicted=3882.9907, Expected=3892.2451
# Month=26, Predicted=3894.0977, Expected=3899.6669
# Month=27, Predicted=3901.7386, Expected=3885.6275
# Month=28, Predicted=3885.1640, Expected=3908.2336
# Month=29, Predicted=3909.8104, Expected=3875.4078
# Month=30, Predicted=3872.5445, Expected=3859.5120
# Month=31, Predicted=3858.9202, Expected=3879.9687
# Month=32, Predicted=3881.7722, Expected=3893.2937
# Month=33, Predicted=3895.5348, Expected=3953.4607
# Month=34, Predicted=3944.0946, Expected=3932.8670
# Month=35, Predicted=3930.9710, Expected=3936.3431
# Month=36, Predicted=3937.9328, Expected=3869.8593
# Month=37, Predicted=3864.6758, Expected=3851.2471
# Month=38, Predicted=3849.9252, Expected=3836.7683
# Month=39, Predicted=3836.9289, Expected=3832.0688
# Month=40, Predicted=3833.7081, Expected=3849.7587
# Month=41, Predicted=3851.3151, Expected=3862.2441
# Month=42, Predicted=3864.3055, Expected=3878.6123
# Month=43, Predicted=3880.4821, Expected=3855.0054
# Month=44, Predicted=3853.5947, Expected=3842.4833
# Month=45, Predicted=3842.3319, Expected=3847.2433
# Month=46, Predicted=3849.2067, Expected=3801.1048
# Month=47, Predicted=3797.7775, Expected=3786.6840
# Month=48, Predicted=3786.7433, Expected=3776.0367
# Month=49, Predicted=3776.9501, Expected=3796.7972
# Month=50, Predicted=3798.0550, Expected=3821.0598
# Month=51, Predicted=3821.5544, Expected=3877.3486
# Month=52, Predicted=3868.2872, Expected=3875.8349
# Month=53, Predicted=3877.3879, Expected=3889.3484
# Month=54, Predicted=3891.6611, Expected=3911.1229
# Month=55, Predicted=3913.1406, Expected=3922.9724
# Month=56, Predicted=3925.1401, Expected=3917.9201
# Month=57, Predicted=3917.6927, Expected=3936.3097
# Month=58, Predicted=3938.5556, Expected=3911.1479
# Month=59, Predicted=3907.6669, Expected=3890.6722
# Month=60, Predicted=3888.4488, Expected=3854.8904
# Run 11 — RMSE: 24.162220, MSE: 583.812897, NMSE: 0.0027004509
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3798.0295, Expected=3796.1139
# Month=2, Predicted=3796.4668, Expected=3793.0240
# Month=3, Predicted=3793.3658, Expected=3765.6570
# Month=4, Predicted=3765.9507, Expected=3748.1286
# Month=5, Predicted=3748.4495, Expected=3754.3337
# Month=6, Predicted=3754.6998, Expected=3754.9339
# Month=7, Predicted=3755.2925, Expected=3767.0982
# Month=8, Predicted=3767.4738, Expected=3750.6516
# Month=9, Predicted=3750.9757, Expected=3769.4487
# Month=10, Predicted=3769.8324, Expected=3759.5828
# Month=11, Predicted=3759.9224, Expected=3784.9396
# Month=12, Predicted=3785.3318, Expected=3776.2658
# Month=13, Predicted=3776.6084, Expected=3755.4558
# Month=14, Predicted=3755.7663, Expected=3754.3681
# Month=15, Predicted=3754.7203, Expected=3750.8239
# Month=16, Predicted=3751.1730, Expected=3775.7500
# Month=17, Predicted=3776.1439, Expected=3846.6561
# Month=18, Predicted=3847.1076, Expected=3830.9294
# Month=19, Predicted=3831.2746, Expected=3881.2132
# Month=20, Predicted=3881.6285, Expected=3898.3362
# Month=21, Predicted=3898.7330, Expected=3917.4832
# Month=22, Predicted=3917.8613, Expected=3914.1172
# Month=23, Predicted=3914.4595, Expected=3901.5435
# Month=24, Predicted=3901.8664, Expected=3885.2002
# Month=25, Predicted=3885.5189, Expected=3892.2451
# Month=26, Predicted=3892.6103, Expected=3899.6669
# Month=27, Predicted=3900.0360, Expected=3885.6275
# Month=28, Predicted=3885.9554, Expected=3908.2336
# Month=29, Predicted=3908.6228, Expected=3875.4078
# Month=30, Predicted=3875.6967, Expected=3859.5120
# Month=31, Predicted=3859.8387, Expected=3879.9687
# Month=32, Predicted=3880.3570, Expected=3893.2937
# Month=33, Predicted=3893.6774, Expected=3953.4607
# Month=34, Predicted=3953.8966, Expected=3932.8670
# Month=35, Predicted=3933.1961, Expected=3936.3431
# Month=36, Predicted=3936.6969, Expected=3869.8593
# Month=37, Predicted=3870.0441, Expected=3851.2471
# Month=38, Predicted=3851.5821, Expected=3836.7683
# Month=39, Predicted=3837.1003, Expected=3832.0688
# Month=40, Predicted=3832.4194, Expected=3849.7587
# Month=41, Predicted=3850.1454, Expected=3862.2441
# Month=42, Predicted=3862.6255, Expected=3878.6123
# Month=43, Predicted=3878.9951, Expected=3855.0054
# Month=44, Predicted=3855.3119, Expected=3842.4833
# Month=45, Predicted=3842.8132, Expected=3847.2433
# Month=46, Predicted=3847.6059, Expected=3801.1048
# Month=47, Predicted=3801.3575, Expected=3786.6840
# Month=48, Predicted=3787.0203, Expected=3776.0367
# Month=49, Predicted=3776.3759, Expected=3796.7972
# Month=50, Predicted=3797.1878, Expected=3821.0598
# Month=51, Predicted=3821.4603, Expected=3877.3486
# Month=52, Predicted=3877.7842, Expected=3875.8349
# Month=53, Predicted=3876.1997, Expected=3889.3484
# Month=54, Predicted=3889.7163, Expected=3911.1229
# Month=55, Predicted=3911.5091, Expected=3922.9724
# Month=56, Predicted=3923.3454, Expected=3917.9201
# Month=57, Predicted=3918.2601, Expected=3936.3097
# Month=58, Predicted=3936.6892, Expected=3911.1479
# Month=59, Predicted=3911.4503, Expected=3890.6722
# Month=60, Predicted=3890.9855, Expected=3854.8904
# Run 12 — RMSE: 24.496799, MSE: 600.093149, NMSE: 0.0027506302
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3798.3496, Expected=3796.1139
# Month=2, Predicted=3796.3115, Expected=3793.0240
# Month=3, Predicted=3793.2347, Expected=3765.6570
# Month=4, Predicted=3765.4511, Expected=3748.1286
# Month=5, Predicted=3748.0546, Expected=3754.3337
# Month=6, Predicted=3754.6107, Expected=3754.9339
# Month=7, Predicted=3755.0893, Expected=3767.0982
# Month=8, Predicted=3767.4666, Expected=3750.6516
# Month=9, Predicted=3750.5599, Expected=3769.4487
# Month=10, Predicted=3769.9677, Expected=3759.5828
# Month=11, Predicted=3759.6019, Expected=3784.9396
# Month=12, Predicted=3785.5704, Expected=3776.2658
# Month=13, Predicted=3776.3143, Expected=3755.4558
# Month=14, Predicted=3755.3336, Expected=3754.3681
# Month=15, Predicted=3754.5603, Expected=3750.8239
# Month=16, Predicted=3750.9400, Expected=3775.7500
# Month=17, Predicted=3776.3413, Expected=3846.6561
# Month=18, Predicted=3848.0501, Expected=3830.9294
# Month=19, Predicted=3830.8524, Expected=3881.2132
# Month=20, Predicted=3882.3269, Expected=3898.3362
# Month=21, Predicted=3898.8297, Expected=3917.4832
# Month=22, Predicted=3918.0507, Expected=3914.1172
# Month=23, Predicted=3914.3177, Expected=3901.5435
# Month=24, Predicted=3901.5949, Expected=3885.2002
# Month=25, Predicted=3885.1606, Expected=3892.2451
# Month=26, Predicted=3892.5634, Expected=3899.6669
# Month=27, Predicted=3899.9583, Expected=3885.6275
# Month=28, Predicted=3885.5747, Expected=3908.2336
# Month=29, Predicted=3908.8092, Expected=3875.4078
# Month=30, Predicted=3875.0481, Expected=3859.5120
# Month=31, Predicted=3859.4516, Expected=3879.9687
# Month=32, Predicted=3880.4764, Expected=3893.2937
# Month=33, Predicted=3893.6549, Expected=3953.4607
# Month=34, Predicted=3954.6624, Expected=3932.8670
# Month=35, Predicted=3932.7195, Expected=3936.3431
# Month=36, Predicted=3936.6573, Expected=3869.8593
# Month=37, Predicted=3869.0625, Expected=3851.2471
# Month=38, Predicted=3851.1219, Expected=3836.7683
# Month=39, Predicted=3836.6067, Expected=3832.0688
# Month=40, Predicted=3832.0693, Expected=3849.7587
# Month=41, Predicted=3850.1503, Expected=3862.2441
# Month=42, Predicted=3862.5722, Expected=3878.6123
# Month=43, Predicted=3879.0553, Expected=3855.0054
# Month=44, Predicted=3854.8249, Expected=3842.4833
# Month=45, Predicted=3842.5039, Expected=3847.2433
# Month=46, Predicted=3847.5163, Expected=3801.1048
# Month=47, Predicted=3800.5182, Expected=3786.6840
# Month=48, Predicted=3786.6167, Expected=3776.0367
# Month=49, Predicted=3775.9744, Expected=3796.7972
# Month=50, Predicted=3797.2607, Expected=3821.0598
# Month=51, Predicted=3821.5843, Expected=3877.3486
# Month=52, Predicted=3878.4711, Expected=3875.8349
# Month=53, Predicted=3876.0064, Expected=3889.3484
# Month=54, Predicted=3889.8373, Expected=3911.1229
# Month=55, Predicted=3911.7347, Expected=3922.9724
# Month=56, Predicted=3923.4099, Expected=3917.9201
# Month=57, Predicted=3918.0877, Expected=3936.3097
# Month=58, Predicted=3936.8642, Expected=3911.1479
# Month=59, Predicted=3910.9565, Expected=3890.6722
# Month=60, Predicted=3890.5578, Expected=3854.8904
# Run 13 — RMSE: 24.483816, MSE: 599.457253, NMSE: 0.0027400388
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3798.5868, Expected=3796.1139
# Month=2, Predicted=3796.5941, Expected=3793.0240
# Month=3, Predicted=3793.2272, Expected=3765.6570
# Month=4, Predicted=3765.4459, Expected=3748.1286
# Month=5, Predicted=3747.9117, Expected=3754.3337
# Month=6, Predicted=3754.6157, Expected=3754.9339
# Month=7, Predicted=3755.3222, Expected=3767.0982
# Month=8, Predicted=3767.5806, Expected=3750.6516
# Month=9, Predicted=3750.7632, Expected=3769.4487
# Month=10, Predicted=3769.8681, Expected=3759.5828
# Month=11, Predicted=3759.8854, Expected=3784.9396
# Month=12, Predicted=3785.5023, Expected=3776.2658
# Month=13, Predicted=3776.6312, Expected=3755.4558
# Month=14, Predicted=3755.3092, Expected=3754.3681
# Month=15, Predicted=3754.4873, Expected=3750.8239
# Month=16, Predicted=3751.0890, Expected=3775.7500
# Month=17, Predicted=3776.3718, Expected=3846.6561
# Month=18, Predicted=3847.8943, Expected=3830.9294
# Month=19, Predicted=3831.4329, Expected=3881.2132
# Month=20, Predicted=3881.9431, Expected=3898.3362
# Month=21, Predicted=3899.2773, Expected=3917.4832
# Month=22, Predicted=3918.1875, Expected=3914.1172
# Month=23, Predicted=3914.5272, Expected=3901.5435
# Month=24, Predicted=3901.6296, Expected=3885.2002
# Month=25, Predicted=3885.1557, Expected=3892.2451
# Month=26, Predicted=3892.5487, Expected=3899.6669
# Month=27, Predicted=3900.1556, Expected=3885.6275
# Month=28, Predicted=3885.7393, Expected=3908.2336
# Month=29, Predicted=3908.7101, Expected=3875.4078
# Month=30, Predicted=3875.2803, Expected=3859.5120
# Month=31, Predicted=3859.2234, Expected=3879.9687
# Month=32, Predicted=3880.4380, Expected=3893.2937
# Month=33, Predicted=3893.9719, Expected=3953.4607
# Month=34, Predicted=3954.5298, Expected=3932.8670
# Month=35, Predicted=3933.2317, Expected=3936.3431
# Month=36, Predicted=3936.4964, Expected=3869.8593
# Month=37, Predicted=3868.8726, Expected=3851.2471
# Month=38, Predicted=3850.6076, Expected=3836.7683
# Month=39, Predicted=3836.7617, Expected=3832.0688
# Month=40, Predicted=3832.2489, Expected=3849.7587
# Month=41, Predicted=3850.3337, Expected=3862.2441
# Month=42, Predicted=3862.9293, Expected=3878.6123
# Month=43, Predicted=3879.2848, Expected=3855.0054
# Month=44, Predicted=3855.0631, Expected=3842.4833
# Month=45, Predicted=3842.4095, Expected=3847.2433
# Month=46, Predicted=3847.5818, Expected=3801.1048
# Month=47, Predicted=3800.6346, Expected=3786.6840
# Month=48, Predicted=3786.3409, Expected=3776.0367
# Month=49, Predicted=3776.1087, Expected=3796.7972
# Month=50, Predicted=3797.3461, Expected=3821.0598
# Month=51, Predicted=3821.9005, Expected=3877.3486
# Month=52, Predicted=3878.4920, Expected=3875.8349
# Month=53, Predicted=3876.5222, Expected=3889.3484
# Month=54, Predicted=3889.8257, Expected=3911.1229
# Month=55, Predicted=3911.8741, Expected=3922.9724
# Month=56, Predicted=3923.6494, Expected=3917.9201
# Month=57, Predicted=3918.2529, Expected=3936.3097
# Month=58, Predicted=3936.8516, Expected=3911.1479
# Month=59, Predicted=3911.1688, Expected=3890.6722
# Month=60, Predicted=3890.4048, Expected=3854.8904
# Run 14 — RMSE: 24.406190, MSE: 595.662129, NMSE: 0.0027220315
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3796.8749, Expected=3796.1139
# Month=2, Predicted=3795.3733, Expected=3793.0240
# Month=3, Predicted=3792.2833, Expected=3765.6570
# Month=4, Predicted=3764.9163, Expected=3748.1286
# Month=5, Predicted=3747.3880, Expected=3754.3337
# Month=6, Predicted=3753.5930, Expected=3754.9339
# Month=7, Predicted=3754.1932, Expected=3767.0982
# Month=8, Predicted=3766.3575, Expected=3750.6516
# Month=9, Predicted=3749.9110, Expected=3769.4487
# Month=10, Predicted=3768.7081, Expected=3759.5828
# Month=11, Predicted=3758.8421, Expected=3784.9396
# Month=12, Predicted=3784.1989, Expected=3776.2658
# Month=13, Predicted=3775.5252, Expected=3755.4558
# Month=14, Predicted=3754.7151, Expected=3754.3681
# Month=15, Predicted=3753.6275, Expected=3750.8239
# Month=16, Predicted=3750.0832, Expected=3775.7500
# Month=17, Predicted=3775.0093, Expected=3846.6561
# Month=18, Predicted=3845.9154, Expected=3830.9294
# Month=19, Predicted=3830.1887, Expected=3881.2132
# Month=20, Predicted=3880.4725, Expected=3898.3362
# Month=21, Predicted=3897.5956, Expected=3917.4832
# Month=22, Predicted=3916.7425, Expected=3914.1172
# Month=23, Predicted=3913.3765, Expected=3901.5435
# Month=24, Predicted=3900.8029, Expected=3885.2002
# Month=25, Predicted=3884.4595, Expected=3892.2451
# Month=26, Predicted=3891.5044, Expected=3899.6669
# Month=27, Predicted=3898.9263, Expected=3885.6275
# Month=28, Predicted=3884.8868, Expected=3908.2336
# Month=29, Predicted=3907.4930, Expected=3875.4078
# Month=30, Predicted=3874.6671, Expected=3859.5120
# Month=31, Predicted=3858.7714, Expected=3879.9687
# Month=32, Predicted=3879.2280, Expected=3893.2937
# Month=33, Predicted=3892.5530, Expected=3953.4607
# Month=34, Predicted=3952.7201, Expected=3932.8670
# Month=35, Predicted=3932.1264, Expected=3936.3431
# Month=36, Predicted=3935.6025, Expected=3869.8593
# Month=37, Predicted=3869.1187, Expected=3851.2471
# Month=38, Predicted=3850.5065, Expected=3836.7683
# Month=39, Predicted=3836.0277, Expected=3832.0688
# Month=40, Predicted=3831.3282, Expected=3849.7587
# Month=41, Predicted=3849.0181, Expected=3862.2441
# Month=42, Predicted=3861.5035, Expected=3878.6123
# Month=43, Predicted=3877.8717, Expected=3855.0054
# Month=44, Predicted=3854.2647, Expected=3842.4833
# Month=45, Predicted=3841.7426, Expected=3847.2433
# Month=46, Predicted=3846.5026, Expected=3801.1048
# Month=47, Predicted=3800.3641, Expected=3786.6840
# Month=48, Predicted=3785.9434, Expected=3776.0367
# Month=49, Predicted=3775.2961, Expected=3796.7972
# Month=50, Predicted=3796.0565, Expected=3821.0598
# Month=51, Predicted=3820.3191, Expected=3877.3486
# Month=52, Predicted=3876.6079, Expected=3875.8349
# Month=53, Predicted=3875.0943, Expected=3889.3484
# Month=54, Predicted=3888.6077, Expected=3911.1229
# Month=55, Predicted=3910.3822, Expected=3922.9724
# Month=56, Predicted=3922.2317, Expected=3917.9201
# Month=57, Predicted=3917.1794, Expected=3936.3097
# Month=58, Predicted=3935.5690, Expected=3911.1479
# Month=59, Predicted=3910.4073, Expected=3890.6722
# Month=60, Predicted=3889.9315, Expected=3854.8904
# Run 15 — RMSE: 24.556385, MSE: 603.016031, NMSE: 0.0027626426
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3799.3476, Expected=3796.1139
# Month=2, Predicted=3796.4029, Expected=3793.0240
# Month=3, Predicted=3794.4429, Expected=3765.6570
# Month=4, Predicted=3764.7139, Expected=3748.1286
# Month=5, Predicted=3749.2943, Expected=3754.3337
# Month=6, Predicted=3756.0699, Expected=3754.9339
# Month=7, Predicted=3756.3884, Expected=3767.0982
# Month=8, Predicted=3768.8280, Expected=3750.6516
# Month=9, Predicted=3750.0714, Expected=3769.4487
# Month=10, Predicted=3769.6612, Expected=3759.5828
# Month=11, Predicted=3759.2851, Expected=3784.9396
# Month=12, Predicted=3784.6979, Expected=3776.2658
# Month=13, Predicted=3775.8014, Expected=3755.4558
# Month=14, Predicted=3755.8536, Expected=3754.3681
# Month=15, Predicted=3755.9454, Expected=3750.8239
# Month=16, Predicted=3752.1129, Expected=3775.7500
# Month=17, Predicted=3776.4657, Expected=3846.6561
# Month=18, Predicted=3843.4354, Expected=3830.9294
# Month=19, Predicted=3827.4522, Expected=3881.2132
# ...
# Month=60, Predicted=3890.5532, Expected=3854.8904
# Run 25 — RMSE: 24.441675, MSE: 597.395487, NMSE: 0.0027199322
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3798.1949, Expected=3796.1139
# Month=2, Predicted=3796.4976, Expected=3793.0240
# Month=3, Predicted=3793.3714, Expected=3765.6570
# Month=4, Predicted=3765.8725, Expected=3748.1286
# Month=5, Predicted=3748.4084, Expected=3754.3337
# Month=6, Predicted=3754.7684, Expected=3754.9339
# Month=7, Predicted=3755.3543, Expected=3767.0982
# Month=8, Predicted=3767.5737, Expected=3750.6516
# Month=9, Predicted=3750.9692, Expected=3769.4487
# Month=10, Predicted=3769.9478, Expected=3759.5828
# Month=11, Predicted=3759.9431, Expected=3784.9396
# Month=12, Predicted=3785.4711, Expected=3776.2658
# Month=13, Predicted=3776.6306, Expected=3755.4558
# Month=14, Predicted=3755.7279, Expected=3754.3681
# Month=15, Predicted=3754.7556, Expected=3750.8239
# Month=16, Predicted=3751.2146, Expected=3775.7500
# Month=17, Predicted=3776.2940, Expected=3846.6561
# Month=18, Predicted=3847.3968, Expected=3830.9294
# Month=19, Predicted=3831.2814, Expected=3881.2132
# Month=20, Predicted=3881.8060, Expected=3898.3362
# Month=21, Predicted=3898.8114, Expected=3917.4832
# Month=22, Predicted=3917.9283, Expected=3914.1172
# Month=23, Predicted=3914.4432, Expected=3901.5435
# Month=24, Predicted=3901.8150, Expected=3885.2002
# Month=25, Predicted=3885.4624, Expected=3892.2451
# Month=26, Predicted=3892.6545, Expected=3899.6669
# Month=27, Predicted=3900.0991, Expected=3885.6275
# Month=28, Predicted=3885.9397, Expected=3908.2336
# Month=29, Predicted=3908.7367, Expected=3875.4078
# Month=30, Predicted=3875.6278, Expected=3859.5120
# Month=31, Predicted=3859.8084, Expected=3879.9687
# Month=32, Predicted=3880.4842, Expected=3893.2937
# Month=33, Predicted=3893.7908, Expected=3953.4607
# Month=34, Predicted=3954.1429, Expected=3932.8670
# Month=35, Predicted=3933.1797, Expected=3936.3431
# Month=36, Predicted=3936.7265, Expected=3869.8593
# Month=37, Predicted=3869.8350, Expected=3851.2471
# Month=38, Predicted=3851.5295, Expected=3836.7683
# Month=39, Predicted=3837.1101, Expected=3832.0688
# Month=40, Predicted=3832.4738, Expected=3849.7587
# Month=41, Predicted=3850.2904, Expected=3862.2441
# Month=42, Predicted=3862.7489, Expected=3878.6123
# Month=43, Predicted=3879.1176, Expected=3855.0054
# Month=44, Predicted=3855.2801, Expected=3842.4833
# Month=45, Predicted=3842.8055, Expected=3847.2433
# Month=46, Predicted=3847.6769, Expected=3801.1048
# Month=47, Predicted=3801.2555, Expected=3786.6840
# Month=48, Predicted=3787.0169, Expected=3776.0367
# Month=49, Predicted=3776.4128, Expected=3796.7972
# Month=50, Predicted=3797.3520, Expected=3821.0598
# Month=51, Predicted=3821.6398, Expected=3877.3486
# Month=52, Predicted=3878.0450, Expected=3875.8349
# Month=53, Predicted=3876.2534, Expected=3889.3484
# Month=54, Predicted=3889.7915, Expected=3911.1229
# Month=55, Predicted=3911.6114, Expected=3922.9724
# Month=56, Predicted=3923.4109, Expected=3917.9201
# Month=57, Predicted=3918.2592, Expected=3936.3097
# Month=58, Predicted=3936.7712, Expected=3911.1479
# Month=59, Predicted=3911.3885, Expected=3890.6722
# Month=60, Predicted=3890.9276, Expected=3854.8904
# Run 26 — RMSE: 24.476759, MSE: 599.111744, NMSE: 0.0027456280
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3799.3383, Expected=3796.1139
# Month=2, Predicted=3796.4508, Expected=3793.0240
# Month=3, Predicted=3792.7321, Expected=3765.6570
# Month=4, Predicted=3764.9381, Expected=3748.1286
# Month=5, Predicted=3747.6585, Expected=3754.3337
# Month=6, Predicted=3755.0062, Expected=3754.9339
# Month=7, Predicted=3755.9197, Expected=3767.0982
# Month=8, Predicted=3767.8899, Expected=3750.6516
# Month=9, Predicted=3750.9111, Expected=3769.4487
# Month=10, Predicted=3769.5676, Expected=3759.5828
# Month=11, Predicted=3760.2666, Expected=3784.9396
# Month=12, Predicted=3785.0886, Expected=3776.2658
# Month=13, Predicted=3776.9227, Expected=3755.4558
# Month=14, Predicted=3754.9636, Expected=3754.3681
# Month=15, Predicted=3754.5838, Expected=3750.8239
# Month=16, Predicted=3751.5472, Expected=3775.7500
# Month=17, Predicted=3776.5545, Expected=3846.6561
# Month=18, Predicted=3848.0198, Expected=3830.9294
# Month=19, Predicted=3830.7113, Expected=3881.2132
# Month=20, Predicted=3879.4736, Expected=3898.3362
# Month=21, Predicted=3899.7084, Expected=3917.4832
# Month=22, Predicted=3917.5879, Expected=3914.1172
# Month=23, Predicted=3913.9320, Expected=3901.5435
# Month=24, Predicted=3900.8407, Expected=3885.2002
# Month=25, Predicted=3884.6936, Expected=3892.2451
# Month=26, Predicted=3892.4820, Expected=3899.6669
# Month=27, Predicted=3900.6110, Expected=3885.6275
# Month=28, Predicted=3885.6943, Expected=3908.2336
# Month=29, Predicted=3908.4667, Expected=3875.4078
# Month=30, Predicted=3874.9084, Expected=3859.5120
# Month=31, Predicted=3858.8041, Expected=3879.9687
# Month=32, Predicted=3880.9626, Expected=3893.2937
# Month=33, Predicted=3894.7512, Expected=3953.4607
# Month=34, Predicted=3953.9796, Expected=3932.8670
# Month=35, Predicted=3932.4299, Expected=3936.3431
# Month=36, Predicted=3935.4126, Expected=3869.8593
# Month=37, Predicted=3867.2910, Expected=3851.2471
# Month=38, Predicted=3849.8749, Expected=3836.7683
# Month=39, Predicted=3837.5649, Expected=3832.0688
# Month=40, Predicted=3832.5969, Expected=3849.7587
# Month=41, Predicted=3850.9248, Expected=3862.2441
# Month=42, Predicted=3863.5930, Expected=3878.6123
# Month=43, Predicted=3879.4979, Expected=3855.0054
# Month=44, Predicted=3854.6358, Expected=3842.4833
# Month=45, Predicted=3841.9765, Expected=3847.2433
# Month=46, Predicted=3847.8932, Expected=3801.1048
# Month=47, Predicted=3800.1961, Expected=3786.6840
# Month=48, Predicted=3786.0990, Expected=3776.0367
# Month=49, Predicted=3776.9133, Expected=3796.7972
# Month=50, Predicted=3797.6373, Expected=3821.0598
# Month=51, Predicted=3822.9213, Expected=3877.3486
# Month=52, Predicted=3878.5363, Expected=3875.8349
# Month=53, Predicted=3876.3971, Expected=3889.3484
# Month=54, Predicted=3889.0113, Expected=3911.1229
# Month=55, Predicted=3912.0327, Expected=3922.9724
# Month=56, Predicted=3923.5718, Expected=3917.9201
# Month=57, Predicted=3917.8039, Expected=3936.3097
# Month=58, Predicted=3936.5291, Expected=3911.1479
# Month=59, Predicted=3910.6243, Expected=3890.6722
# Month=60, Predicted=3889.8965, Expected=3854.8904
# Run 27 — RMSE: 24.220611, MSE: 586.637995, NMSE: 0.0026987056
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3798.9084, Expected=3796.1139
# Month=2, Predicted=3796.6707, Expected=3793.0240
# Month=3, Predicted=3793.3800, Expected=3765.6570
# Month=4, Predicted=3765.3467, Expected=3748.1286
# Month=5, Predicted=3747.7274, Expected=3754.3337
# Month=6, Predicted=3754.4695, Expected=3754.9339
# Month=7, Predicted=3755.1080, Expected=3767.0982
# Month=8, Predicted=3767.6120, Expected=3750.6516
# Month=9, Predicted=3750.5658, Expected=3769.4487
# Month=10, Predicted=3770.0640, Expected=3759.5828
# Month=11, Predicted=3759.6775, Expected=3784.9396
# Month=12, Predicted=3785.7833, Expected=3776.2658
# Month=13, Predicted=3776.4713, Expected=3755.4558
# Month=14, Predicted=3755.2104, Expected=3754.3681
# Month=15, Predicted=3754.4093, Expected=3750.8239
# Month=16, Predicted=3750.8824, Expected=3775.7500
# Month=17, Predicted=3776.5408, Expected=3846.6561
# Month=18, Predicted=3848.7208, Expected=3830.9294
# Month=19, Predicted=3831.2658, Expected=3881.2132
# Month=20, Predicted=3882.7889, Expected=3898.3362
# Month=21, Predicted=3899.4164, Expected=3917.4832
# Month=22, Predicted=3918.5392, Expected=3914.1172
# Month=23, Predicted=3914.6338, Expected=3901.5435
# Month=24, Predicted=3901.6729, Expected=3885.2002
# Month=25, Predicted=3885.0554, Expected=3892.2451
# Month=26, Predicted=3892.5273, Expected=3899.6669
# Month=27, Predicted=3900.0871, Expected=3885.6275
# Month=28, Predicted=3885.5828, Expected=3908.2336
# Month=29, Predicted=3908.9507, Expected=3875.4078
# Month=30, Predicted=3874.9965, Expected=3859.5120
# Month=31, Predicted=3859.1000, Expected=3879.9687
# Month=32, Predicted=3880.4698, Expected=3893.2937
# Month=33, Predicted=3893.9003, Expected=3953.4607
# Month=34, Predicted=3955.2543, Expected=3932.8670
# Month=35, Predicted=3933.0322, Expected=3936.3431
# Month=36, Predicted=3936.7280, Expected=3869.8593
# Month=37, Predicted=3868.9171, Expected=3851.2471
# Month=38, Predicted=3850.3353, Expected=3836.7683
# Month=39, Predicted=3836.1151, Expected=3832.0688
# Month=40, Predicted=3831.7984, Expected=3849.7587
# Month=41, Predicted=3850.2363, Expected=3862.2441
# Month=42, Predicted=3862.8392, Expected=3878.6123
# Month=43, Predicted=3879.3886, Expected=3855.0054
# Month=44, Predicted=3854.8611, Expected=3842.4833
# Month=45, Predicted=3842.2991, Expected=3847.2433
# Month=46, Predicted=3847.4494, Expected=3801.1048
# Month=47, Predicted=3800.2434, Expected=3786.6840
# Month=48, Predicted=3786.0413, Expected=3776.0367
# Month=49, Predicted=3775.6043, Expected=3796.7972
# Month=50, Predicted=3797.2871, Expected=3821.0598
# Month=51, Predicted=3821.9376, Expected=3877.3486
# Month=52, Predicted=3879.1336, Expected=3875.8349
# Month=53, Predicted=3876.4949, Expected=3889.3484
# Month=54, Predicted=3890.1593, Expected=3911.1229
# Month=55, Predicted=3912.1548, Expected=3922.9724
# Month=56, Predicted=3923.8127, Expected=3917.9201
# Month=57, Predicted=3918.3094, Expected=3936.3097
# Month=58, Predicted=3937.1153, Expected=3911.1479
# Month=59, Predicted=3911.0096, Expected=3890.6722
# Month=60, Predicted=3890.2943, Expected=3854.8904
# Run 28 — RMSE: 24.446610, MSE: 597.636764, NMSE: 0.0027215543
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3798.3110, Expected=3796.1139
# Month=2, Predicted=3796.5626, Expected=3793.0240
# Month=3, Predicted=3793.4899, Expected=3765.6570
# Month=4, Predicted=3765.8757, Expected=3748.1286
# Month=5, Predicted=3748.4380, Expected=3754.3337
# Month=6, Predicted=3754.8398, Expected=3754.9339
# Month=7, Predicted=3755.3658, Expected=3767.0982
# Month=8, Predicted=3767.6305, Expected=3750.6516
# Month=9, Predicted=3750.8982, Expected=3769.4487
# Month=10, Predicted=3770.0387, Expected=3759.5828
# Month=11, Predicted=3759.9050, Expected=3784.9396
# Month=12, Predicted=3785.5794, Expected=3776.2658
# Month=13, Predicted=3776.6124, Expected=3755.4558
# Month=14, Predicted=3755.6890, Expected=3754.3681
# Month=15, Predicted=3754.8035, Expected=3750.8239
# Month=16, Predicted=3751.2181, Expected=3775.7500
# Month=17, Predicted=3776.3783, Expected=3846.6561
# Month=18, Predicted=3847.5529, Expected=3830.9294
# Month=19, Predicted=3831.1976, Expected=3881.2132
# Month=20, Predicted=3882.0287, Expected=3898.3362
# Month=21, Predicted=3898.9659, Expected=3917.4832
# Month=22, Predicted=3918.1569, Expected=3914.1172
# Month=23, Predicted=3914.6432, Expected=3901.5435
# Month=24, Predicted=3901.9920, Expected=3885.2002
# Month=25, Predicted=3885.5906, Expected=3892.2451
# Month=26, Predicted=3892.8103, Expected=3899.6669
# Month=27, Predicted=3900.2107, Expected=3885.6275
# Month=28, Predicted=3885.9542, Expected=3908.2336
# Month=29, Predicted=3908.8768, Expected=3875.4078
# Month=30, Predicted=3875.4729, Expected=3859.5120
# Month=31, Predicted=3859.7948, Expected=3879.9687
# Month=32, Predicted=3880.5652, Expected=3893.2937
# Month=33, Predicted=3893.8196, Expected=3953.4607
# Month=34, Predicted=3954.3020, Expected=3932.8670
# Month=35, Predicted=3933.0745, Expected=3936.3431
# Month=36, Predicted=3936.8495, Expected=3869.8593
# Month=37, Predicted=3869.4838, Expected=3851.2471
# Month=38, Predicted=3851.5087, Expected=3836.7683
# Month=39, Predicted=3837.0145, Expected=3832.0688
# Month=40, Predicted=3832.3936, Expected=3849.7587
# Month=41, Predicted=3850.2855, Expected=3862.2441
# Month=42, Predicted=3862.7249, Expected=3878.6123
# Month=43, Predicted=3879.1473, Expected=3855.0054
# Month=44, Predicted=3855.1518, Expected=3842.4833
# Month=45, Predicted=3842.7887, Expected=3847.2433
# Month=46, Predicted=3847.7104, Expected=3801.1048
# Month=47, Predicted=3800.9256, Expected=3786.6840
# Month=48, Predicted=3786.9378, Expected=3776.0367
# Month=49, Predicted=3776.2972, Expected=3796.7972
# Month=50, Predicted=3797.3491, Expected=3821.0598
# Month=51, Predicted=3821.6354, Expected=3877.3486
# Month=52, Predicted=3878.1461, Expected=3875.8349
# Month=53, Predicted=3876.2358, Expected=3889.3484
# Month=54, Predicted=3889.9315, Expected=3911.1229
# Month=55, Predicted=3911.7798, Expected=3922.9724
# Month=56, Predicted=3923.5738, Expected=3917.9201
# Month=57, Predicted=3918.3991, Expected=3936.3097
# Month=58, Predicted=3936.9675, Expected=3911.1479
# Month=59, Predicted=3911.4139, Expected=3890.6722
# Month=60, Predicted=3890.9774, Expected=3854.8904
# Run 29 — RMSE: 24.486199, MSE: 599.573930, NMSE: 0.0027439598
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3798.2193, Expected=3796.1139
# Month=2, Predicted=3796.2266, Expected=3793.0240
# Month=3, Predicted=3793.3105, Expected=3765.6570
# Month=4, Predicted=3765.4942, Expected=3748.1286
# Month=5, Predicted=3748.1751, Expected=3754.3337
# Month=6, Predicted=3754.7566, Expected=3754.9339
# Month=7, Predicted=3755.1042, Expected=3767.0982
# Month=8, Predicted=3767.5568, Expected=3750.6516
# Month=9, Predicted=3750.5490, Expected=3769.4487
# Month=10, Predicted=3770.1665, Expected=3759.5828
# Month=11, Predicted=3759.5714, Expected=3784.9396
# Month=12, Predicted=3785.7024, Expected=3776.2658
# Month=13, Predicted=3776.2691, Expected=3755.4558
# Month=14, Predicted=3755.3880, Expected=3754.3681
# Month=15, Predicted=3754.7289, Expected=3750.8239
# Month=16, Predicted=3750.9814, Expected=3775.7500
# Month=17, Predicted=3776.4370, Expected=3846.6561
# Month=18, Predicted=3847.8855, Expected=3830.9294
# Month=19, Predicted=3830.6921, Expected=3881.2132
# Month=20, Predicted=3882.3824, Expected=3898.3362
# Month=21, Predicted=3898.6537, Expected=3917.4832
# Month=22, Predicted=3917.9781, Expected=3914.1172
# Month=23, Predicted=3914.3043, Expected=3901.5435
# Month=24, Predicted=3901.6557, Expected=3885.2002
# Month=25, Predicted=3885.2321, Expected=3892.2451
# Month=26, Predicted=3892.7177, Expected=3899.6669
# Month=27, Predicted=3900.0024, Expected=3885.6275
# Month=28, Predicted=3885.5723, Expected=3908.2336
# Month=29, Predicted=3908.9903, Expected=3875.4078
# Month=30, Predicted=3875.0311, Expected=3859.5120
# Month=31, Predicted=3859.6299, Expected=3879.9687
# Month=32, Predicted=3880.6536, Expected=3893.2937
# Month=33, Predicted=3893.6394, Expected=3953.4607
# Month=34, Predicted=3954.5717, Expected=3932.8670
# Month=35, Predicted=3932.6097, Expected=3936.3431
# Month=36, Predicted=3936.8204, Expected=3869.8593
# Month=37, Predicted=3869.7052, Expected=3851.2471
# Month=38, Predicted=3851.5248, Expected=3836.7683
# Month=39, Predicted=3836.5964, Expected=3832.0688
# Month=40, Predicted=3832.1107, Expected=3849.7587
# Month=41, Predicted=3850.2623, Expected=3862.2441
# Month=42, Predicted=3862.5930, Expected=3878.6123
# Month=43, Predicted=3879.0825, Expected=3855.0054
# Month=44, Predicted=3854.8205, Expected=3842.4833
# Month=45, Predicted=3842.6487, Expected=3847.2433
# Month=46, Predicted=3847.6409, Expected=3801.1048
# Month=47, Predicted=3800.5799, Expected=3786.6840
# Month=48, Predicted=3786.8727, Expected=3776.0367
# Month=49, Predicted=3776.0148, Expected=3796.7972
# Month=50, Predicted=3797.3943, Expected=3821.0598
# Month=51, Predicted=3821.5624, Expected=3877.3486
# Month=52, Predicted=3878.3443, Expected=3875.8349
# Month=53, Predicted=3875.8353, Expected=3889.3484
# Month=54, Predicted=3889.8985, Expected=3911.1229
# Month=55, Predicted=3911.7237, Expected=3922.9724
# Month=56, Predicted=3923.3594, Expected=3917.9201
# Month=57, Predicted=3918.0997, Expected=3936.3097
# Month=58, Predicted=3936.9711, Expected=3911.1479
# Month=59, Predicted=3910.9367, Expected=3890.6722
# Month=60, Predicted=3890.6778, Expected=3854.8904
# Run 30 — RMSE: 24.514550, MSE: 600.963140, NMSE: 0.0027485206
#
# ===== FINAL RESULTS — Fuzzy Output Layer on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.440614 ± 0.104068
# MSE:  597.354453 ± 5.075317
# NMSE: 0.0027381756 ± 0.0000243239
#
# Best run: 11
#   RMSE: 24.162220
#   MSE:  583.812897
#   NMSE: 0.0027004509
# === Best Run Metrics ===
# RMSE: 24.162220
# MSE:  583.812897
# NMSE: 0.0027004509

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Output Layer on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
