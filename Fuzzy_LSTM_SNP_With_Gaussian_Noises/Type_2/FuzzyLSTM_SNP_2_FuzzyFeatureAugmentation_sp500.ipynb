# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: S&P 500
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.10.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    352
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 361
# Trainable params: 361
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — S&P 500

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/sp500.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.001, 0.005, 0.01]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on S&P 500 (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — S&P 500\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — S&P 500\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.1% (lambda=0.001, sigma=0.101031)
# ================================================================================
#
# Data shape: (251,)
# First 5 values: [2038.2501345  2013.76606003 2011.77539759 1985.47381916 1945.94631426]
# Supervised data shape: (250, 3)
# Train: (190, 3), Test: (60, 3)
# X_train shape: (190, 1, 2), y_train shape: (190,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=2155.1288, Expected=2158.3065
# Month=2, Predicted=2159.3732, Expected=2164.2116
# Month=3, Predicted=2163.7386, Expected=2160.2640
# Month=4, Predicted=2159.7298, Expected=2161.3676
# Month=5, Predicted=2162.1610, Expected=2137.7089
# Month=6, Predicted=2137.2909, Expected=2130.1707
# Month=7, Predicted=2134.1262, Expected=2139.6955
# Month=8, Predicted=2139.3258, Expected=2132.9558
# Month=9, Predicted=2131.4897, Expected=2138.1946
# Month=10, Predicted=2138.8634, Expected=2140.8462
# Month=11, Predicted=2140.8316, Expected=2142.5667
# Month=12, Predicted=2142.7745, Expected=2139.5394
# Month=13, Predicted=2139.8435, Expected=2148.6065
# Month=14, Predicted=2149.3962, Expected=2149.5808
# Month=15, Predicted=2148.8530, Expected=2136.8752
# Month=16, Predicted=2137.0853, Expected=2144.1121
# Month=17, Predicted=2146.5296, Expected=2132.2819
# Month=18, Predicted=2130.8115, Expected=2129.8321
# Month=19, Predicted=2131.2397, Expected=2129.0692
# Month=20, Predicted=2128.7215, Expected=2109.4876
# Month=21, Predicted=2108.6636, Expected=2098.9148
# Month=22, Predicted=2100.8748, Expected=2083.8864
# Month=23, Predicted=2083.5125, Expected=2100.6559
# Month=24, Predicted=2100.8785, Expected=2129.8881
# Month=25, Predicted=2130.6593, Expected=2131.6367
# Month=26, Predicted=2133.5511, Expected=2167.4119
# Month=27, Predicted=2170.3476, Expected=2162.6860
# Month=28, Predicted=2162.0954, Expected=2165.5909
# Month=29, Predicted=2169.5629, Expected=2168.2983
# Month=30, Predicted=2169.7705, Expected=2177.7639
# Month=31, Predicted=2178.1524, Expected=2178.4215
# Month=32, Predicted=2177.2154, Expected=2186.9194
# Month=33, Predicted=2187.2751, Expected=2186.2670
# Month=34, Predicted=2185.1956, Expected=2201.5124
# Month=35, Predicted=2201.8671, Expected=2198.6601
# Month=36, Predicted=2197.2839, Expected=2206.2765
# Month=37, Predicted=2207.3743, Expected=2210.1011
# Month=38, Predicted=2209.6991, Expected=2200.6877
# Month=39, Predicted=2200.5759, Expected=2205.0386
# Month=40, Predicted=2207.0395, Expected=2200.0961
# Month=41, Predicted=2199.3232, Expected=2191.1420
# Month=42, Predicted=2191.5758, Expected=2200.6545
# Month=43, Predicted=2201.5264, Expected=2207.1942
# Month=44, Predicted=2206.1873, Expected=2210.9366
# Month=45, Predicted=2210.7988, Expected=2241.1939
# Month=46, Predicted=2241.9348, Expected=2249.5254
# Month=47, Predicted=2248.7766, Expected=2258.8489
# Month=48, Predicted=2260.0415, Expected=2263.2532
# Month=49, Predicted=2263.7874, Expected=2268.4362
# Month=50, Predicted=2269.1934, Expected=2253.6900
# Month=51, Predicted=2253.8726, Expected=2266.7985
# Month=52, Predicted=2271.0950, Expected=2259.2910
# Month=53, Predicted=2256.8960, Expected=2266.5875
# Month=54, Predicted=2267.5628, Expected=2270.4188
# Month=55, Predicted=2269.5535, Expected=2262.8961
# Month=56, Predicted=2262.5153, Expected=2260.2020
# Month=57, Predicted=2261.3078, Expected=2266.1640
# Month=58, Predicted=2266.3502, Expected=2270.4083
# Month=59, Predicted=2269.8079, Expected=2249.5409
# Month=60, Predicted=2249.0580, Expected=2251.4827
# Run 1 — RMSE: 11.229148, MSE: 126.093772, NMSE: 0.0007656308
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=2156.0105, Expected=2158.3065
# Month=2, Predicted=2159.7685, Expected=2164.2116
# Month=3, Predicted=2164.3070, Expected=2160.2640
# Month=4, Predicted=2160.9604, Expected=2161.3676
# Month=5, Predicted=2163.0721, Expected=2137.7089
# Month=6, Predicted=2138.4830, Expected=2130.1707
# Month=7, Predicted=2134.0355, Expected=2139.6955
# Month=8, Predicted=2139.5389, Expected=2132.9558
# Month=9, Predicted=2133.3465, Expected=2138.1946
# Month=10, Predicted=2137.7820, Expected=2140.8462
# Month=11, Predicted=2140.3368, Expected=2142.5667
# Month=12, Predicted=2140.3474, Expected=2139.5394
# Month=13, Predicted=2136.5571, Expected=2148.6065
# Month=14, Predicted=2144.9914, Expected=2149.5808
# Month=15, Predicted=2145.1965, Expected=2136.8752
# Month=16, Predicted=2133.9877, Expected=2144.1121
# Month=17, Predicted=2143.8317, Expected=2132.2819
# Month=18, Predicted=2128.1085, Expected=2129.8321
# Month=19, Predicted=2130.3650, Expected=2129.0692
# Month=20, Predicted=2126.7069, Expected=2109.4876
# Month=21, Predicted=2107.7749, Expected=2098.9148
# Month=22, Predicted=2101.2682, Expected=2083.8864
# Month=23, Predicted=2082.8819, Expected=2100.6559
# Month=24, Predicted=2101.1086, Expected=2129.8881
# Month=25, Predicted=2134.0914, Expected=2131.6367
# Month=26, Predicted=2134.3072, Expected=2167.4119
# Month=27, Predicted=2165.2808, Expected=2162.6860
# Month=28, Predicted=2163.7096, Expected=2165.5909
# Month=29, Predicted=2169.9619, Expected=2168.2983
# Month=30, Predicted=2168.8460, Expected=2177.7639
# Month=31, Predicted=2176.6058, Expected=2178.4215
# Month=32, Predicted=2175.8066, Expected=2186.9194
# Month=33, Predicted=2187.3157, Expected=2186.2670
# Month=34, Predicted=2184.8447, Expected=2201.5124
# Month=35, Predicted=2203.1678, Expected=2198.6601
# Month=36, Predicted=2197.4693, Expected=2206.2765
# Month=37, Predicted=2210.4945, Expected=2210.1011
# Month=38, Predicted=2211.1528, Expected=2200.6877
# Month=39, Predicted=2203.0627, Expected=2205.0386
# Month=40, Predicted=2209.1062, Expected=2200.0961
# Month=41, Predicted=2201.8934, Expected=2191.1420
# Month=42, Predicted=2194.2934, Expected=2200.6545
# Month=43, Predicted=2203.7517, Expected=2207.1942
# Month=44, Predicted=2211.0359, Expected=2210.9366
# Month=45, Predicted=2213.2412, Expected=2241.1939
# Month=46, Predicted=2241.3877, Expected=2249.5254
# Month=47, Predicted=2250.1894, Expected=2258.8489
# Month=48, Predicted=2256.3380, Expected=2263.2532
# Month=49, Predicted=2261.8138, Expected=2268.4362
# Month=50, Predicted=2267.7423, Expected=2253.6900
# Month=51, Predicted=2253.3037, Expected=2266.7985
# Month=52, Predicted=2271.3838, Expected=2259.2910
# Month=53, Predicted=2254.0160, Expected=2266.5875
# Month=54, Predicted=2268.9559, Expected=2270.4188
# Month=55, Predicted=2268.6407, Expected=2262.8961
# Month=56, Predicted=2263.7288, Expected=2260.2020
# Month=57, Predicted=2263.3412, Expected=2266.1640
# Month=58, Predicted=2267.8962, Expected=2270.4083
# Month=59, Predicted=2272.9110, Expected=2249.5409
# Month=60, Predicted=2252.4907, Expected=2251.4827
# Run 2 — RMSE: 11.204954, MSE: 125.551003, NMSE: 0.0007477099
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=2153.1062, Expected=2158.3065
# Month=2, Predicted=2158.5423, Expected=2164.2116
# Month=3, Predicted=2162.9681, Expected=2160.2640
# Month=4, Predicted=2157.6963, Expected=2161.3676
# Month=5, Predicted=2160.5102, Expected=2137.7089
# Month=6, Predicted=2135.8188, Expected=2130.1707
# Month=7, Predicted=2133.6587, Expected=2139.6955
# Month=8, Predicted=2140.5205, Expected=2132.9558
# Month=9, Predicted=2129.7902, Expected=2138.1946
# Month=10, Predicted=2137.3304, Expected=2140.8462
# Month=11, Predicted=2139.2773, Expected=2142.5667
# Month=12, Predicted=2140.3053, Expected=2139.5394
# Month=13, Predicted=2137.6768, Expected=2148.6065
# Month=14, Predicted=2147.7349, Expected=2149.5808
# Month=15, Predicted=2147.2338, Expected=2136.8752
# Month=16, Predicted=2134.6101, Expected=2144.1121
# Month=17, Predicted=2145.3873, Expected=2132.2819
# Month=18, Predicted=2130.3436, Expected=2129.8321
# Month=19, Predicted=2130.1016, Expected=2129.0692
# Month=20, Predicted=2128.8621, Expected=2109.4876
# Month=21, Predicted=2107.4671, Expected=2098.9148
# Month=22, Predicted=2101.1537, Expected=2083.8864
# Month=23, Predicted=2084.2972, Expected=2100.6559
# Month=24, Predicted=2101.2157, Expected=2129.8881
# Month=25, Predicted=2128.4147, Expected=2131.6367
# Month=26, Predicted=2126.2271, Expected=2167.4119
# Month=27, Predicted=2164.8139, Expected=2162.6860
# Month=28, Predicted=2157.6704, Expected=2165.5909
# Month=29, Predicted=2163.5697, Expected=2168.2983
# Month=30, Predicted=2167.7117, Expected=2177.7639
# Month=31, Predicted=2176.3218, Expected=2178.4215
# Month=32, Predicted=2176.1443, Expected=2186.9194
# Month=33, Predicted=2185.6873, Expected=2186.2670
# Month=34, Predicted=2184.4370, Expected=2201.5124
# Month=35, Predicted=2200.7265, Expected=2198.6601
# Month=36, Predicted=2196.1235, Expected=2206.2765
# Month=37, Predicted=2205.4243, Expected=2210.1011
# Month=38, Predicted=2208.9761, Expected=2200.6877
# Month=39, Predicted=2198.7952, Expected=2205.0386
# Month=40, Predicted=2206.0767, Expected=2200.0961
# Month=41, Predicted=2199.3266, Expected=2191.1420
# Month=42, Predicted=2190.6687, Expected=2200.6545
# Month=43, Predicted=2201.7636, Expected=2207.1942
# Month=44, Predicted=2205.8079, Expected=2210.9366
# Month=45, Predicted=2208.5816, Expected=2241.1939
# Month=46, Predicted=2240.2234, Expected=2249.5254
# Month=47, Predicted=2245.8193, Expected=2258.8489
# Month=48, Predicted=2255.1850, Expected=2263.2532
# Month=49, Predicted=2261.0987, Expected=2268.4362
# Month=50, Predicted=2266.8668, Expected=2253.6900
# Month=51, Predicted=2251.8748, Expected=2266.7985
# Month=52, Predicted=2269.1721, Expected=2259.2910
# Month=53, Predicted=2257.9821, Expected=2266.5875
# Month=54, Predicted=2266.6080, Expected=2270.4188
# Month=55, Predicted=2269.6695, Expected=2262.8961
# Month=56, Predicted=2260.9521, Expected=2260.2020
# Month=57, Predicted=2260.6344, Expected=2266.1640
# Month=58, Predicted=2266.3313, Expected=2270.4083
# Month=59, Predicted=2268.8654, Expected=2249.5409
# Month=60, Predicted=2246.9563, Expected=2251.4827
# Run 3 — RMSE: 11.876799, MSE: 141.058343, NMSE: 0.0008556792
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=2155.4029, Expected=2158.3065
# Month=2, Predicted=2158.9892, Expected=2164.2116
# Month=3, Predicted=2163.1485, Expected=2160.2640
# Month=4, Predicted=2159.1087, Expected=2161.3676
# Month=5, Predicted=2161.5593, Expected=2137.7089
# Month=6, Predicted=2137.1293, Expected=2130.1707
# Month=7, Predicted=2133.8297, Expected=2139.6955
# Month=8, Predicted=2139.1802, Expected=2132.9558
# Month=9, Predicted=2130.4588, Expected=2138.1946
# Month=10, Predicted=2137.4642, Expected=2140.8462
# Month=11, Predicted=2139.1745, Expected=2142.5667
# Month=12, Predicted=2141.8642, Expected=2139.5394
# Month=13, Predicted=2139.2241, Expected=2148.6065
# Month=14, Predicted=2148.8994, Expected=2149.5808
# Month=15, Predicted=2148.6086, Expected=2136.8752
# Month=16, Predicted=2137.1963, Expected=2144.1121
# Month=17, Predicted=2146.0873, Expected=2132.2819
# Month=18, Predicted=2131.0042, Expected=2129.8321
# Month=19, Predicted=2131.1232, Expected=2129.0692
# Month=20, Predicted=2128.1847, Expected=2109.4876
# Month=21, Predicted=2108.1881, Expected=2098.9148
# Month=22, Predicted=2100.3013, Expected=2083.8864
# Month=23, Predicted=2082.8111, Expected=2100.6559
# Month=24, Predicted=2099.4885, Expected=2129.8881
# Month=25, Predicted=2128.0454, Expected=2131.6367
# Month=26, Predicted=2130.5863, Expected=2167.4119
# Month=27, Predicted=2169.0097, Expected=2162.6860
# Month=28, Predicted=2162.3323, Expected=2165.5909
# Month=29, Predicted=2172.5031, Expected=2168.2983
# Month=30, Predicted=2171.6588, Expected=2177.7639
# Month=31, Predicted=2179.6893, Expected=2178.4215
# Month=32, Predicted=2178.2006, Expected=2186.9194
# Month=33, Predicted=2187.5155, Expected=2186.2670
# Month=34, Predicted=2185.6675, Expected=2201.5124
# Month=35, Predicted=2202.3555, Expected=2198.6601
# Month=36, Predicted=2197.7299, Expected=2206.2765
# Month=37, Predicted=2208.2269, Expected=2210.1011
# Month=38, Predicted=2210.1371, Expected=2200.6877
# Month=39, Predicted=2201.2649, Expected=2205.0386
# Month=40, Predicted=2207.1347, Expected=2200.0961
# Month=41, Predicted=2199.4265, Expected=2191.1420
# Month=42, Predicted=2191.4925, Expected=2200.6545
# Month=43, Predicted=2200.8328, Expected=2207.1942
# Month=44, Predicted=2205.4576, Expected=2210.9366
# Month=45, Predicted=2209.9901, Expected=2241.1939
# Month=46, Predicted=2240.8575, Expected=2249.5254
# Month=47, Predicted=2248.4486, Expected=2258.8489
# Month=48, Predicted=2261.2155, Expected=2263.2532
# Month=49, Predicted=2265.2198, Expected=2268.4362
# Month=50, Predicted=2270.8809, Expected=2253.6900
# Month=51, Predicted=2255.1634, Expected=2266.7985
# Month=52, Predicted=2270.9050, Expected=2259.2910
# Month=53, Predicted=2258.0295, Expected=2266.5875
# Month=54, Predicted=2268.0269, Expected=2270.4188
# Month=55, Predicted=2269.3552, Expected=2262.8961
# Month=56, Predicted=2262.5144, Expected=2260.2020
# Month=57, Predicted=2261.2979, Expected=2266.1640
# Month=58, Predicted=2266.0193, Expected=2270.4083
# Month=59, Predicted=2269.2536, Expected=2249.5409
# Month=60, Predicted=2248.8447, Expected=2251.4827
# Run 4 — RMSE: 11.415239, MSE: 130.307685, NMSE: 0.0007791077
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=2154.9243, Expected=2158.3065
# Month=2, Predicted=2159.1867, Expected=2164.2116
# Month=3, Predicted=2163.1793, Expected=2160.2640
# Month=4, Predicted=2159.0906, Expected=2161.3676
# Month=5, Predicted=2161.9386, Expected=2137.7089
# Month=6, Predicted=2137.2572, Expected=2130.1707
# Month=7, Predicted=2134.2642, Expected=2139.6955
# Month=8, Predicted=2138.9881, Expected=2132.9558
# Month=9, Predicted=2130.5429, Expected=2138.1946
# Month=10, Predicted=2138.0275, Expected=2140.8462
# Month=11, Predicted=2140.1577, Expected=2142.5667
# Month=12, Predicted=2141.8797, Expected=2139.5394
# Month=13, Predicted=2139.0033, Expected=2148.6065
# Month=14, Predicted=2148.4975, Expected=2149.5808
# Month=15, Predicted=2148.2841, Expected=2136.8752
# Month=16, Predicted=2136.6871, Expected=2144.1121
# Month=17, Predicted=2146.1299, Expected=2132.2819
# Month=18, Predicted=2130.8083, Expected=2129.8321
# Month=19, Predicted=2131.0025, Expected=2129.0692
# Month=20, Predicted=2128.4463, Expected=2109.4876
# Month=21, Predicted=2108.2881, Expected=2098.9148
# Month=22, Predicted=2100.8024, Expected=2083.8864
# Month=23, Predicted=2083.2250, Expected=2100.6559
# Month=24, Predicted=2099.7514, Expected=2129.8881
# Month=25, Predicted=2129.1196, Expected=2131.6367
# Month=26, Predicted=2132.3327, Expected=2167.4119
# Month=27, Predicted=2169.4475, Expected=2162.6860
# Month=28, Predicted=2162.7168, Expected=2165.5909
# Month=29, Predicted=2170.8597, Expected=2168.2983
# Month=30, Predicted=2169.6858, Expected=2177.7639
# Month=31, Predicted=2177.7053, Expected=2178.4215
# Month=32, Predicted=2177.1588, Expected=2186.9194
# Month=33, Predicted=2188.1188, Expected=2186.2670
# Month=34, Predicted=2186.1461, Expected=2201.5124
# Month=35, Predicted=2203.1351, Expected=2198.6601
# Month=36, Predicted=2197.5088, Expected=2206.2765
# Month=37, Predicted=2208.8070, Expected=2210.1011
# Month=38, Predicted=2210.0602, Expected=2200.6877
# Month=39, Predicted=2200.9426, Expected=2205.0386
# Month=40, Predicted=2207.9987, Expected=2200.0961
# Month=41, Predicted=2199.4107, Expected=2191.1420
# Month=42, Predicted=2191.8848, Expected=2200.6545
# Month=43, Predicted=2201.8571, Expected=2207.1942
# Month=44, Predicted=2205.7786, Expected=2210.9366
# Month=45, Predicted=2210.3303, Expected=2241.1939
# Month=46, Predicted=2241.5608, Expected=2249.5254
# Month=47, Predicted=2248.4665, Expected=2258.8489
# Month=48, Predicted=2261.1058, Expected=2263.2532
# Month=49, Predicted=2264.6296, Expected=2268.4362
# Month=50, Predicted=2269.8171, Expected=2253.6900
# Month=51, Predicted=2253.9900, Expected=2266.7985
# Month=52, Predicted=2272.0565, Expected=2259.2910
# Month=53, Predicted=2257.3283, Expected=2266.5875
# Month=54, Predicted=2268.9533, Expected=2270.4188
# Month=55, Predicted=2269.9777, Expected=2262.8961
# Month=56, Predicted=2262.8661, Expected=2260.2020
# Month=57, Predicted=2262.2856, Expected=2266.1640
# Month=58, Predicted=2266.4539, Expected=2270.4083
# Month=59, Predicted=2269.1518, Expected=2249.5409
# Month=60, Predicted=2248.8854, Expected=2251.4827
# Run 5 — RMSE: 11.338098, MSE: 128.552457, NMSE: 0.0007691233
#
# ===== RUN 6/30 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5628\1828263757.py in ?()
#     141
#     142     for run in range(30):
#     143         print(f'\n===== RUN {run+1}/30 =====')
#     144
# --> 145         np.random.seed(run)
#     146         tf.random.set_seed(run)
#     147
#     148         tf.keras.backend.clear_session()
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\keras\engine\training.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1634             # If eval data_handler exists, delete it after all epochs are done.
#    1635             if getattr(self, "_eval_data_handler", None) is not None:
#    1636                 del self._eval_data_handler
#    1637             callbacks.on_train_end(logs=training_logs)
# -> 1638             return self.history
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\keras\engine\data_adapter.py in ?(self)
#    1370             or self._current_step < self._inferred_steps
#    1371         ):
#    1372             if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1373                 break
# -> 1374             original_spe = self._steps_per_execution.numpy().item()
#    1375             can_run_full_execution = (
#    1376                 original_spe == 1
#    1377                 or self._inferred_steps is None
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in ?(self)
#     635   def numpy(self):
#     636     if context.executing_eagerly():
# --> 637       return self.read_value().numpy()
#     638     raise NotImplementedError(
#     639         "numpy() is only available when eager execution is enabled.")
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in ?(self)
#     724     with ops.name_scope("Read"):
#     725       value = self._read_variable_op()
#     726     # Return an identity so it can get placed on whatever device the context
#     727     # specifies instead of the device where the variable is.
# --> 728     return array_ops.identity(value)
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#    1181         if result is not OpDispatcher.NOT_SUPPORTED:
#    1182           return result
#    1183         else:
# -> 1184           raise
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\ops\array_ops.py in ?(input, name)
#     290   if context.executing_eagerly() and not hasattr(input, "graph"):
#     291     # Make sure we get an input with handle data attached from resource
#     292     # variables. Variables have correct handle data when graph building.
#     293     input = ops.convert_to_tensor(input)
# --> 294   ret = gen_array_ops.identity(input, name=name)
#     295   # Propagate handle data for happier shape inference for resource variables.
#     296   if hasattr(input, "_handle_data"):
#     297     ret._handle_data = input._handle_data  # pylint: disable=protected-access
#
# c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in ?(input, name)
#    4070       return _result
#    4071     except _core._NotOkStatusException as e:
#    4072       _ops.raise_from_not_ok_status(e, name)
#    4073     except _core._FallbackException:
# -> 4074       pass
#    4075     try:
#    4076       return identity_eager_fallback(
#    4077           input, name=name, ctx=_ctx)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on S&P 500
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
