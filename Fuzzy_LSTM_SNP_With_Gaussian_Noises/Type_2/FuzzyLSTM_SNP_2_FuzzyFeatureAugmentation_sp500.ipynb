# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: S&P 500
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    352
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 361 (1.41 KB)
# Trainable params: 361 (1.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — S&P 500

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/sp500.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on S&P 500 (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — S&P 500\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — S&P 500\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.1% (lambda=0.001, sigma=0.101031)
# ================================================================================
#
# Data shape: (251,)
# First 5 values: [2038.2501345  2013.76606003 2011.77539759 1985.47381916 1945.94631426]
# Supervised data shape: (250, 3)
# Train: (190, 3), Test: (60, 3)
# X_train shape: (190, 1, 2), y_train shape: (190,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=2153.9971, Expected=2158.3065
# Month=2, Predicted=2159.2302, Expected=2164.2116
# Month=3, Predicted=2163.1088, Expected=2160.2640
# Month=4, Predicted=2158.2377, Expected=2161.3676
# Month=5, Predicted=2161.2986, Expected=2137.7089
# Month=6, Predicted=2137.1544, Expected=2130.1707
# Month=7, Predicted=2133.5168, Expected=2139.6955
# Month=8, Predicted=2139.8269, Expected=2132.9558
# Month=9, Predicted=2129.2034, Expected=2138.1946
# Month=10, Predicted=2136.9068, Expected=2140.8462
# Month=11, Predicted=2139.3105, Expected=2142.5667
# Month=12, Predicted=2140.0395, Expected=2139.5394
# Month=13, Predicted=2137.9718, Expected=2148.6065
# Month=14, Predicted=2147.2897, Expected=2149.5808
# Month=15, Predicted=2147.2868, Expected=2136.8752
# Month=16, Predicted=2135.4870, Expected=2144.1121
# Month=17, Predicted=2145.1325, Expected=2132.2819
# Month=18, Predicted=2130.4112, Expected=2129.8321
# Month=19, Predicted=2129.4729, Expected=2129.0692
# Month=20, Predicted=2128.1074, Expected=2109.4876
# Month=21, Predicted=2106.8636, Expected=2098.9148
# Month=22, Predicted=2099.8906, Expected=2083.8864
# Month=23, Predicted=2082.6572, Expected=2100.6559
# Month=24, Predicted=2097.8666, Expected=2129.8881
# Month=25, Predicted=2127.4868, Expected=2131.6367
# Month=26, Predicted=2128.6063, Expected=2167.4119
# Month=27, Predicted=2167.8969, Expected=2162.6860
# Month=28, Predicted=2161.5556, Expected=2165.5909
# Month=29, Predicted=2170.4622, Expected=2168.2983
# Month=30, Predicted=2169.7640, Expected=2177.7639
# Month=31, Predicted=2176.9933, Expected=2178.4215
# Month=32, Predicted=2177.6826, Expected=2186.9194
# Month=33, Predicted=2187.4992, Expected=2186.2670
# Month=34, Predicted=2186.3272, Expected=2201.5124
# Month=35, Predicted=2202.1812, Expected=2198.6601
# Month=36, Predicted=2198.4325, Expected=2206.2765
# Month=37, Predicted=2207.9707, Expected=2210.1011
# Month=38, Predicted=2211.1287, Expected=2200.6877
# Month=39, Predicted=2200.9657, Expected=2205.0386
# Month=40, Predicted=2208.0932, Expected=2200.0961
# Month=41, Predicted=2200.8983, Expected=2191.1420
# Month=42, Predicted=2191.6976, Expected=2200.6545
# Month=43, Predicted=2202.4422, Expected=2207.1942
# Month=44, Predicted=2206.5722, Expected=2210.9366
# Month=45, Predicted=2209.4799, Expected=2241.1939
# Month=46, Predicted=2241.0690, Expected=2249.5254
# Month=47, Predicted=2248.6476, Expected=2258.8489
# Month=48, Predicted=2260.1307, Expected=2263.2532
# Month=49, Predicted=2264.9125, Expected=2268.4362
# Month=50, Predicted=2269.6780, Expected=2253.6900
# Month=51, Predicted=2255.1393, Expected=2266.7985
# Month=52, Predicted=2271.6546, Expected=2259.2910
# Month=53, Predicted=2260.6253, Expected=2266.5875
# Month=54, Predicted=2268.1393, Expected=2270.4188
# Month=55, Predicted=2271.9153, Expected=2262.8961
# Month=56, Predicted=2262.6687, Expected=2260.2020
# Month=57, Predicted=2262.6506, Expected=2266.1640
# Month=58, Predicted=2267.4277, Expected=2270.4083
# Month=59, Predicted=2269.5937, Expected=2249.5409
# Month=60, Predicted=2249.1272, Expected=2251.4827
# Run 2 — RMSE: 11.608892, MSE: 134.766383, NMSE: 0.0007880490
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=2152.8589, Expected=2158.3065
# Month=2, Predicted=2156.5134, Expected=2164.2116
# Month=3, Predicted=2161.6100, Expected=2160.2640
# Month=4, Predicted=2157.3339, Expected=2161.3676
# Month=5, Predicted=2159.0944, Expected=2137.7089
# Month=6, Predicted=2135.1840, Expected=2130.1707
# Month=7, Predicted=2131.6861, Expected=2139.6955
# Month=8, Predicted=2138.7938, Expected=2132.9558
# Month=9, Predicted=2130.7004, Expected=2138.1946
# Month=10, Predicted=2137.1640, Expected=2140.8462
# Month=11, Predicted=2139.5531, Expected=2142.5667
# Month=12, Predicted=2141.6234, Expected=2139.5394
# Month=13, Predicted=2138.8776, Expected=2148.6065
# Month=14, Predicted=2148.4478, Expected=2149.5808
# Month=15, Predicted=2148.4735, Expected=2136.8752
# Month=16, Predicted=2136.4095, Expected=2144.1121
# Month=17, Predicted=2145.4362, Expected=2132.2819
# Month=18, Predicted=2131.2418, Expected=2129.8321
# Month=19, Predicted=2130.7372, Expected=2129.0692
# Month=20, Predicted=2128.6764, Expected=2109.4876
# Month=21, Predicted=2108.3618, Expected=2098.9148
# Month=22, Predicted=2100.1941, Expected=2083.8864
# Month=23, Predicted=2083.3415, Expected=2100.6559
# Month=24, Predicted=2099.8230, Expected=2129.8881
# Month=25, Predicted=2128.6939, Expected=2131.6367
# Month=26, Predicted=2130.7417, Expected=2167.4119
# Month=27, Predicted=2167.0879, Expected=2162.6860
# Month=28, Predicted=2161.8188, Expected=2165.5909
# Month=29, Predicted=2169.1577, Expected=2168.2983
# Month=30, Predicted=2171.1059, Expected=2177.7639
# Month=31, Predicted=2180.2987, Expected=2178.4215
# Month=32, Predicted=2179.8329, Expected=2186.9194
# Month=33, Predicted=2189.2511, Expected=2186.2670
# Month=34, Predicted=2187.3315, Expected=2201.5124
# Month=35, Predicted=2203.2479, Expected=2198.6601
# Month=36, Predicted=2198.4954, Expected=2206.2765
# Month=37, Predicted=2207.8316, Expected=2210.1011
# Month=38, Predicted=2210.1601, Expected=2200.6877
# Month=39, Predicted=2200.5948, Expected=2205.0386
# Month=40, Predicted=2206.1157, Expected=2200.0961
# Month=41, Predicted=2199.0830, Expected=2191.1420
# Month=42, Predicted=2190.3542, Expected=2200.6545
# Month=43, Predicted=2199.8136, Expected=2207.1942
# Month=44, Predicted=2204.9931, Expected=2210.9366
# Month=45, Predicted=2208.6215, Expected=2241.1939
# Month=46, Predicted=2239.1736, Expected=2249.5254
# Month=47, Predicted=2247.4830, Expected=2258.8489
# Month=48, Predicted=2257.8682, Expected=2263.2532
# Month=49, Predicted=2262.6025, Expected=2268.4362
# Month=50, Predicted=2268.6735, Expected=2253.6900
# Month=51, Predicted=2254.2228, Expected=2266.7985
# Month=35, Predicted=2200.9884, Expected=2198.6601
# Month=36, Predicted=2196.5207, Expected=2206.2765
# Month=37, Predicted=2206.7781, Expected=2210.1011
# Month=38, Predicted=2208.9383, Expected=2200.6877
# Month=39, Predicted=2199.8912, Expected=2205.0386
# Month=40, Predicted=2205.6034, Expected=2200.0961
# Month=41, Predicted=2198.4951, Expected=2191.1420
# Month=42, Predicted=2190.9338, Expected=2200.6545
# Month=43, Predicted=2200.7489, Expected=2207.1942
# Month=44, Predicted=2205.6160, Expected=2210.9366
# Month=45, Predicted=2210.6962, Expected=2241.1939
# Month=46, Predicted=2241.6358, Expected=2249.5254
# Month=47, Predicted=2247.7462, Expected=2258.8489
# Month=48, Predicted=2260.1553, Expected=2263.2532
# Month=49, Predicted=2263.3453, Expected=2268.4362
# Month=50, Predicted=2267.8791, Expected=2253.6900
# Month=51, Predicted=2251.9956, Expected=2266.7985
# Month=52, Predicted=2267.1918, Expected=2259.2910
# Month=53, Predicted=2256.1039, Expected=2266.5875
# Month=54, Predicted=2266.8899, Expected=2270.4188
# Month=55, Predicted=2269.1304, Expected=2262.8961
# Month=56, Predicted=2262.4896, Expected=2260.2020
# Month=57, Predicted=2261.1854, Expected=2266.1640
# Month=58, Predicted=2265.8636, Expected=2270.4083
# Month=59, Predicted=2269.2307, Expected=2249.5409
# Month=60, Predicted=2249.0519, Expected=2251.4827
# Run 8 — RMSE: 11.329080, MSE: 128.348051, NMSE: 0.0007952550
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=2154.7683, Expected=2158.3065
# Month=2, Predicted=2158.9819, Expected=2164.2116
# Month=3, Predicted=2163.4648, Expected=2160.2640
# Month=4, Predicted=2159.2123, Expected=2161.3676
# Month=5, Predicted=2161.6192, Expected=2137.7089
# Month=6, Predicted=2137.1142, Expected=2130.1707
# Month=7, Predicted=2133.7524, Expected=2139.6955
# Month=8, Predicted=2139.3560, Expected=2132.9558
# Month=9, Predicted=2130.4687, Expected=2138.1946
# Month=10, Predicted=2137.9254, Expected=2140.8462
# Month=11, Predicted=2140.2997, Expected=2142.5667
# Month=12, Predicted=2142.2675, Expected=2139.5394
# Month=13, Predicted=2139.7164, Expected=2148.6065
# Month=14, Predicted=2149.1620, Expected=2149.5808
# Month=15, Predicted=2149.0219, Expected=2136.8752
# Month=16, Predicted=2136.8808, Expected=2144.1121
# Month=17, Predicted=2145.8833, Expected=2132.2819
# Month=18, Predicted=2131.1246, Expected=2129.8321
# Month=19, Predicted=2130.5485, Expected=2129.0692
# Month=20, Predicted=2128.3534, Expected=2109.4876
# Month=21, Predicted=2107.9512, Expected=2098.9148
# Month=22, Predicted=2100.3983, Expected=2083.8864
# Month=23, Predicted=2083.2654, Expected=2100.6559
# Month=24, Predicted=2100.1141, Expected=2129.8881
# Month=25, Predicted=2128.7672, Expected=2131.6367
# Month=26, Predicted=2133.1858, Expected=2167.4119
# Month=27, Predicted=2170.9936, Expected=2162.6860
# Month=28, Predicted=2165.1597, Expected=2165.5909
# Month=29, Predicted=2171.1454, Expected=2168.2983
# Month=30, Predicted=2170.8348, Expected=2177.7639
# Month=21, Predicted=2114.6657, Expected=2098.9148
# Month=22, Predicted=2108.3163, Expected=2083.8864
# Month=23, Predicted=2089.3772, Expected=2100.6559
# Month=24, Predicted=2106.8785, Expected=2129.8881
# Month=25, Predicted=2131.1122, Expected=2131.6367
# Month=26, Predicted=2133.5493, Expected=2167.4119
# Month=27, Predicted=2172.9944, Expected=2162.6860
# Month=28, Predicted=2163.7864, Expected=2165.5909
# Month=29, Predicted=2174.7858, Expected=2168.2983
# Month=30, Predicted=2173.2100, Expected=2177.7639
# Month=31, Predicted=2182.6000, Expected=2178.4215
# Month=32, Predicted=2182.1007, Expected=2186.9194
# Month=33, Predicted=2192.4300, Expected=2186.2670
# Month=34, Predicted=2189.9048, Expected=2201.5124
# Month=35, Predicted=2206.9142, Expected=2198.6601
# Month=36, Predicted=2201.1923, Expected=2206.2765
# Month=37, Predicted=2212.8506, Expected=2210.1011
# Month=38, Predicted=2213.6549, Expected=2200.6877
# Month=39, Predicted=2205.4580, Expected=2205.0386
# Month=40, Predicted=2212.0664, Expected=2200.0961
# Month=41, Predicted=2203.6267, Expected=2191.1420
# Month=42, Predicted=2197.1003, Expected=2200.6545
# Month=43, Predicted=2206.4550, Expected=2207.1942
# Month=44, Predicted=2209.5780, Expected=2210.9366
# Month=45, Predicted=2214.6809, Expected=2241.1939
# Month=46, Predicted=2244.6931, Expected=2249.5254
# Month=47, Predicted=2250.1930, Expected=2258.8489
# Month=48, Predicted=2263.5198, Expected=2263.2532
# Month=49, Predicted=2266.4820, Expected=2268.4362
# Month=50, Predicted=2272.1954, Expected=2253.6900
# Month=51, Predicted=2257.1722, Expected=2266.7985
# Month=52, Predicted=2274.2861, Expected=2259.2910
# Month=53, Predicted=2261.0106, Expected=2266.5875
# Month=54, Predicted=2273.6805, Expected=2270.4188
# Month=55, Predicted=2273.6229, Expected=2262.8961
# Month=56, Predicted=2267.4458, Expected=2260.2020
# Month=57, Predicted=2266.6105, Expected=2266.1640
# Month=58, Predicted=2270.4997, Expected=2270.4083
# Month=59, Predicted=2273.3700, Expected=2249.5409
# Month=60, Predicted=2253.5870, Expected=2251.4827
# Run 12 — RMSE: 12.231742, MSE: 149.615515, NMSE: 0.0009301221
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=2155.7865, Expected=2158.3065
# Month=2, Predicted=2159.5664, Expected=2164.2116
# Month=3, Predicted=2163.5246, Expected=2160.2640
# Month=4, Predicted=2158.9692, Expected=2161.3676
# Month=5, Predicted=2161.4528, Expected=2137.7089
# Month=6, Predicted=2137.4732, Expected=2130.1707
# Month=7, Predicted=2133.9230, Expected=2139.6955
# Month=8, Predicted=2139.5836, Expected=2132.9558
# Month=9, Predicted=2130.0934, Expected=2138.1946
# Month=10, Predicted=2137.3437, Expected=2140.8462
# Month=11, Predicted=2140.0393, Expected=2142.5667
# Month=12, Predicted=2142.8080, Expected=2139.5394
# Month=13, Predicted=2140.4664, Expected=2148.6065
# Month=14, Predicted=2149.9455, Expected=2149.5808
# Month=15, Predicted=2149.2783, Expected=2136.8752
# Month=16, Predicted=2136.9759, Expected=2144.1121
# Month=17, Predicted=2145.7246, Expected=2132.2819
# Month=18, Predicted=2131.0814, Expected=2129.8321
# Month=19, Predicted=2130.5493, Expected=2129.0692
# Month=20, Predicted=2128.3377, Expected=2109.4876
# Month=21, Predicted=2108.2303, Expected=2098.9148
# Month=22, Predicted=2100.5482, Expected=2083.8864
# Month=23, Predicted=2083.4731, Expected=2100.6559
# Month=24, Predicted=2100.0683, Expected=2129.8881
# Month=25, Predicted=2127.7393, Expected=2131.6367
# Month=26, Predicted=2131.1834, Expected=2167.4119
# Month=27, Predicted=2171.0833, Expected=2162.6860
# Month=28, Predicted=2165.6552, Expected=2165.5909
# Month=29, Predicted=2172.7881, Expected=2168.2983
# Month=30, Predicted=2172.0259, Expected=2177.7639
# Month=31, Predicted=2178.1770, Expected=2178.4215
# Month=32, Predicted=2176.0877, Expected=2186.9194
# Month=33, Predicted=2185.3203, Expected=2186.2670
# Month=34, Predicted=2185.2272, Expected=2201.5124
# Month=35, Predicted=2202.4825, Expected=2198.6601
# Month=36, Predicted=2199.2944, Expected=2206.2765
# Month=37, Predicted=2209.0115, Expected=2210.1011
# Month=38, Predicted=2211.0742, Expected=2200.6877
# Month=39, Predicted=2200.9512, Expected=2205.0386
# Month=40, Predicted=2206.1803, Expected=2200.0961
# Month=41, Predicted=2198.8924, Expected=2191.1420
# Month=42, Predicted=2190.5394, Expected=2200.6545
# Month=43, Predicted=2200.5862, Expected=2207.1942
# Month=44, Predicted=2205.8835, Expected=2210.9366
# Month=45, Predicted=2210.5409, Expected=2241.1939
# Month=46, Predicted=2242.0091, Expected=2249.5254
# Month=47, Predicted=2250.0956, Expected=2258.8489
# Month=48, Predicted=2261.9193, Expected=2263.2532
# Month=49, Predicted=2266.0870, Expected=2268.4362
# Month=50, Predicted=2270.6336, Expected=2253.6900
# Month=51, Predicted=2254.2381, Expected=2266.7985
# Month=52, Predicted=2268.9315, Expected=2259.2910
# Month=53, Predicted=2257.3231, Expected=2266.5875
# Month=54, Predicted=2266.4391, Expected=2270.4188
# Month=55, Predicted=2269.4518, Expected=2262.8961
# Month=56, Predicted=2262.7448, Expected=2260.2020
# Month=57, Predicted=2261.8327, Expected=2266.1640
# Month=58, Predicted=2266.8331, Expected=2270.4083
# Month=59, Predicted=2269.5939, Expected=2249.5409
# Month=60, Predicted=2248.7155, Expected=2251.4827
# Run 13 — RMSE: 11.325631, MSE: 128.269915, NMSE: 0.0007704982
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=2155.6384, Expected=2158.3065
# Month=2, Predicted=2159.5399, Expected=2164.2116
# Month=3, Predicted=2163.8576, Expected=2160.2640
# Month=4, Predicted=2159.8385, Expected=2161.3676
# Month=5, Predicted=2162.2693, Expected=2137.7089
# Month=6, Predicted=2137.4767, Expected=2130.1707
# Month=7, Predicted=2133.9904, Expected=2139.6955
# Month=8, Predicted=2139.5092, Expected=2132.9558
# Month=9, Predicted=2131.2841, Expected=2138.1946
# Month=10, Predicted=2139.0693, Expected=2140.8462
# Month=11, Predicted=2140.5197, Expected=2142.5667
# Month=12, Predicted=2142.7478, Expected=2139.5394
# Month=13, Predicted=2139.8357, Expected=2148.6065
# Month=14, Predicted=2149.3516, Expected=2149.5808
# Month=15, Predicted=2148.9382, Expected=2136.8752
# Month=16, Predicted=2137.2144, Expected=2144.1121
# Month=17, Predicted=2146.0892, Expected=2132.2819
# Month=18, Predicted=2131.0862, Expected=2129.8321
# Month=19, Predicted=2131.3199, Expected=2129.0692
# Month=20, Predicted=2128.7554, Expected=2109.4876
# Month=21, Predicted=2108.8153, Expected=2098.9148
# Month=22, Predicted=2101.2508, Expected=2083.8864
# Month=23, Predicted=2083.8761, Expected=2100.6559
# Month=24, Predicted=2101.1012, Expected=2129.8881
# Month=25, Predicted=2128.8465, Expected=2131.6367
# Month=26, Predicted=2131.3568, Expected=2167.4119
# Month=27, Predicted=2170.3537, Expected=2162.6860
# Month=28, Predicted=2162.0465, Expected=2165.5909
# Month=29, Predicted=2170.0745, Expected=2168.2983
# Month=30, Predicted=2169.4373, Expected=2177.7639
# Month=31, Predicted=2177.9669, Expected=2178.4215
# Month=32, Predicted=2177.7267, Expected=2186.9194
# Month=33, Predicted=2187.3819, Expected=2186.2670
# Month=34, Predicted=2185.6203, Expected=2201.5124
# Month=35, Predicted=2201.9761, Expected=2198.6601
# Month=36, Predicted=2197.3600, Expected=2206.2765
# Month=37, Predicted=2207.3715, Expected=2210.1011
# Month=38, Predicted=2209.4225, Expected=2200.6877
# Month=39, Predicted=2200.2645, Expected=2205.0386
# Month=40, Predicted=2206.1885, Expected=2200.0961
# Month=41, Predicted=2198.8716, Expected=2191.1420
# Month=42, Predicted=2191.0377, Expected=2200.6545
# Month=43, Predicted=2200.8033, Expected=2207.1942
# Month=44, Predicted=2205.5163, Expected=2210.9366
# Month=45, Predicted=2210.1894, Expected=2241.1939
# Month=46, Predicted=2241.2397, Expected=2249.5254
# Month=47, Predicted=2248.2303, Expected=2258.8489
# Month=48, Predicted=2260.2363, Expected=2263.2532
# Month=49, Predicted=2263.5063, Expected=2268.4362
# Month=50, Predicted=2268.5801, Expected=2253.6900
# Month=51, Predicted=2252.9989, Expected=2266.7985
# Month=52, Predicted=2268.8290, Expected=2259.2910
# Month=53, Predicted=2256.9982, Expected=2266.5875
# Month=54, Predicted=2267.1706, Expected=2270.4188
# Month=55, Predicted=2269.0641, Expected=2262.8961
# Month=56, Predicted=2262.0715, Expected=2260.2020
# Month=57, Predicted=2260.8000, Expected=2266.1640
# Month=58, Predicted=2265.6049, Expected=2270.4083
# Month=59, Predicted=2269.0037, Expected=2249.5409
# Month=60, Predicted=2248.4439, Expected=2251.4827
# Run 14 — RMSE: 11.328376, MSE: 128.332113, NMSE: 0.0007856742
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=2160.3841, Expected=2158.3065
# Month=2, Predicted=2164.5837, Expected=2164.2116
# Month=3, Predicted=2167.3545, Expected=2160.2640
# Month=4, Predicted=2163.2610, Expected=2161.3676
# Month=5, Predicted=2166.7278, Expected=2137.7089
# Month=6, Predicted=2141.8499, Expected=2130.1707
# Month=7, Predicted=2141.4492, Expected=2139.6955
# Month=8, Predicted=2143.7778, Expected=2132.9558
# Month=9, Predicted=2134.0221, Expected=2138.1946
# Month=10, Predicted=2143.9781, Expected=2140.8462
# Month=11, Predicted=2143.7553, Expected=2142.5667
# Month=12, Predicted=2146.1034, Expected=2139.5394
# Month=13, Predicted=2143.1733, Expected=2148.6065
# Month=14, Predicted=2152.8198, Expected=2149.5808
# Month=15, Predicted=2151.5793, Expected=2136.8752
# Month=16, Predicted=2140.9829, Expected=2144.1121
# Month=17, Predicted=2150.7839, Expected=2132.2819
# Month=18, Predicted=2134.5183, Expected=2129.8321
# Month=19, Predicted=2136.7881, Expected=2129.0692
# Month=20, Predicted=2132.7256, Expected=2109.4876
# Month=21, Predicted=2112.9541, Expected=2098.9148
# Month=22, Predicted=2107.5613, Expected=2083.8864
# Month=23, Predicted=2088.4427, Expected=2100.6559
# Month=24, Predicted=2105.8811, Expected=2129.8881
# Month=25, Predicted=2129.9550, Expected=2131.6367
# Month=26, Predicted=2131.7804, Expected=2167.4119
# Month=27, Predicted=2172.3433, Expected=2162.6860
# Month=28, Predicted=2164.5109, Expected=2165.5909
# Month=29, Predicted=2174.6235, Expected=2168.2983
# Month=30, Predicted=2173.3475, Expected=2177.7639
# Month=31, Predicted=2181.5120, Expected=2178.4215
# Month=32, Predicted=2180.9600, Expected=2186.9194
# Month=33, Predicted=2191.2484, Expected=2186.2670
# Month=34, Predicted=2189.2375, Expected=2201.5124
# Month=35, Predicted=2205.9552, Expected=2198.6601
# Month=36, Predicted=2200.7847, Expected=2206.2765
# Month=37, Predicted=2212.0377, Expected=2210.1011
# Month=38, Predicted=2213.2929, Expected=2200.6877
# Month=39, Predicted=2204.6252, Expected=2205.0386
# Month=40, Predicted=2211.2971, Expected=2200.0961
# Month=41, Predicted=2202.9770, Expected=2191.1420
# Month=42, Predicted=2196.0969, Expected=2200.6545
# Month=43, Predicted=2205.6923, Expected=2207.1942
# Month=44, Predicted=2208.8463, Expected=2210.9366
# Month=45, Predicted=2213.7508, Expected=2241.1939
# Month=46, Predicted=2244.1467, Expected=2249.5254
# Month=47, Predicted=2250.2244, Expected=2258.8489
# Month=48, Predicted=2263.2837, Expected=2263.2532
# Month=49, Predicted=2267.0318, Expected=2268.4362
# Month=50, Predicted=2272.2441, Expected=2253.6900
# Month=51, Predicted=2257.1728, Expected=2266.7985
# Month=52, Predicted=2274.0627, Expected=2259.2910
# Month=53, Predicted=2261.2870, Expected=2266.5875
# Month=54, Predicted=2273.2262, Expected=2270.4188
# Month=55, Predicted=2273.5085, Expected=2262.8961
# Month=56, Predicted=2266.8211, Expected=2260.2020
# Month=57, Predicted=2266.2662, Expected=2266.1640
# Month=58, Predicted=2270.1038, Expected=2270.4083
# Month=59, Predicted=2272.7127, Expected=2249.5409
# Month=60, Predicted=2253.0400, Expected=2251.4827
# Run 15 — RMSE: 11.813233, MSE: 139.552467, NMSE: 0.0008501227
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=2155.8174, Expected=2158.3065
# Month=2, Predicted=2159.5672, Expected=2164.2116
# Month=3, Predicted=2163.6038, Expected=2160.2640
# Month=4, Predicted=2160.0561, Expected=2161.3676
# Month=5, Predicted=2162.6220, Expected=2137.7089
# Month=6, Predicted=2137.7802, Expected=2130.1707
# Month=7, Predicted=2133.8642, Expected=2139.6955
# Month=8, Predicted=2139.1619, Expected=2132.9558
# Month=9, Predicted=2131.7460, Expected=2138.1946
# Month=10, Predicted=2140.0207, Expected=2140.8462
# Month=11, Predicted=2140.5554, Expected=2142.5667
# Month=12, Predicted=2142.9570, Expected=2139.5394
# Month=13, Predicted=2139.9450, Expected=2148.6065
# Month=14, Predicted=2149.3326, Expected=2149.5808
# Month=15, Predicted=2148.7718, Expected=2136.8752
# Month=16, Predicted=2137.6504, Expected=2144.1121
# Month=17, Predicted=2146.1833, Expected=2132.2819
# Month=18, Predicted=2130.9458, Expected=2129.8321
# Month=19, Predicted=2131.9003, Expected=2129.0692
# ...
# Month=10, Predicted=2137.1127, Expected=2140.9908
# Month=11, Predicted=2140.3821, Expected=2142.7933
# Month=12, Predicted=2142.7288, Expected=2139.9770
# Month=13, Predicted=2140.3079, Expected=2149.0323
# Month=14, Predicted=2149.6054, Expected=2149.0240
# Month=15, Predicted=2148.5204, Expected=2136.4962
# Month=16, Predicted=2136.7241, Expected=2144.3202
# Month=17, Predicted=2145.7956, Expected=2132.4895
# Month=18, Predicted=2131.7165, Expected=2130.0402
# Month=19, Predicted=2131.0883, Expected=2130.6262
# Month=20, Predicted=2130.2491, Expected=2109.7183
# Month=21, Predicted=2108.8890, Expected=2099.3737
# Month=22, Predicted=2101.1901, Expected=2084.2720
# Month=23, Predicted=2083.7073, Expected=2100.9191
# Month=24, Predicted=2099.7871, Expected=2129.7607
# Month=25, Predicted=2128.0076, Expected=2131.9435
# Month=26, Predicted=2131.0065, Expected=2167.0996
# Month=27, Predicted=2167.8013, Expected=2162.5903
# Month=28, Predicted=2163.6527, Expected=2165.3947
# Month=29, Predicted=2170.2787, Expected=2168.3314
# Month=30, Predicted=2171.4610, Expected=2178.6993
# Month=31, Predicted=2179.7510, Expected=2177.6668
# Month=32, Predicted=2176.5920, Expected=2187.1968
# Month=33, Predicted=2186.7280, Expected=2185.6153
# Month=34, Predicted=2184.3902, Expected=2201.3217
# Month=35, Predicted=2201.3725, Expected=2199.1001
# Month=36, Predicted=2198.4941, Expected=2206.3025
# Month=37, Predicted=2207.7190, Expected=2209.6655
# Month=38, Predicted=2210.3664, Expected=2200.3987
# Month=39, Predicted=2201.4684, Expected=2205.3133
# Month=40, Predicted=2207.4793, Expected=2199.8010
# Month=41, Predicted=2199.7992, Expected=2191.2295
# Month=42, Predicted=2191.8624, Expected=2200.6729
# Month=43, Predicted=2200.9939, Expected=2206.9309
# Month=44, Predicted=2205.7380, Expected=2211.8030
# Month=45, Predicted=2211.0968, Expected=2241.4501
# Month=46, Predicted=2241.1164, Expected=2248.7070
# Month=47, Predicted=2248.0953, Expected=2258.9243
# Month=48, Predicted=2259.9174, Expected=2262.9858
# Month=49, Predicted=2264.1004, Expected=2268.7807
# Month=50, Predicted=2270.1008, Expected=2253.3697
# Month=51, Predicted=2254.1621, Expected=2266.7521
# Month=52, Predicted=2269.8513, Expected=2259.4951
# Month=53, Predicted=2258.5464, Expected=2266.9373
# Month=54, Predicted=2267.9613, Expected=2269.9337
# Month=55, Predicted=2269.8413, Expected=2262.7610
# Month=56, Predicted=2263.3465, Expected=2260.0101
# Month=57, Predicted=2261.7910, Expected=2265.8999
# Month=58, Predicted=2266.6778, Expected=2271.1218
# Month=59, Predicted=2270.6798, Expected=2249.7046
# Month=60, Predicted=2249.4437, Expected=2250.9732
# Run 7 — RMSE: 11.440547, MSE: 130.886116, NMSE: 0.0007884286
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=2154.2233, Expected=2158.6526
# Month=2, Predicted=2159.5310, Expected=2164.2981
# Month=3, Predicted=2163.4455, Expected=2159.7606
# Month=4, Predicted=2158.5787, Expected=2161.4376
# Month=5, Predicted=2161.8923, Expected=2137.8646
# Month=6, Predicted=2137.4440, Expected=2129.8135
# Month=7, Predicted=2132.9713, Expected=2139.7576
# Month=8, Predicted=2139.6237, Expected=2132.9794
# Month=9, Predicted=2130.4324, Expected=2137.7327
# Month=10, Predicted=2137.8544, Expected=2140.9908
# Month=11, Predicted=2140.8161, Expected=2142.7933
# Month=12, Predicted=2141.6021, Expected=2139.9770
# Month=13, Predicted=2139.7875, Expected=2149.0323
# Month=14, Predicted=2149.0063, Expected=2149.0240
# Month=15, Predicted=2148.2581, Expected=2136.4962
# Month=16, Predicted=2136.3660, Expected=2144.3202
# Month=17, Predicted=2146.0928, Expected=2132.4895
# Month=18, Predicted=2131.5055, Expected=2130.0402
# Month=19, Predicted=2130.8035, Expected=2130.6262
# Month=20, Predicted=2130.7430, Expected=2109.7183
# Month=21, Predicted=2108.1572, Expected=2099.3737
# Month=22, Predicted=2101.7388, Expected=2084.2720
# Month=23, Predicted=2083.9876, Expected=2100.9191
# Month=24, Predicted=2099.7991, Expected=2129.7607
# Month=25, Predicted=2130.0358, Expected=2131.9435
# Month=26, Predicted=2130.4863, Expected=2167.0996
# Month=27, Predicted=2168.3767, Expected=2162.5903
# Month=28, Predicted=2163.3291, Expected=2165.3947
# Month=29, Predicted=2169.1912, Expected=2168.3314
# Month=30, Predicted=2170.6391, Expected=2178.6993
# Month=31, Predicted=2178.4431, Expected=2177.6668
# Month=32, Predicted=2177.3516, Expected=2187.1968
# Month=33, Predicted=2188.0316, Expected=2185.6153
# Month=34, Predicted=2185.4519, Expected=2201.3217
# Month=35, Predicted=2201.6496, Expected=2199.1001
# Month=36, Predicted=2198.7040, Expected=2206.3025
# Month=37, Predicted=2207.1017, Expected=2209.6655
# Month=38, Predicted=2209.9502, Expected=2200.3987
# Month=39, Predicted=2199.9837, Expected=2205.3133
# Month=40, Predicted=2206.8983, Expected=2199.8010
# Month=41, Predicted=2199.2178, Expected=2191.2295
# Month=42, Predicted=2191.1639, Expected=2200.6729
# Month=43, Predicted=2201.2399, Expected=2206.9309
# Month=44, Predicted=2205.7635, Expected=2211.8030
# Month=45, Predicted=2210.7445, Expected=2241.4501
# Month=46, Predicted=2241.4762, Expected=2248.7070
# Month=47, Predicted=2248.2630, Expected=2258.9243
# Month=48, Predicted=2259.8467, Expected=2262.9858
# Month=49, Predicted=2264.0384, Expected=2268.7807
# Month=50, Predicted=2269.3267, Expected=2253.3697
# Month=51, Predicted=2253.7780, Expected=2266.7521
# Month=52, Predicted=2270.0110, Expected=2259.4951
# Month=53, Predicted=2258.9766, Expected=2266.9373
# Month=54, Predicted=2267.6312, Expected=2269.9337
# Month=55, Predicted=2270.1788, Expected=2262.7610
# Month=56, Predicted=2261.9509, Expected=2260.0101
# Month=57, Predicted=2261.0908, Expected=2265.8999
# Month=58, Predicted=2265.6503, Expected=2271.1218
# Month=59, Predicted=2269.9153, Expected=2249.7046
# Month=60, Predicted=2248.9347, Expected=2250.9732
# Run 8 — RMSE: 11.457957, MSE: 131.284769, NMSE: 0.0007935385
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=2154.2241, Expected=2158.6526
# Month=2, Predicted=2159.8911, Expected=2164.2981
# Month=3, Predicted=2163.4204, Expected=2159.7606
# Month=4, Predicted=2158.6398, Expected=2161.4376
# Month=5, Predicted=2162.3420, Expected=2137.8646
# Month=6, Predicted=2137.7882, Expected=2129.8135
# Month=7, Predicted=2133.4771, Expected=2139.7576
# Month=8, Predicted=2139.5774, Expected=2132.9794
# Month=9, Predicted=2130.3381, Expected=2137.7327
# Month=10, Predicted=2137.8559, Expected=2140.9908
# Month=11, Predicted=2140.7010, Expected=2142.7933
# Month=12, Predicted=2141.5650, Expected=2139.9770
# Month=13, Predicted=2139.8365, Expected=2149.0323
# Month=14, Predicted=2149.0966, Expected=2149.0240
# Month=15, Predicted=2148.0166, Expected=2136.4962
# Month=16, Predicted=2136.6218, Expected=2144.3202
# Month=17, Predicted=2146.4767, Expected=2132.4895
# Month=18, Predicted=2131.2946, Expected=2130.0402
# Month=19, Predicted=2130.9923, Expected=2130.6262
# Month=20, Predicted=2130.7326, Expected=2109.7183
# Month=21, Predicted=2108.4876, Expected=2099.3737
# Month=22, Predicted=2102.1678, Expected=2084.2720
# Month=23, Predicted=2084.2175, Expected=2100.9191
# Month=24, Predicted=2100.1228, Expected=2129.7607
# Month=25, Predicted=2129.2244, Expected=2131.9435
# Month=26, Predicted=2130.6154, Expected=2167.0996
# Month=27, Predicted=2169.2788, Expected=2162.5903
# Month=28, Predicted=2163.2192, Expected=2165.3947
# Month=29, Predicted=2169.2819, Expected=2168.3314
# Month=30, Predicted=2169.7998, Expected=2178.6993
# Month=31, Predicted=2177.9826, Expected=2177.6668
# Month=32, Predicted=2177.3694, Expected=2187.1968
# Month=33, Predicted=2188.6937, Expected=2185.6153
# Month=34, Predicted=2185.7746, Expected=2201.3217
# Month=35, Predicted=2202.2697, Expected=2199.1001
# Month=36, Predicted=2198.8461, Expected=2206.3025
# Month=37, Predicted=2207.8612, Expected=2209.6655
# Month=38, Predicted=2210.1694, Expected=2200.3987
# Month=39, Predicted=2200.5673, Expected=2205.3133
# Month=40, Predicted=2207.7811, Expected=2199.8010
# Month=41, Predicted=2199.4099, Expected=2191.2295
# Month=42, Predicted=2191.7714, Expected=2200.6729
# Month=43, Predicted=2201.8875, Expected=2206.9309
# Month=44, Predicted=2205.7583, Expected=2211.8030
# Month=45, Predicted=2210.9343, Expected=2241.4501
# Month=46, Predicted=2241.8245, Expected=2248.7070
# Month=47, Predicted=2248.4067, Expected=2258.9243
# Month=48, Predicted=2260.6840, Expected=2262.9858
# Month=49, Predicted=2264.4103, Expected=2268.7807
# Month=50, Predicted=2269.4824, Expected=2253.3697
# Month=51, Predicted=2254.2705, Expected=2266.7521
# Month=52, Predicted=2271.0441, Expected=2259.4951
# Month=53, Predicted=2258.7079, Expected=2266.9373
# Month=54, Predicted=2268.0512, Expected=2269.9337
# Month=55, Predicted=2270.3016, Expected=2262.7610
# Month=56, Predicted=2262.4586, Expected=2260.0101
# Month=57, Predicted=2261.8319, Expected=2265.8999
# Month=58, Predicted=2266.0254, Expected=2271.1218
# Month=59, Predicted=2269.9520, Expected=2249.7046
# Month=60, Predicted=2249.4693, Expected=2250.9732
# Run 9 — RMSE: 11.459666, MSE: 131.323953, NMSE: 0.0007901672
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=2155.0907, Expected=2158.6526
# Month=2, Predicted=2159.4033, Expected=2164.2981
# Month=3, Predicted=2163.3720, Expected=2159.7606
# Month=4, Predicted=2158.7060, Expected=2161.4376
# Month=5, Predicted=2161.5418, Expected=2137.8646
# Month=6, Predicted=2137.4321, Expected=2129.8135
# Month=7, Predicted=2133.0990, Expected=2139.7576
# Month=8, Predicted=2139.9712, Expected=2132.9794
# Month=9, Predicted=2130.7625, Expected=2137.7327
# Month=10, Predicted=2137.3664, Expected=2140.9908
# Month=11, Predicted=2140.8541, Expected=2142.7933
# Month=12, Predicted=2143.1050, Expected=2139.9770
# Month=13, Predicted=2140.4058, Expected=2149.0323
# Month=14, Predicted=2149.5710, Expected=2149.0240
# Month=15, Predicted=2147.9813, Expected=2136.4962
# Month=16, Predicted=2136.3586, Expected=2144.3202
# Month=17, Predicted=2145.6580, Expected=2132.4895
# Month=18, Predicted=2130.8565, Expected=2130.0402
# Month=19, Predicted=2130.4141, Expected=2130.6262
# Month=20, Predicted=2129.8346, Expected=2109.7183
# Month=21, Predicted=2108.7087, Expected=2099.3737
# Month=22, Predicted=2101.0797, Expected=2084.2720
# Month=23, Predicted=2084.4611, Expected=2100.9191
# Month=24, Predicted=2101.0224, Expected=2129.7607
# Month=25, Predicted=2128.8053, Expected=2131.9435
# Month=26, Predicted=2135.5403, Expected=2167.0996
# Month=27, Predicted=2170.9336, Expected=2162.5903
# Month=28, Predicted=2165.5112, Expected=2165.3947
# Month=29, Predicted=2169.9499, Expected=2168.3314
# Month=30, Predicted=2169.8292, Expected=2178.6993
# Month=31, Predicted=2178.5429, Expected=2177.6668
# Month=32, Predicted=2174.9942, Expected=2187.1968
# Month=33, Predicted=2185.8677, Expected=2185.6153
# Month=34, Predicted=2184.1842, Expected=2201.3217
# Month=35, Predicted=2201.3274, Expected=2199.1001
# Month=36, Predicted=2199.1613, Expected=2206.3025
# Month=37, Predicted=2207.6522, Expected=2209.6655
# Month=38, Predicted=2209.6261, Expected=2200.3987
# Month=39, Predicted=2200.4271, Expected=2205.3133
# Month=40, Predicted=2206.8079, Expected=2199.8010
# Month=41, Predicted=2198.5807, Expected=2191.2295
# Month=42, Predicted=2190.8677, Expected=2200.6729
# Month=43, Predicted=2200.4663, Expected=2206.9309
# Month=44, Predicted=2205.6514, Expected=2211.8030
# Month=45, Predicted=2211.7655, Expected=2241.4501
# Month=46, Predicted=2242.0692, Expected=2248.7070
# Month=47, Predicted=2250.2433, Expected=2258.9243
# Month=48, Predicted=2261.3527, Expected=2262.9858
# Month=49, Predicted=2263.6877, Expected=2268.7807
# Month=50, Predicted=2269.2964, Expected=2253.3697
# Month=51, Predicted=2252.8632, Expected=2266.7521
# Month=52, Predicted=2269.6310, Expected=2259.4951
# Month=53, Predicted=2256.8393, Expected=2266.9373
# Month=54, Predicted=2266.3390, Expected=2269.9337
# Month=55, Predicted=2268.9519, Expected=2262.7610
# Month=56, Predicted=2262.8606, Expected=2260.0101
# Month=57, Predicted=2261.0494, Expected=2265.8999
# Month=58, Predicted=2266.2107, Expected=2271.1218
# Month=59, Predicted=2270.2331, Expected=2249.7046
# Month=60, Predicted=2249.1462, Expected=2250.9732
# Run 10 — RMSE: 11.120449, MSE: 123.664390, NMSE: 0.0007517435
#
# ===== RUN 11/30 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 145
#     143 run_losses = []
#     144 for epoch in range(100):
# --> 145     history = model.fit(
#     146         X_train, y_train,
#     147         epochs=1, batch_size=1,
#     148         verbose=0, shuffle=False
#     149     )
#     150     run_losses.append(history.history['loss'][0])
#     151     rnn_layer.reset_states()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/engine/training.py:1798, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1796 callbacks.on_epoch_begin(epoch)
#    1797 with data_handler.catch_stop_iteration():
# -> 1798     for step in data_handler.steps():
#    1799         with tf.profiler.experimental.Trace(
#    1800             "train",
#    1801             epoch_num=epoch,
#    (...)   1804             _r=1,
#    1805         ):
#    1806             callbacks.on_train_batch_begin(step)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1411, in DataHandler.steps(self)
#    1409 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410     break
# -> 1411 original_spe = self._steps_per_execution.numpy().item()
#    1412 can_run_full_execution = (
#    1413     original_spe == 1
#    1414     or self._inferred_steps is None
#    1415     or self._inferred_steps - self._current_step >= original_spe
#    1416 )
#    1418 if can_run_full_execution:
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:689, in BaseResourceVariable.numpy(self)
#     687 def numpy(self):
#     688   if context.executing_eagerly():
# --> 689     return self.read_value().numpy()
#     690   raise NotImplementedError(
#     691       "numpy() is only available when eager execution is enabled.")
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:839, in BaseResourceVariable.read_value(self)
#     830 """Constructs an op which reads the value of this variable.
#     831
#     832 Should be used when there are multiple reads, or when it is desirable to
#    (...)    836   The value of the variable.
#     837 """
#     838 with ops.name_scope("Read"):
# --> 839   value = self._read_variable_op()
#     840 # Return an identity so it can get placed on whatever device the context
#     841 # specifies instead of the device where the variable is.
#     842 return array_ops.identity(value)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:803, in BaseResourceVariable._read_variable_op(self, no_copy)
#     791 def _read_variable_op(self, no_copy=False):
#     792   """Reads the value of the variable.
#     793
#     794   If the variable is in copy-on-read mode and `no_copy` is True, the variable
#    (...)    801     The value of the variable.
#     802   """
# --> 803   variable_accessed(self)
#     805   def read_and_set_handle(no_copy):
#     806     if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:332, in variable_accessed(variable)
#     330 def variable_accessed(variable):
#     331   """Records that `variable` was accessed for the tape and FuncGraph."""
# --> 332   if hasattr(ops.get_default_graph(), "watch_variable"):
#     333     ops.get_default_graph().watch_variable(variable)
#     334   if variable.trainable:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on S&P 500
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
