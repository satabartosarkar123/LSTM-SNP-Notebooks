# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    352
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 361 (1.41 KB)
# Trainable params: 361 (1.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Lake Erie Levels (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.1% (lambda=0.001, sigma=0.002010)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.76399861 14.64872203 15.08630213 16.37906193 16.92552925]
# Supervised data shape: (599, 3)
# Train: (539, 3), Test: (60, 3)
# X_train shape: (539, 1, 2), y_train shape: (539,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.3100, Expected=13.7017
# Month=2, Predicted=14.1549, Expected=13.8117
# Month=3, Predicted=14.5211, Expected=14.3841
# Month=4, Predicted=15.2408, Expected=15.0499
# Month=5, Predicted=15.5093, Expected=15.6880
# Month=6, Predicted=15.6495, Expected=15.8424
# Month=7, Predicted=15.6138, Expected=15.7132
# Month=8, Predicted=15.2400, Expected=15.3126
# Month=9, Predicted=14.6912, Expected=14.7637
# Month=10, Predicted=14.2562, Expected=13.5468
# Month=11, Predicted=13.0598, Expected=13.5862
# Month=12, Predicted=13.5784, Expected=14.5157
# Month=13, Predicted=14.7465, Expected=14.3853
# Month=14, Predicted=14.5583, Expected=14.4975
# Month=15, Predicted=15.5366, Expected=14.7447
# Month=16, Predicted=15.4503, Expected=15.8052
# Month=17, Predicted=15.9809, Expected=16.5260
# Month=18, Predicted=16.5956, Expected=16.5451
# Month=19, Predicted=16.1296, Expected=16.7178
# Month=20, Predicted=16.3618, Expected=16.4322
# Month=21, Predicted=15.8656, Expected=15.7696
# Month=22, Predicted=15.2057, Expected=15.2792
# Month=23, Predicted=14.9606, Expected=15.1248
# Month=24, Predicted=15.1128, Expected=15.5403
# Month=25, Predicted=15.8263, Expected=15.8274
# Month=26, Predicted=16.3409, Expected=16.3752
# Month=27, Predicted=17.3295, Expected=16.3529
# Month=28, Predicted=16.9537, Expected=16.9050
# Month=29, Predicted=17.0772, Expected=17.0172
# Month=30, Predicted=16.9303, Expected=17.4183
# Month=31, Predicted=17.1625, Expected=17.5330
# Month=32, Predicted=17.2545, Expected=17.2714
# Month=33, Predicted=16.7532, Expected=16.6037
# Month=34, Predicted=16.1283, Expected=15.8246
# Month=35, Predicted=15.4710, Expected=15.4477
# Month=36, Predicted=15.4035, Expected=15.6316
# Month=37, Predicted=15.9112, Expected=15.6935
# Month=38, Predicted=16.1393, Expected=16.7565
# Month=39, Predicted=17.7432, Expected=16.5060
# Month=40, Predicted=17.1449, Expected=17.7253
# Month=41, Predicted=17.9235, Expected=18.6917
# Month=42, Predicted=19.0228, Expected=19.1262
# Month=43, Predicted=18.6317, Expected=19.5653
# Month=44, Predicted=19.3382, Expected=19.2076
# Month=45, Predicted=18.5611, Expected=18.2164
# Month=46, Predicted=17.3799, Expected=17.2115
# Month=47, Predicted=16.6074, Expected=16.6591
# Month=48, Predicted=16.3973, Expected=16.8293
# Month=49, Predicted=16.9351, Expected=15.7707
# Month=50, Predicted=15.8576, Expected=15.7293
# Month=51, Predicted=16.6731, Expected=15.9961
# Month=52, Predicted=16.9580, Expected=17.0200
# Month=53, Predicted=17.6349, Expected=17.5530
# Month=54, Predicted=17.9113, Expected=17.8377
# Month=55, Predicted=17.6771, Expected=17.8581
# Month=56, Predicted=17.6764, Expected=17.5700
# Month=57, Predicted=17.0740, Expected=17.0775
# Month=58, Predicted=16.4636, Expected=16.6580
# Month=59, Predicted=16.2000, Expected=16.4321
# Month=60, Predicted=16.2244, Expected=16.5848
# Run 1 — RMSE: 0.439212, MSE: 0.192908, NMSE: 0.0018088782
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2968, Expected=13.7017
# Month=2, Predicted=14.1868, Expected=13.8117
# Month=3, Predicted=14.4130, Expected=14.3841
# Month=4, Predicted=14.9841, Expected=15.0499
# Month=5, Predicted=15.3060, Expected=15.6880
# Month=6, Predicted=15.7003, Expected=15.8424
# Month=7, Predicted=15.5680, Expected=15.7132
# Month=8, Predicted=15.2661, Expected=15.3126
# Month=9, Predicted=14.7879, Expected=14.7637
# Month=10, Predicted=14.2831, Expected=13.5468
# Month=11, Predicted=12.9274, Expected=13.5862
# Month=12, Predicted=13.6232, Expected=14.5157
# Month=13, Predicted=14.6489, Expected=14.3853
# Month=14, Predicted=14.5347, Expected=14.4975
# Month=15, Predicted=15.2412, Expected=14.7447
# Month=16, Predicted=15.2121, Expected=15.8052
# Month=17, Predicted=16.0416, Expected=16.5260
# Month=18, Predicted=16.5822, Expected=16.5451
# Month=19, Predicted=16.1817, Expected=16.7178
# Month=20, Predicted=16.4094, Expected=16.4322
# Month=21, Predicted=15.9919, Expected=15.7696
# Month=22, Predicted=15.2602, Expected=15.2792
# Month=23, Predicted=14.9573, Expected=15.1248
# Month=24, Predicted=15.0718, Expected=15.5403
# Month=25, Predicted=15.7553, Expected=15.8274
# Month=26, Predicted=16.2320, Expected=16.3752
# Month=27, Predicted=17.1306, Expected=16.3529
# Month=28, Predicted=16.7589, Expected=16.9050
# Month=29, Predicted=17.0570, Expected=17.0172
# Month=30, Predicted=16.8618, Expected=17.4183
# Month=31, Predicted=17.2306, Expected=17.5330
# Month=32, Predicted=17.2462, Expected=17.2714
# Month=33, Predicted=16.8998, Expected=16.6037
# Month=34, Predicted=16.1841, Expected=15.8246
# Month=35, Predicted=15.4855, Expected=15.4477
# Month=36, Predicted=15.4100, Expected=15.6316
# Month=37, Predicted=15.8778, Expected=15.6935
# Month=38, Predicted=16.0732, Expected=16.7565
# Month=39, Predicted=17.5779, Expected=16.5060
# Month=40, Predicted=17.0491, Expected=17.7253
# Month=41, Predicted=18.0474, Expected=18.6917
# Month=42, Predicted=18.8830, Expected=19.1262
# Month=43, Predicted=18.9294, Expected=19.5653
# Month=44, Predicted=19.3245, Expected=19.2076
# Month=45, Predicted=18.6409, Expected=18.2164
# Month=46, Predicted=17.3967, Expected=17.2115
# Month=47, Predicted=16.5494, Expected=16.6591
# Month=48, Predicted=16.2780, Expected=16.8293
# Month=49, Predicted=16.7901, Expected=15.7707
# Month=50, Predicted=15.5662, Expected=15.7293
# Month=51, Predicted=16.4525, Expected=15.9961
# Month=52, Predicted=16.8424, Expected=17.0200
# Month=53, Predicted=17.8941, Expected=17.5530
# Month=54, Predicted=18.0268, Expected=17.8377
# Month=55, Predicted=17.8178, Expected=17.8581
# Month=56, Predicted=17.6005, Expected=17.5700
# Month=57, Predicted=17.0776, Expected=17.0775
# Month=58, Predicted=16.4694, Expected=16.6580
# Month=59, Predicted=16.2098, Expected=16.4321
# Month=60, Predicted=16.1973, Expected=16.5848
# Run 2 — RMSE: 0.414542, MSE: 0.171845, NMSE: 0.0015482807
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2583, Expected=13.7017
# Month=2, Predicted=14.0241, Expected=13.8117
# Month=3, Predicted=14.5606, Expected=14.3841
# Month=4, Predicted=15.0234, Expected=15.0499
# Month=5, Predicted=15.3362, Expected=15.6880
# Month=6, Predicted=15.7201, Expected=15.8424
# Month=7, Predicted=15.6428, Expected=15.7132
# Month=8, Predicted=15.3389, Expected=15.3126
# Month=9, Predicted=14.7750, Expected=14.7637
# Month=10, Predicted=14.2700, Expected=13.5468
# Month=11, Predicted=13.0412, Expected=13.5862
# Month=12, Predicted=13.6276, Expected=14.5157
# Month=13, Predicted=14.6538, Expected=14.3853
# Month=14, Predicted=14.5847, Expected=14.4975
# Month=15, Predicted=15.4018, Expected=14.7447
# Month=16, Predicted=15.3582, Expected=15.8052
# Month=17, Predicted=16.0996, Expected=16.5260
# Month=18, Predicted=16.6613, Expected=16.5451
# Month=19, Predicted=16.2693, Expected=16.7178
# Month=20, Predicted=16.4160, Expected=16.4322
# Month=21, Predicted=15.9747, Expected=15.7696
# Month=22, Predicted=15.2748, Expected=15.2792
# Month=23, Predicted=14.9901, Expected=15.1248
# Month=24, Predicted=15.1222, Expected=15.5403
# Month=25, Predicted=15.7228, Expected=15.8274
# Month=26, Predicted=16.2251, Expected=16.3752
# Month=27, Predicted=17.2554, Expected=16.3529
# Month=28, Predicted=16.7531, Expected=16.9050
# Month=29, Predicted=16.9985, Expected=17.0172
# Month=30, Predicted=16.8714, Expected=17.4183
# Month=31, Predicted=17.2336, Expected=17.5330
# Month=32, Predicted=17.2436, Expected=17.2714
# Month=33, Predicted=16.8964, Expected=16.6037
# Month=34, Predicted=16.1880, Expected=15.8246
# Month=35, Predicted=15.5203, Expected=15.4477
# Month=36, Predicted=15.4382, Expected=15.6316
# Month=37, Predicted=15.8618, Expected=15.6935
# Month=38, Predicted=16.1680, Expected=16.7565
# Month=39, Predicted=17.7613, Expected=16.5060
# Month=40, Predicted=16.9066, Expected=17.7253
# Month=41, Predicted=17.7903, Expected=18.6917
# Month=42, Predicted=18.9530, Expected=19.1262
# Month=43, Predicted=19.0580, Expected=19.5653
# Month=44, Predicted=19.4607, Expected=19.2076
# Month=45, Predicted=18.8306, Expected=18.2164
# Month=46, Predicted=17.6073, Expected=17.2115
# Month=47, Predicted=16.7285, Expected=16.6591
# Month=48, Predicted=16.5118, Expected=16.8293
# Month=49, Predicted=17.0016, Expected=15.7707
# Month=50, Predicted=15.8402, Expected=15.7293
# Month=51, Predicted=16.6270, Expected=15.9961
# Month=52, Predicted=17.0103, Expected=17.0200
# Month=53, Predicted=17.6934, Expected=17.5530
# Month=54, Predicted=17.7523, Expected=17.8377
# Month=55, Predicted=17.6594, Expected=17.8581
# Month=56, Predicted=17.5111, Expected=17.5700
# Month=57, Predicted=17.0531, Expected=17.0775
# Month=58, Predicted=16.4983, Expected=16.6580
# Month=59, Predicted=16.2558, Expected=16.4321
# Month=60, Predicted=16.2950, Expected=16.5848
# Run 3 — RMSE: 0.436879, MSE: 0.190863, NMSE: 0.0017274469
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.3385, Expected=13.7017
# Month=2, Predicted=14.3362, Expected=13.8117
# Month=3, Predicted=14.5082, Expected=14.3841
# Month=4, Predicted=15.0317, Expected=15.0499
# Month=5, Predicted=15.4170, Expected=15.6880
# Month=6, Predicted=15.7830, Expected=15.8424
# Month=7, Predicted=15.6325, Expected=15.7132
# Month=8, Predicted=15.2839, Expected=15.3126
# Month=9, Predicted=14.6840, Expected=14.7637
# Month=10, Predicted=14.1826, Expected=13.5468
# Month=11, Predicted=12.8966, Expected=13.5862
# Month=12, Predicted=13.5321, Expected=14.5157
# Month=13, Predicted=14.8320, Expected=14.3853
# Month=14, Predicted=14.8169, Expected=14.4975
# Month=15, Predicted=15.1245, Expected=14.7447
# Month=16, Predicted=15.4650, Expected=15.8052
# Month=17, Predicted=16.3827, Expected=16.5260
# Month=18, Predicted=16.7898, Expected=16.5451
# Month=19, Predicted=16.2486, Expected=16.7178
# Month=20, Predicted=16.4809, Expected=16.4322
# Month=21, Predicted=15.9686, Expected=15.7696
# Month=22, Predicted=15.0766, Expected=15.2792
# Month=23, Predicted=14.8264, Expected=15.1248
# Month=24, Predicted=14.9818, Expected=15.5403
# Month=25, Predicted=15.7528, Expected=15.8274
# Month=26, Predicted=16.3413, Expected=16.3752
# Month=27, Predicted=17.1411, Expected=16.3529
# Month=28, Predicted=16.9177, Expected=16.9050
# Month=29, Predicted=17.3403, Expected=17.0172
# Month=30, Predicted=17.0771, Expected=17.4183
# Month=31, Predicted=17.3869, Expected=17.5330
# Month=32, Predicted=17.3787, Expected=17.2714
# Month=33, Predicted=16.7769, Expected=16.6037
# Month=34, Predicted=15.9490, Expected=15.8246
# Month=35, Predicted=15.2910, Expected=15.4477
# Month=36, Predicted=15.2426, Expected=15.6316
# Month=37, Predicted=15.8056, Expected=15.6935
# Month=38, Predicted=16.1448, Expected=16.7565
# Month=39, Predicted=17.5775, Expected=16.5060
# Month=40, Predicted=16.9866, Expected=17.7253
# Month=41, Predicted=18.1651, Expected=18.6917
# Month=42, Predicted=19.0901, Expected=19.1262
# Month=43, Predicted=19.0089, Expected=19.5653
# Month=44, Predicted=19.4096, Expected=19.2076
# Month=45, Predicted=18.6519, Expected=18.2164
# Month=46, Predicted=17.3366, Expected=17.2115
# Month=47, Predicted=16.5471, Expected=16.6591
# Month=48, Predicted=16.3393, Expected=16.8293
# Month=49, Predicted=16.9044, Expected=15.7707
# Month=50, Predicted=15.7439, Expected=15.7293
# Month=51, Predicted=16.1341, Expected=15.9961
# Month=52, Predicted=16.8170, Expected=17.0200
# Month=53, Predicted=17.8317, Expected=17.5530
# Month=54, Predicted=17.8956, Expected=17.8377
# Month=55, Predicted=17.7665, Expected=17.8581
# Month=56, Predicted=17.5989, Expected=17.5700
# Month=57, Predicted=17.1271, Expected=17.0775
# Month=58, Predicted=16.4117, Expected=16.6580
# Month=59, Predicted=16.1291, Expected=16.4321
# Month=60, Predicted=16.1495, Expected=16.5848
# Run 4 — RMSE: 0.403274, MSE: 0.162630, NMSE: 0.0014268507
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.4614, Expected=13.7017
# Month=2, Predicted=14.3765, Expected=13.8117
# Month=3, Predicted=14.4006, Expected=14.3841
# Month=4, Predicted=14.9179, Expected=15.0499
# Month=5, Predicted=15.3738, Expected=15.6880
# Month=6, Predicted=15.7619, Expected=15.8424
# Month=7, Predicted=15.5739, Expected=15.7132
# Month=8, Predicted=15.1905, Expected=15.3126
# Month=9, Predicted=14.6762, Expected=14.7637
# Month=10, Predicted=14.1732, Expected=13.5468
# Month=11, Predicted=12.8782, Expected=13.5862
# Month=12, Predicted=13.4759, Expected=14.5157
# Month=13, Predicted=15.0356, Expected=14.3853
# Month=14, Predicted=14.9126, Expected=14.4975
# Month=15, Predicted=15.0831, Expected=14.7447
# Month=16, Predicted=15.3125, Expected=15.8052
# Month=17, Predicted=16.3037, Expected=16.5260
# Month=18, Predicted=16.7509, Expected=16.5451
# Month=19, Predicted=16.2765, Expected=16.7178
# Month=20, Predicted=16.3242, Expected=16.4322
# Month=21, Predicted=15.8804, Expected=15.7696
# Month=22, Predicted=15.0707, Expected=15.2792
# Month=23, Predicted=14.8183, Expected=15.1248
# Month=24, Predicted=15.0709, Expected=15.5403
# Month=25, Predicted=15.9234, Expected=15.8274
# Month=26, Predicted=16.4266, Expected=16.3752
# Month=27, Predicted=17.0816, Expected=16.3529
# Month=28, Predicted=16.7202, Expected=16.9050
# Month=29, Predicted=17.2365, Expected=17.0172
# Month=30, Predicted=17.0217, Expected=17.4183
# Month=31, Predicted=17.3433, Expected=17.5330
# Month=32, Predicted=17.3291, Expected=17.2714
# Month=33, Predicted=16.8806, Expected=16.6037
# Month=34, Predicted=16.0712, Expected=15.8246
# Month=35, Predicted=15.3600, Expected=15.4477
# Month=36, Predicted=15.3103, Expected=15.6316
# Month=37, Predicted=15.9267, Expected=15.6935
# Month=38, Predicted=16.1753, Expected=16.7565
# Month=39, Predicted=17.4766, Expected=16.5060
# Month=40, Predicted=16.7765, Expected=17.7253
# Month=41, Predicted=18.1615, Expected=18.6917
# Month=42, Predicted=19.1236, Expected=19.1262
# Month=43, Predicted=19.1917, Expected=19.5653
# Month=44, Predicted=19.4028, Expected=19.2076
# Month=45, Predicted=18.6081, Expected=18.2164
# Month=46, Predicted=17.2019, Expected=17.2115
# Month=47, Predicted=16.2434, Expected=16.6591
# Month=48, Predicted=16.1580, Expected=16.8293
# Month=49, Predicted=16.9122, Expected=15.7707
# Month=50, Predicted=15.7245, Expected=15.7293
# Month=51, Predicted=15.9787, Expected=15.9961
# Month=52, Predicted=16.6332, Expected=17.0200
# Month=53, Predicted=17.8225, Expected=17.5530
# Month=54, Predicted=17.9928, Expected=17.8377
# Month=55, Predicted=17.9017, Expected=17.8581
# Month=56, Predicted=17.6027, Expected=17.5700
# Month=57, Predicted=17.0688, Expected=17.0775
# Month=58, Predicted=16.4785, Expected=16.6580
# Month=59, Predicted=16.2109, Expected=16.4321
# Month=60, Predicted=16.3106, Expected=16.5848
# Run 5 — RMSE: 0.416062, MSE: 0.173107, NMSE: 0.0015264789
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.3496, Expected=13.7017
# Month=2, Predicted=14.2211, Expected=13.8117
# Month=3, Predicted=14.2700, Expected=14.3841
# Month=4, Predicted=14.8365, Expected=15.0499
# Month=5, Predicted=15.3484, Expected=15.6880
# Month=6, Predicted=15.8140, Expected=15.8424
# Month=7, Predicted=15.6483, Expected=15.7132
# Month=8, Predicted=15.2848, Expected=15.3126
# Month=9, Predicted=14.7423, Expected=14.7637
# Month=10, Predicted=14.1876, Expected=13.5468
# Month=11, Predicted=12.8316, Expected=13.5862
# Month=12, Predicted=13.4572, Expected=14.5157
# Month=13, Predicted=14.8881, Expected=14.3853
# Month=14, Predicted=14.8514, Expected=14.4975
# Month=15, Predicted=15.0393, Expected=14.7447
# Month=16, Predicted=15.1406, Expected=15.8052
# Month=17, Predicted=16.1598, Expected=16.5260
# Month=18, Predicted=16.7138, Expected=16.5451
# Month=19, Predicted=16.3345, Expected=16.7178
# Month=20, Predicted=16.4009, Expected=16.4322
# Month=21, Predicted=15.9089, Expected=15.7696
# Month=22, Predicted=15.1303, Expected=15.2792
# Month=23, Predicted=14.7780, Expected=15.1248
# Month=24, Predicted=14.9372, Expected=15.5403
# Month=25, Predicted=15.7884, Expected=15.8274
# Month=26, Predicted=16.3074, Expected=16.3752
# Month=27, Predicted=16.9559, Expected=16.3529
# Month=28, Predicted=16.6406, Expected=16.9050
# Month=29, Predicted=17.1513, Expected=17.0172
# Month=30, Predicted=16.9757, Expected=17.4183
# Month=31, Predicted=17.3509, Expected=17.5330
# Month=32, Predicted=17.3360, Expected=17.2714
# Month=33, Predicted=16.9234, Expected=16.6037
# Month=34, Predicted=16.1060, Expected=15.8246
# Month=35, Predicted=15.3155, Expected=15.4477
# Month=36, Predicted=15.1957, Expected=15.6316
# Month=37, Predicted=15.7931, Expected=15.6935
# Month=38, Predicted=16.0918, Expected=16.7565
# Month=39, Predicted=17.4055, Expected=16.5060
# Month=40, Predicted=16.7497, Expected=17.7253
# Month=41, Predicted=18.0681, Expected=18.6917
# Month=42, Predicted=18.9167, Expected=19.1262
# Month=43, Predicted=19.0460, Expected=19.5653
# Month=44, Predicted=19.3010, Expected=19.2076
# Month=45, Predicted=18.5526, Expected=18.2164
# Month=46, Predicted=17.2849, Expected=17.2115
# Month=47, Predicted=16.3126, Expected=16.6591
# Month=48, Predicted=16.1262, Expected=16.8293
# Month=49, Predicted=16.9521, Expected=15.7707
# Month=50, Predicted=15.8666, Expected=15.7293
# Month=51, Predicted=16.2192, Expected=15.9961
# Month=52, Predicted=16.6242, Expected=17.0200
# Month=53, Predicted=17.6971, Expected=17.5530
# Month=54, Predicted=17.9423, Expected=17.8377
# Month=55, Predicted=17.9408, Expected=17.8581
# Month=56, Predicted=17.6597, Expected=17.5700
# Month=57, Predicted=17.0953, Expected=17.0775
# Month=58, Predicted=16.4888, Expected=16.6580
# Month=59, Predicted=16.1635, Expected=16.4321
# Month=60, Predicted=16.1704, Expected=16.5848
# Run 6 — RMSE: 0.428011, MSE: 0.183193, NMSE: 0.0016201074
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.3383, Expected=13.7017
# Month=2, Predicted=14.1884, Expected=13.8117
# Month=3, Predicted=14.1952, Expected=14.3841
# Month=4, Predicted=14.7135, Expected=15.0499
# Month=5, Predicted=15.3623, Expected=15.6880
# Month=6, Predicted=15.8643, Expected=15.8424
# Month=7, Predicted=15.7079, Expected=15.7132
# Month=8, Predicted=15.3264, Expected=15.3126
# Month=9, Predicted=14.7321, Expected=14.7637
# Month=10, Predicted=14.1345, Expected=13.5468
# Month=11, Predicted=12.7939, Expected=13.5862
# Month=12, Predicted=13.4333, Expected=14.5157
# Month=13, Predicted=14.9798, Expected=14.3853
# Month=14, Predicted=14.7225, Expected=14.4975
# Month=15, Predicted=14.7159, Expected=14.7447
# Month=16, Predicted=15.0095, Expected=15.8052
# Month=17, Predicted=16.1730, Expected=16.5260
# Month=18, Predicted=16.8521, Expected=16.5451
# Month=19, Predicted=16.3787, Expected=16.7178
# Month=20, Predicted=16.4597, Expected=16.4322
# Month=21, Predicted=15.9930, Expected=15.7696
# Month=22, Predicted=15.0444, Expected=15.2792
# Month=23, Predicted=14.7554, Expected=15.1248
# Month=24, Predicted=14.9663, Expected=15.5403
# Month=25, Predicted=15.8221, Expected=15.8274
# Month=26, Predicted=16.2625, Expected=16.3752
# Month=27, Predicted=16.8044, Expected=16.3529
# Month=28, Predicted=16.5135, Expected=16.9050
# Month=29, Predicted=17.0663, Expected=17.0172
# Month=30, Predicted=17.0540, Expected=17.4183
# Month=31, Predicted=17.4283, Expected=17.5330
# Month=32, Predicted=17.4783, Expected=17.2714
# Month=33, Predicted=16.9690, Expected=16.6037
# Month=34, Predicted=16.0603, Expected=15.8246
# Month=35, Predicted=15.2954, Expected=15.4477
# Month=36, Predicted=15.2446, Expected=15.6316
# Month=37, Predicted=15.8772, Expected=15.6935
# Month=38, Predicted=16.0982, Expected=16.7565
# Month=39, Predicted=17.3048, Expected=16.5060
# Month=40, Predicted=16.7051, Expected=17.7253
# Month=41, Predicted=17.9487, Expected=18.6917
# Month=42, Predicted=19.0465, Expected=19.1262
# Month=43, Predicted=19.1012, Expected=19.5653
# Month=44, Predicted=19.4358, Expected=19.2076
# Month=45, Predicted=18.7127, Expected=18.2164
# Month=46, Predicted=17.2160, Expected=17.2115
# Month=47, Predicted=16.2402, Expected=16.6591
# Month=48, Predicted=16.1355, Expected=16.8293
# Month=49, Predicted=16.8517, Expected=15.7707
# Month=50, Predicted=15.7032, Expected=15.7293
# Month=51, Predicted=15.8327, Expected=15.9961
# Month=52, Predicted=16.5214, Expected=17.0200
# Month=53, Predicted=17.6484, Expected=17.5530
# Month=54, Predicted=17.9679, Expected=17.8377
# Month=55, Predicted=17.9331, Expected=17.8581
# Month=56, Predicted=17.6521, Expected=17.5700
# Month=57, Predicted=17.1087, Expected=17.0775
# Month=58, Predicted=16.4895, Expected=16.6580
# Month=59, Predicted=16.2011, Expected=16.4321
# Month=60, Predicted=16.2514, Expected=16.5848
# Run 7 — RMSE: 0.429946, MSE: 0.184853, NMSE: 0.0015665771
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2761, Expected=13.7017
# Month=2, Predicted=14.1655, Expected=13.8117
# Month=3, Predicted=14.4591, Expected=14.3841
# Month=4, Predicted=15.0788, Expected=15.0499
# Month=5, Predicted=15.4029, Expected=15.6880
# Month=6, Predicted=15.7350, Expected=15.8424
# Month=7, Predicted=15.6493, Expected=15.7132
# Month=8, Predicted=15.3287, Expected=15.3126
# Month=9, Predicted=14.7413, Expected=14.7637
# Month=10, Predicted=14.2728, Expected=13.5468
# Month=11, Predicted=13.0327, Expected=13.5862
# Month=12, Predicted=13.6843, Expected=14.5157
# Month=13, Predicted=14.8078, Expected=14.3853
# Month=14, Predicted=14.7742, Expected=14.4975
# Month=15, Predicted=15.2580, Expected=14.7447
# Month=16, Predicted=15.3546, Expected=15.8052
# Month=17, Predicted=16.1411, Expected=16.5260
# Month=18, Predicted=16.6853, Expected=16.5451
# Month=19, Predicted=16.2667, Expected=16.7178
# Month=20, Predicted=16.4349, Expected=16.4322
# Month=21, Predicted=15.9405, Expected=15.7696
# Month=22, Predicted=15.2542, Expected=15.2792
# Month=23, Predicted=15.0223, Expected=15.1248
# Month=24, Predicted=15.1269, Expected=15.5403
# Month=25, Predicted=15.8436, Expected=15.8274
# Month=26, Predicted=16.3645, Expected=16.3752
# Month=27, Predicted=17.1253, Expected=16.3529
# Month=28, Predicted=16.8027, Expected=16.9050
# Month=29, Predicted=17.0819, Expected=17.0172
# Month=30, Predicted=16.9289, Expected=17.4183
# Month=31, Predicted=17.3123, Expected=17.5330
# Month=32, Predicted=17.2994, Expected=17.2714
# Month=33, Predicted=16.8247, Expected=16.6037
# Month=34, Predicted=16.1792, Expected=15.8246
# Month=35, Predicted=15.5595, Expected=15.4477
# Month=36, Predicted=15.4728, Expected=15.6316
# Month=37, Predicted=15.9541, Expected=15.6935
# Month=38, Predicted=16.2111, Expected=16.7565
# Month=39, Predicted=17.5538, Expected=16.5060
# Month=40, Predicted=16.9040, Expected=17.7253
# Month=41, Predicted=17.9363, Expected=18.6917
# Month=42, Predicted=18.9610, Expected=19.1262
# Month=43, Predicted=19.0164, Expected=19.5653
# Month=44, Predicted=19.3757, Expected=19.2076
# Month=45, Predicted=18.6694, Expected=18.2164
# Month=46, Predicted=17.5521, Expected=17.2115
# Month=47, Predicted=16.7224, Expected=16.6591
# Month=48, Predicted=16.5065, Expected=16.8293
# Month=49, Predicted=17.0327, Expected=15.7707
# Month=50, Predicted=15.8613, Expected=15.7293
# Month=51, Predicted=16.3447, Expected=15.9961
# Month=52, Predicted=16.8142, Expected=17.0200
# Month=53, Predicted=17.7096, Expected=17.5530
# Month=54, Predicted=17.8325, Expected=17.8377
# Month=55, Predicted=17.6856, Expected=17.8581
# Month=56, Predicted=17.5895, Expected=17.5700
# Month=57, Predicted=17.1281, Expected=17.0775
# Month=58, Predicted=16.4627, Expected=16.6580
# Month=59, Predicted=16.2568, Expected=16.4321
# Month=60, Predicted=16.3051, Expected=16.5848
# Run 8 — RMSE: 0.404661, MSE: 0.163751, NMSE: 0.0015254915
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2517, Expected=13.7017
# Month=2, Predicted=14.1399, Expected=13.8117
# Month=3, Predicted=14.4965, Expected=14.3841
# Month=4, Predicted=15.0832, Expected=15.0499
# Month=5, Predicted=15.4107, Expected=15.6880
# Month=6, Predicted=15.7639, Expected=15.8424
# Month=7, Predicted=15.6019, Expected=15.7132
# Month=8, Predicted=15.2762, Expected=15.3126
# Month=9, Predicted=14.7339, Expected=14.7637
# Month=10, Predicted=14.2905, Expected=13.5468
# Month=11, Predicted=13.0769, Expected=13.5862
# Month=12, Predicted=13.6369, Expected=14.5157
# Month=13, Predicted=14.8266, Expected=14.3853
# Month=14, Predicted=14.7900, Expected=14.4975
# Month=15, Predicted=15.3702, Expected=14.7447
# Month=16, Predicted=15.3022, Expected=15.8052
# Month=17, Predicted=16.1483, Expected=16.5260
# Month=18, Predicted=16.7471, Expected=16.5451
# Month=19, Predicted=16.1707, Expected=16.7178
# Month=20, Predicted=16.3320, Expected=16.4322
# Month=21, Predicted=16.0086, Expected=15.7696
# Month=22, Predicted=15.2919, Expected=15.2792
# Month=23, Predicted=15.0367, Expected=15.1248
# Month=24, Predicted=15.1648, Expected=15.5403
# Month=25, Predicted=15.8483, Expected=15.8274
# Month=26, Predicted=16.4525, Expected=16.3752
# Month=27, Predicted=17.1528, Expected=16.3529
# Month=28, Predicted=16.6980, Expected=16.9050
# Month=29, Predicted=17.0237, Expected=17.0172
# Month=30, Predicted=16.9541, Expected=17.4183
# Month=31, Predicted=17.2005, Expected=17.5330
# Month=32, Predicted=17.2381, Expected=17.2714
# Month=33, Predicted=16.8331, Expected=16.6037
# Month=34, Predicted=16.2159, Expected=15.8246
# Month=35, Predicted=15.5789, Expected=15.4477
# Month=36, Predicted=15.5160, Expected=15.6316
# Month=37, Predicted=15.9865, Expected=15.6935
# Month=38, Predicted=16.3062, Expected=16.7565
# Month=39, Predicted=17.6130, Expected=16.5060
# Month=40, Predicted=16.8435, Expected=17.7253
# Month=41, Predicted=17.8718, Expected=18.6917
# Month=42, Predicted=19.1759, Expected=19.1262
# Month=43, Predicted=19.0548, Expected=19.5653
# Month=44, Predicted=19.3937, Expected=19.2076
# Month=45, Predicted=18.7965, Expected=18.2164
# Month=46, Predicted=17.5539, Expected=17.2115
# Month=47, Predicted=16.7281, Expected=16.6591
# Month=48, Predicted=16.5423, Expected=16.8293
# Month=49, Predicted=17.0335, Expected=15.7707
# Month=50, Predicted=15.8800, Expected=15.7293
# Month=51, Predicted=16.4872, Expected=15.9961
# Month=52, Predicted=16.8869, Expected=17.0200
# Month=53, Predicted=17.7137, Expected=17.5530
# Month=54, Predicted=17.8223, Expected=17.8377
# Month=55, Predicted=17.6502, Expected=17.8581
# Month=56, Predicted=17.5427, Expected=17.5700
# Month=57, Predicted=17.1658, Expected=17.0775
# Month=58, Predicted=16.4625, Expected=16.6580
# Month=59, Predicted=16.2237, Expected=16.4321
# Month=60, Predicted=16.2694, Expected=16.5848
# Run 9 — RMSE: 0.424661, MSE: 0.180337, NMSE: 0.0016616402
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2373, Expected=13.7017
# Month=2, Predicted=14.1860, Expected=13.8117
# Month=3, Predicted=14.4691, Expected=14.3841
# Month=4, Predicted=15.1486, Expected=15.0499
# Month=5, Predicted=15.4012, Expected=15.6880
# Month=6, Predicted=15.7231, Expected=15.8424
# Month=7, Predicted=15.6295, Expected=15.7132
# Month=8, Predicted=15.2845, Expected=15.3126
# Month=9, Predicted=14.6561, Expected=14.7637
# Month=10, Predicted=14.1656, Expected=13.5468
# Month=11, Predicted=13.0346, Expected=13.5862
# Month=12, Predicted=13.5533, Expected=14.5157
# Month=13, Predicted=14.6857, Expected=14.3853
# Month=14, Predicted=14.7636, Expected=14.4975
# Month=15, Predicted=15.3270, Expected=14.7447
# Month=16, Predicted=15.3521, Expected=15.8052
# Month=17, Predicted=16.1495, Expected=16.5260
# Month=18, Predicted=16.6754, Expected=16.5451
# Month=19, Predicted=16.2522, Expected=16.7178
# Month=20, Predicted=16.3580, Expected=16.4322
# Month=21, Predicted=15.8754, Expected=15.7696
# Month=22, Predicted=15.1554, Expected=15.2792
# Month=23, Predicted=14.9778, Expected=15.1248
# Month=24, Predicted=15.0973, Expected=15.5403
# Month=25, Predicted=15.8260, Expected=15.8274
# Month=26, Predicted=16.3792, Expected=16.3752
# Month=27, Predicted=17.2040, Expected=16.3529
# Month=28, Predicted=16.7928, Expected=16.9050
# Month=29, Predicted=17.0466, Expected=17.0172
# Month=30, Predicted=16.9082, Expected=17.4183
# Month=31, Predicted=17.2187, Expected=17.5330
# Month=32, Predicted=17.2546, Expected=17.2714
# Month=33, Predicted=16.7238, Expected=16.6037
# Month=34, Predicted=16.1123, Expected=15.8246
# Month=35, Predicted=15.5646, Expected=15.4477
# Month=36, Predicted=15.4622, Expected=15.6316
# Month=37, Predicted=16.0127, Expected=15.6935
# Month=38, Predicted=16.3250, Expected=16.7565
# Month=39, Predicted=17.6489, Expected=16.5060
# Month=40, Predicted=16.8488, Expected=17.7253
# Month=41, Predicted=17.8504, Expected=18.6917
# Month=42, Predicted=18.9402, Expected=19.1262
# Month=43, Predicted=18.9784, Expected=19.5653
# Month=44, Predicted=19.3273, Expected=19.2076
# Month=45, Predicted=18.6279, Expected=18.2164
# Month=46, Predicted=17.4719, Expected=17.2115
# Month=47, Predicted=16.7570, Expected=16.6591
# Month=48, Predicted=16.5224, Expected=16.8293
# Month=49, Predicted=17.0422, Expected=15.7707
# Month=50, Predicted=16.0602, Expected=15.7293
# Month=51, Predicted=16.5006, Expected=15.9961
# Month=52, Predicted=16.7176, Expected=17.0200
# Month=53, Predicted=17.6545, Expected=17.5530
# Month=54, Predicted=17.7809, Expected=17.8377
# Month=55, Predicted=17.7061, Expected=17.8581
# Month=56, Predicted=17.5595, Expected=17.5700
# Month=57, Predicted=17.0998, Expected=17.0775
# Month=58, Predicted=16.4354, Expected=16.6580
# Month=59, Predicted=16.2345, Expected=16.4321
# Month=60, Predicted=16.2846, Expected=16.5848
# Run 10 — RMSE: 0.423520, MSE: 0.179369, NMSE: 0.0016678676
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.2415, Expected=13.7017
# Month=2, Predicted=14.2114, Expected=13.8117
# Month=3, Predicted=14.4526, Expected=14.3841
# Month=4, Predicted=15.0942, Expected=15.0499
# Month=5, Predicted=15.4697, Expected=15.6880
# Month=6, Predicted=15.7506, Expected=15.8424
# Month=7, Predicted=15.5737, Expected=15.7132
# Month=8, Predicted=15.2628, Expected=15.3126
# Month=9, Predicted=14.7415, Expected=14.7637
# Month=10, Predicted=14.1980, Expected=13.5468
# Month=11, Predicted=12.9435, Expected=13.5862
# Month=12, Predicted=13.5433, Expected=14.5157
# Month=13, Predicted=14.7508, Expected=14.3853
# Month=14, Predicted=14.7773, Expected=14.4975
# Month=15, Predicted=15.2093, Expected=14.7447
# Month=16, Predicted=15.4217, Expected=15.8052
# Month=17, Predicted=16.3029, Expected=16.5260
# Month=18, Predicted=16.7040, Expected=16.5451
# Month=19, Predicted=16.2336, Expected=16.7178
# Month=20, Predicted=16.3636, Expected=16.4322
# Month=21, Predicted=15.9828, Expected=15.7696
# Month=22, Predicted=15.1443, Expected=15.2792
# Month=23, Predicted=14.8560, Expected=15.1248
# Month=24, Predicted=14.9757, Expected=15.5403
# Month=25, Predicted=15.6905, Expected=15.8274
# Month=26, Predicted=16.2985, Expected=16.3752
# Month=27, Predicted=17.1091, Expected=16.3529
# Month=28, Predicted=16.9329, Expected=16.9050
# Month=29, Predicted=17.3444, Expected=17.0172
# Month=30, Predicted=17.0320, Expected=17.4183
# Month=31, Predicted=17.2982, Expected=17.5330
# Month=32, Predicted=17.3361, Expected=17.2714
# Month=33, Predicted=16.8869, Expected=16.6037
# Month=34, Predicted=16.0444, Expected=15.8246
# Month=35, Predicted=15.3607, Expected=15.4477
# Month=36, Predicted=15.2887, Expected=15.6316
# Month=37, Predicted=15.7919, Expected=15.6935
# Month=38, Predicted=16.1048, Expected=16.7565
# Month=39, Predicted=17.5138, Expected=16.5060
# Month=40, Predicted=17.0156, Expected=17.7253
# Month=41, Predicted=18.2535, Expected=18.6917
# Month=42, Predicted=18.9734, Expected=19.1262
# Month=43, Predicted=18.9184, Expected=19.5653
# Month=44, Predicted=19.2859, Expected=19.2076
# Month=45, Predicted=18.7026, Expected=18.2164
# Month=46, Predicted=17.3480, Expected=17.2115
# Month=47, Predicted=16.5248, Expected=16.6591
# Month=48, Predicted=16.3334, Expected=16.8293
# Month=49, Predicted=16.8846, Expected=15.7707
# Month=50, Predicted=15.7694, Expected=15.7293
# Month=51, Predicted=16.4000, Expected=15.9961
# Month=52, Predicted=16.8144, Expected=17.0200
# Month=53, Predicted=17.7799, Expected=17.5530
# Month=54, Predicted=17.8343, Expected=17.8377
# Month=55, Predicted=17.6382, Expected=17.8581
# Month=56, Predicted=17.4338, Expected=17.5700
# Month=57, Predicted=17.0127, Expected=17.0775
# Month=58, Predicted=16.4218, Expected=16.6580
# Month=59, Predicted=16.1569, Expected=16.4321
# Month=60, Predicted=16.1344, Expected=16.5848
# Run 11 — RMSE: 0.403463, MSE: 0.162782, NMSE: 0.0014640627
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.4351, Expected=13.7017
# Month=2, Predicted=14.1671, Expected=13.8117
# Month=3, Predicted=14.0403, Expected=14.3841
# Month=4, Predicted=14.5658, Expected=15.0499
# Month=5, Predicted=15.3357, Expected=15.6880
# Month=6, Predicted=15.8498, Expected=15.8424
# Month=7, Predicted=15.7594, Expected=15.7132
# Month=8, Predicted=15.4561, Expected=15.3126
# Month=9, Predicted=14.9621, Expected=14.7637
# Month=10, Predicted=14.3580, Expected=13.5468
# Month=11, Predicted=12.9091, Expected=13.5862
# Month=12, Predicted=13.3687, Expected=14.5157
# Month=13, Predicted=14.9158, Expected=14.3853
# Month=14, Predicted=14.5042, Expected=14.4975
# Month=15, Predicted=14.6838, Expected=14.7447
# Month=16, Predicted=15.1792, Expected=15.8052
# Month=17, Predicted=16.3589, Expected=16.5260
# Month=18, Predicted=17.0080, Expected=16.5451
# Month=19, Predicted=16.3669, Expected=16.7178
# Month=20, Predicted=16.4581, Expected=16.4322
# Month=21, Predicted=16.1165, Expected=15.7696
# Month=22, Predicted=15.2481, Expected=15.2792
# Month=23, Predicted=14.9094, Expected=15.1248
# Month=24, Predicted=15.1629, Expected=15.5403
# Month=25, Predicted=15.9966, Expected=15.8274
# Month=26, Predicted=16.3581, Expected=16.3752
# Month=27, Predicted=16.9186, Expected=16.3529
# Month=28, Predicted=16.6199, Expected=16.9050
# Month=29, Predicted=17.1065, Expected=17.0172
# Month=30, Predicted=17.1208, Expected=17.4183
# Month=31, Predicted=17.4171, Expected=17.5330
# Month=32, Predicted=17.4863, Expected=17.2714
# Month=33, Predicted=17.0302, Expected=16.6037
# Month=34, Predicted=16.2850, Expected=15.8246
# Month=35, Predicted=15.5430, Expected=15.4477
# Month=36, Predicted=15.4364, Expected=15.6316
# Month=37, Predicted=15.9907, Expected=15.6935
# Month=38, Predicted=16.0156, Expected=16.7565
# Month=39, Predicted=17.1574, Expected=16.5060
# Month=40, Predicted=16.5860, Expected=17.7253
# Month=41, Predicted=17.9072, Expected=18.6917
# Month=42, Predicted=19.2782, Expected=19.1262
# Month=43, Predicted=19.1231, Expected=19.5653
# Month=44, Predicted=19.4632, Expected=19.2076
# Month=45, Predicted=18.7907, Expected=18.2164
# Month=46, Predicted=17.3625, Expected=17.2115
# Month=47, Predicted=16.4232, Expected=16.6591
# Month=48, Predicted=16.1782, Expected=16.8293
# Month=49, Predicted=16.8595, Expected=15.7707
# Month=50, Predicted=15.6050, Expected=15.7293
# Month=51, Predicted=15.9477, Expected=15.9961
# Month=52, Predicted=16.7245, Expected=17.0200
# Month=53, Predicted=17.8533, Expected=17.5530
# Month=54, Predicted=18.1803, Expected=17.8377
# Month=55, Predicted=17.9954, Expected=17.8581
# Month=56, Predicted=17.7872, Expected=17.5700
# Month=57, Predicted=17.3256, Expected=17.0775
# Month=58, Predicted=16.7351, Expected=16.6580
# Month=59, Predicted=16.3775, Expected=16.4321
# Month=60, Predicted=16.3856, Expected=16.5848
# Run 12 — RMSE: 0.434252, MSE: 0.188574, NMSE: 0.0015717380
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2014, Expected=13.7017
# Month=2, Predicted=14.0460, Expected=13.8117
# Month=3, Predicted=14.3822, Expected=14.3841
# Month=4, Predicted=15.0371, Expected=15.0499
# Month=5, Predicted=15.3300, Expected=15.6880
# Month=6, Predicted=15.6887, Expected=15.8424
# Month=7, Predicted=15.5927, Expected=15.7132
# Month=8, Predicted=15.3076, Expected=15.3126
# Month=9, Predicted=14.7800, Expected=14.7637
# Month=10, Predicted=14.2576, Expected=13.5468
# Month=11, Predicted=12.9538, Expected=13.5862
# Month=12, Predicted=13.5606, Expected=14.5157
# Month=13, Predicted=14.4281, Expected=14.3853
# Month=14, Predicted=14.5420, Expected=14.4975
# Month=15, Predicted=15.2893, Expected=14.7447
# Month=16, Predicted=15.2882, Expected=15.8052
# Month=17, Predicted=16.1860, Expected=16.5260
# Month=18, Predicted=16.6513, Expected=16.5451
# Month=19, Predicted=16.3384, Expected=16.7178
# Month=20, Predicted=16.4136, Expected=16.4322
# Month=21, Predicted=15.9367, Expected=15.7696
# Month=22, Predicted=15.2541, Expected=15.2792
# Month=23, Predicted=14.9242, Expected=15.1248
# Month=24, Predicted=15.0057, Expected=15.5403
# Month=25, Predicted=15.6681, Expected=15.8274
# Month=26, Predicted=16.0923, Expected=16.3752
# Month=27, Predicted=17.0723, Expected=16.3529
# Month=28, Predicted=16.7974, Expected=16.9050
# Month=29, Predicted=17.1620, Expected=17.0172
# Month=30, Predicted=16.8575, Expected=17.4183
# Month=31, Predicted=17.2513, Expected=17.5330
# Month=32, Predicted=17.2627, Expected=17.2714
# Month=33, Predicted=16.9745, Expected=16.6037
# Month=34, Predicted=16.2293, Expected=15.8246
# Month=35, Predicted=15.4807, Expected=15.4477
# Month=36, Predicted=15.3154, Expected=15.6316
# Month=37, Predicted=15.7692, Expected=15.6935
# Month=38, Predicted=16.1038, Expected=16.7565
# Month=39, Predicted=17.6336, Expected=16.5060
# Month=40, Predicted=16.9471, Expected=17.7253
# Month=41, Predicted=18.0892, Expected=18.6917
# Month=42, Predicted=18.7855, Expected=19.1262
# Month=43, Predicted=19.0701, Expected=19.5653
# Month=44, Predicted=19.4543, Expected=19.2076
# Month=45, Predicted=18.7881, Expected=18.2164
# Month=46, Predicted=17.5413, Expected=17.2115
# Month=47, Predicted=16.4946, Expected=16.6591
# Month=48, Predicted=16.2180, Expected=16.8293
# Month=49, Predicted=16.7771, Expected=15.7707
# Month=50, Predicted=15.4868, Expected=15.7293
# Month=51, Predicted=16.3271, Expected=15.9961
# Month=52, Predicted=16.6706, Expected=17.0200
# Month=53, Predicted=17.9298, Expected=17.5530
# Month=54, Predicted=18.0684, Expected=17.8377
# Month=55, Predicted=17.8942, Expected=17.8581
# Month=56, Predicted=17.5067, Expected=17.5700
# Month=57, Predicted=17.0279, Expected=17.0775
# Month=58, Predicted=16.4584, Expected=16.6580
# Month=59, Predicted=16.1636, Expected=16.4321
# Month=60, Predicted=16.1835, Expected=16.5848
# Run 13 — RMSE: 0.421194, MSE: 0.177404, NMSE: 0.0015277961
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2211, Expected=13.7017
# Month=2, Predicted=14.1211, Expected=13.8117
# Month=3, Predicted=14.4080, Expected=14.3841
# Month=4, Predicted=15.1248, Expected=15.0499
# Month=5, Predicted=15.4688, Expected=15.6880
# Month=6, Predicted=15.7412, Expected=15.8424
# Month=7, Predicted=15.6411, Expected=15.7132
# Month=8, Predicted=15.2567, Expected=15.3126
# Month=9, Predicted=14.7499, Expected=14.7637
# Month=10, Predicted=14.2465, Expected=13.5468
# Month=11, Predicted=13.0368, Expected=13.5862
# Month=12, Predicted=13.5671, Expected=14.5157
# Month=13, Predicted=14.6950, Expected=14.3853
# Month=14, Predicted=14.6932, Expected=14.4975
# Month=15, Predicted=15.2226, Expected=14.7447
# Month=16, Predicted=15.4235, Expected=15.8052
# Month=17, Predicted=16.2160, Expected=16.5260
# Month=18, Predicted=16.7021, Expected=16.5451
# Month=19, Predicted=16.2076, Expected=16.7178
# Month=20, Predicted=16.3420, Expected=16.4322
# Month=21, Predicted=15.9777, Expected=15.7696
# Month=22, Predicted=15.2122, Expected=15.2792
# Month=23, Predicted=14.9346, Expected=15.1248
# Month=24, Predicted=15.0625, Expected=15.5403
# Month=25, Predicted=15.7631, Expected=15.8274
# Month=26, Predicted=16.2979, Expected=16.3752
# Month=27, Predicted=17.1152, Expected=16.3529
# Month=28, Predicted=16.8653, Expected=16.9050
# Month=29, Predicted=17.1242, Expected=17.0172
# Month=30, Predicted=16.9830, Expected=17.4183
# Month=31, Predicted=17.1724, Expected=17.5330
# Month=32, Predicted=17.2234, Expected=17.2714
# Month=33, Predicted=16.7992, Expected=16.6037
# Month=34, Predicted=16.1321, Expected=15.8246
# Month=35, Predicted=15.5308, Expected=15.4477
# Month=36, Predicted=15.5002, Expected=15.6316
# Month=37, Predicted=15.9811, Expected=15.6935
# Month=38, Predicted=16.2521, Expected=16.7565
# Month=39, Predicted=17.5675, Expected=16.5060
# Month=40, Predicted=16.9205, Expected=17.7253
# Month=41, Predicted=17.8841, Expected=18.6917
# Month=42, Predicted=19.0137, Expected=19.1262
# Month=43, Predicted=18.8614, Expected=19.5653
# Month=44, Predicted=19.3167, Expected=19.2076
# Month=45, Predicted=18.7719, Expected=18.2164
# Month=46, Predicted=17.5991, Expected=17.2115
# Month=47, Predicted=16.7693, Expected=16.6591
# Month=48, Predicted=16.5181, Expected=16.8293
# Month=49, Predicted=17.0031, Expected=15.7707
# Month=50, Predicted=15.9849, Expected=15.7293
# Month=51, Predicted=16.4393, Expected=15.9961
# Month=52, Predicted=16.8019, Expected=17.0200
# Month=53, Predicted=17.7252, Expected=17.5530
# Month=54, Predicted=17.8227, Expected=17.8377
# Month=55, Predicted=17.6579, Expected=17.8581
# Month=56, Predicted=17.5705, Expected=17.5700
# Month=57, Predicted=17.0418, Expected=17.0775
# Month=58, Predicted=16.4927, Expected=16.6580
# Month=59, Predicted=16.2290, Expected=16.4321
# Month=60, Predicted=16.2132, Expected=16.5848
# Run 14 — RMSE: 0.415162, MSE: 0.172360, NMSE: 0.0015854930
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.2345, Expected=13.7017
# Month=2, Predicted=14.0977, Expected=13.8117
# Month=3, Predicted=14.5642, Expected=14.3841
# Month=4, Predicted=15.2328, Expected=15.0499
# Month=5, Predicted=15.4458, Expected=15.6880
# Month=6, Predicted=15.7505, Expected=15.8424
# Month=7, Predicted=15.6703, Expected=15.7132
# Month=8, Predicted=15.3177, Expected=15.3126
# Month=9, Predicted=14.7095, Expected=14.7637
# Month=10, Predicted=14.1415, Expected=13.5468
# Month=11, Predicted=13.0223, Expected=13.5862
# Month=12, Predicted=13.5858, Expected=14.5157
# Month=13, Predicted=14.6674, Expected=14.3853
# Month=14, Predicted=14.5727, Expected=14.4975
# Month=15, Predicted=15.3165, Expected=14.7447
# Month=16, Predicted=15.7104, Expected=15.8052
# Month=17, Predicted=16.3604, Expected=16.5260
# Month=18, Predicted=16.7532, Expected=16.5451
# Month=19, Predicted=16.2893, Expected=16.7178
# Month=20, Predicted=16.4184, Expected=16.4322
# Month=21, Predicted=15.9796, Expected=15.7696
# Month=22, Predicted=15.0257, Expected=15.2792
# Month=23, Predicted=14.8619, Expected=15.1248
# Month=24, Predicted=15.0599, Expected=15.5403
# Month=25, Predicted=15.6088, Expected=15.8274
# Month=26, Predicted=16.0965, Expected=16.3752
# Month=27, Predicted=17.1968, Expected=16.3529
# Month=28, Predicted=17.2461, Expected=16.9050
# Month=29, Predicted=17.4189, Expected=17.0172
# Month=30, Predicted=17.0402, Expected=17.4183
# Month=31, Predicted=17.3067, Expected=17.5330
# Month=32, Predicted=17.3877, Expected=17.2714
# Month=33, Predicted=16.8110, Expected=16.6037
# Month=34, Predicted=15.9100, Expected=15.8246
# Month=35, Predicted=15.3093, Expected=15.4477
# Month=36, Predicted=15.3204, Expected=15.6316
# Month=37, Predicted=15.7266, Expected=15.6935
# Month=38, Predicted=15.8924, Expected=16.7565
# Month=39, Predicted=17.5531, Expected=16.5060
# Month=40, Predicted=17.3534, Expected=17.7253
# Month=41, Predicted=18.3734, Expected=18.6917
# Month=42, Predicted=19.0511, Expected=19.1262
# Month=43, Predicted=19.0018, Expected=19.5653
# Month=44, Predicted=19.3797, Expected=19.2076
# Month=45, Predicted=18.6924, Expected=18.2164
# Month=46, Predicted=17.1977, Expected=17.2115
# Month=47, Predicted=16.4747, Expected=16.6591
# Month=48, Predicted=16.4286, Expected=16.8293
# Month=49, Predicted=16.8299, Expected=15.7707
# Month=50, Predicted=15.6648, Expected=15.7293
# Month=51, Predicted=16.3390, Expected=15.9961
# Month=52, Predicted=17.0599, Expected=17.0200
# Month=53, Predicted=17.9350, Expected=17.5530
# Month=54, Predicted=17.8998, Expected=17.8377
# Month=55, Predicted=17.6701, Expected=17.8581
# Month=56, Predicted=17.5263, Expected=17.5700
# Month=57, Predicted=17.0980, Expected=17.0775
# Month=58, Predicted=16.3977, Expected=16.6580
# Month=59, Predicted=16.0596, Expected=16.4321
# Month=60, Predicted=16.2194, Expected=16.5848
# Run 15 — RMSE: 0.391107, MSE: 0.152965, NMSE: 0.0013189384
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.2827, Expected=13.7017
# Month=2, Predicted=14.1511, Expected=13.8117
# Month=3, Predicted=14.6609, Expected=14.3841
# Month=4, Predicted=14.9420, Expected=15.0499
# Month=5, Predicted=15.3182, Expected=15.6880
# Month=6, Predicted=15.7653, Expected=15.8424
# Month=7, Predicted=15.5755, Expected=15.7132
# Month=8, Predicted=15.2390, Expected=15.3126
# Month=9, Predicted=14.6984, Expected=14.7637
# Month=10, Predicted=14.2132, Expected=13.5468
# Month=11, Predicted=13.0716, Expected=13.5862
# Month=12, Predicted=13.6063, Expected=14.5157
# Month=13, Predicted=14.7045, Expected=14.3853
# Month=14, Predicted=14.7232, Expected=14.4975
# Month=15, Predicted=15.3529, Expected=14.7447
# Month=16, Predicted=15.1630, Expected=15.8052
# Month=17, Predicted=16.0861, Expected=16.5260
# Month=18, Predicted=16.7041, Expected=16.5451
# Month=19, Predicted=16.2364, Expected=16.7178
# Month=20, Predicted=16.3851, Expected=16.4322
# Month=21, Predicted=15.9418, Expected=15.7696
# Month=22, Predicted=15.2641, Expected=15.2792
# Month=23, Predicted=15.0107, Expected=15.1248
# Month=24, Predicted=15.1644, Expected=15.5403
# Month=25, Predicted=15.8929, Expected=15.8274
# Month=26, Predicted=16.5581, Expected=16.3752
# Month=27, Predicted=17.2596, Expected=16.3529
# Month=28, Predicted=16.5675, Expected=16.9050
# Month=29, Predicted=16.9975, Expected=17.0172
# Month=30, Predicted=16.8041, Expected=17.4183
# Month=31, Predicted=17.1775, Expected=17.5330
# Month=32, Predicted=17.2311, Expected=17.2714
# Month=33, Predicted=16.9022, Expected=16.6037
# Month=34, Predicted=16.3214, Expected=15.8246
# Month=35, Predicted=15.7209, Expected=15.4477
# Month=36, Predicted=15.6329, Expected=15.6316
# Month=37, Predicted=16.1568, Expected=15.6935
# Month=38, Predicted=16.4974, Expected=16.7565
# Month=39, Predicted=17.6580, Expected=16.5060
# Month=40, Predicted=16.6711, Expected=17.7253
# Month=41, Predicted=17.8793, Expected=18.6917
# Month=42, Predicted=18.9779, Expected=19.1262
# Month=43, Predicted=19.0304, Expected=19.5653
# Month=44, Predicted=19.3867, Expected=19.2076
# Month=45, Predicted=18.7570, Expected=18.2164
# Month=46, Predicted=17.5901, Expected=17.2115
# Month=47, Predicted=16.6443, Expected=16.6591
# Month=48, Predicted=16.3814, Expected=16.8293
# Month=49, Predicted=16.9475, Expected=15.7707
# Month=50, Predicted=15.8477, Expected=15.7293
# Month=51, Predicted=16.5451, Expected=15.9961
# Month=52, Predicted=16.8785, Expected=17.0200
# Month=53, Predicted=17.8327, Expected=17.5530
# Month=54, Predicted=17.9658, Expected=17.8377
# Month=55, Predicted=17.8772, Expected=17.8581
# Month=56, Predicted=17.6005, Expected=17.5700
# Month=57, Predicted=17.0682, Expected=17.0775
# Month=58, Predicted=16.4490, Expected=16.6580
# Month=59, Predicted=16.0995, Expected=16.4321
# Month=60, Predicted=16.1786, Expected=16.5848
# Run 16 — RMSE: 0.447973, MSE: 0.200679, NMSE: 0.0018331036
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.2824, Expected=13.7017
# Month=2, Predicted=14.1971, Expected=13.8117
# Month=3, Predicted=14.3113, Expected=14.3841
# Month=4, Predicted=14.9536, Expected=15.0499
# Month=5, Predicted=15.4264, Expected=15.6880
# Month=6, Predicted=15.8283, Expected=15.8424
# Month=7, Predicted=15.6609, Expected=15.7132
# Month=8, Predicted=15.3178, Expected=15.3126
# Month=9, Predicted=14.7688, Expected=14.7637
# Month=10, Predicted=14.2180, Expected=13.5468
# Month=11, Predicted=12.8768, Expected=13.5862
# Month=12, Predicted=13.5573, Expected=14.5157
# Month=13, Predicted=14.6736, Expected=14.3853
# Month=14, Predicted=14.6024, Expected=14.4975
# Month=15, Predicted=15.1689, Expected=14.7447
# Month=16, Predicted=15.2917, Expected=15.8052
# Month=17, Predicted=16.2401, Expected=16.5260
# Month=18, Predicted=16.7956, Expected=16.5451
# Month=19, Predicted=16.3238, Expected=16.7178
# Month=20, Predicted=16.4615, Expected=16.4322
# Month=21, Predicted=15.9763, Expected=15.7696
# Month=22, Predicted=15.1270, Expected=15.2792
# Month=23, Predicted=14.8695, Expected=15.1248
# Month=24, Predicted=14.9839, Expected=15.5403
# Month=25, Predicted=15.6911, Expected=15.8274
# Month=26, Predicted=16.1824, Expected=16.3752
# Month=27, Predicted=16.9976, Expected=16.3529
# Month=28, Predicted=16.7332, Expected=16.9050
# Month=29, Predicted=17.2135, Expected=17.0172
# Month=30, Predicted=17.0359, Expected=17.4183
# Month=31, Predicted=17.3848, Expected=17.5330
# Month=32, Predicted=17.3931, Expected=17.2714
# Month=33, Predicted=16.9349, Expected=16.6037
# Month=34, Predicted=16.0889, Expected=15.8246
# Month=35, Predicted=15.3724, Expected=15.4477
# Month=36, Predicted=15.2511, Expected=15.6316
# Month=37, Predicted=15.7285, Expected=15.6935
# Month=38, Predicted=15.9363, Expected=16.7565
# Month=39, Predicted=17.4399, Expected=16.5060
# Month=40, Predicted=16.8555, Expected=17.7253
# Month=41, Predicted=18.1929, Expected=18.6917
# Month=42, Predicted=19.1032, Expected=19.1262
# Month=43, Predicted=19.0533, Expected=19.5653
# Month=44, Predicted=19.3578, Expected=19.2076
# Month=45, Predicted=18.6500, Expected=18.2164
# Month=46, Predicted=17.3202, Expected=17.2115
# Month=47, Predicted=16.4965, Expected=16.6591
# Month=48, Predicted=16.2311, Expected=16.8293
# Month=49, Predicted=16.7846, Expected=15.7707
# Month=50, Predicted=15.4928, Expected=15.7293
# Month=51, Predicted=16.2437, Expected=15.9961
# Month=52, Predicted=16.6472, Expected=17.0200
# Month=53, Predicted=17.7740, Expected=17.5530
# Month=54, Predicted=18.0446, Expected=17.8377
# Month=55, Predicted=17.9791, Expected=17.8581
# Month=56, Predicted=17.6483, Expected=17.5700
# Month=57, Predicted=17.1094, Expected=17.0775
# Month=58, Predicted=16.4512, Expected=16.6580
# Month=59, Predicted=16.1817, Expected=16.4321
# Month=60, Predicted=16.1994, Expected=16.5848
# Run 17 — RMSE: 0.401797, MSE: 0.161441, NMSE: 0.0013869071
#
# ===== RUN 18/30 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 145
#     143 run_losses = []
#     144 for epoch in range(100):
# --> 145     history = model.fit(
#     146         X_train, y_train,
#     147         epochs=1, batch_size=1,
#     148         verbose=0, shuffle=False
#     149     )
#     150     run_losses.append(history.history['loss'][0])
#     151     rnn_layer.reset_states()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)   1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)   1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
