# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    352
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 361 (1.41 KB)
# Trainable params: 361 (1.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on Monthly Lake Erie Levels (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.010052)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.76799303 14.64761015 15.09151064 16.39130966 16.92364626]
# Supervised data shape: (599, 3)
# Train: (539, 3), Test: (60, 3)
# X_train shape: (539, 1, 2), y_train shape: (539,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2409, Expected=13.7084
# Month=2, Predicted=14.2270, Expected=13.8026
# Month=3, Predicted=14.4868, Expected=14.3883
# Month=4, Predicted=15.0967, Expected=15.0615
# Month=5, Predicted=15.4692, Expected=15.6682
# Month=6, Predicted=15.7196, Expected=15.8360
# Month=7, Predicted=15.6040, Expected=15.7178
# Month=8, Predicted=15.3277, Expected=15.3110
# Month=9, Predicted=14.7538, Expected=14.7667
# Month=10, Predicted=14.1807, Expected=13.5419
# Month=11, Predicted=12.9428, Expected=13.5869
# Month=12, Predicted=13.5218, Expected=14.5144
# Month=13, Predicted=14.6556, Expected=14.3947
# Month=14, Predicted=14.7590, Expected=14.4996
# Month=15, Predicted=15.2320, Expected=14.7474
# Month=16, Predicted=15.4404, Expected=15.8019
# Month=17, Predicted=16.3318, Expected=16.5221
# Month=18, Predicted=16.7226, Expected=16.5417
# Month=19, Predicted=16.2725, Expected=16.7210
# Month=20, Predicted=16.4226, Expected=16.4288
# Month=21, Predicted=15.9820, Expected=15.7719
# Month=22, Predicted=15.1216, Expected=15.2959
# Month=23, Predicted=14.8159, Expected=15.1318
# Month=24, Predicted=14.9448, Expected=15.5377
# Month=25, Predicted=15.6491, Expected=15.8371
# Month=26, Predicted=16.2552, Expected=16.3719
# Month=27, Predicted=17.1392, Expected=16.3365
# Month=28, Predicted=16.9273, Expected=16.8969
# Month=29, Predicted=17.3424, Expected=17.0022
# Month=30, Predicted=17.0455, Expected=17.4155
# Month=31, Predicted=17.3289, Expected=17.5332
# Month=32, Predicted=17.3562, Expected=17.2849
# Month=33, Predicted=16.9177, Expected=16.6063
# Month=34, Predicted=16.0475, Expected=15.8228
# Month=35, Predicted=15.3467, Expected=15.4543
# Month=36, Predicted=15.2914, Expected=15.6138
# Month=37, Predicted=15.7298, Expected=15.6954
# Month=38, Predicted=16.0917, Expected=16.7627
# Month=39, Predicted=17.5487, Expected=16.4941
# Month=40, Predicted=16.9622, Expected=17.7345
# Month=41, Predicted=18.1993, Expected=18.6944
# Month=42, Predicted=18.9891, Expected=19.1228
# Month=43, Predicted=18.9789, Expected=19.5704
# Month=44, Predicted=19.3707, Expected=19.2258
# Month=45, Predicted=18.7636, Expected=18.2178
# Month=46, Predicted=17.3530, Expected=17.2135
# Month=47, Predicted=16.4347, Expected=16.6554
# Month=48, Predicted=16.2446, Expected=16.8225
# Month=49, Predicted=16.7606, Expected=15.7773
# Month=50, Predicted=15.6755, Expected=15.7224
# Month=51, Predicted=16.1436, Expected=15.9967
# Month=52, Predicted=16.6762, Expected=17.0162
# Month=53, Predicted=17.8423, Expected=17.5568
# Month=54, Predicted=18.0317, Expected=17.8404
# Month=55, Predicted=17.8726, Expected=17.8664
# Month=56, Predicted=17.6272, Expected=17.5659
# Month=57, Predicted=17.1256, Expected=17.0753
# Month=58, Predicted=16.4852, Expected=16.6502
# Month=59, Predicted=16.1265, Expected=16.4285
# Month=60, Predicted=16.1245, Expected=16.5878
# Run 1 — RMSE: 0.406105, MSE: 0.164922, NMSE: 0.0014341527
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.1141, Expected=13.7084
# Month=2, Predicted=14.0540, Expected=13.8026
# Month=3, Predicted=14.4617, Expected=14.3883
# Month=4, Predicted=15.0047, Expected=15.0615
# Month=5, Predicted=15.2290, Expected=15.6682
# Month=6, Predicted=15.5548, Expected=15.8360
# Month=7, Predicted=15.5566, Expected=15.7178
# Month=8, Predicted=15.2567, Expected=15.3110
# Month=9, Predicted=14.6984, Expected=14.7667
# Month=10, Predicted=14.2137, Expected=13.5419
# Month=11, Predicted=13.0653, Expected=13.5869
# Month=12, Predicted=13.4321, Expected=14.5144
# Month=13, Predicted=14.5360, Expected=14.3947
# Month=14, Predicted=14.6747, Expected=14.4996
# Month=15, Predicted=15.3132, Expected=14.7474
# Month=16, Predicted=15.3131, Expected=15.8019
# Month=17, Predicted=16.0283, Expected=16.5221
# Month=18, Predicted=16.5224, Expected=16.5417
# Month=19, Predicted=16.2818, Expected=16.7210
# Month=20, Predicted=16.3423, Expected=16.4288
# Month=21, Predicted=15.9024, Expected=15.7719
# Month=22, Predicted=15.1865, Expected=15.2959
# Month=23, Predicted=14.9285, Expected=15.1318
# Month=24, Predicted=15.0198, Expected=15.5377
# Month=25, Predicted=15.5732, Expected=15.8371
# Month=26, Predicted=16.1740, Expected=16.3719
# Month=27, Predicted=17.1365, Expected=16.3365
# Month=28, Predicted=16.8128, Expected=16.8969
# Month=29, Predicted=17.0339, Expected=17.0022
# Month=30, Predicted=16.7893, Expected=17.4155
# Month=31, Predicted=17.1769, Expected=17.5332
# Month=32, Predicted=17.2419, Expected=17.2849
# Month=33, Predicted=16.8674, Expected=16.6063
# Month=34, Predicted=16.1482, Expected=15.8228
# Month=35, Predicted=15.4834, Expected=15.4543
# Month=36, Predicted=15.3447, Expected=15.6138
# Month=37, Predicted=15.8123, Expected=15.6954
# Month=38, Predicted=16.3560, Expected=16.7627
# Month=39, Predicted=17.7256, Expected=16.4941
# Month=40, Predicted=16.9420, Expected=17.7345
# Month=41, Predicted=17.9011, Expected=18.6944
# Month=42, Predicted=18.7186, Expected=19.1228
# Month=43, Predicted=18.9962, Expected=19.5704
# Month=44, Predicted=19.3511, Expected=19.2258
# Month=45, Predicted=18.7579, Expected=18.2178
# Month=46, Predicted=17.5024, Expected=17.2135
# Month=47, Predicted=16.6037, Expected=16.6554
# Month=48, Predicted=16.3618, Expected=16.8225
# Month=49, Predicted=16.8503, Expected=15.7773
# Month=50, Predicted=15.8964, Expected=15.7224
# Month=51, Predicted=16.4954, Expected=15.9967
# Month=52, Predicted=16.9542, Expected=17.0162
# Month=53, Predicted=17.8003, Expected=17.5568
# Month=54, Predicted=17.8483, Expected=17.8404
# Month=55, Predicted=17.7282, Expected=17.8664
# Month=56, Predicted=17.5326, Expected=17.5659
# Month=57, Predicted=17.0002, Expected=17.0753
# Month=58, Predicted=16.4047, Expected=16.6502
# Month=59, Predicted=16.1518, Expected=16.4285
# Month=60, Predicted=16.2334, Expected=16.5878
# Run 2 — RMSE: 0.435438, MSE: 0.189606, NMSE: 0.0016879618
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2314, Expected=13.7084
# Month=2, Predicted=14.0608, Expected=13.8026
# Month=3, Predicted=14.4488, Expected=14.3883
# Month=4, Predicted=15.1373, Expected=15.0615
# Month=5, Predicted=15.4257, Expected=15.6682
# Month=6, Predicted=15.6699, Expected=15.8360
# Month=7, Predicted=15.6174, Expected=15.7178
# Month=8, Predicted=15.2508, Expected=15.3110
# Month=9, Predicted=14.7413, Expected=14.7667
# Month=10, Predicted=14.2424, Expected=13.5419
# Month=11, Predicted=12.9569, Expected=13.5869
# Month=12, Predicted=13.5591, Expected=14.5144
# Month=13, Predicted=14.6933, Expected=14.3947
# Month=14, Predicted=14.6103, Expected=14.4996
# Month=15, Predicted=15.3054, Expected=14.7474
# Month=16, Predicted=15.3769, Expected=15.8019
# Month=17, Predicted=16.0662, Expected=16.5221
# Month=18, Predicted=16.6730, Expected=16.5417
# Month=19, Predicted=16.2014, Expected=16.7210
# Month=20, Predicted=16.3202, Expected=16.4288
# Month=21, Predicted=15.9613, Expected=15.7719
# Month=22, Predicted=15.2294, Expected=15.2959
# Month=23, Predicted=14.9793, Expected=15.1318
# Month=24, Predicted=15.1754, Expected=15.5377
# Month=25, Predicted=16.0019, Expected=15.8371
# Month=26, Predicted=16.6174, Expected=16.3719
# Month=27, Predicted=17.1967, Expected=16.3365
# Month=28, Predicted=16.5612, Expected=16.8969
# Month=29, Predicted=16.8233, Expected=17.0022
# Month=30, Predicted=16.8770, Expected=17.4155
# Month=31, Predicted=17.1194, Expected=17.5332
# Month=32, Predicted=17.2495, Expected=17.2849
# Month=33, Predicted=16.9532, Expected=16.6063
# Month=34, Predicted=16.2816, Expected=15.8228
# Month=35, Predicted=15.6606, Expected=15.4543
# Month=36, Predicted=15.6849, Expected=15.6138
# Month=37, Predicted=16.2745, Expected=15.6954
# Month=38, Predicted=16.5382, Expected=16.7627
# Month=39, Predicted=17.5650, Expected=16.4941
# Month=40, Predicted=16.6581, Expected=17.7345
# Month=41, Predicted=17.6348, Expected=18.6944
# Month=42, Predicted=19.0276, Expected=19.1228
# Month=43, Predicted=18.9043, Expected=19.5704
# Month=44, Predicted=19.3302, Expected=19.2258
# Month=45, Predicted=18.8208, Expected=18.2178
# Month=46, Predicted=17.6619, Expected=17.2135
# Month=47, Predicted=16.7785, Expected=16.6554
# Month=48, Predicted=16.5334, Expected=16.8225
# Month=49, Predicted=17.1602, Expected=15.7773
# Month=50, Predicted=16.1429, Expected=15.7224
# Month=51, Predicted=16.4944, Expected=15.9967
# Month=52, Predicted=16.8751, Expected=17.0162
# Month=53, Predicted=17.6054, Expected=17.5568
# Month=54, Predicted=17.8438, Expected=17.8404
# Month=55, Predicted=17.7599, Expected=17.8664
# Month=56, Predicted=17.6652, Expected=17.5659
# Month=57, Predicted=17.1186, Expected=17.0753
# Month=58, Predicted=16.5209, Expected=16.6502
# Month=59, Predicted=16.2185, Expected=16.4285
# Month=60, Predicted=16.2852, Expected=16.5878
# Run 3 — RMSE: 0.461654, MSE: 0.213125, NMSE: 0.0019590249
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2689, Expected=13.7084
# Month=2, Predicted=14.1960, Expected=13.8026
# Month=3, Predicted=14.4734, Expected=14.3883
# Month=4, Predicted=15.1155, Expected=15.0615
# Month=5, Predicted=15.3423, Expected=15.6682
# Month=6, Predicted=15.6214, Expected=15.8360
# Month=7, Predicted=15.5648, Expected=15.7178
# Month=8, Predicted=15.2293, Expected=15.3110
# Month=9, Predicted=14.7372, Expected=14.7667
# Month=10, Predicted=14.2394, Expected=13.5419
# Month=11, Predicted=12.9326, Expected=13.5869
# Month=12, Predicted=13.5173, Expected=14.5144
# Month=13, Predicted=14.7336, Expected=14.3947
# Month=14, Predicted=14.7095, Expected=14.4996
# Month=15, Predicted=15.3327, Expected=14.7474
# Month=16, Predicted=15.4459, Expected=15.8019
# Month=17, Predicted=16.0952, Expected=16.5221
# Month=18, Predicted=16.5497, Expected=16.5417
# Month=19, Predicted=16.2168, Expected=16.7210
# Month=20, Predicted=16.2996, Expected=16.4288
# Month=21, Predicted=15.9456, Expected=15.7719
# Month=22, Predicted=15.1732, Expected=15.2959
# Month=23, Predicted=14.9153, Expected=15.1318
# Month=24, Predicted=15.0315, Expected=15.5377
# Month=25, Predicted=15.7479, Expected=15.8371
# Month=26, Predicted=16.3154, Expected=16.3719
# Month=27, Predicted=17.1851, Expected=16.3365
# Month=28, Predicted=16.8520, Expected=16.8969
# Month=29, Predicted=17.0273, Expected=17.0022
# Month=30, Predicted=16.8603, Expected=17.4155
# Month=31, Predicted=17.1435, Expected=17.5332
# Month=32, Predicted=17.2174, Expected=17.2849
# Month=33, Predicted=16.8149, Expected=16.6063
# Month=34, Predicted=16.0924, Expected=15.8228
# Month=35, Predicted=15.4190, Expected=15.4543
# Month=36, Predicted=15.3576, Expected=15.6138
# Month=37, Predicted=15.8505, Expected=15.6954
# Month=38, Predicted=16.2143, Expected=16.7627
# Month=39, Predicted=17.6609, Expected=16.4941
# Month=40, Predicted=16.9875, Expected=17.7345
# Month=41, Predicted=17.8929, Expected=18.6944
# Month=42, Predicted=18.7917, Expected=19.1228
# Month=43, Predicted=18.8938, Expected=19.5704
# Month=44, Predicted=19.2219, Expected=19.2258
# Month=45, Predicted=18.6930, Expected=18.2178
# Month=46, Predicted=17.4452, Expected=17.2135
# Month=47, Predicted=16.5901, Expected=16.6554
# Month=48, Predicted=16.3708, Expected=16.8225
# Month=49, Predicted=16.8522, Expected=15.7773
# Month=50, Predicted=15.7963, Expected=15.7224
# Month=51, Predicted=16.5295, Expected=15.9967
# Month=52, Predicted=16.9252, Expected=17.0162
# Month=53, Predicted=17.8786, Expected=17.5568
# Month=54, Predicted=17.8132, Expected=17.8404
# Month=55, Predicted=17.7229, Expected=17.8664
# Month=56, Predicted=17.5477, Expected=17.5659
# Month=57, Predicted=17.0273, Expected=17.0753
# Month=58, Predicted=16.4515, Expected=16.6502
# Month=59, Predicted=16.1526, Expected=16.4285
# Month=60, Predicted=16.1590, Expected=16.5878
# Run 4 — RMSE: 0.429784, MSE: 0.184714, NMSE: 0.0017116951
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2311, Expected=13.7084
# Month=2, Predicted=14.0543, Expected=13.8026
# Month=3, Predicted=14.4724, Expected=14.3883
# Month=4, Predicted=15.1515, Expected=15.0615
# Month=5, Predicted=15.4305, Expected=15.6682
# Month=6, Predicted=15.7542, Expected=15.8360
# Month=7, Predicted=15.6959, Expected=15.7178
# Month=8, Predicted=15.2710, Expected=15.3110
# Month=9, Predicted=14.7479, Expected=14.7667
# Month=10, Predicted=14.2745, Expected=13.5419
# Month=11, Predicted=13.0339, Expected=13.5869
# Month=12, Predicted=13.5089, Expected=14.5144
# Month=13, Predicted=14.7582, Expected=14.3947
# Month=14, Predicted=14.4635, Expected=14.4996
# Month=15, Predicted=15.3065, Expected=14.7474
# Month=16, Predicted=15.4541, Expected=15.8019
# Month=17, Predicted=16.1228, Expected=16.5221
# Month=18, Predicted=16.7403, Expected=16.5417
# Month=19, Predicted=16.2570, Expected=16.7210
# Month=20, Predicted=16.3331, Expected=16.4288
# Month=21, Predicted=16.0012, Expected=15.7719
# Month=22, Predicted=15.2967, Expected=15.2959
# Month=23, Predicted=15.0377, Expected=15.1318
# Month=24, Predicted=15.1904, Expected=15.5377
# Month=25, Predicted=15.8675, Expected=15.8371
# Month=26, Predicted=16.3820, Expected=16.3719
# Month=27, Predicted=17.2418, Expected=16.3365
# Month=28, Predicted=16.7226, Expected=16.8969
# Month=29, Predicted=17.0053, Expected=17.0022
# Month=30, Predicted=17.0127, Expected=17.4155
# Month=31, Predicted=17.2580, Expected=17.5332
# Month=32, Predicted=17.2932, Expected=17.2849
# Month=33, Predicted=16.9214, Expected=16.6063
# Month=34, Predicted=16.2297, Expected=15.8228
# Month=35, Predicted=15.5894, Expected=15.4543
# Month=36, Predicted=15.5341, Expected=15.6138
# Month=37, Predicted=16.0625, Expected=15.6954
# Month=38, Predicted=16.3634, Expected=16.7627
# Month=39, Predicted=17.6978, Expected=16.4941
# Month=40, Predicted=16.8805, Expected=17.7345
# Month=41, Predicted=17.8438, Expected=18.6944
# Month=42, Predicted=19.1695, Expected=19.1228
# Month=43, Predicted=19.0675, Expected=19.5704
# Month=44, Predicted=19.3174, Expected=19.2258
# Month=45, Predicted=18.7477, Expected=18.2178
# Month=46, Predicted=17.5497, Expected=17.2135
# Month=47, Predicted=16.6764, Expected=16.6554
# Month=48, Predicted=16.4381, Expected=16.8225
# Month=49, Predicted=17.0311, Expected=15.7773
# Month=50, Predicted=15.9159, Expected=15.7224
# Month=51, Predicted=16.3610, Expected=15.9967
# Month=52, Predicted=17.0176, Expected=17.0162
# Month=53, Predicted=17.7560, Expected=17.5568
# Month=54, Predicted=17.8318, Expected=17.8404
# Month=55, Predicted=17.7736, Expected=17.8664
# Month=56, Predicted=17.6777, Expected=17.5659
# Month=57, Predicted=17.0823, Expected=17.0753
# Month=58, Predicted=16.5084, Expected=16.6502
# Month=59, Predicted=16.2468, Expected=16.4285
# Month=60, Predicted=16.2969, Expected=16.5878
# Run 5 — RMSE: 0.422652, MSE: 0.178635, NMSE: 0.0016007715
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2682, Expected=13.7084
# Month=2, Predicted=14.2483, Expected=13.8026
# Month=3, Predicted=14.4023, Expected=14.3883
# Month=4, Predicted=15.0675, Expected=15.0615
# Month=5, Predicted=15.5146, Expected=15.6682
# Month=6, Predicted=15.9208, Expected=15.8360
# Month=7, Predicted=15.7590, Expected=15.7178
# Month=8, Predicted=15.3681, Expected=15.3110
# Month=9, Predicted=14.7201, Expected=14.7667
# Month=10, Predicted=14.2079, Expected=13.5419
# Month=11, Predicted=12.8415, Expected=13.5869
# Month=12, Predicted=13.5354, Expected=14.5144
# Month=13, Predicted=14.6691, Expected=14.3947
# Month=14, Predicted=14.7648, Expected=14.4996
# Month=15, Predicted=15.1574, Expected=14.7474
# Month=16, Predicted=15.1724, Expected=15.8019
# Month=17, Predicted=16.3179, Expected=16.5221
# Month=18, Predicted=16.9390, Expected=16.5417
# Month=19, Predicted=16.4830, Expected=16.7210
# Month=20, Predicted=16.5264, Expected=16.4288
# Month=21, Predicted=15.9306, Expected=15.7719
# Month=22, Predicted=15.1301, Expected=15.2959
# Month=23, Predicted=14.8669, Expected=15.1318
# Month=24, Predicted=14.9981, Expected=15.5377
# Month=25, Predicted=15.7169, Expected=15.8371
# Month=26, Predicted=16.2684, Expected=16.3719
# Month=27, Predicted=17.0915, Expected=16.3365
# Month=28, Predicted=16.7700, Expected=16.8969
# Month=29, Predicted=17.2986, Expected=17.0022
# Month=30, Predicted=17.1580, Expected=17.4155
# Month=31, Predicted=17.5606, Expected=17.5332
# Month=32, Predicted=17.5136, Expected=17.2849
# Month=33, Predicted=17.0069, Expected=16.6063
# Month=34, Predicted=16.0574, Expected=15.8228
# Month=35, Predicted=15.3040, Expected=15.4543
# Month=36, Predicted=15.2921, Expected=15.6138
# Month=37, Predicted=15.7833, Expected=15.6954
# Month=38, Predicted=16.1298, Expected=16.7627
# Month=39, Predicted=17.5721, Expected=16.4941
# Month=40, Predicted=16.8666, Expected=17.7345
# Month=41, Predicted=18.1288, Expected=18.6944
# Month=42, Predicted=19.1018, Expected=19.1228
# Month=43, Predicted=19.1039, Expected=19.5704
# Month=44, Predicted=19.4324, Expected=19.2258
# Month=45, Predicted=18.5715, Expected=18.2178
# Month=46, Predicted=17.2334, Expected=17.2135
# Month=47, Predicted=16.3939, Expected=16.6554
# Month=48, Predicted=16.2981, Expected=16.8225
# Month=49, Predicted=16.8093, Expected=15.7773
# Month=50, Predicted=15.7097, Expected=15.7224
# Month=51, Predicted=16.3398, Expected=15.9967
# Month=52, Predicted=16.6287, Expected=17.0162
# Month=53, Predicted=17.8677, Expected=17.5568
# Month=54, Predicted=18.0235, Expected=17.8404
# Month=55, Predicted=17.7199, Expected=17.8664
# Month=56, Predicted=17.5658, Expected=17.5659
# Month=57, Predicted=17.0690, Expected=17.0753
# Month=58, Predicted=16.4407, Expected=16.6502
# Month=59, Predicted=16.1679, Expected=16.4285
# Month=60, Predicted=16.1676, Expected=16.5878
# Run 6 — RMSE: 0.409951, MSE: 0.168060, NMSE: 0.0014469529
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.2533, Expected=13.7084
# Month=2, Predicted=14.1803, Expected=13.8026
# Month=3, Predicted=14.4192, Expected=14.3883
# Month=4, Predicted=15.1322, Expected=15.0615
# Month=5, Predicted=15.5531, Expected=15.6682
# Month=6, Predicted=15.7738, Expected=15.8360
# Month=7, Predicted=15.6616, Expected=15.7178
# Month=8, Predicted=15.3188, Expected=15.3110
# Month=9, Predicted=14.7368, Expected=14.7667
# Month=10, Predicted=14.2671, Expected=13.5419
# Month=11, Predicted=13.0137, Expected=13.5869
# Month=12, Predicted=13.5938, Expected=14.5144
# Month=13, Predicted=14.7644, Expected=14.3947
# Month=14, Predicted=14.7516, Expected=14.4996
# Month=15, Predicted=15.2860, Expected=14.7474
# Month=16, Predicted=15.4424, Expected=15.8019
# Month=17, Predicted=16.2095, Expected=16.5221
# Month=18, Predicted=16.6919, Expected=16.5417
# Month=19, Predicted=16.2566, Expected=16.7210
# Month=20, Predicted=16.4135, Expected=16.4288
# Month=21, Predicted=15.8981, Expected=15.7719
# Month=22, Predicted=15.2320, Expected=15.2959
# Month=23, Predicted=14.9592, Expected=15.1318
# Month=24, Predicted=15.0278, Expected=15.5377
# Month=25, Predicted=15.7466, Expected=15.8371
# Month=26, Predicted=16.2827, Expected=16.3719
# Month=27, Predicted=17.1130, Expected=16.3365
# Month=28, Predicted=16.8650, Expected=16.8969
# Month=29, Predicted=17.3029, Expected=17.0022
# Month=30, Predicted=17.0592, Expected=17.4155
# Month=31, Predicted=17.2875, Expected=17.5332
# Month=32, Predicted=17.2951, Expected=17.2849
# Month=33, Predicted=16.8445, Expected=16.6063
# Month=34, Predicted=16.1617, Expected=15.8228
# Month=35, Predicted=15.4779, Expected=15.4543
# Month=36, Predicted=15.3809, Expected=15.6138
# Month=37, Predicted=15.8385, Expected=15.6954
# Month=38, Predicted=16.1315, Expected=16.7627
# Month=39, Predicted=17.5774, Expected=16.4941
# Month=40, Predicted=16.9527, Expected=17.7345
# Month=41, Predicted=18.1734, Expected=18.6944
# Month=42, Predicted=19.0380, Expected=19.1228
# Month=43, Predicted=18.8801, Expected=19.5704
# Month=44, Predicted=19.3099, Expected=19.2258
# Month=45, Predicted=18.6354, Expected=18.2178
# Month=46, Predicted=17.5085, Expected=17.2135
# Month=47, Predicted=16.6563, Expected=16.6554
# Month=48, Predicted=16.3669, Expected=16.8225
# Month=49, Predicted=16.8685, Expected=15.7773
# Month=50, Predicted=15.7859, Expected=15.7224
# Month=51, Predicted=16.4686, Expected=15.9967
# Month=52, Predicted=16.8737, Expected=17.0162
# Month=53, Predicted=17.7283, Expected=17.5568
# Month=54, Predicted=17.8978, Expected=17.8404
# Month=55, Predicted=17.7018, Expected=17.8664
# Month=56, Predicted=17.5921, Expected=17.5659
# Month=57, Predicted=17.0504, Expected=17.0753
# Month=58, Predicted=16.4052, Expected=16.6502
# Month=59, Predicted=16.1588, Expected=16.4285
# Month=60, Predicted=16.1541, Expected=16.5878
# Run 7 — RMSE: 0.402552, MSE: 0.162048, NMSE: 0.0014821008
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2108, Expected=13.7084
# Month=2, Predicted=14.2189, Expected=13.8026
# Month=3, Predicted=14.4692, Expected=14.3883
# Month=4, Predicted=15.1174, Expected=15.0615
# Month=5, Predicted=15.4681, Expected=15.6682
# Month=6, Predicted=15.7031, Expected=15.8360
# Month=7, Predicted=15.6413, Expected=15.7178
# Month=8, Predicted=15.3216, Expected=15.3110
# Month=9, Predicted=14.7410, Expected=14.7667
# Month=10, Predicted=14.2135, Expected=13.5419
# Month=11, Predicted=12.9466, Expected=13.5869
# Month=12, Predicted=13.5377, Expected=14.5144
# Month=13, Predicted=14.6533, Expected=14.3947
# Month=14, Predicted=14.6121, Expected=14.4996
# Month=15, Predicted=15.2960, Expected=14.7474
# Month=16, Predicted=15.4119, Expected=15.8019
# Month=17, Predicted=16.1795, Expected=16.5221
# Month=18, Predicted=16.7428, Expected=16.5417
# Month=19, Predicted=16.2644, Expected=16.7210
# Month=20, Predicted=16.3896, Expected=16.4288
# Month=21, Predicted=15.9938, Expected=15.7719
# Month=22, Predicted=15.1624, Expected=15.2959
# Month=23, Predicted=14.8943, Expected=15.1318
# Month=24, Predicted=14.9876, Expected=15.5377
# Month=25, Predicted=15.7182, Expected=15.8371
# Month=26, Predicted=16.3037, Expected=16.3719
# Month=27, Predicted=17.1391, Expected=16.3365
# Month=28, Predicted=16.8390, Expected=16.8969
# Month=29, Predicted=17.1491, Expected=17.0022
# Month=30, Predicted=16.9779, Expected=17.4155
# Month=31, Predicted=17.2404, Expected=17.5332
# Month=32, Predicted=17.3812, Expected=17.2849
# Month=33, Predicted=16.8811, Expected=16.6063
# Month=34, Predicted=16.0790, Expected=15.8228
# Month=35, Predicted=15.4032, Expected=15.4543
# Month=36, Predicted=15.3681, Expected=15.6138
# Month=37, Predicted=15.8608, Expected=15.6954
# Month=38, Predicted=16.1972, Expected=16.7627
# Month=39, Predicted=17.6095, Expected=16.4941
# Month=40, Predicted=16.9090, Expected=17.7345
# Month=41, Predicted=18.0065, Expected=18.6944
# Month=42, Predicted=19.0896, Expected=19.1228
# Month=43, Predicted=18.9833, Expected=19.5704
# Month=44, Predicted=19.4454, Expected=19.2258
# Month=45, Predicted=18.8812, Expected=18.2178
# Month=46, Predicted=17.4039, Expected=17.2135
# Month=47, Predicted=16.5315, Expected=16.6554
# Month=48, Predicted=16.3077, Expected=16.8225
# Month=49, Predicted=16.7963, Expected=15.7773
# Month=50, Predicted=15.7364, Expected=15.7224
# Month=51, Predicted=16.5082, Expected=15.9967
# Month=52, Predicted=16.9271, Expected=17.0162
# Month=53, Predicted=17.8165, Expected=17.5568
# Month=54, Predicted=18.0077, Expected=17.8404
# Month=55, Predicted=17.7649, Expected=17.8664
# Month=56, Predicted=17.6066, Expected=17.5659
# Month=57, Predicted=17.0717, Expected=17.0753
# Month=58, Predicted=16.4008, Expected=16.6502
# Month=59, Predicted=16.1314, Expected=16.4285
# Month=60, Predicted=16.1531, Expected=16.5878
# Run 8 — RMSE: 0.417659, MSE: 0.174439, NMSE: 0.0015232109
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.1969, Expected=13.7084
# Month=2, Predicted=14.1215, Expected=13.8026
# Month=3, Predicted=14.3583, Expected=14.3883
# Month=4, Predicted=14.9152, Expected=15.0615
# Month=5, Predicted=15.2958, Expected=15.6682
# Month=6, Predicted=15.6015, Expected=15.8360
# Month=7, Predicted=15.4740, Expected=15.7178
# Month=8, Predicted=15.2400, Expected=15.3110
# Month=9, Predicted=14.7221, Expected=14.7667
# Month=10, Predicted=14.1420, Expected=13.5419
# Month=11, Predicted=12.9577, Expected=13.5869
# Month=12, Predicted=13.5388, Expected=14.5144
# Month=13, Predicted=14.6167, Expected=14.3947
# Month=14, Predicted=14.6423, Expected=14.4996
# Month=15, Predicted=15.2130, Expected=14.7474
# Month=16, Predicted=15.2877, Expected=15.8019
# Month=17, Predicted=16.1532, Expected=16.5221
# Month=18, Predicted=16.6318, Expected=16.5417
# Month=19, Predicted=16.1816, Expected=16.7210
# Month=20, Predicted=16.3442, Expected=16.4288
# Month=21, Predicted=15.8763, Expected=15.7719
# Month=22, Predicted=15.1090, Expected=15.2959
# Month=23, Predicted=14.8161, Expected=15.1318
# Month=24, Predicted=15.0378, Expected=15.5377
# Month=25, Predicted=15.6510, Expected=15.8371
# Month=26, Predicted=16.1611, Expected=16.3719
# Month=27, Predicted=17.0530, Expected=16.3365
# Month=28, Predicted=16.7533, Expected=16.8969
# Month=29, Predicted=17.1125, Expected=17.0022
# Month=30, Predicted=16.8669, Expected=17.4155
# Month=31, Predicted=17.1992, Expected=17.5332
# Month=32, Predicted=17.1900, Expected=17.2849
# Month=33, Predicted=16.8267, Expected=16.6063
# Month=34, Predicted=16.0393, Expected=15.8228
# Month=35, Predicted=15.3329, Expected=15.4543
# Month=36, Predicted=15.3032, Expected=15.6138
# Month=37, Predicted=15.7389, Expected=15.6954
# Month=38, Predicted=16.0869, Expected=16.7627
# Month=39, Predicted=17.6107, Expected=16.4941
# Month=40, Predicted=16.9351, Expected=17.7345
# Month=41, Predicted=18.0428, Expected=18.6944
# Month=42, Predicted=18.8420, Expected=19.1228
# Month=43, Predicted=18.8101, Expected=19.5704
# Month=44, Predicted=19.1723, Expected=19.2258
# Month=45, Predicted=18.6229, Expected=18.2178
# Month=46, Predicted=17.4165, Expected=17.2135
# Month=47, Predicted=16.3890, Expected=16.6554
# Month=48, Predicted=16.3618, Expected=16.8225
# Month=49, Predicted=16.8569, Expected=15.7773
# Month=50, Predicted=15.5961, Expected=15.7224
# Month=51, Predicted=16.4110, Expected=15.9967
# Month=52, Predicted=16.8615, Expected=17.0162
# Month=53, Predicted=17.8837, Expected=17.5568
# Month=54, Predicted=18.0094, Expected=17.8404
# Month=55, Predicted=17.8060, Expected=17.8664
# Month=56, Predicted=17.5109, Expected=17.5659
# Month=57, Predicted=17.0537, Expected=17.0753
# Month=58, Predicted=16.4346, Expected=16.6502
# Month=59, Predicted=16.0321, Expected=16.4285
# Month=60, Predicted=16.1923, Expected=16.5878
# Run 9 — RMSE: 0.424112, MSE: 0.179871, NMSE: 0.0016014274
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.4598, Expected=13.7084
# Month=2, Predicted=14.2902, Expected=13.8026
# Month=3, Predicted=14.2446, Expected=14.3883
# Month=4, Predicted=14.7263, Expected=15.0615
# Month=5, Predicted=15.3415, Expected=15.6682
# Month=6, Predicted=15.7908, Expected=15.8360
# Month=7, Predicted=15.6928, Expected=15.7178
# Month=8, Predicted=15.3412, Expected=15.3110
# Month=9, Predicted=14.7795, Expected=14.7667
# Month=10, Predicted=14.2119, Expected=13.5419
# Month=11, Predicted=12.8850, Expected=13.5869
# Month=12, Predicted=13.5239, Expected=14.5144
# Month=13, Predicted=15.0741, Expected=14.3947
# Month=14, Predicted=14.8932, Expected=14.4996
# Month=15, Predicted=14.8053, Expected=14.7474
# Month=16, Predicted=14.9867, Expected=15.8019
# Month=17, Predicted=16.0678, Expected=16.5221
# Month=18, Predicted=16.7798, Expected=16.5417
# Month=19, Predicted=16.3845, Expected=16.7210
# Month=20, Predicted=16.4600, Expected=16.4288
# Month=21, Predicted=15.9731, Expected=15.7719
# Month=22, Predicted=15.1457, Expected=15.2959
# Month=23, Predicted=14.8174, Expected=15.1318
# Month=24, Predicted=15.0072, Expected=15.5377
# Month=25, Predicted=15.8854, Expected=15.8371
# Month=26, Predicted=16.3456, Expected=16.3719
# Month=27, Predicted=16.8508, Expected=16.3365
# Month=28, Predicted=16.5340, Expected=16.8969
# Month=29, Predicted=17.0338, Expected=17.0022
# Month=30, Predicted=16.9941, Expected=17.4155
# Month=31, Predicted=17.3703, Expected=17.5332
# Month=32, Predicted=17.4247, Expected=17.2849
# Month=33, Predicted=17.0024, Expected=16.6063
# Month=34, Predicted=16.1482, Expected=15.8228
# Month=35, Predicted=15.3683, Expected=15.4543
# Month=36, Predicted=15.3179, Expected=15.6138
# Month=37, Predicted=15.9261, Expected=15.6954
# Month=38, Predicted=16.1372, Expected=16.7627
# Month=39, Predicted=17.2875, Expected=16.4941
# Month=40, Predicted=16.6878, Expected=17.7345
# Month=41, Predicted=17.8697, Expected=18.6944
# Month=42, Predicted=19.0200, Expected=19.1228
# Month=43, Predicted=19.0815, Expected=19.5704
# Month=44, Predicted=19.3826, Expected=19.2258
# Month=45, Predicted=18.6810, Expected=18.2178
# Month=46, Predicted=17.3239, Expected=17.2135
# Month=47, Predicted=16.3616, Expected=16.6554
# Month=48, Predicted=16.0546, Expected=16.8225
# Month=49, Predicted=16.7291, Expected=15.7773
# Month=50, Predicted=15.7841, Expected=15.7224
# Month=51, Predicted=16.0238, Expected=15.9967
# Month=52, Predicted=16.6095, Expected=17.0162
# Month=53, Predicted=17.6778, Expected=17.5568
# Month=54, Predicted=18.0530, Expected=17.8404
# Month=55, Predicted=17.9735, Expected=17.8664
# Month=56, Predicted=17.7014, Expected=17.5659
# Month=57, Predicted=17.1384, Expected=17.0753
# Month=58, Predicted=16.5320, Expected=16.6502
# Month=59, Predicted=16.2196, Expected=16.4285
# Month=60, Predicted=16.2944, Expected=16.5878
# Run 10 — RMSE: 0.426057, MSE: 0.181525, NMSE: 0.0016122827
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.3935, Expected=13.7084
# Month=2, Predicted=14.2274, Expected=13.8026
# Month=3, Predicted=14.1765, Expected=14.3883
# Month=4, Predicted=14.8002, Expected=15.0615
# Month=5, Predicted=15.3732, Expected=15.6682
# Month=6, Predicted=15.8813, Expected=15.8360
# Month=7, Predicted=15.8095, Expected=15.7178
# Month=8, Predicted=15.4755, Expected=15.3110
# Month=9, Predicted=14.8715, Expected=14.7667
# Month=10, Predicted=14.2597, Expected=13.5419
# Month=11, Predicted=12.7383, Expected=13.5869
# Month=12, Predicted=13.5244, Expected=14.5144
# Month=13, Predicted=15.0995, Expected=14.3947
# Month=14, Predicted=14.8412, Expected=14.4996
# Month=15, Predicted=14.8926, Expected=14.7474
# Month=16, Predicted=14.9540, Expected=15.8019
# Month=17, Predicted=16.0823, Expected=16.5221
# Month=18, Predicted=16.8487, Expected=16.5417
# Month=19, Predicted=16.4871, Expected=16.7210
# Month=20, Predicted=16.5741, Expected=16.4288
# Month=21, Predicted=16.0317, Expected=15.7719
# Month=22, Predicted=15.1608, Expected=15.2959
# Month=23, Predicted=14.8329, Expected=15.1318
# Month=24, Predicted=15.0617, Expected=15.5377
# Month=25, Predicted=15.9439, Expected=15.8371
# Month=26, Predicted=16.3137, Expected=16.3719
# Month=27, Predicted=16.8487, Expected=16.3365
# Month=28, Predicted=16.5135, Expected=16.8969
# Month=29, Predicted=17.1519, Expected=17.0022
# Month=30, Predicted=17.0788, Expected=17.4155
# Month=31, Predicted=17.5674, Expected=17.5332
# Month=32, Predicted=17.5535, Expected=17.2849
# Month=33, Predicted=17.1012, Expected=16.6063
# Month=34, Predicted=16.1412, Expected=15.8228
# Month=35, Predicted=15.2544, Expected=15.4543
# Month=36, Predicted=15.2200, Expected=15.6138
# Month=37, Predicted=15.9171, Expected=15.6954
# Month=38, Predicted=16.1282, Expected=16.7627
# Month=39, Predicted=17.3666, Expected=16.4941
# Month=40, Predicted=16.7106, Expected=17.7345
# Month=41, Predicted=18.1115, Expected=18.6944
# Month=42, Predicted=19.0158, Expected=19.1228
# Month=43, Predicted=19.0804, Expected=19.5704
# Month=44, Predicted=19.3770, Expected=19.2258
# Month=45, Predicted=18.6576, Expected=18.2178
# Month=46, Predicted=17.2281, Expected=17.2135
# Month=47, Predicted=16.3255, Expected=16.6554
# Month=48, Predicted=16.1585, Expected=16.8225
# Month=49, Predicted=17.0559, Expected=15.7773
# Month=50, Predicted=15.8485, Expected=15.7224
# Month=51, Predicted=16.1310, Expected=15.9967
# Month=52, Predicted=16.6779, Expected=17.0162
# Month=53, Predicted=17.7507, Expected=17.5568
# Month=54, Predicted=18.0569, Expected=17.8404
# Month=55, Predicted=18.0368, Expected=17.8664
# Month=56, Predicted=17.7205, Expected=17.5659
# Month=57, Predicted=17.1659, Expected=17.0753
# Month=58, Predicted=16.5540, Expected=16.6502
# Month=59, Predicted=16.2338, Expected=16.4285
# Month=60, Predicted=16.2904, Expected=16.5878
# Run 11 — RMSE: 0.441959, MSE: 0.195328, NMSE: 0.0016785426
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2930, Expected=13.7084
# Month=2, Predicted=14.2262, Expected=13.8026
# Month=3, Predicted=14.3110, Expected=14.3883
# Month=4, Predicted=15.0733, Expected=15.0615
# Month=5, Predicted=15.4867, Expected=15.6682
# Month=6, Predicted=15.9335, Expected=15.8360
# Month=7, Predicted=15.7407, Expected=15.7178
# Month=8, Predicted=15.3664, Expected=15.3110
# Month=9, Predicted=14.7715, Expected=14.7667
# Month=10, Predicted=14.2073, Expected=13.5419
# Month=11, Predicted=12.6831, Expected=13.5869
# Month=12, Predicted=13.5874, Expected=14.5144
# Month=13, Predicted=14.7412, Expected=14.3947
# Month=14, Predicted=14.8249, Expected=14.4996
# Month=15, Predicted=15.0649, Expected=14.7474
# Month=16, Predicted=15.0126, Expected=15.8019
# Month=17, Predicted=16.3206, Expected=16.5221
# Month=18, Predicted=16.9228, Expected=16.5417
# Month=19, Predicted=16.3556, Expected=16.7210
# Month=20, Predicted=16.4717, Expected=16.4288
# Month=21, Predicted=16.0378, Expected=15.7719
# Month=22, Predicted=15.1800, Expected=15.2959
# Month=23, Predicted=14.8164, Expected=15.1318
# Month=24, Predicted=15.0093, Expected=15.5377
# Month=25, Predicted=15.8659, Expected=15.8371
# Month=26, Predicted=16.2809, Expected=16.3719
# Month=27, Predicted=17.0019, Expected=16.3365
# Month=28, Predicted=16.6179, Expected=16.8969
# Month=29, Predicted=17.2858, Expected=17.0022
# Month=30, Predicted=17.1133, Expected=17.4155
# Month=31, Predicted=17.5443, Expected=17.5332
# Month=32, Predicted=17.4787, Expected=17.2849
# Month=33, Predicted=16.9831, Expected=16.6063
# Month=34, Predicted=15.9602, Expected=15.8228
# Month=35, Predicted=15.2223, Expected=15.4543
# Month=36, Predicted=15.2110, Expected=15.6138
# Month=37, Predicted=15.8353, Expected=15.6954
# Month=38, Predicted=16.1315, Expected=16.7627
# Month=39, Predicted=17.5197, Expected=16.4941
# Month=40, Predicted=16.7802, Expected=17.7345
# Month=41, Predicted=18.2161, Expected=18.6944
# Month=42, Predicted=19.2319, Expected=19.1228
# Month=43, Predicted=19.0516, Expected=19.5704
# Month=44, Predicted=19.3819, Expected=19.2258
# Month=45, Predicted=18.7270, Expected=18.2178
# Month=46, Predicted=17.2532, Expected=17.2135
# Month=47, Predicted=16.3218, Expected=16.6554
# Month=48, Predicted=16.2626, Expected=16.8225
# Month=49, Predicted=17.0174, Expected=15.7773
# Month=50, Predicted=15.8024, Expected=15.7224
# Month=51, Predicted=16.4949, Expected=15.9967
# Month=52, Predicted=16.5670, Expected=17.0162
# Month=53, Predicted=17.9563, Expected=17.5568
# Month=54, Predicted=17.9459, Expected=17.8404
# Month=55, Predicted=17.7535, Expected=17.8664
# Month=56, Predicted=17.5298, Expected=17.5659
# Month=57, Predicted=17.0441, Expected=17.0753
# Month=58, Predicted=16.4353, Expected=16.6502
# Month=59, Predicted=16.1126, Expected=16.4285
# Month=60, Predicted=16.1021, Expected=16.5878
# Run 12 — RMSE: 0.438458, MSE: 0.192245, NMSE: 0.0016283218
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2480, Expected=13.7084
# Month=2, Predicted=14.2358, Expected=13.8026
# Month=3, Predicted=14.5419, Expected=14.3883
# Month=4, Predicted=15.2035, Expected=15.0615
# Month=5, Predicted=15.4730, Expected=15.6682
# Month=6, Predicted=15.8042, Expected=15.8360
# Month=7, Predicted=15.7432, Expected=15.7178
# Month=8, Predicted=15.3295, Expected=15.3110
# Month=9, Predicted=14.6709, Expected=14.7667
# Month=10, Predicted=14.2854, Expected=13.5419
# Month=11, Predicted=13.0531, Expected=13.5869
# Month=12, Predicted=13.5690, Expected=14.5144
# Month=13, Predicted=14.6059, Expected=14.3947
# Month=14, Predicted=14.7499, Expected=14.4996
# Month=15, Predicted=15.4557, Expected=14.7474
# Month=16, Predicted=15.4370, Expected=15.8019
# Month=17, Predicted=16.1837, Expected=16.5221
# Month=18, Predicted=16.6940, Expected=16.5417
# Month=19, Predicted=16.3685, Expected=16.7210
# Month=20, Predicted=16.4628, Expected=16.4288
# Month=21, Predicted=15.8319, Expected=15.7719
# Month=22, Predicted=15.2211, Expected=15.2959
# Month=23, Predicted=14.9975, Expected=15.1318
# Month=24, Predicted=15.0048, Expected=15.5377
# Month=25, Predicted=15.7019, Expected=15.8371
# Month=26, Predicted=16.3084, Expected=16.3719
# Month=27, Predicted=17.2761, Expected=16.3365
# Month=28, Predicted=16.9277, Expected=16.8969
# Month=29, Predicted=17.2860, Expected=17.0022
# Month=30, Predicted=17.0014, Expected=17.4155
# Month=31, Predicted=17.3712, Expected=17.5332
# Month=32, Predicted=17.2639, Expected=17.2849
# Month=33, Predicted=16.8490, Expected=16.6063
# Month=34, Predicted=16.1788, Expected=15.8228
# Month=35, Predicted=15.5337, Expected=15.4543
# Month=36, Predicted=15.3784, Expected=15.6138
# Month=37, Predicted=15.7596, Expected=15.6954
# Month=38, Predicted=16.1298, Expected=16.7627
# Month=39, Predicted=17.7054, Expected=16.4941
# Month=40, Predicted=17.0035, Expected=17.7345
# Month=41, Predicted=18.1394, Expected=18.6944
# Month=42, Predicted=18.9442, Expected=19.1228
# Month=43, Predicted=19.0569, Expected=19.5704
# Month=44, Predicted=19.3902, Expected=19.2258
# Month=45, Predicted=18.4668, Expected=18.2178
# Month=46, Predicted=17.3703, Expected=17.2135
# Month=47, Predicted=16.6937, Expected=16.6554
# Month=48, Predicted=16.3516, Expected=16.8225
# Month=49, Predicted=16.7188, Expected=15.7773
# Month=50, Predicted=15.7198, Expected=15.7224
# Month=51, Predicted=16.5303, Expected=15.9967
# Month=52, Predicted=16.8479, Expected=17.0162
# Month=53, Predicted=17.8272, Expected=17.5568
# Month=54, Predicted=17.8553, Expected=17.8404
# Month=55, Predicted=17.6929, Expected=17.8664
# Month=56, Predicted=17.5395, Expected=17.5659
# Month=57, Predicted=17.0956, Expected=17.0753
# Month=58, Predicted=16.4044, Expected=16.6502
# Month=59, Predicted=16.1507, Expected=16.4285
# Month=60, Predicted=16.1425, Expected=16.5878
# Run 13 — RMSE: 0.407412, MSE: 0.165984, NMSE: 0.0015173344
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.1012, Expected=13.7084
# Month=2, Predicted=13.8161, Expected=13.8026
# Month=3, Predicted=13.9762, Expected=14.3883
# Month=4, Predicted=14.5928, Expected=15.0615
# Month=5, Predicted=15.2892, Expected=15.6682
# Month=6, Predicted=15.9692, Expected=15.8360
# Month=7, Predicted=16.0801, Expected=15.7178
# Month=8, Predicted=15.8312, Expected=15.3110
# Month=9, Predicted=15.3935, Expected=14.7667
# Month=10, Predicted=14.8237, Expected=13.5419
# Month=11, Predicted=13.5478, Expected=13.5869
# Month=12, Predicted=13.6220, Expected=14.5144
# Month=13, Predicted=14.6545, Expected=14.3947
# Month=14, Predicted=14.6530, Expected=14.4996
# Month=15, Predicted=14.4765, Expected=14.7474
# Month=16, Predicted=14.6823, Expected=15.8019
# Month=17, Predicted=15.7621, Expected=16.5221
# Month=18, Predicted=16.6487, Expected=16.5417
# Month=19, Predicted=16.3861, Expected=16.7210
# Month=20, Predicted=16.4092, Expected=16.4288
# Month=21, Predicted=16.0602, Expected=15.7719
# Month=22, Predicted=15.4033, Expected=15.2959
# Month=23, Predicted=14.9272, Expected=15.1318
# Month=24, Predicted=14.7631, Expected=15.5377
# Month=25, Predicted=15.1691, Expected=15.8371
# Month=26, Predicted=15.4684, Expected=16.3719
# Month=27, Predicted=16.0033, Expected=16.3365
# Month=28, Predicted=15.9679, Expected=16.8969
# Month=29, Predicted=16.5282, Expected=17.0022
# Month=30, Predicted=16.6335, Expected=17.4155
# Month=31, Predicted=17.0468, Expected=17.5332
# Month=32, Predicted=17.1645, Expected=17.2849
# Month=33, Predicted=16.9162, Expected=16.6063
# Month=34, Predicted=16.2376, Expected=15.8228
# Month=35, Predicted=15.4541, Expected=15.4543
# Month=36, Predicted=15.0857, Expected=15.6138
# Month=37, Predicted=15.2451, Expected=15.6954
# Month=38, Predicted=15.3267, Expected=16.7627
# Month=39, Predicted=16.3941, Expected=16.4941
# Month=40, Predicted=16.1255, Expected=17.7345
# Month=41, Predicted=17.3658, Expected=18.6944
# Month=42, Predicted=18.4255, Expected=19.1228
# Month=43, Predicted=18.7542, Expected=19.5704
# Month=44, Predicted=19.2017, Expected=19.2258
# Month=45, Predicted=18.8572, Expected=18.2178
# Month=46, Predicted=17.8492, Expected=17.2135
# Month=47, Predicted=16.8448, Expected=16.6554
# Month=48, Predicted=16.2867, Expected=16.8225
# Month=49, Predicted=16.4538, Expected=15.7773
# Month=50, Predicted=15.4087, Expected=15.7224
# Month=51, Predicted=15.3537, Expected=15.9967
# Month=52, Predicted=15.6280, Expected=17.0162
# Month=53, Predicted=16.6475, Expected=17.5568
# Month=54, Predicted=17.2817, Expected=17.8404
# Month=55, Predicted=17.6576, Expected=17.8664
# Month=56, Predicted=17.7774, Expected=17.5659
# Month=57, Predicted=17.5483, Expected=17.0753
# Month=58, Predicted=17.0577, Expected=16.6502
# Month=59, Predicted=16.6325, Expected=16.4285
# Month=60, Predicted=16.4109, Expected=16.5878
# Run 14 — RMSE: 0.637525, MSE: 0.406438, NMSE: 0.0038069983
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.1317, Expected=13.7084
# Month=2, Predicted=13.9877, Expected=13.8026
# Month=3, Predicted=14.4360, Expected=14.3883
# Month=4, Predicted=15.3105, Expected=15.0615
# Month=5, Predicted=15.5287, Expected=15.6682
# Month=6, Predicted=15.7917, Expected=15.8360
# Month=7, Predicted=15.7088, Expected=15.7178
# Month=8, Predicted=15.2569, Expected=15.3110
# Month=9, Predicted=14.6887, Expected=14.7667
# Month=10, Predicted=14.2003, Expected=13.5419
# Month=11, Predicted=12.9770, Expected=13.5869
# Month=12, Predicted=13.5090, Expected=14.5144
# Month=13, Predicted=14.6433, Expected=14.3947
# Month=14, Predicted=14.4723, Expected=14.4996
# Month=15, Predicted=15.2400, Expected=14.7474
# Month=16, Predicted=15.5413, Expected=15.8019
# Month=17, Predicted=16.3372, Expected=16.5221
# Month=18, Predicted=16.8158, Expected=16.5417
# Month=19, Predicted=16.3001, Expected=16.7210
# Month=20, Predicted=16.3213, Expected=16.4288
# Month=21, Predicted=15.9203, Expected=15.7719
# Month=22, Predicted=15.1974, Expected=15.2959
# Month=23, Predicted=14.9642, Expected=15.1318
# Month=24, Predicted=15.0602, Expected=15.5377
# Month=25, Predicted=15.6870, Expected=15.8371
# Month=26, Predicted=16.2274, Expected=16.3719
# Month=27, Predicted=17.2329, Expected=16.3365
# Month=28, Predicted=16.8729, Expected=16.8969
# Month=29, Predicted=17.1729, Expected=17.0022
# Month=30, Predicted=17.0404, Expected=17.4155
# Month=31, Predicted=17.3124, Expected=17.5332
# Month=32, Predicted=17.2113, Expected=17.2849
# Month=33, Predicted=16.8130, Expected=16.6063
# Month=34, Predicted=16.1022, Expected=15.8228
# Month=35, Predicted=15.4641, Expected=15.4543
# Month=36, Predicted=15.3761, Expected=15.6138
# Month=37, Predicted=15.8582, Expected=15.6954
# Month=38, Predicted=16.1861, Expected=16.7627
# Month=39, Predicted=17.6740, Expected=16.4941
# Month=40, Predicted=16.8613, Expected=17.7345
# Month=41, Predicted=18.0068, Expected=18.6944
# Month=42, Predicted=19.1361, Expected=19.1228
# Month=43, Predicted=18.9852, Expected=19.5704
# Month=44, Predicted=19.2639, Expected=19.2258
# Month=45, Predicted=18.6988, Expected=18.2178
# Month=46, Predicted=17.5782, Expected=17.2135
# Month=47, Predicted=16.7530, Expected=16.6554
# Month=48, Predicted=16.4997, Expected=16.8225
# Month=49, Predicted=17.0232, Expected=15.7773
# Month=50, Predicted=15.9094, Expected=15.7224
# Month=51, Predicted=16.2859, Expected=15.9967
# Month=52, Predicted=16.7821, Expected=17.0162
# Month=53, Predicted=17.7029, Expected=17.5568
# Month=54, Predicted=17.9235, Expected=17.8404
# Month=55, Predicted=17.8030, Expected=17.8664
# Month=56, Predicted=17.5715, Expected=17.5659
# Month=57, Predicted=17.1006, Expected=17.0753
# Month=58, Predicted=16.6030, Expected=16.6502
# Month=59, Predicted=16.3515, Expected=16.4285
# Month=60, Predicted=16.3101, Expected=16.5878
# Run 15 — RMSE: 0.411060, MSE: 0.168970, NMSE: 0.0014788430
#
# ===== RUN 16/30 =====

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
