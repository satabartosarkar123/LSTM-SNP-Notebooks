# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# GPU Acceleration Settings (CUDA + Apple Metal Support)
# ============================================================
import tensorflow as tf
import platform

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        # Detect GPU type
        if platform.system() == 'Darwin' and platform.processor() == 'arm':
            print(f"Apple Metal GPU Enabled: Found {len(physical_devices)} GPU(s) via tensorflow-metal")
            print(f"  Chipset: Apple {platform.machine()} (M-series)")
        else:
            print(f"CUDA GPU Enabled: Found {len(physical_devices)} GPU(s) - Memory Growth Set")
        for d in physical_devices:
            print(f"  Device: {d.name}")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    if platform.system() == 'Darwin' and platform.processor() == 'arm':
        print("Apple Silicon detected but no GPU found.")
        print("  Install tensorflow-metal: pip install tensorflow-metal")
    else:
        print("No GPU found. Falling back to CPU.")
        print("  For CUDA: ensure NVIDIA drivers + CUDA toolkit are installed.")

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    352
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 361 (1.41 KB)
# Trainable params: 361 (1.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on Dow Jones Industrial Index (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.526428)
# ================================================================================
#
# Data shape: (291,)
# First 5 values: [3645.26148423 3625.9272138  3634.34096137 3621.30176553 3606.87673511]
# Supervised data shape: (290, 3)
# Train: (230, 3), Test: (60, 3)
# X_train shape: (230, 1, 2), y_train shape: (230,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3802.8389, Expected=3796.1139
# Month=2, Predicted=3796.8971, Expected=3793.0240
# Month=3, Predicted=3793.5992, Expected=3765.6570
# Month=4, Predicted=3763.4990, Expected=3748.1286
# Month=5, Predicted=3747.2790, Expected=3754.3337
# Month=6, Predicted=3751.0782, Expected=3754.9339
# Month=7, Predicted=3753.2993, Expected=3767.0982
# Month=8, Predicted=3767.2323, Expected=3750.6516
# Month=9, Predicted=3749.9536, Expected=3769.4487
# Month=10, Predicted=3770.5829, Expected=3759.5828
# Month=11, Predicted=3759.0430, Expected=3784.9396
# Month=12, Predicted=3785.4834, Expected=3776.2658
# Month=13, Predicted=3776.6741, Expected=3755.4558
# Month=14, Predicted=3755.8076, Expected=3754.3681
# Month=15, Predicted=3753.7404, Expected=3750.8239
# Month=16, Predicted=3748.5821, Expected=3775.7500
# Month=17, Predicted=3776.1805, Expected=3846.6561
# Month=18, Predicted=3857.0198, Expected=3830.9294
# Month=19, Predicted=3835.1044, Expected=3881.2132
# Month=20, Predicted=3880.9501, Expected=3898.3362
# Month=21, Predicted=3908.2088, Expected=3917.4832
# Month=22, Predicted=3916.5474, Expected=3914.1172
# Month=23, Predicted=3914.1046, Expected=3901.5435
# Month=24, Predicted=3900.8279, Expected=3885.2002
# Month=25, Predicted=3883.4556, Expected=3892.2451
# Month=26, Predicted=3890.5826, Expected=3899.6669
# Month=27, Predicted=3899.1809, Expected=3885.6275
# Month=28, Predicted=3884.4201, Expected=3908.2336
# Month=29, Predicted=3909.1482, Expected=3875.4078
# Month=30, Predicted=3871.6716, Expected=3859.5120
# Month=31, Predicted=3862.1459, Expected=3879.9687
# Month=32, Predicted=3878.1656, Expected=3893.2937
# Month=33, Predicted=3895.0333, Expected=3953.4607
# Month=34, Predicted=3956.9622, Expected=3932.8670
# Month=35, Predicted=3935.4543, Expected=3936.3431
# Month=36, Predicted=3938.9935, Expected=3869.8593
# Month=37, Predicted=3860.8884, Expected=3851.2471
# Month=38, Predicted=3855.3942, Expected=3836.7683
# Month=39, Predicted=3826.6766, Expected=3832.0688
# Month=40, Predicted=3827.3990, Expected=3849.7587
# Month=41, Predicted=3849.8156, Expected=3862.2441
# Month=42, Predicted=3864.9696, Expected=3878.6123
# Month=43, Predicted=3880.4520, Expected=3855.0054
# Month=44, Predicted=3854.5843, Expected=3842.4833
# Month=45, Predicted=3844.2696, Expected=3847.2433
# Month=46, Predicted=3845.2468, Expected=3801.1048
# Month=47, Predicted=3795.1772, Expected=3786.6840
# Month=48, Predicted=3788.9847, Expected=3776.0367
# Month=49, Predicted=3769.8793, Expected=3796.7972
# Month=50, Predicted=3795.4194, Expected=3821.0598
# Month=51, Predicted=3825.1973, Expected=3877.3486
# Month=52, Predicted=3882.7101, Expected=3875.8349
# Month=53, Predicted=3880.4638, Expected=3889.3484
# Month=54, Predicted=3889.6911, Expected=3911.1229
# Month=55, Predicted=3913.4728, Expected=3922.9724
# Month=56, Predicted=3923.8607, Expected=3917.9201
# Month=57, Predicted=3917.3211, Expected=3936.3097
# Month=58, Predicted=3936.6365, Expected=3911.1479
# Month=59, Predicted=3908.3991, Expected=3890.6722
# Month=60, Predicted=3891.6834, Expected=3854.8904
# Run 1 — RMSE: 24.475198, MSE: 599.035308, NMSE: 0.0026755869
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3801.0768, Expected=3796.1139
# Month=2, Predicted=3797.8613, Expected=3793.0240
# Month=3, Predicted=3792.9025, Expected=3765.6570
# Month=4, Predicted=3763.7271, Expected=3748.1286
# Month=5, Predicted=3746.7052, Expected=3754.3337
# Month=6, Predicted=3752.2618, Expected=3754.9339
# Month=7, Predicted=3754.1407, Expected=3767.0982
# Month=8, Predicted=3767.9420, Expected=3750.6516
# Month=9, Predicted=3750.8863, Expected=3769.4487
# Month=10, Predicted=3770.0790, Expected=3759.5828
# Month=11, Predicted=3759.1648, Expected=3784.9396
# Month=12, Predicted=3785.5094, Expected=3776.2658
# Month=13, Predicted=3776.6981, Expected=3755.4558
# Month=14, Predicted=3755.4287, Expected=3754.3681
# Month=15, Predicted=3754.0371, Expected=3750.8239
# Month=16, Predicted=3749.4773, Expected=3775.7500
# Month=17, Predicted=3776.7480, Expected=3846.6561
# Month=18, Predicted=3851.3618, Expected=3830.9294
# Month=19, Predicted=3835.9710, Expected=3881.2132
# Month=20, Predicted=3878.4039, Expected=3898.3362
# Month=21, Predicted=3900.6779, Expected=3917.4832
# Month=22, Predicted=3916.9253, Expected=3914.1172
# Month=23, Predicted=3913.4439, Expected=3901.5435
# Month=24, Predicted=3900.0751, Expected=3885.2002
# Month=25, Predicted=3882.9786, Expected=3892.2451
# Month=26, Predicted=3890.5453, Expected=3899.6669
# Month=27, Predicted=3898.6731, Expected=3885.6275
# Month=28, Predicted=3885.0469, Expected=3908.2336
# Month=29, Predicted=3908.5373, Expected=3875.4078
# Month=30, Predicted=3872.9312, Expected=3859.5120
# Month=31, Predicted=3859.0357, Expected=3879.9687
# Month=32, Predicted=3878.8508, Expected=3893.2937
# Month=33, Predicted=3894.5577, Expected=3953.4607
# Month=34, Predicted=3955.6605, Expected=3932.8670
# Month=35, Predicted=3936.4559, Expected=3936.3431
# Month=36, Predicted=3935.7275, Expected=3869.8593
# Month=37, Predicted=3862.7401, Expected=3851.2471
# Month=38, Predicted=3851.2163, Expected=3836.7683
# Month=39, Predicted=3829.6815, Expected=3832.0688
# Month=40, Predicted=3830.3514, Expected=3849.7587
# Month=41, Predicted=3850.9259, Expected=3862.2441
# Month=42, Predicted=3864.9970, Expected=3878.6123
# Month=43, Predicted=3880.8203, Expected=3855.0054
# Month=44, Predicted=3855.8886, Expected=3842.4833
# Month=45, Predicted=3843.0265, Expected=3847.2433
# Month=46, Predicted=3846.5040, Expected=3801.1048
# Month=47, Predicted=3797.7087, Expected=3786.6840
# Month=48, Predicted=3787.0574, Expected=3776.0367
# Month=49, Predicted=3772.8017, Expected=3796.7972
# Month=50, Predicted=3797.7095, Expected=3821.0598
# Month=51, Predicted=3824.5414, Expected=3877.3486
# Month=52, Predicted=3881.0512, Expected=3875.8349
# Month=53, Predicted=3880.2505, Expected=3889.3484
# Month=54, Predicted=3888.9886, Expected=3911.1229
# Month=55, Predicted=3911.7038, Expected=3922.9724
# Month=56, Predicted=3923.4685, Expected=3917.9201
# Month=57, Predicted=3917.5492, Expected=3936.3097
# Month=58, Predicted=3936.1612, Expected=3911.1479
# Month=59, Predicted=3908.8551, Expected=3890.6722
# Month=60, Predicted=3889.7667, Expected=3854.8904
# Run 2 — RMSE: 24.100776, MSE: 580.847392, NMSE: 0.0026445856
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3799.8567, Expected=3796.1139
# Month=2, Predicted=3797.3624, Expected=3793.0240
# Month=3, Predicted=3794.2897, Expected=3765.6570
# Month=4, Predicted=3765.9807, Expected=3748.1286
# Month=5, Predicted=3748.8966, Expected=3754.3337
# Month=6, Predicted=3753.9167, Expected=3754.9339
# Month=7, Predicted=3754.2976, Expected=3767.0982
# Month=8, Predicted=3767.1404, Expected=3750.6516
# Month=9, Predicted=3750.1049, Expected=3769.4487
# Month=10, Predicted=3770.2668, Expected=3759.5828
# Month=11, Predicted=3759.5871, Expected=3784.9396
# Month=12, Predicted=3786.1055, Expected=3776.2658
# Month=13, Predicted=3776.6739, Expected=3755.4558
# Month=14, Predicted=3756.0484, Expected=3754.3681
# Month=15, Predicted=3754.8140, Expected=3750.8239
# Month=16, Predicted=3750.4820, Expected=3775.7500
# Month=17, Predicted=3776.2586, Expected=3846.6561
# Month=18, Predicted=3849.7106, Expected=3830.9294
# Month=19, Predicted=3834.5281, Expected=3881.2132
# Month=20, Predicted=3884.0011, Expected=3898.3362
# Month=21, Predicted=3902.7374, Expected=3917.4832
# Month=22, Predicted=3919.0137, Expected=3914.1172
# Month=23, Predicted=3914.6461, Expected=3901.5435
# Month=24, Predicted=3902.1493, Expected=3885.2002
# Month=25, Predicted=3885.5642, Expected=3892.2451
# Month=26, Predicted=3892.3855, Expected=3899.6669
# Month=27, Predicted=3899.5199, Expected=3885.6275
# Month=28, Predicted=3885.0503, Expected=3908.2336
# Month=29, Predicted=3908.8468, Expected=3875.4078
# Month=30, Predicted=3874.0539, Expected=3859.5120
# Month=31, Predicted=3860.5788, Expected=3879.9687
# Month=32, Predicted=3879.7869, Expected=3893.2937
# Month=33, Predicted=3893.7798, Expected=3953.4607
# Month=34, Predicted=3955.7242, Expected=3932.8670
# Month=35, Predicted=3934.9286, Expected=3936.3431
# Month=36, Predicted=3939.0213, Expected=3869.8593
# Month=37, Predicted=3868.3990, Expected=3851.2471
# Month=38, Predicted=3855.2210, Expected=3836.7683
# Month=39, Predicted=3834.0810, Expected=3832.0688
# Month=40, Predicted=3829.4827, Expected=3849.7587
# Month=41, Predicted=3848.5472, Expected=3862.2441
# Month=42, Predicted=3862.3222, Expected=3878.6123
# Month=43, Predicted=3879.5278, Expected=3855.0054
# Month=44, Predicted=3854.9749, Expected=3842.4833
# Month=45, Predicted=3843.7685, Expected=3847.2433
# Month=46, Predicted=3847.4843, Expected=3801.1048
# Month=47, Predicted=3798.9567, Expected=3786.6840
# Month=48, Predicted=3787.6661, Expected=3776.0367
# Month=49, Predicted=3773.8824, Expected=3796.7972
# Month=50, Predicted=3795.7135, Expected=3821.0598
# Month=51, Predicted=3821.8407, Expected=3877.3486
# Month=52, Predicted=3880.1383, Expected=3875.8349
# Month=53, Predicted=3879.2311, Expected=3889.3484
# Month=54, Predicted=3891.3640, Expected=3911.1229
# Month=55, Predicted=3912.6174, Expected=3922.9724
# Month=56, Predicted=3924.0446, Expected=3917.9201
# Month=57, Predicted=3918.4498, Expected=3936.3097
# Month=58, Predicted=3937.2638, Expected=3911.1479
# Month=59, Predicted=3910.6500, Expected=3890.6722
# Month=60, Predicted=3891.7103, Expected=3854.8904
# Run 3 — RMSE: 24.604333, MSE: 605.373217, NMSE: 0.0027332594
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3797.4850, Expected=3796.1139
# Month=2, Predicted=3795.9832, Expected=3793.0240
# Month=3, Predicted=3792.8928, Expected=3765.6570
# Month=4, Predicted=3765.5257, Expected=3748.1286
# Month=5, Predicted=3747.9972, Expected=3754.3337
# Month=6, Predicted=3754.2024, Expected=3754.9339
# Month=7, Predicted=3754.8029, Expected=3767.0982
# Month=8, Predicted=3766.9671, Expected=3750.6516
# Month=9, Predicted=3750.5206, Expected=3769.4487
# Month=10, Predicted=3769.3175, Expected=3759.5828
# Month=11, Predicted=3759.4519, Expected=3784.9396
# Month=12, Predicted=3784.8084, Expected=3776.2658
# Month=13, Predicted=3776.1350, Expected=3755.4558
# Month=14, Predicted=3755.3245, Expected=3754.3681
# Month=15, Predicted=3754.2368, Expected=3750.8239
# Month=16, Predicted=3750.6928, Expected=3775.7500
# Month=17, Predicted=3775.6189, Expected=3846.6561
# Month=18, Predicted=3846.5257, Expected=3830.9294
# Month=19, Predicted=3830.7993, Expected=3881.2132
# Month=20, Predicted=3881.0820, Expected=3898.3362
# Month=21, Predicted=3898.2060, Expected=3917.4832
# Month=22, Predicted=3917.3524, Expected=3914.1172
# Month=23, Predicted=3913.9863, Expected=3901.5435
# Month=24, Predicted=3901.4123, Expected=3885.2002
# Month=25, Predicted=3885.0689, Expected=3892.2451
# Month=26, Predicted=3892.1138, Expected=3899.6669
# Month=27, Predicted=3899.5360, Expected=3885.6275
# Month=28, Predicted=3885.4964, Expected=3908.2336
# Month=29, Predicted=3908.1024, Expected=3875.4078
# Month=30, Predicted=3875.2768, Expected=3859.5120
# Month=31, Predicted=3859.3806, Expected=3879.9687
# Month=32, Predicted=3879.8374, Expected=3893.2937
# Month=33, Predicted=3893.1629, Expected=3953.4607
# Month=34, Predicted=3953.3301, Expected=3932.8670
# Month=35, Predicted=3932.7367, Expected=3936.3431
# Month=36, Predicted=3936.2118, Expected=3869.8593
# Month=37, Predicted=3869.7280, Expected=3851.2471
# Month=38, Predicted=3851.1154, Expected=3836.7683
# Month=39, Predicted=3836.6370, Expected=3832.0688
# Month=40, Predicted=3831.9376, Expected=3849.7587
# Month=41, Predicted=3849.6277, Expected=3862.2441
# Month=42, Predicted=3862.1133, Expected=3878.6123
# Month=43, Predicted=3878.4815, Expected=3855.0054
# Month=44, Predicted=3854.8744, Expected=3842.4833
# Month=45, Predicted=3842.3519, Expected=3847.2433
# Month=46, Predicted=3847.1121, Expected=3801.1048
# Month=47, Predicted=3800.9736, Expected=3786.6840
# Month=48, Predicted=3786.5525, Expected=3776.0367
# Month=49, Predicted=3775.9055, Expected=3796.7972
# Month=50, Predicted=3796.6660, Expected=3821.0598
# Month=51, Predicted=3820.9291, Expected=3877.3486
# Month=52, Predicted=3877.2182, Expected=3875.8349
# Month=53, Predicted=3875.7048, Expected=3889.3484
# Month=54, Predicted=3889.2174, Expected=3911.1229
# Month=55, Predicted=3910.9921, Expected=3922.9724
# Month=56, Predicted=3922.8417, Expected=3917.9201
# Month=57, Predicted=3917.7892, Expected=3936.3097
# Month=58, Predicted=3936.1787, Expected=3911.1479
# Month=59, Predicted=3911.0170, Expected=3890.6722
# Month=60, Predicted=3890.5408, Expected=3854.8904
# Run 4 — RMSE: 24.521751, MSE: 601.316282, NMSE: 0.0027561306
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3803.0471, Expected=3796.1139
# Month=2, Predicted=3794.2969, Expected=3793.0240
# Month=3, Predicted=3793.4138, Expected=3765.6570
# Month=4, Predicted=3763.8642, Expected=3748.1286
# Month=5, Predicted=3745.8723, Expected=3754.3337
# Month=6, Predicted=3747.3950, Expected=3754.9339
# Month=7, Predicted=3752.6535, Expected=3767.0982
# Month=8, Predicted=3768.3791, Expected=3750.6516
# Month=9, Predicted=3751.3644, Expected=3769.4487
# Month=10, Predicted=3773.3659, Expected=3759.5828
# Month=11, Predicted=3760.1035, Expected=3784.9396
# Month=12, Predicted=3786.9845, Expected=3776.2658
# Month=13, Predicted=3776.7070, Expected=3755.4558
# Month=14, Predicted=3756.8740, Expected=3754.3681
# Month=15, Predicted=3754.7280, Expected=3750.8239
# Month=16, Predicted=3748.4232, Expected=3775.7500
# Month=17, Predicted=3777.1911, Expected=3846.6561
# Month=18, Predicted=3858.4209, Expected=3830.9294
# Month=19, Predicted=3831.6747, Expected=3881.2132
# Month=20, Predicted=3882.4408, Expected=3898.3362
# Month=21, Predicted=3902.6046, Expected=3917.4832
# Month=22, Predicted=3913.7362, Expected=3914.1172
# Month=23, Predicted=3910.6562, Expected=3901.5435
# Month=24, Predicted=3898.8276, Expected=3885.2002
# Month=25, Predicted=3880.9785, Expected=3892.2451
# Month=26, Predicted=3887.1819, Expected=3899.6669
# Month=27, Predicted=3898.1583, Expected=3885.6275
# Month=28, Predicted=3884.1689, Expected=3908.2336
# Month=29, Predicted=3910.6517, Expected=3875.4078
# Month=30, Predicted=3873.3201, Expected=3859.5120
# Month=31, Predicted=3864.9835, Expected=3879.9687
# Month=32, Predicted=3878.1555, Expected=3893.2937
# Month=33, Predicted=3897.2673, Expected=3953.4607
# Month=34, Predicted=3959.5933, Expected=3932.8670
# Month=35, Predicted=3932.7852, Expected=3936.3431
# Month=36, Predicted=3942.5760, Expected=3869.8593
# Month=37, Predicted=3864.7474, Expected=3851.2471
# Month=38, Predicted=3852.3162, Expected=3836.7683
# Month=39, Predicted=3816.4598, Expected=3832.0688
# Month=40, Predicted=3823.5005, Expected=3849.7587
# Month=41, Predicted=3851.8701, Expected=3862.2441
# Month=42, Predicted=3867.5651, Expected=3878.6123
# Month=43, Predicted=3881.8618, Expected=3855.0054
# Month=44, Predicted=3855.2142, Expected=3842.4833
# Month=45, Predicted=3847.4637, Expected=3847.2433
# Month=46, Predicted=3844.5011, Expected=3801.1048
# Month=47, Predicted=3793.8371, Expected=3786.6840
# Month=48, Predicted=3787.7823, Expected=3776.0367
# Month=49, Predicted=3766.9122, Expected=3796.7972
# Month=50, Predicted=3797.0189, Expected=3821.0598
# Month=51, Predicted=3828.1111, Expected=3877.3486
# Month=52, Predicted=3883.9115, Expected=3875.8349
# Month=53, Predicted=3875.5688, Expected=3889.3484
# Month=54, Predicted=3889.0170, Expected=3911.1229
# Month=55, Predicted=3910.3405, Expected=3922.9724
# Month=56, Predicted=3920.9384, Expected=3917.9201
# Month=57, Predicted=3914.3873, Expected=3936.3097
# Month=58, Predicted=3934.4959, Expected=3911.1479
# Month=59, Predicted=3906.6815, Expected=3890.6722
# Month=60, Predicted=3890.4240, Expected=3854.8904
# Run 5 — RMSE: 24.812211, MSE: 615.645806, NMSE: 0.0027736328
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3802.5570, Expected=3796.1139
# Month=2, Predicted=3795.1085, Expected=3793.0240
# Month=3, Predicted=3793.6835, Expected=3765.6570
# Month=4, Predicted=3765.0724, Expected=3748.1286
# Month=5, Predicted=3748.5976, Expected=3754.3337
# Month=6, Predicted=3750.5139, Expected=3754.9339
# Month=7, Predicted=3753.5024, Expected=3767.0982
# Month=8, Predicted=3767.7019, Expected=3750.6516
# Month=9, Predicted=3749.8848, Expected=3769.4487
# Month=10, Predicted=3771.0285, Expected=3759.5828
# Month=11, Predicted=3758.8767, Expected=3784.9396
# Month=12, Predicted=3785.8817, Expected=3776.2658
# Month=13, Predicted=3775.9102, Expected=3755.4558
# Month=14, Predicted=3756.2286, Expected=3754.3681
# Month=15, Predicted=3754.3982, Expected=3750.8239
# Month=16, Predicted=3748.6050, Expected=3775.7500
# Month=17, Predicted=3776.5535, Expected=3846.6561
# Month=18, Predicted=3857.0157, Expected=3830.9294
# Month=19, Predicted=3831.6914, Expected=3881.2132
# Month=20, Predicted=3882.0919, Expected=3898.3362
# Month=21, Predicted=3903.9508, Expected=3917.4832
# Month=22, Predicted=3916.9768, Expected=3914.1172
# Month=23, Predicted=3913.3085, Expected=3901.5435
# Month=24, Predicted=3901.7475, Expected=3885.2002
# Month=25, Predicted=3884.4741, Expected=3892.2451
# Month=26, Predicted=3890.5084, Expected=3899.6669
# Month=27, Predicted=3898.9717, Expected=3885.6275
# Month=28, Predicted=3884.3259, Expected=3908.2336
# Month=29, Predicted=3909.2449, Expected=3875.4078
# Month=30, Predicted=3871.6136, Expected=3859.5120
# Month=31, Predicted=3863.1127, Expected=3879.9687
# Month=32, Predicted=3877.9053, Expected=3893.2937
# Month=33, Predicted=3896.2218, Expected=3953.4607
# Month=34, Predicted=3957.9569, Expected=3932.8670
# Month=35, Predicted=3932.3202, Expected=3936.3431
# Month=36, Predicted=3940.3673, Expected=3869.8593
# Month=37, Predicted=3864.6633, Expected=3851.2471
# Month=38, Predicted=3856.2953, Expected=3836.7683
# Month=39, Predicted=3823.3213, Expected=3832.0688
# Month=40, Predicted=3827.4957, Expected=3849.7587
# Month=41, Predicted=3851.2036, Expected=3862.2441
# Month=42, Predicted=3866.2373, Expected=3878.6123
# Month=43, Predicted=3880.7959, Expected=3855.0054
# Month=44, Predicted=3854.3402, Expected=3842.4833
# Month=45, Predicted=3845.7139, Expected=3847.2433
# Month=46, Predicted=3845.6405, Expected=3801.1048
# Month=47, Predicted=3795.2752, Expected=3786.6840
# Month=48, Predicted=3788.8300, Expected=3776.0367
# Month=49, Predicted=3768.4905, Expected=3796.7972
# Month=50, Predicted=3796.4672, Expected=3821.0598
# Month=51, Predicted=3826.5626, Expected=3877.3486
# Month=52, Predicted=3883.2503, Expected=3875.8349
# Month=53, Predicted=3877.4831, Expected=3889.3484
# Month=54, Predicted=3890.3520, Expected=3911.1229
# Month=55, Predicted=3912.8420, Expected=3922.9724
# Month=56, Predicted=3923.3032, Expected=3917.9201
# Month=57, Predicted=3916.8005, Expected=3936.3097
# Month=58, Predicted=3936.7135, Expected=3911.1479
# Month=59, Predicted=3908.0283, Expected=3890.6722
# Month=60, Predicted=3892.4515, Expected=3854.8904
# Run 6 — RMSE: 24.679789, MSE: 609.091992, NMSE: 0.0027278748
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3803.3739, Expected=3796.1139
# Month=2, Predicted=3796.9790, Expected=3793.0240
# Month=3, Predicted=3794.4037, Expected=3765.6570
# Month=4, Predicted=3763.0835, Expected=3748.1286
# Month=5, Predicted=3746.1419, Expected=3754.3337
# Month=6, Predicted=3748.8055, Expected=3754.9339
# Month=7, Predicted=3751.9988, Expected=3767.0982
# Month=8, Predicted=3767.3253, Expected=3750.6516
# Month=9, Predicted=3751.5852, Expected=3769.4487
# Month=10, Predicted=3772.5562, Expected=3759.5828
# Month=11, Predicted=3759.2673, Expected=3784.9396
# Month=12, Predicted=3786.2293, Expected=3776.2658
# Month=13, Predicted=3775.9341, Expected=3755.4558
# Month=14, Predicted=3756.0740, Expected=3754.3681
# Month=15, Predicted=3754.0379, Expected=3750.8239
# Month=16, Predicted=3747.3790, Expected=3775.7500
# Month=17, Predicted=3775.8332, Expected=3846.6561
# Month=18, Predicted=3856.8878, Expected=3830.9294
# Month=19, Predicted=3835.8348, Expected=3881.2132
# Month=20, Predicted=3883.2946, Expected=3898.3362
# Month=21, Predicted=3901.5405, Expected=3917.4832
# Month=22, Predicted=3916.0893, Expected=3914.1172
# Month=23, Predicted=3911.9147, Expected=3901.5435
# Month=24, Predicted=3900.1088, Expected=3885.2002
# Month=25, Predicted=3882.2616, Expected=3892.2451
# Month=26, Predicted=3889.0303, Expected=3899.6669
# Month=27, Predicted=3898.1653, Expected=3885.6275
# Month=28, Predicted=3884.5603, Expected=3908.2336
# Month=29, Predicted=3910.2950, Expected=3875.4078
# Month=30, Predicted=3872.5841, Expected=3859.5120
# Month=31, Predicted=3863.2665, Expected=3879.9687
# Month=32, Predicted=3878.0616, Expected=3893.2937
# Month=33, Predicted=3894.8159, Expected=3953.4607
# Month=34, Predicted=3957.7680, Expected=3932.8670
# Month=35, Predicted=3935.8040, Expected=3936.3431
# Month=36, Predicted=3941.9526, Expected=3869.8593
# Month=37, Predicted=3860.5340, Expected=3851.2471
# Month=38, Predicted=3852.8112, Expected=3836.7683
# Month=39, Predicted=3821.6112, Expected=3832.0688
# Month=40, Predicted=3823.3114, Expected=3849.7587
# Month=41, Predicted=3849.7803, Expected=3862.2441
# Month=42, Predicted=3867.6669, Expected=3878.6123
# Month=43, Predicted=3883.0929, Expected=3855.0054
# Month=44, Predicted=3857.0793, Expected=3842.4833
# Month=45, Predicted=3846.9746, Expected=3847.2433
# Month=46, Predicted=3844.7789, Expected=3801.1048
# Month=47, Predicted=3792.6747, Expected=3786.6840
# Month=48, Predicted=3787.2021, Expected=3776.0367
# Month=49, Predicted=3768.6462, Expected=3796.7972
# Month=50, Predicted=3794.5715, Expected=3821.0598
# Month=51, Predicted=3826.5597, Expected=3877.3486
# Month=52, Predicted=3884.0133, Expected=3875.8349
# Month=53, Predicted=3880.6899, Expected=3889.3484
# Month=54, Predicted=3891.5647, Expected=3911.1229
# Month=55, Predicted=3911.2538, Expected=3922.9724
# Month=56, Predicted=3922.1384, Expected=3917.9201
# Month=57, Predicted=3916.0854, Expected=3936.3097
# Month=58, Predicted=3935.9314, Expected=3911.1479
# Month=59, Predicted=3906.5826, Expected=3890.6722
# Month=60, Predicted=3891.3456, Expected=3854.8904
# Run 7 — RMSE: 24.737905, MSE: 611.963955, NMSE: 0.0027270630
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3802.3253, Expected=3796.1139
# Month=2, Predicted=3796.2428, Expected=3793.0240
# Month=3, Predicted=3793.9037, Expected=3765.6570
# Month=4, Predicted=3763.6547, Expected=3748.1286
# Month=5, Predicted=3746.8098, Expected=3754.3337
# Month=6, Predicted=3749.6845, Expected=3754.9339
# Month=7, Predicted=3752.6644, Expected=3767.0982
# Month=8, Predicted=3767.3700, Expected=3750.6516
# Month=9, Predicted=3750.0186, Expected=3769.4487
# Month=10, Predicted=3770.7912, Expected=3759.5828
# Month=11, Predicted=3758.5745, Expected=3784.9396
# Month=12, Predicted=3785.9085, Expected=3776.2658
# Month=13, Predicted=3775.6854, Expected=3755.4558
# Month=14, Predicted=3755.9812, Expected=3754.3681
# Month=15, Predicted=3753.4558, Expected=3750.8239
# Month=16, Predicted=3747.9612, Expected=3775.7500
# Month=17, Predicted=3776.0042, Expected=3846.6561
# Month=18, Predicted=3856.0817, Expected=3830.9294
# Month=19, Predicted=3832.1669, Expected=3881.2132
# Month=20, Predicted=3884.5473, Expected=3898.3362
# Month=21, Predicted=3901.8588, Expected=3917.4832
# Month=22, Predicted=3916.7575, Expected=3914.1172
# Month=23, Predicted=3912.0251, Expected=3901.5435
# Month=24, Predicted=3899.9457, Expected=3885.2002
# Month=25, Predicted=3882.2267, Expected=3892.2451
# Month=26, Predicted=3888.6020, Expected=3899.6669
# Month=27, Predicted=3897.4509, Expected=3885.6275
# Month=28, Predicted=3883.8120, Expected=3908.2336
# Month=29, Predicted=3908.7344, Expected=3875.4078
# Month=30, Predicted=3871.9388, Expected=3859.5120
# Month=31, Predicted=3861.9480, Expected=3879.9687
# Month=32, Predicted=3877.3667, Expected=3893.2937
# Month=33, Predicted=3895.3961, Expected=3953.4607
# Month=34, Predicted=3959.2412, Expected=3932.8670
# Month=35, Predicted=3933.4023, Expected=3936.3431
# Month=36, Predicted=3941.4224, Expected=3869.8593
# Month=37, Predicted=3864.7758, Expected=3851.2471
# Month=38, Predicted=3854.4998, Expected=3836.7683
# Month=39, Predicted=3826.0385, Expected=3832.0688
# Month=40, Predicted=3827.9341, Expected=3849.7587
# Month=41, Predicted=3851.3630, Expected=3862.2441
# Month=42, Predicted=3866.5924, Expected=3878.6123
# Month=43, Predicted=3882.3225, Expected=3855.0054
# Month=44, Predicted=3855.6600, Expected=3842.4833
# Month=45, Predicted=3845.3755, Expected=3847.2433
# Month=46, Predicted=3845.2722, Expected=3801.1048
# Month=47, Predicted=3796.2493, Expected=3786.6840
# Month=48, Predicted=3788.2599, Expected=3776.0367
# Month=49, Predicted=3769.6411, Expected=3796.7972
# Month=50, Predicted=3796.1557, Expected=3821.0598
# Month=51, Predicted=3826.0310, Expected=3877.3486
# Month=52, Predicted=3884.6807, Expected=3875.8349
# Month=53, Predicted=3878.2779, Expected=3889.3484
# Month=54, Predicted=3891.6474, Expected=3911.1229
# Month=55, Predicted=3911.2945, Expected=3922.9724
# Month=56, Predicted=3922.0515, Expected=3917.9201
# Month=57, Predicted=3915.9109, Expected=3936.3097
# Month=58, Predicted=3934.9807, Expected=3911.1479
# Month=59, Predicted=3906.6939, Expected=3890.6722
# Month=60, Predicted=3890.4785, Expected=3854.8904
# Run 8 — RMSE: 24.684689, MSE: 609.333883, NMSE: 0.0027323760
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3800.7154, Expected=3796.1139
# Month=2, Predicted=3795.8229, Expected=3793.0240
# Month=3, Predicted=3793.2661, Expected=3765.6570
# Month=4, Predicted=3764.4923, Expected=3748.1286
# Month=5, Predicted=3747.4660, Expected=3754.3337
# Month=6, Predicted=3751.9937, Expected=3754.9339
# Month=7, Predicted=3753.4045, Expected=3767.0982
# Month=8, Predicted=3767.1582, Expected=3750.6516
# Month=9, Predicted=3749.6178, Expected=3769.4487
# Month=10, Predicted=3770.4619, Expected=3759.5828
# Month=11, Predicted=3758.9007, Expected=3784.9396
# Month=12, Predicted=3785.9922, Expected=3776.2658
# Month=13, Predicted=3775.9434, Expected=3755.4558
# Month=14, Predicted=3755.2572, Expected=3754.3681
# Month=15, Predicted=3754.0961, Expected=3750.8239
# Month=16, Predicted=3749.2749, Expected=3775.7500
# Month=17, Predicted=3776.2803, Expected=3846.6561
# Month=18, Predicted=3852.1917, Expected=3830.9294
# Month=19, Predicted=3832.5049, Expected=3881.2132
# Month=20, Predicted=3882.7349, Expected=3898.3362
# Month=21, Predicted=3901.4401, Expected=3917.4832
# Month=22, Predicted=3917.2120, Expected=3914.1172
# Month=23, Predicted=3913.1818, Expected=3901.5435
# Month=24, Predicted=3901.0084, Expected=3885.2002
# Month=25, Predicted=3884.0038, Expected=3892.2451
# Month=26, Predicted=3890.8485, Expected=3899.6669
# Month=27, Predicted=3898.5394, Expected=3885.6275
# Month=28, Predicted=3884.1243, Expected=3908.2336
# Month=29, Predicted=3908.8412, Expected=3875.4078
# Month=30, Predicted=3872.5199, Expected=3859.5120
# Month=31, Predicted=3860.5782, Expected=3879.9687
# Month=32, Predicted=3878.9245, Expected=3893.2937
# Month=33, Predicted=3894.2208, Expected=3953.4607
# Month=34, Predicted=3956.8592, Expected=3932.8670
# Month=35, Predicted=3933.2931, Expected=3936.3431
# Month=36, Predicted=3938.4943, Expected=3869.8593
# Month=37, Predicted=3865.2453, Expected=3851.2471
# Month=38, Predicted=3853.6615, Expected=3836.7683
# Month=39, Predicted=3829.8296, Expected=3832.0688
# Month=40, Predicted=3828.3966, Expected=3849.7587
# Month=41, Predicted=3849.5255, Expected=3862.2441
# Month=42, Predicted=3863.8843, Expected=3878.6123
# Month=43, Predicted=3880.2626, Expected=3855.0054
# Month=44, Predicted=3854.3844, Expected=3842.4833
# Month=45, Predicted=3843.7647, Expected=3847.2433
# Month=46, Predicted=3846.4686, Expected=3801.1048
# Month=47, Predicted=3796.7826, Expected=3786.6840
# Month=48, Predicted=3787.2553, Expected=3776.0367
# Month=49, Predicted=3772.0769, Expected=3796.7972
# Month=50, Predicted=3796.2442, Expected=3821.0598
# Month=51, Predicted=3823.6952, Expected=3877.3486
# Month=52, Predicted=3881.7415, Expected=3875.8349
# Month=53, Predicted=3877.7367, Expected=3889.3484
# Month=54, Predicted=3890.0004, Expected=3911.1229
# Month=55, Predicted=3912.1731, Expected=3922.9724
# Month=56, Predicted=3923.2883, Expected=3917.9201
# Month=57, Predicted=3917.0949, Expected=3936.3097
# Month=58, Predicted=3936.6270, Expected=3911.1479
# Month=59, Predicted=3908.7574, Expected=3890.6722
# Month=60, Predicted=3890.8844, Expected=3854.8904
# Run 9 — RMSE: 24.542192, MSE: 602.319186, NMSE: 0.0027177120
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3800.4794, Expected=3796.1139
# Month=2, Predicted=3796.2969, Expected=3793.0240
# Month=3, Predicted=3792.1343, Expected=3765.6570
# Month=4, Predicted=3762.3689, Expected=3748.1286
# Month=5, Predicted=3746.9755, Expected=3754.3337
# Month=6, Predicted=3751.9776, Expected=3754.9339
# Month=7, Predicted=3755.1907, Expected=3767.0982
# Month=8, Predicted=3768.5466, Expected=3750.6516
# Month=9, Predicted=3750.2169, Expected=3769.4487
# Month=10, Predicted=3770.3901, Expected=3759.5828
# Month=11, Predicted=3758.4339, Expected=3784.9396
# Month=12, Predicted=3786.1587, Expected=3776.2658
# Month=13, Predicted=3775.4351, Expected=3755.4558
# Month=14, Predicted=3755.4248, Expected=3754.3681
# Month=15, Predicted=3752.6772, Expected=3750.8239
# Month=16, Predicted=3749.4297, Expected=3775.7500
# Month=17, Predicted=3777.1093, Expected=3846.6561
# Month=18, Predicted=3850.8810, Expected=3830.9294
# Month=19, Predicted=3832.3656, Expected=3881.2132
# Month=20, Predicted=3881.5738, Expected=3898.3362
# Month=21, Predicted=3897.3635, Expected=3917.4832
# Month=22, Predicted=3916.2114, Expected=3914.1172
# Month=23, Predicted=3911.3482, Expected=3901.5435
# Month=24, Predicted=3899.5160, Expected=3885.2002
# Month=25, Predicted=3882.5179, Expected=3892.2451
# Month=26, Predicted=3890.6288, Expected=3899.6669
# Month=27, Predicted=3899.2773, Expected=3885.6275
# Month=28, Predicted=3885.4231, Expected=3908.2336
# Month=29, Predicted=3908.7722, Expected=3875.4078
# Month=30, Predicted=3872.6633, Expected=3859.5120
# Month=31, Predicted=3861.1310, Expected=3879.9687
# Month=32, Predicted=3877.6799, Expected=3893.2937
# Month=33, Predicted=3895.4941, Expected=3953.4607
# Month=34, Predicted=3956.9944, Expected=3932.8670
# Month=35, Predicted=3933.4283, Expected=3936.3431
# Month=36, Predicted=3937.3340, Expected=3869.8593
# Month=37, Predicted=3861.5293, Expected=3851.2471
# Month=38, Predicted=3855.1410, Expected=3836.7683
# Month=39, Predicted=3829.6146, Expected=3832.0688
# Month=40, Predicted=3832.7225, Expected=3849.7587
# Month=41, Predicted=3852.0343, Expected=3862.2441
# Month=42, Predicted=3865.5794, Expected=3878.6123
# Month=43, Predicted=3881.0013, Expected=3855.0054
# Month=44, Predicted=3854.2694, Expected=3842.4833
# Month=45, Predicted=3842.9218, Expected=3847.2433
# Month=46, Predicted=3844.9573, Expected=3801.1048
# Month=47, Predicted=3798.1094, Expected=3786.6840
# Month=48, Predicted=3788.5457, Expected=3776.0367
# Month=49, Predicted=3772.0908, Expected=3796.7972
# Month=50, Predicted=3798.7838, Expected=3821.0598
# Month=51, Predicted=3825.1291, Expected=3877.3486
# Month=52, Predicted=3881.9035, Expected=3875.8349
# Month=53, Predicted=3877.5266, Expected=3889.3484
# Month=54, Predicted=3889.2424, Expected=3911.1229
# Month=55, Predicted=3909.5160, Expected=3922.9724
# Month=56, Predicted=3922.4379, Expected=3917.9201
# Month=57, Predicted=3916.4951, Expected=3936.3097
# Month=58, Predicted=3935.3960, Expected=3911.1479
# Month=59, Predicted=3908.1495, Expected=3890.6722
# Month=60, Predicted=3890.8808, Expected=3854.8904
# Run 10 — RMSE: 24.171007, MSE: 584.237566, NMSE: 0.0026676547
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3802.5327, Expected=3796.1139
# Month=2, Predicted=3796.7099, Expected=3793.0240
# Month=3, Predicted=3792.8861, Expected=3765.6570
# Month=4, Predicted=3762.3395, Expected=3748.1286
# Month=5, Predicted=3745.8194, Expected=3754.3337
# Month=6, Predicted=3750.3288, Expected=3754.9339
# Month=7, Predicted=3753.2659, Expected=3767.0982
# Month=8, Predicted=3768.5261, Expected=3750.6516
# Month=9, Predicted=3751.0347, Expected=3769.4487
# Month=10, Predicted=3771.5126, Expected=3759.5828
# Month=11, Predicted=3759.1415, Expected=3784.9396
# Month=12, Predicted=3786.3581, Expected=3776.2658
# Month=13, Predicted=3775.5175, Expected=3755.4558
# Month=14, Predicted=3755.2029, Expected=3754.3681
# Month=15, Predicted=3753.0697, Expected=3750.8239
# Month=16, Predicted=3748.3171, Expected=3775.7500
# Month=17, Predicted=3776.3777, Expected=3846.6561
# Month=18, Predicted=3854.3088, Expected=3830.9294
# Month=19, Predicted=3832.7872, Expected=3881.2132
# Month=20, Predicted=3884.3375, Expected=3898.3362
# Month=21, Predicted=3898.6953, Expected=3917.4832
# Month=22, Predicted=3916.3933, Expected=3914.1172
# Month=23, Predicted=3910.6991, Expected=3901.5435
# Month=24, Predicted=3898.3126, Expected=3885.2002
# Month=25, Predicted=3881.6464, Expected=3892.2451
# Month=26, Predicted=3889.4698, Expected=3899.6669
# Month=27, Predicted=3898.7308, Expected=3885.6275
# Month=28, Predicted=3885.4812, Expected=3908.2336
# Month=29, Predicted=3910.4077, Expected=3875.4078
# Month=30, Predicted=3873.4644, Expected=3859.5120
# Month=31, Predicted=3862.7019, Expected=3879.9687
# Month=32, Predicted=3879.2575, Expected=3893.2937
# Month=33, Predicted=3895.5449, Expected=3953.4607
# Month=34, Predicted=3960.0105, Expected=3932.8670
# Month=35, Predicted=3933.7984, Expected=3936.3431
# Month=36, Predicted=3939.4518, Expected=3869.8593
# Month=37, Predicted=3863.8383, Expected=3851.2471
# Month=38, Predicted=3854.6878, Expected=3836.7683
# Month=39, Predicted=3828.4402, Expected=3832.0688
# Month=40, Predicted=3828.1732, Expected=3849.7587
# Month=41, Predicted=3851.2654, Expected=3862.2441
# Month=42, Predicted=3867.2371, Expected=3878.6123
# Month=43, Predicted=3883.2382, Expected=3855.0054
# Month=44, Predicted=3855.0790, Expected=3842.4833
# Month=45, Predicted=3843.1825, Expected=3847.2433
# Month=46, Predicted=3844.3817, Expected=3801.1048
# Month=47, Predicted=3794.8548, Expected=3786.6840
# Month=48, Predicted=3787.1413, Expected=3776.0367
# Month=49, Predicted=3771.2522, Expected=3796.7972
# Month=50, Predicted=3796.8312, Expected=3821.0598
# Month=51, Predicted=3826.6066, Expected=3877.3486
# Month=52, Predicted=3886.0022, Expected=3875.8349
# Month=53, Predicted=3879.3041, Expected=3889.3484
# Month=54, Predicted=3890.3641, Expected=3911.1229
# Month=55, Predicted=3909.3269, Expected=3922.9724
# Month=56, Predicted=3920.2249, Expected=3917.9201
# Month=57, Predicted=3914.3772, Expected=3936.3097
# Month=58, Predicted=3934.3821, Expected=3911.1479
# Month=59, Predicted=3906.4460, Expected=3890.6722
# Month=60, Predicted=3890.4870, Expected=3854.8904
# Run 11 — RMSE: 24.438921, MSE: 597.260880, NMSE: 0.0026951893
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3802.6356, Expected=3796.1139
# Month=2, Predicted=3798.4341, Expected=3793.0240
# Month=3, Predicted=3793.3717, Expected=3765.6570
# Month=4, Predicted=3762.7315, Expected=3748.1286
# Month=5, Predicted=3745.2266, Expected=3754.3337
# Month=6, Predicted=3751.8312, Expected=3754.9339
# Month=7, Predicted=3754.7642, Expected=3767.0982
# Month=8, Predicted=3769.1947, Expected=3750.6516
# Month=9, Predicted=3752.0169, Expected=3769.4487
# Month=10, Predicted=3771.7421, Expected=3759.5828
# Month=11, Predicted=3759.9618, Expected=3784.9396
# Month=12, Predicted=3786.3217, Expected=3776.2658
# Month=13, Predicted=3776.6194, Expected=3755.4558
# Month=14, Predicted=3755.0808, Expected=3754.3681
# Month=15, Predicted=3753.2994, Expected=3750.8239
# Month=16, Predicted=3749.3317, Expected=3775.7500
# Month=17, Predicted=3776.7799, Expected=3846.6561
# Month=18, Predicted=3853.6450, Expected=3830.9294
# Month=19, Predicted=3835.3852, Expected=3881.2132
# Month=20, Predicted=3883.8824, Expected=3898.3362
# Month=21, Predicted=3901.6190, Expected=3917.4832
# Month=22, Predicted=3917.0674, Expected=3914.1172
# Month=23, Predicted=3912.1227, Expected=3901.5435
# Month=24, Predicted=3898.5317, Expected=3885.2002
# Month=25, Predicted=3882.0730, Expected=3892.2451
# Month=26, Predicted=3890.7353, Expected=3899.6669
# Month=27, Predicted=3900.3791, Expected=3885.6275
# Month=28, Predicted=3887.0162, Expected=3908.2336
# Month=29, Predicted=3911.3429, Expected=3875.4078
# Month=30, Predicted=3875.1250, Expected=3859.5120
# Month=31, Predicted=3861.5573, Expected=3879.9687
# Month=32, Predicted=3879.6915, Expected=3893.2937
# Month=33, Predicted=3895.1131, Expected=3953.4607
# Month=34, Predicted=3958.4819, Expected=3932.8670
# Month=35, Predicted=3935.5255, Expected=3936.3431
# Month=36, Predicted=3937.7835, Expected=3869.8593
# Month=37, Predicted=3862.7384, Expected=3851.2471
# Month=38, Predicted=3849.3821, Expected=3836.7683
# Month=39, Predicted=3830.3732, Expected=3832.0688
# Month=40, Predicted=3830.0839, Expected=3849.7587
# Month=41, Predicted=3851.5283, Expected=3862.2441
# Month=42, Predicted=3865.7462, Expected=3878.6123
# Month=43, Predicted=3882.0894, Expected=3855.0054
# Month=44, Predicted=3855.3119, Expected=3842.4833
# Month=45, Predicted=3842.0252, Expected=3847.2433
# Month=46, Predicted=3844.4876, Expected=3801.1048
# Month=47, Predicted=3796.2376, Expected=3786.6840
# Month=48, Predicted=3786.2305, Expected=3776.0367
# Month=49, Predicted=3772.9831, Expected=3796.7972
# Month=50, Predicted=3796.9845, Expected=3821.0598
# Month=51, Predicted=3824.4524, Expected=3877.3486
# Month=52, Predicted=3883.3987, Expected=3875.8349
# Month=53, Predicted=3880.0802, Expected=3889.3484
# Month=54, Predicted=3890.1551, Expected=3911.1229
# Month=55, Predicted=3910.3764, Expected=3922.9724
# Month=56, Predicted=3921.9121, Expected=3917.9201
# Month=57, Predicted=3915.7883, Expected=3936.3097
# Month=58, Predicted=3935.1653, Expected=3911.1479
# Month=59, Predicted=3908.7248, Expected=3890.6722
# Month=60, Predicted=3890.1513, Expected=3854.8904
# Run 12 — RMSE: 24.168547, MSE: 584.118646, NMSE: 0.0026431503
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3801.1732, Expected=3796.1139
# Month=2, Predicted=3797.8917, Expected=3793.0240
# Month=3, Predicted=3794.0222, Expected=3765.6570
# Month=4, Predicted=3764.9254, Expected=3748.1286
# Month=5, Predicted=3748.3662, Expected=3754.3337
# Month=6, Predicted=3750.0992, Expected=3754.9339
# Month=7, Predicted=3752.0040, Expected=3767.0982
# Month=8, Predicted=3766.7762, Expected=3750.6516
# Month=9, Predicted=3750.2295, Expected=3769.4487
# Month=10, Predicted=3770.0176, Expected=3759.5828
# Month=11, Predicted=3758.8243, Expected=3784.9396
# Month=12, Predicted=3784.9070, Expected=3776.2658
# Month=13, Predicted=3776.5866, Expected=3755.4558
# Month=14, Predicted=3755.3783, Expected=3754.3681
# Month=15, Predicted=3754.3045, Expected=3750.8239
# Month=16, Predicted=3748.6135, Expected=3775.7500
# Month=17, Predicted=3775.8067, Expected=3846.6561
# Month=18, Predicted=3852.1983, Expected=3830.9294
# Month=19, Predicted=3836.0314, Expected=3881.2132
# Month=20, Predicted=3876.4837, Expected=3898.3362
# Month=21, Predicted=3903.3918, Expected=3917.4832
# Month=22, Predicted=3916.2657, Expected=3914.1172
# Month=23, Predicted=3915.0122, Expected=3901.5435
# Month=24, Predicted=3902.5090, Expected=3885.2002
# Month=25, Predicted=3884.6942, Expected=3892.2451
# Month=26, Predicted=3890.6803, Expected=3899.6669
# Month=27, Predicted=3897.3809, Expected=3885.6275
# Month=28, Predicted=3883.9577, Expected=3908.2336
# Month=29, Predicted=3908.3782, Expected=3875.4078
# Month=30, Predicted=3871.1443, Expected=3859.5120
# Month=31, Predicted=3859.9594, Expected=3879.9687
# Month=32, Predicted=3877.3793, Expected=3893.2937
# Month=33, Predicted=3894.1715, Expected=3953.4607
# Month=34, Predicted=3955.5182, Expected=3932.8670
# Month=35, Predicted=3937.2553, Expected=3936.3431
# Month=36, Predicted=3934.0229, Expected=3869.8593
# Month=37, Predicted=3864.5607, Expected=3851.2471
# Month=38, Predicted=3855.7042, Expected=3836.7683
# Month=39, Predicted=3828.4665, Expected=3832.0688
# Month=40, Predicted=3829.7423, Expected=3849.7587
# Month=41, Predicted=3850.7191, Expected=3862.2441
# Month=42, Predicted=3865.6557, Expected=3878.6123
# Month=43, Predicted=3880.7406, Expected=3855.0054
# Month=44, Predicted=3856.8875, Expected=3842.4833
# Month=45, Predicted=3844.1019, Expected=3847.2433
# Month=46, Predicted=3846.3686, Expected=3801.1048
# Month=47, Predicted=3797.6331, Expected=3786.6840
# Month=48, Predicted=3787.6225, Expected=3776.0367
# Month=49, Predicted=3770.9442, Expected=3796.7972
# Month=50, Predicted=3796.7386, Expected=3821.0598
# Month=51, Predicted=3825.7965, Expected=3877.3486
# Month=52, Predicted=3880.9418, Expected=3875.8349
# Month=53, Predicted=3882.7941, Expected=3889.3484
# Month=54, Predicted=3886.4307, Expected=3911.1229
# Month=55, Predicted=3913.4856, Expected=3922.9724
# Month=56, Predicted=3924.3470, Expected=3917.9201
# Month=57, Predicted=3918.5203, Expected=3936.3097
# Month=58, Predicted=3937.5572, Expected=3911.1479
# Month=59, Predicted=3908.5127, Expected=3890.6722
# Month=60, Predicted=3891.9792, Expected=3854.8904
# Run 13 — RMSE: 24.339374, MSE: 592.405150, NMSE: 0.0026686745
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3800.2515, Expected=3796.1139
# Month=2, Predicted=3797.1170, Expected=3793.0240
# Month=3, Predicted=3794.6690, Expected=3765.6570
# Month=4, Predicted=3764.4323, Expected=3748.1286
# Month=5, Predicted=3745.8556, Expected=3754.3337
# Month=6, Predicted=3748.8015, Expected=3754.9339
# Month=7, Predicted=3751.1757, Expected=3767.0982
# Month=8, Predicted=3767.2365, Expected=3750.6516
# Month=9, Predicted=3752.3107, Expected=3769.4487
# Month=10, Predicted=3773.0430, Expected=3759.5828
# Month=11, Predicted=3760.2113, Expected=3784.9396
# Month=12, Predicted=3786.9181, Expected=3776.2658
# Month=13, Predicted=3776.0515, Expected=3755.4558
# Month=14, Predicted=3756.3633, Expected=3754.3681
# Month=15, Predicted=3753.9636, Expected=3750.8239
# Month=16, Predicted=3748.2801, Expected=3775.7500
# Month=17, Predicted=3775.3924, Expected=3846.6561
# Month=18, Predicted=3851.1688, Expected=3830.9294
# Month=19, Predicted=3833.0838, Expected=3881.2132
# Month=20, Predicted=3885.6653, Expected=3898.3362
# Month=21, Predicted=3899.0211, Expected=3917.4832
# Month=22, Predicted=3916.5328, Expected=3914.1172
# Month=23, Predicted=3912.0305, Expected=3901.5435
# Month=24, Predicted=3899.3335, Expected=3885.2002
# Month=25, Predicted=3881.5956, Expected=3892.2451
# Month=26, Predicted=3887.4034, Expected=3899.6669
# Month=27, Predicted=3895.9999, Expected=3885.6275
# Month=28, Predicted=3884.0717, Expected=3908.2336
# Month=29, Predicted=3909.4424, Expected=3875.4078
# Month=30, Predicted=3874.7067, Expected=3859.5120
# Month=31, Predicted=3862.0819, Expected=3879.9687
# Month=32, Predicted=3878.4569, Expected=3893.2937
# Month=33, Predicted=3893.6673, Expected=3953.4607
# Month=34, Predicted=3957.1588, Expected=3932.8670
# Month=35, Predicted=3934.3502, Expected=3936.3431
# Month=36, Predicted=3941.3217, Expected=3869.8593
# Month=37, Predicted=3866.8345, Expected=3851.2471
# Month=38, Predicted=3849.8396, Expected=3836.7683
# Month=39, Predicted=3824.9480, Expected=3832.0688
# Month=40, Predicted=3824.9477, Expected=3849.7587
# Month=41, Predicted=3850.5393, Expected=3862.2441
# Month=42, Predicted=3868.2222, Expected=3878.6123
# Month=43, Predicted=3885.0234, Expected=3855.0054
# Month=44, Predicted=3858.0551, Expected=3842.4833
# Month=45, Predicted=3846.0162, Expected=3847.2433
# Month=46, Predicted=3845.5519, Expected=3801.1048
# Month=47, Predicted=3796.3864, Expected=3786.6840
# Month=48, Predicted=3784.3364, Expected=3776.0367
# Month=49, Predicted=3769.8481, Expected=3796.7972
# Month=50, Predicted=3796.1253, Expected=3821.0598
# Month=51, Predicted=3826.2412, Expected=3877.3486
# Month=52, Predicted=3884.4422, Expected=3875.8349
# Month=53, Predicted=3879.4913, Expected=3889.3484
# Month=54, Predicted=3892.3588, Expected=3911.1229
# Month=55, Predicted=3910.3623, Expected=3922.9724
# Month=56, Predicted=3920.8372, Expected=3917.9201
# Month=57, Predicted=3915.0896, Expected=3936.3097
# Month=58, Predicted=3934.3774, Expected=3911.1479
# Month=59, Predicted=3907.4748, Expected=3890.6722
# Month=60, Predicted=3888.8481, Expected=3854.8904
# Run 14 — RMSE: 24.711333, MSE: 610.649981, NMSE: 0.0027531201
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3802.4785, Expected=3796.1139
# Month=2, Predicted=3796.9760, Expected=3793.0240
# Month=3, Predicted=3793.6323, Expected=3765.6570
# Month=4, Predicted=3762.7163, Expected=3748.1286
# Month=5, Predicted=3746.1710, Expected=3754.3337
# Month=6, Predicted=3749.6711, Expected=3754.9339
# Month=7, Predicted=3753.3080, Expected=3767.0982
# Month=8, Predicted=3768.1009, Expected=3750.6516
# Month=9, Predicted=3750.1058, Expected=3769.4487
# Month=10, Predicted=3770.8607, Expected=3759.5828
# Month=11, Predicted=3758.3007, Expected=3784.9396
# Month=12, Predicted=3786.3718, Expected=3776.2658
# Month=13, Predicted=3775.7717, Expected=3755.4558
# Month=14, Predicted=3756.2437, Expected=3754.3681
# Month=15, Predicted=3753.2148, Expected=3750.8239
# Month=16, Predicted=3748.0446, Expected=3775.7500
# Month=17, Predicted=3776.5294, Expected=3846.6561
# Month=18, Predicted=3854.3023, Expected=3830.9294
# Month=19, Predicted=3834.1128, Expected=3881.2132
# Month=20, Predicted=3885.0294, Expected=3898.3362
# Month=21, Predicted=3900.5742, Expected=3917.4832
# Month=22, Predicted=3917.5045, Expected=3914.1172
# Month=23, Predicted=3912.1265, Expected=3901.5435
# Month=24, Predicted=3899.6123, Expected=3885.2002
# Month=25, Predicted=3881.6156, Expected=3892.2451
# Month=26, Predicted=3888.3953, Expected=3899.6669
# Month=27, Predicted=3897.5584, Expected=3885.6275
# Month=28, Predicted=3884.3374, Expected=3908.2336
# Month=29, Predicted=3908.7974, Expected=3875.4078
# Month=30, Predicted=3871.7266, Expected=3859.5120
# Month=31, Predicted=3862.3708, Expected=3879.9687
# Month=32, Predicted=3876.9950, Expected=3893.2937
# Month=33, Predicted=3895.0131, Expected=3953.4607
# Month=34, Predicted=3958.7613, Expected=3932.8670
# Month=35, Predicted=3934.6276, Expected=3936.3431
# Month=36, Predicted=3941.1562, Expected=3869.8593
# Month=37, Predicted=3863.5587, Expected=3851.2471
# Month=38, Predicted=3854.7785, Expected=3836.7683
# Month=39, Predicted=3826.1800, Expected=3832.0688
# Month=40, Predicted=3828.7379, Expected=3849.7587
# Month=41, Predicted=3850.9073, Expected=3862.2441
# Month=42, Predicted=3865.4601, Expected=3878.6123
# Month=43, Predicted=3881.3973, Expected=3855.0054
# Month=44, Predicted=3854.6507, Expected=3842.4833
# Month=45, Predicted=3844.5209, Expected=3847.2433
# Month=46, Predicted=3844.5042, Expected=3801.1048
# Month=47, Predicted=3796.5402, Expected=3786.6840
# Month=48, Predicted=3789.5913, Expected=3776.0367
# Month=49, Predicted=3770.8631, Expected=3796.7972
# Month=50, Predicted=3797.3072, Expected=3821.0598
# Month=51, Predicted=3825.8432, Expected=3877.3486
# Month=52, Predicted=3884.0957, Expected=3875.8349
# Month=53, Predicted=3879.4324, Expected=3889.3484
# Month=54, Predicted=3891.4635, Expected=3911.1229
# Month=55, Predicted=3910.6696, Expected=3922.9724
# Month=56, Predicted=3922.5399, Expected=3917.9201
# Month=57, Predicted=3916.5653, Expected=3936.3097
# Month=58, Predicted=3935.4533, Expected=3911.1479
# Month=59, Predicted=3907.2418, Expected=3890.6722
# Month=60, Predicted=3891.1512, Expected=3854.8904
# Run 15 — RMSE: 24.508892, MSE: 600.685776, NMSE: 0.0027010748
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3803.9975, Expected=3796.1139
# Month=2, Predicted=3797.1503, Expected=3793.0240
# Month=3, Predicted=3794.1029, Expected=3765.6570
# Month=4, Predicted=3763.9569, Expected=3748.1286
# Month=5, Predicted=3746.5555, Expected=3754.3337
# Month=6, Predicted=3749.9910, Expected=3754.9339
# Month=7, Predicted=3754.2865, Expected=3767.0982
# Month=8, Predicted=3768.0969, Expected=3750.6516
# Month=9, Predicted=3749.8097, Expected=3769.4487
# Month=10, Predicted=3770.5635, Expected=3759.5828
# Month=11, Predicted=3759.0516, Expected=3784.9396
# Month=12, Predicted=3786.1012, Expected=3776.2658
# Month=13, Predicted=3776.5394, Expected=3755.4558
# Month=14, Predicted=3755.9278, Expected=3754.3681
# Month=15, Predicted=3753.0994, Expected=3750.8239
# Month=16, Predicted=3748.5420, Expected=3775.7500
# Month=17, Predicted=3776.8251, Expected=3846.6561
# Month=18, Predicted=3858.0925, Expected=3830.9294
# Month=19, Predicted=3835.3236, Expected=3881.2132
# ...
# Month=60, Predicted=3891.6642, Expected=3854.8904
# Run 25 — RMSE: 24.724214, MSE: 611.286751, NMSE: 0.0027221474
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3804.0479, Expected=3796.1139
# Month=2, Predicted=3799.4816, Expected=3793.0240
# Month=3, Predicted=3794.2916, Expected=3765.6570
# Month=4, Predicted=3763.7720, Expected=3748.1286
# Month=5, Predicted=3746.0651, Expected=3754.3337
# Month=6, Predicted=3750.4848, Expected=3754.9339
# Month=7, Predicted=3753.0000, Expected=3767.0982
# Month=8, Predicted=3767.7338, Expected=3750.6516
# Month=9, Predicted=3751.3833, Expected=3769.4487
# Month=10, Predicted=3771.6441, Expected=3759.5828
# Month=11, Predicted=3760.8572, Expected=3784.9396
# Month=12, Predicted=3787.2348, Expected=3776.2658
# Month=13, Predicted=3777.5782, Expected=3755.4558
# Month=14, Predicted=3755.8515, Expected=3754.3681
# Month=15, Predicted=3753.5570, Expected=3750.8239
# Month=16, Predicted=3748.7286, Expected=3775.7500
# Month=17, Predicted=3775.8525, Expected=3846.6561
# Month=18, Predicted=3854.5549, Expected=3830.9294
# Month=19, Predicted=3837.9014, Expected=3881.2132
# Month=20, Predicted=3885.5693, Expected=3898.3362
# Month=21, Predicted=3903.6854, Expected=3917.4832
# Month=22, Predicted=3918.6909, Expected=3914.1172
# Month=23, Predicted=3912.9374, Expected=3901.5435
# Month=24, Predicted=3899.1777, Expected=3885.2002
# Month=25, Predicted=3881.7577, Expected=3892.2451
# Month=26, Predicted=3888.9984, Expected=3899.6669
# Month=27, Predicted=3898.6312, Expected=3885.6275
# Month=28, Predicted=3885.5308, Expected=3908.2336
# Month=29, Predicted=3910.2468, Expected=3875.4078
# Month=30, Predicted=3875.6210, Expected=3859.5120
# Month=31, Predicted=3862.2966, Expected=3879.9687
# Month=32, Predicted=3880.1613, Expected=3893.2937
# Month=33, Predicted=3896.2208, Expected=3953.4607
# Month=34, Predicted=3960.3474, Expected=3932.8670
# Month=35, Predicted=3938.0782, Expected=3936.3431
# Month=36, Predicted=3940.1291, Expected=3869.8593
# Month=37, Predicted=3865.8582, Expected=3851.2471
# Month=38, Predicted=3853.6779, Expected=3836.7683
# Month=39, Predicted=3830.4473, Expected=3832.0688
# Month=40, Predicted=3828.5345, Expected=3849.7587
# Month=41, Predicted=3850.5436, Expected=3862.2441
# Month=42, Predicted=3866.9027, Expected=3878.6123
# Month=43, Predicted=3884.1525, Expected=3855.0054
# Month=44, Predicted=3857.5695, Expected=3842.4833
# Month=45, Predicted=3845.1350, Expected=3847.2433
# Month=46, Predicted=3846.2149, Expected=3801.1048
# Month=47, Predicted=3796.8621, Expected=3786.6840
# Month=48, Predicted=3786.7102, Expected=3776.0367
# Month=49, Predicted=3771.7725, Expected=3796.7972
# Month=50, Predicted=3795.7102, Expected=3821.0598
# Month=51, Predicted=3825.2623, Expected=3877.3486
# Month=52, Predicted=3886.1913, Expected=3875.8349
# Month=53, Predicted=3883.5814, Expected=3889.3484
# Month=54, Predicted=3892.8941, Expected=3911.1229
# Month=55, Predicted=3912.3156, Expected=3922.9724
# Month=56, Predicted=3922.7964, Expected=3917.9201
# Month=57, Predicted=3915.7956, Expected=3936.3097
# Month=58, Predicted=3934.2866, Expected=3911.1479
# Month=59, Predicted=3907.1880, Expected=3890.6722
# Month=60, Predicted=3888.8680, Expected=3854.8904
# Run 26 — RMSE: 24.382654, MSE: 594.513827, NMSE: 0.0026560557
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3799.8158, Expected=3796.1139
# Month=2, Predicted=3795.3219, Expected=3793.0240
# Month=3, Predicted=3794.0958, Expected=3765.6570
# Month=4, Predicted=3765.5923, Expected=3748.1286
# Month=5, Predicted=3748.4056, Expected=3754.3337
# Month=6, Predicted=3752.1903, Expected=3754.9339
# Month=7, Predicted=3754.4825, Expected=3767.0982
# Month=8, Predicted=3767.6464, Expected=3750.6516
# Month=9, Predicted=3750.0623, Expected=3769.4487
# Month=10, Predicted=3770.8162, Expected=3759.5828
# Month=11, Predicted=3759.5213, Expected=3784.9396
# Month=12, Predicted=3786.7719, Expected=3776.2658
# Month=13, Predicted=3776.4363, Expected=3755.4558
# Month=14, Predicted=3756.7097, Expected=3754.3681
# Month=15, Predicted=3754.6172, Expected=3750.8239
# Month=16, Predicted=3750.0653, Expected=3775.7500
# Month=17, Predicted=3776.8874, Expected=3846.6561
# Month=18, Predicted=3851.3267, Expected=3830.9294
# Month=19, Predicted=3830.4340, Expected=3881.2132
# Month=20, Predicted=3884.2197, Expected=3898.3362
# Month=21, Predicted=3900.6556, Expected=3917.4832
# Month=22, Predicted=3917.3786, Expected=3914.1172
# Month=23, Predicted=3913.6164, Expected=3901.5435
# Month=24, Predicted=3902.1275, Expected=3885.2002
# Month=25, Predicted=3885.2710, Expected=3892.2451
# Month=26, Predicted=3891.7676, Expected=3899.6669
# Month=27, Predicted=3899.7173, Expected=3885.6275
# Month=28, Predicted=3885.2593, Expected=3908.2336
# Month=29, Predicted=3909.3491, Expected=3875.4078
# Month=30, Predicted=3873.7568, Expected=3859.5120
# Month=31, Predicted=3861.8959, Expected=3879.9687
# Month=32, Predicted=3878.4515, Expected=3893.2937
# Month=33, Predicted=3894.8184, Expected=3953.4607
# Month=34, Predicted=3956.1621, Expected=3932.8670
# Month=35, Predicted=3932.0537, Expected=3936.3431
# Month=36, Predicted=3940.4353, Expected=3869.8593
# Month=37, Predicted=3867.2297, Expected=3851.2471
# Month=38, Predicted=3852.6725, Expected=3836.7683
# Month=39, Predicted=3828.7741, Expected=3832.0688
# Month=40, Predicted=3828.4222, Expected=3849.7587
# Month=41, Predicted=3848.7602, Expected=3862.2441
# Month=42, Predicted=3862.9157, Expected=3878.6123
# Month=43, Predicted=3879.2884, Expected=3855.0054
# Month=44, Predicted=3854.4772, Expected=3842.4833
# Month=45, Predicted=3844.7524, Expected=3847.2433
# Month=46, Predicted=3846.7517, Expected=3801.1048
# Month=47, Predicted=3798.7880, Expected=3786.6840
# Month=48, Predicted=3787.2083, Expected=3776.0367
# Month=49, Predicted=3770.8997, Expected=3796.7972
# Month=50, Predicted=3795.9979, Expected=3821.0598
# Month=51, Predicted=3823.2776, Expected=3877.3486
# Month=52, Predicted=3880.2943, Expected=3875.8349
# Month=53, Predicted=3875.9998, Expected=3889.3484
# Month=54, Predicted=3890.9039, Expected=3911.1229
# Month=55, Predicted=3912.4570, Expected=3922.9724
# Month=56, Predicted=3923.5939, Expected=3917.9201
# Month=57, Predicted=3918.0958, Expected=3936.3097
# Month=58, Predicted=3937.7389, Expected=3911.1479
# Month=59, Predicted=3910.2529, Expected=3890.6722
# Month=60, Predicted=3892.7074, Expected=3854.8904
# Run 27 — RMSE: 24.776071, MSE: 613.853701, NMSE: 0.0027705835
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3803.1984, Expected=3796.1139
# Month=2, Predicted=3794.6700, Expected=3793.0240
# Month=3, Predicted=3793.4950, Expected=3765.6570
# Month=4, Predicted=3763.9413, Expected=3748.1286
# Month=5, Predicted=3745.4191, Expected=3754.3337
# Month=6, Predicted=3747.2395, Expected=3754.9339
# Month=7, Predicted=3753.4900, Expected=3767.0982
# Month=8, Predicted=3769.0656, Expected=3750.6516
# Month=9, Predicted=3751.3241, Expected=3769.4487
# Month=10, Predicted=3772.2118, Expected=3759.5828
# Month=11, Predicted=3759.4082, Expected=3784.9396
# Month=12, Predicted=3786.9346, Expected=3776.2658
# Month=13, Predicted=3776.9202, Expected=3755.4558
# Month=14, Predicted=3757.0384, Expected=3754.3681
# Month=15, Predicted=3754.9414, Expected=3750.8239
# Month=16, Predicted=3748.2649, Expected=3775.7500
# Month=17, Predicted=3778.1496, Expected=3846.6561
# Month=18, Predicted=3858.2806, Expected=3830.9294
# Month=19, Predicted=3833.2032, Expected=3881.2132
# Month=20, Predicted=3880.2377, Expected=3898.3362
# Month=21, Predicted=3900.3758, Expected=3917.4832
# Month=22, Predicted=3911.7909, Expected=3914.1172
# Month=23, Predicted=3908.7842, Expected=3901.5435
# Month=24, Predicted=3897.2093, Expected=3885.2002
# Month=25, Predicted=3879.0110, Expected=3892.2451
# Month=26, Predicted=3884.7583, Expected=3899.6669
# Month=27, Predicted=3895.9470, Expected=3885.6275
# Month=28, Predicted=3882.1412, Expected=3908.2336
# Month=29, Predicted=3907.7431, Expected=3875.4078
# Month=30, Predicted=3869.8382, Expected=3859.5120
# Month=31, Predicted=3860.8669, Expected=3879.9687
# Month=32, Predicted=3875.4471, Expected=3893.2937
# Month=33, Predicted=3895.9031, Expected=3953.4607
# Month=34, Predicted=3957.2540, Expected=3932.8670
# Month=35, Predicted=3931.7213, Expected=3936.3431
# Month=36, Predicted=3938.7978, Expected=3869.8593
# Month=37, Predicted=3862.8098, Expected=3851.2471
# Month=38, Predicted=3852.2507, Expected=3836.7683
# Month=39, Predicted=3818.2986, Expected=3832.0688
# Month=40, Predicted=3827.1875, Expected=3849.7587
# Month=41, Predicted=3851.7461, Expected=3862.2441
# Month=42, Predicted=3866.0302, Expected=3878.6123
# Month=43, Predicted=3879.8232, Expected=3855.0054
# Month=44, Predicted=3854.3212, Expected=3842.4833
# Month=45, Predicted=3846.3487, Expected=3847.2433
# Month=46, Predicted=3844.3692, Expected=3801.1048
# Month=47, Predicted=3794.4424, Expected=3786.6840
# Month=48, Predicted=3789.7793, Expected=3776.0367
# Month=49, Predicted=3769.0201, Expected=3796.7972
# Month=50, Predicted=3799.1801, Expected=3821.0598
# Month=51, Predicted=3829.7675, Expected=3877.3486
# Month=52, Predicted=3883.7905, Expected=3875.8349
# Month=53, Predicted=3877.2777, Expected=3889.3484
# Month=54, Predicted=3889.3201, Expected=3911.1229
# Month=55, Predicted=3910.0526, Expected=3922.9724
# Month=56, Predicted=3920.2870, Expected=3917.9201
# Month=57, Predicted=3914.2216, Expected=3936.3097
# Month=58, Predicted=3934.5413, Expected=3911.1479
# Month=59, Predicted=3905.7160, Expected=3890.6722
# Month=60, Predicted=3889.5310, Expected=3854.8904
# Run 28 — RMSE: 24.343456, MSE: 592.603850, NMSE: 0.0027442271
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3802.1413, Expected=3796.1139
# Month=2, Predicted=3797.9086, Expected=3793.0240
# Month=3, Predicted=3793.8274, Expected=3765.6570
# Month=4, Predicted=3763.4735, Expected=3748.1286
# Month=5, Predicted=3746.5710, Expected=3754.3337
# Month=6, Predicted=3750.6275, Expected=3754.9339
# Month=7, Predicted=3753.2316, Expected=3767.0982
# Month=8, Predicted=3767.7152, Expected=3750.6516
# Month=9, Predicted=3750.2958, Expected=3769.4487
# Month=10, Predicted=3770.4238, Expected=3759.5828
# Month=11, Predicted=3758.6164, Expected=3784.9396
# Month=12, Predicted=3785.8381, Expected=3776.2658
# Month=13, Predicted=3776.0536, Expected=3755.4558
# Month=14, Predicted=3755.5936, Expected=3754.3681
# Month=15, Predicted=3753.3521, Expected=3750.8239
# Month=16, Predicted=3748.2496, Expected=3775.7500
# Month=17, Predicted=3775.9376, Expected=3846.6561
# Month=18, Predicted=3853.8501, Expected=3830.9294
# Month=19, Predicted=3835.4250, Expected=3881.2132
# Month=20, Predicted=3884.9042, Expected=3898.3362
# Month=21, Predicted=3900.7002, Expected=3917.4832
# Month=22, Predicted=3917.2497, Expected=3914.1172
# Month=23, Predicted=3912.3743, Expected=3901.5435
# Month=24, Predicted=3899.6123, Expected=3885.2002
# Month=25, Predicted=3882.3296, Expected=3892.2451
# Month=26, Predicted=3889.1222, Expected=3899.6669
# Month=27, Predicted=3897.6817, Expected=3885.6275
# Month=28, Predicted=3884.1315, Expected=3908.2336
# Month=29, Predicted=3908.5358, Expected=3875.4078
# Month=30, Predicted=3872.4657, Expected=3859.5120
# Month=31, Predicted=3860.9500, Expected=3879.9687
# Month=32, Predicted=3877.6650, Expected=3893.2937
# Month=33, Predicted=3894.6453, Expected=3953.4607
# Month=34, Predicted=3959.1665, Expected=3932.8670
# Month=35, Predicted=3936.0144, Expected=3936.3431
# Month=36, Predicted=3940.3346, Expected=3869.8593
# Month=37, Predicted=3865.4445, Expected=3851.2471
# Month=38, Predicted=3855.0275, Expected=3836.7683
# Month=39, Predicted=3828.9629, Expected=3832.0688
# Month=40, Predicted=3828.5026, Expected=3849.7587
# Month=41, Predicted=3850.7469, Expected=3862.2441
# Month=42, Predicted=3865.8699, Expected=3878.6123
# Month=43, Predicted=3882.3806, Expected=3855.0054
# Month=44, Predicted=3855.7329, Expected=3842.4833
# Month=45, Predicted=3844.1388, Expected=3847.2433
# Month=46, Predicted=3845.1555, Expected=3801.1048
# Month=47, Predicted=3796.6578, Expected=3786.6840
# Month=48, Predicted=3787.7505, Expected=3776.0367
# Month=49, Predicted=3771.2555, Expected=3796.7972
# Month=50, Predicted=3796.3330, Expected=3821.0598
# Month=51, Predicted=3825.7023, Expected=3877.3486
# Month=52, Predicted=3885.6010, Expected=3875.8349
# Month=53, Predicted=3881.6041, Expected=3889.3484
# Month=54, Predicted=3892.3616, Expected=3911.1229
# Month=55, Predicted=3911.2590, Expected=3922.9724
# Month=56, Predicted=3922.4449, Expected=3917.9201
# Month=57, Predicted=3916.5631, Expected=3936.3097
# Month=58, Predicted=3935.2991, Expected=3911.1479
# Month=59, Predicted=3907.7781, Expected=3890.6722
# Month=60, Predicted=3890.5332, Expected=3854.8904
# Run 29 — RMSE: 24.491012, MSE: 599.809663, NMSE: 0.0026887852
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3800.1183, Expected=3796.1139
# Month=2, Predicted=3792.7072, Expected=3793.0240
# Month=3, Predicted=3789.5167, Expected=3765.6570
# Month=4, Predicted=3765.1915, Expected=3748.1286
# Month=5, Predicted=3748.9346, Expected=3754.3337
# Month=6, Predicted=3756.7791, Expected=3754.9339
# Month=7, Predicted=3757.8225, Expected=3767.0982
# Month=8, Predicted=3767.6336, Expected=3750.6516
# Month=9, Predicted=3750.3248, Expected=3769.4487
# Month=10, Predicted=3769.3883, Expected=3759.5828
# Month=11, Predicted=3761.8411, Expected=3784.9396
# Month=12, Predicted=3785.1528, Expected=3776.2658
# Month=13, Predicted=3777.7764, Expected=3755.4558
# Month=14, Predicted=3754.1008, Expected=3754.3681
# Month=15, Predicted=3754.8537, Expected=3750.8239
# Month=16, Predicted=3753.3960, Expected=3775.7500
# Month=17, Predicted=3777.8912, Expected=3846.6561
# Month=18, Predicted=3852.6523, Expected=3830.9294
# Month=19, Predicted=3829.4224, Expected=3881.2132
# Month=20, Predicted=3875.0179, Expected=3898.3362
# Month=21, Predicted=3902.0469, Expected=3917.4832
# Month=22, Predicted=3913.5868, Expected=3914.1172
# Month=23, Predicted=3911.6033, Expected=3901.5435
# Month=24, Predicted=3900.0814, Expected=3885.2002
# Month=25, Predicted=3885.7269, Expected=3892.2451
# Month=26, Predicted=3894.1699, Expected=3899.6669
# Month=27, Predicted=3903.2189, Expected=3885.6275
# Month=28, Predicted=3885.5227, Expected=3908.2336
# Month=29, Predicted=3908.6548, Expected=3875.4078
# Month=30, Predicted=3875.7736, Expected=3859.5120
# Month=31, Predicted=3859.2230, Expected=3879.9687
# Month=32, Predicted=3882.7245, Expected=3893.2937
# Month=33, Predicted=3897.4183, Expected=3953.4607
# Month=34, Predicted=3954.6130, Expected=3932.8670
# Month=35, Predicted=3931.0505, Expected=3936.3431
# Month=36, Predicted=3932.5525, Expected=3869.8593
# Month=37, Predicted=3867.2434, Expected=3851.2471
# Month=38, Predicted=3853.9479, Expected=3836.7683
# Month=39, Predicted=3839.3816, Expected=3832.0688
# Month=40, Predicted=3830.8232, Expected=3849.7587
# Month=41, Predicted=3849.8448, Expected=3862.2441
# Month=42, Predicted=3863.1482, Expected=3878.6123
# Month=43, Predicted=3877.5238, Expected=3855.0054
# Month=44, Predicted=3852.8240, Expected=3842.4833
# Month=45, Predicted=3841.5923, Expected=3847.2433
# Month=46, Predicted=3849.1726, Expected=3801.1048
# Month=47, Predicted=3800.5200, Expected=3786.6840
# Month=48, Predicted=3787.1756, Expected=3776.0367
# Month=49, Predicted=3777.8179, Expected=3796.7972
# Month=50, Predicted=3797.6440, Expected=3821.0598
# Month=51, Predicted=3823.8026, Expected=3877.3486
# Month=52, Predicted=3878.3207, Expected=3875.8349
# Month=53, Predicted=3874.1228, Expected=3889.3484
# Month=54, Predicted=3883.8050, Expected=3911.1229
# Month=55, Predicted=3911.5598, Expected=3922.9724
# Month=56, Predicted=3923.3199, Expected=3917.9201
# Month=57, Predicted=3916.2622, Expected=3936.3097
# Month=58, Predicted=3936.3089, Expected=3911.1479
# Month=59, Predicted=3911.3350, Expected=3890.6722
# Month=60, Predicted=3890.5115, Expected=3854.8904
# Run 30 — RMSE: 24.159140, MSE: 583.664039, NMSE: 0.0027177801
#
# ===== FINAL RESULTS — Fuzzy Feature Augmentation on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.532391 ± 0.223061
# MSE:  601.887968 ± 10.936424
# NMSE: 0.0027105514 ± 0.0000366502
#
# Best run: 2
#   RMSE: 24.100776
#   MSE:  580.847392
#   NMSE: 0.0026445856
# === Best Run Metrics ===
# RMSE: 24.100776
# MSE:  580.847392
# NMSE: 0.0026445856

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
