# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.10.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn_2 (RNN)                 (1, 8)                    352
#
#  dense_2 (Dense)             (1, 1)                    9
#
# =================================================================
# Total params: 361
# Trainable params: 361
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.001, 0.005, 0.01]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on Dow Jones Industrial Index (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.1% (lambda=0.001, sigma=0.105286)
# ================================================================================
#
# Data shape: (291,)
# First 5 values: [3645.05229685 3625.98544276 3634.06819227 3620.66035311 3606.97534702]
# Supervised data shape: (290, 3)
# Train: (230, 3), Test: (60, 3)
# X_train shape: (230, 1, 2), y_train shape: (230,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3802.4318, Expected=3796.0228
# Month=2, Predicted=3797.8278, Expected=3793.0048
# Month=3, Predicted=3796.1577, Expected=3765.9314
# Month=4, Predicted=3764.4046, Expected=3747.2257
# Month=5, Predicted=3743.8570, Expected=3754.0667
# Month=6, Predicted=3748.2936, Expected=3755.7868
# Month=7, Predicted=3752.9227, Expected=3767.0196
# Month=8, Predicted=3767.4531, Expected=3750.9303
# Month=9, Predicted=3752.1074, Expected=3769.0897
# Month=10, Predicted=3771.6371, Expected=3759.9166
# Month=11, Predicted=3759.2656, Expected=3784.9879
# Month=12, Predicted=3785.1330, Expected=3776.0532
# Month=13, Predicted=3775.7762, Expected=3755.0912
# Month=14, Predicted=3755.6093, Expected=3754.8736
# Month=15, Predicted=3754.7214, Expected=3750.9648
# Month=16, Predicted=3748.0087, Expected=3775.9500
# Month=17, Predicted=3775.4727, Expected=3846.9312
# Month=18, Predicted=3855.3649, Expected=3830.1859
# Month=19, Predicted=3833.5107, Expected=3881.0426
# Month=20, Predicted=3886.4896, Expected=3898.8672
# Month=21, Predicted=3904.6715, Expected=3917.0966
# Month=22, Predicted=3916.9012, Expected=3913.2234
# Month=23, Predicted=3912.3397, Expected=3901.1087
# Month=24, Predicted=3899.8372, Expected=3885.8400
# Month=25, Predicted=3882.4669, Expected=3892.4490
# Month=26, Predicted=3888.3719, Expected=3899.1334
# Month=27, Predicted=3896.7628, Expected=3885.9255
# Month=28, Predicted=3884.4510, Expected=3908.0467
# Month=29, Predicted=3909.7239, Expected=3875.0816
# Month=30, Predicted=3872.3693, Expected=3859.9024
# Month=31, Predicted=3861.2147, Expected=3879.9937
# Month=32, Predicted=3877.5407, Expected=3894.6587
# Month=33, Predicted=3895.7834, Expected=3953.8921
# Month=34, Predicted=3958.5249, Expected=3932.9734
# Month=35, Predicted=3935.3188, Expected=3936.8686
# Month=36, Predicted=3943.2529, Expected=3869.1719
# Month=37, Predicted=3862.9310, Expected=3851.8494
# Month=38, Predicted=3851.1895, Expected=3836.9537
# Month=39, Predicted=3825.4450, Expected=3832.0138
# Month=40, Predicted=3826.6740, Expected=3849.1517
# Month=41, Predicted=3850.6930, Expected=3862.8488
# Month=42, Predicted=3867.4707, Expected=3878.1225
# Month=43, Predicted=3882.3564, Expected=3855.0011
# Month=44, Predicted=3856.1986, Expected=3842.8967
# Month=45, Predicted=3844.5687, Expected=3847.0487
# Month=46, Predicted=3843.7640, Expected=3801.0210
# Month=47, Predicted=3793.9774, Expected=3786.9368
# Month=48, Predicted=3787.3602, Expected=3776.0073
# Month=49, Predicted=3771.0127, Expected=3796.9594
# Month=50, Predicted=3796.1288, Expected=3821.0120
# Month=51, Predicted=3825.4838, Expected=3877.0697
# Month=52, Predicted=3884.1739, Expected=3875.1670
# Month=53, Predicted=3880.0816, Expected=3889.8697
# Month=54, Predicted=3894.0791, Expected=3910.2246
# Month=55, Predicted=3911.7976, Expected=3923.7945
# Month=56, Predicted=3923.2431, Expected=3917.9840
# Month=57, Predicted=3915.9698, Expected=3936.0619
# Month=58, Predicted=3935.6972, Expected=3911.0296
# Month=59, Predicted=3907.5276, Expected=3890.9344
# Month=60, Predicted=3890.2641, Expected=3854.9781
# Run 1 — RMSE: 24.670847, MSE: 608.650709, NMSE: 0.0027083465
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3804.8236, Expected=3796.0228
# Month=2, Predicted=3797.0311, Expected=3793.0048
# Month=3, Predicted=3794.2710, Expected=3765.9314
# Month=4, Predicted=3766.7560, Expected=3747.2257
# Month=5, Predicted=3750.4919, Expected=3754.0667
# Month=6, Predicted=3748.3602, Expected=3755.7868
# Month=7, Predicted=3750.0512, Expected=3767.0196
# Month=8, Predicted=3767.0722, Expected=3750.9303
# Month=9, Predicted=3751.8119, Expected=3769.0897
# Month=10, Predicted=3773.2220, Expected=3759.9166
# Month=11, Predicted=3761.7073, Expected=3784.9879
# Month=12, Predicted=3788.7763, Expected=3776.0532
# Month=13, Predicted=3776.8019, Expected=3755.0912
# Month=14, Predicted=3757.4369, Expected=3754.8736
# Month=15, Predicted=3757.2766, Expected=3750.9648
# Month=16, Predicted=3748.2905, Expected=3775.9500
# Month=17, Predicted=3776.4106, Expected=3846.9312
# Month=18, Predicted=3857.7717, Expected=3830.1859
# Month=19, Predicted=3836.4827, Expected=3881.0426
# Month=20, Predicted=3883.7322, Expected=3898.8672
# Month=21, Predicted=3902.1193, Expected=3917.0966
# Month=22, Predicted=3915.1170, Expected=3913.2234
# Month=23, Predicted=3910.4521, Expected=3901.1087
# Month=24, Predicted=3901.3790, Expected=3885.8400
# Month=25, Predicted=3885.2787, Expected=3892.4490
# Month=26, Predicted=3888.3441, Expected=3899.1334
# Month=27, Predicted=3894.1899, Expected=3885.9255
# Month=28, Predicted=3883.4768, Expected=3908.0467
# Month=29, Predicted=3910.2559, Expected=3875.0816
# Month=30, Predicted=3874.3299, Expected=3859.9024
# Month=31, Predicted=3865.1056, Expected=3879.9937
# Month=32, Predicted=3880.5296, Expected=3894.6587
# Month=33, Predicted=3899.0267, Expected=3953.8921
# Month=34, Predicted=3961.1524, Expected=3932.9734
# Month=35, Predicted=3934.9222, Expected=3936.8686
# Month=36, Predicted=3941.9231, Expected=3869.1719
# Month=37, Predicted=3868.0148, Expected=3851.8494
# Month=38, Predicted=3859.5157, Expected=3836.9537
# Month=39, Predicted=3811.7678, Expected=3832.0138
# Month=40, Predicted=3815.5545, Expected=3849.1517
# Month=41, Predicted=3849.9679, Expected=3862.8488
# Month=42, Predicted=3872.4899, Expected=3878.1225
# Month=43, Predicted=3881.2801, Expected=3855.0011
# Month=44, Predicted=3854.0724, Expected=3842.8967
# Month=45, Predicted=3849.8377, Expected=3847.0487
# Month=46, Predicted=3848.5709, Expected=3801.0210
# Month=47, Predicted=3795.1898, Expected=3786.9368
# Month=48, Predicted=3783.1071, Expected=3776.0073
# Month=49, Predicted=3756.0888, Expected=3796.9594
# Month=50, Predicted=3789.8414, Expected=3821.0120
# Month=51, Predicted=3831.7084, Expected=3877.0697
# Month=52, Predicted=3886.8081, Expected=3875.1670
# Month=53, Predicted=3877.0287, Expected=3889.8697
# Month=54, Predicted=3887.4992, Expected=3910.2246
# Month=55, Predicted=3906.9675, Expected=3923.7945
# Month=56, Predicted=3919.7994, Expected=3917.9840
# Month=57, Predicted=3914.5408, Expected=3936.0619
# Month=58, Predicted=3935.5637, Expected=3911.0296
# Month=59, Predicted=3903.8491, Expected=3890.9344
# Month=60, Predicted=3888.4936, Expected=3854.9781
# Run 2 — RMSE: 25.343384, MSE: 642.287097, NMSE: 0.0028640693
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3802.6166, Expected=3796.0228
# Month=2, Predicted=3796.4302, Expected=3793.0048
# Month=3, Predicted=3793.5612, Expected=3765.9314
# Month=4, Predicted=3765.0694, Expected=3747.2257
# Month=5, Predicted=3748.2629, Expected=3754.0667
# Month=6, Predicted=3754.2827, Expected=3755.7868
# Month=7, Predicted=3757.7602, Expected=3767.0196
# Month=8, Predicted=3769.8309, Expected=3750.9303
# Month=9, Predicted=3751.5162, Expected=3769.0897
# Month=10, Predicted=3770.9538, Expected=3759.9166
# Month=11, Predicted=3759.6089, Expected=3784.9879
# Month=12, Predicted=3786.7621, Expected=3776.0532
# Month=13, Predicted=3776.0347, Expected=3755.0912
# Month=14, Predicted=3755.8268, Expected=3754.8736
# Month=15, Predicted=3755.4926, Expected=3750.9648
# Month=16, Predicted=3750.9603, Expected=3775.9500
# Month=17, Predicted=3778.5350, Expected=3846.9312
# Month=18, Predicted=3855.4326, Expected=3830.1859
# Month=19, Predicted=3831.4324, Expected=3881.0426
# Month=20, Predicted=3884.0168, Expected=3898.8672
# Month=21, Predicted=3900.6199, Expected=3917.0966
# Month=22, Predicted=3917.3369, Expected=3913.2234
# Month=23, Predicted=3912.5079, Expected=3901.1087
# Month=24, Predicted=3901.4955, Expected=3885.8400
# Month=25, Predicted=3886.4664, Expected=3892.4490
# Month=26, Predicted=3893.8922, Expected=3899.1334
# Month=27, Predicted=3901.4732, Expected=3885.9255
# Month=28, Predicted=3887.5541, Expected=3908.0467
# Month=29, Predicted=3910.9253, Expected=3875.0816
# Month=30, Predicted=3873.9659, Expected=3859.9024
# Month=31, Predicted=3863.0372, Expected=3879.9937
# Month=32, Predicted=3880.2327, Expected=3894.6587
# Month=33, Predicted=3897.8506, Expected=3953.8921
# Month=34, Predicted=3960.0249, Expected=3932.9734
# Month=35, Predicted=3932.8449, Expected=3936.8686
# Month=36, Predicted=3939.7034, Expected=3869.1719
# Month=37, Predicted=3865.6207, Expected=3851.8494
# Month=38, Predicted=3855.8498, Expected=3836.9537
# Month=39, Predicted=3833.6952, Expected=3832.0138
# Month=40, Predicted=3833.2274, Expected=3849.1517
# Month=41, Predicted=3852.2669, Expected=3862.8488
# Month=42, Predicted=3865.7997, Expected=3878.1225
# Month=43, Predicted=3879.3604, Expected=3855.0011
# Month=44, Predicted=3853.0180, Expected=3842.8967
# Month=45, Predicted=3843.0144, Expected=3847.0487
# Month=46, Predicted=3845.2052, Expected=3801.0210
# Month=47, Predicted=3798.1362, Expected=3786.9368
# Month=48, Predicted=3788.8295, Expected=3776.0073
# Month=49, Predicted=3773.9795, Expected=3796.9594
# Month=50, Predicted=3798.8670, Expected=3821.0120
# Month=51, Predicted=3825.3676, Expected=3877.0697
# Month=52, Predicted=3882.7696, Expected=3875.1670
# Month=53, Predicted=3875.7244, Expected=3889.8697
# Month=54, Predicted=3889.9727, Expected=3910.2246
# Month=55, Predicted=3909.3984, Expected=3923.7945
# Month=56, Predicted=3923.6159, Expected=3917.9840
# Month=57, Predicted=3917.4364, Expected=3936.0619
# Month=58, Predicted=3937.3060, Expected=3911.0296
# Month=59, Predicted=3910.1303, Expected=3890.9344
# Month=60, Predicted=3893.4891, Expected=3854.9781
# Run 3 — RMSE: 24.367175, MSE: 593.759197, NMSE: 0.0027004989
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3802.9543, Expected=3796.0228
# Month=2, Predicted=3794.9863, Expected=3793.0048
# Month=3, Predicted=3793.2172, Expected=3765.9314
# Month=4, Predicted=3762.8442, Expected=3747.2257
# Month=5, Predicted=3746.4595, Expected=3754.0667
# Month=6, Predicted=3748.5341, Expected=3755.7868
# Month=7, Predicted=3753.9233, Expected=3767.0196
# Month=8, Predicted=3768.1502, Expected=3750.9303
# Month=9, Predicted=3750.4094, Expected=3769.0897
# Month=10, Predicted=3771.1205, Expected=3759.9166
# Month=11, Predicted=3759.8088, Expected=3784.9879
# Month=12, Predicted=3787.2536, Expected=3776.0532
# Month=13, Predicted=3776.3221, Expected=3755.0912
# Month=14, Predicted=3756.7209, Expected=3754.8736
# Month=15, Predicted=3754.4767, Expected=3750.9648
# Month=16, Predicted=3748.3609, Expected=3775.9500
# Month=17, Predicted=3777.8421, Expected=3846.9312
# Month=18, Predicted=3857.2340, Expected=3830.1859
# Month=19, Predicted=3830.8772, Expected=3881.0426
# Month=20, Predicted=3880.7945, Expected=3898.8672
# Month=21, Predicted=3900.9193, Expected=3917.0966
# Month=22, Predicted=3914.5752, Expected=3913.2234
# Month=23, Predicted=3909.4343, Expected=3901.1087
# Month=24, Predicted=3899.3051, Expected=3885.8400
# Month=25, Predicted=3881.4178, Expected=3892.4490
# Month=26, Predicted=3887.5911, Expected=3899.1334
# Month=27, Predicted=3896.0110, Expected=3885.9255
# Month=28, Predicted=3884.0933, Expected=3908.0467
# Month=29, Predicted=3909.0915, Expected=3875.0816
# Month=30, Predicted=3870.7643, Expected=3859.9024
# Month=31, Predicted=3863.7774, Expected=3879.9937
# Month=32, Predicted=3878.7197, Expected=3894.6587
# Month=33, Predicted=3898.4124, Expected=3953.8921
# Month=34, Predicted=3958.9871, Expected=3932.9734
# Month=35, Predicted=3933.4503, Expected=3936.8686
# Month=36, Predicted=3940.8199, Expected=3869.1719
# Month=37, Predicted=3860.2628, Expected=3851.8494
# Month=38, Predicted=3860.3687, Expected=3836.9537
# Month=39, Predicted=3823.0148, Expected=3832.0138
# Month=40, Predicted=3828.6195, Expected=3849.1517
# Month=41, Predicted=3851.3063, Expected=3862.8488
# Month=42, Predicted=3867.1869, Expected=3878.1225
# Month=43, Predicted=3880.3701, Expected=3855.0011
# Month=44, Predicted=3854.8977, Expected=3842.8967
# Month=45, Predicted=3846.4826, Expected=3847.0487
# Month=46, Predicted=3845.9413, Expected=3801.0210
# Month=47, Predicted=3796.1612, Expected=3786.9368
# Month=48, Predicted=3791.0178, Expected=3776.0073
# Month=49, Predicted=3769.1341, Expected=3796.9594
# Month=50, Predicted=3797.9324, Expected=3821.0120
# Month=51, Predicted=3827.3781, Expected=3877.0697
# Month=52, Predicted=3882.6514, Expected=3875.1670
# Month=53, Predicted=3876.8189, Expected=3889.8697
# Month=54, Predicted=3888.5642, Expected=3910.2246
# Month=55, Predicted=3908.8643, Expected=3923.7945
# Month=56, Predicted=3922.3975, Expected=3917.9840
# Month=57, Predicted=3915.9073, Expected=3936.0619
# Month=58, Predicted=3935.2676, Expected=3911.0296
# Month=59, Predicted=3904.6011, Expected=3890.9344
# Month=60, Predicted=3892.6328, Expected=3854.9781
# Run 4 — RMSE: 24.619671, MSE: 606.128218, NMSE: 0.0027589438
#
# ===== RUN 5/30 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 145
#     143 run_losses = []
#     144 for epoch in range(100):
# --> 145     history = model.fit(
#     146         X_train, y_train,
#     147         epochs=1, batch_size=1,
#     148         verbose=0, shuffle=False
#     149     )
#     150     run_losses.append(history.history['loss'][0])
#     151     rnn_layer.reset_states()
#
# File c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\keras\engine\training.py:1555, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1551 with data_handler.catch_stop_iteration():
#    1552     data_handler._initial_step = data_handler._initial_step or (
#    1553         self._maybe_load_initial_step_from_ckpt()
#    1554     )
# -> 1555     for step in data_handler.steps():
#    1556         with tf.profiler.experimental.Trace(
#    1557             "train",
#    1558             epoch_num=epoch,
#    (...)
#    1561             _r=1,
#    1562         ):
#    1563             callbacks.on_train_batch_begin(step)
#
# File c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\keras\engine\data_adapter.py:1374, in DataHandler.steps(self)
#    1372 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1373     break
# -> 1374 original_spe = self._steps_per_execution.numpy().item()
#    1375 can_run_full_execution = (
#    1376     original_spe == 1
#    1377     or self._inferred_steps is None
#    1378     or self._inferred_steps - self._current_step >= original_spe
#    1379 )
#    1381 if can_run_full_execution:
#
# File c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:637, in BaseResourceVariable.numpy(self)
#     635 def numpy(self):
#     636   if context.executing_eagerly():
# --> 637     return self.read_value().numpy()
#     638   raise NotImplementedError(
#     639       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\USER\Research\SNP\LSTM-SNP-Notebooks\venv\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
