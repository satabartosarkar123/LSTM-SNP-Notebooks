# %% [markdown]
# # Notebook 2: LSTM-SNP with Fuzzy Feature Augmentation
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements **fuzzy feature augmentation** for the LSTM-SNP model. A Takagi-Sugeno
# fuzzy inference system processes the current and previous input values to generate an additional
# feature, which is concatenated with the original input before being fed into the unmodified
# LSTM-SNP cell.
#
# The LSTM-SNP cell itself is **NOT modified** — only the input representation is enriched with
# fuzzy-derived features.

# %% [markdown]
# ## Theory: Fuzzy Feature Augmentation
#
# ### LSTM-SNP Cell (Unchanged)
# The LSTM-SNP cell equations remain exactly as in the baseline.
#
# ### Fuzzy Inference System
# A Takagi-Sugeno fuzzy system augments the input:
#
# **Membership Functions** (Fixed Gaussian):
# - $\mu_{low}(x) = \exp\left(-\frac{(x - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(x) = \exp\left(-\frac{(x - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **Rules** (4 Takagi-Sugeno rules):
# 1. IF $x(t)$ is low AND $x(t-1)$ is low → $y_1 = a_1 x(t) + b_1 x(t-1) + c_1$
# 2. IF $x(t)$ is low AND $x(t-1)$ is high → $y_2 = a_2 x(t) + b_2 x(t-1) + c_2$
# 3. IF $x(t)$ is high AND $x(t-1)$ is low → $y_3 = a_3 x(t) + b_3 x(t-1) + c_3$
# 4. IF $x(t)$ is high AND $x(t-1)$ is high → $y_4 = a_4 x(t) + b_4 x(t-1) + c_4$
#
# **Defuzzification**: $y_{fuzzy} = \frac{\sum_i w_i y_i}{\sum_i w_i}$ where $w_i = \prod_j \mu_j(x_j)$
#
# **Augmented Input**: $x'(t) = [x(t), y_{fuzzy}(t)]$

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### LSTM-SNP Cell

# %%
# ============================================================
# LSTM-SNP Cell (Original — Unmodified)
# ============================================================

class LSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell: A long short-term memory model inspired from
    spiking neural P systems.

    Gates:
      r(t) = ρ(W_r x(t) + U_r u(t-1) + b_r)   [reset]
      c(t) = ρ(W_c x(t) + U_c u(t-1) + b_c)   [consumption]
      o(t) = ρ(W_o x(t) + U_o u(t-1) + b_o)   [output/generation]
      a(t) = f(W_a x(t) + U_a u(t-1) + b_a)   [generated spikes]

    State update:
      u(t) = r(t) * u(t-1) - c(t) * a(t)
      h(t) = o(t) * a(t)

    ρ = hard_sigmoid, f = tanh
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0)  # reset
        c = self.recurrent_activation(z1)  # consumption
        o = self.recurrent_activation(z2)  # output/generation
        a = self.activation(z3)            # generated spikes

        u = r * u_tm1 - c * a  # internal state
        h = o * a              # output

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({
            'units': self.units,
        })
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Feature Augmentation
# input_dim=2: [x(t), y_fuzzy(t)]
# The LSTM-SNP cell is UNMODIFIED.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    352
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 361 (1.41 KB)
# Trainable params: 361 (1.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        # Set consumption gate (c) bias to 1.0 (unit forget bias)
        rnn_layer = model.layers[1]
        cell = rnn_layer.cell
        weights = cell.get_weights()
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units]
        weights[2] = bias
        cell.set_weights(weights)
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Feature Augmentation on Dow Jones Industrial Index (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Feature Augmentation — Dow Jones Industrial Index\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.1% (lambda=0.001, sigma=0.105286)
# ================================================================================
#
# Data shape: (291,)
# First 5 values: [3645.05229685 3625.98544276 3634.06819227 3620.66035311 3606.97534702]
# Supervised data shape: (290, 3)
# Train: (230, 3), Test: (60, 3)
# X_train shape: (230, 1, 2), y_train shape: (230,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3802.9470, Expected=3796.0228
# Month=2, Predicted=3798.5713, Expected=3793.0048
# Month=3, Predicted=3794.3296, Expected=3765.9314
# Month=4, Predicted=3762.9313, Expected=3747.2257
# Month=5, Predicted=3744.7526, Expected=3754.0667
# Month=6, Predicted=3749.8336, Expected=3755.7868
# Month=7, Predicted=3754.5508, Expected=3767.0196
# Month=8, Predicted=3769.5908, Expected=3750.9303
# Month=9, Predicted=3752.7218, Expected=3769.0897
# Month=10, Predicted=3771.9349, Expected=3759.9166
# Month=11, Predicted=3759.3516, Expected=3784.9879
# Month=12, Predicted=3787.0522, Expected=3776.0532
# Month=13, Predicted=3775.8837, Expected=3755.0912
# Month=14, Predicted=3756.1739, Expected=3754.8736
# Month=15, Predicted=3754.0054, Expected=3750.9648
# Month=16, Predicted=3748.2292, Expected=3775.9500
# Month=17, Predicted=3777.1657, Expected=3846.9312
# Month=18, Predicted=3854.2258, Expected=3830.1859
# Month=19, Predicted=3834.5126, Expected=3881.0426
# Month=20, Predicted=3885.3185, Expected=3898.8672
# Month=21, Predicted=3899.0661, Expected=3917.0966
# Month=22, Predicted=3917.1465, Expected=3913.2234
# Month=23, Predicted=3911.2939, Expected=3901.1087
# Month=24, Predicted=3899.1676, Expected=3885.8400
# Month=25, Predicted=3882.7766, Expected=3892.4490
# Month=26, Predicted=3889.8863, Expected=3899.1334
# Month=27, Predicted=3898.1522, Expected=3885.9255
# Month=28, Predicted=3886.8781, Expected=3908.0467
# Month=29, Predicted=3910.7361, Expected=3875.0816
# Month=30, Predicted=3873.5736, Expected=3859.9024
# Month=31, Predicted=3863.0202, Expected=3879.9937
# Month=32, Predicted=3878.4494, Expected=3894.6587
# Month=33, Predicted=3897.1589, Expected=3953.8921
# Month=34, Predicted=3960.6142, Expected=3932.9734
# Month=35, Predicted=3936.1591, Expected=3936.8686
# Month=36, Predicted=3941.6152, Expected=3869.1719
# Month=37, Predicted=3861.9402, Expected=3851.8494
# Month=38, Predicted=3852.6252, Expected=3836.9537
# Month=39, Predicted=3827.5056, Expected=3832.0138
# Month=40, Predicted=3830.8577, Expected=3849.1517
# Month=41, Predicted=3852.8041, Expected=3862.8488
# Month=42, Predicted=3868.8651, Expected=3878.1225
# Month=43, Predicted=3883.6507, Expected=3855.0011
# Month=44, Predicted=3856.5497, Expected=3842.8967
# Month=45, Predicted=3843.8919, Expected=3847.0487
# Month=46, Predicted=3843.2767, Expected=3801.0210
# Month=47, Predicted=3795.4310, Expected=3786.9368
# Month=48, Predicted=3786.8551, Expected=3776.0073
# Month=49, Predicted=3770.6795, Expected=3796.9594
# Month=50, Predicted=3798.2518, Expected=3821.0120
# Month=51, Predicted=3826.6721, Expected=3877.0697
# Month=52, Predicted=3885.3345, Expected=3875.1670
# Month=53, Predicted=3880.0358, Expected=3889.8697
# Month=54, Predicted=3892.3211, Expected=3910.2246
# Month=55, Predicted=3907.9648, Expected=3923.7945
# Month=56, Predicted=3921.6444, Expected=3917.9840
# Month=57, Predicted=3915.5520, Expected=3936.0619
# Month=58, Predicted=3934.5730, Expected=3911.0296
# Month=59, Predicted=3907.2851, Expected=3890.9344
# Month=60, Predicted=3891.1227, Expected=3854.9781
# Run 1 — RMSE: 24.343420, MSE: 592.602089, NMSE: 0.0026667504
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3801.2230, Expected=3796.0228
# Month=2, Predicted=3797.1574, Expected=3793.0048
# Month=3, Predicted=3794.2072, Expected=3765.9314
# Month=4, Predicted=3764.6686, Expected=3747.2257
# Month=5, Predicted=3747.7996, Expected=3754.0667
# Month=6, Predicted=3752.7790, Expected=3755.7868
# Month=7, Predicted=3755.1192, Expected=3767.0196
# Month=8, Predicted=3767.2626, Expected=3750.9303
# Month=9, Predicted=3749.6796, Expected=3769.0897
# Month=10, Predicted=3769.4836, Expected=3759.9166
# Month=11, Predicted=3758.6673, Expected=3784.9879
# Month=12, Predicted=3786.0391, Expected=3776.0532
# Month=13, Predicted=3775.5300, Expected=3755.0912
# Month=14, Predicted=3755.9404, Expected=3754.8736
# Month=15, Predicted=3754.1514, Expected=3750.9648
# Month=16, Predicted=3749.1714, Expected=3775.9500
# Month=17, Predicted=3776.3058, Expected=3846.9312
# Month=18, Predicted=3851.8416, Expected=3830.1859
# Month=19, Predicted=3833.1562, Expected=3881.0426
# Month=20, Predicted=3885.3534, Expected=3898.8672
# Month=21, Predicted=3902.6302, Expected=3917.0966
# Month=22, Predicted=3919.2372, Expected=3913.2234
# Month=23, Predicted=3913.7692, Expected=3901.1087
# Month=24, Predicted=3901.9037, Expected=3885.8400
# Month=25, Predicted=3885.7908, Expected=3892.4490
# Month=26, Predicted=3892.3763, Expected=3899.1334
# Month=27, Predicted=3899.0676, Expected=3885.9255
# Month=28, Predicted=3885.7624, Expected=3908.0467
# Month=29, Predicted=3908.6865, Expected=3875.0816
# Month=30, Predicted=3872.5391, Expected=3859.9024
# Month=31, Predicted=3862.5576, Expected=3879.9937
# Month=32, Predicted=3878.4438, Expected=3894.6587
# Month=33, Predicted=3895.4895, Expected=3953.8921
# Month=34, Predicted=3956.7916, Expected=3932.9734
# Month=35, Predicted=3934.1358, Expected=3936.8686
# Month=36, Predicted=3941.2741, Expected=3869.1719
# Month=37, Predicted=3864.5787, Expected=3851.8494
# Month=38, Predicted=3857.2760, Expected=3836.9537
# Month=39, Predicted=3832.7140, Expected=3832.0138
# Month=40, Predicted=3829.9495, Expected=3849.1517
# Month=41, Predicted=3847.7063, Expected=3862.8488
# Month=42, Predicted=3862.6545, Expected=3878.1225
# Month=43, Predicted=3878.3950, Expected=3855.0011
# Month=44, Predicted=3853.7039, Expected=3842.8967
# Month=45, Predicted=3843.5080, Expected=3847.0487
# Month=46, Predicted=3845.1516, Expected=3801.0210
# Month=47, Predicted=3797.6875, Expected=3786.9368
# Month=48, Predicted=3788.5959, Expected=3776.0073
# Month=49, Predicted=3771.8119, Expected=3796.9594
# Month=50, Predicted=3795.6374, Expected=3821.0120
# Month=51, Predicted=3822.2597, Expected=3877.0697
# Month=52, Predicted=3880.4173, Expected=3875.1670
# Month=53, Predicted=3877.7912, Expected=3889.8697
# Month=54, Predicted=3892.3063, Expected=3910.2246
# Month=55, Predicted=3910.7556, Expected=3923.7945
# Month=56, Predicted=3924.9975, Expected=3917.9840
# Month=57, Predicted=3918.7304, Expected=3936.0619
# Month=58, Predicted=3937.1842, Expected=3911.0296
# Month=59, Predicted=3909.8455, Expected=3890.9344
# Month=60, Predicted=3893.4247, Expected=3854.9781
# Run 2 — RMSE: 24.675554, MSE: 608.882980, NMSE: 0.0027243516
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3802.5912, Expected=3796.0228
# Month=2, Predicted=3795.6681, Expected=3793.0048
# Month=3, Predicted=3794.2702, Expected=3765.9314
# Month=4, Predicted=3765.6540, Expected=3747.2257
# Month=5, Predicted=3747.7078, Expected=3754.0667
# Month=6, Predicted=3751.5557, Expected=3755.7868
# Month=7, Predicted=3755.7590, Expected=3767.0196
# Month=8, Predicted=3768.2303, Expected=3750.9303
# Month=9, Predicted=3751.0229, Expected=3769.0897
# Month=10, Predicted=3770.5989, Expected=3759.9166
# Month=11, Predicted=3759.6520, Expected=3784.9879
# Month=12, Predicted=3785.9202, Expected=3776.0532
# Month=13, Predicted=3776.1862, Expected=3755.0912
# Month=14, Predicted=3756.1775, Expected=3754.8736
# Month=15, Predicted=3755.0196, Expected=3750.9648
# Month=16, Predicted=3749.4067, Expected=3775.9500
# Month=17, Predicted=3777.0545, Expected=3846.9312
# Month=18, Predicted=3855.0420, Expected=3830.1859
# Month=19, Predicted=3831.9253, Expected=3881.0426
# Month=20, Predicted=3883.5923, Expected=3898.8672
# Month=21, Predicted=3903.1214, Expected=3917.0966
# Month=22, Predicted=3916.2465, Expected=3913.2234
# Month=23, Predicted=3912.4421, Expected=3901.1087
# Month=24, Predicted=3901.5132, Expected=3885.8400
# Month=25, Predicted=3885.4988, Expected=3892.4490
# Month=26, Predicted=3891.6863, Expected=3899.1334
# Month=27, Predicted=3899.4792, Expected=3885.9255
# Month=28, Predicted=3885.7840, Expected=3908.0467
# Month=29, Predicted=3909.3433, Expected=3875.0816
# Month=30, Predicted=3873.0002, Expected=3859.9024
# Month=31, Predicted=3863.3088, Expected=3879.9937
# Month=32, Predicted=3877.9794, Expected=3894.6587
# Month=33, Predicted=3897.3407, Expected=3953.8921
# Month=34, Predicted=3958.5221, Expected=3932.9734
# Month=35, Predicted=3933.6820, Expected=3936.8686
# Month=36, Predicted=3942.2978, Expected=3869.1719
# Month=37, Predicted=3866.0416, Expected=3851.8494
# Month=38, Predicted=3857.5825, Expected=3836.9537
# Month=39, Predicted=3827.1371, Expected=3832.0138
# Month=40, Predicted=3829.1191, Expected=3849.1517
# Month=41, Predicted=3850.2355, Expected=3862.8488
# Month=42, Predicted=3866.0661, Expected=3878.1225
# Month=43, Predicted=3880.0088, Expected=3855.0011
# Month=44, Predicted=3854.8565, Expected=3842.8967
# Month=45, Predicted=3845.4250, Expected=3847.0487
# Month=46, Predicted=3845.2047, Expected=3801.0210
# Month=47, Predicted=3797.0493, Expected=3786.9368
# Month=48, Predicted=3789.3894, Expected=3776.0073
# Month=49, Predicted=3770.2336, Expected=3796.9594
# Month=50, Predicted=3796.7282, Expected=3821.0120
# Month=51, Predicted=3825.7431, Expected=3877.0697
# Month=52, Predicted=3882.7137, Expected=3875.1670
# Month=53, Predicted=3876.9871, Expected=3889.8697
# Month=54, Predicted=3891.3127, Expected=3910.2246
# Month=55, Predicted=3911.3847, Expected=3923.7945
# Month=56, Predicted=3924.3819, Expected=3917.9840
# Month=57, Predicted=3917.4400, Expected=3936.0619
# Month=58, Predicted=3936.7236, Expected=3911.0296
# Month=59, Predicted=3909.3971, Expected=3890.9344
# Month=60, Predicted=3893.2052, Expected=3854.9781
# Run 3 — RMSE: 24.673670, MSE: 608.789983, NMSE: 0.0027354203
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3801.4530, Expected=3796.0228
# Month=2, Predicted=3794.1164, Expected=3793.0048
# Month=3, Predicted=3793.5437, Expected=3765.9314
# Month=4, Predicted=3767.5801, Expected=3747.2257
# Month=5, Predicted=3749.0575, Expected=3754.0667
# Month=6, Predicted=3750.4460, Expected=3755.7868
# Month=7, Predicted=3752.6100, Expected=3767.0196
# Month=8, Predicted=3766.2838, Expected=3750.9303
# Month=9, Predicted=3750.9143, Expected=3769.0897
# Month=10, Predicted=3771.6511, Expected=3759.9166
# Month=11, Predicted=3760.4695, Expected=3784.9879
# Month=12, Predicted=3785.1890, Expected=3776.0532
# Month=13, Predicted=3775.1717, Expected=3755.0912
# Month=14, Predicted=3754.5155, Expected=3754.8736
# Month=15, Predicted=3755.5157, Expected=3750.9648
# Month=16, Predicted=3748.9466, Expected=3775.9500
# Month=17, Predicted=3775.1989, Expected=3846.9312
# Month=18, Predicted=3856.2327, Expected=3830.1859
# Month=19, Predicted=3830.8792, Expected=3881.0426
# Month=20, Predicted=3883.0425, Expected=3898.8672
# Month=21, Predicted=3905.9780, Expected=3917.0966
# Month=22, Predicted=3917.2065, Expected=3913.2234
# Month=23, Predicted=3913.5807, Expected=3901.1087
# Month=24, Predicted=3903.1267, Expected=3885.8400
# Month=25, Predicted=3888.1155, Expected=3892.4490
# Month=26, Predicted=3892.6406, Expected=3899.1334
# Month=27, Predicted=3898.7112, Expected=3885.9255
# Month=28, Predicted=3883.8942, Expected=3908.0467
# Month=29, Predicted=3909.3944, Expected=3875.0816
# Month=30, Predicted=3873.2507, Expected=3859.9024
# Month=31, Predicted=3862.5444, Expected=3879.9937
# Month=32, Predicted=3878.8804, Expected=3894.6587
# Month=33, Predicted=3895.5998, Expected=3953.8921
# Month=34, Predicted=3957.9886, Expected=3932.9734
# Month=35, Predicted=3932.1980, Expected=3936.8686
# Month=36, Predicted=3940.9737, Expected=3869.1719
# Month=37, Predicted=3869.8816, Expected=3851.8494
# Month=38, Predicted=3855.5460, Expected=3836.9537
# Month=39, Predicted=3821.9822, Expected=3832.0138
# Month=40, Predicted=3820.9394, Expected=3849.1517
# Month=41, Predicted=3851.2592, Expected=3862.8488
# Month=42, Predicted=3871.3384, Expected=3878.1225
# Month=43, Predicted=3883.6310, Expected=3855.0011
# Month=44, Predicted=3855.5326, Expected=3842.8967
# Month=45, Predicted=3844.3348, Expected=3847.0487
# Month=46, Predicted=3843.9610, Expected=3801.0210
# Month=47, Predicted=3791.9638, Expected=3786.9368
# Month=48, Predicted=3783.7771, Expected=3776.0073
# Month=49, Predicted=3769.0820, Expected=3796.9594
# Month=50, Predicted=3795.1357, Expected=3821.0120
# Month=51, Predicted=3828.1227, Expected=3877.0697
# Month=52, Predicted=3885.5474, Expected=3875.1670
# Month=53, Predicted=3877.9303, Expected=3889.8697
# Month=54, Predicted=3890.0936, Expected=3910.2246
# Month=55, Predicted=3912.2834, Expected=3923.7945
# Month=56, Predicted=3924.2600, Expected=3917.9840
# Month=57, Predicted=3916.6282, Expected=3936.0619
# Month=58, Predicted=3937.0092, Expected=3911.0296
# Month=59, Predicted=3910.3179, Expected=3890.9344
# Month=60, Predicted=3893.1458, Expected=3854.9781
# Run 4 — RMSE: 24.943885, MSE: 622.197387, NMSE: 0.0027406533
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3787.6690, Expected=3796.0228
# Month=2, Predicted=3785.5326, Expected=3793.0048
# Month=3, Predicted=3786.0317, Expected=3765.9314
# Month=4, Predicted=3753.6262, Expected=3747.2257
# Month=5, Predicted=3740.3067, Expected=3754.0667
# Month=6, Predicted=3741.4800, Expected=3755.7868
# Month=7, Predicted=3742.8722, Expected=3767.0196
# Month=8, Predicted=3758.9963, Expected=3750.9303
# Month=9, Predicted=3740.7596, Expected=3769.0897
# Month=10, Predicted=3762.8161, Expected=3759.9166
# Month=11, Predicted=3744.8949, Expected=3784.9879
# Month=12, Predicted=3777.8485, Expected=3776.0532
# Month=13, Predicted=3761.6582, Expected=3755.0912
# Month=14, Predicted=3750.5197, Expected=3754.8736
# Month=15, Predicted=3746.2445, Expected=3750.9648
# Month=16, Predicted=3737.0116, Expected=3775.9500
# Month=17, Predicted=3766.7085, Expected=3846.9312
# Month=18, Predicted=3837.9628, Expected=3830.1859
# Month=19, Predicted=3816.6070, Expected=3881.0426
# Month=20, Predicted=3879.5951, Expected=3898.8672
# Month=21, Predicted=3880.5823, Expected=3917.0966
# Month=22, Predicted=3907.0453, Expected=3913.2234
# Month=23, Predicted=3899.8301, Expected=3901.1087
# Month=24, Predicted=3891.9501, Expected=3885.8400
# Month=25, Predicted=3875.6377, Expected=3892.4490
# Month=26, Predicted=3882.0582, Expected=3899.1334
# Month=27, Predicted=3885.8459, Expected=3885.9255
# Month=28, Predicted=3876.9437, Expected=3908.0467
# Month=29, Predicted=3900.8135, Expected=3875.0816
# Month=30, Predicted=3860.1125, Expected=3859.9024
# Month=31, Predicted=3860.0227, Expected=3879.9937
# Month=32, Predicted=3864.9030, Expected=3894.6587
# Month=33, Predicted=3880.9609, Expected=3953.8921
# Month=34, Predicted=3945.3102, Expected=3932.9734
# Month=35, Predicted=3918.2481, Expected=3936.8686
# Month=36, Predicted=3937.6494, Expected=3869.1719
# Month=37, Predicted=3853.0951, Expected=3851.8494
# Month=38, Predicted=3853.4091, Expected=3836.9537
# Month=39, Predicted=3815.8662, Expected=3832.0138
# Month=40, Predicted=3823.1075, Expected=3849.1517
# Month=41, Predicted=3840.0514, Expected=3862.8488
# Month=42, Predicted=3852.8215, Expected=3878.1225
# Month=43, Predicted=3869.4781, Expected=3855.0011
# Month=44, Predicted=3844.7314, Expected=3842.8967
# Month=45, Predicted=3838.0315, Expected=3847.0487
# Month=46, Predicted=3833.0914, Expected=3801.0210
# Month=47, Predicted=3789.4455, Expected=3786.9368
# Month=48, Predicted=3787.1818, Expected=3776.0073
# Month=49, Predicted=3760.2476, Expected=3796.9594
# Month=50, Predicted=3788.2116, Expected=3821.0120
# Month=51, Predicted=3811.3987, Expected=3877.0697
# Month=52, Predicted=3870.1253, Expected=3875.1670
# Month=53, Predicted=3863.0286, Expected=3889.8697
# Month=54, Predicted=3884.8115, Expected=3910.2246
# Month=55, Predicted=3894.5506, Expected=3923.7945
# Month=56, Predicted=3910.5764, Expected=3917.9840
# Month=57, Predicted=3907.0071, Expected=3936.0619
# Month=58, Predicted=3926.5106, Expected=3911.0296
# Month=59, Predicted=3896.8744, Expected=3890.9344
# Month=60, Predicted=3888.4675, Expected=3854.9781
# Run 5 — RMSE: 28.036872, MSE: 786.066205, NMSE: 0.0034785545
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3801.7567, Expected=3796.0228
# Month=2, Predicted=3796.2879, Expected=3793.0048
# Month=3, Predicted=3793.0391, Expected=3765.9314
# Month=4, Predicted=3763.0796, Expected=3747.2257
# Month=5, Predicted=3746.0621, Expected=3754.0667
# Month=6, Predicted=3752.0888, Expected=3755.7868
# Month=7, Predicted=3755.6375, Expected=3767.0196
# Month=8, Predicted=3768.3333, Expected=3750.9303
# Month=9, Predicted=3750.3967, Expected=3769.0897
# Month=10, Predicted=3770.0884, Expected=3759.9166
# Month=11, Predicted=3758.8507, Expected=3784.9879
# Month=12, Predicted=3786.5348, Expected=3776.0532
# Month=13, Predicted=3775.3191, Expected=3755.0912
# Month=14, Predicted=3755.3791, Expected=3754.8736
# Month=15, Predicted=3753.7457, Expected=3750.9648
# Month=16, Predicted=3749.5470, Expected=3775.9500
# Month=17, Predicted=3777.4137, Expected=3846.9312
# Month=18, Predicted=3854.0114, Expected=3830.1859
# Month=19, Predicted=3830.9743, Expected=3881.0426
# Month=20, Predicted=3884.0992, Expected=3898.8672
# Month=21, Predicted=3899.2490, Expected=3917.0966
# Month=22, Predicted=3916.7866, Expected=3913.2234
# Month=23, Predicted=3910.8245, Expected=3901.1087
# Month=24, Predicted=3899.3931, Expected=3885.8400
# Month=25, Predicted=3883.5171, Expected=3892.4490
# Month=26, Predicted=3891.0052, Expected=3899.1334
# Month=27, Predicted=3898.6053, Expected=3885.9255
# Month=28, Predicted=3885.3656, Expected=3908.0467
# Month=29, Predicted=3908.8969, Expected=3875.0816
# Month=30, Predicted=3871.9382, Expected=3859.9024
# Month=31, Predicted=3861.4571, Expected=3879.9937
# Month=32, Predicted=3878.6267, Expected=3894.6587
# Month=33, Predicted=3896.6593, Expected=3953.8921
# Month=34, Predicted=3959.0063, Expected=3932.9734
# Month=35, Predicted=3932.6641, Expected=3936.8686
# Month=36, Predicted=3939.7064, Expected=3869.1719
# Month=37, Predicted=3862.1315, Expected=3851.8494
# Month=38, Predicted=3854.2773, Expected=3836.9537
# Month=39, Predicted=3831.5567, Expected=3832.0138
# Month=40, Predicted=3831.3998, Expected=3849.1517
# Month=41, Predicted=3850.7489, Expected=3862.8488
# Month=42, Predicted=3865.7848, Expected=3878.1225
# Month=43, Predicted=3880.6963, Expected=3855.0011
# Month=44, Predicted=3854.5063, Expected=3842.8967
# Month=45, Predicted=3843.3887, Expected=3847.0487
# Month=46, Predicted=3845.3599, Expected=3801.0210
# Month=47, Predicted=3797.6695, Expected=3786.9368
# Month=48, Predicted=3787.8017, Expected=3776.0073
# Month=49, Predicted=3772.6671, Expected=3796.9594
# Month=50, Predicted=3798.1085, Expected=3821.0120
# Month=51, Predicted=3825.0894, Expected=3877.0697
# Month=52, Predicted=3883.3168, Expected=3875.1670
# Month=53, Predicted=3877.2853, Expected=3889.8697
# Month=54, Predicted=3891.4462, Expected=3910.2246
# Month=55, Predicted=3909.4091, Expected=3923.7945
# Month=56, Predicted=3923.3119, Expected=3917.9840
# Month=57, Predicted=3916.5714, Expected=3936.0619
# Month=58, Predicted=3935.7183, Expected=3911.0296
# Month=59, Predicted=3907.6141, Expected=3890.9344
# Month=60, Predicted=3891.2785, Expected=3854.9781
# Run 6 — RMSE: 24.342726, MSE: 592.568287, NMSE: 0.0026887988
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3801.8150, Expected=3796.0228
# Month=2, Predicted=3795.4910, Expected=3793.0048
# Month=3, Predicted=3793.4843, Expected=3765.9314
# Month=4, Predicted=3763.9706, Expected=3747.2257
# Month=5, Predicted=3746.5003, Expected=3754.0667
# Month=6, Predicted=3750.8054, Expected=3755.7868
# Month=7, Predicted=3755.0466, Expected=3767.0196
# Month=8, Predicted=3768.0553, Expected=3750.9303
# Month=9, Predicted=3750.6717, Expected=3769.0897
# Month=10, Predicted=3770.7345, Expected=3759.9166
# Month=11, Predicted=3759.1782, Expected=3784.9879
# Month=12, Predicted=3786.2382, Expected=3776.0532
# Month=13, Predicted=3775.6880, Expected=3755.0912
# Month=14, Predicted=3755.8005, Expected=3754.8736
# Month=15, Predicted=3754.6013, Expected=3750.9648
# Month=16, Predicted=3748.8969, Expected=3775.9500
# Month=17, Predicted=3776.9547, Expected=3846.9312
# Month=18, Predicted=3854.6411, Expected=3830.1859
# Month=19, Predicted=3832.1405, Expected=3881.0426
# Month=20, Predicted=3883.7007, Expected=3898.8672
# Month=21, Predicted=3901.1197, Expected=3917.0966
# Month=22, Predicted=3915.3831, Expected=3913.2234
# Month=23, Predicted=3910.9054, Expected=3901.1087
# Month=24, Predicted=3899.9461, Expected=3885.8400
# Month=25, Predicted=3883.9098, Expected=3892.4490
# Month=26, Predicted=3890.4903, Expected=3899.1334
# Month=27, Predicted=3898.3827, Expected=3885.9255
# Month=28, Predicted=3885.1018, Expected=3908.0467
# Month=29, Predicted=3909.2442, Expected=3875.0816
# Month=30, Predicted=3872.2779, Expected=3859.9024
# Month=31, Predicted=3862.4945, Expected=3879.9937
# Month=32, Predicted=3877.9920, Expected=3894.6587
# Month=33, Predicted=3897.2851, Expected=3953.8921
# Month=34, Predicted=3958.6187, Expected=3932.9734
# Month=35, Predicted=3933.6623, Expected=3936.8686
# Month=36, Predicted=3941.8129, Expected=3869.1719
# Month=37, Predicted=3863.1994, Expected=3851.8494
# Month=38, Predicted=3854.8279, Expected=3836.9537
# Month=39, Predicted=3825.9566, Expected=3832.0138
# Month=40, Predicted=3827.8687, Expected=3849.1517
# Month=41, Predicted=3850.6702, Expected=3862.8488
# Month=42, Predicted=3866.9616, Expected=3878.1225
# Month=43, Predicted=3880.9941, Expected=3855.0011
# Month=44, Predicted=3855.0947, Expected=3842.8967
# Month=45, Predicted=3845.5576, Expected=3847.0487
# Month=46, Predicted=3845.2650, Expected=3801.0210
# Month=47, Predicted=3796.4654, Expected=3786.9368
# Month=48, Predicted=3788.4231, Expected=3776.0073
# Month=49, Predicted=3770.3634, Expected=3796.9594
# Month=50, Predicted=3797.1980, Expected=3821.0120
# Month=51, Predicted=3826.1175, Expected=3877.0697
# Month=52, Predicted=3882.6707, Expected=3875.1670
# Month=53, Predicted=3876.9905, Expected=3889.8697
# Month=54, Predicted=3891.0922, Expected=3910.2246
# Month=55, Predicted=3908.9245, Expected=3923.7945
# Month=56, Predicted=3922.3018, Expected=3917.9840
# Month=57, Predicted=3915.8782, Expected=3936.0619
# Month=58, Predicted=3935.4242, Expected=3911.0296
# Month=59, Predicted=3907.7189, Expected=3890.9344
# Month=60, Predicted=3891.8914, Expected=3854.9781
# Run 7 — RMSE: 24.540196, MSE: 602.221221, NMSE: 0.0027209065
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3801.2129, Expected=3796.0228
# Month=2, Predicted=3796.4769, Expected=3793.0048
# Month=3, Predicted=3793.9882, Expected=3765.9314
# Month=4, Predicted=3763.2951, Expected=3747.2257
# Month=5, Predicted=3742.4571, Expected=3754.0667
# Month=6, Predicted=3747.4693, Expected=3755.7868
# Month=7, Predicted=3751.5520, Expected=3767.0196
# Month=8, Predicted=3767.3139, Expected=3750.9303
# Month=9, Predicted=3753.1174, Expected=3769.0897
# Month=10, Predicted=3773.5740, Expected=3759.9166
# Month=11, Predicted=3761.4132, Expected=3784.9879
# Month=12, Predicted=3786.5536, Expected=3776.0532
# Month=13, Predicted=3775.5169, Expected=3755.0912
# Month=14, Predicted=3754.5958, Expected=3754.8736
# Month=15, Predicted=3753.3940, Expected=3750.9648
# Month=16, Predicted=3748.3149, Expected=3775.9500
# Month=17, Predicted=3776.0015, Expected=3846.9312
# Month=18, Predicted=3853.6940, Expected=3830.1859
# Month=19, Predicted=3831.1817, Expected=3881.0426
# Month=20, Predicted=3884.5947, Expected=3898.8672
# Month=21, Predicted=3901.8129, Expected=3917.0966
# Month=22, Predicted=3914.3060, Expected=3913.2234
# Month=23, Predicted=3908.6636, Expected=3901.1087
# Month=24, Predicted=3895.6021, Expected=3885.8400
# Month=25, Predicted=3879.1682, Expected=3892.4490
# Month=26, Predicted=3886.7528, Expected=3899.1334
# Month=27, Predicted=3896.4318, Expected=3885.9255
# Month=28, Predicted=3885.9895, Expected=3908.0467
# Month=29, Predicted=3911.9022, Expected=3875.0816
# Month=30, Predicted=3875.3608, Expected=3859.9024
# Month=31, Predicted=3863.5710, Expected=3879.9937
# Month=32, Predicted=3879.6778, Expected=3894.6587
# Month=33, Predicted=3895.3348, Expected=3953.8921
# Month=34, Predicted=3957.8797, Expected=3932.9734
# Month=35, Predicted=3933.1493, Expected=3936.8686
# Month=36, Predicted=3941.4036, Expected=3869.1719
# Month=37, Predicted=3864.6292, Expected=3851.8494
# Month=38, Predicted=3849.9042, Expected=3836.9537
# Month=39, Predicted=3825.5286, Expected=3832.0138
# Month=40, Predicted=3824.1092, Expected=3849.1517
# Month=41, Predicted=3848.7888, Expected=3862.8488
# Month=42, Predicted=3867.1666, Expected=3878.1225
# Month=43, Predicted=3883.7773, Expected=3855.0011
# Month=44, Predicted=3857.9023, Expected=3842.8967
# Month=45, Predicted=3844.7748, Expected=3847.0487
# Month=46, Predicted=3844.3957, Expected=3801.0210
# Month=47, Predicted=3793.0237, Expected=3786.9368
# Month=48, Predicted=3784.0939, Expected=3776.0073
# Month=49, Predicted=3770.1303, Expected=3796.9594
# Month=50, Predicted=3796.4770, Expected=3821.0120
# Month=51, Predicted=3825.5745, Expected=3877.0697
# Month=52, Predicted=3884.6038, Expected=3875.1670
# Month=53, Predicted=3878.8057, Expected=3889.8697
# Month=54, Predicted=3891.0540, Expected=3910.2246
# Month=55, Predicted=3909.3058, Expected=3923.7945
# Month=56, Predicted=3920.2172, Expected=3917.9840
# Month=57, Predicted=3912.2554, Expected=3936.0619
# Month=58, Predicted=3931.9687, Expected=3911.0296
# Month=59, Predicted=3905.3622, Expected=3890.9344
# Month=60, Predicted=3890.1548, Expected=3854.9781
# Run 8 — RMSE: 24.706779, MSE: 610.424915, NMSE: 0.0027565211
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3799.8031, Expected=3796.0228
# Month=2, Predicted=3796.1400, Expected=3793.0048
# Month=3, Predicted=3793.4363, Expected=3765.9314
# Month=4, Predicted=3765.4443, Expected=3747.2257
# Month=5, Predicted=3747.2552, Expected=3754.0667
# Month=6, Predicted=3754.0207, Expected=3755.7868
# Month=7, Predicted=3756.1961, Expected=3767.0196
# Month=8, Predicted=3768.0299, Expected=3750.9303
# Month=9, Predicted=3750.7996, Expected=3769.0897
# Month=10, Predicted=3770.5231, Expected=3759.9166
# Month=11, Predicted=3759.6577, Expected=3784.9879
# Month=12, Predicted=3786.3454, Expected=3776.0532
# Month=13, Predicted=3775.8325, Expected=3755.0912
# Month=14, Predicted=3755.5235, Expected=3754.8736
# Month=15, Predicted=3755.8160, Expected=3750.9648
# Month=16, Predicted=3751.0260, Expected=3775.9500
# Month=17, Predicted=3777.2534, Expected=3846.9312
# Month=18, Predicted=3850.2995, Expected=3830.1859
# Month=19, Predicted=3831.4317, Expected=3881.0426
# Month=20, Predicted=3883.4138, Expected=3898.8672
# Month=21, Predicted=3900.0728, Expected=3917.0966
# Month=22, Predicted=3917.4312, Expected=3913.2234
# Month=23, Predicted=3912.7699, Expected=3901.1087
# Month=24, Predicted=3901.1584, Expected=3885.8400
# Month=25, Predicted=3886.0004, Expected=3892.4490
# Month=26, Predicted=3893.0832, Expected=3899.1334
# Month=27, Predicted=3899.4982, Expected=3885.9255
# Month=28, Predicted=3885.9187, Expected=3908.0467
# Month=29, Predicted=3909.4606, Expected=3875.0816
# Month=30, Predicted=3873.7858, Expected=3859.9024
# Month=31, Predicted=3859.7921, Expected=3879.9937
# Month=32, Predicted=3880.8218, Expected=3894.6587
# Month=33, Predicted=3895.6678, Expected=3953.8921
# Month=34, Predicted=3956.5307, Expected=3932.9734
# Month=35, Predicted=3933.2122, Expected=3936.8686
# Month=36, Predicted=3938.7603, Expected=3869.1719
# Month=37, Predicted=3866.6464, Expected=3851.8494
# Month=38, Predicted=3848.1662, Expected=3836.9537
# Month=39, Predicted=3832.5854, Expected=3832.0138
# Month=40, Predicted=3829.8500, Expected=3849.1517
# Month=41, Predicted=3850.4492, Expected=3862.8488
# Month=42, Predicted=3864.0800, Expected=3878.1225
# Month=43, Predicted=3879.0655, Expected=3855.0011
# Month=44, Predicted=3854.3387, Expected=3842.8967
# Month=45, Predicted=3843.6416, Expected=3847.0487
# Month=46, Predicted=3847.3812, Expected=3801.0210
# Month=47, Predicted=3799.6104, Expected=3786.9368
# Month=48, Predicted=3783.8015, Expected=3776.0073
# Month=49, Predicted=3773.3503, Expected=3796.9594
# Month=50, Predicted=3797.2383, Expected=3821.0120
# Month=51, Predicted=3822.7381, Expected=3877.0697
# Month=52, Predicted=3879.7575, Expected=3875.1670
# Month=53, Predicted=3876.2001, Expected=3889.8697
# Month=54, Predicted=3890.6495, Expected=3910.2246
# Month=55, Predicted=3910.3719, Expected=3923.7945
# Month=56, Predicted=3923.9164, Expected=3917.9840
# Month=57, Predicted=3917.6613, Expected=3936.0619
# Month=58, Predicted=3936.8675, Expected=3911.0296
# Month=59, Predicted=3909.9217, Expected=3890.9344
# Month=60, Predicted=3892.0050, Expected=3854.9781
# Run 9 — RMSE: 24.421978, MSE: 596.432994, NMSE: 0.0027116683
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3804.4556, Expected=3796.0228
# Month=2, Predicted=3795.9958, Expected=3793.0048
# Month=3, Predicted=3794.3376, Expected=3765.9314
# Month=4, Predicted=3764.0865, Expected=3747.2257
# Month=5, Predicted=3744.1627, Expected=3754.0667
# Month=6, Predicted=3745.3796, Expected=3755.7868
# Month=7, Predicted=3752.2933, Expected=3767.0196
# Month=8, Predicted=3769.1991, Expected=3750.9303
# Month=9, Predicted=3754.4101, Expected=3769.0897
# Month=10, Predicted=3771.7468, Expected=3759.9166
# Month=11, Predicted=3758.6298, Expected=3784.9879
# Month=12, Predicted=3784.1899, Expected=3776.0532
# Month=13, Predicted=3775.8990, Expected=3755.0912
# Month=14, Predicted=3755.8110, Expected=3754.8736
# Month=15, Predicted=3755.7525, Expected=3750.9648
# Month=16, Predicted=3745.8363, Expected=3775.9500
# Month=17, Predicted=3776.6399, Expected=3846.9312
# Month=18, Predicted=3864.7405, Expected=3830.1859
# Month=19, Predicted=3833.6423, Expected=3881.0426
# Month=20, Predicted=3872.9794, Expected=3898.8672
# Month=21, Predicted=3905.6271, Expected=3917.0966
# Month=22, Predicted=3913.8948, Expected=3913.2234
# Month=23, Predicted=3911.9483, Expected=3901.1087
# Month=24, Predicted=3900.5263, Expected=3885.8400
# Month=25, Predicted=3882.2593, Expected=3892.4490
# Month=26, Predicted=3888.0102, Expected=3899.1334
# Month=27, Predicted=3897.1916, Expected=3885.9255
# Month=28, Predicted=3885.7521, Expected=3908.0467
# Month=29, Predicted=3911.8178, Expected=3875.0816
# Month=30, Predicted=3870.2465, Expected=3859.9024
# Month=31, Predicted=3862.3214, Expected=3879.9937
# Month=32, Predicted=3879.1174, Expected=3894.6587
# Month=33, Predicted=3897.8020, Expected=3953.8921
# Month=34, Predicted=3958.2747, Expected=3932.9734
# Month=35, Predicted=3936.8377, Expected=3936.8686
# Month=36, Predicted=3936.8117, Expected=3869.1719
# Month=37, Predicted=3861.5826, Expected=3851.8494
# Month=38, Predicted=3854.8806, Expected=3836.9537
# Month=39, Predicted=3816.5325, Expected=3832.0138
# Month=40, Predicted=3823.7600, Expected=3849.1517
# Month=41, Predicted=3853.3413, Expected=3862.8488
# Month=42, Predicted=3871.7672, Expected=3878.1225
# Month=43, Predicted=3880.9917, Expected=3855.0011
# Month=44, Predicted=3857.7597, Expected=3842.8967
# Month=45, Predicted=3845.4563, Expected=3847.0487
# Month=46, Predicted=3842.4098, Expected=3801.0210
# Month=47, Predicted=3788.8180, Expected=3786.9368
# Month=48, Predicted=3787.8087, Expected=3776.0073
# Month=49, Predicted=3767.6730, Expected=3796.9594
# Month=50, Predicted=3796.3716, Expected=3821.0120
# Month=51, Predicted=3831.0364, Expected=3877.0697
# Month=52, Predicted=3881.7343, Expected=3875.1670
# Month=53, Predicted=3879.7617, Expected=3889.8697
# Month=54, Predicted=3885.8317, Expected=3910.2246
# Month=55, Predicted=3911.3911, Expected=3923.7945
# Month=56, Predicted=3921.5850, Expected=3917.9840
# Month=57, Predicted=3915.3736, Expected=3936.0619
# Month=58, Predicted=3937.1665, Expected=3911.0296
# Month=59, Predicted=3904.0004, Expected=3890.9344
# Month=60, Predicted=3892.5873, Expected=3854.9781
# Run 10 — RMSE: 24.671889, MSE: 608.702098, NMSE: 0.0027161389
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3801.8794, Expected=3796.0228
# Month=2, Predicted=3796.1427, Expected=3793.0048
# Month=3, Predicted=3795.9752, Expected=3765.9314
# Month=4, Predicted=3763.7369, Expected=3747.2257
# Month=5, Predicted=3743.7779, Expected=3754.0667
# Month=6, Predicted=3747.3243, Expected=3755.7868
# Month=7, Predicted=3752.1804, Expected=3767.0196
# Month=8, Predicted=3768.0607, Expected=3750.9303
# Month=9, Predicted=3754.2854, Expected=3769.0897
# Month=10, Predicted=3773.0322, Expected=3759.9166
# Month=11, Predicted=3760.2519, Expected=3784.9879
# Month=12, Predicted=3784.4336, Expected=3776.0532
# Month=13, Predicted=3777.3503, Expected=3755.0912
# Month=14, Predicted=3755.5237, Expected=3754.8736
# Month=15, Predicted=3755.8010, Expected=3750.9648
# Month=16, Predicted=3746.8046, Expected=3775.9500
# Month=17, Predicted=3774.7743, Expected=3846.9312
# Month=18, Predicted=3859.6007, Expected=3830.1859
# Month=19, Predicted=3833.7580, Expected=3881.0426
# Month=20, Predicted=3884.1697, Expected=3898.8672
# Month=21, Predicted=3907.7246, Expected=3917.0966
# Month=22, Predicted=3910.7369, Expected=3913.2234
# Month=23, Predicted=3912.1776, Expected=3901.1087
# Month=24, Predicted=3900.0799, Expected=3885.8400
# Month=25, Predicted=3882.5026, Expected=3892.4490
# Month=26, Predicted=3887.7472, Expected=3899.1334
# Month=27, Predicted=3896.3478, Expected=3885.9255
# Month=28, Predicted=3884.5401, Expected=3908.0467
# Month=29, Predicted=3912.0303, Expected=3875.0816
# Month=30, Predicted=3873.4006, Expected=3859.9024
# Month=31, Predicted=3863.2746, Expected=3879.9937
# Month=32, Predicted=3879.5186, Expected=3894.6587
# Month=33, Predicted=3896.1643, Expected=3953.8921
# Month=34, Predicted=3957.8839, Expected=3932.9734
# Month=35, Predicted=3937.1120, Expected=3936.8686
# Month=36, Predicted=3943.0087, Expected=3869.1719
# Month=37, Predicted=3860.1546, Expected=3851.8494
# Month=38, Predicted=3854.3690, Expected=3836.9537
# Month=39, Predicted=3821.5153, Expected=3832.0138
# Month=40, Predicted=3823.2538, Expected=3849.1517
# Month=41, Predicted=3853.1531, Expected=3862.8488
# Month=42, Predicted=3871.8650, Expected=3878.1225
# Month=43, Predicted=3883.3602, Expected=3855.0011
# Month=44, Predicted=3856.4638, Expected=3842.8967
# Month=45, Predicted=3845.7506, Expected=3847.0487
# Month=46, Predicted=3843.4900, Expected=3801.0210
# Month=47, Predicted=3791.2974, Expected=3786.9368
# Month=48, Predicted=3789.5751, Expected=3776.0073
# Month=49, Predicted=3770.4380, Expected=3796.9594
# Month=50, Predicted=3794.8494, Expected=3821.0120
# Month=51, Predicted=3828.9852, Expected=3877.0697
# Month=52, Predicted=3885.4841, Expected=3875.1670
# Month=53, Predicted=3880.8045, Expected=3889.8697
# Month=54, Predicted=3891.3105, Expected=3910.2246
# Month=55, Predicted=3911.4847, Expected=3923.7945
# Month=56, Predicted=3919.4532, Expected=3917.9840
# Month=57, Predicted=3914.4093, Expected=3936.0619
# Month=58, Predicted=3936.5864, Expected=3911.0296
# Month=59, Predicted=3906.4346, Expected=3890.9344
# Month=60, Predicted=3891.3273, Expected=3854.9781
# Run 11 — RMSE: 24.837172, MSE: 616.885133, NMSE: 0.0027472629
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3802.5410, Expected=3796.0228
# Month=2, Predicted=3797.6592, Expected=3793.0048
# Month=3, Predicted=3794.0669, Expected=3765.9314
# Month=4, Predicted=3763.1578, Expected=3747.2257
# Month=5, Predicted=3744.8547, Expected=3754.0667
# Month=6, Predicted=3750.4529, Expected=3755.7868
# Month=7, Predicted=3754.3707, Expected=3767.0196
# Month=8, Predicted=3768.1427, Expected=3750.9303
# Month=9, Predicted=3751.5284, Expected=3769.0897
# Month=10, Predicted=3770.8728, Expected=3759.9166
# Month=11, Predicted=3759.7842, Expected=3784.9879
# Month=12, Predicted=3785.6304, Expected=3776.0532
# Month=13, Predicted=3776.1267, Expected=3755.0912
# Month=14, Predicted=3754.7424, Expected=3754.8736
# Month=15, Predicted=3753.7318, Expected=3750.9648
# Month=16, Predicted=3748.3987, Expected=3775.9500
# Month=17, Predicted=3776.1750, Expected=3846.9312
# Month=18, Predicted=3856.2178, Expected=3830.1859
# Month=19, Predicted=3834.8752, Expected=3881.0426
# Month=20, Predicted=3883.5954, Expected=3898.8672
# Month=21, Predicted=3906.9022, Expected=3917.0966
# Month=22, Predicted=3917.5005, Expected=3913.2234
# Month=23, Predicted=3912.8466, Expected=3901.1087
# Month=24, Predicted=3899.4145, Expected=3885.8400
# Month=25, Predicted=3882.7867, Expected=3892.4490
# Month=26, Predicted=3889.8916, Expected=3899.1334
# Month=27, Predicted=3898.2813, Expected=3885.9255
# Month=28, Predicted=3885.6580, Expected=3908.0467
# Month=29, Predicted=3910.3875, Expected=3875.0816
# Month=30, Predicted=3872.8872, Expected=3859.9024
# Month=31, Predicted=3862.7240, Expected=3879.9937
# Month=32, Predicted=3879.8934, Expected=3894.6587
# Month=33, Predicted=3896.4034, Expected=3953.8921
# Month=34, Predicted=3958.3793, Expected=3932.9734
# Month=35, Predicted=3935.6248, Expected=3936.8686
# Month=36, Predicted=3939.9677, Expected=3869.1719
# Month=37, Predicted=3861.0482, Expected=3851.8494
# Month=38, Predicted=3856.1362, Expected=3836.9537
# Month=39, Predicted=3829.3851, Expected=3832.0138
# Month=40, Predicted=3828.9650, Expected=3849.1517
# Month=41, Predicted=3850.5726, Expected=3862.8488
# Month=42, Predicted=3866.2921, Expected=3878.1225
# Month=43, Predicted=3880.9031, Expected=3855.0011
# Month=44, Predicted=3854.5325, Expected=3842.8967
# Month=45, Predicted=3842.8845, Expected=3847.0487
# Month=46, Predicted=3844.0368, Expected=3801.0210
# Month=47, Predicted=3794.0682, Expected=3786.9368
# Month=48, Predicted=3787.6951, Expected=3776.0073
# Month=49, Predicted=3771.6610, Expected=3796.9594
# Month=50, Predicted=3796.5699, Expected=3821.0120
# Month=51, Predicted=3825.6974, Expected=3877.0697
# Month=52, Predicted=3883.9241, Expected=3875.1670
# Month=53, Predicted=3880.6992, Expected=3889.8697
# Month=54, Predicted=3891.1847, Expected=3910.2246
# Month=55, Predicted=3911.4673, Expected=3923.7945
# Month=56, Predicted=3922.9797, Expected=3917.9840
# Month=57, Predicted=3915.9580, Expected=3936.0619
# Month=58, Predicted=3935.5499, Expected=3911.0296
# Month=59, Predicted=3907.5795, Expected=3890.9344
# Month=60, Predicted=3891.4710, Expected=3854.9781
# Run 12 — RMSE: 24.315642, MSE: 591.250462, NMSE: 0.0026415093
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3801.4939, Expected=3796.0228
# Month=2, Predicted=3797.2529, Expected=3793.0048
# Month=3, Predicted=3794.3949, Expected=3765.9314
# Month=4, Predicted=3764.4393, Expected=3747.2257
# Month=5, Predicted=3746.2118, Expected=3754.0667
# Month=6, Predicted=3751.3646, Expected=3755.7868
# Month=7, Predicted=3754.5489, Expected=3767.0196
# Month=8, Predicted=3767.3578, Expected=3750.9303
# Month=9, Predicted=3750.0993, Expected=3769.0897
# Month=10, Predicted=3769.8177, Expected=3759.9166
# Month=11, Predicted=3758.9057, Expected=3784.9879
# Month=12, Predicted=3785.9882, Expected=3776.0532
# Month=13, Predicted=3775.4396, Expected=3755.0912
# Month=14, Predicted=3755.0307, Expected=3754.8736
# Month=15, Predicted=3753.7507, Expected=3750.9648
# Month=16, Predicted=3748.9196, Expected=3775.9500
# Month=17, Predicted=3776.1686, Expected=3846.9312
# Month=18, Predicted=3853.0136, Expected=3830.1859
# Month=19, Predicted=3832.1118, Expected=3881.0426
# Month=20, Predicted=3886.0246, Expected=3898.8672
# Month=21, Predicted=3901.5789, Expected=3917.0966
# Month=22, Predicted=3918.9989, Expected=3913.2234
# Month=23, Predicted=3913.3123, Expected=3901.1087
# Month=24, Predicted=3901.3685, Expected=3885.8400
# Month=25, Predicted=3884.8514, Expected=3892.4490
# Month=26, Predicted=3891.1302, Expected=3899.1334
# Month=27, Predicted=3898.2634, Expected=3885.9255
# Month=28, Predicted=3884.9809, Expected=3908.0467
# Month=29, Predicted=3908.7430, Expected=3875.0816
# Month=30, Predicted=3872.1608, Expected=3859.9024
# Month=31, Predicted=3861.1584, Expected=3879.9937
# Month=32, Predicted=3878.2366, Expected=3894.6587
# Month=33, Predicted=3895.5477, Expected=3953.8921
# Month=34, Predicted=3958.4226, Expected=3932.9734
# Month=35, Predicted=3933.5644, Expected=3936.8686
# Month=36, Predicted=3940.8849, Expected=3869.1719
# Month=37, Predicted=3864.1318, Expected=3851.8494
# Month=38, Predicted=3855.3831, Expected=3836.9537
# Month=39, Predicted=3830.3639, Expected=3832.0138
# Month=40, Predicted=3828.9414, Expected=3849.1517
# Month=41, Predicted=3849.4472, Expected=3862.8488
# Month=42, Predicted=3864.9334, Expected=3878.1225
# Month=43, Predicted=3880.2375, Expected=3855.0011
# Month=44, Predicted=3854.4848, Expected=3842.8967
# Month=45, Predicted=3843.4323, Expected=3847.0487
# Month=46, Predicted=3844.9719, Expected=3801.0210
# Month=47, Predicted=3796.1109, Expected=3786.9368
# Month=48, Predicted=3786.4653, Expected=3776.0073
# Month=49, Predicted=3771.7636, Expected=3796.9594
# Month=50, Predicted=3795.9527, Expected=3821.0120
# Month=51, Predicted=3823.9118, Expected=3877.0697
# Month=52, Predicted=3882.6842, Expected=3875.1670
# Month=53, Predicted=3878.1045, Expected=3889.8697
# Month=54, Predicted=3892.7636, Expected=3910.2246
# Month=55, Predicted=3911.0075, Expected=3923.7945
# Month=56, Predicted=3924.2820, Expected=3917.9840
# Month=57, Predicted=3917.6900, Expected=3936.0619
# Month=58, Predicted=3936.7576, Expected=3911.0296
# Month=59, Predicted=3908.5912, Expected=3890.9344
# Month=60, Predicted=3891.5393, Expected=3854.9781
# Run 13 — RMSE: 24.605736, MSE: 605.442259, NMSE: 0.0027020755
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3802.9388, Expected=3796.0228
# Month=2, Predicted=3797.1142, Expected=3793.0048
# Month=3, Predicted=3793.3375, Expected=3765.9314
# Month=4, Predicted=3763.2032, Expected=3747.2257
# Month=5, Predicted=3744.5597, Expected=3754.0667
# Month=6, Predicted=3749.2270, Expected=3755.7868
# Month=7, Predicted=3754.1464, Expected=3767.0196
# Month=8, Predicted=3768.9654, Expected=3750.9303
# Month=9, Predicted=3752.9479, Expected=3769.0897
# Month=10, Predicted=3772.2667, Expected=3759.9166
# Month=11, Predicted=3760.2868, Expected=3784.9879
# Month=12, Predicted=3786.4701, Expected=3776.0532
# Month=13, Predicted=3775.9973, Expected=3755.0912
# Month=14, Predicted=3755.3060, Expected=3754.8736
# Month=15, Predicted=3754.1879, Expected=3750.9648
# Month=16, Predicted=3748.4963, Expected=3775.9500
# Month=17, Predicted=3776.7791, Expected=3846.9312
# Month=18, Predicted=3855.6353, Expected=3830.1859
# Month=19, Predicted=3833.6448, Expected=3881.0426
# Month=20, Predicted=3883.2866, Expected=3898.8672
# Month=21, Predicted=3899.2629, Expected=3917.0966
# Month=22, Predicted=3913.9046, Expected=3913.2234
# Month=23, Predicted=3909.1467, Expected=3901.1087
# Month=24, Predicted=3897.4130, Expected=3885.8400
# Month=25, Predicted=3881.7157, Expected=3892.4490
# Month=26, Predicted=3888.9699, Expected=3899.1334
# Month=27, Predicted=3897.9998, Expected=3885.9255
# Month=28, Predicted=3886.1523, Expected=3908.0467
# Month=29, Predicted=3910.4901, Expected=3875.0816
# Month=30, Predicted=3874.2562, Expected=3859.9024
# Month=31, Predicted=3862.4878, Expected=3879.9937
# Month=32, Predicted=3878.1333, Expected=3894.6587
# Month=33, Predicted=3896.4970, Expected=3953.8921
# Month=34, Predicted=3959.7387, Expected=3932.9734
# Month=35, Predicted=3935.1669, Expected=3936.8686
# Month=36, Predicted=3940.0993, Expected=3869.1719
# Month=37, Predicted=3862.9751, Expected=3851.8494
# Month=38, Predicted=3851.7342, Expected=3836.9537
# Month=39, Predicted=3823.8785, Expected=3832.0138
# Month=40, Predicted=3826.2525, Expected=3849.1517
# Month=41, Predicted=3851.2978, Expected=3862.8488
# Month=42, Predicted=3869.3683, Expected=3878.1225
# Month=43, Predicted=3883.9793, Expected=3855.0011
# Month=44, Predicted=3857.4814, Expected=3842.8967
# Month=45, Predicted=3845.5971, Expected=3847.0487
# Month=46, Predicted=3844.4813, Expected=3801.0210
# Month=47, Predicted=3795.5771, Expected=3786.9368
# Month=48, Predicted=3786.4590, Expected=3776.0073
# Month=49, Predicted=3770.1518, Expected=3796.9594
# Month=50, Predicted=3797.0774, Expected=3821.0120
# Month=51, Predicted=3827.3819, Expected=3877.0697
# Month=52, Predicted=3885.5021, Expected=3875.1670
# Month=53, Predicted=3879.1330, Expected=3889.8697
# Month=54, Predicted=3891.2779, Expected=3910.2246
# Month=55, Predicted=3908.3389, Expected=3923.7945
# Month=56, Predicted=3921.0013, Expected=3917.9840
# Month=57, Predicted=3914.4531, Expected=3936.0619
# Month=58, Predicted=3933.8538, Expected=3911.0296
# Month=59, Predicted=3906.9596, Expected=3890.9344
# Month=60, Predicted=3889.9571, Expected=3854.9781
# Run 14 — RMSE: 24.446853, MSE: 597.648611, NMSE: 0.0027090287
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3803.5321, Expected=3796.0228
# Month=2, Predicted=3796.3885, Expected=3793.0048
# Month=3, Predicted=3793.6236, Expected=3765.9314
# Month=4, Predicted=3764.6184, Expected=3747.2257
# Month=5, Predicted=3746.9550, Expected=3754.0667
# Month=6, Predicted=3748.5153, Expected=3755.7868
# Month=7, Predicted=3754.2624, Expected=3767.0196
# Month=8, Predicted=3768.2610, Expected=3750.9303
# Month=9, Predicted=3750.5918, Expected=3769.0897
# Month=10, Predicted=3771.0492, Expected=3759.9166
# Month=11, Predicted=3759.1140, Expected=3784.9879
# Month=12, Predicted=3786.4359, Expected=3776.0532
# Month=13, Predicted=3775.8120, Expected=3755.0912
# Month=14, Predicted=3756.1869, Expected=3754.8736
# Month=15, Predicted=3754.3521, Expected=3750.9648
# Month=16, Predicted=3747.8424, Expected=3775.9500
# Month=17, Predicted=3776.9297, Expected=3846.9312
# Month=18, Predicted=3856.1365, Expected=3830.1859
# Month=19, Predicted=3834.8422, Expected=3881.0426
# Month=20, Predicted=3883.9751, Expected=3898.8672
# Month=21, Predicted=3903.9658, Expected=3917.0966
# Month=22, Predicted=3916.2813, Expected=3913.2234
# Month=23, Predicted=3911.5910, Expected=3901.1087
# Month=24, Predicted=3900.7597, Expected=3885.8400
# Month=25, Predicted=3884.1964, Expected=3892.4490
# Month=26, Predicted=3889.4262, Expected=3899.1334
# Month=27, Predicted=3897.8505, Expected=3885.9255
# Month=28, Predicted=3885.1535, Expected=3908.0467
# Month=29, Predicted=3909.1366, Expected=3875.0816
# Month=30, Predicted=3872.0644, Expected=3859.9024
# Month=31, Predicted=3863.7556, Expected=3879.9937
# Month=32, Predicted=3876.7428, Expected=3894.6587
# Month=33, Predicted=3898.3589, Expected=3953.8921
# Month=34, Predicted=3959.4381, Expected=3932.9734
# Month=35, Predicted=3935.1526, Expected=3936.8686
# Month=36, Predicted=3942.1980, Expected=3869.1719
# Month=37, Predicted=3863.5892, Expected=3851.8494
# Month=38, Predicted=3856.3231, Expected=3836.9537
# Month=39, Predicted=3819.8075, Expected=3832.0138
# Month=40, Predicted=3828.1421, Expected=3849.1517
# Month=41, Predicted=3851.9366, Expected=3862.8488
# Month=42, Predicted=3867.5685, Expected=3878.1225
# Month=43, Predicted=3880.0134, Expected=3855.0011
# Month=44, Predicted=3853.7168, Expected=3842.8967
# Month=45, Predicted=3847.0024, Expected=3847.0487
# Month=46, Predicted=3844.7225, Expected=3801.0210
# Month=47, Predicted=3794.7161, Expected=3786.9368
# Month=48, Predicted=3788.7844, Expected=3776.0073
# Month=49, Predicted=3766.4409, Expected=3796.9594
# Month=50, Predicted=3797.3934, Expected=3821.0120
# Month=51, Predicted=3827.1527, Expected=3877.0697
# Month=52, Predicted=3883.0116, Expected=3875.1670
# Month=53, Predicted=3877.4453, Expected=3889.8697
# Month=54, Predicted=3890.4584, Expected=3910.2246
# Month=55, Predicted=3908.4214, Expected=3923.7945
# Month=56, Predicted=3922.1337, Expected=3917.9840
# Month=57, Predicted=3915.8865, Expected=3936.0619
# Month=58, Predicted=3935.3769, Expected=3911.0296
# Month=59, Predicted=3907.6966, Expected=3890.9344
# Month=60, Predicted=3892.3034, Expected=3854.9781
# Run 15 — RMSE: 24.559487, MSE: 603.168423, NMSE: 0.0026986802
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3799.8663, Expected=3796.0228
# Month=2, Predicted=3794.6844, Expected=3793.0048
# Month=3, Predicted=3794.4382, Expected=3765.9314
# Month=4, Predicted=3766.0767, Expected=3747.2257
# Month=5, Predicted=3745.9808, Expected=3754.0667
# Month=6, Predicted=3748.8974, Expected=3755.7868
# Month=7, Predicted=3751.3236, Expected=3767.0196
# Month=8, Predicted=3765.7640, Expected=3750.9303
# Month=9, Predicted=3751.9107, Expected=3769.0897
# Month=10, Predicted=3773.0737, Expected=3759.9166
# Month=11, Predicted=3761.0240, Expected=3784.9879
# Month=12, Predicted=3785.4456, Expected=3776.0532
# Month=13, Predicted=3775.2626, Expected=3755.0912
# Month=14, Predicted=3754.4197, Expected=3754.8736
# Month=15, Predicted=3755.4264, Expected=3750.9648
# Month=16, Predicted=3748.8317, Expected=3775.9500
# Month=17, Predicted=3775.1316, Expected=3846.9312
# Month=18, Predicted=3853.4507, Expected=3830.1859
# Month=19, Predicted=3830.6661, Expected=3881.0426
# ...
# Month=60, Predicted=3891.5690, Expected=3854.8904
# Run 1 — RMSE: 24.873888, MSE: 618.710303, NMSE: 0.0027945494
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3801.1213, Expected=3796.1139
# Month=2, Predicted=3795.6944, Expected=3793.0240
# Month=3, Predicted=3791.8447, Expected=3765.6570
# Month=4, Predicted=3763.1425, Expected=3748.1286
# Month=5, Predicted=3747.5374, Expected=3754.3337
# Month=6, Predicted=3752.7055, Expected=3754.9339
# Month=7, Predicted=3755.0398, Expected=3767.0982
# Month=8, Predicted=3768.5254, Expected=3750.6516
# Month=9, Predicted=3750.3273, Expected=3769.4487
# Month=10, Predicted=3770.3931, Expected=3759.5828
# Month=11, Predicted=3758.9538, Expected=3784.9396
# Month=12, Predicted=3786.1784, Expected=3776.2658
# Month=13, Predicted=3775.7195, Expected=3755.4558
# Month=14, Predicted=3755.2728, Expected=3754.3681
# Month=15, Predicted=3753.5708, Expected=3750.8239
# Month=16, Predicted=3749.7426, Expected=3775.7500
# Month=17, Predicted=3777.0674, Expected=3846.6561
# Month=18, Predicted=3852.3756, Expected=3830.9294
# Month=19, Predicted=3832.0022, Expected=3881.2132
# Month=20, Predicted=3882.0054, Expected=3898.3362
# Month=21, Predicted=3897.4355, Expected=3917.4832
# Month=22, Predicted=3915.1581, Expected=3914.1172
# Month=23, Predicted=3910.6125, Expected=3901.5435
# Month=24, Predicted=3899.3092, Expected=3885.2002
# Month=25, Predicted=3883.1843, Expected=3892.2451
# Month=26, Predicted=3890.8067, Expected=3899.6669
# Month=27, Predicted=3899.2138, Expected=3885.6275
# Month=28, Predicted=3885.1146, Expected=3908.2336
# Month=29, Predicted=3908.8450, Expected=3875.4078
# Month=30, Predicted=3873.0802, Expected=3859.5120
# Month=31, Predicted=3861.3068, Expected=3879.9687
# Month=32, Predicted=3878.9902, Expected=3893.2937
# Month=33, Predicted=3895.7369, Expected=3953.4607
# Month=34, Predicted=3958.3373, Expected=3932.8670
# Month=35, Predicted=3933.2175, Expected=3936.3431
# Month=36, Predicted=3937.8094, Expected=3869.8593
# Month=37, Predicted=3865.1658, Expected=3851.2471
# Month=38, Predicted=3855.2588, Expected=3836.7683
# Month=39, Predicted=3831.4076, Expected=3832.0688
# Month=40, Predicted=3830.8492, Expected=3849.7587
# Month=41, Predicted=3851.3405, Expected=3862.2441
# Month=42, Predicted=3866.1397, Expected=3878.6123
# Month=43, Predicted=3881.9132, Expected=3855.0054
# Month=44, Predicted=3854.6801, Expected=3842.4833
# Month=45, Predicted=3843.2623, Expected=3847.2433
# Month=46, Predicted=3846.0035, Expected=3801.1048
# Month=47, Predicted=3798.4099, Expected=3786.6840
# Month=48, Predicted=3788.6882, Expected=3776.0367
# Month=49, Predicted=3773.0607, Expected=3796.7972
# Month=50, Predicted=3798.3140, Expected=3821.0598
# Month=51, Predicted=3825.7044, Expected=3877.3486
# Month=52, Predicted=3883.7559, Expected=3875.8349
# Month=53, Predicted=3877.8051, Expected=3889.3484
# Month=54, Predicted=3888.9938, Expected=3911.1229
# Month=55, Predicted=3909.1469, Expected=3922.9724
# Month=56, Predicted=3921.0003, Expected=3917.9201
# Month=57, Predicted=3915.3106, Expected=3936.3097
# Month=58, Predicted=3934.7688, Expected=3911.1479
# Month=59, Predicted=3907.7224, Expected=3890.6722
# Month=60, Predicted=3890.8778, Expected=3854.8904
# Run 2 — RMSE: 24.295955, MSE: 590.293426, NMSE: 0.0027044658
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3801.3573, Expected=3796.1139
# Month=2, Predicted=3796.3531, Expected=3793.0240
# Month=3, Predicted=3793.6375, Expected=3765.6570
# Month=4, Predicted=3765.2055, Expected=3748.1286
# Month=5, Predicted=3747.6264, Expected=3754.3337
# Month=6, Predicted=3748.8731, Expected=3754.9339
# Month=7, Predicted=3750.9523, Expected=3767.0982
# Month=8, Predicted=3766.8126, Expected=3750.6516
# Month=9, Predicted=3751.3625, Expected=3769.4487
# Month=10, Predicted=3772.3594, Expected=3759.5828
# Month=11, Predicted=3760.6845, Expected=3784.9396
# Month=12, Predicted=3786.2552, Expected=3776.2658
# Month=13, Predicted=3776.6013, Expected=3755.4558
# Month=14, Predicted=3755.8896, Expected=3754.3681
# Month=15, Predicted=3754.4644, Expected=3750.8239
# Month=16, Predicted=3748.1451, Expected=3775.7500
# Month=17, Predicted=3775.2198, Expected=3846.6561
# Month=18, Predicted=3852.6213, Expected=3830.9294
# Month=19, Predicted=3834.7056, Expected=3881.2132
# Month=20, Predicted=3882.6676, Expected=3898.3362
# Month=21, Predicted=3901.5165, Expected=3917.4832
# Month=22, Predicted=3915.6662, Expected=3914.1172
# Month=23, Predicted=3911.9699, Expected=3901.5435
# Month=24, Predicted=3900.2989, Expected=3885.2002
# Month=25, Predicted=3882.9417, Expected=3892.2451
# Month=26, Predicted=3888.3487, Expected=3899.6669
# Month=27, Predicted=3896.3814, Expected=3885.6275
# Month=28, Predicted=3883.7783, Expected=3908.2336
# Month=29, Predicted=3909.7966, Expected=3875.4078
# Month=30, Predicted=3874.5573, Expected=3859.5120
# Month=31, Predicted=3863.1254, Expected=3879.9687
# Month=32, Predicted=3879.0277, Expected=3893.2937
# Month=33, Predicted=3894.9153, Expected=3953.4607
# Month=34, Predicted=3957.2226, Expected=3932.8670
# Month=35, Predicted=3935.5564, Expected=3936.3431
# Month=36, Predicted=3940.3937, Expected=3869.8593
# Month=37, Predicted=3867.7822, Expected=3851.2471
# Month=38, Predicted=3856.9773, Expected=3836.7683
# Month=39, Predicted=3823.0402, Expected=3832.0688
# Month=40, Predicted=3823.7729, Expected=3849.7587
# Month=41, Predicted=3850.0351, Expected=3862.2441
# Month=42, Predicted=3867.5748, Expected=3878.6123
# Month=43, Predicted=3883.3367, Expected=3855.0054
# Month=44, Predicted=3857.2175, Expected=3842.4833
# Month=45, Predicted=3846.1438, Expected=3847.2433
# Month=46, Predicted=3845.9305, Expected=3801.1048
# Month=47, Predicted=3795.1606, Expected=3786.6840
# Month=48, Predicted=3786.6504, Expected=3776.0367
# Month=49, Predicted=3768.9029, Expected=3796.7972
# Month=50, Predicted=3795.3317, Expected=3821.0598
# Month=51, Predicted=3826.1749, Expected=3877.3486
# Month=52, Predicted=3883.6278, Expected=3875.8349
# Month=53, Predicted=3879.9846, Expected=3889.3484
# Month=54, Predicted=3889.8458, Expected=3911.1229
# Month=55, Predicted=3910.4455, Expected=3922.9724
# Month=56, Predicted=3921.0371, Expected=3917.9201
# Month=57, Predicted=3915.2582, Expected=3936.3097
# Month=58, Predicted=3934.4579, Expected=3911.1479
# Month=59, Predicted=3907.4523, Expected=3890.6722
# Month=60, Predicted=3890.8464, Expected=3854.8904
# Run 3 — RMSE: 24.775253, MSE: 613.813172, NMSE: 0.0027601133
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3801.4790, Expected=3796.1139
# Month=2, Predicted=3794.9739, Expected=3793.0240
# Month=3, Predicted=3793.7116, Expected=3765.6570
# Month=4, Predicted=3765.5689, Expected=3748.1286
# Month=5, Predicted=3746.7429, Expected=3754.3337
# Month=6, Predicted=3747.2110, Expected=3754.9339
# Month=7, Predicted=3750.6951, Expected=3767.0982
# Month=8, Predicted=3767.8970, Expected=3750.6516
# Month=9, Predicted=3751.8794, Expected=3769.4487
# Month=10, Predicted=3773.3371, Expected=3759.5828
# Month=11, Predicted=3761.2080, Expected=3784.9396
# Month=12, Predicted=3787.0783, Expected=3776.2658
# Month=13, Predicted=3776.7547, Expected=3755.4558
# Month=14, Predicted=3756.1644, Expected=3754.3681
# Month=15, Predicted=3753.9226, Expected=3750.8239
# Month=16, Predicted=3747.0022, Expected=3775.7500
# Month=17, Predicted=3775.6472, Expected=3846.6561
# Month=18, Predicted=3854.2026, Expected=3830.9294
# Month=19, Predicted=3832.1091, Expected=3881.2132
# Month=20, Predicted=3880.9829, Expected=3898.3362
# Month=21, Predicted=3901.3499, Expected=3917.4832
# Month=22, Predicted=3914.7419, Expected=3914.1172
# Month=23, Predicted=3912.0803, Expected=3901.5435
# Month=24, Predicted=3900.4287, Expected=3885.2002
# Month=25, Predicted=3881.9053, Expected=3892.2451
# Month=26, Predicted=3886.5112, Expected=3899.6669
# Month=27, Predicted=3895.5023, Expected=3885.6275
# Month=28, Predicted=3883.9732, Expected=3908.2336
# Month=29, Predicted=3910.7356, Expected=3875.4078
# Month=30, Predicted=3874.8534, Expected=3859.5120
# Month=31, Predicted=3864.2762, Expected=3879.9687
# Month=32, Predicted=3879.7240, Expected=3893.2937
# Month=33, Predicted=3895.7005, Expected=3953.4607
# Month=34, Predicted=3957.1764, Expected=3932.8670
# Month=35, Predicted=3933.0571, Expected=3936.3431
# Month=36, Predicted=3939.5101, Expected=3869.8593
# Month=37, Predicted=3866.5647, Expected=3851.2471
# Month=38, Predicted=3851.6483, Expected=3836.7683
# Month=39, Predicted=3818.9099, Expected=3832.0688
# Month=40, Predicted=3824.3646, Expected=3849.7587
# Month=41, Predicted=3852.4033, Expected=3862.2441
# Month=42, Predicted=3868.6164, Expected=3878.6123
# Month=43, Predicted=3882.6344, Expected=3855.0054
# Month=44, Predicted=3857.0742, Expected=3842.4833
# Month=45, Predicted=3847.2980, Expected=3847.2433
# Month=46, Predicted=3846.3613, Expected=3801.1048
# Month=47, Predicted=3793.9952, Expected=3786.6840
# Month=48, Predicted=3783.4451, Expected=3776.0367
# Month=49, Predicted=3763.9995, Expected=3796.7972
# Month=50, Predicted=3795.1822, Expected=3821.0598
# Month=51, Predicted=3827.2419, Expected=3877.3486
# Month=52, Predicted=3883.0386, Expected=3875.8349
# Month=53, Predicted=3877.1766, Expected=3889.3484
# Month=54, Predicted=3888.5858, Expected=3911.1229
# Month=55, Predicted=3911.7412, Expected=3922.9724
# Month=56, Predicted=3921.9224, Expected=3917.9201
# Month=57, Predicted=3915.5687, Expected=3936.3097
# Month=58, Predicted=3934.6198, Expected=3911.1479
# Month=59, Predicted=3905.8326, Expected=3890.6722
# Month=60, Predicted=3888.8636, Expected=3854.8904
# Run 4 — RMSE: 24.806652, MSE: 615.369983, NMSE: 0.0027619459
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3803.7153, Expected=3796.1139
# Month=2, Predicted=3794.6930, Expected=3793.0240
# Month=3, Predicted=3794.1562, Expected=3765.6570
# Month=4, Predicted=3766.6593, Expected=3748.1286
# Month=5, Predicted=3749.2253, Expected=3754.3337
# Month=6, Predicted=3749.4531, Expected=3754.9339
# Month=7, Predicted=3752.8031, Expected=3767.0982
# Month=8, Predicted=3768.0335, Expected=3750.6516
# Month=9, Predicted=3752.3512, Expected=3769.4487
# Month=10, Predicted=3773.9353, Expected=3759.5828
# Month=11, Predicted=3763.2358, Expected=3784.9396
# Month=12, Predicted=3786.7885, Expected=3776.2658
# Month=13, Predicted=3778.7981, Expected=3755.4558
# Month=14, Predicted=3757.4019, Expected=3754.3681
# Month=15, Predicted=3756.7899, Expected=3750.8239
# Month=16, Predicted=3749.9787, Expected=3775.7500
# Month=17, Predicted=3776.6515, Expected=3846.6561
# Month=18, Predicted=3859.4708, Expected=3830.9294
# Month=19, Predicted=3835.3517, Expected=3881.2132
# Month=20, Predicted=3881.8941, Expected=3898.3362
# Month=21, Predicted=3911.6692, Expected=3917.4832
# Month=22, Predicted=3912.6490, Expected=3914.1172
# Month=23, Predicted=3910.8255, Expected=3901.5435
# Month=24, Predicted=3900.6351, Expected=3885.2002
# Month=25, Predicted=3884.8731, Expected=3892.2451
# Month=26, Predicted=3890.2092, Expected=3899.6669
# Month=27, Predicted=3898.8756, Expected=3885.6275
# Month=28, Predicted=3884.4895, Expected=3908.2336
# Month=29, Predicted=3911.3551, Expected=3875.4078
# Month=30, Predicted=3875.6761, Expected=3859.5120
# Month=31, Predicted=3865.6998, Expected=3879.9687
# Month=32, Predicted=3879.7908, Expected=3893.2937
# Month=33, Predicted=3899.1450, Expected=3953.4607
# Month=34, Predicted=3958.3432, Expected=3932.8670
# Month=35, Predicted=3936.8144, Expected=3936.3431
# Month=36, Predicted=3943.1524, Expected=3869.8593
# Month=37, Predicted=3869.4256, Expected=3851.2471
# Month=38, Predicted=3852.4287, Expected=3836.7683
# Month=39, Predicted=3812.2846, Expected=3832.0688
# Month=40, Predicted=3816.8357, Expected=3849.7587
# Month=41, Predicted=3851.0051, Expected=3862.2441
# Month=42, Predicted=3871.1171, Expected=3878.6123
# Month=43, Predicted=3883.8170, Expected=3855.0054
# Month=44, Predicted=3856.1812, Expected=3842.4833
# Month=45, Predicted=3848.1329, Expected=3847.2433
# Month=46, Predicted=3848.4564, Expected=3801.1048
# Month=47, Predicted=3794.1227, Expected=3786.6840
# Month=48, Predicted=3792.7265, Expected=3776.0367
# Month=49, Predicted=3767.9098, Expected=3796.7972
# Month=50, Predicted=3794.2133, Expected=3821.0598
# Month=51, Predicted=3827.1415, Expected=3877.3486
# Month=52, Predicted=3882.4422, Expected=3875.8349
# Month=53, Predicted=3878.8089, Expected=3889.3484
# Month=54, Predicted=3887.6312, Expected=3911.1229
# Month=55, Predicted=3913.3364, Expected=3922.9724
# Month=56, Predicted=3920.2287, Expected=3917.9201
# Month=57, Predicted=3913.2115, Expected=3936.3097
# Month=58, Predicted=3935.1465, Expected=3911.1479
# Month=59, Predicted=3907.9818, Expected=3890.6722
# Month=60, Predicted=3894.6281, Expected=3854.8904
# Run 5 — RMSE: 25.183585, MSE: 634.212958, NMSE: 0.0028453587
#
# ===== RUN 6/30 =====
# Training complete for run 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 163
#     161     y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
#     162     X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
# --> 163     model.predict(X_aug, batch_size=1, verbose=0)
#     165 # Test predictions (single-step) with fuzzy feature augmentation
#     166 predictions = []
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/engine/training.py:2651, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2649     self._steps_per_execution_tuner.start()
#    2650 batch_outputs = None
# -> 2651 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2652     with data_handler.catch_stop_iteration():
#    2653         for step in data_handler.steps():
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1341, in DataHandler.enumerate_epochs(self)
#    1339 """Yields `(epoch, tf.data.Iterator)`."""
#    1340 with self._truncate_execution_to_epoch():
# -> 1341     data_iterator = iter(self._dataset)
#    1342     for epoch in range(self._initial_epoch, self._epochs):
#    1343         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/data/ops/dataset_ops.py:500, in DatasetV2.__iter__(self)
#     498 if context.executing_eagerly() or ops.inside_function():
#     499   with ops.colocate_with(self._variant_tensor):
# --> 500     return iterator_ops.OwnedIterator(self)
#     501 else:
#     502   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     503                      "iteration in eager mode or within tf.function.")
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/data/ops/iterator_ops.py:706, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     702   if (components is not None or element_spec is not None):
#     703     raise ValueError(
#     704         "When `dataset` is provided, `element_spec` and `components` must "
#     705         "not be specified.")
# --> 706   self._create_iterator(dataset)
#     708 self._get_next_call_count = 0
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/data/ops/iterator_ops.py:745, in OwnedIterator._create_iterator(self, dataset)
#     742   assert len(fulltype.args[0].args[0].args) == len(
#     743       self._flat_output_types)
#     744   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 745 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3421, in make_iterator(dataset, iterator, name)
#    3419 if tld.is_eager:
#    3420   try:
# -> 3421     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3422       _ctx, "MakeIterator", name, dataset, iterator)
#    3423     return _result
#    3424   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Feature Augmentation on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
