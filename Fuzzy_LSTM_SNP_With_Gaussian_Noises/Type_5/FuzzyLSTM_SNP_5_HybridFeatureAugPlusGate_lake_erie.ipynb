# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    496
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 505 (1.97 KB)
# Trainable params: 505 (1.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        rnn_layer = model.layers[1]
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Monthly Lake Erie Levels (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Hybrid (Feature Aug + Gate) — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Hybrid (Feature Aug + Gate) — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.010052)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.76799303 14.64761015 15.09151064 16.39130966 16.92364626]
# Supervised data shape: (599, 3)
# Train: (539, 3), Test: (60, 3)
# X_train shape: (539, 1, 2), y_train shape: (539,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.4107, Expected=13.7084
# Month=2, Predicted=14.2415, Expected=13.8026
# Month=3, Predicted=13.8272, Expected=14.3883
# Month=4, Predicted=14.7850, Expected=15.0615
# Month=5, Predicted=15.3996, Expected=15.6682
# Month=6, Predicted=15.8706, Expected=15.8360
# Month=7, Predicted=15.8122, Expected=15.7178
# Month=8, Predicted=15.5525, Expected=15.3110
# Month=9, Predicted=14.9786, Expected=14.7667
# Month=10, Predicted=14.3487, Expected=13.5419
# Month=11, Predicted=12.8543, Expected=13.5869
# Month=12, Predicted=13.8285, Expected=14.5144
# Month=13, Predicted=15.3269, Expected=14.3947
# Month=14, Predicted=14.4531, Expected=14.4996
# Month=15, Predicted=14.4573, Expected=14.7474
# Month=16, Predicted=14.9860, Expected=15.8019
# Month=17, Predicted=16.3904, Expected=16.5221
# Month=18, Predicted=16.7961, Expected=16.5417
# Month=19, Predicted=16.4550, Expected=16.7210
# Month=20, Predicted=16.7573, Expected=16.4288
# Month=21, Predicted=16.2890, Expected=15.7719
# Month=22, Predicted=15.2617, Expected=15.2959
# Month=23, Predicted=14.9764, Expected=15.1318
# Month=24, Predicted=15.2000, Expected=15.5377
# Month=25, Predicted=16.1382, Expected=15.8371
# Month=26, Predicted=16.0250, Expected=16.3719
# Month=27, Predicted=16.6541, Expected=16.3365
# Month=28, Predicted=16.2989, Expected=16.8969
# Month=29, Predicted=17.3671, Expected=17.0022
# Month=30, Predicted=17.0506, Expected=17.4155
# Month=31, Predicted=17.6725, Expected=17.5332
# Month=32, Predicted=17.5730, Expected=17.2849
# Month=33, Predicted=17.0704, Expected=16.6063
# Month=34, Predicted=16.1120, Expected=15.8228
# Month=35, Predicted=15.2428, Expected=15.4543
# Month=36, Predicted=15.3885, Expected=15.6138
# Month=37, Predicted=16.1021, Expected=15.6954
# Month=38, Predicted=15.8464, Expected=16.7627
# Month=39, Predicted=17.3761, Expected=16.4941
# Month=40, Predicted=16.6069, Expected=17.7345
# Month=41, Predicted=18.1682, Expected=18.6944
# Month=42, Predicted=19.1721, Expected=19.1228
# Month=43, Predicted=19.1618, Expected=19.5704
# Month=44, Predicted=19.6673, Expected=19.2258
# Month=45, Predicted=19.1244, Expected=18.2178
# Month=46, Predicted=17.5271, Expected=17.2135
# Month=47, Predicted=16.4866, Expected=16.6554
# Month=48, Predicted=16.5197, Expected=16.8225
# Month=49, Predicted=17.3345, Expected=15.7773
# Month=50, Predicted=15.5789, Expected=15.7224
# Month=51, Predicted=15.8096, Expected=15.9967
# Month=52, Predicted=16.5574, Expected=17.0162
# Month=53, Predicted=17.6281, Expected=17.5568
# Month=54, Predicted=17.7331, Expected=17.8404
# Month=55, Predicted=17.8248, Expected=17.8664
# Month=56, Predicted=17.8130, Expected=17.5659
# Month=57, Predicted=17.3151, Expected=17.0753
# Month=58, Predicted=16.6788, Expected=16.6502
# Month=59, Predicted=16.3600, Expected=16.4285
# Month=60, Predicted=16.3739, Expected=16.5878
# Run 1 — RMSE: 0.480487, MSE: 0.230868, NMSE: 0.0018909691
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.3663, Expected=13.7084
# Month=2, Predicted=14.2119, Expected=13.8026
# Month=3, Predicted=13.8545, Expected=14.3883
# Month=4, Predicted=14.7664, Expected=15.0615
# Month=5, Predicted=15.4081, Expected=15.6682
# Month=6, Predicted=15.9036, Expected=15.8360
# Month=7, Predicted=15.8877, Expected=15.7178
# Month=8, Predicted=15.5927, Expected=15.3110
# Month=9, Predicted=15.0246, Expected=14.7667
# Month=10, Predicted=14.3802, Expected=13.5419
# Month=11, Predicted=12.8272, Expected=13.5869
# Month=12, Predicted=14.7302, Expected=14.5144
# Month=13, Predicted=15.3938, Expected=14.3947
# Month=14, Predicted=14.4516, Expected=14.4996
# Month=15, Predicted=14.5115, Expected=14.7474
# Month=16, Predicted=14.9671, Expected=15.8019
# Month=17, Predicted=16.3927, Expected=16.5221
# Month=18, Predicted=16.7652, Expected=16.5417
# Month=19, Predicted=16.5776, Expected=16.7210
# Month=20, Predicted=16.7868, Expected=16.4288
# Month=21, Predicted=16.2730, Expected=15.7719
# Month=22, Predicted=15.3182, Expected=15.2959
# Month=23, Predicted=15.0091, Expected=15.1318
# Month=24, Predicted=15.1755, Expected=15.5377
# Month=25, Predicted=16.0841, Expected=15.8371
# Month=26, Predicted=16.0287, Expected=16.3719
# Month=27, Predicted=16.6667, Expected=16.3365
# Month=28, Predicted=16.3234, Expected=16.8969
# Month=29, Predicted=17.3324, Expected=17.0022
# Month=30, Predicted=17.0730, Expected=17.4155
# Month=31, Predicted=17.6655, Expected=17.5332
# Month=32, Predicted=17.5912, Expected=17.2849
# Month=33, Predicted=17.0974, Expected=16.6063
# Month=34, Predicted=16.1568, Expected=15.8228
# Month=35, Predicted=15.2725, Expected=15.4543
# Month=36, Predicted=15.3972, Expected=15.6138
# Month=37, Predicted=16.0386, Expected=15.6954
# Month=38, Predicted=15.7911, Expected=16.7627
# Month=39, Predicted=17.4027, Expected=16.4941
# Month=40, Predicted=16.5788, Expected=17.7345
# Month=41, Predicted=18.3197, Expected=18.6944
# Month=42, Predicted=19.0555, Expected=19.1228
# Month=43, Predicted=19.2627, Expected=19.5704
# Month=44, Predicted=19.7737, Expected=19.2258
# Month=45, Predicted=19.1331, Expected=18.2178
# Month=46, Predicted=17.6131, Expected=17.2135
# Month=47, Predicted=16.5728, Expected=16.6554
# Month=48, Predicted=16.5530, Expected=16.8225
# Month=49, Predicted=17.4548, Expected=15.7773
# Month=50, Predicted=15.4485, Expected=15.7224
# Month=51, Predicted=16.2684, Expected=15.9967
# Month=52, Predicted=16.4324, Expected=17.0162
# Month=53, Predicted=17.6215, Expected=17.5568
# Month=54, Predicted=17.7280, Expected=17.8404
# Month=55, Predicted=17.9535, Expected=17.8664
# Month=56, Predicted=17.8363, Expected=17.5659
# Month=57, Predicted=17.3470, Expected=17.0753
# Month=58, Predicted=16.7221, Expected=16.6502
# Month=59, Predicted=16.3783, Expected=16.4285
# Month=60, Predicted=16.3640, Expected=16.5878
# Run 2 — RMSE: 0.489136, MSE: 0.239254, NMSE: 0.0019817368
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.3818, Expected=13.7084
# Month=2, Predicted=14.2268, Expected=13.8026
# Month=3, Predicted=13.8722, Expected=14.3883
# Month=4, Predicted=14.7077, Expected=15.0615
# Month=5, Predicted=15.4180, Expected=15.6682
# Month=6, Predicted=15.8866, Expected=15.8360
# Month=7, Predicted=15.8621, Expected=15.7178
# Month=8, Predicted=15.5626, Expected=15.3110
# Month=9, Predicted=14.9897, Expected=14.7667
# Month=10, Predicted=14.3632, Expected=13.5419
# Month=11, Predicted=12.8612, Expected=13.5869
# Month=12, Predicted=14.5239, Expected=14.5144
# Month=13, Predicted=15.6427, Expected=14.3947
# Month=14, Predicted=14.3691, Expected=14.4996
# Month=15, Predicted=14.4226, Expected=14.7474
# Month=16, Predicted=14.9623, Expected=15.8019
# Month=17, Predicted=16.3910, Expected=16.5221
# Month=18, Predicted=16.8073, Expected=16.5417
# Month=19, Predicted=16.4987, Expected=16.7210
# Month=20, Predicted=16.7277, Expected=16.4288
# Month=21, Predicted=16.2462, Expected=15.7719
# Month=22, Predicted=15.2828, Expected=15.2959
# Month=23, Predicted=14.9777, Expected=15.1318
# Month=24, Predicted=15.1940, Expected=15.5377
# Month=25, Predicted=16.0871, Expected=15.8371
# Month=26, Predicted=16.0871, Expected=16.3719
# Month=27, Predicted=16.6797, Expected=16.3365
# Month=28, Predicted=16.3352, Expected=16.8969
# Month=29, Predicted=17.2283, Expected=17.0022
# Month=30, Predicted=17.1081, Expected=17.4155
# Month=31, Predicted=17.6190, Expected=17.5332
# Month=32, Predicted=17.6160, Expected=17.2849
# Month=33, Predicted=17.0679, Expected=16.6063
# Month=34, Predicted=16.1240, Expected=15.8228
# Month=35, Predicted=15.2684, Expected=15.4543
# Month=36, Predicted=15.3812, Expected=15.6138
# Month=37, Predicted=16.0834, Expected=15.6954
# Month=38, Predicted=15.8195, Expected=16.7627
# Month=39, Predicted=17.3411, Expected=16.4941
# Month=40, Predicted=16.4630, Expected=17.7345
# Month=41, Predicted=18.0996, Expected=18.6944
# Month=42, Predicted=19.1148, Expected=19.1228
# Month=43, Predicted=19.2190, Expected=19.5704
# Month=44, Predicted=19.7601, Expected=19.2258
# Month=45, Predicted=19.1004, Expected=18.2178
# Month=46, Predicted=17.6146, Expected=17.2135
# Month=47, Predicted=16.6885, Expected=16.6554
# Month=48, Predicted=16.6108, Expected=16.8225
# Month=49, Predicted=17.5203, Expected=15.7773
# Month=50, Predicted=15.4166, Expected=15.7224
# Month=51, Predicted=15.9398, Expected=15.9967
# Month=52, Predicted=16.5585, Expected=17.0162
# Month=53, Predicted=17.6438, Expected=17.5568
# Month=54, Predicted=17.7631, Expected=17.8404
# Month=55, Predicted=17.9102, Expected=17.8664
# Month=56, Predicted=17.8212, Expected=17.5659
# Month=57, Predicted=17.3163, Expected=17.0753
# Month=58, Predicted=16.6957, Expected=16.6502
# Month=59, Predicted=16.3659, Expected=16.4285
# Month=60, Predicted=16.3689, Expected=16.5878
# Run 3 — RMSE: 0.499128, MSE: 0.249129, NMSE: 0.0020676865
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.3281, Expected=13.7084
# Month=2, Predicted=14.1234, Expected=13.8026
# Month=3, Predicted=13.8652, Expected=14.3883
# Month=4, Predicted=14.7198, Expected=15.0615
# Month=5, Predicted=15.4253, Expected=15.6682
# Month=6, Predicted=15.9480, Expected=15.8360
# Month=7, Predicted=15.8946, Expected=15.7178
# Month=8, Predicted=15.5829, Expected=15.3110
# Month=9, Predicted=14.9979, Expected=14.7667
# Month=10, Predicted=14.3735, Expected=13.5419
# Month=11, Predicted=12.7406, Expected=13.5869
# Month=12, Predicted=13.8299, Expected=14.5144
# Month=13, Predicted=15.2359, Expected=14.3947
# Month=14, Predicted=14.3291, Expected=14.4996
# Month=15, Predicted=14.5309, Expected=14.7474
# Month=16, Predicted=14.9508, Expected=15.8019
# Month=17, Predicted=16.2832, Expected=16.5221
# Month=18, Predicted=16.8159, Expected=16.5417
# Month=19, Predicted=16.5058, Expected=16.7210
# Month=20, Predicted=16.8040, Expected=16.4288
# Month=21, Predicted=16.2465, Expected=15.7719
# Month=22, Predicted=15.2642, Expected=15.2959
# Month=23, Predicted=14.9936, Expected=15.1318
# Month=24, Predicted=15.1585, Expected=15.5377
# Month=25, Predicted=15.9318, Expected=15.8371
# Month=26, Predicted=16.0583, Expected=16.3719
# Month=27, Predicted=16.6773, Expected=16.3365
# Month=28, Predicted=16.3021, Expected=16.8969
# Month=29, Predicted=17.2281, Expected=17.0022
# Month=30, Predicted=17.0905, Expected=17.4155
# Month=31, Predicted=17.6565, Expected=17.5332
# Month=32, Predicted=17.6067, Expected=17.2849
# Month=33, Predicted=17.0768, Expected=16.6063
# Month=34, Predicted=16.0993, Expected=15.8228
# Month=35, Predicted=15.2593, Expected=15.4543
# Month=36, Predicted=15.3285, Expected=15.6138
# Month=37, Predicted=15.9219, Expected=15.6954
# Month=38, Predicted=15.8196, Expected=16.7627
# Month=39, Predicted=17.2308, Expected=16.4941
# Month=40, Predicted=16.3472, Expected=17.7345
# Month=41, Predicted=18.1106, Expected=18.6944
# Month=42, Predicted=19.1046, Expected=19.1228
# Month=43, Predicted=19.2575, Expected=19.5704
# Month=44, Predicted=19.7937, Expected=19.2258
# Month=45, Predicted=18.9959, Expected=18.2178
# Month=46, Predicted=17.4422, Expected=17.2135
# Month=47, Predicted=16.5538, Expected=16.6554
# Month=48, Predicted=16.4831, Expected=16.8225
# Month=49, Predicted=17.2084, Expected=15.7773
# Month=50, Predicted=15.2630, Expected=15.7224
# Month=51, Predicted=15.7308, Expected=15.9967
# Month=52, Predicted=16.4165, Expected=17.0162
# Month=53, Predicted=17.5152, Expected=17.5568
# Month=54, Predicted=17.7719, Expected=17.8404
# Month=55, Predicted=17.9539, Expected=17.8664
# Month=56, Predicted=17.8349, Expected=17.5659
# Month=57, Predicted=17.3266, Expected=17.0753
# Month=58, Predicted=16.7043, Expected=16.6502
# Month=59, Predicted=16.3877, Expected=16.4285
# Month=60, Predicted=16.3697, Expected=16.5878
# Run 4 — RMSE: 0.484325, MSE: 0.234571, NMSE: 0.0018859291
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.3023, Expected=13.7084
# Month=2, Predicted=14.1601, Expected=13.8026
# Month=3, Predicted=13.6855, Expected=14.3883
# Month=4, Predicted=14.8324, Expected=15.0615
# Month=5, Predicted=15.3658, Expected=15.6682
# Month=6, Predicted=15.8838, Expected=15.8360
# Month=7, Predicted=15.7442, Expected=15.7178
# Month=8, Predicted=15.5115, Expected=15.3110
# Month=9, Predicted=15.0083, Expected=14.7667
# Month=10, Predicted=14.4455, Expected=13.5419
# Month=11, Predicted=13.1198, Expected=13.5869
# Month=12, Predicted=14.8297, Expected=14.5144
# Month=13, Predicted=15.2567, Expected=14.3947
# Month=14, Predicted=14.3400, Expected=14.4996
# Month=15, Predicted=14.5655, Expected=14.7474
# Month=16, Predicted=14.8601, Expected=15.8019
# Month=17, Predicted=16.4104, Expected=16.5221
# Month=18, Predicted=16.7742, Expected=16.5417
# Month=19, Predicted=16.4035, Expected=16.7210
# Month=20, Predicted=16.7890, Expected=16.4288
# Month=21, Predicted=16.1623, Expected=15.7719
# Month=22, Predicted=15.3964, Expected=15.2959
# Month=23, Predicted=15.1085, Expected=15.1318
# Month=24, Predicted=15.1646, Expected=15.5377
# Month=25, Predicted=16.0338, Expected=15.8371
# Month=26, Predicted=15.8804, Expected=16.3719
# Month=27, Predicted=16.6538, Expected=16.3365
# Month=28, Predicted=16.1659, Expected=16.8969
# Month=29, Predicted=17.4168, Expected=17.0022
# Month=30, Predicted=16.8926, Expected=17.4155
# Month=31, Predicted=17.6818, Expected=17.5332
# Month=32, Predicted=17.4373, Expected=17.2849
# Month=33, Predicted=17.0272, Expected=16.6063
# Month=34, Predicted=16.2319, Expected=15.8228
# Month=35, Predicted=15.4410, Expected=15.4543
# Month=36, Predicted=15.4666, Expected=15.6138
# Month=37, Predicted=15.9830, Expected=15.6954
# Month=38, Predicted=15.6397, Expected=16.7627
# Month=39, Predicted=17.4437, Expected=16.4941
# Month=40, Predicted=16.5776, Expected=17.7345
# Month=41, Predicted=18.5854, Expected=18.6944
# Month=42, Predicted=19.1114, Expected=19.1228
# Month=43, Predicted=19.1537, Expected=19.5704
# Month=44, Predicted=19.7075, Expected=19.2258
# Month=45, Predicted=19.0117, Expected=18.2178
# Month=46, Predicted=17.8223, Expected=17.2135
# Month=47, Predicted=16.7994, Expected=16.6554
# Month=48, Predicted=16.6156, Expected=16.8225
# Month=49, Predicted=17.4067, Expected=15.7773
# Month=50, Predicted=15.6122, Expected=15.7224
# Month=51, Predicted=16.4741, Expected=15.9967
# Month=52, Predicted=16.2654, Expected=17.0162
# Month=53, Predicted=17.6132, Expected=17.5568
# Month=54, Predicted=17.6789, Expected=17.8404
# Month=55, Predicted=17.8187, Expected=17.8664
# Month=56, Predicted=17.7254, Expected=17.5659
# Month=57, Predicted=17.2938, Expected=17.0753
# Month=58, Predicted=16.7597, Expected=16.6502
# Month=59, Predicted=16.4314, Expected=16.4285
# Month=60, Predicted=16.3630, Expected=16.5878
# Run 5 — RMSE: 0.498628, MSE: 0.248629, NMSE: 0.0020913411
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.3523, Expected=13.7084
# Month=2, Predicted=14.2030, Expected=13.8026
# Month=3, Predicted=13.6900, Expected=14.3883
# Month=4, Predicted=14.6827, Expected=15.0615
# Month=5, Predicted=15.4171, Expected=15.6682
# Month=6, Predicted=15.8611, Expected=15.8360
# Month=7, Predicted=15.7059, Expected=15.7178
# Month=8, Predicted=15.4583, Expected=15.3110
# Month=9, Predicted=14.9701, Expected=14.7667
# Month=10, Predicted=14.4179, Expected=13.5419
# Month=11, Predicted=13.1409, Expected=13.5869
# Month=12, Predicted=14.4191, Expected=14.5144
# Month=13, Predicted=15.7820, Expected=14.3947
# Month=14, Predicted=14.2369, Expected=14.4996
# Month=15, Predicted=14.4493, Expected=14.7474
# Month=16, Predicted=14.8836, Expected=15.8019
# Month=17, Predicted=16.3796, Expected=16.5221
# Month=18, Predicted=16.7918, Expected=16.5417
# Month=19, Predicted=16.3409, Expected=16.7210
# Month=20, Predicted=16.6922, Expected=16.4288
# Month=21, Predicted=16.1386, Expected=15.7719
# Month=22, Predicted=15.4006, Expected=15.2959
# Month=23, Predicted=15.0636, Expected=15.1318
# Month=24, Predicted=15.2007, Expected=15.5377
# Month=25, Predicted=16.0785, Expected=15.8371
# Month=26, Predicted=15.9620, Expected=16.3719
# Month=27, Predicted=16.5977, Expected=16.3365
# Month=28, Predicted=16.1305, Expected=16.8969
# Month=29, Predicted=17.2295, Expected=17.0022
# Month=30, Predicted=16.9206, Expected=17.4155
# Month=31, Predicted=17.5637, Expected=17.5332
# Month=32, Predicted=17.4517, Expected=17.2849
# Month=33, Predicted=16.9793, Expected=16.6063
# Month=34, Predicted=16.2391, Expected=15.8228
# Month=35, Predicted=15.4323, Expected=15.4543
# Month=36, Predicted=15.4470, Expected=15.6138
# Month=37, Predicted=16.0824, Expected=15.6954
# Month=38, Predicted=15.7257, Expected=16.7627
# Month=39, Predicted=17.3406, Expected=16.4941
# Month=40, Predicted=16.3562, Expected=17.7345
# Month=41, Predicted=18.2803, Expected=18.6944
# Month=42, Predicted=19.1587, Expected=19.1228
# Month=43, Predicted=19.1227, Expected=19.5704
# Month=44, Predicted=19.6505, Expected=19.2258
# Month=45, Predicted=18.9546, Expected=18.2178
# Month=46, Predicted=17.8276, Expected=17.2135
# Month=47, Predicted=16.8067, Expected=16.6554
# Month=48, Predicted=16.6457, Expected=16.8225
# Month=49, Predicted=17.5427, Expected=15.7773
# Month=50, Predicted=15.4488, Expected=15.7224
# Month=51, Predicted=16.0549, Expected=15.9967
# Month=52, Predicted=16.5734, Expected=17.0162
# Month=53, Predicted=17.6424, Expected=17.5568
# Month=54, Predicted=17.6973, Expected=17.8404
# Month=55, Predicted=17.7799, Expected=17.8664
# Month=56, Predicted=17.6815, Expected=17.5659
# Month=57, Predicted=17.2522, Expected=17.0753
# Month=58, Predicted=16.7227, Expected=16.6502
# Month=59, Predicted=16.4108, Expected=16.4285
# Month=60, Predicted=16.3726, Expected=16.5878
# Run 6 — RMSE: 0.515523, MSE: 0.265764, NMSE: 0.0022618951
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.3002, Expected=13.7084
# Month=2, Predicted=14.0832, Expected=13.8026
# Month=3, Predicted=13.7849, Expected=14.3883
# Month=4, Predicted=14.6615, Expected=15.0615
# Month=5, Predicted=15.3714, Expected=15.6682
# Month=6, Predicted=15.9011, Expected=15.8360
# Month=7, Predicted=15.8264, Expected=15.7178
# Month=8, Predicted=15.5438, Expected=15.3110
# Month=9, Predicted=15.0100, Expected=14.7667
# Month=10, Predicted=14.4170, Expected=13.5419
# Month=11, Predicted=12.8970, Expected=13.5869
# Month=12, Predicted=14.0922, Expected=14.5144
# Month=13, Predicted=15.3120, Expected=14.3947
# Month=14, Predicted=14.3328, Expected=14.4996
# Month=15, Predicted=14.4546, Expected=14.7474
# Month=16, Predicted=14.8737, Expected=15.8019
# Month=17, Predicted=16.2569, Expected=16.5221
# Month=18, Predicted=16.8450, Expected=16.5417
# Month=19, Predicted=16.4658, Expected=16.7210
# Month=20, Predicted=16.7247, Expected=16.4288
# Month=21, Predicted=16.2091, Expected=15.7719
# Month=22, Predicted=15.3395, Expected=15.2959
# Month=23, Predicted=15.0480, Expected=15.1318
# Month=24, Predicted=15.1736, Expected=15.5377
# Month=25, Predicted=15.9496, Expected=15.8371
# Month=26, Predicted=15.9593, Expected=16.3719
# Month=27, Predicted=16.5970, Expected=16.3365
# Month=28, Predicted=16.2446, Expected=16.8969
# Month=29, Predicted=17.1969, Expected=17.0022
# Month=30, Predicted=16.9994, Expected=17.4155
# Month=31, Predicted=17.5803, Expected=17.5332
# Month=32, Predicted=17.5233, Expected=17.2849
# Month=33, Predicted=17.0558, Expected=16.6063
# Month=34, Predicted=16.1727, Expected=15.8228
# Month=35, Predicted=15.3557, Expected=15.4543
# Month=36, Predicted=15.4268, Expected=15.6138
# Month=37, Predicted=15.9695, Expected=15.6954
# Month=38, Predicted=15.7224, Expected=16.7627
# Month=39, Predicted=17.2321, Expected=16.4941
# Month=40, Predicted=16.4189, Expected=17.7345
# Month=41, Predicted=18.1344, Expected=18.6944
# Month=42, Predicted=19.1892, Expected=19.1228
# Month=43, Predicted=19.2517, Expected=19.5704
# Month=44, Predicted=19.6918, Expected=19.2258
# Month=45, Predicted=18.9983, Expected=18.2178
# Month=46, Predicted=17.6290, Expected=17.2135
# Month=47, Predicted=16.7362, Expected=16.6554
# Month=48, Predicted=16.6733, Expected=16.8225
# Month=49, Predicted=17.3880, Expected=15.7773
# Month=50, Predicted=15.3427, Expected=15.7224
# Month=51, Predicted=16.0997, Expected=15.9967
# Month=52, Predicted=16.3694, Expected=17.0162
# Month=53, Predicted=17.4852, Expected=17.5568
# Month=54, Predicted=17.7791, Expected=17.8404
# Month=55, Predicted=17.8694, Expected=17.8664
# Month=56, Predicted=17.7755, Expected=17.5659
# Month=57, Predicted=17.3153, Expected=17.0753
# Month=58, Predicted=16.7395, Expected=16.6502
# Month=59, Predicted=16.4108, Expected=16.4285
# Month=60, Predicted=16.3679, Expected=16.5878
# Run 7 — RMSE: 0.489910, MSE: 0.240012, NMSE: 0.0019665850
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2556, Expected=13.7084
# Month=2, Predicted=14.0852, Expected=13.8026
# Month=3, Predicted=13.7338, Expected=14.3883
# Month=4, Predicted=14.7063, Expected=15.0615
# Month=5, Predicted=15.3490, Expected=15.6682
# Month=6, Predicted=15.8672, Expected=15.8360
# Month=7, Predicted=15.7680, Expected=15.7178
# Month=8, Predicted=15.4931, Expected=15.3110
# Month=9, Predicted=14.9984, Expected=14.7667
# Month=10, Predicted=14.4545, Expected=13.5419
# Month=11, Predicted=12.9847, Expected=13.5869
# Month=12, Predicted=14.3660, Expected=14.5144
# Month=13, Predicted=15.2437, Expected=14.3947
# Month=14, Predicted=14.3745, Expected=14.4996
# Month=15, Predicted=14.4896, Expected=14.7474
# Month=16, Predicted=14.8326, Expected=15.8019
# Month=17, Predicted=16.3102, Expected=16.5221
# Month=18, Predicted=16.8048, Expected=16.5417
# Month=19, Predicted=16.4492, Expected=16.7210
# Month=20, Predicted=16.7305, Expected=16.4288
# Month=21, Predicted=16.1521, Expected=15.7719
# Month=22, Predicted=15.3726, Expected=15.2959
# Month=23, Predicted=15.0994, Expected=15.1318
# Month=24, Predicted=15.1331, Expected=15.5377
# Month=25, Predicted=15.9310, Expected=15.8371
# Month=26, Predicted=15.8834, Expected=16.3719
# Month=27, Predicted=16.5934, Expected=16.3365
# Month=28, Predicted=16.2102, Expected=16.8969
# Month=29, Predicted=17.2564, Expected=17.0022
# Month=30, Predicted=16.9418, Expected=17.4155
# Month=31, Predicted=17.5946, Expected=17.5332
# Month=32, Predicted=17.4341, Expected=17.2849
# Month=33, Predicted=17.0037, Expected=16.6063
# Month=34, Predicted=16.1922, Expected=15.8228
# Month=35, Predicted=15.4556, Expected=15.4543
# Month=36, Predicted=15.4118, Expected=15.6138
# Month=37, Predicted=15.8987, Expected=15.6954
# Month=38, Predicted=15.6496, Expected=16.7627
# Month=39, Predicted=17.3007, Expected=16.4941
# Month=40, Predicted=16.5284, Expected=17.7345
# Month=41, Predicted=18.2862, Expected=18.6944
# Month=42, Predicted=19.1621, Expected=19.1228
# Month=43, Predicted=19.1814, Expected=19.5704
# Month=44, Predicted=19.6725, Expected=19.2258
# Month=45, Predicted=19.0323, Expected=18.2178
# Month=46, Predicted=17.6851, Expected=17.2135
# Month=47, Predicted=16.8179, Expected=16.6554
# Month=48, Predicted=16.5727, Expected=16.8225
# Month=49, Predicted=17.2723, Expected=15.7773
# Month=50, Predicted=15.5989, Expected=15.7224
# Month=51, Predicted=16.0889, Expected=15.9967
# Month=52, Predicted=16.2591, Expected=17.0162
# Month=53, Predicted=17.5322, Expected=17.5568
# Month=54, Predicted=17.7162, Expected=17.8404
# Month=55, Predicted=17.8041, Expected=17.8664
# Month=56, Predicted=17.7095, Expected=17.5659
# Month=57, Predicted=17.2773, Expected=17.0753
# Month=58, Predicted=16.7619, Expected=16.6502
# Month=59, Predicted=16.4370, Expected=16.4285
# Month=60, Predicted=16.3496, Expected=16.5878
# Run 8 — RMSE: 0.481016, MSE: 0.231376, NMSE: 0.0019328104
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.4349, Expected=13.7084
# Month=2, Predicted=14.3352, Expected=13.8026
# Month=3, Predicted=13.8326, Expected=14.3883
# Month=4, Predicted=14.8756, Expected=15.0615
# Month=5, Predicted=15.4410, Expected=15.6682
# Month=6, Predicted=15.8999, Expected=15.8360
# Month=7, Predicted=15.8370, Expected=15.7178
# Month=8, Predicted=15.5792, Expected=15.3110
# Month=9, Predicted=14.9585, Expected=14.7667
# Month=10, Predicted=14.3308, Expected=13.5419
# Month=11, Predicted=13.0361, Expected=13.5869
# Month=12, Predicted=14.5255, Expected=14.5144
# Month=13, Predicted=15.6242, Expected=14.3947
# Month=14, Predicted=14.3858, Expected=14.4996
# Month=15, Predicted=14.5412, Expected=14.7474
# Month=16, Predicted=15.0281, Expected=15.8019
# Month=17, Predicted=16.4951, Expected=16.5221
# Month=18, Predicted=16.7737, Expected=16.5417
# Month=19, Predicted=16.4786, Expected=16.7210
# Month=20, Predicted=16.8329, Expected=16.4288
# Month=21, Predicted=16.2605, Expected=15.7719
# Month=22, Predicted=15.2495, Expected=15.2959
# Month=23, Predicted=14.9654, Expected=15.1318
# Month=24, Predicted=15.1669, Expected=15.5377
# Month=25, Predicted=16.1945, Expected=15.8371
# Month=26, Predicted=16.0788, Expected=16.3719
# Month=27, Predicted=16.7408, Expected=16.3365
# Month=28, Predicted=16.2926, Expected=16.8969
# Month=29, Predicted=17.4372, Expected=17.0022
# Month=30, Predicted=17.0599, Expected=17.4155
# Month=31, Predicted=17.7490, Expected=17.5332
# Month=32, Predicted=17.5999, Expected=17.2849
# Month=33, Predicted=17.0669, Expected=16.6063
# Month=34, Predicted=16.0980, Expected=15.8228
# Month=35, Predicted=15.2792, Expected=15.4543
# Month=36, Predicted=15.3783, Expected=15.6138
# Month=37, Predicted=16.1150, Expected=15.6954
# Month=38, Predicted=15.8561, Expected=16.7627
# Month=39, Predicted=17.5158, Expected=16.4941
# Month=40, Predicted=16.5469, Expected=17.7345
# Month=41, Predicted=18.4548, Expected=18.6944
# Month=42, Predicted=19.1510, Expected=19.1228
# Month=43, Predicted=19.1833, Expected=19.5704
# Month=44, Predicted=19.7727, Expected=19.2258
# Month=45, Predicted=19.0624, Expected=18.2178
# Month=46, Predicted=17.5675, Expected=17.2135
# Month=47, Predicted=16.7650, Expected=16.6554
# Month=48, Predicted=16.5833, Expected=16.8225
# Month=49, Predicted=17.5134, Expected=15.7773
# Month=50, Predicted=15.5806, Expected=15.7224
# Month=51, Predicted=16.0785, Expected=15.9967
# Month=52, Predicted=16.5852, Expected=17.0162
# Month=53, Predicted=17.7312, Expected=17.5568
# Month=54, Predicted=17.7053, Expected=17.8404
# Month=55, Predicted=17.9029, Expected=17.8664
# Month=56, Predicted=17.8345, Expected=17.5659
# Month=57, Predicted=17.3094, Expected=17.0753
# Month=58, Predicted=16.6525, Expected=16.6502
# Month=59, Predicted=16.3353, Expected=16.4285
# Month=60, Predicted=16.3417, Expected=16.5878
# Run 9 — RMSE: 0.492822, MSE: 0.242873, NMSE: 0.0020217065
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.3319, Expected=13.7084
# Month=2, Predicted=14.0978, Expected=13.8026
# Month=3, Predicted=13.8519, Expected=14.3883
# Month=4, Predicted=14.7281, Expected=15.0615
# Month=5, Predicted=15.4032, Expected=15.6682
# Month=6, Predicted=15.9588, Expected=15.8360
# Month=7, Predicted=15.9015, Expected=15.7178
# Month=8, Predicted=15.6341, Expected=15.3110
# Month=9, Predicted=15.0059, Expected=14.7667
# Month=10, Predicted=14.3917, Expected=13.5419
# Month=11, Predicted=12.6198, Expected=13.5869
# Month=12, Predicted=13.8720, Expected=14.5144
# Month=13, Predicted=15.1323, Expected=14.3947
# Month=14, Predicted=14.3413, Expected=14.4996
# Month=15, Predicted=14.5765, Expected=14.7474
# Month=16, Predicted=14.9561, Expected=15.8019
# Month=17, Predicted=16.2440, Expected=16.5221
# Month=18, Predicted=16.8368, Expected=16.5417
# Month=19, Predicted=16.5170, Expected=16.7210
# Month=20, Predicted=16.8535, Expected=16.4288
# Month=21, Predicted=16.2677, Expected=15.7719
# Month=22, Predicted=15.2652, Expected=15.2959
# Month=23, Predicted=15.0224, Expected=15.1318
# Month=24, Predicted=15.1604, Expected=15.5377
# Month=25, Predicted=15.9403, Expected=15.8371
# Month=26, Predicted=16.0323, Expected=16.3719
# Month=27, Predicted=16.6622, Expected=16.3365
# Month=28, Predicted=16.3014, Expected=16.8969
# Month=29, Predicted=17.2684, Expected=17.0022
# Month=30, Predicted=17.0682, Expected=17.4155
# Month=31, Predicted=17.6716, Expected=17.5332
# Month=32, Predicted=17.6034, Expected=17.2849
# Month=33, Predicted=17.1169, Expected=16.6063
# Month=34, Predicted=16.0836, Expected=15.8228
# Month=35, Predicted=15.2727, Expected=15.4543
# Month=36, Predicted=15.3450, Expected=15.6138
# Month=37, Predicted=15.9129, Expected=15.6954
# Month=38, Predicted=15.8142, Expected=16.7627
# Month=39, Predicted=17.2207, Expected=16.4941
# Month=40, Predicted=16.3739, Expected=17.7345
# Month=41, Predicted=18.1728, Expected=18.6944
# Month=42, Predicted=19.1055, Expected=19.1228
# Month=43, Predicted=19.2880, Expected=19.5704
# Month=44, Predicted=19.7870, Expected=19.2258
# Month=45, Predicted=19.0029, Expected=18.2178
# Month=46, Predicted=17.3970, Expected=17.2135
# Month=47, Predicted=16.5011, Expected=16.6554
# Month=48, Predicted=16.4588, Expected=16.8225
# Month=49, Predicted=17.1915, Expected=15.7773
# Month=50, Predicted=15.1197, Expected=15.7224
# Month=51, Predicted=15.8086, Expected=15.9967
# Month=52, Predicted=16.3771, Expected=17.0162
# Month=53, Predicted=17.4648, Expected=17.5568
# Month=54, Predicted=17.7989, Expected=17.8404
# Month=55, Predicted=17.9643, Expected=17.8664
# Month=56, Predicted=17.8668, Expected=17.5659
# Month=57, Predicted=17.3476, Expected=17.0753
# Month=58, Predicted=16.7244, Expected=16.6502
# Month=59, Predicted=16.4065, Expected=16.4285
# Month=60, Predicted=16.3785, Expected=16.5878
# Run 10 — RMSE: 0.487381, MSE: 0.237541, NMSE: 0.0018888989
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.0932, Expected=13.7084
# Month=2, Predicted=13.6764, Expected=13.8026
# Month=3, Predicted=13.7706, Expected=14.3883
# Month=4, Predicted=14.3563, Expected=15.0615
# Month=5, Predicted=15.0295, Expected=15.6682
# Month=6, Predicted=15.6361, Expected=15.8360
# Month=7, Predicted=15.8040, Expected=15.7178
# Month=8, Predicted=15.6858, Expected=15.3110
# Month=9, Predicted=15.2789, Expected=14.7667
# Month=10, Predicted=14.7347, Expected=13.5419
# Month=11, Predicted=13.5099, Expected=13.5869
# Month=12, Predicted=13.5548, Expected=14.5144
# Month=13, Predicted=14.4824, Expected=14.3947
# Month=14, Predicted=14.3627, Expected=14.4996
# Month=15, Predicted=14.4675, Expected=14.7474
# Month=16, Predicted=14.7154, Expected=15.8019
# Month=17, Predicted=15.7698, Expected=16.5221
# Month=18, Predicted=16.4901, Expected=16.5417
# Month=19, Predicted=16.5096, Expected=16.7210
# Month=20, Predicted=16.6889, Expected=16.4288
# Month=21, Predicted=16.3967, Expected=15.7719
# Month=22, Predicted=15.7399, Expected=15.2959
# Month=23, Predicted=15.2638, Expected=15.1318
# Month=24, Predicted=15.0997, Expected=15.5377
# Month=25, Predicted=15.5057, Expected=15.8371
# Month=26, Predicted=15.8051, Expected=16.3719
# Month=27, Predicted=16.3399, Expected=16.3365
# Month=28, Predicted=16.3045, Expected=16.8969
# Month=29, Predicted=16.8648, Expected=17.0022
# Month=30, Predicted=16.9702, Expected=17.4155
# Month=31, Predicted=17.3834, Expected=17.5332
# Month=32, Predicted=17.5012, Expected=17.2849
# Month=33, Predicted=17.2528, Expected=16.6063
# Month=34, Predicted=16.5743, Expected=15.8228
# Month=35, Predicted=15.7908, Expected=15.4543
# Month=36, Predicted=15.4223, Expected=15.6138
# Month=37, Predicted=15.5818, Expected=15.6954
# Month=38, Predicted=15.6633, Expected=16.7627
# Month=39, Predicted=16.7307, Expected=16.4941
# Month=40, Predicted=16.4621, Expected=17.7345
# Month=41, Predicted=17.7025, Expected=18.6944
# Month=42, Predicted=18.6624, Expected=19.1228
# Month=43, Predicted=19.0908, Expected=19.5704
# Month=44, Predicted=19.5383, Expected=19.2258
# Month=45, Predicted=19.1938, Expected=18.2178
# Month=46, Predicted=18.1858, Expected=17.2135
# Month=47, Predicted=17.1815, Expected=16.6554
# Month=48, Predicted=16.6234, Expected=16.8225
# Month=49, Predicted=16.7904, Expected=15.7773
# Month=50, Predicted=15.7453, Expected=15.7224
# Month=51, Predicted=15.6904, Expected=15.9967
# Month=52, Predicted=15.9647, Expected=17.0162
# Month=53, Predicted=16.9842, Expected=17.5568
# Month=54, Predicted=17.5248, Expected=17.8404
# Month=55, Predicted=17.8083, Expected=17.8664
# Month=56, Predicted=17.8344, Expected=17.5659
# Month=57, Predicted=17.5339, Expected=17.0753
# Month=58, Predicted=17.0433, Expected=16.6502
# Month=59, Predicted=16.6181, Expected=16.4285
# Month=60, Predicted=16.3965, Expected=16.5878
# Run 11 — RMSE: 0.566362, MSE: 0.320766, NMSE: 0.0026623046
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2989, Expected=13.7084
# Month=2, Predicted=14.1455, Expected=13.8026
# Month=3, Predicted=13.8373, Expected=14.3883
# Month=4, Predicted=14.7759, Expected=15.0615
# Month=5, Predicted=15.4288, Expected=15.6682
# Month=6, Predicted=15.9538, Expected=15.8360
# Month=7, Predicted=15.8976, Expected=15.7178
# Month=8, Predicted=15.5906, Expected=15.3110
# Month=9, Predicted=15.0152, Expected=14.7667
# Month=10, Predicted=14.4027, Expected=13.5419
# Month=11, Predicted=12.8809, Expected=13.5869
# Month=12, Predicted=14.1664, Expected=14.5144
# Month=13, Predicted=15.3697, Expected=14.3947
# Month=14, Predicted=14.4134, Expected=14.4996
# Month=15, Predicted=14.5498, Expected=14.7474
# Month=16, Predicted=14.9171, Expected=15.8019
# Month=17, Predicted=16.3568, Expected=16.5221
# Month=18, Predicted=16.7964, Expected=16.5417
# Month=19, Predicted=16.5365, Expected=16.7210
# Month=20, Predicted=16.8104, Expected=16.4288
# Month=21, Predicted=16.2176, Expected=15.7719
# Month=22, Predicted=15.3274, Expected=15.2959
# Month=23, Predicted=15.0227, Expected=15.1318
# Month=24, Predicted=15.1335, Expected=15.5377
# Month=25, Predicted=15.9743, Expected=15.8371
# Month=26, Predicted=16.0184, Expected=16.3719
# Month=27, Predicted=16.6902, Expected=16.3365
# Month=28, Predicted=16.2861, Expected=16.8969
# Month=29, Predicted=17.3123, Expected=17.0022
# Month=30, Predicted=17.0503, Expected=17.4155
# Month=31, Predicted=17.6767, Expected=17.5332
# Month=32, Predicted=17.5757, Expected=17.2849
# Month=33, Predicted=17.0818, Expected=16.6063
# Month=34, Predicted=16.1530, Expected=15.8228
# Month=35, Predicted=15.3260, Expected=15.4543
# Month=36, Predicted=15.3598, Expected=15.6138
# Month=37, Predicted=15.9428, Expected=15.6954
# Month=38, Predicted=15.7503, Expected=16.7627
# Month=39, Predicted=17.3349, Expected=16.4941
# Month=40, Predicted=16.5333, Expected=17.7345
# Month=41, Predicted=18.3380, Expected=18.6944
# Month=42, Predicted=19.0895, Expected=19.1228
# Month=43, Predicted=19.2449, Expected=19.5704
# Month=44, Predicted=19.8036, Expected=19.2258
# Month=45, Predicted=19.0625, Expected=18.2178
# Month=46, Predicted=17.6202, Expected=17.2135
# Month=47, Predicted=16.7390, Expected=16.6554
# Month=48, Predicted=16.5138, Expected=16.8225
# Month=49, Predicted=17.3350, Expected=15.7773
# Month=50, Predicted=15.5052, Expected=15.7224
# Month=51, Predicted=16.1303, Expected=15.9967
# Month=52, Predicted=16.3671, Expected=17.0162
# Month=53, Predicted=17.5786, Expected=17.5568
# Month=54, Predicted=17.7414, Expected=17.8404
# Month=55, Predicted=17.9649, Expected=17.8664
# Month=56, Predicted=17.8326, Expected=17.5659
# Month=57, Predicted=17.3325, Expected=17.0753
# Month=58, Predicted=16.7348, Expected=16.6502
# Month=59, Predicted=16.3899, Expected=16.4285
# Month=60, Predicted=16.3418, Expected=16.5878
# Run 12 — RMSE: 0.483355, MSE: 0.233632, NMSE: 0.0019031466
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.4892, Expected=13.7084
# Month=2, Predicted=14.2664, Expected=13.8026
# Month=3, Predicted=13.8390, Expected=14.3883
# Month=4, Predicted=14.7493, Expected=15.0615
# Month=5, Predicted=15.4143, Expected=15.6682
# Month=6, Predicted=15.8830, Expected=15.8360
# Month=7, Predicted=15.8400, Expected=15.7178
# Month=8, Predicted=15.5850, Expected=15.3110
# Month=9, Predicted=14.9452, Expected=14.7667
# Month=10, Predicted=14.3139, Expected=13.5419
# Month=11, Predicted=12.7188, Expected=13.5869
# Month=12, Predicted=13.6907, Expected=14.5144
# Month=13, Predicted=15.3424, Expected=14.3947
# Month=14, Predicted=14.3647, Expected=14.4996
# Month=15, Predicted=14.4553, Expected=14.7474
# Month=16, Predicted=15.0569, Expected=15.8019
# Month=17, Predicted=16.3373, Expected=16.5221
# Month=18, Predicted=16.7803, Expected=16.5417
# Month=19, Predicted=16.4575, Expected=16.7210
# Month=20, Predicted=16.7840, Expected=16.4288
# Month=21, Predicted=16.2620, Expected=15.7719
# Month=22, Predicted=15.1818, Expected=15.2959
# Month=23, Predicted=14.9734, Expected=15.1318
# Month=24, Predicted=15.2765, Expected=15.5377
# Month=25, Predicted=16.1181, Expected=15.8371
# Month=26, Predicted=16.0867, Expected=16.3719
# Month=27, Predicted=16.6599, Expected=16.3365
# Month=28, Predicted=16.2935, Expected=16.8969
# Month=29, Predicted=17.2930, Expected=17.0022
# Month=30, Predicted=17.0765, Expected=17.4155
# Month=31, Predicted=17.6827, Expected=17.5332
# Month=32, Predicted=17.6151, Expected=17.2849
# Month=33, Predicted=17.0633, Expected=16.6063
# Month=34, Predicted=16.0291, Expected=15.8228
# Month=35, Predicted=15.1920, Expected=15.4543
# Month=36, Predicted=15.4309, Expected=15.6138
# Month=37, Predicted=16.0541, Expected=15.6954
# Month=38, Predicted=15.9377, Expected=16.7627
# Month=39, Predicted=17.3343, Expected=16.4941
# Month=40, Predicted=16.4585, Expected=17.7345
# Month=41, Predicted=18.1310, Expected=18.6944
# Month=42, Predicted=19.1497, Expected=19.1228
# Month=43, Predicted=19.1825, Expected=19.5704
# Month=44, Predicted=19.7278, Expected=19.2258
# Month=45, Predicted=19.0702, Expected=18.2178
# Month=46, Predicted=17.3893, Expected=17.2135
# Month=47, Predicted=16.4242, Expected=16.6554
# Month=48, Predicted=16.5254, Expected=16.8225
# Month=49, Predicted=17.2521, Expected=15.7773
# Month=50, Predicted=15.3770, Expected=15.7224
# Month=51, Predicted=15.6820, Expected=15.9967
# Month=52, Predicted=16.6749, Expected=17.0162
# Month=53, Predicted=17.5907, Expected=17.5568
# Month=54, Predicted=17.7251, Expected=17.8404
# Month=55, Predicted=17.8944, Expected=17.8664
# Month=56, Predicted=17.8666, Expected=17.5659
# Month=57, Predicted=17.2985, Expected=17.0753
# Month=58, Predicted=16.6399, Expected=16.6502
# Month=59, Predicted=16.3619, Expected=16.4285
# Month=60, Predicted=16.4124, Expected=16.5878
# Run 13 — RMSE: 0.480375, MSE: 0.230761, NMSE: 0.0018682489
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.3504, Expected=13.7084
# Month=2, Predicted=14.1867, Expected=13.8026
# Month=3, Predicted=13.8734, Expected=14.3883
# Month=4, Predicted=14.7343, Expected=15.0615
# Month=5, Predicted=15.4369, Expected=15.6682
# Month=6, Predicted=15.9423, Expected=15.8360
# Month=7, Predicted=15.9087, Expected=15.7178
# Month=8, Predicted=15.5647, Expected=15.3110
# Month=9, Predicted=14.9838, Expected=14.7667
# Month=10, Predicted=14.3650, Expected=13.5419
# Month=11, Predicted=12.8471, Expected=13.5869
# Month=12, Predicted=13.9907, Expected=14.5144
# Month=13, Predicted=15.6358, Expected=14.3947
# Month=14, Predicted=14.4067, Expected=14.4996
# Month=15, Predicted=14.4810, Expected=14.7474
# Month=16, Predicted=14.9268, Expected=15.8019
# Month=17, Predicted=16.3706, Expected=16.5221
# Month=18, Predicted=16.7999, Expected=16.5417
# Month=19, Predicted=16.5507, Expected=16.7210
# Month=20, Predicted=16.7533, Expected=16.4288
# Month=21, Predicted=16.2303, Expected=15.7719
# Month=22, Predicted=15.2922, Expected=15.2959
# Month=23, Predicted=15.0012, Expected=15.1318
# Month=24, Predicted=15.1888, Expected=15.5377
# Month=25, Predicted=16.0474, Expected=15.8371
# Month=26, Predicted=16.0522, Expected=16.3719
# Month=27, Predicted=16.6746, Expected=16.3365
# Month=28, Predicted=16.3197, Expected=16.8969
# Month=29, Predicted=17.2623, Expected=17.0022
# Month=30, Predicted=17.0915, Expected=17.4155
# Month=31, Predicted=17.6346, Expected=17.5332
# Month=32, Predicted=17.5904, Expected=17.2849
# Month=33, Predicted=17.0639, Expected=16.6063
# Month=34, Predicted=16.1295, Expected=15.8228
# Month=35, Predicted=15.2947, Expected=15.4543
# Month=36, Predicted=15.4196, Expected=15.6138
# Month=37, Predicted=16.0622, Expected=15.6954
# Month=38, Predicted=15.7840, Expected=16.7627
# Month=39, Predicted=17.3290, Expected=16.4941
# Month=40, Predicted=16.5003, Expected=17.7345
# Month=41, Predicted=18.2655, Expected=18.6944
# Month=42, Predicted=19.1110, Expected=19.1228
# Month=43, Predicted=19.2169, Expected=19.5704
# Month=44, Predicted=19.7840, Expected=19.2258
# Month=45, Predicted=19.0562, Expected=18.2178
# Month=46, Predicted=17.5929, Expected=17.2135
# Month=47, Predicted=16.5917, Expected=16.6554
# Month=48, Predicted=16.5770, Expected=16.8225
# Month=49, Predicted=17.4092, Expected=15.7773
# Month=50, Predicted=15.3726, Expected=15.7224
# Month=51, Predicted=15.8201, Expected=15.9967
# Month=52, Predicted=16.5385, Expected=17.0162
# Month=53, Predicted=17.6138, Expected=17.5568
# Month=54, Predicted=17.7536, Expected=17.8404
# Month=55, Predicted=17.9633, Expected=17.8664
# Month=56, Predicted=17.8163, Expected=17.5659
# Month=57, Predicted=17.3090, Expected=17.0753
# Month=58, Predicted=16.6944, Expected=16.6502
# Month=59, Predicted=16.3689, Expected=16.4285
# Month=60, Predicted=16.3599, Expected=16.5878
# Run 14 — RMSE: 0.493948, MSE: 0.243984, NMSE: 0.0019862287
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.3286, Expected=13.7084
# Month=2, Predicted=14.1583, Expected=13.8026
# Month=3, Predicted=13.7656, Expected=14.3883
# Month=4, Predicted=14.7780, Expected=15.0615
# Month=5, Predicted=15.3934, Expected=15.6682
# Month=6, Predicted=15.9243, Expected=15.8360
# Month=7, Predicted=15.8228, Expected=15.7178
# Month=8, Predicted=15.5362, Expected=15.3110
# Month=9, Predicted=14.9880, Expected=14.7667
# Month=10, Predicted=14.3852, Expected=13.5419
# Month=11, Predicted=12.9615, Expected=13.5869
# Month=12, Predicted=14.7496, Expected=14.5144
# Month=13, Predicted=15.4277, Expected=14.3947
# Month=14, Predicted=14.4167, Expected=14.4996
# Month=15, Predicted=14.5234, Expected=14.7474
# Month=16, Predicted=14.8793, Expected=15.8019
# Month=17, Predicted=16.3671, Expected=16.5221
# Month=18, Predicted=16.8349, Expected=16.5417
# Month=19, Predicted=16.4969, Expected=16.7210
# Month=20, Predicted=16.7693, Expected=16.4288
# Month=21, Predicted=16.1925, Expected=15.7719
# Month=22, Predicted=15.3305, Expected=15.2959
# Month=23, Predicted=15.0355, Expected=15.1318
# Month=24, Predicted=15.1834, Expected=15.5377
# Month=25, Predicted=16.0446, Expected=15.8371
# Month=26, Predicted=15.9412, Expected=16.3719
# Month=27, Predicted=16.6485, Expected=16.3365
# Month=28, Predicted=16.2396, Expected=16.8969
# Month=29, Predicted=17.3372, Expected=17.0022
# Month=30, Predicted=16.9734, Expected=17.4155
# Month=31, Predicted=17.6526, Expected=17.5332
# Month=32, Predicted=17.4977, Expected=17.2849
# Month=33, Predicted=17.0441, Expected=16.6063
# Month=34, Predicted=16.1685, Expected=15.8228
# Month=35, Predicted=15.3289, Expected=15.4543
# Month=36, Predicted=15.4494, Expected=15.6138
# Month=37, Predicted=16.0433, Expected=15.6954
# Month=38, Predicted=15.6965, Expected=16.7627
# Month=39, Predicted=17.3730, Expected=16.4941
# Month=40, Predicted=16.6204, Expected=17.7345
# Month=41, Predicted=18.4281, Expected=18.6944
# Month=42, Predicted=19.1464, Expected=19.1228
# Month=43, Predicted=19.2613, Expected=19.5704
# Month=44, Predicted=19.7392, Expected=19.2258
# Month=45, Predicted=19.0451, Expected=18.2178
# Month=46, Predicted=17.6946, Expected=17.2135
# Month=47, Predicted=16.7415, Expected=16.6554
# Month=48, Predicted=16.6751, Expected=16.8225
# Month=49, Predicted=17.5065, Expected=15.7773
# Month=50, Predicted=15.5264, Expected=15.7224
# Month=51, Predicted=16.2847, Expected=15.9967
# Month=52, Predicted=16.3985, Expected=17.0162
# Month=53, Predicted=17.5891, Expected=17.5568
# Month=54, Predicted=17.7622, Expected=17.8404
# Month=55, Predicted=17.8857, Expected=17.8664
# Month=56, Predicted=17.7651, Expected=17.5659
# Month=57, Predicted=17.2973, Expected=17.0753
# Month=58, Predicted=16.7116, Expected=16.6502
# Month=59, Predicted=16.3839, Expected=16.4285
# Month=60, Predicted=16.3590, Expected=16.5878
# Run 15 — RMSE: 0.490375, MSE: 0.240468, NMSE: 0.0019952421
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.3312, Expected=13.7084
# Month=2, Predicted=14.1713, Expected=13.8026
# Month=3, Predicted=13.7779, Expected=14.3883
# Month=4, Predicted=14.7449, Expected=15.0615
# Month=5, Predicted=15.4328, Expected=15.6682
# Month=6, Predicted=15.9432, Expected=15.8360
# Month=7, Predicted=15.8263, Expected=15.7178
# Month=8, Predicted=15.5341, Expected=15.3110
# Month=9, Predicted=14.9861, Expected=14.7667
# Month=10, Predicted=14.3967, Expected=13.5419
# Month=11, Predicted=12.9782, Expected=13.5869
# Month=12, Predicted=14.4876, Expected=14.5144
# Month=13, Predicted=15.4693, Expected=14.3947
# Month=14, Predicted=14.3560, Expected=14.4996
# Month=15, Predicted=14.4934, Expected=14.7474
# Month=16, Predicted=14.9031, Expected=15.8019
# Month=17, Predicted=16.3575, Expected=16.5221
# Month=18, Predicted=16.8386, Expected=16.5417
# Month=19, Predicted=16.4802, Expected=16.7210
# Month=20, Predicted=16.7585, Expected=16.4288
# Month=21, Predicted=16.1799, Expected=15.7719
# Month=22, Predicted=15.3409, Expected=15.2959
# Month=23, Predicted=15.0341, Expected=15.1318
# Month=24, Predicted=15.1694, Expected=15.5377
# Month=25, Predicted=16.0267, Expected=15.8371
# Month=26, Predicted=15.9917, Expected=16.3719
# Month=27, Predicted=16.6562, Expected=16.3365
# Month=28, Predicted=16.2262, Expected=16.8969
# Month=29, Predicted=17.2819, Expected=17.0022
# Month=30, Predicted=16.9940, Expected=17.4155
# Month=31, Predicted=17.6388, Expected=17.5332
# Month=32, Predicted=17.5246, Expected=17.2849
# Month=33, Predicted=17.0351, Expected=16.6063
# Month=34, Predicted=16.1825, Expected=15.8228
# Month=35, Predicted=15.3442, Expected=15.4543
# Month=36, Predicted=15.4093, Expected=15.6138
# Month=37, Predicted=16.0224, Expected=15.6954
# Month=38, Predicted=15.7412, Expected=16.7627
# Month=39, Predicted=17.3345, Expected=16.4941
# Month=40, Predicted=16.4462, Expected=17.7345
# Month=41, Predicted=18.2679, Expected=18.6944
# Month=42, Predicted=19.1206, Expected=19.1228
# Month=43, Predicted=19.2272, Expected=19.5704
# Month=44, Predicted=19.7472, Expected=19.2258
# Month=45, Predicted=19.0255, Expected=18.2178
# Month=46, Predicted=17.7124, Expected=17.2135
# Month=47, Predicted=16.7018, Expected=16.6554
# Month=48, Predicted=16.6162, Expected=16.8225
# Month=49, Predicted=17.4486, Expected=15.7773
# Month=50, Predicted=15.4002, Expected=15.7224
# Month=51, Predicted=16.0745, Expected=15.9967
# Month=52, Predicted=16.4419, Expected=17.0162
# Month=53, Predicted=17.5997, Expected=17.5568
# Month=54, Predicted=17.7729, Expected=17.8404
# Month=55, Predicted=17.8966, Expected=17.8664
# Month=56, Predicted=17.7728, Expected=17.5659
# Month=57, Predicted=17.2926, Expected=17.0753
# Month=58, Predicted=16.7183, Expected=16.6502
# Month=59, Predicted=16.3936, Expected=16.4285
# Month=60, Predicted=16.3585, Expected=16.5878
# Run 16 — RMSE: 0.491922, MSE: 0.241987, NMSE: 0.0020135164
#
# ===== RUN 17/30 =====

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
