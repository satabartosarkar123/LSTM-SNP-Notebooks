# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    496
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 505 (1.97 KB)
# Trainable params: 505 (1.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        rnn_layer = model.layers[1]
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Monthly Lake Erie Levels (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Hybrid (Feature Aug + Gate) — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Hybrid (Feature Aug + Gate) — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.010052)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.76799303 14.64761015 15.09151064 16.39130966 16.92364626]
# Supervised data shape: (599, 3)
# Train: (539, 3), Test: (60, 3)
# X_train shape: (539, 1, 2), y_train shape: (539,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2982, Expected=13.7084
# Month=2, Predicted=14.1492, Expected=13.8026
# Month=3, Predicted=13.8925, Expected=14.3883
# Month=4, Predicted=14.7767, Expected=15.0615
# Month=5, Predicted=15.4265, Expected=15.6682
# Month=6, Predicted=15.9551, Expected=15.8360
# Month=7, Predicted=15.9482, Expected=15.7178
# Month=8, Predicted=15.6148, Expected=15.3110
# Month=9, Predicted=15.0236, Expected=14.7667
# Month=10, Predicted=14.3865, Expected=13.5419
# Month=11, Predicted=12.8244, Expected=13.5869
# Month=12, Predicted=14.0076, Expected=14.5144
# Month=13, Predicted=15.3598, Expected=14.3947
# Month=14, Predicted=14.3811, Expected=14.4996
# Month=15, Predicted=14.5389, Expected=14.7474
# Month=16, Predicted=14.9198, Expected=15.8019
# Month=17, Predicted=16.3612, Expected=16.5221
# Month=18, Predicted=16.7621, Expected=16.5417
# Month=19, Predicted=16.5791, Expected=16.7210
# Month=20, Predicted=16.8076, Expected=16.4288
# Month=21, Predicted=16.2546, Expected=15.7719
# Month=22, Predicted=15.3289, Expected=15.2959
# Month=23, Predicted=14.9929, Expected=15.1318
# Month=24, Predicted=15.1265, Expected=15.5377
# Month=25, Predicted=15.9843, Expected=15.8371
# Month=26, Predicted=16.0383, Expected=16.3719
# Month=27, Predicted=16.6989, Expected=16.3365
# Month=28, Predicted=16.3489, Expected=16.8969
# Month=29, Predicted=17.3114, Expected=17.0022
# Month=30, Predicted=17.0998, Expected=17.4155
# Month=31, Predicted=17.6776, Expected=17.5332
# Month=32, Predicted=17.6091, Expected=17.2849
# Month=33, Predicted=17.1090, Expected=16.6063
# Month=34, Predicted=16.1627, Expected=15.8228
# Month=35, Predicted=15.2903, Expected=15.4543
# Month=36, Predicted=15.3495, Expected=15.6138
# Month=37, Predicted=15.9579, Expected=15.6954
# Month=38, Predicted=15.7614, Expected=16.7627
# Month=39, Predicted=17.3396, Expected=16.4941
# Month=40, Predicted=16.4401, Expected=17.7345
# Month=41, Predicted=18.3512, Expected=18.6944
# Month=42, Predicted=19.0113, Expected=19.1228
# Month=43, Predicted=19.2487, Expected=19.5704
# Month=44, Predicted=19.8246, Expected=19.2258
# Month=45, Predicted=19.0840, Expected=18.2178
# Month=46, Predicted=17.6065, Expected=17.2135
# Month=47, Predicted=16.6428, Expected=16.6554
# Month=48, Predicted=16.5074, Expected=16.8225
# Month=49, Predicted=17.3817, Expected=15.7773
# Month=50, Predicted=15.3437, Expected=15.7224
# Month=51, Predicted=16.1597, Expected=15.9967
# Month=52, Predicted=16.3652, Expected=17.0162
# Month=53, Predicted=17.5838, Expected=17.5568
# Month=54, Predicted=17.7282, Expected=17.8404
# Month=55, Predicted=18.0059, Expected=17.8664
# Month=56, Predicted=17.8605, Expected=17.5659
# Month=57, Predicted=17.3518, Expected=17.0753
# Month=58, Predicted=16.7270, Expected=16.6502
# Month=59, Predicted=16.3676, Expected=16.4285
# Month=60, Predicted=16.3286, Expected=16.5878
# Run 1 — RMSE: 0.495445, MSE: 0.245465, NMSE: 0.0019730485
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.3607, Expected=13.7084
# Month=2, Predicted=14.2250, Expected=13.8026
# Month=3, Predicted=13.8440, Expected=14.3883
# Month=4, Predicted=14.8294, Expected=15.0615
# Month=5, Predicted=15.4324, Expected=15.6682
# Month=6, Predicted=15.9305, Expected=15.8360
# Month=7, Predicted=15.8934, Expected=15.7178
# Month=8, Predicted=15.5814, Expected=15.3110
# Month=9, Predicted=14.9966, Expected=14.7667
# Month=10, Predicted=14.3622, Expected=13.5419
# Month=11, Predicted=12.8971, Expected=13.5869
# Month=12, Predicted=14.5571, Expected=14.5144
# Month=13, Predicted=15.4799, Expected=14.3947
# Month=14, Predicted=14.4210, Expected=14.4996
# Month=15, Predicted=14.5560, Expected=14.7474
# Month=16, Predicted=14.9472, Expected=15.8019
# Month=17, Predicted=16.4329, Expected=16.5221
# Month=18, Predicted=16.8070, Expected=16.5417
# Month=19, Predicted=16.5527, Expected=16.7210
# Month=20, Predicted=16.8156, Expected=16.4288
# Month=21, Predicted=16.2322, Expected=15.7719
# Month=22, Predicted=15.3014, Expected=15.2959
# Month=23, Predicted=14.9998, Expected=15.1318
# Month=24, Predicted=15.1731, Expected=15.5377
# Month=25, Predicted=16.0788, Expected=15.8371
# Month=26, Predicted=16.0279, Expected=16.3719
# Month=27, Predicted=16.7175, Expected=16.3365
# Month=28, Predicted=16.3086, Expected=16.8969
# Month=29, Predicted=17.3792, Expected=17.0022
# Month=30, Predicted=17.0557, Expected=17.4155
# Month=31, Predicted=17.7082, Expected=17.5332
# Month=32, Predicted=17.5751, Expected=17.2849
# Month=33, Predicted=17.0789, Expected=16.6063
# Month=34, Predicted=16.1400, Expected=15.8228
# Month=35, Predicted=15.2961, Expected=15.4543
# Month=36, Predicted=15.3937, Expected=15.6138
# Month=37, Predicted=16.0447, Expected=15.6954
# Month=38, Predicted=15.7653, Expected=16.7627
# Month=39, Predicted=17.4250, Expected=16.4941
# Month=40, Predicted=16.5931, Expected=17.7345
# Month=41, Predicted=18.4389, Expected=18.6944
# Month=42, Predicted=19.0532, Expected=19.1228
# Month=43, Predicted=19.2633, Expected=19.5704
# Month=44, Predicted=19.8018, Expected=19.2258
# Month=45, Predicted=19.0887, Expected=18.2178
# Month=46, Predicted=17.6217, Expected=17.2135
# Month=47, Predicted=16.7117, Expected=16.6554
# Month=48, Predicted=16.5625, Expected=16.8225
# Month=49, Predicted=17.4566, Expected=15.7773
# Month=50, Predicted=15.4786, Expected=15.7224
# Month=51, Predicted=16.2151, Expected=15.9967
# Month=52, Predicted=16.4546, Expected=17.0162
# Month=53, Predicted=17.6572, Expected=17.5568
# Month=54, Predicted=17.7712, Expected=17.8404
# Month=55, Predicted=17.9517, Expected=17.8664
# Month=56, Predicted=17.8254, Expected=17.5659
# Month=57, Predicted=17.3238, Expected=17.0753
# Month=58, Predicted=16.7008, Expected=16.6502
# Month=59, Predicted=16.3638, Expected=16.4285
# Month=60, Predicted=16.3554, Expected=16.5878
# Run 2 — RMSE: 0.487768, MSE: 0.237918, NMSE: 0.0019562855
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.3224, Expected=13.7084
# Month=2, Predicted=14.1609, Expected=13.8026
# Month=3, Predicted=13.7705, Expected=14.3883
# Month=4, Predicted=14.6456, Expected=15.0615
# Month=5, Predicted=15.4556, Expected=15.6682
# Month=6, Predicted=15.9119, Expected=15.8360
# Month=7, Predicted=15.7658, Expected=15.7178
# Month=8, Predicted=15.4708, Expected=15.3110
# Month=9, Predicted=14.9887, Expected=14.7667
# Month=10, Predicted=14.4327, Expected=13.5419
# Month=11, Predicted=13.0675, Expected=13.5869
# Month=12, Predicted=14.3064, Expected=14.5144
# Month=13, Predicted=15.4478, Expected=14.3947
# Month=14, Predicted=14.3630, Expected=14.4996
# Month=15, Predicted=14.3811, Expected=14.7474
# Month=16, Predicted=14.8810, Expected=15.8019
# Month=17, Predicted=16.3441, Expected=16.5221
# Month=18, Predicted=16.8574, Expected=16.5417
# Month=19, Predicted=16.3947, Expected=16.7210
# Month=20, Predicted=16.6554, Expected=16.4288
# Month=21, Predicted=16.1829, Expected=15.7719
# Month=22, Predicted=15.3612, Expected=15.2959
# Month=23, Predicted=15.0661, Expected=15.1318
# Month=24, Predicted=15.1776, Expected=15.5377
# Month=25, Predicted=16.0185, Expected=15.8371
# Month=26, Predicted=15.9920, Expected=16.3719
# Month=27, Predicted=16.5871, Expected=16.3365
# Month=28, Predicted=16.2002, Expected=16.8969
# Month=29, Predicted=17.1891, Expected=17.0022
# Month=30, Predicted=17.0059, Expected=17.4155
# Month=31, Predicted=17.5414, Expected=17.5332
# Month=32, Predicted=17.4999, Expected=17.2849
# Month=33, Predicted=17.0014, Expected=16.6063
# Month=34, Predicted=16.1967, Expected=15.8228
# Month=35, Predicted=15.4251, Expected=15.4543
# Month=36, Predicted=15.4306, Expected=15.6138
# Month=37, Predicted=16.0052, Expected=15.6954
# Month=38, Predicted=15.7371, Expected=16.7627
# Month=39, Predicted=17.3011, Expected=16.4941
# Month=40, Predicted=16.4703, Expected=17.7345
# Month=41, Predicted=18.1240, Expected=18.6944
# Month=42, Predicted=19.1501, Expected=19.1228
# Month=43, Predicted=19.2416, Expected=19.5704
# Month=44, Predicted=19.6374, Expected=19.2258
# Month=45, Predicted=18.9491, Expected=18.2178
# Month=46, Predicted=17.7211, Expected=17.2135
# Month=47, Predicted=16.7756, Expected=16.6554
# Month=48, Predicted=16.6150, Expected=16.8225
# Month=49, Predicted=17.3697, Expected=15.7773
# Month=50, Predicted=15.4544, Expected=15.7224
# Month=51, Predicted=16.0396, Expected=15.9967
# Month=52, Predicted=16.4779, Expected=17.0162
# Month=53, Predicted=17.5992, Expected=17.5568
# Month=54, Predicted=17.8036, Expected=17.8404
# Month=55, Predicted=17.8008, Expected=17.8664
# Month=56, Predicted=17.7053, Expected=17.5659
# Month=57, Predicted=17.2739, Expected=17.0753
# Month=58, Predicted=16.7404, Expected=16.6502
# Month=59, Predicted=16.4178, Expected=16.4285
# Month=60, Predicted=16.3664, Expected=16.5878
# Run 3 — RMSE: 0.482194, MSE: 0.232511, NMSE: 0.0019684730
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.3102, Expected=13.7084
# Month=2, Predicted=14.1048, Expected=13.8026
# Month=3, Predicted=13.7915, Expected=14.3883
# Month=4, Predicted=14.5973, Expected=15.0615
# Month=5, Predicted=15.3979, Expected=15.6682
# Month=6, Predicted=15.8836, Expected=15.8360
# Month=7, Predicted=15.7994, Expected=15.7178
# Month=8, Predicted=15.5096, Expected=15.3110
# Month=9, Predicted=14.9965, Expected=14.7667
# Month=10, Predicted=14.4135, Expected=13.5419
# Month=11, Predicted=12.9405, Expected=13.5869
# Month=12, Predicted=14.3889, Expected=14.5144
# Month=13, Predicted=15.5649, Expected=14.3947
# Month=14, Predicted=14.3535, Expected=14.4996
# Month=15, Predicted=14.3874, Expected=14.7474
# Month=16, Predicted=14.8698, Expected=15.8019
# Month=17, Predicted=16.2590, Expected=16.5221
# Month=18, Predicted=16.8958, Expected=16.5417
# Month=19, Predicted=16.4323, Expected=16.7210
# Month=20, Predicted=16.6621, Expected=16.4288
# Month=21, Predicted=16.2067, Expected=15.7719
# Month=22, Predicted=15.3375, Expected=15.2959
# Month=23, Predicted=15.0281, Expected=15.1318
# Month=24, Predicted=15.1721, Expected=15.5377
# Month=25, Predicted=15.9763, Expected=15.8371
# Month=26, Predicted=15.9833, Expected=16.3719
# Month=27, Predicted=16.5615, Expected=16.3365
# Month=28, Predicted=16.2362, Expected=16.8969
# Month=29, Predicted=17.1245, Expected=17.0022
# Month=30, Predicted=17.0171, Expected=17.4155
# Month=31, Predicted=17.5208, Expected=17.5332
# Month=32, Predicted=17.5210, Expected=17.2849
# Month=33, Predicted=17.0323, Expected=16.6063
# Month=34, Predicted=16.1737, Expected=15.8228
# Month=35, Predicted=15.3667, Expected=15.4543
# Month=36, Predicted=15.3997, Expected=15.6138
# Month=37, Predicted=16.0046, Expected=15.6954
# Month=38, Predicted=15.7445, Expected=16.7627
# Month=39, Predicted=17.2090, Expected=16.4941
# Month=40, Predicted=16.4310, Expected=17.7345
# Month=41, Predicted=18.0301, Expected=18.6944
# Month=42, Predicted=19.2565, Expected=19.1228
# Month=43, Predicted=19.2359, Expected=19.5704
# Month=44, Predicted=19.6366, Expected=19.2258
# Month=45, Predicted=18.9805, Expected=18.2178
# Month=46, Predicted=17.6385, Expected=17.2135
# Month=47, Predicted=16.7290, Expected=16.6554
# Month=48, Predicted=16.6250, Expected=16.8225
# Month=49, Predicted=17.4424, Expected=15.7773
# Month=50, Predicted=15.3627, Expected=15.7224
# Month=51, Predicted=15.8952, Expected=15.9967
# Month=52, Predicted=16.4820, Expected=17.0162
# Month=53, Predicted=17.5127, Expected=17.5568
# Month=54, Predicted=17.8168, Expected=17.8404
# Month=55, Predicted=17.8250, Expected=17.8664
# Month=56, Predicted=17.7416, Expected=17.5659
# Month=57, Predicted=17.2961, Expected=17.0753
# Month=58, Predicted=16.7309, Expected=16.6502
# Month=59, Predicted=16.3997, Expected=16.4285
# Month=60, Predicted=16.3592, Expected=16.5878
# Run 4 — RMSE: 0.495322, MSE: 0.245344, NMSE: 0.0020509095
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.2955, Expected=13.7084
# Month=2, Predicted=14.1038, Expected=13.8026
# Month=3, Predicted=13.8163, Expected=14.3883
# Month=4, Predicted=14.7200, Expected=15.0615
# Month=5, Predicted=15.4010, Expected=15.6682
# Month=6, Predicted=15.9403, Expected=15.8360
# Month=7, Predicted=15.8676, Expected=15.7178
# Month=8, Predicted=15.5829, Expected=15.3110
# Month=9, Predicted=15.0149, Expected=14.7667
# Month=10, Predicted=14.3957, Expected=13.5419
# Month=11, Predicted=12.7996, Expected=13.5869
# Month=12, Predicted=13.9871, Expected=14.5144
# Month=13, Predicted=15.2705, Expected=14.3947
# Month=14, Predicted=14.3319, Expected=14.4996
# Month=15, Predicted=14.5268, Expected=14.7474
# Month=16, Predicted=14.8985, Expected=15.8019
# Month=17, Predicted=16.2836, Expected=16.5221
# Month=18, Predicted=16.8503, Expected=16.5417
# Month=19, Predicted=16.5011, Expected=16.7210
# Month=20, Predicted=16.7860, Expected=16.4288
# Month=21, Predicted=16.2206, Expected=15.7719
# Month=22, Predicted=15.3204, Expected=15.2959
# Month=23, Predicted=15.0084, Expected=15.1318
# Month=24, Predicted=15.1361, Expected=15.5377
# Month=25, Predicted=15.9457, Expected=15.8371
# Month=26, Predicted=15.9920, Expected=16.3719
# Month=27, Predicted=16.6411, Expected=16.3365
# Month=28, Predicted=16.2728, Expected=16.8969
# Month=29, Predicted=17.2537, Expected=17.0022
# Month=30, Predicted=17.0294, Expected=17.4155
# Month=31, Predicted=17.6366, Expected=17.5332
# Month=32, Predicted=17.5574, Expected=17.2849
# Month=33, Predicted=17.0802, Expected=16.6063
# Month=34, Predicted=16.1492, Expected=15.8228
# Month=35, Predicted=15.2991, Expected=15.4543
# Month=36, Predicted=15.3466, Expected=15.6138
# Month=37, Predicted=15.9384, Expected=15.6954
# Month=38, Predicted=15.7471, Expected=16.7627
# Month=39, Predicted=17.2590, Expected=16.4941
# Month=40, Predicted=16.3850, Expected=17.7345
# Month=41, Predicted=18.2412, Expected=18.6944
# Month=42, Predicted=19.1475, Expected=19.1228
# Month=43, Predicted=19.2859, Expected=19.5704
# Month=44, Predicted=19.7575, Expected=19.2258
# Month=45, Predicted=19.0033, Expected=18.2178
# Month=46, Predicted=17.5679, Expected=17.2135
# Month=47, Predicted=16.6677, Expected=16.6554
# Month=48, Predicted=16.5301, Expected=16.8225
# Month=49, Predicted=17.3170, Expected=15.7773
# Month=50, Predicted=15.2593, Expected=15.7224
# Month=51, Predicted=16.0272, Expected=15.9967
# Month=52, Predicted=16.3538, Expected=17.0162
# Month=53, Predicted=17.5112, Expected=17.5568
# Month=54, Predicted=17.7943, Expected=17.8404
# Month=55, Predicted=17.9285, Expected=17.8664
# Month=56, Predicted=17.8177, Expected=17.5659
# Month=57, Predicted=17.3322, Expected=17.0753
# Month=58, Predicted=16.7306, Expected=16.6502
# Month=59, Predicted=16.3837, Expected=16.4285
# Month=60, Predicted=16.3401, Expected=16.5878
# Run 5 — RMSE: 0.490354, MSE: 0.240447, NMSE: 0.0019315298
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2910, Expected=13.7084
# Month=2, Predicted=14.0970, Expected=13.8026
# Month=3, Predicted=13.8548, Expected=14.3883
# Month=4, Predicted=14.7430, Expected=15.0615
# Month=5, Predicted=15.4139, Expected=15.6682
# Month=6, Predicted=15.9496, Expected=15.8360
# Month=7, Predicted=15.9031, Expected=15.7178
# Month=8, Predicted=15.6146, Expected=15.3110
# Month=9, Predicted=15.0234, Expected=14.7667
# Month=10, Predicted=14.4038, Expected=13.5419
# Month=11, Predicted=12.6880, Expected=13.5869
# Month=12, Predicted=13.9360, Expected=14.5144
# Month=13, Predicted=15.0613, Expected=14.3947
# Month=14, Predicted=14.2729, Expected=14.4996
# Month=15, Predicted=14.5749, Expected=14.7474
# Month=16, Predicted=14.9407, Expected=15.8019
# Month=17, Predicted=16.2785, Expected=16.5221
# Month=18, Predicted=16.8120, Expected=16.5417
# Month=19, Predicted=16.4983, Expected=16.7210
# Month=20, Predicted=16.8402, Expected=16.4288
# Month=21, Predicted=16.2203, Expected=15.7719
# Month=22, Predicted=15.2970, Expected=15.2959
# Month=23, Predicted=15.0203, Expected=15.1318
# Month=24, Predicted=15.1254, Expected=15.5377
# Month=25, Predicted=15.8873, Expected=15.8371
# Month=26, Predicted=16.0392, Expected=16.3719
# Month=27, Predicted=16.6937, Expected=16.3365
# Month=28, Predicted=16.3046, Expected=16.8969
# Month=29, Predicted=17.2535, Expected=17.0022
# Month=30, Predicted=17.0743, Expected=17.4155
# Month=31, Predicted=17.6814, Expected=17.5332
# Month=32, Predicted=17.6009, Expected=17.2849
# Month=33, Predicted=17.0944, Expected=16.6063
# Month=34, Predicted=16.1171, Expected=15.8228
# Month=35, Predicted=15.2939, Expected=15.4543
# Month=36, Predicted=15.3172, Expected=15.6138
# Month=37, Predicted=15.8547, Expected=15.6954
# Month=38, Predicted=15.7813, Expected=16.7627
# Month=39, Predicted=17.2313, Expected=16.4941
# Month=40, Predicted=16.2778, Expected=17.7345
# Month=41, Predicted=18.1565, Expected=18.6944
# Month=42, Predicted=19.0529, Expected=19.1228
# Month=43, Predicted=19.2625, Expected=19.5704
# Month=44, Predicted=19.8261, Expected=19.2258
# Month=45, Predicted=18.9876, Expected=18.2178
# Month=46, Predicted=17.4620, Expected=17.2135
# Month=47, Predicted=16.6939, Expected=16.6554
# Month=48, Predicted=16.4953, Expected=16.8225
# Month=49, Predicted=17.1189, Expected=15.7773
# Month=50, Predicted=15.1209, Expected=15.7224
# Month=51, Predicted=15.8514, Expected=15.9967
# Month=52, Predicted=16.2892, Expected=17.0162
# Month=53, Predicted=17.4981, Expected=17.5568
# Month=54, Predicted=17.7650, Expected=17.8404
# Month=55, Predicted=17.9804, Expected=17.8664
# Month=56, Predicted=17.8622, Expected=17.5659
# Month=57, Predicted=17.3462, Expected=17.0753
# Month=58, Predicted=16.7398, Expected=16.6502
# Month=59, Predicted=16.4030, Expected=16.4285
# Month=60, Predicted=16.3555, Expected=16.5878
# Run 6 — RMSE: 0.487486, MSE: 0.237643, NMSE: 0.0018943874
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.3346, Expected=13.7084
# Month=2, Predicted=14.1994, Expected=13.8026
# Month=3, Predicted=13.8408, Expected=14.3883
# Month=4, Predicted=14.7490, Expected=15.0615
# Month=5, Predicted=15.4886, Expected=15.6682
# Month=6, Predicted=15.9660, Expected=15.8360
# Month=7, Predicted=15.8588, Expected=15.7178
# Month=8, Predicted=15.5757, Expected=15.3110
# Month=9, Predicted=15.0217, Expected=14.7667
# Month=10, Predicted=14.4072, Expected=13.5419
# Month=11, Predicted=13.0260, Expected=13.5869
# Month=12, Predicted=13.8690, Expected=14.5144
# Month=13, Predicted=15.3732, Expected=14.3947
# Month=14, Predicted=14.3355, Expected=14.4996
# Month=15, Predicted=14.4965, Expected=14.7474
# Month=16, Predicted=14.9672, Expected=15.8019
# Month=17, Predicted=16.3856, Expected=16.5221
# Month=18, Predicted=16.8634, Expected=16.5417
# Month=19, Predicted=16.4562, Expected=16.7210
# Month=20, Predicted=16.7842, Expected=16.4288
# Month=21, Predicted=16.2336, Expected=15.7719
# Month=22, Predicted=15.3268, Expected=15.2959
# Month=23, Predicted=15.0035, Expected=15.1318
# Month=24, Predicted=15.1354, Expected=15.5377
# Month=25, Predicted=15.9959, Expected=15.8371
# Month=26, Predicted=16.0664, Expected=16.3719
# Month=27, Predicted=16.6978, Expected=16.3365
# Month=28, Predicted=16.2775, Expected=16.8969
# Month=29, Predicted=17.2710, Expected=17.0022
# Month=30, Predicted=17.0662, Expected=17.4155
# Month=31, Predicted=17.6628, Expected=17.5332
# Month=32, Predicted=17.5947, Expected=17.2849
# Month=33, Predicted=17.0781, Expected=16.6063
# Month=34, Predicted=16.1630, Expected=15.8228
# Month=35, Predicted=15.3544, Expected=15.4543
# Month=36, Predicted=15.3015, Expected=15.6138
# Month=37, Predicted=15.9337, Expected=15.6954
# Month=38, Predicted=15.8078, Expected=16.7627
# Month=39, Predicted=17.3379, Expected=16.4941
# Month=40, Predicted=16.3981, Expected=17.7345
# Month=41, Predicted=18.1430, Expected=18.6944
# Month=42, Predicted=19.1737, Expected=19.1228
# Month=43, Predicted=19.2383, Expected=19.5704
# Month=44, Predicted=19.7519, Expected=19.2258
# Month=45, Predicted=18.9862, Expected=18.2178
# Month=46, Predicted=17.7164, Expected=17.2135
# Month=47, Predicted=16.7129, Expected=16.6554
# Month=48, Predicted=16.3919, Expected=16.8225
# Month=49, Predicted=17.2234, Expected=15.7773
# Month=50, Predicted=15.3421, Expected=15.7224
# Month=51, Predicted=15.7651, Expected=15.9967
# Month=52, Predicted=16.4190, Expected=17.0162
# Month=53, Predicted=17.6242, Expected=17.5568
# Month=54, Predicted=17.8046, Expected=17.8404
# Month=55, Predicted=17.9040, Expected=17.8664
# Month=56, Predicted=17.8226, Expected=17.5659
# Month=57, Predicted=17.3368, Expected=17.0753
# Month=58, Predicted=16.7401, Expected=16.6502
# Month=59, Predicted=16.3943, Expected=16.4285
# Month=60, Predicted=16.3554, Expected=16.5878
# Run 7 — RMSE: 0.487548, MSE: 0.237704, NMSE: 0.0019415976
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2990, Expected=13.7084
# Month=2, Predicted=14.1425, Expected=13.8026
# Month=3, Predicted=13.8502, Expected=14.3883
# Month=4, Predicted=14.7668, Expected=15.0615
# Month=5, Predicted=15.4086, Expected=15.6682
# Month=6, Predicted=15.9439, Expected=15.8360
# Month=7, Predicted=15.8979, Expected=15.7178
# Month=8, Predicted=15.5959, Expected=15.3110
# Month=9, Predicted=15.0120, Expected=14.7667
# Month=10, Predicted=14.3914, Expected=13.5419
# Month=11, Predicted=12.7884, Expected=13.5869
# Month=12, Predicted=13.9796, Expected=14.5144
# Month=13, Predicted=15.1981, Expected=14.3947
# Month=14, Predicted=14.3532, Expected=14.4996
# Month=15, Predicted=14.5333, Expected=14.7474
# Month=16, Predicted=14.9272, Expected=15.8019
# Month=17, Predicted=16.3491, Expected=16.5221
# Month=18, Predicted=16.8329, Expected=16.5417
# Month=19, Predicted=16.5272, Expected=16.7210
# Month=20, Predicted=16.8046, Expected=16.4288
# Month=21, Predicted=16.2307, Expected=15.7719
# Month=22, Predicted=15.3117, Expected=15.2959
# Month=23, Predicted=15.0219, Expected=15.1318
# Month=24, Predicted=15.1322, Expected=15.5377
# Month=25, Predicted=15.9657, Expected=15.8371
# Month=26, Predicted=16.0306, Expected=16.3719
# Month=27, Predicted=16.6955, Expected=16.3365
# Month=28, Predicted=16.3205, Expected=16.8969
# Month=29, Predicted=17.2997, Expected=17.0022
# Month=30, Predicted=17.0640, Expected=17.4155
# Month=31, Predicted=17.6744, Expected=17.5332
# Month=32, Predicted=17.5973, Expected=17.2849
# Month=33, Predicted=17.0879, Expected=16.6063
# Month=34, Predicted=16.1410, Expected=15.8228
# Month=35, Predicted=15.3045, Expected=15.4543
# Month=36, Predicted=15.3704, Expected=15.6138
# Month=37, Predicted=15.9252, Expected=15.6954
# Month=38, Predicted=15.7541, Expected=16.7627
# Month=39, Predicted=17.3251, Expected=16.4941
# Month=40, Predicted=16.4227, Expected=17.7345
# Month=41, Predicted=18.2814, Expected=18.6944
# Month=42, Predicted=19.1113, Expected=19.1228
# Month=43, Predicted=19.2749, Expected=19.5704
# Month=44, Predicted=19.8010, Expected=19.2258
# Month=45, Predicted=19.0376, Expected=18.2178
# Month=46, Predicted=17.5622, Expected=17.2135
# Month=47, Predicted=16.6584, Expected=16.6554
# Month=48, Predicted=16.5116, Expected=16.8225
# Month=49, Predicted=17.2930, Expected=15.7773
# Month=50, Predicted=15.2592, Expected=15.7224
# Month=51, Predicted=16.0912, Expected=15.9967
# Month=52, Predicted=16.3059, Expected=17.0162
# Month=53, Predicted=17.5679, Expected=17.5568
# Month=54, Predicted=17.7803, Expected=17.8404
# Month=55, Predicted=17.9601, Expected=17.8664
# Month=56, Predicted=17.8452, Expected=17.5659
# Month=57, Predicted=17.3355, Expected=17.0753
# Month=58, Predicted=16.7256, Expected=16.6502
# Month=59, Predicted=16.3856, Expected=16.4285
# Month=60, Predicted=16.3417, Expected=16.5878
# Run 8 — RMSE: 0.487625, MSE: 0.237778, NMSE: 0.0019007397
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.3334, Expected=13.7084
# Month=2, Predicted=14.1441, Expected=13.8026
# Month=3, Predicted=13.8550, Expected=14.3883
# Month=4, Predicted=14.6572, Expected=15.0615
# Month=5, Predicted=15.4257, Expected=15.6682
# Month=6, Predicted=15.9352, Expected=15.8360
# Month=7, Predicted=15.8821, Expected=15.7178
# Month=8, Predicted=15.5582, Expected=15.3110
# Month=9, Predicted=14.9987, Expected=14.7667
# Month=10, Predicted=14.3750, Expected=13.5419
# Month=11, Predicted=12.8337, Expected=13.5869
# Month=12, Predicted=14.0173, Expected=14.5144
# Month=13, Predicted=15.5461, Expected=14.3947
# Month=14, Predicted=14.4381, Expected=14.4996
# Month=15, Predicted=14.4230, Expected=14.7474
# Month=16, Predicted=14.9099, Expected=15.8019
# Month=17, Predicted=16.3007, Expected=16.5221
# Month=18, Predicted=16.8020, Expected=16.5417
# Month=19, Predicted=16.5418, Expected=16.7210
# Month=20, Predicted=16.7112, Expected=16.4288
# Month=21, Predicted=16.2414, Expected=15.7719
# Month=22, Predicted=15.3047, Expected=15.2959
# Month=23, Predicted=14.9850, Expected=15.1318
# Month=24, Predicted=15.1690, Expected=15.5377
# Month=25, Predicted=16.0173, Expected=15.8371
# Month=26, Predicted=16.0240, Expected=16.3719
# Month=27, Predicted=16.6165, Expected=16.3365
# Month=28, Predicted=16.3085, Expected=16.8969
# Month=29, Predicted=17.1853, Expected=17.0022
# Month=30, Predicted=17.0737, Expected=17.4155
# Month=31, Predicted=17.5771, Expected=17.5332
# Month=32, Predicted=17.5769, Expected=17.2849
# Month=33, Predicted=17.0687, Expected=16.6063
# Month=34, Predicted=16.1449, Expected=15.8228
# Month=35, Predicted=15.2819, Expected=15.4543
# Month=36, Predicted=15.3778, Expected=15.6138
# Month=37, Predicted=16.0323, Expected=15.6954
# Month=38, Predicted=15.7741, Expected=16.7627
# Month=39, Predicted=17.2628, Expected=16.4941
# Month=40, Predicted=16.5328, Expected=17.7345
# Month=41, Predicted=18.0990, Expected=18.6944
# Month=42, Predicted=19.1039, Expected=19.1228
# Month=43, Predicted=19.2763, Expected=19.5704
# Month=44, Predicted=19.7173, Expected=19.2258
# Month=45, Predicted=19.0539, Expected=18.2178
# Month=46, Predicted=17.5822, Expected=17.2135
# Month=47, Predicted=16.6501, Expected=16.6554
# Month=48, Predicted=16.5571, Expected=16.8225
# Month=49, Predicted=17.4853, Expected=15.7773
# Month=50, Predicted=15.3676, Expected=15.7224
# Month=51, Predicted=15.9650, Expected=15.9967
# Month=52, Predicted=16.4866, Expected=17.0162
# Month=53, Predicted=17.5457, Expected=17.5568
# Month=54, Predicted=17.7711, Expected=17.8404
# Month=55, Predicted=17.9144, Expected=17.8664
# Month=56, Predicted=17.8022, Expected=17.5659
# Month=57, Predicted=17.3197, Expected=17.0753
# Month=58, Predicted=16.7077, Expected=16.6502
# Month=59, Predicted=16.3671, Expected=16.4285
# Month=60, Predicted=16.3506, Expected=16.5878
# Run 9 — RMSE: 0.495049, MSE: 0.245074, NMSE: 0.0020050502
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2979, Expected=13.7084
# Month=2, Predicted=14.0962, Expected=13.8026
# Month=3, Predicted=13.8581, Expected=14.3883
# Month=4, Predicted=14.7724, Expected=15.0615
# Month=5, Predicted=15.3985, Expected=15.6682
# Month=6, Predicted=15.9634, Expected=15.8360
# Month=7, Predicted=15.9297, Expected=15.7178
# Month=8, Predicted=15.6906, Expected=15.3110
# Month=9, Predicted=15.0405, Expected=14.7667
# Month=10, Predicted=14.4157, Expected=13.5419
# Month=11, Predicted=12.6577, Expected=13.5869
# Month=12, Predicted=13.8624, Expected=14.5144
# Month=13, Predicted=15.0109, Expected=14.3947
# Month=14, Predicted=14.2820, Expected=14.4996
# Month=15, Predicted=14.6246, Expected=14.7474
# Month=16, Predicted=14.9706, Expected=15.8019
# Month=17, Predicted=16.2578, Expected=16.5221
# Month=18, Predicted=16.8015, Expected=16.5417
# Month=19, Predicted=16.5369, Expected=16.7210
# Month=20, Predicted=16.9135, Expected=16.4288
# Month=21, Predicted=16.2759, Expected=15.7719
# Month=22, Predicted=15.3126, Expected=15.2959
# Month=23, Predicted=15.0331, Expected=15.1318
# Month=24, Predicted=15.1171, Expected=15.5377
# Month=25, Predicted=15.9078, Expected=15.8371
# Month=26, Predicted=16.0337, Expected=16.3719
# Month=27, Predicted=16.6968, Expected=16.3365
# Month=28, Predicted=16.3194, Expected=16.8969
# Month=29, Predicted=17.3028, Expected=17.0022
# Month=30, Predicted=17.0678, Expected=17.4155
# Month=31, Predicted=17.7205, Expected=17.5332
# Month=32, Predicted=17.6219, Expected=17.2849
# Month=33, Predicted=17.1536, Expected=16.6063
# Month=34, Predicted=16.1279, Expected=15.8228
# Month=35, Predicted=15.3017, Expected=15.4543
# Month=36, Predicted=15.3109, Expected=15.6138
# Month=37, Predicted=15.8457, Expected=15.6954
# Month=38, Predicted=15.8117, Expected=16.7627
# Month=39, Predicted=17.2367, Expected=16.4941
# Month=40, Predicted=16.2773, Expected=17.7345
# Month=41, Predicted=18.2150, Expected=18.6944
# Month=42, Predicted=19.0369, Expected=19.1228
# Month=43, Predicted=19.2798, Expected=19.5704
# Month=44, Predicted=19.8327, Expected=19.2258
# Month=45, Predicted=19.0318, Expected=18.2178
# Month=46, Predicted=17.4779, Expected=17.2135
# Month=47, Predicted=16.5418, Expected=16.6554
# Month=48, Predicted=16.3904, Expected=16.8225
# Month=49, Predicted=17.0948, Expected=15.7773
# Month=50, Predicted=15.0535, Expected=15.7224
# Month=51, Predicted=15.8612, Expected=15.9967
# Month=52, Predicted=16.2888, Expected=17.0162
# Month=53, Predicted=17.4691, Expected=17.5568
# Month=54, Predicted=17.7623, Expected=17.8404
# Month=55, Predicted=18.0031, Expected=17.8664
# Month=56, Predicted=17.9157, Expected=17.5659
# Month=57, Predicted=17.3842, Expected=17.0753
# Month=58, Predicted=16.7549, Expected=16.6502
# Month=59, Predicted=16.4110, Expected=16.4285
# Month=60, Predicted=16.3555, Expected=16.5878
# Run 10 — RMSE: 0.495395, MSE: 0.245416, NMSE: 0.0019365080
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.3555, Expected=13.7084
# Month=2, Predicted=14.2379, Expected=13.8026
# Month=3, Predicted=13.8277, Expected=14.3883
# Month=4, Predicted=14.8468, Expected=15.0615
# Month=5, Predicted=15.4697, Expected=15.6682
# Month=6, Predicted=15.9953, Expected=15.8360
# Month=7, Predicted=15.8766, Expected=15.7178
# Month=8, Predicted=15.5527, Expected=15.3110
# Month=9, Predicted=14.9629, Expected=14.7667
# Month=10, Predicted=14.3682, Expected=13.5419
# Month=11, Predicted=12.8941, Expected=13.5869
# Month=12, Predicted=13.9063, Expected=14.5144
# Month=13, Predicted=15.3433, Expected=14.3947
# Month=14, Predicted=14.3883, Expected=14.4996
# Month=15, Predicted=14.5755, Expected=14.7474
# Month=16, Predicted=14.9914, Expected=15.8019
# Month=17, Predicted=16.4329, Expected=16.5221
# Month=18, Predicted=16.8560, Expected=16.5417
# Month=19, Predicted=16.4994, Expected=16.7210
# Month=20, Predicted=16.8529, Expected=16.4288
# Month=21, Predicted=16.1484, Expected=15.7719
# Month=22, Predicted=15.2941, Expected=15.2959
# Month=23, Predicted=14.9923, Expected=15.1318
# Month=24, Predicted=15.1377, Expected=15.5377
# Month=25, Predicted=16.0325, Expected=15.8371
# Month=26, Predicted=16.0455, Expected=16.3719
# Month=27, Predicted=16.7540, Expected=16.3365
# Month=28, Predicted=16.2538, Expected=16.8969
# Month=29, Predicted=17.3718, Expected=17.0022
# Month=30, Predicted=17.0451, Expected=17.4155
# Month=31, Predicted=17.7445, Expected=17.5332
# Month=32, Predicted=17.5501, Expected=17.2849
# Month=33, Predicted=17.0240, Expected=16.6063
# Month=34, Predicted=16.1136, Expected=15.8228
# Month=35, Predicted=15.3717, Expected=15.4543
# Month=36, Predicted=15.3056, Expected=15.6138
# Month=37, Predicted=15.9518, Expected=15.6954
# Month=38, Predicted=15.7957, Expected=16.7627
# Month=39, Predicted=17.4045, Expected=16.4941
# Month=40, Predicted=16.5066, Expected=17.7345
# Month=41, Predicted=18.2845, Expected=18.6944
# Month=42, Predicted=19.0562, Expected=19.1228
# Month=43, Predicted=19.2804, Expected=19.5704
# Month=44, Predicted=19.8206, Expected=19.2258
# Month=45, Predicted=18.9299, Expected=18.2178
# Month=46, Predicted=17.5994, Expected=17.2135
# Month=47, Predicted=16.7307, Expected=16.6554
# Month=48, Predicted=16.4040, Expected=16.8225
# Month=49, Predicted=17.2316, Expected=15.7773
# Month=50, Predicted=15.1992, Expected=15.7224
# Month=51, Predicted=15.8334, Expected=15.9967
# Month=52, Predicted=16.4273, Expected=17.0162
# Month=53, Predicted=17.6562, Expected=17.5568
# Month=54, Predicted=17.8233, Expected=17.8404
# Month=55, Predicted=17.9351, Expected=17.8664
# Month=56, Predicted=17.8064, Expected=17.5659
# Month=57, Predicted=17.2815, Expected=17.0753
# Month=58, Predicted=16.6890, Expected=16.6502
# Month=59, Predicted=16.3720, Expected=16.4285
# Month=60, Predicted=16.3512, Expected=16.5878
# Run 11 — RMSE: 0.480518, MSE: 0.230897, NMSE: 0.0018718005
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.4020, Expected=13.7084
# Month=2, Predicted=14.2472, Expected=13.8026
# Month=3, Predicted=13.8669, Expected=14.3883
# Month=4, Predicted=14.6427, Expected=15.0615
# Month=5, Predicted=15.4393, Expected=15.6682
# Month=6, Predicted=15.8605, Expected=15.8360
# Month=7, Predicted=15.8280, Expected=15.7178
# Month=8, Predicted=15.5014, Expected=15.3110
# Month=9, Predicted=14.9635, Expected=14.7667
# Month=10, Predicted=14.3534, Expected=13.5419
# Month=11, Predicted=12.8957, Expected=13.5869
# Month=12, Predicted=14.5463, Expected=14.5144
# Month=13, Predicted=15.6762, Expected=14.3947
# Month=14, Predicted=14.4494, Expected=14.4996
# Month=15, Predicted=14.3290, Expected=14.7474
# Month=16, Predicted=14.9318, Expected=15.8019
# Month=17, Predicted=16.3841, Expected=16.5221
# Month=18, Predicted=16.7697, Expected=16.5417
# Month=19, Predicted=16.5072, Expected=16.7210
# Month=20, Predicted=16.6343, Expected=16.4288
# Month=21, Predicted=16.2284, Expected=15.7719
# Month=22, Predicted=15.2843, Expected=15.2959
# Month=23, Predicted=14.9768, Expected=15.1318
# Month=24, Predicted=15.2188, Expected=15.5377
# Month=25, Predicted=16.1274, Expected=15.8371
# Month=26, Predicted=16.0797, Expected=16.3719
# Month=27, Predicted=16.6305, Expected=16.3365
# Month=28, Predicted=16.3101, Expected=16.8969
# Month=29, Predicted=17.1700, Expected=17.0022
# Month=30, Predicted=17.0923, Expected=17.4155
# Month=31, Predicted=17.5532, Expected=17.5332
# Month=32, Predicted=17.5758, Expected=17.2849
# Month=33, Predicted=17.0325, Expected=16.6063
# Month=34, Predicted=16.1340, Expected=15.8228
# Month=35, Predicted=15.2765, Expected=15.4543
# Month=36, Predicted=15.4116, Expected=15.6138
# Month=37, Predicted=16.1297, Expected=15.6954
# Month=38, Predicted=15.8234, Expected=16.7627
# Month=39, Predicted=17.3401, Expected=16.4941
# Month=40, Predicted=16.5560, Expected=17.7345
# Month=41, Predicted=18.0073, Expected=18.6944
# Month=42, Predicted=19.1758, Expected=19.1228
# Month=43, Predicted=19.1236, Expected=19.5704
# Month=44, Predicted=19.6479, Expected=19.2258
# Month=45, Predicted=19.0916, Expected=18.2178
# Month=46, Predicted=17.6304, Expected=17.2135
# Month=47, Predicted=16.6582, Expected=16.6554
# Month=48, Predicted=16.6372, Expected=16.8225
# Month=49, Predicted=17.5714, Expected=15.7773
# Month=50, Predicted=15.5090, Expected=15.7224
# Month=51, Predicted=16.0210, Expected=15.9967
# Month=52, Predicted=16.5845, Expected=17.0162
# Month=53, Predicted=17.6721, Expected=17.5568
# Month=54, Predicted=17.7177, Expected=17.8404
# Month=55, Predicted=17.8351, Expected=17.8664
# Month=56, Predicted=17.7528, Expected=17.5659
# Month=57, Predicted=17.2826, Expected=17.0753
# Month=58, Predicted=16.6775, Expected=16.6502
# Month=59, Predicted=16.3616, Expected=16.4285
# Month=60, Predicted=16.3821, Expected=16.5878
# Run 12 — RMSE: 0.497675, MSE: 0.247680, NMSE: 0.0021021737
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2780, Expected=13.7084
# Month=2, Predicted=14.1045, Expected=13.8026
# Month=3, Predicted=13.8337, Expected=14.3883
# Month=4, Predicted=14.7730, Expected=15.0615
# Month=5, Predicted=15.4334, Expected=15.6682
# Month=6, Predicted=15.9869, Expected=15.8360
# Month=7, Predicted=15.9024, Expected=15.7178
# Month=8, Predicted=15.6657, Expected=15.3110
# Month=9, Predicted=15.0661, Expected=14.7667
# Month=10, Predicted=14.4368, Expected=13.5419
# Month=11, Predicted=12.7636, Expected=13.5869
# Month=12, Predicted=13.7821, Expected=14.5144
# Month=13, Predicted=15.0204, Expected=14.3947
# Month=14, Predicted=14.2116, Expected=14.4996
# Month=15, Predicted=14.5652, Expected=14.7474
# Month=16, Predicted=14.9642, Expected=15.8019
# Month=17, Predicted=16.2893, Expected=16.5221
# Month=18, Predicted=16.8345, Expected=16.5417
# Month=19, Predicted=16.4650, Expected=16.7210
# Month=20, Predicted=16.8737, Expected=16.4288
# Month=21, Predicted=16.2623, Expected=15.7719
# Month=22, Predicted=15.3540, Expected=15.2959
# Month=23, Predicted=15.0293, Expected=15.1318
# Month=24, Predicted=15.0942, Expected=15.5377
# Month=25, Predicted=15.8790, Expected=15.8371
# Month=26, Predicted=16.0353, Expected=16.3719
# Month=27, Predicted=16.7089, Expected=16.3365
# Month=28, Predicted=16.2860, Expected=16.8969
# Month=29, Predicted=17.2930, Expected=17.0022
# Month=30, Predicted=17.0473, Expected=17.4155
# Month=31, Predicted=17.7151, Expected=17.5332
# Month=32, Predicted=17.6086, Expected=17.2849
# Month=33, Predicted=17.1435, Expected=16.6063
# Month=34, Predicted=16.1735, Expected=15.8228
# Month=35, Predicted=15.3369, Expected=15.4543
# Month=36, Predicted=15.2826, Expected=15.6138
# Month=37, Predicted=15.8094, Expected=15.6954
# Month=38, Predicted=15.7997, Expected=16.7627
# Month=39, Predicted=17.2507, Expected=16.4941
# Month=40, Predicted=16.4615, Expected=17.7345
# Month=41, Predicted=18.1028, Expected=18.6944
# Month=42, Predicted=19.0982, Expected=19.1228
# Month=43, Predicted=19.2416, Expected=19.5704
# Month=44, Predicted=19.8149, Expected=19.2258
# Month=45, Predicted=18.9887, Expected=18.2178
# Month=46, Predicted=17.5581, Expected=17.2135
# Month=47, Predicted=16.7475, Expected=16.6554
# Month=48, Predicted=16.3909, Expected=16.8225
# Month=49, Predicted=17.0390, Expected=15.7773
# Month=50, Predicted=15.3601, Expected=15.7224
# Month=51, Predicted=15.7984, Expected=15.9967
# Month=52, Predicted=16.2609, Expected=17.0162
# Month=53, Predicted=17.5035, Expected=17.5568
# Month=54, Predicted=17.7713, Expected=17.8404
# Month=55, Predicted=17.9683, Expected=17.8664
# Month=56, Predicted=17.8962, Expected=17.5659
# Month=57, Predicted=17.3915, Expected=17.0753
# Month=58, Predicted=16.7780, Expected=16.6502
# Month=59, Predicted=16.4132, Expected=16.4285
# Month=60, Predicted=16.3425, Expected=16.5878
# Run 13 — RMSE: 0.484373, MSE: 0.234618, NMSE: 0.0018653140
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2902, Expected=13.7084
# Month=2, Predicted=14.0766, Expected=13.8026
# Month=3, Predicted=13.8187, Expected=14.3883
# Month=4, Predicted=14.7171, Expected=15.0615
# Month=5, Predicted=15.4186, Expected=15.6682
# Month=6, Predicted=15.9773, Expected=15.8360
# Month=7, Predicted=15.8816, Expected=15.7178
# Month=8, Predicted=15.5865, Expected=15.3110
# Month=9, Predicted=14.9973, Expected=14.7667
# Month=10, Predicted=14.3869, Expected=13.5419
# Month=11, Predicted=12.6853, Expected=13.5869
# Month=12, Predicted=13.9646, Expected=14.5144
# Month=13, Predicted=15.0754, Expected=14.3947
# Month=14, Predicted=14.2739, Expected=14.4996
# Month=15, Predicted=14.5496, Expected=14.7474
# Month=16, Predicted=14.9225, Expected=15.8019
# Month=17, Predicted=16.2492, Expected=16.5221
# Month=18, Predicted=16.8704, Expected=16.5417
# Month=19, Predicted=16.4883, Expected=16.7210
# Month=20, Predicted=16.8158, Expected=16.4288
# Month=21, Predicted=16.2015, Expected=15.7719
# Month=22, Predicted=15.2711, Expected=15.2959
# Month=23, Predicted=15.0200, Expected=15.1318
# Month=24, Predicted=15.1376, Expected=15.5377
# Month=25, Predicted=15.8817, Expected=15.8371
# Month=26, Predicted=16.0155, Expected=16.3719
# Month=27, Predicted=16.6663, Expected=16.3365
# Month=28, Predicted=16.2624, Expected=16.8969
# Month=29, Predicted=17.2297, Expected=17.0022
# Month=30, Predicted=17.0347, Expected=17.4155
# Month=31, Predicted=17.6566, Expected=17.5332
# Month=32, Predicted=17.5749, Expected=17.2849
# Month=33, Predicted=17.0653, Expected=16.6063
# Month=34, Predicted=16.0947, Expected=15.8228
# Month=35, Predicted=15.2860, Expected=15.4543
# Month=36, Predicted=15.3395, Expected=15.6138
# Month=37, Predicted=15.8682, Expected=15.6954
# Month=38, Predicted=15.7659, Expected=16.7627
# Month=39, Predicted=17.2052, Expected=16.4941
# Month=40, Predicted=16.2818, Expected=17.7345
# Month=41, Predicted=18.1284, Expected=18.6944
# Month=42, Predicted=19.1434, Expected=19.1228
# Month=43, Predicted=19.3068, Expected=19.5704
# Month=44, Predicted=19.7992, Expected=19.2258
# Month=45, Predicted=18.9464, Expected=18.2178
# Month=46, Predicted=17.4349, Expected=17.2135
# Month=47, Predicted=16.6618, Expected=16.6554
# Month=48, Predicted=16.5207, Expected=16.8225
# Month=49, Predicted=17.1492, Expected=15.7773
# Month=50, Predicted=15.1036, Expected=15.7224
# Month=51, Predicted=15.8665, Expected=15.9967
# Month=52, Predicted=16.3043, Expected=17.0162
# Month=53, Predicted=17.4687, Expected=17.5568
# Month=54, Predicted=17.8115, Expected=17.8404
# Month=55, Predicted=17.9635, Expected=17.8664
# Month=56, Predicted=17.8353, Expected=17.5659
# Month=57, Predicted=17.3186, Expected=17.0753
# Month=58, Predicted=16.7180, Expected=16.6502
# Month=59, Predicted=16.3982, Expected=16.4285
# Month=60, Predicted=16.3589, Expected=16.5878
# Run 14 — RMSE: 0.486177, MSE: 0.236368, NMSE: 0.0018798177
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.3558, Expected=13.7084
# Month=2, Predicted=14.1883, Expected=13.8026
# Month=3, Predicted=13.8466, Expected=14.3883
# Month=4, Predicted=14.7640, Expected=15.0615
# Month=5, Predicted=15.4540, Expected=15.6682
# Month=6, Predicted=15.9762, Expected=15.8360
# Month=7, Predicted=15.8919, Expected=15.7178
# Month=8, Predicted=15.5601, Expected=15.3110
# Month=9, Predicted=14.9892, Expected=14.7667
# Month=10, Predicted=14.3708, Expected=13.5419
# Month=11, Predicted=12.8146, Expected=13.5869
# Month=12, Predicted=14.7769, Expected=14.5144
# Month=13, Predicted=15.4218, Expected=14.3947
# Month=14, Predicted=14.4928, Expected=14.4996
# Month=15, Predicted=14.5026, Expected=14.7474
# Month=16, Predicted=14.9214, Expected=15.8019
# Month=17, Predicted=16.3815, Expected=16.5221
# Month=18, Predicted=16.8497, Expected=16.5417
# Month=19, Predicted=16.5727, Expected=16.7210
# Month=20, Predicted=16.7688, Expected=16.4288
# Month=21, Predicted=16.2199, Expected=15.7719
# Month=22, Predicted=15.2967, Expected=15.2959
# Month=23, Predicted=15.0296, Expected=15.1318
# Month=24, Predicted=15.1955, Expected=15.5377
# Month=25, Predicted=16.0729, Expected=15.8371
# Month=26, Predicted=16.0082, Expected=16.3719
# Month=27, Predicted=16.6684, Expected=16.3365
# Month=28, Predicted=16.3056, Expected=16.8969
# Month=29, Predicted=17.3212, Expected=17.0022
# Month=30, Predicted=17.0565, Expected=17.4155
# Month=31, Predicted=17.6522, Expected=17.5332
# Month=32, Predicted=17.5637, Expected=17.2849
# Month=33, Predicted=17.0630, Expected=16.6063
# Month=34, Predicted=16.1333, Expected=15.8228
# Month=35, Predicted=15.2825, Expected=15.4543
# Month=36, Predicted=15.4515, Expected=15.6138
# Month=37, Predicted=16.0618, Expected=15.6954
# Month=38, Predicted=15.7440, Expected=16.7627
# Month=39, Predicted=17.3786, Expected=16.4941
# Month=40, Predicted=16.6511, Expected=17.7345
# Month=41, Predicted=18.3722, Expected=18.6944
# Month=42, Predicted=19.1073, Expected=19.1228
# Month=43, Predicted=19.3343, Expected=19.5704
# Month=44, Predicted=19.7554, Expected=19.2258
# Month=45, Predicted=19.0737, Expected=18.2178
# Month=46, Predicted=17.5928, Expected=17.2135
# Month=47, Predicted=16.5843, Expected=16.6554
# Month=48, Predicted=16.6086, Expected=16.8225
# Month=49, Predicted=17.5234, Expected=15.7773
# Month=50, Predicted=15.4081, Expected=15.7224
# Month=51, Predicted=16.3292, Expected=15.9967
# Month=52, Predicted=16.4135, Expected=17.0162
# Month=53, Predicted=17.6090, Expected=17.5568
# Month=54, Predicted=17.8235, Expected=17.8404
# Month=55, Predicted=17.9316, Expected=17.8664
# Month=56, Predicted=17.8042, Expected=17.5659
# Month=57, Predicted=17.3111, Expected=17.0753
# Month=58, Predicted=16.7022, Expected=16.6502
# Month=59, Predicted=16.3824, Expected=16.4285
# Month=60, Predicted=16.3710, Expected=16.5878
# Run 15 — RMSE: 0.488281, MSE: 0.238419, NMSE: 0.0019653397
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.2986, Expected=13.7084
# Month=2, Predicted=14.0694, Expected=13.8026
# Month=3, Predicted=13.8424, Expected=14.3883
# Month=4, Predicted=14.6713, Expected=15.0615
# Month=5, Predicted=15.4217, Expected=15.6682
# Month=6, Predicted=15.9708, Expected=15.8360
# Month=7, Predicted=15.8889, Expected=15.7178
# Month=8, Predicted=15.5684, Expected=15.3110
# Month=9, Predicted=14.9837, Expected=14.7667
# Month=10, Predicted=14.3797, Expected=13.5419
# Month=11, Predicted=12.6975, Expected=13.5869
# Month=12, Predicted=13.9083, Expected=14.5144
# Month=13, Predicted=15.1636, Expected=14.3947
# Month=14, Predicted=14.3051, Expected=14.4996
# Month=15, Predicted=14.4905, Expected=14.7474
# Month=16, Predicted=14.9183, Expected=15.8019
# Month=17, Predicted=16.2282, Expected=16.5221
# Month=18, Predicted=16.8932, Expected=16.5417
# Month=19, Predicted=16.4989, Expected=16.7210
# Month=20, Predicted=16.7696, Expected=16.4288
# Month=21, Predicted=16.2114, Expected=15.7719
# Month=22, Predicted=15.2510, Expected=15.2959
# Month=23, Predicted=15.0228, Expected=15.1318
# Month=24, Predicted=15.1564, Expected=15.5377
# Month=25, Predicted=15.8821, Expected=15.8371
# Month=26, Predicted=16.0320, Expected=16.3719
# Month=27, Predicted=16.6410, Expected=16.3365
# Month=28, Predicted=16.2774, Expected=16.8969
# Month=29, Predicted=17.1769, Expected=17.0022
# Month=30, Predicted=17.0651, Expected=17.4155
# Month=31, Predicted=17.6150, Expected=17.5332
# Month=32, Predicted=17.5871, Expected=17.2849
# Month=33, Predicted=17.0552, Expected=16.6063
# Month=34, Predicted=16.0768, Expected=15.8228
# Month=35, Predicted=15.2984, Expected=15.4543
# Month=36, Predicted=15.3700, Expected=15.6138
# Month=37, Predicted=15.8981, Expected=15.6954
# Month=38, Predicted=15.7858, Expected=16.7627
# Month=39, Predicted=17.1722, Expected=16.4941
# Month=40, Predicted=16.3086, Expected=17.7345
# Month=41, Predicted=18.0529, Expected=18.6944
# Month=42, Predicted=19.1862, Expected=19.1228
# Month=43, Predicted=19.3265, Expected=19.5704
# Month=44, Predicted=19.7755, Expected=19.2258
# Month=45, Predicted=18.9504, Expected=18.2178
# Month=46, Predicted=17.4180, Expected=17.2135
# Month=47, Predicted=16.6677, Expected=16.6554
# Month=48, Predicted=16.5458, Expected=16.8225
# Month=49, Predicted=17.2009, Expected=15.7773
# Month=50, Predicted=15.1291, Expected=15.7224
# Month=51, Predicted=15.7753, Expected=15.9967
# Month=52, Predicted=16.3810, Expected=17.0162
# Month=53, Predicted=17.4552, Expected=17.5568
# Month=54, Predicted=17.8415, Expected=17.8404
# Month=55, Predicted=17.9549, Expected=17.8664
# Month=56, Predicted=17.8231, Expected=17.5659
# Month=57, Predicted=17.3077, Expected=17.0753
# Month=58, Predicted=16.6997, Expected=16.6502
# Month=59, Predicted=16.3962, Expected=16.4285
# Month=60, Predicted=16.3630, Expected=16.5878
# Run 16 — RMSE: 0.485013, MSE: 0.235238, NMSE: 0.0018739606
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.3615, Expected=13.7084
# Month=2, Predicted=14.1917, Expected=13.8026
# Month=3, Predicted=13.8831, Expected=14.3883
# Month=4, Predicted=14.6044, Expected=15.0615
# Month=5, Predicted=15.4581, Expected=15.6682
# Month=6, Predicted=15.9109, Expected=15.8360
# Month=7, Predicted=15.8642, Expected=15.7178
# Month=8, Predicted=15.5232, Expected=15.3110
# Month=9, Predicted=14.9797, Expected=14.7667
# Month=10, Predicted=14.3756, Expected=13.5419
# Month=11, Predicted=12.8982, Expected=13.5869
# Month=12, Predicted=14.1630, Expected=14.5144
# Month=13, Predicted=15.7186, Expected=14.3947
# Month=14, Predicted=14.4279, Expected=14.4996
# Month=15, Predicted=14.3391, Expected=14.7474
# Month=16, Predicted=14.9546, Expected=15.8019
# Month=17, Predicted=16.3176, Expected=16.5221
# Month=18, Predicted=16.7756, Expected=16.5417
# Month=19, Predicted=16.5037, Expected=16.7210
# Month=20, Predicted=16.6549, Expected=16.4288
# Month=21, Predicted=16.2606, Expected=15.7719
# Month=22, Predicted=15.2793, Expected=15.2959
# Month=23, Predicted=14.9823, Expected=15.1318
# Month=24, Predicted=15.1704, Expected=15.5377
# Month=25, Predicted=16.0316, Expected=15.8371
# Month=26, Predicted=16.0980, Expected=16.3719
# Month=27, Predicted=16.6113, Expected=16.3365
# Month=28, Predicted=16.3156, Expected=16.8969
# Month=29, Predicted=17.1058, Expected=17.0022
# Month=30, Predicted=17.1263, Expected=17.4155
# Month=31, Predicted=17.5346, Expected=17.5332
# Month=32, Predicted=17.6135, Expected=17.2849
# Month=33, Predicted=17.0397, Expected=16.6063
# Month=34, Predicted=16.1250, Expected=15.8228
# Month=35, Predicted=15.3387, Expected=15.4543
# Month=36, Predicted=15.3501, Expected=15.6138
# Month=37, Predicted=16.0307, Expected=15.6954
# Month=38, Predicted=15.8561, Expected=16.7627
# Month=39, Predicted=17.2381, Expected=16.4941
# Month=40, Predicted=16.5032, Expected=17.7345
# Month=41, Predicted=17.9098, Expected=18.6944
# Month=42, Predicted=19.1516, Expected=19.1228
# Month=43, Predicted=19.2129, Expected=19.5704
# Month=44, Predicted=19.6986, Expected=19.2258
# Month=45, Predicted=19.0309, Expected=18.2178
# Month=46, Predicted=17.5416, Expected=17.2135
# Month=47, Predicted=16.6948, Expected=16.6554
# Month=48, Predicted=16.5604, Expected=16.8225
# Month=49, Predicted=17.4087, Expected=15.7773
# Month=50, Predicted=15.3974, Expected=15.7224
# Month=51, Predicted=15.7573, Expected=15.9967
# Month=52, Predicted=16.6208, Expected=17.0162
# Month=53, Predicted=17.5856, Expected=17.5568
# Month=54, Predicted=17.7421, Expected=17.8404
# Month=55, Predicted=17.8939, Expected=17.8664
# Month=56, Predicted=17.7851, Expected=17.5659
# Month=57, Predicted=17.2976, Expected=17.0753
# Month=58, Predicted=16.6965, Expected=16.6502
# Month=59, Predicted=16.3695, Expected=16.4285
# Month=60, Predicted=16.3575, Expected=16.5878
# Run 17 — RMSE: 0.491149, MSE: 0.241227, NMSE: 0.0020218654
#
# ===== RUN 18/30 =====
# Training complete for run 18
# Month=1, Predicted=13.3347, Expected=13.7084
# Month=2, Predicted=14.1637, Expected=13.8026
# Month=3, Predicted=13.9030, Expected=14.3883
# Month=4, Predicted=14.7263, Expected=15.0615
# Month=5, Predicted=15.4472, Expected=15.6682
# Month=6, Predicted=15.9675, Expected=15.8360
# Month=7, Predicted=15.9508, Expected=15.7178
# Month=8, Predicted=15.5883, Expected=15.3110
# Month=9, Predicted=14.9959, Expected=14.7667
# Month=10, Predicted=14.3685, Expected=13.5419
# Month=11, Predicted=12.7779, Expected=13.5869
# Month=12, Predicted=14.2506, Expected=14.5144
# Month=13, Predicted=15.4271, Expected=14.3947
# Month=14, Predicted=14.4617, Expected=14.4996
# Month=15, Predicted=14.4876, Expected=14.7474
# Month=16, Predicted=14.9322, Expected=15.8019
# Month=17, Predicted=16.3415, Expected=16.5221
# Month=18, Predicted=16.8059, Expected=16.5417
# Month=19, Predicted=16.6139, Expected=16.7210
# Month=20, Predicted=16.7687, Expected=16.4288
# Month=21, Predicted=16.2465, Expected=15.7719
# Month=22, Predicted=15.2873, Expected=15.2959
# Month=23, Predicted=14.9970, Expected=15.1318
# Month=24, Predicted=15.1689, Expected=15.5377
# Month=25, Predicted=16.0157, Expected=15.8371
# Month=26, Predicted=16.0628, Expected=16.3719
# Month=27, Predicted=16.6786, Expected=16.3365
# Month=28, Predicted=16.3487, Expected=16.8969
# Month=29, Predicted=17.2506, Expected=17.0022
# Month=30, Predicted=17.1166, Expected=17.4155
# Month=31, Predicted=17.6399, Expected=17.5332
# Month=32, Predicted=17.6163, Expected=17.2849
# Month=33, Predicted=17.0826, Expected=16.6063
# Month=34, Predicted=16.1227, Expected=15.8228
# Month=35, Predicted=15.2722, Expected=15.4543
# Month=36, Predicted=15.3951, Expected=15.6138
# Month=37, Predicted=16.0139, Expected=15.6954
# Month=38, Predicted=15.7912, Expected=16.7627
# Month=39, Predicted=17.3027, Expected=16.4941
# Month=40, Predicted=16.5442, Expected=17.7345
# Month=41, Predicted=18.2164, Expected=18.6944
# Month=42, Predicted=19.0867, Expected=19.1228
# Month=43, Predicted=19.2929, Expected=19.5704
# Month=44, Predicted=19.8092, Expected=19.2258
# Month=45, Predicted=19.0676, Expected=18.2178
# Month=46, Predicted=17.5374, Expected=17.2135
# Month=47, Predicted=16.6471, Expected=16.6554
# Month=48, Predicted=16.5708, Expected=16.8225
# Month=49, Predicted=17.4476, Expected=15.7773
# Month=50, Predicted=15.3167, Expected=15.7224
# Month=51, Predicted=16.1419, Expected=15.9967
# Month=52, Predicted=16.4356, Expected=17.0162
# Month=53, Predicted=17.5811, Expected=17.5568
# Month=54, Predicted=17.7729, Expected=17.8404
# Month=55, Predicted=18.0013, Expected=17.8664
# Month=56, Predicted=17.8432, Expected=17.5659
# Month=57, Predicted=17.3260, Expected=17.0753
# Month=58, Predicted=16.7019, Expected=16.6502
# Month=59, Predicted=16.3708, Expected=16.4285
# Month=60, Predicted=16.3556, Expected=16.5878
# Run 18 — RMSE: 0.486120, MSE: 0.236312, NMSE: 0.0019213958
#
# ===== RUN 19/30 =====
# Training complete for run 19
# Month=1, Predicted=13.2922, Expected=13.7084
# Month=2, Predicted=14.1170, Expected=13.8026
# Month=3, Predicted=13.8589, Expected=14.3883
# Month=4, Predicted=14.7290, Expected=15.0615
# Month=5, Predicted=15.4342, Expected=15.6682
# Month=6, Predicted=15.9620, Expected=15.8360
# Month=7, Predicted=15.8991, Expected=15.7178
# Month=8, Predicted=15.5984, Expected=15.3110
# Month=9, Predicted=15.0226, Expected=14.7667
# Month=10, Predicted=14.4088, Expected=13.5419
# Month=11, Predicted=12.7582, Expected=13.5869
# Month=12, Predicted=13.9522, Expected=14.5144
# Month=13, Predicted=15.3236, Expected=14.3947
# Month=14, Predicted=14.3129, Expected=14.4996
# Month=15, Predicted=14.5113, Expected=14.7474
# Month=16, Predicted=14.9225, Expected=15.8019
# Month=17, Predicted=16.2951, Expected=16.5221
# Month=18, Predicted=16.8508, Expected=16.5417
# Month=19, Predicted=16.5029, Expected=16.7210
# Month=20, Predicted=16.7946, Expected=16.4288
# Month=21, Predicted=16.2270, Expected=15.7719
# Month=22, Predicted=15.3163, Expected=15.2959
# Month=23, Predicted=15.0317, Expected=15.1318
# Month=24, Predicted=15.1265, Expected=15.5377
# Month=25, Predicted=15.9229, Expected=15.8371
# Month=26, Predicted=16.0559, Expected=16.3719
# Month=27, Predicted=16.6801, Expected=16.3365
# Month=28, Predicted=16.3041, Expected=16.8969
# Month=29, Predicted=17.2449, Expected=17.0022
# Month=30, Predicted=17.0804, Expected=17.4155
# Month=31, Predicted=17.6566, Expected=17.5332
# Month=32, Predicted=17.6031, Expected=17.2849
# Month=33, Predicted=17.0930, Expected=16.6063
# Month=34, Predicted=16.1424, Expected=15.8228
# Month=35, Predicted=15.3231, Expected=15.4543
# Month=36, Predicted=15.3546, Expected=15.6138
# Month=37, Predicted=15.9105, Expected=15.6954
# Month=38, Predicted=15.7935, Expected=16.7627
# Month=39, Predicted=17.2553, Expected=16.4941
# Month=40, Predicted=16.3188, Expected=17.7345
# Month=41, Predicted=18.1377, Expected=18.6944
# Month=42, Predicted=19.1441, Expected=19.1228
# Month=43, Predicted=19.2742, Expected=19.5704
# Month=44, Predicted=19.7923, Expected=19.2258
# Month=45, Predicted=18.9947, Expected=18.2178
# Month=46, Predicted=17.5160, Expected=17.2135
# Month=47, Predicted=16.6231, Expected=16.6554
# Month=48, Predicted=16.4959, Expected=16.8225
# Month=49, Predicted=17.2510, Expected=15.7773
# Month=50, Predicted=15.2063, Expected=15.7224
# Month=51, Predicted=15.9413, Expected=15.9967
# Month=52, Predicted=16.3985, Expected=17.0162
# Month=53, Predicted=17.5334, Expected=17.5568
# Month=54, Predicted=17.7961, Expected=17.8404
# Month=55, Predicted=17.9609, Expected=17.8664
# Month=56, Predicted=17.8497, Expected=17.5659
# Month=57, Predicted=17.3431, Expected=17.0753
# Month=58, Predicted=16.7413, Expected=16.6502
# Month=59, Predicted=16.4007, Expected=16.4285
# Month=60, Predicted=16.3465, Expected=16.5878
# Run 19 — RMSE: 0.492326, MSE: 0.242385, NMSE: 0.0019474307
#
# ===== RUN 20/30 =====

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
