# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# GPU Acceleration Settings (CUDA + Apple Metal Support)
# ============================================================
import tensorflow as tf
import platform

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        # Detect GPU type
        if platform.system() == 'Darwin' and platform.processor() == 'arm':
            print(f"Apple Metal GPU Enabled: Found {len(physical_devices)} GPU(s) via tensorflow-metal")
            print(f"  Chipset: Apple {platform.machine()} (M-series)")
        else:
            print(f"CUDA GPU Enabled: Found {len(physical_devices)} GPU(s) - Memory Growth Set")
        for d in physical_devices:
            print(f"  Device: {d.name}")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    if platform.system() == 'Darwin' and platform.processor() == 'arm':
        print("Apple Silicon detected but no GPU found.")
        print("  Install tensorflow-metal: pip install tensorflow-metal")
    else:
        print("No GPU found. Falling back to CPU.")
        print("  For CUDA: ensure NVIDIA drivers + CUDA toolkit are installed.")

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    496
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 505 (1.97 KB)
# Trainable params: 505 (1.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        rnn_layer = model.layers[1]
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Monthly Milk Production (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Hybrid (Feature Aug + Gate) — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Hybrid (Feature Aug + Gate) — Monthly Milk Production\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.509499)
# ================================================================================
#
# Data shape: (168,)
# First 5 values: [589.25307559 560.92955441 640.32999695 656.77598287 726.88069898]
# Supervised data shape: (167, 3)
# Train: (107, 3), Test: (60, 3)
# X_train shape: (107, 1, 2), y_train shape: (107,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=746.6335, Expected=804.1312
# Month=2, Predicted=815.7746, Expected=755.9621
# Month=3, Predicted=813.4581, Expected=859.0224
# Month=4, Predicted=858.1814, Expected=877.9865
# Month=5, Predicted=946.5409, Expected=942.0307
# Month=6, Predicted=911.6545, Expected=914.2550
# Month=7, Predicted=860.7225, Expected=868.9020
# Month=8, Predicted=849.6498, Expected=834.1536
# Month=9, Predicted=810.9689, Expected=789.9823
# Month=10, Predicted=768.7995, Expected=799.4046
# Month=11, Predicted=790.1133, Expected=763.5823
# Month=12, Predicted=812.1913, Expected=800.3831
# Month=13, Predicted=795.3993, Expected=826.4030
# Month=14, Predicted=794.7156, Expected=798.5367
# Month=15, Predicted=863.1289, Expected=890.7147
# Month=16, Predicted=913.7762, Expected=899.2858
# Month=17, Predicted=948.3399, Expected=961.2990
# Month=18, Predicted=989.3228, Expected=936.1160
# Month=19, Predicted=883.5110, Expected=893.4953
# Month=20, Predicted=876.6079, Expected=854.7115
# Month=21, Predicted=831.4487, Expected=809.0508
# Month=22, Predicted=785.3273, Expected=809.7435
# Month=23, Predicted=798.2830, Expected=765.2099
# Month=24, Predicted=789.2973, Expected=805.0349
# Month=25, Predicted=794.0845, Expected=820.4588
# Month=26, Predicted=783.1520, Expected=773.2413
# Month=27, Predicted=824.8924, Expected=882.5316
# Month=28, Predicted=885.1706, Expected=898.7897
# Month=29, Predicted=967.8075, Expected=956.6009
# Month=30, Predicted=940.1016, Expected=923.8359
# Month=31, Predicted=902.5489, Expected=881.4145
# Month=32, Predicted=860.7854, Expected=836.3729
# Month=33, Predicted=811.0368, Expected=784.1159
# Month=34, Predicted=755.1014, Expected=791.6660
# Month=35, Predicted=777.5150, Expected=759.1810
# Month=36, Predicted=806.2445, Expected=802.0941
# Month=37, Predicted=800.6603, Expected=828.1324
# Month=38, Predicted=811.1086, Expected=778.3983
# Month=39, Predicted=842.9905, Expected=888.3698
# Month=40, Predicted=888.9004, Expected=901.3272
# Month=41, Predicted=965.5463, Expected=969.2659
# Month=42, Predicted=959.0181, Expected=947.1513
# Month=43, Predicted=890.5168, Expected=908.1276
# Month=44, Predicted=894.0973, Expected=867.1765
# Month=45, Predicted=844.9240, Expected=814.6535
# Month=46, Predicted=787.4919, Expected=812.1183
# Month=47, Predicted=796.0644, Expected=773.1493
# Month=48, Predicted=795.1094, Expected=812.6360
# Month=49, Predicted=805.5603, Expected=834.9506
# Month=50, Predicted=804.7261, Expected=782.2414
# Month=51, Predicted=842.0281, Expected=891.3930
# Month=52, Predicted=889.4518, Expected=903.3345
# Month=53, Predicted=965.4407, Expected=965.5034
# Month=54, Predicted=969.8687, Expected=937.4010
# Month=55, Predicted=888.6632, Expected=896.5903
# Month=56, Predicted=878.8665, Expected=857.5819
# Month=57, Predicted=835.1490, Expected=817.4908
# Month=58, Predicted=795.6230, Expected=827.2103
# Month=59, Predicted=820.4116, Expected=797.4188
# Month=60, Predicted=850.2870, Expected=843.9664
# Run 1 — RMSE: 26.786238, MSE: 717.502538, NMSE: 0.0031515841
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=751.7828, Expected=804.1312
# Month=2, Predicted=774.7402, Expected=755.9621
# Month=3, Predicted=765.0570, Expected=859.0224
# Month=4, Predicted=858.5648, Expected=877.9865
# Month=5, Predicted=954.2726, Expected=942.0307
# Month=6, Predicted=909.2563, Expected=914.2550
# Month=7, Predicted=864.1981, Expected=868.9020
# Month=8, Predicted=852.1708, Expected=834.1536
# Month=9, Predicted=807.2171, Expected=789.9823
# Month=10, Predicted=767.4611, Expected=799.4046
# Month=11, Predicted=792.4878, Expected=763.5823
# Month=12, Predicted=811.8735, Expected=800.3831
# Month=13, Predicted=800.3730, Expected=826.4030
# Month=14, Predicted=789.3557, Expected=798.5367
# Month=15, Predicted=856.3990, Expected=890.7147
# Month=16, Predicted=906.0474, Expected=899.2858
# Month=17, Predicted=933.4089, Expected=961.2990
# Month=18, Predicted=976.4246, Expected=936.1160
# Month=19, Predicted=890.2302, Expected=893.4953
# Month=20, Predicted=881.9622, Expected=854.7115
# Month=21, Predicted=827.4918, Expected=809.0508
# Month=22, Predicted=781.0782, Expected=809.7435
# Month=23, Predicted=800.2262, Expected=765.2099
# Month=24, Predicted=791.9835, Expected=805.0349
# Month=25, Predicted=796.4139, Expected=820.4588
# Month=26, Predicted=789.1476, Expected=773.2413
# Month=27, Predicted=823.7239, Expected=882.5316
# Month=28, Predicted=883.9330, Expected=898.7897
# Month=29, Predicted=976.8761, Expected=956.6009
# Month=30, Predicted=941.3338, Expected=923.8359
# Month=31, Predicted=896.9574, Expected=881.4145
# Month=32, Predicted=861.0229, Expected=836.3729
# Month=33, Predicted=804.8659, Expected=784.1159
# Month=34, Predicted=744.5117, Expected=791.6660
# Month=35, Predicted=778.1383, Expected=759.1810
# Month=36, Predicted=805.3082, Expected=802.0941
# Month=37, Predicted=805.9854, Expected=828.1324
# Month=38, Predicted=803.8849, Expected=778.3983
# Month=39, Predicted=832.3950, Expected=888.3698
# Month=40, Predicted=888.0881, Expected=901.3272
# Month=41, Predicted=971.4719, Expected=969.2659
# Month=42, Predicted=956.8177, Expected=947.1513
# Month=43, Predicted=895.8331, Expected=908.1276
# Month=44, Predicted=902.9613, Expected=867.1765
# Month=45, Predicted=841.9309, Expected=814.6535
# Month=46, Predicted=778.8423, Expected=812.1183
# Month=47, Predicted=796.3010, Expected=773.1493
# Month=48, Predicted=797.5090, Expected=812.6360
# Month=49, Predicted=809.5291, Expected=834.9506
# Month=50, Predicted=802.7531, Expected=782.2414
# Month=51, Predicted=837.0120, Expected=891.3930
# Month=52, Predicted=888.9165, Expected=903.3345
# Month=53, Predicted=969.6459, Expected=965.5034
# Month=54, Predicted=964.7369, Expected=937.4010
# Month=55, Predicted=893.0676, Expected=896.5903
# Month=56, Predicted=882.7777, Expected=857.5819
# Month=57, Predicted=832.0609, Expected=817.4908
# Month=58, Predicted=793.3231, Expected=827.2103
# Month=59, Predicted=823.7649, Expected=797.4188
# Month=60, Predicted=849.0052, Expected=843.9664
# Run 2 — RMSE: 28.350396, MSE: 803.744965, NMSE: 0.0033478343
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=752.1307, Expected=804.1312
# Month=2, Predicted=798.0579, Expected=755.9621
# Month=3, Predicted=782.4253, Expected=859.0224
# Month=4, Predicted=855.8435, Expected=877.9865
# Month=5, Predicted=964.9285, Expected=942.0307
# Month=6, Predicted=912.9660, Expected=914.2550
# Month=7, Predicted=865.3236, Expected=868.9020
# Month=8, Predicted=858.0694, Expected=834.1536
# Month=9, Predicted=805.1198, Expected=789.9823
# Month=10, Predicted=770.9607, Expected=799.4046
# Month=11, Predicted=788.5033, Expected=763.5823
# Month=12, Predicted=810.9446, Expected=800.3831
# Month=13, Predicted=800.4064, Expected=826.4030
# Month=14, Predicted=793.9378, Expected=798.5367
# Month=15, Predicted=853.6963, Expected=890.7147
# Month=16, Predicted=917.8589, Expected=899.2858
# Month=17, Predicted=933.9818, Expected=961.2990
# Month=18, Predicted=961.7014, Expected=936.1160
# Month=19, Predicted=887.9070, Expected=893.4953
# Month=20, Predicted=887.5114, Expected=854.7115
# Month=21, Predicted=827.4472, Expected=809.0508
# Month=22, Predicted=783.8001, Expected=809.7435
# Month=23, Predicted=795.2593, Expected=765.2099
# Month=24, Predicted=794.8927, Expected=805.0349
# Month=25, Predicted=791.9108, Expected=820.4588
# Month=26, Predicted=785.3563, Expected=773.2413
# Month=27, Predicted=820.9128, Expected=882.5316
# Month=28, Predicted=882.8088, Expected=898.7897
# Month=29, Predicted=992.3095, Expected=956.6009
# Month=30, Predicted=935.1114, Expected=923.8359
# Month=31, Predicted=894.1735, Expected=881.4145
# Month=32, Predicted=865.3631, Expected=836.3729
# Month=33, Predicted=806.4079, Expected=784.1159
# Month=34, Predicted=747.1446, Expected=791.6660
# Month=35, Predicted=769.3936, Expected=759.1810
# Month=36, Predicted=805.9531, Expected=802.0941
# Month=37, Predicted=807.8259, Expected=828.1324
# Month=38, Predicted=803.4253, Expected=778.3983
# Month=39, Predicted=834.3638, Expected=888.3698
# Month=40, Predicted=884.8926, Expected=901.3272
# Month=41, Predicted=986.2337, Expected=969.2659
# Month=42, Predicted=950.1747, Expected=947.1513
# Month=43, Predicted=892.7893, Expected=908.1276
# Month=44, Predicted=907.9263, Expected=867.1765
# Month=45, Predicted=843.7566, Expected=814.6535
# Month=46, Predicted=783.1267, Expected=812.1183
# Month=47, Predicted=787.3469, Expected=773.1493
# Month=48, Predicted=801.3351, Expected=812.6360
# Month=49, Predicted=807.9789, Expected=834.9506
# Month=50, Predicted=801.9212, Expected=782.2414
# Month=51, Predicted=834.6090, Expected=891.3930
# Month=52, Predicted=883.0628, Expected=903.3345
# Month=53, Predicted=983.2608, Expected=965.5034
# Month=54, Predicted=953.2908, Expected=937.4010
# Month=55, Predicted=891.7673, Expected=896.5903
# Month=56, Predicted=887.5158, Expected=857.5819
# Month=57, Predicted=832.6844, Expected=817.4908
# Month=58, Predicted=794.5910, Expected=827.2103
# Month=59, Predicted=822.0966, Expected=797.4188
# Month=60, Predicted=848.2696, Expected=843.9664
# Run 3 — RMSE: 28.066907, MSE: 787.751282, NMSE: 0.0032454860
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=751.5897, Expected=804.1312
# Month=2, Predicted=799.4135, Expected=755.9621
# Month=3, Predicted=778.8492, Expected=859.0224
# Month=4, Predicted=856.3718, Expected=877.9865
# Month=5, Predicted=964.0298, Expected=942.0307
# Month=6, Predicted=913.1360, Expected=914.2550
# Month=7, Predicted=865.7146, Expected=868.9020
# Month=8, Predicted=849.8254, Expected=834.1536
# Month=9, Predicted=806.2921, Expected=789.9823
# Month=10, Predicted=771.3906, Expected=799.4046
# Month=11, Predicted=791.3512, Expected=763.5823
# Month=12, Predicted=811.6415, Expected=800.3831
# Month=13, Predicted=799.7967, Expected=826.4030
# Month=14, Predicted=798.8719, Expected=798.5367
# Month=15, Predicted=854.5729, Expected=890.7147
# Month=16, Predicted=915.5477, Expected=899.2858
# Month=17, Predicted=931.1547, Expected=961.2990
# Month=18, Predicted=957.6570, Expected=936.1160
# Month=19, Predicted=887.8698, Expected=893.4953
# Month=20, Predicted=879.3097, Expected=854.7115
# Month=21, Predicted=827.9500, Expected=809.0508
# Month=22, Predicted=784.6275, Expected=809.7435
# Month=23, Predicted=798.3382, Expected=765.2099
# Month=24, Predicted=795.9130, Expected=805.0349
# Month=25, Predicted=792.6614, Expected=820.4588
# Month=26, Predicted=788.8857, Expected=773.2413
# Month=27, Predicted=819.6072, Expected=882.5316
# Month=28, Predicted=885.7877, Expected=898.7897
# Month=29, Predicted=991.3245, Expected=956.6009
# Month=30, Predicted=932.7910, Expected=923.8359
# Month=31, Predicted=890.2973, Expected=881.4145
# Month=32, Predicted=858.7053, Expected=836.3729
# Month=33, Predicted=807.2155, Expected=784.1159
# Month=34, Predicted=748.8861, Expected=791.6660
# Month=35, Predicted=773.8410, Expected=759.1810
# Month=36, Predicted=806.3660, Expected=802.0941
# Month=37, Predicted=807.0637, Expected=828.1324
# Month=38, Predicted=807.4096, Expected=778.3983
# Month=39, Predicted=834.4346, Expected=888.3698
# Month=40, Predicted=887.7955, Expected=901.3272
# Month=41, Predicted=984.7627, Expected=969.2659
# Month=42, Predicted=947.6504, Expected=947.1513
# Month=43, Predicted=899.6589, Expected=908.1276
# Month=44, Predicted=898.8243, Expected=867.1765
# Month=45, Predicted=843.4787, Expected=814.6535
# Month=46, Predicted=783.9864, Expected=812.1183
# Month=47, Predicted=791.3877, Expected=773.1493
# Month=48, Predicted=802.3053, Expected=812.6360
# Month=49, Predicted=808.3177, Expected=834.9506
# Month=50, Predicted=807.7443, Expected=782.2414
# Month=51, Predicted=834.6764, Expected=891.3930
# Month=52, Predicted=886.3475, Expected=903.3345
# Month=53, Predicted=981.6548, Expected=965.5034
# Month=54, Predicted=949.7267, Expected=937.4010
# Month=55, Predicted=891.0991, Expected=896.5903
# Month=56, Predicted=879.7121, Expected=857.5819
# Month=57, Predicted=833.0812, Expected=817.4908
# Month=58, Predicted=795.4600, Expected=827.2103
# Month=59, Predicted=824.6817, Expected=797.4188
# Month=60, Predicted=847.3072, Expected=843.9664
# Run 4 — RMSE: 27.644378, MSE: 764.211649, NMSE: 0.0032901020
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=750.7054, Expected=804.1312
# Month=2, Predicted=803.0659, Expected=755.9621
# Month=3, Predicted=787.1841, Expected=859.0224
# Month=4, Predicted=857.5534, Expected=877.9865
# Month=5, Predicted=950.6815, Expected=942.0307
# Month=6, Predicted=915.7319, Expected=914.2550
# Month=7, Predicted=864.5773, Expected=868.9020
# Month=8, Predicted=851.8365, Expected=834.1536
# Month=9, Predicted=806.2855, Expected=789.9823
# Month=10, Predicted=768.9216, Expected=799.4046
# Month=11, Predicted=788.4563, Expected=763.5823
# Month=12, Predicted=812.1025, Expected=800.3831
# Month=13, Predicted=799.0109, Expected=826.4030
# Month=14, Predicted=791.3074, Expected=798.5367
# Month=15, Predicted=850.7206, Expected=890.7147
# Month=16, Predicted=919.3897, Expected=899.2858
# Month=17, Predicted=941.0247, Expected=961.2990
# Month=18, Predicted=963.7681, Expected=936.1160
# Month=19, Predicted=885.6328, Expected=893.4953
# Month=20, Predicted=880.6327, Expected=854.7115
# Month=21, Predicted=827.7825, Expected=809.0508
# Month=22, Predicted=782.9481, Expected=809.7435
# Month=23, Predicted=795.5527, Expected=765.2099
# Month=24, Predicted=794.1887, Expected=805.0349
# Month=25, Predicted=792.0374, Expected=820.4588
# Month=26, Predicted=782.8733, Expected=773.2413
# Month=27, Predicted=819.7514, Expected=882.5316
# Month=28, Predicted=884.6405, Expected=898.7897
# Month=29, Predicted=973.6870, Expected=956.6009
# Month=30, Predicted=933.9382, Expected=923.8359
# Month=31, Predicted=896.9923, Expected=881.4145
# Month=32, Predicted=861.5452, Expected=836.3729
# Month=33, Predicted=806.9426, Expected=784.1159
# Month=34, Predicted=749.1215, Expected=791.6660
# Month=35, Predicted=771.5389, Expected=759.1810
# Month=36, Predicted=807.1449, Expected=802.0941
# Month=37, Predicted=806.3764, Expected=828.1324
# Month=38, Predicted=800.9549, Expected=778.3983
# Month=39, Predicted=831.1642, Expected=888.3698
# Month=40, Predicted=886.9150, Expected=901.3272
# Month=41, Predicted=969.1199, Expected=969.2659
# Month=42, Predicted=948.9512, Expected=947.1513
# Month=43, Predicted=896.6652, Expected=908.1276
# Month=44, Predicted=899.4489, Expected=867.1765
# Month=45, Predicted=842.8722, Expected=814.6535
# Month=46, Predicted=783.4485, Expected=812.1183
# Month=47, Predicted=789.7508, Expected=773.1493
# Month=48, Predicted=801.1030, Expected=812.6360
# Month=49, Predicted=806.9638, Expected=834.9506
# Month=50, Predicted=798.2643, Expected=782.2414
# Month=51, Predicted=834.9306, Expected=891.3930
# Month=52, Predicted=885.4101, Expected=903.3345
# Month=53, Predicted=967.6660, Expected=965.5034
# Month=54, Predicted=954.2612, Expected=937.4010
# Month=55, Predicted=891.3769, Expected=896.5903
# Month=56, Predicted=881.5792, Expected=857.5819
# Month=57, Predicted=832.3470, Expected=817.4908
# Month=58, Predicted=793.5933, Expected=827.2103
# Month=59, Predicted=821.2208, Expected=797.4188
# Month=60, Predicted=846.0131, Expected=843.9664
# Run 5 — RMSE: 26.982580, MSE: 728.059614, NMSE: 0.0031995504
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=752.3530, Expected=804.1312
# Month=2, Predicted=796.7687, Expected=755.9621
# Month=3, Predicted=793.7709, Expected=859.0224
# Month=4, Predicted=861.8992, Expected=877.9865
# Month=5, Predicted=934.5113, Expected=942.0307
# Month=6, Predicted=917.6294, Expected=914.2550
# Month=7, Predicted=862.8407, Expected=868.9020
# Month=8, Predicted=848.6119, Expected=834.1536
# Month=9, Predicted=806.4713, Expected=789.9823
# Month=10, Predicted=768.3637, Expected=799.4046
# Month=11, Predicted=794.4042, Expected=763.5823
# Month=12, Predicted=807.5940, Expected=800.3831
# Month=13, Predicted=800.6425, Expected=826.4030
# Month=14, Predicted=792.4806, Expected=798.5367
# Month=15, Predicted=854.6792, Expected=890.7147
# Month=16, Predicted=916.9565, Expected=899.2858
# Month=17, Predicted=956.5254, Expected=961.2990
# Month=18, Predicted=970.6871, Expected=936.1160
# Month=19, Predicted=885.9853, Expected=893.4953
# Month=20, Predicted=877.9703, Expected=854.7115
# Month=21, Predicted=827.0548, Expected=809.0508
# Month=22, Predicted=782.1852, Expected=809.7435
# Month=23, Predicted=801.5785, Expected=765.2099
# Month=24, Predicted=790.6744, Expected=805.0349
# Month=25, Predicted=795.1730, Expected=820.4588
# Month=26, Predicted=784.6544, Expected=773.2413
# Month=27, Predicted=817.9515, Expected=882.5316
# Month=28, Predicted=890.4520, Expected=898.7897
# Month=29, Predicted=953.7773, Expected=956.6009
# Month=30, Predicted=935.3465, Expected=923.8359
# Month=31, Predicted=899.6632, Expected=881.4145
# Month=32, Predicted=857.5732, Expected=836.3729
# Month=33, Predicted=805.5896, Expected=784.1159
# Month=34, Predicted=746.8144, Expected=791.6660
# Month=35, Predicted=779.0561, Expected=759.1810
# Month=36, Predicted=802.3892, Expected=802.0941
# Month=37, Predicted=807.4366, Expected=828.1324
# Month=38, Predicted=789.8705, Expected=778.3983
# Month=39, Predicted=834.5409, Expected=888.3698
# Month=40, Predicted=892.9384, Expected=901.3272
# Month=41, Predicted=954.6114, Expected=969.2659
# Month=42, Predicted=952.4911, Expected=947.1513
# Month=43, Predicted=891.3622, Expected=908.1276
# Month=44, Predicted=898.2884, Expected=867.1765
# Month=45, Predicted=841.5964, Expected=814.6535
# Month=46, Predicted=781.0700, Expected=812.1183
# Month=47, Predicted=796.2833, Expected=773.1493
# Month=48, Predicted=797.4615, Expected=812.6360
# Month=49, Predicted=809.7446, Expected=834.9506
# Month=50, Predicted=799.1911, Expected=782.2414
# Month=51, Predicted=833.6223, Expected=891.3930
# Month=52, Predicted=892.3438, Expected=903.3345
# Month=53, Predicted=956.2075, Expected=965.5034
# Month=54, Predicted=959.1607, Expected=937.4010
# Month=55, Predicted=887.7219, Expected=896.5903
# Month=56, Predicted=878.8250, Expected=857.5819
# Month=57, Predicted=831.8278, Expected=817.4908
# Month=58, Predicted=793.7207, Expected=827.2103
# Month=59, Predicted=826.8072, Expected=797.4188
# Month=60, Predicted=844.2106, Expected=843.9664
# Run 6 — RMSE: 26.485958, MSE: 701.505950, NMSE: 0.0031875100
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=750.2451, Expected=804.1312
# Month=2, Predicted=801.9618, Expected=755.9621
# Month=3, Predicted=821.0420, Expected=859.0224
# Month=4, Predicted=846.7537, Expected=877.9865
# Month=5, Predicted=957.8265, Expected=942.0307
# Month=6, Predicted=913.1873, Expected=914.2550
# Month=7, Predicted=867.0583, Expected=868.9020
# Month=8, Predicted=858.3454, Expected=834.1536
# Month=9, Predicted=803.4386, Expected=789.9823
# Month=10, Predicted=774.7636, Expected=799.4046
# Month=11, Predicted=786.9670, Expected=763.5823
# Month=12, Predicted=816.7679, Expected=800.3831
# Month=13, Predicted=798.2860, Expected=826.4030
# Month=14, Predicted=795.4008, Expected=798.5367
# Month=15, Predicted=860.4641, Expected=890.7147
# Month=16, Predicted=914.2503, Expected=899.2858
# Month=17, Predicted=943.8455, Expected=961.2990
# Month=18, Predicted=975.0002, Expected=936.1160
# Month=19, Predicted=889.6206, Expected=893.4953
# Month=20, Predicted=888.7769, Expected=854.7115
# Month=21, Predicted=826.4565, Expected=809.0508
# Month=22, Predicted=786.0026, Expected=809.7435
# Month=23, Predicted=793.8209, Expected=765.2099
# Month=24, Predicted=807.9371, Expected=805.0349
# Month=25, Predicted=787.4470, Expected=820.4588
# Month=26, Predicted=785.2392, Expected=773.2413
# Month=27, Predicted=828.0196, Expected=882.5316
# Month=28, Predicted=875.5108, Expected=898.7897
# Month=29, Predicted=982.8036, Expected=956.6009
# Month=30, Predicted=936.6642, Expected=923.8359
# Month=31, Predicted=906.6267, Expected=881.4145
# Month=32, Predicted=863.8414, Expected=836.3729
# Month=33, Predicted=806.4044, Expected=784.1159
# Month=34, Predicted=747.4574, Expected=791.6660
# Month=35, Predicted=766.5749, Expected=759.1810
# Month=36, Predicted=811.7626, Expected=802.0941
# Month=37, Predicted=806.6475, Expected=828.1324
# Month=38, Predicted=807.4646, Expected=778.3983
# Month=39, Predicted=839.5162, Expected=888.3698
# Month=40, Predicted=876.3443, Expected=901.3272
# Month=41, Predicted=980.3390, Expected=969.2659
# Month=42, Predicted=952.5236, Expected=947.1513
# Month=43, Predicted=900.4890, Expected=908.1276
# Month=44, Predicted=910.0430, Expected=867.1765
# Month=45, Predicted=843.6771, Expected=814.6535
# Month=46, Predicted=784.3273, Expected=812.1183
# Month=47, Predicted=784.0460, Expected=773.1493
# Month=48, Predicted=814.2460, Expected=812.6360
# Month=49, Predicted=805.4262, Expected=834.9506
# Month=50, Predicted=805.2265, Expected=782.2414
# Month=51, Predicted=841.1197, Expected=891.3930
# Month=52, Predicted=873.8603, Expected=903.3345
# Month=53, Predicted=979.3312, Expected=965.5034
# Month=54, Predicted=957.8796, Expected=937.4010
# Month=55, Predicted=893.0180, Expected=896.5903
# Month=56, Predicted=887.6502, Expected=857.5819
# Month=57, Predicted=832.5803, Expected=817.4908
# Month=58, Predicted=796.3882, Expected=827.2103
# Month=59, Predicted=822.3226, Expected=797.4188
# Month=60, Predicted=850.7398, Expected=843.9664
# Run 7 — RMSE: 26.571135, MSE: 706.025235, NMSE: 0.0029925502
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=753.3535, Expected=804.1312
# Month=2, Predicted=800.8386, Expected=755.9621
# Month=3, Predicted=806.3722, Expected=859.0224
# Month=4, Predicted=860.7443, Expected=877.9865
# Month=5, Predicted=946.7487, Expected=942.0307
# Month=6, Predicted=912.9778, Expected=914.2550
# Month=7, Predicted=864.1056, Expected=868.9020
# Month=8, Predicted=852.1197, Expected=834.1536
# Month=9, Predicted=803.4945, Expected=789.9823
# Month=10, Predicted=766.8029, Expected=799.4046
# Month=11, Predicted=790.6435, Expected=763.5823
# Month=12, Predicted=815.8801, Expected=800.3831
# Month=13, Predicted=801.6079, Expected=826.4030
# Month=14, Predicted=795.3896, Expected=798.5367
# Month=15, Predicted=857.5666, Expected=890.7147
# Month=16, Predicted=917.5141, Expected=899.2858
# Month=17, Predicted=918.7709, Expected=961.2990
# Month=18, Predicted=962.7430, Expected=936.1160
# Month=19, Predicted=887.7940, Expected=893.4953
# Month=20, Predicted=881.7027, Expected=854.7115
# Month=21, Predicted=824.9668, Expected=809.0508
# Month=22, Predicted=780.0668, Expected=809.7435
# Month=23, Predicted=797.1749, Expected=765.2099
# Month=24, Predicted=804.5985, Expected=805.0349
# Month=25, Predicted=793.5528, Expected=820.4588
# Month=26, Predicted=786.2399, Expected=773.2413
# Month=27, Predicted=850.4600, Expected=882.5316
# Month=28, Predicted=888.9207, Expected=898.7897
# Month=29, Predicted=963.1837, Expected=956.6009
# Month=30, Predicted=936.3558, Expected=923.8359
# Month=31, Predicted=905.5688, Expected=881.4145
# Month=32, Predicted=860.3976, Expected=836.3729
# Month=33, Predicted=803.2671, Expected=784.1159
# Month=34, Predicted=743.7608, Expected=791.6660
# Month=35, Predicted=772.3356, Expected=759.1810
# Month=36, Predicted=802.4751, Expected=802.0941
# Month=37, Predicted=809.0918, Expected=828.1324
# Month=38, Predicted=806.7265, Expected=778.3983
# Month=39, Predicted=871.0954, Expected=888.3698
# Month=40, Predicted=891.0141, Expected=901.3272
# Month=41, Predicted=954.3606, Expected=969.2659
# Month=42, Predicted=952.2516, Expected=947.1513
# Month=43, Predicted=884.3821, Expected=908.1276
# Month=44, Predicted=902.2839, Expected=867.1765
# Month=45, Predicted=840.4815, Expected=814.6535
# Month=46, Predicted=778.9937, Expected=812.1183
# Month=47, Predicted=789.8291, Expected=773.1493
# Month=48, Predicted=797.1601, Expected=812.6360
# Month=49, Predicted=809.3209, Expected=834.9506
# Month=50, Predicted=804.6377, Expected=782.2414
# Month=51, Predicted=874.9386, Expected=891.3930
# Month=52, Predicted=889.2778, Expected=903.3345
# Month=53, Predicted=952.0000, Expected=965.5034
# Month=54, Predicted=956.3308, Expected=937.4010
# Month=55, Predicted=893.4413, Expected=896.5903
# Month=56, Predicted=882.2063, Expected=857.5819
# Month=57, Predicted=829.9169, Expected=817.4908
# Month=58, Predicted=791.5016, Expected=827.2103
# Month=59, Predicted=823.9475, Expected=797.4188
# Month=60, Predicted=842.7324, Expected=843.9664
# Run 8 — RMSE: 24.072483, MSE: 579.484434, NMSE: 0.0027223209
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=745.5034, Expected=804.1312
# Month=2, Predicted=815.1368, Expected=755.9621
# Month=3, Predicted=831.5731, Expected=859.0224
# Month=4, Predicted=849.6709, Expected=877.9865
# Month=5, Predicted=940.7002, Expected=942.0307
# Month=6, Predicted=913.8963, Expected=914.2550
# Month=7, Predicted=860.8636, Expected=868.9020
# Month=8, Predicted=847.7101, Expected=834.1536
# Month=9, Predicted=812.9617, Expected=789.9823
# Month=10, Predicted=768.7904, Expected=799.4046
# Month=11, Predicted=778.2126, Expected=763.5823
# Month=12, Predicted=820.1972, Expected=800.3831
# Month=13, Predicted=793.4974, Expected=826.4030
# Month=14, Predicted=791.8295, Expected=798.5367
# Month=15, Predicted=886.0243, Expected=890.7147
# Month=16, Predicted=914.3029, Expected=899.2858
# Month=17, Predicted=944.8162, Expected=961.2990
# Month=18, Predicted=968.4117, Expected=936.1160
# Month=19, Predicted=884.4612, Expected=893.4953
# Month=20, Predicted=872.8665, Expected=854.7115
# Month=21, Predicted=833.5195, Expected=809.0508
# Month=22, Predicted=787.8588, Expected=809.7435
# Month=23, Predicted=788.5515, Expected=765.2099
# Month=24, Predicted=789.8636, Expected=805.0349
# Month=25, Predicted=783.8430, Expected=820.4588
# Month=26, Predicted=782.8934, Expected=773.2413
# Month=27, Predicted=852.6426, Expected=882.5316
# Month=28, Predicted=878.8496, Expected=898.7897
# Month=29, Predicted=958.7098, Expected=956.6009
# Month=30, Predicted=935.0651, Expected=923.8359
# Month=31, Predicted=904.9659, Expected=881.4145
# Month=32, Predicted=860.2225, Expected=836.3729
# Month=33, Predicted=815.1809, Expected=784.1159
# Month=34, Predicted=762.9239, Expected=791.6660
# Month=35, Predicted=770.4740, Expected=759.1810
# Month=36, Predicted=807.9979, Expected=802.0941
# Month=37, Predicted=802.3855, Expected=828.1324
# Month=38, Predicted=803.9068, Expected=778.3983
# Month=39, Predicted=883.2033, Expected=888.3698
# Month=40, Predicted=880.0022, Expected=901.3272
# Month=41, Predicted=956.8131, Expected=969.2659
# Month=42, Predicted=950.7497, Expected=947.1513
# Month=43, Predicted=893.6385, Expected=908.1276
# Month=44, Predicted=895.5608, Expected=867.1765
# Month=45, Predicted=845.9846, Expected=814.6535
# Month=46, Predicted=793.4616, Expected=812.1183
# Month=47, Predicted=790.9264, Expected=773.1493
# Month=48, Predicted=794.3563, Expected=812.6360
# Month=49, Predicted=799.5869, Expected=834.9506
# Month=50, Predicted=799.1874, Expected=782.2414
# Month=51, Predicted=880.1611, Expected=891.3930
# Month=52, Predicted=876.9166, Expected=903.3345
# Month=53, Predicted=957.3611, Expected=965.5034
# Month=54, Predicted=955.4373, Expected=937.4010
# Month=55, Predicted=890.2040, Expected=896.5903
# Month=56, Predicted=875.3984, Expected=857.5819
# Month=57, Predicted=836.3899, Expected=817.4908
# Month=58, Predicted=796.2989, Expected=827.2103
# Month=59, Predicted=812.5181, Expected=797.4188
# Month=60, Predicted=853.6391, Expected=843.9664
# Run 9 — RMSE: 22.879014, MSE: 523.449272, NMSE: 0.0024475735
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=749.8192, Expected=804.1312
# Month=2, Predicted=806.3010, Expected=755.9621
# Month=3, Predicted=824.5689, Expected=859.0224
# Month=4, Predicted=857.9796, Expected=877.9865
# Month=5, Predicted=952.7884, Expected=942.0307
# Month=6, Predicted=910.7125, Expected=914.2550
# Month=7, Predicted=861.8044, Expected=868.9020
# Month=8, Predicted=847.6725, Expected=834.1536
# Month=9, Predicted=805.4173, Expected=789.9823
# Month=10, Predicted=765.0277, Expected=799.4046
# Month=11, Predicted=791.3242, Expected=763.5823
# Month=12, Predicted=815.0294, Expected=800.3831
# Month=13, Predicted=798.2705, Expected=826.4030
# Month=14, Predicted=794.6175, Expected=798.5367
# Month=15, Predicted=875.8929, Expected=890.7147
# Month=16, Predicted=906.4289, Expected=899.2858
# Month=17, Predicted=940.6017, Expected=961.2990
# Month=18, Predicted=988.6758, Expected=936.1160
# Month=19, Predicted=885.5824, Expected=893.4953
# Month=20, Predicted=877.2839, Expected=854.7115
# Month=21, Predicted=825.7093, Expected=809.0508
# Month=22, Predicted=779.4570, Expected=809.7435
# Month=23, Predicted=798.7063, Expected=765.2099
# Month=24, Predicted=795.8620, Expected=805.0349
# Month=25, Predicted=794.5125, Expected=820.4588
# Month=26, Predicted=785.9331, Expected=773.2413
# Month=27, Predicted=831.7316, Expected=882.5316
# Month=28, Predicted=885.9821, Expected=898.7897
# Month=29, Predicted=976.8367, Expected=956.6009
# Month=30, Predicted=943.8551, Expected=923.8359
# Month=31, Predicted=907.3980, Expected=881.4145
# Month=32, Predicted=855.8762, Expected=836.3729
# Month=33, Predicted=804.0001, Expected=784.1159
# Month=34, Predicted=745.6659, Expected=791.6660
# Month=35, Predicted=775.4710, Expected=759.1810
# Month=36, Predicted=807.8290, Expected=802.0941
# Month=37, Predicted=804.4264, Expected=828.1324
# Month=38, Predicted=809.6715, Expected=778.3983
# Month=39, Predicted=854.2349, Expected=888.3698
# Month=40, Predicted=887.3255, Expected=901.3272
# Month=41, Predicted=973.8081, Expected=969.2659
# Month=42, Predicted=961.4877, Expected=947.1513
# Month=43, Predicted=900.2497, Expected=908.1276
# Month=44, Predicted=897.9536, Expected=867.1765
# Month=45, Predicted=839.8980, Expected=814.6535
# Month=46, Predicted=779.3058, Expected=812.1183
# Month=47, Predicted=793.9032, Expected=773.1493
# Month=48, Predicted=799.8112, Expected=812.6360
# Month=49, Predicted=807.5698, Expected=834.9506
# Month=50, Predicted=804.9857, Expected=782.2414
# Month=51, Predicted=850.8661, Expected=891.3930
# Month=52, Predicted=885.2134, Expected=903.3345
# Month=53, Predicted=972.7719, Expected=965.5034
# Month=54, Predicted=970.8458, Expected=937.4010
# Month=55, Predicted=887.7862, Expected=896.5903
# Month=56, Predicted=877.3468, Expected=857.5819
# Month=57, Predicted=829.9147, Expected=817.4908
# Month=58, Predicted=790.8169, Expected=827.2103
# Month=59, Predicted=822.5434, Expected=797.4188
# Month=60, Predicted=849.6432, Expected=843.9664
# Run 10 — RMSE: 25.428990, MSE: 646.633553, NMSE: 0.0027111639
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=750.7379, Expected=804.1312
# Month=2, Predicted=806.6390, Expected=755.9621
# Month=3, Predicted=805.1427, Expected=859.0224
# Month=4, Predicted=860.8646, Expected=877.9865
# Month=5, Predicted=940.9151, Expected=942.0307
# Month=6, Predicted=912.2549, Expected=914.2550
# Month=7, Predicted=860.0965, Expected=868.9020
# Month=8, Predicted=852.6766, Expected=834.1536
# Month=9, Predicted=807.7170, Expected=789.9823
# Month=10, Predicted=769.0735, Expected=799.4046
# Month=11, Predicted=791.7244, Expected=763.5823
# Month=12, Predicted=824.6462, Expected=800.3831
# Month=13, Predicted=799.3116, Expected=826.4030
# Month=14, Predicted=793.7446, Expected=798.5367
# Month=15, Predicted=884.7765, Expected=890.7147
# Month=16, Predicted=905.6048, Expected=899.2858
# Month=17, Predicted=956.2180, Expected=961.2990
# Month=18, Predicted=967.0852, Expected=936.1160
# Month=19, Predicted=883.9511, Expected=893.4953
# Month=20, Predicted=881.1040, Expected=854.7115
# Month=21, Predicted=828.7435, Expected=809.0508
# Month=22, Predicted=783.5038, Expected=809.7435
# Month=23, Predicted=799.1432, Expected=765.2099
# Month=24, Predicted=799.6574, Expected=805.0349
# Month=25, Predicted=794.7045, Expected=820.4588
# Month=26, Predicted=785.4864, Expected=773.2413
# Month=27, Predicted=859.5198, Expected=882.5316
# Month=28, Predicted=887.5183, Expected=898.7897
# Month=29, Predicted=961.2487, Expected=956.6009
# Month=30, Predicted=934.7242, Expected=923.8359
# Month=31, Predicted=900.7576, Expected=881.4145
# Month=32, Predicted=862.0383, Expected=836.3729
# Month=33, Predicted=807.4798, Expected=784.1159
# Month=34, Predicted=749.2676, Expected=791.6660
# Month=35, Predicted=776.3633, Expected=759.1810
# Month=36, Predicted=811.7883, Expected=802.0941
# Month=37, Predicted=805.0515, Expected=828.1324
# Month=38, Predicted=793.7906, Expected=778.3983
# Month=39, Predicted=885.2380, Expected=888.3698
# Month=40, Predicted=890.8943, Expected=901.3272
# Month=41, Predicted=961.7891, Expected=969.2659
# Month=42, Predicted=948.1166, Expected=947.1513
# Month=43, Predicted=884.7437, Expected=908.1276
# Month=44, Predicted=900.3777, Expected=867.1765
# Month=45, Predicted=843.4515, Expected=814.6535
# Month=46, Predicted=783.4183, Expected=812.1183
# Month=47, Predicted=794.2095, Expected=773.1493
# Month=48, Predicted=791.4371, Expected=812.6360
# Month=49, Predicted=808.4127, Expected=834.9506
# Month=50, Predicted=801.0475, Expected=782.2414
# Month=51, Predicted=885.4933, Expected=891.3930
# Month=52, Predicted=890.4824, Expected=903.3345
# Month=53, Predicted=963.0891, Expected=965.5034
# Month=54, Predicted=953.0146, Expected=937.4010
# Month=55, Predicted=887.1770, Expected=896.5903
# Month=56, Predicted=882.3621, Expected=857.5819
# Month=57, Predicted=833.2558, Expected=817.4908
# Month=58, Predicted=794.5434, Expected=827.2103
# Month=59, Predicted=823.5674, Expected=797.4188
# Month=60, Predicted=856.0287, Expected=843.9664
# Run 11 — RMSE: 22.872280, MSE: 523.141215, NMSE: 0.0024068994
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=754.2627, Expected=804.1312
# Month=2, Predicted=796.3236, Expected=755.9621
# Month=3, Predicted=816.7292, Expected=859.0224
# Month=4, Predicted=848.5890, Expected=877.9865
# Month=5, Predicted=963.5233, Expected=942.0307
# Month=6, Predicted=918.0477, Expected=914.2550
# Month=7, Predicted=856.8508, Expected=868.9020
# Month=8, Predicted=874.5669, Expected=834.1536
# Month=9, Predicted=818.5595, Expected=789.9823
# Month=10, Predicted=786.8089, Expected=799.4046
# Month=11, Predicted=792.0828, Expected=763.5823
# Month=12, Predicted=812.3220, Expected=800.3831
# Month=13, Predicted=802.8936, Expected=826.4030
# Month=14, Predicted=787.9963, Expected=798.5367
# Month=15, Predicted=851.8227, Expected=890.7147
# Month=16, Predicted=898.0225, Expected=899.2858
# Month=17, Predicted=947.1282, Expected=961.2990
# Month=18, Predicted=963.7596, Expected=936.1160
# Month=19, Predicted=879.0849, Expected=893.4953
# Month=20, Predicted=903.2759, Expected=854.7115
# Month=21, Predicted=841.9041, Expected=809.0508
# Month=22, Predicted=799.8205, Expected=809.7435
# Month=23, Predicted=800.1564, Expected=765.2099
# Month=24, Predicted=806.3283, Expected=805.0349
# Month=25, Predicted=796.8513, Expected=820.4588
# Month=26, Predicted=779.7100, Expected=773.2413
# Month=27, Predicted=829.0557, Expected=882.5316
# Month=28, Predicted=872.9805, Expected=898.7897
# Month=29, Predicted=988.3385, Expected=956.6009
# Month=30, Predicted=942.2965, Expected=923.8359
# Month=31, Predicted=899.9920, Expected=881.4145
# Month=32, Predicted=880.9693, Expected=836.3729
# Month=33, Predicted=822.1343, Expected=784.1159
# Month=34, Predicted=763.9476, Expected=791.6660
# Month=35, Predicted=774.0175, Expected=759.1810
# Month=36, Predicted=805.7698, Expected=802.0941
# Month=37, Predicted=808.3582, Expected=828.1324
# Month=38, Predicted=797.8436, Expected=778.3983
# Month=39, Predicted=844.4254, Expected=888.3698
# Month=40, Predicted=876.3409, Expected=901.3272
# Month=41, Predicted=985.6770, Expected=969.2659
# Month=42, Predicted=954.3835, Expected=947.1513
# Month=43, Predicted=893.1291, Expected=908.1276
# Month=44, Predicted=922.5531, Expected=867.1765
# Month=45, Predicted=858.8563, Expected=814.6535
# Month=46, Predicted=800.3573, Expected=812.1183
# Month=47, Predicted=793.3234, Expected=773.1493
# Month=48, Predicted=810.9197, Expected=812.6360
# Month=49, Predicted=811.4119, Expected=834.9506
# Month=50, Predicted=795.4968, Expected=782.2414
# Month=51, Predicted=845.2280, Expected=891.3930
# Month=52, Predicted=876.2084, Expected=903.3345
# Month=53, Predicted=984.2712, Expected=965.5034
# Month=54, Predicted=957.4749, Expected=937.4010
# Month=55, Predicted=879.7835, Expected=896.5903
# Month=56, Predicted=902.8368, Expected=857.5819
# Month=57, Predicted=847.2602, Expected=817.4908
# Month=58, Predicted=809.4136, Expected=827.2103
# Month=59, Predicted=824.8216, Expected=797.4188
# Month=60, Predicted=845.0733, Expected=843.9664
# Run 12 — RMSE: 28.105554, MSE: 789.922171, NMSE: 0.0034688952
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=752.9695, Expected=804.1312
# Month=2, Predicted=794.8802, Expected=755.9621
# Month=3, Predicted=785.4720, Expected=859.0224
# Month=4, Predicted=862.1832, Expected=877.9865
# Month=5, Predicted=960.8518, Expected=942.0307
# Month=6, Predicted=917.7116, Expected=914.2550
# Month=7, Predicted=865.7222, Expected=868.9020
# Month=8, Predicted=849.9525, Expected=834.1536
# Month=9, Predicted=805.3510, Expected=789.9823
# Month=10, Predicted=768.0204, Expected=799.4046
# Month=11, Predicted=793.4583, Expected=763.5823
# Month=12, Predicted=805.9904, Expected=800.3831
# Month=13, Predicted=801.3148, Expected=826.4030
# Month=14, Predicted=788.9792, Expected=798.5367
# Month=15, Predicted=854.9439, Expected=890.7147
# Month=16, Predicted=915.7884, Expected=899.2858
# Month=17, Predicted=942.6686, Expected=961.2990
# Month=18, Predicted=968.8393, Expected=936.1160
# Month=19, Predicted=888.3657, Expected=893.4953
# Month=20, Predicted=879.5333, Expected=854.7115
# Month=21, Predicted=826.0781, Expected=809.0508
# Month=22, Predicted=781.3885, Expected=809.7435
# Month=23, Predicted=800.5389, Expected=765.2099
# Month=24, Predicted=787.4426, Expected=805.0349
# Month=25, Predicted=795.2548, Expected=820.4588
# Month=26, Predicted=780.1427, Expected=773.2413
# Month=27, Predicted=813.1930, Expected=882.5316
# Month=28, Predicted=889.1933, Expected=898.7897
# Month=29, Predicted=986.5176, Expected=956.6009
# Month=30, Predicted=939.0827, Expected=923.8359
# Month=31, Predicted=894.8839, Expected=881.4145
# Month=32, Predicted=858.5758, Expected=836.3729
# Month=33, Predicted=804.3373, Expected=784.1159
# Month=34, Predicted=745.1274, Expected=791.6660
# Month=35, Predicted=777.2445, Expected=759.1810
# Month=36, Predicted=801.4552, Expected=802.0941
# Month=37, Predicted=808.0105, Expected=828.1324
# Month=38, Predicted=801.4088, Expected=778.3983
# Month=39, Predicted=831.7667, Expected=888.3698
# Month=40, Predicted=892.1653, Expected=901.3272
# Month=41, Predicted=983.5444, Expected=969.2659
# Month=42, Predicted=955.6204, Expected=947.1513
# Month=43, Predicted=896.9068, Expected=908.1276
# Month=44, Predicted=900.3439, Expected=867.1765
# Month=45, Predicted=840.8856, Expected=814.6535
# Month=46, Predicted=779.7063, Expected=812.1183
# Month=47, Predicted=794.6010, Expected=773.1493
# Month=48, Predicted=794.9868, Expected=812.6360
# Month=49, Predicted=810.0444, Expected=834.9506
# Month=50, Predicted=798.0892, Expected=782.2414
# Month=51, Predicted=827.8816, Expected=891.3930
# Month=52, Predicted=891.4462, Expected=903.3345
# Month=53, Predicted=982.2875, Expected=965.5034
# Month=54, Predicted=959.8253, Expected=937.4010
# Month=55, Predicted=892.4707, Expected=896.5903
# Month=56, Predicted=880.3615, Expected=857.5819
# Month=57, Predicted=830.9943, Expected=817.4908
# Month=58, Predicted=793.1021, Expected=827.2103
# Month=59, Predicted=825.9709, Expected=797.4188
# Month=60, Predicted=844.5682, Expected=843.9664
# Run 13 — RMSE: 27.867445, MSE: 776.594483, NMSE: 0.0031163458
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=751.4599, Expected=804.1312
# Month=2, Predicted=795.8277, Expected=755.9621
# Month=3, Predicted=816.8263, Expected=859.0224
# Month=4, Predicted=852.3464, Expected=877.9865
# Month=5, Predicted=955.6979, Expected=942.0307
# Month=6, Predicted=918.0948, Expected=914.2550
# Month=7, Predicted=865.9601, Expected=868.9020
# Month=8, Predicted=861.0045, Expected=834.1536
# Month=9, Predicted=805.4425, Expected=789.9823
# Month=10, Predicted=772.7975, Expected=799.4046
# Month=11, Predicted=787.3210, Expected=763.5823
# Month=12, Predicted=812.8770, Expected=800.3831
# Month=13, Predicted=799.7438, Expected=826.4030
# Month=14, Predicted=783.0852, Expected=798.5367
# Month=15, Predicted=864.5945, Expected=890.7147
# Month=16, Predicted=913.1749, Expected=899.2858
# Month=17, Predicted=947.9093, Expected=961.2990
# Month=18, Predicted=980.7547, Expected=936.1160
# Month=19, Predicted=888.9134, Expected=893.4953
# Month=20, Predicted=890.5103, Expected=854.7115
# Month=21, Predicted=828.2207, Expected=809.0508
# Month=22, Predicted=785.2815, Expected=809.7435
# Month=23, Predicted=794.1573, Expected=765.2099
# Month=24, Predicted=798.1456, Expected=805.0349
# Month=25, Predicted=790.8365, Expected=820.4588
# Month=26, Predicted=776.5805, Expected=773.2413
# Month=27, Predicted=824.8445, Expected=882.5316
# Month=28, Predicted=878.8889, Expected=898.7897
# Month=29, Predicted=980.3888, Expected=956.6009
# Month=30, Predicted=942.3079, Expected=923.8359
# Month=31, Predicted=908.0714, Expected=881.4145
# Month=32, Predicted=867.5801, Expected=836.3729
# Month=33, Predicted=807.4477, Expected=784.1159
# Month=34, Predicted=748.1295, Expected=791.6660
# Month=35, Predicted=767.5361, Expected=759.1810
# Month=36, Predicted=807.4778, Expected=802.0941
# Month=37, Predicted=807.0970, Expected=828.1324
# Month=38, Predicted=793.3856, Expected=778.3983
# Month=39, Predicted=842.3152, Expected=888.3698
# Month=40, Predicted=880.9578, Expected=901.3272
# Month=41, Predicted=978.7288, Expected=969.2659
# Month=42, Predicted=958.6581, Expected=947.1513
# Month=43, Predicted=895.4748, Expected=908.1276
# Month=44, Predicted=911.0702, Expected=867.1765
# Month=45, Predicted=844.9904, Expected=814.6535
# Month=46, Predicted=784.5908, Expected=812.1183
# Month=47, Predicted=785.6672, Expected=773.1493
# Month=48, Predicted=804.1258, Expected=812.6360
# Month=49, Predicted=807.2042, Expected=834.9506
# Month=50, Predicted=789.5269, Expected=782.2414
# Month=51, Predicted=839.8341, Expected=891.3930
# Month=52, Predicted=879.1207, Expected=903.3345
# Month=53, Predicted=978.1799, Expected=965.5034
# Month=54, Predicted=964.1021, Expected=937.4010
# Month=55, Predicted=893.3272, Expected=896.5903
# Month=56, Predicted=890.1939, Expected=857.5819
# Month=57, Predicted=833.6756, Expected=817.4908
# Month=58, Predicted=795.8458, Expected=827.2103
# Month=59, Predicted=821.1920, Expected=797.4188
# Month=60, Predicted=849.8922, Expected=843.9664
# Run 14 — RMSE: 26.322526, MSE: 692.875358, NMSE: 0.0027796256
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=746.1871, Expected=804.1312
# Month=2, Predicted=795.7738, Expected=755.9621
# Month=3, Predicted=809.8952, Expected=859.0224
# Month=4, Predicted=848.6703, Expected=877.9865
# Month=5, Predicted=958.4022, Expected=942.0307
# Month=6, Predicted=910.4064, Expected=914.2550
# Month=7, Predicted=865.2022, Expected=868.9020
# Month=8, Predicted=852.0667, Expected=834.1536
# Month=9, Predicted=809.1198, Expected=789.9823
# Month=10, Predicted=769.6229, Expected=799.4046
# Month=11, Predicted=784.6199, Expected=763.5823
# Month=12, Predicted=820.4688, Expected=800.3831
# Month=13, Predicted=793.9010, Expected=826.4030
# Month=14, Predicted=789.3597, Expected=798.5367
# Month=15, Predicted=870.2445, Expected=890.7147
# Month=16, Predicted=916.3162, Expected=899.2858
# Month=17, Predicted=940.6132, Expected=961.2990
# Month=18, Predicted=973.9906, Expected=936.1160
# Month=19, Predicted=888.4370, Expected=893.4953
# Month=20, Predicted=880.2661, Expected=854.7115
# Month=21, Predicted=830.3380, Expected=809.0508
# Month=22, Predicted=785.6164, Expected=809.7435
# Month=23, Predicted=793.1574, Expected=765.2099
# Month=24, Predicted=804.4306, Expected=805.0349
# Month=25, Predicted=788.6740, Expected=820.4588
# Month=26, Predicted=781.4053, Expected=773.2413
# Month=27, Predicted=836.0951, Expected=882.5316
# Month=28, Predicted=874.2323, Expected=898.7897
# Month=29, Predicted=981.8419, Expected=956.6009
# Month=30, Predicted=938.9446, Expected=923.8359
# Month=31, Predicted=901.1991, Expected=881.4145
# Month=32, Predicted=862.1255, Expected=836.3729
# Month=33, Predicted=810.5580, Expected=784.1159
# Month=34, Predicted=754.8103, Expected=791.6660
# Month=35, Predicted=771.4909, Expected=759.1810
# Month=36, Predicted=814.1397, Expected=802.0941
# Month=37, Predicted=804.3563, Expected=828.1324
# Month=38, Predicted=800.0115, Expected=778.3983
# Month=39, Predicted=854.4841, Expected=888.3698
# Month=40, Predicted=878.0155, Expected=901.3272
# Month=41, Predicted=977.9326, Expected=969.2659
# Month=42, Predicted=956.1219, Expected=947.1513
# Month=43, Predicted=895.5676, Expected=908.1276
# Month=44, Predicted=904.6935, Expected=867.1765
# Month=45, Predicted=844.5242, Expected=814.6535
# Month=46, Predicted=787.8893, Expected=812.1183
# Month=47, Predicted=790.4802, Expected=773.1493
# Month=48, Predicted=809.2054, Expected=812.6360
# Month=49, Predicted=800.4180, Expected=834.9506
# Month=50, Predicted=798.6966, Expected=782.2414
# Month=51, Predicted=852.7647, Expected=891.3930
# Month=52, Predicted=878.6663, Expected=903.3345
# Month=53, Predicted=976.6013, Expected=965.5034
# Month=54, Predicted=962.3660, Expected=937.4010
# Month=55, Predicted=891.1206, Expected=896.5903
# Month=56, Predicted=880.7622, Expected=857.5819
# Month=57, Predicted=834.3751, Expected=817.4908
# Month=58, Predicted=795.3787, Expected=827.2103
# Month=59, Predicted=815.2511, Expected=797.4188
# Month=60, Predicted=856.2258, Expected=843.9664
# Run 15 — RMSE: 25.209292, MSE: 635.508410, NMSE: 0.0026935105
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=752.6183, Expected=804.1312
# Month=2, Predicted=818.8116, Expected=755.9621
# Month=3, Predicted=759.5752, Expected=859.0224
# Month=4, Predicted=866.5916, Expected=877.9865
# Month=5, Predicted=866.2371, Expected=942.0307
# Month=6, Predicted=956.7110, Expected=914.2550
# Month=7, Predicted=874.7277, Expected=868.9020
# Month=8, Predicted=848.9212, Expected=834.1536
# Month=9, Predicted=807.5444, Expected=789.9823
# Month=10, Predicted=768.9236, Expected=799.4046
# Month=11, Predicted=796.0684, Expected=763.5823
# Month=12, Predicted=778.2626, Expected=800.3831
# Month=13, Predicted=801.2199, Expected=826.4030
# Month=14, Predicted=841.0834, Expected=798.5367
# Month=15, Predicted=822.8399, Expected=890.7147
# Month=16, Predicted=907.3803, Expected=899.2858
# Month=17, Predicted=868.2342, Expected=961.2990
# Month=18, Predicted=975.9793, Expected=936.1160
# Month=19, Predicted=901.7749, Expected=893.4953
# Month=20, Predicted=878.0849, Expected=854.7115
# Month=21, Predicted=827.8463, Expected=809.0508
# Month=22, Predicted=782.7981, Expected=809.7435
# Month=23, Predicted=803.5555, Expected=765.2099
# Month=24, Predicted=785.0884, Expected=805.0349
# Month=25, Predicted=797.8296, Expected=820.4588
# Month=26, Predicted=835.1391, Expected=773.2413
# Month=27, Predicted=826.0228, Expected=882.5316
# Month=28, Predicted=893.4756, Expected=898.7897
# Month=29, Predicted=867.4007, Expected=956.6009
# Month=30, Predicted=971.2813, Expected=923.8359
# Month=31, Predicted=899.6946, Expected=881.4145
# Month=32, Predicted=858.8834, Expected=836.3729
# Month=33, Predicted=806.1233, Expected=784.1159
# Month=34, Predicted=747.3639, Expected=791.6660
# Month=35, Predicted=782.1714, Expected=759.1810
# Month=36, Predicted=773.8613, Expected=802.0941
# Month=37, Predicted=806.4385, Expected=828.1324
# Month=38, Predicted=842.8128, Expected=778.3983
# Month=39, Predicted=836.4802, Expected=888.3698
# Month=40, Predicted=897.5267, Expected=901.3272
# Month=41, Predicted=860.5088, Expected=969.2659
# Month=42, Predicted=983.9463, Expected=947.1513
# Month=43, Predicted=901.9891, Expected=908.1276
# Month=44, Predicted=897.3254, Expected=867.1765
# Month=45, Predicted=842.1389, Expected=814.6535
# Month=46, Predicted=781.4474, Expected=812.1183
# Month=47, Predicted=799.2410, Expected=773.1493
# Month=48, Predicted=786.4523, Expected=812.6360
# Month=49, Predicted=810.9321, Expected=834.9506
# Month=50, Predicted=849.6310, Expected=782.2414
# Month=51, Predicted=845.7867, Expected=891.3930
# Month=52, Predicted=897.8675, Expected=903.3345
# Month=53, Predicted=861.8227, Expected=965.5034
# Month=54, Predicted=980.1837, Expected=937.4010
# Month=55, Predicted=902.0970, Expected=896.5903
# Month=56, Predicted=879.2951, Expected=857.5819
# Month=57, Predicted=832.4862, Expected=817.4908
# ...
# Month=47, Predicted=794.0930, Expected=773.1493
# Month=48, Predicted=799.1204, Expected=812.6360
# Month=49, Predicted=804.8839, Expected=834.9506
# Month=50, Predicted=801.8897, Expected=782.2414
# Month=51, Predicted=875.6382, Expected=891.3930
# Month=52, Predicted=884.5663, Expected=903.3345
# Month=53, Predicted=968.6110, Expected=965.5034
# Month=54, Predicted=953.5953, Expected=937.4010
# Month=55, Predicted=891.2684, Expected=896.5903
# Month=56, Predicted=881.6864, Expected=857.5819
# Month=57, Predicted=836.7210, Expected=817.4908
# Month=58, Predicted=797.1407, Expected=827.2103
# Month=59, Predicted=818.8003, Expected=797.4188
# Month=60, Predicted=854.5225, Expected=843.9664
# Run 25 — RMSE: 23.355788, MSE: 545.492847, NMSE: 0.0025578622
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=750.3383, Expected=804.1312
# Month=2, Predicted=796.7576, Expected=755.9621
# Month=3, Predicted=828.1313, Expected=859.0224
# Month=4, Predicted=857.5905, Expected=877.9865
# Month=5, Predicted=943.8825, Expected=942.0307
# Month=6, Predicted=914.5943, Expected=914.2550
# Month=7, Predicted=863.8300, Expected=868.9020
# Month=8, Predicted=851.5993, Expected=834.1536
# Month=9, Predicted=809.7121, Expected=789.9823
# Month=10, Predicted=771.1400, Expected=799.4046
# Month=11, Predicted=791.5632, Expected=763.5823
# Month=12, Predicted=819.1003, Expected=800.3831
# Month=13, Predicted=798.9476, Expected=826.4030
# Month=14, Predicted=790.2587, Expected=798.5367
# Month=15, Predicted=889.0311, Expected=890.7147
# Month=16, Predicted=905.5033, Expected=899.2858
# Month=17, Predicted=951.5395, Expected=961.2990
# Month=18, Predicted=950.5687, Expected=936.1160
# Month=19, Predicted=886.5592, Expected=893.4953
# Month=20, Predicted=879.9437, Expected=854.7115
# Month=21, Predicted=830.7744, Expected=809.0508
# Month=22, Predicted=785.7631, Expected=809.7435
# Month=23, Predicted=799.3665, Expected=765.2099
# Month=24, Predicted=786.5529, Expected=805.0349
# Month=25, Predicted=795.3916, Expected=820.4588
# Month=26, Predicted=781.9323, Expected=773.2413
# Month=27, Predicted=853.5608, Expected=882.5316
# Month=28, Predicted=884.9206, Expected=898.7897
# Month=29, Predicted=965.8181, Expected=956.6009
# Month=30, Predicted=931.7560, Expected=923.8359
# Month=31, Predicted=902.9764, Expected=881.4145
# Month=32, Predicted=861.8842, Expected=836.3729
# Month=33, Predicted=809.7825, Expected=784.1159
# Month=34, Predicted=752.0156, Expected=791.6660
# Month=35, Predicted=776.9685, Expected=759.1810
# Month=36, Predicted=807.0471, Expected=802.0941
# Month=37, Predicted=804.1996, Expected=828.1324
# Month=38, Predicted=787.3121, Expected=778.3983
# Month=39, Predicted=876.4679, Expected=888.3698
# Month=40, Predicted=888.4409, Expected=901.3272
# Month=41, Predicted=965.3338, Expected=969.2659
# Month=42, Predicted=940.7849, Expected=947.1513
# Month=43, Predicted=885.3361, Expected=908.1276
# Month=44, Predicted=898.1061, Expected=867.1765
# Month=45, Predicted=845.4160, Expected=814.6535
# Month=46, Predicted=785.9727, Expected=812.1183
# Month=47, Predicted=795.0354, Expected=773.1493
# Month=48, Predicted=783.5598, Expected=812.6360
# Month=49, Predicted=808.3756, Expected=834.9506
# Month=50, Predicted=796.1311, Expected=782.2414
# Month=51, Predicted=882.6279, Expected=891.3930
# Month=52, Predicted=888.5531, Expected=903.3345
# Month=53, Predicted=965.8713, Expected=965.5034
# Month=54, Predicted=943.4838, Expected=937.4010
# Month=55, Predicted=891.5910, Expected=896.5903
# Month=56, Predicted=881.3366, Expected=857.5819
# Month=57, Predicted=835.1922, Expected=817.4908
# Month=58, Predicted=796.5369, Expected=827.2103
# Month=59, Predicted=823.0603, Expected=797.4188
# Month=60, Predicted=852.6478, Expected=843.9664
# Run 26 — RMSE: 21.531510, MSE: 463.605908, NMSE: 0.0021637521
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=755.1939, Expected=804.1312
# Month=2, Predicted=797.8985, Expected=755.9621
# Month=3, Predicted=776.8739, Expected=859.0224
# Month=4, Predicted=861.7788, Expected=877.9865
# Month=5, Predicted=960.8514, Expected=942.0307
# Month=6, Predicted=913.0615, Expected=914.2550
# Month=7, Predicted=870.2349, Expected=868.9020
# Month=8, Predicted=853.7822, Expected=834.1536
# Month=9, Predicted=801.2997, Expected=789.9823
# Month=10, Predicted=767.3427, Expected=799.4046
# Month=11, Predicted=791.2713, Expected=763.5823
# Month=12, Predicted=809.0574, Expected=800.3831
# Month=13, Predicted=803.3010, Expected=826.4030
# Month=14, Predicted=798.0593, Expected=798.5367
# Month=15, Predicted=843.2623, Expected=890.7147
# Month=16, Predicted=925.3215, Expected=899.2858
# Month=17, Predicted=937.5908, Expected=961.2990
# Month=18, Predicted=969.5717, Expected=936.1160
# Month=19, Predicted=892.3968, Expected=893.4953
# Month=20, Predicted=884.1235, Expected=854.7115
# Month=21, Predicted=823.1865, Expected=809.0508
# Month=22, Predicted=779.3022, Expected=809.7435
# Month=23, Predicted=797.3470, Expected=765.2099
# Month=24, Predicted=794.7458, Expected=805.0349
# Month=25, Predicted=793.2563, Expected=820.4588
# Month=26, Predicted=788.8416, Expected=773.2413
# Month=27, Predicted=818.6698, Expected=882.5316
# Month=28, Predicted=889.6407, Expected=898.7897
# Month=29, Predicted=989.1908, Expected=956.6009
# Month=30, Predicted=939.5165, Expected=923.8359
# Month=31, Predicted=898.7803, Expected=881.4145
# Month=32, Predicted=861.0701, Expected=836.3729
# Month=33, Predicted=801.2347, Expected=784.1159
# Month=34, Predicted=740.6439, Expected=791.6660
# Month=35, Predicted=771.0904, Expected=759.1810
# Month=36, Predicted=804.6155, Expected=802.0941
# Month=37, Predicted=811.5095, Expected=828.1324
# Month=38, Predicted=807.6818, Expected=778.3983
# Month=39, Predicted=825.1282, Expected=888.3698
# Month=40, Predicted=891.2583, Expected=901.3272
# Month=41, Predicted=986.0486, Expected=969.2659
# Month=42, Predicted=956.2599, Expected=947.1513
# Month=43, Predicted=906.2607, Expected=908.1276
# Month=44, Predicted=905.4729, Expected=867.1765
# Month=45, Predicted=839.4839, Expected=814.6535
# Month=46, Predicted=776.9690, Expected=812.1183
# Month=47, Predicted=788.0901, Expected=773.1493
# Month=48, Predicted=802.2025, Expected=812.6360
# Month=49, Predicted=810.4774, Expected=834.9506
# Month=50, Predicted=807.6276, Expected=782.2414
# Month=51, Predicted=828.4036, Expected=891.3930
# Month=52, Predicted=888.7469, Expected=903.3345
# Month=53, Predicted=984.2811, Expected=965.5034
# Month=54, Predicted=961.0042, Expected=937.4010
# Month=55, Predicted=896.8156, Expected=896.5903
# Month=56, Predicted=884.0869, Expected=857.5819
# Month=57, Predicted=828.6949, Expected=817.4908
# Month=58, Predicted=791.0370, Expected=827.2103
# Month=59, Predicted=825.6410, Expected=797.4188
# Month=60, Predicted=843.3126, Expected=843.9664
# Run 27 — RMSE: 29.186637, MSE: 851.859753, NMSE: 0.0033517305
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=749.4841, Expected=804.1312
# Month=2, Predicted=798.5659, Expected=755.9621
# Month=3, Predicted=793.3143, Expected=859.0224
# Month=4, Predicted=863.8522, Expected=877.9865
# Month=5, Predicted=939.2917, Expected=942.0307
# Month=6, Predicted=916.9418, Expected=914.2550
# Month=7, Predicted=865.3622, Expected=868.9020
# Month=8, Predicted=844.4315, Expected=834.1536
# Month=9, Predicted=807.1297, Expected=789.9823
# Month=10, Predicted=765.8413, Expected=799.4046
# Month=11, Predicted=794.4281, Expected=763.5823
# Month=12, Predicted=809.2320, Expected=800.3831
# Month=13, Predicted=797.9075, Expected=826.4030
# Month=14, Predicted=793.7533, Expected=798.5367
# Month=15, Predicted=859.6023, Expected=890.7147
# Month=16, Predicted=912.8191, Expected=899.2858
# Month=17, Predicted=947.8275, Expected=961.2990
# Month=18, Predicted=966.1736, Expected=936.1160
# Month=19, Predicted=887.7488, Expected=893.4953
# Month=20, Predicted=873.3556, Expected=854.7115
# Month=21, Predicted=826.7534, Expected=809.0508
# Month=22, Predicted=781.1214, Expected=809.7435
# Month=23, Predicted=802.2076, Expected=765.2099
# Month=24, Predicted=787.4298, Expected=805.0349
# Month=25, Predicted=794.8877, Expected=820.4588
# Month=26, Predicted=784.4396, Expected=773.2413
# Month=27, Predicted=823.2870, Expected=882.5316
# Month=28, Predicted=891.4047, Expected=898.7897
# Month=29, Predicted=960.6474, Expected=956.6009
# Month=30, Predicted=937.4497, Expected=923.8359
# Month=31, Predicted=905.0108, Expected=881.4145
# Month=32, Predicted=854.6742, Expected=836.3729
# Month=33, Predicted=805.5217, Expected=784.1159
# Month=34, Predicted=748.2600, Expected=791.6660
# Month=35, Predicted=781.8592, Expected=759.1810
# Month=36, Predicted=803.2860, Expected=802.0941
# Month=37, Predicted=804.2362, Expected=828.1324
# Month=38, Predicted=792.4209, Expected=778.3983
# Month=39, Predicted=840.8426, Expected=888.3698
# Month=40, Predicted=894.8661, Expected=901.3272
# Month=41, Predicted=960.4527, Expected=969.2659
# Month=42, Predicted=952.8441, Expected=947.1513
# Month=43, Predicted=882.5818, Expected=908.1276
# Month=44, Predicted=893.6552, Expected=867.1765
# Month=45, Predicted=839.9283, Expected=814.6535
# Month=46, Predicted=780.8453, Expected=812.1183
# Month=47, Predicted=799.1013, Expected=773.1493
# Month=48, Predicted=794.0881, Expected=812.6360
# Month=49, Predicted=807.6422, Expected=834.9506
# Month=50, Predicted=800.3719, Expected=782.2414
# Month=51, Predicted=842.5077, Expected=891.3930
# Month=52, Predicted=894.8158, Expected=903.3345
# Month=53, Predicted=961.2022, Expected=965.5034
# Month=54, Predicted=957.7403, Expected=937.4010
# Month=55, Predicted=894.6389, Expected=896.5903
# Month=56, Predicted=874.7622, Expected=857.5819
# Month=57, Predicted=830.9161, Expected=817.4908
# Month=58, Predicted=792.5853, Expected=827.2103
# Month=59, Predicted=825.7375, Expected=797.4188
# Month=60, Predicted=845.4055, Expected=843.9664
# Run 28 — RMSE: 25.844903, MSE: 667.958991, NMSE: 0.0030087142
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=749.6223, Expected=804.1312
# Month=2, Predicted=807.3660, Expected=755.9621
# Month=3, Predicted=801.6506, Expected=859.0224
# Month=4, Predicted=854.0795, Expected=877.9865
# Month=5, Predicted=956.0647, Expected=942.0307
# Month=6, Predicted=912.9418, Expected=914.2550
# Month=7, Predicted=859.0476, Expected=868.9020
# Month=8, Predicted=850.3641, Expected=834.1536
# Month=9, Predicted=807.4113, Expected=789.9823
# Month=10, Predicted=771.5014, Expected=799.4046
# Month=11, Predicted=791.2400, Expected=763.5823
# Month=12, Predicted=813.0117, Expected=800.3831
# Month=13, Predicted=797.7998, Expected=826.4030
# Month=14, Predicted=796.2578, Expected=798.5367
# Month=15, Predicted=868.2590, Expected=890.7147
# Month=16, Predicted=909.9932, Expected=899.2858
# Month=17, Predicted=934.6567, Expected=961.2990
# Month=18, Predicted=950.0327, Expected=936.1160
# Month=19, Predicted=882.6350, Expected=893.4953
# Month=20, Predicted=879.2694, Expected=854.7115
# Month=21, Predicted=828.8222, Expected=809.0508
# Month=22, Predicted=785.5794, Expected=809.7435
# Month=23, Predicted=798.4591, Expected=765.2099
# Month=24, Predicted=794.1568, Expected=805.0349
# Month=25, Predicted=791.2796, Expected=820.4588
# Month=26, Predicted=784.3983, Expected=773.2413
# Month=27, Predicted=825.0718, Expected=882.5316
# Month=28, Predicted=884.7784, Expected=898.7897
# Month=29, Predicted=979.9146, Expected=956.6009
# Month=30, Predicted=936.9300, Expected=923.8359
# Month=31, Predicted=895.7443, Expected=881.4145
# Month=32, Predicted=858.7924, Expected=836.3729
# Month=33, Predicted=808.7149, Expected=784.1159
# Month=34, Predicted=751.7630, Expected=791.6660
# Month=35, Predicted=774.7087, Expected=759.1810
# Month=36, Predicted=806.3989, Expected=802.0941
# Month=37, Predicted=805.0934, Expected=828.1324
# Month=38, Predicted=808.1013, Expected=778.3983
# Month=39, Predicted=848.1207, Expected=888.3698
# Month=40, Predicted=885.9490, Expected=901.3272
# Month=41, Predicted=975.6890, Expected=969.2659
# Month=42, Predicted=949.0330, Expected=947.1513
# Month=43, Predicted=891.0557, Expected=908.1276
# Month=44, Predicted=899.0512, Expected=867.1765
# Month=45, Predicted=843.8025, Expected=814.6535
# Month=46, Predicted=785.9348, Expected=812.1183
# Month=47, Predicted=792.2750, Expected=773.1493
# Month=48, Predicted=800.0419, Expected=812.6360
# Month=49, Predicted=806.7528, Expected=834.9506
# Month=50, Predicted=804.9675, Expected=782.2414
# Month=51, Predicted=848.6184, Expected=891.3930
# Month=52, Predicted=884.4634, Expected=903.3345
# Month=53, Predicted=974.1500, Expected=965.5034
# Month=54, Predicted=949.3990, Expected=937.4010
# Month=55, Predicted=886.7144, Expected=896.5903
# Month=56, Predicted=879.7755, Expected=857.5819
# Month=57, Predicted=833.7090, Expected=817.4908
# Month=58, Predicted=796.0461, Expected=827.2103
# Month=59, Predicted=824.4884, Expected=797.4188
# Month=60, Predicted=847.6013, Expected=843.9664
# Run 29 — RMSE: 25.373562, MSE: 643.817626, NMSE: 0.0029569999
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=754.5985, Expected=804.1312
# Month=2, Predicted=798.3582, Expected=755.9621
# Month=3, Predicted=770.2488, Expected=859.0224
# Month=4, Predicted=860.8250, Expected=877.9865
# Month=5, Predicted=958.7425, Expected=942.0307
# Month=6, Predicted=914.6078, Expected=914.2550
# Month=7, Predicted=872.2996, Expected=868.9020
# Month=8, Predicted=853.2554, Expected=834.1536
# Month=9, Predicted=801.3038, Expected=789.9823
# Month=10, Predicted=766.6802, Expected=799.4046
# Month=11, Predicted=790.6012, Expected=763.5823
# Month=12, Predicted=809.7382, Expected=800.3831
# Month=13, Predicted=802.7233, Expected=826.4030
# Month=14, Predicted=796.4251, Expected=798.5367
# Month=15, Predicted=840.9484, Expected=890.7147
# Month=16, Predicted=924.4044, Expected=899.2858
# Month=17, Predicted=939.9561, Expected=961.2990
# Month=18, Predicted=969.4307, Expected=936.1160
# Month=19, Predicted=894.3915, Expected=893.4953
# Month=20, Predicted=883.4134, Expected=854.7115
# Month=21, Predicted=823.1413, Expected=809.0508
# Month=22, Predicted=778.9072, Expected=809.7435
# Month=23, Predicted=796.7379, Expected=765.2099
# Month=24, Predicted=793.2899, Expected=805.0349
# Month=25, Predicted=793.0050, Expected=820.4588
# Month=26, Predicted=787.2705, Expected=773.2413
# Month=27, Predicted=817.6410, Expected=882.5316
# Month=28, Predicted=889.1407, Expected=898.7897
# Month=29, Predicted=985.6259, Expected=956.6009
# Month=30, Predicted=939.2378, Expected=923.8359
# Month=31, Predicted=897.4672, Expected=881.4145
# Month=32, Predicted=860.5227, Expected=836.3729
# Month=33, Predicted=801.1835, Expected=784.1159
# Month=34, Predicted=740.7056, Expected=791.6660
# Month=35, Predicted=770.7103, Expected=759.1810
# Month=36, Predicted=805.3547, Expected=802.0941
# Month=37, Predicted=810.8140, Expected=828.1324
# Month=38, Predicted=807.6700, Expected=778.3983
# Month=39, Predicted=827.2815, Expected=888.3698
# Month=40, Predicted=890.7805, Expected=901.3272
# Month=41, Predicted=983.0438, Expected=969.2659
# Month=42, Predicted=955.8374, Expected=947.1513
# Month=43, Predicted=907.3511, Expected=908.1276
# Month=44, Predicted=904.8101, Expected=867.1765
# Month=45, Predicted=839.3303, Expected=814.6535
# Month=46, Predicted=776.8519, Expected=812.1183
# Month=47, Predicted=787.8364, Expected=773.1493
# Month=48, Predicted=800.6239, Expected=812.6360
# Month=49, Predicted=809.9698, Expected=834.9506
# Month=50, Predicted=806.4730, Expected=782.2414
# Month=51, Predicted=829.7976, Expected=891.3930
# Month=52, Predicted=888.4202, Expected=903.3345
# Month=53, Predicted=981.6655, Expected=965.5034
# Month=54, Predicted=960.0320, Expected=937.4010
# Month=55, Predicted=898.1642, Expected=896.5903
# Month=56, Predicted=883.4570, Expected=857.5819
# Month=57, Predicted=828.5237, Expected=817.4908
# Month=58, Predicted=790.5905, Expected=827.2103
# Month=59, Predicted=824.7503, Expected=797.4188
# Month=60, Predicted=846.3020, Expected=843.9664
# Run 30 — RMSE: 29.278108, MSE: 857.207595, NMSE: 0.0033781313
#
# ===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Monthly Milk Production (30 runs) =====
# RMSE: 26.918941 ± 3.805998
# MSE:  739.114984 ± 251.263469
# NMSE: 0.0031979002 ± 0.0012874981
#
# Best run: 26
#   RMSE: 21.531510
#   MSE:  463.605908
#   NMSE: 0.0021637521
# === Best Run Metrics ===
# RMSE: 21.531510
# MSE:  463.605908
# NMSE: 0.0021637521

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
