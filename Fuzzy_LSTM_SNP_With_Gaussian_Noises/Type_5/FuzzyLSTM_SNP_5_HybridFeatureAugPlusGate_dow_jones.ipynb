# %% [markdown]
# # Notebook 5: Hybrid LSTM-SNP (Fuzzy Feature Aug + Fuzzy Gates)
#
# **Dataset**: Dow Jones Industrial Index
#
# ## Description
# This notebook implements the **hybrid model** that combines:
# 1. **Fuzzy Feature Augmentation** (from Notebook 2): Input is augmented with fuzzy-derived features
# 2. **Fuzzy Gate Replacement** (from Notebook 3): Gates use fuzzy inference instead of sigmoid
#
# This represents the most complex integration of fuzzy logic with LSTM-SNP. Gradient clipping
# (norm=1.0) and careful weight initialization are applied for training stability.
#
# The interaction between input-level and gate-level fuzzy reasoning is documented and analyzed.

# %% [markdown]
# ## Theory: Hybrid Fuzzy LSTM-SNP
#
# This model combines two fuzzy integration strategies:
#
# ### 1. Input-Level: Fuzzy Feature Augmentation
# Same as Notebook 2:
# - Fuzzy inference on $x(t)$ and $x(t-1)$
# - Augmented input: $x'(t) = [x(t), y_{fuzzy}]$
# - Input dimension becomes 2
#
# ### 2. Gate-Level: Fuzzy Gate Replacement
# Same as Notebook 3:
# - Gates r, c, o computed via fuzzy inference
# - Fixed Gaussian MFs, trainable consequent parameters
# - Generation gate a retains tanh
#
# ### Interaction Between Levels
# - The fuzzy-augmented input provides richer information to the cell
# - The fuzzy gates process this enriched input with adaptive, rule-based gating
# - This creates a two-level fuzzy reasoning pipeline
#
# ### Stability Measures
# - Gradient clipping (norm ≤ 1.0)
# - Careful weight initialization
# - Fuzzy weights are clipped to valid ranges

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# GPU Acceleration Settings (CUDA + Apple Metal Support)
# ============================================================
import tensorflow as tf
import platform

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        # Detect GPU type
        if platform.system() == 'Darwin' and platform.processor() == 'arm':
            print(f"Apple Metal GPU Enabled: Found {len(physical_devices)} GPU(s) via tensorflow-metal")
            print(f"  Chipset: Apple {platform.machine()} (M-series)")
        else:
            print(f"CUDA GPU Enabled: Found {len(physical_devices)} GPU(s) - Memory Growth Set")
        for d in physical_devices:
            print(f"  Device: {d.name}")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    if platform.system() == 'Darwin' and platform.processor() == 'arm':
        print("Apple Silicon detected but no GPU found.")
        print("  Install tensorflow-metal: pip install tensorflow-metal")
    else:
        print("No GPU found. Falling back to CPU.")
        print("  For CUDA: ensure NVIDIA drivers + CUDA toolkit are installed.")

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Inference System (NumPy — for preprocessing)

# %%
# ============================================================
# Fuzzy Inference System (NumPy — for preprocessing)
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# 4 Takagi-Sugeno rules with fixed consequent parameters:
#   IF x(t) is low  AND x(t-1) is low  → y₁ = 0.5·x(t) + 0.5·x(t-1)
#   IF x(t) is low  AND x(t-1) is high → y₂ = 0.7·x(t) + 0.3·x(t-1) - 0.1
#   IF x(t) is high AND x(t-1) is low  → y₃ = 0.3·x(t) + 0.7·x(t-1) + 0.1
#   IF x(t) is high AND x(t-1) is high → y₄ = 0.5·x(t) + 0.5·x(t-1)
#
# Output: y = Σ(wᵢ·yᵢ) / Σ(wᵢ)
# ============================================================

def gaussian_mf(x, center, sigma=0.5):
    """Fixed Gaussian membership function."""
    return np.exp(-(x - center)**2 / (2 * sigma**2))

def fuzzy_inference_numpy(x_t, x_tm1):
    """
    Compute fuzzy feature from x(t) and x(t-1).
    Uses fixed membership functions and fixed consequent parameters.
    """
    # Membership degrees
    mu_low_xt = gaussian_mf(x_t, center=-1.0)
    mu_high_xt = gaussian_mf(x_t, center=1.0)
    mu_low_xtm1 = gaussian_mf(x_tm1, center=-1.0)
    mu_high_xtm1 = gaussian_mf(x_tm1, center=1.0)

    # Rule firing strengths (product)
    w1 = mu_low_xt * mu_low_xtm1      # low-low
    w2 = mu_low_xt * mu_high_xtm1     # low-high
    w3 = mu_high_xt * mu_low_xtm1     # high-low
    w4 = mu_high_xt * mu_high_xtm1    # high-high

    # Consequent outputs (fixed linear functions)
    y1 = 0.5 * x_t + 0.5 * x_tm1
    y2 = 0.7 * x_t + 0.3 * x_tm1 - 0.1
    y3 = 0.3 * x_t + 0.7 * x_tm1 + 0.1
    y4 = 0.5 * x_t + 0.5 * x_tm1

    # Weighted average defuzzification
    numerator = w1 * y1 + w2 * y2 + w3 * y3 + w4 * y4
    denominator = w1 + w2 + w3 + w4 + 1e-8

    return numerator / denominator

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: Hybrid LSTM-SNP
# Combines: Fuzzy Feature Augmentation + Fuzzy Gate Replacement
# input_dim=2, FuzzyLSTMSNPCell, gradient clipping.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=2, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 2)]               0
#
#  rnn (RNN)                   (1, 8)                    496
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 505 (1.97 KB)
# Trainable params: 505 (1.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Dow Jones Industrial Index

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=2)
    #    Needed for fuzzy feature augmentation: x(t), x(t-1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 2)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input (with Fuzzy Feature Augmentation)
    #    supervised columns: [x(t-2), x(t-1), x(t)]
    #    We use x(t-1) as primary input, x(t-2) for fuzzy context
    # ============================================================
    
    # Extract columns: col0=x(t-2), col1=x(t-1), col2=x(t) (target)
    X_train_raw = train_scaled[:, 0:-1]  # [x(t-2), x(t-1)]
    y_train = train_scaled[:, -1]        # x(t)
    
    X_test_raw = test_scaled[:, 0:-1]
    y_test = test_scaled[:, -1]
    
    # Compute fuzzy features for training data
    X_train_fuzzy = np.zeros((X_train_raw.shape[0], 2))  # [x(t-1), y_fuzzy]
    for i in range(X_train_raw.shape[0]):
        x_t = X_train_raw[i, 1]      # x(t-1) = current input
        x_tm1 = X_train_raw[i, 0]    # x(t-2) = previous input
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_train_fuzzy[i, 0] = x_t
        X_train_fuzzy[i, 1] = y_fuzz
    
    X_train = X_train_fuzzy.reshape((X_train_fuzzy.shape[0], 1, 2))
    
    # Compute fuzzy features for test data
    X_test_fuzzy = np.zeros((X_test_raw.shape[0], 2))
    for i in range(X_test_raw.shape[0]):
        x_t = X_test_raw[i, 1]
        x_tm1 = X_test_raw[i, 0]
        y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
        X_test_fuzzy[i, 0] = x_t
        X_test_fuzzy[i, 1] = y_fuzz
    
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=2, units=8, batch_size=1)
    
        rnn_layer = model.layers[1]
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        for i in range(len(train_scaled)):
            X_raw = train_scaled[i, 0:-1]
            x_t = X_raw[1]
            x_tm1 = X_raw[0]
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            model.predict(X_aug, batch_size=1, verbose=0)
    
        # Test predictions (single-step) with fuzzy feature augmentation
        predictions = []
        for i in range(len(test_scaled)):
            X_raw = test_scaled[i, 0:-1]  # [x(t-2), x(t-1)]
            x_t = X_raw[1]      # current input
            x_tm1 = X_raw[0]    # previous input
            y_fuzz = fuzzy_inference_numpy(x_t, x_tm1)
            X_aug = np.array([x_t, y_fuzz]).reshape(1, 1, 2)
            yhat = model.predict(X_aug, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling (need to match the scaler's column structure)
            # Scaler was fit on 3-column data [x(t-2), x(t-1), x(t)]
            new_row = list(X_raw) + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Dow Jones Industrial Index (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Hybrid (Feature Aug + Gate) — Dow Jones Industrial Index\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Hybrid (Feature Aug + Gate) — Dow Jones Industrial Index\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.526428)
# ================================================================================
#
# Data shape: (291,)
# First 5 values: [3645.26148423 3625.9272138  3634.34096137 3621.30176553 3606.87673511]
# Supervised data shape: (290, 3)
# Train: (230, 3), Test: (60, 3)
# X_train shape: (230, 1, 2), y_train shape: (230,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3803.5836, Expected=3796.1139
# Month=2, Predicted=3797.5957, Expected=3793.0240
# Month=3, Predicted=3793.3903, Expected=3765.6570
# Month=4, Predicted=3762.9532, Expected=3748.1286
# Month=5, Predicted=3747.9009, Expected=3754.3337
# Month=6, Predicted=3757.3786, Expected=3754.9339
# Month=7, Predicted=3754.3304, Expected=3767.0982
# Month=8, Predicted=3769.6821, Expected=3750.6516
# Month=9, Predicted=3745.5236, Expected=3769.4487
# Month=10, Predicted=3774.3993, Expected=3759.5828
# Month=11, Predicted=3755.8153, Expected=3784.9396
# Month=12, Predicted=3791.2538, Expected=3776.2658
# Month=13, Predicted=3774.0419, Expected=3755.4558
# Month=14, Predicted=3754.9675, Expected=3754.3681
# Month=15, Predicted=3756.1362, Expected=3750.8239
# Month=16, Predicted=3751.1912, Expected=3775.7500
# Month=17, Predicted=3780.8070, Expected=3846.6561
# Month=18, Predicted=3853.5664, Expected=3830.9294
# Month=19, Predicted=3842.2290, Expected=3881.2132
# Month=20, Predicted=3889.7724, Expected=3898.3362
# Month=21, Predicted=3910.7936, Expected=3917.4832
# Month=22, Predicted=3917.4057, Expected=3914.1172
# Month=23, Predicted=3911.8274, Expected=3901.5435
# Month=24, Predicted=3901.0352, Expected=3885.2002
# Month=25, Predicted=3885.8039, Expected=3892.2451
# Month=26, Predicted=3895.5403, Expected=3899.6669
# Month=27, Predicted=3900.2211, Expected=3885.6275
# Month=28, Predicted=3881.9769, Expected=3908.2336
# Month=29, Predicted=3914.0484, Expected=3875.4078
# Month=30, Predicted=3864.7834, Expected=3859.5120
# Month=31, Predicted=3858.9673, Expected=3879.9687
# Month=32, Predicted=3885.2636, Expected=3893.2937
# Month=33, Predicted=3893.4504, Expected=3953.4607
# Month=34, Predicted=3956.7690, Expected=3932.8670
# Month=35, Predicted=3943.1699, Expected=3936.3431
# Month=36, Predicted=3938.4583, Expected=3869.8593
# Month=37, Predicted=3860.4814, Expected=3851.2471
# Month=38, Predicted=3854.3357, Expected=3836.7683
# Month=39, Predicted=3837.5599, Expected=3832.0688
# Month=40, Predicted=3834.0047, Expected=3849.7587
# Month=41, Predicted=3854.3336, Expected=3862.2441
# Month=42, Predicted=3862.0919, Expected=3878.6123
# Month=43, Predicted=3878.8520, Expected=3855.0054
# Month=44, Predicted=3847.4305, Expected=3842.4833
# Month=45, Predicted=3842.9355, Expected=3847.2433
# Month=46, Predicted=3850.4022, Expected=3801.1048
# Month=47, Predicted=3792.5011, Expected=3786.6840
# Month=48, Predicted=3786.7713, Expected=3776.0367
# Month=49, Predicted=3777.2812, Expected=3796.7972
# Month=50, Predicted=3802.4341, Expected=3821.0598
# Month=51, Predicted=3822.2106, Expected=3877.3486
# Month=52, Predicted=3882.3008, Expected=3875.8349
# Month=53, Predicted=3887.4527, Expected=3889.3484
# Month=54, Predicted=3892.3329, Expected=3911.1229
# Month=55, Predicted=3911.7111, Expected=3922.9724
# Month=56, Predicted=3922.9898, Expected=3917.9201
# Month=57, Predicted=3915.1534, Expected=3936.3097
# Month=58, Predicted=3940.9953, Expected=3911.1479
# Month=59, Predicted=3903.0606, Expected=3890.6722
# Month=60, Predicted=3890.5042, Expected=3854.8904
# Run 1 — RMSE: 23.987520, MSE: 575.401136, NMSE: 0.0025833300
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3803.7875, Expected=3796.1139
# Month=2, Predicted=3798.0041, Expected=3793.0240
# Month=3, Predicted=3793.8369, Expected=3765.6570
# Month=4, Predicted=3764.7597, Expected=3748.1286
# Month=5, Predicted=3748.0557, Expected=3754.3337
# Month=6, Predicted=3758.1612, Expected=3754.9339
# Month=7, Predicted=3754.1475, Expected=3767.0982
# Month=8, Predicted=3769.1785, Expected=3750.6516
# Month=9, Predicted=3746.2292, Expected=3769.4487
# Month=10, Predicted=3774.3953, Expected=3759.5828
# Month=11, Predicted=3755.7018, Expected=3784.9396
# Month=12, Predicted=3790.3926, Expected=3776.2658
# Month=13, Predicted=3773.7910, Expected=3755.4558
# Month=14, Predicted=3756.6792, Expected=3754.3681
# Month=15, Predicted=3757.1514, Expected=3750.8239
# Month=16, Predicted=3751.8260, Expected=3775.7500
# Month=17, Predicted=3780.1757, Expected=3846.6561
# Month=18, Predicted=3851.5168, Expected=3830.9294
# Month=19, Predicted=3846.4423, Expected=3881.2132
# Month=20, Predicted=3887.4830, Expected=3898.3362
# Month=21, Predicted=3914.9510, Expected=3917.4832
# Month=22, Predicted=3916.2190, Expected=3914.1172
# Month=23, Predicted=3910.9929, Expected=3901.5435
# Month=24, Predicted=3902.2504, Expected=3885.2002
# Month=25, Predicted=3887.5758, Expected=3892.2451
# Month=26, Predicted=3896.2939, Expected=3899.6669
# Month=27, Predicted=3899.3959, Expected=3885.6275
# Month=28, Predicted=3882.7219, Expected=3908.2336
# Month=29, Predicted=3913.6949, Expected=3875.4078
# Month=30, Predicted=3867.3164, Expected=3859.5120
# Month=31, Predicted=3857.0192, Expected=3879.9687
# Month=32, Predicted=3885.1208, Expected=3893.2937
# Month=33, Predicted=3892.5161, Expected=3953.4607
# Month=34, Predicted=3956.4203, Expected=3932.8670
# Month=35, Predicted=3945.2674, Expected=3936.3431
# Month=36, Predicted=3938.5192, Expected=3869.8593
# Month=37, Predicted=3862.6034, Expected=3851.2471
# Month=38, Predicted=3853.5830, Expected=3836.7683
# Month=39, Predicted=3839.2199, Expected=3832.0688
# Month=40, Predicted=3835.3093, Expected=3849.7587
# Month=41, Predicted=3853.7757, Expected=3862.2441
# Month=42, Predicted=3861.0879, Expected=3878.6123
# Month=43, Predicted=3877.9948, Expected=3855.0054
# Month=44, Predicted=3848.6755, Expected=3842.4833
# Month=45, Predicted=3843.8725, Expected=3847.2433
# Month=46, Predicted=3851.1627, Expected=3801.1048
# Month=47, Predicted=3794.8507, Expected=3786.6840
# Month=48, Predicted=3779.2773, Expected=3776.0367
# Month=49, Predicted=3778.8516, Expected=3796.7972
# Month=50, Predicted=3802.0175, Expected=3821.0598
# Month=51, Predicted=3821.4467, Expected=3877.3486
# Month=52, Predicted=3880.9557, Expected=3875.8349
# Month=53, Predicted=3892.4494, Expected=3889.3484
# Month=54, Predicted=3891.0833, Expected=3911.1229
# Month=55, Predicted=3911.0668, Expected=3922.9724
# Month=56, Predicted=3922.1321, Expected=3917.9201
# Month=57, Predicted=3914.9073, Expected=3936.3097
# Month=58, Predicted=3940.4320, Expected=3911.1479
# Month=59, Predicted=3904.5209, Expected=3890.6722
# Month=60, Predicted=3891.2403, Expected=3854.8904
# Run 2 — RMSE: 23.995429, MSE: 575.780595, NMSE: 0.0025824023
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3800.6256, Expected=3796.1139
# Month=2, Predicted=3796.5960, Expected=3793.0240
# Month=3, Predicted=3793.8068, Expected=3765.6570
# Month=4, Predicted=3765.3034, Expected=3748.1286
# Month=5, Predicted=3746.5487, Expected=3754.3337
# Month=6, Predicted=3754.7508, Expected=3754.9339
# Month=7, Predicted=3755.9505, Expected=3767.0982
# Month=8, Predicted=3768.8211, Expected=3750.6516
# Month=9, Predicted=3750.5664, Expected=3769.4487
# Month=10, Predicted=3770.9415, Expected=3759.5828
# Month=11, Predicted=3759.7955, Expected=3784.9396
# Month=12, Predicted=3787.2826, Expected=3776.2658
# Month=13, Predicted=3776.4504, Expected=3755.4558
# Month=14, Predicted=3755.3571, Expected=3754.3681
# Month=15, Predicted=3753.8340, Expected=3750.8239
# Month=16, Predicted=3751.6573, Expected=3775.7500
# Month=17, Predicted=3778.2473, Expected=3846.6561
# Month=18, Predicted=3852.6230, Expected=3830.9294
# Month=19, Predicted=3829.5292, Expected=3881.2132
# Month=20, Predicted=3884.5296, Expected=3898.3362
# Month=21, Predicted=3900.0299, Expected=3917.4832
# Month=22, Predicted=3919.4561, Expected=3914.1172
# Month=23, Predicted=3914.7193, Expected=3901.5435
# Month=24, Predicted=3901.9145, Expected=3885.2002
# Month=25, Predicted=3885.0792, Expected=3892.2451
# Month=26, Predicted=3892.9291, Expected=3899.6669
# Month=27, Predicted=3901.0917, Expected=3885.6275
# Month=28, Predicted=3885.7773, Expected=3908.2336
# Month=29, Predicted=3910.2881, Expected=3875.4078
# Month=30, Predicted=3873.8289, Expected=3859.5120
# Month=31, Predicted=3857.7692, Expected=3879.9687
# Month=32, Predicted=3881.7555, Expected=3893.2937
# Month=33, Predicted=3895.0011, Expected=3953.4607
# Month=34, Predicted=3958.5466, Expected=3932.8670
# Month=35, Predicted=3931.2792, Expected=3936.3431
# Month=36, Predicted=3935.8506, Expected=3869.8593
# Month=37, Predicted=3868.1967, Expected=3851.2471
# Month=38, Predicted=3851.9334, Expected=3836.7683
# Month=39, Predicted=3836.0641, Expected=3832.0688
# Month=40, Predicted=3832.3304, Expected=3849.7587
# Month=41, Predicted=3851.7892, Expected=3862.2441
# Month=42, Predicted=3863.9207, Expected=3878.6123
# Month=43, Predicted=3880.5556, Expected=3855.0054
# Month=44, Predicted=3854.3173, Expected=3842.4833
# Month=45, Predicted=3841.2373, Expected=3847.2433
# Month=46, Predicted=3848.3970, Expected=3801.1048
# Month=47, Predicted=3799.4311, Expected=3786.6840
# Month=48, Predicted=3785.4191, Expected=3776.0367
# Month=49, Predicted=3776.0008, Expected=3796.7972
# Month=50, Predicted=3798.8806, Expected=3821.0598
# Month=51, Predicted=3823.5237, Expected=3877.3486
# Month=52, Predicted=3882.1263, Expected=3875.8349
# Month=53, Predicted=3876.0398, Expected=3889.3484
# Month=54, Predicted=3890.9758, Expected=3911.1229
# Month=55, Predicted=3913.4556, Expected=3922.9724
# Month=56, Predicted=3924.5514, Expected=3917.9201
# Month=57, Predicted=3918.5024, Expected=3936.3097
# Month=58, Predicted=3938.3578, Expected=3911.1479
# Month=59, Predicted=3910.3012, Expected=3890.6722
# Month=60, Predicted=3889.1919, Expected=3854.8904
# Run 3 — RMSE: 24.401377, MSE: 595.427218, NMSE: 0.0027018553
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3802.0824, Expected=3796.1139
# Month=2, Predicted=3798.2456, Expected=3793.0240
# Month=3, Predicted=3793.3582, Expected=3765.6570
# Month=4, Predicted=3761.9939, Expected=3748.1286
# Month=5, Predicted=3747.2223, Expected=3754.3337
# Month=6, Predicted=3756.7920, Expected=3754.9339
# Month=7, Predicted=3754.5737, Expected=3767.0982
# Month=8, Predicted=3769.7229, Expected=3750.6516
# Month=9, Predicted=3745.8729, Expected=3769.4487
# Month=10, Predicted=3774.1061, Expected=3759.5828
# Month=11, Predicted=3756.3548, Expected=3784.9396
# Month=12, Predicted=3790.7211, Expected=3776.2658
# Month=13, Predicted=3774.1439, Expected=3755.4558
# Month=14, Predicted=3754.2535, Expected=3754.3681
# Month=15, Predicted=3755.3901, Expected=3750.8239
# Month=16, Predicted=3750.7798, Expected=3775.7500
# Month=17, Predicted=3779.9561, Expected=3846.6561
# Month=18, Predicted=3851.0737, Expected=3830.9294
# Month=19, Predicted=3836.3211, Expected=3881.2132
# Month=20, Predicted=3887.8400, Expected=3898.3362
# Month=21, Predicted=3905.9733, Expected=3917.4832
# Month=22, Predicted=3918.7925, Expected=3914.1172
# Month=23, Predicted=3912.8724, Expected=3901.5435
# Month=24, Predicted=3900.5811, Expected=3885.2002
# Month=25, Predicted=3884.8724, Expected=3892.2451
# Month=26, Predicted=3894.9769, Expected=3899.6669
# Month=27, Predicted=3900.6493, Expected=3885.6275
# Month=28, Predicted=3882.1081, Expected=3908.2336
# Month=29, Predicted=3913.7296, Expected=3875.4078
# Month=30, Predicted=3864.3812, Expected=3859.5120
# Month=31, Predicted=3858.6912, Expected=3879.9687
# Month=32, Predicted=3884.9049, Expected=3893.2937
# Month=33, Predicted=3894.8229, Expected=3953.4607
# Month=34, Predicted=3955.9416, Expected=3932.8670
# Month=35, Predicted=3934.9943, Expected=3936.3431
# Month=36, Predicted=3938.2808, Expected=3869.8593
# Month=37, Predicted=3861.9982, Expected=3851.2471
# Month=38, Predicted=3855.5910, Expected=3836.7683
# Month=39, Predicted=3836.4313, Expected=3832.0688
# Month=40, Predicted=3833.2156, Expected=3849.7587
# Month=41, Predicted=3853.9975, Expected=3862.2441
# Month=42, Predicted=3863.5966, Expected=3878.6123
# Month=43, Predicted=3880.0441, Expected=3855.0054
# Month=44, Predicted=3847.8533, Expected=3842.4833
# Month=45, Predicted=3842.1540, Expected=3847.2433
# Month=46, Predicted=3849.8205, Expected=3801.1048
# Month=47, Predicted=3791.8672, Expected=3786.6840
# Month=48, Predicted=3786.9375, Expected=3776.0367
# Month=49, Predicted=3776.3703, Expected=3796.7972
# Month=50, Predicted=3802.0156, Expected=3821.0598
# Month=51, Predicted=3822.9715, Expected=3877.3486
# Month=52, Predicted=3880.9205, Expected=3875.8349
# Month=53, Predicted=3883.3887, Expected=3889.3484
# Month=54, Predicted=3892.6177, Expected=3911.1229
# Month=55, Predicted=3912.6844, Expected=3922.9724
# Month=56, Predicted=3924.4711, Expected=3917.9201
# Month=57, Predicted=3916.0709, Expected=3936.3097
# Month=58, Predicted=3940.7538, Expected=3911.1479
# Month=59, Predicted=3903.1786, Expected=3890.6722
# Month=60, Predicted=3889.7660, Expected=3854.8904
# Run 4 — RMSE: 24.063058, MSE: 579.030742, NMSE: 0.0026115625
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3800.7656, Expected=3796.1139
# Month=2, Predicted=3795.1030, Expected=3793.0240
# Month=3, Predicted=3793.2972, Expected=3765.6570
# Month=4, Predicted=3764.4074, Expected=3748.1286
# Month=5, Predicted=3747.1742, Expected=3754.3337
# Month=6, Predicted=3756.7802, Expected=3754.9339
# Month=7, Predicted=3755.6316, Expected=3767.0982
# Month=8, Predicted=3769.7946, Expected=3750.6516
# Month=9, Predicted=3749.1029, Expected=3769.4487
# Month=10, Predicted=3773.2210, Expected=3759.5828
# Month=11, Predicted=3758.8225, Expected=3784.9396
# Month=12, Predicted=3789.9081, Expected=3776.2658
# Month=13, Predicted=3775.4607, Expected=3755.4558
# Month=14, Predicted=3754.8233, Expected=3754.3681
# Month=15, Predicted=3755.6018, Expected=3750.8239
# Month=16, Predicted=3752.3464, Expected=3775.7500
# Month=17, Predicted=3780.7755, Expected=3846.6561
# Month=18, Predicted=3854.2352, Expected=3830.9294
# Month=19, Predicted=3828.1134, Expected=3881.2132
# Month=20, Predicted=3886.7262, Expected=3898.3362
# Month=21, Predicted=3899.8737, Expected=3917.4832
# Month=22, Predicted=3918.6758, Expected=3914.1172
# Month=23, Predicted=3913.6220, Expected=3901.5435
# Month=24, Predicted=3901.6128, Expected=3885.2002
# Month=25, Predicted=3885.8591, Expected=3892.2451
# Month=26, Predicted=3894.9852, Expected=3899.6669
# Month=27, Predicted=3901.1193, Expected=3885.6275
# Month=28, Predicted=3884.3908, Expected=3908.2336
# Month=29, Predicted=3912.9514, Expected=3875.4078
# Month=30, Predicted=3871.2427, Expected=3859.5120
# Month=31, Predicted=3858.2499, Expected=3879.9687
# Month=32, Predicted=3884.4233, Expected=3893.2937
# Month=33, Predicted=3895.0814, Expected=3953.4607
# Month=34, Predicted=3960.1040, Expected=3932.8670
# Month=35, Predicted=3929.5706, Expected=3936.3431
# Month=36, Predicted=3936.7322, Expected=3869.8593
# Month=37, Predicted=3860.8345, Expected=3851.2471
# Month=38, Predicted=3853.5514, Expected=3836.7683
# Month=39, Predicted=3837.8709, Expected=3832.0688
# Month=40, Predicted=3833.8115, Expected=3849.7587
# Month=41, Predicted=3854.1926, Expected=3862.2441
# Month=42, Predicted=3863.9306, Expected=3878.6123
# Month=43, Predicted=3880.4879, Expected=3855.0054
# Month=44, Predicted=3852.1335, Expected=3842.4833
# Month=45, Predicted=3842.4439, Expected=3847.2433
# Month=46, Predicted=3850.1869, Expected=3801.1048
# Month=47, Predicted=3795.4762, Expected=3786.6840
# Month=48, Predicted=3778.4595, Expected=3776.0367
# Month=49, Predicted=3777.4240, Expected=3796.7972
# Month=50, Predicted=3801.8268, Expected=3821.0598
# Month=51, Predicted=3824.0072, Expected=3877.3486
# Month=52, Predicted=3883.0452, Expected=3875.8349
# Month=53, Predicted=3874.7674, Expected=3889.3484
# Month=54, Predicted=3890.4132, Expected=3911.1229
# Month=55, Predicted=3913.9286, Expected=3922.9724
# Month=56, Predicted=3924.1672, Expected=3917.9201
# Month=57, Predicted=3917.3013, Expected=3936.3097
# Month=58, Predicted=3940.3896, Expected=3911.1479
# Month=59, Predicted=3908.2714, Expected=3890.6722
# Month=60, Predicted=3889.9896, Expected=3854.8904
# Run 5 — RMSE: 24.368600, MSE: 593.828666, NMSE: 0.0026923271
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3798.3351, Expected=3796.1139
# Month=2, Predicted=3796.0071, Expected=3793.0240
# Month=3, Predicted=3795.8015, Expected=3765.6570
# Month=4, Predicted=3767.3077, Expected=3748.1286
# Month=5, Predicted=3746.5102, Expected=3754.3337
# Month=6, Predicted=3757.2588, Expected=3754.9339
# Month=7, Predicted=3756.4061, Expected=3767.0982
# Month=8, Predicted=3770.9417, Expected=3750.6516
# Month=9, Predicted=3749.6937, Expected=3769.4487
# Month=10, Predicted=3773.4501, Expected=3759.5828
# Month=11, Predicted=3758.8898, Expected=3784.9396
# Month=12, Predicted=3790.5577, Expected=3776.2658
# Month=13, Predicted=3775.7826, Expected=3755.4558
# Month=14, Predicted=3757.8486, Expected=3754.3681
# Month=15, Predicted=3755.9089, Expected=3750.8239
# Month=16, Predicted=3753.7581, Expected=3775.7500
# Month=17, Predicted=3781.4147, Expected=3846.6561
# Month=18, Predicted=3847.8486, Expected=3830.9294
# Month=19, Predicted=3831.8777, Expected=3881.2132
# Month=20, Predicted=3887.4630, Expected=3898.3362
# Month=21, Predicted=3899.4245, Expected=3917.4832
# Month=22, Predicted=3917.1990, Expected=3914.1172
# Month=23, Predicted=3913.5344, Expected=3901.5435
# Month=24, Predicted=3904.0831, Expected=3885.2002
# Month=25, Predicted=3887.7741, Expected=3892.2451
# Month=26, Predicted=3895.5135, Expected=3899.6669
# Month=27, Predicted=3901.4372, Expected=3885.6275
# Month=28, Predicted=3885.5254, Expected=3908.2336
# Month=29, Predicted=3913.0962, Expected=3875.4078
# Month=30, Predicted=3874.3283, Expected=3859.5120
# Month=31, Predicted=3855.6668, Expected=3879.9687
# Month=32, Predicted=3884.2859, Expected=3893.2937
# Month=33, Predicted=3893.0855, Expected=3953.4607
# Month=34, Predicted=3957.9820, Expected=3932.8670
# Month=35, Predicted=3933.2078, Expected=3936.3431
# Month=36, Predicted=3937.8983, Expected=3869.8593
# Month=37, Predicted=3868.7291, Expected=3851.2471
# Month=38, Predicted=3851.5547, Expected=3836.7683
# Month=39, Predicted=3838.3655, Expected=3832.0688
# Month=40, Predicted=3835.0037, Expected=3849.7587
# Month=41, Predicted=3854.8630, Expected=3862.2441
# Month=42, Predicted=3861.9213, Expected=3878.6123
# Month=43, Predicted=3879.0017, Expected=3855.0054
# Month=44, Predicted=3854.0005, Expected=3842.4833
# Month=45, Predicted=3842.4994, Expected=3847.2433
# Month=46, Predicted=3851.0374, Expected=3801.1048
# Month=47, Predicted=3799.9746, Expected=3786.6840
# Month=48, Predicted=3778.4659, Expected=3776.0367
# Month=49, Predicted=3778.6755, Expected=3796.7972
# Month=50, Predicted=3802.0558, Expected=3821.0598
# Month=51, Predicted=3821.0808, Expected=3877.3486
# Month=52, Predicted=3878.1611, Expected=3875.8349
# Month=53, Predicted=3876.6603, Expected=3889.3484
# Month=54, Predicted=3893.1328, Expected=3911.1229
# Month=55, Predicted=3911.7402, Expected=3922.9724
# Month=56, Predicted=3922.7637, Expected=3917.9201
# Month=57, Predicted=3917.1110, Expected=3936.3097
# Month=58, Predicted=3941.4206, Expected=3911.1479
# Month=59, Predicted=3910.1560, Expected=3890.6722
# Month=60, Predicted=3889.8033, Expected=3854.8904
# Run 6 — RMSE: 24.543811, MSE: 602.398665, NMSE: 0.0027566355
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3802.1763, Expected=3796.1139
# Month=2, Predicted=3797.0258, Expected=3793.0240
# Month=3, Predicted=3792.9995, Expected=3765.6570
# Month=4, Predicted=3762.7647, Expected=3748.1286
# Month=5, Predicted=3747.4168, Expected=3754.3337
# Month=6, Predicted=3756.6898, Expected=3754.9339
# Month=7, Predicted=3755.6770, Expected=3767.0982
# Month=8, Predicted=3769.9307, Expected=3750.6516
# Month=9, Predicted=3747.7109, Expected=3769.4487
# Month=10, Predicted=3773.3024, Expected=3759.5828
# Month=11, Predicted=3758.2723, Expected=3784.9396
# Month=12, Predicted=3790.1726, Expected=3776.2658
# Month=13, Predicted=3775.7313, Expected=3755.4558
# Month=14, Predicted=3753.9620, Expected=3754.3681
# Month=15, Predicted=3755.4490, Expected=3750.8239
# Month=16, Predicted=3751.5647, Expected=3775.7500
# Month=17, Predicted=3780.9643, Expected=3846.6561
# Month=18, Predicted=3851.3020, Expected=3830.9294
# Month=19, Predicted=3832.6359, Expected=3881.2132
# Month=20, Predicted=3888.2003, Expected=3898.3362
# Month=21, Predicted=3902.9749, Expected=3917.4832
# Month=22, Predicted=3919.7564, Expected=3914.1172
# Month=23, Predicted=3913.6190, Expected=3901.5435
# Month=24, Predicted=3900.6037, Expected=3885.2002
# Month=25, Predicted=3885.1923, Expected=3892.2451
# Month=26, Predicted=3894.8433, Expected=3899.6669
# Month=27, Predicted=3901.4467, Expected=3885.6275
# Month=28, Predicted=3883.4367, Expected=3908.2336
# Month=29, Predicted=3913.0397, Expected=3875.4078
# Month=30, Predicted=3868.7402, Expected=3859.5120
# Month=31, Predicted=3857.8332, Expected=3879.9687
# Month=32, Predicted=3884.4564, Expected=3893.2937
# Month=33, Predicted=3895.8209, Expected=3953.4607
# Month=34, Predicted=3958.5075, Expected=3932.8670
# Month=35, Predicted=3932.5277, Expected=3936.3431
# Month=36, Predicted=3936.5574, Expected=3869.8593
# Month=37, Predicted=3861.8062, Expected=3851.2471
# Month=38, Predicted=3854.1484, Expected=3836.7683
# Month=39, Predicted=3837.0085, Expected=3832.0688
# Month=40, Predicted=3833.4306, Expected=3849.7587
# Month=41, Predicted=3854.1198, Expected=3862.2441
# Month=42, Predicted=3864.3675, Expected=3878.6123
# Month=43, Predicted=3880.9646, Expected=3855.0054
# Month=44, Predicted=3850.1519, Expected=3842.4833
# Month=45, Predicted=3842.1674, Expected=3847.2433
# Month=46, Predicted=3849.8454, Expected=3801.1048
# Month=47, Predicted=3793.6334, Expected=3786.6840
# Month=48, Predicted=3784.6393, Expected=3776.0367
# Month=49, Predicted=3776.6925, Expected=3796.7972
# Month=50, Predicted=3801.7918, Expected=3821.0598
# Month=51, Predicted=3824.8536, Expected=3877.3486
# Month=52, Predicted=3881.9606, Expected=3875.8349
# Month=53, Predicted=3879.0967, Expected=3889.3484
# Month=54, Predicted=3891.4838, Expected=3911.1229
# Month=55, Predicted=3914.3630, Expected=3922.9724
# Month=56, Predicted=3925.1470, Expected=3917.9201
# Month=57, Predicted=3916.7743, Expected=3936.3097
# Month=58, Predicted=3940.4750, Expected=3911.1479
# Month=59, Predicted=3906.2745, Expected=3890.6722
# Month=60, Predicted=3889.8903, Expected=3854.8904
# Run 7 — RMSE: 23.994874, MSE: 575.753973, NMSE: 0.0026037990
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3804.7073, Expected=3796.1139
# Month=2, Predicted=3798.2036, Expected=3793.0240
# Month=3, Predicted=3793.1695, Expected=3765.6570
# Month=4, Predicted=3764.8768, Expected=3748.1286
# Month=5, Predicted=3746.4589, Expected=3754.3337
# Month=6, Predicted=3759.1305, Expected=3754.9339
# Month=7, Predicted=3753.7362, Expected=3767.0982
# Month=8, Predicted=3768.3718, Expected=3750.6516
# Month=9, Predicted=3746.4682, Expected=3769.4487
# Month=10, Predicted=3774.6964, Expected=3759.5828
# Month=11, Predicted=3756.0678, Expected=3784.9396
# Month=12, Predicted=3789.6474, Expected=3776.2658
# Month=13, Predicted=3774.2279, Expected=3755.4558
# Month=14, Predicted=3756.6351, Expected=3754.3681
# Month=15, Predicted=3759.2221, Expected=3750.8239
# Month=16, Predicted=3751.2791, Expected=3775.7500
# Month=17, Predicted=3779.2385, Expected=3846.6561
# Month=18, Predicted=3852.6068, Expected=3830.9294
# Month=19, Predicted=3844.6271, Expected=3881.2132
# Month=20, Predicted=3886.9584, Expected=3898.3362
# Month=21, Predicted=3912.6722, Expected=3917.4832
# Month=22, Predicted=3916.8615, Expected=3914.1172
# Month=23, Predicted=3911.4774, Expected=3901.5435
# Month=24, Predicted=3901.8182, Expected=3885.2002
# Month=25, Predicted=3887.9918, Expected=3892.2451
# Month=26, Predicted=3896.9338, Expected=3899.6669
# Month=27, Predicted=3898.9501, Expected=3885.6275
# Month=28, Predicted=3882.6599, Expected=3908.2336
# Month=29, Predicted=3913.5326, Expected=3875.4078
# Month=30, Predicted=3868.1309, Expected=3859.5120
# Month=31, Predicted=3855.1186, Expected=3879.9687
# Month=32, Predicted=3885.4439, Expected=3893.2937
# Month=33, Predicted=3893.0060, Expected=3953.4607
# Month=34, Predicted=3956.9000, Expected=3932.8670
# Month=35, Predicted=3944.1780, Expected=3936.3431
# Month=36, Predicted=3939.9919, Expected=3869.8593
# Month=37, Predicted=3866.0445, Expected=3851.2471
# Month=38, Predicted=3852.5603, Expected=3836.7683
# Month=39, Predicted=3840.9541, Expected=3832.0688
# Month=40, Predicted=3835.8343, Expected=3849.7587
# Month=41, Predicted=3852.9535, Expected=3862.2441
# Month=42, Predicted=3861.4400, Expected=3878.6123
# Month=43, Predicted=3878.0025, Expected=3855.0054
# Month=44, Predicted=3849.3211, Expected=3842.4833
# Month=45, Predicted=3844.5065, Expected=3847.2433
# Month=46, Predicted=3851.1798, Expected=3801.1048
# Month=47, Predicted=3795.7560, Expected=3786.6840
# Month=48, Predicted=3781.3749, Expected=3776.0367
# Month=49, Predicted=3779.5200, Expected=3796.7972
# Month=50, Predicted=3801.5354, Expected=3821.0598
# Month=51, Predicted=3822.1245, Expected=3877.3486
# Month=52, Predicted=3882.5262, Expected=3875.8349
# Month=53, Predicted=3890.4862, Expected=3889.3484
# Month=54, Predicted=3890.1584, Expected=3911.1229
# Month=55, Predicted=3911.1324, Expected=3922.9724
# Month=56, Predicted=3922.7763, Expected=3917.9201
# Month=57, Predicted=3914.9839, Expected=3936.3097
# Month=58, Predicted=3939.5400, Expected=3911.1479
# Month=59, Predicted=3905.1893, Expected=3890.6722
# Month=60, Predicted=3890.1139, Expected=3854.8904
# Run 8 — RMSE: 24.181981, MSE: 584.768191, NMSE: 0.0026288273
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3800.7200, Expected=3796.1139
# Month=2, Predicted=3796.1641, Expected=3793.0240
# Month=3, Predicted=3793.7681, Expected=3765.6570
# Month=4, Predicted=3763.8673, Expected=3748.1286
# Month=5, Predicted=3745.0895, Expected=3754.3337
# Month=6, Predicted=3756.0178, Expected=3754.9339
# Month=7, Predicted=3755.9005, Expected=3767.0982
# Month=8, Predicted=3769.3681, Expected=3750.6516
# Month=9, Predicted=3749.6403, Expected=3769.4487
# Month=10, Predicted=3772.3540, Expected=3759.5828
# Month=11, Predicted=3759.1261, Expected=3784.9396
# Month=12, Predicted=3788.6642, Expected=3776.2658
# Month=13, Predicted=3775.7798, Expected=3755.4558
# Month=14, Predicted=3754.6469, Expected=3754.3681
# Month=15, Predicted=3755.4084, Expected=3750.8239
# Month=16, Predicted=3751.5729, Expected=3775.7500
# Month=17, Predicted=3779.4136, Expected=3846.6561
# Month=18, Predicted=3852.9940, Expected=3830.9294
# Month=19, Predicted=3829.6162, Expected=3881.2132
# Month=20, Predicted=3887.1089, Expected=3898.3362
# Month=21, Predicted=3899.8719, Expected=3917.4832
# Month=22, Predicted=3919.8333, Expected=3914.1172
# Month=23, Predicted=3914.2893, Expected=3901.5435
# Month=24, Predicted=3901.4205, Expected=3885.2002
# Month=25, Predicted=3884.9699, Expected=3892.2451
# Month=26, Predicted=3894.0326, Expected=3899.6669
# Month=27, Predicted=3901.2901, Expected=3885.6275
# Month=28, Predicted=3885.0352, Expected=3908.2336
# Month=29, Predicted=3911.6124, Expected=3875.4078
# Month=30, Predicted=3871.7956, Expected=3859.5120
# Month=31, Predicted=3856.0303, Expected=3879.9687
# Month=32, Predicted=3883.0944, Expected=3893.2937
# Month=33, Predicted=3895.0722, Expected=3953.4607
# Month=34, Predicted=3959.6315, Expected=3932.8670
# Month=35, Predicted=3930.7485, Expected=3936.3431
# Month=36, Predicted=3937.6142, Expected=3869.8593
# Month=37, Predicted=3861.7612, Expected=3851.2471
# Month=38, Predicted=3852.2678, Expected=3836.7683
# Month=39, Predicted=3837.0471, Expected=3832.0688
# Month=40, Predicted=3832.8374, Expected=3849.7587
# Month=41, Predicted=3852.7160, Expected=3862.2441
# Month=42, Predicted=3864.0196, Expected=3878.6123
# Month=43, Predicted=3880.9090, Expected=3855.0054
# Month=44, Predicted=3852.9373, Expected=3842.4833
# Month=45, Predicted=3841.4197, Expected=3847.2433
# Month=46, Predicted=3848.8940, Expected=3801.1048
# Month=47, Predicted=3795.9360, Expected=3786.6840
# Month=48, Predicted=3784.4393, Expected=3776.0367
# Month=49, Predicted=3776.3669, Expected=3796.7972
# Month=50, Predicted=3800.0778, Expected=3821.0598
# Month=51, Predicted=3823.8359, Expected=3877.3486
# Month=52, Predicted=3882.6367, Expected=3875.8349
# Month=53, Predicted=3875.8046, Expected=3889.3484
# Month=54, Predicted=3891.7214, Expected=3911.1229
# Month=55, Predicted=3913.9221, Expected=3922.9724
# Month=56, Predicted=3924.5488, Expected=3917.9201
# Month=57, Predicted=3918.1151, Expected=3936.3097
# Month=58, Predicted=3939.3205, Expected=3911.1479
# Month=59, Predicted=3908.8162, Expected=3890.6722
# Month=60, Predicted=3888.1118, Expected=3854.8904
# Run 9 — RMSE: 24.350137, MSE: 592.929164, NMSE: 0.0026808327
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3806.1539, Expected=3796.1139
# Month=2, Predicted=3796.8583, Expected=3793.0240
# Month=3, Predicted=3792.3223, Expected=3765.6570
# Month=4, Predicted=3764.4481, Expected=3748.1286
# Month=5, Predicted=3748.8261, Expected=3754.3337
# Month=6, Predicted=3756.2949, Expected=3754.9339
# Month=7, Predicted=3754.4052, Expected=3767.0982
# Month=8, Predicted=3767.5809, Expected=3750.6516
# Month=9, Predicted=3748.3486, Expected=3769.4487
# Month=10, Predicted=3771.8591, Expected=3759.5828
# Month=11, Predicted=3758.0409, Expected=3784.9396
# Month=12, Predicted=3787.0596, Expected=3776.2658
# Month=13, Predicted=3775.6033, Expected=3755.4558
# Month=14, Predicted=3754.9035, Expected=3754.3681
# Month=15, Predicted=3755.9389, Expected=3750.8239
# Month=16, Predicted=3750.7671, Expected=3775.7500
# Month=17, Predicted=3777.5298, Expected=3846.6561
# Month=18, Predicted=3859.1642, Expected=3830.9294
# Month=19, Predicted=3840.8802, Expected=3881.2132
# Month=20, Predicted=3883.7513, Expected=3898.3362
# Month=21, Predicted=3910.9761, Expected=3917.4832
# Month=22, Predicted=3916.8866, Expected=3914.1172
# Month=23, Predicted=3912.6614, Expected=3901.5435
# Month=24, Predicted=3900.9246, Expected=3885.2002
# Month=25, Predicted=3885.6769, Expected=3892.2451
# Month=26, Predicted=3894.2021, Expected=3899.6669
# Month=27, Predicted=3899.5871, Expected=3885.6275
# Month=28, Predicted=3883.8013, Expected=3908.2336
# Month=29, Predicted=3910.7652, Expected=3875.4078
# Month=30, Predicted=3871.1405, Expected=3859.5120
# Month=31, Predicted=3860.0057, Expected=3879.9687
# Month=32, Predicted=3882.6606, Expected=3893.2937
# Month=33, Predicted=3894.7899, Expected=3953.4607
# Month=34, Predicted=3959.2882, Expected=3932.8670
# Month=35, Predicted=3941.8096, Expected=3936.3431
# Month=36, Predicted=3936.7761, Expected=3869.8593
# Month=37, Predicted=3865.1453, Expected=3851.2471
# Month=38, Predicted=3857.3461, Expected=3836.7683
# Month=39, Predicted=3837.7424, Expected=3832.0688
# Month=40, Predicted=3833.3108, Expected=3849.7587
# Month=41, Predicted=3851.2848, Expected=3862.2441
# Month=42, Predicted=3863.0247, Expected=3878.6123
# Month=43, Predicted=3878.7812, Expected=3855.0054
# Month=44, Predicted=3851.5848, Expected=3842.4833
# Month=45, Predicted=3843.2142, Expected=3847.2433
# Month=46, Predicted=3848.8400, Expected=3801.1048
# Month=47, Predicted=3797.4258, Expected=3786.6840
# Month=48, Predicted=3788.5232, Expected=3776.0367
# Month=49, Predicted=3776.9765, Expected=3796.7972
# Month=50, Predicted=3799.0937, Expected=3821.0598
# Month=51, Predicted=3824.1465, Expected=3877.3486
# Month=52, Predicted=3885.9001, Expected=3875.8349
# Month=53, Predicted=3886.6322, Expected=3889.3484
# Month=54, Predicted=3888.8318, Expected=3911.1229
# Month=55, Predicted=3912.4759, Expected=3922.9724
# Month=56, Predicted=3923.8474, Expected=3917.9201
# Month=57, Predicted=3916.0587, Expected=3936.3097
# Month=58, Predicted=3937.6599, Expected=3911.1479
# Month=59, Predicted=3907.8003, Expected=3890.6722
# Month=60, Predicted=3891.0605, Expected=3854.8904
# Run 10 — RMSE: 24.145100, MSE: 582.985873, NMSE: 0.0026206103
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3804.0279, Expected=3796.1139
# Month=2, Predicted=3797.5077, Expected=3793.0240
# Month=3, Predicted=3792.8703, Expected=3765.6570
# Month=4, Predicted=3763.4977, Expected=3748.1286
# Month=5, Predicted=3747.0715, Expected=3754.3337
# Month=6, Predicted=3756.8880, Expected=3754.9339
# Month=7, Predicted=3754.5460, Expected=3767.0982
# Month=8, Predicted=3768.2739, Expected=3750.6516
# Month=9, Predicted=3747.9326, Expected=3769.4487
# Month=10, Predicted=3773.1032, Expected=3759.5828
# Month=11, Predicted=3757.8110, Expected=3784.9396
# Month=12, Predicted=3788.6660, Expected=3776.2658
# Month=13, Predicted=3775.3531, Expected=3755.4558
# Month=14, Predicted=3754.7679, Expected=3754.3681
# Month=15, Predicted=3755.7842, Expected=3750.8239
# Month=16, Predicted=3750.9690, Expected=3775.7500
# Month=17, Predicted=3778.6378, Expected=3846.6561
# Month=18, Predicted=3854.0823, Expected=3830.9294
# Month=19, Predicted=3843.0300, Expected=3881.2132
# Month=20, Predicted=3886.7950, Expected=3898.3362
# Month=21, Predicted=3909.4917, Expected=3917.4832
# Month=22, Predicted=3917.9376, Expected=3914.1172
# Month=23, Predicted=3912.8495, Expected=3901.5435
# Month=24, Predicted=3900.9474, Expected=3885.2002
# Month=25, Predicted=3885.5901, Expected=3892.2451
# Month=26, Predicted=3894.8689, Expected=3899.6669
# Month=27, Predicted=3899.8378, Expected=3885.6275
# Month=28, Predicted=3883.5058, Expected=3908.2336
# Month=29, Predicted=3912.2247, Expected=3875.4078
# Month=30, Predicted=3870.0420, Expected=3859.5120
# Month=31, Predicted=3856.8244, Expected=3879.9687
# Month=32, Predicted=3884.0457, Expected=3893.2937
# Month=33, Predicted=3894.3068, Expected=3953.4607
# Month=34, Predicted=3957.6120, Expected=3932.8670
# Month=35, Predicted=3942.0668, Expected=3936.3431
# Month=36, Predicted=3937.4765, Expected=3869.8593
# Month=37, Predicted=3860.6014, Expected=3851.2471
# Month=38, Predicted=3852.4792, Expected=3836.7683
# Month=39, Predicted=3838.3140, Expected=3832.0688
# Month=40, Predicted=3833.6209, Expected=3849.7587
# Month=41, Predicted=3852.2966, Expected=3862.2441
# Month=42, Predicted=3862.7973, Expected=3878.6123
# Month=43, Predicted=3879.1370, Expected=3855.0054
# Month=44, Predicted=3851.0234, Expected=3842.4833
# Month=45, Predicted=3842.4272, Expected=3847.2433
# Month=46, Predicted=3849.5951, Expected=3801.1048
# Month=47, Predicted=3794.6030, Expected=3786.6840
# Month=48, Predicted=3780.7831, Expected=3776.0367
# Month=49, Predicted=3777.4101, Expected=3796.7972
# Month=50, Predicted=3800.4291, Expected=3821.0598
# Month=51, Predicted=3823.2302, Expected=3877.3486
# Month=52, Predicted=3883.0157, Expected=3875.8349
# Month=53, Predicted=3886.4914, Expected=3889.3484
# Month=54, Predicted=3890.3428, Expected=3911.1229
# Month=55, Predicted=3912.3399, Expected=3922.9724
# Month=56, Predicted=3923.7406, Expected=3917.9201
# Month=57, Predicted=3916.3021, Expected=3936.3097
# Month=58, Predicted=3938.8106, Expected=3911.1479
# Month=59, Predicted=3907.0571, Expected=3890.6722
# Month=60, Predicted=3889.8768, Expected=3854.8904
# Run 11 — RMSE: 23.864751, MSE: 569.526345, NMSE: 0.0025508569
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3803.0806, Expected=3796.1139
# Month=2, Predicted=3796.8194, Expected=3793.0240
# Month=3, Predicted=3792.7880, Expected=3765.6570
# Month=4, Predicted=3763.7727, Expected=3748.1286
# Month=5, Predicted=3747.2649, Expected=3754.3337
# Month=6, Predicted=3755.1142, Expected=3754.9339
# Month=7, Predicted=3755.2655, Expected=3767.0982
# Month=8, Predicted=3768.6462, Expected=3750.6516
# Month=9, Predicted=3749.0178, Expected=3769.4487
# Month=10, Predicted=3771.3559, Expected=3759.5828
# Month=11, Predicted=3758.7802, Expected=3784.9396
# Month=12, Predicted=3787.7511, Expected=3776.2658
# Month=13, Predicted=3775.8546, Expected=3755.4558
# Month=14, Predicted=3754.2606, Expected=3754.3681
# Month=15, Predicted=3754.3353, Expected=3750.8239
# Month=16, Predicted=3750.9340, Expected=3775.7500
# Month=17, Predicted=3778.6877, Expected=3846.6561
# Month=18, Predicted=3855.7244, Expected=3830.9294
# Month=19, Predicted=3834.0245, Expected=3881.2132
# Month=20, Predicted=3885.1303, Expected=3898.3362
# Month=21, Predicted=3903.5673, Expected=3917.4832
# Month=22, Predicted=3919.4879, Expected=3914.1172
# Month=23, Predicted=3913.9905, Expected=3901.5435
# Month=24, Predicted=3900.8232, Expected=3885.2002
# Month=25, Predicted=3884.6427, Expected=3892.2451
# Month=26, Predicted=3893.2344, Expected=3899.6669
# Month=27, Predicted=3900.7355, Expected=3885.6275
# Month=28, Predicted=3884.3569, Expected=3908.2336
# Month=29, Predicted=3910.8665, Expected=3875.4078
# Month=30, Predicted=3871.1951, Expected=3859.5120
# Month=31, Predicted=3858.6367, Expected=3879.9687
# Month=32, Predicted=3882.2098, Expected=3893.2937
# Month=33, Predicted=3895.4453, Expected=3953.4607
# Month=34, Predicted=3960.7175, Expected=3932.8670
# Month=35, Predicted=3933.4691, Expected=3936.3431
# Month=36, Predicted=3935.5026, Expected=3869.8593
# Month=37, Predicted=3862.8574, Expected=3851.2471
# Month=38, Predicted=3852.0434, Expected=3836.7683
# Month=39, Predicted=3836.1402, Expected=3832.0688
# Month=40, Predicted=3832.2803, Expected=3849.7587
# Month=41, Predicted=3851.9827, Expected=3862.2441
# Month=42, Predicted=3864.1622, Expected=3878.6123
# Month=43, Predicted=3880.6570, Expected=3855.0054
# Month=44, Predicted=3852.2601, Expected=3842.4833
# Month=45, Predicted=3841.6072, Expected=3847.2433
# Month=46, Predicted=3848.3473, Expected=3801.1048
# Month=47, Predicted=3796.1724, Expected=3786.6840
# Month=48, Predicted=3786.2736, Expected=3776.0367
# Month=49, Predicted=3775.7841, Expected=3796.7972
# Month=50, Predicted=3799.3882, Expected=3821.0598
# Month=51, Predicted=3824.6021, Expected=3877.3486
# Month=52, Predicted=3884.7012, Expected=3875.8349
# Month=53, Predicted=3879.2514, Expected=3889.3484
# Month=54, Predicted=3890.2148, Expected=3911.1229
# Month=55, Predicted=3914.0081, Expected=3922.9724
# Month=56, Predicted=3924.9054, Expected=3917.9201
# Month=57, Predicted=3917.3999, Expected=3936.3097
# Month=58, Predicted=3938.4973, Expected=3911.1479
# Month=59, Predicted=3908.2371, Expected=3890.6722
# Month=60, Predicted=3889.5519, Expected=3854.8904
# Run 12 — RMSE: 24.094040, MSE: 580.522762, NMSE: 0.0026158965
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3803.4291, Expected=3796.1139
# Month=2, Predicted=3796.7833, Expected=3793.0240
# Month=3, Predicted=3793.0163, Expected=3765.6570
# Month=4, Predicted=3763.6033, Expected=3748.1286
# Month=5, Predicted=3747.2277, Expected=3754.3337
# Month=6, Predicted=3756.2220, Expected=3754.9339
# Month=7, Predicted=3754.9546, Expected=3767.0982
# Month=8, Predicted=3768.5642, Expected=3750.6516
# Month=9, Predicted=3748.3366, Expected=3769.4487
# Month=10, Predicted=3772.5446, Expected=3759.5828
# Month=11, Predicted=3758.0155, Expected=3784.9396
# Month=12, Predicted=3788.3699, Expected=3776.2658
# Month=13, Predicted=3775.2680, Expected=3755.4558
# Month=14, Predicted=3754.4615, Expected=3754.3681
# Month=15, Predicted=3755.3033, Expected=3750.8239
# Month=16, Predicted=3751.1602, Expected=3775.7500
# Month=17, Predicted=3778.6824, Expected=3846.6561
# Month=18, Predicted=3854.6049, Expected=3830.9294
# Month=19, Predicted=3836.5947, Expected=3881.2132
# Month=20, Predicted=3885.8752, Expected=3898.3362
# Month=21, Predicted=3905.6655, Expected=3917.4832
# Month=22, Predicted=3918.1416, Expected=3914.1172
# Month=23, Predicted=3913.1150, Expected=3901.5435
# Month=24, Predicted=3901.0267, Expected=3885.2002
# Month=25, Predicted=3885.1259, Expected=3892.2451
# Month=26, Predicted=3894.3026, Expected=3899.6669
# Month=27, Predicted=3900.2513, Expected=3885.6275
# Month=28, Predicted=3883.9490, Expected=3908.2336
# Month=29, Predicted=3911.7426, Expected=3875.4078
# Month=30, Predicted=3869.8314, Expected=3859.5120
# Month=31, Predicted=3858.0702, Expected=3879.9687
# Month=32, Predicted=3883.3198, Expected=3893.2937
# Month=33, Predicted=3894.5618, Expected=3953.4607
# Month=34, Predicted=3958.2667, Expected=3932.8670
# Month=35, Predicted=3937.7063, Expected=3936.3431
# Month=36, Predicted=3936.7013, Expected=3869.8593
# Month=37, Predicted=3861.4634, Expected=3851.2471
# Month=38, Predicted=3856.9366, Expected=3836.7683
# Month=39, Predicted=3837.1383, Expected=3832.0688
# Month=40, Predicted=3833.0706, Expected=3849.7587
# Month=41, Predicted=3852.2931, Expected=3862.2441
# Month=42, Predicted=3863.1658, Expected=3878.6123
# Month=43, Predicted=3879.5751, Expected=3855.0054
# Month=44, Predicted=3851.2518, Expected=3842.4833
# Month=45, Predicted=3842.1374, Expected=3847.2433
# Month=46, Predicted=3849.1311, Expected=3801.1048
# Month=47, Predicted=3795.0552, Expected=3786.6840
# Month=48, Predicted=3784.1871, Expected=3776.0367
# Month=49, Predicted=3776.5466, Expected=3796.7972
# Month=50, Predicted=3800.0846, Expected=3821.0598
# Month=51, Predicted=3823.5269, Expected=3877.3486
# Month=52, Predicted=3883.3948, Expected=3875.8349
# Month=53, Predicted=3882.2140, Expected=3889.3484
# Month=54, Predicted=3890.3586, Expected=3911.1229
# Month=55, Predicted=3912.7960, Expected=3922.9724
# Month=56, Predicted=3923.9732, Expected=3917.9201
# Month=57, Predicted=3916.7081, Expected=3936.3097
# Month=58, Predicted=3938.8213, Expected=3911.1479
# Month=59, Predicted=3907.1913, Expected=3890.6722
# Month=60, Predicted=3889.7026, Expected=3854.8904
# Run 13 — RMSE: 24.077009, MSE: 579.702343, NMSE: 0.0026131047
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3801.1658, Expected=3796.1139
# Month=2, Predicted=3796.1946, Expected=3793.0240
# Month=3, Predicted=3794.2043, Expected=3765.6570
# Month=4, Predicted=3763.9638, Expected=3748.1286
# Month=5, Predicted=3746.3917, Expected=3754.3337
# Month=6, Predicted=3758.6896, Expected=3754.9339
# Month=7, Predicted=3754.8889, Expected=3767.0982
# Month=8, Predicted=3770.5440, Expected=3750.6516
# Month=9, Predicted=3744.9901, Expected=3769.4487
# Month=10, Predicted=3775.3490, Expected=3759.5828
# Month=11, Predicted=3754.4518, Expected=3784.9396
# Month=12, Predicted=3792.2042, Expected=3776.2658
# Month=13, Predicted=3772.0949, Expected=3755.4558
# Month=14, Predicted=3755.7675, Expected=3754.3681
# Month=15, Predicted=3756.6743, Expected=3750.8239
# Month=16, Predicted=3752.8415, Expected=3775.7500
# Month=17, Predicted=3781.8161, Expected=3846.6561
# Month=18, Predicted=3847.0948, Expected=3830.9294
# Month=19, Predicted=3851.6301, Expected=3881.2132
# Month=20, Predicted=3887.3311, Expected=3898.3362
# Month=21, Predicted=3916.6423, Expected=3917.4832
# Month=22, Predicted=3914.4615, Expected=3914.1172
# Month=23, Predicted=3909.5956, Expected=3901.5435
# Month=24, Predicted=3902.1460, Expected=3885.2002
# Month=25, Predicted=3887.0295, Expected=3892.2451
# Month=26, Predicted=3896.9189, Expected=3899.6669
# Month=27, Predicted=3900.4150, Expected=3885.6275
# Month=28, Predicted=3882.0906, Expected=3908.2336
# Month=29, Predicted=3915.2472, Expected=3875.4078
# Month=30, Predicted=3863.6998, Expected=3859.5120
# Month=31, Predicted=3854.8745, Expected=3879.9687
# Month=32, Predicted=3886.7853, Expected=3893.2937
# Month=33, Predicted=3892.0928, Expected=3953.4607
# Month=34, Predicted=3952.2724, Expected=3932.8670
# Month=35, Predicted=3949.3110, Expected=3936.3431
# Month=36, Predicted=3937.3671, Expected=3869.8593
# Month=37, Predicted=3858.7873, Expected=3851.2471
# Month=38, Predicted=3850.5612, Expected=3836.7683
# Month=39, Predicted=3838.2861, Expected=3832.0688
# Month=40, Predicted=3835.4803, Expected=3849.7587
# Month=41, Predicted=3855.9665, Expected=3862.2441
# Month=42, Predicted=3860.7637, Expected=3878.6123
# Month=43, Predicted=3877.5795, Expected=3855.0054
# Month=44, Predicted=3846.2123, Expected=3842.4833
# Month=45, Predicted=3842.1556, Expected=3847.2433
# Month=46, Predicted=3852.2051, Expected=3801.1048
# Month=47, Predicted=3791.7223, Expected=3786.6840
# Month=48, Predicted=3777.2030, Expected=3776.0367
# Month=49, Predicted=3778.6698, Expected=3796.7972
# Month=50, Predicted=3804.1521, Expected=3821.0598
# Month=51, Predicted=3820.0632, Expected=3877.3486
# Month=52, Predicted=3876.5639, Expected=3875.8349
# Month=53, Predicted=3896.8197, Expected=3889.3484
# Month=54, Predicted=3892.4039, Expected=3911.1229
# Month=55, Predicted=3910.4745, Expected=3922.9724
# Month=56, Predicted=3920.9687, Expected=3917.9201
# Month=57, Predicted=3914.1238, Expected=3936.3097
# Month=58, Predicted=3942.1925, Expected=3911.1479
# Month=59, Predicted=3901.9340, Expected=3890.6722
# Month=60, Predicted=3889.0883, Expected=3854.8904
# Run 14 — RMSE: 23.714761, MSE: 562.389868, NMSE: 0.0025171281
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3797.3333, Expected=3796.1139
# Month=2, Predicted=3799.4069, Expected=3793.0240
# Month=3, Predicted=3795.0514, Expected=3765.6570
# Month=4, Predicted=3762.2528, Expected=3748.1286
# Month=5, Predicted=3746.6001, Expected=3754.3337
# Month=6, Predicted=3756.9095, Expected=3754.9339
# Month=7, Predicted=3757.0551, Expected=3767.0982
# Month=8, Predicted=3770.5785, Expected=3750.6516
# Month=9, Predicted=3748.1942, Expected=3769.4487
# Month=10, Predicted=3773.4789, Expected=3759.5828
# Month=11, Predicted=3759.3091, Expected=3784.9396
# Month=12, Predicted=3789.2293, Expected=3776.2658
# Month=13, Predicted=3776.9005, Expected=3755.4558
# Month=14, Predicted=3754.5546, Expected=3754.3681
# Month=15, Predicted=3755.1929, Expected=3750.8239
# Month=16, Predicted=3752.8617, Expected=3775.7500
# Month=17, Predicted=3779.2402, Expected=3846.6561
# Month=18, Predicted=3834.8058, Expected=3830.9294
# Month=19, Predicted=3840.0998, Expected=3881.2132
# Month=20, Predicted=3882.8892, Expected=3898.3362
# Month=21, Predicted=3905.1013, Expected=3917.4832
# Month=22, Predicted=3918.9113, Expected=3914.1172
# Month=23, Predicted=3915.4119, Expected=3901.5435
# Month=24, Predicted=3901.9057, Expected=3885.2002
# Month=25, Predicted=3885.3617, Expected=3892.2451
# Month=26, Predicted=3895.1917, Expected=3899.6669
# Month=27, Predicted=3902.3934, Expected=3885.6275
# Month=28, Predicted=3884.3880, Expected=3908.2336
# Month=29, Predicted=3912.7056, Expected=3875.4078
# Month=30, Predicted=3863.3353, Expected=3859.5120
# Month=31, Predicted=3857.3401, Expected=3879.9687
# Month=32, Predicted=3884.2359, Expected=3893.2937
# Month=33, Predicted=3895.7799, Expected=3953.4607
# Month=34, Predicted=3945.0639, Expected=3932.8670
# Month=35, Predicted=3934.3074, Expected=3936.3431
# Month=36, Predicted=3937.3398, Expected=3869.8593
# Month=37, Predicted=3858.9122, Expected=3851.2471
# Month=38, Predicted=3851.0079, Expected=3836.7683
# Month=39, Predicted=3837.0276, Expected=3832.0688
# Month=40, Predicted=3833.7696, Expected=3849.7587
# Month=41, Predicted=3853.8916, Expected=3862.2441
# Month=42, Predicted=3864.6503, Expected=3878.6123
# Month=43, Predicted=3880.7342, Expected=3855.0054
# Month=44, Predicted=3848.9772, Expected=3842.4833
# Month=45, Predicted=3841.6620, Expected=3847.2433
# Month=46, Predicted=3850.5428, Expected=3801.1048
# Month=47, Predicted=3789.5375, Expected=3786.6840
# Month=48, Predicted=3784.5508, Expected=3776.0367
# Month=49, Predicted=3776.9880, Expected=3796.7972
# Month=50, Predicted=3801.3507, Expected=3821.0598
# Month=51, Predicted=3822.0513, Expected=3877.3486
# Month=52, Predicted=3869.6369, Expected=3875.8349
# Month=53, Predicted=3885.1144, Expected=3889.3484
# Month=54, Predicted=3892.8351, Expected=3911.1229
# Month=55, Predicted=3912.6148, Expected=3922.9724
# Month=56, Predicted=3925.5019, Expected=3917.9201
# Month=57, Predicted=3918.7096, Expected=3936.3097
# Month=58, Predicted=3940.4129, Expected=3911.1479
# Month=59, Predicted=3904.1489, Expected=3890.6722
# Month=60, Predicted=3889.2389, Expected=3854.8904
# Run 15 — RMSE: 23.528546, MSE: 553.592466, NMSE: 0.0025375557
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3802.2276, Expected=3796.1139
# Month=2, Predicted=3796.8178, Expected=3793.0240
# Month=3, Predicted=3793.1539, Expected=3765.6570
# Month=4, Predicted=3764.4903, Expected=3748.1286
# Month=5, Predicted=3747.5838, Expected=3754.3337
# Month=6, Predicted=3756.0966, Expected=3754.9339
# Month=7, Predicted=3755.5218, Expected=3767.0982
# Month=8, Predicted=3768.6236, Expected=3750.6516
# Month=9, Predicted=3749.5503, Expected=3769.4487
# Month=10, Predicted=3771.9453, Expected=3759.5828
# Month=11, Predicted=3759.2661, Expected=3784.9396
# Month=12, Predicted=3787.7113, Expected=3776.2658
# Month=13, Predicted=3776.2931, Expected=3755.4558
# Month=14, Predicted=3755.0948, Expected=3754.3681
# Month=15, Predicted=3755.5646, Expected=3750.8239
# Month=16, Predicted=3751.3552, Expected=3775.7500
# Month=17, Predicted=3778.4560, Expected=3846.6561
# Month=18, Predicted=3854.1254, Expected=3830.9294
# Month=19, Predicted=3835.4705, Expected=3881.2132
# ...
# Month=60, Predicted=3892.6359, Expected=3854.8904
# Run 25 — RMSE: 24.309672, MSE: 590.960162, NMSE: 0.0026835019
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3802.9039, Expected=3796.1139
# Month=2, Predicted=3797.6446, Expected=3793.0240
# Month=3, Predicted=3792.8105, Expected=3765.6570
# Month=4, Predicted=3764.1055, Expected=3748.1286
# Month=5, Predicted=3747.8160, Expected=3754.3337
# Month=6, Predicted=3754.2892, Expected=3754.9339
# Month=7, Predicted=3755.1798, Expected=3767.0982
# Month=8, Predicted=3767.9725, Expected=3750.6516
# Month=9, Predicted=3749.7229, Expected=3769.4487
# Month=10, Predicted=3769.9988, Expected=3759.5828
# Month=11, Predicted=3759.4096, Expected=3784.9396
# Month=12, Predicted=3786.1626, Expected=3776.2658
# Month=13, Predicted=3776.5050, Expected=3755.4558
# Month=14, Predicted=3754.3870, Expected=3754.3681
# Month=15, Predicted=3754.1228, Expected=3750.8239
# Month=16, Predicted=3750.6065, Expected=3775.7500
# Month=17, Predicted=3777.3288, Expected=3846.6561
# Month=18, Predicted=3854.4389, Expected=3830.9294
# Month=19, Predicted=3833.6717, Expected=3881.2132
# Month=20, Predicted=3883.3755, Expected=3898.3362
# Month=21, Predicted=3903.5871, Expected=3917.4832
# Month=22, Predicted=3919.8848, Expected=3914.1172
# Month=23, Predicted=3914.5665, Expected=3901.5435
# Month=24, Predicted=3900.8020, Expected=3885.2002
# Month=25, Predicted=3884.3971, Expected=3892.2451
# Month=26, Predicted=3892.2884, Expected=3899.6669
# Month=27, Predicted=3900.4697, Expected=3885.6275
# Month=28, Predicted=3884.8364, Expected=3908.2336
# Month=29, Predicted=3909.0773, Expected=3875.4078
# Month=30, Predicted=3872.8389, Expected=3859.5120
# Month=31, Predicted=3859.5794, Expected=3879.9687
# Month=32, Predicted=3880.5443, Expected=3893.2937
# Month=33, Predicted=3895.4141, Expected=3953.4607
# Month=34, Predicted=3959.3203, Expected=3932.8670
# Month=35, Predicted=3933.6044, Expected=3936.3431
# Month=36, Predicted=3936.1734, Expected=3869.8593
# Month=37, Predicted=3866.4185, Expected=3851.2471
# Month=38, Predicted=3855.2916, Expected=3836.7683
# Month=39, Predicted=3835.8876, Expected=3832.0688
# Month=40, Predicted=3831.6815, Expected=3849.7587
# Month=41, Predicted=3850.7727, Expected=3862.2441
# Month=42, Predicted=3864.0912, Expected=3878.6123
# Month=43, Predicted=3880.4702, Expected=3855.0054
# Month=44, Predicted=3853.4452, Expected=3842.4833
# Month=45, Predicted=3842.0583, Expected=3847.2433
# Month=46, Predicted=3847.2495, Expected=3801.1048
# Month=47, Predicted=3798.1470, Expected=3786.6840
# Month=48, Predicted=3788.0061, Expected=3776.0367
# Month=49, Predicted=3775.2831, Expected=3796.7972
# Month=50, Predicted=3797.7075, Expected=3821.0598
# Month=51, Predicted=3824.2758, Expected=3877.3486
# Month=52, Predicted=3883.8808, Expected=3875.8349
# Month=53, Predicted=3879.4921, Expected=3889.3484
# Month=54, Predicted=3890.1743, Expected=3911.1229
# Month=55, Predicted=3913.5457, Expected=3922.9724
# Month=56, Predicted=3925.0456, Expected=3917.9201
# Month=57, Predicted=3917.9140, Expected=3936.3097
# Month=58, Predicted=3937.3512, Expected=3911.1479
# Month=59, Predicted=3909.4335, Expected=3890.6722
# Month=60, Predicted=3890.1985, Expected=3854.8904
# Run 26 — RMSE: 24.239726, MSE: 587.564340, NMSE: 0.0026494946
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3798.3762, Expected=3796.1139
# Month=2, Predicted=3796.8746, Expected=3793.0240
# Month=3, Predicted=3794.1524, Expected=3765.6570
# Month=4, Predicted=3766.8190, Expected=3748.1286
# Month=5, Predicted=3749.5841, Expected=3754.3337
# Month=6, Predicted=3755.8834, Expected=3754.9339
# Month=7, Predicted=3755.7963, Expected=3767.0982
# Month=8, Predicted=3768.1782, Expected=3750.6516
# Month=9, Predicted=3751.4123, Expected=3769.4487
# Month=10, Predicted=3770.9710, Expected=3759.5828
# Month=11, Predicted=3760.3435, Expected=3784.9396
# Month=12, Predicted=3786.3578, Expected=3776.2658
# Month=13, Predicted=3777.0265, Expected=3755.4558
# Month=14, Predicted=3756.8385, Expected=3754.3681
# Month=15, Predicted=3755.9281, Expected=3750.8239
# Month=16, Predicted=3751.9464, Expected=3775.7500
# Month=17, Predicted=3776.9909, Expected=3846.6561
# Month=18, Predicted=3847.4168, Expected=3830.9294
# Month=19, Predicted=3831.6900, Expected=3881.2132
# Month=20, Predicted=3882.6460, Expected=3898.3362
# Month=21, Predicted=3899.0969, Expected=3917.4832
# Month=22, Predicted=3918.2438, Expected=3914.1172
# Month=23, Predicted=3914.8778, Expected=3901.5435
# Month=24, Predicted=3902.7361, Expected=3885.2002
# Month=25, Predicted=3886.7069, Expected=3892.2451
# Month=26, Predicted=3893.7907, Expected=3899.6669
# Month=27, Predicted=3900.5156, Expected=3885.6275
# Month=28, Predicted=3886.4135, Expected=3908.2336
# Month=29, Predicted=3909.7300, Expected=3875.4078
# Month=30, Predicted=3876.1684, Expected=3859.5120
# Month=31, Predicted=3860.7182, Expected=3879.9687
# Month=32, Predicted=3881.4780, Expected=3893.2937
# Month=33, Predicted=3894.0544, Expected=3953.4607
# Month=34, Predicted=3954.2328, Expected=3932.8670
# Month=35, Predicted=3933.6277, Expected=3936.3431
# Month=36, Predicted=3937.8835, Expected=3869.8593
# Month=37, Predicted=3870.6200, Expected=3851.2471
# Month=38, Predicted=3856.9668, Expected=3836.7683
# Month=39, Predicted=3838.3171, Expected=3832.0688
# Month=40, Predicted=3833.6079, Expected=3849.7587
# Month=41, Predicted=3851.0346, Expected=3862.2441
# Month=42, Predicted=3863.0048, Expected=3878.6123
# Month=43, Predicted=3879.3730, Expected=3855.0054
# Month=44, Predicted=3855.7660, Expected=3842.4833
# Month=45, Predicted=3844.0280, Expected=3847.2433
# Month=46, Predicted=3848.7383, Expected=3801.1048
# Month=47, Predicted=3801.8821, Expected=3786.6840
# Month=48, Predicted=3787.4447, Expected=3776.0367
# Month=49, Predicted=3777.5571, Expected=3796.7972
# Month=50, Predicted=3798.2405, Expected=3821.0598
# Month=51, Predicted=3821.8204, Expected=3877.3486
# Month=52, Predicted=3878.1092, Expected=3875.8349
# Month=53, Predicted=3876.5956, Expected=3889.3484
# Month=54, Predicted=3890.4892, Expected=3911.1229
# Month=55, Predicted=3911.8835, Expected=3922.9724
# Month=56, Predicted=3923.7330, Expected=3917.9201
# Month=57, Predicted=3918.6808, Expected=3936.3097
# Month=58, Predicted=3937.5938, Expected=3911.1479
# Month=59, Predicted=3911.9086, Expected=3890.6722
# Month=60, Predicted=3892.1991, Expected=3854.8904
# Run 27 — RMSE: 24.603292, MSE: 605.321988, NMSE: 0.0027803033
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3804.3391, Expected=3796.1139
# Month=2, Predicted=3796.9746, Expected=3793.0240
# Month=3, Predicted=3793.0595, Expected=3765.6570
# Month=4, Predicted=3765.1238, Expected=3748.1286
# Month=5, Predicted=3747.1957, Expected=3754.3337
# Month=6, Predicted=3756.7398, Expected=3754.9339
# Month=7, Predicted=3754.9691, Expected=3767.0982
# Month=8, Predicted=3768.3308, Expected=3750.6516
# Month=9, Predicted=3748.6778, Expected=3769.4487
# Month=10, Predicted=3772.3255, Expected=3759.5828
# Month=11, Predicted=3758.1744, Expected=3784.9396
# Month=12, Predicted=3787.9573, Expected=3776.2658
# Month=13, Predicted=3775.6470, Expected=3755.4558
# Month=14, Predicted=3756.0829, Expected=3754.3681
# Month=15, Predicted=3755.8195, Expected=3750.8239
# Month=16, Predicted=3751.4076, Expected=3775.7500
# Month=17, Predicted=3778.3228, Expected=3846.6561
# Month=18, Predicted=3855.9619, Expected=3830.9294
# Month=19, Predicted=3844.0070, Expected=3881.2132
# Month=20, Predicted=3884.3018, Expected=3898.3362
# Month=21, Predicted=3909.6058, Expected=3917.4832
# Month=22, Predicted=3917.5630, Expected=3914.1172
# Month=23, Predicted=3912.9932, Expected=3901.5435
# Month=24, Predicted=3901.6104, Expected=3885.2002
# Month=25, Predicted=3886.7637, Expected=3892.2451
# Month=26, Predicted=3894.7792, Expected=3899.6669
# Month=27, Predicted=3900.1300, Expected=3885.6275
# Month=28, Predicted=3884.2946, Expected=3908.2336
# Month=29, Predicted=3911.4865, Expected=3875.4078
# Month=30, Predicted=3871.0195, Expected=3859.5120
# Month=31, Predicted=3856.3519, Expected=3879.9687
# Month=32, Predicted=3883.2524, Expected=3893.2937
# Month=33, Predicted=3894.6576, Expected=3953.4607
# Month=34, Predicted=3958.5540, Expected=3932.8670
# Month=35, Predicted=3939.8412, Expected=3936.3431
# Month=36, Predicted=3936.3871, Expected=3869.8593
# Month=37, Predicted=3865.7988, Expected=3851.2471
# Month=38, Predicted=3852.6824, Expected=3836.7683
# Month=39, Predicted=3838.3971, Expected=3832.0688
# Month=40, Predicted=3834.1889, Expected=3849.7587
# Month=41, Predicted=3852.0655, Expected=3862.2441
# Month=42, Predicted=3863.1011, Expected=3878.6123
# Month=43, Predicted=3879.1640, Expected=3855.0054
# Month=44, Predicted=3851.7528, Expected=3842.4833
# Month=45, Predicted=3842.5141, Expected=3847.2433
# Month=46, Predicted=3849.7364, Expected=3801.1048
# Month=47, Predicted=3797.6153, Expected=3786.6840
# Month=48, Predicted=3782.0971, Expected=3776.0367
# Month=49, Predicted=3777.9649, Expected=3796.7972
# Month=50, Predicted=3799.9511, Expected=3821.0598
# Month=51, Predicted=3823.7226, Expected=3877.3486
# Month=52, Predicted=3884.1365, Expected=3875.8349
# Month=53, Predicted=3885.4043, Expected=3889.3484
# Month=54, Predicted=3889.7908, Expected=3911.1229
# Month=55, Predicted=3912.5823, Expected=3922.9724
# Month=56, Predicted=3923.9486, Expected=3917.9201
# Month=57, Predicted=3916.5878, Expected=3936.3097
# Month=58, Predicted=3938.4753, Expected=3911.1479
# Month=59, Predicted=3907.7588, Expected=3890.6722
# Month=60, Predicted=3890.0137, Expected=3854.8904
# Run 28 — RMSE: 23.900955, MSE: 571.255656, NMSE: 0.0025742683
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3805.8165, Expected=3796.1139
# Month=2, Predicted=3798.4008, Expected=3793.0240
# Month=3, Predicted=3793.5239, Expected=3765.6570
# Month=4, Predicted=3765.6083, Expected=3748.1286
# Month=5, Predicted=3747.9333, Expected=3754.3337
# Month=6, Predicted=3756.2636, Expected=3754.9339
# Month=7, Predicted=3754.5056, Expected=3767.0982
# Month=8, Predicted=3767.9036, Expected=3750.6516
# Month=9, Predicted=3748.7313, Expected=3769.4487
# Month=10, Predicted=3771.9625, Expected=3759.5828
# Month=11, Predicted=3757.8683, Expected=3784.9396
# Month=12, Predicted=3787.5824, Expected=3776.2658
# Month=13, Predicted=3775.4245, Expected=3755.4558
# Month=14, Predicted=3756.3611, Expected=3754.3681
# Month=15, Predicted=3755.7184, Expected=3750.8239
# Month=16, Predicted=3751.2559, Expected=3775.7500
# Month=17, Predicted=3777.6835, Expected=3846.6561
# Month=18, Predicted=3856.6088, Expected=3830.9294
# Month=19, Predicted=3850.0472, Expected=3881.2132
# Month=20, Predicted=3885.1445, Expected=3898.3362
# Month=21, Predicted=3913.4014, Expected=3917.4832
# Month=22, Predicted=3918.1787, Expected=3914.1172
# Month=23, Predicted=3912.9216, Expected=3901.5435
# Month=24, Predicted=3902.0299, Expected=3885.2002
# Month=25, Predicted=3886.4918, Expected=3892.2451
# Month=26, Predicted=3894.2803, Expected=3899.6669
# Month=27, Predicted=3899.5060, Expected=3885.6275
# Month=28, Predicted=3884.3743, Expected=3908.2336
# Month=29, Predicted=3910.9594, Expected=3875.4078
# Month=30, Predicted=3871.7644, Expected=3859.5120
# Month=31, Predicted=3858.3432, Expected=3879.9687
# Month=32, Predicted=3882.5885, Expected=3893.2937
# Month=33, Predicted=3893.9549, Expected=3953.4607
# Month=34, Predicted=3958.1908, Expected=3932.8670
# Month=35, Predicted=3945.1648, Expected=3936.3431
# Month=36, Predicted=3937.8702, Expected=3869.8593
# Month=37, Predicted=3867.3051, Expected=3851.2471
# Month=38, Predicted=3850.1817, Expected=3836.7683
# Month=39, Predicted=3837.9760, Expected=3832.0688
# Month=40, Predicted=3833.7379, Expected=3849.7587
# Month=41, Predicted=3851.5181, Expected=3862.2441
# Month=42, Predicted=3862.4077, Expected=3878.6123
# Month=43, Predicted=3878.8181, Expected=3855.0054
# Month=44, Predicted=3852.2904, Expected=3842.4833
# Month=45, Predicted=3843.0768, Expected=3847.2433
# Month=46, Predicted=3849.2311, Expected=3801.1048
# Month=47, Predicted=3798.9632, Expected=3786.6840
# Month=48, Predicted=3784.2432, Expected=3776.0367
# Month=49, Predicted=3777.5446, Expected=3796.7972
# Month=50, Predicted=3799.3083, Expected=3821.0598
# Month=51, Predicted=3823.0574, Expected=3877.3486
# Month=52, Predicted=3884.8586, Expected=3875.8349
# Month=53, Predicted=3890.9339, Expected=3889.3484
# Month=54, Predicted=3890.4779, Expected=3911.1229
# Month=55, Predicted=3911.8446, Expected=3922.9724
# Month=56, Predicted=3923.6874, Expected=3917.9201
# Month=57, Predicted=3916.6591, Expected=3936.3097
# Month=58, Predicted=3938.1447, Expected=3911.1479
# Month=59, Predicted=3908.2107, Expected=3890.6722
# Month=60, Predicted=3890.7876, Expected=3854.8904
# Run 29 — RMSE: 23.937198, MSE: 572.989443, NMSE: 0.0025597326
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3802.0849, Expected=3796.1139
# Month=2, Predicted=3797.4614, Expected=3793.0240
# Month=3, Predicted=3794.3318, Expected=3765.6570
# Month=4, Predicted=3765.1339, Expected=3748.1286
# Month=5, Predicted=3746.6423, Expected=3754.3337
# Month=6, Predicted=3755.6936, Expected=3754.9339
# Month=7, Predicted=3755.7685, Expected=3767.0982
# Month=8, Predicted=3769.5718, Expected=3750.6516
# Month=9, Predicted=3748.8479, Expected=3769.4487
# Month=10, Predicted=3771.6994, Expected=3759.5828
# Month=11, Predicted=3758.7972, Expected=3784.9396
# Month=12, Predicted=3788.2549, Expected=3776.2658
# Month=13, Predicted=3776.1067, Expected=3755.4558
# Month=14, Predicted=3755.7111, Expected=3754.3681
# Month=15, Predicted=3754.7564, Expected=3750.8239
# Month=16, Predicted=3752.1644, Expected=3775.7500
# Month=17, Predicted=3779.3483, Expected=3846.6561
# Month=18, Predicted=3854.0405, Expected=3830.9294
# Month=19, Predicted=3834.4417, Expected=3881.2132
# Month=20, Predicted=3884.8721, Expected=3898.3362
# Month=21, Predicted=3903.9601, Expected=3917.4832
# Month=22, Predicted=3918.7388, Expected=3914.1172
# Month=23, Predicted=3913.9434, Expected=3901.5435
# Month=24, Predicted=3902.2855, Expected=3885.2002
# Month=25, Predicted=3885.6953, Expected=3892.2451
# Month=26, Predicted=3893.8120, Expected=3899.6669
# Month=27, Predicted=3900.9991, Expected=3885.6275
# Month=28, Predicted=3884.8013, Expected=3908.2336
# Month=29, Predicted=3911.0288, Expected=3875.4078
# Month=30, Predicted=3872.0104, Expected=3859.5120
# Month=31, Predicted=3857.3116, Expected=3879.9687
# Month=32, Predicted=3882.4535, Expected=3893.2937
# Month=33, Predicted=3894.6650, Expected=3953.4607
# Month=34, Predicted=3959.0995, Expected=3932.8670
# Month=35, Predicted=3933.8257, Expected=3936.3431
# Month=36, Predicted=3936.7823, Expected=3869.8593
# Month=37, Predicted=3864.8317, Expected=3851.2471
# Month=38, Predicted=3852.8301, Expected=3836.7683
# Month=39, Predicted=3836.8410, Expected=3832.0688
# Month=40, Predicted=3833.1211, Expected=3849.7587
# Month=41, Predicted=3852.8431, Expected=3862.2441
# Month=42, Predicted=3863.2668, Expected=3878.6123
# Month=43, Predicted=3879.7018, Expected=3855.0054
# Month=44, Predicted=3852.6265, Expected=3842.4833
# Month=45, Predicted=3841.7536, Expected=3847.2433
# Month=46, Predicted=3849.0725, Expected=3801.1048
# Month=47, Predicted=3797.2569, Expected=3786.6840
# Month=48, Predicted=3784.7110, Expected=3776.0367
# Month=49, Predicted=3776.7628, Expected=3796.7972
# Month=50, Predicted=3799.8341, Expected=3821.0598
# Month=51, Predicted=3823.2685, Expected=3877.3486
# Month=52, Predicted=3882.7210, Expected=3875.8349
# Month=53, Predicted=3880.1877, Expected=3889.3484
# Month=54, Predicted=3891.8030, Expected=3911.1229
# Month=55, Predicted=3912.5407, Expected=3922.9724
# Month=56, Predicted=3924.3403, Expected=3917.9201
# Month=57, Predicted=3917.0378, Expected=3936.3097
# Month=58, Predicted=3939.3950, Expected=3911.1479
# Month=59, Predicted=3908.6532, Expected=3890.6722
# Month=60, Predicted=3889.3720, Expected=3854.8904
# Run 30 — RMSE: 24.204891, MSE: 585.876728, NMSE: 0.0026563460
#
# ===== FINAL RESULTS — Hybrid (Feature Aug + Gate) on Dow Jones Industrial Index (30 runs) =====
# RMSE: 24.113817 ± 0.269677
# MSE:  581.548894 ± 12.985785
# NMSE: 0.0026271155 ± 0.0000682331
#
# Best run: 23
#   RMSE: 23.482495
#   MSE:  551.427569
#   NMSE: 0.0025298206
# === Best Run Metrics ===
# RMSE: 23.482495
# MSE:  551.427569
# NMSE: 0.0025298206

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Hybrid (Feature Aug + Gate) on Dow Jones Industrial Index
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
