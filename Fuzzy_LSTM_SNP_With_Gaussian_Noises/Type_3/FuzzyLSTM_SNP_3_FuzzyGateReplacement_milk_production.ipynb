# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value clipped to $[0, 1]$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Gate Replacement
# Uses FuzzyLSTMSNPCell instead of LSTMSNPCell.
# Gradient clipping applied for stability.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 1)]               0
#
#  rnn (RNN)                   (1, 8)                    464
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 473 (1.85 KB)
# Trainable params: 473 (1.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load
#  Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 1)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input
    # ============================================================
    
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)
    
        rnn_layer = model.layers[1]
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)
    
        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Milk Production (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Gate Replacement — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Gate Replacement — Monthly Milk Production\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.1% (lambda=0.001, sigma=0.101900)
# ================================================================================
#
# Data shape: (168,)
# First 5 values: [589.05061512 560.98591088 640.06599939 656.15519657 726.9761398 ]
# Supervised data shape: (167, 2)
# Train: (107, 2), Test: (60, 2)
# X_train shape: (107, 1, 1), y_train shape: (107,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=753.2120, Expected=804.0262
# Month=2, Predicted=810.1756, Expected=755.9924
# Month=3, Predicted=748.3147, Expected=859.8045
# Month=4, Predicted=862.0866, Expected=877.9973
# Month=5, Predicted=884.0946, Expected=942.0061
# Month=6, Predicted=948.4587, Expected=913.2510
# Month=7, Predicted=913.1601, Expected=868.9804
# Month=8, Predicted=855.3863, Expected=834.0307
# Month=9, Predicted=820.0601, Expected=789.9965
# Month=10, Predicted=774.4075, Expected=799.8809
# Month=11, Predicted=797.2807, Expected=763.1165
# Month=12, Predicted=762.1447, Expected=800.0766
# Month=13, Predicted=801.8423, Expected=826.0806
# Month=14, Predicted=831.6223, Expected=798.9073
# Month=15, Predicted=799.3254, Expected=890.1429
# Month=16, Predicted=894.5419, Expected=899.8572
# Month=17, Predicted=905.0400, Expected=961.0598
# Month=18, Predicted=967.2897, Expected=935.2232
# Month=19, Predicted=935.4593, Expected=893.8991
# Month=20, Predicted=882.6869, Expected=854.9423
# Month=21, Predicted=839.9496, Expected=809.0102
# Month=22, Predicted=791.3304, Expected=809.9487
# Month=23, Predicted=806.0444, Expected=765.8420
# Month=24, Predicted=759.2475, Expected=805.0070
# Month=25, Predicted=805.6388, Expected=820.8918
# Month=26, Predicted=826.1716, Expected=773.0483
# Month=27, Predicted=765.9297, Expected=882.9063
# Month=28, Predicted=885.3743, Expected=898.1579
# Month=29, Predicted=904.4995, Expected=956.9202
# Month=30, Predicted=963.2128, Expected=923.9672
# Month=31, Predicted=923.3834, Expected=881.0829
# Month=32, Predicted=866.9265, Expected=836.8746
# Month=33, Predicted=818.8379, Expected=784.0232
# Month=34, Predicted=761.8169, Expected=791.1332
# Month=35, Predicted=786.5916, Expected=759.8362
# Month=36, Predicted=759.3432, Expected=802.0188
# Month=37, Predicted=804.7858, Expected=828.0265
# Month=38, Predicted=833.5103, Expected=778.0797
# Month=39, Predicted=769.9096, Expected=888.8740
# Month=40, Predicted=891.1026, Expected=901.8654
# Month=41, Predicted=908.1924, Expected=969.0532
# Month=42, Predicted=975.5036, Expected=947.0303
# Month=43, Predicted=947.7473, Expected=908.0255
# Month=44, Predicted=899.1988, Expected=867.0353
# Month=45, Predicted=851.8086, Expected=814.9307
# Month=46, Predicted=793.9738, Expected=812.0237
# Month=47, Predicted=806.6020, Expected=773.0299
# Month=48, Predicted=768.7390, Expected=812.9272
# Month=49, Predicted=814.5841, Expected=834.1901
# Month=50, Predicted=839.5886, Expected=782.0483
# Month=51, Predicted=772.6921, Expected=891.8786
# Month=52, Predicted=893.7983, Expected=903.0669
# Month=53, Predicted=909.2856, Expected=965.9007
# Month=54, Predicted=972.2086, Expected=937.0802
# Month=55, Predicted=936.9743, Expected=896.1181
# Month=56, Predicted=884.2040, Expected=857.9164
# Month=57, Predicted=843.4008, Expected=817.0982
# Month=58, Predicted=802.0871, Expected=827.0421
# Month=59, Predicted=825.0139, Expected=797.0838
# Month=60, Predicted=796.9035, Expected=843.1933
# Run 1 — RMSE: 48.003543, MSE: 2304.340111, NMSE: 0.0092770964
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=754.0214, Expected=804.0262
# Month=2, Predicted=808.6256, Expected=755.9924
# Month=3, Predicted=743.4306, Expected=859.8045
# Month=4, Predicted=858.0724, Expected=877.9973
# Month=5, Predicted=888.1737, Expected=942.0061
# Month=6, Predicted=945.6443, Expected=913.2510
# Month=7, Predicted=908.3345, Expected=868.9804
# Month=8, Predicted=855.9867, Expected=834.0307
# Month=9, Predicted=823.1137, Expected=789.9965
# Month=10, Predicted=776.5610, Expected=799.8809
# Month=11, Predicted=801.1406, Expected=763.1165
# Month=12, Predicted=754.7921, Expected=800.0766
# Month=13, Predicted=803.1181, Expected=826.0806
# Month=14, Predicted=831.7913, Expected=798.9073
# Month=15, Predicted=794.2259, Expected=890.1429
# Month=16, Predicted=890.4900, Expected=899.8572
# Month=17, Predicted=907.3848, Expected=961.0598
# Month=18, Predicted=964.8564, Expected=935.2232
# Month=19, Predicted=931.2808, Expected=893.8991
# Month=20, Predicted=882.2317, Expected=854.9423
# Month=21, Predicted=842.8468, Expected=809.0102
# Month=22, Predicted=794.4613, Expected=809.9487
# Month=23, Predicted=809.5412, Expected=765.8420
# Month=24, Predicted=754.4791, Expected=805.0070
# Month=25, Predicted=807.2554, Expected=820.8918
# Month=26, Predicted=826.1784, Expected=773.0483
# Month=27, Predicted=760.5313, Expected=882.9063
# Month=28, Predicted=881.2707, Expected=898.1579
# Month=29, Predicted=909.0165, Expected=956.9202
# Month=30, Predicted=960.9652, Expected=923.9672
# Month=31, Predicted=917.3389, Expected=881.0829
# Month=32, Predicted=868.2827, Expected=836.8746
# Month=33, Predicted=822.6592, Expected=784.0232
# Month=34, Predicted=766.1854, Expected=791.1332
# Month=35, Predicted=791.0011, Expected=759.8362
# Month=36, Predicted=753.5059, Expected=802.0188
# Month=37, Predicted=805.2894, Expected=828.0265
# Month=38, Predicted=833.7900, Expected=778.0797
# Month=39, Predicted=764.7258, Expected=888.8740
# Month=40, Predicted=887.0403, Expected=901.8654
# Month=41, Predicted=912.5930, Expected=969.0532
# Month=42, Predicted=972.4190, Expected=947.0303
# Month=43, Predicted=944.6408, Expected=908.0255
# Month=44, Predicted=897.5001, Expected=867.0353
# Month=45, Predicted=854.4044, Expected=814.9307
# Month=46, Predicted=797.6989, Expected=812.0237
# Month=47, Predicted=810.1041, Expected=773.0299
# Month=48, Predicted=763.4991, Expected=812.9272
# Month=49, Predicted=815.6363, Expected=834.1901
# Month=50, Predicted=839.8004, Expected=782.0483
# Month=51, Predicted=767.7833, Expected=891.8786
# Month=52, Predicted=889.7861, Expected=903.0669
# Month=53, Predicted=913.3702, Expected=965.9007
# Month=54, Predicted=969.5883, Expected=937.0802
# Month=55, Predicted=932.1012, Expected=896.1181
# Month=56, Predicted=884.3664, Expected=857.9164
# Month=57, Predicted=846.1300, Expected=817.0982
# Month=58, Predicted=804.5828, Expected=827.0421
# Month=59, Predicted=828.6366, Expected=797.0838
# Month=60, Predicted=791.3004, Expected=843.1933
# Run 2 — RMSE: 48.935699, MSE: 2394.702682, NMSE: 0.0097029895
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=748.8748, Expected=804.0262
# Month=2, Predicted=791.3221, Expected=755.9924
# Month=3, Predicted=750.2455, Expected=859.8045
# Month=4, Predicted=857.6615, Expected=877.9973
# Month=5, Predicted=875.8543, Expected=942.0061
# Month=6, Predicted=928.3783, Expected=913.2510
# Month=7, Predicted=911.1080, Expected=868.9804
# Month=8, Predicted=863.6491, Expected=834.0307
# Month=9, Predicted=830.0320, Expected=789.9965
# Month=10, Predicted=784.4643, Expected=799.8809
# Month=11, Predicted=797.7379, Expected=763.1165
# Month=12, Predicted=759.8589, Expected=800.0766
# Month=13, Predicted=797.9336, Expected=826.0806
# Month=14, Predicted=823.9376, Expected=798.9073
# Month=15, Predicted=796.7644, Expected=890.1429
# Month=16, Predicted=888.0000, Expected=899.8572
# Month=17, Predicted=897.7142, Expected=961.0598
# Month=18, Predicted=947.0281, Expected=935.2232
# Month=19, Predicted=933.0802, Expected=893.8991
# Month=20, Predicted=889.2319, Expected=854.9423
# Month=21, Predicted=850.2503, Expected=809.0102
# Month=22, Predicted=802.9741, Expected=809.9487
# Month=23, Predicted=807.8057, Expected=765.8420
# Month=24, Predicted=761.0481, Expected=805.0070
# Month=25, Predicted=802.8640, Expected=820.8918
# Month=26, Predicted=818.7488, Expected=773.0483
# Month=27, Predicted=767.6178, Expected=882.9063
# Month=28, Predicted=880.7666, Expected=898.1579
# Month=29, Predicted=896.0150, Expected=956.9202
# Month=30, Predicted=942.8826, Expected=923.9672
# Month=31, Predicted=921.1216, Expected=881.0829
# Month=32, Predicted=875.9106, Expected=836.8746
# Month=33, Predicted=831.0665, Expected=784.0232
# Month=34, Predicted=776.4308, Expected=791.1332
# Month=35, Predicted=788.9902, Expected=759.8362
# Month=36, Predicted=757.5986, Expected=802.0188
# Month=37, Predicted=798.0509, Expected=828.0265
# Month=38, Predicted=825.8835, Expected=778.0797
# Month=39, Predicted=772.1750, Expected=888.8740
# Month=40, Predicted=886.7378, Expected=901.8654
# Month=41, Predicted=899.7225, Expected=969.0532
# Month=42, Predicted=956.3331, Expected=947.0303
# Month=43, Predicted=944.8873, Expected=908.0255
# Month=44, Predicted=903.9153, Expected=867.0353
# Month=45, Predicted=862.0174, Expected=814.9307
# Month=46, Predicted=807.6024, Expected=812.0237
# Month=47, Predicted=809.8807, Expected=773.0299
# Month=48, Predicted=769.2074, Expected=812.9272
# Month=49, Predicted=810.7842, Expected=834.1901
# Month=50, Predicted=832.0471, Expected=782.0483
# Month=51, Predicted=775.7458, Expected=891.8786
# Month=52, Predicted=889.7392, Expected=903.0669
# Month=53, Predicted=900.9239, Expected=965.9007
# Month=54, Predicted=952.0552, Expected=937.0802
# Month=55, Predicted=934.9372, Expected=896.1181
# Month=56, Predicted=891.4482, Expected=857.9164
# Month=57, Predicted=853.3838, Expected=817.0982
# Month=58, Predicted=812.1131, Expected=827.0421
# Month=59, Predicted=824.8991, Expected=797.0838
# Month=60, Predicted=794.9408, Expected=843.1933
# Run 3 — RMSE: 47.999902, MSE: 2303.990592, NMSE: 0.0105768744
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=753.6993, Expected=804.0262
# Month=2, Predicted=808.5925, Expected=755.9924
# Month=3, Predicted=742.8770, Expected=859.8045
# Month=4, Predicted=861.9396, Expected=877.9973
# Month=5, Predicted=886.4908, Expected=942.0061
# Month=6, Predicted=946.5085, Expected=913.2510
# Month=7, Predicted=908.6917, Expected=868.9804
# Month=8, Predicted=854.3591, Expected=834.0307
# Month=9, Predicted=822.0035, Expected=789.9965
# Month=10, Predicted=774.6449, Expected=799.8809
# Month=11, Predicted=797.4720, Expected=763.1165
# Month=12, Predicted=755.3876, Expected=800.0766
# Month=13, Predicted=802.6689, Expected=826.0806
# Month=14, Predicted=829.7850, Expected=798.9073
# Month=15, Predicted=793.3352, Expected=890.1429
# Month=16, Predicted=893.7779, Expected=899.8572
# Month=17, Predicted=905.1961, Expected=961.0598
# Month=18, Predicted=965.5280, Expected=935.2232
# Month=19, Predicted=931.0171, Expected=893.8991
# Month=20, Predicted=881.2007, Expected=854.9423
# Month=21, Predicted=841.2340, Expected=809.0102
# Month=22, Predicted=792.1266, Expected=809.9487
# Month=23, Predicted=805.8413, Expected=765.8420
# Month=24, Predicted=753.6349, Expected=805.0070
# Month=25, Predicted=807.0171, Expected=820.8918
# Month=26, Predicted=823.0312, Expected=773.0483
# Month=27, Predicted=759.1082, Expected=882.9063
# Month=28, Predicted=885.1063, Expected=898.1579
# Month=29, Predicted=907.3114, Expected=956.9202
# Month=30, Predicted=961.3848, Expected=923.9672
# Month=31, Predicted=918.2829, Expected=881.0829
# Month=32, Predicted=866.6174, Expected=836.8746
# Month=33, Predicted=820.2035, Expected=784.0232
# Month=34, Predicted=763.2482, Expected=791.1332
# Month=35, Predicted=787.1125, Expected=759.8362
# Month=36, Predicted=753.4473, Expected=802.0188
# Month=37, Predicted=805.0347, Expected=828.0265
# Month=38, Predicted=831.8663, Expected=778.0797
# Month=39, Predicted=763.1073, Expected=888.8740
# Month=40, Predicted=890.8807, Expected=901.8654
# Month=41, Predicted=910.8639, Expected=969.0532
# Month=42, Predicted=973.5770, Expected=947.0303
# Month=43, Predicted=943.9712, Expected=908.0255
# Month=44, Predicted=897.0678, Expected=867.0353
# Month=45, Predicted=852.6366, Expected=814.9307
# Month=46, Predicted=794.9491, Expected=812.0237
# Month=47, Predicted=806.4791, Expected=773.0299
# Month=48, Predicted=763.5719, Expected=812.9272
# Month=49, Predicted=815.3685, Expected=834.1901
# Month=50, Predicted=837.2160, Expected=782.0483
# Month=51, Predicted=765.9864, Expected=891.8786
# Month=52, Predicted=893.6616, Expected=903.0669
# Month=53, Predicted=911.5747, Expected=965.9007
# Month=54, Predicted=970.3878, Expected=937.0802
# Month=55, Predicted=932.4264, Expected=896.1181
# Month=56, Predicted=883.2389, Expected=857.9164
# Month=57, Predicted=844.6795, Expected=817.0982
# Month=58, Predicted=802.9128, Expected=827.0421
# Month=59, Predicted=825.0271, Expected=797.0838
# Month=60, Predicted=790.9645, Expected=843.1933
# Run 4 — RMSE: 48.901910, MSE: 2391.396827, NMSE: 0.0094604976
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=750.1586, Expected=804.0262
# Month=2, Predicted=803.1670, Expected=755.9924
# Month=3, Predicted=742.5651, Expected=859.8045
# Month=4, Predicted=858.9453, Expected=877.9973
# Month=5, Predicted=877.1381, Expected=942.0061
# Month=6, Predicted=941.1469, Expected=913.2510
# Month=7, Predicted=911.8592, Expected=868.9804
# Month=8, Predicted=857.2505, Expected=834.0307
# Month=9, Predicted=827.5673, Expected=789.9965
# Month=10, Predicted=778.2272, Expected=799.8809
# Month=11, Predicted=799.0217, Expected=763.1165
# Month=12, Predicted=756.6235, Expected=800.0766
# Month=13, Predicted=799.2174, Expected=826.0806
# Month=14, Predicted=825.2214, Expected=798.9073
# Month=15, Predicted=798.0481, Expected=890.1429
# Month=16, Predicted=889.2837, Expected=899.8572
# Month=17, Predicted=898.9980, Expected=961.0598
# Month=18, Predicted=960.2006, Expected=935.2232
# Month=19, Predicted=934.3640, Expected=893.8991
# Month=20, Predicted=884.0149, Expected=854.9423
# Month=21, Predicted=846.0558, Expected=809.0102
# Month=22, Predicted=796.0121, Expected=809.9487
# Month=23, Predicted=809.0895, Expected=765.8420
# Month=24, Predicted=754.7299, Expected=805.0070
# Month=25, Predicted=804.1478, Expected=820.8918
# Month=26, Predicted=820.0326, Expected=773.0483
# Month=27, Predicted=759.8198, Expected=882.9063
# Month=28, Predicted=882.0471, Expected=898.1579
# Month=29, Predicted=897.2987, Expected=956.9202
# Month=30, Predicted=956.0610, Expected=923.9672
# Month=31, Predicted=919.8188, Expected=881.0829
# Month=32, Predicted=870.0657, Expected=836.8746
# Month=33, Predicted=824.7601, Expected=784.0232
# Month=34, Predicted=767.0183, Expected=791.1332
# Month=35, Predicted=790.2740, Expected=759.8362
# Month=36, Predicted=756.9029, Expected=802.0188
# Month=37, Predicted=801.1596, Expected=828.0265
# Month=38, Predicted=827.1673, Expected=778.0797
# Month=39, Predicted=763.7093, Expected=888.8740
# Month=40, Predicted=888.0148, Expected=901.8654
# Month=41, Predicted=901.0062, Expected=969.0532
# Month=42, Predicted=968.1940, Expected=947.0303
# Month=43, Predicted=946.1711, Expected=908.0255
# Month=44, Predicted=899.6663, Expected=867.0353
# Month=45, Predicted=856.9762, Expected=814.9307
# Month=46, Predicted=798.4242, Expected=812.0237
# Month=47, Predicted=811.1645, Expected=773.0299
# Month=48, Predicted=765.0092, Expected=812.9272
# Month=49, Predicted=812.0680, Expected=834.1901
# Month=50, Predicted=833.3309, Expected=782.0483
# Month=51, Predicted=766.4259, Expected=891.8786
# Month=52, Predicted=891.0194, Expected=903.0669
# Month=53, Predicted=902.2077, Expected=965.9007
# Month=54, Predicted=965.0415, Expected=937.0802
# Month=55, Predicted=935.6536, Expected=896.1181
# Month=56, Predicted=886.3785, Expected=857.9164
# Month=57, Predicted=849.5112, Expected=817.0982
# Month=58, Predicted=807.1640, Expected=827.0421
# Month=59, Predicted=826.1829, Expected=797.0838
# Month=60, Predicted=795.0619, Expected=843.1933
# Run 5 — RMSE: 49.663711, MSE: 2466.484225, NMSE: 0.0102542562
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=755.9605, Expected=804.0262
# Month=2, Predicted=793.0178, Expected=755.9924
# Month=3, Predicted=741.8030, Expected=859.8045
# Month=4, Predicted=886.4151, Expected=877.9973
# Month=5, Predicted=887.1300, Expected=942.0061
# Month=6, Predicted=920.2913, Expected=913.2510
# Month=7, Predicted=907.0294, Expected=868.9804
# Month=8, Predicted=855.6292, Expected=834.0307
# Month=9, Predicted=824.2280, Expected=789.9965
# Month=10, Predicted=776.6598, Expected=799.8809
# Month=11, Predicted=804.9745, Expected=763.1165
# Month=12, Predicted=753.1903, Expected=800.0766
# Month=13, Predicted=808.7009, Expected=826.0806
# Month=14, Predicted=834.6832, Expected=798.9073
# Month=15, Predicted=792.7574, Expected=890.1429
# Month=16, Predicted=904.6870, Expected=899.8572
# Month=17, Predicted=906.8414, Expected=961.0598
# Month=18, Predicted=941.8713, Expected=935.2232
# Month=19, Predicted=930.0880, Expected=893.8991
# Month=20, Predicted=881.7778, Expected=854.9423
# Month=21, Predicted=843.5731, Expected=809.0102
# Month=22, Predicted=794.8422, Expected=809.9487
# Month=23, Predicted=812.9107, Expected=765.8420
# Month=24, Predicted=752.9277, Expected=805.0070
# Month=25, Predicted=810.9186, Expected=820.8918
# Month=26, Predicted=827.7768, Expected=773.0483
# Month=27, Predicted=758.5898, Expected=882.9063
# Month=28, Predicted=913.4953, Expected=898.1579
# Month=29, Predicted=906.9994, Expected=956.9202
# Month=30, Predicted=939.9853, Expected=923.9672
# Month=31, Predicted=915.9715, Expected=881.0829
# Month=32, Predicted=868.2439, Expected=836.8746
# Month=33, Predicted=823.3496, Expected=784.0232
# Month=34, Predicted=766.9352, Expected=791.1332
# Month=35, Predicted=795.4845, Expected=759.8362
# Month=36, Predicted=752.0973, Expected=802.0188
# Month=37, Predicted=803.9020, Expected=828.0265
# Month=38, Predicted=836.7018, Expected=778.0797
# Month=39, Predicted=762.7635, Expected=888.8740
# Month=40, Predicted=920.1215, Expected=901.8654
# Month=41, Predicted=910.3071, Expected=969.0532
# Month=42, Predicted=950.3233, Expected=947.0303
# Month=43, Predicted=943.5141, Expected=908.0255
# Month=44, Predicted=896.8903, Expected=867.0353
# Month=45, Predicted=854.8790, Expected=814.9307
# Month=46, Predicted=798.2028, Expected=812.0237
# Month=47, Predicted=813.8960, Expected=773.0299
# Month=48, Predicted=762.1507, Expected=812.9272
# Month=49, Predicted=817.8233, Expected=834.1901
# Month=50, Predicted=842.0628, Expected=782.0483
# Month=51, Predicted=765.8006, Expected=891.8786
# Month=52, Predicted=922.6610, Expected=903.0669
# Month=53, Predicted=911.1019, Expected=965.9007
# Month=54, Predicted=945.2458, Expected=937.0802
# Month=55, Predicted=930.8070, Expected=896.1181
# Month=56, Predicted=884.1094, Expected=857.9164
# Month=57, Predicted=846.8572, Expected=817.0982
# Month=58, Predicted=805.0211, Expected=827.0421
# Month=59, Predicted=832.1850, Expected=797.0838
# Month=60, Predicted=789.8727, Expected=843.1933
# Run 6 — RMSE: 48.794357, MSE: 2380.889227, NMSE: 0.0101181819
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=755.8785, Expected=804.0262
# Month=2, Predicted=808.5745, Expected=755.9924
# Month=3, Predicted=741.9671, Expected=859.8045
# Month=4, Predicted=856.3715, Expected=877.9973
# Month=5, Predicted=886.2841, Expected=942.0061
# Month=6, Predicted=945.5833, Expected=913.2510
# Month=7, Predicted=906.7615, Expected=868.9804
# Month=8, Predicted=855.8846, Expected=834.0307
# Month=9, Predicted=823.2903, Expected=789.9965
# Month=10, Predicted=776.5488, Expected=799.8809
# Month=11, Predicted=802.4934, Expected=763.1165
# Month=12, Predicted=753.9557, Expected=800.0766
# Month=13, Predicted=804.9940, Expected=826.0806
# Month=14, Predicted=832.0222, Expected=798.9073
# Month=15, Predicted=793.2475, Expected=890.1429
# Month=16, Predicted=889.4123, Expected=899.8572
# Month=17, Predicted=905.7442, Expected=961.0598
# Month=18, Predicted=964.9935, Expected=935.2232
# Month=19, Predicted=929.7470, Expected=893.8991
# Month=20, Predicted=882.1095, Expected=854.9423
# Month=21, Predicted=842.9596, Expected=809.0102
# Month=22, Predicted=794.4959, Expected=809.9487
# Month=23, Predicted=810.5757, Expected=765.8420
# Month=24, Predicted=753.7349, Expected=805.0070
# Month=25, Predicted=809.2675, Expected=820.8918
# Month=26, Predicted=826.0927, Expected=773.0483
# Month=27, Predicted=759.5549, Expected=882.9063
# Month=28, Predicted=879.0179, Expected=898.1579
# Month=29, Predicted=906.9106, Expected=956.9202
# Month=30, Predicted=961.1800, Expected=923.9672
# Month=31, Predicted=915.8312, Expected=881.0829
# Month=32, Predicted=868.2481, Expected=836.8746
# Month=33, Predicted=822.6961, Expected=784.0232
# Month=34, Predicted=766.3674, Expected=791.1332
# Month=35, Predicted=792.3500, Expected=759.8362
# Month=36, Predicted=752.7287, Expected=802.0188
# Month=37, Predicted=807.0434, Expected=828.0265
# Month=38, Predicted=833.8862, Expected=778.0797
# Month=39, Predicted=763.6300, Expected=888.8740
# Month=40, Predicted=884.7457, Expected=901.8654
# Month=41, Predicted=910.4694, Expected=969.0532
# Month=42, Predicted=972.1923, Expected=947.0303
# Month=43, Predicted=943.0414, Expected=908.0255
# Month=44, Predicted=897.3026, Expected=867.0353
# Month=45, Predicted=854.4594, Expected=814.9307
# Month=46, Predicted=797.8409, Expected=812.0237
# Month=47, Predicted=811.0514, Expected=773.0299
# Month=48, Predicted=762.8676, Expected=812.9272
# Month=49, Predicted=817.5566, Expected=834.1901
# Month=50, Predicted=839.8511, Expected=782.0483
# Month=51, Predicted=766.8117, Expected=891.8786
# Month=52, Predicted=887.6209, Expected=903.0669
# Month=53, Predicted=911.2926, Expected=965.9007
# Month=54, Predicted=969.6250, Expected=937.0802
# Month=55, Predicted=930.5431, Expected=896.1181
# Month=56, Predicted=884.3293, Expected=857.9164
# Month=57, Predicted=846.2564, Expected=817.0982
# Month=58, Predicted=804.6542, Expected=827.0421
# Month=59, Predicted=829.9571, Expected=797.0838
# Month=60, Predicted=790.4977, Expected=843.1933
# Run 7 — RMSE: 49.353004, MSE: 2435.719045, NMSE: 0.0099819107
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=750.3921, Expected=804.0262
# Month=2, Predicted=795.1134, Expected=755.9924
# Month=3, Predicted=748.6060, Expected=859.8045
# Month=4, Predicted=885.2077, Expected=877.9973
# Month=5, Predicted=899.5440, Expected=942.0061
# Month=6, Predicted=919.4969, Expected=913.2510
# Month=7, Predicted=919.0935, Expected=868.9804
# Month=8, Predicted=853.0960, Expected=834.0307
# Month=9, Predicted=818.9594, Expected=789.9965
# Month=10, Predicted=772.4212, Expected=799.8809
# Month=11, Predicted=805.0708, Expected=763.1165
# Month=12, Predicted=762.1028, Expected=800.0766
# Month=13, Predicted=801.1117, Expected=826.0806
# Month=14, Predicted=839.4599, Expected=798.9073
# Month=15, Predicted=804.7258, Expected=890.1429
# Month=16, Predicted=905.2080, Expected=899.8572
# Month=17, Predicted=921.3551, Expected=961.0598
# Month=18, Predicted=941.9244, Expected=935.2232
# Month=19, Predicted=942.6887, Expected=893.8991
# Month=20, Predicted=880.9711, Expected=854.9423
# Month=21, Predicted=838.3376, Expected=809.0102
# Month=22, Predicted=788.8445, Expected=809.9487
# Month=23, Predicted=812.5086, Expected=765.8420
# Month=24, Predicted=758.4287, Expected=805.0070
# Month=25, Predicted=803.2061, Expected=820.8918
# Month=26, Predicted=838.0078, Expected=773.0483
# Month=27, Predicted=765.1897, Expected=882.9063
# Month=28, Predicted=910.1964, Expected=898.1579
# Month=29, Predicted=920.9563, Expected=956.9202
# Month=30, Predicted=940.6919, Expected=923.9672
# Month=31, Predicted=926.9940, Expected=881.0829
# Month=32, Predicted=864.7427, Expected=836.8746
# Month=33, Predicted=816.4019, Expected=784.0232
# Month=34, Predicted=759.4381, Expected=791.1332
# Month=35, Predicted=792.7285, Expected=759.8362
# Month=36, Predicted=761.8182, Expected=802.0188
# Month=37, Predicted=800.4346, Expected=828.0265
# Month=38, Predicted=841.5955, Expected=778.0797
# Month=39, Predicted=769.0608, Expected=888.8740
# Month=40, Predicted=916.8037, Expected=901.8654
# Month=41, Predicted=925.0702, Expected=969.0532
# Month=42, Predicted=949.6840, Expected=947.0303
# Month=43, Predicted=956.9788, Expected=908.0255
# Month=44, Predicted=897.9226, Expected=867.0353
# Month=45, Predicted=849.9332, Expected=814.9307
# Month=46, Predicted=790.5024, Expected=812.0237
# Month=47, Predicted=810.9710, Expected=773.0299
# Month=48, Predicted=768.4585, Expected=812.9272
# Month=49, Predicted=811.6876, Expected=834.1901
# Month=50, Predicted=849.7306, Expected=782.0483
# Month=51, Predicted=771.4488, Expected=891.8786
# Month=52, Predicted=919.8589, Expected=903.0669
# Month=53, Predicted=926.3189, Expected=965.9007
# Month=54, Predicted=944.7953, Expected=937.0802
# Month=55, Predicted=942.8301, Expected=896.1181
# Month=56, Predicted=882.4387, Expected=857.9164
# Month=57, Predicted=841.9444, Expected=817.0982
# Month=58, Predicted=800.4636, Expected=827.0421
# Month=59, Predicted=833.3510, Expected=797.0838
# Month=60, Predicted=800.2320, Expected=843.1933
# Run 8 — RMSE: 47.000390, MSE: 2209.036690, NMSE: 0.0089254113
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=753.4073, Expected=804.0262
# Month=2, Predicted=805.7434, Expected=755.9924
# Month=3, Predicted=740.9456, Expected=859.8045
# Month=4, Predicted=864.6638, Expected=877.9973
# Month=5, Predicted=888.3301, Expected=942.0061
# Month=6, Predicted=941.5732, Expected=913.2510
# Month=7, Predicted=906.2583, Expected=868.9804
# Month=8, Predicted=854.6849, Expected=834.0307
# Month=9, Predicted=823.4672, Expected=789.9965
# Month=10, Predicted=775.7560, Expected=799.8809
# Month=11, Predicted=802.4150, Expected=763.1165
# Month=12, Predicted=752.5246, Expected=800.0766
# Month=13, Predicted=802.7875, Expected=826.0806
# Month=14, Predicted=830.4376, Expected=798.9073
# Month=15, Predicted=792.4564, Expected=890.1429
# Month=16, Predicted=892.8698, Expected=899.8572
# Month=17, Predicted=906.6898, Expected=961.0598
# Month=18, Predicted=960.8662, Expected=935.2232
# Month=19, Predicted=929.3532, Expected=893.8991
# Month=20, Predicted=880.8349, Expected=854.9423
# Month=21, Predicted=842.7368, Expected=809.0102
# Month=22, Predicted=793.9810, Expected=809.9487
# Month=23, Predicted=810.9558, Expected=765.8420
# Month=24, Predicted=752.0351, Expected=805.0070
# Month=25, Predicted=807.4243, Expected=820.8918
# Month=26, Predicted=825.1183, Expected=773.0483
# Month=27, Predicted=757.9789, Expected=882.9063
# Month=28, Predicted=888.9258, Expected=898.1579
# Month=29, Predicted=908.5475, Expected=956.9202
# Month=30, Predicted=956.9237, Expected=923.9672
# Month=31, Predicted=915.2016, Expected=881.0829
# Month=32, Predicted=867.3145, Expected=836.8746
# Month=33, Predicted=822.5153, Expected=784.0232
# Month=34, Predicted=766.2920, Expected=791.1332
# Month=35, Predicted=793.2171, Expected=759.8362
# Month=36, Predicted=751.4768, Expected=802.0188
# Month=37, Predicted=804.1367, Expected=828.0265
# Month=38, Predicted=832.6738, Expected=778.0797
# Month=39, Predicted=762.2203, Expected=888.8740
# Month=40, Predicted=895.0997, Expected=901.8654
# Month=41, Predicted=911.7040, Expected=969.0532
# Month=42, Predicted=968.5245, Expected=947.0303
# Month=43, Predicted=942.6307, Expected=908.0255
# Month=44, Predicted=895.9599, Expected=867.0353
# Month=45, Predicted=854.0067, Expected=814.9307
# Month=46, Predicted=797.4939, Expected=812.0237
# Month=47, Predicted=812.1537, Expected=773.0299
# Month=48, Predicted=761.2717, Expected=812.9272
# Month=49, Predicted=815.2900, Expected=834.1901
# Month=50, Predicted=838.7089, Expected=782.0483
# Month=51, Predicted=765.3323, Expected=891.8786
# Month=52, Predicted=897.8575, Expected=903.0669
# Month=53, Predicted=912.2211, Expected=965.9007
# Month=54, Predicted=965.5857, Expected=937.0802
# Month=55, Predicted=930.0540, Expected=896.1181
# Month=56, Predicted=883.1713, Expected=857.9164
# Month=57, Predicted=846.0249, Expected=817.0982
# Month=58, Predicted=804.1458, Expected=827.0421
# Month=59, Predicted=829.6057, Expected=797.0838
# Month=60, Predicted=789.3302, Expected=843.1933
# Run 9 — RMSE: 49.141703, MSE: 2414.906944, NMSE: 0.0097951835
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=752.1281, Expected=804.0262
# Month=2, Predicted=796.5049, Expected=755.9924
# Month=3, Predicted=742.9657, Expected=859.8045
# Month=4, Predicted=882.2501, Expected=877.9973
# Month=5, Predicted=895.0540, Expected=942.0061
# Month=6, Predicted=920.7839, Expected=913.2510
# Month=7, Predicted=908.2825, Expected=868.9804
# Month=8, Predicted=855.1319, Expected=834.0307
# Month=9, Predicted=822.1797, Expected=789.9965
# Month=10, Predicted=775.7507, Expected=799.8809
# Month=11, Predicted=803.0124, Expected=763.1165
# Month=12, Predicted=754.2694, Expected=800.0766
# Month=13, Predicted=802.9819, Expected=826.0806
# Month=14, Predicted=835.5771, Expected=798.9073
# Month=15, Predicted=794.2218, Expected=890.1429
# Month=16, Predicted=903.2282, Expected=899.8572
# Month=17, Predicted=912.8674, Expected=961.0598
# Month=18, Predicted=943.1379, Expected=935.2232
# Month=19, Predicted=931.4433, Expected=893.8991
# Month=20, Predicted=881.3476, Expected=854.9423
# Month=21, Predicted=841.9529, Expected=809.0102
# Month=22, Predicted=793.7552, Expected=809.9487
# Month=23, Predicted=810.5534, Expected=765.8420
# Month=24, Predicted=753.8248, Expected=805.0070
# Month=25, Predicted=805.8302, Expected=820.8918
# Month=26, Predicted=830.5876, Expected=773.0483
# Month=27, Predicted=760.0109, Expected=882.9063
# Month=28, Predicted=906.9669, Expected=898.1579
# Month=29, Predicted=915.8966, Expected=956.9202
# Month=30, Predicted=941.8619, Expected=923.9672
# Month=31, Predicted=917.0716, Expected=881.0829
# Month=32, Predicted=867.4060, Expected=836.8746
# Month=33, Predicted=821.8969, Expected=784.0232
# Month=34, Predicted=765.7611, Expected=791.1332
# Month=35, Predicted=792.2773, Expected=759.8362
# Month=36, Predicted=753.1308, Expected=802.0188
# Month=37, Predicted=801.7570, Expected=828.0265
# Month=38, Predicted=837.7663, Expected=778.0797
# Month=39, Predicted=764.3079, Expected=888.8740
# Month=40, Predicted=913.4688, Expected=901.8654
# Month=41, Predicted=919.1946, Expected=969.0532
# Month=42, Predicted=950.8697, Expected=947.0303
# Month=43, Predicted=945.1354, Expected=908.0255
# Month=44, Predicted=896.6104, Expected=867.0353
# Month=45, Predicted=853.5437, Expected=814.9307
# Month=46, Predicted=797.2218, Expected=812.0237
# Month=47, Predicted=810.5339, Expected=773.0299
# Month=48, Predicted=762.8187, Expected=812.9272
# Month=49, Predicted=813.7187, Expected=834.1901
# Month=50, Predicted=844.1387, Expected=782.0483
# Month=51, Predicted=767.4001, Expected=891.8786
# Month=52, Predicted=916.5706, Expected=903.0669
# Month=53, Predicted=919.6387, Expected=965.9007
# Month=54, Predicted=946.0417, Expected=937.0802
# Month=55, Predicted=932.0474, Expected=896.1181
# Month=56, Predicted=883.4612, Expected=857.9164
# Month=57, Predicted=845.2253, Expected=817.0982
# Month=58, Predicted=803.7110, Expected=827.0421
# Month=59, Predicted=830.6444, Expected=797.0838
# Month=60, Predicted=791.0210, Expected=843.1933
# Run 10 — RMSE: 47.812926, MSE: 2286.075852, NMSE: 0.0095131387
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=751.1530, Expected=804.0262
# Month=2, Predicted=805.2131, Expected=755.9924
# Month=3, Predicted=745.2900, Expected=859.8045
# Month=4, Predicted=863.9752, Expected=877.9973
# Month=5, Predicted=892.4421, Expected=942.0061
# Month=6, Predicted=942.3057, Expected=913.2510
# Month=7, Predicted=913.5999, Expected=868.9804
# Month=8, Predicted=854.4012, Expected=834.0307
# Month=9, Predicted=820.3541, Expected=789.9965
# Month=10, Predicted=773.9796, Expected=799.8809
# Month=11, Predicted=801.6700, Expected=763.1165
# Month=12, Predicted=759.1779, Expected=800.0766
# Month=13, Predicted=800.7250, Expected=826.0806
# Month=14, Predicted=833.8962, Expected=798.9073
# Month=15, Predicted=800.0504, Expected=890.1429
# Month=16, Predicted=893.1022, Expected=899.8572
# Month=17, Predicted=912.9481, Expected=961.0598
# Month=18, Predicted=961.2905, Expected=935.2232
# Month=19, Predicted=936.8419, Expected=893.8991
# Month=20, Predicted=881.7739, Expected=854.9423
# Month=21, Predicted=839.9360, Expected=809.0102
# Month=22, Predicted=790.7409, Expected=809.9487
# Month=23, Predicted=810.0884, Expected=765.8420
# Month=24, Predicted=757.0252, Expected=805.0070
# Month=25, Predicted=803.9570, Expected=820.8918
# Month=26, Predicted=830.1855, Expected=773.0483
# Month=27, Predicted=762.9097, Expected=882.9063
# Month=28, Predicted=888.8793, Expected=898.1579
# Month=29, Predicted=914.0741, Expected=956.9202
# Month=30, Predicted=957.3738, Expected=923.9672
# Month=31, Predicted=921.9594, Expected=881.0829
# Month=32, Predicted=866.1887, Expected=836.8746
# Month=33, Predicted=818.4228, Expected=784.0232
# Month=34, Predicted=760.1923, Expected=791.1332
# Month=35, Predicted=790.4340, Expected=759.8362
# Month=36, Predicted=758.6304, Expected=802.0188
# Month=37, Predicted=802.2585, Expected=828.0265
# Month=38, Predicted=835.8558, Expected=778.0797
# Month=39, Predicted=766.6333, Expected=888.8740
# Month=40, Predicted=894.7333, Expected=901.8654
# Month=41, Predicted=918.1738, Expected=969.0532
# Month=42, Predicted=969.4477, Expected=947.0303
# Month=43, Predicted=950.6660, Expected=908.0255
# Month=44, Predicted=898.1382, Expected=867.0353
# Month=45, Predicted=851.5583, Expected=814.9307
# Month=46, Predicted=792.4338, Expected=812.0237
# Month=47, Predicted=809.5710, Expected=773.0299
# Month=48, Predicted=766.7111, Expected=812.9272
# Month=49, Predicted=812.5590, Expected=834.1901
# Month=50, Predicted=842.8426, Expected=782.0483
# Month=51, Predicted=769.3221, Expected=891.8786
# Month=52, Predicted=896.9953, Expected=903.0669
# Month=53, Predicted=919.3087, Expected=965.9007
# Month=54, Predicted=966.1263, Expected=937.0802
# Month=55, Predicted=937.3401, Expected=896.1181
# Month=56, Predicted=883.4344, Expected=857.9164
# Month=57, Predicted=843.4482, Expected=817.0982
# Month=58, Predicted=801.9958, Expected=827.0421
# Month=59, Predicted=829.5965, Expected=797.0838
# Month=60, Predicted=796.7158, Expected=843.1933
# Run 11 — RMSE: 47.929025, MSE: 2297.191427, NMSE: 0.0091275021
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=752.5216, Expected=804.0262
# Month=2, Predicted=806.1869, Expected=755.9924
# Month=3, Predicted=745.1079, Expected=859.8045
# Month=4, Predicted=861.8809, Expected=877.9973
# Month=5, Predicted=880.9633, Expected=942.0061
# Month=6, Predicted=944.1190, Expected=913.2510
# Month=7, Predicted=906.9351, Expected=868.9804
# Month=8, Predicted=858.1386, Expected=834.0307
# Month=9, Predicted=824.9327, Expected=789.9965
# Month=10, Predicted=779.0888, Expected=799.8809
# Month=11, Predicted=798.8809, Expected=763.1165
# Month=12, Predicted=754.3246, Expected=800.0766
# Month=13, Predicted=801.5361, Expected=826.0806
# Month=14, Predicted=827.9015, Expected=798.9073
# Month=15, Predicted=792.3708, Expected=890.1429
# Month=16, Predicted=892.3347, Expected=899.8572
# Month=17, Predicted=901.0897, Expected=961.0598
# Month=18, Predicted=963.1353, Expected=935.2232
# Month=19, Predicted=929.5263, Expected=893.8991
# Month=20, Predicted=883.7496, Expected=854.9423
# Month=21, Predicted=845.0193, Expected=809.0102
# Month=22, Predicted=797.6142, Expected=809.9487
# Month=23, Predicted=807.4357, Expected=765.8420
# Month=24, Predicted=755.3748, Expected=805.0070
# Month=25, Predicted=806.3942, Expected=820.8918
# Month=26, Predicted=821.8280, Expected=773.0483
# Month=27, Predicted=761.8186, Expected=882.9063
# Month=28, Predicted=885.0511, Expected=898.1579
# Month=29, Predicted=901.0194, Expected=956.9202
# Month=30, Predicted=958.9736, Expected=923.9672
# Month=31, Predicted=916.5731, Expected=881.0829
# Month=32, Predicted=870.4690, Expected=836.8746
# Month=33, Predicted=825.7693, Expected=784.0232
# Month=34, Predicted=771.0571, Expected=791.1332
# Month=35, Predicted=789.4669, Expected=759.8362
# Month=36, Predicted=752.2749, Expected=802.0188
# Month=37, Predicted=803.6033, Expected=828.0265
# Month=38, Predicted=829.9042, Expected=778.0797
# Month=39, Predicted=766.4488, Expected=888.8740
# Month=40, Predicted=890.9981, Expected=901.8654
# Month=41, Predicted=904.3851, Expected=969.0532
# Month=42, Predicted=971.2021, Expected=947.0303
# Month=43, Predicted=942.1687, Expected=908.0255
# Month=44, Predicted=898.4493, Expected=867.0353
# Month=45, Predicted=856.7134, Expected=814.9307
# Month=46, Predicted=802.1861, Expected=812.0237
# Month=47, Predicted=808.7285, Expected=773.0299
# Month=48, Predicted=763.6677, Expected=812.9272
# Month=49, Predicted=814.3921, Expected=834.1901
# Month=50, Predicted=835.9877, Expected=782.0483
# Month=51, Predicted=769.9129, Expected=891.8786
# Month=52, Predicted=893.9573, Expected=903.0669
# Month=53, Predicted=905.2422, Expected=965.9007
# Month=54, Predicted=967.9980, Expected=937.0802
# Month=55, Predicted=930.7239, Expected=896.1181
# Month=56, Predicted=885.9997, Expected=857.9164
# Month=57, Predicted=848.1681, Expected=817.0982
# Month=58, Predicted=806.8296, Expected=827.0421
# Month=59, Predicted=826.1225, Expected=797.0838
# Month=60, Predicted=789.8390, Expected=843.1933
# Run 12 — RMSE: 48.980545, MSE: 2399.093800, NMSE: 0.0099695934
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=753.7013, Expected=804.0262
# Month=2, Predicted=804.5706, Expected=755.9924
# Month=3, Predicted=739.8446, Expected=859.8045
# Month=4, Predicted=873.0664, Expected=877.9973
# Month=5, Predicted=882.6111, Expected=942.0061
# Month=6, Predicted=942.5966, Expected=913.2510
# Month=7, Predicted=906.7084, Expected=868.9804
# Month=8, Predicted=854.4467, Expected=834.0307
# Month=9, Predicted=823.6954, Expected=789.9965
# Month=10, Predicted=775.5011, Expected=799.8809
# Month=11, Predicted=799.7702, Expected=763.1165
# Month=12, Predicted=752.1125, Expected=800.0766
# Month=13, Predicted=803.2666, Expected=826.0806
# Month=14, Predicted=828.4188, Expected=798.9073
# Month=15, Predicted=792.1516, Expected=890.1429
# Month=16, Predicted=897.4484, Expected=899.8572
# Month=17, Predicted=901.8964, Expected=961.0598
# Month=18, Predicted=961.6012, Expected=935.2232
# Month=19, Predicted=929.1978, Expected=893.8991
# Month=20, Predicted=880.7448, Expected=854.9423
# Month=21, Predicted=842.7172, Expected=809.0102
# Month=22, Predicted=793.6059, Expected=809.9487
# Month=23, Predicted=808.2906, Expected=765.8420
# Month=24, Predicted=751.3981, Expected=805.0070
# Month=25, Predicted=807.7879, Expected=820.8918
# Month=26, Predicted=821.5845, Expected=773.0483
# Month=27, Predicted=756.8544, Expected=882.9063
# Month=28, Predicted=899.7872, Expected=898.1579
# Month=29, Predicted=902.9040, Expected=956.9202
# Month=30, Predicted=957.3676, Expected=923.9672
# Month=31, Predicted=915.1054, Expected=881.0829
# Month=32, Predicted=867.1395, Expected=836.8746
# Month=33, Predicted=822.1799, Expected=784.0232
# Month=34, Predicted=765.5589, Expected=791.1332
# Month=35, Predicted=790.4084, Expected=759.8362
# Month=36, Predicted=751.5843, Expected=802.0188
# Month=37, Predicted=804.3095, Expected=828.0265
# Month=38, Predicted=830.4081, Expected=778.0797
# Month=39, Predicted=760.9069, Expected=888.8740
# Month=40, Predicted=906.3170, Expected=901.8654
# Month=41, Predicted=906.3296, Expected=969.0532
# Month=42, Predicted=969.9421, Expected=947.0303
# Month=43, Predicted=941.9499, Expected=908.0255
# Month=44, Predicted=895.9940, Expected=867.0353
# Month=45, Predicted=853.8876, Expected=814.9307
# Month=46, Predicted=796.8320, Expected=812.0237
# Month=47, Predicted=809.5996, Expected=773.0299
# Month=48, Predicted=760.9997, Expected=812.9272
# Month=49, Predicted=815.5992, Expected=834.1901
# Month=50, Predicted=835.7746, Expected=782.0483
# Month=51, Predicted=763.9713, Expected=891.8786
# Month=52, Predicted=908.6612, Expected=903.0669
# Month=53, Predicted=907.1202, Expected=965.9007
# Month=54, Predicted=966.4858, Expected=937.0802
# Month=55, Predicted=930.4608, Expected=896.1181
# Month=56, Predicted=883.1113, Expected=857.9164
# Month=57, Predicted=846.0593, Expected=817.0982
# Month=58, Predicted=804.0434, Expected=827.0421
# Month=59, Predicted=826.9795, Expected=797.0838
# Month=60, Predicted=789.5025, Expected=843.1933
# Run 13 — RMSE: 49.504210, MSE: 2450.666798, NMSE: 0.0097405606
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=745.7388, Expected=804.0262
# Month=2, Predicted=789.0836, Expected=755.9924
# Month=3, Predicted=750.7134, Expected=859.8045
# Month=4, Predicted=888.9215, Expected=877.9973
# Month=5, Predicted=872.7183, Expected=942.0061
# Month=6, Predicted=919.7662, Expected=913.2510
# Month=7, Predicted=907.9720, Expected=868.9804
# Month=8, Predicted=863.7014, Expected=834.0307
# Month=9, Predicted=828.7517, Expected=789.9965
# Month=10, Predicted=784.7175, Expected=799.8809
# Month=11, Predicted=794.6019, Expected=763.1165
# Month=12, Predicted=757.8375, Expected=800.0766
# Month=13, Predicted=794.7976, Expected=826.0806
# Month=14, Predicted=820.8016, Expected=798.9073
# Month=15, Predicted=793.6284, Expected=890.1429
# Month=16, Predicted=906.7495, Expected=899.8572
# Month=17, Predicted=894.5782, Expected=961.0598
# Month=18, Predicted=940.5192, Expected=935.2232
# Month=19, Predicted=929.9442, Expected=893.8991
# Month=20, Predicted=888.6201, Expected=854.9423
# Month=21, Predicted=849.6633, Expected=809.0102
# Month=22, Predicted=803.7312, Expected=809.9487
# Month=23, Predicted=804.6697, Expected=765.8420
# Month=24, Predicted=760.5630, Expected=805.0070
# Month=25, Predicted=799.7280, Expected=820.8918
# Month=26, Predicted=815.6128, Expected=773.0483
# Month=27, Predicted=767.7693, Expected=882.9063
# Month=28, Predicted=916.5344, Expected=898.1579
# Month=29, Predicted=892.8790, Expected=956.9202
# Month=30, Predicted=937.8547, Expected=923.9672
# Month=31, Predicted=918.6882, Expected=881.0829
# Month=32, Predicted=875.8039, Expected=836.8746
# Month=33, Predicted=831.5956, Expected=784.0232
# Month=34, Predicted=778.7442, Expected=791.1332
# Month=35, Predicted=785.8542, Expected=759.8362
# Month=36, Predicted=754.5572, Expected=802.0188
# Month=37, Predicted=795.5514, Expected=828.0265
# Month=38, Predicted=822.7475, Expected=778.0797
# Month=39, Predicted=772.8007, Expected=888.8740
# Month=40, Predicted=923.2165, Expected=901.8654
# Month=41, Predicted=896.5865, Expected=969.0532
# Month=42, Predicted=950.6856, Expected=947.0303
# Month=43, Predicted=941.7513, Expected=908.0255
# Month=44, Predicted=902.7465, Expected=867.0353
# Month=45, Predicted=861.7563, Expected=814.9307
# Month=46, Predicted=809.6517, Expected=812.0237
# Month=47, Predicted=806.7447, Expected=773.0299
# Month=48, Predicted=767.7509, Expected=812.9272
# Month=49, Predicted=807.6482, Expected=834.1901
# Month=50, Predicted=828.9111, Expected=782.0483
# Month=51, Predicted=776.7693, Expected=891.8786
# Month=52, Predicted=925.6128, Expected=903.0669
# Month=53, Predicted=897.7879, Expected=965.9007
# Month=54, Predicted=944.3870, Expected=937.0802
# Month=55, Predicted=931.8012, Expected=896.1181
# Month=56, Predicted=890.8391, Expected=857.9164
# Month=57, Predicted=852.6374, Expected=817.0982
# Month=58, Predicted=811.8192, Expected=827.0421
# Month=59, Predicted=821.7631, Expected=797.0838
# Month=60, Predicted=791.8048, Expected=843.1933
# Run 14 — RMSE: 47.966926, MSE: 2300.825985, NMSE: 0.0100958896
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=761.3308, Expected=804.0262
# Month=2, Predicted=792.9027, Expected=755.9924
# Month=3, Predicted=744.3482, Expected=859.8045
# Month=4, Predicted=873.2399, Expected=877.9973
# Month=5, Predicted=891.5940, Expected=942.0061
# Month=6, Predicted=928.5161, Expected=913.2510
# Month=7, Predicted=910.9198, Expected=868.9804
# Month=8, Predicted=854.2232, Expected=834.0307
# Month=9, Predicted=822.3961, Expected=789.9965
# Month=10, Predicted=774.5178, Expected=799.8809
# Month=11, Predicted=805.9805, Expected=763.1165
# Month=12, Predicted=757.0498, Expected=800.0766
# Month=13, Predicted=813.4192, Expected=826.0806
# Month=14, Predicted=840.2820, Expected=798.9073
# Month=15, Predicted=797.0927, Expected=890.1429
# Month=16, Predicted=902.0495, Expected=899.8572
# Month=17, Predicted=911.1031, Expected=961.0598
# Month=18, Predicted=946.7893, Expected=935.2232
# Month=19, Predicted=933.9526, Expected=893.8991
# Month=20, Predicted=881.0735, Expected=854.9423
# Month=21, Predicted=841.4586, Expected=809.0102
# Month=22, Predicted=792.1000, Expected=809.9487
# Month=23, Predicted=812.8536, Expected=765.8420
# Month=24, Predicted=754.3693, Expected=805.0070
# Month=25, Predicted=816.2842, Expected=820.8918
# Month=26, Predicted=833.0685, Expected=773.0483
# Month=27, Predicted=761.1283, Expected=882.9063
# Month=28, Predicted=895.7525, Expected=898.1579
# Month=29, Predicted=911.1628, Expected=956.9202
# Month=30, Predicted=942.8244, Expected=923.9672
# Month=31, Predicted=920.0520, Expected=881.0829
# Month=32, Predicted=866.5918, Expected=836.8746
# Month=33, Predicted=820.4045, Expected=784.0232
# Month=34, Predicted=763.2134, Expected=791.1332
# Month=35, Predicted=795.4533, Expected=759.8362
# Month=36, Predicted=755.6311, Expected=802.0188
# Month=37, Predicted=807.7323, Expected=828.0265
# Month=38, Predicted=842.2196, Expected=778.0797
# Month=39, Predicted=765.3233, Expected=888.8740
# Month=40, Predicted=901.5895, Expected=901.8654
# Month=41, Predicted=914.3036, Expected=969.0532
# Month=42, Predicted=957.2484, Expected=947.0303
# Month=43, Predicted=947.2403, Expected=908.0255
# Month=44, Predicted=896.9419, Expected=867.0353
# Month=45, Predicted=852.7428, Expected=814.9307
# Month=46, Predicted=794.8161, Expected=812.0237
# Month=47, Predicted=812.9385, Expected=773.0299
# Month=48, Predicted=764.0793, Expected=812.9272
# Month=49, Predicted=822.9439, Expected=834.1901
# Month=50, Predicted=847.5172, Expected=782.0483
# Month=51, Predicted=768.0960, Expected=891.8786
# Month=52, Predicted=904.6557, Expected=903.0669
# Month=53, Predicted=915.0005, Expected=965.9007
# Month=54, Predicted=951.9524, Expected=937.0802
# Month=55, Predicted=934.7161, Expected=896.1181
# Month=56, Predicted=883.1462, Expected=857.9164
# Month=57, Predicted=844.8855, Expected=817.0982
# Month=58, Predicted=802.9482, Expected=827.0421
# Month=59, Predicted=833.4488, Expected=797.0838
# Month=60, Predicted=793.5909, Expected=843.1933
# Run 15 — RMSE: 47.981394, MSE: 2302.214182, NMSE: 0.0098925867
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=754.7104, Expected=804.0262
# Month=2, Predicted=807.0956, Expected=755.9924
# Month=3, Predicted=744.9582, Expected=859.8045
# Month=4, Predicted=860.9996, Expected=877.9973
# Month=5, Predicted=885.9441, Expected=942.0061
# Month=6, Predicted=944.6980, Expected=913.2510
# Month=7, Predicted=909.0189, Expected=868.9804
# Month=8, Predicted=858.2884, Expected=834.0307
# Month=9, Predicted=825.9571, Expected=789.9965
# Month=10, Predicted=779.1064, Expected=799.8809
# Month=11, Predicted=800.9376, Expected=763.1165
# Month=12, Predicted=755.8236, Expected=800.0766
# Month=13, Predicted=803.8080, Expected=826.0806
# Month=14, Predicted=829.5655, Expected=798.9073
# Month=15, Predicted=793.8545, Expected=890.1429
# Month=16, Predicted=892.5874, Expected=899.8572
# Month=17, Predicted=905.0191, Expected=961.0598
# Month=18, Predicted=963.9264, Expected=935.2232
# Month=19, Predicted=931.4177, Expected=893.8991
# Month=20, Predicted=884.4086, Expected=854.9423
# Month=21, Predicted=845.5593, Expected=809.0102
# Month=22, Predicted=797.2174, Expected=809.9487
# Month=23, Predicted=809.5271, Expected=765.8420
# Month=24, Predicted=755.7755, Expected=805.0070
# Month=25, Predicted=808.6179, Expected=820.8918
# Month=26, Predicted=823.1731, Expected=773.0483
# Month=27, Predicted=761.5943, Expected=882.9063
# Month=28, Predicted=883.5463, Expected=898.1579
# Month=29, Predicted=906.5061, Expected=956.9202
# Month=30, Predicted=959.7604, Expected=923.9672
# Month=31, Predicted=918.5573, Expected=881.0829
# Month=32, Predicted=870.7095, Expected=836.8746
# Month=33, Predicted=825.4659, Expected=784.0232
# Month=34, Predicted=769.4980, Expected=791.1332
# Month=35, Predicted=791.3667, Expected=759.8362
# Month=36, Predicted=754.0180, Expected=802.0188
# Month=37, Predicted=805.6941, Expected=828.0265
# Month=38, Predicted=831.6280, Expected=778.0797
# Month=39, Predicted=765.8630, Expected=888.8740
# Month=40, Predicted=889.3913, Expected=901.8654
# Month=41, Predicted=910.0104, Expected=969.0532
# Month=42, Predicted=971.7379, Expected=947.0303
# Month=43, Predicted=944.3747, Expected=908.0255
# Month=44, Predicted=899.5406, Expected=867.0353
# Month=45, Predicted=857.0386, Expected=814.9307
# Month=46, Predicted=800.8519, Expected=812.0237
# Month=47, Predicted=810.6605, Expected=773.0299
# Month=48, Predicted=764.8720, Expected=812.9272
# Month=49, Predicted=816.5965, Expected=834.1901
# Month=50, Predicted=837.1775, Expected=782.0483
# Month=51, Predicted=769.0487, Expected=891.8786
# Month=52, Predicted=892.4359, Expected=903.0669
# Month=53, Predicted=910.8066, Expected=965.9007
# Month=54, Predicted=968.7097, Expected=937.0802
# Month=55, Predicted=932.7632, Expected=896.1181
# Month=56, Predicted=886.6464, Expected=857.9164
# Month=57, Predicted=848.8391, Expected=817.0982
# ...
# Month=50, Predicted=834.7055, Expected=782.2414
# Month=51, Predicted=771.7220, Expected=891.3930
# Month=52, Predicted=919.4618, Expected=903.3345
# Month=53, Predicted=903.0894, Expected=965.5034
# Month=54, Predicted=965.2582, Expected=937.4010
# Month=55, Predicted=937.1559, Expected=896.5903
# Month=56, Predicted=885.0983, Expected=857.5819
# Month=57, Predicted=841.8318, Expected=817.4908
# Month=58, Predicted=801.7893, Expected=827.2103
# Month=59, Predicted=826.9652, Expected=797.4188
# Month=60, Predicted=797.1737, Expected=843.9664
# Run 16 — RMSE: 48.159132, MSE: 2319.302027, NMSE: 0.0092331958
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=749.9931, Expected=804.1312
# Month=2, Predicted=794.0295, Expected=755.9621
# Month=3, Predicted=743.0564, Expected=859.0224
# Month=4, Predicted=885.3999, Expected=877.9865
# Month=5, Predicted=907.1678, Expected=942.0307
# Month=6, Predicted=920.1340, Expected=914.2550
# Month=7, Predicted=909.7987, Expected=868.9020
# Month=8, Predicted=855.2124, Expected=834.1536
# Month=9, Predicted=821.8903, Expected=789.9823
# Month=10, Predicted=776.1652, Expected=799.4046
# Month=11, Predicted=801.1581, Expected=763.5823
# Month=12, Predicted=753.9270, Expected=800.3831
# Month=13, Predicted=800.4973, Expected=826.4030
# Month=14, Predicted=833.4714, Expected=798.5367
# Month=15, Predicted=791.5561, Expected=890.7147
# Month=16, Predicted=907.9251, Expected=899.2858
# Month=17, Predicted=920.3292, Expected=961.2990
# Month=18, Predicted=941.3606, Expected=936.1160
# Month=19, Predicted=932.4642, Expected=893.4953
# Month=20, Predicted=880.7695, Expected=854.7115
# Month=21, Predicted=841.6095, Expected=809.0508
# Month=22, Predicted=794.4557, Expected=809.7435
# Month=23, Predicted=809.0334, Expected=765.2099
# Month=24, Predicted=752.6551, Expected=805.0349
# Month=25, Predicted=801.5743, Expected=820.4588
# Month=26, Predicted=828.2495, Expected=773.2413
# Month=27, Predicted=759.9165, Expected=882.5316
# Month=28, Predicted=914.7691, Expected=898.7897
# Month=29, Predicted=930.9663, Expected=956.6009
# Month=30, Predicted=940.8571, Expected=923.8359
# Month=31, Predicted=916.6175, Expected=881.4145
# Month=32, Predicted=868.2145, Expected=836.3729
# Month=33, Predicted=821.5640, Expected=784.1159
# Month=34, Predicted=767.2511, Expected=791.6660
# Month=35, Predicted=790.8938, Expected=759.1810
# Month=36, Predicted=750.6484, Expected=802.0941
# Month=37, Predicted=798.9802, Expected=828.1324
# Month=38, Predicted=835.8768, Expected=778.3983
# Month=39, Predicted=764.2722, Expected=888.3698
# Month=40, Predicted=920.7433, Expected=901.3272
# Month=41, Predicted=932.9912, Expected=969.2659
# Month=42, Predicted=952.1530, Expected=947.1513
# Month=43, Predicted=945.8173, Expected=908.1276
# Month=44, Predicted=896.6895, Expected=867.1765
# Month=45, Predicted=853.8538, Expected=814.6535
# Month=46, Predicted=798.1154, Expected=812.1183
# Month=47, Predicted=808.6896, Expected=773.1493
# Month=48, Predicted=762.3537, Expected=812.6360
# Month=49, Predicted=810.6219, Expected=834.9506
# Month=50, Predicted=842.7694, Expected=782.2414
# Month=51, Predicted=767.3402, Expected=891.3930
# Month=52, Predicted=922.4708, Expected=903.3345
# Month=53, Predicted=934.1924, Expected=965.5034
# Month=54, Predicted=945.3545, Expected=937.4010
# Month=55, Predicted=932.5441, Expected=896.5903
# Month=56, Predicted=884.2243, Expected=857.5819
# Month=57, Predicted=844.6306, Expected=817.4908
# Month=58, Predicted=804.4333, Expected=827.2103
# Month=59, Predicted=829.9749, Expected=797.4188
# Month=60, Predicted=789.8401, Expected=843.9664
# Run 17 — RMSE: 47.072638, MSE: 2215.833295, NMSE: 0.0086507809
#
# ===== RUN 18/30 =====
# Training complete for run 18
# Month=1, Predicted=748.7332, Expected=804.1312
# Month=2, Predicted=801.9302, Expected=755.9621
# Month=3, Predicted=747.9913, Expected=859.0224
# Month=4, Predicted=857.3347, Expected=877.9865
# Month=5, Predicted=875.4639, Expected=942.0307
# Month=6, Predicted=939.9460, Expected=914.2550
# Month=7, Predicted=911.2098, Expected=868.9020
# Month=8, Predicted=861.6684, Expected=834.1536
# Month=9, Predicted=829.9800, Expected=789.9823
# Month=10, Predicted=783.0042, Expected=799.4046
# Month=11, Predicted=796.7274, Expected=763.5823
# Month=12, Predicted=759.6332, Expected=800.3831
# Month=13, Predicted=798.0022, Expected=826.4030
# Month=14, Predicted=823.9131, Expected=798.5367
# Month=15, Predicted=795.4817, Expected=890.7147
# Month=16, Predicted=888.9256, Expected=899.2858
# Month=17, Predicted=896.6415, Expected=961.2990
# Month=18, Predicted=959.1939, Expected=936.1160
# Month=19, Predicted=933.0963, Expected=893.4953
# Month=20, Predicted=887.1881, Expected=854.7115
# Month=21, Predicted=849.2864, Expected=809.0508
# Month=22, Predicted=801.4986, Expected=809.7435
# Month=23, Predicted=806.9734, Expected=765.2099
# Month=24, Predicted=758.4177, Expected=805.0349
# Month=25, Predicted=802.6808, Expected=820.4588
# Month=26, Predicted=817.8566, Expected=773.2413
# Month=27, Predicted=765.5222, Expected=882.5316
# Month=28, Predicted=880.9090, Expected=898.7897
# Month=29, Predicted=896.2453, Expected=956.6009
# Month=30, Predicted=954.4501, Expected=923.8359
# Month=31, Predicted=920.7365, Expected=881.4145
# Month=32, Predicted=875.0400, Expected=836.3729
# Month=33, Predicted=828.9204, Expected=784.1159
# Month=34, Predicted=774.3360, Expected=791.6660
# Month=35, Predicted=788.9629, Expected=759.1810
# Month=36, Predicted=756.0802, Expected=802.0941
# Month=37, Predicted=799.7801, Expected=828.1324
# Month=38, Predicted=825.6436, Expected=778.3983
# Month=39, Predicted=769.8838, Expected=888.3698
# Month=40, Predicted=886.7510, Expected=901.3272
# Month=41, Predicted=898.7485, Expected=969.2659
# Month=42, Predicted=967.2233, Expected=947.1513
# Month=43, Predicted=944.1666, Expected=908.1276
# Month=44, Predicted=903.0440, Expected=867.1765
# Month=45, Predicted=861.1397, Expected=814.6535
# Month=46, Predicted=804.9025, Expected=812.1183
# Month=47, Predicted=809.3091, Expected=773.1493
# Month=48, Predicted=768.1919, Expected=812.6360
# Month=49, Predicted=810.2820, Expected=834.9506
# Month=50, Predicted=832.4216, Expected=782.2414
# Month=51, Predicted=772.7923, Expected=891.3930
# Month=52, Predicted=889.7643, Expected=903.3345
# Month=53, Predicted=900.7440, Expected=965.5034
# Month=54, Predicted=963.3995, Expected=937.4010
# Month=55, Predicted=934.3514, Expected=896.5903
# Month=56, Predicted=890.8302, Expected=857.5819
# Month=57, Predicted=852.1351, Expected=817.4908
# Month=58, Predicted=811.7386, Expected=827.2103
# Month=59, Predicted=824.5390, Expected=797.4188
# Month=60, Predicted=794.3453, Expected=843.9664
# Run 18 — RMSE: 48.850181, MSE: 2386.340156, NMSE: 0.0103094978
#
# ===== RUN 19/30 =====
# Training complete for run 19
# Month=1, Predicted=754.2162, Expected=804.1312
# Month=2, Predicted=808.4435, Expected=755.9621
# Month=3, Predicted=741.3408, Expected=859.0224
# Month=4, Predicted=860.9023, Expected=877.9865
# Month=5, Predicted=886.0148, Expected=942.0307
# Month=6, Predicted=946.1674, Expected=914.2550
# Month=7, Predicted=908.6509, Expected=868.9020
# Month=8, Predicted=854.5906, Expected=834.1536
# Month=9, Predicted=823.9771, Expected=789.9823
# Month=10, Predicted=775.9953, Expected=799.4046
# Month=11, Predicted=799.2312, Expected=763.5823
# Month=12, Predicted=753.6956, Expected=800.3831
# Month=13, Predicted=803.3522, Expected=826.4030
# Month=14, Predicted=829.1087, Expected=798.5367
# Month=15, Predicted=791.7368, Expected=890.7147
# Month=16, Predicted=893.7791, Expected=899.2858
# Month=17, Predicted=904.1070, Expected=961.2990
# Month=18, Predicted=965.4477, Expected=936.1160
# Month=19, Predicted=931.0143, Expected=893.4953
# Month=20, Predicted=880.4107, Expected=854.7115
# Month=21, Predicted=842.8492, Expected=809.0508
# Month=22, Predicted=794.3212, Expected=809.7435
# Month=23, Predicted=808.1323, Expected=765.2099
# Month=24, Predicted=751.4665, Expected=805.0349
# Month=25, Predicted=807.9153, Expected=820.4588
# Month=26, Predicted=822.0349, Expected=773.2413
# Month=27, Predicted=758.3991, Expected=882.5316
# Month=28, Predicted=884.0514, Expected=898.7897
# Month=29, Predicted=907.4456, Expected=956.6009
# Month=30, Predicted=960.7334, Expected=923.8359
# Month=31, Predicted=916.3021, Expected=881.4145
# Month=32, Predicted=868.2538, Expected=836.3729
# Month=33, Predicted=821.8090, Expected=784.1159
# Month=34, Predicted=766.4013, Expected=791.6660
# Month=35, Predicted=790.9333, Expected=759.1810
# Month=36, Predicted=750.7759, Expected=802.0941
# Month=37, Predicted=805.4926, Expected=828.1324
# Month=38, Predicted=831.0079, Expected=778.3983
# Month=39, Predicted=762.5198, Expected=888.3698
# Month=40, Predicted=889.7534, Expected=901.3272
# Month=41, Predicted=909.5765, Expected=969.2659
# Month=42, Predicted=973.3683, Expected=947.1513
# Month=43, Predicted=943.1785, Expected=908.1276
# Month=44, Predicted=896.6702, Expected=867.1765
# Month=45, Predicted=854.4759, Expected=814.6535
# Month=46, Predicted=796.9438, Expected=812.1183
# Month=47, Predicted=809.7105, Expected=773.1493
# Month=48, Predicted=761.8157, Expected=812.6360
# Month=49, Predicted=815.6764, Expected=834.9506
# Month=50, Predicted=837.3399, Expected=782.2414
# Month=51, Predicted=765.0679, Expected=891.3930
# Month=52, Predicted=892.7079, Expected=903.3345
# Month=53, Predicted=911.2797, Expected=965.5034
# Month=54, Predicted=969.6537, Expected=937.4010
# Month=55, Predicted=931.6003, Expected=896.5903
# Month=56, Predicted=884.2378, Expected=857.5819
# Month=57, Predicted=845.6752, Expected=817.4908
# Month=58, Predicted=805.1588, Expected=827.2103
# Month=59, Predicted=827.2030, Expected=797.4188
# Month=60, Predicted=790.1070, Expected=843.9664
# Run 19 — RMSE: 49.321316, MSE: 2432.592234, NMSE: 0.0097004394
#
# ===== RUN 20/30 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 113
#     111 run_losses = []
#     112 for epoch in range(100):
# --> 113     history = model.fit(
#     114         X_train, y_train,
#     115         epochs=1, batch_size=1,
#     116         verbose=0, shuffle=False
#     117     )
#     118     run_losses.append(history.history['loss'][0])
#     119     rnn_layer.reset_states()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)   1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)   1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
