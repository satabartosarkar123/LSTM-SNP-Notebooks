# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Monthly Milk Production
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value clipped to $[0, 1]$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# PROCESS IDENTIFICATION
# ============================================================
import os
print(f"Process ID (PID): {os.getpid()}")

# %%
# ============================================================
# NOTEBOOK TIMER — START
# ============================================================
import time as _timer_module
_NOTEBOOK_START_TIME = _timer_module.time()
print(f"Notebook execution started at: {_timer_module.strftime('%Y-%m-%d %H:%M:%S')}")

# %%
# ============================================================
# GPU Acceleration Settings (CUDA + Apple Metal Support)
# ============================================================
import tensorflow as tf
import platform

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
        # Detect GPU type
        if platform.system() == 'Darwin' and platform.processor() == 'arm':
            print(f"Apple Metal GPU Enabled: Found {len(physical_devices)} GPU(s) via tensorflow-metal")
            print(f"  Chipset: Apple {platform.machine()} (M-series)")
        else:
            print(f"CUDA GPU Enabled: Found {len(physical_devices)} GPU(s) - Memory Growth Set")
        for d in physical_devices:
            print(f"  Device: {d.name}")
    except RuntimeError as e:
        print(f"GPU configuration error: {e}")
else:
    if platform.system() == 'Darwin' and platform.processor() == 'arm':
        print("Apple Silicon detected but no GPU found.")
        print("  Install tensorflow-metal: pip install tensorflow-metal")
    else:
        print("No GPU found. Falling back to CPU.")
        print("  For CUDA: ensure NVIDIA drivers + CUDA toolkit are installed.")

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Gate Replacement
# Uses FuzzyLSTMSNPCell instead of LSTMSNPCell.
# Gradient clipping applied for stability.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 1)]               0
#
#  rnn (RNN)                   (1, 8)                    464
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 473 (1.85 KB)
# Trainable params: 473 (1.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Milk Production

# %%
# ============================================================
# 1. Load
#  Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-milk-production-pounds-p.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 1)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input
    # ============================================================
    
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)
    
        rnn_layer = model.layers[1]
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)
    
        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Milk Production (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Gate Replacement — Monthly Milk Production\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Gate Replacement — Monthly Milk Production\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.509499)
# ================================================================================
#
# Data shape: (168,)
# First 5 values: [589.25307559 560.92955441 640.32999695 656.77598287 726.88069898]
# Supervised data shape: (167, 2)
# Train: (107, 2), Test: (60, 2)
# X_train shape: (107, 1, 1), y_train shape: (107,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=755.3317, Expected=804.1312
# Month=2, Predicted=810.5436, Expected=755.9621
# Month=3, Predicted=742.6886, Expected=859.0224
# Month=4, Predicted=857.3177, Expected=877.9865
# Month=5, Predicted=888.9313, Expected=942.0307
# Month=6, Predicted=947.7312, Expected=914.2550
# Month=7, Predicted=909.0413, Expected=868.9020
# Month=8, Predicted=854.5917, Expected=834.1536
# Month=9, Predicted=822.0779, Expected=789.9823
# Month=10, Predicted=775.4938, Expected=799.4046
# Month=11, Predicted=799.4788, Expected=763.5823
# Month=12, Predicted=754.3690, Expected=800.3831
# Month=13, Predicted=804.4727, Expected=826.4030
# Month=14, Predicted=831.8622, Expected=798.5367
# Month=15, Predicted=792.1187, Expected=890.7147
# Month=16, Predicted=892.2080, Expected=899.2858
# Month=17, Predicted=906.8337, Expected=961.2990
# Month=18, Predicted=967.0999, Expected=936.1160
# Month=19, Predicted=931.6096, Expected=893.4953
# Month=20, Predicted=880.4639, Expected=854.7115
# Month=21, Predicted=841.5332, Expected=809.0508
# Month=22, Predicted=793.5701, Expected=809.7435
# Month=23, Predicted=807.8685, Expected=765.2099
# Month=24, Predicted=752.6663, Expected=805.0349
# Month=25, Predicted=808.5028, Expected=820.4588
# Month=26, Predicted=824.6854, Expected=773.2413
# Month=27, Predicted=759.9269, Expected=882.5316
# Month=28, Predicted=879.8311, Expected=898.7897
# Month=29, Predicted=910.4732, Expected=956.6009
# Month=30, Predicted=962.6427, Expected=923.8359
# Month=31, Predicted=916.5492, Expected=881.4145
# Month=32, Predicted=867.8562, Expected=836.3729
# Month=33, Predicted=820.7932, Expected=784.1159
# Month=34, Predicted=765.2768, Expected=791.6660
# Month=35, Predicted=790.4879, Expected=759.1810
# Month=36, Predicted=751.0681, Expected=802.0941
# Month=37, Predicted=806.6674, Expected=828.1324
# Month=38, Predicted=833.7409, Expected=778.3983
# Month=39, Predicted=764.0463, Expected=888.3698
# Month=40, Predicted=885.3212, Expected=901.3272
# Month=41, Predicted=912.5679, Expected=969.2659
# Month=42, Predicted=974.6829, Expected=947.1513
# Month=43, Predicted=944.0636, Expected=908.1276
# Month=44, Predicted=896.6143, Expected=867.1765
# Month=45, Predicted=853.5782, Expected=814.6535
# Month=46, Predicted=796.1314, Expected=812.1183
# Month=47, Predicted=808.7202, Expected=773.1493
# Month=48, Predicted=762.5375, Expected=812.6360
# Month=49, Predicted=816.5870, Expected=834.9506
# Month=50, Predicted=840.0734, Expected=782.2414
# Month=51, Predicted=766.6430, Expected=891.3930
# Month=52, Predicted=888.2104, Expected=903.3345
# Month=53, Predicted=914.2142, Expected=965.5034
# Month=54, Predicted=971.3137, Expected=937.4010
# Month=55, Predicted=931.9500, Expected=896.5903
# Month=56, Predicted=884.0215, Expected=857.5819
# Month=57, Predicted=844.5013, Expected=817.4908
# Month=58, Predicted=804.1883, Expected=827.2103
# Month=59, Predicted=827.7346, Expected=797.4188
# Month=60, Predicted=790.2501, Expected=843.9664
# Run 1 — RMSE: 49.062440, MSE: 2407.123010, NMSE: 0.0095746883
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=745.9338, Expected=804.1312
# Month=2, Predicted=788.8377, Expected=755.9621
# Month=3, Predicted=750.8069, Expected=859.0224
# Month=4, Predicted=887.8193, Expected=877.9865
# Month=5, Predicted=872.8313, Expected=942.0307
# Month=6, Predicted=920.3618, Expected=914.2550
# Month=7, Predicted=909.0999, Expected=868.9020
# Month=8, Predicted=863.7468, Expected=834.1536
# Month=9, Predicted=828.9985, Expected=789.9823
# Month=10, Predicted=784.8271, Expected=799.4046
# Month=11, Predicted=794.2494, Expected=763.5823
# Month=12, Predicted=758.4271, Expected=800.3831
# Month=13, Predicted=795.2279, Expected=826.4030
# Month=14, Predicted=821.2479, Expected=798.5367
# Month=15, Predicted=793.3815, Expected=890.7147
# Month=16, Predicted=908.2059, Expected=899.2858
# Month=17, Predicted=894.1306, Expected=961.2990
# Month=18, Predicted=940.7235, Expected=936.1160
# Month=19, Predicted=930.9609, Expected=893.4953
# Month=20, Predicted=888.3402, Expected=854.7115
# Month=21, Predicted=849.5563, Expected=809.0508
# Month=22, Predicted=803.8956, Expected=809.7435
# Month=23, Predicted=804.5883, Expected=765.2099
# Month=24, Predicted=760.0548, Expected=805.0349
# Month=25, Predicted=799.8798, Expected=820.4588
# Month=26, Predicted=815.3036, Expected=773.2413
# Month=27, Predicted=768.0861, Expected=882.5316
# Month=28, Predicted=916.1655, Expected=898.7897
# Month=29, Predicted=893.6345, Expected=956.6009
# Month=30, Predicted=938.3777, Expected=923.8359
# Month=31, Predicted=918.6807, Expected=881.4145
# Month=32, Predicted=876.2593, Expected=836.3729
# Month=33, Predicted=831.2177, Expected=784.1159
# Month=34, Predicted=778.9607, Expected=791.6660
# Month=35, Predicted=786.5108, Expected=759.1810
# Month=36, Predicted=754.0258, Expected=802.0941
# Month=37, Predicted=794.7789, Expected=828.1324
# Month=38, Predicted=822.9772, Expected=778.3983
# Month=39, Predicted=773.2432, Expected=888.3698
# Month=40, Predicted=922.6498, Expected=901.3272
# Month=41, Predicted=896.1721, Expected=969.2659
# Month=42, Predicted=953.0097, Expected=947.1513
# Month=43, Predicted=941.9961, Expected=908.1276
# Month=44, Predicted=902.9725, Expected=867.1765
# Month=45, Predicted=862.0213, Expected=814.6535
# Month=46, Predicted=809.4984, Expected=812.1183
# Month=47, Predicted=806.9632, Expected=773.1493
# Month=48, Predicted=767.9942, Expected=812.6360
# Month=49, Predicted=807.4809, Expected=834.9506
# Month=50, Predicted=829.7954, Expected=782.2414
# Month=51, Predicted=777.0862, Expected=891.3930
# Month=52, Predicted=925.2479, Expected=903.3345
# Month=53, Predicted=898.1793, Expected=965.5034
# Month=54, Predicted=944.8301, Expected=937.4010
# Month=55, Predicted=932.2458, Expected=896.5903
# Month=56, Predicted=891.4351, Expected=857.5819
# Month=57, Predicted=852.4267, Expected=817.4908
# Month=58, Predicted=812.3357, Expected=827.2103
# Month=59, Predicted=822.0551, Expected=797.4188
# Month=60, Predicted=792.2637, Expected=843.9664
# Run 2 — RMSE: 47.934161, MSE: 2297.683787, NMSE: 0.0100445793
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=752.9989, Expected=804.1312
# Month=2, Predicted=807.0520, Expected=755.9621
# Month=3, Predicted=745.0697, Expected=859.0224
# Month=4, Predicted=862.8812, Expected=877.9865
# Month=5, Predicted=883.6614, Expected=942.0307
# Month=6, Predicted=945.0801, Expected=914.2550
# Month=7, Predicted=910.2466, Expected=868.9020
# Month=8, Predicted=858.5249, Expected=834.1536
# Month=9, Predicted=827.2601, Expected=789.9823
# Month=10, Predicted=779.9902, Expected=799.4046
# Month=11, Predicted=799.3038, Expected=763.5823
# Month=12, Predicted=756.3351, Expected=800.3831
# Month=13, Predicted=802.1606, Expected=826.4030
# Month=14, Predicted=827.7525, Expected=798.5367
# Month=15, Predicted=793.9323, Expected=890.7147
# Month=16, Predicted=894.4710, Expected=899.2858
# Month=17, Predicted=902.9617, Expected=961.2990
# Month=18, Predicted=964.2818, Expected=936.1160
# Month=19, Predicted=932.9043, Expected=893.4953
# Month=20, Predicted=884.0019, Expected=854.7115
# Month=21, Predicted=846.4824, Expected=809.0508
# Month=22, Predicted=798.5812, Expected=809.7435
# Month=23, Predicted=808.9218, Expected=765.2099
# Month=24, Predicted=755.1081, Expected=805.0349
# Month=25, Predicted=806.9841, Expected=820.4588
# Month=26, Predicted=821.1477, Expected=773.2413
# Month=27, Predicted=762.2835, Expected=882.5316
# Month=28, Predicted=886.4019, Expected=898.7897
# Month=29, Predicted=904.5742, Expected=956.6009
# Month=30, Predicted=959.4184, Expected=923.8359
# Month=31, Predicted=918.0159, Expected=881.4145
# Month=32, Predicted=871.9883, Expected=836.3729
# Month=33, Predicted=826.1068, Expected=784.1159
# Month=34, Predicted=771.5475, Expected=791.6660
# Month=35, Predicted=791.4160, Expected=759.1810
# Month=36, Predicted=753.0411, Expected=802.0941
# Month=37, Predicted=804.2104, Expected=828.1324
# Month=38, Predicted=829.6713, Expected=778.3983
# Month=39, Predicted=766.6335, Expected=888.3698
# Month=40, Predicted=892.2399, Expected=901.3272
# Month=41, Predicted=906.7616, Expected=969.2659
# Month=42, Predicted=972.4580, Expected=947.1513
# Month=43, Predicted=945.1271, Expected=908.1276
# Month=44, Predicted=899.8083, Expected=867.1765
# Month=45, Predicted=858.2341, Expected=814.6535
# Month=46, Predicted=801.9961, Expected=812.1183
# Month=47, Predicted=811.0158, Expected=773.1493
# Month=48, Predicted=764.8572, Expected=812.6360
# Month=49, Predicted=814.5662, Expected=834.9506
# Month=50, Predicted=836.1248, Expected=782.2414
# Month=51, Predicted=769.5292, Expected=891.3930
# Month=52, Predicted=895.2634, Expected=903.3345
# Month=53, Predicted=908.5852, Expected=965.5034
# Month=54, Predicted=968.4921, Expected=937.4010
# Month=55, Predicted=933.2306, Expected=896.5903
# Month=56, Predicted=887.6867, Expected=857.5819
# Month=57, Predicted=849.2770, Expected=817.4908
# Month=58, Predicted=808.8294, Expected=827.2103
# Month=59, Predicted=827.1327, Expected=797.4188
# Month=60, Predicted=792.1806, Expected=843.9664
# Run 3 — RMSE: 48.843137, MSE: 2385.652046, NMSE: 0.0098078430
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=753.1380, Expected=804.1312
# Month=2, Predicted=805.2447, Expected=755.9621
# Month=3, Predicted=740.3960, Expected=859.0224
# Month=4, Predicted=870.2399, Expected=877.9865
# Month=5, Predicted=886.3028, Expected=942.0307
# Month=6, Predicted=943.1216, Expected=914.2550
# Month=7, Predicted=909.0413, Expected=868.9020
# Month=8, Predicted=853.7971, Expected=834.1536
# Month=9, Predicted=823.2642, Expected=789.9823
# Month=10, Predicted=775.0984, Expected=799.4046
# Month=11, Predicted=802.5535, Expected=763.5823
# Month=12, Predicted=754.2495, Expected=800.3831
# Month=13, Predicted=802.7244, Expected=826.4030
# Month=14, Predicted=830.9964, Expected=798.5367
# Month=15, Predicted=793.0607, Expected=890.7147
# Month=16, Predicted=897.9101, Expected=899.2858
# Month=17, Predicted=906.1453, Expected=961.2990
# Month=18, Predicted=962.4059, Expected=936.1160
# Month=19, Predicted=932.1180, Expected=893.4953
# Month=20, Predicted=879.8293, Expected=854.7115
# Month=21, Predicted=842.0176, Expected=809.0508
# Month=22, Predicted=793.2391, Expected=809.7435
# Month=23, Predicted=811.6644, Expected=765.2099
# Month=24, Predicted=751.4642, Expected=805.0349
# Month=25, Predicted=806.4913, Expected=820.4588
# Month=26, Predicted=825.4831, Expected=773.2413
# Month=27, Predicted=758.2117, Expected=882.5316
# Month=28, Predicted=897.3028, Expected=898.7897
# Month=29, Predicted=907.7575, Expected=956.6009
# Month=30, Predicted=957.6284, Expected=923.8359
# Month=31, Predicted=916.0002, Expected=881.4145
# Month=32, Predicted=867.4977, Expected=836.3729
# Month=33, Predicted=820.6573, Expected=784.1159
# Month=34, Predicted=764.8296, Expected=791.6660
# Month=35, Predicted=794.1060, Expected=759.1810
# Month=36, Predicted=751.5245, Expected=802.0941
# Month=37, Predicted=803.7309, Expected=828.1324
# Month=38, Predicted=832.7556, Expected=778.3983
# Month=39, Predicted=762.0781, Expected=888.3698
# Month=40, Predicted=903.3482, Expected=901.3272
# Month=41, Predicted=910.2196, Expected=969.2659
# Month=42, Predicted=970.7785, Expected=947.1513
# Month=43, Predicted=944.8104, Expected=908.1276
# Month=44, Predicted=896.3663, Expected=867.1765
# Month=45, Predicted=853.6365, Expected=814.6535
# Month=46, Predicted=795.4693, Expected=812.1183
# Month=47, Predicted=812.9364, Expected=773.1493
# Month=48, Predicted=762.1275, Expected=812.6360
# Month=49, Predicted=814.4474, Expected=834.9506
# Month=50, Predicted=839.8080, Expected=782.2414
# Month=51, Predicted=764.5256, Expected=891.3930
# Month=52, Predicted=905.6328, Expected=903.3345
# Month=53, Predicted=912.0590, Expected=965.5034
# Month=54, Predicted=966.6044, Expected=937.4010
# Month=55, Predicted=931.9791, Expected=896.5903
# Month=56, Predicted=883.6873, Expected=857.5819
# Month=57, Predicted=844.8859, Expected=817.4908
# Month=58, Predicted=804.3632, Expected=827.2103
# Month=59, Predicted=830.6203, Expected=797.4188
# Month=60, Predicted=791.1107, Expected=843.9664
# Run 4 — RMSE: 49.340422, MSE: 2434.477228, NMSE: 0.0096433349
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=751.2252, Expected=804.1312
# Month=2, Predicted=806.2595, Expected=755.9621
# Month=3, Predicted=744.0262, Expected=859.0224
# Month=4, Predicted=866.6115, Expected=877.9865
# Month=5, Predicted=881.9791, Expected=942.0307
# Month=6, Predicted=945.1740, Expected=914.2550
# Month=7, Predicted=907.7994, Expected=868.9020
# Month=8, Predicted=856.7658, Expected=834.1536
# Month=9, Predicted=824.4116, Expected=789.9823
# Month=10, Predicted=778.0756, Expected=799.4046
# Month=11, Predicted=795.8075, Expected=763.5823
# Month=12, Predicted=753.5329, Expected=800.3831
# Month=13, Predicted=800.2229, Expected=826.4030
# Month=14, Predicted=825.0120, Expected=798.5367
# Month=15, Predicted=790.4122, Expected=890.7147
# Month=16, Predicted=897.4755, Expected=899.2858
# Month=17, Predicted=900.3218, Expected=961.2990
# Month=18, Predicted=964.1900, Expected=936.1160
# Month=19, Predicted=929.8128, Expected=893.4953
# Month=20, Predicted=881.9714, Expected=854.7115
# Month=21, Predicted=844.0029, Expected=809.0508
# Month=22, Predicted=796.7934, Expected=809.7435
# Month=23, Predicted=805.0760, Expected=765.2099
# Month=24, Predicted=753.1086, Expected=805.0349
# Month=25, Predicted=805.2216, Expected=820.4588
# Month=26, Predicted=817.8513, Expected=773.2413
# Month=27, Predicted=760.5313, Expected=882.5316
# Month=28, Predicted=890.5911, Expected=898.7897
# Month=29, Predicted=903.4404, Expected=956.6009
# Month=30, Predicted=958.9353, Expected=923.8359
# Month=31, Predicted=915.8911, Expected=881.4145
# Month=32, Predicted=869.9271, Expected=836.3729
# Month=33, Predicted=824.2255, Expected=784.1159
# Month=34, Predicted=770.4284, Expected=791.6660
# Month=35, Predicted=787.7758, Expected=759.1810
# Month=36, Predicted=749.9870, Expected=802.0941
# Month=37, Predicted=802.7154, Expected=828.1324
# Month=38, Predicted=826.9671, Expected=778.3983
# Month=39, Predicted=765.2144, Expected=888.3698
# Month=40, Predicted=896.4681, Expected=901.3272
# Month=41, Predicted=905.6595, Expected=969.2659
# Month=42, Predicted=972.9237, Expected=947.1513
# Month=43, Predicted=941.6860, Expected=908.1276
# Month=44, Predicted=897.4501, Expected=867.1765
# Month=45, Predicted=855.9820, Expected=814.6535
# Month=46, Predicted=800.9434, Expected=812.1183
# Month=47, Predicted=807.0034, Expected=773.1493
# Month=48, Predicted=762.3623, Expected=812.6360
# Month=49, Predicted=812.8089, Expected=834.9506
# Month=50, Predicted=833.1866, Expected=782.2414
# Month=51, Predicted=768.4060, Expected=891.3930
# Month=52, Predicted=899.4044, Expected=903.3345
# Month=53, Predicted=907.3967, Expected=965.5034
# Month=54, Predicted=968.4090, Expected=937.4010
# Month=55, Predicted=930.7648, Expected=896.5903
# Month=56, Predicted=885.4884, Expected=857.5819
# Month=57, Predicted=846.8352, Expected=817.4908
# Month=58, Predicted=806.5011, Expected=827.2103
# Month=59, Predicted=823.6705, Expected=797.4188
# Month=60, Predicted=788.9416, Expected=843.9664
# Run 5 — RMSE: 48.810544, MSE: 2382.469251, NMSE: 0.0095561373
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=743.9490, Expected=804.1312
# Month=2, Predicted=796.9913, Expected=755.9621
# Month=3, Predicted=748.8222, Expected=859.0224
# Month=4, Predicted=885.0569, Expected=877.9865
# Month=5, Predicted=870.8466, Expected=942.0307
# Month=6, Predicted=934.8908, Expected=914.2550
# Month=7, Predicted=907.1151, Expected=868.9020
# Month=8, Predicted=861.7621, Expected=834.1536
# Month=9, Predicted=827.0137, Expected=789.9823
# Month=10, Predicted=782.8424, Expected=799.4046
# Month=11, Predicted=792.2647, Expected=763.5823
# Month=12, Predicted=756.4424, Expected=800.3831
# Month=13, Predicted=793.2432, Expected=826.4030
# Month=14, Predicted=819.2631, Expected=798.5367
# Month=15, Predicted=791.3968, Expected=890.7147
# Month=16, Predicted=908.9631, Expected=899.2858
# Month=17, Predicted=892.1459, Expected=961.2990
# Month=18, Predicted=954.1591, Expected=936.1160
# Month=19, Predicted=928.9761, Expected=893.4953
# Month=20, Predicted=886.3554, Expected=854.7115
# Month=21, Predicted=847.5716, Expected=809.0508
# Month=22, Predicted=801.9109, Expected=809.7435
# Month=23, Predicted=802.6036, Expected=765.2099
# Month=24, Predicted=758.0700, Expected=805.0349
# Month=25, Predicted=797.8950, Expected=820.4588
# Month=26, Predicted=813.3189, Expected=773.2413
# Month=27, Predicted=766.1014, Expected=882.5316
# Month=28, Predicted=912.4344, Expected=898.7897
# Month=29, Predicted=891.6498, Expected=956.6009
# Month=30, Predicted=949.4610, Expected=923.8359
# Month=31, Predicted=916.6960, Expected=881.4145
# Month=32, Predicted=874.2746, Expected=836.3729
# Month=33, Predicted=829.2330, Expected=784.1159
# Month=34, Predicted=776.9760, Expected=791.6660
# Month=35, Predicted=784.5261, Expected=759.1810
# Month=36, Predicted=752.0411, Expected=802.0941
# Month=37, Predicted=794.9542, Expected=828.1324
# Month=38, Predicted=820.9925, Expected=778.3983
# Month=39, Predicted=771.2584, Expected=888.3698
# Month=40, Predicted=918.6884, Expected=901.3272
# Month=41, Predicted=894.1873, Expected=969.2659
# Month=42, Predicted=964.6247, Expected=947.1513
# Month=43, Predicted=940.0114, Expected=908.1276
# Month=44, Predicted=900.9877, Expected=867.1765
# Month=45, Predicted=860.0366, Expected=814.6535
# Month=46, Predicted=807.5136, Expected=812.1183
# Month=47, Predicted=804.9784, Expected=773.1493
# Month=48, Predicted=766.0094, Expected=812.6360
# Month=49, Predicted=805.4961, Expected=834.9506
# Month=50, Predicted=827.8107, Expected=782.2414
# Month=51, Predicted=775.1015, Expected=891.3930
# Month=52, Predicted=921.2400, Expected=903.3345
# Month=53, Predicted=896.1946, Expected=965.5034
# Month=54, Predicted=958.3635, Expected=937.4010
# Month=55, Predicted=930.2611, Expected=896.5903
# Month=56, Predicted=889.4504, Expected=857.5819
# Month=57, Predicted=850.4420, Expected=817.4908
# Month=58, Predicted=810.3509, Expected=827.2103
# Month=59, Predicted=820.0704, Expected=797.4188
# Month=60, Predicted=790.2789, Expected=843.9664
# Run 6 — RMSE: 48.593353, MSE: 2361.313908, NMSE: 0.0097495975
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=750.8503, Expected=804.1312
# Month=2, Predicted=806.5650, Expected=755.9621
# Month=3, Predicted=747.5932, Expected=859.0224
# Month=4, Predicted=864.1629, Expected=877.9865
# Month=5, Predicted=877.1622, Expected=942.0307
# Month=6, Predicted=945.6839, Expected=914.2550
# Month=7, Predicted=907.8870, Expected=868.9020
# Month=8, Predicted=859.9955, Expected=834.1536
# Month=9, Predicted=825.6433, Expected=789.9823
# Month=10, Predicted=780.9768, Expected=799.4046
# Month=11, Predicted=795.4408, Expected=763.5823
# Month=12, Predicted=756.0609, Expected=800.3831
# Month=13, Predicted=799.8512, Expected=826.4030
# Month=14, Predicted=825.5962, Expected=798.5367
# Month=15, Predicted=791.8144, Expected=890.7147
# Month=16, Predicted=896.0233, Expected=899.2858
# Month=17, Predicted=897.1322, Expected=961.2990
# Month=18, Predicted=964.6809, Expected=936.1160
# Month=19, Predicted=929.9807, Expected=893.4953
# Month=20, Predicted=884.8889, Expected=854.7115
# Month=21, Predicted=845.9338, Expected=809.0508
# Month=22, Predicted=799.8016, Expected=809.7435
# Month=23, Predicted=804.7680, Expected=765.2099
# Month=24, Predicted=756.8527, Expected=805.0349
# Month=25, Predicted=804.5479, Expected=820.4588
# Month=26, Predicted=818.4527, Expected=773.2413
# Month=27, Predicted=764.7219, Expected=882.5316
# Month=28, Predicted=887.9484, Expected=898.7897
# Month=29, Predicted=897.7411, Expected=956.6009
# Month=30, Predicted=959.4897, Expected=923.8359
# Month=31, Predicted=916.9100, Expected=881.4145
# Month=32, Predicted=872.6210, Expected=836.3729
# Month=33, Predicted=827.0617, Expected=784.1159
# Month=34, Predicted=774.1301, Expected=791.6660
# Month=35, Predicted=787.1689, Expected=759.1810
# Month=36, Predicted=751.9632, Expected=802.0941
# Month=37, Predicted=802.3980, Expected=828.1324
# Month=38, Predicted=827.3806, Expected=778.3983
# Month=39, Predicted=769.6941, Expected=888.3698
# Month=40, Predicted=893.7264, Expected=901.3272
# Month=41, Predicted=899.9057, Expected=969.2659
# Month=42, Predicted=973.3947, Expected=947.1513
# Month=43, Predicted=941.3919, Expected=908.1276
# Month=44, Predicted=899.9110, Expected=867.1765
# Month=45, Predicted=858.3240, Expected=814.6535
# Month=46, Predicted=804.7794, Expected=812.1183
# Month=47, Predicted=806.5202, Expected=773.1493
# Month=48, Predicted=765.2546, Expected=812.6360
# Month=49, Predicted=812.3145, Expected=834.9506
# Month=50, Predicted=833.7348, Expected=782.2414
# Month=51, Predicted=773.2757, Expected=891.3930
# Month=52, Predicted=896.6093, Expected=903.3345
# Month=53, Predicted=901.7819, Expected=965.5034
# Month=54, Predicted=968.9180, Expected=937.4010
# Month=55, Predicted=930.9796, Expected=896.5903
# Month=56, Predicted=888.0682, Expected=857.5819
# Month=57, Predicted=848.8432, Expected=817.4908
# Month=58, Predicted=808.7130, Expected=827.2103
# Month=59, Predicted=823.4265, Expected=797.4188
# Month=60, Predicted=790.4677, Expected=843.9664
# Run 7 — RMSE: 48.678098, MSE: 2369.557177, NMSE: 0.0098600374
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=753.1952, Expected=804.1312
# Month=2, Predicted=807.4293, Expected=755.9621
# Month=3, Predicted=746.7863, Expected=859.0224
# Month=4, Predicted=862.4444, Expected=877.9865
# Month=5, Predicted=881.3599, Expected=942.0307
# Month=6, Predicted=945.5410, Expected=914.2550
# Month=7, Predicted=908.7155, Expected=868.9020
# Month=8, Predicted=859.1380, Expected=834.1536
# Month=9, Predicted=825.3074, Expected=789.9823
# Month=10, Predicted=780.1267, Expected=799.4046
# Month=11, Predicted=797.9754, Expected=763.5823
# Month=12, Predicted=756.2208, Expected=800.3831
# Month=13, Predicted=802.4075, Expected=826.4030
# Month=14, Predicted=828.9508, Expected=798.5367
# Month=15, Predicted=792.5638, Expected=890.7147
# Month=16, Predicted=894.4733, Expected=899.2858
# Month=17, Predicted=900.7784, Expected=961.2990
# Month=18, Predicted=964.7498, Expected=936.1160
# Month=19, Predicted=930.9813, Expected=893.4953
# Month=20, Predicted=884.2791, Expected=854.7115
# Month=21, Predicted=845.3497, Expected=809.0508
# Month=22, Predicted=798.7642, Expected=809.7435
# Month=23, Predicted=806.7821, Expected=765.2099
# Month=24, Predicted=756.3121, Expected=805.0349
# Month=25, Predicted=806.8550, Expected=820.4588
# Month=26, Predicted=821.9005, Expected=773.2413
# Month=27, Predicted=763.9783, Expected=882.5316
# Month=28, Predicted=886.1583, Expected=898.7897
# Month=29, Predicted=902.2657, Expected=956.6009
# Month=30, Predicted=959.9465, Expected=923.8359
# Month=31, Predicted=917.3312, Expected=881.4145
# Month=32, Predicted=871.9267, Expected=836.3729
# Month=33, Predicted=826.0034, Expected=784.1159
# Month=34, Predicted=772.4609, Expected=791.6660
# Month=35, Predicted=789.4201, Expected=759.1810
# Month=36, Predicted=752.3754, Expected=802.0941
# Month=37, Predicted=804.3853, Expected=828.1324
# Month=38, Predicted=830.7124, Expected=778.3983
# Month=39, Predicted=768.7447, Expected=888.3698
# Month=40, Predicted=891.9215, Expected=901.3272
# Month=41, Predicted=904.3496, Expected=969.2659
# Month=42, Predicted=972.8862, Expected=947.1513
# Month=43, Predicted=942.6650, Expected=908.1276
# Month=44, Predicted=899.6170, Expected=867.1765
# Month=45, Predicted=857.6425, Expected=814.6535
# Month=46, Predicted=803.1618, Expected=812.1183
# Month=47, Predicted=808.1883, Expected=773.1493
# Month=48, Predicted=765.1392, Expected=812.6360
# Month=49, Predicted=814.6362, Expected=834.9506
# Month=50, Predicted=837.4100, Expected=782.2414
# Month=51, Predicted=772.0771, Expected=891.3930
# Month=52, Predicted=894.8076, Expected=903.3345
# Month=53, Predicted=906.1445, Expected=965.5034
# Month=54, Predicted=968.9661, Expected=937.4010
# Month=55, Predicted=931.7692, Expected=896.5903
# Month=56, Predicted=887.5619, Expected=857.5819
# Month=57, Predicted=848.2777, Expected=817.4908
# Month=58, Predicted=808.1017, Expected=827.2103
# Month=59, Predicted=826.0660, Expected=797.4188
# Month=60, Predicted=791.0817, Expected=843.9664
# Run 8 — RMSE: 48.620248, MSE: 2363.928526, NMSE: 0.0098330115
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=752.8421, Expected=804.1312
# Month=2, Predicted=806.7484, Expected=755.9621
# Month=3, Predicted=744.8014, Expected=859.0224
# Month=4, Predicted=866.6143, Expected=877.9865
# Month=5, Predicted=884.8069, Expected=942.0307
# Month=6, Predicted=944.9363, Expected=914.2550
# Month=7, Predicted=909.2736, Expected=868.9020
# Month=8, Predicted=857.1555, Expected=834.1536
# Month=9, Predicted=824.6434, Expected=789.9823
# Month=10, Predicted=778.3486, Expected=799.4046
# Month=11, Predicted=799.1046, Expected=763.5823
# Month=12, Predicted=754.8366, Expected=800.3831
# Month=13, Predicted=802.1335, Expected=826.4030
# Month=14, Predicted=828.9071, Expected=798.5367
# Month=15, Predicted=792.0520, Expected=890.7147
# Month=16, Predicted=897.0151, Expected=899.2858
# Month=17, Predicted=903.8429, Expected=961.2990
# Month=18, Predicted=964.0050, Expected=936.1160
# Month=19, Predicted=931.7121, Expected=893.4953
# Month=20, Predicted=882.5484, Expected=854.7115
# Month=21, Predicted=844.2323, Expected=809.0508
# Month=22, Predicted=796.8761, Expected=809.7435
# Month=23, Predicted=808.0805, Expected=765.2099
# Month=24, Predicted=754.0762, Expected=805.0349
# Month=25, Predicted=806.4485, Expected=820.4588
# Month=26, Predicted=822.2645, Expected=773.2413
# Month=27, Predicted=761.4324, Expected=882.5316
# Month=28, Predicted=891.2300, Expected=898.7897
# Month=29, Predicted=906.1146, Expected=956.6009
# Month=30, Predicted=959.0294, Expected=923.8359
# Month=31, Predicted=917.1139, Expected=881.4145
# Month=32, Predicted=870.3146, Expected=836.3729
# Month=33, Predicted=824.2218, Expected=784.1159
# Month=34, Predicted=769.9324, Expected=791.6660
# Month=35, Predicted=790.7292, Expected=759.1810
# Month=36, Predicted=751.3335, Expected=802.0941
# Month=37, Predicted=803.8836, Expected=828.1324
# Month=38, Predicted=830.8247, Expected=778.3983
# Month=39, Predicted=766.0007, Expected=888.3698
# Month=40, Predicted=897.1115, Expected=901.3272
# Month=41, Predicted=908.4030, Expected=969.2659
# Month=42, Predicted=972.6184, Expected=947.1513
# Month=43, Predicted=943.9817, Expected=908.1276
# Month=44, Predicted=898.2189, Expected=867.1765
# Month=45, Predicted=856.2565, Expected=814.6535
# Month=46, Predicted=800.5660, Expected=812.1183
# Month=47, Predicted=809.5722, Expected=773.1493
# Month=48, Predicted=763.5020, Expected=812.6360
# Month=49, Predicted=814.2624, Expected=834.9506
# Month=50, Predicted=837.3264, Expected=782.2414
# Month=51, Predicted=768.9962, Expected=891.3930
# Month=52, Predicted=899.8920, Expected=903.3345
# Month=53, Predicted=910.1951, Expected=965.5034
# Month=54, Predicted=968.2276, Expected=937.4010
# Month=55, Predicted=932.2105, Expected=896.5903
# Month=56, Predicted=886.0583, Expected=857.5819
# Month=57, Predicted=847.1158, Expected=817.4908
# Month=58, Predicted=806.8036, Expected=827.2103
# Month=59, Predicted=827.1168, Expected=797.4188
# Month=60, Predicted=790.3082, Expected=843.9664
# Run 9 — RMSE: 48.728527, MSE: 2374.469295, NMSE: 0.0095970702
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=764.1088, Expected=804.1312
# Month=2, Predicted=787.2901, Expected=755.9621
# Month=3, Predicted=744.2255, Expected=859.0224
# Month=4, Predicted=878.3403, Expected=877.9865
# Month=5, Predicted=893.8104, Expected=942.0307
# Month=6, Predicted=925.4843, Expected=914.2550
# Month=7, Predicted=909.7028, Expected=868.9020
# Month=8, Predicted=857.4064, Expected=834.1536
# Month=9, Predicted=825.2597, Expected=789.9823
# Month=10, Predicted=778.5745, Expected=799.4046
# Month=11, Predicted=804.3356, Expected=763.5823
# Month=12, Predicted=755.0579, Expected=800.3831
# Month=13, Predicted=813.0102, Expected=826.4030
# Month=14, Predicted=836.9363, Expected=798.5367
# Month=15, Predicted=792.4248, Expected=890.7147
# Month=16, Predicted=908.4339, Expected=899.2858
# Month=17, Predicted=910.1599, Expected=961.2990
# Month=18, Predicted=943.4915, Expected=936.1160
# Month=19, Predicted=932.3177, Expected=893.4953
# Month=20, Predicted=882.8845, Expected=854.7115
# Month=21, Predicted=844.6922, Expected=809.0508
# Month=22, Predicted=797.0535, Expected=809.7435
# Month=23, Predicted=811.9550, Expected=765.2099
# Month=24, Predicted=754.0925, Expected=805.0349
# Month=25, Predicted=815.6121, Expected=820.4588
# Month=26, Predicted=828.2639, Expected=773.2413
# Month=27, Predicted=761.1486, Expected=882.5316
# Month=28, Predicted=901.3253, Expected=898.7897
# Month=29, Predicted=914.5745, Expected=956.6009
# Month=30, Predicted=936.9895, Expected=923.8359
# Month=31, Predicted=917.2523, Expected=881.4145
# Month=32, Predicted=870.6805, Expected=836.3729
# Month=33, Predicted=824.4392, Expected=784.1159
# Month=34, Predicted=769.8751, Expected=791.6660
# Month=35, Predicted=795.5355, Expected=759.1810
# Month=36, Predicted=751.7151, Expected=802.0941
# Month=37, Predicted=804.2984, Expected=828.1324
# Month=38, Predicted=839.0982, Expected=778.3983
# Month=39, Predicted=765.5468, Expected=888.3698
# Month=40, Predicted=907.0029, Expected=901.3272
# Month=41, Predicted=916.0509, Expected=969.2659
# Month=42, Predicted=956.9636, Expected=947.1513
# Month=43, Predicted=944.8067, Expected=908.1276
# Month=44, Predicted=898.6954, Expected=867.1765
# Month=45, Predicted=856.6359, Expected=814.6535
# Month=46, Predicted=800.5066, Expected=812.1183
# Month=47, Predicted=812.9226, Expected=773.1493
# Month=48, Predicted=763.7558, Expected=812.6360
# Month=49, Predicted=824.5231, Expected=834.9506
# Month=50, Predicted=844.6661, Expected=782.2414
# Month=51, Predicted=768.4586, Expected=891.3930
# Month=52, Predicted=909.9275, Expected=903.3345
# Month=53, Predicted=917.5764, Expected=965.5034
# Month=54, Predicted=947.6967, Expected=937.4010
# Month=55, Predicted=932.6237, Expected=896.5903
# Month=56, Predicted=886.4823, Expected=857.5819
# Month=57, Predicted=847.5674, Expected=817.4908
# Month=58, Predicted=807.1935, Expected=827.2103
# Month=59, Predicted=832.4250, Expected=797.4188
# Month=60, Predicted=790.7675, Expected=843.9664
# Run 10 — RMSE: 47.628762, MSE: 2268.498985, NMSE: 0.0097799913
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=760.2026, Expected=804.1312
# Month=2, Predicted=789.2905, Expected=755.9621
# Month=3, Predicted=744.4926, Expected=859.0224
# Month=4, Predicted=878.1068, Expected=877.9865
# Month=5, Predicted=887.2961, Expected=942.0307
# Month=6, Predicted=926.8649, Expected=914.2550
# Month=7, Predicted=907.8505, Expected=868.9020
# Month=8, Predicted=857.2955, Expected=834.1536
# Month=9, Predicted=824.0638, Expected=789.9823
# Month=10, Predicted=778.3597, Expected=799.4046
# Month=11, Predicted=800.7948, Expected=763.5823
# Month=12, Predicted=754.6371, Expected=800.3831
# Month=13, Predicted=809.5337, Expected=826.4030
# Month=14, Predicted=834.2618, Expected=798.5367
# Month=15, Predicted=791.4041, Expected=890.7147
# Month=16, Predicted=908.9549, Expected=899.2858
# Month=17, Predicted=904.5080, Expected=961.2990
# Month=18, Predicted=944.9287, Expected=936.1160
# Month=19, Predicted=930.2882, Expected=893.4953
# Month=20, Predicted=882.5691, Expected=854.7115
# Month=21, Predicted=843.8752, Expected=809.0508
# Month=22, Predicted=796.9245, Expected=809.7435
# Month=23, Predicted=808.5845, Expected=765.2099
# Month=24, Predicted=754.2936, Expected=805.0349
# Month=25, Predicted=812.1703, Expected=820.4588
# Month=26, Predicted=825.2132, Expected=773.2413
# Month=27, Predicted=761.6994, Expected=882.5316
# Month=28, Predicted=902.5943, Expected=898.7897
# Month=29, Predicted=907.9248, Expected=956.6009
# Month=30, Predicted=939.3288, Expected=923.8359
# Month=31, Predicted=916.0029, Expected=881.4145
# Month=32, Predicted=870.2549, Expected=836.3729
# Month=33, Predicted=824.1926, Expected=784.1159
# Month=34, Predicted=770.3151, Expected=791.6660
# Month=35, Predicted=791.8867, Expected=759.1810
# Month=36, Predicted=751.0312, Expected=802.0941
# Month=37, Predicted=803.0990, Expected=828.1324
# Month=38, Predicted=836.0993, Expected=778.3983
# Month=39, Predicted=766.2745, Expected=888.3698
# Month=40, Predicted=908.4045, Expected=901.3272
# Month=41, Predicted=909.5324, Expected=969.2659
# Month=42, Predicted=957.6751, Expected=947.1513
# Month=43, Predicted=942.3379, Expected=908.1276
# Month=44, Predicted=898.0977, Expected=867.1765
# Month=45, Predicted=856.0523, Expected=814.6535
# Month=46, Predicted=801.0097, Expected=812.1183
# Month=47, Predicted=809.5441, Expected=773.1493
# Month=48, Predicted=763.4661, Expected=812.6360
# Month=49, Predicted=820.7946, Expected=834.9506
# Month=50, Predicted=841.7393, Expected=782.2414
# Month=51, Predicted=769.4946, Expected=891.3930
# Month=52, Predicted=911.1423, Expected=903.3345
# Month=53, Predicted=911.1406, Expected=965.5034
# Month=54, Predicted=949.2028, Expected=937.4010
# Month=55, Predicted=930.8478, Expected=896.5903
# Month=56, Predicted=885.9662, Expected=857.5819
# Month=57, Predicted=846.7943, Expected=817.4908
# Month=58, Predicted=806.5576, Expected=827.2103
# Month=59, Predicted=828.9667, Expected=797.4188
# Month=60, Predicted=789.9092, Expected=843.9664
# Run 11 — RMSE: 47.704378, MSE: 2275.707710, NMSE: 0.0098222632
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=753.1410, Expected=804.1312
# Month=2, Predicted=806.3748, Expected=755.9621
# Month=3, Predicted=741.7118, Expected=859.0224
# Month=4, Predicted=863.9443, Expected=877.9865
# Month=5, Predicted=880.0003, Expected=942.0307
# Month=6, Predicted=944.7068, Expected=914.2550
# Month=7, Predicted=907.4793, Expected=868.9020
# Month=8, Predicted=855.2988, Expected=834.1536
# Month=9, Predicted=823.5789, Expected=789.9823
# Month=10, Predicted=776.5078, Expected=799.4046
# Month=11, Predicted=798.6948, Expected=763.5823
# Month=12, Predicted=754.4908, Expected=800.3831
# Month=13, Predicted=802.6027, Expected=826.4030
# Month=14, Predicted=829.1028, Expected=798.5367
# Month=15, Predicted=791.9274, Expected=890.7147
# Month=16, Predicted=895.1694, Expected=899.2858
# Month=17, Predicted=899.8469, Expected=961.2990
# Month=18, Predicted=963.9649, Expected=936.1160
# Month=19, Predicted=930.0937, Expected=893.4953
# Month=20, Predicted=881.1454, Expected=854.7115
# Month=21, Predicted=842.8623, Expected=809.0508
# Month=22, Predicted=794.6544, Expected=809.7435
# Month=23, Predicted=807.6811, Expected=765.2099
# Month=24, Predicted=752.8069, Expected=805.0349
# Month=25, Predicted=806.6048, Expected=820.4588
# Month=26, Predicted=821.8750, Expected=773.2413
# Month=27, Predicted=759.6325, Expected=882.5316
# Month=28, Predicted=888.1683, Expected=898.7897
# Month=29, Predicted=900.5505, Expected=956.6009
# Month=30, Predicted=959.0702, Expected=923.8359
# Month=31, Predicted=915.5235, Expected=881.4145
# Month=32, Predicted=868.7666, Expected=836.3729
# Month=33, Predicted=822.0272, Expected=784.1159
# Month=34, Predicted=766.0883, Expected=791.6660
# Month=35, Predicted=790.1976, Expected=759.1810
# Month=36, Predicted=751.2203, Expected=802.0941
# Month=37, Predicted=804.0174, Expected=828.1324
# Month=38, Predicted=830.8053, Expected=778.3983
# Month=39, Predicted=763.5371, Expected=888.3698
# Month=40, Predicted=893.9965, Expected=901.3272
# Month=41, Predicted=902.6830, Expected=969.2659
# Month=42, Predicted=972.2145, Expected=947.1513
# Month=43, Predicted=941.9427, Expected=908.1276
# Month=44, Predicted=897.2853, Expected=867.1765
# Month=45, Predicted=854.7342, Expected=814.6535
# Month=46, Predicted=796.7860, Expected=812.1183
# Month=47, Predicted=809.0964, Expected=773.1493
# Month=48, Predicted=762.8537, Expected=812.6360
# Month=49, Predicted=814.4970, Expected=834.9506
# Month=50, Predicted=837.2035, Expected=782.2414
# Month=51, Predicted=765.9079, Expected=891.3930
# Month=52, Predicted=896.8213, Expected=903.3345
# Month=53, Predicted=904.5490, Expected=965.5034
# Month=54, Predicted=968.1593, Expected=937.4010
# Month=55, Predicted=930.5341, Expected=896.5903
# Month=56, Predicted=884.8074, Expected=857.5819
# Month=57, Predicted=845.7639, Expected=817.4908
# Month=58, Predicted=805.3689, Expected=827.2103
# Month=59, Predicted=826.7621, Expected=797.4188
# Month=60, Predicted=790.3170, Expected=843.9664
# Run 12 — RMSE: 49.509402, MSE: 2451.180925, NMSE: 0.0099529727
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=752.6085, Expected=804.1312
# Month=2, Predicted=804.5700, Expected=755.9621
# Month=3, Predicted=741.1770, Expected=859.0224
# Month=4, Predicted=870.8840, Expected=877.9865
# Month=5, Predicted=885.8562, Expected=942.0307
# Month=6, Predicted=942.8487, Expected=914.2550
# Month=7, Predicted=909.7815, Expected=868.9020
# Month=8, Predicted=854.7604, Expected=834.1536
# Month=9, Predicted=824.8218, Expected=789.9823
# Month=10, Predicted=776.2511, Expected=799.4046
# Month=11, Predicted=801.1745, Expected=763.5823
# Month=12, Predicted=754.7539, Expected=800.3831
# Month=13, Predicted=802.2013, Expected=826.4030
# Month=14, Predicted=829.9369, Expected=798.5367
# Month=15, Predicted=793.3834, Expected=890.7147
# Month=16, Predicted=898.0101, Expected=899.2858
# Month=17, Predicted=904.2531, Expected=961.2990
# Month=18, Predicted=962.0258, Expected=936.1160
# Month=19, Predicted=932.1461, Expected=893.4953
# Month=20, Predicted=880.7822, Expected=854.7115
# Month=21, Predicted=843.4455, Expected=809.0508
# Month=22, Predicted=794.4610, Expected=809.7435
# Month=23, Predicted=809.8642, Expected=765.2099
# Month=24, Predicted=751.9272, Expected=805.0349
# Month=25, Predicted=806.3404, Expected=820.4588
# Month=26, Predicted=823.9597, Expected=773.2413
# Month=27, Predicted=758.7057, Expected=882.5316
# Month=28, Predicted=897.7465, Expected=898.7897
# Month=29, Predicted=906.9130, Expected=956.6009
# Month=30, Predicted=957.0922, Expected=923.8359
# Month=31, Predicted=916.9522, Expected=881.4145
# Month=32, Predicted=868.6141, Expected=836.3729
# Month=33, Predicted=821.9795, Expected=784.1159
# Month=34, Predicted=765.9863, Expected=791.6660
# Month=35, Predicted=792.8714, Expected=759.1810
# Month=36, Predicted=752.0139, Expected=802.0941
# Month=37, Predicted=803.2079, Expected=828.1324
# Month=38, Predicted=831.7285, Expected=778.3983
# Month=39, Predicted=762.5875, Expected=888.3698
# Month=40, Predicted=903.9365, Expected=901.3272
# Month=41, Predicted=908.9626, Expected=969.2659
# Month=42, Predicted=970.5533, Expected=947.1513
# Month=43, Predicted=944.1554, Expected=908.1276
# Month=44, Predicted=897.2920, Expected=867.1765
# Month=45, Predicted=854.9343, Expected=814.6535
# Month=46, Predicted=796.5158, Expected=812.1183
# Month=47, Predicted=811.4197, Expected=773.1493
# Month=48, Predicted=762.6417, Expected=812.6360
# Month=49, Predicted=814.0635, Expected=834.9506
# Month=50, Predicted=839.0560, Expected=782.2414
# Month=51, Predicted=764.9073, Expected=891.3930
# Month=52, Predicted=906.4410, Expected=903.3345
# Month=53, Predicted=910.6952, Expected=965.5034
# Month=54, Predicted=966.2216, Expected=937.4010
# Month=55, Predicted=932.7704, Expected=896.5903
# Month=56, Predicted=884.7187, Expected=857.5819
# Month=57, Predicted=846.2608, Expected=817.4908
# Month=58, Predicted=805.6817, Expected=827.2103
# Month=59, Predicted=829.1373, Expected=797.4188
# Month=60, Predicted=791.5958, Expected=843.9664
# Run 13 — RMSE: 49.239215, MSE: 2424.500247, NMSE: 0.0096446349
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=753.5459, Expected=804.1312
# Month=2, Predicted=805.4960, Expected=755.9621
# Month=3, Predicted=741.7240, Expected=859.0224
# Month=4, Predicted=869.4161, Expected=877.9865
# Month=5, Predicted=884.7082, Expected=942.0307
# Month=6, Predicted=942.2180, Expected=914.2550
# Month=7, Predicted=909.2921, Expected=868.9020
# Month=8, Predicted=854.6955, Expected=834.1536
# Month=9, Predicted=823.7671, Expected=789.9823
# Month=10, Predicted=775.9893, Expected=799.4046
# Month=11, Predicted=801.3199, Expected=763.5823
# Month=12, Predicted=754.9080, Expected=800.3831
# Month=13, Predicted=803.0515, Expected=826.4030
# Month=14, Predicted=830.8620, Expected=798.5367
# Month=15, Predicted=793.2347, Expected=890.7147
# Month=16, Predicted=898.1070, Expected=899.2858
# Month=17, Predicted=904.4644, Expected=961.2990
# Month=18, Predicted=961.2177, Expected=936.1160
# Month=19, Predicted=932.1093, Expected=893.4953
# Month=20, Predicted=880.7006, Expected=854.7115
# Month=21, Predicted=842.7323, Expected=809.0508
# Month=22, Predicted=794.1289, Expected=809.7435
# Month=23, Predicted=810.2465, Expected=765.2099
# Month=24, Predicted=752.3929, Expected=805.0349
# Month=25, Predicted=807.0355, Expected=820.4588
# Month=26, Predicted=824.7618, Expected=773.2413
# Month=27, Predicted=759.3157, Expected=882.5316
# Month=28, Predicted=894.4690, Expected=898.7897
# Month=29, Predicted=905.7653, Expected=956.6009
# Month=30, Predicted=956.9892, Expected=923.8359
# Month=31, Predicted=916.7432, Expected=881.4145
# Month=32, Predicted=868.3357, Expected=836.3729
# Month=33, Predicted=821.5295, Expected=784.1159
# Month=34, Predicted=765.6377, Expected=791.6660
# Month=35, Predicted=792.8569, Expected=759.1810
# Month=36, Predicted=751.9147, Expected=802.0941
# Month=37, Predicted=804.1944, Expected=828.1324
# Month=38, Predicted=832.6515, Expected=778.3983
# Month=39, Predicted=763.2475, Expected=888.3698
# Month=40, Predicted=900.3683, Expected=901.3272
# Month=41, Predicted=908.0578, Expected=969.2659
# Month=42, Predicted=970.0724, Expected=947.1513
# Month=43, Predicted=944.3680, Expected=908.1276
# Month=44, Predicted=897.1240, Expected=867.1765
# Month=45, Predicted=854.4325, Expected=814.6535
# Month=46, Predicted=796.2808, Expected=812.1183
# Month=47, Predicted=811.5545, Expected=773.1493
# Month=48, Predicted=762.8556, Expected=812.6360
# Month=49, Predicted=814.9087, Expected=834.9506
# Month=50, Predicted=839.4689, Expected=782.2414
# Month=51, Predicted=765.6017, Expected=891.3930
# Month=52, Predicted=903.0357, Expected=903.3345
# Month=53, Predicted=909.8998, Expected=965.5034
# Month=54, Predicted=965.4564, Expected=937.4010
# Month=55, Predicted=932.2780, Expected=896.5903
# Month=56, Predicted=884.4933, Expected=857.5819
# Month=57, Predicted=845.6127, Expected=817.4908
# Month=58, Predicted=805.1432, Expected=827.2103
# Month=59, Predicted=829.3857, Expected=797.4188
# Month=60, Predicted=791.2871, Expected=843.9664
# Run 14 — RMSE: 49.169244, MSE: 2417.614584, NMSE: 0.0097435312
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=749.9083, Expected=804.1312
# Month=2, Predicted=797.4562, Expected=755.9621
# Month=3, Predicted=741.0406, Expected=859.0224
# Month=4, Predicted=876.1137, Expected=877.9865
# Month=5, Predicted=891.4300, Expected=942.0307
# Month=6, Predicted=935.5835, Expected=914.2550
# Month=7, Predicted=907.6745, Expected=868.9020
# Month=8, Predicted=853.7675, Expected=834.1536
# Month=9, Predicted=822.8622, Expected=789.9823
# Month=10, Predicted=775.2554, Expected=799.4046
# Month=11, Predicted=804.3634, Expected=763.5823
# Month=12, Predicted=752.0322, Expected=800.3831
# Month=13, Predicted=800.7591, Expected=826.4030
# Month=14, Predicted=834.4337, Expected=798.5367
# Month=15, Predicted=790.1711, Expected=890.7147
# Month=16, Predicted=900.2443, Expected=899.2858
# Month=17, Predicted=908.1260, Expected=961.2990
# Month=18, Predicted=954.3317, Expected=936.1160
# Month=19, Predicted=930.3920, Expected=893.4953
# Month=20, Predicted=879.4003, Expected=854.7115
# Month=21, Predicted=841.9384, Expected=809.0508
# Month=22, Predicted=793.7275, Expected=809.7435
# Month=23, Predicted=811.5420, Expected=765.2099
# Month=24, Predicted=750.3797, Expected=805.0349
# Month=25, Predicted=803.1957, Expected=820.4588
# Month=26, Predicted=828.4743, Expected=773.2413
# Month=27, Predicted=757.3906, Expected=882.5316
# Month=28, Predicted=904.1026, Expected=898.7897
# Month=29, Predicted=911.6753, Expected=956.6009
# Month=30, Predicted=948.9493, Expected=923.8359
# Month=31, Predicted=915.0161, Expected=881.4145
# Month=32, Predicted=867.3624, Expected=836.3729
# Month=33, Predicted=821.2439, Expected=784.1159
# Month=34, Predicted=766.2293, Expected=791.6660
# Month=35, Predicted=795.8264, Expected=759.1810
# Month=36, Predicted=748.8851, Expected=802.0941
# Month=37, Predicted=798.6170, Expected=828.1324
# Month=38, Predicted=836.5157, Expected=778.3983
# Month=39, Predicted=761.7864, Expected=888.3698
# Month=40, Predicted=910.4349, Expected=901.3272
# Month=41, Predicted=913.1613, Expected=969.2659
# Month=42, Predicted=964.2519, Expected=947.1513
# Month=43, Predicted=942.9371, Expected=908.1276
# Month=44, Predicted=895.3941, Expected=867.1765
# Month=45, Predicted=853.6265, Expected=814.6535
# Month=46, Predicted=796.7146, Expected=812.1183
# Month=47, Predicted=812.6327, Expected=773.1493
# Month=48, Predicted=760.4216, Expected=812.6360
# Month=49, Predicted=811.1501, Expected=834.9506
# Month=50, Predicted=845.1467, Expected=782.2414
# Month=51, Predicted=764.3851, Expected=891.3930
# Month=52, Predicted=912.8660, Expected=903.3345
# Month=53, Predicted=914.7870, Expected=965.5034
# Month=54, Predicted=958.5616, Expected=937.4010
# Month=55, Predicted=930.5856, Expected=896.5903
# Month=56, Predicted=883.1683, Expected=857.5819
# Month=57, Predicted=844.7449, Expected=817.4908
# Month=58, Predicted=804.2655, Expected=827.2103
# Month=59, Predicted=832.3250, Expected=797.4188
# Month=60, Predicted=788.1319, Expected=843.9664
# Run 15 — RMSE: 49.297140, MSE: 2430.207995, NMSE: 0.0096752526
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=761.7412, Expected=804.1312
# Month=2, Predicted=794.8533, Expected=755.9621
# Month=3, Predicted=739.9348, Expected=859.0224
# Month=4, Predicted=876.2367, Expected=877.9865
# Month=5, Predicted=883.2538, Expected=942.0307
# Month=6, Predicted=932.8514, Expected=914.2550
# Month=7, Predicted=905.6435, Expected=868.9020
# Month=8, Predicted=853.5442, Expected=834.1536
# Month=9, Predicted=822.3363, Expected=789.9823
# Month=10, Predicted=774.9406, Expected=799.4046
# Month=11, Predicted=801.3149, Expected=763.5823
# Month=12, Predicted=752.1188, Expected=800.3831
# Month=13, Predicted=810.6384, Expected=826.4030
# Month=14, Predicted=833.6671, Expected=798.5367
# Month=15, Predicted=789.8876, Expected=890.7147
# Month=16, Predicted=899.9960, Expected=899.2858
# Month=17, Predicted=901.7181, Expected=961.2990
# Month=18, Predicted=951.4107, Expected=936.1160
# Month=19, Predicted=928.3905, Expected=893.4953
# Month=20, Predicted=879.2023, Expected=854.7115
# Month=21, Predicted=841.4971, Expected=809.0508
# Month=22, Predicted=793.3715, Expected=809.7435
# Month=23, Predicted=809.2267, Expected=765.2099
# Month=24, Predicted=750.5058, Expected=805.0349
# Month=25, Predicted=814.3639, Expected=820.4588
# Month=26, Predicted=824.7174, Expected=773.2413
# Month=27, Predicted=757.5752, Expected=882.5316
# Month=28, Predicted=904.6273, Expected=898.7897
# Month=29, Predicted=903.3173, Expected=956.6009
# Month=30, Predicted=946.0534, Expected=923.8359
# Month=31, Predicted=913.4773, Expected=881.4145
# Month=32, Predicted=867.0597, Expected=836.3729
# Month=33, Predicted=820.8497, Expected=784.1159
# Month=34, Predicted=765.7960, Expected=791.6660
# Month=35, Predicted=792.8811, Expected=759.1810
# Month=36, Predicted=748.9032, Expected=802.0941
# Month=37, Predicted=805.5114, Expected=828.1324
# Month=38, Predicted=835.4024, Expected=778.3983
# Month=39, Predicted=761.7722, Expected=888.3698
# Month=40, Predicted=910.9533, Expected=901.3272
# Month=41, Predicted=904.9585, Expected=969.2659
# Month=42, Predicted=962.1190, Expected=947.1513
# Month=43, Predicted=940.4586, Expected=908.1276
# Month=44, Predicted=895.2092, Expected=867.1765
# Month=45, Predicted=853.2438, Expected=814.6535
# Month=46, Predicted=796.3193, Expected=812.1183
# Month=47, Predicted=810.5286, Expected=773.1493
# Month=48, Predicted=760.4815, Expected=812.6360
# Month=49, Predicted=822.5989, Expected=834.9506
# Month=50, Predicted=841.1301, Expected=782.2414
# Month=51, Predicted=764.4722, Expected=891.3930
# Month=52, Predicted=913.2694, Expected=903.3345
# Month=53, Predicted=906.6902, Expected=965.5034
# Month=54, Predicted=955.6527, Expected=937.4010
# Month=55, Predicted=928.6762, Expected=896.5903
# Month=56, Predicted=882.9151, Expected=857.5819
# Month=57, Predicted=844.3243, Expected=817.4908
# ...
# Month=47, Predicted=806.9233, Expected=773.1493
# Month=48, Predicted=767.9542, Expected=812.6360
# Month=49, Predicted=807.3320, Expected=834.9506
# Month=50, Predicted=829.7555, Expected=782.2414
# Month=51, Predicted=777.0463, Expected=891.3930
# Month=52, Predicted=925.6272, Expected=903.3345
# Month=53, Predicted=898.1394, Expected=965.5034
# Month=54, Predicted=945.8498, Expected=937.4010
# Month=55, Predicted=932.2059, Expected=896.5903
# Month=56, Predicted=891.3952, Expected=857.5819
# Month=57, Predicted=852.3868, Expected=817.4908
# Month=58, Predicted=812.2958, Expected=827.2103
# Month=59, Predicted=822.0152, Expected=797.4188
# Month=60, Predicted=792.2238, Expected=843.9664
# Run 25 — RMSE: 47.968401, MSE: 2300.967513, NMSE: 0.0100159886
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=752.6488, Expected=804.1312
# Month=2, Predicted=804.2621, Expected=755.9621
# Month=3, Predicted=738.2430, Expected=859.0224
# Month=4, Predicted=866.3575, Expected=877.9865
# Month=5, Predicted=885.0319, Expected=942.0307
# Month=6, Predicted=942.0925, Expected=914.2550
# Month=7, Predicted=906.1680, Expected=868.9020
# Month=8, Predicted=851.8135, Expected=834.1536
# Month=9, Predicted=821.5557, Expected=789.9823
# Month=10, Predicted=773.3245, Expected=799.4046
# Month=11, Predicted=801.7373, Expected=763.5823
# Month=12, Predicted=751.1273, Expected=800.3831
# Month=13, Predicted=802.3573, Expected=826.4030
# Month=14, Predicted=830.6484, Expected=798.5367
# Month=15, Predicted=789.5224, Expected=890.7147
# Month=16, Predicted=895.5702, Expected=899.2858
# Month=17, Predicted=904.1073, Expected=961.2990
# Month=18, Predicted=961.2748, Expected=936.1160
# Month=19, Predicted=929.0168, Expected=893.4953
# Month=20, Predicted=877.7464, Expected=854.7115
# Month=21, Predicted=840.3774, Expected=809.0508
# Month=22, Predicted=791.5832, Expected=809.7435
# Month=23, Predicted=809.9828, Expected=765.2099
# Month=24, Predicted=748.7335, Expected=805.0349
# Month=25, Predicted=806.3261, Expected=820.4588
# Month=26, Predicted=824.6018, Expected=773.2413
# Month=27, Predicted=755.4299, Expected=882.5316
# Month=28, Predicted=891.5834, Expected=898.7897
# Month=29, Predicted=905.8722, Expected=956.6009
# Month=30, Predicted=956.4394, Expected=923.8359
# Month=31, Predicted=913.4146, Expected=881.4145
# Month=32, Predicted=865.6345, Expected=836.3729
# Month=33, Predicted=819.1056, Expected=784.1159
# Month=34, Predicted=763.2138, Expected=791.6660
# Month=35, Predicted=793.3409, Expected=759.1810
# Month=36, Predicted=748.2010, Expected=802.0941
# Month=37, Predicted=803.0515, Expected=828.1324
# Month=38, Predicted=832.4760, Expected=778.3983
# Month=39, Predicted=759.3834, Expected=888.3698
# Month=40, Predicted=897.5610, Expected=901.3272
# Month=41, Predicted=907.9472, Expected=969.2659
# Month=42, Predicted=969.7037, Expected=947.1513
# Month=43, Predicted=941.4882, Expected=908.1276
# Month=44, Predicted=894.0920, Expected=867.1765
# Month=45, Predicted=851.9387, Expected=814.6535
# Month=46, Predicted=793.7381, Expected=812.1183
# Month=47, Predicted=811.2297, Expected=773.1493
# Month=48, Predicted=759.2780, Expected=812.6360
# Month=49, Predicted=814.0806, Expected=834.9506
# Month=50, Predicted=839.7588, Expected=782.2414
# Month=51, Predicted=761.6992, Expected=891.3930
# Month=52, Predicted=900.2860, Expected=903.3345
# Month=53, Predicted=909.7312, Expected=965.5034
# Month=54, Predicted=965.4771, Expected=937.4010
# Month=55, Predicted=929.1112, Expected=896.5903
# Month=56, Predicted=881.6482, Expected=857.5819
# Month=57, Predicted=843.1957, Expected=817.4908
# Month=58, Predicted=802.6523, Expected=827.2103
# Month=59, Predicted=829.7114, Expected=797.4188
# Month=60, Predicted=787.5864, Expected=843.9664
# Run 26 — RMSE: 49.938556, MSE: 2493.859326, NMSE: 0.0098664452
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=751.3781, Expected=804.1312
# Month=2, Predicted=806.0598, Expected=755.9621
# Month=3, Predicted=744.6120, Expected=859.0224
# Month=4, Predicted=862.8809, Expected=877.9865
# Month=5, Predicted=881.9864, Expected=942.0307
# Month=6, Predicted=944.1870, Expected=914.2550
# Month=7, Predicted=908.7318, Expected=868.9020
# Month=8, Predicted=856.3092, Expected=834.1536
# Month=9, Predicted=822.7273, Expected=789.9823
# Month=10, Predicted=776.8641, Expected=799.4046
# Month=11, Predicted=796.5877, Expected=763.5823
# Month=12, Predicted=755.8917, Expected=800.3831
# Month=13, Predicted=800.7170, Expected=826.4030
# Month=14, Predicted=829.1768, Expected=798.5367
# Month=15, Predicted=792.5039, Expected=890.7147
# Month=16, Predicted=894.6664, Expected=899.2858
# Month=17, Predicted=901.4608, Expected=961.2990
# Month=18, Predicted=963.5009, Expected=936.1160
# Month=19, Predicted=931.1203, Expected=893.4953
# Month=20, Predicted=881.9744, Expected=854.7115
# Month=21, Predicted=842.4319, Expected=809.0508
# Month=22, Predicted=795.1032, Expected=809.7435
# Month=23, Predicted=805.3923, Expected=765.2099
# Month=24, Predicted=754.6960, Expected=805.0349
# Month=25, Predicted=804.5270, Expected=820.4588
# Month=26, Predicted=822.3407, Expected=773.2413
# Month=27, Predicted=762.0127, Expected=882.5316
# Month=28, Predicted=887.5719, Expected=898.7897
# Month=29, Predicted=902.7112, Expected=956.6009
# Month=30, Predicted=958.5633, Expected=923.8359
# Month=31, Predicted=917.0618, Expected=881.4145
# Month=32, Predicted=869.1589, Expected=836.3729
# Month=33, Predicted=822.2634, Expected=784.1159
# Month=34, Predicted=767.6074, Expected=791.6660
# Month=35, Predicted=787.5408, Expected=759.1810
# Month=36, Predicted=752.2411, Expected=802.0941
# Month=37, Predicted=802.4377, Expected=828.1324
# Month=38, Predicted=830.9581, Expected=778.3983
# Month=39, Predicted=766.3038, Expected=888.3698
# Month=40, Predicted=893.2661, Expected=901.3272
# Month=41, Predicted=904.8290, Expected=969.2659
# Month=42, Predicted=971.8325, Expected=947.1513
# Month=43, Predicted=942.9509, Expected=908.1276
# Month=44, Predicted=897.9852, Expected=867.1765
# Month=45, Predicted=854.6658, Expected=814.6535
# Month=46, Predicted=798.5169, Expected=812.1183
# Month=47, Predicted=806.3852, Expected=773.1493
# Month=48, Predicted=764.2144, Expected=812.6360
# Month=49, Predicted=812.6098, Expected=834.9506
# Month=50, Predicted=837.6649, Expected=782.2414
# Month=51, Predicted=769.2310, Expected=891.3930
# Month=52, Predicted=895.8185, Expected=903.3345
# Month=53, Predicted=906.6537, Expected=965.5034
# Month=54, Predicted=967.6945, Expected=937.4010
# Month=55, Predicted=931.7652, Expected=896.5903
# Month=56, Predicted=885.3168, Expected=857.5819
# Month=57, Predicted=845.4247, Expected=817.4908
# Month=58, Predicted=805.1533, Expected=827.2103
# Month=59, Predicted=824.8784, Expected=797.4188
# Month=60, Predicted=791.1085, Expected=843.9664
# Run 27 — RMSE: 48.727865, MSE: 2374.404849, NMSE: 0.0096595853
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=746.3840, Expected=804.1312
# Month=2, Predicted=799.4263, Expected=755.9621
# Month=3, Predicted=744.0557, Expected=859.0224
# Month=4, Predicted=884.5291, Expected=877.9865
# Month=5, Predicted=873.2815, Expected=942.0307
# Month=6, Predicted=937.3257, Expected=914.2550
# Month=7, Predicted=909.5501, Expected=868.9020
# Month=8, Predicted=857.5343, Expected=834.1536
# Month=9, Predicted=826.8574, Expected=789.9823
# Month=10, Predicted=778.9397, Expected=799.4046
# Month=11, Predicted=794.6996, Expected=763.5823
# Month=12, Predicted=756.8301, Expected=800.3831
# Month=13, Predicted=795.6782, Expected=826.4030
# Month=14, Predicted=821.6981, Expected=798.5367
# Month=15, Predicted=793.8317, Expected=890.7147
# Month=16, Predicted=908.5939, Expected=899.2858
# Month=17, Predicted=894.5808, Expected=961.2990
# Month=18, Predicted=956.5941, Expected=936.1160
# Month=19, Predicted=931.4111, Expected=893.4953
# Month=20, Predicted=883.3799, Expected=854.7115
# Month=21, Predicted=845.7211, Expected=809.0508
# Month=22, Predicted=797.2193, Expected=809.7435
# Month=23, Predicted=805.0385, Expected=765.2099
# Month=24, Predicted=754.5223, Expected=805.0349
# Month=25, Predicted=800.3300, Expected=820.4588
# Month=26, Predicted=815.7538, Expected=773.2413
# Month=27, Predicted=761.3820, Expected=882.5316
# Month=28, Predicted=911.8597, Expected=898.7897
# Month=29, Predicted=894.0847, Expected=956.6009
# Month=30, Predicted=951.8960, Expected=923.8359
# Month=31, Predicted=918.4118, Expected=881.4145
# Month=32, Predicted=871.1963, Expected=836.3729
# Month=33, Predicted=824.6506, Expected=784.1159
# Month=34, Predicted=769.3171, Expected=791.6660
# Month=35, Predicted=786.9610, Expected=759.1810
# Month=36, Predicted=753.6741, Expected=802.0941
# Month=37, Predicted=797.3891, Expected=828.1324
# Month=38, Predicted=823.4275, Expected=778.3983
# Month=39, Predicted=765.6432, Expected=888.3698
# Month=40, Predicted=918.1252, Expected=901.3272
# Month=41, Predicted=896.6223, Expected=969.2659
# Month=42, Predicted=966.1465, Expected=947.1513
# Month=43, Predicted=942.4464, Expected=908.1276
# Month=44, Predicted=899.6869, Expected=867.1765
# Month=45, Predicted=857.3816, Expected=814.6535
# Month=46, Predicted=799.9171, Expected=812.1183
# Month=47, Predicted=807.4134, Expected=773.1493
# Month=48, Predicted=764.9405, Expected=812.6360
# Month=49, Predicted=807.9311, Expected=834.9506
# Month=50, Predicted=830.2457, Expected=782.2414
# Month=51, Predicted=768.1725, Expected=891.3930
# Month=52, Predicted=920.6937, Expected=903.3345
# Month=53, Predicted=898.6296, Expected=965.5034
# Month=54, Predicted=960.7985, Expected=937.4010
# Month=55, Predicted=932.6961, Expected=896.5903
# Month=56, Predicted=887.2131, Expected=857.5819
# Month=57, Predicted=848.5761, Expected=817.4908
# Month=58, Predicted=808.0814, Expected=827.2103
# Month=59, Predicted=822.5054, Expected=797.4188
# Month=60, Predicted=792.4294, Expected=843.9664
# Run 28 — RMSE: 49.304406, MSE: 2430.924484, NMSE: 0.0097348791
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=751.7820, Expected=804.1312
# Month=2, Predicted=806.3352, Expected=755.9621
# Month=3, Predicted=742.0602, Expected=859.0224
# Month=4, Predicted=869.7076, Expected=877.9865
# Month=5, Predicted=881.9641, Expected=942.0307
# Month=6, Predicted=945.0598, Expected=914.2550
# Month=7, Predicted=906.5891, Expected=868.9020
# Month=8, Predicted=854.2681, Expected=834.1536
# Month=9, Predicted=821.4367, Expected=789.9823
# Month=10, Predicted=775.2634, Expected=799.4046
# Month=11, Predicted=798.3956, Expected=763.5823
# Month=12, Predicted=752.9358, Expected=800.3831
# Month=13, Predicted=801.0390, Expected=826.4030
# Month=14, Predicted=828.5343, Expected=798.5367
# Month=15, Predicted=790.2608, Expected=890.7147
# Month=16, Predicted=899.0450, Expected=899.2858
# Month=17, Predicted=902.1960, Expected=961.2990
# Month=18, Predicted=964.0657, Expected=936.1160
# Month=19, Predicted=929.1416, Expected=893.4953
# Month=20, Predicted=879.8084, Expected=854.7115
# Month=21, Predicted=841.0206, Expected=809.0508
# Month=22, Predicted=793.6151, Expected=809.7435
# Month=23, Predicted=807.2509, Expected=765.2099
# Month=24, Predicted=751.8860, Expected=805.0349
# Month=25, Predicted=805.2130, Expected=820.4588
# Month=26, Predicted=822.2807, Expected=773.2413
# Month=27, Predicted=759.2909, Expected=882.5316
# Month=28, Predicted=895.0821, Expected=898.7897
# Month=29, Predicted=903.0291, Expected=956.6009
# Month=30, Predicted=959.0153, Expected=923.8359
# Month=31, Predicted=914.5532, Expected=881.4145
# Month=32, Predicted=867.3435, Expected=836.3729
# Month=33, Predicted=820.8520, Expected=784.1159
# Month=34, Predicted=766.2552, Expected=791.6660
# Month=35, Predicted=789.7933, Expected=759.1810
# Month=36, Predicted=749.4882, Expected=802.0941
# Month=37, Predicted=802.9429, Expected=828.1324
# Month=38, Predicted=830.3228, Expected=778.3983
# Month=39, Predicted=763.7232, Expected=888.3698
# Month=40, Predicted=901.0141, Expected=901.3272
# Month=41, Predicted=905.4699, Expected=969.2659
# Month=42, Predicted=972.8214, Expected=947.1513
# Month=43, Predicted=941.2393, Expected=908.1276
# Month=44, Predicted=895.6555, Expected=867.1765
# Month=45, Predicted=853.1132, Expected=814.6535
# Month=46, Predicted=797.0294, Expected=812.1183
# Month=47, Predicted=808.1482, Expected=773.1493
# Month=48, Predicted=761.3894, Expected=812.6360
# Month=49, Predicted=813.1324, Expected=834.9506
# Month=50, Predicted=837.0416, Expected=782.2414
# Month=51, Predicted=766.6795, Expected=891.3930
# Month=52, Predicted=903.6620, Expected=903.3345
# Month=53, Predicted=907.3762, Expected=965.5034
# Month=54, Predicted=968.3038, Expected=937.4010
# Month=55, Predicted=929.5866, Expected=896.5903
# Month=56, Predicted=883.2750, Expected=857.5819
# Month=57, Predicted=843.9605, Expected=817.4908
# Month=58, Predicted=803.6814, Expected=827.2103
# Month=59, Predicted=826.5328, Expected=797.4188
# Month=60, Predicted=788.5324, Expected=843.9664
# Run 29 — RMSE: 49.190657, MSE: 2419.720717, NMSE: 0.0095978053
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=752.4227, Expected=804.1312
# Month=2, Predicted=807.1779, Expected=755.9621
# Month=3, Predicted=744.2327, Expected=859.0224
# Month=4, Predicted=867.6548, Expected=877.9865
# Month=5, Predicted=877.2547, Expected=942.0307
# Month=6, Predicted=946.3330, Expected=914.2550
# Month=7, Predicted=908.3732, Expected=868.9020
# Month=8, Predicted=857.6089, Expected=834.1536
# Month=9, Predicted=825.8244, Expected=789.9823
# Month=10, Predicted=778.9677, Expected=799.4046
# Month=11, Predicted=797.3889, Expected=763.5823
# Month=12, Predicted=755.3623, Expected=800.3831
# Month=13, Predicted=801.4520, Expected=826.4030
# Month=14, Predicted=826.3967, Expected=798.5367
# Month=15, Predicted=792.6273, Expected=890.7147
# Month=16, Predicted=898.1643, Expected=899.2858
# Month=17, Predicted=897.3863, Expected=961.2990
# Month=18, Predicted=965.3798, Expected=936.1160
# Month=19, Predicted=930.5104, Expected=893.4953
# Month=20, Predicted=882.9814, Expected=854.7115
# Month=21, Predicted=845.1823, Expected=809.0508
# Month=22, Predicted=797.6017, Expected=809.7435
# Month=23, Predicted=806.7623, Expected=765.2099
# Month=24, Predicted=754.3674, Expected=805.0349
# Month=25, Predicted=806.4090, Expected=820.4588
# Month=26, Predicted=819.2727, Expected=773.2413
# Month=27, Predicted=761.7460, Expected=882.5316
# Month=28, Predicted=891.8988, Expected=898.7897
# Month=29, Predicted=897.7663, Expected=956.6009
# Month=30, Predicted=960.1935, Expected=923.8359
# Month=31, Predicted=916.6424, Expected=881.4145
# Month=32, Predicted=870.8991, Expected=836.3729
# Month=33, Predicted=825.0688, Expected=784.1159
# Month=34, Predicted=770.9143, Expected=791.6660
# Month=35, Predicted=789.4114, Expected=759.1810
# Month=36, Predicted=752.0006, Expected=802.0941
# Month=37, Predicted=803.8667, Expected=828.1324
# Month=38, Predicted=828.1306, Expected=778.3983
# Month=39, Predicted=766.2460, Expected=888.3698
# Month=40, Predicted=897.8057, Expected=901.3272
# Month=41, Predicted=899.9386, Expected=969.2659
# Month=42, Predicted=974.0244, Expected=947.1513
# Month=43, Predicted=941.8800, Expected=908.1276
# Month=44, Predicted=898.6803, Expected=867.1765
# Month=45, Predicted=857.0398, Expected=814.6535
# Month=46, Predicted=801.4093, Expected=812.1183
# Month=47, Predicted=808.7566, Expected=773.1493
# Month=48, Predicted=763.8814, Expected=812.6360
# Month=49, Predicted=813.9954, Expected=834.9506
# Month=50, Predicted=834.5312, Expected=782.2414
# Month=51, Predicted=769.3235, Expected=891.3930
# Month=52, Predicted=900.7189, Expected=903.3345
# Month=53, Predicted=901.8321, Expected=965.5034
# Month=54, Predicted=969.6004, Expected=937.4010
# Month=55, Predicted=931.4828, Expected=896.5903
# Month=56, Predicted=886.5698, Expected=857.5819
# Month=57, Predicted=847.9986, Expected=817.4908
# Month=58, Predicted=807.6040, Expected=827.2103
# Month=59, Predicted=825.2440, Expected=797.4188
# Month=60, Predicted=791.1281, Expected=843.9664
# Run 30 — RMSE: 49.274774, MSE: 2428.003361, NMSE: 0.0099173400
#
# ===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Milk Production (30 runs) =====
# RMSE: 48.732471 ± 0.617601
# MSE:  2375.235136 ± 59.930009
# NMSE: 0.0097492307 ± 0.0002406319
#
# Best run: 20
#   RMSE: 47.107107
#   MSE:  2219.079554
#   NMSE: 0.0089598142
# === Best Run Metrics ===
# RMSE: 47.107107
# MSE:  2219.079554
# NMSE: 0.0089598142

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Monthly Milk Production
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*

# %%
# ============================================================
# NOTEBOOK TIMER — END
# ============================================================
import time as _timer_module
_NOTEBOOK_END_TIME = _timer_module.time()
_NOTEBOOK_ELAPSED = _NOTEBOOK_END_TIME - _NOTEBOOK_START_TIME
_hours, _rem = divmod(_NOTEBOOK_ELAPSED, 3600)
_minutes, _seconds = divmod(_rem, 60)
print(f"\nTotal notebook execution time: {int(_hours)}h {int(_minutes)}m {_seconds:.2f}s")
print(f"Total seconds: {_NOTEBOOK_ELAPSED:.2f}")
