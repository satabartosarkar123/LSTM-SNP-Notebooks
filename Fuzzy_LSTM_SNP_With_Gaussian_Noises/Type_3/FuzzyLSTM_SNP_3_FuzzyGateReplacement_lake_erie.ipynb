# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value clipped to $[0, 1]$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Gate Replacement
# Uses FuzzyLSTMSNPCell instead of LSTMSNPCell.
# Gradient clipping applied for stability.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 1)]               0
#
#  rnn (RNN)                   (1, 8)                    464
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 473 (1.85 KB)
# Trainable params: 473 (1.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 1)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input
    # ============================================================
    
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)
    
        rnn_layer = model.layers[1]
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)
    
        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Lake Erie Levels (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Gate Replacement — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Gate Replacement — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.1% (lambda=0.001, sigma=0.002010)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.76399861 14.64872203 15.08630213 16.37906193 16.92552925]
# Supervised data shape: (599, 2)
# Train: (539, 2), Test: (60, 2)
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2107, Expected=13.7017
# Month=2, Predicted=14.0364, Expected=13.8117
# Month=3, Predicted=13.8806, Expected=14.3841
# Month=4, Predicted=14.7191, Expected=15.0499
# Month=5, Predicted=15.4369, Expected=15.6880
# Month=6, Predicted=16.0599, Expected=15.8424
# Month=7, Predicted=15.9376, Expected=15.7132
# Month=8, Predicted=15.6369, Expected=15.3126
# Month=9, Predicted=15.0672, Expected=14.7637
# Month=10, Predicted=14.4245, Expected=13.5468
# Month=11, Predicted=12.7739, Expected=13.5862
# Month=12, Predicted=13.6176, Expected=14.5157
# Month=13, Predicted=15.0450, Expected=14.3853
# Month=14, Predicted=14.3094, Expected=14.4975
# Month=15, Predicted=14.5677, Expected=14.7447
# Month=16, Predicted=14.8942, Expected=15.8052
# Month=17, Predicted=16.4035, Expected=16.5260
# Month=18, Predicted=16.9437, Expected=16.5451
# Month=19, Predicted=16.5597, Expected=16.7178
# Month=20, Predicted=16.8236, Expected=16.4322
# Month=21, Predicted=16.2588, Expected=15.7696
# Month=22, Predicted=15.3568, Expected=15.2792
# Month=23, Predicted=14.9782, Expected=15.1248
# Month=24, Predicted=15.0342, Expected=15.5403
# Month=25, Predicted=15.7873, Expected=15.8274
# Month=26, Predicted=16.0002, Expected=16.3752
# Month=27, Predicted=16.6965, Expected=16.3529
# Month=28, Predicted=16.3421, Expected=16.9050
# Month=29, Predicted=17.2288, Expected=17.0172
# Month=30, Predicted=17.0874, Expected=17.4183
# Month=31, Predicted=17.6567, Expected=17.5330
# Month=32, Predicted=17.6045, Expected=17.2714
# Month=33, Predicted=17.1130, Expected=16.6037
# Month=34, Predicted=16.1875, Expected=15.8246
# Month=35, Predicted=15.3376, Expected=15.4477
# Month=36, Predicted=15.2194, Expected=15.6316
# Month=37, Predicted=15.7447, Expected=15.6935
# Month=38, Predicted=15.7333, Expected=16.7565
# Month=39, Predicted=17.3563, Expected=16.5060
# Month=40, Predicted=16.3556, Expected=17.7253
# Month=41, Predicted=18.4063, Expected=18.6917
# Month=42, Predicted=19.2405, Expected=19.1262
# Month=43, Predicted=19.3847, Expected=19.5653
# Month=44, Predicted=19.8254, Expected=19.2076
# Month=45, Predicted=18.9890, Expected=18.2164
# Month=46, Predicted=17.5901, Expected=17.2115
# Month=47, Predicted=16.5793, Expected=16.6591
# Month=48, Predicted=16.3204, Expected=16.8293
# Month=49, Predicted=16.9349, Expected=15.7707
# Month=50, Predicted=15.0996, Expected=15.7293
# Month=51, Predicted=15.7108, Expected=15.9961
# Month=52, Predicted=16.1573, Expected=17.0200
# Month=53, Predicted=17.5992, Expected=17.5530
# Month=54, Predicted=17.8669, Expected=17.8377
# Month=55, Predicted=18.0092, Expected=17.8581
# Month=56, Predicted=17.8730, Expected=17.5700
# Month=57, Predicted=17.3952, Expected=17.0775
# Month=58, Predicted=16.7739, Expected=16.6580
# Month=59, Predicted=16.4016, Expected=16.4321
# Month=60, Predicted=16.2970, Expected=16.5848
# Run 1 — RMSE: 0.499064, MSE: 0.249065, NMSE: 0.0018926317
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2142, Expected=13.7017
# Month=2, Predicted=14.0342, Expected=13.8117
# Month=3, Predicted=13.8624, Expected=14.3841
# Month=4, Predicted=14.7177, Expected=15.0499
# Month=5, Predicted=15.4300, Expected=15.6880
# Month=6, Predicted=16.0524, Expected=15.8424
# Month=7, Predicted=15.9201, Expected=15.7132
# Month=8, Predicted=15.6038, Expected=15.3126
# Month=9, Predicted=15.0358, Expected=14.7637
# Month=10, Predicted=14.4088, Expected=13.5468
# Month=11, Predicted=12.8060, Expected=13.5862
# Month=12, Predicted=13.6943, Expected=14.5157
# Month=13, Predicted=15.0530, Expected=14.3853
# Month=14, Predicted=14.2703, Expected=14.4975
# Month=15, Predicted=14.5669, Expected=14.7447
# Month=16, Predicted=14.8859, Expected=15.8052
# Month=17, Predicted=16.4089, Expected=16.5260
# Month=18, Predicted=16.9394, Expected=16.5451
# Month=19, Predicted=16.5319, Expected=16.7178
# Month=20, Predicted=16.8175, Expected=16.4322
# Month=21, Predicted=16.2177, Expected=15.7696
# Month=22, Predicted=15.3380, Expected=15.2792
# Month=23, Predicted=14.9798, Expected=15.1248
# Month=24, Predicted=15.0321, Expected=15.5403
# Month=25, Predicted=15.7923, Expected=15.8274
# Month=26, Predicted=15.9859, Expected=16.3752
# Month=27, Predicted=16.6900, Expected=16.3529
# Month=28, Predicted=16.3102, Expected=16.9050
# Month=29, Predicted=17.2315, Expected=17.0172
# Month=30, Predicted=17.0692, Expected=17.4183
# Month=31, Predicted=17.6515, Expected=17.5330
# Month=32, Predicted=17.5876, Expected=17.2714
# Month=33, Predicted=17.0746, Expected=16.6037
# Month=34, Predicted=16.1676, Expected=15.8246
# Month=35, Predicted=15.3482, Expected=15.4477
# Month=36, Predicted=15.2304, Expected=15.6316
# Month=37, Predicted=15.7570, Expected=15.6935
# Month=38, Predicted=15.7158, Expected=16.7565
# Month=39, Predicted=17.3666, Expected=16.5060
# Month=40, Predicted=16.3108, Expected=17.7253
# Month=41, Predicted=18.4303, Expected=18.6917
# Month=42, Predicted=19.2423, Expected=19.1262
# Month=43, Predicted=19.3734, Expected=19.5653
# Month=44, Predicted=19.8140, Expected=19.2076
# Month=45, Predicted=18.9410, Expected=18.2164
# Month=46, Predicted=17.5951, Expected=17.2115
# Month=47, Predicted=16.6294, Expected=16.6591
# Month=48, Predicted=16.3497, Expected=16.8293
# Month=49, Predicted=16.9578, Expected=15.7707
# Month=50, Predicted=15.0879, Expected=15.7293
# Month=51, Predicted=15.7688, Expected=15.9961
# Month=52, Predicted=16.1542, Expected=17.0200
# Month=53, Predicted=17.6036, Expected=17.5530
# Month=54, Predicted=17.8580, Expected=17.8377
# Month=55, Predicted=17.9939, Expected=17.8581
# Month=56, Predicted=17.8487, Expected=17.5700
# Month=57, Predicted=17.3593, Expected=17.0775
# Month=58, Predicted=16.7509, Expected=16.6580
# Month=59, Predicted=16.3909, Expected=16.4321
# Month=60, Predicted=16.2863, Expected=16.5848
# Run 2 — RMSE: 0.495790, MSE: 0.245808, NMSE: 0.0018798944
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.2134, Expected=13.7017
# Month=2, Predicted=14.0391, Expected=13.8117
# Month=3, Predicted=13.8622, Expected=14.3841
# Month=4, Predicted=14.7222, Expected=15.0499
# Month=5, Predicted=15.4352, Expected=15.6880
# Month=6, Predicted=16.0567, Expected=15.8424
# Month=7, Predicted=15.9201, Expected=15.7132
# Month=8, Predicted=15.6168, Expected=15.3126
# Month=9, Predicted=15.0467, Expected=14.7637
# Month=10, Predicted=14.4133, Expected=13.5468
# Month=11, Predicted=12.7780, Expected=13.5862
# Month=12, Predicted=13.6918, Expected=14.5157
# Month=13, Predicted=15.0577, Expected=14.3853
# Month=14, Predicted=14.2802, Expected=14.4975
# Month=15, Predicted=14.5653, Expected=14.7447
# Month=16, Predicted=14.8879, Expected=15.8052
# Month=17, Predicted=16.4136, Expected=16.5260
# Month=18, Predicted=16.9390, Expected=16.5451
# Month=19, Predicted=16.5369, Expected=16.7178
# Month=20, Predicted=16.8173, Expected=16.4322
# Month=21, Predicted=16.2326, Expected=15.7696
# Month=22, Predicted=15.3351, Expected=15.2792
# Month=23, Predicted=14.9878, Expected=15.1248
# Month=24, Predicted=15.0432, Expected=15.5403
# Month=25, Predicted=15.7952, Expected=15.8274
# Month=26, Predicted=15.9895, Expected=16.3752
# Month=27, Predicted=16.6954, Expected=16.3529
# Month=28, Predicted=16.3194, Expected=16.9050
# Month=29, Predicted=17.2350, Expected=17.0172
# Month=30, Predicted=17.0693, Expected=17.4183
# Month=31, Predicted=17.6550, Expected=17.5330
# Month=32, Predicted=17.5884, Expected=17.2714
# Month=33, Predicted=17.0891, Expected=16.6037
# Month=34, Predicted=16.1647, Expected=15.8246
# Month=35, Predicted=15.3420, Expected=15.4477
# Month=36, Predicted=15.2424, Expected=15.6316
# Month=37, Predicted=15.7574, Expected=15.6935
# Month=38, Predicted=15.7193, Expected=16.7565
# Month=39, Predicted=17.3701, Expected=16.5060
# Month=40, Predicted=16.3195, Expected=17.7253
# Month=41, Predicted=18.4321, Expected=18.6917
# Month=42, Predicted=19.2380, Expected=19.1262
# Month=43, Predicted=19.3742, Expected=19.5653
# Month=44, Predicted=19.8191, Expected=19.2076
# Month=45, Predicted=18.9553, Expected=18.2164
# Month=46, Predicted=17.5788, Expected=17.2115
# Month=47, Predicted=16.6135, Expected=16.6591
# Month=48, Predicted=16.3571, Expected=16.8293
# Month=49, Predicted=16.9582, Expected=15.7707
# Month=50, Predicted=15.0689, Expected=15.7293
# Month=51, Predicted=15.7682, Expected=15.9961
# Month=52, Predicted=16.1562, Expected=17.0200
# Month=53, Predicted=17.6085, Expected=17.5530
# Month=54, Predicted=17.8580, Expected=17.8377
# Month=55, Predicted=17.9970, Expected=17.8581
# Month=56, Predicted=17.8555, Expected=17.5700
# Month=57, Predicted=17.3728, Expected=17.0775
# Month=58, Predicted=16.7582, Expected=16.6580
# Month=59, Predicted=16.4014, Expected=16.4321
# Month=60, Predicted=16.2990, Expected=16.5848
# Run 3 — RMSE: 0.496986, MSE: 0.246995, NMSE: 0.0018856569
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2118, Expected=13.7017
# Month=2, Predicted=14.0376, Expected=13.8117
# Month=3, Predicted=13.8809, Expected=14.3841
# Month=4, Predicted=14.7203, Expected=15.0499
# Month=5, Predicted=15.4395, Expected=15.6880
# Month=6, Predicted=16.0633, Expected=15.8424
# Month=7, Predicted=15.9390, Expected=15.7132
# Month=8, Predicted=15.6319, Expected=15.3126
# Month=9, Predicted=15.0596, Expected=14.7637
# Month=10, Predicted=14.4193, Expected=13.5468
# Month=11, Predicted=12.7615, Expected=13.5862
# Month=12, Predicted=13.6547, Expected=14.5157
# Month=13, Predicted=15.0414, Expected=14.3853
# Month=14, Predicted=14.3088, Expected=14.4975
# Month=15, Predicted=14.5675, Expected=14.7447
# Month=16, Predicted=14.8941, Expected=15.8052
# Month=17, Predicted=16.3963, Expected=16.5260
# Month=18, Predicted=16.9481, Expected=16.5451
# Month=19, Predicted=16.5600, Expected=16.7178
# Month=20, Predicted=16.8230, Expected=16.4322
# Month=21, Predicted=16.2514, Expected=15.7696
# Month=22, Predicted=15.3473, Expected=15.2792
# Month=23, Predicted=14.9820, Expected=15.1248
# Month=24, Predicted=15.0370, Expected=15.5403
# Month=25, Predicted=15.7900, Expected=15.8274
# Month=26, Predicted=16.0013, Expected=16.3752
# Month=27, Predicted=16.6979, Expected=16.3529
# Month=28, Predicted=16.3406, Expected=16.9050
# Month=29, Predicted=17.2306, Expected=17.0172
# Month=30, Predicted=17.0876, Expected=17.4183
# Month=31, Predicted=17.6577, Expected=17.5330
# Month=32, Predicted=17.6037, Expected=17.2714
# Month=33, Predicted=17.1061, Expected=16.6037
# Month=34, Predicted=16.1774, Expected=15.8246
# Month=35, Predicted=15.3369, Expected=15.4477
# Month=36, Predicted=15.2290, Expected=15.6316
# Month=37, Predicted=15.7490, Expected=15.6935
# Month=38, Predicted=15.7310, Expected=16.7565
# Month=39, Predicted=17.3491, Expected=16.5060
# Month=40, Predicted=16.3534, Expected=17.7253
# Month=41, Predicted=18.3945, Expected=18.6917
# Month=42, Predicted=19.2405, Expected=19.1262
# Month=43, Predicted=19.3899, Expected=19.5653
# Month=44, Predicted=19.8275, Expected=19.2076
# Month=45, Predicted=18.9816, Expected=18.2164
# Month=46, Predicted=17.5766, Expected=17.2115
# Month=47, Predicted=16.5893, Expected=16.6591
# Month=48, Predicted=16.3373, Expected=16.8293
# Month=49, Predicted=16.9431, Expected=15.7707
# Month=50, Predicted=15.0793, Expected=15.7293
# Month=51, Predicted=15.7389, Expected=15.9961
# Month=52, Predicted=16.1574, Expected=17.0200
# Month=53, Predicted=17.5933, Expected=17.5530
# Month=54, Predicted=17.8723, Expected=17.8377
# Month=55, Predicted=18.0110, Expected=17.8581
# Month=56, Predicted=17.8703, Expected=17.5700
# Month=57, Predicted=17.3881, Expected=17.0775
# Month=58, Predicted=16.7672, Expected=16.6580
# Month=59, Predicted=16.4008, Expected=16.4321
# Month=60, Predicted=16.2971, Expected=16.5848
# Run 4 — RMSE: 0.497298, MSE: 0.247305, NMSE: 0.0018818624
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.1977, Expected=13.7017
# Month=2, Predicted=14.0293, Expected=13.8117
# Month=3, Predicted=13.8577, Expected=14.3841
# Month=4, Predicted=14.7123, Expected=15.0499
# Month=5, Predicted=15.4288, Expected=15.6880
# Month=6, Predicted=16.0504, Expected=15.8424
# Month=7, Predicted=15.9151, Expected=15.7132
# Month=8, Predicted=15.6164, Expected=15.3126
# Month=9, Predicted=15.0548, Expected=14.7637
# Month=10, Predicted=14.4223, Expected=13.5468
# Month=11, Predicted=12.8234, Expected=13.5862
# Month=12, Predicted=13.6316, Expected=14.5157
# Month=13, Predicted=15.0501, Expected=14.3853
# Month=14, Predicted=14.2834, Expected=14.4975
# Month=15, Predicted=14.5528, Expected=14.7447
# Month=16, Predicted=14.8782, Expected=15.8052
# Month=17, Predicted=16.4029, Expected=16.5260
# Month=18, Predicted=16.9360, Expected=16.5451
# Month=19, Predicted=16.5350, Expected=16.7178
# Month=20, Predicted=16.8074, Expected=16.4322
# Month=21, Predicted=16.2397, Expected=15.7696
# Month=22, Predicted=15.3575, Expected=15.2792
# Month=23, Predicted=14.9800, Expected=15.1248
# Month=24, Predicted=15.0252, Expected=15.5403
# Month=25, Predicted=15.7796, Expected=15.8274
# Month=26, Predicted=15.9819, Expected=16.3752
# Month=27, Predicted=16.6869, Expected=16.3529
# Month=28, Predicted=16.3181, Expected=16.9050
# Month=29, Predicted=17.2231, Expected=17.0172
# Month=30, Predicted=17.0646, Expected=17.4183
# Month=31, Predicted=17.6446, Expected=17.5330
# Month=32, Predicted=17.5830, Expected=17.2714
# Month=33, Predicted=17.0942, Expected=16.6037
# Month=34, Predicted=16.1880, Expected=15.8246
# Month=35, Predicted=15.3535, Expected=15.4477
# Month=36, Predicted=15.2211, Expected=15.6316
# Month=37, Predicted=15.7357, Expected=15.6935
# Month=38, Predicted=15.7133, Expected=16.7565
# Month=39, Predicted=17.3574, Expected=16.5060
# Month=40, Predicted=16.3306, Expected=17.7253
# Month=41, Predicted=18.3952, Expected=18.6917
# Month=42, Predicted=19.2407, Expected=19.1262
# Month=43, Predicted=19.3676, Expected=19.5653
# Month=44, Predicted=19.8111, Expected=19.2076
# Month=45, Predicted=18.9686, Expected=18.2164
# Month=46, Predicted=17.6145, Expected=17.2115
# Month=47, Predicted=16.6205, Expected=16.6591
# Month=48, Predicted=16.3346, Expected=16.8293
# Month=49, Predicted=16.9297, Expected=15.7707
# Month=50, Predicted=15.1220, Expected=15.7293
# Month=51, Predicted=15.7183, Expected=15.9961
# Month=52, Predicted=16.1439, Expected=17.0200
# Month=53, Predicted=17.6014, Expected=17.5530
# Month=54, Predicted=17.8529, Expected=17.8377
# Month=55, Predicted=17.9900, Expected=17.8581
# Month=56, Predicted=17.8515, Expected=17.5700
# Month=57, Predicted=17.3781, Expected=17.0775
# Month=58, Predicted=16.7673, Expected=16.6580
# Month=59, Predicted=16.3970, Expected=16.4321
# Month=60, Predicted=16.2870, Expected=16.5848
# Run 5 — RMSE: 0.498627, MSE: 0.248629, NMSE: 0.0018985939
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2116, Expected=13.7017
# Month=2, Predicted=14.0399, Expected=13.8117
# Month=3, Predicted=13.8451, Expected=14.3841
# Month=4, Predicted=14.7232, Expected=15.0499
# Month=5, Predicted=15.4313, Expected=15.6880
# Month=6, Predicted=16.0511, Expected=15.8424
# Month=7, Predicted=15.9031, Expected=15.7132
# Month=8, Predicted=15.6044, Expected=15.3126
# Month=9, Predicted=15.0404, Expected=14.7637
# Month=10, Predicted=14.4129, Expected=13.5468
# Month=11, Predicted=12.7569, Expected=13.5862
# Month=12, Predicted=13.7121, Expected=14.5157
# Month=13, Predicted=15.0726, Expected=14.3853
# Month=14, Predicted=14.2592, Expected=14.4975
# Month=15, Predicted=14.5608, Expected=14.7447
# Month=16, Predicted=14.8810, Expected=15.8052
# Month=17, Predicted=16.4272, Expected=16.5260
# Month=18, Predicted=16.9362, Expected=16.5451
# Month=19, Predicted=16.5176, Expected=16.7178
# Month=20, Predicted=16.8111, Expected=16.4322
# Month=21, Predicted=16.2198, Expected=15.7696
# Month=22, Predicted=15.3330, Expected=15.2792
# Month=23, Predicted=14.9919, Expected=15.1248
# Month=24, Predicted=15.0439, Expected=15.5403
# Month=25, Predicted=15.7979, Expected=15.8274
# Month=26, Predicted=15.9776, Expected=16.3752
# Month=27, Predicted=16.6920, Expected=16.3529
# Month=28, Predicted=16.3012, Expected=16.9050
# Month=29, Predicted=17.2384, Expected=17.0172
# Month=30, Predicted=17.0525, Expected=17.4183
# Month=31, Predicted=17.6513, Expected=17.5330
# Month=32, Predicted=17.5736, Expected=17.2714
# Month=33, Predicted=17.0774, Expected=16.6037
# Month=34, Predicted=16.1618, Expected=15.8246
# Month=35, Predicted=15.3437, Expected=15.4477
# Month=36, Predicted=15.2490, Expected=15.6316
# Month=37, Predicted=15.7598, Expected=15.6935
# Month=38, Predicted=15.7080, Expected=16.7565
# Month=39, Predicted=17.3877, Expected=16.5060
# Month=40, Predicted=16.2994, Expected=17.7253
# Month=41, Predicted=18.4600, Expected=18.6917
# Month=42, Predicted=19.2446, Expected=19.1262
# Month=43, Predicted=19.3618, Expected=19.5653
# Month=44, Predicted=19.8103, Expected=19.2076
# Month=45, Predicted=18.9379, Expected=18.2164
# Month=46, Predicted=17.5628, Expected=17.2115
# Month=47, Predicted=16.6138, Expected=16.6591
# Month=48, Predicted=16.3706, Expected=16.8293
# Month=49, Predicted=16.9647, Expected=15.7707
# Month=50, Predicted=15.0390, Expected=15.7293
# Month=51, Predicted=15.7814, Expected=15.9961
# Month=52, Predicted=16.1539, Expected=17.0200
# Month=53, Predicted=17.6206, Expected=17.5530
# Month=54, Predicted=17.8490, Expected=17.8377
# Month=55, Predicted=17.9833, Expected=17.8581
# Month=56, Predicted=17.8415, Expected=17.5700
# Month=57, Predicted=17.3634, Expected=17.0775
# Month=58, Predicted=16.7552, Expected=16.6580
# Month=59, Predicted=16.4018, Expected=16.4321
# Month=60, Predicted=16.2979, Expected=16.5848
# Run 6 — RMSE: 0.499087, MSE: 0.249088, NMSE: 0.0019011858
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.1841, Expected=13.7017
# Month=2, Predicted=14.0259, Expected=13.8117
# Month=3, Predicted=13.8476, Expected=14.3841
# Month=4, Predicted=14.7087, Expected=15.0499
# Month=5, Predicted=15.4278, Expected=15.6880
# Month=6, Predicted=16.0495, Expected=15.8424
# Month=7, Predicted=15.9057, Expected=15.7132
# Month=8, Predicted=15.6050, Expected=15.3126
# Month=9, Predicted=15.0513, Expected=14.7637
# Month=10, Predicted=14.4264, Expected=13.5468
# Month=11, Predicted=12.9214, Expected=13.5862
# Month=12, Predicted=13.5993, Expected=14.5157
# Month=13, Predicted=15.0464, Expected=14.3853
# Month=14, Predicted=14.2754, Expected=14.4975
# Month=15, Predicted=14.5396, Expected=14.7447
# Month=16, Predicted=14.8685, Expected=15.8052
# Month=17, Predicted=16.4033, Expected=16.5260
# Month=18, Predicted=16.9372, Expected=16.5451
# Month=19, Predicted=16.5248, Expected=16.7178
# Month=20, Predicted=16.7959, Expected=16.4322
# Month=21, Predicted=16.2325, Expected=15.7696
# Month=22, Predicted=15.3740, Expected=15.2792
# Month=23, Predicted=14.9755, Expected=15.1248
# Month=24, Predicted=15.0087, Expected=15.5403
# Month=25, Predicted=15.7720, Expected=15.8274
# Month=26, Predicted=15.9741, Expected=16.3752
# Month=27, Predicted=16.6836, Expected=16.3529
# Month=28, Predicted=16.3073, Expected=16.9050
# Month=29, Predicted=17.2187, Expected=17.0172
# Month=30, Predicted=17.0545, Expected=17.4183
# Month=31, Predicted=17.6380, Expected=17.5330
# Month=32, Predicted=17.5723, Expected=17.2714
# Month=33, Predicted=17.0859, Expected=16.6037
# Month=34, Predicted=16.2054, Expected=15.8246
# Month=35, Predicted=15.3781, Expected=15.4477
# Month=36, Predicted=15.2073, Expected=15.6316
# Month=37, Predicted=15.7215, Expected=15.6935
# Month=38, Predicted=15.7014, Expected=16.7565
# Month=39, Predicted=17.3575, Expected=16.5060
# Month=40, Predicted=16.3258, Expected=17.7253
# Month=41, Predicted=18.4069, Expected=18.6917
# Month=42, Predicted=19.2394, Expected=19.1262
# Month=43, Predicted=19.3652, Expected=19.5653
# Month=44, Predicted=19.8064, Expected=19.2076
# Month=45, Predicted=18.9660, Expected=18.2164
# Month=46, Predicted=17.6752, Expected=17.2115
# Month=47, Predicted=16.6712, Expected=16.6591
# Month=48, Predicted=16.3275, Expected=16.8293
# Month=49, Predicted=16.9133, Expected=15.7707
# Month=50, Predicted=15.1990, Expected=15.7293
# Month=51, Predicted=15.6899, Expected=15.9961
# Month=52, Predicted=16.1339, Expected=17.0200
# Month=53, Predicted=17.5991, Expected=17.5530
# Month=54, Predicted=17.8523, Expected=17.8377
# Month=55, Predicted=17.9825, Expected=17.8581
# Month=56, Predicted=17.8397, Expected=17.5700
# Month=57, Predicted=17.3702, Expected=17.0775
# Month=58, Predicted=16.7683, Expected=16.6580
# Month=59, Predicted=16.3905, Expected=16.4321
# Month=60, Predicted=16.2730, Expected=16.5848
# Run 7 — RMSE: 0.498351, MSE: 0.248354, NMSE: 0.0019012324
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2082, Expected=13.7017
# Month=2, Predicted=14.0488, Expected=13.8117
# Month=3, Predicted=13.8393, Expected=14.3841
# Month=4, Predicted=14.7329, Expected=15.0499
# Month=5, Predicted=15.4347, Expected=15.6880
# Month=6, Predicted=16.0531, Expected=15.8424
# Month=7, Predicted=15.8968, Expected=15.7132
# Month=8, Predicted=15.6037, Expected=15.3126
# Month=9, Predicted=15.0432, Expected=14.7637
# Month=10, Predicted=14.4155, Expected=13.5468
# Month=11, Predicted=12.7957, Expected=13.5862
# Month=12, Predicted=13.6840, Expected=14.5157
# Month=13, Predicted=15.0789, Expected=14.3853
# Month=14, Predicted=14.2476, Expected=14.4975
# Month=15, Predicted=14.5599, Expected=14.7447
# Month=16, Predicted=14.8815, Expected=15.8052
# Month=17, Predicted=16.4338, Expected=16.5260
# Month=18, Predicted=16.9302, Expected=16.5451
# Month=19, Predicted=16.5091, Expected=16.7178
# Month=20, Predicted=16.8114, Expected=16.4322
# Month=21, Predicted=16.2206, Expected=15.7696
# Month=22, Predicted=15.3427, Expected=15.2792
# Month=23, Predicted=14.9860, Expected=15.1248
# Month=24, Predicted=15.0349, Expected=15.5403
# Month=25, Predicted=15.8009, Expected=15.8274
# Month=26, Predicted=15.9762, Expected=16.3752
# Month=27, Predicted=16.6995, Expected=16.3529
# Month=28, Predicted=16.2955, Expected=16.9050
# Month=29, Predicted=17.2477, Expected=17.0172
# Month=30, Predicted=17.0469, Expected=17.4183
# Month=31, Predicted=17.6557, Expected=17.5330
# Month=32, Predicted=17.5703, Expected=17.2714
# Month=33, Predicted=17.0783, Expected=16.6037
# Month=34, Predicted=16.1721, Expected=15.8246
# Month=35, Predicted=15.3495, Expected=15.4477
# Month=36, Predicted=15.2357, Expected=15.6316
# Month=37, Predicted=15.7540, Expected=15.6935
# Month=38, Predicted=15.7060, Expected=16.7565
# Month=39, Predicted=17.3956, Expected=16.5060
# Month=40, Predicted=16.2873, Expected=17.7253
# Month=41, Predicted=18.4661, Expected=18.6917
# Month=42, Predicted=19.2335, Expected=19.1262
# Month=43, Predicted=19.3550, Expected=19.5653
# Month=44, Predicted=19.8127, Expected=19.2076
# Month=45, Predicted=18.9381, Expected=18.2164
# Month=46, Predicted=17.5901, Expected=17.2115
# Month=47, Predicted=16.6224, Expected=16.6591
# Month=48, Predicted=16.3534, Expected=16.8293
# Month=49, Predicted=16.9543, Expected=15.7707
# Month=50, Predicted=15.0752, Expected=15.7293
# Month=51, Predicted=15.7599, Expected=15.9961
# Month=52, Predicted=16.1532, Expected=17.0200
# Month=53, Predicted=17.6270, Expected=17.5530
# Month=54, Predicted=17.8439, Expected=17.8377
# Month=55, Predicted=17.9807, Expected=17.8581
# Month=56, Predicted=17.8393, Expected=17.5700
# Month=57, Predicted=17.3647, Expected=17.0775
# Month=58, Predicted=16.7582, Expected=16.6580
# Month=59, Predicted=16.3981, Expected=16.4321
# Month=60, Predicted=16.2916, Expected=16.5848
# Run 8 — RMSE: 0.500495, MSE: 0.250495, NMSE: 0.0019140157
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2100, Expected=13.7017
# Month=2, Predicted=14.0301, Expected=13.8117
# Month=3, Predicted=13.8468, Expected=14.3841
# Month=4, Predicted=14.7143, Expected=15.0499
# Month=5, Predicted=15.4221, Expected=15.6880
# Month=6, Predicted=16.0438, Expected=15.8424
# Month=7, Predicted=15.9052, Expected=15.7132
# Month=8, Predicted=15.6041, Expected=15.3126
# Month=9, Predicted=15.0386, Expected=14.7637
# Month=10, Predicted=14.4124, Expected=13.5468
# Month=11, Predicted=12.7456, Expected=13.5862
# Month=12, Predicted=13.7400, Expected=14.5157
# Month=13, Predicted=15.0464, Expected=14.3853
# Month=14, Predicted=14.2646, Expected=14.4975
# Month=15, Predicted=14.5612, Expected=14.7447
# Month=16, Predicted=14.8783, Expected=15.8052
# Month=17, Predicted=16.4002, Expected=16.5260
# Month=18, Predicted=16.9301, Expected=16.5451
# Month=19, Predicted=16.5211, Expected=16.7178
# Month=20, Predicted=16.8101, Expected=16.4322
# Month=21, Predicted=16.2179, Expected=15.7696
# Month=22, Predicted=15.3292, Expected=15.2792
# Month=23, Predicted=14.9986, Expected=15.1248
# Month=24, Predicted=15.0462, Expected=15.5403
# Month=25, Predicted=15.7915, Expected=15.8274
# Month=26, Predicted=15.9759, Expected=16.3752
# Month=27, Predicted=16.6844, Expected=16.3529
# Month=28, Predicted=16.3031, Expected=16.9050
# Month=29, Predicted=17.2301, Expected=17.0172
# Month=30, Predicted=17.0539, Expected=17.4183
# Month=31, Predicted=17.6467, Expected=17.5330
# Month=32, Predicted=17.5738, Expected=17.2714
# Month=33, Predicted=17.0761, Expected=16.6037
# Month=34, Predicted=16.1574, Expected=15.8246
# Month=35, Predicted=15.3461, Expected=15.4477
# Month=36, Predicted=15.2580, Expected=15.6316
# Month=37, Predicted=15.7578, Expected=15.6935
# Month=38, Predicted=15.7067, Expected=16.7565
# Month=39, Predicted=17.3599, Expected=16.5060
# Month=40, Predicted=16.3057, Expected=17.7253
# Month=41, Predicted=18.4266, Expected=18.6917
# Month=42, Predicted=19.2311, Expected=19.1262
# Month=43, Predicted=19.3629, Expected=19.5653
# Month=44, Predicted=19.8063, Expected=19.2076
# Month=45, Predicted=18.9366, Expected=18.2164
# Month=46, Predicted=17.5542, Expected=17.2115
# Month=47, Predicted=16.6250, Expected=16.6591
# Month=48, Predicted=16.3833, Expected=16.8293
# Month=49, Predicted=16.9638, Expected=15.7707
# Month=50, Predicted=15.0216, Expected=15.7293
# Month=51, Predicted=15.8078, Expected=15.9961
# Month=52, Predicted=16.1474, Expected=17.0200
# Month=53, Predicted=17.5952, Expected=17.5530
# Month=54, Predicted=17.8483, Expected=17.8377
# Month=55, Predicted=17.9830, Expected=17.8581
# Month=56, Predicted=17.8416, Expected=17.5700
# Month=57, Predicted=17.3620, Expected=17.0775
# Month=58, Predicted=16.7539, Expected=16.6580
# Month=59, Predicted=16.4045, Expected=16.4321
# Month=60, Predicted=16.2995, Expected=16.5848
# Run 9 — RMSE: 0.496692, MSE: 0.246703, NMSE: 0.0018884332
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.1767, Expected=13.7017
# Month=2, Predicted=13.9911, Expected=13.8117
# Month=3, Predicted=13.7957, Expected=14.3841
# Month=4, Predicted=14.6756, Expected=15.0499
# Month=5, Predicted=15.3803, Expected=15.6880
# Month=6, Predicted=16.0001, Expected=15.8424
# Month=7, Predicted=15.8531, Expected=15.7132
# Month=8, Predicted=15.5651, Expected=15.3126
# Month=9, Predicted=15.0217, Expected=14.7637
# Month=10, Predicted=14.4159, Expected=13.5468
# Month=11, Predicted=12.8243, Expected=13.5862
# Month=12, Predicted=13.7630, Expected=14.5157
# Month=13, Predicted=15.0325, Expected=14.3853
# Month=14, Predicted=14.2189, Expected=14.4975
# Month=15, Predicted=14.5236, Expected=14.7447
# Month=16, Predicted=14.8329, Expected=15.8052
# Month=17, Predicted=16.3878, Expected=16.5260
# Month=18, Predicted=16.8895, Expected=16.5451
# Month=19, Predicted=16.4711, Expected=16.7178
# Month=20, Predicted=16.7673, Expected=16.4322
# Month=21, Predicted=16.1864, Expected=15.7696
# Month=22, Predicted=15.3376, Expected=15.2792
# Month=23, Predicted=15.0091, Expected=15.1248
# Month=24, Predicted=15.0316, Expected=15.5403
# Month=25, Predicted=15.7571, Expected=15.8274
# Month=26, Predicted=15.9252, Expected=16.3752
# Month=27, Predicted=16.6408, Expected=16.3529
# Month=28, Predicted=16.2552, Expected=16.9050
# Month=29, Predicted=17.1946, Expected=17.0172
# Month=30, Predicted=17.0029, Expected=17.4183
# Month=31, Predicted=17.6028, Expected=17.5330
# Month=32, Predicted=17.5241, Expected=17.2714
# Month=33, Predicted=17.0443, Expected=16.6037
# Month=34, Predicted=16.1655, Expected=15.8246
# Month=35, Predicted=15.3805, Expected=15.4477
# Month=36, Predicted=15.2683, Expected=15.6316
# Month=37, Predicted=15.7312, Expected=15.6935
# Month=38, Predicted=15.6616, Expected=16.7565
# Month=39, Predicted=17.3527, Expected=16.5060
# Month=40, Predicted=16.2656, Expected=17.7253
# Month=41, Predicted=18.4439, Expected=18.6917
# Month=42, Predicted=19.2059, Expected=19.1262
# Month=43, Predicted=19.3110, Expected=19.5653
# Month=44, Predicted=19.7574, Expected=19.2076
# Month=45, Predicted=18.9057, Expected=18.2164
# Month=46, Predicted=17.5981, Expected=17.2115
# Month=47, Predicted=16.6969, Expected=16.6591
# Month=48, Predicted=16.4184, Expected=16.8293
# Month=49, Predicted=16.9468, Expected=15.7707
# Month=50, Predicted=15.0608, Expected=15.7293
# Month=51, Predicted=15.8191, Expected=15.9961
# Month=52, Predicted=16.1078, Expected=17.0200
# Month=53, Predicted=17.5799, Expected=17.5530
# Month=54, Predicted=17.7992, Expected=17.8377
# Month=55, Predicted=17.9311, Expected=17.8581
# Month=56, Predicted=17.7954, Expected=17.5700
# Month=57, Predicted=17.3339, Expected=17.0775
# Month=58, Predicted=16.7488, Expected=16.6580
# Month=59, Predicted=16.4027, Expected=16.4321
# Month=60, Predicted=16.2843, Expected=16.5848
# Run 10 — RMSE: 0.497381, MSE: 0.247388, NMSE: 0.0019112879
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.2165, Expected=13.7017
# Month=2, Predicted=14.0413, Expected=13.8117
# Month=3, Predicted=13.8720, Expected=14.3841
# Month=4, Predicted=14.7244, Expected=15.0499
# Month=5, Predicted=15.4387, Expected=15.6880
# Month=6, Predicted=16.0619, Expected=15.8424
# Month=7, Predicted=15.9306, Expected=15.7132
# Month=8, Predicted=15.6245, Expected=15.3126
# Month=9, Predicted=15.0522, Expected=14.7637
# Month=10, Predicted=14.4143, Expected=13.5468
# Month=11, Predicted=12.7360, Expected=13.5862
# Month=12, Predicted=13.6770, Expected=14.5157
# Month=13, Predicted=15.0505, Expected=14.3853
# Month=14, Predicted=14.2967, Expected=14.4975
# Month=15, Predicted=14.5700, Expected=14.7447
# Month=16, Predicted=14.8937, Expected=15.8052
# Month=17, Predicted=16.4030, Expected=16.5260
# Month=18, Predicted=16.9497, Expected=16.5451
# Month=19, Predicted=16.5491, Expected=16.7178
# Month=20, Predicted=16.8234, Expected=16.4322
# Month=21, Predicted=16.2405, Expected=15.7696
# Month=22, Predicted=15.3366, Expected=15.2792
# Month=23, Predicted=14.9841, Expected=15.1248
# Month=24, Predicted=15.0428, Expected=15.5403
# Month=25, Predicted=15.7970, Expected=15.8274
# Month=26, Predicted=15.9967, Expected=16.3752
# Month=27, Predicted=16.6988, Expected=16.3529
# Month=28, Predicted=16.3296, Expected=16.9050
# Month=29, Predicted=17.2368, Expected=17.0172
# Month=30, Predicted=17.0789, Expected=17.4183
# Month=31, Predicted=17.6595, Expected=17.5330
# Month=32, Predicted=17.5966, Expected=17.2714
# Month=33, Predicted=17.0968, Expected=16.6037
# Month=34, Predicted=16.1661, Expected=15.8246
# Month=35, Predicted=15.3311, Expected=15.4477
# Month=36, Predicted=15.2364, Expected=15.6316
# Month=37, Predicted=15.7577, Expected=15.6935
# Month=38, Predicted=15.7264, Expected=16.7565
# Month=39, Predicted=17.3586, Expected=16.5060
# Month=40, Predicted=16.3394, Expected=17.7253
# Month=41, Predicted=18.4098, Expected=18.6917
# Month=42, Predicted=19.2445, Expected=19.1262
# Month=43, Predicted=19.3877, Expected=19.5653
# Month=44, Predicted=19.8249, Expected=19.2076
# Month=45, Predicted=18.9647, Expected=18.2164
# Month=46, Predicted=17.5564, Expected=17.2115
# Month=47, Predicted=16.5826, Expected=16.6591
# Month=48, Predicted=16.3458, Expected=16.8293
# Month=49, Predicted=16.9555, Expected=15.7707
# Month=50, Predicted=15.0446, Expected=15.7293
# Month=51, Predicted=15.7569, Expected=15.9961
# Month=52, Predicted=16.1605, Expected=17.0200
# Month=53, Predicted=17.5994, Expected=17.5530
# Month=54, Predicted=17.8715, Expected=17.8377
# Month=55, Predicted=18.0053, Expected=17.8581
# Month=56, Predicted=17.8634, Expected=17.5700
# Month=57, Predicted=17.3802, Expected=17.0775
# Month=58, Predicted=16.7612, Expected=16.6580
# Month=59, Predicted=16.4010, Expected=16.4321
# Month=60, Predicted=16.2999, Expected=16.5848
# Run 11 — RMSE: 0.498011, MSE: 0.248015, NMSE: 0.0018868217
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2122, Expected=13.7017
# Month=2, Predicted=14.0370, Expected=13.8117
# Month=3, Predicted=13.8763, Expected=14.3841
# Month=4, Predicted=14.7200, Expected=15.0499
# Month=5, Predicted=15.4369, Expected=15.6880
# Month=6, Predicted=16.0606, Expected=15.8424
# Month=7, Predicted=15.9345, Expected=15.7132
# Month=8, Predicted=15.6294, Expected=15.3126
# Month=9, Predicted=15.0581, Expected=14.7637
# Month=10, Predicted=14.4181, Expected=13.5468
# Month=11, Predicted=12.7525, Expected=13.5862
# Month=12, Predicted=13.6493, Expected=14.5157
# Month=13, Predicted=15.0439, Expected=14.3853
# Month=14, Predicted=14.3059, Expected=14.4975
# Month=15, Predicted=14.5674, Expected=14.7447
# Month=16, Predicted=14.8926, Expected=15.8052
# Month=17, Predicted=16.3989, Expected=16.5260
# Month=18, Predicted=16.9486, Expected=16.5451
# Month=19, Predicted=16.5553, Expected=16.7178
# Month=20, Predicted=16.8221, Expected=16.4322
# Month=21, Predicted=16.2483, Expected=15.7696
# Month=22, Predicted=15.3451, Expected=15.2792
# Month=23, Predicted=14.9808, Expected=15.1248
# Month=24, Predicted=15.0376, Expected=15.5403
# Month=25, Predicted=15.7905, Expected=15.8274
# Month=26, Predicted=15.9976, Expected=16.3752
# Month=27, Predicted=16.6962, Expected=16.3529
# Month=28, Predicted=16.3357, Expected=16.9050
# Month=29, Predicted=17.2310, Expected=17.0172
# Month=30, Predicted=17.0830, Expected=17.4183
# Month=31, Predicted=17.6567, Expected=17.5330
# Month=32, Predicted=17.5998, Expected=17.2714
# Month=33, Predicted=17.1035, Expected=16.6037
# Month=34, Predicted=16.1751, Expected=15.8246
# Month=35, Predicted=15.3336, Expected=15.4477
# Month=36, Predicted=15.2278, Expected=15.6316
# Month=37, Predicted=15.7501, Expected=15.6935
# Month=38, Predicted=15.7286, Expected=16.7565
# Month=39, Predicted=17.3529, Expected=16.5060
# Month=40, Predicted=16.3509, Expected=17.7253
# Month=41, Predicted=18.4021, Expected=18.6917
# Month=42, Predicted=19.2433, Expected=19.1262
# Month=43, Predicted=19.3889, Expected=19.5653
# Month=44, Predicted=19.8242, Expected=19.2076
# Month=45, Predicted=18.9761, Expected=18.2164
# Month=46, Predicted=17.5713, Expected=17.2115
# Month=47, Predicted=16.5807, Expected=16.6591
# Month=48, Predicted=16.3335, Expected=16.8293
# Month=49, Predicted=16.9445, Expected=15.7707
# Month=50, Predicted=15.0696, Expected=15.7293
# Month=51, Predicted=15.7355, Expected=15.9961
# Month=52, Predicted=16.1571, Expected=17.0200
# Month=53, Predicted=17.5953, Expected=17.5530
# Month=54, Predicted=17.8717, Expected=17.8377
# Month=55, Predicted=18.0069, Expected=17.8581
# Month=56, Predicted=17.8671, Expected=17.5700
# Month=57, Predicted=17.3861, Expected=17.0775
# Month=58, Predicted=16.7661, Expected=16.6580
# Month=59, Predicted=16.4004, Expected=16.4321
# Month=60, Predicted=16.2974, Expected=16.5848
# Run 12 — RMSE: 0.498107, MSE: 0.248111, NMSE: 0.0018864024
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2002, Expected=13.7017
# Month=2, Predicted=14.0253, Expected=13.8117
# Month=3, Predicted=13.8632, Expected=14.3841
# Month=4, Predicted=14.7080, Expected=15.0499
# Month=5, Predicted=15.4238, Expected=15.6880
# Month=6, Predicted=16.0459, Expected=15.8424
# Month=7, Predicted=15.9205, Expected=15.7132
# Month=8, Predicted=15.6140, Expected=15.3126
# Month=9, Predicted=15.0473, Expected=14.7637
# Month=10, Predicted=14.4132, Expected=13.5468
# Month=11, Predicted=12.8252, Expected=13.5862
# Month=12, Predicted=13.6233, Expected=14.5157
# Month=13, Predicted=15.0387, Expected=14.3853
# Month=14, Predicted=14.2813, Expected=14.4975
# Month=15, Predicted=14.5563, Expected=14.7447
# Month=16, Predicted=14.8807, Expected=15.8052
# Month=17, Predicted=16.3932, Expected=16.5260
# Month=18, Predicted=16.9293, Expected=16.5451
# Month=19, Predicted=16.5372, Expected=16.7178
# Month=20, Predicted=16.8108, Expected=16.4322
# Month=21, Predicted=16.2346, Expected=15.7696
# Month=22, Predicted=15.3506, Expected=15.2792
# Month=23, Predicted=14.9684, Expected=15.1248
# Month=24, Predicted=15.0183, Expected=15.5403
# Month=25, Predicted=15.7770, Expected=15.8274
# Month=26, Predicted=15.9847, Expected=16.3752
# Month=27, Predicted=16.6838, Expected=16.3529
# Month=28, Predicted=16.3191, Expected=16.9050
# Month=29, Predicted=17.2186, Expected=17.0172
# Month=30, Predicted=17.0703, Expected=17.4183
# Month=31, Predicted=17.6440, Expected=17.5330
# Month=32, Predicted=17.5886, Expected=17.2714
# Month=33, Predicted=17.0892, Expected=16.6037
# Month=34, Predicted=16.1813, Expected=15.8246
# Month=35, Predicted=15.3454, Expected=15.4477
# Month=36, Predicted=15.2086, Expected=15.6316
# Month=37, Predicted=15.7361, Expected=15.6935
# Month=38, Predicted=15.7166, Expected=16.7565
# Month=39, Predicted=17.3471, Expected=16.5060
# Month=40, Predicted=16.3260, Expected=17.7253
# Month=41, Predicted=18.3894, Expected=18.6917
# Month=42, Predicted=19.2290, Expected=19.1262
# Month=43, Predicted=19.3671, Expected=19.5653
# Month=44, Predicted=19.8107, Expected=19.2076
# Month=45, Predicted=18.9636, Expected=18.2164
# Month=46, Predicted=17.6147, Expected=17.2115
# Month=47, Predicted=16.6150, Expected=16.6591
# Month=48, Predicted=16.3199, Expected=16.8293
# Month=49, Predicted=16.9289, Expected=15.7707
# Month=50, Predicted=15.1278, Expected=15.7293
# Month=51, Predicted=15.7089, Expected=15.9961
# Month=52, Predicted=16.1453, Expected=17.0200
# Month=53, Predicted=17.5907, Expected=17.5530
# Month=54, Predicted=17.8502, Expected=17.8377
# Month=55, Predicted=17.9929, Expected=17.8581
# Month=56, Predicted=17.8535, Expected=17.5700
# Month=57, Predicted=17.3723, Expected=17.0775
# Month=58, Predicted=16.7587, Expected=16.6580
# Month=59, Predicted=16.3868, Expected=16.4321
# Month=60, Predicted=16.2792, Expected=16.5848
# Run 13 — RMSE: 0.497903, MSE: 0.247907, NMSE: 0.0018932505
#
# ===== RUN 14/30 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 112
#     110 run_losses = []
#     111 for epoch in range(100):
# --> 112     history = model.fit(
#     113         X_train, y_train,
#     114         epochs=1, batch_size=1,
#     115         verbose=0, shuffle=False
#     116     )
#     117     run_losses.append(history.history['loss'][0])
#     118     rnn_layer.reset_states()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)   1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)   1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/Research/snn_venv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
