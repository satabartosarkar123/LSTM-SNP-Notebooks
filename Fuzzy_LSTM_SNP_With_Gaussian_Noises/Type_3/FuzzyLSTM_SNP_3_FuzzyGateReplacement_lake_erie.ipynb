# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value clipped to $[0, 1]$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.15.0
# NumPy version: 1.26.4

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Gate Replacement
# Uses FuzzyLSTMSNPCell instead of LSTMSNPCell.
# Gradient clipping applied for stability.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 1, 1)]               0
#
#  rnn (RNN)                   (1, 8)                    464
#
#  dense (Dense)               (1, 1)                    9
#
# =================================================================
# Total params: 473 (1.85 KB)
# Trainable params: 473 (1.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    '../../content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()

import numpy as np
original_raw_values = np.copy(raw_values)
s_x = np.std(original_raw_values)
noise_levels = [0.005]

for lam in noise_levels:
    sigma = lam * s_x
    print("\n" + "="*80)
    print(f"EVALUATING NOISE LEVEL: {lam*100:.1f}% (lambda={lam}, sigma={sigma:.6f})")
    print("="*80 + "\n")
    
    np.random.seed(42)
    tf.random.set_seed(42)
    noise = np.random.normal(0, sigma, size=original_raw_values.shape)
    raw_values = original_raw_values + noise
    
    print(f"Data shape: {raw_values.shape}")
    print(f"First 5 values: {raw_values[:5]}")
    
    # ============================================================
    # 2. First-Order Differencing
    # ============================================================
    
    def difference(dataset, interval=1):
        diff = []
        for i in range(interval, len(dataset)):
            value = dataset[i] - dataset[i - interval]
            diff.append(value)
        return np.array(diff)
    
    diff_values = difference(raw_values, 1)
    
    # ============================================================
    # 3. Convert to Supervised Learning Format (lag=1)
    # ============================================================
    
    def timeseries_to_supervised(data, lag=1):
        df = pd.DataFrame(data)
        columns = [df.shift(i) for i in range(1, lag+1)]
        columns.append(df)
        df = pd.concat(columns, axis=1)
        df.fillna(0, inplace=True)
        return df.values
    
    supervised = timeseries_to_supervised(diff_values, 1)
    print(f"Supervised data shape: {supervised.shape}")
    
    # ============================================================
    # 4. Train-Test Split
    # ============================================================
    
    train, test = supervised[:-60], supervised[-60:]
    print(f"Train: {train.shape}, Test: {test.shape}")
    
    # ============================================================
    # 5. Feature Scaling
    # ============================================================
    
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler.fit(train)
    
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    # ============================================================
    # 6. Reshape for RNN Input
    # ============================================================
    
    X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
    X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
    
    X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
    print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
    
    # ============================================================
    # 30-Run Experiment Protocol
    # ============================================================
    
    all_rmse = []
    all_mse = []
    all_nmse = []
    all_predictions = []
    all_losses = []
    
    for run in range(30):
        print(f'\n===== RUN {run+1}/30 =====')
    
        np.random.seed(run)
        tf.random.set_seed(run)
    
        tf.keras.backend.clear_session()
        model = build_model(input_dim=1, units=8, batch_size=1)
    
        rnn_layer = model.layers[1]
    
        # Training with manual epoch loop + reset_states
        run_losses = []
        for epoch in range(100):
            history = model.fit(
                X_train, y_train,
                epochs=1, batch_size=1,
                verbose=0, shuffle=False
            )
            run_losses.append(history.history['loss'][0])
            rnn_layer.reset_states()
    
        all_losses.append(run_losses)
        print(f'Training complete for run {run+1}')
    
        # Warm-up: condition hidden states on training data
        train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
        model.predict(train_reshaped, batch_size=1, verbose=0)
    
        # Test predictions (single-step)
        predictions = []
        for i in range(len(test_scaled)):
            X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
            X_input = X.reshape(1, 1, len(X))
            yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]
    
            # Invert scaling
            new_row = [x for x in X] + [yhat]
            array = np.array(new_row).reshape(1, len(new_row))
            inverted = scaler.inverse_transform(array)[0, -1]
    
            # Invert differencing
            inverted = inverted + raw_values[len(train) + i]
            predictions.append(inverted)
    
            expected = raw_values[len(train) + i + 1]
            print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')
    
        # Compute metrics
        actual = raw_values[-60:]
        rmse = sqrt(mean_squared_error(actual, predictions))
        mse = mean_squared_error(actual, predictions)
        meanV = np.mean(actual)
        dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
        nmse = mse / np.power(dominator, 2)
    
        all_rmse.append(rmse)
        all_mse.append(mse)
        all_nmse.append(nmse)
        all_predictions.append(predictions)
    
        print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
    
    # ============================================================
    # Summary Statistics (30 runs)
    # ============================================================
    
    print('\n===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Lake Erie Levels (30 runs) =====')
    print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
    print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
    print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')
    
    best_idx = np.argmin(all_rmse)
    print(f'\nBest run: {best_idx+1}')
    print(f'  RMSE: {all_rmse[best_idx]:.6f}')
    print(f'  MSE:  {all_mse[best_idx]:.6f}')
    print(f'  NMSE: {all_nmse[best_idx]:.10f}')
    
    # ============================================================
    # Predictions vs Actual (Best Run)
    # ============================================================
    
    actual = raw_values[-60:]
    best_predictions = all_predictions[best_idx]
    
    plt.figure(figsize=(12, 5))
    plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
    plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
             linewidth=1.5, linestyle='--')
    plt.title('Fuzzy Gate Replacement — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
    plt.xlabel('Time Step')
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Loss Curve (Best Run)
    # ============================================================
    
    plt.figure(figsize=(12, 4))
    plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
    plt.title('Fuzzy Gate Replacement — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # ============================================================
    # Final Metrics Summary
    # ============================================================
    
    print('=== Best Run Metrics ===')
    print(f'RMSE: {all_rmse[best_idx]:.6f}')
    print(f'MSE:  {all_mse[best_idx]:.6f}')
    print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ================================================================================
# EVALUATING NOISE LEVEL: 0.5% (lambda=0.005, sigma=0.010052)
# ================================================================================
#
# Data shape: (600,)
# First 5 values: [14.76799303 14.64761015 15.09151064 16.39130966 16.92364626]
# Supervised data shape: (599, 2)
# Train: (539, 2), Test: (60, 2)
# X_train shape: (539, 1, 1), y_train shape: (539,)
#
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=13.2068, Expected=13.7084
# Month=2, Predicted=14.0510, Expected=13.8026
# Month=3, Predicted=13.8679, Expected=14.3883
# Month=4, Predicted=14.7323, Expected=15.0615
# Month=5, Predicted=15.4512, Expected=15.6682
# Month=6, Predicted=16.0231, Expected=15.8360
# Month=7, Predicted=15.9463, Expected=15.7178
# Month=8, Predicted=15.6369, Expected=15.3110
# Month=9, Predicted=15.0426, Expected=14.7667
# Month=10, Predicted=14.4129, Expected=13.5419
# Month=11, Predicted=12.7796, Expected=13.5869
# Month=12, Predicted=13.6198, Expected=14.5144
# Month=13, Predicted=15.0323, Expected=14.3947
# Month=14, Predicted=14.3137, Expected=14.4996
# Month=15, Predicted=14.5732, Expected=14.7474
# Month=16, Predicted=14.9043, Expected=15.8019
# Month=17, Predicted=16.3797, Expected=16.5221
# Month=18, Predicted=16.9372, Expected=16.5417
# Month=19, Predicted=16.5549, Expected=16.7210
# Month=20, Predicted=16.8384, Expected=16.4288
# Month=21, Predicted=16.2332, Expected=15.7719
# Month=22, Predicted=15.3484, Expected=15.2959
# Month=23, Predicted=14.9850, Expected=15.1318
# Month=24, Predicted=15.0217, Expected=15.5377
# Month=25, Predicted=15.7845, Expected=15.8371
# Month=26, Predicted=16.0231, Expected=16.3719
# Month=27, Predicted=16.6884, Expected=16.3365
# Month=28, Predicted=16.3116, Expected=16.8969
# Month=29, Predicted=17.2276, Expected=17.0022
# Month=30, Predicted=17.0753, Expected=17.4155
# Month=31, Predicted=17.6658, Expected=17.5332
# Month=32, Predicted=17.6141, Expected=17.2849
# Month=33, Predicted=17.1179, Expected=16.6063
# Month=34, Predicted=16.1694, Expected=15.8228
# Month=35, Predicted=15.3232, Expected=15.4543
# Month=36, Predicted=15.2117, Expected=15.6138
# Month=37, Predicted=15.7205, Expected=15.6954
# Month=38, Predicted=15.7519, Expected=16.7627
# Month=39, Predicted=17.3468, Expected=16.4941
# Month=40, Predicted=16.3148, Expected=17.7345
# Month=41, Predicted=18.3971, Expected=18.6944
# Month=42, Predicted=19.2281, Expected=19.1228
# Month=43, Predicted=19.3823, Expected=19.5704
# Month=44, Predicted=19.8393, Expected=19.2258
# Month=45, Predicted=18.9963, Expected=18.2178
# Month=46, Predicted=17.5838, Expected=17.2135
# Month=47, Predicted=16.5824, Expected=16.6554
# Month=48, Predicted=16.2937, Expected=16.8225
# Month=49, Predicted=16.9341, Expected=15.7773
# Month=50, Predicted=15.1204, Expected=15.7224
# Month=51, Predicted=15.6865, Expected=15.9967
# Month=52, Predicted=16.1691, Expected=17.0162
# Month=53, Predicted=17.5776, Expected=17.5568
# Month=54, Predicted=17.8775, Expected=17.8404
# Month=55, Predicted=18.0174, Expected=17.8664
# Month=56, Predicted=17.8840, Expected=17.5659
# Month=57, Predicted=17.3652, Expected=17.0753
# Month=58, Predicted=16.7546, Expected=16.6502
# Month=59, Predicted=16.3711, Expected=16.4285
# Month=60, Predicted=16.2804, Expected=16.5878
# Run 1 — RMSE: 0.499217, MSE: 0.249217, NMSE: 0.0018941956
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2030, Expected=13.7084
# Month=2, Predicted=14.0431, Expected=13.8026
# Month=3, Predicted=13.8203, Expected=14.3883
# Month=4, Predicted=14.7254, Expected=15.0615
# Month=5, Predicted=15.4180, Expected=15.6682
# Month=6, Predicted=15.9888, Expected=15.8360
# Month=7, Predicted=15.9006, Expected=15.7178
# Month=8, Predicted=15.6148, Expected=15.3110
# Month=9, Predicted=15.0271, Expected=14.7667
# Month=10, Predicted=14.4159, Expected=13.5419
# Month=11, Predicted=12.8373, Expected=13.5869
# Month=12, Predicted=13.6996, Expected=14.5144
# Month=13, Predicted=15.0147, Expected=14.3947
# Month=14, Predicted=14.2569, Expected=14.4996
# Month=15, Predicted=14.5628, Expected=14.7474
# Month=16, Predicted=14.8892, Expected=15.8019
# Month=17, Predicted=16.3469, Expected=16.5221
# Month=18, Predicted=16.8883, Expected=16.5417
# Month=19, Predicted=16.5042, Expected=16.7210
# Month=20, Predicted=16.8238, Expected=16.4288
# Month=21, Predicted=16.2061, Expected=15.7719
# Month=22, Predicted=15.3503, Expected=15.2959
# Month=23, Predicted=15.0034, Expected=15.1318
# Month=24, Predicted=15.0412, Expected=15.5377
# Month=25, Predicted=15.7957, Expected=15.8371
# Month=26, Predicted=15.9954, Expected=16.3719
# Month=27, Predicted=16.6731, Expected=16.3365
# Month=28, Predicted=16.2703, Expected=16.8969
# Month=29, Predicted=17.2288, Expected=17.0022
# Month=30, Predicted=17.0282, Expected=17.4155
# Month=31, Predicted=17.6611, Expected=17.5332
# Month=32, Predicted=17.5741, Expected=17.2849
# Month=33, Predicted=17.0960, Expected=16.6063
# Month=34, Predicted=16.1697, Expected=15.8228
# Month=35, Predicted=15.3599, Expected=15.4543
# Month=36, Predicted=15.2478, Expected=15.6138
# Month=37, Predicted=15.7300, Expected=15.6954
# Month=38, Predicted=15.7263, Expected=16.7627
# Month=39, Predicted=17.3214, Expected=16.4941
# Month=40, Predicted=16.2527, Expected=17.7345
# Month=41, Predicted=18.3828, Expected=18.6944
# Month=42, Predicted=19.1705, Expected=19.1228
# Month=43, Predicted=19.3404, Expected=19.5704
# Month=44, Predicted=19.8200, Expected=19.2258
# Month=45, Predicted=18.9526, Expected=18.2178
# Month=46, Predicted=17.6112, Expected=17.2135
# Month=47, Predicted=16.6577, Expected=16.6554
# Month=48, Predicted=16.3451, Expected=16.8225
# Month=49, Predicted=16.9579, Expected=15.7773
# Month=50, Predicted=15.1218, Expected=15.7224
# Month=51, Predicted=15.7524, Expected=15.9967
# Month=52, Predicted=16.1654, Expected=17.0162
# Month=53, Predicted=17.5450, Expected=17.5568
# Month=54, Predicted=17.8352, Expected=17.8404
# Month=55, Predicted=17.9822, Expected=17.8664
# Month=56, Predicted=17.8536, Expected=17.5659
# Month=57, Predicted=17.3466, Expected=17.0753
# Month=58, Predicted=16.7469, Expected=16.6502
# Month=59, Predicted=16.3803, Expected=16.4285
# Month=60, Predicted=16.2948, Expected=16.5878
# Run 2 — RMSE: 0.496360, MSE: 0.246373, NMSE: 0.0019023509
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.1652, Expected=13.7084
# Month=2, Predicted=14.0130, Expected=13.8026
# Month=3, Predicted=13.8256, Expected=14.3883
# Month=4, Predicted=14.6945, Expected=15.0615
# Month=5, Predicted=15.4155, Expected=15.6682
# Month=6, Predicted=15.9841, Expected=15.8360
# Month=7, Predicted=15.9010, Expected=15.7178
# Month=8, Predicted=15.6208, Expected=15.3110
# Month=9, Predicted=15.0520, Expected=14.7667
# Month=10, Predicted=14.4329, Expected=13.5419
# Month=11, Predicted=12.8399, Expected=13.5869
# Month=12, Predicted=13.5968, Expected=14.5144
# Month=13, Predicted=15.0146, Expected=14.3947
# Month=14, Predicted=14.2950, Expected=14.4996
# Month=15, Predicted=14.5318, Expected=14.7474
# Month=16, Predicted=14.8602, Expected=15.8019
# Month=17, Predicted=16.3714, Expected=16.5221
# Month=18, Predicted=16.9025, Expected=16.5417
# Month=19, Predicted=16.5216, Expected=16.7210
# Month=20, Predicted=16.7950, Expected=16.4288
# Month=21, Predicted=16.2328, Expected=15.7719
# Month=22, Predicted=15.3744, Expected=15.2959
# Month=23, Predicted=15.0026, Expected=15.1318
# Month=24, Predicted=15.0133, Expected=15.5377
# Month=25, Predicted=15.7428, Expected=15.8371
# Month=26, Predicted=15.9780, Expected=16.3719
# Month=27, Predicted=16.6480, Expected=16.3365
# Month=28, Predicted=16.2854, Expected=16.8969
# Month=29, Predicted=17.1894, Expected=17.0022
# Month=30, Predicted=17.0315, Expected=17.4155
# Month=31, Predicted=17.6230, Expected=17.5332
# Month=32, Predicted=17.5700, Expected=17.2849
# Month=33, Predicted=17.1141, Expected=16.6063
# Month=34, Predicted=16.1964, Expected=15.8228
# Month=35, Predicted=15.3589, Expected=15.4543
# Month=36, Predicted=15.2230, Expected=15.6138
# Month=37, Predicted=15.6793, Expected=15.6954
# Month=38, Predicted=15.7126, Expected=16.7627
# Month=39, Predicted=17.3403, Expected=16.4941
# Month=40, Predicted=16.3097, Expected=17.7345
# Month=41, Predicted=18.4086, Expected=18.6944
# Month=42, Predicted=19.2097, Expected=19.1228
# Month=43, Predicted=19.3368, Expected=19.5704
# Month=44, Predicted=19.7961, Expected=19.2258
# Month=45, Predicted=18.9992, Expected=18.2178
# Month=46, Predicted=17.6290, Expected=17.2135
# Month=47, Predicted=16.6331, Expected=16.6554
# Month=48, Predicted=16.3200, Expected=16.8225
# Month=49, Predicted=16.8942, Expected=15.7773
# Month=50, Predicted=15.1656, Expected=15.7224
# Month=51, Predicted=15.6726, Expected=15.9967
# Month=52, Predicted=16.1257, Expected=17.0162
# Month=53, Predicted=17.5663, Expected=17.5568
# Month=54, Predicted=17.8349, Expected=17.8404
# Month=55, Predicted=17.9718, Expected=17.8664
# Month=56, Predicted=17.8513, Expected=17.5659
# Month=57, Predicted=17.3660, Expected=17.0753
# Month=58, Predicted=16.7706, Expected=16.6502
# Month=59, Predicted=16.3839, Expected=16.4285
# Month=60, Predicted=16.2769, Expected=16.5878
# Run 3 — RMSE: 0.500730, MSE: 0.250730, NMSE: 0.0019158475
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.1511, Expected=13.7084
# Month=2, Predicted=13.9835, Expected=13.8026
# Month=3, Predicted=13.7875, Expected=14.3883
# Month=4, Predicted=14.6667, Expected=15.0615
# Month=5, Predicted=15.3760, Expected=15.6682
# Month=6, Predicted=15.9432, Expected=15.8360
# Month=7, Predicted=15.8617, Expected=15.7178
# Month=8, Predicted=15.5971, Expected=15.3110
# Month=9, Predicted=15.0485, Expected=14.7667
# Month=10, Predicted=14.4493, Expected=13.5419
# Month=11, Predicted=12.8980, Expected=13.5869
# Month=12, Predicted=13.6597, Expected=14.5144
# Month=13, Predicted=14.9913, Expected=14.3947
# Month=14, Predicted=14.2610, Expected=14.4996
# Month=15, Predicted=14.5151, Expected=14.7474
# Month=16, Predicted=14.8313, Expected=15.8019
# Month=17, Predicted=16.3485, Expected=16.5221
# Month=18, Predicted=16.8631, Expected=16.5417
# Month=19, Predicted=16.4841, Expected=16.7210
# Month=20, Predicted=16.7709, Expected=16.4288
# Month=21, Predicted=16.2136, Expected=15.7719
# Month=22, Predicted=15.3900, Expected=15.2959
# Month=23, Predicted=15.0318, Expected=15.1318
# Month=24, Predicted=15.0195, Expected=15.5377
# Month=25, Predicted=15.7243, Expected=15.8371
# Month=26, Predicted=15.9401, Expected=16.3719
# Month=27, Predicted=16.6130, Expected=16.3365
# Month=28, Predicted=16.2508, Expected=16.8969
# Month=29, Predicted=17.1668, Expected=17.0022
# Month=30, Predicted=16.9935, Expected=17.4155
# Month=31, Predicted=17.5941, Expected=17.5332
# Month=32, Predicted=17.5343, Expected=17.2849
# Month=33, Predicted=17.0958, Expected=16.6063
# Month=34, Predicted=16.2107, Expected=15.8228
# Month=35, Predicted=15.4026, Expected=15.4543
# Month=36, Predicted=15.2564, Expected=15.6138
# Month=37, Predicted=15.6724, Expected=15.6954
# Month=38, Predicted=15.6837, Expected=16.7627
# Month=39, Predicted=17.3238, Expected=16.4941
# Month=40, Predicted=16.2808, Expected=17.7345
# Month=41, Predicted=18.4180, Expected=18.6944
# Month=42, Predicted=19.1751, Expected=19.1228
# Month=43, Predicted=19.2950, Expected=19.5704
# Month=44, Predicted=19.7577, Expected=19.2258
# Month=45, Predicted=18.9756, Expected=18.2178
# Month=46, Predicted=17.6655, Expected=17.2135
# Month=47, Predicted=16.7109, Expected=16.6554
# Month=48, Predicted=16.3757, Expected=16.8225
# Month=49, Predicted=16.8984, Expected=15.7773
# Month=50, Predicted=15.1824, Expected=15.7224
# Month=51, Predicted=15.7227, Expected=15.9967
# Month=52, Predicted=16.1005, Expected=17.0162
# Month=53, Predicted=17.5412, Expected=17.5568
# Month=54, Predicted=17.7936, Expected=17.8404
# Month=55, Predicted=17.9321, Expected=17.8664
# Month=56, Predicted=17.8206, Expected=17.5659
# Month=57, Predicted=17.3528, Expected=17.0753
# Month=58, Predicted=16.7792, Expected=16.6502
# Month=59, Predicted=16.4003, Expected=16.4285
# Month=60, Predicted=16.2821, Expected=16.5878
# Run 4 — RMSE: 0.499292, MSE: 0.249292, NMSE: 0.0019282949
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.1710, Expected=13.7084
# Month=2, Predicted=14.0171, Expected=13.8026
# Month=3, Predicted=13.8114, Expected=14.3883
# Month=4, Predicted=14.6997, Expected=15.0615
# Month=5, Predicted=15.4148, Expected=15.6682
# Month=6, Predicted=15.9819, Expected=15.8360
# Month=7, Predicted=15.8886, Expected=15.7178
# Month=8, Predicted=15.6071, Expected=15.3110
# Month=9, Predicted=15.0408, Expected=14.7667
# Month=10, Predicted=14.4338, Expected=13.5419
# Month=11, Predicted=12.8343, Expected=13.5869
# Month=12, Predicted=13.6893, Expected=14.5144
# Month=13, Predicted=15.0253, Expected=14.3947
# Month=14, Predicted=14.2756, Expected=14.4996
# Month=15, Predicted=14.5338, Expected=14.7474
# Month=16, Predicted=14.8570, Expected=15.8019
# Month=17, Predicted=16.3787, Expected=16.5221
# Month=18, Predicted=16.9016, Expected=16.5417
# Month=19, Predicted=16.5053, Expected=16.7210
# Month=20, Predicted=16.7932, Expected=16.4288
# Month=21, Predicted=16.2142, Expected=15.7719
# Month=22, Predicted=15.3660, Expected=15.2959
# Month=23, Predicted=15.0235, Expected=15.1318
# Month=24, Predicted=15.0274, Expected=15.5377
# Month=25, Predicted=15.7532, Expected=15.8371
# Month=26, Predicted=15.9701, Expected=16.3719
# Month=27, Predicted=16.6473, Expected=16.3365
# Month=28, Predicted=16.2682, Expected=16.8969
# Month=29, Predicted=17.1985, Expected=17.0022
# Month=30, Predicted=17.0177, Expected=17.4155
# Month=31, Predicted=17.6241, Expected=17.5332
# Month=32, Predicted=17.5577, Expected=17.2849
# Month=33, Predicted=17.0984, Expected=16.6063
# Month=34, Predicted=16.1851, Expected=15.8228
# Month=35, Predicted=15.3739, Expected=15.4543
# Month=36, Predicted=15.2568, Expected=15.6138
# Month=37, Predicted=15.6942, Expected=15.6954
# Month=38, Predicted=15.7036, Expected=16.7627
# Month=39, Predicted=17.3513, Expected=16.4941
# Month=40, Predicted=16.2852, Expected=17.7345
# Month=41, Predicted=18.4295, Expected=18.6944
# Month=42, Predicted=19.2102, Expected=19.1228
# Month=43, Predicted=19.3310, Expected=19.5704
# Month=44, Predicted=19.7916, Expected=19.2258
# Month=45, Predicted=18.9750, Expected=18.2178
# Month=46, Predicted=17.6161, Expected=17.2135
# Month=47, Predicted=16.6729, Expected=16.6554
# Month=48, Predicted=16.3686, Expected=16.8225
# Month=49, Predicted=16.9215, Expected=15.7773
# Month=50, Predicted=15.1306, Expected=15.7224
# Month=51, Predicted=15.7438, Expected=15.9967
# Month=52, Predicted=16.1270, Expected=17.0162
# Month=53, Predicted=17.5736, Expected=17.5568
# Month=54, Predicted=17.8309, Expected=17.8404
# Month=55, Predicted=17.9626, Expected=17.8664
# Month=56, Predicted=17.8387, Expected=17.5659
# Month=57, Predicted=17.3519, Expected=17.0753
# Month=58, Predicted=16.7665, Expected=16.6502
# Month=59, Predicted=16.3932, Expected=16.4285
# Month=60, Predicted=16.2865, Expected=16.5878
# Run 5 — RMSE: 0.498133, MSE: 0.248136, NMSE: 0.0019067310
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2116, Expected=13.7084
# Month=2, Predicted=14.0487, Expected=13.8026
# Month=3, Predicted=13.8335, Expected=14.3883
# Month=4, Predicted=14.7314, Expected=15.0615
# Month=5, Predicted=15.4388, Expected=15.6682
# Month=6, Predicted=16.0075, Expected=15.8360
# Month=7, Predicted=15.9186, Expected=15.7178
# Month=8, Predicted=15.6133, Expected=15.3110
# Month=9, Predicted=15.0262, Expected=14.7667
# Month=10, Predicted=14.4138, Expected=13.5419
# Month=11, Predicted=12.7738, Expected=13.5869
# Month=12, Predicted=13.7355, Expected=14.5144
# Month=13, Predicted=15.0440, Expected=14.3947
# Month=14, Predicted=14.2725, Expected=14.4996
# Month=15, Predicted=14.5721, Expected=14.7474
# Month=16, Predicted=14.8936, Expected=15.8019
# Month=17, Predicted=16.3901, Expected=16.5221
# Month=18, Predicted=16.9235, Expected=16.5417
# Month=19, Predicted=16.5181, Expected=16.7210
# Month=20, Predicted=16.8306, Expected=16.4288
# Month=21, Predicted=16.2033, Expected=15.7719
# Month=22, Predicted=15.3352, Expected=15.2959
# Month=23, Predicted=15.0143, Expected=15.1318
# Month=24, Predicted=15.0460, Expected=15.5377
# Month=25, Predicted=15.7927, Expected=15.8371
# Month=26, Predicted=16.0025, Expected=16.3719
# Month=27, Predicted=16.6778, Expected=16.3365
# Month=28, Predicted=16.2767, Expected=16.8969
# Month=29, Predicted=17.2325, Expected=17.0022
# Month=30, Predicted=17.0412, Expected=17.4155
# Month=31, Predicted=17.6595, Expected=17.5332
# Month=32, Predicted=17.5842, Expected=17.2849
# Month=33, Predicted=17.0928, Expected=16.6063
# Month=34, Predicted=16.1520, Expected=15.8228
# Month=35, Predicted=15.3402, Expected=15.4543
# Month=36, Predicted=15.2611, Expected=15.6138
# Month=37, Predicted=15.7378, Expected=15.6954
# Month=38, Predicted=15.7316, Expected=16.7627
# Month=39, Predicted=17.3642, Expected=16.4941
# Month=40, Predicted=16.2700, Expected=17.7345
# Month=41, Predicted=18.4424, Expected=18.6944
# Month=42, Predicted=19.2254, Expected=19.1228
# Month=43, Predicted=19.3588, Expected=19.5704
# Month=44, Predicted=19.8224, Expected=19.2258
# Month=45, Predicted=18.9549, Expected=18.2178
# Month=46, Predicted=17.5643, Expected=17.2135
# Month=47, Predicted=16.6272, Expected=16.6554
# Month=48, Predicted=16.3591, Expected=16.8225
# Month=49, Predicted=16.9677, Expected=15.7773
# Month=50, Predicted=15.0703, Expected=15.7224
# Month=51, Predicted=15.7884, Expected=15.9967
# Month=52, Predicted=16.1667, Expected=17.0162
# Month=53, Predicted=17.5855, Expected=17.5568
# Month=54, Predicted=17.8576, Expected=17.8404
# Month=55, Predicted=17.9939, Expected=17.8664
# Month=56, Predicted=17.8576, Expected=17.5659
# Month=57, Predicted=17.3435, Expected=17.0753
# Month=58, Predicted=16.7488, Expected=16.6502
# Month=59, Predicted=16.3853, Expected=16.4285
# Month=60, Predicted=16.2973, Expected=16.5878
# Run 6 — RMSE: 0.496533, MSE: 0.246545, NMSE: 0.0018895332
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.1908, Expected=13.7084
# Month=2, Predicted=14.0454, Expected=13.8026
# Month=3, Predicted=13.8534, Expected=14.3883
# Month=4, Predicted=14.7269, Expected=15.0615
# Month=5, Predicted=15.4531, Expected=15.6682
# Month=6, Predicted=16.0241, Expected=15.8360
# Month=7, Predicted=15.9321, Expected=15.7178
# Month=8, Predicted=15.6327, Expected=15.3110
# Month=9, Predicted=15.0462, Expected=14.7667
# Month=10, Predicted=14.4223, Expected=13.5419
# Month=11, Predicted=12.7640, Expected=13.5869
# Month=12, Predicted=13.6607, Expected=14.5144
# Month=13, Predicted=15.0418, Expected=14.3947
# Month=14, Predicted=14.3230, Expected=14.4996
# Month=15, Predicted=14.5556, Expected=14.7474
# Month=16, Predicted=14.8876, Expected=15.8019
# Month=17, Predicted=16.3956, Expected=16.5221
# Month=18, Predicted=16.9505, Expected=16.5417
# Month=19, Predicted=16.5498, Expected=16.7210
# Month=20, Predicted=16.8204, Expected=16.4288
# Month=21, Predicted=16.2340, Expected=15.7719
# Month=22, Predicted=15.3510, Expected=15.2959
# Month=23, Predicted=15.0065, Expected=15.1318
# Month=24, Predicted=15.0317, Expected=15.5377
# Month=25, Predicted=15.7755, Expected=15.8371
# Month=26, Predicted=16.0091, Expected=16.3719
# Month=27, Predicted=16.6813, Expected=16.3365
# Month=28, Predicted=16.3063, Expected=16.8969
# Month=29, Predicted=17.2221, Expected=17.0022
# Month=30, Predicted=17.0592, Expected=17.4155
# Month=31, Predicted=17.6540, Expected=17.5332
# Month=32, Predicted=17.5955, Expected=17.2849
# Month=33, Predicted=17.1180, Expected=16.6063
# Month=34, Predicted=16.1701, Expected=15.8228
# Month=35, Predicted=15.3366, Expected=15.4543
# Month=36, Predicted=15.2405, Expected=15.6138
# Month=37, Predicted=15.7096, Expected=15.6954
# Month=38, Predicted=15.7342, Expected=16.7627
# Month=39, Predicted=17.3634, Expected=16.4941
# Month=40, Predicted=16.3303, Expected=17.7345
# Month=41, Predicted=18.4271, Expected=18.6944
# Month=42, Predicted=19.2521, Expected=19.1228
# Month=43, Predicted=19.3848, Expected=19.5704
# Month=44, Predicted=19.8302, Expected=19.2258
# Month=45, Predicted=18.9995, Expected=18.2178
# Month=46, Predicted=17.5718, Expected=17.2135
# Month=47, Predicted=16.6045, Expected=16.6554
# Month=48, Predicted=16.3339, Expected=16.8225
# Month=49, Predicted=16.9303, Expected=15.7773
# Month=50, Predicted=15.0982, Expected=15.7224
# Month=51, Predicted=15.7226, Expected=15.9967
# Month=52, Predicted=16.1541, Expected=17.0162
# Month=53, Predicted=17.5919, Expected=17.5568
# Month=54, Predicted=17.8840, Expected=17.8404
# Month=55, Predicted=18.0049, Expected=17.8664
# Month=56, Predicted=17.8713, Expected=17.5659
# Month=57, Predicted=17.3666, Expected=17.0753
# Month=58, Predicted=16.7616, Expected=16.6502
# Month=59, Predicted=16.3854, Expected=16.4285
# Month=60, Predicted=16.2903, Expected=16.5878
# Run 7 — RMSE: 0.498523, MSE: 0.248525, NMSE: 0.0018870607
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.1361, Expected=13.7084
# Month=2, Predicted=13.9447, Expected=13.8026
# Month=3, Predicted=13.7970, Expected=14.3883
# Month=4, Predicted=14.6260, Expected=15.0615
# Month=5, Predicted=15.3493, Expected=15.6682
# Month=6, Predicted=15.9183, Expected=15.8360
# Month=7, Predicted=15.8632, Expected=15.7178
# Month=8, Predicted=15.6229, Expected=15.3110
# Month=9, Predicted=15.1142, Expected=14.7667
# Month=10, Predicted=14.5433, Expected=13.5419
# Month=11, Predicted=13.2758, Expected=13.5869
# Month=12, Predicted=13.6695, Expected=14.5144
# Month=13, Predicted=14.9525, Expected=14.3947
# Month=14, Predicted=14.2994, Expected=14.4996
# Month=15, Predicted=14.4986, Expected=14.7474
# Month=16, Predicted=14.8108, Expected=15.8019
# Month=17, Predicted=16.3186, Expected=16.5221
# Month=18, Predicted=16.8426, Expected=16.5417
# Month=19, Predicted=16.5037, Expected=16.7210
# Month=20, Predicted=16.7524, Expected=16.4288
# Month=21, Predicted=16.2697, Expected=15.7719
# Month=22, Predicted=15.5199, Expected=15.2959
# Month=23, Predicted=15.1114, Expected=15.1318
# Month=24, Predicted=15.0450, Expected=15.5377
# Month=25, Predicted=15.6838, Expected=15.8371
# Month=26, Predicted=15.9261, Expected=16.3719
# Month=27, Predicted=16.5820, Expected=16.3365
# Month=28, Predicted=16.2760, Expected=16.8969
# Month=29, Predicted=17.1207, Expected=17.0022
# Month=30, Predicted=17.0015, Expected=17.4155
# Month=31, Predicted=17.5605, Expected=17.5332
# Month=32, Predicted=17.5377, Expected=17.2849
# Month=33, Predicted=17.1413, Expected=16.6063
# Month=34, Predicted=16.3536, Expected=15.8228
# Month=35, Predicted=15.5669, Expected=15.4543
# Month=36, Predicted=15.3173, Expected=15.6138
# Month=37, Predicted=15.6563, Expected=15.6954
# Month=38, Predicted=15.6830, Expected=16.7627
# Month=39, Predicted=17.2875, Expected=16.4941
# Month=40, Predicted=16.3483, Expected=17.7345
# Month=41, Predicted=18.3861, Expected=18.6944
# Month=42, Predicted=19.1752, Expected=19.1228
# Month=43, Predicted=19.2756, Expected=19.5704
# Month=44, Predicted=19.7342, Expected=19.2258
# Month=45, Predicted=19.0501, Expected=18.2178
# Month=46, Predicted=17.9561, Expected=17.2135
# Month=47, Predicted=16.9519, Expected=16.6554
# Month=48, Predicted=16.4731, Expected=16.8225
# Month=49, Predicted=16.8865, Expected=15.7773
# Month=50, Predicted=15.5147, Expected=15.7224
# Month=51, Predicted=15.7372, Expected=15.9967
# Month=52, Predicted=16.0730, Expected=17.0162
# Month=53, Predicted=17.5111, Expected=17.5568
# Month=54, Predicted=17.7732, Expected=17.8404
# Month=55, Predicted=17.9219, Expected=17.8664
# Month=56, Predicted=17.8306, Expected=17.5659
# Month=57, Predicted=17.4040, Expected=17.0753
# Month=58, Predicted=16.8618, Expected=16.6502
# Month=59, Predicted=16.4701, Expected=16.4285
# Month=60, Predicted=16.3157, Expected=16.5878
# Run 8 — RMSE: 0.500153, MSE: 0.250154, NMSE: 0.0019775518
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.1564, Expected=13.7084
# Month=2, Predicted=13.9978, Expected=13.8026
# Month=3, Predicted=13.7857, Expected=14.3883
# Month=4, Predicted=14.6814, Expected=15.0615
# Month=5, Predicted=15.3884, Expected=15.6682
# Month=6, Predicted=15.9529, Expected=15.8360
# Month=7, Predicted=15.8614, Expected=15.7178
# Month=8, Predicted=15.5938, Expected=15.3110
# Month=9, Predicted=15.0403, Expected=14.7667
# Month=10, Predicted=14.4403, Expected=13.5419
# Month=11, Predicted=12.8694, Expected=13.5869
# Month=12, Predicted=13.6781, Expected=14.5144
# Month=13, Predicted=15.0135, Expected=14.3947
# Month=14, Predicted=14.2490, Expected=14.4996
# Month=15, Predicted=14.5200, Expected=14.7474
# Month=16, Predicted=14.8373, Expected=15.8019
# Month=17, Predicted=16.3714, Expected=16.5221
# Month=18, Predicted=16.8694, Expected=16.5417
# Month=19, Predicted=16.4788, Expected=16.7210
# Month=20, Predicted=16.7762, Expected=16.4288
# Month=21, Predicted=16.2058, Expected=15.7719
# Month=22, Predicted=15.3768, Expected=15.2959
# Month=23, Predicted=15.0277, Expected=15.1318
# Month=24, Predicted=15.0204, Expected=15.5377
# Month=25, Predicted=15.7363, Expected=15.8371
# Month=26, Predicted=15.9450, Expected=16.3719
# Month=27, Predicted=16.6246, Expected=16.3365
# Month=28, Predicted=16.2463, Expected=16.8969
# Month=29, Predicted=17.1820, Expected=17.0022
# Month=30, Predicted=16.9922, Expected=17.4155
# Month=31, Predicted=17.6043, Expected=17.5332
# Month=32, Predicted=17.5347, Expected=17.2849
# Month=33, Predicted=17.0897, Expected=16.6063
# Month=34, Predicted=16.1963, Expected=15.8228
# Month=35, Predicted=15.3903, Expected=15.4543
# Month=36, Predicted=15.2561, Expected=15.6138
# Month=37, Predicted=15.6799, Expected=15.6954
# Month=38, Predicted=15.6853, Expected=16.7627
# Month=39, Predicted=17.3479, Expected=16.4941
# Month=40, Predicted=16.2631, Expected=17.7345
# Month=41, Predicted=18.4443, Expected=18.6944
# Month=42, Predicted=19.1844, Expected=19.1228
# Month=43, Predicted=19.2955, Expected=19.5704
# Month=44, Predicted=19.7662, Expected=19.2258
# Month=45, Predicted=18.9642, Expected=18.2178
# Month=46, Predicted=17.6423, Expected=17.2135
# Month=47, Predicted=16.6976, Expected=16.6554
# Month=48, Predicted=16.3727, Expected=16.8225
# Month=49, Predicted=16.9076, Expected=15.7773
# Month=50, Predicted=15.1526, Expected=15.7224
# Month=51, Predicted=15.7370, Expected=15.9967
# Month=52, Predicted=16.1080, Expected=17.0162
# Month=53, Predicted=17.5634, Expected=17.5568
# Month=54, Predicted=17.7960, Expected=17.8404
# Month=55, Predicted=17.9354, Expected=17.8664
# Month=56, Predicted=17.8199, Expected=17.5659
# Month=57, Predicted=17.3461, Expected=17.0753
# Month=58, Predicted=16.7706, Expected=16.6502
# Month=59, Predicted=16.3953, Expected=16.4285
# Month=60, Predicted=16.2812, Expected=16.5878
# Run 9 — RMSE: 0.500255, MSE: 0.250255, NMSE: 0.0019313219
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.1972, Expected=13.7084
# Month=2, Predicted=14.0544, Expected=13.8026
# Month=3, Predicted=13.8500, Expected=14.3883
# Month=4, Predicted=14.7360, Expected=15.0615
# Month=5, Predicted=15.4546, Expected=15.6682
# Month=6, Predicted=16.0229, Expected=15.8360
# Month=7, Predicted=15.9288, Expected=15.7178
# Month=8, Predicted=15.6357, Expected=15.3110
# Month=9, Predicted=15.0497, Expected=14.7667
# Month=10, Predicted=14.4244, Expected=13.5419
# Month=11, Predicted=12.7800, Expected=13.5869
# Month=12, Predicted=13.6469, Expected=14.5144
# Month=13, Predicted=15.0523, Expected=14.3947
# Month=14, Predicted=14.3066, Expected=14.4996
# Month=15, Predicted=14.5620, Expected=14.7474
# Month=16, Predicted=14.8942, Expected=15.8019
# Month=17, Predicted=16.3990, Expected=16.5221
# Month=18, Predicted=16.9394, Expected=16.5417
# Month=19, Predicted=16.5417, Expected=16.7210
# Month=20, Predicted=16.8271, Expected=16.4288
# Month=21, Predicted=16.2359, Expected=15.7719
# Month=22, Predicted=15.3551, Expected=15.2959
# Month=23, Predicted=15.0043, Expected=15.1318
# Month=24, Predicted=15.0336, Expected=15.5377
# Month=25, Predicted=15.7844, Expected=15.8371
# Month=26, Predicted=16.0119, Expected=16.3719
# Month=27, Predicted=16.6877, Expected=16.3365
# Month=28, Predicted=16.3030, Expected=16.8969
# Month=29, Predicted=17.2318, Expected=17.0022
# Month=30, Predicted=17.0566, Expected=17.4155
# Month=31, Predicted=17.6620, Expected=17.5332
# Month=32, Predicted=17.5964, Expected=17.2849
# Month=33, Predicted=17.1208, Expected=16.6063
# Month=34, Predicted=16.1747, Expected=15.8228
# Month=35, Predicted=15.3365, Expected=15.4543
# Month=36, Predicted=15.2357, Expected=15.6138
# Month=37, Predicted=15.7154, Expected=15.6954
# Month=38, Predicted=15.7389, Expected=16.7627
# Month=39, Predicted=17.3668, Expected=16.4941
# Month=40, Predicted=16.3095, Expected=17.7345
# Month=41, Predicted=18.4085, Expected=18.6944
# Month=42, Predicted=19.2394, Expected=19.1228
# Month=43, Predicted=19.3728, Expected=19.5704
# Month=44, Predicted=19.8338, Expected=19.2258
# Month=45, Predicted=18.9967, Expected=18.2178
# Month=46, Predicted=17.5823, Expected=17.2135
# Month=47, Predicted=16.6010, Expected=16.6554
# Month=48, Predicted=16.3239, Expected=16.8225
# Month=49, Predicted=16.9338, Expected=15.7773
# Month=50, Predicted=15.1098, Expected=15.7224
# Month=51, Predicted=15.7125, Expected=15.9967
# Month=52, Predicted=16.1622, Expected=17.0162
# Month=53, Predicted=17.5989, Expected=17.5568
# Month=54, Predicted=17.8719, Expected=17.8404
# Month=55, Predicted=18.0045, Expected=17.8664
# Month=56, Predicted=17.8738, Expected=17.5659
# Month=57, Predicted=17.3699, Expected=17.0753
# Month=58, Predicted=16.7645, Expected=16.6502
# Month=59, Predicted=16.3861, Expected=16.4285
# Month=60, Predicted=16.2924, Expected=16.5878
# Run 10 — RMSE: 0.500182, MSE: 0.250182, NMSE: 0.0019045584
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.0932, Expected=13.7084
# Month=2, Predicted=13.6764, Expected=13.8026
# Month=3, Predicted=13.7706, Expected=14.3883
# Month=4, Predicted=14.3563, Expected=15.0615
# Month=5, Predicted=15.0295, Expected=15.6682
# Month=6, Predicted=15.6361, Expected=15.8360
# Month=7, Predicted=15.8040, Expected=15.7178
# Month=8, Predicted=15.6858, Expected=15.3110
# Month=9, Predicted=15.2789, Expected=14.7667
# Month=10, Predicted=14.7347, Expected=13.5419
# Month=11, Predicted=13.5099, Expected=13.5869
# Month=12, Predicted=13.5548, Expected=14.5144
# Month=13, Predicted=14.4824, Expected=14.3947
# Month=14, Predicted=14.3627, Expected=14.4996
# Month=15, Predicted=14.4675, Expected=14.7474
# Month=16, Predicted=14.7154, Expected=15.8019
# Month=17, Predicted=15.7698, Expected=16.5221
# Month=18, Predicted=16.4901, Expected=16.5417
# Month=19, Predicted=16.5096, Expected=16.7210
# Month=20, Predicted=16.6889, Expected=16.4288
# Month=21, Predicted=16.3967, Expected=15.7719
# Month=22, Predicted=15.7399, Expected=15.2959
# Month=23, Predicted=15.2638, Expected=15.1318
# Month=24, Predicted=15.0997, Expected=15.5377
# Month=25, Predicted=15.5057, Expected=15.8371
# Month=26, Predicted=15.8051, Expected=16.3719
# Month=27, Predicted=16.3399, Expected=16.3365
# Month=28, Predicted=16.3045, Expected=16.8969
# Month=29, Predicted=16.8648, Expected=17.0022
# Month=30, Predicted=16.9702, Expected=17.4155
# Month=31, Predicted=17.3834, Expected=17.5332
# Month=32, Predicted=17.5012, Expected=17.2849
# Month=33, Predicted=17.2528, Expected=16.6063
# Month=34, Predicted=16.5743, Expected=15.8228
# Month=35, Predicted=15.7908, Expected=15.4543
# Month=36, Predicted=15.4223, Expected=15.6138
# Month=37, Predicted=15.5818, Expected=15.6954
# Month=38, Predicted=15.6633, Expected=16.7627
# Month=39, Predicted=16.7307, Expected=16.4941
# Month=40, Predicted=16.4621, Expected=17.7345
# Month=41, Predicted=17.7025, Expected=18.6944
# Month=42, Predicted=18.6624, Expected=19.1228
# Month=43, Predicted=19.0908, Expected=19.5704
# Month=44, Predicted=19.5383, Expected=19.2258
# Month=45, Predicted=19.1938, Expected=18.2178
# Month=46, Predicted=18.1858, Expected=17.2135
# Month=47, Predicted=17.1815, Expected=16.6554
# Month=48, Predicted=16.6234, Expected=16.8225
# Month=49, Predicted=16.7904, Expected=15.7773
# Month=50, Predicted=15.7453, Expected=15.7224
# Month=51, Predicted=15.6904, Expected=15.9967
# Month=52, Predicted=15.9647, Expected=17.0162
# Month=53, Predicted=16.9842, Expected=17.5568
# Month=54, Predicted=17.5248, Expected=17.8404
# Month=55, Predicted=17.8083, Expected=17.8664
# Month=56, Predicted=17.8344, Expected=17.5659
# Month=57, Predicted=17.5339, Expected=17.0753
# Month=58, Predicted=17.0433, Expected=16.6502
# Month=59, Predicted=16.6181, Expected=16.4285
# Month=60, Predicted=16.3965, Expected=16.5878
# Run 11 — RMSE: 0.566362, MSE: 0.320766, NMSE: 0.0026623046
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2134, Expected=13.7084
# Month=2, Predicted=14.0535, Expected=13.8026
# Month=3, Predicted=13.8068, Expected=14.3883
# Month=4, Predicted=14.7370, Expected=15.0615
# Month=5, Predicted=15.4352, Expected=15.6682
# Month=6, Predicted=16.0000, Expected=15.8360
# Month=7, Predicted=15.8956, Expected=15.7178
# Month=8, Predicted=15.5911, Expected=15.3110
# Month=9, Predicted=15.0111, Expected=14.7667
# Month=10, Predicted=14.4093, Expected=13.5419
# Month=11, Predicted=12.8060, Expected=13.5869
# Month=12, Predicted=13.7706, Expected=14.5144
# Month=13, Predicted=15.0613, Expected=14.3947
# Month=14, Predicted=14.2341, Expected=14.4996
# Month=15, Predicted=14.5702, Expected=14.7474
# Month=16, Predicted=14.8889, Expected=15.8019
# Month=17, Predicted=16.4057, Expected=16.5221
# Month=18, Predicted=16.9173, Expected=16.5417
# Month=19, Predicted=16.4852, Expected=16.7210
# Month=20, Predicted=16.8270, Expected=16.4288
# Month=21, Predicted=16.1788, Expected=15.7719
# Month=22, Predicted=15.3309, Expected=15.2959
# Month=23, Predicted=15.0164, Expected=15.1318
# Month=24, Predicted=15.0446, Expected=15.5377
# Month=25, Predicted=15.8000, Expected=15.8371
# Month=26, Predicted=15.9913, Expected=16.3719
# Month=27, Predicted=16.6763, Expected=16.3365
# Month=28, Predicted=16.2461, Expected=16.8969
# Month=29, Predicted=17.2410, Expected=17.0022
# Month=30, Predicted=17.0157, Expected=17.4155
# Month=31, Predicted=17.6595, Expected=17.5332
# Month=32, Predicted=17.5640, Expected=17.2849
# Month=33, Predicted=17.0703, Expected=16.6063
# Month=34, Predicted=16.1473, Expected=15.8228
# Month=35, Predicted=15.3509, Expected=15.4543
# Month=36, Predicted=15.2671, Expected=15.6138
# Month=37, Predicted=15.7452, Expected=15.6954
# Month=38, Predicted=15.7175, Expected=16.7627
# Month=39, Predicted=17.3829, Expected=16.4941
# Month=40, Predicted=16.2300, Expected=17.7345
# Month=41, Predicted=18.4560, Expected=18.6944
# Month=42, Predicted=19.2265, Expected=19.1228
# Month=43, Predicted=19.3432, Expected=19.5704
# Month=44, Predicted=19.8151, Expected=19.2258
# Month=45, Predicted=18.9238, Expected=18.2178
# Month=46, Predicted=17.5793, Expected=17.2135
# Month=47, Predicted=16.6573, Expected=16.6554
# Month=48, Predicted=16.3729, Expected=16.8225
# Month=49, Predicted=16.9813, Expected=15.7773
# Month=50, Predicted=15.0768, Expected=15.7224
# Month=51, Predicted=15.8159, Expected=15.9967
# Month=52, Predicted=16.1671, Expected=17.0162
# Month=53, Predicted=17.5998, Expected=17.5568
# Month=54, Predicted=17.8454, Expected=17.8404
# Month=55, Predicted=17.9789, Expected=17.8664
# Month=56, Predicted=17.8368, Expected=17.5659
# Month=57, Predicted=17.3235, Expected=17.0753
# Month=58, Predicted=16.7402, Expected=16.6502
# Month=59, Predicted=16.3817, Expected=16.4285
# Month=60, Predicted=16.2927, Expected=16.5878
# Run 12 — RMSE: 0.497542, MSE: 0.247548, NMSE: 0.0019054223
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.1972, Expected=13.7084
# Month=2, Predicted=14.0530, Expected=13.8026
# Month=3, Predicted=13.8312, Expected=14.3883
# Month=4, Predicted=14.7353, Expected=15.0615
# Month=5, Predicted=15.4451, Expected=15.6682
# Month=6, Predicted=16.0104, Expected=15.8360
# Month=7, Predicted=15.9104, Expected=15.7178
# Month=8, Predicted=15.6245, Expected=15.3110
# Month=9, Predicted=15.0445, Expected=14.7667
# Month=10, Predicted=14.4262, Expected=13.5419
# Month=11, Predicted=12.7856, Expected=13.5869
# Month=12, Predicted=13.6707, Expected=14.5144
# Month=13, Predicted=15.0598, Expected=14.3947
# Month=14, Predicted=14.2794, Expected=14.4996
# Month=15, Predicted=14.5598, Expected=14.7474
# Month=16, Predicted=14.8879, Expected=15.8019
# Month=17, Predicted=16.4052, Expected=16.5221
# Month=18, Predicted=16.9249, Expected=16.5417
# Month=19, Predicted=16.5195, Expected=16.7210
# Month=20, Predicted=16.8221, Expected=16.4288
# Month=21, Predicted=16.2235, Expected=15.7719
# Month=22, Predicted=15.3540, Expected=15.2959
# Month=23, Predicted=15.0125, Expected=15.1318
# Month=24, Predicted=15.0382, Expected=15.5377
# Month=25, Predicted=15.7867, Expected=15.8371
# Month=26, Predicted=15.9992, Expected=16.3719
# Month=27, Predicted=16.6814, Expected=16.3365
# Month=28, Predicted=16.2840, Expected=16.8969
# Month=29, Predicted=17.2337, Expected=17.0022
# Month=30, Predicted=17.0384, Expected=17.4155
# Month=31, Predicted=17.6581, Expected=17.5332
# Month=32, Predicted=17.5814, Expected=17.2849
# Month=33, Predicted=17.1101, Expected=16.6063
# Month=34, Predicted=16.1725, Expected=15.8228
# Month=35, Predicted=15.3450, Expected=15.4543
# Month=36, Predicted=15.2472, Expected=15.6138
# Month=37, Predicted=15.7198, Expected=15.6954
# Month=38, Predicted=15.7294, Expected=16.7627
# Month=39, Predicted=17.3771, Expected=16.4941
# Month=40, Predicted=16.2816, Expected=17.7345
# Month=41, Predicted=18.4319, Expected=18.6944
# Month=42, Predicted=19.2314, Expected=19.1228
# Month=43, Predicted=19.3518, Expected=19.5704
# Month=44, Predicted=19.8231, Expected=19.2258
# Month=45, Predicted=18.9780, Expected=18.2178
# Month=46, Predicted=17.5830, Expected=17.2135
# Month=47, Predicted=16.6171, Expected=16.6554
# Month=48, Predicted=16.3402, Expected=16.8225
# Month=49, Predicted=16.9430, Expected=15.7773
# Month=50, Predicted=15.0982, Expected=15.7224
# Month=51, Predicted=15.7317, Expected=15.9967
# Month=52, Predicted=16.1599, Expected=17.0162
# Month=53, Predicted=17.6033, Expected=17.5568
# Month=54, Predicted=17.8533, Expected=17.8404
# Month=55, Predicted=17.9889, Expected=17.8664
# Month=56, Predicted=17.8609, Expected=17.5659
# Month=57, Predicted=17.3613, Expected=17.0753
# Month=58, Predicted=16.7638, Expected=16.6502
# Month=59, Predicted=16.3902, Expected=16.4285
# Month=60, Predicted=16.2956, Expected=16.5878
# Run 13 — RMSE: 0.500758, MSE: 0.250759, NMSE: 0.0019155363
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2270, Expected=13.7084
# Month=2, Predicted=14.1129, Expected=13.8026
# Month=3, Predicted=13.6658, Expected=14.3883
# Month=4, Predicted=14.7911, Expected=15.0615
# Month=5, Predicted=15.3919, Expected=15.6682
# Month=6, Predicted=15.9092, Expected=15.8360
# Month=7, Predicted=15.7423, Expected=15.7178
# Month=8, Predicted=15.5281, Expected=15.3110
# Month=9, Predicted=15.0220, Expected=14.7667
# Month=10, Predicted=14.4696, Expected=13.5419
# Month=11, Predicted=13.0359, Expected=13.5869
# Month=12, Predicted=14.0046, Expected=14.5144
# Month=13, Predicted=15.2034, Expected=14.3947
# Month=14, Predicted=14.0735, Expected=14.4996
# Month=15, Predicted=14.5402, Expected=14.7474
# Month=16, Predicted=14.8541, Expected=15.8019
# Month=17, Predicted=16.4722, Expected=16.5221
# Month=18, Predicted=16.7873, Expected=16.5417
# Month=19, Predicted=16.3267, Expected=16.7210
# Month=20, Predicted=16.7850, Expected=16.4288
# Month=21, Predicted=16.1429, Expected=15.7719
# Month=22, Predicted=15.4015, Expected=15.2959
# Month=23, Predicted=15.0909, Expected=15.1318
# Month=24, Predicted=15.0908, Expected=15.5377
# Month=25, Predicted=15.8795, Expected=15.8371
# Month=26, Predicted=15.9015, Expected=16.3719
# Month=27, Predicted=16.6597, Expected=16.3365
# Month=28, Predicted=16.1251, Expected=16.8969
# Month=29, Predicted=17.3221, Expected=17.0022
# Month=30, Predicted=16.8785, Expected=17.4155
# Month=31, Predicted=17.6533, Expected=17.5332
# Month=32, Predicted=17.4505, Expected=17.2849
# Month=33, Predicted=17.0312, Expected=16.6063
# Month=34, Predicted=16.2206, Expected=15.8228
# Month=35, Predicted=15.4716, Expected=15.4543
# Month=36, Predicted=15.3567, Expected=15.6138
# Month=37, Predicted=15.8126, Expected=15.6954
# Month=38, Predicted=15.6551, Expected=16.7627
# Month=39, Predicted=17.4729, Expected=16.4941
# Month=40, Predicted=16.0986, Expected=17.7345
# Month=41, Predicted=18.5731, Expected=18.6944
# Month=42, Predicted=19.1873, Expected=19.1228
# Month=43, Predicted=19.1494, Expected=19.5704
# Month=44, Predicted=19.7382, Expected=19.2258
# Month=45, Predicted=18.8677, Expected=18.2178
# Month=46, Predicted=17.7365, Expected=17.2135
# Month=47, Predicted=16.8345, Expected=16.6554
# Month=48, Predicted=16.5019, Expected=16.8225
# Month=49, Predicted=17.1036, Expected=15.7773
# Month=50, Predicted=15.2375, Expected=15.7224
# Month=51, Predicted=15.9479, Expected=15.9967
# Month=52, Predicted=16.1906, Expected=17.0162
# Month=53, Predicted=17.6714, Expected=17.5568
# Month=54, Predicted=17.6686, Expected=17.8404
# Month=55, Predicted=17.8487, Expected=17.8664
# Month=56, Predicted=17.7456, Expected=17.5659
# Month=57, Predicted=17.3029, Expected=17.0753
# Month=58, Predicted=16.7817, Expected=16.6502
# Month=59, Predicted=16.4358, Expected=16.4285
# Month=60, Predicted=16.3289, Expected=16.5878
# Run 14 — RMSE: 0.513621, MSE: 0.263807, NMSE: 0.0021165019
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.1498, Expected=13.7084
# Month=2, Predicted=14.0186, Expected=13.8026
# Month=3, Predicted=13.7932, Expected=14.3883
# Month=4, Predicted=14.7008, Expected=15.0615
# Month=5, Predicted=15.4206, Expected=15.6682
# Month=6, Predicted=15.9826, Expected=15.8360
# Month=7, Predicted=15.8730, Expected=15.7178
# Month=8, Predicted=15.5915, Expected=15.3110
# Month=9, Predicted=15.0478, Expected=14.7667
# Month=10, Predicted=14.4524, Expected=13.5419
# Month=11, Predicted=13.0046, Expected=13.5869
# Month=12, Predicted=13.6217, Expected=14.5144
# Month=13, Predicted=15.0622, Expected=14.3947
# Month=14, Predicted=14.2585, Expected=14.4996
# Month=15, Predicted=14.5130, Expected=14.7474
# Month=16, Predicted=14.8479, Expected=15.8019
# Month=17, Predicted=16.3905, Expected=16.5221
# Month=18, Predicted=16.9097, Expected=16.5417
# Month=19, Predicted=16.4855, Expected=16.7210
# Month=20, Predicted=16.7780, Expected=16.4288
# Month=21, Predicted=16.2124, Expected=15.7719
# Month=22, Predicted=15.4093, Expected=15.2959
# Month=23, Predicted=15.0195, Expected=15.1318
# Month=24, Predicted=15.0008, Expected=15.5377
# Month=25, Predicted=15.7462, Expected=15.8371
# Month=26, Predicted=15.9659, Expected=16.3719
# Month=27, Predicted=16.6464, Expected=16.3365
# Month=28, Predicted=16.2502, Expected=16.8969
# Month=29, Predicted=17.1973, Expected=17.0022
# Month=30, Predicted=16.9999, Expected=17.4155
# Month=31, Predicted=17.6196, Expected=17.5332
# Month=32, Predicted=17.5409, Expected=17.2849
# Month=33, Predicted=17.0915, Expected=16.6063
# Month=34, Predicted=16.2342, Expected=15.8228
# Month=35, Predicted=15.4253, Expected=15.4543
# Month=36, Predicted=15.2328, Expected=15.6138
# Month=37, Predicted=15.6722, Expected=15.6954
# Month=38, Predicted=15.6859, Expected=16.7627
# Month=39, Predicted=17.3579, Expected=16.4941
# Month=40, Predicted=16.2810, Expected=17.7345
# Month=41, Predicted=18.3852, Expected=18.6944
# Month=42, Predicted=19.2479, Expected=19.1228
# Month=43, Predicted=19.3238, Expected=19.5704
# Month=44, Predicted=19.7879, Expected=19.2258
# Month=45, Predicted=18.9801, Expected=18.2178
# Month=46, Predicted=17.7370, Expected=17.2135
# Month=47, Predicted=16.7548, Expected=16.6554
# Month=48, Predicted=16.3590, Expected=16.8225
# Month=49, Predicted=16.8949, Expected=15.7773
# Month=50, Predicted=15.2756, Expected=15.7224
# Month=51, Predicted=15.6832, Expected=15.9967
# Month=52, Predicted=16.1206, Expected=17.0162
# Month=53, Predicted=17.5948, Expected=17.5568
# Month=54, Predicted=17.8271, Expected=17.8404
# Month=55, Predicted=17.9559, Expected=17.8664
# Month=56, Predicted=17.8202, Expected=17.5659
# Month=57, Predicted=17.3489, Expected=17.0753
# Month=58, Predicted=16.7803, Expected=16.6502
# Month=59, Predicted=16.3903, Expected=16.4285
# Month=60, Predicted=16.2651, Expected=16.5878
# Run 15 — RMSE: 0.501800, MSE: 0.251803, NMSE: 0.0019430103
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1652, Expected=13.7084
# Month=2, Predicted=14.0240, Expected=13.8026
# Month=3, Predicted=13.7131, Expected=14.3883
# Month=4, Predicted=14.7112, Expected=15.0615
# Month=5, Predicted=15.3653, Expected=15.6682
# Month=6, Predicted=15.9078, Expected=15.8360
# Month=7, Predicted=15.7866, Expected=15.7178
# Month=8, Predicted=15.5605, Expected=15.3110
# Month=9, Predicted=15.0492, Expected=14.7667
# Month=10, Predicted=14.4812, Expected=13.5419
# Month=11, Predicted=13.0267, Expected=13.5869
# Month=12, Predicted=13.8351, Expected=14.5144
# Month=13, Predicted=15.1534, Expected=14.3947
# Month=14, Predicted=14.1681, Expected=14.4996
# Month=15, Predicted=14.5145, Expected=14.7474
# Month=16, Predicted=14.8160, Expected=15.8019
# Month=17, Predicted=16.4921, Expected=16.5221
# Month=18, Predicted=16.8160, Expected=16.5417
# Month=19, Predicted=16.3991, Expected=16.7210
# Month=20, Predicted=16.7593, Expected=16.4288
# Month=21, Predicted=16.1847, Expected=15.7719
# Month=22, Predicted=15.4252, Expected=15.2959
# Month=23, Predicted=15.0790, Expected=15.1318
# Month=24, Predicted=15.0485, Expected=15.5377
# Month=25, Predicted=15.7741, Expected=15.8371
# Month=26, Predicted=15.8936, Expected=16.3719
# Month=27, Predicted=16.6140, Expected=16.3365
# Month=28, Predicted=16.1816, Expected=16.8969
# Month=29, Predicted=17.2278, Expected=17.0022
# Month=30, Predicted=16.9212, Expected=17.4155
# Month=31, Predicted=17.6013, Expected=17.5332
# Month=32, Predicted=17.4758, Expected=17.2849
# Month=33, Predicted=17.0685, Expected=16.6063
# Month=34, Predicted=16.2461, Expected=15.8228
# Month=35, Predicted=15.4742, Expected=15.4543
# Month=36, Predicted=15.3151, Expected=15.6138
# Month=37, Predicted=15.7144, Expected=15.6954
# Month=38, Predicted=15.6502, Expected=16.7627
# Month=39, Predicted=17.4530, Expected=16.4941
# Month=40, Predicted=16.1988, Expected=17.7345
# Month=41, Predicted=18.4247, Expected=18.6944
# Month=42, Predicted=19.1895, Expected=19.1228
# Month=43, Predicted=19.2040, Expected=19.5704
# Month=44, Predicted=19.7265, Expected=19.2258
# Month=45, Predicted=18.9329, Expected=18.2178
# Month=46, Predicted=17.7509, Expected=17.2135
# Month=47, Predicted=16.8246, Expected=16.6554
# Month=48, Predicted=16.4596, Expected=16.8225
# Month=49, Predicted=16.9732, Expected=15.7773
# Month=50, Predicted=15.2569, Expected=15.7224
# Month=51, Predicted=15.8399, Expected=15.9967
# Month=52, Predicted=16.1128, Expected=17.0162
# Month=53, Predicted=17.6850, Expected=17.5568
# Month=54, Predicted=17.7151, Expected=17.8404
# Month=55, Predicted=17.8696, Expected=17.8664
# Month=56, Predicted=17.7727, Expected=17.5659
# Month=57, Predicted=17.3355, Expected=17.0753
# Month=58, Predicted=16.7993, Expected=16.6502
# Month=59, Predicted=16.4315, Expected=16.4285
# Month=60, Predicted=16.3038, Expected=16.5878
# Run 16 — RMSE: 0.509328, MSE: 0.259415, NMSE: 0.0020536250
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.1891, Expected=13.7084
# Month=2, Predicted=14.0463, Expected=13.8026
# Month=3, Predicted=13.8438, Expected=14.3883
# Month=4, Predicted=14.7279, Expected=15.0615
# Month=5, Predicted=15.4481, Expected=15.6682
# Month=6, Predicted=16.0161, Expected=15.8360
# Month=7, Predicted=15.9221, Expected=15.7178
# Month=8, Predicted=15.6309, Expected=15.3110
# Month=9, Predicted=15.0489, Expected=14.7667
# Month=10, Predicted=14.4258, Expected=13.5419
# Month=11, Predicted=12.7947, Expected=13.5869
# Month=12, Predicted=13.6423, Expected=14.5144
# Month=13, Predicted=15.0473, Expected=14.3947
# Month=14, Predicted=14.3032, Expected=14.4996
# Month=15, Predicted=14.5542, Expected=14.7474
# Month=16, Predicted=14.8859, Expected=15.8019
# Month=17, Predicted=16.3925, Expected=16.5221
# Month=18, Predicted=16.9347, Expected=16.5417
# Month=19, Predicted=16.5365, Expected=16.7210
# Month=20, Predicted=16.8190, Expected=16.4288
# Month=21, Predicted=16.2337, Expected=15.7719
# Month=22, Predicted=15.3588, Expected=15.2959
# Month=23, Predicted=15.0046, Expected=15.1318
# Month=24, Predicted=15.0285, Expected=15.5377
# Month=25, Predicted=15.7753, Expected=15.8371
# Month=26, Predicted=16.0040, Expected=16.3719
# Month=27, Predicted=16.6798, Expected=16.3365
# Month=28, Predicted=16.2981, Expected=16.8969
# Month=29, Predicted=17.2234, Expected=17.0022
# Month=30, Predicted=17.0503, Expected=17.4155
# Month=31, Predicted=17.6534, Expected=17.5332
# Month=32, Predicted=17.5896, Expected=17.2849
# Month=33, Predicted=17.1177, Expected=16.6063
# Month=34, Predicted=16.1789, Expected=15.8228
# Month=35, Predicted=15.3429, Expected=15.4543
# Month=36, Predicted=15.2343, Expected=15.6138
# Month=37, Predicted=15.7070, Expected=15.6954
# Month=38, Predicted=15.7318, Expected=16.7627
# Month=39, Predicted=17.3608, Expected=16.4941
# Month=40, Predicted=16.3098, Expected=17.7345
# Month=41, Predicted=18.4124, Expected=18.6944
# Month=42, Predicted=19.2373, Expected=19.1228
# Month=43, Predicted=19.3655, Expected=19.5704
# Month=44, Predicted=19.8258, Expected=19.2258
# Month=45, Predicted=18.9960, Expected=18.2178
# Month=46, Predicted=17.5930, Expected=17.2135
# Month=47, Predicted=16.6127, Expected=16.6554
# Month=48, Predicted=16.3266, Expected=16.8225
# Month=49, Predicted=16.9254, Expected=15.7773
# Month=50, Predicted=15.1220, Expected=15.7224
# Month=51, Predicted=15.7077, Expected=15.9967
# Month=52, Predicted=16.1534, Expected=17.0162
# Month=53, Predicted=17.5905, Expected=17.5568
# Month=54, Predicted=17.8656, Expected=17.8404
# Month=55, Predicted=17.9970, Expected=17.8664
# Month=56, Predicted=17.8675, Expected=17.5659
# Month=57, Predicted=17.3675, Expected=17.0753
# Month=58, Predicted=16.7650, Expected=16.6502
# Month=59, Predicted=16.3853, Expected=16.4285
# Month=60, Predicted=16.2883, Expected=16.5878
# Run 17 — RMSE: 0.499898, MSE: 0.249898, NMSE: 0.0019041489
#
# ===== RUN 18/30 =====
# Training complete for run 18
# Month=1, Predicted=13.1508, Expected=13.7084
# Month=2, Predicted=13.9893, Expected=13.8026
# Month=3, Predicted=13.7978, Expected=14.3883
# Month=4, Predicted=14.6716, Expected=15.0615
# Month=5, Predicted=15.3874, Expected=15.6682
# Month=6, Predicted=15.9549, Expected=15.8360
# Month=7, Predicted=15.8721, Expected=15.7178
# Month=8, Predicted=15.6023, Expected=15.3110
# Month=9, Predicted=15.0498, Expected=14.7667
# Month=10, Predicted=14.4456, Expected=13.5419
# Month=11, Predicted=12.8948, Expected=13.5869
# Month=12, Predicted=13.6325, Expected=14.5144
# Month=13, Predicted=14.9979, Expected=14.3947
# Month=14, Predicted=14.2723, Expected=14.4996
# Month=15, Predicted=14.5153, Expected=14.7474
# Month=16, Predicted=14.8362, Expected=15.8019
# Month=17, Predicted=16.3560, Expected=16.5221
# Month=18, Predicted=16.8757, Expected=16.5417
# Month=19, Predicted=16.4949, Expected=16.7210
# Month=20, Predicted=16.7738, Expected=16.4288
# Month=21, Predicted=16.2195, Expected=15.7719
# Month=22, Predicted=15.3887, Expected=15.2959
# Month=23, Predicted=15.0224, Expected=15.1318
# Month=24, Predicted=15.0141, Expected=15.5377
# Month=25, Predicted=15.7251, Expected=15.8371
# Month=26, Predicted=15.9492, Expected=16.3719
# Month=27, Predicted=16.6209, Expected=16.3365
# Month=28, Predicted=16.2605, Expected=16.8969
# Month=29, Predicted=17.1693, Expected=17.0022
# Month=30, Predicted=17.0036, Expected=17.4155
# Month=31, Predicted=17.5988, Expected=17.5332
# Month=32, Predicted=17.5431, Expected=17.2849
# Month=33, Predicted=17.1005, Expected=16.6063
# Month=34, Predicted=16.2104, Expected=15.8228
# Month=35, Predicted=15.3940, Expected=15.4543
# Month=36, Predicted=15.2441, Expected=15.6138
# Month=37, Predicted=15.6694, Expected=15.6954
# Month=38, Predicted=15.6895, Expected=16.7627
# Month=39, Predicted=17.3286, Expected=16.4941
# Month=40, Predicted=16.2920, Expected=17.7345
# Month=41, Predicted=18.4138, Expected=18.6944
# Month=42, Predicted=19.1879, Expected=19.1228
# Month=43, Predicted=19.3070, Expected=19.5704
# Month=44, Predicted=19.7671, Expected=19.2258
# Month=45, Predicted=18.9847, Expected=18.2178
# Month=46, Predicted=17.6643, Expected=17.2135
# Month=47, Predicted=16.6956, Expected=16.6554
# Month=48, Predicted=16.3594, Expected=16.8225
# Month=49, Predicted=16.8916, Expected=15.7773
# Month=50, Predicted=15.1903, Expected=15.7224
# Month=51, Predicted=15.6999, Expected=15.9967
# Month=52, Predicted=16.1044, Expected=17.0162
# Month=53, Predicted=17.5493, Expected=17.5568
# Month=54, Predicted=17.8058, Expected=17.8404
# Month=55, Predicted=17.9422, Expected=17.8664
# Month=56, Predicted=17.8275, Expected=17.5659
# Month=57, Predicted=17.3562, Expected=17.0753
# Month=58, Predicted=16.7774, Expected=16.6502
# Month=59, Predicted=16.3946, Expected=16.4285
# Month=60, Predicted=16.2776, Expected=16.5878
# Run 18 — RMSE: 0.499715, MSE: 0.249715, NMSE: 0.0019245048
#
# ===== RUN 19/30 =====

# %% [markdown]
# ## Training Loop

# %% [markdown]
# ## Results

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
