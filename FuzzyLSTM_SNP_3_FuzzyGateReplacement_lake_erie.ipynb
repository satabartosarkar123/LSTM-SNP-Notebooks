# %% [markdown]
# # Notebook 3: LSTM-SNP with Fuzzy Gate Replacement
#
# **Dataset**: Monthly Lake Erie Levels
#
# ## Description
# This notebook implements **fuzzy gate replacement** for the LSTM-SNP model. The reset (r),
# consumption (c), and output (o) gates — which normally use hard sigmoid activation — are
# replaced with fuzzy inference systems. Each gate uses 2 Takagi-Sugeno rules with fixed Gaussian
# membership functions and trainable consequent parameters.
#
# The generation gate (a) retains its original tanh activation. The rest of the SNP architecture
# is unchanged. Gradient clipping (norm=1.0) is applied for training stability.

# %% [markdown]
# ## Theory: Fuzzy Gate Replacement
#
# ### Modified Gate Computation
# Instead of applying hard sigmoid directly, each gate (r, c, o) uses fuzzy inference:
#
# **Standard**: $r(t) = \sigma(z_r)$ where $z_r = W_r x(t) + U_r u(t-1) + b_r$
#
# **Fuzzy**: $r(t) = FuzzyInference(z_r, \bar{u}(t-1))$
#
# The fuzzy inference uses:
#
# **Fixed Gaussian Membership Functions**:
# - $\mu_{low}(z) = \exp\left(-\frac{(z - (-1))^2}{2 \cdot 0.5^2}\right)$
# - $\mu_{high}(z) = \exp\left(-\frac{(z - (+1))^2}{2 \cdot 0.5^2}\right)$
#
# **2 Rules per gate** (trainable consequents):
# 1. IF $z_{gate}$ is low → $y_0 = a_0 z + b_0 \bar{u} + c_0$
# 2. IF $z_{gate}$ is high → $y_1 = a_1 z + b_1 \bar{u} + c_1$
#
# **Output**: Gate value clipped to $[0, 1]$
#
# ### Unchanged
# - Generation gate $a(t) = \tanh(\cdot)$ — unchanged
# - State update: $u(t) = r \cdot u_{t-1} - c \cdot a$, $h(t) = o \cdot a$ — unchanged
# - Gradient clipping (norm ≤ 1.0) applied for stability

# %% [markdown]
# ## Model Architecture & Implementation

# %%
# ============================================================
# ALL IMPORTS
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

print(f"TensorFlow version: {tf.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# TensorFlow version: 2.20.0
# NumPy version: 2.4.2

# %% [markdown]
# ### Fuzzy Gate LSTM-SNP Cell

# %%
# ============================================================
# Fuzzy Gate LSTM-SNP Cell
# Gates r, c, o use fuzzy inference instead of hard sigmoid.
# Generation gate 'a' keeps tanh (unchanged).
#
# Fixed Gaussian membership functions:
#   μ_low(x)  = exp(-(x - (-1))² / (2·0.5²))
#   μ_high(x) = exp(-(x - (+1))² / (2·0.5²))
#
# Each gate uses 2 Takagi-Sugeno rules with trainable consequents.
# ============================================================

@tf.keras.utils.register_keras_serializable()
class FuzzyLSTMSNPCell(layers.Layer):
    """
    LSTM-SNP Cell with fuzzy gate replacement.
    Gates r, c, o are computed via fuzzy inference.
    Gate a keeps tanh activation.
    """
    def __init__(self, units, **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units
        self.output_size = units
        self.activation = tf.keras.activations.get('tanh')
        # Fixed membership function parameters
        self.mu_low = -1.0
        self.mu_high = 1.0
        self.sigma = 0.5

    def build(self, input_shape):
        input_dim = input_shape[-1]

        # Standard weights for pre-activation computation
        # 4 gates: r, c, o, a
        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )
        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )
        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

        # Fuzzy consequent parameters for 3 gates (r, c, o)
        # Each gate has 2 rules, each rule has 3 params (a, b, c_param)
        # rule_i: y_i = a_i * z_gate + b_i * u_mean + c_i
        # Store as instance attributes for reliable access
        self.fuzzy_params = {}
        for gate_name in ['r', 'c', 'o']:
            self.fuzzy_params[gate_name] = {}
            for rule_idx in range(2):
                self.fuzzy_params[gate_name][rule_idx] = {
                    'a': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_a'
                    ),
                    'b': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.RandomUniform(-0.1, 0.1),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_b'
                    ),
                    'c_param': self.add_weight(
                        shape=(self.units,),
                        initializer=tf.keras.initializers.Zeros(),
                        name=f'fuzzy_{gate_name}_rule{rule_idx}_c'
                    ),
                }

    def _gaussian_mf(self, x, center):
        """Fixed Gaussian membership function."""
        return tf.exp(-tf.square(x - center) / (2.0 * self.sigma ** 2))

    def _fuzzy_gate(self, z_gate, u_mean, gate_name):
        """Compute gate value via fuzzy inference (2 rules)."""
        # Membership degrees (fixed)
        w_low = self._gaussian_mf(z_gate, self.mu_low)
        w_high = self._gaussian_mf(z_gate, self.mu_high)

        # Get trainable consequent parameters from instance dict
        p = self.fuzzy_params[gate_name]

        # Rule outputs (trainable linear consequents)
        y0 = p[0]['a'] * z_gate + p[0]['b'] * u_mean + p[0]['c_param']
        y1 = p[1]['a'] * z_gate + p[1]['b'] * u_mean + p[1]['c_param']

        # Weighted average defuzzification
        numerator = w_low * y0 + w_high * y1
        denominator = w_low + w_high + 1e-8
        output = numerator / denominator

        # Clip to [0, 1] since gates should be bounded
        return tf.clip_by_value(output, 0.0, 1.0)

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        # Mean of previous state for fuzzy rule input
        u_mean = tf.reduce_mean(u_tm1, axis=-1, keepdims=True)
        u_mean = tf.tile(u_mean, [1, self.units])

        # Fuzzy gates
        r = self._fuzzy_gate(z0, u_mean, 'r')
        c = self._fuzzy_gate(z1, u_mean, 'c')
        o = self._fuzzy_gate(z2, u_mean, 'o')
        a = self.activation(z3)  # tanh unchanged

        u = r * u_tm1 - c * a
        h = o * a

        return h, [u]

    def get_config(self):
        config = super().get_config()
        config.update({'units': self.units})
        return config

# %% [markdown]
# ### Build Model

# %%
# ============================================================
# Model Construction: LSTM-SNP with Fuzzy Gate Replacement
# Uses FuzzyLSTMSNPCell instead of LSTMSNPCell.
# Gradient clipping applied for stability.
# ============================================================

def build_model(input_dim, units, batch_size):
    cell = FuzzyLSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    optimizer = tf.keras.optimizers.legacy.Adam(clipnorm=1.0)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# %%
# Quick model check
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 473 (1.85 KB)
#  Trainable params: 473 (1.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Data Pipeline — Monthly Lake Erie Levels

# %%
# ============================================================
# 1. Load Time Series Data
# ============================================================

series = pd.read_csv(
    'content/monthly-lake-erie-levels-1921-19.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (600,)
# First 5 values: [14.763 14.649 15.085 16.376 16.926]

# %%
# ============================================================
# 2. First-Order Differencing
# ============================================================

def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
# ============================================================
# 3. Convert to Supervised Learning Format (lag=1)
# ============================================================

def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)
print(f"Supervised data shape: {supervised.shape}")
# Out:
# Supervised data shape: (599, 2)

# %%
# ============================================================
# 4. Train-Test Split
# ============================================================

train, test = supervised[:-60], supervised[-60:]
print(f"Train: {train.shape}, Test: {test.shape}")

# ============================================================
# 5. Feature Scaling
# ============================================================

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)
# Out:
# Train: (539, 2), Test: (60, 2)

# %%
# ============================================================
# 6. Reshape for RNN Input
# ============================================================

X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
# Out:
# X_train shape: (539, 1, 1), y_train shape: (539,)

# %% [markdown]
# ## Training Loop

# %%
# ============================================================
# 30-Run Experiment Protocol
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []
all_losses = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    np.random.seed(run)
    tf.random.set_seed(run)

    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    rnn_layer = model.layers[1]

    # Training with manual epoch loop + reset_states
    run_losses = []
    for epoch in range(100):
        history = model.fit(
            X_train, y_train,
            epochs=1, batch_size=1,
            verbose=0, shuffle=False
        )
        run_losses.append(history.history['loss'][0])
        rnn_layer.reset_states()

    all_losses.append(run_losses)
    print(f'Training complete for run {run+1}')

    # Warm-up: condition hidden states on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]
        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# WARNING:tensorflow:From c:\Users\gigab\Research\SNN-SNP\LSTM-SNP-Notebooks\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Training complete for run 1
# Month=1, Predicted=13.2048, Expected=13.7000
# Month=2, Predicted=14.0270, Expected=13.8140
# Month=3, Predicted=13.8722, Expected=14.3830
# Month=4, Predicted=14.7102, Expected=15.0470
# Month=5, Predicted=15.4270, Expected=15.6930
# Month=6, Predicted=16.0629, Expected=15.8440
# Month=7, Predicted=15.9246, Expected=15.7120
# Month=8, Predicted=15.6219, Expected=15.3130
# Month=9, Predicted=15.0596, Expected=14.7630
# Month=10, Predicted=14.4173, Expected=13.5480
# Month=11, Predicted=12.7837, Expected=13.5860
# Month=12, Predicted=13.6125, Expected=14.5160
# Month=13, Predicted=15.0470, Expected=14.3830
# Month=14, Predicted=14.2929, Expected=14.4970
# Month=15, Predicted=14.5586, Expected=14.7440
# Month=16, Predicted=14.8832, Expected=15.8060
# Month=17, Predicted=16.4083, Expected=16.5270
# Month=18, Predicted=16.9406, Expected=16.5460
# Month=19, Predicted=16.5472, Expected=16.7170
# Month=20, Predicted=16.8116, Expected=16.4330
# Month=21, Predicted=16.2490, Expected=15.7690
# Month=22, Predicted=15.3504, Expected=15.2750
# Month=23, Predicted=14.9672, Expected=15.1230
# Month=24, Predicted=15.0262, Expected=15.5410
# Month=25, Predicted=15.7828, Expected=15.8250
# Month=26, Predicted=15.9847, Expected=16.3760
# Month=27, Predicted=16.6919, Expected=16.3570
# Month=28, Predicted=16.3348, Expected=16.9070
# Month=29, Predicted=17.2242, Expected=17.0210
# Month=30, Predicted=17.0792, Expected=17.4190
# Month=31, Predicted=17.6471, Expected=17.5330
# Month=32, Predicted=17.5914, Expected=17.2680
# Month=33, Predicted=17.0961, Expected=16.6030
# Month=34, Predicted=16.1836, Expected=15.8250
# Month=35, Predicted=15.3381, Expected=15.4460
# Month=36, Predicted=15.2114, Expected=15.6360
# Month=37, Predicted=15.7454, Expected=15.6930
# Month=38, Predicted=15.7179, Expected=16.7550
# Month=39, Predicted=17.3584, Expected=16.5090
# Month=40, Predicted=16.3488, Expected=17.7230
# Month=41, Predicted=18.4111, Expected=18.6910
# Month=42, Predicted=19.2411, Expected=19.1270
# Month=43, Predicted=19.3780, Expected=19.5640
# Month=44, Predicted=19.8135, Expected=19.2030
# Month=45, Predicted=18.9700, Expected=18.2160
# Month=46, Predicted=17.5938, Expected=17.2110
# Month=47, Predicted=16.5835, Expected=16.6600
# Month=48, Predicted=16.3199, Expected=16.8310
# Month=49, Predicted=16.9307, Expected=15.7690
# Month=50, Predicted=15.0952, Expected=15.7310
# Month=51, Predicted=15.7097, Expected=15.9960
# Month=52, Predicted=16.1469, Expected=17.0210
# Month=53, Predicted=17.6030, Expected=17.5520
# Month=54, Predicted=17.8576, Expected=17.8370
# Month=55, Predicted=17.9972, Expected=17.8560
# Month=56, Predicted=17.8574, Expected=17.5710
# Month=57, Predicted=17.3874, Expected=17.0780
# Month=58, Predicted=16.7671, Expected=16.6600
# Month=59, Predicted=16.3981, Expected=16.4330
# Month=60, Predicted=16.2892, Expected=16.5840
# Run 1 — RMSE: 0.499428, MSE: 0.249428, NMSE: 0.0018960042
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=13.2182, Expected=13.7000
# Month=2, Predicted=14.0366, Expected=13.8140
# Month=3, Predicted=13.8852, Expected=14.3830
# Month=4, Predicted=14.7197, Expected=15.0470
# Month=5, Predicted=15.4338, Expected=15.6930
# Month=6, Predicted=16.0701, Expected=15.8440
# Month=7, Predicted=15.9376, Expected=15.7120
# Month=8, Predicted=15.6321, Expected=15.3130
# Month=9, Predicted=15.0637, Expected=14.7630
# Month=10, Predicted=14.4174, Expected=13.5480
# Month=11, Predicted=12.7583, Expected=13.5860
# Month=12, Predicted=13.6302, Expected=14.5160
# Month=13, Predicted=15.0424, Expected=14.3830
# Month=14, Predicted=14.3016, Expected=14.4970
# Month=15, Predicted=14.5718, Expected=14.7440
# Month=16, Predicted=14.8966, Expected=15.8060
# Month=17, Predicted=16.3958, Expected=16.5270
# Month=18, Predicted=16.9436, Expected=16.5460
# Month=19, Predicted=16.5590, Expected=16.7170
# Month=20, Predicted=16.8250, Expected=16.4330
# Month=21, Predicted=16.2560, Expected=15.7690
# Month=22, Predicted=15.3464, Expected=15.2750
# Month=23, Predicted=14.9701, Expected=15.1230
# Month=24, Predicted=15.0367, Expected=15.5410
# Month=25, Predicted=15.7950, Expected=15.8250
# Month=26, Predicted=15.9981, Expected=16.3760
# Month=27, Predicted=16.7019, Expected=16.3570
# Month=28, Predicted=16.3465, Expected=16.9070
# Month=29, Predicted=17.2341, Expected=17.0210
# Month=30, Predicted=17.0923, Expected=17.4190
# Month=31, Predicted=17.6596, Expected=17.5330
# Month=32, Predicted=17.6046, Expected=17.2680
# Month=33, Predicted=17.1036, Expected=16.6030
# Month=34, Predicted=16.1795, Expected=15.8250
# Month=35, Predicted=15.3313, Expected=15.4460
# Month=36, Predicted=15.2181, Expected=15.6360
# Month=37, Predicted=15.7590, Expected=15.6930
# Month=38, Predicted=15.7306, Expected=16.7550
# Month=39, Predicted=17.3457, Expected=16.5090
# Month=40, Predicted=16.3546, Expected=17.7230
# Month=41, Predicted=18.3866, Expected=18.6910
# Month=42, Predicted=19.2317, Expected=19.1270
# Month=43, Predicted=19.3882, Expected=19.5640
# Month=44, Predicted=19.8255, Expected=19.2030
# Month=45, Predicted=18.9750, Expected=18.2160
# Month=46, Predicted=17.5775, Expected=17.2110
# Month=47, Predicted=16.5702, Expected=16.6600
# Month=48, Predicted=16.3233, Expected=16.8310
# Month=49, Predicted=16.9448, Expected=15.7690
# Month=50, Predicted=15.0751, Expected=15.7310
# Month=51, Predicted=15.7254, Expected=15.9960
# Month=52, Predicted=16.1603, Expected=17.0210
# Month=53, Predicted=17.5929, Expected=17.5520
# Month=54, Predicted=17.8660, Expected=17.8370
# Month=55, Predicted=18.0105, Expected=17.8560
# Month=56, Predicted=17.8698, Expected=17.5710
# Month=57, Predicted=17.3944, Expected=17.0780
# Month=58, Predicted=16.7687, Expected=16.6600
# Month=59, Predicted=16.4024, Expected=16.4330
# Month=60, Predicted=16.2980, Expected=16.5840
# Run 2 — RMSE: 0.498517, MSE: 0.248519, NMSE: 0.0018906857
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=13.1913, Expected=13.7000
# Month=2, Predicted=13.9964, Expected=13.8140
# Month=3, Predicted=13.7947, Expected=14.3830
# Month=4, Predicted=14.6804, Expected=15.0470
# Month=5, Predicted=15.3719, Expected=15.6930
# Month=6, Predicted=16.0007, Expected=15.8440
# Month=7, Predicted=15.8427, Expected=15.7120
# Month=8, Predicted=15.5698, Expected=15.3130
# Month=9, Predicted=15.0370, Expected=14.7630
# Month=10, Predicted=14.4290, Expected=13.5480
# Month=11, Predicted=12.8543, Expected=13.5860
# Month=12, Predicted=13.7523, Expected=14.5160
# Month=13, Predicted=15.0479, Expected=14.3830
# Month=14, Predicted=14.1943, Expected=14.4970
# Month=15, Predicted=14.5343, Expected=14.7440
# Month=16, Predicted=14.8399, Expected=15.8060
# Month=17, Predicted=16.4008, Expected=16.5270
# Month=18, Predicted=16.8657, Expected=16.5460
# Month=19, Predicted=16.4589, Expected=16.7170
# Month=20, Predicted=16.7738, Expected=16.4330
# Month=21, Predicted=16.1976, Expected=15.7690
# Month=22, Predicted=15.3537, Expected=15.2750
# Month=23, Predicted=15.0125, Expected=15.1230
# Month=24, Predicted=15.0417, Expected=15.5410
# Month=25, Predicted=15.7710, Expected=15.8250
# Month=26, Predicted=15.9209, Expected=16.3760
# Month=27, Predicted=16.6481, Expected=16.3570
# Month=28, Predicted=16.2566, Expected=16.9070
# Month=29, Predicted=17.2053, Expected=17.0210
# Month=30, Predicted=17.0030, Expected=17.4190
# Month=31, Predicted=17.6089, Expected=17.5330
# Month=32, Predicted=17.5241, Expected=17.2680
# Month=33, Predicted=17.0485, Expected=16.6030
# Month=34, Predicted=16.1848, Expected=15.8250
# Month=35, Predicted=15.3949, Expected=15.4460
# Month=36, Predicted=15.2704, Expected=15.6360
# Month=37, Predicted=15.7507, Expected=15.6930
# Month=38, Predicted=15.6646, Expected=16.7550
# Month=39, Predicted=17.3664, Expected=16.5090
# Month=40, Predicted=16.2487, Expected=17.7230
# Month=41, Predicted=18.4562, Expected=18.6910
# Month=42, Predicted=19.1820, Expected=19.1270
# Month=43, Predicted=19.2873, Expected=19.5640
# Month=44, Predicted=19.7533, Expected=19.2030
# Month=45, Predicted=18.9022, Expected=18.2160
# Month=46, Predicted=17.6251, Expected=17.2110
# Month=47, Predicted=16.7028, Expected=16.6600
# Month=48, Predicted=16.4190, Expected=16.8310
# Month=49, Predicted=16.9577, Expected=15.7690
# Month=50, Predicted=15.0854, Expected=15.7310
# Month=51, Predicted=15.8207, Expected=15.9960
# Month=52, Predicted=16.1176, Expected=17.0210
# Month=53, Predicted=17.5924, Expected=17.5520
# Month=54, Predicted=17.7715, Expected=17.8370
# Month=55, Predicted=17.9252, Expected=17.8560
# Month=56, Predicted=17.7958, Expected=17.5710
# Month=57, Predicted=17.3481, Expected=17.0780
# Month=58, Predicted=16.7635, Expected=16.6600
# Month=59, Predicted=16.4175, Expected=16.4330
# Month=60, Predicted=16.2955, Expected=16.5840
# Run 3 — RMSE: 0.498901, MSE: 0.248902, NMSE: 0.0019331895
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=13.2103, Expected=13.7000
# Month=2, Predicted=14.0336, Expected=13.8140
# Month=3, Predicted=13.8815, Expected=14.3830
# Month=4, Predicted=14.7166, Expected=15.0470
# Month=5, Predicted=15.4339, Expected=15.6930
# Month=6, Predicted=16.0698, Expected=15.8440
# Month=7, Predicted=15.9337, Expected=15.7120
# Month=8, Predicted=15.6299, Expected=15.3130
# Month=9, Predicted=15.0640, Expected=14.7630
# Month=10, Predicted=14.4181, Expected=13.5480
# Month=11, Predicted=12.7699, Expected=13.5860
# Month=12, Predicted=13.6103, Expected=14.5160
# Month=13, Predicted=15.0496, Expected=14.3830
# Month=14, Predicted=14.3000, Expected=14.4970
# Month=15, Predicted=14.5649, Expected=14.7440
# Month=16, Predicted=14.8910, Expected=15.8060
# Month=17, Predicted=16.4102, Expected=16.5270
# Month=18, Predicted=16.9455, Expected=16.5460
# Month=19, Predicted=16.5561, Expected=16.7170
# Month=20, Predicted=16.8189, Expected=16.4330
# Month=21, Predicted=16.2563, Expected=15.7690
# Month=22, Predicted=15.3507, Expected=15.2750
# Month=23, Predicted=14.9663, Expected=15.1230
# Month=24, Predicted=15.0290, Expected=15.5410
# Month=25, Predicted=15.7882, Expected=15.8250
# Month=26, Predicted=15.9937, Expected=16.3760
# Month=27, Predicted=16.6993, Expected=16.3570
# Month=28, Predicted=16.3440, Expected=16.9070
# Month=29, Predicted=17.2298, Expected=17.0210
# Month=30, Predicted=17.0885, Expected=17.4190
# Month=31, Predicted=17.6545, Expected=17.5330
# Month=32, Predicted=17.6006, Expected=17.2680
# Month=33, Predicted=17.1032, Expected=16.6030
# Month=34, Predicted=16.1840, Expected=15.8250
# Month=35, Predicted=15.3335, Expected=15.4460
# Month=36, Predicted=15.2106, Expected=15.6360
# Month=37, Predicted=15.7495, Expected=15.6930
# Month=38, Predicted=15.7264, Expected=16.7550
# Month=39, Predicted=17.3593, Expected=16.5090
# Month=40, Predicted=16.3555, Expected=17.7230
# Month=41, Predicted=18.4071, Expected=18.6910
# Month=42, Predicted=19.2437, Expected=19.1270
# Month=43, Predicted=19.3842, Expected=19.5640
# Month=44, Predicted=19.8219, Expected=19.2030
# Month=45, Predicted=18.9777, Expected=18.2160
# Month=46, Predicted=17.5876, Expected=17.2110
# Month=47, Predicted=16.5722, Expected=16.6600
# Month=48, Predicted=16.3159, Expected=16.8310
# Month=49, Predicted=16.9334, Expected=15.7690
# Month=50, Predicted=15.0910, Expected=15.7310
# Month=51, Predicted=15.7085, Expected=15.9960
# Month=52, Predicted=16.1537, Expected=17.0210
# Month=53, Predicted=17.6056, Expected=17.5520
# Month=54, Predicted=17.8636, Expected=17.8370
# Month=55, Predicted=18.0062, Expected=17.8560
# Month=56, Predicted=17.8663, Expected=17.5710
# Month=57, Predicted=17.3937, Expected=17.0780
# Month=58, Predicted=16.7694, Expected=16.6600
# Month=59, Predicted=16.3993, Expected=16.4330
# Month=60, Predicted=16.2923, Expected=16.5840
# Run 4 — RMSE: 0.499726, MSE: 0.249726, NMSE: 0.0018955958
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=13.1682, Expected=13.7000
# Month=2, Predicted=14.0234, Expected=13.8140
# Month=3, Predicted=13.8305, Expected=14.3830
# Month=4, Predicted=14.7066, Expected=15.0470
# Month=5, Predicted=15.4316, Expected=15.6930
# Month=6, Predicted=16.0648, Expected=15.8440
# Month=7, Predicted=15.8834, Expected=15.7120
# Month=8, Predicted=15.5864, Expected=15.3130
# Month=9, Predicted=15.0515, Expected=14.7630
# Month=10, Predicted=14.4345, Expected=13.5480
# Month=11, Predicted=12.9712, Expected=13.5860
# Month=12, Predicted=13.5873, Expected=14.5160
# Month=13, Predicted=15.0814, Expected=14.3830
# Month=14, Predicted=14.2533, Expected=14.4970
# Month=15, Predicted=14.5206, Expected=14.7440
# Month=16, Predicted=14.8494, Expected=15.8060
# Month=17, Predicted=16.4053, Expected=16.5270
# Month=18, Predicted=16.9495, Expected=16.5460
# Month=19, Predicted=16.5040, Expected=16.7170
# Month=20, Predicted=16.7744, Expected=16.4330
# Month=21, Predicted=16.2258, Expected=15.7690
# Month=22, Predicted=15.3898, Expected=15.2750
# Month=23, Predicted=14.9758, Expected=15.1230
# Month=24, Predicted=14.9953, Expected=15.5410
# Month=25, Predicted=15.7651, Expected=15.8250
# Month=26, Predicted=15.9517, Expected=16.3760
# Month=27, Predicted=16.6852, Expected=16.3570
# Month=28, Predicted=16.2931, Expected=16.9070
# Month=29, Predicted=17.2195, Expected=17.0210
# Month=30, Predicted=17.0376, Expected=17.4190
# Month=31, Predicted=17.6253, Expected=17.5330
# Month=32, Predicted=17.5506, Expected=17.2680
# Month=33, Predicted=17.0711, Expected=16.6030
# Month=34, Predicted=16.2232, Expected=15.8250
# Month=35, Predicted=15.4041, Expected=15.4460
# Month=36, Predicted=15.2040, Expected=15.6360
# Month=37, Predicted=15.7124, Expected=15.6930
# Month=38, Predicted=15.6773, Expected=16.7550
# Month=39, Predicted=17.3543, Expected=16.5090
# Month=40, Predicted=16.3184, Expected=17.7230
# Month=41, Predicted=18.3223, Expected=18.6910
# Month=42, Predicted=19.2736, Expected=19.1270
# Month=43, Predicted=19.3541, Expected=19.5640
# Month=44, Predicted=19.7935, Expected=19.2030
# Month=45, Predicted=18.9553, Expected=18.2160
# Month=46, Predicted=17.7136, Expected=17.2110
# Month=47, Predicted=16.7096, Expected=16.6600
# Month=48, Predicted=16.3408, Expected=16.8310
# Month=49, Predicted=16.8988, Expected=15.7690
# Month=50, Predicted=15.2368, Expected=15.7310
# Month=51, Predicted=15.6816, Expected=15.9960
# Month=52, Predicted=16.1154, Expected=17.0210
# Month=53, Predicted=17.6203, Expected=17.5520
# Month=54, Predicted=17.8442, Expected=17.8370
# Month=55, Predicted=17.9636, Expected=17.8560
# Month=56, Predicted=17.8164, Expected=17.5710
# Month=57, Predicted=17.3647, Expected=17.0780
# Month=58, Predicted=16.7739, Expected=16.6600
# Month=59, Predicted=16.3941, Expected=16.4330
# Month=60, Predicted=16.2630, Expected=16.5840
# Run 5 — RMSE: 0.502267, MSE: 0.252272, NMSE: 0.0019387098
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=13.2172, Expected=13.7000
# Month=2, Predicted=14.0035, Expected=13.8140
# Month=3, Predicted=13.7424, Expected=14.3830
# Month=4, Predicted=14.6920, Expected=15.0470
# Month=5, Predicted=15.3158, Expected=15.6930
# Month=6, Predicted=15.9314, Expected=15.8440
# Month=7, Predicted=15.7830, Expected=15.7120
# Month=8, Predicted=15.5615, Expected=15.3130
# Month=9, Predicted=15.0525, Expected=14.7630
# Month=10, Predicted=14.4576, Expected=13.5480
# Month=11, Predicted=13.1914, Expected=13.5860
# Month=12, Predicted=13.8626, Expected=14.5160
# Month=13, Predicted=15.1165, Expected=14.3830
# Month=14, Predicted=14.1332, Expected=14.4970
# Month=15, Predicted=14.5507, Expected=14.7440
# Month=16, Predicted=14.8328, Expected=15.8060
# Month=17, Predicted=16.4420, Expected=16.5270
# Month=18, Predicted=16.7608, Expected=16.5460
# Month=19, Predicted=16.4008, Expected=16.7170
# Month=20, Predicted=16.7764, Expected=16.4330
# Month=21, Predicted=16.1925, Expected=15.7690
# Month=22, Predicted=15.4146, Expected=15.2750
# Month=23, Predicted=15.0474, Expected=15.1230
# Month=24, Predicted=15.0773, Expected=15.5410
# Month=25, Predicted=15.8086, Expected=15.8250
# Month=26, Predicted=15.8789, Expected=16.3760
# Month=27, Predicted=16.6311, Expected=16.3570
# Month=28, Predicted=16.2122, Expected=16.9070
# Month=29, Predicted=17.2368, Expected=17.0210
# Month=30, Predicted=16.9521, Expected=17.4190
# Month=31, Predicted=17.6087, Expected=17.5330
# Month=32, Predicted=17.4874, Expected=17.2680
# Month=33, Predicted=17.0467, Expected=16.6030
# Month=34, Predicted=16.2486, Expected=15.8250
# Month=35, Predicted=15.4704, Expected=15.4460
# Month=36, Predicted=15.3117, Expected=15.6360
# Month=37, Predicted=15.7970, Expected=15.6930
# Month=38, Predicted=15.6477, Expected=16.7550
# Month=39, Predicted=17.4552, Expected=16.5090
# Month=40, Predicted=16.1982, Expected=17.7230
# Month=41, Predicted=18.6678, Expected=18.6910
# Month=42, Predicted=19.0831, Expected=19.1270
# Month=43, Predicted=19.1875, Expected=19.5640
# Month=44, Predicted=19.7118, Expected=19.2030
# Month=45, Predicted=18.8859, Expected=18.2160
# Month=46, Predicted=17.8602, Expected=17.2110
# Month=47, Predicted=16.8556, Expected=16.6600
# Month=48, Predicted=16.4610, Expected=16.8310
# Month=49, Predicted=17.0219, Expected=15.7690
# Month=50, Predicted=15.4127, Expected=15.7310
# Month=51, Predicted=15.9026, Expected=15.9960
# Month=52, Predicted=16.1284, Expected=17.0210
# Month=53, Predicted=17.6231, Expected=17.5520
# Month=54, Predicted=17.6694, Expected=17.8370
# Month=55, Predicted=17.8728, Expected=17.8560
# Month=56, Predicted=17.7726, Expected=17.5710
# Month=57, Predicted=17.3526, Expected=17.0780
# Month=58, Predicted=16.7874, Expected=16.6600
# Month=59, Predicted=16.4478, Expected=16.4330
# Month=60, Predicted=16.3243, Expected=16.5840
# Run 6 — RMSE: 0.501382, MSE: 0.251384, NMSE: 0.0020127236
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=13.2257, Expected=13.7000
# Month=2, Predicted=14.0369, Expected=13.8140
# Month=3, Predicted=13.8937, Expected=14.3830
# Month=4, Predicted=14.7200, Expected=15.0470
# Month=5, Predicted=15.4369, Expected=15.6930
# Month=6, Predicted=16.0739, Expected=15.8440
# Month=7, Predicted=15.9473, Expected=15.7120
# Month=8, Predicted=15.6160, Expected=15.3130
# Month=9, Predicted=15.0413, Expected=14.7630
# Month=10, Predicted=14.4032, Expected=13.5480
# Month=11, Predicted=12.8067, Expected=13.5860
# Month=12, Predicted=13.6718, Expected=14.5160
# Month=13, Predicted=15.0456, Expected=14.3830
# Month=14, Predicted=14.2916, Expected=14.4970
# Month=15, Predicted=14.5779, Expected=14.7440
# Month=16, Predicted=14.9006, Expected=15.8060
# Month=17, Predicted=16.4040, Expected=16.5270
# Month=18, Predicted=16.9500, Expected=16.5460
# Month=19, Predicted=16.5594, Expected=16.7170
# Month=20, Predicted=16.8305, Expected=16.4330
# Month=21, Predicted=16.2337, Expected=15.7690
# Month=22, Predicted=15.3384, Expected=15.2750
# Month=23, Predicted=14.9603, Expected=15.1230
# Month=24, Predicted=15.0262, Expected=15.5410
# Month=25, Predicted=15.7969, Expected=15.8250
# Month=26, Predicted=16.0031, Expected=16.3760
# Month=27, Predicted=16.7029, Expected=16.3570
# Month=28, Predicted=16.3418, Expected=16.9070
# Month=29, Predicted=17.2345, Expected=17.0210
# Month=30, Predicted=17.1005, Expected=17.4190
# Month=31, Predicted=17.6612, Expected=17.5330
# Month=32, Predicted=17.6113, Expected=17.2680
# Month=33, Predicted=17.0815, Expected=16.6030
# Month=34, Predicted=16.1714, Expected=15.8250
# Month=35, Predicted=15.3424, Expected=15.4460
# Month=36, Predicted=15.2103, Expected=15.6360
# Month=37, Predicted=15.7672, Expected=15.6930
# Month=38, Predicted=15.7300, Expected=16.7550
# Month=39, Predicted=17.3535, Expected=16.5090
# Month=40, Predicted=16.3400, Expected=17.7230
# Month=41, Predicted=18.4021, Expected=18.6910
# Month=42, Predicted=19.2435, Expected=19.1270
# Month=43, Predicted=19.3947, Expected=19.5640
# Month=44, Predicted=19.8284, Expected=19.2030
# Month=45, Predicted=18.9538, Expected=18.2160
# Month=46, Predicted=17.6112, Expected=17.2110
# Month=47, Predicted=16.6230, Expected=16.6600
# Month=48, Predicted=16.3285, Expected=16.8310
# Month=49, Predicted=16.9566, Expected=15.7690
# Month=50, Predicted=15.1138, Expected=15.7310
# Month=51, Predicted=15.7500, Expected=15.9960
# Month=52, Predicted=16.1634, Expected=17.0210
# Month=53, Predicted=17.6000, Expected=17.5520
# Month=54, Predicted=17.8720, Expected=17.8370
# Month=55, Predicted=18.0163, Expected=17.8560
# Month=56, Predicted=17.8660, Expected=17.5710
# Month=57, Predicted=17.3719, Expected=17.0780
# Month=58, Predicted=16.7501, Expected=16.6600
# Month=59, Predicted=16.3859, Expected=16.4330
# Month=60, Predicted=16.2821, Expected=16.5840
# Run 7 — RMSE: 0.494410, MSE: 0.244441, NMSE: 0.0018647955
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=13.2167, Expected=13.7000
# Month=2, Predicted=14.0393, Expected=13.8140
# Month=3, Predicted=13.8674, Expected=14.3830
# Month=4, Predicted=14.7230, Expected=15.0470
# Month=5, Predicted=15.4330, Expected=15.6930
# Month=6, Predicted=16.0675, Expected=15.8440
# Month=7, Predicted=15.9196, Expected=15.7120
# Month=8, Predicted=15.6180, Expected=15.3130
# Month=9, Predicted=15.0556, Expected=14.7630
# Month=10, Predicted=14.4181, Expected=13.5480
# Month=11, Predicted=12.7905, Expected=13.5860
# Month=12, Predicted=13.6594, Expected=14.5160
# Month=13, Predicted=15.0573, Expected=14.3830
# Month=14, Predicted=14.2758, Expected=14.4970
# Month=15, Predicted=14.5680, Expected=14.7440
# Month=16, Predicted=14.8900, Expected=15.8060
# Month=17, Predicted=16.4007, Expected=16.5270
# Month=18, Predicted=16.9424, Expected=16.5460
# Month=19, Predicted=16.5375, Expected=16.7170
# Month=20, Predicted=16.8188, Expected=16.4330
# Month=21, Predicted=16.2404, Expected=15.7690
# Month=22, Predicted=15.3463, Expected=15.2750
# Month=23, Predicted=14.9781, Expected=15.1230
# Month=24, Predicted=15.0385, Expected=15.5410
# Month=25, Predicted=15.7990, Expected=15.8250
# Month=26, Predicted=15.9868, Expected=16.3760
# Month=27, Predicted=16.7014, Expected=16.3570
# Month=28, Predicted=16.3265, Expected=16.9070
# Month=29, Predicted=17.2396, Expected=17.0210
# Month=30, Predicted=17.0747, Expected=17.4190
# Month=31, Predicted=17.6574, Expected=17.5330
# Month=32, Predicted=17.5894, Expected=17.2680
# Month=33, Predicted=17.0894, Expected=16.6030
# Month=34, Predicted=16.1789, Expected=15.8250
# Month=35, Predicted=15.3455, Expected=15.4460
# Month=36, Predicted=15.2287, Expected=15.6360
# Month=37, Predicted=15.7627, Expected=15.6930
# Month=38, Predicted=15.7181, Expected=16.7550
# Month=39, Predicted=17.3539, Expected=16.5090
# Month=40, Predicted=16.3289, Expected=17.7230
# Month=41, Predicted=18.3900, Expected=18.6910
# Month=42, Predicted=19.2368, Expected=19.1270
# Month=43, Predicted=19.3755, Expected=19.5640
# Month=44, Predicted=19.8187, Expected=19.2030
# Month=45, Predicted=18.9546, Expected=18.2160
# Month=46, Predicted=17.5915, Expected=17.2110
# Month=47, Predicted=16.6041, Expected=16.6600
# Month=48, Predicted=16.3433, Expected=16.8310
# Month=49, Predicted=16.9528, Expected=15.7690
# Month=50, Predicted=15.0803, Expected=15.7310
# Month=51, Predicted=15.7483, Expected=15.9960
# Month=52, Predicted=16.1570, Expected=17.0210
# Month=53, Predicted=17.5996, Expected=17.5520
# Month=54, Predicted=17.8572, Expected=17.8370
# Month=55, Predicted=17.9976, Expected=17.8560
# Month=56, Predicted=17.8549, Expected=17.5710
# Month=57, Predicted=17.3823, Expected=17.0780
# Month=58, Predicted=16.7654, Expected=16.6600
# Month=59, Predicted=16.4043, Expected=16.4330
# Month=60, Predicted=16.2972, Expected=16.5840
# Run 8 — RMSE: 0.498094, MSE: 0.248098, NMSE: 0.0018962601
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=13.2148, Expected=13.7000
# Month=2, Predicted=14.0298, Expected=13.8140
# Month=3, Predicted=13.8711, Expected=14.3830
# Month=4, Predicted=14.7131, Expected=15.0470
# Month=5, Predicted=15.4245, Expected=15.6930
# Month=6, Predicted=16.0597, Expected=15.8440
# Month=7, Predicted=15.9251, Expected=15.7120
# Month=8, Predicted=15.6095, Expected=15.3130
# Month=9, Predicted=15.0458, Expected=14.7630
# Month=10, Predicted=14.4106, Expected=13.5480
# Month=11, Predicted=12.8400, Expected=13.5860
# Month=12, Predicted=13.6394, Expected=14.5160
# Month=13, Predicted=15.0466, Expected=14.3830
# Month=14, Predicted=14.2710, Expected=14.4970
# Month=15, Predicted=14.5662, Expected=14.7440
# Month=16, Predicted=14.8930, Expected=15.8060
# Month=17, Predicted=16.4054, Expected=16.5270
# Month=18, Predicted=16.9313, Expected=16.5460
# Month=19, Predicted=16.5368, Expected=16.7170
# Month=20, Predicted=16.8203, Expected=16.4330
# Month=21, Predicted=16.2320, Expected=15.7690
# Month=22, Predicted=15.3480, Expected=15.2750
# Month=23, Predicted=14.9627, Expected=15.1230
# Month=24, Predicted=15.0219, Expected=15.5410
# Month=25, Predicted=15.7911, Expected=15.8250
# Month=26, Predicted=15.9910, Expected=16.3760
# Month=27, Predicted=16.6937, Expected=16.3570
# Month=28, Predicted=16.3239, Expected=16.9070
# Month=29, Predicted=17.2286, Expected=17.0210
# Month=30, Predicted=17.0783, Expected=17.4190
# Month=31, Predicted=17.6533, Expected=17.5330
# Month=32, Predicted=17.5923, Expected=17.2680
# Month=33, Predicted=17.0800, Expected=16.6030
# Month=34, Predicted=16.1811, Expected=15.8250
# Month=35, Predicted=15.3487, Expected=15.4460
# Month=36, Predicted=15.2076, Expected=15.6360
# Month=37, Predicted=15.7606, Expected=15.6930
# Month=38, Predicted=15.7166, Expected=16.7550
# Month=39, Predicted=17.3570, Expected=16.5090
# Month=40, Predicted=16.3211, Expected=17.7230
# Month=41, Predicted=18.4107, Expected=18.6910
# Month=42, Predicted=19.2282, Expected=19.1270
# Month=43, Predicted=19.3744, Expected=19.5640
# Month=44, Predicted=19.8161, Expected=19.2030
# Month=45, Predicted=18.9501, Expected=18.2160
# Month=46, Predicted=17.6206, Expected=17.2110
# Month=47, Predicted=16.6214, Expected=16.6600
# Month=48, Predicted=16.3242, Expected=16.8310
# Month=49, Predicted=16.9480, Expected=15.7690
# Month=50, Predicted=15.1265, Expected=15.7310
# Month=51, Predicted=15.7258, Expected=15.9960
# Month=52, Predicted=16.1577, Expected=17.0210
# Month=53, Predicted=17.6002, Expected=17.5520
# Month=54, Predicted=17.8513, Expected=17.8370
# Month=55, Predicted=18.0023, Expected=17.8560
# Month=56, Predicted=17.8522, Expected=17.5710
# Month=57, Predicted=17.3720, Expected=17.0780
# Month=58, Predicted=16.7569, Expected=16.6600
# Month=59, Predicted=16.3894, Expected=16.4330
# Month=60, Predicted=16.2808, Expected=16.5840
# Run 9 — RMSE: 0.496685, MSE: 0.246696, NMSE: 0.0018860288
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=13.2041, Expected=13.7000
# Month=2, Predicted=14.0256, Expected=13.8140
# Month=3, Predicted=13.8506, Expected=14.3830
# Month=4, Predicted=14.7094, Expected=15.0470
# Month=5, Predicted=15.4203, Expected=15.6930
# Month=6, Predicted=16.0551, Expected=15.8440
# Month=7, Predicted=15.9044, Expected=15.7120
# Month=8, Predicted=15.5968, Expected=15.3130
# Month=9, Predicted=15.0395, Expected=14.7630
# Month=10, Predicted=14.4102, Expected=13.5480
# Month=11, Predicted=12.8218, Expected=13.5860
# Month=12, Predicted=13.6766, Expected=14.5160
# Month=13, Predicted=15.0522, Expected=14.3830
# Month=14, Predicted=14.2576, Expected=14.4970
# Month=15, Predicted=14.5534, Expected=14.7440
# Month=16, Predicted=14.8773, Expected=15.8060
# Month=17, Predicted=16.4053, Expected=16.5270
# Month=18, Predicted=16.9326, Expected=16.5460
# Month=19, Predicted=16.5191, Expected=16.7170
# Month=20, Predicted=16.8046, Expected=16.4330
# Month=21, Predicted=16.2203, Expected=15.7690
# Month=22, Predicted=15.3415, Expected=15.2750
# Month=23, Predicted=14.9738, Expected=15.1230
# Month=24, Predicted=15.0252, Expected=15.5410
# Month=25, Predicted=15.7870, Expected=15.8250
# Month=26, Predicted=15.9737, Expected=16.3760
# Month=27, Predicted=16.6873, Expected=16.3570
# Month=28, Predicted=16.3066, Expected=16.9070
# Month=29, Predicted=17.2266, Expected=17.0210
# Month=30, Predicted=17.0578, Expected=17.4190
# Month=31, Predicted=17.6436, Expected=17.5330
# Month=32, Predicted=17.5721, Expected=17.2680
# Month=33, Predicted=17.0691, Expected=16.6030
# Month=34, Predicted=16.1740, Expected=15.8250
# Month=35, Predicted=15.3529, Expected=15.4460
# Month=36, Predicted=15.2246, Expected=15.6360
# Month=37, Predicted=15.7552, Expected=15.6930
# Month=38, Predicted=15.6993, Expected=16.7550
# Month=39, Predicted=17.3592, Expected=16.5090
# Month=40, Predicted=16.3117, Expected=17.7230
# Month=41, Predicted=18.4113, Expected=18.6910
# Month=42, Predicted=19.2369, Expected=19.1270
# Month=43, Predicted=19.3644, Expected=19.5640
# Month=44, Predicted=19.8046, Expected=19.2030
# Month=45, Predicted=18.9363, Expected=18.2160
# Month=46, Predicted=17.6054, Expected=17.2110
# Month=47, Predicted=16.6329, Expected=16.6600
# Month=48, Predicted=16.3511, Expected=16.8310
# Month=49, Predicted=16.9486, Expected=15.7690
# Month=50, Predicted=15.0957, Expected=15.7310
# Month=51, Predicted=15.7559, Expected=15.9960
# Month=52, Predicted=16.1449, Expected=17.0210
# Month=53, Predicted=17.6014, Expected=17.5520
# Month=54, Predicted=17.8461, Expected=17.8370
# Month=55, Predicted=17.9848, Expected=17.8560
# Month=56, Predicted=17.8351, Expected=17.5710
# Month=57, Predicted=17.3628, Expected=17.0780
# Month=58, Predicted=16.7538, Expected=16.6600
# Month=59, Predicted=16.3940, Expected=16.4330
# Month=60, Predicted=16.2824, Expected=16.5840
# Run 10 — RMSE: 0.497061, MSE: 0.247069, NMSE: 0.0018914958
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=13.1668, Expected=13.7000
# Month=2, Predicted=13.9518, Expected=13.8140
# Month=3, Predicted=13.7933, Expected=14.3830
# Month=4, Predicted=14.6370, Expected=15.0470
# Month=5, Predicted=15.3298, Expected=15.6930
# Month=6, Predicted=15.9623, Expected=15.8440
# Month=7, Predicted=15.8406, Expected=15.7120
# Month=8, Predicted=15.5820, Expected=15.3130
# Month=9, Predicted=15.0630, Expected=14.7630
# Month=10, Predicted=14.4565, Expected=13.5480
# Month=11, Predicted=12.9415, Expected=13.5860
# Month=12, Predicted=13.6709, Expected=14.5160
# Month=13, Predicted=14.9777, Expected=14.3830
# Month=14, Predicted=14.2223, Expected=14.4970
# Month=15, Predicted=14.5171, Expected=14.7440
# Month=16, Predicted=14.8184, Expected=15.8060
# Month=17, Predicted=16.3341, Expected=16.5270
# Month=18, Predicted=16.8316, Expected=16.5460
# Month=19, Predicted=16.4697, Expected=16.7170
# Month=20, Predicted=16.7571, Expected=16.4330
# Month=21, Predicted=16.2224, Expected=15.7690
# Month=22, Predicted=15.3974, Expected=15.2750
# Month=23, Predicted=15.0196, Expected=15.1230
# Month=24, Predicted=15.0281, Expected=15.5410
# Month=25, Predicted=15.7277, Expected=15.8250
# Month=26, Predicted=15.9027, Expected=16.3760
# Month=27, Predicted=16.6093, Expected=16.3570
# Month=28, Predicted=16.2662, Expected=16.9070
# Month=29, Predicted=17.1594, Expected=17.0210
# Month=30, Predicted=17.0009, Expected=17.4190
# Month=31, Predicted=17.5774, Expected=17.5330
# Month=32, Predicted=17.5197, Expected=17.2680
# Month=33, Predicted=17.0709, Expected=16.6030
# Month=34, Predicted=16.2294, Expected=15.8250
# Month=35, Predicted=15.4282, Expected=15.4460
# Month=36, Predicted=15.2595, Expected=15.6360
# Month=37, Predicted=15.7145, Expected=15.6930
# Month=38, Predicted=15.6597, Expected=16.7550
# Month=39, Predicted=17.2956, Expected=16.5090
# Month=40, Predicted=16.2893, Expected=17.7230
# Month=41, Predicted=18.3772, Expected=18.6910
# Month=42, Predicted=19.1363, Expected=19.1270
# Month=43, Predicted=19.2720, Expected=19.5640
# Month=44, Predicted=19.7259, Expected=19.2030
# Month=45, Predicted=18.9398, Expected=18.2160
# Month=46, Predicted=17.6948, Expected=17.2110
# Month=47, Predicted=16.7353, Expected=16.6600
# Month=48, Predicted=16.4076, Expected=16.8310
# Month=49, Predicted=16.9137, Expected=15.7690
# Month=50, Predicted=15.1927, Expected=15.7310
# Month=51, Predicted=15.7578, Expected=15.9960
# Month=52, Predicted=16.0880, Expected=17.0210
# Month=53, Predicted=17.5263, Expected=17.5520
# Month=54, Predicted=17.7497, Expected=17.8370
# Month=55, Predicted=17.9108, Expected=17.8560
# Month=56, Predicted=17.7981, Expected=17.5710
# Month=57, Predicted=17.3694, Expected=17.0780
# Month=58, Predicted=16.7915, Expected=16.6600
# Month=59, Predicted=16.4279, Expected=16.4330
# Month=60, Predicted=16.2927, Expected=16.5840
# Run 11 — RMSE: 0.497960, MSE: 0.247965, NMSE: 0.0019388426
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=13.2041, Expected=13.7000
# Month=2, Predicted=14.0300, Expected=13.8140
# Month=3, Predicted=13.8709, Expected=14.3830
# Month=4, Predicted=14.7131, Expected=15.0470
# Month=5, Predicted=15.4301, Expected=15.6930
# Month=6, Predicted=16.0655, Expected=15.8440
# Month=7, Predicted=15.9232, Expected=15.7120
# Month=8, Predicted=15.6200, Expected=15.3130
# Month=9, Predicted=15.0588, Expected=14.7630
# Month=10, Predicted=14.4191, Expected=13.5480
# Month=11, Predicted=12.8113, Expected=13.5860
# Month=12, Predicted=13.6172, Expected=14.5160
# Month=13, Predicted=15.0502, Expected=14.3830
# Month=14, Predicted=14.2882, Expected=14.4970
# Month=15, Predicted=14.5576, Expected=14.7440
# Month=16, Predicted=14.8834, Expected=15.8060
# Month=17, Predicted=16.4033, Expected=16.5270
# Month=18, Predicted=16.9421, Expected=16.5460
# Month=19, Predicted=16.5446, Expected=16.7170
# Month=20, Predicted=16.8111, Expected=16.4330
# Month=21, Predicted=16.2474, Expected=15.7690
# Month=22, Predicted=15.3543, Expected=15.2750
# Month=23, Predicted=14.9690, Expected=15.1230
# Month=24, Predicted=15.0248, Expected=15.5410
# Month=25, Predicted=15.7844, Expected=15.8250
# Month=26, Predicted=15.9852, Expected=16.3760
# Month=27, Predicted=16.6948, Expected=16.3570
# Month=28, Predicted=16.3327, Expected=16.9070
# Month=29, Predicted=17.2269, Expected=17.0210
# Month=30, Predicted=17.0779, Expected=17.4190
# Month=31, Predicted=17.6487, Expected=17.5330
# Month=32, Predicted=17.5904, Expected=17.2680
# Month=33, Predicted=17.0944, Expected=16.6030
# Month=34, Predicted=16.1875, Expected=15.8250
# Month=35, Predicted=15.3464, Expected=15.4460
# Month=36, Predicted=15.2124, Expected=15.6360
# Month=37, Predicted=15.7453, Expected=15.6930
# Month=38, Predicted=15.7167, Expected=16.7550
# Month=39, Predicted=17.3533, Expected=16.5090
# Month=40, Predicted=16.3447, Expected=17.7230
# Month=41, Predicted=18.3851, Expected=18.6910
# Month=42, Predicted=19.2432, Expected=19.1270
# Month=43, Predicted=19.3768, Expected=19.5640
# Month=44, Predicted=19.8153, Expected=19.2030
# Month=45, Predicted=18.9688, Expected=18.2160
# Month=46, Predicted=17.6090, Expected=17.2110
# Month=47, Predicted=16.6028, Expected=16.6600
# Month=48, Predicted=16.3251, Expected=16.8310
# Month=49, Predicted=16.9310, Expected=15.7690
# Month=50, Predicted=15.1138, Expected=15.7310
# Month=51, Predicted=15.7125, Expected=15.9960
# Month=52, Predicted=16.1472, Expected=17.0210
# Month=53, Predicted=17.6023, Expected=17.5520
# Month=54, Predicted=17.8577, Expected=17.8370
# Month=55, Predicted=17.9974, Expected=17.8560
# Month=56, Predicted=17.8560, Expected=17.5710
# Month=57, Predicted=17.3857, Expected=17.0780
# Month=58, Predicted=16.7676, Expected=16.6600
# Month=59, Predicted=16.3982, Expected=16.4330
# Month=60, Predicted=16.2877, Expected=16.5840
# Run 12 — RMSE: 0.498805, MSE: 0.248806, NMSE: 0.0018964359
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=13.2181, Expected=13.7000
# Month=2, Predicted=14.0590, Expected=13.8140
# Month=3, Predicted=13.8266, Expected=14.3830
# Month=4, Predicted=14.7451, Expected=15.0470
# Month=5, Predicted=15.4387, Expected=15.6930
# Month=6, Predicted=16.0705, Expected=15.8440
# Month=7, Predicted=15.8803, Expected=15.7120
# Month=8, Predicted=15.5772, Expected=15.3130
# Month=9, Predicted=15.0250, Expected=14.7630
# Month=10, Predicted=14.4053, Expected=13.5480
# Month=11, Predicted=12.8693, Expected=13.5860
# Month=12, Predicted=13.7455, Expected=14.5160
# Month=13, Predicted=15.0496, Expected=14.3830
# Month=14, Predicted=14.2142, Expected=14.4970
# Month=15, Predicted=14.5634, Expected=14.7440
# Month=16, Predicted=14.8817, Expected=15.8060
# Month=17, Predicted=16.3396, Expected=16.5270
# Month=18, Predicted=16.9411, Expected=16.5460
# Month=19, Predicted=16.4860, Expected=16.7170
# Month=20, Predicted=16.8096, Expected=16.4330
# Month=21, Predicted=16.1953, Expected=15.7690
# Month=22, Predicted=15.3377, Expected=15.2750
# Month=23, Predicted=14.9767, Expected=15.1230
# Month=24, Predicted=15.0332, Expected=15.5410
# Month=25, Predicted=15.8255, Expected=15.8250
# Month=26, Predicted=15.9676, Expected=16.3760
# Month=27, Predicted=16.7134, Expected=16.3570
# Month=28, Predicted=16.2765, Expected=16.9070
# Month=29, Predicted=17.2689, Expected=17.0210
# Month=30, Predicted=17.0342, Expected=17.4190
# Month=31, Predicted=17.6664, Expected=17.5330
# Month=32, Predicted=17.5543, Expected=17.2680
# Month=33, Predicted=17.0470, Expected=16.6030
# Month=34, Predicted=16.1696, Expected=15.8250
# Month=35, Predicted=15.3617, Expected=15.4460
# Month=36, Predicted=15.2336, Expected=15.6360
# Month=37, Predicted=15.7817, Expected=15.6930
# Month=38, Predicted=15.6862, Expected=16.7550
# Month=39, Predicted=17.2886, Expected=16.5090
# Month=40, Predicted=16.2666, Expected=17.7230
# Month=41, Predicted=18.2566, Expected=18.6910
# Month=42, Predicted=19.2213, Expected=19.1270
# Month=43, Predicted=19.3580, Expected=19.5640
# Month=44, Predicted=19.8153, Expected=19.2030
# Month=45, Predicted=18.9036, Expected=18.2160
# Month=46, Predicted=17.6272, Expected=17.2110
# Month=47, Predicted=16.6585, Expected=16.6600
# Month=48, Predicted=16.3610, Expected=16.8310
# Month=49, Predicted=16.9839, Expected=15.7690
# Month=50, Predicted=15.1192, Expected=15.7310
# Month=51, Predicted=15.8107, Expected=15.9960
# Month=52, Predicted=16.1571, Expected=17.0210
# Month=53, Predicted=17.5546, Expected=17.5520
# Month=54, Predicted=17.8479, Expected=17.8370
# Month=55, Predicted=17.9751, Expected=17.8560
# Month=56, Predicted=17.8170, Expected=17.5710
# Month=57, Predicted=17.3438, Expected=17.0780
# Month=58, Predicted=16.7449, Expected=16.6600
# Month=59, Predicted=16.3919, Expected=16.4330
# Month=60, Predicted=16.2828, Expected=16.5840
# Run 13 — RMSE: 0.496712, MSE: 0.246723, NMSE: 0.0019185802
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=13.2041, Expected=13.7000
# Month=2, Predicted=14.0197, Expected=13.8140
# Month=3, Predicted=13.8648, Expected=14.3830
# Month=4, Predicted=14.7030, Expected=15.0470
# Month=5, Predicted=15.4152, Expected=15.6930
# Month=6, Predicted=16.0509, Expected=15.8440
# Month=7, Predicted=15.9166, Expected=15.7120
# Month=8, Predicted=15.6166, Expected=15.3130
# Month=9, Predicted=15.0551, Expected=14.7630
# Month=10, Predicted=14.4153, Expected=13.5480
# Month=11, Predicted=12.7776, Expected=13.5860
# Month=12, Predicted=13.6331, Expected=14.5160
# Month=13, Predicted=15.0315, Expected=14.3830
# Month=14, Predicted=14.2818, Expected=14.4970
# Month=15, Predicted=14.5566, Expected=14.7440
# Month=16, Predicted=14.8788, Expected=15.8060
# Month=17, Predicted=16.3860, Expected=16.5270
# Month=18, Predicted=16.9241, Expected=16.5460
# Month=19, Predicted=16.5385, Expected=16.7170
# Month=20, Predicted=16.8081, Expected=16.4330
# Month=21, Predicted=16.2425, Expected=15.7690
# Month=22, Predicted=15.3455, Expected=15.2750
# Month=23, Predicted=14.9705, Expected=15.1230
# Month=24, Predicted=15.0286, Expected=15.5410
# Month=25, Predicted=15.7799, Expected=15.8250
# Month=26, Predicted=15.9781, Expected=16.3760
# Month=27, Predicted=16.6838, Expected=16.3570
# Month=28, Predicted=16.3271, Expected=16.9070
# Month=29, Predicted=17.2184, Expected=17.0210
# Month=30, Predicted=17.0719, Expected=17.4190
# Month=31, Predicted=17.6419, Expected=17.5330
# Month=32, Predicted=17.5851, Expected=17.2680
# Month=33, Predicted=17.0902, Expected=16.6030
# Month=34, Predicted=16.1785, Expected=15.8250
# Month=35, Predicted=15.3388, Expected=15.4460
# Month=36, Predicted=15.2182, Expected=15.6360
# Month=37, Predicted=15.7466, Expected=15.6930
# Month=38, Predicted=15.7130, Expected=16.7550
# Month=39, Predicted=17.3373, Expected=16.5090
# Month=40, Predicted=16.3360, Expected=17.7230
# Month=41, Predicted=18.3847, Expected=18.6910
# Month=42, Predicted=19.2160, Expected=19.1270
# Month=43, Predicted=19.3663, Expected=19.5640
# Month=44, Predicted=19.8057, Expected=19.2030
# Month=45, Predicted=18.9610, Expected=18.2160
# Month=46, Predicted=17.5869, Expected=17.2110
# Month=47, Predicted=16.5898, Expected=16.6600
# Month=48, Predicted=16.3313, Expected=16.8310
# Month=49, Predicted=16.9348, Expected=15.7690
# Month=50, Predicted=15.0816, Expected=15.7310
# Month=51, Predicted=15.7256, Expected=15.9960
# Month=52, Predicted=16.1439, Expected=17.0210
# Month=53, Predicted=17.5822, Expected=17.5520
# Month=54, Predicted=17.8445, Expected=17.8370
# Month=55, Predicted=17.9898, Expected=17.8560
# Month=56, Predicted=17.8517, Expected=17.5710
# Month=57, Predicted=17.3822, Expected=17.0780
# Month=58, Predicted=16.7638, Expected=16.6600
# Month=59, Predicted=16.3987, Expected=16.4330
# Month=60, Predicted=16.2899, Expected=16.5840
# Run 14 — RMSE: 0.498347, MSE: 0.248349, NMSE: 0.0018959849
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=13.2112, Expected=13.7000
# Month=2, Predicted=14.0339, Expected=13.8140
# Month=3, Predicted=13.8550, Expected=14.3830
# Month=4, Predicted=14.7175, Expected=15.0470
# Month=5, Predicted=15.4279, Expected=15.6930
# Month=6, Predicted=16.0629, Expected=15.8440
# Month=7, Predicted=15.9101, Expected=15.7120
# Month=8, Predicted=15.5953, Expected=15.3130
# Month=9, Predicted=15.0393, Expected=14.7630
# Month=10, Predicted=14.4140, Expected=13.5480
# Month=11, Predicted=12.8644, Expected=13.5860
# Month=12, Predicted=13.6899, Expected=14.5160
# Month=13, Predicted=15.0565, Expected=14.3830
# Month=14, Predicted=14.2564, Expected=14.4970
# Month=15, Predicted=14.5587, Expected=14.7440
# Month=16, Predicted=14.8884, Expected=15.8060
# Month=17, Predicted=16.4102, Expected=16.5270
# Month=18, Predicted=16.9389, Expected=16.5460
# Month=19, Predicted=16.5208, Expected=16.7170
# Month=20, Predicted=16.8114, Expected=16.4330
# Month=21, Predicted=16.2188, Expected=15.7690
# Month=22, Predicted=15.3497, Expected=15.2750
# Month=23, Predicted=14.9760, Expected=15.1230
# Month=24, Predicted=15.0262, Expected=15.5410
# Month=25, Predicted=15.7980, Expected=15.8250
# Month=26, Predicted=15.9866, Expected=16.3760
# Month=27, Predicted=16.6956, Expected=16.3570
# Month=28, Predicted=16.3073, Expected=16.9070
# Month=29, Predicted=17.2352, Expected=17.0210
# Month=30, Predicted=17.0622, Expected=17.4190
# Month=31, Predicted=17.6540, Expected=17.5330
# Month=32, Predicted=17.5763, Expected=17.2680
# Month=33, Predicted=17.0673, Expected=16.6030
# Month=34, Predicted=16.1822, Expected=15.8250
# Month=35, Predicted=15.3656, Expected=15.4460
# Month=36, Predicted=15.2259, Expected=15.6360
# Month=37, Predicted=15.7663, Expected=15.6930
# Month=38, Predicted=15.7019, Expected=16.7550
# Month=39, Predicted=17.3639, Expected=16.5090
# Month=40, Predicted=16.3098, Expected=17.7230
# Month=41, Predicted=18.4159, Expected=18.6910
# Month=42, Predicted=19.2389, Expected=19.1270
# Month=43, Predicted=19.3742, Expected=19.5640
# Month=44, Predicted=19.8145, Expected=19.2030
# Month=45, Predicted=18.9362, Expected=18.2160
# Month=46, Predicted=17.6319, Expected=17.2110
# Month=47, Predicted=16.6562, Expected=16.6600
# Month=48, Predicted=16.3551, Expected=16.8310
# Month=49, Predicted=16.9610, Expected=15.7690
# Month=50, Predicted=15.1308, Expected=15.7310
# Month=51, Predicted=15.7639, Expected=15.9960
# Month=52, Predicted=16.1589, Expected=17.0210
# Month=53, Predicted=17.6058, Expected=17.5520
# Month=54, Predicted=17.8543, Expected=17.8370
# Month=55, Predicted=17.9978, Expected=17.8560
# Month=56, Predicted=17.8364, Expected=17.5710
# Month=57, Predicted=17.3611, Expected=17.0780
# Month=58, Predicted=16.7559, Expected=16.6600
# Month=59, Predicted=16.3947, Expected=16.4330
# Month=60, Predicted=16.2821, Expected=16.5840
# Run 15 — RMSE: 0.495269, MSE: 0.245291, NMSE: 0.0018821446
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=13.1708, Expected=13.7000
# Month=2, Predicted=13.9820, Expected=13.8140
# Month=3, Predicted=13.8239, Expected=14.3830
# Month=4, Predicted=14.6658, Expected=15.0470
# Month=5, Predicted=15.3798, Expected=15.6930
# Month=6, Predicted=16.0147, Expected=15.8440
# Month=7, Predicted=15.8748, Expected=15.7120
# Month=8, Predicted=15.5908, Expected=15.3130
# Month=9, Predicted=15.0520, Expected=14.7630
# Month=10, Predicted=14.4306, Expected=13.5480
# Month=11, Predicted=12.8653, Expected=13.5860
# Month=12, Predicted=13.6402, Expected=14.5160
# Month=13, Predicted=15.0215, Expected=14.3830
# Month=14, Predicted=14.2565, Expected=14.4970
# Month=15, Predicted=14.5226, Expected=14.7440
# Month=16, Predicted=14.8371, Expected=15.8060
# Month=17, Predicted=16.3889, Expected=16.5270
# Month=18, Predicted=16.8965, Expected=16.5460
# Month=19, Predicted=16.5023, Expected=16.7170
# Month=20, Predicted=16.7695, Expected=16.4330
# Month=21, Predicted=16.2263, Expected=15.7690
# Month=22, Predicted=15.3685, Expected=15.2750
# Month=23, Predicted=14.9892, Expected=15.1230
# Month=24, Predicted=15.0167, Expected=15.5410
# Month=25, Predicted=15.7427, Expected=15.8250
# Month=26, Predicted=15.9335, Expected=16.3760
# Month=27, Predicted=16.6440, Expected=16.3570
# Month=28, Predicted=16.2922, Expected=16.9070
# Month=29, Predicted=17.1827, Expected=17.0210
# Month=30, Predicted=17.0310, Expected=17.4190
# Month=31, Predicted=17.6003, Expected=17.5330
# Month=32, Predicted=17.5444, Expected=17.2680
# Month=33, Predicted=17.0735, Expected=16.6030
# Month=34, Predicted=16.2010, Expected=15.8250
# Month=35, Predicted=15.3832, Expected=15.4460
# Month=36, Predicted=15.2313, Expected=15.6360
# Month=37, Predicted=15.7154, Expected=15.6930
# Month=38, Predicted=15.6756, Expected=16.7550
# Month=39, Predicted=17.3430, Expected=16.5090
# Month=40, Predicted=16.3199, Expected=17.7230
# Month=41, Predicted=18.4125, Expected=18.6910
# Month=42, Predicted=19.2140, Expected=19.1270
# Month=43, Predicted=19.3253, Expected=19.5640
# Month=44, Predicted=19.7619, Expected=19.2030
# Month=45, Predicted=18.9489, Expected=18.2160
# Month=46, Predicted=17.6445, Expected=17.2110
# Month=47, Predicted=16.6692, Expected=16.6600
# Month=48, Predicted=16.3663, Expected=16.8310
# Month=49, Predicted=16.9090, Expected=15.7690
# Month=50, Predicted=15.1378, Expected=15.7310
# Month=51, Predicted=15.7299, Expected=15.9960
# Month=52, Predicted=16.1031, Expected=17.0210
# Month=53, Predicted=17.5816, Expected=17.5520
# Month=54, Predicted=17.8067, Expected=17.8370
# Month=55, Predicted=17.9452, Expected=17.8560
# Month=56, Predicted=17.8156, Expected=17.5710
# Month=57, Predicted=17.3681, Expected=17.0780
# Month=58, Predicted=16.7715, Expected=16.6600
# Month=59, Predicted=16.4058, Expected=16.4330
# Month=60, Predicted=16.2808, Expected=16.5840
# Run 16 — RMSE: 0.498521, MSE: 0.248523, NMSE: 0.0019102307
#
# ===== RUN 17/30 =====
# Training complete for run 17
# Month=1, Predicted=13.2044, Expected=13.7000
# Month=2, Predicted=14.0339, Expected=13.8140
# Month=3, Predicted=13.7081, Expected=14.3830
# Month=4, Predicted=14.7195, Expected=15.0470
# Month=5, Predicted=15.3468, Expected=15.6930
# Month=6, Predicted=15.9561, Expected=15.8440
# Month=7, Predicted=15.7466, Expected=15.7120
# Month=8, Predicted=15.5382, Expected=15.3130
# Month=9, Predicted=15.0528, Expected=14.7630
# Month=10, Predicted=14.4759, Expected=13.5480
# Month=11, Predicted=13.0619, Expected=13.5860
# Month=12, Predicted=13.8399, Expected=14.5160
# Month=13, Predicted=15.2098, Expected=14.3830
# Month=14, Predicted=14.0958, Expected=14.4970
# Month=15, Predicted=14.5292, Expected=14.7440
# Month=16, Predicted=14.8200, Expected=15.8060
# Month=17, Predicted=16.4910, Expected=16.5270
# Month=18, Predicted=16.7849, Expected=16.5460
# Month=19, Predicted=16.3613, Expected=16.7170
# Month=20, Predicted=16.7569, Expected=16.4330
# Month=21, Predicted=16.1811, Expected=15.7690
# Month=22, Predicted=15.4204, Expected=15.2750
# Month=23, Predicted=15.0540, Expected=15.1230
# Month=24, Predicted=15.0618, Expected=15.5410
# Month=25, Predicted=15.8268, Expected=15.8250
# Month=26, Predicted=15.8601, Expected=16.3760
# Month=27, Predicted=16.6555, Expected=16.3570
# Month=28, Predicted=16.1787, Expected=16.9070
# Month=29, Predicted=17.2629, Expected=17.0210
# Month=30, Predicted=16.9186, Expected=17.4190
# Month=31, Predicted=17.6118, Expected=17.5330
# Month=32, Predicted=17.4584, Expected=17.2680
# Month=33, Predicted=17.0330, Expected=16.6030
# Month=34, Predicted=16.2518, Expected=15.8250
# Month=35, Predicted=15.4832, Expected=15.4460
# Month=36, Predicted=15.3062, Expected=15.6360
# Month=37, Predicted=15.7923, Expected=15.6930
# Month=38, Predicted=15.6236, Expected=16.7550
# Month=39, Predicted=17.4681, Expected=16.5090
# Month=40, Predicted=16.1723, Expected=17.7230
# Month=41, Predicted=18.5055, Expected=18.6910
# Month=42, Predicted=19.1561, Expected=19.1270
# ...
# Month=26, Predicted=15.9678, Expected=16.3760
# Month=27, Predicted=16.6897, Expected=16.3570
# Month=28, Predicted=16.2951, Expected=16.9070
# Month=29, Predicted=17.2330, Expected=17.0210
# Month=30, Predicted=17.0539, Expected=17.4190
# Month=31, Predicted=17.6441, Expected=17.5330
# Month=32, Predicted=17.5706, Expected=17.2680
# Month=33, Predicted=17.0557, Expected=16.6030
# Month=34, Predicted=16.1664, Expected=15.8250
# Month=35, Predicted=15.3535, Expected=15.4460
# Month=36, Predicted=15.2231, Expected=15.6360
# Month=37, Predicted=15.7594, Expected=15.6930
# Month=38, Predicted=15.6980, Expected=16.7550
# Month=39, Predicted=17.3678, Expected=16.5090
# Month=40, Predicted=16.2816, Expected=17.7230
# Month=41, Predicted=18.4298, Expected=18.6910
# Month=42, Predicted=19.2217, Expected=19.1270
# Month=43, Predicted=19.3513, Expected=19.5640
# Month=44, Predicted=19.8017, Expected=19.2030
# Month=45, Predicted=18.9170, Expected=18.2160
# Month=46, Predicted=17.6104, Expected=17.2110
# Month=47, Predicted=16.6460, Expected=16.6600
# Month=48, Predicted=16.3529, Expected=16.8310
# Month=49, Predicted=16.9555, Expected=15.7690
# Month=50, Predicted=15.0993, Expected=15.7310
# Month=51, Predicted=15.7709, Expected=15.9960
# Month=52, Predicted=16.1456, Expected=17.0210
# Month=53, Predicted=17.6059, Expected=17.5520
# Month=54, Predicted=17.8344, Expected=17.8370
# Month=55, Predicted=17.9771, Expected=17.8560
# Month=56, Predicted=17.8299, Expected=17.5710
# Month=57, Predicted=17.3502, Expected=17.0780
# Month=58, Predicted=16.7442, Expected=16.6600
# Month=59, Predicted=16.3874, Expected=16.4330
# Month=60, Predicted=16.2781, Expected=16.5840
# Run 25 — RMSE: 0.496911, MSE: 0.246920, NMSE: 0.0018965221
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=13.1895, Expected=13.7000
# Month=2, Predicted=14.0071, Expected=13.8140
# Month=3, Predicted=13.8293, Expected=14.3830
# Month=4, Predicted=14.6910, Expected=15.0470
# Month=5, Predicted=15.4005, Expected=15.6930
# Month=6, Predicted=16.0343, Expected=15.8440
# Month=7, Predicted=15.8810, Expected=15.7120
# Month=8, Predicted=15.5881, Expected=15.3130
# Month=9, Predicted=15.0412, Expected=14.7630
# Month=10, Predicted=14.4188, Expected=13.5480
# Month=11, Predicted=12.8248, Expected=13.5860
# Month=12, Predicted=13.6851, Expected=14.5160
# Month=13, Predicted=15.0473, Expected=14.3830
# Month=14, Predicted=14.2447, Expected=14.4970
# Month=15, Predicted=14.5380, Expected=14.7440
# Month=16, Predicted=14.8539, Expected=15.8060
# Month=17, Predicted=16.4040, Expected=16.5270
# Month=18, Predicted=16.9131, Expected=16.5460
# Month=19, Predicted=16.5013, Expected=16.7170
# Month=20, Predicted=16.7846, Expected=16.4330
# Month=21, Predicted=16.2158, Expected=15.7690
# Month=22, Predicted=15.3479, Expected=15.2750
# Month=23, Predicted=14.9878, Expected=15.1230
# Month=24, Predicted=15.0274, Expected=15.5410
# Month=25, Predicted=15.7697, Expected=15.8250
# Month=26, Predicted=15.9476, Expected=16.3760
# Month=27, Predicted=16.6666, Expected=16.3570
# Month=28, Predicted=16.2910, Expected=16.9070
# Month=29, Predicted=17.2095, Expected=17.0210
# Month=30, Predicted=17.0366, Expected=17.4190
# Month=31, Predicted=17.6218, Expected=17.5330
# Month=32, Predicted=17.5517, Expected=17.2680
# Month=33, Predicted=17.0647, Expected=16.6030
# Month=34, Predicted=16.1800, Expected=15.8250
# Month=35, Predicted=15.3679, Expected=15.4460
# Month=36, Predicted=15.2396, Expected=15.6360
# Month=37, Predicted=15.7403, Expected=15.6930
# Month=38, Predicted=15.6831, Expected=16.7550
# Month=39, Predicted=17.3609, Expected=16.5090
# Month=40, Predicted=16.3017, Expected=17.7230
# Month=41, Predicted=18.4314, Expected=18.6910
# Month=42, Predicted=19.2244, Expected=19.1270
# Month=43, Predicted=19.3380, Expected=19.5640
# Month=44, Predicted=19.7804, Expected=19.2030
# Month=45, Predicted=18.9310, Expected=18.2160
# Month=46, Predicted=17.6097, Expected=17.2110
# Month=47, Predicted=16.6542, Expected=16.6600
# Month=48, Predicted=16.3748, Expected=16.8310
# Month=49, Predicted=16.9378, Expected=15.7690
# Month=50, Predicted=15.0889, Expected=15.7310
# Month=51, Predicted=15.7646, Expected=15.9960
# Month=52, Predicted=16.1239, Expected=17.0210
# Month=53, Predicted=17.5974, Expected=17.5520
# Month=54, Predicted=17.8214, Expected=17.8370
# Month=55, Predicted=17.9580, Expected=17.8560
# Month=56, Predicted=17.8196, Expected=17.5710
# Month=57, Predicted=17.3599, Expected=17.0780
# Month=58, Predicted=16.7595, Expected=16.6600
# Month=59, Predicted=16.4030, Expected=16.4330
# Month=60, Predicted=16.2855, Expected=16.5840
# Run 26 — RMSE: 0.498083, MSE: 0.248087, NMSE: 0.0019045597
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=13.1873, Expected=13.7000
# Month=2, Predicted=14.0090, Expected=13.8140
# Month=3, Predicted=13.7438, Expected=14.3830
# Month=4, Predicted=14.6935, Expected=15.0470
# Month=5, Predicted=15.3607, Expected=15.6930
# Month=6, Predicted=15.9807, Expected=15.8440
# Month=7, Predicted=15.7882, Expected=15.7120
# Month=8, Predicted=15.5472, Expected=15.3130
# Month=9, Predicted=15.0504, Expected=14.7630
# Month=10, Predicted=14.4666, Expected=13.5480
# Month=11, Predicted=13.0359, Expected=13.5860
# Month=12, Predicted=13.8052, Expected=14.5160
# Month=13, Predicted=15.1420, Expected=14.3830
# Month=14, Predicted=14.1530, Expected=14.4970
# Month=15, Predicted=14.5204, Expected=14.7440
# Month=16, Predicted=14.8162, Expected=15.8060
# Month=17, Predicted=16.4593, Expected=16.5270
# Month=18, Predicted=16.8423, Expected=16.5460
# Month=19, Predicted=16.4075, Expected=16.7170
# Month=20, Predicted=16.7521, Expected=16.4330
# Month=21, Predicted=16.1899, Expected=15.7690
# Month=22, Predicted=15.4112, Expected=15.2750
# Month=23, Predicted=15.0423, Expected=15.1230
# Month=24, Predicted=15.0478, Expected=15.5410
# Month=25, Predicted=15.7898, Expected=15.8250
# Month=26, Predicted=15.8800, Expected=16.3760
# Month=27, Predicted=16.6437, Expected=16.3570
# Month=28, Predicted=16.2122, Expected=16.9070
# Month=29, Predicted=17.2290, Expected=17.0210
# Month=30, Predicted=16.9528, Expected=17.4190
# Month=31, Predicted=17.5976, Expected=17.5330
# Month=32, Predicted=17.4810, Expected=17.2680
# Month=33, Predicted=17.0395, Expected=16.6030
# Month=34, Predicted=16.2428, Expected=15.8250
# Month=35, Predicted=15.4679, Expected=15.4460
# Month=36, Predicted=15.2924, Expected=15.6360
# Month=37, Predicted=15.7638, Expected=15.6930
# Month=38, Predicted=15.6326, Expected=16.7550
# Month=39, Predicted=17.4284, Expected=16.5090
# Month=40, Predicted=16.2247, Expected=17.7230
# Month=41, Predicted=18.4634, Expected=18.6910
# Month=42, Predicted=19.2020, Expected=19.1270
# Month=43, Predicted=19.2307, Expected=19.5640
# Month=44, Predicted=19.7228, Expected=19.2030
# Month=45, Predicted=18.9007, Expected=18.2160
# Month=46, Predicted=17.7530, Expected=17.2110
# Month=47, Predicted=16.8081, Expected=16.6600
# Month=48, Predicted=16.4564, Expected=16.8310
# Month=49, Predicted=16.9843, Expected=15.7690
# Month=50, Predicted=15.2471, Expected=15.7310
# Month=51, Predicted=15.8505, Expected=15.9960
# Month=52, Predicted=16.1098, Expected=17.0210
# Month=53, Predicted=17.6657, Expected=17.5520
# Month=54, Predicted=17.7240, Expected=17.8370
# Month=55, Predicted=17.8781, Expected=17.8560
# Month=56, Predicted=17.7600, Expected=17.5710
# Month=57, Predicted=17.3441, Expected=17.0780
# Month=58, Predicted=16.7920, Expected=16.6600
# Month=59, Predicted=16.4386, Expected=16.4330
# Month=60, Predicted=16.3007, Expected=16.5840
# Run 27 — RMSE: 0.505567, MSE: 0.255598, NMSE: 0.0020185315
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=13.1976, Expected=13.7000
# Month=2, Predicted=13.9959, Expected=13.8140
# Month=3, Predicted=13.7084, Expected=14.3830
# Month=4, Predicted=14.6875, Expected=15.0470
# Month=5, Predicted=15.3065, Expected=15.6930
# Month=6, Predicted=15.9220, Expected=15.8440
# Month=7, Predicted=15.7495, Expected=15.7120
# Month=8, Predicted=15.5389, Expected=15.3130
# Month=9, Predicted=15.0509, Expected=14.7630
# Month=10, Predicted=14.4733, Expected=13.5480
# Month=11, Predicted=13.0098, Expected=13.5860
# Month=12, Predicted=13.9210, Expected=14.5160
# Month=13, Predicted=15.1182, Expected=14.3830
# Month=14, Predicted=14.1108, Expected=14.4970
# Month=15, Predicted=14.5307, Expected=14.7440
# Month=16, Predicted=14.8054, Expected=15.8060
# Month=17, Predicted=16.4524, Expected=16.5270
# Month=18, Predicted=16.7547, Expected=16.5460
# Month=19, Predicted=16.3706, Expected=16.7170
# Month=20, Predicted=16.7517, Expected=16.4330
# Month=21, Predicted=16.1788, Expected=15.7690
# Month=22, Predicted=15.4101, Expected=15.2750
# Month=23, Predicted=15.0637, Expected=15.1230
# Month=24, Predicted=15.0688, Expected=15.5410
# Month=25, Predicted=15.8009, Expected=15.8250
# Month=26, Predicted=15.8466, Expected=16.3760
# Month=27, Predicted=16.6203, Expected=16.3570
# Month=28, Predicted=16.1821, Expected=16.9070
# Month=29, Predicted=17.2363, Expected=17.0210
# Month=30, Predicted=16.9177, Expected=17.4190
# Month=31, Predicted=17.5910, Expected=17.5330
# Month=32, Predicted=17.4542, Expected=17.2680
# Month=33, Predicted=17.0324, Expected=16.6030
# Month=34, Predicted=16.2408, Expected=15.8250
# Month=35, Predicted=15.4758, Expected=15.4460
# Month=36, Predicted=15.3239, Expected=15.6360
# Month=37, Predicted=15.7861, Expected=15.6930
# Month=38, Predicted=15.6164, Expected=16.7550
# Month=39, Predicted=17.4696, Expected=16.5090
# Month=40, Predicted=16.1864, Expected=17.7230
# Month=41, Predicted=18.6979, Expected=18.6910
# Month=42, Predicted=19.0910, Expected=19.1270
# Month=43, Predicted=19.1599, Expected=19.5640
# Month=44, Predicted=19.6889, Expected=19.2030
# Month=45, Predicted=18.8804, Expected=18.2160
# Month=46, Predicted=17.7390, Expected=17.2110
# Month=47, Predicted=16.8169, Expected=16.6600
# Month=48, Predicted=16.4922, Expected=16.8310
# Month=49, Predicted=17.0201, Expected=15.7690
# Month=50, Predicted=15.2105, Expected=15.7310
# Month=51, Predicted=15.9410, Expected=15.9960
# Month=52, Predicted=16.1029, Expected=17.0210
# Month=53, Predicted=17.6311, Expected=17.5520
# Month=54, Predicted=17.6482, Expected=17.8370
# Month=55, Predicted=17.8414, Expected=17.8560
# Month=56, Predicted=17.7428, Expected=17.5710
# Month=57, Predicted=17.3404, Expected=17.0780
# Month=58, Predicted=16.7962, Expected=16.6600
# Month=59, Predicted=16.4535, Expected=16.4330
# Month=60, Predicted=16.3158, Expected=16.5840
# Run 28 — RMSE: 0.509114, MSE: 0.259197, NMSE: 0.0020605870
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=13.2347, Expected=13.7000
# Month=2, Predicted=14.0393, Expected=13.8140
# Month=3, Predicted=13.8187, Expected=14.3830
# Month=4, Predicted=14.7244, Expected=15.0470
# Month=5, Predicted=15.4078, Expected=15.6930
# Month=6, Predicted=16.0373, Expected=15.8440
# Month=7, Predicted=15.8700, Expected=15.7120
# Month=8, Predicted=15.5830, Expected=15.3130
# Month=9, Predicted=15.0357, Expected=14.7630
# Month=10, Predicted=14.4203, Expected=13.5480
# Month=11, Predicted=12.7862, Expected=13.5860
# Month=12, Predicted=13.7942, Expected=14.5160
# Month=13, Predicted=15.0865, Expected=14.3830
# Month=14, Predicted=14.2039, Expected=14.4970
# Month=15, Predicted=14.5748, Expected=14.7440
# Month=16, Predicted=14.8785, Expected=15.8060
# Month=17, Predicted=16.4312, Expected=16.5270
# Month=18, Predicted=16.9063, Expected=16.5460
# Month=19, Predicted=16.4769, Expected=16.7170
# Month=20, Predicted=16.8128, Expected=16.4330
# Month=21, Predicted=16.1980, Expected=15.7690
# Month=22, Predicted=15.3331, Expected=15.2750
# Month=23, Predicted=15.0118, Expected=15.1230
# Month=24, Predicted=15.0697, Expected=15.5410
# Month=25, Predicted=15.8199, Expected=15.8250
# Month=26, Predicted=15.9540, Expected=16.3760
# Month=27, Predicted=16.6882, Expected=16.3570
# Month=28, Predicted=16.2708, Expected=16.9070
# Month=29, Predicted=17.2523, Expected=17.0210
# Month=30, Predicted=17.0270, Expected=17.4190
# Month=31, Predicted=17.6514, Expected=17.5330
# Month=32, Predicted=17.5504, Expected=17.2680
# Month=33, Predicted=17.0520, Expected=16.6030
# Month=34, Predicted=16.1639, Expected=15.8250
# Month=35, Predicted=15.3683, Expected=15.4460
# Month=36, Predicted=15.2817, Expected=15.6360
# Month=37, Predicted=15.7998, Expected=15.6930
# Month=38, Predicted=15.6909, Expected=16.7550
# Month=39, Predicted=17.3998, Expected=16.5090
# Month=40, Predicted=16.2504, Expected=17.7230
# Month=41, Predicted=18.4883, Expected=18.6910
# Month=42, Predicted=19.2155, Expected=19.1270
# Month=43, Predicted=19.3291, Expected=19.5640
# Month=44, Predicted=19.7904, Expected=19.2030
# Month=45, Predicted=18.8921, Expected=18.2160
# Month=46, Predicted=17.5767, Expected=17.2110
# Month=47, Predicted=16.6530, Expected=16.6600
# Month=48, Predicted=16.4159, Expected=16.8310
# Month=49, Predicted=17.0096, Expected=15.7690
# Month=50, Predicted=15.0221, Expected=15.7310
# Month=51, Predicted=15.8596, Expected=15.9960
# Month=52, Predicted=16.1607, Expected=17.0210
# Month=53, Predicted=17.6232, Expected=17.5520
# Month=54, Predicted=17.8132, Expected=17.8370
# Month=55, Predicted=17.9583, Expected=17.8560
# Month=56, Predicted=17.8175, Expected=17.5710
# Month=57, Predicted=17.3524, Expected=17.0780
# Month=58, Predicted=16.7576, Expected=16.6600
# Month=59, Predicted=16.4218, Expected=16.4330
# Month=60, Predicted=16.3152, Expected=16.5840
# Run 29 — RMSE: 0.498816, MSE: 0.248817, NMSE: 0.0019224178
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=13.2175, Expected=13.7000
# Month=2, Predicted=14.0620, Expected=13.8140
# Month=3, Predicted=13.8372, Expected=14.3830
# Month=4, Predicted=14.7464, Expected=15.0470
# Month=5, Predicted=15.4447, Expected=15.6930
# Month=6, Predicted=16.0762, Expected=15.8440
# Month=7, Predicted=15.8902, Expected=15.7120
# Month=8, Predicted=15.5859, Expected=15.3130
# Month=9, Predicted=15.0306, Expected=14.7630
# Month=10, Predicted=14.4063, Expected=13.5480
# Month=11, Predicted=12.8658, Expected=13.5860
# Month=12, Predicted=13.6972, Expected=14.5160
# Month=13, Predicted=15.0584, Expected=14.3830
# Month=14, Predicted=14.2235, Expected=14.4970
# Month=15, Predicted=14.5631, Expected=14.7440
# Month=16, Predicted=14.8878, Expected=15.8060
# Month=17, Predicted=16.3484, Expected=16.5270
# Month=18, Predicted=16.9446, Expected=16.5460
# Month=19, Predicted=16.4962, Expected=16.7170
# Month=20, Predicted=16.8130, Expected=16.4330
# Month=21, Predicted=16.2057, Expected=15.7690
# Month=22, Predicted=15.3416, Expected=15.2750
# Month=23, Predicted=14.9691, Expected=15.1230
# Month=24, Predicted=15.0276, Expected=15.5410
# Month=25, Predicted=15.8235, Expected=15.8250
# Month=26, Predicted=15.9770, Expected=16.3760
# Month=27, Predicted=16.7180, Expected=16.3570
# Month=28, Predicted=16.2877, Expected=16.9070
# Month=29, Predicted=17.2670, Expected=17.0210
# Month=30, Predicted=17.0451, Expected=17.4190
# Month=31, Predicted=17.6695, Expected=17.5330
# Month=32, Predicted=17.5646, Expected=17.2680
# Month=33, Predicted=17.0560, Expected=16.6030
# Month=34, Predicted=16.1740, Expected=15.8250
# Month=35, Predicted=15.3577, Expected=15.4460
# Month=36, Predicted=15.2208, Expected=15.6360
# Month=37, Predicted=15.7759, Expected=15.6930
# Month=38, Predicted=15.6957, Expected=16.7550
# Month=39, Predicted=17.2974, Expected=16.5090
# Month=40, Predicted=16.2758, Expected=17.7230
# Month=41, Predicted=18.2654, Expected=18.6910
# Month=42, Predicted=19.2291, Expected=19.1270
# Month=43, Predicted=19.3633, Expected=19.5640
# Month=44, Predicted=19.8223, Expected=19.2030
# Month=45, Predicted=18.9156, Expected=18.2160
# Month=46, Predicted=17.6288, Expected=17.2110
# Month=47, Predicted=16.6474, Expected=16.6600
# Month=48, Predicted=16.3443, Expected=16.8310
# Month=49, Predicted=16.9721, Expected=15.7690
# Month=50, Predicted=15.1263, Expected=15.7310
# Month=51, Predicted=15.7707, Expected=15.9960
# Month=52, Predicted=16.1627, Expected=17.0210
# Month=53, Predicted=17.5634, Expected=17.5520
# Month=54, Predicted=17.8524, Expected=17.8370
# Month=55, Predicted=17.9841, Expected=17.8560
# Month=56, Predicted=17.8265, Expected=17.5710
# Month=57, Predicted=17.3515, Expected=17.0780
# Month=58, Predicted=16.7479, Expected=16.6600
# Month=59, Predicted=16.3889, Expected=16.4330
# Month=60, Predicted=16.2804, Expected=16.5840
# Run 30 — RMSE: 0.498040, MSE: 0.248043, NMSE: 0.0019203424

# %% [markdown]
# ## Results

# %%
# ============================================================
# Summary Statistics (30 runs)
# ============================================================

print('\n===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Lake Erie Levels (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.6f} ± {np.std(all_rmse):.6f}')
print(f'MSE:  {np.mean(all_mse):.6f} ± {np.std(all_mse):.6f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.std(all_nmse):.10f}')

best_idx = np.argmin(all_rmse)
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.6f}')
print(f'  MSE:  {all_mse[best_idx]:.6f}')
print(f'  NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# ===== FINAL RESULTS — Fuzzy Gate Replacement on Monthly Lake Erie Levels (30 runs) =====
# RMSE: 0.499039 ± 0.004080
# MSE:  0.249057 ± 0.004106
# NMSE: 0.0019209184 ± 0.0000560770
#
# Best run: 20
#   RMSE: 0.493551
#   MSE:  0.243593
#   NMSE: 0.0018672712

# %%
# ============================================================
# Predictions vs Actual (Best Run)
# ============================================================

actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(12, 5))
plt.plot(actual, label='Actual', color='blue', linewidth=1.5)
plt.plot(best_predictions, label='Predicted (Best Run)', color='red',
         linewidth=1.5, linestyle='--')
plt.title('Fuzzy Gate Replacement — Monthly Lake Erie Levels\nPredictions vs Actual (Best of 30 runs)')
plt.xlabel('Time Step')
plt.ylabel('Value')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Loss Curve (Best Run)
# ============================================================

plt.figure(figsize=(12, 4))
plt.plot(all_losses[best_idx], color='green', linewidth=1.0)
plt.title('Fuzzy Gate Replacement — Monthly Lake Erie Levels\nTraining Loss (Best Run)')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# ============================================================
# Final Metrics Summary
# ============================================================

print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]:.6f}')
print(f'MSE:  {all_mse[best_idx]:.6f}')
print(f'NMSE: {all_nmse[best_idx]:.10f}')
# Out:
# === Best Run Metrics ===
# RMSE: 0.493551
# MSE:  0.243593
# NMSE: 0.0018672712

# %% [markdown]
# ## Observations
#
# ### Fuzzy Gate Replacement on Monthly Lake Erie Levels
#
# **Run the notebook to generate results and fill in observations:**
#
# 1. **Prediction Quality**: Compare RMSE/MSE/NMSE with other variants
# 2. **Training Stability**: Examine loss curves for convergence behavior
# 3. **Prediction Tracking**: Assess how well predictions track actual values
# 4. **Computational Cost**: Note training time per run
#
# *After running all 5 variant notebooks, perform cross-variant comparison to evaluate
# whether fuzzy logic improves nonlinearity handling, interpretability, and prediction performance.*
