# %% [markdown]
# Paper Referred : [LSTM-SNP: A long short-term memory model inspired from spiking neural P systems](https://drive.google.com/file/d/1V_n4Cn342ShMSTQDLnfiGsBgXEeTGyJE/view?usp=sharing)

# %% [markdown]
# Architecture of Neuron :
#
# ![image.png](data:image/png;base64,...)

# %%
# ============================================================
# ALL IMPORTS (consolidated)
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model

# %% [markdown]
# ## Reset Gate
#
# $$
# r(t) = \rho\left( W_r x(t) + U_r u(t-1) + b_r \right)
# $$
#
# ## Consumption Gate
#
# $$
# c(t) = \rho\left( W_c x(t) + U_c u(t-1) + b_c \right)
# $$
#
# ## Output Gate
#
# $$
# o(t) = \rho\left( W_o x(t) + U_o u(t-1) + b_o \right)
# $$
#
# ## Generated Spikes
#
# $$
# a(t) = f\left( W_a x(t) + U_a u(t-1) + b_a \right)
# $$
#
# ---
#
# ### Parameter Dimensions
#
# $$
# W_* \in \mathbb{R}^{d \times h}, \qquad
# U_* \in \mathbb{R}^{h \times h}, \qquad
# b_* \in \mathbb{R}^{h}
# $$
#
# ---
#
# ### Activations
#
# $$
# \rho(\cdot) = \text{hard sigmoid}, \qquad
# f(\cdot) = \tanh
# $$

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable()
class LSTMSNPCell(layers.Layer):
    """
      This serves as an RNN Cell Instance.
    """
    def __init__(self, units,
                 activation='tanh',
                 recurrent_activation='hard_sigmoid',
                 **kwargs):
        super().__init__(**kwargs)
        self.units = units
        self.state_size = units      # REQUIRED
        self.output_size = units     # REQUIRED

        self.activation = tf.keras.activations.get(activation)
        self.recurrent_activation = tf.keras.activations.get(recurrent_activation)

    def build(self, input_shape):
        input_dim = input_shape[-1]

        self.kernel = self.add_weight(
            shape=(input_dim, self.units * 4),
            initializer='glorot_uniform',
            name='kernel'
        )

        self.recurrent_kernel = self.add_weight(
            shape=(self.units, self.units * 4),
            initializer='orthogonal',
            name='recurrent_kernel'
        )

        self.bias = self.add_weight(
            shape=(self.units * 4,),
            initializer='zeros',
            name='bias'
        )

    def call(self, inputs, states):
        u_tm1 = states[0]

        z = tf.matmul(inputs, self.kernel) + \
            tf.matmul(u_tm1, self.recurrent_kernel) + self.bias

        z0 = z[:, :self.units]
        z1 = z[:, self.units:2*self.units]
        z2 = z[:, 2*self.units:3*self.units]
        z3 = z[:, 3*self.units:]

        r = self.recurrent_activation(z0) #reset :how much previous state reset
        c = self.recurrent_activation(z1) #how much of previous state (u) is consumed.Wrt to current i/p, refer to the T/g(t)->f(t) philosophy
        o = self.recurrent_activation(z2) # generation : how much spike generated.
        a = self.recurrent_activation(z3)

        u = r * u_tm1 - c * a #internal state of LSTM-SNP
        h = o * a #output of SNP

        return h, [u]

# %% [markdown]
# Wrapping in RNN (As directeed in paper)

# %%
def build_model(input_dim, units, batch_size):
    cell = LSTMSNPCell(units)
    rnn = layers.RNN(cell, return_sequences=False, stateful=True)

    inputs = tf.keras.Input(
        batch_shape=(batch_size, 1, input_dim)
    )
    x = rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)

    model.compile(
        optimizer='adam',
        loss='mean_squared_error'
    )

    return model

# %%
model = build_model(input_dim=1, units=8, batch_size=1)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn (RNN)                       │ (1, 8)                 │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (1, 1)                 │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 329 (1.29 KB)
#  Trainable params: 329 (1.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **TESTING ON DOW_JONES DATASET (from GITHUB REPO attached to paper)**

# %% [markdown]
# # LSTM-SNP Experiment Pipeline — Dow Jones Dataset
#
# ## 1. Load Time Series Data
# - Read monthly Dow Jones closing prices
# - Parse date column
# - Extract raw numeric values
#
#
# ## 2. First-Order Differencing
# - Remove trend component
# - Compute:
#
#   diff(t) = raw(t) − raw(t−1)
#
# - Purpose: make series more stationary
#
#
# ## 3. Convert to Supervised Learning Format
# - Use lag = 1
# - Create input-output pairs:
#
#   X(t) = diff(t−1)
#   y(t) = diff(t)
#
# - Fill initial NaN with 0
#
#
# ## 4. Train-Test Split
# - Last 60 samples → Test set
# - Remaining samples → Training set
#
#
#
# ## 5. Feature Scaling
# - Apply MinMaxScaler
# - Scale to range [-1, 1]
# - Fit scaler on training set only
# - Transform both train and test
#
#
# ## 6. Reshape for RNN Input
# - Reshape X_train to:
#
#   (samples, timesteps=1, features=1)
#
# - Required input shape for RNN
#
#
# ## 7. Model Construction
# - Custom LSTM-SNP cell (8 units)
# - Wrapped inside RNN layer
# - Dense(1) output layer
# - Loss: Mean Squared Error
# - Optimizer: Adam
#
#
#
# ## 8. Model Training
# - Epochs: 200
# - Batch size: 1
# - shuffle=False (preserve sequence order)
# - Backpropagation Through Time
#
#
#
# ## 9. Rolling Prediction (One-Step Ahead)
# For each test sample:
# - Predict next differenced value
# - Inverse scale
# - Inverse differencing:
#
#   predicted_raw(t) = predicted_diff(t) + raw(t−1)
#
#
#
# ## 10. Evaluation Metrics
# - RMSE
# - MSE
# - NMSE:
#
#   NMSE = MSE / ||prediction − mean(actual)||²
#
#
# ## 11. Visualization
# - Plot actual vs predicted
# - Observe tracking behavior

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

def parser(x):
    return pd.to_datetime(x, format='%Y-%m')

series = pd.read_csv(
    'content/monthly-closings-of-the-dowjones.csv',
    header=0,
    parse_dates=[0],
    index_col=0
)

raw_values = series.values.flatten()
print(f"Data shape: {raw_values.shape}")
print(f"First 5 values: {raw_values[:5]}")
# Out:
# Data shape: (291,)
# First 5 values: [3645.  3626.  3634.  3620.5 3607. ]

# %%
def difference(dataset, interval=1):
    diff = []
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

diff_values = difference(raw_values, 1)

# %%
def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df.values

supervised = timeseries_to_supervised(diff_values, 1)

# %%
train, test = supervised[:-60], supervised[-60:]

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(train)

train_scaled = scaler.transform(train)
test_scaled = scaler.transform(test)

# %%
X_train, y_train = train_scaled[:, 0:-1], train_scaled[:, -1]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test, y_test = test_scaled[:, 0:-1], test_scaled[:, -1]

# %%
# ============================================================
# 30-Run Experiment Protocol (matching reference test.py)
# ============================================================

all_rmse = []
all_mse = []
all_nmse = []
all_predictions = []

for run in range(30):
    print(f'\n===== RUN {run+1}/30 =====')

    # Fix #4: Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)

    # Build stateful model (Fix #2)
    tf.keras.backend.clear_session()
    model = build_model(input_dim=1, units=8, batch_size=1)

    # Fix #3: Unit forget bias — set consume gate (c) bias to 1.0
    # Access the RNN layer's cell weights
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()  # [kernel, recurrent_kernel, bias]
    bias = weights[2].copy()
    bias[8:16] = 1.0  # units=8, so bias[units:2*units] = bias[8:16]
    weights[2] = bias
    cell.set_weights(weights)

    # Fix #2: Stateful training with manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train,
            y_train,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Fix #6: Warm-up prediction pass on training data
    # This conditions the hidden states before test predictions
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]

        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    all_rmse.append(rmse)
    all_mse.append(mse)
    all_nmse.append(nmse)
    all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3798.8010, Expected=3796.0000
# Month=2, Predicted=3795.8966, Expected=3793.0000
# Month=3, Predicted=3792.8769, Expected=3766.0000
# Month=4, Predicted=3765.2583, Expected=3747.0000
# Month=5, Predicted=3746.4587, Expected=3754.0000
# Month=6, Predicted=3754.1107, Expected=3756.0000
# Month=7, Predicted=3755.9790, Expected=3767.0000
# Month=8, Predicted=3767.2119, Expected=3751.0000
# Month=9, Predicted=3750.5258, Expected=3769.0000
# Month=10, Predicted=3769.3938, Expected=3760.0000
# Month=11, Predicted=3759.7054, Expected=3785.0000
# Month=12, Predicted=3785.5712, Expected=3776.0000
# Month=13, Predicted=3775.7079, Expected=3755.0000
# Month=14, Predicted=3754.4061, Expected=3755.0000
# Month=15, Predicted=3754.9390, Expected=3751.0000
# Month=16, Predicted=3750.8312, Expected=3776.0000
# Month=17, Predicted=3776.5643, Expected=3847.0000
# Month=18, Predicted=3848.7292, Expected=3830.0000
# Month=19, Predicted=3829.5048, Expected=3881.0000
# Month=20, Predicted=3882.2488, Expected=3899.0000
# Month=21, Predicted=3899.4172, Expected=3917.0000
# Month=22, Predicted=3917.4224, Expected=3913.0000
# Month=23, Predicted=3912.8570, Expected=3901.0000
# Month=24, Predicted=3900.6486, Expected=3886.0000
# Month=25, Predicted=3885.5648, Expected=3892.5000
# Month=26, Predicted=3892.6050, Expected=3899.0000
# Month=27, Predicted=3899.0997, Expected=3886.0000
# Month=28, Predicted=3885.6032, Expected=3908.0000
# Month=29, Predicted=3908.4930, Expected=3875.0000
# Month=30, Predicted=3874.0899, Expected=3860.0000
# Month=31, Predicted=3859.5564, Expected=3880.0000
# Month=32, Predicted=3880.4355, Expected=3895.0000
# Month=33, Predicted=3895.3113, Expected=3954.0000
# Month=34, Predicted=3955.4270, Expected=3933.0000
# Month=35, Predicted=3932.4021, Expected=3937.0000
# Month=36, Predicted=3937.0566, Expected=3869.0000
# Month=37, Predicted=3867.2033, Expected=3852.0000
# Month=38, Predicted=3851.5085, Expected=3837.0000
# Month=39, Predicted=3836.5420, Expected=3832.0000
# Month=40, Predicted=3831.7918, Expected=3849.0000
# Month=41, Predicted=3849.3496, Expected=3863.0000
# Month=42, Predicted=3863.2818, Expected=3878.0000
# Month=43, Predicted=3878.3176, Expected=3855.0000
# Month=44, Predicted=3854.3516, Expected=3843.0000
# Month=45, Predicted=3842.6370, Expected=3847.0000
# Month=46, Predicted=3847.0382, Expected=3801.0000
# Month=47, Predicted=3799.7575, Expected=3787.0000
# Month=48, Predicted=3786.5766, Expected=3776.0000
# Month=49, Predicted=3775.6437, Expected=3797.0000
# Month=50, Predicted=3797.4507, Expected=3821.0000
# Month=51, Predicted=3821.5322, Expected=3877.0000
# Month=52, Predicted=3878.3518, Expected=3875.0000
# Month=53, Predicted=3874.8947, Expected=3890.0000
# Month=54, Predicted=3890.3422, Expected=3910.0000
# Month=55, Predicted=3910.4650, Expected=3924.0000
# Month=56, Predicted=3924.3123, Expected=3918.0000
# Month=57, Predicted=3917.7991, Expected=3936.0000
# Month=58, Predicted=3936.4087, Expected=3911.0000
# Month=59, Predicted=3910.3045, Expected=3891.0000
# Month=60, Predicted=3890.4341, Expected=3855.0000
# Run 1 — RMSE: 24.421709, MSE: 596.419859, NMSE: 0.0027233015
#
# ===== RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3798.6248, Expected=3796.0000
# Month=2, Predicted=3795.7673, Expected=3793.0000
# Month=3, Predicted=3792.8560, Expected=3766.0000
# Month=4, Predicted=3765.2904, Expected=3747.0000
# Month=5, Predicted=3746.5908, Expected=3754.0000
# Month=6, Predicted=3754.2233, Expected=3756.0000
# Month=7, Predicted=3756.0116, Expected=3767.0000
# Month=8, Predicted=3767.2121, Expected=3751.0000
# Month=9, Predicted=3750.5238, Expected=3769.0000
# Month=10, Predicted=3769.4229, Expected=3760.0000
# Month=11, Predicted=3759.6927, Expected=3785.0000
# Month=12, Predicted=3785.5552, Expected=3776.0000
# Month=13, Predicted=3775.6622, Expected=3755.0000
# Month=14, Predicted=3754.4470, Expected=3755.0000
# Month=15, Predicted=3755.0372, Expected=3751.0000
# Month=16, Predicted=3750.8873, Expected=3776.0000
# Month=17, Predicted=3776.5580, Expected=3847.0000
# Month=18, Predicted=3848.4117, Expected=3830.0000
# Month=19, Predicted=3829.2830, Expected=3881.0000
# Month=20, Predicted=3882.0796, Expected=3899.0000
# Month=21, Predicted=3899.2246, Expected=3917.0000
# Month=22, Predicted=3917.2855, Expected=3913.0000
# Month=23, Predicted=3912.7837, Expected=3901.0000
# Month=24, Predicted=3900.6637, Expected=3886.0000
# Month=25, Predicted=3885.6382, Expected=3892.5000
# Month=26, Predicted=3892.6836, Expected=3899.0000
# Month=27, Predicted=3899.1143, Expected=3886.0000
# Month=28, Predicted=3885.6177, Expected=3908.0000
# Month=29, Predicted=3908.5084, Expected=3875.0000
# Month=30, Predicted=3874.0606, Expected=3860.0000
# Month=31, Predicted=3859.6871, Expected=3880.0000
# Month=32, Predicted=3880.5061, Expected=3895.0000
# Month=33, Predicted=3895.2682, Expected=3954.0000
# Month=34, Predicted=3955.1914, Expected=3933.0000
# Month=35, Predicted=3932.2225, Expected=3937.0000
# Month=36, Predicted=3937.0669, Expected=3869.0000
# Month=37, Predicted=3867.1490, Expected=3852.0000
# Month=38, Predicted=3851.7865, Expected=3837.0000
# Month=39, Predicted=3836.7268, Expected=3832.0000
# Month=40, Predicted=3831.9268, Expected=3849.0000
# Month=41, Predicted=3849.3951, Expected=3863.0000
# Month=42, Predicted=3863.2388, Expected=3878.0000
# Month=43, Predicted=3878.2487, Expected=3855.0000
# Month=44, Predicted=3854.3156, Expected=3843.0000
# Month=45, Predicted=3842.7264, Expected=3847.0000
# Month=46, Predicted=3847.1171, Expected=3801.0000
# Month=47, Predicted=3799.7798, Expected=3787.0000
# Month=48, Predicted=3786.7793, Expected=3776.0000
# Month=49, Predicted=3775.7878, Expected=3797.0000
# Month=50, Predicted=3797.5096, Expected=3821.0000
# Month=51, Predicted=3821.4603, Expected=3877.0000
# Month=52, Predicted=3878.0993, Expected=3875.0000
# Month=53, Predicted=3874.7010, Expected=3890.0000
# Month=54, Predicted=3890.2630, Expected=3910.0000
# Month=55, Predicted=3910.3722, Expected=3924.0000
# Month=56, Predicted=3924.2154, Expected=3918.0000
# Month=57, Predicted=3917.7509, Expected=3936.0000
# Month=58, Predicted=3936.3889, Expected=3911.0000
# Month=59, Predicted=3910.2804, Expected=3891.0000
# Month=60, Predicted=3890.5381, Expected=3855.0000
# Run 2 — RMSE: 24.431399, MSE: 596.893234, NMSE: 0.0027291758
#
# ===== RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3798.6773, Expected=3796.0000
# Month=2, Predicted=3795.6741, Expected=3793.0000
# Month=3, Predicted=3792.7951, Expected=3766.0000
# Month=4, Predicted=3765.2525, Expected=3747.0000
# Month=5, Predicted=3746.5766, Expected=3754.0000
# Month=6, Predicted=3754.2463, Expected=3756.0000
# Month=7, Predicted=3756.0016, Expected=3767.0000
# Month=8, Predicted=3767.2174, Expected=3751.0000
# Month=9, Predicted=3750.4801, Expected=3769.0000
# Month=10, Predicted=3769.4602, Expected=3760.0000
# Month=11, Predicted=3759.6443, Expected=3785.0000
# Month=12, Predicted=3785.6118, Expected=3776.0000
# Month=13, Predicted=3775.5999, Expected=3755.0000
# Month=14, Predicted=3754.4106, Expected=3755.0000
# Month=15, Predicted=3755.0328, Expected=3751.0000
# Month=16, Predicted=3750.8687, Expected=3776.0000
# Month=17, Predicted=3776.6236, Expected=3847.0000
# Month=18, Predicted=3848.7738, Expected=3830.0000
# Month=19, Predicted=3829.1395, Expected=3881.0000
# Month=20, Predicted=3882.2540, Expected=3899.0000
# Month=21, Predicted=3899.1536, Expected=3917.0000
# Month=22, Predicted=3917.2380, Expected=3913.0000
# Month=23, Predicted=3912.6953, Expected=3901.0000
# Month=24, Predicted=3900.6030, Expected=3886.0000
# Month=25, Predicted=3885.6028, Expected=3892.5000
# Month=26, Predicted=3892.6903, Expected=3899.0000
# Month=27, Predicted=3899.1061, Expected=3886.0000
# Month=28, Predicted=3885.5784, Expected=3908.0000
# Month=29, Predicted=3908.5619, Expected=3875.0000
# Month=30, Predicted=3874.0317, Expected=3860.0000
# Month=31, Predicted=3859.6744, Expected=3880.0000
# Month=32, Predicted=3880.5693, Expected=3895.0000
# Month=33, Predicted=3895.2737, Expected=3954.0000
# Month=34, Predicted=3955.4459, Expected=3933.0000
# Month=35, Predicted=3932.1035, Expected=3937.0000
# Month=36, Predicted=3937.0259, Expected=3869.0000
# Month=37, Predicted=3867.2769, Expected=3852.0000
# Month=38, Predicted=3851.7988, Expected=3837.0000
# Month=39, Predicted=3836.7373, Expected=3832.0000
# Month=40, Predicted=3831.9394, Expected=3849.0000
# Month=41, Predicted=3849.4469, Expected=3863.0000
# Month=42, Predicted=3863.2452, Expected=3878.0000
# Month=43, Predicted=3878.2429, Expected=3855.0000
# Month=44, Predicted=3854.2604, Expected=3843.0000
# Month=45, Predicted=3842.7002, Expected=3847.0000
# Month=46, Predicted=3847.1187, Expected=3801.0000
# Month=47, Predicted=3799.8149, Expected=3787.0000
# Month=48, Predicted=3786.7891, Expected=3776.0000
# Month=49, Predicted=3775.7932, Expected=3797.0000
# Month=50, Predicted=3797.5825, Expected=3821.0000
# Month=51, Predicted=3821.5025, Expected=3877.0000
# Month=52, Predicted=3878.3149, Expected=3875.0000
# Month=53, Predicted=3874.5794, Expected=3890.0000
# Month=54, Predicted=3890.2286, Expected=3910.0000
# Month=55, Predicted=3910.3585, Expected=3924.0000
# Month=56, Predicted=3924.1758, Expected=3918.0000
# Month=57, Predicted=3917.6774, Expected=3936.0000
# Month=58, Predicted=3936.3982, Expected=3911.0000
# Month=59, Predicted=3910.2257, Expected=3891.0000
# Month=60, Predicted=3890.5159, Expected=3855.0000
# Run 3 — RMSE: 24.438510, MSE: 597.240779, NMSE: 0.0027305473
#
# ===== RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3798.7372, Expected=3796.0000
# Month=2, Predicted=3795.8951, Expected=3793.0000
# Month=3, Predicted=3792.8896, Expected=3766.0000
# Month=4, Predicted=3765.3105, Expected=3747.0000
# Month=5, Predicted=3746.5084, Expected=3754.0000
# Month=6, Predicted=3754.1245, Expected=3756.0000
# Month=7, Predicted=3755.9880, Expected=3767.0000
# Month=8, Predicted=3767.2030, Expected=3751.0000
# Month=9, Predicted=3750.5555, Expected=3769.0000
# Month=10, Predicted=3769.3803, Expected=3760.0000
# Month=11, Predicted=3759.7237, Expected=3785.0000
# Month=12, Predicted=3785.5435, Expected=3776.0000
# Month=13, Predicted=3775.7234, Expected=3755.0000
# Month=14, Predicted=3754.4478, Expected=3755.0000
# Month=15, Predicted=3754.9581, Expected=3751.0000
# Month=16, Predicted=3750.8505, Expected=3776.0000
# Month=17, Predicted=3776.5388, Expected=3847.0000
# Month=18, Predicted=3848.5937, Expected=3830.0000
# Month=19, Predicted=3829.5228, Expected=3881.0000
# Month=20, Predicted=3882.1684, Expected=3899.0000
# Month=21, Predicted=3899.3751, Expected=3917.0000
# Month=22, Predicted=3917.3904, Expected=3913.0000
# Month=23, Predicted=3912.8692, Expected=3901.0000
# Month=24, Predicted=3900.6816, Expected=3886.0000
# Month=25, Predicted=3885.6062, Expected=3892.5000
# Month=26, Predicted=3892.6163, Expected=3899.0000
# Month=27, Predicted=3899.1014, Expected=3886.0000
# Month=28, Predicted=3885.6320, Expected=3908.0000
# Month=29, Predicted=3908.4747, Expected=3875.0000
# Month=30, Predicted=3874.1420, Expected=3860.0000
# Month=31, Predicted=3859.5983, Expected=3880.0000
# Month=32, Predicted=3880.4275, Expected=3895.0000
# Month=33, Predicted=3895.2902, Expected=3954.0000
# Month=34, Predicted=3955.3218, Expected=3933.0000
# Month=35, Predicted=3932.4288, Expected=3937.0000
# Month=36, Predicted=3937.0622, Expected=3869.0000
# Month=37, Predicted=3867.2985, Expected=3852.0000
# Month=38, Predicted=3851.5716, Expected=3837.0000
# Month=39, Predicted=3836.5928, Expected=3832.0000
# Month=40, Predicted=3831.8233, Expected=3849.0000
# Month=41, Predicted=3849.3408, Expected=3863.0000
# Month=42, Predicted=3863.2616, Expected=3878.0000
# Month=43, Predicted=3878.2920, Expected=3855.0000
# Month=44, Predicted=3854.3887, Expected=3843.0000
# Month=45, Predicted=3842.6705, Expected=3847.0000
# Month=46, Predicted=3847.0490, Expected=3801.0000
# Month=47, Predicted=3799.8276, Expected=3787.0000
# Month=48, Predicted=3786.6245, Expected=3776.0000
# Month=49, Predicted=3775.6818, Expected=3797.0000
# Month=50, Predicted=3797.4397, Expected=3821.0000
# Month=51, Predicted=3821.4964, Expected=3877.0000
# Month=52, Predicted=3878.2461, Expected=3875.0000
# Month=53, Predicted=3874.8866, Expected=3890.0000
# Month=54, Predicted=3890.3200, Expected=3910.0000
# Month=55, Predicted=3910.4343, Expected=3924.0000
# Month=56, Predicted=3924.2892, Expected=3918.0000
# Month=57, Predicted=3917.8147, Expected=3936.0000
# Month=58, Predicted=3936.3918, Expected=3911.0000
# Month=59, Predicted=3910.3498, Expected=3891.0000
# Month=60, Predicted=3890.4828, Expected=3855.0000
# Run 4 — RMSE: 24.425316, MSE: 596.596040, NMSE: 0.0027250599
#
# ===== RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3798.6857, Expected=3796.0000
# Month=2, Predicted=3795.7800, Expected=3793.0000
# Month=3, Predicted=3792.9081, Expected=3766.0000
# Month=4, Predicted=3765.3011, Expected=3747.0000
# Month=5, Predicted=3746.6180, Expected=3754.0000
# Month=6, Predicted=3754.2730, Expected=3756.0000
# Month=7, Predicted=3756.0262, Expected=3767.0000
# Month=8, Predicted=3767.2560, Expected=3751.0000
# Month=9, Predicted=3750.5164, Expected=3769.0000
# Month=10, Predicted=3769.4959, Expected=3760.0000
# Month=11, Predicted=3759.6927, Expected=3785.0000
# Month=12, Predicted=3785.6317, Expected=3776.0000
# Month=13, Predicted=3775.6601, Expected=3755.0000
# Month=14, Predicted=3754.4601, Expected=3755.0000
# Month=15, Predicted=3755.0875, Expected=3751.0000
# Month=16, Predicted=3750.9048, Expected=3776.0000
# Month=17, Predicted=3776.6194, Expected=3847.0000
# Month=18, Predicted=3848.5310, Expected=3830.0000
# Month=19, Predicted=3829.2268, Expected=3881.0000
# Month=20, Predicted=3882.2261, Expected=3899.0000
# Month=21, Predicted=3899.2817, Expected=3917.0000
# Month=22, Predicted=3917.3720, Expected=3913.0000
# Month=23, Predicted=3912.8235, Expected=3901.0000
# Month=24, Predicted=3900.7030, Expected=3886.0000
# Month=25, Predicted=3885.6673, Expected=3892.5000
# Month=26, Predicted=3892.7399, Expected=3899.0000
# Month=27, Predicted=3899.1476, Expected=3886.0000
# Month=28, Predicted=3885.6174, Expected=3908.0000
# Month=29, Predicted=3908.5803, Expected=3875.0000
# Month=30, Predicted=3874.0226, Expected=3860.0000
# Month=31, Predicted=3859.7210, Expected=3880.0000
# Month=32, Predicted=3880.5640, Expected=3895.0000
# Month=33, Predicted=3895.3037, Expected=3954.0000
# Month=34, Predicted=3955.2954, Expected=3933.0000
# Month=35, Predicted=3932.1742, Expected=3937.0000
# Month=36, Predicted=3937.1498, Expected=3869.0000
# Month=37, Predicted=3867.1266, Expected=3852.0000
# Month=38, Predicted=3851.8384, Expected=3837.0000
# Month=39, Predicted=3836.7163, Expected=3832.0000
# Month=40, Predicted=3831.9264, Expected=3849.0000
# Month=41, Predicted=3849.4274, Expected=3863.0000
# Month=42, Predicted=3863.2699, Expected=3878.0000
# Month=43, Predicted=3878.2988, Expected=3855.0000
# Month=44, Predicted=3854.3045, Expected=3843.0000
# Month=45, Predicted=3842.7656, Expected=3847.0000
# Month=46, Predicted=3847.1646, Expected=3801.0000
# Month=47, Predicted=3799.7402, Expected=3787.0000
# Month=48, Predicted=3786.8112, Expected=3776.0000
# Month=49, Predicted=3775.7864, Expected=3797.0000
# Month=50, Predicted=3797.5495, Expected=3821.0000
# Month=51, Predicted=3821.4959, Expected=3877.0000
# Month=52, Predicted=3878.1924, Expected=3875.0000
# Month=53, Predicted=3874.6915, Expected=3890.0000
# Month=54, Predicted=3890.3579, Expected=3910.0000
# Month=55, Predicted=3910.4587, Expected=3924.0000
# Month=56, Predicted=3924.2829, Expected=3918.0000
# Month=57, Predicted=3917.7813, Expected=3936.0000
# Month=58, Predicted=3936.4761, Expected=3911.0000
# Month=59, Predicted=3910.2690, Expected=3891.0000
# Month=60, Predicted=3890.5659, Expected=3855.0000
# Run 5 — RMSE: 24.436968, MSE: 597.165424, NMSE: 0.0027295118
#
# ===== RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3798.5664, Expected=3796.0000
# Month=2, Predicted=3795.6341, Expected=3793.0000
# Month=3, Predicted=3792.7679, Expected=3766.0000
# Month=4, Predicted=3765.2460, Expected=3747.0000
# Month=5, Predicted=3746.6083, Expected=3754.0000
# Month=6, Predicted=3754.2680, Expected=3756.0000
# Month=7, Predicted=3756.0190, Expected=3767.0000
# Month=8, Predicted=3767.2056, Expected=3751.0000
# Month=9, Predicted=3750.4861, Expected=3769.0000
# Month=10, Predicted=3769.4263, Expected=3760.0000
# Month=11, Predicted=3759.6463, Expected=3785.0000
# Month=12, Predicted=3785.5492, Expected=3776.0000
# Month=13, Predicted=3775.5898, Expected=3755.0000
# Month=14, Predicted=3754.4163, Expected=3755.0000
# Month=15, Predicted=3755.0491, Expected=3751.0000
# Month=16, Predicted=3750.8897, Expected=3776.0000
# Month=17, Predicted=3776.5721, Expected=3847.0000
# Month=18, Predicted=3848.4750, Expected=3830.0000
# Month=19, Predicted=3829.0904, Expected=3881.0000
# Month=20, Predicted=3882.0545, Expected=3899.0000
# Month=21, Predicted=3899.0766, Expected=3917.0000
# Month=22, Predicted=3917.1578, Expected=3913.0000
# Month=23, Predicted=3912.6498, Expected=3901.0000
# Month=24, Predicted=3900.5790, Expected=3886.0000
# Month=25, Predicted=3885.6042, Expected=3892.5000
# Month=26, Predicted=3892.6877, Expected=3899.0000
# Month=27, Predicted=3899.0983, Expected=3886.0000
# Month=28, Predicted=3885.5832, Expected=3908.0000
# Month=29, Predicted=3908.5125, Expected=3875.0000
# Month=30, Predicted=3874.0232, Expected=3860.0000
# Month=31, Predicted=3859.7096, Expected=3880.0000
# Month=32, Predicted=3880.5537, Expected=3895.0000
# Month=33, Predicted=3895.2524, Expected=3954.0000
# Month=34, Predicted=3955.2207, Expected=3933.0000
# Month=35, Predicted=3932.0589, Expected=3937.0000
# Month=36, Predicted=3936.9974, Expected=3869.0000
# Month=37, Predicted=3867.1946, Expected=3852.0000
# Month=38, Predicted=3851.8802, Expected=3837.0000
# Month=39, Predicted=3836.8322, Expected=3832.0000
# Month=40, Predicted=3832.0171, Expected=3849.0000
# Month=41, Predicted=3849.4583, Expected=3863.0000
# Month=42, Predicted=3863.2350, Expected=3878.0000
# Month=43, Predicted=3878.2101, Expected=3855.0000
# Month=44, Predicted=3854.2514, Expected=3843.0000
# Month=45, Predicted=3842.7179, Expected=3847.0000
# Month=46, Predicted=3847.1327, Expected=3801.0000
# Month=47, Predicted=3799.8210, Expected=3787.0000
# Month=48, Predicted=3786.8623, Expected=3776.0000
# Month=49, Predicted=3775.8711, Expected=3797.0000
# Month=50, Predicted=3797.5838, Expected=3821.0000
# Month=51, Predicted=3821.4632, Expected=3877.0000
# Month=52, Predicted=3878.1109, Expected=3875.0000
# Month=53, Predicted=3874.5364, Expected=3890.0000
# Month=54, Predicted=3890.1690, Expected=3910.0000
# Month=55, Predicted=3910.2851, Expected=3924.0000
# Month=56, Predicted=3924.1137, Expected=3918.0000
# Month=57, Predicted=3917.6433, Expected=3936.0000
# Month=58, Predicted=3936.3349, Expected=3911.0000
# Month=59, Predicted=3910.2056, Expected=3891.0000
# Month=60, Predicted=3890.5318, Expected=3855.0000
# Run 6 — RMSE: 24.434195, MSE: 597.029865, NMSE: 0.0027318465
#
# ===== RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3799.0611, Expected=3796.0000
# Month=2, Predicted=3796.2639, Expected=3793.0000
# Month=3, Predicted=3793.1109, Expected=3766.0000
# Month=4, Predicted=3765.4431, Expected=3747.0000
# Month=5, Predicted=3746.4667, Expected=3754.0000
# Month=6, Predicted=3754.0579, Expected=3756.0000
# Month=7, Predicted=3756.0309, Expected=3767.0000
# Month=8, Predicted=3767.2886, Expected=3751.0000
# Month=9, Predicted=3750.6832, Expected=3769.0000
# Month=10, Predicted=3769.4280, Expected=3760.0000
# Month=11, Predicted=3759.8683, Expected=3785.0000
# Month=12, Predicted=3785.6493, Expected=3776.0000
# Month=13, Predicted=3775.9302, Expected=3755.0000
# Month=14, Predicted=3754.5392, Expected=3755.0000
# Month=15, Predicted=3754.9394, Expected=3751.0000
# Month=16, Predicted=3750.8806, Expected=3776.0000
# Month=17, Predicted=3776.6112, Expected=3847.0000
# Month=18, Predicted=3848.9481, Expected=3830.0000
# Month=19, Predicted=3830.0361, Expected=3881.0000
# Month=20, Predicted=3882.4784, Expected=3899.0000
# Month=21, Predicted=3899.8403, Expected=3917.0000
# Month=22, Predicted=3917.7929, Expected=3913.0000
# Month=23, Predicted=3913.2129, Expected=3901.0000
# Month=24, Predicted=3900.8768, Expected=3886.0000
# Month=25, Predicted=3885.6816, Expected=3892.5000
# Month=26, Predicted=3892.6306, Expected=3899.0000
# Month=27, Predicted=3899.1915, Expected=3886.0000
# Month=28, Predicted=3885.7441, Expected=3908.0000
# Month=29, Predicted=3908.5380, Expected=3875.0000
# Month=30, Predicted=3874.3082, Expected=3860.0000
# Month=31, Predicted=3859.5387, Expected=3880.0000
# Month=32, Predicted=3880.3910, Expected=3895.0000
# Month=33, Predicted=3895.4231, Expected=3954.0000
# Month=34, Predicted=3955.6233, Expected=3933.0000
# Month=35, Predicted=3932.8706, Expected=3937.0000
# Month=36, Predicted=3937.2221, Expected=3869.0000
# Month=37, Predicted=3867.4688, Expected=3852.0000
# Month=38, Predicted=3851.2988, Expected=3837.0000
# Month=39, Predicted=3836.4056, Expected=3832.0000
# Month=40, Predicted=3831.6899, Expected=3849.0000
# Month=41, Predicted=3849.3079, Expected=3863.0000
# Month=42, Predicted=3863.3777, Expected=3878.0000
# Month=43, Predicted=3878.4766, Expected=3855.0000
# Month=44, Predicted=3854.5847, Expected=3843.0000
# Month=45, Predicted=3842.6829, Expected=3847.0000
# Month=46, Predicted=3847.0425, Expected=3801.0000
# Month=47, Predicted=3799.8805, Expected=3787.0000
# Month=48, Predicted=3786.4339, Expected=3776.0000
# Month=49, Predicted=3775.5492, Expected=3797.0000
# Month=50, Predicted=3797.3847, Expected=3821.0000
# Month=51, Predicted=3821.6349, Expected=3877.0000
# Month=52, Predicted=3878.5803, Expected=3875.0000
# Month=53, Predicted=3875.3455, Expected=3890.0000
# Month=54, Predicted=3890.6080, Expected=3910.0000
# Month=55, Predicted=3910.7308, Expected=3924.0000
# Month=56, Predicted=3924.6040, Expected=3918.0000
# Month=57, Predicted=3918.0885, Expected=3936.0000
# Month=58, Predicted=3936.5703, Expected=3911.0000
# Month=59, Predicted=3910.5635, Expected=3891.0000
# Month=60, Predicted=3890.4923, Expected=3855.0000
# Run 7 — RMSE: 24.415052, MSE: 596.094789, NMSE: 0.0027165919
#
# ===== RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3798.7652, Expected=3796.0000
# Month=2, Predicted=3795.8635, Expected=3793.0000
# Month=3, Predicted=3792.8458, Expected=3766.0000
# Month=4, Predicted=3765.2984, Expected=3747.0000
# Month=5, Predicted=3746.5088, Expected=3754.0000
# Month=6, Predicted=3754.1486, Expected=3756.0000
# Month=7, Predicted=3756.0164, Expected=3767.0000
# Month=8, Predicted=3767.2271, Expected=3751.0000
# Month=9, Predicted=3750.5707, Expected=3769.0000
# Month=10, Predicted=3769.3991, Expected=3760.0000
# Month=11, Predicted=3759.7317, Expected=3785.0000
# Month=12, Predicted=3785.5650, Expected=3776.0000
# Month=13, Predicted=3775.7216, Expected=3755.0000
# Month=14, Predicted=3754.4476, Expected=3755.0000
# Month=15, Predicted=3754.9624, Expected=3751.0000
# Month=16, Predicted=3750.8666, Expected=3776.0000
# Month=17, Predicted=3776.5774, Expected=3847.0000
# Month=18, Predicted=3848.7473, Expected=3830.0000
# Month=19, Predicted=3829.5105, Expected=3881.0000
# Month=20, Predicted=3882.1895, Expected=3899.0000
# Month=21, Predicted=3899.3311, Expected=3917.0000
# Month=22, Predicted=3917.3307, Expected=3913.0000
# Month=23, Predicted=3912.8045, Expected=3901.0000
# Month=24, Predicted=3900.6321, Expected=3886.0000
# Month=25, Predicted=3885.5825, Expected=3892.5000
# Month=26, Predicted=3892.6157, Expected=3899.0000
# Month=27, Predicted=3899.1119, Expected=3886.0000
# Month=28, Predicted=3885.6409, Expected=3908.0000
# Month=29, Predicted=3908.4983, Expected=3875.0000
# Month=30, Predicted=3874.1771, Expected=3860.0000
# Month=31, Predicted=3859.6104, Expected=3880.0000
# Month=32, Predicted=3880.4711, Expected=3895.0000
# Month=33, Predicted=3895.3225, Expected=3954.0000
# Month=34, Predicted=3955.4278, Expected=3933.0000
# Month=35, Predicted=3932.4227, Expected=3937.0000
# Month=36, Predicted=3937.0197, Expected=3869.0000
# Month=37, Predicted=3867.4023, Expected=3852.0000
# Month=38, Predicted=3851.5916, Expected=3837.0000
# Month=39, Predicted=3836.6507, Expected=3832.0000
# Month=40, Predicted=3831.8874, Expected=3849.0000
# Month=41, Predicted=3849.4115, Expected=3863.0000
# Month=42, Predicted=3863.3073, Expected=3878.0000
# Month=43, Predicted=3878.3113, Expected=3855.0000
# Month=44, Predicted=3854.3967, Expected=3843.0000
# Month=45, Predicted=3842.6671, Expected=3847.0000
# Month=46, Predicted=3847.0617, Expected=3801.0000
# Month=47, Predicted=3799.9007, Expected=3787.0000
# Month=48, Predicted=3786.6613, Expected=3776.0000
# Month=49, Predicted=3775.7370, Expected=3797.0000
# Month=50, Predicted=3797.5131, Expected=3821.0000
# Month=51, Predicted=3821.5541, Expected=3877.0000
# Month=52, Predicted=3878.3443, Expected=3875.0000
# Month=53, Predicted=3874.8609, Expected=3890.0000
# Month=54, Predicted=3890.2727, Expected=3910.0000
# Month=55, Predicted=3910.3976, Expected=3924.0000
# Month=56, Predicted=3924.2479, Expected=3918.0000
# Month=57, Predicted=3917.7694, Expected=3936.0000
# Month=58, Predicted=3936.3651, Expected=3911.0000
# Month=59, Predicted=3910.3408, Expected=3891.0000
# Month=60, Predicted=3890.4770, Expected=3855.0000
# Run 8 — RMSE: 24.420613, MSE: 596.366335, NMSE: 0.0027248882
#
# ===== RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3798.7272, Expected=3796.0000
# Month=2, Predicted=3795.9001, Expected=3793.0000
# Month=3, Predicted=3792.8938, Expected=3766.0000
# Month=4, Predicted=3765.3199, Expected=3747.0000
# Month=5, Predicted=3746.5364, Expected=3754.0000
# Month=6, Predicted=3754.1628, Expected=3756.0000
# Month=7, Predicted=3756.0243, Expected=3767.0000
# Month=8, Predicted=3767.2276, Expected=3751.0000
# Month=9, Predicted=3750.5761, Expected=3769.0000
# Month=10, Predicted=3769.3925, Expected=3760.0000
# Month=11, Predicted=3759.7447, Expected=3785.0000
# Month=12, Predicted=3785.5469, Expected=3776.0000
# Month=13, Predicted=3775.7399, Expected=3755.0000
# Month=14, Predicted=3754.4607, Expected=3755.0000
# Month=15, Predicted=3754.9845, Expected=3751.0000
# Month=16, Predicted=3750.8828, Expected=3776.0000
# Month=17, Predicted=3776.5522, Expected=3847.0000
# Month=18, Predicted=3848.5152, Expected=3830.0000
# Month=19, Predicted=3829.5154, Expected=3881.0000
# Month=20, Predicted=3882.0993, Expected=3899.0000
# Month=21, Predicted=3899.3674, Expected=3917.0000
# Month=22, Predicted=3917.3840, Expected=3913.0000
# Month=23, Predicted=3912.8793, Expected=3901.0000
# Month=24, Predicted=3900.6983, Expected=3886.0000
# Month=25, Predicted=3885.6340, Expected=3892.5000
# Month=26, Predicted=3892.6501, Expected=3899.0000
# Month=27, Predicted=3899.1343, Expected=3886.0000
# Month=28, Predicted=3885.6605, Expected=3908.0000
# Month=29, Predicted=3908.4884, Expected=3875.0000
# Month=30, Predicted=3874.1511, Expected=3860.0000
# Month=31, Predicted=3859.6222, Expected=3880.0000
# Month=32, Predicted=3880.4514, Expected=3895.0000
# Month=33, Predicted=3895.3112, Expected=3954.0000
# Month=34, Predicted=3955.2692, Expected=3933.0000
# Month=35, Predicted=3932.4226, Expected=3937.0000
# Month=36, Predicted=3937.0542, Expected=3869.0000
# Month=37, Predicted=3867.2477, Expected=3852.0000
# Month=38, Predicted=3851.6035, Expected=3837.0000
# Month=39, Predicted=3836.6481, Expected=3832.0000
# Month=40, Predicted=3831.8775, Expected=3849.0000
# Month=41, Predicted=3849.3754, Expected=3863.0000
# Month=42, Predicted=3863.2826, Expected=3878.0000
# Month=43, Predicted=3878.3009, Expected=3855.0000
# Month=44, Predicted=3854.3928, Expected=3843.0000
# Month=45, Predicted=3842.6854, Expected=3847.0000
# Month=46, Predicted=3847.0758, Expected=3801.0000
# Month=47, Predicted=3799.8304, Expected=3787.0000
# Month=48, Predicted=3786.6627, Expected=3776.0000
# Month=49, Predicted=3775.7303, Expected=3797.0000
# Month=50, Predicted=3797.4708, Expected=3821.0000
# Month=51, Predicted=3821.5094, Expected=3877.0000
# Month=52, Predicted=3878.1970, Expected=3875.0000
# Month=53, Predicted=3874.8835, Expected=3890.0000
# Month=54, Predicted=3890.3055, Expected=3910.0000
# Month=55, Predicted=3910.4292, Expected=3924.0000
# Month=56, Predicted=3924.2943, Expected=3918.0000
# Month=57, Predicted=3917.8288, Expected=3936.0000
# Month=58, Predicted=3936.3994, Expected=3911.0000
# Month=59, Predicted=3910.3658, Expected=3891.0000
# Month=60, Predicted=3890.5066, Expected=3855.0000
# Run 9 — RMSE: 24.420998, MSE: 596.385157, NMSE: 0.0027249254
#
# ===== RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3798.5959, Expected=3796.0000
# Month=2, Predicted=3795.5439, Expected=3793.0000
# Month=3, Predicted=3792.7011, Expected=3766.0000
# Month=4, Predicted=3765.1197, Expected=3747.0000
# Month=5, Predicted=3746.5759, Expected=3754.0000
# Month=6, Predicted=3754.3514, Expected=3756.0000
# Month=7, Predicted=3756.0678, Expected=3767.0000
# Month=8, Predicted=3767.2715, Expected=3751.0000
# Month=9, Predicted=3750.4303, Expected=3769.0000
# Month=10, Predicted=3769.4846, Expected=3760.0000
# Month=11, Predicted=3759.6101, Expected=3785.0000
# Month=12, Predicted=3785.5945, Expected=3776.0000
# Month=13, Predicted=3775.5323, Expected=3755.0000
# Month=14, Predicted=3754.3372, Expected=3755.0000
# Month=15, Predicted=3755.0839, Expected=3751.0000
# Month=16, Predicted=3750.9100, Expected=3776.0000
# Month=17, Predicted=3776.6369, Expected=3847.0000
# Month=18, Predicted=3848.4985, Expected=3830.0000
# Month=19, Predicted=3828.9015, Expected=3881.0000
# Month=20, Predicted=3882.0239, Expected=3899.0000
# Month=21, Predicted=3899.0439, Expected=3917.0000
# Month=22, Predicted=3917.1307, Expected=3913.0000
# Month=23, Predicted=3912.5486, Expected=3901.0000
# Month=24, Predicted=3900.4902, Expected=3886.0000
# Month=25, Predicted=3885.5499, Expected=3892.5000
# Month=26, Predicted=3892.7404, Expected=3899.0000
# Month=27, Predicted=3899.1432, Expected=3886.0000
# Month=28, Predicted=3885.5459, Expected=3908.0000
# Month=29, Predicted=3908.5702, Expected=3875.0000
# Month=30, Predicted=3873.8873, Expected=3860.0000
# Month=31, Predicted=3859.7031, Expected=3880.0000
# Month=32, Predicted=3880.6309, Expected=3895.0000
# Month=33, Predicted=3895.3283, Expected=3954.0000
# Month=34, Predicted=3955.2472, Expected=3933.0000
# Month=35, Predicted=3931.8741, Expected=3937.0000
# Month=36, Predicted=3936.9718, Expected=3869.0000
# Month=37, Predicted=3866.8985, Expected=3852.0000
# Month=38, Predicted=3851.9223, Expected=3837.0000
# Month=39, Predicted=3836.8939, Expected=3832.0000
# Month=40, Predicted=3832.1080, Expected=3849.0000
# Month=41, Predicted=3849.5694, Expected=3863.0000
# Month=42, Predicted=3863.3196, Expected=3878.0000
# Month=43, Predicted=3878.2621, Expected=3855.0000
# Month=44, Predicted=3854.1333, Expected=3843.0000
# Month=45, Predicted=3842.6903, Expected=3847.0000
# Month=46, Predicted=3847.1803, Expected=3801.0000
# Month=47, Predicted=3799.6723, Expected=3787.0000
# Month=48, Predicted=3786.9057, Expected=3776.0000
# Month=49, Predicted=3775.9268, Expected=3797.0000
# Month=50, Predicted=3797.6840, Expected=3821.0000
# Month=51, Predicted=3821.5436, Expected=3877.0000
# Month=52, Predicted=3878.1372, Expected=3875.0000
# Month=53, Predicted=3874.4257, Expected=3890.0000
# Month=54, Predicted=3890.1498, Expected=3910.0000
# Month=55, Predicted=3910.2921, Expected=3924.0000
# Month=56, Predicted=3924.0963, Expected=3918.0000
# Month=57, Predicted=3917.5548, Expected=3936.0000
# Month=58, Predicted=3936.3556, Expected=3911.0000
# Month=59, Predicted=3910.0686, Expected=3891.0000
# Month=60, Predicted=3890.4762, Expected=3855.0000
# Run 10 — RMSE: 24.422209, MSE: 596.444315, NMSE: 0.0027303336
#
# ===== RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3798.8372, Expected=3796.0000
# Month=2, Predicted=3796.0825, Expected=3793.0000
# Month=3, Predicted=3793.0171, Expected=3766.0000
# Month=4, Predicted=3765.3142, Expected=3747.0000
# Month=5, Predicted=3746.4987, Expected=3754.0000
# Month=6, Predicted=3754.1386, Expected=3756.0000
# Month=7, Predicted=3755.9621, Expected=3767.0000
# Month=8, Predicted=3767.2024, Expected=3751.0000
# Month=9, Predicted=3750.4907, Expected=3769.0000
# Month=10, Predicted=3769.3883, Expected=3760.0000
# Month=11, Predicted=3759.7194, Expected=3785.0000
# Month=12, Predicted=3785.5669, Expected=3776.0000
# Month=13, Predicted=3775.7725, Expected=3755.0000
# Month=14, Predicted=3754.4428, Expected=3755.0000
# Month=15, Predicted=3754.9816, Expected=3751.0000
# Month=16, Predicted=3750.8297, Expected=3776.0000
# Month=17, Predicted=3776.5283, Expected=3847.0000
# Month=18, Predicted=3848.5695, Expected=3830.0000
# Month=19, Predicted=3829.8146, Expected=3881.0000
# Month=20, Predicted=3882.3654, Expected=3899.0000
# Month=21, Predicted=3899.7527, Expected=3917.0000
# Month=22, Predicted=3917.6925, Expected=3913.0000
# Month=23, Predicted=3913.0907, Expected=3901.0000
# Month=24, Predicted=3900.7948, Expected=3886.0000
# Month=25, Predicted=3885.6463, Expected=3892.5000
# Month=26, Predicted=3892.6657, Expected=3899.0000
# Month=27, Predicted=3899.1167, Expected=3886.0000
# Month=28, Predicted=3885.5853, Expected=3908.0000
# Month=29, Predicted=3908.4785, Expected=3875.0000
# Month=30, Predicted=3874.0880, Expected=3860.0000
# Month=31, Predicted=3859.5915, Expected=3880.0000
# Month=32, Predicted=3880.4281, Expected=3895.0000
# Month=33, Predicted=3895.3358, Expected=3954.0000
# Month=34, Predicted=3955.3108, Expected=3933.0000
# Month=35, Predicted=3932.6348, Expected=3937.0000
# Month=36, Predicted=3937.2651, Expected=3869.0000
# Month=37, Predicted=3867.2063, Expected=3852.0000
# Month=38, Predicted=3851.5804, Expected=3837.0000
# Month=39, Predicted=3836.5235, Expected=3832.0000
# Month=40, Predicted=3831.7546, Expected=3849.0000
# Month=41, Predicted=3849.2971, Expected=3863.0000
# Month=42, Predicted=3863.2665, Expected=3878.0000
# Month=43, Predicted=3878.3223, Expected=3855.0000
# Month=44, Predicted=3854.3499, Expected=3843.0000
# Month=45, Predicted=3842.6653, Expected=3847.0000
# Month=46, Predicted=3847.0573, Expected=3801.0000
# Month=47, Predicted=3799.6752, Expected=3787.0000
# Month=48, Predicted=3786.5713, Expected=3776.0000
# Month=49, Predicted=3775.6008, Expected=3797.0000
# Month=50, Predicted=3797.3909, Expected=3821.0000
# Month=51, Predicted=3821.5061, Expected=3877.0000
# Month=52, Predicted=3878.2722, Expected=3875.0000
# Month=53, Predicted=3875.1595, Expected=3890.0000
# Month=54, Predicted=3890.5369, Expected=3910.0000
# Month=55, Predicted=3910.6021, Expected=3924.0000
# Month=56, Predicted=3924.4639, Expected=3918.0000
# Month=57, Predicted=3917.9217, Expected=3936.0000
# Month=58, Predicted=3936.4875, Expected=3911.0000
# Month=59, Predicted=3910.3631, Expected=3891.0000
# Month=60, Predicted=3890.4859, Expected=3855.0000
# Run 11 — RMSE: 24.419356, MSE: 596.304930, NMSE: 0.0027195955
#
# ===== RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3798.9011, Expected=3796.0000
# Month=2, Predicted=3796.0776, Expected=3793.0000
# Month=3, Predicted=3792.9545, Expected=3766.0000
# Month=4, Predicted=3765.3463, Expected=3747.0000
# Month=5, Predicted=3746.4343, Expected=3754.0000
# Month=6, Predicted=3754.0492, Expected=3756.0000
# Month=7, Predicted=3755.9992, Expected=3767.0000
# Month=8, Predicted=3767.2288, Expected=3751.0000
# Month=9, Predicted=3750.6129, Expected=3769.0000
# Month=10, Predicted=3769.3602, Expected=3760.0000
# Month=11, Predicted=3759.7875, Expected=3785.0000
# Month=12, Predicted=3785.5581, Expected=3776.0000
# Month=13, Predicted=3775.8231, Expected=3755.0000
# Month=14, Predicted=3754.4618, Expected=3755.0000
# Month=15, Predicted=3754.8964, Expected=3751.0000
# Month=16, Predicted=3750.8412, Expected=3776.0000
# Month=17, Predicted=3776.5502, Expected=3847.0000
# Month=18, Predicted=3848.7861, Expected=3830.0000
# Month=19, Predicted=3829.8234, Expected=3881.0000
# Month=20, Predicted=3882.2503, Expected=3899.0000
# Month=21, Predicted=3899.5950, Expected=3917.0000
# Month=22, Predicted=3917.5525, Expected=3913.0000
# Month=23, Predicted=3913.0121, Expected=3901.0000
# Month=24, Predicted=3900.7371, Expected=3886.0000
# Month=25, Predicted=3885.6023, Expected=3892.5000
# Month=26, Predicted=3892.5815, Expected=3899.0000
# Month=27, Predicted=3899.1315, Expected=3886.0000
# Month=28, Predicted=3885.6795, Expected=3908.0000
# Month=29, Predicted=3908.4698, Expected=3875.0000
# Month=30, Predicted=3874.2393, Expected=3860.0000
# Month=31, Predicted=3859.5133, Expected=3880.0000
# Month=32, Predicted=3880.3700, Expected=3895.0000
# Month=33, Predicted=3895.3522, Expected=3954.0000
# Month=34, Predicted=3955.4729, Expected=3933.0000
# Month=35, Predicted=3932.6837, Expected=3937.0000
# Month=36, Predicted=3937.0677, Expected=3869.0000
# Month=37, Predicted=3867.4016, Expected=3852.0000
# Month=38, Predicted=3851.3333, Expected=3837.0000
# Month=39, Predicted=3836.4621, Expected=3832.0000
# Month=40, Predicted=3831.7352, Expected=3849.0000
# Month=41, Predicted=3849.3124, Expected=3863.0000
# Month=42, Predicted=3863.3186, Expected=3878.0000
# Month=43, Predicted=3878.3701, Expected=3855.0000
# Month=44, Predicted=3854.4797, Expected=3843.0000
# Month=45, Predicted=3842.6211, Expected=3847.0000
# Month=46, Predicted=3847.0015, Expected=3801.0000
# Month=47, Predicted=3799.8621, Expected=3787.0000
# Month=48, Predicted=3786.4672, Expected=3776.0000
# Month=49, Predicted=3775.5881, Expected=3797.0000
# Month=50, Predicted=3797.3942, Expected=3821.0000
# Month=51, Predicted=3821.5692, Expected=3877.0000
# Month=52, Predicted=3878.4195, Expected=3875.0000
# Month=53, Predicted=3875.1320, Expected=3890.0000
# Month=54, Predicted=3890.4047, Expected=3910.0000
# Month=55, Predicted=3910.5405, Expected=3924.0000
# Month=56, Predicted=3924.4189, Expected=3918.0000
# Month=57, Predicted=3917.9289, Expected=3936.0000
# Month=58, Predicted=3936.4336, Expected=3911.0000
# Month=59, Predicted=3910.4557, Expected=3891.0000
# Month=60, Predicted=3890.4408, Expected=3855.0000
# Run 12 — RMSE: 24.413713, MSE: 596.029374, NMSE: 0.0027193305
#
# ===== RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3798.7834, Expected=3796.0000
# Month=2, Predicted=3795.7041, Expected=3793.0000
# Month=3, Predicted=3792.8575, Expected=3766.0000
# Month=4, Predicted=3765.2883, Expected=3747.0000
# Month=5, Predicted=3746.6876, Expected=3754.0000
# Month=6, Predicted=3754.4301, Expected=3756.0000
# Month=7, Predicted=3756.1500, Expected=3767.0000
# Month=8, Predicted=3767.3665, Expected=3751.0000
# Month=9, Predicted=3750.5589, Expected=3769.0000
# Month=10, Predicted=3769.6220, Expected=3760.0000
# Month=11, Predicted=3759.7327, Expected=3785.0000
# Month=12, Predicted=3785.7641, Expected=3776.0000
# Month=13, Predicted=3775.6673, Expected=3755.0000
# Month=14, Predicted=3754.4795, Expected=3755.0000
# Month=15, Predicted=3755.1826, Expected=3751.0000
# Month=16, Predicted=3751.0037, Expected=3776.0000
# Month=17, Predicted=3776.7921, Expected=3847.0000
# Month=18, Predicted=3848.8850, Expected=3830.0000
# Month=19, Predicted=3829.0972, Expected=3881.0000
# Month=20, Predicted=3882.3487, Expected=3899.0000
# Month=21, Predicted=3899.1886, Expected=3917.0000
# Month=22, Predicted=3917.2853, Expected=3913.0000
# Month=23, Predicted=3912.7192, Expected=3901.0000
# Month=24, Predicted=3900.6509, Expected=3886.0000
# Month=25, Predicted=3885.6836, Expected=3892.5000
# Month=26, Predicted=3892.8404, Expected=3899.0000
# Month=27, Predicted=3899.2413, Expected=3886.0000
# Month=28, Predicted=3885.6668, Expected=3908.0000
# Month=29, Predicted=3908.7238, Expected=3875.0000
# Month=30, Predicted=3874.0546, Expected=3860.0000
# Month=31, Predicted=3859.8048, Expected=3880.0000
# Month=32, Predicted=3880.7643, Expected=3895.0000
# Month=33, Predicted=3895.4186, Expected=3954.0000
# Month=34, Predicted=3955.5700, Expected=3933.0000
# Month=35, Predicted=3932.0720, Expected=3937.0000
# Month=36, Predicted=3937.1161, Expected=3869.0000
# Month=37, Predicted=3867.1811, Expected=3852.0000
# Month=38, Predicted=3851.9833, Expected=3837.0000
# Month=39, Predicted=3836.9289, Expected=3832.0000
# Month=40, Predicted=3832.1427, Expected=3849.0000
# Month=41, Predicted=3849.6558, Expected=3863.0000
# Month=42, Predicted=3863.4001, Expected=3878.0000
# Month=43, Predicted=3878.3694, Expected=3855.0000
# Month=44, Predicted=3854.2978, Expected=3843.0000
# Month=45, Predicted=3842.8126, Expected=3847.0000
# Month=46, Predicted=3847.2767, Expected=3801.0000
# Month=47, Predicted=3799.8389, Expected=3787.0000
# Month=48, Predicted=3786.9704, Expected=3776.0000
# Month=49, Predicted=3775.9775, Expected=3797.0000
# Month=50, Predicted=3797.7995, Expected=3821.0000
# Month=51, Predicted=3821.6650, Expected=3877.0000
# Month=52, Predicted=3878.4336, Expected=3875.0000
# Month=53, Predicted=3874.5864, Expected=3890.0000
# Month=54, Predicted=3890.3029, Expected=3910.0000
# Month=55, Predicted=3910.4409, Expected=3924.0000
# Month=56, Predicted=3924.2450, Expected=3918.0000
# Month=57, Predicted=3917.7201, Expected=3936.0000
# Month=58, Predicted=3936.5104, Expected=3911.0000
# Month=59, Predicted=3910.2464, Expected=3891.0000
# Month=60, Predicted=3890.6070, Expected=3855.0000
# Run 13 — RMSE: 24.426911, MSE: 596.673973, NMSE: 0.0027297037
#
# ===== RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3798.7687, Expected=3796.0000
# Month=2, Predicted=3795.8831, Expected=3793.0000
# Month=3, Predicted=3792.8367, Expected=3766.0000
# Month=4, Predicted=3765.2425, Expected=3747.0000
# Month=5, Predicted=3746.4605, Expected=3754.0000
# Month=6, Predicted=3754.1325, Expected=3756.0000
# Month=7, Predicted=3756.0277, Expected=3767.0000
# Month=8, Predicted=3767.2428, Expected=3751.0000
# Month=9, Predicted=3750.5728, Expected=3769.0000
# Month=10, Predicted=3769.3960, Expected=3760.0000
# Month=11, Predicted=3759.7435, Expected=3785.0000
# Month=12, Predicted=3785.5569, Expected=3776.0000
# Month=13, Predicted=3775.7344, Expected=3755.0000
# Month=14, Predicted=3754.4213, Expected=3755.0000
# Month=15, Predicted=3754.9518, Expected=3751.0000
# Month=16, Predicted=3750.8696, Expected=3776.0000
# Month=17, Predicted=3776.5726, Expected=3847.0000
# Month=18, Predicted=3848.6118, Expected=3830.0000
# Month=19, Predicted=3829.5195, Expected=3881.0000
# Month=20, Predicted=3882.0924, Expected=3899.0000
# Month=21, Predicted=3899.3282, Expected=3917.0000
# Month=22, Predicted=3917.3103, Expected=3913.0000
# Month=23, Predicted=3912.7778, Expected=3901.0000
# Month=24, Predicted=3900.5874, Expected=3886.0000
# Month=25, Predicted=3885.5348, Expected=3892.5000
# Month=26, Predicted=3892.5919, Expected=3899.0000
# Month=27, Predicted=3899.1124, Expected=3886.0000
# Month=28, Predicted=3885.6353, Expected=3908.0000
# Month=29, Predicted=3908.4864, Expected=3875.0000
# Month=30, Predicted=3874.1338, Expected=3860.0000
# Month=31, Predicted=3859.5809, Expected=3880.0000
# Month=32, Predicted=3880.4571, Expected=3895.0000
# Month=33, Predicted=3895.3451, Expected=3954.0000
# Month=34, Predicted=3955.3452, Expected=3933.0000
# Month=35, Predicted=3932.4220, Expected=3937.0000
# Month=36, Predicted=3937.0032, Expected=3869.0000
# Month=37, Predicted=3867.1706, Expected=3852.0000
# Month=38, Predicted=3851.5133, Expected=3837.0000
# Month=39, Predicted=3836.6144, Expected=3832.0000
# Month=40, Predicted=3831.8837, Expected=3849.0000
# Month=41, Predicted=3849.4235, Expected=3863.0000
# Month=42, Predicted=3863.3422, Expected=3878.0000
# Month=43, Predicted=3878.3428, Expected=3855.0000
# Month=44, Predicted=3854.3874, Expected=3843.0000
# Month=45, Predicted=3842.6508, Expected=3847.0000
# Month=46, Predicted=3847.0599, Expected=3801.0000
# Month=47, Predicted=3799.8064, Expected=3787.0000
# Month=48, Predicted=3786.6269, Expected=3776.0000
# Month=49, Predicted=3775.7280, Expected=3797.0000
# Month=50, Predicted=3797.5155, Expected=3821.0000
# Month=51, Predicted=3821.5807, Expected=3877.0000
# Month=52, Predicted=3878.2890, Expected=3875.0000
# Month=53, Predicted=3874.8951, Expected=3890.0000
# Month=54, Predicted=3890.2662, Expected=3910.0000
# Month=55, Predicted=3910.3850, Expected=3924.0000
# Month=56, Predicted=3924.2418, Expected=3918.0000
# Month=57, Predicted=3917.7543, Expected=3936.0000
# Month=58, Predicted=3936.3407, Expected=3911.0000
# Month=59, Predicted=3910.2967, Expected=3891.0000
# Month=60, Predicted=3890.4272, Expected=3855.0000
# Run 14 — RMSE: 24.408315, MSE: 595.765844, NMSE: 0.0027227305
#
# ===== RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3798.6460, Expected=3796.0000
# Month=2, Predicted=3795.6497, Expected=3793.0000
# Month=3, Predicted=3792.7235, Expected=3766.0000
# Month=4, Predicted=3765.2189, Expected=3747.0000
# Month=5, Predicted=3746.5438, Expected=3754.0000
# Month=6, Predicted=3754.2489, Expected=3756.0000
# Month=7, Predicted=3756.0614, Expected=3767.0000
# Month=8, Predicted=3767.2662, Expected=3751.0000
# Month=9, Predicted=3750.5461, Expected=3769.0000
# Month=10, Predicted=3769.4396, Expected=3760.0000
# Month=11, Predicted=3759.6781, Expected=3785.0000
# Month=12, Predicted=3785.5740, Expected=3776.0000
# Month=13, Predicted=3775.6156, Expected=3755.0000
# Month=14, Predicted=3754.4015, Expected=3755.0000
# Month=15, Predicted=3755.0113, Expected=3751.0000
# Month=16, Predicted=3750.9155, Expected=3776.0000
# Month=17, Predicted=3776.6344, Expected=3847.0000
# Month=18, Predicted=3848.6786, Expected=3830.0000
# Month=19, Predicted=3829.1163, Expected=3881.0000
# Month=20, Predicted=3882.0281, Expected=3899.0000
# Month=21, Predicted=3899.0322, Expected=3917.0000
# Month=22, Predicted=3917.1252, Expected=3913.0000
# Month=23, Predicted=3912.6263, Expected=3901.0000
# Month=24, Predicted=3900.5275, Expected=3886.0000
# Month=25, Predicted=3885.5548, Expected=3892.5000
# Month=26, Predicted=3892.6611, Expected=3899.0000
# Month=27, Predicted=3899.1332, Expected=3886.0000
# Month=28, Predicted=3885.6343, Expected=3908.0000
# Month=29, Predicted=3908.5415, Expected=3875.0000
# Month=30, Predicted=3874.0782, Expected=3860.0000
# Month=31, Predicted=3859.6539, Expected=3880.0000
# Month=32, Predicted=3880.5667, Expected=3895.0000
# Month=33, Predicted=3895.3051, Expected=3954.0000
# Month=34, Predicted=3955.3776, Expected=3933.0000
# Month=35, Predicted=3932.0928, Expected=3937.0000
# Month=36, Predicted=3936.9003, Expected=3869.0000
# Month=37, Predicted=3867.2584, Expected=3852.0000
# Month=38, Predicted=3851.7339, Expected=3837.0000
# Month=39, Predicted=3836.8239, Expected=3832.0000
# Month=40, Predicted=3832.0588, Expected=3849.0000
# Month=41, Predicted=3849.5508, Expected=3863.0000
# Month=42, Predicted=3863.3259, Expected=3878.0000
# Month=43, Predicted=3878.2845, Expected=3855.0000
# Month=44, Predicted=3854.3065, Expected=3843.0000
# Month=45, Predicted=3842.6773, Expected=3847.0000
# Month=46, Predicted=3847.1223, Expected=3801.0000
# Month=47, Predicted=3799.8949, Expected=3787.0000
# Month=48, Predicted=3786.8036, Expected=3776.0000
# Month=49, Predicted=3775.8902, Expected=3797.0000
# Month=50, Predicted=3797.6576, Expected=3821.0000
# Month=51, Predicted=3821.5577, Expected=3877.0000
# Month=52, Predicted=3878.2630, Expected=3875.0000
# Month=53, Predicted=3874.5548, Expected=3890.0000
# Month=54, Predicted=3890.1117, Expected=3910.0000
# Month=55, Predicted=3910.2772, Expected=3924.0000
# Month=56, Predicted=3924.1206, Expected=3918.0000
# Month=57, Predicted=3917.6463, Expected=3936.0000
# Month=58, Predicted=3936.3184, Expected=3911.0000
# Month=59, Predicted=3910.2228, Expected=3891.0000
# Month=60, Predicted=3890.4757, Expected=3855.0000
# Run 15 — RMSE: 24.421847, MSE: 596.426624, NMSE: 0.0027293202
#
# ===== RUN 16/30 =====
# Training complete for run 16
# Month=1, Predicted=3798.7493, Expected=3796.0000
# Month=2, Predicted=3795.8136, Expected=3793.0000
# Month=3, Predicted=3792.8641, Expected=3766.0000
# Month=4, Predicted=3765.2442, Expected=3747.0000
# Month=5, Predicted=3746.5409, Expected=3754.0000
# Month=6, Predicted=3754.2840, Expected=3756.0000
# Month=7, Predicted=3756.0725, Expected=3767.0000
# Month=8, Predicted=3767.3160, Expected=3751.0000
# Month=9, Predicted=3750.5248, Expected=3769.0000
# Month=10, Predicted=3769.5014, Expected=3760.0000
# Month=11, Predicted=3759.7100, Expected=3785.0000
# Month=12, Predicted=3785.6395, Expected=3776.0000
# Month=13, Predicted=3775.6809, Expected=3755.0000
# Month=14, Predicted=3754.4141, Expected=3755.0000
# Month=15, Predicted=3755.0557, Expected=3751.0000
# Month=16, Predicted=3750.9113, Expected=3776.0000
# Month=17, Predicted=3776.6527, Expected=3847.0000
# Month=18, Predicted=3848.6331, Expected=3830.0000
# Month=19, Predicted=3829.3136, Expected=3881.0000
# Month=20, Predicted=3882.1789, Expected=3899.0000
# Month=21, Predicted=3899.3270, Expected=3917.0000
# Month=22, Predicted=3917.3667, Expected=3913.0000
# Month=23, Predicted=3912.7917, Expected=3901.0000
# Month=24, Predicted=3900.6319, Expected=3886.0000
# Month=25, Predicted=3885.5986, Expected=3892.5000
# Month=26, Predicted=3892.7326, Expected=3899.0000
# Month=27, Predicted=3899.1855, Expected=3886.0000
# Month=28, Predicted=3885.6178, Expected=3908.0000
# ...
# Month=53, Predicted=3875.2780, Expected=3890.0000
# Month=54, Predicted=3890.5416, Expected=3910.0000
# Month=55, Predicted=3910.6309, Expected=3924.0000
# Month=56, Predicted=3924.5288, Expected=3918.0000
# Month=57, Predicted=3918.0970, Expected=3936.0000
# Month=58, Predicted=3936.5399, Expected=3911.0000
# Month=59, Predicted=3910.5975, Expected=3891.0000
# Month=60, Predicted=3890.6354, Expected=3855.0000
# Run 25 — RMSE: 24.403145, MSE: 595.513504, NMSE: 0.0027200202
#
# ===== RUN 26/30 =====
# Training complete for run 26
# Month=1, Predicted=3798.8356, Expected=3796.0000
# Month=2, Predicted=3795.9664, Expected=3793.0000
# Month=3, Predicted=3792.8852, Expected=3766.0000
# Month=4, Predicted=3765.2855, Expected=3747.0000
# Month=5, Predicted=3746.4392, Expected=3754.0000
# Month=6, Predicted=3754.0911, Expected=3756.0000
# Month=7, Predicted=3756.0061, Expected=3767.0000
# Month=8, Predicted=3767.2267, Expected=3751.0000
# Month=9, Predicted=3750.5752, Expected=3769.0000
# Month=10, Predicted=3769.3731, Expected=3760.0000
# Month=11, Predicted=3759.7518, Expected=3785.0000
# Month=12, Predicted=3785.5573, Expected=3776.0000
# Month=13, Predicted=3775.7658, Expected=3755.0000
# Month=14, Predicted=3754.4266, Expected=3755.0000
# Month=15, Predicted=3754.9164, Expected=3751.0000
# Month=16, Predicted=3750.8463, Expected=3776.0000
# Month=17, Predicted=3776.5628, Expected=3847.0000
# Month=18, Predicted=3848.7378, Expected=3830.0000
# Month=19, Predicted=3829.6605, Expected=3881.0000
# Month=20, Predicted=3882.1950, Expected=3899.0000
# Month=21, Predicted=3899.4667, Expected=3917.0000
# Month=22, Predicted=3917.4362, Expected=3913.0000
# Month=23, Predicted=3912.8942, Expected=3901.0000
# Month=24, Predicted=3900.6599, Expected=3886.0000
# Month=25, Predicted=3885.5648, Expected=3892.5000
# Month=26, Predicted=3892.5876, Expected=3899.0000
# Month=27, Predicted=3899.1181, Expected=3886.0000
# Month=28, Predicted=3885.6435, Expected=3908.0000
# Month=29, Predicted=3908.4770, Expected=3875.0000
# Month=30, Predicted=3874.1734, Expected=3860.0000
# Month=31, Predicted=3859.5327, Expected=3880.0000
# Month=32, Predicted=3880.4174, Expected=3895.0000
# Month=33, Predicted=3895.3441, Expected=3954.0000
# Month=34, Predicted=3955.4315, Expected=3933.0000
# Month=35, Predicted=3932.5408, Expected=3937.0000
# Month=36, Predicted=3937.0291, Expected=3869.0000
# Month=37, Predicted=3867.2930, Expected=3852.0000
# Month=38, Predicted=3851.4215, Expected=3837.0000
# Month=39, Predicted=3836.5387, Expected=3832.0000
# Month=40, Predicted=3831.8035, Expected=3849.0000
# Month=41, Predicted=3849.3643, Expected=3863.0000
# Month=42, Predicted=3863.3184, Expected=3878.0000
# Month=43, Predicted=3878.3425, Expected=3855.0000
# Month=44, Predicted=3854.4146, Expected=3843.0000
# Month=45, Predicted=3842.6211, Expected=3847.0000
# Month=46, Predicted=3847.0249, Expected=3801.0000
# Month=47, Predicted=3799.8235, Expected=3787.0000
# Month=48, Predicted=3786.5345, Expected=3776.0000
# Month=49, Predicted=3775.6480, Expected=3797.0000
# Month=50, Predicted=3797.4550, Expected=3821.0000
# Month=51, Predicted=3821.5694, Expected=3877.0000
# Month=52, Predicted=3878.3674, Expected=3875.0000
# Month=53, Predicted=3874.9979, Expected=3890.0000
# Month=54, Predicted=3890.3303, Expected=3910.0000
# Month=55, Predicted=3910.4658, Expected=3924.0000
# Month=56, Predicted=3924.3309, Expected=3918.0000
# Month=57, Predicted=3917.8358, Expected=3936.0000
# Month=58, Predicted=3936.3905, Expected=3911.0000
# Month=59, Predicted=3910.3689, Expected=3891.0000
# Month=60, Predicted=3890.4241, Expected=3855.0000
# Run 26 — RMSE: 24.411878, MSE: 595.939797, NMSE: 0.0027209178
#
# ===== RUN 27/30 =====
# Training complete for run 27
# Month=1, Predicted=3799.0280, Expected=3796.0000
# Month=2, Predicted=3796.1626, Expected=3793.0000
# Month=3, Predicted=3792.9951, Expected=3766.0000
# Month=4, Predicted=3765.3195, Expected=3747.0000
# Month=5, Predicted=3746.3601, Expected=3754.0000
# Month=6, Predicted=3753.9967, Expected=3756.0000
# Month=7, Predicted=3755.9751, Expected=3767.0000
# Month=8, Predicted=3767.2349, Expected=3751.0000
# Month=9, Predicted=3750.5959, Expected=3769.0000
# Month=10, Predicted=3769.3686, Expected=3760.0000
# Month=11, Predicted=3759.7867, Expected=3785.0000
# Month=12, Predicted=3785.5980, Expected=3776.0000
# Month=13, Predicted=3775.8433, Expected=3755.0000
# Month=14, Predicted=3754.4300, Expected=3755.0000
# Month=15, Predicted=3754.8562, Expected=3751.0000
# Month=16, Predicted=3750.8078, Expected=3776.0000
# Month=17, Predicted=3776.5738, Expected=3847.0000
# Month=18, Predicted=3848.9897, Expected=3830.0000
# Month=19, Predicted=3829.9262, Expected=3881.0000
# Month=20, Predicted=3882.4194, Expected=3899.0000
# Month=21, Predicted=3899.7442, Expected=3917.0000
# Month=22, Predicted=3917.6843, Expected=3913.0000
# Month=23, Predicted=3913.0853, Expected=3901.0000
# Month=24, Predicted=3900.7510, Expected=3886.0000
# Month=25, Predicted=3885.5705, Expected=3892.5000
# Month=26, Predicted=3892.5574, Expected=3899.0000
# Month=27, Predicted=3899.1304, Expected=3886.0000
# Month=28, Predicted=3885.6589, Expected=3908.0000
# Month=29, Predicted=3908.4867, Expected=3875.0000
# Month=30, Predicted=3874.2096, Expected=3860.0000
# Month=31, Predicted=3859.4382, Expected=3880.0000
# Month=32, Predicted=3880.3471, Expected=3895.0000
# Month=33, Predicted=3895.3802, Expected=3954.0000
# Month=34, Predicted=3955.6346, Expected=3933.0000
# Month=35, Predicted=3932.7595, Expected=3937.0000
# Month=36, Predicted=3937.1044, Expected=3869.0000
# Month=37, Predicted=3867.9917, Expected=3852.0000
# Month=38, Predicted=3851.2915, Expected=3837.0000
# Month=39, Predicted=3836.3795, Expected=3832.0000
# Month=40, Predicted=3831.6555, Expected=3849.0000
# Month=41, Predicted=3849.2879, Expected=3863.0000
# Month=42, Predicted=3863.3415, Expected=3878.0000
# Month=43, Predicted=3878.4208, Expected=3855.0000
# Month=44, Predicted=3854.4785, Expected=3843.0000
# Month=45, Predicted=3842.5778, Expected=3847.0000
# Month=46, Predicted=3846.9698, Expected=3801.0000
# Month=47, Predicted=3799.7797, Expected=3787.0000
# Month=48, Predicted=3786.3449, Expected=3776.0000
# Month=49, Predicted=3775.4840, Expected=3797.0000
# Month=50, Predicted=3797.3600, Expected=3821.0000
# Month=51, Predicted=3821.6116, Expected=3877.0000
# Month=52, Predicted=3878.5874, Expected=3875.0000
# Month=53, Predicted=3875.2457, Expected=3890.0000
# Month=54, Predicted=3890.5004, Expected=3910.0000
# Month=55, Predicted=3910.6424, Expected=3924.0000
# Month=56, Predicted=3924.5134, Expected=3918.0000
# Month=57, Predicted=3917.9765, Expected=3936.0000
# Month=58, Predicted=3936.4895, Expected=3911.0000
# Month=59, Predicted=3910.4520, Expected=3891.0000
# Month=60, Predicted=3890.3811, Expected=3855.0000
# Run 27 — RMSE: 24.418528, MSE: 596.264528, NMSE: 0.0027171777
#
# ===== RUN 28/30 =====
# Training complete for run 28
# Month=1, Predicted=3798.8899, Expected=3796.0000
# Month=2, Predicted=3795.9751, Expected=3793.0000
# Month=3, Predicted=3792.8774, Expected=3766.0000
# Month=4, Predicted=3765.2735, Expected=3747.0000
# Month=5, Predicted=3746.3926, Expected=3754.0000
# Month=6, Predicted=3754.0280, Expected=3756.0000
# Month=7, Predicted=3755.9569, Expected=3767.0000
# Month=8, Predicted=3767.1968, Expected=3751.0000
# Month=9, Predicted=3750.5498, Expected=3769.0000
# Month=10, Predicted=3769.3523, Expected=3760.0000
# Month=11, Predicted=3759.7236, Expected=3785.0000
# Month=12, Predicted=3785.5574, Expected=3776.0000
# Month=13, Predicted=3775.7470, Expected=3755.0000
# Month=14, Predicted=3754.4051, Expected=3755.0000
# Month=15, Predicted=3754.8669, Expected=3751.0000
# Month=16, Predicted=3750.7972, Expected=3776.0000
# Month=17, Predicted=3776.5506, Expected=3847.0000
# Month=18, Predicted=3848.9386, Expected=3830.0000
# Month=19, Predicted=3829.6880, Expected=3881.0000
# Month=20, Predicted=3882.3244, Expected=3899.0000
# Month=21, Predicted=3899.5077, Expected=3917.0000
# Month=22, Predicted=3917.4706, Expected=3913.0000
# Month=23, Predicted=3912.8938, Expected=3901.0000
# Month=24, Predicted=3900.6409, Expected=3886.0000
# Month=25, Predicted=3885.5283, Expected=3892.5000
# Month=26, Predicted=3892.5393, Expected=3899.0000
# Month=27, Predicted=3899.0797, Expected=3886.0000
# Month=28, Predicted=3885.6110, Expected=3908.0000
# Month=29, Predicted=3908.4621, Expected=3875.0000
# Month=30, Predicted=3874.1725, Expected=3860.0000
# Month=31, Predicted=3859.4863, Expected=3880.0000
# Month=32, Predicted=3880.3762, Expected=3895.0000
# Month=33, Predicted=3895.3233, Expected=3954.0000
# Month=34, Predicted=3955.5705, Expected=3933.0000
# Month=35, Predicted=3932.5623, Expected=3937.0000
# Month=36, Predicted=3937.0248, Expected=3869.0000
# Month=37, Predicted=3867.4017, Expected=3852.0000
# Month=38, Predicted=3851.3467, Expected=3837.0000
# Month=39, Predicted=3836.4516, Expected=3832.0000
# Month=40, Predicted=3831.7207, Expected=3849.0000
# Month=41, Predicted=3849.3148, Expected=3863.0000
# Month=42, Predicted=3863.2969, Expected=3878.0000
# Month=43, Predicted=3878.3399, Expected=3855.0000
# Month=44, Predicted=3854.4096, Expected=3843.0000
# Month=45, Predicted=3842.5848, Expected=3847.0000
# Month=46, Predicted=3846.9757, Expected=3801.0000
# Month=47, Predicted=3799.8373, Expected=3787.0000
# Month=48, Predicted=3786.4629, Expected=3776.0000
# Month=49, Predicted=3775.5711, Expected=3797.0000
# Month=50, Predicted=3797.4070, Expected=3821.0000
# Month=51, Predicted=3821.5656, Expected=3877.0000
# Month=52, Predicted=3878.5024, Expected=3875.0000
# Month=53, Predicted=3875.0206, Expected=3890.0000
# Month=54, Predicted=3890.3536, Expected=3910.0000
# Month=55, Predicted=3910.4874, Expected=3924.0000
# Month=56, Predicted=3924.3416, Expected=3918.0000
# Month=57, Predicted=3917.8256, Expected=3936.0000
# Month=58, Predicted=3936.3886, Expected=3911.0000
# Month=59, Predicted=3910.3590, Expected=3891.0000
# Month=60, Predicted=3890.3881, Expected=3855.0000
# Run 28 — RMSE: 24.417938, MSE: 596.235710, NMSE: 0.0027205489
#
# ===== RUN 29/30 =====
# Training complete for run 29
# Month=1, Predicted=3798.6862, Expected=3796.0000
# Month=2, Predicted=3795.7440, Expected=3793.0000
# Month=3, Predicted=3792.7900, Expected=3766.0000
# Month=4, Predicted=3765.2681, Expected=3747.0000
# Month=5, Predicted=3746.5715, Expected=3754.0000
# Month=6, Predicted=3754.2492, Expected=3756.0000
# Month=7, Predicted=3756.0560, Expected=3767.0000
# Month=8, Predicted=3767.2497, Expected=3751.0000
# Month=9, Predicted=3750.5510, Expected=3769.0000
# Month=10, Predicted=3769.4400, Expected=3760.0000
# Month=11, Predicted=3759.7052, Expected=3785.0000
# Month=12, Predicted=3785.5808, Expected=3776.0000
# Month=13, Predicted=3775.6631, Expected=3755.0000
# Month=14, Predicted=3754.4378, Expected=3755.0000
# Month=15, Predicted=3755.0257, Expected=3751.0000
# Month=16, Predicted=3750.9075, Expected=3776.0000
# Month=17, Predicted=3776.6156, Expected=3847.0000
# Month=18, Predicted=3848.6777, Expected=3830.0000
# Month=19, Predicted=3829.2971, Expected=3881.0000
# Month=20, Predicted=3882.1100, Expected=3899.0000
# Month=21, Predicted=3899.1836, Expected=3917.0000
# Month=22, Predicted=3917.2244, Expected=3913.0000
# Month=23, Predicted=3912.7091, Expected=3901.0000
# Month=24, Predicted=3900.5887, Expected=3886.0000
# Month=25, Predicted=3885.5907, Expected=3892.5000
# Month=26, Predicted=3892.6690, Expected=3899.0000
# Month=27, Predicted=3899.1277, Expected=3886.0000
# Month=28, Predicted=3885.6314, Expected=3908.0000
# Month=29, Predicted=3908.5344, Expected=3875.0000
# Month=30, Predicted=3874.1194, Expected=3860.0000
# Month=31, Predicted=3859.6782, Expected=3880.0000
# Month=32, Predicted=3880.5611, Expected=3895.0000
# Month=33, Predicted=3895.3189, Expected=3954.0000
# Month=34, Predicted=3955.3756, Expected=3933.0000
# Month=35, Predicted=3932.2395, Expected=3937.0000
# Month=36, Predicted=3936.9771, Expected=3869.0000
# Month=37, Predicted=3867.3152, Expected=3852.0000
# Month=38, Predicted=3851.7619, Expected=3837.0000
# Month=39, Predicted=3836.8158, Expected=3832.0000
# Month=40, Predicted=3832.0381, Expected=3849.0000
# Month=41, Predicted=3849.5166, Expected=3863.0000
# Month=42, Predicted=3863.3205, Expected=3878.0000
# Month=43, Predicted=3878.2883, Expected=3855.0000
# Month=44, Predicted=3854.3377, Expected=3843.0000
# Month=45, Predicted=3842.7032, Expected=3847.0000
# Month=46, Predicted=3847.1260, Expected=3801.0000
# Month=47, Predicted=3799.9027, Expected=3787.0000
# Month=48, Predicted=3786.8154, Expected=3776.0000
# Month=49, Predicted=3775.8785, Expected=3797.0000
# Month=50, Predicted=3797.6316, Expected=3821.0000
# Month=51, Predicted=3821.5607, Expected=3877.0000
# Month=52, Predicted=3878.2789, Expected=3875.0000
# Month=53, Predicted=3874.6971, Expected=3890.0000
# Month=54, Predicted=3890.1986, Expected=3910.0000
# Month=55, Predicted=3910.3308, Expected=3924.0000
# Month=56, Predicted=3924.1720, Expected=3918.0000
# Month=57, Predicted=3917.6961, Expected=3936.0000
# Month=58, Predicted=3936.3459, Expected=3911.0000
# Month=59, Predicted=3910.2733, Expected=3891.0000
# Month=60, Predicted=3890.5076, Expected=3855.0000
# Run 29 — RMSE: 24.420264, MSE: 596.349283, NMSE: 0.0027276747
#
# ===== RUN 30/30 =====
# Training complete for run 30
# Month=1, Predicted=3799.1973, Expected=3796.0000
# Month=2, Predicted=3796.3807, Expected=3793.0000
# Month=3, Predicted=3793.0409, Expected=3766.0000
# Month=4, Predicted=3765.3055, Expected=3747.0000
# Month=5, Predicted=3746.2083, Expected=3754.0000
# Month=6, Predicted=3753.8382, Expected=3756.0000
# Month=7, Predicted=3755.9515, Expected=3767.0000
# Month=8, Predicted=3767.2366, Expected=3751.0000
# Month=9, Predicted=3750.6539, Expected=3769.0000
# Month=10, Predicted=3769.3036, Expected=3760.0000
# Month=11, Predicted=3759.8489, Expected=3785.0000
# Month=12, Predicted=3785.5690, Expected=3776.0000
# Month=13, Predicted=3775.9499, Expected=3755.0000
# Month=14, Predicted=3754.4196, Expected=3755.0000
# Month=15, Predicted=3754.7373, Expected=3751.0000
# Month=16, Predicted=3750.7607, Expected=3776.0000
# Month=17, Predicted=3776.5348, Expected=3847.0000
# Month=18, Predicted=3849.1222, Expected=3830.0000
# Month=19, Predicted=3830.3188, Expected=3881.0000
# Month=20, Predicted=3882.4604, Expected=3899.0000
# Month=21, Predicted=3899.9804, Expected=3917.0000
# Month=22, Predicted=3917.8256, Expected=3913.0000
# Month=23, Predicted=3913.1871, Expected=3901.0000
# Month=24, Predicted=3900.7323, Expected=3886.0000
# Month=25, Predicted=3885.4776, Expected=3892.5000
# Month=26, Predicted=3892.4281, Expected=3899.0000
# Month=27, Predicted=3899.1034, Expected=3886.0000
# Month=28, Predicted=3885.6771, Expected=3908.0000
# Month=29, Predicted=3908.4201, Expected=3875.0000
# Month=30, Predicted=3874.2997, Expected=3860.0000
# Month=31, Predicted=3859.3033, Expected=3880.0000
# Month=32, Predicted=3880.2202, Expected=3895.0000
# Month=33, Predicted=3895.4341, Expected=3954.0000
# Month=34, Predicted=3955.7446, Expected=3933.0000
# Month=35, Predicted=3933.0867, Expected=3937.0000
# Month=36, Predicted=3937.0940, Expected=3869.0000
# Month=37, Predicted=3867.3689, Expected=3852.0000
# Month=38, Predicted=3850.8513, Expected=3837.0000
# Month=39, Predicted=3836.1388, Expected=3832.0000
# Month=40, Predicted=3831.5075, Expected=3849.0000
# Month=41, Predicted=3849.2238, Expected=3863.0000
# Month=42, Predicted=3863.4155, Expected=3878.0000
# Month=43, Predicted=3878.5234, Expected=3855.0000
# Month=44, Predicted=3854.5946, Expected=3843.0000
# Month=45, Predicted=3842.4985, Expected=3847.0000
# Month=46, Predicted=3846.8741, Expected=3801.0000
# Month=47, Predicted=3799.7860, Expected=3787.0000
# Month=48, Predicted=3786.1235, Expected=3776.0000
# Month=49, Predicted=3775.3474, Expected=3797.0000
# Month=50, Predicted=3797.2687, Expected=3821.0000
# Month=51, Predicted=3821.6956, Expected=3877.0000
# Month=52, Predicted=3878.7584, Expected=3875.0000
# Month=53, Predicted=3875.5796, Expected=3890.0000
# Month=54, Predicted=3890.5884, Expected=3910.0000
# Month=55, Predicted=3910.7196, Expected=3924.0000
# Month=56, Predicted=3924.6106, Expected=3918.0000
# Month=57, Predicted=3918.0521, Expected=3936.0000
# Month=58, Predicted=3936.4565, Expected=3911.0000
# Month=59, Predicted=3910.5116, Expected=3891.0000
# Month=60, Predicted=3890.2639, Expected=3855.0000
# Run 30 — RMSE: 24.390693, MSE: 594.905908, NMSE: 0.0027080299

# %%
# ============================================================
# Summary Statistics (matching reference calculate.py)
# ============================================================

print('\n===== FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(all_rmse):.10f} ± {np.var(all_rmse):.15f}')
print(f'MSE:  {np.mean(all_mse):.10f} ± {np.var(all_mse):.15f}')
print(f'NMSE: {np.mean(all_nmse):.10f} ± {np.var(all_nmse):.15f}')

# Best run (minimum RMSE)
best_idx = all_rmse.index(min(all_rmse))
print(f'\nBest run: {best_idx+1}')
print(f'  RMSE: {all_rmse[best_idx]:.15f}')
print(f'  MSE:  {all_mse[best_idx]:.15f}')
print(f'  NMSE: {all_nmse[best_idx]:.15f}')

print(f'\nAll RMSE values: {all_rmse}')
# Out:
# ===== FINAL RESULTS (30 runs) =====
# RMSE: 24.4196147247 ± 0.000145681726041
# MSE:  596.3177289840 ± 0.347420943269070
# NMSE: 0.0027238972 ± 0.000000000033093
#
# Best run: 30
#   RMSE: 24.390693059890278
#   MSE:  594.905907941779788
#   NMSE: 0.002708029854072
#
# All RMSE values: [24.421708768593497, 24.43139853210146, 24.4385101615656, 24.425315553156196, 24.4369683936223, 24.43419458244958, 24.415052499949866, 24.420612919597254, 24.420998272802727, 24.422209456175576, 24.419355645665235, 24.413712831928606, 24.426910831592437, 24.408315050170895, 24.42184726861392, 24.419714643137347, 24.42042674177704, 24.40455294210039, 24.417725017441217, 24.424721325881947, 24.43277544655598, 24.444738569666555, 24.391469667432194, 24.412759569958016, 24.403145363630646, 24.41187819431648, 24.41852836857518, 24.41793828727647, 24.420263775083086, 24.39069305989028]

# %%
# Plot best run predictions vs actual
actual = raw_values[-60:]
best_predictions = all_predictions[best_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_predictions, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('CLOSING - use 60 datas as test (Best Run)')
plt.show()

# Error plot
error = abs(np.array(actual) - np.array(best_predictions))
plt.figure(figsize=(10, 5))
plt.plot(error, 'k-o', label='|Actual - Predicted|')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('CLOSING - Prediction Error (Best Run)')
plt.show()

# %%
# Final metrics summary from best run
print('=== Best Run Metrics ===')
print(f'RMSE: {all_rmse[best_idx]}')
print(f'MSE:  {all_mse[best_idx]}')
print(f'NMSE: {all_nmse[best_idx]}')
# Out:
# === Best Run Metrics ===
# RMSE: 24.39069305989028
# MSE:  594.9059079417798
# NMSE: 0.0027080298540719024

# %%
plt.figure(figsize=(10,5))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.legend()
plt.title("LSTM-SNP Dow Jones Prediction")
plt.show()

# %% [markdown]
# Report

# %% [markdown]
# # **Bi-LSTM SNP**

# %%
def build_bilstm_snp_model(input_dim, units, batch_size):
    """
    Stateful BiLSTM-SNP model.
    Both forward and backward cells are independent LSTMSNPCell clones.
    Bidirectional merge_mode='concat' → output dim = 2*units.
    """
    cell_fw = LSTMSNPCell(units)
    cell_bw = LSTMSNPCell(units)

    rnn_fw = layers.RNN(cell_fw, return_sequences=False, stateful=True)
    rnn_bw = layers.RNN(cell_bw, return_sequences=False, stateful=True, go_backwards=True)

    bi_rnn = layers.Bidirectional(rnn_fw, backward_layer=rnn_bw)

    inputs = tf.keras.Input(batch_shape=(batch_size, 1, input_dim))
    x = bi_rnn(inputs)
    outputs = layers.Dense(1)(x)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
bi_model_check = build_bilstm_snp_model(input_dim=1, units=8, batch_size=1)
bi_model_check.summary()
print(f"\nTotal params: {bi_model_check.count_params()}")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (1, 1, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (1, 16)                │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (1, 1)                 │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 657 (2.57 KB)
#  Trainable params: 657 (2.57 KB)
#  Non-trainable params: 0 (0.00 B)
# Total params: 657

# %%
# ============================================================
# BiLSTM-SNP: 30-Run Experiment Protocol
# (Protocol-aligned with baseline LSTM-SNP)
# ============================================================

bi_all_rmse = []
bi_all_mse = []
bi_all_nmse = []
bi_all_predictions = []

for run in range(30):
    print(f'\n===== BiLSTM-SNP RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful BiLSTM model
    model = build_bilstm_snp_model(input_dim=1, units=8, batch_size=1)

    # Unit forget bias for BOTH forward and backward cells
    bi_layer = model.layers[1]  # Bidirectional layer
    for rnn_sub in [bi_layer.forward_layer, bi_layer.backward_layer]:
        cell = rnn_sub.cell
        weights = cell.get_weights()  # [kernel, recurrent_kernel, bias]
        bias = weights[2].copy()
        bias[8:16] = 1.0  # units=8, bias[units:2*units] = consume gate
        weights[2] = bias
        cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train,
            y_train,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        bi_layer.forward_layer.reset_states()
        bi_layer.backward_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]

        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics (matching calculate.py)
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    bi_all_rmse.append(rmse)
    bi_all_mse.append(mse)
    bi_all_nmse.append(nmse)
    bi_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')
# Out:
# ===== BiLSTM-SNP RUN 1/30 =====
# Training complete for run 1
# Month=1, Predicted=3798.9428, Expected=3796.0000
# Month=2, Predicted=3796.1341, Expected=3793.0000
# Month=3, Predicted=3793.0665, Expected=3766.0000
# Month=4, Predicted=3765.4150, Expected=3747.0000
# Month=5, Predicted=3746.5445, Expected=3754.0000
# Month=6, Predicted=3754.1551, Expected=3756.0000
# Month=7, Predicted=3756.0742, Expected=3767.0000
# Month=8, Predicted=3767.3201, Expected=3751.0000
# Month=9, Predicted=3750.6774, Expected=3769.0000
# Month=10, Predicted=3769.4745, Expected=3760.0000
# Month=11, Predicted=3759.8562, Expected=3785.0000
# Month=12, Predicted=3785.6558, Expected=3776.0000
# Month=13, Predicted=3775.8827, Expected=3755.0000
# Month=14, Predicted=3754.5514, Expected=3755.0000
# Month=15, Predicted=3755.0223, Expected=3751.0000
# Month=16, Predicted=3750.9314, Expected=3776.0000
# Month=17, Predicted=3776.6301, Expected=3847.0000
# Month=18, Predicted=3848.7239, Expected=3830.0000
# Month=19, Predicted=3829.7944, Expected=3881.0000
# Month=20, Predicted=3882.3333, Expected=3899.0000
# Month=21, Predicted=3899.6551, Expected=3917.0000
# Month=22, Predicted=3917.6436, Expected=3913.0000
# Month=23, Predicted=3913.0840, Expected=3901.0000
# Month=24, Predicted=3900.8252, Expected=3886.0000
# Month=25, Predicted=3885.6922, Expected=3892.5000
# Month=26, Predicted=3892.6840, Expected=3899.0000
# Month=27, Predicted=3899.2080, Expected=3886.0000
# Month=28, Predicted=3885.7441, Expected=3908.0000
# Month=29, Predicted=3908.5662, Expected=3875.0000
# Month=30, Predicted=3874.2471, Expected=3860.0000
# Month=31, Predicted=3859.6408, Expected=3880.0000
# Month=32, Predicted=3880.4668, Expected=3895.0000
# Month=33, Predicted=3895.4241, Expected=3954.0000
# Month=34, Predicted=3955.4622, Expected=3933.0000
# Month=35, Predicted=3932.6674, Expected=3937.0000
# Month=36, Predicted=3937.2227, Expected=3869.0000
# Month=37, Predicted=3867.3261, Expected=3852.0000
# Month=38, Predicted=3851.5019, Expected=3837.0000
# Month=39, Predicted=3836.5513, Expected=3832.0000
# Month=40, Predicted=3831.8220, Expected=3849.0000
# Month=41, Predicted=3849.3920, Expected=3863.0000
# Month=42, Predicted=3863.3973, Expected=3878.0000
# Month=43, Predicted=3878.4641, Expected=3855.0000
# Month=44, Predicted=3854.5361, Expected=3843.0000
# Month=45, Predicted=3842.7513, Expected=3847.0000
# Month=46, Predicted=3847.1181, Expected=3801.0000
# Month=47, Predicted=3799.8623, Expected=3787.0000
# Month=48, Predicted=3786.6019, Expected=3776.0000
# Month=49, Predicted=3775.6800, Expected=3797.0000
# Month=50, Predicted=3797.4719, Expected=3821.0000
# Month=51, Predicted=3821.6293, Expected=3877.0000
# Month=52, Predicted=3878.4191, Expected=3875.0000
# Month=53, Predicted=3875.1647, Expected=3890.0000
# Month=54, Predicted=3890.5370, Expected=3910.0000
# Month=55, Predicted=3910.6369, Expected=3924.0000
# Month=56, Predicted=3924.5023, Expected=3918.0000
# Month=57, Predicted=3917.9998, Expected=3936.0000
# Month=58, Predicted=3936.5363, Expected=3911.0000
# Month=59, Predicted=3910.4819, Expected=3891.0000
# Month=60, Predicted=3890.5431, Expected=3855.0000
# Run 1 — RMSE: 24.415734, MSE: 596.128052, NMSE: 0.0027204702
#
# ===== BiLSTM-SNP RUN 2/30 =====
# Training complete for run 2
# Month=1, Predicted=3798.5674, Expected=3796.0000
# Month=2, Predicted=3795.5879, Expected=3793.0000
# Month=3, Predicted=3792.8023, Expected=3766.0000
# Month=4, Predicted=3765.3450, Expected=3747.0000
# Month=5, Predicted=3746.7962, Expected=3754.0000
# Month=6, Predicted=3754.4694, Expected=3756.0000
# Month=7, Predicted=3756.1591, Expected=3767.0000
# Month=8, Predicted=3767.3259, Expected=3751.0000
# Month=9, Predicted=3750.5843, Expected=3769.0000
# Month=10, Predicted=3769.5704, Expected=3760.0000
# Month=11, Predicted=3759.7283, Expected=3785.0000
# Month=12, Predicted=3785.6662, Expected=3776.0000
# Month=13, Predicted=3775.6366, Expected=3755.0000
# Month=14, Predicted=3754.5327, Expected=3755.0000
# Month=15, Predicted=3755.2188, Expected=3751.0000
# Month=16, Predicted=3751.0354, Expected=3776.0000
# Month=17, Predicted=3776.7121, Expected=3847.0000
# Month=18, Predicted=3848.5335, Expected=3830.0000
# Month=19, Predicted=3828.9621, Expected=3881.0000
# Month=20, Predicted=3882.0685, Expected=3899.0000
# Month=21, Predicted=3898.9677, Expected=3917.0000
# Month=22, Predicted=3917.0948, Expected=3913.0000
# Month=23, Predicted=3912.6261, Expected=3901.0000
# Month=24, Predicted=3900.6421, Expected=3886.0000
# Month=25, Predicted=3885.7352, Expected=3892.5000
# Month=26, Predicted=3892.8496, Expected=3899.0000
# Month=27, Predicted=3899.2187, Expected=3886.0000
# Month=28, Predicted=3885.6945, Expected=3908.0000
# Month=29, Predicted=3908.6573, Expected=3875.0000
# Month=30, Predicted=3874.1118, Expected=3860.0000
# Month=31, Predicted=3859.9024, Expected=3880.0000
# Month=32, Predicted=3880.7457, Expected=3895.0000
# Month=33, Predicted=3895.3422, Expected=3954.0000
# Month=34, Predicted=3955.2800, Expected=3933.0000
# Month=35, Predicted=3931.9740, Expected=3937.0000
# Month=36, Predicted=3937.0518, Expected=3869.0000
# Month=37, Predicted=3867.3233, Expected=3852.0000
# Month=38, Predicted=3852.1740, Expected=3837.0000
# Month=39, Predicted=3837.0917, Expected=3832.0000
# Month=40, Predicted=3832.2518, Expected=3849.0000
# Month=41, Predicted=3849.6475, Expected=3863.0000
# Month=42, Predicted=3863.3327, Expected=3878.0000
# Month=43, Predicted=3878.2690, Expected=3855.0000
# Month=44, Predicted=3854.3101, Expected=3843.0000
# Month=45, Predicted=3842.8681, Expected=3847.0000
# Month=46, Predicted=3847.2945, Expected=3801.0000
# Month=47, Predicted=3799.9817, Expected=3787.0000
# Month=48, Predicted=3787.1240, Expected=3776.0000
# Month=49, Predicted=3776.1027, Expected=3797.0000
# Month=50, Predicted=3797.7878, Expected=3821.0000
# Month=51, Predicted=3821.5553, Expected=3877.0000
# Month=52, Predicted=3878.1378, Expected=3875.0000
# Month=53, Predicted=3874.4283, Expected=3890.0000
# Month=54, Predicted=3890.1569, Expected=3910.0000
# Month=55, Predicted=3910.2821, Expected=3924.0000
# Month=56, Predicted=3924.1033, Expected=3918.0000
# Month=57, Predicted=3917.6601, Expected=3936.0000
# Month=58, Predicted=3936.4096, Expected=3911.0000
# Month=59, Predicted=3910.2672, Expected=3891.0000
# Month=60, Predicted=3890.6967, Expected=3855.0000
# Run 2 — RMSE: 24.437044, MSE: 597.169116, NMSE: 0.0027359284
#
# ===== BiLSTM-SNP RUN 3/30 =====
# Training complete for run 3
# Month=1, Predicted=3798.6893, Expected=3796.0000
# Month=2, Predicted=3795.8266, Expected=3793.0000
# Month=3, Predicted=3792.8519, Expected=3766.0000
# Month=4, Predicted=3765.2861, Expected=3747.0000
# Month=5, Predicted=3746.5760, Expected=3754.0000
# Month=6, Predicted=3754.2645, Expected=3756.0000
# Month=7, Predicted=3756.0970, Expected=3767.0000
# Month=8, Predicted=3767.3011, Expected=3751.0000
# Month=9, Predicted=3750.5956, Expected=3769.0000
# Month=10, Predicted=3769.4600, Expected=3760.0000
# Month=11, Predicted=3759.7611, Expected=3785.0000
# Month=12, Predicted=3785.5843, Expected=3776.0000
# Month=13, Predicted=3775.7277, Expected=3755.0000
# Month=14, Predicted=3754.4679, Expected=3755.0000
# Month=15, Predicted=3755.0554, Expected=3751.0000
# Month=16, Predicted=3750.9436, Expected=3776.0000
# Month=17, Predicted=3776.6090, Expected=3847.0000
# Month=18, Predicted=3848.4397, Expected=3830.0000
# Month=19, Predicted=3829.3753, Expected=3881.0000
# Month=20, Predicted=3882.0060, Expected=3899.0000
# Month=21, Predicted=3899.2568, Expected=3917.0000
# Month=22, Predicted=3917.2799, Expected=3913.0000
# Month=23, Predicted=3912.7643, Expected=3901.0000
# Month=24, Predicted=3900.6262, Expected=3886.0000
# Month=25, Predicted=3885.6142, Expected=3892.5000
# Month=26, Predicted=3892.7007, Expected=3899.0000
# Month=27, Predicted=3899.1772, Expected=3886.0000
# Month=28, Predicted=3885.6740, Expected=3908.0000
# Month=29, Predicted=3908.5397, Expected=3875.0000
# Month=30, Predicted=3874.1398, Expected=3860.0000
# Month=31, Predicted=3859.6907, Expected=3880.0000
# Month=32, Predicted=3880.5473, Expected=3895.0000
# Month=33, Predicted=3895.3697, Expected=3954.0000
# Month=34, Predicted=3955.2201, Expected=3933.0000
# Month=35, Predicted=3932.3081, Expected=3937.0000
# Month=36, Predicted=3937.0412, Expected=3869.0000
# Month=37, Predicted=3867.2219, Expected=3852.0000
# Month=38, Predicted=3851.7206, Expected=3837.0000
# Month=39, Predicted=3836.7793, Expected=3832.0000
# Month=40, Predicted=3832.0226, Expected=3849.0000
# Month=41, Predicted=3849.5073, Expected=3863.0000
# Month=42, Predicted=3863.3694, Expected=3878.0000
# Month=43, Predicted=3878.3500, Expected=3855.0000
# Month=44, Predicted=3854.3811, Expected=3843.0000
# Month=45, Predicted=3842.7324, Expected=3847.0000
# Month=46, Predicted=3847.1583, Expected=3801.0000
# Month=47, Predicted=3799.8710, Expected=3787.0000
# Month=48, Predicted=3786.7929, Expected=3776.0000
# Month=49, Predicted=3775.8645, Expected=3797.0000
# Month=50, Predicted=3797.6013, Expected=3821.0000
# Month=51, Predicted=3821.5761, Expected=3877.0000
# Month=52, Predicted=3878.1527, Expected=3875.0000
# Month=53, Predicted=3874.7910, Expected=3890.0000
# Month=54, Predicted=3890.2664, Expected=3910.0000
# Month=55, Predicted=3910.3762, Expected=3924.0000
# Month=56, Predicted=3924.2403, Expected=3918.0000
# Month=57, Predicted=3917.7541, Expected=3936.0000
# Month=58, Predicted=3936.3816, Expected=3911.0000
# Month=59, Predicted=3910.3043, Expected=3891.0000
# Month=60, Predicted=3890.5214, Expected=3855.0000
# Run 3 — RMSE: 24.413530, MSE: 596.020431, NMSE: 0.0027262573
#
# ===== BiLSTM-SNP RUN 4/30 =====
# Training complete for run 4
# Month=1, Predicted=3798.6084, Expected=3796.0000
# Month=2, Predicted=3795.7057, Expected=3793.0000
# Month=3, Predicted=3792.8037, Expected=3766.0000
# Month=4, Predicted=3765.2886, Expected=3747.0000
# Month=5, Predicted=3746.6097, Expected=3754.0000
# Month=6, Predicted=3754.2529, Expected=3756.0000
# Month=7, Predicted=3756.0428, Expected=3767.0000
# Month=8, Predicted=3767.2334, Expected=3751.0000
# Month=9, Predicted=3750.5478, Expected=3769.0000
# Month=10, Predicted=3769.4374, Expected=3760.0000
# Month=11, Predicted=3759.7017, Expected=3785.0000
# Month=12, Predicted=3785.5631, Expected=3776.0000
# Month=13, Predicted=3775.6538, Expected=3755.0000
# Month=14, Predicted=3754.4603, Expected=3755.0000
# Month=15, Predicted=3755.0512, Expected=3751.0000
# Month=16, Predicted=3750.9128, Expected=3776.0000
# Month=17, Predicted=3776.5855, Expected=3847.0000
# Month=18, Predicted=3848.4890, Expected=3830.0000
# Month=19, Predicted=3829.2149, Expected=3881.0000
# Month=20, Predicted=3882.0439, Expected=3899.0000
# Month=21, Predicted=3899.1151, Expected=3917.0000
# Month=22, Predicted=3917.1801, Expected=3913.0000
# Month=23, Predicted=3912.6926, Expected=3901.0000
# Month=24, Predicted=3900.6093, Expected=3886.0000
# Month=25, Predicted=3885.6218, Expected=3892.5000
# Month=26, Predicted=3892.6835, Expected=3899.0000
# Month=27, Predicted=3899.1206, Expected=3886.0000
# Month=28, Predicted=3885.6333, Expected=3908.0000
# Month=29, Predicted=3908.5225, Expected=3875.0000
# Month=30, Predicted=3874.1023, Expected=3860.0000
# Month=31, Predicted=3859.7157, Expected=3880.0000
# Month=32, Predicted=3880.5439, Expected=3895.0000
# Month=33, Predicted=3895.2857, Expected=3954.0000
# Month=34, Predicted=3955.2389, Expected=3933.0000
# Month=35, Predicted=3932.1713, Expected=3937.0000
# Month=36, Predicted=3937.0102, Expected=3869.0000
# Month=37, Predicted=3867.3516, Expected=3852.0000
# Month=38, Predicted=3851.8131, Expected=3837.0000
# Month=39, Predicted=3836.7986, Expected=3832.0000
# Month=40, Predicted=3832.0051, Expected=3849.0000
# Month=41, Predicted=3849.4640, Expected=3863.0000
# Month=42, Predicted=3863.2749, Expected=3878.0000
# Month=43, Predicted=3878.2547, Expected=3855.0000
# Month=44, Predicted=3854.3287, Expected=3843.0000
# Month=45, Predicted=3842.7382, Expected=3847.0000
# Month=46, Predicted=3847.1371, Expected=3801.0000
# Month=47, Predicted=3799.8795, Expected=3787.0000
# Month=48, Predicted=3786.8377, Expected=3776.0000
# Month=49, Predicted=3775.8639, Expected=3797.0000
# Month=50, Predicted=3797.5808, Expected=3821.0000
# Month=51, Predicted=3821.4991, Expected=3877.0000
# Month=52, Predicted=3878.1386, Expected=3875.0000
# Month=53, Predicted=3874.6234, Expected=3890.0000
# Month=54, Predicted=3890.1879, Expected=3910.0000
# Month=55, Predicted=3910.3044, Expected=3924.0000
# Month=56, Predicted=3924.1448, Expected=3918.0000
# Month=57, Predicted=3917.6918, Expected=3936.0000
# Month=58, Predicted=3936.3457, Expected=3911.0000
# Month=59, Predicted=3910.2698, Expected=3891.0000
# Month=60, Predicted=3890.5469, Expected=3855.0000
# Run 4 — RMSE: 24.430328, MSE: 596.840931, NMSE: 0.0027307204
#
# ===== BiLSTM-SNP RUN 5/30 =====
# Training complete for run 5
# Month=1, Predicted=3798.9211, Expected=3796.0000
# Month=2, Predicted=3796.1017, Expected=3793.0000
# Month=3, Predicted=3793.0512, Expected=3766.0000
# Month=4, Predicted=3765.4491, Expected=3747.0000
# Month=5, Predicted=3746.6221, Expected=3754.0000
# Month=6, Predicted=3754.2448, Expected=3756.0000
# Month=7, Predicted=3756.1387, Expected=3767.0000
# Month=8, Predicted=3767.3548, Expected=3751.0000
# Month=9, Predicted=3750.7142, Expected=3769.0000
# Month=10, Predicted=3769.5108, Expected=3760.0000
# Month=11, Predicted=3759.8888, Expected=3785.0000
# Month=12, Predicted=3785.6803, Expected=3776.0000
# Month=13, Predicted=3775.9004, Expected=3755.0000
# Month=14, Predicted=3754.5869, Expected=3755.0000
# Month=15, Predicted=3755.0822, Expected=3751.0000
# Month=16, Predicted=3750.9931, Expected=3776.0000
# Month=17, Predicted=3776.6757, Expected=3847.0000
# Month=18, Predicted=3848.7165, Expected=3830.0000
# Month=19, Predicted=3829.7705, Expected=3881.0000
# Month=20, Predicted=3882.2932, Expected=3899.0000
# Month=21, Predicted=3899.5957, Expected=3917.0000
# Month=22, Predicted=3917.5841, Expected=3913.0000
# Month=23, Predicted=3913.0573, Expected=3901.0000
# Month=24, Predicted=3900.8362, Expected=3886.0000
# Month=25, Predicted=3885.7420, Expected=3892.5000
# Month=26, Predicted=3892.7472, Expected=3899.0000
# Month=27, Predicted=3899.2554, Expected=3886.0000
# Month=28, Predicted=3885.7887, Expected=3908.0000
# Month=29, Predicted=3908.6070, Expected=3875.0000
# Month=30, Predicted=3874.2981, Expected=3860.0000
# Month=31, Predicted=3859.7122, Expected=3880.0000
# Month=32, Predicted=3880.5470, Expected=3895.0000
# Month=33, Predicted=3895.4552, Expected=3954.0000
# Month=34, Predicted=3955.4564, Expected=3933.0000
# Month=35, Predicted=3932.6540, Expected=3937.0000
# Month=36, Predicted=3937.2058, Expected=3869.0000
# Month=37, Predicted=3867.3875, Expected=3852.0000
# Month=38, Predicted=3851.6443, Expected=3837.0000
# Month=39, Predicted=3836.7023, Expected=3832.0000
# Month=40, Predicted=3831.9467, Expected=3849.0000
# Month=41, Predicted=3849.4746, Expected=3863.0000
# Month=42, Predicted=3863.4254, Expected=3878.0000
# Month=43, Predicted=3878.4602, Expected=3855.0000
# Month=44, Predicted=3854.5515, Expected=3843.0000
# Month=45, Predicted=3842.7948, Expected=3847.0000
# Month=46, Predicted=3847.1782, Expected=3801.0000
# Month=47, Predicted=3799.9461, Expected=3787.0000
# Month=48, Predicted=3786.7205, Expected=3776.0000
# Month=49, Predicted=3775.8006, Expected=3797.0000
# Month=50, Predicted=3797.5642, Expected=3821.0000
# Month=51, Predicted=3821.6593, Expected=3877.0000
# Month=52, Predicted=3878.3969, Expected=3875.0000
# Month=53, Predicted=3875.1196, Expected=3890.0000
# Month=54, Predicted=3890.4865, Expected=3910.0000
# Month=55, Predicted=3910.6059, Expected=3924.0000
# Month=56, Predicted=3924.4726, Expected=3918.0000
# Month=57, Predicted=3917.9928, Expected=3936.0000
# Month=58, Predicted=3936.5405, Expected=3911.0000
# Month=59, Predicted=3910.5145, Expected=3891.0000
# Month=60, Predicted=3890.6046, Expected=3855.0000
# Run 5 — RMSE: 24.412556, MSE: 595.972878, NMSE: 0.0027216553
#
# ===== BiLSTM-SNP RUN 6/30 =====
# Training complete for run 6
# Month=1, Predicted=3798.5820, Expected=3796.0000
# Month=2, Predicted=3795.6409, Expected=3793.0000
# Month=3, Predicted=3792.8364, Expected=3766.0000
# Month=4, Predicted=3765.3766, Expected=3747.0000
# Month=5, Predicted=3746.8319, Expected=3754.0000
# Month=6, Predicted=3754.5185, Expected=3756.0000
# Month=7, Predicted=3756.2317, Expected=3767.0000
# Month=8, Predicted=3767.3871, Expected=3751.0000
# Month=9, Predicted=3750.6562, Expected=3769.0000
# Month=10, Predicted=3769.6092, Expected=3760.0000
# Month=11, Predicted=3759.8013, Expected=3785.0000
# Month=12, Predicted=3785.6924, Expected=3776.0000
# Month=13, Predicted=3775.7068, Expected=3755.0000
# Month=14, Predicted=3754.5820, Expected=3755.0000
# Month=15, Predicted=3755.2679, Expected=3751.0000
# Month=16, Predicted=3751.1021, Expected=3776.0000
# Month=17, Predicted=3776.7481, Expected=3847.0000
# Month=18, Predicted=3848.4209, Expected=3830.0000
# Month=19, Predicted=3829.0259, Expected=3881.0000
# Month=20, Predicted=3881.9857, Expected=3899.0000
# Month=21, Predicted=3898.9831, Expected=3917.0000
# Month=22, Predicted=3917.0942, Expected=3913.0000
# Month=23, Predicted=3912.6502, Expected=3901.0000
# Month=24, Predicted=3900.6667, Expected=3886.0000
# Month=25, Predicted=3885.7671, Expected=3892.5000
# Month=26, Predicted=3892.8881, Expected=3899.0000
# Month=27, Predicted=3899.2754, Expected=3886.0000
# Month=28, Predicted=3885.7600, Expected=3908.0000
# Month=29, Predicted=3908.6884, Expected=3875.0000
# Month=30, Predicted=3874.1717, Expected=3860.0000
# Month=31, Predicted=3859.9504, Expected=3880.0000
# Month=32, Predicted=3880.7872, Expected=3895.0000
# Month=33, Predicted=3895.4068, Expected=3954.0000
# Month=34, Predicted=3955.2155, Expected=3933.0000
# Month=35, Predicted=3932.0410, Expected=3937.0000
# Month=36, Predicted=3937.0746, Expected=3869.0000
# Month=37, Predicted=3867.2734, Expected=3852.0000
# Month=38, Predicted=3852.1904, Expected=3837.0000
# Month=39, Predicted=3837.1526, Expected=3832.0000
# Month=40, Predicted=3832.3305, Expected=3849.0000
# Month=41, Predicted=3849.7171, Expected=3863.0000
# Month=42, Predicted=3863.4082, Expected=3878.0000
# Month=43, Predicted=3878.3283, Expected=3855.0000
# Month=44, Predicted=3854.3738, Expected=3843.0000
# Month=45, Predicted=3842.9171, Expected=3847.0000
# Month=46, Predicted=3847.3494, Expected=3801.0000
# Month=47, Predicted=3800.0175, Expected=3787.0000
# Month=48, Predicted=3787.1755, Expected=3776.0000
# Month=49, Predicted=3776.1789, Expected=3797.0000
# Month=50, Predicted=3797.8483, Expected=3821.0000
# Month=51, Predicted=3821.6162, Expected=3877.0000
# Month=52, Predicted=3878.0904, Expected=3875.0000
# Month=53, Predicted=3874.4894, Expected=3890.0000
# Month=54, Predicted=3890.1685, Expected=3910.0000
# Month=55, Predicted=3910.2923, Expected=3924.0000
# Month=56, Predicted=3924.1260, Expected=3918.0000
# Month=57, Predicted=3917.6982, Expected=3936.0000
# Month=58, Predicted=3936.4233, Expected=3911.0000
# Month=59, Predicted=3910.3125, Expected=3891.0000
# Month=60, Predicted=3890.7310, Expected=3855.0000
# Run 6 — RMSE: 24.426133, MSE: 596.635988, NMSE: 0.0027347543
#
# ===== BiLSTM-SNP RUN 7/30 =====
# Training complete for run 7
# Month=1, Predicted=3798.7632, Expected=3796.0000
# Month=2, Predicted=3795.8004, Expected=3793.0000
# Month=3, Predicted=3792.9388, Expected=3766.0000
# Month=4, Predicted=3765.4403, Expected=3747.0000
# Month=5, Predicted=3746.8119, Expected=3754.0000
# Month=6, Predicted=3754.4874, Expected=3756.0000
# Month=7, Predicted=3756.2243, Expected=3767.0000
# Month=8, Predicted=3767.4114, Expected=3751.0000
# Month=9, Predicted=3750.6860, Expected=3769.0000
# Month=10, Predicted=3769.6433, Expected=3760.0000
# Month=11, Predicted=3759.8396, Expected=3785.0000
# Month=12, Predicted=3785.7659, Expected=3776.0000
# Month=13, Predicted=3775.7769, Expected=3755.0000
# Month=14, Predicted=3754.6136, Expected=3755.0000
# Month=15, Predicted=3755.2541, Expected=3751.0000
# Month=16, Predicted=3751.0918, Expected=3776.0000
# Month=17, Predicted=3776.7986, Expected=3847.0000
# Month=18, Predicted=3848.7644, Expected=3830.0000
# Month=19, Predicted=3829.2718, Expected=3881.0000
# Month=20, Predicted=3882.2700, Expected=3899.0000
# Month=21, Predicted=3899.2216, Expected=3917.0000
# Month=22, Predicted=3917.3066, Expected=3913.0000
# Month=23, Predicted=3912.8097, Expected=3901.0000
# Month=24, Predicted=3900.7570, Expected=3886.0000
# Month=25, Predicted=3885.7973, Expected=3892.5000
# Month=26, Predicted=3892.8946, Expected=3899.0000
# Month=27, Predicted=3899.2996, Expected=3886.0000
# Month=28, Predicted=3885.7834, Expected=3908.0000
# Month=29, Predicted=3908.7357, Expected=3875.0000
# Month=30, Predicted=3874.2369, Expected=3860.0000
# Month=31, Predicted=3859.9177, Expected=3880.0000
# Month=32, Predicted=3880.7888, Expected=3895.0000
# Month=33, Predicted=3895.4552, Expected=3954.0000
# Month=34, Predicted=3955.4810, Expected=3933.0000
# Month=35, Predicted=3932.2476, Expected=3937.0000
# Month=36, Predicted=3937.1713, Expected=3869.0000
# Month=37, Predicted=3867.4574, Expected=3852.0000
# Month=38, Predicted=3852.1058, Expected=3837.0000
# Month=39, Predicted=3837.0566, Expected=3832.0000
# Month=40, Predicted=3832.2417, Expected=3849.0000
# Month=41, Predicted=3849.6923, Expected=3863.0000
# Month=42, Predicted=3863.4408, Expected=3878.0000
# Month=43, Predicted=3878.4033, Expected=3855.0000
# Month=44, Predicted=3854.4484, Expected=3843.0000
# Month=45, Predicted=3842.9163, Expected=3847.0000
# Month=46, Predicted=3847.3389, Expected=3801.0000
# Month=47, Predicted=3800.0507, Expected=3787.0000
# Month=48, Predicted=3787.0847, Expected=3776.0000
# Month=49, Predicted=3776.0902, Expected=3797.0000
# Month=50, Predicted=3797.8266, Expected=3821.0000
# Month=51, Predicted=3821.6777, Expected=3877.0000
# Month=52, Predicted=3878.3528, Expected=3875.0000
# Month=53, Predicted=3874.6976, Expected=3890.0000
# Month=54, Predicted=3890.3289, Expected=3910.0000
# Month=55, Predicted=3910.4528, Expected=3924.0000
# Month=56, Predicted=3924.2783, Expected=3918.0000
# Month=57, Predicted=3917.8154, Expected=3936.0000
# Month=58, Predicted=3936.5252, Expected=3911.0000
# Month=59, Predicted=3910.4014, Expected=3891.0000
# Month=60, Predicted=3890.7338, Expected=3855.0000
# Run 7 — RMSE: 24.427225, MSE: 596.689307, NMSE: 0.0027310522
#
# ===== BiLSTM-SNP RUN 8/30 =====
# Training complete for run 8
# Month=1, Predicted=3798.7725, Expected=3796.0000
# Month=2, Predicted=3795.9004, Expected=3793.0000
# Month=3, Predicted=3792.9239, Expected=3766.0000
# Month=4, Predicted=3765.3754, Expected=3747.0000
# Month=5, Predicted=3746.6413, Expected=3754.0000
# Month=6, Predicted=3754.2910, Expected=3756.0000
# Month=7, Predicted=3756.1396, Expected=3767.0000
# Month=8, Predicted=3767.3367, Expected=3751.0000
# Month=9, Predicted=3750.6659, Expected=3769.0000
# Month=10, Predicted=3769.5021, Expected=3760.0000
# Month=11, Predicted=3759.8242, Expected=3785.0000
# Month=12, Predicted=3785.6412, Expected=3776.0000
# Month=13, Predicted=3775.7957, Expected=3755.0000
# Month=14, Predicted=3754.5418, Expected=3755.0000
# Month=15, Predicted=3755.0967, Expected=3751.0000
# Month=16, Predicted=3750.9941, Expected=3776.0000
# Month=17, Predicted=3776.6635, Expected=3847.0000
# Month=18, Predicted=3848.6153, Expected=3830.0000
# Month=19, Predicted=3829.4590, Expected=3881.0000
# Month=20, Predicted=3882.1289, Expected=3899.0000
# Month=21, Predicted=3899.3205, Expected=3917.0000
# Month=22, Predicted=3917.3564, Expected=3913.0000
# Month=23, Predicted=3912.8596, Expected=3901.0000
# Month=24, Predicted=3900.7174, Expected=3886.0000
# Month=25, Predicted=3885.6943, Expected=3892.5000
# Month=26, Predicted=3892.7441, Expected=3899.0000
# Month=27, Predicted=3899.2264, Expected=3886.0000
# Month=28, Predicted=3885.7452, Expected=3908.0000
# Month=29, Predicted=3908.5914, Expected=3875.0000
# Month=30, Predicted=3874.2240, Expected=3860.0000
# Month=31, Predicted=3859.7448, Expected=3880.0000
# Month=32, Predicted=3880.5826, Expected=3895.0000
# Month=33, Predicted=3895.4064, Expected=3954.0000
# Month=34, Predicted=3955.3629, Expected=3933.0000
# Month=35, Predicted=3932.3951, Expected=3937.0000
# Month=36, Predicted=3937.0977, Expected=3869.0000
# Month=37, Predicted=3867.3274, Expected=3852.0000
# Month=38, Predicted=3851.7626, Expected=3837.0000
# Month=39, Predicted=3836.8173, Expected=3832.0000
# Month=40, Predicted=3832.0483, Expected=3849.0000
# Month=41, Predicted=3849.5320, Expected=3863.0000
# Month=42, Predicted=3863.3994, Expected=3878.0000
# Month=43, Predicted=3878.3930, Expected=3855.0000
# Month=44, Predicted=3854.4628, Expected=3843.0000
# Month=45, Predicted=3842.7918, Expected=3847.0000
# Month=46, Predicted=3847.1949, Expected=3801.0000
# Month=47, Predicted=3799.9533, Expected=3787.0000
# Month=48, Predicted=3786.8288, Expected=3776.0000
# Month=49, Predicted=3775.8979, Expected=3797.0000
# Month=50, Predicted=3797.6292, Expected=3821.0000
# Month=51, Predicted=3821.6198, Expected=3877.0000
# Month=52, Predicted=3878.2814, Expected=3875.0000
# Month=53, Predicted=3874.8573, Expected=3890.0000
# Month=54, Predicted=3890.3206, Expected=3910.0000
# Month=55, Predicted=3910.4489, Expected=3924.0000
# Month=56, Predicted=3924.3085, Expected=3918.0000
# Month=57, Predicted=3917.8426, Expected=3936.0000
# Month=58, Predicted=3936.4472, Expected=3911.0000
# Month=59, Predicted=3910.4009, Expected=3891.0000
# Month=60, Predicted=3890.5956, Expected=3855.0000
# Run 8 — RMSE: 24.417134, MSE: 596.196448, NMSE: 0.0027263118
#
# ===== BiLSTM-SNP RUN 9/30 =====
# Training complete for run 9
# Month=1, Predicted=3799.0519, Expected=3796.0000
# Month=2, Predicted=3796.1773, Expected=3793.0000
# Month=3, Predicted=3793.1315, Expected=3766.0000
# Month=4, Predicted=3765.5231, Expected=3747.0000
# Month=5, Predicted=3746.6804, Expected=3754.0000
# Month=6, Predicted=3754.3086, Expected=3756.0000
# Month=7, Predicted=3756.1981, Expected=3767.0000
# Month=8, Predicted=3767.4327, Expected=3751.0000
# Month=9, Predicted=3750.7781, Expected=3769.0000
# Month=10, Predicted=3769.6088, Expected=3760.0000
# Month=11, Predicted=3759.9537, Expected=3785.0000
# Month=12, Predicted=3785.7940, Expected=3776.0000
# Month=13, Predicted=3775.9679, Expected=3755.0000
# Month=14, Predicted=3754.6575, Expected=3755.0000
# Month=15, Predicted=3755.1504, Expected=3751.0000
# Month=16, Predicted=3751.0525, Expected=3776.0000
# Month=17, Predicted=3776.7817, Expected=3847.0000
# Month=18, Predicted=3848.9927, Expected=3830.0000
# Month=19, Predicted=3829.8448, Expected=3881.0000
# Month=20, Predicted=3882.5051, Expected=3899.0000
# Month=21, Predicted=3899.6937, Expected=3917.0000
# Month=22, Predicted=3917.6847, Expected=3913.0000
# Month=23, Predicted=3913.1301, Expected=3901.0000
# Month=24, Predicted=3900.9046, Expected=3886.0000
# Month=25, Predicted=3885.8019, Expected=3892.5000
# Month=26, Predicted=3892.8144, Expected=3899.0000
# Month=27, Predicted=3899.3218, Expected=3886.0000
# Month=28, Predicted=3885.8473, Expected=3908.0000
# Month=29, Predicted=3908.7092, Expected=3875.0000
# Month=30, Predicted=3874.3728, Expected=3860.0000
# Month=31, Predicted=3859.7751, Expected=3880.0000
# Month=32, Predicted=3880.6390, Expected=3895.0000
# Month=33, Predicted=3895.5389, Expected=3954.0000
# Month=34, Predicted=3955.6801, Expected=3933.0000
# Month=35, Predicted=3932.7315, Expected=3937.0000
# Month=36, Predicted=3937.3009, Expected=3869.0000
# Month=37, Predicted=3868.0300, Expected=3852.0000
# Month=38, Predicted=3851.6962, Expected=3837.0000
# Month=39, Predicted=3836.7346, Expected=3832.0000
# Month=40, Predicted=3831.9867, Expected=3849.0000
# Month=41, Predicted=3849.5535, Expected=3863.0000
# Month=42, Predicted=3863.5090, Expected=3878.0000
# Month=43, Predicted=3878.5538, Expected=3855.0000
# Month=44, Predicted=3854.6281, Expected=3843.0000
# Month=45, Predicted=3842.8657, Expected=3847.0000
# Month=46, Predicted=3847.2488, Expected=3801.0000
# Month=47, Predicted=3800.0322, Expected=3787.0000
# Month=48, Predicted=3786.7702, Expected=3776.0000
# Month=49, Predicted=3775.8421, Expected=3797.0000
# Month=50, Predicted=3797.6517, Expected=3821.0000
# Month=51, Predicted=3821.7617, Expected=3877.0000
# Month=52, Predicted=3878.6082, Expected=3875.0000
# Month=53, Predicted=3875.1971, Expected=3890.0000
# Month=54, Predicted=3890.5936, Expected=3910.0000
# Month=55, Predicted=3910.7119, Expected=3924.0000
# Month=56, Predicted=3924.5628, Expected=3918.0000
# Month=57, Predicted=3918.0627, Expected=3936.0000
# Month=58, Predicted=3936.6380, Expected=3911.0000
# Month=59, Predicted=3910.5820, Expected=3891.0000
# Month=60, Predicted=3890.6670, Expected=3855.0000
# Run 9 — RMSE: 24.419658, MSE: 596.319712, NMSE: 0.0027220138
#
# ===== BiLSTM-SNP RUN 10/30 =====
# Training complete for run 10
# Month=1, Predicted=3798.7777, Expected=3796.0000
# Month=2, Predicted=3795.9094, Expected=3793.0000
# Month=3, Predicted=3792.9436, Expected=3766.0000
# Month=4, Predicted=3765.3804, Expected=3747.0000
# Month=5, Predicted=3746.6076, Expected=3754.0000
# Month=6, Predicted=3754.2348, Expected=3756.0000
# Month=7, Predicted=3756.0656, Expected=3767.0000
# Month=8, Predicted=3767.2774, Expected=3751.0000
# Month=9, Predicted=3750.6105, Expected=3769.0000
# Month=10, Predicted=3769.4708, Expected=3760.0000
# Month=11, Predicted=3759.7763, Expected=3785.0000
# Month=12, Predicted=3785.6291, Expected=3776.0000
# Month=13, Predicted=3775.7644, Expected=3755.0000
# Month=14, Predicted=3754.5156, Expected=3755.0000
# Month=15, Predicted=3755.0540, Expected=3751.0000
# Month=16, Predicted=3750.9321, Expected=3776.0000
# Month=17, Predicted=3776.6301, Expected=3847.0000
# Month=18, Predicted=3848.6793, Expected=3830.0000
# Month=19, Predicted=3829.4940, Expected=3881.0000
# Month=20, Predicted=3882.2445, Expected=3899.0000
# Month=21, Predicted=3899.3903, Expected=3917.0000
# Month=22, Predicted=3917.4329, Expected=3913.0000
# Month=23, Predicted=3912.9164, Expected=3901.0000
# Month=24, Predicted=3900.7534, Expected=3886.0000
# Month=25, Predicted=3885.6948, Expected=3892.5000
# Month=26, Predicted=3892.7188, Expected=3899.0000
# Month=27, Predicted=3899.1808, Expected=3886.0000
# Month=28, Predicted=3885.6968, Expected=3908.0000
# Month=29, Predicted=3908.5687, Expected=3875.0000
# Month=30, Predicted=3874.1892, Expected=3860.0000
# Month=31, Predicted=3859.6902, Expected=3880.0000
# Month=32, Predicted=3880.5352, Expected=3895.0000
# Month=33, Predicted=3895.3506, Expected=3954.0000
# Month=34, Predicted=3955.4004, Expected=3933.0000
# Month=35, Predicted=3932.4162, Expected=3937.0000
# Month=36, Predicted=3937.1233, Expected=3869.0000
# Month=37, Predicted=3867.3733, Expected=3852.0000
# Month=38, Predicted=3851.6950, Expected=3837.0000
# Month=39, Predicted=3836.7048, Expected=3832.0000
# Month=40, Predicted=3831.9273, Expected=3849.0000
# Month=41, Predicted=3849.4355, Expected=3863.0000
# Month=42, Predicted=3863.3184, Expected=3878.0000
# Month=43, Predicted=3878.3417, Expected=3855.0000
# Month=44, Predicted=3854.4292, Expected=3843.0000
# Month=45, Predicted=3842.7523, Expected=3847.0000
# Month=46, Predicted=3847.1427, Expected=3801.0000
# Month=47, Predicted=3799.9010, Expected=3787.0000
# Month=48, Predicted=3786.7381, Expected=3776.0000
# Month=49, Predicted=3775.7847, Expected=3797.0000
# Month=50, Predicted=3797.5446, Expected=3821.0000
# Month=51, Predicted=3821.5548, Expected=3877.0000
# Month=52, Predicted=3878.3055, Expected=3875.0000
# Month=53, Predicted=3874.8744, Expected=3890.0000
# Month=54, Predicted=3890.3692, Expected=3910.0000
# Month=55, Predicted=3910.4929, Expected=3924.0000
# Month=56, Predicted=3924.3412, Expected=3918.0000
# Month=57, Predicted=3917.8665, Expected=3936.0000
# Month=58, Predicted=3936.4743, Expected=3911.0000
# Month=59, Predicted=3910.4042, Expected=3891.0000
# Month=60, Predicted=3890.5726, Expected=3855.0000
# Run 10 — RMSE: 24.427108, MSE: 596.683598, NMSE: 0.0027262004
#
# ===== BiLSTM-SNP RUN 11/30 =====
# Training complete for run 11
# Month=1, Predicted=3798.6372, Expected=3796.0000
# Month=2, Predicted=3795.6991, Expected=3793.0000
# Month=3, Predicted=3792.8605, Expected=3766.0000
# Month=4, Predicted=3765.3171, Expected=3747.0000
# Month=5, Predicted=3746.6935, Expected=3754.0000
# Month=6, Predicted=3754.3591, Expected=3756.0000
# Month=7, Predicted=3756.0858, Expected=3767.0000
# Month=8, Predicted=3767.2806, Expected=3751.0000
# Month=9, Predicted=3750.5417, Expected=3769.0000
# Month=10, Predicted=3769.5203, Expected=3760.0000
# Month=11, Predicted=3759.7059, Expected=3785.0000
# Month=12, Predicted=3785.6431, Expected=3776.0000
# Month=13, Predicted=3775.6490, Expected=3755.0000
# Month=14, Predicted=3754.4824, Expected=3755.0000
# Month=15, Predicted=3755.1387, Expected=3751.0000
# Month=16, Predicted=3750.9616, Expected=3776.0000
# Month=17, Predicted=3776.6598, Expected=3847.0000
# Month=18, Predicted=3848.5299, Expected=3830.0000
# Month=19, Predicted=3829.1062, Expected=3881.0000
# Month=20, Predicted=3882.1606, Expected=3899.0000
# Month=21, Predicted=3899.1550, Expected=3917.0000
# Month=22, Predicted=3917.2638, Expected=3913.0000
# Month=23, Predicted=3912.7557, Expected=3901.0000
# Month=24, Predicted=3900.6890, Expected=3886.0000
# Month=25, Predicted=3885.7073, Expected=3892.5000
# Month=26, Predicted=3892.7958, Expected=3899.0000
# Month=27, Predicted=3899.1858, Expected=3886.0000
# Month=28, Predicted=3885.6545, Expected=3908.0000
# Month=29, Predicted=3908.6137, Expected=3875.0000
# Month=30, Predicted=3874.0543, Expected=3860.0000
# Month=31, Predicted=3859.7880, Expected=3880.0000
# Month=32, Predicted=3880.6419, Expected=3895.0000
# Month=33, Predicted=3895.3139, Expected=3954.0000
# Month=34, Predicted=3955.2887, Expected=3933.0000
# Month=35, Predicted=3932.0818, Expected=3937.0000
# Month=36, Predicted=3937.0979, Expected=3869.0000
# Month=37, Predicted=3867.1749, Expected=3852.0000
# Month=38, Predicted=3852.0458, Expected=3837.0000
# Month=39, Predicted=3836.9360, Expected=3832.0000
# Month=40, Predicted=3832.1028, Expected=3849.0000
# Month=41, Predicted=3849.5398, Expected=3863.0000
# Month=42, Predicted=3863.2992, Expected=3878.0000
# Month=43, Predicted=3878.2820, Expected=3855.0000
# Month=44, Predicted=3854.3023, Expected=3843.0000
# Month=45, Predicted=3842.8009, Expected=3847.0000
# Month=46, Predicted=3847.2179, Expected=3801.0000
# Month=47, Predicted=3799.8311, Expected=3787.0000
# Month=48, Predicted=3786.9537, Expected=3776.0000
# Month=49, Predicted=3775.9344, Expected=3797.0000
# Month=50, Predicted=3797.6566, Expected=3821.0000
# Month=51, Predicted=3821.5180, Expected=3877.0000
# Month=52, Predicted=3878.1682, Expected=3875.0000
# Month=53, Predicted=3874.5775, Expected=3890.0000
# Month=54, Predicted=3890.2632, Expected=3910.0000
# Month=55, Predicted=3910.3875, Expected=3924.0000
# Month=56, Predicted=3924.2154, Expected=3918.0000
# Month=57, Predicted=3917.7408, Expected=3936.0000
# Month=58, Predicted=3936.4556, Expected=3911.0000
# Month=59, Predicted=3910.2749, Expected=3891.0000
# Month=60, Predicted=3890.6202, Expected=3855.0000
# Run 11 — RMSE: 24.436573, MSE: 597.146099, NMSE: 0.0027320329
#
# ===== BiLSTM-SNP RUN 12/30 =====
# Training complete for run 12
# Month=1, Predicted=3798.7672, Expected=3796.0000
# Month=2, Predicted=3795.9256, Expected=3793.0000
# Month=3, Predicted=3792.9409, Expected=3766.0000
# Month=4, Predicted=3765.1777, Expected=3747.0000
# Month=5, Predicted=3746.4981, Expected=3754.0000
# Month=6, Predicted=3754.3951, Expected=3756.0000
# Month=7, Predicted=3756.1750, Expected=3767.0000
# Month=8, Predicted=3767.4806, Expected=3751.0000
# Month=9, Predicted=3750.5145, Expected=3769.0000
# Month=10, Predicted=3769.5891, Expected=3760.0000
# Month=11, Predicted=3759.7488, Expected=3785.0000
# Month=12, Predicted=3785.6706, Expected=3776.0000
# Month=13, Predicted=3775.7306, Expected=3755.0000
# Month=14, Predicted=3754.3728, Expected=3755.0000
# Month=15, Predicted=3755.1242, Expected=3751.0000
# Month=16, Predicted=3750.9664, Expected=3776.0000
# Month=17, Predicted=3776.6776, Expected=3847.0000
# Month=18, Predicted=3848.2194, Expected=3830.0000
# Month=19, Predicted=3829.3723, Expected=3881.0000
# Month=20, Predicted=3881.9663, Expected=3899.0000
# Month=21, Predicted=3899.5700, Expected=3917.0000
# Month=22, Predicted=3917.5841, Expected=3913.0000
# Month=23, Predicted=3912.8830, Expected=3901.0000
# Month=24, Predicted=3900.6565, Expected=3886.0000
# Month=25, Predicted=3885.5960, Expected=3892.5000
# Month=26, Predicted=3892.8589, Expected=3899.0000
# Month=27, Predicted=3899.3274, Expected=3886.0000
# Month=28, Predicted=3885.6300, Expected=3908.0000
# Month=29, Predicted=3908.6412, Expected=3875.0000
# Month=30, Predicted=3873.9669, Expected=3860.0000
# Month=31, Predicted=3859.6243, Expected=3880.0000
# Month=32, Predicted=3880.6218, Expected=3895.0000
# Month=33, Predicted=3895.5507, Expected=3954.0000
# Month=34, Predicted=3955.0761, Expected=3933.0000
# Month=35, Predicted=3932.2587, Expected=3937.0000
# Month=36, Predicted=3937.2073, Expected=3869.0000
# Month=37, Predicted=3867.0037, Expected=3852.0000
# Month=38, Predicted=3851.6480, Expected=3837.0000
# Month=39, Predicted=3836.6852, Expected=3832.0000
# Month=40, Predicted=3831.9945, Expected=3849.0000
# Month=41, Predicted=3849.5885, Expected=3863.0000
# Month=42, Predicted=3863.5377, Expected=3878.0000
# Month=43, Predicted=3878.5449, Expected=3855.0000
# Month=44, Predicted=3854.2573, Expected=3843.0000
# Month=45, Predicted=3842.6919, Expected=3847.0000
# Month=46, Predicted=3847.2596, Expected=3801.0000
# Month=47, Predicted=3799.6205, Expected=3787.0000
# Month=48, Predicted=3786.7047, Expected=3776.0000
# Month=49, Predicted=3775.7852, Expected=3797.0000
# Month=50, Predicted=3797.6360, Expected=3821.0000
# Month=51, Predicted=3821.6552, Expected=3877.0000
# Month=52, Predicted=3878.0312, Expected=3875.0000
# Month=53, Predicted=3874.8952, Expected=3890.0000
# Month=54, Predicted=3890.5371, Expected=3910.0000
# Month=55, Predicted=3910.6092, Expected=3924.0000
# Month=56, Predicted=3924.5340, Expected=3918.0000
# Month=57, Predicted=3917.8250, Expected=3936.0000
# Month=58, Predicted=3936.5928, Expected=3911.0000
# Month=59, Predicted=3910.2131, Expected=3891.0000
# Month=60, Predicted=3890.4466, Expected=3855.0000
# Run 12 — RMSE: 24.400898, MSE: 595.403841, NMSE: 0.0027206002
#
# ===== BiLSTM-SNP RUN 13/30 =====
# Training complete for run 13
# Month=1, Predicted=3799.0380, Expected=3796.0000
# Month=2, Predicted=3796.2908, Expected=3793.0000
# Month=3, Predicted=3793.2364, Expected=3766.0000
# Month=4, Predicted=3765.6322, Expected=3747.0000
# Month=5, Predicted=3746.8097, Expected=3754.0000
# Month=6, Predicted=3754.4385, Expected=3756.0000
# Month=7, Predicted=3756.3464, Expected=3767.0000
# Month=8, Predicted=3767.5464, Expected=3751.0000
# Month=9, Predicted=3750.9234, Expected=3769.0000
# Month=10, Predicted=3769.6843, Expected=3760.0000
# Month=11, Predicted=3760.0944, Expected=3785.0000
# Month=12, Predicted=3785.8328, Expected=3776.0000
# Month=13, Predicted=3776.1016, Expected=3755.0000
# Month=14, Predicted=3754.7847, Expected=3755.0000
# Month=15, Predicted=3755.2819, Expected=3751.0000
# Month=16, Predicted=3751.1982, Expected=3776.0000
# Month=17, Predicted=3776.8336, Expected=3847.0000
# Month=18, Predicted=3848.7079, Expected=3830.0000
# Month=19, Predicted=3829.9584, Expected=3881.0000
# Month=20, Predicted=3882.3376, Expected=3899.0000
# Month=21, Predicted=3899.7193, Expected=3917.0000
# Month=22, Predicted=3917.7084, Expected=3913.0000
# Month=23, Predicted=3913.2229, Expected=3901.0000
# Month=24, Predicted=3901.0061, Expected=3886.0000
# Month=25, Predicted=3885.9193, Expected=3892.5000
# Month=26, Predicted=3892.9287, Expected=3899.0000
# Month=27, Predicted=3899.4433, Expected=3886.0000
# Month=28, Predicted=3885.9903, Expected=3908.0000
# Month=29, Predicted=3908.7676, Expected=3875.0000
# Month=30, Predicted=3874.4983, Expected=3860.0000
# Month=31, Predicted=3859.9121, Expected=3880.0000
# Month=32, Predicted=3880.7204, Expected=3895.0000
# Month=33, Predicted=3895.6370, Expected=3954.0000
# Month=34, Predicted=3955.4990, Expected=3933.0000
# Month=35, Predicted=3932.8474, Expected=3937.0000
# Month=36, Predicted=3937.3840, Expected=3869.0000
# Month=37, Predicted=3867.5494, Expected=3852.0000
# Month=38, Predicted=3851.8260, Expected=3837.0000
# Month=39, Predicted=3836.9069, Expected=3832.0000
# Month=40, Predicted=3832.1663, Expected=3849.0000
# Month=41, Predicted=3849.6719, Expected=3863.0000
# Month=42, Predicted=3863.6224, Expected=3878.0000
# Month=43, Predicted=3878.6456, Expected=3855.0000
# Month=44, Predicted=3854.7592, Expected=3843.0000
# Month=45, Predicted=3842.9959, Expected=3847.0000
# Month=46, Predicted=3847.3793, Expected=3801.0000
# Month=47, Predicted=3800.1428, Expected=3787.0000
# Month=48, Predicted=3786.9247, Expected=3776.0000
# Month=49, Predicted=3776.0161, Expected=3797.0000
# Month=50, Predicted=3797.7501, Expected=3821.0000
# Month=51, Predicted=3821.8303, Expected=3877.0000
# Month=52, Predicted=3878.4536, Expected=3875.0000
# Month=53, Predicted=3875.3089, Expected=3890.0000
# Month=54, Predicted=3890.6377, Expected=3910.0000
# Month=55, Predicted=3910.7406, Expected=3924.0000
# Month=56, Predicted=3924.6181, Expected=3918.0000
# Month=57, Predicted=3918.1695, Expected=3936.0000
# Month=58, Predicted=3936.6842, Expected=3911.0000
# Month=59, Predicted=3910.6963, Expected=3891.0000
# Month=60, Predicted=3890.7897, Expected=3855.0000
# Run 13 — RMSE: 24.403158, MSE: 595.514106, NMSE: 0.0027212072
#
# ===== BiLSTM-SNP RUN 14/30 =====
# Training complete for run 14
# Month=1, Predicted=3798.6253, Expected=3796.0000
# Month=2, Predicted=3795.6672, Expected=3793.0000
# Month=3, Predicted=3792.8066, Expected=3766.0000
# Month=4, Predicted=3765.2884, Expected=3747.0000
# Month=5, Predicted=3746.6475, Expected=3754.0000
# Month=6, Predicted=3754.3159, Expected=3756.0000
# Month=7, Predicted=3756.0636, Expected=3767.0000
# Month=8, Predicted=3767.2577, Expected=3751.0000
# Month=9, Predicted=3750.5317, Expected=3769.0000
# Month=10, Predicted=3769.4876, Expected=3760.0000
# Month=11, Predicted=3759.6892, Expected=3785.0000
# Month=12, Predicted=3785.6148, Expected=3776.0000
# Month=13, Predicted=3775.6311, Expected=3755.0000
# Month=14, Predicted=3754.4595, Expected=3755.0000
# Month=15, Predicted=3755.0945, Expected=3751.0000
# Month=16, Predicted=3750.9333, Expected=3776.0000
# Month=17, Predicted=3776.6397, Expected=3847.0000
# Month=18, Predicted=3848.5881, Expected=3830.0000
# Month=19, Predicted=3829.1801, Expected=3881.0000
# Month=20, Predicted=3882.1575, Expected=3899.0000
# Month=21, Predicted=3899.1474, Expected=3917.0000
# Month=22, Predicted=3917.2141, Expected=3913.0000
# Month=23, Predicted=3912.6975, Expected=3901.0000
# Month=24, Predicted=3900.6287, Expected=3886.0000
# Month=25, Predicted=3885.6527, Expected=3892.5000
# Month=26, Predicted=3892.7410, Expected=3899.0000
# Month=27, Predicted=3899.1496, Expected=3886.0000
# Month=28, Predicted=3885.6315, Expected=3908.0000
# Month=29, Predicted=3908.5804, Expected=3875.0000
# Month=30, Predicted=3874.0704, Expected=3860.0000
# Month=31, Predicted=3859.7491, Expected=3880.0000
# Month=32, Predicted=3880.6144, Expected=3895.0000
# Month=33, Predicted=3895.3012, Expected=3954.0000
# Month=34, Predicted=3955.3172, Expected=3933.0000
# Month=35, Predicted=3932.1366, Expected=3937.0000
# Month=36, Predicted=3937.0558, Expected=3869.0000
# Month=37, Predicted=3867.2629, Expected=3852.0000
# Month=38, Predicted=3851.9049, Expected=3837.0000
# Month=39, Predicted=3836.8562, Expected=3832.0000
# Month=40, Predicted=3832.0497, Expected=3849.0000
# Month=41, Predicted=3849.5117, Expected=3863.0000
# Month=42, Predicted=3863.2824, Expected=3878.0000
# Month=43, Predicted=3878.2579, Expected=3855.0000
# Month=44, Predicted=3854.2947, Expected=3843.0000
# Month=45, Predicted=3842.7597, Expected=3847.0000
# Month=46, Predicted=3847.1783, Expected=3801.0000
# Month=47, Predicted=3799.8651, Expected=3787.0000
# Month=48, Predicted=3786.8931, Expected=3776.0000
# Month=49, Predicted=3775.9007, Expected=3797.0000
# Month=50, Predicted=3797.6413, Expected=3821.0000
# Month=51, Predicted=3821.5175, Expected=3877.0000
# Month=52, Predicted=3878.1938, Expected=3875.0000
# Month=53, Predicted=3874.5972, Expected=3890.0000
# Month=54, Predicted=3890.2224, Expected=3910.0000
# Month=55, Predicted=3910.3372, Expected=3924.0000
# Month=56, Predicted=3924.1588, Expected=3918.0000
# Month=57, Predicted=3917.6870, Expected=3936.0000
# Month=58, Predicted=3936.3929, Expected=3911.0000
# Month=59, Predicted=3910.2523, Expected=3891.0000
# Month=60, Predicted=3890.5753, Expected=3855.0000
# Run 14 — RMSE: 24.431082, MSE: 596.877749, NMSE: 0.0027307265
#
# ===== BiLSTM-SNP RUN 15/30 =====
# Training complete for run 15
# Month=1, Predicted=3798.8795, Expected=3796.0000
# Month=2, Predicted=3796.0216, Expected=3793.0000
# Month=3, Predicted=3793.0566, Expected=3766.0000
# Month=4, Predicted=3765.4841, Expected=3747.0000
# Month=5, Predicted=3746.7291, Expected=3754.0000
# Month=6, Predicted=3754.3538, Expected=3756.0000
# Month=7, Predicted=3756.1880, Expected=3767.0000
# Month=8, Predicted=3767.3989, Expected=3751.0000
# Month=9, Predicted=3750.7329, Expected=3769.0000
# Month=10, Predicted=3769.5908, Expected=3760.0000
# Month=11, Predicted=3759.8996, Expected=3785.0000
# Month=12, Predicted=3785.7397, Expected=3776.0000
# Month=13, Predicted=3775.8837, Expected=3755.0000
# Month=14, Predicted=3754.6364, Expected=3755.0000
# Month=15, Predicted=3755.1813, Expected=3751.0000
# Month=16, Predicted=3751.0564, Expected=3776.0000
# Month=17, Predicted=3776.7392, Expected=3847.0000
# Month=18, Predicted=3848.7160, Expected=3830.0000
# Month=19, Predicted=3829.5936, Expected=3881.0000
# Month=20, Predicted=3882.3163, Expected=3899.0000
# Month=21, Predicted=3899.4876, Expected=3917.0000
# Month=22, Predicted=3917.5209, Expected=3913.0000
# Month=23, Predicted=3913.0048, Expected=3901.0000
# Month=24, Predicted=3900.8476, Expected=3886.0000
# Month=25, Predicted=3885.7967, Expected=3892.5000
# Month=26, Predicted=3892.8251, Expected=3899.0000
# Month=27, Predicted=3899.2904, Expected=3886.0000
# Month=28, Predicted=3885.8119, Expected=3908.0000
# Month=29, Predicted=3908.6779, Expected=3875.0000
# Month=30, Predicted=3874.2943, Expected=3860.0000
# Month=31, Predicted=3859.8286, Expected=3880.0000
# Month=32, Predicted=3880.6527, Expected=3895.0000
# Month=33, Predicted=3895.4725, Expected=3954.0000
# Month=34, Predicted=3955.4639, Expected=3933.0000
# Month=35, Predicted=3932.5176, Expected=3937.0000
# Month=36, Predicted=3937.2471, Expected=3869.0000
# Month=37, Predicted=3867.4227, Expected=3852.0000
# Month=38, Predicted=3851.8515, Expected=3837.0000
# Month=39, Predicted=3836.8428, Expected=3832.0000
# Month=40, Predicted=3832.0665, Expected=3849.0000
# Month=41, Predicted=3849.5653, Expected=3863.0000
# Month=42, Predicted=3863.4511, Expected=3878.0000
# Month=43, Predicted=3878.4698, Expected=3855.0000
# Month=44, Predicted=3854.5487, Expected=3843.0000
# Month=45, Predicted=3842.8872, Expected=3847.0000
# Month=46, Predicted=3847.2697, Expected=3801.0000
# Month=47, Predicted=3800.0030, Expected=3787.0000
# Month=48, Predicted=3786.8896, Expected=3776.0000
# Month=49, Predicted=3775.9271, Expected=3797.0000
# Month=50, Predicted=3797.6707, Expected=3821.0000
# Month=51, Predicted=3821.6804, Expected=3877.0000
# Month=52, Predicted=3878.3851, Expected=3875.0000
# Month=53, Predicted=3874.9888, Expected=3890.0000
# Month=54, Predicted=3890.4790, Expected=3910.0000
# Month=55, Predicted=3910.5886, Expected=3924.0000
# Month=56, Predicted=3924.4363, Expected=3918.0000
# Month=57, Predicted=3917.9641, Expected=3936.0000
# Month=58, Predicted=3936.5692, Expected=3911.0000
# Month=59, Predicted=3910.4981, Expected=3891.0000
# Month=60, Predicted=3890.6898, Expected=3855.0000
# Run 15 — RMSE: 24.420236, MSE: 596.347942, NMSE: 0.0027256224
#
# ===== BiLSTM-SNP RUN 16/30 =====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 34
#      32 # Stateful training: manual epoch loop + reset_states
#      33 for epoch in range(100):
# ---> 34     model.fit(
#      35         X_train,
#      36         y_train,
#      37         epochs=1,
#      38         batch_size=1,
#      39         verbose=0,
#      40         shuffle=False
#      41     )
#      42     bi_layer.forward_layer.reset_states()
#      43     bi_layer.backward_layer.reset_states()
#
# File ~/Research/venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/Research/venv/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/Research/venv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# ============================================================
# BiLSTM-SNP Summary Statistics
# ============================================================

print('\n===== BiLSTM-SNP FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(bi_all_rmse):.10f} ± {np.var(bi_all_rmse):.15f}')
print(f'MSE:  {np.mean(bi_all_mse):.10f} ± {np.var(bi_all_mse):.15f}')
print(f'NMSE: {np.mean(bi_all_nmse):.10f} ± {np.var(bi_all_nmse):.15f}')

best_bi_idx = bi_all_rmse.index(min(bi_all_rmse))
print(f'\nBest run: {best_bi_idx+1}')
print(f'  RMSE: {bi_all_rmse[best_bi_idx]:.15f}')
print(f'  MSE:  {bi_all_mse[best_bi_idx]:.15f}')
print(f'  NMSE: {bi_all_nmse[best_bi_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_bi_preds = bi_all_predictions[best_bi_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_bi_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('BiLSTM-SNP — CLOSING (Best Run)')
plt.show()

# %% [markdown]
# # **Incorporating attention mechanism**

# %% [markdown]
# # Attention Mechanism in LSTM-SNP
#
# ## 1. Sequence Representation
#
# Standard LSTM-SNP compresses a sequence as:
#
# $$
# x_1, x_2, \dots, x_T \longrightarrow h_T
# $$
#
# This creates an information bottleneck.
#
# Instead, with attention we retain all hidden states:
#
# $$
# H = \{h_1, h_2, \dots, h_T\}
# $$
#
# where:
#
# $$
# h_t \in \mathbb{R}^{d}
# $$
#
#
#
# ## 2. Alignment Score Function (Additive Attention)
#
# Each hidden state receives a score:
#
# $$
# e_t = v^\top \tanh(W h_t + b)
# $$
#
# where:
#
# $$
# W \in \mathbb{R}^{d \times d},
# \quad
# v \in \mathbb{R}^{d},
# \quad
# b \in \mathbb{R}^{d}
# $$
#
#
#
# ## 3. Softmax Normalization
#
# Attention weights are computed as:
#
# $$
# \alpha_t =
# \frac{\exp(e_t)}
# {\sum_{k=1}^{T} \exp(e_k)}
# $$
#
# with:
#
# $$
# \sum_{t=1}^{T} \alpha_t = 1
# $$
#
#
# ## 4. Context Vector
#
# The context vector is a weighted sum of hidden states:
#
# $$
# c = \sum_{t=1}^{T} \alpha_t h_t
# $$
#
# where:
#
# $$
# c \in \mathbb{R}^{d}
# $$
#
#
#
# ## 5. Final Prediction
#
# The final output is computed as:
#
# $$
# \hat{y} = W_o c + b_o
# $$
#
# where:
#
# $$
# W_o \in \mathbb{R}^{1 \times d},
# \quad
# b_o \in \mathbb{R}
# $$
#
#
# ## 6. Full Compact Form
#
# $$
# e_t = v^\top \tanh(W h_t + b)
# $$
#
# $$
# \alpha_t =
# \frac{\exp(e_t)}
# {\sum_{k=1}^{T} \exp(e_k)}
# $$
#
# $$
# c = \sum_{t=1}^{T} \alpha_t h_t
# $$
#
# $$
# \hat{y} = W_o c + b_o
# $$

# %%
class SimpleAttention(layers.Layer):
    def __init__(self, units):
        super().__init__()
        self.W = layers.Dense(units)
        self.V = layers.Dense(1)

    def call(self, hidden_states):
        # hidden_states: (batch, T, units)

        score = self.V(tf.nn.tanh(self.W(hidden_states)))
        attention_weights = tf.nn.softmax(score, axis=1)

        context_vector = attention_weights * hidden_states
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector

# %%
def build_lstm_snp_attention(input_dim, units, batch_size):
    """
    Stateful LSTM-SNP + Attention model.
    return_sequences=True to provide all hidden states to attention.
    """
    cell = LSTMSNPCell(units)
    rnn_layer = layers.RNN(cell, return_sequences=True, stateful=True)

    inputs = tf.keras.Input(batch_shape=(batch_size, None, input_dim))
    sequence_output = rnn_layer(inputs)

    attention_layer = SimpleAttention(units)
    context = attention_layer(sequence_output)

    outputs = layers.Dense(1)(context)

    model = tf.keras.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
# ============================================================
# LSTM-SNP + Attention (lag=1) — DEGENERATE ATTENTION CONTROL
# With T=1 timestep: softmax([e_1]) = [1.0], α_1 = 1 always.
# Context vector = h_1. Attention has zero selective effect.
# This serves as a control experiment.
# ============================================================
att_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att_model_check.summary()

# %%
# ============================================================
# LSTM-SNP + Attention (lag=1): 30-Run Protocol
# DEGENERATE ATTENTION CONTROL (T=1, α₁=1 always)
# ============================================================

att1_all_rmse = []
att1_all_mse = []
att1_all_nmse = []
att1_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=1) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train,
            y_train,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass
    train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
    model.predict(train_reshaped, batch_size=1, verbose=0)

    # Test predictions (single-step)
    predictions = []
    for i in range(len(test_scaled)):
        X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
        X_input = X.reshape(1, 1, len(X))
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling
        new_row = [x for x in X] + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train) + i]

        predictions.append(inverted)

        expected = raw_values[len(train) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att1_all_rmse.append(rmse)
    att1_all_mse.append(mse)
    att1_all_nmse.append(nmse)
    att1_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

# %%
# ============================================================
# Attention (lag=1) Summary — Degenerate Attention Control
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=1) — DEGENERATE ATTENTION CONTROL =====')
print('Note: T=1, softmax([e_1]) = [1.0], α_1 = 1 always. Attention has NO selective effect.')
print(f'\nRMSE: {np.mean(att1_all_rmse):.10f} ± {np.var(att1_all_rmse):.15f}')
print(f'MSE:  {np.mean(att1_all_mse):.10f} ± {np.var(att1_all_mse):.15f}')
print(f'NMSE: {np.mean(att1_all_nmse):.10f} ± {np.var(att1_all_nmse):.15f}')

best_att1_idx = att1_all_rmse.index(min(att1_all_rmse))
print(f'\nBest run: {best_att1_idx+1}')
print(f'  RMSE: {att1_all_rmse[best_att1_idx]:.15f}')
print(f'  MSE:  {att1_all_mse[best_att1_idx]:.15f}')
print(f'  NMSE: {att1_all_nmse[best_att1_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att1_preds = att1_all_predictions[best_att1_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att1_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=1) — Degenerate Control (Best Run)')
plt.show()

# %% [markdown]
# # LSTM-SNP + Attention (lag=5)

# %%
# Redefine supervised data with lag=5

lag = 5
supervised_lag5 = timeseries_to_supervised(diff_values, lag)

# %%
# lag=5 data preparation (distinct variable names to avoid shadowing)
train5, test5 = supervised_lag5[:-60], supervised_lag5[-60:]

scaler5 = MinMaxScaler(feature_range=(-1, 1))
scaler5.fit(train5)

train5_scaled = scaler5.transform(train5)
test5_scaled = scaler5.transform(test5)

X_train5 = train5_scaled[:, :-1].reshape((-1, lag, 1))
y_train5 = train5_scaled[:, -1]

X_test5 = test5_scaled[:, :-1].reshape((-1, lag, 1))
y_test5 = test5_scaled[:, -1]

print(f"X_train5 shape: {X_train5.shape}")  # (samples, 5, 1)
print(f"X_test5 shape:  {X_test5.shape}")   # (60, 5, 1)

# %%
att5_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att5_model_check.summary()

# %%
# ============================================================
# LSTM-SNP + Attention (lag=5): 30-Run Protocol
# ============================================================

att5_all_rmse = []
att5_all_mse = []
att5_all_nmse = []
att5_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=5) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model (input_dim=1, lag=5 timesteps)
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train5,
            y_train5,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    model.predict(X_train5, batch_size=1, verbose=0)

    # Test predictions (single-step over lag=5 windows)
    predictions = []
    for i in range(len(test5_scaled)):
        X_input = X_test5[i].reshape(1, lag, 1)
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling: reconstruct full row [x1..x5, yhat]
        new_row = list(X_test5[i].flatten()) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler5.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train5) + i]

        predictions.append(inverted)

        expected = raw_values[len(train5) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att5_all_rmse.append(rmse)
    att5_all_mse.append(mse)
    att5_all_nmse.append(nmse)
    att5_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

# %%
# ============================================================
# Attention (lag=5) Summary Statistics
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=5) FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(att5_all_rmse):.10f} ± {np.var(att5_all_rmse):.15f}')
print(f'MSE:  {np.mean(att5_all_mse):.10f} ± {np.var(att5_all_mse):.15f}')
print(f'NMSE: {np.mean(att5_all_nmse):.10f} ± {np.var(att5_all_nmse):.15f}')

best_att5_idx = att5_all_rmse.index(min(att5_all_rmse))
print(f'\nBest run: {best_att5_idx+1}')
print(f'  RMSE: {att5_all_rmse[best_att5_idx]:.15f}')
print(f'  MSE:  {att5_all_mse[best_att5_idx]:.15f}')
print(f'  NMSE: {att5_all_nmse[best_att5_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att5_preds = att5_all_predictions[best_att5_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att5_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=5) — Best Run')
plt.show()

# %% [markdown]
# # LSTM-SNP + Attention (lag=10)

# %%
# Redefine supervised data with lag=10

lag10 = 10
supervised_lag10 = timeseries_to_supervised(diff_values, lag10)

train10, test10 = supervised_lag10[:-60], supervised_lag10[-60:]

scaler10 = MinMaxScaler(feature_range=(-1, 1))
scaler10.fit(train10)

train10_scaled = scaler10.transform(train10)
test10_scaled = scaler10.transform(test10)

X_train10 = train10_scaled[:, :-1].reshape((-1, lag10, 1))
y_train10 = train10_scaled[:, -1]

X_test10 = test10_scaled[:, :-1].reshape((-1, lag10, 1))
y_test10 = test10_scaled[:, -1]

print(f"X_train10 shape: {X_train10.shape}")  # (samples, 10, 1)
print(f"X_test10 shape:  {X_test10.shape}")   # (60, 10, 1)

# %%
att10_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att10_model_check.summary()

# %%
# ============================================================
# LSTM-SNP + Attention (lag=10): 30-Run Protocol
# ============================================================

att10_all_rmse = []
att10_all_mse = []
att10_all_nmse = []
att10_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=10) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model (input_dim=1, lag=10 timesteps)
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train10,
            y_train10,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    model.predict(X_train10, batch_size=1, verbose=0)

    # Test predictions (single-step over lag=10 windows)
    predictions = []
    for i in range(len(test10_scaled)):
        X_input = X_test10[i].reshape(1, lag10, 1)
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling: reconstruct full row [x1..x10, yhat]
        new_row = list(X_test10[i].flatten()) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler10.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train10) + i]

        predictions.append(inverted)

        expected = raw_values[len(train10) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att10_all_rmse.append(rmse)
    att10_all_mse.append(mse)
    att10_all_nmse.append(nmse)
    att10_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

# %%
# ============================================================
# Attention (lag=10) Summary Statistics
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=10) FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(att10_all_rmse):.10f} ± {np.var(att10_all_rmse):.15f}')
print(f'MSE:  {np.mean(att10_all_mse):.10f} ± {np.var(att10_all_mse):.15f}')
print(f'NMSE: {np.mean(att10_all_nmse):.10f} ± {np.var(att10_all_nmse):.15f}')

best_att10_idx = att10_all_rmse.index(min(att10_all_rmse))
print(f'\nBest run: {best_att10_idx+1}')
print(f'  RMSE: {att10_all_rmse[best_att10_idx]:.15f}')
print(f'  MSE:  {att10_all_mse[best_att10_idx]:.15f}')
print(f'  NMSE: {att10_all_nmse[best_att10_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att10_preds = att10_all_predictions[best_att10_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att10_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=10) — Best Run')
plt.show()

# %% [markdown]
# # LSTM-SNP + Attention (lag=20)

# %%
# Redefine supervised data with lag=20

lag20 = 20
supervised_lag20 = timeseries_to_supervised(diff_values, lag20)

train20, test20 = supervised_lag20[:-60], supervised_lag20[-60:]

scaler20 = MinMaxScaler(feature_range=(-1, 1))
scaler20.fit(train20)

train20_scaled = scaler20.transform(train20)
test20_scaled = scaler20.transform(test20)

X_train20 = train20_scaled[:, :-1].reshape((-1, lag20, 1))
y_train20 = train20_scaled[:, -1]

X_test20 = test20_scaled[:, :-1].reshape((-1, lag20, 1))
y_test20 = test20_scaled[:, -1]

print(f"X_train20 shape: {X_train20.shape}")  # (samples, 20, 1)
print(f"X_test20 shape:  {X_test20.shape}")   # (60, 20, 1)

# %%
att20_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att20_model_check.summary()

# %%
# ============================================================
# LSTM-SNP + Attention (lag=20): 30-Run Protocol
# ============================================================

att20_all_rmse = []
att20_all_mse = []
att20_all_nmse = []
att20_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=20) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model (input_dim=1, lag=20 timesteps)
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train20,
            y_train20,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    model.predict(X_train20, batch_size=1, verbose=0)

    # Test predictions (single-step over lag=20 windows)
    predictions = []
    for i in range(len(test20_scaled)):
        X_input = X_test20[i].reshape(1, lag20, 1)
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling: reconstruct full row [x1..x20, yhat]
        new_row = list(X_test20[i].flatten()) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler20.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train20) + i]

        predictions.append(inverted)

        expected = raw_values[len(train20) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att20_all_rmse.append(rmse)
    att20_all_mse.append(mse)
    att20_all_nmse.append(nmse)
    att20_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

# %%
# ============================================================
# Attention (lag=20) Summary Statistics
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=20) FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(att20_all_rmse):.10f} ± {np.var(att20_all_rmse):.15f}')
print(f'MSE:  {np.mean(att20_all_mse):.10f} ± {np.var(att20_all_mse):.15f}')
print(f'NMSE: {np.mean(att20_all_nmse):.10f} ± {np.var(att20_all_nmse):.15f}')

best_att20_idx = att20_all_rmse.index(min(att20_all_rmse))
print(f'\nBest run: {best_att20_idx+1}')
print(f'  RMSE: {att20_all_rmse[best_att20_idx]:.15f}')
print(f'  MSE:  {att20_all_mse[best_att20_idx]:.15f}')
print(f'  NMSE: {att20_all_nmse[best_att20_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att20_preds = att20_all_predictions[best_att20_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att20_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=20) — Best Run')
plt.show()

# %% [markdown]
# # LSTM-SNP + Attention (lag=30)

# %%
# Redefine supervised data with lag=30

lag30 = 30
supervised_lag30 = timeseries_to_supervised(diff_values, lag30)

train30, test30 = supervised_lag30[:-60], supervised_lag30[-60:]

scaler30 = MinMaxScaler(feature_range=(-1, 1))
scaler30.fit(train30)

train30_scaled = scaler30.transform(train30)
test30_scaled = scaler30.transform(test30)

X_train30 = train30_scaled[:, :-1].reshape((-1, lag30, 1))
y_train30 = train30_scaled[:, -1]

X_test30 = test30_scaled[:, :-1].reshape((-1, lag30, 1))
y_test30 = test30_scaled[:, -1]

print(f"X_train30 shape: {X_train30.shape}")  # (samples, 30, 1)
print(f"X_test30 shape:  {X_test30.shape}")   # (60, 30, 1)

# %%
att30_model_check = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)
att30_model_check.summary()

# %%
# ============================================================
# LSTM-SNP + Attention (lag=30): 30-Run Protocol
# ============================================================

att30_all_rmse = []
att30_all_mse = []
att30_all_nmse = []
att30_all_predictions = []

for run in range(30):
    print(f'\n===== Attention(lag=30) RUN {run+1}/30 =====')

    # Per-run seed control
    np.random.seed(run)
    tf.random.set_seed(run)
    tf.keras.backend.clear_session()

    # Build stateful attention model (input_dim=1, lag=30 timesteps)
    model = build_lstm_snp_attention(input_dim=1, units=8, batch_size=1)

    # Unit forget bias initialization
    rnn_layer = model.layers[1]  # RNN layer
    cell = rnn_layer.cell
    weights = cell.get_weights()
    bias = weights[2].copy()
    bias[8:16] = 1.0
    weights[2] = bias
    cell.set_weights(weights)

    # Stateful training: manual epoch loop + reset_states
    for epoch in range(100):
        model.fit(
            X_train30,
            y_train30,
            epochs=1,
            batch_size=1,
            verbose=0,
            shuffle=False
        )
        rnn_layer.reset_states()

    print(f'Training complete for run {run+1}')

    # Warm-up prediction pass on training data
    model.predict(X_train30, batch_size=1, verbose=0)

    # Test predictions (single-step over lag=30 windows)
    predictions = []
    for i in range(len(test30_scaled)):
        X_input = X_test30[i].reshape(1, lag30, 1)
        yhat = model.predict(X_input, batch_size=1, verbose=0)[0, 0]

        # Invert scaling: reconstruct full row [x1..x30, yhat]
        new_row = list(X_test30[i].flatten()) + [yhat]
        array = np.array(new_row).reshape(1, len(new_row))
        inverted = scaler30.inverse_transform(array)[0, -1]

        # Invert differencing
        inverted = inverted + raw_values[len(train30) + i]

        predictions.append(inverted)

        expected = raw_values[len(train30) + i + 1]
        print(f'Month={i+1}, Predicted={inverted:.4f}, Expected={expected:.4f}')

    # Compute metrics
    actual = raw_values[-60:]
    rmse = sqrt(mean_squared_error(actual, predictions))
    mse = mean_squared_error(actual, predictions)
    meanV = np.mean(actual)
    dominator = np.linalg.norm(np.array(predictions) - meanV, 2)
    nmse = mse / np.power(dominator, 2)

    att30_all_rmse.append(rmse)
    att30_all_mse.append(mse)
    att30_all_nmse.append(nmse)
    att30_all_predictions.append(predictions)

    print(f'Run {run+1} — RMSE: {rmse:.6f}, MSE: {mse:.6f}, NMSE: {nmse:.10f}')

# %%
# ============================================================
# Attention (lag=30) Summary Statistics
# ============================================================

print('\n===== LSTM-SNP + Attention (lag=30) FINAL RESULTS (30 runs) =====')
print(f'RMSE: {np.mean(att30_all_rmse):.10f} ± {np.var(att30_all_rmse):.15f}')
print(f'MSE:  {np.mean(att30_all_mse):.10f} ± {np.var(att30_all_mse):.15f}')
print(f'NMSE: {np.mean(att30_all_nmse):.10f} ± {np.var(att30_all_nmse):.15f}')

best_att30_idx = att30_all_rmse.index(min(att30_all_rmse))
print(f'\nBest run: {best_att30_idx+1}')
print(f'  RMSE: {att30_all_rmse[best_att30_idx]:.15f}')
print(f'  MSE:  {att30_all_mse[best_att30_idx]:.15f}')
print(f'  NMSE: {att30_all_nmse[best_att30_idx]:.15f}')

# Plot best run
actual = raw_values[-60:]
best_att30_preds = att30_all_predictions[best_att30_idx]

plt.figure(figsize=(10, 5))
plt.plot(actual, 'k-o', label='Original data')
plt.plot(best_att30_preds, 'k+-', label='Predicted data')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Magnitude', fontsize=12)
plt.legend()
plt.title('LSTM-SNP + Attention (lag=30) — Best Run')
plt.show()

# %%
# ============================================================
# FINAL COMPREHENSIVE SUMMARY — ALL MODELS
# Average ± Std Dev over 30 runs for RMSE, MSE, NMSE
# ============================================================

models = {
    'LSTM-SNP (Baseline, lag=1)': (all_rmse, all_mse, all_nmse),
    'BiLSTM-SNP (lag=1)': (bi_all_rmse, bi_all_mse, bi_all_nmse),
    'Attention (lag=1, degenerate)': (att1_all_rmse, att1_all_mse, att1_all_nmse),
    'Attention (lag=5)': (att5_all_rmse, att5_all_mse, att5_all_nmse),
    'Attention (lag=10)': (att10_all_rmse, att10_all_mse, att10_all_nmse),
    'Attention (lag=20)': (att20_all_rmse, att20_all_mse, att20_all_nmse),
    'Attention (lag=30)': (att30_all_rmse, att30_all_mse, att30_all_nmse),
}

print('=' * 110)
print('COMPREHENSIVE RESULTS — All Models (30 runs each)')
print('=' * 110)
print(f"{'Model':<35} {'Avg RMSE':>12} {'± Std':>12} {'Avg MSE':>14} {'± Std':>14} {'Avg NMSE':>16} {'± Std':>16}")
print('-' * 110)

for name, (rmse_list, mse_list, nmse_list) in models.items():
    print(
        f"{name:<35} "
        f"{np.mean(rmse_list):>12.6f} {np.std(rmse_list):>12.6f} "
        f"{np.mean(mse_list):>14.6f} {np.std(mse_list):>14.6f} "
        f"{np.mean(nmse_list):>16.10f} {np.std(nmse_list):>16.10f}"
    )

print('=' * 110)
